# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_zhishi_yesheng=pd.DataFrame(columns=columns)
channel_zhishi_yesheng
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[7]/div/a/span').click()  #选择“知识”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[7]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '知识'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[7]/a').click()  #选择“野生技术协会”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[7]/a').text
sub_channel
# Out:
# '野生技术协会'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(4,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_zhishi_yesheng.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-22 07:44:05.475539
# <ipython-input-12-687f3809e3d0>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-12-687f3809e3d0>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-12-687f3809e3d0>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1Vf4y1m7Kg视频属性的抓取
# BV号为1Vf4y1m7Kg的视频属性抓取结束
# <ipython-input-12-687f3809e3d0>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为13k4y1R74f视频属性的抓取
# BV号为13k4y1R74f的视频属性抓取结束
# 开始BV号为1nt4y12789视频属性的抓取
# BV号为1nt4y12789的视频属性抓取结束
# 开始BV号为1Za4y1v7Ms视频属性的抓取
# BV号为1Za4y1v7Ms的视频属性抓取结束
# 开始BV号为1FA41187pV视频属性的抓取
# BV号为1FA41187pV的视频属性抓取结束
# 开始BV号为1dc411h7ib视频属性的抓取
# BV号为1dc411h7ib的视频属性抓取结束
# 开始BV号为13f4y1S7qh视频属性的抓取
# BV号为13f4y1S7qh的视频属性抓取结束
# 开始BV号为1yk4y1R7Ds视频属性的抓取
# BV号为1yk4y1R7Ds的视频属性抓取结束
# 开始BV号为1vA411b7Rn视频属性的抓取
# BV号为1vA411b7Rn的视频属性抓取结束
# 开始BV号为1tA411h7Kf视频属性的抓取
# BV号为1tA411h7Kf的视频属性抓取结束
# 开始BV号为1Yi4y1t7YK视频属性的抓取
# BV号为1Yi4y1t7YK的视频属性抓取结束
# 开始BV号为1Gt4y127dD视频属性的抓取
# BV号为1Gt4y127dD的视频属性抓取结束
# 开始BV号为16i4y1t7HB视频属性的抓取
# BV号为16i4y1t7HB的视频属性抓取结束
# 开始BV号为1wk4y1k7zF视频属性的抓取
# BV号为1wk4y1k7zF的视频属性抓取结束
# 开始BV号为1EZ4y1j7xu视频属性的抓取
# BV号为1EZ4y1j7xu的视频属性抓取结束
# 开始BV号为1QK4y1r7ms视频属性的抓取
# BV号为1QK4y1r7ms的视频属性抓取结束
# 开始BV号为1zT4y1G7i2视频属性的抓取
# BV号为1zT4y1G7i2的视频属性抓取结束
# 开始BV号为12i4y1t7bw视频属性的抓取
# BV号为12i4y1t7bw的视频属性抓取结束
# 开始BV号为1f54y1X7HA视频属性的抓取
# BV号为1f54y1X7HA的视频属性抓取结束
# 开始BV号为1GV411Z7YR视频属性的抓取
# BV号为1GV411Z7YR的视频属性抓取结束
# 开始BV号为1Xg4y1z7Qn视频属性的抓取
# BV号为1Xg4y1z7Qn的视频属性抓取结束
# 开始BV号为1JV411o7Jj视频属性的抓取
# BV号为1JV411o7Jj的视频属性抓取结束
# 开始BV号为1XK4y1r7wc视频属性的抓取
# BV号为1XK4y1r7wc的视频属性抓取结束
# 开始BV号为1v64y1T7V8视频属性的抓取
# BV号为1v64y1T7V8的视频属性抓取结束
# 开始BV号为14Q4y1T7XH视频属性的抓取
# BV号为14Q4y1T7XH的视频属性抓取结束
# 开始BV号为1dZ4y1W7XH视频属性的抓取
# BV号为1dZ4y1W7XH的视频属性抓取结束
# 开始BV号为1S54y1R7SB视频属性的抓取
# BV号为1S54y1R7SB的视频属性抓取结束
# 开始BV号为1YT4y1g72C视频属性的抓取
# BV号为1YT4y1g72C的视频属性抓取结束
# 开始BV号为1Tz41187r5视频属性的抓取
# BV号为1Tz41187r5的视频属性抓取结束
# 开始BV号为1Kz41187Pe视频属性的抓取
# BV号为1Kz41187Pe的视频属性抓取结束
# 开始BV号为1Mf4y1S7mb视频属性的抓取
# BV号为1Mf4y1S7mb的视频属性抓取结束
# 开始BV号为1Z5411t74c视频属性的抓取
# BV号为1Z5411t74c的视频属性抓取结束
# 开始BV号为1Sk4y1d7fr视频属性的抓取
# BV号为1Sk4y1d7fr的视频属性抓取结束
# 开始BV号为1464y1u73U视频属性的抓取
# BV号为1464y1u73U的视频属性抓取结束
# 开始BV号为1kp4y1X7Ya视频属性的抓取
# BV号为1kp4y1X7Ya的视频属性抓取结束
# 开始BV号为1W54y197s6视频属性的抓取
# BV号为1W54y197s6的视频属性抓取结束
# 开始BV号为1q54y1d7nL视频属性的抓取
# BV号为1q54y1d7nL的视频属性抓取结束
# 开始BV号为1ik4y1R7Yw视频属性的抓取
# BV号为1ik4y1R7Yw的视频属性抓取结束
# 开始BV号为1LC4y1s7q1视频属性的抓取
# BV号为1LC4y1s7q1的视频属性抓取结束
# 开始BV号为1Tp4y197Xh视频属性的抓取
# BV号为1Tp4y197Xh的视频属性抓取结束
# 开始BV号为1Y54y1d77C视频属性的抓取
# BV号为1Y54y1d77C的视频属性抓取结束
# 开始BV号为1T64y1u7GX视频属性的抓取
# BV号为1T64y1u7GX的视频属性抓取结束
# 开始BV号为1uV411o7gg视频属性的抓取
# BV号为1uV411o7gg的视频属性抓取结束
# 开始BV号为11g4y1879b视频属性的抓取
# BV号为11g4y1879b的视频属性抓取结束
# 开始BV号为1sK41177Yx视频属性的抓取
# BV号为1sK41177Yx的视频属性抓取结束
# 开始BV号为1Yz411B7QV视频属性的抓取
# BV号为1Yz411B7QV的视频属性抓取结束
# 开始BV号为1sc411h7x5视频属性的抓取
# BV号为1sc411h7x5的视频属性抓取结束
# 开始BV号为1qK411L7gn视频属性的抓取
# BV号为1qK411L7gn的视频属性抓取结束
# 开始BV号为1QC4y1s7NG视频属性的抓取
# BV号为1QC4y1s7NG的视频属性抓取结束
# 开始BV号为1DC4y1p7vN视频属性的抓取
# BV号为1DC4y1p7vN的视频属性抓取结束
# 开始BV号为1Zp4y1X7bh视频属性的抓取
# BV号为1Zp4y1X7bh的视频属性抓取结束
# 开始BV号为1mk4y1r7ec视频属性的抓取
# BV号为1mk4y1r7ec的视频属性抓取结束
# 开始BV号为11K411V71i视频属性的抓取
# BV号为11K411V71i的视频属性抓取结束
# 开始BV号为1Bf4y1S7Wu视频属性的抓取
# BV号为1Bf4y1S7Wu的视频属性抓取结束
# 开始BV号为1bt4y127Ui视频属性的抓取
# BV号为1bt4y127Ui的视频属性抓取结束
# 开始BV号为1954y1Q7Wi视频属性的抓取
# BV号为1954y1Q7Wi的视频属性抓取结束
# 开始BV号为11T4y1G7rW视频属性的抓取
# BV号为11T4y1G7rW的视频属性抓取结束
# 开始BV号为1ha4y1t71Z视频属性的抓取
# BV号为1ha4y1t71Z的视频属性抓取结束
# 开始BV号为1XA411t7Wo视频属性的抓取
# BV号为1XA411t7Wo的视频属性抓取结束
# 开始BV号为13z411b7n5视频属性的抓取
# BV号为13z411b7n5的视频属性抓取结束
# 开始BV号为1ep4y1X7Gx视频属性的抓取
# BV号为1ep4y1X7Gx的视频属性抓取结束
# 开始BV号为1SV411o7Zo视频属性的抓取
# BV号为1SV411o7Zo的视频属性抓取结束
# 开始BV号为1Xf4y1U7Qh视频属性的抓取
# BV号为1Xf4y1U7Qh的视频属性抓取结束
# 开始BV号为1qi4y1b7XA视频属性的抓取
# BV号为1qi4y1b7XA的视频属性抓取结束
# 开始BV号为1R5411t7QQ视频属性的抓取
# BV号为1R5411t7QQ的视频属性抓取结束
# 开始BV号为1TT4y1372z视频属性的抓取
# BV号为1TT4y1372z的视频属性抓取结束
# 开始BV号为1NC4y1x72v视频属性的抓取
# BV号为1NC4y1x72v的视频属性抓取结束
# 开始BV号为1Lg4y1z75i视频属性的抓取
# BV号为1Lg4y1z75i的视频属性抓取结束
# 开始BV号为1DA41187yT视频属性的抓取
# BV号为1DA41187yT的视频属性抓取结束
# 开始BV号为1Hz411b76U视频属性的抓取
# BV号为1Hz411b76U的视频属性抓取结束
# 开始BV号为1S54y197D2视频属性的抓取
# BV号为1S54y197D2的视频属性抓取结束
# 开始BV号为1qt4y1y7ky视频属性的抓取
# BV号为1qt4y1y7ky的视频属性抓取结束
# 开始BV号为1ya4y1v7J7视频属性的抓取
# BV号为1ya4y1v7J7的视频属性抓取结束
# 开始BV号为11Z4y1x7dm视频属性的抓取
# BV号为11Z4y1x7dm的视频属性抓取结束
# 开始BV号为1cC4y1x7xs视频属性的抓取
# BV号为1cC4y1x7xs的视频属性抓取结束
# 开始BV号为1vV411o7fH视频属性的抓取
# BV号为1vV411o7fH的视频属性抓取结束
# 开始BV号为1YC4y147Nf视频属性的抓取
# BV号为1YC4y147Nf的视频属性抓取结束
# 开始BV号为1Bp4y1C7Yu视频属性的抓取
# BV号为1Bp4y1C7Yu的视频属性抓取结束
# 开始BV号为1jA411h7gV视频属性的抓取
# BV号为1jA411h7gV的视频属性抓取结束
# 开始BV号为13A411h7wX视频属性的抓取
# BV号为13A411h7wX的视频属性抓取结束
# 开始BV号为1w54114777视频属性的抓取
# BV号为1w54114777的视频属性抓取结束
# 开始BV号为1qZ4y1j7m2视频属性的抓取
# BV号为1qZ4y1j7m2的视频属性抓取结束
# 开始BV号为14V411d7P7视频属性的抓取
# BV号为14V411d7P7的视频属性抓取结束
# 开始BV号为1Rc411h7Z3视频属性的抓取
# BV号为1Rc411h7Z3的视频属性抓取结束
# 开始BV号为1Sk4y197zY视频属性的抓取
# BV号为1Sk4y197zY的视频属性抓取结束
# 开始BV号为1Zt4y127GC视频属性的抓取
# BV号为1Zt4y127GC的视频属性抓取结束
# 开始BV号为1bp4y11769视频属性的抓取
# BV号为1bp4y11769的视频属性抓取结束
# 开始BV号为1P5411r7R1视频属性的抓取
# BV号为1P5411r7R1的视频属性抓取结束
# 开始BV号为1V64y1M7d8视频属性的抓取
# BV号为1V64y1M7d8的视频属性抓取结束
# 开始BV号为1Nt4y1U7oN视频属性的抓取
# BV号为1Nt4y1U7oN的视频属性抓取结束
# 开始BV号为1Pt4y1m7Bw视频属性的抓取
# BV号为1Pt4y1m7Bw的视频属性抓取结束
# 开始BV号为1Ra4y1t7wS视频属性的抓取
# BV号为1Ra4y1t7wS的视频属性抓取结束
# 开始BV号为1n5411t7qQ视频属性的抓取
# BV号为1n5411t7qQ的视频属性抓取结束
# 开始BV号为1kg4y1b75B视频属性的抓取
# BV号为1kg4y1b75B的视频属性抓取结束
# 开始BV号为1gk4y1o7ZD视频属性的抓取
# BV号为1gk4y1o7ZD的视频属性抓取结束
# 开始BV号为1W5411x7tv视频属性的抓取
# BV号为1W5411x7tv的视频属性抓取结束
# 开始BV号为1Lz41187k4视频属性的抓取
# BV号为1Lz41187k4的视频属性抓取结束
# 开始BV号为13i4y1t7bX视频属性的抓取
# 开始BV号为13i4y1t7bX视频属性的抓取
# BV号为13i4y1t7bX的视频属性抓取结束
# 开始BV号为1AZ4y1479G视频属性的抓取
# BV号为1AZ4y1479G的视频属性抓取结束
# 开始BV号为1gt4y1m7Eo视频属性的抓取
# BV号为1gt4y1m7Eo的视频属性抓取结束
# 开始BV号为1BK411W75W视频属性的抓取
# BV号为1BK411W75W的视频属性抓取结束
# 开始BV号为1Lp4y1X7Wq视频属性的抓取
# BV号为1Lp4y1X7Wq的视频属性抓取结束
# 开始BV号为19z411q7ma视频属性的抓取
# BV号为19z411q7ma的视频属性抓取结束
# 开始BV号为1Bz411q7Y5视频属性的抓取
# BV号为1Bz411q7Y5的视频属性抓取结束
# 开始BV号为1ja4y1i7zv视频属性的抓取
# BV号为1ja4y1i7zv的视频属性抓取结束
# 开始BV号为1K5411x7u3视频属性的抓取
# BV号为1K5411x7u3的视频属性抓取结束
# 开始BV号为1Jz411B7UW视频属性的抓取
# BV号为1Jz411B7UW的视频属性抓取结束
# 开始BV号为1Yz411z7Yt视频属性的抓取
# BV号为1Yz411z7Yt的视频属性抓取结束
# 开始BV号为1iK41157ip视频属性的抓取
# BV号为1iK41157ip的视频属性抓取结束
# 开始BV号为16K411W79T视频属性的抓取
# BV号为16K411W79T的视频属性抓取结束
# 开始BV号为1wQ4y1K7Qi视频属性的抓取
# BV号为1wQ4y1K7Qi的视频属性抓取结束
# 开始BV号为1bA411q74K视频属性的抓取
# BV号为1bA411q74K的视频属性抓取结束
# 开始BV号为14z411q7jX视频属性的抓取
# BV号为14z411q7jX的视频属性抓取结束
# 开始BV号为1dk4y167H7视频属性的抓取
# BV号为1dk4y167H7的视频属性抓取结束
# 开始BV号为1uz4y1d7zx视频属性的抓取
# BV号为1uz4y1d7zx的视频属性抓取结束
# 开始BV号为17K411W79T视频属性的抓取
# BV号为17K411W79T的视频属性抓取结束
# 开始BV号为1KA411t7CJ视频属性的抓取
# BV号为1KA411t7CJ的视频属性抓取结束
# 开始BV号为1HQ4y1P7hE视频属性的抓取
# BV号为1HQ4y1P7hE的视频属性抓取结束
# 开始BV号为18e411W7zV视频属性的抓取
# BV号为18e411W7zV的视频属性抓取结束
# 开始BV号为1Re411p7xY视频属性的抓取
# BV号为1Re411p7xY的视频属性抓取结束
# 开始BV号为1wK4y1b7Xm视频属性的抓取
# BV号为1wK4y1b7Xm的视频属性抓取结束
# 开始BV号为1ap4y19756视频属性的抓取
# BV号为1ap4y19756的视频属性抓取结束
# 开始BV号为1P541147mG视频属性的抓取
# BV号为1P541147mG的视频属性抓取结束
# 开始BV号为1Qa4y1e7fi视频属性的抓取
# BV号为1Qa4y1e7fi的视频属性抓取结束
# 开始BV号为1BQ4y1N7Ks视频属性的抓取
# BV号为1BQ4y1N7Ks的视频属性抓取结束
# 开始BV号为1jt4y1C77C视频属性的抓取
# BV号为1jt4y1C77C的视频属性抓取结束
# 开始BV号为1Cp4y1Q732视频属性的抓取
# BV号为1Cp4y1Q732的视频属性抓取结束
# 开始BV号为1PK4y1t7e6视频属性的抓取
# BV号为1PK4y1t7e6的视频属性抓取结束
# 开始BV号为1cT4y1g7QC视频属性的抓取
# BV号为1cT4y1g7QC的视频属性抓取结束
# 开始BV号为1bK4y187vy视频属性的抓取
# BV号为1bK4y187vy的视频属性抓取结束
# 开始BV号为18T4y1u7wL视频属性的抓取
# BV号为18T4y1u7wL的视频属性抓取结束
# 开始BV号为1Qp4y1Q7jq视频属性的抓取
# BV号为1Qp4y1Q7jq的视频属性抓取结束
# 开始BV号为1Hk4y1k7ZF视频属性的抓取
# BV号为1Hk4y1k7ZF的视频属性抓取结束
# 开始BV号为1D54y1X7yt视频属性的抓取
# BV号为1D54y1X7yt的视频属性抓取结束
# 开始BV号为1uQ4y1P7Yo视频属性的抓取
# BV号为1uQ4y1P7Yo的视频属性抓取结束
# 开始BV号为1hT4y1u7iC视频属性的抓取
# BV号为1hT4y1u7iC的视频属性抓取结束
# 开始BV号为1zf4y127Ks视频属性的抓取
# 开始BV号为1zf4y127Ks视频属性的抓取
# BV号为1zf4y127Ks的视频属性抓取结束
# 开始BV号为1qK41157bW视频属性的抓取
# BV号为1qK41157bW的视频属性抓取结束
# 开始BV号为1BT4y1u7DA视频属性的抓取
# BV号为1BT4y1u7DA的视频属性抓取结束
# <ipython-input-12-687f3809e3d0>:190: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1DT4y1g7oi视频属性的抓取
# BV号为1DT4y1g7oi的视频属性抓取结束
# 开始BV号为1bT4y1376L视频属性的抓取
# BV号为1bT4y1376L的视频属性抓取结束
# 开始BV号为19K411W7b6视频属性的抓取
# BV号为19K411W7b6的视频属性抓取结束
# 开始BV号为1WT4y1u7Cy视频属性的抓取
# BV号为1WT4y1u7Cy的视频属性抓取结束
# 开始BV号为17i4y147Ri视频属性的抓取
# BV号为17i4y147Ri的视频属性抓取结束
# 开始BV号为1NZ4y1W7yv视频属性的抓取
# BV号为1NZ4y1W7yv的视频属性抓取结束
# 开始BV号为1Nt4y1178T视频属性的抓取
# BV号为1Nt4y1178T的视频属性抓取结束
# 开始BV号为1Fk4y1k7Kq视频属性的抓取
# BV号为1Fk4y1k7Kq的视频属性抓取结束
# 开始BV号为1og4y1q7M4视频属性的抓取
# BV号为1og4y1q7M4的视频属性抓取结束
# 开始BV号为1dV411R7Th视频属性的抓取
# BV号为1dV411R7Th的视频属性抓取结束
# 开始BV号为1YT4y137eR视频属性的抓取
# BV号为1YT4y137eR的视频属性抓取结束
# 开始BV号为1Xg4y1B7xc视频属性的抓取
# BV号为1Xg4y1B7xc的视频属性抓取结束
# 开始BV号为1Ea4y1e7fq视频属性的抓取
# BV号为1Ea4y1e7fq的视频属性抓取结束
# 开始BV号为16a4y1i72Y视频属性的抓取
# BV号为16a4y1i72Y的视频属性抓取结束
# 开始BV号为1TK4y1t7mR视频属性的抓取
# BV号为1TK4y1t7mR的视频属性抓取结束
# 开始BV号为1ot4y117iw视频属性的抓取
# BV号为1ot4y117iw的视频属性抓取结束
# 开始BV号为17A411t7tf视频属性的抓取
# BV号为17A411t7tf的视频属性抓取结束
# 开始BV号为1vp4y1Q7yp视频属性的抓取
# BV号为1vp4y1Q7yp的视频属性抓取结束
# 开始BV号为1mt4y117ib视频属性的抓取
# BV号为1mt4y117ib的视频属性抓取结束
# 开始BV号为1Vf4y127N5视频属性的抓取
# BV号为1Vf4y127N5的视频属性抓取结束
# 开始BV号为1HQ4y1P79w视频属性的抓取
# BV号为1HQ4y1P79w的视频属性抓取结束
# 开始BV号为1Xp4y1Q7uf视频属性的抓取
# BV号为1Xp4y1Q7uf的视频属性抓取结束
# 开始BV号为14C4y1W7Nv视频属性的抓取
# BV号为14C4y1W7Nv的视频属性抓取结束
# 开始BV号为1L5411s7uX视频属性的抓取
# BV号为1L5411s7uX的视频属性抓取结束
# 开始BV号为1sV411C7Tr视频属性的抓取
# BV号为1sV411C7Tr的视频属性抓取结束
# 开始BV号为1Ua4y1e7zc视频属性的抓取
# BV号为1Ua4y1e7zc的视频属性抓取结束
# 开始BV号为1N5411x73c视频属性的抓取
# BV号为1N5411x73c的视频属性抓取结束
# 开始BV号为16z4y1R7cU视频属性的抓取
# BV号为16z4y1R7cU的视频属性抓取结束
# 开始BV号为1KA411t7rx视频属性的抓取
# BV号为1KA411t7rx的视频属性抓取结束
# 开始BV号为1Rg4y1B7Ua视频属性的抓取
# BV号为1Rg4y1B7Ua的视频属性抓取结束
# 开始BV号为1o54y1Q7ZL视频属性的抓取
# BV号为1o54y1Q7ZL的视频属性抓取结束
# 开始BV号为1vg4y1B7Q9视频属性的抓取
# BV号为1vg4y1B7Q9的视频属性抓取结束
# 开始BV号为1iT4y137h6视频属性的抓取
# BV号为1iT4y137h6的视频属性抓取结束
# 开始BV号为17Z4y1s7DL视频属性的抓取
# BV号为17Z4y1s7DL的视频属性抓取结束
# 开始BV号为1X54y1Q7Rr视频属性的抓取
# BV号为1X54y1Q7Rr的视频属性抓取结束
# 开始BV号为1pV411C7w4视频属性的抓取
# BV号为1pV411C7w4的视频属性抓取结束
# 开始BV号为1ZA411i7WW视频属性的抓取
# BV号为1ZA411i7WW的视频属性抓取结束
# 开始BV号为1uK411s755视频属性的抓取
# BV号为1uK411s755的视频属性抓取结束
# 开始BV号为1B5411x7s4视频属性的抓取
# BV号为1B5411x7s4的视频属性抓取结束
# 开始BV号为1sT4y137Uw视频属性的抓取
# BV号为1sT4y137Uw的视频属性抓取结束
# 开始BV号为1TK411W72a视频属性的抓取
# BV号为1TK411W72a的视频属性抓取结束
# 开始BV号为13Q4y1N75Q视频属性的抓取
# BV号为13Q4y1N75Q的视频属性抓取结束
# 开始BV号为13a4y1i7ES视频属性的抓取
# BV号为13a4y1i7ES的视频属性抓取结束
# 开始BV号为1mZ4y1s7fB视频属性的抓取
# BV号为1mZ4y1s7fB的视频属性抓取结束
# 开始BV号为1dz411v7ao视频属性的抓取
# BV号为1dz411v7ao的视频属性抓取结束
# 开始BV号为1Ng4y167zf视频属性的抓取
# BV号为1Ng4y167zf的视频属性抓取结束
# 开始BV号为1mC4y1H7mT视频属性的抓取
# BV号为1mC4y1H7mT的视频属性抓取结束
# 开始BV号为19Q4y1N7cS视频属性的抓取
# BV号为19Q4y1N7cS的视频属性抓取结束
# 开始BV号为1TV411d7i3视频属性的抓取
# BV号为1TV411d7i3的视频属性抓取结束
# 开始BV号为1dQ4y1A75e视频属性的抓取
# BV号为1dQ4y1A75e的视频属性抓取结束
# 开始BV号为1dZ4y1p7Tk视频属性的抓取
# BV号为1dZ4y1p7Tk的视频属性抓取结束
# 开始BV号为1g64y1M7vV视频属性的抓取
# BV号为1g64y1M7vV的视频属性抓取结束
# 开始BV号为1RZ4y1s7PR视频属性的抓取
# BV号为1RZ4y1s7PR的视频属性抓取结束
# 开始BV号为1yg4y1B7eC视频属性的抓取
# BV号为1yg4y1B7eC的视频属性抓取结束
# 开始BV号为1yC4y1W7hb视频属性的抓取
# BV号为1yC4y1W7hb的视频属性抓取结束
# 开始BV号为1E5411s7cg视频属性的抓取
# BV号为1E5411s7cg的视频属性抓取结束
# 开始BV号为12V411C76m视频属性的抓取
# BV号为12V411C76m的视频属性抓取结束
# 开始BV号为1nz4y1d7uy视频属性的抓取
# BV号为1nz4y1d7uy的视频属性抓取结束
# 开始BV号为16A411t7yN视频属性的抓取
# BV号为16A411t7yN的视频属性抓取结束
# 开始BV号为1ot4y117bR视频属性的抓取
# BV号为1ot4y117bR的视频属性抓取结束
# 开始BV号为14g4y1v7Ks视频属性的抓取
# BV号为14g4y1v7Ks的视频属性抓取结束
# 开始BV号为1Lt4y197rU视频属性的抓取
# BV号为1Lt4y197rU的视频属性抓取结束
# 开始BV号为1Cf4y1y7KT视频属性的抓取
# BV号为1Cf4y1y7KT的视频属性抓取结束
# 开始BV号为1cK411W7yK视频属性的抓取
# BV号为1cK411W7yK的视频属性抓取结束
# 开始BV号为11T4y1J7Lk视频属性的抓取
# BV号为11T4y1J7Lk的视频属性抓取结束
# 开始BV号为1a54y1Q7Wc视频属性的抓取
# BV号为1a54y1Q7Wc的视频属性抓取结束
# 开始BV号为1CT4y1J7ku视频属性的抓取
# BV号为1CT4y1J7ku的视频属性抓取结束
# 开始BV号为1i5411W7fe视频属性的抓取
# BV号为1i5411W7fe的视频属性抓取结束
# 开始BV号为19C4y187NT视频属性的抓取
# BV号为19C4y187NT的视频属性抓取结束
# 开始BV号为1iC4y187XS视频属性的抓取
# BV号为1iC4y187XS的视频属性抓取结束
# 开始BV号为1jD4y1S7v1视频属性的抓取
# BV号为1jD4y1S7v1的视频属性抓取结束
# 开始BV号为125411W7QG视频属性的抓取
# BV号为125411W7QG的视频属性抓取结束
# 开始BV号为1AC4y1Y7AE视频属性的抓取
# BV号为1AC4y1Y7AE的视频属性抓取结束
# 开始BV号为1ai4y1x7Uz视频属性的抓取
# BV号为1ai4y1x7Uz的视频属性抓取结束
# 开始BV号为1EA411i7Ca视频属性的抓取
# BV号为1EA411i7Ca的视频属性抓取结束
# 开始BV号为14g4y1i7Ey视频属性的抓取
# BV号为14g4y1i7Ey的视频属性抓取结束
# 开始BV号为1Kp4y1S7n3视频属性的抓取
# BV号为1Kp4y1S7n3的视频属性抓取结束
# 开始BV号为1oA411q7As视频属性的抓取
# BV号为1oA411q7As的视频属性抓取结束
# 开始BV号为1zT4y1E7dR视频属性的抓取
# BV号为1zT4y1E7dR的视频属性抓取结束
# 开始BV号为1ip4y1U7ax视频属性的抓取
# BV号为1ip4y1U7ax的视频属性抓取结束
# 开始BV号为1qg4y1q7S1视频属性的抓取
# BV号为1qg4y1q7S1的视频属性抓取结束
# 开始BV号为1DZ4y1M7fY视频属性的抓取
# BV号为1DZ4y1M7fY的视频属性抓取结束
# 开始BV号为15A411e7eP视频属性的抓取
# BV号为15A411e7eP的视频属性抓取结束
# 开始BV号为1yi4y1s7eS视频属性的抓取
# BV号为1yi4y1s7eS的视频属性抓取结束
# 开始BV号为1bk4y1q7VN视频属性的抓取
# BV号为1bk4y1q7VN的视频属性抓取结束
# 开始BV号为1VA411B7TK视频属性的抓取
# BV号为1VA411B7TK的视频属性抓取结束
# 开始BV号为1mt4y1X7eM视频属性的抓取
# BV号为1mt4y1X7eM的视频属性抓取结束
# 开始BV号为15a4y1v785视频属性的抓取
# BV号为15a4y1v785的视频属性抓取结束
# 开始BV号为1Vv411B7p1视频属性的抓取
# BV号为1Vv411B7p1的视频属性抓取结束
# 开始BV号为1tz411i7AG视频属性的抓取
# BV号为1tz411i7AG的视频属性抓取结束
# 开始BV号为1BQ4y1P7dk视频属性的抓取
# BV号为1BQ4y1P7dk的视频属性抓取结束
# 开始BV号为1nD4y1Q7Ab视频属性的抓取
# BV号为1nD4y1Q7Ab的视频属性抓取结束
# 开始BV号为1oi4y1s7m5视频属性的抓取
# BV号为1oi4y1s7m5的视频属性抓取结束
# 开始BV号为1RZ4y1n7wv视频属性的抓取
# BV号为1RZ4y1n7wv的视频属性抓取结束
# 开始BV号为1ti4y1x7rb视频属性的抓取
# BV号为1ti4y1x7rb的视频属性抓取结束
# 开始BV号为1xt4y1y7jH视频属性的抓取
# BV号为1xt4y1y7jH的视频属性抓取结束
# 开始BV号为1hp4y1D778视频属性的抓取
# BV号为1hp4y1D778的视频属性抓取结束
# 开始BV号为1bg4y1q7es视频属性的抓取
# BV号为1bg4y1q7es的视频属性抓取结束
# 开始BV号为1AK4y1475o视频属性的抓取
# BV号为1AK4y1475o的视频属性抓取结束
# 开始BV号为1RC4y1877Z视频属性的抓取
# BV号为1RC4y1877Z的视频属性抓取结束
# 开始BV号为1kp4y1D7BA视频属性的抓取
# BV号为1kp4y1D7BA的视频属性抓取结束
# 开始BV号为1PA411B75s视频属性的抓取
# BV号为1PA411B75s的视频属性抓取结束
# 开始BV号为1eV411k7Qs视频属性的抓取
# BV号为1eV411k7Qs的视频属性抓取结束
# 开始BV号为1iz411e74z视频属性的抓取
# BV号为1iz411e74z的视频属性抓取结束
# 开始BV号为1yA411v7t9视频属性的抓取
# BV号为1yA411v7t9的视频属性抓取结束
# 开始BV号为1qD4y1D74w视频属性的抓取
# BV号为1qD4y1D74w的视频属性抓取结束
# 开始BV号为1gk4y1z7V1视频属性的抓取
# BV号为1gk4y1z7V1的视频属性抓取结束
# 开始BV号为1WZ4y1H7du视频属性的抓取
# BV号为1WZ4y1H7du的视频属性抓取结束
# 开始BV号为1Fz4y1R7ap视频属性的抓取
# BV号为1Fz4y1R7ap的视频属性抓取结束
# 开始BV号为1Qf4y127St视频属性的抓取
# BV号为1Qf4y127St的视频属性抓取结束
# 开始BV号为1xV411r739视频属性的抓取
# BV号为1xV411r739的视频属性抓取结束
# 开始BV号为1GA411i7w7视频属性的抓取
# BV号为1GA411i7w7的视频属性抓取结束
# 开始BV号为1HK4y1s77f视频属性的抓取
# BV号为1HK4y1s77f的视频属性抓取结束
# 开始BV号为12a4y1Y76k视频属性的抓取
# BV号为12a4y1Y76k的视频属性抓取结束
# 开始BV号为1PV411k7te视频属性的抓取
# BV号为1PV411k7te的视频属性抓取结束
# 开始BV号为13K4y1b7yM视频属性的抓取
# BV号为13K4y1b7yM的视频属性抓取结束
# 开始BV号为1Sz4y197UJ视频属性的抓取
# BV号为1Sz4y197UJ的视频属性抓取结束
# 开始BV号为1Ai4y1x7y5视频属性的抓取
# BV号为1Ai4y1x7y5的视频属性抓取结束
# 开始BV号为1wz411i7BX视频属性的抓取
# BV号为1wz411i7BX的视频属性抓取结束
# 开始BV号为1R54y1i761视频属性的抓取
# BV号为1R54y1i761的视频属性抓取结束
# 开始BV号为1Rz4y197JB视频属性的抓取
# BV号为1Rz4y197JB的视频属性抓取结束
# 开始BV号为1oz411e7Jk视频属性的抓取
# BV号为1oz411e7Jk的视频属性抓取结束
# 开始BV号为1LT4y1J7ib视频属性的抓取
# BV号为1LT4y1J7ib的视频属性抓取结束
# 开始BV号为1SC4y1h7Jp视频属性的抓取
# BV号为1SC4y1h7Jp的视频属性抓取结束
# 开始BV号为1RC4y1h7ps视频属性的抓取
# BV号为1RC4y1h7ps的视频属性抓取结束
# 开始BV号为1Jk4y1z7Wf视频属性的抓取
# BV号为1Jk4y1z7Wf的视频属性抓取结束
# 开始BV号为1r5411p7ob视频属性的抓取
# BV号为1r5411p7ob的视频属性抓取结束
# 开始BV号为1HK4y1t7FA视频属性的抓取
# BV号为1HK4y1t7FA的视频属性抓取结束
# 开始BV号为1Vp4y1D7uX视频属性的抓取
# BV号为1Vp4y1D7uX的视频属性抓取结束
# 开始BV号为1B5411W7B6视频属性的抓取
# BV号为1B5411W7B6的视频属性抓取结束
# 开始BV号为1d5411W7bA视频属性的抓取
# BV号为1d5411W7bA的视频属性抓取结束
# 开始BV号为1FZ4y1H7rh视频属性的抓取
# BV号为1FZ4y1H7rh的视频属性抓取结束
# 开始BV号为1i54y1B7WF视频属性的抓取
# BV号为1i54y1B7WF的视频属性抓取结束
# 开始BV号为13a4y1v7La视频属性的抓取
# BV号为13a4y1v7La的视频属性抓取结束
# 开始BV号为1QC4y1877n视频属性的抓取
# BV号为1QC4y1877n的视频属性抓取结束
# 开始BV号为1pT4y1J7rC视频属性的抓取
# BV号为1pT4y1J7rC的视频属性抓取结束
# 开始BV号为1kk4y1z7ru视频属性的抓取
# BV号为1kk4y1z7ru的视频属性抓取结束
# 开始BV号为1DT4y1J7MQ视频属性的抓取
# BV号为1DT4y1J7MQ的视频属性抓取结束
# 开始BV号为1bi4y1x7yT视频属性的抓取
# BV号为1bi4y1x7yT的视频属性抓取结束
# 开始BV号为1ia4y1Y7oq视频属性的抓取
# BV号为1ia4y1Y7oq的视频属性抓取结束
# 开始BV号为1Nk4y1z7sc视频属性的抓取
# BV号为1Nk4y1z7sc的视频属性抓取结束
# 开始BV号为1ri4y1G7iQ视频属性的抓取
# BV号为1ri4y1G7iQ的视频属性抓取结束
# 开始BV号为1YZ4y1H7Jj视频属性的抓取
# BV号为1YZ4y1H7Jj的视频属性抓取结束
# 开始BV号为19z411v7yj视频属性的抓取
# BV号为19z411v7yj的视频属性抓取结束
# 开始BV号为1Az411i7Ch视频属性的抓取
# BV号为1Az411i7Ch的视频属性抓取结束
# 开始BV号为1Xz4y1Q7u2视频属性的抓取
# BV号为1Xz4y1Q7u2的视频属性抓取结束
# 开始BV号为1uK411p7Bp视频属性的抓取
# BV号为1uK411p7Bp的视频属性抓取结束
# 开始BV号为1qz4y1Q7tC视频属性的抓取
# BV号为1qz4y1Q7tC的视频属性抓取结束
# 开始BV号为1t54y1B7Np视频属性的抓取
# BV号为1t54y1B7Np的视频属性抓取结束
# 开始BV号为1yz411i7iS视频属性的抓取
# BV号为1yz411i7iS的视频属性抓取结束
# 开始BV号为1qC4y1a7La视频属性的抓取
# BV号为1qC4y1a7La的视频属性抓取结束
# 开始BV号为19C4y1a762视频属性的抓取
# BV号为19C4y1a762的视频属性抓取结束
# 开始BV号为1tk4y1z79j视频属性的抓取
# BV号为1tk4y1z79j的视频属性抓取结束
# 开始BV号为1wz4y1X7P6视频属性的抓取
# BV号为1wz4y1X7P6的视频属性抓取结束
# 开始BV号为1LC4y1a786视频属性的抓取
# BV号为1LC4y1a786的视频属性抓取结束
# 开始BV号为1mp4y1D7UP视频属性的抓取
# BV号为1mp4y1D7UP的视频属性抓取结束
# 开始BV号为1BC4y187RM视频属性的抓取
# BV号为1BC4y187RM的视频属性抓取结束
# 开始BV号为1Dg4y1i7tL视频属性的抓取
# BV号为1Dg4y1i7tL的视频属性抓取结束
# 开始BV号为1JK411p7mn视频属性的抓取
# BV号为1JK411p7mn的视频属性抓取结束
# 开始BV号为1KV41167Bj视频属性的抓取
# BV号为1KV41167Bj的视频属性抓取结束
# 开始BV号为13v411z7sR视频属性的抓取
# BV号为13v411z7sR的视频属性抓取结束
# 开始BV号为1A54y1S7SX视频属性的抓取
# BV号为1A54y1S7SX的视频属性抓取结束
# 开始BV号为1ma4y1a7iF视频属性的抓取
# BV号为1ma4y1a7iF的视频属性抓取结束
# 开始BV号为1K54y1B7sx视频属性的抓取
# BV号为1K54y1B7sx的视频属性抓取结束
# 开始BV号为1gK4y1x7xA视频属性的抓取
# BV号为1gK4y1x7xA的视频属性抓取结束
# 开始BV号为18z4y1X7Su视频属性的抓取
# BV号为18z4y1X7Su的视频属性抓取结束
# 开始BV号为1hp4y1i7tg视频属性的抓取
# BV号为1hp4y1i7tg的视频属性抓取结束
# 开始BV号为1UZ4y1T7Go视频属性的抓取
# BV号为1UZ4y1T7Go的视频属性抓取结束
# 开始BV号为1Jt4y1D7ws视频属性的抓取
# BV号为1Jt4y1D7ws的视频属性抓取结束
# 开始BV号为1Mk4y1m7wy视频属性的抓取
# BV号为1Mk4y1m7wy的视频属性抓取结束
# 开始BV号为1Pp4y1q7AY视频属性的抓取
# BV号为1Pp4y1q7AY的视频属性抓取结束
# 开始BV号为1JK4y1v7D8视频属性的抓取
# BV号为1JK4y1v7D8的视频属性抓取结束
# 开始BV号为1bf4y1R7HY视频属性的抓取
# BV号为1bf4y1R7HY的视频属性抓取结束
# 开始BV号为1W5411a7Nd视频属性的抓取
# BV号为1W5411a7Nd的视频属性抓取结束
# 开始BV号为1ph411Z7tG视频属性的抓取
# BV号为1ph411Z7tG的视频属性抓取结束
# 开始BV号为1FZ4y1g74Y视频属性的抓取
# BV号为1FZ4y1g74Y的视频属性抓取结束
# 开始BV号为1Ka4y1e7TB视频属性的抓取
# BV号为1Ka4y1e7TB的视频属性抓取结束
# 开始BV号为15f4y1d7Y4视频属性的抓取
# BV号为15f4y1d7Y4的视频属性抓取结束
# 开始BV号为1qC4y1b75t视频属性的抓取
# BV号为1qC4y1b75t的视频属性抓取结束
# 开始BV号为1FV411r7RP视频属性的抓取
# BV号为1FV411r7RP的视频属性抓取结束
# 开始BV号为1xa4y1a7BB视频属性的抓取
# BV号为1xa4y1a7BB的视频属性抓取结束
# 开始BV号为1qK411n7gQ视频属性的抓取
# BV号为1qK411n7gQ的视频属性抓取结束
# 开始BV号为15Z4y1p76F视频属性的抓取
# BV号为15Z4y1p76F的视频属性抓取结束
# 开始BV号为1Ai4y1V7rg视频属性的抓取
# BV号为1Ai4y1V7rg的视频属性抓取结束
# 开始BV号为1na4y1a74t视频属性的抓取
# BV号为1na4y1a74t的视频属性抓取结束
# 开始BV号为17K411J7dg视频属性的抓取
# BV号为17K411J7dg的视频属性抓取结束
# 开始BV号为1wa4y1a7jA视频属性的抓取
# BV号为1wa4y1a7jA的视频属性抓取结束
# 开始BV号为1Cv411q73X视频属性的抓取
# BV号为1Cv411q73X的视频属性抓取结束
# 开始BV号为1ZK4y1s7it视频属性的抓取
# BV号为1ZK4y1s7it的视频属性抓取结束
# 开始BV号为1Za4y1h7wD视频属性的抓取
# BV号为1Za4y1h7wD的视频属性抓取结束
# 开始BV号为16v411i7Ji视频属性的抓取
# BV号为16v411i7Ji的视频属性抓取结束
# 开始BV号为1QK411J78F视频属性的抓取
# BV号为1QK411J78F的视频属性抓取结束
# 开始BV号为1Pk4y1B7j1视频属性的抓取
# BV号为1Pk4y1B7j1的视频属性抓取结束
# 开始BV号为1oV41167fL视频属性的抓取
# BV号为1oV41167fL的视频属性抓取结束
# 开始BV号为12h411o7rG视频属性的抓取
# BV号为12h411o7rG的视频属性抓取结束
# 开始BV号为1yD4y1S7ku视频属性的抓取
# BV号为1yD4y1S7ku的视频属性抓取结束
# 开始BV号为1Hz4y1Q7xC视频属性的抓取
# BV号为1Hz4y1Q7xC的视频属性抓取结束
# 开始BV号为1xh411Z7TS视频属性的抓取
# BV号为1xh411Z7TS的视频属性抓取结束
# 开始BV号为1ZA411e7Ff视频属性的抓取
# BV号为1ZA411e7Ff的视频属性抓取结束
# 开始BV号为1fA411a7P7视频属性的抓取
# BV号为1fA411a7P7的视频属性抓取结束
# 开始BV号为1uz4y1Q7vU视频属性的抓取
# BV号为1uz4y1Q7vU的视频属性抓取结束
# 开始BV号为1tV411677o视频属性的抓取
# BV号为1tV411677o的视频属性抓取结束
# 开始BV号为1f54y1U7ym视频属性的抓取
# BV号为1f54y1U7ym的视频属性抓取结束
# 开始BV号为1sT4y1j7G2视频属性的抓取
# BV号为1sT4y1j7G2的视频属性抓取结束
# 开始BV号为1xK411H7GB视频属性的抓取
# BV号为1xK411H7GB的视频属性抓取结束
# 开始BV号为1mh411o7WR视频属性的抓取
# BV号为1mh411o7WR的视频属性抓取结束
# 开始BV号为1WA411Y7nk视频属性的抓取
# BV号为1WA411Y7nk的视频属性抓取结束
# 开始BV号为1ri4y137Kn视频属性的抓取
# BV号为1ri4y137Kn的视频属性抓取结束
# 开始BV号为1KT4y1E7tV视频属性的抓取
# BV号为1KT4y1E7tV的视频属性抓取结束
# 开始BV号为1dC4y187i8视频属性的抓取
# BV号为1dC4y187i8的视频属性抓取结束
# 开始BV号为1Vf4y1d7N5视频属性的抓取
# BV号为1Vf4y1d7N5的视频属性抓取结束
# 开始BV号为1U5411Y7YL视频属性的抓取
# BV号为1U5411Y7YL的视频属性抓取结束
# 开始BV号为17V411r7dw视频属性的抓取
# BV号为17V411r7dw的视频属性抓取结束
# 开始BV号为1Yp4y1S78v视频属性的抓取
# BV号为1Yp4y1S78v的视频属性抓取结束
# 开始BV号为19D4y1S7Bh视频属性的抓取
# BV号为19D4y1S7Bh的视频属性抓取结束
# 开始BV号为1TC4y1b7R7视频属性的抓取
# BV号为1TC4y1b7R7的视频属性抓取结束
# 开始BV号为18t4y197o2视频属性的抓取
# BV号为18t4y197o2的视频属性抓取结束
# 开始BV号为1vT4y1E7eZ视频属性的抓取
# BV号为1vT4y1E7eZ的视频属性抓取结束
# 开始BV号为1Fh411Z7n4视频属性的抓取
# BV号为1Fh411Z7n4的视频属性抓取结束
# 开始BV号为1kf4y1R7h3视频属性的抓取
# BV号为1kf4y1R7h3的视频属性抓取结束
# 开始BV号为1Pz4y1X7H7视频属性的抓取
# BV号为1Pz4y1X7H7的视频属性抓取结束
# 开始BV号为1JV41167Fg视频属性的抓取
# BV号为1JV41167Fg的视频属性抓取结束
# 开始BV号为1VT4y1j7FV视频属性的抓取
# BV号为1VT4y1j7FV的视频属性抓取结束
# 开始BV号为1Xk4y127Zu视频属性的抓取
# BV号为1Xk4y127Zu的视频属性抓取结束
# 开始BV号为1Hz411v7ZW视频属性的抓取
# BV号为1Hz411v7ZW的视频属性抓取结束
# 开始BV号为1ei4y1V7jM视频属性的抓取
# BV号为1ei4y1V7jM的视频属性抓取结束
# 开始BV号为1hK4y1x7y9视频属性的抓取
# BV号为1hK4y1x7y9的视频属性抓取结束
# 开始BV号为1Yt4y1X7t6视频属性的抓取
# BV号为1Yt4y1X7t6的视频属性抓取结束
# 开始BV号为1Lt4y197p4视频属性的抓取
# BV号为1Lt4y197p4的视频属性抓取结束
# 开始BV号为13K411J7TQ视频属性的抓取
# BV号为13K411J7TQ的视频属性抓取结束
# 开始BV号为1Xf4y1X7VJ视频属性的抓取
# BV号为1Xf4y1X7VJ的视频属性抓取结束
# 开始BV号为1Xh411o7Qe视频属性的抓取
# BV号为1Xh411o7Qe的视频属性抓取结束
# 开始BV号为1Bz4y1D7Hq视频属性的抓取
# BV号为1Bz4y1D7Hq的视频属性抓取结束
# 开始BV号为15g4y1i7WN视频属性的抓取
# BV号为15g4y1i7WN的视频属性抓取结束
# 开始BV号为1XK4y147HQ视频属性的抓取
# BV号为1XK4y147HQ的视频属性抓取结束
# 开始BV号为1vk4y1B7PE视频属性的抓取
# BV号为1vk4y1B7PE的视频属性抓取结束
# 开始BV号为1aT4y177WM视频属性的抓取
# BV号为1aT4y177WM的视频属性抓取结束
# 开始BV号为12t4y1Q7xr视频属性的抓取
# BV号为12t4y1Q7xr的视频属性抓取结束
# 开始BV号为1LD4y1D7RS视频属性的抓取
# BV号为1LD4y1D7RS的视频属性抓取结束
# 开始BV号为1qk4y1B7XG视频属性的抓取
# BV号为1qk4y1B7XG的视频属性抓取结束
# 开始BV号为1LC4y1h7S2视频属性的抓取
# BV号为1LC4y1h7S2的视频属性抓取结束
# 开始BV号为1HC4y1b7cu视频属性的抓取
# BV号为1HC4y1b7cu的视频属性抓取结束
# 开始BV号为1WC4y1h7k4视频属性的抓取
# BV号为1WC4y1h7k4的视频属性抓取结束
# 开始BV号为1f54y1S7n1视频属性的抓取
# BV号为1f54y1S7n1的视频属性抓取结束
# 开始BV号为1At4y1X7mU视频属性的抓取
# BV号为1At4y1X7mU的视频属性抓取结束
# 开始BV号为1Vz4y1Q7rG视频属性的抓取
# BV号为1Vz4y1Q7rG的视频属性抓取结束
# 开始BV号为1e5411a7xd视频属性的抓取
# BV号为1e5411a7xd的视频属性抓取结束
# 开始BV号为1pz4y1D73n视频属性的抓取
# BV号为1pz4y1D73n的视频属性抓取结束
# 开始BV号为1Jk4y1B7jE视频属性的抓取
# BV号为1Jk4y1B7jE的视频属性抓取结束
# 开始BV号为1Tt4y1D7Ez视频属性的抓取
# BV号为1Tt4y1D7Ez的视频属性抓取结束
# 开始BV号为1GD4y1D7Ba视频属性的抓取
# BV号为1GD4y1D7Ba的视频属性抓取结束
# 开始BV号为17a4y1J7Gm视频属性的抓取
# BV号为17a4y1J7Gm的视频属性抓取结束
# 开始BV号为1CA411e7Np视频属性的抓取
# BV号为1CA411e7Np的视频属性抓取结束
# 开始BV号为1vk4y1B719视频属性的抓取
# BV号为1vk4y1B719的视频属性抓取结束
# 开始BV号为1q64y1F7rj视频属性的抓取
# BV号为1q64y1F7rj的视频属性抓取结束
# 开始BV号为1nT4y1E7Hz视频属性的抓取
# BV号为1nT4y1E7Hz的视频属性抓取结束
# 开始BV号为1xh411Z79d视频属性的抓取
# BV号为1xh411Z79d的视频属性抓取结束
# 开始BV号为1Si4y137Pg视频属性的抓取
# BV号为1Si4y137Pg的视频属性抓取结束
# 开始BV号为1Tg4y1i7rq视频属性的抓取
# BV号为1Tg4y1i7rq的视频属性抓取结束
# 开始BV号为1sD4y1S7s4视频属性的抓取
# BV号为1sD4y1S7s4的视频属性抓取结束
# 开始BV号为1C54y1e71b视频属性的抓取
# BV号为1C54y1e71b的视频属性抓取结束
# 开始BV号为1554y1i7Ww视频属性的抓取
# BV号为1554y1i7Ww的视频属性抓取结束
# 开始BV号为1i54y1m7hA视频属性的抓取
# BV号为1i54y1m7hA的视频属性抓取结束
# 开始BV号为1aT4y1w7yL视频属性的抓取
# BV号为1aT4y1w7yL的视频属性抓取结束
# 开始BV号为1Uv411y75i视频属性的抓取
# BV号为1Uv411y75i的视频属性抓取结束
# 开始BV号为1qC4y1b7Rj视频属性的抓取
# BV号为1qC4y1b7Rj的视频属性抓取结束
# 开始BV号为1DC4y147qX视频属性的抓取
# BV号为1DC4y147qX的视频属性抓取结束
# 开始BV号为1P54y1D7Zf视频属性的抓取
# BV号为1P54y1D7Zf的视频属性抓取结束
# 开始BV号为1Vk4y127w8视频属性的抓取
# BV号为1Vk4y127w8的视频属性抓取结束
# 开始BV号为1Ci4y1u7cp视频属性的抓取
# BV号为1Ci4y1u7cp的视频属性抓取结束
# 开始BV号为1up4y1e7tb视频属性的抓取
# BV号为1up4y1e7tb的视频属性抓取结束
# 开始BV号为1WC4y187f5视频属性的抓取
# BV号为1WC4y187f5的视频属性抓取结束
# 开始BV号为1ra4y1J7AR视频属性的抓取
# BV号为1ra4y1J7AR的视频属性抓取结束
# 开始BV号为1q54y1S7UY视频属性的抓取
# BV号为1q54y1S7UY的视频属性抓取结束
# 开始BV号为12K4y1v7Gk视频属性的抓取
# BV号为12K4y1v7Gk的视频属性抓取结束
# 开始BV号为1264y1c71r视频属性的抓取
# BV号为1264y1c71r的视频属性抓取结束
# 开始BV号为1KA411Y7hu视频属性的抓取
# BV号为1KA411Y7hu的视频属性抓取结束
# 开始BV号为1vi4y1M7z3视频属性的抓取
# BV号为1vi4y1M7z3的视频属性抓取结束
# 开始BV号为1Ga4y177ag视频属性的抓取
# BV号为1Ga4y177ag的视频属性抓取结束
# 开始BV号为1mf4y197u2视频属性的抓取
# BV号为1mf4y197u2的视频属性抓取结束
# 开始BV号为14h411d7S3视频属性的抓取
# BV号为14h411d7S3的视频属性抓取结束
# 开始BV号为19A411Y7uZ视频属性的抓取
# BV号为19A411Y7uZ的视频属性抓取结束
# 开始BV号为1u64y1c7h8视频属性的抓取
# BV号为1u64y1c7h8的视频属性抓取结束
# 开始BV号为1qD4y1U79v视频属性的抓取
# BV号为1qD4y1U79v的视频属性抓取结束
# 开始BV号为11T4y157Dq视频属性的抓取
# BV号为11T4y157Dq的视频属性抓取结束
# 开始BV号为1dV411z7Pr视频属性的抓取
# BV号为1dV411z7Pr的视频属性抓取结束
# 开始BV号为1sz4y1f75K视频属性的抓取
# BV号为1sz4y1f75K的视频属性抓取结束
# 开始BV号为1XD4y1m7sC视频属性的抓取
# BV号为1XD4y1m7sC的视频属性抓取结束
# 开始BV号为1St4y1D79G视频属性的抓取
# BV号为1St4y1D79G的视频属性抓取结束
# 开始BV号为1Xt4y1D7KQ视频属性的抓取
# BV号为1Xt4y1D7KQ的视频属性抓取结束
# 开始BV号为15K411M7vM视频属性的抓取
# BV号为15K411M7vM的视频属性抓取结束
# 开始BV号为1gA411e7ZW视频属性的抓取
# BV号为1gA411e7ZW的视频属性抓取结束
# 开始BV号为1Cp4y1Y7FS视频属性的抓取
# BV号为1Cp4y1Y7FS的视频属性抓取结束
# 开始BV号为1zV411z7X2视频属性的抓取
# BV号为1zV411z7X2的视频属性抓取结束
# 开始BV号为1Ek4y1m7rg视频属性的抓取
# BV号为1Ek4y1m7rg的视频属性抓取结束
# 开始BV号为1Ez4y1f76v视频属性的抓取
# BV号为1Ez4y1f76v的视频属性抓取结束
# 开始BV号为1kp4y1v7yt视频属性的抓取
# BV号为1kp4y1v7yt的视频属性抓取结束
# 开始BV号为1X64y1F7HJ视频属性的抓取
# BV号为1X64y1F7HJ的视频属性抓取结束
# 开始BV号为1oD4y1U7b1视频属性的抓取
# BV号为1oD4y1U7b1的视频属性抓取结束
# 开始BV号为15h411R74P视频属性的抓取
# BV号为15h411R74P的视频属性抓取结束
# 开始BV号为1q54y1e7hc视频属性的抓取
# BV号为1q54y1e7hc的视频属性抓取结束
# 开始BV号为1ya4y1E7Td视频属性的抓取
# BV号为1ya4y1E7Td的视频属性抓取结束
# 开始BV号为12C4y147Uv视频属性的抓取
# BV号为12C4y147Uv的视频属性抓取结束
# 开始BV号为1sh411d7uT视频属性的抓取
# BV号为1sh411d7uT的视频属性抓取结束
# 开始BV号为1Xi4y1u7MK视频属性的抓取
# BV号为1Xi4y1u7MK的视频属性抓取结束
# 开始BV号为1Ak4y1U7ej视频属性的抓取
# BV号为1Ak4y1U7ej的视频属性抓取结束
# 开始BV号为1jK411n7md视频属性的抓取
# BV号为1jK411n7md的视频属性抓取结束
# 开始BV号为1C64y1F7pr视频属性的抓取
# BV号为1C64y1F7pr的视频属性抓取结束
# 开始BV号为13h411R7yq视频属性的抓取
# BV号为13h411R7yq的视频属性抓取结束
# 开始BV号为1gD4y1m7k5视频属性的抓取
# BV号为1gD4y1m7k5的视频属性抓取结束
# 开始BV号为1FK4y1e7DV视频属性的抓取
# BV号为1FK4y1e7DV的视频属性抓取结束
# 开始BV号为1a54y1v7hx视频属性的抓取
# BV号为1a54y1v7hx的视频属性抓取结束
# 开始BV号为15h411R7cP视频属性的抓取
# BV号为15h411R7cP的视频属性抓取结束
# 开始BV号为1Gk4y1m7Z9视频属性的抓取
# BV号为1Gk4y1m7Z9的视频属性抓取结束
# 开始BV号为1AK411T72Y视频属性的抓取
# BV号为1AK411T72Y的视频属性抓取结束
# 开始BV号为1XA411a7qv视频属性的抓取
# BV号为1XA411a7qv的视频属性抓取结束
# 开始BV号为1DT4y1j7rk视频属性的抓取
# BV号为1DT4y1j7rk的视频属性抓取结束
# 开始BV号为1Bh41197Tr视频属性的抓取
# BV号为1Bh41197Tr的视频属性抓取结束
# 开始BV号为1o54y1m7Zt视频属性的抓取
# BV号为1o54y1m7Zt的视频属性抓取结束
# 开始BV号为1E64y1c7kr视频属性的抓取
# BV号为1E64y1c7kr的视频属性抓取结束
# 开始BV号为1Tt4y1Q712视频属性的抓取
# BV号为1Tt4y1Q712的视频属性抓取结束
# 开始BV号为1gi4y1G7zv视频属性的抓取
# BV号为1gi4y1G7zv的视频属性抓取结束
# 开始BV号为1JA411Y7oZ视频属性的抓取
# BV号为1JA411Y7oZ的视频属性抓取结束
# 开始BV号为135411b7Hv视频属性的抓取
# BV号为135411b7Hv的视频属性抓取结束
# 开始BV号为1jK411M7W2视频属性的抓取
# BV号为1jK411M7W2的视频属性抓取结束
# 开始BV号为1tV411z7z5视频属性的抓取
# BV号为1tV411z7z5的视频属性抓取结束
# 开始BV号为1Mk4y1U7q4视频属性的抓取
# BV号为1Mk4y1U7q4的视频属性抓取结束
# 开始BV号为15K4y1v7nS视频属性的抓取
# BV号为15K4y1v7nS的视频属性抓取结束
# 开始BV号为1ot4y1D7j7视频属性的抓取
# BV号为1ot4y1D7j7的视频属性抓取结束
# 开始BV号为1iD4y1U7gd视频属性的抓取
# BV号为1iD4y1U7gd的视频属性抓取结束
# 开始BV号为1Np4y1e78d视频属性的抓取
# BV号为1Np4y1e78d的视频属性抓取结束
# 开始BV号为1Kk4y1U7a6视频属性的抓取
# BV号为1Kk4y1U7a6的视频属性抓取结束
# 开始BV号为1mA411Y72x视频属性的抓取
# BV号为1mA411Y72x的视频属性抓取结束
# 开始BV号为1S5411a7sM视频属性的抓取
# BV号为1S5411a7sM的视频属性抓取结束
# 开始BV号为1nh411d7iK视频属性的抓取
# BV号为1nh411d7iK的视频属性抓取结束
# 开始BV号为1k5411h75R视频属性的抓取
# BV号为1k5411h75R的视频属性抓取结束
# 开始BV号为1ak4y1m7PS视频属性的抓取
# BV号为1ak4y1m7PS的视频属性抓取结束
# 开始BV号为1M54y1i7Lq视频属性的抓取
# BV号为1M54y1i7Lq的视频属性抓取结束
# 开始BV号为1MT4y1778w视频属性的抓取
# BV号为1MT4y1778w的视频属性抓取结束
# 开始BV号为1Yk4y127Dj视频属性的抓取
# BV号为1Yk4y127Dj的视频属性抓取结束
# 开始BV号为11Z4y1M7BA视频属性的抓取
# BV号为11Z4y1M7BA的视频属性抓取结束
# 开始BV号为17K411K7Ty视频属性的抓取
# BV号为17K411K7Ty的视频属性抓取结束
# 开始BV号为1ra4y177TP视频属性的抓取
# BV号为1ra4y177TP的视频属性抓取结束
# 开始BV号为1NK4y1e7Xo视频属性的抓取
# BV号为1NK4y1e7Xo的视频属性抓取结束
# 开始BV号为1ff4y1X7va视频属性的抓取
# BV号为1ff4y1X7va的视频属性抓取结束
# 开始BV号为11v411y7Vs视频属性的抓取
# BV号为11v411y7Vs的视频属性抓取结束
# 开始BV号为1Ct4y1U7MK视频属性的抓取
# BV号为1Ct4y1U7MK的视频属性抓取结束
# 开始BV号为1PK4y1v7Xg视频属性的抓取
# BV号为1PK4y1v7Xg的视频属性抓取结束
# 开始BV号为1xp4y1q7S1视频属性的抓取
# BV号为1xp4y1q7S1的视频属性抓取结束
# 开始BV号为1KA411e7pZ视频属性的抓取
# BV号为1KA411e7pZ的视频属性抓取结束
# 开始BV号为14K4y1v7qu视频属性的抓取
# BV号为14K4y1v7qu的视频属性抓取结束
# 开始BV号为1Qf4y1X7Yy视频属性的抓取
# BV号为1Qf4y1X7Yy的视频属性抓取结束
# 开始BV号为1dV411z7Yd视频属性的抓取
# BV号为1dV411z7Yd的视频属性抓取结束
# 开始BV号为1k64y1c7Du视频属性的抓取
# BV号为1k64y1c7Du的视频属性抓取结束
# 开始BV号为1w54y1U7jc视频属性的抓取
# BV号为1w54y1U7jc的视频属性抓取结束
# 开始BV号为1g54y1i7AH视频属性的抓取
# BV号为1g54y1i7AH的视频属性抓取结束
# 开始BV号为1354y1e7dq视频属性的抓取
# BV号为1354y1e7dq的视频属性抓取结束
# 开始BV号为1nT4y1L7GP视频属性的抓取
# BV号为1nT4y1L7GP的视频属性抓取结束
# 开始BV号为1SV411z7Ly视频属性的抓取
# BV号为1SV411z7Ly的视频属性抓取结束
# 开始BV号为1454y127rW视频属性的抓取
# BV号为1454y127rW的视频属性抓取结束
# 开始BV号为1ez4y1Z78d视频属性的抓取
# BV号为1ez4y1Z78d的视频属性抓取结束
# 开始BV号为1wD4y1o7AS视频属性的抓取
# BV号为1wD4y1o7AS的视频属性抓取结束
# 开始BV号为1w54y1v7pQ视频属性的抓取
# BV号为1w54y1v7pQ的视频属性抓取结束
# 开始BV号为1WD4y1m7nF视频属性的抓取
# BV号为1WD4y1m7nF的视频属性抓取结束
# 开始BV号为1rp4y1e745视频属性的抓取
# BV号为1rp4y1e745的视频属性抓取结束
# 开始BV号为1TA41177nU视频属性的抓取
# BV号为1TA41177nU的视频属性抓取结束
# 开始BV号为1o54y1C7JR视频属性的抓取
# BV号为1o54y1C7JR的视频属性抓取结束
# 开始BV号为1gk4y1y7Go视频属性的抓取
# BV号为1gk4y1y7Go的视频属性抓取结束
# 开始BV号为1wv411y7L6视频属性的抓取
# BV号为1wv411y7L6的视频属性抓取结束
# 开始BV号为1Hk4y1y7RH视频属性的抓取
# BV号为1Hk4y1y7RH的视频属性抓取结束
# 开始BV号为17t4y1S7iw视频属性的抓取
# BV号为17t4y1S7iw的视频属性抓取结束
# 开始BV号为1Hh411X7VV视频属性的抓取
# BV号为1Hh411X7VV的视频属性抓取结束
# 开始BV号为1ak4y127BQ视频属性的抓取
# BV号为1ak4y127BQ的视频属性抓取结束
# 开始BV号为1UK411K7N6视频属性的抓取
# BV号为1UK411K7N6的视频属性抓取结束
# 开始BV号为1kK411P7hd视频属性的抓取
# BV号为1kK411P7hd的视频属性抓取结束
# 开始BV号为1Az4y1Z7x8视频属性的抓取
# BV号为1Az4y1Z7x8的视频属性抓取结束
# 开始BV号为1ti4y1u7YF视频属性的抓取
# BV号为1ti4y1u7YF的视频属性抓取结束
# 开始BV号为1Q54y1C7MJ视频属性的抓取
# BV号为1Q54y1C7MJ的视频属性抓取结束
# 开始BV号为16z4y1Z7rT视频属性的抓取
# BV号为16z4y1Z7rT的视频属性抓取结束
# 开始BV号为1p54y1v7hn视频属性的抓取
# BV号为1p54y1v7hn的视频属性抓取结束
# 开始BV号为1na4y1E768视频属性的抓取
# BV号为1na4y1E768的视频属性抓取结束
# 开始BV号为1tp4y1e7ur视频属性的抓取
# BV号为1tp4y1e7ur的视频属性抓取结束
# 开始BV号为1of4y1S7A6视频属性的抓取
# BV号为1of4y1S7A6的视频属性抓取结束
# 开始BV号为19k4y1y7ZE视频属性的抓取
# BV号为19k4y1y7ZE的视频属性抓取结束
# 开始BV号为1BT4y1A7ZW视频属性的抓取
# BV号为1BT4y1A7ZW的视频属性抓取结束
# 开始BV号为1Dt4y1i7dy视频属性的抓取
# BV号为1Dt4y1i7dy的视频属性抓取结束
# 开始BV号为1zf4y1D7q2视频属性的抓取
# BV号为1zf4y1D7q2的视频属性抓取结束
# 开始BV号为1NV411m7kJ视频属性的抓取
# BV号为1NV411m7kJ的视频属性抓取结束
# 开始BV号为1r5411b79t视频属性的抓取
# BV号为1r5411b79t的视频属性抓取结束
# 开始BV号为1zh411X7Tx视频属性的抓取
# BV号为1zh411X7Tx的视频属性抓取结束
# 开始BV号为1bh411R7Ud视频属性的抓取
# BV号为1bh411R7Ud的视频属性抓取结束
# 开始BV号为1jh411R7ee视频属性的抓取
# BV号为1jh411R7ee的视频属性抓取结束
# 开始BV号为1Rv411173T视频属性的抓取
# BV号为1Rv411173T的视频属性抓取结束
# 开始BV号为1Na4y1E795视频属性的抓取
# BV号为1Na4y1E795的视频属性抓取结束
# 开始BV号为1xK411K7w7视频属性的抓取
# BV号为1xK411K7w7的视频属性抓取结束
# 开始BV号为1sf4y1X7AD视频属性的抓取
# BV号为1sf4y1X7AD的视频属性抓取结束
# 开始BV号为1mt4y1i7ZX视频属性的抓取
# BV号为1mt4y1i7ZX的视频属性抓取结束
# 开始BV号为13y4y1y71F视频属性的抓取
# BV号为13y4y1y71F的视频属性抓取结束
# 开始BV号为1kK411N745视频属性的抓取
# BV号为1kK411N745的视频属性抓取结束
# 开始BV号为1av411C7ci视频属性的抓取
# BV号为1av411C7ci的视频属性抓取结束
# 开始BV号为1ok4y1y7iU视频属性的抓取
# BV号为1ok4y1y7iU的视频属性抓取结束
# 开始BV号为1R5411b7CS视频属性的抓取
# BV号为1R5411b7CS的视频属性抓取结束
# 开始BV号为1LA411J7HH视频属性的抓取
# BV号为1LA411J7HH的视频属性抓取结束
# 开始BV号为1Ja4y1E7Ku视频属性的抓取
# BV号为1Ja4y1E7Ku的视频属性抓取结束
# 开始BV号为1Lp4y1e7Av视频属性的抓取
# BV号为1Lp4y1e7Av的视频属性抓取结束
# 开始BV号为1Wa4y1j7z3视频属性的抓取
# BV号为1Wa4y1j7z3的视频属性抓取结束
# 开始BV号为1kV411m7rk视频属性的抓取
# BV号为1kV411m7rk的视频属性抓取结束
# 开始BV号为18k4y1y731视频属性的抓取
# BV号为18k4y1y731的视频属性抓取结束
# 开始BV号为11V41127pq视频属性的抓取
# BV号为11V41127pq的视频属性抓取结束
# 开始BV号为1Dh411X7vd视频属性的抓取
# BV号为1Dh411X7vd的视频属性抓取结束
# 开始BV号为1uh411R7vY视频属性的抓取
# BV号为1uh411R7vY的视频属性抓取结束
# 开始BV号为1HA411J7W8视频属性的抓取
# BV号为1HA411J7W8的视频属性抓取结束
# 开始BV号为14T4y1A7nW视频属性的抓取
# BV号为14T4y1A7nW的视频属性抓取结束
# 开始BV号为1W54y127Gv视频属性的抓取
# BV号为1W54y127Gv的视频属性抓取结束
# 开始BV号为11K4y1a7HS视频属性的抓取
# BV号为11K4y1a7HS的视频属性抓取结束
# 开始BV号为1Vk4y1y7Wk视频属性的抓取
# BV号为1Vk4y1y7Wk的视频属性抓取结束
# 开始BV号为1my4y1y75R视频属性的抓取
# BV号为1my4y1y75R的视频属性抓取结束
# 开始BV号为1iZ4y1N7Sc视频属性的抓取
# BV号为1iZ4y1N7Sc的视频属性抓取结束
# 开始BV号为1sp4y1a7HL视频属性的抓取
# BV号为1sp4y1a7HL的视频属性抓取结束
# 开始BV号为1t54y127LJ视频属性的抓取
# BV号为1t54y127LJ的视频属性抓取结束
# 开始BV号为1tZ4y1T7Pr视频属性的抓取
# BV号为1tZ4y1T7Pr的视频属性抓取结束
# 开始BV号为13A411J7gz视频属性的抓取
# BV号为13A411J7gz的视频属性抓取结束
# 开始BV号为1wa4y1j7WZ视频属性的抓取
# BV号为1wa4y1j7WZ的视频属性抓取结束
# 开始BV号为1mv411179B视频属性的抓取
# BV号为1mv411179B的视频属性抓取结束
# 开始BV号为1D5411j7D1视频属性的抓取
# BV号为1D5411j7D1的视频属性抓取结束
# 开始BV号为1Sy4y1C7ha视频属性的抓取
# BV号为1Sy4y1C7ha的视频属性抓取结束
# 开始BV号为1bZ4y1N7aJ视频属性的抓取
# BV号为1bZ4y1N7aJ的视频属性抓取结束
# 开始BV号为1et4y1S72z视频属性的抓取
# BV号为1et4y1S72z的视频属性抓取结束
# 开始BV号为1WK4y1a7Hq视频属性的抓取
# BV号为1WK4y1a7Hq的视频属性抓取结束
# 开始BV号为1ZT4y1w7FT视频属性的抓取
# BV号为1ZT4y1w7FT的视频属性抓取结束
# 开始BV号为1J54y117Jy视频属性的抓取
# BV号为1J54y117Jy的视频属性抓取结束
# 开始BV号为1PT4y1A7DR视频属性的抓取
# BV号为1PT4y1A7DR的视频属性抓取结束
# 开始BV号为1sT4y1c7KE视频属性的抓取
# BV号为1sT4y1c7KE的视频属性抓取结束
# 开始BV号为1iv411C76b视频属性的抓取
# BV号为1iv411C76b的视频属性抓取结束
# 开始BV号为1kz4y1d7B6视频属性的抓取
# BV号为1kz4y1d7B6的视频属性抓取结束
# 开始BV号为1wD4y1o7ES视频属性的抓取
# BV号为1wD4y1o7ES的视频属性抓取结束
# 开始BV号为1Yf4y1D7XS视频属性的抓取
# BV号为1Yf4y1D7XS的视频属性抓取结束
# 开始BV号为1ZZ4y1P7Cq视频属性的抓取
# BV号为1ZZ4y1P7Cq的视频属性抓取结束
# 开始BV号为1CD4y1o7LT视频属性的抓取
# BV号为1CD4y1o7LT的视频属性抓取结束
# 开始BV号为1VV411S79g视频属性的抓取
# BV号为1VV411S79g的视频属性抓取结束
# 开始BV号为1ik4y1y7M8视频属性的抓取
# BV号为1ik4y1y7M8的视频属性抓取结束
# 开始BV号为1jh411R7WY视频属性的抓取
# BV号为1jh411R7WY的视频属性抓取结束
# 开始BV号为14a4y1j7Dg视频属性的抓取
# BV号为14a4y1j7Dg的视频属性抓取结束
# 开始BV号为1Np4y1e7Vh视频属性的抓取
# BV号为1Np4y1e7Vh的视频属性抓取结束
# 开始BV号为11f4y1D7mC视频属性的抓取
# BV号为11f4y1D7mC的视频属性抓取结束
# 开始BV号为1eD4y1o7QC视频属性的抓取
# BV号为1eD4y1o7QC的视频属性抓取结束
# 开始BV号为1Y54y1y7Mz视频属性的抓取
# BV号为1Y54y1y7Mz的视频属性抓取结束
# 开始BV号为19z4y1o7e6视频属性的抓取
# BV号为19z4y1o7e6的视频属性抓取结束
# 开始BV号为1Vf4y1D73Z视频属性的抓取
# BV号为1Vf4y1D73Z的视频属性抓取结束
# 开始BV号为1Ui4y1M79W视频属性的抓取
# BV号为1Ui4y1M79W的视频属性抓取结束
# 开始BV号为1fK411K7wv视频属性的抓取
# BV号为1fK411K7wv的视频属性抓取结束
# 开始BV号为14K4y1e7Dy视频属性的抓取
# BV号为14K4y1e7Dy的视频属性抓取结束
# 开始BV号为1Vh41197di视频属性的抓取
# BV号为1Vh41197di的视频属性抓取结束
# 开始BV号为1hv411179b视频属性的抓取
# BV号为1hv411179b的视频属性抓取结束
# 开始BV号为11A411E7sK视频属性的抓取
# BV号为11A411E7sK的视频属性抓取结束
# 开始BV号为1PC4y1b7PW视频属性的抓取
# BV号为1PC4y1b7PW的视频属性抓取结束
# 开始BV号为1Sz4y1Z7K3视频属性的抓取
# BV号为1Sz4y1Z7K3的视频属性抓取结束
# 开始BV号为1a5411b7XN视频属性的抓取
# BV号为1a5411b7XN的视频属性抓取结束
# 开始BV号为1Qi4y1M7Ka视频属性的抓取
# BV号为1Qi4y1M7Ka的视频属性抓取结束
# 开始BV号为1UD4y1o7WT视频属性的抓取
# BV号为1UD4y1o7WT的视频属性抓取结束
# 开始BV号为1eD4y1R7bk视频属性的抓取
# BV号为1eD4y1R7bk的视频属性抓取结束
# 开始BV号为1Ya4y157c2视频属性的抓取
# BV号为1Ya4y157c2的视频属性抓取结束
# 开始BV号为15D4y197SA视频属性的抓取
# BV号为15D4y197SA的视频属性抓取结束
# 开始BV号为1ca4y1L7oC视频属性的抓取
# BV号为1ca4y1L7oC的视频属性抓取结束
# 开始BV号为1Xa411w7HU视频属性的抓取
# BV号为1Xa411w7HU的视频属性抓取结束
# 开始BV号为1Ny4y1C7tz视频属性的抓取
# BV号为1Ny4y1C7tz的视频属性抓取结束
# 开始BV号为1jA411E7Qr视频属性的抓取
# BV号为1jA411E7Qr的视频属性抓取结束
# 开始BV号为1Ha411A7Nx视频属性的抓取
# BV号为1Ha411A7Nx的视频属性抓取结束
# 开始BV号为1yv41167qZ视频属性的抓取
# BV号为1yv41167qZ的视频属性抓取结束
# 开始BV号为1YD4y197MN视频属性的抓取
# BV号为1YD4y197MN的视频属性抓取结束
# 开始BV号为1Zf4y1D7Tr视频属性的抓取
# BV号为1Zf4y1D7Tr的视频属性抓取结束
# 开始BV号为1pi4y177ZU视频属性的抓取
# BV号为1pi4y177ZU的视频属性抓取结束
# 开始BV号为1n5411L786视频属性的抓取
# BV号为1n5411L786的视频属性抓取结束
# 开始BV号为1pi4y177gP视频属性的抓取
# BV号为1pi4y177gP的视频属性抓取结束
# 开始BV号为1sp4y1Y7uZ视频属性的抓取
# BV号为1sp4y1Y7uZ的视频属性抓取结束
# 开始BV号为1F54y127RD视频属性的抓取
# BV号为1F54y127RD的视频属性抓取结束
# 开始BV号为1CK4y1h7FE视频属性的抓取
# BV号为1CK4y1h7FE的视频属性抓取结束
# 开始BV号为1Sa411w7ho视频属性的抓取
# BV号为1Sa411w7ho的视频属性抓取结束
# 开始BV号为1ZA41177de视频属性的抓取
# BV号为1ZA41177de的视频属性抓取结束
# 开始BV号为1da4y1W78J视频属性的抓取
# BV号为1da4y1W78J的视频属性抓取结束
# 开始BV号为1Gf4y1B7my视频属性的抓取
# BV号为1Gf4y1B7my的视频属性抓取结束
# 开始BV号为1gy4y1C7CL视频属性的抓取
# BV号为1gy4y1C7CL的视频属性抓取结束
# 开始BV号为1aa4y157Lu视频属性的抓取
# BV号为1aa4y157Lu的视频属性抓取结束
# 开始BV号为1Kf4y1z7RP视频属性的抓取
# BV号为1Kf4y1z7RP的视频属性抓取结束
# 开始BV号为1pr4y1w7uM视频属性的抓取
# BV号为1pr4y1w7uM的视频属性抓取结束
# 开始BV号为1dT4y1c76b视频属性的抓取
# BV号为1dT4y1c76b的视频属性抓取结束
# 开始BV号为16z4y1o7Ku视频属性的抓取
# BV号为16z4y1o7Ku的视频属性抓取结束
# 开始BV号为1Ay4y1r7he视频属性的抓取
# BV号为1Ay4y1r7he的视频属性抓取结束
# 开始BV号为1zD4y197Qi视频属性的抓取
# BV号为1zD4y197Qi的视频属性抓取结束
# 开始BV号为13i4y177vS视频属性的抓取
# BV号为13i4y177vS的视频属性抓取结束
# 开始BV号为1ja4y1L7mm视频属性的抓取
# BV号为1ja4y1L7mm的视频属性抓取结束
# 开始BV号为1WV41127vq视频属性的抓取
# BV号为1WV41127vq的视频属性抓取结束
# 开始BV号为1Vp4y1Y7yz视频属性的抓取
# BV号为1Vp4y1Y7yz的视频属性抓取结束
# 开始BV号为1eV411y7FS视频属性的抓取
# BV号为1eV411y7FS的视频属性抓取结束
# 开始BV号为1Fa4y1x7Mj视频属性的抓取
# BV号为1Fa4y1x7Mj的视频属性抓取结束
# 开始BV号为1QZ4y157rK视频属性的抓取
# BV号为1QZ4y157rK的视频属性抓取结束
# 开始BV号为1ah411979E视频属性的抓取
# BV号为1ah411979E的视频属性抓取结束
# 开始BV号为1AZ4y1L7qe视频属性的抓取
# BV号为1AZ4y1L7qe的视频属性抓取结束
# 开始BV号为1nV411y7Ce视频属性的抓取
# BV号为1nV411y7Ce的视频属性抓取结束
# 开始BV号为1jk4y1C7Y8视频属性的抓取
# BV号为1jk4y1C7Y8的视频属性抓取结束
# 开始BV号为1B54y1R7nD视频属性的抓取
# BV号为1B54y1R7nD的视频属性抓取结束
# 开始BV号为1Ei4y1E7GK视频属性的抓取
# BV号为1Ei4y1E7GK的视频属性抓取结束
# 开始BV号为19Z4y1G7dM视频属性的抓取
# BV号为19Z4y1G7dM的视频属性抓取结束
# 开始BV号为1Yz4y1C7Hn视频属性的抓取
# BV号为1Yz4y1C7Hn的视频属性抓取结束
# 开始BV号为1Ja411A7FH视频属性的抓取
# BV号为1Ja411A7FH的视频属性抓取结束
# 开始BV号为1fv411k7eE视频属性的抓取
# BV号为1fv411k7eE的视频属性抓取结束
# 开始BV号为1Lf4y1B7zG视频属性的抓取
# BV号为1Lf4y1B7zG的视频属性抓取结束
# 开始BV号为1qK411N7D8视频属性的抓取
# BV号为1qK411N7D8的视频属性抓取结束
# 开始BV号为1rv411k7RD视频属性的抓取
# BV号为1rv411k7RD的视频属性抓取结束
# 开始BV号为1Fy4y1C7pC视频属性的抓取
# BV号为1Fy4y1C7pC的视频属性抓取结束
# 开始BV号为1oa4y157LL视频属性的抓取
# BV号为1oa4y157LL的视频属性抓取结束
# 开始BV号为1Tf4y1z7cF视频属性的抓取
# BV号为1Tf4y1z7cF的视频属性抓取结束
# 开始BV号为1yv411671C视频属性的抓取
# BV号为1yv411671C的视频属性抓取结束
# 开始BV号为1hi4y1E7ap视频属性的抓取
# BV号为1hi4y1E7ap的视频属性抓取结束
# 开始BV号为1nv411k7km视频属性的抓取
# BV号为1nv411k7km的视频属性抓取结束
# 开始BV号为1h54y1R7qg视频属性的抓取
# BV号为1h54y1R7qg的视频属性抓取结束
# 开始BV号为1CD4y197jG视频属性的抓取
# BV号为1CD4y197jG的视频属性抓取结束
# 开始BV号为1g541177iW视频属性的抓取
# BV号为1g541177iW的视频属性抓取结束
# 开始BV号为1154y1r7Bv视频属性的抓取
# BV号为1154y1r7Bv的视频属性抓取结束
# 开始BV号为1YV411y76T视频属性的抓取
# BV号为1YV411y76T的视频属性抓取结束
# 开始BV号为1UZ4y157ZP视频属性的抓取
# BV号为1UZ4y157ZP的视频属性抓取结束
# 开始BV号为1s5411L7Mw视频属性的抓取
# BV号为1s5411L7Mw的视频属性抓取结束
# 开始BV号为1fZ4y15732视频属性的抓取
# BV号为1fZ4y15732的视频属性抓取结束
# 开始BV号为1zt4y1v7pi视频属性的抓取
# BV号为1zt4y1v7pi的视频属性抓取结束
# 开始BV号为1cz4y1f7Jx视频属性的抓取
# BV号为1cz4y1f7Jx的视频属性抓取结束
# 开始BV号为16D4y1R7rW视频属性的抓取
# BV号为16D4y1R7rW的视频属性抓取结束
# 开始BV号为1Yp4y1Y7iL视频属性的抓取
# BV号为1Yp4y1Y7iL的视频属性抓取结束
# 开始BV号为1Qk4y1C7zj视频属性的抓取
# BV号为1Qk4y1C7zj的视频属性抓取结束
# 开始BV号为1Zy4y1k7hE视频属性的抓取
# BV号为1Zy4y1k7hE的视频属性抓取结束
# 开始BV号为1ni4y1E7qz视频属性的抓取
# BV号为1ni4y1E7qz的视频属性抓取结束
# 开始BV号为1dv411k76P视频属性的抓取
# BV号为1dv411k76P的视频属性抓取结束
# 开始BV号为1vf4y1B78D视频属性的抓取
# BV号为1vf4y1B78D的视频属性抓取结束
# 开始BV号为1nD4y197e6视频属性的抓取
# BV号为1nD4y197e6的视频属性抓取结束
# 开始BV号为1Pv411C7e7视频属性的抓取
# BV号为1Pv411C7e7的视频属性抓取结束
# 开始BV号为1Fi4y177Qr视频属性的抓取
# BV号为1Fi4y177Qr的视频属性抓取结束
# 开始BV号为1Ri4y1j7H4视频属性的抓取
# BV号为1Ri4y1j7H4的视频属性抓取结束
# 开始BV号为1dK4y1771A视频属性的抓取
# BV号为1dK4y1771A的视频属性抓取结束
# 开始BV号为1XZ4y1G7AC视频属性的抓取
# BV号为1XZ4y1G7AC的视频属性抓取结束
# 开始BV号为1gZ4y1V7VV视频属性的抓取
# BV号为1gZ4y1V7VV的视频属性抓取结束
# 开始BV号为1Ef4y1B7UY视频属性的抓取
# BV号为1Ef4y1B7UY的视频属性抓取结束
# 开始BV号为1Ba4y157sH视频属性的抓取
# BV号为1Ba4y157sH的视频属性抓取结束
# 开始BV号为1xZ4y157Kp视频属性的抓取
# BV号为1xZ4y157Kp的视频属性抓取结束
# 开始BV号为1Di4y1j7TR视频属性的抓取
# BV号为1Di4y1j7TR的视频属性抓取结束
# 开始BV号为1o54y117Ur视频属性的抓取
# BV号为1o54y117Ur的视频属性抓取结束
# 开始BV号为1ra411A7uk视频属性的抓取
# BV号为1ra411A7uk的视频属性抓取结束
# 开始BV号为1bf4y1i7HZ视频属性的抓取
# BV号为1bf4y1i7HZ的视频属性抓取结束
# 开始BV号为1k54y1k7rx视频属性的抓取
# BV号为1k54y1k7rx的视频属性抓取结束
# 开始BV号为1ni4y1E7jo视频属性的抓取
# BV号为1ni4y1E7jo的视频属性抓取结束
# 开始BV号为1MK4y1h77b视频属性的抓取
# BV号为1MK4y1h77b的视频属性抓取结束
# 开始BV号为1kf4y1i76S视频属性的抓取
# BV号为1kf4y1i76S的视频属性抓取结束
# 开始BV号为1Qt4y1Y74S视频属性的抓取
# BV号为1Qt4y1Y74S的视频属性抓取结束
# 开始BV号为1cp4y1Y7QS视频属性的抓取
# BV号为1cp4y1Y7QS的视频属性抓取结束
# 开始BV号为1Fi4y1779v视频属性的抓取
# BV号为1Fi4y1779v的视频属性抓取结束
# 开始BV号为1Kk4y1y7SW视频属性的抓取
# BV号为1Kk4y1y7SW的视频属性抓取结束
# 开始BV号为18a4y1L7km视频属性的抓取
# BV号为18a4y1L7km的视频属性抓取结束
# 开始BV号为1Cf4y1i7eJ视频属性的抓取
# BV号为1Cf4y1i7eJ的视频属性抓取结束
# 开始BV号为1LD4y197Ny视频属性的抓取
# BV号为1LD4y197Ny的视频属性抓取结束
# 开始BV号为1eV411y7EC视频属性的抓取
# BV号为1eV411y7EC的视频属性抓取结束
# 开始BV号为1H54y1C7pU视频属性的抓取
# BV号为1H54y1C7pU的视频属性抓取结束
# 开始BV号为1Hi4y177oq视频属性的抓取
# BV号为1Hi4y177oq的视频属性抓取结束
# 2020-12-22 14:35:04.462614

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-11-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_zhishi_yesheng.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月   100  100  100  100  100  100   100
# 2月   100  100  100  100  100  100   100
# 3月   100  100  100  100  100  100   100
# 4月   100  100  100  100  100  100   100
# 5月    99   99   99   99   99   99    99
# 6月   100  100  100  100  100  100   100
# 7月   100  100  100  100  100  100   100
# 8月   100  100  100  100  100  100   100
# 9月   100  100  100  100  100  100   100

# %%
channel_zhishi_yesheng.to_json('channel_zhishi_yesheng.json')
