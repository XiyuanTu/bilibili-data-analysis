# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_zhishi_xiaoyuan=pd.DataFrame(columns=columns)
channel_zhishi_xiaoyuan
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[7]/div/a/span').click()  #选择“知识”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[7]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '知识'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[5]/a').click()  #选择“校园学习”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[5]/a').text
sub_channel
# Out:
# '校园学习'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(1,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_zhishi_xiaoyuan.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-21 07:49:19.903649
# <ipython-input-10-ba31970754f6>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-10-ba31970754f6>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-10-ba31970754f6>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1CJ411p7cH视频属性的抓取
# BV号为1CJ411p7cH的视频属性抓取结束
# <ipython-input-10-ba31970754f6>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1gJ411L75M视频属性的抓取
# BV号为1gJ411L75M的视频属性抓取结束
# 开始BV号为1YJ411H7j7视频属性的抓取
# BV号为1YJ411H7j7的视频属性抓取结束
# 开始BV号为1P7411C7Gz视频属性的抓取
# BV号为1P7411C7Gz的视频属性抓取结束
# 开始BV号为1fJ411b7EV视频属性的抓取
# BV号为1fJ411b7EV的视频属性抓取结束
# 开始BV号为147411i7V6视频属性的抓取
# BV号为147411i7V6的视频属性抓取结束
# 开始BV号为1EJ41157bq视频属性的抓取
# BV号为1EJ41157bq的视频属性抓取结束
# 开始BV号为1VJ411j7Xe视频属性的抓取
# BV号为1VJ411j7Xe的视频属性抓取结束
# 开始BV号为1X7411i7q6视频属性的抓取
# BV号为1X7411i7q6的视频属性抓取结束
# 开始BV号为1XJ411L7Gu视频属性的抓取
# BV号为1XJ411L7Gu的视频属性抓取结束
# 开始BV号为1BJ41157Xz视频属性的抓取
# BV号为1BJ41157Xz的视频属性抓取结束
# 开始BV号为1EJ41157a2视频属性的抓取
# BV号为1EJ41157a2的视频属性抓取结束
# 开始BV号为1sJ411H75y视频属性的抓取
# BV号为1sJ411H75y的视频属性抓取结束
# 开始BV号为1SJ411n7aQ视频属性的抓取
# BV号为1SJ411n7aQ的视频属性抓取结束
# 开始BV号为1m7411B7eK视频属性的抓取
# BV号为1m7411B7eK的视频属性抓取结束
# 开始BV号为1nJ411V7bd视频属性的抓取
# BV号为1nJ411V7bd的视频属性抓取结束
# 开始BV号为1hJ411879j视频属性的抓取
# BV号为1hJ411879j的视频属性抓取结束
# 开始BV号为1BJ41177tk视频属性的抓取
# BV号为1BJ41177tk的视频属性抓取结束
# 开始BV号为1c7411v7Dq视频属性的抓取
# BV号为1c7411v7Dq的视频属性抓取结束
# 开始BV号为1B7411z76e视频属性的抓取
# BV号为1B7411z76e的视频属性抓取结束
# 开始BV号为15J411p72o视频属性的抓取
# BV号为15J411p72o的视频属性抓取结束
# 开始BV号为1s7411q75Y视频属性的抓取
# BV号为1s7411q75Y的视频属性抓取结束
# 开始BV号为1GJ411p7bm视频属性的抓取
# BV号为1GJ411p7bm的视频属性抓取结束
# 开始BV号为1fJ411E7CT视频属性的抓取
# BV号为1fJ411E7CT的视频属性抓取结束
# 开始BV号为1a7411i7tc视频属性的抓取
# BV号为1a7411i7tc的视频属性抓取结束
# 开始BV号为187411q7my视频属性的抓取
# BV号为187411q7my的视频属性抓取结束
# 开始BV号为1P7411z7c9视频属性的抓取
# BV号为1P7411z7c9的视频属性抓取结束
# 开始BV号为1J741167Ta视频属性的抓取
# BV号为1J741167Ta的视频属性抓取结束
# 开始BV号为1u7411Y7j9视频属性的抓取
# BV号为1u7411Y7j9的视频属性抓取结束
# 开始BV号为11J411p75E视频属性的抓取
# BV号为11J411p75E的视频属性抓取结束
# 开始BV号为1J7411e7w1视频属性的抓取
# BV号为1J7411e7w1的视频属性抓取结束
# 开始BV号为1WJ411E7qh视频属性的抓取
# BV号为1WJ411E7qh的视频属性抓取结束
# 开始BV号为1Y7411a75B视频属性的抓取
# BV号为1Y7411a75B的视频属性抓取结束
# 开始BV号为14J411G7sd视频属性的抓取
# BV号为14J411G7sd的视频属性抓取结束
# 开始BV号为1pJ411H784视频属性的抓取
# BV号为1pJ411H784的视频属性抓取结束
# 开始BV号为1M7411B7uG视频属性的抓取
# BV号为1M7411B7uG的视频属性抓取结束
# 开始BV号为1WJ411e7bb视频属性的抓取
# BV号为1WJ411e7bb的视频属性抓取结束
# 开始BV号为1NJ41187DK视频属性的抓取
# BV号为1NJ41187DK的视频属性抓取结束
# 开始BV号为1GJ411e7Ts视频属性的抓取
# BV号为1GJ411e7Ts的视频属性抓取结束
# 开始BV号为1iJ411H7mk视频属性的抓取
# BV号为1iJ411H7mk的视频属性抓取结束
# 开始BV号为1uJ411V7Vg视频属性的抓取
# BV号为1uJ411V7Vg的视频属性抓取结束
# 开始BV号为1q7411r7Zi视频属性的抓取
# BV号为1q7411r7Zi的视频属性抓取结束
# 开始BV号为1jJ411b7Ej视频属性的抓取
# BV号为1jJ411b7Ej的视频属性抓取结束
# 开始BV号为1nJ411V7wi视频属性的抓取
# BV号为1nJ411V7wi的视频属性抓取结束
# 开始BV号为18J411H7HX视频属性的抓取
# BV号为18J411H7HX的视频属性抓取结束
# 开始BV号为1w741167o8视频属性的抓取
# BV号为1w741167o8的视频属性抓取结束
# 开始BV号为1s7411a7GH视频属性的抓取
# BV号为1s7411a7GH的视频属性抓取结束
# 开始BV号为1sJ411E7St视频属性的抓取
# BV号为1sJ411E7St的视频属性抓取结束
# 开始BV号为1z7411q7tr视频属性的抓取
# BV号为1z7411q7tr的视频属性抓取结束
# 开始BV号为1SJ411E77q视频属性的抓取
# BV号为1SJ411E77q的视频属性抓取结束
# 开始BV号为1Y7411e7hQ视频属性的抓取
# BV号为1Y7411e7hQ的视频属性抓取结束
# 开始BV号为1u7411i77F视频属性的抓取
# BV号为1u7411i77F的视频属性抓取结束
# 开始BV号为1BJ411p7BB视频属性的抓取
# BV号为1BJ411p7BB的视频属性抓取结束
# 开始BV号为1KJ411G7k5视频属性的抓取
# BV号为1KJ411G7k5的视频属性抓取结束
# 开始BV号为147411q7be视频属性的抓取
# BV号为147411q7be的视频属性抓取结束
# 开始BV号为18J41157DE视频属性的抓取
# BV号为18J41157DE的视频属性抓取结束
# <ipython-input-10-ba31970754f6>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1XJ411E7P4视频属性的抓取
# BV号为1XJ411E7P4的视频属性抓取结束
# 开始BV号为1LJ411V7bF视频属性的抓取
# BV号为1LJ411V7bF的视频属性抓取结束
# 开始BV号为1PJ41157hM视频属性的抓取
# BV号为1PJ41157hM的视频属性抓取结束
# 开始BV号为137411q7oC视频属性的抓取
# BV号为137411q7oC的视频属性抓取结束
# 开始BV号为1GJ411p7fx视频属性的抓取
# BV号为1GJ411p7fx的视频属性抓取结束
# 开始BV号为1YJ411j76J视频属性的抓取
# BV号为1YJ411j76J的视频属性抓取结束
# 开始BV号为1uJ41177sT视频属性的抓取
# BV号为1uJ41177sT的视频属性抓取结束
# 开始BV号为1VJ411j7gp视频属性的抓取
# BV号为1VJ411j7gp的视频属性抓取结束
# 开始BV号为1mJ411V7e2视频属性的抓取
# BV号为1mJ411V7e2的视频属性抓取结束
# 开始BV号为1uJ411Y7bS视频属性的抓取
# BV号为1uJ411Y7bS的视频属性抓取结束
# 开始BV号为147411q7ZU视频属性的抓取
# BV号为147411q7ZU的视频属性抓取结束
# 开始BV号为1dJ411J7DD视频属性的抓取
# BV号为1dJ411J7DD的视频属性抓取结束
# 开始BV号为1hJ41187hs视频属性的抓取
# BV号为1hJ41187hs的视频属性抓取结束
# 开始BV号为1xJ41187Gr视频属性的抓取
# BV号为1xJ41187Gr的视频属性抓取结束
# 开始BV号为1i7411i7HT视频属性的抓取
# BV号为1i7411i7HT的视频属性抓取结束
# 开始BV号为1MJ41177Jw视频属性的抓取
# BV号为1MJ41177Jw的视频属性抓取结束
# 开始BV号为137411B7vB视频属性的抓取
# BV号为137411B7vB的视频属性抓取结束
# 开始BV号为1t7411v7Ac视频属性的抓取
# BV号为1t7411v7Ac的视频属性抓取结束
# 开始BV号为1VJ411G71e视频属性的抓取
# BV号为1VJ411G71e的视频属性抓取结束
# 开始BV号为1Y7411k7uP视频属性的抓取
# BV号为1Y7411k7uP的视频属性抓取结束
# 开始BV号为1DJ411p7xJ视频属性的抓取
# BV号为1DJ411p7xJ的视频属性抓取结束
# 开始BV号为1aJ411H7Ej视频属性的抓取
# BV号为1aJ411H7Ej的视频属性抓取结束
# 开始BV号为1Z7411B73h视频属性的抓取
# BV号为1Z7411B73h的视频属性抓取结束
# 开始BV号为1C7411q7dD视频属性的抓取
# BV号为1C7411q7dD的视频属性抓取结束
# 开始BV号为1tJ411n7KN视频属性的抓取
# BV号为1tJ411n7KN的视频属性抓取结束
# 开始BV号为1nJ41177LQ视频属性的抓取
# BV号为1nJ41177LQ的视频属性抓取结束
# 开始BV号为1R7411e7rU视频属性的抓取
# BV号为1R7411e7rU的视频属性抓取结束
# 开始BV号为137411v7rh视频属性的抓取
# BV号为137411v7rh的视频属性抓取结束
# 开始BV号为1X7411a7B9视频属性的抓取
# BV号为1X7411a7B9的视频属性抓取结束
# 开始BV号为1U7411v7cL视频属性的抓取
# BV号为1U7411v7cL的视频属性抓取结束
# 开始BV号为1f7411i7kS视频属性的抓取
# BV号为1f7411i7kS的视频属性抓取结束
# 开始BV号为177411q7e8视频属性的抓取
# BV号为177411q7e8的视频属性抓取结束
# 开始BV号为1cJ41187vS视频属性的抓取
# BV号为1cJ41187vS的视频属性抓取结束
# 开始BV号为1X7411e7mr视频属性的抓取
# BV号为1X7411e7mr的视频属性抓取结束
# 开始BV号为14J41157wo视频属性的抓取
# BV号为14J41157wo的视频属性抓取结束
# 开始BV号为1bJ411j7Gn视频属性的抓取
# BV号为1bJ411j7Gn的视频属性抓取结束
# 开始BV号为1JJ411b7JW视频属性的抓取
# BV号为1JJ411b7JW的视频属性抓取结束
# 开始BV号为1b7411a7dJ视频属性的抓取
# BV号为1b7411a7dJ的视频属性抓取结束
# 开始BV号为1YJ41157KQ视频属性的抓取
# BV号为1YJ41157KQ的视频属性抓取结束
# 开始BV号为1j74116784视频属性的抓取
# BV号为1j74116784的视频属性抓取结束
# 开始BV号为1QJ411L7Hg视频属性的抓取
# 开始BV号为1QJ411L7Hg视频属性的抓取
# BV号为1QJ411L7Hg的视频属性抓取结束
# 开始BV号为1e7411z7Lv视频属性的抓取
# BV号为1e7411z7Lv的视频属性抓取结束
# 开始BV号为1DJ411L7xV视频属性的抓取
# BV号为1DJ411L7xV的视频属性抓取结束
# 开始BV号为1V7411A7Th视频属性的抓取
# BV号为1V7411A7Th的视频属性抓取结束
# 开始BV号为1U7411t7sG视频属性的抓取
# BV号为1U7411t7sG的视频属性抓取结束
# 开始BV号为1W7411t7fy视频属性的抓取
# BV号为1W7411t7fy的视频属性抓取结束
# 开始BV号为19741147fr视频属性的抓取
# BV号为19741147fr的视频属性抓取结束
# 开始BV号为1B7411h7zo视频属性的抓取
# BV号为1B7411h7zo的视频属性抓取结束
# 开始BV号为1e7411w7d4视频属性的抓取
# BV号为1e7411w7d4的视频属性抓取结束
# 开始BV号为147411K7xu视频属性的抓取
# BV号为147411K7xu的视频属性抓取结束
# 开始BV号为1b7411N798视频属性的抓取
# BV号为1b7411N798的视频属性抓取结束
# 开始BV号为1c7411M7VE视频属性的抓取
# BV号为1c7411M7VE的视频属性抓取结束
# 开始BV号为1v7411V7UZ视频属性的抓取
# BV号为1v7411V7UZ的视频属性抓取结束
# 开始BV号为1K7411j7PT视频属性的抓取
# BV号为1K7411j7PT的视频属性抓取结束
# 开始BV号为1B7411A7M1视频属性的抓取
# BV号为1B7411A7M1的视频属性抓取结束
# 开始BV号为1J7411P7Xk视频属性的抓取
# BV号为1J7411P7Xk的视频属性抓取结束
# 开始BV号为127411j7SH视频属性的抓取
# BV号为127411j7SH的视频属性抓取结束
# 开始BV号为1N7411A74L视频属性的抓取
# BV号为1N7411A74L的视频属性抓取结束
# 开始BV号为1Y7411K7zz视频属性的抓取
# BV号为1Y7411K7zz的视频属性抓取结束
# 开始BV号为1b7411J7LX视频属性的抓取
# BV号为1b7411J7LX的视频属性抓取结束
# 开始BV号为1q7411p7hw视频属性的抓取
# BV号为1q7411p7hw的视频属性抓取结束
# 开始BV号为1a7411N7gy视频属性的抓取
# BV号为1a7411N7gy的视频属性抓取结束
# 开始BV号为1a7411T7dY视频属性的抓取
# BV号为1a7411T7dY的视频属性抓取结束
# 开始BV号为1x7411j7ER视频属性的抓取
# BV号为1x7411j7ER的视频属性抓取结束
# 开始BV号为1i7411G7vm视频属性的抓取
# BV号为1i7411G7vm的视频属性抓取结束
# 开始BV号为1S7411g7Ne视频属性的抓取
# BV号为1S7411g7Ne的视频属性抓取结束
# 开始BV号为1B7411t7N9视频属性的抓取
# BV号为1B7411t7N9的视频属性抓取结束
# 开始BV号为137411n7pQ视频属性的抓取
# BV号为137411n7pQ的视频属性抓取结束
# 开始BV号为1Y741137fy视频属性的抓取
# BV号为1Y741137fy的视频属性抓取结束
# 开始BV号为1c7411A7aF视频属性的抓取
# BV号为1c7411A7aF的视频属性抓取结束
# 开始BV号为1Ej411f7Er视频属性的抓取
# BV号为1Ej411f7Er的视频属性抓取结束
# 开始BV号为1q7411b7Wm视频属性的抓取
# BV号为1q7411b7Wm的视频属性抓取结束
# 开始BV号为1h7411h7Vb视频属性的抓取
# BV号为1h7411h7Vb的视频属性抓取结束
# 开始BV号为1L7411K7ht视频属性的抓取
# BV号为1L7411K7ht的视频属性抓取结束
# 开始BV号为1b7411A75j视频属性的抓取
# BV号为1b7411A75j的视频属性抓取结束
# 开始BV号为1H7411V7Ub视频属性的抓取
# BV号为1H7411V7Ub的视频属性抓取结束
# 开始BV号为1P7411b7VJ视频属性的抓取
# BV号为1P7411b7VJ的视频属性抓取结束
# 开始BV号为1e7411H7tr视频属性的抓取
# BV号为1e7411H7tr的视频属性抓取结束
# 开始BV号为1DE411n7p7视频属性的抓取
# BV号为1DE411n7p7的视频属性抓取结束
# 开始BV号为1H7411g76e视频属性的抓取
# BV号为1H7411g76e的视频属性抓取结束
# 开始BV号为1qE411H7Uv视频属性的抓取
# BV号为1qE411H7Uv的视频属性抓取结束
# 开始BV号为1t741157LG视频属性的抓取
# BV号为1t741157LG的视频属性抓取结束
# 开始BV号为187411j7ab视频属性的抓取
# BV号为187411j7ab的视频属性抓取结束
# 开始BV号为137411s7pU视频属性的抓取
# BV号为137411s7pU的视频属性抓取结束
# 开始BV号为1w7411L7gU视频属性的抓取
# BV号为1w7411L7gU的视频属性抓取结束
# 开始BV号为1j7411c7VV视频属性的抓取
# BV号为1j7411c7VV的视频属性抓取结束
# 开始BV号为1x7411M74h视频属性的抓取
# BV号为1x7411M74h的视频属性抓取结束
# 开始BV号为1BE411H7pr视频属性的抓取
# BV号为1BE411H7pr的视频属性抓取结束
# 开始BV号为1P741187ZL视频属性的抓取
# BV号为1P741187ZL的视频属性抓取结束
# 开始BV号为1B7411F7vm视频属性的抓取
# BV号为1B7411F7vm的视频属性抓取结束
# 开始BV号为1L7411K7iH视频属性的抓取
# BV号为1L7411K7iH的视频属性抓取结束
# 开始BV号为1F7411W7di视频属性的抓取
# BV号为1F7411W7di的视频属性抓取结束
# 开始BV号为1A7411J7KC视频属性的抓取
# BV号为1A7411J7KC的视频属性抓取结束
# 开始BV号为1X7411F744视频属性的抓取
# BV号为1X7411F744的视频属性抓取结束
# 开始BV号为117411w7PR视频属性的抓取
# BV号为117411w7PR的视频属性抓取结束
# 开始BV号为187411n7s7视频属性的抓取
# BV号为187411n7s7的视频属性抓取结束
# 开始BV号为1H7411W7WF视频属性的抓取
# BV号为1H7411W7WF的视频属性抓取结束
# 开始BV号为1w7411w7kQ视频属性的抓取
# BV号为1w7411w7kQ的视频属性抓取结束
# 开始BV号为157411t7s9视频属性的抓取
# BV号为157411t7s9的视频属性抓取结束
# 开始BV号为1q7411h7mg视频属性的抓取
# BV号为1q7411h7mg的视频属性抓取结束
# 开始BV号为197411h7Yi视频属性的抓取
# BV号为197411h7Yi的视频属性抓取结束
# 开始BV号为1h7411b7By视频属性的抓取
# BV号为1h7411b7By的视频属性抓取结束
# 开始BV号为147411p77V视频属性的抓取
# BV号为147411p77V的视频属性抓取结束
# 开始BV号为187411h7P8视频属性的抓取
# BV号为187411h7P8的视频属性抓取结束
# 开始BV号为1a7411w7wy视频属性的抓取
# BV号为1a7411w7wy的视频属性抓取结束
# 开始BV号为197411j7bU视频属性的抓取
# BV号为197411j7bU的视频属性抓取结束
# 开始BV号为1A7411J71h视频属性的抓取
# BV号为1A7411J71h的视频属性抓取结束
# 开始BV号为127411n7nj视频属性的抓取
# BV号为127411n7nj的视频属性抓取结束
# 开始BV号为1U7411j7JJ视频属性的抓取
# BV号为1U7411j7JJ的视频属性抓取结束
# 开始BV号为177411u7j8视频属性的抓取
# BV号为177411u7j8的视频属性抓取结束
# 开始BV号为117411H7C1视频属性的抓取
# BV号为117411H7C1的视频属性抓取结束
# 开始BV号为1G7411A72i视频属性的抓取
# BV号为1G7411A72i的视频属性抓取结束
# 开始BV号为1L7411a7Rz视频属性的抓取
# BV号为1L7411a7Rz的视频属性抓取结束
# 开始BV号为1k7411P7U6视频属性的抓取
# BV号为1k7411P7U6的视频属性抓取结束
# 开始BV号为137411x7oZ视频属性的抓取
# BV号为137411x7oZ的视频属性抓取结束
# 开始BV号为1j7411b7ZM视频属性的抓取
# BV号为1j7411b7ZM的视频属性抓取结束
# 开始BV号为1d7411775Q视频属性的抓取
# BV号为1d7411775Q的视频属性抓取结束
# 开始BV号为1a7411h7m7视频属性的抓取
# BV号为1a7411h7m7的视频属性抓取结束
# 开始BV号为1p7411L7DE视频属性的抓取
# BV号为1p7411L7DE的视频属性抓取结束
# 开始BV号为1v7411M7Ed视频属性的抓取
# BV号为1v7411M7Ed的视频属性抓取结束
# 开始BV号为1E7411j76A视频属性的抓取
# BV号为1E7411j76A的视频属性抓取结束
# 开始BV号为1L7411V7vC视频属性的抓取
# BV号为1L7411V7vC的视频属性抓取结束
# 开始BV号为1g7411W78U视频属性的抓取
# BV号为1g7411W78U的视频属性抓取结束
# 开始BV号为1q7411u7YD视频属性的抓取
# BV号为1q7411u7YD的视频属性抓取结束
# 开始BV号为1Y7411P72G视频属性的抓取
# BV号为1Y7411P72G的视频属性抓取结束
# 开始BV号为1T7411p7u5视频属性的抓取
# BV号为1T7411p7u5的视频属性抓取结束
# 开始BV号为187411h7Kf视频属性的抓取
# BV号为187411h7Kf的视频属性抓取结束
# 开始BV号为1W7411h7uf视频属性的抓取
# BV号为1W7411h7uf的视频属性抓取结束
# 开始BV号为1Y7411w7Bu视频属性的抓取
# BV号为1Y7411w7Bu的视频属性抓取结束
# 开始BV号为1t7411P7YQ视频属性的抓取
# BV号为1t7411P7YQ的视频属性抓取结束
# 开始BV号为1F7411G7aY视频属性的抓取
# BV号为1F7411G7aY的视频属性抓取结束
# 开始BV号为1Q7411n7KJ视频属性的抓取
# BV号为1Q7411n7KJ的视频属性抓取结束
# 开始BV号为1Q741147DB视频属性的抓取
# BV号为1Q741147DB的视频属性抓取结束
# 开始BV号为1J7411G7vh视频属性的抓取
# BV号为1J7411G7vh的视频属性抓取结束
# 开始BV号为1j7411T7BF视频属性的抓取
# BV号为1j7411T7BF的视频属性抓取结束
# 开始BV号为19741177Lz视频属性的抓取
# BV号为19741177Lz的视频属性抓取结束
# 开始BV号为1c741147y1视频属性的抓取
# BV号为1c741147y1的视频属性抓取结束
# 开始BV号为1b7411w7G8视频属性的抓取
# BV号为1b7411w7G8的视频属性抓取结束
# 开始BV号为1X7411T7DS视频属性的抓取
# BV号为1X7411T7DS的视频属性抓取结束
# 开始BV号为13741187bY视频属性的抓取
# BV号为13741187bY的视频属性抓取结束
# 开始BV号为1m7411h7LE视频属性的抓取
# BV号为1m7411h7LE的视频属性抓取结束
# 开始BV号为1b7411h7R4视频属性的抓取
# BV号为1b7411h7R4的视频属性抓取结束
# 开始BV号为1c7411N7s3视频属性的抓取
# BV号为1c7411N7s3的视频属性抓取结束
# 开始BV号为1gE411V7Hs视频属性的抓取
# BV号为1gE411V7Hs的视频属性抓取结束
# 开始BV号为1uE411g7PB视频属性的抓取
# BV号为1uE411g7PB的视频属性抓取结束
# 开始BV号为1dE411A7Rx视频属性的抓取
# BV号为1dE411A7Rx的视频属性抓取结束
# 开始BV号为1tE411x7mk视频属性的抓取
# BV号为1tE411x7mk的视频属性抓取结束
# 开始BV号为1kE411E7Xq视频属性的抓取
# BV号为1kE411E7Xq的视频属性抓取结束
# 开始BV号为1yE411E7jY视频属性的抓取
# BV号为1yE411E7jY的视频属性抓取结束
# 开始BV号为1nE411A7u2视频属性的抓取
# BV号为1nE411A7u2的视频属性抓取结束
# 开始BV号为1YE411p7WP视频属性的抓取
# BV号为1YE411p7WP的视频属性抓取结束
# 开始BV号为1wE411j7Lo视频属性的抓取
# BV号为1wE411j7Lo的视频属性抓取结束
# 开始BV号为1mE411p7Ht视频属性的抓取
# BV号为1mE411p7Ht的视频属性抓取结束
# 开始BV号为1Rt4y1m7Sj视频属性的抓取
# BV号为1Rt4y1m7Sj的视频属性抓取结束
# 开始BV号为1eE411J7Bh视频属性的抓取
# BV号为1eE411J7Bh的视频属性抓取结束
# 开始BV号为1gE411V7Qq视频属性的抓取
# BV号为1gE411V7Qq的视频属性抓取结束
# 开始BV号为14E411j7Aq视频属性的抓取
# BV号为14E411j7Aq的视频属性抓取结束
# 开始BV号为1r7411m76U视频属性的抓取
# BV号为1r7411m76U的视频属性抓取结束
# 开始BV号为1p7411f7yA视频属性的抓取
# BV号为1p7411f7yA的视频属性抓取结束
# 开始BV号为1RE411w7SL视频属性的抓取
# BV号为1RE411w7SL的视频属性抓取结束
# 开始BV号为1cE411E7R3视频属性的抓取
# BV号为1cE411E7R3的视频属性抓取结束
# 开始BV号为1pE411N77x视频属性的抓取
# BV号为1pE411N77x的视频属性抓取结束
# 开始BV号为1Ga4y1t7KM视频属性的抓取
# BV号为1Ga4y1t7KM的视频属性抓取结束
# 开始BV号为1Y7411n7iM视频属性的抓取
# BV号为1Y7411n7iM的视频属性抓取结束
# 开始BV号为1CE411E7By视频属性的抓取
# BV号为1CE411E7By的视频属性抓取结束
# 开始BV号为1sE41147Y4视频属性的抓取
# BV号为1sE41147Y4的视频属性抓取结束
# 开始BV号为1s7411279m视频属性的抓取
# BV号为1s7411279m的视频属性抓取结束
# 开始BV号为1F5411r7it视频属性的抓取
# BV号为1F5411r7it的视频属性抓取结束
# 开始BV号为1c7411Z78e视频属性的抓取
# BV号为1c7411Z78e的视频属性抓取结束
# 开始BV号为1H7411o7KD视频属性的抓取
# BV号为1H7411o7KD的视频属性抓取结束
# 开始BV号为1TE411g7L4视频属性的抓取
# BV号为1TE411g7L4的视频属性抓取结束
# 开始BV号为1o7411d7k9视频属性的抓取
# BV号为1o7411d7k9的视频属性抓取结束
# 开始BV号为1tE411K7yX视频属性的抓取
# BV号为1tE411K7yX的视频属性抓取结束
# 开始BV号为13E411x74W视频属性的抓取
# BV号为13E411x74W的视频属性抓取结束
# 开始BV号为1sE41147CD视频属性的抓取
# BV号为1sE41147CD的视频属性抓取结束
# 开始BV号为1YE411c7Ef视频属性的抓取
# BV号为1YE411c7Ef的视频属性抓取结束
# 开始BV号为1o7411y7pH视频属性的抓取
# BV号为1o7411y7pH的视频属性抓取结束
# 开始BV号为1AE411j7ZY视频属性的抓取
# BV号为1AE411j7ZY的视频属性抓取结束
# 开始BV号为16E411E7PA视频属性的抓取
# BV号为16E411E7PA的视频属性抓取结束
# 开始BV号为1Wc411h7N1视频属性的抓取
# BV号为1Wc411h7N1的视频属性抓取结束
# 开始BV号为1t7411o79q视频属性的抓取
# BV号为1t7411o79q的视频属性抓取结束
# 开始BV号为18K4y1C7dd视频属性的抓取
# BV号为18K4y1C7dd的视频属性抓取结束
# 开始BV号为1S7411o7pE视频属性的抓取
# BV号为1S7411o7pE的视频属性抓取结束
# 开始BV号为1EE41177wr视频属性的抓取
# BV号为1EE41177wr的视频属性抓取结束
# 开始BV号为1fE411M7PF视频属性的抓取
# BV号为1fE411M7PF的视频属性抓取结束
# 开始BV号为18E411s7ER视频属性的抓取
# BV号为18E411s7ER的视频属性抓取结束
# 开始BV号为1iE411u7j6视频属性的抓取
# BV号为1iE411u7j6的视频属性抓取结束
# 开始BV号为1DE41177tM视频属性的抓取
# BV号为1DE41177tM的视频属性抓取结束
# 开始BV号为1QE411s7hT视频属性的抓取
# BV号为1QE411s7hT的视频属性抓取结束
# 开始BV号为1CE411W77z视频属性的抓取
# BV号为1CE411W77z的视频属性抓取结束
# 开始BV号为1SE411V7LY视频属性的抓取
# BV号为1SE411V7LY的视频属性抓取结束
# 开始BV号为1TE41177k6视频属性的抓取
# BV号为1TE41177k6的视频属性抓取结束
# 开始BV号为1PE411c7N7视频属性的抓取
# BV号为1PE411c7N7的视频属性抓取结束
# 开始BV号为1L74111786视频属性的抓取
# BV号为1L74111786的视频属性抓取结束
# 开始BV号为1EE41157Jj视频属性的抓取
# BV号为1EE41157Jj的视频属性抓取结束
# 开始BV号为117411o78d视频属性的抓取
# BV号为117411o78d的视频属性抓取结束
# 开始BV号为1BK41177ag视频属性的抓取
# BV号为1BK41177ag的视频属性抓取结束
# 开始BV号为1uT4y157ui视频属性的抓取
# BV号为1uT4y157ui的视频属性抓取结束
# 开始BV号为1Zi4y1b71m视频属性的抓取
# BV号为1Zi4y1b71m的视频属性抓取结束
# 开始BV号为1QE411K7Xb视频属性的抓取
# BV号为1QE411K7Xb的视频属性抓取结束
# 开始BV号为1NE411P7YG视频属性的抓取
# BV号为1NE411P7YG的视频属性抓取结束
# 开始BV号为1g741117R2视频属性的抓取
# BV号为1g741117R2的视频属性抓取结束
# 开始BV号为1hE411L7EG视频属性的抓取
# BV号为1hE411L7EG的视频属性抓取结束
# 开始BV号为1yE411G7Ma视频属性的抓取
# BV号为1yE411G7Ma的视频属性抓取结束
# 开始BV号为1zk4y197K4视频属性的抓取
# BV号为1zk4y197K4的视频属性抓取结束
# 开始BV号为11E411F7HD视频属性的抓取
# BV号为11E411F7HD的视频属性抓取结束
# 开始BV号为1hE411K7sb视频属性的抓取
# BV号为1hE411K7sb的视频属性抓取结束
# 开始BV号为1UE411K7My视频属性的抓取
# BV号为1UE411K7My的视频属性抓取结束
# 开始BV号为1K7411D7sC视频属性的抓取
# BV号为1K7411D7sC的视频属性抓取结束
# 开始BV号为1iE411J7Sg视频属性的抓取
# BV号为1iE411J7Sg的视频属性抓取结束
# 开始BV号为1Q7411o7i5视频属性的抓取
# BV号为1Q7411o7i5的视频属性抓取结束
# 开始BV号为1PE411x7Z6视频属性的抓取
# BV号为1PE411x7Z6的视频属性抓取结束
# 开始BV号为1H7411y7QN视频属性的抓取
# BV号为1H7411y7QN的视频属性抓取结束
# 开始BV号为1PE411L7x2视频属性的抓取
# BV号为1PE411L7x2的视频属性抓取结束
# 开始BV号为1jE411N7LK视频属性的抓取
# BV号为1jE411N7LK的视频属性抓取结束
# 开始BV号为1dE411x7Ag视频属性的抓取
# BV号为1dE411x7Ag的视频属性抓取结束
# 开始BV号为1EE411W7R2视频属性的抓取
# BV号为1EE411W7R2的视频属性抓取结束
# 开始BV号为1w7411f7Xw视频属性的抓取
# BV号为1w7411f7Xw的视频属性抓取结束
# 开始BV号为1oE411A7xj视频属性的抓取
# BV号为1oE411A7xj的视频属性抓取结束
# 开始BV号为1GE41177j5视频属性的抓取
# BV号为1GE41177j5的视频属性抓取结束
# 开始BV号为117411f7rT视频属性的抓取
# BV号为117411f7rT的视频属性抓取结束
# 开始BV号为1N741127Tj视频属性的抓取
# BV号为1N741127Tj的视频属性抓取结束
# 开始BV号为187411C7DY视频属性的抓取
# BV号为187411C7DY的视频属性抓取结束
# 开始BV号为1iE411u7MV视频属性的抓取
# BV号为1iE411u7MV的视频属性抓取结束
# 开始BV号为1aZ4y1j7kY视频属性的抓取
# BV号为1aZ4y1j7kY的视频属性抓取结束
# 开始BV号为1QE41147hU视频属性的抓取
# BV号为1QE41147hU的视频属性抓取结束
# 开始BV号为1K7411R7hd视频属性的抓取
# BV号为1K7411R7hd的视频属性抓取结束
# 开始BV号为1zE411x7e2视频属性的抓取
# BV号为1zE411x7e2的视频属性抓取结束
# 开始BV号为1QE41147ji视频属性的抓取
# BV号为1QE41147ji的视频属性抓取结束
# 开始BV号为167411y7S8视频属性的抓取
# BV号为167411y7S8的视频属性抓取结束
# 开始BV号为1RE411p7Bw视频属性的抓取
# BV号为1RE411p7Bw的视频属性抓取结束
# 开始BV号为14E411M7yx视频属性的抓取
# BV号为14E411M7yx的视频属性抓取结束
# 开始BV号为1X7411C7ig视频属性的抓取
# BV号为1X7411C7ig的视频属性抓取结束
# 开始BV号为1q7411C7S7视频属性的抓取
# BV号为1q7411C7S7的视频属性抓取结束
# 开始BV号为1q7411o7Xf视频属性的抓取
# BV号为1q7411o7Xf的视频属性抓取结束
# 开始BV号为1eE4113737视频属性的抓取
# BV号为1eE4113737的视频属性抓取结束
# 开始BV号为18E411G7ZN视频属性的抓取
# BV号为18E411G7ZN的视频属性抓取结束
# 开始BV号为1wE41147fz视频属性的抓取
# BV号为1wE41147fz的视频属性抓取结束
# 开始BV号为1ME411M7hp视频属性的抓取
# BV号为1ME411M7hp的视频属性抓取结束
# 开始BV号为1iE411G7Qx视频属性的抓取
# BV号为1iE411G7Qx的视频属性抓取结束
# 开始BV号为1ZE411H7xW视频属性的抓取
# BV号为1ZE411H7xW的视频属性抓取结束
# 开始BV号为1XE411P7hk视频属性的抓取
# BV号为1XE411P7hk的视频属性抓取结束
# 开始BV号为19741117j2视频属性的抓取
# BV号为19741117j2的视频属性抓取结束
# 开始BV号为1Xg4y187KB视频属性的抓取
# BV号为1Xg4y187KB的视频属性抓取结束
# 开始BV号为16i4y1t7WW视频属性的抓取
# BV号为16i4y1t7WW的视频属性抓取结束
# 开始BV号为1ht4y1m7VE视频属性的抓取
# BV号为1ht4y1m7VE的视频属性抓取结束
# 开始BV号为1Yg4y1z71b视频属性的抓取
# BV号为1Yg4y1z71b的视频属性抓取结束
# 开始BV号为1Gg4y1z7jq视频属性的抓取
# BV号为1Gg4y1z7jq的视频属性抓取结束
# 开始BV号为1Ai4y187eH视频属性的抓取
# BV号为1Ai4y187eH的视频属性抓取结束
# 开始BV号为1ce41147QS视频属性的抓取
# BV号为1ce41147QS的视频属性抓取结束
# 开始BV号为1864y1T7Ks视频属性的抓取
# BV号为1864y1T7Ks的视频属性抓取结束
# 开始BV号为1CZ4y1W7wB视频属性的抓取
# BV号为1CZ4y1W7wB的视频属性抓取结束
# 开始BV号为1fp4y1X7CW视频属性的抓取
# BV号为1fp4y1X7CW的视频属性抓取结束
# 开始BV号为1N54y1R7da视频属性的抓取
# BV号为1N54y1R7da的视频属性抓取结束
# 开始BV号为1YC4y1W7FM视频属性的抓取
# BV号为1YC4y1W7FM的视频属性抓取结束
# 开始BV号为1Pp4y1y7F7视频属性的抓取
# BV号为1Pp4y1y7F7的视频属性抓取结束
# 开始BV号为1kf4y1U75X视频属性的抓取
# BV号为1kf4y1U75X的视频属性抓取结束
# 开始BV号为1Fp4y197Qc视频属性的抓取
# BV号为1Fp4y197Qc的视频属性抓取结束
# 开始BV号为1ZK411V7v2视频属性的抓取
# BV号为1ZK411V7v2的视频属性抓取结束
# 开始BV号为1LK411j7ey视频属性的抓取
# BV号为1LK411j7ey的视频属性抓取结束
# 开始BV号为1w5411t7vP视频属性的抓取
# BV号为1w5411t7vP的视频属性抓取结束
# 开始BV号为1Za4y1v7RB视频属性的抓取
# BV号为1Za4y1v7RB的视频属性抓取结束
# 开始BV号为1pA411b75d视频属性的抓取
# BV号为1pA411b75d的视频属性抓取结束
# 开始BV号为1XQ4y1P7sQ视频属性的抓取
# BV号为1XQ4y1P7sQ的视频属性抓取结束
# 开始BV号为1di4y1b7gg视频属性的抓取
# BV号为1di4y1b7gg的视频属性抓取结束
# 开始BV号为1mC4y1p7Fh视频属性的抓取
# BV号为1mC4y1p7Fh的视频属性抓取结束
# 开始BV号为1Si4y1t7HY视频属性的抓取
# BV号为1Si4y1t7HY的视频属性抓取结束
# 开始BV号为1yK411V7VH视频属性的抓取
# BV号为1yK411V7VH的视频属性抓取结束
# 开始BV号为1cp4y1y7Ae视频属性的抓取
# BV号为1cp4y1y7Ae的视频属性抓取结束
# 开始BV号为1Xi4y1t7Az视频属性的抓取
# BV号为1Xi4y1t7Az的视频属性抓取结束
# 开始BV号为1GQ4y1T7uq视频属性的抓取
# BV号为1GQ4y1T7uq的视频属性抓取结束
# 开始BV号为18K4y1k7ug视频属性的抓取
# BV号为18K4y1k7ug的视频属性抓取结束
# 开始BV号为1VC4y1x7LJ视频属性的抓取
# BV号为1VC4y1x7LJ的视频属性抓取结束
# 开始BV号为1RK411V7pu视频属性的抓取
# BV号为1RK411V7pu的视频属性抓取结束
# 开始BV号为1CZ4y1j7hs视频属性的抓取
# BV号为1CZ4y1j7hs的视频属性抓取结束
# 开始BV号为1ik4y1R7mS视频属性的抓取
# BV号为1ik4y1R7mS的视频属性抓取结束
# 开始BV号为18c411h7x2视频属性的抓取
# BV号为18c411h7x2的视频属性抓取结束
# 开始BV号为1Vz41187Rt视频属性的抓取
# BV号为1Vz41187Rt的视频属性抓取结束
# 开始BV号为1na4y1t7Xo视频属性的抓取
# BV号为1na4y1t7Xo的视频属性抓取结束
# 开始BV号为1uT4y137uB视频属性的抓取
# BV号为1uT4y137uB的视频属性抓取结束
# 开始BV号为1hC4y147Yg视频属性的抓取
# BV号为1hC4y147Yg的视频属性抓取结束
# 开始BV号为1BT4y1g7Rx视频属性的抓取
# BV号为1BT4y1g7Rx的视频属性抓取结束
# 开始BV号为1d541167PV视频属性的抓取
# BV号为1d541167PV的视频属性抓取结束
# 开始BV号为1za4y1v7sU视频属性的抓取
# BV号为1za4y1v7sU的视频属性抓取结束
# 开始BV号为1Wz411b7xC视频属性的抓取
# BV号为1Wz411b7xC的视频属性抓取结束
# 开始BV号为1rV411o7gq视频属性的抓取
# BV号为1rV411o7gq的视频属性抓取结束
# 开始BV号为1Az41187Uc视频属性的抓取
# BV号为1Az41187Uc的视频属性抓取结束
# 开始BV号为1LQ4y1K7r7视频属性的抓取
# BV号为1LQ4y1K7r7的视频属性抓取结束
# 开始BV号为1ip4y1C7Fw视频属性的抓取
# BV号为1ip4y1C7Fw的视频属性抓取结束
# 开始BV号为1F5411t7YJ视频属性的抓取
# BV号为1F5411t7YJ的视频属性抓取结束
# 开始BV号为1ne411s74K视频属性的抓取
# BV号为1ne411s74K的视频属性抓取结束
# 开始BV号为11V411f7qX视频属性的抓取
# BV号为11V411f7qX的视频属性抓取结束
# 开始BV号为11g4y1z7Lz视频属性的抓取
# BV号为11g4y1z7Lz的视频属性抓取结束
# 开始BV号为14z411b7u5视频属性的抓取
# BV号为14z411b7u5的视频属性抓取结束
# 开始BV号为1b5411t7ED视频属性的抓取
# BV号为1b5411t7ED的视频属性抓取结束
# 开始BV号为1mT4y1G7oT视频属性的抓取
# BV号为1mT4y1G7oT的视频属性抓取结束
# 开始BV号为1564y1M787视频属性的抓取
# BV号为1564y1M787的视频属性抓取结束
# 开始BV号为1LK4y1b7bb视频属性的抓取
# BV号为1LK4y1b7bb的视频属性抓取结束
# 开始BV号为19f4y1U7ab视频属性的抓取
# BV号为19f4y1U7ab的视频属性抓取结束
# 开始BV号为1LC4y1x7VP视频属性的抓取
# BV号为1LC4y1x7VP的视频属性抓取结束
# 开始BV号为1Jg4y1z7MB视频属性的抓取
# BV号为1Jg4y1z7MB的视频属性抓取结束
# 开始BV号为1LV411o7q9视频属性的抓取
# BV号为1LV411o7q9的视频属性抓取结束
# 开始BV号为1ra4y1t73D视频属性的抓取
# BV号为1ra4y1t73D的视频属性抓取结束
# 开始BV号为1MC4y1W7PG视频属性的抓取
# BV号为1MC4y1W7PG的视频属性抓取结束
# 开始BV号为1TQ4y1T7zm视频属性的抓取
# BV号为1TQ4y1T7zm的视频属性抓取结束
# 开始BV号为1Me41147Gm视频属性的抓取
# BV号为1Me41147Gm的视频属性抓取结束
# 开始BV号为1Pf4y1S78v视频属性的抓取
# BV号为1Pf4y1S78v的视频属性抓取结束
# 开始BV号为16C4y1s7h4视频属性的抓取
# BV号为16C4y1s7h4的视频属性抓取结束
# 开始BV号为1HK41157uU视频属性的抓取
# BV号为1HK41157uU的视频属性抓取结束
# 开始BV号为1iV411f7KD视频属性的抓取
# BV号为1iV411f7KD的视频属性抓取结束
# 开始BV号为1SA41187Ms视频属性的抓取
# BV号为1SA41187Ms的视频属性抓取结束
# 开始BV号为1mK411V7n7视频属性的抓取
# BV号为1mK411V7n7的视频属性抓取结束
# 开始BV号为1Bz411B7eg视频属性的抓取
# BV号为1Bz411B7eg的视频属性抓取结束
# 开始BV号为1dQ4y1K74b视频属性的抓取
# BV号为1dQ4y1K74b的视频属性抓取结束
# 开始BV号为1oC4y1p7jW视频属性的抓取
# BV号为1oC4y1p7jW的视频属性抓取结束
# 开始BV号为1664y1u7Y4视频属性的抓取
# BV号为1664y1u7Y4的视频属性抓取结束
# 开始BV号为1UC4y1p7Zk视频属性的抓取
# BV号为1UC4y1p7Zk的视频属性抓取结束
# 开始BV号为15Q4y1K7VA视频属性的抓取
# BV号为15Q4y1K7VA的视频属性抓取结束
# 开始BV号为1PV411Z71E视频属性的抓取
# BV号为1PV411Z71E的视频属性抓取结束
# 开始BV号为1TK4y1k7Ad视频属性的抓取
# BV号为1TK4y1k7Ad的视频属性抓取结束
# 开始BV号为1oC4y1p7G4视频属性的抓取
# BV号为1oC4y1p7G4的视频属性抓取结束
# 开始BV号为1HC4y1W7L4视频属性的抓取
# BV号为1HC4y1W7L4的视频属性抓取结束
# 开始BV号为1Az411876N视频属性的抓取
# BV号为1Az411876N的视频属性抓取结束
# 开始BV号为1N54y197E2视频属性的抓取
# BV号为1N54y197E2的视频属性抓取结束
# 开始BV号为1AZ4y1s7o3视频属性的抓取
# BV号为1AZ4y1s7o3的视频属性抓取结束
# 开始BV号为1Ct4y1m7ME视频属性的抓取
# BV号为1Ct4y1m7ME的视频属性抓取结束
# 开始BV号为1YV411o7uk视频属性的抓取
# BV号为1YV411o7uk的视频属性抓取结束
# 开始BV号为1yZ4y1x7ds视频属性的抓取
# BV号为1yZ4y1x7ds的视频属性抓取结束
# 开始BV号为1AK4y1k7Px视频属性的抓取
# BV号为1AK4y1k7Px的视频属性抓取结束
# 开始BV号为1U541167XB视频属性的抓取
# BV号为1U541167XB的视频属性抓取结束
# 开始BV号为11f4y1U7eD视频属性的抓取
# BV号为11f4y1U7eD的视频属性抓取结束
# 开始BV号为13C4y1s7yF视频属性的抓取
# BV号为13C4y1s7yF的视频属性抓取结束
# 开始BV号为1kk4y1d78b视频属性的抓取
# BV号为1kk4y1d78b的视频属性抓取结束
# 开始BV号为1Rg4y1b7vq视频属性的抓取
# BV号为1Rg4y1b7vq的视频属性抓取结束
# 开始BV号为16k4y1r7jU视频属性的抓取
# BV号为16k4y1r7jU的视频属性抓取结束
# 开始BV号为1dV411o7vJ视频属性的抓取
# BV号为1dV411o7vJ的视频属性抓取结束
# 开始BV号为1Fg4y167XH视频属性的抓取
# BV号为1Fg4y167XH的视频属性抓取结束
# 开始BV号为1At4y127Pu视频属性的抓取
# BV号为1At4y127Pu的视频属性抓取结束
# 开始BV号为1TQ4y1T7JW视频属性的抓取
# BV号为1TQ4y1T7JW的视频属性抓取结束
# 开始BV号为1xT4y15777视频属性的抓取
# BV号为1xT4y15777的视频属性抓取结束
# 开始BV号为1zV411o764视频属性的抓取
# BV号为1zV411o764的视频属性抓取结束
# 开始BV号为1bg4y187du视频属性的抓取
# BV号为1bg4y187du的视频属性抓取结束
# 开始BV号为127411U7bB视频属性的抓取
# BV号为127411U7bB的视频属性抓取结束
# 开始BV号为1e5411t7Yt视频属性的抓取
# BV号为1e5411t7Yt的视频属性抓取结束
# 开始BV号为1Yi4y147FG视频属性的抓取
# BV号为1Yi4y147FG的视频属性抓取结束
# 开始BV号为1VA411q79R视频属性的抓取
# BV号为1VA411q79R的视频属性抓取结束
# 开始BV号为1YK4y1t7bg视频属性的抓取
# BV号为1YK4y1t7bg的视频属性抓取结束
# 开始BV号为1Fi4y1t7yJ视频属性的抓取
# BV号为1Fi4y1t7yJ的视频属性抓取结束
# 开始BV号为1Da4y1e7Q8视频属性的抓取
# BV号为1Da4y1e7Q8的视频属性抓取结束
# 开始BV号为16A411q7TX视频属性的抓取
# BV号为16A411q7TX的视频属性抓取结束
# 开始BV号为1kZ4y1p73H视频属性的抓取
# BV号为1kZ4y1p73H的视频属性抓取结束
# 开始BV号为15a4y1i7Zb视频属性的抓取
# BV号为15a4y1i7Zb的视频属性抓取结束
# 开始BV号为1qZ4y1s7Ut视频属性的抓取
# BV号为1qZ4y1s7Ut的视频属性抓取结束
# 开始BV号为1bQ4y1N7aQ视频属性的抓取
# BV号为1bQ4y1N7aQ的视频属性抓取结束
# 开始BV号为1V54y1Q7G2视频属性的抓取
# BV号为1V54y1Q7G2的视频属性抓取结束
# 开始BV号为1QV411k7cB视频属性的抓取
# BV号为1QV411k7cB的视频属性抓取结束
# 开始BV号为13f4y127aF视频属性的抓取
# BV号为13f4y127aF的视频属性抓取结束
# 开始BV号为1yz411v7YK视频属性的抓取
# BV号为1yz411v7YK的视频属性抓取结束
# 开始BV号为1r5411x7Yc视频属性的抓取
# BV号为1r5411x7Yc的视频属性抓取结束
# 开始BV号为11p4y197EL视频属性的抓取
# BV号为11p4y197EL的视频属性抓取结束
# 开始BV号为1MA411q7zN视频属性的抓取
# BV号为1MA411q7zN的视频属性抓取结束
# 开始BV号为1nK411s7bM视频属性的抓取
# BV号为1nK411s7bM的视频属性抓取结束
# 开始BV号为1Xf4y1m752视频属性的抓取
# BV号为1Xf4y1m752的视频属性抓取结束
# 开始BV号为1Zk4y167gS视频属性的抓取
# BV号为1Zk4y167gS的视频属性抓取结束
# 开始BV号为1dK4y147aZ视频属性的抓取
# BV号为1dK4y147aZ的视频属性抓取结束
# 开始BV号为1Bp4y197vv视频属性的抓取
# BV号为1Bp4y197vv的视频属性抓取结束
# 开始BV号为1zv411z7VW视频属性的抓取
# BV号为1zv411z7VW的视频属性抓取结束
# 开始BV号为13k4y1r7sE视频属性的抓取
# BV号为13k4y1r7sE的视频属性抓取结束
# 开始BV号为1Hg4y1B7nB视频属性的抓取
# BV号为1Hg4y1B7nB的视频属性抓取结束
# 开始BV号为1iQ4y1A7SU视频属性的抓取
# BV号为1iQ4y1A7SU的视频属性抓取结束
# 开始BV号为11f4y1m74G视频属性的抓取
# BV号为11f4y1m74G的视频属性抓取结束
# 开始BV号为1Xz411v7WP视频属性的抓取
# BV号为1Xz411v7WP的视频属性抓取结束
# 开始BV号为1KZ4y1s7nt视频属性的抓取
# BV号为1KZ4y1s7nt的视频属性抓取结束
# 开始BV号为1gp4y1Q7Ts视频属性的抓取
# BV号为1gp4y1Q7Ts的视频属性抓取结束
# 开始BV号为1rg4y1B7tm视频属性的抓取
# BV号为1rg4y1B7tm的视频属性抓取结束
# 开始BV号为1fz411v7fD视频属性的抓取
# BV号为1fz411v7fD的视频属性抓取结束
# 开始BV号为12k4y167B3视频属性的抓取
# BV号为12k4y167B3的视频属性抓取结束
# 开始BV号为1Yp4y1Q7kN视频属性的抓取
# BV号为1Yp4y1Q7kN的视频属性抓取结束
# 开始BV号为1Cg4y1B7jB视频属性的抓取
# BV号为1Cg4y1B7jB的视频属性抓取结束
# 开始BV号为1rv411z7oh视频属性的抓取
# BV号为1rv411z7oh的视频属性抓取结束
# 开始BV号为1jz4y1R7YY视频属性的抓取
# BV号为1jz4y1R7YY的视频属性抓取结束
# 开始BV号为1bC4y1H7cp视频属性的抓取
# BV号为1bC4y1H7cp的视频属性抓取结束
# 开始BV号为1KC4y1W7eF视频属性的抓取
# BV号为1KC4y1W7eF的视频属性抓取结束
# 开始BV号为1av411z7vN视频属性的抓取
# BV号为1av411z7vN的视频属性抓取结束
# 开始BV号为1Qf4y1m7BZ视频属性的抓取
# BV号为1Qf4y1m7BZ的视频属性抓取结束
# 开始BV号为1Za4y1v7si视频属性的抓取
# BV号为1Za4y1v7si的视频属性抓取结束
# 开始BV号为1FK4y1b7BE视频属性的抓取
# BV号为1FK4y1b7BE的视频属性抓取结束
# 开始BV号为17K4y187eh视频属性的抓取
# BV号为17K4y187eh的视频属性抓取结束
# 开始BV号为1ep4y1Q7Sy视频属性的抓取
# BV号为1ep4y1Q7Sy的视频属性抓取结束
# 开始BV号为1ep4y1Q7jV视频属性的抓取
# BV号为1ep4y1Q7jV的视频属性抓取结束
# 开始BV号为1te411W7Hy视频属性的抓取
# BV号为1te411W7Hy的视频属性抓取结束
# 开始BV号为13g4y1B7qB视频属性的抓取
# BV号为13g4y1B7qB的视频属性抓取结束
# 开始BV号为1bt4y117dw视频属性的抓取
# BV号为1bt4y117dw的视频属性抓取结束
# 开始BV号为1G541147Xt视频属性的抓取
# BV号为1G541147Xt的视频属性抓取结束
# 开始BV号为1hi4y1s7qQ视频属性的抓取
# BV号为1hi4y1s7qQ的视频属性抓取结束
# 开始BV号为1ii4y147pb视频属性的抓取
# BV号为1ii4y147pb的视频属性抓取结束
# 开始BV号为1ae411p7N9视频属性的抓取
# BV号为1ae411p7N9的视频属性抓取结束
# 开始BV号为1qi4y1s7wM视频属性的抓取
# BV号为1qi4y1s7wM的视频属性抓取结束
# 开始BV号为1J541147ni视频属性的抓取
# BV号为1J541147ni的视频属性抓取结束
# 开始BV号为1G54y1Q7Bm视频属性的抓取
# BV号为1G54y1Q7Bm的视频属性抓取结束
# 开始BV号为1Wp4y1X7M8视频属性的抓取
# BV号为1Wp4y1X7M8的视频属性抓取结束
# 开始BV号为1gA411q7LU视频属性的抓取
# BV号为1gA411q7LU的视频属性抓取结束
# 开始BV号为1eT4y137CB视频属性的抓取
# BV号为1eT4y137CB的视频属性抓取结束
# 开始BV号为1zg4y1z7MD视频属性的抓取
# BV号为1zg4y1z7MD的视频属性抓取结束
# 开始BV号为1t541147Eb视频属性的抓取
# BV号为1t541147Eb的视频属性抓取结束
# 开始BV号为1Rt4y1y7Wu视频属性的抓取
# BV号为1Rt4y1y7Wu的视频属性抓取结束
# 开始BV号为1Rf4y117Fq视频属性的抓取
# BV号为1Rf4y117Fq的视频属性抓取结束
# 开始BV号为1QK4y1t7iA视频属性的抓取
# BV号为1QK4y1t7iA的视频属性抓取结束
# 开始BV号为1q54y1D72v视频属性的抓取
# BV号为1q54y1D72v的视频属性抓取结束
# 开始BV号为1tf4y1m7XW视频属性的抓取
# BV号为1tf4y1m7XW的视频属性抓取结束
# 开始BV号为1Hv411z77Y视频属性的抓取
# BV号为1Hv411z77Y的视频属性抓取结束
# 开始BV号为1qz411q7z8视频属性的抓取
# BV号为1qz411q7z8的视频属性抓取结束
# 开始BV号为1Fg4y1B7Zr视频属性的抓取
# BV号为1Fg4y1B7Zr的视频属性抓取结束
# 开始BV号为14z4y1R7QW视频属性的抓取
# BV号为14z4y1R7QW的视频属性抓取结束
# 开始BV号为11Z4y1W7xK视频属性的抓取
# BV号为11Z4y1W7xK的视频属性抓取结束
# 开始BV号为1FK411L7J3视频属性的抓取
# BV号为1FK411L7J3的视频属性抓取结束
# 开始BV号为1zv411z7Ea视频属性的抓取
# BV号为1zv411z7Ea的视频属性抓取结束
# 开始BV号为1mt4y1C7AL视频属性的抓取
# BV号为1mt4y1C7AL的视频属性抓取结束
# 开始BV号为1Bi4y1s7RN视频属性的抓取
# BV号为1Bi4y1s7RN的视频属性抓取结束
# 开始BV号为1Ef4y1U7yU视频属性的抓取
# BV号为1Ef4y1U7yU的视频属性抓取结束
# 开始BV号为1pC4y1p77J视频属性的抓取
# BV号为1pC4y1p77J的视频属性抓取结束
# 开始BV号为11z411v7F8视频属性的抓取
# BV号为11z411v7F8的视频属性抓取结束
# 开始BV号为1Jz4y1R77e视频属性的抓取
# BV号为1Jz4y1R77e的视频属性抓取结束
# 开始BV号为1Ea4y1i7rs视频属性的抓取
# BV号为1Ea4y1i7rs的视频属性抓取结束
# 开始BV号为1At4y1y7BB视频属性的抓取
# BV号为1At4y1y7BB的视频属性抓取结束
# 开始BV号为1RK411W75Q视频属性的抓取
# BV号为1RK411W75Q的视频属性抓取结束
# 开始BV号为14z4y1R7Na视频属性的抓取
# BV号为14z4y1R7Na的视频属性抓取结束
# 开始BV号为1sC4y1H7uA视频属性的抓取
# BV号为1sC4y1H7uA的视频属性抓取结束
# 开始BV号为1Vg4y1B7LK视频属性的抓取
# BV号为1Vg4y1B7LK的视频属性抓取结束
# 开始BV号为19t4y117Af视频属性的抓取
# BV号为19t4y117Af的视频属性抓取结束
# 开始BV号为1h541147jX视频属性的抓取
# BV号为1h541147jX的视频属性抓取结束
# 开始BV号为1SC4y1H7Z1视频属性的抓取
# BV号为1SC4y1H7Z1的视频属性抓取结束
# 开始BV号为1Bk4y167hp视频属性的抓取
# BV号为1Bk4y167hp的视频属性抓取结束
# 开始BV号为1Mp4y1Q7Nd视频属性的抓取
# BV号为1Mp4y1Q7Nd的视频属性抓取结束
# 开始BV号为1pT4y137a9视频属性的抓取
# BV号为1pT4y137a9的视频属性抓取结束
# 开始BV号为1Tz4y1d7vk视频属性的抓取
# BV号为1Tz4y1d7vk的视频属性抓取结束
# 开始BV号为1LK411s7ZR视频属性的抓取
# BV号为1LK411s7ZR的视频属性抓取结束
# 开始BV号为1o54y1D7rC视频属性的抓取
# BV号为1o54y1D7rC的视频属性抓取结束
# 开始BV号为13p4y1Q7ee视频属性的抓取
# BV号为13p4y1Q7ee的视频属性抓取结束
# 开始BV号为1Nt4y117dL视频属性的抓取
# BV号为1Nt4y117dL的视频属性抓取结束
# 开始BV号为1GC4y1p7u2视频属性的抓取
# BV号为1GC4y1p7u2的视频属性抓取结束
# 开始BV号为1yV411k7ry视频属性的抓取
# BV号为1yV411k7ry的视频属性抓取结束
# 开始BV号为12g4y1q7s6视频属性的抓取
# BV号为12g4y1q7s6的视频属性抓取结束
# 开始BV号为16A411i7E3视频属性的抓取
# BV号为16A411i7E3的视频属性抓取结束
# 开始BV号为17f4y127YZ视频属性的抓取
# BV号为17f4y127YZ的视频属性抓取结束
# 开始BV号为1gg4y1v7bm视频属性的抓取
# BV号为1gg4y1v7bm的视频属性抓取结束
# 开始BV号为1n54y1B7bE视频属性的抓取
# BV号为1n54y1B7bE的视频属性抓取结束
# 开始BV号为1CT4y1E7rf视频属性的抓取
# BV号为1CT4y1E7rf的视频属性抓取结束
# 开始BV号为1jV411k7Za视频属性的抓取
# BV号为1jV411k7Za的视频属性抓取结束
# 开始BV号为1Zk4y1B7bE视频属性的抓取
# BV号为1Zk4y1B7bE的视频属性抓取结束
# 开始BV号为1yv411B7Ga视频属性的抓取
# BV号为1yv411B7Ga的视频属性抓取结束
# 开始BV号为1xT4y1g7KZ视频属性的抓取
# BV号为1xT4y1g7KZ的视频属性抓取结束
# 开始BV号为1Q5411p766视频属性的抓取
# BV号为1Q5411p766的视频属性抓取结束
# 开始BV号为1zv411z73y视频属性的抓取
# BV号为1zv411z73y的视频属性抓取结束
# 开始BV号为1b54y1B799视频属性的抓取
# BV号为1b54y1B799的视频属性抓取结束
# 开始BV号为1NK4y147Wo视频属性的抓取
# BV号为1NK4y147Wo的视频属性抓取结束
# 开始BV号为16z4y197yc视频属性的抓取
# BV号为16z4y197yc的视频属性抓取结束
# 开始BV号为1yf4y1y7Bp视频属性的抓取
# BV号为1yf4y1y7Bp的视频属性抓取结束
# 开始BV号为1DD4y1D7L6视频属性的抓取
# BV号为1DD4y1D7L6的视频属性抓取结束
# 开始BV号为1KK411W7uW视频属性的抓取
# BV号为1KK411W7uW的视频属性抓取结束
# 开始BV号为1JT4y1J7hz视频属性的抓取
# BV号为1JT4y1J7hz的视频属性抓取结束
# 开始BV号为1V54y1B72a视频属性的抓取
# BV号为1V54y1B72a的视频属性抓取结束
# 开始BV号为1ut4y197bG视频属性的抓取
# BV号为1ut4y197bG的视频属性抓取结束
# 开始BV号为1kz4y197AH视频属性的抓取
# BV号为1kz4y197AH的视频属性抓取结束
# 开始BV号为1JD4y1S78a视频属性的抓取
# BV号为1JD4y1S78a的视频属性抓取结束
# 开始BV号为1BC4y1a72c视频属性的抓取
# BV号为1BC4y1a72c的视频属性抓取结束
# 开始BV号为15z411i7u6视频属性的抓取
# BV号为15z411i7u6的视频属性抓取结束
# 开始BV号为1qg4y1i73V视频属性的抓取
# BV号为1qg4y1i73V的视频属性抓取结束
# 开始BV号为1gK4y147wf视频属性的抓取
# BV号为1gK4y147wf的视频属性抓取结束
# 开始BV号为1hg4y1q7od视频属性的抓取
# BV号为1hg4y1q7od的视频属性抓取结束
# 开始BV号为1Bf4y117cY视频属性的抓取
# BV号为1Bf4y117cY的视频属性抓取结束
# 开始BV号为11z4y197sm视频属性的抓取
# BV号为11z4y197sm的视频属性抓取结束
# 开始BV号为1WZ4y1H7Jv视频属性的抓取
# BV号为1WZ4y1H7Jv的视频属性抓取结束
# 开始BV号为1s5411W7Hd视频属性的抓取
# BV号为1s5411W7Hd的视频属性抓取结束
# 开始BV号为19i4y1s7aV视频属性的抓取
# BV号为19i4y1s7aV的视频属性抓取结束
# 开始BV号为1jT4y1J77v视频属性的抓取
# BV号为1jT4y1J77v的视频属性抓取结束
# 开始BV号为1Ai4y1V7WX视频属性的抓取
# BV号为1Ai4y1V7WX的视频属性抓取结束
# 开始BV号为1Ma4y1e7uQ视频属性的抓取
# BV号为1Ma4y1e7uQ的视频属性抓取结束
# 开始BV号为1bk4y1q7ft视频属性的抓取
# BV号为1bk4y1q7ft的视频属性抓取结束
# 开始BV号为1WK411p7Xj视频属性的抓取
# BV号为1WK411p7Xj的视频属性抓取结束
# 开始BV号为1MV41167ut视频属性的抓取
# BV号为1MV41167ut的视频属性抓取结束
# 开始BV号为1Vk4y1z75i视频属性的抓取
# BV号为1Vk4y1z75i的视频属性抓取结束
# 开始BV号为19p4y1U7B4视频属性的抓取
# BV号为19p4y1U7B4的视频属性抓取结束
# 开始BV号为1gZ4y1H78s视频属性的抓取
# BV号为1gZ4y1H78s的视频属性抓取结束
# 开始BV号为19p4y1D7iX视频属性的抓取
# BV号为19p4y1D7iX的视频属性抓取结束
# 开始BV号为1ug4y1q7Y1视频属性的抓取
# BV号为1ug4y1q7Y1的视频属性抓取结束
# 开始BV号为16g4y1v7pJ视频属性的抓取
# BV号为16g4y1v7pJ的视频属性抓取结束
# 开始BV号为1954y1i7yP视频属性的抓取
# BV号为1954y1i7yP的视频属性抓取结束
# 开始BV号为18K411p7Wj视频属性的抓取
# BV号为18K411p7Wj的视频属性抓取结束
# 开始BV号为14g4y1q7aw视频属性的抓取
# BV号为14g4y1q7aw的视频属性抓取结束
# 开始BV号为1Tf4y1179J视频属性的抓取
# BV号为1Tf4y1179J的视频属性抓取结束
# 开始BV号为1vg4y1q7fj视频属性的抓取
# BV号为1vg4y1q7fj的视频属性抓取结束
# 开始BV号为1Bp4y1D747视频属性的抓取
# BV号为1Bp4y1D747的视频属性抓取结束
# 开始BV号为1Pv41167Wn视频属性的抓取
# BV号为1Pv41167Wn的视频属性抓取结束
# 开始BV号为1Gg4y1v73D视频属性的抓取
# BV号为1Gg4y1v73D的视频属性抓取结束
# 开始BV号为1rg4y1q7sK视频属性的抓取
# BV号为1rg4y1q7sK的视频属性抓取结束
# 开始BV号为1Zp4y1D7oq视频属性的抓取
# BV号为1Zp4y1D7oq的视频属性抓取结束
# 开始BV号为1iK4y1x7g7视频属性的抓取
# BV号为1iK4y1x7g7的视频属性抓取结束
# 开始BV号为18i4y1G7Rn视频属性的抓取
# BV号为18i4y1G7Rn的视频属性抓取结束
# 开始BV号为1wv41167pc视频属性的抓取
# BV号为1wv41167pc的视频属性抓取结束
# 开始BV号为1wt4y197yk视频属性的抓取
# BV号为1wt4y197yk的视频属性抓取结束
# 开始BV号为1Sz411e7iH视频属性的抓取
# BV号为1Sz411e7iH的视频属性抓取结束
# 开始BV号为19V411C7pu视频属性的抓取
# BV号为19V411C7pu的视频属性抓取结束
# 开始BV号为1cK411p7pp视频属性的抓取
# BV号为1cK411p7pp的视频属性抓取结束
# 开始BV号为165411W75q视频属性的抓取
# BV号为165411W75q的视频属性抓取结束
# 开始BV号为1754y1B7Xc视频属性的抓取
# BV号为1754y1B7Xc的视频属性抓取结束
# 开始BV号为1eD4y1Q7Ho视频属性的抓取
# BV号为1eD4y1Q7Ho的视频属性抓取结束
# 开始BV号为1FD4y1Q7Aw视频属性的抓取
# BV号为1FD4y1Q7Aw的视频属性抓取结束
# 开始BV号为1sD4y1D7tG视频属性的抓取
# BV号为1sD4y1D7tG的视频属性抓取结束
# 开始BV号为1Ea4y1v7mY视频属性的抓取
# BV号为1Ea4y1v7mY的视频属性抓取结束
# 开始BV号为1aC4y1a7ok视频属性的抓取
# BV号为1aC4y1a7ok的视频属性抓取结束
# 开始BV号为1e5411W7Ln视频属性的抓取
# BV号为1e5411W7Ln的视频属性抓取结束
# 开始BV号为1it4y1y7eo视频属性的抓取
# BV号为1it4y1y7eo的视频属性抓取结束
# 开始BV号为1KZ4y1u7v1视频属性的抓取
# BV号为1KZ4y1u7v1的视频属性抓取结束
# 开始BV号为1ZC4y1a7bx视频属性的抓取
# BV号为1ZC4y1a7bx的视频属性抓取结束
# 开始BV号为1LD4y1Q7zc视频属性的抓取
# BV号为1LD4y1Q7zc的视频属性抓取结束
# 开始BV号为1NZ4y1H7Ca视频属性的抓取
# BV号为1NZ4y1H7Ca的视频属性抓取结束
# 开始BV号为14g4y1v7kX视频属性的抓取
# BV号为14g4y1v7kX的视频属性抓取结束
# 开始BV号为1qf4y127wf视频属性的抓取
# BV号为1qf4y127wf的视频属性抓取结束
# 开始BV号为1ai4y1x7XB视频属性的抓取
# BV号为1ai4y1x7XB的视频属性抓取结束
# 开始BV号为1Ep4y1D74U视频属性的抓取
# BV号为1Ep4y1D74U的视频属性抓取结束
# 开始BV号为1EZ4y1H7HZ视频属性的抓取
# BV号为1EZ4y1H7HZ的视频属性抓取结束
# 开始BV号为16f4y1y7vp视频属性的抓取
# BV号为16f4y1y7vp的视频属性抓取结束
# 开始BV号为1Va4y1e7pz视频属性的抓取
# BV号为1Va4y1e7pz的视频属性抓取结束
# 开始BV号为1kC4y1a7Cd视频属性的抓取
# BV号为1kC4y1a7Cd的视频属性抓取结束
# 开始BV号为1CA411v7wZ视频属性的抓取
# BV号为1CA411v7wZ的视频属性抓取结束
# 开始BV号为1yk4y1z7iy视频属性的抓取
# BV号为1yk4y1z7iy的视频属性抓取结束
# 开始BV号为1Ei4y1G7nH视频属性的抓取
# BV号为1Ei4y1G7nH的视频属性抓取结束
# 开始BV号为1p54y1z7su视频属性的抓取
# BV号为1p54y1z7su的视频属性抓取结束
# 开始BV号为14V411r7Ps视频属性的抓取
# BV号为14V411r7Ps的视频属性抓取结束
# 开始BV号为1ot4y197xp视频属性的抓取
# BV号为1ot4y197xp的视频属性抓取结束
# 开始BV号为17v411B7ve视频属性的抓取
# BV号为17v411B7ve的视频属性抓取结束
# 开始BV号为1WZ4y1W76J视频属性的抓取
# BV号为1WZ4y1W76J的视频属性抓取结束
# 开始BV号为1iA411v721视频属性的抓取
# BV号为1iA411v721的视频属性抓取结束
# 开始BV号为1Fz411q7sn视频属性的抓取
# BV号为1Fz411q7sn的视频属性抓取结束
# 开始BV号为1ZK4y1t7su视频属性的抓取
# BV号为1ZK4y1t7su的视频属性抓取结束
# 开始BV号为15i4y1G7nL视频属性的抓取
# BV号为15i4y1G7nL的视频属性抓取结束
# 开始BV号为1aT4y1J7w2视频属性的抓取
# BV号为1aT4y1J7w2的视频属性抓取结束
# 开始BV号为1qg4y1i7Cd视频属性的抓取
# BV号为1qg4y1i7Cd的视频属性抓取结束
# 开始BV号为1yz4y1Q7vg视频属性的抓取
# BV号为1yz4y1Q7vg的视频属性抓取结束
# 开始BV号为1zT4y1E7ev视频属性的抓取
# BV号为1zT4y1E7ev的视频属性抓取结束
# 开始BV号为1tk4y1z7Jn视频属性的抓取
# BV号为1tk4y1z7Jn的视频属性抓取结束
# 开始BV号为11a4y1Y7aU视频属性的抓取
# BV号为11a4y1Y7aU的视频属性抓取结束
# 开始BV号为1Dk4y1q781视频属性的抓取
# BV号为1Dk4y1q781的视频属性抓取结束
# 开始BV号为1iV411z7Nj视频属性的抓取
# BV号为1iV411z7Nj的视频属性抓取结束
# 开始BV号为17g4y1v7Qn视频属性的抓取
# BV号为17g4y1v7Qn的视频属性抓取结束
# 开始BV号为1hK411H7bY视频属性的抓取
# BV号为1hK411H7bY的视频属性抓取结束
# 开始BV号为1vK411J7Xt视频属性的抓取
# BV号为1vK411J7Xt的视频属性抓取结束
# 开始BV号为1xC4y1b71f视频属性的抓取
# BV号为1xC4y1b71f的视频属性抓取结束
# 开始BV号为1qz4y1D7W3视频属性的抓取
# BV号为1qz4y1D7W3的视频属性抓取结束
# 开始BV号为12V41167ZL视频属性的抓取
# BV号为12V41167ZL的视频属性抓取结束
# 开始BV号为1Pf4y1d7gz视频属性的抓取
# BV号为1Pf4y1d7gz的视频属性抓取结束
# 开始BV号为1PK411n7Go视频属性的抓取
# BV号为1PK411n7Go的视频属性抓取结束
# 开始BV号为1RT4y177f6视频属性的抓取
# BV号为1RT4y177f6的视频属性抓取结束
# 开始BV号为1CK411H7zk视频属性的抓取
# BV号为1CK411H7zk的视频属性抓取结束
# 开始BV号为1Q5411Y7co视频属性的抓取
# BV号为1Q5411Y7co的视频属性抓取结束
# 开始BV号为1vK4y1v7NP视频属性的抓取
# BV号为1vK4y1v7NP的视频属性抓取结束
# 开始BV号为1bp4y1U7fo视频属性的抓取
# BV号为1bp4y1U7fo的视频属性抓取结束
# 开始BV号为1da4y1Y7sY视频属性的抓取
# BV号为1da4y1Y7sY的视频属性抓取结束
# 开始BV号为1Uz4y1X78v视频属性的抓取
# BV号为1Uz4y1X78v的视频属性抓取结束
# 开始BV号为1hC4y1h7yX视频属性的抓取
# BV号为1hC4y1h7yX的视频属性抓取结束
# 开始BV号为1UD4y1S7Pn视频属性的抓取
# BV号为1UD4y1S7Pn的视频属性抓取结束
# 开始BV号为16K4y147oQ视频属性的抓取
# BV号为16K4y147oQ的视频属性抓取结束
# 开始BV号为1eh411o7wx视频属性的抓取
# BV号为1eh411o7wx的视频属性抓取结束
# 开始BV号为1Bp4y1U71o视频属性的抓取
# BV号为1Bp4y1U71o的视频属性抓取结束
# 开始BV号为1RK411J7VV视频属性的抓取
# BV号为1RK411J7VV的视频属性抓取结束
# 开始BV号为17i4y137WG视频属性的抓取
# BV号为17i4y137WG的视频属性抓取结束
# 开始BV号为1cD4y1U7ff视频属性的抓取
# BV号为1cD4y1U7ff的视频属性抓取结束
# 开始BV号为1hV41167aU视频属性的抓取
# BV号为1hV41167aU的视频属性抓取结束
# 开始BV号为1eA411e7WB视频属性的抓取
# BV号为1eA411e7WB的视频属性抓取结束
# 开始BV号为1eK4y1s7xp视频属性的抓取
# BV号为1eK4y1s7xp的视频属性抓取结束
# 开始BV号为1GA411e77U视频属性的抓取
# BV号为1GA411e77U的视频属性抓取结束
# 开始BV号为1WZ4y1u7Bk视频属性的抓取
# BV号为1WZ4y1u7Bk的视频属性抓取结束
# 开始BV号为1VD4y1D7UB视频属性的抓取
# BV号为1VD4y1D7UB的视频属性抓取结束
# 开始BV号为1Hf4y1R7Cg视频属性的抓取
# BV号为1Hf4y1R7Cg的视频属性抓取结束
# 开始BV号为1jA411Y7KV视频属性的抓取
# BV号为1jA411Y7KV的视频属性抓取结束
# 开始BV号为1f5411h7MV视频属性的抓取
# BV号为1f5411h7MV的视频属性抓取结束
# 开始BV号为1jz4y1Q7jX视频属性的抓取
# BV号为1jz4y1Q7jX的视频属性抓取结束
# 开始BV号为1Pk4y1B7Ks视频属性的抓取
# BV号为1Pk4y1B7Ks的视频属性抓取结束
# 开始BV号为1MC4y1b7bV视频属性的抓取
# BV号为1MC4y1b7bV的视频属性抓取结束
# 开始BV号为1CT4y1j7Do视频属性的抓取
# BV号为1CT4y1j7Do的视频属性抓取结束
# 开始BV号为1ev411B7Lr视频属性的抓取
# BV号为1ev411B7Lr的视频属性抓取结束
# 开始BV号为1WZ4y1u7SX视频属性的抓取
# BV号为1WZ4y1u7SX的视频属性抓取结束
# 开始BV号为1hV41167t1视频属性的抓取
# BV号为1hV41167t1的视频属性抓取结束
# 开始BV号为1WZ4y1u7GK视频属性的抓取
# BV号为1WZ4y1u7GK的视频属性抓取结束
# 开始BV号为1pK4y1v7ew视频属性的抓取
# BV号为1pK4y1v7ew的视频属性抓取结束
# 开始BV号为14p4y1S7yv视频属性的抓取
# BV号为14p4y1S7yv的视频属性抓取结束
# 开始BV号为18A411i7TH视频属性的抓取
# BV号为18A411i7TH的视频属性抓取结束
# 开始BV号为1nD4y1D7g3视频属性的抓取
# BV号为1nD4y1D7g3的视频属性抓取结束
# 开始BV号为1iv411B79K视频属性的抓取
# BV号为1iv411B79K的视频属性抓取结束
# 开始BV号为1Ci4y137xJ视频属性的抓取
# BV号为1Ci4y137xJ的视频属性抓取结束
# 开始BV号为1Tv411z7eU视频属性的抓取
# BV号为1Tv411z7eU的视频属性抓取结束
# 开始BV号为1CA411i7Q9视频属性的抓取
# BV号为1CA411i7Q9的视频属性抓取结束
# 开始BV号为1F54y1q7Po视频属性的抓取
# BV号为1F54y1q7Po的视频属性抓取结束
# 开始BV号为15A411v7qm视频属性的抓取
# BV号为15A411v7qm的视频属性抓取结束
# 开始BV号为1rt4y197Dy视频属性的抓取
# BV号为1rt4y197Dy的视频属性抓取结束
# 开始BV号为17k4y1m7fL视频属性的抓取
# BV号为17k4y1m7fL的视频属性抓取结束
# 开始BV号为1b54y1q7VM视频属性的抓取
# BV号为1b54y1q7VM的视频属性抓取结束
# 开始BV号为1d54y1q7de视频属性的抓取
# BV号为1d54y1q7de的视频属性抓取结束
# 开始BV号为14a4y1a7tn视频属性的抓取
# BV号为14a4y1a7tn的视频属性抓取结束
# 开始BV号为1UV41167Gr视频属性的抓取
# BV号为1UV41167Gr的视频属性抓取结束
# 开始BV号为1KZ4y1g7vh视频属性的抓取
# BV号为1KZ4y1g7vh的视频属性抓取结束
# 开始BV号为1HK411H7zR视频属性的抓取
# BV号为1HK411H7zR的视频属性抓取结束
# 开始BV号为19i4y1G73k视频属性的抓取
# BV号为19i4y1G73k的视频属性抓取结束
# 开始BV号为1UK411J7re视频属性的抓取
# BV号为1UK411J7re的视频属性抓取结束
# 开始BV号为1EC4y1h7Wh视频属性的抓取
# BV号为1EC4y1h7Wh的视频属性抓取结束
# 开始BV号为18v411v77L视频属性的抓取
# BV号为18v411v77L的视频属性抓取结束
# 开始BV号为1Jg4y1i7CG视频属性的抓取
# BV号为1Jg4y1i7CG的视频属性抓取结束
# 开始BV号为1Zz411e7CF视频属性的抓取
# BV号为1Zz411e7CF的视频属性抓取结束
# 开始BV号为1QC4y187YH视频属性的抓取
# BV号为1QC4y187YH的视频属性抓取结束
# 开始BV号为15A411e7RD视频属性的抓取
# BV号为15A411e7RD的视频属性抓取结束
# 开始BV号为15t4y1X7kd视频属性的抓取
# BV号为15t4y1X7kd的视频属性抓取结束
# 开始BV号为1Ek4y1B7jU视频属性的抓取
# BV号为1Ek4y1B7jU的视频属性抓取结束
# 开始BV号为1Pv411z7WC视频属性的抓取
# BV号为1Pv411z7WC的视频属性抓取结束
# 开始BV号为1RK4y1s7eN视频属性的抓取
# BV号为1RK4y1s7eN的视频属性抓取结束
# 开始BV号为1Ht4y197Xk视频属性的抓取
# BV号为1Ht4y197Xk的视频属性抓取结束
# 开始BV号为1zh411o7Vn视频属性的抓取
# BV号为1zh411o7Vn的视频属性抓取结束
# 开始BV号为1nC4y1b7ns视频属性的抓取
# BV号为1nC4y1b7ns的视频属性抓取结束
# 开始BV号为1sg4y1v7ug视频属性的抓取
# BV号为1sg4y1v7ug的视频属性抓取结束
# 开始BV号为14k4y1q7gg视频属性的抓取
# BV号为14k4y1q7gg的视频属性抓取结束
# 开始BV号为1AT4y1j7P4视频属性的抓取
# BV号为1AT4y1j7P4的视频属性抓取结束
# 开始BV号为1ta4y1a7kr视频属性的抓取
# BV号为1ta4y1a7kr的视频属性抓取结束
# 开始BV号为16K411J7ss视频属性的抓取
# BV号为16K411J7ss的视频属性抓取结束
# 开始BV号为1qz4y1D7TH视频属性的抓取
# BV号为1qz4y1D7TH的视频属性抓取结束
# 开始BV号为11z4y1D7yx视频属性的抓取
# BV号为11z4y1D7yx的视频属性抓取结束
# 开始BV号为17Z4y1u76s视频属性的抓取
# BV号为17Z4y1u76s的视频属性抓取结束
# 开始BV号为11z4y1X7Yb视频属性的抓取
# BV号为11z4y1X7Yb的视频属性抓取结束
# 开始BV号为19v411i7hC视频属性的抓取
# BV号为19v411i7hC的视频属性抓取结束
# 开始BV号为1q54y1q79w视频属性的抓取
# BV号为1q54y1q79w的视频属性抓取结束
# 开始BV号为1DV411B7Jk视频属性的抓取
# BV号为1DV411B7Jk的视频属性抓取结束
# 开始BV号为15i4y137GX视频属性的抓取
# BV号为15i4y137GX的视频属性抓取结束
# 开始BV号为1Qa4y1a78b视频属性的抓取
# BV号为1Qa4y1a78b的视频属性抓取结束
# 开始BV号为1Kf4y1d7YQ视频属性的抓取
# BV号为1Kf4y1d7YQ的视频属性抓取结束
# 开始BV号为13f4y1d7Rd视频属性的抓取
# BV号为13f4y1d7Rd的视频属性抓取结束
# 开始BV号为1Qt4y1Q7uG视频属性的抓取
# BV号为1Qt4y1Q7uG的视频属性抓取结束
# 开始BV号为1MC4y1h77B视频属性的抓取
# BV号为1MC4y1h77B的视频属性抓取结束
# 开始BV号为1Gg4y1v7jR视频属性的抓取
# BV号为1Gg4y1v7jR的视频属性抓取结束
# 开始BV号为1qf4y1R7mD视频属性的抓取
# BV号为1qf4y1R7mD的视频属性抓取结束
# 开始BV号为1ah411Z7Zc视频属性的抓取
# BV号为1ah411Z7Zc的视频属性抓取结束
# 开始BV号为1Xt4y197Ed视频属性的抓取
# BV号为1Xt4y197Ed的视频属性抓取结束
# 开始BV号为1Pz4y1Q7xe视频属性的抓取
# BV号为1Pz4y1Q7xe的视频属性抓取结束
# 开始BV号为1aK411H7hc视频属性的抓取
# BV号为1aK411H7hc的视频属性抓取结束
# 开始BV号为1ea4y1a7yV视频属性的抓取
# BV号为1ea4y1a7yV的视频属性抓取结束
# 开始BV号为1r54y1m7gd视频属性的抓取
# BV号为1r54y1m7gd的视频属性抓取结束
# 开始BV号为1aD4y1U7Bc视频属性的抓取
# BV号为1aD4y1U7Bc的视频属性抓取结束
# 开始BV号为12t4y1U7yD视频属性的抓取
# BV号为12t4y1U7yD的视频属性抓取结束
# 开始BV号为1hh411d7DM视频属性的抓取
# BV号为1hh411d7DM的视频属性抓取结束
# 开始BV号为1z54y1e784视频属性的抓取
# BV号为1z54y1e784的视频属性抓取结束
# 开始BV号为1Rp4y1v71J视频属性的抓取
# BV号为1Rp4y1v71J的视频属性抓取结束
# 开始BV号为18C4y1t7qn视频属性的抓取
# BV号为18C4y1t7qn的视频属性抓取结束
# 开始BV号为1Wp4y1q7MM视频属性的抓取
# BV号为1Wp4y1q7MM的视频属性抓取结束
# 开始BV号为1Sv411y7d8视频属性的抓取
# BV号为1Sv411y7d8的视频属性抓取结束
# 开始BV号为1of4y1Q7h3视频属性的抓取
# BV号为1of4y1Q7h3的视频属性抓取结束
# 开始BV号为1ah411d74w视频属性的抓取
# BV号为1ah411d74w的视频属性抓取结束
# 开始BV号为1bp4y1v7FU视频属性的抓取
# BV号为1bp4y1v7FU的视频属性抓取结束
# 开始BV号为1cK411M7pq视频属性的抓取
# BV号为1cK411M7pq的视频属性抓取结束
# 开始BV号为1Pf4y1X7cx视频属性的抓取
# BV号为1Pf4y1X7cx的视频属性抓取结束
# 开始BV号为1154y1S748视频属性的抓取
# BV号为1154y1S748的视频属性抓取结束
# 开始BV号为1mC4y1b7LC视频属性的抓取
# BV号为1mC4y1b7LC的视频属性抓取结束
# 开始BV号为1DK4y1v7uq视频属性的抓取
# BV号为1DK4y1v7uq的视频属性抓取结束
# 开始BV号为1z54y1U74k视频属性的抓取
# BV号为1z54y1U74k的视频属性抓取结束
# 开始BV号为1XZ4y1T79p视频属性的抓取
# BV号为1XZ4y1T79p的视频属性抓取结束
# 开始BV号为1XC4y147Hr视频属性的抓取
# BV号为1XC4y147Hr的视频属性抓取结束
# 开始BV号为1CA411n7CY视频属性的抓取
# BV号为1CA411n7CY的视频属性抓取结束
# 开始BV号为16f4y1Q7nS视频属性的抓取
# BV号为16f4y1Q7nS的视频属性抓取结束
# 开始BV号为1p5411h7Fm视频属性的抓取
# BV号为1p5411h7Fm的视频属性抓取结束
# 开始BV号为1vi4y1M7HX视频属性的抓取
# BV号为1vi4y1M7HX的视频属性抓取结束
# 开始BV号为1nD4y1U7Z7视频属性的抓取
# BV号为1nD4y1U7Z7的视频属性抓取结束
# 开始BV号为1fv411y7YY视频属性的抓取
# BV号为1fv411y7YY的视频属性抓取结束
# 开始BV号为1SZ4y1K73Q视频属性的抓取
# BV号为1SZ4y1K73Q的视频属性抓取结束
# 开始BV号为1yZ4y1M7iE视频属性的抓取
# BV号为1yZ4y1M7iE的视频属性抓取结束
# 开始BV号为1dV411U797视频属性的抓取
# BV号为1dV411U797的视频属性抓取结束
# 开始BV号为1ya4y1J7JR视频属性的抓取
# BV号为1ya4y1J7JR的视频属性抓取结束
# 开始BV号为1et4y1S74Z视频属性的抓取
# BV号为1et4y1S74Z的视频属性抓取结束
# 开始BV号为1Tv41117MT视频属性的抓取
# BV号为1Tv41117MT的视频属性抓取结束
# 开始BV号为1MZ4y1M7Xk视频属性的抓取
# BV号为1MZ4y1M7Xk的视频属性抓取结束
# 开始BV号为1yf4y1Q7db视频属性的抓取
# BV号为1yf4y1Q7db的视频属性抓取结束
# 开始BV号为1JK4y1e7Ue视频属性的抓取
# BV号为1JK4y1e7Ue的视频属性抓取结束
# 开始BV号为1Kh411o7BG视频属性的抓取
# BV号为1Kh411o7BG的视频属性抓取结束
# 开始BV号为1164y1c7ri视频属性的抓取
# BV号为1164y1c7ri的视频属性抓取结束
# 开始BV号为1Hp4y1q7yf视频属性的抓取
# BV号为1Hp4y1q7yf的视频属性抓取结束
# 开始BV号为1VK411T7Zq视频属性的抓取
# BV号为1VK411T7Zq的视频属性抓取结束
# 开始BV号为1cv411i7m7视频属性的抓取
# BV号为1cv411i7m7的视频属性抓取结束
# 开始BV号为1p64y1c711视频属性的抓取
# BV号为1p64y1c711的视频属性抓取结束
# 开始BV号为1z64y1c7Ca视频属性的抓取
# BV号为1z64y1c7Ca的视频属性抓取结束
# 开始BV号为1Zi4y137qH视频属性的抓取
# BV号为1Zi4y137qH的视频属性抓取结束
# 开始BV号为11K411N7rG视频属性的抓取
# BV号为11K411N7rG的视频属性抓取结束
# 开始BV号为1ct4y1S7FD视频属性的抓取
# BV号为1ct4y1S7FD的视频属性抓取结束
# 开始BV号为1R64y1F7rs视频属性的抓取
# BV号为1R64y1F7rs的视频属性抓取结束
# 开始BV号为1GV411S7Cb视频属性的抓取
# BV号为1GV411S7Cb的视频属性抓取结束
# 开始BV号为1ha4y1J7hf视频属性的抓取
# BV号为1ha4y1J7hf的视频属性抓取结束
# 开始BV号为16T4y157Tt视频属性的抓取
# BV号为16T4y157Tt的视频属性抓取结束
# 开始BV号为1wa4y1J7V9视频属性的抓取
# BV号为1wa4y1J7V9的视频属性抓取结束
# 开始BV号为1wt4y1Q7Ri视频属性的抓取
# BV号为1wt4y1Q7Ri的视频属性抓取结束
# 开始BV号为1XC4y1t7fV视频属性的抓取
# BV号为1XC4y1t7fV的视频属性抓取结束
# 开始BV号为1Za4y1E7Xn视频属性的抓取
# BV号为1Za4y1E7Xn的视频属性抓取结束
# 开始BV号为1MK4y1v7qp视频属性的抓取
# BV号为1MK4y1v7qp的视频属性抓取结束
# 开始BV号为1aD4y127GE视频属性的抓取
# BV号为1aD4y127GE的视频属性抓取结束
# 开始BV号为1H64y1c7uy视频属性的抓取
# BV号为1H64y1c7uy的视频属性抓取结束
# 开始BV号为1HK411T7H1视频属性的抓取
# BV号为1HK411T7H1的视频属性抓取结束
# 开始BV号为1bK4y1v7rH视频属性的抓取
# BV号为1bK4y1v7rH的视频属性抓取结束
# 开始BV号为1aT4y1L72i视频属性的抓取
# BV号为1aT4y1L72i的视频属性抓取结束
# 开始BV号为1JD4y1U77h视频属性的抓取
# BV号为1JD4y1U77h的视频属性抓取结束
# 开始BV号为1Xz4y1f7s1视频属性的抓取
# BV号为1Xz4y1f7s1的视频属性抓取结束
# 开始BV号为1Da4y177NQ视频属性的抓取
# BV号为1Da4y177NQ的视频属性抓取结束
# 开始BV号为1SZ4y1K7Lr视频属性的抓取
# BV号为1SZ4y1K7Lr的视频属性抓取结束
# 开始BV号为1vC4y1t7NX视频属性的抓取
# BV号为1vC4y1t7NX的视频属性抓取结束
# 开始BV号为1C54y1i7Ss视频属性的抓取
# BV号为1C54y1i7Ss的视频属性抓取结束
# 开始BV号为11Z4y1K7pL视频属性的抓取
# BV号为11Z4y1K7pL的视频属性抓取结束
# 开始BV号为1b54y127wz视频属性的抓取
# BV号为1b54y127wz的视频属性抓取结束
# 开始BV号为1D54y1m7Av视频属性的抓取
# BV号为1D54y1m7Av的视频属性抓取结束
# 开始BV号为1tk4y127Ms视频属性的抓取
# BV号为1tk4y127Ms的视频属性抓取结束
# 开始BV号为1Xi4y1u7jY视频属性的抓取
# BV号为1Xi4y1u7jY的视频属性抓取结束
# 开始BV号为1WD4y1U72F视频属性的抓取
# BV号为1WD4y1U72F的视频属性抓取结束
# 开始BV号为1EK411K7NH视频属性的抓取
# BV号为1EK411K7NH的视频属性抓取结束
# 开始BV号为1oD4y1U7YX视频属性的抓取
# BV号为1oD4y1U7YX的视频属性抓取结束
# 开始BV号为1L5411b7eB视频属性的抓取
# BV号为1L5411b7eB的视频属性抓取结束
# 开始BV号为16T4y1j7wG视频属性的抓取
# BV号为16T4y1j7wG的视频属性抓取结束
# 开始BV号为1xT4y1L7pL视频属性的抓取
# BV号为1xT4y1L7pL的视频属性抓取结束
# 开始BV号为1df4y1X7kY视频属性的抓取
# BV号为1df4y1X7kY的视频属性抓取结束
# 开始BV号为1Wi4y1g7nv视频属性的抓取
# BV号为1Wi4y1g7nv的视频属性抓取结束
# 开始BV号为1V64y1F7zf视频属性的抓取
# BV号为1V64y1F7zf的视频属性抓取结束
# 开始BV号为12T4y1w7JM视频属性的抓取
# BV号为12T4y1w7JM的视频属性抓取结束
# 开始BV号为1ri4y1M76R视频属性的抓取
# BV号为1ri4y1M76R的视频属性抓取结束
# 开始BV号为1Fh411o77J视频属性的抓取
# BV号为1Fh411o77J的视频属性抓取结束
# 开始BV号为1n5411b7ze视频属性的抓取
# BV号为1n5411b7ze的视频属性抓取结束
# 开始BV号为1XK4y1v7U1视频属性的抓取
# BV号为1XK4y1v7U1的视频属性抓取结束
# 开始BV号为1QC4y1b7eY视频属性的抓取
# BV号为1QC4y1b7eY的视频属性抓取结束
# 开始BV号为1R64y1c7m2视频属性的抓取
# BV号为1R64y1c7m2的视频属性抓取结束
# 开始BV号为1zi4y1u7Z5视频属性的抓取
# BV号为1zi4y1u7Z5的视频属性抓取结束
# 开始BV号为13A411e7T8视频属性的抓取
# BV号为13A411e7T8的视频属性抓取结束
# 开始BV号为1954y1m7nk视频属性的抓取
# BV号为1954y1m7nk的视频属性抓取结束
# 开始BV号为1h5411a71z视频属性的抓取
# BV号为1h5411a71z的视频属性抓取结束
# 开始BV号为19i4y137xR视频属性的抓取
# BV号为19i4y137xR的视频属性抓取结束
# 开始BV号为1PK411M7uq视频属性的抓取
# BV号为1PK411M7uq的视频属性抓取结束
# 开始BV号为1p54y1U7vC视频属性的抓取
# BV号为1p54y1U7vC的视频属性抓取结束
# 开始BV号为1Ph411d78o视频属性的抓取
# BV号为1Ph411d78o的视频属性抓取结束
# 开始BV号为1J5411h7Ke视频属性的抓取
# BV号为1J5411h7Ke的视频属性抓取结束
# 开始BV号为1P54y1v7Bb视频属性的抓取
# BV号为1P54y1v7Bb的视频属性抓取结束
# 开始BV号为1u5411h7vg视频属性的抓取
# BV号为1u5411h7vg的视频属性抓取结束
# 开始BV号为1Gp4y1v7yh视频属性的抓取
# BV号为1Gp4y1v7yh的视频属性抓取结束
# 开始BV号为1bK4y1Y74e视频属性的抓取
# BV号为1bK4y1Y74e的视频属性抓取结束
# 开始BV号为1bK4y1e7Bd视频属性的抓取
# BV号为1bK4y1e7Bd的视频属性抓取结束
# 开始BV号为1NA411J7DW视频属性的抓取
# BV号为1NA411J7DW的视频属性抓取结束
# 开始BV号为1r54y127Tc视频属性的抓取
# BV号为1r54y127Tc的视频属性抓取结束
# 开始BV号为1q5411b7UX视频属性的抓取
# BV号为1q5411b7UX的视频属性抓取结束
# 开始BV号为1yi4y177aw视频属性的抓取
# BV号为1yi4y177aw的视频属性抓取结束
# 开始BV号为1rv41117Pb视频属性的抓取
# BV号为1rv41117Pb的视频属性抓取结束
# 开始BV号为12t4y1i7xS视频属性的抓取
# BV号为12t4y1i7xS的视频属性抓取结束
# 开始BV号为17a4y1E79R视频属性的抓取
# BV号为17a4y1E79R的视频属性抓取结束
# 开始BV号为13a4y1j7A7视频属性的抓取
# BV号为13a4y1j7A7的视频属性抓取结束
# 开始BV号为1y54y117kS视频属性的抓取
# BV号为1y54y117kS的视频属性抓取结束
# 开始BV号为1yT4y1A7j6视频属性的抓取
# BV号为1yT4y1A7j6的视频属性抓取结束
# 开始BV号为1vK4y1e7A6视频属性的抓取
# BV号为1vK4y1e7A6的视频属性抓取结束
# 开始BV号为1EZ4y1T7tp视频属性的抓取
# BV号为1EZ4y1T7tp的视频属性抓取结束
# 开始BV号为1eK4y1a7oS视频属性的抓取
# BV号为1eK4y1a7oS的视频属性抓取结束
# 开始BV号为1n54y1m7b7视频属性的抓取
# BV号为1n54y1m7b7的视频属性抓取结束
# 开始BV号为1FT4y1A7nm视频属性的抓取
# BV号为1FT4y1A7nm的视频属性抓取结束
# 开始BV号为1854y127NE视频属性的抓取
# BV号为1854y127NE的视频属性抓取结束
# 开始BV号为1mt4y1S7JS视频属性的抓取
# BV号为1mt4y1S7JS的视频属性抓取结束
# 开始BV号为1aK4y1e7ig视频属性的抓取
# BV号为1aK4y1e7ig的视频属性抓取结束
# 开始BV号为1T54y1m7Xv视频属性的抓取
# BV号为1T54y1m7Xv的视频属性抓取结束
# 开始BV号为17a4y1j7AD视频属性的抓取
# BV号为17a4y1j7AD的视频属性抓取结束
# 开始BV号为12V41127Fz视频属性的抓取
# BV号为12V41127Fz的视频属性抓取结束
# 开始BV号为1dt4y1S7J9视频属性的抓取
# BV号为1dt4y1S7J9的视频属性抓取结束
# 开始BV号为1j64y1F7dN视频属性的抓取
# BV号为1j64y1F7dN的视频属性抓取结束
# 开始BV号为1Qt4y1i75Y视频属性的抓取
# BV号为1Qt4y1i75Y的视频属性抓取结束
# 开始BV号为1nt4y1q7TZ视频属性的抓取
# BV号为1nt4y1q7TZ的视频属性抓取结束
# 开始BV号为1X54y1y7RD视频属性的抓取
# BV号为1X54y1y7RD的视频属性抓取结束
# 开始BV号为1L54y1y7BD视频属性的抓取
# BV号为1L54y1y7BD的视频属性抓取结束
# 开始BV号为1mA411E7kt视频属性的抓取
# BV号为1mA411E7kt的视频属性抓取结束
# 开始BV号为1AA411J76L视频属性的抓取
# BV号为1AA411J76L的视频属性抓取结束
# 开始BV号为1Uh41197g5视频属性的抓取
# BV号为1Uh41197g5的视频属性抓取结束
# 开始BV号为1WT4y1c7Qm视频属性的抓取
# BV号为1WT4y1c7Qm的视频属性抓取结束
# 开始BV号为1oa4y1777T视频属性的抓取
# BV号为1oa4y1777T的视频属性抓取结束
# 开始BV号为12t4y1i77Z视频属性的抓取
# BV号为12t4y1i77Z的视频属性抓取结束
# 开始BV号为13D4y1o7iY视频属性的抓取
# BV号为13D4y1o7iY的视频属性抓取结束
# 开始BV号为1Ft4y1q7s7视频属性的抓取
# BV号为1Ft4y1q7s7的视频属性抓取结束
# 开始BV号为1RV41127kT视频属性的抓取
# BV号为1RV41127kT的视频属性抓取结束
# 开始BV号为1bA411J7BE视频属性的抓取
# BV号为1bA411J7BE的视频属性抓取结束
# 开始BV号为1Rp4y1e7vq视频属性的抓取
# BV号为1Rp4y1e7vq的视频属性抓取结束
# 开始BV号为1nz4y1Z7oc视频属性的抓取
# BV号为1nz4y1Z7oc的视频属性抓取结束
# 开始BV号为1i5411b7JU视频属性的抓取
# BV号为1i5411b7JU的视频属性抓取结束
# 开始BV号为1yV41117FP视频属性的抓取
# BV号为1yV41117FP的视频属性抓取结束
# 开始BV号为1zK4y1a7yN视频属性的抓取
# BV号为1zK4y1a7yN的视频属性抓取结束
# 开始BV号为1Wi4y1u7UU视频属性的抓取
# BV号为1Wi4y1u7UU的视频属性抓取结束
# 开始BV号为17z4y1Z7fZ视频属性的抓取
# BV号为17z4y1Z7fZ的视频属性抓取结束
# 开始BV号为1Af4y1D7ve视频属性的抓取
# BV号为1Af4y1D7ve的视频属性抓取结束
# 开始BV号为1zi4y1M7Bu视频属性的抓取
# BV号为1zi4y1M7Bu的视频属性抓取结束
# 开始BV号为1at4y1q7Hn视频属性的抓取
# BV号为1at4y1q7Hn的视频属性抓取结束
# 开始BV号为1FA411H79J视频属性的抓取
# BV号为1FA411H79J的视频属性抓取结束
# 开始BV号为1KZ4y1K7YV视频属性的抓取
# BV号为1KZ4y1K7YV的视频属性抓取结束
# 开始BV号为1tK411N7C8视频属性的抓取
# BV号为1tK411N7C8的视频属性抓取结束
# 开始BV号为1j54118762视频属性的抓取
# BV号为1j54118762的视频属性抓取结束
# 开始BV号为1E54y1v74U视频属性的抓取
# BV号为1E54y1v74U的视频属性抓取结束
# 开始BV号为1ZK4y1h7Tv视频属性的抓取
# BV号为1ZK4y1h7Tv的视频属性抓取结束
# 开始BV号为1UZ4y1N78t视频属性的抓取
# BV号为1UZ4y1N78t的视频属性抓取结束
# 开始BV号为1zi4y1M7BM视频属性的抓取
# BV号为1zi4y1M7BM的视频属性抓取结束
# 开始BV号为16D4y1o7kC视频属性的抓取
# BV号为16D4y1o7kC的视频属性抓取结束
# 开始BV号为1D54y127XG视频属性的抓取
# BV号为1D54y127XG的视频属性抓取结束
# 开始BV号为1Rh411R7GW视频属性的抓取
# BV号为1Rh411R7GW的视频属性抓取结束
# 开始BV号为1FK4y1Y7FD视频属性的抓取
# BV号为1FK4y1Y7FD的视频属性抓取结束
# 开始BV号为1Pi4y1u7Ht视频属性的抓取
# BV号为1Pi4y1u7Ht的视频属性抓取结束
# 开始BV号为1bt4y1S779视频属性的抓取
# BV号为1bt4y1S779的视频属性抓取结束
# 开始BV号为1Q54y1y7Ra视频属性的抓取
# BV号为1Q54y1y7Ra的视频属性抓取结束
# 开始BV号为1wZ4y1T7Uz视频属性的抓取
# BV号为1wZ4y1T7Uz的视频属性抓取结束
# 开始BV号为1rh411R76i视频属性的抓取
# BV号为1rh411R76i的视频属性抓取结束
# 开始BV号为19D4y1d7wf视频属性的抓取
# BV号为19D4y1d7wf的视频属性抓取结束
# 开始BV号为1CK411N7kd视频属性的抓取
# BV号为1CK411N7kd的视频属性抓取结束
# 开始BV号为1gV411S7oQ视频属性的抓取
# BV号为1gV411S7oQ的视频属性抓取结束
# 开始BV号为1mh411R7QN视频属性的抓取
# BV号为1mh411R7QN的视频属性抓取结束
# 开始BV号为16a4y1j7Ae视频属性的抓取
# BV号为16a4y1j7Ae的视频属性抓取结束
# 开始BV号为1g54y1v7ui视频属性的抓取
# BV号为1g54y1v7ui的视频属性抓取结束
# 开始BV号为1Qh41197th视频属性的抓取
# BV号为1Qh41197th的视频属性抓取结束
# 开始BV号为1rK4y1a7bE视频属性的抓取
# BV号为1rK4y1a7bE的视频属性抓取结束
# 开始BV号为1hf4y1D74x视频属性的抓取
# BV号为1hf4y1D74x的视频属性抓取结束
# 开始BV号为15D4y1o7YN视频属性的抓取
# BV号为15D4y1o7YN的视频属性抓取结束
# 开始BV号为1Ay4y1y7cB视频属性的抓取
# BV号为1Ay4y1y7cB的视频属性抓取结束
# 开始BV号为1PV411S7aB视频属性的抓取
# BV号为1PV411S7aB的视频属性抓取结束
# 开始BV号为1g54y1y77B视频属性的抓取
# BV号为1g54y1y77B的视频属性抓取结束
# 开始BV号为1bk4y127id视频属性的抓取
# BV号为1bk4y127id的视频属性抓取结束
# 开始BV号为1LZ4y1N7Wu视频属性的抓取
# BV号为1LZ4y1N7Wu的视频属性抓取结束
# 开始BV号为1YV411m7d9视频属性的抓取
# BV号为1YV411m7d9的视频属性抓取结束
# 开始BV号为1ua4y1E7uf视频属性的抓取
# BV号为1ua4y1E7uf的视频属性抓取结束
# 开始BV号为1354y1179q视频属性的抓取
# BV号为1354y1179q的视频属性抓取结束
# 开始BV号为19z4y1Z7ad视频属性的抓取
# BV号为19z4y1Z7ad的视频属性抓取结束
# 开始BV号为19i4y177xg视频属性的抓取
# BV号为19i4y177xg的视频属性抓取结束
# 开始BV号为1Dp4y1Y79t视频属性的抓取
# BV号为1Dp4y1Y79t的视频属性抓取结束
# 开始BV号为1Y54y1279x视频属性的抓取
# BV号为1Y54y1279x的视频属性抓取结束
# 开始BV号为1Gt4y1q7Q9视频属性的抓取
# BV号为1Gt4y1q7Q9的视频属性抓取结束
# 开始BV号为1Uh411R7PJ视频属性的抓取
# BV号为1Uh411R7PJ的视频属性抓取结束
# 开始BV号为1Zz4y1f7i5视频属性的抓取
# BV号为1Zz4y1f7i5的视频属性抓取结束
# 开始BV号为1oC4y1t7H6视频属性的抓取
# BV号为1oC4y1t7H6的视频属性抓取结束
# 开始BV号为1nD4y1m7Bb视频属性的抓取
# BV号为1nD4y1m7Bb的视频属性抓取结束
# 开始BV号为1zV411m7kV视频属性的抓取
# BV号为1zV411m7kV的视频属性抓取结束
# 开始BV号为14V41117Pm视频属性的抓取
# BV号为14V41117Pm的视频属性抓取结束
# 开始BV号为11v41117SZ视频属性的抓取
# BV号为11v41117SZ的视频属性抓取结束
# 开始BV号为1zt4y1i7kb视频属性的抓取
# BV号为1zt4y1i7kb的视频属性抓取结束
# 开始BV号为1qV41117yR视频属性的抓取
# BV号为1qV41117yR的视频属性抓取结束
# 开始BV号为1Gf4y1D7Mr视频属性的抓取
# BV号为1Gf4y1D7Mr的视频属性抓取结束
# 开始BV号为1KA411H777视频属性的抓取
# BV号为1KA411H777的视频属性抓取结束
# 开始BV号为1hz4y1Z7YB视频属性的抓取
# BV号为1hz4y1Z7YB的视频属性抓取结束
# 开始BV号为1RV411m7Yp视频属性的抓取
# BV号为1RV411m7Yp的视频属性抓取结束
# 开始BV号为1nr4y1w7NW视频属性的抓取
# BV号为1nr4y1w7NW的视频属性抓取结束
# 开始BV号为1HV411y7sK视频属性的抓取
# BV号为1HV411y7sK的视频属性抓取结束
# 开始BV号为1Gt4y1i7By视频属性的抓取
# BV号为1Gt4y1i7By的视频属性抓取结束
# 开始BV号为1P541177XQ视频属性的抓取
# BV号为1P541177XQ的视频属性抓取结束
# 开始BV号为1fa411A7w1视频属性的抓取
# BV号为1fa411A7w1的视频属性抓取结束
# 开始BV号为1q5411j7rW视频属性的抓取
# BV号为1q5411j7rW的视频属性抓取结束
# 开始BV号为1K5411L7pV视频属性的抓取
# BV号为1K5411L7pV的视频属性抓取结束
# 开始BV号为1Lt4y1i73d视频属性的抓取
# BV号为1Lt4y1i73d的视频属性抓取结束
# 开始BV号为1xy4y1B7Ci视频属性的抓取
# BV号为1xy4y1B7Ci的视频属性抓取结束
# 开始BV号为1XK4y187FP视频属性的抓取
# BV号为1XK4y187FP的视频属性抓取结束
# 开始BV号为1nt4y1v7Nm视频属性的抓取
# BV号为1nt4y1v7Nm的视频属性抓取结束
# 开始BV号为1dA41177QD视频属性的抓取
# BV号为1dA41177QD的视频属性抓取结束
# 开始BV号为1th41197oy视频属性的抓取
# BV号为1th41197oy的视频属性抓取结束
# 开始BV号为1e54y1R7bo视频属性的抓取
# BV号为1e54y1R7bo的视频属性抓取结束
# 开始BV号为1jA411E7i1视频属性的抓取
# BV号为1jA411E7i1的视频属性抓取结束
# 开始BV号为1Zy4y1b7mF视频属性的抓取
# BV号为1Zy4y1b7mF的视频属性抓取结束
# 开始BV号为1Vi4y177q8视频属性的抓取
# BV号为1Vi4y177q8的视频属性抓取结束
# 开始BV号为1eV411176P视频属性的抓取
# BV号为1eV411176P的视频属性抓取结束
# 开始BV号为1Qz4y1o7Qs视频属性的抓取
# BV号为1Qz4y1o7Qs的视频属性抓取结束
# 开始BV号为1eZ4y157Yc视频属性的抓取
# BV号为1eZ4y157Yc的视频属性抓取结束
# 开始BV号为1Gz4y1o7VR视频属性的抓取
# BV号为1Gz4y1o7VR的视频属性抓取结束
# 开始BV号为1ni4y177JB视频属性的抓取
# BV号为1ni4y177JB的视频属性抓取结束
# 开始BV号为1uZ4y1L7wM视频属性的抓取
# BV号为1uZ4y1L7wM的视频属性抓取结束
# 开始BV号为1HD4y197Ug视频属性的抓取
# BV号为1HD4y197Ug的视频属性抓取结束
# 开始BV号为1Gf4y1B7Su视频属性的抓取
# BV号为1Gf4y1B7Su的视频属性抓取结束
# 开始BV号为1TT4y1w7Vh视频属性的抓取
# BV号为1TT4y1w7Vh的视频属性抓取结束
# 开始BV号为1ja4y1L79B视频属性的抓取
# BV号为1ja4y1L79B的视频属性抓取结束
# 开始BV号为1Ey4y1B7eJ视频属性的抓取
# BV号为1Ey4y1B7eJ的视频属性抓取结束
# 开始BV号为17K411N7hU视频属性的抓取
# BV号为17K411N7hU的视频属性抓取结束
# 开始BV号为1iA41177gi视频属性的抓取
# BV号为1iA41177gi的视频属性抓取结束
# 开始BV号为1Rk4y1C7xF视频属性的抓取
# BV号为1Rk4y1C7xF的视频属性抓取结束
# 开始BV号为1Xi4y1E7uz视频属性的抓取
# BV号为1Xi4y1E7uz的视频属性抓取结束
# 开始BV号为1Mz4y1o78x视频属性的抓取
# BV号为1Mz4y1o78x的视频属性抓取结束
# 开始BV号为1Nz4y1f7Qj视频属性的抓取
# BV号为1Nz4y1f7Qj的视频属性抓取结束
# 开始BV号为1Fz4y1o7af视频属性的抓取
# BV号为1Fz4y1o7af的视频属性抓取结束
# 开始BV号为13K411A7wC视频属性的抓取
# BV号为13K411A7wC的视频属性抓取结束
# 开始BV号为1yk4y1C7bU视频属性的抓取
# BV号为1yk4y1C7bU的视频属性抓取结束
# 开始BV号为19t4y1v7kc视频属性的抓取
# BV号为19t4y1v7kc的视频属性抓取结束
# 开始BV号为1T54y1C7Bf视频属性的抓取
# BV号为1T54y1C7Bf的视频属性抓取结束
# 开始BV号为1TA41177zE视频属性的抓取
# BV号为1TA41177zE的视频属性抓取结束
# 开始BV号为1jZ4y1V7HT视频属性的抓取
# BV号为1jZ4y1V7HT的视频属性抓取结束
# 开始BV号为1Ky4y187wV视频属性的抓取
# BV号为1Ky4y187wV的视频属性抓取结束
# 开始BV号为19t4y1Y7Rv视频属性的抓取
# BV号为19t4y1Y7Rv的视频属性抓取结束
# 开始BV号为1Yz4y1C7xP视频属性的抓取
# BV号为1Yz4y1C7xP的视频属性抓取结束
# 开始BV号为1x5411j74s视频属性的抓取
# BV号为1x5411j74s的视频属性抓取结束
# 开始BV号为1uk4y1C742视频属性的抓取
# BV号为1uk4y1C742的视频属性抓取结束
# 开始BV号为1hi4y1j7m9视频属性的抓取
# BV号为1hi4y1j7m9的视频属性抓取结束
# 开始BV号为1i541157xs视频属性的抓取
# BV号为1i541157xs的视频属性抓取结束
# 开始BV号为1Rv411k7zW视频属性的抓取
# BV号为1Rv411k7zW的视频属性抓取结束
# 开始BV号为1av411k7g6视频属性的抓取
# BV号为1av411k7g6的视频属性抓取结束
# 开始BV号为1Dy4y1k77V视频属性的抓取
# BV号为1Dy4y1k77V的视频属性抓取结束
# 开始BV号为1TT4y1F7Z9视频属性的抓取
# BV号为1TT4y1F7Z9的视频属性抓取结束
# 开始BV号为1X54y1k7Ut视频属性的抓取
# BV号为1X54y1k7Ut的视频属性抓取结束
# 开始BV号为1Si4y1E7mv视频属性的抓取
# BV号为1Si4y1E7mv的视频属性抓取结束
# 开始BV号为165411j7UF视频属性的抓取
# BV号为165411j7UF的视频属性抓取结束
# 开始BV号为1hy4y1C7ao视频属性的抓取
# BV号为1hy4y1C7ao的视频属性抓取结束
# 开始BV号为1ck4y1y7Fm视频属性的抓取
# BV号为1ck4y1y7Fm的视频属性抓取结束
# 开始BV号为1UZ4y157uw视频属性的抓取
# BV号为1UZ4y157uw的视频属性抓取结束
# 开始BV号为1ca4y1s7LD视频属性的抓取
# BV号为1ca4y1s7LD的视频属性抓取结束
# 开始BV号为1YA41177DY视频属性的抓取
# BV号为1YA41177DY的视频属性抓取结束
# 开始BV号为11f4y1B78p视频属性的抓取
# BV号为11f4y1B78p的视频属性抓取结束
# 开始BV号为1354y1m77H视频属性的抓取
# BV号为1354y1m77H的视频属性抓取结束
# 开始BV号为18T4y1F7X6视频属性的抓取
# BV号为18T4y1F7X6的视频属性抓取结束
# 开始BV号为1kV41117gw视频属性的抓取
# BV号为1kV41117gw的视频属性抓取结束
# 开始BV号为1ZZ4y1G7Ta视频属性的抓取
# BV号为1ZZ4y1G7Ta的视频属性抓取结束
# 开始BV号为1da411A7je视频属性的抓取
# BV号为1da411A7je的视频属性抓取结束
# 开始BV号为1Rv411k77i视频属性的抓取
# BV号为1Rv411k77i的视频属性抓取结束
# 开始BV号为1g54y1r7ys视频属性的抓取
# BV号为1g54y1r7ys的视频属性抓取结束
# 开始BV号为1bD4y1d7td视频属性的抓取
# BV号为1bD4y1d7td的视频属性抓取结束
# 开始BV号为1Yv411k7jM视频属性的抓取
# BV号为1Yv411k7jM的视频属性抓取结束
# 开始BV号为1wy4y1878G视频属性的抓取
# BV号为1wy4y1878G的视频属性抓取结束
# 开始BV号为1GK4y1h7kS视频属性的抓取
# BV号为1GK4y1h7kS的视频属性抓取结束
# 开始BV号为1Yy4y1B7mj视频属性的抓取
# BV号为1Yy4y1B7mj的视频属性抓取结束
# 开始BV号为1af4y1i7Rj视频属性的抓取
# BV号为1af4y1i7Rj的视频属性抓取结束
# 开始BV号为1BK4y1h7Qy视频属性的抓取
# BV号为1BK4y1h7Qy的视频属性抓取结束
# 开始BV号为1HZ4y1V7bZ视频属性的抓取
# BV号为1HZ4y1V7bZ的视频属性抓取结束
# 开始BV号为1JV41127a2视频属性的抓取
# BV号为1JV41127a2的视频属性抓取结束
# 开始BV号为1fz4y1d7Sb视频属性的抓取
# BV号为1fz4y1d7Sb的视频属性抓取结束
# 开始BV号为1xv411k77x视频属性的抓取
# BV号为1xv411k77x的视频属性抓取结束
# 开始BV号为1Dz4y1d7nL视频属性的抓取
# BV号为1Dz4y1d7nL的视频属性抓取结束
# 开始BV号为1oV41117UC视频属性的抓取
# BV号为1oV41117UC的视频属性抓取结束
# 开始BV号为1mD4y1R7ru视频属性的抓取
# BV号为1mD4y1R7ru的视频属性抓取结束
# 开始BV号为1Et4y1i7oP视频属性的抓取
# BV号为1Et4y1i7oP的视频属性抓取结束
# 开始BV号为1Rr4y1c7h9视频属性的抓取
# BV号为1Rr4y1c7h9的视频属性抓取结束
# 开始BV号为15v411k78g视频属性的抓取
# BV号为15v411k78g的视频属性抓取结束
# 开始BV号为1Y54y1k7Ay视频属性的抓取
# BV号为1Y54y1k7Ay的视频属性抓取结束
# 开始BV号为1cA411j723视频属性的抓取
# BV号为1cA411j723的视频属性抓取结束
# 开始BV号为1TT4y1w7J9视频属性的抓取
# BV号为1TT4y1w7J9的视频属性抓取结束
# 开始BV号为1yZ4y157hx视频属性的抓取
# BV号为1yZ4y157hx的视频属性抓取结束
# 开始BV号为1Qt4y1v7A4视频属性的抓取
# BV号为1Qt4y1v7A4的视频属性抓取结束
# 开始BV号为1ft4y1Y73j视频属性的抓取
# BV号为1ft4y1Y73j的视频属性抓取结束
# 开始BV号为1qi4y1j7ft视频属性的抓取
# BV号为1qi4y1j7ft的视频属性抓取结束
# 开始BV号为17y4y1r7Fm视频属性的抓取
# BV号为17y4y1r7Fm的视频属性抓取结束
# 开始BV号为1sa4y1L7zD视频属性的抓取
# BV号为1sa4y1L7zD的视频属性抓取结束
# 开始BV号为1pV411y7pY视频属性的抓取
# BV号为1pV411y7pY的视频属性抓取结束
# 开始BV号为1bp4y1k7DP视频属性的抓取
# BV号为1bp4y1k7DP的视频属性抓取结束
# 开始BV号为1HA41177Xq视频属性的抓取
# BV号为1HA41177Xq的视频属性抓取结束
# 开始BV号为1NA411E7tR视频属性的抓取
# BV号为1NA411E7tR的视频属性抓取结束
# 开始BV号为1CK411A7DY视频属性的抓取
# BV号为1CK411A7DY的视频属性抓取结束
# 开始BV号为1n54y1k74Q视频属性的抓取
# BV号为1n54y1k74Q的视频属性抓取结束
# 2020-12-21 20:59:30.744479

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-29-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_zhishi_xiaoyuan.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月    99   99   99   99   99   99    99
# 2月   100  100  100  100  100  100   100
# 3月   100  100  100  100  100  100   100
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月   100  100  100  100  100  100   100
# 7月   100  100  100  100  100  100   100
# 8月   100  100  100  100  100  100   100
# 9月   100  100  100  100  100  100   100

# %%
channel_zhishi_xiaoyuan.to_json('channel_zhishi_xiaoyuan.json')

# %%
pd.read_json('channel_zhishi_xiaoyuan.json')
# Out:
#              时间          作者名  作者类型    粉丝数  投稿数  \
# 1CJ411p7cH   1月    阿凯阿凯12138     无   5.6万   18
# 1gJ411L75M   1月         装甲尼禄  个人认证      0    0
# 1YJ411H7j7   1月         众合教育  机构认证   9.9万  150
# 1P7411C7Gz   1月  学习使我快乐到无与伦比     无  28.3万  176
# 1fJ411b7EV   1月    数列极限今年一定考     无  11.2万    4
# ...         ...          ...   ...    ...  ...
# 1HA41177Xq  10月          煎桃桃     无   2.5万   16
# 1pV411y7pY  10月       高教考试在线  个人认证   6.3万  239
# 1n54y1k74Q  10月      小晗学姐www  个人认证   5.3万   78
# 13V411y7bX  10月          韦甫李     无   7.2万  116
# 1FA411j7BH  10月       传闻中的穗穗     无   2.4万    9
#
#                                                           视频名  分区   子分区  视频类型  \
# 1CJ411p7cH                          前置摄像头里的你和镜子里的你到底哪个才是真的你？！  知识  校园学习  普通视频
# 1gJ411L75M                 【厚大法考】请不要这样！我是有尊严的！！！！之请尽情的鞭打我的尊严。  知识  校园学习  普通视频
# 1YJ411H7j7                        【字幕完结版】2020法考客观题行政法精讲课-众合李佳  知识  校园学习  普通视频
# 1P7411C7Gz                                    【公开课】耶鲁大学：哲学-死亡  知识  校园学习  普通视频
# 1fJ411b7EV                            2021刘晓燕语法长难句完整版（刘晓燕长难句）  知识  校园学习  普通视频
# ...                                                       ...  ..   ...   ...
# 1HA41177Xq                              「阿煎」斑马平替/小众荧光笔/学习文具分享  知识  校园学习  活动作品
# 1pV411y7pY                           【刘晓艳】考研毒鸡汤“你今年考不上，明年也难！”  知识  校园学习  活动作品
# 1n54y1k74Q                   【自学】大学上课听不懂怎么自学？自学什么比较好？考证需要报班吗？  知识  校园学习  活动作品
# 13V411y7bX                            背书难又背不完?恭喜你在考前发现这个超强记忆法  知识  校园学习  活动作品
# 1FA411j7BH  【Notability】多级分类/快速索引/手势操作/手帐外挂,装备6大BUFF,生产力UPUP!  知识  校园学习  活动作品
#
#            自制or转载                                                 标签   视频长度  \
# 1CJ411p7cH     自制                    [科普, 知识, 校园学习, 自拍, 新人, 大学生, 自制]  03:04
# 1gJ411L75M     转载  [演讲, 相声, 考试, 搞笑, 知识, 校园学习, 厚大法考, 学习, 教育, 线上课堂,...  15:14
# 1YJ411H7j7     自制  [法考, 法律, 考试, 公开课, 知识, 校园学习, 李佳, 免费课程, 众合, 行政法,...  81:07
# 1P7411C7Gz     转载                  [英语, 公开课, 知识, 校园学习, 学习, 哲学, 耶鲁大学]  46:15
# 1fJ411b7EV     转载            [英语学习, 考研, 英语, 知识, 校园学习, 考研英语, 学习, 长难句]  99:19
# ...           ...                                                ...    ...
# 1HA41177Xq     自制          [手工, 知识, 校园学习, 知识分享官, 文具, 学习, 花式过节展台, 高中]  01:22
# 1pV411y7pY     自制            [考研, 英语, 考试, 知识, 校园学习, 知识分享官, 大学, 经验分享]  01:26
# 1n54y1k74Q     自制      [考试, 必剪创作, 知识, 校园学习, 必剪十一大作战, 自学, 大学, 花式过节展台]  09:32
# 13V411y7bX     自制     [考研, 知识, 校园学习, 知识分享官, 经验分享, 记忆方法, 学习心得, 专业课背诵]  11:42
# 1FA411j7BH     自制  [IPAD, 知识, 校园学习, 就是爱学习, 学习, 效率, 经验分享, 生产力, 学习心...  05:26
#
#                播放量    点赞数    投币数    收藏数   转发数  评论数   弹幕数 有无分集
# 1CJ411p7cH  277.9万  36.3万  24.6万  10.4万  3.3万  NaN  1.3万    否
# 1gJ411L75M  208.3万  11.0万   2.9万   6.7万  2.9万  NaN  2.0万    否
# 1YJ411H7j7  199.0万   1.1万   7034   3.3万  2342  NaN  8.6万    是
# 1P7411C7Gz  167.8万  10.3万   5.4万  32.4万  2.4万  NaN  1.6万    是
# 1fJ411b7EV  123.4万   1.7万   4494   3.4万  1.5万  NaN  7.0万    是
# ...            ...    ...    ...    ...   ...  ...   ...  ...
# 1HA41177Xq   10.2万   4953    364   3106    57  NaN   177    否
# 1pV411y7pY   10.1万   2285    152   1174   700  NaN    95    否
# 1n54y1k74Q    9.9万   6957   2530   6336   608  NaN   658    否
# 13V411y7bX    9.8万   6865   3705   1.1万   574  NaN   335    否
# 1FA411j7BH    9.8万   8177   6020   1.4万   479  NaN   290    否
#
# [993 rows x 20 columns]
