# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_zixun_redian=pd.DataFrame(columns=columns)
channel_zixun_redian
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[12]/div/a/span').click()  #选择频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[12]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '资讯'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[2]/a').click()  #选择子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[2]/a').text
sub_channel
# Out:
# '热点'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(1,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_zixun_redian.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-16 23:43:08.171060
# <ipython-input-10-a118c3ce0451>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-10-a118c3ce0451>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-10-a118c3ce0451>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1f7411v7tX视频属性的抓取
# BV号为1f7411v7tX的视频属性抓取结束
# <ipython-input-10-a118c3ce0451>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1cJ411E7j7视频属性的抓取
# BV号为1cJ411E7j7的视频属性抓取结束
# 开始BV号为1x7411z7Ci视频属性的抓取
# BV号为1x7411z7Ci的视频属性抓取结束
# 开始BV号为12J41177ih视频属性的抓取
# BV号为12J41177ih的视频属性抓取结束
# 开始BV号为177411v7PM视频属性的抓取
# BV号为177411v7PM的视频属性抓取结束
# 开始BV号为1d7411a7UR视频属性的抓取
# BV号为1d7411a7UR的视频属性抓取结束
# 开始BV号为1A7411i727视频属性的抓取
# BV号为1A7411i727的视频属性抓取结束
# 开始BV号为1d7411e7oK视频属性的抓取
# BV号为1d7411e7oK的视频属性抓取结束
# 开始BV号为117411v78z视频属性的抓取
# BV号为117411v78z的视频属性抓取结束
# 开始BV号为1U7411B73E视频属性的抓取
# BV号为1U7411B73E的视频属性抓取结束
# 开始BV号为1o7411v7we视频属性的抓取
# BV号为1o7411v7we的视频属性抓取结束
# 开始BV号为1HJ411p7qv视频属性的抓取
# BV号为1HJ411p7qv的视频属性抓取结束
# 开始BV号为18741167Jg视频属性的抓取
# BV号为18741167Jg的视频属性抓取结束
# 开始BV号为1T7411v71g视频属性的抓取
# BV号为1T7411v71g的视频属性抓取结束
# 开始BV号为1x7411v71H视频属性的抓取
# BV号为1x7411v71H的视频属性抓取结束
# 开始BV号为157411i7Gd视频属性的抓取
# BV号为157411i7Gd的视频属性抓取结束
# 开始BV号为1N741167GM视频属性的抓取
# BV号为1N741167GM的视频属性抓取结束
# 开始BV号为167411Y7LA视频属性的抓取
# BV号为167411Y7LA的视频属性抓取结束
# 开始BV号为1wJ41177UW视频属性的抓取
# BV号为1wJ41177UW的视频属性抓取结束
# 开始BV号为1sJ411V7rJ视频属性的抓取
# BV号为1sJ411V7rJ的视频属性抓取结束
# 开始BV号为1H7411e72o视频属性的抓取
# BV号为1H7411e72o的视频属性抓取结束
# 开始BV号为1UJ41177iS视频属性的抓取
# BV号为1UJ41177iS的视频属性抓取结束
# 开始BV号为127411Y7UL视频属性的抓取
# BV号为127411Y7UL的视频属性抓取结束
# 开始BV号为1C741167Uv视频属性的抓取
# BV号为1C741167Uv的视频属性抓取结束
# 开始BV号为1J7411Y7qs视频属性的抓取
# BV号为1J7411Y7qs的视频属性抓取结束
# 开始BV号为1M7411i7V2视频属性的抓取
# BV号为1M7411i7V2的视频属性抓取结束
# 开始BV号为167411Y7za视频属性的抓取
# BV号为167411Y7za的视频属性抓取结束
# 开始BV号为1N7411r7dY视频属性的抓取
# BV号为1N7411r7dY的视频属性抓取结束
# 开始BV号为1p7411k79L视频属性的抓取
# BV号为1p7411k79L的视频属性抓取结束
# 开始BV号为1D7411Y7dE视频属性的抓取
# BV号为1D7411Y7dE的视频属性抓取结束
# 开始BV号为1XJ411E7uK视频属性的抓取
# BV号为1XJ411E7uK的视频属性抓取结束
# 开始BV号为1yJ41157qi视频属性的抓取
# BV号为1yJ41157qi的视频属性抓取结束
# 开始BV号为1L7411k7fx视频属性的抓取
# BV号为1L7411k7fx的视频属性抓取结束
# 开始BV号为1M7411z7w5视频属性的抓取
# BV号为1M7411z7w5的视频属性抓取结束
# 开始BV号为1L7411r7fe视频属性的抓取
# BV号为1L7411r7fe的视频属性抓取结束
# 开始BV号为18741167YM视频属性的抓取
# BV号为18741167YM的视频属性抓取结束
# 开始BV号为1pJ411H7Ar视频属性的抓取
# BV号为1pJ411H7Ar的视频属性抓取结束
# 开始BV号为1t7411B7Tx视频属性的抓取
# BV号为1t7411B7Tx的视频属性抓取结束
# 开始BV号为1x7411v7Mu视频属性的抓取
# BV号为1x7411v7Mu的视频属性抓取结束
# 开始BV号为1W7411r7KR视频属性的抓取
# BV号为1W7411r7KR的视频属性抓取结束
# 开始BV号为1z7411676Y视频属性的抓取
# BV号为1z7411676Y的视频属性抓取结束
# 开始BV号为1f7411v7gc视频属性的抓取
# BV号为1f7411v7gc的视频属性抓取结束
# 开始BV号为1GJ411V7ib视频属性的抓取
# BV号为1GJ411V7ib的视频属性抓取结束
# 开始BV号为1k7411r74F视频属性的抓取
# BV号为1k7411r74F的视频属性抓取结束
# 开始BV号为1x7411B7HE视频属性的抓取
# BV号为1x7411B7HE的视频属性抓取结束
# 开始BV号为1Q7411B7se视频属性的抓取
# BV号为1Q7411B7se的视频属性抓取结束
# 开始BV号为1a7411z76s视频属性的抓取
# BV号为1a7411z76s的视频属性抓取结束
# 开始BV号为1Z7411B7ze视频属性的抓取
# BV号为1Z7411B7ze的视频属性抓取结束
# 开始BV号为167411s76S视频属性的抓取
# BV号为167411s76S的视频属性抓取结束
# 开始BV号为1U7411a7td视频属性的抓取
# BV号为1U7411a7td的视频属性抓取结束
# 开始BV号为1J7411r7pR视频属性的抓取
# BV号为1J7411r7pR的视频属性抓取结束
# 开始BV号为1U7411a7gR视频属性的抓取
# BV号为1U7411a7gR的视频属性抓取结束
# 开始BV号为1T7411e7US视频属性的抓取
# BV号为1T7411e7US的视频属性抓取结束
# 开始BV号为1s7411a7ck视频属性的抓取
# BV号为1s7411a7ck的视频属性抓取结束
# 开始BV号为13J41157bn视频属性的抓取
# BV号为13J41157bn的视频属性抓取结束
# <ipython-input-10-a118c3ce0451>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1Z7411z773视频属性的抓取
# BV号为1Z7411z773的视频属性抓取结束
# 开始BV号为167411a7PV视频属性的抓取
# BV号为167411a7PV的视频属性抓取结束
# 开始BV号为1A7411679x视频属性的抓取
# BV号为1A7411679x的视频属性抓取结束
# 开始BV号为1Q7411i7ZJ视频属性的抓取
# BV号为1Q7411i7ZJ的视频属性抓取结束
# 开始BV号为1x741167AM视频属性的抓取
# BV号为1x741167AM的视频属性抓取结束
# 开始BV号为1P7411Y7bG视频属性的抓取
# BV号为1P7411Y7bG的视频属性抓取结束
# 开始BV号为1nJ41187Zy视频属性的抓取
# BV号为1nJ41187Zy的视频属性抓取结束
# 开始BV号为127411s7zD视频属性的抓取
# 开始BV号为127411s7zD视频属性的抓取
# 开始BV号为127411s7zD视频属性的抓取
# BV号为127411s7zD的视频属性抓取结束
# 开始BV号为1A7411C7uf视频属性的抓取
# 开始BV号为1A7411C7uf视频属性的抓取
# 开始BV号为1A7411C7uf视频属性的抓取
# BV号为1A7411C7uf的视频属性抓取结束
# 开始BV号为1f7411q7GZ视频属性的抓取
# BV号为1f7411q7GZ的视频属性抓取结束
# 开始BV号为1jJ41157PF视频属性的抓取
# BV号为1jJ41157PF的视频属性抓取结束
# 开始BV号为12J411j7fT视频属性的抓取
# BV号为12J411j7fT的视频属性抓取结束
# 开始BV号为1GJ411n7WZ视频属性的抓取
# BV号为1GJ411n7WZ的视频属性抓取结束
# 开始BV号为1pJ411L7uZ视频属性的抓取
# BV号为1pJ411L7uZ的视频属性抓取结束
# 开始BV号为1z741167Y5视频属性的抓取
# BV号为1z741167Y5的视频属性抓取结束
# 开始BV号为1y741167Yz视频属性的抓取
# BV号为1y741167Yz的视频属性抓取结束
# 开始BV号为1p741167iR视频属性的抓取
# BV号为1p741167iR的视频属性抓取结束
# 开始BV号为1eJ411J7MF视频属性的抓取
# BV号为1eJ411J7MF的视频属性抓取结束
# 开始BV号为1o7411v73E视频属性的抓取
# BV号为1o7411v73E的视频属性抓取结束
# 开始BV号为1R7411a7wp视频属性的抓取
# BV号为1R7411a7wp的视频属性抓取结束
# 开始BV号为157411Y7tR视频属性的抓取
# BV号为157411Y7tR的视频属性抓取结束
# 开始BV号为1r7411v7Cq视频属性的抓取
# BV号为1r7411v7Cq的视频属性抓取结束
# 开始BV号为1jJ411H7eV视频属性的抓取
# BV号为1jJ411H7eV的视频属性抓取结束
# 开始BV号为1J7411e7V9视频属性的抓取
# BV号为1J7411e7V9的视频属性抓取结束
# 开始BV号为1m74116775视频属性的抓取
# BV号为1m74116775的视频属性抓取结束
# 开始BV号为1Z7411k7RU视频属性的抓取
# BV号为1Z7411k7RU的视频属性抓取结束
# 开始BV号为1N7411C7c9视频属性的抓取
# BV号为1N7411C7c9的视频属性抓取结束
# 开始BV号为1Z7411Y7pR视频属性的抓取
# BV号为1Z7411Y7pR的视频属性抓取结束
# 开始BV号为1hJ411b7ci视频属性的抓取
# BV号为1hJ411b7ci的视频属性抓取结束
# 开始BV号为1L7411k7FP视频属性的抓取
# BV号为1L7411k7FP的视频属性抓取结束
# 开始BV号为1s7411i7yW视频属性的抓取
# BV号为1s7411i7yW的视频属性抓取结束
# 开始BV号为1P7411Y79a视频属性的抓取
# BV号为1P7411Y79a的视频属性抓取结束
# 开始BV号为15J41177pi视频属性的抓取
# BV号为15J41177pi的视频属性抓取结束
# 开始BV号为1x7411Y7SF视频属性的抓取
# BV号为1x7411Y7SF的视频属性抓取结束
# 开始BV号为1p7411B7nC视频属性的抓取
# BV号为1p7411B7nC的视频属性抓取结束
# 开始BV号为13J411E7KY视频属性的抓取
# BV号为13J411E7KY的视频属性抓取结束
# 开始BV号为1m7411B78a视频属性的抓取
# BV号为1m7411B78a的视频属性抓取结束
# 开始BV号为157411r77Z视频属性的抓取
# BV号为157411r77Z的视频属性抓取结束
# 开始BV号为1FJ411H7MQ视频属性的抓取
# BV号为1FJ411H7MQ的视频属性抓取结束
# 开始BV号为1eJ41177Tb视频属性的抓取
# BV号为1eJ41177Tb的视频属性抓取结束
# 开始BV号为127411e7eg视频属性的抓取
# BV号为127411e7eg的视频属性抓取结束
# 开始BV号为1s7411a78Y视频属性的抓取
# BV号为1s7411a78Y的视频属性抓取结束
# 开始BV号为1N7411e76B视频属性的抓取
# BV号为1N7411e76B的视频属性抓取结束
# 开始BV号为1m7411F7si视频属性的抓取
# BV号为1m7411F7si的视频属性抓取结束
# 开始BV号为1M7411p7sg视频属性的抓取
# BV号为1M7411p7sg的视频属性抓取结束
# 开始BV号为1M7411N7Vs视频属性的抓取
# BV号为1M7411N7Vs的视频属性抓取结束
# 开始BV号为1h7411j71R视频属性的抓取
# BV号为1h7411j71R的视频属性抓取结束
# 开始BV号为187411T7jU视频属性的抓取
# BV号为187411T7jU的视频属性抓取结束
# <ipython-input-10-a118c3ce0451>:190: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1KE411H7km视频属性的抓取
# BV号为1KE411H7km的视频属性抓取结束
# 开始BV号为1F7411N7VR视频属性的抓取
# BV号为1F7411N7VR的视频属性抓取结束
# 开始BV号为1i741137i4视频属性的抓取
# BV号为1i741137i4的视频属性抓取结束
# 开始BV号为19j411f7Li视频属性的抓取
# BV号为19j411f7Li的视频属性抓取结束
# 开始BV号为1e7411P7WF视频属性的抓取
# BV号为1e7411P7WF的视频属性抓取结束
# 开始BV号为167411T7qz视频属性的抓取
# BV号为167411T7qz的视频属性抓取结束
# 开始BV号为167411P79H视频属性的抓取
# 开始BV号为167411P79H视频属性的抓取
# BV号为167411P79H的视频属性抓取结束
# 开始BV号为1s7411s73H视频属性的抓取
# BV号为1s7411s73H的视频属性抓取结束
# 开始BV号为147411T7bj视频属性的抓取
# BV号为147411T7bj的视频属性抓取结束
# 开始BV号为1R7411W7b6视频属性的抓取
# BV号为1R7411W7b6的视频属性抓取结束
# 开始BV号为1o7411T7z8视频属性的抓取
# BV号为1o7411T7z8的视频属性抓取结束
# 开始BV号为1M7411V7HZ视频属性的抓取
# BV号为1M7411V7HZ的视频属性抓取结束
# 开始BV号为1y7411K7r9视频属性的抓取
# BV号为1y7411K7r9的视频属性抓取结束
# 开始BV号为1z7411c76M视频属性的抓取
# BV号为1z7411c76M的视频属性抓取结束
# 开始BV号为117411H7o7视频属性的抓取
# BV号为117411H7o7的视频属性抓取结束
# 开始BV号为1p7411T7sp视频属性的抓取
# BV号为1p7411T7sp的视频属性抓取结束
# 开始BV号为1c741147iG视频属性的抓取
# BV号为1c741147iG的视频属性抓取结束
# 开始BV号为1o7411N77X视频属性的抓取
# BV号为1o7411N77X的视频属性抓取结束
# 开始BV号为1M7411K7mx视频属性的抓取
# 开始BV号为1M7411K7mx视频属性的抓取
# BV号为1M7411K7mx的视频属性抓取结束
# 开始BV号为187411t7XT视频属性的抓取
# BV号为187411t7XT的视频属性抓取结束
# 开始BV号为1Z7411N754视频属性的抓取
# BV号为1Z7411N754的视频属性抓取结束
# 开始BV号为1v7411K7o3视频属性的抓取
# BV号为1v7411K7o3的视频属性抓取结束
# 开始BV号为1b741157DP视频属性的抓取
# BV号为1b741157DP的视频属性抓取结束
# 开始BV号为1q7411T7aQ视频属性的抓取
# BV号为1q7411T7aQ的视频属性抓取结束
# 开始BV号为1H7411x752视频属性的抓取
# BV号为1H7411x752的视频属性抓取结束
# 开始BV号为1M7411P7Uu视频属性的抓取
# BV号为1M7411P7Uu的视频属性抓取结束
# 开始BV号为1a7411W73u视频属性的抓取
# BV号为1a7411W73u的视频属性抓取结束
# 开始BV号为1e741187kd视频属性的抓取
# BV号为1e741187kd的视频属性抓取结束
# 开始BV号为1K741157f2视频属性的抓取
# BV号为1K741157f2的视频属性抓取结束
# 开始BV号为1J7411W7fN视频属性的抓取
# BV号为1J7411W7fN的视频属性抓取结束
# 开始BV号为1W7411p7MF视频属性的抓取
# BV号为1W7411p7MF的视频属性抓取结束
# 开始BV号为187411T7Ma视频属性的抓取
# BV号为187411T7Ma的视频属性抓取结束
# 开始BV号为1j7411W7M4视频属性的抓取
# BV号为1j7411W7M4的视频属性抓取结束
# 开始BV号为1V7411L7Nt视频属性的抓取
# BV号为1V7411L7Nt的视频属性抓取结束
# 开始BV号为1L7411x7mn视频属性的抓取
# BV号为1L7411x7mn的视频属性抓取结束
# 开始BV号为1b7411t7iW视频属性的抓取
# BV号为1b7411t7iW的视频属性抓取结束
# 开始BV号为1x7411T7Wz视频属性的抓取
# BV号为1x7411T7Wz的视频属性抓取结束
# 开始BV号为1a741187yY视频属性的抓取
# BV号为1a741187yY的视频属性抓取结束
# 开始BV号为1n741137VN视频属性的抓取
# BV号为1n741137VN的视频属性抓取结束
# 开始BV号为1m7411b7Jx视频属性的抓取
# BV号为1m7411b7Jx的视频属性抓取结束
# 开始BV号为1s7411378W视频属性的抓取
# BV号为1s7411378W的视频属性抓取结束
# 开始BV号为1g7411t7Hu视频属性的抓取
# BV号为1g7411t7Hu的视频属性抓取结束
# 开始BV号为1i7411K7e6视频属性的抓取
# BV号为1i7411K7e6的视频属性抓取结束
# 开始BV号为1b7411K7TX视频属性的抓取
# BV号为1b7411K7TX的视频属性抓取结束
# 开始BV号为1A7411t7Jo视频属性的抓取
# BV号为1A7411t7Jo的视频属性抓取结束
# 开始BV号为1KE411H7Xx视频属性的抓取
# BV号为1KE411H7Xx的视频属性抓取结束
# 开始BV号为1S7411j7JQ视频属性的抓取
# BV号为1S7411j7JQ的视频属性抓取结束
# 开始BV号为12E411n7tf视频属性的抓取
# BV号为12E411n7tf的视频属性抓取结束
# 开始BV号为1e7411A7VR视频属性的抓取
# BV号为1e7411A7VR的视频属性抓取结束
# 开始BV号为1J741177S2视频属性的抓取
# BV号为1J741177S2的视频属性抓取结束
# 开始BV号为1n741187aP视频属性的抓取
# BV号为1n741187aP的视频属性抓取结束
# 开始BV号为1M7411P7zf视频属性的抓取
# BV号为1M7411P7zf的视频属性抓取结束
# 开始BV号为1E7411s7mW视频属性的抓取
# BV号为1E7411s7mW的视频属性抓取结束
# 开始BV号为1b7411K7iS视频属性的抓取
# BV号为1b7411K7iS的视频属性抓取结束
# 开始BV号为117411n7hK视频属性的抓取
# BV号为117411n7hK的视频属性抓取结束
# 开始BV号为1j7411x76u视频属性的抓取
# BV号为1j7411x76u的视频属性抓取结束
# 开始BV号为1S7411G7rp视频属性的抓取
# BV号为1S7411G7rp的视频属性抓取结束
# 开始BV号为1R7411P7if视频属性的抓取
# BV号为1R7411P7if的视频属性抓取结束
# 开始BV号为1x7411h7w9视频属性的抓取
# 开始BV号为1x7411h7w9视频属性的抓取
# BV号为1x7411h7w9的视频属性抓取结束
# 开始BV号为1i741147ro视频属性的抓取
# BV号为1i741147ro的视频属性抓取结束
# 开始BV号为1F7411579q视频属性的抓取
# BV号为1F7411579q的视频属性抓取结束
# 开始BV号为1v7411x79Y视频属性的抓取
# BV号为1v7411x79Y的视频属性抓取结束
# 开始BV号为1M7411g77Q视频属性的抓取
# BV号为1M7411g77Q的视频属性抓取结束
# 开始BV号为1f7411w79W视频属性的抓取
# BV号为1f7411w79W的视频属性抓取结束
# 开始BV号为127411N7VS视频属性的抓取
# BV号为127411N7VS的视频属性抓取结束
# 开始BV号为1zE411n7DU视频属性的抓取
# BV号为1zE411n7DU的视频属性抓取结束
# 开始BV号为1Q7411c7d9视频属性的抓取
# BV号为1Q7411c7d9的视频属性抓取结束
# 开始BV号为1j7411p7fb视频属性的抓取
# BV号为1j7411p7fb的视频属性抓取结束
# 开始BV号为177411u7Nn视频属性的抓取
# BV号为177411u7Nn的视频属性抓取结束
# 开始BV号为1A7411u799视频属性的抓取
# BV号为1A7411u799的视频属性抓取结束
# 开始BV号为197411H7nM视频属性的抓取
# BV号为197411H7nM的视频属性抓取结束
# 开始BV号为1D7411t7Gg视频属性的抓取
# BV号为1D7411t7Gg的视频属性抓取结束
# 开始BV号为1v741147cT视频属性的抓取
# BV号为1v741147cT的视频属性抓取结束
# 开始BV号为177411K73U视频属性的抓取
# BV号为177411K73U的视频属性抓取结束
# 开始BV号为1P7411x7oz视频属性的抓取
# BV号为1P7411x7oz的视频属性抓取结束
# 开始BV号为1u7411x7HU视频属性的抓取
# BV号为1u7411x7HU的视频属性抓取结束
# 开始BV号为1q7411s72o视频属性的抓取
# BV号为1q7411s72o的视频属性抓取结束
# 开始BV号为1W7411n7ip视频属性的抓取
# 开始BV号为1W7411n7ip视频属性的抓取
# BV号为1W7411n7ip的视频属性抓取结束
# 开始BV号为1V7411n7wV视频属性的抓取
# BV号为1V7411n7wV的视频属性抓取结束
# 开始BV号为1n7411W7Up视频属性的抓取
# BV号为1n7411W7Up的视频属性抓取结束
# 开始BV号为1Lj411f7m1视频属性的抓取
# BV号为1Lj411f7m1的视频属性抓取结束
# 开始BV号为1J7411W7py视频属性的抓取
# BV号为1J7411W7py的视频属性抓取结束
# 开始BV号为1Q7411E7Fk视频属性的抓取
# BV号为1Q7411E7Fk的视频属性抓取结束
# 开始BV号为137411M7kd视频属性的抓取
# BV号为137411M7kd的视频属性抓取结束
# 开始BV号为1b741137R4视频属性的抓取
# BV号为1b741137R4的视频属性抓取结束
# 开始BV号为1d7411p7C4视频属性的抓取
# BV号为1d7411p7C4的视频属性抓取结束
# 开始BV号为1eE411J7SS视频属性的抓取
# BV号为1eE411J7SS的视频属性抓取结束
# 开始BV号为1s7411h711视频属性的抓取
# BV号为1s7411h711的视频属性抓取结束
# 开始BV号为1K7411t7VV视频属性的抓取
# BV号为1K7411t7VV的视频属性抓取结束
# 开始BV号为1P7411p7UB视频属性的抓取
# BV号为1P7411p7UB的视频属性抓取结束
# 开始BV号为1YE411T7PZ视频属性的抓取
# BV号为1YE411T7PZ的视频属性抓取结束
# 开始BV号为13E411x7oF视频属性的抓取
# BV号为13E411x7oF的视频属性抓取结束
# 开始BV号为1iE411E7xc视频属性的抓取
# BV号为1iE411E7xc的视频属性抓取结束
# 开始BV号为16K4y1C75L视频属性的抓取
# BV号为16K4y1C75L的视频属性抓取结束
# 开始BV号为1BE411A75Z视频属性的抓取
# BV号为1BE411A75Z的视频属性抓取结束
# 开始BV号为14E411E7b2视频属性的抓取
# BV号为14E411E7b2的视频属性抓取结束
# 开始BV号为1sE411E7aG视频属性的抓取
# BV号为1sE411E7aG的视频属性抓取结束
# 开始BV号为1vE411571w视频属性的抓取
# BV号为1vE411571w的视频属性抓取结束
# 开始BV号为1pE411E7R9视频属性的抓取
# BV号为1pE411E7R9的视频属性抓取结束
# 开始BV号为1gE411A7jq视频属性的抓取
# BV号为1gE411A7jq的视频属性抓取结束
# 开始BV号为1iE411c7tD视频属性的抓取
# BV号为1iE411c7tD的视频属性抓取结束
# 开始BV号为1AE411w7B8视频属性的抓取
# BV号为1AE411w7B8的视频属性抓取结束
# 开始BV号为1v7411m7Rz视频属性的抓取
# BV号为1v7411m7Rz的视频属性抓取结束
# 开始BV号为1A7411Z7g5视频属性的抓取
# BV号为1A7411Z7g5的视频属性抓取结束
# 开始BV号为1bE411P71i视频属性的抓取
# BV号为1bE411P71i的视频属性抓取结束
# 开始BV号为16E411W7DQ视频属性的抓取
# BV号为16E411W7DQ的视频属性抓取结束
# 开始BV号为1E7411f7HE视频属性的抓取
# BV号为1E7411f7HE的视频属性抓取结束
# 开始BV号为11741117gK视频属性的抓取
# BV号为11741117gK的视频属性抓取结束
# 开始BV号为1f741127An视频属性的抓取
# BV号为1f741127An的视频属性抓取结束
# 开始BV号为13z411b7u8视频属性的抓取
# BV号为13z411b7u8的视频属性抓取结束
# 开始BV号为1wE411s7tR视频属性的抓取
# BV号为1wE411s7tR的视频属性抓取结束
# 开始BV号为1q7411o7eP视频属性的抓取
# BV号为1q7411o7eP的视频属性抓取结束
# 开始BV号为1hE411L7dv视频属性的抓取
# BV号为1hE411L7dv的视频属性抓取结束
# 开始BV号为1s7411U799视频属性的抓取
# BV号为1s7411U799的视频属性抓取结束
# 开始BV号为15e411x7kH视频属性的抓取
# BV号为15e411x7kH的视频属性抓取结束
# 开始BV号为16Z4y1j77a视频属性的抓取
# BV号为16Z4y1j77a的视频属性抓取结束
# 开始BV号为1vQ4y1M7EN视频属性的抓取
# BV号为1vQ4y1M7EN的视频属性抓取结束
# 开始BV号为1w7411y7Gf视频属性的抓取
# BV号为1w7411y7Gf的视频属性抓取结束
# 开始BV号为1GE41147cu视频属性的抓取
# BV号为1GE41147cu的视频属性抓取结束
# 开始BV号为1C7411R7Pa视频属性的抓取
# BV号为1C7411R7Pa的视频属性抓取结束
# 开始BV号为1iE411A7C5视频属性的抓取
# BV号为1iE411A7C5的视频属性抓取结束
# 开始BV号为127411d7RK视频属性的抓取
# BV号为127411d7RK的视频属性抓取结束
# 开始BV号为1F7411f78f视频属性的抓取
# BV号为1F7411f78f的视频属性抓取结束
# 开始BV号为1uE411A71f视频属性的抓取
# BV号为1uE411A71f的视频属性抓取结束
# 开始BV号为1yE411s7R7视频属性的抓取
# BV号为1yE411s7R7的视频属性抓取结束
# 开始BV号为1Q7411o7u9视频属性的抓取
# BV号为1Q7411o7u9的视频属性抓取结束
# 开始BV号为1QE411K7XP视频属性的抓取
# BV号为1QE411K7XP的视频属性抓取结束
# 开始BV号为13E411F7jx视频属性的抓取
# BV号为13E411F7jx的视频属性抓取结束
# 开始BV号为1zE411c7PQ视频属性的抓取
# BV号为1zE411c7PQ的视频属性抓取结束
# 开始BV号为13c411h7dv视频属性的抓取
# BV号为13c411h7dv的视频属性抓取结束
# 开始BV号为1gE411w7zs视频属性的抓取
# BV号为1gE411w7zs的视频属性抓取结束
# 开始BV号为1s741127sV视频属性的抓取
# BV号为1s741127sV的视频属性抓取结束
# 开始BV号为1QE411K7P2视频属性的抓取
# BV号为1QE411K7P2的视频属性抓取结束
# 开始BV号为1zE411W7vH视频属性的抓取
# BV号为1zE411W7vH的视频属性抓取结束
# 开始BV号为18E411s7wG视频属性的抓取
# BV号为18E411s7wG的视频属性抓取结束
# 开始BV号为1ME411g7F6视频属性的抓取
# BV号为1ME411g7F6的视频属性抓取结束
# 开始BV号为11E411W7DC视频属性的抓取
# BV号为11E411W7DC的视频属性抓取结束
# 开始BV号为1d741127GY视频属性的抓取
# BV号为1d741127GY的视频属性抓取结束
# 开始BV号为1i741117vy视频属性的抓取
# BV号为1i741117vy的视频属性抓取结束
# 开始BV号为1yE411x7oc视频属性的抓取
# BV号为1yE411x7oc的视频属性抓取结束
# 开始BV号为1xE411G7Jy视频属性的抓取
# BV号为1xE411G7Jy的视频属性抓取结束
# 开始BV号为1H7411m7Cy视频属性的抓取
# BV号为1H7411m7Cy的视频属性抓取结束
# 开始BV号为1SE411s7j1视频属性的抓取
# BV号为1SE411s7j1的视频属性抓取结束
# 开始BV号为1KE411g7jp视频属性的抓取
# BV号为1KE411g7jp的视频属性抓取结束
# 开始BV号为1d741197mC视频属性的抓取
# BV号为1d741197mC的视频属性抓取结束
# 开始BV号为1LE411F7xY视频属性的抓取
# BV号为1LE411F7xY的视频属性抓取结束
# 开始BV号为1z7411U7bu视频属性的抓取
# BV号为1z7411U7bu的视频属性抓取结束
# 开始BV号为1q7411R7eQ视频属性的抓取
# BV号为1q7411R7eQ的视频属性抓取结束
# 开始BV号为11t4y1m7RW视频属性的抓取
# BV号为11t4y1m7RW的视频属性抓取结束
# 开始BV号为1e7411Z7r6视频属性的抓取
# BV号为1e7411Z7r6的视频属性抓取结束
# 开始BV号为1xE411V7kM视频属性的抓取
# BV号为1xE411V7kM的视频属性抓取结束
# 开始BV号为1z7411R76j视频属性的抓取
# BV号为1z7411R76j的视频属性抓取结束
# 开始BV号为1fE411x7eY视频属性的抓取
# BV号为1fE411x7eY的视频属性抓取结束
# 开始BV号为1xE411j7on视频属性的抓取
# BV号为1xE411j7on的视频属性抓取结束
# 开始BV号为1bE411L778视频属性的抓取
# BV号为1bE411L778的视频属性抓取结束
# 开始BV号为187411f7ye视频属性的抓取
# BV号为187411f7ye的视频属性抓取结束
# 开始BV号为1bE411F7Nm视频属性的抓取
# BV号为1bE411F7Nm的视频属性抓取结束
# 开始BV号为1m741197YY视频属性的抓取
# 开始BV号为1m741197YY视频属性的抓取
# BV号为1m741197YY的视频属性抓取结束
# 开始BV号为1N7411f7ZG视频属性的抓取
# BV号为1N7411f7ZG的视频属性抓取结束
# 开始BV号为1e7411Z7tb视频属性的抓取
# BV号为1e7411Z7tb的视频属性抓取结束
# 开始BV号为1PE411N77N视频属性的抓取
# BV号为1PE411N77N的视频属性抓取结束
# 开始BV号为1oE41147Eu视频属性的抓取
# BV号为1oE41147Eu的视频属性抓取结束
# 开始BV号为11E411K7Vg视频属性的抓取
# BV号为11E411K7Vg的视频属性抓取结束
# 开始BV号为1ZE411G7zT视频属性的抓取
# BV号为1ZE411G7zT的视频属性抓取结束
# 开始BV号为1DE411V776视频属性的抓取
# BV号为1DE411V776的视频属性抓取结束
# 开始BV号为1rp4y117M2视频属性的抓取
# BV号为1rp4y117M2的视频属性抓取结束
# 开始BV号为1pE411T7ko视频属性的抓取
# BV号为1pE411T7ko的视频属性抓取结束
# 开始BV号为1hE411T7jm视频属性的抓取
# BV号为1hE411T7jm的视频属性抓取结束
# 开始BV号为1UE411H7pT视频属性的抓取
# 开始BV号为1UE411H7pT视频属性的抓取
# 开始BV号为1UE411H7pT视频属性的抓取
# 开始BV号为1UE411H7pT视频属性的抓取
# BV号为1UE411H7pT的视频属性抓取结束
# 开始BV号为1SE411c7zD视频属性的抓取
# BV号为1SE411c7zD的视频属性抓取结束
# 开始BV号为1r7411C7ES视频属性的抓取
# BV号为1r7411C7ES的视频属性抓取结束
# 开始BV号为1k7411m7Gj视频属性的抓取
# BV号为1k7411m7Gj的视频属性抓取结束
# 开始BV号为1Sc41187zG视频属性的抓取
# BV号为1Sc41187zG的视频属性抓取结束
# 开始BV号为14E41147NX视频属性的抓取
# BV号为14E41147NX的视频属性抓取结束
# 开始BV号为1iE411P7YZ视频属性的抓取
# BV号为1iE411P7YZ的视频属性抓取结束
# 开始BV号为1XE411P7cA视频属性的抓取
# BV号为1XE411P7cA的视频属性抓取结束
# 开始BV号为1zE411K7pY视频属性的抓取
# BV号为1zE411K7pY的视频属性抓取结束
# 开始BV号为1Z7411f7b3视频属性的抓取
# BV号为1Z7411f7b3的视频属性抓取结束
# 开始BV号为1K7411R7V3视频属性的抓取
# BV号为1K7411R7V3的视频属性抓取结束
# 开始BV号为1X7411m7F7视频属性的抓取
# BV号为1X7411m7F7的视频属性抓取结束
# 开始BV号为15E411T7o4视频属性的抓取
# BV号为15E411T7o4的视频属性抓取结束
# 开始BV号为187411d7UZ视频属性的抓取
# BV号为187411d7UZ的视频属性抓取结束
# 开始BV号为12E411g7Rc视频属性的抓取
# BV号为12E411g7Rc的视频属性抓取结束
# 开始BV号为1te411x7w3视频属性的抓取
# BV号为1te411x7w3的视频属性抓取结束
# 开始BV号为1a7411C7j2视频属性的抓取
# BV号为1a7411C7j2的视频属性抓取结束
# 开始BV号为1EE411F7Lg视频属性的抓取
# BV号为1EE411F7Lg的视频属性抓取结束
# 开始BV号为1V7411d72s视频属性的抓取
# BV号为1V7411d72s的视频属性抓取结束
# 开始BV号为1pE411W758视频属性的抓取
# BV号为1pE411W758的视频属性抓取结束
# 开始BV号为1ME411W7Tf视频属性的抓取
# BV号为1ME411W7Tf的视频属性抓取结束
# 开始BV号为1Qe411W74T视频属性的抓取
# BV号为1Qe411W74T的视频属性抓取结束
# 开始BV号为18Q4y1M7Mx视频属性的抓取
# BV号为18Q4y1M7Mx的视频属性抓取结束
# 开始BV号为1pe41147kj视频属性的抓取
# BV号为1pe41147kj的视频属性抓取结束
# 开始BV号为1bZ4y1j7yi视频属性的抓取
# BV号为1bZ4y1j7yi的视频属性抓取结束
# 开始BV号为1AT4y1G7rQ视频属性的抓取
# BV号为1AT4y1G7rQ的视频属性抓取结束
# 开始BV号为1fC4y1s7nD视频属性的抓取
# BV号为1fC4y1s7nD的视频属性抓取结束
# 开始BV号为14K41177m3视频属性的抓取
# BV号为14K41177m3的视频属性抓取结束
# 开始BV号为1k5411x7db视频属性的抓取
# BV号为1k5411x7db的视频属性抓取结束
# 开始BV号为1Uz411b7jx视频属性的抓取
# BV号为1Uz411b7jx的视频属性抓取结束
# 开始BV号为1t64y1T76w视频属性的抓取
# BV号为1t64y1T76w的视频属性抓取结束
# 开始BV号为1zK411L74y视频属性的抓取
# BV号为1zK411L74y的视频属性抓取结束
# 开始BV号为1z54y1Q7E9视频属性的抓取
# BV号为1z54y1Q7E9的视频属性抓取结束
# 开始BV号为1KA411b7Dm视频属性的抓取
# BV号为1KA411b7Dm的视频属性抓取结束
# 开始BV号为1RQ4y1K7Pj视频属性的抓取
# BV号为1RQ4y1K7Pj的视频属性抓取结束
# 开始BV号为1de411W7EF视频属性的抓取
# BV号为1de411W7EF的视频属性抓取结束
# 开始BV号为1he411x7cC视频属性的抓取
# BV号为1he411x7cC的视频属性抓取结束
# 开始BV号为1J64y1M7Mg视频属性的抓取
# BV号为1J64y1M7Mg的视频属性抓取结束
# 开始BV号为1Ck4y1R7rF视频属性的抓取
# BV号为1Ck4y1R7rF的视频属性抓取结束
# 开始BV号为1254y197H6视频属性的抓取
# BV号为1254y197H6的视频属性抓取结束
# 开始BV号为1564y1u724视频属性的抓取
# BV号为1564y1u724的视频属性抓取结束
# 开始BV号为1TV411o7yM视频属性的抓取
# BV号为1TV411o7yM的视频属性抓取结束
# 开始BV号为1BV411f7Q2视频属性的抓取
# BV号为1BV411f7Q2的视频属性抓取结束
# 开始BV号为11V411f74t视频属性的抓取
# BV号为11V411f74t的视频属性抓取结束
# 开始BV号为1GA411b7KX视频属性的抓取
# BV号为1GA411b7KX的视频属性抓取结束
# 开始BV号为1KA411874M视频属性的抓取
# BV号为1KA411874M的视频属性抓取结束
# 开始BV号为1Qk4y197Te视频属性的抓取
# BV号为1Qk4y197Te的视频属性抓取结束
# 开始BV号为1Ye411x7Ki视频属性的抓取
# BV号为1Ye411x7Ki的视频属性抓取结束
# 开始BV号为13p4y1y73Q视频属性的抓取
# BV号为13p4y1y73Q的视频属性抓取结束
# 开始BV号为11k4y1r7bN视频属性的抓取
# BV号为11k4y1r7bN的视频属性抓取结束
# 开始BV号为1JK411j7os视频属性的抓取
# BV号为1JK411j7os的视频属性抓取结束
# 开始BV号为1qk4y1R7yD视频属性的抓取
# BV号为1qk4y1R7yD的视频属性抓取结束
# 开始BV号为1UV411R7VU视频属性的抓取
# BV号为1UV411R7VU的视频属性抓取结束
# 开始BV号为1Rz411b7eA视频属性的抓取
# BV号为1Rz411b7eA的视频属性抓取结束
# 开始BV号为1RQ4y1K7FR视频属性的抓取
# BV号为1RQ4y1K7FR的视频属性抓取结束
# 开始BV号为1Z64y1M71z视频属性的抓取
# BV号为1Z64y1M71z的视频属性抓取结束
# 开始BV号为1DK411L7xT视频属性的抓取
# BV号为1DK411L7xT的视频属性抓取结束
# 开始BV号为15T4y157yT视频属性的抓取
# BV号为15T4y157yT的视频属性抓取结束
# 开始BV号为1Lk4y1R7nS视频属性的抓取
# BV号为1Lk4y1R7nS的视频属性抓取结束
# 开始BV号为11T4y1G7Ar视频属性的抓取
# BV号为11T4y1G7Ar的视频属性抓取结束
# 开始BV号为12A411b7L7视频属性的抓取
# BV号为12A411b7L7的视频属性抓取结束
# 开始BV号为1Bk4y197wk视频属性的抓取
# BV号为1Bk4y197wk的视频属性抓取结束
# 开始BV号为1nT4y1G7ss视频属性的抓取
# BV号为1nT4y1G7ss的视频属性抓取结束
# 开始BV号为1Ra4y1x7c3视频属性的抓取
# BV号为1Ra4y1x7c3的视频属性抓取结束
# 开始BV号为1J64y1u7Q7视频属性的抓取
# BV号为1J64y1u7Q7的视频属性抓取结束
# 开始BV号为1se411x7eG视频属性的抓取
# 开始BV号为1se411x7eG视频属性的抓取
# BV号为1se411x7eG的视频属性抓取结束
# 开始BV号为1UC4y1s7RY视频属性的抓取
# BV号为1UC4y1s7RY的视频属性抓取结束
# 开始BV号为18V411f79H视频属性的抓取
# BV号为18V411f79H的视频属性抓取结束
# 开始BV号为1Ng4y1a75M视频属性的抓取
# BV号为1Ng4y1a75M的视频属性抓取结束
# 开始BV号为1xg4y1z76S视频属性的抓取
# BV号为1xg4y1z76S的视频属性抓取结束
# 开始BV号为1TA411h7om视频属性的抓取
# BV号为1TA411h7om的视频属性抓取结束
# 开始BV号为1jT4y157os视频属性的抓取
# BV号为1jT4y157os的视频属性抓取结束
# 开始BV号为1c5411t7m9视频属性的抓取
# BV号为1c5411t7m9的视频属性抓取结束
# 开始BV号为1Di4y1b7Uc视频属性的抓取
# BV号为1Di4y1b7Uc的视频属性抓取结束
# 开始BV号为18i4y187BB视频属性的抓取
# BV号为18i4y187BB的视频属性抓取结束
# 开始BV号为1D64y1u7JS视频属性的抓取
# BV号为1D64y1u7JS的视频属性抓取结束
# 开始BV号为1Tz41187dq视频属性的抓取
# BV号为1Tz41187dq的视频属性抓取结束
# 开始BV号为1Gt4y127bE视频属性的抓取
# BV号为1Gt4y127bE的视频属性抓取结束
# 开始BV号为1ui4y1t7aR视频属性的抓取
# BV号为1ui4y1t7aR的视频属性抓取结束
# 开始BV号为1JQ4y1K7if视频属性的抓取
# BV号为1JQ4y1K7if的视频属性抓取结束
# 开始BV号为1rC4y1s7oA视频属性的抓取
# BV号为1rC4y1s7oA的视频属性抓取结束
# 开始BV号为1j64y1M7Br视频属性的抓取
# BV号为1j64y1M7Br的视频属性抓取结束
# 开始BV号为1MC4y1s7QP视频属性的抓取
# BV号为1MC4y1s7QP的视频属性抓取结束
# 开始BV号为1yK4y1r7Hw视频属性的抓取
# BV号为1yK4y1r7Hw的视频属性抓取结束
# 开始BV号为1tf4y1S7dD视频属性的抓取
# BV号为1tf4y1S7dD的视频属性抓取结束
# 开始BV号为1JZ4y1x7yz视频属性的抓取
# BV号为1JZ4y1x7yz的视频属性抓取结束
# 开始BV号为1u54y197b7视频属性的抓取
# BV号为1u54y197b7的视频属性抓取结束
# 开始BV号为1kC4y1s7ZK视频属性的抓取
# BV号为1kC4y1s7ZK的视频属性抓取结束
# 开始BV号为1v64y1T7av视频属性的抓取
# BV号为1v64y1T7av的视频属性抓取结束
# 开始BV号为1fg4y187D4视频属性的抓取
# BV号为1fg4y187D4的视频属性抓取结束
# 开始BV号为1kf4y1U7Wi视频属性的抓取
# BV号为1kf4y1U7Wi的视频属性抓取结束
# 开始BV号为1TK411j7A2视频属性的抓取
# BV号为1TK411j7A2的视频属性抓取结束
# 开始BV号为1P5411r7aA视频属性的抓取
# BV号为1P5411r7aA的视频属性抓取结束
# 开始BV号为1MZ4y1x7nw视频属性的抓取
# BV号为1MZ4y1x7nw的视频属性抓取结束
# 开始BV号为1HC4y1x7SJ视频属性的抓取
# BV号为1HC4y1x7SJ的视频属性抓取结束
# 开始BV号为1tp4y117TR视频属性的抓取
# BV号为1tp4y117TR的视频属性抓取结束
# 开始BV号为1ZK411V7oS视频属性的抓取
# BV号为1ZK411V7oS的视频属性抓取结束
# 开始BV号为1m541167cQ视频属性的抓取
# BV号为1m541167cQ的视频属性抓取结束
# 开始BV号为18p4y1X76c视频属性的抓取
# BV号为18p4y1X76c的视频属性抓取结束
# 开始BV号为1Fz411b7F5视频属性的抓取
# BV号为1Fz411b7F5的视频属性抓取结束
# 开始BV号为17T4y1G7iJ视频属性的抓取
# BV号为17T4y1G7iJ的视频属性抓取结束
# 开始BV号为1aa4y147dW视频属性的抓取
# BV号为1aa4y147dW的视频属性抓取结束
# 开始BV号为1kk4y1d7f5视频属性的抓取
# BV号为1kk4y1d7f5的视频属性抓取结束
# 开始BV号为14K4y1k7Rb视频属性的抓取
# BV号为14K4y1k7Rb的视频属性抓取结束
# 开始BV号为1ng4y1z75G视频属性的抓取
# BV号为1ng4y1z75G的视频属性抓取结束
# 开始BV号为1Ne411s7UN视频属性的抓取
# BV号为1Ne411s7UN的视频属性抓取结束
# 开始BV号为1pV411f7hi视频属性的抓取
# BV号为1pV411f7hi的视频属性抓取结束
# 开始BV号为1JQ4y1T7ej视频属性的抓取
# BV号为1JQ4y1T7ej的视频属性抓取结束
# 开始BV号为1Ti4y1t7NC视频属性的抓取
# BV号为1Ti4y1t7NC的视频属性抓取结束
# 开始BV号为1pV411f7JV视频属性的抓取
# BV号为1pV411f7JV的视频属性抓取结束
# 开始BV号为1k64y1M7df视频属性的抓取
# BV号为1k64y1M7df的视频属性抓取结束
# 开始BV号为1i64y1M7AY视频属性的抓取
# BV号为1i64y1M7AY的视频属性抓取结束
# 开始BV号为1954y1R79N视频属性的抓取
# BV号为1954y1R79N的视频属性抓取结束
# 开始BV号为1Nt4y1U7Dg视频属性的抓取
# BV号为1Nt4y1U7Dg的视频属性抓取结束
# 开始BV号为1d64y1M79Q视频属性的抓取
# BV号为1d64y1M79Q的视频属性抓取结束
# 开始BV号为1qf4y1U7p4视频属性的抓取
# BV号为1qf4y1U7p4的视频属性抓取结束
# 开始BV号为1h54y197fL视频属性的抓取
# BV号为1h54y197fL的视频属性抓取结束
# 开始BV号为1Gg4y187jY视频属性的抓取
# BV号为1Gg4y187jY的视频属性抓取结束
# 开始BV号为1sQ4y1T77k视频属性的抓取
# 开始BV号为1sQ4y1T77k视频属性的抓取
# BV号为1sQ4y1T77k的视频属性抓取结束
# 开始BV号为1rg4y187EA视频属性的抓取
# BV号为1rg4y187EA的视频属性抓取结束
# 开始BV号为1pa4y147cR视频属性的抓取
# BV号为1pa4y147cR的视频属性抓取结束
# 开始BV号为1B54y1X7Jk视频属性的抓取
# BV号为1B54y1X7Jk的视频属性抓取结束
# 开始BV号为1Mt4y117os视频属性的抓取
# BV号为1Mt4y117os的视频属性抓取结束
# 开始BV号为1og4y1B7eF视频属性的抓取
# BV号为1og4y1B7eF的视频属性抓取结束
# 开始BV号为1a54y1D7td视频属性的抓取
# BV号为1a54y1D7td的视频属性抓取结束
# 开始BV号为135411s74Y视频属性的抓取
# BV号为135411s74Y的视频属性抓取结束
# 开始BV号为14e411W7kc视频属性的抓取
# BV号为14e411W7kc的视频属性抓取结束
# 开始BV号为1Nf4y1U7AD视频属性的抓取
# BV号为1Nf4y1U7AD的视频属性抓取结束
# 开始BV号为1vt4y1C7oy视频属性的抓取
# BV号为1vt4y1C7oy的视频属性抓取结束
# 开始BV号为14f4y127g7视频属性的抓取
# BV号为14f4y127g7的视频属性抓取结束
# 开始BV号为1gt4y117iN视频属性的抓取
# BV号为1gt4y117iN的视频属性抓取结束
# 开始BV号为1Re411p75S视频属性的抓取
# BV号为1Re411p75S的视频属性抓取结束
# 开始BV号为1SA411t7sj视频属性的抓取
# BV号为1SA411t7sj的视频属性抓取结束
# 开始BV号为1Wv411z78r视频属性的抓取
# BV号为1Wv411z78r的视频属性抓取结束
# 开始BV号为1Kf4y1272H视频属性的抓取
# BV号为1Kf4y1272H的视频属性抓取结束
# 开始BV号为18t4y1C7bh视频属性的抓取
# BV号为18t4y1C7bh的视频属性抓取结束
# 开始BV号为1sa4y1e7zf视频属性的抓取
# BV号为1sa4y1e7zf的视频属性抓取结束
# 开始BV号为17K4y1t7qb视频属性的抓取
# BV号为17K4y1t7qb的视频属性抓取结束
# 开始BV号为1zZ4y1p74L视频属性的抓取
# BV号为1zZ4y1p74L的视频属性抓取结束
# 开始BV号为1Xa4y1i7VC视频属性的抓取
# BV号为1Xa4y1i7VC的视频属性抓取结束
# 开始BV号为16K411W7pJ视频属性的抓取
# BV号为16K411W7pJ的视频属性抓取结束
# 开始BV号为1vC4y1p73p视频属性的抓取
# BV号为1vC4y1p73p的视频属性抓取结束
# 开始BV号为1kA411q7on视频属性的抓取
# BV号为1kA411q7on的视频属性抓取结束
# 开始BV号为1Hp4y1Q7kb视频属性的抓取
# BV号为1Hp4y1Q7kb的视频属性抓取结束
# 开始BV号为1WT4y1u7pi视频属性的抓取
# BV号为1WT4y1u7pi的视频属性抓取结束
# 开始BV号为1oV411C7ir视频属性的抓取
# BV号为1oV411C7ir的视频属性抓取结束
# 开始BV号为1Gk4y1k7WZ视频属性的抓取
# BV号为1Gk4y1k7WZ的视频属性抓取结束
# 开始BV号为1ZT4y1u7tb视频属性的抓取
# BV号为1ZT4y1u7tb的视频属性抓取结束
# 开始BV号为1Ck4y167tH视频属性的抓取
# BV号为1Ck4y167tH的视频属性抓取结束
# 开始BV号为1R54y1X7KJ视频属性的抓取
# BV号为1R54y1X7KJ的视频属性抓取结束
# 开始BV号为1G5411473L视频属性的抓取
# BV号为1G5411473L的视频属性抓取结束
# 开始BV号为1af4y1m7iW视频属性的抓取
# BV号为1af4y1m7iW的视频属性抓取结束
# 开始BV号为18K4y187nB视频属性的抓取
# BV号为18K4y187nB的视频属性抓取结束
# 开始BV号为1oa4y1e7Mb视频属性的抓取
# BV号为1oa4y1e7Mb的视频属性抓取结束
# 开始BV号为1s5411s7Vg视频属性的抓取
# BV号为1s5411s7Vg的视频属性抓取结束
# 开始BV号为1SK411H7QK视频属性的抓取
# BV号为1SK411H7QK的视频属性抓取结束
# 开始BV号为1wK4y1b7Wk视频属性的抓取
# BV号为1wK4y1b7Wk的视频属性抓取结束
# 开始BV号为12p4y1Q7EQ视频属性的抓取
# BV号为12p4y1Q7EQ的视频属性抓取结束
# 开始BV号为1Nz411i7Kv视频属性的抓取
# BV号为1Nz411i7Kv的视频属性抓取结束
# 开始BV号为1S5411s79U视频属性的抓取
# BV号为1S5411s79U的视频属性抓取结束
# 开始BV号为1d54y1X7gk视频属性的抓取
# BV号为1d54y1X7gk的视频属性抓取结束
# 开始BV号为1Rg4y1B7uY视频属性的抓取
# BV号为1Rg4y1B7uY的视频属性抓取结束
# 开始BV号为11i4y147TJ视频属性的抓取
# BV号为11i4y147TJ的视频属性抓取结束
# 开始BV号为1r5411s7KN视频属性的抓取
# BV号为1r5411s7KN的视频属性抓取结束
# 开始BV号为1Xt4y1y7gX视频属性的抓取
# BV号为1Xt4y1y7gX的视频属性抓取结束
# 开始BV号为1P5411s77B视频属性的抓取
# BV号为1P5411s77B的视频属性抓取结束
# 开始BV号为1Xi4y14743视频属性的抓取
# BV号为1Xi4y14743的视频属性抓取结束
# 开始BV号为1yK4y1t7w8视频属性的抓取
# BV号为1yK4y1t7w8的视频属性抓取结束
# 开始BV号为1B5411s7XH视频属性的抓取
# BV号为1B5411s7XH的视频属性抓取结束
# 开始BV号为1mT4y137bF视频属性的抓取
# BV号为1mT4y137bF的视频属性抓取结束
# 开始BV号为1SA411t74W视频属性的抓取
# BV号为1SA411t74W的视频属性抓取结束
# 开始BV号为1iK4y1t77x视频属性的抓取
# BV号为1iK4y1t77x的视频属性抓取结束
# 开始BV号为1RZ4y1s7Cy视频属性的抓取
# BV号为1RZ4y1s7Cy的视频属性抓取结束
# 开始BV号为1mK41157yK视频属性的抓取
# BV号为1mK41157yK的视频属性抓取结束
# 开始BV号为1rQ4y1A7Ac视频属性的抓取
# BV号为1rQ4y1A7Ac的视频属性抓取结束
# 开始BV号为17v411z7xN视频属性的抓取
# BV号为17v411z7xN的视频属性抓取结束
# 开始BV号为1Nz411i77C视频属性的抓取
# BV号为1Nz411i77C的视频属性抓取结束
# 开始BV号为1Nz411B7XV视频属性的抓取
# BV号为1Nz411B7XV的视频属性抓取结束
# 开始BV号为1PK4y1t72q视频属性的抓取
# BV号为1PK4y1t72q的视频属性抓取结束
# 开始BV号为1oz4y1X7Rv视频属性的抓取
# BV号为1oz4y1X7Rv的视频属性抓取结束
# 开始BV号为1ci4y1t7T3视频属性的抓取
# BV号为1ci4y1t7T3的视频属性抓取结束
# 开始BV号为1bT4y1u7yK视频属性的抓取
# BV号为1bT4y1u7yK的视频属性抓取结束
# 开始BV号为13K4y187pL视频属性的抓取
# BV号为13K4y187pL的视频属性抓取结束
# 开始BV号为1aC4y1H7pe视频属性的抓取
# BV号为1aC4y1H7pe的视频属性抓取结束
# 开始BV号为1GT4y1g7DN视频属性的抓取
# BV号为1GT4y1g7DN的视频属性抓取结束
# 开始BV号为1C5411s7wL视频属性的抓取
# BV号为1C5411s7wL的视频属性抓取结束
# 开始BV号为1n5411s758视频属性的抓取
# BV号为1n5411s758的视频属性抓取结束
# 开始BV号为19A41147kb视频属性的抓取
# BV号为19A41147kb的视频属性抓取结束
# 开始BV号为1KQ4y1P7f1视频属性的抓取
# BV号为1KQ4y1P7f1的视频属性抓取结束
# 开始BV号为1JC4y1p7Ez视频属性的抓取
# BV号为1JC4y1p7Ez的视频属性抓取结束
# 开始BV号为1yQ4y1A7Fd视频属性的抓取
# BV号为1yQ4y1A7Fd的视频属性抓取结束
# 开始BV号为135411s7JE视频属性的抓取
# BV号为135411s7JE的视频属性抓取结束
# 开始BV号为1qA411q7m9视频属性的抓取
# BV号为1qA411q7m9的视频属性抓取结束
# 开始BV号为1GZ4y1W7cQ视频属性的抓取
# BV号为1GZ4y1W7cQ的视频属性抓取结束
# 开始BV号为1wZ4y1W7R9视频属性的抓取
# BV号为1wZ4y1W7R9的视频属性抓取结束
# 开始BV号为1wA411q7De视频属性的抓取
# BV号为1wA411q7De的视频属性抓取结束
# 开始BV号为1kt4y117n3视频属性的抓取
# BV号为1kt4y117n3的视频属性抓取结束
# 开始BV号为1rK4y1t7XW视频属性的抓取
# BV号为1rK4y1t7XW的视频属性抓取结束
# 开始BV号为1wp4y1X7vM视频属性的抓取
# BV号为1wp4y1X7vM的视频属性抓取结束
# 开始BV号为17p4y1Q7MS视频属性的抓取
# BV号为17p4y1Q7MS的视频属性抓取结束
# 开始BV号为1kQ4y1A7MQ视频属性的抓取
# BV号为1kQ4y1A7MQ的视频属性抓取结束
# 开始BV号为1dg4y1q7hK视频属性的抓取
# BV号为1dg4y1q7hK的视频属性抓取结束
# 开始BV号为1QA411q7cx视频属性的抓取
# BV号为1QA411q7cx的视频属性抓取结束
# 开始BV号为12t4y1y7iA视频属性的抓取
# BV号为12t4y1y7iA的视频属性抓取结束
# 开始BV号为1ni4y147kz视频属性的抓取
# BV号为1ni4y147kz的视频属性抓取结束
# 开始BV号为15k4y1r7A1视频属性的抓取
# BV号为15k4y1r7A1的视频属性抓取结束
# 开始BV号为1pf4y1U7EG视频属性的抓取
# BV号为1pf4y1U7EG的视频属性抓取结束
# 开始BV号为1kK411W7N4视频属性的抓取
# BV号为1kK411W7N4的视频属性抓取结束
# 开始BV号为16a4y1e7PM视频属性的抓取
# BV号为16a4y1e7PM的视频属性抓取结束
# 开始BV号为155411s7o1视频属性的抓取
# BV号为155411s7o1的视频属性抓取结束
# 开始BV号为1Pf4y1U7sT视频属性的抓取
# BV号为1Pf4y1U7sT的视频属性抓取结束
# 开始BV号为1ji4y147Z3视频属性的抓取
# BV号为1ji4y147Z3的视频属性抓取结束
# 开始BV号为1Pp4y1X73p视频属性的抓取
# BV号为1Pp4y1X73p的视频属性抓取结束
# 开始BV号为1y54y1X79R视频属性的抓取
# BV号为1y54y1X79R的视频属性抓取结束
# 开始BV号为1ie411W7xC视频属性的抓取
# BV号为1ie411W7xC的视频属性抓取结束
# 开始BV号为1D5411s7Z7视频属性的抓取
# BV号为1D5411s7Z7的视频属性抓取结束
# 开始BV号为1WK4y1t7nh视频属性的抓取
# BV号为1WK4y1t7nh的视频属性抓取结束
# 开始BV号为1Xz411v7da视频属性的抓取
# BV号为1Xz411v7da的视频属性抓取结束
# 开始BV号为1Ut4y1y7TL视频属性的抓取
# BV号为1Ut4y1y7TL的视频属性抓取结束
# 开始BV号为1Vg4y1B7pM视频属性的抓取
# BV号为1Vg4y1B7pM的视频属性抓取结束
# 开始BV号为1NV411C7wS视频属性的抓取
# BV号为1NV411C7wS的视频属性抓取结束
# 开始BV号为1Fk4y167CC视频属性的抓取
# BV号为1Fk4y167CC的视频属性抓取结束
# 开始BV号为1sV41167ow视频属性的抓取
# BV号为1sV41167ow的视频属性抓取结束
# 开始BV号为1pV411r7UR视频属性的抓取
# BV号为1pV411r7UR的视频属性抓取结束
# 开始BV号为13g4y1q7aR视频属性的抓取
# BV号为13g4y1q7aR的视频属性抓取结束
# 开始BV号为1HZ4y1H7PJ视频属性的抓取
# BV号为1HZ4y1H7PJ的视频属性抓取结束
# 开始BV号为1Ui4y1s7cQ视频属性的抓取
# BV号为1Ui4y1s7cQ的视频属性抓取结束
# 开始BV号为1Vi4y1x7Xd视频属性的抓取
# BV号为1Vi4y1x7Xd的视频属性抓取结束
# 开始BV号为1gz411v77h视频属性的抓取
# BV号为1gz411v77h的视频属性抓取结束
# 开始BV号为1UV411r7MR视频属性的抓取
# BV号为1UV411r7MR的视频属性抓取结束
# 开始BV号为1LK411H724视频属性的抓取
# BV号为1LK411H724的视频属性抓取结束
# 开始BV号为1Yf4y117mG视频属性的抓取
# BV号为1Yf4y117mG的视频属性抓取结束
# 开始BV号为1jv411B7fn视频属性的抓取
# BV号为1jv411B7fn的视频属性抓取结束
# 开始BV号为18a4y1Y7mL视频属性的抓取
# BV号为18a4y1Y7mL的视频属性抓取结束
# 开始BV号为1gC4y1a76q视频属性的抓取
# BV号为1gC4y1a76q的视频属性抓取结束
# 开始BV号为1ap4y1D7J7视频属性的抓取
# BV号为1ap4y1D7J7的视频属性抓取结束
# 开始BV号为1MD4y1S7e8视频属性的抓取
# BV号为1MD4y1S7e8的视频属性抓取结束
# 开始BV号为1Ag4y1v7Zt视频属性的抓取
# BV号为1Ag4y1v7Zt的视频属性抓取结束
# 开始BV号为1ET4y1J7jc视频属性的抓取
# BV号为1ET4y1J7jc的视频属性抓取结束
# 开始BV号为1nk4y1r74P视频属性的抓取
# BV号为1nk4y1r74P的视频属性抓取结束
# 开始BV号为1XA411q7FJ视频属性的抓取
# BV号为1XA411q7FJ的视频属性抓取结束
# 开始BV号为1fk4y1z7Jr视频属性的抓取
# BV号为1fk4y1z7Jr的视频属性抓取结束
# 开始BV号为1Mg4y1q7qJ视频属性的抓取
# BV号为1Mg4y1q7qJ的视频属性抓取结束
# 开始BV号为1Wv411672L视频属性的抓取
# BV号为1Wv411672L的视频属性抓取结束
# 开始BV号为1Vk4y1z7DG视频属性的抓取
# BV号为1Vk4y1z7DG的视频属性抓取结束
# 开始BV号为1A5411Y7ph视频属性的抓取
# BV号为1A5411Y7ph的视频属性抓取结束
# 开始BV号为1Bk4y1z7dF视频属性的抓取
# BV号为1Bk4y1z7dF的视频属性抓取结束
# 开始BV号为1ri4y1s7we视频属性的抓取
# BV号为1ri4y1s7we的视频属性抓取结束
# 开始BV号为1ig4y1i7ES视频属性的抓取
# BV号为1ig4y1i7ES的视频属性抓取结束
# 开始BV号为1pz411i7xh视频属性的抓取
# BV号为1pz411i7xh的视频属性抓取结束
# 开始BV号为1Na4y1Y7oy视频属性的抓取
# BV号为1Na4y1Y7oy的视频属性抓取结束
# 开始BV号为1Jk4y1r7sD视频属性的抓取
# BV号为1Jk4y1r7sD的视频属性抓取结束
# 开始BV号为1Dv411z7jQ视频属性的抓取
# BV号为1Dv411z7jQ的视频属性抓取结束
# 开始BV号为1Tg4y1q7Cu视频属性的抓取
# BV号为1Tg4y1q7Cu的视频属性抓取结束
# 开始BV号为13z4y1X7f9视频属性的抓取
# BV号为13z4y1X7f9的视频属性抓取结束
# 开始BV号为1L54y1z7B6视频属性的抓取
# BV号为1L54y1z7B6的视频属性抓取结束
# 开始BV号为1o54y1B79P视频属性的抓取
# BV号为1o54y1B79P的视频属性抓取结束
# 开始BV号为12V411r7Rz视频属性的抓取
# BV号为12V411r7Rz的视频属性抓取结束
# 开始BV号为1N5411Y73S视频属性的抓取
# BV号为1N5411Y73S的视频属性抓取结束
# 开始BV号为1wz411i7Hf视频属性的抓取
# BV号为1wz411i7Hf的视频属性抓取结束
# 开始BV号为1S5411p7ga视频属性的抓取
# BV号为1S5411p7ga的视频属性抓取结束
# 开始BV号为1BT4y1J7yp视频属性的抓取
# BV号为1BT4y1J7yp的视频属性抓取结束
# 开始BV号为1AZ4y1p7gU视频属性的抓取
# BV号为1AZ4y1p7gU的视频属性抓取结束
# 开始BV号为1Wk4y1r7Ah视频属性的抓取
# BV号为1Wk4y1r7Ah的视频属性抓取结束
# 开始BV号为1UV411r7qz视频属性的抓取
# BV号为1UV411r7qz的视频属性抓取结束
# 开始BV号为1Df4y117kp视频属性的抓取
# BV号为1Df4y117kp的视频属性抓取结束
# 开始BV号为1Tp4y1Q7Lr视频属性的抓取
# BV号为1Tp4y1Q7Lr的视频属性抓取结束
# 开始BV号为1U54y1B7VG视频属性的抓取
# BV号为1U54y1B7VG的视频属性抓取结束
# 开始BV号为14D4y1Q7qp视频属性的抓取
# BV号为14D4y1Q7qp的视频属性抓取结束
# 开始BV号为14z411i7Nb视频属性的抓取
# BV号为14z411i7Nb的视频属性抓取结束
# 开始BV号为1t54y1z7Mx视频属性的抓取
# BV号为1t54y1z7Mx的视频属性抓取结束
# 开始BV号为1WT4y1J7xt视频属性的抓取
# BV号为1WT4y1J7xt的视频属性抓取结束
# 开始BV号为1YK411n73x视频属性的抓取
# BV号为1YK411n73x的视频属性抓取结束
# 开始BV号为1iK411n7oF视频属性的抓取
# BV号为1iK411n7oF的视频属性抓取结束
# 开始BV号为1Si4y1s74B视频属性的抓取
# BV号为1Si4y1s74B的视频属性抓取结束
# 开始BV号为1zK411p7J9视频属性的抓取
# BV号为1zK411p7J9的视频属性抓取结束
# 开始BV号为1LT4y1J7fS视频属性的抓取
# BV号为1LT4y1J7fS的视频属性抓取结束
# 开始BV号为1NC4y1h7jH视频属性的抓取
# BV号为1NC4y1h7jH的视频属性抓取结束
# 开始BV号为1N54y1Q7ya视频属性的抓取
# BV号为1N54y1Q7ya的视频属性抓取结束
# 开始BV号为1RK411p7zq视频属性的抓取
# BV号为1RK411p7zq的视频属性抓取结束
# 开始BV号为1of4y1274z视频属性的抓取
# BV号为1of4y1274z的视频属性抓取结束
# 开始BV号为15v411673c视频属性的抓取
# BV号为15v411673c的视频属性抓取结束
# 开始BV号为1Hg4y1q7do视频属性的抓取
# BV号为1Hg4y1q7do的视频属性抓取结束
# 开始BV号为1bv41167XC视频属性的抓取
# BV号为1bv41167XC的视频属性抓取结束
# 开始BV号为1iz411e7hi视频属性的抓取
# BV号为1iz411e7hi的视频属性抓取结束
# 开始BV号为1Sk4y1q7DB视频属性的抓取
# BV号为1Sk4y1q7DB的视频属性抓取结束
# 开始BV号为1jT4y1J7Kx视频属性的抓取
# BV号为1jT4y1J7Kx的视频属性抓取结束
# 开始BV号为1mf4y127KL视频属性的抓取
# BV号为1mf4y127KL的视频属性抓取结束
# 开始BV号为1gf4y1m7cY视频属性的抓取
# BV号为1gf4y1m7cY的视频属性抓取结束
# 开始BV号为18A411i7gF视频属性的抓取
# BV号为18A411i7gF的视频属性抓取结束
# 开始BV号为1KA411B7TN视频属性的抓取
# BV号为1KA411B7TN的视频属性抓取结束
# 开始BV号为1ek4y1z7XQ视频属性的抓取
# BV号为1ek4y1z7XQ的视频属性抓取结束
# 开始BV号为1sC4y1a7ko视频属性的抓取
# BV号为1sC4y1a7ko的视频属性抓取结束
# 开始BV号为1pi4y1G7fn视频属性的抓取
# BV号为1pi4y1G7fn的视频属性抓取结束
# 开始BV号为1Kf4y117bw视频属性的抓取
# BV号为1Kf4y117bw的视频属性抓取结束
# 开始BV号为12Q4y1P778视频属性的抓取
# BV号为12Q4y1P778的视频属性抓取结束
# 开始BV号为1rK4y147WX视频属性的抓取
# BV号为1rK4y147WX的视频属性抓取结束
# 开始BV号为1Zv411q7kf视频属性的抓取
# BV号为1Zv411q7kf的视频属性抓取结束
# 开始BV号为1zA411v7mZ视频属性的抓取
# BV号为1zA411v7mZ的视频属性抓取结束
# 开始BV号为1gA411i7bj视频属性的抓取
# BV号为1gA411i7bj的视频属性抓取结束
# 开始BV号为1gA411i71g视频属性的抓取
# 开始BV号为1gA411i71g视频属性的抓取
# 开始BV号为1gA411i71g视频属性的抓取
# BV号为1gA411i71g的视频属性抓取结束
# 开始BV号为1rt4y1X7Yx视频属性的抓取
# BV号为1rt4y1X7Yx的视频属性抓取结束
# 开始BV号为1vz411i7NJ视频属性的抓取
# BV号为1vz411i7NJ的视频属性抓取结束
# 开始BV号为135411W7sd视频属性的抓取
# BV号为135411W7sd的视频属性抓取结束
# 开始BV号为1hg4y1q7hp视频属性的抓取
# BV号为1hg4y1q7hp的视频属性抓取结束
# 开始BV号为1Pp4y1D72K视频属性的抓取
# BV号为1Pp4y1D72K的视频属性抓取结束
# 开始BV号为1wZ4y1H7Jv视频属性的抓取
# BV号为1wZ4y1H7Jv的视频属性抓取结束
# 开始BV号为1kK411p7oi视频属性的抓取
# BV号为1kK411p7oi的视频属性抓取结束
# 开始BV号为1QC4y1h7GR视频属性的抓取
# BV号为1QC4y1h7GR的视频属性抓取结束
# 开始BV号为1sD4y1Q7z3视频属性的抓取
# BV号为1sD4y1Q7z3的视频属性抓取结束
# 开始BV号为1jv41167a5视频属性的抓取
# BV号为1jv41167a5的视频属性抓取结束
# 开始BV号为1yt4y1X7Xi视频属性的抓取
# BV号为1yt4y1X7Xi的视频属性抓取结束
# 开始BV号为18C4y1a7Xo视频属性的抓取
# BV号为18C4y1a7Xo的视频属性抓取结束
# 开始BV号为1jK411p7wn视频属性的抓取
# BV号为1jK411p7wn的视频属性抓取结束
# 开始BV号为1Sp4y1S7tX视频属性的抓取
# BV号为1Sp4y1S7tX的视频属性抓取结束
# 开始BV号为1cC4y1Y7wg视频属性的抓取
# BV号为1cC4y1Y7wg的视频属性抓取结束
# 开始BV号为1WT4y1g7FL视频属性的抓取
# BV号为1WT4y1g7FL的视频属性抓取结束
# 开始BV号为1MD4y1Q7Gk视频属性的抓取
# BV号为1MD4y1Q7Gk的视频属性抓取结束
# 开始BV号为1jZ4y1W72d视频属性的抓取
# BV号为1jZ4y1W72d的视频属性抓取结束
# 开始BV号为1Gp4y1D7UA视频属性的抓取
# BV号为1Gp4y1D7UA的视频属性抓取结束
# 开始BV号为1aK411p7La视频属性的抓取
# BV号为1aK411p7La的视频属性抓取结束
# 开始BV号为1qz411v7Kt视频属性的抓取
# BV号为1qz411v7Kt的视频属性抓取结束
# 开始BV号为1oT4y1L7K2视频属性的抓取
# BV号为1oT4y1L7K2的视频属性抓取结束
# 开始BV号为1rt4y197vF视频属性的抓取
# BV号为1rt4y197vF的视频属性抓取结束
# 开始BV号为17a4y1a7r4视频属性的抓取
# BV号为17a4y1a7r4的视频属性抓取结束
# 开始BV号为1ii4y1G785视频属性的抓取
# BV号为1ii4y1G785的视频属性抓取结束
# 开始BV号为1VC4y187JK视频属性的抓取
# BV号为1VC4y187JK的视频属性抓取结束
# 开始BV号为1FZ4y1p7Kh视频属性的抓取
# BV号为1FZ4y1p7Kh的视频属性抓取结束
# 开始BV号为17K411J7VZ视频属性的抓取
# BV号为17K411J7VZ的视频属性抓取结束
# 开始BV号为1Xi4y137q3视频属性的抓取
# BV号为1Xi4y137q3的视频属性抓取结束
# 开始BV号为1FA411Y7Re视频属性的抓取
# BV号为1FA411Y7Re的视频属性抓取结束
# 开始BV号为1Hg4y1i727视频属性的抓取
# BV号为1Hg4y1i727的视频属性抓取结束
# 开始BV号为1cT4y177GQ视频属性的抓取
# BV号为1cT4y177GQ的视频属性抓取结束
# 开始BV号为1iV411z79H视频属性的抓取
# BV号为1iV411z79H的视频属性抓取结束
# 开始BV号为1ft4y197ah视频属性的抓取
# BV号为1ft4y197ah的视频属性抓取结束
# 开始BV号为1Vv411z7rc视频属性的抓取
# BV号为1Vv411z7rc的视频属性抓取结束
# 开始BV号为1XA411a7m4视频属性的抓取
# BV号为1XA411a7m4的视频属性抓取结束
# 开始BV号为11z4y1X7yQ视频属性的抓取
# BV号为11z4y1X7yQ的视频属性抓取结束
# 开始BV号为1sA411e76g视频属性的抓取
# BV号为1sA411e76g的视频属性抓取结束
# 开始BV号为1wZ4y1u7yA视频属性的抓取
# 开始BV号为1wZ4y1u7yA视频属性的抓取
# BV号为1wZ4y1u7yA的视频属性抓取结束
# 开始BV号为1Mv411q7tn视频属性的抓取
# BV号为1Mv411q7tn的视频属性抓取结束
# 开始BV号为1ZZ4y1T79s视频属性的抓取
# BV号为1ZZ4y1T79s的视频属性抓取结束
# 开始BV号为1xv411B7Vu视频属性的抓取
# BV号为1xv411B7Vu的视频属性抓取结束
# 开始BV号为1xA411v7iN视频属性的抓取
# BV号为1xA411v7iN的视频属性抓取结束
# 开始BV号为1vK4y1s7CJ视频属性的抓取
# BV号为1vK4y1s7CJ的视频属性抓取结束
# 开始BV号为14K4y1x7vc视频属性的抓取
# BV号为14K4y1x7vc的视频属性抓取结束
# 开始BV号为1mt4y197Nt视频属性的抓取
# BV号为1mt4y197Nt的视频属性抓取结束
# 开始BV号为1dZ4y1H7P2视频属性的抓取
# BV号为1dZ4y1H7P2的视频属性抓取结束
# 开始BV号为1BD4y1Q7u4视频属性的抓取
# BV号为1BD4y1Q7u4的视频属性抓取结束
# 开始BV号为1LT4y1E7oT视频属性的抓取
# BV号为1LT4y1E7oT的视频属性抓取结束
# 开始BV号为1yV41167fV视频属性的抓取
# BV号为1yV41167fV的视频属性抓取结束
# 开始BV号为14z4y1X7bW视频属性的抓取
# BV号为14z4y1X7bW的视频属性抓取结束
# 开始BV号为1wp4y1S7UA视频属性的抓取
# BV号为1wp4y1S7UA的视频属性抓取结束
# 开始BV号为1iV411k7Rz视频属性的抓取
# BV号为1iV411k7Rz的视频属性抓取结束
# 开始BV号为1ez4y1X7sC视频属性的抓取
# BV号为1ez4y1X7sC的视频属性抓取结束
# 开始BV号为1N54y1B7uo视频属性的抓取
# BV号为1N54y1B7uo的视频属性抓取结束
# 开始BV号为1a54y1q727视频属性的抓取
# BV号为1a54y1q727的视频属性抓取结束
# 开始BV号为1Qv411B7HX视频属性的抓取
# BV号为1Qv411B7HX的视频属性抓取结束
# 开始BV号为1nz4y1Q7w6视频属性的抓取
# BV号为1nz4y1Q7w6的视频属性抓取结束
# 开始BV号为1rD4y1m7bx视频属性的抓取
# BV号为1rD4y1m7bx的视频属性抓取结束
# 开始BV号为1Yi4y1V73z视频属性的抓取
# BV号为1Yi4y1V73z的视频属性抓取结束
# 开始BV号为1bt4y1D78x视频属性的抓取
# BV号为1bt4y1D78x的视频属性抓取结束
# 开始BV号为1bk4y1B7Ee视频属性的抓取
# BV号为1bk4y1B7Ee的视频属性抓取结束
# 开始BV号为1PK4y1x7Gx视频属性的抓取
# BV号为1PK4y1x7Gx的视频属性抓取结束
# 开始BV号为1qZ4y1u77x视频属性的抓取
# BV号为1qZ4y1u77x的视频属性抓取结束
# 开始BV号为1iT4y1j77h视频属性的抓取
# BV号为1iT4y1j77h的视频属性抓取结束
# 开始BV号为1K54y1D79o视频属性的抓取
# BV号为1K54y1D79o的视频属性抓取结束
# 开始BV号为1MC4y1b7Fn视频属性的抓取
# BV号为1MC4y1b7Fn的视频属性抓取结束
# 开始BV号为1Az4y1Q7ru视频属性的抓取
# BV号为1Az4y1Q7ru的视频属性抓取结束
# 开始BV号为1ZT4y1L7DZ视频属性的抓取
# BV号为1ZT4y1L7DZ的视频属性抓取结束
# 开始BV号为1Qa4y1Y7FR视频属性的抓取
# BV号为1Qa4y1Y7FR的视频属性抓取结束
# 开始BV号为1cD4y1D7Nq视频属性的抓取
# 开始BV号为1cD4y1D7Nq视频属性的抓取
# BV号为1cD4y1D7Nq的视频属性抓取结束
# 开始BV号为1ok4y1z7M6视频属性的抓取
# BV号为1ok4y1z7M6的视频属性抓取结束
# 开始BV号为1D5411h7Eh视频属性的抓取
# BV号为1D5411h7Eh的视频属性抓取结束
# 开始BV号为15K411J7fd视频属性的抓取
# BV号为15K411J7fd的视频属性抓取结束
# 开始BV号为1nk4y1m7mV视频属性的抓取
# BV号为1nk4y1m7mV的视频属性抓取结束
# 开始BV号为1MV411z7gs视频属性的抓取
# 开始BV号为1MV411z7gs视频属性的抓取
# BV号为1MV411z7gs的视频属性抓取结束
# 开始BV号为1gK4y1v7Wm视频属性的抓取
# BV号为1gK4y1v7Wm的视频属性抓取结束
# 开始BV号为1ct4y1X75J视频属性的抓取
# BV号为1ct4y1X75J的视频属性抓取结束
# 开始BV号为1kD4y1m7xS视频属性的抓取
# BV号为1kD4y1m7xS的视频属性抓取结束
# 开始BV号为1bz4y1X78S视频属性的抓取
# BV号为1bz4y1X78S的视频属性抓取结束
# 开始BV号为1dg4y1v7PZ视频属性的抓取
# BV号为1dg4y1v7PZ的视频属性抓取结束
# 开始BV号为1rv411B7yG视频属性的抓取
# BV号为1rv411B7yG的视频属性抓取结束
# 开始BV号为1jz4y1D7sE视频属性的抓取
# BV号为1jz4y1D7sE的视频属性抓取结束
# 开始BV号为1Xz411e7Cw视频属性的抓取
# BV号为1Xz411e7Cw的视频属性抓取结束
# 开始BV号为1hK4y1x7EV视频属性的抓取
# BV号为1hK4y1x7EV的视频属性抓取结束
# 开始BV号为1yC4y1b7xU视频属性的抓取
# BV号为1yC4y1b7xU的视频属性抓取结束
# 开始BV号为1Zp4y1U77V视频属性的抓取
# BV号为1Zp4y1U77V的视频属性抓取结束
# 开始BV号为1RV411B77L视频属性的抓取
# BV号为1RV411B77L的视频属性抓取结束
# 开始BV号为1ZV41167NC视频属性的抓取
# BV号为1ZV41167NC的视频属性抓取结束
# 开始BV号为1uh411Z7e8视频属性的抓取
# BV号为1uh411Z7e8的视频属性抓取结束
# 开始BV号为1S54y1i7a8视频属性的抓取
# BV号为1S54y1i7a8的视频属性抓取结束
# 开始BV号为1z64y1F7Mh视频属性的抓取
# BV号为1z64y1F7Mh的视频属性抓取结束
# 开始BV号为1sT4y1j7dV视频属性的抓取
# BV号为1sT4y1j7dV的视频属性抓取结束
# 开始BV号为1oV41167YL视频属性的抓取
# BV号为1oV41167YL的视频属性抓取结束
# 开始BV号为1TK411J7Qr视频属性的抓取
# BV号为1TK411J7Qr的视频属性抓取结束
# 开始BV号为1zD4y1S7Af视频属性的抓取
# BV号为1zD4y1S7Af的视频属性抓取结束
# 开始BV号为1sz4y1Q7SQ视频属性的抓取
# BV号为1sz4y1Q7SQ的视频属性抓取结束
# 开始BV号为16C4y187C6视频属性的抓取
# BV号为16C4y187C6的视频属性抓取结束
# 开始BV号为1sC4y1h7vA视频属性的抓取
# BV号为1sC4y1h7vA的视频属性抓取结束
# 开始BV号为1E5411a7zi视频属性的抓取
# BV号为1E5411a7zi的视频属性抓取结束
# 开始BV号为1vz411v7tM视频属性的抓取
# BV号为1vz411v7tM的视频属性抓取结束
# 开始BV号为1xV411z7fV视频属性的抓取
# BV号为1xV411z7fV的视频属性抓取结束
# 开始BV号为13t4y1X7ij视频属性的抓取
# BV号为13t4y1X7ij的视频属性抓取结束
# 开始BV号为1dZ4y1u7oj视频属性的抓取
# BV号为1dZ4y1u7oj的视频属性抓取结束
# 开始BV号为1cp4y1S7Gt视频属性的抓取
# BV号为1cp4y1S7Gt的视频属性抓取结束
# 开始BV号为1kz4y1D7mx视频属性的抓取
# BV号为1kz4y1D7mx的视频属性抓取结束
# 开始BV号为1GT4y1E71C视频属性的抓取
# BV号为1GT4y1E71C的视频属性抓取结束
# 开始BV号为1wA411v7Yo视频属性的抓取
# BV号为1wA411v7Yo的视频属性抓取结束
# 开始BV号为1gA411v7jX视频属性的抓取
# BV号为1gA411v7jX的视频属性抓取结束
# 开始BV号为1m54y1q71d视频属性的抓取
# BV号为1m54y1q71d的视频属性抓取结束
# 开始BV号为1at4y197qn视频属性的抓取
# BV号为1at4y197qn的视频属性抓取结束
# 开始BV号为1qt4y1X7M2视频属性的抓取
# BV号为1qt4y1X7M2的视频属性抓取结束
# 开始BV号为1Hz411v713视频属性的抓取
# BV号为1Hz411v713的视频属性抓取结束
# 开始BV号为1S54y1q7Lr视频属性的抓取
# BV号为1S54y1q7Lr的视频属性抓取结束
# 开始BV号为17Z4y1M7sH视频属性的抓取
# BV号为17Z4y1M7sH的视频属性抓取结束
# 开始BV号为1tT4y1j7kE视频属性的抓取
# BV号为1tT4y1j7kE的视频属性抓取结束
# 开始BV号为1Qv411i7uV视频属性的抓取
# BV号为1Qv411i7uV的视频属性抓取结束
# 开始BV号为1Qt4y197YP视频属性的抓取
# BV号为1Qt4y197YP的视频属性抓取结束
# 开始BV号为1zk4y1m7oH视频属性的抓取
# BV号为1zk4y1m7oH的视频属性抓取结束
# 开始BV号为1zv411v7f4视频属性的抓取
# BV号为1zv411v7f4的视频属性抓取结束
# 开始BV号为11D4y1U7on视频属性的抓取
# BV号为11D4y1U7on的视频属性抓取结束
# 开始BV号为1z54y1v7p4视频属性的抓取
# BV号为1z54y1v7p4的视频属性抓取结束
# 开始BV号为1XA411n7Mx视频属性的抓取
# BV号为1XA411n7Mx的视频属性抓取结束
# 开始BV号为1UV411z7QM视频属性的抓取
# BV号为1UV411z7QM的视频属性抓取结束
# 开始BV号为13Z4y1T7kA视频属性的抓取
# BV号为13Z4y1T7kA的视频属性抓取结束
# 开始BV号为1f64y1F7LP视频属性的抓取
# BV号为1f64y1F7LP的视频属性抓取结束
# 开始BV号为1J54y1e77V视频属性的抓取
# BV号为1J54y1e77V的视频属性抓取结束
# 开始BV号为1Xp4y1i7Sm视频属性的抓取
# BV号为1Xp4y1i7Sm的视频属性抓取结束
# 开始BV号为1st4y1S71s视频属性的抓取
# BV号为1st4y1S71s的视频属性抓取结束
# 开始BV号为16Z4y1M7TY视频属性的抓取
# BV号为16Z4y1M7TY的视频属性抓取结束
# 开始BV号为1MA411n7zP视频属性的抓取
# BV号为1MA411n7zP的视频属性抓取结束
# 开始BV号为1Ci4y1g7jC视频属性的抓取
# BV号为1Ci4y1g7jC的视频属性抓取结束
# 开始BV号为1PK411M7vj视频属性的抓取
# BV号为1PK411M7vj的视频属性抓取结束
# 开始BV号为11V411U7yg视频属性的抓取
# BV号为11V411U7yg的视频属性抓取结束
# 开始BV号为17T4y1j7yB视频属性的抓取
# BV号为17T4y1j7yB的视频属性抓取结束
# 开始BV号为1BT4y1w7UY视频属性的抓取
# BV号为1BT4y1w7UY的视频属性抓取结束
# 开始BV号为1v54y1i7Pj视频属性的抓取
# BV号为1v54y1i7Pj的视频属性抓取结束
# 开始BV号为1yp4y1Y7Li视频属性的抓取
# BV号为1yp4y1Y7Li的视频属性抓取结束
# 开始BV号为1Pi4y1g76z视频属性的抓取
# BV号为1Pi4y1g76z的视频属性抓取结束
# 开始BV号为1654y1v71e视频属性的抓取
# BV号为1654y1v71e的视频属性抓取结束
# 开始BV号为1nz4y1f7VX视频属性的抓取
# BV号为1nz4y1f7VX的视频属性抓取结束
# 开始BV号为1F54y1U7Hh视频属性的抓取
# BV号为1F54y1U7Hh的视频属性抓取结束
# 开始BV号为12541187BQ视频属性的抓取
# BV号为12541187BQ的视频属性抓取结束
# 开始BV号为1P54y1v7F1视频属性的抓取
# BV号为1P54y1v7F1的视频属性抓取结束
# 开始BV号为1ca4y1J7zc视频属性的抓取
# BV号为1ca4y1J7zc的视频属性抓取结束
# 开始BV号为1EA411n7rs视频属性的抓取
# BV号为1EA411n7rs的视频属性抓取结束
# 开始BV号为1yZ4y1M7Ut视频属性的抓取
# BV号为1yZ4y1M7Ut的视频属性抓取结束
# 开始BV号为18f4y197cJ视频属性的抓取
# BV号为18f4y197cJ的视频属性抓取结束
# 开始BV号为1MD4y1m7J6视频属性的抓取
# BV号为1MD4y1m7J6的视频属性抓取结束
# 开始BV号为1HV411U7C3视频属性的抓取
# BV号为1HV411U7C3的视频属性抓取结束
# 开始BV号为1A54y1i7Qr视频属性的抓取
# BV号为1A54y1i7Qr的视频属性抓取结束
# 开始BV号为1Np4y1e7op视频属性的抓取
# BV号为1Np4y1e7op的视频属性抓取结束
# 开始BV号为1Bf4y1Q71J视频属性的抓取
# BV号为1Bf4y1Q71J的视频属性抓取结束
# 开始BV号为1M54y1U7yo视频属性的抓取
# BV号为1M54y1U7yo的视频属性抓取结束
# 开始BV号为1pp4y1q7Qf视频属性的抓取
# BV号为1pp4y1q7Qf的视频属性抓取结束
# 开始BV号为16y4y1C7mY视频属性的抓取
# BV号为16y4y1C7mY的视频属性抓取结束
# 开始BV号为1P64y1F7Ev视频属性的抓取
# BV号为1P64y1F7Ev的视频属性抓取结束
# 开始BV号为1qA411n7SP视频属性的抓取
# BV号为1qA411n7SP的视频属性抓取结束
# 开始BV号为1oi4y137Fz视频属性的抓取
# BV号为1oi4y137Fz的视频属性抓取结束
# 开始BV号为1964y1c7bK视频属性的抓取
# BV号为1964y1c7bK的视频属性抓取结束
# 开始BV号为1y5411a7qX视频属性的抓取
# BV号为1y5411a7qX的视频属性抓取结束
# 开始BV号为1r54y1U7Lx视频属性的抓取
# BV号为1r54y1U7Lx的视频属性抓取结束
# 开始BV号为1yk4y127yt视频属性的抓取
# BV号为1yk4y127yt的视频属性抓取结束
# 开始BV号为1gV411U725视频属性的抓取
# BV号为1gV411U725的视频属性抓取结束
# 开始BV号为1y64y1F7CR视频属性的抓取
# BV号为1y64y1F7CR的视频属性抓取结束
# 开始BV号为1nf4y1X7Nv视频属性的抓取
# BV号为1nf4y1X7Nv的视频属性抓取结束
# 开始BV号为1MC4y187aG视频属性的抓取
# BV号为1MC4y187aG的视频属性抓取结束
# 开始BV号为1DK4y1Y7gs视频属性的抓取
# BV号为1DK4y1Y7gs的视频属性抓取结束
# 开始BV号为1ui4y1G74E视频属性的抓取
# BV号为1ui4y1G74E的视频属性抓取结束
# 开始BV号为1jZ4y1K7XE视频属性的抓取
# BV号为1jZ4y1K7XE的视频属性抓取结束
# 开始BV号为1Yi4y1M75m视频属性的抓取
# BV号为1Yi4y1M75m的视频属性抓取结束
# 开始BV号为1Bv411v7X5视频属性的抓取
# BV号为1Bv411v7X5的视频属性抓取结束
# 开始BV号为1Si4y1M7GT视频属性的抓取
# BV号为1Si4y1M7GT的视频属性抓取结束
# 开始BV号为1UT4y1j73R视频属性的抓取
# BV号为1UT4y1j73R的视频属性抓取结束
# 开始BV号为1jt4y1Q7fZ视频属性的抓取
# BV号为1jt4y1Q7fZ的视频属性抓取结束
# 开始BV号为17z4y1f73H视频属性的抓取
# BV号为17z4y1f73H的视频属性抓取结束
# 开始BV号为1JV411U7aR视频属性的抓取
# BV号为1JV411U7aR的视频属性抓取结束
# 开始BV号为1T54y1D7WK视频属性的抓取
# BV号为1T54y1D7WK的视频属性抓取结束
# 开始BV号为1jz4y1f7v2视频属性的抓取
# BV号为1jz4y1f7v2的视频属性抓取结束
# 开始BV号为12a4y1E7KJ视频属性的抓取
# BV号为12a4y1E7KJ的视频属性抓取结束
# 开始BV号为1Kk4y127SD视频属性的抓取
# 开始BV号为1Kk4y127SD视频属性的抓取
# BV号为1Kk4y127SD的视频属性抓取结束
# 开始BV号为19k4y1m73K视频属性的抓取
# BV号为19k4y1m73K的视频属性抓取结束
# 开始BV号为1NV411S78f视频属性的抓取
# BV号为1NV411S78f的视频属性抓取结束
# 开始BV号为1j54y1e7i1视频属性的抓取
# BV号为1j54y1e7i1的视频属性抓取结束
# 开始BV号为1bi4y1M7VS视频属性的抓取
# BV号为1bi4y1M7VS的视频属性抓取结束
# 开始BV号为1SK411J7KQ视频属性的抓取
# BV号为1SK411J7KQ的视频属性抓取结束
# 开始BV号为1q541187k8视频属性的抓取
# BV号为1q541187k8的视频属性抓取结束
# 开始BV号为1i64y1F7cN视频属性的抓取
# BV号为1i64y1F7cN的视频属性抓取结束
# 开始BV号为1xC4y187Va视频属性的抓取
# BV号为1xC4y187Va的视频属性抓取结束
# 开始BV号为1Uf4y197iw视频属性的抓取
# BV号为1Uf4y197iw的视频属性抓取结束
# 开始BV号为1U54y1e71G视频属性的抓取
# BV号为1U54y1e71G的视频属性抓取结束
# 开始BV号为1mh411975Y视频属性的抓取
# BV号为1mh411975Y的视频属性抓取结束
# 开始BV号为1Kp4y1v7DP视频属性的抓取
# BV号为1Kp4y1v7DP的视频属性抓取结束
# 开始BV号为1x54y1i7WB视频属性的抓取
# BV号为1x54y1i7WB的视频属性抓取结束
# 开始BV号为1jt4y1Q7Ya视频属性的抓取
# BV号为1jt4y1Q7Ya的视频属性抓取结束
# 开始BV号为1E54y127Ft视频属性的抓取
# BV号为1E54y127Ft的视频属性抓取结束
# 开始BV号为1Sk4y1m7k9视频属性的抓取
# BV号为1Sk4y1m7k9的视频属性抓取结束
# 开始BV号为1Ph411d76P视频属性的抓取
# BV号为1Ph411d76P的视频属性抓取结束
# 开始BV号为1Ft4y1Q7L7视频属性的抓取
# BV号为1Ft4y1Q7L7的视频属性抓取结束
# 开始BV号为1jz4y1f7cF视频属性的抓取
# BV号为1jz4y1f7cF的视频属性抓取结束
# 开始BV号为1FT4y177Vg视频属性的抓取
# BV号为1FT4y177Vg的视频属性抓取结束
# 开始BV号为1za4y1J74N视频属性的抓取
# BV号为1za4y1J74N的视频属性抓取结束
# 开始BV号为1qt4y1D71p视频属性的抓取
# BV号为1qt4y1D71p的视频属性抓取结束
# 开始BV号为1cK4y1e77j视频属性的抓取
# BV号为1cK4y1e77j的视频属性抓取结束
# 开始BV号为1bA411n7W4视频属性的抓取
# BV号为1bA411n7W4的视频属性抓取结束
# 开始BV号为1uh411R74G视频属性的抓取
# BV号为1uh411R74G的视频属性抓取结束
# 开始BV号为1dk4y117C9视频属性的抓取
# BV号为1dk4y117C9的视频属性抓取结束
# 开始BV号为1ZK4y1h79J视频属性的抓取
# BV号为1ZK4y1h79J的视频属性抓取结束
# 开始BV号为15h411R7Tu视频属性的抓取
# BV号为15h411R7Tu的视频属性抓取结束
# 开始BV号为1oD4y127xb视频属性的抓取
# BV号为1oD4y127xb的视频属性抓取结束
# 开始BV号为1yC4y1t7vT视频属性的抓取
# BV号为1yC4y1t7vT的视频属性抓取结束
# 开始BV号为1554y127tc视频属性的抓取
# BV号为1554y127tc的视频属性抓取结束
# 开始BV号为1wC4y1b7UF视频属性的抓取
# BV号为1wC4y1b7UF的视频属性抓取结束
# 开始BV号为1bk4y127VW视频属性的抓取
# BV号为1bk4y127VW的视频属性抓取结束
# 开始BV号为1UK411N76F视频属性的抓取
# BV号为1UK411N76F的视频属性抓取结束
# 开始BV号为1uv411i7AD视频属性的抓取
# BV号为1uv411i7AD的视频属性抓取结束
# 开始BV号为1E54y1e7Zm视频属性的抓取
# BV号为1E54y1e7Zm的视频属性抓取结束
# 开始BV号为1b541187Li视频属性的抓取
# BV号为1b541187Li的视频属性抓取结束
# 开始BV号为13Z4y1T7CU视频属性的抓取
# BV号为13Z4y1T7CU的视频属性抓取结束
# 开始BV号为1wK4y1Y7P4视频属性的抓取
# BV号为1wK4y1Y7P4的视频属性抓取结束
# 开始BV号为1Qf4y1q7jS视频属性的抓取
# BV号为1Qf4y1q7jS的视频属性抓取结束
# 开始BV号为1Li4y1u7Ne视频属性的抓取
# BV号为1Li4y1u7Ne的视频属性抓取结束
# 开始BV号为1RK411K7yF视频属性的抓取
# BV号为1RK411K7yF的视频属性抓取结束
# 开始BV号为1554y1y7en视频属性的抓取
# BV号为1554y1y7en的视频属性抓取结束
# 开始BV号为1Dh411X7m5视频属性的抓取
# BV号为1Dh411X7m5的视频属性抓取结束
# 开始BV号为1nZ4y1N7Kv视频属性的抓取
# BV号为1nZ4y1N7Kv的视频属性抓取结束
# 开始BV号为1A5411j7gm视频属性的抓取
# BV号为1A5411j7gm的视频属性抓取结束
# 开始BV号为1ua4y1j7iu视频属性的抓取
# BV号为1ua4y1j7iu的视频属性抓取结束
# 开始BV号为1Hh411X72h视频属性的抓取
# BV号为1Hh411X72h的视频属性抓取结束
# 开始BV号为1Wp4y1a79z视频属性的抓取
# BV号为1Wp4y1a79z的视频属性抓取结束
# 开始BV号为1zz4y1Z7m6视频属性的抓取
# BV号为1zz4y1Z7m6的视频属性抓取结束
# 开始BV号为1Yp4y1e73h视频属性的抓取
# BV号为1Yp4y1e73h的视频属性抓取结束
# 开始BV号为1yt4y1i7KL视频属性的抓取
# BV号为1yt4y1i7KL的视频属性抓取结束
# 开始BV号为1Mi4y1E7sW视频属性的抓取
# BV号为1Mi4y1E7sW的视频属性抓取结束
# 开始BV号为1n5411b7Kw视频属性的抓取
# BV号为1n5411b7Kw的视频属性抓取结束
# 开始BV号为1sv411C7Uj视频属性的抓取
# BV号为1sv411C7Uj的视频属性抓取结束
# 开始BV号为1dz4y1f7mt视频属性的抓取
# BV号为1dz4y1f7mt的视频属性抓取结束
# 开始BV号为1Wt4y1q7Ag视频属性的抓取
# BV号为1Wt4y1q7Ag的视频属性抓取结束
# 开始BV号为19h411X71o视频属性的抓取
# BV号为19h411X71o的视频属性抓取结束
# 开始BV号为1V54y1k7po视频属性的抓取
# BV号为1V54y1k7po的视频属性抓取结束
# 开始BV号为1xy4y1y7Wj视频属性的抓取
# BV号为1xy4y1y7Wj的视频属性抓取结束
# 开始BV号为1Lz4y1Z7yb视频属性的抓取
# BV号为1Lz4y1Z7yb的视频属性抓取结束
# 开始BV号为1Gy4y1y73w视频属性的抓取
# BV号为1Gy4y1y73w的视频属性抓取结束
# 开始BV号为1zD4y1o7cf视频属性的抓取
# BV号为1zD4y1o7cf的视频属性抓取结束
# 开始BV号为1SV411m7b1视频属性的抓取
# BV号为1SV411m7b1的视频属性抓取结束
# 开始BV号为1JV411m7ME视频属性的抓取
# BV号为1JV411m7ME的视频属性抓取结束
# 开始BV号为1vy4y1k7PL视频属性的抓取
# BV号为1vy4y1k7PL的视频属性抓取结束
# 开始BV号为1KK4y1e7H4视频属性的抓取
# BV号为1KK4y1e7H4的视频属性抓取结束
# 开始BV号为1yi4y1E7Wa视频属性的抓取
# BV号为1yi4y1E7Wa的视频属性抓取结束
# 开始BV号为1MV411S7do视频属性的抓取
# BV号为1MV411S7do的视频属性抓取结束
# 开始BV号为1Ey4y1y7Nr视频属性的抓取
# BV号为1Ey4y1y7Nr的视频属性抓取结束
# 开始BV号为1Ri4y1E7Xo视频属性的抓取
# BV号为1Ri4y1E7Xo的视频属性抓取结束
# 开始BV号为1Av411y7ty视频属性的抓取
# BV号为1Av411y7ty的视频属性抓取结束
# 开始BV号为1Ht4y1q7Jr视频属性的抓取
# BV号为1Ht4y1q7Jr的视频属性抓取结束
# 开始BV号为1864y1F7kg视频属性的抓取
# BV号为1864y1F7kg的视频属性抓取结束
# 开始BV号为1uK4y1a7mG视频属性的抓取
# BV号为1uK4y1a7mG的视频属性抓取结束
# 开始BV号为1yA411n7pe视频属性的抓取
# BV号为1yA411n7pe的视频属性抓取结束
# 开始BV号为1Qp4y1Y7Kw视频属性的抓取
# BV号为1Qp4y1Y7Kw的视频属性抓取结束
# 开始BV号为1m54y1C7kX视频属性的抓取
# BV号为1m54y1C7kX的视频属性抓取结束
# 开始BV号为1oz4y1o766视频属性的抓取
# BV号为1oz4y1o766的视频属性抓取结束
# 开始BV号为1TT4y1c7d9视频属性的抓取
# BV号为1TT4y1c7d9的视频属性抓取结束
# 开始BV号为1oD4y1d7xR视频属性的抓取
# BV号为1oD4y1d7xR的视频属性抓取结束
# 开始BV号为14Z4y1N7ux视频属性的抓取
# BV号为14Z4y1N7ux的视频属性抓取结束
# 开始BV号为1Ji4y1u7Zs视频属性的抓取
# BV号为1Ji4y1u7Zs的视频属性抓取结束
# 开始BV号为1pt4y1v7h1视频属性的抓取
# BV号为1pt4y1v7h1的视频属性抓取结束
# 开始BV号为1Qa4y1L7yT视频属性的抓取
# BV号为1Qa4y1L7yT的视频属性抓取结束
# 开始BV号为1ua4y1j7p8视频属性的抓取
# BV号为1ua4y1j7p8的视频属性抓取结束
# 开始BV号为1g64y1F7gW视频属性的抓取
# BV号为1g64y1F7gW的视频属性抓取结束
# 开始BV号为1ff4y1S7WT视频属性的抓取
# BV号为1ff4y1S7WT的视频属性抓取结束
# 开始BV号为1q5411h7PN视频属性的抓取
# BV号为1q5411h7PN的视频属性抓取结束
# 开始BV号为1Wk4y1y7z5视频属性的抓取
# BV号为1Wk4y1y7z5的视频属性抓取结束
# 开始BV号为1Q54y1y7zS视频属性的抓取
# BV号为1Q54y1y7zS的视频属性抓取结束
# 开始BV号为1U54y1y7Qu视频属性的抓取
# BV号为1U54y1y7Qu的视频属性抓取结束
# 开始BV号为1rA411J7mi视频属性的抓取
# BV号为1rA411J7mi的视频属性抓取结束
# 开始BV号为1f5411L7Z3视频属性的抓取
# BV号为1f5411L7Z3的视频属性抓取结束
# 开始BV号为17h411X7RS视频属性的抓取
# BV号为17h411X7RS的视频属性抓取结束
# 开始BV号为1D54y1y7iC视频属性的抓取
# BV号为1D54y1y7iC的视频属性抓取结束
# 开始BV号为1i54y127dD视频属性的抓取
# BV号为1i54y127dD的视频属性抓取结束
# 开始BV号为1Sv411C77y视频属性的抓取
# BV号为1Sv411C77y的视频属性抓取结束
# 开始BV号为1Ui4y1E7aa视频属性的抓取
# BV号为1Ui4y1E7aa的视频属性抓取结束
# 开始BV号为1w54y1y7uJ视频属性的抓取
# BV号为1w54y1y7uJ的视频属性抓取结束
# 开始BV号为1W5411b7L6视频属性的抓取
# BV号为1W5411b7L6的视频属性抓取结束
# 开始BV号为1SK411P7A1视频属性的抓取
# BV号为1SK411P7A1的视频属性抓取结束
# 开始BV号为13V411m7so视频属性的抓取
# BV号为13V411m7so的视频属性抓取结束
# 开始BV号为1kK411P7fN视频属性的抓取
# BV号为1kK411P7fN的视频属性抓取结束
# 开始BV号为1D54y1C7PH视频属性的抓取
# BV号为1D54y1C7PH的视频属性抓取结束
# 开始BV号为1gV411S73z视频属性的抓取
# BV号为1gV411S73z的视频属性抓取结束
# 开始BV号为1Ka4y177RB视频属性的抓取
# BV号为1Ka4y177RB的视频属性抓取结束
# 开始BV号为1U54y117Wy视频属性的抓取
# BV号为1U54y117Wy的视频属性抓取结束
# 开始BV号为19i4y1M7fN视频属性的抓取
# BV号为19i4y1M7fN的视频属性抓取结束
# 开始BV号为1ok4y1k7zk视频属性的抓取
# BV号为1ok4y1k7zk的视频属性抓取结束
# 开始BV号为1k5411b7Qh视频属性的抓取
# BV号为1k5411b7Qh的视频属性抓取结束
# 开始BV号为1J54y127Te视频属性的抓取
# BV号为1J54y127Te的视频属性抓取结束
# 开始BV号为1Vy4y1y7tt视频属性的抓取
# BV号为1Vy4y1y7tt的视频属性抓取结束
# 开始BV号为1K541187JY视频属性的抓取
# BV号为1K541187JY的视频属性抓取结束
# 开始BV号为1154y127JT视频属性的抓取
# BV号为1154y127JT的视频属性抓取结束
# 开始BV号为1tV411m7gC视频属性的抓取
# BV号为1tV411m7gC的视频属性抓取结束
# 开始BV号为1Qa4y1j7tR视频属性的抓取
# BV号为1Qa4y1j7tR的视频属性抓取结束
# 开始BV号为1Xt4y1i78H视频属性的抓取
# BV号为1Xt4y1i78H的视频属性抓取结束
# 开始BV号为1d54y127WJ视频属性的抓取
# BV号为1d54y127WJ的视频属性抓取结束
# 开始BV号为1Kk4y1C7vZ视频属性的抓取
# BV号为1Kk4y1C7vZ的视频属性抓取结束
# 开始BV号为1Zp4y1Y787视频属性的抓取
# BV号为1Zp4y1Y787的视频属性抓取结束
# 开始BV号为1kZ4y1N7gT视频属性的抓取
# BV号为1kZ4y1N7gT的视频属性抓取结束
# 开始BV号为1av41117rM视频属性的抓取
# BV号为1av41117rM的视频属性抓取结束
# 开始BV号为19a4y1L79b视频属性的抓取
# BV号为19a4y1L79b的视频属性抓取结束
# 开始BV号为1XD4y1o7wh视频属性的抓取
# BV号为1XD4y1o7wh的视频属性抓取结束
# 开始BV号为1ky4y1C77b视频属性的抓取
# BV号为1ky4y1C77b的视频属性抓取结束
# 开始BV号为1Lp4y1e7Dx视频属性的抓取
# BV号为1Lp4y1e7Dx的视频属性抓取结束
# 开始BV号为1nv411C7qn视频属性的抓取
# BV号为1nv411C7qn的视频属性抓取结束
# 开始BV号为1Rv411C7QE视频属性的抓取
# BV号为1Rv411C7QE的视频属性抓取结束
# 开始BV号为1Z54y117Um视频属性的抓取
# BV号为1Z54y117Um的视频属性抓取结束
# 开始BV号为1z5411b7Sb视频属性的抓取
# BV号为1z5411b7Sb的视频属性抓取结束
# 开始BV号为1PZ4y1N7TF视频属性的抓取
# BV号为1PZ4y1N7TF的视频属性抓取结束
# 开始BV号为16K411P7D2视频属性的抓取
# BV号为16K411P7D2的视频属性抓取结束
# 开始BV号为1A54y1v7ns视频属性的抓取
# BV号为1A54y1v7ns的视频属性抓取结束
# 开始BV号为1NV411m7BA视频属性的抓取
# BV号为1NV411m7BA的视频属性抓取结束
# 开始BV号为1Gh411R7M7视频属性的抓取
# BV号为1Gh411R7M7的视频属性抓取结束
# 开始BV号为1iA411J77v视频属性的抓取
# BV号为1iA411J77v的视频属性抓取结束
# 开始BV号为18t4y1v7s3视频属性的抓取
# BV号为18t4y1v7s3的视频属性抓取结束
# 开始BV号为1AA411E7CA视频属性的抓取
# BV号为1AA411E7CA的视频属性抓取结束
# 开始BV号为1QK4y177xc视频属性的抓取
# BV号为1QK4y177xc的视频属性抓取结束
# 开始BV号为1PK411P7Mz视频属性的抓取
# BV号为1PK411P7Mz的视频属性抓取结束
# 开始BV号为1354y127C1视频属性的抓取
# BV号为1354y127C1的视频属性抓取结束
# 开始BV号为1V54y1k7E1视频属性的抓取
# BV号为1V54y1k7E1的视频属性抓取结束
# 开始BV号为1aV411y7sU视频属性的抓取
# 开始BV号为1aV411y7sU视频属性的抓取
# 开始BV号为1aV411y7sU视频属性的抓取
# BV号为1aV411y7sU的视频属性抓取结束
# 开始BV号为1tf4y1i7Xb视频属性的抓取
# BV号为1tf4y1i7Xb的视频属性抓取结束
# 开始BV号为1wp4y1Y7d7视频属性的抓取
# BV号为1wp4y1Y7d7的视频属性抓取结束
# 开始BV号为1yt4y1q7vK视频属性的抓取
# BV号为1yt4y1q7vK的视频属性抓取结束
# 开始BV号为1KZ4y1V71G视频属性的抓取
# BV号为1KZ4y1V71G的视频属性抓取结束
# 开始BV号为1MZ4y1V7gh视频属性的抓取
# BV号为1MZ4y1V7gh的视频属性抓取结束
# 开始BV号为1Ev411y71H视频属性的抓取
# BV号为1Ev411y71H的视频属性抓取结束
# 开始BV号为1fa4y1W7RN视频属性的抓取
# BV号为1fa4y1W7RN的视频属性抓取结束
# 开始BV号为1i54y1R7Ta视频属性的抓取
# BV号为1i54y1R7Ta的视频属性抓取结束
# 开始BV号为1X5411j7Uq视频属性的抓取
# BV号为1X5411j7Uq的视频属性抓取结束
# 开始BV号为1Jt4y1i7xJ视频属性的抓取
# BV号为1Jt4y1i7xJ的视频属性抓取结束
# 开始BV号为1R541157cA视频属性的抓取
# BV号为1R541157cA的视频属性抓取结束
# 开始BV号为1tr4y1F7tF视频属性的抓取
# BV号为1tr4y1F7tF的视频属性抓取结束
# 开始BV号为1c54y1C7Dc视频属性的抓取
# BV号为1c54y1C7Dc的视频属性抓取结束
# 开始BV号为1vV411271U视频属性的抓取
# BV号为1vV411271U的视频属性抓取结束
# 开始BV号为1hD4y197Fx视频属性的抓取
# BV号为1hD4y197Fx的视频属性抓取结束
# 开始BV号为1yK4y177KG视频属性的抓取
# BV号为1yK4y177KG的视频属性抓取结束
# 开始BV号为14z4y1o74H视频属性的抓取
# BV号为14z4y1o74H的视频属性抓取结束
# 开始BV号为1Ry4y1b7fx视频属性的抓取
# BV号为1Ry4y1b7fx的视频属性抓取结束
# 开始BV号为1x54y1R7DL视频属性的抓取
# BV号为1x54y1R7DL的视频属性抓取结束
# 开始BV号为1K54y1C7Vn视频属性的抓取
# BV号为1K54y1C7Vn的视频属性抓取结束
# 开始BV号为1XK4y177cA视频属性的抓取
# BV号为1XK4y177cA的视频属性抓取结束
# 开始BV号为1Uf4y1q7AX视频属性的抓取
# BV号为1Uf4y1q7AX的视频属性抓取结束
# 开始BV号为1ip4y1k7Sc视频属性的抓取
# BV号为1ip4y1k7Sc的视频属性抓取结束
# 开始BV号为1df4y1B7c3视频属性的抓取
# BV号为1df4y1B7c3的视频属性抓取结束
# 开始BV号为1TK411P7LB视频属性的抓取
# BV号为1TK411P7LB的视频属性抓取结束
# 开始BV号为14i4y177oE视频属性的抓取
# BV号为14i4y177oE的视频属性抓取结束
# 开始BV号为14A41177Kc视频属性的抓取
# BV号为14A41177Kc的视频属性抓取结束
# 开始BV号为1Q54115715视频属性的抓取
# BV号为1Q54115715的视频属性抓取结束
# 开始BV号为1GK411A7e4视频属性的抓取
# BV号为1GK411A7e4的视频属性抓取结束
# 开始BV号为1L541177PD视频属性的抓取
# BV号为1L541177PD的视频属性抓取结束
# 开始BV号为1rf4y1B774视频属性的抓取
# BV号为1rf4y1B774的视频属性抓取结束
# 开始BV号为1Rp4y1a7r8视频属性的抓取
# BV号为1Rp4y1a7r8的视频属性抓取结束
# 开始BV号为1Cz4y1o7Jn视频属性的抓取
# BV号为1Cz4y1o7Jn的视频属性抓取结束
# 开始BV号为1ca4y177mS视频属性的抓取
# BV号为1ca4y177mS的视频属性抓取结束
# 开始BV号为1oa411A7xo视频属性的抓取
# BV号为1oa411A7xo的视频属性抓取结束
# 开始BV号为1sK411A7JN视频属性的抓取
# BV号为1sK411A7JN的视频属性抓取结束
# 开始BV号为1ma4y1L7V3视频属性的抓取
# BV号为1ma4y1L7V3的视频属性抓取结束
# 开始BV号为1FK4y1h7vV视频属性的抓取
# BV号为1FK4y1h7vV的视频属性抓取结束
# 开始BV号为1Ry4y1r7rA视频属性的抓取
# BV号为1Ry4y1r7rA的视频属性抓取结束
# 开始BV号为1ca4y1s7VG视频属性的抓取
# BV号为1ca4y1s7VG的视频属性抓取结束
# 开始BV号为1QK4y177cv视频属性的抓取
# BV号为1QK4y177cv的视频属性抓取结束
# 开始BV号为1Wh411978R视频属性的抓取
# BV号为1Wh411978R的视频属性抓取结束
# 开始BV号为1bh411971E视频属性的抓取
# BV号为1bh411971E的视频属性抓取结束
# 开始BV号为11f4y1B7KQ视频属性的抓取
# BV号为11f4y1B7KQ的视频属性抓取结束
# 开始BV号为1uZ4y1V7m7视频属性的抓取
# BV号为1uZ4y1V7m7的视频属性抓取结束
# 开始BV号为1SK4y1h7zh视频属性的抓取
# BV号为1SK4y1h7zh的视频属性抓取结束
# 开始BV号为17i4y177Qa视频属性的抓取
# BV号为17i4y177Qa的视频属性抓取结束
# 开始BV号为1qT4y1F76B视频属性的抓取
# BV号为1qT4y1F76B的视频属性抓取结束
# 开始BV号为1s54y1C7p1视频属性的抓取
# BV号为1s54y1C7p1的视频属性抓取结束
# 开始BV号为1R54y1k7Wg视频属性的抓取
# BV号为1R54y1k7Wg的视频属性抓取结束
# 开始BV号为12y4y1k7PJ视频属性的抓取
# BV号为12y4y1k7PJ的视频属性抓取结束
# 开始BV号为15K411N7vr视频属性的抓取
# BV号为15K411N7vr的视频属性抓取结束
# 开始BV号为12i4y1j74v视频属性的抓取
# BV号为12i4y1j74v的视频属性抓取结束
# 开始BV号为1Sp4y1r7yP视频属性的抓取
# BV号为1Sp4y1r7yP的视频属性抓取结束
# 开始BV号为1tf4y1B7bz视频属性的抓取
# BV号为1tf4y1B7bz的视频属性抓取结束
# 开始BV号为18a411A7SC视频属性的抓取
# BV号为18a411A7SC的视频属性抓取结束
# 开始BV号为18i4y1j7JA视频属性的抓取
# BV号为18i4y1j7JA的视频属性抓取结束
# 开始BV号为1qa411A7NY视频属性的抓取
# BV号为1qa411A7NY的视频属性抓取结束
# 开始BV号为18t4y1v7pM视频属性的抓取
# BV号为18t4y1v7pM的视频属性抓取结束
# 开始BV号为1N5411L7qA视频属性的抓取
# BV号为1N5411L7qA的视频属性抓取结束
# 开始BV号为1Nv411C7MS视频属性的抓取
# BV号为1Nv411C7MS的视频属性抓取结束
# 开始BV号为1Hy4y1B7dW视频属性的抓取
# BV号为1Hy4y1B7dW的视频属性抓取结束
# 开始BV号为1TT4y1F71z视频属性的抓取
# BV号为1TT4y1F71z的视频属性抓取结束
# 开始BV号为1gA411j7of视频属性的抓取
# BV号为1gA411j7of的视频属性抓取结束
# 开始BV号为1uf4y1B7CP视频属性的抓取
# BV号为1uf4y1B7CP的视频属性抓取结束
# 开始BV号为1ZK411P7b4视频属性的抓取
# BV号为1ZK411P7b4的视频属性抓取结束
# 开始BV号为1zt4y1v7Qj视频属性的抓取
# BV号为1zt4y1v7Qj的视频属性抓取结束
# 开始BV号为13a4y1s7rE视频属性的抓取
# BV号为13a4y1s7rE的视频属性抓取结束
# 开始BV号为1rt4y1q7Vh视频属性的抓取
# BV号为1rt4y1q7Vh的视频属性抓取结束
# 开始BV号为1x5411L7eW视频属性的抓取
# BV号为1x5411L7eW的视频属性抓取结束
# 开始BV号为14h411976x视频属性的抓取
# BV号为14h411976x的视频属性抓取结束
# 开始BV号为1x54y117hL视频属性的抓取
# BV号为1x54y117hL的视频属性抓取结束
# 开始BV号为1fp4y1a7fm视频属性的抓取
# BV号为1fp4y1a7fm的视频属性抓取结束
# 开始BV号为1Uy4y1r7Mh视频属性的抓取
# BV号为1Uy4y1r7Mh的视频属性抓取结束
# 开始BV号为1X54y117dJ视频属性的抓取
# BV号为1X54y117dJ的视频属性抓取结束
# 开始BV号为18y4y1r71m视频属性的抓取
# BV号为18y4y1r71m的视频属性抓取结束
# 开始BV号为1TT4y1F7LY视频属性的抓取
# BV号为1TT4y1F7LY的视频属性抓取结束
# 开始BV号为1Ny4y1r7sw视频属性的抓取
# BV号为1Ny4y1r7sw的视频属性抓取结束
# 开始BV号为1by4y1C7qr视频属性的抓取
# BV号为1by4y1C7qr的视频属性抓取结束
# 开始BV号为1Qi4y1j7Uj视频属性的抓取
# BV号为1Qi4y1j7Uj的视频属性抓取结束
# 开始BV号为1ep4y1Y7gj视频属性的抓取
# BV号为1ep4y1Y7gj的视频属性抓取结束
# 开始BV号为1uA411j7PC视频属性的抓取
# BV号为1uA411j7PC的视频属性抓取结束
# 开始BV号为1vV411y72j视频属性的抓取
# BV号为1vV411y72j的视频属性抓取结束
# 开始BV号为1VZ4y1V75t视频属性的抓取
# BV号为1VZ4y1V75t的视频属性抓取结束
# 开始BV号为1tZ4y1L71q视频属性的抓取
# BV号为1tZ4y1L71q的视频属性抓取结束
# 开始BV号为1ya411A7pL视频属性的抓取
# BV号为1ya411A7pL的视频属性抓取结束
# 开始BV号为1Cf4y1i7qF视频属性的抓取
# BV号为1Cf4y1i7qF的视频属性抓取结束
# 开始BV号为1Qz4y1o7ys视频属性的抓取
# 开始BV号为1Qz4y1o7ys视频属性的抓取
# 开始BV号为1Qz4y1o7ys视频属性的抓取
# 开始BV号为1Qz4y1o7ys视频属性的抓取
# BV号为1Qz4y1o7ys的视频属性抓取结束
# 开始BV号为1Ck4y1C7bC视频属性的抓取
# BV号为1Ck4y1C7bC的视频属性抓取结束
# 开始BV号为1Ra4y1W7JX视频属性的抓取
# BV号为1Ra4y1W7JX的视频属性抓取结束
# 2020-12-17 09:47:50.086701

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-14-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_zixun_redian.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月    98   98    98   98   98   98   98   98    98      98   98    98   98
# 1月     98   98    98   98   98   98   98   98    98      98   98    98   98
# 2月     95   95    95   95   95   95   95   95    95      95   95    95   95
# 3月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月     98   98    98   98   98   98   98   98    98      98   98    98   98
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月   98   98   98   98   98   98    98
# 1月    98   98   98   98   98   98    98
# 2月    95   95   95   95   95   95    95
# 3月    99   99   99   99   99   99    99
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月   100  100  100  100  100  100   100
# 7月    99   99   99   99   99   99    99
# 8月   100  100  100  100  100  100   100
# 9月    98   98   98   98   98   98    98

# %%
channel_zixun_redian.to_json('channel_zixun_redian.json')

# %%
pd.set_option('display.max_rows', None)

# %%
channel_youxi_danji[channel_youxi_danji['时间']=='4月']
# Out:
#             时间            作者名  作者类型      粉丝数   投稿数  \
# 1h54y1d7Qq  4月            鹤吱菌  个人认证   191.3万    81
# 1L64y1M7Dp  4月            老番茄  个人认证  1360.1万   348
# 18K41157Tu  4月            老番茄  个人认证  1360.1万   348
# 1PT4y1G7ME  4月            老番茄  个人认证  1360.1万   348
# 1S54y197uX  4月           徐大虾咯  个人认证   570.1万   224
# 1ti4y1t7YM  4月            老番茄  个人认证  1360.1万   348
# 1Ai4y1b7ET  4月            敖厂长  个人认证   735.1万   348
# 1Up4y1C7PB  4月        丢鹏D1uuu     无     8.4万    20
# 1wi4y187bu  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 13t4y1U7kQ  4月           徐大虾咯  个人认证   570.1万   224
# 1fe411x7FA  4月         芦苇草的梦想  个人认证    29.3万   726
# 1LA411b7Dt  4月      LexBurner  个人认证   929.6万   383
# 1Ji4y1t7T9  4月            沧桑丸  个人认证    86.6万    57
# 1Lz411z72u  4月           徐大虾咯  个人认证   570.1万   224
# 13T4y1G7WT  4月          逗比的雀巢  个人认证   242.3万    82
# 1T54y197DH  4月           徐大虾咯  个人认证   570.1万   224
# 1Va4y147fH  4月            鹤吱菌  个人认证   191.3万    81
# 1tt4y127yy  4月           小潮院长  个人认证   481.6万   266
# 16T4y1g7RY  4月         吉儿一范伦婷  个人认证    67.6万    79
# 1754y197Da  4月            敖厂长  个人认证   735.1万   348
# 1hK41157M3  4月           花少北丶  个人认证   491.9万   173
# 1Rk4y197kw  4月       3DM游戏网官方  机构认证    13.5万  2822
# 1ST4y1G7E1  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1H54y1d76B  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1Sz411B7P4  4月          游汐_YX  个人认证    12.9万    98
# 1CT4y1g7Ya  4月    育碧中国Ubisoft  机构认证    64.5万  1211
# 12T4y1G7AZ  4月          与山0v0  个人认证   208.5万   557
# 1b5411x79t  4月        东尼ookii  个人认证   331.7万   166
# 1hA411h7Ky  4月          与山0v0  个人认证   208.5万   557
# 1Gt4y127AJ  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 13f4y1S7sa  4月          我是凉菜啊     无     8516   447
# 1Fz41187eM  4月       彩虹天河CHTH     无      759    30
# 1Jg4y1z7RH  4月          -Fm2-  个人认证    14.6万   394
# 1KJ411e7nN                              如何提高审美？审美有无高低？审美是谁建立？  数码  摄影摄像  普通视频
# ...                                                       ...  ..   ...   ...
# 1cr4y1w7ig              困难重重，国家天文签约摄影师遭遇拍摄滑铁卢？！【华为Mate40 Pro】  数码  摄影摄像  活动作品
# 1Y5411L7TW                     富士X-S10相机测试——2020 apsc画幅性价比最强机  数码  摄影摄像  活动作品
# 1c541177hR      索尼（Sony）12-24mm F2.8 GM深度评测，只要买得起，它就是一颗完美的镜头！  数码  摄影摄像  普通视频
# 1DA41177UY                            大疆旗舰稳定器 - DJI RS 2 正式登场  数码  摄影摄像  普通视频
# 1rA411776p                 让我非常失望的佳能M50 Mark II（来自一代老用户的真实心声）  数码  摄影摄像  普通视频
#
#             ...                                                 标签   视频长度  \
# 1gJ411n7hp  ...                         [摄影, 数码, 摄影摄像, 数码, 教程, 器材]  01:44
# 1tJ41187w6  ...  [相机, 数码, 摄影摄像, 数码, 何同学, 啊吗粽, 宝剑嫂, 自媒体, 大祥哥, 体验...  30:03
# 1i7411i7yA  ...        [摄影, 短片, 数码, 摄影摄像, 数码, 创意, YOUTUBE, 镜头, 老蛙]  04:51
# 1gJ411G7Cs  ...           [摄影, 数码, 摄影摄像, 数码, VLOG, 后期, 教程, ps, 器材]  06:01
# 1KJ411e7nN  ...  [校园vlog, 相机, 脱口秀, 摄影, 公开课, vlog, 科普, 数码, 摄影摄像,...  27:08
# ...         ...                                                ...    ...
# 1cr4y1w7ig  ...  [vlog, 数码, 摄影摄像, 数码, 放心购机攻略, 敦煌, 星空, 手机摄影, 华为,...  11:43
# 1Y5411L7TW  ...  [相机, 摄影, 数码, 摄影摄像, 数码, 数码玩家训练营, 拍照, 测评, xs10, ...  10:20
# 1c541177hR  ...  [摄影, 数码, 摄影摄像, 数码, 评测, 超广角大光圈, 摄像, 镜头, 数码评测, 超...  21:23
# 1DA41177UY  ...   [相机, 摄影, 数码, 摄影摄像, 数码, 科技, 测评, 器材, 大疆, DJI, 稳定器]  02:26
# 1rA411776p  ...  [vlog, 数码, 摄影摄像, 数码, 佳能, 测评, 体验, m50 mark ii, ...  06:30
#
#                播放量    点赞数   投币数   收藏数   转发数   评论数   弹幕数 有无分集
# 1gJ411n7hp  222.4万   9.7万  2.0万  1.4万  4980  3182  1571    否
# 1tJ41187w6  134.0万  10.7万  8.4万  5.8万  8907  3935  3.0万    否
# 1i7411i7yA   57.8万   4.4万  1.0万  1.6万  2043   641   983    否
# 1gJ411G7Cs   42.3万   3.3万  3.4万  8.6万  2605  1405   612    否
# 1KJ411e7nN   39.6万   4.8万  5.4万  3.4万  6217  1156  1.0万    否
# ...            ...    ...   ...   ...   ...   ...   ...  ...
# 1cr4y1w7ig    4.3万   3051  1391   692   255   337   349    否
# 1Y5411L7TW    4.3万    773   219   221   111   273   104    否
# 1c541177hR    4.1万   1469   443   297   123   250   561    否
# 1DA41177UY    4.1万   1565   197   334   640   171   110    否
# 1rA411776p    4.1万   1262   267   147   101   385   314    否
#
# [999 rows x 21 columns]
