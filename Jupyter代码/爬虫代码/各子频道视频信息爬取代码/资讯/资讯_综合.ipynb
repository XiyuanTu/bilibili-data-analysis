# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_zixun_zonghe=pd.DataFrame(columns=columns)
channel_zixun_zonghe
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[12]/div/a/span').click()  #选择频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[12]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '资讯'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[5]/a').click()  #选择子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[5]/a').text
sub_channel
# Out:
# '综合'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(1,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_zixun_zonghe.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-17 00:01:28.082629
# <ipython-input-11-b580ddf1ba89>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-11-b580ddf1ba89>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-11-b580ddf1ba89>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1LJ411H7WK视频属性的抓取
# BV号为1LJ411H7WK的视频属性抓取结束
# <ipython-input-11-b580ddf1ba89>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1s7411r77D视频属性的抓取
# BV号为1s7411r77D的视频属性抓取结束
# 开始BV号为117411e7Bf视频属性的抓取
# BV号为117411e7Bf的视频属性抓取结束
# 开始BV号为1t741167rh视频属性的抓取
# BV号为1t741167rh的视频属性抓取结束
# 开始BV号为1sJ411b7Cf视频属性的抓取
# BV号为1sJ411b7Cf的视频属性抓取结束
# 开始BV号为1QJ411G7zw视频属性的抓取
# BV号为1QJ411G7zw的视频属性抓取结束
# 开始BV号为1pJ411G7V4视频属性的抓取
# BV号为1pJ411G7V4的视频属性抓取结束
# 开始BV号为1nJ411L7oe视频属性的抓取
# BV号为1nJ411L7oe的视频属性抓取结束
# 开始BV号为1JJ411E7YN视频属性的抓取
# BV号为1JJ411E7YN的视频属性抓取结束
# 开始BV号为1H7411e7L1视频属性的抓取
# BV号为1H7411e7L1的视频属性抓取结束
# 开始BV号为1bJ411573d视频属性的抓取
# BV号为1bJ411573d的视频属性抓取结束
# 开始BV号为1aJ411L7Lo视频属性的抓取
# BV号为1aJ411L7Lo的视频属性抓取结束
# 开始BV号为16J411j7ra视频属性的抓取
# BV号为16J411j7ra的视频属性抓取结束
# 开始BV号为1p741167ds视频属性的抓取
# BV号为1p741167ds的视频属性抓取结束
# 开始BV号为1S7411e79Z视频属性的抓取
# BV号为1S7411e79Z的视频属性抓取结束
# 开始BV号为1TJ41157Gs视频属性的抓取
# BV号为1TJ41157Gs的视频属性抓取结束
# 开始BV号为1A7411q7cJ视频属性的抓取
# BV号为1A7411q7cJ的视频属性抓取结束
# 开始BV号为1MJ411V76d视频属性的抓取
# BV号为1MJ411V76d的视频属性抓取结束
# 开始BV号为1hJ411V7HJ视频属性的抓取
# 开始BV号为1hJ411V7HJ视频属性的抓取
# BV号为1hJ411V7HJ的视频属性抓取结束
# 开始BV号为1ZJ411L7CS视频属性的抓取
# BV号为1ZJ411L7CS的视频属性抓取结束
# 开始BV号为1xJ41177qz视频属性的抓取
# BV号为1xJ41177qz的视频属性抓取结束
# 开始BV号为1bJ411L7GE视频属性的抓取
# BV号为1bJ411L7GE的视频属性抓取结束
# 开始BV号为1cJ411n7Ao视频属性的抓取
# BV号为1cJ411n7Ao的视频属性抓取结束
# 开始BV号为1GJ41157Bm视频属性的抓取
# BV号为1GJ41157Bm的视频属性抓取结束
# 开始BV号为1KJ411n7qP视频属性的抓取
# BV号为1KJ411n7qP的视频属性抓取结束
# 开始BV号为1A7411z7pS视频属性的抓取
# BV号为1A7411z7pS的视频属性抓取结束
# 开始BV号为1g7411e7wu视频属性的抓取
# BV号为1g7411e7wu的视频属性抓取结束
# 开始BV号为1S7411Y7Yd视频属性的抓取
# BV号为1S7411Y7Yd的视频属性抓取结束
# 开始BV号为1h7411v7cx视频属性的抓取
# BV号为1h7411v7cx的视频属性抓取结束
# 开始BV号为17J41177D5视频属性的抓取
# BV号为17J41177D5的视频属性抓取结束
# 开始BV号为1X7411q7B8视频属性的抓取
# BV号为1X7411q7B8的视频属性抓取结束
# 开始BV号为1S7411i7Sr视频属性的抓取
# 开始BV号为1S7411i7Sr视频属性的抓取
# BV号为1S7411i7Sr的视频属性抓取结束
# 开始BV号为1D741167hr视频属性的抓取
# 开始BV号为1D741167hr视频属性的抓取
# 开始BV号为1D741167hr视频属性的抓取
# 开始BV号为1D741167hr视频属性的抓取
# 开始BV号为1D741167hr视频属性的抓取
# 开始BV号为1D741167hr视频属性的抓取
# BV号为1D741167hr的视频属性抓取结束
# 开始BV号为1n7411i7Bn视频属性的抓取
# BV号为1n7411i7Bn的视频属性抓取结束
# 开始BV号为1vJ411G7uD视频属性的抓取
# BV号为1vJ411G7uD的视频属性抓取结束
# 开始BV号为1BJ411H7a9视频属性的抓取
# BV号为1BJ411H7a9的视频属性抓取结束
# 开始BV号为147411a7ff视频属性的抓取
# BV号为147411a7ff的视频属性抓取结束
# 开始BV号为1sJ411E7tA视频属性的抓取
# BV号为1sJ411E7tA的视频属性抓取结束
# 开始BV号为1i7411q7Mt视频属性的抓取
# BV号为1i7411q7Mt的视频属性抓取结束
# 开始BV号为167411v71t视频属性的抓取
# BV号为167411v71t的视频属性抓取结束
# 开始BV号为1aJ411V7tM视频属性的抓取
# BV号为1aJ411V7tM的视频属性抓取结束
# 开始BV号为1uJ41157iR视频属性的抓取
# BV号为1uJ41157iR的视频属性抓取结束
# 开始BV号为1uJ411V7CP视频属性的抓取
# BV号为1uJ411V7CP的视频属性抓取结束
# 开始BV号为18J411H73q视频属性的抓取
# BV号为18J411H73q的视频属性抓取结束
# 开始BV号为1DJ411L7xZ视频属性的抓取
# BV号为1DJ411L7xZ的视频属性抓取结束
# 开始BV号为1yJ411j7XD视频属性的抓取
# BV号为1yJ411j7XD的视频属性抓取结束
# 开始BV号为1h7411r7Ub视频属性的抓取
# BV号为1h7411r7Ub的视频属性抓取结束
# 开始BV号为1zJ411j735视频属性的抓取
# BV号为1zJ411j735的视频属性抓取结束
# 开始BV号为1E741167ia视频属性的抓取
# BV号为1E741167ia的视频属性抓取结束
# 开始BV号为1J7411i7vH视频属性的抓取
# BV号为1J7411i7vH的视频属性抓取结束
# 开始BV号为1GJ41177yz视频属性的抓取
# BV号为1GJ41177yz的视频属性抓取结束
# 开始BV号为1hJ411574U视频属性的抓取
# BV号为1hJ411574U的视频属性抓取结束
# 开始BV号为13J411G7TY视频属性的抓取
# BV号为13J411G7TY的视频属性抓取结束
# 开始BV号为177411i7dc视频属性的抓取
# BV号为177411i7dc的视频属性抓取结束
# 开始BV号为15J411774L视频属性的抓取
# BV号为15J411774L的视频属性抓取结束
# 开始BV号为1HJ411V73X视频属性的抓取
# BV号为1HJ411V73X的视频属性抓取结束
# 开始BV号为1zJ411V75a视频属性的抓取
# BV号为1zJ411V75a的视频属性抓取结束
# 开始BV号为1iJ41157mV视频属性的抓取
# BV号为1iJ41157mV的视频属性抓取结束
# 开始BV号为18J41177S9视频属性的抓取
# BV号为18J41177S9的视频属性抓取结束
# 开始BV号为137411v7KZ视频属性的抓取
# BV号为137411v7KZ的视频属性抓取结束
# 开始BV号为1CJ411E7xH视频属性的抓取
# BV号为1CJ411E7xH的视频属性抓取结束
# 开始BV号为187411B7gX视频属性的抓取
# BV号为187411B7gX的视频属性抓取结束
# 开始BV号为18J411578R视频属性的抓取
# BV号为18J411578R的视频属性抓取结束
# 开始BV号为1ZJ41157cX视频属性的抓取
# BV号为1ZJ41157cX的视频属性抓取结束
# 开始BV号为1wJ411j7z7视频属性的抓取
# BV号为1wJ411j7z7的视频属性抓取结束
# 开始BV号为1KJ411J7Vp视频属性的抓取
# BV号为1KJ411J7Vp的视频属性抓取结束
# 开始BV号为1u7411e7MM视频属性的抓取
# BV号为1u7411e7MM的视频属性抓取结束
# 开始BV号为1rJ41157cZ视频属性的抓取
# BV号为1rJ41157cZ的视频属性抓取结束
# 开始BV号为1GJ41157bW视频属性的抓取
# BV号为1GJ41157bW的视频属性抓取结束
# 开始BV号为1bJ41187Xg视频属性的抓取
# BV号为1bJ41187Xg的视频属性抓取结束
# 开始BV号为17J411j7Um视频属性的抓取
# BV号为17J411j7Um的视频属性抓取结束
# 开始BV号为1k7411q7oe视频属性的抓取
# BV号为1k7411q7oe的视频属性抓取结束
# 开始BV号为1QJ411n7mW视频属性的抓取
# BV号为1QJ411n7mW的视频属性抓取结束
# 开始BV号为1uJ411E7JB视频属性的抓取
# BV号为1uJ411E7JB的视频属性抓取结束
# 开始BV号为1PJ41187iZ视频属性的抓取
# BV号为1PJ41187iZ的视频属性抓取结束
# 开始BV号为13J411n7oT视频属性的抓取
# BV号为13J411n7oT的视频属性抓取结束
# 开始BV号为1HJ411L7gu视频属性的抓取
# BV号为1HJ411L7gu的视频属性抓取结束
# 开始BV号为1b7411a7F4视频属性的抓取
# BV号为1b7411a7F4的视频属性抓取结束
# 开始BV号为1kJ411p7a5视频属性的抓取
# BV号为1kJ411p7a5的视频属性抓取结束
# 开始BV号为1kJ411V7TH视频属性的抓取
# BV号为1kJ411V7TH的视频属性抓取结束
# 开始BV号为16J41157AM视频属性的抓取
# BV号为16J41157AM的视频属性抓取结束
# 开始BV号为17J411j7Nq视频属性的抓取
# BV号为17J411j7Nq的视频属性抓取结束
# 开始BV号为1sJ411L7TZ视频属性的抓取
# BV号为1sJ411L7TZ的视频属性抓取结束
# 开始BV号为1yJ411j7S2视频属性的抓取
# BV号为1yJ411j7S2的视频属性抓取结束
# 开始BV号为1bJ411G7Hy视频属性的抓取
# BV号为1bJ411G7Hy的视频属性抓取结束
# 开始BV号为1NJ411n7eK视频属性的抓取
# BV号为1NJ411n7eK的视频属性抓取结束
# 开始BV号为1MJ411G7WQ视频属性的抓取
# BV号为1MJ411G7WQ的视频属性抓取结束
# 开始BV号为1rJ41157Cf视频属性的抓取
# BV号为1rJ41157Cf的视频属性抓取结束
# 开始BV号为1pJ41187VZ视频属性的抓取
# BV号为1pJ41187VZ的视频属性抓取结束
# 开始BV号为1WJ411G7GF视频属性的抓取
# BV号为1WJ411G7GF的视频属性抓取结束
# 开始BV号为1HJ411V75U视频属性的抓取
# BV号为1HJ411V75U的视频属性抓取结束
# 开始BV号为1tJ411V7bG视频属性的抓取
# BV号为1tJ411V7bG的视频属性抓取结束
# 开始BV号为1zJ411G76J视频属性的抓取
# BV号为1zJ411G76J的视频属性抓取结束
# 开始BV号为1KJ411p7uM视频属性的抓取
# BV号为1KJ411p7uM的视频属性抓取结束
# 开始BV号为11J411j7Ju视频属性的抓取
# BV号为11J411j7Ju的视频属性抓取结束
# 开始BV号为1TJ411j7ua视频属性的抓取
# BV号为1TJ411j7ua的视频属性抓取结束
# 开始BV号为1uJ41157c9视频属性的抓取
# BV号为1uJ41157c9的视频属性抓取结束
# 开始BV号为13J411G7RH视频属性的抓取
# BV号为13J411G7RH的视频属性抓取结束
# 开始BV号为1i7411a7Nt视频属性的抓取
# BV号为1i7411a7Nt的视频属性抓取结束
# 开始BV号为1EJ41177B6视频属性的抓取
# BV号为1EJ41177B6的视频属性抓取结束
# 开始BV号为1X7411H7t7视频属性的抓取
# BV号为1X7411H7t7的视频属性抓取结束
# 开始BV号为1j7411g71d视频属性的抓取
# BV号为1j7411g71d的视频属性抓取结束
# 开始BV号为1j7411H7S2视频属性的抓取
# BV号为1j7411H7S2的视频属性抓取结束
# 开始BV号为167411K7yj视频属性的抓取
# BV号为167411K7yj的视频属性抓取结束
# 开始BV号为1Q7411P7dY视频属性的抓取
# BV号为1Q7411P7dY的视频属性抓取结束
# 开始BV号为197411A74r视频属性的抓取
# BV号为197411A74r的视频属性抓取结束
# 开始BV号为117411T7Cy视频属性的抓取
# BV号为117411T7Cy的视频属性抓取结束
# 开始BV号为1vE411J75C视频属性的抓取
# BV号为1vE411J75C的视频属性抓取结束
# 开始BV号为1f741187w4视频属性的抓取
# BV号为1f741187w4的视频属性抓取结束
# 开始BV号为11741137UK视频属性的抓取
# BV号为11741137UK的视频属性抓取结束
# 开始BV号为1J7411n7a5视频属性的抓取
# BV号为1J7411n7a5的视频属性抓取结束
# 开始BV号为1z7411K7MY视频属性的抓取
# BV号为1z7411K7MY的视频属性抓取结束
# 开始BV号为1F7411P7Pk视频属性的抓取
# BV号为1F7411P7Pk的视频属性抓取结束
# 开始BV号为1G7411K7Ft视频属性的抓取
# BV号为1G7411K7Ft的视频属性抓取结束
# 开始BV号为1Q7411s76w视频属性的抓取
# BV号为1Q7411s76w的视频属性抓取结束
# 开始BV号为1A7411j778视频属性的抓取
# BV号为1A7411j778的视频属性抓取结束
# 开始BV号为17741137TM视频属性的抓取
# BV号为17741137TM的视频属性抓取结束
# 开始BV号为1N7411M7SV视频属性的抓取
# BV号为1N7411M7SV的视频属性抓取结束
# 开始BV号为1c7411M7Hi视频属性的抓取
# BV号为1c7411M7Hi的视频属性抓取结束
# 开始BV号为1U7411w7Vu视频属性的抓取
# BV号为1U7411w7Vu的视频属性抓取结束
# 开始BV号为1c7411K7DM视频属性的抓取
# BV号为1c7411K7DM的视频属性抓取结束
# 开始BV号为1S7411g7K3视频属性的抓取
# BV号为1S7411g7K3的视频属性抓取结束
# 开始BV号为14E411H7UJ视频属性的抓取
# BV号为14E411H7UJ的视频属性抓取结束
# 开始BV号为11E411n7tP视频属性的抓取
# BV号为11E411n7tP的视频属性抓取结束
# 开始BV号为1C7411M7gb视频属性的抓取
# BV号为1C7411M7gb的视频属性抓取结束
# 开始BV号为147411K7RG视频属性的抓取
# BV号为147411K7RG的视频属性抓取结束
# 开始BV号为1J741177aV视频属性的抓取
# BV号为1J741177aV的视频属性抓取结束
# 开始BV号为1K7411W7cF视频属性的抓取
# BV号为1K7411W7cF的视频属性抓取结束
# 开始BV号为1z7411w7cj视频属性的抓取
# BV号为1z7411w7cj的视频属性抓取结束
# 开始BV号为1b7411J7Lw视频属性的抓取
# BV号为1b7411J7Lw的视频属性抓取结束
# 开始BV号为1g7411L7iH视频属性的抓取
# BV号为1g7411L7iH的视频属性抓取结束
# 开始BV号为1v7411H7Ke视频属性的抓取
# BV号为1v7411H7Ke的视频属性抓取结束
# 开始BV号为1A7411J7K8视频属性的抓取
# BV号为1A7411J7K8的视频属性抓取结束
# 开始BV号为1N7411H7dp视频属性的抓取
# BV号为1N7411H7dp的视频属性抓取结束
# 开始BV号为167411P7qy视频属性的抓取
# BV号为167411P7qy的视频属性抓取结束
# 开始BV号为1W7411j7ds视频属性的抓取
# BV号为1W7411j7ds的视频属性抓取结束
# 开始BV号为1u7411V77N视频属性的抓取
# BV号为1u7411V77N的视频属性抓取结束
# 开始BV号为1W7411E7Y1视频属性的抓取
# BV号为1W7411E7Y1的视频属性抓取结束
# 开始BV号为1KE411H7hU视频属性的抓取
# BV号为1KE411H7hU的视频属性抓取结束
# 开始BV号为1k741177fL视频属性的抓取
# BV号为1k741177fL的视频属性抓取结束
# 开始BV号为167411P7EA视频属性的抓取
# BV号为167411P7EA的视频属性抓取结束
# 开始BV号为1aj411f72D视频属性的抓取
# BV号为1aj411f72D的视频属性抓取结束
# 开始BV号为1e7411A7PA视频属性的抓取
# BV号为1e7411A7PA的视频属性抓取结束
# 开始BV号为1y7411J7zV视频属性的抓取
# BV号为1y7411J7zV的视频属性抓取结束
# 开始BV号为1Q741177RJ视频属性的抓取
# BV号为1Q741177RJ的视频属性抓取结束
# 开始BV号为1N7411M7YY视频属性的抓取
# BV号为1N7411M7YY的视频属性抓取结束
# 开始BV号为1x7411F7sg视频属性的抓取
# BV号为1x7411F7sg的视频属性抓取结束
# 开始BV号为1T7411u7P2视频属性的抓取
# BV号为1T7411u7P2的视频属性抓取结束
# 开始BV号为1m7411A7BK视频属性的抓取
# BV号为1m7411A7BK的视频属性抓取结束
# 开始BV号为1eE411H7gg视频属性的抓取
# BV号为1eE411H7gg的视频属性抓取结束
# 开始BV号为1p7411P7Tn视频属性的抓取
# BV号为1p7411P7Tn的视频属性抓取结束
# 开始BV号为1b7411n7gQ视频属性的抓取
# BV号为1b7411n7gQ的视频属性抓取结束
# 开始BV号为1m7411T7ge视频属性的抓取
# BV号为1m7411T7ge的视频属性抓取结束
# 开始BV号为1G7411P76h视频属性的抓取
# BV号为1G7411P76h的视频属性抓取结束
# 开始BV号为1c7411J7Dm视频属性的抓取
# BV号为1c7411J7Dm的视频属性抓取结束
# 开始BV号为1iE411J7WU视频属性的抓取
# BV号为1iE411J7WU的视频属性抓取结束
# 开始BV号为1g7411u7wy视频属性的抓取
# BV号为1g7411u7wy的视频属性抓取结束
# 开始BV号为1V7411u7LB视频属性的抓取
# BV号为1V7411u7LB的视频属性抓取结束
# 开始BV号为1n7411N7zz视频属性的抓取
# BV号为1n7411N7zz的视频属性抓取结束
# 开始BV号为1p7411N7Lt视频属性的抓取
# BV号为1p7411N7Lt的视频属性抓取结束
# 开始BV号为1w7411j7XB视频属性的抓取
# BV号为1w7411j7XB的视频属性抓取结束
# 开始BV号为1p7411s74Q视频属性的抓取
# BV号为1p7411s74Q的视频属性抓取结束
# 开始BV号为1E7411V7ad视频属性的抓取
# BV号为1E7411V7ad的视频属性抓取结束
# 开始BV号为1x741157MC视频属性的抓取
# BV号为1x741157MC的视频属性抓取结束
# 开始BV号为1p7411c7Nw视频属性的抓取
# BV号为1p7411c7Nw的视频属性抓取结束
# 开始BV号为1dj411f7wn视频属性的抓取
# BV号为1dj411f7wn的视频属性抓取结束
# 开始BV号为1t741157Ad视频属性的抓取
# BV号为1t741157Ad的视频属性抓取结束
# 开始BV号为1a7411c7yn视频属性的抓取
# BV号为1a7411c7yn的视频属性抓取结束
# 开始BV号为1G7411H7e1视频属性的抓取
# BV号为1G7411H7e1的视频属性抓取结束
# 开始BV号为117411j7JM视频属性的抓取
# BV号为117411j7JM的视频属性抓取结束
# 开始BV号为1u7411K78J视频属性的抓取
# BV号为1u7411K78J的视频属性抓取结束
# 开始BV号为1M7411b7XD视频属性的抓取
# BV号为1M7411b7XD的视频属性抓取结束
# 开始BV号为137411A7aZ视频属性的抓取
# BV号为137411A7aZ的视频属性抓取结束
# 开始BV号为1EE411J7W6视频属性的抓取
# BV号为1EE411J7W6的视频属性抓取结束
# 开始BV号为1X7411G74E视频属性的抓取
# BV号为1X7411G74E的视频属性抓取结束
# 开始BV号为1M7411J7Bi视频属性的抓取
# BV号为1M7411J7Bi的视频属性抓取结束
# 开始BV号为1E7411a7aZ视频属性的抓取
# BV号为1E7411a7aZ的视频属性抓取结束
# 开始BV号为1U741177bd视频属性的抓取
# BV号为1U741177bd的视频属性抓取结束
# 开始BV号为1z741177q4视频属性的抓取
# BV号为1z741177q4的视频属性抓取结束
# 开始BV号为1t7411h7Cn视频属性的抓取
# BV号为1t7411h7Cn的视频属性抓取结束
# 开始BV号为1Q7411u7V9视频属性的抓取
# BV号为1Q7411u7V9的视频属性抓取结束
# 开始BV号为1m7411E7Kr视频属性的抓取
# BV号为1m7411E7Kr的视频属性抓取结束
# 开始BV号为1y741147WS视频属性的抓取
# BV号为1y741147WS的视频属性抓取结束
# 开始BV号为1o741157vU视频属性的抓取
# BV号为1o741157vU的视频属性抓取结束
# 开始BV号为1C7411L7j2视频属性的抓取
# BV号为1C7411L7j2的视频属性抓取结束
# 开始BV号为1r7411A7nE视频属性的抓取
# BV号为1r7411A7nE的视频属性抓取结束
# 开始BV号为127411V7rU视频属性的抓取
# BV号为127411V7rU的视频属性抓取结束
# 开始BV号为137411H7Zn视频属性的抓取
# BV号为137411H7Zn的视频属性抓取结束
# 开始BV号为157411b7cG视频属性的抓取
# BV号为157411b7cG的视频属性抓取结束
# 开始BV号为1J7411K7cr视频属性的抓取
# BV号为1J7411K7cr的视频属性抓取结束
# 开始BV号为1y7411M7P9视频属性的抓取
# BV号为1y7411M7P9的视频属性抓取结束
# 开始BV号为1T741187Bk视频属性的抓取
# BV号为1T741187Bk的视频属性抓取结束
# 开始BV号为1e7411T7yC视频属性的抓取
# BV号为1e7411T7yC的视频属性抓取结束
# 开始BV号为1K7411N7WA视频属性的抓取
# BV号为1K7411N7WA的视频属性抓取结束
# 开始BV号为1T7411j7Yy视频属性的抓取
# BV号为1T7411j7Yy的视频属性抓取结束
# 开始BV号为1d7411J7JF视频属性的抓取
# BV号为1d7411J7JF的视频属性抓取结束
# 开始BV号为1Q7411x7fg视频属性的抓取
# BV号为1Q7411x7fg的视频属性抓取结束
# 开始BV号为1j7411j7XW视频属性的抓取
# BV号为1j7411j7XW的视频属性抓取结束
# 开始BV号为1F7411G7tU视频属性的抓取
# BV号为1F7411G7tU的视频属性抓取结束
# 开始BV号为1G7411V71k视频属性的抓取
# BV号为1G7411V71k的视频属性抓取结束
# 开始BV号为19E411c7fV视频属性的抓取
# BV号为19E411c7fV的视频属性抓取结束
# 开始BV号为1WE411V71A视频属性的抓取
# BV号为1WE411V71A的视频属性抓取结束
# 开始BV号为1v741117Dn视频属性的抓取
# BV号为1v741117Dn的视频属性抓取结束
# 开始BV号为1pE411V7X5视频属性的抓取
# BV号为1pE411V7X5的视频属性抓取结束
# 开始BV号为1n7411Q7nK视频属性的抓取
# BV号为1n7411Q7nK的视频属性抓取结束
# 开始BV号为1Kc411h7Qg视频属性的抓取
# BV号为1Kc411h7Qg的视频属性抓取结束
# 开始BV号为1A741127ZR视频属性的抓取
# BV号为1A741127ZR的视频属性抓取结束
# 开始BV号为1tE411L7Pm视频属性的抓取
# BV号为1tE411L7Pm的视频属性抓取结束
# 开始BV号为1QE411u7LN视频属性的抓取
# BV号为1QE411u7LN的视频属性抓取结束
# 开始BV号为1A7411R7dy视频属性的抓取
# BV号为1A7411R7dy的视频属性抓取结束
# 开始BV号为1BE411G75Z视频属性的抓取
# BV号为1BE411G75Z的视频属性抓取结束
# 开始BV号为1U7411o7LG视频属性的抓取
# BV号为1U7411o7LG的视频属性抓取结束
# 开始BV号为1sE411E7U1视频属性的抓取
# BV号为1sE411E7U1的视频属性抓取结束
# 开始BV号为1cE41157U4视频属性的抓取
# BV号为1cE41157U4的视频属性抓取结束
# 开始BV号为1ZE411p7rB视频属性的抓取
# BV号为1ZE411p7rB的视频属性抓取结束
# 开始BV号为1A7411d7Dz视频属性的抓取
# BV号为1A7411d7Dz的视频属性抓取结束
# 开始BV号为1n7411U7jw视频属性的抓取
# BV号为1n7411U7jw的视频属性抓取结束
# 开始BV号为1kE411G7YC视频属性的抓取
# BV号为1kE411G7YC的视频属性抓取结束
# 开始BV号为1a7411C7G7视频属性的抓取
# BV号为1a7411C7G7的视频属性抓取结束
# 开始BV号为1ZE41147L5视频属性的抓取
# BV号为1ZE41147L5的视频属性抓取结束
# 开始BV号为1K7411d7jX视频属性的抓取
# BV号为1K7411d7jX的视频属性抓取结束
# 开始BV号为1FE411t7QP视频属性的抓取
# BV号为1FE411t7QP的视频属性抓取结束
# 开始BV号为1V741127vo视频属性的抓取
# BV号为1V741127vo的视频属性抓取结束
# 开始BV号为1nE411u7a7视频属性的抓取
# BV号为1nE411u7a7的视频属性抓取结束
# 开始BV号为1N54y1d7CK视频属性的抓取
# BV号为1N54y1d7CK的视频属性抓取结束
# 开始BV号为1dE411V7t6视频属性的抓取
# BV号为1dE411V7t6的视频属性抓取结束
# 开始BV号为1ME411F7nA视频属性的抓取
# BV号为1ME411F7nA的视频属性抓取结束
# 开始BV号为1TE411j7No视频属性的抓取
# BV号为1TE411j7No的视频属性抓取结束
# 开始BV号为1dE411V7UA视频属性的抓取
# BV号为1dE411V7UA的视频属性抓取结束
# 开始BV号为1t7411o7sb视频属性的抓取
# BV号为1t7411o7sb的视频属性抓取结束
# 开始BV号为1RE411c7k2视频属性的抓取
# BV号为1RE411c7k2的视频属性抓取结束
# 开始BV号为17T4y157vo视频属性的抓取
# BV号为17T4y157vo的视频属性抓取结束
# 开始BV号为1U7411o7Ph视频属性的抓取
# BV号为1U7411o7Ph的视频属性抓取结束
# 开始BV号为1q7411U7JE视频属性的抓取
# BV号为1q7411U7JE的视频属性抓取结束
# 开始BV号为13z411b7Z8视频属性的抓取
# BV号为13z411b7Z8的视频属性抓取结束
# 开始BV号为1n7411f7zC视频属性的抓取
# BV号为1n7411f7zC的视频属性抓取结束
# 开始BV号为167411y7KJ视频属性的抓取
# BV号为167411y7KJ的视频属性抓取结束
# 开始BV号为1B741127v2视频属性的抓取
# BV号为1B741127v2的视频属性抓取结束
# 开始BV号为1G7411D79r视频属性的抓取
# BV号为1G7411D79r的视频属性抓取结束
# 开始BV号为1Z7411Z7bd视频属性的抓取
# BV号为1Z7411Z7bd的视频属性抓取结束
# 开始BV号为1BE411P7Ex视频属性的抓取
# BV号为1BE411P7Ex的视频属性抓取结束
# 开始BV号为1Uc41187gr视频属性的抓取
# BV号为1Uc41187gr的视频属性抓取结束
# 开始BV号为1g7411R7bG视频属性的抓取
# BV号为1g7411R7bG的视频属性抓取结束
# 开始BV号为1wE41147ox视频属性的抓取
# BV号为1wE41147ox的视频属性抓取结束
# 开始BV号为1A7411971X视频属性的抓取
# BV号为1A7411971X的视频属性抓取结束
# 开始BV号为1DE41157D2视频属性的抓取
# BV号为1DE41157D2的视频属性抓取结束
# 开始BV号为1m7411C7MT视频属性的抓取
# BV号为1m7411C7MT的视频属性抓取结束
# 开始BV号为1UE411x7Xq视频属性的抓取
# 开始BV号为1UE411x7Xq视频属性的抓取
# BV号为1UE411x7Xq的视频属性抓取结束
# 开始BV号为1FE411j7Cv视频属性的抓取
# BV号为1FE411j7Cv的视频属性抓取结束
# 开始BV号为117411d79F视频属性的抓取
# BV号为117411d79F的视频属性抓取结束
# 开始BV号为1E7411U7JT视频属性的抓取
# BV号为1E7411U7JT的视频属性抓取结束
# 开始BV号为1jE411A7Lp视频属性的抓取
# BV号为1jE411A7Lp的视频属性抓取结束
# 开始BV号为1TE41147Zj视频属性的抓取
# BV号为1TE41147Zj的视频属性抓取结束
# 开始BV号为1R741197hy视频属性的抓取
# BV号为1R741197hy的视频属性抓取结束
# 开始BV号为1a7411o7JC视频属性的抓取
# BV号为1a7411o7JC的视频属性抓取结束
# 开始BV号为1hE411c7WT视频属性的抓取
# BV号为1hE411c7WT的视频属性抓取结束
# 开始BV号为1gE411A7C6视频属性的抓取
# BV号为1gE411A7C6的视频属性抓取结束
# 开始BV号为1DE411c7TV视频属性的抓取
# BV号为1DE411c7TV的视频属性抓取结束
# 开始BV号为14E411u7iq视频属性的抓取
# BV号为14E411u7iq的视频属性抓取结束
# 开始BV号为1k741127Zi视频属性的抓取
# BV号为1k741127Zi的视频属性抓取结束
# 开始BV号为1CE411W7ei视频属性的抓取
# BV号为1CE411W7ei的视频属性抓取结束
# 开始BV号为1Gp4y1C77k视频属性的抓取
# BV号为1Gp4y1C77k的视频属性抓取结束
# 开始BV号为16K4y1C7iB视频属性的抓取
# 开始BV号为16K4y1C7iB视频属性的抓取
# 开始BV号为16K4y1C7iB视频属性的抓取
# 开始BV号为16K4y1C7iB视频属性的抓取
# BV号为16K4y1C7iB的视频属性抓取结束
# 开始BV号为1TE41157cT视频属性的抓取
# BV号为1TE41157cT的视频属性抓取结束
# 开始BV号为1564y1u7wX视频属性的抓取
# BV号为1564y1u7wX的视频属性抓取结束
# 开始BV号为1mE411w7cV视频属性的抓取
# BV号为1mE411w7cV的视频属性抓取结束
# 开始BV号为1hE411w79Y视频属性的抓取
# BV号为1hE411w79Y的视频属性抓取结束
# 开始BV号为1BE411P7GK视频属性的抓取
# BV号为1BE411P7GK的视频属性抓取结束
# 开始BV号为1R7411C7Ng视频属性的抓取
# BV号为1R7411C7Ng的视频属性抓取结束
# 开始BV号为1ME411G7ch视频属性的抓取
# BV号为1ME411G7ch的视频属性抓取结束
# 开始BV号为1Z541147EX视频属性的抓取
# BV号为1Z541147EX的视频属性抓取结束
# 开始BV号为1KE411F7Nc视频属性的抓取
# BV号为1KE411F7Nc的视频属性抓取结束
# 开始BV号为1UZ4y1j7oY视频属性的抓取
# BV号为1UZ4y1j7oY的视频属性抓取结束
# 开始BV号为1yA41187Ba视频属性的抓取
# BV号为1yA41187Ba的视频属性抓取结束
# 开始BV号为1p7411X72a视频属性的抓取
# BV号为1p7411X72a的视频属性抓取结束
# 开始BV号为1vE41147V9视频属性的抓取
# BV号为1vE41147V9的视频属性抓取结束
# 开始BV号为1A7411y7V6视频属性的抓取
# BV号为1A7411y7V6的视频属性抓取结束
# 开始BV号为1CE411A7Kq视频属性的抓取
# BV号为1CE411A7Kq的视频属性抓取结束
# 开始BV号为1JE411L7vG视频属性的抓取
# BV号为1JE411L7vG的视频属性抓取结束
# 开始BV号为1a7411m7mV视频属性的抓取
# BV号为1a7411m7mV的视频属性抓取结束
# 开始BV号为1f7411Z7Xd视频属性的抓取
# BV号为1f7411Z7Xd的视频属性抓取结束
# 开始BV号为1hE411p72M视频属性的抓取
# BV号为1hE411p72M的视频属性抓取结束
# 开始BV号为1fE411x7QF视频属性的抓取
# BV号为1fE411x7QF的视频属性抓取结束
# 开始BV号为1rE411w7Hg视频属性的抓取
# BV号为1rE411w7Hg的视频属性抓取结束
# 开始BV号为1n7411f7en视频属性的抓取
# BV号为1n7411f7en的视频属性抓取结束
# 开始BV号为1Ug4y1b7ke视频属性的抓取
# BV号为1Ug4y1b7ke的视频属性抓取结束
# 开始BV号为1Y7411Z7f5视频属性的抓取
# BV号为1Y7411Z7f5的视频属性抓取结束
# 开始BV号为1xz411b7in视频属性的抓取
# BV号为1xz411b7in的视频属性抓取结束
# 开始BV号为1kE411A7tf视频属性的抓取
# BV号为1kE411A7tf的视频属性抓取结束
# 开始BV号为1BE411x7jW视频属性的抓取
# BV号为1BE411x7jW的视频属性抓取结束
# 开始BV号为1S7411m7ZB视频属性的抓取
# BV号为1S7411m7ZB的视频属性抓取结束
# <ipython-input-11-b580ddf1ba89>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为177411R7Sm视频属性的抓取
# BV号为177411R7Sm的视频属性抓取结束
# 开始BV号为1ZE411V7kD视频属性的抓取
# BV号为1ZE411V7kD的视频属性抓取结束
# 开始BV号为1aK4y1C7Hy视频属性的抓取
# BV号为1aK4y1C7Hy的视频属性抓取结束
# 开始BV号为1nE411M7VD视频属性的抓取
# BV号为1nE411M7VD的视频属性抓取结束
# 开始BV号为1vE411F77n视频属性的抓取
# BV号为1vE411F77n的视频属性抓取结束
# 开始BV号为1F741127Gq视频属性的抓取
# BV号为1F741127Gq的视频属性抓取结束
# 开始BV号为1Y7411d7Ab视频属性的抓取
# BV号为1Y7411d7Ab的视频属性抓取结束
# 开始BV号为1464y1u7eD视频属性的抓取
# BV号为1464y1u7eD的视频属性抓取结束
# 开始BV号为1Kt4y127QQ视频属性的抓取
# BV号为1Kt4y127QQ的视频属性抓取结束
# 开始BV号为1vK41177Zm视频属性的抓取
# BV号为1vK41177Zm的视频属性抓取结束
# 开始BV号为1di4y1t7QK视频属性的抓取
# BV号为1di4y1t7QK的视频属性抓取结束
# 开始BV号为1RK411V7NV视频属性的抓取
# BV号为1RK411V7NV的视频属性抓取结束
# 开始BV号为1jf4y1S7wr视频属性的抓取
# BV号为1jf4y1S7wr的视频属性抓取结束
# 开始BV号为13e411s7Xm视频属性的抓取
# BV号为13e411s7Xm的视频属性抓取结束
# 开始BV号为1Hi4y1t7J7视频属性的抓取
# BV号为1Hi4y1t7J7的视频属性抓取结束
# 开始BV号为1vg4y1874S视频属性的抓取
# BV号为1vg4y1874S的视频属性抓取结束
# 开始BV号为1kk4y1R7Ha视频属性的抓取
# BV号为1kk4y1R7Ha的视频属性抓取结束
# 开始BV号为1n64y1M7cH视频属性的抓取
# BV号为1n64y1M7cH的视频属性抓取结束
# 开始BV号为1wz411z7VB视频属性的抓取
# BV号为1wz411z7VB的视频属性抓取结束
# 开始BV号为1164y1T7BW视频属性的抓取
# BV号为1164y1T7BW的视频属性抓取结束
# 开始BV号为11t4y1m7Fh视频属性的抓取
# BV号为11t4y1m7Fh的视频属性抓取结束
# 开始BV号为1yT4y1G7zn视频属性的抓取
# BV号为1yT4y1G7zn的视频属性抓取结束
# 开始BV号为1ZK4y1r7Vm视频属性的抓取
# BV号为1ZK4y1r7Vm的视频属性抓取结束
# 开始BV号为1fp4y1C7Lh视频属性的抓取
# BV号为1fp4y1C7Lh的视频属性抓取结束
# 开始BV号为1pt4y1U799视频属性的抓取
# BV号为1pt4y1U799的视频属性抓取结束
# 开始BV号为1fk4y1d73c视频属性的抓取
# BV号为1fk4y1d73c的视频属性抓取结束
# 开始BV号为1rT4y1g75z视频属性的抓取
# BV号为1rT4y1g75z的视频属性抓取结束
# 开始BV号为1YA411473x视频属性的抓取
# BV号为1YA411473x的视频属性抓取结束
# 开始BV号为1Ae411s7HH视频属性的抓取
# BV号为1Ae411s7HH的视频属性抓取结束
# 开始BV号为1Dk4y1R7AL视频属性的抓取
# BV号为1Dk4y1R7AL的视频属性抓取结束
# 开始BV号为1n64y1T7AV视频属性的抓取
# BV号为1n64y1T7AV的视频属性抓取结束
# 开始BV号为1Ha4y147nL视频属性的抓取
# BV号为1Ha4y147nL的视频属性抓取结束
# 开始BV号为1hz411B7rQ视频属性的抓取
# BV号为1hz411B7rQ的视频属性抓取结束
# 开始BV号为1fT4y1G7UG视频属性的抓取
# BV号为1fT4y1G7UG的视频属性抓取结束
# 开始BV号为1Rk4y1d7iA视频属性的抓取
# BV号为1Rk4y1d7iA的视频属性抓取结束
# 开始BV号为1Ne411x7E5视频属性的抓取
# BV号为1Ne411x7E5的视频属性抓取结束
# 开始BV号为1Zp4y1X7Cw视频属性的抓取
# BV号为1Zp4y1X7Cw的视频属性抓取结束
# 开始BV号为1pQ4y1K7TB视频属性的抓取
# BV号为1pQ4y1K7TB的视频属性抓取结束
# 开始BV号为1Hg4y1z7Yr视频属性的抓取
# BV号为1Hg4y1z7Yr的视频属性抓取结束
# 开始BV号为1BK4y1k7We视频属性的抓取
# BV号为1BK4y1k7We的视频属性抓取结束
# 开始BV号为1dg4y187iZ视频属性的抓取
# BV号为1dg4y187iZ的视频属性抓取结束
# 开始BV号为1ae411s78y视频属性的抓取
# BV号为1ae411s78y的视频属性抓取结束
# 开始BV号为1ba4y1t7gF视频属性的抓取
# BV号为1ba4y1t7gF的视频属性抓取结束
# 开始BV号为1Lz41187aX视频属性的抓取
# BV号为1Lz41187aX的视频属性抓取结束
# <ipython-input-11-b580ddf1ba89>:190: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1jC4y1x7ud视频属性的抓取
# BV号为1jC4y1x7ud的视频属性抓取结束
# 开始BV号为1gi4y1t7Eu视频属性的抓取
# BV号为1gi4y1t7Eu的视频属性抓取结束
# 开始BV号为1st4y1U7KW视频属性的抓取
# BV号为1st4y1U7KW的视频属性抓取结束
# 开始BV号为1AC4y1x78t视频属性的抓取
# BV号为1AC4y1x78t的视频属性抓取结束
# 开始BV号为1eV411o7qX视频属性的抓取
# BV号为1eV411o7qX的视频属性抓取结束
# 开始BV号为1Le411x7D2视频属性的抓取
# BV号为1Le411x7D2的视频属性抓取结束
# 开始BV号为1NC4y1x7Pz视频属性的抓取
# BV号为1NC4y1x7Pz的视频属性抓取结束
# 开始BV号为1up4y1y79e视频属性的抓取
# BV号为1up4y1y79e的视频属性抓取结束
# 开始BV号为1fk4y1d7vq视频属性的抓取
# BV号为1fk4y1d7vq的视频属性抓取结束
# 开始BV号为1Dk4y1r7WE视频属性的抓取
# BV号为1Dk4y1r7WE的视频属性抓取结束
# 开始BV号为18p4y1X7kG视频属性的抓取
# BV号为18p4y1X7kG的视频属性抓取结束
# 开始BV号为1Pf4y1S7WG视频属性的抓取
# BV号为1Pf4y1S7WG的视频属性抓取结束
# 开始BV号为1Li4y187uh视频属性的抓取
# BV号为1Li4y187uh的视频属性抓取结束
# 开始BV号为1Dz411B7XC视频属性的抓取
# BV号为1Dz411B7XC的视频属性抓取结束
# 开始BV号为1ut4y1m77r视频属性的抓取
# BV号为1ut4y1m77r的视频属性抓取结束
# 开始BV号为1ip4y117ee视频属性的抓取
# BV号为1ip4y117ee的视频属性抓取结束
# 开始BV号为1QA411b7F1视频属性的抓取
# BV号为1QA411b7F1的视频属性抓取结束
# 开始BV号为1vi4y1b79B视频属性的抓取
# BV号为1vi4y1b79B的视频属性抓取结束
# 开始BV号为1K54y197Zm视频属性的抓取
# BV号为1K54y197Zm的视频属性抓取结束
# 开始BV号为18A411h76o视频属性的抓取
# BV号为18A411h76o的视频属性抓取结束
# 开始BV号为1xK4y1C7qu视频属性的抓取
# BV号为1xK4y1C7qu的视频属性抓取结束
# 开始BV号为1dz411B7ke视频属性的抓取
# BV号为1dz411B7ke的视频属性抓取结束
# 开始BV号为1Ke41147d3视频属性的抓取
# BV号为1Ke41147d3的视频属性抓取结束
# 开始BV号为1Hg4y1z7wa视频属性的抓取
# BV号为1Hg4y1z7wa的视频属性抓取结束
# 开始BV号为1Bf4y1S7Vn视频属性的抓取
# BV号为1Bf4y1S7Vn的视频属性抓取结束
# 开始BV号为1ht4y127Wy视频属性的抓取
# BV号为1ht4y127Wy的视频属性抓取结束
# 开始BV号为1Et4y127Kb视频属性的抓取
# BV号为1Et4y127Kb的视频属性抓取结束
# 开始BV号为1Ne411s76r视频属性的抓取
# BV号为1Ne411s76r的视频属性抓取结束
# 开始BV号为1D54y197na视频属性的抓取
# BV号为1D54y197na的视频属性抓取结束
# 开始BV号为19e411W7cP视频属性的抓取
# BV号为19e411W7cP的视频属性抓取结束
# 开始BV号为16i4y1t7bA视频属性的抓取
# BV号为16i4y1t7bA的视频属性抓取结束
# 开始BV号为1oz411t7vr视频属性的抓取
# BV号为1oz411t7vr的视频属性抓取结束
# 开始BV号为1cC4y1W7gQ视频属性的抓取
# BV号为1cC4y1W7gQ的视频属性抓取结束
# 开始BV号为1AC4y1W7zV视频属性的抓取
# BV号为1AC4y1W7zV的视频属性抓取结束
# 开始BV号为1EV411Z741视频属性的抓取
# BV号为1EV411Z741的视频属性抓取结束
# 开始BV号为1az411h7Uq视频属性的抓取
# BV号为1az411h7Uq的视频属性抓取结束
# 开始BV号为18i4y1t7Kc视频属性的抓取
# BV号为18i4y1t7Kc的视频属性抓取结束
# 开始BV号为1Nz411b7KL视频属性的抓取
# BV号为1Nz411b7KL的视频属性抓取结束
# 开始BV号为1JQ4y1K7Vw视频属性的抓取
# BV号为1JQ4y1K7Vw的视频属性抓取结束
# 开始BV号为1h54y197pB视频属性的抓取
# BV号为1h54y197pB的视频属性抓取结束
# 开始BV号为1Dp4y1C739视频属性的抓取
# BV号为1Dp4y1C739的视频属性抓取结束
# 开始BV号为1Jf4y1S7mY视频属性的抓取
# BV号为1Jf4y1S7mY的视频属性抓取结束
# 开始BV号为1B64y1T7z7视频属性的抓取
# BV号为1B64y1T7z7的视频属性抓取结束
# 开始BV号为1S64y1u7kg视频属性的抓取
# BV号为1S64y1u7kg的视频属性抓取结束
# 开始BV号为1N54y1R79v视频属性的抓取
# BV号为1N54y1R79v的视频属性抓取结束
# 开始BV号为1xV411Z7Yd视频属性的抓取
# BV号为1xV411Z7Yd的视频属性抓取结束
# 开始BV号为1Ke41147jM视频属性的抓取
# BV号为1Ke41147jM的视频属性抓取结束
# 开始BV号为1aQ4y1K7WG视频属性的抓取
# BV号为1aQ4y1K7WG的视频属性抓取结束
# 开始BV号为1cQ4y1T7qy视频属性的抓取
# BV号为1cQ4y1T7qy的视频属性抓取结束
# 开始BV号为1kt4y127QS视频属性的抓取
# BV号为1kt4y127QS的视频属性抓取结束
# 开始BV号为1o5411t74C视频属性的抓取
# BV号为1o5411t74C的视频属性抓取结束
# 开始BV号为1ip4y1X74t视频属性的抓取
# BV号为1ip4y1X74t的视频属性抓取结束
# 开始BV号为1Tp4y1y73W视频属性的抓取
# BV号为1Tp4y1y73W的视频属性抓取结束
# 开始BV号为1GT4y157a4视频属性的抓取
# BV号为1GT4y157a4的视频属性抓取结束
# 开始BV号为1oc411h7Vd视频属性的抓取
# BV号为1oc411h7Vd的视频属性抓取结束
# 开始BV号为115411t7sE视频属性的抓取
# BV号为115411t7sE的视频属性抓取结束
# 开始BV号为1W64y1M73x视频属性的抓取
# BV号为1W64y1M73x的视频属性抓取结束
# 开始BV号为1xK41157dN视频属性的抓取
# BV号为1xK41157dN的视频属性抓取结束
# 开始BV号为13C4y1W7Ks视频属性的抓取
# BV号为13C4y1W7Ks的视频属性抓取结束
# 开始BV号为1Uz411b7Xm视频属性的抓取
# BV号为1Uz411b7Xm的视频属性抓取结束
# 开始BV号为1iz411B7Ur视频属性的抓取
# BV号为1iz411B7Ur的视频属性抓取结束
# 开始BV号为1uK41157Xv视频属性的抓取
# BV号为1uK41157Xv的视频属性抓取结束
# 开始BV号为1xQ4y1N76X视频属性的抓取
# BV号为1xQ4y1N76X的视频属性抓取结束
# 开始BV号为1Kz411q7yi视频属性的抓取
# BV号为1Kz411q7yi的视频属性抓取结束
# 开始BV号为1Vf4y1m74E视频属性的抓取
# BV号为1Vf4y1m74E的视频属性抓取结束
# 开始BV号为1Xz4y1X7dw视频属性的抓取
# BV号为1Xz4y1X7dw的视频属性抓取结束
# 开始BV号为1xf4y127Zp视频属性的抓取
# BV号为1xf4y127Zp的视频属性抓取结束
# 开始BV号为18Q4y1N7FY视频属性的抓取
# BV号为18Q4y1N7FY的视频属性抓取结束
# 开始BV号为1np4y197aa视频属性的抓取
# BV号为1np4y197aa的视频属性抓取结束
# 开始BV号为1Kt4y117Am视频属性的抓取
# BV号为1Kt4y117Am的视频属性抓取结束
# 开始BV号为1Yg4y1z7dD视频属性的抓取
# BV号为1Yg4y1z7dD的视频属性抓取结束
# 开始BV号为1Y64y1M7sC视频属性的抓取
# BV号为1Y64y1M7sC的视频属性抓取结束
# 开始BV号为1oK411W7uY视频属性的抓取
# BV号为1oK411W7uY的视频属性抓取结束
# 开始BV号为1D5411s7Sh视频属性的抓取
# BV号为1D5411s7Sh的视频属性抓取结束
# 开始BV号为1UC4y1W7sv视频属性的抓取
# BV号为1UC4y1W7sv的视频属性抓取结束
# 开始BV号为1g54y1X7jZ视频属性的抓取
# BV号为1g54y1X7jZ的视频属性抓取结束
# 开始BV号为12K4y1t7KW视频属性的抓取
# BV号为12K4y1t7KW的视频属性抓取结束
# 开始BV号为1954y1D7SE视频属性的抓取
# BV号为1954y1D7SE的视频属性抓取结束
# 开始BV号为1Up4y1Q7tt视频属性的抓取
# BV号为1Up4y1Q7tt的视频属性抓取结束
# 开始BV号为1RK411W7CM视频属性的抓取
# BV号为1RK411W7CM的视频属性抓取结束
# 开始BV号为1FK4y1t7vY视频属性的抓取
# BV号为1FK4y1t7vY的视频属性抓取结束
# 开始BV号为1j54y1X7jE视频属性的抓取
# BV号为1j54y1X7jE的视频属性抓取结束
# 开始BV号为1oa4y1v7FL视频属性的抓取
# BV号为1oa4y1v7FL的视频属性抓取结束
# 开始BV号为1aA411q7ig视频属性的抓取
# BV号为1aA411q7ig的视频属性抓取结束
# 开始BV号为1dZ4y1p7bS视频属性的抓取
# BV号为1dZ4y1p7bS的视频属性抓取结束
# 开始BV号为1nT4y1g7BY视频属性的抓取
# BV号为1nT4y1g7BY的视频属性抓取结束
# 开始BV号为1aa4y1e7qR视频属性的抓取
# BV号为1aa4y1e7qR的视频属性抓取结束
# 开始BV号为1oz411q7yV视频属性的抓取
# BV号为1oz411q7yV的视频属性抓取结束
# 开始BV号为1Gz411B7RW视频属性的抓取
# BV号为1Gz411B7RW的视频属性抓取结束
# 开始BV号为1Wz411z7Qy视频属性的抓取
# BV号为1Wz411z7Qy的视频属性抓取结束
# 开始BV号为1wi4y1b7ct视频属性的抓取
# BV号为1wi4y1b7ct的视频属性抓取结束
# 开始BV号为1HK411s7yv视频属性的抓取
# BV号为1HK411s7yv的视频属性抓取结束
# 开始BV号为16g4y1i7wd视频属性的抓取
# BV号为16g4y1i7wd的视频属性抓取结束
# 开始BV号为1E5411s7GH视频属性的抓取
# BV号为1E5411s7GH的视频属性抓取结束
# 开始BV号为1vz411q783视频属性的抓取
# BV号为1vz411q783的视频属性抓取结束
# 开始BV号为1tT4y1378g视频属性的抓取
# BV号为1tT4y1378g的视频属性抓取结束
# 开始BV号为1Nz411q7SG视频属性的抓取
# BV号为1Nz411q7SG的视频属性抓取结束
# 开始BV号为1Kz411q7Y6视频属性的抓取
# BV号为1Kz411q7Y6的视频属性抓取结束
# 开始BV号为1zQ4y1A7kQ视频属性的抓取
# BV号为1zQ4y1A7kQ的视频属性抓取结束
# 开始BV号为1xp4y1X7T1视频属性的抓取
# BV号为1xp4y1X7T1的视频属性抓取结束
# 开始BV号为1RA41147oC视频属性的抓取
# BV号为1RA41147oC的视频属性抓取结束
# 开始BV号为1aC4y1H72h视频属性的抓取
# BV号为1aC4y1H72h的视频属性抓取结束
# 开始BV号为16V411C7vC视频属性的抓取
# BV号为16V411C7vC的视频属性抓取结束
# 开始BV号为1ke411p7Zf视频属性的抓取
# BV号为1ke411p7Zf的视频属性抓取结束
# 开始BV号为11z411v79V视频属性的抓取
# BV号为11z411v79V的视频属性抓取结束
# 开始BV号为1VK411W7KR视频属性的抓取
# BV号为1VK411W7KR的视频属性抓取结束
# 开始BV号为1tV411C7NJ视频属性的抓取
# BV号为1tV411C7NJ的视频属性抓取结束
# 开始BV号为1vC4y1p79d视频属性的抓取
# BV号为1vC4y1p79d的视频属性抓取结束
# 开始BV号为1GK411s7cz视频属性的抓取
# BV号为1GK411s7cz的视频属性抓取结束
# 开始BV号为1WQ4y1N7D9视频属性的抓取
# BV号为1WQ4y1N7D9的视频属性抓取结束
# 开始BV号为15k4y1r724视频属性的抓取
# BV号为15k4y1r724的视频属性抓取结束
# 开始BV号为1A54y1Q72t视频属性的抓取
# BV号为1A54y1Q72t的视频属性抓取结束
# 开始BV号为1tf4y1m7xy视频属性的抓取
# BV号为1tf4y1m7xy的视频属性抓取结束
# 开始BV号为1r54y1D7Ch视频属性的抓取
# BV号为1r54y1D7Ch的视频属性抓取结束
# 开始BV号为1P54y1X7VQ视频属性的抓取
# BV号为1P54y1X7VQ的视频属性抓取结束
# 开始BV号为1Bi4y1s7Do视频属性的抓取
# BV号为1Bi4y1s7Do的视频属性抓取结束
# 开始BV号为15Q4y1P725视频属性的抓取
# BV号为15Q4y1P725的视频属性抓取结束
# 开始BV号为1EK4y1t7x1视频属性的抓取
# BV号为1EK4y1t7x1的视频属性抓取结束
# 开始BV号为1WV411C7uJ视频属性的抓取
# BV号为1WV411C7uJ的视频属性抓取结束
# 开始BV号为15z411q7ox视频属性的抓取
# BV号为15z411q7ox的视频属性抓取结束
# 开始BV号为1Lg4y1B7rG视频属性的抓取
# BV号为1Lg4y1B7rG的视频属性抓取结束
# 开始BV号为1Fa4y1i7ib视频属性的抓取
# BV号为1Fa4y1i7ib的视频属性抓取结束
# 开始BV号为1hK411W7id视频属性的抓取
# BV号为1hK411W7id的视频属性抓取结束
# 开始BV号为175411s7U8视频属性的抓取
# BV号为175411s7U8的视频属性抓取结束
# 开始BV号为1VA411q7Fb视频属性的抓取
# BV号为1VA411q7Fb的视频属性抓取结束
# 开始BV号为1yZ4y1p7a1视频属性的抓取
# BV号为1yZ4y1p7a1的视频属性抓取结束
# 开始BV号为1yp4y197Tg视频属性的抓取
# BV号为1yp4y197Tg的视频属性抓取结束
# 开始BV号为1hz411q7Kn视频属性的抓取
# BV号为1hz411q7Kn的视频属性抓取结束
# 开始BV号为1CV411C7QE视频属性的抓取
# BV号为1CV411C7QE的视频属性抓取结束
# 开始BV号为1tp4y1Q7Vf视频属性的抓取
# BV号为1tp4y1Q7Vf的视频属性抓取结束
# 开始BV号为1qz411q71R视频属性的抓取
# BV号为1qz411q71R的视频属性抓取结束
# 开始BV号为1zV411C79J视频属性的抓取
# BV号为1zV411C79J的视频属性抓取结束
# 开始BV号为1HK411s7TF视频属性的抓取
# BV号为1HK411s7TF的视频属性抓取结束
# 开始BV号为1ye411p7vo视频属性的抓取
# BV号为1ye411p7vo的视频属性抓取结束
# 开始BV号为1LK411s7Jt视频属性的抓取
# BV号为1LK411s7Jt的视频属性抓取结束
# 开始BV号为1af4y1m7hP视频属性的抓取
# BV号为1af4y1m7hP的视频属性抓取结束
# 开始BV号为1Rz411v75a视频属性的抓取
# BV号为1Rz411v75a的视频属性抓取结束
# 开始BV号为1Ae411W7NP视频属性的抓取
# BV号为1Ae411W7NP的视频属性抓取结束
# 开始BV号为1s541147yt视频属性的抓取
# BV号为1s541147yt的视频属性抓取结束
# 开始BV号为1kZ4y1p7xV视频属性的抓取
# BV号为1kZ4y1p7xV的视频属性抓取结束
# 开始BV号为1j541147BN视频属性的抓取
# BV号为1j541147BN的视频属性抓取结束
# 开始BV号为1Ng4y1B7AV视频属性的抓取
# BV号为1Ng4y1B7AV的视频属性抓取结束
# 开始BV号为12z4y1R7xD视频属性的抓取
# BV号为12z4y1R7xD的视频属性抓取结束
# 开始BV号为1SQ4y1N7BJ视频属性的抓取
# BV号为1SQ4y1N7BJ的视频属性抓取结束
# 开始BV号为155411x7pp视频属性的抓取
# BV号为155411x7pp的视频属性抓取结束
# 开始BV号为16k4y167eR视频属性的抓取
# BV号为16k4y167eR的视频属性抓取结束
# 开始BV号为17k4y1k7Bq视频属性的抓取
# BV号为17k4y1k7Bq的视频属性抓取结束
# 开始BV号为1Ta4y1v7fa视频属性的抓取
# BV号为1Ta4y1v7fa的视频属性抓取结束
# 开始BV号为1hT4y1u7Mt视频属性的抓取
# BV号为1hT4y1u7Mt的视频属性抓取结束
# 开始BV号为1v54y1X7Lf视频属性的抓取
# BV号为1v54y1X7Lf的视频属性抓取结束
# 开始BV号为1mi4y1474R视频属性的抓取
# BV号为1mi4y1474R的视频属性抓取结束
# 开始BV号为1uk4y167JY视频属性的抓取
# BV号为1uk4y167JY的视频属性抓取结束
# 开始BV号为1ii4y1s7Zn视频属性的抓取
# BV号为1ii4y1s7Zn的视频属性抓取结束
# 开始BV号为1Ap4y1X7oc视频属性的抓取
# BV号为1Ap4y1X7oc的视频属性抓取结束
# 开始BV号为1ti4y1472Y视频属性的抓取
# BV号为1ti4y1472Y的视频属性抓取结束
# 开始BV号为1HA411t7dw视频属性的抓取
# BV号为1HA411t7dw的视频属性抓取结束
# 开始BV号为1Af4y127ps视频属性的抓取
# BV号为1Af4y127ps的视频属性抓取结束
# 开始BV号为1eV411d7bg视频属性的抓取
# BV号为1eV411d7bg的视频属性抓取结束
# 开始BV号为1Xp4y1Q7dP视频属性的抓取
# BV号为1Xp4y1Q7dP的视频属性抓取结束
# 开始BV号为11z411v7gv视频属性的抓取
# BV号为11z411v7gv的视频属性抓取结束
# 开始BV号为1xC4y1H7p4视频属性的抓取
# BV号为1xC4y1H7p4的视频属性抓取结束
# 开始BV号为14T4y137Hc视频属性的抓取
# BV号为14T4y137Hc的视频属性抓取结束
# 开始BV号为1Dk4y1B77w视频属性的抓取
# 开始BV号为1Dk4y1B77w视频属性的抓取
# BV号为1Dk4y1B77w的视频属性抓取结束
# 开始BV号为1og4y1i7wm视频属性的抓取
# BV号为1og4y1i7wm的视频属性抓取结束
# 开始BV号为1rQ4y1P7TJ视频属性的抓取
# BV号为1rQ4y1P7TJ的视频属性抓取结束
# 开始BV号为1k54y1B7rZ视频属性的抓取
# BV号为1k54y1B7rZ的视频属性抓取结束
# 开始BV号为12z4y197S7视频属性的抓取
# BV号为12z4y197S7的视频属性抓取结束
# 开始BV号为1mk4y1z7e4视频属性的抓取
# BV号为1mk4y1z7e4的视频属性抓取结束
# 开始BV号为1254y1B7YS视频属性的抓取
# BV号为1254y1B7YS的视频属性抓取结束
# 开始BV号为1iT4y1E7NZ视频属性的抓取
# BV号为1iT4y1E7NZ的视频属性抓取结束
# 开始BV号为1ii4y1x7wE视频属性的抓取
# BV号为1ii4y1x7wE的视频属性抓取结束
# 开始BV号为1CK4y1x7Yq视频属性的抓取
# BV号为1CK4y1x7Yq的视频属性抓取结束
# 开始BV号为15k4y1z72w视频属性的抓取
# BV号为15k4y1z72w的视频属性抓取结束
# 开始BV号为1TT4y1J7He视频属性的抓取
# BV号为1TT4y1J7He的视频属性抓取结束
# 开始BV号为1wV41167wc视频属性的抓取
# BV号为1wV41167wc的视频属性抓取结束
# 开始BV号为1kg4y1q7Re视频属性的抓取
# BV号为1kg4y1q7Re的视频属性抓取结束
# 开始BV号为1Wp4y1D7zq视频属性的抓取
# BV号为1Wp4y1D7zq的视频属性抓取结束
# 开始BV号为1ig4y1q7VC视频属性的抓取
# BV号为1ig4y1q7VC的视频属性抓取结束
# 开始BV号为1UT4y1J7wT视频属性的抓取
# BV号为1UT4y1J7wT的视频属性抓取结束
# 开始BV号为16z411i7y4视频属性的抓取
# BV号为16z411i7y4的视频属性抓取结束
# 开始BV号为1AD4y1Q7Ai视频属性的抓取
# BV号为1AD4y1Q7Ai的视频属性抓取结束
# 开始BV号为15V41167w7视频属性的抓取
# BV号为15V41167w7的视频属性抓取结束
# 开始BV号为1mz411i7WM视频属性的抓取
# BV号为1mz411i7WM的视频属性抓取结束
# 开始BV号为1Rk4y1z7Ar视频属性的抓取
# BV号为1Rk4y1z7Ar的视频属性抓取结束
# 开始BV号为1aT4y1J75Z视频属性的抓取
# BV号为1aT4y1J75Z的视频属性抓取结束
# 开始BV号为1QA411q7eN视频属性的抓取
# BV号为1QA411q7eN的视频属性抓取结束
# 开始BV号为1yk4y1z7DT视频属性的抓取
# BV号为1yk4y1z7DT的视频属性抓取结束
# 开始BV号为1qZ4y1H7Km视频属性的抓取
# BV号为1qZ4y1H7Km的视频属性抓取结束
# 开始BV号为1254y1B7HQ视频属性的抓取
# BV号为1254y1B7HQ的视频属性抓取结束
# 开始BV号为1yk4y1q7Lx视频属性的抓取
# BV号为1yk4y1q7Lx的视频属性抓取结束
# 开始BV号为16g4y1v7f8视频属性的抓取
# BV号为16g4y1v7f8的视频属性抓取结束
# 开始BV号为1YA411v7bw视频属性的抓取
# BV号为1YA411v7bw的视频属性抓取结束
# 开始BV号为1fz4y1Q7ph视频属性的抓取
# BV号为1fz4y1Q7ph的视频属性抓取结束
# 开始BV号为1sf4y117Wr视频属性的抓取
# BV号为1sf4y117Wr的视频属性抓取结束
# 开始BV号为13i4y1x7Be视频属性的抓取
# BV号为13i4y1x7Be的视频属性抓取结束
# 开始BV号为1Sg4y1v7Q3视频属性的抓取
# BV号为1Sg4y1v7Q3的视频属性抓取结束
# 开始BV号为1jT4y177M1视频属性的抓取
# BV号为1jT4y177M1的视频属性抓取结束
# 开始BV号为1g54y1B73T视频属性的抓取
# BV号为1g54y1B73T的视频属性抓取结束
# 开始BV号为1Ez411i7ec视频属性的抓取
# BV号为1Ez411i7ec的视频属性抓取结束
# 开始BV号为1dC4y1h7gw视频属性的抓取
# BV号为1dC4y1h7gw的视频属性抓取结束
# 开始BV号为1Qk4y1B7KK视频属性的抓取
# BV号为1Qk4y1B7KK的视频属性抓取结束
# 开始BV号为1Np4y1D7LV视频属性的抓取
# BV号为1Np4y1D7LV的视频属性抓取结束
# 开始BV号为1ef4y127qr视频属性的抓取
# BV号为1ef4y127qr的视频属性抓取结束
# 开始BV号为1Sv411B7Ea视频属性的抓取
# BV号为1Sv411B7Ea的视频属性抓取结束
# 开始BV号为1954y1i7Cd视频属性的抓取
# BV号为1954y1i7Cd的视频属性抓取结束
# 开始BV号为1ft4y1X7Gu视频属性的抓取
# BV号为1ft4y1X7Gu的视频属性抓取结束
# 开始BV号为115411W74K视频属性的抓取
# BV号为115411W74K的视频属性抓取结束
# 开始BV号为1uV411k7wY视频属性的抓取
# BV号为1uV411k7wY的视频属性抓取结束
# 开始BV号为1Mp4y1D7ZR视频属性的抓取
# BV号为1Mp4y1D7ZR的视频属性抓取结束
# 开始BV号为1mK411p7dG视频属性的抓取
# BV号为1mK411p7dG的视频属性抓取结束
# 开始BV号为1mp4y1D7B1视频属性的抓取
# BV号为1mp4y1D7B1的视频属性抓取结束
# 开始BV号为1dV411r7d3视频属性的抓取
# BV号为1dV411r7d3的视频属性抓取结束
# 开始BV号为1GK4y1b7VD视频属性的抓取
# BV号为1GK4y1b7VD的视频属性抓取结束
# 开始BV号为1zK411p79x视频属性的抓取
# BV号为1zK411p79x的视频属性抓取结束
# 开始BV号为1oK411H7ZK视频属性的抓取
# BV号为1oK411H7ZK的视频属性抓取结束
# 开始BV号为1Y5411W737视频属性的抓取
# BV号为1Y5411W737的视频属性抓取结束
# 开始BV号为11z411i7qL视频属性的抓取
# BV号为11z411i7qL的视频属性抓取结束
# 开始BV号为1LV411k7Jp视频属性的抓取
# BV号为1LV411k7Jp的视频属性抓取结束
# 开始BV号为19C4y1a7qx视频属性的抓取
# BV号为19C4y1a7qx的视频属性抓取结束
# 开始BV号为1Af4y1m7iv视频属性的抓取
# BV号为1Af4y1m7iv的视频属性抓取结束
# 开始BV号为1Nz4y1X7oT视频属性的抓取
# BV号为1Nz4y1X7oT的视频属性抓取结束
# 开始BV号为1ig4y1q7rj视频属性的抓取
# BV号为1ig4y1q7rj的视频属性抓取结束
# 开始BV号为13f4y11774视频属性的抓取
# BV号为13f4y11774的视频属性抓取结束
# 开始BV号为1YQ4y1P7Ae视频属性的抓取
# BV号为1YQ4y1P7Ae的视频属性抓取结束
# 开始BV号为1Vv411B7dA视频属性的抓取
# BV号为1Vv411B7dA的视频属性抓取结束
# 开始BV号为1rf4y127iM视频属性的抓取
# BV号为1rf4y127iM的视频属性抓取结束
# 开始BV号为1sD4y1Q7nj视频属性的抓取
# BV号为1sD4y1Q7nj的视频属性抓取结束
# 开始BV号为1Rz4y1975j视频属性的抓取
# BV号为1Rz4y1975j的视频属性抓取结束
# 开始BV号为1oK411p7Kv视频属性的抓取
# BV号为1oK411p7Kv的视频属性抓取结束
# 开始BV号为1iV411r71z视频属性的抓取
# BV号为1iV411r71z的视频属性抓取结束
# 开始BV号为1Q54y1B7Ak视频属性的抓取
# BV号为1Q54y1B7Ak的视频属性抓取结束
# 开始BV号为1kf4y117Ei视频属性的抓取
# BV号为1kf4y117Ei的视频属性抓取结束
# 开始BV号为1xk4y1z7Yq视频属性的抓取
# BV号为1xk4y1z7Yq的视频属性抓取结束
# 开始BV号为1ct4y197P2视频属性的抓取
# BV号为1ct4y197P2的视频属性抓取结束
# 开始BV号为1Ek4y1z7xk视频属性的抓取
# BV号为1Ek4y1z7xk的视频属性抓取结束
# 开始BV号为11p4y1D7on视频属性的抓取
# BV号为11p4y1D7on的视频属性抓取结束
# 开始BV号为1qQ4y1P7Xh视频属性的抓取
# BV号为1qQ4y1P7Xh的视频属性抓取结束
# 开始BV号为1ei4y1G77G视频属性的抓取
# BV号为1ei4y1G77G的视频属性抓取结束
# 开始BV号为13v411B7J6视频属性的抓取
# 开始BV号为13v411B7J6视频属性的抓取
# BV号为13v411B7J6的视频属性抓取结束
# 开始BV号为1Gv41167kV视频属性的抓取
# BV号为1Gv41167kV的视频属性抓取结束
# 开始BV号为15Z4y1H71y视频属性的抓取
# BV号为15Z4y1H71y的视频属性抓取结束
# 开始BV号为1nv411B7hz视频属性的抓取
# BV号为1nv411B7hz的视频属性抓取结束
# 开始BV号为1Q54y1B7q4视频属性的抓取
# BV号为1Q54y1B7q4的视频属性抓取结束
# 开始BV号为1Sg4y1i7Ec视频属性的抓取
# BV号为1Sg4y1i7Ec的视频属性抓取结束
# 开始BV号为1i54y1B7eU视频属性的抓取
# BV号为1i54y1B7eU的视频属性抓取结束
# 开始BV号为13A411i7ik视频属性的抓取
# BV号为13A411i7ik的视频属性抓取结束
# 开始BV号为1iT4y1J7Zo视频属性的抓取
# BV号为1iT4y1J7Zo的视频属性抓取结束
# 开始BV号为1MC4y1Y7AY视频属性的抓取
# BV号为1MC4y1Y7AY的视频属性抓取结束
# 开始BV号为1op4y1S7Cq视频属性的抓取
# BV号为1op4y1S7Cq的视频属性抓取结束
# 开始BV号为1cz4y1X7E1视频属性的抓取
# BV号为1cz4y1X7E1的视频属性抓取结束
# 开始BV号为1Np4y1Q7XD视频属性的抓取
# BV号为1Np4y1Q7XD的视频属性抓取结束
# 开始BV号为1Kt4y197xy视频属性的抓取
# BV号为1Kt4y197xy的视频属性抓取结束
# 开始BV号为1iz411e7rX视频属性的抓取
# BV号为1iz411e7rX的视频属性抓取结束
# 开始BV号为1GV411k7KJ视频属性的抓取
# BV号为1GV411k7KJ的视频属性抓取结束
# 开始BV号为1Yz4y1Q7cG视频属性的抓取
# BV号为1Yz4y1Q7cG的视频属性抓取结束
# 开始BV号为1bk4y1z7jg视频属性的抓取
# 开始BV号为1bk4y1z7jg视频属性的抓取
# BV号为1bk4y1z7jg的视频属性抓取结束
# 开始BV号为1Uz411e7zw视频属性的抓取
# BV号为1Uz411e7zw的视频属性抓取结束
# 开始BV号为1Yk4y1q7NS视频属性的抓取
# BV号为1Yk4y1q7NS的视频属性抓取结束
# 开始BV号为14a4y1Y7Z9视频属性的抓取
# BV号为14a4y1Y7Z9的视频属性抓取结束
# 开始BV号为1Yf4y1y7eU视频属性的抓取
# BV号为1Yf4y1y7eU的视频属性抓取结束
# 开始BV号为1cz411v7r3视频属性的抓取
# BV号为1cz411v7r3的视频属性抓取结束
# 开始BV号为1QV41167KQ视频属性的抓取
# BV号为1QV41167KQ的视频属性抓取结束
# 开始BV号为1J5411e7ZL视频属性的抓取
# BV号为1J5411e7ZL的视频属性抓取结束
# 开始BV号为1Kg4y1i7EK视频属性的抓取
# BV号为1Kg4y1i7EK的视频属性抓取结束
# 开始BV号为1M5411a7pt视频属性的抓取
# BV号为1M5411a7pt的视频属性抓取结束
# 开始BV号为1G5411Y7aV视频属性的抓取
# BV号为1G5411Y7aV的视频属性抓取结束
# 开始BV号为1VD4y1U7Ny视频属性的抓取
# BV号为1VD4y1U7Ny的视频属性抓取结束
# 开始BV号为1rz4y1D7LY视频属性的抓取
# BV号为1rz4y1D7LY的视频属性抓取结束
# 开始BV号为1PK4y1v7TX视频属性的抓取
# BV号为1PK4y1v7TX的视频属性抓取结束
# 开始BV号为16k4y1q7Wi视频属性的抓取
# BV号为16k4y1q7Wi的视频属性抓取结束
# 开始BV号为1qV411z7bC视频属性的抓取
# BV号为1qV411z7bC的视频属性抓取结束
# 开始BV号为18D4y1S7a3视频属性的抓取
# BV号为18D4y1S7a3的视频属性抓取结束
# 开始BV号为1iv411i7QF视频属性的抓取
# BV号为1iv411i7QF的视频属性抓取结束
# 开始BV号为1PK4y1x752视频属性的抓取
# BV号为1PK4y1x752的视频属性抓取结束
# 开始BV号为1aa4y1a7KP视频属性的抓取
# BV号为1aa4y1a7KP的视频属性抓取结束
# 开始BV号为1yT4y1777P视频属性的抓取
# BV号为1yT4y1777P的视频属性抓取结束
# 开始BV号为1T54y1S7Um视频属性的抓取
# BV号为1T54y1S7Um的视频属性抓取结束
# 开始BV号为1xh411o7sN视频属性的抓取
# BV号为1xh411o7sN的视频属性抓取结束
# 开始BV号为1x5411Y7Gd视频属性的抓取
# BV号为1x5411Y7Gd的视频属性抓取结束
# 开始BV号为1xt4y1X7HD视频属性的抓取
# BV号为1xt4y1X7HD的视频属性抓取结束
# 开始BV号为1wT4y17781视频属性的抓取
# BV号为1wT4y17781的视频属性抓取结束
# 开始BV号为1af4y1R7mZ视频属性的抓取
# BV号为1af4y1R7mZ的视频属性抓取结束
# 开始BV号为11f4y1177h视频属性的抓取
# BV号为11f4y1177h的视频属性抓取结束
# 开始BV号为1h54y1q76t视频属性的抓取
# BV号为1h54y1q76t的视频属性抓取结束
# 开始BV号为11K411J7J2视频属性的抓取
# BV号为11K411J7J2的视频属性抓取结束
# 开始BV号为18K411H7sV视频属性的抓取
# BV号为18K411H7sV的视频属性抓取结束
# 开始BV号为1fz411e7kF视频属性的抓取
# BV号为1fz411e7kF的视频属性抓取结束
# 开始BV号为1vv411i76H视频属性的抓取
# BV号为1vv411i76H的视频属性抓取结束
# 开始BV号为1Ua4y1a7ot视频属性的抓取
# BV号为1Ua4y1a7ot的视频属性抓取结束
# 开始BV号为1Dk4y1q7xB视频属性的抓取
# BV号为1Dk4y1q7xB的视频属性抓取结束
# 开始BV号为1Q54y1S7Wj视频属性的抓取
# BV号为1Q54y1S7Wj的视频属性抓取结束
# 开始BV号为1YC4y1h7hG视频属性的抓取
# BV号为1YC4y1h7hG的视频属性抓取结束
# 开始BV号为1aK4y1x7zX视频属性的抓取
# BV号为1aK4y1x7zX的视频属性抓取结束
# 开始BV号为1Hv411v7QJ视频属性的抓取
# BV号为1Hv411v7QJ的视频属性抓取结束
# 开始BV号为1CZ4y1u7Xi视频属性的抓取
# BV号为1CZ4y1u7Xi的视频属性抓取结束
# 开始BV号为1QA411i7Pq视频属性的抓取
# BV号为1QA411i7Pq的视频属性抓取结束
# 开始BV号为1YD4y1S7Ws视频属性的抓取
# BV号为1YD4y1S7Ws的视频属性抓取结束
# 开始BV号为1if4y117Fy视频属性的抓取
# BV号为1if4y117Fy的视频属性抓取结束
# 开始BV号为1ca4y1J7v7视频属性的抓取
# BV号为1ca4y1J7v7的视频属性抓取结束
# 开始BV号为1C54y1v7TP视频属性的抓取
# BV号为1C54y1v7TP的视频属性抓取结束
# 开始BV号为1854y1S7nx视频属性的抓取
# BV号为1854y1S7nx的视频属性抓取结束
# 开始BV号为1fT4y1L7uu视频属性的抓取
# 开始BV号为1fT4y1L7uu视频属性的抓取
# 开始BV号为1fT4y1L7uu视频属性的抓取
# BV号为1fT4y1L7uu的视频属性抓取结束
# 开始BV号为1GK411n7gM视频属性的抓取
# BV号为1GK411n7gM的视频属性抓取结束
# 开始BV号为1ea4y1E72v视频属性的抓取
# BV号为1ea4y1E72v的视频属性抓取结束
# 开始BV号为1u54y1B7As视频属性的抓取
# BV号为1u54y1B7As的视频属性抓取结束
# 开始BV号为15t4y1X7yA视频属性的抓取
# BV号为15t4y1X7yA的视频属性抓取结束
# 开始BV号为1zg4y1v7bP视频属性的抓取
# BV号为1zg4y1v7bP的视频属性抓取结束
# 开始BV号为1MC4y1b7Yu视频属性的抓取
# BV号为1MC4y1b7Yu的视频属性抓取结束
# 开始BV号为1354y1q7B5视频属性的抓取
# BV号为1354y1q7B5的视频属性抓取结束
# 开始BV号为1tt4y1X7kL视频属性的抓取
# BV号为1tt4y1X7kL的视频属性抓取结束
# 开始BV号为14A411v79J视频属性的抓取
# BV号为14A411v79J的视频属性抓取结束
# 开始BV号为1mv411B7hm视频属性的抓取
# BV号为1mv411B7hm的视频属性抓取结束
# 开始BV号为1Hf4y1R7bZ视频属性的抓取
# BV号为1Hf4y1R7bZ的视频属性抓取结束
# 开始BV号为1g54y1q7QD视频属性的抓取
# BV号为1g54y1q7QD的视频属性抓取结束
# 开始BV号为1zV41167tE视频属性的抓取
# BV号为1zV41167tE的视频属性抓取结束
# 开始BV号为1cZ4y1M7Yy视频属性的抓取
# BV号为1cZ4y1M7Yy的视频属性抓取结束
# 开始BV号为1fD4y1S77y视频属性的抓取
# BV号为1fD4y1S77y的视频属性抓取结束
# 开始BV号为1ua4y1a7Vx视频属性的抓取
# BV号为1ua4y1a7Vx的视频属性抓取结束
# 开始BV号为1Rh411o7Yq视频属性的抓取
# BV号为1Rh411o7Yq的视频属性抓取结束
# 开始BV号为1gD4y1U7W2视频属性的抓取
# BV号为1gD4y1U7W2的视频属性抓取结束
# 开始BV号为1Ya4y1a7gm视频属性的抓取
# BV号为1Ya4y1a7gm的视频属性抓取结束
# 开始BV号为1YK4y1s7YM视频属性的抓取
# BV号为1YK4y1s7YM的视频属性抓取结束
# 开始BV号为1Vv411z7h7视频属性的抓取
# BV号为1Vv411z7h7的视频属性抓取结束
# 开始BV号为1qz411v7qs视频属性的抓取
# BV号为1qz411v7qs的视频属性抓取结束
# 开始BV号为1tA411Y7uG视频属性的抓取
# BV号为1tA411Y7uG的视频属性抓取结束
# 开始BV号为1pT4y1j7kZ视频属性的抓取
# BV号为1pT4y1j7kZ的视频属性抓取结束
# 开始BV号为1iK4y1s7kM视频属性的抓取
# BV号为1iK4y1s7kM的视频属性抓取结束
# 开始BV号为16K411H72z视频属性的抓取
# BV号为16K411H72z的视频属性抓取结束
# 开始BV号为18A411v7wX视频属性的抓取
# BV号为18A411v7wX的视频属性抓取结束
# 开始BV号为1xt4y197YS视频属性的抓取
# BV号为1xt4y197YS的视频属性抓取结束
# 开始BV号为1bt4y1X7Ds视频属性的抓取
# BV号为1bt4y1X7Ds的视频属性抓取结束
# 开始BV号为1E5411e7RU视频属性的抓取
# BV号为1E5411e7RU的视频属性抓取结束
# 开始BV号为1Zk4y1q7ek视频属性的抓取
# BV号为1Zk4y1q7ek的视频属性抓取结束
# 开始BV号为1wi4y137tB视频属性的抓取
# BV号为1wi4y137tB的视频属性抓取结束
# 开始BV号为1ig4y1v77U视频属性的抓取
# BV号为1ig4y1v77U的视频属性抓取结束
# 开始BV号为1jz4y1D7tk视频属性的抓取
# BV号为1jz4y1D7tk的视频属性抓取结束
# 开始BV号为1WK411J7EP视频属性的抓取
# BV号为1WK411J7EP的视频属性抓取结束
# 开始BV号为1Wv411q7vM视频属性的抓取
# BV号为1Wv411q7vM的视频属性抓取结束
# 开始BV号为1a5411Y7Xm视频属性的抓取
# BV号为1a5411Y7Xm的视频属性抓取结束
# 开始BV号为1vz4y1D7jM视频属性的抓取
# BV号为1vz4y1D7jM的视频属性抓取结束
# 开始BV号为1iD4y1S7EK视频属性的抓取
# BV号为1iD4y1S7EK的视频属性抓取结束
# 开始BV号为1x54y1q7FB视频属性的抓取
# BV号为1x54y1q7FB的视频属性抓取结束
# 开始BV号为19a4y1h7YN视频属性的抓取
# BV号为19a4y1h7YN的视频属性抓取结束
# 开始BV号为1jf4y1R7k9视频属性的抓取
# BV号为1jf4y1R7k9的视频属性抓取结束
# 开始BV号为1u5411e7CW视频属性的抓取
# BV号为1u5411e7CW的视频属性抓取结束
# 开始BV号为1i54y1q72S视频属性的抓取
# BV号为1i54y1q72S的视频属性抓取结束
# 开始BV号为1az411v7Up视频属性的抓取
# BV号为1az411v7Up的视频属性抓取结束
# 开始BV号为1UZ4y1u79N视频属性的抓取
# BV号为1UZ4y1u79N的视频属性抓取结束
# 开始BV号为155411e7Cg视频属性的抓取
# BV号为155411e7Cg的视频属性抓取结束
# 开始BV号为1P54y1q7nS视频属性的抓取
# BV号为1P54y1q7nS的视频属性抓取结束
# 开始BV号为1qp4y1S78q视频属性的抓取
# BV号为1qp4y1S78q的视频属性抓取结束
# 开始BV号为1tA411v7pY视频属性的抓取
# BV号为1tA411v7pY的视频属性抓取结束
# 开始BV号为1Qv411i7oX视频属性的抓取
# BV号为1Qv411i7oX的视频属性抓取结束
# 开始BV号为1xf4y117YX视频属性的抓取
# BV号为1xf4y117YX的视频属性抓取结束
# 开始BV号为1nv411v7nj视频属性的抓取
# BV号为1nv411v7nj的视频属性抓取结束
# 开始BV号为15V411r7hC视频属性的抓取
# BV号为15V411r7hC的视频属性抓取结束
# 开始BV号为1nK4y1x7sp视频属性的抓取
# BV号为1nK4y1x7sp的视频属性抓取结束
# 开始BV号为1W54y1S7ft视频属性的抓取
# BV号为1W54y1S7ft的视频属性抓取结束
# 开始BV号为1Up4y1U7Tn视频属性的抓取
# BV号为1Up4y1U7Tn的视频属性抓取结束
# 开始BV号为15D4y1S7WQ视频属性的抓取
# BV号为15D4y1S7WQ的视频属性抓取结束
# 开始BV号为1LV411U7Co视频属性的抓取
# BV号为1LV411U7Co的视频属性抓取结束
# 开始BV号为1Qz4y1f7B8视频属性的抓取
# BV号为1Qz4y1f7B8的视频属性抓取结束
# 开始BV号为14Z4y1T7f6视频属性的抓取
# BV号为14Z4y1T7f6的视频属性抓取结束
# 开始BV号为1tt4y1S7D9视频属性的抓取
# BV号为1tt4y1S7D9的视频属性抓取结束
# 开始BV号为1Xy4y1C7E8视频属性的抓取
# BV号为1Xy4y1C7E8的视频属性抓取结束
# 开始BV号为1AV411m7cP视频属性的抓取
# BV号为1AV411m7cP的视频属性抓取结束
# 开始BV号为1Fi4y1G7Ba视频属性的抓取
# BV号为1Fi4y1G7Ba的视频属性抓取结束
# 开始BV号为13C4y187NU视频属性的抓取
# BV号为13C4y187NU的视频属性抓取结束
# 开始BV号为1Tt4y1D7xt视频属性的抓取
# BV号为1Tt4y1D7xt的视频属性抓取结束
# 开始BV号为1554y1v7Pc视频属性的抓取
# BV号为1554y1v7Pc的视频属性抓取结束
# 开始BV号为1Qh411d7aw视频属性的抓取
# BV号为1Qh411d7aw的视频属性抓取结束
# 开始BV号为1Gv411174v视频属性的抓取
# BV号为1Gv411174v的视频属性抓取结束
# 开始BV号为1sf4y1Q7Ae视频属性的抓取
# BV号为1sf4y1Q7Ae的视频属性抓取结束
# 开始BV号为1kV411U7TX视频属性的抓取
# BV号为1kV411U7TX的视频属性抓取结束
# 开始BV号为1cD4y1U7jU视频属性的抓取
# BV号为1cD4y1U7jU的视频属性抓取结束
# 开始BV号为1ep4y1q7cf视频属性的抓取
# BV号为1ep4y1q7cf的视频属性抓取结束
# 开始BV号为1554y1v7n8视频属性的抓取
# BV号为1554y1v7n8的视频属性抓取结束
# 开始BV号为19p4y1Y7CA视频属性的抓取
# BV号为19p4y1Y7CA的视频属性抓取结束
# 开始BV号为1MC4y1t7Xa视频属性的抓取
# BV号为1MC4y1t7Xa的视频属性抓取结束
# 开始BV号为16p4y1q74A视频属性的抓取
# BV号为16p4y1q74A的视频属性抓取结束
# 开始BV号为1Xp4y1v71C视频属性的抓取
# BV号为1Xp4y1v71C的视频属性抓取结束
# 开始BV号为1xk4y1272R视频属性的抓取
# BV号为1xk4y1272R的视频属性抓取结束
# 开始BV号为1ri4y1g7Yd视频属性的抓取
# BV号为1ri4y1g7Yd的视频属性抓取结束
# 开始BV号为1Th411d77f视频属性的抓取
# BV号为1Th411d77f的视频属性抓取结束
# 开始BV号为19V411z7P8视频属性的抓取
# BV号为19V411z7P8的视频属性抓取结束
# 开始BV号为1qZ4y1M7qg视频属性的抓取
# BV号为1qZ4y1M7qg的视频属性抓取结束
# 开始BV号为1wD4y1m7Xs视频属性的抓取
# BV号为1wD4y1m7Xs的视频属性抓取结束
# 开始BV号为1UT4y1w7AQ视频属性的抓取
# BV号为1UT4y1w7AQ的视频属性抓取结束
# 开始BV号为1FA411e7TZ视频属性的抓取
# BV号为1FA411e7TZ的视频属性抓取结束
# 开始BV号为1XK4y1Y7W6视频属性的抓取
# BV号为1XK4y1Y7W6的视频属性抓取结束
# 开始BV号为1dT4y1j7ho视频属性的抓取
# BV号为1dT4y1j7ho的视频属性抓取结束
# 开始BV号为1cA411Y7Xx视频属性的抓取
# BV号为1cA411Y7Xx的视频属性抓取结束
# 开始BV号为1Ua4y177Vb视频属性的抓取
# BV号为1Ua4y177Vb的视频属性抓取结束
# 开始BV号为1Ba4y1773V视频属性的抓取
# BV号为1Ba4y1773V的视频属性抓取结束
# 开始BV号为1N54y1i7bA视频属性的抓取
# BV号为1N54y1i7bA的视频属性抓取结束
# 开始BV号为1C54y1e7xf视频属性的抓取
# BV号为1C54y1e7xf的视频属性抓取结束
# 开始BV号为1t54y1U7Kq视频属性的抓取
# BV号为1t54y1U7Kq的视频属性抓取结束
# 开始BV号为1Mt4y1S7rX视频属性的抓取
# BV号为1Mt4y1S7rX的视频属性抓取结束
# 开始BV号为1PK4y1e7CL视频属性的抓取
# BV号为1PK4y1e7CL的视频属性抓取结束
# 开始BV号为1wh411o7cE视频属性的抓取
# BV号为1wh411o7cE的视频属性抓取结束
# 开始BV号为1WZ4y1K737视频属性的抓取
# BV号为1WZ4y1K737的视频属性抓取结束
# 开始BV号为1Wh411d7JX视频属性的抓取
# BV号为1Wh411d7JX的视频属性抓取结束
# 开始BV号为1rD4y1U7zz视频属性的抓取
# BV号为1rD4y1U7zz的视频属性抓取结束
# 开始BV号为1ft4y1S7vJ视频属性的抓取
# BV号为1ft4y1S7vJ的视频属性抓取结束
# 开始BV号为1AV411S7Df视频属性的抓取
# BV号为1AV411S7Df的视频属性抓取结束
# 开始BV号为1Mp4y1i7D4视频属性的抓取
# BV号为1Mp4y1i7D4的视频属性抓取结束
# 开始BV号为1FA411n7bc视频属性的抓取
# BV号为1FA411n7bc的视频属性抓取结束
# 开始BV号为1AK411M7qV视频属性的抓取
# BV号为1AK411M7qV的视频属性抓取结束
# 开始BV号为1ka4y177zJ视频属性的抓取
# BV号为1ka4y177zJ的视频属性抓取结束
# 开始BV号为16D4y1m7EQ视频属性的抓取
# BV号为16D4y1m7EQ的视频属性抓取结束
# 开始BV号为1jv411v7UP视频属性的抓取
# BV号为1jv411v7UP的视频属性抓取结束
# 开始BV号为1TK411T7Y4视频属性的抓取
# BV号为1TK411T7Y4的视频属性抓取结束
# 开始BV号为17C4y1t7HJ视频属性的抓取
# BV号为17C4y1t7HJ的视频属性抓取结束
# 开始BV号为1cK411K74j视频属性的抓取
# BV号为1cK411K74j的视频属性抓取结束
# 开始BV号为1ga4y177QP视频属性的抓取
# BV号为1ga4y177QP的视频属性抓取结束
# 开始BV号为1yA411Y7qy视频属性的抓取
# BV号为1yA411Y7qy的视频属性抓取结束
# 开始BV号为1Qh411d7TY视频属性的抓取
# BV号为1Qh411d7TY的视频属性抓取结束
# 开始BV号为1PC4y1t72N视频属性的抓取
# BV号为1PC4y1t72N的视频属性抓取结束
# 开始BV号为1PZ4y1T7bK视频属性的抓取
# BV号为1PZ4y1T7bK的视频属性抓取结束
# 开始BV号为1Y64y1c7RD视频属性的抓取
# BV号为1Y64y1c7RD的视频属性抓取结束
# 开始BV号为1X541187fE视频属性的抓取
# BV号为1X541187fE的视频属性抓取结束
# 开始BV号为1mT4y1j7EZ视频属性的抓取
# BV号为1mT4y1j7EZ的视频属性抓取结束
# 开始BV号为1z64y1c7dB视频属性的抓取
# BV号为1z64y1c7dB的视频属性抓取结束
# 开始BV号为1p64y1c7F1视频属性的抓取
# BV号为1p64y1c7F1的视频属性抓取结束
# 开始BV号为1La4y1J7sg视频属性的抓取
# BV号为1La4y1J7sg的视频属性抓取结束
# 开始BV号为1164y1F7ku视频属性的抓取
# BV号为1164y1F7ku的视频属性抓取结束
# 开始BV号为1YA411Y7X9视频属性的抓取
# BV号为1YA411Y7X9的视频属性抓取结束
# 开始BV号为1QA411Y7o1视频属性的抓取
# BV号为1QA411Y7o1的视频属性抓取结束
# 开始BV号为1nC4y18721视频属性的抓取
# BV号为1nC4y18721的视频属性抓取结束
# 开始BV号为1pT4y1L7w4视频属性的抓取
# BV号为1pT4y1L7w4的视频属性抓取结束
# 开始BV号为1u64y1c784视频属性的抓取
# BV号为1u64y1c784的视频属性抓取结束
# 开始BV号为12f4y1X79t视频属性的抓取
# BV号为12f4y1X79t的视频属性抓取结束
# 开始BV号为17v411v7Sr视频属性的抓取
# BV号为17v411v7Sr的视频属性抓取结束
# 开始BV号为1ov411y7Qh视频属性的抓取
# BV号为1ov411y7Qh的视频属性抓取结束
# 开始BV号为1st4y1S7mK视频属性的抓取
# BV号为1st4y1S7mK的视频属性抓取结束
# 开始BV号为1up4y1v79u视频属性的抓取
# BV号为1up4y1v79u的视频属性抓取结束
# 开始BV号为1At4y1Q7gy视频属性的抓取
# BV号为1At4y1Q7gy的视频属性抓取结束
# 开始BV号为1R64y1c7eP视频属性的抓取
# BV号为1R64y1c7eP的视频属性抓取结束
# 开始BV号为1W54y1e75J视频属性的抓取
# BV号为1W54y1e75J的视频属性抓取结束
# 开始BV号为1nv41117AQ视频属性的抓取
# BV号为1nv41117AQ的视频属性抓取结束
# 开始BV号为1Jv41117VW视频属性的抓取
# BV号为1Jv41117VW的视频属性抓取结束
# 开始BV号为1ht4y1X7Ny视频属性的抓取
# BV号为1ht4y1X7Ny的视频属性抓取结束
# 开始BV号为1mt4y1U7aq视频属性的抓取
# BV号为1mt4y1U7aq的视频属性抓取结束
# 开始BV号为1JZ4y1T7w8视频属性的抓取
# BV号为1JZ4y1T7w8的视频属性抓取结束
# 开始BV号为1qt4y1S7GH视频属性的抓取
# BV号为1qt4y1S7GH的视频属性抓取结束
# 开始BV号为1PD4y1m759视频属性的抓取
# 开始BV号为1PD4y1m759视频属性的抓取
# BV号为1PD4y1m759的视频属性抓取结束
# 开始BV号为1KA411H7U4视频属性的抓取
# BV号为1KA411H7U4的视频属性抓取结束
# 开始BV号为1nZ4y1K7NA视频属性的抓取
# BV号为1nZ4y1K7NA的视频属性抓取结束
# 开始BV号为1FD4y1S7qp视频属性的抓取
# BV号为1FD4y1S7qp的视频属性抓取结束
# 开始BV号为1kV411z7Cz视频属性的抓取
# BV号为1kV411z7Cz的视频属性抓取结束
# 开始BV号为185411h7Ty视频属性的抓取
# BV号为185411h7Ty的视频属性抓取结束
# 开始BV号为1E54y1i71D视频属性的抓取
# BV号为1E54y1i71D的视频属性抓取结束
# 开始BV号为1Qa4y1E7Xe视频属性的抓取
# BV号为1Qa4y1E7Xe的视频属性抓取结束
# 开始BV号为1st4y1D782视频属性的抓取
# BV号为1st4y1D782的视频属性抓取结束
# 开始BV号为1BC4y1t7yv视频属性的抓取
# BV号为1BC4y1t7yv的视频属性抓取结束
# 开始BV号为1ip4y1v7ze视频属性的抓取
# BV号为1ip4y1v7ze的视频属性抓取结束
# 开始BV号为1hK4y1v7rq视频属性的抓取
# BV号为1hK4y1v7rq的视频属性抓取结束
# 开始BV号为1fZ4y1T71X视频属性的抓取
# BV号为1fZ4y1T71X的视频属性抓取结束
# 开始BV号为1Hp4y1v7nj视频属性的抓取
# BV号为1Hp4y1v7nj的视频属性抓取结束
# 开始BV号为1XD4y1o7kD视频属性的抓取
# BV号为1XD4y1o7kD的视频属性抓取结束
# 开始BV号为1ph411X7cd视频属性的抓取
# BV号为1ph411X7cd的视频属性抓取结束
# 开始BV号为1my4y1y7XU视频属性的抓取
# BV号为1my4y1y7XU的视频属性抓取结束
# 开始BV号为1ph411X7Pq视频属性的抓取
# BV号为1ph411X7Pq的视频属性抓取结束
# 开始BV号为1a54y127R2视频属性的抓取
# BV号为1a54y127R2的视频属性抓取结束
# 开始BV号为1d5411b7Kx视频属性的抓取
# BV号为1d5411b7Kx的视频属性抓取结束
# 开始BV号为11t4y1S7Eh视频属性的抓取
# BV号为11t4y1S7Eh的视频属性抓取结束
# 开始BV号为1nD4y1o7vb视频属性的抓取
# BV号为1nD4y1o7vb的视频属性抓取结束
# 开始BV号为1ph411X7pB视频属性的抓取
# BV号为1ph411X7pB的视频属性抓取结束
# 开始BV号为1c5411b7Ys视频属性的抓取
# BV号为1c5411b7Ys的视频属性抓取结束
# 开始BV号为1e54y1y79V视频属性的抓取
# BV号为1e54y1y79V的视频属性抓取结束
# 开始BV号为1P54y1y7oD视频属性的抓取
# BV号为1P54y1y7oD的视频属性抓取结束
# 开始BV号为1bK4y1e7xd视频属性的抓取
# BV号为1bK4y1e7xd的视频属性抓取结束
# 开始BV号为1bV41117xi视频属性的抓取
# BV号为1bV41117xi的视频属性抓取结束
# 开始BV号为1By4y1y7XU视频属性的抓取
# BV号为1By4y1y7XU的视频属性抓取结束
# 开始BV号为1Dv41117k7视频属性的抓取
# BV号为1Dv41117k7的视频属性抓取结束
# 开始BV号为1K54y1m7kp视频属性的抓取
# BV号为1K54y1m7kp的视频属性抓取结束
# 开始BV号为1Q5411b78s视频属性的抓取
# BV号为1Q5411b78s的视频属性抓取结束
# 开始BV号为14h411R75n视频属性的抓取
# BV号为14h411R75n的视频属性抓取结束
# 开始BV号为17h411R7Ao视频属性的抓取
# BV号为17h411R7Ao的视频属性抓取结束
# 开始BV号为1Cf4y1D7MU视频属性的抓取
# BV号为1Cf4y1D7MU的视频属性抓取结束
# 开始BV号为1YT4y1c7xd视频属性的抓取
# BV号为1YT4y1c7xd的视频属性抓取结束
# 开始BV号为1w54118756视频属性的抓取
# BV号为1w54118756的视频属性抓取结束
# 开始BV号为1g54y1m7Mb视频属性的抓取
# BV号为1g54y1m7Mb的视频属性抓取结束
# 开始BV号为1Bk4y1y7Uw视频属性的抓取
# BV号为1Bk4y1y7Uw的视频属性抓取结束
# 开始BV号为1nK4y1e7hN视频属性的抓取
# BV号为1nK4y1e7hN的视频属性抓取结束
# 开始BV号为15Z4y1N7eJ视频属性的抓取
# BV号为15Z4y1N7eJ的视频属性抓取结束
# 开始BV号为1nV411m7pB视频属性的抓取
# BV号为1nV411m7pB的视频属性抓取结束
# 开始BV号为1ua4y1j7vk视频属性的抓取
# BV号为1ua4y1j7vk的视频属性抓取结束
# 开始BV号为1rf4y1D7NC视频属性的抓取
# BV号为1rf4y1D7NC的视频属性抓取结束
# 开始BV号为1tA411E7dy视频属性的抓取
# BV号为1tA411E7dy的视频属性抓取结束
# 开始BV号为1bK4y1a7Sr视频属性的抓取
# BV号为1bK4y1a7Sr的视频属性抓取结束
# 开始BV号为1WV41117y4视频属性的抓取
# BV号为1WV41117y4的视频属性抓取结束
# 开始BV号为14h411R7Sx视频属性的抓取
# BV号为14h411R7Sx的视频属性抓取结束
# 开始BV号为1754y1v7AM视频属性的抓取
# BV号为1754y1v7AM的视频属性抓取结束
# 开始BV号为1Ri4y177iL视频属性的抓取
# BV号为1Ri4y177iL的视频属性抓取结束
# 开始BV号为1XT4y1c7j5视频属性的抓取
# BV号为1XT4y1c7j5的视频属性抓取结束
# 开始BV号为1YK411K7NG视频属性的抓取
# BV号为1YK411K7NG的视频属性抓取结束
# 开始BV号为1TK4y1Y7mc视频属性的抓取
# BV号为1TK4y1Y7mc的视频属性抓取结束
# 开始BV号为1Na4y1E7qh视频属性的抓取
# BV号为1Na4y1E7qh的视频属性抓取结束
# 开始BV号为1Fi4y1u7GG视频属性的抓取
# BV号为1Fi4y1u7GG的视频属性抓取结束
# 开始BV号为1fy4y1C78T视频属性的抓取
# BV号为1fy4y1C78T的视频属性抓取结束
# 开始BV号为1wh411971a视频属性的抓取
# BV号为1wh411971a的视频属性抓取结束
# 开始BV号为1UA411E7dp视频属性的抓取
# BV号为1UA411E7dp的视频属性抓取结束
# 开始BV号为1Af4y1D7Wk视频属性的抓取
# BV号为1Af4y1D7Wk的视频属性抓取结束
# 开始BV号为1et4y1i7ZJ视频属性的抓取
# BV号为1et4y1i7ZJ的视频属性抓取结束
# 开始BV号为1jK4y1a7p2视频属性的抓取
# BV号为1jK4y1a7p2的视频属性抓取结束
# 开始BV号为1dp4y1a7hE视频属性的抓取
# BV号为1dp4y1a7hE的视频属性抓取结束
# 开始BV号为1xa4y1j7jc视频属性的抓取
# BV号为1xa4y1j7jc的视频属性抓取结束
# 开始BV号为1654y1y7ki视频属性的抓取
# BV号为1654y1y7ki的视频属性抓取结束
# 开始BV号为1Zf4y1q7xd视频属性的抓取
# BV号为1Zf4y1q7xd的视频属性抓取结束
# 开始BV号为11D4y1o7dk视频属性的抓取
# BV号为11D4y1o7dk的视频属性抓取结束
# 开始BV号为1ut4y1q7vo视频属性的抓取
# BV号为1ut4y1q7vo的视频属性抓取结束
# 开始BV号为1i54y1y7Ao视频属性的抓取
# BV号为1i54y1y7Ao的视频属性抓取结束
# 开始BV号为1DZ4y1N7Vz视频属性的抓取
# BV号为1DZ4y1N7Vz的视频属性抓取结束
# 开始BV号为1HV411S7Yr视频属性的抓取
# BV号为1HV411S7Yr的视频属性抓取结束
# 开始BV号为1rT4y1c7vD视频属性的抓取
# BV号为1rT4y1c7vD的视频属性抓取结束
# 开始BV号为1s54y1v7cQ视频属性的抓取
# BV号为1s54y1v7cQ的视频属性抓取结束
# 开始BV号为16K411P76q视频属性的抓取
# BV号为16K411P76q的视频属性抓取结束
# 开始BV号为11y4y1y7Xv视频属性的抓取
# BV号为11y4y1y7Xv的视频属性抓取结束
# 开始BV号为19K411P7HG视频属性的抓取
# BV号为19K411P7HG的视频属性抓取结束
# 开始BV号为1iA411J7Um视频属性的抓取
# BV号为1iA411J7Um的视频属性抓取结束
# 开始BV号为1e5411j7vd视频属性的抓取
# BV号为1e5411j7vd的视频属性抓取结束
# 开始BV号为1o54y1y7Nt视频属性的抓取
# BV号为1o54y1y7Nt的视频属性抓取结束
# 开始BV号为1xT4y1c7CK视频属性的抓取
# BV号为1xT4y1c7CK的视频属性抓取结束
# 开始BV号为14A411E7eA视频属性的抓取
# BV号为14A411E7eA的视频属性抓取结束
# 开始BV号为1H54y1y7oC视频属性的抓取
# BV号为1H54y1y7oC的视频属性抓取结束
# 开始BV号为1By4y1y79o视频属性的抓取
# BV号为1By4y1y79o的视频属性抓取结束
# 开始BV号为1e64y1F7qn视频属性的抓取
# BV号为1e64y1F7qn的视频属性抓取结束
# 开始BV号为1qD4y1R77m视频属性的抓取
# BV号为1qD4y1R77m的视频属性抓取结束
# 开始BV号为1hT4y1A7xc视频属性的抓取
# BV号为1hT4y1A7xc的视频属性抓取结束
# 开始BV号为1Th411R7Je视频属性的抓取
# BV号为1Th411R7Je的视频属性抓取结束
# 开始BV号为1iT4y1A7FV视频属性的抓取
# BV号为1iT4y1A7FV的视频属性抓取结束
# 开始BV号为1ik4y127sk视频属性的抓取
# BV号为1ik4y127sk的视频属性抓取结束
# 开始BV号为1P54y1y74u视频属性的抓取
# BV号为1P54y1y74u的视频属性抓取结束
# 开始BV号为1sf4y1X7qy视频属性的抓取
# BV号为1sf4y1X7qy的视频属性抓取结束
# 开始BV号为1pa4y1E7An视频属性的抓取
# BV号为1pa4y1E7An的视频属性抓取结束
# 开始BV号为1L54y117j3视频属性的抓取
# BV号为1L54y117j3的视频属性抓取结束
# 开始BV号为1ph411R7t7视频属性的抓取
# BV号为1ph411R7t7的视频属性抓取结束
# 开始BV号为18y4y1y79J视频属性的抓取
# BV号为18y4y1y79J的视频属性抓取结束
# 开始BV号为1ap4y1e73S视频属性的抓取
# BV号为1ap4y1e73S的视频属性抓取结束
# 开始BV号为1oA411n7wc视频属性的抓取
# BV号为1oA411n7wc的视频属性抓取结束
# 开始BV号为1Cv411C7NS视频属性的抓取
# BV号为1Cv411C7NS的视频属性抓取结束
# 开始BV号为1CV411m7wo视频属性的抓取
# BV号为1CV411m7wo的视频属性抓取结束
# 开始BV号为1zT4y1A7Qw视频属性的抓取
# BV号为1zT4y1A7Qw的视频属性抓取结束
# 开始BV号为1354y1y7gN视频属性的抓取
# BV号为1354y1y7gN的视频属性抓取结束
# 开始BV号为12K411P73g视频属性的抓取
# BV号为12K411P73g的视频属性抓取结束
# 开始BV号为1Za4y1j7yN视频属性的抓取
# BV号为1Za4y1j7yN的视频属性抓取结束
# 开始BV号为1DA411E7Vs视频属性的抓取
# BV号为1DA411E7Vs的视频属性抓取结束
# 开始BV号为1A5411j7UM视频属性的抓取
# BV号为1A5411j7UM的视频属性抓取结束
# 开始BV号为1Rf4y1S7c8视频属性的抓取
# BV号为1Rf4y1S7c8的视频属性抓取结束
# 开始BV号为1Qh411X7Xj视频属性的抓取
# BV号为1Qh411X7Xj的视频属性抓取结束
# 开始BV号为1z54y1C794视频属性的抓取
# BV号为1z54y1C794的视频属性抓取结束
# 开始BV号为1e54y1k7Ur视频属性的抓取
# BV号为1e54y1k7Ur的视频属性抓取结束
# 开始BV号为1mf4y1Q7dN视频属性的抓取
# BV号为1mf4y1Q7dN的视频属性抓取结束
# 开始BV号为1Cv411C758视频属性的抓取
# BV号为1Cv411C758的视频属性抓取结束
# 开始BV号为15A411J7V9视频属性的抓取
# BV号为15A411J7V9的视频属性抓取结束
# 开始BV号为1Vy4y1y7o9视频属性的抓取
# BV号为1Vy4y1y7o9的视频属性抓取结束
# 开始BV号为1B54y1C7id视频属性的抓取
# BV号为1B54y1C7id的视频属性抓取结束
# 开始BV号为1Qv411k7UW视频属性的抓取
# BV号为1Qv411k7UW的视频属性抓取结束
# 开始BV号为1Mf4y1Q7Kp视频属性的抓取
# BV号为1Mf4y1Q7Kp的视频属性抓取结束
# 开始BV号为1jf4y1q7Yf视频属性的抓取
# BV号为1jf4y1q7Yf的视频属性抓取结束
# 开始BV号为1Ji4y1j7Q3视频属性的抓取
# BV号为1Ji4y1j7Q3的视频属性抓取结束
# 开始BV号为1QK4y177WF视频属性的抓取
# BV号为1QK4y177WF的视频属性抓取结束
# 开始BV号为1eZ4y157T8视频属性的抓取
# BV号为1eZ4y157T8的视频属性抓取结束
# 开始BV号为1v54y1r7BK视频属性的抓取
# BV号为1v54y1r7BK的视频属性抓取结束
# 开始BV号为1Ky4y1r7Yo视频属性的抓取
# BV号为1Ky4y1r7Yo的视频属性抓取结束
# 开始BV号为1FT4y1w7BS视频属性的抓取
# BV号为1FT4y1w7BS的视频属性抓取结束
# 开始BV号为1R54y117vv视频属性的抓取
# BV号为1R54y117vv的视频属性抓取结束
# 开始BV号为1iv411k7bc视频属性的抓取
# BV号为1iv411k7bc的视频属性抓取结束
# 开始BV号为1ut4y1e7Tx视频属性的抓取
# BV号为1ut4y1e7Tx的视频属性抓取结束
# 开始BV号为11i4y1E7Zo视频属性的抓取
# BV号为11i4y1E7Zo的视频属性抓取结束
# 开始BV号为1fA411L78g视频属性的抓取
# BV号为1fA411L78g的视频属性抓取结束
# 开始BV号为17y4y1B7qL视频属性的抓取
# BV号为17y4y1B7qL的视频属性抓取结束
# 开始BV号为1A54y1r7pZ视频属性的抓取
# BV号为1A54y1r7pZ的视频属性抓取结束
# 开始BV号为1Wa411A7is视频属性的抓取
# BV号为1Wa411A7is的视频属性抓取结束
# 开始BV号为1YD4y1R7MF视频属性的抓取
# BV号为1YD4y1R7MF的视频属性抓取结束
# 开始BV号为16D4y197Sg视频属性的抓取
# BV号为16D4y197Sg的视频属性抓取结束
# 开始BV号为1by4y1C7X6视频属性的抓取
# BV号为1by4y1C7X6的视频属性抓取结束
# 开始BV号为1RK4y177zZ视频属性的抓取
# BV号为1RK4y177zZ的视频属性抓取结束
# 开始BV号为1hk4y1C737视频属性的抓取
# BV号为1hk4y1C737的视频属性抓取结束
# 开始BV号为1Ci4y1j7NH视频属性的抓取
# BV号为1Ci4y1j7NH的视频属性抓取结束
# 开始BV号为1uK411N7ob视频属性的抓取
# BV号为1uK411N7ob的视频属性抓取结束
# 开始BV号为1Mp4y1k7dX视频属性的抓取
# BV号为1Mp4y1k7dX的视频属性抓取结束
# 开始BV号为1bZ4y1V7DA视频属性的抓取
# BV号为1bZ4y1V7DA的视频属性抓取结束
# 开始BV号为1Ua4y1L7Ug视频属性的抓取
# BV号为1Ua4y1L7Ug的视频属性抓取结束
# 开始BV号为1cD4y1R7fX视频属性的抓取
# BV号为1cD4y1R7fX的视频属性抓取结束
# 开始BV号为1kD4y1978z视频属性的抓取
# BV号为1kD4y1978z的视频属性抓取结束
# 开始BV号为1Vz4y1o7Ck视频属性的抓取
# BV号为1Vz4y1o7Ck的视频属性抓取结束
# 开始BV号为1jz4y1o7DD视频属性的抓取
# BV号为1jz4y1o7DD的视频属性抓取结束
# 开始BV号为1VV41127LF视频属性的抓取
# BV号为1VV41127LF的视频属性抓取结束
# 开始BV号为1ZA41177Jq视频属性的抓取
# BV号为1ZA41177Jq的视频属性抓取结束
# 开始BV号为1MD4y1d7Jp视频属性的抓取
# BV号为1MD4y1d7Jp的视频属性抓取结束
# 开始BV号为1da4y1W7dv视频属性的抓取
# BV号为1da4y1W7dv的视频属性抓取结束
# 开始BV号为1w5411771J视频属性的抓取
# BV号为1w5411771J的视频属性抓取结束
# 开始BV号为1Sz4y1o7Aq视频属性的抓取
# BV号为1Sz4y1o7Aq的视频属性抓取结束
# 开始BV号为15Z4y1L7ZU视频属性的抓取
# BV号为15Z4y1L7ZU的视频属性抓取结束
# 开始BV号为1Pv411C7CU视频属性的抓取
# BV号为1Pv411C7CU的视频属性抓取结束
# 开始BV号为155411L7Bb视频属性的抓取
# BV号为155411L7Bb的视频属性抓取结束
# 开始BV号为15t4y1v73X视频属性的抓取
# BV号为15t4y1v73X的视频属性抓取结束
# 开始BV号为1xV411y7tA视频属性的抓取
# BV号为1xV411y7tA的视频属性抓取结束
# 开始BV号为1zD4y197Jp视频属性的抓取
# BV号为1zD4y197Jp的视频属性抓取结束
# 开始BV号为1Ba4y1s7xM视频属性的抓取
# BV号为1Ba4y1s7xM的视频属性抓取结束
# 开始BV号为1mk4y1C7ob视频属性的抓取
# BV号为1mk4y1C7ob的视频属性抓取结束
# 开始BV号为1iV411y7Pu视频属性的抓取
# BV号为1iV411y7Pu的视频属性抓取结束
# 开始BV号为1Si4y1j7KJ视频属性的抓取
# BV号为1Si4y1j7KJ的视频属性抓取结束
# 开始BV号为1Ay4y1875z视频属性的抓取
# BV号为1Ay4y1875z的视频属性抓取结束
# 开始BV号为1Ni4y177Rf视频属性的抓取
# BV号为1Ni4y177Rf的视频属性抓取结束
# 开始BV号为1vz4y1C7ne视频属性的抓取
# BV号为1vz4y1C7ne的视频属性抓取结束
# 开始BV号为1wV41127zX视频属性的抓取
# BV号为1wV41127zX的视频属性抓取结束
# 开始BV号为1Fv411C7Wb视频属性的抓取
# BV号为1Fv411C7Wb的视频属性抓取结束
# 开始BV号为1Pa411A7Li视频属性的抓取
# BV号为1Pa411A7Li的视频属性抓取结束
# 开始BV号为1aK4y1h7nd视频属性的抓取
# BV号为1aK4y1h7nd的视频属性抓取结束
# 开始BV号为17r4y1w7VQ视频属性的抓取
# BV号为17r4y1w7VQ的视频属性抓取结束
# 开始BV号为1XK4y1h7bv视频属性的抓取
# BV号为1XK4y1h7bv的视频属性抓取结束
# 开始BV号为1ip4y1k7Ck视频属性的抓取
# BV号为1ip4y1k7Ck的视频属性抓取结束
# 开始BV号为1WD4y1979i视频属性的抓取
# BV号为1WD4y1979i的视频属性抓取结束
# 开始BV号为1wv411k74N视频属性的抓取
# BV号为1wv411k74N的视频属性抓取结束
# 开始BV号为1Ha4y1s7Xg视频属性的抓取
# BV号为1Ha4y1s7Xg的视频属性抓取结束
# 开始BV号为1Hi4y1j7yQ视频属性的抓取
# BV号为1Hi4y1j7yQ的视频属性抓取结束
# 开始BV号为1Sa411w7yq视频属性的抓取
# BV号为1Sa411w7yq的视频属性抓取结束
# 开始BV号为1VD4y1d7yk视频属性的抓取
# BV号为1VD4y1d7yk的视频属性抓取结束
# 开始BV号为1EV41117tk视频属性的抓取
# BV号为1EV41117tk的视频属性抓取结束
# 开始BV号为14Z4y1L7vR视频属性的抓取
# BV号为14Z4y1L7vR的视频属性抓取结束
# 开始BV号为16t4y1e7fG视频属性的抓取
# BV号为16t4y1e7fG的视频属性抓取结束
# 开始BV号为11f4y1B7TZ视频属性的抓取
# BV号为11f4y1B7TZ的视频属性抓取结束
# 开始BV号为1wT4y1w7sF视频属性的抓取
# BV号为1wT4y1w7sF的视频属性抓取结束
# 开始BV号为1N5411L7TV视频属性的抓取
# BV号为1N5411L7TV的视频属性抓取结束
# 开始BV号为1vt4y1v7kr视频属性的抓取
# BV号为1vt4y1v7kr的视频属性抓取结束
# 开始BV号为1hK411A7gD视频属性的抓取
# BV号为1hK411A7gD的视频属性抓取结束
# 开始BV号为1my4y1r7dF视频属性的抓取
# BV号为1my4y1r7dF的视频属性抓取结束
# 开始BV号为1Mv411k7so视频属性的抓取
# BV号为1Mv411k7so的视频属性抓取结束
# 开始BV号为1Jp4y1Y7fe视频属性的抓取
# BV号为1Jp4y1Y7fe的视频属性抓取结束
# 开始BV号为1RK411A7Vp视频属性的抓取
# BV号为1RK411A7Vp的视频属性抓取结束
# 开始BV号为1D54y1176w视频属性的抓取
# BV号为1D54y1176w的视频属性抓取结束
# 开始BV号为1aV411y79m视频属性的抓取
# BV号为1aV411y79m的视频属性抓取结束
# 开始BV号为1Dz4y1C7ZE视频属性的抓取
# BV号为1Dz4y1C7ZE的视频属性抓取结束
# 开始BV号为14D4y1R7bm视频属性的抓取
# BV号为14D4y1R7bm的视频属性抓取结束
# 开始BV号为175411L73k视频属性的抓取
# BV号为175411L73k的视频属性抓取结束
# 开始BV号为1MK411N7um视频属性的抓取
# BV号为1MK411N7um的视频属性抓取结束
# 开始BV号为1QZ4y1G7Du视频属性的抓取
# BV号为1QZ4y1G7Du的视频属性抓取结束
# 开始BV号为1Np4y1k7Uh视频属性的抓取
# BV号为1Np4y1k7Uh的视频属性抓取结束
# 开始BV号为1RK411A7k8视频属性的抓取
# BV号为1RK411A7k8的视频属性抓取结束
# 开始BV号为1aZ4y157Y3视频属性的抓取
# BV号为1aZ4y157Y3的视频属性抓取结束
# 开始BV号为1da411w77y视频属性的抓取
# BV号为1da411w77y的视频属性抓取结束
# 开始BV号为1my4y1r7yt视频属性的抓取
# BV号为1my4y1r7yt的视频属性抓取结束
# 开始BV号为1fZ4y157xt视频属性的抓取
# BV号为1fZ4y157xt的视频属性抓取结束
# 开始BV号为1Ja411A7nb视频属性的抓取
# BV号为1Ja411A7nb的视频属性抓取结束
# 开始BV号为1Py4y1r7gG视频属性的抓取
# BV号为1Py4y1r7gG的视频属性抓取结束
# 开始BV号为1TD4y1976c视频属性的抓取
# BV号为1TD4y1976c的视频属性抓取结束
# 开始BV号为1Dz4y1Z7Tc视频属性的抓取
# BV号为1Dz4y1Z7Tc的视频属性抓取结束
# 开始BV号为15r4y1w7i5视频属性的抓取
# BV号为15r4y1w7i5的视频属性抓取结束
# 开始BV号为1N5411L7yz视频属性的抓取
# BV号为1N5411L7yz的视频属性抓取结束
# 开始BV号为1GT4y1F7eb视频属性的抓取
# BV号为1GT4y1F7eb的视频属性抓取结束
# 开始BV号为1Ma4y177Ec视频属性的抓取
# BV号为1Ma4y177Ec的视频属性抓取结束
# 开始BV号为1Zy4y1b7SB视频属性的抓取
# BV号为1Zy4y1b7SB的视频属性抓取结束
# 开始BV号为1TT4y1w77L视频属性的抓取
# BV号为1TT4y1w77L的视频属性抓取结束
# 开始BV号为17f4y1B7n7视频属性的抓取
# BV号为17f4y1B7n7的视频属性抓取结束
# 2020-12-17 09:58:33.328143

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-14-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_zixun_zonghe.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月    99   99    99   99   99   99   99   99    99      99   99    99   99
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 4月     98   98    98   98   98   98   98   98    98      98   98    98   98
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 7月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 8月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 9月     99   99    99   99   99   99   99   99    99      99   99    99   99
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月   99   99   99   99   99   99    99
# 1月   100  100  100  100  100  100   100
# 2月   100  100  100  100  100  100   100
# 3月    99   99   99   99   99   99    99
# 4月    98   98   98   98   98   98    98
# 5月   100  100  100  100  100  100   100
# 6月    99   99   99   99   99   99    99
# 7月    99   99   99   99   99   99    99
# 8月    99   99   99   99   99   99    99
# 9月    99   99   99   99   99   99    99

# %%
channel_zixun_zonghe.to_json('channel_zixun_zonghe.json')

# %%
pd.set_option('display.max_rows', None)

# %%
channel_youxi_danji[channel_youxi_danji['时间']=='4月']
# Out:
#             时间            作者名  作者类型      粉丝数   投稿数  \
# 1h54y1d7Qq  4月            鹤吱菌  个人认证   191.3万    81
# 1L64y1M7Dp  4月            老番茄  个人认证  1360.1万   348
# 18K41157Tu  4月            老番茄  个人认证  1360.1万   348
# 1PT4y1G7ME  4月            老番茄  个人认证  1360.1万   348
# 1S54y197uX  4月           徐大虾咯  个人认证   570.1万   224
# 1ti4y1t7YM  4月            老番茄  个人认证  1360.1万   348
# 1Ai4y1b7ET  4月            敖厂长  个人认证   735.1万   348
# 1Up4y1C7PB  4月        丢鹏D1uuu     无     8.4万    20
# 1wi4y187bu  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 13t4y1U7kQ  4月           徐大虾咯  个人认证   570.1万   224
# 1fe411x7FA  4月         芦苇草的梦想  个人认证    29.3万   726
# 1LA411b7Dt  4月      LexBurner  个人认证   929.6万   383
# 1Ji4y1t7T9  4月            沧桑丸  个人认证    86.6万    57
# 1Lz411z72u  4月           徐大虾咯  个人认证   570.1万   224
# 13T4y1G7WT  4月          逗比的雀巢  个人认证   242.3万    82
# 1T54y197DH  4月           徐大虾咯  个人认证   570.1万   224
# 1Va4y147fH  4月            鹤吱菌  个人认证   191.3万    81
# 1tt4y127yy  4月           小潮院长  个人认证   481.6万   266
# 16T4y1g7RY  4月         吉儿一范伦婷  个人认证    67.6万    79
# 1754y197Da  4月            敖厂长  个人认证   735.1万   348
# 1hK41157M3  4月           花少北丶  个人认证   491.9万   173
# 1Rk4y197kw  4月       3DM游戏网官方  机构认证    13.5万  2822
# 1ST4y1G7E1  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1H54y1d76B  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1Sz411B7P4  4月          游汐_YX  个人认证    12.9万    98
# 1CT4y1g7Ya  4月    育碧中国Ubisoft  机构认证    64.5万  1211
# 12T4y1G7AZ  4月          与山0v0  个人认证   208.5万   557
# 1b5411x79t  4月        东尼ookii  个人认证   331.7万   166
# 1hA411h7Ky  4月          与山0v0  个人认证   208.5万   557
# 1Gt4y127AJ  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 13f4y1S7sa  4月          我是凉菜啊     无     8516   447
# 1KJ411e7nN                              如何提高审美？审美有无高低？审美是谁建立？  数码  摄影摄像  普通视频
# ...                                                       ...  ..   ...   ...
# 1cr4y1w7ig              困难重重，国家天文签约摄影师遭遇拍摄滑铁卢？！【华为Mate40 Pro】  数码  摄影摄像  活动作品
# 1Y5411L7TW                     富士X-S10相机测试——2020 apsc画幅性价比最强机  数码  摄影摄像  活动作品
# 1c541177hR      索尼（Sony）12-24mm F2.8 GM深度评测，只要买得起，它就是一颗完美的镜头！  数码  摄影摄像  普通视频
# 1DA41177UY                            大疆旗舰稳定器 - DJI RS 2 正式登场  数码  摄影摄像  普通视频
# 1rA411776p                 让我非常失望的佳能M50 Mark II（来自一代老用户的真实心声）  数码  摄影摄像  普通视频
#
#             ...                                                 标签   视频长度  \
# 1gJ411n7hp  ...                         [摄影, 数码, 摄影摄像, 数码, 教程, 器材]  01:44
# 1tJ41187w6  ...  [相机, 数码, 摄影摄像, 数码, 何同学, 啊吗粽, 宝剑嫂, 自媒体, 大祥哥, 体验...  30:03
# 1i7411i7yA  ...        [摄影, 短片, 数码, 摄影摄像, 数码, 创意, YOUTUBE, 镜头, 老蛙]  04:51
# 1gJ411G7Cs  ...           [摄影, 数码, 摄影摄像, 数码, VLOG, 后期, 教程, ps, 器材]  06:01
# 1KJ411e7nN  ...  [校园vlog, 相机, 脱口秀, 摄影, 公开课, vlog, 科普, 数码, 摄影摄像,...  27:08
# ...         ...                                                ...    ...
# 1cr4y1w7ig  ...  [vlog, 数码, 摄影摄像, 数码, 放心购机攻略, 敦煌, 星空, 手机摄影, 华为,...  11:43
# 1Y5411L7TW  ...  [相机, 摄影, 数码, 摄影摄像, 数码, 数码玩家训练营, 拍照, 测评, xs10, ...  10:20
# 1c541177hR  ...  [摄影, 数码, 摄影摄像, 数码, 评测, 超广角大光圈, 摄像, 镜头, 数码评测, 超...  21:23
# 1DA41177UY  ...   [相机, 摄影, 数码, 摄影摄像, 数码, 科技, 测评, 器材, 大疆, DJI, 稳定器]  02:26
# 1rA411776p  ...  [vlog, 数码, 摄影摄像, 数码, 佳能, 测评, 体验, m50 mark ii, ...  06:30
#
#                播放量    点赞数   投币数   收藏数   转发数   评论数   弹幕数 有无分集
# 1gJ411n7hp  222.4万   9.7万  2.0万  1.4万  4980  3182  1571    否
# 1tJ41187w6  134.0万  10.7万  8.4万  5.8万  8907  3935  3.0万    否
# 1i7411i7yA   57.8万   4.4万  1.0万  1.6万  2043   641   983    否
# 1gJ411G7Cs   42.3万   3.3万  3.4万  8.6万  2605  1405   612    否
# 1KJ411e7nN   39.6万   4.8万  5.4万  3.4万  6217  1156  1.0万    否
# ...            ...    ...   ...   ...   ...   ...   ...  ...
# 1cr4y1w7ig    4.3万   3051  1391   692   255   337   349    否
# 1Y5411L7TW    4.3万    773   219   221   111   273   104    否
# 1c541177hR    4.1万   1469   443   297   123   250   561    否
# 1DA41177UY    4.1万   1565   197   334   640   171   110    否
# 1rA411776p    4.1万   1262   267   147   101   385   314    否
#
# [999 rows x 21 columns]
