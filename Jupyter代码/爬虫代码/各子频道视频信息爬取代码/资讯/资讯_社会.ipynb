# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_zixun_shehui=pd.DataFrame(columns=columns)
channel_zixun_shehui
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[12]/div/a/span').click()  #选择频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[12]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '资讯'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[4]/a').click()  #选择子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[4]/a').text
sub_channel
# Out:
# '社会'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(1,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_zixun_shehui.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-17 12:06:20.669693
# <ipython-input-18-49e7a0eaf418>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-18-49e7a0eaf418>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-18-49e7a0eaf418>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1KJ411j7Bf视频属性的抓取
# BV号为1KJ411j7Bf的视频属性抓取结束
# <ipython-input-18-49e7a0eaf418>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1c7411Y7L5视频属性的抓取
# BV号为1c7411Y7L5的视频属性抓取结束
# 开始BV号为12J41177qf视频属性的抓取
# BV号为12J41177qf的视频属性抓取结束
# 开始BV号为1M7411q7sf视频属性的抓取
# BV号为1M7411q7sf的视频属性抓取结束
# 开始BV号为1fJ411j7sL视频属性的抓取
# BV号为1fJ411j7sL的视频属性抓取结束
# 开始BV号为1j7411k7Ug视频属性的抓取
# BV号为1j7411k7Ug的视频属性抓取结束
# 开始BV号为1u7411679U视频属性的抓取
# BV号为1u7411679U的视频属性抓取结束
# 开始BV号为1HJ411J7ix视频属性的抓取
# BV号为1HJ411J7ix的视频属性抓取结束
# 开始BV号为1t7411Y76x视频属性的抓取
# BV号为1t7411Y76x的视频属性抓取结束
# 开始BV号为1bJ411V7Hg视频属性的抓取
# BV号为1bJ411V7Hg的视频属性抓取结束
# 开始BV号为1YJ411b7dV视频属性的抓取
# BV号为1YJ411b7dV的视频属性抓取结束
# 开始BV号为1e7411B7gt视频属性的抓取
# BV号为1e7411B7gt的视频属性抓取结束
# 开始BV号为1AJ411p7Pk视频属性的抓取
# BV号为1AJ411p7Pk的视频属性抓取结束
# 开始BV号为1v7411B7Ww视频属性的抓取
# BV号为1v7411B7Ww的视频属性抓取结束
# 开始BV号为1WJ411n7o7视频属性的抓取
# BV号为1WJ411n7o7的视频属性抓取结束
# 开始BV号为1ZJ411V7Eq视频属性的抓取
# BV号为1ZJ411V7Eq的视频属性抓取结束
# 开始BV号为1P7411v77M视频属性的抓取
# BV号为1P7411v77M的视频属性抓取结束
# 开始BV号为1VJ411E7Js视频属性的抓取
# BV号为1VJ411E7Js的视频属性抓取结束
# 开始BV号为1R7411Y7CG视频属性的抓取
# BV号为1R7411Y7CG的视频属性抓取结束
# 开始BV号为1v7411q7GT视频属性的抓取
# BV号为1v7411q7GT的视频属性抓取结束
# 开始BV号为1bJ41157De视频属性的抓取
# BV号为1bJ41157De的视频属性抓取结束
# 开始BV号为1SJ411E7b2视频属性的抓取
# BV号为1SJ411E7b2的视频属性抓取结束
# 开始BV号为1gJ411n786视频属性的抓取
# BV号为1gJ411n786的视频属性抓取结束
# 开始BV号为1x7411z7Qa视频属性的抓取
# BV号为1x7411z7Qa的视频属性抓取结束
# 开始BV号为14741167Ls视频属性的抓取
# BV号为14741167Ls的视频属性抓取结束
# 开始BV号为157411Y7FA视频属性的抓取
# BV号为157411Y7FA的视频属性抓取结束
# 开始BV号为197411Y7aJ视频属性的抓取
# BV号为197411Y7aJ的视频属性抓取结束
# 开始BV号为177411B7RA视频属性的抓取
# BV号为177411B7RA的视频属性抓取结束
# 开始BV号为1SJ411j7LB视频属性的抓取
# BV号为1SJ411j7LB的视频属性抓取结束
# 开始BV号为1o7411a7RF视频属性的抓取
# BV号为1o7411a7RF的视频属性抓取结束
# 开始BV号为1MJ411p7kU视频属性的抓取
# BV号为1MJ411p7kU的视频属性抓取结束
# 开始BV号为1XJ411n75c视频属性的抓取
# BV号为1XJ411n75c的视频属性抓取结束
# 开始BV号为1g7411e7Gi视频属性的抓取
# BV号为1g7411e7Gi的视频属性抓取结束
# 开始BV号为1g7411Y7zZ视频属性的抓取
# BV号为1g7411Y7zZ的视频属性抓取结束
# 开始BV号为18J411H7v2视频属性的抓取
# BV号为18J411H7v2的视频属性抓取结束
# 开始BV号为1m7411r7MK视频属性的抓取
# BV号为1m7411r7MK的视频属性抓取结束
# 开始BV号为1oJ411572V视频属性的抓取
# BV号为1oJ411572V的视频属性抓取结束
# 开始BV号为1h7411q7Dt视频属性的抓取
# BV号为1h7411q7Dt的视频属性抓取结束
# 开始BV号为1Q7411B7N7视频属性的抓取
# BV号为1Q7411B7N7的视频属性抓取结束
# 开始BV号为16J411j7wv视频属性的抓取
# BV号为16J411j7wv的视频属性抓取结束
# 开始BV号为147411q7zU视频属性的抓取
# BV号为147411q7zU的视频属性抓取结束
# 开始BV号为1dJ411E7uF视频属性的抓取
# BV号为1dJ411E7uF的视频属性抓取结束
# 开始BV号为1SJ411V7s3视频属性的抓取
# BV号为1SJ411V7s3的视频属性抓取结束
# 开始BV号为1e7411e7cf视频属性的抓取
# BV号为1e7411e7cf的视频属性抓取结束
# 开始BV号为1A7411Y78e视频属性的抓取
# BV号为1A7411Y78e的视频属性抓取结束
# 开始BV号为1u741167er视频属性的抓取
# BV号为1u741167er的视频属性抓取结束
# 开始BV号为1bJ41157sX视频属性的抓取
# BV号为1bJ41157sX的视频属性抓取结束
# 开始BV号为1G7411B7FB视频属性的抓取
# BV号为1G7411B7FB的视频属性抓取结束
# 开始BV号为1aJ411J7zm视频属性的抓取
# BV号为1aJ411J7zm的视频属性抓取结束
# 开始BV号为13J411G7ry视频属性的抓取
# BV号为13J411G7ry的视频属性抓取结束
# 开始BV号为1DJ411E7gs视频属性的抓取
# BV号为1DJ411E7gs的视频属性抓取结束
# 开始BV号为117411r7yR视频属性的抓取
# BV号为117411r7yR的视频属性抓取结束
# 开始BV号为1nJ41187Gm视频属性的抓取
# BV号为1nJ41187Gm的视频属性抓取结束
# 开始BV号为1F7411Y7CY视频属性的抓取
# BV号为1F7411Y7CY的视频属性抓取结束
# 开始BV号为1GJ411776q视频属性的抓取
# BV号为1GJ411776q的视频属性抓取结束
# 开始BV号为1n7411q7uE视频属性的抓取
# 开始BV号为1n7411q7uE视频属性的抓取
# BV号为1n7411q7uE的视频属性抓取结束
# 开始BV号为1b7411v7eS视频属性的抓取
# BV号为1b7411v7eS的视频属性抓取结束
# 开始BV号为1KJ411H7WS视频属性的抓取
# BV号为1KJ411H7WS的视频属性抓取结束
# 开始BV号为167411v7FJ视频属性的抓取
# BV号为167411v7FJ的视频属性抓取结束
# 开始BV号为14J411V7Fh视频属性的抓取
# BV号为14J411V7Fh的视频属性抓取结束
# 开始BV号为1dJ411578M视频属性的抓取
# BV号为1dJ411578M的视频属性抓取结束
# 开始BV号为1uJ411V7Zw视频属性的抓取
# BV号为1uJ411V7Zw的视频属性抓取结束
# 开始BV号为1y7411r7Ro视频属性的抓取
# BV号为1y7411r7Ro的视频属性抓取结束
# 开始BV号为1YJ411V7oH视频属性的抓取
# BV号为1YJ411V7oH的视频属性抓取结束
# 开始BV号为1bJ411G7Vr视频属性的抓取
# BV号为1bJ411G7Vr的视频属性抓取结束
# 开始BV号为1QJ41177Mf视频属性的抓取
# BV号为1QJ41177Mf的视频属性抓取结束
# 开始BV号为1U7411Y7S9视频属性的抓取
# BV号为1U7411Y7S9的视频属性抓取结束
# 开始BV号为1XJ411V783视频属性的抓取
# BV号为1XJ411V783的视频属性抓取结束
# 开始BV号为1zJ411H72C视频属性的抓取
# BV号为1zJ411H72C的视频属性抓取结束
# 开始BV号为19J411G7LT视频属性的抓取
# BV号为19J411G7LT的视频属性抓取结束
# 开始BV号为1d7411r7Ko视频属性的抓取
# BV号为1d7411r7Ko的视频属性抓取结束
# 开始BV号为1QJ411L7iw视频属性的抓取
# BV号为1QJ411L7iw的视频属性抓取结束
# 开始BV号为157411e7kJ视频属性的抓取
# BV号为157411e7kJ的视频属性抓取结束
# 开始BV号为1yJ411b7X1视频属性的抓取
# BV号为1yJ411b7X1的视频属性抓取结束
# 开始BV号为1RJ41177Af视频属性的抓取
# BV号为1RJ41177Af的视频属性抓取结束
# 开始BV号为1X7411v7zF视频属性的抓取
# BV号为1X7411v7zF的视频属性抓取结束
# 开始BV号为1z7411r7NV视频属性的抓取
# BV号为1z7411r7NV的视频属性抓取结束
# 开始BV号为1G7411i7vt视频属性的抓取
# BV号为1G7411i7vt的视频属性抓取结束
# 开始BV号为1SJ411n7NZ视频属性的抓取
# BV号为1SJ411n7NZ的视频属性抓取结束
# 开始BV号为1bJ41187Ds视频属性的抓取
# BV号为1bJ41187Ds的视频属性抓取结束
# 开始BV号为1t7411v7Ei视频属性的抓取
# BV号为1t7411v7Ei的视频属性抓取结束
# 开始BV号为1N741167fz视频属性的抓取
# BV号为1N741167fz的视频属性抓取结束
# 开始BV号为1YJ411L7wA视频属性的抓取
# BV号为1YJ411L7wA的视频属性抓取结束
# 开始BV号为1R7411e7vp视频属性的抓取
# BV号为1R7411e7vp的视频属性抓取结束
# 开始BV号为1JJ411E7h6视频属性的抓取
# BV号为1JJ411E7h6的视频属性抓取结束
# 开始BV号为1vJ411L7Fe视频属性的抓取
# BV号为1vJ411L7Fe的视频属性抓取结束
# <ipython-input-18-49e7a0eaf418>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1c7411i7y7视频属性的抓取
# BV号为1c7411i7y7的视频属性抓取结束
# 开始BV号为1BJ411H7Tu视频属性的抓取
# BV号为1BJ411H7Tu的视频属性抓取结束
# 开始BV号为1a7411v71v视频属性的抓取
# BV号为1a7411v71v的视频属性抓取结束
# 开始BV号为1N7411i7ym视频属性的抓取
# BV号为1N7411i7ym的视频属性抓取结束
# 开始BV号为1xJ411p7NA视频属性的抓取
# BV号为1xJ411p7NA的视频属性抓取结束
# 开始BV号为1Y7411v7Pp视频属性的抓取
# BV号为1Y7411v7Pp的视频属性抓取结束
# 开始BV号为1F7411e7MM视频属性的抓取
# BV号为1F7411e7MM的视频属性抓取结束
# 开始BV号为167411Y7KD视频属性的抓取
# BV号为167411Y7KD的视频属性抓取结束
# 开始BV号为1SJ411E7Xj视频属性的抓取
# BV号为1SJ411E7Xj的视频属性抓取结束
# 开始BV号为1g7411v76b视频属性的抓取
# BV号为1g7411v76b的视频属性抓取结束
# 开始BV号为16J411j7H2视频属性的抓取
# BV号为16J411j7H2的视频属性抓取结束
# 开始BV号为15J41157Na视频属性的抓取
# BV号为15J41157Na的视频属性抓取结束
# 开始BV号为1iJ411L7qj视频属性的抓取
# BV号为1iJ411L7qj的视频属性抓取结束
# 开始BV号为1sj411f7fw视频属性的抓取
# BV号为1sj411f7fw的视频属性抓取结束
# 开始BV号为1D7411J7WQ视频属性的抓取
# BV号为1D7411J7WQ的视频属性抓取结束
# 开始BV号为1s7411L71D视频属性的抓取
# BV号为1s7411L71D的视频属性抓取结束
# 开始BV号为1k7411K7jj视频属性的抓取
# BV号为1k7411K7jj的视频属性抓取结束
# 开始BV号为117411x79F视频属性的抓取
# BV号为117411x79F的视频属性抓取结束
# 开始BV号为1h741147Vb视频属性的抓取
# BV号为1h741147Vb的视频属性抓取结束
# 开始BV号为117411K74r视频属性的抓取
# BV号为117411K74r的视频属性抓取结束
# 开始BV号为1w7411j78d视频属性的抓取
# BV号为1w7411j78d的视频属性抓取结束
# 开始BV号为1k741157mF视频属性的抓取
# BV号为1k741157mF的视频属性抓取结束
# 开始BV号为1n741137sp视频属性的抓取
# BV号为1n741137sp的视频属性抓取结束
# 开始BV号为1H741137Ve视频属性的抓取
# BV号为1H741137Ve的视频属性抓取结束
# 开始BV号为147411u7yX视频属性的抓取
# BV号为147411u7yX的视频属性抓取结束
# 开始BV号为1a741147NB视频属性的抓取
# BV号为1a741147NB的视频属性抓取结束
# 开始BV号为1W7411u7CK视频属性的抓取
# BV号为1W7411u7CK的视频属性抓取结束
# 开始BV号为177411H7Ve视频属性的抓取
# BV号为177411H7Ve的视频属性抓取结束
# 开始BV号为1U7411g7Y2视频属性的抓取
# BV号为1U7411g7Y2的视频属性抓取结束
# 开始BV号为1b7411N7CG视频属性的抓取
# BV号为1b7411N7CG的视频属性抓取结束
# 开始BV号为1x741157Ww视频属性的抓取
# BV号为1x741157Ww的视频属性抓取结束
# 开始BV号为1R7411V7Hk视频属性的抓取
# BV号为1R7411V7Hk的视频属性抓取结束
# 开始BV号为1wE411n7Tu视频属性的抓取
# BV号为1wE411n7Tu的视频属性抓取结束
# 开始BV号为1W7411c77A视频属性的抓取
# BV号为1W7411c77A的视频属性抓取结束
# 开始BV号为1L7411878C视频属性的抓取
# BV号为1L7411878C的视频属性抓取结束
# 开始BV号为1qE411J7Rd视频属性的抓取
# BV号为1qE411J7Rd的视频属性抓取结束
# 开始BV号为167411T7s5视频属性的抓取
# BV号为167411T7s5的视频属性抓取结束
# 开始BV号为1B7411G7gA视频属性的抓取
# BV号为1B7411G7gA的视频属性抓取结束
# 开始BV号为1Y7411w75w视频属性的抓取
# BV号为1Y7411w75w的视频属性抓取结束
# 开始BV号为1p7411A7nX视频属性的抓取
# BV号为1p7411A7nX的视频属性抓取结束
# 开始BV号为137411h7cv视频属性的抓取
# BV号为137411h7cv的视频属性抓取结束
# 开始BV号为177411b7pa视频属性的抓取
# BV号为177411b7pa的视频属性抓取结束
# 开始BV号为1V7411K7xt视频属性的抓取
# BV号为1V7411K7xt的视频属性抓取结束
# 开始BV号为1Y7411h7Jd视频属性的抓取
# BV号为1Y7411h7Jd的视频属性抓取结束
# 开始BV号为1c7411c7V4视频属性的抓取
# BV号为1c7411c7V4的视频属性抓取结束
# 开始BV号为1x7411p7W8视频属性的抓取
# BV号为1x7411p7W8的视频属性抓取结束
# 开始BV号为117411p7ce视频属性的抓取
# BV号为117411p7ce的视频属性抓取结束
# 开始BV号为1W741157KJ视频属性的抓取
# BV号为1W741157KJ的视频属性抓取结束
# 开始BV号为1r7411u7ai视频属性的抓取
# BV号为1r7411u7ai的视频属性抓取结束
# 开始BV号为1W7411K7bQ视频属性的抓取
# BV号为1W7411K7bQ的视频属性抓取结束
# 开始BV号为1M7411F7HF视频属性的抓取
# BV号为1M7411F7HF的视频属性抓取结束
# 开始BV号为1tE411n74Q视频属性的抓取
# BV号为1tE411n74Q的视频属性抓取结束
# 开始BV号为1X7411g7Mu视频属性的抓取
# BV号为1X7411g7Mu的视频属性抓取结束
# 开始BV号为1ME411J7Kt视频属性的抓取
# BV号为1ME411J7Kt的视频属性抓取结束
# 开始BV号为197411w7dP视频属性的抓取
# BV号为197411w7dP的视频属性抓取结束
# 开始BV号为1n741157t6视频属性的抓取
# BV号为1n741157t6的视频属性抓取结束
# 开始BV号为1C7411A7mp视频属性的抓取
# BV号为1C7411A7mp的视频属性抓取结束
# 开始BV号为1S7411t7iw视频属性的抓取
# BV号为1S7411t7iw的视频属性抓取结束
# 开始BV号为1nE411H7w6视频属性的抓取
# BV号为1nE411H7w6的视频属性抓取结束
# 开始BV号为1i7411G7v8视频属性的抓取
# BV号为1i7411G7v8的视频属性抓取结束
# 开始BV号为1e7411s7Fk视频属性的抓取
# BV号为1e7411s7Fk的视频属性抓取结束
# 开始BV号为1n7411b7yT视频属性的抓取
# BV号为1n7411b7yT的视频属性抓取结束
# 开始BV号为1V7411M7Jf视频属性的抓取
# BV号为1V7411M7Jf的视频属性抓取结束
# 开始BV号为117411w73T视频属性的抓取
# BV号为117411w73T的视频属性抓取结束
# 开始BV号为1Qj411f7yF视频属性的抓取
# BV号为1Qj411f7yF的视频属性抓取结束
# 开始BV号为1f7411x7Ng视频属性的抓取
# BV号为1f7411x7Ng的视频属性抓取结束
# 开始BV号为1c7411s7ig视频属性的抓取
# BV号为1c7411s7ig的视频属性抓取结束
# 开始BV号为1f7411p7yr视频属性的抓取
# BV号为1f7411p7yr的视频属性抓取结束
# 开始BV号为1j7411t7fZ视频属性的抓取
# BV号为1j7411t7fZ的视频属性抓取结束
# 开始BV号为1U7411K7QQ视频属性的抓取
# BV号为1U7411K7QQ的视频属性抓取结束
# 开始BV号为1N7411G7r3视频属性的抓取
# BV号为1N7411G7r3的视频属性抓取结束
# 开始BV号为167411V7bN视频属性的抓取
# BV号为167411V7bN的视频属性抓取结束
# 开始BV号为1D7411F7Ac视频属性的抓取
# BV号为1D7411F7Ac的视频属性抓取结束
# 开始BV号为1b7411T7vN视频属性的抓取
# BV号为1b7411T7vN的视频属性抓取结束
# 开始BV号为1Hj411f7n3视频属性的抓取
# BV号为1Hj411f7n3的视频属性抓取结束
# 开始BV号为137411K7Pp视频属性的抓取
# BV号为137411K7Pp的视频属性抓取结束
# 开始BV号为1t7411t7Wz视频属性的抓取
# BV号为1t7411t7Wz的视频属性抓取结束
# 开始BV号为137411K73M视频属性的抓取
# BV号为137411K73M的视频属性抓取结束
# 开始BV号为1o7411L7Rz视频属性的抓取
# BV号为1o7411L7Rz的视频属性抓取结束
# 开始BV号为1j7411t7yM视频属性的抓取
# BV号为1j7411t7yM的视频属性抓取结束
# 开始BV号为1Z7411w7Pt视频属性的抓取
# BV号为1Z7411w7Pt的视频属性抓取结束
# 开始BV号为1F7411g7RF视频属性的抓取
# BV号为1F7411g7RF的视频属性抓取结束
# 开始BV号为1E7411L7Ke视频属性的抓取
# BV号为1E7411L7Ke的视频属性抓取结束
# 开始BV号为1c7411F7c4视频属性的抓取
# BV号为1c7411F7c4的视频属性抓取结束
# 开始BV号为1H7411j74V视频属性的抓取
# BV号为1H7411j74V的视频属性抓取结束
# 开始BV号为1F741157gd视频属性的抓取
# BV号为1F741157gd的视频属性抓取结束
# 开始BV号为1Z7411J7bx视频属性的抓取
# BV号为1Z7411J7bx的视频属性抓取结束
# 开始BV号为1D7411G7ro视频属性的抓取
# BV号为1D7411G7ro的视频属性抓取结束
# 开始BV号为1u7411p79r视频属性的抓取
# BV号为1u7411p79r的视频属性抓取结束
# 开始BV号为1E7411c72G视频属性的抓取
# BV号为1E7411c72G的视频属性抓取结束
# 开始BV号为1y7411w7Un视频属性的抓取
# BV号为1y7411w7Un的视频属性抓取结束
# 开始BV号为1K7411H7ED视频属性的抓取
# BV号为1K7411H7ED的视频属性抓取结束
# 开始BV号为1z7411K7QK视频属性的抓取
# BV号为1z7411K7QK的视频属性抓取结束
# 开始BV号为1G7411s7zd视频属性的抓取
# BV号为1G7411s7zd的视频属性抓取结束
# 开始BV号为1a7411J7ZP视频属性的抓取
# BV号为1a7411J7ZP的视频属性抓取结束
# 开始BV号为1u7411J7gr视频属性的抓取
# BV号为1u7411J7gr的视频属性抓取结束
# 开始BV号为1q7411h7TL视频属性的抓取
# BV号为1q7411h7TL的视频属性抓取结束
# 开始BV号为1W7411H7P7视频属性的抓取
# BV号为1W7411H7P7的视频属性抓取结束
# 开始BV号为1T7411u7b2视频属性的抓取
# BV号为1T7411u7b2的视频属性抓取结束
# 开始BV号为1A7411h75R视频属性的抓取
# BV号为1A7411h75R的视频属性抓取结束
# 开始BV号为1s7411n7Gf视频属性的抓取
# BV号为1s7411n7Gf的视频属性抓取结束
# 开始BV号为1w7411p7Bw视频属性的抓取
# BV号为1w7411p7Bw的视频属性抓取结束
# 开始BV号为1W7411V7B4视频属性的抓取
# BV号为1W7411V7B4的视频属性抓取结束
# 开始BV号为1X7411F7JA视频属性的抓取
# BV号为1X7411F7JA的视频属性抓取结束
# 开始BV号为1m7411T7vm视频属性的抓取
# BV号为1m7411T7vm的视频属性抓取结束
# 开始BV号为1h7411w7ZK视频属性的抓取
# BV号为1h7411w7ZK的视频属性抓取结束
# 开始BV号为1u741177YX视频属性的抓取
# BV号为1u741177YX的视频属性抓取结束
# 开始BV号为177411u7vW视频属性的抓取
# BV号为177411u7vW的视频属性抓取结束
# 开始BV号为1i7411G7GT视频属性的抓取
# BV号为1i7411G7GT的视频属性抓取结束
# 开始BV号为1y741137Z3视频属性的抓取
# BV号为1y741137Z3的视频属性抓取结束
# 开始BV号为1vE411p7GH视频属性的抓取
# BV号为1vE411p7GH的视频属性抓取结束
# 开始BV号为1PA411h78S视频属性的抓取
# BV号为1PA411h78S的视频属性抓取结束
# 开始BV号为1BE411x7bE视频属性的抓取
# BV号为1BE411x7bE的视频属性抓取结束
# 开始BV号为1nE411G7ou视频属性的抓取
# 开始BV号为1nE411G7ou视频属性的抓取
# BV号为1nE411G7ou的视频属性抓取结束
# 开始BV号为11E411K7Ff视频属性的抓取
# BV号为11E411K7Ff的视频属性抓取结束
# 开始BV号为1R7411U7hK视频属性的抓取
# BV号为1R7411U7hK的视频属性抓取结束
# 开始BV号为1C7411R7oE视频属性的抓取
# BV号为1C7411R7oE的视频属性抓取结束
# 开始BV号为1LE411F7pS视频属性的抓取
# BV号为1LE411F7pS的视频属性抓取结束
# 开始BV号为15E41177Pq视频属性的抓取
# BV号为15E41177Pq的视频属性抓取结束
# 开始BV号为1SE411u72a视频属性的抓取
# BV号为1SE411u72a的视频属性抓取结束
# 开始BV号为1j7411d7Nr视频属性的抓取
# BV号为1j7411d7Nr的视频属性抓取结束
# 开始BV号为19741127Re视频属性的抓取
# BV号为19741127Re的视频属性抓取结束
# 开始BV号为1SE411V72s视频属性的抓取
# BV号为1SE411V72s的视频属性抓取结束
# 开始BV号为1N7411d77g视频属性的抓取
# BV号为1N7411d77g的视频属性抓取结束
# 开始BV号为16E411j7ab视频属性的抓取
# BV号为16E411j7ab的视频属性抓取结束
# 开始BV号为1D541147NK视频属性的抓取
# BV号为1D541147NK的视频属性抓取结束
# 开始BV号为1vE411c7d3视频属性的抓取
# BV号为1vE411c7d3的视频属性抓取结束
# 开始BV号为1vE411G7r9视频属性的抓取
# BV号为1vE411G7r9的视频属性抓取结束
# 开始BV号为1uE411p7aq视频属性的抓取
# BV号为1uE411p7aq的视频属性抓取结束
# 开始BV号为14Z4y1j7hQ视频属性的抓取
# BV号为14Z4y1j7hQ的视频属性抓取结束
# 开始BV号为1UE41177Pe视频属性的抓取
# BV号为1UE41177Pe的视频属性抓取结束
# 开始BV号为1QE411s7Af视频属性的抓取
# BV号为1QE411s7Af的视频属性抓取结束
# 开始BV号为18E411E7ma视频属性的抓取
# BV号为18E411E7ma的视频属性抓取结束
# 开始BV号为1U7411275V视频属性的抓取
# BV号为1U7411275V的视频属性抓取结束
# 开始BV号为1f541147xJ视频属性的抓取
# BV号为1f541147xJ的视频属性抓取结束
# 开始BV号为1gV411f7kt视频属性的抓取
# BV号为1gV411f7kt的视频属性抓取结束
# 开始BV号为1C7411d7Wi视频属性的抓取
# BV号为1C7411d7Wi的视频属性抓取结束
# 开始BV号为1NE411j79Y视频属性的抓取
# BV号为1NE411j79Y的视频属性抓取结束
# 开始BV号为1S7411o7Uv视频属性的抓取
# BV号为1S7411o7Uv的视频属性抓取结束
# 开始BV号为1uE411M7D8视频属性的抓取
# BV号为1uE411M7D8的视频属性抓取结束
# 开始BV号为1jE411x7aP视频属性的抓取
# BV号为1jE411x7aP的视频属性抓取结束
# 开始BV号为1Ag4y1a7X5视频属性的抓取
# BV号为1Ag4y1a7X5的视频属性抓取结束
# 开始BV号为1J7411R7QA视频属性的抓取
# BV号为1J7411R7QA的视频属性抓取结束
# 开始BV号为1cT4y1G7nt视频属性的抓取
# BV号为1cT4y1G7nt的视频属性抓取结束
# 开始BV号为1oE411w7hp视频属性的抓取
# BV号为1oE411w7hp的视频属性抓取结束
# 开始BV号为18E411u7bS视频属性的抓取
# BV号为18E411u7bS的视频属性抓取结束
# 开始BV号为1u741117ob视频属性的抓取
# BV号为1u741117ob的视频属性抓取结束
# 开始BV号为1m541147Bo视频属性的抓取
# BV号为1m541147Bo的视频属性抓取结束
# 开始BV号为1gE411w7kT视频属性的抓取
# BV号为1gE411w7kT的视频属性抓取结束
# 开始BV号为1VE411F7S2视频属性的抓取
# BV号为1VE411F7S2的视频属性抓取结束
# 开始BV号为1W7411C7JN视频属性的抓取
# BV号为1W7411C7JN的视频属性抓取结束
# 开始BV号为1vE411w7on视频属性的抓取
# BV号为1vE411w7on的视频属性抓取结束
# 开始BV号为1hE411L73S视频属性的抓取
# BV号为1hE411L73S的视频属性抓取结束
# 开始BV号为1WE411j7nm视频属性的抓取
# BV号为1WE411j7nm的视频属性抓取结束
# 开始BV号为1WE411A7Pd视频属性的抓取
# BV号为1WE411A7Pd的视频属性抓取结束
# 开始BV号为1hE411u7DE视频属性的抓取
# BV号为1hE411u7DE的视频属性抓取结束
# 开始BV号为1k7411S7Yt视频属性的抓取
# BV号为1k7411S7Yt的视频属性抓取结束
# 开始BV号为1d7411S73S视频属性的抓取
# BV号为1d7411S73S的视频属性抓取结束
# 开始BV号为1NE41137jT视频属性的抓取
# BV号为1NE41137jT的视频属性抓取结束
# 开始BV号为1va4y1t7Jd视频属性的抓取
# BV号为1va4y1t7Jd的视频属性抓取结束
# 开始BV号为1sE411g78N视频属性的抓取
# BV号为1sE411g78N的视频属性抓取结束
# 开始BV号为1M7411d7XA视频属性的抓取
# BV号为1M7411d7XA的视频属性抓取结束
# 开始BV号为1SE411c7QG视频属性的抓取
# BV号为1SE411c7QG的视频属性抓取结束
# 开始BV号为1xE411E7uk视频属性的抓取
# BV号为1xE411E7uk的视频属性抓取结束
# 开始BV号为1cE411L7xZ视频属性的抓取
# BV号为1cE411L7xZ的视频属性抓取结束
# 开始BV号为1GE411G7Uy视频属性的抓取
# BV号为1GE411G7Uy的视频属性抓取结束
# 开始BV号为1sc411h7yJ视频属性的抓取
# BV号为1sc411h7yJ的视频属性抓取结束
# 开始BV号为117411Z7AE视频属性的抓取
# BV号为117411Z7AE的视频属性抓取结束
# 开始BV号为1YE411u7hK视频属性的抓取
# BV号为1YE411u7hK的视频属性抓取结束
# 开始BV号为1QE411A7ux视频属性的抓取
# BV号为1QE411A7ux的视频属性抓取结束
# 开始BV号为1cE411g77h视频属性的抓取
# BV号为1cE411g77h的视频属性抓取结束
# 开始BV号为1o7411Q72p视频属性的抓取
# BV号为1o7411Q72p的视频属性抓取结束
# 开始BV号为1QE411s7ca视频属性的抓取
# BV号为1QE411s7ca的视频属性抓取结束
# 开始BV号为1NZ4y1j717视频属性的抓取
# BV号为1NZ4y1j717的视频属性抓取结束
# 开始BV号为14E411V7b1视频属性的抓取
# BV号为14E411V7b1的视频属性抓取结束
# 开始BV号为17E411x7V6视频属性的抓取
# BV号为17E411x7V6的视频属性抓取结束
# 开始BV号为1LE41147fF视频属性的抓取
# BV号为1LE41147fF的视频属性抓取结束
# 开始BV号为177411o7rN视频属性的抓取
# BV号为177411o7rN的视频属性抓取结束
# 开始BV号为1Y7411R7EL视频属性的抓取
# BV号为1Y7411R7EL的视频属性抓取结束
# 开始BV号为1hE411u7AE视频属性的抓取
# BV号为1hE411u7AE的视频属性抓取结束
# 开始BV号为1jE411c7X8视频属性的抓取
# BV号为1jE411c7X8的视频属性抓取结束
# 开始BV号为1TE411N7PH视频属性的抓取
# BV号为1TE411N7PH的视频属性抓取结束
# 开始BV号为1pE411u7rK视频属性的抓取
# BV号为1pE411u7rK的视频属性抓取结束
# 开始BV号为1vE411c7vC视频属性的抓取
# BV号为1vE411c7vC的视频属性抓取结束
# 开始BV号为1GE411L7Jt视频属性的抓取
# BV号为1GE411L7Jt的视频属性抓取结束
# 开始BV号为1gQ4y1M77B视频属性的抓取
# BV号为1gQ4y1M77B的视频属性抓取结束
# 开始BV号为16E411T7WA视频属性的抓取
# BV号为16E411T7WA的视频属性抓取结束
# 开始BV号为1GE411T78G视频属性的抓取
# BV号为1GE411T78G的视频属性抓取结束
# 开始BV号为1m7411m7wQ视频属性的抓取
# BV号为1m7411m7wQ的视频属性抓取结束
# 开始BV号为19E411c74D视频属性的抓取
# BV号为19E411c74D的视频属性抓取结束
# 开始BV号为1Z7411C73M视频属性的抓取
# BV号为1Z7411C73M的视频属性抓取结束
# 开始BV号为1UE411V7h5视频属性的抓取
# BV号为1UE411V7h5的视频属性抓取结束
# 开始BV号为1BE411u7jb视频属性的抓取
# BV号为1BE411u7jb的视频属性抓取结束
# 开始BV号为13741197Ge视频属性的抓取
# BV号为13741197Ge的视频属性抓取结束
# 开始BV号为1RE411W7FK视频属性的抓取
# BV号为1RE411W7FK的视频属性抓取结束
# 开始BV号为16e411x77f视频属性的抓取
# BV号为16e411x77f的视频属性抓取结束
# 开始BV号为1dE411u7c6视频属性的抓取
# BV号为1dE411u7c6的视频属性抓取结束
# 开始BV号为1XE411c7TF视频属性的抓取
# BV号为1XE411c7TF的视频属性抓取结束
# 开始BV号为1oE411V729视频属性的抓取
# BV号为1oE411V729的视频属性抓取结束
# 开始BV号为1eE411u7Zw视频属性的抓取
# BV号为1eE411u7Zw的视频属性抓取结束
# 开始BV号为1F7411Z7r5视频属性的抓取
# BV号为1F7411Z7r5的视频属性抓取结束
# 开始BV号为1zE411w7Vv视频属性的抓取
# BV号为1zE411w7Vv的视频属性抓取结束
# 开始BV号为1bp4y117jk视频属性的抓取
# BV号为1bp4y117jk的视频属性抓取结束
# 开始BV号为1u7411o7WZ视频属性的抓取
# BV号为1u7411o7WZ的视频属性抓取结束
# 开始BV号为137411R7y2视频属性的抓取
# BV号为137411R7y2的视频属性抓取结束
# 开始BV号为1TE411W7aF视频属性的抓取
# BV号为1TE411W7aF的视频属性抓取结束
# 开始BV号为1RE411A7UZ视频属性的抓取
# BV号为1RE411A7UZ的视频属性抓取结束
# 开始BV号为1F7411R7pE视频属性的抓取
# BV号为1F7411R7pE的视频属性抓取结束
# 开始BV号为1zE411M7EH视频属性的抓取
# BV号为1zE411M7EH的视频属性抓取结束
# 开始BV号为1kA411b7oo视频属性的抓取
# BV号为1kA411b7oo的视频属性抓取结束
# 开始BV号为1Bp4y1X7NT视频属性的抓取
# BV号为1Bp4y1X7NT的视频属性抓取结束
# 开始BV号为1v54y1d7M3视频属性的抓取
# BV号为1v54y1d7M3的视频属性抓取结束
# 开始BV号为1tK4y1r7VP视频属性的抓取
# BV号为1tK4y1r7VP的视频属性抓取结束
# 开始BV号为1fe411W7XS视频属性的抓取
# BV号为1fe411W7XS的视频属性抓取结束
# 开始BV号为1Fa4y1479F视频属性的抓取
# BV号为1Fa4y1479F的视频属性抓取结束
# 开始BV号为18C4y147Y3视频属性的抓取
# BV号为18C4y147Y3的视频属性抓取结束
# 开始BV号为1ea4y147id视频属性的抓取
# BV号为1ea4y147id的视频属性抓取结束
# 开始BV号为14f4y1S7d7视频属性的抓取
# BV号为14f4y1S7d7的视频属性抓取结束
# 开始BV号为1MC4y1W7tr视频属性的抓取
# BV号为1MC4y1W7tr的视频属性抓取结束
# 开始BV号为19p4y1C7vz视频属性的抓取
# BV号为19p4y1C7vz的视频属性抓取结束
# 开始BV号为1VK411j7CL视频属性的抓取
# BV号为1VK411j7CL的视频属性抓取结束
# 开始BV号为1FK4115764视频属性的抓取
# BV号为1FK4115764的视频属性抓取结束
# 开始BV号为11g4y1z7Xp视频属性的抓取
# BV号为11g4y1z7Xp的视频属性抓取结束
# 开始BV号为1QK411V7vP视频属性的抓取
# BV号为1QK411V7vP的视频属性抓取结束
# 开始BV号为1yA41147r3视频属性的抓取
# BV号为1yA41147r3的视频属性抓取结束
# 开始BV号为1CZ4y1W7uW视频属性的抓取
# BV号为1CZ4y1W7uW的视频属性抓取结束
# 开始BV号为1C64y1M7j1视频属性的抓取
# BV号为1C64y1M7j1的视频属性抓取结束
# 开始BV号为1CC4y1s7yC视频属性的抓取
# BV号为1CC4y1s7yC的视频属性抓取结束
# 开始BV号为1XK411L7ue视频属性的抓取
# BV号为1XK411L7ue的视频属性抓取结束
# 开始BV号为1f54y1X7fJ视频属性的抓取
# BV号为1f54y1X7fJ的视频属性抓取结束
# 开始BV号为1Qz411b7BE视频属性的抓取
# BV号为1Qz411b7BE的视频属性抓取结束
# 开始BV号为1Di4y1b71X视频属性的抓取
# BV号为1Di4y1b71X的视频属性抓取结束
# 开始BV号为1Ya4y147Bv视频属性的抓取
# BV号为1Ya4y147Bv的视频属性抓取结束
# 开始BV号为1CQ4y1K7f4视频属性的抓取
# BV号为1CQ4y1K7f4的视频属性抓取结束
# 开始BV号为1TZ4y147cY视频属性的抓取
# BV号为1TZ4y147cY的视频属性抓取结束
# 开始BV号为1ZC4y1s7ic视频属性的抓取
# BV号为1ZC4y1s7ic的视频属性抓取结束
# 开始BV号为1ai4y187Wi视频属性的抓取
# BV号为1ai4y187Wi的视频属性抓取结束
# 开始BV号为1Hi4y18739视频属性的抓取
# BV号为1Hi4y18739的视频属性抓取结束
# 开始BV号为1it4y1272J视频属性的抓取
# BV号为1it4y1272J的视频属性抓取结束
# 开始BV号为1PQ4y1T78H视频属性的抓取
# BV号为1PQ4y1T78H的视频属性抓取结束
# 开始BV号为11c411h7pv视频属性的抓取
# BV号为11c411h7pv的视频属性抓取结束
# 开始BV号为1GC4y1x7L3视频属性的抓取
# BV号为1GC4y1x7L3的视频属性抓取结束
# 开始BV号为1oi4y1t796视频属性的抓取
# BV号为1oi4y1t796的视频属性抓取结束
# 开始BV号为1j54y1R7hT视频属性的抓取
# BV号为1j54y1R7hT的视频属性抓取结束
# 开始BV号为1P54y197Ke视频属性的抓取
# BV号为1P54y197Ke的视频属性抓取结束
# 开始BV号为1ig4y187qF视频属性的抓取
# BV号为1ig4y187qF的视频属性抓取结束
# 开始BV号为1wV411Z7MY视频属性的抓取
# BV号为1wV411Z7MY的视频属性抓取结束
# 开始BV号为1Mz411z7Pa视频属性的抓取
# BV号为1Mz411z7Pa的视频属性抓取结束
# 开始BV号为1iZ4y1x7mC视频属性的抓取
# BV号为1iZ4y1x7mC的视频属性抓取结束
# 开始BV号为1mk4y197Lp视频属性的抓取
# BV号为1mk4y197Lp的视频属性抓取结束
# 开始BV号为15A411h76r视频属性的抓取
# BV号为15A411h76r的视频属性抓取结束
# 开始BV号为1Nz411z7iF视频属性的抓取
# BV号为1Nz411z7iF的视频属性抓取结束
# 开始BV号为1ZK4y1C7KP视频属性的抓取
# BV号为1ZK4y1C7KP的视频属性抓取结束
# 开始BV号为15A411h7pC视频属性的抓取
# BV号为15A411h7pC的视频属性抓取结束
# 开始BV号为1wt4y127qg视频属性的抓取
# BV号为1wt4y127qg的视频属性抓取结束
# 开始BV号为1ma4y1t742视频属性的抓取
# BV号为1ma4y1t742的视频属性抓取结束
# 开始BV号为1v54y197wk视频属性的抓取
# BV号为1v54y197wk的视频属性抓取结束
# 开始BV号为1xC4y1s7x2视频属性的抓取
# BV号为1xC4y1s7x2的视频属性抓取结束
# 开始BV号为1V54y1R7yZ视频属性的抓取
# 开始BV号为1V54y1R7yZ视频属性的抓取
# BV号为1V54y1R7yZ的视频属性抓取结束
# 开始BV号为1pK4y1k7Lw视频属性的抓取
# BV号为1pK4y1k7Lw的视频属性抓取结束
# 开始BV号为1Ck4y197jS视频属性的抓取
# BV号为1Ck4y197jS的视频属性抓取结束
# 开始BV号为1E64y1T7HG视频属性的抓取
# BV号为1E64y1T7HG的视频属性抓取结束
# 开始BV号为1gV411d7iX视频属性的抓取
# BV号为1gV411d7iX的视频属性抓取结束
# 开始BV号为1di4y1t7EP视频属性的抓取
# BV号为1di4y1t7EP的视频属性抓取结束
# 开始BV号为1hA411b7zS视频属性的抓取
# BV号为1hA411b7zS的视频属性抓取结束
# 开始BV号为1Sa4y1v7tX视频属性的抓取
# BV号为1Sa4y1v7tX的视频属性抓取结束
# 开始BV号为1TK41157Ze视频属性的抓取
# BV号为1TK41157Ze的视频属性抓取结束
# 开始BV号为1e5411x7nu视频属性的抓取
# BV号为1e5411x7nu的视频属性抓取结束
# 开始BV号为1Vt4y1m7Js视频属性的抓取
# BV号为1Vt4y1m7Js的视频属性抓取结束
# 开始BV号为1rK4y1C7JK视频属性的抓取
# BV号为1rK4y1C7JK的视频属性抓取结束
# 开始BV号为1mk4y1r7yM视频属性的抓取
# BV号为1mk4y1r7yM的视频属性抓取结束
# 开始BV号为1jg4y1z7T4视频属性的抓取
# BV号为1jg4y1z7T4的视频属性抓取结束
# 开始BV号为1Ht4y127md视频属性的抓取
# BV号为1Ht4y127md的视频属性抓取结束
# 开始BV号为17a4y1x7b4视频属性的抓取
# BV号为17a4y1x7b4的视频属性抓取结束
# 开始BV号为1Ag4y1a7Vv视频属性的抓取
# BV号为1Ag4y1a7Vv的视频属性抓取结束
# 开始BV号为15C4y1W7LM视频属性的抓取
# BV号为15C4y1W7LM的视频属性抓取结束
# 开始BV号为1Jk4y1R7L6视频属性的抓取
# BV号为1Jk4y1R7L6的视频属性抓取结束
# 开始BV号为1354y1R7fH视频属性的抓取
# BV号为1354y1R7fH的视频属性抓取结束
# 开始BV号为1Pf4y1S7uj视频属性的抓取
# BV号为1Pf4y1S7uj的视频属性抓取结束
# 开始BV号为1aA41187Px视频属性的抓取
# BV号为1aA41187Px的视频属性抓取结束
# 开始BV号为1X54y1Q7n6视频属性的抓取
# BV号为1X54y1Q7n6的视频属性抓取结束
# 开始BV号为12A41147AL视频属性的抓取
# BV号为12A41147AL的视频属性抓取结束
# 开始BV号为1pk4y1R7NV视频属性的抓取
# BV号为1pk4y1R7NV的视频属性抓取结束
# 开始BV号为11A41147jC视频属性的抓取
# BV号为11A41147jC的视频属性抓取结束
# 开始BV号为1XK411V7yg视频属性的抓取
# BV号为1XK411V7yg的视频属性抓取结束
# 开始BV号为1yg4y18734视频属性的抓取
# BV号为1yg4y18734的视频属性抓取结束
# 开始BV号为1Qg4y1z7tv视频属性的抓取
# BV号为1Qg4y1z7tv的视频属性抓取结束
# 开始BV号为1Wz411B7V1视频属性的抓取
# BV号为1Wz411B7V1的视频属性抓取结束
# 开始BV号为1pK4y1b7oh视频属性的抓取
# BV号为1pK4y1b7oh的视频属性抓取结束
# 开始BV号为1Pi4y187iL视频属性的抓取
# BV号为1Pi4y187iL的视频属性抓取结束
# 开始BV号为1Vz411z7zw视频属性的抓取
# BV号为1Vz411z7zw的视频属性抓取结束
# 开始BV号为1nC4y1W7xm视频属性的抓取
# 开始BV号为1nC4y1W7xm视频属性的抓取
# BV号为1nC4y1W7xm的视频属性抓取结束
# 开始BV号为1aZ4y1j7Z6视频属性的抓取
# BV号为1aZ4y1j7Z6的视频属性抓取结束
# 开始BV号为1Ue411s7Hq视频属性的抓取
# BV号为1Ue411s7Hq的视频属性抓取结束
# 开始BV号为1Jt4y1U7Rm视频属性的抓取
# BV号为1Jt4y1U7Rm的视频属性抓取结束
# 开始BV号为1q54y1d7HD视频属性的抓取
# BV号为1q54y1d7HD的视频属性抓取结束
# 开始BV号为1Eg4y1a71p视频属性的抓取
# BV号为1Eg4y1a71p的视频属性抓取结束
# 开始BV号为1xK4y1k72A视频属性的抓取
# BV号为1xK4y1k72A的视频属性抓取结束
# 开始BV号为1eK4y1k7ye视频属性的抓取
# BV号为1eK4y1k7ye的视频属性抓取结束
# 开始BV号为1Rf4y1U7A4视频属性的抓取
# BV号为1Rf4y1U7A4的视频属性抓取结束
# 开始BV号为1G54y197gL视频属性的抓取
# BV号为1G54y197gL的视频属性抓取结束
# 开始BV号为1AT4y137Uj视频属性的抓取
# BV号为1AT4y137Uj的视频属性抓取结束
# 开始BV号为1nK4y1C7bm视频属性的抓取
# BV号为1nK4y1C7bm的视频属性抓取结束
# 开始BV号为1Fa4y147MZ视频属性的抓取
# BV号为1Fa4y147MZ的视频属性抓取结束
# 开始BV号为1pV411o7LE视频属性的抓取
# BV号为1pV411o7LE的视频属性抓取结束
# 开始BV号为1kt4y1y785视频属性的抓取
# BV号为1kt4y1y785的视频属性抓取结束
# 开始BV号为1wz411b7Q8视频属性的抓取
# BV号为1wz411b7Q8的视频属性抓取结束
# 开始BV号为1Dp4y1C7Dv视频属性的抓取
# BV号为1Dp4y1C7Dv的视频属性抓取结束
# 开始BV号为1Z64y1T7za视频属性的抓取
# BV号为1Z64y1T7za的视频属性抓取结束
# 开始BV号为1YZ4y1p7sN视频属性的抓取
# BV号为1YZ4y1p7sN的视频属性抓取结束
# 开始BV号为1jz4y1d7wa视频属性的抓取
# BV号为1jz4y1d7wa的视频属性抓取结束
# 开始BV号为1gK4y1t7Du视频属性的抓取
# BV号为1gK4y1t7Du的视频属性抓取结束
# 开始BV号为1HA411q7dt视频属性的抓取
# BV号为1HA411q7dt的视频属性抓取结束
# 开始BV号为1Sz4y1R7cw视频属性的抓取
# BV号为1Sz4y1R7cw的视频属性抓取结束
# 开始BV号为1E54y1D7Yn视频属性的抓取
# BV号为1E54y1D7Yn的视频属性抓取结束
# 开始BV号为1zC4y1p7Lm视频属性的抓取
# BV号为1zC4y1p7Lm的视频属性抓取结束
# 开始BV号为1sV411C7LG视频属性的抓取
# BV号为1sV411C7LG的视频属性抓取结束
# 开始BV号为1fz4y1R77y视频属性的抓取
# BV号为1fz4y1R77y的视频属性抓取结束
# 开始BV号为1nf4y127nR视频属性的抓取
# BV号为1nf4y127nR的视频属性抓取结束
# 开始BV号为1AK411s7iw视频属性的抓取
# BV号为1AK411s7iw的视频属性抓取结束
# 开始BV号为1Fi4y147xV视频属性的抓取
# BV号为1Fi4y147xV的视频属性抓取结束
# 开始BV号为12t4y117Hu视频属性的抓取
# BV号为12t4y117Hu的视频属性抓取结束
# 开始BV号为1Rg4y1B7rV视频属性的抓取
# BV号为1Rg4y1B7rV的视频属性抓取结束
# 开始BV号为19p4y1Q7VZ视频属性的抓取
# BV号为19p4y1Q7VZ的视频属性抓取结束
# 开始BV号为1sk4y167eJ视频属性的抓取
# BV号为1sk4y167eJ的视频属性抓取结束
# 开始BV号为1HK4y1878u视频属性的抓取
# BV号为1HK4y1878u的视频属性抓取结束
# 开始BV号为17f4y127N5视频属性的抓取
# BV号为17f4y127N5的视频属性抓取结束
# 开始BV号为1w54y1Q748视频属性的抓取
# BV号为1w54y1Q748的视频属性抓取结束
# 开始BV号为1q5411s7Vs视频属性的抓取
# BV号为1q5411s7Vs的视频属性抓取结束
# 开始BV号为1ZV411k7MV视频属性的抓取
# BV号为1ZV411k7MV的视频属性抓取结束
# 开始BV号为1dV411k7yC视频属性的抓取
# BV号为1dV411k7yC的视频属性抓取结束
# 开始BV号为1JK4y1t7uJ视频属性的抓取
# BV号为1JK4y1t7uJ的视频属性抓取结束
# 开始BV号为13A411t7BU视频属性的抓取
# BV号为13A411t7BU的视频属性抓取结束
# 开始BV号为1TK4y187nZ视频属性的抓取
# BV号为1TK4y187nZ的视频属性抓取结束
# 开始BV号为15C4y1p7vg视频属性的抓取
# BV号为15C4y1p7vg的视频属性抓取结束
# 开始BV号为1U54y1D7U5视频属性的抓取
# BV号为1U54y1D7U5的视频属性抓取结束
# 开始BV号为16v411z7mJ视频属性的抓取
# BV号为16v411z7mJ的视频属性抓取结束
# 开始BV号为1Tg4y1B7pT视频属性的抓取
# BV号为1Tg4y1B7pT的视频属性抓取结束
# 开始BV号为1Wz411q7Xc视频属性的抓取
# BV号为1Wz411q7Xc的视频属性抓取结束
# 开始BV号为1ti4y1473v视频属性的抓取
# BV号为1ti4y1473v的视频属性抓取结束
# 开始BV号为1up4y1Q7oT视频属性的抓取
# BV号为1up4y1Q7oT的视频属性抓取结束
# 开始BV号为1bp4y1Q7S5视频属性的抓取
# BV号为1bp4y1Q7S5的视频属性抓取结束
# 开始BV号为1Pz4y197PL视频属性的抓取
# BV号为1Pz4y197PL的视频属性抓取结束
# 开始BV号为1qe411W7r3视频属性的抓取
# BV号为1qe411W7r3的视频属性抓取结束
# 开始BV号为1eV411d7wu视频属性的抓取
# BV号为1eV411d7wu的视频属性抓取结束
# 开始BV号为1Bi4y1s7rS视频属性的抓取
# BV号为1Bi4y1s7rS的视频属性抓取结束
# 开始BV号为1ag4y1i7YS视频属性的抓取
# BV号为1ag4y1i7YS的视频属性抓取结束
# 开始BV号为1Q54y1D7TW视频属性的抓取
# BV号为1Q54y1D7TW的视频属性抓取结束
# 开始BV号为1wQ4y1P7NL视频属性的抓取
# BV号为1wQ4y1P7NL的视频属性抓取结束
# 开始BV号为1xf4y1U7Nq视频属性的抓取
# BV号为1xf4y1U7Nq的视频属性抓取结束
# 开始BV号为1JK411s7oi视频属性的抓取
# BV号为1JK411s7oi的视频属性抓取结束
# 开始BV号为1za4y1i7iZ视频属性的抓取
# BV号为1za4y1i7iZ的视频属性抓取结束
# 开始BV号为1mA411t7k2视频属性的抓取
# BV号为1mA411t7k2的视频属性抓取结束
# 开始BV号为1Wf4y1U7yB视频属性的抓取
# BV号为1Wf4y1U7yB的视频属性抓取结束
# 开始BV号为1vt4y117PB视频属性的抓取
# BV号为1vt4y117PB的视频属性抓取结束
# 开始BV号为1fC4y1H7cA视频属性的抓取
# BV号为1fC4y1H7cA的视频属性抓取结束
# 开始BV号为1ra4y1e7nB视频属性的抓取
# BV号为1ra4y1e7nB的视频属性抓取结束
# 开始BV号为1gk4y167w4视频属性的抓取
# BV号为1gk4y167w4的视频属性抓取结束
# 开始BV号为1LC4y1p7pY视频属性的抓取
# BV号为1LC4y1p7pY的视频属性抓取结束
# 开始BV号为1mt4y1172S视频属性的抓取
# BV号为1mt4y1172S的视频属性抓取结束
# 开始BV号为1ta4y1e7Gt视频属性的抓取
# BV号为1ta4y1e7Gt的视频属性抓取结束
# 开始BV号为1NV411C7U9视频属性的抓取
# BV号为1NV411C7U9的视频属性抓取结束
# 开始BV号为1Wg4y1B7Sf视频属性的抓取
# BV号为1Wg4y1B7Sf的视频属性抓取结束
# 开始BV号为17z4y1d7UA视频属性的抓取
# BV号为17z4y1d7UA的视频属性抓取结束
# 开始BV号为1nf4y127ct视频属性的抓取
# BV号为1nf4y127ct的视频属性抓取结束
# 开始BV号为1RK4y1b7UN视频属性的抓取
# BV号为1RK4y1b7UN的视频属性抓取结束
# 开始BV号为19C4y1W79K视频属性的抓取
# BV号为19C4y1W79K的视频属性抓取结束
# 开始BV号为1Hk4y1r7N4视频属性的抓取
# BV号为1Hk4y1r7N4的视频属性抓取结束
# 开始BV号为18g4y1B79m视频属性的抓取
# BV号为18g4y1B79m的视频属性抓取结束
# 开始BV号为12k4y167sv视频属性的抓取
# BV号为12k4y167sv的视频属性抓取结束
# 开始BV号为1Et4y1C7TA视频属性的抓取
# BV号为1Et4y1C7TA的视频属性抓取结束
# 开始BV号为1zp4y1Q7C1视频属性的抓取
# BV号为1zp4y1Q7C1的视频属性抓取结束
# 开始BV号为1Zf4y11742视频属性的抓取
# BV号为1Zf4y11742的视频属性抓取结束
# 开始BV号为1Yp4y1Q7B4视频属性的抓取
# BV号为1Yp4y1Q7B4的视频属性抓取结束
# 开始BV号为1ok4y1673s视频属性的抓取
# BV号为1ok4y1673s的视频属性抓取结束
# 开始BV号为1GT4y1u7tN视频属性的抓取
# BV号为1GT4y1u7tN的视频属性抓取结束
# 开始BV号为1wK411p7VP视频属性的抓取
# BV号为1wK411p7VP的视频属性抓取结束
# 开始BV号为16f4y1S7cC视频属性的抓取
# BV号为16f4y1S7cC的视频属性抓取结束
# 开始BV号为1yK411W7Hd视频属性的抓取
# BV号为1yK411W7Hd的视频属性抓取结束
# 开始BV号为1Ye411p7XH视频属性的抓取
# BV号为1Ye411p7XH的视频属性抓取结束
# 开始BV号为1Ki4y1b7hB视频属性的抓取
# BV号为1Ki4y1b7hB的视频属性抓取结束
# 开始BV号为1aK411W75T视频属性的抓取
# BV号为1aK411W75T的视频属性抓取结束
# 开始BV号为1Uz4y1R7mW视频属性的抓取
# BV号为1Uz4y1R7mW的视频属性抓取结束
# 开始BV号为11i4y147ah视频属性的抓取
# BV号为11i4y147ah的视频属性抓取结束
# 开始BV号为1hT4y1g7RQ视频属性的抓取
# BV号为1hT4y1g7RQ的视频属性抓取结束
# 开始BV号为1sA411t75S视频属性的抓取
# BV号为1sA411t75S的视频属性抓取结束
# 开始BV号为17V411C7pH视频属性的抓取
# BV号为17V411C7pH的视频属性抓取结束
# 开始BV号为1NV411C7LG视频属性的抓取
# BV号为1NV411C7LG的视频属性抓取结束
# 开始BV号为1nz4y197Uu视频属性的抓取
# BV号为1nz4y197Uu的视频属性抓取结束
# 开始BV号为1ET4y1u7we视频属性的抓取
# BV号为1ET4y1u7we的视频属性抓取结束
# 开始BV号为1jg4y1B777视频属性的抓取
# BV号为1jg4y1B777的视频属性抓取结束
# 开始BV号为1vQ4y1N7CB视频属性的抓取
# BV号为1vQ4y1N7CB的视频属性抓取结束
# 开始BV号为12a4y1i7oz视频属性的抓取
# BV号为12a4y1i7oz的视频属性抓取结束
# 开始BV号为1oK4y147Xq视频属性的抓取
# BV号为1oK4y147Xq的视频属性抓取结束
# 开始BV号为1wC4y1p7bD视频属性的抓取
# BV号为1wC4y1p7bD的视频属性抓取结束
# 开始BV号为1Hg4y1B7Lx视频属性的抓取
# BV号为1Hg4y1B7Lx的视频属性抓取结束
# 开始BV号为1rz411z7nv视频属性的抓取
# BV号为1rz411z7nv的视频属性抓取结束
# 开始BV号为19C4y1H73b视频属性的抓取
# BV号为19C4y1H73b的视频属性抓取结束
# 开始BV号为1ZV411k7o4视频属性的抓取
# BV号为1ZV411k7o4的视频属性抓取结束
# 开始BV号为1ck4y1k7KA视频属性的抓取
# BV号为1ck4y1k7KA的视频属性抓取结束
# 开始BV号为1oV411C7b6视频属性的抓取
# BV号为1oV411C7b6的视频属性抓取结束
# 开始BV号为1nQ4y1P7Dh视频属性的抓取
# BV号为1nQ4y1P7Dh的视频属性抓取结束
# 开始BV号为1VT4y1374T视频属性的抓取
# BV号为1VT4y1374T的视频属性抓取结束
# 开始BV号为16p4y1Q7Zn视频属性的抓取
# BV号为16p4y1Q7Zn的视频属性抓取结束
# 开始BV号为1z5411s7YR视频属性的抓取
# BV号为1z5411s7YR的视频属性抓取结束
# 开始BV号为1Qt4y117by视频属性的抓取
# BV号为1Qt4y117by的视频属性抓取结束
# 开始BV号为1zp4y1Q7BT视频属性的抓取
# BV号为1zp4y1Q7BT的视频属性抓取结束
# 开始BV号为1Pz4y197SM视频属性的抓取
# BV号为1Pz4y197SM的视频属性抓取结束
# 开始BV号为1nK4y1t74Q视频属性的抓取
# BV号为1nK4y1t74Q的视频属性抓取结束
# 开始BV号为1SK4y147fW视频属性的抓取
# BV号为1SK4y147fW的视频属性抓取结束
# 开始BV号为1rz4y197KM视频属性的抓取
# BV号为1rz4y197KM的视频属性抓取结束
# 开始BV号为1Gt4y197NY视频属性的抓取
# BV号为1Gt4y197NY的视频属性抓取结束
# 开始BV号为1Up4y1D7AJ视频属性的抓取
# BV号为1Up4y1D7AJ的视频属性抓取结束
# 开始BV号为1qk4y1z7yy视频属性的抓取
# BV号为1qk4y1z7yy的视频属性抓取结束
# 开始BV号为19f4y1y771视频属性的抓取
# BV号为19f4y1y771的视频属性抓取结束
# 开始BV号为1Xz411e7XQ视频属性的抓取
# BV号为1Xz411e7XQ的视频属性抓取结束
# 开始BV号为1zg4y1q7ff视频属性的抓取
# BV号为1zg4y1q7ff的视频属性抓取结束
# 开始BV号为1Xz4y197rM视频属性的抓取
# BV号为1Xz4y197rM的视频属性抓取结束
# 开始BV号为1bZ4y1W7k5视频属性的抓取
# BV号为1bZ4y1W7k5的视频属性抓取结束
# 开始BV号为18Z4y1W74V视频属性的抓取
# BV号为18Z4y1W74V的视频属性抓取结束
# 开始BV号为1zK411p7xn视频属性的抓取
# BV号为1zK411p7xn的视频属性抓取结束
# 开始BV号为1Zv411q73H视频属性的抓取
# BV号为1Zv411q73H的视频属性抓取结束
# 开始BV号为1ka4y1Y7pi视频属性的抓取
# BV号为1ka4y1Y7pi的视频属性抓取结束
# 开始BV号为1qz411i7mb视频属性的抓取
# BV号为1qz411i7mb的视频属性抓取结束
# 开始BV号为1qf4y117mx视频属性的抓取
# BV号为1qf4y117mx的视频属性抓取结束
# 开始BV号为1Ma4y1e7h1视频属性的抓取
# BV号为1Ma4y1e7h1的视频属性抓取结束
# 开始BV号为1Mt4y19786视频属性的抓取
# BV号为1Mt4y19786的视频属性抓取结束
# 开始BV号为1HT4y177sA视频属性的抓取
# BV号为1HT4y177sA的视频属性抓取结束
# 开始BV号为1rg4y1v7EX视频属性的抓取
# BV号为1rg4y1v7EX的视频属性抓取结束
# 开始BV号为1ji4y1G7gD视频属性的抓取
# BV号为1ji4y1G7gD的视频属性抓取结束
# 开始BV号为1Bz4y1Q7zE视频属性的抓取
# BV号为1Bz4y1Q7zE的视频属性抓取结束
# 开始BV号为1TV411k71o视频属性的抓取
# BV号为1TV411k71o的视频属性抓取结束
# 开始BV号为1TA411i7hS视频属性的抓取
# BV号为1TA411i7hS的视频属性抓取结束
# 开始BV号为1Pz4y1R7go视频属性的抓取
# BV号为1Pz4y1R7go的视频属性抓取结束
# 开始BV号为1SD4y1D7M4视频属性的抓取
# BV号为1SD4y1D7M4的视频属性抓取结束
# 开始BV号为1fv411z73o视频属性的抓取
# BV号为1fv411z73o的视频属性抓取结束
# 开始BV号为1qk4y1q7ds视频属性的抓取
# BV号为1qk4y1q7ds的视频属性抓取结束
# 开始BV号为1Dk4y1z7FC视频属性的抓取
# BV号为1Dk4y1z7FC的视频属性抓取结束
# 开始BV号为16D4y1D7BK视频属性的抓取
# BV号为16D4y1D7BK的视频属性抓取结束
# 开始BV号为1XC4y1875j视频属性的抓取
# BV号为1XC4y1875j的视频属性抓取结束
# 开始BV号为1hZ4y1W7if视频属性的抓取
# BV号为1hZ4y1W7if的视频属性抓取结束
# 开始BV号为1Ug4y1i7TZ视频属性的抓取
# BV号为1Ug4y1i7TZ的视频属性抓取结束
# 开始BV号为12D4y1D7f4视频属性的抓取
# BV号为12D4y1D7f4的视频属性抓取结束
# 开始BV号为1zg4y1q7oR视频属性的抓取
# BV号为1zg4y1q7oR的视频属性抓取结束
# 开始BV号为1ja4y1Y77e视频属性的抓取
# BV号为1ja4y1Y77e的视频属性抓取结束
# 开始BV号为1Cg4y1i7Yb视频属性的抓取
# BV号为1Cg4y1i7Yb的视频属性抓取结束
# 开始BV号为1p54y1Q7CB视频属性的抓取
# BV号为1p54y1Q7CB的视频属性抓取结束
# 开始BV号为1VD4y1Q7Lx视频属性的抓取
# BV号为1VD4y1Q7Lx的视频属性抓取结束
# 开始BV号为1ff4y127Pu视频属性的抓取
# BV号为1ff4y127Pu的视频属性抓取结束
# 开始BV号为1jg4y1q7CB视频属性的抓取
# BV号为1jg4y1q7CB的视频属性抓取结束
# 开始BV号为155411W7qG视频属性的抓取
# BV号为155411W7qG的视频属性抓取结束
# 开始BV号为1pZ4y1H7as视频属性的抓取
# BV号为1pZ4y1H7as的视频属性抓取结束
# 开始BV号为18Z4y1W7X6视频属性的抓取
# BV号为18Z4y1W7X6的视频属性抓取结束
# 开始BV号为1tD4y1Q7ud视频属性的抓取
# BV号为1tD4y1Q7ud的视频属性抓取结束
# 开始BV号为1RC4y1h7Nr视频属性的抓取
# BV号为1RC4y1h7Nr的视频属性抓取结束
# 开始BV号为1ot4y1C71z视频属性的抓取
# BV号为1ot4y1C71z的视频属性抓取结束
# 开始BV号为1aK411p7Bw视频属性的抓取
# BV号为1aK411p7Bw的视频属性抓取结束
# 开始BV号为1bz4y1X7Xq视频属性的抓取
# BV号为1bz4y1X7Xq的视频属性抓取结束
# 开始BV号为1Ng4y1v7gt视频属性的抓取
# BV号为1Ng4y1v7gt的视频属性抓取结束
# 开始BV号为1J5411W7iD视频属性的抓取
# BV号为1J5411W7iD的视频属性抓取结束
# 开始BV号为1nt4y1978o视频属性的抓取
# BV号为1nt4y1978o的视频属性抓取结束
# 开始BV号为17v411B7nT视频属性的抓取
# BV号为17v411B7nT的视频属性抓取结束
# 开始BV号为1Zz4y1Q7Ni视频属性的抓取
# BV号为1Zz4y1Q7Ni的视频属性抓取结束
# 开始BV号为1Et4y1y7cb视频属性的抓取
# BV号为1Et4y1y7cb的视频属性抓取结束
# 开始BV号为1YT4y1J7QE视频属性的抓取
# BV号为1YT4y1J7QE的视频属性抓取结束
# 开始BV号为1qz4y1Q7nj视频属性的抓取
# BV号为1qz4y1Q7nj的视频属性抓取结束
# 开始BV号为1E54y1Q7xB视频属性的抓取
# BV号为1E54y1Q7xB的视频属性抓取结束
# 开始BV号为1Dz4y1Q776视频属性的抓取
# BV号为1Dz4y1Q776的视频属性抓取结束
# 开始BV号为1Cg4y1q7F2视频属性的抓取
# BV号为1Cg4y1q7F2的视频属性抓取结束
# 开始BV号为1gf4y1m7Fh视频属性的抓取
# BV号为1gf4y1m7Fh的视频属性抓取结束
# 开始BV号为1iD4y1D77d视频属性的抓取
# BV号为1iD4y1D77d的视频属性抓取结束
# 开始BV号为1cD4y1Q7pv视频属性的抓取
# BV号为1cD4y1Q7pv的视频属性抓取结束
# 开始BV号为1qz4y1Q7aj视频属性的抓取
# BV号为1qz4y1Q7aj的视频属性抓取结束
# 开始BV号为1oD4y1D76Q视频属性的抓取
# BV号为1oD4y1D76Q的视频属性抓取结束
# 开始BV号为1TK4y147ez视频属性的抓取
# BV号为1TK4y147ez的视频属性抓取结束
# 开始BV号为1jk4y1r71y视频属性的抓取
# BV号为1jk4y1r71y的视频属性抓取结束
# 开始BV号为1DT4y1E7kN视频属性的抓取
# BV号为1DT4y1E7kN的视频属性抓取结束
# 开始BV号为1Zf4y127fc视频属性的抓取
# BV号为1Zf4y127fc的视频属性抓取结束
# 开始BV号为1U5411W7FB视频属性的抓取
# BV号为1U5411W7FB的视频属性抓取结束
# 开始BV号为1Nv41167CD视频属性的抓取
# BV号为1Nv41167CD的视频属性抓取结束
# 开始BV号为1d54y1B7hQ视频属性的抓取
# BV号为1d54y1B7hQ的视频属性抓取结束
# 开始BV号为1Ja4y1Y7d6视频属性的抓取
# BV号为1Ja4y1Y7d6的视频属性抓取结束
# 开始BV号为1tt4y1y7qK视频属性的抓取
# BV号为1tt4y1y7qK的视频属性抓取结束
# 开始BV号为1PA411B7f5视频属性的抓取
# BV号为1PA411B7f5的视频属性抓取结束
# 开始BV号为1cz4y1R7Fk视频属性的抓取
# BV号为1cz4y1R7Fk的视频属性抓取结束
# 开始BV号为1kT4y1E7Z4视频属性的抓取
# BV号为1kT4y1E7Z4的视频属性抓取结束
# 开始BV号为13i4y1x7Te视频属性的抓取
# BV号为13i4y1x7Te的视频属性抓取结束
# 开始BV号为1Sp4y1D7YR视频属性的抓取
# BV号为1Sp4y1D7YR的视频属性抓取结束
# 开始BV号为1Yt4y1y7tu视频属性的抓取
# BV号为1Yt4y1y7tu的视频属性抓取结束
# 开始BV号为13K411H7zx视频属性的抓取
# BV号为13K411H7zx的视频属性抓取结束
# 开始BV号为1xZ4y1H7Gt视频属性的抓取
# BV号为1xZ4y1H7Gt的视频属性抓取结束
# 开始BV号为1sv411B7SP视频属性的抓取
# BV号为1sv411B7SP的视频属性抓取结束
# 开始BV号为1HA411i7vg视频属性的抓取
# BV号为1HA411i7vg的视频属性抓取结束
# 开始BV号为1kT4y1J7Mm视频属性的抓取
# BV号为1kT4y1J7Mm的视频属性抓取结束
# 开始BV号为1zk4y1z7PD视频属性的抓取
# BV号为1zk4y1z7PD的视频属性抓取结束
# 开始BV号为1U54y1B7FZ视频属性的抓取
# BV号为1U54y1B7FZ的视频属性抓取结束
# 开始BV号为1Qg4y1i7FT视频属性的抓取
# BV号为1Qg4y1i7FT的视频属性抓取结束
# 开始BV号为16g4y1i7CG视频属性的抓取
# BV号为16g4y1i7CG的视频属性抓取结束
# 开始BV号为1DK4y1x7Qy视频属性的抓取
# BV号为1DK4y1x7Qy的视频属性抓取结束
# 开始BV号为1eC4y1a7YD视频属性的抓取
# BV号为1eC4y1a7YD的视频属性抓取结束
# 开始BV号为1Q54y1B79B视频属性的抓取
# 开始BV号为1Q54y1B79B视频属性的抓取
# 开始BV号为1Q54y1B79B视频属性的抓取
# BV号为1Q54y1B79B的视频属性抓取结束
# 开始BV号为1N5411Y7nW视频属性的抓取
# BV号为1N5411Y7nW的视频属性抓取结束
# 开始BV号为1gZ4y1H73p视频属性的抓取
# BV号为1gZ4y1H73p的视频属性抓取结束
# 开始BV号为15T4y1J7eS视频属性的抓取
# BV号为15T4y1J7eS的视频属性抓取结束
# 开始BV号为1wg4y1v7De视频属性的抓取
# BV号为1wg4y1v7De的视频属性抓取结束
# 开始BV号为1ot4y1C7bv视频属性的抓取
# BV号为1ot4y1C7bv的视频属性抓取结束
# 开始BV号为1ZZ4y1M7we视频属性的抓取
# BV号为1ZZ4y1M7we的视频属性抓取结束
# 开始BV号为1q5411W7iA视频属性的抓取
# BV号为1q5411W7iA的视频属性抓取结束
# 开始BV号为1rA411i7Dh视频属性的抓取
# BV号为1rA411i7Dh的视频属性抓取结束
# 开始BV号为1Mz4y1X7GL视频属性的抓取
# BV号为1Mz4y1X7GL的视频属性抓取结束
# 开始BV号为1WT4y1E7uQ视频属性的抓取
# BV号为1WT4y1E7uQ的视频属性抓取结束
# 开始BV号为11p4y1S7YV视频属性的抓取
# BV号为11p4y1S7YV的视频属性抓取结束
# 开始BV号为1R5411h7MD视频属性的抓取
# BV号为1R5411h7MD的视频属性抓取结束
# 开始BV号为18v411v7NB视频属性的抓取
# BV号为18v411v7NB的视频属性抓取结束
# 开始BV号为1SZ4y1T7NY视频属性的抓取
# BV号为1SZ4y1T7NY的视频属性抓取结束
# 开始BV号为13C4y1h7hC视频属性的抓取
# BV号为13C4y1h7hC的视频属性抓取结束
# 开始BV号为1HZ4y1u7r8视频属性的抓取
# BV号为1HZ4y1u7r8的视频属性抓取结束
# 开始BV号为1kC4y1h7hJ视频属性的抓取
# BV号为1kC4y1h7hJ的视频属性抓取结束
# 开始BV号为1ya4y1a7tQ视频属性的抓取
# BV号为1ya4y1a7tQ的视频属性抓取结束
# 开始BV号为1Fh411d7st视频属性的抓取
# BV号为1Fh411d7st的视频属性抓取结束
# 开始BV号为1LD4y1S7Jk视频属性的抓取
# BV号为1LD4y1S7Jk的视频属性抓取结束
# 开始BV号为1ri4y1G7dE视频属性的抓取
# 开始BV号为1ri4y1G7dE视频属性的抓取
# BV号为1ri4y1G7dE的视频属性抓取结束
# 开始BV号为1MK411H7jw视频属性的抓取
# BV号为1MK411H7jw的视频属性抓取结束
# 开始BV号为1kD4y1m7bM视频属性的抓取
# BV号为1kD4y1m7bM的视频属性抓取结束
# 开始BV号为1Yp4y1S7U7视频属性的抓取
# BV号为1Yp4y1S7U7的视频属性抓取结束
# 开始BV号为1Ez4y1D7Ru视频属性的抓取
# BV号为1Ez4y1D7Ru的视频属性抓取结束
# 开始BV号为1Qa4y1h7jp视频属性的抓取
# BV号为1Qa4y1h7jp的视频属性抓取结束
# 开始BV号为19z411e7fC视频属性的抓取
# BV号为19z411e7fC的视频属性抓取结束
# 开始BV号为1fp4y1i79S视频属性的抓取
# BV号为1fp4y1i79S的视频属性抓取结束
# 开始BV号为16V411B7Jb视频属性的抓取
# BV号为16V411B7Jb的视频属性抓取结束
# 开始BV号为1HD4y1U7H3视频属性的抓取
# BV号为1HD4y1U7H3的视频属性抓取结束
# 开始BV号为1gp4y1S7Qx视频属性的抓取
# BV号为1gp4y1S7Qx的视频属性抓取结束
# 开始BV号为1Xk4y127SL视频属性的抓取
# BV号为1Xk4y127SL的视频属性抓取结束
# 开始BV号为1oh411R74q视频属性的抓取
# BV号为1oh411R74q的视频属性抓取结束
# 开始BV号为1Yi4y1u7Cc视频属性的抓取
# BV号为1Yi4y1u7Cc的视频属性抓取结束
# 开始BV号为1EC4y1h7k7视频属性的抓取
# BV号为1EC4y1h7k7的视频属性抓取结束
# 开始BV号为1ap4y1S7bq视频属性的抓取
# BV号为1ap4y1S7bq的视频属性抓取结束
# 开始BV号为1iv411i7h6视频属性的抓取
# BV号为1iv411i7h6的视频属性抓取结束
# 开始BV号为1Xa4y1Y7di视频属性的抓取
# BV号为1Xa4y1Y7di的视频属性抓取结束
# 开始BV号为1Yh411o7Eb视频属性的抓取
# BV号为1Yh411o7Eb的视频属性抓取结束
# 开始BV号为1BK411H795视频属性的抓取
# BV号为1BK411H795的视频属性抓取结束
# 开始BV号为1QC4y187xh视频属性的抓取
# BV号为1QC4y187xh的视频属性抓取结束
# 开始BV号为1Gv411z7Q6视频属性的抓取
# BV号为1Gv411z7Q6的视频属性抓取结束
# 开始BV号为1nv411q7GH视频属性的抓取
# BV号为1nv411q7GH的视频属性抓取结束
# 开始BV号为1Pv411z75N视频属性的抓取
# BV号为1Pv411z75N的视频属性抓取结束
# 开始BV号为1gC4y1h7yb视频属性的抓取
# BV号为1gC4y1h7yb的视频属性抓取结束
# 开始BV号为1Vk4y1B7hM视频属性的抓取
# BV号为1Vk4y1B7hM的视频属性抓取结束
# 开始BV号为12C4y1h7mP视频属性的抓取
# BV号为12C4y1h7mP的视频属性抓取结束
# 开始BV号为19V411B7u9视频属性的抓取
# BV号为19V411B7u9的视频属性抓取结束
# 开始BV号为1QZ4y1M7bd视频属性的抓取
# BV号为1QZ4y1M7bd的视频属性抓取结束
# 开始BV号为1DD4y1S7kh视频属性的抓取
# BV号为1DD4y1S7kh的视频属性抓取结束
# 开始BV号为1eh411o7XF视频属性的抓取
# BV号为1eh411o7XF的视频属性抓取结束
# 开始BV号为1qp4y1S7GP视频属性的抓取
# BV号为1qp4y1S7GP的视频属性抓取结束
# 开始BV号为1SD4y1m7SA视频属性的抓取
# BV号为1SD4y1m7SA的视频属性抓取结束
# 开始BV号为1oh411R7WE视频属性的抓取
# BV号为1oh411R7WE的视频属性抓取结束
# 开始BV号为17A411Y7QY视频属性的抓取
# BV号为17A411Y7QY的视频属性抓取结束
# 开始BV号为1A5411e7NM视频属性的抓取
# BV号为1A5411e7NM的视频属性抓取结束
# 开始BV号为1oT4y1774J视频属性的抓取
# BV号为1oT4y1774J的视频属性抓取结束
# 开始BV号为1Ua4y1E737视频属性的抓取
# BV号为1Ua4y1E737的视频属性抓取结束
# 开始BV号为1Bv411i7dU视频属性的抓取
# BV号为1Bv411i7dU的视频属性抓取结束
# 开始BV号为1GZ4y1p7pc视频属性的抓取
# BV号为1GZ4y1p7pc的视频属性抓取结束
# 开始BV号为1sk4y1q7Fo视频属性的抓取
# BV号为1sk4y1q7Fo的视频属性抓取结束
# 开始BV号为1kt4y1Q792视频属性的抓取
# BV号为1kt4y1Q792的视频属性抓取结束
# 开始BV号为1qa4y1E7yy视频属性的抓取
# BV号为1qa4y1E7yy的视频属性抓取结束
# 开始BV号为1WK411J7Fv视频属性的抓取
# BV号为1WK411J7Fv的视频属性抓取结束
# 开始BV号为1xA411e7Gb视频属性的抓取
# BV号为1xA411e7Gb的视频属性抓取结束
# 开始BV号为1rD4y1S79r视频属性的抓取
# BV号为1rD4y1S79r的视频属性抓取结束
# 开始BV号为1g54y1S7j8视频属性的抓取
# BV号为1g54y1S7j8的视频属性抓取结束
# 开始BV号为1hi4y137e6视频属性的抓取
# BV号为1hi4y137e6的视频属性抓取结束
# 开始BV号为1Gt4y1X79r视频属性的抓取
# BV号为1Gt4y1X79r的视频属性抓取结束
# 开始BV号为1wf4y1d7SP视频属性的抓取
# BV号为1wf4y1d7SP的视频属性抓取结束
# 开始BV号为16K4y1e7Yz视频属性的抓取
# BV号为16K4y1e7Yz的视频属性抓取结束
# 开始BV号为1yK4y147M1视频属性的抓取
# BV号为1yK4y147M1的视频属性抓取结束
# 开始BV号为1Z54y1q79T视频属性的抓取
# BV号为1Z54y1q79T的视频属性抓取结束
# 开始BV号为11K411n7Cw视频属性的抓取
# BV号为11K411n7Cw的视频属性抓取结束
# 开始BV号为1RK411n7N4视频属性的抓取
# BV号为1RK411n7N4的视频属性抓取结束
# 开始BV号为1La4y1a7Yp视频属性的抓取
# BV号为1La4y1a7Yp的视频属性抓取结束
# 开始BV号为1dA411e7yx视频属性的抓取
# BV号为1dA411e7yx的视频属性抓取结束
# 开始BV号为1Sz4y1X7zt视频属性的抓取
# BV号为1Sz4y1X7zt的视频属性抓取结束
# 开始BV号为14A411i7Di视频属性的抓取
# BV号为14A411i7Di的视频属性抓取结束
# 开始BV号为1ez411v7Sn视频属性的抓取
# BV号为1ez411v7Sn的视频属性抓取结束
# 开始BV号为1sA411v7xs视频属性的抓取
# BV号为1sA411v7xs的视频属性抓取结束
# 开始BV号为1YC4y187F7视频属性的抓取
# BV号为1YC4y187F7的视频属性抓取结束
# 开始BV号为1sK4y1v76m视频属性的抓取
# BV号为1sK4y1v76m的视频属性抓取结束
# 开始BV号为1eZ4y1u7Xb视频属性的抓取
# BV号为1eZ4y1u7Xb的视频属性抓取结束
# 开始BV号为1fC4y1b7Py视频属性的抓取
# BV号为1fC4y1b7Py的视频属性抓取结束
# 开始BV号为1Kz411v7AJ视频属性的抓取
# BV号为1Kz411v7AJ的视频属性抓取结束
# 开始BV号为1JK4y1s7u2视频属性的抓取
# BV号为1JK4y1s7u2的视频属性抓取结束
# 开始BV号为1kV411B7ef视频属性的抓取
# BV号为1kV411B7ef的视频属性抓取结束
# 开始BV号为1QD4y1S7KP视频属性的抓取
# BV号为1QD4y1S7KP的视频属性抓取结束
# 开始BV号为1gT4y1E7GF视频属性的抓取
# BV号为1gT4y1E7GF的视频属性抓取结束
# 开始BV号为1iZ4y1u7dV视频属性的抓取
# BV号为1iZ4y1u7dV的视频属性抓取结束
# 开始BV号为1Up4y1i75T视频属性的抓取
# BV号为1Up4y1i75T的视频属性抓取结束
# 开始BV号为17C4y1h7Vo视频属性的抓取
# BV号为17C4y1h7Vo的视频属性抓取结束
# 开始BV号为1TK411H71J视频属性的抓取
# BV号为1TK411H71J的视频属性抓取结束
# 开始BV号为1r54y1q7os视频属性的抓取
# BV号为1r54y1q7os的视频属性抓取结束
# 开始BV号为17g4y1v7QU视频属性的抓取
# BV号为17g4y1v7QU的视频属性抓取结束
# 开始BV号为1v54y1v7bo视频属性的抓取
# BV号为1v54y1v7bo的视频属性抓取结束
# 开始BV号为1Bi4y137hw视频属性的抓取
# BV号为1Bi4y137hw的视频属性抓取结束
# 开始BV号为1it4y1Q7BZ视频属性的抓取
# BV号为1it4y1Q7BZ的视频属性抓取结束
# 开始BV号为1uD4y1D7er视频属性的抓取
# BV号为1uD4y1D7er的视频属性抓取结束
# 开始BV号为1vC4y1h75g视频属性的抓取
# BV号为1vC4y1h75g的视频属性抓取结束
# 开始BV号为1iv411i7yH视频属性的抓取
# BV号为1iv411i7yH的视频属性抓取结束
# 开始BV号为1rv411i7Vk视频属性的抓取
# BV号为1rv411i7Vk的视频属性抓取结束
# 开始BV号为1Wi4y1V7Ce视频属性的抓取
# BV号为1Wi4y1V7Ce的视频属性抓取结束
# 开始BV号为1o5411h73r视频属性的抓取
# BV号为1o5411h73r的视频属性抓取结束
# 开始BV号为1CK411J7kh视频属性的抓取
# BV号为1CK411J7kh的视频属性抓取结束
# 开始BV号为15g4y1i7nf视频属性的抓取
# BV号为15g4y1i7nf的视频属性抓取结束
# 开始BV号为1Z54y1v7Xt视频属性的抓取
# BV号为1Z54y1v7Xt的视频属性抓取结束
# 开始BV号为1Y54y1U73i视频属性的抓取
# BV号为1Y54y1U73i的视频属性抓取结束
# 开始BV号为1MV411U7Rj视频属性的抓取
# BV号为1MV411U7Rj的视频属性抓取结束
# 开始BV号为1vK411T7HG视频属性的抓取
# BV号为1vK411T7HG的视频属性抓取结束
# 开始BV号为1tZ4y1M7Pu视频属性的抓取
# BV号为1tZ4y1M7Pu的视频属性抓取结束
# 开始BV号为1uf4y1d7qF视频属性的抓取
# BV号为1uf4y1d7qF的视频属性抓取结束
# 开始BV号为1zt4y1U7ht视频属性的抓取
# BV号为1zt4y1U7ht的视频属性抓取结束
# 开始BV号为1uT4y177Lg视频属性的抓取
# BV号为1uT4y177Lg的视频属性抓取结束
# 开始BV号为1CT4y1L7f3视频属性的抓取
# BV号为1CT4y1L7f3的视频属性抓取结束
# 开始BV号为1cT4y1L7D1视频属性的抓取
# BV号为1cT4y1L7D1的视频属性抓取结束
# 开始BV号为19f4y1X7NW视频属性的抓取
# BV号为19f4y1X7NW的视频属性抓取结束
# 开始BV号为12y4y1C7dw视频属性的抓取
# BV号为12y4y1C7dw的视频属性抓取结束
# 开始BV号为1qK411T7U5视频属性的抓取
# BV号为1qK411T7U5的视频属性抓取结束
# 开始BV号为1Nk4y12754视频属性的抓取
# BV号为1Nk4y12754的视频属性抓取结束
# 开始BV号为1hZ4y1M7JH视频属性的抓取
# BV号为1hZ4y1M7JH的视频属性抓取结束
# 开始BV号为1Hv41117C4视频属性的抓取
# BV号为1Hv41117C4的视频属性抓取结束
# 开始BV号为1p5411h77y视频属性的抓取
# BV号为1p5411h77y的视频属性抓取结束
# 开始BV号为13T4y177Bf视频属性的抓取
# BV号为13T4y177Bf的视频属性抓取结束
# 开始BV号为1Z64y1F7Zp视频属性的抓取
# BV号为1Z64y1F7Zp的视频属性抓取结束
# 开始BV号为1iK4y1v7Xb视频属性的抓取
# BV号为1iK4y1v7Xb的视频属性抓取结束
# 开始BV号为1xa4y177eE视频属性的抓取
# BV号为1xa4y177eE的视频属性抓取结束
# 开始BV号为1vT4y157B5视频属性的抓取
# BV号为1vT4y157B5的视频属性抓取结束
# 开始BV号为12K4y1Y7e9视频属性的抓取
# BV号为12K4y1Y7e9的视频属性抓取结束
# 开始BV号为1xZ4y1M72t视频属性的抓取
# BV号为1xZ4y1M72t的视频属性抓取结束
# 开始BV号为1SV411U73u视频属性的抓取
# BV号为1SV411U73u的视频属性抓取结束
# 开始BV号为1kT4y1j7Hm视频属性的抓取
# BV号为1kT4y1j7Hm的视频属性抓取结束
# 开始BV号为1Ak4y1U7tJ视频属性的抓取
# BV号为1Ak4y1U7tJ的视频属性抓取结束
# 开始BV号为1Qk4y1m7XS视频属性的抓取
# BV号为1Qk4y1m7XS的视频属性抓取结束
# 开始BV号为145411h7b9视频属性的抓取
# BV号为145411h7b9的视频属性抓取结束
# 开始BV号为1kV411z7nB视频属性的抓取
# BV号为1kV411z7nB的视频属性抓取结束
# 开始BV号为1MA411n7GA视频属性的抓取
# BV号为1MA411n7GA的视频属性抓取结束
# 开始BV号为17C4y1t7Uk视频属性的抓取
# BV号为17C4y1t7Uk的视频属性抓取结束
# 开始BV号为1Pk4y127N6视频属性的抓取
# BV号为1Pk4y127N6的视频属性抓取结束
# 开始BV号为13f4y197wA视频属性的抓取
# BV号为13f4y197wA的视频属性抓取结束
# 开始BV号为16p4y1v7LC视频属性的抓取
# BV号为16p4y1v7LC的视频属性抓取结束
# 开始BV号为1Za4y1E7JK视频属性的抓取
# BV号为1Za4y1E7JK的视频属性抓取结束
# 开始BV号为1EC4y1t75b视频属性的抓取
# BV号为1EC4y1t75b的视频属性抓取结束
# 开始BV号为1qp4y1q7gg视频属性的抓取
# BV号为1qp4y1q7gg的视频属性抓取结束
# 开始BV号为1ET4y1L7vZ视频属性的抓取
# BV号为1ET4y1L7vZ的视频属性抓取结束
# 开始BV号为1YC4y1t7B7视频属性的抓取
# BV号为1YC4y1t7B7的视频属性抓取结束
# 开始BV号为1ha4y177LU视频属性的抓取
# BV号为1ha4y177LU的视频属性抓取结束
# 开始BV号为1A54y1U7o4视频属性的抓取
# BV号为1A54y1U7o4的视频属性抓取结束
# 开始BV号为1Kv41117av视频属性的抓取
# BV号为1Kv41117av的视频属性抓取结束
# 开始BV号为1oz4y1f7gb视频属性的抓取
# BV号为1oz4y1f7gb的视频属性抓取结束
# 开始BV号为1mC4y147Je视频属性的抓取
# BV号为1mC4y147Je的视频属性抓取结束
# 开始BV号为1N64y1c7pH视频属性的抓取
# BV号为1N64y1c7pH的视频属性抓取结束
# 开始BV号为1Ei4y1g7HP视频属性的抓取
# BV号为1Ei4y1g7HP的视频属性抓取结束
# 开始BV号为1Xi4y1g7Po视频属性的抓取
# BV号为1Xi4y1g7Po的视频属性抓取结束
# 开始BV号为1k54y1m75t视频属性的抓取
# BV号为1k54y1m75t的视频属性抓取结束
# 开始BV号为1iv411v7NX视频属性的抓取
# BV号为1iv411v7NX的视频属性抓取结束
# 开始BV号为1M54y1v7Bq视频属性的抓取
# BV号为1M54y1v7Bq的视频属性抓取结束
# 开始BV号为15C4y187mq视频属性的抓取
# BV号为15C4y187mq的视频属性抓取结束
# 开始BV号为1qh411d7W3视频属性的抓取
# BV号为1qh411d7W3的视频属性抓取结束
# 开始BV号为1ch411o7Nk视频属性的抓取
# BV号为1ch411o7Nk的视频属性抓取结束
# 开始BV号为1Ft4y1S7T3视频属性的抓取
# BV号为1Ft4y1S7T3的视频属性抓取结束
# 开始BV号为13Z4y1K7mg视频属性的抓取
# BV号为13Z4y1K7mg的视频属性抓取结束
# 开始BV号为1gV411z7Hc视频属性的抓取
# BV号为1gV411z7Hc的视频属性抓取结束
# 开始BV号为18z4y1f7Z3视频属性的抓取
# BV号为18z4y1f7Z3的视频属性抓取结束
# 开始BV号为16C4y1b7vC视频属性的抓取
# BV号为16C4y1b7vC的视频属性抓取结束
# 开始BV号为1yV41127xg视频属性的抓取
# BV号为1yV41127xg的视频属性抓取结束
# 开始BV号为1Bv411y7yo视频属性的抓取
# BV号为1Bv411y7yo的视频属性抓取结束
# 开始BV号为1hA411n7BY视频属性的抓取
# BV号为1hA411n7BY的视频属性抓取结束
# 开始BV号为15C4y1t7Xx视频属性的抓取
# BV号为15C4y1t7Xx的视频属性抓取结束
# 开始BV号为1Qf4y1972b视频属性的抓取
# BV号为1Qf4y1972b的视频属性抓取结束
# 开始BV号为1N54y1D7TM视频属性的抓取
# BV号为1N54y1D7TM的视频属性抓取结束
# 开始BV号为1QA411n7uj视频属性的抓取
# BV号为1QA411n7uj的视频属性抓取结束
# 开始BV号为1FK411K7BT视频属性的抓取
# BV号为1FK411K7BT的视频属性抓取结束
# 开始BV号为1x64y1c7iT视频属性的抓取
# BV号为1x64y1c7iT的视频属性抓取结束
# 开始BV号为1mv411y7bS视频属性的抓取
# BV号为1mv411y7bS的视频属性抓取结束
# 开始BV号为1pV411U7qL视频属性的抓取
# BV号为1pV411U7qL的视频属性抓取结束
# 开始BV号为14Z4y1M7R5视频属性的抓取
# BV号为14Z4y1M7R5的视频属性抓取结束
# 开始BV号为13K411T734视频属性的抓取
# BV号为13K411T734的视频属性抓取结束
# 开始BV号为1zK4y1v7jX视频属性的抓取
# BV号为1zK4y1v7jX的视频属性抓取结束
# 开始BV号为1jK4y1Y7LU视频属性的抓取
# BV号为1jK4y1Y7LU的视频属性抓取结束
# 开始BV号为1ZT4y157e8视频属性的抓取
# BV号为1ZT4y157e8的视频属性抓取结束
# 开始BV号为1WT4y1L7do视频属性的抓取
# BV号为1WT4y1L7do的视频属性抓取结束
# 开始BV号为16f4y1979V视频属性的抓取
# BV号为16f4y1979V的视频属性抓取结束
# 开始BV号为1wf4y1X7wL视频属性的抓取
# BV号为1wf4y1X7wL的视频属性抓取结束
# 开始BV号为1Gf4y197Kz视频属性的抓取
# BV号为1Gf4y197Kz的视频属性抓取结束
# 开始BV号为1L64y1c7XF视频属性的抓取
# BV号为1L64y1c7XF的视频属性抓取结束
# 开始BV号为1qV411U7AD视频属性的抓取
# BV号为1qV411U7AD的视频属性抓取结束
# 开始BV号为19v411v7AK视频属性的抓取
# BV号为19v411v7AK的视频属性抓取结束
# 开始BV号为1Rt4y1U7Mt视频属性的抓取
# BV号为1Rt4y1U7Mt的视频属性抓取结束
# 开始BV号为1oT4y1j7UN视频属性的抓取
# BV号为1oT4y1j7UN的视频属性抓取结束
# 开始BV号为1GD4y1m7Gc视频属性的抓取
# BV号为1GD4y1m7Gc的视频属性抓取结束
# 开始BV号为18541187ud视频属性的抓取
# BV号为18541187ud的视频属性抓取结束
# 开始BV号为1wT4y1L7EA视频属性的抓取
# BV号为1wT4y1L7EA的视频属性抓取结束
# 开始BV号为1zT4y157oD视频属性的抓取
# BV号为1zT4y157oD的视频属性抓取结束
# 开始BV号为1gA411e7yd视频属性的抓取
# BV号为1gA411e7yd的视频属性抓取结束
# 开始BV号为1Ki4y1G7ed视频属性的抓取
# BV号为1Ki4y1G7ed的视频属性抓取结束
# 开始BV号为1iv411v7vf视频属性的抓取
# BV号为1iv411v7vf的视频属性抓取结束
# 开始BV号为1ZK4y1Y7bH视频属性的抓取
# BV号为1ZK4y1Y7bH的视频属性抓取结束
# 开始BV号为1b54y1i7bQ视频属性的抓取
# BV号为1b54y1i7bQ的视频属性抓取结束
# 开始BV号为14h411d7gC视频属性的抓取
# BV号为14h411d7gC的视频属性抓取结束
# 开始BV号为1Vi4y1g7CW视频属性的抓取
# BV号为1Vi4y1g7CW的视频属性抓取结束
# 开始BV号为1oh411d7eY视频属性的抓取
# BV号为1oh411d7eY的视频属性抓取结束
# 开始BV号为1MK411M7ye视频属性的抓取
# BV号为1MK411M7ye的视频属性抓取结束
# 开始BV号为1Sf4y1X7mt视频属性的抓取
# BV号为1Sf4y1X7mt的视频属性抓取结束
# 开始BV号为1j64y1c7Gv视频属性的抓取
# BV号为1j64y1c7Gv的视频属性抓取结束
# 开始BV号为17f4y197FT视频属性的抓取
# BV号为17f4y197FT的视频属性抓取结束
# 开始BV号为1Hv411v7Qp视频属性的抓取
# BV号为1Hv411v7Qp的视频属性抓取结束
# 开始BV号为1ct4y1S7Br视频属性的抓取
# BV号为1ct4y1S7Br的视频属性抓取结束
# 开始BV号为1J54y1k7Jr视频属性的抓取
# BV号为1J54y1k7Jr的视频属性抓取结束
# 开始BV号为1Ni4y1E7hJ视频属性的抓取
# BV号为1Ni4y1E7hJ的视频属性抓取结束
# 开始BV号为1jy4y1y7WQ视频属性的抓取
# BV号为1jy4y1y7WQ的视频属性抓取结束
# 开始BV号为15K411K7Mf视频属性的抓取
# BV号为15K411K7Mf的视频属性抓取结束
# 开始BV号为1xK4y1a7vD视频属性的抓取
# BV号为1xK4y1a7vD的视频属性抓取结束
# 开始BV号为1pi4y1E7gW视频属性的抓取
# BV号为1pi4y1E7gW的视频属性抓取结束
# 开始BV号为1TV411S7xy视频属性的抓取
# BV号为1TV411S7xy的视频属性抓取结束
# 开始BV号为1x54y1m7Hg视频属性的抓取
# BV号为1x54y1m7Hg的视频属性抓取结束
# 开始BV号为1hv411y7W9视频属性的抓取
# BV号为1hv411y7W9的视频属性抓取结束
# 开始BV号为1Sy4y1y7Xc视频属性的抓取
# BV号为1Sy4y1y7Xc的视频属性抓取结束
# 开始BV号为1864y1F7Ks视频属性的抓取
# BV号为1864y1F7Ks的视频属性抓取结束
# 开始BV号为1sa4y1E7yB视频属性的抓取
# BV号为1sa4y1E7yB的视频属性抓取结束
# 开始BV号为1ny4y1y7Gh视频属性的抓取
# BV号为1ny4y1y7Gh的视频属性抓取结束
# 开始BV号为12K411K7Yh视频属性的抓取
# BV号为12K411K7Yh的视频属性抓取结束
# 开始BV号为1TV411278d视频属性的抓取
# BV号为1TV411278d的视频属性抓取结束
# 开始BV号为1mv411C7ZE视频属性的抓取
# BV号为1mv411C7ZE的视频属性抓取结束
# 开始BV号为1ti4y1u7yo视频属性的抓取
# BV号为1ti4y1u7yo的视频属性抓取结束
# 开始BV号为1rt4y1S7Ap视频属性的抓取
# BV号为1rt4y1S7Ap的视频属性抓取结束
# 开始BV号为1dy4y1y71H视频属性的抓取
# BV号为1dy4y1y71H的视频属性抓取结束
# 开始BV号为1y5411b77k视频属性的抓取
# BV号为1y5411b77k的视频属性抓取结束
# 开始BV号为1ca4y1E7ho视频属性的抓取
# BV号为1ca4y1E7ho的视频属性抓取结束
# 开始BV号为1XZ4y1P7fU视频属性的抓取
# BV号为1XZ4y1P7fU的视频属性抓取结束
# 开始BV号为1Xy4y1y7pE视频属性的抓取
# BV号为1Xy4y1y7pE的视频属性抓取结束
# 开始BV号为17v411C7KB视频属性的抓取
# BV号为17v411C7KB的视频属性抓取结束
# 开始BV号为17i4y1u7jV视频属性的抓取
# BV号为17i4y1u7jV的视频属性抓取结束
# 开始BV号为1mv41117Ci视频属性的抓取
# BV号为1mv41117Ci的视频属性抓取结束
# 开始BV号为16z4y1Z7ak视频属性的抓取
# BV号为16z4y1Z7ak的视频属性抓取结束
# 开始BV号为1n54y1y7L4视频属性的抓取
# BV号为1n54y1y7L4的视频属性抓取结束
# 开始BV号为1Up4y1a7uW视频属性的抓取
# BV号为1Up4y1a7uW的视频属性抓取结束
# 开始BV号为1Tt4y1q7Qs视频属性的抓取
# BV号为1Tt4y1q7Qs的视频属性抓取结束
# 开始BV号为1kT4y1A7bm视频属性的抓取
# BV号为1kT4y1A7bm的视频属性抓取结束
# 开始BV号为1tD4y1o7wS视频属性的抓取
# BV号为1tD4y1o7wS的视频属性抓取结束
# 开始BV号为19i4y177Sr视频属性的抓取
# BV号为19i4y177Sr的视频属性抓取结束
# 开始BV号为1wz4y1Z7kp视频属性的抓取
# BV号为1wz4y1Z7kp的视频属性抓取结束
# 开始BV号为14K411P72h视频属性的抓取
# BV号为14K411P72h的视频属性抓取结束
# 开始BV号为1YK411P7oC视频属性的抓取
# BV号为1YK411P7oC的视频属性抓取结束
# 开始BV号为1zV411m74r视频属性的抓取
# BV号为1zV411m74r的视频属性抓取结束
# 开始BV号为1HA411J7ky视频属性的抓取
# BV号为1HA411J7ky的视频属性抓取结束
# 开始BV号为1xK411P7kE视频属性的抓取
# BV号为1xK411P7kE的视频属性抓取结束
# 开始BV号为1W54y127G2视频属性的抓取
# BV号为1W54y127G2的视频属性抓取结束
# 开始BV号为1ED4y1o74A视频属性的抓取
# BV号为1ED4y1o74A的视频属性抓取结束
# 开始BV号为13t4y1q7sm视频属性的抓取
# BV号为13t4y1q7sm的视频属性抓取结束
# 开始BV号为1At4y1q7hB视频属性的抓取
# BV号为1At4y1q7hB的视频属性抓取结束
# 开始BV号为1Yp4y1e7Jc视频属性的抓取
# BV号为1Yp4y1e7Jc的视频属性抓取结束
# 开始BV号为1Kk4y117Ax视频属性的抓取
# BV号为1Kk4y117Ax的视频属性抓取结束
# 开始BV号为1jk4y1177a视频属性的抓取
# BV号为1jk4y1177a的视频属性抓取结束
# 开始BV号为1uK4y1a7fU视频属性的抓取
# BV号为1uK4y1a7fU的视频属性抓取结束
# 开始BV号为1fK411K7Qx视频属性的抓取
# BV号为1fK411K7Qx的视频属性抓取结束
# 开始BV号为1u54y1m7fx视频属性的抓取
# BV号为1u54y1m7fx的视频属性抓取结束
# 开始BV号为16z4y1Z7ZP视频属性的抓取
# BV号为16z4y1Z7ZP的视频属性抓取结束
# 开始BV号为1Vi4y1u7tp视频属性的抓取
# BV号为1Vi4y1u7tp的视频属性抓取结束
# 开始BV号为1J54y117p3视频属性的抓取
# BV号为1J54y117p3的视频属性抓取结束
# 开始BV号为1L5411j7eA视频属性的抓取
# BV号为1L5411j7eA的视频属性抓取结束
# 开始BV号为1na4y1j765视频属性的抓取
# BV号为1na4y1j765的视频属性抓取结束
# 开始BV号为1MK4y1Y7hN视频属性的抓取
# BV号为1MK4y1Y7hN的视频属性抓取结束
# 开始BV号为1bV41117Ji视频属性的抓取
# BV号为1bV41117Ji的视频属性抓取结束
# 开始BV号为1Ca4y1775T视频属性的抓取
# BV号为1Ca4y1775T的视频属性抓取结束
# 开始BV号为1jZ4y1T79Z视频属性的抓取
# BV号为1jZ4y1T79Z的视频属性抓取结束
# 开始BV号为1ah411R7ZM视频属性的抓取
# BV号为1ah411R7ZM的视频属性抓取结束
# 开始BV号为1qh411R7yw视频属性的抓取
# BV号为1qh411R7yw的视频属性抓取结束
# 开始BV号为1p54y1v7wM视频属性的抓取
# BV号为1p54y1v7wM的视频属性抓取结束
# 开始BV号为1Ef4y1D7nw视频属性的抓取
# BV号为1Ef4y1D7nw的视频属性抓取结束
# 开始BV号为1qz4y1Z71Y视频属性的抓取
# BV号为1qz4y1Z71Y的视频属性抓取结束
# 开始BV号为1Hy4y1y7Qq视频属性的抓取
# BV号为1Hy4y1y7Qq的视频属性抓取结束
# 开始BV号为1i54y1C74m视频属性的抓取
# BV号为1i54y1C74m的视频属性抓取结束
# 开始BV号为1qz4y1Z7oW视频属性的抓取
# BV号为1qz4y1Z7oW的视频属性抓取结束
# 开始BV号为16h411X7M8视频属性的抓取
# BV号为16h411X7M8的视频属性抓取结束
# 开始BV号为1H54y1m7Bv视频属性的抓取
# BV号为1H54y1m7Bv的视频属性抓取结束
# 开始BV号为1sy4y1y7R3视频属性的抓取
# BV号为1sy4y1y7R3的视频属性抓取结束
# 开始BV号为1n5411876o视频属性的抓取
# BV号为1n5411876o的视频属性抓取结束
# 开始BV号为1yi4y1M7Q3视频属性的抓取
# BV号为1yi4y1M7Q3的视频属性抓取结束
# 开始BV号为1EZ4y157Jn视频属性的抓取
# BV号为1EZ4y157Jn的视频属性抓取结束
# 开始BV号为1VK411K7DJ视频属性的抓取
# BV号为1VK411K7DJ的视频属性抓取结束
# 开始BV号为1UK411N7Qv视频属性的抓取
# BV号为1UK411N7Qv的视频属性抓取结束
# 开始BV号为1zf4y1D7QE视频属性的抓取
# BV号为1zf4y1D7QE的视频属性抓取结束
# 开始BV号为1P5411j7Yx视频属性的抓取
# BV号为1P5411j7Yx的视频属性抓取结束
# 开始BV号为1Di4y1M7cZ视频属性的抓取
# BV号为1Di4y1M7cZ的视频属性抓取结束
# 开始BV号为1U54y1C7Tw视频属性的抓取
# BV号为1U54y1C7Tw的视频属性抓取结束
# 开始BV号为1FV411U7gr视频属性的抓取
# BV号为1FV411U7gr的视频属性抓取结束
# 开始BV号为1zz4y1Z7E4视频属性的抓取
# BV号为1zz4y1Z7E4的视频属性抓取结束
# 开始BV号为1KA411H7kk视频属性的抓取
# BV号为1KA411H7kk的视频属性抓取结束
# 开始BV号为17Z4y157nZ视频属性的抓取
# BV号为17Z4y157nZ的视频属性抓取结束
# 开始BV号为1J54y117zZ视频属性的抓取
# BV号为1J54y117zZ的视频属性抓取结束
# 开始BV号为1Yv41117E2视频属性的抓取
# BV号为1Yv41117E2的视频属性抓取结束
# 开始BV号为1Df4y1D725视频属性的抓取
# BV号为1Df4y1D725的视频属性抓取结束
# 开始BV号为15T4y1c7Ms视频属性的抓取
# BV号为15T4y1c7Ms的视频属性抓取结束
# 开始BV号为1jK4y1a7ss视频属性的抓取
# BV号为1jK4y1a7ss的视频属性抓取结束
# 开始BV号为1rA411J7dc视频属性的抓取
# BV号为1rA411J7dc的视频属性抓取结束
# 开始BV号为1sV411m7M5视频属性的抓取
# BV号为1sV411m7M5的视频属性抓取结束
# 开始BV号为1qy4y1k7uR视频属性的抓取
# BV号为1qy4y1k7uR的视频属性抓取结束
# 开始BV号为17Z4y1N7VH视频属性的抓取
# BV号为17Z4y1N7VH的视频属性抓取结束
# 开始BV号为16T4y1c7NE视频属性的抓取
# BV号为16T4y1c7NE的视频属性抓取结束
# 开始BV号为1354y1m7xs视频属性的抓取
# BV号为1354y1m7xs的视频属性抓取结束
# 开始BV号为1hZ4y1N7K1视频属性的抓取
# BV号为1hZ4y1N7K1的视频属性抓取结束
# 开始BV号为1HD4y1o7pa视频属性的抓取
# BV号为1HD4y1o7pa的视频属性抓取结束
# 开始BV号为1az4y1Z7fd视频属性的抓取
# BV号为1az4y1Z7fd的视频属性抓取结束
# 开始BV号为1uz4y1Z7ac视频属性的抓取
# BV号为1uz4y1Z7ac的视频属性抓取结束
# 开始BV号为1MT4y1A7S8视频属性的抓取
# BV号为1MT4y1A7S8的视频属性抓取结束
# 开始BV号为1Gk4y117X2视频属性的抓取
# BV号为1Gk4y117X2的视频属性抓取结束
# 开始BV号为1wA411E7Jr视频属性的抓取
# BV号为1wA411E7Jr的视频属性抓取结束
# 开始BV号为1ND4y1d7Xj视频属性的抓取
# BV号为1ND4y1d7Xj的视频属性抓取结束
# 开始BV号为1VV411y7hJ视频属性的抓取
# BV号为1VV411y7hJ的视频属性抓取结束
# 开始BV号为1jV41127Qu视频属性的抓取
# BV号为1jV41127Qu的视频属性抓取结束
# 开始BV号为1zk4y1C72J视频属性的抓取
# BV号为1zk4y1C72J的视频属性抓取结束
# 开始BV号为1NV411y7Uk视频属性的抓取
# BV号为1NV411y7Uk的视频属性抓取结束
# 开始BV号为1dZ4y1G71B视频属性的抓取
# BV号为1dZ4y1G71B的视频属性抓取结束
# 开始BV号为1La4y1s7At视频属性的抓取
# BV号为1La4y1s7At的视频属性抓取结束
# 开始BV号为1JV411y7Zm视频属性的抓取
# BV号为1JV411y7Zm的视频属性抓取结束
# 开始BV号为1VT4y1w7Ar视频属性的抓取
# BV号为1VT4y1w7Ar的视频属性抓取结束
# 开始BV号为18f4y1i7Yi视频属性的抓取
# BV号为18f4y1i7Yi的视频属性抓取结束
# 开始BV号为1Az4y1f7oV视频属性的抓取
# BV号为1Az4y1f7oV的视频属性抓取结束
# 开始BV号为1zK4y1h7w7视频属性的抓取
# BV号为1zK4y1h7w7的视频属性抓取结束
# 开始BV号为1tp4y1Y7ME视频属性的抓取
# BV号为1tp4y1Y7ME的视频属性抓取结束
# 开始BV号为1ui4y177ss视频属性的抓取
# BV号为1ui4y177ss的视频属性抓取结束
# 开始BV号为1Ff4y1B73i视频属性的抓取
# BV号为1Ff4y1B73i的视频属性抓取结束
# 开始BV号为1qi4y1E7gq视频属性的抓取
# BV号为1qi4y1E7gq的视频属性抓取结束
# 开始BV号为1Z54y1k79Z视频属性的抓取
# BV号为1Z54y1k79Z的视频属性抓取结束
# 开始BV号为1na4y1L75g视频属性的抓取
# BV号为1na4y1L75g的视频属性抓取结束
# 开始BV号为1vK411A7Wa视频属性的抓取
# BV号为1vK411A7Wa的视频属性抓取结束
# 开始BV号为1ov411k7Kb视频属性的抓取
# BV号为1ov411k7Kb的视频属性抓取结束
# 开始BV号为1K5411L7xZ视频属性的抓取
# BV号为1K5411L7xZ的视频属性抓取结束
# 开始BV号为1Dp4y1a7Tj视频属性的抓取
# BV号为1Dp4y1a7Tj的视频属性抓取结束
# 开始BV号为1af4y1i7Zd视频属性的抓取
# BV号为1af4y1i7Zd的视频属性抓取结束
# 开始BV号为1gD4y197tn视频属性的抓取
# BV号为1gD4y197tn的视频属性抓取结束
# 开始BV号为18V41127DU视频属性的抓取
# 开始BV号为18V41127DU视频属性的抓取
# BV号为18V41127DU的视频属性抓取结束
# 开始BV号为1tk4y1C7Wy视频属性的抓取
# BV号为1tk4y1C7Wy的视频属性抓取结束
# 开始BV号为1Xz4y1o7iG视频属性的抓取
# BV号为1Xz4y1o7iG的视频属性抓取结束
# 开始BV号为1qK411A7M5视频属性的抓取
# BV号为1qK411A7M5的视频属性抓取结束
# 开始BV号为1qK4y1h76C视频属性的抓取
# BV号为1qK4y1h76C的视频属性抓取结束
# 开始BV号为1g5411L7sq视频属性的抓取
# BV号为1g5411L7sq的视频属性抓取结束
# 开始BV号为1Si4y1E7ks视频属性的抓取
# BV号为1Si4y1E7ks的视频属性抓取结束
# 开始BV号为1Ei4y1E7Lo视频属性的抓取
# BV号为1Ei4y1E7Lo的视频属性抓取结束
# 开始BV号为1Sp4y1a74S视频属性的抓取
# BV号为1Sp4y1a74S的视频属性抓取结束
# 开始BV号为1gZ4y1L7Wp视频属性的抓取
# BV号为1gZ4y1L7Wp的视频属性抓取结束
# 开始BV号为1Qr4y1c745视频属性的抓取
# BV号为1Qr4y1c745的视频属性抓取结束
# 开始BV号为1i54y1R7JY视频属性的抓取
# BV号为1i54y1R7JY的视频属性抓取结束
# 开始BV号为1RK4y177XA视频属性的抓取
# BV号为1RK4y177XA的视频属性抓取结束
# 开始BV号为1NA411E7yk视频属性的抓取
# BV号为1NA411E7yk的视频属性抓取结束
# 开始BV号为1rK4y177oz视频属性的抓取
# BV号为1rK4y177oz的视频属性抓取结束
# 开始BV号为1j54y1C7mD视频属性的抓取
# BV号为1j54y1C7mD的视频属性抓取结束
# 开始BV号为1LK411P7e6视频属性的抓取
# BV号为1LK411P7e6的视频属性抓取结束
# 开始BV号为17v411k7UQ视频属性的抓取
# BV号为17v411k7UQ的视频属性抓取结束
# 开始BV号为1hV411y7c8视频属性的抓取
# BV号为1hV411y7c8的视频属性抓取结束
# 开始BV号为1Lp4y1k7VN视频属性的抓取
# BV号为1Lp4y1k7VN的视频属性抓取结束
# 开始BV号为1Fz4y1o7Pg视频属性的抓取
# BV号为1Fz4y1o7Pg的视频属性抓取结束
# 开始BV号为1Gv411C7Cx视频属性的抓取
# BV号为1Gv411C7Cx的视频属性抓取结束
# 开始BV号为12A411L78n视频属性的抓取
# BV号为12A411L78n的视频属性抓取结束
# 开始BV号为1GD4y1d7uA视频属性的抓取
# BV号为1GD4y1d7uA的视频属性抓取结束
# 开始BV号为1ST4y1c7gr视频属性的抓取
# BV号为1ST4y1c7gr的视频属性抓取结束
# 开始BV号为1ay4y1C7A9视频属性的抓取
# BV号为1ay4y1C7A9的视频属性抓取结束
# 开始BV号为1Ff4y1z7r1视频属性的抓取
# BV号为1Ff4y1z7r1的视频属性抓取结束
# 开始BV号为1c541177sZ视频属性的抓取
# BV号为1c541177sZ的视频属性抓取结束
# 开始BV号为1tZ4y1L7Jo视频属性的抓取
# BV号为1tZ4y1L7Jo的视频属性抓取结束
# 开始BV号为1jf4y1B7p3视频属性的抓取
# BV号为1jf4y1B7p3的视频属性抓取结束
# 开始BV号为1uZ4y1L7sH视频属性的抓取
# BV号为1uZ4y1L7sH的视频属性抓取结束
# 开始BV号为1Rf4y1D7on视频属性的抓取
# BV号为1Rf4y1D7on的视频属性抓取结束
# 开始BV号为1Ga4y1L7rQ视频属性的抓取
# BV号为1Ga4y1L7rQ的视频属性抓取结束
# 开始BV号为1Jv411k7bb视频属性的抓取
# BV号为1Jv411k7bb的视频属性抓取结束
# 开始BV号为1Fr4y1w7Te视频属性的抓取
# BV号为1Fr4y1w7Te的视频属性抓取结束
# 开始BV号为1oZ4y1G7Vo视频属性的抓取
# BV号为1oZ4y1G7Vo的视频属性抓取结束
# 开始BV号为1Q54y117nz视频属性的抓取
# BV号为1Q54y117nz的视频属性抓取结束
# 开始BV号为13v411k7gS视频属性的抓取
# BV号为13v411k7gS的视频属性抓取结束
# 开始BV号为1xa411A7CP视频属性的抓取
# BV号为1xa411A7CP的视频属性抓取结束
# 开始BV号为1KA411E7oZ视频属性的抓取
# BV号为1KA411E7oZ的视频属性抓取结束
# 开始BV号为1Ut4y1v7Qw视频属性的抓取
# BV号为1Ut4y1v7Qw的视频属性抓取结束
# 开始BV号为18a4y1L7sJ视频属性的抓取
# BV号为18a4y1L7sJ的视频属性抓取结束
# 开始BV号为1AV41127Rc视频属性的抓取
# BV号为1AV41127Rc的视频属性抓取结束
# 开始BV号为1Lz4y1o7gK视频属性的抓取
# BV号为1Lz4y1o7gK的视频属性抓取结束
# 开始BV号为1F541177Sb视频属性的抓取
# BV号为1F541177Sb的视频属性抓取结束
# 开始BV号为1oA41177oV视频属性的抓取
# BV号为1oA41177oV的视频属性抓取结束
# 开始BV号为1Tt4y1e7C5视频属性的抓取
# BV号为1Tt4y1e7C5的视频属性抓取结束
# 开始BV号为1EZ4y1L75M视频属性的抓取
# BV号为1EZ4y1L75M的视频属性抓取结束
# 开始BV号为12i4y1E7tH视频属性的抓取
# BV号为12i4y1E7tH的视频属性抓取结束
# 开始BV号为1q54y1R7vM视频属性的抓取
# BV号为1q54y1R7vM的视频属性抓取结束
# 开始BV号为1Ez4y1o73f视频属性的抓取
# BV号为1Ez4y1o73f的视频属性抓取结束
# 开始BV号为1Er4y1w7Kn视频属性的抓取
# BV号为1Er4y1w7Kn的视频属性抓取结束
# 开始BV号为1Vp4y1k7k7视频属性的抓取
# BV号为1Vp4y1k7k7的视频属性抓取结束
# 开始BV号为1sD4y197id视频属性的抓取
# BV号为1sD4y197id的视频属性抓取结束
# 开始BV号为1C54y1R7tR视频属性的抓取
# BV号为1C54y1R7tR的视频属性抓取结束
# 开始BV号为1ty4y1r7de视频属性的抓取
# BV号为1ty4y1r7de的视频属性抓取结束
# 开始BV号为1TK411P7U7视频属性的抓取
# BV号为1TK411P7U7的视频属性抓取结束
# 开始BV号为1np4y1k7ok视频属性的抓取
# BV号为1np4y1k7ok的视频属性抓取结束
# 开始BV号为1F5411L7CH视频属性的抓取
# BV号为1F5411L7CH的视频属性抓取结束
# 开始BV号为1Pt4y1i7h2视频属性的抓取
# BV号为1Pt4y1i7h2的视频属性抓取结束
# 开始BV号为19K4y1h7Gf视频属性的抓取
# BV号为19K4y1h7Gf的视频属性抓取结束
# 开始BV号为1fr4y1c7Dd视频属性的抓取
# BV号为1fr4y1c7Dd的视频属性抓取结束
# 开始BV号为1A54y1r7H1视频属性的抓取
# BV号为1A54y1r7H1的视频属性抓取结束
# 开始BV号为1ZK411P7jD视频属性的抓取
# BV号为1ZK411P7jD的视频属性抓取结束
# 开始BV号为1854y1C7LQ视频属性的抓取
# BV号为1854y1C7LQ的视频属性抓取结束
# 开始BV号为1sZ4y157ak视频属性的抓取
# BV号为1sZ4y157ak的视频属性抓取结束
# 开始BV号为1wt4y1e7Fk视频属性的抓取
# BV号为1wt4y1e7Fk的视频属性抓取结束
# 开始BV号为1Bf4y1B7Ya视频属性的抓取
# 开始BV号为1Bf4y1B7Ya视频属性的抓取
# BV号为1Bf4y1B7Ya的视频属性抓取结束
# 开始BV号为1Nk4y1y7Wi视频属性的抓取
# BV号为1Nk4y1y7Wi的视频属性抓取结束
# 开始BV号为13z4y1f7Lx视频属性的抓取
# BV号为13z4y1f7Lx的视频属性抓取结束
# 开始BV号为1Sa411A79x视频属性的抓取
# BV号为1Sa411A79x的视频属性抓取结束
# 开始BV号为1kK411A74N视频属性的抓取
# 开始BV号为1kK411A74N视频属性的抓取
# BV号为1kK411A74N的视频属性抓取结束
# 开始BV号为1wA411j7kG视频属性的抓取
# BV号为1wA411j7kG的视频属性抓取结束
# 开始BV号为1Yi4y1j7uc视频属性的抓取
# BV号为1Yi4y1j7uc的视频属性抓取结束
# 开始BV号为1ky4y1r7wv视频属性的抓取
# BV号为1ky4y1r7wv的视频属性抓取结束
# 2020-12-17 21:33:39.730048

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-14-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_zixun_shehui.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 2月     97   97    97   97   97   97   97   97    97      97   97    97   97
# 3月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月    99   99   99   99   99   99    99
# 2月    97   97   97   97   97   97    97
# 3月    99   99   99   99   99   99    99
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月   100  100  100  100  100  100   100
# 7月   100  100  100  100  100  100   100
# 8月   100  100  100  100  100  100   100
# 9月   100  100  100  100  100  100   100

# %%
channel_zixun_shehui.to_json('channel_zixun_shehui.json')

# %%
pd.set_option('display.max_rows', None)

# %%
channel_youxi_danji[channel_youxi_danji['时间']=='4月']
# Out:
#             时间            作者名  作者类型      粉丝数   投稿数  \
# 1h54y1d7Qq  4月            鹤吱菌  个人认证   191.3万    81
# 1L64y1M7Dp  4月            老番茄  个人认证  1360.1万   348
# 18K41157Tu  4月            老番茄  个人认证  1360.1万   348
# 1PT4y1G7ME  4月            老番茄  个人认证  1360.1万   348
# 1S54y197uX  4月           徐大虾咯  个人认证   570.1万   224
# 1ti4y1t7YM  4月            老番茄  个人认证  1360.1万   348
# 1Ai4y1b7ET  4月            敖厂长  个人认证   735.1万   348
# 1Up4y1C7PB  4月        丢鹏D1uuu     无     8.4万    20
# 1wi4y187bu  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 13t4y1U7kQ  4月           徐大虾咯  个人认证   570.1万   224
# 1fe411x7FA  4月         芦苇草的梦想  个人认证    29.3万   726
# 1LA411b7Dt  4月      LexBurner  个人认证   929.6万   383
# 1Ji4y1t7T9  4月            沧桑丸  个人认证    86.6万    57
# 1Lz411z72u  4月           徐大虾咯  个人认证   570.1万   224
# 13T4y1G7WT  4月          逗比的雀巢  个人认证   242.3万    82
# 1T54y197DH  4月           徐大虾咯  个人认证   570.1万   224
# 1Va4y147fH  4月            鹤吱菌  个人认证   191.3万    81
# 1tt4y127yy  4月           小潮院长  个人认证   481.6万   266
# 16T4y1g7RY  4月         吉儿一范伦婷  个人认证    67.6万    79
# 1754y197Da  4月            敖厂长  个人认证   735.1万   348
# 1hK41157M3  4月           花少北丶  个人认证   491.9万   173
# 1Rk4y197kw  4月       3DM游戏网官方  机构认证    13.5万  2822
# 1ST4y1G7E1  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1H54y1d76B  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1Sz411B7P4  4月          游汐_YX  个人认证    12.9万    98
# 1CT4y1g7Ya  4月    育碧中国Ubisoft  机构认证    64.5万  1211
# 12T4y1G7AZ  4月          与山0v0  个人认证   208.5万   557
# 1b5411x79t  4月        东尼ookii  个人认证   331.7万   166
# 1hA411h7Ky  4月          与山0v0  个人认证   208.5万   557
# 1Gt4y127AJ  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1KJ411e7nN                              如何提高审美？审美有无高低？审美是谁建立？  数码  摄影摄像  普通视频
# ...                                                       ...  ..   ...   ...
# 1cr4y1w7ig              困难重重，国家天文签约摄影师遭遇拍摄滑铁卢？！【华为Mate40 Pro】  数码  摄影摄像  活动作品
# 1Y5411L7TW                     富士X-S10相机测试——2020 apsc画幅性价比最强机  数码  摄影摄像  活动作品
# 1c541177hR      索尼（Sony）12-24mm F2.8 GM深度评测，只要买得起，它就是一颗完美的镜头！  数码  摄影摄像  普通视频
# 1DA41177UY                            大疆旗舰稳定器 - DJI RS 2 正式登场  数码  摄影摄像  普通视频
# 1rA411776p                 让我非常失望的佳能M50 Mark II（来自一代老用户的真实心声）  数码  摄影摄像  普通视频
#
#             ...                                                 标签   视频长度  \
# 1gJ411n7hp  ...                         [摄影, 数码, 摄影摄像, 数码, 教程, 器材]  01:44
# 1tJ41187w6  ...  [相机, 数码, 摄影摄像, 数码, 何同学, 啊吗粽, 宝剑嫂, 自媒体, 大祥哥, 体验...  30:03
# 1i7411i7yA  ...        [摄影, 短片, 数码, 摄影摄像, 数码, 创意, YOUTUBE, 镜头, 老蛙]  04:51
# 1gJ411G7Cs  ...           [摄影, 数码, 摄影摄像, 数码, VLOG, 后期, 教程, ps, 器材]  06:01
# 1KJ411e7nN  ...  [校园vlog, 相机, 脱口秀, 摄影, 公开课, vlog, 科普, 数码, 摄影摄像,...  27:08
# ...         ...                                                ...    ...
# 1cr4y1w7ig  ...  [vlog, 数码, 摄影摄像, 数码, 放心购机攻略, 敦煌, 星空, 手机摄影, 华为,...  11:43
# 1Y5411L7TW  ...  [相机, 摄影, 数码, 摄影摄像, 数码, 数码玩家训练营, 拍照, 测评, xs10, ...  10:20
# 1c541177hR  ...  [摄影, 数码, 摄影摄像, 数码, 评测, 超广角大光圈, 摄像, 镜头, 数码评测, 超...  21:23
# 1DA41177UY  ...   [相机, 摄影, 数码, 摄影摄像, 数码, 科技, 测评, 器材, 大疆, DJI, 稳定器]  02:26
# 1rA411776p  ...  [vlog, 数码, 摄影摄像, 数码, 佳能, 测评, 体验, m50 mark ii, ...  06:30
#
#                播放量    点赞数   投币数   收藏数   转发数   评论数   弹幕数 有无分集
# 1gJ411n7hp  222.4万   9.7万  2.0万  1.4万  4980  3182  1571    否
# 1tJ41187w6  134.0万  10.7万  8.4万  5.8万  8907  3935  3.0万    否
# 1i7411i7yA   57.8万   4.4万  1.0万  1.6万  2043   641   983    否
# 1gJ411G7Cs   42.3万   3.3万  3.4万  8.6万  2605  1405   612    否
# 1KJ411e7nN   39.6万   4.8万  5.4万  3.4万  6217  1156  1.0万    否
# ...            ...    ...   ...   ...   ...   ...   ...  ...
# 1cr4y1w7ig    4.3万   3051  1391   692   255   337   349    否
# 1Y5411L7TW    4.3万    773   219   221   111   273   104    否
# 1c541177hR    4.1万   1469   443   297   123   250   561    否
# 1DA41177UY    4.1万   1565   197   334   640   171   110    否
# 1rA411776p    4.1万   1262   267   147   101   385   314    否
#
# [999 rows x 21 columns]
