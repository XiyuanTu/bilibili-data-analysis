# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_shuma_yingyin=pd.DataFrame(columns=columns)
channel_shuma_yingyin
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[8]/div/a/span').click()  #选择频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[8]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '数码'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[5]/a').click()  #选择子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[5]/a').text
sub_channel
# Out:
# '影音智能'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(4,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_shuma_yingyin.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-16 23:47:36.608777
# <ipython-input-24-a44922c99c6c>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-24-a44922c99c6c>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-24-a44922c99c6c>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1Je411x7jR视频属性的抓取
# BV号为1Je411x7jR的视频属性抓取结束
# <ipython-input-24-a44922c99c6c>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1uC4y1s74t视频属性的抓取
# BV号为1uC4y1s74t的视频属性抓取结束
# 开始BV号为1pK4y1k7Sr视频属性的抓取
# BV号为1pK4y1k7Sr的视频属性抓取结束
# 开始BV号为1nK411L782视频属性的抓取
# 开始BV号为1nK411L782视频属性的抓取
# BV号为1nK411L782的视频属性抓取结束
# 开始BV号为1xt4y127Rq视频属性的抓取
# BV号为1xt4y127Rq的视频属性抓取结束
# 开始BV号为1k64y1T7HZ视频属性的抓取
# BV号为1k64y1T7HZ的视频属性抓取结束
# 开始BV号为1qC4y1s7mb视频属性的抓取
# BV号为1qC4y1s7mb的视频属性抓取结束
# 开始BV号为1mf4y1S7uW视频属性的抓取
# BV号为1mf4y1S7uW的视频属性抓取结束
# 开始BV号为1kp4y1X7mb视频属性的抓取
# BV号为1kp4y1X7mb的视频属性抓取结束
# 开始BV号为1Uz411b7SF视频属性的抓取
# BV号为1Uz411b7SF的视频属性抓取结束
# 开始BV号为1UK411L7jY视频属性的抓取
# BV号为1UK411L7jY的视频属性抓取结束
# 开始BV号为1ap4y1C73B视频属性的抓取
# BV号为1ap4y1C73B的视频属性抓取结束
# 开始BV号为1Dt4y127qR视频属性的抓取
# BV号为1Dt4y127qR的视频属性抓取结束
# 开始BV号为1XZ4y1W78i视频属性的抓取
# BV号为1XZ4y1W78i的视频属性抓取结束
# 开始BV号为15K411L7dV视频属性的抓取
# BV号为15K411L7dV的视频属性抓取结束
# 开始BV号为1Eg4y187BJ视频属性的抓取
# BV号为1Eg4y187BJ的视频属性抓取结束
# 开始BV号为1yC4y1s7fd视频属性的抓取
# BV号为1yC4y1s7fd的视频属性抓取结束
# 开始BV号为16i4y1t7MD视频属性的抓取
# BV号为16i4y1t7MD的视频属性抓取结束
# 开始BV号为13T4y1574a视频属性的抓取
# BV号为13T4y1574a的视频属性抓取结束
# 开始BV号为1Zp4y1C7NP视频属性的抓取
# BV号为1Zp4y1C7NP的视频属性抓取结束
# 开始BV号为1qc411h7nH视频属性的抓取
# BV号为1qc411h7nH的视频属性抓取结束
# 开始BV号为11c411h7NQ视频属性的抓取
# BV号为11c411h7NQ的视频属性抓取结束
# 开始BV号为18k4y1R7H4视频属性的抓取
# 开始BV号为18k4y1R7H4视频属性的抓取
# BV号为18k4y1R7H4的视频属性抓取结束
# 开始BV号为17Q4y1N7mv视频属性的抓取
# BV号为17Q4y1N7mv的视频属性抓取结束
# 开始BV号为1UQ4y1P7fz视频属性的抓取
# BV号为1UQ4y1P7fz的视频属性抓取结束
# 开始BV号为1B54y1Q7W5视频属性的抓取
# BV号为1B54y1Q7W5的视频属性抓取结束
# 开始BV号为1wC4y1x7ya视频属性的抓取
# BV号为1wC4y1x7ya的视频属性抓取结束
# 开始BV号为1op4y1C7jy视频属性的抓取
# BV号为1op4y1C7jy的视频属性抓取结束
# 开始BV号为1ff4y1U7fU视频属性的抓取
# BV号为1ff4y1U7fU的视频属性抓取结束
# 开始BV号为11A411b7hC视频属性的抓取
# BV号为11A411b7hC的视频属性抓取结束
# 开始BV号为1JV411Z7Px视频属性的抓取
# BV号为1JV411Z7Px的视频属性抓取结束
# 开始BV号为1WK411L7Jm视频属性的抓取
# BV号为1WK411L7Jm的视频属性抓取结束
# 开始BV号为1DC4y1s7kj视频属性的抓取
# BV号为1DC4y1s7kj的视频属性抓取结束
# 开始BV号为1of4y1U7fg视频属性的抓取
# BV号为1of4y1U7fg的视频属性抓取结束
# 开始BV号为19k4y197K4视频属性的抓取
# BV号为19k4y197K4的视频属性抓取结束
# 开始BV号为1qp4y1X7su视频属性的抓取
# BV号为1qp4y1X7su的视频属性抓取结束
# 开始BV号为1dA411b77t视频属性的抓取
# BV号为1dA411b77t的视频属性抓取结束
# 开始BV号为1gc411h7GX视频属性的抓取
# BV号为1gc411h7GX的视频属性抓取结束
# 开始BV号为1KK4y1k7s7视频属性的抓取
# BV号为1KK4y1k7s7的视频属性抓取结束
# 开始BV号为15a4y147Vt视频属性的抓取
# BV号为15a4y147Vt的视频属性抓取结束
# 开始BV号为1ke411s7VX视频属性的抓取
# BV号为1ke411s7VX的视频属性抓取结束
# 开始BV号为1Np4y1y7Sc视频属性的抓取
# BV号为1Np4y1y7Sc的视频属性抓取结束
# 开始BV号为1aZ4y1x7T4视频属性的抓取
# BV号为1aZ4y1x7T4的视频属性抓取结束
# 开始BV号为1EV411f7mk视频属性的抓取
# BV号为1EV411f7mk的视频属性抓取结束
# 开始BV号为13Z4y1x7vG视频属性的抓取
# BV号为13Z4y1x7vG的视频属性抓取结束
# 开始BV号为1954y197TQ视频属性的抓取
# BV号为1954y197TQ的视频属性抓取结束
# 开始BV号为1NZ4y1x7mm视频属性的抓取
# BV号为1NZ4y1x7mm的视频属性抓取结束
# 开始BV号为1PA411h7qn视频属性的抓取
# BV号为1PA411h7qn的视频属性抓取结束
# 开始BV号为1ve411s7rU视频属性的抓取
# BV号为1ve411s7rU的视频属性抓取结束
# 开始BV号为1dT4y1g7ra视频属性的抓取
# BV号为1dT4y1g7ra的视频属性抓取结束
# 开始BV号为1X54y1Q765视频属性的抓取
# BV号为1X54y1Q765的视频属性抓取结束
# 开始BV号为1cz411b7Uw视频属性的抓取
# BV号为1cz411b7Uw的视频属性抓取结束
# 开始BV号为12C4y1s768视频属性的抓取
# BV号为12C4y1s768的视频属性抓取结束
# 开始BV号为1Ft4y127uw视频属性的抓取
# BV号为1Ft4y127uw的视频属性抓取结束
# 开始BV号为1ck4y1R73g视频属性的抓取
# BV号为1ck4y1R73g的视频属性抓取结束
# 开始BV号为18a4y1x7Pc视频属性的抓取
# BV号为18a4y1x7Pc的视频属性抓取结束
# 开始BV号为1pK4y1b7Ez视频属性的抓取
# BV号为1pK4y1b7Ez的视频属性抓取结束
# 开始BV号为19A411b7m6视频属性的抓取
# BV号为19A411b7m6的视频属性抓取结束
# 开始BV号为13V411f7yc视频属性的抓取
# BV号为13V411f7yc的视频属性抓取结束
# 开始BV号为15z411b7g7视频属性的抓取
# BV号为15z411b7g7的视频属性抓取结束
# 开始BV号为17Q4y1K7CK视频属性的抓取
# BV号为17Q4y1K7CK的视频属性抓取结束
# 开始BV号为1Yp4y1X7uA视频属性的抓取
# BV号为1Yp4y1X7uA的视频属性抓取结束
# 开始BV号为1uT4y137ps视频属性的抓取
# BV号为1uT4y137ps的视频属性抓取结束
# 开始BV号为1U64y1u7uw视频属性的抓取
# BV号为1U64y1u7uw的视频属性抓取结束
# 开始BV号为1vz411b7tC视频属性的抓取
# BV号为1vz411b7tC的视频属性抓取结束
# 开始BV号为1ok4y197u1视频属性的抓取
# BV号为1ok4y197u1的视频属性抓取结束
# 开始BV号为1HT4y157Zc视频属性的抓取
# BV号为1HT4y157Zc的视频属性抓取结束
# 开始BV号为19T4y1376f视频属性的抓取
# BV号为19T4y1376f的视频属性抓取结束
# 开始BV号为1Hp4y1y71T视频属性的抓取
# BV号为1Hp4y1y71T的视频属性抓取结束
# 开始BV号为1d5411x7iq视频属性的抓取
# BV号为1d5411x7iq的视频属性抓取结束
# 开始BV号为1gV411Z7qB视频属性的抓取
# BV号为1gV411Z7qB的视频属性抓取结束
# 开始BV号为1Ma4y14736视频属性的抓取
# BV号为1Ma4y14736的视频属性抓取结束
# 开始BV号为1xV411f7RR视频属性的抓取
# BV号为1xV411f7RR的视频属性抓取结束
# 开始BV号为1Zt4y117Yt视频属性的抓取
# BV号为1Zt4y117Yt的视频属性抓取结束
# 开始BV号为14p4y1176b视频属性的抓取
# BV号为14p4y1176b的视频属性抓取结束
# 开始BV号为1y54y197Sm视频属性的抓取
# BV号为1y54y197Sm的视频属性抓取结束
# 开始BV号为1m64y1T7Ka视频属性的抓取
# BV号为1m64y1T7Ka的视频属性抓取结束
# 开始BV号为1Ai4y187av视频属性的抓取
# BV号为1Ai4y187av的视频属性抓取结束
# 开始BV号为15i4y1t7Km视频属性的抓取
# BV号为15i4y1t7Km的视频属性抓取结束
# 开始BV号为1K54y197yJ视频属性的抓取
# BV号为1K54y197yJ的视频属性抓取结束
# 开始BV号为1JQ4y1K71z视频属性的抓取
# BV号为1JQ4y1K71z的视频属性抓取结束
# 开始BV号为16Z4y1j7cF视频属性的抓取
# BV号为16Z4y1j7cF的视频属性抓取结束
# 开始BV号为1Y5411x7cc视频属性的抓取
# BV号为1Y5411x7cc的视频属性抓取结束
# 开始BV号为1vZ4y1W7oV视频属性的抓取
# BV号为1vZ4y1W7oV的视频属性抓取结束
# 开始BV号为1uV411o74s视频属性的抓取
# BV号为1uV411o74s的视频属性抓取结束
# 开始BV号为1B54y197zD视频属性的抓取
# BV号为1B54y197zD的视频属性抓取结束
# 开始BV号为19V411R7zy视频属性的抓取
# BV号为19V411R7zy的视频属性抓取结束
# 开始BV号为1HT4y1G7Cz视频属性的抓取
# BV号为1HT4y1G7Cz的视频属性抓取结束
# 开始BV号为1FK411j7de视频属性的抓取
# BV号为1FK411j7de的视频属性抓取结束
# 开始BV号为1M5411t7hi视频属性的抓取
# BV号为1M5411t7hi的视频属性抓取结束
# 开始BV号为1aC4y1s7Cb视频属性的抓取
# BV号为1aC4y1s7Cb的视频属性抓取结束
# 开始BV号为1864y1u7GT视频属性的抓取
# BV号为1864y1u7GT的视频属性抓取结束
# 开始BV号为1Pk4y1k7MZ视频属性的抓取
# BV号为1Pk4y1k7MZ的视频属性抓取结束
# 开始BV号为1Dk4y1R7Nk视频属性的抓取
# BV号为1Dk4y1R7Nk的视频属性抓取结束
# 开始BV号为1uT4y1G7Sg视频属性的抓取
# BV号为1uT4y1G7Sg的视频属性抓取结束
# 开始BV号为1Fz41187Va视频属性的抓取
# BV号为1Fz41187Va的视频属性抓取结束
# 开始BV号为1oz411b7Gn视频属性的抓取
# BV号为1oz411b7Gn的视频属性抓取结束
# 开始BV号为1zT4y1G7g9视频属性的抓取
# BV号为1zT4y1G7g9的视频属性抓取结束
# 开始BV号为1Vg4y187ZS视频属性的抓取
# BV号为1Vg4y187ZS的视频属性抓取结束
# 开始BV号为1E64y1T73B视频属性的抓取
# BV号为1E64y1T73B的视频属性抓取结束
# 开始BV号为1mV411C7TC视频属性的抓取
# BV号为1mV411C7TC的视频属性抓取结束
# 开始BV号为1ht4y117Ls视频属性的抓取
# BV号为1ht4y117Ls的视频属性抓取结束
# 开始BV号为17z4y1d7sN视频属性的抓取
# BV号为17z4y1d7sN的视频属性抓取结束
# 开始BV号为1uA411t7rU视频属性的抓取
# BV号为1uA411t7rU的视频属性抓取结束
# 开始BV号为1kt4y1C7Cq视频属性的抓取
# BV号为1kt4y1C7Cq的视频属性抓取结束
# 开始BV号为1CT4y1u7Zn视频属性的抓取
# BV号为1CT4y1u7Zn的视频属性抓取结束
# 开始BV号为1Jz411q7K5视频属性的抓取
# BV号为1Jz411q7K5的视频属性抓取结束
# 开始BV号为1aQ4y1A7mT视频属性的抓取
# BV号为1aQ4y1A7mT的视频属性抓取结束
# 开始BV号为1cK411L7LY视频属性的抓取
# BV号为1cK411L7LY的视频属性抓取结束
# 开始BV号为1eK411W7XW视频属性的抓取
# BV号为1eK411W7XW的视频属性抓取结束
# 开始BV号为1of4y1m7K4视频属性的抓取
# BV号为1of4y1m7K4的视频属性抓取结束
# 开始BV号为1654y1D7Cw视频属性的抓取
# BV号为1654y1D7Cw的视频属性抓取结束
# 开始BV号为1PQ4y1K75F视频属性的抓取
# BV号为1PQ4y1K75F的视频属性抓取结束
# 开始BV号为1bK4y1b7Nq视频属性的抓取
# BV号为1bK4y1b7Nq的视频属性抓取结束
# 开始BV号为1Pe411W7xq视频属性的抓取
# BV号为1Pe411W7xq的视频属性抓取结束
# 开始BV号为1xC4y1p789视频属性的抓取
# BV号为1xC4y1p789的视频属性抓取结束
# 开始BV号为1GQ4y1P7HZ视频属性的抓取
# BV号为1GQ4y1P7HZ的视频属性抓取结束
# 开始BV号为1Mf4y127tM视频属性的抓取
# BV号为1Mf4y127tM的视频属性抓取结束
# 开始BV号为1iC4y1H7au视频属性的抓取
# BV号为1iC4y1H7au的视频属性抓取结束
# 开始BV号为1ug4y1B7e2视频属性的抓取
# BV号为1ug4y1B7e2的视频属性抓取结束
# 开始BV号为1rA411t7R4视频属性的抓取
# BV号为1rA411t7R4的视频属性抓取结束
# 开始BV号为1VK411s7Vv视频属性的抓取
# BV号为1VK411s7Vv的视频属性抓取结束
# 开始BV号为1tk4y167cy视频属性的抓取
# BV号为1tk4y167cy的视频属性抓取结束
# 开始BV号为1a5411s7db视频属性的抓取
# BV号为1a5411s7db的视频属性抓取结束
# 开始BV号为1BV411d7tU视频属性的抓取
# BV号为1BV411d7tU的视频属性抓取结束
# 开始BV号为1Xz411v77q视频属性的抓取
# BV号为1Xz411v77q的视频属性抓取结束
# 开始BV号为1H541147YH视频属性的抓取
# BV号为1H541147YH的视频属性抓取结束
# 开始BV号为1Mz4y197us视频属性的抓取
# BV号为1Mz4y197us的视频属性抓取结束
# 开始BV号为1zV411C7Jv视频属性的抓取
# BV号为1zV411C7Jv的视频属性抓取结束
# 开始BV号为13z4y1d7w8视频属性的抓取
# BV号为13z4y1d7w8的视频属性抓取结束
# 开始BV号为1bK411W79S视频属性的抓取
# BV号为1bK411W79S的视频属性抓取结束
# 开始BV号为1ng4y1B7x7视频属性的抓取
# BV号为1ng4y1B7x7的视频属性抓取结束
# 开始BV号为15k4y1r7Vb视频属性的抓取
# BV号为15k4y1r7Vb的视频属性抓取结束
# 开始BV号为1bK41157Vo视频属性的抓取
# BV号为1bK41157Vo的视频属性抓取结束
# 开始BV号为1Lz411q7LE视频属性的抓取
# BV号为1Lz411q7LE的视频属性抓取结束
# 开始BV号为1Pi4y147u4视频属性的抓取
# BV号为1Pi4y147u4的视频属性抓取结束
# 开始BV号为1i5411s7Q5视频属性的抓取
# BV号为1i5411s7Q5的视频属性抓取结束
# 开始BV号为1Ma4y1i76E视频属性的抓取
# BV号为1Ma4y1i76E的视频属性抓取结束
# 开始BV号为1fz4y1R7We视频属性的抓取
# BV号为1fz4y1R7We的视频属性抓取结束
# 开始BV号为16A411q7yz视频属性的抓取
# BV号为16A411q7yz的视频属性抓取结束
# 开始BV号为1Lf4y127YT视频属性的抓取
# BV号为1Lf4y127YT的视频属性抓取结束
# 开始BV号为1fg4y1q7Xz视频属性的抓取
# BV号为1fg4y1q7Xz的视频属性抓取结束
# 开始BV号为1mK4y1t7KE视频属性的抓取
# BV号为1mK4y1t7KE的视频属性抓取结束
# 开始BV号为1At4y117c7视频属性的抓取
# BV号为1At4y117c7的视频属性抓取结束
# 开始BV号为1of4y1m7W9视频属性的抓取
# BV号为1of4y1m7W9的视频属性抓取结束
# 开始BV号为1Wv411z77B视频属性的抓取
# BV号为1Wv411z77B的视频属性抓取结束
# 开始BV号为1Yz4y1R74g视频属性的抓取
# BV号为1Yz4y1R74g的视频属性抓取结束
# 开始BV号为1Ae411W7aV视频属性的抓取
# BV号为1Ae411W7aV的视频属性抓取结束
# 开始BV号为1xz4y1d7GW视频属性的抓取
# BV号为1xz4y1d7GW的视频属性抓取结束
# 开始BV号为12a4y1e7bP视频属性的抓取
# BV号为12a4y1e7bP的视频属性抓取结束
# 开始BV号为1Qp4y1Q7Vs视频属性的抓取
# BV号为1Qp4y1Q7Vs的视频属性抓取结束
# 开始BV号为1kt4y1C7ZG视频属性的抓取
# BV号为1kt4y1C7ZG的视频属性抓取结束
# 开始BV号为1Ya4y1i7kP视频属性的抓取
# BV号为1Ya4y1i7kP的视频属性抓取结束
# 开始BV号为1MT4y1g7qR视频属性的抓取
# BV号为1MT4y1g7qR的视频属性抓取结束
# 开始BV号为1Wg4y1i7r9视频属性的抓取
# BV号为1Wg4y1i7r9的视频属性抓取结束
# 开始BV号为11g4y1q7Qh视频属性的抓取
# BV号为11g4y1q7Qh的视频属性抓取结束
# 开始BV号为1qC4y1H7xc视频属性的抓取
# BV号为1qC4y1H7xc的视频属性抓取结束
# 开始BV号为1sp4y1Q7Uf视频属性的抓取
# BV号为1sp4y1Q7Uf的视频属性抓取结束
# 开始BV号为1HA411t7uX视频属性的抓取
# BV号为1HA411t7uX的视频属性抓取结束
# 开始BV号为1zA411q7aG视频属性的抓取
# BV号为1zA411q7aG的视频属性抓取结束
# 开始BV号为19z4y1R7qj视频属性的抓取
# BV号为19z4y1R7qj的视频属性抓取结束
# 开始BV号为1m5411s7im视频属性的抓取
# BV号为1m5411s7im的视频属性抓取结束
# 开始BV号为1nv411z7BP视频属性的抓取
# BV号为1nv411z7BP的视频属性抓取结束
# 开始BV号为1DK411H7VG视频属性的抓取
# BV号为1DK411H7VG的视频属性抓取结束
# 开始BV号为1kg4y1B76J视频属性的抓取
# BV号为1kg4y1B76J的视频属性抓取结束
# 开始BV号为14k4y167tM视频属性的抓取
# BV号为14k4y167tM的视频属性抓取结束
# 开始BV号为1fz4y1X7kU视频属性的抓取
# BV号为1fz4y1X7kU的视频属性抓取结束
# 开始BV号为1GZ4y1W787视频属性的抓取
# BV号为1GZ4y1W787的视频属性抓取结束
# 开始BV号为1iK4y1t79F视频属性的抓取
# 开始BV号为1iK4y1t79F视频属性的抓取
# BV号为1iK4y1t79F的视频属性抓取结束
# 开始BV号为1af4y1m72K视频属性的抓取
# BV号为1af4y1m72K的视频属性抓取结束
# 开始BV号为1554y1X7Ur视频属性的抓取
# BV号为1554y1X7Ur的视频属性抓取结束
# 开始BV号为1Gz4y1d77b视频属性的抓取
# BV号为1Gz4y1d77b的视频属性抓取结束
# 开始BV号为15Z4y1s7ZQ视频属性的抓取
# BV号为15Z4y1s7ZQ的视频属性抓取结束
# 开始BV号为1CC4y1p77n视频属性的抓取
# BV号为1CC4y1p77n的视频属性抓取结束
# 开始BV号为1aQ4y1N7Qk视频属性的抓取
# BV号为1aQ4y1N7Qk的视频属性抓取结束
# 开始BV号为1gz4y197mi视频属性的抓取
# BV号为1gz4y197mi的视频属性抓取结束
# 开始BV号为115411s795视频属性的抓取
# BV号为115411s795的视频属性抓取结束
# 开始BV号为1Vg4y1B7yF视频属性的抓取
# BV号为1Vg4y1B7yF的视频属性抓取结束
# 开始BV号为1x54y1X7Qq视频属性的抓取
# BV号为1x54y1X7Qq的视频属性抓取结束
# 开始BV号为1Hp4y1Q7TD视频属性的抓取
# BV号为1Hp4y1Q7TD的视频属性抓取结束
# 开始BV号为1ue411W7dJ视频属性的抓取
# BV号为1ue411W7dJ的视频属性抓取结束
# 开始BV号为1jK411s7TC视频属性的抓取
# BV号为1jK411s7TC的视频属性抓取结束
# 开始BV号为1KT4y1g71U视频属性的抓取
# BV号为1KT4y1g71U的视频属性抓取结束
# 开始BV号为1ei4y1s7bq视频属性的抓取
# BV号为1ei4y1s7bq的视频属性抓取结束
# 开始BV号为1za4y1i7nY视频属性的抓取
# BV号为1za4y1i7nY的视频属性抓取结束
# 开始BV号为1Fz4y197Hh视频属性的抓取
# BV号为1Fz4y197Hh的视频属性抓取结束
# 开始BV号为1JA411t79b视频属性的抓取
# BV号为1JA411t79b的视频属性抓取结束
# 开始BV号为1XT4y1u799视频属性的抓取
# BV号为1XT4y1u799的视频属性抓取结束
# 开始BV号为1rT4y137yC视频属性的抓取
# BV号为1rT4y137yC的视频属性抓取结束
# 开始BV号为1dQ4y1N7xY视频属性的抓取
# BV号为1dQ4y1N7xY的视频属性抓取结束
# 开始BV号为1fV411C77Q视频属性的抓取
# BV号为1fV411C77Q的视频属性抓取结束
# 开始BV号为1cg4y1z78V视频属性的抓取
# BV号为1cg4y1z78V的视频属性抓取结束
# 开始BV号为17t4y1C7R5视频属性的抓取
# BV号为17t4y1C7R5的视频属性抓取结束
# 开始BV号为1jk4y167o2视频属性的抓取
# BV号为1jk4y167o2的视频属性抓取结束
# 开始BV号为1hV411C7jY视频属性的抓取
# BV号为1hV411C7jY的视频属性抓取结束
# 开始BV号为18a4y1e7o6视频属性的抓取
# BV号为18a4y1e7o6的视频属性抓取结束
# 开始BV号为1Jf4y127tb视频属性的抓取
# BV号为1Jf4y127tb的视频属性抓取结束
# 开始BV号为1654y1X79X视频属性的抓取
# BV号为1654y1X79X的视频属性抓取结束
# 开始BV号为1sA411q762视频属性的抓取
# BV号为1sA411q762的视频属性抓取结束
# 开始BV号为1Zk4y167cY视频属性的抓取
# BV号为1Zk4y167cY的视频属性抓取结束
# 开始BV号为1CK411p7sF视频属性的抓取
# BV号为1CK411p7sF的视频属性抓取结束
# 开始BV号为1H5411W76V视频属性的抓取
# BV号为1H5411W76V的视频属性抓取结束
# 开始BV号为16T4y1E7Pt视频属性的抓取
# BV号为16T4y1E7Pt的视频属性抓取结束
# 开始BV号为1Ma4y1v7m9视频属性的抓取
# BV号为1Ma4y1v7m9的视频属性抓取结束
# 开始BV号为1Sv411z7gk视频属性的抓取
# BV号为1Sv411z7gk的视频属性抓取结束
# 开始BV号为1sD4y1D7CE视频属性的抓取
# BV号为1sD4y1D7CE的视频属性抓取结束
# 开始BV号为1oK411n7pm视频属性的抓取
# BV号为1oK411n7pm的视频属性抓取结束
# 开始BV号为1Jg4y1q7D2视频属性的抓取
# 开始BV号为1Jg4y1q7D2视频属性的抓取
# BV号为1Jg4y1q7D2的视频属性抓取结束
# 开始BV号为1VZ4y1H7pj视频属性的抓取
# BV号为1VZ4y1H7pj的视频属性抓取结束
# 开始BV号为1mT4y1E7rY视频属性的抓取
# BV号为1mT4y1E7rY的视频属性抓取结束
# 开始BV号为1VT4y1J7Q5视频属性的抓取
# BV号为1VT4y1J7Q5的视频属性抓取结束
# 开始BV号为1MD4y1Q7VJ视频属性的抓取
# BV号为1MD4y1Q7VJ的视频属性抓取结束
# 开始BV号为1bz411e7zJ视频属性的抓取
# BV号为1bz411e7zJ的视频属性抓取结束
# 开始BV号为1NK4y147ka视频属性的抓取
# BV号为1NK4y147ka的视频属性抓取结束
# 开始BV号为1HT4y1J7dG视频属性的抓取
# 开始BV号为1HT4y1J7dG视频属性的抓取
# BV号为1HT4y1J7dG的视频属性抓取结束
# 开始BV号为17a4y1v7ZA视频属性的抓取
# BV号为17a4y1v7ZA的视频属性抓取结束
# 开始BV号为19z4y197Qw视频属性的抓取
# BV号为19z4y197Qw的视频属性抓取结束
# 开始BV号为1Yf4y127nU视频属性的抓取
# BV号为1Yf4y127nU的视频属性抓取结束
# 开始BV号为1Gg4y1v7uT视频属性的抓取
# BV号为1Gg4y1v7uT的视频属性抓取结束
# 开始BV号为1PV411k7Gx视频属性的抓取
# BV号为1PV411k7Gx的视频属性抓取结束
# 开始BV号为1SK411p7Xk视频属性的抓取
# 开始BV号为1SK411p7Xk视频属性的抓取
# 开始BV号为1SK411p7Xk视频属性的抓取
# BV号为1SK411p7Xk的视频属性抓取结束
# 开始BV号为1Ez411v7mv视频属性的抓取
# BV号为1Ez411v7mv的视频属性抓取结束
# 开始BV号为15p4y1D763视频属性的抓取
# BV号为15p4y1D763的视频属性抓取结束
# 开始BV号为1AA411B77Z视频属性的抓取
# 开始BV号为1AA411B77Z视频属性的抓取
# BV号为1AA411B77Z的视频属性抓取结束
# 开始BV号为1xv41167KZ视频属性的抓取
# BV号为1xv41167KZ的视频属性抓取结束
# 开始BV号为1Pi4y1x7xr视频属性的抓取
# BV号为1Pi4y1x7xr的视频属性抓取结束
# 开始BV号为1P5411W7JA视频属性的抓取
# BV号为1P5411W7JA的视频属性抓取结束
# 开始BV号为1hD4y1D76B视频属性的抓取
# BV号为1hD4y1D76B的视频属性抓取结束
# 开始BV号为1iz4y1Q7Vb视频属性的抓取
# 开始BV号为1iz4y1Q7Vb视频属性的抓取
# 开始BV号为1iz4y1Q7Vb视频属性的抓取
# BV号为1iz4y1Q7Vb的视频属性抓取结束
# 开始BV号为1rQ4y1P73t视频属性的抓取
# BV号为1rQ4y1P73t的视频属性抓取结束
# 开始BV号为1m5411W7xe视频属性的抓取
# BV号为1m5411W7xe的视频属性抓取结束
# 开始BV号为1jZ4y1W7LD视频属性的抓取
# BV号为1jZ4y1W7LD的视频属性抓取结束
# 开始BV号为17Z4y1H77a视频属性的抓取
# BV号为17Z4y1H77a的视频属性抓取结束
# 开始BV号为1VK4y1b7pN视频属性的抓取
# BV号为1VK4y1b7pN的视频属性抓取结束
# 开始BV号为17t4y1y7sH视频属性的抓取
# BV号为17t4y1y7sH的视频属性抓取结束
# 开始BV号为1at4y1y7wD视频属性的抓取
# BV号为1at4y1y7wD的视频属性抓取结束
# 开始BV号为18a4y1Y7mD视频属性的抓取
# BV号为18a4y1Y7mD的视频属性抓取结束
# 开始BV号为17z411i7Tk视频属性的抓取
# BV号为17z411i7Tk的视频属性抓取结束
# 开始BV号为1Uz4y1Q7Qo视频属性的抓取
# BV号为1Uz4y1Q7Qo的视频属性抓取结束
# 开始BV号为1Nz4y1R7Th视频属性的抓取
# BV号为1Nz4y1R7Th的视频属性抓取结束
# 开始BV号为1it4y1y7ms视频属性的抓取
# BV号为1it4y1y7ms的视频属性抓取结束
# 开始BV号为1WT4y1J779视频属性的抓取
# BV号为1WT4y1J779的视频属性抓取结束
# 开始BV号为1PK4y147wY视频属性的抓取
# BV号为1PK4y147wY的视频属性抓取结束
# 开始BV号为1iz4y1Q7pU视频属性的抓取
# BV号为1iz4y1Q7pU的视频属性抓取结束
# 开始BV号为1oZ4y1n725视频属性的抓取
# BV号为1oZ4y1n725的视频属性抓取结束
# 开始BV号为1gz4y1R7HF视频属性的抓取
# BV号为1gz4y1R7HF的视频属性抓取结束
# 开始BV号为1ig4y1i7BF视频属性的抓取
# BV号为1ig4y1i7BF的视频属性抓取结束
# 开始BV号为1Np4y1D7hM视频属性的抓取
# BV号为1Np4y1D7hM的视频属性抓取结束
# 开始BV号为1nV411k7dP视频属性的抓取
# BV号为1nV411k7dP的视频属性抓取结束
# 开始BV号为1Rz4y1Q7JQ视频属性的抓取
# BV号为1Rz4y1Q7JQ的视频属性抓取结束
# 开始BV号为1hZ4y1H7D9视频属性的抓取
# BV号为1hZ4y1H7D9的视频属性抓取结束
# 开始BV号为1PK4y147F3视频属性的抓取
# BV号为1PK4y147F3的视频属性抓取结束
# 开始BV号为11K4y1x7Tf视频属性的抓取
# BV号为11K4y1x7Tf的视频属性抓取结束
# 开始BV号为1LZ4y1H7sq视频属性的抓取
# BV号为1LZ4y1H7sq的视频属性抓取结束
# 开始BV号为16v411B7y9视频属性的抓取
# BV号为16v411B7y9的视频属性抓取结束
# 开始BV号为1Ba4y1Y7ko视频属性的抓取
# BV号为1Ba4y1Y7ko的视频属性抓取结束
# 开始BV号为1PK4y147Nv视频属性的抓取
# BV号为1PK4y147Nv的视频属性抓取结束
# 开始BV号为1Bz411e75S视频属性的抓取
# BV号为1Bz411e75S的视频属性抓取结束
# 开始BV号为1QC4y1a7Yo视频属性的抓取
# 开始BV号为1QC4y1a7Yo视频属性的抓取
# BV号为1QC4y1a7Yo的视频属性抓取结束
# 开始BV号为1Yz411i7xU视频属性的抓取
# BV号为1Yz411i7xU的视频属性抓取结束
# 开始BV号为17g4y1q78g视频属性的抓取
# BV号为17g4y1q78g的视频属性抓取结束
# 开始BV号为1r5411W7UX视频属性的抓取
# BV号为1r5411W7UX的视频属性抓取结束
# 开始BV号为1j54y1z7pP视频属性的抓取
# BV号为1j54y1z7pP的视频属性抓取结束
# 开始BV号为15z411i7Dt视频属性的抓取
# BV号为15z411i7Dt的视频属性抓取结束
# 开始BV号为1dk4y1z7yS视频属性的抓取
# BV号为1dk4y1z7yS的视频属性抓取结束
# 开始BV号为1Bp4y1U79f视频属性的抓取
# BV号为1Bp4y1U79f的视频属性抓取结束
# 开始BV号为1Jz411e7p5视频属性的抓取
# BV号为1Jz411e7p5的视频属性抓取结束
# 开始BV号为17D4y1Q7hN视频属性的抓取
# BV号为17D4y1Q7hN的视频属性抓取结束
# 开始BV号为1nD4y1Q7Mj视频属性的抓取
# BV号为1nD4y1Q7Mj的视频属性抓取结束
# 开始BV号为1zi4y1x7Pa视频属性的抓取
# BV号为1zi4y1x7Pa的视频属性抓取结束
# 开始BV号为1NT4y1J7Sg视频属性的抓取
# BV号为1NT4y1J7Sg的视频属性抓取结束
# 开始BV号为1YZ4y1W7Pt视频属性的抓取
# BV号为1YZ4y1W7Pt的视频属性抓取结束
# 开始BV号为1XC4y1a7BM视频属性的抓取
# BV号为1XC4y1a7BM的视频属性抓取结束
# 开始BV号为1D54y1B7Ac视频属性的抓取
# BV号为1D54y1B7Ac的视频属性抓取结束
# 开始BV号为14D4y1Q76f视频属性的抓取
# BV号为14D4y1Q76f的视频属性抓取结束
# 开始BV号为1wK411H7Mm视频属性的抓取
# BV号为1wK411H7Mm的视频属性抓取结束
# 开始BV号为1rf4y11777视频属性的抓取
# BV号为1rf4y11777的视频属性抓取结束
# 开始BV号为1BV411r7G4视频属性的抓取
# BV号为1BV411r7G4的视频属性抓取结束
# 开始BV号为1rg4y1v7AW视频属性的抓取
# BV号为1rg4y1v7AW的视频属性抓取结束
# 开始BV号为1KK411W7s4视频属性的抓取
# BV号为1KK411W7s4的视频属性抓取结束
# 开始BV号为1mz4y1Q7gJ视频属性的抓取
# BV号为1mz4y1Q7gJ的视频属性抓取结束
# 开始BV号为1gK411p7F8视频属性的抓取
# BV号为1gK411p7F8的视频属性抓取结束
# 开始BV号为1Ht4y1y7VS视频属性的抓取
# BV号为1Ht4y1y7VS的视频属性抓取结束
# 开始BV号为1ND4y1Q7Rh视频属性的抓取
# BV号为1ND4y1Q7Rh的视频属性抓取结束
# 开始BV号为13C4y1a7AM视频属性的抓取
# BV号为13C4y1a7AM的视频属性抓取结束
# 开始BV号为1ia4y1Y7QR视频属性的抓取
# BV号为1ia4y1Y7QR的视频属性抓取结束
# 开始BV号为1yA411q7m4视频属性的抓取
# BV号为1yA411q7m4的视频属性抓取结束
# 开始BV号为1fz411i74u视频属性的抓取
# BV号为1fz411i74u的视频属性抓取结束
# 开始BV号为1fK4y1x7m8视频属性的抓取
# BV号为1fK4y1x7m8的视频属性抓取结束
# 开始BV号为1TC4y1h7kc视频属性的抓取
# BV号为1TC4y1h7kc的视频属性抓取结束
# 开始BV号为1a54y1B7ht视频属性的抓取
# BV号为1a54y1B7ht的视频属性抓取结束
# 开始BV号为1pK4y147AF视频属性的抓取
# BV号为1pK4y147AF的视频属性抓取结束
# 开始BV号为1mp4y1U7KM视频属性的抓取
# BV号为1mp4y1U7KM的视频属性抓取结束
# 开始BV号为1ua4y1Y78x视频属性的抓取
# BV号为1ua4y1Y78x的视频属性抓取结束
# 开始BV号为1Az411i7YB视频属性的抓取
# BV号为1Az411i7YB的视频属性抓取结束
# 开始BV号为1ET4y1J7cs视频属性的抓取
# BV号为1ET4y1J7cs的视频属性抓取结束
# 开始BV号为1xD4y1Q7pa视频属性的抓取
# BV号为1xD4y1Q7pa的视频属性抓取结束
# 开始BV号为14a4y1Y7YV视频属性的抓取
# BV号为14a4y1Y7YV的视频属性抓取结束
# 开始BV号为1Np4y1Q7s8视频属性的抓取
# BV号为1Np4y1Q7s8的视频属性抓取结束
# 开始BV号为1Pp4y1Q7ur视频属性的抓取
# BV号为1Pp4y1Q7ur的视频属性抓取结束
# 开始BV号为145411a7DR视频属性的抓取
# BV号为145411a7DR的视频属性抓取结束
# 开始BV号为1BK4y1e7Gh视频属性的抓取
# BV号为1BK4y1e7Gh的视频属性抓取结束
# 开始BV号为1Kh411d7zk视频属性的抓取
# BV号为1Kh411d7zk的视频属性抓取结束
# 开始BV号为1xz411v7hi视频属性的抓取
# BV号为1xz411v7hi的视频属性抓取结束
# 开始BV号为1bz411v7Bw视频属性的抓取
# BV号为1bz411v7Bw的视频属性抓取结束
# 开始BV号为14a4y1a7DG视频属性的抓取
# BV号为14a4y1a7DG的视频属性抓取结束
# 开始BV号为16V411k7Uu视频属性的抓取
# BV号为16V411k7Uu的视频属性抓取结束
# 开始BV号为1pz4y1X7Rp视频属性的抓取
# BV号为1pz4y1X7Rp的视频属性抓取结束
# 开始BV号为1h5411Y7Ej视频属性的抓取
# BV号为1h5411Y7Ej的视频属性抓取结束
# 开始BV号为1tt4y1X7Xc视频属性的抓取
# 开始BV号为1tt4y1X7Xc视频属性的抓取
# BV号为1tt4y1X7Xc的视频属性抓取结束
# 开始BV号为1Wi4y1V7t5视频属性的抓取
# BV号为1Wi4y1V7t5的视频属性抓取结束
# 开始BV号为1kp4y1i7bi视频属性的抓取
# BV号为1kp4y1i7bi的视频属性抓取结束
# 开始BV号为1Yf4y117KW视频属性的抓取
# BV号为1Yf4y117KW的视频属性抓取结束
# 开始BV号为18T4y1E7iB视频属性的抓取
# BV号为18T4y1E7iB的视频属性抓取结束
# 开始BV号为1KD4y1U7yL视频属性的抓取
# BV号为1KD4y1U7yL的视频属性抓取结束
# 开始BV号为1Hp4y1q7KH视频属性的抓取
# BV号为1Hp4y1q7KH的视频属性抓取结束
# 开始BV号为13a4y1a7i6视频属性的抓取
# BV号为13a4y1a7i6的视频属性抓取结束
# 开始BV号为1xg4y1v7Fq视频属性的抓取
# BV号为1xg4y1v7Fq的视频属性抓取结束
# 开始BV号为1jV41167on视频属性的抓取
# BV号为1jV41167on的视频属性抓取结束
# 开始BV号为16v411q7az视频属性的抓取
# BV号为16v411q7az的视频属性抓取结束
# 开始BV号为1rp4y1i7Mq视频属性的抓取
# BV号为1rp4y1i7Mq的视频属性抓取结束
# 开始BV号为14t4y1X7yL视频属性的抓取
# BV号为14t4y1X7yL的视频属性抓取结束
# 开始BV号为1Zz411e7Tq视频属性的抓取
# BV号为1Zz411e7Tq的视频属性抓取结束
# 开始BV号为1p54y1S79C视频属性的抓取
# BV号为1p54y1S79C的视频属性抓取结束
# 开始BV号为1qt4y1Q7Qo视频属性的抓取
# BV号为1qt4y1Q7Qo的视频属性抓取结束
# 开始BV号为1pt4y1Q7nK视频属性的抓取
# BV号为1pt4y1Q7nK的视频属性抓取结束
# 开始BV号为1A54y1i7Ht视频属性的抓取
# BV号为1A54y1i7Ht的视频属性抓取结束
# 开始BV号为1At4y1D7Da视频属性的抓取
# BV号为1At4y1D7Da的视频属性抓取结束
# 开始BV号为1VK4y1x7yZ视频属性的抓取
# BV号为1VK4y1x7yZ的视频属性抓取结束
# 开始BV号为1cZ4y1M76q视频属性的抓取
# BV号为1cZ4y1M76q的视频属性抓取结束
# 开始BV号为1CK411n7ug视频属性的抓取
# BV号为1CK411n7ug的视频属性抓取结束
# 开始BV号为15A411Y7Jd视频属性的抓取
# BV号为15A411Y7Jd的视频属性抓取结束
# 开始BV号为1ZV411B7c2视频属性的抓取
# BV号为1ZV411B7c2的视频属性抓取结束
# 开始BV号为1bt4y1Q7F1视频属性的抓取
# BV号为1bt4y1Q7F1的视频属性抓取结束
# 开始BV号为1Wz4y1X7zH视频属性的抓取
# BV号为1Wz4y1X7zH的视频属性抓取结束
# 开始BV号为1Ua4y1Y7T4视频属性的抓取
# BV号为1Ua4y1Y7T4的视频属性抓取结束
# 开始BV号为1b54y1z7Nv视频属性的抓取
# BV号为1b54y1z7Nv的视频属性抓取结束
# 开始BV号为1Zh411o7eW视频属性的抓取
# BV号为1Zh411o7eW的视频属性抓取结束
# 开始BV号为1uV41167CC视频属性的抓取
# BV号为1uV41167CC的视频属性抓取结束
# 开始BV号为1LA411v7Lr视频属性的抓取
# BV号为1LA411v7Lr的视频属性抓取结束
# 开始BV号为1Pk4y167kt视频属性的抓取
# BV号为1Pk4y167kt的视频属性抓取结束
# 开始BV号为1aV411z77x视频属性的抓取
# BV号为1aV411z77x的视频属性抓取结束
# 开始BV号为1254y1v7Pr视频属性的抓取
# BV号为1254y1v7Pr的视频属性抓取结束
# 开始BV号为1KC4y1h7uM视频属性的抓取
# BV号为1KC4y1h7uM的视频属性抓取结束
# 开始BV号为1EZ4y1u74F视频属性的抓取
# BV号为1EZ4y1u74F的视频属性抓取结束
# 开始BV号为1Df4y1R7fi视频属性的抓取
# BV号为1Df4y1R7fi的视频属性抓取结束
# 开始BV号为1ot4y197PK视频属性的抓取
# BV号为1ot4y197PK的视频属性抓取结束
# 开始BV号为1mT4y1J7xU视频属性的抓取
# BV号为1mT4y1J7xU的视频属性抓取结束
# 开始BV号为1ck4y1B73d视频属性的抓取
# BV号为1ck4y1B73d的视频属性抓取结束
# 开始BV号为13V41167Q5视频属性的抓取
# BV号为13V41167Q5的视频属性抓取结束
# 开始BV号为11D4y1S7LC视频属性的抓取
# BV号为11D4y1S7LC的视频属性抓取结束
# 开始BV号为1fZ4y1u7vE视频属性的抓取
# BV号为1fZ4y1u7vE的视频属性抓取结束
# 开始BV号为1FV411z7Cm视频属性的抓取
# BV号为1FV411z7Cm的视频属性抓取结束
# 开始BV号为1nt4y1X7CK视频属性的抓取
# BV号为1nt4y1X7CK的视频属性抓取结束
# 开始BV号为1qK4y1474X视频属性的抓取
# BV号为1qK4y1474X的视频属性抓取结束
# 开始BV号为1V5411a7KZ视频属性的抓取
# BV号为1V5411a7KZ的视频属性抓取结束
# 开始BV号为1ff4y1X7KK视频属性的抓取
# BV号为1ff4y1X7KK的视频属性抓取结束
# 开始BV号为1DA411i7gr视频属性的抓取
# BV号为1DA411i7gr的视频属性抓取结束
# 开始BV号为1PV411r7nX视频属性的抓取
# BV号为1PV411r7nX的视频属性抓取结束
# 开始BV号为1Ca4y1E7rw视频属性的抓取
# BV号为1Ca4y1E7rw的视频属性抓取结束
# 开始BV号为1zK411n776视频属性的抓取
# BV号为1zK411n776的视频属性抓取结束
# 开始BV号为1Xg4y1v7Gf视频属性的抓取
# BV号为1Xg4y1v7Gf的视频属性抓取结束
# 开始BV号为1wZ4y1p7nb视频属性的抓取
# BV号为1wZ4y1p7nb的视频属性抓取结束
# 开始BV号为1SV411B7tB视频属性的抓取
# BV号为1SV411B7tB的视频属性抓取结束
# 开始BV号为1Va4y1e7Ar视频属性的抓取
# BV号为1Va4y1e7Ar的视频属性抓取结束
# 开始BV号为1wz4y1Q7YV视频属性的抓取
# BV号为1wz4y1Q7YV的视频属性抓取结束
# 开始BV号为1Sk4y127rD视频属性的抓取
# BV号为1Sk4y127rD的视频属性抓取结束
# 开始BV号为1df4y1X7mb视频属性的抓取
# BV号为1df4y1X7mb的视频属性抓取结束
# 开始BV号为19a4y1a78w视频属性的抓取
# BV号为19a4y1a78w的视频属性抓取结束
# 开始BV号为1Ua4y1Y7nm视频属性的抓取
# BV号为1Ua4y1Y7nm的视频属性抓取结束
# 开始BV号为1sp4y1i7aT视频属性的抓取
# BV号为1sp4y1i7aT的视频属性抓取结束
# 开始BV号为1F5411a7oS视频属性的抓取
# BV号为1F5411a7oS的视频属性抓取结束
# 开始BV号为1dT4y1L7n9视频属性的抓取
# BV号为1dT4y1L7n9的视频属性抓取结束
# 开始BV号为1Pp4y1S7EL视频属性的抓取
# BV号为1Pp4y1S7EL的视频属性抓取结束
# 开始BV号为15z4y1X7gD视频属性的抓取
# BV号为15z4y1X7gD的视频属性抓取结束
# 开始BV号为1fK4y1e71j视频属性的抓取
# BV号为1fK4y1e71j的视频属性抓取结束
# 开始BV号为11p4y1S7T3视频属性的抓取
# BV号为11p4y1S7T3的视频属性抓取结束
# 开始BV号为1nz4y1D769视频属性的抓取
# BV号为1nz4y1D769的视频属性抓取结束
# 开始BV号为1JK4y1s71m视频属性的抓取
# BV号为1JK4y1s71m的视频属性抓取结束
# 开始BV号为1jK411J7xm视频属性的抓取
# BV号为1jK411J7xm的视频属性抓取结束
# 开始BV号为1ag4y1v7ju视频属性的抓取
# BV号为1ag4y1v7ju的视频属性抓取结束
# 开始BV号为1Tz4y1X7Sa视频属性的抓取
# BV号为1Tz4y1X7Sa的视频属性抓取结束
# 开始BV号为1uT4y1j7WM视频属性的抓取
# BV号为1uT4y1j7WM的视频属性抓取结束
# 开始BV号为18a4y1a79o视频属性的抓取
# BV号为18a4y1a79o的视频属性抓取结束
# 开始BV号为1fV411B7Zx视频属性的抓取
# BV号为1fV411B7Zx的视频属性抓取结束
# 开始BV号为1oi4y1g7b7视频属性的抓取
# BV号为1oi4y1g7b7的视频属性抓取结束
# 开始BV号为1xk4y1q7iF视频属性的抓取
# BV号为1xk4y1q7iF的视频属性抓取结束
# 开始BV号为1kp4y1i7uV视频属性的抓取
# BV号为1kp4y1i7uV的视频属性抓取结束
# 开始BV号为12V411B7Au视频属性的抓取
# BV号为12V411B7Au的视频属性抓取结束
# 开始BV号为1kK411H7NU视频属性的抓取
# BV号为1kK411H7NU的视频属性抓取结束
# 开始BV号为18T4y1E7JE视频属性的抓取
# BV号为18T4y1E7JE的视频属性抓取结束
# 开始BV号为145411a73o视频属性的抓取
# BV号为145411a73o的视频属性抓取结束
# 开始BV号为1Ra4y1h7h6视频属性的抓取
# BV号为1Ra4y1h7h6的视频属性抓取结束
# 开始BV号为1yh411o7g1视频属性的抓取
# BV号为1yh411o7g1的视频属性抓取结束
# 开始BV号为1ca4y1e7Nt视频属性的抓取
# BV号为1ca4y1e7Nt的视频属性抓取结束
# 开始BV号为1gf4y1d74D视频属性的抓取
# BV号为1gf4y1d74D的视频属性抓取结束
# 开始BV号为11K411H7s9视频属性的抓取
# BV号为11K411H7s9的视频属性抓取结束
# 开始BV号为1bt4y1D7sR视频属性的抓取
# BV号为1bt4y1D7sR的视频属性抓取结束
# 开始BV号为1yv411q7CD视频属性的抓取
# BV号为1yv411q7CD的视频属性抓取结束
# 开始BV号为1CK4y1e7DX视频属性的抓取
# BV号为1CK4y1e7DX的视频属性抓取结束
# 开始BV号为1TV411S7pw视频属性的抓取
# BV号为1TV411S7pw的视频属性抓取结束
# 开始BV号为1Mi4y1g7N5视频属性的抓取
# BV号为1Mi4y1g7N5的视频属性抓取结束
# 开始BV号为155411h7iK视频属性的抓取
# BV号为155411h7iK的视频属性抓取结束
# 开始BV号为1e54y1i7KD视频属性的抓取
# BV号为1e54y1i7KD的视频属性抓取结束
# 开始BV号为1Hp4y1v7mX视频属性的抓取
# BV号为1Hp4y1v7mX的视频属性抓取结束
# 开始BV号为1cA411e7ty视频属性的抓取
# BV号为1cA411e7ty的视频属性抓取结束
# 开始BV号为1CK4y1Y7XW视频属性的抓取
# BV号为1CK4y1Y7XW的视频属性抓取结束
# 开始BV号为1r54y1m7D2视频属性的抓取
# BV号为1r54y1m7D2的视频属性抓取结束
# 开始BV号为1U64y1c7aS视频属性的抓取
# BV号为1U64y1c7aS的视频属性抓取结束
# 开始BV号为1ja4y1E7hv视频属性的抓取
# BV号为1ja4y1E7hv的视频属性抓取结束
# 开始BV号为1Wf4y1972g视频属性的抓取
# BV号为1Wf4y1972g的视频属性抓取结束
# 开始BV号为1X5411a7B2视频属性的抓取
# BV号为1X5411a7B2的视频属性抓取结束
# 开始BV号为1VT4y177Kn视频属性的抓取
# BV号为1VT4y177Kn的视频属性抓取结束
# 开始BV号为13v411174V视频属性的抓取
# BV号为13v411174V的视频属性抓取结束
# 开始BV号为1r54y1e7dA视频属性的抓取
# BV号为1r54y1e7dA的视频属性抓取结束
# 开始BV号为1Sh411d7tP视频属性的抓取
# BV号为1Sh411d7tP的视频属性抓取结束
# 开始BV号为1n64y1c7A1视频属性的抓取
# BV号为1n64y1c7A1的视频属性抓取结束
# 开始BV号为1ft4y1D7kR视频属性的抓取
# BV号为1ft4y1D7kR的视频属性抓取结束
# 开始BV号为1WK4y1Y7YH视频属性的抓取
# BV号为1WK4y1Y7YH的视频属性抓取结束
# 开始BV号为1Pi4y1g7Bu视频属性的抓取
# BV号为1Pi4y1g7Bu的视频属性抓取结束
# 开始BV号为1pT4y1L7tQ视频属性的抓取
# BV号为1pT4y1L7tQ的视频属性抓取结束
# 开始BV号为18K411T7cB视频属性的抓取
# BV号为18K411T7cB的视频属性抓取结束
# 开始BV号为1Nt4y1S7Ln视频属性的抓取
# BV号为1Nt4y1S7Ln的视频属性抓取结束
# 开始BV号为1zV411U78u视频属性的抓取
# BV号为1zV411U78u的视频属性抓取结束
# 开始BV号为1X54y1m7dJ视频属性的抓取
# BV号为1X54y1m7dJ的视频属性抓取结束
# 开始BV号为1bp4y1v71S视频属性的抓取
# BV号为1bp4y1v71S的视频属性抓取结束
# 开始BV号为15T4y1j7iG视频属性的抓取
# BV号为15T4y1j7iG的视频属性抓取结束
# 开始BV号为1fv411v7KL视频属性的抓取
# BV号为1fv411v7KL的视频属性抓取结束
# 开始BV号为1qa4y1J7Uj视频属性的抓取
# BV号为1qa4y1J7Uj的视频属性抓取结束
# 开始BV号为1aa4y177vu视频属性的抓取
# BV号为1aa4y177vu的视频属性抓取结束
# 开始BV号为1LT4y1L7xa视频属性的抓取
# BV号为1LT4y1L7xa的视频属性抓取结束
# 开始BV号为1Ha4y1779a视频属性的抓取
# BV号为1Ha4y1779a的视频属性抓取结束
# 开始BV号为1g64y1c7RF视频属性的抓取
# BV号为1g64y1c7RF的视频属性抓取结束
# 开始BV号为1Tp4y1q72d视频属性的抓取
# BV号为1Tp4y1q72d的视频属性抓取结束
# 开始BV号为1bK4y1e7Uo视频属性的抓取
# BV号为1bK4y1e7Uo的视频属性抓取结束
# 开始BV号为1dv411y7gV视频属性的抓取
# BV号为1dv411y7gV的视频属性抓取结束
# 开始BV号为1454y1e7FZ视频属性的抓取
# BV号为1454y1e7FZ的视频属性抓取结束
# 开始BV号为1ND4y1m7uN视频属性的抓取
# BV号为1ND4y1m7uN的视频属性抓取结束
# 开始BV号为1rz4y1f73N视频属性的抓取
# BV号为1rz4y1f73N的视频属性抓取结束
# 开始BV号为1hz4y1f7gt视频属性的抓取
# BV号为1hz4y1f7gt的视频属性抓取结束
# 开始BV号为1iD4y1m7ad视频属性的抓取
# BV号为1iD4y1m7ad的视频属性抓取结束
# 开始BV号为1RC4y1t7eV视频属性的抓取
# BV号为1RC4y1t7eV的视频属性抓取结束
# 开始BV号为1f54y1m7Xb视频属性的抓取
# BV号为1f54y1m7Xb的视频属性抓取结束
# 开始BV号为14t4y1D7B9视频属性的抓取
# BV号为14t4y1D7B9的视频属性抓取结束
# 开始BV号为1ah411Z7Xj视频属性的抓取
# BV号为1ah411Z7Xj的视频属性抓取结束
# 开始BV号为1R64y1c7kx视频属性的抓取
# BV号为1R64y1c7kx的视频属性抓取结束
# 开始BV号为1gf4y197Ga视频属性的抓取
# BV号为1gf4y197Ga的视频属性抓取结束
# 开始BV号为16K4y1v7dt视频属性的抓取
# BV号为16K4y1v7dt的视频属性抓取结束
# 开始BV号为1zp4y1v7Tk视频属性的抓取
# BV号为1zp4y1v7Tk的视频属性抓取结束
# 开始BV号为19V411z78n视频属性的抓取
# BV号为19V411z78n的视频属性抓取结束
# 开始BV号为1jC4y1t7DD视频属性的抓取
# BV号为1jC4y1t7DD的视频属性抓取结束
# 开始BV号为1gK411M7SZ视频属性的抓取
# BV号为1gK411M7SZ的视频属性抓取结束
# 开始BV号为1pz4y1Q7Ts视频属性的抓取
# BV号为1pz4y1Q7Ts的视频属性抓取结束
# 开始BV号为1wv411i7P7视频属性的抓取
# BV号为1wv411i7P7的视频属性抓取结束
# 开始BV号为17p4y1i7YS视频属性的抓取
# BV号为17p4y1i7YS的视频属性抓取结束
# 开始BV号为1j64y1c7S5视频属性的抓取
# BV号为1j64y1c7S5的视频属性抓取结束
# 开始BV号为12541187Rh视频属性的抓取
# BV号为12541187Rh的视频属性抓取结束
# 开始BV号为1254y1e7Qt视频属性的抓取
# BV号为1254y1e7Qt的视频属性抓取结束
# 开始BV号为1Mh411o7pg视频属性的抓取
# BV号为1Mh411o7pg的视频属性抓取结束
# 开始BV号为18h411Z7Z8视频属性的抓取
# BV号为18h411Z7Z8的视频属性抓取结束
# 开始BV号为1DT4y157ii视频属性的抓取
# BV号为1DT4y157ii的视频属性抓取结束
# 开始BV号为1ZD4y1U7vW视频属性的抓取
# BV号为1ZD4y1U7vW的视频属性抓取结束
# 开始BV号为1uf4y1X7F2视频属性的抓取
# 开始BV号为1uf4y1X7F2视频属性的抓取
# BV号为1uf4y1X7F2的视频属性抓取结束
# 开始BV号为12f4y1Q7fd视频属性的抓取
# BV号为12f4y1Q7fd的视频属性抓取结束
# 开始BV号为1mV411z7v9视频属性的抓取
# BV号为1mV411z7v9的视频属性抓取结束
# 开始BV号为1Eh411d7BW视频属性的抓取
# BV号为1Eh411d7BW的视频属性抓取结束
# 开始BV号为17i4y1g7SQ视频属性的抓取
# BV号为17i4y1g7SQ的视频属性抓取结束
# 开始BV号为1e54y1i7qc视频属性的抓取
# BV号为1e54y1i7qc的视频属性抓取结束
# 开始BV号为1tf4y1Q7Zw视频属性的抓取
# BV号为1tf4y1Q7Zw的视频属性抓取结束
# 开始BV号为18K4y1Y78S视频属性的抓取
# BV号为18K4y1Y78S的视频属性抓取结束
# 开始BV号为1fT4y1j7Vv视频属性的抓取
# BV号为1fT4y1j7Vv的视频属性抓取结束
# 开始BV号为1xT4y1L7ei视频属性的抓取
# BV号为1xT4y1L7ei的视频属性抓取结束
# 开始BV号为1W54y1i7ga视频属性的抓取
# BV号为1W54y1i7ga的视频属性抓取结束
# 开始BV号为1KK411T7g9视频属性的抓取
# BV号为1KK411T7g9的视频属性抓取结束
# 开始BV号为1w54y1v7U9视频属性的抓取
# BV号为1w54y1v7U9的视频属性抓取结束
# 开始BV号为11y4y1C7ap视频属性的抓取
# BV号为11y4y1C7ap的视频属性抓取结束
# 开始BV号为19a4y1778G视频属性的抓取
# BV号为19a4y1778G的视频属性抓取结束
# 开始BV号为1vK4y1v7Cn视频属性的抓取
# BV号为1vK4y1v7Cn的视频属性抓取结束
# 开始BV号为1B54y1m7eS视频属性的抓取
# BV号为1B54y1m7eS的视频属性抓取结束
# 开始BV号为1dD4y1U7nS视频属性的抓取
# BV号为1dD4y1U7nS的视频属性抓取结束
# 开始BV号为1yt4y1D7EF视频属性的抓取
# BV号为1yt4y1D7EF的视频属性抓取结束
# 开始BV号为1WA411Y7XH视频属性的抓取
# BV号为1WA411Y7XH的视频属性抓取结束
# 开始BV号为1Bk4y117gv视频属性的抓取
# BV号为1Bk4y117gv的视频属性抓取结束
# 开始BV号为1Pi4y1g7uk视频属性的抓取
# BV号为1Pi4y1g7uk的视频属性抓取结束
# 开始BV号为1D64y1c7yb视频属性的抓取
# BV号为1D64y1c7yb的视频属性抓取结束
# 开始BV号为1kf4y1X79C视频属性的抓取
# BV号为1kf4y1X79C的视频属性抓取结束
# 开始BV号为1uy4y1y7Lt视频属性的抓取
# BV号为1uy4y1y7Lt的视频属性抓取结束
# 开始BV号为14a4y1J7Eo视频属性的抓取
# BV号为14a4y1J7Eo的视频属性抓取结束
# 开始BV号为1qt4y1S7QS视频属性的抓取
# BV号为1qt4y1S7QS的视频属性抓取结束
# 开始BV号为1i541187Zd视频属性的抓取
# BV号为1i541187Zd的视频属性抓取结束
# 开始BV号为1uD4y1m7fQ视频属性的抓取
# BV号为1uD4y1m7fQ的视频属性抓取结束
# 开始BV号为1Y54y1e7hk视频属性的抓取
# BV号为1Y54y1e7hk的视频属性抓取结束
# 开始BV号为1vp4y1v7CG视频属性的抓取
# BV号为1vp4y1v7CG的视频属性抓取结束
# 开始BV号为1iD4y1m79x视频属性的抓取
# BV号为1iD4y1m79x的视频属性抓取结束
# 开始BV号为1854y127d7视频属性的抓取
# BV号为1854y127d7的视频属性抓取结束
# 开始BV号为1CZ4y1M7EN视频属性的抓取
# BV号为1CZ4y1M7EN的视频属性抓取结束
# 开始BV号为19p4y1v7zh视频属性的抓取
# BV号为19p4y1v7zh的视频属性抓取结束
# 开始BV号为1ZK4y1Y7Wt视频属性的抓取
# BV号为1ZK4y1Y7Wt的视频属性抓取结束
# 开始BV号为1at4y1S7zV视频属性的抓取
# BV号为1at4y1S7zV的视频属性抓取结束
# 开始BV号为1ZZ4y1K7MU视频属性的抓取
# BV号为1ZZ4y1K7MU的视频属性抓取结束
# 开始BV号为1pV41117Cu视频属性的抓取
# BV号为1pV41117Cu的视频属性抓取结束
# 开始BV号为1Nv411y7ph视频属性的抓取
# BV号为1Nv411y7ph的视频属性抓取结束
# 开始BV号为155411j74F视频属性的抓取
# BV号为155411j74F的视频属性抓取结束
# 开始BV号为1Y5411b73D视频属性的抓取
# BV号为1Y5411b73D的视频属性抓取结束
# 开始BV号为1ka4y1j7Zq视频属性的抓取
# BV号为1ka4y1j7Zq的视频属性抓取结束
# 开始BV号为1bi4y1u7vQ视频属性的抓取
# BV号为1bi4y1u7vQ的视频属性抓取结束
# 开始BV号为1Sh411X7ft视频属性的抓取
# BV号为1Sh411X7ft的视频属性抓取结束
# 开始BV号为1oD4y1d7p8视频属性的抓取
# BV号为1oD4y1d7p8的视频属性抓取结束
# 开始BV号为1e5411b7Eh视频属性的抓取
# BV号为1e5411b7Eh的视频属性抓取结束
# 开始BV号为1Pz4y1Z7uT视频属性的抓取
# BV号为1Pz4y1Z7uT的视频属性抓取结束
# 开始BV号为16y4y1y7DJ视频属性的抓取
# BV号为16y4y1y7DJ的视频属性抓取结束
# 开始BV号为1Qp4y1Y7wn视频属性的抓取
# BV号为1Qp4y1Y7wn的视频属性抓取结束
# 开始BV号为1gK4y1a7VT视频属性的抓取
# BV号为1gK4y1a7VT的视频属性抓取结束
# 开始BV号为11v4111755视频属性的抓取
# BV号为11v4111755的视频属性抓取结束
# 开始BV号为1k5411h7Eo视频属性的抓取
# BV号为1k5411h7Eo的视频属性抓取结束
# 开始BV号为1kv41117v2视频属性的抓取
# BV号为1kv41117v2的视频属性抓取结束
# 开始BV号为1t64y1F7iy视频属性的抓取
# BV号为1t64y1F7iy的视频属性抓取结束
# 开始BV号为1kz4y1Z7sm视频属性的抓取
# BV号为1kz4y1Z7sm的视频属性抓取结束
# 开始BV号为1ch41197iN视频属性的抓取
# BV号为1ch41197iN的视频属性抓取结束
# 开始BV号为11D4y1d7nE视频属性的抓取
# BV号为11D4y1d7nE的视频属性抓取结束
# 开始BV号为1JD4y1m7Mk视频属性的抓取
# BV号为1JD4y1m7Mk的视频属性抓取结束
# 开始BV号为1Up4y1e7K5视频属性的抓取
# BV号为1Up4y1e7K5的视频属性抓取结束
# 开始BV号为1c54y1y7Y7视频属性的抓取
# BV号为1c54y1y7Y7的视频属性抓取结束
# 开始BV号为19k4y1y7aZ视频属性的抓取
# BV号为19k4y1y7aZ的视频属性抓取结束
# 开始BV号为1GK4y1Y7yn视频属性的抓取
# BV号为1GK4y1Y7yn的视频属性抓取结束
# 开始BV号为1U54y1C75q视频属性的抓取
# BV号为1U54y1C75q的视频属性抓取结束
# 开始BV号为1fk4y1y7dn视频属性的抓取
# BV号为1fk4y1y7dn的视频属性抓取结束
# 开始BV号为1X54y1y7nT视频属性的抓取
# BV号为1X54y1y7nT的视频属性抓取结束
# 开始BV号为1FA411J7oU视频属性的抓取
# BV号为1FA411J7oU的视频属性抓取结束
# 开始BV号为1fv411y74E视频属性的抓取
# BV号为1fv411y74E的视频属性抓取结束
# 开始BV号为14z4y1Z7rx视频属性的抓取
# BV号为14z4y1Z7rx的视频属性抓取结束
# 开始BV号为1N54y117Wg视频属性的抓取
# BV号为1N54y117Wg的视频属性抓取结束
# 开始BV号为1xp4y1a7ep视频属性的抓取
# BV号为1xp4y1a7ep的视频属性抓取结束
# 开始BV号为19a4y1L7kq视频属性的抓取
# BV号为19a4y1L7kq的视频属性抓取结束
# 开始BV号为1ZD4y1d7aC视频属性的抓取
# BV号为1ZD4y1d7aC的视频属性抓取结束
# 开始BV号为1VZ4y1T7Zt视频属性的抓取
# BV号为1VZ4y1T7Zt的视频属性抓取结束
# 开始BV号为1HK4y1a76R视频属性的抓取
# BV号为1HK4y1a76R的视频属性抓取结束
# 开始BV号为1Dt4y1S72v视频属性的抓取
# BV号为1Dt4y1S72v的视频属性抓取结束
# 开始BV号为1na4y1E7Qa视频属性的抓取
# BV号为1na4y1E7Qa的视频属性抓取结束
# 开始BV号为19K411K7ch视频属性的抓取
# BV号为19K411K7ch的视频属性抓取结束
# 开始BV号为13i4y1u7g2视频属性的抓取
# BV号为13i4y1u7g2的视频属性抓取结束
# 开始BV号为1RK4y1a7UL视频属性的抓取
# BV号为1RK4y1a7UL的视频属性抓取结束
# 开始BV号为16T4y1A71X视频属性的抓取
# BV号为16T4y1A71X的视频属性抓取结束
# 开始BV号为1pV41117mr视频属性的抓取
# BV号为1pV41117mr的视频属性抓取结束
# 开始BV号为1VT4y1A7ft视频属性的抓取
# BV号为1VT4y1A7ft的视频属性抓取结束
# 开始BV号为1fy4y1y7mq视频属性的抓取
# BV号为1fy4y1y7mq的视频属性抓取结束
# 开始BV号为1Bh411X7Te视频属性的抓取
# BV号为1Bh411X7Te的视频属性抓取结束
# 开始BV号为1c5411j7x7视频属性的抓取
# BV号为1c5411j7x7的视频属性抓取结束
# 开始BV号为1Nt4y1q7nt视频属性的抓取
# BV号为1Nt4y1q7nt的视频属性抓取结束
# 开始BV号为12T4y1w78b视频属性的抓取
# BV号为12T4y1w78b的视频属性抓取结束
# 开始BV号为1uZ4y1N76Q视频属性的抓取
# BV号为1uZ4y1N76Q的视频属性抓取结束
# 开始BV号为1QK4y1a7CS视频属性的抓取
# BV号为1QK4y1a7CS的视频属性抓取结束
# 开始BV号为1oh411R7wn视频属性的抓取
# BV号为1oh411R7wn的视频属性抓取结束
# 开始BV号为1tp4y1e7tt视频属性的抓取
# BV号为1tp4y1e7tt的视频属性抓取结束
# 开始BV号为1LZ4y1N7ps视频属性的抓取
# BV号为1LZ4y1N7ps的视频属性抓取结束
# 开始BV号为1cz4y1Z7NC视频属性的抓取
# BV号为1cz4y1Z7NC的视频属性抓取结束
# 开始BV号为1f5411L7H6视频属性的抓取
# BV号为1f5411L7H6的视频属性抓取结束
# 开始BV号为1rZ4y1N7Ze视频属性的抓取
# BV号为1rZ4y1N7Ze的视频属性抓取结束
# 开始BV号为1KT4y1A7GK视频属性的抓取
# BV号为1KT4y1A7GK的视频属性抓取结束
# 开始BV号为1o54y1y79r视频属性的抓取
# BV号为1o54y1y79r的视频属性抓取结束
# 开始BV号为1e54y1277w视频属性的抓取
# BV号为1e54y1277w的视频属性抓取结束
# 开始BV号为1554y1m79L视频属性的抓取
# BV号为1554y1m79L的视频属性抓取结束
# 开始BV号为1up4y1e7qg视频属性的抓取
# BV号为1up4y1e7qg的视频属性抓取结束
# 开始BV号为1ZK411N7QQ视频属性的抓取
# BV号为1ZK411N7QQ的视频属性抓取结束
# 开始BV号为1pK4y1a7Kh视频属性的抓取
# BV号为1pK4y1a7Kh的视频属性抓取结束
# 开始BV号为18p4y1a7t9视频属性的抓取
# BV号为18p4y1a7t9的视频属性抓取结束
# 开始BV号为1mZ4y1P7aF视频属性的抓取
# BV号为1mZ4y1P7aF的视频属性抓取结束
# 开始BV号为1QT4y1w74B视频属性的抓取
# BV号为1QT4y1w74B的视频属性抓取结束
# 开始BV号为1PZ4y1N768视频属性的抓取
# BV号为1PZ4y1N768的视频属性抓取结束
# 开始BV号为1Fi4y1E73C视频属性的抓取
# BV号为1Fi4y1E73C的视频属性抓取结束
# 开始BV号为1Ji4y1u7yw视频属性的抓取
# BV号为1Ji4y1u7yw的视频属性抓取结束
# 开始BV号为1B5411h7Ao视频属性的抓取
# BV号为1B5411h7Ao的视频属性抓取结束
# 开始BV号为1kD4y1o73f视频属性的抓取
# 开始BV号为1kD4y1o73f视频属性的抓取
# BV号为1kD4y1o73f的视频属性抓取结束
# 开始BV号为1Np4y1Y7TZ视频属性的抓取
# BV号为1Np4y1Y7TZ的视频属性抓取结束
# 开始BV号为1Hh41197VH视频属性的抓取
# BV号为1Hh41197VH的视频属性抓取结束
# 开始BV号为1Gk4y117YW视频属性的抓取
# BV号为1Gk4y117YW的视频属性抓取结束
# 开始BV号为1Gy4y1y78n视频属性的抓取
# BV号为1Gy4y1y78n的视频属性抓取结束
# 开始BV号为1NT4y1A7pq视频属性的抓取
# BV号为1NT4y1A7pq的视频属性抓取结束
# 开始BV号为1Cv411C7q7视频属性的抓取
# BV号为1Cv411C7q7的视频属性抓取结束
# 开始BV号为1Xh411X7kd视频属性的抓取
# BV号为1Xh411X7kd的视频属性抓取结束
# 开始BV号为1XA411E7t1视频属性的抓取
# BV号为1XA411E7t1的视频属性抓取结束
# 开始BV号为11K4y1a79h视频属性的抓取
# BV号为11K4y1a79h的视频属性抓取结束
# 开始BV号为1A5411j7xU视频属性的抓取
# BV号为1A5411j7xU的视频属性抓取结束
# 开始BV号为1V54y1v7JV视频属性的抓取
# BV号为1V54y1v7JV的视频属性抓取结束
# 开始BV号为1Ek4y117Uh视频属性的抓取
# 开始BV号为1Ek4y117Uh视频属性的抓取
# BV号为1Ek4y117Uh的视频属性抓取结束
# 开始BV号为11a4y157oa视频属性的抓取
# BV号为11a4y157oa的视频属性抓取结束
# 开始BV号为1ft4y1i7uW视频属性的抓取
# BV号为1ft4y1i7uW的视频属性抓取结束
# 开始BV号为1mi4y177BS视频属性的抓取
# BV号为1mi4y177BS的视频属性抓取结束
# 开始BV号为1iT4y1A7bX视频属性的抓取
# BV号为1iT4y1A7bX的视频属性抓取结束
# 开始BV号为1rT4y1w7WQ视频属性的抓取
# BV号为1rT4y1w7WQ的视频属性抓取结束
# 开始BV号为1hf4y1D7sA视频属性的抓取
# BV号为1hf4y1D7sA的视频属性抓取结束
# 开始BV号为16p4y1e7WJ视频属性的抓取
# BV号为16p4y1e7WJ的视频属性抓取结束
# 开始BV号为1yp4y1a7SB视频属性的抓取
# BV号为1yp4y1a7SB的视频属性抓取结束
# 开始BV号为1Nk4y117Lh视频属性的抓取
# BV号为1Nk4y117Lh的视频属性抓取结束
# 开始BV号为1JK4y1a7ze视频属性的抓取
# 开始BV号为1JK4y1a7ze视频属性的抓取
# 开始BV号为1JK4y1a7ze视频属性的抓取
# 开始BV号为1JK4y1a7ze视频属性的抓取
# BV号为1JK4y1a7ze的视频属性抓取结束
# 开始BV号为12i4y1M7Fn视频属性的抓取
# BV号为12i4y1M7Fn的视频属性抓取结束
# 开始BV号为1Az4y1Z7k5视频属性的抓取
# BV号为1Az4y1Z7k5的视频属性抓取结束
# 开始BV号为1GV411m7Mc视频属性的抓取
# BV号为1GV411m7Mc的视频属性抓取结束
# 开始BV号为1Xf4y1D7A1视频属性的抓取
# BV号为1Xf4y1D7A1的视频属性抓取结束
# 开始BV号为1tZ4y1N737视频属性的抓取
# BV号为1tZ4y1N737的视频属性抓取结束
# 开始BV号为1ca4y1s7qf视频属性的抓取
# BV号为1ca4y1s7qf的视频属性抓取结束
# 开始BV号为1yK411A7Hu视频属性的抓取
# BV号为1yK411A7Hu的视频属性抓取结束
# 开始BV号为1hk4y1C7nC视频属性的抓取
# BV号为1hk4y1C7nC的视频属性抓取结束
# 开始BV号为1Sy4y1r7uC视频属性的抓取
# BV号为1Sy4y1r7uC的视频属性抓取结束
# 开始BV号为1zt4y1v74f视频属性的抓取
# BV号为1zt4y1v74f的视频属性抓取结束
# 开始BV号为1ka411A7eN视频属性的抓取
# BV号为1ka411A7eN的视频属性抓取结束
# 开始BV号为13a4y1L7CA视频属性的抓取
# BV号为13a4y1L7CA的视频属性抓取结束
# 开始BV号为1Gp4y1k7Db视频属性的抓取
# BV号为1Gp4y1k7Db的视频属性抓取结束
# 开始BV号为1HD4y197RM视频属性的抓取
# BV号为1HD4y197RM的视频属性抓取结束
# 开始BV号为1iz4y1d7PV视频属性的抓取
# BV号为1iz4y1d7PV的视频属性抓取结束
# 开始BV号为1xK411N7yF视频属性的抓取
# BV号为1xK411N7yF的视频属性抓取结束
# 开始BV号为1nT4y1w74T视频属性的抓取
# 开始BV号为1nT4y1w74T视频属性的抓取
# BV号为1nT4y1w74T的视频属性抓取结束
# 开始BV号为1Av411r769视频属性的抓取
# BV号为1Av411r769的视频属性抓取结束
# 开始BV号为1s54y1C727视频属性的抓取
# BV号为1s54y1C727的视频属性抓取结束
# 开始BV号为1YA411774W视频属性的抓取
# BV号为1YA411774W的视频属性抓取结束
# 开始BV号为1av411k74V视频属性的抓取
# BV号为1av411k74V的视频属性抓取结束
# 开始BV号为1Wa411A7YX视频属性的抓取
# BV号为1Wa411A7YX的视频属性抓取结束
# 开始BV号为1hh41197uT视频属性的抓取
# BV号为1hh41197uT的视频属性抓取结束
# 开始BV号为1Xt4y1Y7ds视频属性的抓取
# BV号为1Xt4y1Y7ds的视频属性抓取结束
# 开始BV号为1Df4y1q7bB视频属性的抓取
# BV号为1Df4y1q7bB的视频属性抓取结束
# 开始BV号为1da4y157TH视频属性的抓取
# BV号为1da4y157TH的视频属性抓取结束
# 开始BV号为1jK4y1h7aj视频属性的抓取
# BV号为1jK4y1h7aj的视频属性抓取结束
# 开始BV号为1e5411L7PM视频属性的抓取
# BV号为1e5411L7PM的视频属性抓取结束
# 开始BV号为13V411y7MR视频属性的抓取
# BV号为13V411y7MR的视频属性抓取结束
# 开始BV号为1Fa4y1s7Re视频属性的抓取
# BV号为1Fa4y1s7Re的视频属性抓取结束
# 开始BV号为1Vr4y1w7sG视频属性的抓取
# BV号为1Vr4y1w7sG的视频属性抓取结束
# 开始BV号为1ti4y1j7E9视频属性的抓取
# BV号为1ti4y1j7E9的视频属性抓取结束
# 开始BV号为1Lz4y1y7jK视频属性的抓取
# BV号为1Lz4y1y7jK的视频属性抓取结束
# 开始BV号为1RK4y1f7mi视频属性的抓取
# BV号为1RK4y1f7mi的视频属性抓取结束
# 开始BV号为1JD4y197ju视频属性的抓取
# BV号为1JD4y197ju的视频属性抓取结束
# 开始BV号为1ai4y1E7Hj视频属性的抓取
# BV号为1ai4y1E7Hj的视频属性抓取结束
# 开始BV号为15A41177NS视频属性的抓取
# BV号为15A41177NS的视频属性抓取结束
# 开始BV号为1xZ4y1V7zB视频属性的抓取
# BV号为1xZ4y1V7zB的视频属性抓取结束
# 开始BV号为1vV411y7NW视频属性的抓取
# 开始BV号为1vV411y7NW视频属性的抓取
# BV号为1vV411y7NW的视频属性抓取结束
# 开始BV号为1DZ4y1V7Li视频属性的抓取
# BV号为1DZ4y1V7Li的视频属性抓取结束
# 开始BV号为1Bv411k7b8视频属性的抓取
# BV号为1Bv411k7b8的视频属性抓取结束
# 开始BV号为1Fv411k73E视频属性的抓取
# BV号为1Fv411k73E的视频属性抓取结束
# 开始BV号为1si4y1j7iD视频属性的抓取
# BV号为1si4y1j7iD的视频属性抓取结束
# 开始BV号为1AZ4y1V7vC视频属性的抓取
# BV号为1AZ4y1V7vC的视频属性抓取结束
# 开始BV号为1SK4y177xQ视频属性的抓取
# BV号为1SK4y177xQ的视频属性抓取结束
# 开始BV号为1vy4y1r78J视频属性的抓取
# BV号为1vy4y1r78J的视频属性抓取结束
# 开始BV号为1vT4y1F7JH视频属性的抓取
# BV号为1vT4y1F7JH的视频属性抓取结束
# 开始BV号为1xz4y1o7ik视频属性的抓取
# 开始BV号为1xz4y1o7ik视频属性的抓取
# BV号为1xz4y1o7ik的视频属性抓取结束
# 开始BV号为1kA411777N视频属性的抓取
# BV号为1kA411777N的视频属性抓取结束
# 开始BV号为1P54y1C7nA视频属性的抓取
# BV号为1P54y1C7nA的视频属性抓取结束
# 开始BV号为1ny4y1r7xf视频属性的抓取
# 开始BV号为1ny4y1r7xf视频属性的抓取
# BV号为1ny4y1r7xf的视频属性抓取结束
# 开始BV号为1uV4112796视频属性的抓取
# BV号为1uV4112796的视频属性抓取结束
# 开始BV号为1LD4y1979i视频属性的抓取
# BV号为1LD4y1979i的视频属性抓取结束
# 开始BV号为1HA411E7wU视频属性的抓取
# BV号为1HA411E7wU的视频属性抓取结束
# 开始BV号为19K4y1h72B视频属性的抓取
# BV号为19K4y1h72B的视频属性抓取结束
# 开始BV号为12f4y1i7qz视频属性的抓取
# BV号为12f4y1i7qz的视频属性抓取结束
# 开始BV号为1154y1177H视频属性的抓取
# BV号为1154y1177H的视频属性抓取结束
# 开始BV号为1Xt4y1Y79K视频属性的抓取
# BV号为1Xt4y1Y79K的视频属性抓取结束
# 开始BV号为1s54y1C79k视频属性的抓取
# BV号为1s54y1C79k的视频属性抓取结束
# 开始BV号为1J5411L745视频属性的抓取
# BV号为1J5411L745的视频属性抓取结束
# 开始BV号为1yv411k74N视频属性的抓取
# BV号为1yv411k74N的视频属性抓取结束
# 开始BV号为13v411k7jz视频属性的抓取
# BV号为13v411k7jz的视频属性抓取结束
# 开始BV号为1254y1y7u5视频属性的抓取
# BV号为1254y1y7u5的视频属性抓取结束
# 开始BV号为1zV411y7z2视频属性的抓取
# BV号为1zV411y7z2的视频属性抓取结束
# 开始BV号为1jT4y1w7AD视频属性的抓取
# BV号为1jT4y1w7AD的视频属性抓取结束
# 开始BV号为1Ka4y1s77a视频属性的抓取
# BV号为1Ka4y1s77a的视频属性抓取结束
# 开始BV号为1tZ4y157gb视频属性的抓取
# BV号为1tZ4y157gb的视频属性抓取结束
# 开始BV号为1bV41127n6视频属性的抓取
# BV号为1bV41127n6的视频属性抓取结束
# 开始BV号为1N54y1r7ap视频属性的抓取
# BV号为1N54y1r7ap的视频属性抓取结束
# 开始BV号为1tT4y1c7i7视频属性的抓取
# BV号为1tT4y1c7i7的视频属性抓取结束
# 开始BV号为1rv41167pi视频属性的抓取
# BV号为1rv41167pi的视频属性抓取结束
# 开始BV号为1QZ4y1G7xX视频属性的抓取
# BV号为1QZ4y1G7xX的视频属性抓取结束
# 开始BV号为14a4y1L7rV视频属性的抓取
# BV号为14a4y1L7rV的视频属性抓取结束
# 开始BV号为1wD4y1d7is视频属性的抓取
# BV号为1wD4y1d7is的视频属性抓取结束
# 开始BV号为18V41127D4视频属性的抓取
# BV号为18V41127D4的视频属性抓取结束
# 开始BV号为1cy4y1C7LD视频属性的抓取
# BV号为1cy4y1C7LD的视频属性抓取结束
# 开始BV号为1B54y1k7QG视频属性的抓取
# BV号为1B54y1k7QG的视频属性抓取结束
# 开始BV号为1if4y1i7hb视频属性的抓取
# BV号为1if4y1i7hb的视频属性抓取结束
# 开始BV号为1gv411k7Jo视频属性的抓取
# BV号为1gv411k7Jo的视频属性抓取结束
# 开始BV号为17i4y1j7zM视频属性的抓取
# BV号为17i4y1j7zM的视频属性抓取结束
# 开始BV号为1Np4y1Y7n9视频属性的抓取
# BV号为1Np4y1Y7n9的视频属性抓取结束
# 开始BV号为1Ga4y1s71W视频属性的抓取
# BV号为1Ga4y1s71W的视频属性抓取结束
# 开始BV号为1HZ4y1V7CJ视频属性的抓取
# BV号为1HZ4y1V7CJ的视频属性抓取结束
# 开始BV号为1KK411A7NU视频属性的抓取
# BV号为1KK411A7NU的视频属性抓取结束
# 开始BV号为1Xt4y1v7PV视频属性的抓取
# BV号为1Xt4y1v7PV的视频属性抓取结束
# 开始BV号为1wv411C7Ww视频属性的抓取
# BV号为1wv411C7Ww的视频属性抓取结束
# 开始BV号为1ni4y1j7xN视频属性的抓取
# BV号为1ni4y1j7xN的视频属性抓取结束
# 开始BV号为1e5411j7vT视频属性的抓取
# BV号为1e5411j7vT的视频属性抓取结束
# 开始BV号为1K54y1278W视频属性的抓取
# BV号为1K54y1278W的视频属性抓取结束
# 开始BV号为1Uz4y1o7VT视频属性的抓取
# BV号为1Uz4y1o7VT的视频属性抓取结束
# 开始BV号为1DK4y1779T视频属性的抓取
# BV号为1DK4y1779T的视频属性抓取结束
# 开始BV号为1fK411P7ag视频属性的抓取
# BV号为1fK411P7ag的视频属性抓取结束
# 开始BV号为1CK4y177rc视频属性的抓取
# BV号为1CK4y177rc的视频属性抓取结束
# 开始BV号为1RK411A7o5视频属性的抓取
# BV号为1RK411A7o5的视频属性抓取结束
# 开始BV号为1ZK4y187Ct视频属性的抓取
# BV号为1ZK4y187Ct的视频属性抓取结束
# 开始BV号为12f4y1i7Ug视频属性的抓取
# BV号为12f4y1i7Ug的视频属性抓取结束
# 开始BV号为1Tv411C7yp视频属性的抓取
# BV号为1Tv411C7yp的视频属性抓取结束
# 开始BV号为1Ty4y1873n视频属性的抓取
# BV号为1Ty4y1873n的视频属性抓取结束
# 开始BV号为19k4y1C7zJ视频属性的抓取
# BV号为19k4y1C7zJ的视频属性抓取结束
# 开始BV号为1Gf4y1B77L视频属性的抓取
# BV号为1Gf4y1B77L的视频属性抓取结束
# 开始BV号为19a4y1W72t视频属性的抓取
# BV号为19a4y1W72t的视频属性抓取结束
# 开始BV号为1eV41117rp视频属性的抓取
# BV号为1eV41117rp的视频属性抓取结束
# 开始BV号为13y4y187My视频属性的抓取
# BV号为13y4y187My的视频属性抓取结束
# 开始BV号为17z4y1o7yp视频属性的抓取
# BV号为17z4y1o7yp的视频属性抓取结束
# 开始BV号为1YV411274d视频属性的抓取
# BV号为1YV411274d的视频属性抓取结束
# 2020-12-17 07:51:06.149158

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-23-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_shuma_yingyin.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月   100  100  100  100  100  100   100
# 2月   100  100  100  100  100  100   100
# 3月   100  100  100  100  100  100   100
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月   100  100  100  100  100  100   100
# 7月   100  100  100  100  100  100   100
# 8月   100  100  100  100  100  100   100
# 9月   100  100  100  100  100  100   100

# %%
channel_shuma_yingyin.to_json('channel_shuma_yingyin.json')

# %%
pd.set_option('display.max_rows', None)

# %%
channel_youxi_danji[channel_youxi_danji['时间']=='4月']
# Out:
#             时间            作者名  作者类型      粉丝数   投稿数  \
# 1h54y1d7Qq  4月            鹤吱菌  个人认证   191.3万    81
# 1L64y1M7Dp  4月            老番茄  个人认证  1360.1万   348
# 18K41157Tu  4月            老番茄  个人认证  1360.1万   348
# 1PT4y1G7ME  4月            老番茄  个人认证  1360.1万   348
# 1S54y197uX  4月           徐大虾咯  个人认证   570.1万   224
# 1ti4y1t7YM  4月            老番茄  个人认证  1360.1万   348
