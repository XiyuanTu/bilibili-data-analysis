# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_yinyue_xianchang=pd.DataFrame(columns=columns)
channel_yinyue_xianchang
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[3]/div/a/span').click()  #选择“音乐”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[3]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '音乐'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[8]/a').click()  #选择“音乐综合”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[8]/a').text
sub_channel
# Out:
# '音乐现场'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(1,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_yinyue_xianchang.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-20 19:34:24.961223
# <ipython-input-9-a1b20a4f7284>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-9-a1b20a4f7284>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-9-a1b20a4f7284>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1Z7411B7uD视频属性的抓取
# BV号为1Z7411B7uD的视频属性抓取结束
# <ipython-input-9-a1b20a4f7284>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1k7411k79Q视频属性的抓取
# BV号为1k7411k79Q的视频属性抓取结束
# 开始BV号为1HJ411p7WK视频属性的抓取
# BV号为1HJ411p7WK的视频属性抓取结束
# 开始BV号为1C7411q7QY视频属性的抓取
# BV号为1C7411q7QY的视频属性抓取结束
# 开始BV号为1T7411r7UE视频属性的抓取
# BV号为1T7411r7UE的视频属性抓取结束
# 开始BV号为1EJ411H77v视频属性的抓取
# BV号为1EJ411H77v的视频属性抓取结束
# 开始BV号为1YJ411p7ZH视频属性的抓取
# BV号为1YJ411p7ZH的视频属性抓取结束
# 开始BV号为18J411p7Ln视频属性的抓取
# BV号为18J411p7Ln的视频属性抓取结束
# 开始BV号为1M7411k7bH视频属性的抓取
# BV号为1M7411k7bH的视频属性抓取结束
# 开始BV号为187411z7kp视频属性的抓取
# BV号为187411z7kp的视频属性抓取结束
# 开始BV号为1LJ41187Hf视频属性的抓取
# BV号为1LJ41187Hf的视频属性抓取结束
# 开始BV号为1R7411k7D3视频属性的抓取
# BV号为1R7411k7D3的视频属性抓取结束
# 开始BV号为1EJ41187XS视频属性的抓取
# BV号为1EJ41187XS的视频属性抓取结束
# 开始BV号为1jJ411b7fx视频属性的抓取
# BV号为1jJ411b7fx的视频属性抓取结束
# 开始BV号为1GJ411p7UZ视频属性的抓取
# BV号为1GJ411p7UZ的视频属性抓取结束
# 开始BV号为14J411J7HL视频属性的抓取
# BV号为14J411J7HL的视频属性抓取结束
# 开始BV号为1pJ411E7hc视频属性的抓取
# BV号为1pJ411E7hc的视频属性抓取结束
# 开始BV号为1a7411z7m7视频属性的抓取
# BV号为1a7411z7m7的视频属性抓取结束
# 开始BV号为1MJ411H7HN视频属性的抓取
# BV号为1MJ411H7HN的视频属性抓取结束
# 开始BV号为13J411L7uC视频属性的抓取
# BV号为13J411L7uC的视频属性抓取结束
# 开始BV号为1JJ411b7Gf视频属性的抓取
# BV号为1JJ411b7Gf的视频属性抓取结束
# 开始BV号为12J411p7S7视频属性的抓取
# BV号为12J411p7S7的视频属性抓取结束
# 开始BV号为1nJ411b7eH视频属性的抓取
# BV号为1nJ411b7eH的视频属性抓取结束
# 开始BV号为1BJ411J7pA视频属性的抓取
# BV号为1BJ411J7pA的视频属性抓取结束
# 开始BV号为1zJ411b7Kp视频属性的抓取
# BV号为1zJ411b7Kp的视频属性抓取结束
# 开始BV号为1zJ411b7SM视频属性的抓取
# BV号为1zJ411b7SM的视频属性抓取结束
# 开始BV号为1PJ41177bC视频属性的抓取
# BV号为1PJ41177bC的视频属性抓取结束
# 开始BV号为1JJ411b7gX视频属性的抓取
# BV号为1JJ411b7gX的视频属性抓取结束
# 开始BV号为1oJ411G74V视频属性的抓取
# BV号为1oJ411G74V的视频属性抓取结束
# 开始BV号为1a7411r7u5视频属性的抓取
# BV号为1a7411r7u5的视频属性抓取结束
# 开始BV号为1BJ411J7se视频属性的抓取
# BV号为1BJ411J7se的视频属性抓取结束
# 开始BV号为1kJ411L7JF视频属性的抓取
# BV号为1kJ411L7JF的视频属性抓取结束
# 开始BV号为1z741167JW视频属性的抓取
# BV号为1z741167JW的视频属性抓取结束
# 开始BV号为1KJ41177sg视频属性的抓取
# BV号为1KJ41177sg的视频属性抓取结束
# 开始BV号为17J411j7h6视频属性的抓取
# BV号为17J411j7h6的视频属性抓取结束
# 开始BV号为13J411H7VQ视频属性的抓取
# BV号为13J411H7VQ的视频属性抓取结束
# 开始BV号为1F7411r7Mn视频属性的抓取
# BV号为1F7411r7Mn的视频属性抓取结束
# 开始BV号为1pJ411b78h视频属性的抓取
# BV号为1pJ411b78h的视频属性抓取结束
# 开始BV号为1SJ411G7sB视频属性的抓取
# BV号为1SJ411G7sB的视频属性抓取结束
# 开始BV号为1JJ411b7AV视频属性的抓取
# BV号为1JJ411b7AV的视频属性抓取结束
# 开始BV号为1XJ411G77u视频属性的抓取
# BV号为1XJ411G77u的视频属性抓取结束
# 开始BV号为1nJ411b7dn视频属性的抓取
# BV号为1nJ411b7dn的视频属性抓取结束
# 开始BV号为1c7411r75T视频属性的抓取
# BV号为1c7411r75T的视频属性抓取结束
# 开始BV号为1D7411e74K视频属性的抓取
# BV号为1D7411e74K的视频属性抓取结束
# 开始BV号为1uJ411j7Ua视频属性的抓取
# BV号为1uJ411j7Ua的视频属性抓取结束
# 开始BV号为1NJ41177Ci视频属性的抓取
# BV号为1NJ41177Ci的视频属性抓取结束
# 开始BV号为1sJ411L7yd视频属性的抓取
# BV号为1sJ411L7yd的视频属性抓取结束
# 开始BV号为1C741167nY视频属性的抓取
# BV号为1C741167nY的视频属性抓取结束
# 开始BV号为15J411L7p5视频属性的抓取
# BV号为15J411L7p5的视频属性抓取结束
# 开始BV号为1yJ411V7rp视频属性的抓取
# BV号为1yJ411V7rp的视频属性抓取结束
# 开始BV号为15J411p7iB视频属性的抓取
# BV号为15J411p7iB的视频属性抓取结束
# 开始BV号为1oJ41157rT视频属性的抓取
# BV号为1oJ41157rT的视频属性抓取结束
# 开始BV号为1PJ411577U视频属性的抓取
# BV号为1PJ411577U的视频属性抓取结束
# 开始BV号为1a7411q7vB视频属性的抓取
# BV号为1a7411q7vB的视频属性抓取结束
# 开始BV号为1xJ411p74k视频属性的抓取
# BV号为1xJ411p74k的视频属性抓取结束
# 开始BV号为147411B7fW视频属性的抓取
# BV号为147411B7fW的视频属性抓取结束
# 开始BV号为1MJ411H7HL视频属性的抓取
# BV号为1MJ411H7HL的视频属性抓取结束
# 开始BV号为1nJ411b7fz视频属性的抓取
# BV号为1nJ411b7fz的视频属性抓取结束
# 开始BV号为1VJ411b79j视频属性的抓取
# BV号为1VJ411b79j的视频属性抓取结束
# 开始BV号为1GJ41177zg视频属性的抓取
# BV号为1GJ41177zg的视频属性抓取结束
# 开始BV号为1X7411q7N2视频属性的抓取
# BV号为1X7411q7N2的视频属性抓取结束
# 开始BV号为1pJ411V7qG视频属性的抓取
# BV号为1pJ411V7qG的视频属性抓取结束
# 开始BV号为117411B7DJ视频属性的抓取
# BV号为117411B7DJ的视频属性抓取结束
# 开始BV号为1pJ411n758视频属性的抓取
# BV号为1pJ411n758的视频属性抓取结束
# 开始BV号为1X7411z7kx视频属性的抓取
# BV号为1X7411z7kx的视频属性抓取结束
# 开始BV号为14J411n7H9视频属性的抓取
# BV号为14J411n7H9的视频属性抓取结束
# 开始BV号为1kJ411H7Zt视频属性的抓取
# BV号为1kJ411H7Zt的视频属性抓取结束
# 开始BV号为1N741167t2视频属性的抓取
# BV号为1N741167t2的视频属性抓取结束
# 开始BV号为1uJ411E7S8视频属性的抓取
# BV号为1uJ411E7S8的视频属性抓取结束
# 开始BV号为19J411b7XL视频属性的抓取
# BV号为19J411b7XL的视频属性抓取结束
# 开始BV号为1vJ411n78V视频属性的抓取
# BV号为1vJ411n78V的视频属性抓取结束
# 开始BV号为12J411p72X视频属性的抓取
# BV号为12J411p72X的视频属性抓取结束
# 开始BV号为1XJ411E7EP视频属性的抓取
# BV号为1XJ411E7EP的视频属性抓取结束
# 开始BV号为11J411h7uu视频属性的抓取
# BV号为11J411h7uu的视频属性抓取结束
# 开始BV号为137411Y7hG视频属性的抓取
# BV号为137411Y7hG的视频属性抓取结束
# 开始BV号为1T741167SB视频属性的抓取
# BV号为1T741167SB的视频属性抓取结束
# 开始BV号为17J411b7uC视频属性的抓取
# BV号为17J411b7uC的视频属性抓取结束
# 开始BV号为1gJ411L7DY视频属性的抓取
# BV号为1gJ411L7DY的视频属性抓取结束
# 开始BV号为1K7411q7sW视频属性的抓取
# BV号为1K7411q7sW的视频属性抓取结束
# 开始BV号为1oJ411L75G视频属性的抓取
# BV号为1oJ411L75G的视频属性抓取结束
# 开始BV号为1wJ41157oD视频属性的抓取
# BV号为1wJ41157oD的视频属性抓取结束
# 开始BV号为1JJ411b7Dd视频属性的抓取
# BV号为1JJ411b7Dd的视频属性抓取结束
# 开始BV号为17741167Sr视频属性的抓取
# BV号为17741167Sr的视频属性抓取结束
# 开始BV号为1c7411q7Kn视频属性的抓取
# BV号为1c7411q7Kn的视频属性抓取结束
# 开始BV号为1oJ41177Zt视频属性的抓取
# BV号为1oJ41177Zt的视频属性抓取结束
# 开始BV号为1e7411i7Y9视频属性的抓取
# BV号为1e7411i7Y9的视频属性抓取结束
# 开始BV号为1uJ41187YP视频属性的抓取
# BV号为1uJ41187YP的视频属性抓取结束
# 开始BV号为1dJ41157EY视频属性的抓取
# BV号为1dJ41157EY的视频属性抓取结束
# 开始BV号为1rJ411E76h视频属性的抓取
# BV号为1rJ411E76h的视频属性抓取结束
# 开始BV号为1qJ411G7zy视频属性的抓取
# BV号为1qJ411G7zy的视频属性抓取结束
# 开始BV号为1aJ411b77D视频属性的抓取
# BV号为1aJ411b77D的视频属性抓取结束
# 开始BV号为1iJ411n7Qd视频属性的抓取
# BV号为1iJ411n7Qd的视频属性抓取结束
# 开始BV号为12J411H7xt视频属性的抓取
# BV号为12J411H7xt的视频属性抓取结束
# 开始BV号为1cJ41177La视频属性的抓取
# BV号为1cJ41177La的视频属性抓取结束
# 开始BV号为1eJ41187jn视频属性的抓取
# BV号为1eJ41187jn的视频属性抓取结束
# 开始BV号为1fJ411V7iy视频属性的抓取
# BV号为1fJ411V7iy的视频属性抓取结束
# 开始BV号为1m7411r7gR视频属性的抓取
# BV号为1m7411r7gR的视频属性抓取结束
# 开始BV号为1WJ41187vC视频属性的抓取
# BV号为1WJ41187vC的视频属性抓取结束
# 开始BV号为1U7411v7Bn视频属性的抓取
# BV号为1U7411v7Bn的视频属性抓取结束
# 开始BV号为1i7411r7Er视频属性的抓取
# BV号为1i7411r7Er的视频属性抓取结束
# 开始BV号为1M7411n7rM视频属性的抓取
# BV号为1M7411n7rM的视频属性抓取结束
# 开始BV号为1k7411g7HS视频属性的抓取
# BV号为1k7411g7HS的视频属性抓取结束
# 开始BV号为1j7411V7Pv视频属性的抓取
# BV号为1j7411V7Pv的视频属性抓取结束
# 开始BV号为1k7411T7T6视频属性的抓取
# BV号为1k7411T7T6的视频属性抓取结束
# <ipython-input-9-a1b20a4f7284>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1A7411574g视频属性的抓取
# BV号为1A7411574g的视频属性抓取结束
# 开始BV号为1u7411F7t7视频属性的抓取
# BV号为1u7411F7t7的视频属性抓取结束
# 开始BV号为1F7411E71A视频属性的抓取
# BV号为1F7411E71A的视频属性抓取结束
# 开始BV号为1D7411s7qB视频属性的抓取
# BV号为1D7411s7qB的视频属性抓取结束
# 开始BV号为1J7411T73S视频属性的抓取
# BV号为1J7411T73S的视频属性抓取结束
# 开始BV号为1q7411x7Sq视频属性的抓取
# BV号为1q7411x7Sq的视频属性抓取结束
# 开始BV号为187411W7SK视频属性的抓取
# BV号为187411W7SK的视频属性抓取结束
# 开始BV号为1z7411476Z视频属性的抓取
# BV号为1z7411476Z的视频属性抓取结束
# 开始BV号为1r7411W7bc视频属性的抓取
# BV号为1r7411W7bc的视频属性抓取结束
# 开始BV号为1M7411s7MB视频属性的抓取
# BV号为1M7411s7MB的视频属性抓取结束
# 开始BV号为1T7411G7Es视频属性的抓取
# BV号为1T7411G7Es的视频属性抓取结束
# 开始BV号为1k7411h7wq视频属性的抓取
# BV号为1k7411h7wq的视频属性抓取结束
# 开始BV号为1Y741187T8视频属性的抓取
# BV号为1Y741187T8的视频属性抓取结束
# 开始BV号为1J7411s7ZY视频属性的抓取
# BV号为1J7411s7ZY的视频属性抓取结束
# 开始BV号为1C741137mN视频属性的抓取
# BV号为1C741137mN的视频属性抓取结束
# 开始BV号为18741147dH视频属性的抓取
# BV号为18741147dH的视频属性抓取结束
# 开始BV号为127411j76D视频属性的抓取
# BV号为127411j76D的视频属性抓取结束
# 开始BV号为1n7411H7qG视频属性的抓取
# BV号为1n7411H7qG的视频属性抓取结束
# 开始BV号为1T7411875V视频属性的抓取
# BV号为1T7411875V的视频属性抓取结束
# 开始BV号为1N741157dD视频属性的抓取
# BV号为1N741157dD的视频属性抓取结束
# 开始BV号为1D7411p75g视频属性的抓取
# BV号为1D7411p75g的视频属性抓取结束
# 开始BV号为1r7411K7jA视频属性的抓取
# BV号为1r7411K7jA的视频属性抓取结束
# 开始BV号为137411n7hY视频属性的抓取
# BV号为137411n7hY的视频属性抓取结束
# 开始BV号为1i7411H75p视频属性的抓取
# BV号为1i7411H75p的视频属性抓取结束
# 开始BV号为1f74113766视频属性的抓取
# BV号为1f74113766的视频属性抓取结束
# 开始BV号为1n7411W731视频属性的抓取
# BV号为1n7411W731的视频属性抓取结束
# 开始BV号为197411b7Bf视频属性的抓取
# BV号为197411b7Bf的视频属性抓取结束
# 开始BV号为1P741187CB视频属性的抓取
# BV号为1P741187CB的视频属性抓取结束
# 开始BV号为1G7411w7PT视频属性的抓取
# BV号为1G7411w7PT的视频属性抓取结束
# 开始BV号为1P7411a7o5视频属性的抓取
# BV号为1P7411a7o5的视频属性抓取结束
# 开始BV号为1Z741157r4视频属性的抓取
# BV号为1Z741157r4的视频属性抓取结束
# 开始BV号为1H7411n7JM视频属性的抓取
# BV号为1H7411n7JM的视频属性抓取结束
# 开始BV号为1P7411L7VJ视频属性的抓取
# BV号为1P7411L7VJ的视频属性抓取结束
# 开始BV号为1W7411n7gH视频属性的抓取
# BV号为1W7411n7gH的视频属性抓取结束
# 开始BV号为13E411J7HW视频属性的抓取
# BV号为13E411J7HW的视频属性抓取结束
# 开始BV号为1G7411M7s3视频属性的抓取
# BV号为1G7411M7s3的视频属性抓取结束
# 开始BV号为1h7411K7k7视频属性的抓取
# BV号为1h7411K7k7的视频属性抓取结束
# 开始BV号为147411H7Pp视频属性的抓取
# BV号为147411H7Pp的视频属性抓取结束
# 开始BV号为1R7411h7f9视频属性的抓取
# BV号为1R7411h7f9的视频属性抓取结束
# <ipython-input-9-a1b20a4f7284>:190: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1Q7411A7SG视频属性的抓取
# BV号为1Q7411A7SG的视频属性抓取结束
# 开始BV号为1f7411P79d视频属性的抓取
# BV号为1f7411P79d的视频属性抓取结束
# 开始BV号为1z741157Fj视频属性的抓取
# BV号为1z741157Fj的视频属性抓取结束
# 开始BV号为1U7411W7Uv视频属性的抓取
# BV号为1U7411W7Uv的视频属性抓取结束
# 开始BV号为1f741187TR视频属性的抓取
# BV号为1f741187TR的视频属性抓取结束
# 开始BV号为1g741157Bw视频属性的抓取
# BV号为1g741157Bw的视频属性抓取结束
# 开始BV号为1R7411L7Nc视频属性的抓取
# BV号为1R7411L7Nc的视频属性抓取结束
# 开始BV号为1F741137pj视频属性的抓取
# BV号为1F741137pj的视频属性抓取结束
# 开始BV号为1p7411w7Jt视频属性的抓取
# BV号为1p7411w7Jt的视频属性抓取结束
# 开始BV号为1o7411F7v5视频属性的抓取
# BV号为1o7411F7v5的视频属性抓取结束
# 开始BV号为11E411n7FQ视频属性的抓取
# BV号为11E411n7FQ的视频属性抓取结束
# 开始BV号为1E7411J7Rh视频属性的抓取
# BV号为1E7411J7Rh的视频属性抓取结束
# 开始BV号为1tj411f7Qa视频属性的抓取
# BV号为1tj411f7Qa的视频属性抓取结束
# 开始BV号为1j7411t7y3视频属性的抓取
# BV号为1j7411t7y3的视频属性抓取结束
# 开始BV号为1s7411x7Ar视频属性的抓取
# BV号为1s7411x7Ar的视频属性抓取结束
# 开始BV号为1L7411c7jf视频属性的抓取
# BV号为1L7411c7jf的视频属性抓取结束
# 开始BV号为1E7411b7uB视频属性的抓取
# BV号为1E7411b7uB的视频属性抓取结束
# 开始BV号为1u7411h7WH视频属性的抓取
# BV号为1u7411h7WH的视频属性抓取结束
# 开始BV号为1o7411W7CF视频属性的抓取
# BV号为1o7411W7CF的视频属性抓取结束
# 开始BV号为1o7411J7uz视频属性的抓取
# BV号为1o7411J7uz的视频属性抓取结束
# 开始BV号为1m7411W7Ap视频属性的抓取
# BV号为1m7411W7Ap的视频属性抓取结束
# 开始BV号为1a7411b7Ai视频属性的抓取
# BV号为1a7411b7Ai的视频属性抓取结束
# 开始BV号为1U7411J72A视频属性的抓取
# BV号为1U7411J72A的视频属性抓取结束
# 开始BV号为1V7411h7RT视频属性的抓取
# BV号为1V7411h7RT的视频属性抓取结束
# 开始BV号为1Dj411f7n8视频属性的抓取
# BV号为1Dj411f7n8的视频属性抓取结束
# 开始BV号为1A7411F7rD视频属性的抓取
# BV号为1A7411F7rD的视频属性抓取结束
# 开始BV号为127411p7dj视频属性的抓取
# BV号为127411p7dj的视频属性抓取结束
# 开始BV号为1w7411c7eT视频属性的抓取
# BV号为1w7411c7eT的视频属性抓取结束
# 开始BV号为1Y7411p7Tq视频属性的抓取
# BV号为1Y7411p7Tq的视频属性抓取结束
# 开始BV号为14741137zS视频属性的抓取
# BV号为14741137zS的视频属性抓取结束
# 开始BV号为1o7411W7WK视频属性的抓取
# BV号为1o7411W7WK的视频属性抓取结束
# 开始BV号为1o7411V7ry视频属性的抓取
# BV号为1o7411V7ry的视频属性抓取结束
# 开始BV号为1H7411J7pN视频属性的抓取
# BV号为1H7411J7pN的视频属性抓取结束
# 开始BV号为187411s7Rx视频属性的抓取
# BV号为187411s7Rx的视频属性抓取结束
# 开始BV号为117411F7cb视频属性的抓取
# BV号为117411F7cb的视频属性抓取结束
# 开始BV号为1L7411F7bN视频属性的抓取
# BV号为1L7411F7bN的视频属性抓取结束
# 开始BV号为1o7411t7zK视频属性的抓取
# BV号为1o7411t7zK的视频属性抓取结束
# 开始BV号为1Q741157yC视频属性的抓取
# BV号为1Q741157yC的视频属性抓取结束
# 开始BV号为1b7411n7XC视频属性的抓取
# BV号为1b7411n7XC的视频属性抓取结束
# 开始BV号为1k7411H7UT视频属性的抓取
# BV号为1k7411H7UT的视频属性抓取结束
# 开始BV号为1k7411V76u视频属性的抓取
# BV号为1k7411V76u的视频属性抓取结束
# 开始BV号为1a7411n7gZ视频属性的抓取
# BV号为1a7411n7gZ的视频属性抓取结束
# 开始BV号为1M7411A7P7视频属性的抓取
# BV号为1M7411A7P7的视频属性抓取结束
# 开始BV号为1q7411j7MP视频属性的抓取
# BV号为1q7411j7MP的视频属性抓取结束
# 开始BV号为1t7411u785视频属性的抓取
# BV号为1t7411u785的视频属性抓取结束
# 开始BV号为1B7411A7QU视频属性的抓取
# BV号为1B7411A7QU的视频属性抓取结束
# 开始BV号为1Z741157So视频属性的抓取
# BV号为1Z741157So的视频属性抓取结束
# 开始BV号为1M7411b7Jz视频属性的抓取
# BV号为1M7411b7Jz的视频属性抓取结束
# 开始BV号为1a7411E7Jb视频属性的抓取
# BV号为1a7411E7Jb的视频属性抓取结束
# 开始BV号为1d7411K7FS视频属性的抓取
# BV号为1d7411K7FS的视频属性抓取结束
# 开始BV号为1T7411u7Dx视频属性的抓取
# BV号为1T7411u7Dx的视频属性抓取结束
# 开始BV号为1z7411P7Dr视频属性的抓取
# BV号为1z7411P7Dr的视频属性抓取结束
# 开始BV号为1g7411b77n视频属性的抓取
# BV号为1g7411b77n的视频属性抓取结束
# 开始BV号为1u741117Ps视频属性的抓取
# BV号为1u741117Ps的视频属性抓取结束
# 开始BV号为19E411E7N4视频属性的抓取
# BV号为19E411E7N4的视频属性抓取结束
# 开始BV号为1kE411T7bS视频属性的抓取
# BV号为1kE411T7bS的视频属性抓取结束
# 开始BV号为1b7411Z72Q视频属性的抓取
# BV号为1b7411Z72Q的视频属性抓取结束
# 开始BV号为1r541147Hp视频属性的抓取
# BV号为1r541147Hp的视频属性抓取结束
# 开始BV号为1PE411x7jx视频属性的抓取
# BV号为1PE411x7jx的视频属性抓取结束
# 开始BV号为1z741197zW视频属性的抓取
# BV号为1z741197zW的视频属性抓取结束
# 开始BV号为1SE411P7ho视频属性的抓取
# BV号为1SE411P7ho的视频属性抓取结束
# 开始BV号为177411d7K5视频属性的抓取
# BV号为177411d7K5的视频属性抓取结束
# 开始BV号为19E411371c视频属性的抓取
# BV号为19E411371c的视频属性抓取结束
# 开始BV号为127411C7k5视频属性的抓取
# BV号为127411C7k5的视频属性抓取结束
# 开始BV号为1xE411p7DL视频属性的抓取
# BV号为1xE411p7DL的视频属性抓取结束
# 开始BV号为1iE411373t视频属性的抓取
# BV号为1iE411373t的视频属性抓取结束
# 开始BV号为1qE411G7kD视频属性的抓取
# BV号为1qE411G7kD的视频属性抓取结束
# 开始BV号为16g4y1b7Gu视频属性的抓取
# BV号为16g4y1b7Gu的视频属性抓取结束
# 开始BV号为1HZ4y1j7q1视频属性的抓取
# BV号为1HZ4y1j7q1的视频属性抓取结束
# 开始BV号为1fE411w7gn视频属性的抓取
# BV号为1fE411w7gn的视频属性抓取结束
# 开始BV号为1zE411J7QG视频属性的抓取
# BV号为1zE411J7QG的视频属性抓取结束
# 开始BV号为1m7411R7rv视频属性的抓取
# BV号为1m7411R7rv的视频属性抓取结束
# 开始BV号为1LE411M7SM视频属性的抓取
# BV号为1LE411M7SM的视频属性抓取结束
# 开始BV号为1qE411x72B视频属性的抓取
# BV号为1qE411x72B的视频属性抓取结束
# 开始BV号为1BE411c79n视频属性的抓取
# BV号为1BE411c79n的视频属性抓取结束
# 开始BV号为13E411T7rj视频属性的抓取
# BV号为13E411T7rj的视频属性抓取结束
# 开始BV号为1X7411Q7jK视频属性的抓取
# BV号为1X7411Q7jK的视频属性抓取结束
# 开始BV号为1W7411Q7v2视频属性的抓取
# BV号为1W7411Q7v2的视频属性抓取结束
# 开始BV号为1gE411J79C视频属性的抓取
# BV号为1gE411J79C的视频属性抓取结束
# 开始BV号为1xE411u7AX视频属性的抓取
# BV号为1xE411u7AX的视频属性抓取结束
# 开始BV号为1UE411N7SF视频属性的抓取
# BV号为1UE411N7SF的视频属性抓取结束
# 开始BV号为14E411j77g视频属性的抓取
# BV号为14E411j77g的视频属性抓取结束
# 开始BV号为1xE4115755视频属性的抓取
# BV号为1xE4115755的视频属性抓取结束
# 开始BV号为17E411G7p4视频属性的抓取
# BV号为17E411G7p4的视频属性抓取结束
# 开始BV号为1PE411P7Qu视频属性的抓取
# BV号为1PE411P7Qu的视频属性抓取结束
# 开始BV号为1wE411V7De视频属性的抓取
# BV号为1wE411V7De的视频属性抓取结束
# 开始BV号为1iE41177ZF视频属性的抓取
# BV号为1iE41177ZF的视频属性抓取结束
# 开始BV号为1p741127f8视频属性的抓取
# BV号为1p741127f8的视频属性抓取结束
# 开始BV号为1fE411E7ZJ视频属性的抓取
# BV号为1fE411E7ZJ的视频属性抓取结束
# 开始BV号为1jE411n7zD视频属性的抓取
# BV号为1jE411n7zD的视频属性抓取结束
# 开始BV号为1wE411A736视频属性的抓取
# BV号为1wE411A736的视频属性抓取结束
# 开始BV号为1PE411E7dj视频属性的抓取
# BV号为1PE411E7dj的视频属性抓取结束
# 开始BV号为1e7411o7qR视频属性的抓取
# BV号为1e7411o7qR的视频属性抓取结束
# 开始BV号为1dE411s75G视频属性的抓取
# BV号为1dE411s75G的视频属性抓取结束
# 开始BV号为1hE411T7HL视频属性的抓取
# BV号为1hE411T7HL的视频属性抓取结束
# 开始BV号为1PE41177e6视频属性的抓取
# BV号为1PE41177e6的视频属性抓取结束
# 开始BV号为1KE411M715视频属性的抓取
# 开始BV号为1KE411M715视频属性的抓取
# BV号为1KE411M715的视频属性抓取结束
# 开始BV号为1JE411j7KK视频属性的抓取
# BV号为1JE411j7KK的视频属性抓取结束
# 开始BV号为1PE411V7mu视频属性的抓取
# BV号为1PE411V7mu的视频属性抓取结束
# 开始BV号为1PE411s7sL视频属性的抓取
# BV号为1PE411s7sL的视频属性抓取结束
# 开始BV号为1NE411A7yb视频属性的抓取
# BV号为1NE411A7yb的视频属性抓取结束
# 开始BV号为1GE41137ye视频属性的抓取
# BV号为1GE41137ye的视频属性抓取结束
# 开始BV号为1yE411s7bo视频属性的抓取
# 开始BV号为1yE411s7bo视频属性的抓取
# BV号为1yE411s7bo的视频属性抓取结束
# 开始BV号为1DE411T7X3视频属性的抓取
# BV号为1DE411T7X3的视频属性抓取结束
# 开始BV号为1xE41147ET视频属性的抓取
# BV号为1xE41147ET的视频属性抓取结束
# 开始BV号为1i7411d7hv视频属性的抓取
# BV号为1i7411d7hv的视频属性抓取结束
# 开始BV号为1D7411X7CJ视频属性的抓取
# BV号为1D7411X7CJ的视频属性抓取结束
# 开始BV号为1v7411y7kL视频属性的抓取
# BV号为1v7411y7kL的视频属性抓取结束
# 开始BV号为1U7411d7co视频属性的抓取
# BV号为1U7411d7co的视频属性抓取结束
# 开始BV号为1mE411E7qQ视频属性的抓取
# BV号为1mE411E7qQ的视频属性抓取结束
# 开始BV号为1t7411Z7Bh视频属性的抓取
# BV号为1t7411Z7Bh的视频属性抓取结束
# 开始BV号为17E411T7iE视频属性的抓取
# BV号为17E411T7iE的视频属性抓取结束
# 开始BV号为1ME411T72B视频属性的抓取
# BV号为1ME411T72B的视频属性抓取结束
# 开始BV号为1NE411g7tj视频属性的抓取
# BV号为1NE411g7tj的视频属性抓取结束
# 开始BV号为1W7411f7L9视频属性的抓取
# BV号为1W7411f7L9的视频属性抓取结束
# 开始BV号为1KE411g7dX视频属性的抓取
# BV号为1KE411g7dX的视频属性抓取结束
# 开始BV号为1v7411S75Q视频属性的抓取
# BV号为1v7411S75Q的视频属性抓取结束
# 开始BV号为1oE411L7mE视频属性的抓取
# BV号为1oE411L7mE的视频属性抓取结束
# 开始BV号为1eE41177cT视频属性的抓取
# BV号为1eE41177cT的视频属性抓取结束
# 开始BV号为1nE41177gb视频属性的抓取
# BV号为1nE41177gb的视频属性抓取结束
# 开始BV号为1ME41157E5视频属性的抓取
# BV号为1ME41157E5的视频属性抓取结束
# 开始BV号为1Y7411D7R5视频属性的抓取
# BV号为1Y7411D7R5的视频属性抓取结束
# 开始BV号为1xE411w7PJ视频属性的抓取
# BV号为1xE411w7PJ的视频属性抓取结束
# 开始BV号为14E411478T视频属性的抓取
# BV号为14E411478T的视频属性抓取结束
# 开始BV号为1cE411w7Tj视频属性的抓取
# BV号为1cE411w7Tj的视频属性抓取结束
# 开始BV号为1JE411V72W视频属性的抓取
# BV号为1JE411V72W的视频属性抓取结束
# 开始BV号为1xE41137wU视频属性的抓取
# BV号为1xE41137wU的视频属性抓取结束
# 开始BV号为1x741117wy视频属性的抓取
# BV号为1x741117wy的视频属性抓取结束
# 开始BV号为14E411j7iC视频属性的抓取
# BV号为14E411j7iC的视频属性抓取结束
# 开始BV号为1KE411w7Sg视频属性的抓取
# BV号为1KE411w7Sg的视频属性抓取结束
# 开始BV号为1iE411M76a视频属性的抓取
# BV号为1iE411M76a的视频属性抓取结束
# 开始BV号为1H7411Z79t视频属性的抓取
# BV号为1H7411Z79t的视频属性抓取结束
# 开始BV号为1oE411P7mf视频属性的抓取
# BV号为1oE411P7mf的视频属性抓取结束
# 开始BV号为1b7411y7zp视频属性的抓取
# BV号为1b7411y7zp的视频属性抓取结束
# 开始BV号为1mE411N7F8视频属性的抓取
# BV号为1mE411N7F8的视频属性抓取结束
# 开始BV号为1gp4y1C7Fy视频属性的抓取
# BV号为1gp4y1C7Fy的视频属性抓取结束
# 开始BV号为1xE411E76P视频属性的抓取
# BV号为1xE411E76P的视频属性抓取结束
# 开始BV号为1GE411x7qv视频属性的抓取
# BV号为1GE411x7qv的视频属性抓取结束
# 开始BV号为1EE411T7Lh视频属性的抓取
# BV号为1EE411T7Lh的视频属性抓取结束
# 开始BV号为1BE411W7zE视频属性的抓取
# BV号为1BE411W7zE的视频属性抓取结束
# 开始BV号为1E7411d7dN视频属性的抓取
# BV号为1E7411d7dN的视频属性抓取结束
# 开始BV号为1w741117xg视频属性的抓取
# BV号为1w741117xg的视频属性抓取结束
# 开始BV号为14E411V7TD视频属性的抓取
# BV号为14E411V7TD的视频属性抓取结束
# 开始BV号为1q741197jA视频属性的抓取
# BV号为1q741197jA的视频属性抓取结束
# 开始BV号为1k7411C7j6视频属性的抓取
# BV号为1k7411C7j6的视频属性抓取结束
# 开始BV号为1hE411j7ox视频属性的抓取
# BV号为1hE411j7ox的视频属性抓取结束
# 开始BV号为1j7411C78h视频属性的抓取
# BV号为1j7411C78h的视频属性抓取结束
# 开始BV号为1wE411w7LR视频属性的抓取
# BV号为1wE411w7LR的视频属性抓取结束
# 开始BV号为13E411u7Ui视频属性的抓取
# BV号为13E411u7Ui的视频属性抓取结束
# 开始BV号为13E411F74G视频属性的抓取
# BV号为13E411F74G的视频属性抓取结束
# 开始BV号为1YE411J7Qb视频属性的抓取
# BV号为1YE411J7Qb的视频属性抓取结束
# 开始BV号为1VE411p71c视频属性的抓取
# BV号为1VE411p71c的视频属性抓取结束
# 开始BV号为1yE411s7zK视频属性的抓取
# BV号为1yE411s7zK的视频属性抓取结束
# 开始BV号为15z411z73U视频属性的抓取
# BV号为15z411z73U的视频属性抓取结束
# 开始BV号为1b5411t7d7视频属性的抓取
# BV号为1b5411t7d7的视频属性抓取结束
# 开始BV号为1fC4y1p7pj视频属性的抓取
# BV号为1fC4y1p7pj的视频属性抓取结束
# 开始BV号为1LC4y1W7TS视频属性的抓取
# BV号为1LC4y1W7TS的视频属性抓取结束
# 开始BV号为1Lp4y1y7sW视频属性的抓取
# BV号为1Lp4y1y7sW的视频属性抓取结束
# 开始BV号为1Tz41187h2视频属性的抓取
# BV号为1Tz41187h2的视频属性抓取结束
# 开始BV号为1La4y1t7kA视频属性的抓取
# BV号为1La4y1t7kA的视频属性抓取结束
# 开始BV号为1aK411L7fz视频属性的抓取
# BV号为1aK411L7fz的视频属性抓取结束
# 开始BV号为1Rt4y127q2视频属性的抓取
# BV号为1Rt4y127q2的视频属性抓取结束
# 开始BV号为1zC4y1s7zH视频属性的抓取
# BV号为1zC4y1s7zH的视频属性抓取结束
# 开始BV号为17a4y1x7iG视频属性的抓取
# BV号为17a4y1x7iG的视频属性抓取结束
# 开始BV号为1Xe411x7KV视频属性的抓取
# BV号为1Xe411x7KV的视频属性抓取结束
# 开始BV号为15C4y1x7yn视频属性的抓取
# BV号为15C4y1x7yn的视频属性抓取结束
# 开始BV号为1x5411t7Ak视频属性的抓取
# BV号为1x5411t7Ak的视频属性抓取结束
# 开始BV号为1Z54y197JE视频属性的抓取
# BV号为1Z54y197JE的视频属性抓取结束
# 开始BV号为1kp4y117UL视频属性的抓取
# BV号为1kp4y117UL的视频属性抓取结束
# 开始BV号为1jC4y147Bg视频属性的抓取
# BV号为1jC4y147Bg的视频属性抓取结束
# 开始BV号为1Vz411877p视频属性的抓取
# 开始BV号为1Vz411877p视频属性的抓取
# BV号为1Vz411877p的视频属性抓取结束
# 开始BV号为1qa4y1x7vr视频属性的抓取
# BV号为1qa4y1x7vr的视频属性抓取结束
# 开始BV号为1EC4y1s7Cn视频属性的抓取
# BV号为1EC4y1s7Cn的视频属性抓取结束
# 开始BV号为1GQ4y1K739视频属性的抓取
# BV号为1GQ4y1K739的视频属性抓取结束
# 开始BV号为18K4y1C7NK视频属性的抓取
# BV号为18K4y1C7NK的视频属性抓取结束
# 开始BV号为1MZ4y147Rc视频属性的抓取
# BV号为1MZ4y147Rc的视频属性抓取结束
# 开始BV号为1qA41147aT视频属性的抓取
# BV号为1qA41147aT的视频属性抓取结束
# 开始BV号为13g4y1z7KY视频属性的抓取
# BV号为13g4y1z7KY的视频属性抓取结束
# 开始BV号为1KV411d771视频属性的抓取
# BV号为1KV411d771的视频属性抓取结束
# 开始BV号为1sz411B75P视频属性的抓取
# 开始BV号为1sz411B75P视频属性的抓取
# BV号为1sz411B75P的视频属性抓取结束
# 开始BV号为1ei4y187o6视频属性的抓取
# BV号为1ei4y187o6的视频属性抓取结束
# 开始BV号为1P5411t7Lw视频属性的抓取
# BV号为1P5411t7Lw的视频属性抓取结束
# 开始BV号为1F5411t7bx视频属性的抓取
# BV号为1F5411t7bx的视频属性抓取结束
# 开始BV号为1k54y19735视频属性的抓取
# BV号为1k54y19735的视频属性抓取结束
# 开始BV号为1xf4y1S7a6视频属性的抓取
# BV号为1xf4y1S7a6的视频属性抓取结束
# 开始BV号为1bK41157BN视频属性的抓取
# BV号为1bK41157BN的视频属性抓取结束
# 开始BV号为1MT4y15751视频属性的抓取
# BV号为1MT4y15751的视频属性抓取结束
# 开始BV号为1uC4y1W7jy视频属性的抓取
# BV号为1uC4y1W7jy的视频属性抓取结束
# 开始BV号为19a4y1t72m视频属性的抓取
# BV号为19a4y1t72m的视频属性抓取结束
# 开始BV号为1ng4y187Zp视频属性的抓取
# 开始BV号为1ng4y187Zp视频属性的抓取
# BV号为1ng4y187Zp的视频属性抓取结束
# 开始BV号为1sV411d7qf视频属性的抓取
# BV号为1sV411d7qf的视频属性抓取结束
# 开始BV号为1j54y1R7xx视频属性的抓取
# BV号为1j54y1R7xx的视频属性抓取结束
# 开始BV号为1ct4y1m73b视频属性的抓取
# BV号为1ct4y1m73b的视频属性抓取结束
# 开始BV号为1W54y197hR视频属性的抓取
# BV号为1W54y197hR的视频属性抓取结束
# 开始BV号为1Gp4y1y7rU视频属性的抓取
# BV号为1Gp4y1y7rU的视频属性抓取结束
# 开始BV号为1i541167Qh视频属性的抓取
# BV号为1i541167Qh的视频属性抓取结束
# 开始BV号为17C4y1W7P7视频属性的抓取
# BV号为17C4y1W7P7的视频属性抓取结束
# 开始BV号为1YQ4y1K7ap视频属性的抓取
# BV号为1YQ4y1K7ap的视频属性抓取结束
# 开始BV号为12Z4y1W7PF视频属性的抓取
# BV号为12Z4y1W7PF的视频属性抓取结束
# 开始BV号为15f4y1m7gg视频属性的抓取
# BV号为15f4y1m7gg的视频属性抓取结束
# 开始BV号为18i4y1871i视频属性的抓取
# BV号为18i4y1871i的视频属性抓取结束
# 开始BV号为1K64y1u7cm视频属性的抓取
# BV号为1K64y1u7cm的视频属性抓取结束
# 开始BV号为11z411B7cN视频属性的抓取
# BV号为11z411B7cN的视频属性抓取结束
# 开始BV号为1Rg4y1b7AV视频属性的抓取
# BV号为1Rg4y1b7AV的视频属性抓取结束
# 开始BV号为1sC4y1s7tT视频属性的抓取
# BV号为1sC4y1s7tT的视频属性抓取结束
# 开始BV号为1of4y1U7CN视频属性的抓取
# BV号为1of4y1U7CN的视频属性抓取结束
# 开始BV号为1BV411o7ra视频属性的抓取
# BV号为1BV411o7ra的视频属性抓取结束
# 开始BV号为1k541147L7视频属性的抓取
# BV号为1k541147L7的视频属性抓取结束
# 开始BV号为1Q64y1u7ht视频属性的抓取
# BV号为1Q64y1u7ht的视频属性抓取结束
# 开始BV号为1ht4y127xQ视频属性的抓取
# BV号为1ht4y127xQ的视频属性抓取结束
# 开始BV号为1rK41177c6视频属性的抓取
# BV号为1rK41177c6的视频属性抓取结束
# 开始BV号为1L64y1u7Ps视频属性的抓取
# BV号为1L64y1u7Ps的视频属性抓取结束
# 开始BV号为1vg4y1z7Sb视频属性的抓取
# BV号为1vg4y1z7Sb的视频属性抓取结束
# 开始BV号为1Ti4y1t7EW视频属性的抓取
# BV号为1Ti4y1t7EW的视频属性抓取结束
# 开始BV号为15g4y187YS视频属性的抓取
# BV号为15g4y187YS的视频属性抓取结束
# 开始BV号为1e5411t7YG视频属性的抓取
# 开始BV号为1e5411t7YG视频属性的抓取
# 开始BV号为1e5411t7YG视频属性的抓取
# BV号为1e5411t7YG的视频属性抓取结束
# 开始BV号为12Q4y1M7aP视频属性的抓取
# BV号为12Q4y1M7aP的视频属性抓取结束
# 开始BV号为1a5411t7Ki视频属性的抓取
# BV号为1a5411t7Ki的视频属性抓取结束
# 开始BV号为1df4y1U74W视频属性的抓取
# BV号为1df4y1U74W的视频属性抓取结束
# 开始BV号为1MK411578H视频属性的抓取
# BV号为1MK411578H的视频属性抓取结束
# 开始BV号为1PQ4y1M7Hh视频属性的抓取
# BV号为1PQ4y1M7Hh的视频属性抓取结束
# 开始BV号为1dQ4y1P7Gq视频属性的抓取
# BV号为1dQ4y1P7Gq的视频属性抓取结束
# 开始BV号为1va4y1x7gi视频属性的抓取
# BV号为1va4y1x7gi的视频属性抓取结束
# 开始BV号为1gK4y1k7rZ视频属性的抓取
# BV号为1gK4y1k7rZ的视频属性抓取结束
# 开始BV号为13T4y1V7mD视频属性的抓取
# BV号为13T4y1V7mD的视频属性抓取结束
# 开始BV号为1NE411c73h视频属性的抓取
# BV号为1NE411c73h的视频属性抓取结束
# 开始BV号为1TT4y137Qx视频属性的抓取
# BV号为1TT4y137Qx的视频属性抓取结束
# 开始BV号为1ap4y1X7Yf视频属性的抓取
# BV号为1ap4y1X7Yf的视频属性抓取结束
# 开始BV号为1oA411b73X视频属性的抓取
# BV号为1oA411b73X的视频属性抓取结束
# 开始BV号为1EV411o7U1视频属性的抓取
# BV号为1EV411o7U1的视频属性抓取结束
# 开始BV号为1m541147Uy视频属性的抓取
# BV号为1m541147Uy的视频属性抓取结束
# 开始BV号为1AK411L7Qf视频属性的抓取
# BV号为1AK411L7Qf的视频属性抓取结束
# 开始BV号为1iQ4y1K769视频属性的抓取
# BV号为1iQ4y1K769的视频属性抓取结束
# 开始BV号为1vk4y1r74q视频属性的抓取
# BV号为1vk4y1r74q的视频属性抓取结束
# 开始BV号为1Jg4y1z79K视频属性的抓取
# BV号为1Jg4y1z79K的视频属性抓取结束
# 开始BV号为1Yp4y1X7ac视频属性的抓取
# BV号为1Yp4y1X7ac的视频属性抓取结束
# 开始BV号为1BC4y1s7ET视频属性的抓取
# BV号为1BC4y1s7ET的视频属性抓取结束
# 开始BV号为17C4y1s7R4视频属性的抓取
# BV号为17C4y1s7R4的视频属性抓取结束
# 开始BV号为1te411x7NK视频属性的抓取
# BV号为1te411x7NK的视频属性抓取结束
# 开始BV号为1ok4y1d72s视频属性的抓取
# BV号为1ok4y1d72s的视频属性抓取结束
# 开始BV号为1LT4y1G7P5视频属性的抓取
# BV号为1LT4y1G7P5的视频属性抓取结束
# 开始BV号为1sg4y187W2视频属性的抓取
# BV号为1sg4y187W2的视频属性抓取结束
# 开始BV号为1rT4y1g7j9视频属性的抓取
# BV号为1rT4y1g7j9的视频属性抓取结束
# 开始BV号为1ye411x7PV视频属性的抓取
# BV号为1ye411x7PV的视频属性抓取结束
# 开始BV号为1Gt4y1U7ED视频属性的抓取
# BV号为1Gt4y1U7ED的视频属性抓取结束
# 开始BV号为1rk4y197dp视频属性的抓取
# BV号为1rk4y197dp的视频属性抓取结束
# 开始BV号为1VT4y157Wy视频属性的抓取
# BV号为1VT4y157Wy的视频属性抓取结束
# 开始BV号为1Aa4y147qi视频属性的抓取
# BV号为1Aa4y147qi的视频属性抓取结束
# 开始BV号为13e41147su视频属性的抓取
# BV号为13e41147su的视频属性抓取结束
# 开始BV号为1Nf4y1S7pc视频属性的抓取
# BV号为1Nf4y1S7pc的视频属性抓取结束
# 开始BV号为1Dc411h7p6视频属性的抓取
# BV号为1Dc411h7p6的视频属性抓取结束
# 开始BV号为1WK4y1r7Sa视频属性的抓取
# BV号为1WK4y1r7Sa的视频属性抓取结束
# 开始BV号为1A54y1d7bA视频属性的抓取
# BV号为1A54y1d7bA的视频属性抓取结束
# 开始BV号为1Hv411z73N视频属性的抓取
# BV号为1Hv411z73N的视频属性抓取结束
# 开始BV号为1ki4y1x7me视频属性的抓取
# BV号为1ki4y1x7me的视频属性抓取结束
# 开始BV号为1mz4y1R7Ry视频属性的抓取
# BV号为1mz4y1R7Ry的视频属性抓取结束
# 开始BV号为18V411d7d6视频属性的抓取
# BV号为18V411d7d6的视频属性抓取结束
# 开始BV号为1za4y1e7tS视频属性的抓取
# BV号为1za4y1e7tS的视频属性抓取结束
# 开始BV号为1SA41147qy视频属性的抓取
# BV号为1SA41147qy的视频属性抓取结束
# 开始BV号为1ZA411i7XM视频属性的抓取
# BV号为1ZA411i7XM的视频属性抓取结束
# 开始BV号为19K4y1b7ec视频属性的抓取
# BV号为19K4y1b7ec的视频属性抓取结束
# 开始BV号为1az411z7L3视频属性的抓取
# BV号为1az411z7L3的视频属性抓取结束
# 开始BV号为1hf4y127un视频属性的抓取
# BV号为1hf4y127un的视频属性抓取结束
# 开始BV号为1Mk4y1r7NC视频属性的抓取
# BV号为1Mk4y1r7NC的视频属性抓取结束
# 开始BV号为1JA411t7Ek视频属性的抓取
# BV号为1JA411t7Ek的视频属性抓取结束
# 开始BV号为1NK4y187TS视频属性的抓取
# BV号为1NK4y187TS的视频属性抓取结束
# 开始BV号为1BT4y1u71M视频属性的抓取
# BV号为1BT4y1u71M的视频属性抓取结束
# 开始BV号为1ta4y1e7v2视频属性的抓取
# BV号为1ta4y1e7v2的视频属性抓取结束
# 开始BV号为1G54y1X74N视频属性的抓取
# BV号为1G54y1X74N的视频属性抓取结束
# 开始BV号为11Z4y1s71H视频属性的抓取
# BV号为11Z4y1s71H的视频属性抓取结束
# 开始BV号为12t4y117XD视频属性的抓取
# BV号为12t4y117XD的视频属性抓取结束
# 开始BV号为16a4y1e7vg视频属性的抓取
# BV号为16a4y1e7vg的视频属性抓取结束
# 开始BV号为1Qf4y1m7kA视频属性的抓取
# BV号为1Qf4y1m7kA的视频属性抓取结束
# 开始BV号为1ok4y167Q9视频属性的抓取
# BV号为1ok4y167Q9的视频属性抓取结束
# 开始BV号为1np4y197mA视频属性的抓取
# BV号为1np4y197mA的视频属性抓取结束
# 开始BV号为1ai4y147VX视频属性的抓取
# BV号为1ai4y147VX的视频属性抓取结束
# 开始BV号为1iZ4y1s7s2视频属性的抓取
# BV号为1iZ4y1s7s2的视频属性抓取结束
# 开始BV号为1UA411t7xz视频属性的抓取
# BV号为1UA411t7xz的视频属性抓取结束
# 开始BV号为1tK411s7FS视频属性的抓取
# BV号为1tK411s7FS的视频属性抓取结束
# 开始BV号为1gi4y14798视频属性的抓取
# BV号为1gi4y14798的视频属性抓取结束
# 开始BV号为1zp4y1Q7eJ视频属性的抓取
# BV号为1zp4y1Q7eJ的视频属性抓取结束
# 开始BV号为1FC4y1p7X4视频属性的抓取
# BV号为1FC4y1p7X4的视频属性抓取结束
# 开始BV号为1cC4y1p7XG视频属性的抓取
# BV号为1cC4y1p7XG的视频属性抓取结束
# 开始BV号为1jz4y197XL视频属性的抓取
# BV号为1jz4y197XL的视频属性抓取结束
# 开始BV号为14Z4y1s79w视频属性的抓取
# BV号为14Z4y1s79w的视频属性抓取结束
# 开始BV号为1fC4y1W7P1视频属性的抓取
# BV号为1fC4y1W7P1的视频属性抓取结束
# 开始BV号为1LT4y1u7L6视频属性的抓取
# BV号为1LT4y1u7L6的视频属性抓取结束
# 开始BV号为15z411q7Va视频属性的抓取
# BV号为15z411q7Va的视频属性抓取结束
# 开始BV号为1bC4y1H7Yr视频属性的抓取
# BV号为1bC4y1H7Yr的视频属性抓取结束
# 开始BV号为1yi4y1x75T视频属性的抓取
# BV号为1yi4y1x75T的视频属性抓取结束
# 开始BV号为1Zg4y1z7Zn视频属性的抓取
# BV号为1Zg4y1z7Zn的视频属性抓取结束
# 开始BV号为16f4y1m7k1视频属性的抓取
# BV号为16f4y1m7k1的视频属性抓取结束
# 开始BV号为1ZC4y1H7Fw视频属性的抓取
# BV号为1ZC4y1H7Fw的视频属性抓取结束
# 开始BV号为1st4y117dk视频属性的抓取
# BV号为1st4y117dk的视频属性抓取结束
# 开始BV号为1jZ4y1s7DU视频属性的抓取
# BV号为1jZ4y1s7DU的视频属性抓取结束
# 开始BV号为135411s7Kt视频属性的抓取
# BV号为135411s7Kt的视频属性抓取结束
# 开始BV号为1154y1X7fj视频属性的抓取
# BV号为1154y1X7fj的视频属性抓取结束
# 开始BV号为1et4y117zA视频属性的抓取
# BV号为1et4y117zA的视频属性抓取结束
# 开始BV号为1zC4y1W7mN视频属性的抓取
# BV号为1zC4y1W7mN的视频属性抓取结束
# 开始BV号为1bg4y1i7MW视频属性的抓取
# BV号为1bg4y1i7MW的视频属性抓取结束
# 开始BV号为1Qz4y1X7ov视频属性的抓取
# BV号为1Qz4y1X7ov的视频属性抓取结束
# 开始BV号为1854y1X78B视频属性的抓取
# BV号为1854y1X78B的视频属性抓取结束
# 开始BV号为13C4y1p7jQ视频属性的抓取
# BV号为13C4y1p7jQ的视频属性抓取结束
# 开始BV号为11K41157QG视频属性的抓取
# BV号为11K41157QG的视频属性抓取结束
# 开始BV号为1GK411s7Pr视频属性的抓取
# BV号为1GK411s7Pr的视频属性抓取结束
# 开始BV号为17Z4y1s72E视频属性的抓取
# 开始BV号为17Z4y1s72E视频属性的抓取
# BV号为17Z4y1s72E的视频属性抓取结束
# 开始BV号为1LA411t7jn视频属性的抓取
# BV号为1LA411t7jn的视频属性抓取结束
# 开始BV号为1WA411t7X1视频属性的抓取
# BV号为1WA411t7X1的视频属性抓取结束
# 开始BV号为1Ei4y147Tm视频属性的抓取
# BV号为1Ei4y147Tm的视频属性抓取结束
# 开始BV号为1Ev411z7DP视频属性的抓取
# BV号为1Ev411z7DP的视频属性抓取结束
# 开始BV号为1mf4y1m7bU视频属性的抓取
# BV号为1mf4y1m7bU的视频属性抓取结束
# 开始BV号为16f4y1m7w8视频属性的抓取
# BV号为16f4y1m7w8的视频属性抓取结束
# 开始BV号为1Vi4y1b71t视频属性的抓取
# BV号为1Vi4y1b71t的视频属性抓取结束
# 开始BV号为1ep4y197U7视频属性的抓取
# BV号为1ep4y197U7的视频属性抓取结束
# 开始BV号为1Ki4y1b7g1视频属性的抓取
# 开始BV号为1Ki4y1b7g1视频属性的抓取
# BV号为1Ki4y1b7g1的视频属性抓取结束
# 开始BV号为1kC4y1H7ud视频属性的抓取
# BV号为1kC4y1H7ud的视频属性抓取结束
# 开始BV号为1NT4y1g7td视频属性的抓取
# 开始BV号为1NT4y1g7td视频属性的抓取
# 开始BV号为1NT4y1g7td视频属性的抓取
# 开始BV号为1NT4y1g7td视频属性的抓取
# BV号为1NT4y1g7td的视频属性抓取结束
# 开始BV号为1Rk4y167ht视频属性的抓取
# BV号为1Rk4y167ht的视频属性抓取结束
# 开始BV号为1Fg4y1z74b视频属性的抓取
# 开始BV号为1Fg4y1z74b视频属性的抓取
# BV号为1Fg4y1z74b的视频属性抓取结束
# 开始BV号为1iT4y1g7MG视频属性的抓取
# BV号为1iT4y1g7MG的视频属性抓取结束
# 开始BV号为1PK4y1t79P视频属性的抓取
# BV号为1PK4y1t79P的视频属性抓取结束
# 开始BV号为1zC4y1H7Zk视频属性的抓取
# BV号为1zC4y1H7Zk的视频属性抓取结束
# 开始BV号为1y54y1X79G视频属性的抓取
# BV号为1y54y1X79G的视频属性抓取结束
# 开始BV号为1aT4y137sn视频属性的抓取
# BV号为1aT4y137sn的视频属性抓取结束
# 开始BV号为1ez4y1R7J5视频属性的抓取
# BV号为1ez4y1R7J5的视频属性抓取结束
# 开始BV号为1bT4y1u7kk视频属性的抓取
# BV号为1bT4y1u7kk的视频属性抓取结束
# 开始BV号为1fQ4y1N7xf视频属性的抓取
# BV号为1fQ4y1N7xf的视频属性抓取结束
# 开始BV号为1cK4y187zF视频属性的抓取
# BV号为1cK4y187zF的视频属性抓取结束
# 开始BV号为1GK4y187az视频属性的抓取
# BV号为1GK4y187az的视频属性抓取结束
# 开始BV号为15z4y19765视频属性的抓取
# BV号为15z4y19765的视频属性抓取结束
# 开始BV号为1DV411d7vH视频属性的抓取
# BV号为1DV411d7vH的视频属性抓取结束
# 开始BV号为11z4y1R7Ew视频属性的抓取
# BV号为11z4y1R7Ew的视频属性抓取结束
# 开始BV号为1Q54y1X7aH视频属性的抓取
# BV号为1Q54y1X7aH的视频属性抓取结束
# 开始BV号为1di4y147nk视频属性的抓取
# BV号为1di4y147nk的视频属性抓取结束
# 开始BV号为1fi4y147a8视频属性的抓取
# BV号为1fi4y147a8的视频属性抓取结束
# 开始BV号为1QA41147oG视频属性的抓取
# BV号为1QA41147oG的视频属性抓取结束
# 开始BV号为1fT4y1u7F3视频属性的抓取
# BV号为1fT4y1u7F3的视频属性抓取结束
# 开始BV号为1LV411C7A5视频属性的抓取
# BV号为1LV411C7A5的视频属性抓取结束
# 开始BV号为1yT4y137ef视频属性的抓取
# BV号为1yT4y137ef的视频属性抓取结束
# 开始BV号为1Bp4y19795视频属性的抓取
# BV号为1Bp4y19795的视频属性抓取结束
# 开始BV号为1Ka4y1i7v8视频属性的抓取
# BV号为1Ka4y1i7v8的视频属性抓取结束
# 开始BV号为1Rp4y1S7Ro视频属性的抓取
# BV号为1Rp4y1S7Ro的视频属性抓取结束
# 开始BV号为1qT4y137Qy视频属性的抓取
# BV号为1qT4y137Qy的视频属性抓取结束
# 开始BV号为1kA41147ja视频属性的抓取
# BV号为1kA41147ja的视频属性抓取结束
# 开始BV号为1G541147A7视频属性的抓取
# BV号为1G541147A7的视频属性抓取结束
# 开始BV号为1L541147Cg视频属性的抓取
# BV号为1L541147Cg的视频属性抓取结束
# 开始BV号为1bz411z7PA视频属性的抓取
# BV号为1bz411z7PA的视频属性抓取结束
# 开始BV号为1of4y117Jg视频属性的抓取
# BV号为1of4y117Jg的视频属性抓取结束
# 开始BV号为1kz4y1R7vY视频属性的抓取
# BV号为1kz4y1R7vY的视频属性抓取结束
# 开始BV号为1Na4y1i7sV视频属性的抓取
# BV号为1Na4y1i7sV的视频属性抓取结束
# 开始BV号为1fa4y1v7tX视频属性的抓取
# BV号为1fa4y1v7tX的视频属性抓取结束
# 开始BV号为1af4y1m7Hj视频属性的抓取
# BV号为1af4y1m7Hj的视频属性抓取结束
# 开始BV号为1SC4y1a7jo视频属性的抓取
# BV号为1SC4y1a7jo的视频属性抓取结束
# 开始BV号为1UK411p7jR视频属性的抓取
# BV号为1UK411p7jR的视频属性抓取结束
# 开始BV号为1Dz4y1Q7Ct视频属性的抓取
# BV号为1Dz4y1Q7Ct的视频属性抓取结束
# 开始BV号为14a4y1v7LA视频属性的抓取
# BV号为14a4y1v7LA的视频属性抓取结束
# 开始BV号为1TZ4y1H7fS视频属性的抓取
# BV号为1TZ4y1H7fS的视频属性抓取结束
# 开始BV号为1B5411W7b6视频属性的抓取
# BV号为1B5411W7b6的视频属性抓取结束
# 开始BV号为1Rz4y197E7视频属性的抓取
# BV号为1Rz4y197E7的视频属性抓取结束
# 开始BV号为1cp4y1Q7gK视频属性的抓取
# BV号为1cp4y1Q7gK的视频属性抓取结束
# 开始BV号为1BC4y187Au视频属性的抓取
# BV号为1BC4y187Au的视频属性抓取结束
# 开始BV号为1ai4y1x74G视频属性的抓取
# BV号为1ai4y1x74G的视频属性抓取结束
# 开始BV号为1hf4y1y7vq视频属性的抓取
# BV号为1hf4y1y7vq的视频属性抓取结束
# 开始BV号为1W5411W74K视频属性的抓取
# BV号为1W5411W74K的视频属性抓取结束
# 开始BV号为15V411k721视频属性的抓取
# BV号为15V411k721的视频属性抓取结束
# 开始BV号为1Cz411e7nL视频属性的抓取
# BV号为1Cz411e7nL的视频属性抓取结束
# 开始BV号为1ng4y1q7d6视频属性的抓取
# BV号为1ng4y1q7d6的视频属性抓取结束
# 开始BV号为1jv411B7Jv视频属性的抓取
# BV号为1jv411B7Jv的视频属性抓取结束
# 开始BV号为1kf4y1y7T9视频属性的抓取
# BV号为1kf4y1y7T9的视频属性抓取结束
# 开始BV号为1vi4y1G7Vz视频属性的抓取
# BV号为1vi4y1G7Vz的视频属性抓取结束
# 开始BV号为1Zk4y1B7HH视频属性的抓取
# BV号为1Zk4y1B7HH的视频属性抓取结束
# 开始BV号为1AV411k7s8视频属性的抓取
# BV号为1AV411k7s8的视频属性抓取结束
# 开始BV号为1Mv41167o9视频属性的抓取
# 开始BV号为1Mv41167o9视频属性的抓取
# BV号为1Mv41167o9的视频属性抓取结束
# 开始BV号为1XK4y147tQ视频属性的抓取
# BV号为1XK4y147tQ的视频属性抓取结束
# 开始BV号为1vT4y1J7De视频属性的抓取
# BV号为1vT4y1J7De的视频属性抓取结束
# 开始BV号为1gV411k7DK视频属性的抓取
# BV号为1gV411k7DK的视频属性抓取结束
# 开始BV号为1pg4y1q7e2视频属性的抓取
# BV号为1pg4y1q7e2的视频属性抓取结束
# 开始BV号为1kk4y1q7wF视频属性的抓取
# BV号为1kk4y1q7wF的视频属性抓取结束
# 开始BV号为1CC4y1a7J5视频属性的抓取
# BV号为1CC4y1a7J5的视频属性抓取结束
# 开始BV号为1qz4y1Q7H6视频属性的抓取
# BV号为1qz4y1Q7H6的视频属性抓取结束
# 开始BV号为1kZ4y1H77i视频属性的抓取
# BV号为1kZ4y1H77i的视频属性抓取结束
# 开始BV号为1Mf4y117xb视频属性的抓取
# BV号为1Mf4y117xb的视频属性抓取结束
# 开始BV号为1Ek4y1r7nu视频属性的抓取
# BV号为1Ek4y1r7nu的视频属性抓取结束
# 开始BV号为1Yz411e7Rb视频属性的抓取
# BV号为1Yz411e7Rb的视频属性抓取结束
# 开始BV号为1f5411W7NF视频属性的抓取
# BV号为1f5411W7NF的视频属性抓取结束
# 开始BV号为1NZ4y1p7Qk视频属性的抓取
# BV号为1NZ4y1p7Qk的视频属性抓取结束
# 开始BV号为15z411v7dX视频属性的抓取
# BV号为15z411v7dX的视频属性抓取结束
# 开始BV号为1iz411e7bb视频属性的抓取
# BV号为1iz411e7bb的视频属性抓取结束
# 开始BV号为1uz4y1X7Co视频属性的抓取
# BV号为1uz4y1X7Co的视频属性抓取结束
# 开始BV号为19A411v7cf视频属性的抓取
# BV号为19A411v7cf的视频属性抓取结束
# 开始BV号为1MK411p7vT视频属性的抓取
# BV号为1MK411p7vT的视频属性抓取结束
# 开始BV号为1qC4y1a7Ae视频属性的抓取
# BV号为1qC4y1a7Ae的视频属性抓取结束
# 开始BV号为1Yi4y1G7hM视频属性的抓取
# BV号为1Yi4y1G7hM的视频属性抓取结束
# 开始BV号为1Mt4y197zV视频属性的抓取
# BV号为1Mt4y197zV的视频属性抓取结束
# 开始BV号为1n5411W7xH视频属性的抓取
# BV号为1n5411W7xH的视频属性抓取结束
# 开始BV号为1ht4y197HF视频属性的抓取
# BV号为1ht4y197HF的视频属性抓取结束
# 开始BV号为1Bz4y197NB视频属性的抓取
# BV号为1Bz4y197NB的视频属性抓取结束
# 开始BV号为12p4y1U7BC视频属性的抓取
# BV号为12p4y1U7BC的视频属性抓取结束
# 开始BV号为12i4y1s74C视频属性的抓取
# BV号为12i4y1s74C的视频属性抓取结束
# 开始BV号为1Rz4y1Q7K8视频属性的抓取
# BV号为1Rz4y1Q7K8的视频属性抓取结束
# 开始BV号为1Zk4y1B7V9视频属性的抓取
# BV号为1Zk4y1B7V9的视频属性抓取结束
# 开始BV号为1xA411i7kW视频属性的抓取
# BV号为1xA411i7kW的视频属性抓取结束
# 开始BV号为1az4y1975V视频属性的抓取
# BV号为1az4y1975V的视频属性抓取结束
# 开始BV号为1FC4y1a78a视频属性的抓取
# BV号为1FC4y1a78a的视频属性抓取结束
# 开始BV号为1pk4y1z7MA视频属性的抓取
# BV号为1pk4y1z7MA的视频属性抓取结束
# 开始BV号为1xT4y1g7er视频属性的抓取
# BV号为1xT4y1g7er的视频属性抓取结束
# 开始BV号为1bp4y1D7Uo视频属性的抓取
# BV号为1bp4y1D7Uo的视频属性抓取结束
# 开始BV号为1oC4y187pU视频属性的抓取
# BV号为1oC4y187pU的视频属性抓取结束
# 开始BV号为1XK411p7d1视频属性的抓取
# BV号为1XK411p7d1的视频属性抓取结束
# 开始BV号为1C5411Y7ur视频属性的抓取
# BV号为1C5411Y7ur的视频属性抓取结束
# 开始BV号为1xZ4y1W7p7视频属性的抓取
# BV号为1xZ4y1W7p7的视频属性抓取结束
# 开始BV号为14Z4y1H74d视频属性的抓取
# BV号为14Z4y1H74d的视频属性抓取结束
# 开始BV号为1Wi4y1G7za视频属性的抓取
# BV号为1Wi4y1G7za的视频属性抓取结束
# 开始BV号为1qD4y1D77D视频属性的抓取
# BV号为1qD4y1D77D的视频属性抓取结束
# 开始BV号为1h5411W7hN视频属性的抓取
# BV号为1h5411W7hN的视频属性抓取结束
# 开始BV号为1TT4y1J7NQ视频属性的抓取
# BV号为1TT4y1J7NQ的视频属性抓取结束
# 开始BV号为125411W7Vq视频属性的抓取
# BV号为125411W7Vq的视频属性抓取结束
# 开始BV号为1iD4y1D7gr视频属性的抓取
# BV号为1iD4y1D7gr的视频属性抓取结束
# 开始BV号为1Pp4y1S74b视频属性的抓取
# BV号为1Pp4y1S74b的视频属性抓取结束
# 开始BV号为1Az4y1R7bY视频属性的抓取
# BV号为1Az4y1R7bY的视频属性抓取结束
# 开始BV号为1nA411e7se视频属性的抓取
# BV号为1nA411e7se的视频属性抓取结束
# 开始BV号为18T4y1J7uZ视频属性的抓取
# BV号为18T4y1J7uZ的视频属性抓取结束
# 开始BV号为1fv411q7N3视频属性的抓取
# BV号为1fv411q7N3的视频属性抓取结束
# 开始BV号为145411W7hQ视频属性的抓取
# BV号为145411W7hQ的视频属性抓取结束
# 开始BV号为1YT4y1J7w1视频属性的抓取
# BV号为1YT4y1J7w1的视频属性抓取结束
# 开始BV号为1jZ4y1H7Kq视频属性的抓取
# BV号为1jZ4y1H7Kq的视频属性抓取结束
# 开始BV号为1gK4y147iN视频属性的抓取
# BV号为1gK4y147iN的视频属性抓取结束
# 开始BV号为12Z4y1H7Ah视频属性的抓取
# BV号为12Z4y1H7Ah的视频属性抓取结束
# 开始BV号为1Ek4y1z7Bn视频属性的抓取
# BV号为1Ek4y1z7Bn的视频属性抓取结束
# 开始BV号为1pi4y1G7Mq视频属性的抓取
# BV号为1pi4y1G7Mq的视频属性抓取结束
# 开始BV号为1Rk4y1z7zW视频属性的抓取
# BV号为1Rk4y1z7zW的视频属性抓取结束
# 开始BV号为16Z4y1H7T3视频属性的抓取
# BV号为16Z4y1H7T3的视频属性抓取结束
# 开始BV号为175411W7Cx视频属性的抓取
# BV号为175411W7Cx的视频属性抓取结束
# 开始BV号为1PK411H7dX视频属性的抓取
# BV号为1PK411H7dX的视频属性抓取结束
# 开始BV号为1ik4y1z731视频属性的抓取
# BV号为1ik4y1z731的视频属性抓取结束
# 开始BV号为1fC4y1a7xw视频属性的抓取
# BV号为1fC4y1a7xw的视频属性抓取结束
# 开始BV号为1r5411W7WU视频属性的抓取
# BV号为1r5411W7WU的视频属性抓取结束
# 开始BV号为1GK411H7iY视频属性的抓取
# BV号为1GK411H7iY的视频属性抓取结束
# 开始BV号为1Pa4y1Y75K视频属性的抓取
# BV号为1Pa4y1Y75K的视频属性抓取结束
# 开始BV号为1254y1B7Vm视频属性的抓取
# BV号为1254y1B7Vm的视频属性抓取结束
# 开始BV号为1ag4y1q7Qx视频属性的抓取
# BV号为1ag4y1q7Qx的视频属性抓取结束
# 开始BV号为14T4y177W5视频属性的抓取
# BV号为14T4y177W5的视频属性抓取结束
# 开始BV号为1UK411p71u视频属性的抓取
# BV号为1UK411p71u的视频属性抓取结束
# 开始BV号为1dK4y1x7Cj视频属性的抓取
# BV号为1dK4y1x7Cj的视频属性抓取结束
# 开始BV号为1UV411r7wg视频属性的抓取
# BV号为1UV411r7wg的视频属性抓取结束
# 开始BV号为1Qz4y197sN视频属性的抓取
# BV号为1Qz4y197sN的视频属性抓取结束
# 开始BV号为1oK411p7xE视频属性的抓取
# BV号为1oK411p7xE的视频属性抓取结束
# 开始BV号为1gK4y1b7yM视频属性的抓取
# BV号为1gK4y1b7yM的视频属性抓取结束
# 开始BV号为11T4y1E78U视频属性的抓取
# BV号为11T4y1E78U的视频属性抓取结束
# 开始BV号为1ZD4y1D7Lt视频属性的抓取
# BV号为1ZD4y1D7Lt的视频属性抓取结束
# 开始BV号为1iQ4y1P7Qv视频属性的抓取
# BV号为1iQ4y1P7Qv的视频属性抓取结束
# 开始BV号为1PA411i78G视频属性的抓取
# BV号为1PA411i78G的视频属性抓取结束
# 开始BV号为1za4y1a7JZ视频属性的抓取
# BV号为1za4y1a7JZ的视频属性抓取结束
# 开始BV号为1Vh411Z7XH视频属性的抓取
# BV号为1Vh411Z7XH的视频属性抓取结束
# 开始BV号为1Mt4y1X718视频属性的抓取
# BV号为1Mt4y1X718的视频属性抓取结束
# 开始BV号为1Aa4y1a7u9视频属性的抓取
# BV号为1Aa4y1a7u9的视频属性抓取结束
# 开始BV号为1zK411J7nC视频属性的抓取
# BV号为1zK411J7nC的视频属性抓取结束
# 开始BV号为1tC4y1h7Yy视频属性的抓取
# BV号为1tC4y1h7Yy的视频属性抓取结束
# 开始BV号为1954y1q7XB视频属性的抓取
# BV号为1954y1q7XB的视频属性抓取结束
# 开始BV号为1dk4y1z7qb视频属性的抓取
# BV号为1dk4y1z7qb的视频属性抓取结束
# 开始BV号为1Hp4y1i7Fn视频属性的抓取
# BV号为1Hp4y1i7Fn的视频属性抓取结束
# 开始BV号为13K411J7up视频属性的抓取
# BV号为13K411J7up的视频属性抓取结束
# 开始BV号为1q54y1q75b视频属性的抓取
# BV号为1q54y1q75b的视频属性抓取结束
# 开始BV号为1qz4y1X7GV视频属性的抓取
# BV号为1qz4y1X7GV的视频属性抓取结束
# 开始BV号为1UA411i7X5视频属性的抓取
# BV号为1UA411i7X5的视频属性抓取结束
# 开始BV号为1QZ4y1u7gP视频属性的抓取
# BV号为1QZ4y1u7gP的视频属性抓取结束
# 开始BV号为14A411i7W5视频属性的抓取
# BV号为14A411i7W5的视频属性抓取结束
# 开始BV号为1ZT4y1L7Gz视频属性的抓取
# BV号为1ZT4y1L7Gz的视频属性抓取结束
# 开始BV号为1J54y1q7z4视频属性的抓取
# BV号为1J54y1q7z4的视频属性抓取结束
# 开始BV号为1PA411v7gN视频属性的抓取
# BV号为1PA411v7gN的视频属性抓取结束
# 开始BV号为1AV411z7vL视频属性的抓取
# BV号为1AV411z7vL的视频属性抓取结束
# 开始BV号为17t4y1X7Pi视频属性的抓取
# BV号为17t4y1X7Pi的视频属性抓取结束
# 开始BV号为1xt4y1Q7uC视频属性的抓取
# BV号为1xt4y1Q7uC的视频属性抓取结束
# 开始BV号为1V54y1z75M视频属性的抓取
# BV号为1V54y1z75M的视频属性抓取结束
# 开始BV号为1Hg4y1i7Rf视频属性的抓取
# BV号为1Hg4y1i7Rf的视频属性抓取结束
# 开始BV号为1zK4y1s7Jp视频属性的抓取
# BV号为1zK4y1s7Jp的视频属性抓取结束
# 开始BV号为1LK4y1x76B视频属性的抓取
# BV号为1LK4y1x76B的视频属性抓取结束
# 开始BV号为1qt4y1X7TW视频属性的抓取
# BV号为1qt4y1X7TW的视频属性抓取结束
# 开始BV号为1pt4y1X72t视频属性的抓取
# BV号为1pt4y1X72t的视频属性抓取结束
# 开始BV号为1Sz411e7zn视频属性的抓取
# BV号为1Sz411e7zn的视频属性抓取结束
# 开始BV号为1Ti4y1V75w视频属性的抓取
# BV号为1Ti4y1V75w的视频属性抓取结束
# 开始BV号为15V41167Yx视频属性的抓取
# BV号为15V41167Yx的视频属性抓取结束
# 开始BV号为16p4y1i75y视频属性的抓取
# BV号为16p4y1i75y的视频属性抓取结束
# 开始BV号为1ZT4y177wQ视频属性的抓取
# BV号为1ZT4y177wQ的视频属性抓取结束
# 开始BV号为1dT4y1L7Sk视频属性的抓取
# BV号为1dT4y1L7Sk的视频属性抓取结束
# 开始BV号为1Nf4y1R72g视频属性的抓取
# BV号为1Nf4y1R72g的视频属性抓取结束
# 开始BV号为1xp4y1i7md视频属性的抓取
# BV号为1xp4y1i7md的视频属性抓取结束
# 开始BV号为16a4y1a7KD视频属性的抓取
# BV号为16a4y1a7KD的视频属性抓取结束
# 开始BV号为1vC4y1b76j视频属性的抓取
# BV号为1vC4y1b76j的视频属性抓取结束
# 开始BV号为1UC4y1b7iq视频属性的抓取
# BV号为1UC4y1b7iq的视频属性抓取结束
# 开始BV号为15Z4y1u7zD视频属性的抓取
# BV号为15Z4y1u7zD的视频属性抓取结束
# 开始BV号为1zk4y1q7Bg视频属性的抓取
# BV号为1zk4y1q7Bg的视频属性抓取结束
# 开始BV号为1Dp4y1U7tc视频属性的抓取
# BV号为1Dp4y1U7tc的视频属性抓取结束
# 开始BV号为1uD4y1S78W视频属性的抓取
# BV号为1uD4y1S78W的视频属性抓取结束
# 开始BV号为1d54y1i7jB视频属性的抓取
# BV号为1d54y1i7jB的视频属性抓取结束
# 开始BV号为1NT4y1j7fF视频属性的抓取
# BV号为1NT4y1j7fF的视频属性抓取结束
# 开始BV号为1AD4y1D7Bm视频属性的抓取
# BV号为1AD4y1D7Bm的视频属性抓取结束
# 开始BV号为1gp4y1S7AR视频属性的抓取
# BV号为1gp4y1S7AR的视频属性抓取结束
# 开始BV号为1Zk4y1275h视频属性的抓取
# BV号为1Zk4y1275h的视频属性抓取结束
# 开始BV号为1BV411678G视频属性的抓取
# BV号为1BV411678G的视频属性抓取结束
# 开始BV号为1zC4y187jE视频属性的抓取
# BV号为1zC4y187jE的视频属性抓取结束
# 开始BV号为1wT4y1j7MG视频属性的抓取
# BV号为1wT4y1j7MG的视频属性抓取结束
# 开始BV号为1Gk4y1B7fX视频属性的抓取
# BV号为1Gk4y1B7fX的视频属性抓取结束
# 开始BV号为1hp4y1i7Lc视频属性的抓取
# BV号为1hp4y1i7Lc的视频属性抓取结束
# 开始BV号为1uC4y1b76F视频属性的抓取
# BV号为1uC4y1b76F的视频属性抓取结束
# 开始BV号为1Qg4y1v7jK视频属性的抓取
# BV号为1Qg4y1v7jK的视频属性抓取结束
# 开始BV号为1GA411Y7WH视频属性的抓取
# BV号为1GA411Y7WH的视频属性抓取结束
# 开始BV号为1Fk4y1m71m视频属性的抓取
# BV号为1Fk4y1m71m的视频属性抓取结束
# 开始BV号为1iT4y177WQ视频属性的抓取
# BV号为1iT4y177WQ的视频属性抓取结束
# 开始BV号为1sK4y1x7F6视频属性的抓取
# BV号为1sK4y1x7F6的视频属性抓取结束
# 开始BV号为1bv411v7QS视频属性的抓取
# BV号为1bv411v7QS的视频属性抓取结束
# 开始BV号为1DZ4y1M7bJ视频属性的抓取
# BV号为1DZ4y1M7bJ的视频属性抓取结束
# 开始BV号为1wv411z7rV视频属性的抓取
# BV号为1wv411z7rV的视频属性抓取结束
# 开始BV号为1Zv411i7sT视频属性的抓取
# BV号为1Zv411i7sT的视频属性抓取结束
# 开始BV号为1gf4y197qJ视频属性的抓取
# BV号为1gf4y197qJ的视频属性抓取结束
# 开始BV号为1Eh411Z7kp视频属性的抓取
# BV号为1Eh411Z7kp的视频属性抓取结束
# 开始BV号为1Wi4y137xA视频属性的抓取
# BV号为1Wi4y137xA的视频属性抓取结束
# 开始BV号为1Z5411Y7qT视频属性的抓取
# BV号为1Z5411Y7qT的视频属性抓取结束
# 开始BV号为1Z5411Y7bB视频属性的抓取
# BV号为1Z5411Y7bB的视频属性抓取结束
# 开始BV号为13i4y1V7tV视频属性的抓取
# BV号为13i4y1V7tV的视频属性抓取结束
# 开始BV号为1Xf4y1R7gZ视频属性的抓取
# BV号为1Xf4y1R7gZ的视频属性抓取结束
# 开始BV号为1NV411r7z4视频属性的抓取
# BV号为1NV411r7z4的视频属性抓取结束
# 开始BV号为1FK411H72o视频属性的抓取
# BV号为1FK411H72o的视频属性抓取结束
# 开始BV号为1D54y1q76A视频属性的抓取
# BV号为1D54y1q76A的视频属性抓取结束
# 开始BV号为1Rk4y1q7rd视频属性的抓取
# BV号为1Rk4y1q7rd的视频属性抓取结束
# 开始BV号为1qv411i7T2视频属性的抓取
# BV号为1qv411i7T2的视频属性抓取结束
# 开始BV号为19v411q7nP视频属性的抓取
# BV号为19v411q7nP的视频属性抓取结束
# 开始BV号为1MC4y1b7Sq视频属性的抓取
# BV号为1MC4y1b7Sq的视频属性抓取结束
# 开始BV号为1MC4y1b7UG视频属性的抓取
# BV号为1MC4y1b7UG的视频属性抓取结束
# 开始BV号为1Fa4y1a7jE视频属性的抓取
# BV号为1Fa4y1a7jE的视频属性抓取结束
# 开始BV号为1Ha4y1a74h视频属性的抓取
# BV号为1Ha4y1a74h的视频属性抓取结束
# 开始BV号为1ek4y1B7TT视频属性的抓取
# BV号为1ek4y1B7TT的视频属性抓取结束
# 开始BV号为1iV411k7vV视频属性的抓取
# BV号为1iV411k7vV的视频属性抓取结束
# 开始BV号为1CZ4y1T7rs视频属性的抓取
# BV号为1CZ4y1T7rs的视频属性抓取结束
# 开始BV号为1r54y1q7UF视频属性的抓取
# BV号为1r54y1q7UF的视频属性抓取结束
# 开始BV号为1sp4y1S7RE视频属性的抓取
# BV号为1sp4y1S7RE的视频属性抓取结束
# 开始BV号为1ez4y1X7Wy视频属性的抓取
# BV号为1ez4y1X7Wy的视频属性抓取结束
# 开始BV号为1E5411Y7hF视频属性的抓取
# BV号为1E5411Y7hF的视频属性抓取结束
# 开始BV号为1Xa4y1a7Gg视频属性的抓取
# BV号为1Xa4y1a7Gg的视频属性抓取结束
# 开始BV号为1Uz4y1D7ED视频属性的抓取
# BV号为1Uz4y1D7ED的视频属性抓取结束
# 开始BV号为1Yp4y1i7ao视频属性的抓取
# BV号为1Yp4y1i7ao的视频属性抓取结束
# 开始BV号为1VT4y1j7PC视频属性的抓取
# BV号为1VT4y1j7PC的视频属性抓取结束
# 开始BV号为1Y54y1q7CQ视频属性的抓取
# BV号为1Y54y1q7CQ的视频属性抓取结束
# 开始BV号为1tV41167rr视频属性的抓取
# BV号为1tV41167rr的视频属性抓取结束
# 开始BV号为1ZK4y1s7Sr视频属性的抓取
# BV号为1ZK4y1s7Sr的视频属性抓取结束
# 开始BV号为1Nz411v7tM视频属性的抓取
# BV号为1Nz411v7tM的视频属性抓取结束
# 开始BV号为1AT4y1j7dw视频属性的抓取
# BV号为1AT4y1j7dw的视频属性抓取结束
# 开始BV号为1554y1S7L7视频属性的抓取
# BV号为1554y1S7L7的视频属性抓取结束
# 开始BV号为1jK411J7Kc视频属性的抓取
# BV号为1jK411J7Kc的视频属性抓取结束
# 开始BV号为1N5411a7i3视频属性的抓取
# BV号为1N5411a7i3的视频属性抓取结束
# 开始BV号为1fV41167do视频属性的抓取
# BV号为1fV41167do的视频属性抓取结束
# 开始BV号为1qk4y1m7tM视频属性的抓取
# BV号为1qk4y1m7tM的视频属性抓取结束
# 开始BV号为1zk4y127Lu视频属性的抓取
# BV号为1zk4y127Lu的视频属性抓取结束
# 开始BV号为1mD4y1U7z9视频属性的抓取
# BV号为1mD4y1U7z9的视频属性抓取结束
# 开始BV号为1Wf4y1Q7H5视频属性的抓取
# BV号为1Wf4y1Q7H5的视频属性抓取结束
# 开始BV号为16p4y1q7DZ视频属性的抓取
# BV号为16p4y1q7DZ的视频属性抓取结束
# 开始BV号为1iK4y1Y7r7视频属性的抓取
# BV号为1iK4y1Y7r7的视频属性抓取结束
# 开始BV号为1dA411a77U视频属性的抓取
# BV号为1dA411a77U的视频属性抓取结束
# 开始BV号为1hD4y127cG视频属性的抓取
# BV号为1hD4y127cG的视频属性抓取结束
# 开始BV号为1MK411M7PY视频属性的抓取
# BV号为1MK411M7PY的视频属性抓取结束
# 开始BV号为1kZ4y1K7mH视频属性的抓取
# BV号为1kZ4y1K7mH的视频属性抓取结束
# 开始BV号为1Yk4y117FF视频属性的抓取
# BV号为1Yk4y117FF的视频属性抓取结束
# 开始BV号为1dA411n7fJ视频属性的抓取
# BV号为1dA411n7fJ的视频属性抓取结束
# 开始BV号为1JT4y1L7U8视频属性的抓取
# BV号为1JT4y1L7U8的视频属性抓取结束
# 开始BV号为1sz4y1f7p2视频属性的抓取
# BV号为1sz4y1f7p2的视频属性抓取结束
# 开始BV号为1KA411H78W视频属性的抓取
# BV号为1KA411H78W的视频属性抓取结束
# 开始BV号为1pC4y1t72t视频属性的抓取
# BV号为1pC4y1t72t的视频属性抓取结束
# 开始BV号为1ya4y1J7B3视频属性的抓取
# BV号为1ya4y1J7B3的视频属性抓取结束
# 开始BV号为13K411T7Ka视频属性的抓取
# BV号为13K411T7Ka的视频属性抓取结束
# 开始BV号为1GT4y177u1视频属性的抓取
# BV号为1GT4y177u1的视频属性抓取结束
# 开始BV号为1XD4y127bK视频属性的抓取
# BV号为1XD4y127bK的视频属性抓取结束
# 开始BV号为1ni4y1g7DP视频属性的抓取
# BV号为1ni4y1g7DP的视频属性抓取结束
# 开始BV号为1hD4y1m7f9视频属性的抓取
# BV号为1hD4y1m7f9的视频属性抓取结束
# 开始BV号为11V411U7pT视频属性的抓取
# BV号为11V411U7pT的视频属性抓取结束
# 开始BV号为1oZ4y1K79s视频属性的抓取
# BV号为1oZ4y1K79s的视频属性抓取结束
# 开始BV号为1Xf4y1Q7tv视频属性的抓取
# BV号为1Xf4y1Q7tv的视频属性抓取结束
# 开始BV号为1RK4y1Y7Bf视频属性的抓取
# BV号为1RK4y1Y7Bf的视频属性抓取结束
# 开始BV号为1h64y1c7Eb视频属性的抓取
# BV号为1h64y1c7Eb的视频属性抓取结束
# 开始BV号为1ma4y1E7re视频属性的抓取
# BV号为1ma4y1E7re的视频属性抓取结束
# 开始BV号为14V411U7kp视频属性的抓取
# BV号为14V411U7kp的视频属性抓取结束
# 开始BV号为1tC4y1t7oG视频属性的抓取
# BV号为1tC4y1t7oG的视频属性抓取结束
# 开始BV号为1Ph411d7vy视频属性的抓取
# BV号为1Ph411d7vy的视频属性抓取结束
# 开始BV号为1H5411h7TC视频属性的抓取
# BV号为1H5411h7TC的视频属性抓取结束
# 开始BV号为1eD4y12757视频属性的抓取
# BV号为1eD4y12757的视频属性抓取结束
# 开始BV号为18k4y1178e视频属性的抓取
# BV号为18k4y1178e的视频属性抓取结束
# 开始BV号为1JC4y187p7视频属性的抓取
# BV号为1JC4y187p7的视频属性抓取结束
# 开始BV号为18z4y1Q79c视频属性的抓取
# BV号为18z4y1Q79c的视频属性抓取结束
# 开始BV号为1zZ4y1M7zN视频属性的抓取
# BV号为1zZ4y1M7zN的视频属性抓取结束
# 开始BV号为1ez4y1f7pq视频属性的抓取
# BV号为1ez4y1f7pq的视频属性抓取结束
# 开始BV号为1kt4y1D7Ta视频属性的抓取
# BV号为1kt4y1D7Ta的视频属性抓取结束
# 开始BV号为1Ev411179L视频属性的抓取
# BV号为1Ev411179L的视频属性抓取结束
# 开始BV号为1dt4y1U7zA视频属性的抓取
# BV号为1dt4y1U7zA的视频属性抓取结束
# 开始BV号为1fv411y7BV视频属性的抓取
# BV号为1fv411y7BV的视频属性抓取结束
# 开始BV号为1WT4y1L78i视频属性的抓取
# BV号为1WT4y1L78i的视频属性抓取结束
# 开始BV号为1KK4y1v7Gp视频属性的抓取
# BV号为1KK4y1v7Gp的视频属性抓取结束
# 开始BV号为1vD4y1m7f7视频属性的抓取
# BV号为1vD4y1m7f7的视频属性抓取结束
# 开始BV号为1954y1U71N视频属性的抓取
# BV号为1954y1U71N的视频属性抓取结束
# 开始BV号为1Yv411v7L2视频属性的抓取
# BV号为1Yv411v7L2的视频属性抓取结束
# 开始BV号为1sa4y1777k视频属性的抓取
# BV号为1sa4y1777k的视频属性抓取结束
# 开始BV号为1ah411d71p视频属性的抓取
# BV号为1ah411d71p的视频属性抓取结束
# 开始BV号为1tt4y1S7mf视频属性的抓取
# BV号为1tt4y1S7mf的视频属性抓取结束
# 开始BV号为1Vi4y1g7fj视频属性的抓取
# BV号为1Vi4y1g7fj的视频属性抓取结束
# 开始BV号为1XC4y1472T视频属性的抓取
# BV号为1XC4y1472T的视频属性抓取结束
# 开始BV号为1x54y1i7iQ视频属性的抓取
# BV号为1x54y1i7iQ的视频属性抓取结束
# 开始BV号为1UZ4y1T7bs视频属性的抓取
# BV号为1UZ4y1T7bs的视频属性抓取结束
# 开始BV号为1Na4y1E7XN视频属性的抓取
# BV号为1Na4y1E7XN的视频属性抓取结束
# 开始BV号为1sf4y1Q74u视频属性的抓取
# BV号为1sf4y1Q74u的视频属性抓取结束
# 开始BV号为1oC4y1b7NB视频属性的抓取
# BV号为1oC4y1b7NB的视频属性抓取结束
# 开始BV号为1dK4y1v7mg视频属性的抓取
# BV号为1dK4y1v7mg的视频属性抓取结束
# 开始BV号为1wV411S7fs视频属性的抓取
# BV号为1wV411S7fs的视频属性抓取结束
# 开始BV号为1EZ4y1K7zf视频属性的抓取
# BV号为1EZ4y1K7zf的视频属性抓取结束
# 开始BV号为1dZ4y1T7uy视频属性的抓取
# BV号为1dZ4y1T7uy的视频属性抓取结束
# 开始BV号为1C54y1e78i视频属性的抓取
# BV号为1C54y1e78i的视频属性抓取结束
# 开始BV号为1MK411K7i9视频属性的抓取
# BV号为1MK411K7i9的视频属性抓取结束
# 开始BV号为1eT4y1w7Kk视频属性的抓取
# BV号为1eT4y1w7Kk的视频属性抓取结束
# 开始BV号为1vi4y1g7hh视频属性的抓取
# BV号为1vi4y1g7hh的视频属性抓取结束
# 开始BV号为1QD4y1m7vP视频属性的抓取
# BV号为1QD4y1m7vP的视频属性抓取结束
# 开始BV号为1rA411Y7W5视频属性的抓取
# 开始BV号为1rA411Y7W5视频属性的抓取
# BV号为1rA411Y7W5的视频属性抓取结束
# 开始BV号为1BT4y157W4视频属性的抓取
# BV号为1BT4y157W4的视频属性抓取结束
# 开始BV号为1XV411U7GZ视频属性的抓取
# BV号为1XV411U7GZ的视频属性抓取结束
# 开始BV号为1CT4y157fe视频属性的抓取
# BV号为1CT4y157fe的视频属性抓取结束
# 开始BV号为1bZ4y1M71H视频属性的抓取
# BV号为1bZ4y1M71H的视频属性抓取结束
# 开始BV号为1oZ4y1K731视频属性的抓取
# BV号为1oZ4y1K731的视频属性抓取结束
# 开始BV号为1kf4y197Vu视频属性的抓取
# BV号为1kf4y197Vu的视频属性抓取结束
# 开始BV号为17i4y1g7Rf视频属性的抓取
# BV号为17i4y1g7Rf的视频属性抓取结束
# 开始BV号为1Cp4y1v74X视频属性的抓取
# BV号为1Cp4y1v74X的视频属性抓取结束
# 开始BV号为1kv411v7bY视频属性的抓取
# BV号为1kv411v7bY的视频属性抓取结束
# 开始BV号为1aK4y1e7Le视频属性的抓取
# BV号为1aK4y1e7Le的视频属性抓取结束
# 开始BV号为1Ti4y1g7Fq视频属性的抓取
# BV号为1Ti4y1g7Fq的视频属性抓取结束
# 开始BV号为1ya4y1J7Yw视频属性的抓取
# BV号为1ya4y1J7Yw的视频属性抓取结束
# 开始BV号为1XT4y1j7JN视频属性的抓取
# BV号为1XT4y1j7JN的视频属性抓取结束
# 开始BV号为1FV411S7x1视频属性的抓取
# BV号为1FV411S7x1的视频属性抓取结束
# 开始BV号为1ft4y1U7e7视频属性的抓取
# BV号为1ft4y1U7e7的视频属性抓取结束
# 开始BV号为11t4y1S7fK视频属性的抓取
# BV号为11t4y1S7fK的视频属性抓取结束
# 开始BV号为1V54y1e7KB视频属性的抓取
# BV号为1V54y1e7KB的视频属性抓取结束
# 开始BV号为1ua4y177Gq视频属性的抓取
# BV号为1ua4y177Gq的视频属性抓取结束
# 开始BV号为1c64y1F7mF视频属性的抓取
# BV号为1c64y1F7mF的视频属性抓取结束
# 开始BV号为1H54y117P2视频属性的抓取
# BV号为1H54y117P2的视频属性抓取结束
# 开始BV号为19z4y1o7eB视频属性的抓取
# BV号为19z4y1o7eB的视频属性抓取结束
# 开始BV号为17v411C77Y视频属性的抓取
# BV号为17v411C77Y的视频属性抓取结束
# 开始BV号为1oi4y1M7FD视频属性的抓取
# BV号为1oi4y1M7FD的视频属性抓取结束
# 开始BV号为1hZ4y1N7cJ视频属性的抓取
# BV号为1hZ4y1N7cJ的视频属性抓取结束
# 开始BV号为1VK4y1Y79W视频属性的抓取
# BV号为1VK4y1Y79W的视频属性抓取结束
# 开始BV号为1pk4y117r9视频属性的抓取
# BV号为1pk4y117r9的视频属性抓取结束
# 开始BV号为1dD4y1R74X视频属性的抓取
# BV号为1dD4y1R74X的视频属性抓取结束
# 开始BV号为1Dv411C7pj视频属性的抓取
# BV号为1Dv411C7pj的视频属性抓取结束
# 开始BV号为11T4y1A7w9视频属性的抓取
# BV号为11T4y1A7w9的视频属性抓取结束
# 开始BV号为1xh411R7T7视频属性的抓取
# BV号为1xh411R7T7的视频属性抓取结束
# 开始BV号为1PV411m73F视频属性的抓取
# BV号为1PV411m73F的视频属性抓取结束
# 开始BV号为1p54y1v7Vn视频属性的抓取
# BV号为1p54y1v7Vn的视频属性抓取结束
# 开始BV号为1f5411b7Rc视频属性的抓取
# BV号为1f5411b7Rc的视频属性抓取结束
# 开始BV号为1EK4y1e7Y8视频属性的抓取
# BV号为1EK4y1e7Y8的视频属性抓取结束
# 开始BV号为1py4y1k7m1视频属性的抓取
# BV号为1py4y1k7m1的视频属性抓取结束
# 开始BV号为1dK411N71C视频属性的抓取
# BV号为1dK411N71C的视频属性抓取结束
# 开始BV号为15K411K79N视频属性的抓取
# BV号为15K411K79N的视频属性抓取结束
# 开始BV号为1kz4y1f7pH视频属性的抓取
# BV号为1kz4y1f7pH的视频属性抓取结束
# 开始BV号为12D4y1d7Mw视频属性的抓取
# BV号为12D4y1d7Mw的视频属性抓取结束
# 开始BV号为1Rv41117JG视频属性的抓取
# BV号为1Rv41117JG的视频属性抓取结束
# 开始BV号为1Lf4y1X7aE视频属性的抓取
# BV号为1Lf4y1X7aE的视频属性抓取结束
# 开始BV号为1MV411m74U视频属性的抓取
# BV号为1MV411m74U的视频属性抓取结束
# 开始BV号为1nK411P7xh视频属性的抓取
# BV号为1nK411P7xh的视频属性抓取结束
# 开始BV号为1ef4y1D7Ys视频属性的抓取
# BV号为1ef4y1D7Ys的视频属性抓取结束
# 开始BV号为1SV411m7GT视频属性的抓取
# BV号为1SV411m7GT的视频属性抓取结束
# 开始BV号为1ya4y177pW视频属性的抓取
# BV号为1ya4y177pW的视频属性抓取结束
# 开始BV号为1fa4y1j7Jd视频属性的抓取
# BV号为1fa4y1j7Jd的视频属性抓取结束
# 开始BV号为1ah411X7Fg视频属性的抓取
# BV号为1ah411X7Fg的视频属性抓取结束
# 开始BV号为1p5411b7dk视频属性的抓取
# BV号为1p5411b7dk的视频属性抓取结束
# 开始BV号为1ri4y1M7Fe视频属性的抓取
# BV号为1ri4y1M7Fe的视频属性抓取结束
# 开始BV号为1kT4y1L7vZ视频属性的抓取
# BV号为1kT4y1L7vZ的视频属性抓取结束
# 开始BV号为1tf4y1D7eM视频属性的抓取
# BV号为1tf4y1D7eM的视频属性抓取结束
# 开始BV号为1EZ4y1N74k视频属性的抓取
# 开始BV号为1EZ4y1N74k视频属性的抓取
# BV号为1EZ4y1N74k的视频属性抓取结束
# 开始BV号为1RD4y1o7tg视频属性的抓取
# BV号为1RD4y1o7tg的视频属性抓取结束
# 开始BV号为1pi4y1M7tZ视频属性的抓取
# BV号为1pi4y1M7tZ的视频属性抓取结束
# 开始BV号为1yZ4y1N7TT视频属性的抓取
# BV号为1yZ4y1N7TT的视频属性抓取结束
# 开始BV号为1Bi4y1775g视频属性的抓取
# BV号为1Bi4y1775g的视频属性抓取结束
# 开始BV号为1ZK411N7g6视频属性的抓取
# BV号为1ZK411N7g6的视频属性抓取结束
# 开始BV号为1Bt4y1i7eM视频属性的抓取
# BV号为1Bt4y1i7eM的视频属性抓取结束
# 开始BV号为13Z4y1N7mf视频属性的抓取
# BV号为13Z4y1N7mf的视频属性抓取结束
# 开始BV号为1tK411P7bb视频属性的抓取
# BV号为1tK411P7bb的视频属性抓取结束
# 开始BV号为1Z54y117RF视频属性的抓取
# BV号为1Z54y117RF的视频属性抓取结束
# 开始BV号为1K54y1y78U视频属性的抓取
# BV号为1K54y1y78U的视频属性抓取结束
# 开始BV号为1bD4y1m7xg视频属性的抓取
# BV号为1bD4y1m7xg的视频属性抓取结束
# 开始BV号为1yi4y177fB视频属性的抓取
# BV号为1yi4y177fB的视频属性抓取结束
# 开始BV号为1aV411m7dZ视频属性的抓取
# BV号为1aV411m7dZ的视频属性抓取结束
# 开始BV号为1xf4y1X7Cu视频属性的抓取
# BV号为1xf4y1X7Cu的视频属性抓取结束
# 开始BV号为1Xh41197gA视频属性的抓取
# BV号为1Xh41197gA的视频属性抓取结束
# 开始BV号为1j54y1m7j1视频属性的抓取
# BV号为1j54y1m7j1的视频属性抓取结束
# 开始BV号为1Yy4y1k7Vq视频属性的抓取
# BV号为1Yy4y1k7Vq的视频属性抓取结束
# 开始BV号为1Jh411R73p视频属性的抓取
# BV号为1Jh411R73p的视频属性抓取结束
# 开始BV号为1kk4y1y7Rv视频属性的抓取
# BV号为1kk4y1y7Rv的视频属性抓取结束
# 开始BV号为1bD4y1R7p4视频属性的抓取
# BV号为1bD4y1R7p4的视频属性抓取结束
# 开始BV号为19i4y1M7NC视频属性的抓取
# BV号为19i4y1M7NC的视频属性抓取结束
# 开始BV号为1YK411P799视频属性的抓取
# BV号为1YK411P799的视频属性抓取结束
# 开始BV号为17y4y1y7j5视频属性的抓取
# BV号为17y4y1y7j5的视频属性抓取结束
# 开始BV号为15i4y1u7GV视频属性的抓取
# BV号为15i4y1u7GV的视频属性抓取结束
# 开始BV号为15D4y1o7ZH视频属性的抓取
# BV号为15D4y1o7ZH的视频属性抓取结束
# 开始BV号为1SD4y1R7z8视频属性的抓取
# BV号为1SD4y1R7z8的视频属性抓取结束
# 开始BV号为1Ti4y1u7As视频属性的抓取
# BV号为1Ti4y1u7As的视频属性抓取结束
# 开始BV号为1XA411E7Qr视频属性的抓取
# BV号为1XA411E7Qr的视频属性抓取结束
# 开始BV号为1oz4y1o7XD视频属性的抓取
# BV号为1oz4y1o7XD的视频属性抓取结束
# 开始BV号为1N54y1y7wv视频属性的抓取
# BV号为1N54y1y7wv的视频属性抓取结束
# 开始BV号为1e64y1F7ej视频属性的抓取
# BV号为1e64y1F7ej的视频属性抓取结束
# 开始BV号为19T4y1c7op视频属性的抓取
# BV号为19T4y1c7op的视频属性抓取结束
# 开始BV号为1Wy4y1B7f6视频属性的抓取
# BV号为1Wy4y1B7f6的视频属性抓取结束
# 开始BV号为1kV411y7Wo视频属性的抓取
# BV号为1kV411y7Wo的视频属性抓取结束
# 开始BV号为1TD4y197Xc视频属性的抓取
# BV号为1TD4y197Xc的视频属性抓取结束
# 开始BV号为1X54y1r7Zb视频属性的抓取
# BV号为1X54y1r7Zb的视频属性抓取结束
# 开始BV号为1Kf4y1q7N3视频属性的抓取
# 开始BV号为1Kf4y1q7N3视频属性的抓取
# 开始BV号为1Kf4y1q7N3视频属性的抓取
# 开始BV号为1Kf4y1q7N3视频属性的抓取
# BV号为1Kf4y1q7N3的视频属性抓取结束
# 开始BV号为1Fa4y1L7fK视频属性的抓取
# BV号为1Fa4y1L7fK的视频属性抓取结束
# 开始BV号为1Ck4y1C7QQ视频属性的抓取
# BV号为1Ck4y1C7QQ的视频属性抓取结束
# 开始BV号为1Ey4y1r7Co视频属性的抓取
# BV号为1Ey4y1r7Co的视频属性抓取结束
# 开始BV号为1At4y1i7Rw视频属性的抓取
# BV号为1At4y1i7Rw的视频属性抓取结束
# 开始BV号为1by4y1C7PJ视频属性的抓取
# BV号为1by4y1C7PJ的视频属性抓取结束
# 开始BV号为17y4y1r7pu视频属性的抓取
# BV号为17y4y1r7pu的视频属性抓取结束
# 开始BV号为1xp4y1k7W1视频属性的抓取
# BV号为1xp4y1k7W1的视频属性抓取结束
# 开始BV号为1fa4y157hp视频属性的抓取
# BV号为1fa4y157hp的视频属性抓取结束
# 开始BV号为1xy4y1C7Ed视频属性的抓取
# BV号为1xy4y1C7Ed的视频属性抓取结束
# 开始BV号为1HZ4y1V7wq视频属性的抓取
# BV号为1HZ4y1V7wq的视频属性抓取结束
# 开始BV号为1qK411A7PN视频属性的抓取
# BV号为1qK411A7PN的视频属性抓取结束
# 开始BV号为1QZ4y1G7ni视频属性的抓取
# BV号为1QZ4y1G7ni的视频属性抓取结束
# 开始BV号为1gD4y197fd视频属性的抓取
# BV号为1gD4y197fd的视频属性抓取结束
# 开始BV号为1SK4y177Fg视频属性的抓取
# BV号为1SK4y177Fg的视频属性抓取结束
# 开始BV号为1da4y157zz视频属性的抓取
# BV号为1da4y157zz的视频属性抓取结束
# 开始BV号为1fv41167R8视频属性的抓取
# BV号为1fv41167R8的视频属性抓取结束
# 开始BV号为1X54y1k7sD视频属性的抓取
# BV号为1X54y1k7sD的视频属性抓取结束
# 开始BV号为11Z4y1V7qP视频属性的抓取
# BV号为11Z4y1V7qP的视频属性抓取结束
# 开始BV号为1N541177L1视频属性的抓取
# BV号为1N541177L1的视频属性抓取结束
# 开始BV号为1d541157X1视频属性的抓取
# BV号为1d541157X1的视频属性抓取结束
# 开始BV号为17p4y1Y7jv视频属性的抓取
# BV号为17p4y1Y7jv的视频属性抓取结束
# 开始BV号为1dv411k7Ta视频属性的抓取
# BV号为1dv411k7Ta的视频属性抓取结束
# 开始BV号为1w54y1C7Zw视频属性的抓取
# BV号为1w54y1C7Zw的视频属性抓取结束
# 开始BV号为1Ka411A78h视频属性的抓取
# BV号为1Ka411A78h的视频属性抓取结束
# 开始BV号为1Jp4y1Y7V9视频属性的抓取
# BV号为1Jp4y1Y7V9的视频属性抓取结束
# 开始BV号为1NK4y1E7Ly视频属性的抓取
# BV号为1NK4y1E7Ly的视频属性抓取结束
# 开始BV号为1T54y1r7or视频属性的抓取
# BV号为1T54y1r7or的视频属性抓取结束
# 开始BV号为1JZ4y1L7yq视频属性的抓取
# BV号为1JZ4y1L7yq的视频属性抓取结束
# 开始BV号为1Ea4y1L7Mz视频属性的抓取
# BV号为1Ea4y1L7Mz的视频属性抓取结束
# 开始BV号为1rt4y1v7Qc视频属性的抓取
# BV号为1rt4y1v7Qc的视频属性抓取结束
# 开始BV号为1eK411N7yf视频属性的抓取
# BV号为1eK411N7yf的视频属性抓取结束
# 开始BV号为15Z4y1L7CL视频属性的抓取
# BV号为15Z4y1L7CL的视频属性抓取结束
# 开始BV号为1Kv411C7tT视频属性的抓取
# BV号为1Kv411C7tT的视频属性抓取结束
# 开始BV号为1Zi4y1j7WM视频属性的抓取
# BV号为1Zi4y1j7WM的视频属性抓取结束
# 开始BV号为13y4y1r719视频属性的抓取
# BV号为13y4y1r719的视频属性抓取结束
# 开始BV号为1sy4y1C7tt视频属性的抓取
# BV号为1sy4y1C7tt的视频属性抓取结束
# 开始BV号为1Az4y1o7jn视频属性的抓取
# BV号为1Az4y1o7jn的视频属性抓取结束
# 2020-12-21 05:53:33.984311

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-18-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_yinyue_xianchang.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月    43   43    43   43   43   43   43   43    43      43   43    43   43
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月     96   96    96   96   96   96   96   96    96      96   96    96   96
# 3月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月     83   83    83   83   83   83   83   83    83      83   83    83   83
# 9月     67   67    67   67   67   67   67   67    67      67   67    67   67
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月   43   43   43   43   43   43    43
# 1月   100  100  100  100  100  100   100
# 2月    96   96   96   96   96   96    96
# 3月   100  100  100  100  100  100   100
# 4月   100  100  100  100  100  100   100
# 5月    99   99   99   99   99   99    99
# 6月   100  100  100  100  100  100   100
# 7月   100  100  100  100  100  100   100
# 8月    83   83   83   83   83   83    83
# 9月    67   67   67   67   67   67    67

# %%
channel_yinyue_xianchang.to_json('channel_yinyue_xianchang.json')

# %% [markdown]
# 里面没有作者名为“说唱新世代X造浪”，因为结构不一样

# %%
channel_yinyue_xianchang.to_json('channel_yinyue_xianchang.json')
