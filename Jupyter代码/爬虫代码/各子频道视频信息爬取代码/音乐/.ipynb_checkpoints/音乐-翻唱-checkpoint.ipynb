# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_yinyue_fanchang=pd.DataFrame(columns=columns)
channel_yinyue_fanchang
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[3]/div/a/span').click()  #选择“音乐”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[3]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '音乐'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[3]/a').click()  #选择“翻唱”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[3]/a').text
sub_channel
# Out:
# '翻唱'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(2,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_yinyue_fanchang.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-20 10:07:05.112646
# <ipython-input-18-f37bbdbd021d>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-18-f37bbdbd021d>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-18-f37bbdbd021d>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1aE411n7wb视频属性的抓取
# E:\anaconda\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-18-f37bbdbd021d>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# BV号为1aE411n7wb的视频属性抓取结束
# 开始BV号为1Q7411E7uz视频属性的抓取
# BV号为1Q7411E7uz的视频属性抓取结束
# 开始BV号为1o7411N7FH视频属性的抓取
# 开始BV号为1o7411N7FH视频属性的抓取
# BV号为1o7411N7FH的视频属性抓取结束
# 开始BV号为1x74115773视频属性的抓取
# BV号为1x74115773的视频属性抓取结束
# 开始BV号为1a7411T74G视频属性的抓取
# BV号为1a7411T74G的视频属性抓取结束
# 开始BV号为1F7411c7u7视频属性的抓取
# BV号为1F7411c7u7的视频属性抓取结束
# 开始BV号为167411774N视频属性的抓取
# BV号为167411774N的视频属性抓取结束
# 开始BV号为1f7411t7Cy视频属性的抓取
# BV号为1f7411t7Cy的视频属性抓取结束
# 开始BV号为1p741187JY视频属性的抓取
# BV号为1p741187JY的视频属性抓取结束
# 开始BV号为1L7411j7pk视频属性的抓取
# BV号为1L7411j7pk的视频属性抓取结束
# 开始BV号为1p7411p7iD视频属性的抓取
# BV号为1p7411p7iD的视频属性抓取结束
# 开始BV号为1W741137u2视频属性的抓取
# BV号为1W741137u2的视频属性抓取结束
# 开始BV号为1R7411A7zY视频属性的抓取
# BV号为1R7411A7zY的视频属性抓取结束
# 开始BV号为1A7411P7D1视频属性的抓取
# BV号为1A7411P7D1的视频属性抓取结束
# 开始BV号为1w7411w7k4视频属性的抓取
# BV号为1w7411w7k4的视频属性抓取结束
# 开始BV号为1F7411b7EW视频属性的抓取
# BV号为1F7411b7EW的视频属性抓取结束
# 开始BV号为1kj411f7kA视频属性的抓取
# BV号为1kj411f7kA的视频属性抓取结束
# 开始BV号为1v7411w7e4视频属性的抓取
# BV号为1v7411w7e4的视频属性抓取结束
# 开始BV号为1qj411f7vM视频属性的抓取
# BV号为1qj411f7vM的视频属性抓取结束
# 开始BV号为1J7411H7EZ视频属性的抓取
# BV号为1J7411H7EZ的视频属性抓取结束
# 开始BV号为137411F7sA视频属性的抓取
# BV号为137411F7sA的视频属性抓取结束
# 开始BV号为1v7411J7wd视频属性的抓取
# BV号为1v7411J7wd的视频属性抓取结束
# 开始BV号为1D7411s7wr视频属性的抓取
# BV号为1D7411s7wr的视频属性抓取结束
# 开始BV号为1F7411G7KK视频属性的抓取
# BV号为1F7411G7KK的视频属性抓取结束
# 开始BV号为1F7411w7Ck视频属性的抓取
# BV号为1F7411w7Ck的视频属性抓取结束
# 开始BV号为1q7411V7RB视频属性的抓取
# BV号为1q7411V7RB的视频属性抓取结束
# 开始BV号为1J7411t7nj视频属性的抓取
# 开始BV号为1J7411t7nj视频属性的抓取
# BV号为1J7411t7nj的视频属性抓取结束
# 开始BV号为1L7411w79m视频属性的抓取
# BV号为1L7411w79m的视频属性抓取结束
# 开始BV号为1X741187kz视频属性的抓取
# 开始BV号为1X741187kz视频属性的抓取
# BV号为1X741187kz的视频属性抓取结束
# 开始BV号为1H7411u76J视频属性的抓取
# BV号为1H7411u76J的视频属性抓取结束
# 开始BV号为127411L7X8视频属性的抓取
# BV号为127411L7X8的视频属性抓取结束
# 开始BV号为1R7411u7xQ视频属性的抓取
# BV号为1R7411u7xQ的视频属性抓取结束
# 开始BV号为1j7411V7dB视频属性的抓取
# BV号为1j7411V7dB的视频属性抓取结束
# 开始BV号为1H7411t7Nu视频属性的抓取
# BV号为1H7411t7Nu的视频属性抓取结束
# 开始BV号为1Gj411f7TX视频属性的抓取
# BV号为1Gj411f7TX的视频属性抓取结束
# 开始BV号为1V7411N7c1视频属性的抓取
# BV号为1V7411N7c1的视频属性抓取结束
# 开始BV号为1C7411u7xn视频属性的抓取
# BV号为1C7411u7xn的视频属性抓取结束
# 开始BV号为137411n7W3视频属性的抓取
# BV号为137411n7W3的视频属性抓取结束
# 开始BV号为1n7411s7H2视频属性的抓取
# BV号为1n7411s7H2的视频属性抓取结束
# 开始BV号为1U7411V7Mg视频属性的抓取
# BV号为1U7411V7Mg的视频属性抓取结束
# 开始BV号为1Q7411j7ow视频属性的抓取
# BV号为1Q7411j7ow的视频属性抓取结束
# 开始BV号为1aE411J7hf视频属性的抓取
# 开始BV号为1aE411J7hf视频属性的抓取
# 开始BV号为1aE411J7hf视频属性的抓取
# BV号为1aE411J7hf的视频属性抓取结束
# 开始BV号为1aE411n7dK视频属性的抓取
# BV号为1aE411n7dK的视频属性抓取结束
# 开始BV号为1g7411c7kr视频属性的抓取
# BV号为1g7411c7kr的视频属性抓取结束
# 开始BV号为1H7411A7Pp视频属性的抓取
# BV号为1H7411A7Pp的视频属性抓取结束
# 开始BV号为1S7411c73W视频属性的抓取
# BV号为1S7411c73W的视频属性抓取结束
# <ipython-input-18-f37bbdbd021d>:190: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1d7411G7EK视频属性的抓取
# BV号为1d7411G7EK的视频属性抓取结束
# 开始BV号为1N7411N7nt视频属性的抓取
# BV号为1N7411N7nt的视频属性抓取结束
# 开始BV号为1Y7411V76Y视频属性的抓取
# BV号为1Y7411V76Y的视频属性抓取结束
# 开始BV号为1a7411G7Ca视频属性的抓取
# BV号为1a7411G7Ca的视频属性抓取结束
# 开始BV号为1c7411c7o6视频属性的抓取
# BV号为1c7411c7o6的视频属性抓取结束
# 开始BV号为137411b7Hz视频属性的抓取
# BV号为137411b7Hz的视频属性抓取结束
# 开始BV号为117411A73e视频属性的抓取
# BV号为117411A73e的视频属性抓取结束
# 开始BV号为157411g7vU视频属性的抓取
# BV号为157411g7vU的视频属性抓取结束
# 开始BV号为1v7411G73K视频属性的抓取
# BV号为1v7411G73K的视频属性抓取结束
# 开始BV号为137411c794视频属性的抓取
# BV号为137411c794的视频属性抓取结束
# 开始BV号为1sj411f73S视频属性的抓取
# BV号为1sj411f73S的视频属性抓取结束
# 开始BV号为1C7411p74a视频属性的抓取
# BV号为1C7411p74a的视频属性抓取结束
# 开始BV号为1h7411j71E视频属性的抓取
# BV号为1h7411j71E的视频属性抓取结束
# 开始BV号为11741137Ub视频属性的抓取
# BV号为11741137Ub的视频属性抓取结束
# 开始BV号为1M7411w7NS视频属性的抓取
# BV号为1M7411w7NS的视频属性抓取结束
# 开始BV号为1s7411T7bf视频属性的抓取
# BV号为1s7411T7bf的视频属性抓取结束
# 开始BV号为1V7411W7hX视频属性的抓取
# BV号为1V7411W7hX的视频属性抓取结束
# 开始BV号为167411T7qg视频属性的抓取
# BV号为167411T7qg的视频属性抓取结束
# 开始BV号为1K7411s7G9视频属性的抓取
# 开始BV号为1K7411s7G9视频属性的抓取
# BV号为1K7411s7G9的视频属性抓取结束
# 开始BV号为1DE411n7V3视频属性的抓取
# BV号为1DE411n7V3的视频属性抓取结束
# 开始BV号为1R7411g7gJ视频属性的抓取
# BV号为1R7411g7gJ的视频属性抓取结束
# 开始BV号为1V7411W7XC视频属性的抓取
# BV号为1V7411W7XC的视频属性抓取结束
# 开始BV号为1y7411u7So视频属性的抓取
# BV号为1y7411u7So的视频属性抓取结束
# 开始BV号为1K7411377P视频属性的抓取
# BV号为1K7411377P的视频属性抓取结束
# 开始BV号为1e7411w7Vy视频属性的抓取
# BV号为1e7411w7Vy的视频属性抓取结束
# 开始BV号为1N7411F7SG视频属性的抓取
# BV号为1N7411F7SG的视频属性抓取结束
# 开始BV号为1H7411K7v2视频属性的抓取
# BV号为1H7411K7v2的视频属性抓取结束
# 开始BV号为1x7411T7fM视频属性的抓取
# BV号为1x7411T7fM的视频属性抓取结束
# 开始BV号为1g7411c7Fk视频属性的抓取
# 开始BV号为1g7411c7Fk视频属性的抓取
# BV号为1g7411c7Fk的视频属性抓取结束
# 开始BV号为1Y7411b7aC视频属性的抓取
# BV号为1Y7411b7aC的视频属性抓取结束
# 开始BV号为1u7411H7b9视频属性的抓取
# 开始BV号为1u7411H7b9视频属性的抓取
# 开始BV号为1u7411H7b9视频属性的抓取
# BV号为1u7411H7b9的视频属性抓取结束
# 开始BV号为157411G7GH视频属性的抓取
# BV号为157411G7GH的视频属性抓取结束
# 开始BV号为1E7411F7Jn视频属性的抓取
# BV号为1E7411F7Jn的视频属性抓取结束
# 开始BV号为1W7411A7sz视频属性的抓取
# BV号为1W7411A7sz的视频属性抓取结束
# 开始BV号为1w7411c7rk视频属性的抓取
# BV号为1w7411c7rk的视频属性抓取结束
# 开始BV号为177411c7h4视频属性的抓取
# BV号为177411c7h4的视频属性抓取结束
# 开始BV号为1r7411K77Q视频属性的抓取
# BV号为1r7411K77Q的视频属性抓取结束
# 开始BV号为1t7411c75p视频属性的抓取
# 开始BV号为1t7411c75p视频属性的抓取
# 开始BV号为1t7411c75p视频属性的抓取
# BV号为1t7411c75p的视频属性抓取结束
# 开始BV号为1F741187XL视频属性的抓取
# BV号为1F741187XL的视频属性抓取结束
# 开始BV号为1N7411P7uZ视频属性的抓取
# BV号为1N7411P7uZ的视频属性抓取结束
# 开始BV号为1Y7411E73c视频属性的抓取
# BV号为1Y7411E73c的视频属性抓取结束
# 开始BV号为177411M7cY视频属性的抓取
# 开始BV号为177411M7cY视频属性的抓取
# BV号为177411M7cY的视频属性抓取结束
# 开始BV号为1s7411479E视频属性的抓取
# BV号为1s7411479E的视频属性抓取结束
# 开始BV号为1V7411w7Fu视频属性的抓取
# BV号为1V7411w7Fu的视频属性抓取结束
# 开始BV号为1j7411H739视频属性的抓取
# BV号为1j7411H739的视频属性抓取结束
# 开始BV号为1R741177uR视频属性的抓取
# BV号为1R741177uR的视频属性抓取结束
# 开始BV号为1D7411875E视频属性的抓取
# BV号为1D7411875E的视频属性抓取结束
# 开始BV号为1z7411577m视频属性的抓取
# BV号为1z7411577m的视频属性抓取结束
# 开始BV号为1Qj411f7LL视频属性的抓取
# BV号为1Qj411f7LL的视频属性抓取结束
# 开始BV号为1S7411h7tD视频属性的抓取
# BV号为1S7411h7tD的视频属性抓取结束
# 开始BV号为1y541147cN视频属性的抓取
# BV号为1y541147cN的视频属性抓取结束
# 开始BV号为1bE411c7kQ视频属性的抓取
# BV号为1bE411c7kQ的视频属性抓取结束
# 开始BV号为1KA411h7R5视频属性的抓取
# BV号为1KA411h7R5的视频属性抓取结束
# 开始BV号为1q7411Q7QA视频属性的抓取
# BV号为1q7411Q7QA的视频属性抓取结束
# 开始BV号为1NE411s7LF视频属性的抓取
# BV号为1NE411s7LF的视频属性抓取结束
# 开始BV号为1TE41137zQ视频属性的抓取
# BV号为1TE41137zQ的视频属性抓取结束
# 开始BV号为1Gp4y1C75z视频属性的抓取
# 开始BV号为1Gp4y1C75z视频属性的抓取
# BV号为1Gp4y1C75z的视频属性抓取结束
# 开始BV号为1UE411M7sN视频属性的抓取
# BV号为1UE411M7sN的视频属性抓取结束
# 开始BV号为1B7411R7a8视频属性的抓取
# BV号为1B7411R7a8的视频属性抓取结束
# 开始BV号为1F7411Z7JL视频属性的抓取
# BV号为1F7411Z7JL的视频属性抓取结束
# 开始BV号为1og4y1b7EZ视频属性的抓取
# BV号为1og4y1b7EZ的视频属性抓取结束
# 开始BV号为14E41147wa视频属性的抓取
# BV号为14E41147wa的视频属性抓取结束
# 开始BV号为1JE411u7wJ视频属性的抓取
# BV号为1JE411u7wJ的视频属性抓取结束
# 开始BV号为1EQ4y1M7sw视频属性的抓取
# BV号为1EQ4y1M7sw的视频属性抓取结束
# 开始BV号为1bz411h7EJ视频属性的抓取
# BV号为1bz411h7EJ的视频属性抓取结束
# 开始BV号为1wE411P7yj视频属性的抓取
# BV号为1wE411P7yj的视频属性抓取结束
# 开始BV号为1HE411L7xL视频属性的抓取
# BV号为1HE411L7xL的视频属性抓取结束
# 开始BV号为1y741117A7视频属性的抓取
# BV号为1y741117A7的视频属性抓取结束
# 开始BV号为1U7411o7X9视频属性的抓取
# BV号为1U7411o7X9的视频属性抓取结束
# 开始BV号为1X7411D7JS视频属性的抓取
# 开始BV号为1X7411D7JS视频属性的抓取
# 开始BV号为1X7411D7JS视频属性的抓取
# 开始BV号为1X7411D7JS视频属性的抓取
# BV号为1X7411D7JS的视频属性抓取结束
# 开始BV号为1z64y1M7Bc视频属性的抓取
# BV号为1z64y1M7Bc的视频属性抓取结束
# 开始BV号为1tE411c74Q视频属性的抓取
# BV号为1tE411c74Q的视频属性抓取结束
# 开始BV号为1o7411K7rB视频属性的抓取
# 开始BV号为1o7411K7rB视频属性的抓取
# BV号为1o7411K7rB的视频属性抓取结束
# 开始BV号为11E411w78Q视频属性的抓取
# BV号为11E411w78Q的视频属性抓取结束
# 开始BV号为1cE411K7qc视频属性的抓取
# BV号为1cE411K7qc的视频属性抓取结束
# 开始BV号为1qE411M7hZ视频属性的抓取
# BV号为1qE411M7hZ的视频属性抓取结束
# 开始BV号为1c741127PY视频属性的抓取
# BV号为1c741127PY的视频属性抓取结束
# 开始BV号为127411C7jS视频属性的抓取
# BV号为127411C7jS的视频属性抓取结束
# 开始BV号为1qe411x7PH视频属性的抓取
# BV号为1qe411x7PH的视频属性抓取结束
# 开始BV号为18E411E7Q4视频属性的抓取
# BV号为18E411E7Q4的视频属性抓取结束
# 开始BV号为15E41137qt视频属性的抓取
# BV号为15E41137qt的视频属性抓取结束
# 开始BV号为1T7411Z7Kx视频属性的抓取
# BV号为1T7411Z7Kx的视频属性抓取结束
# 开始BV号为1hE411M7hs视频属性的抓取
# BV号为1hE411M7hs的视频属性抓取结束
# 开始BV号为1QE41147Td视频属性的抓取
# BV号为1QE41147Td的视频属性抓取结束
# 开始BV号为1Yt4y1m7FU视频属性的抓取
# BV号为1Yt4y1m7FU的视频属性抓取结束
# 开始BV号为1CE411g7tW视频属性的抓取
# BV号为1CE411g7tW的视频属性抓取结束
# 开始BV号为1gC4y1s7iX视频属性的抓取
# BV号为1gC4y1s7iX的视频属性抓取结束
# 开始BV号为11E411W7o7视频属性的抓取
# BV号为11E411W7o7的视频属性抓取结束
# 开始BV号为1mE411V7s7视频属性的抓取
# BV号为1mE411V7s7的视频属性抓取结束
# 开始BV号为13E411M7ei视频属性的抓取
# 开始BV号为13E411M7ei视频属性的抓取
# BV号为13E411M7ei的视频属性抓取结束
# 开始BV号为1k7411y7UM视频属性的抓取
# BV号为1k7411y7UM的视频属性抓取结束
# 开始BV号为1E7411Z7Mx视频属性的抓取
# BV号为1E7411Z7Mx的视频属性抓取结束
# 开始BV号为1xK4y1C7Ci视频属性的抓取
# BV号为1xK4y1C7Ci的视频属性抓取结束
# 开始BV号为1pE411E7PH视频属性的抓取
# BV号为1pE411E7PH的视频属性抓取结束
# 开始BV号为1pE411E7z8视频属性的抓取
# BV号为1pE411E7z8的视频属性抓取结束
# 开始BV号为1LE411g794视频属性的抓取
# BV号为1LE411g794的视频属性抓取结束
# 开始BV号为1CE41177hb视频属性的抓取
# BV号为1CE41177hb的视频属性抓取结束
# 开始BV号为1JE41177Mw视频属性的抓取
# BV号为1JE41177Mw的视频属性抓取结束
# 开始BV号为1hE411M7Qv视频属性的抓取
# BV号为1hE411M7Qv的视频属性抓取结束
# 开始BV号为1ME411w7bb视频属性的抓取
# BV号为1ME411w7bb的视频属性抓取结束
# 开始BV号为1xE41147xA视频属性的抓取
# BV号为1xE41147xA的视频属性抓取结束
# 开始BV号为1BE411p7oi视频属性的抓取
# BV号为1BE411p7oi的视频属性抓取结束
# 开始BV号为1hT4y1578K视频属性的抓取
# 开始BV号为1hT4y1578K视频属性的抓取
# BV号为1hT4y1578K的视频属性抓取结束
# 开始BV号为1PE411x7LS视频属性的抓取
# BV号为1PE411x7LS的视频属性抓取结束
# 开始BV号为15E411E7DK视频属性的抓取
# BV号为15E411E7DK的视频属性抓取结束
# 开始BV号为1tt4y1m7fS视频属性的抓取
# BV号为1tt4y1m7fS的视频属性抓取结束
# 开始BV号为1HE411K7Ga视频属性的抓取
# BV号为1HE411K7Ga的视频属性抓取结束
# 开始BV号为16E41157bo视频属性的抓取
# BV号为16E41157bo的视频属性抓取结束
# 开始BV号为1xE411G7ui视频属性的抓取
# BV号为1xE411G7ui的视频属性抓取结束
# 开始BV号为1SK4y1C7wF视频属性的抓取
# BV号为1SK4y1C7wF的视频属性抓取结束
# 开始BV号为1FE41177uq视频属性的抓取
# BV号为1FE41177uq的视频属性抓取结束
# 开始BV号为1iE41157V6视频属性的抓取
# BV号为1iE41157V6的视频属性抓取结束
# 开始BV号为1r741127vn视频属性的抓取
# BV号为1r741127vn的视频属性抓取结束
# 开始BV号为1z7411Z71i视频属性的抓取
# BV号为1z7411Z71i的视频属性抓取结束
# 开始BV号为1uE411p7qZ视频属性的抓取
# BV号为1uE411p7qZ的视频属性抓取结束
# 开始BV号为1J741127bJ视频属性的抓取
# BV号为1J741127bJ的视频属性抓取结束
# 开始BV号为14C4y147BA视频属性的抓取
# BV号为14C4y147BA的视频属性抓取结束
# 开始BV号为1PE411c71K视频属性的抓取
# BV号为1PE411c71K的视频属性抓取结束
# <ipython-input-18-f37bbdbd021d>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为17E41147Ju视频属性的抓取
# BV号为17E41147Ju的视频属性抓取结束
# 开始BV号为1hE411L7ce视频属性的抓取
# BV号为1hE411L7ce的视频属性抓取结束
# 开始BV号为1sE411x7fj视频属性的抓取
# BV号为1sE411x7fj的视频属性抓取结束
# 开始BV号为1pE411g7A9视频属性的抓取
# BV号为1pE411g7A9的视频属性抓取结束
# 开始BV号为117411C7ci视频属性的抓取
# BV号为117411C7ci的视频属性抓取结束
# 开始BV号为1kE411p79R视频属性的抓取
# BV号为1kE411p79R的视频属性抓取结束
# 开始BV号为1mE411j7Lc视频属性的抓取
# BV号为1mE411j7Lc的视频属性抓取结束
# 开始BV号为1qE41137kV视频属性的抓取
# 开始BV号为1qE41137kV视频属性的抓取
# 开始BV号为1qE41137kV视频属性的抓取
# BV号为1qE41137kV的视频属性抓取结束
# 开始BV号为1gE411572G视频属性的抓取
# BV号为1gE411572G的视频属性抓取结束
# 开始BV号为1LE411T7Un视频属性的抓取
# BV号为1LE411T7Un的视频属性抓取结束
# 开始BV号为1xE411476s视频属性的抓取
# BV号为1xE411476s的视频属性抓取结束
# 开始BV号为1j7411m7w3视频属性的抓取
# 开始BV号为1j7411m7w3视频属性的抓取
# BV号为1j7411m7w3的视频属性抓取结束
# 开始BV号为19E41157nN视频属性的抓取
# BV号为19E41157nN的视频属性抓取结束
# 开始BV号为19E4113752视频属性的抓取
# BV号为19E4113752的视频属性抓取结束
# 开始BV号为1CE411P7Ty视频属性的抓取
# 开始BV号为1CE411P7Ty视频属性的抓取
# 开始BV号为1CE411P7Ty视频属性的抓取
# BV号为1CE411P7Ty的视频属性抓取结束
# 开始BV号为1j7411f7Bt视频属性的抓取
# BV号为1j7411f7Bt的视频属性抓取结束
# 开始BV号为1YE411x7EY视频属性的抓取
# BV号为1YE411x7EY的视频属性抓取结束
# 开始BV号为1VE411K7mB视频属性的抓取
# BV号为1VE411K7mB的视频属性抓取结束
# 开始BV号为1RE411H7mW视频属性的抓取
# BV号为1RE411H7mW的视频属性抓取结束
# 开始BV号为1UE411V7hD视频属性的抓取
# BV号为1UE411V7hD的视频属性抓取结束
# 开始BV号为1XE411P7kd视频属性的抓取
# BV号为1XE411P7kd的视频属性抓取结束
# 开始BV号为1HC4y1s76A视频属性的抓取
# BV号为1HC4y1s76A的视频属性抓取结束
# 开始BV号为1hE411g7cF视频属性的抓取
# BV号为1hE411g7cF的视频属性抓取结束
# 开始BV号为11E411G7os视频属性的抓取
# BV号为11E411G7os的视频属性抓取结束
# 开始BV号为1KC4y1s71a视频属性的抓取
# BV号为1KC4y1s71a的视频属性抓取结束
# 开始BV号为1P7411179t视频属性的抓取
# BV号为1P7411179t的视频属性抓取结束
# 开始BV号为1fE411W7DM视频属性的抓取
# BV号为1fE411W7DM的视频属性抓取结束
# 开始BV号为16E411p7ey视频属性的抓取
# BV号为16E411p7ey的视频属性抓取结束
# 开始BV号为1YE411W7DL视频属性的抓取
# BV号为1YE411W7DL的视频属性抓取结束
# 开始BV号为1CE411E71x视频属性的抓取
# BV号为1CE411E71x的视频属性抓取结束
# 开始BV号为1D541167gU视频属性的抓取
# BV号为1D541167gU的视频属性抓取结束
# 开始BV号为1pZ4y1j7nA视频属性的抓取
# BV号为1pZ4y1j7nA的视频属性抓取结束
# 开始BV号为1He41147Rs视频属性的抓取
# BV号为1He41147Rs的视频属性抓取结束
# 开始BV号为1dT4y1G7zx视频属性的抓取
# BV号为1dT4y1G7zx的视频属性抓取结束
# 开始BV号为1Sp4y1X7uq视频属性的抓取
# BV号为1Sp4y1X7uq的视频属性抓取结束
# 开始BV号为1GT4y1571D视频属性的抓取
# BV号为1GT4y1571D的视频属性抓取结束
# 开始BV号为1st4y1U78m视频属性的抓取
# BV号为1st4y1U78m的视频属性抓取结束
# 开始BV号为14i4y1t7U5视频属性的抓取
# 开始BV号为14i4y1t7U5视频属性的抓取
# BV号为14i4y1t7U5的视频属性抓取结束
# 开始BV号为1S64y1T76x视频属性的抓取
# BV号为1S64y1T76x的视频属性抓取结束
# 开始BV号为19K411L7FE视频属性的抓取
# BV号为19K411L7FE的视频属性抓取结束
# 开始BV号为1Zt4y127Ju视频属性的抓取
# BV号为1Zt4y127Ju的视频属性抓取结束
# 开始BV号为1D54y1Q7B7视频属性的抓取
# BV号为1D54y1Q7B7的视频属性抓取结束
# 开始BV号为1ht4y127pc视频属性的抓取
# BV号为1ht4y127pc的视频属性抓取结束
# 开始BV号为16k4y1r7UQ视频属性的抓取
# BV号为16k4y1r7UQ的视频属性抓取结束
# 开始BV号为1654y1Q76M视频属性的抓取
# BV号为1654y1Q76M的视频属性抓取结束
# 开始BV号为1T64y1u7Dm视频属性的抓取
# BV号为1T64y1u7Dm的视频属性抓取结束
# 开始BV号为1KC4y1W7uD视频属性的抓取
# BV号为1KC4y1W7uD的视频属性抓取结束
# 开始BV号为1Ga4y147uB视频属性的抓取
# BV号为1Ga4y147uB的视频属性抓取结束
# 开始BV号为1nk4y1R72d视频属性的抓取
# BV号为1nk4y1R72d的视频属性抓取结束
# 开始BV号为1te411x7Bt视频属性的抓取
# BV号为1te411x7Bt的视频属性抓取结束
# 开始BV号为1eK411L76J视频属性的抓取
# BV号为1eK411L76J的视频属性抓取结束
# 开始BV号为1KA411b7kp视频属性的抓取
# BV号为1KA411b7kp的视频属性抓取结束
# 开始BV号为1Te411s7Em视频属性的抓取
# BV号为1Te411s7Em的视频属性抓取结束
# 开始BV号为1sV411f7zG视频属性的抓取
# BV号为1sV411f7zG的视频属性抓取结束
# 开始BV号为1J64y1M7Zd视频属性的抓取
# 开始BV号为1J64y1M7Zd视频属性的抓取
# BV号为1J64y1M7Zd的视频属性抓取结束
# 开始BV号为1Hp4y1y7iQ视频属性的抓取
# BV号为1Hp4y1y7iQ的视频属性抓取结束
# 开始BV号为1De411x7RA视频属性的抓取
# BV号为1De411x7RA的视频属性抓取结束
# 开始BV号为1Cz411B7iY视频属性的抓取
# BV号为1Cz411B7iY的视频属性抓取结束
# 开始BV号为13Z4y147NJ视频属性的抓取
# BV号为13Z4y147NJ的视频属性抓取结束
# 开始BV号为1w5411t7Ar视频属性的抓取
# BV号为1w5411t7Ar的视频属性抓取结束
# 开始BV号为1664y1u7bj视频属性的抓取
# BV号为1664y1u7bj的视频属性抓取结束
# 开始BV号为1e5411t7P3视频属性的抓取
# BV号为1e5411t7P3的视频属性抓取结束
# 开始BV号为1T64y1M7sA视频属性的抓取
# BV号为1T64y1M7sA的视频属性抓取结束
# 开始BV号为19C4y1s7Ka视频属性的抓取
# BV号为19C4y1s7Ka的视频属性抓取结束
# 开始BV号为1Fe41147h8视频属性的抓取
# BV号为1Fe41147h8的视频属性抓取结束
# 开始BV号为1jg4y1z74z视频属性的抓取
# BV号为1jg4y1z74z的视频属性抓取结束
# 开始BV号为1up4y1y77i视频属性的抓取
# BV号为1up4y1y77i的视频属性抓取结束
# 开始BV号为1Lz411b79U视频属性的抓取
# BV号为1Lz411b79U的视频属性抓取结束
# 开始BV号为1WK411j7Yw视频属性的抓取
# BV号为1WK411j7Yw的视频属性抓取结束
# 开始BV号为13A411h7mD视频属性的抓取
# BV号为13A411h7mD的视频属性抓取结束
# 开始BV号为17p4y1y7U2视频属性的抓取
# BV号为17p4y1y7U2的视频属性抓取结束
# 开始BV号为15Z4y147KG视频属性的抓取
# BV号为15Z4y147KG的视频属性抓取结束
# 开始BV号为1VT4y1G7cb视频属性的抓取
# BV号为1VT4y1G7cb的视频属性抓取结束
# 开始BV号为1PZ4y1x7Vd视频属性的抓取
# BV号为1PZ4y1x7Vd的视频属性抓取结束
# 开始BV号为1wA411h7JB视频属性的抓取
# BV号为1wA411h7JB的视频属性抓取结束
# 开始BV号为1zA411b7Ny视频属性的抓取
# BV号为1zA411b7Ny的视频属性抓取结束
# 开始BV号为1wC4y1W7Lc视频属性的抓取
# BV号为1wC4y1W7Lc的视频属性抓取结束
# 开始BV号为1pa4y147gY视频属性的抓取
# BV号为1pa4y147gY的视频属性抓取结束
# 开始BV号为1hK41157pe视频属性的抓取
# BV号为1hK41157pe的视频属性抓取结束
# 开始BV号为17K411j7k1视频属性的抓取
# BV号为17K411j7k1的视频属性抓取结束
# 开始BV号为1Nk4y1R7Md视频属性的抓取
# BV号为1Nk4y1R7Md的视频属性抓取结束
# 开始BV号为1Ap4y1y7Z7视频属性的抓取
# BV号为1Ap4y1y7Z7的视频属性抓取结束
# 开始BV号为1ci4y187HK视频属性的抓取
# 开始BV号为1ci4y187HK视频属性的抓取
# BV号为1ci4y187HK的视频属性抓取结束
# 开始BV号为1rf4y1U7Rr视频属性的抓取
# BV号为1rf4y1U7Rr的视频属性抓取结束
# 开始BV号为1EC4y1x7fk视频属性的抓取
# BV号为1EC4y1x7fk的视频属性抓取结束
# 开始BV号为1564y1M7xF视频属性的抓取
# BV号为1564y1M7xF的视频属性抓取结束
# 开始BV号为1EV411d7pY视频属性的抓取
# BV号为1EV411d7pY的视频属性抓取结束
# 开始BV号为15K411j7Px视频属性的抓取
# 开始BV号为15K411j7Px视频属性的抓取
# BV号为15K411j7Px的视频属性抓取结束
# 开始BV号为1b5411t7AA视频属性的抓取
# BV号为1b5411t7AA的视频属性抓取结束
# 开始BV号为1554y197Sz视频属性的抓取
# 开始BV号为1554y197Sz视频属性的抓取
# BV号为1554y197Sz的视频属性抓取结束
# 开始BV号为1FV411d7nT视频属性的抓取
# BV号为1FV411d7nT的视频属性抓取结束
# 开始BV号为1Sf4y1U76o视频属性的抓取
# BV号为1Sf4y1U76o的视频属性抓取结束
# 开始BV号为1ui4y187so视频属性的抓取
# BV号为1ui4y187so的视频属性抓取结束
# 开始BV号为1GC4y1W7UH视频属性的抓取
# BV号为1GC4y1W7UH的视频属性抓取结束
# 开始BV号为1Et4y127sH视频属性的抓取
# BV号为1Et4y127sH的视频属性抓取结束
# 开始BV号为1gC4y1s7pG视频属性的抓取
# BV号为1gC4y1s7pG的视频属性抓取结束
# 开始BV号为1mK411V742视频属性的抓取
# BV号为1mK411V742的视频属性抓取结束
# 开始BV号为1rf4y1S7Be视频属性的抓取
# BV号为1rf4y1S7Be的视频属性抓取结束
# 开始BV号为1gQ4y1N747视频属性的抓取
# BV号为1gQ4y1N747的视频属性抓取结束
# 开始BV号为1w64y1M7V6视频属性的抓取
# BV号为1w64y1M7V6的视频属性抓取结束
# 开始BV号为1U64y1T7vZ视频属性的抓取
# 开始BV号为1U64y1T7vZ视频属性的抓取
# BV号为1U64y1T7vZ的视频属性抓取结束
# 开始BV号为1EA411b7qq视频属性的抓取
# BV号为1EA411b7qq的视频属性抓取结束
# 开始BV号为1Fg4y1h7HY视频属性的抓取
# BV号为1Fg4y1h7HY的视频属性抓取结束
# 开始BV号为17A411b7fh视频属性的抓取
# BV号为17A411b7fh的视频属性抓取结束
# 开始BV号为1yt4y127b8视频属性的抓取
# BV号为1yt4y127b8的视频属性抓取结束
# 开始BV号为1qt4y1U7eh视频属性的抓取
# BV号为1qt4y1U7eh的视频属性抓取结束
# 开始BV号为1dz411b7iu视频属性的抓取
# BV号为1dz411b7iu的视频属性抓取结束
# 开始BV号为1mf4y1U78U视频属性的抓取
# BV号为1mf4y1U78U的视频属性抓取结束
# 开始BV号为1ec411h7mm视频属性的抓取
# BV号为1ec411h7mm的视频属性抓取结束
# 开始BV号为1Df4y1U7uf视频属性的抓取
# 开始BV号为1Df4y1U7uf视频属性的抓取
# 开始BV号为1Df4y1U7uf视频属性的抓取
# BV号为1Df4y1U7uf的视频属性抓取结束
# 开始BV号为1Jg4y1a7Je视频属性的抓取
# BV号为1Jg4y1a7Je的视频属性抓取结束
# 开始BV号为1R54y197Ap视频属性的抓取
# BV号为1R54y197Ap的视频属性抓取结束
# 开始BV号为1w541147hj视频属性的抓取
# 开始BV号为1w541147hj视频属性的抓取
# BV号为1w541147hj的视频属性抓取结束
# 开始BV号为18a4y1t7Xm视频属性的抓取
# BV号为18a4y1t7Xm的视频属性抓取结束
# 开始BV号为1R541147ue视频属性的抓取
# BV号为1R541147ue的视频属性抓取结束
# 开始BV号为1q64y1u73B视频属性的抓取
# BV号为1q64y1u73B的视频属性抓取结束
# 开始BV号为1b54y19733视频属性的抓取
# 开始BV号为1b54y19733视频属性的抓取
# 开始BV号为1b54y19733视频属性的抓取
# 开始BV号为1b54y19733视频属性的抓取
# 开始BV号为1b54y19733视频属性的抓取
# BV号为1b54y19733的视频属性抓取结束
# 开始BV号为1xZ4y1x7bD视频属性的抓取
# BV号为1xZ4y1x7bD的视频属性抓取结束
# 开始BV号为17i4y187uU视频属性的抓取
# BV号为17i4y187uU的视频属性抓取结束
# 开始BV号为1PT4y157VD视频属性的抓取
# BV号为1PT4y157VD的视频属性抓取结束
# 开始BV号为1QA411b7pJ视频属性的抓取
# BV号为1QA411b7pJ的视频属性抓取结束
# 开始BV号为1zt4y1m7kC视频属性的抓取
# BV号为1zt4y1m7kC的视频属性抓取结束
# 开始BV号为1Z5411x7cD视频属性的抓取
# BV号为1Z5411x7cD的视频属性抓取结束
# 开始BV号为1dK4y1r7Wc视频属性的抓取
# BV号为1dK4y1r7Wc的视频属性抓取结束
# 开始BV号为1iz411B7py视频属性的抓取
# BV号为1iz411B7py的视频属性抓取结束
# 开始BV号为14e411x7tj视频属性的抓取
# BV号为14e411x7tj的视频属性抓取结束
# 开始BV号为1pz411z7N3视频属性的抓取
# BV号为1pz411z7N3的视频属性抓取结束
# 开始BV号为1vZ4y1x7xS视频属性的抓取
# BV号为1vZ4y1x7xS的视频属性抓取结束
# 开始BV号为1Ka4y1t79C视频属性的抓取
# BV号为1Ka4y1t79C的视频属性抓取结束
# 开始BV号为1Wp4y1y7W4视频属性的抓取
# BV号为1Wp4y1y7W4的视频属性抓取结束
# 开始BV号为1dp4y1C7Sb视频属性的抓取
# BV号为1dp4y1C7Sb的视频属性抓取结束
# 开始BV号为1hz4y1R7pz视频属性的抓取
# BV号为1hz4y1R7pz的视频属性抓取结束
# 开始BV号为1F54y1X7mg视频属性的抓取
# BV号为1F54y1X7mg的视频属性抓取结束
# 开始BV号为1bp4y1Q75Q视频属性的抓取
# BV号为1bp4y1Q75Q的视频属性抓取结束
# 开始BV号为1DT4y137gf视频属性的抓取
# BV号为1DT4y137gf的视频属性抓取结束
# 开始BV号为1cQ4y1P7CS视频属性的抓取
# BV号为1cQ4y1P7CS的视频属性抓取结束
# 开始BV号为1W54y1X73b视频属性的抓取
# BV号为1W54y1X73b的视频属性抓取结束
# 开始BV号为13z411q7gQ视频属性的抓取
# BV号为13z411q7gQ的视频属性抓取结束
# 开始BV号为1CA411q7Pr视频属性的抓取
# BV号为1CA411q7Pr的视频属性抓取结束
# 开始BV号为1ap4y1Q7eL视频属性的抓取
# BV号为1ap4y1Q7eL的视频属性抓取结束
# 开始BV号为1Lz4y1R7Kc视频属性的抓取
# BV号为1Lz4y1R7Kc的视频属性抓取结束
# 开始BV号为1Tg4y1B78W视频属性的抓取
# BV号为1Tg4y1B78W的视频属性抓取结束
# 开始BV号为1A54y1X7BV视频属性的抓取
# BV号为1A54y1X7BV的视频属性抓取结束
# 开始BV号为19f4y1173X视频属性的抓取
# BV号为19f4y1173X的视频属性抓取结束
# 开始BV号为1ii4y1472v视频属性的抓取
# BV号为1ii4y1472v的视频属性抓取结束
# 开始BV号为1Bp4y1Q79H视频属性的抓取
# BV号为1Bp4y1Q79H的视频属性抓取结束
# 开始BV号为1254y1X7G3视频属性的抓取
# BV号为1254y1X7G3的视频属性抓取结束
# 开始BV号为1jT4y1u7bR视频属性的抓取
# BV号为1jT4y1u7bR的视频属性抓取结束
# 开始BV号为1We411W72V视频属性的抓取
# BV号为1We411W72V的视频属性抓取结束
# 开始BV号为1xk4y1k7aw视频属性的抓取
# BV号为1xk4y1k7aw的视频属性抓取结束
# 开始BV号为1qf4y127x5视频属性的抓取
# BV号为1qf4y127x5的视频属性抓取结束
# 开始BV号为1w5411s7vn视频属性的抓取
# BV号为1w5411s7vn的视频属性抓取结束
# 开始BV号为19K411H7Dg视频属性的抓取
# BV号为19K411H7Dg的视频属性抓取结束
# 开始BV号为1tv411z7hQ视频属性的抓取
# BV号为1tv411z7hQ的视频属性抓取结束
# 开始BV号为1KQ4y1K7iZ视频属性的抓取
# BV号为1KQ4y1K7iZ的视频属性抓取结束
# 开始BV号为14K4y1t7S4视频属性的抓取
# BV号为14K4y1t7S4的视频属性抓取结束
# 开始BV号为1Xe411s7vG视频属性的抓取
# BV号为1Xe411s7vG的视频属性抓取结束
# 开始BV号为1ae411W7Va视频属性的抓取
# BV号为1ae411W7Va的视频属性抓取结束
# 开始BV号为14v411z7W7视频属性的抓取
# BV号为14v411z7W7的视频属性抓取结束
# 开始BV号为1kz411q7tY视频属性的抓取
# BV号为1kz411q7tY的视频属性抓取结束
# 开始BV号为1Mi4y1b7pt视频属性的抓取
# BV号为1Mi4y1b7pt的视频属性抓取结束
# 开始BV号为1Ut4y1y73P视频属性的抓取
# BV号为1Ut4y1y73P的视频属性抓取结束
# 开始BV号为16K411W79z视频属性的抓取
# BV号为16K411W79z的视频属性抓取结束
# 开始BV号为1Vk4y1k7Km视频属性的抓取
# BV号为1Vk4y1k7Km的视频属性抓取结束
# 开始BV号为1bA411t7GB视频属性的抓取
# BV号为1bA411t7GB的视频属性抓取结束
# 开始BV号为1mK4y1t787视频属性的抓取
# 开始BV号为1mK4y1t787视频属性的抓取
# BV号为1mK4y1t787的视频属性抓取结束
# 开始BV号为15z4y1R73C视频属性的抓取
# BV号为15z4y1R73C的视频属性抓取结束
# 开始BV号为1Cz411v7Zg视频属性的抓取
# BV号为1Cz411v7Zg的视频属性抓取结束
# 开始BV号为1aK4y1b7ce视频属性的抓取
# BV号为1aK4y1b7ce的视频属性抓取结束
# 开始BV号为16K411W7yz视频属性的抓取
# BV号为16K411W7yz的视频属性抓取结束
# 开始BV号为1vi4y1s77d视频属性的抓取
# BV号为1vi4y1s77d的视频属性抓取结束
# 开始BV号为1wa4y1i7RS视频属性的抓取
# BV号为1wa4y1i7RS的视频属性抓取结束
# 开始BV号为11V411C7BQ视频属性的抓取
# BV号为11V411C7BQ的视频属性抓取结束
# 开始BV号为1MK411W78a视频属性的抓取
# BV号为1MK411W78a的视频属性抓取结束
# 开始BV号为11Q4y1N745视频属性的抓取
# BV号为11Q4y1N745的视频属性抓取结束
# 开始BV号为1DZ4y1p7Fj视频属性的抓取
# BV号为1DZ4y1p7Fj的视频属性抓取结束
# 开始BV号为1Yf4y1m7JX视频属性的抓取
# BV号为1Yf4y1m7JX的视频属性抓取结束
# 开始BV号为1TV411C7qR视频属性的抓取
# BV号为1TV411C7qR的视频属性抓取结束
# 开始BV号为1kz411v7U4视频属性的抓取
# BV号为1kz411v7U4的视频属性抓取结束
# 开始BV号为1W5411473m视频属性的抓取
# BV号为1W5411473m的视频属性抓取结束
# 开始BV号为1Gp4y1X7o7视频属性的抓取
# BV号为1Gp4y1X7o7的视频属性抓取结束
# 开始BV号为18e411p7WH视频属性的抓取
# BV号为18e411p7WH的视频属性抓取结束
# 开始BV号为1Rp4y1S7dY视频属性的抓取
# BV号为1Rp4y1S7dY的视频属性抓取结束
# 开始BV号为1gi4y147wL视频属性的抓取
# BV号为1gi4y147wL的视频属性抓取结束
# 开始BV号为19t4y1C7ta视频属性的抓取
# BV号为19t4y1C7ta的视频属性抓取结束
# 开始BV号为1uk4y167cu视频属性的抓取
# BV号为1uk4y167cu的视频属性抓取结束
# 开始BV号为1y54y1D73U视频属性的抓取
# BV号为1y54y1D73U的视频属性抓取结束
# 开始BV号为1fT4y1u7nB视频属性的抓取
# BV号为1fT4y1u7nB的视频属性抓取结束
# 开始BV号为1sa4y1i745视频属性的抓取
# BV号为1sa4y1i745的视频属性抓取结束
# 开始BV号为1RQ4y1N7QM视频属性的抓取
# BV号为1RQ4y1N7QM的视频属性抓取结束
# 开始BV号为1CZ4y1p7JR视频属性的抓取
# BV号为1CZ4y1p7JR的视频属性抓取结束
# 开始BV号为19Z4y1s7Kv视频属性的抓取
# BV号为19Z4y1s7Kv的视频属性抓取结束
# 开始BV号为1SV411k7N2视频属性的抓取
# BV号为1SV411k7N2的视频属性抓取结束
# 开始BV号为1cK4y1b7NP视频属性的抓取
# BV号为1cK4y1b7NP的视频属性抓取结束
# 开始BV号为1H541147cC视频属性的抓取
# BV号为1H541147cC的视频属性抓取结束
# 开始BV号为1gi4y147Ra视频属性的抓取
# BV号为1gi4y147Ra的视频属性抓取结束
# 开始BV号为1Lk4y167Bn视频属性的抓取
# BV号为1Lk4y167Bn的视频属性抓取结束
# 开始BV号为1hQ4y1A7C9视频属性的抓取
# BV号为1hQ4y1A7C9的视频属性抓取结束
# 开始BV号为1pz4y1R7Ui视频属性的抓取
# BV号为1pz4y1R7Ui的视频属性抓取结束
# 开始BV号为1xt4y117yu视频属性的抓取
# BV号为1xt4y117yu的视频属性抓取结束
# 开始BV号为1jg4y1B73e视频属性的抓取
# BV号为1jg4y1B73e的视频属性抓取结束
# 开始BV号为12e411s7E7视频属性的抓取
# BV号为12e411s7E7的视频属性抓取结束
# 开始BV号为1VK411s7pP视频属性的抓取
# BV号为1VK411s7pP的视频属性抓取结束
# 开始BV号为1Jp4y1Q7Vw视频属性的抓取
# BV号为1Jp4y1Q7Vw的视频属性抓取结束
# 开始BV号为1hZ4y1s7Gh视频属性的抓取
# BV号为1hZ4y1s7Gh的视频属性抓取结束
# 开始BV号为13Z4y1W7TB视频属性的抓取
# BV号为13Z4y1W7TB的视频属性抓取结束
# 开始BV号为15g4y1B74c视频属性的抓取
# BV号为15g4y1B74c的视频属性抓取结束
# 开始BV号为1tV411d7n5视频属性的抓取
# BV号为1tV411d7n5的视频属性抓取结束
# 开始BV号为1xg4y1B7DG视频属性的抓取
# BV号为1xg4y1B7DG的视频属性抓取结束
# 开始BV号为1if4y1m725视频属性的抓取
# BV号为1if4y1m725的视频属性抓取结束
# 开始BV号为1KK411s74h视频属性的抓取
# BV号为1KK411s74h的视频属性抓取结束
# 开始BV号为1mV411k7hV视频属性的抓取
# BV号为1mV411k7hV的视频属性抓取结束
# 开始BV号为1pp4y1Q7Fq视频属性的抓取
# BV号为1pp4y1Q7Fq的视频属性抓取结束
# 开始BV号为1DK411H7Hv视频属性的抓取
# BV号为1DK411H7Hv的视频属性抓取结束
# 开始BV号为1j54y1X7pZ视频属性的抓取
# BV号为1j54y1X7pZ的视频属性抓取结束
# 开始BV号为1W54y1X7s4视频属性的抓取
# BV号为1W54y1X7s4的视频属性抓取结束
# 开始BV号为1St4y117KX视频属性的抓取
# BV号为1St4y117KX的视频属性抓取结束
# 开始BV号为1Kz411B7ig视频属性的抓取
# 开始BV号为1Kz411B7ig视频属性的抓取
# BV号为1Kz411B7ig的视频属性抓取结束
# 开始BV号为14T4y1g7fW视频属性的抓取
# BV号为14T4y1g7fW的视频属性抓取结束
# 开始BV号为1cV411C7iq视频属性的抓取
# BV号为1cV411C7iq的视频属性抓取结束
# 开始BV号为1MK411W7gL视频属性的抓取
# BV号为1MK411W7gL的视频属性抓取结束
# 开始BV号为13K4y1t7qY视频属性的抓取
# BV号为13K4y1t7qY的视频属性抓取结束
# 开始BV号为1EQ4y1P7cb视频属性的抓取
# BV号为1EQ4y1P7cb的视频属性抓取结束
# 开始BV号为11i4y1s74o视频属性的抓取
# BV号为11i4y1s74o的视频属性抓取结束
# 开始BV号为1St4y1C73y视频属性的抓取
# BV号为1St4y1C73y的视频属性抓取结束
# 开始BV号为1Aa4y1v7KN视频属性的抓取
# BV号为1Aa4y1v7KN的视频属性抓取结束
# 开始BV号为1Bt4y117Ye视频属性的抓取
# BV号为1Bt4y117Ye的视频属性抓取结束
# 开始BV号为1pf4y1m7ky视频属性的抓取
# BV号为1pf4y1m7ky的视频属性抓取结束
# 开始BV号为1Wa4y1v7qB视频属性的抓取
# BV号为1Wa4y1v7qB的视频属性抓取结束
# 开始BV号为1mK4y1x7Mb视频属性的抓取
# BV号为1mK4y1x7Mb的视频属性抓取结束
# 开始BV号为1Vi4y1x7bk视频属性的抓取
# BV号为1Vi4y1x7bk的视频属性抓取结束
# 开始BV号为1zf4y1y77u视频属性的抓取
# 开始BV号为1zf4y1y77u视频属性的抓取
# 开始BV号为1zf4y1y77u视频属性的抓取
# BV号为1zf4y1y77u的视频属性抓取结束
# 开始BV号为1T5411Y7n3视频属性的抓取
# BV号为1T5411Y7n3的视频属性抓取结束
# 开始BV号为1dD4y1D7BV视频属性的抓取
# BV号为1dD4y1D7BV的视频属性抓取结束
# 开始BV号为1kz4y1Q7Dy视频属性的抓取
# BV号为1kz4y1Q7Dy的视频属性抓取结束
# 开始BV号为1pk4y1r7E5视频属性的抓取
# BV号为1pk4y1r7E5的视频属性抓取结束
# 开始BV号为11D4y1D7Kx视频属性的抓取
# BV号为11D4y1D7Kx的视频属性抓取结束
# 开始BV号为12p4y1U7Xe视频属性的抓取
# BV号为12p4y1U7Xe的视频属性抓取结束
# 开始BV号为1Dt4y197dr视频属性的抓取
# BV号为1Dt4y197dr的视频属性抓取结束
# 开始BV号为1Pz411i7y4视频属性的抓取
# BV号为1Pz411i7y4的视频属性抓取结束
# 开始BV号为1dV411r7gL视频属性的抓取
# BV号为1dV411r7gL的视频属性抓取结束
# 开始BV号为1f5411p7HZ视频属性的抓取
# BV号为1f5411p7HZ的视频属性抓取结束
# 开始BV号为1EK411p7eY视频属性的抓取
# BV号为1EK411p7eY的视频属性抓取结束
# 开始BV号为1J54y1Q7Lo视频属性的抓取
# BV号为1J54y1Q7Lo的视频属性抓取结束
# 开始BV号为1Av411z7Hr视频属性的抓取
# BV号为1Av411z7Hr的视频属性抓取结束
# 开始BV号为1bv41167v7视频属性的抓取
# BV号为1bv41167v7的视频属性抓取结束
# 开始BV号为1xz4y1X7gN视频属性的抓取
# BV号为1xz4y1X7gN的视频属性抓取结束
# 开始BV号为1XD4y1D7wa视频属性的抓取
# BV号为1XD4y1D7wa的视频属性抓取结束
# 开始BV号为1a5411W7Zp视频属性的抓取
# BV号为1a5411W7Zp的视频属性抓取结束
# 开始BV号为1nA411e7co视频属性的抓取
# BV号为1nA411e7co的视频属性抓取结束
# 开始BV号为12g4y1i7nQ视频属性的抓取
# BV号为12g4y1i7nQ的视频属性抓取结束
# 开始BV号为1P5411W7wX视频属性的抓取
# BV号为1P5411W7wX的视频属性抓取结束
# 开始BV号为1ya4y1Y7jD视频属性的抓取
# BV号为1ya4y1Y7jD的视频属性抓取结束
# 开始BV号为1kk4y1z7gH视频属性的抓取
# BV号为1kk4y1z7gH的视频属性抓取结束
# 开始BV号为1cf4y117sw视频属性的抓取
# BV号为1cf4y117sw的视频属性抓取结束
# 开始BV号为1e54y1Q7ZS视频属性的抓取
# BV号为1e54y1Q7ZS的视频属性抓取结束
# 开始BV号为1NK4y147Lp视频属性的抓取
# BV号为1NK4y147Lp的视频属性抓取结束
# 开始BV号为13f4y1m7b1视频属性的抓取
# BV号为13f4y1m7b1的视频属性抓取结束
# 开始BV号为1Mf4y117Nz视频属性的抓取
# BV号为1Mf4y117Nz的视频属性抓取结束
# 开始BV号为1Zi4y1s7ni视频属性的抓取
# BV号为1Zi4y1s7ni的视频属性抓取结束
# 开始BV号为17t4y197Bu视频属性的抓取
# BV号为17t4y197Bu的视频属性抓取结束
# 开始BV号为1Bz4y1Q7CC视频属性的抓取
# 开始BV号为1Bz4y1Q7CC视频属性的抓取
# BV号为1Bz4y1Q7CC的视频属性抓取结束
# 开始BV号为1Zt4y1X7BV视频属性的抓取
# BV号为1Zt4y1X7BV的视频属性抓取结束
# 开始BV号为1Wz411i7Fx视频属性的抓取
# BV号为1Wz411i7Fx的视频属性抓取结束
# 开始BV号为1NK4y1b7Vw视频属性的抓取
# BV号为1NK4y1b7Vw的视频属性抓取结束
# 开始BV号为1Eg4y1q7Kq视频属性的抓取
# BV号为1Eg4y1q7Kq的视频属性抓取结束
# 开始BV号为1KK411p7DZ视频属性的抓取
# BV号为1KK411p7DZ的视频属性抓取结束
# 开始BV号为1cV41167md视频属性的抓取
# BV号为1cV41167md的视频属性抓取结束
# 开始BV号为13g4y1v7VP视频属性的抓取
# BV号为13g4y1v7VP的视频属性抓取结束
# 开始BV号为1Zz4y1Q71y视频属性的抓取
# BV号为1Zz4y1Q71y的视频属性抓取结束
# 开始BV号为18D4y1D7Le视频属性的抓取
# BV号为18D4y1D7Le的视频属性抓取结束
# 开始BV号为1ut4y197cx视频属性的抓取
# BV号为1ut4y197cx的视频属性抓取结束
# 开始BV号为1H54y1B7N9视频属性的抓取
# BV号为1H54y1B7N9的视频属性抓取结束
# 开始BV号为1u54y1B7B9视频属性的抓取
# BV号为1u54y1B7B9的视频属性抓取结束
# 开始BV号为1AV411k7Vu视频属性的抓取
# BV号为1AV411k7Vu的视频属性抓取结束
# 开始BV号为1zk4y1z7aS视频属性的抓取
# BV号为1zk4y1z7aS的视频属性抓取结束
# 开始BV号为14i4y1x7y5视频属性的抓取
# BV号为14i4y1x7y5的视频属性抓取结束
# 开始BV号为1qp4y1U7Vi视频属性的抓取
# BV号为1qp4y1U7Vi的视频属性抓取结束
# 开始BV号为1bV411k7ED视频属性的抓取
# BV号为1bV411k7ED的视频属性抓取结束
# 开始BV号为1HC4y1a72b视频属性的抓取
# BV号为1HC4y1a72b的视频属性抓取结束
# 开始BV号为1LA411i7ds视频属性的抓取
# 开始BV号为1LA411i7ds视频属性的抓取
# BV号为1LA411i7ds的视频属性抓取结束
# 开始BV号为1bg4y1q76R视频属性的抓取
# BV号为1bg4y1q76R的视频属性抓取结束
# 开始BV号为145411W73i视频属性的抓取
# BV号为145411W73i的视频属性抓取结束
# 开始BV号为1Xg4y1i7QS视频属性的抓取
# BV号为1Xg4y1i7QS的视频属性抓取结束
# 开始BV号为1mK4y1x7xg视频属性的抓取
# BV号为1mK4y1x7xg的视频属性抓取结束
# 开始BV号为1Da4y1Y7x4视频属性的抓取
# BV号为1Da4y1Y7x4的视频属性抓取结束
# 开始BV号为12i4y1G7zG视频属性的抓取
# BV号为12i4y1G7zG的视频属性抓取结束
# 开始BV号为1nv411B7aN视频属性的抓取
# BV号为1nv411B7aN的视频属性抓取结束
# 开始BV号为1NQ4y1P7vs视频属性的抓取
# BV号为1NQ4y1P7vs的视频属性抓取结束
# 开始BV号为1rg4y1v7xR视频属性的抓取
# BV号为1rg4y1v7xR的视频属性抓取结束
# 开始BV号为13a4y1e75v视频属性的抓取
# 开始BV号为13a4y1e75v视频属性的抓取
# 开始BV号为13a4y1e75v视频属性的抓取
# BV号为13a4y1e75v的视频属性抓取结束
# 开始BV号为1iK411n7ZQ视频属性的抓取
# BV号为1iK411n7ZQ的视频属性抓取结束
# 开始BV号为1Lz411i7pD视频属性的抓取
# BV号为1Lz411i7pD的视频属性抓取结束
# 开始BV号为1G5411W7o8视频属性的抓取
# BV号为1G5411W7o8的视频属性抓取结束
# 开始BV号为1Yz4y197Tb视频属性的抓取
# BV号为1Yz4y197Tb的视频属性抓取结束
# 开始BV号为1et4y1y7VH视频属性的抓取
# BV号为1et4y1y7VH的视频属性抓取结束
# 开始BV号为1zi4y1x767视频属性的抓取
# BV号为1zi4y1x767的视频属性抓取结束
# 开始BV号为1wZ4y1p77q视频属性的抓取
# BV号为1wZ4y1p77q的视频属性抓取结束
# 开始BV号为1kD4y1D7Cq视频属性的抓取
# BV号为1kD4y1D7Cq的视频属性抓取结束
# 开始BV号为1Hv411B7Gt视频属性的抓取
# BV号为1Hv411B7Gt的视频属性抓取结束
# 开始BV号为1DT4y1E7VD视频属性的抓取
# BV号为1DT4y1E7VD的视频属性抓取结束
# 开始BV号为12K411p73G视频属性的抓取
# BV号为12K411p73G的视频属性抓取结束
# 开始BV号为1Ri4y1s7JW视频属性的抓取
# BV号为1Ri4y1s7JW的视频属性抓取结束
# 开始BV号为1JA411e7r1视频属性的抓取
# 开始BV号为1JA411e7r1视频属性的抓取
# 开始BV号为1JA411e7r1视频属性的抓取
# 开始BV号为1JA411e7r1视频属性的抓取
# BV号为1JA411e7r1的视频属性抓取结束
# 开始BV号为1Ff4y1m7A1视频属性的抓取
# BV号为1Ff4y1m7A1的视频属性抓取结束
# 开始BV号为1cz411v7VU视频属性的抓取
# BV号为1cz411v7VU的视频属性抓取结束
# 开始BV号为1cC4y1Y7JD视频属性的抓取
# BV号为1cC4y1Y7JD的视频属性抓取结束
# 开始BV号为1A5411W73r视频属性的抓取
# BV号为1A5411W73r的视频属性抓取结束
# 开始BV号为1ST4y1J7c4视频属性的抓取
# BV号为1ST4y1J7c4的视频属性抓取结束
# 开始BV号为1HZ4y1H7F9视频属性的抓取
# BV号为1HZ4y1H7F9的视频属性抓取结束
# 开始BV号为1xv41167Lh视频属性的抓取
# BV号为1xv41167Lh的视频属性抓取结束
# 开始BV号为1bZ4y1H745视频属性的抓取
# BV号为1bZ4y1H745的视频属性抓取结束
# 开始BV号为1gv411B7Jh视频属性的抓取
# BV号为1gv411B7Jh的视频属性抓取结束
# 开始BV号为1XK4y1x7JY视频属性的抓取
# BV号为1XK4y1x7JY的视频属性抓取结束
# 开始BV号为1fv411q7jn视频属性的抓取
# BV号为1fv411q7jn的视频属性抓取结束
# 开始BV号为1MZ4y1p7k4视频属性的抓取
# BV号为1MZ4y1p7k4的视频属性抓取结束
# 开始BV号为1of4y127YE视频属性的抓取
# BV号为1of4y127YE的视频属性抓取结束
# 开始BV号为1CD4y1D7oi视频属性的抓取
# BV号为1CD4y1D7oi的视频属性抓取结束
# 开始BV号为18t4y1y7nn视频属性的抓取
# BV号为18t4y1y7nn的视频属性抓取结束
# 开始BV号为1mK4y1x7ZP视频属性的抓取
# BV号为1mK4y1x7ZP的视频属性抓取结束
# 开始BV号为1kK4y1x71M视频属性的抓取
# BV号为1kK4y1x71M的视频属性抓取结束
# 开始BV号为1rA411i7sR视频属性的抓取
# BV号为1rA411i7sR的视频属性抓取结束
# 开始BV号为17C4y1a7TV视频属性的抓取
# BV号为17C4y1a7TV的视频属性抓取结束
# 开始BV号为1ak4y1q7yu视频属性的抓取
# BV号为1ak4y1q7yu的视频属性抓取结束
# 开始BV号为1Pf4y117SD视频属性的抓取
# BV号为1Pf4y117SD的视频属性抓取结束
# 开始BV号为1Rf4y1y7t6视频属性的抓取
# BV号为1Rf4y1y7t6的视频属性抓取结束
# 开始BV号为1854y1q7Le视频属性的抓取
# BV号为1854y1q7Le的视频属性抓取结束
# 开始BV号为15v411z7xD视频属性的抓取
# BV号为15v411z7xD的视频属性抓取结束
# 开始BV号为1Vh411Z7j5视频属性的抓取
# BV号为1Vh411Z7j5的视频属性抓取结束
# 开始BV号为1f54y1U7nL视频属性的抓取
# BV号为1f54y1U7nL的视频属性抓取结束
# 开始BV号为1PZ4y1g7z1视频属性的抓取
# BV号为1PZ4y1g7z1的视频属性抓取结束
# 开始BV号为1op4y1U7Gs视频属性的抓取
# 开始BV号为1op4y1U7Gs视频属性的抓取
# BV号为1op4y1U7Gs的视频属性抓取结束
# 开始BV号为1Ca4y1h7fW视频属性的抓取
# BV号为1Ca4y1h7fW的视频属性抓取结束
# 开始BV号为1gT4y1j7H1视频属性的抓取
# BV号为1gT4y1j7H1的视频属性抓取结束
# 开始BV号为1xk4y1B7yg视频属性的抓取
# BV号为1xk4y1B7yg的视频属性抓取结束
# 开始BV号为13Z4y1u7Uk视频属性的抓取
# BV号为13Z4y1u7Uk的视频属性抓取结束
# 开始BV号为1Xa4y1Y7uQ视频属性的抓取
# BV号为1Xa4y1Y7uQ的视频属性抓取结束
# 开始BV号为1ez4y1X7gf视频属性的抓取
# BV号为1ez4y1X7gf的视频属性抓取结束
# 开始BV号为1of4y1X7Qt视频属性的抓取
# 开始BV号为1of4y1X7Qt视频属性的抓取
# 开始BV号为1of4y1X7Qt视频属性的抓取
# 开始BV号为1of4y1X7Qt视频属性的抓取
# BV号为1of4y1X7Qt的视频属性抓取结束
# 开始BV号为1ZT4y177cw视频属性的抓取
# 开始BV号为1ZT4y177cw视频属性的抓取
# BV号为1ZT4y177cw的视频属性抓取结束
# 开始BV号为15k4y1B78q视频属性的抓取
# BV号为15k4y1B78q的视频属性抓取结束
# 开始BV号为1Sk4y127Qi视频属性的抓取
# BV号为1Sk4y127Qi的视频属性抓取结束
# 开始BV号为17D4y1S7HT视频属性的抓取
# 开始BV号为17D4y1S7HT视频属性的抓取
# BV号为17D4y1S7HT的视频属性抓取结束
# 开始BV号为16K4y1s7YQ视频属性的抓取
# BV号为16K4y1s7YQ的视频属性抓取结束
# 开始BV号为1AZ4y1g7s2视频属性的抓取
# BV号为1AZ4y1g7s2的视频属性抓取结束
# 开始BV号为1b54y1S7dy视频属性的抓取
# 开始BV号为1b54y1S7dy视频属性的抓取
# BV号为1b54y1S7dy的视频属性抓取结束
# 开始BV号为1bz411v7Ty视频属性的抓取
# BV号为1bz411v7Ty的视频属性抓取结束
# 开始BV号为1sT4y1E77T视频属性的抓取
# BV号为1sT4y1E77T的视频属性抓取结束
# 开始BV号为1hD4y1S7ew视频属性的抓取
# BV号为1hD4y1S7ew的视频属性抓取结束
# 开始BV号为1nt4y1X7sS视频属性的抓取
# BV号为1nt4y1X7sS的视频属性抓取结束
# 开始BV号为1VV411r7NF视频属性的抓取
# BV号为1VV411r7NF的视频属性抓取结束
# 开始BV号为1CT4y177ok视频属性的抓取
# BV号为1CT4y177ok的视频属性抓取结束
# 开始BV号为1v5411Y7gW视频属性的抓取
# BV号为1v5411Y7gW的视频属性抓取结束
# 开始BV号为1hz411v7sd视频属性的抓取
# BV号为1hz411v7sd的视频属性抓取结束
# 开始BV号为1sk4y1q7Y1视频属性的抓取
# BV号为1sk4y1q7Y1的视频属性抓取结束
# 开始BV号为1tz4y1Q7Kg视频属性的抓取
# BV号为1tz4y1Q7Kg的视频属性抓取结束
# 开始BV号为1zi4y137jb视频属性的抓取
# BV号为1zi4y137jb的视频属性抓取结束
# 开始BV号为1sV411k749视频属性的抓取
# BV号为1sV411k749的视频属性抓取结束
# 开始BV号为1Hp4y1S7Bm视频属性的抓取
# BV号为1Hp4y1S7Bm的视频属性抓取结束
# 开始BV号为1Wz4y1D7Kw视频属性的抓取
# BV号为1Wz4y1D7Kw的视频属性抓取结束
# 开始BV号为16a4y1h7EW视频属性的抓取
# BV号为16a4y1h7EW的视频属性抓取结束
# 开始BV号为1iz4y1X7Fo视频属性的抓取
# BV号为1iz4y1X7Fo的视频属性抓取结束
# 开始BV号为1rp4y1S7Vv视频属性的抓取
# BV号为1rp4y1S7Vv的视频属性抓取结束
# 开始BV号为1Mk4y1B7GJ视频属性的抓取
# 开始BV号为1Mk4y1B7GJ视频属性的抓取
# BV号为1Mk4y1B7GJ的视频属性抓取结束
# 开始BV号为1PZ4y1p7Dc视频属性的抓取
# BV号为1PZ4y1p7Dc的视频属性抓取结束
# 开始BV号为14t4y1X7v2视频属性的抓取
# BV号为14t4y1X7v2的视频属性抓取结束
# 开始BV号为1Bz4y1D7dT视频属性的抓取
# BV号为1Bz4y1D7dT的视频属性抓取结束
# 开始BV号为1hZ4y1T7iT视频属性的抓取
# BV号为1hZ4y1T7iT的视频属性抓取结束
# 开始BV号为18f4y1R7fF视频属性的抓取
# BV号为18f4y1R7fF的视频属性抓取结束
# 开始BV号为1DK411J7yR视频属性的抓取
# BV号为1DK411J7yR的视频属性抓取结束
# 开始BV号为1Aa4y1a7NH视频属性的抓取
# BV号为1Aa4y1a7NH的视频属性抓取结束
# 开始BV号为1ha4y1a7Kq视频属性的抓取
# BV号为1ha4y1a7Kq的视频属性抓取结束
# 开始BV号为1Hp4y1S7TH视频属性的抓取
# BV号为1Hp4y1S7TH的视频属性抓取结束
# 开始BV号为1bD4y1S7kx视频属性的抓取
# BV号为1bD4y1S7kx的视频属性抓取结束
# 开始BV号为1jK411J7Xx视频属性的抓取
# BV号为1jK411J7Xx的视频属性抓取结束
# 开始BV号为14A411v779视频属性的抓取
# BV号为14A411v779的视频属性抓取结束
# 开始BV号为1Da4y1a7su视频属性的抓取
# BV号为1Da4y1a7su的视频属性抓取结束
# 开始BV号为1CC4y1h721视频属性的抓取
# BV号为1CC4y1h721的视频属性抓取结束
# 开始BV号为1rk4y1q7ax视频属性的抓取
# BV号为1rk4y1q7ax的视频属性抓取结束
# 开始BV号为1fa4y1E7wp视频属性的抓取
# BV号为1fa4y1E7wp的视频属性抓取结束
# 开始BV号为1qh411Z7xX视频属性的抓取
# BV号为1qh411Z7xX的视频属性抓取结束
# 开始BV号为1Wt4y1Q72X视频属性的抓取
# BV号为1Wt4y1Q72X的视频属性抓取结束
# 开始BV号为1ua4y1a7tm视频属性的抓取
# BV号为1ua4y1a7tm的视频属性抓取结束
# 开始BV号为1Rv411B7Rd视频属性的抓取
# BV号为1Rv411B7Rd的视频属性抓取结束
# 开始BV号为1pz411v775视频属性的抓取
# BV号为1pz411v775的视频属性抓取结束
# 开始BV号为1ZC4y1b7ek视频属性的抓取
# BV号为1ZC4y1b7ek的视频属性抓取结束
# 开始BV号为1wf4y1d7iG视频属性的抓取
# BV号为1wf4y1d7iG的视频属性抓取结束
# 开始BV号为1U5411Y7eL视频属性的抓取
# BV号为1U5411Y7eL的视频属性抓取结束
# 开始BV号为13a4y1a7PP视频属性的抓取
# BV号为13a4y1a7PP的视频属性抓取结束
# 开始BV号为1Mv411z7AY视频属性的抓取
# BV号为1Mv411z7AY的视频属性抓取结束
# 开始BV号为1ja4y1J7zx视频属性的抓取
# BV号为1ja4y1J7zx的视频属性抓取结束
# 开始BV号为1A5411Y7W9视频属性的抓取
# BV号为1A5411Y7W9的视频属性抓取结束
# 开始BV号为1ca4y1e7PL视频属性的抓取
# BV号为1ca4y1e7PL的视频属性抓取结束
# 开始BV号为1YV41167eF视频属性的抓取
# BV号为1YV41167eF的视频属性抓取结束
# 开始BV号为11z411e7tH视频属性的抓取
# BV号为11z411e7tH的视频属性抓取结束
# 开始BV号为1Yk4y1B7pm视频属性的抓取
# BV号为1Yk4y1B7pm的视频属性抓取结束
# 开始BV号为15g4y1i7HM视频属性的抓取
# BV号为15g4y1i7HM的视频属性抓取结束
# 开始BV号为1rD4y1S71t视频属性的抓取
# BV号为1rD4y1S71t的视频属性抓取结束
# 开始BV号为1BT4y177gB视频属性的抓取
# BV号为1BT4y177gB的视频属性抓取结束
# 开始BV号为1Rv411i7wc视频属性的抓取
# BV号为1Rv411i7wc的视频属性抓取结束
# 开始BV号为1JD4y1U7Ag视频属性的抓取
# BV号为1JD4y1U7Ag的视频属性抓取结束
# 开始BV号为14p4y1U7uM视频属性的抓取
# BV号为14p4y1U7uM的视频属性抓取结束
# 开始BV号为1yV41167Wq视频属性的抓取
# BV号为1yV41167Wq的视频属性抓取结束
# 开始BV号为13K411J7Qz视频属性的抓取
# BV号为13K411J7Qz的视频属性抓取结束
# 开始BV号为1Yi4y137nL视频属性的抓取
# BV号为1Yi4y137nL的视频属性抓取结束
# 开始BV号为1Xa4y1E7TQ视频属性的抓取
# BV号为1Xa4y1E7TQ的视频属性抓取结束
# 开始BV号为1XK4y147eC视频属性的抓取
# BV号为1XK4y147eC的视频属性抓取结束
# 开始BV号为1Vp4y1S7sp视频属性的抓取
# BV号为1Vp4y1S7sp的视频属性抓取结束
# 开始BV号为1pp4y1i7r6视频属性的抓取
# BV号为1pp4y1i7r6的视频属性抓取结束
# 开始BV号为1ya4y1E7DR视频属性的抓取
# BV号为1ya4y1E7DR的视频属性抓取结束
# 开始BV号为1dk4y127R2视频属性的抓取
# BV号为1dk4y127R2的视频属性抓取结束
# 开始BV号为1hC4y1b7uF视频属性的抓取
# BV号为1hC4y1b7uF的视频属性抓取结束
# 开始BV号为1ov411B7Hx视频属性的抓取
# BV号为1ov411B7Hx的视频属性抓取结束
# 开始BV号为1sK4y1v7qu视频属性的抓取
# BV号为1sK4y1v7qu的视频属性抓取结束
# 开始BV号为1Th411Z7u3视频属性的抓取
# BV号为1Th411Z7u3的视频属性抓取结束
# 开始BV号为15a4y1a7j3视频属性的抓取
# BV号为15a4y1a7j3的视频属性抓取结束
# 开始BV号为1e5411a7Fb视频属性的抓取
# BV号为1e5411a7Fb的视频属性抓取结束
# 开始BV号为1ep4y1i77c视频属性的抓取
# 开始BV号为1ep4y1i77c视频属性的抓取
# BV号为1ep4y1i77c的视频属性抓取结束
# 开始BV号为1fZ4y1u7Qy视频属性的抓取
# BV号为1fZ4y1u7Qy的视频属性抓取结束
# 开始BV号为1Ng4y1v7LH视频属性的抓取
# BV号为1Ng4y1v7LH的视频属性抓取结束
# 开始BV号为1bz411v7o3视频属性的抓取
# BV号为1bz411v7o3的视频属性抓取结束
# 开始BV号为1RK4y1e7gx视频属性的抓取
# BV号为1RK4y1e7gx的视频属性抓取结束
# 开始BV号为1SD4y1m7JQ视频属性的抓取
# BV号为1SD4y1m7JQ的视频属性抓取结束
# 开始BV号为1T5411Y7FE视频属性的抓取
# BV号为1T5411Y7FE的视频属性抓取结束
# 开始BV号为1554y1D7YQ视频属性的抓取
# 开始BV号为1554y1D7YQ视频属性的抓取
# BV号为1554y1D7YQ的视频属性抓取结束
# 开始BV号为1ZK4y1s74f视频属性的抓取
# BV号为1ZK4y1s74f的视频属性抓取结束
# 开始BV号为1q5411h7sS视频属性的抓取
# BV号为1q5411h7sS的视频属性抓取结束
# 开始BV号为1hV411U71U视频属性的抓取
# BV号为1hV411U71U的视频属性抓取结束
# 开始BV号为1Wz4y1f7LY视频属性的抓取
# BV号为1Wz4y1f7LY的视频属性抓取结束
# 开始BV号为1f54y1m7zQ视频属性的抓取
# BV号为1f54y1m7zQ的视频属性抓取结束
# 开始BV号为1CC4y1t7m6视频属性的抓取
# 开始BV号为1CC4y1t7m6视频属性的抓取
# 开始BV号为1CC4y1t7m6视频属性的抓取
# BV号为1CC4y1t7m6的视频属性抓取结束
# 开始BV号为1Ch411975R视频属性的抓取
# BV号为1Ch411975R的视频属性抓取结束
# 开始BV号为1AD4y1U7Ff视频属性的抓取
# 开始BV号为1AD4y1U7Ff视频属性的抓取
# BV号为1AD4y1U7Ff的视频属性抓取结束
# 开始BV号为1DV411z7mb视频属性的抓取
# BV号为1DV411z7mb的视频属性抓取结束
# 开始BV号为19C4y1t7YU视频属性的抓取
# 开始BV号为19C4y1t7YU视频属性的抓取
# BV号为19C4y1t7YU的视频属性抓取结束
# 开始BV号为1m54y1m7Sy视频属性的抓取
# BV号为1m54y1m7Sy的视频属性抓取结束
# 开始BV号为1SK4y1v7Yd视频属性的抓取
# BV号为1SK4y1v7Yd的视频属性抓取结束
# 开始BV号为1Q541187wv视频属性的抓取
# BV号为1Q541187wv的视频属性抓取结束
# 开始BV号为1GA411n77i视频属性的抓取
# BV号为1GA411n77i的视频属性抓取结束
# 开始BV号为1PC4y1b7i4视频属性的抓取
# BV号为1PC4y1b7i4的视频属性抓取结束
# 开始BV号为1FZ4y1T7Ks视频属性的抓取
# BV号为1FZ4y1T7Ks的视频属性抓取结束
# 开始BV号为1qA411n7zb视频属性的抓取
# BV号为1qA411n7zb的视频属性抓取结束
# 开始BV号为16f4y1Q7L6视频属性的抓取
# BV号为16f4y1Q7L6的视频属性抓取结束
# 开始BV号为18a4y177Ni视频属性的抓取
# BV号为18a4y177Ni的视频属性抓取结束
# 开始BV号为1EZ4y1M7MX视频属性的抓取
# BV号为1EZ4y1M7MX的视频属性抓取结束
# 开始BV号为1Uk4y117qk视频属性的抓取
# 开始BV号为1Uk4y117qk视频属性的抓取
# BV号为1Uk4y117qk的视频属性抓取结束
# 开始BV号为1na4y1J7sJ视频属性的抓取
# BV号为1na4y1J7sJ的视频属性抓取结束
# 开始BV号为1WD4y127Sk视频属性的抓取
# BV号为1WD4y127Sk的视频属性抓取结束
# 开始BV号为1wk4y1U73V视频属性的抓取
# BV号为1wk4y1U73V的视频属性抓取结束
# 开始BV号为1Pv41117Wq视频属性的抓取
# BV号为1Pv41117Wq的视频属性抓取结束
# 开始BV号为1eA411Y7FZ视频属性的抓取
# BV号为1eA411Y7FZ的视频属性抓取结束
# 开始BV号为17A411Y71t视频属性的抓取
# BV号为17A411Y71t的视频属性抓取结束
# 开始BV号为1kD4y1U7H6视频属性的抓取
# BV号为1kD4y1U7H6的视频属性抓取结束
# 开始BV号为1YA411n74e视频属性的抓取
# BV号为1YA411n74e的视频属性抓取结束
# 开始BV号为1Qh411d7ec视频属性的抓取
# BV号为1Qh411d7ec的视频属性抓取结束
# 开始BV号为19K4y1Y7aS视频属性的抓取
# BV号为19K4y1Y7aS的视频属性抓取结束
# 开始BV号为1xt4y1D7VU视频属性的抓取
# BV号为1xt4y1D7VU的视频属性抓取结束
# 开始BV号为1Tp4y1i7Me视频属性的抓取
# BV号为1Tp4y1i7Me的视频属性抓取结束
# 开始BV号为1Fk4y1U7eV视频属性的抓取
# BV号为1Fk4y1U7eV的视频属性抓取结束
# 开始BV号为1Xk4y1m7yP视频属性的抓取
# BV号为1Xk4y1m7yP的视频属性抓取结束
# 开始BV号为1Nt4y1Q7TB视频属性的抓取
# BV号为1Nt4y1Q7TB的视频属性抓取结束
# 开始BV号为1Av411176W视频属性的抓取
# BV号为1Av411176W的视频属性抓取结束
# 开始BV号为16K4y1Y7qq视频属性的抓取
# BV号为16K4y1Y7qq的视频属性抓取结束
# 开始BV号为1Mp4y1i7ud视频属性的抓取
# BV号为1Mp4y1i7ud的视频属性抓取结束
# 开始BV号为1qT4y1L75J视频属性的抓取
# BV号为1qT4y1L75J的视频属性抓取结束
# 开始BV号为1it4y1D7aw视频属性的抓取
# BV号为1it4y1D7aw的视频属性抓取结束
# 开始BV号为1Uh411d7JC视频属性的抓取
# BV号为1Uh411d7JC的视频属性抓取结束
# 开始BV号为1kC4y1t7Yu视频属性的抓取
# BV号为1kC4y1t7Yu的视频属性抓取结束
# 开始BV号为1ki4y1g7Q9视频属性的抓取
# BV号为1ki4y1g7Q9的视频属性抓取结束
# 开始BV号为1nK4y1e7PA视频属性的抓取
# BV号为1nK4y1e7PA的视频属性抓取结束
# 开始BV号为1nz4y1f7k4视频属性的抓取
# BV号为1nz4y1f7k4的视频属性抓取结束
# 开始BV号为16h411d7Zm视频属性的抓取
# BV号为16h411d7Zm的视频属性抓取结束
# 开始BV号为1B54y1e7kk视频属性的抓取
# BV号为1B54y1e7kk的视频属性抓取结束
# 开始BV号为1Ez4y1f7oB视频属性的抓取
# BV号为1Ez4y1f7oB的视频属性抓取结束
# 开始BV号为1b5411a7b8视频属性的抓取
# BV号为1b5411a7b8的视频属性抓取结束
# 开始BV号为1Xv411v7mT视频属性的抓取
# BV号为1Xv411v7mT的视频属性抓取结束
# 开始BV号为1FA411n7ju视频属性的抓取
# BV号为1FA411n7ju的视频属性抓取结束
# 开始BV号为1ep4y1v7T9视频属性的抓取
# BV号为1ep4y1v7T9的视频属性抓取结束
# 开始BV号为1Ph411R78M视频属性的抓取
# BV号为1Ph411R78M的视频属性抓取结束
# 开始BV号为1wk4y127XB视频属性的抓取
# BV号为1wk4y127XB的视频属性抓取结束
# 开始BV号为1Bv41117VF视频属性的抓取
# BV号为1Bv41117VF的视频属性抓取结束
# 开始BV号为1Aa4y1J7DX视频属性的抓取
# BV号为1Aa4y1J7DX的视频属性抓取结束
# 开始BV号为1aa4y177DD视频属性的抓取
# BV号为1aa4y177DD的视频属性抓取结束
# 开始BV号为1RK4y1Y7u9视频属性的抓取
# BV号为1RK4y1Y7u9的视频属性抓取结束
# 开始BV号为145411b7kN视频属性的抓取
# BV号为145411b7kN的视频属性抓取结束
# 开始BV号为1WD4y1273T视频属性的抓取
# BV号为1WD4y1273T的视频属性抓取结束
# 开始BV号为1H5411h7kn视频属性的抓取
# BV号为1H5411h7kn的视频属性抓取结束
# 开始BV号为1aV411U7G1视频属性的抓取
# BV号为1aV411U7G1的视频属性抓取结束
# 开始BV号为19i4y1g7PH视频属性的抓取
# BV号为19i4y1g7PH的视频属性抓取结束
# 开始BV号为1Yt4y1S7bd视频属性的抓取
# BV号为1Yt4y1S7bd的视频属性抓取结束
# 开始BV号为1A5411h7gw视频属性的抓取
# BV号为1A5411h7gw的视频属性抓取结束
# 开始BV号为1pp4y1v7Ba视频属性的抓取
# BV号为1pp4y1v7Ba的视频属性抓取结束
# 开始BV号为1YV411U7LW视频属性的抓取
# BV号为1YV411U7LW的视频属性抓取结束
# 开始BV号为1fA411J79b视频属性的抓取
# BV号为1fA411J79b的视频属性抓取结束
# 开始BV号为1854y1U7rc视频属性的抓取
# 开始BV号为1854y1U7rc视频属性的抓取
# BV号为1854y1U7rc的视频属性抓取结束
# 开始BV号为1mi4y1g7Gr视频属性的抓取
# BV号为1mi4y1g7Gr的视频属性抓取结束
# 开始BV号为1LC4y1t7cp视频属性的抓取
# BV号为1LC4y1t7cp的视频属性抓取结束
# 开始BV号为1zZ4y1K7JD视频属性的抓取
# 开始BV号为1zZ4y1K7JD视频属性的抓取
# 开始BV号为1zZ4y1K7JD视频属性的抓取
# 开始BV号为1zZ4y1K7JD视频属性的抓取
# BV号为1zZ4y1K7JD的视频属性抓取结束
# 开始BV号为1ev41117V4视频属性的抓取
# 开始BV号为1ev41117V4视频属性的抓取
# BV号为1ev41117V4的视频属性抓取结束
# 开始BV号为1UA411J7b5视频属性的抓取
# BV号为1UA411J7b5的视频属性抓取结束
# 开始BV号为1pK4y1e7Lb视频属性的抓取
# BV号为1pK4y1e7Lb的视频属性抓取结束
# 开始BV号为1Gt4y1Q7vn视频属性的抓取
# BV号为1Gt4y1Q7vn的视频属性抓取结束
# 开始BV号为1AK4y1e7vH视频属性的抓取
# BV号为1AK4y1e7vH的视频属性抓取结束
# 开始BV号为1TD4y1m7tL视频属性的抓取
# BV号为1TD4y1m7tL的视频属性抓取结束
# 开始BV号为1eT4y157aF视频属性的抓取
# BV号为1eT4y157aF的视频属性抓取结束
# 开始BV号为1mf4y197ua视频属性的抓取
# BV号为1mf4y197ua的视频属性抓取结束
# 开始BV号为1Qv411v7ex视频属性的抓取
# BV号为1Qv411v7ex的视频属性抓取结束
# 开始BV号为1Gk4y1y7dL视频属性的抓取
# BV号为1Gk4y1y7dL的视频属性抓取结束
# 开始BV号为17a4y1777z视频属性的抓取
# BV号为17a4y1777z的视频属性抓取结束
# 开始BV号为17t4y1Q7wf视频属性的抓取
# BV号为17t4y1Q7wf的视频属性抓取结束
# 开始BV号为1JZ4y1M7PG视频属性的抓取
# BV号为1JZ4y1M7PG的视频属性抓取结束
# 开始BV号为1954y1e7fy视频属性的抓取
# BV号为1954y1e7fy的视频属性抓取结束
# 开始BV号为1yh411d7Sb视频属性的抓取
# BV号为1yh411d7Sb的视频属性抓取结束
# 开始BV号为1xa4y1J7cu视频属性的抓取
# BV号为1xa4y1J7cu的视频属性抓取结束
# 开始BV号为1XA411J7B5视频属性的抓取
# 开始BV号为1XA411J7B5视频属性的抓取
# BV号为1XA411J7B5的视频属性抓取结束
# 开始BV号为1ji4y1g7Fc视频属性的抓取
# BV号为1ji4y1g7Fc的视频属性抓取结束
# 开始BV号为1SA411J7C2视频属性的抓取
# BV号为1SA411J7C2的视频属性抓取结束
# 开始BV号为1U5411a7uK视频属性的抓取
# BV号为1U5411a7uK的视频属性抓取结束
# 开始BV号为1ei4y1u7VE视频属性的抓取
# 开始BV号为1ei4y1u7VE视频属性的抓取
# 开始BV号为1ei4y1u7VE视频属性的抓取
# BV号为1ei4y1u7VE的视频属性抓取结束
# 开始BV号为1p54y1e7gF视频属性的抓取
# BV号为1p54y1e7gF的视频属性抓取结束
# 开始BV号为1gA411e798视频属性的抓取
# BV号为1gA411e798的视频属性抓取结束
# 开始BV号为1z54y1e79F视频属性的抓取
# BV号为1z54y1e79F的视频属性抓取结束
# 开始BV号为1L54y1275E视频属性的抓取
# BV号为1L54y1275E的视频属性抓取结束
# 开始BV号为1Pk4y1U75X视频属性的抓取
# BV号为1Pk4y1U75X的视频属性抓取结束
# 开始BV号为1Ki4y1g7PX视频属性的抓取
# BV号为1Ki4y1g7PX的视频属性抓取结束
# 开始BV号为1m5411b7r2视频属性的抓取
# BV号为1m5411b7r2的视频属性抓取结束
# 开始BV号为1VZ4y1T78D视频属性的抓取
# BV号为1VZ4y1T78D的视频属性抓取结束
# 开始BV号为13z4y1f76a视频属性的抓取
# BV号为13z4y1f76a的视频属性抓取结束
# 开始BV号为16K411K7rh视频属性的抓取
# BV号为16K411K7rh的视频属性抓取结束
# 开始BV号为1CT4y1w7Ed视频属性的抓取
# BV号为1CT4y1w7Ed的视频属性抓取结束
# 开始BV号为1eZ4y1N7fJ视频属性的抓取
# BV号为1eZ4y1N7fJ的视频属性抓取结束
# 开始BV号为1qz4y1Z7Br视频属性的抓取
# BV号为1qz4y1Z7Br的视频属性抓取结束
# 开始BV号为1BT4y1A7xp视频属性的抓取
# BV号为1BT4y1A7xp的视频属性抓取结束
# 开始BV号为1Jy4y1y7Tu视频属性的抓取
# BV号为1Jy4y1y7Tu的视频属性抓取结束
# 开始BV号为11T4y1w7fj视频属性的抓取
# 开始BV号为11T4y1w7fj视频属性的抓取
# BV号为11T4y1w7fj的视频属性抓取结束
# 开始BV号为1c54y127v5视频属性的抓取
# 开始BV号为1c54y127v5视频属性的抓取
# BV号为1c54y127v5的视频属性抓取结束
# 开始BV号为17T4y1A7eW视频属性的抓取
# BV号为17T4y1A7eW的视频属性抓取结束
# 开始BV号为1U54y1e71f视频属性的抓取
# BV号为1U54y1e71f的视频属性抓取结束
# 开始BV号为1sD4y1o7XM视频属性的抓取
# BV号为1sD4y1o7XM的视频属性抓取结束
# 开始BV号为1rv411C7Jd视频属性的抓取
# BV号为1rv411C7Jd的视频属性抓取结束
# 开始BV号为1tp4y1a7Vv视频属性的抓取
# BV号为1tp4y1a7Vv的视频属性抓取结束
# 开始BV号为1H54y1m7c5视频属性的抓取
# BV号为1H54y1m7c5的视频属性抓取结束
# 开始BV号为1hk4y127pM视频属性的抓取
# BV号为1hk4y127pM的视频属性抓取结束
# 开始BV号为1dk4y1y7J7视频属性的抓取
# BV号为1dk4y1y7J7的视频属性抓取结束
# 开始BV号为1p54y127wo视频属性的抓取
# BV号为1p54y127wo的视频属性抓取结束
# 开始BV号为18i4y1M72X视频属性的抓取
# BV号为18i4y1M72X的视频属性抓取结束
# 开始BV号为1vy4y1y7Tb视频属性的抓取
# BV号为1vy4y1y7Tb的视频属性抓取结束
# 开始BV号为1qT4y1L7eV视频属性的抓取
# BV号为1qT4y1L7eV的视频属性抓取结束
# 开始BV号为1vT4y1A7V7视频属性的抓取
# BV号为1vT4y1A7V7的视频属性抓取结束
# 开始BV号为13h411R79V视频属性的抓取
# BV号为13h411R79V的视频属性抓取结束
# 开始BV号为1xt4y1S71B视频属性的抓取
# BV号为1xt4y1S71B的视频属性抓取结束
# 开始BV号为1zK4y187sy视频属性的抓取
# BV号为1zK4y187sy的视频属性抓取结束
# 开始BV号为1Ch411R7ZG视频属性的抓取
# BV号为1Ch411R7ZG的视频属性抓取结束
# 开始BV号为19a4y177iP视频属性的抓取
# BV号为19a4y177iP的视频属性抓取结束
# 开始BV号为1wV411m7vu视频属性的抓取
# BV号为1wV411m7vu的视频属性抓取结束
# 开始BV号为1by4y1y7hx视频属性的抓取
# 开始BV号为1by4y1y7hx视频属性的抓取
# BV号为1by4y1y7hx的视频属性抓取结束
# 开始BV号为1LZ4y1N7ES视频属性的抓取
# BV号为1LZ4y1N7ES的视频属性抓取结束
# 开始BV号为1sz4y1Z7Fr视频属性的抓取
# BV号为1sz4y1Z7Fr的视频属性抓取结束
# 开始BV号为1454y1v78n视频属性的抓取
# BV号为1454y1v78n的视频属性抓取结束
# 开始BV号为1Kt4y1q7kL视频属性的抓取
# BV号为1Kt4y1q7kL的视频属性抓取结束
# 开始BV号为1UZ4y1P73n视频属性的抓取
# BV号为1UZ4y1P73n的视频属性抓取结束
# 开始BV号为1ah411R7Bw视频属性的抓取
# BV号为1ah411R7Bw的视频属性抓取结束
# 开始BV号为16a4y1j7oW视频属性的抓取
# BV号为16a4y1j7oW的视频属性抓取结束
# 开始BV号为1tt4y1q7LM视频属性的抓取
# BV号为1tt4y1q7LM的视频属性抓取结束
# 开始BV号为16y4y1C7TJ视频属性的抓取
# BV号为16y4y1C7TJ的视频属性抓取结束
# 开始BV号为1Qf4y1D7wQ视频属性的抓取
# BV号为1Qf4y1D7wQ的视频属性抓取结束
# 开始BV号为1F541187LS视频属性的抓取
# BV号为1F541187LS的视频属性抓取结束
# 开始BV号为1g541187W1视频属性的抓取
# BV号为1g541187W1的视频属性抓取结束
# 开始BV号为1zZ4y1N75Z视频属性的抓取
# BV号为1zZ4y1N75Z的视频属性抓取结束
# 开始BV号为1Qt4y1i7JB视频属性的抓取
# BV号为1Qt4y1i7JB的视频属性抓取结束
# 开始BV号为1Av411y799视频属性的抓取
# BV号为1Av411y799的视频属性抓取结束
# 开始BV号为1Lk4y11797视频属性的抓取
# BV号为1Lk4y11797的视频属性抓取结束
# 开始BV号为1Ti4y1u7v4视频属性的抓取
# BV号为1Ti4y1u7v4的视频属性抓取结束
# 开始BV号为1Eh411R7qV视频属性的抓取
# BV号为1Eh411R7qV的视频属性抓取结束
# 开始BV号为1np4y1a7TB视频属性的抓取
# BV号为1np4y1a7TB的视频属性抓取结束
# 开始BV号为1Yv41117yv视频属性的抓取
# BV号为1Yv41117yv的视频属性抓取结束
# 开始BV号为1vp4y1a7Pr视频属性的抓取
# BV号为1vp4y1a7Pr的视频属性抓取结束
# 开始BV号为14i4y1u7cw视频属性的抓取
# BV号为14i4y1u7cw的视频属性抓取结束
# 开始BV号为1kv411C7WK视频属性的抓取
# BV号为1kv411C7WK的视频属性抓取结束
# 开始BV号为13541187N1视频属性的抓取
# BV号为13541187N1的视频属性抓取结束
# 开始BV号为1Sh411X7KU视频属性的抓取
# BV号为1Sh411X7KU的视频属性抓取结束
# 开始BV号为16V411m7Mw视频属性的抓取
# BV号为16V411m7Mw的视频属性抓取结束
# 开始BV号为1iy4y1k7Qd视频属性的抓取
# BV号为1iy4y1k7Qd的视频属性抓取结束
# 开始BV号为1hA411E7ri视频属性的抓取
# BV号为1hA411E7ri的视频属性抓取结束
# 开始BV号为1Ki4y1u7Pr视频属性的抓取
# BV号为1Ki4y1u7Pr的视频属性抓取结束
# 开始BV号为1Aa4y1E7Vy视频属性的抓取
# BV号为1Aa4y1E7Vy的视频属性抓取结束
# 开始BV号为1TV411S7JQ视频属性的抓取
# BV号为1TV411S7JQ的视频属性抓取结束
# 开始BV号为1jZ4y157yW视频属性的抓取
# BV号为1jZ4y157yW的视频属性抓取结束
# 开始BV号为1Z5411L71R视频属性的抓取
# BV号为1Z5411L71R的视频属性抓取结束
# 开始BV号为1V54y127zd视频属性的抓取
# BV号为1V54y127zd的视频属性抓取结束
# 开始BV号为1tV411m7hH视频属性的抓取
# BV号为1tV411m7hH的视频属性抓取结束
# 开始BV号为12z4y1f7Db视频属性的抓取
# BV号为12z4y1f7Db的视频属性抓取结束
# 开始BV号为1cV411m7Vt视频属性的抓取
# BV号为1cV411m7Vt的视频属性抓取结束
# 开始BV号为1PK4y1a7w6视频属性的抓取
# BV号为1PK4y1a7w6的视频属性抓取结束
# 开始BV号为1hk4y1y71t视频属性的抓取
# BV号为1hk4y1y71t的视频属性抓取结束
# 开始BV号为1Pi4y1u7fq视频属性的抓取
# BV号为1Pi4y1u7fq的视频属性抓取结束
# 开始BV号为1Ty4y1y756视频属性的抓取
# 开始BV号为1Ty4y1y756视频属性的抓取
# BV号为1Ty4y1y756的视频属性抓取结束
# 开始BV号为1ZZ4y1P7t3视频属性的抓取
# BV号为1ZZ4y1P7t3的视频属性抓取结束
# 开始BV号为12k4y127mJ视频属性的抓取
# BV号为12k4y127mJ的视频属性抓取结束
# 开始BV号为1NV411S7wW视频属性的抓取
# BV号为1NV411S7wW的视频属性抓取结束
# 开始BV号为1Z54y1y7ZW视频属性的抓取
# BV号为1Z54y1y7ZW的视频属性抓取结束
# 开始BV号为1JD4y1m7u5视频属性的抓取
# 开始BV号为1JD4y1m7u5视频属性的抓取
# BV号为1JD4y1m7u5的视频属性抓取结束
# 开始BV号为1yD4y1o7P1视频属性的抓取
# BV号为1yD4y1o7P1的视频属性抓取结束
# 开始BV号为1xK411K7Gm视频属性的抓取
# BV号为1xK411K7Gm的视频属性抓取结束
# 开始BV号为1Et4y1v77Z视频属性的抓取
# BV号为1Et4y1v77Z的视频属性抓取结束
# 开始BV号为14f4y1D7yv视频属性的抓取
# BV号为14f4y1D7yv的视频属性抓取结束
# 开始BV号为1DT4y1w7cV视频属性的抓取
# BV号为1DT4y1w7cV的视频属性抓取结束
# 开始BV号为1RT4y1w7jJ视频属性的抓取
# BV号为1RT4y1w7jJ的视频属性抓取结束
# 开始BV号为1gf4y1D716视频属性的抓取
# BV号为1gf4y1D716的视频属性抓取结束
# 开始BV号为15y4y1C7uS视频属性的抓取
# BV号为15y4y1C7uS的视频属性抓取结束
# 开始BV号为13D4y1m75n视频属性的抓取
# BV号为13D4y1m75n的视频属性抓取结束
# 开始BV号为1fD4y1o7Kt视频属性的抓取
# BV号为1fD4y1o7Kt的视频属性抓取结束
# 开始BV号为1jZ4y1N745视频属性的抓取
# BV号为1jZ4y1N745的视频属性抓取结束
# 开始BV号为1ky4y1y7uH视频属性的抓取
# BV号为1ky4y1y7uH的视频属性抓取结束
# 开始BV号为1MK411K7yw视频属性的抓取
# BV号为1MK411K7yw的视频属性抓取结束
# 开始BV号为1xp4y1a7mU视频属性的抓取
# 开始BV号为1xp4y1a7mU视频属性的抓取
# BV号为1xp4y1a7mU的视频属性抓取结束
# 开始BV号为1h54y1m7HB视频属性的抓取
# BV号为1h54y1m7HB的视频属性抓取结束
# 开始BV号为1hV411m716视频属性的抓取
# BV号为1hV411m716的视频属性抓取结束
# 开始BV号为1Sv411y7c9视频属性的抓取
# BV号为1Sv411y7c9的视频属性抓取结束
# 开始BV号为11K411N7Zh视频属性的抓取
# BV号为11K411N7Zh的视频属性抓取结束
# 开始BV号为18A411E7Dq视频属性的抓取
# BV号为18A411E7Dq的视频属性抓取结束
# 开始BV号为1NA41177J2视频属性的抓取
# 开始BV号为1NA41177J2视频属性的抓取
# BV号为1NA41177J2的视频属性抓取结束
# 开始BV号为1rT4y1A7bV视频属性的抓取
# BV号为1rT4y1A7bV的视频属性抓取结束
# 开始BV号为1BK411P7oA视频属性的抓取
# BV号为1BK411P7oA的视频属性抓取结束
# 开始BV号为1W54y1v7Kv视频属性的抓取
# BV号为1W54y1v7Kv的视频属性抓取结束
# 开始BV号为1vT4y1F7oo视频属性的抓取
# BV号为1vT4y1F7oo的视频属性抓取结束
# 开始BV号为1uD4y197Zy视频属性的抓取
# BV号为1uD4y197Zy的视频属性抓取结束
# 开始BV号为1Hy4y1B7SW视频属性的抓取
# BV号为1Hy4y1B7SW的视频属性抓取结束
# 开始BV号为1qV411y7zj视频属性的抓取
# BV号为1qV411y7zj的视频属性抓取结束
# 开始BV号为1my4y1k7JC视频属性的抓取
# BV号为1my4y1k7JC的视频属性抓取结束
# 开始BV号为1E5411V79J视频属性的抓取
# BV号为1E5411V79J的视频属性抓取结束
# 开始BV号为1ha411A7p9视频属性的抓取
# BV号为1ha411A7p9的视频属性抓取结束
# 开始BV号为1cz4y1o7mW视频属性的抓取
# BV号为1cz4y1o7mW的视频属性抓取结束
# 开始BV号为1Yt4y1v7cC视频属性的抓取
# BV号为1Yt4y1v7cC的视频属性抓取结束
# 开始BV号为1ka4y1L71W视频属性的抓取
# BV号为1ka4y1L71W的视频属性抓取结束
# 开始BV号为1Zr4y1w7mu视频属性的抓取
# BV号为1Zr4y1w7mu的视频属性抓取结束
# 开始BV号为1X541157d1视频属性的抓取
# BV号为1X541157d1的视频属性抓取结束
# 开始BV号为1Cp4y1a7zK视频属性的抓取
# BV号为1Cp4y1a7zK的视频属性抓取结束
# 开始BV号为1gK411A7V8视频属性的抓取
# BV号为1gK411A7V8的视频属性抓取结束
# 开始BV号为1nD4y197tT视频属性的抓取
# BV号为1nD4y197tT的视频属性抓取结束
# 开始BV号为17p4y1Y7yQ视频属性的抓取
# BV号为17p4y1Y7yQ的视频属性抓取结束
# 开始BV号为1Mf4y1z7cf视频属性的抓取
# BV号为1Mf4y1z7cf的视频属性抓取结束
# 开始BV号为1wK411N7hx视频属性的抓取
# BV号为1wK411N7hx的视频属性抓取结束
# 开始BV号为19f4y1B7h1视频属性的抓取
# BV号为19f4y1B7h1的视频属性抓取结束
# 开始BV号为1rD4y1d77a视频属性的抓取
# BV号为1rD4y1d77a的视频属性抓取结束
# 开始BV号为1Sa4y157BC视频属性的抓取
# BV号为1Sa4y157BC的视频属性抓取结束
# 开始BV号为1T5411L7oG视频属性的抓取
# BV号为1T5411L7oG的视频属性抓取结束
# 开始BV号为1DA41177yP视频属性的抓取
# BV号为1DA41177yP的视频属性抓取结束
# 开始BV号为1rf4y1B72G视频属性的抓取
# BV号为1rf4y1B72G的视频属性抓取结束
# 开始BV号为1FT4y1F7HQ视频属性的抓取
# BV号为1FT4y1F7HQ的视频属性抓取结束
# 开始BV号为1HT4y1c7gP视频属性的抓取
# BV号为1HT4y1c7gP的视频属性抓取结束
# 开始BV号为1Qt4y1Y7zo视频属性的抓取
# BV号为1Qt4y1Y7zo的视频属性抓取结束
# 开始BV号为1ji4y177K2视频属性的抓取
# BV号为1ji4y177K2的视频属性抓取结束
# 开始BV号为1w5411L7Kj视频属性的抓取
# BV号为1w5411L7Kj的视频属性抓取结束
# 开始BV号为1ZK411A7vR视频属性的抓取
# BV号为1ZK411A7vR的视频属性抓取结束
# 开始BV号为1qf4y1B7U1视频属性的抓取
# BV号为1qf4y1B7U1的视频属性抓取结束
# 开始BV号为1Rv411k7ZP视频属性的抓取
# BV号为1Rv411k7ZP的视频属性抓取结束
# 开始BV号为1Ci4y1j7u4视频属性的抓取
# BV号为1Ci4y1j7u4的视频属性抓取结束
# 开始BV号为1qv411y78n视频属性的抓取
# BV号为1qv411y78n的视频属性抓取结束
# 开始BV号为1WV411y7Fq视频属性的抓取
# BV号为1WV411y7Fq的视频属性抓取结束
# 开始BV号为1T5411L75G视频属性的抓取
# BV号为1T5411L75G的视频属性抓取结束
# 开始BV号为1zT4y1c7mF视频属性的抓取
# BV号为1zT4y1c7mF的视频属性抓取结束
# 开始BV号为1XK4y1f7jc视频属性的抓取
# BV号为1XK4y1f7jc的视频属性抓取结束
# 开始BV号为1Fy4y1C7HE视频属性的抓取
# BV号为1Fy4y1C7HE的视频属性抓取结束
# 开始BV号为1kV41117Dd视频属性的抓取
# BV号为1kV41117Dd的视频属性抓取结束
# 开始BV号为13541177Ky视频属性的抓取
# BV号为13541177Ky的视频属性抓取结束
# 开始BV号为1za411A7HT视频属性的抓取
# BV号为1za411A7HT的视频属性抓取结束
# 开始BV号为1ez4y1C7v2视频属性的抓取
# BV号为1ez4y1C7v2的视频属性抓取结束
# 开始BV号为1Jr4y1w76d视频属性的抓取
# BV号为1Jr4y1w76d的视频属性抓取结束
# 开始BV号为1By4y1C72f视频属性的抓取
# BV号为1By4y1C72f的视频属性抓取结束
# 开始BV号为1Nr4y1w7MM视频属性的抓取
# BV号为1Nr4y1w7MM的视频属性抓取结束
# 开始BV号为1at4y1i7ay视频属性的抓取
# BV号为1at4y1i7ay的视频属性抓取结束
# 开始BV号为1tZ4y157Qf视频属性的抓取
# BV号为1tZ4y157Qf的视频属性抓取结束
# 开始BV号为1R54y1679P视频属性的抓取
# BV号为1R54y1679P的视频属性抓取结束
# 开始BV号为1Df4y1q7kw视频属性的抓取
# BV号为1Df4y1q7kw的视频属性抓取结束
# 开始BV号为1Lp4y1Y7J2视频属性的抓取
# BV号为1Lp4y1Y7J2的视频属性抓取结束
# 开始BV号为1SV411171D视频属性的抓取
# BV号为1SV411171D的视频属性抓取结束
# 开始BV号为11V41117en视频属性的抓取
# BV号为11V41117en的视频属性抓取结束
# 开始BV号为1n54y1R7bq视频属性的抓取
# BV号为1n54y1R7bq的视频属性抓取结束
# 开始BV号为1Zp4y1r7t4视频属性的抓取
# BV号为1Zp4y1r7t4的视频属性抓取结束
# 开始BV号为1954y1k7Tj视频属性的抓取
# BV号为1954y1k7Tj的视频属性抓取结束
# 开始BV号为1aD4y1R7SK视频属性的抓取
# BV号为1aD4y1R7SK的视频属性抓取结束
# 开始BV号为1SZ4y157td视频属性的抓取
# BV号为1SZ4y157td的视频属性抓取结束
# 开始BV号为1oK4y187G2视频属性的抓取
# BV号为1oK4y187G2的视频属性抓取结束
# 开始BV号为1wt4y1e7qF视频属性的抓取
# BV号为1wt4y1e7qF的视频属性抓取结束
# 开始BV号为12V41117Au视频属性的抓取
# BV号为12V41117Au的视频属性抓取结束
# 开始BV号为1j5411L7B2视频属性的抓取
# BV号为1j5411L7B2的视频属性抓取结束
# 开始BV号为1SK411P7iL视频属性的抓取
# BV号为1SK411P7iL的视频属性抓取结束
# 开始BV号为1CK411A7yk视频属性的抓取
# BV号为1CK411A7yk的视频属性抓取结束
# 开始BV号为1br4y1w7ML视频属性的抓取
# BV号为1br4y1w7ML的视频属性抓取结束
# 开始BV号为1bi4y1j7gB视频属性的抓取
# BV号为1bi4y1j7gB的视频属性抓取结束
# 开始BV号为1y54y117PL视频属性的抓取
# BV号为1y54y117PL的视频属性抓取结束
# 开始BV号为19r4y1c7S9视频属性的抓取
# BV号为19r4y1c7S9的视频属性抓取结束
# 开始BV号为1V541177RD视频属性的抓取
# BV号为1V541177RD的视频属性抓取结束
# 开始BV号为1Zy4y1b7iv视频属性的抓取
# BV号为1Zy4y1b7iv的视频属性抓取结束
# 开始BV号为1rV411y7zg视频属性的抓取
# BV号为1rV411y7zg的视频属性抓取结束
# 开始BV号为1yz4y1Z76b视频属性的抓取
# BV号为1yz4y1Z76b的视频属性抓取结束
# 开始BV号为12K4y1h7wP视频属性的抓取
# BV号为12K4y1h7wP的视频属性抓取结束
# 开始BV号为1iv411y7LK视频属性的抓取
# BV号为1iv411y7LK的视频属性抓取结束
# 开始BV号为1AK4y1h7tE视频属性的抓取
# BV号为1AK4y1h7tE的视频属性抓取结束
# 开始BV号为1Na4y1L7a5视频属性的抓取
# BV号为1Na4y1L7a5的视频属性抓取结束
# 开始BV号为1iT4y1F7XE视频属性的抓取
# BV号为1iT4y1F7XE的视频属性抓取结束
# 开始BV号为1tf4y1B7mU视频属性的抓取
# BV号为1tf4y1B7mU的视频属性抓取结束
# 开始BV号为19y4y1k7T8视频属性的抓取
# BV号为19y4y1k7T8的视频属性抓取结束
# 开始BV号为165411j7kP视频属性的抓取
# BV号为165411j7kP的视频属性抓取结束
# 开始BV号为165411j7kP视频属性的抓取
# BV号为165411j7kP的视频属性抓取结束
# 开始BV号为1Jv411k7Sx视频属性的抓取
# BV号为1Jv411k7Sx的视频属性抓取结束
# 开始BV号为1u54y1r7Aw视频属性的抓取
# BV号为1u54y1r7Aw的视频属性抓取结束
# 开始BV号为1cA411E7Az视频属性的抓取
# BV号为1cA411E7Az的视频属性抓取结束
# 开始BV号为16z4y1o761视频属性的抓取
# BV号为16z4y1o761的视频属性抓取结束
# 开始BV号为1ba4y157o7视频属性的抓取
# BV号为1ba4y157o7的视频属性抓取结束
# 开始BV号为1Z54y167GA视频属性的抓取
# BV号为1Z54y167GA的视频属性抓取结束
# 开始BV号为1DA411L7z5视频属性的抓取
# BV号为1DA411L7z5的视频属性抓取结束
# 开始BV号为1ap4y1k7cK视频属性的抓取
# BV号为1ap4y1k7cK的视频属性抓取结束
# 开始BV号为1ra411A7W2视频属性的抓取
# BV号为1ra411A7W2的视频属性抓取结束
# 开始BV号为1jK411A7wC视频属性的抓取
# BV号为1jK411A7wC的视频属性抓取结束
# 开始BV号为1Tv411r7kq视频属性的抓取
# BV号为1Tv411r7kq的视频属性抓取结束
# 开始BV号为1Jy4y1r7U9视频属性的抓取
# BV号为1Jy4y1r7U9的视频属性抓取结束
# 开始BV号为1Pk4y1C7w3视频属性的抓取
# BV号为1Pk4y1C7w3的视频属性抓取结束
# 开始BV号为1q54y1k7xL视频属性的抓取
# BV号为1q54y1k7xL的视频属性抓取结束
# 开始BV号为1Pr4y1w7qW视频属性的抓取
# BV号为1Pr4y1w7qW的视频属性抓取结束
# 开始BV号为1JT4y1w7VP视频属性的抓取
# BV号为1JT4y1w7VP的视频属性抓取结束
# 开始BV号为1k541157aJ视频属性的抓取
# BV号为1k541157aJ的视频属性抓取结束
# 开始BV号为14y4y1B73R视频属性的抓取
# BV号为14y4y1B73R的视频属性抓取结束
# 开始BV号为1fy4y1k7Ng视频属性的抓取
# BV号为1fy4y1k7Ng的视频属性抓取结束
# 2020-12-20 20:32:31.377918

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-10-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_yinyue_fanchang.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月    99   99    99   99   99   99   99   99    99      99   99    99   99
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月     96   96    96   96   96   96   96   96    96      96   96    96   96
# 3月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月     97   97    97   97   97   97   97   97    97      97   97    97   97
# 6月     98   98    98   98   98   98   98   98    98      98   98    98   98
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月   99   99   99   99   99   99    99
# 1月   100  100  100  100  100  100   100
# 2月    96   96   96   96   96   96    96
# 3月    99   99   99   99   99   99    99
# 4月   100  100  100  100  100  100   100
# 5月    97   97   97   97   97   97    97
# 6月    98   98   98   98   98   98    98
# 7月   100  100  100  100  100  100   100
# 8月    99   99   99   99   99   99    99
# 9月   100  100  100  100  100  100   100

# %%
channel_yinyue_fanchang.to_json('channel_yinyue_fanchang.json')

# %%
channel_yinyue_fanchang=channel_yinyue_fanchang[:100]
