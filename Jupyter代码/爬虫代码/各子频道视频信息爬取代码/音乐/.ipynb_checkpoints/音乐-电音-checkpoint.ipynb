# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_yinyue_dianyin=pd.DataFrame(columns=columns)
channel_yinyue_dianyin
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[3]/div/a/span').click()  #选择“音乐”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[3]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '音乐'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[5]/a').click()  #选择“电音”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[5]/a').text
sub_channel
# Out:
# '电音'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-29-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
print(datetime.datetime.now())

for month in range(8,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_yinyue_dianyin.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-19 09:32:02.420951
# <ipython-input-15-7b4409d804e4>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-15-7b4409d804e4>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-15-7b4409d804e4>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1oA411J7hA视频属性的抓取
# BV号为1oA411J7hA的视频属性抓取结束
# <ipython-input-15-7b4409d804e4>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1X64y1F7tq视频属性的抓取
# BV号为1X64y1F7tq的视频属性抓取结束
# 开始BV号为1ZA411n7Ni视频属性的抓取
# BV号为1ZA411n7Ni的视频属性抓取结束
# 开始BV号为15h411o7Fr视频属性的抓取
# BV号为15h411o7Fr的视频属性抓取结束
# 开始BV号为1Gi4y1g7pA视频属性的抓取
# BV号为1Gi4y1g7pA的视频属性抓取结束
# 开始BV号为15p4y1v7cR视频属性的抓取
# BV号为15p4y1v7cR的视频属性抓取结束
# 开始BV号为1o64y1F743视频属性的抓取
# BV号为1o64y1F743的视频属性抓取结束
# 开始BV号为1sK411T7fZ视频属性的抓取
# BV号为1sK411T7fZ的视频属性抓取结束
# 开始BV号为1zv411v7cY视频属性的抓取
# BV号为1zv411v7cY的视频属性抓取结束
# 开始BV号为1ra4y1E75x视频属性的抓取
# BV号为1ra4y1E75x的视频属性抓取结束
# 开始BV号为1B5411a7sH视频属性的抓取
# BV号为1B5411a7sH的视频属性抓取结束
# 开始BV号为1vv411v7gt视频属性的抓取
# BV号为1vv411v7gt的视频属性抓取结束
# 开始BV号为1eD4y1U7fE视频属性的抓取
# BV号为1eD4y1U7fE的视频属性抓取结束
# 开始BV号为1Ea4y1E7fN视频属性的抓取
# BV号为1Ea4y1E7fN的视频属性抓取结束
# 开始BV号为1oC4y1b7mi视频属性的抓取
# BV号为1oC4y1b7mi的视频属性抓取结束
# 开始BV号为1KC4y187Yb视频属性的抓取
# BV号为1KC4y187Yb的视频属性抓取结束
# 开始BV号为1EC4y1t7z5视频属性的抓取
# BV号为1EC4y1t7z5的视频属性抓取结束
# 开始BV号为1v54y127Qz视频属性的抓取
# BV号为1v54y127Qz的视频属性抓取结束
# 开始BV号为1ik4y127Lr视频属性的抓取
# BV号为1ik4y127Lr的视频属性抓取结束
# 开始BV号为16f4y1X7PE视频属性的抓取
# BV号为16f4y1X7PE的视频属性抓取结束
# 开始BV号为1Yt4y1D7G1视频属性的抓取
# BV号为1Yt4y1D7G1的视频属性抓取结束
# 开始BV号为1kZ4y1K7r7视频属性的抓取
# BV号为1kZ4y1K7r7的视频属性抓取结束
# 开始BV号为1qK411T7km视频属性的抓取
# 开始BV号为1qK411T7km视频属性的抓取
# BV号为1qK411T7km的视频属性抓取结束
# 开始BV号为1P54y1U7pM视频属性的抓取
# 开始BV号为1P54y1U7pM视频属性的抓取
# BV号为1P54y1U7pM的视频属性抓取结束
# 开始BV号为1tC4y1t7Gr视频属性的抓取
# 开始BV号为1tC4y1t7Gr视频属性的抓取
# BV号为1tC4y1t7Gr的视频属性抓取结束
# 开始BV号为1U54y1m72N视频属性的抓取
# BV号为1U54y1m72N的视频属性抓取结束
# 开始BV号为1hf4y1Q7ud视频属性的抓取
# BV号为1hf4y1Q7ud的视频属性抓取结束
# 开始BV号为1j54y1e7zs视频属性的抓取
# BV号为1j54y1e7zs的视频属性抓取结束
# 开始BV号为1Xv411y7Qp视频属性的抓取
# BV号为1Xv411y7Qp的视频属性抓取结束
# 开始BV号为1cp4y1v7Cq视频属性的抓取
# BV号为1cp4y1v7Cq的视频属性抓取结束
# 开始BV号为1ta4y177hH视频属性的抓取
# BV号为1ta4y177hH的视频属性抓取结束
# 开始BV号为1a54y1U7dm视频属性的抓取
# BV号为1a54y1U7dm的视频属性抓取结束
# 开始BV号为1RT4y157ub视频属性的抓取
# BV号为1RT4y157ub的视频属性抓取结束
# 开始BV号为1AC4y1t7Dv视频属性的抓取
# BV号为1AC4y1t7Dv的视频属性抓取结束
# 开始BV号为1r54y1i7iE视频属性的抓取
# BV号为1r54y1i7iE的视频属性抓取结束
# 开始BV号为1zA411Y7kx视频属性的抓取
# BV号为1zA411Y7kx的视频属性抓取结束
# 开始BV号为1FC4y1b7Ss视频属性的抓取
# BV号为1FC4y1b7Ss的视频属性抓取结束
# 开始BV号为1tf4y1Q7H3视频属性的抓取
# BV号为1tf4y1Q7H3的视频属性抓取结束
# 开始BV号为1pV411S7rJ视频属性的抓取
# BV号为1pV411S7rJ的视频属性抓取结束
# 开始BV号为1TZ4y1K7SD视频属性的抓取
# BV号为1TZ4y1K7SD的视频属性抓取结束
# 开始BV号为12i4y1g7Bx视频属性的抓取
# BV号为12i4y1g7Bx的视频属性抓取结束
# 开始BV号为1G54y1U7uK视频属性的抓取
# BV号为1G54y1U7uK的视频属性抓取结束
# 开始BV号为1UT4y1L7RP视频属性的抓取
# BV号为1UT4y1L7RP的视频属性抓取结束
# 开始BV号为1P54y1U7Ds视频属性的抓取
# BV号为1P54y1U7Ds的视频属性抓取结束
# 开始BV号为18i4y1M7D2视频属性的抓取
# BV号为18i4y1M7D2的视频属性抓取结束
# 开始BV号为1fp4y1v7Sk视频属性的抓取
# BV号为1fp4y1v7Sk的视频属性抓取结束
# 开始BV号为1gZ4y1M7uS视频属性的抓取
# 开始BV号为1gZ4y1M7uS视频属性的抓取
# BV号为1gZ4y1M7uS的视频属性抓取结束
# 开始BV号为1Yp4y1q7Xh视频属性的抓取
# BV号为1Yp4y1q7Xh的视频属性抓取结束
# 开始BV号为1RD4y1U7bM视频属性的抓取
# BV号为1RD4y1U7bM的视频属性抓取结束
# 开始BV号为1fA411a7Qg视频属性的抓取
# BV号为1fA411a7Qg的视频属性抓取结束
# 开始BV号为1FT4y1L7P8视频属性的抓取
# BV号为1FT4y1L7P8的视频属性抓取结束
# 开始BV号为16D4y1U7Bk视频属性的抓取
# BV号为16D4y1U7Bk的视频属性抓取结束
# 开始BV号为1Wh411Z7X3视频属性的抓取
# BV号为1Wh411Z7X3的视频属性抓取结束
# 开始BV号为1Hz4y1f7RS视频属性的抓取
# BV号为1Hz4y1f7RS的视频属性抓取结束
# 开始BV号为1Yf4y1Q7qz视频属性的抓取
# BV号为1Yf4y1Q7qz的视频属性抓取结束
# 开始BV号为1y64y1c79n视频属性的抓取
# BV号为1y64y1c79n的视频属性抓取结束
# 开始BV号为1zf4y197Su视频属性的抓取
# BV号为1zf4y197Su的视频属性抓取结束
# 开始BV号为1h541187Qz视频属性的抓取
# BV号为1h541187Qz的视频属性抓取结束
# 开始BV号为1zA411Y7V3视频属性的抓取
# BV号为1zA411Y7V3的视频属性抓取结束
# 开始BV号为1Kt4y1D79y视频属性的抓取
# BV号为1Kt4y1D79y的视频属性抓取结束
# 开始BV号为1Tk4y127iE视频属性的抓取
# BV号为1Tk4y127iE的视频属性抓取结束
# 开始BV号为1rf4y197JQ视频属性的抓取
# BV号为1rf4y197JQ的视频属性抓取结束
# 开始BV号为13K4y1v7Jp视频属性的抓取
# BV号为13K4y1v7Jp的视频属性抓取结束
# 开始BV号为1Ef4y1Q7HJ视频属性的抓取
# BV号为1Ef4y1Q7HJ的视频属性抓取结束
# 开始BV号为1zv411v7Mx视频属性的抓取
# BV号为1zv411v7Mx的视频属性抓取结束
# 开始BV号为1Ep4y1i7rH视频属性的抓取
# BV号为1Ep4y1i7rH的视频属性抓取结束
# 开始BV号为1Pk4y127Wg视频属性的抓取
# BV号为1Pk4y127Wg的视频属性抓取结束
# 开始BV号为1R54y1S7e7视频属性的抓取
# BV号为1R54y1S7e7的视频属性抓取结束
# 开始BV号为1qh411971J视频属性的抓取
# BV号为1qh411971J的视频属性抓取结束
# 开始BV号为1oA411J7nE视频属性的抓取
# BV号为1oA411J7nE的视频属性抓取结束
# 开始BV号为1Ui4y1g7do视频属性的抓取
# BV号为1Ui4y1g7do的视频属性抓取结束
# 开始BV号为1Gi4y1g73G视频属性的抓取
# BV号为1Gi4y1g73G的视频属性抓取结束
# 开始BV号为1oh411d7v4视频属性的抓取
# BV号为1oh411d7v4的视频属性抓取结束
# 开始BV号为1NT4y1L7Ww视频属性的抓取
# BV号为1NT4y1L7Ww的视频属性抓取结束
# 开始BV号为1QD4y1m7Rr视频属性的抓取
# BV号为1QD4y1m7Rr的视频属性抓取结束
# 开始BV号为1kK4y1v7y1视频属性的抓取
# BV号为1kK4y1v7y1的视频属性抓取结束
# 开始BV号为1J54y1U7v6视频属性的抓取
# BV号为1J54y1U7v6的视频属性抓取结束
# 开始BV号为1qD4y1m7Ex视频属性的抓取
# BV号为1qD4y1m7Ex的视频属性抓取结束
# 开始BV号为1EZ4y1M789视频属性的抓取
# BV号为1EZ4y1M789的视频属性抓取结束
# 开始BV号为1kK411T7sR视频属性的抓取
# BV号为1kK411T7sR的视频属性抓取结束
# 开始BV号为1Pi4y1G79S视频属性的抓取
# BV号为1Pi4y1G79S的视频属性抓取结束
# 开始BV号为1xv41117Ny视频属性的抓取
# BV号为1xv41117Ny的视频属性抓取结束
# 开始BV号为1mZ4y1T7CE视频属性的抓取
# BV号为1mZ4y1T7CE的视频属性抓取结束
# 开始BV号为1pK4y1Y7Pd视频属性的抓取
# BV号为1pK4y1Y7Pd的视频属性抓取结束
# 开始BV号为1Bv411y7PL视频属性的抓取
# BV号为1Bv411y7PL的视频属性抓取结束
# 开始BV号为13K411M7Xv视频属性的抓取
# BV号为13K411M7Xv的视频属性抓取结束
# 开始BV号为1jK4y1v7Er视频属性的抓取
# BV号为1jK4y1v7Er的视频属性抓取结束
# 开始BV号为1nz4y1f7wm视频属性的抓取
# BV号为1nz4y1f7wm的视频属性抓取结束
# 开始BV号为11v411q7CM视频属性的抓取
# BV号为11v411q7CM的视频属性抓取结束
# 开始BV号为1wt4y1Q7uT视频属性的抓取
# BV号为1wt4y1Q7uT的视频属性抓取结束
# 开始BV号为1Vi4y1g7Lw视频属性的抓取
# BV号为1Vi4y1g7Lw的视频属性抓取结束
# 开始BV号为1Zp4y1v7RF视频属性的抓取
# BV号为1Zp4y1v7RF的视频属性抓取结束
# 开始BV号为1Y5411h7Ar视频属性的抓取
# BV号为1Y5411h7Ar的视频属性抓取结束
# 开始BV号为14f4y197xK视频属性的抓取
# BV号为14f4y197xK的视频属性抓取结束
# 开始BV号为1gh411d7Nd视频属性的抓取
# BV号为1gh411d7Nd的视频属性抓取结束
# 开始BV号为1a64y1c77o视频属性的抓取
# BV号为1a64y1c77o的视频属性抓取结束
# 开始BV号为1kh411973T视频属性的抓取
# BV号为1kh411973T的视频属性抓取结束
# 开始BV号为1Gk4y1y71m视频属性的抓取
# BV号为1Gk4y1y71m的视频属性抓取结束
# 开始BV号为1Ai4y1g72E视频属性的抓取
# BV号为1Ai4y1g72E的视频属性抓取结束
# 开始BV号为1iD4y127xm视频属性的抓取
# 开始BV号为1iD4y127xm视频属性的抓取
# BV号为1iD4y127xm的视频属性抓取结束
# 开始BV号为1c54y1v7LV视频属性的抓取
# BV号为1c54y1v7LV的视频属性抓取结束
# 开始BV号为1bh411R7GZ视频属性的抓取
# BV号为1bh411R7GZ的视频属性抓取结束
# 开始BV号为1ah411X78o视频属性的抓取
# BV号为1ah411X78o的视频属性抓取结束
# 开始BV号为1N64y1F71i视频属性的抓取
# BV号为1N64y1F71i的视频属性抓取结束
# 开始BV号为1ft4y1S7VS视频属性的抓取
# BV号为1ft4y1S7VS的视频属性抓取结束
# 开始BV号为1a64y1F7pV视频属性的抓取
# BV号为1a64y1F7pV的视频属性抓取结束
# 开始BV号为14t4y1q7Jr视频属性的抓取
# BV号为14t4y1q7Jr的视频属性抓取结束
# 开始BV号为1h54y1272w视频属性的抓取
# BV号为1h54y1272w的视频属性抓取结束
# 开始BV号为1xA411E7jq视频属性的抓取
# BV号为1xA411E7jq的视频属性抓取结束
# 开始BV号为1iV411m7jW视频属性的抓取
# BV号为1iV411m7jW的视频属性抓取结束
# 开始BV号为1fi4y1771M视频属性的抓取
# BV号为1fi4y1771M的视频属性抓取结束
# 开始BV号为1ZZ4y1N7cs视频属性的抓取
# BV号为1ZZ4y1N7cs的视频属性抓取结束
# 开始BV号为1dt4y1i7WW视频属性的抓取
# BV号为1dt4y1i7WW的视频属性抓取结束
# 开始BV号为1Tp4y1e7hE视频属性的抓取
# BV号为1Tp4y1e7hE的视频属性抓取结束
# 开始BV号为1RV411m7Ek视频属性的抓取
# BV号为1RV411m7Ek的视频属性抓取结束
# 开始BV号为1NV41127t9视频属性的抓取
# BV号为1NV41127t9的视频属性抓取结束
# 开始BV号为1m5411b7BT视频属性的抓取
# BV号为1m5411b7BT的视频属性抓取结束
# 开始BV号为1864y1F7wv视频属性的抓取
# BV号为1864y1F7wv的视频属性抓取结束
# 开始BV号为1wD4y1Z7ap视频属性的抓取
# BV号为1wD4y1Z7ap的视频属性抓取结束
# 开始BV号为1qt4y1i7u4视频属性的抓取
# BV号为1qt4y1i7u4的视频属性抓取结束
# 开始BV号为1rh411R7cr视频属性的抓取
# BV号为1rh411R7cr的视频属性抓取结束
# 开始BV号为1j54y1y7br视频属性的抓取
# BV号为1j54y1y7br的视频属性抓取结束
# 开始BV号为19D4y1o7h3视频属性的抓取
# BV号为19D4y1o7h3的视频属性抓取结束
# 开始BV号为1oD4y1d7vK视频属性的抓取
# BV号为1oD4y1d7vK的视频属性抓取结束
# 开始BV号为1rk4y1y7N4视频属性的抓取
# BV号为1rk4y1y7N4的视频属性抓取结束
# 开始BV号为1GD4y1o7zh视频属性的抓取
# BV号为1GD4y1o7zh的视频属性抓取结束
# 开始BV号为1jh411X7qD视频属性的抓取
# BV号为1jh411X7qD的视频属性抓取结束
# 开始BV号为1P54y1y7C3视频属性的抓取
# BV号为1P54y1y7C3的视频属性抓取结束
# 开始BV号为1hK4y1e7rC视频属性的抓取
# 开始BV号为1hK4y1e7rC视频属性的抓取
# BV号为1hK4y1e7rC的视频属性抓取结束
# 开始BV号为1H54y1m71z视频属性的抓取
# BV号为1H54y1m71z的视频属性抓取结束
# 开始BV号为1u54y1y7zm视频属性的抓取
# BV号为1u54y1y7zm的视频属性抓取结束
# 开始BV号为1wk4y1C7os视频属性的抓取
# BV号为1wk4y1C7os的视频属性抓取结束
# 开始BV号为1AD4y1Z7hG视频属性的抓取
# BV号为1AD4y1Z7hG的视频属性抓取结束
# 开始BV号为1p54y117F7视频属性的抓取
# BV号为1p54y117F7的视频属性抓取结束
# 开始BV号为1sz4y1Z7Gv视频属性的抓取
# BV号为1sz4y1Z7Gv的视频属性抓取结束
# 开始BV号为1kT4y1w7yK视频属性的抓取
# BV号为1kT4y1w7yK的视频属性抓取结束
# 开始BV号为1Xa4y177RE视频属性的抓取
# 开始BV号为1Xa4y177RE视频属性的抓取
# BV号为1Xa4y177RE的视频属性抓取结束
# 开始BV号为1wi4y1E7mD视频属性的抓取
# BV号为1wi4y1E7mD的视频属性抓取结束
# 开始BV号为1oy4y1k7Po视频属性的抓取
# BV号为1oy4y1k7Po的视频属性抓取结束
# 开始BV号为1Tf4y1D7Ak视频属性的抓取
# BV号为1Tf4y1D7Ak的视频属性抓取结束
# 开始BV号为1bh411R7ob视频属性的抓取
# 开始BV号为1bh411R7ob视频属性的抓取
# BV号为1bh411R7ob的视频属性抓取结束
# 开始BV号为1GZ4y1N7HF视频属性的抓取
# BV号为1GZ4y1N7HF的视频属性抓取结束
# 开始BV号为1Ey4y1y772视频属性的抓取
# BV号为1Ey4y1y772的视频属性抓取结束
# 开始BV号为1Y5411h7Sa视频属性的抓取
# BV号为1Y5411h7Sa的视频属性抓取结束
# 开始BV号为1hh411R75x视频属性的抓取
# BV号为1hh411R75x的视频属性抓取结束
# 开始BV号为1BA411n7bW视频属性的抓取
# BV号为1BA411n7bW的视频属性抓取结束
# 开始BV号为1cZ4y1N71U视频属性的抓取
# BV号为1cZ4y1N71U的视频属性抓取结束
# 开始BV号为1xt4y1S73X视频属性的抓取
# BV号为1xt4y1S73X的视频属性抓取结束
# 开始BV号为1tA411E71C视频属性的抓取
# BV号为1tA411E71C的视频属性抓取结束
# 开始BV号为1d54y1y7kp视频属性的抓取
# BV号为1d54y1y7kp的视频属性抓取结束
# 开始BV号为1QV411m74q视频属性的抓取
# BV号为1QV411m74q的视频属性抓取结束
# 开始BV号为1954y127kK视频属性的抓取
# BV号为1954y127kK的视频属性抓取结束
# 开始BV号为1G5411b75f视频属性的抓取
# BV号为1G5411b75f的视频属性抓取结束
# 开始BV号为1t54y127Yd视频属性的抓取
# BV号为1t54y127Yd的视频属性抓取结束
# 开始BV号为1Dv411y7DV视频属性的抓取
# BV号为1Dv411y7DV的视频属性抓取结束
# 开始BV号为1Zf4y1S7ZS视频属性的抓取
# BV号为1Zf4y1S7ZS的视频属性抓取结束
# 开始BV号为1tv411C7Jm视频属性的抓取
# BV号为1tv411C7Jm的视频属性抓取结束
# 开始BV号为1mT4y1L7CQ视频属性的抓取
# BV号为1mT4y1L7CQ的视频属性抓取结束
# 开始BV号为1x54y1y7p9视频属性的抓取
# BV号为1x54y1y7p9的视频属性抓取结束
# 开始BV号为1Z5411L7Lc视频属性的抓取
# BV号为1Z5411L7Lc的视频属性抓取结束
# 开始BV号为135411j7e3视频属性的抓取
# BV号为135411j7e3的视频属性抓取结束
# 开始BV号为1XZ4y1K77w视频属性的抓取
# BV号为1XZ4y1K77w的视频属性抓取结束
# 开始BV号为12k4y1y7tk视频属性的抓取
# BV号为12k4y1y7tk的视频属性抓取结束
# 开始BV号为1Kp4y1e7qd视频属性的抓取
# BV号为1Kp4y1e7qd的视频属性抓取结束
# 开始BV号为1dy4y1C7c3视频属性的抓取
# BV号为1dy4y1C7c3的视频属性抓取结束
# 开始BV号为1jZ4y157jj视频属性的抓取
# BV号为1jZ4y157jj的视频属性抓取结束
# 开始BV号为14D4y1o7uJ视频属性的抓取
# BV号为14D4y1o7uJ的视频属性抓取结束
# 开始BV号为1pv411C7ti视频属性的抓取
# BV号为1pv411C7ti的视频属性抓取结束
# 开始BV号为1rK4y187JZ视频属性的抓取
# BV号为1rK4y187JZ的视频属性抓取结束
# 开始BV号为1ft4y1S78z视频属性的抓取
# BV号为1ft4y1S78z的视频属性抓取结束
# 开始BV号为19v411C7a8视频属性的抓取
# BV号为19v411C7a8的视频属性抓取结束
# 开始BV号为18y4y1y7nV视频属性的抓取
# BV号为18y4y1y7nV的视频属性抓取结束
# 开始BV号为1PZ4y1N7Tv视频属性的抓取
# BV号为1PZ4y1N7Tv的视频属性抓取结束
# 开始BV号为1qy4y1k7MA视频属性的抓取
# BV号为1qy4y1k7MA的视频属性抓取结束
# 开始BV号为1qK4y1a7ca视频属性的抓取
# BV号为1qK4y1a7ca的视频属性抓取结束
# 开始BV号为1Ek4y1C7Ro视频属性的抓取
# BV号为1Ek4y1C7Ro的视频属性抓取结束
# 开始BV号为1Zt4y1i7jW视频属性的抓取
# BV号为1Zt4y1i7jW的视频属性抓取结束
# 开始BV号为1Sv41117FK视频属性的抓取
# BV号为1Sv41117FK的视频属性抓取结束
# 开始BV号为1iK411P7QT视频属性的抓取
# BV号为1iK411P7QT的视频属性抓取结束
# 开始BV号为1WK4y1e7o1视频属性的抓取
# BV号为1WK4y1e7o1的视频属性抓取结束
# 开始BV号为1Xt4y1S7n4视频属性的抓取
# BV号为1Xt4y1S7n4的视频属性抓取结束
# 开始BV号为1bh411X7BC视频属性的抓取
# BV号为1bh411X7BC的视频属性抓取结束
# 开始BV号为16Z4y1N7DJ视频属性的抓取
# BV号为16Z4y1N7DJ的视频属性抓取结束
# 开始BV号为1yv41117Lu视频属性的抓取
# BV号为1yv41117Lu的视频属性抓取结束
# 开始BV号为1gD4y1m7o3视频属性的抓取
# BV号为1gD4y1m7o3的视频属性抓取结束
# 开始BV号为19D4y1d7yr视频属性的抓取
# BV号为19D4y1d7yr的视频属性抓取结束
# 开始BV号为1Mt4y1q7ht视频属性的抓取
# BV号为1Mt4y1q7ht的视频属性抓取结束
# 开始BV号为1Ef4y1X7ew视频属性的抓取
# BV号为1Ef4y1X7ew的视频属性抓取结束
# 开始BV号为1zT4y1L71h视频属性的抓取
# BV号为1zT4y1L71h的视频属性抓取结束
# 开始BV号为1MT4y1A7sM视频属性的抓取
# BV号为1MT4y1A7sM的视频属性抓取结束
# 开始BV号为1ua4y1E76K视频属性的抓取
# BV号为1ua4y1E76K的视频属性抓取结束
# 开始BV号为1DV411m78W视频属性的抓取
# BV号为1DV411m78W的视频属性抓取结束
# 开始BV号为1ht4y1S7w9视频属性的抓取
# BV号为1ht4y1S7w9的视频属性抓取结束
# 开始BV号为14y4y1y7XR视频属性的抓取
# BV号为14y4y1y7XR的视频属性抓取结束
# 开始BV号为1pi4y1E7GZ视频属性的抓取
# BV号为1pi4y1E7GZ的视频属性抓取结束
# 开始BV号为1wp4y1Y7fh视频属性的抓取
# BV号为1wp4y1Y7fh的视频属性抓取结束
# 开始BV号为1MV411m7Wr视频属性的抓取
# BV号为1MV411m7Wr的视频属性抓取结束
# 开始BV号为1u5411b7XB视频属性的抓取
# BV号为1u5411b7XB的视频属性抓取结束
# 开始BV号为1xf4y1X7em视频属性的抓取
# BV号为1xf4y1X7em的视频属性抓取结束
# 开始BV号为1yf4y1D7Y5视频属性的抓取
# BV号为1yf4y1D7Y5的视频属性抓取结束
# 开始BV号为1Li4y177BV视频属性的抓取
# BV号为1Li4y177BV的视频属性抓取结束
# 开始BV号为1YT4y1F7nt视频属性的抓取
# BV号为1YT4y1F7nt的视频属性抓取结束
# 开始BV号为1GD4y197kn视频属性的抓取
# BV号为1GD4y197kn的视频属性抓取结束
# 开始BV号为1kz4y1o7Cz视频属性的抓取
# BV号为1kz4y1o7Cz的视频属性抓取结束
# 开始BV号为1Ea411A7dE视频属性的抓取
# BV号为1Ea411A7dE的视频属性抓取结束
# 开始BV号为1b54y1k7hU视频属性的抓取
# BV号为1b54y1k7hU的视频属性抓取结束
# 开始BV号为1my4y1z7V2视频属性的抓取
# BV号为1my4y1z7V2的视频属性抓取结束
# 开始BV号为1A541177oG视频属性的抓取
# BV号为1A541177oG的视频属性抓取结束
# 开始BV号为1AV411y7CL视频属性的抓取
# BV号为1AV411y7CL的视频属性抓取结束
# 开始BV号为1JT4y1w7sV视频属性的抓取
# BV号为1JT4y1w7sV的视频属性抓取结束
# 开始BV号为1Rp4y1r7Xn视频属性的抓取
# BV号为1Rp4y1r7Xn的视频属性抓取结束
# 开始BV号为1hD4y1R7V4视频属性的抓取
# BV号为1hD4y1R7V4的视频属性抓取结束
# 开始BV号为1ii4y177gK视频属性的抓取
# BV号为1ii4y177gK的视频属性抓取结束
# 开始BV号为1EA411E73F视频属性的抓取
# BV号为1EA411E73F的视频属性抓取结束
# 开始BV号为1oK4y1f7EJ视频属性的抓取
# BV号为1oK4y1f7EJ的视频属性抓取结束
# 开始BV号为1JZ4y1V7uf视频属性的抓取
# BV号为1JZ4y1V7uf的视频属性抓取结束
# 开始BV号为1Pp4y1k79p视频属性的抓取
# BV号为1Pp4y1k79p的视频属性抓取结束
# 开始BV号为1ea4y1L758视频属性的抓取
# BV号为1ea4y1L758的视频属性抓取结束
# 开始BV号为1UK4y177WT视频属性的抓取
# BV号为1UK4y177WT的视频属性抓取结束
# 开始BV号为1TK4y1E7yA视频属性的抓取
# BV号为1TK4y1E7yA的视频属性抓取结束
# 开始BV号为1mZ4y157N5视频属性的抓取
# BV号为1mZ4y157N5的视频属性抓取结束
# 开始BV号为1fZ4y157iM视频属性的抓取
# BV号为1fZ4y157iM的视频属性抓取结束
# 开始BV号为1Ga4y1L7KD视频属性的抓取
# BV号为1Ga4y1L7KD的视频属性抓取结束
# 开始BV号为1p54y1C7ok视频属性的抓取
# BV号为1p54y1C7ok的视频属性抓取结束
# 开始BV号为1CT4y1c7sd视频属性的抓取
# BV号为1CT4y1c7sd的视频属性抓取结束
# 开始BV号为1Vy4y1r7MY视频属性的抓取
# BV号为1Vy4y1r7MY的视频属性抓取结束
# 开始BV号为1Kf4y1Q7UD视频属性的抓取
# BV号为1Kf4y1Q7UD的视频属性抓取结束
# 开始BV号为1o541157Gn视频属性的抓取
# BV号为1o541157Gn的视频属性抓取结束
# 开始BV号为1DZ4y157vw视频属性的抓取
# BV号为1DZ4y157vw的视频属性抓取结束
# 开始BV号为1N5411L7Yh视频属性的抓取
# 开始BV号为1N5411L7Yh视频属性的抓取
# 开始BV号为1N5411L7Yh视频属性的抓取
# 开始BV号为1N5411L7Yh视频属性的抓取
# 开始BV号为1N5411L7Yh视频属性的抓取
# 开始BV号为1N5411L7Yh视频属性的抓取
# 开始BV号为1N5411L7Yh视频属性的抓取
# 开始BV号为1N5411L7Yh视频属性的抓取
# BV号为1N5411L7Yh的视频属性抓取结束
# 开始BV号为1ka411A7Ua视频属性的抓取
# BV号为1ka411A7Ua的视频属性抓取结束
# 开始BV号为1PA411j7Pk视频属性的抓取
# BV号为1PA411j7Pk的视频属性抓取结束
# 开始BV号为1aA41177PJ视频属性的抓取
# BV号为1aA41177PJ的视频属性抓取结束
# 开始BV号为1pT4y1F7ow视频属性的抓取
# BV号为1pT4y1F7ow的视频属性抓取结束
# 开始BV号为1Ta4y1s7ft视频属性的抓取
# BV号为1Ta4y1s7ft的视频属性抓取结束
# 开始BV号为1Ra411w7Qh视频属性的抓取
# BV号为1Ra411w7Qh的视频属性抓取结束
# 开始BV号为18i4y1j7AH视频属性的抓取
# BV号为18i4y1j7AH的视频属性抓取结束
# 开始BV号为1DV41117gE视频属性的抓取
# BV号为1DV41117gE的视频属性抓取结束
# 开始BV号为13V41127CL视频属性的抓取
# BV号为13V41127CL的视频属性抓取结束
# 开始BV号为1Ya4y1L7Ne视频属性的抓取
# BV号为1Ya4y1L7Ne的视频属性抓取结束
# 开始BV号为1Vi4y177Vn视频属性的抓取
# BV号为1Vi4y177Vn的视频属性抓取结束
# 开始BV号为1P54y127qu视频属性的抓取
# BV号为1P54y127qu的视频属性抓取结束
# 开始BV号为15Z4y1V79H视频属性的抓取
# BV号为15Z4y1V79H的视频属性抓取结束
# 开始BV号为1hv411k7ng视频属性的抓取
# BV号为1hv411k7ng的视频属性抓取结束
# 开始BV号为1fK4y187Js视频属性的抓取
# BV号为1fK4y187Js的视频属性抓取结束
# 开始BV号为1Mp4y1k7Eq视频属性的抓取
# BV号为1Mp4y1k7Eq的视频属性抓取结束
# 开始BV号为13a4y1L7RU视频属性的抓取
# BV号为13a4y1L7RU的视频属性抓取结束
# 开始BV号为18z4y1o7nT视频属性的抓取
# BV号为18z4y1o7nT的视频属性抓取结束
# 开始BV号为16K4y177gU视频属性的抓取
# BV号为16K4y177gU的视频属性抓取结束
# 开始BV号为1gK411N7r6视频属性的抓取
# BV号为1gK411N7r6的视频属性抓取结束
# 开始BV号为1uK4y1h799视频属性的抓取
# BV号为1uK4y1h799的视频属性抓取结束
# 开始BV号为1Aa4y177dj视频属性的抓取
# BV号为1Aa4y177dj的视频属性抓取结束
# 开始BV号为1Wv411k7Aj视频属性的抓取
# BV号为1Wv411k7Aj的视频属性抓取结束
# 开始BV号为1XZ4y1G7UL视频属性的抓取
# BV号为1XZ4y1G7UL的视频属性抓取结束
# 开始BV号为19Z4y1G7Ez视频属性的抓取
# BV号为19Z4y1G7Ez的视频属性抓取结束
# 开始BV号为1bv411k7Fc视频属性的抓取
# BV号为1bv411k7Fc的视频属性抓取结束
# 开始BV号为1MK411A7LK视频属性的抓取
# BV号为1MK411A7LK的视频属性抓取结束
# 开始BV号为1v54y1r76Y视频属性的抓取
# BV号为1v54y1r76Y的视频属性抓取结束
# 开始BV号为19y4y1b7DM视频属性的抓取
# BV号为19y4y1b7DM的视频属性抓取结束
# 开始BV号为1QV41117CT视频属性的抓取
# BV号为1QV41117CT的视频属性抓取结束
# 开始BV号为1rk4y1C77U视频属性的抓取
# BV号为1rk4y1C77U的视频属性抓取结束
# 开始BV号为1vK411A7fB视频属性的抓取
# BV号为1vK411A7fB的视频属性抓取结束
# 开始BV号为1Bi4y1j7Do视频属性的抓取
# BV号为1Bi4y1j7Do的视频属性抓取结束
# 开始BV号为1SV411y7fb视频属性的抓取
# BV号为1SV411y7fb的视频属性抓取结束
# 开始BV号为1bv411k7c9视频属性的抓取
# BV号为1bv411k7c9的视频属性抓取结束
# 开始BV号为1xZ4y1L7Zm视频属性的抓取
# BV号为1xZ4y1L7Zm的视频属性抓取结束
# 开始BV号为1py4y1r767视频属性的抓取
# BV号为1py4y1r767的视频属性抓取结束
# 开始BV号为1Yy4y1r7fw视频属性的抓取
# BV号为1Yy4y1r7fw的视频属性抓取结束
# 开始BV号为1Tp4y1k7KX视频属性的抓取
# BV号为1Tp4y1k7KX的视频属性抓取结束
# 开始BV号为1u54y127kN视频属性的抓取
# BV号为1u54y127kN的视频属性抓取结束
# 开始BV号为1Vt4y1v72P视频属性的抓取
# BV号为1Vt4y1v72P的视频属性抓取结束
# 开始BV号为1Ga411A729视频属性的抓取
# BV号为1Ga411A729的视频属性抓取结束
# 开始BV号为1Ci4y1j7iV视频属性的抓取
# BV号为1Ci4y1j7iV的视频属性抓取结束
# 开始BV号为1QD4y1R7zr视频属性的抓取
# BV号为1QD4y1R7zr的视频属性抓取结束
# 开始BV号为1wk4y1y7mS视频属性的抓取
# BV号为1wk4y1y7mS的视频属性抓取结束
# 开始BV号为1r5411L7GR视频属性的抓取
# BV号为1r5411L7GR的视频属性抓取结束
# 开始BV号为1qV411y7bv视频属性的抓取
# BV号为1qV411y7bv的视频属性抓取结束
# 开始BV号为17Z4y1578v视频属性的抓取
# BV号为17Z4y1578v的视频属性抓取结束
# 开始BV号为1TK411P7vL视频属性的抓取
# BV号为1TK411P7vL的视频属性抓取结束
# 开始BV号为1ma411w7Cf视频属性的抓取
# BV号为1ma411w7Cf的视频属性抓取结束
# 开始BV号为1qa4y157od视频属性的抓取
# BV号为1qa4y157od的视频属性抓取结束
# 开始BV号为1ca4y1x79j视频属性的抓取
# BV号为1ca4y1x79j的视频属性抓取结束
# 开始BV号为1JV411y7kf视频属性的抓取
# BV号为1JV411y7kf的视频属性抓取结束
# 开始BV号为1fa411A7ZZ视频属性的抓取
# BV号为1fa411A7ZZ的视频属性抓取结束
# 开始BV号为13Z4y1V7h6视频属性的抓取
# BV号为13Z4y1V7h6的视频属性抓取结束
# 开始BV号为1tt4y1e7fi视频属性的抓取
# BV号为1tt4y1e7fi的视频属性抓取结束
# 开始BV号为1PT4y1w7ic视频属性的抓取
# BV号为1PT4y1w7ic的视频属性抓取结束
# 开始BV号为1Pa4y177St视频属性的抓取
# BV号为1Pa4y177St的视频属性抓取结束
# 开始BV号为1sD4y197ya视频属性的抓取
# 开始BV号为1sD4y197ya视频属性的抓取
# 开始BV号为1sD4y197ya视频属性的抓取
# BV号为1sD4y197ya的视频属性抓取结束
# 开始BV号为16T4y1c7pF视频属性的抓取
# BV号为16T4y1c7pF的视频属性抓取结束
# 开始BV号为1Vf4y1B7yj视频属性的抓取
# BV号为1Vf4y1B7yj的视频属性抓取结束
# 开始BV号为1vK411G75i视频属性的抓取
# BV号为1vK411G75i的视频属性抓取结束
# 开始BV号为1GV411271E视频属性的抓取
# BV号为1GV411271E的视频属性抓取结束
# 开始BV号为1454y1k7KU视频属性的抓取
# BV号为1454y1k7KU的视频属性抓取结束
# 开始BV号为1Vz4y1o7v1视频属性的抓取
# BV号为1Vz4y1o7v1的视频属性抓取结束
# 开始BV号为1Wy4y1r7AL视频属性的抓取
# BV号为1Wy4y1r7AL的视频属性抓取结束
# 开始BV号为12i4y1j7SJ视频属性的抓取
# BV号为12i4y1j7SJ的视频属性抓取结束
# 开始BV号为1PT4y1w7Lz视频属性的抓取
# BV号为1PT4y1w7Lz的视频属性抓取结束
# 开始BV号为1CV41117UL视频属性的抓取
# BV号为1CV41117UL的视频属性抓取结束
# 开始BV号为1J54y1R7BB视频属性的抓取
# BV号为1J54y1R7BB的视频属性抓取结束
# 2020-12-19 13:13:19.427693

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-14-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_yinyue_dianyin.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月     96   96    96   96   96   96   96   96    96      96   96    96   96
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月    96   96   96   96   96   96    96
# 2月   100  100  100  100  100  100   100
# 3月   100  100  100  100  100  100   100
# 4月   100  100  100  100  100  100   100
# 5月    99   99   99   99   99   99    99
# 6月   100  100  100  100  100  100   100
# 7月   100  100  100  100  100  100   100
# 8月   100  100  100  100  100  100   100
# 9月   100  100  100  100  100  100   100

# %%
channel_yinyue_dianyin.to_json('channel_yinyue_dianyin.json')
