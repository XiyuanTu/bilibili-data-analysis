# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_yingshi_duanpian=pd.DataFrame(columns=columns)
channel_yingshi_duanpian
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[14]/div/a/span').click()  #选择频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[14]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '影视'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[4]/a').click()  #选择子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[4]/a').text
sub_channel
# Out:
# '短片'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(1,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_yingshi_duanpian.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-17 09:53:00.260856
# <ipython-input-9-1143bc03595d>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-9-1143bc03595d>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-9-1143bc03595d>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为17J411V79D视频属性的抓取
# BV号为17J411V79D的视频属性抓取结束
# <ipython-input-9-1143bc03595d>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为11741167eC视频属性的抓取
# BV号为11741167eC的视频属性抓取结束
# 开始BV号为1GJ411G7mR视频属性的抓取
# BV号为1GJ411G7mR的视频属性抓取结束
# 开始BV号为1iJ411n7aG视频属性的抓取
# BV号为1iJ411n7aG的视频属性抓取结束
# 开始BV号为1XJ411G7c2视频属性的抓取
# BV号为1XJ411G7c2的视频属性抓取结束
# 开始BV号为1zJ411H7PR视频属性的抓取
# BV号为1zJ411H7PR的视频属性抓取结束
# 开始BV号为1UJ411n7wS视频属性的抓取
# BV号为1UJ411n7wS的视频属性抓取结束
# 开始BV号为1XJ411j7A5视频属性的抓取
# BV号为1XJ411j7A5的视频属性抓取结束
# 开始BV号为1H7411k7HW视频属性的抓取
# BV号为1H7411k7HW的视频属性抓取结束
# 开始BV号为147411B7pp视频属性的抓取
# BV号为147411B7pp的视频属性抓取结束
# 开始BV号为1mJ411V7Su视频属性的抓取
# BV号为1mJ411V7Su的视频属性抓取结束
# 开始BV号为1eJ411H7Fy视频属性的抓取
# BV号为1eJ411H7Fy的视频属性抓取结束
# 开始BV号为18J411G7WR视频属性的抓取
# BV号为18J411G7WR的视频属性抓取结束
# 开始BV号为1gJ4117752视频属性的抓取
# BV号为1gJ4117752的视频属性抓取结束
# 开始BV号为1HJ411G7CP视频属性的抓取
# BV号为1HJ411G7CP的视频属性抓取结束
# 开始BV号为1QJ411G7Qd视频属性的抓取
# BV号为1QJ411G7Qd的视频属性抓取结束
# 开始BV号为1m7411B75P视频属性的抓取
# BV号为1m7411B75P的视频属性抓取结束
# 开始BV号为1UJ411p73j视频属性的抓取
# BV号为1UJ411p73j的视频属性抓取结束
# 开始BV号为1jJ41187Y5视频属性的抓取
# BV号为1jJ41187Y5的视频属性抓取结束
# 开始BV号为1G7411k7Ng视频属性的抓取
# BV号为1G7411k7Ng的视频属性抓取结束
# 开始BV号为1S7411B7C7视频属性的抓取
# BV号为1S7411B7C7的视频属性抓取结束
# 开始BV号为1C7411Y7N6视频属性的抓取
# BV号为1C7411Y7N6的视频属性抓取结束
# 开始BV号为1aJ411E7aS视频属性的抓取
# BV号为1aJ411E7aS的视频属性抓取结束
# 开始BV号为1TJ41177hH视频属性的抓取
# BV号为1TJ41177hH的视频属性抓取结束
# 开始BV号为1F7411B7dE视频属性的抓取
# BV号为1F7411B7dE的视频属性抓取结束
# 开始BV号为1uJ411J7jn视频属性的抓取
# BV号为1uJ411J7jn的视频属性抓取结束
# 开始BV号为17J411j7Gx视频属性的抓取
# BV号为17J411j7Gx的视频属性抓取结束
# 开始BV号为1nJ41157Xx视频属性的抓取
# BV号为1nJ41157Xx的视频属性抓取结束
# 开始BV号为1f7411i7By视频属性的抓取
# BV号为1f7411i7By的视频属性抓取结束
# 开始BV号为1AJ411V7WG视频属性的抓取
# BV号为1AJ411V7WG的视频属性抓取结束
# 开始BV号为1p7411B7aa视频属性的抓取
# BV号为1p7411B7aa的视频属性抓取结束
# 开始BV号为1pJ411L7gi视频属性的抓取
# BV号为1pJ411L7gi的视频属性抓取结束
# 开始BV号为1S7411677Y视频属性的抓取
# BV号为1S7411677Y的视频属性抓取结束
# 开始BV号为1P7411i7Vj视频属性的抓取
# BV号为1P7411i7Vj的视频属性抓取结束
# 开始BV号为1D7411Y7Yg视频属性的抓取
# BV号为1D7411Y7Yg的视频属性抓取结束
# 开始BV号为1U7411s7Jq视频属性的抓取
# BV号为1U7411s7Jq的视频属性抓取结束
# 开始BV号为1oJ411G7uD视频属性的抓取
# BV号为1oJ411G7uD的视频属性抓取结束
# 开始BV号为1hJ411j79k视频属性的抓取
# BV号为1hJ411j79k的视频属性抓取结束
# 开始BV号为1Q7411z73J视频属性的抓取
# BV号为1Q7411z73J的视频属性抓取结束
# 开始BV号为1Z7411Y74J视频属性的抓取
# BV号为1Z7411Y74J的视频属性抓取结束
# 开始BV号为1LJ411H7an视频属性的抓取
# 开始BV号为1LJ411H7an视频属性的抓取
# BV号为1LJ411H7an的视频属性抓取结束
# 开始BV号为11J411J7z6视频属性的抓取
# BV号为11J411J7z6的视频属性抓取结束
# 开始BV号为1S7411v7pN视频属性的抓取
# BV号为1S7411v7pN的视频属性抓取结束
# 开始BV号为1y7411Y7S4视频属性的抓取
# BV号为1y7411Y7S4的视频属性抓取结束
# 开始BV号为1kJ411J73w视频属性的抓取
# BV号为1kJ411J73w的视频属性抓取结束
# 开始BV号为1q7411q7RS视频属性的抓取
# BV号为1q7411q7RS的视频属性抓取结束
# 开始BV号为1XJ411G7UQ视频属性的抓取
# BV号为1XJ411G7UQ的视频属性抓取结束
# 开始BV号为1VJ411E7pD视频属性的抓取
# BV号为1VJ411E7pD的视频属性抓取结束
# 开始BV号为117411z7Cj视频属性的抓取
# BV号为117411z7Cj的视频属性抓取结束
# 开始BV号为1NJ411V75J视频属性的抓取
# BV号为1NJ411V75J的视频属性抓取结束
# 开始BV号为1N7411B75k视频属性的抓取
# BV号为1N7411B75k的视频属性抓取结束
# 开始BV号为1x7411i7RU视频属性的抓取
# BV号为1x7411i7RU的视频属性抓取结束
# 开始BV号为1cJ411H7PK视频属性的抓取
# BV号为1cJ411H7PK的视频属性抓取结束
# 开始BV号为1hJ411E7Zm视频属性的抓取
# BV号为1hJ411E7Zm的视频属性抓取结束
# 开始BV号为1VJ411j7ya视频属性的抓取
# BV号为1VJ411j7ya的视频属性抓取结束
# 开始BV号为1hJ411V7tE视频属性的抓取
# BV号为1hJ411V7tE的视频属性抓取结束
# 开始BV号为17J41177n6视频属性的抓取
# BV号为17J41177n6的视频属性抓取结束
# 开始BV号为1K7411z7BF视频属性的抓取
# BV号为1K7411z7BF的视频属性抓取结束
# 开始BV号为1f7411r7Fy视频属性的抓取
# BV号为1f7411r7Fy的视频属性抓取结束
# 开始BV号为1jJ411578J视频属性的抓取
# BV号为1jJ411578J的视频属性抓取结束
# 开始BV号为1M7411r7en视频属性的抓取
# BV号为1M7411r7en的视频属性抓取结束
# 开始BV号为1CJ41177dK视频属性的抓取
# BV号为1CJ41177dK的视频属性抓取结束
# 开始BV号为1B7411a7Bp视频属性的抓取
# BV号为1B7411a7Bp的视频属性抓取结束
# 开始BV号为1EJ411n7T7视频属性的抓取
# BV号为1EJ411n7T7的视频属性抓取结束
# 开始BV号为1C7411B7Ad视频属性的抓取
# BV号为1C7411B7Ad的视频属性抓取结束
# 开始BV号为14J411E76p视频属性的抓取
# BV号为14J411E76p的视频属性抓取结束
# 开始BV号为1CJ411n7xU视频属性的抓取
# BV号为1CJ411n7xU的视频属性抓取结束
# 开始BV号为15J411p7Mj视频属性的抓取
# BV号为15J411p7Mj的视频属性抓取结束
# 开始BV号为1S7411e7ot视频属性的抓取
# BV号为1S7411e7ot的视频属性抓取结束
# 开始BV号为1V7411Y7yw视频属性的抓取
# BV号为1V7411Y7yw的视频属性抓取结束
# 开始BV号为1C7411B7bi视频属性的抓取
# BV号为1C7411B7bi的视频属性抓取结束
# 开始BV号为1m7411k7w4视频属性的抓取
# BV号为1m7411k7w4的视频属性抓取结束
# 开始BV号为1S7411v7Vb视频属性的抓取
# BV号为1S7411v7Vb的视频属性抓取结束
# 开始BV号为1BJ411H7Ai视频属性的抓取
# BV号为1BJ411H7Ai的视频属性抓取结束
# 开始BV号为1iJ411L7HK视频属性的抓取
# BV号为1iJ411L7HK的视频属性抓取结束
# 开始BV号为117411v7C6视频属性的抓取
# BV号为117411v7C6的视频属性抓取结束
# 开始BV号为1W7411k7p8视频属性的抓取
# BV号为1W7411k7p8的视频属性抓取结束
# 开始BV号为16J411j7XE视频属性的抓取
# BV号为16J411j7XE的视频属性抓取结束
# 开始BV号为1RJ411L7f8视频属性的抓取
# BV号为1RJ411L7f8的视频属性抓取结束
# 开始BV号为1pJ411b7BD视频属性的抓取
# BV号为1pJ411b7BD的视频属性抓取结束
# 开始BV号为19J41177tR视频属性的抓取
# BV号为19J41177tR的视频属性抓取结束
# 开始BV号为1gJ411p7Ap视频属性的抓取
# BV号为1gJ411p7Ap的视频属性抓取结束
# 开始BV号为1TJ411H7HE视频属性的抓取
# BV号为1TJ411H7HE的视频属性抓取结束
# 开始BV号为1VJ411n7AE视频属性的抓取
# BV号为1VJ411n7AE的视频属性抓取结束
# 开始BV号为1C7411Y7JD视频属性的抓取
# BV号为1C7411Y7JD的视频属性抓取结束
# 开始BV号为1nJ41177Qt视频属性的抓取
# BV号为1nJ41177Qt的视频属性抓取结束
# 开始BV号为1TJ411H7Xa视频属性的抓取
# BV号为1TJ411H7Xa的视频属性抓取结束
# 开始BV号为147411e7Hi视频属性的抓取
# BV号为147411e7Hi的视频属性抓取结束
# 开始BV号为1z7411z7oy视频属性的抓取
# BV号为1z7411z7oy的视频属性抓取结束
# 开始BV号为1qJ411V7AQ视频属性的抓取
# BV号为1qJ411V7AQ的视频属性抓取结束
# 开始BV号为1w7411B7XL视频属性的抓取
# BV号为1w7411B7XL的视频属性抓取结束
# 开始BV号为19J41177RJ视频属性的抓取
# BV号为19J41177RJ的视频属性抓取结束
# 开始BV号为1i7411a7jg视频属性的抓取
# BV号为1i7411a7jg的视频属性抓取结束
# 开始BV号为1f7411k7et视频属性的抓取
# BV号为1f7411k7et的视频属性抓取结束
# 开始BV号为19J411n7zP视频属性的抓取
# BV号为19J411n7zP的视频属性抓取结束
# 开始BV号为1D7411v75L视频属性的抓取
# BV号为1D7411v75L的视频属性抓取结束
# 开始BV号为15J411G7M1视频属性的抓取
# BV号为15J411G7M1的视频属性抓取结束
# 开始BV号为1N7411e7Uu视频属性的抓取
# BV号为1N7411e7Uu的视频属性抓取结束
# 开始BV号为1BJ411H7mJ视频属性的抓取
# BV号为1BJ411H7mJ的视频属性抓取结束
# 开始BV号为1vJ411G7wk视频属性的抓取
# BV号为1vJ411G7wk的视频属性抓取结束
# 开始BV号为1w7411P7jJ视频属性的抓取
# BV号为1w7411P7jJ的视频属性抓取结束
# 开始BV号为1w741157R8视频属性的抓取
# BV号为1w741157R8的视频属性抓取结束
# 开始BV号为1V7411471S视频属性的抓取
# BV号为1V7411471S的视频属性抓取结束
# 开始BV号为1t7411c7Fv视频属性的抓取
# BV号为1t7411c7Fv的视频属性抓取结束
# 开始BV号为167411J7Zk视频属性的抓取
# BV号为167411J7Zk的视频属性抓取结束
# 开始BV号为1P7411L7a2视频属性的抓取
# BV号为1P7411L7a2的视频属性抓取结束
# 开始BV号为1o7411g71r视频属性的抓取
# BV号为1o7411g71r的视频属性抓取结束
# 开始BV号为1Q7411b7BQ视频属性的抓取
# BV号为1Q7411b7BQ的视频属性抓取结束
# 开始BV号为1t7411F7yF视频属性的抓取
# BV号为1t7411F7yF的视频属性抓取结束
# 开始BV号为1d7411F7Mc视频属性的抓取
# BV号为1d7411F7Mc的视频属性抓取结束
# 开始BV号为1jE411H7XF视频属性的抓取
# BV号为1jE411H7XF的视频属性抓取结束
# 开始BV号为1B7411M7wm视频属性的抓取
# BV号为1B7411M7wm的视频属性抓取结束
# 开始BV号为1x7411E7PA视频属性的抓取
# BV号为1x7411E7PA的视频属性抓取结束
# 开始BV号为1nj411f7S7视频属性的抓取
# BV号为1nj411f7S7的视频属性抓取结束
# <ipython-input-9-1143bc03595d>:190: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1C741137yj视频属性的抓取
# BV号为1C741137yj的视频属性抓取结束
# 开始BV号为1J7411V7k3视频属性的抓取
# BV号为1J7411V7k3的视频属性抓取结束
# 开始BV号为1b7411T74R视频属性的抓取
# BV号为1b7411T74R的视频属性抓取结束
# 开始BV号为1ZE411n7Hi视频属性的抓取
# BV号为1ZE411n7Hi的视频属性抓取结束
# 开始BV号为1Q7411b7Gu视频属性的抓取
# BV号为1Q7411b7Gu的视频属性抓取结束
# 开始BV号为1x7411n7QC视频属性的抓取
# BV号为1x7411n7QC的视频属性抓取结束
# 开始BV号为197411u7RG视频属性的抓取
# BV号为197411u7RG的视频属性抓取结束
# 开始BV号为1Y7411j7ER视频属性的抓取
# 开始BV号为1Y7411j7ER视频属性的抓取
# BV号为1Y7411j7ER的视频属性抓取结束
# 开始BV号为1KE411H7YR视频属性的抓取
# BV号为1KE411H7YR的视频属性抓取结束
# 开始BV号为1e7411W76B视频属性的抓取
# BV号为1e7411W76B的视频属性抓取结束
# 开始BV号为1r7411t7j2视频属性的抓取
# BV号为1r7411t7j2的视频属性抓取结束
# 开始BV号为1aj411f7Dr视频属性的抓取
# BV号为1aj411f7Dr的视频属性抓取结束
# 开始BV号为1K7411J7ZZ视频属性的抓取
# BV号为1K7411J7ZZ的视频属性抓取结束
# 开始BV号为1z7411E7tF视频属性的抓取
# BV号为1z7411E7tF的视频属性抓取结束
# 开始BV号为1b7411g74E视频属性的抓取
# 开始BV号为1b7411g74E视频属性的抓取
# 开始BV号为1b7411g74E视频属性的抓取
# BV号为1b7411g74E的视频属性抓取结束
# 开始BV号为1f7411u7GH视频属性的抓取
# BV号为1f7411u7GH的视频属性抓取结束
# 开始BV号为1s7411t7km视频属性的抓取
# BV号为1s7411t7km的视频属性抓取结束
# 开始BV号为117411K7mg视频属性的抓取
# BV号为117411K7mg的视频属性抓取结束
# 开始BV号为1g741187oU视频属性的抓取
# BV号为1g741187oU的视频属性抓取结束
# 开始BV号为187411w7cJ视频属性的抓取
# BV号为187411w7cJ的视频属性抓取结束
# 开始BV号为1g7411w7Lm视频属性的抓取
# BV号为1g7411w7Lm的视频属性抓取结束
# 开始BV号为1Q7411N7zu视频属性的抓取
# BV号为1Q7411N7zu的视频属性抓取结束
# 开始BV号为1K7411p7t1视频属性的抓取
# BV号为1K7411p7t1的视频属性抓取结束
# 开始BV号为1o7411u7SF视频属性的抓取
# BV号为1o7411u7SF的视频属性抓取结束
# 开始BV号为1V7411s7KP视频属性的抓取
# BV号为1V7411s7KP的视频属性抓取结束
# 开始BV号为1NE411J7py视频属性的抓取
# BV号为1NE411J7py的视频属性抓取结束
# 开始BV号为1s7411x76d视频属性的抓取
# BV号为1s7411x76d的视频属性抓取结束
# 开始BV号为1R7411h7JM视频属性的抓取
# BV号为1R7411h7JM的视频属性抓取结束
# 开始BV号为1M7411P7CL视频属性的抓取
# BV号为1M7411P7CL的视频属性抓取结束
# 开始BV号为1Q7411j7LK视频属性的抓取
# BV号为1Q7411j7LK的视频属性抓取结束
# 开始BV号为1G7411N7k4视频属性的抓取
# BV号为1G7411N7k4的视频属性抓取结束
# 开始BV号为1c7411n7ew视频属性的抓取
# BV号为1c7411n7ew的视频属性抓取结束
# 开始BV号为1s7411x7Mw视频属性的抓取
# BV号为1s7411x7Mw的视频属性抓取结束
# 开始BV号为1x7411j7Nw视频属性的抓取
# BV号为1x7411j7Nw的视频属性抓取结束
# 开始BV号为1K741187RT视频属性的抓取
# BV号为1K741187RT的视频属性抓取结束
# 开始BV号为1F7411W7mF视频属性的抓取
# BV号为1F7411W7mF的视频属性抓取结束
# 开始BV号为1D7411s7ky视频属性的抓取
# BV号为1D7411s7ky的视频属性抓取结束
# 开始BV号为1c7411M7Zf视频属性的抓取
# BV号为1c7411M7Zf的视频属性抓取结束
# 开始BV号为197411s7mK视频属性的抓取
# BV号为197411s7mK的视频属性抓取结束
# 开始BV号为1f7411u7oi视频属性的抓取
# BV号为1f7411u7oi的视频属性抓取结束
# 开始BV号为1U7411c7Qu视频属性的抓取
# BV号为1U7411c7Qu的视频属性抓取结束
# 开始BV号为1J7411L7rF视频属性的抓取
# BV号为1J7411L7rF的视频属性抓取结束
# 开始BV号为1xE411n7cv视频属性的抓取
# BV号为1xE411n7cv的视频属性抓取结束
# 开始BV号为1Z7411j76E视频属性的抓取
# BV号为1Z7411j76E的视频属性抓取结束
# 开始BV号为1R7411w7fu视频属性的抓取
# BV号为1R7411w7fu的视频属性抓取结束
# 开始BV号为1Z7411n7SA视频属性的抓取
# BV号为1Z7411n7SA的视频属性抓取结束
# 开始BV号为1T7411t7V4视频属性的抓取
# BV号为1T7411t7V4的视频属性抓取结束
# 开始BV号为1S7411V7Gr视频属性的抓取
# BV号为1S7411V7Gr的视频属性抓取结束
# 开始BV号为1u741177Jc视频属性的抓取
# BV号为1u741177Jc的视频属性抓取结束
# 开始BV号为1g7411P7J1视频属性的抓取
# BV号为1g7411P7J1的视频属性抓取结束
# 开始BV号为1d741137t5视频属性的抓取
# BV号为1d741137t5的视频属性抓取结束
# 开始BV号为1q7411J7Df视频属性的抓取
# BV号为1q7411J7Df的视频属性抓取结束
# 开始BV号为1E7411s7jR视频属性的抓取
# BV号为1E7411s7jR的视频属性抓取结束
# 开始BV号为1LE411J7ZG视频属性的抓取
# BV号为1LE411J7ZG的视频属性抓取结束
# 开始BV号为1d7411b7xc视频属性的抓取
# BV号为1d7411b7xc的视频属性抓取结束
# 开始BV号为1T7411F7H2视频属性的抓取
# BV号为1T7411F7H2的视频属性抓取结束
# 开始BV号为1X7411K7i9视频属性的抓取
# BV号为1X7411K7i9的视频属性抓取结束
# 开始BV号为1b7411u7ra视频属性的抓取
# BV号为1b7411u7ra的视频属性抓取结束
# 开始BV号为1A741137LH视频属性的抓取
# BV号为1A741137LH的视频属性抓取结束
# 开始BV号为1J7411t78T视频属性的抓取
# BV号为1J7411t78T的视频属性抓取结束
# 开始BV号为1D7411M7C3视频属性的抓取
# BV号为1D7411M7C3的视频属性抓取结束
# 开始BV号为1Y7411H7DA视频属性的抓取
# BV号为1Y7411H7DA的视频属性抓取结束
# 开始BV号为1K741147Ms视频属性的抓取
# BV号为1K741147Ms的视频属性抓取结束
# 开始BV号为1x7411h7Zq视频属性的抓取
# BV号为1x7411h7Zq的视频属性抓取结束
# 开始BV号为1R741147jb视频属性的抓取
# BV号为1R741147jb的视频属性抓取结束
# 开始BV号为1x7411J7oR视频属性的抓取
# BV号为1x7411J7oR的视频属性抓取结束
# 开始BV号为1y7411W7mm视频属性的抓取
# BV号为1y7411W7mm的视频属性抓取结束
# 开始BV号为1W7411375u视频属性的抓取
# BV号为1W7411375u的视频属性抓取结束
# 开始BV号为1W7411b7Xh视频属性的抓取
# BV号为1W7411b7Xh的视频属性抓取结束
# 开始BV号为1VE411J7ii视频属性的抓取
# BV号为1VE411J7ii的视频属性抓取结束
# 开始BV号为19741157Qy视频属性的抓取
# BV号为19741157Qy的视频属性抓取结束
# 开始BV号为1ME411H7aB视频属性的抓取
# BV号为1ME411H7aB的视频属性抓取结束
# 开始BV号为147411L72M视频属性的抓取
# BV号为147411L72M的视频属性抓取结束
# 开始BV号为1G7411w7qa视频属性的抓取
# BV号为1G7411w7qa的视频属性抓取结束
# 开始BV号为117411N7b2视频属性的抓取
# BV号为117411N7b2的视频属性抓取结束
# 开始BV号为1D7411H7q3视频属性的抓取
# BV号为1D7411H7q3的视频属性抓取结束
# 开始BV号为167411s7b5视频属性的抓取
# BV号为167411s7b5的视频属性抓取结束
# 开始BV号为1p7411c7JA视频属性的抓取
# BV号为1p7411c7JA的视频属性抓取结束
# 开始BV号为127411u7vB视频属性的抓取
# BV号为127411u7vB的视频属性抓取结束
# 开始BV号为1p7411u7nr视频属性的抓取
# BV号为1p7411u7nr的视频属性抓取结束
# 开始BV号为1s7411c7bG视频属性的抓取
# BV号为1s7411c7bG的视频属性抓取结束
# 开始BV号为1T7411M7Qg视频属性的抓取
# BV号为1T7411M7Qg的视频属性抓取结束
# 开始BV号为1y7411t7C8视频属性的抓取
# BV号为1y7411t7C8的视频属性抓取结束
# 开始BV号为177411477B视频属性的抓取
# BV号为177411477B的视频属性抓取结束
# 开始BV号为1VE411W7nQ视频属性的抓取
# BV号为1VE411W7nQ的视频属性抓取结束
# 开始BV号为1fE411V7xk视频属性的抓取
# BV号为1fE411V7xk的视频属性抓取结束
# 开始BV号为1qE411M7da视频属性的抓取
# BV号为1qE411M7da的视频属性抓取结束
# 开始BV号为1W7411U7Pj视频属性的抓取
# BV号为1W7411U7Pj的视频属性抓取结束
# 开始BV号为187411m7zb视频属性的抓取
# BV号为187411m7zb的视频属性抓取结束
# 开始BV号为1f741127Dk视频属性的抓取
# BV号为1f741127Dk的视频属性抓取结束
# 开始BV号为1RE411G7AZ视频属性的抓取
# BV号为1RE411G7AZ的视频属性抓取结束
# 开始BV号为1PE41157rG视频属性的抓取
# BV号为1PE41157rG的视频属性抓取结束
# 开始BV号为1z7411D7Qk视频属性的抓取
# BV号为1z7411D7Qk的视频属性抓取结束
# 开始BV号为1pc411h7Ur视频属性的抓取
# BV号为1pc411h7Ur的视频属性抓取结束
# 开始BV号为1dE411A7KG视频属性的抓取
# BV号为1dE411A7KG的视频属性抓取结束
# 开始BV号为13E411A7vT视频属性的抓取
# BV号为13E411A7vT的视频属性抓取结束
# 开始BV号为16K41177ud视频属性的抓取
# BV号为16K41177ud的视频属性抓取结束
# 开始BV号为1uE411s7bN视频属性的抓取
# BV号为1uE411s7bN的视频属性抓取结束
# 开始BV号为1A54y1d7Gb视频属性的抓取
# BV号为1A54y1d7Gb的视频属性抓取结束
# 开始BV号为1Mi4y1n7PU视频属性的抓取
# BV号为1Mi4y1n7PU的视频属性抓取结束
# 开始BV号为1xE411s7M1视频属性的抓取
# BV号为1xE411s7M1的视频属性抓取结束
# 开始BV号为1ME411g7HS视频属性的抓取
# BV号为1ME411g7HS的视频属性抓取结束
# 开始BV号为1vK4y1C7Zw视频属性的抓取
# BV号为1vK4y1C7Zw的视频属性抓取结束
# 开始BV号为11E411x7Qq视频属性的抓取
# BV号为11E411x7Qq的视频属性抓取结束
# 开始BV号为1Pk4y1o7J5视频属性的抓取
# BV号为1Pk4y1o7J5的视频属性抓取结束
# 开始BV号为1pE411p7Fq视频属性的抓取
# BV号为1pE411p7Fq的视频属性抓取结束
# 开始BV号为1HE411M7Gp视频属性的抓取
# BV号为1HE411M7Gp的视频属性抓取结束
# 开始BV号为1H741117Q4视频属性的抓取
# BV号为1H741117Q4的视频属性抓取结束
# 开始BV号为1zV411f7C4视频属性的抓取
# BV号为1zV411f7C4的视频属性抓取结束
# 开始BV号为1oa4y147wh视频属性的抓取
# BV号为1oa4y147wh的视频属性抓取结束
# 开始BV号为1F7411y7ok视频属性的抓取
# BV号为1F7411y7ok的视频属性抓取结束
# 开始BV号为1ME41147eC视频属性的抓取
# BV号为1ME41147eC的视频属性抓取结束
# 开始BV号为14E41137zW视频属性的抓取
# BV号为14E41137zW的视频属性抓取结束
# 开始BV号为1sE411p7Sp视频属性的抓取
# BV号为1sE411p7Sp的视频属性抓取结束
# 开始BV号为187411R7i1视频属性的抓取
# BV号为187411R7i1的视频属性抓取结束
# 开始BV号为1yE411x7b4视频属性的抓取
# BV号为1yE411x7b4的视频属性抓取结束
# 开始BV号为1c7411Z7HC视频属性的抓取
# BV号为1c7411Z7HC的视频属性抓取结束
# 开始BV号为1QE411j7hd视频属性的抓取
# BV号为1QE411j7hd的视频属性抓取结束
# 开始BV号为1JE411u7PC视频属性的抓取
# BV号为1JE411u7PC的视频属性抓取结束
# 开始BV号为17E411F7qh视频属性的抓取
# BV号为17E411F7qh的视频属性抓取结束
# 开始BV号为1YE411T7vn视频属性的抓取
# BV号为1YE411T7vn的视频属性抓取结束
# 开始BV号为1PE411W7Zw视频属性的抓取
# BV号为1PE411W7Zw的视频属性抓取结束
# 开始BV号为1K5411r7AV视频属性的抓取
# BV号为1K5411r7AV的视频属性抓取结束
# 开始BV号为1d7411y7z7视频属性的抓取
# BV号为1d7411y7z7的视频属性抓取结束
# 开始BV号为1ei4y1b7su视频属性的抓取
# BV号为1ei4y1b7su的视频属性抓取结束
# 开始BV号为15E411L7CX视频属性的抓取
# BV号为15E411L7CX的视频属性抓取结束
# 开始BV号为197411m7a1视频属性的抓取
# BV号为197411m7a1的视频属性抓取结束
# 开始BV号为1zE411L75h视频属性的抓取
# BV号为1zE411L75h的视频属性抓取结束
# 开始BV号为1wE411c7UC视频属性的抓取
# BV号为1wE411c7UC的视频属性抓取结束
# 开始BV号为1LE411w7Cx视频属性的抓取
# BV号为1LE411w7Cx的视频属性抓取结束
# 开始BV号为1DE41157c2视频属性的抓取
# BV号为1DE41157c2的视频属性抓取结束
# 开始BV号为1xE41147h6视频属性的抓取
# BV号为1xE41147h6的视频属性抓取结束
# 开始BV号为14z411b775视频属性的抓取
# BV号为14z411b775的视频属性抓取结束
# 开始BV号为11E411L7w1视频属性的抓取
# BV号为11E411L7w1的视频属性抓取结束
# 开始BV号为1qE411j7cw视频属性的抓取
# BV号为1qE411j7cw的视频属性抓取结束
# 开始BV号为1gE41177Ce视频属性的抓取
# BV号为1gE41177Ce的视频属性抓取结束
# 开始BV号为1dE411K7dQ视频属性的抓取
# BV号为1dE411K7dQ的视频属性抓取结束
# 开始BV号为14E411E7HL视频属性的抓取
# BV号为14E411E7HL的视频属性抓取结束
# 开始BV号为1ZE411j78f视频属性的抓取
# BV号为1ZE411j78f的视频属性抓取结束
# 开始BV号为11E411A7Lw视频属性的抓取
# BV号为11E411A7Lw的视频属性抓取结束
# 开始BV号为1T7411U7dC视频属性的抓取
# BV号为1T7411U7dC的视频属性抓取结束
# 开始BV号为1i7411C7aL视频属性的抓取
# BV号为1i7411C7aL的视频属性抓取结束
# 开始BV号为1i7411d7Yd视频属性的抓取
# BV号为1i7411d7Yd的视频属性抓取结束
# 开始BV号为1xE411T7So视频属性的抓取
# BV号为1xE411T7So的视频属性抓取结束
# 开始BV号为1tE411s7TW视频属性的抓取
# BV号为1tE411s7TW的视频属性抓取结束
# 开始BV号为1AE411L7HY视频属性的抓取
# BV号为1AE411L7HY的视频属性抓取结束
# 开始BV号为1Pc411h7fY视频属性的抓取
# BV号为1Pc411h7fY的视频属性抓取结束
# 开始BV号为12E411g7ac视频属性的抓取
# BV号为12E411g7ac的视频属性抓取结束
# 开始BV号为1pE411w7Jn视频属性的抓取
# BV号为1pE411w7Jn的视频属性抓取结束
# 开始BV号为1Zt4y1m7Zm视频属性的抓取
# BV号为1Zt4y1m7Zm的视频属性抓取结束
# 开始BV号为1kE411G7bS视频属性的抓取
# BV号为1kE411G7bS的视频属性抓取结束
# 开始BV号为1AE411K7fx视频属性的抓取
# BV号为1AE411K7fx的视频属性抓取结束
# 开始BV号为1QE411c7XR视频属性的抓取
# BV号为1QE411c7XR的视频属性抓取结束
# 开始BV号为11A41187Br视频属性的抓取
# BV号为11A41187Br的视频属性抓取结束
# 开始BV号为1B7411d7Sg视频属性的抓取
# BV号为1B7411d7Sg的视频属性抓取结束
# 开始BV号为1UE411P7Ra视频属性的抓取
# BV号为1UE411P7Ra的视频属性抓取结束
# 开始BV号为1VT4y157kt视频属性的抓取
# BV号为1VT4y157kt的视频属性抓取结束
# 开始BV号为1NE411p7uq视频属性的抓取
# BV号为1NE411p7uq的视频属性抓取结束
# 开始BV号为1u7411Z7Uf视频属性的抓取
# BV号为1u7411Z7Uf的视频属性抓取结束
# 开始BV号为1hE411c7My视频属性的抓取
# BV号为1hE411c7My的视频属性抓取结束
# 开始BV号为1m741127q5视频属性的抓取
# BV号为1m741127q5的视频属性抓取结束
# 开始BV号为1NE411x7Eg视频属性的抓取
# BV号为1NE411x7Eg的视频属性抓取结束
# 开始BV号为1rE411N7h8视频属性的抓取
# BV号为1rE411N7h8的视频属性抓取结束
# 开始BV号为19E411V7BQ视频属性的抓取
# BV号为19E411V7BQ的视频属性抓取结束
# 开始BV号为11i4y1b7bd视频属性的抓取
# BV号为11i4y1b7bd的视频属性抓取结束
# 开始BV号为1YE411A7CH视频属性的抓取
# BV号为1YE411A7CH的视频属性抓取结束
# 开始BV号为1jC4y14723视频属性的抓取
# BV号为1jC4y14723的视频属性抓取结束
# 开始BV号为1KE411t7J1视频属性的抓取
# BV号为1KE411t7J1的视频属性抓取结束
# 开始BV号为1aE411M71o视频属性的抓取
# BV号为1aE411M71o的视频属性抓取结束
# 开始BV号为1mt4y1m7ji视频属性的抓取
# BV号为1mt4y1m7ji的视频属性抓取结束
# 开始BV号为1L7411U7bc视频属性的抓取
# BV号为1L7411U7bc的视频属性抓取结束
# 开始BV号为1EE411473w视频属性的抓取
# BV号为1EE411473w的视频属性抓取结束
# 开始BV号为1oE411E7xB视频属性的抓取
# BV号为1oE411E7xB的视频属性抓取结束
# 开始BV号为11E411w7wc视频属性的抓取
# BV号为11E411w7wc的视频属性抓取结束
# 开始BV号为1x54y1d7P9视频属性的抓取
# BV号为1x54y1d7P9的视频属性抓取结束
# 开始BV号为1HE411W7e7视频属性的抓取
# BV号为1HE411W7e7的视频属性抓取结束
# 开始BV号为1Z7411d7KY视频属性的抓取
# BV号为1Z7411d7KY的视频属性抓取结束
# 开始BV号为1UE411J7k3视频属性的抓取
# BV号为1UE411J7k3的视频属性抓取结束
# 开始BV号为1iE411J7WN视频属性的抓取
# BV号为1iE411J7WN的视频属性抓取结束
# 开始BV号为1Zz411t7Y6视频属性的抓取
# BV号为1Zz411t7Y6的视频属性抓取结束
# 开始BV号为1E7411f7m5视频属性的抓取
# BV号为1E7411f7m5的视频属性抓取结束
# 开始BV号为1WE411K7Mw视频属性的抓取
# BV号为1WE411K7Mw的视频属性抓取结束
# 开始BV号为1mE411g7jb视频属性的抓取
# BV号为1mE411g7jb的视频属性抓取结束
# 开始BV号为1r7411y7tP视频属性的抓取
# BV号为1r7411y7tP的视频属性抓取结束
# 开始BV号为15Z4y147Ch视频属性的抓取
# BV号为15Z4y147Ch的视频属性抓取结束
# 开始BV号为1MQ4y1T7V8视频属性的抓取
# BV号为1MQ4y1T7V8的视频属性抓取结束
# 开始BV号为1ot4y127mw视频属性的抓取
# BV号为1ot4y127mw的视频属性抓取结束
# 开始BV号为1Vg4y1a7B9视频属性的抓取
# BV号为1Vg4y1a7B9的视频属性抓取结束
# 开始BV号为1Xa4y1x7Rv视频属性的抓取
# BV号为1Xa4y1x7Rv的视频属性抓取结束
# 开始BV号为12Z4y1W7zX视频属性的抓取
# BV号为12Z4y1W7zX的视频属性抓取结束
# 开始BV号为1Ua4y1v7Nk视频属性的抓取
# BV号为1Ua4y1v7Nk的视频属性抓取结束
# 开始BV号为1Ua4y1x7Fm视频属性的抓取
# BV号为1Ua4y1x7Fm的视频属性抓取结束
# 开始BV号为1ei4y187ok视频属性的抓取
# BV号为1ei4y187ok的视频属性抓取结束
# 开始BV号为1Pe411s7EJ视频属性的抓取
# BV号为1Pe411s7EJ的视频属性抓取结束
# 开始BV号为14Z4y1x7xq视频属性的抓取
# BV号为14Z4y1x7xq的视频属性抓取结束
# 开始BV号为1Je41147Vf视频属性的抓取
# BV号为1Je41147Vf的视频属性抓取结束
# 开始BV号为1x64y1u7EN视频属性的抓取
# BV号为1x64y1u7EN的视频属性抓取结束
# 开始BV号为1YK4y1r74K视频属性的抓取
# BV号为1YK4y1r74K的视频属性抓取结束
# 开始BV号为1cQ4y1N7YX视频属性的抓取
# BV号为1cQ4y1N7YX的视频属性抓取结束
# 开始BV号为1dK4y1r7jX视频属性的抓取
# BV号为1dK4y1r7jX的视频属性抓取结束
# 开始BV号为14z411B7p8视频属性的抓取
# BV号为14z411B7p8的视频属性抓取结束
# 开始BV号为1We411s7WF视频属性的抓取
# BV号为1We411s7WF的视频属性抓取结束
# 开始BV号为1UZ4y1j7Te视频属性的抓取
# BV号为1UZ4y1j7Te的视频属性抓取结束
# 开始BV号为1at4y127WH视频属性的抓取
# BV号为1at4y127WH的视频属性抓取结束
# 开始BV号为1b64y1M7hh视频属性的抓取
# BV号为1b64y1M7hh的视频属性抓取结束
# 开始BV号为115411x7V7视频属性的抓取
# BV号为115411x7V7的视频属性抓取结束
# 开始BV号为1vC4y1s7mN视频属性的抓取
# BV号为1vC4y1s7mN的视频属性抓取结束
# 开始BV号为1if4y1S7nv视频属性的抓取
# BV号为1if4y1S7nv的视频属性抓取结束
# 开始BV号为1PT4y1V7e7视频属性的抓取
# BV号为1PT4y1V7e7的视频属性抓取结束
# 开始BV号为1R64y1M7ua视频属性的抓取
# BV号为1R64y1M7ua的视频属性抓取结束
# 开始BV号为1CQ4y1K7Vw视频属性的抓取
# BV号为1CQ4y1K7Vw的视频属性抓取结束
# 开始BV号为1fV411o72C视频属性的抓取
# BV号为1fV411o72C的视频属性抓取结束
# 开始BV号为1mk4y1R7hX视频属性的抓取
# BV号为1mk4y1R7hX的视频属性抓取结束
# 开始BV号为1nt4y1U7UL视频属性的抓取
# BV号为1nt4y1U7UL的视频属性抓取结束
# 开始BV号为18A411473x视频属性的抓取
# BV号为18A411473x的视频属性抓取结束
# 开始BV号为1uz41187Wh视频属性的抓取
# BV号为1uz41187Wh的视频属性抓取结束
# 开始BV号为1yp4y1X7wP视频属性的抓取
# BV号为1yp4y1X7wP的视频属性抓取结束
# 开始BV号为1ft4y117c7视频属性的抓取
# BV号为1ft4y117c7的视频属性抓取结束
# 开始BV号为1VV411d7en视频属性的抓取
# BV号为1VV411d7en的视频属性抓取结束
# 开始BV号为1jV411o7We视频属性的抓取
# BV号为1jV411o7We的视频属性抓取结束
# 开始BV号为1ne411s7gy视频属性的抓取
# BV号为1ne411s7gy的视频属性抓取结束
# 开始BV号为14k4y1r76q视频属性的抓取
# BV号为14k4y1r76q的视频属性抓取结束
# 开始BV号为1qp4y1X78i视频属性的抓取
# BV号为1qp4y1X78i的视频属性抓取结束
# 开始BV号为1Dk4y1r7VM视频属性的抓取
# 开始BV号为1Dk4y1r7VM视频属性的抓取
# BV号为1Dk4y1r7VM的视频属性抓取结束
# 开始BV号为1Bp4y1X7P5视频属性的抓取
# BV号为1Bp4y1X7P5的视频属性抓取结束
# 开始BV号为1Ep4y1y75w视频属性的抓取
# BV号为1Ep4y1y75w的视频属性抓取结束
# 开始BV号为1Ap4y1y7hh视频属性的抓取
# BV号为1Ap4y1y7hh的视频属性抓取结束
# 开始BV号为1ak4y197ni视频属性的抓取
# BV号为1ak4y197ni的视频属性抓取结束
# 开始BV号为1P54y197xp视频属性的抓取
# BV号为1P54y197xp的视频属性抓取结束
# 开始BV号为16i4y187pT视频属性的抓取
# BV号为16i4y187pT的视频属性抓取结束
# 开始BV号为1Bt4y1U7wq视频属性的抓取
# BV号为1Bt4y1U7wq的视频属性抓取结束
# 开始BV号为1AC4y1W7Gt视频属性的抓取
# BV号为1AC4y1W7Gt的视频属性抓取结束
# 开始BV号为1ac411h7We视频属性的抓取
# BV号为1ac411h7We的视频属性抓取结束
# 开始BV号为1jg4y1a7Fv视频属性的抓取
# BV号为1jg4y1a7Fv的视频属性抓取结束
# 开始BV号为1Dk4y197ep视频属性的抓取
# BV号为1Dk4y197ep的视频属性抓取结束
# 开始BV号为1Vk4y1R7Se视频属性的抓取
# BV号为1Vk4y1R7Se的视频属性抓取结束
# 开始BV号为1w54y1d72E视频属性的抓取
# BV号为1w54y1d72E的视频属性抓取结束
# 开始BV号为1Yp4y1C7tf视频属性的抓取
# BV号为1Yp4y1C7tf的视频属性抓取结束
# 开始BV号为1H54y1d7vV视频属性的抓取
# BV号为1H54y1d7vV的视频属性抓取结束
# 开始BV号为1VK41157Ya视频属性的抓取
# BV号为1VK41157Ya的视频属性抓取结束
# 开始BV号为1VC4y1x7UK视频属性的抓取
# BV号为1VC4y1x7UK的视频属性抓取结束
# 开始BV号为1mt4y127kh视频属性的抓取
# BV号为1mt4y127kh的视频属性抓取结束
# 开始BV号为1pQ4y1M7dz视频属性的抓取
# BV号为1pQ4y1M7dz的视频属性抓取结束
# 开始BV号为1bt4y1276v视频属性的抓取
# BV号为1bt4y1276v的视频属性抓取结束
# 开始BV号为1hg4y1z7st视频属性的抓取
# BV号为1hg4y1z7st的视频属性抓取结束
# 开始BV号为17f4y1S7JB视频属性的抓取
# BV号为17f4y1S7JB的视频属性抓取结束
# 开始BV号为1qC4y1s7W4视频属性的抓取
# BV号为1qC4y1s7W4的视频属性抓取结束
# 开始BV号为1S541147u4视频属性的抓取
# BV号为1S541147u4的视频属性抓取结束
# 开始BV号为1cQ4y1N7XQ视频属性的抓取
# BV号为1cQ4y1N7XQ的视频属性抓取结束
# 开始BV号为1c5411t7AS视频属性的抓取
# BV号为1c5411t7AS的视频属性抓取结束
# 开始BV号为17V411o7B1视频属性的抓取
# BV号为17V411o7B1的视频属性抓取结束
# 开始BV号为1fz411b7dQ视频属性的抓取
# BV号为1fz411b7dQ的视频属性抓取结束
# 开始BV号为1oQ4y1P78A视频属性的抓取
# BV号为1oQ4y1P78A的视频属性抓取结束
# 开始BV号为1Ze411x7Bw视频属性的抓取
# BV号为1Ze411x7Bw的视频属性抓取结束
# 开始BV号为1sk4y1R75e视频属性的抓取
# BV号为1sk4y1R75e的视频属性抓取结束
# 开始BV号为1BQ4y1K7Ls视频属性的抓取
# BV号为1BQ4y1K7Ls的视频属性抓取结束
# 开始BV号为1Fe411x7H4视频属性的抓取
# BV号为1Fe411x7H4的视频属性抓取结束
# 开始BV号为1b5411x7uj视频属性的抓取
# BV号为1b5411x7uj的视频属性抓取结束
# 开始BV号为1Gg4y1z7mQ视频属性的抓取
# BV号为1Gg4y1z7mQ的视频属性抓取结束
# 开始BV号为18g4y1z7Vw视频属性的抓取
# BV号为18g4y1z7Vw的视频属性抓取结束
# 开始BV号为1Z64y1u7jr视频属性的抓取
# BV号为1Z64y1u7jr的视频属性抓取结束
# 开始BV号为1RK4y1r7Mj视频属性的抓取
# BV号为1RK4y1r7Mj的视频属性抓取结束
# 开始BV号为1VQ4y1N73s视频属性的抓取
# BV号为1VQ4y1N73s的视频属性抓取结束
# 开始BV号为115411x7c5视频属性的抓取
# BV号为115411x7c5的视频属性抓取结束
# 开始BV号为1jV411d7yz视频属性的抓取
# BV号为1jV411d7yz的视频属性抓取结束
# 开始BV号为1EZ4y1x71G视频属性的抓取
# BV号为1EZ4y1x71G的视频属性抓取结束
# 开始BV号为1KA41187cj视频属性的抓取
# BV号为1KA41187cj的视频属性抓取结束
# 开始BV号为13a4y1t7Qu视频属性的抓取
# BV号为13a4y1t7Qu的视频属性抓取结束
# 开始BV号为1ee411s7RU视频属性的抓取
# BV号为1ee411s7RU的视频属性抓取结束
# 开始BV号为1Qi4y1b7r2视频属性的抓取
# BV号为1Qi4y1b7r2的视频属性抓取结束
# 开始BV号为1dg4y187ms视频属性的抓取
# BV号为1dg4y187ms的视频属性抓取结束
# 开始BV号为1Mz411z7SD视频属性的抓取
# BV号为1Mz411z7SD的视频属性抓取结束
# 开始BV号为195411t7KZ视频属性的抓取
# BV号为195411t7KZ的视频属性抓取结束
# 开始BV号为17a4y1x7PB视频属性的抓取
# BV号为17a4y1x7PB的视频属性抓取结束
# 开始BV号为1ZK411V7gP视频属性的抓取
# BV号为1ZK411V7gP的视频属性抓取结束
# 开始BV号为1zz411b7MG视频属性的抓取
# BV号为1zz411b7MG的视频属性抓取结束
# 开始BV号为1Hi4y1t7UU视频属性的抓取
# BV号为1Hi4y1t7UU的视频属性抓取结束
# 开始BV号为1Dk4y1r7d7视频属性的抓取
# BV号为1Dk4y1r7d7的视频属性抓取结束
# 开始BV号为1VZ4y1x7Dj视频属性的抓取
# BV号为1VZ4y1x7Dj的视频属性抓取结束
# 开始BV号为1QZ4y1j7r2视频属性的抓取
# BV号为1QZ4y1j7r2的视频属性抓取结束
# 开始BV号为1iK411L7JV视频属性的抓取
# BV号为1iK411L7JV的视频属性抓取结束
# 开始BV号为1ig4y1z7Dt视频属性的抓取
# BV号为1ig4y1z7Dt的视频属性抓取结束
# 开始BV号为16K4y1r7Nc视频属性的抓取
# BV号为16K4y1r7Nc的视频属性抓取结束
# 开始BV号为1uC4y1W7LA视频属性的抓取
# BV号为1uC4y1W7LA的视频属性抓取结束
# 开始BV号为1vp4y1Q7fn视频属性的抓取
# BV号为1vp4y1Q7fn的视频属性抓取结束
# 开始BV号为1Sa4y1i73R视频属性的抓取
# BV号为1Sa4y1i73R的视频属性抓取结束
# 开始BV号为1Ue411p7Ti视频属性的抓取
# BV号为1Ue411p7Ti的视频属性抓取结束
# 开始BV号为1QT4y1u7nn视频属性的抓取
# BV号为1QT4y1u7nn的视频属性抓取结束
# 开始BV号为1QC4y1W7VR视频属性的抓取
# BV号为1QC4y1W7VR的视频属性抓取结束
# 开始BV号为1P5411475g视频属性的抓取
# BV号为1P5411475g的视频属性抓取结束
# 开始BV号为1yT4y1g7cH视频属性的抓取
# BV号为1yT4y1g7cH的视频属性抓取结束
# 开始BV号为1Ck4y1k7BV视频属性的抓取
# BV号为1Ck4y1k7BV的视频属性抓取结束
# 开始BV号为1KZ4y1W7Dk视频属性的抓取
# BV号为1KZ4y1W7Dk的视频属性抓取结束
# 开始BV号为1DK4y1b7k7视频属性的抓取
# BV号为1DK4y1b7k7的视频属性抓取结束
# 开始BV号为1ae411p7z7视频属性的抓取
# BV号为1ae411p7z7的视频属性抓取结束
# 开始BV号为1EK4y187UN视频属性的抓取
# BV号为1EK4y187UN的视频属性抓取结束
# 开始BV号为1MQ4y1P7Xg视频属性的抓取
# BV号为1MQ4y1P7Xg的视频属性抓取结束
# 开始BV号为1Zf4y1m7Ma视频属性的抓取
# BV号为1Zf4y1m7Ma的视频属性抓取结束
# 开始BV号为1Rz4y1X7FM视频属性的抓取
# BV号为1Rz4y1X7FM的视频属性抓取结束
# 开始BV号为1wt4y1y7Qj视频属性的抓取
# BV号为1wt4y1y7Qj的视频属性抓取结束
# 开始BV号为1MK411W7fz视频属性的抓取
# BV号为1MK411W7fz的视频属性抓取结束
# 开始BV号为16Z4y1s7ho视频属性的抓取
# BV号为16Z4y1s7ho的视频属性抓取结束
# 开始BV号为1rA411t7DC视频属性的抓取
# BV号为1rA411t7DC的视频属性抓取结束
# 开始BV号为1nT4y1g7gm视频属性的抓取
# BV号为1nT4y1g7gm的视频属性抓取结束
# 开始BV号为1XC4y1H7PJ视频属性的抓取
# BV号为1XC4y1H7PJ的视频属性抓取结束
# 开始BV号为1MA411q7oA视频属性的抓取
# BV号为1MA411q7oA的视频属性抓取结束
# 开始BV号为13Q4y1N7Go视频属性的抓取
# BV号为13Q4y1N7Go的视频属性抓取结束
# 开始BV号为1JV411d7RH视频属性的抓取
# BV号为1JV411d7RH的视频属性抓取结束
# 开始BV号为1RZ4y1s7JM视频属性的抓取
# BV号为1RZ4y1s7JM的视频属性抓取结束
# 开始BV号为1Ci4y1476H视频属性的抓取
# BV号为1Ci4y1476H的视频属性抓取结束
# 开始BV号为1G5411s7B4视频属性的抓取
# BV号为1G5411s7B4的视频属性抓取结束
# 开始BV号为1B54y1Q7Hk视频属性的抓取
# BV号为1B54y1Q7Hk的视频属性抓取结束
# 开始BV号为1jf4y1U7Gs视频属性的抓取
# BV号为1jf4y1U7Gs的视频属性抓取结束
# 开始BV号为165411473P视频属性的抓取
# BV号为165411473P的视频属性抓取结束
# 开始BV号为1cK4y1t7yh视频属性的抓取
# BV号为1cK4y1t7yh的视频属性抓取结束
# 开始BV号为1eV411d7FK视频属性的抓取
# BV号为1eV411d7FK的视频属性抓取结束
# 开始BV号为1ii4y1s7Zf视频属性的抓取
# BV号为1ii4y1s7Zf的视频属性抓取结束
# 开始BV号为1PT4y1g7kQ视频属性的抓取
# BV号为1PT4y1g7kQ的视频属性抓取结束
# 开始BV号为1ta4y1e7bR视频属性的抓取
# BV号为1ta4y1e7bR的视频属性抓取结束
# 开始BV号为14Z4y1p7mZ视频属性的抓取
# BV号为14Z4y1p7mZ的视频属性抓取结束
# 开始BV号为1JT4y1g7fB视频属性的抓取
# BV号为1JT4y1g7fB的视频属性抓取结束
# 开始BV号为1rQ4y1A7E5视频属性的抓取
# BV号为1rQ4y1A7E5的视频属性抓取结束
# 开始BV号为1rT4y137tH视频属性的抓取
# BV号为1rT4y137tH的视频属性抓取结束
# 开始BV号为1Vg4y167zS视频属性的抓取
# BV号为1Vg4y167zS的视频属性抓取结束
# 开始BV号为1cg4y1B7u1视频属性的抓取
# BV号为1cg4y1B7u1的视频属性抓取结束
# 开始BV号为1cK411L7bt视频属性的抓取
# BV号为1cK411L7bt的视频属性抓取结束
# 开始BV号为1Rf4y1m7f2视频属性的抓取
# BV号为1Rf4y1m7f2的视频属性抓取结束
# 开始BV号为1bz4y1d77p视频属性的抓取
# BV号为1bz4y1d77p的视频属性抓取结束
# 开始BV号为1BK4y1t7Vk视频属性的抓取
# BV号为1BK4y1t7Vk的视频属性抓取结束
# 开始BV号为1rz411q7qJ视频属性的抓取
# BV号为1rz411q7qJ的视频属性抓取结束
# 开始BV号为1Ca4y1i7TH视频属性的抓取
# BV号为1Ca4y1i7TH的视频属性抓取结束
# 开始BV号为14p4y1X7rS视频属性的抓取
# BV号为14p4y1X7rS的视频属性抓取结束
# 开始BV号为1Ez4y197wZ视频属性的抓取
# BV号为1Ez4y197wZ的视频属性抓取结束
# 开始BV号为1vg4y1B7WY视频属性的抓取
# BV号为1vg4y1B7WY的视频属性抓取结束
# 开始BV号为14v411z73i视频属性的抓取
# BV号为14v411z73i的视频属性抓取结束
# 开始BV号为1f54y1D7Pf视频属性的抓取
# BV号为1f54y1D7Pf的视频属性抓取结束
# 开始BV号为1c5411x75E视频属性的抓取
# BV号为1c5411x75E的视频属性抓取结束
# 开始BV号为1Jp4y1Q7ma视频属性的抓取
# BV号为1Jp4y1Q7ma的视频属性抓取结束
# 开始BV号为1dz4y1X7hE视频属性的抓取
# BV号为1dz4y1X7hE的视频属性抓取结束
# 开始BV号为1xa4y1e7HR视频属性的抓取
# BV号为1xa4y1e7HR的视频属性抓取结束
# 开始BV号为1MZ4y1W7XF视频属性的抓取
# BV号为1MZ4y1W7XF的视频属性抓取结束
# 开始BV号为1nV411C7j9视频属性的抓取
# BV号为1nV411C7j9的视频属性抓取结束
# 开始BV号为1aT4y1u7j8视频属性的抓取
# BV号为1aT4y1u7j8的视频属性抓取结束
# 开始BV号为1Ag4y1z7VU视频属性的抓取
# BV号为1Ag4y1z7VU的视频属性抓取结束
# 开始BV号为1nA411q7Qh视频属性的抓取
# BV号为1nA411q7Qh的视频属性抓取结束
# 开始BV号为1iK4y1t7pj视频属性的抓取
# BV号为1iK4y1t7pj的视频属性抓取结束
# 开始BV号为1xp4y197i7视频属性的抓取
# BV号为1xp4y197i7的视频属性抓取结束
# 开始BV号为17a4y1i7d2视频属性的抓取
# BV号为17a4y1i7d2的视频属性抓取结束
# 开始BV号为12p4y1Q7Xk视频属性的抓取
# BV号为12p4y1Q7Xk的视频属性抓取结束
# 开始BV号为1Di4y1x7Wb视频属性的抓取
# BV号为1Di4y1x7Wb的视频属性抓取结束
# 开始BV号为1aZ4y1s7yr视频属性的抓取
# BV号为1aZ4y1s7yr的视频属性抓取结束
# 开始BV号为1JK4y1t7NR视频属性的抓取
# BV号为1JK4y1t7NR的视频属性抓取结束
# 开始BV号为1yV411d776视频属性的抓取
# 开始BV号为1yV411d776视频属性的抓取
# BV号为1yV411d776的视频属性抓取结束
# 开始BV号为1HT4y1u7we视频属性的抓取
# BV号为1HT4y1u7we的视频属性抓取结束
# 开始BV号为1yA411t7up视频属性的抓取
# BV号为1yA411t7up的视频属性抓取结束
# 开始BV号为1rk4y1k7ok视频属性的抓取
# BV号为1rk4y1k7ok的视频属性抓取结束
# 开始BV号为1Ep4y197CJ视频属性的抓取
# BV号为1Ep4y197CJ的视频属性抓取结束
# 开始BV号为18C4y1p7g9视频属性的抓取
# BV号为18C4y1p7g9的视频属性抓取结束
# 开始BV号为1vC4y1H7WQ视频属性的抓取
# BV号为1vC4y1H7WQ的视频属性抓取结束
# 开始BV号为1Xz411v7ED视频属性的抓取
# BV号为1Xz411v7ED的视频属性抓取结束
# 开始BV号为1hp4y197Q5视频属性的抓取
# BV号为1hp4y197Q5的视频属性抓取结束
# 开始BV号为1uZ4y1W7xm视频属性的抓取
# BV号为1uZ4y1W7xm的视频属性抓取结束
# 开始BV号为1K64y1M7bj视频属性的抓取
# BV号为1K64y1M7bj的视频属性抓取结束
# 开始BV号为1FT4y1379F视频属性的抓取
# BV号为1FT4y1379F的视频属性抓取结束
# 开始BV号为13T4y1g7JN视频属性的抓取
# BV号为13T4y1g7JN的视频属性抓取结束
# 开始BV号为1gQ4y1P7ab视频属性的抓取
# BV号为1gQ4y1P7ab的视频属性抓取结束
# 开始BV号为1fV411d7o5视频属性的抓取
# BV号为1fV411d7o5的视频属性抓取结束
# 开始BV号为1EK4y187KZ视频属性的抓取
# BV号为1EK4y187KZ的视频属性抓取结束
# 开始BV号为1VQ4y1P7Xa视频属性的抓取
# BV号为1VQ4y1P7Xa的视频属性抓取结束
# 开始BV号为1LQ4y1P73r视频属性的抓取
# BV号为1LQ4y1P73r的视频属性抓取结束
# 开始BV号为1Ki4y147BJ视频属性的抓取
# BV号为1Ki4y147BJ的视频属性抓取结束
# 开始BV号为1yQ4y1N7ue视频属性的抓取
# BV号为1yQ4y1N7ue的视频属性抓取结束
# 开始BV号为1mi4y147pC视频属性的抓取
# BV号为1mi4y147pC的视频属性抓取结束
# 开始BV号为1RZ4y1s7yB视频属性的抓取
# BV号为1RZ4y1s7yB的视频属性抓取结束
# 开始BV号为1Sa4y1e7vj视频属性的抓取
# BV号为1Sa4y1e7vj的视频属性抓取结束
# 开始BV号为1Bk4y1k7yH视频属性的抓取
# BV号为1Bk4y1k7yH的视频属性抓取结束
# 开始BV号为1Wg4y1i79G视频属性的抓取
# BV号为1Wg4y1i79G的视频属性抓取结束
# 开始BV号为1EA411q7U3视频属性的抓取
# BV号为1EA411q7U3的视频属性抓取结束
# 开始BV号为1oC4y1H7hp视频属性的抓取
# BV号为1oC4y1H7hp的视频属性抓取结束
# 开始BV号为1VK411W77o视频属性的抓取
# BV号为1VK411W77o的视频属性抓取结束
# 开始BV号为1xZ4y1s7cd视频属性的抓取
# BV号为1xZ4y1s7cd的视频属性抓取结束
# 开始BV号为1Ma4y1i7LE视频属性的抓取
# BV号为1Ma4y1i7LE的视频属性抓取结束
# 开始BV号为1FK411L7mA视频属性的抓取
# BV号为1FK411L7mA的视频属性抓取结束
# 开始BV号为1QC4y1H78N视频属性的抓取
# BV号为1QC4y1H78N的视频属性抓取结束
# 开始BV号为1yt4y1X75B视频属性的抓取
# BV号为1yt4y1X75B的视频属性抓取结束
# 开始BV号为1Dt4y1X7z4视频属性的抓取
# BV号为1Dt4y1X7z4的视频属性抓取结束
# 开始BV号为1Sv411z7N4视频属性的抓取
# BV号为1Sv411z7N4的视频属性抓取结束
# 开始BV号为1tZ4y1H7o7视频属性的抓取
# BV号为1tZ4y1H7o7的视频属性抓取结束
# 开始BV号为18t4y197iy视频属性的抓取
# BV号为18t4y197iy的视频属性抓取结束
# 开始BV号为1Tg4y1q7eJ视频属性的抓取
# BV号为1Tg4y1q7eJ的视频属性抓取结束
# 开始BV号为1sZ4y1H72Y视频属性的抓取
# BV号为1sZ4y1H72Y的视频属性抓取结束
# 开始BV号为1Ai4y1V7Cq视频属性的抓取
# BV号为1Ai4y1V7Cq的视频属性抓取结束
# 开始BV号为1ip4y1D7DB视频属性的抓取
# BV号为1ip4y1D7DB的视频属性抓取结束
# 开始BV号为1Jz411e77d视频属性的抓取
# BV号为1Jz411e77d的视频属性抓取结束
# 开始BV号为1DA411v787视频属性的抓取
# BV号为1DA411v787的视频属性抓取结束
# 开始BV号为1rD4y1D7Kb视频属性的抓取
# BV号为1rD4y1D7Kb的视频属性抓取结束
# 开始BV号为1wt4y197po视频属性的抓取
# BV号为1wt4y197po的视频属性抓取结束
# 开始BV号为1LA411i78p视频属性的抓取
# BV号为1LA411i78p的视频属性抓取结束
# 开始BV号为1Kg4y1v7H5视频属性的抓取
# BV号为1Kg4y1v7H5的视频属性抓取结束
# 开始BV号为1RA411v7nf视频属性的抓取
# BV号为1RA411v7nf的视频属性抓取结束
# 开始BV号为1zC4y1a77A视频属性的抓取
# BV号为1zC4y1a77A的视频属性抓取结束
# 开始BV号为1dC4y1h78B视频属性的抓取
# BV号为1dC4y1h78B的视频属性抓取结束
# 开始BV号为1Ja4y1v7f7视频属性的抓取
# BV号为1Ja4y1v7f7的视频属性抓取结束
# 开始BV号为1Ug4y1v7oG视频属性的抓取
# BV号为1Ug4y1v7oG的视频属性抓取结束
# 开始BV号为12p4y1S7yL视频属性的抓取
# BV号为12p4y1S7yL的视频属性抓取结束
# 开始BV号为1bV411r7By视频属性的抓取
# BV号为1bV411r7By的视频属性抓取结束
# 开始BV号为1nC4y1a7mf视频属性的抓取
# BV号为1nC4y1a7mf的视频属性抓取结束
# 开始BV号为1Ui4y1G7Pn视频属性的抓取
# BV号为1Ui4y1G7Pn的视频属性抓取结束
# 开始BV号为1vf4y127fH视频属性的抓取
# BV号为1vf4y127fH的视频属性抓取结束
# 开始BV号为15i4y1x7pv视频属性的抓取
# BV号为15i4y1x7pv的视频属性抓取结束
# 开始BV号为1kA411i7dt视频属性的抓取
# BV号为1kA411i7dt的视频属性抓取结束
# 开始BV号为11z4y197Fz视频属性的抓取
# BV号为11z4y197Fz的视频属性抓取结束
# 开始BV号为13a4y1Y7Z8视频属性的抓取
# BV号为13a4y1Y7Z8的视频属性抓取结束
# 开始BV号为195411W7xH视频属性的抓取
# BV号为195411W7xH的视频属性抓取结束
# 开始BV号为1WA411i79Y视频属性的抓取
# BV号为1WA411i79Y的视频属性抓取结束
# 开始BV号为1Sk4y1q7mS视频属性的抓取
# BV号为1Sk4y1q7mS的视频属性抓取结束
# 开始BV号为1gV411k7Z5视频属性的抓取
# BV号为1gV411k7Z5的视频属性抓取结束
# 开始BV号为1NZ4y1H7kE视频属性的抓取
# BV号为1NZ4y1H7kE的视频属性抓取结束
# 开始BV号为1qg4y1i7uZ视频属性的抓取
# BV号为1qg4y1i7uZ的视频属性抓取结束
# 开始BV号为1wK411H7rV视频属性的抓取
# BV号为1wK411H7rV的视频属性抓取结束
# 开始BV号为1mA411v7jh视频属性的抓取
# BV号为1mA411v7jh的视频属性抓取结束
# 开始BV号为1gZ4y1p7WN视频属性的抓取
# BV号为1gZ4y1p7WN的视频属性抓取结束
# 开始BV号为1GA411i7Wm视频属性的抓取
# BV号为1GA411i7Wm的视频属性抓取结束
# 开始BV号为1nA411e7jt视频属性的抓取
# BV号为1nA411e7jt的视频属性抓取结束
# 开始BV号为1wK4y1b76p视频属性的抓取
# BV号为1wK4y1b76p的视频属性抓取结束
# 开始BV号为1aa4y1Y77A视频属性的抓取
# BV号为1aa4y1Y77A的视频属性抓取结束
# 开始BV号为1Zt4y1C7xo视频属性的抓取
# BV号为1Zt4y1C7xo的视频属性抓取结束
# 开始BV号为18T4y1J77R视频属性的抓取
# BV号为18T4y1J77R的视频属性抓取结束
# 开始BV号为1Yp4y1U7xi视频属性的抓取
# BV号为1Yp4y1U7xi的视频属性抓取结束
# 开始BV号为1JA411i7au视频属性的抓取
# BV号为1JA411i7au的视频属性抓取结束
# 开始BV号为1ng4y1q7YM视频属性的抓取
# BV号为1ng4y1q7YM的视频属性抓取结束
# 开始BV号为1WV411r7Fz视频属性的抓取
# BV号为1WV411r7Fz的视频属性抓取结束
# 开始BV号为1B54y1B7Tk视频属性的抓取
# BV号为1B54y1B7Tk的视频属性抓取结束
# 开始BV号为1di4y1s7Jd视频属性的抓取
# BV号为1di4y1s7Jd的视频属性抓取结束
# 开始BV号为1y54y1B7PD视频属性的抓取
# BV号为1y54y1B7PD的视频属性抓取结束
# 开始BV号为1DT4y1E7Q7视频属性的抓取
# BV号为1DT4y1E7Q7的视频属性抓取结束
# 开始BV号为1EA411i7sU视频属性的抓取
# BV号为1EA411i7sU的视频属性抓取结束
# 开始BV号为1B5411W7hf视频属性的抓取
# BV号为1B5411W7hf的视频属性抓取结束
# 开始BV号为1hp4y1D74Y视频属性的抓取
# BV号为1hp4y1D74Y的视频属性抓取结束
# 开始BV号为12k4y167ez视频属性的抓取
# BV号为12k4y167ez的视频属性抓取结束
# 开始BV号为11C4y1a7Jw视频属性的抓取
# BV号为11C4y1a7Jw的视频属性抓取结束
# 开始BV号为1Ek4y1r7Mv视频属性的抓取
# BV号为1Ek4y1r7Mv的视频属性抓取结束
# 开始BV号为1jK4y147QD视频属性的抓取
# BV号为1jK4y147QD的视频属性抓取结束
# 开始BV号为13Z4y1H7tR视频属性的抓取
# BV号为13Z4y1H7tR的视频属性抓取结束
# 开始BV号为1mA411q7ky视频属性的抓取
# BV号为1mA411q7ky的视频属性抓取结束
# 开始BV号为19A411q7kB视频属性的抓取
# BV号为19A411q7kB的视频属性抓取结束
# 开始BV号为1Hv41167Xn视频属性的抓取
# BV号为1Hv41167Xn的视频属性抓取结束
# 开始BV号为18z411e7oF视频属性的抓取
# BV号为18z411e7oF的视频属性抓取结束
# 开始BV号为1rf4y1276f视频属性的抓取
# BV号为1rf4y1276f的视频属性抓取结束
# 开始BV号为1gA411B77V视频属性的抓取
# BV号为1gA411B77V的视频属性抓取结束
# 开始BV号为15t4y1y7ff视频属性的抓取
# BV号为15t4y1y7ff的视频属性抓取结束
# 开始BV号为1Va4y1Y7gZ视频属性的抓取
# BV号为1Va4y1Y7gZ的视频属性抓取结束
# 开始BV号为1EV411k7cF视频属性的抓取
# BV号为1EV411k7cF的视频属性抓取结束
# 开始BV号为1Ei4y1x7kd视频属性的抓取
# BV号为1Ei4y1x7kd的视频属性抓取结束
# 开始BV号为1rz4y1X787视频属性的抓取
# BV号为1rz4y1X787的视频属性抓取结束
# 开始BV号为1NC4y1Y7HH视频属性的抓取
# BV号为1NC4y1Y7HH的视频属性抓取结束
# 开始BV号为1sv41167gV视频属性的抓取
# BV号为1sv41167gV的视频属性抓取结束
# 开始BV号为1QA411q7TL视频属性的抓取
# BV号为1QA411q7TL的视频属性抓取结束
# 开始BV号为1bK411n79E视频属性的抓取
# BV号为1bK411n79E的视频属性抓取结束
# 开始BV号为1kK411p7zF视频属性的抓取
# BV号为1kK411p7zF的视频属性抓取结束
# 开始BV号为1VK4y147YP视频属性的抓取
# BV号为1VK4y147YP的视频属性抓取结束
# 开始BV号为19T4y1E74f视频属性的抓取
# BV号为19T4y1E74f的视频属性抓取结束
# 开始BV号为1tD4y1D7TX视频属性的抓取
# BV号为1tD4y1D7TX的视频属性抓取结束
# 开始BV号为1ik4y1z7nc视频属性的抓取
# BV号为1ik4y1z7nc的视频属性抓取结束
# 开始BV号为1XV411r7V7视频属性的抓取
# BV号为1XV411r7V7的视频属性抓取结束
# 开始BV号为1Lg4y1q7aV视频属性的抓取
# BV号为1Lg4y1q7aV的视频属性抓取结束
# 开始BV号为1Yv41167hx视频属性的抓取
# BV号为1Yv41167hx的视频属性抓取结束
# 开始BV号为13p4y1D7ar视频属性的抓取
# BV号为13p4y1D7ar的视频属性抓取结束
# 开始BV号为175411Y7bh视频属性的抓取
# BV号为175411Y7bh的视频属性抓取结束
# 开始BV号为1hD4y1Q7Sw视频属性的抓取
# BV号为1hD4y1Q7Sw的视频属性抓取结束
# 开始BV号为1BC4y1a7eU视频属性的抓取
# BV号为1BC4y1a7eU的视频属性抓取结束
# 开始BV号为1YV411r7CH视频属性的抓取
# BV号为1YV411r7CH的视频属性抓取结束
# 开始BV号为19A411v7V5视频属性的抓取
# BV号为19A411v7V5的视频属性抓取结束
# 开始BV号为16k4y1q7X1视频属性的抓取
# BV号为16k4y1q7X1的视频属性抓取结束
# 开始BV号为1Df4y1y7FM视频属性的抓取
# BV号为1Df4y1y7FM的视频属性抓取结束
# 开始BV号为1iQ4y1P7eU视频属性的抓取
# BV号为1iQ4y1P7eU的视频属性抓取结束
# 开始BV号为1BQ4y1P7Cf视频属性的抓取
# BV号为1BQ4y1P7Cf的视频属性抓取结束
# 开始BV号为1E5411Y7eZ视频属性的抓取
# BV号为1E5411Y7eZ的视频属性抓取结束
# 开始BV号为1tf4y1174K视频属性的抓取
# BV号为1tf4y1174K的视频属性抓取结束
# 开始BV号为1cf4y117VY视频属性的抓取
# BV号为1cf4y117VY的视频属性抓取结束
# 开始BV号为1uA411B71F视频属性的抓取
# BV号为1uA411B71F的视频属性抓取结束
# 开始BV号为1jK411p7eZ视频属性的抓取
# BV号为1jK411p7eZ的视频属性抓取结束
# 开始BV号为1pz4y197aN视频属性的抓取
# BV号为1pz4y197aN的视频属性抓取结束
# 开始BV号为1cK4y1477G视频属性的抓取
# BV号为1cK4y1477G的视频属性抓取结束
# 开始BV号为1Ri4y1G7jN视频属性的抓取
# BV号为1Ri4y1G7jN的视频属性抓取结束
# 开始BV号为1ND4y1S75u视频属性的抓取
# BV号为1ND4y1S75u的视频属性抓取结束
# 开始BV号为1iz4y1D79R视频属性的抓取
# BV号为1iz4y1D79R的视频属性抓取结束
# 开始BV号为1Q54y1S7P3视频属性的抓取
# BV号为1Q54y1S7P3的视频属性抓取结束
# 开始BV号为13v411q7Vd视频属性的抓取
# BV号为13v411q7Vd的视频属性抓取结束
# 开始BV号为1Ga4y1e7m4视频属性的抓取
# BV号为1Ga4y1e7m4的视频属性抓取结束
# 开始BV号为1Rz411e73d视频属性的抓取
# BV号为1Rz411e73d的视频属性抓取结束
# 开始BV号为1ZV411B7L2视频属性的抓取
# BV号为1ZV411B7L2的视频属性抓取结束
# 开始BV号为1TZ4y1g7pC视频属性的抓取
# BV号为1TZ4y1g7pC的视频属性抓取结束
# 开始BV号为1gT4y1E7gu视频属性的抓取
# BV号为1gT4y1E7gu的视频属性抓取结束
# 开始BV号为1sg4y1v7zF视频属性的抓取
# BV号为1sg4y1v7zF的视频属性抓取结束
# 开始BV号为1hK411J7bb视频属性的抓取
# BV号为1hK411J7bb的视频属性抓取结束
# 开始BV号为1ai4y1V748视频属性的抓取
# BV号为1ai4y1V748的视频属性抓取结束
# 开始BV号为1uv411z7jA视频属性的抓取
# BV号为1uv411z7jA的视频属性抓取结束
# 开始BV号为18C4y1b7Hz视频属性的抓取
# BV号为18C4y1b7Hz的视频属性抓取结束
# 开始BV号为18i4y1V7bJ视频属性的抓取
# BV号为18i4y1V7bJ的视频属性抓取结束
# 开始BV号为1bf4y1R773视频属性的抓取
# BV号为1bf4y1R773的视频属性抓取结束
# 开始BV号为1F54y1S7CP视频属性的抓取
# BV号为1F54y1S7CP的视频属性抓取结束
# 开始BV号为1Xf4y1X7GQ视频属性的抓取
# BV号为1Xf4y1X7GQ的视频属性抓取结束
# 开始BV号为1BV41167Kn视频属性的抓取
# BV号为1BV41167Kn的视频属性抓取结束
# 开始BV号为1Ci4y1377J视频属性的抓取
# BV号为1Ci4y1377J的视频属性抓取结束
# 开始BV号为1oC4y187cA视频属性的抓取
# BV号为1oC4y187cA的视频属性抓取结束
# 开始BV号为1Wk4y1m71Q视频属性的抓取
# BV号为1Wk4y1m71Q的视频属性抓取结束
# 开始BV号为1qp4y1q7iz视频属性的抓取
# BV号为1qp4y1q7iz的视频属性抓取结束
# 开始BV号为1gK4y1x7BN视频属性的抓取
# BV号为1gK4y1x7BN的视频属性抓取结束
# 开始BV号为16C4y1b7mw视频属性的抓取
# BV号为16C4y1b7mw的视频属性抓取结束
# 开始BV号为1n54y1q737视频属性的抓取
# BV号为1n54y1q737的视频属性抓取结束
# 开始BV号为1zf4y1R7Na视频属性的抓取
# BV号为1zf4y1R7Na的视频属性抓取结束
# 开始BV号为1Mp4y1q7FD视频属性的抓取
# BV号为1Mp4y1q7FD的视频属性抓取结束
# 开始BV号为12k4y1q78p视频属性的抓取
# BV号为12k4y1q78p的视频属性抓取结束
# 开始BV号为1Jt4y1X7mL视频属性的抓取
# BV号为1Jt4y1X7mL的视频属性抓取结束
# 开始BV号为14A411v7YR视频属性的抓取
# BV号为14A411v7YR的视频属性抓取结束
# 开始BV号为1Dp4y1i7s1视频属性的抓取
# BV号为1Dp4y1i7s1的视频属性抓取结束
# 开始BV号为1G54y1q7mn视频属性的抓取
# BV号为1G54y1q7mn的视频属性抓取结束
# 开始BV号为1rh411o7C8视频属性的抓取
# BV号为1rh411o7C8的视频属性抓取结束
# 开始BV号为1ka4y1E7Dg视频属性的抓取
# BV号为1ka4y1E7Dg的视频属性抓取结束
# 开始BV号为1Nt4y1X7QQ视频属性的抓取
# BV号为1Nt4y1X7QQ的视频属性抓取结束
# 开始BV号为1z54y1v7Cy视频属性的抓取
# BV号为1z54y1v7Cy的视频属性抓取结束
# 开始BV号为1Mk4y1B7b8视频属性的抓取
# BV号为1Mk4y1B7b8的视频属性抓取结束
# 开始BV号为1j5411a7ik视频属性的抓取
# BV号为1j5411a7ik的视频属性抓取结束
# 开始BV号为1xh411o7pB视频属性的抓取
# BV号为1xh411o7pB的视频属性抓取结束
# 开始BV号为19a4y1h7Ez视频属性的抓取
# BV号为19a4y1h7Ez的视频属性抓取结束
# 开始BV号为1vC4y1h7cg视频属性的抓取
# BV号为1vC4y1h7cg的视频属性抓取结束
# 开始BV号为1Sf4y1R7re视频属性的抓取
# BV号为1Sf4y1R7re的视频属性抓取结束
# 开始BV号为1GC4y1b7eb视频属性的抓取
# BV号为1GC4y1b7eb的视频属性抓取结束
# 开始BV号为1DK411J7cV视频属性的抓取
# BV号为1DK411J7cV的视频属性抓取结束
# 开始BV号为1sT4y1E7dR视频属性的抓取
# BV号为1sT4y1E7dR的视频属性抓取结束
# 开始BV号为1CA411e71y视频属性的抓取
# BV号为1CA411e71y的视频属性抓取结束
# 开始BV号为14p4y1S7yr视频属性的抓取
# BV号为14p4y1S7yr的视频属性抓取结束
# 开始BV号为1Pt4y1X7Gt视频属性的抓取
# BV号为1Pt4y1X7Gt的视频属性抓取结束
# 开始BV号为17Z4y1M7Ht视频属性的抓取
# BV号为17Z4y1M7Ht的视频属性抓取结束
# 开始BV号为1YK4y1471H视频属性的抓取
# BV号为1YK4y1471H的视频属性抓取结束
# 开始BV号为1Xi4y137Ef视频属性的抓取
# BV号为1Xi4y137Ef的视频属性抓取结束
# 开始BV号为1gZ4y1u7aj视频属性的抓取
# BV号为1gZ4y1u7aj的视频属性抓取结束
# 开始BV号为1zz411v7zc视频属性的抓取
# BV号为1zz411v7zc的视频属性抓取结束
# 开始BV号为1rz4y1D7pX视频属性的抓取
# BV号为1rz4y1D7pX的视频属性抓取结束
# 开始BV号为1N5411a7fz视频属性的抓取
# BV号为1N5411a7fz的视频属性抓取结束
# 开始BV号为1sp4y1S7AZ视频属性的抓取
# BV号为1sp4y1S7AZ的视频属性抓取结束
# 开始BV号为1Ea4y1a7Bd视频属性的抓取
# BV号为1Ea4y1a7Bd的视频属性抓取结束
# 开始BV号为1GZ4y1p7RG视频属性的抓取
# BV号为1GZ4y1p7RG的视频属性抓取结束
# 开始BV号为1FC4y1h7uK视频属性的抓取
# BV号为1FC4y1h7uK的视频属性抓取结束
# 开始BV号为15t4y1D724视频属性的抓取
# BV号为15t4y1D724的视频属性抓取结束
# 开始BV号为1Yz4y1X7T9视频属性的抓取
# BV号为1Yz4y1X7T9的视频属性抓取结束
# 开始BV号为1vk4y1m7FH视频属性的抓取
# BV号为1vk4y1m7FH的视频属性抓取结束
# 开始BV号为1og4y1v7jA视频属性的抓取
# BV号为1og4y1v7jA的视频属性抓取结束
# 开始BV号为1ev411q7gA视频属性的抓取
# BV号为1ev411q7gA的视频属性抓取结束
# 开始BV号为11p4y1i7sZ视频属性的抓取
# BV号为11p4y1i7sZ的视频属性抓取结束
# 开始BV号为1Ci4y1G7Xw视频属性的抓取
# BV号为1Ci4y1G7Xw的视频属性抓取结束
# 开始BV号为1x5411a77T视频属性的抓取
# BV号为1x5411a77T的视频属性抓取结束
# 开始BV号为1wk4y167aJ视频属性的抓取
# BV号为1wk4y167aJ的视频属性抓取结束
# 开始BV号为1ig4y1v7fv视频属性的抓取
# BV号为1ig4y1v7fv的视频属性抓取结束
# 开始BV号为1Wh411o75g视频属性的抓取
# BV号为1Wh411o75g的视频属性抓取结束
# 开始BV号为1Ap4y1S7H4视频属性的抓取
# BV号为1Ap4y1S7H4的视频属性抓取结束
# 开始BV号为1va4y1a7j6视频属性的抓取
# BV号为1va4y1a7j6的视频属性抓取结束
# 开始BV号为1Qz4y1D7Mw视频属性的抓取
# BV号为1Qz4y1D7Mw的视频属性抓取结束
# 开始BV号为155411Y7YJ视频属性的抓取
# BV号为155411Y7YJ的视频属性抓取结束
# 开始BV号为1Z5411Y7nW视频属性的抓取
# BV号为1Z5411Y7nW的视频属性抓取结束
# 开始BV号为1cZ4y1p7Wb视频属性的抓取
# BV号为1cZ4y1p7Wb的视频属性抓取结束
# 开始BV号为1rK4y1e74K视频属性的抓取
# BV号为1rK4y1e74K的视频属性抓取结束
# 开始BV号为1jD4y1D7if视频属性的抓取
# BV号为1jD4y1D7if的视频属性抓取结束
# 开始BV号为1zA411e7Li视频属性的抓取
# BV号为1zA411e7Li的视频属性抓取结束
# 开始BV号为1yC4y1h7cj视频属性的抓取
# BV号为1yC4y1h7cj的视频属性抓取结束
# 开始BV号为1PZ4y1g7Dr视频属性的抓取
# BV号为1PZ4y1g7Dr的视频属性抓取结束
# 开始BV号为1wD4y1D7ni视频属性的抓取
# BV号为1wD4y1D7ni的视频属性抓取结束
# 开始BV号为19T4y1J7uc视频属性的抓取
# BV号为19T4y1J7uc的视频属性抓取结束
# 开始BV号为18K4y1s7yF视频属性的抓取
# BV号为18K4y1s7yF的视频属性抓取结束
# 开始BV号为1C5411a7k3视频属性的抓取
# BV号为1C5411a7k3的视频属性抓取结束
# 开始BV号为17A411v7mj视频属性的抓取
# BV号为17A411v7mj的视频属性抓取结束
# 开始BV号为1R54y1v7cT视频属性的抓取
# BV号为1R54y1v7cT的视频属性抓取结束
# 开始BV号为1zk4y1B7TL视频属性的抓取
# BV号为1zk4y1B7TL的视频属性抓取结束
# 开始BV号为19a4y1Y7cd视频属性的抓取
# BV号为19a4y1Y7cd的视频属性抓取结束
# 开始BV号为1RV411B7MT视频属性的抓取
# BV号为1RV411B7MT的视频属性抓取结束
# 开始BV号为1Ag4y1i7k8视频属性的抓取
# BV号为1Ag4y1i7k8的视频属性抓取结束
# 开始BV号为1tp4y1S7t1视频属性的抓取
# BV号为1tp4y1S7t1的视频属性抓取结束
# 开始BV号为135411Y7R7视频属性的抓取
# BV号为135411Y7R7的视频属性抓取结束
# 开始BV号为1jf4y1174e视频属性的抓取
# BV号为1jf4y1174e的视频属性抓取结束
# 开始BV号为1MT4y1j71P视频属性的抓取
# BV号为1MT4y1j71P的视频属性抓取结束
# 开始BV号为1hf4y1176b视频属性的抓取
# BV号为1hf4y1176b的视频属性抓取结束
# 开始BV号为1iZ4y1u7cy视频属性的抓取
# BV号为1iZ4y1u7cy的视频属性抓取结束
# 开始BV号为1Wz4y1D7p4视频属性的抓取
# BV号为1Wz4y1D7p4的视频属性抓取结束
# 开始BV号为1GK411T77V视频属性的抓取
# BV号为1GK411T77V的视频属性抓取结束
# 开始BV号为1Zk4y1m7mL视频属性的抓取
# BV号为1Zk4y1m7mL的视频属性抓取结束
# 开始BV号为1XZ4y1T7S8视频属性的抓取
# BV号为1XZ4y1T7S8的视频属性抓取结束
# 开始BV号为12Z4y1M7Ci视频属性的抓取
# BV号为12Z4y1M7Ci的视频属性抓取结束
# 开始BV号为15i4y1g7h4视频属性的抓取
# BV号为15i4y1g7h4的视频属性抓取结束
# 开始BV号为13h411Z7ju视频属性的抓取
# BV号为13h411Z7ju的视频属性抓取结束
# 开始BV号为1654y127eE视频属性的抓取
# BV号为1654y127eE的视频属性抓取结束
# 开始BV号为1Tt4y1Q7Bo视频属性的抓取
# BV号为1Tt4y1Q7Bo的视频属性抓取结束
# 开始BV号为1dk4y1179B视频属性的抓取
# BV号为1dk4y1179B的视频属性抓取结束
# 开始BV号为1RA411Y7G4视频属性的抓取
# BV号为1RA411Y7G4的视频属性抓取结束
# 开始BV号为1CV411z71v视频属性的抓取
# BV号为1CV411z71v的视频属性抓取结束
# 开始BV号为1cv41117eD视频属性的抓取
# BV号为1cv41117eD的视频属性抓取结束
# 开始BV号为1kp4y1v7Xc视频属性的抓取
# BV号为1kp4y1v7Xc的视频属性抓取结束
# 开始BV号为12D4y127wt视频属性的抓取
# BV号为12D4y127wt的视频属性抓取结束
# 开始BV号为1F5411h7P5视频属性的抓取
# BV号为1F5411h7P5的视频属性抓取结束
# 开始BV号为1Rf4y1Q7e4视频属性的抓取
# BV号为1Rf4y1Q7e4的视频属性抓取结束
# 开始BV号为1wp4y1i7Ei视频属性的抓取
# BV号为1wp4y1i7Ei的视频属性抓取结束
# 开始BV号为19f4y1Q7e2视频属性的抓取
# 开始BV号为19f4y1Q7e2视频属性的抓取
# BV号为19f4y1Q7e2的视频属性抓取结束
# 开始BV号为1u54y1i7Av视频属性的抓取
# BV号为1u54y1i7Av的视频属性抓取结束
# 开始BV号为12k4y1m7DZ视频属性的抓取
# BV号为12k4y1m7DZ的视频属性抓取结束
# 开始BV号为1up4y1v7qN视频属性的抓取
# BV号为1up4y1v7qN的视频属性抓取结束
# 开始BV号为15K411n7S2视频属性的抓取
# BV号为15K411n7S2的视频属性抓取结束
# 开始BV号为1UA411Y7CL视频属性的抓取
# BV号为1UA411Y7CL的视频属性抓取结束
# 开始BV号为1tK4y1v7E9视频属性的抓取
# BV号为1tK4y1v7E9的视频属性抓取结束
# 开始BV号为1zV411z7gS视频属性的抓取
# BV号为1zV411z7gS的视频属性抓取结束
# 开始BV号为1Qa4y1J7Hd视频属性的抓取
# BV号为1Qa4y1J7Hd的视频属性抓取结束
# 开始BV号为1Jp4y1q7C9视频属性的抓取
# BV号为1Jp4y1q7C9的视频属性抓取结束
# 开始BV号为1fa4y1E73G视频属性的抓取
# BV号为1fa4y1E73G的视频属性抓取结束
# 开始BV号为1Xk4y11719视频属性的抓取
# BV号为1Xk4y11719的视频属性抓取结束
# 开始BV号为1K54y1i7XF视频属性的抓取
# BV号为1K54y1i7XF的视频属性抓取结束
# 开始BV号为1UA411Y7pA视频属性的抓取
# BV号为1UA411Y7pA的视频属性抓取结束
# 开始BV号为1ci4y1u7Cp视频属性的抓取
# BV号为1ci4y1u7Cp的视频属性抓取结束
# 开始BV号为15f4y197rn视频属性的抓取
# BV号为15f4y197rn的视频属性抓取结束
# 开始BV号为1VA411Y7hN视频属性的抓取
# BV号为1VA411Y7hN的视频属性抓取结束
# 开始BV号为1TZ4y1T7uM视频属性的抓取
# BV号为1TZ4y1T7uM的视频属性抓取结束
# 开始BV号为1n54y1U7ge视频属性的抓取
# BV号为1n54y1U7ge的视频属性抓取结束
# 开始BV号为1BV411U7q1视频属性的抓取
# BV号为1BV411U7q1的视频属性抓取结束
# 开始BV号为1Qi4y1u7Z4视频属性的抓取
# BV号为1Qi4y1u7Z4的视频属性抓取结束
# 开始BV号为1Xi4y1u72g视频属性的抓取
# BV号为1Xi4y1u72g的视频属性抓取结束
# 开始BV号为1K64y1c7iJ视频属性的抓取
# BV号为1K64y1c7iJ的视频属性抓取结束
# 开始BV号为1xz4y1f72g视频属性的抓取
# BV号为1xz4y1f72g的视频属性抓取结束
# 开始BV号为1bz4y1Q7RV视频属性的抓取
# BV号为1bz4y1Q7RV的视频属性抓取结束
# 开始BV号为1p5411h7dj视频属性的抓取
# BV号为1p5411h7dj的视频属性抓取结束
# 开始BV号为15C4y1t71G视频属性的抓取
# BV号为15C4y1t71G的视频属性抓取结束
# 开始BV号为1df4y1Q7n3视频属性的抓取
# BV号为1df4y1Q7n3的视频属性抓取结束
# 开始BV号为1nv41117p6视频属性的抓取
# BV号为1nv41117p6的视频属性抓取结束
# 开始BV号为125411a7pq视频属性的抓取
# BV号为125411a7pq的视频属性抓取结束
# 开始BV号为1oT4y1j7bC视频属性的抓取
# BV号为1oT4y1j7bC的视频属性抓取结束
# 开始BV号为1Nf4y197bR视频属性的抓取
# BV号为1Nf4y197bR的视频属性抓取结束
# 开始BV号为1Z54y1S7rG视频属性的抓取
# BV号为1Z54y1S7rG的视频属性抓取结束
# 开始BV号为1w64y1c7t9视频属性的抓取
# BV号为1w64y1c7t9的视频属性抓取结束
# 开始BV号为1UV411U7Np视频属性的抓取
# BV号为1UV411U7Np的视频属性抓取结束
# 开始BV号为1W64y1c7G9视频属性的抓取
# BV号为1W64y1c7G9的视频属性抓取结束
# 开始BV号为1pa4y177Zx视频属性的抓取
# BV号为1pa4y177Zx的视频属性抓取结束
# 开始BV号为1LZ4y1K73p视频属性的抓取
# BV号为1LZ4y1K73p的视频属性抓取结束
# 开始BV号为1yh411d7a9视频属性的抓取
# BV号为1yh411d7a9的视频属性抓取结束
# 开始BV号为1j5411h7n1视频属性的抓取
# BV号为1j5411h7n1的视频属性抓取结束
# 开始BV号为13A411e7c4视频属性的抓取
# BV号为13A411e7c4的视频属性抓取结束
# 开始BV号为1pZ4y1K7kz视频属性的抓取
# BV号为1pZ4y1K7kz的视频属性抓取结束
# 开始BV号为1mK4y1v7g3视频属性的抓取
# BV号为1mK4y1v7g3的视频属性抓取结束
# 开始BV号为1d54y1S7bw视频属性的抓取
# BV号为1d54y1S7bw的视频属性抓取结束
# 开始BV号为1q64y1F7pp视频属性的抓取
# BV号为1q64y1F7pp的视频属性抓取结束
# 开始BV号为1fh411d7uf视频属性的抓取
# BV号为1fh411d7uf的视频属性抓取结束
# 开始BV号为1oC4y1b7XB视频属性的抓取
# BV号为1oC4y1b7XB的视频属性抓取结束
# 开始BV号为1yK4y1v7Yh视频属性的抓取
# BV号为1yK4y1v7Yh的视频属性抓取结束
# 开始BV号为1uD4y1m7oy视频属性的抓取
# BV号为1uD4y1m7oy的视频属性抓取结束
# 开始BV号为1Bp4y1q7a4视频属性的抓取
# BV号为1Bp4y1q7a4的视频属性抓取结束
# 开始BV号为1Q54y1m784视频属性的抓取
# BV号为1Q54y1m784的视频属性抓取结束
# 开始BV号为1d54y1m7By视频属性的抓取
# BV号为1d54y1m7By的视频属性抓取结束
# 开始BV号为1Ra4y177U3视频属性的抓取
# BV号为1Ra4y177U3的视频属性抓取结束
# 开始BV号为1P54y1i7im视频属性的抓取
# BV号为1P54y1i7im的视频属性抓取结束
# 开始BV号为1sp4y1v76e视频属性的抓取
# BV号为1sp4y1v76e的视频属性抓取结束
# 开始BV号为1q54y1m75G视频属性的抓取
# BV号为1q54y1m75G的视频属性抓取结束
# 开始BV号为1U5411a7W4视频属性的抓取
# BV号为1U5411a7W4的视频属性抓取结束
# 开始BV号为1BK411T7kR视频属性的抓取
# BV号为1BK411T7kR的视频属性抓取结束
# 开始BV号为1Di4y1u77R视频属性的抓取
# BV号为1Di4y1u77R的视频属性抓取结束
# 开始BV号为1kk4y1275C视频属性的抓取
# BV号为1kk4y1275C的视频属性抓取结束
# 开始BV号为1fD4y1m73f视频属性的抓取
# BV号为1fD4y1m73f的视频属性抓取结束
# 开始BV号为1sZ4y1M77r视频属性的抓取
# BV号为1sZ4y1M77r的视频属性抓取结束
# 开始BV号为1hp4y1v75c视频属性的抓取
# BV号为1hp4y1v75c的视频属性抓取结束
# 开始BV号为1WC4y1t7Vm视频属性的抓取
# BV号为1WC4y1t7Vm的视频属性抓取结束
# 开始BV号为1uk4y1m7cW视频属性的抓取
# BV号为1uk4y1m7cW的视频属性抓取结束
# 开始BV号为1tA411n7CC视频属性的抓取
# BV号为1tA411n7CC的视频属性抓取结束
# 开始BV号为1MA411n7vq视频属性的抓取
# BV号为1MA411n7vq的视频属性抓取结束
# 开始BV号为1ok4y117rB视频属性的抓取
# BV号为1ok4y117rB的视频属性抓取结束
# 开始BV号为1Ha4y177Hd视频属性的抓取
# BV号为1Ha4y177Hd的视频属性抓取结束
# 开始BV号为1a54y1i7mU视频属性的抓取
# BV号为1a54y1i7mU的视频属性抓取结束
# 开始BV号为1bT4y1L7S4视频属性的抓取
# BV号为1bT4y1L7S4的视频属性抓取结束
# 开始BV号为1pk4y1m7g1视频属性的抓取
# BV号为1pk4y1m7g1的视频属性抓取结束
# 开始BV号为1Vt4y1S7if视频属性的抓取
# BV号为1Vt4y1S7if的视频属性抓取结束
# 开始BV号为13a4y177po视频属性的抓取
# BV号为13a4y177po的视频属性抓取结束
# 开始BV号为1gD4y1U7aT视频属性的抓取
# BV号为1gD4y1U7aT的视频属性抓取结束
# 开始BV号为1ap4y1q71y视频属性的抓取
# BV号为1ap4y1q71y的视频属性抓取结束
# 开始BV号为1rv411v7Bq视频属性的抓取
# BV号为1rv411v7Bq的视频属性抓取结束
# 开始BV号为1pt4y1S7wK视频属性的抓取
# BV号为1pt4y1S7wK的视频属性抓取结束
# 开始BV号为1AA411n7Qg视频属性的抓取
# BV号为1AA411n7Qg的视频属性抓取结束
# 开始BV号为1Xf4y1X7A7视频属性的抓取
# BV号为1Xf4y1X7A7的视频属性抓取结束
# 开始BV号为1rf4y197Qz视频属性的抓取
# BV号为1rf4y197Qz的视频属性抓取结束
# 开始BV号为1DK411T7nR视频属性的抓取
# BV号为1DK411T7nR的视频属性抓取结束
# 开始BV号为1nV411U79q视频属性的抓取
# BV号为1nV411U79q的视频属性抓取结束
# 开始BV号为1F54y127Vc视频属性的抓取
# BV号为1F54y127Vc的视频属性抓取结束
# 开始BV号为1S54y1179d视频属性的抓取
# BV号为1S54y1179d的视频属性抓取结束
# 开始BV号为1Hh411X71b视频属性的抓取
# BV号为1Hh411X71b的视频属性抓取结束
# 开始BV号为1Kp4y1e7UR视频属性的抓取
# BV号为1Kp4y1e7UR的视频属性抓取结束
# 开始BV号为1854y1m7CT视频属性的抓取
# BV号为1854y1m7CT的视频属性抓取结束
# 开始BV号为1Wi4y1M7Qj视频属性的抓取
# BV号为1Wi4y1M7Qj的视频属性抓取结束
# 开始BV号为1kA411n7rD视频属性的抓取
# BV号为1kA411n7rD的视频属性抓取结束
# 开始BV号为1MZ4y1N791视频属性的抓取
# BV号为1MZ4y1N791的视频属性抓取结束
# 开始BV号为1L54y1v7dS视频属性的抓取
# BV号为1L54y1v7dS的视频属性抓取结束
# 开始BV号为1ty4y1y7YW视频属性的抓取
# BV号为1ty4y1y7YW的视频属性抓取结束
# 开始BV号为1Zh41197wj视频属性的抓取
# BV号为1Zh41197wj的视频属性抓取结束
# 开始BV号为1ov411172F视频属性的抓取
# BV号为1ov411172F的视频属性抓取结束
# 开始BV号为1dk4y1k7fy视频属性的抓取
# BV号为1dk4y1k7fy的视频属性抓取结束
# 开始BV号为17h411R7uB视频属性的抓取
# BV号为17h411R7uB的视频属性抓取结束
# 开始BV号为1nv41117p5视频属性的抓取
# BV号为1nv41117p5的视频属性抓取结束
# 开始BV号为1Sa4y1j7TK视频属性的抓取
# BV号为1Sa4y1j7TK的视频属性抓取结束
# 开始BV号为1TK4y1a7tM视频属性的抓取
# BV号为1TK4y1a7tM的视频属性抓取结束
# 开始BV号为1hV41117St视频属性的抓取
# BV号为1hV41117St的视频属性抓取结束
# 开始BV号为1xa4y1j7k3视频属性的抓取
# BV号为1xa4y1j7k3的视频属性抓取结束
# 开始BV号为1Si4y1M7ZG视频属性的抓取
# BV号为1Si4y1M7ZG的视频属性抓取结束
# 开始BV号为11K411K71X视频属性的抓取
# BV号为11K411K71X的视频属性抓取结束
# 开始BV号为1u54y1m75X视频属性的抓取
# BV号为1u54y1m75X的视频属性抓取结束
# 开始BV号为1XT4y1w7xk视频属性的抓取
# BV号为1XT4y1w7xk的视频属性抓取结束
# 开始BV号为1WT4y1c7RS视频属性的抓取
# BV号为1WT4y1c7RS的视频属性抓取结束
# 开始BV号为1pi4y1u7DT视频属性的抓取
# BV号为1pi4y1u7DT的视频属性抓取结束
# 开始BV号为1fZ4y1P7Np视频属性的抓取
# BV号为1fZ4y1P7Np的视频属性抓取结束
# 开始BV号为1qk4y1y7GK视频属性的抓取
# BV号为1qk4y1y7GK的视频属性抓取结束
# 开始BV号为1pt4y1q77J视频属性的抓取
# BV号为1pt4y1q77J的视频属性抓取结束
# 开始BV号为1GA411J7Yx视频属性的抓取
# BV号为1GA411J7Yx的视频属性抓取结束
# 开始BV号为1Zk4y1y7w2视频属性的抓取
# BV号为1Zk4y1y7w2的视频属性抓取结束
# 开始BV号为1T54y1m7KB视频属性的抓取
# BV号为1T54y1m7KB的视频属性抓取结束
# 开始BV号为1Qa4y157Fq视频属性的抓取
# BV号为1Qa4y157Fq的视频属性抓取结束
# 开始BV号为1Jh411R7Xx视频属性的抓取
# BV号为1Jh411R7Xx的视频属性抓取结束
# 开始BV号为1cf4y1D7ht视频属性的抓取
# BV号为1cf4y1D7ht的视频属性抓取结束
# 开始BV号为1FK4y1a754视频属性的抓取
# BV号为1FK4y1a754的视频属性抓取结束
# 开始BV号为19A411E73M视频属性的抓取
# BV号为19A411E73M的视频属性抓取结束
# 开始BV号为1Uf4y1Q7k6视频属性的抓取
# BV号为1Uf4y1Q7k6的视频属性抓取结束
# 开始BV号为1Jy4y1y7AM视频属性的抓取
# BV号为1Jy4y1y7AM的视频属性抓取结束
# 开始BV号为1Lk4y1C7SF视频属性的抓取
# BV号为1Lk4y1C7SF的视频属性抓取结束
# 开始BV号为1Uv41117GD视频属性的抓取
# BV号为1Uv41117GD的视频属性抓取结束
# 开始BV号为1Y54y1C7Bi视频属性的抓取
# 开始BV号为1Y54y1C7Bi视频属性的抓取
# BV号为1Y54y1C7Bi的视频属性抓取结束
# 开始BV号为1dk4y1k75o视频属性的抓取
# BV号为1dk4y1k75o的视频属性抓取结束
# 开始BV号为1Si4y177YZ视频属性的抓取
# BV号为1Si4y177YZ的视频属性抓取结束
# 开始BV号为1mf4y1Q7T2视频属性的抓取
# BV号为1mf4y1Q7T2的视频属性抓取结束
# 开始BV号为1Xv41117ew视频属性的抓取
# BV号为1Xv41117ew的视频属性抓取结束
# 开始BV号为1th411X7z2视频属性的抓取
# BV号为1th411X7z2的视频属性抓取结束
# 开始BV号为15k4y1y7Dd视频属性的抓取
# BV号为15k4y1y7Dd的视频属性抓取结束
# 开始BV号为1p54y1v7xy视频属性的抓取
# BV号为1p54y1v7xy的视频属性抓取结束
# 开始BV号为1j64y1F7nV视频属性的抓取
# BV号为1j64y1F7nV的视频属性抓取结束
# 开始BV号为1mk4y1k74a视频属性的抓取
# BV号为1mk4y1k74a的视频属性抓取结束
# 开始BV号为1Ki4y1E73r视频属性的抓取
# BV号为1Ki4y1E73r的视频属性抓取结束
# 开始BV号为1gV411S7VS视频属性的抓取
# BV号为1gV411S7VS的视频属性抓取结束
# 开始BV号为1KK4y1a72P视频属性的抓取
# BV号为1KK4y1a72P的视频属性抓取结束
# 开始BV号为1o54y1y7XB视频属性的抓取
# BV号为1o54y1y7XB的视频属性抓取结束
# 开始BV号为1nt4y1q7PU视频属性的抓取
# BV号为1nt4y1q7PU的视频属性抓取结束
# 开始BV号为1dp4y1e7Cn视频属性的抓取
# BV号为1dp4y1e7Cn的视频属性抓取结束
# 开始BV号为1rD4y1o7vh视频属性的抓取
# BV号为1rD4y1o7vh的视频属性抓取结束
# 开始BV号为1CK411N7R7视频属性的抓取
# BV号为1CK411N7R7的视频属性抓取结束
# 开始BV号为1E54y1y7qj视频属性的抓取
# BV号为1E54y1y7qj的视频属性抓取结束
# 开始BV号为1np4y1e7BU视频属性的抓取
# BV号为1np4y1e7BU的视频属性抓取结束
# 开始BV号为1Ry4y1k75u视频属性的抓取
# BV号为1Ry4y1k75u的视频属性抓取结束
# 开始BV号为14v411C7NQ视频属性的抓取
# BV号为14v411C7NQ的视频属性抓取结束
# 开始BV号为1Vy4y1y7A1视频属性的抓取
# BV号为1Vy4y1y7A1的视频属性抓取结束
# 开始BV号为1UT4y1A7sQ视频属性的抓取
# BV号为1UT4y1A7sQ的视频属性抓取结束
# 开始BV号为1gi4y1u729视频属性的抓取
# BV号为1gi4y1u729的视频属性抓取结束
# 开始BV号为1di4y177SP视频属性的抓取
# BV号为1di4y177SP的视频属性抓取结束
# 开始BV号为1Sp4y1e7rm视频属性的抓取
# BV号为1Sp4y1e7rm的视频属性抓取结束
# 开始BV号为1T5411b7F5视频属性的抓取
# BV号为1T5411b7F5的视频属性抓取结束
# 开始BV号为1FV411U78a视频属性的抓取
# BV号为1FV411U78a的视频属性抓取结束
# 开始BV号为1X54y1279o视频属性的抓取
# BV号为1X54y1279o的视频属性抓取结束
# 开始BV号为1Xi4y177kF视频属性的抓取
# BV号为1Xi4y177kF的视频属性抓取结束
# 开始BV号为1Ff4y1D7Qr视频属性的抓取
# BV号为1Ff4y1D7Qr的视频属性抓取结束
# 开始BV号为1EA411J7x1视频属性的抓取
# BV号为1EA411J7x1的视频属性抓取结束
# 开始BV号为1bi4y1E7kJ视频属性的抓取
# BV号为1bi4y1E7kJ的视频属性抓取结束
# 开始BV号为1G54y1y7Qs视频属性的抓取
# BV号为1G54y1y7Qs的视频属性抓取结束
# 开始BV号为135411b7MT视频属性的抓取
# BV号为135411b7MT的视频属性抓取结束
# 开始BV号为1KK4y1Y7dH视频属性的抓取
# BV号为1KK4y1Y7dH的视频属性抓取结束
# 开始BV号为1Xk4y1y7u4视频属性的抓取
# BV号为1Xk4y1y7u4的视频属性抓取结束
# 开始BV号为17Z4y1N7Ju视频属性的抓取
# BV号为17Z4y1N7Ju的视频属性抓取结束
# 开始BV号为1u64y1F7k5视频属性的抓取
# BV号为1u64y1F7k5的视频属性抓取结束
# 开始BV号为1Rk4y1k7KS视频属性的抓取
# BV号为1Rk4y1k7KS的视频属性抓取结束
# 开始BV号为1C5411b7jj视频属性的抓取
# BV号为1C5411b7jj的视频属性抓取结束
# 开始BV号为1GK4y1a7T7视频属性的抓取
# BV号为1GK4y1a7T7的视频属性抓取结束
# 开始BV号为19A411E7W1视频属性的抓取
# BV号为19A411E7W1的视频属性抓取结束
# 开始BV号为1F54y127rf视频属性的抓取
# BV号为1F54y127rf的视频属性抓取结束
# 开始BV号为1La4y1E7DF视频属性的抓取
# BV号为1La4y1E7DF的视频属性抓取结束
# 开始BV号为1hf4y1Q7BU视频属性的抓取
# BV号为1hf4y1Q7BU的视频属性抓取结束
# 开始BV号为1Ui4y1M7uU视频属性的抓取
# BV号为1Ui4y1M7uU的视频属性抓取结束
# 开始BV号为1Jz4y1Z7Dq视频属性的抓取
# BV号为1Jz4y1Z7Dq的视频属性抓取结束
# 开始BV号为17A411J77i视频属性的抓取
# BV号为17A411J77i的视频属性抓取结束
# 开始BV号为1Xi4y177W6视频属性的抓取
# BV号为1Xi4y177W6的视频属性抓取结束
# 开始BV号为1Tf4y1X75D视频属性的抓取
# BV号为1Tf4y1X75D的视频属性抓取结束
# 开始BV号为1gh411R7Np视频属性的抓取
# BV号为1gh411R7Np的视频属性抓取结束
# 开始BV号为1u54y1m7Qy视频属性的抓取
# BV号为1u54y1m7Qy的视频属性抓取结束
# 开始BV号为1iv411C7f6视频属性的抓取
# BV号为1iv411C7f6的视频属性抓取结束
# 开始BV号为1fi4y177XJ视频属性的抓取
# BV号为1fi4y177XJ的视频属性抓取结束
# 开始BV号为1154y1C75w视频属性的抓取
# BV号为1154y1C75w的视频属性抓取结束
# 开始BV号为1EA411n7yc视频属性的抓取
# BV号为1EA411n7yc的视频属性抓取结束
# 开始BV号为14z4y1Z77s视频属性的抓取
# BV号为14z4y1Z77s的视频属性抓取结束
# 开始BV号为1Sf4y1Q7DR视频属性的抓取
# BV号为1Sf4y1Q7DR的视频属性抓取结束
# 开始BV号为1hT4y1F7MB视频属性的抓取
# BV号为1hT4y1F7MB的视频属性抓取结束
# 开始BV号为1LK411N7g9视频属性的抓取
# BV号为1LK411N7g9的视频属性抓取结束
# 开始BV号为1Lv411y7Jd视频属性的抓取
# BV号为1Lv411y7Jd的视频属性抓取结束
# 开始BV号为1YD4y1R7h8视频属性的抓取
# BV号为1YD4y1R7h8的视频属性抓取结束
# 开始BV号为1HK411A7BU视频属性的抓取
# BV号为1HK411A7BU的视频属性抓取结束
# 开始BV号为1DA411L7Wr视频属性的抓取
# BV号为1DA411L7Wr的视频属性抓取结束
# 开始BV号为13a4y1s7zU视频属性的抓取
# BV号为13a4y1s7zU的视频属性抓取结束
# 开始BV号为1of4y1D7hA视频属性的抓取
# BV号为1of4y1D7hA的视频属性抓取结束
# 开始BV号为1kV411y7Lv视频属性的抓取
# BV号为1kV411y7Lv的视频属性抓取结束
# 开始BV号为1wr4y1w7f9视频属性的抓取
# BV号为1wr4y1w7f9的视频属性抓取结束
# 开始BV号为1rf4y1B7yA视频属性的抓取
# BV号为1rf4y1B7yA的视频属性抓取结束
# 开始BV号为1Jp4y1k72d视频属性的抓取
# BV号为1Jp4y1k72d的视频属性抓取结束
# 开始BV号为1VD4y197To视频属性的抓取
# BV号为1VD4y197To的视频属性抓取结束
# 开始BV号为1oa4y157Qy视频属性的抓取
# BV号为1oa4y157Qy的视频属性抓取结束
# 开始BV号为1p5411j74U视频属性的抓取
# BV号为1p5411j74U的视频属性抓取结束
# 开始BV号为1tt4y1i76V视频属性的抓取
# BV号为1tt4y1i76V的视频属性抓取结束
# 开始BV号为1oh411X7Qv视频属性的抓取
# 开始BV号为1oh411X7Qv视频属性的抓取
# 开始BV号为1oh411X7Qv视频属性的抓取
# BV号为1oh411X7Qv的视频属性抓取结束
# 开始BV号为1rD4y1R7wf视频属性的抓取
# BV号为1rD4y1R7wf的视频属性抓取结束
# 开始BV号为1MT4y1w7N3视频属性的抓取
# BV号为1MT4y1w7N3的视频属性抓取结束
# 开始BV号为1pV411y7Fr视频属性的抓取
# BV号为1pV411y7Fr的视频属性抓取结束
# 开始BV号为19K4y1h75U视频属性的抓取
# BV号为19K4y1h75U的视频属性抓取结束
# 开始BV号为1QK4y187XW视频属性的抓取
# BV号为1QK4y187XW的视频属性抓取结束
# 开始BV号为1o541157YX视频属性的抓取
# BV号为1o541157YX的视频属性抓取结束
# 开始BV号为1MA411E7jT视频属性的抓取
# BV号为1MA411E7jT的视频属性抓取结束
# 开始BV号为1g541177uY视频属性的抓取
# BV号为1g541177uY的视频属性抓取结束
# 开始BV号为1Rr4y1c73y视频属性的抓取
# BV号为1Rr4y1c73y的视频属性抓取结束
# 开始BV号为1ZT4y1c768视频属性的抓取
# BV号为1ZT4y1c768的视频属性抓取结束
# 开始BV号为1Xa411w7wW视频属性的抓取
# BV号为1Xa411w7wW的视频属性抓取结束
# 开始BV号为1s54y1R7EE视频属性的抓取
# BV号为1s54y1R7EE的视频属性抓取结束
# 开始BV号为1ip4y1k7XJ视频属性的抓取
# BV号为1ip4y1k7XJ的视频属性抓取结束
# 开始BV号为1hp4y1Y7Ek视频属性的抓取
# BV号为1hp4y1Y7Ek的视频属性抓取结束
# 开始BV号为1eD4y1d7CW视频属性的抓取
# BV号为1eD4y1d7CW的视频属性抓取结束
# 开始BV号为1th41197rC视频属性的抓取
# BV号为1th41197rC的视频属性抓取结束
# 开始BV号为1tz4y1o7BX视频属性的抓取
# BV号为1tz4y1o7BX的视频属性抓取结束
# 开始BV号为1Q54y1k7Lx视频属性的抓取
# BV号为1Q54y1k7Lx的视频属性抓取结束
# 开始BV号为19z4y1Z7mp视频属性的抓取
# BV号为19z4y1Z7mp的视频属性抓取结束
# 开始BV号为1454y1C7Cj视频属性的抓取
# BV号为1454y1C7Cj的视频属性抓取结束
# 开始BV号为1u54y1C777视频属性的抓取
# BV号为1u54y1C777的视频属性抓取结束
# 开始BV号为1mK411A7rE视频属性的抓取
# BV号为1mK411A7rE的视频属性抓取结束
# 开始BV号为1Ri4y1E7uM视频属性的抓取
# BV号为1Ri4y1E7uM的视频属性抓取结束
# 开始BV号为1o5411j7gp视频属性的抓取
# BV号为1o5411j7gp的视频属性抓取结束
# 开始BV号为17i4y1L7Xk视频属性的抓取
# BV号为17i4y1L7Xk的视频属性抓取结束
# 开始BV号为1MT4y1F7fZ视频属性的抓取
# BV号为1MT4y1F7fZ的视频属性抓取结束
# 开始BV号为1nZ4y157My视频属性的抓取
# BV号为1nZ4y157My的视频属性抓取结束
# 开始BV号为1HZ4y1L72i视频属性的抓取
# BV号为1HZ4y1L72i的视频属性抓取结束
# 开始BV号为1uf4y1B7mQ视频属性的抓取
# BV号为1uf4y1B7mQ的视频属性抓取结束
# 开始BV号为18t4y1i7AD视频属性的抓取
# BV号为18t4y1i7AD的视频属性抓取结束
# 开始BV号为1PZ4y1V7ck视频属性的抓取
# BV号为1PZ4y1V7ck的视频属性抓取结束
# 开始BV号为1vi4y1j7ea视频属性的抓取
# BV号为1vi4y1j7ea的视频属性抓取结束
# 开始BV号为15D4y1d7ey视频属性的抓取
# BV号为15D4y1d7ey的视频属性抓取结束
# 开始BV号为1oZ4y1G79o视频属性的抓取
# BV号为1oZ4y1G79o的视频属性抓取结束
# 开始BV号为1xv411k7BQ视频属性的抓取
# BV号为1xv411k7BQ的视频属性抓取结束
# 开始BV号为1dh411X7yU视频属性的抓取
# BV号为1dh411X7yU的视频属性抓取结束
# 开始BV号为1SA411L78W视频属性的抓取
# BV号为1SA411L78W的视频属性抓取结束
# 开始BV号为1Pv411k7xq视频属性的抓取
# BV号为1Pv411k7xq的视频属性抓取结束
# 开始BV号为17p4y1k7BE视频属性的抓取
# BV号为17p4y1k7BE的视频属性抓取结束
# 开始BV号为15t4y1i7tD视频属性的抓取
# BV号为15t4y1i7tD的视频属性抓取结束
# 开始BV号为1a5411L77w视频属性的抓取
# BV号为1a5411L77w的视频属性抓取结束
# 开始BV号为1ff4y1q7qE视频属性的抓取
# BV号为1ff4y1q7qE的视频属性抓取结束
# 开始BV号为12k4y1C7h5视频属性的抓取
# BV号为12k4y1C7h5的视频属性抓取结束
# 开始BV号为15541177Kx视频属性的抓取
# BV号为15541177Kx的视频属性抓取结束
# 开始BV号为1Lp4y1Y7bc视频属性的抓取
# BV号为1Lp4y1Y7bc的视频属性抓取结束
# 开始BV号为1JZ4y1L77S视频属性的抓取
# BV号为1JZ4y1L77S的视频属性抓取结束
# 开始BV号为1az4y1o7K3视频属性的抓取
# BV号为1az4y1o7K3的视频属性抓取结束
# 开始BV号为1tv411k753视频属性的抓取
# BV号为1tv411k753的视频属性抓取结束
# 开始BV号为1nh41197W8视频属性的抓取
# BV号为1nh41197W8的视频属性抓取结束
# 开始BV号为1Wh41197Dd视频属性的抓取
# BV号为1Wh41197Dd的视频属性抓取结束
# 开始BV号为1Pv411k7HT视频属性的抓取
# BV号为1Pv411k7HT的视频属性抓取结束
# 开始BV号为1tA41177Am视频属性的抓取
# BV号为1tA41177Am的视频属性抓取结束
# 开始BV号为1vt4y1v7FM视频属性的抓取
# BV号为1vt4y1v7FM的视频属性抓取结束
# 开始BV号为1YK4y1h7gG视频属性的抓取
# BV号为1YK4y1h7gG的视频属性抓取结束
# 开始BV号为1HT4y1F74C视频属性的抓取
# BV号为1HT4y1F74C的视频属性抓取结束
# 开始BV号为1Fi4y177iE视频属性的抓取
# BV号为1Fi4y177iE的视频属性抓取结束
# 开始BV号为1rv411k7Yj视频属性的抓取
# BV号为1rv411k7Yj的视频属性抓取结束
# 开始BV号为1YV411y7ZJ视频属性的抓取
# BV号为1YV411y7ZJ的视频属性抓取结束
# 开始BV号为1ba4y1L7nP视频属性的抓取
# BV号为1ba4y1L7nP的视频属性抓取结束
# 开始BV号为1Tt4y1e7ux视频属性的抓取
# BV号为1Tt4y1e7ux的视频属性抓取结束
# 开始BV号为1hv411k76G视频属性的抓取
# BV号为1hv411k76G的视频属性抓取结束
# 开始BV号为1ED4y197ZS视频属性的抓取
# BV号为1ED4y197ZS的视频属性抓取结束
# 开始BV号为1Q54y1k7MZ视频属性的抓取
# BV号为1Q54y1k7MZ的视频属性抓取结束
# 开始BV号为1Rr4y1c7Kn视频属性的抓取
# BV号为1Rr4y1c7Kn的视频属性抓取结束
# 开始BV号为1wV411279R视频属性的抓取
# BV号为1wV411279R的视频属性抓取结束
# 开始BV号为1fy4y167Xs视频属性的抓取
# BV号为1fy4y167Xs的视频属性抓取结束
# 开始BV号为1WK4y1h7iY视频属性的抓取
# BV号为1WK4y1h7iY的视频属性抓取结束
# 开始BV号为1gv411C7SL视频属性的抓取
# BV号为1gv411C7SL的视频属性抓取结束
# 开始BV号为1854y1R75g视频属性的抓取
# BV号为1854y1R75g的视频属性抓取结束
# 开始BV号为13v411C7dN视频属性的抓取
# BV号为13v411C7dN的视频属性抓取结束
# 开始BV号为1fy4y167bC视频属性的抓取
# BV号为1fy4y167bC的视频属性抓取结束
# 开始BV号为1yy4y1r7M2视频属性的抓取
# BV号为1yy4y1r7M2的视频属性抓取结束
# 开始BV号为1gZ4y1L7H4视频属性的抓取
# BV号为1gZ4y1L7H4的视频属性抓取结束
# 开始BV号为1Z541157mv视频属性的抓取
# BV号为1Z541157mv的视频属性抓取结束
# 开始BV号为1Ky4y1r78L视频属性的抓取
# BV号为1Ky4y1r78L的视频属性抓取结束
# 开始BV号为1cf4y1z7yR视频属性的抓取
# BV号为1cf4y1z7yR的视频属性抓取结束
# 开始BV号为1Pf4y1z7oj视频属性的抓取
# BV号为1Pf4y1z7oj的视频属性抓取结束
# 开始BV号为15t4y1i7zw视频属性的抓取
# BV号为15t4y1i7zw的视频属性抓取结束
# 开始BV号为1vy4y1C7xN视频属性的抓取
# BV号为1vy4y1C7xN的视频属性抓取结束
# 开始BV号为16A41177N4视频属性的抓取
# BV号为16A41177N4的视频属性抓取结束
# 开始BV号为1ok4y1C7HM视频属性的抓取
# BV号为1ok4y1C7HM的视频属性抓取结束
# 开始BV号为1Ez4y1o7er视频属性的抓取
# BV号为1Ez4y1o7er的视频属性抓取结束
# 开始BV号为1Pa4y1s7Mf视频属性的抓取
# BV号为1Pa4y1s7Mf的视频属性抓取结束
# 2020-12-17 19:54:58.805283

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-14-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_yingshi_duanpian.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月     98   98    98   98   98   98   98   98    98      98   98    98   98
# 3月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月   100  100  100  100  100  100   100
# 2月    98   98   98   98   98   98    98
# 3月   100  100  100  100  100  100   100
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月   100  100  100  100  100  100   100
# 7月   100  100  100  100  100  100   100
# 8月   100  100  100  100  100  100   100
# 9月   100  100  100  100  100  100   100

# %%
channel_yingshi_duanpian.to_json('channel_yingshi_duanpian.json')

# %%
pd.set_option('display.max_rows', None)

# %%
channel_youxi_danji[channel_youxi_danji['时间']=='4月']
# Out:
#             时间            作者名  作者类型      粉丝数   投稿数  \
# 1h54y1d7Qq  4月            鹤吱菌  个人认证   191.3万    81
# 1L64y1M7Dp  4月            老番茄  个人认证  1360.1万   348
# 18K41157Tu  4月            老番茄  个人认证  1360.1万   348
# 1PT4y1G7ME  4月            老番茄  个人认证  1360.1万   348
# 1S54y197uX  4月           徐大虾咯  个人认证   570.1万   224
# 1ti4y1t7YM  4月            老番茄  个人认证  1360.1万   348
# 1Ai4y1b7ET  4月            敖厂长  个人认证   735.1万   348
# 1Up4y1C7PB  4月        丢鹏D1uuu     无     8.4万    20
# 1wi4y187bu  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 13t4y1U7kQ  4月           徐大虾咯  个人认证   570.1万   224
# 1fe411x7FA  4月         芦苇草的梦想  个人认证    29.3万   726
# 1LA411b7Dt  4月      LexBurner  个人认证   929.6万   383
# 1Ji4y1t7T9  4月            沧桑丸  个人认证    86.6万    57
# 1Lz411z72u  4月           徐大虾咯  个人认证   570.1万   224
# 13T4y1G7WT  4月          逗比的雀巢  个人认证   242.3万    82
# 1T54y197DH  4月           徐大虾咯  个人认证   570.1万   224
# 1Va4y147fH  4月            鹤吱菌  个人认证   191.3万    81
# 1tt4y127yy  4月           小潮院长  个人认证   481.6万   266
# 16T4y1g7RY  4月         吉儿一范伦婷  个人认证    67.6万    79
# 1754y197Da  4月            敖厂长  个人认证   735.1万   348
# 1hK41157M3  4月           花少北丶  个人认证   491.9万   173
# 1Rk4y197kw  4月       3DM游戏网官方  机构认证    13.5万  2822
# 1ST4y1G7E1  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1H54y1d76B  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1Sz411B7P4  4月          游汐_YX  个人认证    12.9万    98
# 1CT4y1g7Ya  4月    育碧中国Ubisoft  机构认证    64.5万  1211
# 12T4y1G7AZ  4月          与山0v0  个人认证   208.5万   557
# 1b5411x79t  4月        东尼ookii  个人认证   331.7万   166
# 1hA411h7Ky  4月          与山0v0  个人认证   208.5万   557
# 1KJ411e7nN                              如何提高审美？审美有无高低？审美是谁建立？  数码  摄影摄像  普通视频
# ...                                                       ...  ..   ...   ...
# 1cr4y1w7ig              困难重重，国家天文签约摄影师遭遇拍摄滑铁卢？！【华为Mate40 Pro】  数码  摄影摄像  活动作品
# 1Y5411L7TW                     富士X-S10相机测试——2020 apsc画幅性价比最强机  数码  摄影摄像  活动作品
# 1c541177hR      索尼（Sony）12-24mm F2.8 GM深度评测，只要买得起，它就是一颗完美的镜头！  数码  摄影摄像  普通视频
# 1DA41177UY                            大疆旗舰稳定器 - DJI RS 2 正式登场  数码  摄影摄像  普通视频
# 1rA411776p                 让我非常失望的佳能M50 Mark II（来自一代老用户的真实心声）  数码  摄影摄像  普通视频
#
#             ...                                                 标签   视频长度  \
# 1gJ411n7hp  ...                         [摄影, 数码, 摄影摄像, 数码, 教程, 器材]  01:44
# 1tJ41187w6  ...  [相机, 数码, 摄影摄像, 数码, 何同学, 啊吗粽, 宝剑嫂, 自媒体, 大祥哥, 体验...  30:03
# 1i7411i7yA  ...        [摄影, 短片, 数码, 摄影摄像, 数码, 创意, YOUTUBE, 镜头, 老蛙]  04:51
# 1gJ411G7Cs  ...           [摄影, 数码, 摄影摄像, 数码, VLOG, 后期, 教程, ps, 器材]  06:01
# 1KJ411e7nN  ...  [校园vlog, 相机, 脱口秀, 摄影, 公开课, vlog, 科普, 数码, 摄影摄像,...  27:08
# ...         ...                                                ...    ...
# 1cr4y1w7ig  ...  [vlog, 数码, 摄影摄像, 数码, 放心购机攻略, 敦煌, 星空, 手机摄影, 华为,...  11:43
# 1Y5411L7TW  ...  [相机, 摄影, 数码, 摄影摄像, 数码, 数码玩家训练营, 拍照, 测评, xs10, ...  10:20
# 1c541177hR  ...  [摄影, 数码, 摄影摄像, 数码, 评测, 超广角大光圈, 摄像, 镜头, 数码评测, 超...  21:23
# 1DA41177UY  ...   [相机, 摄影, 数码, 摄影摄像, 数码, 科技, 测评, 器材, 大疆, DJI, 稳定器]  02:26
# 1rA411776p  ...  [vlog, 数码, 摄影摄像, 数码, 佳能, 测评, 体验, m50 mark ii, ...  06:30
#
#                播放量    点赞数   投币数   收藏数   转发数   评论数   弹幕数 有无分集
# 1gJ411n7hp  222.4万   9.7万  2.0万  1.4万  4980  3182  1571    否
# 1tJ41187w6  134.0万  10.7万  8.4万  5.8万  8907  3935  3.0万    否
# 1i7411i7yA   57.8万   4.4万  1.0万  1.6万  2043   641   983    否
# 1gJ411G7Cs   42.3万   3.3万  3.4万  8.6万  2605  1405   612    否
# 1KJ411e7nN   39.6万   4.8万  5.4万  3.4万  6217  1156  1.0万    否
# ...            ...    ...   ...   ...   ...   ...   ...  ...
# 1cr4y1w7ig    4.3万   3051  1391   692   255   337   349    否
# 1Y5411L7TW    4.3万    773   219   221   111   273   104    否
# 1c541177hR    4.1万   1469   443   297   123   250   561    否
# 1DA41177UY    4.1万   1565   197   334   640   171   110    否
# 1rA411776p    4.1万   1262   267   147   101   385   314    否
#
# [999 rows x 21 columns]
