# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_yingshi_zatan=pd.DataFrame(columns=columns)
channel_yingshi_zatan
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[14]/div/a/span').click()  #选择频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[14]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '影视'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[2]/a').click()  #选择子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[2]/a').text
sub_channel
# Out:
# '影视杂谈'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(1,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_yingshi_zatan.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-17 09:46:44.170841
# <ipython-input-10-24293aec47bb>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-10-24293aec47bb>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-10-24293aec47bb>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1VJ411G7mz视频属性的抓取
# BV号为1VJ411G7mz的视频属性抓取结束
# <ipython-input-10-24293aec47bb>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1yJ41157JV视频属性的抓取
# BV号为1yJ41157JV的视频属性抓取结束
# 开始BV号为17J411p7tj视频属性的抓取
# BV号为17J411p7tj的视频属性抓取结束
# 开始BV号为1zJ411h7hK视频属性的抓取
# BV号为1zJ411h7hK的视频属性抓取结束
# 开始BV号为1GJ411G7Ut视频属性的抓取
# 开始BV号为1GJ411G7Ut视频属性的抓取
# BV号为1GJ411G7Ut的视频属性抓取结束
# 开始BV号为1GJ41157pb视频属性的抓取
# BV号为1GJ41157pb的视频属性抓取结束
# 开始BV号为1hJ411E7ZR视频属性的抓取
# BV号为1hJ411E7ZR的视频属性抓取结束
# 开始BV号为1Q7411z7D3视频属性的抓取
# BV号为1Q7411z7D3的视频属性抓取结束
# 开始BV号为19J411j7RJ视频属性的抓取
# BV号为19J411j7RJ的视频属性抓取结束
# 开始BV号为1oJ4117765视频属性的抓取
# BV号为1oJ4117765的视频属性抓取结束
# 开始BV号为1B7411q7bs视频属性的抓取
# BV号为1B7411q7bs的视频属性抓取结束
# 开始BV号为1DJ411G7i5视频属性的抓取
# BV号为1DJ411G7i5的视频属性抓取结束
# 开始BV号为1hJ411H7eF视频属性的抓取
# BV号为1hJ411H7eF的视频属性抓取结束
# 开始BV号为1j7411r7qj视频属性的抓取
# BV号为1j7411r7qj的视频属性抓取结束
# 开始BV号为1i7411q7Hc视频属性的抓取
# BV号为1i7411q7Hc的视频属性抓取结束
# 开始BV号为1RJ41177Pk视频属性的抓取
# BV号为1RJ41177Pk的视频属性抓取结束
# 开始BV号为1dJ411j7yL视频属性的抓取
# BV号为1dJ411j7yL的视频属性抓取结束
# 开始BV号为1U7411B7ne视频属性的抓取
# BV号为1U7411B7ne的视频属性抓取结束
# 开始BV号为1jJ411b7Kd视频属性的抓取
# BV号为1jJ411b7Kd的视频属性抓取结束
# 开始BV号为1L7411B7bN视频属性的抓取
# BV号为1L7411B7bN的视频属性抓取结束
# 开始BV号为1S7411Y7G4视频属性的抓取
# BV号为1S7411Y7G4的视频属性抓取结束
# 开始BV号为14J41187n3视频属性的抓取
# BV号为14J41187n3的视频属性抓取结束
# 开始BV号为1i7411v7z4视频属性的抓取
# BV号为1i7411v7z4的视频属性抓取结束
# 开始BV号为1iJ411J7ou视频属性的抓取
# BV号为1iJ411J7ou的视频属性抓取结束
# 开始BV号为1jJ411b7zt视频属性的抓取
# BV号为1jJ411b7zt的视频属性抓取结束
# 开始BV号为1M7411z7AJ视频属性的抓取
# BV号为1M7411z7AJ的视频属性抓取结束
# 开始BV号为1K741167cZ视频属性的抓取
# BV号为1K741167cZ的视频属性抓取结束
# 开始BV号为1aJ411E7LK视频属性的抓取
# BV号为1aJ411E7LK的视频属性抓取结束
# 开始BV号为117411Y7MV视频属性的抓取
# BV号为117411Y7MV的视频属性抓取结束
# 开始BV号为1k7411v7zu视频属性的抓取
# BV号为1k7411v7zu的视频属性抓取结束
# 开始BV号为1n7411e7kg视频属性的抓取
# BV号为1n7411e7kg的视频属性抓取结束
# 开始BV号为1t7411q7Wr视频属性的抓取
# BV号为1t7411q7Wr的视频属性抓取结束
# <ipython-input-10-24293aec47bb>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1fJ41177G7视频属性的抓取
# BV号为1fJ41177G7的视频属性抓取结束
# 开始BV号为1r7411k73s视频属性的抓取
# BV号为1r7411k73s的视频属性抓取结束
# 开始BV号为1HJ411H7eB视频属性的抓取
# BV号为1HJ411H7eB的视频属性抓取结束
# 开始BV号为1SJ411J7te视频属性的抓取
# BV号为1SJ411J7te的视频属性抓取结束
# 开始BV号为1uJ411572m视频属性的抓取
# BV号为1uJ411572m的视频属性抓取结束
# 开始BV号为1F7411e7AF视频属性的抓取
# BV号为1F7411e7AF的视频属性抓取结束
# 开始BV号为1dJ411G7ex视频属性的抓取
# BV号为1dJ411G7ex的视频属性抓取结束
# 开始BV号为1VJ411G7yg视频属性的抓取
# BV号为1VJ411G7yg的视频属性抓取结束
# 开始BV号为1U7411e7wT视频属性的抓取
# BV号为1U7411e7wT的视频属性抓取结束
# 开始BV号为1h7411e7jb视频属性的抓取
# BV号为1h7411e7jb的视频属性抓取结束
# 开始BV号为1D7411v791视频属性的抓取
# BV号为1D7411v791的视频属性抓取结束
# 开始BV号为1zJ411J77B视频属性的抓取
# BV号为1zJ411J77B的视频属性抓取结束
# 开始BV号为1mJ41157Rm视频属性的抓取
# BV号为1mJ41157Rm的视频属性抓取结束
# 开始BV号为1BJ411V758视频属性的抓取
# BV号为1BJ411V758的视频属性抓取结束
# 开始BV号为1M7411v7ZW视频属性的抓取
# BV号为1M7411v7ZW的视频属性抓取结束
# 开始BV号为1UJ411J7k4视频属性的抓取
# BV号为1UJ411J7k4的视频属性抓取结束
# 开始BV号为1fJ411j7u5视频属性的抓取
# BV号为1fJ411j7u5的视频属性抓取结束
# 开始BV号为1RJ411E7pc视频属性的抓取
# BV号为1RJ411E7pc的视频属性抓取结束
# 开始BV号为1e7411Y7At视频属性的抓取
# BV号为1e7411Y7At的视频属性抓取结束
# 开始BV号为1K7411q7VV视频属性的抓取
# BV号为1K7411q7VV的视频属性抓取结束
# 开始BV号为1YJ41187jo视频属性的抓取
# BV号为1YJ41187jo的视频属性抓取结束
# 开始BV号为1xJ41187j7视频属性的抓取
# 开始BV号为1xJ41187j7视频属性的抓取
# 开始BV号为1xJ41187j7视频属性的抓取
# 开始BV号为1xJ41187j7视频属性的抓取
# BV号为1xJ41187j7的视频属性抓取结束
# 开始BV号为1EJ41187He视频属性的抓取
# BV号为1EJ41187He的视频属性抓取结束
# 开始BV号为1z7411e7FJ视频属性的抓取
# BV号为1z7411e7FJ的视频属性抓取结束
# 开始BV号为1b7411z7yu视频属性的抓取
# BV号为1b7411z7yu的视频属性抓取结束
# 开始BV号为1w7411Y7Vz视频属性的抓取
# BV号为1w7411Y7Vz的视频属性抓取结束
# 开始BV号为1GJ411G7xB视频属性的抓取
# BV号为1GJ411G7xB的视频属性抓取结束
# 开始BV号为1fJ411j7g8视频属性的抓取
# BV号为1fJ411j7g8的视频属性抓取结束
# 开始BV号为1B7411q7qY视频属性的抓取
# BV号为1B7411q7qY的视频属性抓取结束
# 开始BV号为11J411p7UV视频属性的抓取
# BV号为11J411p7UV的视频属性抓取结束
# 开始BV号为1QJ411n7wd视频属性的抓取
# BV号为1QJ411n7wd的视频属性抓取结束
# 开始BV号为1RJ411n73G视频属性的抓取
# BV号为1RJ411n73G的视频属性抓取结束
# 开始BV号为1yJ411J7Cu视频属性的抓取
# BV号为1yJ411J7Cu的视频属性抓取结束
# 开始BV号为1g7411B7Ed视频属性的抓取
# BV号为1g7411B7Ed的视频属性抓取结束
# 开始BV号为1e7411i7Hi视频属性的抓取
# BV号为1e7411i7Hi的视频属性抓取结束
# 开始BV号为1h7411i73Y视频属性的抓取
# BV号为1h7411i73Y的视频属性抓取结束
# 开始BV号为1x7411a78Z视频属性的抓取
# BV号为1x7411a78Z的视频属性抓取结束
# 开始BV号为1MJ411H72G视频属性的抓取
# BV号为1MJ411H72G的视频属性抓取结束
# 开始BV号为17J411V7WX视频属性的抓取
# BV号为17J411V7WX的视频属性抓取结束
# 开始BV号为1nJ411V7jT视频属性的抓取
# BV号为1nJ411V7jT的视频属性抓取结束
# 开始BV号为1PJ41157k7视频属性的抓取
# BV号为1PJ41157k7的视频属性抓取结束
# 开始BV号为1hJ411V71f视频属性的抓取
# BV号为1hJ411V71f的视频属性抓取结束
# 开始BV号为1C7411a7uW视频属性的抓取
# BV号为1C7411a7uW的视频属性抓取结束
# 开始BV号为1FJ41177Sm视频属性的抓取
# BV号为1FJ41177Sm的视频属性抓取结束
# 开始BV号为16J411n7aT视频属性的抓取
# BV号为16J411n7aT的视频属性抓取结束
# 开始BV号为14J411b75q视频属性的抓取
# BV号为14J411b75q的视频属性抓取结束
# 开始BV号为1gJ411G7ZC视频属性的抓取
# BV号为1gJ411G7ZC的视频属性抓取结束
# 开始BV号为127411i7fQ视频属性的抓取
# BV号为127411i7fQ的视频属性抓取结束
# 开始BV号为14J411J7gt视频属性的抓取
# BV号为14J411J7gt的视频属性抓取结束
# 开始BV号为1f7411q79f视频属性的抓取
# BV号为1f7411q79f的视频属性抓取结束
# 开始BV号为1GJ411L7Hi视频属性的抓取
# BV号为1GJ411L7Hi的视频属性抓取结束
# 开始BV号为1pJ411H71Q视频属性的抓取
# BV号为1pJ411H71Q的视频属性抓取结束
# 开始BV号为1zJ411E772视频属性的抓取
# BV号为1zJ411E772的视频属性抓取结束
# 开始BV号为18J411p7d7视频属性的抓取
# BV号为18J411p7d7的视频属性抓取结束
# 开始BV号为14J41177LK视频属性的抓取
# BV号为14J41177LK的视频属性抓取结束
# 开始BV号为1VJ411G7bG视频属性的抓取
# BV号为1VJ411G7bG的视频属性抓取结束
# 开始BV号为1fJ411E7HW视频属性的抓取
# BV号为1fJ411E7HW的视频属性抓取结束
# 开始BV号为1p741167p8视频属性的抓取
# BV号为1p741167p8的视频属性抓取结束
# 开始BV号为1SJ411V7K4视频属性的抓取
# BV号为1SJ411V7K4的视频属性抓取结束
# 开始BV号为1FJ41187P7视频属性的抓取
# BV号为1FJ41187P7的视频属性抓取结束
# 开始BV号为1tJ411G7eZ视频属性的抓取
# BV号为1tJ411G7eZ的视频属性抓取结束
# 开始BV号为1LJ41177XM视频属性的抓取
# BV号为1LJ41177XM的视频属性抓取结束
# 开始BV号为1EJ411V7pw视频属性的抓取
# BV号为1EJ411V7pw的视频属性抓取结束
# 开始BV号为19J411G7KK视频属性的抓取
# BV号为19J411G7KK的视频属性抓取结束
# 开始BV号为1hJ411h787视频属性的抓取
# BV号为1hJ411h787的视频属性抓取结束
# 开始BV号为1NJ411E7p6视频属性的抓取
# BV号为1NJ411E7p6的视频属性抓取结束
# 开始BV号为1RJ41157Ya视频属性的抓取
# BV号为1RJ41157Ya的视频属性抓取结束
# 开始BV号为1V7411H7gm视频属性的抓取
# BV号为1V7411H7gm的视频属性抓取结束
# 开始BV号为177411N7Cy视频属性的抓取
# BV号为177411N7Cy的视频属性抓取结束
# 开始BV号为1G7411j75x视频属性的抓取
# BV号为1G7411j75x的视频属性抓取结束
# 开始BV号为1j7411H7zN视频属性的抓取
# BV号为1j7411H7zN的视频属性抓取结束
# 开始BV号为1V7411V7GX视频属性的抓取
# BV号为1V7411V7GX的视频属性抓取结束
# 开始BV号为197411s77P视频属性的抓取
# BV号为197411s77P的视频属性抓取结束
# 开始BV号为1i7411V7Kv视频属性的抓取
# BV号为1i7411V7Kv的视频属性抓取结束
# 开始BV号为1r7411T7vY视频属性的抓取
# BV号为1r7411T7vY的视频属性抓取结束
# 开始BV号为1z7411G7uz视频属性的抓取
# BV号为1z7411G7uz的视频属性抓取结束
# 开始BV号为177411h7wR视频属性的抓取
# BV号为177411h7wR的视频属性抓取结束
# 开始BV号为137411M736视频属性的抓取
# BV号为137411M736的视频属性抓取结束
# 开始BV号为1w7411G7ov视频属性的抓取
# BV号为1w7411G7ov的视频属性抓取结束
# 开始BV号为1j7411E7Hy视频属性的抓取
# BV号为1j7411E7Hy的视频属性抓取结束
# 开始BV号为1w7411L7mw视频属性的抓取
# BV号为1w7411L7mw的视频属性抓取结束
# 开始BV号为11741177fn视频属性的抓取
# BV号为11741177fn的视频属性抓取结束
# 开始BV号为1W7411L7ik视频属性的抓取
# BV号为1W7411L7ik的视频属性抓取结束
# 开始BV号为1P7411j7PW视频属性的抓取
# BV号为1P7411j7PW的视频属性抓取结束
# 开始BV号为137411h7Bc视频属性的抓取
# BV号为137411h7Bc的视频属性抓取结束
# 开始BV号为1V7411s7oQ视频属性的抓取
# BV号为1V7411s7oQ的视频属性抓取结束
# 开始BV号为1o7411W7fj视频属性的抓取
# BV号为1o7411W7fj的视频属性抓取结束
# 开始BV号为1N741137Gv视频属性的抓取
# BV号为1N741137Gv的视频属性抓取结束
# 开始BV号为1f7411379a视频属性的抓取
# BV号为1f7411379a的视频属性抓取结束
# 开始BV号为1P7411h7QS视频属性的抓取
# BV号为1P7411h7QS的视频属性抓取结束
# 开始BV号为1W7411M7G4视频属性的抓取
# BV号为1W7411M7G4的视频属性抓取结束
# 开始BV号为1G7411W7zg视频属性的抓取
# BV号为1G7411W7zg的视频属性抓取结束
# 开始BV号为1r7411T7Nd视频属性的抓取
# BV号为1r7411T7Nd的视频属性抓取结束
# 开始BV号为13E411H73o视频属性的抓取
# BV号为13E411H73o的视频属性抓取结束
# 开始BV号为1Q741187y7视频属性的抓取
# BV号为1Q741187y7的视频属性抓取结束
# 开始BV号为1N7411W71W视频属性的抓取
# BV号为1N7411W71W的视频属性抓取结束
# 开始BV号为137411N74G视频属性的抓取
# BV号为137411N74G的视频属性抓取结束
# 开始BV号为1b7411N7Yj视频属性的抓取
# BV号为1b7411N7Yj的视频属性抓取结束
# 开始BV号为1fj411f7ke视频属性的抓取
# BV号为1fj411f7ke的视频属性抓取结束
# 开始BV号为1T7411c7uV视频属性的抓取
# 开始BV号为1T7411c7uV视频属性的抓取
# 开始BV号为1T7411c7uV视频属性的抓取
# BV号为1T7411c7uV的视频属性抓取结束
# 开始BV号为137411j714视频属性的抓取
# BV号为137411j714的视频属性抓取结束
# 开始BV号为17741137zg视频属性的抓取
# BV号为17741137zg的视频属性抓取结束
# 开始BV号为1G7411E7Cn视频属性的抓取
# BV号为1G7411E7Cn的视频属性抓取结束
# 开始BV号为1n7411b7Go视频属性的抓取
# BV号为1n7411b7Go的视频属性抓取结束
# 开始BV号为1Y7411b7fh视频属性的抓取
# BV号为1Y7411b7fh的视频属性抓取结束
# 开始BV号为1k7411778r视频属性的抓取
# BV号为1k7411778r的视频属性抓取结束
# 开始BV号为1J7411P7LC视频属性的抓取
# BV号为1J7411P7LC的视频属性抓取结束
# 开始BV号为1F7411W7Gb视频属性的抓取
# BV号为1F7411W7Gb的视频属性抓取结束
# 开始BV号为1g7411u74Q视频属性的抓取
# BV号为1g7411u74Q的视频属性抓取结束
# 开始BV号为1yj411f7LA视频属性的抓取
# BV号为1yj411f7LA的视频属性抓取结束
# 开始BV号为1w741187bS视频属性的抓取
# BV号为1w741187bS的视频属性抓取结束
# 开始BV号为157411474R视频属性的抓取
# BV号为157411474R的视频属性抓取结束
# 开始BV号为1A7411V72q视频属性的抓取
# BV号为1A7411V72q的视频属性抓取结束
# 开始BV号为1s7411w7pP视频属性的抓取
# BV号为1s7411w7pP的视频属性抓取结束
# 开始BV号为1Z7411A72s视频属性的抓取
# BV号为1Z7411A72s的视频属性抓取结束
# 开始BV号为1b7411x72p视频属性的抓取
# BV号为1b7411x72p的视频属性抓取结束
# 开始BV号为1m741177x1视频属性的抓取
# BV号为1m741177x1的视频属性抓取结束
# 开始BV号为1J7411571n视频属性的抓取
# BV号为1J7411571n的视频属性抓取结束
# 开始BV号为1b741187Gt视频属性的抓取
# BV号为1b741187Gt的视频属性抓取结束
# 开始BV号为1u741157rm视频属性的抓取
# BV号为1u741157rm的视频属性抓取结束
# 开始BV号为1nE411J7MC视频属性的抓取
# BV号为1nE411J7MC的视频属性抓取结束
# 开始BV号为1q741147Zm视频属性的抓取
# BV号为1q741147Zm的视频属性抓取结束
# 开始BV号为1R7411P7E4视频属性的抓取
# BV号为1R7411P7E4的视频属性抓取结束
# 开始BV号为1iE411H7d7视频属性的抓取
# BV号为1iE411H7d7的视频属性抓取结束
# 开始BV号为1s7411P7Gh视频属性的抓取
# BV号为1s7411P7Gh的视频属性抓取结束
# 开始BV号为1B7411b7bH视频属性的抓取
# BV号为1B7411b7bH的视频属性抓取结束
# 开始BV号为1E7411K7Nn视频属性的抓取
# BV号为1E7411K7Nn的视频属性抓取结束
# 开始BV号为1A7411b7bK视频属性的抓取
# BV号为1A7411b7bK的视频属性抓取结束
# 开始BV号为1qE411J7sz视频属性的抓取
# BV号为1qE411J7sz的视频属性抓取结束
# 开始BV号为137411E7Sq视频属性的抓取
# BV号为137411E7Sq的视频属性抓取结束
# 开始BV号为1p7411g7mu视频属性的抓取
# BV号为1p7411g7mu的视频属性抓取结束
# 开始BV号为167411h7HR视频属性的抓取
# BV号为167411h7HR的视频属性抓取结束
# 开始BV号为1M7411N7QY视频属性的抓取
# BV号为1M7411N7QY的视频属性抓取结束
# 开始BV号为1d7411N7h1视频属性的抓取
# BV号为1d7411N7h1的视频属性抓取结束
# 开始BV号为1H741187uw视频属性的抓取
# BV号为1H741187uw的视频属性抓取结束
# 开始BV号为1i7411h7uE视频属性的抓取
# BV号为1i7411h7uE的视频属性抓取结束
# 开始BV号为1G7411p7n5视频属性的抓取
# BV号为1G7411p7n5的视频属性抓取结束
# 开始BV号为1i7411x7UU视频属性的抓取
# BV号为1i7411x7UU的视频属性抓取结束
# 开始BV号为13E411H79w视频属性的抓取
# BV号为13E411H79w的视频属性抓取结束
# 开始BV号为1o741187zb视频属性的抓取
# BV号为1o741187zb的视频属性抓取结束
# 开始BV号为1m7411F7A7视频属性的抓取
# BV号为1m7411F7A7的视频属性抓取结束
# 开始BV号为1CE411H7DN视频属性的抓取
# BV号为1CE411H7DN的视频属性抓取结束
# 开始BV号为1a7411c7CF视频属性的抓取
# BV号为1a7411c7CF的视频属性抓取结束
# 开始BV号为1b7411K7ds视频属性的抓取
# BV号为1b7411K7ds的视频属性抓取结束
# 开始BV号为1p7411H7mw视频属性的抓取
# BV号为1p7411H7mw的视频属性抓取结束
# 开始BV号为1H7411g7XX视频属性的抓取
# BV号为1H7411g7XX的视频属性抓取结束
# 开始BV号为187411G72h视频属性的抓取
# BV号为187411G72h的视频属性抓取结束
# 开始BV号为1Z741177ZY视频属性的抓取
# BV号为1Z741177ZY的视频属性抓取结束
# 开始BV号为1A7411x7d9视频属性的抓取
# BV号为1A7411x7d9的视频属性抓取结束
# 开始BV号为1o741137F7视频属性的抓取
# BV号为1o741137F7的视频属性抓取结束
# 开始BV号为1G741137jn视频属性的抓取
# BV号为1G741137jn的视频属性抓取结束
# 开始BV号为1V7411379Y视频属性的抓取
# BV号为1V7411379Y的视频属性抓取结束
# 开始BV号为1p7411N7SV视频属性的抓取
# BV号为1p7411N7SV的视频属性抓取结束
# 开始BV号为1k7411h7Ca视频属性的抓取
# BV号为1k7411h7Ca的视频属性抓取结束
# 开始BV号为147411t713视频属性的抓取
# BV号为147411t713的视频属性抓取结束
# 开始BV号为1i7411475D视频属性的抓取
# BV号为1i7411475D的视频属性抓取结束
# 开始BV号为1o7411g79N视频属性的抓取
# BV号为1o7411g79N的视频属性抓取结束
# 开始BV号为1Z7411g74w视频属性的抓取
# BV号为1Z7411g74w的视频属性抓取结束
# 开始BV号为1QE411J7XY视频属性的抓取
# BV号为1QE411J7XY的视频属性抓取结束
# 开始BV号为137411K7Vo视频属性的抓取
# BV号为137411K7Vo的视频属性抓取结束
# 开始BV号为1z7411M7gr视频属性的抓取
# BV号为1z7411M7gr的视频属性抓取结束
# 开始BV号为1U7411j7hK视频属性的抓取
# BV号为1U7411j7hK的视频属性抓取结束
# 开始BV号为1D741137QP视频属性的抓取
# BV号为1D741137QP的视频属性抓取结束
# 开始BV号为1b7411w7Jx视频属性的抓取
# BV号为1b7411w7Jx的视频属性抓取结束
# 开始BV号为1M7411H7hE视频属性的抓取
# BV号为1M7411H7hE的视频属性抓取结束
# 开始BV号为1x7411F7ZG视频属性的抓取
# BV号为1x7411F7ZG的视频属性抓取结束
# 开始BV号为1F7411F7Ap视频属性的抓取
# BV号为1F7411F7Ap的视频属性抓取结束
# 开始BV号为1q7411D7Mw视频属性的抓取
# BV号为1q7411D7Mw的视频属性抓取结束
# 开始BV号为1sE411c7DB视频属性的抓取
# BV号为1sE411c7DB的视频属性抓取结束
# 开始BV号为12E411j7Zf视频属性的抓取
# BV号为12E411j7Zf的视频属性抓取结束
# 开始BV号为16E411A7zb视频属性的抓取
# BV号为16E411A7zb的视频属性抓取结束
# 开始BV号为13E411A7HJ视频属性的抓取
# BV号为13E411A7HJ的视频属性抓取结束
# 开始BV号为1nE411K72Z视频属性的抓取
# BV号为1nE411K72Z的视频属性抓取结束
# 开始BV号为11E411W7et视频属性的抓取
# BV号为11E411W7et的视频属性抓取结束
# 开始BV号为1GE411P7Nm视频属性的抓取
# BV号为1GE411P7Nm的视频属性抓取结束
# 开始BV号为18p411A79Q视频属性的抓取
# BV号为18p411A79Q的视频属性抓取结束
# 开始BV号为1XE411g7DD视频属性的抓取
# BV号为1XE411g7DD的视频属性抓取结束
# 开始BV号为1KE411n7mk视频属性的抓取
# BV号为1KE411n7mk的视频属性抓取结束
# 开始BV号为1PE41147zU视频属性的抓取
# BV号为1PE41147zU的视频属性抓取结束
# 开始BV号为1ME411x77U视频属性的抓取
# BV号为1ME411x77U的视频属性抓取结束
# 开始BV号为1Wz411b71r视频属性的抓取
# BV号为1Wz411b71r的视频属性抓取结束
# 开始BV号为1EE411W77o视频属性的抓取
# BV号为1EE411W77o的视频属性抓取结束
# 开始BV号为18E411P7oS视频属性的抓取
# BV号为18E411P7oS的视频属性抓取结束
# 开始BV号为1tE411s7xY视频属性的抓取
# BV号为1tE411s7xY的视频属性抓取结束
# 开始BV号为1N7411f7w1视频属性的抓取
# BV号为1N7411f7w1的视频属性抓取结束
# 开始BV号为1TE41177ZV视频属性的抓取
# BV号为1TE41177ZV的视频属性抓取结束
# 开始BV号为17741127DF视频属性的抓取
# BV号为17741127DF的视频属性抓取结束
# 开始BV号为167411o7tH视频属性的抓取
# BV号为167411o7tH的视频属性抓取结束
# 开始BV号为1rE411L7wh视频属性的抓取
# BV号为1rE411L7wh的视频属性抓取结束
# 开始BV号为1g7411d7v7视频属性的抓取
# BV号为1g7411d7v7的视频属性抓取结束
# 开始BV号为16E411g7EU视频属性的抓取
# BV号为16E411g7EU的视频属性抓取结束
# 开始BV号为1P7411U7qj视频属性的抓取
# BV号为1P7411U7qj的视频属性抓取结束
# 开始BV号为1S7411C7Nb视频属性的抓取
# BV号为1S7411C7Nb的视频属性抓取结束
# 开始BV号为1R7411y7BZ视频属性的抓取
# BV号为1R7411y7BZ的视频属性抓取结束
# 开始BV号为1q7411o7CY视频属性的抓取
# BV号为1q7411o7CY的视频属性抓取结束
# 开始BV号为1eT4y157Fm视频属性的抓取
# BV号为1eT4y157Fm的视频属性抓取结束
# 开始BV号为1uE411L7mr视频属性的抓取
# BV号为1uE411L7mr的视频属性抓取结束
# 开始BV号为1DE411P7Lx视频属性的抓取
# BV号为1DE411P7Lx的视频属性抓取结束
# 开始BV号为1eE411A7de视频属性的抓取
# BV号为1eE411A7de的视频属性抓取结束
# 开始BV号为1FE411p7ti视频属性的抓取
# BV号为1FE411p7ti的视频属性抓取结束
# 开始BV号为1C741127oF视频属性的抓取
# BV号为1C741127oF的视频属性抓取结束
# 开始BV号为137411o7gr视频属性的抓取
# BV号为137411o7gr的视频属性抓取结束
# 开始BV号为1x7411d7o4视频属性的抓取
# BV号为1x7411d7o4的视频属性抓取结束
# 开始BV号为1aE411u7K3视频属性的抓取
# BV号为1aE411u7K3的视频属性抓取结束
# 开始BV号为1BE411j7kb视频属性的抓取
# BV号为1BE411j7kb的视频属性抓取结束
# 开始BV号为187411U7Eo视频属性的抓取
# BV号为187411U7Eo的视频属性抓取结束
# 开始BV号为1UE411u77K视频属性的抓取
# BV号为1UE411u77K的视频属性抓取结束
# 开始BV号为1ez411b7L8视频属性的抓取
# BV号为1ez411b7L8的视频属性抓取结束
# 开始BV号为1xE411779H视频属性的抓取
# BV号为1xE411779H的视频属性抓取结束
# 开始BV号为1AE411T7gK视频属性的抓取
# 开始BV号为1AE411T7gK视频属性的抓取
# BV号为1AE411T7gK的视频属性抓取结束
# 开始BV号为167411m7PT视频属性的抓取
# BV号为167411m7PT的视频属性抓取结束
# 开始BV号为1PE411n7Bx视频属性的抓取
# BV号为1PE411n7Bx的视频属性抓取结束
# 开始BV号为1N7411y7bv视频属性的抓取
# BV号为1N7411y7bv的视频属性抓取结束
# 开始BV号为1CE41137Pk视频属性的抓取
# BV号为1CE41137Pk的视频属性抓取结束
# 开始BV号为1wE411K77c视频属性的抓取
# BV号为1wE411K77c的视频属性抓取结束
# 开始BV号为1zE411x77w视频属性的抓取
# BV号为1zE411x77w的视频属性抓取结束
# 开始BV号为1K7411R7k2视频属性的抓取
# BV号为1K7411R7k2的视频属性抓取结束
# 开始BV号为1uE411M75o视频属性的抓取
# BV号为1uE411M75o的视频属性抓取结束
# 开始BV号为1CE411j7FZ视频属性的抓取
# BV号为1CE411j7FZ的视频属性抓取结束
# 开始BV号为1ME41147iW视频属性的抓取
# BV号为1ME41147iW的视频属性抓取结束
# 开始BV号为1N7411U7Kq视频属性的抓取
# BV号为1N7411U7Kq的视频属性抓取结束
# 开始BV号为1QE411j7hL视频属性的抓取
# BV号为1QE411j7hL的视频属性抓取结束
# 开始BV号为1tE411s7XF视频属性的抓取
# BV号为1tE411s7XF的视频属性抓取结束
# 开始BV号为1t7411Z7iR视频属性的抓取
# BV号为1t7411Z7iR的视频属性抓取结束
# 开始BV号为1aE411u7zx视频属性的抓取
# BV号为1aE411u7zx的视频属性抓取结束
# 开始BV号为19E411K7YH视频属性的抓取
# BV号为19E411K7YH的视频属性抓取结束
# 开始BV号为1KE411c7Yj视频属性的抓取
# BV号为1KE411c7Yj的视频属性抓取结束
# 开始BV号为1QE411H7Nt视频属性的抓取
# BV号为1QE411H7Nt的视频属性抓取结束
# 开始BV号为1KE411N7WS视频属性的抓取
# BV号为1KE411N7WS的视频属性抓取结束
# 开始BV号为1P7411f7KX视频属性的抓取
# BV号为1P7411f7KX的视频属性抓取结束
# 开始BV号为1gE411s7MA视频属性的抓取
# BV号为1gE411s7MA的视频属性抓取结束
# 开始BV号为1S7411m7vj视频属性的抓取
# BV号为1S7411m7vj的视频属性抓取结束
# 开始BV号为1oT4y1V7xg视频属性的抓取
# BV号为1oT4y1V7xg的视频属性抓取结束
# 开始BV号为1ZE411g7ud视频属性的抓取
# BV号为1ZE411g7ud的视频属性抓取结束
# 开始BV号为1SE411W7Pv视频属性的抓取
# BV号为1SE411W7Pv的视频属性抓取结束
# 开始BV号为1jE411p7uh视频属性的抓取
# BV号为1jE411p7uh的视频属性抓取结束
# 开始BV号为1M7411y7E9视频属性的抓取
# BV号为1M7411y7E9的视频属性抓取结束
# 开始BV号为1pE411w71s视频属性的抓取
# BV号为1pE411w71s的视频属性抓取结束
# 开始BV号为1p741127Ue视频属性的抓取
# BV号为1p741127Ue的视频属性抓取结束
# 开始BV号为1HE411g7ES视频属性的抓取
# BV号为1HE411g7ES的视频属性抓取结束
# 开始BV号为1wE411x7vx视频属性的抓取
# BV号为1wE411x7vx的视频属性抓取结束
# 开始BV号为18E411A7iQ视频属性的抓取
# BV号为18E411A7iQ的视频属性抓取结束
# 开始BV号为1JE411P7QX视频属性的抓取
# BV号为1JE411P7QX的视频属性抓取结束
# 开始BV号为1ME411u7D4视频属性的抓取
# BV号为1ME411u7D4的视频属性抓取结束
# 开始BV号为187411Z7qa视频属性的抓取
# BV号为187411Z7qa的视频属性抓取结束
# 开始BV号为1ui4y1n7xF视频属性的抓取
# BV号为1ui4y1n7xF的视频属性抓取结束
# 开始BV号为1dE411s71W视频属性的抓取
# BV号为1dE411s71W的视频属性抓取结束
# 开始BV号为1aE41147Kw视频属性的抓取
# BV号为1aE41147Kw的视频属性抓取结束
# 开始BV号为1bE411F7de视频属性的抓取
# BV号为1bE411F7de的视频属性抓取结束
# 开始BV号为1AQ4y1M72p视频属性的抓取
# BV号为1AQ4y1M72p的视频属性抓取结束
# 开始BV号为16741197Hm视频属性的抓取
# BV号为16741197Hm的视频属性抓取结束
# 开始BV号为1354y1d7EA视频属性的抓取
# BV号为1354y1d7EA的视频属性抓取结束
# 开始BV号为1FT4y1G7qZ视频属性的抓取
# BV号为1FT4y1G7qZ的视频属性抓取结束
# 开始BV号为1J7411R7NT视频属性的抓取
# BV号为1J7411R7NT的视频属性抓取结束
# 开始BV号为1rK4y1C7PF视频属性的抓取
# BV号为1rK4y1C7PF的视频属性抓取结束
# 开始BV号为1oE411T7WY视频属性的抓取
# BV号为1oE411T7WY的视频属性抓取结束
# 开始BV号为12E411W7qq视频属性的抓取
# BV号为12E411W7qq的视频属性抓取结束
# 开始BV号为1P7411R7Wm视频属性的抓取
# BV号为1P7411R7Wm的视频属性抓取结束
# 开始BV号为1ZE411N7V1视频属性的抓取
# BV号为1ZE411N7V1的视频属性抓取结束
# 开始BV号为1LE411g7yz视频属性的抓取
# BV号为1LE411g7yz的视频属性抓取结束
# 开始BV号为1LE411J7nf视频属性的抓取
# BV号为1LE411J7nf的视频属性抓取结束
# 开始BV号为1jE411E7SJ视频属性的抓取
# BV号为1jE411E7SJ的视频属性抓取结束
# 开始BV号为12E411P78H视频属性的抓取
# BV号为12E411P78H的视频属性抓取结束
# 开始BV号为1eT4y157cv视频属性的抓取
# BV号为1eT4y157cv的视频属性抓取结束
# 开始BV号为1WE411j7rd视频属性的抓取
# BV号为1WE411j7rd的视频属性抓取结束
# 开始BV号为1BE411A73z视频属性的抓取
# BV号为1BE411A73z的视频属性抓取结束
# 开始BV号为1dE411P76X视频属性的抓取
# BV号为1dE411P76X的视频属性抓取结束
# 开始BV号为19K4y1r7i4视频属性的抓取
# BV号为19K4y1r7i4的视频属性抓取结束
# 开始BV号为1NA41187w9视频属性的抓取
# BV号为1NA41187w9的视频属性抓取结束
# 开始BV号为1hK41157yT视频属性的抓取
# BV号为1hK41157yT的视频属性抓取结束
# 开始BV号为1BK4y1C7fy视频属性的抓取
# BV号为1BK4y1C7fy的视频属性抓取结束
# 开始BV号为12Z4y1j7UT视频属性的抓取
# BV号为12Z4y1j7UT的视频属性抓取结束
# 开始BV号为1ap4y1C7oZ视频属性的抓取
# BV号为1ap4y1C7oZ的视频属性抓取结束
# 开始BV号为1ip4y1X7RD视频属性的抓取
# BV号为1ip4y1X7RD的视频属性抓取结束
# 开始BV号为1q5411x7vp视频属性的抓取
# BV号为1q5411x7vp的视频属性抓取结束
# 开始BV号为1kk4y1R7ke视频属性的抓取
# BV号为1kk4y1R7ke的视频属性抓取结束
# 开始BV号为1KA41187cr视频属性的抓取
# BV号为1KA41187cr的视频属性抓取结束
# 开始BV号为1Wk4y1R76j视频属性的抓取
# BV号为1Wk4y1R76j的视频属性抓取结束
# 开始BV号为1Nz411b7Rd视频属性的抓取
# BV号为1Nz411b7Rd的视频属性抓取结束
# 开始BV号为1s5411t7Bo视频属性的抓取
# BV号为1s5411t7Bo的视频属性抓取结束
# 开始BV号为1nK411j7ww视频属性的抓取
# BV号为1nK411j7ww的视频属性抓取结束
# 开始BV号为1CK4y1C7hb视频属性的抓取
# BV号为1CK4y1C7hb的视频属性抓取结束
# 开始BV号为1Jf4y1S7Pr视频属性的抓取
# BV号为1Jf4y1S7Pr的视频属性抓取结束
# 开始BV号为15z411z7ro视频属性的抓取
# BV号为15z411z7ro的视频属性抓取结束
# 开始BV号为1HQ4y1M75G视频属性的抓取
# BV号为1HQ4y1M75G的视频属性抓取结束
# 开始BV号为1Sf4y1S793视频属性的抓取
# BV号为1Sf4y1S793的视频属性抓取结束
# 开始BV号为1Sk4y1d7Eu视频属性的抓取
# BV号为1Sk4y1d7Eu的视频属性抓取结束
# 开始BV号为1fK411L7Lq视频属性的抓取
# BV号为1fK411L7Lq的视频属性抓取结束
# 开始BV号为16z411b7td视频属性的抓取
# BV号为16z411b7td的视频属性抓取结束
# 开始BV号为1TT4y1571X视频属性的抓取
# BV号为1TT4y1571X的视频属性抓取结束
# 开始BV号为1Af4y1S7Mx视频属性的抓取
# BV号为1Af4y1S7Mx的视频属性抓取结束
# 开始BV号为12e411x7Y9视频属性的抓取
# BV号为12e411x7Y9的视频属性抓取结束
# 开始BV号为13e411476z视频属性的抓取
# BV号为13e411476z的视频属性抓取结束
# 开始BV号为1GT4y157dn视频属性的抓取
# BV号为1GT4y157dn的视频属性抓取结束
# 开始BV号为1TZ4y1x7hV视频属性的抓取
# BV号为1TZ4y1x7hV的视频属性抓取结束
# 开始BV号为1rZ4y1W7X3视频属性的抓取
# BV号为1rZ4y1W7X3的视频属性抓取结束
# 开始BV号为1464y1T7dF视频属性的抓取
# BV号为1464y1T7dF的视频属性抓取结束
# 开始BV号为14e411x7Xw视频属性的抓取
# BV号为14e411x7Xw的视频属性抓取结束
# 开始BV号为1zi4y1t7vL视频属性的抓取
# BV号为1zi4y1t7vL的视频属性抓取结束
# 开始BV号为19K411V7Cp视频属性的抓取
# BV号为19K411V7Cp的视频属性抓取结束
# 开始BV号为1Tt4y1U7wS视频属性的抓取
# BV号为1Tt4y1U7wS的视频属性抓取结束
# 开始BV号为1d64y1u7Cj视频属性的抓取
# BV号为1d64y1u7Cj的视频属性抓取结束
# 开始BV号为1SQ4y1K7PV视频属性的抓取
# BV号为1SQ4y1K7PV的视频属性抓取结束
# 开始BV号为1nt4y127au视频属性的抓取
# BV号为1nt4y127au的视频属性抓取结束
# 开始BV号为11V411f7g3视频属性的抓取
# BV号为11V411f7g3的视频属性抓取结束
# 开始BV号为1754y1d7EK视频属性的抓取
# BV号为1754y1d7EK的视频属性抓取结束
# 开始BV号为1ma4y1v7Se视频属性的抓取
# BV号为1ma4y1v7Se的视频属性抓取结束
# 开始BV号为1n5411t76U视频属性的抓取
# BV号为1n5411t76U的视频属性抓取结束
# 开始BV号为1qg4y1z7D1视频属性的抓取
# BV号为1qg4y1z7D1的视频属性抓取结束
# 开始BV号为1wi4y1b7cN视频属性的抓取
# BV号为1wi4y1b7cN的视频属性抓取结束
# 开始BV号为1ti4y187BV视频属性的抓取
# BV号为1ti4y187BV的视频属性抓取结束
# 开始BV号为1B541167em视频属性的抓取
# BV号为1B541167em的视频属性抓取结束
# 开始BV号为1up4y1C7st视频属性的抓取
# BV号为1up4y1C7st的视频属性抓取结束
# 开始BV号为1g64y1M7zy视频属性的抓取
# BV号为1g64y1M7zy的视频属性抓取结束
# 开始BV号为1Dc41187iD视频属性的抓取
# BV号为1Dc41187iD的视频属性抓取结束
# 开始BV号为1UK411V7N7视频属性的抓取
# BV号为1UK411V7N7的视频属性抓取结束
# 开始BV号为1Zf4y1U7rH视频属性的抓取
# BV号为1Zf4y1U7rH的视频属性抓取结束
# 开始BV号为1G5411t7AR视频属性的抓取
# BV号为1G5411t7AR的视频属性抓取结束
# 开始BV号为1m7411o7Lg视频属性的抓取
# BV号为1m7411o7Lg的视频属性抓取结束
# 开始BV号为1GK41157sv视频属性的抓取
# BV号为1GK41157sv的视频属性抓取结束
# 开始BV号为12g4y187tL视频属性的抓取
# BV号为12g4y187tL的视频属性抓取结束
# 开始BV号为1164y1T7Ci视频属性的抓取
# BV号为1164y1T7Ci的视频属性抓取结束
# 开始BV号为1Hf4y1S7SN视频属性的抓取
# BV号为1Hf4y1S7SN的视频属性抓取结束
# 开始BV号为1Pg4y1z784视频属性的抓取
# BV号为1Pg4y1z784的视频属性抓取结束
# 开始BV号为15A411h7Ht视频属性的抓取
# BV号为15A411h7Ht的视频属性抓取结束
# 开始BV号为1tA411b7qC视频属性的抓取
# BV号为1tA411b7qC的视频属性抓取结束
# 开始BV号为1rA411b7iJ视频属性的抓取
# BV号为1rA411b7iJ的视频属性抓取结束
# 开始BV号为1UQ4y1M7ow视频属性的抓取
# BV号为1UQ4y1M7ow的视频属性抓取结束
# 开始BV号为1t64y1M7Nv视频属性的抓取
# BV号为1t64y1M7Nv的视频属性抓取结束
# 开始BV号为15g4y1a7c2视频属性的抓取
# BV号为15g4y1a7c2的视频属性抓取结束
# 开始BV号为1Hg4y1z7rx视频属性的抓取
# BV号为1Hg4y1z7rx的视频属性抓取结束
# 开始BV号为1pt4y127HV视频属性的抓取
# BV号为1pt4y127HV的视频属性抓取结束
# 开始BV号为1jt4y1U76C视频属性的抓取
# BV号为1jt4y1U76C的视频属性抓取结束
# 开始BV号为1yT4y1G7hK视频属性的抓取
# BV号为1yT4y1G7hK的视频属性抓取结束
# 开始BV号为1uf4y1S7dV视频属性的抓取
# BV号为1uf4y1S7dV的视频属性抓取结束
# 开始BV号为16f4y1S7uE视频属性的抓取
# BV号为16f4y1S7uE的视频属性抓取结束
# 开始BV号为1pk4y1R7eg视频属性的抓取
# BV号为1pk4y1R7eg的视频属性抓取结束
# 开始BV号为1Rk4y1971b视频属性的抓取
# BV号为1Rk4y1971b的视频属性抓取结束
# 开始BV号为1CQ4y1K7SN视频属性的抓取
# BV号为1CQ4y1K7SN的视频属性抓取结束
# 开始BV号为1aK4y1k7GH视频属性的抓取
# BV号为1aK4y1k7GH的视频属性抓取结束
# 开始BV号为1ok4y1d7GF视频属性的抓取
# BV号为1ok4y1d7GF的视频属性抓取结束
# 开始BV号为1h5411t7oG视频属性的抓取
# BV号为1h5411t7oG的视频属性抓取结束
# 开始BV号为19i4y1b79H视频属性的抓取
# BV号为19i4y1b79H的视频属性抓取结束
# 开始BV号为1iK4y1b7ou视频属性的抓取
# BV号为1iK4y1b7ou的视频属性抓取结束
# 开始BV号为1ut4y127Ps视频属性的抓取
# BV号为1ut4y127Ps的视频属性抓取结束
# 开始BV号为1Bt4y1U73t视频属性的抓取
# BV号为1Bt4y1U73t的视频属性抓取结束
# 开始BV号为1vp4y117gt视频属性的抓取
# BV号为1vp4y117gt的视频属性抓取结束
# 开始BV号为1KK411j7Hd视频属性的抓取
# 开始BV号为1KK411j7Hd视频属性的抓取
# BV号为1KK411j7Hd的视频属性抓取结束
# 开始BV号为17z411b7sq视频属性的抓取
# BV号为17z411b7sq的视频属性抓取结束
# 开始BV号为1kT4y1G7Yo视频属性的抓取
# BV号为1kT4y1G7Yo的视频属性抓取结束
# 开始BV号为1ya4y1v79r视频属性的抓取
# BV号为1ya4y1v79r的视频属性抓取结束
# 开始BV号为1SQ4y1K7oS视频属性的抓取
# BV号为1SQ4y1K7oS的视频属性抓取结束
# 开始BV号为1Gk4y1R73H视频属性的抓取
# BV号为1Gk4y1R73H的视频属性抓取结束
# 开始BV号为1dp4y1C7Gg视频属性的抓取
# BV号为1dp4y1C7Gg的视频属性抓取结束
# 开始BV号为1KA411b7in视频属性的抓取
# BV号为1KA411b7in的视频属性抓取结束
# 开始BV号为18V411o7M9视频属性的抓取
# BV号为18V411o7M9的视频属性抓取结束
# 开始BV号为1CQ4y1M7Qk视频属性的抓取
# BV号为1CQ4y1M7Qk的视频属性抓取结束
# 开始BV号为17V411o76L视频属性的抓取
# BV号为17V411o76L的视频属性抓取结束
# 开始BV号为18a4y1x7s6视频属性的抓取
# BV号为18a4y1x7s6的视频属性抓取结束
# 开始BV号为15c411h7iL视频属性的抓取
# BV号为15c411h7iL的视频属性抓取结束
# 开始BV号为1eQ4y1M7PZ视频属性的抓取
# BV号为1eQ4y1M7PZ的视频属性抓取结束
# 开始BV号为1J64y1T7xU视频属性的抓取
# BV号为1J64y1T7xU的视频属性抓取结束
# 开始BV号为1oC4y1p7Nx视频属性的抓取
# BV号为1oC4y1p7Nx的视频属性抓取结束
# 开始BV号为1Vi4y187NP视频属性的抓取
# BV号为1Vi4y187NP的视频属性抓取结束
# 开始BV号为19C4y1s7k1视频属性的抓取
# BV号为19C4y1s7k1的视频属性抓取结束
# 开始BV号为1za4y1x7tH视频属性的抓取
# BV号为1za4y1x7tH的视频属性抓取结束
# 开始BV号为1gV411d7GP视频属性的抓取
# BV号为1gV411d7GP的视频属性抓取结束
# 开始BV号为1Ez4y1d7Ux视频属性的抓取
# BV号为1Ez4y1d7Ux的视频属性抓取结束
# 开始BV号为1xC4y1W7qd视频属性的抓取
# BV号为1xC4y1W7qd的视频属性抓取结束
# 开始BV号为1jK411W777视频属性的抓取
# BV号为1jK411W777的视频属性抓取结束
# 开始BV号为1ra4y1i7ZQ视频属性的抓取
# BV号为1ra4y1i7ZQ的视频属性抓取结束
# 开始BV号为1TT4y1g7Xd视频属性的抓取
# BV号为1TT4y1g7Xd的视频属性抓取结束
# 开始BV号为1xf4y1m7Bb视频属性的抓取
# BV号为1xf4y1m7Bb的视频属性抓取结束
# 开始BV号为1sv411z7ju视频属性的抓取
# BV号为1sv411z7ju的视频属性抓取结束
# 开始BV号为1XZ4y1p7UM视频属性的抓取
# BV号为1XZ4y1p7UM的视频属性抓取结束
# 开始BV号为1gK411s7AD视频属性的抓取
# BV号为1gK411s7AD的视频属性抓取结束
# 开始BV号为1Tk4y1r7aG视频属性的抓取
# BV号为1Tk4y1r7aG的视频属性抓取结束
# 开始BV号为1Ht4y1C76z视频属性的抓取
# BV号为1Ht4y1C76z的视频属性抓取结束
# 开始BV号为1Sz411q7Kg视频属性的抓取
# BV号为1Sz411q7Kg的视频属性抓取结束
# 开始BV号为1Ua4y1i7Fw视频属性的抓取
# BV号为1Ua4y1i7Fw的视频属性抓取结束
# 开始BV号为1SK4y1t7e7视频属性的抓取
# BV号为1SK4y1t7e7的视频属性抓取结束
# <ipython-input-10-24293aec47bb>:190: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为17T4y1g7qS视频属性的抓取
# BV号为17T4y1g7qS的视频属性抓取结束
# 开始BV号为1sf4y1m7aP视频属性的抓取
# BV号为1sf4y1m7aP的视频属性抓取结束
# 开始BV号为1fA411i7sb视频属性的抓取
# BV号为1fA411i7sb的视频属性抓取结束
# 开始BV号为1tK4y1b7VT视频属性的抓取
# BV号为1tK4y1b7VT的视频属性抓取结束
# 开始BV号为1sV411C7Dk视频属性的抓取
# BV号为1sV411C7Dk的视频属性抓取结束
# 开始BV号为1fT4y1u78u视频属性的抓取
# BV号为1fT4y1u78u的视频属性抓取结束
# 开始BV号为1VZ4y1W7gc视频属性的抓取
# BV号为1VZ4y1W7gc的视频属性抓取结束
# 开始BV号为1ct4y1m7xf视频属性的抓取
# BV号为1ct4y1m7xf的视频属性抓取结束
# 开始BV号为185411s75Z视频属性的抓取
# BV号为185411s75Z的视频属性抓取结束
# 开始BV号为1dK4y147d1视频属性的抓取
# BV号为1dK4y147d1的视频属性抓取结束
# 开始BV号为1wa4y1v7JB视频属性的抓取
# BV号为1wa4y1v7JB的视频属性抓取结束
# 开始BV号为1TK411s7gg视频属性的抓取
# BV号为1TK411s7gg的视频属性抓取结束
# 开始BV号为14C4y1H73e视频属性的抓取
# BV号为14C4y1H73e的视频属性抓取结束
# 开始BV号为1Rz4y1R7fT视频属性的抓取
# BV号为1Rz4y1R7fT的视频属性抓取结束
# 开始BV号为1a541147Th视频属性的抓取
# BV号为1a541147Th的视频属性抓取结束
# 开始BV号为1Zg4y1z7mg视频属性的抓取
# BV号为1Zg4y1z7mg的视频属性抓取结束
# 开始BV号为1df4y117EU视频属性的抓取
# BV号为1df4y117EU的视频属性抓取结束
# 开始BV号为1BV411d7ox视频属性的抓取
# BV号为1BV411d7ox的视频属性抓取结束
# 开始BV号为1Wk4y1k726视频属性的抓取
# BV号为1Wk4y1k726的视频属性抓取结束
# 开始BV号为1h54y1X7ny视频属性的抓取
# BV号为1h54y1X7ny的视频属性抓取结束
# 开始BV号为1u54y1X79t视频属性的抓取
# BV号为1u54y1X79t的视频属性抓取结束
# 开始BV号为13t4y117Rn视频属性的抓取
# BV号为13t4y117Rn的视频属性抓取结束
# 开始BV号为1Vi4y1b7JQ视频属性的抓取
# BV号为1Vi4y1b7JQ的视频属性抓取结束
# 开始BV号为1zQ4y1A7tv视频属性的抓取
# BV号为1zQ4y1A7tv的视频属性抓取结束
# 开始BV号为1gz411B74H视频属性的抓取
# BV号为1gz411B74H的视频属性抓取结束
# 开始BV号为1Xp4y1Q7VN视频属性的抓取
# BV号为1Xp4y1Q7VN的视频属性抓取结束
# 开始BV号为11K411578Z视频属性的抓取
# BV号为11K411578Z的视频属性抓取结束
# 开始BV号为1nT4y1u7fS视频属性的抓取
# BV号为1nT4y1u7fS的视频属性抓取结束
# 开始BV号为1ev411z7ud视频属性的抓取
# BV号为1ev411z7ud的视频属性抓取结束
# 开始BV号为1Qz4y1X72V视频属性的抓取
# BV号为1Qz4y1X72V的视频属性抓取结束
# 开始BV号为1Bk4y167Jn视频属性的抓取
# BV号为1Bk4y167Jn的视频属性抓取结束
# 开始BV号为1RV411k75q视频属性的抓取
# BV号为1RV411k75q的视频属性抓取结束
# 开始BV号为1z54y1X7KX视频属性的抓取
# BV号为1z54y1X7KX的视频属性抓取结束
# 开始BV号为1y5411p7EZ视频属性的抓取
# BV号为1y5411p7EZ的视频属性抓取结束
# 开始BV号为1CV411C7xF视频属性的抓取
# BV号为1CV411C7xF的视频属性抓取结束
# 开始BV号为1se411p7JF视频属性的抓取
# BV号为1se411p7JF的视频属性抓取结束
# 开始BV号为1c5411s7WC视频属性的抓取
# BV号为1c5411s7WC的视频属性抓取结束
# 开始BV号为1Ni4y1b7ZE视频属性的抓取
# BV号为1Ni4y1b7ZE的视频属性抓取结束
# 开始BV号为1sp4y197Vt视频属性的抓取
# BV号为1sp4y197Vt的视频属性抓取结束
# 开始BV号为1QA411475f视频属性的抓取
# BV号为1QA411475f的视频属性抓取结束
# 开始BV号为1Zg4y1z71E视频属性的抓取
# 开始BV号为1Zg4y1z71E视频属性的抓取
# 开始BV号为1Zg4y1z71E视频属性的抓取
# BV号为1Zg4y1z71E的视频属性抓取结束
# 开始BV号为1pz4y1R754视频属性的抓取
# BV号为1pz4y1R754的视频属性抓取结束
# 开始BV号为1ip4y1Q7dR视频属性的抓取
# BV号为1ip4y1Q7dR的视频属性抓取结束
# 开始BV号为1dz411v7qE视频属性的抓取
# BV号为1dz411v7qE的视频属性抓取结束
# 开始BV号为1Ev411z7xY视频属性的抓取
# BV号为1Ev411z7xY的视频属性抓取结束
# 开始BV号为1uz4y1d78c视频属性的抓取
# BV号为1uz4y1d78c的视频属性抓取结束
# 开始BV号为1rQ4y1A7xp视频属性的抓取
# BV号为1rQ4y1A7xp的视频属性抓取结束
# 开始BV号为1A5411s7Wr视频属性的抓取
# BV号为1A5411s7Wr的视频属性抓取结束
# 开始BV号为19K411W7kC视频属性的抓取
# BV号为19K411W7kC的视频属性抓取结束
# 开始BV号为1mz411q7ix视频属性的抓取
# BV号为1mz411q7ix的视频属性抓取结束
# 开始BV号为1yp4y1971T视频属性的抓取
# BV号为1yp4y1971T的视频属性抓取结束
# 开始BV号为1vA411q7Fj视频属性的抓取
# BV号为1vA411q7Fj的视频属性抓取结束
# 开始BV号为1tQ4y1T7Kv视频属性的抓取
# BV号为1tQ4y1T7Kv的视频属性抓取结束
# 开始BV号为1Lz411q7pm视频属性的抓取
# BV号为1Lz411q7pm的视频属性抓取结束
# 开始BV号为1vk4y167Mr视频属性的抓取
# BV号为1vk4y167Mr的视频属性抓取结束
# 开始BV号为1xK4y187UE视频属性的抓取
# BV号为1xK4y187UE的视频属性抓取结束
# 开始BV号为1hA411t7Mz视频属性的抓取
# BV号为1hA411t7Mz的视频属性抓取结束
# 开始BV号为1mZ4y1s7f5视频属性的抓取
# BV号为1mZ4y1s7f5的视频属性抓取结束
# 开始BV号为1Ht4y117HL视频属性的抓取
# BV号为1Ht4y117HL的视频属性抓取结束
# 开始BV号为1i54y1Q7MQ视频属性的抓取
# BV号为1i54y1Q7MQ的视频属性抓取结束
# 开始BV号为1UC4y1H7TE视频属性的抓取
# BV号为1UC4y1H7TE的视频属性抓取结束
# 开始BV号为1tv411z7cc视频属性的抓取
# BV号为1tv411z7cc的视频属性抓取结束
# 开始BV号为1ti4y147TA视频属性的抓取
# BV号为1ti4y147TA的视频属性抓取结束
# 开始BV号为1RC4y1h7Qc视频属性的抓取
# BV号为1RC4y1h7Qc的视频属性抓取结束
# 开始BV号为1MK4y1878s视频属性的抓取
# BV号为1MK4y1878s的视频属性抓取结束
# 开始BV号为1Eg4y1B7zm视频属性的抓取
# BV号为1Eg4y1B7zm的视频属性抓取结束
# 开始BV号为1Ta4y1v7NX视频属性的抓取
# BV号为1Ta4y1v7NX的视频属性抓取结束
# 开始BV号为18T4y1g71g视频属性的抓取
# BV号为18T4y1g71g的视频属性抓取结束
# 开始BV号为1JK411W7Ky视频属性的抓取
# BV号为1JK411W7Ky的视频属性抓取结束
# 开始BV号为1ht4y117XT视频属性的抓取
# BV号为1ht4y117XT的视频属性抓取结束
# 开始BV号为1aA411q7yB视频属性的抓取
# BV号为1aA411q7yB的视频属性抓取结束
# 开始BV号为1uQ4y1N7zv视频属性的抓取
# BV号为1uQ4y1N7zv的视频属性抓取结束
# 开始BV号为1gA411873S视频属性的抓取
# BV号为1gA411873S的视频属性抓取结束
# 开始BV号为12f4y1S7aE视频属性的抓取
# BV号为12f4y1S7aE的视频属性抓取结束
# 开始BV号为1mC4y1W7EF视频属性的抓取
# BV号为1mC4y1W7EF的视频属性抓取结束
# 开始BV号为1pe411W7V7视频属性的抓取
# BV号为1pe411W7V7的视频属性抓取结束
# 开始BV号为19g4y1q7o6视频属性的抓取
# BV号为19g4y1q7o6的视频属性抓取结束
# 开始BV号为1FT4y1g7C6视频属性的抓取
# BV号为1FT4y1g7C6的视频属性抓取结束
# 开始BV号为1D54y1X765视频属性的抓取
# BV号为1D54y1X765的视频属性抓取结束
# 开始BV号为1zg4y1B7zX视频属性的抓取
# BV号为1zg4y1B7zX的视频属性抓取结束
# 开始BV号为1FK4y187za视频属性的抓取
# BV号为1FK4y187za的视频属性抓取结束
# 开始BV号为1ft4y1275r视频属性的抓取
# BV号为1ft4y1275r的视频属性抓取结束
# 开始BV号为1LZ4y1s7HD视频属性的抓取
# BV号为1LZ4y1s7HD的视频属性抓取结束
# 开始BV号为1Xk4y167nP视频属性的抓取
# BV号为1Xk4y167nP的视频属性抓取结束
# 开始BV号为1zp4y1U7Z5视频属性的抓取
# BV号为1zp4y1U7Z5的视频属性抓取结束
# 开始BV号为1Rp4y1D7Fk视频属性的抓取
# BV号为1Rp4y1D7Fk的视频属性抓取结束
# 开始BV号为19k4y1q7e7视频属性的抓取
# BV号为19k4y1q7e7的视频属性抓取结束
# 开始BV号为1Nz411v71T视频属性的抓取
# BV号为1Nz411v71T的视频属性抓取结束
# 开始BV号为1VK4y1s7Wd视频属性的抓取
# BV号为1VK4y1s7Wd的视频属性抓取结束
# 开始BV号为1m54y1B7NK视频属性的抓取
# BV号为1m54y1B7NK的视频属性抓取结束
# 开始BV号为1Zz411i7ho视频属性的抓取
# BV号为1Zz411i7ho的视频属性抓取结束
# 开始BV号为1CC4y1a7ee视频属性的抓取
# BV号为1CC4y1a7ee的视频属性抓取结束
# 开始BV号为16D4y1D771视频属性的抓取
# BV号为16D4y1D771的视频属性抓取结束
# 开始BV号为1mi4y1G7uv视频属性的抓取
# BV号为1mi4y1G7uv的视频属性抓取结束
# 开始BV号为1QK411n7hG视频属性的抓取
# BV号为1QK411n7hG的视频属性抓取结束
# 开始BV号为1kg4y1q7JN视频属性的抓取
# BV号为1kg4y1q7JN的视频属性抓取结束
# 开始BV号为1Dp4y1S7EB视频属性的抓取
# BV号为1Dp4y1S7EB的视频属性抓取结束
# 开始BV号为1iA411v7o4视频属性的抓取
# BV号为1iA411v7o4的视频属性抓取结束
# 开始BV号为1kf4y127uc视频属性的抓取
# BV号为1kf4y127uc的视频属性抓取结束
# 开始BV号为1YC4y1a79c视频属性的抓取
# BV号为1YC4y1a79c的视频属性抓取结束
# 开始BV号为1BK4y147CL视频属性的抓取
# BV号为1BK4y147CL的视频属性抓取结束
# 开始BV号为1fK411p79H视频属性的抓取
# BV号为1fK411p79H的视频属性抓取结束
# 开始BV号为1Np4y1D7vQ视频属性的抓取
# BV号为1Np4y1D7vQ的视频属性抓取结束
# 开始BV号为1hC4y187Hd视频属性的抓取
# BV号为1hC4y187Hd的视频属性抓取结束
# 开始BV号为1KZ4y1u7WX视频属性的抓取
# BV号为1KZ4y1u7WX的视频属性抓取结束
# 开始BV号为1pT4y1J76c视频属性的抓取
# BV号为1pT4y1J76c的视频属性抓取结束
# 开始BV号为1M54y1Q7Km视频属性的抓取
# BV号为1M54y1Q7Km的视频属性抓取结束
# 开始BV号为1YV411k7E5视频属性的抓取
# BV号为1YV411k7E5的视频属性抓取结束
# 开始BV号为1Bi4y1x7Lw视频属性的抓取
# BV号为1Bi4y1x7Lw的视频属性抓取结束
# 开始BV号为1vK4y1x7Fg视频属性的抓取
# BV号为1vK4y1x7Fg的视频属性抓取结束
# 开始BV号为1wt4y197SD视频属性的抓取
# BV号为1wt4y197SD的视频属性抓取结束
# 开始BV号为1SK4y1x7QN视频属性的抓取
# BV号为1SK4y1x7QN的视频属性抓取结束
# 开始BV号为1YV411r7Q6视频属性的抓取
# BV号为1YV411r7Q6的视频属性抓取结束
# 开始BV号为1uK4y147hE视频属性的抓取
# BV号为1uK4y147hE的视频属性抓取结束
# 开始BV号为12V411r7Ph视频属性的抓取
# BV号为12V411r7Ph的视频属性抓取结束
# 开始BV号为1B5411W7R9视频属性的抓取
# BV号为1B5411W7R9的视频属性抓取结束
# 开始BV号为1k54y1B7WM视频属性的抓取
# BV号为1k54y1B7WM的视频属性抓取结束
# 开始BV号为1fp4y1S7vZ视频属性的抓取
# BV号为1fp4y1S7vZ的视频属性抓取结束
# 开始BV号为1BK4y147Je视频属性的抓取
# BV号为1BK4y147Je的视频属性抓取结束
# 开始BV号为1H5411Y71R视频属性的抓取
# BV号为1H5411Y71R的视频属性抓取结束
# 开始BV号为1np4y1D7D7视频属性的抓取
# BV号为1np4y1D7D7的视频属性抓取结束
# 开始BV号为19K4y1t7Uz视频属性的抓取
# BV号为19K4y1t7Uz的视频属性抓取结束
# 开始BV号为1aZ4y1H7wy视频属性的抓取
# BV号为1aZ4y1H7wy的视频属性抓取结束
# 开始BV号为1Kz4y1X7tF视频属性的抓取
# BV号为1Kz4y1X7tF的视频属性抓取结束
# 开始BV号为1Kk4y1z7Sb视频属性的抓取
# BV号为1Kk4y1z7Sb的视频属性抓取结束
# 开始BV号为13T4y1J7bS视频属性的抓取
# BV号为13T4y1J7bS的视频属性抓取结束
# 开始BV号为1fv411q7jQ视频属性的抓取
# BV号为1fv411q7jQ的视频属性抓取结束
# 开始BV号为1Gt4y1971Z视频属性的抓取
# BV号为1Gt4y1971Z的视频属性抓取结束
# 开始BV号为1p54y1Q7QE视频属性的抓取
# BV号为1p54y1Q7QE的视频属性抓取结束
# 开始BV号为1oK411H7bH视频属性的抓取
# BV号为1oK411H7bH的视频属性抓取结束
# 开始BV号为1fZ4y1H7KV视频属性的抓取
# BV号为1fZ4y1H7KV的视频属性抓取结束
# 开始BV号为1AA411i7ph视频属性的抓取
# BV号为1AA411i7ph的视频属性抓取结束
# 开始BV号为1jv411B7LT视频属性的抓取
# BV号为1jv411B7LT的视频属性抓取结束
# 开始BV号为1KT4y1J7nw视频属性的抓取
# BV号为1KT4y1J7nw的视频属性抓取结束
# 开始BV号为1yA411q7pc视频属性的抓取
# BV号为1yA411q7pc的视频属性抓取结束
# 开始BV号为1wg4y1q7NN视频属性的抓取
# BV号为1wg4y1q7NN的视频属性抓取结束
# 开始BV号为1qf4y1y7VJ视频属性的抓取
# BV号为1qf4y1y7VJ的视频属性抓取结束
# 开始BV号为19C4y187RA视频属性的抓取
# BV号为19C4y187RA的视频属性抓取结束
# 开始BV号为1Mk4y1z7qr视频属性的抓取
# BV号为1Mk4y1z7qr的视频属性抓取结束
# 开始BV号为1rC4y1a7pW视频属性的抓取
# BV号为1rC4y1a7pW的视频属性抓取结束
# 开始BV号为1ka4y1Y7U4视频属性的抓取
# BV号为1ka4y1Y7U4的视频属性抓取结束
# 开始BV号为1rK4y1x7K3视频属性的抓取
# BV号为1rK4y1x7K3的视频属性抓取结束
# 开始BV号为1xp4y1D7nw视频属性的抓取
# BV号为1xp4y1D7nw的视频属性抓取结束
# 开始BV号为19K411p7Jf视频属性的抓取
# BV号为19K411p7Jf的视频属性抓取结束
# 开始BV号为17v411B7qW视频属性的抓取
# BV号为17v411B7qW的视频属性抓取结束
# 开始BV号为1tC4y1a7VQ视频属性的抓取
# BV号为1tC4y1a7VQ的视频属性抓取结束
# 开始BV号为1YC4y1876o视频属性的抓取
# 开始BV号为1YC4y1876o视频属性的抓取
# BV号为1YC4y1876o的视频属性抓取结束
# 开始BV号为1eA411v7TZ视频属性的抓取
# BV号为1eA411v7TZ的视频属性抓取结束
# 开始BV号为19A411q7sB视频属性的抓取
# BV号为19A411q7sB的视频属性抓取结束
# 开始BV号为1kT4y1J7vg视频属性的抓取
# BV号为1kT4y1J7vg的视频属性抓取结束
# 开始BV号为1ya4y1h7xv视频属性的抓取
# BV号为1ya4y1h7xv的视频属性抓取结束
# 开始BV号为1Fa4y1e7tJ视频属性的抓取
# BV号为1Fa4y1e7tJ的视频属性抓取结束
# 开始BV号为1yD4y1D7FJ视频属性的抓取
# BV号为1yD4y1D7FJ的视频属性抓取结束
# 开始BV号为1Fz411i7o9视频属性的抓取
# BV号为1Fz411i7o9的视频属性抓取结束
# 开始BV号为1fz4y197L1视频属性的抓取
# BV号为1fz4y197L1的视频属性抓取结束
# 开始BV号为1dC4y1a75Q视频属性的抓取
# BV号为1dC4y1a75Q的视频属性抓取结束
# 开始BV号为1L5411W7N2视频属性的抓取
# BV号为1L5411W7N2的视频属性抓取结束
# 开始BV号为1cC4y1a7JC视频属性的抓取
# BV号为1cC4y1a7JC的视频属性抓取结束
# 开始BV号为1Rv411B7GX视频属性的抓取
# BV号为1Rv411B7GX的视频属性抓取结束
# 开始BV号为1WK411p7zA视频属性的抓取
# BV号为1WK411p7zA的视频属性抓取结束
# 开始BV号为1zf4y117Xr视频属性的抓取
# BV号为1zf4y117Xr的视频属性抓取结束
# 开始BV号为1jV41167Cu视频属性的抓取
# BV号为1jV41167Cu的视频属性抓取结束
# 开始BV号为1tD4y1D7Sf视频属性的抓取
# BV号为1tD4y1D7Sf的视频属性抓取结束
# 开始BV号为1MZ4y1H7fX视频属性的抓取
# BV号为1MZ4y1H7fX的视频属性抓取结束
# 开始BV号为1Cg4y1i7QV视频属性的抓取
# BV号为1Cg4y1i7QV的视频属性抓取结束
# 开始BV号为1pK411p7bd视频属性的抓取
# BV号为1pK411p7bd的视频属性抓取结束
# 开始BV号为1az411i74h视频属性的抓取
# BV号为1az411i74h的视频属性抓取结束
# 开始BV号为1yD4y1D7qZ视频属性的抓取
# BV号为1yD4y1D7qZ的视频属性抓取结束
# 开始BV号为1dz4y197fc视频属性的抓取
# BV号为1dz4y197fc的视频属性抓取结束
# 开始BV号为1e5411Y7Gz视频属性的抓取
# BV号为1e5411Y7Gz的视频属性抓取结束
# 开始BV号为1vK4y147tZ视频属性的抓取
# BV号为1vK4y147tZ的视频属性抓取结束
# 开始BV号为1fg4y1i7Nf视频属性的抓取
# BV号为1fg4y1i7Nf的视频属性抓取结束
# 开始BV号为1Rv411q7WE视频属性的抓取
# BV号为1Rv411q7WE的视频属性抓取结束
# 开始BV号为13t4y197G7视频属性的抓取
# BV号为13t4y197G7的视频属性抓取结束
# 开始BV号为1HD4y1D79n视频属性的抓取
# BV号为1HD4y1D79n的视频属性抓取结束
# 开始BV号为1ji4y1x7fz视频属性的抓取
# BV号为1ji4y1x7fz的视频属性抓取结束
# 开始BV号为1rf4y1279i视频属性的抓取
# BV号为1rf4y1279i的视频属性抓取结束
# 开始BV号为1KC4y1h7rD视频属性的抓取
# BV号为1KC4y1h7rD的视频属性抓取结束
# 开始BV号为1Pp4y1Q74n视频属性的抓取
# BV号为1Pp4y1Q74n的视频属性抓取结束
# 开始BV号为1WK4y147Qd视频属性的抓取
# BV号为1WK4y147Qd的视频属性抓取结束
# 开始BV号为1pz4y197r9视频属性的抓取
# BV号为1pz4y197r9的视频属性抓取结束
# 开始BV号为1ya4y1Y744视频属性的抓取
# BV号为1ya4y1Y744的视频属性抓取结束
# 开始BV号为1854y1Q7Y3视频属性的抓取
# BV号为1854y1Q7Y3的视频属性抓取结束
# 开始BV号为11z411e7z4视频属性的抓取
# BV号为11z411e7z4的视频属性抓取结束
# 开始BV号为1T54y1i7ib视频属性的抓取
# BV号为1T54y1i7ib的视频属性抓取结束
# 开始BV号为1Wi4y137Kq视频属性的抓取
# BV号为1Wi4y137Kq的视频属性抓取结束
# 开始BV号为1854y1S7Un视频属性的抓取
# BV号为1854y1S7Un的视频属性抓取结束
# 开始BV号为1hA411e75w视频属性的抓取
# BV号为1hA411e75w的视频属性抓取结束
# 开始BV号为1Kf4y1R7EN视频属性的抓取
# BV号为1Kf4y1R7EN的视频属性抓取结束
# 开始BV号为1gz4y1Q7fb视频属性的抓取
# BV号为1gz4y1Q7fb的视频属性抓取结束
# 开始BV号为1DZ4y1u7Ye视频属性的抓取
# BV号为1DZ4y1u7Ye的视频属性抓取结束
# 开始BV号为1F64y1c7CJ视频属性的抓取
# BV号为1F64y1c7CJ的视频属性抓取结束
# 开始BV号为1xK411H7Le视频属性的抓取
# BV号为1xK411H7Le的视频属性抓取结束
# 开始BV号为1fV41167tv视频属性的抓取
# BV号为1fV41167tv的视频属性抓取结束
# 开始BV号为13z4y1D7t4视频属性的抓取
# BV号为13z4y1D7t4的视频属性抓取结束
# 开始BV号为1az4y1D73Y视频属性的抓取
# BV号为1az4y1D73Y的视频属性抓取结束
# 开始BV号为1cD4y1D7My视频属性的抓取
# BV号为1cD4y1D7My的视频属性抓取结束
# 开始BV号为1rf4y1X7Pm视频属性的抓取
# BV号为1rf4y1X7Pm的视频属性抓取结束
# 开始BV号为1Af4y1d7j3视频属性的抓取
# BV号为1Af4y1d7j3的视频属性抓取结束
# 开始BV号为1DT4y1j78V视频属性的抓取
# BV号为1DT4y1j78V的视频属性抓取结束
# 开始BV号为1rT4y1775K视频属性的抓取
# BV号为1rT4y1775K的视频属性抓取结束
# 开始BV号为1CK4y1s7Nc视频属性的抓取
# BV号为1CK4y1s7Nc的视频属性抓取结束
# 开始BV号为1FC4y187SK视频属性的抓取
# BV号为1FC4y187SK的视频属性抓取结束
# 开始BV号为1YC4y1871D视频属性的抓取
# BV号为1YC4y1871D的视频属性抓取结束
# 开始BV号为1Eh411o76E视频属性的抓取
# BV号为1Eh411o76E的视频属性抓取结束
# 开始BV号为1zV41167cZ视频属性的抓取
# BV号为1zV41167cZ的视频属性抓取结束
# 开始BV号为1At4y1X7tU视频属性的抓取
# BV号为1At4y1X7tU的视频属性抓取结束
# 开始BV号为1k54y1q7wB视频属性的抓取
# BV号为1k54y1q7wB的视频属性抓取结束
# 开始BV号为1yv411B7Rk视频属性的抓取
# BV号为1yv411B7Rk的视频属性抓取结束
# 开始BV号为12k4y1m792视频属性的抓取
# BV号为12k4y1m792的视频属性抓取结束
# 开始BV号为1L5411Y7gr视频属性的抓取
# BV号为1L5411Y7gr的视频属性抓取结束
# 开始BV号为1hK4y1x7K5视频属性的抓取
# BV号为1hK4y1x7K5的视频属性抓取结束
# 开始BV号为1Eh411o73B视频属性的抓取
# BV号为1Eh411o73B的视频属性抓取结束
# 开始BV号为1Z5411Y7ot视频属性的抓取
# BV号为1Z5411Y7ot的视频属性抓取结束
# 开始BV号为19D4y1S7iU视频属性的抓取
# BV号为19D4y1S7iU的视频属性抓取结束
# 开始BV号为1Rv411i71p视频属性的抓取
# BV号为1Rv411i71p的视频属性抓取结束
# 开始BV号为17C4y1h74h视频属性的抓取
# BV号为17C4y1h74h的视频属性抓取结束
# 开始BV号为1hC4y1b7UH视频属性的抓取
# BV号为1hC4y1b7UH的视频属性抓取结束
# 开始BV号为1Dz4y1D79T视频属性的抓取
# BV号为1Dz4y1D79T的视频属性抓取结束
# 开始BV号为1RT4y1J7rs视频属性的抓取
# BV号为1RT4y1J7rs的视频属性抓取结束
# 开始BV号为135411e73M视频属性的抓取
# BV号为135411e73M的视频属性抓取结束
# 开始BV号为1o54y1U7RT视频属性的抓取
# BV号为1o54y1U7RT的视频属性抓取结束
# 开始BV号为14D4y1S7jc视频属性的抓取
# BV号为14D4y1S7jc的视频属性抓取结束
# 开始BV号为1RA411e7No视频属性的抓取
# BV号为1RA411e7No的视频属性抓取结束
# 开始BV号为1va4y1a7fo视频属性的抓取
# BV号为1va4y1a7fo的视频属性抓取结束
# 开始BV号为1Eh411Z7wt视频属性的抓取
# BV号为1Eh411Z7wt的视频属性抓取结束
# 开始BV号为1VA411Y7iG视频属性的抓取
# BV号为1VA411Y7iG的视频属性抓取结束
# 开始BV号为1sK411J7Jq视频属性的抓取
# BV号为1sK411J7Jq的视频属性抓取结束
# 开始BV号为1Aa4y1a7HP视频属性的抓取
# BV号为1Aa4y1a7HP的视频属性抓取结束
# 开始BV号为1Qk4y1q7US视频属性的抓取
# BV号为1Qk4y1q7US的视频属性抓取结束
# 开始BV号为1Qp4y1i7qW视频属性的抓取
# BV号为1Qp4y1i7qW的视频属性抓取结束
# 开始BV号为1aK411H7e1视频属性的抓取
# BV号为1aK411H7e1的视频属性抓取结束
# 开始BV号为17f4y1R7ic视频属性的抓取
# BV号为17f4y1R7ic的视频属性抓取结束
# 开始BV号为1D54y1i7Zr视频属性的抓取
# BV号为1D54y1i7Zr的视频属性抓取结束
# 开始BV号为1iz411v7dT视频属性的抓取
# BV号为1iz411v7dT的视频属性抓取结束
# 开始BV号为1yK411H734视频属性的抓取
# BV号为1yK411H734的视频属性抓取结束
# 开始BV号为1sa4y1a7Co视频属性的抓取
# BV号为1sa4y1a7Co的视频属性抓取结束
# 开始BV号为1aK4y1s7mR视频属性的抓取
# BV号为1aK4y1s7mR的视频属性抓取结束
# 开始BV号为1h54y1S7Hs视频属性的抓取
# BV号为1h54y1S7Hs的视频属性抓取结束
# 开始BV号为1yV411672a视频属性的抓取
# BV号为1yV411672a的视频属性抓取结束
# 开始BV号为18C4y1h7yQ视频属性的抓取
# BV号为18C4y1h7yQ的视频属性抓取结束
# 开始BV号为1ip4y1S7tG视频属性的抓取
# 开始BV号为1ip4y1S7tG视频属性的抓取
# 开始BV号为1ip4y1S7tG视频属性的抓取
# BV号为1ip4y1S7tG的视频属性抓取结束
# 开始BV号为1K54y1S7d3视频属性的抓取
# BV号为1K54y1S7d3的视频属性抓取结束
# 开始BV号为13h411Z7b5视频属性的抓取
# BV号为13h411Z7b5的视频属性抓取结束
# 开始BV号为1ik4y1m7uz视频属性的抓取
# BV号为1ik4y1m7uz的视频属性抓取结束
# 开始BV号为18f4y1R78C视频属性的抓取
# BV号为18f4y1R78C的视频属性抓取结束
# 开始BV号为12K4y1e7cC视频属性的抓取
# 开始BV号为12K4y1e7cC视频属性的抓取
# 开始BV号为12K4y1e7cC视频属性的抓取
# BV号为12K4y1e7cC的视频属性抓取结束
# 开始BV号为1xk4y1B7pa视频属性的抓取
# BV号为1xk4y1B7pa的视频属性抓取结束
# 开始BV号为1sf4y117nL视频属性的抓取
# BV号为1sf4y117nL的视频属性抓取结束
# 开始BV号为1rp4y1i7R1视频属性的抓取
# BV号为1rp4y1i7R1的视频属性抓取结束
# 开始BV号为1Ki4y1V7DD视频属性的抓取
# BV号为1Ki4y1V7DD的视频属性抓取结束
# 开始BV号为1zV411z7Tp视频属性的抓取
# BV号为1zV411z7Tp的视频属性抓取结束
# 开始BV号为1pD4y1Q7q7视频属性的抓取
# BV号为1pD4y1Q7q7的视频属性抓取结束
# 开始BV号为1VV411z7gg视频属性的抓取
# BV号为1VV411z7gg的视频属性抓取结束
# 开始BV号为1ET4y1773Y视频属性的抓取
# BV号为1ET4y1773Y的视频属性抓取结束
# 开始BV号为1tA411v7vW视频属性的抓取
# BV号为1tA411v7vW的视频属性抓取结束
# 开始BV号为1ot4y1Q7Xr视频属性的抓取
# BV号为1ot4y1Q7Xr的视频属性抓取结束
# 开始BV号为1Tz4y1Q7Jt视频属性的抓取
# BV号为1Tz4y1Q7Jt的视频属性抓取结束
# 开始BV号为1Rk4y127X3视频属性的抓取
# BV号为1Rk4y127X3的视频属性抓取结束
# 开始BV号为1hV41167VD视频属性的抓取
# BV号为1hV41167VD的视频属性抓取结束
# 开始BV号为1o54y1q7pW视频属性的抓取
# BV号为1o54y1q7pW的视频属性抓取结束
# 开始BV号为1GC4y1h7oJ视频属性的抓取
# BV号为1GC4y1h7oJ的视频属性抓取结束
# 开始BV号为1Lk4y1m77o视频属性的抓取
# BV号为1Lk4y1m77o的视频属性抓取结束
# 开始BV号为1jv411q7zk视频属性的抓取
# BV号为1jv411q7zk的视频属性抓取结束
# 开始BV号为1bp4y1U79L视频属性的抓取
# BV号为1bp4y1U79L的视频属性抓取结束
# 开始BV号为1UA411e7cc视频属性的抓取
# BV号为1UA411e7cc的视频属性抓取结束
# 开始BV号为1ZT4y177AG视频属性的抓取
# BV号为1ZT4y177AG的视频属性抓取结束
# 开始BV号为1QK411J7tZ视频属性的抓取
# BV号为1QK411J7tZ的视频属性抓取结束
# 开始BV号为1dk4y127By视频属性的抓取
# BV号为1dk4y127By的视频属性抓取结束
# 开始BV号为1Wi4y137ai视频属性的抓取
# BV号为1Wi4y137ai的视频属性抓取结束
# 开始BV号为1EA411Y7fq视频属性的抓取
# BV号为1EA411Y7fq的视频属性抓取结束
# 开始BV号为19C4y1b7ST视频属性的抓取
# BV号为19C4y1b7ST的视频属性抓取结束
# 开始BV号为1ki4y1G7qc视频属性的抓取
# BV号为1ki4y1G7qc的视频属性抓取结束
# 开始BV号为1Lz4y1X7RW视频属性的抓取
# BV号为1Lz4y1X7RW的视频属性抓取结束
# 开始BV号为1ag4y1v7D9视频属性的抓取
# BV号为1ag4y1v7D9的视频属性抓取结束
# 开始BV号为1kf4y1X7LV视频属性的抓取
# BV号为1kf4y1X7LV的视频属性抓取结束
# 开始BV号为1di4y137Th视频属性的抓取
# BV号为1di4y137Th的视频属性抓取结束
# 开始BV号为19a4y1h721视频属性的抓取
# BV号为19a4y1h721的视频属性抓取结束
# 开始BV号为1QK411J72k视频属性的抓取
# BV号为1QK411J72k的视频属性抓取结束
# 开始BV号为1bz411v7oZ视频属性的抓取
# BV号为1bz411v7oZ的视频属性抓取结束
# 开始BV号为11t4y1Q7rh视频属性的抓取
# BV号为11t4y1Q7rh的视频属性抓取结束
# 开始BV号为1Ra4y1E7hM视频属性的抓取
# BV号为1Ra4y1E7hM的视频属性抓取结束
# 开始BV号为1E5411e79c视频属性的抓取
# BV号为1E5411e79c的视频属性抓取结束
# 开始BV号为1Rt4y1Q7Mb视频属性的抓取
# BV号为1Rt4y1Q7Mb的视频属性抓取结束
# 开始BV号为1bi4y1g7zM视频属性的抓取
# BV号为1bi4y1g7zM的视频属性抓取结束
# 开始BV号为1uZ4y1K7mA视频属性的抓取
# BV号为1uZ4y1K7mA的视频属性抓取结束
# 开始BV号为1Lp4y1q7Ly视频属性的抓取
# BV号为1Lp4y1q7Ly的视频属性抓取结束
# 开始BV号为1gv41117zN视频属性的抓取
# BV号为1gv41117zN的视频属性抓取结束
# 开始BV号为11v411v7iS视频属性的抓取
# BV号为11v411v7iS的视频属性抓取结束
# 开始BV号为1sA411n72J视频属性的抓取
# BV号为1sA411n72J的视频属性抓取结束
# 开始BV号为1Yh411d7zz视频属性的抓取
# BV号为1Yh411d7zz的视频属性抓取结束
# 开始BV号为1mV41127jt视频属性的抓取
# BV号为1mV41127jt的视频属性抓取结束
# 开始BV号为1oh411d7b1视频属性的抓取
# BV号为1oh411d7b1的视频属性抓取结束
# 开始BV号为1nZ4y1K7gS视频属性的抓取
# BV号为1nZ4y1K7gS的视频属性抓取结束
# 开始BV号为11A411Y7m3视频属性的抓取
# BV号为11A411Y7m3的视频属性抓取结束
# 开始BV号为16t4y1S7wY视频属性的抓取
# BV号为16t4y1S7wY的视频属性抓取结束
# 开始BV号为1ci4y1g7cV视频属性的抓取
# BV号为1ci4y1g7cV的视频属性抓取结束
# 开始BV号为1LZ4y1T7b7视频属性的抓取
# BV号为1LZ4y1T7b7的视频属性抓取结束
# 开始BV号为1dh41197my视频属性的抓取
# BV号为1dh41197my的视频属性抓取结束
# 开始BV号为1AA411H74Z视频属性的抓取
# BV号为1AA411H74Z的视频属性抓取结束
# 开始BV号为17h411d7C3视频属性的抓取
# BV号为17h411d7C3的视频属性抓取结束
# 开始BV号为15a4y1J7z9视频属性的抓取
# BV号为15a4y1J7z9的视频属性抓取结束
# 开始BV号为1ET4y1L7jk视频属性的抓取
# BV号为1ET4y1L7jk的视频属性抓取结束
# 开始BV号为1aC4y1t7p6视频属性的抓取
# BV号为1aC4y1t7p6的视频属性抓取结束
# 开始BV号为15i4y1g7wL视频属性的抓取
# BV号为15i4y1g7wL的视频属性抓取结束
# 开始BV号为1Jh411d7dv视频属性的抓取
# BV号为1Jh411d7dv的视频属性抓取结束
# 开始BV号为16p4y1q7BS视频属性的抓取
# 开始BV号为16p4y1q7BS视频属性的抓取
# BV号为16p4y1q7BS的视频属性抓取结束
# 开始BV号为17a4y1E7oj视频属性的抓取
# BV号为17a4y1E7oj的视频属性抓取结束
# 开始BV号为1oh411R7C1视频属性的抓取
# BV号为1oh411R7C1的视频属性抓取结束
# 开始BV号为11i4y1u7Ui视频属性的抓取
# BV号为11i4y1u7Ui的视频属性抓取结束
# 开始BV号为1u54y1i7h6视频属性的抓取
# BV号为1u54y1i7h6的视频属性抓取结束
# 开始BV号为1NZ4y1T7wh视频属性的抓取
# BV号为1NZ4y1T7wh的视频属性抓取结束
# 开始BV号为1aD4y1m7dn视频属性的抓取
# BV号为1aD4y1m7dn的视频属性抓取结束
# 开始BV号为1Rt4y1U741视频属性的抓取
# BV号为1Rt4y1U741的视频属性抓取结束
# 开始BV号为1RD4y1m7hJ视频属性的抓取
# BV号为1RD4y1m7hJ的视频属性抓取结束
# 开始BV号为1dp4y1Y7Nk视频属性的抓取
# BV号为1dp4y1Y7Nk的视频属性抓取结束
# 开始BV号为1KK411T7S7视频属性的抓取
# BV号为1KK411T7S7的视频属性抓取结束
# 开始BV号为1Mh411o7Vr视频属性的抓取
# BV号为1Mh411o7Vr的视频属性抓取结束
# 开始BV号为1y64y1c7gj视频属性的抓取
# BV号为1y64y1c7gj的视频属性抓取结束
# 开始BV号为1QC4y1t7rM视频属性的抓取
# BV号为1QC4y1t7rM的视频属性抓取结束
# 开始BV号为1Yp4y1v7mC视频属性的抓取
# BV号为1Yp4y1v7mC的视频属性抓取结束
# 开始BV号为1m54y1e7dH视频属性的抓取
# BV号为1m54y1e7dH的视频属性抓取结束
# 开始BV号为1kZ4y1M7ge视频属性的抓取
# BV号为1kZ4y1M7ge的视频属性抓取结束
# 开始BV号为1Q54y1m7z2视频属性的抓取
# BV号为1Q54y1m7z2的视频属性抓取结束
# 开始BV号为18V411U76A视频属性的抓取
# BV号为18V411U76A的视频属性抓取结束
# 开始BV号为1Yv411v7L8视频属性的抓取
# BV号为1Yv411v7L8的视频属性抓取结束
# 开始BV号为1Ua4y1E7n7视频属性的抓取
# BV号为1Ua4y1E7n7的视频属性抓取结束
# 开始BV号为1WC4y1t7Aj视频属性的抓取
# BV号为1WC4y1t7Aj的视频属性抓取结束
# 开始BV号为1Y541187Lc视频属性的抓取
# BV号为1Y541187Lc的视频属性抓取结束
# 开始BV号为1bh411d744视频属性的抓取
# BV号为1bh411d744的视频属性抓取结束
# 开始BV号为1ka4y1J7Pi视频属性的抓取
# BV号为1ka4y1J7Pi的视频属性抓取结束
# 开始BV号为1L54y127iM视频属性的抓取
# BV号为1L54y127iM的视频属性抓取结束
# 开始BV号为1gD4y1m79q视频属性的抓取
# BV号为1gD4y1m79q的视频属性抓取结束
# 开始BV号为1Uv411v7mM视频属性的抓取
# BV号为1Uv411v7mM的视频属性抓取结束
# 开始BV号为1L5411a75k视频属性的抓取
# BV号为1L5411a75k的视频属性抓取结束
# 开始BV号为1Ja4y1J7hu视频属性的抓取
# BV号为1Ja4y1J7hu的视频属性抓取结束
# 开始BV号为1HC4y187eX视频属性的抓取
# BV号为1HC4y187eX的视频属性抓取结束
# 开始BV号为1zZ4y1M71U视频属性的抓取
# BV号为1zZ4y1M71U的视频属性抓取结束
# 开始BV号为1sC4y187qG视频属性的抓取
# BV号为1sC4y187qG的视频属性抓取结束
# 开始BV号为1Ph411R7BY视频属性的抓取
# BV号为1Ph411R7BY的视频属性抓取结束
# 开始BV号为1xK411T7Zs视频属性的抓取
# BV号为1xK411T7Zs的视频属性抓取结束
# 开始BV号为1pT4y1L7ff视频属性的抓取
# BV号为1pT4y1L7ff的视频属性抓取结束
# 开始BV号为1Np4y1i791视频属性的抓取
# BV号为1Np4y1i791的视频属性抓取结束
# 开始BV号为1Pt4y1Q7Kd视频属性的抓取
# BV号为1Pt4y1Q7Kd的视频属性抓取结束
# 开始BV号为1LK4y1e7FJ视频属性的抓取
# BV号为1LK4y1e7FJ的视频属性抓取结束
# 开始BV号为1eD4y1m79B视频属性的抓取
# BV号为1eD4y1m79B的视频属性抓取结束
# 开始BV号为1Vv411v7z9视频属性的抓取
# BV号为1Vv411v7z9的视频属性抓取结束
# 开始BV号为1W541187sY视频属性的抓取
# BV号为1W541187sY的视频属性抓取结束
# 开始BV号为1UK411N72v视频属性的抓取
# BV号为1UK411N72v的视频属性抓取结束
# 开始BV号为12A411J7LP视频属性的抓取
# BV号为12A411J7LP的视频属性抓取结束
# 开始BV号为1fZ4y1T7vC视频属性的抓取
# BV号为1fZ4y1T7vC的视频属性抓取结束
# 开始BV号为1eA411Y7o2视频属性的抓取
# BV号为1eA411Y7o2的视频属性抓取结束
# 开始BV号为1Vz4y1Q7T6视频属性的抓取
# BV号为1Vz4y1Q7T6的视频属性抓取结束
# 开始BV号为1M64y1c7o3视频属性的抓取
# BV号为1M64y1c7o3的视频属性抓取结束
# 开始BV号为1dV411z7pa视频属性的抓取
# BV号为1dV411z7pa的视频属性抓取结束
# 开始BV号为1tt4y1D7HK视频属性的抓取
# BV号为1tt4y1D7HK的视频属性抓取结束
# 开始BV号为1864y1c7CR视频属性的抓取
# BV号为1864y1c7CR的视频属性抓取结束
# 开始BV号为1Kf4y197RU视频属性的抓取
# BV号为1Kf4y197RU的视频属性抓取结束
# 开始BV号为16V411z7eE视频属性的抓取
# BV号为16V411z7eE的视频属性抓取结束
# 开始BV号为1DK4y1Y7Mc视频属性的抓取
# BV号为1DK4y1Y7Mc的视频属性抓取结束
# 开始BV号为1S54y1U7kU视频属性的抓取
# BV号为1S54y1U7kU的视频属性抓取结束
# 开始BV号为1tv411i7VG视频属性的抓取
# BV号为1tv411i7VG的视频属性抓取结束
# 开始BV号为1sh411R7AY视频属性的抓取
# BV号为1sh411R7AY的视频属性抓取结束
# 开始BV号为1Ui4y1M7YT视频属性的抓取
# BV号为1Ui4y1M7YT的视频属性抓取结束
# 开始BV号为1ZC4y1t7HG视频属性的抓取
# BV号为1ZC4y1t7HG的视频属性抓取结束
# 开始BV号为1mk4y127et视频属性的抓取
# BV号为1mk4y127et的视频属性抓取结束
# 开始BV号为1Dp4y1v7mc视频属性的抓取
# BV号为1Dp4y1v7mc的视频属性抓取结束
# 开始BV号为1n64y1c77A视频属性的抓取
# BV号为1n64y1c77A的视频属性抓取结束
# 开始BV号为1B54y1U7xd视频属性的抓取
# BV号为1B54y1U7xd的视频属性抓取结束
# 开始BV号为1SD4y127Sh视频属性的抓取
# BV号为1SD4y127Sh的视频属性抓取结束
# 开始BV号为1Sh41197SK视频属性的抓取
# BV号为1Sh41197SK的视频属性抓取结束
# 开始BV号为1eh411d7hQ视频属性的抓取
# BV号为1eh411d7hQ的视频属性抓取结束
# 开始BV号为1q5411a7uG视频属性的抓取
# BV号为1q5411a7uG的视频属性抓取结束
# 开始BV号为1VZ4y1T7hT视频属性的抓取
# BV号为1VZ4y1T7hT的视频属性抓取结束
# 开始BV号为1xK411T7Kw视频属性的抓取
# BV号为1xK411T7Kw的视频属性抓取结束
# 开始BV号为1Y5411a7HG视频属性的抓取
# BV号为1Y5411a7HG的视频属性抓取结束
# 开始BV号为1Ki4y1g7Uo视频属性的抓取
# BV号为1Ki4y1g7Uo的视频属性抓取结束
# 开始BV号为19T4y157HG视频属性的抓取
# BV号为19T4y157HG的视频属性抓取结束
# 开始BV号为1xk4y1271a视频属性的抓取
# BV号为1xk4y1271a的视频属性抓取结束
# 开始BV号为1Vk4y1y7SF视频属性的抓取
# BV号为1Vk4y1y7SF的视频属性抓取结束
# 开始BV号为1Z541187Rs视频属性的抓取
# BV号为1Z541187Rs的视频属性抓取结束
# 开始BV号为19K411J7NQ视频属性的抓取
# BV号为19K411J7NQ的视频属性抓取结束
# 开始BV号为19A411n7av视频属性的抓取
# BV号为19A411n7av的视频属性抓取结束
# 开始BV号为1oZ4y1N7fY视频属性的抓取
# BV号为1oZ4y1N7fY的视频属性抓取结束
# 开始BV号为1Ct4y1q7nH视频属性的抓取
# BV号为1Ct4y1q7nH的视频属性抓取结束
# 开始BV号为1oK411K7JX视频属性的抓取
# BV号为1oK411K7JX的视频属性抓取结束
# 开始BV号为1dh411R7Ps视频属性的抓取
# BV号为1dh411R7Ps的视频属性抓取结束
# 开始BV号为1Dh411R7kQ视频属性的抓取
# BV号为1Dh411R7kQ的视频属性抓取结束
# 开始BV号为1E54y1y7mB视频属性的抓取
# BV号为1E54y1y7mB的视频属性抓取结束
# 开始BV号为1LZ4y1N7tG视频属性的抓取
# BV号为1LZ4y1N7tG的视频属性抓取结束
# 开始BV号为1Ef4y1D7q1视频属性的抓取
# BV号为1Ef4y1D7q1的视频属性抓取结束
# 开始BV号为145411h7r9视频属性的抓取
# BV号为145411h7r9的视频属性抓取结束
# 开始BV号为1WV411m7Zp视频属性的抓取
# BV号为1WV411m7Zp的视频属性抓取结束
# 开始BV号为1w64y1F7ym视频属性的抓取
# BV号为1w64y1F7ym的视频属性抓取结束
# 开始BV号为1qv411C7c2视频属性的抓取
# BV号为1qv411C7c2的视频属性抓取结束
# 开始BV号为1J54y1m7G8视频属性的抓取
# 开始BV号为1J54y1m7G8视频属性的抓取
# BV号为1J54y1m7G8的视频属性抓取结束
# 开始BV号为1G54y117ZU视频属性的抓取
# BV号为1G54y117ZU的视频属性抓取结束
# 开始BV号为1xK411P7Pk视频属性的抓取
# BV号为1xK411P7Pk的视频属性抓取结束
# 开始BV号为1ev411173V视频属性的抓取
# BV号为1ev411173V的视频属性抓取结束
# 开始BV号为1ah411X7QS视频属性的抓取
# BV号为1ah411X7QS的视频属性抓取结束
# 开始BV号为1Ta4y1E7o2视频属性的抓取
# BV号为1Ta4y1E7o2的视频属性抓取结束
# 开始BV号为1rv411C7Uq视频属性的抓取
# BV号为1rv411C7Uq的视频属性抓取结束
# 开始BV号为16h41197c2视频属性的抓取
# BV号为16h41197c2的视频属性抓取结束
# 开始BV号为1Dz4y1f7vZ视频属性的抓取
# BV号为1Dz4y1f7vZ的视频属性抓取结束
# 开始BV号为16f4y1D7PA视频属性的抓取
# BV号为16f4y1D7PA的视频属性抓取结束
# 开始BV号为1RK411P7u8视频属性的抓取
# BV号为1RK411P7u8的视频属性抓取结束
# 开始BV号为1Qk4y1y7uU视频属性的抓取
# BV号为1Qk4y1y7uU的视频属性抓取结束
# 开始BV号为1B5411b72K视频属性的抓取
# BV号为1B5411b72K的视频属性抓取结束
# 开始BV号为1Fz4y1Z7uA视频属性的抓取
# BV号为1Fz4y1Z7uA的视频属性抓取结束
# 开始BV号为1UV41127xF视频属性的抓取
# BV号为1UV41127xF的视频属性抓取结束
# 开始BV号为1554y117np视频属性的抓取
# BV号为1554y117np的视频属性抓取结束
# 开始BV号为1Ep4y1e7Wv视频属性的抓取
# BV号为1Ep4y1e7Wv的视频属性抓取结束
# 开始BV号为13K411M7am视频属性的抓取
# BV号为13K411M7am的视频属性抓取结束
# 开始BV号为1P54y117ri视频属性的抓取
# BV号为1P54y117ri的视频属性抓取结束
# 开始BV号为1mK411K7Wu视频属性的抓取
# BV号为1mK411K7Wu的视频属性抓取结束
# 开始BV号为115411b7Js视频属性的抓取
# BV号为115411b7Js的视频属性抓取结束
# 开始BV号为1Di4y177Jr视频属性的抓取
# BV号为1Di4y177Jr的视频属性抓取结束
# 开始BV号为1SC4y1t7Ps视频属性的抓取
# BV号为1SC4y1t7Ps的视频属性抓取结束
# 开始BV号为1Jy4y1y7e5视频属性的抓取
# BV号为1Jy4y1y7e5的视频属性抓取结束
# 开始BV号为1Ak4y11782视频属性的抓取
# BV号为1Ak4y11782的视频属性抓取结束
# 开始BV号为1p5411b75N视频属性的抓取
# BV号为1p5411b75N的视频属性抓取结束
# 开始BV号为1cA411J7Y5视频属性的抓取
# BV号为1cA411J7Y5的视频属性抓取结束
# 开始BV号为1Uy4y1y7b3视频属性的抓取
# BV号为1Uy4y1y7b3的视频属性抓取结束
# 开始BV号为17a4y1j7oD视频属性的抓取
# BV号为17a4y1j7oD的视频属性抓取结束
# 开始BV号为1fh41197NE视频属性的抓取
# BV号为1fh41197NE的视频属性抓取结束
# 开始BV号为18T4y1w79Z视频属性的抓取
# BV号为18T4y1w79Z的视频属性抓取结束
# 开始BV号为1aK411K7Cj视频属性的抓取
# BV号为1aK411K7Cj的视频属性抓取结束
# 开始BV号为1Ta4y177FF视频属性的抓取
# BV号为1Ta4y177FF的视频属性抓取结束
# 开始BV号为1RD4y1d7Fi视频属性的抓取
# BV号为1RD4y1d7Fi的视频属性抓取结束
# 开始BV号为1Eh411X7Nk视频属性的抓取
# BV号为1Eh411X7Nk的视频属性抓取结束
# 开始BV号为1pp4y1a7KC视频属性的抓取
# BV号为1pp4y1a7KC的视频属性抓取结束
# 开始BV号为1Sh411R7M9视频属性的抓取
# BV号为1Sh411R7M9的视频属性抓取结束
# 开始BV号为1F5411j7AG视频属性的抓取
# BV号为1F5411j7AG的视频属性抓取结束
# 开始BV号为1R54y1C7cY视频属性的抓取
# BV号为1R54y1C7cY的视频属性抓取结束
# 开始BV号为17t4y1S7pz视频属性的抓取
# BV号为17t4y1S7pz的视频属性抓取结束
# 开始BV号为18V411m7rk视频属性的抓取
# BV号为18V411m7rk的视频属性抓取结束
# 开始BV号为1sZ4y1T7Zb视频属性的抓取
# BV号为1sZ4y1T7Zb的视频属性抓取结束
# 开始BV号为1gA411J7gw视频属性的抓取
# BV号为1gA411J7gw的视频属性抓取结束
# 开始BV号为1jh411R7kU视频属性的抓取
# BV号为1jh411R7kU的视频属性抓取结束
# 开始BV号为1np4y1e75L视频属性的抓取
# BV号为1np4y1e75L的视频属性抓取结束
# 开始BV号为1zt4y1S7WF视频属性的抓取
# BV号为1zt4y1S7WF的视频属性抓取结束
# 开始BV号为1yK4y1a7iJ视频属性的抓取
# BV号为1yK4y1a7iJ的视频属性抓取结束
# 开始BV号为1QT4y1L7Na视频属性的抓取
# BV号为1QT4y1L7Na的视频属性抓取结束
# 开始BV号为19D4y1o74n视频属性的抓取
# BV号为19D4y1o74n的视频属性抓取结束
# 开始BV号为16z4y1Z7Ch视频属性的抓取
# BV号为16z4y1Z7Ch的视频属性抓取结束
# 开始BV号为1mv41117gf视频属性的抓取
# BV号为1mv41117gf的视频属性抓取结束
# 开始BV号为1Rk4y1k7EG视频属性的抓取
# BV号为1Rk4y1k7EG的视频属性抓取结束
# 开始BV号为1pv41117ri视频属性的抓取
# BV号为1pv41117ri的视频属性抓取结束
# 开始BV号为1yA411n7wj视频属性的抓取
# BV号为1yA411n7wj的视频属性抓取结束
# 开始BV号为1ti4y1u7TS视频属性的抓取
# BV号为1ti4y1u7TS的视频属性抓取结束
# 开始BV号为1Hp4y1a7hH视频属性的抓取
# BV号为1Hp4y1a7hH的视频属性抓取结束
# 开始BV号为1Bk4y1y7Qm视频属性的抓取
# BV号为1Bk4y1y7Qm的视频属性抓取结束
# 开始BV号为1yv411177m视频属性的抓取
# BV号为1yv411177m的视频属性抓取结束
# 开始BV号为1g5411b756视频属性的抓取
# BV号为1g5411b756的视频属性抓取结束
# 开始BV号为1Ki4y1u7r7视频属性的抓取
# BV号为1Ki4y1u7r7的视频属性抓取结束
# 开始BV号为1Ya4y1j7VN视频属性的抓取
# BV号为1Ya4y1j7VN的视频属性抓取结束
# 开始BV号为1WD4y1m7SD视频属性的抓取
# BV号为1WD4y1m7SD的视频属性抓取结束
# 开始BV号为18y4y1k7Db视频属性的抓取
# BV号为18y4y1k7Db的视频属性抓取结束
# 开始BV号为14t4y1q7bK视频属性的抓取
# BV号为14t4y1q7bK的视频属性抓取结束
# 开始BV号为1rT4y1A7Mg视频属性的抓取
# BV号为1rT4y1A7Mg的视频属性抓取结束
# 开始BV号为1AT4y1A7kj视频属性的抓取
# BV号为1AT4y1A7kj的视频属性抓取结束
# 开始BV号为1qh411X7PS视频属性的抓取
# BV号为1qh411X7PS的视频属性抓取结束
# 开始BV号为1rK411P74y视频属性的抓取
# BV号为1rK411P74y的视频属性抓取结束
# 开始BV号为1rK411P7AK视频属性的抓取
# BV号为1rK411P7AK的视频属性抓取结束
# 开始BV号为1Y5411b71P视频属性的抓取
# BV号为1Y5411b71P的视频属性抓取结束
# 开始BV号为1Tf4y1D7wE视频属性的抓取
# BV号为1Tf4y1D7wE的视频属性抓取结束
# 开始BV号为1D54y1C77k视频属性的抓取
# BV号为1D54y1C77k的视频属性抓取结束
# 开始BV号为1Q5411b7m5视频属性的抓取
# BV号为1Q5411b7m5的视频属性抓取结束
# 开始BV号为1dT4y1w78t视频属性的抓取
# BV号为1dT4y1w78t的视频属性抓取结束
# 开始BV号为16A411n7yB视频属性的抓取
# BV号为16A411n7yB的视频属性抓取结束
# 开始BV号为13p4y1e7Wr视频属性的抓取
# BV号为13p4y1e7Wr的视频属性抓取结束
# 开始BV号为1Nk4y117ze视频属性的抓取
# BV号为1Nk4y117ze的视频属性抓取结束
# 开始BV号为1h54y1m7aE视频属性的抓取
# BV号为1h54y1m7aE的视频属性抓取结束
# 开始BV号为1Hp4y1e7Gj视频属性的抓取
# BV号为1Hp4y1e7Gj的视频属性抓取结束
# 开始BV号为1L54y127uG视频属性的抓取
# BV号为1L54y127uG的视频属性抓取结束
# 开始BV号为1cv411y7he视频属性的抓取
# BV号为1cv411y7he的视频属性抓取结束
# 开始BV号为1Uz4y1Z7C3视频属性的抓取
# BV号为1Uz4y1Z7C3的视频属性抓取结束
# 开始BV号为1XK4y1a7gC视频属性的抓取
# BV号为1XK4y1a7gC的视频属性抓取结束
# 开始BV号为1ZZ4y1K7kH视频属性的抓取
# BV号为1ZZ4y1K7kH的视频属性抓取结束
# 开始BV号为1Ma4y1E7Xw视频属性的抓取
# BV号为1Ma4y1E7Xw的视频属性抓取结束
# 开始BV号为1d54y127AK视频属性的抓取
# BV号为1d54y127AK的视频属性抓取结束
# 开始BV号为1pp4y1a75D视频属性的抓取
# BV号为1pp4y1a75D的视频属性抓取结束
# 开始BV号为1Jy4y1B7Pj视频属性的抓取
# BV号为1Jy4y1B7Pj的视频属性抓取结束
# 开始BV号为1Uz4y1o77H视频属性的抓取
# BV号为1Uz4y1o77H的视频属性抓取结束
# 开始BV号为1dp4y1a7MH视频属性的抓取
# BV号为1dp4y1a7MH的视频属性抓取结束
# 开始BV号为1zf4y1B7WE视频属性的抓取
# BV号为1zf4y1B7WE的视频属性抓取结束
# 开始BV号为1P5411L78A视频属性的抓取
# BV号为1P5411L78A的视频属性抓取结束
# 开始BV号为1EV411y7g4视频属性的抓取
# BV号为1EV411y7g4的视频属性抓取结束
# 开始BV号为18t4y1i7xw视频属性的抓取
# BV号为18t4y1i7xw的视频属性抓取结束
# 开始BV号为1gy4y187MU视频属性的抓取
# BV号为1gy4y187MU的视频属性抓取结束
# 开始BV号为1L541177BG视频属性的抓取
# BV号为1L541177BG的视频属性抓取结束
# 开始BV号为1654y117D2视频属性的抓取
# BV号为1654y117D2的视频属性抓取结束
# 开始BV号为1tK4y1h762视频属性的抓取
# BV号为1tK4y1h762的视频属性抓取结束
# 开始BV号为1cy4y1C7BZ视频属性的抓取
# BV号为1cy4y1C7BZ的视频属性抓取结束
# 开始BV号为1Tz4y1f7Bw视频属性的抓取
# BV号为1Tz4y1f7Bw的视频属性抓取结束
# 开始BV号为1Aa4y1s7AQ视频属性的抓取
# BV号为1Aa4y1s7AQ的视频属性抓取结束
# 开始BV号为1Lp4y1k731视频属性的抓取
# BV号为1Lp4y1k731的视频属性抓取结束
# 开始BV号为1cz4y1f7EV视频属性的抓取
# BV号为1cz4y1f7EV的视频属性抓取结束
# 开始BV号为1gT4y1w7WJ视频属性的抓取
# BV号为1gT4y1w7WJ的视频属性抓取结束
# 开始BV号为1ot4y1v78B视频属性的抓取
# BV号为1ot4y1v78B的视频属性抓取结束
# 开始BV号为1h54y1C7HV视频属性的抓取
# BV号为1h54y1C7HV的视频属性抓取结束
# 开始BV号为1sy4y1B7hN视频属性的抓取
# BV号为1sy4y1B7hN的视频属性抓取结束
# 开始BV号为1Bi4y1E7zs视频属性的抓取
# BV号为1Bi4y1E7zs的视频属性抓取结束
# 开始BV号为1Ca411A7L7视频属性的抓取
# BV号为1Ca411A7L7的视频属性抓取结束
# 开始BV号为1bZ4y157yX视频属性的抓取
# BV号为1bZ4y157yX的视频属性抓取结束
# 开始BV号为1Si4y1j76T视频属性的抓取
# BV号为1Si4y1j76T的视频属性抓取结束
# 开始BV号为1Vy4y1C7wT视频属性的抓取
# BV号为1Vy4y1C7wT的视频属性抓取结束
# 开始BV号为1Dz4y1d7cx视频属性的抓取
# BV号为1Dz4y1d7cx的视频属性抓取结束
# 开始BV号为1PV411y7pY视频属性的抓取
# BV号为1PV411y7pY的视频属性抓取结束
# 开始BV号为18i4y1j7s7视频属性的抓取
# BV号为18i4y1j7s7的视频属性抓取结束
# 开始BV号为1AT4y1F7Zh视频属性的抓取
# BV号为1AT4y1F7Zh的视频属性抓取结束
# 开始BV号为1bt4y1v7RE视频属性的抓取
# BV号为1bt4y1v7RE的视频属性抓取结束
# 开始BV号为1MA411E7H7视频属性的抓取
# BV号为1MA411E7H7的视频属性抓取结束
# 开始BV号为1WA411j7PA视频属性的抓取
# BV号为1WA411j7PA的视频属性抓取结束
# 开始BV号为1Ma4y1s7EZ视频属性的抓取
# BV号为1Ma4y1s7EZ的视频属性抓取结束
# 开始BV号为1DZ4y1G7oe视频属性的抓取
# BV号为1DZ4y1G7oe的视频属性抓取结束
# 开始BV号为1tr4y1w7L8视频属性的抓取
# BV号为1tr4y1w7L8的视频属性抓取结束
# 开始BV号为1Cp4y1r7zy视频属性的抓取
# BV号为1Cp4y1r7zy的视频属性抓取结束
# 开始BV号为18p4y1k79A视频属性的抓取
# BV号为18p4y1k79A的视频属性抓取结束
# 开始BV号为17i4y1E7et视频属性的抓取
# BV号为17i4y1E7et的视频属性抓取结束
# 开始BV号为1m54y1k7Rv视频属性的抓取
# BV号为1m54y1k7Rv的视频属性抓取结束
# 开始BV号为1vz4y1o7Kd视频属性的抓取
# BV号为1vz4y1o7Kd的视频属性抓取结束
# 开始BV号为1Yy4y1B795视频属性的抓取
# BV号为1Yy4y1B795的视频属性抓取结束
# 开始BV号为1Ka411A7XL视频属性的抓取
# BV号为1Ka411A7XL的视频属性抓取结束
# 开始BV号为1ea4y1L7cD视频属性的抓取
# BV号为1ea4y1L7cD的视频属性抓取结束
# 开始BV号为18K411A7DD视频属性的抓取
# BV号为18K411A7DD的视频属性抓取结束
# 开始BV号为1uK4y1h7qV视频属性的抓取
# BV号为1uK4y1h7qV的视频属性抓取结束
# 开始BV号为1DV41117Yu视频属性的抓取
# BV号为1DV41117Yu的视频属性抓取结束
# 开始BV号为1Xp4y1r7hz视频属性的抓取
# BV号为1Xp4y1r7hz的视频属性抓取结束
# 开始BV号为1Ey4y1B71x视频属性的抓取
# BV号为1Ey4y1B71x的视频属性抓取结束
# 开始BV号为13Z4y1L7Xy视频属性的抓取
# BV号为13Z4y1L7Xy的视频属性抓取结束
# 开始BV号为1r541157ou视频属性的抓取
# BV号为1r541157ou的视频属性抓取结束
# 开始BV号为1Q54y1k7Ut视频属性的抓取
# BV号为1Q54y1k7Ut的视频属性抓取结束
# 开始BV号为1Dp4y1r7Bk视频属性的抓取
# BV号为1Dp4y1r7Bk的视频属性抓取结束
# 开始BV号为1oT4y1c7tL视频属性的抓取
# BV号为1oT4y1c7tL的视频属性抓取结束
# 开始BV号为14V411y7YX视频属性的抓取
# BV号为14V411y7YX的视频属性抓取结束
# 开始BV号为15541177xn视频属性的抓取
# BV号为15541177xn的视频属性抓取结束
# 开始BV号为1Zy4y1b7GL视频属性的抓取
# BV号为1Zy4y1b7GL的视频属性抓取结束
# 开始BV号为1PV411y7HJ视频属性的抓取
# BV号为1PV411y7HJ的视频属性抓取结束
# 开始BV号为175411j7Fs视频属性的抓取
# BV号为175411j7Fs的视频属性抓取结束
# 开始BV号为1kZ4y157Mn视频属性的抓取
# BV号为1kZ4y157Mn的视频属性抓取结束
# 开始BV号为1Fh41197LH视频属性的抓取
# BV号为1Fh41197LH的视频属性抓取结束
# 开始BV号为1hK411N7cG视频属性的抓取
# BV号为1hK411N7cG的视频属性抓取结束
# 开始BV号为1x5411L7iz视频属性的抓取
# BV号为1x5411L7iz的视频属性抓取结束
# 开始BV号为1sa4y1L7vi视频属性的抓取
# BV号为1sa4y1L7vi的视频属性抓取结束
# 开始BV号为1kV411y7Eo视频属性的抓取
# BV号为1kV411y7Eo的视频属性抓取结束
# 开始BV号为1vi4y1j7Dw视频属性的抓取
# BV号为1vi4y1j7Dw的视频属性抓取结束
# 开始BV号为1qa4y1575p视频属性的抓取
# BV号为1qa4y1575p的视频属性抓取结束
# 开始BV号为1hp4y1Y7F9视频属性的抓取
# BV号为1hp4y1Y7F9的视频属性抓取结束
# 开始BV号为1Wh41197Yx视频属性的抓取
# BV号为1Wh41197Yx的视频属性抓取结束
# 开始BV号为1Tv411y7oT视频属性的抓取
# BV号为1Tv411y7oT的视频属性抓取结束
# 开始BV号为17Z4y1V7zY视频属性的抓取
# BV号为17Z4y1V7zY的视频属性抓取结束
# 开始BV号为1DZ4y1G728视频属性的抓取
# BV号为1DZ4y1G728的视频属性抓取结束
# 开始BV号为1Ff4y1B72Q视频属性的抓取
# BV号为1Ff4y1B72Q的视频属性抓取结束
# 开始BV号为12z4y1Z7rW视频属性的抓取
# BV号为12z4y1Z7rW的视频属性抓取结束
# 开始BV号为1Yz4y1C7UA视频属性的抓取
# BV号为1Yz4y1C7UA的视频属性抓取结束
# 开始BV号为1xa411A7VC视频属性的抓取
# BV号为1xa411A7VC的视频属性抓取结束
# 开始BV号为1BZ4y1578p视频属性的抓取
# BV号为1BZ4y1578p的视频属性抓取结束
# 开始BV号为1dp4y1r7ji视频属性的抓取
# BV号为1dp4y1r7ji的视频属性抓取结束
# 开始BV号为1Pk4y1y7UL视频属性的抓取
# BV号为1Pk4y1y7UL的视频属性抓取结束
# 开始BV号为1wK4y1E7U6视频属性的抓取
# BV号为1wK4y1E7U6的视频属性抓取结束
# 开始BV号为16K411A7uL视频属性的抓取
# BV号为16K411A7uL的视频属性抓取结束
# 开始BV号为1UK411P7Ya视频属性的抓取
# BV号为1UK411P7Ya的视频属性抓取结束
# 开始BV号为1wh41197nR视频属性的抓取
# BV号为1wh41197nR的视频属性抓取结束
# 开始BV号为1iA411J7Eg视频属性的抓取
# BV号为1iA411J7Eg的视频属性抓取结束
# 开始BV号为1kv41167D2视频属性的抓取
# BV号为1kv41167D2的视频属性抓取结束
# 开始BV号为1Za4y157KS视频属性的抓取
# BV号为1Za4y157KS的视频属性抓取结束
# 开始BV号为1xD4y197Ru视频属性的抓取
# BV号为1xD4y197Ru的视频属性抓取结束
# 开始BV号为1w5411L7o7视频属性的抓取
# BV号为1w5411L7o7的视频属性抓取结束
# 开始BV号为1ht4y1i7eo视频属性的抓取
# BV号为1ht4y1i7eo的视频属性抓取结束
# 开始BV号为1i54y1k779视频属性的抓取
# BV号为1i54y1k779的视频属性抓取结束
# 开始BV号为1oA411777z视频属性的抓取
# BV号为1oA411777z的视频属性抓取结束
# 开始BV号为1cy4y187bS视频属性的抓取
# BV号为1cy4y187bS的视频属性抓取结束
# 开始BV号为1Tf4y1B7vw视频属性的抓取
# BV号为1Tf4y1B7vw的视频属性抓取结束
# 开始BV号为1ma411w7L7视频属性的抓取
# BV号为1ma411w7L7的视频属性抓取结束
# 开始BV号为1Kz4y1f7v4视频属性的抓取
# BV号为1Kz4y1f7v4的视频属性抓取结束
# 开始BV号为1bv411y7MA视频属性的抓取
# BV号为1bv411y7MA的视频属性抓取结束
# 开始BV号为1zi4y1E73f视频属性的抓取
# BV号为1zi4y1E73f的视频属性抓取结束
# 开始BV号为18V41127cj视频属性的抓取
# BV号为18V41127cj的视频属性抓取结束
# 开始BV号为1va4y1L78Q视频属性的抓取
# BV号为1va4y1L78Q的视频属性抓取结束
# 开始BV号为1Ma4y1L764视频属性的抓取
# BV号为1Ma4y1L764的视频属性抓取结束
# 开始BV号为1fy4y1b7bb视频属性的抓取
# BV号为1fy4y1b7bb的视频属性抓取结束
# 2020-12-17 20:23:27.497799

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-14-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_yingshi_zatan.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月     98   98    98   98   98   98   98   98    98      98   98    98   98
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月     98   98    98   98   98   98   98   98    98      98   98    98   98
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月    99   99   99   99   99   99    99
# 2月   100  100  100  100  100  100   100
# 3月   100  100  100  100  100  100   100
# 4月   100  100  100  100  100  100   100
# 5月    98   98   98   98   98   98    98
# 6月   100  100  100  100  100  100   100
# 7月   100  100  100  100  100  100   100
# 8月    98   98   98   98   98   98    98
# 9月   100  100  100  100  100  100   100

# %%
channel_yingshi_zatan.to_json('channel_yingshi_zatan.json')

# %%
pd.set_option('display.max_rows', None)

# %%
channel_youxi_danji[channel_youxi_danji['时间']=='4月']
# Out:
#             时间            作者名  作者类型      粉丝数   投稿数  \
# 1h54y1d7Qq  4月            鹤吱菌  个人认证   191.3万    81
# 1L64y1M7Dp  4月            老番茄  个人认证  1360.1万   348
# 18K41157Tu  4月            老番茄  个人认证  1360.1万   348
# 1PT4y1G7ME  4月            老番茄  个人认证  1360.1万   348
# 1S54y197uX  4月           徐大虾咯  个人认证   570.1万   224
# 1ti4y1t7YM  4月            老番茄  个人认证  1360.1万   348
# 1Ai4y1b7ET  4月            敖厂长  个人认证   735.1万   348
# 1Up4y1C7PB  4月        丢鹏D1uuu     无     8.4万    20
# 1wi4y187bu  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 13t4y1U7kQ  4月           徐大虾咯  个人认证   570.1万   224
# 1fe411x7FA  4月         芦苇草的梦想  个人认证    29.3万   726
# 1LA411b7Dt  4月      LexBurner  个人认证   929.6万   383
# 1Ji4y1t7T9  4月            沧桑丸  个人认证    86.6万    57
# 1Lz411z72u  4月           徐大虾咯  个人认证   570.1万   224
# 13T4y1G7WT  4月          逗比的雀巢  个人认证   242.3万    82
# 1T54y197DH  4月           徐大虾咯  个人认证   570.1万   224
# 1Va4y147fH  4月            鹤吱菌  个人认证   191.3万    81
# 1tt4y127yy  4月           小潮院长  个人认证   481.6万   266
# 16T4y1g7RY  4月         吉儿一范伦婷  个人认证    67.6万    79
# 1754y197Da  4月            敖厂长  个人认证   735.1万   348
# 1hK41157M3  4月           花少北丶  个人认证   491.9万   173
# 1Rk4y197kw  4月       3DM游戏网官方  机构认证    13.5万  2822
# 1ST4y1G7E1  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1H54y1d76B  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1Sz411B7P4  4月          游汐_YX  个人认证    12.9万    98
# 1CT4y1g7Ya  4月    育碧中国Ubisoft  机构认证    64.5万  1211
# 12T4y1G7AZ  4月          与山0v0  个人认证   208.5万   557
# 1b5411x79t  4月        东尼ookii  个人认证   331.7万   166
# 1hA411h7Ky  4月          与山0v0  个人认证   208.5万   557
# 1Gt4y127AJ  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1KJ411e7nN                              如何提高审美？审美有无高低？审美是谁建立？  数码  摄影摄像  普通视频
# ...                                                       ...  ..   ...   ...
# 1cr4y1w7ig              困难重重，国家天文签约摄影师遭遇拍摄滑铁卢？！【华为Mate40 Pro】  数码  摄影摄像  活动作品
# 1Y5411L7TW                     富士X-S10相机测试——2020 apsc画幅性价比最强机  数码  摄影摄像  活动作品
# 1c541177hR      索尼（Sony）12-24mm F2.8 GM深度评测，只要买得起，它就是一颗完美的镜头！  数码  摄影摄像  普通视频
# 1DA41177UY                            大疆旗舰稳定器 - DJI RS 2 正式登场  数码  摄影摄像  普通视频
# 1rA411776p                 让我非常失望的佳能M50 Mark II（来自一代老用户的真实心声）  数码  摄影摄像  普通视频
#
#             ...                                                 标签   视频长度  \
# 1gJ411n7hp  ...                         [摄影, 数码, 摄影摄像, 数码, 教程, 器材]  01:44
# 1tJ41187w6  ...  [相机, 数码, 摄影摄像, 数码, 何同学, 啊吗粽, 宝剑嫂, 自媒体, 大祥哥, 体验...  30:03
# 1i7411i7yA  ...        [摄影, 短片, 数码, 摄影摄像, 数码, 创意, YOUTUBE, 镜头, 老蛙]  04:51
# 1gJ411G7Cs  ...           [摄影, 数码, 摄影摄像, 数码, VLOG, 后期, 教程, ps, 器材]  06:01
# 1KJ411e7nN  ...  [校园vlog, 相机, 脱口秀, 摄影, 公开课, vlog, 科普, 数码, 摄影摄像,...  27:08
# ...         ...                                                ...    ...
# 1cr4y1w7ig  ...  [vlog, 数码, 摄影摄像, 数码, 放心购机攻略, 敦煌, 星空, 手机摄影, 华为,...  11:43
# 1Y5411L7TW  ...  [相机, 摄影, 数码, 摄影摄像, 数码, 数码玩家训练营, 拍照, 测评, xs10, ...  10:20
# 1c541177hR  ...  [摄影, 数码, 摄影摄像, 数码, 评测, 超广角大光圈, 摄像, 镜头, 数码评测, 超...  21:23
# 1DA41177UY  ...   [相机, 摄影, 数码, 摄影摄像, 数码, 科技, 测评, 器材, 大疆, DJI, 稳定器]  02:26
# 1rA411776p  ...  [vlog, 数码, 摄影摄像, 数码, 佳能, 测评, 体验, m50 mark ii, ...  06:30
#
#                播放量    点赞数   投币数   收藏数   转发数   评论数   弹幕数 有无分集
# 1gJ411n7hp  222.4万   9.7万  2.0万  1.4万  4980  3182  1571    否
# 1tJ41187w6  134.0万  10.7万  8.4万  5.8万  8907  3935  3.0万    否
# 1i7411i7yA   57.8万   4.4万  1.0万  1.6万  2043   641   983    否
# 1gJ411G7Cs   42.3万   3.3万  3.4万  8.6万  2605  1405   612    否
# 1KJ411e7nN   39.6万   4.8万  5.4万  3.4万  6217  1156  1.0万    否
# ...            ...    ...   ...   ...   ...   ...   ...  ...
# 1cr4y1w7ig    4.3万   3051  1391   692   255   337   349    否
# 1Y5411L7TW    4.3万    773   219   221   111   273   104    否
# 1c541177hR    4.1万   1469   443   297   123   250   561    否
# 1DA41177UY    4.1万   1565   197   334   640   171   110    否
# 1rA411776p    4.1万   1262   267   147   101   385   314    否
#
# [999 rows x 21 columns]
