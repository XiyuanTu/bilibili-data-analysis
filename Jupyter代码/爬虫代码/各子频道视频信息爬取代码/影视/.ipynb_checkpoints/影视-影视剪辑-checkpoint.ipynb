# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_yingshi_jianji=pd.DataFrame(columns=columns)
channel_yingshi_jianji
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[14]/div/a/span').click()  #选择频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[14]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '影视'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[3]/a').click()  #选择子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[3]/a').text
sub_channel
# Out:
# '影视剪辑'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(1,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_yingshi_jianji.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-17 09:53:23.746366
# <ipython-input-9-54d5a7f154fb>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-9-54d5a7f154fb>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-9-54d5a7f154fb>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1FJ411V7gy视频属性的抓取
# BV号为1FJ411V7gy的视频属性抓取结束
# <ipython-input-9-54d5a7f154fb>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1D7411v74v视频属性的抓取
# BV号为1D7411v74v的视频属性抓取结束
# 开始BV号为197411e7JN视频属性的抓取
# BV号为197411e7JN的视频属性抓取结束
# 开始BV号为1pJ411b7Lh视频属性的抓取
# BV号为1pJ411b7Lh的视频属性抓取结束
# 开始BV号为1T7411C7cS视频属性的抓取
# BV号为1T7411C7cS的视频属性抓取结束
# 开始BV号为1N7411e7tc视频属性的抓取
# BV号为1N7411e7tc的视频属性抓取结束
# 开始BV号为1q741167W5视频属性的抓取
# BV号为1q741167W5的视频属性抓取结束
# 开始BV号为1R7411i7Pd视频属性的抓取
# BV号为1R7411i7Pd的视频属性抓取结束
# 开始BV号为1CJ411V7TU视频属性的抓取
# BV号为1CJ411V7TU的视频属性抓取结束
# 开始BV号为1P7411B7eA视频属性的抓取
# BV号为1P7411B7eA的视频属性抓取结束
# 开始BV号为1wJ411n7H4视频属性的抓取
# BV号为1wJ411n7H4的视频属性抓取结束
# 开始BV号为1T7411k7nB视频属性的抓取
# BV号为1T7411k7nB的视频属性抓取结束
# 开始BV号为1uJ411L7Ps视频属性的抓取
# BV号为1uJ411L7Ps的视频属性抓取结束
# 开始BV号为1n7411e7Ne视频属性的抓取
# BV号为1n7411e7Ne的视频属性抓取结束
# 开始BV号为1o7411q7Ud视频属性的抓取
# BV号为1o7411q7Ud的视频属性抓取结束
# 开始BV号为1zJ411V7rD视频属性的抓取
# BV号为1zJ411V7rD的视频属性抓取结束
# 开始BV号为127411a7dF视频属性的抓取
# BV号为127411a7dF的视频属性抓取结束
# 开始BV号为1v7411v7gy视频属性的抓取
# BV号为1v7411v7gy的视频属性抓取结束
# 开始BV号为1e7411B7ii视频属性的抓取
# BV号为1e7411B7ii的视频属性抓取结束
# 开始BV号为19J411J7ng视频属性的抓取
# BV号为19J411J7ng的视频属性抓取结束
# 开始BV号为1K7411C7Ag视频属性的抓取
# BV号为1K7411C7Ag的视频属性抓取结束
# 开始BV号为1aJ41187yU视频属性的抓取
# BV号为1aJ41187yU的视频属性抓取结束
# 开始BV号为1tJ411H7uh视频属性的抓取
# BV号为1tJ411H7uh的视频属性抓取结束
# 开始BV号为1QJ411J7Wd视频属性的抓取
# BV号为1QJ411J7Wd的视频属性抓取结束
# 开始BV号为1DJ411E7Jq视频属性的抓取
# BV号为1DJ411E7Jq的视频属性抓取结束
# 开始BV号为1BJ41177ZJ视频属性的抓取
# BV号为1BJ41177ZJ的视频属性抓取结束
# 开始BV号为117411r7od视频属性的抓取
# BV号为117411r7od的视频属性抓取结束
# 开始BV号为1r7411v7ea视频属性的抓取
# BV号为1r7411v7ea的视频属性抓取结束
# 开始BV号为1YJ411j7xC视频属性的抓取
# BV号为1YJ411j7xC的视频属性抓取结束
# 开始BV号为1J74116722视频属性的抓取
# BV号为1J74116722的视频属性抓取结束
# 开始BV号为1j7411q7ab视频属性的抓取
# BV号为1j7411q7ab的视频属性抓取结束
# 开始BV号为19J411j7dE视频属性的抓取
# BV号为19J411j7dE的视频属性抓取结束
# 开始BV号为1UJ411V7C1视频属性的抓取
# BV号为1UJ411V7C1的视频属性抓取结束
# 开始BV号为1t7411e7VK视频属性的抓取
# BV号为1t7411e7VK的视频属性抓取结束
# 开始BV号为1Z7411v7XH视频属性的抓取
# BV号为1Z7411v7XH的视频属性抓取结束
# 开始BV号为1hJ411p74q视频属性的抓取
# BV号为1hJ411p74q的视频属性抓取结束
# 开始BV号为1e7411k7xs视频属性的抓取
# BV号为1e7411k7xs的视频属性抓取结束
# 开始BV号为1iJ411n7XR视频属性的抓取
# BV号为1iJ411n7XR的视频属性抓取结束
# 开始BV号为1jJ411p7xK视频属性的抓取
# BV号为1jJ411p7xK的视频属性抓取结束
# 开始BV号为1jJ411J7UZ视频属性的抓取
# BV号为1jJ411J7UZ的视频属性抓取结束
# 开始BV号为1w7411q7rp视频属性的抓取
# BV号为1w7411q7rp的视频属性抓取结束
# 开始BV号为1b7411i7Wj视频属性的抓取
# 开始BV号为1b7411i7Wj视频属性的抓取
# BV号为1b7411i7Wj的视频属性抓取结束
# 开始BV号为1kJ411p7tb视频属性的抓取
# BV号为1kJ411p7tb的视频属性抓取结束
# 开始BV号为1kJ41157Qb视频属性的抓取
# BV号为1kJ41157Qb的视频属性抓取结束
# 开始BV号为1W7411e7KZ视频属性的抓取
# BV号为1W7411e7KZ的视频属性抓取结束
# 开始BV号为1qJ411E7Tw视频属性的抓取
# BV号为1qJ411E7Tw的视频属性抓取结束
# 开始BV号为1Z7411q7VB视频属性的抓取
# BV号为1Z7411q7VB的视频属性抓取结束
# 开始BV号为1kJ411p7hZ视频属性的抓取
# BV号为1kJ411p7hZ的视频属性抓取结束
# 开始BV号为1L7411e7ih视频属性的抓取
# BV号为1L7411e7ih的视频属性抓取结束
# 开始BV号为1pJ411E7zG视频属性的抓取
# BV号为1pJ411E7zG的视频属性抓取结束
# 开始BV号为1R7411Y7Hf视频属性的抓取
# BV号为1R7411Y7Hf的视频属性抓取结束
# 开始BV号为1kJ411E7b8视频属性的抓取
# BV号为1kJ411E7b8的视频属性抓取结束
# 开始BV号为1PJ411p7k5视频属性的抓取
# BV号为1PJ411p7k5的视频属性抓取结束
# 开始BV号为1i7411q7HJ视频属性的抓取
# BV号为1i7411q7HJ的视频属性抓取结束
# 开始BV号为1z741167aj视频属性的抓取
# BV号为1z741167aj的视频属性抓取结束
# 开始BV号为17J411H7bV视频属性的抓取
# BV号为17J411H7bV的视频属性抓取结束
# 开始BV号为1HJ411L7ZL视频属性的抓取
# BV号为1HJ411L7ZL的视频属性抓取结束
# 开始BV号为1pJ411G7X8视频属性的抓取
# BV号为1pJ411G7X8的视频属性抓取结束
# 开始BV号为1i7411Y7gu视频属性的抓取
# BV号为1i7411Y7gu的视频属性抓取结束
# 开始BV号为1gJ411E7uh视频属性的抓取
# BV号为1gJ411E7uh的视频属性抓取结束
# 开始BV号为16J411j7nb视频属性的抓取
# BV号为16J411j7nb的视频属性抓取结束
# 开始BV号为1v7411i7Hw视频属性的抓取
# BV号为1v7411i7Hw的视频属性抓取结束
# 开始BV号为1V7411q7HP视频属性的抓取
# BV号为1V7411q7HP的视频属性抓取结束
# 开始BV号为1SJ411E7YQ视频属性的抓取
# BV号为1SJ411E7YQ的视频属性抓取结束
# 开始BV号为137411e7Qv视频属性的抓取
# BV号为137411e7Qv的视频属性抓取结束
# 开始BV号为15J411V7Lq视频属性的抓取
# BV号为15J411V7Lq的视频属性抓取结束
# 开始BV号为1aJ411H7Sd视频属性的抓取
# BV号为1aJ411H7Sd的视频属性抓取结束
# 开始BV号为1a7411k7Ej视频属性的抓取
# BV号为1a7411k7Ej的视频属性抓取结束
# 开始BV号为1zJ411j78s视频属性的抓取
# BV号为1zJ411j78s的视频属性抓取结束
# 开始BV号为1MJ41157m4视频属性的抓取
# BV号为1MJ41157m4的视频属性抓取结束
# 开始BV号为1iJ411j7LS视频属性的抓取
# BV号为1iJ411j7LS的视频属性抓取结束
# 开始BV号为1qJ411n7Wd视频属性的抓取
# BV号为1qJ411n7Wd的视频属性抓取结束
# 开始BV号为1wJ411p7av视频属性的抓取
# BV号为1wJ411p7av的视频属性抓取结束
# 开始BV号为1kJ411J7Xz视频属性的抓取
# BV号为1kJ411J7Xz的视频属性抓取结束
# 开始BV号为1YJ411E7BE视频属性的抓取
# BV号为1YJ411E7BE的视频属性抓取结束
# 开始BV号为1g7411q7YB视频属性的抓取
# BV号为1g7411q7YB的视频属性抓取结束
# 开始BV号为1HJ411773F视频属性的抓取
# BV号为1HJ411773F的视频属性抓取结束
# 开始BV号为137411v7mv视频属性的抓取
# BV号为137411v7mv的视频属性抓取结束
# 开始BV号为1QJ411n7YF视频属性的抓取
# BV号为1QJ411n7YF的视频属性抓取结束
# 开始BV号为1qJ411577p视频属性的抓取
# BV号为1qJ411577p的视频属性抓取结束
# 开始BV号为1CJ411n7bb视频属性的抓取
# BV号为1CJ411n7bb的视频属性抓取结束
# 开始BV号为1dJ411V7dY视频属性的抓取
# BV号为1dJ411V7dY的视频属性抓取结束
# 开始BV号为1jJ411E7nM视频属性的抓取
# BV号为1jJ411E7nM的视频属性抓取结束
# 开始BV号为1UJ411E79r视频属性的抓取
# BV号为1UJ411E79r的视频属性抓取结束
# 开始BV号为1YJ411J7Zx视频属性的抓取
# BV号为1YJ411J7Zx的视频属性抓取结束
# 开始BV号为1e7411k7gR视频属性的抓取
# BV号为1e7411k7gR的视频属性抓取结束
# 开始BV号为1M7411k7iT视频属性的抓取
# BV号为1M7411k7iT的视频属性抓取结束
# 开始BV号为1AJ411577j视频属性的抓取
# BV号为1AJ411577j的视频属性抓取结束
# 开始BV号为1X7411k7mN视频属性的抓取
# BV号为1X7411k7mN的视频属性抓取结束
# 开始BV号为1FJ411E7pf视频属性的抓取
# BV号为1FJ411E7pf的视频属性抓取结束
# 开始BV号为1EJ411E716视频属性的抓取
# BV号为1EJ411E716的视频属性抓取结束
# 开始BV号为167411r7sV视频属性的抓取
# BV号为167411r7sV的视频属性抓取结束
# 开始BV号为1H7411a7Uv视频属性的抓取
# BV号为1H7411a7Uv的视频属性抓取结束
# 开始BV号为1k741167wh视频属性的抓取
# BV号为1k741167wh的视频属性抓取结束
# 开始BV号为1m7411z7U1视频属性的抓取
# BV号为1m7411z7U1的视频属性抓取结束
# 开始BV号为15J411n7QC视频属性的抓取
# BV号为15J411n7QC的视频属性抓取结束
# 开始BV号为1iJ411j7Bs视频属性的抓取
# BV号为1iJ411j7Bs的视频属性抓取结束
# 开始BV号为147411e7KF视频属性的抓取
# BV号为147411e7KF的视频属性抓取结束
# 开始BV号为1iJ411E721视频属性的抓取
# BV号为1iJ411E721的视频属性抓取结束
# 开始BV号为1dJ411H7jj视频属性的抓取
# BV号为1dJ411H7jj的视频属性抓取结束
# 开始BV号为1SE411n7V6视频属性的抓取
# BV号为1SE411n7V6的视频属性抓取结束
# 开始BV号为1e7411s7W6视频属性的抓取
# BV号为1e7411s7W6的视频属性抓取结束
# 开始BV号为1Q7411H7GT视频属性的抓取
# BV号为1Q7411H7GT的视频属性抓取结束
# 开始BV号为1f741137Q5视频属性的抓取
# BV号为1f741137Q5的视频属性抓取结束
# 开始BV号为1Q7411p73E视频属性的抓取
# BV号为1Q7411p73E的视频属性抓取结束
# 开始BV号为1b7411c72n视频属性的抓取
# BV号为1b7411c72n的视频属性抓取结束
# 开始BV号为1s7411c7fa视频属性的抓取
# BV号为1s7411c7fa的视频属性抓取结束
# 开始BV号为18E411H7Rx视频属性的抓取
# BV号为18E411H7Rx的视频属性抓取结束
# 开始BV号为1E7411G7jH视频属性的抓取
# BV号为1E7411G7jH的视频属性抓取结束
# 开始BV号为1H741137rC视频属性的抓取
# BV号为1H741137rC的视频属性抓取结束
# 开始BV号为14741187aT视频属性的抓取
# BV号为14741187aT的视频属性抓取结束
# 开始BV号为1y741137sG视频属性的抓取
# BV号为1y741137sG的视频属性抓取结束
# 开始BV号为1Q7411A7Sb视频属性的抓取
# BV号为1Q7411A7Sb的视频属性抓取结束
# 开始BV号为1m7411u7Gt视频属性的抓取
# BV号为1m7411u7Gt的视频属性抓取结束
# 开始BV号为1g7411L7Jw视频属性的抓取
# BV号为1g7411L7Jw的视频属性抓取结束
# 开始BV号为1Lj411f7Mn视频属性的抓取
# BV号为1Lj411f7Mn的视频属性抓取结束
# 开始BV号为1Y741177jt视频属性的抓取
# BV号为1Y741177jt的视频属性抓取结束
# 开始BV号为1Mj411f7Ns视频属性的抓取
# BV号为1Mj411f7Ns的视频属性抓取结束
# 开始BV号为1K7411u7b3视频属性的抓取
# BV号为1K7411u7b3的视频属性抓取结束
# 开始BV号为1N741147RD视频属性的抓取
# BV号为1N741147RD的视频属性抓取结束
# 开始BV号为127411V7nK视频属性的抓取
# BV号为127411V7nK的视频属性抓取结束
# 开始BV号为177411J7se视频属性的抓取
# BV号为177411J7se的视频属性抓取结束
# 开始BV号为1B7411V7cc视频属性的抓取
# BV号为1B7411V7cc的视频属性抓取结束
# 开始BV号为1S7411W75q视频属性的抓取
# BV号为1S7411W75q的视频属性抓取结束
# 开始BV号为1hE411n7Ko视频属性的抓取
# BV号为1hE411n7Ko的视频属性抓取结束
# 开始BV号为197411L7LX视频属性的抓取
# BV号为197411L7LX的视频属性抓取结束
# 开始BV号为1B7411M7Xi视频属性的抓取
# BV号为1B7411M7Xi的视频属性抓取结束
# 开始BV号为12741177NL视频属性的抓取
# BV号为12741177NL的视频属性抓取结束
# 开始BV号为1K7411L7jv视频属性的抓取
# BV号为1K7411L7jv的视频属性抓取结束
# 开始BV号为1J7411L75W视频属性的抓取
# BV号为1J7411L75W的视频属性抓取结束
# 开始BV号为1Q7411c795视频属性的抓取
# BV号为1Q7411c795的视频属性抓取结束
# 开始BV号为1d7411s7KP视频属性的抓取
# BV号为1d7411s7KP的视频属性抓取结束
# 开始BV号为1d7411k7qW视频属性的抓取
# BV号为1d7411k7qW的视频属性抓取结束
# 开始BV号为1r7411b71z视频属性的抓取
# BV号为1r7411b71z的视频属性抓取结束
# 开始BV号为1u741157Te视频属性的抓取
# BV号为1u741157Te的视频属性抓取结束
# 开始BV号为1HE411H76n视频属性的抓取
# BV号为1HE411H76n的视频属性抓取结束
# 开始BV号为1D7411L7g8视频属性的抓取
# BV号为1D7411L7g8的视频属性抓取结束
# 开始BV号为1d7411j7gJ视频属性的抓取
# BV号为1d7411j7gJ的视频属性抓取结束
# 开始BV号为1v7411V7VX视频属性的抓取
# BV号为1v7411V7VX的视频属性抓取结束
# 开始BV号为1e7411H7ps视频属性的抓取
# BV号为1e7411H7ps的视频属性抓取结束
# 开始BV号为1v7411u7CT视频属性的抓取
# BV号为1v7411u7CT的视频属性抓取结束
# 开始BV号为1S7411M74C视频属性的抓取
# BV号为1S7411M74C的视频属性抓取结束
# 开始BV号为1o7411x7wr视频属性的抓取
# BV号为1o7411x7wr的视频属性抓取结束
# 开始BV号为1e741187RB视频属性的抓取
# BV号为1e741187RB的视频属性抓取结束
# 开始BV号为1d7411W77Y视频属性的抓取
# BV号为1d7411W77Y的视频属性抓取结束
# 开始BV号为1h741137Cy视频属性的抓取
# BV号为1h741137Cy的视频属性抓取结束
# 开始BV号为1h7411E7rh视频属性的抓取
# BV号为1h7411E7rh的视频属性抓取结束
# 开始BV号为1f7411H7GZ视频属性的抓取
# BV号为1f7411H7GZ的视频属性抓取结束
# 开始BV号为1T7411N7z1视频属性的抓取
# BV号为1T7411N7z1的视频属性抓取结束
# 开始BV号为197411371q视频属性的抓取
# BV号为197411371q的视频属性抓取结束
# 开始BV号为1k7411g7F9视频属性的抓取
# BV号为1k7411g7F9的视频属性抓取结束
# 开始BV号为1Rj411f7k4视频属性的抓取
# BV号为1Rj411f7k4的视频属性抓取结束
# 开始BV号为1X7411F7ts视频属性的抓取
# BV号为1X7411F7ts的视频属性抓取结束
# 开始BV号为1h7411N7ZK视频属性的抓取
# BV号为1h7411N7ZK的视频属性抓取结束
# 开始BV号为1G7411u7mx视频属性的抓取
# BV号为1G7411u7mx的视频属性抓取结束
# 开始BV号为1V7411b73Q视频属性的抓取
# BV号为1V7411b73Q的视频属性抓取结束
# 开始BV号为127411n7oh视频属性的抓取
# BV号为127411n7oh的视频属性抓取结束
# 开始BV号为187411b7sn视频属性的抓取
# BV号为187411b7sn的视频属性抓取结束
# 开始BV号为1V7411x7mc视频属性的抓取
# BV号为1V7411x7mc的视频属性抓取结束
# 开始BV号为1h7411p7eT视频属性的抓取
# BV号为1h7411p7eT的视频属性抓取结束
# 开始BV号为1h7411G7yx视频属性的抓取
# BV号为1h7411G7yx的视频属性抓取结束
# 开始BV号为1Y7411F7pT视频属性的抓取
# BV号为1Y7411F7pT的视频属性抓取结束
# 开始BV号为1G7411c7ZC视频属性的抓取
# BV号为1G7411c7ZC的视频属性抓取结束
# 开始BV号为1A741137W4视频属性的抓取
# BV号为1A741137W4的视频属性抓取结束
# 开始BV号为1q741177Mv视频属性的抓取
# BV号为1q741177Mv的视频属性抓取结束
# 开始BV号为1P7411F7uB视频属性的抓取
# BV号为1P7411F7uB的视频属性抓取结束
# 开始BV号为1r7411t7gu视频属性的抓取
# BV号为1r7411t7gu的视频属性抓取结束
# 开始BV号为117411P7eN视频属性的抓取
# BV号为117411P7eN的视频属性抓取结束
# 开始BV号为1D741187A6视频属性的抓取
# 开始BV号为1D741187A6视频属性的抓取
# BV号为1D741187A6的视频属性抓取结束
# 开始BV号为1Y7411n7vc视频属性的抓取
# BV号为1Y7411n7vc的视频属性抓取结束
# 开始BV号为1z7411N7ke视频属性的抓取
# BV号为1z7411N7ke的视频属性抓取结束
# 开始BV号为1w7411j7Qv视频属性的抓取
# BV号为1w7411j7Qv的视频属性抓取结束
# 开始BV号为1V7411T7LY视频属性的抓取
# BV号为1V7411T7LY的视频属性抓取结束
# 开始BV号为1J7411p732视频属性的抓取
# BV号为1J7411p732的视频属性抓取结束
# 开始BV号为1i7411w7Ge视频属性的抓取
# BV号为1i7411w7Ge的视频属性抓取结束
# 开始BV号为177411t7EN视频属性的抓取
# BV号为177411t7EN的视频属性抓取结束
# 开始BV号为1e741187rM视频属性的抓取
# BV号为1e741187rM的视频属性抓取结束
# 开始BV号为1Z7411M7Dy视频属性的抓取
# BV号为1Z7411M7Dy的视频属性抓取结束
# 开始BV号为1v7411W77j视频属性的抓取
# BV号为1v7411W77j的视频属性抓取结束
# 开始BV号为1s7411p7xw视频属性的抓取
# BV号为1s7411p7xw的视频属性抓取结束
# 开始BV号为1E7411G7nM视频属性的抓取
# BV号为1E7411G7nM的视频属性抓取结束
# 开始BV号为1c741147Q1视频属性的抓取
# BV号为1c741147Q1的视频属性抓取结束
# 开始BV号为1k7411G7fb视频属性的抓取
# BV号为1k7411G7fb的视频属性抓取结束
# 开始BV号为1H7411T7jh视频属性的抓取
# BV号为1H7411T7jh的视频属性抓取结束
# 开始BV号为1k7411471N视频属性的抓取
# BV号为1k7411471N的视频属性抓取结束
# 开始BV号为1y741177LU视频属性的抓取
# BV号为1y741177LU的视频属性抓取结束
# 开始BV号为12741187mK视频属性的抓取
# BV号为12741187mK的视频属性抓取结束
# 开始BV号为1w7411j7cJ视频属性的抓取
# BV号为1w7411j7cJ的视频属性抓取结束
# 开始BV号为1G741177Yj视频属性的抓取
# BV号为1G741177Yj的视频属性抓取结束
# 开始BV号为1d741177Be视频属性的抓取
# BV号为1d741177Be的视频属性抓取结束
# 开始BV号为16j411f7S2视频属性的抓取
# BV号为16j411f7S2的视频属性抓取结束
# 开始BV号为1m7411x7vi视频属性的抓取
# BV号为1m7411x7vi的视频属性抓取结束
# 开始BV号为1a7411N7rV视频属性的抓取
# BV号为1a7411N7rV的视频属性抓取结束
# 开始BV号为1r7411J76f视频属性的抓取
# BV号为1r7411J76f的视频属性抓取结束
# 开始BV号为1M7411A729视频属性的抓取
# BV号为1M7411A729的视频属性抓取结束
# 开始BV号为1M7411j7JF视频属性的抓取
# BV号为1M7411j7JF的视频属性抓取结束
# 开始BV号为1m741177W9视频属性的抓取
# BV号为1m741177W9的视频属性抓取结束
# 开始BV号为1G741157Vi视频属性的抓取
# BV号为1G741157Vi的视频属性抓取结束
# 开始BV号为197411s7zC视频属性的抓取
# BV号为197411s7zC的视频属性抓取结束
# 开始BV号为147411n7KW视频属性的抓取
# BV号为147411n7KW的视频属性抓取结束
# 开始BV号为1XE411E7qC视频属性的抓取
# BV号为1XE411E7qC的视频属性抓取结束
# 开始BV号为1F54y1d71h视频属性的抓取
# BV号为1F54y1d71h的视频属性抓取结束
# 开始BV号为1kE411T7NT视频属性的抓取
# BV号为1kE411T7NT的视频属性抓取结束
# 开始BV号为1NE411t7Dv视频属性的抓取
# BV号为1NE411t7Dv的视频属性抓取结束
# 开始BV号为12E41177PQ视频属性的抓取
# BV号为12E41177PQ的视频属性抓取结束
# 开始BV号为1mE411g712视频属性的抓取
# BV号为1mE411g712的视频属性抓取结束
# 开始BV号为177411R7kp视频属性的抓取
# BV号为177411R7kp的视频属性抓取结束
# 开始BV号为19E411p7Ky视频属性的抓取
# BV号为19E411p7Ky的视频属性抓取结束
# 开始BV号为1Y741127ps视频属性的抓取
# BV号为1Y741127ps的视频属性抓取结束
# 开始BV号为1QE411W7G8视频属性的抓取
# BV号为1QE411W7G8的视频属性抓取结束
# 开始BV号为1ME411478V视频属性的抓取
# BV号为1ME411478V的视频属性抓取结束
# 开始BV号为1kE41157kM视频属性的抓取
# BV号为1kE41157kM的视频属性抓取结束
# 开始BV号为1PE411x7hS视频属性的抓取
# BV号为1PE411x7hS的视频属性抓取结束
# 开始BV号为1SE411T7uX视频属性的抓取
# BV号为1SE411T7uX的视频属性抓取结束
# 开始BV号为1w7411X7N6视频属性的抓取
# BV号为1w7411X7N6的视频属性抓取结束
# 开始BV号为1Q7411R7AM视频属性的抓取
# BV号为1Q7411R7AM的视频属性抓取结束
# 开始BV号为16E41147mZ视频属性的抓取
# BV号为16E41147mZ的视频属性抓取结束
# 开始BV号为1vE411P7qd视频属性的抓取
# BV号为1vE411P7qd的视频属性抓取结束
# 开始BV号为1DE411j7PH视频属性的抓取
# BV号为1DE411j7PH的视频属性抓取结束
# 开始BV号为1GE411L7AK视频属性的抓取
# BV号为1GE411L7AK的视频属性抓取结束
# 开始BV号为1ZE411A76d视频属性的抓取
# BV号为1ZE411A76d的视频属性抓取结束
# 开始BV号为1SE411u7jq视频属性的抓取
# BV号为1SE411u7jq的视频属性抓取结束
# 开始BV号为1DE411P7EL视频属性的抓取
# BV号为1DE411P7EL的视频属性抓取结束
# 开始BV号为1aE411N7Tk视频属性的抓取
# BV号为1aE411N7Tk的视频属性抓取结束
# 开始BV号为1YE411G7Ar视频属性的抓取
# BV号为1YE411G7Ar的视频属性抓取结束
# 开始BV号为1P7411o7Fo视频属性的抓取
# BV号为1P7411o7Fo的视频属性抓取结束
# 开始BV号为17E411x7Hb视频属性的抓取
# BV号为17E411x7Hb的视频属性抓取结束
# 开始BV号为1R7411d78D视频属性的抓取
# BV号为1R7411d78D的视频属性抓取结束
# 开始BV号为1sE411u7ky视频属性的抓取
# BV号为1sE411u7ky的视频属性抓取结束
# 开始BV号为1NE411L7jm视频属性的抓取
# BV号为1NE411L7jm的视频属性抓取结束
# 开始BV号为1HE41147SM视频属性的抓取
# BV号为1HE41147SM的视频属性抓取结束
# 开始BV号为1sE411x7Ko视频属性的抓取
# BV号为1sE411x7Ko的视频属性抓取结束
# 开始BV号为1y741127BH视频属性的抓取
# BV号为1y741127BH的视频属性抓取结束
# 开始BV号为1vE411G7a3视频属性的抓取
# BV号为1vE411G7a3的视频属性抓取结束
# 开始BV号为1RE411G7Sy视频属性的抓取
# BV号为1RE411G7Sy的视频属性抓取结束
# 开始BV号为1VE411F7pJ视频属性的抓取
# BV号为1VE411F7pJ的视频属性抓取结束
# 开始BV号为1CE411W75E视频属性的抓取
# BV号为1CE411W75E的视频属性抓取结束
# 开始BV号为1Fk4y1o7ub视频属性的抓取
# BV号为1Fk4y1o7ub的视频属性抓取结束
# 开始BV号为1yE411A7o9视频属性的抓取
# BV号为1yE411A7o9的视频属性抓取结束
# 开始BV号为1tZ4y1j7r6视频属性的抓取
# BV号为1tZ4y1j7r6的视频属性抓取结束
# 开始BV号为18Z4y1j7Ww视频属性的抓取
# BV号为18Z4y1j7Ww的视频属性抓取结束
# 开始BV号为1Y741117Lk视频属性的抓取
# BV号为1Y741117Lk的视频属性抓取结束
# 开始BV号为1m7411y7kD视频属性的抓取
# BV号为1m7411y7kD的视频属性抓取结束
# 开始BV号为19E411H7FF视频属性的抓取
# BV号为19E411H7FF的视频属性抓取结束
# 开始BV号为1V7411m74x视频属性的抓取
# BV号为1V7411m74x的视频属性抓取结束
# 开始BV号为1pp4y1C7KW视频属性的抓取
# BV号为1pp4y1C7KW的视频属性抓取结束
# 开始BV号为137411U71Q视频属性的抓取
# BV号为137411U71Q的视频属性抓取结束
# 开始BV号为1EE411W7Jm视频属性的抓取
# BV号为1EE411W7Jm的视频属性抓取结束
# 开始BV号为1o7411R74J视频属性的抓取
# BV号为1o7411R74J的视频属性抓取结束
# 开始BV号为1X741197wn视频属性的抓取
# BV号为1X741197wn的视频属性抓取结束
# 开始BV号为1LE411V7iJ视频属性的抓取
# BV号为1LE411V7iJ的视频属性抓取结束
# 开始BV号为16E411W7R3视频属性的抓取
# BV号为16E411W7R3的视频属性抓取结束
# 开始BV号为18E411E74r视频属性的抓取
# BV号为18E411E74r的视频属性抓取结束
# 开始BV号为1xE411E7B3视频属性的抓取
# BV号为1xE411E7B3的视频属性抓取结束
# 开始BV号为1h7411f7pP视频属性的抓取
# BV号为1h7411f7pP的视频属性抓取结束
# 开始BV号为1s7411C7i8视频属性的抓取
# BV号为1s7411C7i8的视频属性抓取结束
# 开始BV号为1kE411j7Qe视频属性的抓取
# BV号为1kE411j7Qe的视频属性抓取结束
# 开始BV号为1HC4y1s7wS视频属性的抓取
# BV号为1HC4y1s7wS的视频属性抓取结束
# 开始BV号为1vE411g73U视频属性的抓取
# BV号为1vE411g73U的视频属性抓取结束
# 开始BV号为1rE411p7nM视频属性的抓取
# BV号为1rE411p7nM的视频属性抓取结束
# 开始BV号为1d7411f7rH视频属性的抓取
# BV号为1d7411f7rH的视频属性抓取结束
# 开始BV号为1LE411W7gt视频属性的抓取
# BV号为1LE411W7gt的视频属性抓取结束
# 开始BV号为1sE411N7j2视频属性的抓取
# BV号为1sE411N7j2的视频属性抓取结束
# 开始BV号为1a7411Q7Vt视频属性的抓取
# BV号为1a7411Q7Vt的视频属性抓取结束
# 开始BV号为1c741127m5视频属性的抓取
# BV号为1c741127m5的视频属性抓取结束
# 开始BV号为1YE411N7Cj视频属性的抓取
# BV号为1YE411N7Cj的视频属性抓取结束
# 开始BV号为1YE41147EP视频属性的抓取
# BV号为1YE41147EP的视频属性抓取结束
# 开始BV号为1xE411w79q视频属性的抓取
# BV号为1xE411w79q的视频属性抓取结束
# 开始BV号为1pE411j7gC视频属性的抓取
# BV号为1pE411j7gC的视频属性抓取结束
# 开始BV号为15e411x7ub视频属性的抓取
# BV号为15e411x7ub的视频属性抓取结束
# 开始BV号为1HE411N7M2视频属性的抓取
# BV号为1HE411N7M2的视频属性抓取结束
# 开始BV号为1x741127ky视频属性的抓取
# BV号为1x741127ky的视频属性抓取结束
# 开始BV号为1XE411T7ZK视频属性的抓取
# BV号为1XE411T7ZK的视频属性抓取结束
# 开始BV号为1XE411M7p2视频属性的抓取
# BV号为1XE411M7p2的视频属性抓取结束
# 开始BV号为1764y1u77L视频属性的抓取
# BV号为1764y1u77L的视频属性抓取结束
# 开始BV号为1SE41177ek视频属性的抓取
# BV号为1SE41177ek的视频属性抓取结束
# 开始BV号为1uE411w7Sd视频属性的抓取
# BV号为1uE411w7Sd的视频属性抓取结束
# 开始BV号为1PE411M7Pd视频属性的抓取
# BV号为1PE411M7Pd的视频属性抓取结束
# 开始BV号为1nE411M7PY视频属性的抓取
# BV号为1nE411M7PY的视频属性抓取结束
# 开始BV号为1NE41157JP视频属性的抓取
# BV号为1NE41157JP的视频属性抓取结束
# 开始BV号为1yE411s7yQ视频属性的抓取
# BV号为1yE411s7yQ的视频属性抓取结束
# 开始BV号为1oE41157cS视频属性的抓取
# BV号为1oE41157cS的视频属性抓取结束
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# 开始BV号为1Z7411Z7TJ视频属性的抓取
# BV号为1Z7411Z7TJ的视频属性抓取结束
# 开始BV号为19E411u7V4视频属性的抓取
# BV号为19E411u7V4的视频属性抓取结束
# 开始BV号为1ZE411G7a5视频属性的抓取
# BV号为1ZE411G7a5的视频属性抓取结束
# 开始BV号为1mE411T7xD视频属性的抓取
# BV号为1mE411T7xD的视频属性抓取结束
# 开始BV号为1CE411V7Nc视频属性的抓取
# BV号为1CE411V7Nc的视频属性抓取结束
# 开始BV号为1cE41137re视频属性的抓取
# BV号为1cE41137re的视频属性抓取结束
# 开始BV号为1a7411Q7QL视频属性的抓取
# BV号为1a7411Q7QL的视频属性抓取结束
# 开始BV号为1xE411s7bG视频属性的抓取
# BV号为1xE411s7bG的视频属性抓取结束
# 开始BV号为1vE411u7gM视频属性的抓取
# BV号为1vE411u7gM的视频属性抓取结束
# 开始BV号为1nE411N7MV视频属性的抓取
# BV号为1nE411N7MV的视频属性抓取结束
# 开始BV号为1U7411d7Ge视频属性的抓取
# BV号为1U7411d7Ge的视频属性抓取结束
# 开始BV号为1SE411E7i9视频属性的抓取
# BV号为1SE411E7i9的视频属性抓取结束
# 开始BV号为1xE41147KF视频属性的抓取
# BV号为1xE41147KF的视频属性抓取结束
# 开始BV号为1RE41147m3视频属性的抓取
# BV号为1RE41147m3的视频属性抓取结束
# 开始BV号为1U74112744视频属性的抓取
# BV号为1U74112744的视频属性抓取结束
# 开始BV号为1uE41157NW视频属性的抓取
# BV号为1uE41157NW的视频属性抓取结束
# 开始BV号为1BC4y147Dk视频属性的抓取
# BV号为1BC4y147Dk的视频属性抓取结束
# 开始BV号为1aE411E7wp视频属性的抓取
# BV号为1aE411E7wp的视频属性抓取结束
# 开始BV号为1sV411Z7nf视频属性的抓取
# BV号为1sV411Z7nf的视频属性抓取结束
# 开始BV号为1uZ4y1x77J视频属性的抓取
# BV号为1uZ4y1x77J的视频属性抓取结束
# 开始BV号为1C54y197CT视频属性的抓取
# BV号为1C54y197CT的视频属性抓取结束
# 开始BV号为1Zk4y197QB视频属性的抓取
# BV号为1Zk4y197QB的视频属性抓取结束
# 开始BV号为17Q4y1K7Ep视频属性的抓取
# BV号为17Q4y1K7Ep的视频属性抓取结束
# 开始BV号为1mK411V7wY视频属性的抓取
# BV号为1mK411V7wY的视频属性抓取结束
# 开始BV号为1Ug4y187Bt视频属性的抓取
# BV号为1Ug4y187Bt的视频属性抓取结束
# 开始BV号为1gT4y1V7VR视频属性的抓取
# BV号为1gT4y1V7VR的视频属性抓取结束
# 开始BV号为1wp4y197xU视频属性的抓取
# BV号为1wp4y197xU的视频属性抓取结束
# 开始BV号为1sa4y1t7Qo视频属性的抓取
# BV号为1sa4y1t7Qo的视频属性抓取结束
# 开始BV号为1Ke41147cZ视频属性的抓取
# BV号为1Ke41147cZ的视频属性抓取结束
# 开始BV号为185411x72Q视频属性的抓取
# BV号为185411x72Q的视频属性抓取结束
# 开始BV号为1PZ4y1x7St视频属性的抓取
# BV号为1PZ4y1x7St的视频属性抓取结束
# 开始BV号为1FK411j7jR视频属性的抓取
# BV号为1FK411j7jR的视频属性抓取结束
# 开始BV号为1hp4y1C7tn视频属性的抓取
# BV号为1hp4y1C7tn的视频属性抓取结束
# 开始BV号为1nC4y1W7Su视频属性的抓取
# BV号为1nC4y1W7Su的视频属性抓取结束
# 开始BV号为1KT4y157zG视频属性的抓取
# BV号为1KT4y157zG的视频属性抓取结束
# 开始BV号为12z411B7vJ视频属性的抓取
# BV号为12z411B7vJ的视频属性抓取结束
# 开始BV号为1Gk4y1R7pu视频属性的抓取
# BV号为1Gk4y1R7pu的视频属性抓取结束
# 开始BV号为1UQ4y1M7iJ视频属性的抓取
# BV号为1UQ4y1M7iJ的视频属性抓取结束
# 开始BV号为1gT4y1V7PB视频属性的抓取
# BV号为1gT4y1V7PB的视频属性抓取结束
# 开始BV号为1ng4y187pt视频属性的抓取
# BV号为1ng4y187pt的视频属性抓取结束
# 开始BV号为13i4y1t7Dd视频属性的抓取
# BV号为13i4y1t7Dd的视频属性抓取结束
# 开始BV号为1Ft4y1m7fR视频属性的抓取
# 开始BV号为1Ft4y1m7fR视频属性的抓取
# BV号为1Ft4y1m7fR的视频属性抓取结束
# 开始BV号为1tA411h7mW视频属性的抓取
# BV号为1tA411h7mW的视频属性抓取结束
# 开始BV号为1sV411Z7K1视频属性的抓取
# BV号为1sV411Z7K1的视频属性抓取结束
# 开始BV号为1Et4y127n9视频属性的抓取
# BV号为1Et4y127n9的视频属性抓取结束
# 开始BV号为19a4y1v7Lb视频属性的抓取
# BV号为19a4y1v7Lb的视频属性抓取结束
# 开始BV号为1hz411b7M1视频属性的抓取
# BV号为1hz411b7M1的视频属性抓取结束
# 开始BV号为1qZ4y1W7Qt视频属性的抓取
# BV号为1qZ4y1W7Qt的视频属性抓取结束
# 开始BV号为1HV411Z7Dr视频属性的抓取
# BV号为1HV411Z7Dr的视频属性抓取结束
# 开始BV号为1Ai4y1t7kh视频属性的抓取
# BV号为1Ai4y1t7kh的视频属性抓取结束
# 开始BV号为1aA41187DX视频属性的抓取
# BV号为1aA41187DX的视频属性抓取结束
# 开始BV号为1KV411d7fT视频属性的抓取
# BV号为1KV411d7fT的视频属性抓取结束
# 开始BV号为1GA411h78p视频属性的抓取
# BV号为1GA411h78p的视频属性抓取结束
# 开始BV号为1Wt4y1U7Cw视频属性的抓取
# BV号为1Wt4y1U7Cw的视频属性抓取结束
# 开始BV号为1uz411z7xM视频属性的抓取
# BV号为1uz411z7xM的视频属性抓取结束
# 开始BV号为1N54y1R7vZ视频属性的抓取
# BV号为1N54y1R7vZ的视频属性抓取结束
# 开始BV号为1Cg4y187gD视频属性的抓取
# BV号为1Cg4y187gD的视频属性抓取结束
# 开始BV号为1R54y1Q7kw视频属性的抓取
# BV号为1R54y1Q7kw的视频属性抓取结束
# 开始BV号为1E64y1M7EU视频属性的抓取
# BV号为1E64y1M7EU的视频属性抓取结束
# 开始BV号为1mK4y1r7oE视频属性的抓取
# BV号为1mK4y1r7oE的视频属性抓取结束
# 开始BV号为1UT4y1G7g7视频属性的抓取
# BV号为1UT4y1G7g7的视频属性抓取结束
# 开始BV号为16k4y1r7iR视频属性的抓取
# BV号为16k4y1r7iR的视频属性抓取结束
# 开始BV号为1zA41147Nm视频属性的抓取
# BV号为1zA41147Nm的视频属性抓取结束
# 开始BV号为1jA411b7JA视频属性的抓取
# BV号为1jA411b7JA的视频属性抓取结束
# 开始BV号为1B54y1Q7No视频属性的抓取
# BV号为1B54y1Q7No的视频属性抓取结束
# 开始BV号为1ea4y1t7B9视频属性的抓取
# BV号为1ea4y1t7B9的视频属性抓取结束
# 开始BV号为1FQ4y1T7B1视频属性的抓取
# BV号为1FQ4y1T7B1的视频属性抓取结束
# 开始BV号为1sg4y1z7kc视频属性的抓取
# BV号为1sg4y1z7kc的视频属性抓取结束
# 开始BV号为1yg4y1b7jC视频属性的抓取
# BV号为1yg4y1b7jC的视频属性抓取结束
# 开始BV号为1w5411t7bk视频属性的抓取
# BV号为1w5411t7bk的视频属性抓取结束
# 开始BV号为1cV411d7nE视频属性的抓取
# BV号为1cV411d7nE的视频属性抓取结束
# 开始BV号为1PK41157UE视频属性的抓取
# BV号为1PK41157UE的视频属性抓取结束
# 开始BV号为1Fe4114713视频属性的抓取
# BV号为1Fe4114713的视频属性抓取结束
# 开始BV号为1H54y1d7Hj视频属性的抓取
# BV号为1H54y1d7Hj的视频属性抓取结束
# 开始BV号为1s5411x7xU视频属性的抓取
# BV号为1s5411x7xU的视频属性抓取结束
# 开始BV号为1oC4y1s7Vt视频属性的抓取
# BV号为1oC4y1s7Vt的视频属性抓取结束
# 开始BV号为1WA411b7Y3视频属性的抓取
# BV号为1WA411b7Y3的视频属性抓取结束
# 开始BV号为1TV411o7k5视频属性的抓取
# BV号为1TV411o7k5的视频属性抓取结束
# 开始BV号为17K4y1b7N3视频属性的抓取
# BV号为17K4y1b7N3的视频属性抓取结束
# 开始BV号为14z411b7U4视频属性的抓取
# BV号为14z411b7U4的视频属性抓取结束
# 开始BV号为1iZ4y1W7wE视频属性的抓取
# BV号为1iZ4y1W7wE的视频属性抓取结束
# 开始BV号为1qQ4y1K7XD视频属性的抓取
# BV号为1qQ4y1K7XD的视频属性抓取结束
# 开始BV号为1KZ4y1x72H视频属性的抓取
# BV号为1KZ4y1x72H的视频属性抓取结束
# 开始BV号为1Xa4y1x7QU视频属性的抓取
# BV号为1Xa4y1x7QU的视频属性抓取结束
# 开始BV号为1vC4y1s79u视频属性的抓取
# BV号为1vC4y1s79u的视频属性抓取结束
# 开始BV号为1XK4y1C7av视频属性的抓取
# BV号为1XK4y1C7av的视频属性抓取结束
# 开始BV号为1BC4y1s77f视频属性的抓取
# BV号为1BC4y1s77f的视频属性抓取结束
# 开始BV号为1GC4y1W7jt视频属性的抓取
# BV号为1GC4y1W7jt的视频属性抓取结束
# 开始BV号为11z411B7N7视频属性的抓取
# BV号为11z411B7N7的视频属性抓取结束
# 开始BV号为19K4y1r75G视频属性的抓取
# BV号为19K4y1r75G的视频属性抓取结束
# 开始BV号为1NT4y137UF视频属性的抓取
# BV号为1NT4y137UF的视频属性抓取结束
# 开始BV号为1G54y1R75L视频属性的抓取
# BV号为1G54y1R75L的视频属性抓取结束
# 开始BV号为1Le411s7ff视频属性的抓取
# BV号为1Le411s7ff的视频属性抓取结束
# 开始BV号为1tK4y1r7rE视频属性的抓取
# BV号为1tK4y1r7rE的视频属性抓取结束
# 开始BV号为12g4y187y5视频属性的抓取
# BV号为12g4y187y5的视频属性抓取结束
# 开始BV号为1uZ4y1x7wC视频属性的抓取
# BV号为1uZ4y1x7wC的视频属性抓取结束
# 开始BV号为1ae411x7YC视频属性的抓取
# BV号为1ae411x7YC的视频属性抓取结束
# 开始BV号为1pf4y1S7M2视频属性的抓取
# BV号为1pf4y1S7M2的视频属性抓取结束
# 开始BV号为1ue411s7bs视频属性的抓取
# BV号为1ue411s7bs的视频属性抓取结束
# 开始BV号为1At4y1m7BC视频属性的抓取
# BV号为1At4y1m7BC的视频属性抓取结束
# 开始BV号为1Gz41187hw视频属性的抓取
# BV号为1Gz41187hw的视频属性抓取结束
# 开始BV号为1Gf4y1S74C视频属性的抓取
# BV号为1Gf4y1S74C的视频属性抓取结束
# 开始BV号为14e411x72G视频属性的抓取
# BV号为14e411x72G的视频属性抓取结束
# 开始BV号为1mk4y197zq视频属性的抓取
# BV号为1mk4y197zq的视频属性抓取结束
# 开始BV号为1v5411x7Gz视频属性的抓取
# BV号为1v5411x7Gz的视频属性抓取结束
# 开始BV号为1YK4y1k7vA视频属性的抓取
# BV号为1YK4y1k7vA的视频属性抓取结束
# 开始BV号为1UQ4y1M7XB视频属性的抓取
# BV号为1UQ4y1M7XB的视频属性抓取结束
# 开始BV号为1UT4y1g7ju视频属性的抓取
# BV号为1UT4y1g7ju的视频属性抓取结束
# 开始BV号为1k54y197MV视频属性的抓取
# BV号为1k54y197MV的视频属性抓取结束
# 开始BV号为1at4y1m7dy视频属性的抓取
# BV号为1at4y1m7dy的视频属性抓取结束
# 开始BV号为1mi4y1b7NN视频属性的抓取
# BV号为1mi4y1b7NN的视频属性抓取结束
# 开始BV号为15C4y1s7S8视频属性的抓取
# BV号为15C4y1s7S8的视频属性抓取结束
# 开始BV号为1Kt4y127xD视频属性的抓取
# BV号为1Kt4y127xD的视频属性抓取结束
# 开始BV号为1Ze411x7en视频属性的抓取
# BV号为1Ze411x7en的视频属性抓取结束
# <ipython-input-9-54d5a7f154fb>:190: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1iC4y1s7zw视频属性的抓取
# BV号为1iC4y1s7zw的视频属性抓取结束
# 开始BV号为1N64y1u78Z视频属性的抓取
# BV号为1N64y1u78Z的视频属性抓取结束
# 开始BV号为1854y1971i视频属性的抓取
# BV号为1854y1971i的视频属性抓取结束
# 开始BV号为1zZ4y1p7g3视频属性的抓取
# BV号为1zZ4y1p7g3的视频属性抓取结束
# 开始BV号为1o5411s76C视频属性的抓取
# BV号为1o5411s76C的视频属性抓取结束
# 开始BV号为14z411q7yv视频属性的抓取
# BV号为14z411q7yv的视频属性抓取结束
# 开始BV号为12K4y1t7BW视频属性的抓取
# BV号为12K4y1t7BW的视频属性抓取结束
# 开始BV号为13a4y1i7o9视频属性的抓取
# BV号为13a4y1i7o9的视频属性抓取结束
# 开始BV号为1At4y117WA视频属性的抓取
# BV号为1At4y117WA的视频属性抓取结束
# 开始BV号为15T4y1g7fi视频属性的抓取
# BV号为15T4y1g7fi的视频属性抓取结束
# 开始BV号为1Q5411s71H视频属性的抓取
# BV号为1Q5411s71H的视频属性抓取结束
# 开始BV号为17i4y147z2视频属性的抓取
# BV号为17i4y147z2的视频属性抓取结束
# 开始BV号为1Zz4y1R7tR视频属性的抓取
# BV号为1Zz4y1R7tR的视频属性抓取结束
# 开始BV号为1Si4y1474A视频属性的抓取
# BV号为1Si4y1474A的视频属性抓取结束
# 开始BV号为1jT4y137vd视频属性的抓取
# BV号为1jT4y137vd的视频属性抓取结束
# 开始BV号为1mK4y1t7ns视频属性的抓取
# BV号为1mK4y1t7ns的视频属性抓取结束
# 开始BV号为19K41157L3视频属性的抓取
# BV号为19K41157L3的视频属性抓取结束
# 开始BV号为17z411B7i3视频属性的抓取
# BV号为17z411B7i3的视频属性抓取结束
# 开始BV号为1RK4y147sM视频属性的抓取
# BV号为1RK4y147sM的视频属性抓取结束
# 开始BV号为1vi4y147Uq视频属性的抓取
# BV号为1vi4y147Uq的视频属性抓取结束
# 开始BV号为1uK4y187Ck视频属性的抓取
# BV号为1uK4y187Ck的视频属性抓取结束
# 开始BV号为1P54y1X7F7视频属性的抓取
# BV号为1P54y1X7F7的视频属性抓取结束
# 开始BV号为1qi4y1s7eq视频属性的抓取
# BV号为1qi4y1s7eq的视频属性抓取结束
# 开始BV号为1ri4y147hQ视频属性的抓取
# BV号为1ri4y147hQ的视频属性抓取结束
# 开始BV号为1sk4y1k76k视频属性的抓取
# BV号为1sk4y1k76k的视频属性抓取结束
# 开始BV号为17f4y1U73j视频属性的抓取
# BV号为17f4y1U73j的视频属性抓取结束
# 开始BV号为1Ev411z79Q视频属性的抓取
# BV号为1Ev411z79Q的视频属性抓取结束
# 开始BV号为1LC4y1p7VK视频属性的抓取
# BV号为1LC4y1p7VK的视频属性抓取结束
# 开始BV号为1qV411C7n5视频属性的抓取
# BV号为1qV411C7n5的视频属性抓取结束
# 开始BV号为1it4y1C79Y视频属性的抓取
# 开始BV号为1it4y1C79Y视频属性的抓取
# BV号为1it4y1C79Y的视频属性抓取结束
# 开始BV号为1dp4y1Q7jB视频属性的抓取
# 开始BV号为1dp4y1Q7jB视频属性的抓取
# 开始BV号为1dp4y1Q7jB视频属性的抓取
# BV号为1dp4y1Q7jB的视频属性抓取结束
# 开始BV号为11g4y1B7mP视频属性的抓取
# BV号为11g4y1B7mP的视频属性抓取结束
# 开始BV号为1Qi4y1479W视频属性的抓取
# BV号为1Qi4y1479W的视频属性抓取结束
# 开始BV号为1Ep4y1X7Xs视频属性的抓取
# BV号为1Ep4y1X7Xs的视频属性抓取结束
# 开始BV号为1oz411q7uc视频属性的抓取
# BV号为1oz411q7uc的视频属性抓取结束
# 开始BV号为1Jt4y117eN视频属性的抓取
# BV号为1Jt4y117eN的视频属性抓取结束
# 开始BV号为1Tz411B75n视频属性的抓取
# BV号为1Tz411B75n的视频属性抓取结束
# 开始BV号为1tK4y187yo视频属性的抓取
# BV号为1tK4y187yo的视频属性抓取结束
# 开始BV号为1pe411W7fA视频属性的抓取
# BV号为1pe411W7fA的视频属性抓取结束
# 开始BV号为1dK411H7Rw视频属性的抓取
# BV号为1dK411H7Rw的视频属性抓取结束
# 开始BV号为1bK4y1t7Ep视频属性的抓取
# BV号为1bK4y1t7Ep的视频属性抓取结束
# 开始BV号为1CK411W7X1视频属性的抓取
# BV号为1CK411W7X1的视频属性抓取结束
# 开始BV号为1Yg4y1B7MY视频属性的抓取
# BV号为1Yg4y1B7MY的视频属性抓取结束
# 开始BV号为17f4y12713视频属性的抓取
# BV号为17f4y12713的视频属性抓取结束
# 开始BV号为1g541147qC视频属性的抓取
# BV号为1g541147qC的视频属性抓取结束
# 开始BV号为1iZ4y1p7Jy视频属性的抓取
# BV号为1iZ4y1p7Jy的视频属性抓取结束
# 开始BV号为12K411H7CS视频属性的抓取
# BV号为12K411H7CS的视频属性抓取结束
# 开始BV号为1y54y1D7bW视频属性的抓取
# BV号为1y54y1D7bW的视频属性抓取结束
# 开始BV号为1TZ4y1s7bA视频属性的抓取
# BV号为1TZ4y1s7bA的视频属性抓取结束
# 开始BV号为1CQ4y1A7n9视频属性的抓取
# BV号为1CQ4y1A7n9的视频属性抓取结束
# 开始BV号为1VV411C7vf视频属性的抓取
# BV号为1VV411C7vf的视频属性抓取结束
# 开始BV号为1DZ4y1s7UQ视频属性的抓取
# BV号为1DZ4y1s7UQ的视频属性抓取结束
# 开始BV号为1wt4y1173V视频属性的抓取
# BV号为1wt4y1173V的视频属性抓取结束
# 开始BV号为1gz4y1d7PE视频属性的抓取
# BV号为1gz4y1d7PE的视频属性抓取结束
# 开始BV号为1U54y1X7gF视频属性的抓取
# BV号为1U54y1X7gF的视频属性抓取结束
# 开始BV号为1mA411t7d4视频属性的抓取
# BV号为1mA411t7d4的视频属性抓取结束
# 开始BV号为1dZ4y1s7NC视频属性的抓取
# BV号为1dZ4y1s7NC的视频属性抓取结束
# 开始BV号为14Q4y1N7P5视频属性的抓取
# BV号为14Q4y1N7P5的视频属性抓取结束
# 开始BV号为1Xz4y1X7oZ视频属性的抓取
# BV号为1Xz4y1X7oZ的视频属性抓取结束
# 开始BV号为1M5411x73P视频属性的抓取
# BV号为1M5411x73P的视频属性抓取结束
# 开始BV号为1nt4y117wK视频属性的抓取
# BV号为1nt4y117wK的视频属性抓取结束
# 开始BV号为17A411q7dC视频属性的抓取
# BV号为17A411q7dC的视频属性抓取结束
# 开始BV号为1Fi4y1t7k6视频属性的抓取
# BV号为1Fi4y1t7k6的视频属性抓取结束
# 开始BV号为13V411C7EA视频属性的抓取
# BV号为13V411C7EA的视频属性抓取结束
# 开始BV号为13f4y127fi视频属性的抓取
# BV号为13f4y127fi的视频属性抓取结束
# 开始BV号为1Sk4y1672U视频属性的抓取
# BV号为1Sk4y1672U的视频属性抓取结束
# 开始BV号为1PA411q7x4视频属性的抓取
# BV号为1PA411q7x4的视频属性抓取结束
# 开始BV号为1pt4y1C7t5视频属性的抓取
# BV号为1pt4y1C7t5的视频属性抓取结束
# 开始BV号为1954y1D7ai视频属性的抓取
# BV号为1954y1D7ai的视频属性抓取结束
# 开始BV号为1Wi4y147HJ视频属性的抓取
# BV号为1Wi4y147HJ的视频属性抓取结束
# 开始BV号为1c54y1Q77s视频属性的抓取
# BV号为1c54y1Q77s的视频属性抓取结束
# 开始BV号为15K4y1t7uB视频属性的抓取
# BV号为15K4y1t7uB的视频属性抓取结束
# 开始BV号为11z411q77X视频属性的抓取
# BV号为11z411q77X的视频属性抓取结束
# 开始BV号为1MK4y1t7dc视频属性的抓取
# BV号为1MK4y1t7dc的视频属性抓取结束
# 开始BV号为1EQ4y1N7EN视频属性的抓取
# BV号为1EQ4y1N7EN的视频属性抓取结束
# 开始BV号为1Xz411q7Qe视频属性的抓取
# BV号为1Xz411q7Qe的视频属性抓取结束
# 开始BV号为1Eg4y1B7tU视频属性的抓取
# BV号为1Eg4y1B7tU的视频属性抓取结束
# 开始BV号为1af4y1m7ce视频属性的抓取
# BV号为1af4y1m7ce的视频属性抓取结束
# 开始BV号为1Kz4y1d7np视频属性的抓取
# BV号为1Kz4y1d7np的视频属性抓取结束
# 开始BV号为1nT4y1u7TL视频属性的抓取
# BV号为1nT4y1u7TL的视频属性抓取结束
# 开始BV号为1Xa4y1i72m视频属性的抓取
# BV号为1Xa4y1i72m的视频属性抓取结束
# 开始BV号为1HA411t7x4视频属性的抓取
# BV号为1HA411t7x4的视频属性抓取结束
# 开始BV号为1bi4y1s7ow视频属性的抓取
# BV号为1bi4y1s7ow的视频属性抓取结束
# 开始BV号为1uz411q77J视频属性的抓取
# BV号为1uz411q77J的视频属性抓取结束
# 开始BV号为1gp4y1X7Zn视频属性的抓取
# BV号为1gp4y1X7Zn的视频属性抓取结束
# 开始BV号为1dK4y1476D视频属性的抓取
# BV号为1dK4y1476D的视频属性抓取结束
# 开始BV号为1RA411i78f视频属性的抓取
# BV号为1RA411i78f的视频属性抓取结束
# 开始BV号为1bC4y1p7uE视频属性的抓取
# BV号为1bC4y1p7uE的视频属性抓取结束
# 开始BV号为1iT4y1379H视频属性的抓取
# BV号为1iT4y1379H的视频属性抓取结束
# 开始BV号为1754y1D7Nt视频属性的抓取
# BV号为1754y1D7Nt的视频属性抓取结束
# 开始BV号为1XQ4y1A7ro视频属性的抓取
# BV号为1XQ4y1A7ro的视频属性抓取结束
# 开始BV号为1zz411q7RN视频属性的抓取
# BV号为1zz411q7RN的视频属性抓取结束
# 开始BV号为1ZA411i7pp视频属性的抓取
# BV号为1ZA411i7pp的视频属性抓取结束
# 开始BV号为1A5411s7ve视频属性的抓取
# BV号为1A5411s7ve的视频属性抓取结束
# 开始BV号为16Z4y1p7rH视频属性的抓取
# BV号为16Z4y1p7rH的视频属性抓取结束
# 开始BV号为1hi4y1s7Cs视频属性的抓取
# BV号为1hi4y1s7Cs的视频属性抓取结束
# 开始BV号为1Yi4y1s7TV视频属性的抓取
# BV号为1Yi4y1s7TV的视频属性抓取结束
# 开始BV号为16Q4y1A7b1视频属性的抓取
# BV号为16Q4y1A7b1的视频属性抓取结束
# 开始BV号为1VT4y1u7dk视频属性的抓取
# BV号为1VT4y1u7dk的视频属性抓取结束
# 开始BV号为1hv411z7P3视频属性的抓取
# BV号为1hv411z7P3的视频属性抓取结束
# 开始BV号为18e411p7xq视频属性的抓取
# BV号为18e411p7xq的视频属性抓取结束
# 开始BV号为1ba4y1e7jP视频属性的抓取
# BV号为1ba4y1e7jP的视频属性抓取结束
# 开始BV号为1pz411q7D9视频属性的抓取
# BV号为1pz411q7D9的视频属性抓取结束
# 开始BV号为1pv41167CH视频属性的抓取
# BV号为1pv41167CH的视频属性抓取结束
# 开始BV号为11f4y127AC视频属性的抓取
# BV号为11f4y127AC的视频属性抓取结束
# 开始BV号为1Nk4y1z7G2视频属性的抓取
# BV号为1Nk4y1z7G2的视频属性抓取结束
# 开始BV号为13a4y1Y746视频属性的抓取
# BV号为13a4y1Y746的视频属性抓取结束
# 开始BV号为1yK411p7nB视频属性的抓取
# BV号为1yK411p7nB的视频属性抓取结束
# 开始BV号为17Z4y1H7Mp视频属性的抓取
# BV号为17Z4y1H7Mp的视频属性抓取结束
# 开始BV号为1Ef4y117cS视频属性的抓取
# BV号为1Ef4y117cS的视频属性抓取结束
# 开始BV号为1qz4y1X7ss视频属性的抓取
# BV号为1qz4y1X7ss的视频属性抓取结束
# 开始BV号为1tp4y1D7zU视频属性的抓取
# BV号为1tp4y1D7zU的视频属性抓取结束
# 开始BV号为1fA411q7Ck视频属性的抓取
# BV号为1fA411q7Ck的视频属性抓取结束
# 开始BV号为1dz411i7x5视频属性的抓取
# BV号为1dz411i7x5的视频属性抓取结束
# 开始BV号为1eZ4y1W7fJ视频属性的抓取
# BV号为1eZ4y1W7fJ的视频属性抓取结束
# 开始BV号为1Xi4y1s7qG视频属性的抓取
# BV号为1Xi4y1s7qG的视频属性抓取结束
# 开始BV号为1tv41167E2视频属性的抓取
# BV号为1tv41167E2的视频属性抓取结束
# 开始BV号为1mf4y127vA视频属性的抓取
# BV号为1mf4y127vA的视频属性抓取结束
# 开始BV号为19p4y1U7QU视频属性的抓取
# BV号为19p4y1U7QU的视频属性抓取结束
# 开始BV号为1EK4y1s73M视频属性的抓取
# BV号为1EK4y1s73M的视频属性抓取结束
# 开始BV号为17a4y1v7LT视频属性的抓取
# BV号为17a4y1v7LT的视频属性抓取结束
# 开始BV号为1xg4y1v7vP视频属性的抓取
# BV号为1xg4y1v7vP的视频属性抓取结束
# 开始BV号为1aQ4y1P7S1视频属性的抓取
# BV号为1aQ4y1P7S1的视频属性抓取结束
# 开始BV号为1Ga4y1e7et视频属性的抓取
# BV号为1Ga4y1e7et的视频属性抓取结束
# 开始BV号为1C54y1B727视频属性的抓取
# BV号为1C54y1B727的视频属性抓取结束
# 开始BV号为1sz4y197L8视频属性的抓取
# BV号为1sz4y197L8的视频属性抓取结束
# 开始BV号为1sz411i7Uh视频属性的抓取
# BV号为1sz411i7Uh的视频属性抓取结束
# 开始BV号为1az411i7Cf视频属性的抓取
# BV号为1az411i7Cf的视频属性抓取结束
# 开始BV号为1Ag4y1q7Kd视频属性的抓取
# BV号为1Ag4y1q7Kd的视频属性抓取结束
# 开始BV号为1pK4y147bk视频属性的抓取
# BV号为1pK4y147bk的视频属性抓取结束
# 开始BV号为1y5411W7dr视频属性的抓取
# BV号为1y5411W7dr的视频属性抓取结束
# 开始BV号为1of4y127AR视频属性的抓取
# BV号为1of4y127AR的视频属性抓取结束
# 开始BV号为12A411q7pA视频属性的抓取
# BV号为12A411q7pA的视频属性抓取结束
# 开始BV号为1hz411i7a4视频属性的抓取
# BV号为1hz411i7a4的视频属性抓取结束
# 开始BV号为19K4y1x7VB视频属性的抓取
# BV号为19K4y1x7VB的视频属性抓取结束
# 开始BV号为1Lz411i71Q视频属性的抓取
# BV号为1Lz411i71Q的视频属性抓取结束
# 开始BV号为1Uk4y1B7fx视频属性的抓取
# BV号为1Uk4y1B7fx的视频属性抓取结束
# 开始BV号为1cK411H7DA视频属性的抓取
# BV号为1cK411H7DA的视频属性抓取结束
# 开始BV号为1Up4y1D7C4视频属性的抓取
# BV号为1Up4y1D7C4的视频属性抓取结束
# 开始BV号为1iV411k7U1视频属性的抓取
# BV号为1iV411k7U1的视频属性抓取结束
# 开始BV号为115411W7cY视频属性的抓取
# BV号为115411W7cY的视频属性抓取结束
# 开始BV号为1h54y1Q7Kw视频属性的抓取
# BV号为1h54y1Q7Kw的视频属性抓取结束
# 开始BV号为1p5411W74W视频属性的抓取
# BV号为1p5411W74W的视频属性抓取结束
# 开始BV号为1xD4y1Q7c9视频属性的抓取
# BV号为1xD4y1Q7c9的视频属性抓取结束
# 开始BV号为1dz4y197EA视频属性的抓取
# BV号为1dz4y197EA的视频属性抓取结束
# 开始BV号为1dA411v7kj视频属性的抓取
# BV号为1dA411v7kj的视频属性抓取结束
# 开始BV号为1YK411p7uF视频属性的抓取
# BV号为1YK411p7uF的视频属性抓取结束
# 开始BV号为1ci4y1x78b视频属性的抓取
# BV号为1ci4y1x78b的视频属性抓取结束
# 开始BV号为1EZ4y1W7vL视频属性的抓取
# BV号为1EZ4y1W7vL的视频属性抓取结束
# 开始BV号为1cK411p7vc视频属性的抓取
# BV号为1cK411p7vc的视频属性抓取结束
# 开始BV号为15a4y1e7TX视频属性的抓取
# BV号为15a4y1e7TX的视频属性抓取结束
# 开始BV号为13p4y1D7Cg视频属性的抓取
# BV号为13p4y1D7Cg的视频属性抓取结束
# 开始BV号为1J5411Y7Rt视频属性的抓取
# BV号为1J5411Y7Rt的视频属性抓取结束
# 开始BV号为1Dp4y1S7Sf视频属性的抓取
# BV号为1Dp4y1S7Sf的视频属性抓取结束
# 开始BV号为1zz4y1975s视频属性的抓取
# BV号为1zz4y1975s的视频属性抓取结束
# 开始BV号为1vA411i79v视频属性的抓取
# BV号为1vA411i79v的视频属性抓取结束
# 开始BV号为1oC4y1a7aX视频属性的抓取
# BV号为1oC4y1a7aX的视频属性抓取结束
# 开始BV号为1xD4y1D7CY视频属性的抓取
# BV号为1xD4y1D7CY的视频属性抓取结束
# 开始BV号为1ef4y1y75R视频属性的抓取
# BV号为1ef4y1y75R的视频属性抓取结束
# 开始BV号为14V411671i视频属性的抓取
# BV号为14V411671i的视频属性抓取结束
# 开始BV号为1np4y1D7Wq视频属性的抓取
# BV号为1np4y1D7Wq的视频属性抓取结束
# 开始BV号为1cV411y7bv视频属性的抓取
# BV号为1cV411y7bv的视频属性抓取结束
# 开始BV号为1dz4y1Q7Sd视频属性的抓取
# BV号为1dz4y1Q7Sd的视频属性抓取结束
# 开始BV号为15Z4y1H7Sy视频属性的抓取
# BV号为15Z4y1H7Sy的视频属性抓取结束
# 开始BV号为1K5411Y7Rz视频属性的抓取
# BV号为1K5411Y7Rz的视频属性抓取结束
# 开始BV号为17i4y1G7V7视频属性的抓取
# BV号为17i4y1G7V7的视频属性抓取结束
# 开始BV号为1eV411r7aw视频属性的抓取
# BV号为1eV411r7aw的视频属性抓取结束
# 开始BV号为1YT4y1774Z视频属性的抓取
# BV号为1YT4y1774Z的视频属性抓取结束
# 开始BV号为1Ki4y1x7NK视频属性的抓取
# BV号为1Ki4y1x7NK的视频属性抓取结束
# 开始BV号为1UK411n7uK视频属性的抓取
# BV号为1UK411n7uK的视频属性抓取结束
# 开始BV号为1o5411p7Q2视频属性的抓取
# BV号为1o5411p7Q2的视频属性抓取结束
# 开始BV号为1rz411e7mM视频属性的抓取
# BV号为1rz411e7mM的视频属性抓取结束
# 开始BV号为1954y1i7x7视频属性的抓取
# BV号为1954y1i7x7的视频属性抓取结束
# 开始BV号为1DT4y1E71F视频属性的抓取
# BV号为1DT4y1E71F的视频属性抓取结束
# 开始BV号为1n54y1Q7GX视频属性的抓取
# BV号为1n54y1Q7GX的视频属性抓取结束
# 开始BV号为1Aa4y1Y75j视频属性的抓取
# BV号为1Aa4y1Y75j的视频属性抓取结束
# 开始BV号为1uf4y1m7aN视频属性的抓取
# BV号为1uf4y1m7aN的视频属性抓取结束
# 开始BV号为1Nf4y1m7pg视频属性的抓取
# BV号为1Nf4y1m7pg的视频属性抓取结束
# 开始BV号为1FT4y1J7kf视频属性的抓取
# BV号为1FT4y1J7kf的视频属性抓取结束
# 开始BV号为1ta4y1v7n5视频属性的抓取
# BV号为1ta4y1v7n5的视频属性抓取结束
# 开始BV号为13K4y1b7kz视频属性的抓取
# BV号为13K4y1b7kz的视频属性抓取结束
# 开始BV号为1Dp4y1U7zC视频属性的抓取
# BV号为1Dp4y1U7zC的视频属性抓取结束
# 开始BV号为1eK4y1x71J视频属性的抓取
# BV号为1eK4y1x71J的视频属性抓取结束
# 开始BV号为1Ja4y1Y78z视频属性的抓取
# BV号为1Ja4y1Y78z的视频属性抓取结束
# 开始BV号为1Pi4y1x7VT视频属性的抓取
# BV号为1Pi4y1x7VT的视频属性抓取结束
# 开始BV号为1EC4y1a7ZS视频属性的抓取
# BV号为1EC4y1a7ZS的视频属性抓取结束
# 开始BV号为1D5411W7h5视频属性的抓取
# BV号为1D5411W7h5的视频属性抓取结束
# 开始BV号为13t4y197aA视频属性的抓取
# BV号为13t4y197aA的视频属性抓取结束
# 开始BV号为1RA411v7Ny视频属性的抓取
# BV号为1RA411v7Ny的视频属性抓取结束
# 开始BV号为13C4y1a7CJ视频属性的抓取
# BV号为13C4y1a7CJ的视频属性抓取结束
# 开始BV号为1XK4y1x7om视频属性的抓取
# BV号为1XK4y1x7om的视频属性抓取结束
# 开始BV号为1rf4y1274y视频属性的抓取
# BV号为1rf4y1274y的视频属性抓取结束
# 开始BV号为1mZ4y1H7Vi视频属性的抓取
# BV号为1mZ4y1H7Vi的视频属性抓取结束
# 开始BV号为1ek4y1q7M8视频属性的抓取
# 开始BV号为1ek4y1q7M8视频属性的抓取
# 开始BV号为1ek4y1q7M8视频属性的抓取
# 开始BV号为1ek4y1q7M8视频属性的抓取
# BV号为1ek4y1q7M8的视频属性抓取结束
# 开始BV号为1dg4y1i7Fd视频属性的抓取
# BV号为1dg4y1i7Fd的视频属性抓取结束
# 开始BV号为1aK411p74f视频属性的抓取
# BV号为1aK411p74f的视频属性抓取结束
# 开始BV号为14z4y197Y7视频属性的抓取
# BV号为14z4y197Y7的视频属性抓取结束
# 开始BV号为1ET4y1J7s5视频属性的抓取
# BV号为1ET4y1J7s5的视频属性抓取结束
# 开始BV号为1Qv411B73W视频属性的抓取
# BV号为1Qv411B73W的视频属性抓取结束
# 开始BV号为11v411z7Dk视频属性的抓取
# BV号为11v411z7Dk的视频属性抓取结束
# 开始BV号为1tZ4y1W79u视频属性的抓取
# BV号为1tZ4y1W79u的视频属性抓取结束
# 开始BV号为16T4y1E7PM视频属性的抓取
# BV号为16T4y1E7PM的视频属性抓取结束
# 开始BV号为1Qf4y127E4视频属性的抓取
# BV号为1Qf4y127E4的视频属性抓取结束
# 开始BV号为1rV41167eW视频属性的抓取
# BV号为1rV41167eW的视频属性抓取结束
# 开始BV号为13Z4y1u7nb视频属性的抓取
# BV号为13Z4y1u7nb的视频属性抓取结束
# 开始BV号为1rp4y1U7Bc视频属性的抓取
# BV号为1rp4y1U7Bc的视频属性抓取结束
# 开始BV号为1ih411o7c6视频属性的抓取
# BV号为1ih411o7c6的视频属性抓取结束
# 开始BV号为1KT4y1E7Ku视频属性的抓取
# BV号为1KT4y1E7Ku的视频属性抓取结束
# 开始BV号为1fZ4y1H7TC视频属性的抓取
# BV号为1fZ4y1H7TC的视频属性抓取结束
# 开始BV号为1ND4y1S7Zs视频属性的抓取
# BV号为1ND4y1S7Zs的视频属性抓取结束
# 开始BV号为1qa4y1a7TG视频属性的抓取
# BV号为1qa4y1a7TG的视频属性抓取结束
# 开始BV号为1rp4y1i7oz视频属性的抓取
# BV号为1rp4y1i7oz的视频属性抓取结束
# 开始BV号为1Mk4y1B7w4视频属性的抓取
# BV号为1Mk4y1B7w4的视频属性抓取结束
# 开始BV号为1MK411J7Fg视频属性的抓取
# BV号为1MK411J7Fg的视频属性抓取结束
# 开始BV号为1T54y1S76o视频属性的抓取
# BV号为1T54y1S76o的视频属性抓取结束
# 开始BV号为17D4y1S7c1视频属性的抓取
# BV号为17D4y1S7c1的视频属性抓取结束
# 开始BV号为15p4y1S7JN视频属性的抓取
# BV号为15p4y1S7JN的视频属性抓取结束
# 开始BV号为1u54y1q7yM视频属性的抓取
# BV号为1u54y1q7yM的视频属性抓取结束
# 开始BV号为1fK4y1s7cc视频属性的抓取
# BV号为1fK4y1s7cc的视频属性抓取结束
# 开始BV号为1vD4y1S7dQ视频属性的抓取
# BV号为1vD4y1S7dQ的视频属性抓取结束
# 开始BV号为1PZ4y1p716视频属性的抓取
# BV号为1PZ4y1p716的视频属性抓取结束
# 开始BV号为1YZ4y1u7aE视频属性的抓取
# BV号为1YZ4y1u7aE的视频属性抓取结束
# 开始BV号为1iz4y1X7hv视频属性的抓取
# BV号为1iz4y1X7hv的视频属性抓取结束
# 开始BV号为16K4y1s7xk视频属性的抓取
# BV号为16K4y1s7xk的视频属性抓取结束
# 开始BV号为1Vk4y1m7zd视频属性的抓取
# BV号为1Vk4y1m7zd的视频属性抓取结束
# 开始BV号为1554y1z7kY视频属性的抓取
# BV号为1554y1z7kY的视频属性抓取结束
# 开始BV号为1Nz4y1X7iu视频属性的抓取
# BV号为1Nz4y1X7iu的视频属性抓取结束
# 开始BV号为1Sp4y1U7zc视频属性的抓取
# BV号为1Sp4y1U7zc的视频属性抓取结束
# 开始BV号为1Ya4y1a7ih视频属性的抓取
# BV号为1Ya4y1a7ih的视频属性抓取结束
# 开始BV号为1P54y1z7kK视频属性的抓取
# BV号为1P54y1z7kK的视频属性抓取结束
# 开始BV号为1Wz411v7TB视频属性的抓取
# BV号为1Wz411v7TB的视频属性抓取结束
# 开始BV号为1mk4y1q7oB视频属性的抓取
# BV号为1mk4y1q7oB的视频属性抓取结束
# 开始BV号为1St4y19777视频属性的抓取
# BV号为1St4y19777的视频属性抓取结束
# 开始BV号为1uD4y1D7vR视频属性的抓取
# BV号为1uD4y1D7vR的视频属性抓取结束
# 开始BV号为1854y1q7yc视频属性的抓取
# BV号为1854y1q7yc的视频属性抓取结束
# 开始BV号为1454y1z7Ta视频属性的抓取
# BV号为1454y1z7Ta的视频属性抓取结束
# 开始BV号为1CV41167ig视频属性的抓取
# BV号为1CV41167ig的视频属性抓取结束
# 开始BV号为1oV411B7eD视频属性的抓取
# BV号为1oV411B7eD的视频属性抓取结束
# 开始BV号为1vT4y1776v视频属性的抓取
# BV号为1vT4y1776v的视频属性抓取结束
# 开始BV号为1ap4y1S7S7视频属性的抓取
# BV号为1ap4y1S7S7的视频属性抓取结束
# 开始BV号为1eA411i7G6视频属性的抓取
# BV号为1eA411i7G6的视频属性抓取结束
# 开始BV号为1pK4y1x7DU视频属性的抓取
# BV号为1pK4y1x7DU的视频属性抓取结束
# 开始BV号为1uV411r73Q视频属性的抓取
# BV号为1uV411r73Q的视频属性抓取结束
# 开始BV号为16K4y147Bg视频属性的抓取
# BV号为16K4y147Bg的视频属性抓取结束
# 开始BV号为1EZ4y1u7EG视频属性的抓取
# BV号为1EZ4y1u7EG的视频属性抓取结束
# 开始BV号为1m64y1F7ww视频属性的抓取
# BV号为1m64y1F7ww的视频属性抓取结束
# 开始BV号为1pa4y1a7D5视频属性的抓取
# BV号为1pa4y1a7D5的视频属性抓取结束
# 开始BV号为1st4y1X7jz视频属性的抓取
# BV号为1st4y1X7jz的视频属性抓取结束
# 开始BV号为1yD4y1m7a3视频属性的抓取
# BV号为1yD4y1m7a3的视频属性抓取结束
# 开始BV号为1ii4y137jH视频属性的抓取
# BV号为1ii4y137jH的视频属性抓取结束
# 开始BV号为15f4y1R73a视频属性的抓取
# BV号为15f4y1R73a的视频属性抓取结束
# 开始BV号为15p4y1q77D视频属性的抓取
# BV号为15p4y1q77D的视频属性抓取结束
# 开始BV号为1ya4y1h7jo视频属性的抓取
# BV号为1ya4y1h7jo的视频属性抓取结束
# 开始BV号为1KK4y1v7dX视频属性的抓取
# BV号为1KK4y1v7dX的视频属性抓取结束
# 开始BV号为125411h7U4视频属性的抓取
# BV号为125411h7U4的视频属性抓取结束
# 开始BV号为11z4y1D7TP视频属性的抓取
# BV号为11z4y1D7TP的视频属性抓取结束
# 开始BV号为1ft4y1Q7sM视频属性的抓取
# BV号为1ft4y1Q7sM的视频属性抓取结束
# 开始BV号为1HZ4y1u7mB视频属性的抓取
# BV号为1HZ4y1u7mB的视频属性抓取结束
# 开始BV号为1jT4y177YV视频属性的抓取
# BV号为1jT4y177YV的视频属性抓取结束
# 开始BV号为1Zh411R7aZ视频属性的抓取
# BV号为1Zh411R7aZ的视频属性抓取结束
# 开始BV号为1LV411r7J3视频属性的抓取
# BV号为1LV411r7J3的视频属性抓取结束
# 开始BV号为1Yk4y1m7f4视频属性的抓取
# BV号为1Yk4y1m7f4的视频属性抓取结束
# 开始BV号为1Pk4y1672Z视频属性的抓取
# BV号为1Pk4y1672Z的视频属性抓取结束
# 开始BV号为1Ft4y1D7Xu视频属性的抓取
# BV号为1Ft4y1D7Xu的视频属性抓取结束
# 开始BV号为1u5411a7Xo视频属性的抓取
# BV号为1u5411a7Xo的视频属性抓取结束
# 开始BV号为1154y1q7AX视频属性的抓取
# BV号为1154y1q7AX的视频属性抓取结束
# 开始BV号为135411Y7C7视频属性的抓取
# BV号为135411Y7C7的视频属性抓取结束
# 开始BV号为1rD4y1S7ab视频属性的抓取
# BV号为1rD4y1S7ab的视频属性抓取结束
# 开始BV号为1xp4y1S7FD视频属性的抓取
# BV号为1xp4y1S7FD的视频属性抓取结束
# 开始BV号为1YK4y14733视频属性的抓取
# BV号为1YK4y14733的视频属性抓取结束
# 开始BV号为1jz4y1Q76V视频属性的抓取
# BV号为1jz4y1Q76V的视频属性抓取结束
# 开始BV号为1ck4y1m7Mc视频属性的抓取
# BV号为1ck4y1m7Mc的视频属性抓取结束
# 开始BV号为15p4y1q7gN视频属性的抓取
# BV号为15p4y1q7gN的视频属性抓取结束
# 开始BV号为16A411e7Dd视频属性的抓取
# BV号为16A411e7Dd的视频属性抓取结束
# 开始BV号为1Pk4y1m71k视频属性的抓取
# BV号为1Pk4y1m71k的视频属性抓取结束
# 开始BV号为1ef4y1R7ou视频属性的抓取
# BV号为1ef4y1R7ou的视频属性抓取结束
# 开始BV号为1oK411n7hx视频属性的抓取
# BV号为1oK411n7hx的视频属性抓取结束
# 开始BV号为1zC4y187Br视频属性的抓取
# BV号为1zC4y187Br的视频属性抓取结束
# 开始BV号为1Vp4y1q7Nk视频属性的抓取
# BV号为1Vp4y1q7Nk的视频属性抓取结束
# 开始BV号为1gD4y1S7AL视频属性的抓取
# BV号为1gD4y1S7AL的视频属性抓取结束
# 开始BV号为1di4y1g7Tk视频属性的抓取
# BV号为1di4y1g7Tk的视频属性抓取结束
# 开始BV号为1y5411h7xe视频属性的抓取
# BV号为1y5411h7xe的视频属性抓取结束
# 开始BV号为1BZ4y1T7av视频属性的抓取
# BV号为1BZ4y1T7av的视频属性抓取结束
# 开始BV号为1zC4y187Kp视频属性的抓取
# BV号为1zC4y187Kp的视频属性抓取结束
# 开始BV号为1Ua4y1h7Wz视频属性的抓取
# BV号为1Ua4y1h7Wz的视频属性抓取结束
# 开始BV号为1EZ4y1u7PN视频属性的抓取
# BV号为1EZ4y1u7PN的视频属性抓取结束
# 开始BV号为1Lg4y1i7n3视频属性的抓取
# BV号为1Lg4y1i7n3的视频属性抓取结束
# 开始BV号为1A5411a7Vg视频属性的抓取
# BV号为1A5411a7Vg的视频属性抓取结束
# 开始BV号为1g54y1q7FM视频属性的抓取
# BV号为1g54y1q7FM的视频属性抓取结束
# 开始BV号为1RK4y1s7pe视频属性的抓取
# BV号为1RK4y1s7pe的视频属性抓取结束
# 开始BV号为1Ck4y1B7Ch视频属性的抓取
# BV号为1Ck4y1B7Ch的视频属性抓取结束
# 开始BV号为1XK4y147Fh视频属性的抓取
# BV号为1XK4y147Fh的视频属性抓取结束
# 开始BV号为1wV41167j3视频属性的抓取
# BV号为1wV41167j3的视频属性抓取结束
# 开始BV号为1zK411H77x视频属性的抓取
# BV号为1zK411H77x的视频属性抓取结束
# 开始BV号为1gV411r7LS视频属性的抓取
# BV号为1gV411r7LS的视频属性抓取结束
# 开始BV号为1zK411J788视频属性的抓取
# BV号为1zK411J788的视频属性抓取结束
# 开始BV号为1X54y1q7Qe视频属性的抓取
# BV号为1X54y1q7Qe的视频属性抓取结束
# 开始BV号为1sK411J7q2视频属性的抓取
# BV号为1sK411J7q2的视频属性抓取结束
# 开始BV号为1eV411k7eg视频属性的抓取
# BV号为1eV411k7eg的视频属性抓取结束
# 开始BV号为1Pf4y1R7hZ视频属性的抓取
# BV号为1Pf4y1R7hZ的视频属性抓取结束
# 开始BV号为1Tv411q7yL视频属性的抓取
# BV号为1Tv411q7yL的视频属性抓取结束
# 开始BV号为1Yh411o7Sg视频属性的抓取
# BV号为1Yh411o7Sg的视频属性抓取结束
# 开始BV号为1RK411J7f4视频属性的抓取
# BV号为1RK411J7f4的视频属性抓取结束
# 开始BV号为1q54y1U7eD视频属性的抓取
# BV号为1q54y1U7eD的视频属性抓取结束
# 开始BV号为1dK4y1Y71Q视频属性的抓取
# BV号为1dK4y1Y71Q的视频属性抓取结束
# 开始BV号为1YD4y127Vq视频属性的抓取
# BV号为1YD4y127Vq的视频属性抓取结束
# 开始BV号为1MV411z7Vh视频属性的抓取
# BV号为1MV411z7Vh的视频属性抓取结束
# 开始BV号为11f4y197eS视频属性的抓取
# BV号为11f4y197eS的视频属性抓取结束
# 开始BV号为1G54y1U7H4视频属性的抓取
# BV号为1G54y1U7H4的视频属性抓取结束
# 开始BV号为1QD4y1U7FD视频属性的抓取
# BV号为1QD4y1U7FD的视频属性抓取结束
# 开始BV号为1sz4y1Q7p9视频属性的抓取
# BV号为1sz4y1Q7p9的视频属性抓取结束
# 开始BV号为1854y1v7Jr视频属性的抓取
# BV号为1854y1v7Jr的视频属性抓取结束
# 开始BV号为1Xk4y1m7Q3视频属性的抓取
# BV号为1Xk4y1m7Q3的视频属性抓取结束
# 开始BV号为1yv411q7xq视频属性的抓取
# BV号为1yv411q7xq的视频属性抓取结束
# 开始BV号为1KT4y177Bj视频属性的抓取
# BV号为1KT4y177Bj的视频属性抓取结束
# 开始BV号为1uA411e7qH视频属性的抓取
# BV号为1uA411e7qH的视频属性抓取结束
# 开始BV号为1tZ4y1K7vo视频属性的抓取
# BV号为1tZ4y1K7vo的视频属性抓取结束
# 开始BV号为13t4y1S7Rp视频属性的抓取
# BV号为13t4y1S7Rp的视频属性抓取结束
# 开始BV号为1EK4y1e7Gh视频属性的抓取
# BV号为1EK4y1e7Gh的视频属性抓取结束
# 开始BV号为1w54y1D7KP视频属性的抓取
# BV号为1w54y1D7KP的视频属性抓取结束
# 开始BV号为1uk4y1y76W视频属性的抓取
# BV号为1uk4y1y76W的视频属性抓取结束
# 开始BV号为1vk4y117V4视频属性的抓取
# BV号为1vk4y117V4的视频属性抓取结束
# 开始BV号为1Xi4y1M7PM视频属性的抓取
# BV号为1Xi4y1M7PM的视频属性抓取结束
# 开始BV号为19V411z7SD视频属性的抓取
# BV号为19V411z7SD的视频属性抓取结束
# 开始BV号为1k54y1e78n视频属性的抓取
# BV号为1k54y1e78n的视频属性抓取结束
# 开始BV号为1K64y1c7qk视频属性的抓取
# BV号为1K64y1c7qk的视频属性抓取结束
# 开始BV号为1Ya4y1J7sz视频属性的抓取
# BV号为1Ya4y1J7sz的视频属性抓取结束
# 开始BV号为1Ef4y197wH视频属性的抓取
# 开始BV号为1Ef4y197wH视频属性的抓取
# BV号为1Ef4y197wH的视频属性抓取结束
# 开始BV号为1KA411e7oq视频属性的抓取
# BV号为1KA411e7oq的视频属性抓取结束
# 开始BV号为1K5411h77V视频属性的抓取
# BV号为1K5411h77V的视频属性抓取结束
# 开始BV号为1kT4y1w7cA视频属性的抓取
# BV号为1kT4y1w7cA的视频属性抓取结束
# 开始BV号为1vk4y127BK视频属性的抓取
# BV号为1vk4y127BK的视频属性抓取结束
# 开始BV号为11A411Y71X视频属性的抓取
# BV号为11A411Y71X的视频属性抓取结束
# 开始BV号为1Q54y127m6视频属性的抓取
# BV号为1Q54y127m6的视频属性抓取结束
# 开始BV号为1z64y1c7ni视频属性的抓取
# BV号为1z64y1c7ni的视频属性抓取结束
# 开始BV号为1b54y127ha视频属性的抓取
# BV号为1b54y127ha的视频属性抓取结束
# 开始BV号为1Np4y1e7ox视频属性的抓取
# BV号为1Np4y1e7ox的视频属性抓取结束
# 开始BV号为1SA411J7HE视频属性的抓取
# BV号为1SA411J7HE的视频属性抓取结束
# 开始BV号为1v541187De视频属性的抓取
# BV号为1v541187De的视频属性抓取结束
# 开始BV号为1Ma4y1E79e视频属性的抓取
# BV号为1Ma4y1E79e的视频属性抓取结束
# 开始BV号为1CK411N7Dg视频属性的抓取
# BV号为1CK411N7Dg的视频属性抓取结束
# 开始BV号为16f4y197WJ视频属性的抓取
# BV号为16f4y197WJ的视频属性抓取结束
# 开始BV号为1PC4y1b7LS视频属性的抓取
# BV号为1PC4y1b7LS的视频属性抓取结束
# 开始BV号为17T4y1j7h1视频属性的抓取
# BV号为17T4y1j7h1的视频属性抓取结束
# 开始BV号为1dD4y1U7zr视频属性的抓取
# BV号为1dD4y1U7zr的视频属性抓取结束
# 开始BV号为1q5411a73B视频属性的抓取
# BV号为1q5411a73B的视频属性抓取结束
# 开始BV号为18z4y1f7WH视频属性的抓取
# BV号为18z4y1f7WH的视频属性抓取结束
# 开始BV号为1564y1F7s4视频属性的抓取
# BV号为1564y1F7s4的视频属性抓取结束
# 开始BV号为19C4y1b7BP视频属性的抓取
# BV号为19C4y1b7BP的视频属性抓取结束
# 开始BV号为1sD4y127Q4视频属性的抓取
# BV号为1sD4y127Q4的视频属性抓取结束
# 开始BV号为1ot4y1U7f2视频属性的抓取
# BV号为1ot4y1U7f2的视频属性抓取结束
# 开始BV号为1YT4y1w7K8视频属性的抓取
# BV号为1YT4y1w7K8的视频属性抓取结束
# 开始BV号为1U54y1U7pU视频属性的抓取
# BV号为1U54y1U7pU的视频属性抓取结束
# 开始BV号为1Bk4y117CQ视频属性的抓取
# BV号为1Bk4y117CQ的视频属性抓取结束
# 开始BV号为1VT4y1L7Pe视频属性的抓取
# BV号为1VT4y1L7Pe的视频属性抓取结束
# 开始BV号为1jZ4y1K7fq视频属性的抓取
# BV号为1jZ4y1K7fq的视频属性抓取结束
# 开始BV号为16p4y1v7Qi视频属性的抓取
# BV号为16p4y1v7Qi的视频属性抓取结束
# 开始BV号为1Ta4y1J7da视频属性的抓取
# BV号为1Ta4y1J7da的视频属性抓取结束
# 开始BV号为1oK4y1e7dy视频属性的抓取
# BV号为1oK4y1e7dy的视频属性抓取结束
# 开始BV号为1wV411z7mf视频属性的抓取
# BV号为1wV411z7mf的视频属性抓取结束
# 开始BV号为1gC4y1t7EY视频属性的抓取
# BV号为1gC4y1t7EY的视频属性抓取结束
# 开始BV号为1VV411S7qC视频属性的抓取
# BV号为1VV411S7qC的视频属性抓取结束
# 开始BV号为1Lk4y127hr视频属性的抓取
# BV号为1Lk4y127hr的视频属性抓取结束
# 开始BV号为1qT4y1L75W视频属性的抓取
# BV号为1qT4y1L75W的视频属性抓取结束
# 开始BV号为1ZT4y157nN视频属性的抓取
# BV号为1ZT4y157nN的视频属性抓取结束
# 开始BV号为1kK411T7mK视频属性的抓取
# BV号为1kK411T7mK的视频属性抓取结束
# 开始BV号为1C54y1i7pF视频属性的抓取
# BV号为1C54y1i7pF的视频属性抓取结束
# 开始BV号为1Tk4y1U757视频属性的抓取
# BV号为1Tk4y1U757的视频属性抓取结束
# 开始BV号为1CZ4y1M78R视频属性的抓取
# BV号为1CZ4y1M78R的视频属性抓取结束
# 开始BV号为1ha4y177pY视频属性的抓取
# BV号为1ha4y177pY的视频属性抓取结束
# 开始BV号为1WV411U788视频属性的抓取
# BV号为1WV411U788的视频属性抓取结束
# 开始BV号为1Kk4y127fU视频属性的抓取
# BV号为1Kk4y127fU的视频属性抓取结束
# 开始BV号为14p4y1v7vm视频属性的抓取
# BV号为14p4y1v7vm的视频属性抓取结束
# 开始BV号为1W5411a7my视频属性的抓取
# BV号为1W5411a7my的视频属性抓取结束
# 开始BV号为1Kf4y197SC视频属性的抓取
# BV号为1Kf4y197SC的视频属性抓取结束
# 开始BV号为1av411i7xa视频属性的抓取
# BV号为1av411i7xa的视频属性抓取结束
# 开始BV号为1wK411M78r视频属性的抓取
# BV号为1wK411M78r的视频属性抓取结束
# 开始BV号为1ji4y1g7j7视频属性的抓取
# BV号为1ji4y1g7j7的视频属性抓取结束
# 开始BV号为1BK4y1Y74S视频属性的抓取
# BV号为1BK4y1Y74S的视频属性抓取结束
# 开始BV号为1HV411U7xZ视频属性的抓取
# BV号为1HV411U7xZ的视频属性抓取结束
# 开始BV号为1oA411J7S9视频属性的抓取
# BV号为1oA411J7S9的视频属性抓取结束
# 开始BV号为1p64y1c7pQ视频属性的抓取
# BV号为1p64y1c7pQ的视频属性抓取结束
# 开始BV号为1FV411S7ke视频属性的抓取
# BV号为1FV411S7ke的视频属性抓取结束
# 开始BV号为1gV411U7Vj视频属性的抓取
# BV号为1gV411U7Vj的视频属性抓取结束
# 开始BV号为1cK4y1v7N8视频属性的抓取
# BV号为1cK4y1v7N8的视频属性抓取结束
# 开始BV号为1ta4y177fe视频属性的抓取
# BV号为1ta4y177fe的视频属性抓取结束
# 开始BV号为11z4y1f7Bs视频属性的抓取
# BV号为11z4y1f7Bs的视频属性抓取结束
# 开始BV号为1xC4y18767视频属性的抓取
# BV号为1xC4y18767的视频属性抓取结束
# 开始BV号为1q54y1U71Z视频属性的抓取
# BV号为1q54y1U71Z的视频属性抓取结束
# 开始BV号为1zt4y1X7G1视频属性的抓取
# BV号为1zt4y1X7G1的视频属性抓取结束
# 开始BV号为1zk4y117cA视频属性的抓取
# BV号为1zk4y117cA的视频属性抓取结束
# 开始BV号为1CZ4y1T7wM视频属性的抓取
# BV号为1CZ4y1T7wM的视频属性抓取结束
# 开始BV号为1sv41117sR视频属性的抓取
# BV号为1sv41117sR的视频属性抓取结束
# 开始BV号为1St4y1U7zT视频属性的抓取
# BV号为1St4y1U7zT的视频属性抓取结束
# 开始BV号为1TK411n7HZ视频属性的抓取
# BV号为1TK411n7HZ的视频属性抓取结束
# 开始BV号为1UK411T7Hh视频属性的抓取
# BV号为1UK411T7Hh的视频属性抓取结束
# 开始BV号为1HK411T7Q8视频属性的抓取
# BV号为1HK411T7Q8的视频属性抓取结束
# 开始BV号为1mk4y1m7nr视频属性的抓取
# BV号为1mk4y1m7nr的视频属性抓取结束
# 开始BV号为1tz4y1f7Fw视频属性的抓取
# BV号为1tz4y1f7Fw的视频属性抓取结束
# 开始BV号为1Ft4y1Q7nb视频属性的抓取
# BV号为1Ft4y1Q7nb的视频属性抓取结束
# 开始BV号为1Lp4y1q74K视频属性的抓取
# BV号为1Lp4y1q74K的视频属性抓取结束
# 开始BV号为1F64y1c7S8视频属性的抓取
# BV号为1F64y1c7S8的视频属性抓取结束
# 开始BV号为1BA411J7FP视频属性的抓取
# BV号为1BA411J7FP的视频属性抓取结束
# 开始BV号为1Ch411R7vo视频属性的抓取
# BV号为1Ch411R7vo的视频属性抓取结束
# 开始BV号为1bT4y1w7vv视频属性的抓取
# BV号为1bT4y1w7vv的视频属性抓取结束
# 开始BV号为1GK411K7Ke视频属性的抓取
# BV号为1GK411K7Ke的视频属性抓取结束
# 开始BV号为1MK4y1Y74X视频属性的抓取
# BV号为1MK4y1Y74X的视频属性抓取结束
# 开始BV号为1Ti4y1u7AV视频属性的抓取
# BV号为1Ti4y1u7AV的视频属性抓取结束
# 开始BV号为15i4y1E7Ve视频属性的抓取
# BV号为15i4y1E7Ve的视频属性抓取结束
# 开始BV号为1H54y1y7Uu视频属性的抓取
# BV号为1H54y1y7Uu的视频属性抓取结束
# 开始BV号为1Ha4y1j715视频属性的抓取
# BV号为1Ha4y1j715的视频属性抓取结束
# 开始BV号为1Ba4y157e4视频属性的抓取
# BV号为1Ba4y157e4的视频属性抓取结束
# 开始BV号为1pv411C7GY视频属性的抓取
# BV号为1pv411C7GY的视频属性抓取结束
# 开始BV号为1Ka4y1j7Z3视频属性的抓取
# BV号为1Ka4y1j7Z3的视频属性抓取结束
# 开始BV号为1Ck4y1y72t视频属性的抓取
# BV号为1Ck4y1y72t的视频属性抓取结束
# 开始BV号为1G54y117fo视频属性的抓取
# BV号为1G54y117fo的视频属性抓取结束
# 开始BV号为1fa4y1j7gZ视频属性的抓取
# BV号为1fa4y1j7gZ的视频属性抓取结束
# 开始BV号为16Z4y1N7Qo视频属性的抓取
# BV号为16Z4y1N7Qo的视频属性抓取结束
# 开始BV号为1T54y1174c视频属性的抓取
# BV号为1T54y1174c的视频属性抓取结束
# 开始BV号为1iy4y1y7FX视频属性的抓取
# BV号为1iy4y1y7FX的视频属性抓取结束
# 开始BV号为15k4y1C7c8视频属性的抓取
# BV号为15k4y1C7c8的视频属性抓取结束
# 开始BV号为1zV411m7nZ视频属性的抓取
# BV号为1zV411m7nZ的视频属性抓取结束
# 开始BV号为1TZ4y1N7km视频属性的抓取
# BV号为1TZ4y1N7km的视频属性抓取结束
# 开始BV号为14A411E7dB视频属性的抓取
# BV号为14A411E7dB的视频属性抓取结束
# 开始BV号为1954y1y7xK视频属性的抓取
# BV号为1954y1y7xK的视频属性抓取结束
# 开始BV号为12T4y1A7ga视频属性的抓取
# BV号为12T4y1A7ga的视频属性抓取结束
# 开始BV号为1Sk4y1k7qH视频属性的抓取
# BV号为1Sk4y1k7qH的视频属性抓取结束
# 开始BV号为1oD4y1d7Bq视频属性的抓取
# BV号为1oD4y1d7Bq的视频属性抓取结束
# 开始BV号为1yA411E7J5视频属性的抓取
# BV号为1yA411E7J5的视频属性抓取结束
# 开始BV号为1hv411C7Ry视频属性的抓取
# BV号为1hv411C7Ry的视频属性抓取结束
# 开始BV号为1Sv411C7VK视频属性的抓取
# BV号为1Sv411C7VK的视频属性抓取结束
# 开始BV号为1of4y1S7uT视频属性的抓取
# BV号为1of4y1S7uT的视频属性抓取结束
# 开始BV号为1Mi4y1u7Uh视频属性的抓取
# BV号为1Mi4y1u7Uh的视频属性抓取结束
# 开始BV号为1cZ4y1K7ir视频属性的抓取
# BV号为1cZ4y1K7ir的视频属性抓取结束
# 开始BV号为1ci4y1E7gU视频属性的抓取
# BV号为1ci4y1E7gU的视频属性抓取结束
# 开始BV号为1u64y1F7to视频属性的抓取
# BV号为1u64y1F7to的视频属性抓取结束
# 开始BV号为1kk4y1y7fq视频属性的抓取
# BV号为1kk4y1y7fq的视频属性抓取结束
# 开始BV号为1a64y1F77L视频属性的抓取
# BV号为1a64y1F77L的视频属性抓取结束
# 开始BV号为1S54y1C76Z视频属性的抓取
# BV号为1S54y1C76Z的视频属性抓取结束
# 开始BV号为1VZ4y1T7Sh视频属性的抓取
# BV号为1VZ4y1T7Sh的视频属性抓取结束
# 开始BV号为1gT4y1A7Mf视频属性的抓取
# BV号为1gT4y1A7Mf的视频属性抓取结束
# 开始BV号为1iK411K7gu视频属性的抓取
# BV号为1iK411K7gu的视频属性抓取结束
# 开始BV号为1ey4y1k7wH视频属性的抓取
# BV号为1ey4y1k7wH的视频属性抓取结束
# 开始BV号为14p4y1e7dq视频属性的抓取
# BV号为14p4y1e7dq的视频属性抓取结束
# 开始BV号为1Z54y117a2视频属性的抓取
# BV号为1Z54y117a2的视频属性抓取结束
# 开始BV号为1Np4y1e71z视频属性的抓取
# BV号为1Np4y1e71z的视频属性抓取结束
# 开始BV号为1EV411S7ws视频属性的抓取
# BV号为1EV411S7ws的视频属性抓取结束
# 开始BV号为1X54y1y7zZ视频属性的抓取
# BV号为1X54y1y7zZ的视频属性抓取结束
# 开始BV号为1Vf4y1X7gq视频属性的抓取
# BV号为1Vf4y1X7gq的视频属性抓取结束
# 开始BV号为1gf4y1D75W视频属性的抓取
# BV号为1gf4y1D75W的视频属性抓取结束
# 开始BV号为1zT4y1A7T8视频属性的抓取
# BV号为1zT4y1A7T8的视频属性抓取结束
# 开始BV号为1g54y117mE视频属性的抓取
# BV号为1g54y117mE的视频属性抓取结束
# 开始BV号为1zK411K786视频属性的抓取
# BV号为1zK411K786的视频属性抓取结束
# 开始BV号为1qp4y1e7Rg视频属性的抓取
# BV号为1qp4y1e7Rg的视频属性抓取结束
# 开始BV号为1dZ4y1N7TC视频属性的抓取
# BV号为1dZ4y1N7TC的视频属性抓取结束
# 开始BV号为1Mt4y1q7Mf视频属性的抓取
# BV号为1Mt4y1q7Mf的视频属性抓取结束
# 开始BV号为1aA411E785视频属性的抓取
# BV号为1aA411E785的视频属性抓取结束
# 开始BV号为1SZ4y1P7Bg视频属性的抓取
# BV号为1SZ4y1P7Bg的视频属性抓取结束
# 开始BV号为1254y1C77L视频属性的抓取
# BV号为1254y1C77L的视频属性抓取结束
# 开始BV号为1UA411n7Kg视频属性的抓取
# BV号为1UA411n7Kg的视频属性抓取结束
# 开始BV号为1e54y1C7SR视频属性的抓取
# BV号为1e54y1C7SR的视频属性抓取结束
# 开始BV号为1oV41117Fb视频属性的抓取
# BV号为1oV41117Fb的视频属性抓取结束
# 开始BV号为1gi4y1u7pc视频属性的抓取
# BV号为1gi4y1u7pc的视频属性抓取结束
# 开始BV号为12A411E7g6视频属性的抓取
# BV号为12A411E7g6的视频属性抓取结束
# 开始BV号为1Hf4y1D7Se视频属性的抓取
# BV号为1Hf4y1D7Se的视频属性抓取结束
# 开始BV号为1tK411P7qu视频属性的抓取
# BV号为1tK411P7qu的视频属性抓取结束
# 开始BV号为1n541187Pn视频属性的抓取
# BV号为1n541187Pn的视频属性抓取结束
# 开始BV号为15t4y1q7St视频属性的抓取
# BV号为15t4y1q7St的视频属性抓取结束
# 开始BV号为1PK411K7n7视频属性的抓取
# BV号为1PK411K7n7的视频属性抓取结束
# 开始BV号为13k4y117wS视频属性的抓取
# BV号为13k4y117wS的视频属性抓取结束
# 开始BV号为1qA411E7Qq视频属性的抓取
# BV号为1qA411E7Qq的视频属性抓取结束
# 开始BV号为1rh411R75w视频属性的抓取
# BV号为1rh411R75w的视频属性抓取结束
# 开始BV号为1UK4y1a76M视频属性的抓取
# BV号为1UK4y1a76M的视频属性抓取结束
# 开始BV号为1yk4y1y7mr视频属性的抓取
# 开始BV号为1yk4y1y7mr视频属性的抓取
# BV号为1yk4y1y7mr的视频属性抓取结束
# 开始BV号为1xA411J7Tz视频属性的抓取
# BV号为1xA411J7Tz的视频属性抓取结束
# 开始BV号为12i4y177Hu视频属性的抓取
# BV号为12i4y177Hu的视频属性抓取结束
# 开始BV号为1Bz4y1f7Uq视频属性的抓取
# BV号为1Bz4y1f7Uq的视频属性抓取结束
# 开始BV号为1s54y1y752视频属性的抓取
# BV号为1s54y1y752的视频属性抓取结束
# 开始BV号为1hA411E7Hx视频属性的抓取
# BV号为1hA411E7Hx的视频属性抓取结束
# 开始BV号为1Gp4y1e73D视频属性的抓取
# BV号为1Gp4y1e73D的视频属性抓取结束
# 开始BV号为1nz4y1Z7iS视频属性的抓取
# BV号为1nz4y1Z7iS的视频属性抓取结束
# 开始BV号为1vt4y1S7sk视频属性的抓取
# BV号为1vt4y1S7sk的视频属性抓取结束
# 开始BV号为12D4y1R7RV视频属性的抓取
# BV号为12D4y1R7RV的视频属性抓取结束
# 开始BV号为1SK411K7T5视频属性的抓取
# BV号为1SK411K7T5的视频属性抓取结束
# 开始BV号为1wD4y1o7mx视频属性的抓取
# BV号为1wD4y1o7mx的视频属性抓取结束
# 开始BV号为1pp4y1a7t7视频属性的抓取
# BV号为1pp4y1a7t7的视频属性抓取结束
# 开始BV号为1fv411r72x视频属性的抓取
# BV号为1fv411r72x的视频属性抓取结束
# 开始BV号为1J54y1y7Am视频属性的抓取
# BV号为1J54y1y7Am的视频属性抓取结束
# 开始BV号为1jT4y1A7Q8视频属性的抓取
# BV号为1jT4y1A7Q8的视频属性抓取结束
# 开始BV号为12A411n7Qk视频属性的抓取
# BV号为12A411n7Qk的视频属性抓取结束
# 开始BV号为1Xv41117qW视频属性的抓取
# BV号为1Xv41117qW的视频属性抓取结束
# 开始BV号为1fa4y1L7P9视频属性的抓取
# BV号为1fa4y1L7P9的视频属性抓取结束
# 开始BV号为1Ba4y1j79P视频属性的抓取
# BV号为1Ba4y1j79P的视频属性抓取结束
# 开始BV号为1PA411H7zo视频属性的抓取
# BV号为1PA411H7zo的视频属性抓取结束
# 开始BV号为1by4y1y7YA视频属性的抓取
# BV号为1by4y1y7YA的视频属性抓取结束
# 开始BV号为1CT4y1L7x9视频属性的抓取
# BV号为1CT4y1L7x9的视频属性抓取结束
# 开始BV号为1XV41127Yw视频属性的抓取
# BV号为1XV41127Yw的视频属性抓取结束
# 开始BV号为1vh411R79m视频属性的抓取
# BV号为1vh411R79m的视频属性抓取结束
# 开始BV号为1fi4y1M7XJ视频属性的抓取
# BV号为1fi4y1M7XJ的视频属性抓取结束
# 开始BV号为1av411179L视频属性的抓取
# BV号为1av411179L的视频属性抓取结束
# 开始BV号为1WA41177jp视频属性的抓取
# BV号为1WA41177jp的视频属性抓取结束
# 开始BV号为1sK4y1a7jt视频属性的抓取
# BV号为1sK4y1a7jt的视频属性抓取结束
# 开始BV号为1DK4y187xe视频属性的抓取
# BV号为1DK4y187xe的视频属性抓取结束
# 开始BV号为1Xa4y157wX视频属性的抓取
# BV号为1Xa4y157wX的视频属性抓取结束
# 开始BV号为1ty4y1C7k7视频属性的抓取
# BV号为1ty4y1C7k7的视频属性抓取结束
# 开始BV号为19i4y1j7Nm视频属性的抓取
# BV号为19i4y1j7Nm的视频属性抓取结束
# 开始BV号为1uz4y1f73M视频属性的抓取
# BV号为1uz4y1f73M的视频属性抓取结束
# 开始BV号为1ra4y1L7ei视频属性的抓取
# BV号为1ra4y1L7ei的视频属性抓取结束
# 开始BV号为1pa4y1s7SW视频属性的抓取
# BV号为1pa4y1s7SW的视频属性抓取结束
# 开始BV号为1ii4y177xh视频属性的抓取
# BV号为1ii4y177xh的视频属性抓取结束
# 开始BV号为1PD4y197e6视频属性的抓取
# BV号为1PD4y197e6的视频属性抓取结束
# 开始BV号为1My4y187Lt视频属性的抓取
# BV号为1My4y187Lt的视频属性抓取结束
# 开始BV号为1pA41177Ya视频属性的抓取
# BV号为1pA41177Ya的视频属性抓取结束
# 开始BV号为1Dv411k73p视频属性的抓取
# BV号为1Dv411k73p的视频属性抓取结束
# 开始BV号为1RV41117p2视频属性的抓取
# BV号为1RV41117p2的视频属性抓取结束
# 开始BV号为1kz4y1o7x8视频属性的抓取
# BV号为1kz4y1o7x8的视频属性抓取结束
# 开始BV号为1ff4y1q7AX视频属性的抓取
# BV号为1ff4y1q7AX的视频属性抓取结束
# 开始BV号为1ji4y177kx视频属性的抓取
# BV号为1ji4y177kx的视频属性抓取结束
# 开始BV号为1dy4y1b7Wk视频属性的抓取
# BV号为1dy4y1b7Wk的视频属性抓取结束
# 开始BV号为1yA411J7pg视频属性的抓取
# BV号为1yA411J7pg的视频属性抓取结束
# 开始BV号为1SV41117h2视频属性的抓取
# BV号为1SV41117h2的视频属性抓取结束
# 开始BV号为1Ff4y1z7Ac视频属性的抓取
# BV号为1Ff4y1z7Ac的视频属性抓取结束
# 开始BV号为1Va411A7ws视频属性的抓取
# BV号为1Va411A7ws的视频属性抓取结束
# 开始BV号为1ni4y1E7Ug视频属性的抓取
# BV号为1ni4y1E7Ug的视频属性抓取结束
# 开始BV号为1Jt4y1v7PG视频属性的抓取
# BV号为1Jt4y1v7PG的视频属性抓取结束
# 开始BV号为1i54y1k7U4视频属性的抓取
# BV号为1i54y1k7U4的视频属性抓取结束
# 开始BV号为1Q54y167MS视频属性的抓取
# BV号为1Q54y167MS的视频属性抓取结束
# 开始BV号为14T4y1F7N3视频属性的抓取
# BV号为14T4y1F7N3的视频属性抓取结束
# 开始BV号为1W54y1R7Ui视频属性的抓取
# BV号为1W54y1R7Ui的视频属性抓取结束
# 开始BV号为1ta4y1L78G视频属性的抓取
# BV号为1ta4y1L78G的视频属性抓取结束
# 开始BV号为18T4y1c7k1视频属性的抓取
# BV号为18T4y1c7k1的视频属性抓取结束
# 开始BV号为12i4y1E7Nm视频属性的抓取
# BV号为12i4y1E7Nm的视频属性抓取结束
# 开始BV号为16i4y1E7nz视频属性的抓取
# BV号为16i4y1E7nz的视频属性抓取结束
# 开始BV号为1ZK411w7YY视频属性的抓取
# BV号为1ZK411w7YY的视频属性抓取结束
# 开始BV号为1iK411N7z4视频属性的抓取
# BV号为1iK411N7z4的视频属性抓取结束
# 开始BV号为1R5411j7p5视频属性的抓取
# BV号为1R5411j7p5的视频属性抓取结束
# 开始BV号为16D4y1d7Ma视频属性的抓取
# BV号为16D4y1d7Ma的视频属性抓取结束
# 开始BV号为1eA411j7Mv视频属性的抓取
# BV号为1eA411j7Mv的视频属性抓取结束
# 开始BV号为1PD4y1d7ZY视频属性的抓取
# BV号为1PD4y1d7ZY的视频属性抓取结束
# 开始BV号为1Li4y177hJ视频属性的抓取
# BV号为1Li4y177hJ的视频属性抓取结束
# 开始BV号为1Fh41197Yp视频属性的抓取
# BV号为1Fh41197Yp的视频属性抓取结束
# 开始BV号为1HA41177Y3视频属性的抓取
# BV号为1HA41177Y3的视频属性抓取结束
# 开始BV号为1ry4y1r7yN视频属性的抓取
# BV号为1ry4y1r7yN的视频属性抓取结束
# 开始BV号为1W5411L7q2视频属性的抓取
# BV号为1W5411L7q2的视频属性抓取结束
# 开始BV号为1wK4y1E7wE视频属性的抓取
# BV号为1wK4y1E7wE的视频属性抓取结束
# 开始BV号为1h54y1C7w8视频属性的抓取
# BV号为1h54y1C7w8的视频属性抓取结束
# 开始BV号为1ti4y1j7sU视频属性的抓取
# BV号为1ti4y1j7sU的视频属性抓取结束
# 开始BV号为1LZ4y157Qk视频属性的抓取
# BV号为1LZ4y157Qk的视频属性抓取结束
# 开始BV号为15A411E78A视频属性的抓取
# BV号为15A411E78A的视频属性抓取结束
# 开始BV号为11f4y1B7QY视频属性的抓取
# BV号为11f4y1B7QY的视频属性抓取结束
# 开始BV号为1zp4y1k77U视频属性的抓取
# BV号为1zp4y1k77U的视频属性抓取结束
# 开始BV号为1eA41177Eb视频属性的抓取
# BV号为1eA41177Eb的视频属性抓取结束
# 开始BV号为1o541157bD视频属性的抓取
# BV号为1o541157bD的视频属性抓取结束
# 开始BV号为1954y117B7视频属性的抓取
# BV号为1954y117B7的视频属性抓取结束
# 开始BV号为1ef4y1D71Z视频属性的抓取
# BV号为1ef4y1D71Z的视频属性抓取结束
# 开始BV号为1x54y1R7z8视频属性的抓取
# BV号为1x54y1R7z8的视频属性抓取结束
# 开始BV号为1ra411A7Yc视频属性的抓取
# BV号为1ra411A7Yc的视频属性抓取结束
# 开始BV号为1754y1k7c8视频属性的抓取
# BV号为1754y1k7c8的视频属性抓取结束
# 开始BV号为1Ma4y1L7P3视频属性的抓取
# BV号为1Ma4y1L7P3的视频属性抓取结束
# 开始BV号为1JA411779n视频属性的抓取
# BV号为1JA411779n的视频属性抓取结束
# 开始BV号为1yz4y1o7US视频属性的抓取
# BV号为1yz4y1o7US的视频属性抓取结束
# 开始BV号为1qK411N7tL视频属性的抓取
# BV号为1qK411N7tL的视频属性抓取结束
# 开始BV号为1cp4y1Y7Kv视频属性的抓取
# BV号为1cp4y1Y7Kv的视频属性抓取结束
# 开始BV号为14z4y1o7Ek视频属性的抓取
# BV号为14z4y1o7Ek的视频属性抓取结束
# 开始BV号为1ZV41117rP视频属性的抓取
# BV号为1ZV41117rP的视频属性抓取结束
# 开始BV号为1tp4y1Y7YU视频属性的抓取
# BV号为1tp4y1Y7YU的视频属性抓取结束
# 开始BV号为1Qi4y1j7BF视频属性的抓取
# BV号为1Qi4y1j7BF的视频属性抓取结束
# 开始BV号为1oA41177so视频属性的抓取
# BV号为1oA41177so的视频属性抓取结束
# 开始BV号为1PK4y1E76p视频属性的抓取
# BV号为1PK4y1E76p的视频属性抓取结束
# 开始BV号为12i4y1E7Pu视频属性的抓取
# BV号为12i4y1E7Pu的视频属性抓取结束
# 开始BV号为1vf4y1i7hM视频属性的抓取
# BV号为1vf4y1i7hM的视频属性抓取结束
# 开始BV号为1da411w7oq视频属性的抓取
# BV号为1da411w7oq的视频属性抓取结束
# 开始BV号为1vK411N7Yf视频属性的抓取
# BV号为1vK411N7Yf的视频属性抓取结束
# 开始BV号为1Hy4y1B7uN视频属性的抓取
# BV号为1Hy4y1B7uN的视频属性抓取结束
# 开始BV号为1Ua411w7Ag视频属性的抓取
# BV号为1Ua411w7Ag的视频属性抓取结束
# <ipython-input-9-54d5a7f154fb>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1Sa411A7UV视频属性的抓取
# BV号为1Sa411A7UV的视频属性抓取结束
# 开始BV号为1Y54y1R76P视频属性的抓取
# BV号为1Y54y1R76P的视频属性抓取结束
# 开始BV号为1tt4y1v7Ah视频属性的抓取
# BV号为1tt4y1v7Ah的视频属性抓取结束
# 开始BV号为1Xf4y1B7tv视频属性的抓取
# BV号为1Xf4y1B7tv的视频属性抓取结束
# 开始BV号为1nt4y1v7Ay视频属性的抓取
# BV号为1nt4y1v7Ay的视频属性抓取结束
# 开始BV号为1Rt4y1Y73Z视频属性的抓取
# BV号为1Rt4y1Y73Z的视频属性抓取结束
# 开始BV号为1154y1y7r9视频属性的抓取
# BV号为1154y1y7r9的视频属性抓取结束
# 开始BV号为1Rv411k728视频属性的抓取
# BV号为1Rv411k728的视频属性抓取结束
# 开始BV号为1ka4y1L7j3视频属性的抓取
# BV号为1ka4y1L7j3的视频属性抓取结束
# 开始BV号为1KK411P7AY视频属性的抓取
# BV号为1KK411P7AY的视频属性抓取结束
# 开始BV号为1Qa4y157Fo视频属性的抓取
# BV号为1Qa4y157Fo的视频属性抓取结束
# 开始BV号为1Cz4y1C7RK视频属性的抓取
# BV号为1Cz4y1C7RK的视频属性抓取结束
# 开始BV号为1WZ4y157Cv视频属性的抓取
# BV号为1WZ4y157Cv的视频属性抓取结束
# 开始BV号为1cK411A7wm视频属性的抓取
# BV号为1cK411A7wm的视频属性抓取结束
# 开始BV号为1BD4y1d7Ym视频属性的抓取
# BV号为1BD4y1d7Ym的视频属性抓取结束
# 开始BV号为1aD4y197aQ视频属性的抓取
# BV号为1aD4y197aQ的视频属性抓取结束
# 开始BV号为1h54y1k714视频属性的抓取
# BV号为1h54y1k714的视频属性抓取结束
# 开始BV号为1JA411E7iM视频属性的抓取
# BV号为1JA411E7iM的视频属性抓取结束
# 开始BV号为145411j7fj视频属性的抓取
# BV号为145411j7fj的视频属性抓取结束
# 开始BV号为1jv411k7zM视频属性的抓取
# BV号为1jv411k7zM的视频属性抓取结束
# 开始BV号为1My4y1r7d1视频属性的抓取
# BV号为1My4y1r7d1的视频属性抓取结束
# 开始BV号为1x54y117gV视频属性的抓取
# BV号为1x54y117gV的视频属性抓取结束
# 开始BV号为1R54y117tu视频属性的抓取
# 开始BV号为1R54y117tu视频属性的抓取
# BV号为1R54y117tu的视频属性抓取结束
# 开始BV号为1Xk4y1C7tt视频属性的抓取
# BV号为1Xk4y1C7tt的视频属性抓取结束
# 开始BV号为1vv411y7rk视频属性的抓取
# BV号为1vv411y7rk的视频属性抓取结束
# 开始BV号为1x54y1r7HS视频属性的抓取
# BV号为1x54y1r7HS的视频属性抓取结束
# 2020-12-17 20:18:31.835851

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-14-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_yingshi_jianji.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月    99   99    99   99   99   99   99   99    99      99   99    99   99
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 4月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月   99   99   99   99   99   99    99
# 1月   100  100  100  100  100  100   100
# 2月   100  100  100  100  100  100   100
# 3月   100  100  100  100  100  100   100
# 1KJ411e7nN                              如何提高审美？审美有无高低？审美是谁建立？  数码  摄影摄像  普通视频
# ...                                                       ...  ..   ...   ...
# 1cr4y1w7ig              困难重重，国家天文签约摄影师遭遇拍摄滑铁卢？！【华为Mate40 Pro】  数码  摄影摄像  活动作品
# 1Y5411L7TW                     富士X-S10相机测试——2020 apsc画幅性价比最强机  数码  摄影摄像  活动作品
# 1c541177hR      索尼（Sony）12-24mm F2.8 GM深度评测，只要买得起，它就是一颗完美的镜头！  数码  摄影摄像  普通视频
# 1DA41177UY                            大疆旗舰稳定器 - DJI RS 2 正式登场  数码  摄影摄像  普通视频
# 1rA411776p                 让我非常失望的佳能M50 Mark II（来自一代老用户的真实心声）  数码  摄影摄像  普通视频
#
#             ...                                                 标签   视频长度  \
# 1gJ411n7hp  ...                         [摄影, 数码, 摄影摄像, 数码, 教程, 器材]  01:44
# 1tJ41187w6  ...  [相机, 数码, 摄影摄像, 数码, 何同学, 啊吗粽, 宝剑嫂, 自媒体, 大祥哥, 体验...  30:03
# 1i7411i7yA  ...        [摄影, 短片, 数码, 摄影摄像, 数码, 创意, YOUTUBE, 镜头, 老蛙]  04:51
# 1gJ411G7Cs  ...           [摄影, 数码, 摄影摄像, 数码, VLOG, 后期, 教程, ps, 器材]  06:01
# 1KJ411e7nN  ...  [校园vlog, 相机, 脱口秀, 摄影, 公开课, vlog, 科普, 数码, 摄影摄像,...  27:08
# ...         ...                                                ...    ...
# 1cr4y1w7ig  ...  [vlog, 数码, 摄影摄像, 数码, 放心购机攻略, 敦煌, 星空, 手机摄影, 华为,...  11:43
# 1Y5411L7TW  ...  [相机, 摄影, 数码, 摄影摄像, 数码, 数码玩家训练营, 拍照, 测评, xs10, ...  10:20
# 1c541177hR  ...  [摄影, 数码, 摄影摄像, 数码, 评测, 超广角大光圈, 摄像, 镜头, 数码评测, 超...  21:23
# 1DA41177UY  ...   [相机, 摄影, 数码, 摄影摄像, 数码, 科技, 测评, 器材, 大疆, DJI, 稳定器]  02:26
# 1rA411776p  ...  [vlog, 数码, 摄影摄像, 数码, 佳能, 测评, 体验, m50 mark ii, ...  06:30
#
#                播放量    点赞数   投币数   收藏数   转发数   评论数   弹幕数 有无分集
# 1gJ411n7hp  222.4万   9.7万  2.0万  1.4万  4980  3182  1571    否
# 1tJ41187w6  134.0万  10.7万  8.4万  5.8万  8907  3935  3.0万    否
# 1i7411i7yA   57.8万   4.4万  1.0万  1.6万  2043   641   983    否
# 1gJ411G7Cs   42.3万   3.3万  3.4万  8.6万  2605  1405   612    否
# 1KJ411e7nN   39.6万   4.8万  5.4万  3.4万  6217  1156  1.0万    否
# ...            ...    ...   ...   ...   ...   ...   ...  ...
# 1cr4y1w7ig    4.3万   3051  1391   692   255   337   349    否
# 1Y5411L7TW    4.3万    773   219   221   111   273   104    否
# 1c541177hR    4.1万   1469   443   297   123   250   561    否
# 1DA41177UY    4.1万   1565   197   334   640   171   110    否
# 1rA411776p    4.1万   1262   267   147   101   385   314    否
#
# [999 rows x 21 columns]
