# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_meishi_zhentan=pd.DataFrame(columns=columns)
channel_meishi_zhentan
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[18]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '美食'

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[18]/div/a/span').click()  #选择频道

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[3]/a').click()  #选择子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[3]/a').text
sub_channel
# Out:
# '美食侦探'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(1,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_meishi_zhentan.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-17 21:51:47.000852
# <ipython-input-12-7de52d9190a4>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-12-7de52d9190a4>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-12-7de52d9190a4>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1MJ41177XA视频属性的抓取
# BV号为1MJ41177XA的视频属性抓取结束
# <ipython-input-12-7de52d9190a4>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1J7411i7i5视频属性的抓取
# BV号为1J7411i7i5的视频属性抓取结束
# 开始BV号为1kJ411G7Fq视频属性的抓取
# BV号为1kJ411G7Fq的视频属性抓取结束
# 开始BV号为1BJ411E7RE视频属性的抓取
# BV号为1BJ411E7RE的视频属性抓取结束
# 开始BV号为117411i7pg视频属性的抓取
# BV号为117411i7pg的视频属性抓取结束
# 开始BV号为1GJ411n7fM视频属性的抓取
# BV号为1GJ411n7fM的视频属性抓取结束
# 开始BV号为1FJ411V7qn视频属性的抓取
# BV号为1FJ411V7qn的视频属性抓取结束
# 开始BV号为15J411G7jf视频属性的抓取
# BV号为15J411G7jf的视频属性抓取结束
# 开始BV号为1FJ41187nj视频属性的抓取
# BV号为1FJ41187nj的视频属性抓取结束
# 开始BV号为1DJ411J7nT视频属性的抓取
# BV号为1DJ411J7nT的视频属性抓取结束
# 开始BV号为1RJ411G76f视频属性的抓取
# BV号为1RJ411G76f的视频属性抓取结束
# 开始BV号为1pJ411E7W2视频属性的抓取
# BV号为1pJ411E7W2的视频属性抓取结束
# 开始BV号为1vJ411V7sH视频属性的抓取
# BV号为1vJ411V7sH的视频属性抓取结束
# 开始BV号为1D7411Y7EC视频属性的抓取
# BV号为1D7411Y7EC的视频属性抓取结束
# 开始BV号为1h7411e7oo视频属性的抓取
# BV号为1h7411e7oo的视频属性抓取结束
# 开始BV号为1WJ411p7Vw视频属性的抓取
# BV号为1WJ411p7Vw的视频属性抓取结束
# 开始BV号为17J411p7qG视频属性的抓取
# BV号为17J411p7qG的视频属性抓取结束
# 开始BV号为17J41177cD视频属性的抓取
# BV号为17J41177cD的视频属性抓取结束
# 开始BV号为1fJ411V7vf视频属性的抓取
# BV号为1fJ411V7vf的视频属性抓取结束
# 开始BV号为1V7411i7R6视频属性的抓取
# BV号为1V7411i7R6的视频属性抓取结束
# 开始BV号为1qJ41177Dm视频属性的抓取
# BV号为1qJ41177Dm的视频属性抓取结束
# 开始BV号为1M7411i7ZX视频属性的抓取
# BV号为1M7411i7ZX的视频属性抓取结束
# 开始BV号为18J411j7Ff视频属性的抓取
# BV号为18J411j7Ff的视频属性抓取结束
# 开始BV号为1zJ411j7gR视频属性的抓取
# BV号为1zJ411j7gR的视频属性抓取结束
# 开始BV号为1x7411B7FU视频属性的抓取
# BV号为1x7411B7FU的视频属性抓取结束
# 开始BV号为1wJ41157H8视频属性的抓取
# BV号为1wJ41157H8的视频属性抓取结束
# 开始BV号为1YJ411J7ih视频属性的抓取
# BV号为1YJ411J7ih的视频属性抓取结束
# 开始BV号为1f7411v7Qk视频属性的抓取
# BV号为1f7411v7Qk的视频属性抓取结束
# 开始BV号为1NJ41177yg视频属性的抓取
# BV号为1NJ41177yg的视频属性抓取结束
# 开始BV号为1w7411k7ZX视频属性的抓取
# BV号为1w7411k7ZX的视频属性抓取结束
# 开始BV号为1s7411v7ZG视频属性的抓取
# BV号为1s7411v7ZG的视频属性抓取结束
# 开始BV号为1UJ411H7ba视频属性的抓取
# BV号为1UJ411H7ba的视频属性抓取结束
# 开始BV号为1iJ411p7gZ视频属性的抓取
# BV号为1iJ411p7gZ的视频属性抓取结束
# 开始BV号为1SJ411L7dG视频属性的抓取
# BV号为1SJ411L7dG的视频属性抓取结束
# 开始BV号为17J411G7sN视频属性的抓取
# BV号为17J411G7sN的视频属性抓取结束
# 开始BV号为1cJ411H73a视频属性的抓取
# BV号为1cJ411H73a的视频属性抓取结束
# 开始BV号为12741167Yh视频属性的抓取
# BV号为12741167Yh的视频属性抓取结束
# 开始BV号为1DJ411E7wC视频属性的抓取
# BV号为1DJ411E7wC的视频属性抓取结束
# 开始BV号为117411q7t8视频属性的抓取
# BV号为117411q7t8的视频属性抓取结束
# 开始BV号为1t7411679q视频属性的抓取
# BV号为1t7411679q的视频属性抓取结束
# 开始BV号为1DJ411V7dR视频属性的抓取
# BV号为1DJ411V7dR的视频属性抓取结束
# 开始BV号为1Y7411v7sF视频属性的抓取
# BV号为1Y7411v7sF的视频属性抓取结束
# 开始BV号为167411e7vR视频属性的抓取
# BV号为167411e7vR的视频属性抓取结束
# 开始BV号为18J411j7hM视频属性的抓取
# BV号为18J411j7hM的视频属性抓取结束
# 开始BV号为1tJ411E7fy视频属性的抓取
# BV号为1tJ411E7fy的视频属性抓取结束
# 开始BV号为1D7411e7PU视频属性的抓取
# BV号为1D7411e7PU的视频属性抓取结束
# 开始BV号为1wJ411J76e视频属性的抓取
# BV号为1wJ411J76e的视频属性抓取结束
# 开始BV号为1DJ411p7Cn视频属性的抓取
# BV号为1DJ411p7Cn的视频属性抓取结束
# 开始BV号为1s7411B7ox视频属性的抓取
# 开始BV号为1s7411B7ox视频属性的抓取
# BV号为1s7411B7ox的视频属性抓取结束
# 开始BV号为14J411E7ye视频属性的抓取
# BV号为14J411E7ye的视频属性抓取结束
# 开始BV号为1N7411v7ZN视频属性的抓取
# BV号为1N7411v7ZN的视频属性抓取结束
# 开始BV号为1L7411e7Yy视频属性的抓取
# BV号为1L7411e7Yy的视频属性抓取结束
# 开始BV号为1VJ411E7C3视频属性的抓取
# BV号为1VJ411E7C3的视频属性抓取结束
# 开始BV号为19J41157sL视频属性的抓取
# BV号为19J41157sL的视频属性抓取结束
# 开始BV号为12J411J7kH视频属性的抓取
# BV号为12J411J7kH的视频属性抓取结束
# 开始BV号为1d7411r7JU视频属性的抓取
# BV号为1d7411r7JU的视频属性抓取结束
# 开始BV号为1QJ41177oP视频属性的抓取
# BV号为1QJ41177oP的视频属性抓取结束
# 开始BV号为1k7411q7A3视频属性的抓取
# BV号为1k7411q7A3的视频属性抓取结束
# 开始BV号为1c7411e7yW视频属性的抓取
# BV号为1c7411e7yW的视频属性抓取结束
# 开始BV号为1xJ41187fU视频属性的抓取
# BV号为1xJ41187fU的视频属性抓取结束
# 开始BV号为1UJ411n7fv视频属性的抓取
# BV号为1UJ411n7fv的视频属性抓取结束
# 开始BV号为1eJ41177et视频属性的抓取
# BV号为1eJ41177et的视频属性抓取结束
# 开始BV号为1aJ411E7aE视频属性的抓取
# BV号为1aJ411E7aE的视频属性抓取结束
# 开始BV号为18J41187jA视频属性的抓取
# BV号为18J41187jA的视频属性抓取结束
# 开始BV号为1PJ411j7sR视频属性的抓取
# BV号为1PJ411j7sR的视频属性抓取结束
# 开始BV号为1o7411e7QM视频属性的抓取
# BV号为1o7411e7QM的视频属性抓取结束
# 开始BV号为1j7411q7d9视频属性的抓取
# BV号为1j7411q7d9的视频属性抓取结束
# 开始BV号为13J41157NH视频属性的抓取
# BV号为13J41157NH的视频属性抓取结束
# 开始BV号为1A7411z7ra视频属性的抓取
# BV号为1A7411z7ra的视频属性抓取结束
# 开始BV号为1U7411v7Rr视频属性的抓取
# BV号为1U7411v7Rr的视频属性抓取结束
# 开始BV号为1c7411C7az视频属性的抓取
# BV号为1c7411C7az的视频属性抓取结束
# 开始BV号为1UJ4117739视频属性的抓取
# BV号为1UJ4117739的视频属性抓取结束
# 开始BV号为1hJ411j7Bv视频属性的抓取
# BV号为1hJ411j7Bv的视频属性抓取结束
# 开始BV号为1zJ411V7MM视频属性的抓取
# BV号为1zJ411V7MM的视频属性抓取结束
# 开始BV号为1gJ411H7DE视频属性的抓取
# BV号为1gJ411H7DE的视频属性抓取结束
# 开始BV号为1W7411i714视频属性的抓取
# BV号为1W7411i714的视频属性抓取结束
# 开始BV号为1KJ411V7f5视频属性的抓取
# BV号为1KJ411V7f5的视频属性抓取结束
# 开始BV号为167411v7dG视频属性的抓取
# BV号为167411v7dG的视频属性抓取结束
# 开始BV号为1uJ411E7nh视频属性的抓取
# BV号为1uJ411E7nh的视频属性抓取结束
# 开始BV号为1E7411Y7YR视频属性的抓取
# BV号为1E7411Y7YR的视频属性抓取结束
# 开始BV号为1j7411i7Zu视频属性的抓取
# BV号为1j7411i7Zu的视频属性抓取结束
# 开始BV号为1m7411B7Zc视频属性的抓取
# BV号为1m7411B7Zc的视频属性抓取结束
# 开始BV号为1w7411r7Gk视频属性的抓取
# BV号为1w7411r7Gk的视频属性抓取结束
# 开始BV号为1m7411a7kS视频属性的抓取
# BV号为1m7411a7kS的视频属性抓取结束
# 开始BV号为1jJ411V7Wh视频属性的抓取
# BV号为1jJ411V7Wh的视频属性抓取结束
# 开始BV号为1WJ41187Au视频属性的抓取
# BV号为1WJ41187Au的视频属性抓取结束
# 开始BV号为1a7411v73p视频属性的抓取
# BV号为1a7411v73p的视频属性抓取结束
# 开始BV号为1c7411k7iQ视频属性的抓取
# BV号为1c7411k7iQ的视频属性抓取结束
# 开始BV号为1Y7411r7Xc视频属性的抓取
# BV号为1Y7411r7Xc的视频属性抓取结束
# 开始BV号为1eJ411J74j视频属性的抓取
# BV号为1eJ411J74j的视频属性抓取结束
# 开始BV号为1U7411B7in视频属性的抓取
# BV号为1U7411B7in的视频属性抓取结束
# 开始BV号为14J411H7ps视频属性的抓取
# BV号为14J411H7ps的视频属性抓取结束
# 开始BV号为1d7411q7co视频属性的抓取
# BV号为1d7411q7co的视频属性抓取结束
# 开始BV号为12J411j7Jt视频属性的抓取
# BV号为12J411j7Jt的视频属性抓取结束
# 开始BV号为14J411V7vX视频属性的抓取
# BV号为14J411V7vX的视频属性抓取结束
# 开始BV号为1FJ411j7v6视频属性的抓取
# BV号为1FJ411j7v6的视频属性抓取结束
# 开始BV号为1C7411q7Xb视频属性的抓取
# BV号为1C7411q7Xb的视频属性抓取结束
# 开始BV号为1oJ411G7bk视频属性的抓取
# BV号为1oJ411G7bk的视频属性抓取结束
# 开始BV号为1rJ411j71W视频属性的抓取
# BV号为1rJ411j71W的视频属性抓取结束
# 开始BV号为1yJ411V7UC视频属性的抓取
# BV号为1yJ411V7UC的视频属性抓取结束
# 开始BV号为1k7411w7jx视频属性的抓取
# BV号为1k7411w7jx的视频属性抓取结束
# 开始BV号为1D7411j7BU视频属性的抓取
# BV号为1D7411j7BU的视频属性抓取结束
# 开始BV号为1c741177iN视频属性的抓取
# BV号为1c741177iN的视频属性抓取结束
# 开始BV号为1e7411F7WF视频属性的抓取
# BV号为1e7411F7WF的视频属性抓取结束
# 开始BV号为1H7411s7bg视频属性的抓取
# BV号为1H7411s7bg的视频属性抓取结束
# 开始BV号为14741137B9视频属性的抓取
# BV号为14741137B9的视频属性抓取结束
# 开始BV号为1q741137Qd视频属性的抓取
# BV号为1q741137Qd的视频属性抓取结束
# 开始BV号为1L7411N7HQ视频属性的抓取
# BV号为1L7411N7HQ的视频属性抓取结束
# 开始BV号为1yE411J7hy视频属性的抓取
# BV号为1yE411J7hy的视频属性抓取结束
# 开始BV号为1d7411w7FS视频属性的抓取
# BV号为1d7411w7FS的视频属性抓取结束
# 开始BV号为1V7411371D视频属性的抓取
# BV号为1V7411371D的视频属性抓取结束
# 开始BV号为1T7411a7LU视频属性的抓取
# BV号为1T7411a7LU的视频属性抓取结束
# 开始BV号为1T7411g72i视频属性的抓取
# BV号为1T7411g72i的视频属性抓取结束
# 开始BV号为1S7411K7K2视频属性的抓取
# BV号为1S7411K7K2的视频属性抓取结束
# 开始BV号为13741157LS视频属性的抓取
# BV号为13741157LS的视频属性抓取结束
# 开始BV号为1C7411c7AG视频属性的抓取
# BV号为1C7411c7AG的视频属性抓取结束
# 开始BV号为1d7411W7xj视频属性的抓取
# BV号为1d7411W7xj的视频属性抓取结束
# 开始BV号为1w7411L7Uh视频属性的抓取
# BV号为1w7411L7Uh的视频属性抓取结束
# 开始BV号为1A7411w7Wy视频属性的抓取
# 开始BV号为1A7411w7Wy视频属性的抓取
# BV号为1A7411w7Wy的视频属性抓取结束
# 开始BV号为157411b7M6视频属性的抓取
# BV号为157411b7M6的视频属性抓取结束
# 开始BV号为1C7411g7Fq视频属性的抓取
# BV号为1C7411g7Fq的视频属性抓取结束
# 开始BV号为197411K7Lg视频属性的抓取
# BV号为197411K7Lg的视频属性抓取结束
# 开始BV号为1F7411F7Y9视频属性的抓取
# BV号为1F7411F7Y9的视频属性抓取结束
# 开始BV号为1g741187vw视频属性的抓取
# BV号为1g741187vw的视频属性抓取结束
# 开始BV号为1k741147ET视频属性的抓取
# BV号为1k741147ET的视频属性抓取结束
# 开始BV号为1W7411L7E5视频属性的抓取
# BV号为1W7411L7E5的视频属性抓取结束
# 开始BV号为1u7411p7Hr视频属性的抓取
# BV号为1u7411p7Hr的视频属性抓取结束
# 开始BV号为1B7411W7Ao视频属性的抓取
# BV号为1B7411W7Ao的视频属性抓取结束
# 开始BV号为11741137RU视频属性的抓取
# BV号为11741137RU的视频属性抓取结束
# 开始BV号为1Q741177y5视频属性的抓取
# BV号为1Q741177y5的视频属性抓取结束
# <ipython-input-12-7de52d9190a4>:190: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为187411V7tm视频属性的抓取
# BV号为187411V7tm的视频属性抓取结束
# 开始BV号为1D7411p7z9视频属性的抓取
# BV号为1D7411p7z9的视频属性抓取结束
# 开始BV号为1Y7411s7o1视频属性的抓取
# BV号为1Y7411s7o1的视频属性抓取结束
# 开始BV号为1j7411t7PC视频属性的抓取
# BV号为1j7411t7PC的视频属性抓取结束
# 开始BV号为1g7411G7uw视频属性的抓取
# BV号为1g7411G7uw的视频属性抓取结束
# 开始BV号为1B7411H7Fw视频属性的抓取
# BV号为1B7411H7Fw的视频属性抓取结束
# 开始BV号为1J7411579u视频属性的抓取
# BV号为1J7411579u的视频属性抓取结束
# 开始BV号为1s7411P7B5视频属性的抓取
# BV号为1s7411P7B5的视频属性抓取结束
# 开始BV号为1u7411p7Le视频属性的抓取
# BV号为1u7411p7Le的视频属性抓取结束
# 开始BV号为1v7411G7rg视频属性的抓取
# BV号为1v7411G7rg的视频属性抓取结束
# 开始BV号为1U7411F7SP视频属性的抓取
# BV号为1U7411F7SP的视频属性抓取结束
# 开始BV号为1X7411u7d6视频属性的抓取
# BV号为1X7411u7d6的视频属性抓取结束
# 开始BV号为1v7411u7rw视频属性的抓取
# BV号为1v7411u7rw的视频属性抓取结束
# 开始BV号为127411L7Da视频属性的抓取
# BV号为127411L7Da的视频属性抓取结束
# 开始BV号为1e7411j7L2视频属性的抓取
# BV号为1e7411j7L2的视频属性抓取结束
# 开始BV号为1P7411p7Gt视频属性的抓取
# BV号为1P7411p7Gt的视频属性抓取结束
# 开始BV号为137411w7uF视频属性的抓取
# BV号为137411w7uF的视频属性抓取结束
# 开始BV号为1P741187Nw视频属性的抓取
# BV号为1P741187Nw的视频属性抓取结束
# 开始BV号为1M741147LV视频属性的抓取
# BV号为1M741147LV的视频属性抓取结束
# 开始BV号为1Q7411u7m6视频属性的抓取
# BV号为1Q7411u7m6的视频属性抓取结束
# 开始BV号为1h7411t74s视频属性的抓取
# BV号为1h7411t74s的视频属性抓取结束
# 开始BV号为1X7411N7uR视频属性的抓取
# BV号为1X7411N7uR的视频属性抓取结束
# 开始BV号为1N7411n7aW视频属性的抓取
# 开始BV号为1N7411n7aW视频属性的抓取
# BV号为1N7411n7aW的视频属性抓取结束
# 开始BV号为1f7411g7kQ视频属性的抓取
# BV号为1f7411g7kQ的视频属性抓取结束
# 开始BV号为1M741177Vf视频属性的抓取
# BV号为1M741177Vf的视频属性抓取结束
# 开始BV号为1c7411w7fy视频属性的抓取
# BV号为1c7411w7fy的视频属性抓取结束
# 开始BV号为1U7411h7LV视频属性的抓取
# BV号为1U7411h7LV的视频属性抓取结束
# 开始BV号为1q7411H7tv视频属性的抓取
# BV号为1q7411H7tv的视频属性抓取结束
# 开始BV号为1Z7411j7g2视频属性的抓取
# BV号为1Z7411j7g2的视频属性抓取结束
# 开始BV号为1H7411j7Qy视频属性的抓取
# BV号为1H7411j7Qy的视频属性抓取结束
# 开始BV号为1p7411b7H2视频属性的抓取
# BV号为1p7411b7H2的视频属性抓取结束
# 开始BV号为1d7411w7ob视频属性的抓取
# BV号为1d7411w7ob的视频属性抓取结束
# 开始BV号为1V7411w7Cn视频属性的抓取
# BV号为1V7411w7Cn的视频属性抓取结束
# 开始BV号为1G7411c7WS视频属性的抓取
# BV号为1G7411c7WS的视频属性抓取结束
# 开始BV号为1j7411h7KE视频属性的抓取
# BV号为1j7411h7KE的视频属性抓取结束
# 开始BV号为1n7411b7mB视频属性的抓取
# BV号为1n7411b7mB的视频属性抓取结束
# 开始BV号为17741177EG视频属性的抓取
# BV号为17741177EG的视频属性抓取结束
# 开始BV号为19741157qQ视频属性的抓取
# BV号为19741157qQ的视频属性抓取结束
# 开始BV号为1h7411p73G视频属性的抓取
# BV号为1h7411p73G的视频属性抓取结束
# 开始BV号为1d7411J7XZ视频属性的抓取
# BV号为1d7411J7XZ的视频属性抓取结束
# 开始BV号为1T7411V7vV视频属性的抓取
# BV号为1T7411V7vV的视频属性抓取结束
# 开始BV号为1U7411h7qH视频属性的抓取
# BV号为1U7411h7qH的视频属性抓取结束
# 开始BV号为1t7411j71d视频属性的抓取
# BV号为1t7411j71d的视频属性抓取结束
# 开始BV号为1Q7411s7iK视频属性的抓取
# BV号为1Q7411s7iK的视频属性抓取结束
# 开始BV号为1NE411J7Qi视频属性的抓取
# BV号为1NE411J7Qi的视频属性抓取结束
# 开始BV号为1h7411E7fh视频属性的抓取
# BV号为1h7411E7fh的视频属性抓取结束
# 开始BV号为1W7411H7wB视频属性的抓取
# BV号为1W7411H7wB的视频属性抓取结束
# 开始BV号为1c7411A7PM视频属性的抓取
# BV号为1c7411A7PM的视频属性抓取结束
# 开始BV号为1w7411F7JF视频属性的抓取
# BV号为1w7411F7JF的视频属性抓取结束
# 开始BV号为1S7411b769视频属性的抓取
# BV号为1S7411b769的视频属性抓取结束
# 开始BV号为187411E7jt视频属性的抓取
# BV号为187411E7jt的视频属性抓取结束
# 开始BV号为1h7411T7u1视频属性的抓取
# BV号为1h7411T7u1的视频属性抓取结束
# 开始BV号为1W7411P7rQ视频属性的抓取
# BV号为1W7411P7rQ的视频属性抓取结束
# 开始BV号为1T7411E7GQ视频属性的抓取
# BV号为1T7411E7GQ的视频属性抓取结束
# 开始BV号为1g7411M7ZM视频属性的抓取
# BV号为1g7411M7ZM的视频属性抓取结束
# 开始BV号为1E7411p7MN视频属性的抓取
# BV号为1E7411p7MN的视频属性抓取结束
# 开始BV号为1UE411n77i视频属性的抓取
# BV号为1UE411n77i的视频属性抓取结束
# 开始BV号为1c7411g72e视频属性的抓取
# BV号为1c7411g72e的视频属性抓取结束
# 开始BV号为14741177mp视频属性的抓取
# BV号为14741177mp的视频属性抓取结束
# 开始BV号为137411s7EN视频属性的抓取
# BV号为137411s7EN的视频属性抓取结束
# 开始BV号为1j7411F7Gb视频属性的抓取
# BV号为1j7411F7Gb的视频属性抓取结束
# 开始BV号为1W7411F71f视频属性的抓取
# BV号为1W7411F71f的视频属性抓取结束
# 开始BV号为1o7411T7L1视频属性的抓取
# BV号为1o7411T7L1的视频属性抓取结束
# 开始BV号为1j7411H7TY视频属性的抓取
# BV号为1j7411H7TY的视频属性抓取结束
# 开始BV号为1AE411J7J2视频属性的抓取
# BV号为1AE411J7J2的视频属性抓取结束
# 开始BV号为1c7411h7Qh视频属性的抓取
# BV号为1c7411h7Qh的视频属性抓取结束
# 开始BV号为1jE411J7CT视频属性的抓取
# BV号为1jE411J7CT的视频属性抓取结束
# 开始BV号为1vZ4y1j7kR视频属性的抓取
# BV号为1vZ4y1j7kR的视频属性抓取结束
# 开始BV号为1i7411R7Qr视频属性的抓取
# BV号为1i7411R7Qr的视频属性抓取结束
# 开始BV号为13E41137Dp视频属性的抓取
# BV号为13E41137Dp的视频属性抓取结束
# 开始BV号为1m7411o7p2视频属性的抓取
# BV号为1m7411o7p2的视频属性抓取结束
# 开始BV号为1UE411E7vq视频属性的抓取
# BV号为1UE411E7vq的视频属性抓取结束
# 开始BV号为14T4y1573i视频属性的抓取
# BV号为14T4y1573i的视频属性抓取结束
# 开始BV号为1DE411K7p7视频属性的抓取
# BV号为1DE411K7p7的视频属性抓取结束
# 开始BV号为1aV411f76M视频属性的抓取
# BV号为1aV411f76M的视频属性抓取结束
# 开始BV号为1S7411m7KJ视频属性的抓取
# BV号为1S7411m7KJ的视频属性抓取结束
# 开始BV号为12E411779E视频属性的抓取
# BV号为12E411779E的视频属性抓取结束
# 开始BV号为1dE41157JH视频属性的抓取
# BV号为1dE41157JH的视频属性抓取结束
# 开始BV号为1qE411s75X视频属性的抓取
# BV号为1qE411s75X的视频属性抓取结束
# 开始BV号为1EE411g7ea视频属性的抓取
# BV号为1EE411g7ea的视频属性抓取结束
# 开始BV号为1KE411g727视频属性的抓取
# BV号为1KE411g727的视频属性抓取结束
# 开始BV号为1YE411p77U视频属性的抓取
# BV号为1YE411p77U的视频属性抓取结束
# 开始BV号为1ZE41137gd视频属性的抓取
# BV号为1ZE41137gd的视频属性抓取结束
# 开始BV号为1oE411A7rN视频属性的抓取
# BV号为1oE411A7rN的视频属性抓取结束
# 开始BV号为1c7411Z7eD视频属性的抓取
# BV号为1c7411Z7eD的视频属性抓取结束
# 开始BV号为1GE411M7b3视频属性的抓取
# 开始BV号为1GE411M7b3视频属性的抓取
# BV号为1GE411M7b3的视频属性抓取结束
# 开始BV号为1gE411s7Rg视频属性的抓取
# BV号为1gE411s7Rg的视频属性抓取结束
# 开始BV号为14E411s7Rg视频属性的抓取
# BV号为14E411s7Rg的视频属性抓取结束
# 开始BV号为1T7411C7vU视频属性的抓取
# BV号为1T7411C7vU的视频属性抓取结束
# 开始BV号为1XE411K7J3视频属性的抓取
# BV号为1XE411K7J3的视频属性抓取结束
# 开始BV号为1gi4y1n7jx视频属性的抓取
# BV号为1gi4y1n7jx的视频属性抓取结束
# 开始BV号为1QE411P7wG视频属性的抓取
# BV号为1QE411P7wG的视频属性抓取结束
# 开始BV号为1G7411X7SB视频属性的抓取
# BV号为1G7411X7SB的视频属性抓取结束
# 开始BV号为1Z7411Z7Ru视频属性的抓取
# BV号为1Z7411Z7Ru的视频属性抓取结束
# 开始BV号为1jC4y1472u视频属性的抓取
# BV号为1jC4y1472u的视频属性抓取结束
# 开始BV号为1MA411h7Pd视频属性的抓取
# BV号为1MA411h7Pd的视频属性抓取结束
# 开始BV号为16741127QX视频属性的抓取
# BV号为16741127QX的视频属性抓取结束
# 开始BV号为1RE411x7pW视频属性的抓取
# BV号为1RE411x7pW的视频属性抓取结束
# 开始BV号为13a4y1t7cj视频属性的抓取
# BV号为13a4y1t7cj的视频属性抓取结束
# 开始BV号为1R64y1M7iA视频属性的抓取
# BV号为1R64y1M7iA的视频属性抓取结束
# 开始BV号为1H7411o79E视频属性的抓取
# BV号为1H7411o79E的视频属性抓取结束
# 开始BV号为1sE411E7Jx视频属性的抓取
# BV号为1sE411E7Jx的视频属性抓取结束
# 开始BV号为1bE411j7Nu视频属性的抓取
# BV号为1bE411j7Nu的视频属性抓取结束
# 开始BV号为1SE411N77d视频属性的抓取
# BV号为1SE411N77d的视频属性抓取结束
# 开始BV号为1hz411h7T5视频属性的抓取
# BV号为1hz411h7T5的视频属性抓取结束
# 开始BV号为1zE411A7VV视频属性的抓取
# BV号为1zE411A7VV的视频属性抓取结束
# 开始BV号为1NE41177yM视频属性的抓取
# BV号为1NE41177yM的视频属性抓取结束
# 开始BV号为1hV411f7en视频属性的抓取
# BV号为1hV411f7en的视频属性抓取结束
# 开始BV号为1MK411L7pq视频属性的抓取
# BV号为1MK411L7pq的视频属性抓取结束
# 开始BV号为1fE411L7qJ视频属性的抓取
# BV号为1fE411L7qJ的视频属性抓取结束
# 开始BV号为11E411g7yh视频属性的抓取
# BV号为11E411g7yh的视频属性抓取结束
# 开始BV号为1xE411L72M视频属性的抓取
# BV号为1xE411L72M的视频属性抓取结束
# 开始BV号为197411o77d视频属性的抓取
# BV号为197411o77d的视频属性抓取结束
# 开始BV号为1oE41177rj视频属性的抓取
# BV号为1oE41177rj的视频属性抓取结束
# 开始BV号为157411R7fw视频属性的抓取
# BV号为157411R7fw的视频属性抓取结束
# 开始BV号为1VE411W7Fa视频属性的抓取
# BV号为1VE411W7Fa的视频属性抓取结束
# 开始BV号为1iE411G7vg视频属性的抓取
# BV号为1iE411G7vg的视频属性抓取结束
# 开始BV号为1ZE411L78Y视频属性的抓取
# BV号为1ZE411L78Y的视频属性抓取结束
# 开始BV号为1Q7411R7hU视频属性的抓取
# BV号为1Q7411R7hU的视频属性抓取结束
# 开始BV号为1rE411N7Sk视频属性的抓取
# BV号为1rE411N7Sk的视频属性抓取结束
# 开始BV号为1jE4117761视频属性的抓取
# BV号为1jE4117761的视频属性抓取结束
# 开始BV号为1GE411M7WX视频属性的抓取
# BV号为1GE411M7WX的视频属性抓取结束
# 开始BV号为1zE411p7h2视频属性的抓取
# BV号为1zE411p7h2的视频属性抓取结束
# 开始BV号为1D7411P7jS视频属性的抓取
# BV号为1D7411P7jS的视频属性抓取结束
# 开始BV号为1e741117SH视频属性的抓取
# BV号为1e741117SH的视频属性抓取结束
# 开始BV号为1ZE411H7TH视频属性的抓取
# BV号为1ZE411H7TH的视频属性抓取结束
# 开始BV号为1qE411x7Vg视频属性的抓取
# BV号为1qE411x7Vg的视频属性抓取结束
# 开始BV号为127411o7HY视频属性的抓取
# BV号为127411o7HY的视频属性抓取结束
# 开始BV号为1S741197TT视频属性的抓取
# BV号为1S741197TT的视频属性抓取结束
# 开始BV号为1fE411P7ws视频属性的抓取
# BV号为1fE411P7ws的视频属性抓取结束
# <ipython-input-12-7de52d9190a4>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1yE411w7HV视频属性的抓取
# BV号为1yE411w7HV的视频属性抓取结束
# 开始BV号为1zE411M72e视频属性的抓取
# BV号为1zE411M72e的视频属性抓取结束
# 开始BV号为1EE411L7Bf视频属性的抓取
# BV号为1EE411L7Bf的视频属性抓取结束
# 开始BV号为1H7411S7oc视频属性的抓取
# BV号为1H7411S7oc的视频属性抓取结束
# 开始BV号为1Nk4y1o7Zg视频属性的抓取
# BV号为1Nk4y1o7Zg的视频属性抓取结束
# 开始BV号为1pE411N7mE视频属性的抓取
# BV号为1pE411N7mE的视频属性抓取结束
# 开始BV号为1s7411Z7SP视频属性的抓取
# BV号为1s7411Z7SP的视频属性抓取结束
# 开始BV号为16E411g7Hj视频属性的抓取
# BV号为16E411g7Hj的视频属性抓取结束
# 开始BV号为157411D7Kt视频属性的抓取
# BV号为157411D7Kt的视频属性抓取结束
# 开始BV号为1rt4y1m7p4视频属性的抓取
# BV号为1rt4y1m7p4的视频属性抓取结束
# 开始BV号为1xE41157Tf视频属性的抓取
# BV号为1xE41157Tf的视频属性抓取结束
# 开始BV号为1cE411K7MA视频属性的抓取
# BV号为1cE411K7MA的视频属性抓取结束
# 开始BV号为13E411g79D视频属性的抓取
# BV号为13E411g79D的视频属性抓取结束
# 开始BV号为1J7411U79T视频属性的抓取
# BV号为1J7411U79T的视频属性抓取结束
# 开始BV号为1s741127RX视频属性的抓取
# BV号为1s741127RX的视频属性抓取结束
# 开始BV号为1T7411o7NY视频属性的抓取
# BV号为1T7411o7NY的视频属性抓取结束
# 开始BV号为1Pg4y1a7UR视频属性的抓取
# BV号为1Pg4y1a7UR的视频属性抓取结束
# 开始BV号为1DE411c7zn视频属性的抓取
# BV号为1DE411c7zn的视频属性抓取结束
# 开始BV号为1wE411W7fy视频属性的抓取
# BV号为1wE411W7fy的视频属性抓取结束
# 开始BV号为1SE411w7aR视频属性的抓取
# BV号为1SE411w7aR的视频属性抓取结束
# 开始BV号为1zE411G78a视频属性的抓取
# BV号为1zE411G78a的视频属性抓取结束
# 开始BV号为1nE411E7ts视频属性的抓取
# BV号为1nE411E7ts的视频属性抓取结束
# 开始BV号为1S7411R7iV视频属性的抓取
# BV号为1S7411R7iV的视频属性抓取结束
# 开始BV号为1kE41157y8视频属性的抓取
# BV号为1kE41157y8的视频属性抓取结束
# 开始BV号为1ZE411H7Wd视频属性的抓取
# BV号为1ZE411H7Wd的视频属性抓取结束
# 开始BV号为1zE411x7sb视频属性的抓取
# BV号为1zE411x7sb的视频属性抓取结束
# 开始BV号为1BE41147hX视频属性的抓取
# BV号为1BE41147hX的视频属性抓取结束
# 开始BV号为1PE411A7GT视频属性的抓取
# BV号为1PE411A7GT的视频属性抓取结束
# 开始BV号为1aE411p7JQ视频属性的抓取
# BV号为1aE411p7JQ的视频属性抓取结束
# 开始BV号为1kE41157Ud视频属性的抓取
# BV号为1kE41157Ud的视频属性抓取结束
# 开始BV号为1oE411j7AK视频属性的抓取
# BV号为1oE411j7AK的视频属性抓取结束
# 开始BV号为1xE411x7B2视频属性的抓取
# BV号为1xE411x7B2的视频属性抓取结束
# 开始BV号为1SE411V714视频属性的抓取
# BV号为1SE411V714的视频属性抓取结束
# 开始BV号为1jE411E7Ak视频属性的抓取
# BV号为1jE411E7Ak的视频属性抓取结束
# 开始BV号为1gE411s79z视频属性的抓取
# BV号为1gE411s79z的视频属性抓取结束
# 开始BV号为1La4y1x7DM视频属性的抓取
# BV号为1La4y1x7DM的视频属性抓取结束
# 开始BV号为1RA411t7js视频属性的抓取
# BV号为1RA411t7js的视频属性抓取结束
# 开始BV号为1n5411t7GU视频属性的抓取
# BV号为1n5411t7GU的视频属性抓取结束
# 开始BV号为1664y1u7gw视频属性的抓取
# BV号为1664y1u7gw的视频属性抓取结束
# 开始BV号为1wi4y187sS视频属性的抓取
# BV号为1wi4y187sS的视频属性抓取结束
# 开始BV号为1c54y1d7gp视频属性的抓取
# BV号为1c54y1d7gp的视频属性抓取结束
# 开始BV号为15p4y1y7kr视频属性的抓取
# BV号为15p4y1y7kr的视频属性抓取结束
# 开始BV号为1oK411V7zy视频属性的抓取
# BV号为1oK411V7zy的视频属性抓取结束
# 开始BV号为1XT4y137vo视频属性的抓取
# BV号为1XT4y137vo的视频属性抓取结束
# 开始BV号为1rz411B7ce视频属性的抓取
# BV号为1rz411B7ce的视频属性抓取结束
# 开始BV号为1Rp4y1X74r视频属性的抓取
# BV号为1Rp4y1X74r的视频属性抓取结束
# 开始BV号为1nV411Z7pP视频属性的抓取
# BV号为1nV411Z7pP的视频属性抓取结束
# 开始BV号为1TC4y1W7jZ视频属性的抓取
# BV号为1TC4y1W7jZ的视频属性抓取结束
# 开始BV号为1nK41157T4视频属性的抓取
# BV号为1nK41157T4的视频属性抓取结束
# 开始BV号为1NV411Z7aN视频属性的抓取
# BV号为1NV411Z7aN的视频属性抓取结束
# 开始BV号为16f4y1U7DR视频属性的抓取
# BV号为16f4y1U7DR的视频属性抓取结束
# 开始BV号为1ck4y1k7dQ视频属性的抓取
# BV号为1ck4y1k7dQ的视频属性抓取结束
# 开始BV号为13V411d7uv视频属性的抓取
# BV号为13V411d7uv的视频属性抓取结束
# 开始BV号为1x64y1M7PM视频属性的抓取
# BV号为1x64y1M7PM的视频属性抓取结束
# 开始BV号为1Xk4y1977v视频属性的抓取
# BV号为1Xk4y1977v的视频属性抓取结束
# 开始BV号为1ZV411o7hP视频属性的抓取
# BV号为1ZV411o7hP的视频属性抓取结束
# 开始BV号为1o54y1R7b6视频属性的抓取
# BV号为1o54y1R7b6的视频属性抓取结束
# 开始BV号为1Ck4y1R74w视频属性的抓取
# BV号为1Ck4y1R74w的视频属性抓取结束
# 开始BV号为1ok4y1d7br视频属性的抓取
# BV号为1ok4y1d7br的视频属性抓取结束
# 开始BV号为1nZ4y1x7Em视频属性的抓取
# BV号为1nZ4y1x7Em的视频属性抓取结束
# 开始BV号为1pV411d75M视频属性的抓取
# BV号为1pV411d75M的视频属性抓取结束
# 开始BV号为1g54y197DZ视频属性的抓取
# BV号为1g54y197DZ的视频属性抓取结束
# 开始BV号为1C54y1Q7SK视频属性的抓取
# BV号为1C54y1Q7SK的视频属性抓取结束
# 开始BV号为16k4y1R7Ma视频属性的抓取
# BV号为16k4y1R7Ma的视频属性抓取结束
# 开始BV号为17t4y1U7ps视频属性的抓取
# BV号为17t4y1U7ps的视频属性抓取结束
# 开始BV号为1y64y1T7Ys视频属性的抓取
# BV号为1y64y1T7Ys的视频属性抓取结束
# 开始BV号为1KQ4y1N7dg视频属性的抓取
# BV号为1KQ4y1N7dg的视频属性抓取结束
# 开始BV号为1Ez411b7au视频属性的抓取
# BV号为1Ez411b7au的视频属性抓取结束
# 开始BV号为1Mt4y1m7U3视频属性的抓取
# BV号为1Mt4y1m7U3的视频属性抓取结束
# 开始BV号为15z411b7gR视频属性的抓取
# BV号为15z411b7gR的视频属性抓取结束
# 开始BV号为1BC4y1s72y视频属性的抓取
# BV号为1BC4y1s72y的视频属性抓取结束
# 开始BV号为1Cf4y1S7mj视频属性的抓取
# BV号为1Cf4y1S7mj的视频属性抓取结束
# 开始BV号为1u54y197L9视频属性的抓取
# BV号为1u54y197L9的视频属性抓取结束
# 开始BV号为14p4y117Jr视频属性的抓取
# BV号为14p4y117Jr的视频属性抓取结束
# 开始BV号为1Gi4y1t7ha视频属性的抓取
# BV号为1Gi4y1t7ha的视频属性抓取结束
# 开始BV号为1Xf4y1U7D3视频属性的抓取
# BV号为1Xf4y1U7D3的视频属性抓取结束
# 开始BV号为1pQ4y1T7TS视频属性的抓取
# BV号为1pQ4y1T7TS的视频属性抓取结束
# 开始BV号为1GQ4y1M7ih视频属性的抓取
# BV号为1GQ4y1M7ih的视频属性抓取结束
# 开始BV号为19g4y1b7nJ视频属性的抓取
# BV号为19g4y1b7nJ的视频属性抓取结束
# 开始BV号为1t64y1u7ug视频属性的抓取
# BV号为1t64y1u7ug的视频属性抓取结束
# 开始BV号为1MZ4y1x7xU视频属性的抓取
# BV号为1MZ4y1x7xU的视频属性抓取结束
# 开始BV号为1nt4y127v4视频属性的抓取
# BV号为1nt4y127v4的视频属性抓取结束
# 开始BV号为1Sf4y1S7xM视频属性的抓取
# BV号为1Sf4y1S7xM的视频属性抓取结束
# 开始BV号为14A411b7Kb视频属性的抓取
# BV号为14A411b7Kb的视频属性抓取结束
# 开始BV号为1Ei4y1878v视频属性的抓取
# BV号为1Ei4y1878v的视频属性抓取结束
# 开始BV号为1fi4y1t7EF视频属性的抓取
# BV号为1fi4y1t7EF的视频属性抓取结束
# 开始BV号为1fk4y1978y视频属性的抓取
# BV号为1fk4y1978y的视频属性抓取结束
# 开始BV号为1V64y1M7ot视频属性的抓取
# BV号为1V64y1M7ot的视频属性抓取结束
# 开始BV号为1MA411b7ek视频属性的抓取
# BV号为1MA411b7ek的视频属性抓取结束
# 开始BV号为1fT4y1G7ML视频属性的抓取
# BV号为1fT4y1G7ML的视频属性抓取结束
# 开始BV号为1WA411b7Cc视频属性的抓取
# BV号为1WA411b7Cc的视频属性抓取结束
# 开始BV号为1Cf4y1U7L5视频属性的抓取
# BV号为1Cf4y1U7L5的视频属性抓取结束
# 开始BV号为1iT4y1G71j视频属性的抓取
# BV号为1iT4y1G71j的视频属性抓取结束
# 开始BV号为1EV411d7JD视频属性的抓取
# BV号为1EV411d7JD的视频属性抓取结束
# 开始BV号为1uz41187nE视频属性的抓取
# BV号为1uz41187nE的视频属性抓取结束
# 开始BV号为1PK4y1k7Z2视频属性的抓取
# BV号为1PK4y1k7Z2的视频属性抓取结束
# 开始BV号为1xQ4y1K77Y视频属性的抓取
# BV号为1xQ4y1K77Y的视频属性抓取结束
# 开始BV号为1Lp4y1y7dj视频属性的抓取
# BV号为1Lp4y1y7dj的视频属性抓取结束
# 开始BV号为1uZ4y1x7HV视频属性的抓取
# BV号为1uZ4y1x7HV的视频属性抓取结束
# 开始BV号为1up4y1y7Zb视频属性的抓取
# BV号为1up4y1y7Zb的视频属性抓取结束
# 开始BV号为1NC4y1x72z视频属性的抓取
# BV号为1NC4y1x72z的视频属性抓取结束
# 开始BV号为13e411s7MR视频属性的抓取
# BV号为13e411s7MR的视频属性抓取结束
# 开始BV号为1ng4y1z7VW视频属性的抓取
# BV号为1ng4y1z7VW的视频属性抓取结束
# 开始BV号为1ce411s7CB视频属性的抓取
# BV号为1ce411s7CB的视频属性抓取结束
# 开始BV号为1xK411L7NY视频属性的抓取
# BV号为1xK411L7NY的视频属性抓取结束
# 开始BV号为1854y197b5视频属性的抓取
# BV号为1854y197b5的视频属性抓取结束
# 开始BV号为1qA411b79z视频属性的抓取
# BV号为1qA411b79z的视频属性抓取结束
# 开始BV号为1PZ4y1x7ra视频属性的抓取
# BV号为1PZ4y1x7ra的视频属性抓取结束
# 开始BV号为1La4y1t7QR视频属性的抓取
# BV号为1La4y1t7QR的视频属性抓取结束
# 开始BV号为1wg4y167yH视频属性的抓取
# BV号为1wg4y167yH的视频属性抓取结束
# 开始BV号为1up4y197Ac视频属性的抓取
# BV号为1up4y197Ac的视频属性抓取结束
# 开始BV号为1Vf4y1S7Rh视频属性的抓取
# BV号为1Vf4y1S7Rh的视频属性抓取结束
# 开始BV号为16K41157xc视频属性的抓取
# BV号为16K41157xc的视频属性抓取结束
# 开始BV号为1z54y1Q7Gk视频属性的抓取
# BV号为1z54y1Q7Gk的视频属性抓取结束
# 开始BV号为1ba4y147c3视频属性的抓取
# BV号为1ba4y147c3的视频属性抓取结束
# 开始BV号为1554y197oU视频属性的抓取
# BV号为1554y197oU的视频属性抓取结束
# 开始BV号为12z411B7wE视频属性的抓取
# BV号为12z411B7wE的视频属性抓取结束
# 开始BV号为1rC4y1s7bJ视频属性的抓取
# BV号为1rC4y1s7bJ的视频属性抓取结束
# 开始BV号为1Kp4y1y7qw视频属性的抓取
# BV号为1Kp4y1y7qw的视频属性抓取结束
# 开始BV号为1Qe411W7Wx视频属性的抓取
# BV号为1Qe411W7Wx的视频属性抓取结束
# 开始BV号为1wk4y1k7Lc视频属性的抓取
# BV号为1wk4y1k7Lc的视频属性抓取结束
# 开始BV号为1NQ4y1N7Lg视频属性的抓取
# BV号为1NQ4y1N7Lg的视频属性抓取结束
# 开始BV号为1sK41157gg视频属性的抓取
# BV号为1sK41157gg的视频属性抓取结束
# 开始BV号为1Z5411x7yU视频属性的抓取
# BV号为1Z5411x7yU的视频属性抓取结束
# 开始BV号为1vp4y1C76k视频属性的抓取
# BV号为1vp4y1C76k的视频属性抓取结束
# 开始BV号为1mc411h74k视频属性的抓取
# BV号为1mc411h74k的视频属性抓取结束
# 开始BV号为1Ya4y1x7bd视频属性的抓取
# BV号为1Ya4y1x7bd的视频属性抓取结束
# 开始BV号为14K411L76U视频属性的抓取
# BV号为14K411L76U的视频属性抓取结束
# 开始BV号为1et4y12782视频属性的抓取
# BV号为1et4y12782的视频属性抓取结束
# 开始BV号为1mQ4y1M7z1视频属性的抓取
# BV号为1mQ4y1M7z1的视频属性抓取结束
# 开始BV号为1MQ4y1M7YS视频属性的抓取
# BV号为1MQ4y1M7YS的视频属性抓取结束
# 开始BV号为1Qt4y127Jn视频属性的抓取
# BV号为1Qt4y127Jn的视频属性抓取结束
# 开始BV号为1Vt4y1U7uM视频属性的抓取
# BV号为1Vt4y1U7uM的视频属性抓取结束
# 开始BV号为1bt4y1U7i6视频属性的抓取
# BV号为1bt4y1U7i6的视频属性抓取结束
# 开始BV号为17t4y127dh视频属性的抓取
# BV号为17t4y127dh的视频属性抓取结束
# 开始BV号为1SK4115767视频属性的抓取
# BV号为1SK4115767的视频属性抓取结束
# 开始BV号为1ZV411d7EJ视频属性的抓取
# BV号为1ZV411d7EJ的视频属性抓取结束
# 开始BV号为1FZ4y1s71C视频属性的抓取
# BV号为1FZ4y1s71C的视频属性抓取结束
# 开始BV号为1NK4y187fx视频属性的抓取
# BV号为1NK4y187fx的视频属性抓取结束
# 开始BV号为12K4y1b7ak视频属性的抓取
# BV号为12K4y1b7ak的视频属性抓取结束
# 开始BV号为1qt4y1C7DK视频属性的抓取
# BV号为1qt4y1C7DK的视频属性抓取结束
# 开始BV号为1FK411L7Yz视频属性的抓取
# BV号为1FK411L7Yz的视频属性抓取结束
# 开始BV号为1EC4y1p7Wr视频属性的抓取
# BV号为1EC4y1p7Wr的视频属性抓取结束
# 开始BV号为1Yg4y1B7G7视频属性的抓取
# BV号为1Yg4y1B7G7的视频属性抓取结束
# 开始BV号为155411x7GL视频属性的抓取
# BV号为155411x7GL的视频属性抓取结束
# 开始BV号为1LC4y1p7LY视频属性的抓取
# BV号为1LC4y1p7LY的视频属性抓取结束
# 开始BV号为1p5411s7fF视频属性的抓取
# BV号为1p5411s7fF的视频属性抓取结束
# 开始BV号为135411475W视频属性的抓取
# BV号为135411475W的视频属性抓取结束
# 开始BV号为12T4y137Ke视频属性的抓取
# BV号为12T4y137Ke的视频属性抓取结束
# 开始BV号为1di4y1t7g9视频属性的抓取
# BV号为1di4y1t7g9的视频属性抓取结束
# 开始BV号为1mk4y167iW视频属性的抓取
# BV号为1mk4y167iW的视频属性抓取结束
# 开始BV号为1nT4y1g7gu视频属性的抓取
# BV号为1nT4y1g7gu的视频属性抓取结束
# 开始BV号为1XK4y147yD视频属性的抓取
# BV号为1XK4y147yD的视频属性抓取结束
# 开始BV号为1Lp4y1X7hR视频属性的抓取
# BV号为1Lp4y1X7hR的视频属性抓取结束
# 开始BV号为1L5411s7tR视频属性的抓取
# BV号为1L5411s7tR的视频属性抓取结束
# 开始BV号为1tz4y1R7Px视频属性的抓取
# BV号为1tz4y1R7Px的视频属性抓取结束
# 开始BV号为1oV411C7cx视频属性的抓取
# BV号为1oV411C7cx的视频属性抓取结束
# 开始BV号为1Wg4y1i7Gs视频属性的抓取
# BV号为1Wg4y1i7Gs的视频属性抓取结束
# 开始BV号为1b5411s7fu视频属性的抓取
# BV号为1b5411s7fu的视频属性抓取结束
# 开始BV号为1UQ4y1N7SH视频属性的抓取
# BV号为1UQ4y1N7SH的视频属性抓取结束
# 开始BV号为1tT4y1u7So视频属性的抓取
# BV号为1tT4y1u7So的视频属性抓取结束
# 开始BV号为1Hk4y1k7PA视频属性的抓取
# BV号为1Hk4y1k7PA的视频属性抓取结束
# 开始BV号为1de411s7CV视频属性的抓取
# BV号为1de411s7CV的视频属性抓取结束
# 开始BV号为1dz4y1R7eQ视频属性的抓取
# BV号为1dz4y1R7eQ的视频属性抓取结束
# 开始BV号为1a54y1X7zL视频属性的抓取
# BV号为1a54y1X7zL的视频属性抓取结束
# 开始BV号为1n54y1X7Ah视频属性的抓取
# BV号为1n54y1X7Ah的视频属性抓取结束
# 开始BV号为1nK4y1t7Fw视频属性的抓取
# BV号为1nK4y1t7Fw的视频属性抓取结束
# 开始BV号为1uk4y167wE视频属性的抓取
# BV号为1uk4y167wE的视频属性抓取结束
# 开始BV号为1Ea4y1e7Gj视频属性的抓取
# BV号为1Ea4y1e7Gj的视频属性抓取结束
# 开始BV号为16i4y147WN视频属性的抓取
# BV号为16i4y147WN的视频属性抓取结束
# 开始BV号为1Bp4y197rQ视频属性的抓取
# BV号为1Bp4y197rQ的视频属性抓取结束
# 开始BV号为1Dt4y117hq视频属性的抓取
# BV号为1Dt4y117hq的视频属性抓取结束
# 开始BV号为1Rt4y1y7o6视频属性的抓取
# BV号为1Rt4y1y7o6的视频属性抓取结束
# 开始BV号为1zg4y1z7Lh视频属性的抓取
# BV号为1zg4y1z7Lh的视频属性抓取结束
# 开始BV号为14z411z7jQ视频属性的抓取
# BV号为14z411z7jQ的视频属性抓取结束
# 开始BV号为1Pz4y197Gj视频属性的抓取
# BV号为1Pz4y197Gj的视频属性抓取结束
# 开始BV号为1Mz4y1d7E2视频属性的抓取
# BV号为1Mz4y1d7E2的视频属性抓取结束
# 开始BV号为1se411W7R3视频属性的抓取
# BV号为1se411W7R3的视频属性抓取结束
# 开始BV号为1HK4y187hD视频属性的抓取
# BV号为1HK4y187hD的视频属性抓取结束
# 开始BV号为1QZ4y1p7Z3视频属性的抓取
# BV号为1QZ4y1p7Z3的视频属性抓取结束
# 开始BV号为1n54y1D7yW视频属性的抓取
# BV号为1n54y1D7yW的视频属性抓取结束
# 开始BV号为1sk4y167wh视频属性的抓取
# BV号为1sk4y167wh的视频属性抓取结束
# 开始BV号为1854y1D7TJ视频属性的抓取
# BV号为1854y1D7TJ的视频属性抓取结束
# 开始BV号为18K4y1t7gJ视频属性的抓取
# BV号为18K4y1t7gJ的视频属性抓取结束
# 开始BV号为1Rk4y167ib视频属性的抓取
# BV号为1Rk4y167ib的视频属性抓取结束
# 开始BV号为1Wv411z7wB视频属性的抓取
# BV号为1Wv411z7wB的视频属性抓取结束
# 开始BV号为1ni4y1b7oC视频属性的抓取
# BV号为1ni4y1b7oC的视频属性抓取结束
# 开始BV号为1cV411C7So视频属性的抓取
# BV号为1cV411C7So的视频属性抓取结束
# 开始BV号为1pf4y127Fy视频属性的抓取
# BV号为1pf4y127Fy的视频属性抓取结束
# 开始BV号为1ie411W7Rb视频属性的抓取
# BV号为1ie411W7Rb的视频属性抓取结束
# 开始BV号为1bf4y1U7kZ视频属性的抓取
# BV号为1bf4y1U7kZ的视频属性抓取结束
# 开始BV号为1jT4y1u7ep视频属性的抓取
# BV号为1jT4y1u7ep的视频属性抓取结束
# 开始BV号为13a4y1i7vA视频属性的抓取
# BV号为13a4y1i7vA的视频属性抓取结束
# 开始BV号为1zz411q7pp视频属性的抓取
# BV号为1zz411q7pp的视频属性抓取结束
# 开始BV号为1iV411d7ay视频属性的抓取
# BV号为1iV411d7ay的视频属性抓取结束
# 开始BV号为1iK411W787视频属性的抓取
# BV号为1iK411W787的视频属性抓取结束
# 开始BV号为1N54y1Q7E4视频属性的抓取
# BV号为1N54y1Q7E4的视频属性抓取结束
# 开始BV号为1Mg4y167au视频属性的抓取
# BV号为1Mg4y167au的视频属性抓取结束
# 开始BV号为1SZ4y1s7KC视频属性的抓取
# BV号为1SZ4y1s7KC的视频属性抓取结束
# 开始BV号为1P5411x78z视频属性的抓取
# BV号为1P5411x78z的视频属性抓取结束
# 开始BV号为1SQ4y1N79E视频属性的抓取
# BV号为1SQ4y1N79E的视频属性抓取结束
# 开始BV号为15p4y1X7r3视频属性的抓取
# BV号为15p4y1X7r3的视频属性抓取结束
# 开始BV号为1Ra4y1e74a视频属性的抓取
# BV号为1Ra4y1e74a的视频属性抓取结束
# 开始BV号为1gZ4y147yU视频属性的抓取
# BV号为1gZ4y147yU的视频属性抓取结束
# 开始BV号为1xV411C75F视频属性的抓取
# BV号为1xV411C75F的视频属性抓取结束
# 开始BV号为175411x7ZE视频属性的抓取
# BV号为175411x7ZE的视频属性抓取结束
# 开始BV号为1j5411x7Rn视频属性的抓取
# BV号为1j5411x7Rn的视频属性抓取结束
# 开始BV号为13T4y1g7p4视频属性的抓取
# BV号为13T4y1g7p4的视频属性抓取结束
# 开始BV号为1U54y1X7bB视频属性的抓取
# BV号为1U54y1X7bB的视频属性抓取结束
# 开始BV号为1b541147WM视频属性的抓取
# BV号为1b541147WM的视频属性抓取结束
# 开始BV号为1Hi4y147yK视频属性的抓取
# BV号为1Hi4y147yK的视频属性抓取结束
# 开始BV号为1Tf4y127a2视频属性的抓取
# BV号为1Tf4y127a2的视频属性抓取结束
# 开始BV号为18A411t7ye视频属性的抓取
# BV号为18A411t7ye的视频属性抓取结束
# 开始BV号为19K4y1b7or视频属性的抓取
# BV号为19K4y1b7or的视频属性抓取结束
# 开始BV号为1rz411v712视频属性的抓取
# BV号为1rz411v712的视频属性抓取结束
# 开始BV号为1hA411t7rV视频属性的抓取
# BV号为1hA411t7rV的视频属性抓取结束
# 开始BV号为1CC4y1H7Kh视频属性的抓取
# BV号为1CC4y1H7Kh的视频属性抓取结束
# 开始BV号为1tK411W7B5视频属性的抓取
# BV号为1tK411W7B5的视频属性抓取结束
# 开始BV号为1wK411p7dJ视频属性的抓取
# BV号为1wK411p7dJ的视频属性抓取结束
# 开始BV号为1tZ4y1s7KF视频属性的抓取
# BV号为1tZ4y1s7KF的视频属性抓取结束
# 开始BV号为15g4y1B7hz视频属性的抓取
# BV号为15g4y1B7hz的视频属性抓取结束
# 开始BV号为1GZ4y1s7V7视频属性的抓取
# BV号为1GZ4y1s7V7的视频属性抓取结束
# 开始BV号为1Wp4y1Q715视频属性的抓取
# BV号为1Wp4y1Q715的视频属性抓取结束
# 开始BV号为1mK411H7bx视频属性的抓取
# BV号为1mK411H7bx的视频属性抓取结束
# 开始BV号为1K54y1X7Am视频属性的抓取
# BV号为1K54y1X7Am的视频属性抓取结束
# 开始BV号为1pk4y1r71B视频属性的抓取
# BV号为1pk4y1r71B的视频属性抓取结束
# 开始BV号为1Tk4y167KB视频属性的抓取
# BV号为1Tk4y167KB的视频属性抓取结束
# 开始BV号为1J54y1X7WB视频属性的抓取
# BV号为1J54y1X7WB的视频属性抓取结束
# 开始BV号为1Uf4y1m7LK视频属性的抓取
# BV号为1Uf4y1m7LK的视频属性抓取结束
# 开始BV号为1fK4y1t7bc视频属性的抓取
# BV号为1fK4y1t7bc的视频属性抓取结束
# 开始BV号为1uk4y1k7co视频属性的抓取
# BV号为1uk4y1k7co的视频属性抓取结束
# 开始BV号为1Dz411v7bU视频属性的抓取
# BV号为1Dz411v7bU的视频属性抓取结束
# 开始BV号为1Ff4y127ed视频属性的抓取
# BV号为1Ff4y127ed的视频属性抓取结束
# 开始BV号为1op4y1D7dJ视频属性的抓取
# BV号为1op4y1D7dJ的视频属性抓取结束
# 开始BV号为1Mt4y197oQ视频属性的抓取
# BV号为1Mt4y197oQ的视频属性抓取结束
# 开始BV号为1ZC4y1a7hD视频属性的抓取
# BV号为1ZC4y1a7hD的视频属性抓取结束
# 开始BV号为1n54y1Q76G视频属性的抓取
# BV号为1n54y1Q76G的视频属性抓取结束
# 开始BV号为1DT4y1J7vA视频属性的抓取
# BV号为1DT4y1J7vA的视频属性抓取结束
# 开始BV号为1Cz411e7qD视频属性的抓取
# BV号为1Cz411e7qD的视频属性抓取结束
# 开始BV号为1754y1z7Rb视频属性的抓取
# 开始BV号为1754y1z7Rb视频属性的抓取
# BV号为1754y1z7Rb的视频属性抓取结束
# 开始BV号为1zz411i7Gg视频属性的抓取
# BV号为1zz411i7Gg的视频属性抓取结束
# 开始BV号为1mK4y1x7TU视频属性的抓取
# BV号为1mK4y1x7TU的视频属性抓取结束
# 开始BV号为1Zv411z7zC视频属性的抓取
# BV号为1Zv411z7zC的视频属性抓取结束
# 开始BV号为1jz411i7B9视频属性的抓取
# BV号为1jz411i7B9的视频属性抓取结束
# 开始BV号为1ha4y1Y7g7视频属性的抓取
# BV号为1ha4y1Y7g7的视频属性抓取结束
# 开始BV号为1x5411W7eZ视频属性的抓取
# BV号为1x5411W7eZ的视频属性抓取结束
# 开始BV号为1iz411e7TW视频属性的抓取
# BV号为1iz411e7TW的视频属性抓取结束
# 开始BV号为1Rt4y1X79C视频属性的抓取
# BV号为1Rt4y1X79C的视频属性抓取结束
# 开始BV号为1iK4y147yv视频属性的抓取
# BV号为1iK4y147yv的视频属性抓取结束
# 开始BV号为1ri4y1s7b7视频属性的抓取
# BV号为1ri4y1s7b7的视频属性抓取结束
# 开始BV号为1pi4y1G7xQ视频属性的抓取
# BV号为1pi4y1G7xQ的视频属性抓取结束
# 开始BV号为1PC4y1h7jr视频属性的抓取
# BV号为1PC4y1h7jr的视频属性抓取结束
# 开始BV号为1Bz4y19718视频属性的抓取
# BV号为1Bz4y19718的视频属性抓取结束
# 开始BV号为1ot4y1X7Wo视频属性的抓取
# BV号为1ot4y1X7Wo的视频属性抓取结束
# 开始BV号为1cK4y1b732视频属性的抓取
# BV号为1cK4y1b732的视频属性抓取结束
# 开始BV号为1gt4y1y7Ja视频属性的抓取
# BV号为1gt4y1y7Ja的视频属性抓取结束
# 开始BV号为1eD4y1D7Zm视频属性的抓取
# BV号为1eD4y1D7Zm的视频属性抓取结束
# 开始BV号为1VA411i7wK视频属性的抓取
# BV号为1VA411i7wK的视频属性抓取结束
# 开始BV号为1kK411p768视频属性的抓取
# BV号为1kK411p768的视频属性抓取结束
# 开始BV号为1f54y1B7XU视频属性的抓取
# BV号为1f54y1B7XU的视频属性抓取结束
# 开始BV号为1zz411e7yn视频属性的抓取
# BV号为1zz411e7yn的视频属性抓取结束
# 开始BV号为12A411v7fs视频属性的抓取
# BV号为12A411v7fs的视频属性抓取结束
# 开始BV号为1vt4y1y7LB视频属性的抓取
# BV号为1vt4y1y7LB的视频属性抓取结束
# 开始BV号为1yz4y197DR视频属性的抓取
# BV号为1yz4y197DR的视频属性抓取结束
# 开始BV号为1SC4y1a7L4视频属性的抓取
# BV号为1SC4y1a7L4的视频属性抓取结束
# 开始BV号为19Z4y1H7sz视频属性的抓取
# BV号为19Z4y1H7sz的视频属性抓取结束
# 开始BV号为12C4y1a7ej视频属性的抓取
# BV号为12C4y1a7ej的视频属性抓取结束
# 开始BV号为1Af4y1m7Ee视频属性的抓取
# BV号为1Af4y1m7Ee的视频属性抓取结束
# 开始BV号为1jV41167Xx视频属性的抓取
# BV号为1jV41167Xx的视频属性抓取结束
# 开始BV号为1N54y1Q7oH视频属性的抓取
# BV号为1N54y1Q7oH的视频属性抓取结束
# 开始BV号为1bk4y1z7z9视频属性的抓取
# BV号为1bk4y1z7z9的视频属性抓取结束
# 开始BV号为1wV41167Gf视频属性的抓取
# BV号为1wV41167Gf的视频属性抓取结束
# 开始BV号为1GV411C7bh视频属性的抓取
# BV号为1GV411C7bh的视频属性抓取结束
# 开始BV号为12T4y1E7EX视频属性的抓取
# BV号为12T4y1E7EX的视频属性抓取结束
# 开始BV号为1jk4y1z73U视频属性的抓取
# BV号为1jk4y1z73U的视频属性抓取结束
# 开始BV号为1654y1B77q视频属性的抓取
# BV号为1654y1B77q的视频属性抓取结束
# 开始BV号为1tz411e7sY视频属性的抓取
# BV号为1tz411e7sY的视频属性抓取结束
# 开始BV号为1ND4y1Q7ks视频属性的抓取
# BV号为1ND4y1Q7ks的视频属性抓取结束
# 开始BV号为1pV411k7fJ视频属性的抓取
# BV号为1pV411k7fJ的视频属性抓取结束
# 开始BV号为1jt4y1y7y6视频属性的抓取
# BV号为1jt4y1y7y6的视频属性抓取结束
# 开始BV号为1Xz4y1Q74b视频属性的抓取
# BV号为1Xz4y1Q74b的视频属性抓取结束
# 开始BV号为1St4y197c3视频属性的抓取
# BV号为1St4y197c3的视频属性抓取结束
# 开始BV号为1Dz4y1Q7B8视频属性的抓取
# BV号为1Dz4y1Q7B8的视频属性抓取结束
# 开始BV号为1CA411v76Q视频属性的抓取
# BV号为1CA411v76Q的视频属性抓取结束
# 开始BV号为1oC4y187U6视频属性的抓取
# BV号为1oC4y187U6的视频属性抓取结束
# 开始BV号为1zT4y1E7Nt视频属性的抓取
# BV号为1zT4y1E7Nt的视频属性抓取结束
# 开始BV号为1Bz411i7bx视频属性的抓取
# BV号为1Bz411i7bx的视频属性抓取结束
# 开始BV号为1rK411n7v7视频属性的抓取
# BV号为1rK411n7v7的视频属性抓取结束
# 开始BV号为18k4y1z7zi视频属性的抓取
# BV号为18k4y1z7zi的视频属性抓取结束
# 开始BV号为1Xk4y1B7i5视频属性的抓取
# BV号为1Xk4y1B7i5的视频属性抓取结束
# 开始BV号为1Dz411i7io视频属性的抓取
# BV号为1Dz411i7io的视频属性抓取结束
# 开始BV号为1Az4y1X7P8视频属性的抓取
# BV号为1Az4y1X7P8的视频属性抓取结束
# 开始BV号为1tp4y1D7A9视频属性的抓取
# BV号为1tp4y1D7A9的视频属性抓取结束
# 开始BV号为1eA411v76C视频属性的抓取
# BV号为1eA411v76C的视频属性抓取结束
# 开始BV号为1J5411Y7Zk视频属性的抓取
# BV号为1J5411Y7Zk的视频属性抓取结束
# 开始BV号为1cK411p7WH视频属性的抓取
# BV号为1cK411p7WH的视频属性抓取结束
# 开始BV号为13z4y1X7R9视频属性的抓取
# BV号为13z4y1X7R9的视频属性抓取结束
# 开始BV号为16Z4y1H7W8视频属性的抓取
# BV号为16Z4y1H7W8的视频属性抓取结束
# 开始BV号为1zA411v7Dh视频属性的抓取
# BV号为1zA411v7Dh的视频属性抓取结束
# 开始BV号为1fK411n7tw视频属性的抓取
# BV号为1fK411n7tw的视频属性抓取结束
# 开始BV号为1zg4y1i7Ba视频属性的抓取
# BV号为1zg4y1i7Ba的视频属性抓取结束
# 开始BV号为1wD4y1S7wz视频属性的抓取
# BV号为1wD4y1S7wz的视频属性抓取结束
# 开始BV号为1hz411e7cE视频属性的抓取
# BV号为1hz411e7cE的视频属性抓取结束
# 开始BV号为19V411r7ZT视频属性的抓取
# BV号为19V411r7ZT的视频属性抓取结束
# 开始BV号为1Bz4y1Q7kB视频属性的抓取
# BV号为1Bz4y1Q7kB的视频属性抓取结束
# 开始BV号为1zg4y1i72a视频属性的抓取
# BV号为1zg4y1i72a的视频属性抓取结束
# 开始BV号为16C4y1a7rA视频属性的抓取
# BV号为16C4y1a7rA的视频属性抓取结束
# 开始BV号为1aV411r74U视频属性的抓取
# BV号为1aV411r74U的视频属性抓取结束
# 开始BV号为1NT4y1J7th视频属性的抓取
# BV号为1NT4y1J7th的视频属性抓取结束
# 开始BV号为1Vv41167TB视频属性的抓取
# BV号为1Vv41167TB的视频属性抓取结束
# 开始BV号为1Ut4y1X756视频属性的抓取
# BV号为1Ut4y1X756的视频属性抓取结束
# 开始BV号为1mz411i7dz视频属性的抓取
# BV号为1mz411i7dz的视频属性抓取结束
# 开始BV号为1rg4y1i7yx视频属性的抓取
# BV号为1rg4y1i7yx的视频属性抓取结束
# 开始BV号为1dg4y1i7nZ视频属性的抓取
# BV号为1dg4y1i7nZ的视频属性抓取结束
# 开始BV号为1DK411n7er视频属性的抓取
# BV号为1DK411n7er的视频属性抓取结束
# 开始BV号为1bi4y1G7ay视频属性的抓取
# BV号为1bi4y1G7ay的视频属性抓取结束
# 开始BV号为1E54y1B7qv视频属性的抓取
# BV号为1E54y1B7qv的视频属性抓取结束
# 开始BV号为1oK411p7uB视频属性的抓取
# BV号为1oK411p7uB的视频属性抓取结束
# 开始BV号为1ZC4y1h74d视频属性的抓取
# BV号为1ZC4y1h74d的视频属性抓取结束
# 开始BV号为1ZK4y1x76i视频属性的抓取
# BV号为1ZK4y1x76i的视频属性抓取结束
# 开始BV号为1Ev411B7Vx视频属性的抓取
# BV号为1Ev411B7Vx的视频属性抓取结束
# 开始BV号为1wp4y1S7oP视频属性的抓取
# 开始BV号为1wp4y1S7oP视频属性的抓取
# BV号为1wp4y1S7oP的视频属性抓取结束
# 开始BV号为1eA411v7mm视频属性的抓取
# BV号为1eA411v7mm的视频属性抓取结束
# 开始BV号为1Kf4y117me视频属性的抓取
# BV号为1Kf4y117me的视频属性抓取结束
# 开始BV号为1St4y1X7Ch视频属性的抓取
# BV号为1St4y1X7Ch的视频属性抓取结束
# 开始BV号为1eK411n7QZ视频属性的抓取
# BV号为1eK411n7QZ的视频属性抓取结束
# 开始BV号为1bA411i7Hk视频属性的抓取
# BV号为1bA411i7Hk的视频属性抓取结束
# 开始BV号为1Ka4y1Y7ww视频属性的抓取
# BV号为1Ka4y1Y7ww的视频属性抓取结束
# 开始BV号为1Q54y1i7Z2视频属性的抓取
# BV号为1Q54y1i7Z2的视频属性抓取结束
# 开始BV号为1gK4y147qt视频属性的抓取
# BV号为1gK4y147qt的视频属性抓取结束
# 开始BV号为1ht4y1y7eo视频属性的抓取
# BV号为1ht4y1y7eo的视频属性抓取结束
# 开始BV号为1sz411i7YF视频属性的抓取
# BV号为1sz411i7YF的视频属性抓取结束
# 开始BV号为12D4y1D7pD视频属性的抓取
# BV号为12D4y1D7pD的视频属性抓取结束
# 开始BV号为1HC4y1b7d4视频属性的抓取
# BV号为1HC4y1b7d4的视频属性抓取结束
# 开始BV号为19a4y1Y7wW视频属性的抓取
# BV号为19a4y1Y7wW的视频属性抓取结束
# 开始BV号为17C4y1h73n视频属性的抓取
# BV号为17C4y1h73n的视频属性抓取结束
# 开始BV号为1bD4y1S71H视频属性的抓取
# BV号为1bD4y1S71H的视频属性抓取结束
# 开始BV号为1ji4y137Ex视频属性的抓取
# BV号为1ji4y137Ex的视频属性抓取结束
# 开始BV号为1ga4y1J7sT视频属性的抓取
# BV号为1ga4y1J7sT的视频属性抓取结束
# 开始BV号为1sh411Z7xs视频属性的抓取
# BV号为1sh411Z7xs的视频属性抓取结束
# 开始BV号为1S5411h7DU视频属性的抓取
# BV号为1S5411h7DU的视频属性抓取结束
# 开始BV号为1zf4y117dN视频属性的抓取
# BV号为1zf4y117dN的视频属性抓取结束
# 开始BV号为1zz4y1D7Vi视频属性的抓取
# BV号为1zz4y1D7Vi的视频属性抓取结束
# 开始BV号为1Pf4y1d7G8视频属性的抓取
# BV号为1Pf4y1d7G8的视频属性抓取结束
# 开始BV号为1uD4y1D7q1视频属性的抓取
# BV号为1uD4y1D7q1的视频属性抓取结束
# 开始BV号为1ba4y1a7HB视频属性的抓取
# BV号为1ba4y1a7HB的视频属性抓取结束
# 开始BV号为1LT4y1E7ET视频属性的抓取
# BV号为1LT4y1E7ET的视频属性抓取结束
# 开始BV号为13z4y1X7n9视频属性的抓取
# BV号为13z4y1X7n9的视频属性抓取结束
# 开始BV号为1bp4y1i77W视频属性的抓取
# BV号为1bp4y1i77W的视频属性抓取结束
# 开始BV号为16t4y1Q7HJ视频属性的抓取
# BV号为16t4y1Q7HJ的视频属性抓取结束
# 开始BV号为1ji4y137Zc视频属性的抓取
# BV号为1ji4y137Zc的视频属性抓取结束
# 开始BV号为1eV411k756视频属性的抓取
# BV号为1eV411k756的视频属性抓取结束
# 开始BV号为1Zv411i7AS视频属性的抓取
# BV号为1Zv411i7AS的视频属性抓取结束
# 开始BV号为1Ft4y1X7HJ视频属性的抓取
# BV号为1Ft4y1X7HJ的视频属性抓取结束
# 开始BV号为1wa4y1J7S7视频属性的抓取
# BV号为1wa4y1J7S7的视频属性抓取结束
# 开始BV号为1xD4y1Q7uu视频属性的抓取
# BV号为1xD4y1Q7uu的视频属性抓取结束
# 开始BV号为1ZT4y177xg视频属性的抓取
# BV号为1ZT4y177xg的视频属性抓取结束
# 开始BV号为1ui4y1V7wF视频属性的抓取
# BV号为1ui4y1V7wF的视频属性抓取结束
# 开始BV号为1o5411h7wh视频属性的抓取
# 开始BV号为1o5411h7wh视频属性的抓取
# BV号为1o5411h7wh的视频属性抓取结束
# 开始BV号为1xt4y1Q7bp视频属性的抓取
# BV号为1xt4y1Q7bp的视频属性抓取结束
# 开始BV号为1zi4y1G7Q1视频属性的抓取
# BV号为1zi4y1G7Q1的视频属性抓取结束
# 开始BV号为1Jf4y1R7pF视频属性的抓取
# BV号为1Jf4y1R7pF的视频属性抓取结束
# 开始BV号为1Kt4y1X76r视频属性的抓取
# BV号为1Kt4y1X76r的视频属性抓取结束
# 开始BV号为1jv411q7Zu视频属性的抓取
# BV号为1jv411q7Zu的视频属性抓取结束
# 开始BV号为1ZZ4y1u7t8视频属性的抓取
# BV号为1ZZ4y1u7t8的视频属性抓取结束
# 开始BV号为1ep4y1i7ie视频属性的抓取
# BV号为1ep4y1i7ie的视频属性抓取结束
# 开始BV号为1754y1q7YZ视频属性的抓取
# BV号为1754y1q7YZ的视频属性抓取结束
# 开始BV号为1fT4y1775w视频属性的抓取
# BV号为1fT4y1775w的视频属性抓取结束
# 开始BV号为1JV411r7e4视频属性的抓取
# BV号为1JV411r7e4的视频属性抓取结束
# 开始BV号为1Q54y1S7wi视频属性的抓取
# BV号为1Q54y1S7wi的视频属性抓取结束
# 开始BV号为1u54y1z7oc视频属性的抓取
# BV号为1u54y1z7oc的视频属性抓取结束
# 开始BV号为1T54y1S71n视频属性的抓取
# BV号为1T54y1S71n的视频属性抓取结束
# 开始BV号为1fT4y1L7hk视频属性的抓取
# BV号为1fT4y1L7hk的视频属性抓取结束
# 开始BV号为1WT4y1E7kN视频属性的抓取
# BV号为1WT4y1E7kN的视频属性抓取结束
# 开始BV号为1HD4y1U7A1视频属性的抓取
# 开始BV号为1HD4y1U7A1视频属性的抓取
# BV号为1HD4y1U7A1的视频属性抓取结束
# 开始BV号为1gi4y1V7r3视频属性的抓取
# BV号为1gi4y1V7r3的视频属性抓取结束
# 开始BV号为1mh411o7e6视频属性的抓取
# BV号为1mh411o7e6的视频属性抓取结束
# 开始BV号为1uf4y1R7L8视频属性的抓取
# BV号为1uf4y1R7L8的视频属性抓取结束
# 开始BV号为1Pi4y1V76P视频属性的抓取
# BV号为1Pi4y1V76P的视频属性抓取结束
# 开始BV号为1ia4y1a7P1视频属性的抓取
# BV号为1ia4y1a7P1的视频属性抓取结束
# 开始BV号为1cZ4y1g79X视频属性的抓取
# BV号为1cZ4y1g79X的视频属性抓取结束
# 开始BV号为1ii4y1373X视频属性的抓取
# BV号为1ii4y1373X的视频属性抓取结束
# 开始BV号为13h411Z7Mq视频属性的抓取
# 开始BV号为13h411Z7Mq视频属性的抓取
# BV号为13h411Z7Mq的视频属性抓取结束
# 开始BV号为1DD4y1S7Sv视频属性的抓取
# BV号为1DD4y1S7Sv的视频属性抓取结束
# 开始BV号为1bh411o75X视频属性的抓取
# BV号为1bh411o75X的视频属性抓取结束
# 开始BV号为1Bz411v7eV视频属性的抓取
# BV号为1Bz411v7eV的视频属性抓取结束
# 开始BV号为1Hh411o7qH视频属性的抓取
# BV号为1Hh411o7qH的视频属性抓取结束
# 开始BV号为1aT4y1E7U4视频属性的抓取
# BV号为1aT4y1E7U4的视频属性抓取结束
# 开始BV号为17z4y1D7g4视频属性的抓取
# BV号为17z4y1D7g4的视频属性抓取结束
# 开始BV号为18p4y1S7P5视频属性的抓取
# BV号为18p4y1S7P5的视频属性抓取结束
# 开始BV号为1bh411o7fn视频属性的抓取
# BV号为1bh411o7fn的视频属性抓取结束
# 开始BV号为1Ci4y1G7XP视频属性的抓取
# BV号为1Ci4y1G7XP的视频属性抓取结束
# 开始BV号为1PK4y1x7x7视频属性的抓取
# BV号为1PK4y1x7x7的视频属性抓取结束
# 开始BV号为1zD4y1Q7mN视频属性的抓取
# BV号为1zD4y1Q7mN的视频属性抓取结束
# 开始BV号为1Nk4y167x1视频属性的抓取
# BV号为1Nk4y167x1的视频属性抓取结束
# 开始BV号为1J54y1S7k6视频属性的抓取
# BV号为1J54y1S7k6的视频属性抓取结束
# 开始BV号为1RA411a7x7视频属性的抓取
# BV号为1RA411a7x7的视频属性抓取结束
# 开始BV号为1V5411e7Hn视频属性的抓取
# BV号为1V5411e7Hn的视频属性抓取结束
# 开始BV号为1aA411v7g9视频属性的抓取
# BV号为1aA411v7g9的视频属性抓取结束
# 开始BV号为1cp4y1q7Fe视频属性的抓取
# BV号为1cp4y1q7Fe的视频属性抓取结束
# 开始BV号为1va4y1a7sU视频属性的抓取
# BV号为1va4y1a7sU的视频属性抓取结束
# 开始BV号为1FC4y1h7jo视频属性的抓取
# BV号为1FC4y1h7jo的视频属性抓取结束
# 开始BV号为13V411r7ei视频属性的抓取
# BV号为13V411r7ei的视频属性抓取结束
# 开始BV号为1PK4y1x7Bp视频属性的抓取
# BV号为1PK4y1x7Bp的视频属性抓取结束
# 开始BV号为1sC4y1b7Zk视频属性的抓取
# BV号为1sC4y1b7Zk的视频属性抓取结束
# 开始BV号为1Kz411v7WF视频属性的抓取
# BV号为1Kz411v7WF的视频属性抓取结束
# 开始BV号为11p4y1i7JP视频属性的抓取
# BV号为11p4y1i7JP的视频属性抓取结束
# 开始BV号为1hT4y177tV视频属性的抓取
# BV号为1hT4y177tV的视频属性抓取结束
# 开始BV号为1Qp4y1U77u视频属性的抓取
# BV号为1Qp4y1U77u的视频属性抓取结束
# 开始BV号为1iz4y1X7Y9视频属性的抓取
# BV号为1iz4y1X7Y9的视频属性抓取结束
# 开始BV号为1xv411v7ry视频属性的抓取
# BV号为1xv411v7ry的视频属性抓取结束
# 开始BV号为1og4y1v7n7视频属性的抓取
# BV号为1og4y1v7n7的视频属性抓取结束
# 开始BV号为1kh411o7aN视频属性的抓取
# BV号为1kh411o7aN的视频属性抓取结束
# 开始BV号为1N5411e72W视频属性的抓取
# BV号为1N5411e72W的视频属性抓取结束
# 开始BV号为1AK411n7M3视频属性的抓取
# BV号为1AK411n7M3的视频属性抓取结束
# 开始BV号为1QK411J7cJ视频属性的抓取
# BV号为1QK411J7cJ的视频属性抓取结束
# 开始BV号为1Gi4y137ba视频属性的抓取
# BV号为1Gi4y137ba的视频属性抓取结束
# 开始BV号为1HK411H7Hd视频属性的抓取
# BV号为1HK411H7Hd的视频属性抓取结束
# 开始BV号为1fC4y1b7Fq视频属性的抓取
# BV号为1fC4y1b7Fq的视频属性抓取结束
# 开始BV号为1ct4y1D7Up视频属性的抓取
# BV号为1ct4y1D7Up的视频属性抓取结束
# 开始BV号为1Ba4y1E71e视频属性的抓取
# BV号为1Ba4y1E71e的视频属性抓取结束
# 开始BV号为1hk4y1m7Xj视频属性的抓取
# BV号为1hk4y1m7Xj的视频属性抓取结束
# 开始BV号为19t4y1975f视频属性的抓取
# BV号为19t4y1975f的视频属性抓取结束
# 开始BV号为1Li4y1V7qo视频属性的抓取
# BV号为1Li4y1V7qo的视频属性抓取结束
# 开始BV号为1Ck4y1m7Z9视频属性的抓取
# BV号为1Ck4y1m7Z9的视频属性抓取结束
# 开始BV号为1Av411z7Xu视频属性的抓取
# BV号为1Av411z7Xu的视频属性抓取结束
# 开始BV号为1KA411v7pc视频属性的抓取
# BV号为1KA411v7pc的视频属性抓取结束
# 开始BV号为19h411o7re视频属性的抓取
# BV号为19h411o7re的视频属性抓取结束
# 开始BV号为1qZ4y1u7W1视频属性的抓取
# BV号为1qZ4y1u7W1的视频属性抓取结束
# 开始BV号为1zp4y1i7Ai视频属性的抓取
# BV号为1zp4y1i7Ai的视频属性抓取结束
# 开始BV号为1b54y1v7MU视频属性的抓取
# BV号为1b54y1v7MU的视频属性抓取结束
# 开始BV号为1iC4y1b7R5视频属性的抓取
# BV号为1iC4y1b7R5的视频属性抓取结束
# 开始BV号为1ea4y1E7dh视频属性的抓取
# BV号为1ea4y1E7dh的视频属性抓取结束
# 开始BV号为1q54y1m7bA视频属性的抓取
# BV号为1q54y1m7bA的视频属性抓取结束
# 开始BV号为1oZ4y1K7tb视频属性的抓取
# BV号为1oZ4y1K7tb的视频属性抓取结束
# 开始BV号为14t4y1S7gQ视频属性的抓取
# BV号为14t4y1S7gQ的视频属性抓取结束
# 开始BV号为1S54y1e7fr视频属性的抓取
# BV号为1S54y1e7fr的视频属性抓取结束
# 开始BV号为11V411z7Ry视频属性的抓取
# BV号为11V411z7Ry的视频属性抓取结束
# 开始BV号为1MA411n7kJ视频属性的抓取
# BV号为1MA411n7kJ的视频属性抓取结束
# 开始BV号为1664y1c7Ls视频属性的抓取
# BV号为1664y1c7Ls的视频属性抓取结束
# 开始BV号为1Q54y1e7UM视频属性的抓取
# BV号为1Q54y1e7UM的视频属性抓取结束
# 开始BV号为1AZ4y1T7u2视频属性的抓取
# BV号为1AZ4y1T7u2的视频属性抓取结束
# 开始BV号为1Cf4y1Q7hn视频属性的抓取
# BV号为1Cf4y1Q7hn的视频属性抓取结束
# 开始BV号为1N5411b71j视频属性的抓取
# BV号为1N5411b71j的视频属性抓取结束
# 开始BV号为15C4y1t7Q4视频属性的抓取
# BV号为15C4y1t7Q4的视频属性抓取结束
# 开始BV号为1Th411o7PJ视频属性的抓取
# BV号为1Th411o7PJ的视频属性抓取结束
# 开始BV号为1hZ4y1M77C视频属性的抓取
# BV号为1hZ4y1M77C的视频属性抓取结束
# 开始BV号为1EC4y187A2视频属性的抓取
# BV号为1EC4y187A2的视频属性抓取结束
# 开始BV号为1FD4y1U7HZ视频属性的抓取
# BV号为1FD4y1U7HZ的视频属性抓取结束
# 开始BV号为1pZ4y1M7e5视频属性的抓取
# BV号为1pZ4y1M7e5的视频属性抓取结束
# 开始BV号为1Rf4y197TQ视频属性的抓取
# BV号为1Rf4y197TQ的视频属性抓取结束
# 开始BV号为1a54y1v7sH视频属性的抓取
# BV号为1a54y1v7sH的视频属性抓取结束
# 开始BV号为1o54y1v7VL视频属性的抓取
# BV号为1o54y1v7VL的视频属性抓取结束
# 开始BV号为1G54y1i7nH视频属性的抓取
# BV号为1G54y1i7nH的视频属性抓取结束
# 开始BV号为1a541187Kf视频属性的抓取
# BV号为1a541187Kf的视频属性抓取结束
# 开始BV号为1fT4y157VR视频属性的抓取
# BV号为1fT4y157VR的视频属性抓取结束
# 开始BV号为1KZ4y1T7Q7视频属性的抓取
# BV号为1KZ4y1T7Q7的视频属性抓取结束
# 开始BV号为19v411v7xX视频属性的抓取
# BV号为19v411v7xX的视频属性抓取结束
# 开始BV号为1sA411n7Ws视频属性的抓取
# BV号为1sA411n7Ws的视频属性抓取结束
# 开始BV号为1xC4y187CH视频属性的抓取
# BV号为1xC4y187CH的视频属性抓取结束
# 开始BV号为1254y1e7PS视频属性的抓取
# BV号为1254y1e7PS的视频属性抓取结束
# 开始BV号为13A411n7vQ视频属性的抓取
# BV号为13A411n7vQ的视频属性抓取结束
# 开始BV号为1eh411Z7ea视频属性的抓取
# BV号为1eh411Z7ea的视频属性抓取结束
# 开始BV号为1954y1e7TP视频属性的抓取
# BV号为1954y1e7TP的视频属性抓取结束
# 开始BV号为11v411v73N视频属性的抓取
# BV号为11v411v73N的视频属性抓取结束
# 开始BV号为1X541187hQ视频属性的抓取
# BV号为1X541187hQ的视频属性抓取结束
# 开始BV号为1654y1i7EA视频属性的抓取
# BV号为1654y1i7EA的视频属性抓取结束
# 开始BV号为1sZ4y1M7q2视频属性的抓取
# BV号为1sZ4y1M7q2的视频属性抓取结束
# 开始BV号为1wk4y127yP视频属性的抓取
# BV号为1wk4y127yP的视频属性抓取结束
# 开始BV号为1ct4y1S7Kc视频属性的抓取
# BV号为1ct4y1S7Kc的视频属性抓取结束
# 开始BV号为1nk4y1m7YU视频属性的抓取
# BV号为1nk4y1m7YU的视频属性抓取结束
# 开始BV号为1h5411874H视频属性的抓取
# BV号为1h5411874H的视频属性抓取结束
# 开始BV号为1SA411Y7GY视频属性的抓取
# BV号为1SA411Y7GY的视频属性抓取结束
# 开始BV号为1Mp4y1e7nq视频属性的抓取
# BV号为1Mp4y1e7nq的视频属性抓取结束
# 开始BV号为1zD4y127pP视频属性的抓取
# BV号为1zD4y127pP的视频属性抓取结束
# 开始BV号为1ya4y177kC视频属性的抓取
# BV号为1ya4y177kC的视频属性抓取结束
# 开始BV号为1vz4y1f72F视频属性的抓取
# BV号为1vz4y1f72F的视频属性抓取结束
# 开始BV号为1Wk4y1m7dM视频属性的抓取
# BV号为1Wk4y1m7dM的视频属性抓取结束
# 开始BV号为18K4y1Y7f4视频属性的抓取
# BV号为18K4y1Y7f4的视频属性抓取结束
# 开始BV号为1ah411d7HG视频属性的抓取
# BV号为1ah411d7HG的视频属性抓取结束
# 开始BV号为1R541187zt视频属性的抓取
# BV号为1R541187zt的视频属性抓取结束
# 开始BV号为1uZ4y1K74v视频属性的抓取
# BV号为1uZ4y1K74v的视频属性抓取结束
# 开始BV号为17K411K7p5视频属性的抓取
# BV号为17K411K7p5的视频属性抓取结束
# 开始BV号为1Vk4y1m7Vc视频属性的抓取
# 开始BV号为1Vk4y1m7Vc视频属性的抓取
# 开始BV号为1Vk4y1m7Vc视频属性的抓取
# 开始BV号为1Vk4y1m7Vc视频属性的抓取
# BV号为1Vk4y1m7Vc的视频属性抓取结束
# 开始BV号为1DC4y1473G视频属性的抓取
# BV号为1DC4y1473G的视频属性抓取结束
# 开始BV号为1554y127M2视频属性的抓取
# BV号为1554y127M2的视频属性抓取结束
# 开始BV号为19a4y1E7zk视频属性的抓取
# BV号为19a4y1E7zk的视频属性抓取结束
# 开始BV号为1Ei4y1M775视频属性的抓取
# BV号为1Ei4y1M775的视频属性抓取结束
# 开始BV号为1fy4y1C7fi视频属性的抓取
# BV号为1fy4y1C7fi的视频属性抓取结束
# 开始BV号为1v541187kV视频属性的抓取
# BV号为1v541187kV的视频属性抓取结束
# 开始BV号为1ap4y1v7rz视频属性的抓取
# BV号为1ap4y1v7rz的视频属性抓取结束
# 开始BV号为11i4y1379w视频属性的抓取
# BV号为11i4y1379w的视频属性抓取结束
# 开始BV号为1P64y1F7nD视频属性的抓取
# BV号为1P64y1F7nD的视频属性抓取结束
# 开始BV号为1EK411M7ry视频属性的抓取
# BV号为1EK411M7ry的视频属性抓取结束
# 开始BV号为14z4y1f7MY视频属性的抓取
# BV号为14z4y1f7MY的视频属性抓取结束
# 开始BV号为1tA411n7xN视频属性的抓取
# BV号为1tA411n7xN的视频属性抓取结束
# 开始BV号为1Ut4y1S7NT视频属性的抓取
# BV号为1Ut4y1S7NT的视频属性抓取结束
# 开始BV号为1Xa4y177dQ视频属性的抓取
# BV号为1Xa4y177dQ的视频属性抓取结束
# 开始BV号为1Ny4y1y78S视频属性的抓取
# BV号为1Ny4y1y78S的视频属性抓取结束
# 开始BV号为1b54y1e7B7视频属性的抓取
# BV号为1b54y1e7B7的视频属性抓取结束
# 开始BV号为1DD4y1U7J6视频属性的抓取
# BV号为1DD4y1U7J6的视频属性抓取结束
# 开始BV号为1jk4y127Tc视频属性的抓取
# BV号为1jk4y127Tc的视频属性抓取结束
# 开始BV号为1YZ4y1K7k1视频属性的抓取
# BV号为1YZ4y1K7k1的视频属性抓取结束
# 开始BV号为11D4y127Jo视频属性的抓取
# BV号为11D4y127Jo的视频属性抓取结束
# 开始BV号为1o64y1F7Jy视频属性的抓取
# BV号为1o64y1F7Jy的视频属性抓取结束
# 开始BV号为1QA411Y7jD视频属性的抓取
# BV号为1QA411Y7jD的视频属性抓取结束
# 开始BV号为1c5411h7vf视频属性的抓取
# BV号为1c5411h7vf的视频属性抓取结束
# 开始BV号为1Ah411d72d视频属性的抓取
# BV号为1Ah411d72d的视频属性抓取结束
# 开始BV号为1x64y1c7oq视频属性的抓取
# BV号为1x64y1c7oq的视频属性抓取结束
# 开始BV号为1Y541187vU视频属性的抓取
# BV号为1Y541187vU的视频属性抓取结束
# 开始BV号为1C54y1i7cf视频属性的抓取
# BV号为1C54y1i7cf的视频属性抓取结束
# 开始BV号为1AA411n7JC视频属性的抓取
# BV号为1AA411n7JC的视频属性抓取结束
# 开始BV号为1vf4y197cL视频属性的抓取
# BV号为1vf4y197cL的视频属性抓取结束
# 开始BV号为1mv411v7qg视频属性的抓取
# BV号为1mv411v7qg的视频属性抓取结束
# 开始BV号为1ut4y1Q7Ln视频属性的抓取
# BV号为1ut4y1Q7Ln的视频属性抓取结束
# 开始BV号为1Gi4y1g7dt视频属性的抓取
# BV号为1Gi4y1g7dt的视频属性抓取结束
# 开始BV号为1QD4y1U7bA视频属性的抓取
# BV号为1QD4y1U7bA的视频属性抓取结束
# 开始BV号为19f4y1X783视频属性的抓取
# BV号为19f4y1X783的视频属性抓取结束
# 开始BV号为1Yi4y1M7EG视频属性的抓取
# BV号为1Yi4y1M7EG的视频属性抓取结束
# 开始BV号为18A411n7fj视频属性的抓取
# BV号为18A411n7fj的视频属性抓取结束
# 开始BV号为1Yf4y1Q76n视频属性的抓取
# BV号为1Yf4y1Q76n的视频属性抓取结束
# 开始BV号为1Lv411v7dU视频属性的抓取
# BV号为1Lv411v7dU的视频属性抓取结束
# 开始BV号为1JC4y187oQ视频属性的抓取
# BV号为1JC4y187oQ的视频属性抓取结束
# 开始BV号为14D4y1U7rA视频属性的抓取
# BV号为14D4y1U7rA的视频属性抓取结束
# 开始BV号为1hi4y1g7gM视频属性的抓取
# BV号为1hi4y1g7gM的视频属性抓取结束
# 开始BV号为1oC4y147W2视频属性的抓取
# BV号为1oC4y147W2的视频属性抓取结束
# 开始BV号为1Qi4y1u7nX视频属性的抓取
# BV号为1Qi4y1u7nX的视频属性抓取结束
# 开始BV号为17t4y1Q7R7视频属性的抓取
# BV号为17t4y1Q7R7的视频属性抓取结束
# 开始BV号为1uy4y1y7w1视频属性的抓取
# BV号为1uy4y1y7w1的视频属性抓取结束
# 开始BV号为1yA411n7ZM视频属性的抓取
# BV号为1yA411n7ZM的视频属性抓取结束
# 开始BV号为1mT4y157Zq视频属性的抓取
# BV号为1mT4y157Zq的视频属性抓取结束
# 开始BV号为1MZ4y1K7h8视频属性的抓取
# BV号为1MZ4y1K7h8的视频属性抓取结束
# 开始BV号为1jf4y1Q71G视频属性的抓取
# BV号为1jf4y1Q71G的视频属性抓取结束
# 开始BV号为1AZ4y1N7PB视频属性的抓取
# BV号为1AZ4y1N7PB的视频属性抓取结束
# 开始BV号为1qz4y1f73J视频属性的抓取
# BV号为1qz4y1f73J的视频属性抓取结束
# 开始BV号为135411j7rx视频属性的抓取
# BV号为135411j7rx的视频属性抓取结束
# 开始BV号为15f4y1D7mG视频属性的抓取
# BV号为15f4y1D7mG的视频属性抓取结束
# 开始BV号为1Kv4111788视频属性的抓取
# BV号为1Kv4111788的视频属性抓取结束
# 开始BV号为17541187cH视频属性的抓取
# BV号为17541187cH的视频属性抓取结束
# 开始BV号为1jZ4y157kR视频属性的抓取
# BV号为1jZ4y157kR的视频属性抓取结束
# 开始BV号为14K411K7TM视频属性的抓取
# BV号为14K411K7TM的视频属性抓取结束
# 开始BV号为1mT4y1L7hL视频属性的抓取
# BV号为1mT4y1L7hL的视频属性抓取结束
# 开始BV号为1ey4y1k746视频属性的抓取
# BV号为1ey4y1k746的视频属性抓取结束
# 开始BV号为1bv411C7F2视频属性的抓取
# BV号为1bv411C7F2的视频属性抓取结束
# 开始BV号为1pv411C7kv视频属性的抓取
# BV号为1pv411C7kv的视频属性抓取结束
# 开始BV号为1PD4y1Z7vF视频属性的抓取
# BV号为1PD4y1Z7vF的视频属性抓取结束
# 开始BV号为17a4y1j7iz视频属性的抓取
# BV号为17a4y1j7iz的视频属性抓取结束
# 开始BV号为1uT4y1c7zN视频属性的抓取
# BV号为1uT4y1c7zN的视频属性抓取结束
# 开始BV号为1ST4y1L7g9视频属性的抓取
# BV号为1ST4y1L7g9的视频属性抓取结束
# 开始BV号为1sD4y1m7a5视频属性的抓取
# BV号为1sD4y1m7a5的视频属性抓取结束
# 开始BV号为1yk4y1y7Ac视频属性的抓取
# BV号为1yk4y1y7Ac的视频属性抓取结束
# 开始BV号为1uf4y1D7os视频属性的抓取
# BV号为1uf4y1D7os的视频属性抓取结束
# 开始BV号为1iT4y1A7cc视频属性的抓取
# BV号为1iT4y1A7cc的视频属性抓取结束
# 开始BV号为1xD4y1o7JG视频属性的抓取
# BV号为1xD4y1o7JG的视频属性抓取结束
# 开始BV号为18A411E77Q视频属性的抓取
# BV号为18A411E77Q的视频属性抓取结束
# 开始BV号为1HK411K71n视频属性的抓取
# BV号为1HK411K71n的视频属性抓取结束
# 开始BV号为1bz4y1Z7Ds视频属性的抓取
# BV号为1bz4y1Z7Ds的视频属性抓取结束
# 开始BV号为1bD4y1m7wt视频属性的抓取
# BV号为1bD4y1m7wt的视频属性抓取结束
# 开始BV号为1PA411H7qk视频属性的抓取
# BV号为1PA411H7qk的视频属性抓取结束
# 开始BV号为1pZ4y1N7ca视频属性的抓取
# BV号为1pZ4y1N7ca的视频属性抓取结束
# 开始BV号为1T54y1m7XA视频属性的抓取
# BV号为1T54y1m7XA的视频属性抓取结束
# 开始BV号为1e5411b7Vj视频属性的抓取
# BV号为1e5411b7Vj的视频属性抓取结束
# 开始BV号为1XK411N7XH视频属性的抓取
# BV号为1XK411N7XH的视频属性抓取结束
# 开始BV号为1c5411b7eV视频属性的抓取
# BV号为1c5411b7eV的视频属性抓取结束
# 开始BV号为16t4y1i7Gk视频属性的抓取
# BV号为16t4y1i7Gk的视频属性抓取结束
# 开始BV号为19v411C7Tp视频属性的抓取
# BV号为19v411C7Tp的视频属性抓取结束
# 开始BV号为1L54y1m7rT视频属性的抓取
# BV号为1L54y1m7rT的视频属性抓取结束
# 开始BV号为12K411K7L7视频属性的抓取
# BV号为12K411K7L7的视频属性抓取结束
# 开始BV号为1TA411J7eG视频属性的抓取
# BV号为1TA411J7eG的视频属性抓取结束
# 开始BV号为1bp4y1e7Rj视频属性的抓取
# BV号为1bp4y1e7Rj的视频属性抓取结束
# 开始BV号为1JV411m7Hs视频属性的抓取
# BV号为1JV411m7Hs的视频属性抓取结束
# 开始BV号为18A411n7y5视频属性的抓取
# BV号为18A411n7y5的视频属性抓取结束
# 开始BV号为15t4y1q7g4视频属性的抓取
# BV号为15t4y1q7g4的视频属性抓取结束
# 开始BV号为1Ct4y1S7j7视频属性的抓取
# BV号为1Ct4y1S7j7的视频属性抓取结束
# 开始BV号为1iK4y1a7F6视频属性的抓取
# BV号为1iK4y1a7F6的视频属性抓取结束
# 开始BV号为1SV411m74b视频属性的抓取
# BV号为1SV411m74b的视频属性抓取结束
# 开始BV号为1dT4y1w7UF视频属性的抓取
# BV号为1dT4y1w7UF的视频属性抓取结束
# 开始BV号为1Ji4y1u7uJ视频属性的抓取
# BV号为1Ji4y1u7uJ的视频属性抓取结束
# 开始BV号为1U5411b7Do视频属性的抓取
# BV号为1U5411b7Do的视频属性抓取结束
# 开始BV号为1JZ4y1T7BR视频属性的抓取
# BV号为1JZ4y1T7BR的视频属性抓取结束
# 开始BV号为1YK411K7SD视频属性的抓取
# BV号为1YK411K7SD的视频属性抓取结束
# 开始BV号为1vy4y1k7vq视频属性的抓取
# BV号为1vy4y1k7vq的视频属性抓取结束
# 开始BV号为1N64y1F7Wa视频属性的抓取
# BV号为1N64y1F7Wa的视频属性抓取结束
# 开始BV号为1di4y1M77X视频属性的抓取
# BV号为1di4y1M77X的视频属性抓取结束
# 开始BV号为1gp4y1e7eU视频属性的抓取
# BV号为1gp4y1e7eU的视频属性抓取结束
# 开始BV号为1Yv41117Gh视频属性的抓取
# BV号为1Yv41117Gh的视频属性抓取结束
# 开始BV号为1Q54y127nQ视频属性的抓取
# BV号为1Q54y127nQ的视频属性抓取结束
# 开始BV号为1Ta4y1j77B视频属性的抓取
# BV号为1Ta4y1j77B的视频属性抓取结束
# 开始BV号为1PT4y1A7eJ视频属性的抓取
# BV号为1PT4y1A7eJ的视频属性抓取结束
# 开始BV号为1Jp4y1a7Tr视频属性的抓取
# BV号为1Jp4y1a7Tr的视频属性抓取结束
# 开始BV号为1sK411N75e视频属性的抓取
# BV号为1sK411N75e的视频属性抓取结束
# 开始BV号为1Pv41117im视频属性的抓取
# BV号为1Pv41117im的视频属性抓取结束
# 开始BV号为1UZ4y1N7Bk视频属性的抓取
# BV号为1UZ4y1N7Bk的视频属性抓取结束
# 开始BV号为1VZ4y1N7zi视频属性的抓取
# BV号为1VZ4y1N7zi的视频属性抓取结束
# 开始BV号为1dy4y1y75B视频属性的抓取
# BV号为1dy4y1y75B的视频属性抓取结束
# 开始BV号为1MK4y1a7im视频属性的抓取
# BV号为1MK4y1a7im的视频属性抓取结束
# 开始BV号为1tz4y1f7su视频属性的抓取
# BV号为1tz4y1f7su的视频属性抓取结束
# 开始BV号为1mk4y1y7oN视频属性的抓取
# BV号为1mk4y1y7oN的视频属性抓取结束
# 开始BV号为15K411K7wo视频属性的抓取
# BV号为15K411K7wo的视频属性抓取结束
# 开始BV号为1b64y1F7LQ视频属性的抓取
# BV号为1b64y1F7LQ的视频属性抓取结束
# 开始BV号为1iA411E7P7视频属性的抓取
# BV号为1iA411E7P7的视频属性抓取结束
# 开始BV号为1T54y1v7uY视频属性的抓取
# BV号为1T54y1v7uY的视频属性抓取结束
# 开始BV号为1Xy4y1y7Eo视频属性的抓取
# BV号为1Xy4y1y7Eo的视频属性抓取结束
# 开始BV号为1ua4y1E7Jh视频属性的抓取
# BV号为1ua4y1E7Jh的视频属性抓取结束
# 开始BV号为1UZ4y1P7r9视频属性的抓取
# BV号为1UZ4y1P7r9的视频属性抓取结束
# 开始BV号为1Ga4y1E7Jk视频属性的抓取
# BV号为1Ga4y1E7Jk的视频属性抓取结束
# 开始BV号为18D4y1o7Hr视频属性的抓取
# BV号为18D4y1o7Hr的视频属性抓取结束
# 开始BV号为1mD4y1d7za视频属性的抓取
# BV号为1mD4y1d7za的视频属性抓取结束
# 开始BV号为1j54y117JC视频属性的抓取
# BV号为1j54y117JC的视频属性抓取结束
# 开始BV号为1st4y1q77j视频属性的抓取
# BV号为1st4y1q77j的视频属性抓取结束
# 开始BV号为1sK411P7j5视频属性的抓取
# BV号为1sK411P7j5的视频属性抓取结束
# 开始BV号为1Wk4y1C76T视频属性的抓取
# BV号为1Wk4y1C76T的视频属性抓取结束
# 开始BV号为1MT4y1A7iZ视频属性的抓取
# BV号为1MT4y1A7iZ的视频属性抓取结束
# 开始BV号为1Si4y1M7wm视频属性的抓取
# BV号为1Si4y1M7wm的视频属性抓取结束
# 开始BV号为14p4y1e7KM视频属性的抓取
# BV号为14p4y1e7KM的视频属性抓取结束
# 开始BV号为1Y5411b7KL视频属性的抓取
# BV号为1Y5411b7KL的视频属性抓取结束
# 开始BV号为19v411C7cv视频属性的抓取
# BV号为19v411C7cv的视频属性抓取结束
# 开始BV号为11p4y1e7De视频属性的抓取
# BV号为11p4y1e7De的视频属性抓取结束
# 开始BV号为1N54y1y76y视频属性的抓取
# BV号为1N54y1y76y的视频属性抓取结束
# 开始BV号为1M5411j73E视频属性的抓取
# BV号为1M5411j73E的视频属性抓取结束
# 开始BV号为1o5411b7hh视频属性的抓取
# BV号为1o5411b7hh的视频属性抓取结束
# 开始BV号为1ST4y1w7GD视频属性的抓取
# BV号为1ST4y1w7GD的视频属性抓取结束
# 开始BV号为1Yf4y1D7rW视频属性的抓取
# BV号为1Yf4y1D7rW的视频属性抓取结束
# 开始BV号为1b5411b7kA视频属性的抓取
# BV号为1b5411b7kA的视频属性抓取结束
# 开始BV号为1q54y1k7G1视频属性的抓取
# BV号为1q54y1k7G1的视频属性抓取结束
# 开始BV号为1m54y127Mh视频属性的抓取
# BV号为1m54y127Mh的视频属性抓取结束
# 开始BV号为1Qa4y1j7io视频属性的抓取
# BV号为1Qa4y1j7io的视频属性抓取结束
# 开始BV号为1Ft4y1q7fZ视频属性的抓取
# BV号为1Ft4y1q7fZ的视频属性抓取结束
# 开始BV号为1M54y1y7v4视频属性的抓取
# BV号为1M54y1y7v4的视频属性抓取结束
# 开始BV号为1kk4y127Zm视频属性的抓取
# BV号为1kk4y127Zm的视频属性抓取结束
# 开始BV号为14k4y117FA视频属性的抓取
# BV号为14k4y117FA的视频属性抓取结束
# 开始BV号为1TA411J7vz视频属性的抓取
# BV号为1TA411J7vz的视频属性抓取结束
# 开始BV号为1zV411m7Tx视频属性的抓取
# BV号为1zV411m7Tx的视频属性抓取结束
# 开始BV号为1Gy4y1r7bh视频属性的抓取
# BV号为1Gy4y1r7bh的视频属性抓取结束
# 开始BV号为1Ai4y1772G视频属性的抓取
# BV号为1Ai4y1772G的视频属性抓取结束
# 开始BV号为1Ff4y1B7q3视频属性的抓取
# BV号为1Ff4y1B7q3的视频属性抓取结束
# 开始BV号为1WV411y7bE视频属性的抓取
# BV号为1WV411y7bE的视频属性抓取结束
# 开始BV号为1gK411N7rc视频属性的抓取
# BV号为1gK411N7rc的视频属性抓取结束
# 开始BV号为1GV411y7Yi视频属性的抓取
# BV号为1GV411y7Yi的视频属性抓取结束
# 开始BV号为1ef4y1B7es视频属性的抓取
# BV号为1ef4y1B7es的视频属性抓取结束
# 开始BV号为1sD4y1R7xo视频属性的抓取
# BV号为1sD4y1R7xo的视频属性抓取结束
# 开始BV号为18h41197fY视频属性的抓取
# BV号为18h41197fY的视频属性抓取结束
# 开始BV号为1by4y1r7Dj视频属性的抓取
# BV号为1by4y1r7Dj的视频属性抓取结束
# 开始BV号为1Cf4y1i7Po视频属性的抓取
# BV号为1Cf4y1i7Po的视频属性抓取结束
# 开始BV号为1RK4y177xX视频属性的抓取
# BV号为1RK4y177xX的视频属性抓取结束
# 开始BV号为19K411A7tz视频属性的抓取
# BV号为19K411A7tz的视频属性抓取结束
# 开始BV号为1o54y1177g视频属性的抓取
# BV号为1o54y1177g的视频属性抓取结束
# 开始BV号为1Jy4y1B7Lf视频属性的抓取
# 开始BV号为1Jy4y1B7Lf视频属性的抓取
# 开始BV号为1Jy4y1B7Lf视频属性的抓取
# BV号为1Jy4y1B7Lf的视频属性抓取结束
# 开始BV号为1yi4y1j7Ug视频属性的抓取
# BV号为1yi4y1j7Ug的视频属性抓取结束
# 开始BV号为1xD4y1R721视频属性的抓取
# BV号为1xD4y1R721的视频属性抓取结束
# 开始BV号为1bK411A7J2视频属性的抓取
# BV号为1bK411A7J2的视频属性抓取结束
# 开始BV号为1ta411A7Vr视频属性的抓取
# BV号为1ta411A7Vr的视频属性抓取结束
# 开始BV号为1y54y1y71c视频属性的抓取
# BV号为1y54y1y71c的视频属性抓取结束
# 开始BV号为1ua411A7TM视频属性的抓取
# BV号为1ua411A7TM的视频属性抓取结束
# 开始BV号为1va411A7bS视频属性的抓取
# BV号为1va411A7bS的视频属性抓取结束
# 开始BV号为1di4y1E7F7视频属性的抓取
# BV号为1di4y1E7F7的视频属性抓取结束
# 开始BV号为1TV41127Tc视频属性的抓取
# BV号为1TV41127Tc的视频属性抓取结束
# 开始BV号为1vi4y177UW视频属性的抓取
# BV号为1vi4y177UW的视频属性抓取结束
# 开始BV号为1Kf4y1z7UL视频属性的抓取
# BV号为1Kf4y1z7UL的视频属性抓取结束
# 开始BV号为1VK411A74b视频属性的抓取
# BV号为1VK411A74b的视频属性抓取结束
# 开始BV号为1Tr4y1w7aP视频属性的抓取
# BV号为1Tr4y1w7aP的视频属性抓取结束
# 开始BV号为1Wi4y1j75B视频属性的抓取
# BV号为1Wi4y1j75B的视频属性抓取结束
# 开始BV号为1AA411E7Mg视频属性的抓取
# BV号为1AA411E7Mg的视频属性抓取结束
# 开始BV号为1fZ4y157mS视频属性的抓取
# BV号为1fZ4y157mS的视频属性抓取结束
# 开始BV号为1ty4y1r71c视频属性的抓取
# BV号为1ty4y1r71c的视频属性抓取结束
# 开始BV号为1by4y1C7h1视频属性的抓取
# BV号为1by4y1C7h1的视频属性抓取结束
# 开始BV号为17z4y1o73B视频属性的抓取
# BV号为17z4y1o73B的视频属性抓取结束
# 开始BV号为1Q541157BL视频属性的抓取
# BV号为1Q541157BL的视频属性抓取结束
# 开始BV号为1w54y127Fh视频属性的抓取
# BV号为1w54y127Fh的视频属性抓取结束
# 开始BV号为1Ev411y7zX视频属性的抓取
# BV号为1Ev411y7zX的视频属性抓取结束
# 开始BV号为1dK4y1f7CV视频属性的抓取
# BV号为1dK4y1f7CV的视频属性抓取结束
# 开始BV号为1uZ4y1L7Ju视频属性的抓取
# BV号为1uZ4y1L7Ju的视频属性抓取结束
# 开始BV号为1Py4y1C7mp视频属性的抓取
# BV号为1Py4y1C7mp的视频属性抓取结束
# 开始BV号为14f4y1B7fV视频属性的抓取
# BV号为14f4y1B7fV的视频属性抓取结束
# 开始BV号为1Pz4y1f7Sz视频属性的抓取
# BV号为1Pz4y1f7Sz的视频属性抓取结束
# 开始BV号为1HT4y1F7JM视频属性的抓取
# BV号为1HT4y1F7JM的视频属性抓取结束
# 开始BV号为1FK411N7Zk视频属性的抓取
# BV号为1FK411N7Zk的视频属性抓取结束
# 开始BV号为1Wy4y1B77D视频属性的抓取
# BV号为1Wy4y1B77D的视频属性抓取结束
# 开始BV号为1Wp4y1Y7Uc视频属性的抓取
# BV号为1Wp4y1Y7Uc的视频属性抓取结束
# 开始BV号为1354y1C7WA视频属性的抓取
# BV号为1354y1C7WA的视频属性抓取结束
# 开始BV号为1kr4y1c7Cq视频属性的抓取
# BV号为1kr4y1c7Cq的视频属性抓取结束
# 开始BV号为1n5411L7Y4视频属性的抓取
# BV号为1n5411L7Y4的视频属性抓取结束
# 开始BV号为1Vy4y1C7vk视频属性的抓取
# BV号为1Vy4y1C7vk的视频属性抓取结束
# 开始BV号为1hk4y1C7rP视频属性的抓取
# BV号为1hk4y1C7rP的视频属性抓取结束
# 开始BV号为1UA41177ck视频属性的抓取
# BV号为1UA41177ck的视频属性抓取结束
# 开始BV号为1oy4y1k7z5视频属性的抓取
# BV号为1oy4y1k7z5的视频属性抓取结束
# 开始BV号为1dz4y1d7ZG视频属性的抓取
# BV号为1dz4y1d7ZG的视频属性抓取结束
# 开始BV号为14t4y1i7BH视频属性的抓取
# BV号为14t4y1i7BH的视频属性抓取结束
# 开始BV号为17z4y1o7G2视频属性的抓取
# 开始BV号为17z4y1o7G2视频属性的抓取
# BV号为17z4y1o7G2的视频属性抓取结束
# 开始BV号为1a5411L7Ve视频属性的抓取
# BV号为1a5411L7Ve的视频属性抓取结束
# 开始BV号为1FV41127Hn视频属性的抓取
# BV号为1FV41127Hn的视频属性抓取结束
# 开始BV号为1jD4y1d7sp视频属性的抓取
# BV号为1jD4y1d7sp的视频属性抓取结束
# 开始BV号为18Z4y1V76S视频属性的抓取
# BV号为18Z4y1V76S的视频属性抓取结束
# 开始BV号为1ty4y1r7fc视频属性的抓取
# BV号为1ty4y1r7fc的视频属性抓取结束
# 开始BV号为14h41197Sy视频属性的抓取
# BV号为14h41197Sy的视频属性抓取结束
# 开始BV号为1jt4y1v7ya视频属性的抓取
# BV号为1jt4y1v7ya的视频属性抓取结束
# 开始BV号为1KV411275s视频属性的抓取
# BV号为1KV411275s的视频属性抓取结束
# 开始BV号为1Vt4y1v79u视频属性的抓取
# BV号为1Vt4y1v79u的视频属性抓取结束
# 开始BV号为1PA411E7Gh视频属性的抓取
# BV号为1PA411E7Gh的视频属性抓取结束
# 开始BV号为13D4y197RX视频属性的抓取
# BV号为13D4y197RX的视频属性抓取结束
# 开始BV号为1wp4y1Y78N视频属性的抓取
# BV号为1wp4y1Y78N的视频属性抓取结束
# 开始BV号为1Ba411A7Lv视频属性的抓取
# BV号为1Ba411A7Lv的视频属性抓取结束
# 开始BV号为1CD4y1d711视频属性的抓取
# BV号为1CD4y1d711的视频属性抓取结束
# 开始BV号为1uA41177qZ视频属性的抓取
# BV号为1uA41177qZ的视频属性抓取结束
# 开始BV号为1sp4y1k7X5视频属性的抓取
# BV号为1sp4y1k7X5的视频属性抓取结束
# 开始BV号为1GT4y1F7cC视频属性的抓取
# BV号为1GT4y1F7cC的视频属性抓取结束
# 开始BV号为14K411A7BZ视频属性的抓取
# BV号为14K411A7BZ的视频属性抓取结束
# 开始BV号为12y4y1r7uE视频属性的抓取
# BV号为12y4y1r7uE的视频属性抓取结束
# 开始BV号为1gD4y1d7wz视频属性的抓取
# BV号为1gD4y1d7wz的视频属性抓取结束
# 开始BV号为1354y1C79m视频属性的抓取
# BV号为1354y1C79m的视频属性抓取结束
# 开始BV号为1xa4y1L7tR视频属性的抓取
# BV号为1xa4y1L7tR的视频属性抓取结束
# 开始BV号为1Yi4y1E7Ky视频属性的抓取
# BV号为1Yi4y1E7Ky的视频属性抓取结束
# 开始BV号为1Sa4y1L7BJ视频属性的抓取
# BV号为1Sa4y1L7BJ的视频属性抓取结束
# 开始BV号为1Zy4y1r7D1视频属性的抓取
# BV号为1Zy4y1r7D1的视频属性抓取结束
# 开始BV号为1Mt4y1i7WD视频属性的抓取
# BV号为1Mt4y1i7WD的视频属性抓取结束
# 开始BV号为17K411A7F7视频属性的抓取
# BV号为17K411A7F7的视频属性抓取结束
# 开始BV号为1ia411A7nH视频属性的抓取
# BV号为1ia411A7nH的视频属性抓取结束
# 开始BV号为1vz4y1d7To视频属性的抓取
# BV号为1vz4y1d7To的视频属性抓取结束
# 开始BV号为11z4y1d7tD视频属性的抓取
# BV号为11z4y1d7tD的视频属性抓取结束
# 开始BV号为1RK4y177vi视频属性的抓取
# BV号为1RK4y177vi的视频属性抓取结束
# 开始BV号为1VT4y1w7PF视频属性的抓取
# BV号为1VT4y1w7PF的视频属性抓取结束
# 开始BV号为1Ct4y1q7K5视频属性的抓取
# 开始BV号为1Ct4y1q7K5视频属性的抓取
# BV号为1Ct4y1q7K5的视频属性抓取结束
# 开始BV号为1eK411N7Y5视频属性的抓取
# BV号为1eK411N7Y5的视频属性抓取结束
# 开始BV号为11t4y1q7Fj视频属性的抓取
# BV号为11t4y1q7Fj的视频属性抓取结束
# 开始BV号为1Zz4y1C7mG视频属性的抓取
# BV号为1Zz4y1C7mG的视频属性抓取结束
# 开始BV号为1PK4y1h72V视频属性的抓取
# 开始BV号为1PK4y1h72V视频属性的抓取
# BV号为1PK4y1h72V的视频属性抓取结束
# 开始BV号为1PD4y1d7rP视频属性的抓取
# BV号为1PD4y1d7rP的视频属性抓取结束
# 开始BV号为1vK411A7eQ视频属性的抓取
# BV号为1vK411A7eQ的视频属性抓取结束
# 开始BV号为1EV411y7mr视频属性的抓取
# BV号为1EV411y7mr的视频属性抓取结束
# 开始BV号为1SA411L7vC视频属性的抓取
# BV号为1SA411L7vC的视频属性抓取结束
# 开始BV号为1ap4y1Y712视频属性的抓取
# BV号为1ap4y1Y712的视频属性抓取结束
# 开始BV号为1Sf4y1B7ZU视频属性的抓取
# BV号为1Sf4y1B7ZU的视频属性抓取结束
# 2020-12-18 09:42:00.407223

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-14-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_meishi_zhentan.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月    99   99    99   99   99   99   99   99    99      99   99    99   99
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月     97   97    97   97   97   97   97   97    97      97   97    97   97
# 3月     98   98    98   98   98   98   98   98    98      98   98    98   98
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月     98   98    98   98   98   98   98   98    98      98   98    98   98
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月   99   99   99   99   99   99    99
# 1月   100  100  100  100  100  100   100
# 2月    97   97   97   97   97   97    97
# 3月    98   98   98   98   98   98    98
# 4月   100  100  100  100  100  100   100
# 5月    98   98   98   98   98   98    98
# 6月   100  100  100  100  100  100   100
# 7月   100  100  100  100  100  100   100
# 8月   100  100  100  100  100  100   100
# 9月   100  100  100  100  100  100   100

# %%
channel_meishi_zhentan.to_json('channel_meishi_zhentan.json')

# %%
pd.set_option('display.max_rows', None)

# %%
channel_youxi_danji[channel_youxi_danji['时间']=='4月']
# Out:
#             时间            作者名  作者类型      粉丝数   投稿数  \
# 1h54y1d7Qq  4月            鹤吱菌  个人认证   191.3万    81
# 1L64y1M7Dp  4月            老番茄  个人认证  1360.1万   348
# 18K41157Tu  4月            老番茄  个人认证  1360.1万   348
# 1PT4y1G7ME  4月            老番茄  个人认证  1360.1万   348
# 1S54y197uX  4月           徐大虾咯  个人认证   570.1万   224
# 1ti4y1t7YM  4月            老番茄  个人认证  1360.1万   348
# 1Ai4y1b7ET  4月            敖厂长  个人认证   735.1万   348
# 1Up4y1C7PB  4月        丢鹏D1uuu     无     8.4万    20
# 1wi4y187bu  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 13t4y1U7kQ  4月           徐大虾咯  个人认证   570.1万   224
# 1fe411x7FA  4月         芦苇草的梦想  个人认证    29.3万   726
# 1LA411b7Dt  4月      LexBurner  个人认证   929.6万   383
# 1Ji4y1t7T9  4月            沧桑丸  个人认证    86.6万    57
# 1Lz411z72u  4月           徐大虾咯  个人认证   570.1万   224
# 13T4y1G7WT  4月          逗比的雀巢  个人认证   242.3万    82
# 1T54y197DH  4月           徐大虾咯  个人认证   570.1万   224
# 1Va4y147fH  4月            鹤吱菌  个人认证   191.3万    81
# 1tt4y127yy  4月           小潮院长  个人认证   481.6万   266
# 16T4y1g7RY  4月         吉儿一范伦婷  个人认证    67.6万    79
# 1754y197Da  4月            敖厂长  个人认证   735.1万   348
# 1hK41157M3  4月           花少北丶  个人认证   491.9万   173
# 1Rk4y197kw  4月       3DM游戏网官方  机构认证    13.5万  2822
# 1ST4y1G7E1  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1H54y1d76B  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1Sz411B7P4  4月          游汐_YX  个人认证    12.9万    98
# 1CT4y1g7Ya  4月    育碧中国Ubisoft  机构认证    64.5万  1211
# 12T4y1G7AZ  4月          与山0v0  个人认证   208.5万   557
# 1b5411x79t  4月        东尼ookii  个人认证   331.7万   166
# 1hA411h7Ky  4月          与山0v0  个人认证   208.5万   557
# 1Gt4y127AJ  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 13f4y1S7sa  4月          我是凉菜啊     无     8516   447
# 1KJ411e7nN                              如何提高审美？审美有无高低？审美是谁建立？  数码  摄影摄像  普通视频
# ...                                                       ...  ..   ...   ...
# 1cr4y1w7ig              困难重重，国家天文签约摄影师遭遇拍摄滑铁卢？！【华为Mate40 Pro】  数码  摄影摄像  活动作品
# 1Y5411L7TW                     富士X-S10相机测试——2020 apsc画幅性价比最强机  数码  摄影摄像  活动作品
# 1c541177hR      索尼（Sony）12-24mm F2.8 GM深度评测，只要买得起，它就是一颗完美的镜头！  数码  摄影摄像  普通视频
# 1DA41177UY                            大疆旗舰稳定器 - DJI RS 2 正式登场  数码  摄影摄像  普通视频
# 1rA411776p                 让我非常失望的佳能M50 Mark II（来自一代老用户的真实心声）  数码  摄影摄像  普通视频
#
#             ...                                                 标签   视频长度  \
# 1gJ411n7hp  ...                         [摄影, 数码, 摄影摄像, 数码, 教程, 器材]  01:44
# 1tJ41187w6  ...  [相机, 数码, 摄影摄像, 数码, 何同学, 啊吗粽, 宝剑嫂, 自媒体, 大祥哥, 体验...  30:03
# 1i7411i7yA  ...        [摄影, 短片, 数码, 摄影摄像, 数码, 创意, YOUTUBE, 镜头, 老蛙]  04:51
# 1gJ411G7Cs  ...           [摄影, 数码, 摄影摄像, 数码, VLOG, 后期, 教程, ps, 器材]  06:01
# 1KJ411e7nN  ...  [校园vlog, 相机, 脱口秀, 摄影, 公开课, vlog, 科普, 数码, 摄影摄像,...  27:08
# ...         ...                                                ...    ...
# 1cr4y1w7ig  ...  [vlog, 数码, 摄影摄像, 数码, 放心购机攻略, 敦煌, 星空, 手机摄影, 华为,...  11:43
# 1Y5411L7TW  ...  [相机, 摄影, 数码, 摄影摄像, 数码, 数码玩家训练营, 拍照, 测评, xs10, ...  10:20
# 1c541177hR  ...  [摄影, 数码, 摄影摄像, 数码, 评测, 超广角大光圈, 摄像, 镜头, 数码评测, 超...  21:23
# 1DA41177UY  ...   [相机, 摄影, 数码, 摄影摄像, 数码, 科技, 测评, 器材, 大疆, DJI, 稳定器]  02:26
# 1rA411776p  ...  [vlog, 数码, 摄影摄像, 数码, 佳能, 测评, 体验, m50 mark ii, ...  06:30
#
#                播放量    点赞数   投币数   收藏数   转发数   评论数   弹幕数 有无分集
# 1gJ411n7hp  222.4万   9.7万  2.0万  1.4万  4980  3182  1571    否
# 1tJ41187w6  134.0万  10.7万  8.4万  5.8万  8907  3935  3.0万    否
# 1i7411i7yA   57.8万   4.4万  1.0万  1.6万  2043   641   983    否
# 1gJ411G7Cs   42.3万   3.3万  3.4万  8.6万  2605  1405   612    否
# 1KJ411e7nN   39.6万   4.8万  5.4万  3.4万  6217  1156  1.0万    否
# ...            ...    ...   ...   ...   ...   ...   ...  ...
# 1cr4y1w7ig    4.3万   3051  1391   692   255   337   349    否
# 1Y5411L7TW    4.3万    773   219   221   111   273   104    否
# 1c541177hR    4.1万   1469   443   297   123   250   561    否
# 1DA41177UY    4.1万   1565   197   334   640   171   110    否
# 1rA411776p    4.1万   1262   267   147   101   385   314    否
#
# [999 rows x 21 columns]
