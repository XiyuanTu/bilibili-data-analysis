# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_meishi_jilu=pd.DataFrame(columns=columns)
channel_meishi_jilu
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[18]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '美食'

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[18]/div/a/span').click()  #选择频道

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[6]/a').click()  #选择子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[6]/a').text
sub_channel
# Out:
# '美食记录'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(5,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_meishi_jilu.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-18 16:24:21.452880
# <ipython-input-42-3bb3c4302f8b>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-42-3bb3c4302f8b>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-42-3bb3c4302f8b>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1ck4y1k7aw视频属性的抓取
# E:\anaconda\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# BV号为1ck4y1k7aw的视频属性抓取结束
# <ipython-input-42-3bb3c4302f8b>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1KK4y187Qw视频属性的抓取
# BV号为1KK4y187Qw的视频属性抓取结束
# 开始BV号为1Xp4y1X7Ki视频属性的抓取
# BV号为1Xp4y1X7Ki的视频属性抓取结束
# 开始BV号为1xt4y1C7yv视频属性的抓取
# BV号为1xt4y1C7yv的视频属性抓取结束
# 开始BV号为1YK4y1t7Lr视频属性的抓取
# BV号为1YK4y1t7Lr的视频属性抓取结束
# 开始BV号为1wC4y1s7ZL视频属性的抓取
# BV号为1wC4y1s7ZL的视频属性抓取结束
# 开始BV号为1jK411s7rD视频属性的抓取
# BV号为1jK411s7rD的视频属性抓取结束
# 开始BV号为1J54y1X7vd视频属性的抓取
# BV号为1J54y1X7vd的视频属性抓取结束
# 开始BV号为1Bt4y1C7qm视频属性的抓取
# BV号为1Bt4y1C7qm的视频属性抓取结束
# 开始BV号为1bg4y1B7zs视频属性的抓取
# BV号为1bg4y1B7zs的视频属性抓取结束
# 开始BV号为15Q4y1P7YN视频属性的抓取
# BV号为15Q4y1P7YN的视频属性抓取结束
# 开始BV号为1xC4y1H72h视频属性的抓取
# BV号为1xC4y1H72h的视频属性抓取结束
# 开始BV号为1vQ4y1N71K视频属性的抓取
# BV号为1vQ4y1N71K的视频属性抓取结束
# 开始BV号为1AZ4y1W7iZ视频属性的抓取
# BV号为1AZ4y1W7iZ的视频属性抓取结束
# 开始BV号为1ZZ4y1p732视频属性的抓取
# BV号为1ZZ4y1p732的视频属性抓取结束
# 开始BV号为1df4y117dS视频属性的抓取
# BV号为1df4y117dS的视频属性抓取结束
# 开始BV号为1Sz411q7n6视频属性的抓取
# BV号为1Sz411q7n6的视频属性抓取结束
# 开始BV号为18T4y1g7ss视频属性的抓取
# BV号为18T4y1g7ss的视频属性抓取结束
# 开始BV号为1Hz411z7V2视频属性的抓取
# BV号为1Hz411z7V2的视频属性抓取结束
# 开始BV号为1St4y117Mt视频属性的抓取
# BV号为1St4y117Mt的视频属性抓取结束
# 开始BV号为1hz411q77W视频属性的抓取
# BV号为1hz411q77W的视频属性抓取结束
# 开始BV号为1Wg4y1B7Ba视频属性的抓取
# BV号为1Wg4y1B7Ba的视频属性抓取结束
# 开始BV号为1Ut4y1171q视频属性的抓取
# BV号为1Ut4y1171q的视频属性抓取结束
# 开始BV号为1kC4y1p7T9视频属性的抓取
# BV号为1kC4y1p7T9的视频属性抓取结束
# 开始BV号为1vi4y1s711视频属性的抓取
# BV号为1vi4y1s711的视频属性抓取结束
# 开始BV号为1nZ4y1W7yq视频属性的抓取
# BV号为1nZ4y1W7yq的视频属性抓取结束
# 开始BV号为1fV411k7Wc视频属性的抓取
# BV号为1fV411k7Wc的视频属性抓取结束
# 开始BV号为1jK4y1t745视频属性的抓取
# BV号为1jK4y1t745的视频属性抓取结束
# 开始BV号为1kZ4y1p7bf视频属性的抓取
# BV号为1kZ4y1p7bf的视频属性抓取结束
# 开始BV号为1wV411C7om视频属性的抓取
# BV号为1wV411C7om的视频属性抓取结束
# 开始BV号为1Za4y1i7W3视频属性的抓取
# BV号为1Za4y1i7W3的视频属性抓取结束
# 开始BV号为1SK411H7wC视频属性的抓取
# BV号为1SK411H7wC的视频属性抓取结束
# 开始BV号为19i4y147Sz视频属性的抓取
# BV号为19i4y147Sz的视频属性抓取结束
# 开始BV号为1wC4y1s74Z视频属性的抓取
# BV号为1wC4y1s74Z的视频属性抓取结束
# 开始BV号为1oT4y1u7rW视频属性的抓取
# BV号为1oT4y1u7rW的视频属性抓取结束
# 开始BV号为17e411W7Ad视频属性的抓取
# BV号为17e411W7Ad的视频属性抓取结束
# 开始BV号为1ck4y1k7tj视频属性的抓取
# BV号为1ck4y1k7tj的视频属性抓取结束
# 开始BV号为1kV411d7Uc视频属性的抓取
# BV号为1kV411d7Uc的视频属性抓取结束
# 开始BV号为1hg4y1i7g7视频属性的抓取
# BV号为1hg4y1i7g7的视频属性抓取结束
# 开始BV号为1zQ4y1A7oF视频属性的抓取
# BV号为1zQ4y1A7oF的视频属性抓取结束
# 开始BV号为1qK411W7d5视频属性的抓取
# BV号为1qK411W7d5的视频属性抓取结束
# 开始BV号为17z411z7Xm视频属性的抓取
# BV号为17z411z7Xm的视频属性抓取结束
# 开始BV号为1mA411t7Hr视频属性的抓取
# BV号为1mA411t7Hr的视频属性抓取结束
# 开始BV号为1Sz411v72Z视频属性的抓取
# BV号为1Sz411v72Z的视频属性抓取结束
# 开始BV号为1TT4y1g7k8视频属性的抓取
# BV号为1TT4y1g7k8的视频属性抓取结束
# 开始BV号为15541147zA视频属性的抓取
# BV号为15541147zA的视频属性抓取结束
# 开始BV号为1sg4y1B7je视频属性的抓取
# BV号为1sg4y1B7je的视频属性抓取结束
# 开始BV号为1NQ4y1K7AX视频属性的抓取
# BV号为1NQ4y1K7AX的视频属性抓取结束
# 开始BV号为1Qe411s73F视频属性的抓取
# BV号为1Qe411s73F的视频属性抓取结束
# 开始BV号为1bK411W7Tt视频属性的抓取
# BV号为1bK411W7Tt的视频属性抓取结束
# 开始BV号为11Z4y1p7Gs视频属性的抓取
# BV号为11Z4y1p7Gs的视频属性抓取结束
# 开始BV号为1nk4y167L8视频属性的抓取
# BV号为1nk4y167L8的视频属性抓取结束
# 开始BV号为1QK4y1b7YJ视频属性的抓取
# BV号为1QK4y1b7YJ的视频属性抓取结束
# 开始BV号为1R5411s74b视频属性的抓取
# BV号为1R5411s74b的视频属性抓取结束
# 开始BV号为11g4y1q7xn视频属性的抓取
# BV号为11g4y1q7xn的视频属性抓取结束
# 开始BV号为1mV411k7pb视频属性的抓取
# BV号为1mV411k7pb的视频属性抓取结束
# 开始BV号为1Yz411q7No视频属性的抓取
# BV号为1Yz411q7No的视频属性抓取结束
# 开始BV号为1zv411z7cR视频属性的抓取
# BV号为1zv411z7cR的视频属性抓取结束
# 开始BV号为1yp4y1979H视频属性的抓取
# BV号为1yp4y1979H的视频属性抓取结束
# 开始BV号为1yk4y1k7y3视频属性的抓取
# BV号为1yk4y1k7y3的视频属性抓取结束
# 开始BV号为16i4y1478q视频属性的抓取
# BV号为16i4y1478q的视频属性抓取结束
# 开始BV号为18V411C7Lu视频属性的抓取
# BV号为18V411C7Lu的视频属性抓取结束
# 开始BV号为1cz411B7rS视频属性的抓取
# BV号为1cz411B7rS的视频属性抓取结束
# 开始BV号为1Qe411p7ne视频属性的抓取
# BV号为1Qe411p7ne的视频属性抓取结束
# 开始BV号为19t4y1C723视频属性的抓取
# BV号为19t4y1C723的视频属性抓取结束
# 开始BV号为1yz4y1R7Js视频属性的抓取
# BV号为1yz4y1R7Js的视频属性抓取结束
# 开始BV号为1WA411t7bu视频属性的抓取
# BV号为1WA411t7bu的视频属性抓取结束
# 开始BV号为1Ag4y1z7ux视频属性的抓取
# BV号为1Ag4y1z7ux的视频属性抓取结束
# 开始BV号为1ee411W75v视频属性的抓取
# BV号为1ee411W75v的视频属性抓取结束
# 开始BV号为1L541147Vh视频属性的抓取
# BV号为1L541147Vh的视频属性抓取结束
# 开始BV号为17z411B7LS视频属性的抓取
# BV号为17z411B7LS的视频属性抓取结束
# 开始BV号为14K4y187i8视频属性的抓取
# BV号为14K4y187i8的视频属性抓取结束
# 开始BV号为1Mz411q7w6视频属性的抓取
# BV号为1Mz411q7w6的视频属性抓取结束
# 开始BV号为145411s7vA视频属性的抓取
# BV号为145411s7vA的视频属性抓取结束
# 开始BV号为1zg4y1i7R9视频属性的抓取
# BV号为1zg4y1i7R9的视频属性抓取结束
# 开始BV号为1Az4y1d7M1视频属性的抓取
# BV号为1Az4y1d7M1的视频属性抓取结束
# 开始BV号为1m5411s7jD视频属性的抓取
# BV号为1m5411s7jD的视频属性抓取结束
# 开始BV号为1GQ4y1P7ab视频属性的抓取
# BV号为1GQ4y1P7ab的视频属性抓取结束
# 开始BV号为1wi4y147dC视频属性的抓取
# BV号为1wi4y147dC的视频属性抓取结束
# 开始BV号为1ta4y1e7Nz视频属性的抓取
# BV号为1ta4y1e7Nz的视频属性抓取结束
# 开始BV号为1ba4y1i7Ys视频属性的抓取
# BV号为1ba4y1i7Ys的视频属性抓取结束
# 开始BV号为12K411W78b视频属性的抓取
# BV号为12K411W78b的视频属性抓取结束
# 开始BV号为1Hz4y1R73F视频属性的抓取
# BV号为1Hz4y1R73F的视频属性抓取结束
# 开始BV号为1UK411H7aL视频属性的抓取
# BV号为1UK411H7aL的视频属性抓取结束
# 开始BV号为18Q4y1N76F视频属性的抓取
# BV号为18Q4y1N76F的视频属性抓取结束
# 开始BV号为1F5411s7uv视频属性的抓取
# BV号为1F5411s7uv的视频属性抓取结束
# 开始BV号为14t4y117S7视频属性的抓取
# BV号为14t4y117S7的视频属性抓取结束
# 开始BV号为1yz411q7dk视频属性的抓取
# BV号为1yz411q7dk的视频属性抓取结束
# 开始BV号为1HT4y1u7Yq视频属性的抓取
# BV号为1HT4y1u7Yq的视频属性抓取结束
# 开始BV号为1Wa4y1e731视频属性的抓取
# BV号为1Wa4y1e731的视频属性抓取结束
# 开始BV号为1XK411W7cH视频属性的抓取
# BV号为1XK411W7cH的视频属性抓取结束
# 开始BV号为13e411W7bm视频属性的抓取
# BV号为13e411W7bm的视频属性抓取结束
# 开始BV号为1Gp4y1Q716视频属性的抓取
# BV号为1Gp4y1Q716的视频属性抓取结束
# 开始BV号为1YK4y187QK视频属性的抓取
# BV号为1YK4y187QK的视频属性抓取结束
# 开始BV号为15z4y1d7m7视频属性的抓取
# BV号为15z4y1d7m7的视频属性抓取结束
# 开始BV号为16C4y1H7pz视频属性的抓取
# BV号为16C4y1H7pz的视频属性抓取结束
# 开始BV号为1Xg4y1q7Nc视频属性的抓取
# BV号为1Xg4y1q7Nc的视频属性抓取结束
# 开始BV号为1kz411q7wQ视频属性的抓取
# BV号为1kz411q7wQ的视频属性抓取结束
# 开始BV号为1ee411p7m6视频属性的抓取
# BV号为1ee411p7m6的视频属性抓取结束
# 开始BV号为1Vk4y167RE视频属性的抓取
# BV号为1Vk4y167RE的视频属性抓取结束
# 开始BV号为1wA411i7zQ视频属性的抓取
# BV号为1wA411i7zQ的视频属性抓取结束
# 开始BV号为15V411k7GF视频属性的抓取
# BV号为15V411k7GF的视频属性抓取结束
# 开始BV号为1CK411p7JQ视频属性的抓取
# BV号为1CK411p7JQ的视频属性抓取结束
# 开始BV号为16f4y1y7ee视频属性的抓取
# BV号为16f4y1y7ee的视频属性抓取结束
# 开始BV号为1uV411k74o视频属性的抓取
# BV号为1uV411k74o的视频属性抓取结束
# 开始BV号为15V411k7rW视频属性的抓取
# BV号为15V411k7rW的视频属性抓取结束
# 开始BV号为14K4y147mi视频属性的抓取
# BV号为14K4y147mi的视频属性抓取结束
# 开始BV号为1Ct4y197ZV视频属性的抓取
# BV号为1Ct4y197ZV的视频属性抓取结束
# 开始BV号为1b5411W7Uk视频属性的抓取
# BV号为1b5411W7Uk的视频属性抓取结束
# 开始BV号为1Pf4y117n9视频属性的抓取
# BV号为1Pf4y117n9的视频属性抓取结束
# 开始BV号为1Lz4y1X7cf视频属性的抓取
# BV号为1Lz4y1X7cf的视频属性抓取结束
# 开始BV号为13f4y1m7kr视频属性的抓取
# BV号为13f4y1m7kr的视频属性抓取结束
# 开始BV号为12C4y1871c视频属性的抓取
# BV号为12C4y1871c的视频属性抓取结束
# 开始BV号为1Vv41167V1视频属性的抓取
# BV号为1Vv41167V1的视频属性抓取结束
# 开始BV号为1sf4y1173p视频属性的抓取
# BV号为1sf4y1173p的视频属性抓取结束
# 开始BV号为1yv411B7LP视频属性的抓取
# BV号为1yv411B7LP的视频属性抓取结束
# 开始BV号为1ug4y1v7Te视频属性的抓取
# BV号为1ug4y1v7Te的视频属性抓取结束
# 开始BV号为18Z4y1W7cF视频属性的抓取
# BV号为18Z4y1W7cF的视频属性抓取结束
# 开始BV号为1d5411p72U视频属性的抓取
# BV号为1d5411p72U的视频属性抓取结束
# 开始BV号为19K411n7hG视频属性的抓取
# BV号为19K411n7hG的视频属性抓取结束
# 开始BV号为1AC4y1h7Np视频属性的抓取
# BV号为1AC4y1h7Np的视频属性抓取结束
# 开始BV号为1MK411p7dG视频属性的抓取
# BV号为1MK411p7dG的视频属性抓取结束
# 开始BV号为1HV411r7nS视频属性的抓取
# BV号为1HV411r7nS的视频属性抓取结束
# 开始BV号为1mi4y1s7D8视频属性的抓取
# BV号为1mi4y1s7D8的视频属性抓取结束
# 开始BV号为13C4y1a7pv视频属性的抓取
# BV号为13C4y1a7pv的视频属性抓取结束
# <ipython-input-42-3bb3c4302f8b>:190: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1yD4y1D7Xv视频属性的抓取
# BV号为1yD4y1D7Xv的视频属性抓取结束
# 开始BV号为1Sf4y117LF视频属性的抓取
# BV号为1Sf4y117LF的视频属性抓取结束
# 开始BV号为1wD4y1Q7BN视频属性的抓取
# BV号为1wD4y1Q7BN的视频属性抓取结束
# 开始BV号为1Xp4y1U71K视频属性的抓取
# BV号为1Xp4y1U71K的视频属性抓取结束
# 开始BV号为1St4y1X73d视频属性的抓取
# BV号为1St4y1X73d的视频属性抓取结束
# 开始BV号为1GZ4y1H7RC视频属性的抓取
# BV号为1GZ4y1H7RC的视频属性抓取结束
# 开始BV号为1rf4y117sN视频属性的抓取
# BV号为1rf4y117sN的视频属性抓取结束
# 开始BV号为12z411i7wB视频属性的抓取
# BV号为12z411i7wB的视频属性抓取结束
# 开始BV号为1ED4y1Q7Qm视频属性的抓取
# BV号为1ED4y1Q7Qm的视频属性抓取结束
# 开始BV号为1Ji4y1G7b3视频属性的抓取
# BV号为1Ji4y1G7b3的视频属性抓取结束
# 开始BV号为1az4y1Q7zC视频属性的抓取
# BV号为1az4y1Q7zC的视频属性抓取结束
# 开始BV号为1CK411n7mb视频属性的抓取
# BV号为1CK411n7mb的视频属性抓取结束
# 开始BV号为1HC4y1a77v视频属性的抓取
# BV号为1HC4y1a77v的视频属性抓取结束
# 开始BV号为1xz411e7Tx视频属性的抓取
# BV号为1xz411e7Tx的视频属性抓取结束
# 开始BV号为1oC4y1a7KL视频属性的抓取
# BV号为1oC4y1a7KL的视频属性抓取结束
# 开始BV号为1Dt4y1X7Gs视频属性的抓取
# BV号为1Dt4y1X7Gs的视频属性抓取结束
# 开始BV号为17v411B79e视频属性的抓取
# BV号为17v411B79e的视频属性抓取结束
# 开始BV号为13i4y1x7zg视频属性的抓取
# BV号为13i4y1x7zg的视频属性抓取结束
# 开始BV号为1CD4y1D74Y视频属性的抓取
# BV号为1CD4y1D74Y的视频属性抓取结束
# 开始BV号为1Af4y117im视频属性的抓取
# BV号为1Af4y117im的视频属性抓取结束
# 开始BV号为1n54y1Q7B7视频属性的抓取
# BV号为1n54y1Q7B7的视频属性抓取结束
# 开始BV号为1Rg4y1i7mx视频属性的抓取
# BV号为1Rg4y1i7mx的视频属性抓取结束
# 开始BV号为1m5411W7J1视频属性的抓取
# BV号为1m5411W7J1的视频属性抓取结束
# 开始BV号为1Tz411v7YU视频属性的抓取
# BV号为1Tz411v7YU的视频属性抓取结束
# 开始BV号为1FT4y1J7aq视频属性的抓取
# BV号为1FT4y1J7aq的视频属性抓取结束
# 开始BV号为1dZ4y1n7C3视频属性的抓取
# BV号为1dZ4y1n7C3的视频属性抓取结束
# 开始BV号为12p4y1D7KZ视频属性的抓取
# BV号为12p4y1D7KZ的视频属性抓取结束
# 开始BV号为1Ba4y1e7G3视频属性的抓取
# BV号为1Ba4y1e7G3的视频属性抓取结束
# 开始BV号为1gz411i7DA视频属性的抓取
# BV号为1gz411i7DA的视频属性抓取结束
# 开始BV号为1NK411p7dL视频属性的抓取
# BV号为1NK411p7dL的视频属性抓取结束
# 开始BV号为1uv411B7rK视频属性的抓取
# BV号为1uv411B7rK的视频属性抓取结束
# 开始BV号为11a4y1Y738视频属性的抓取
# BV号为11a4y1Y738的视频属性抓取结束
# 开始BV号为1wz411i7x9视频属性的抓取
# BV号为1wz411i7x9的视频属性抓取结束
# 开始BV号为1Ei4y1x7p7视频属性的抓取
# BV号为1Ei4y1x7p7的视频属性抓取结束
# 开始BV号为1eV411k7Q4视频属性的抓取
# BV号为1eV411k7Q4的视频属性抓取结束
# 开始BV号为17Z4y1W7C2视频属性的抓取
# BV号为17Z4y1W7C2的视频属性抓取结束
# 开始BV号为1nA411i7u7视频属性的抓取
# BV号为1nA411i7u7的视频属性抓取结束
# 开始BV号为1Pz411i7ip视频属性的抓取
# BV号为1Pz411i7ip的视频属性抓取结束
# 开始BV号为1EZ4y1W7ZH视频属性的抓取
# BV号为1EZ4y1W7ZH的视频属性抓取结束
# 开始BV号为1hz4y1X7x7视频属性的抓取
# BV号为1hz4y1X7x7的视频属性抓取结束
# 开始BV号为1wv411B72i视频属性的抓取
# BV号为1wv411B72i的视频属性抓取结束
# 开始BV号为1Lv41167aQ视频属性的抓取
# BV号为1Lv41167aQ的视频属性抓取结束
# 开始BV号为1cp4y1D7uc视频属性的抓取
# BV号为1cp4y1D7uc的视频属性抓取结束
# 开始BV号为1ji4y1G7CC视频属性的抓取
# BV号为1ji4y1G7CC的视频属性抓取结束
# 开始BV号为1eD4y1D7Zt视频属性的抓取
# BV号为1eD4y1D7Zt的视频属性抓取结束
# 开始BV号为15f4y117Dp视频属性的抓取
# BV号为15f4y117Dp的视频属性抓取结束
# 开始BV号为1qK411n7cP视频属性的抓取
# BV号为1qK411n7cP的视频属性抓取结束
# 开始BV号为14p4y1U7uq视频属性的抓取
# BV号为14p4y1U7uq的视频属性抓取结束
# 开始BV号为1sv411B76D视频属性的抓取
# BV号为1sv411B76D的视频属性抓取结束
# 开始BV号为1k5411Y78X视频属性的抓取
# BV号为1k5411Y78X的视频属性抓取结束
# 开始BV号为1Wk4y1r7o2视频属性的抓取
# BV号为1Wk4y1r7o2的视频属性抓取结束
# 开始BV号为1Qf4y127en视频属性的抓取
# BV号为1Qf4y127en的视频属性抓取结束
# 开始BV号为1Eg4y1v7ur视频属性的抓取
# BV号为1Eg4y1v7ur的视频属性抓取结束
# 开始BV号为1Xi4y1s7BK视频属性的抓取
# BV号为1Xi4y1s7BK的视频属性抓取结束
# 开始BV号为1nC4y1a7yU视频属性的抓取
# BV号为1nC4y1a7yU的视频属性抓取结束
# 开始BV号为1Yp4y1U7q6视频属性的抓取
# BV号为1Yp4y1U7q6的视频属性抓取结束
# 开始BV号为1wT4y1J7Fk视频属性的抓取
# BV号为1wT4y1J7Fk的视频属性抓取结束
# 开始BV号为1uz4y1R7rN视频属性的抓取
# BV号为1uz4y1R7rN的视频属性抓取结束
# 开始BV号为1uZ4y1H7Mx视频属性的抓取
# BV号为1uZ4y1H7Mx的视频属性抓取结束
# 开始BV号为1LV411k7GA视频属性的抓取
# BV号为1LV411k7GA的视频属性抓取结束
# 开始BV号为1cD4y1Q72S视频属性的抓取
# BV号为1cD4y1Q72S的视频属性抓取结束
# 开始BV号为1XC4y1h7FY视频属性的抓取
# BV号为1XC4y1h7FY的视频属性抓取结束
# 开始BV号为1fK411p73r视频属性的抓取
# BV号为1fK411p73r的视频属性抓取结束
# 开始BV号为1Kz411i7vv视频属性的抓取
# BV号为1Kz411i7vv的视频属性抓取结束
# 开始BV号为1HD4y1Q7dS视频属性的抓取
# BV号为1HD4y1Q7dS的视频属性抓取结束
# 开始BV号为1gD4y1S7RH视频属性的抓取
# BV号为1gD4y1S7RH的视频属性抓取结束
# 开始BV号为1Lg4y1v7iu视频属性的抓取
# BV号为1Lg4y1v7iu的视频属性抓取结束
# 开始BV号为1s5411W7f4视频属性的抓取
# BV号为1s5411W7f4的视频属性抓取结束
# 开始BV号为1r5411Y7ZG视频属性的抓取
# BV号为1r5411Y7ZG的视频属性抓取结束
# 开始BV号为1zZ4y1H7ET视频属性的抓取
# BV号为1zZ4y1H7ET的视频属性抓取结束
# 开始BV号为1Tz4y1X7qY视频属性的抓取
# BV号为1Tz4y1X7qY的视频属性抓取结束
# 开始BV号为1yt4y1X7ah视频属性的抓取
# BV号为1yt4y1X7ah的视频属性抓取结束
# 开始BV号为1Dv411B7tU视频属性的抓取
# BV号为1Dv411B7tU的视频属性抓取结束
# 开始BV号为1w54y1B7Q8视频属性的抓取
# BV号为1w54y1B7Q8的视频属性抓取结束
# 开始BV号为1pC4y1b7qQ视频属性的抓取
# BV号为1pC4y1b7qQ的视频属性抓取结束
# 开始BV号为1Ei4y137ws视频属性的抓取
# BV号为1Ei4y137ws的视频属性抓取结束
# 开始BV号为1s54y1S7Uk视频属性的抓取
# BV号为1s54y1S7Uk的视频属性抓取结束
# 开始BV号为15p4y1S7YE视频属性的抓取
# BV号为15p4y1S7YE的视频属性抓取结束
# 开始BV号为1Za4y1h7MY视频属性的抓取
# BV号为1Za4y1h7MY的视频属性抓取结束
# 开始BV号为16f4y1R7iH视频属性的抓取
# BV号为16f4y1R7iH的视频属性抓取结束
# 开始BV号为15i4y1V7wi视频属性的抓取
# BV号为15i4y1V7wi的视频属性抓取结束
# 开始BV号为1Gh411Z7kB视频属性的抓取
# BV号为1Gh411Z7kB的视频属性抓取结束
# 开始BV号为1Wt4y1Q7VP视频属性的抓取
# BV号为1Wt4y1Q7VP的视频属性抓取结束
# 开始BV号为1zK4y1e7V8视频属性的抓取
# BV号为1zK4y1e7V8的视频属性抓取结束
# 开始BV号为1u5411e7SX视频属性的抓取
# BV号为1u5411e7SX的视频属性抓取结束
# 开始BV号为1jZ4y1u77t视频属性的抓取
# BV号为1jZ4y1u77t的视频属性抓取结束
# 开始BV号为1ii4y1G7Kx视频属性的抓取
# BV号为1ii4y1G7Kx的视频属性抓取结束
# 开始BV号为16a4y1h7Sw视频属性的抓取
# BV号为16a4y1h7Sw的视频属性抓取结束
# 开始BV号为1iV41167Sn视频属性的抓取
# BV号为1iV41167Sn的视频属性抓取结束
# 开始BV号为1Fi4y137E9视频属性的抓取
# BV号为1Fi4y137E9的视频属性抓取结束
# 开始BV号为1sA411v71o视频属性的抓取
# BV号为1sA411v71o的视频属性抓取结束
# 开始BV号为1354y1D7AS视频属性的抓取
# BV号为1354y1D7AS的视频属性抓取结束
# 开始BV号为1jz411v7js视频属性的抓取
# BV号为1jz411v7js的视频属性抓取结束
# 开始BV号为1Rp4y1i7Nx视频属性的抓取
# BV号为1Rp4y1i7Nx的视频属性抓取结束
# 开始BV号为17g4y1i74B视频属性的抓取
# BV号为17g4y1i74B的视频属性抓取结束
# 开始BV号为1U5411a7XE视频属性的抓取
# BV号为1U5411a7XE的视频属性抓取结束
# 开始BV号为1aK411J7e8视频属性的抓取
# BV号为1aK411J7e8的视频属性抓取结束
# 开始BV号为1nK4y1s7rV视频属性的抓取
# BV号为1nK4y1s7rV的视频属性抓取结束
# 开始BV号为1xt4y1D7PW视频属性的抓取
# BV号为1xt4y1D7PW的视频属性抓取结束
# 开始BV号为1o54y1v7Fg视频属性的抓取
# BV号为1o54y1v7Fg的视频属性抓取结束
# 开始BV号为13i4y137v1视频属性的抓取
# BV号为13i4y137v1的视频属性抓取结束
# 开始BV号为1Qa4y1E7xV视频属性的抓取
# BV号为1Qa4y1E7xV的视频属性抓取结束
# 开始BV号为1ZV41167Vi视频属性的抓取
# BV号为1ZV41167Vi的视频属性抓取结束
# 开始BV号为1NZ4y1u7Vz视频属性的抓取
# BV号为1NZ4y1u7Vz的视频属性抓取结束
# 开始BV号为1Rh411o7y1视频属性的抓取
# BV号为1Rh411o7y1的视频属性抓取结束
# 开始BV号为17T4y177Hx视频属性的抓取
# BV号为17T4y177Hx的视频属性抓取结束
# 开始BV号为1Sp4y1i7DC视频属性的抓取
# BV号为1Sp4y1i7DC的视频属性抓取结束
# 开始BV号为1bZ4y1u7rj视频属性的抓取
# BV号为1bZ4y1u7rj的视频属性抓取结束
# 开始BV号为1W54y1S7x2视频属性的抓取
# BV号为1W54y1S7x2的视频属性抓取结束
# 开始BV号为1oD4y1S7eu视频属性的抓取
# BV号为1oD4y1S7eu的视频属性抓取结束
# 开始BV号为1wD4y1D7XN视频属性的抓取
# BV号为1wD4y1D7XN的视频属性抓取结束
# 开始BV号为19g4y1v7oZ视频属性的抓取
# BV号为19g4y1v7oZ的视频属性抓取结束
# 开始BV号为1cT4y1E76T视频属性的抓取
# BV号为1cT4y1E76T的视频属性抓取结束
# 开始BV号为1CK4y1e7p6视频属性的抓取
# BV号为1CK4y1e7p6的视频属性抓取结束
# 开始BV号为1GZ4y1p7ez视频属性的抓取
# BV号为1GZ4y1p7ez的视频属性抓取结束
# 开始BV号为1Ua4y1h7fW视频属性的抓取
# BV号为1Ua4y1h7fW的视频属性抓取结束
# 开始BV号为1Hf4y1R7BK视频属性的抓取
# BV号为1Hf4y1R7BK的视频属性抓取结束
# 开始BV号为1nC4y1h7sF视频属性的抓取
# BV号为1nC4y1h7sF的视频属性抓取结束
# 开始BV号为1rf4y117FG视频属性的抓取
# BV号为1rf4y117FG的视频属性抓取结束
# 开始BV号为1Vk4y1m7D9视频属性的抓取
# BV号为1Vk4y1m7D9的视频属性抓取结束
# 开始BV号为1y5411Y7ao视频属性的抓取
# BV号为1y5411Y7ao的视频属性抓取结束
# 开始BV号为1ni4y1V77V视频属性的抓取
# BV号为1ni4y1V77V的视频属性抓取结束
# 开始BV号为1Nt4y1X7pr视频属性的抓取
# BV号为1Nt4y1X7pr的视频属性抓取结束
# 开始BV号为1FK4y1x7io视频属性的抓取
# BV号为1FK4y1x7io的视频属性抓取结束
# 开始BV号为1C5411Y7cb视频属性的抓取
# BV号为1C5411Y7cb的视频属性抓取结束
# 开始BV号为1oK4y1s7EB视频属性的抓取
# BV号为1oK4y1s7EB的视频属性抓取结束
# 开始BV号为15z4y1D7Cj视频属性的抓取
# BV号为15z4y1D7Cj的视频属性抓取结束
# 开始BV号为1kV41167vo视频属性的抓取
# BV号为1kV41167vo的视频属性抓取结束
# 开始BV号为1w54y1S7TX视频属性的抓取
# BV号为1w54y1S7TX的视频属性抓取结束
# 开始BV号为1Zf4y1R746视频属性的抓取
# BV号为1Zf4y1R746的视频属性抓取结束
# 开始BV号为1mp4y1U7Tu视频属性的抓取
# BV号为1mp4y1U7Tu的视频属性抓取结束
# 开始BV号为1UA411e7AC视频属性的抓取
# BV号为1UA411e7AC的视频属性抓取结束
# 开始BV号为1St4y1Q7sP视频属性的抓取
# BV号为1St4y1Q7sP的视频属性抓取结束
# 开始BV号为1b54y1S7py视频属性的抓取
# BV号为1b54y1S7py的视频属性抓取结束
# 开始BV号为1iV411676t视频属性的抓取
# BV号为1iV411676t的视频属性抓取结束
# 开始BV号为1gz4y1Q71n视频属性的抓取
# BV号为1gz4y1Q71n的视频属性抓取结束
# 开始BV号为1CV411B72J视频属性的抓取
# BV号为1CV411B72J的视频属性抓取结束
# 开始BV号为18k4y1B7MC视频属性的抓取
# BV号为18k4y1B7MC的视频属性抓取结束
# 开始BV号为1E54y1q7Xa视频属性的抓取
# BV号为1E54y1q7Xa的视频属性抓取结束
# 开始BV号为1Nz4y1Q7Y1视频属性的抓取
# BV号为1Nz4y1Q7Y1的视频属性抓取结束
# 开始BV号为1uC4y1b7o1视频属性的抓取
# BV号为1uC4y1b7o1的视频属性抓取结束
# 开始BV号为1cp4y1S79R视频属性的抓取
# BV号为1cp4y1S79R的视频属性抓取结束
# 开始BV号为18v411q7jx视频属性的抓取
# BV号为18v411q7jx的视频属性抓取结束
# 开始BV号为1c5411a7zr视频属性的抓取
# BV号为1c5411a7zr的视频属性抓取结束
# 开始BV号为1Mz411v7Mq视频属性的抓取
# BV号为1Mz411v7Mq的视频属性抓取结束
# 开始BV号为1Lp4y1S7n5视频属性的抓取
# BV号为1Lp4y1S7n5的视频属性抓取结束
# 开始BV号为1hT4y1E7uR视频属性的抓取
# BV号为1hT4y1E7uR的视频属性抓取结束
# 开始BV号为1Sp4y1i7jN视频属性的抓取
# BV号为1Sp4y1i7jN的视频属性抓取结束
# 开始BV号为1Sv411q7Jx视频属性的抓取
# BV号为1Sv411q7Jx的视频属性抓取结束
# 开始BV号为17g4y1i7aj视频属性的抓取
# BV号为17g4y1i7aj的视频属性抓取结束
# 开始BV号为14z4y1Q7mx视频属性的抓取
# BV号为14z4y1Q7mx的视频属性抓取结束
# 开始BV号为1ff4y197h5视频属性的抓取
# BV号为1ff4y197h5的视频属性抓取结束
# 开始BV号为1fk4y1z73X视频属性的抓取
# BV号为1fk4y1z73X的视频属性抓取结束
# 开始BV号为1T5411e7d5视频属性的抓取
# BV号为1T5411e7d5的视频属性抓取结束
# 开始BV号为1bD4y1U7yK视频属性的抓取
# BV号为1bD4y1U7yK的视频属性抓取结束
# 开始BV号为1Vt4y197VD视频属性的抓取
# BV号为1Vt4y197VD的视频属性抓取结束
# 开始BV号为1Mz4y1Q7b8视频属性的抓取
# BV号为1Mz4y1Q7b8的视频属性抓取结束
# 开始BV号为1S5411Y7dt视频属性的抓取
# BV号为1S5411Y7dt的视频属性抓取结束
# 开始BV号为1np4y1S7Vv视频属性的抓取
# BV号为1np4y1S7Vv的视频属性抓取结束
# 开始BV号为14K4y1x7pN视频属性的抓取
# BV号为14K4y1x7pN的视频属性抓取结束
# 开始BV号为1xz4y1Q7mc视频属性的抓取
# BV号为1xz4y1Q7mc的视频属性抓取结束
# 开始BV号为1Zf4y1R72u视频属性的抓取
# BV号为1Zf4y1R72u的视频属性抓取结束
# 开始BV号为18Z4y1T7jk视频属性的抓取
# BV号为18Z4y1T7jk的视频属性抓取结束
# 开始BV号为1mi4y137yQ视频属性的抓取
# BV号为1mi4y137yQ的视频属性抓取结束
# 开始BV号为1X54y1v7aC视频属性的抓取
# BV号为1X54y1v7aC的视频属性抓取结束
# 开始BV号为1ZK411n7TX视频属性的抓取
# BV号为1ZK411n7TX的视频属性抓取结束
# 开始BV号为1CA411i7f2视频属性的抓取
# BV号为1CA411i7f2的视频属性抓取结束
# 开始BV号为17V411672E视频属性的抓取
# BV号为17V411672E的视频属性抓取结束
# 开始BV号为1JT4y1E7aS视频属性的抓取
# BV号为1JT4y1E7aS的视频属性抓取结束
# 开始BV号为19D4y1m72E视频属性的抓取
# BV号为19D4y1m72E的视频属性抓取结束
# 开始BV号为1wk4y1m7gf视频属性的抓取
# BV号为1wk4y1m7gf的视频属性抓取结束
# 开始BV号为1nZ4y1u7d8视频属性的抓取
# BV号为1nZ4y1u7d8的视频属性抓取结束
# 开始BV号为1UD4y1m7Xp视频属性的抓取
# BV号为1UD4y1m7Xp的视频属性抓取结束
# 开始BV号为1yv411v7Th视频属性的抓取
# BV号为1yv411v7Th的视频属性抓取结束
# 开始BV号为1rZ4y1K7Ym视频属性的抓取
# BV号为1rZ4y1K7Ym的视频属性抓取结束
# 开始BV号为1xK411T7UJ视频属性的抓取
# BV号为1xK411T7UJ的视频属性抓取结束
# 开始BV号为1Gp4y1q7vq视频属性的抓取
# BV号为1Gp4y1q7vq的视频属性抓取结束
# 开始BV号为1Vz4y1Q7TC视频属性的抓取
# BV号为1Vz4y1Q7TC的视频属性抓取结束
# 开始BV号为1Qp4y1v7qA视频属性的抓取
# BV号为1Qp4y1v7qA的视频属性抓取结束
# 开始BV号为1Ft4y1Q7Cy视频属性的抓取
# BV号为1Ft4y1Q7Cy的视频属性抓取结束
# 开始BV号为1BD4y1m7hf视频属性的抓取
# BV号为1BD4y1m7hf的视频属性抓取结束
# 开始BV号为1Lz4y1Q7S6视频属性的抓取
# BV号为1Lz4y1Q7S6的视频属性抓取结束
# 开始BV号为19T4y1j7Jd视频属性的抓取
# BV号为19T4y1j7Jd的视频属性抓取结束
# 开始BV号为1y54y1e7TV视频属性的抓取
# BV号为1y54y1e7TV的视频属性抓取结束
# 开始BV号为1Di4y1g7yf视频属性的抓取
# BV号为1Di4y1g7yf的视频属性抓取结束
# 开始BV号为12p4y1Y7Cs视频属性的抓取
# BV号为12p4y1Y7Cs的视频属性抓取结束
# 开始BV号为1M54y1D7Ps视频属性的抓取
# BV号为1M54y1D7Ps的视频属性抓取结束
# 开始BV号为1bp4y1v7hh视频属性的抓取
# BV号为1bp4y1v7hh的视频属性抓取结束
# 开始BV号为1dD4y127F2视频属性的抓取
# BV号为1dD4y127F2的视频属性抓取结束
# 开始BV号为1xT4y1L7m3视频属性的抓取
# BV号为1xT4y1L7m3的视频属性抓取结束
# 开始BV号为1Xv411y7S6视频属性的抓取
# BV号为1Xv411y7S6的视频属性抓取结束
# 开始BV号为1Ct4y1D7nL视频属性的抓取
# BV号为1Ct4y1D7nL的视频属性抓取结束
# 开始BV号为14Z4y1K7x9视频属性的抓取
# BV号为14Z4y1K7x9的视频属性抓取结束
# 开始BV号为1zT4y1j7Vn视频属性的抓取
# BV号为1zT4y1j7Vn的视频属性抓取结束
# 开始BV号为1Mt4y1S7Xe视频属性的抓取
# BV号为1Mt4y1S7Xe的视频属性抓取结束
# 开始BV号为1da4y177TQ视频属性的抓取
# BV号为1da4y177TQ的视频属性抓取结束
# 开始BV号为1HK4y1v7Rz视频属性的抓取
# BV号为1HK4y1v7Rz的视频属性抓取结束
# 开始BV号为1754y1v7Fn视频属性的抓取
# BV号为1754y1v7Fn的视频属性抓取结束
# 开始BV号为1Yv411v7JP视频属性的抓取
# BV号为1Yv411v7JP的视频属性抓取结束
# 开始BV号为1s54y1e7zu视频属性的抓取
# BV号为1s54y1e7zu的视频属性抓取结束
# 开始BV号为1rk4y1m7qS视频属性的抓取
# BV号为1rk4y1m7qS的视频属性抓取结束
# 开始BV号为1iA411Y7Po视频属性的抓取
# BV号为1iA411Y7Po的视频属性抓取结束
# 开始BV号为13v411i7rC视频属性的抓取
# BV号为13v411i7rC的视频属性抓取结束
# 开始BV号为1F64y1c7dj视频属性的抓取
# BV号为1F64y1c7dj的视频属性抓取结束
# 开始BV号为1C54y1S7Km视频属性的抓取
# BV号为1C54y1S7Km的视频属性抓取结束
# 开始BV号为1ma4y1E7DP视频属性的抓取
# BV号为1ma4y1E7DP的视频属性抓取结束
# 开始BV号为1uD4y1m7Qe视频属性的抓取
# BV号为1uD4y1m7Qe的视频属性抓取结束
# 开始BV号为1uA411n7fE视频属性的抓取
# BV号为1uA411n7fE的视频属性抓取结束
# 开始BV号为1jK411T7wD视频属性的抓取
# BV号为1jK411T7wD的视频属性抓取结束
# 开始BV号为1a64y1c7Dn视频属性的抓取
# BV号为1a64y1c7Dn的视频属性抓取结束
# 开始BV号为1Ti4y1g7Nn视频属性的抓取
# BV号为1Ti4y1g7Nn的视频属性抓取结束
# 开始BV号为1fV411278F视频属性的抓取
# BV号为1fV411278F的视频属性抓取结束
# 开始BV号为1Di4y1u7zG视频属性的抓取
# BV号为1Di4y1u7zG的视频属性抓取结束
# 开始BV号为1wA411n7xd视频属性的抓取
# 开始BV号为1wA411n7xd视频属性的抓取
# BV号为1wA411n7xd的视频属性抓取结束
# 开始BV号为1h54y1i7tH视频属性的抓取
# BV号为1h54y1i7tH的视频属性抓取结束
# 开始BV号为1ai4y1g7Hr视频属性的抓取
# BV号为1ai4y1g7Hr的视频属性抓取结束
# 开始BV号为1QA411J7LX视频属性的抓取
# BV号为1QA411J7LX的视频属性抓取结束
# 开始BV号为1ST4y157Q2视频属性的抓取
# BV号为1ST4y157Q2的视频属性抓取结束
# 开始BV号为1Ua4y1J7ge视频属性的抓取
# BV号为1Ua4y1J7ge的视频属性抓取结束
# 开始BV号为1PZ4y1T7PP视频属性的抓取
# BV号为1PZ4y1T7PP的视频属性抓取结束
# 开始BV号为1fV411U7go视频属性的抓取
# BV号为1fV411U7go的视频属性抓取结束
# 开始BV号为1R5411872L视频属性的抓取
# BV号为1R5411872L的视频属性抓取结束
# 开始BV号为1Ht4y1D7DD视频属性的抓取
# BV号为1Ht4y1D7DD的视频属性抓取结束
# 开始BV号为1v541187EU视频属性的抓取
# BV号为1v541187EU的视频属性抓取结束
# 开始BV号为1mp4y1v7Mk视频属性的抓取
# BV号为1mp4y1v7Mk的视频属性抓取结束
# 开始BV号为1HK4y1e7Bt视频属性的抓取
# BV号为1HK4y1e7Bt的视频属性抓取结束
# 开始BV号为1QA411n7gK视频属性的抓取
# BV号为1QA411n7gK的视频属性抓取结束
# 开始BV号为1EC4y1t7Cd视频属性的抓取
# BV号为1EC4y1t7Cd的视频属性抓取结束
# 开始BV号为18f4y197w2视频属性的抓取
# BV号为18f4y197w2的视频属性抓取结束
# 开始BV号为19D4y1m7z3视频属性的抓取
# BV号为19D4y1m7z3的视频属性抓取结束
# 开始BV号为1YT4y1L77P视频属性的抓取
# BV号为1YT4y1L77P的视频属性抓取结束
# 开始BV号为1nD4y1m76b视频属性的抓取
# BV号为1nD4y1m76b的视频属性抓取结束
# 开始BV号为1oZ4y1K7nz视频属性的抓取
# BV号为1oZ4y1K7nz的视频属性抓取结束
# 开始BV号为1Hp4y1q7sb视频属性的抓取
# BV号为1Hp4y1q7sb的视频属性抓取结束
# 开始BV号为1xZ4y1M7ZS视频属性的抓取
# BV号为1xZ4y1M7ZS的视频属性抓取结束
# 开始BV号为1CV411U7yY视频属性的抓取
# BV号为1CV411U7yY的视频属性抓取结束
# 开始BV号为1tZ4y1T7s2视频属性的抓取
# BV号为1tZ4y1T7s2的视频属性抓取结束
# 开始BV号为1XV411z7PH视频属性的抓取
# BV号为1XV411z7PH的视频属性抓取结束
# 开始BV号为1ka4y177Wv视频属性的抓取
# BV号为1ka4y177Wv的视频属性抓取结束
# 开始BV号为1rD4y1U7Ru视频属性的抓取
# BV号为1rD4y1U7Ru的视频属性抓取结束
# 开始BV号为1vv41117iW视频属性的抓取
# BV号为1vv41117iW的视频属性抓取结束
# 开始BV号为1sA411n7rw视频属性的抓取
# BV号为1sA411n7rw的视频属性抓取结束
# 开始BV号为1i54y1S7Py视频属性的抓取
# BV号为1i54y1S7Py的视频属性抓取结束
# 开始BV号为1xp4y1v7Yv视频属性的抓取
# BV号为1xp4y1v7Yv的视频属性抓取结束
# 开始BV号为1gf4y1X74r视频属性的抓取
# BV号为1gf4y1X74r的视频属性抓取结束
# 开始BV号为1ET4y1j7KJ视频属性的抓取
# BV号为1ET4y1j7KJ的视频属性抓取结束
# 开始BV号为1c54y1i79g视频属性的抓取
# BV号为1c54y1i79g的视频属性抓取结束
# 开始BV号为1fA411J7vk视频属性的抓取
# BV号为1fA411J7vk的视频属性抓取结束
# 开始BV号为1Nt4y1D7ew视频属性的抓取
# BV号为1Nt4y1D7ew的视频属性抓取结束
# 开始BV号为1gZ4y1K7du视频属性的抓取
# BV号为1gZ4y1K7du的视频属性抓取结束
# 开始BV号为1G54y1U7PE视频属性的抓取
# BV号为1G54y1U7PE的视频属性抓取结束
# 开始BV号为1if4y1Q7A5视频属性的抓取
# BV号为1if4y1Q7A5的视频属性抓取结束
# 开始BV号为1tD4y127Yb视频属性的抓取
# BV号为1tD4y127Yb的视频属性抓取结束
# 开始BV号为1nK4y1v7YK视频属性的抓取
# BV号为1nK4y1v7YK的视频属性抓取结束
# 开始BV号为13v411i7AZ视频属性的抓取
# BV号为13v411i7AZ的视频属性抓取结束
# 开始BV号为1Ja4y1773L视频属性的抓取
# BV号为1Ja4y1773L的视频属性抓取结束
# 开始BV号为1SZ4y1T7Fe视频属性的抓取
# BV号为1SZ4y1T7Fe的视频属性抓取结束
# 开始BV号为13a4y1J7AF视频属性的抓取
# BV号为13a4y1J7AF的视频属性抓取结束
# 开始BV号为12V411z7Bm视频属性的抓取
# BV号为12V411z7Bm的视频属性抓取结束
# 开始BV号为1UV411z7Jr视频属性的抓取
# BV号为1UV411z7Jr的视频属性抓取结束
# 开始BV号为1SC4y147Cv视频属性的抓取
# BV号为1SC4y147Cv的视频属性抓取结束
# 开始BV号为1x54y1U797视频属性的抓取
# BV号为1x54y1U797的视频属性抓取结束
# 开始BV号为1JA411n7Ya视频属性的抓取
# BV号为1JA411n7Ya的视频属性抓取结束
# 开始BV号为1Y5411h78y视频属性的抓取
# BV号为1Y5411h78y的视频属性抓取结束
# 开始BV号为1Gf4y197S4视频属性的抓取
# BV号为1Gf4y197S4的视频属性抓取结束
# 开始BV号为1YK4y1v7eY视频属性的抓取
# BV号为1YK4y1v7eY的视频属性抓取结束
# 开始BV号为1Da4y177GU视频属性的抓取
# BV号为1Da4y177GU的视频属性抓取结束
# 开始BV号为1Dh41197P5视频属性的抓取
# BV号为1Dh41197P5的视频属性抓取结束
# 开始BV号为1fi4y1M7jW视频属性的抓取
# BV号为1fi4y1M7jW的视频属性抓取结束
# 开始BV号为1ot4y1D7Sb视频属性的抓取
# BV号为1ot4y1D7Sb的视频属性抓取结束
# 开始BV号为1Li4y1g762视频属性的抓取
# BV号为1Li4y1g762的视频属性抓取结束
# 开始BV号为1554y1i7tX视频属性的抓取
# BV号为1554y1i7tX的视频属性抓取结束
# 开始BV号为1q54y127NR视频属性的抓取
# BV号为1q54y127NR的视频属性抓取结束
# 开始BV号为1E54y117Tr视频属性的抓取
# BV号为1E54y117Tr的视频属性抓取结束
# 开始BV号为1Mv41117Eh视频属性的抓取
# BV号为1Mv41117Eh的视频属性抓取结束
# 开始BV号为1ti4y1u72V视频属性的抓取
# BV号为1ti4y1u72V的视频属性抓取结束
# 开始BV号为1Tv41117Fu视频属性的抓取
# BV号为1Tv41117Fu的视频属性抓取结束
# 开始BV号为1qK411K7PN视频属性的抓取
# BV号为1qK411K7PN的视频属性抓取结束
# 开始BV号为1tk4y1C7qU视频属性的抓取
# BV号为1tk4y1C7qU的视频属性抓取结束
# 开始BV号为1c54y117ut视频属性的抓取
# BV号为1c54y117ut的视频属性抓取结束
# 开始BV号为1hZ4y157h9视频属性的抓取
# BV号为1hZ4y157h9的视频属性抓取结束
# 开始BV号为1qZ4y1N7Am视频属性的抓取
# BV号为1qZ4y1N7Am的视频属性抓取结束
# 开始BV号为12p4y1e7Gv视频属性的抓取
# BV号为12p4y1e7Gv的视频属性抓取结束
# 开始BV号为1QZ4y1N77A视频属性的抓取
# BV号为1QZ4y1N77A的视频属性抓取结束
# 开始BV号为1qT4y1A7Ke视频属性的抓取
# BV号为1qT4y1A7Ke的视频属性抓取结束
# 开始BV号为1zy4y1y7i4视频属性的抓取
# BV号为1zy4y1y7i4的视频属性抓取结束
# 开始BV号为1x5411b76p视频属性的抓取
# BV号为1x5411b76p的视频属性抓取结束
# 开始BV号为1qh411R7UJ视频属性的抓取
# BV号为1qh411R7UJ的视频属性抓取结束
# 开始BV号为1Vy4y1y7rb视频属性的抓取
# BV号为1Vy4y1y7rb的视频属性抓取结束
# 开始BV号为1oy4y1y76i视频属性的抓取
# BV号为1oy4y1y76i的视频属性抓取结束
# 开始BV号为1gA41177Hr视频属性的抓取
# BV号为1gA41177Hr的视频属性抓取结束
# 开始BV号为1YA411E71E视频属性的抓取
# BV号为1YA411E71E的视频属性抓取结束
# 开始BV号为1m54y127kr视频属性的抓取
# BV号为1m54y127kr的视频属性抓取结束
# 开始BV号为1Xk4y1k7Q7视频属性的抓取
# BV号为1Xk4y1k7Q7的视频属性抓取结束
# 开始BV号为1kK4y1873h视频属性的抓取
# BV号为1kK4y1873h的视频属性抓取结束
# 开始BV号为16T4y1L7E2视频属性的抓取
# BV号为16T4y1L7E2的视频属性抓取结束
# 开始BV号为13V411m78w视频属性的抓取
# BV号为13V411m78w的视频属性抓取结束
# 开始BV号为1Yt4y1q76C视频属性的抓取
# BV号为1Yt4y1q76C的视频属性抓取结束
# 开始BV号为16v41117bq视频属性的抓取
# BV号为16v41117bq的视频属性抓取结束
# 开始BV号为1C54y1C7P5视频属性的抓取
# BV号为1C54y1C7P5的视频属性抓取结束
# 开始BV号为1gK4y1a7c3视频属性的抓取
# BV号为1gK4y1a7c3的视频属性抓取结束
# 开始BV号为1z54y1C7RH视频属性的抓取
# BV号为1z54y1C7RH的视频属性抓取结束
# 开始BV号为1Xk4y1k77v视频属性的抓取
# BV号为1Xk4y1k77v的视频属性抓取结束
# 开始BV号为17z4y1Z7eR视频属性的抓取
# BV号为17z4y1Z7eR的视频属性抓取结束
# 开始BV号为1Ma4y1j7pb视频属性的抓取
# BV号为1Ma4y1j7pb的视频属性抓取结束
# 开始BV号为1MV411m7X4视频属性的抓取
# BV号为1MV411m7X4的视频属性抓取结束
# 开始BV号为13p4y1e7e2视频属性的抓取
# BV号为13p4y1e7e2的视频属性抓取结束
# 开始BV号为1Gz4y1Z7sR视频属性的抓取
# BV号为1Gz4y1Z7sR的视频属性抓取结束
# 开始BV号为1vK411P7NJ视频属性的抓取
# BV号为1vK411P7NJ的视频属性抓取结束
# 开始BV号为1Qy4y1k7Gk视频属性的抓取
# BV号为1Qy4y1k7Gk的视频属性抓取结束
# 开始BV号为1bi4y1M7o2视频属性的抓取
# BV号为1bi4y1M7o2的视频属性抓取结束
# 开始BV号为1e5411b7rY视频属性的抓取
# BV号为1e5411b7rY的视频属性抓取结束
# 开始BV号为1Zt4y1S75t视频属性的抓取
# BV号为1Zt4y1S75t的视频属性抓取结束
# 开始BV号为1Sf4y1Q7RM视频属性的抓取
# BV号为1Sf4y1Q7RM的视频属性抓取结束
# 开始BV号为1M54y1m7CA视频属性的抓取
# BV号为1M54y1m7CA的视频属性抓取结束
# 开始BV号为1Lk4y1C7ZF视频属性的抓取
# BV号为1Lk4y1C7ZF的视频属性抓取结束
# 开始BV号为1Rp4y1e7a1视频属性的抓取
# BV号为1Rp4y1e7a1的视频属性抓取结束
# 开始BV号为1ED4y1o78z视频属性的抓取
# BV号为1ED4y1o78z的视频属性抓取结束
# 开始BV号为1Wa4y1E78f视频属性的抓取
# BV号为1Wa4y1E78f的视频属性抓取结束
# 开始BV号为1rf4y1D7Dh视频属性的抓取
# BV号为1rf4y1D7Dh的视频属性抓取结束
# 开始BV号为1QA411E7fg视频属性的抓取
# BV号为1QA411E7fg的视频属性抓取结束
# 开始BV号为1a54y1y785视频属性的抓取
# BV号为1a54y1y785的视频属性抓取结束
# 开始BV号为1st4y1q7qW视频属性的抓取
# BV号为1st4y1q7qW的视频属性抓取结束
# 开始BV号为1jf4y1D7oG视频属性的抓取
# BV号为1jf4y1D7oG的视频属性抓取结束
# 开始BV号为1zt4y1S7uY视频属性的抓取
# BV号为1zt4y1S7uY的视频属性抓取结束
# 开始BV号为1754y1k73A视频属性的抓取
# BV号为1754y1k73A的视频属性抓取结束
# 开始BV号为1dZ4y1N7vP视频属性的抓取
# BV号为1dZ4y1N7vP的视频属性抓取结束
# 开始BV号为17541187ce视频属性的抓取
# BV号为17541187ce的视频属性抓取结束
# 开始BV号为1Jh411X7yi视频属性的抓取
# BV号为1Jh411X7yi的视频属性抓取结束
# 开始BV号为1m54y1e7UC视频属性的抓取
# BV号为1m54y1e7UC的视频属性抓取结束
# 开始BV号为17y4y1y7je视频属性的抓取
# BV号为17y4y1y7je的视频属性抓取结束
# 开始BV号为1AZ4y1N7sh视频属性的抓取
# BV号为1AZ4y1N7sh的视频属性抓取结束
# 开始BV号为1zV411m7Ei视频属性的抓取
# BV号为1zV411m7Ei的视频属性抓取结束
# 开始BV号为1Rh411X7f7视频属性的抓取
# BV号为1Rh411X7f7的视频属性抓取结束
# 开始BV号为16a4y1j7wZ视频属性的抓取
# BV号为16a4y1j7wZ的视频属性抓取结束
# 开始BV号为1Yf4y1D7Pa视频属性的抓取
# BV号为1Yf4y1D7Pa的视频属性抓取结束
# 开始BV号为1Xa4y1L7u7视频属性的抓取
# BV号为1Xa4y1L7u7的视频属性抓取结束
# 开始BV号为1Wp4y1e7cf视频属性的抓取
# BV号为1Wp4y1e7cf的视频属性抓取结束
# 开始BV号为18v411C7vw视频属性的抓取
# BV号为18v411C7vw的视频属性抓取结束
# 开始BV号为14z4y1Z73u视频属性的抓取
# BV号为14z4y1Z73u的视频属性抓取结束
# 开始BV号为15v411171Z视频属性的抓取
# BV号为15v411171Z的视频属性抓取结束
# 开始BV号为18D4y1o76t视频属性的抓取
# BV号为18D4y1o76t的视频属性抓取结束
# 开始BV号为1Z5411b7Rf视频属性的抓取
# BV号为1Z5411b7Rf的视频属性抓取结束
# 开始BV号为1Xp4y1Y7YE视频属性的抓取
# BV号为1Xp4y1Y7YE的视频属性抓取结束
# 开始BV号为1d5411b7ri视频属性的抓取
# BV号为1d5411b7ri的视频属性抓取结束
# 开始BV号为1ov41117Pn视频属性的抓取
# BV号为1ov41117Pn的视频属性抓取结束
# 开始BV号为1JT4y1A7ka视频属性的抓取
# BV号为1JT4y1A7ka的视频属性抓取结束
# 开始BV号为1uZ4y1N7hU视频属性的抓取
# BV号为1uZ4y1N7hU的视频属性抓取结束
# 开始BV号为1vK4y1e7Hz视频属性的抓取
# BV号为1vK4y1e7Hz的视频属性抓取结束
# 开始BV号为1PT4y1w7CT视频属性的抓取
# BV号为1PT4y1w7CT的视频属性抓取结束
# 开始BV号为1UT4y1L78c视频属性的抓取
# BV号为1UT4y1L78c的视频属性抓取结束
# 开始BV号为1af4y1D7qr视频属性的抓取
# BV号为1af4y1D7qr的视频属性抓取结束
# 开始BV号为1zv41117hS视频属性的抓取
# BV号为1zv41117hS的视频属性抓取结束
# 开始BV号为1Tt4y1q7mA视频属性的抓取
# BV号为1Tt4y1q7mA的视频属性抓取结束
# 开始BV号为1Rp4y1e7vz视频属性的抓取
# BV号为1Rp4y1e7vz的视频属性抓取结束
# 开始BV号为1aa4y15759视频属性的抓取
# BV号为1aa4y15759的视频属性抓取结束
# 开始BV号为1qZ4y1N7yq视频属性的抓取
# BV号为1qZ4y1N7yq的视频属性抓取结束
# 开始BV号为1Lp4y1i77w视频属性的抓取
# BV号为1Lp4y1i77w的视频属性抓取结束
# 开始BV号为1L54y127XE视频属性的抓取
# BV号为1L54y127XE的视频属性抓取结束
# 开始BV号为12a4y1j7NW视频属性的抓取
# BV号为12a4y1j7NW的视频属性抓取结束
# 开始BV号为1nK4y1a7tS视频属性的抓取
# BV号为1nK4y1a7tS的视频属性抓取结束
# 开始BV号为1R54y1y7sz视频属性的抓取
# BV号为1R54y1y7sz的视频属性抓取结束
# 开始BV号为1nZ4y1N7aM视频属性的抓取
# BV号为1nZ4y1N7aM的视频属性抓取结束
# 开始BV号为1DK411P71j视频属性的抓取
# BV号为1DK411P71j的视频属性抓取结束
# 开始BV号为1qi4y177vB视频属性的抓取
# BV号为1qi4y177vB的视频属性抓取结束
# 开始BV号为1Hh411R7us视频属性的抓取
# BV号为1Hh411R7us的视频属性抓取结束
# 开始BV号为1VK4y1Y7Lo视频属性的抓取
# BV号为1VK4y1Y7Lo的视频属性抓取结束
# 开始BV号为1954y1C7FC视频属性的抓取
# BV号为1954y1C7FC的视频属性抓取结束
# 开始BV号为1sh411X79X视频属性的抓取
# BV号为1sh411X79X的视频属性抓取结束
# 开始BV号为1vk4y1y7Ap视频属性的抓取
# BV号为1vk4y1y7Ap的视频属性抓取结束
# 开始BV号为1CT4y1L7bd视频属性的抓取
# BV号为1CT4y1L7bd的视频属性抓取结束
# 开始BV号为13y4y1y7XT视频属性的抓取
# BV号为13y4y1y7XT的视频属性抓取结束
# 开始BV号为1QV411m7GC视频属性的抓取
# BV号为1QV411m7GC的视频属性抓取结束
# 开始BV号为1uV41127Bi视频属性的抓取
# BV号为1uV41127Bi的视频属性抓取结束
# 开始BV号为1VT4y1w7rm视频属性的抓取
# BV号为1VT4y1w7rm的视频属性抓取结束
# 开始BV号为1ht4y1i7xq视频属性的抓取
# BV号为1ht4y1i7xq的视频属性抓取结束
# 开始BV号为1Ht4y1i7RX视频属性的抓取
# BV号为1Ht4y1i7RX的视频属性抓取结束
# 开始BV号为1gK4y1h7cR视频属性的抓取
# BV号为1gK4y1h7cR的视频属性抓取结束
# 开始BV号为1za411w7Q4视频属性的抓取
# BV号为1za411w7Q4的视频属性抓取结束
# 开始BV号为14i4y177kd视频属性的抓取
# BV号为14i4y177kd的视频属性抓取结束
# 开始BV号为19Z4y157my视频属性的抓取
# BV号为19Z4y157my的视频属性抓取结束
# 开始BV号为12K4y1877G视频属性的抓取
# BV号为12K4y1877G的视频属性抓取结束
# 开始BV号为13z4y1o7WM视频属性的抓取
# 开始BV号为13z4y1o7WM视频属性的抓取
# BV号为13z4y1o7WM的视频属性抓取结束
# 开始BV号为1Vp4y1k7Mb视频属性的抓取
# BV号为1Vp4y1k7Mb的视频属性抓取结束
# 开始BV号为13p4y1k7vM视频属性的抓取
# BV号为13p4y1k7vM的视频属性抓取结束
# 开始BV号为1yi4y1E7hw视频属性的抓取
# BV号为1yi4y1E7hw的视频属性抓取结束
# 开始BV号为1154y1R7z5视频属性的抓取
# BV号为1154y1R7z5的视频属性抓取结束
# 开始BV号为1Vz4y1f7zv视频属性的抓取
# BV号为1Vz4y1f7zv的视频属性抓取结束
# 开始BV号为1Pf4y1z7Ei视频属性的抓取
# BV号为1Pf4y1z7Ei的视频属性抓取结束
# 开始BV号为1b54y1R7eT视频属性的抓取
# BV号为1b54y1R7eT的视频属性抓取结束
# 开始BV号为1xk4y1C7UC视频属性的抓取
# BV号为1xk4y1C7UC的视频属性抓取结束
# 开始BV号为1e5411L73Z视频属性的抓取
# BV号为1e5411L73Z的视频属性抓取结束
# 开始BV号为1p54y1C7La视频属性的抓取
# BV号为1p54y1C7La的视频属性抓取结束
# 开始BV号为1Zy4y1b7bk视频属性的抓取
# BV号为1Zy4y1b7bk的视频属性抓取结束
# 开始BV号为1tV411y7Pk视频属性的抓取
# BV号为1tV411y7Pk的视频属性抓取结束
# 开始BV号为185411j7VU视频属性的抓取
# BV号为185411j7VU的视频属性抓取结束
# 开始BV号为18i4y1j72b视频属性的抓取
# BV号为18i4y1j72b的视频属性抓取结束
# 开始BV号为1vp4y1Y7ac视频属性的抓取
# BV号为1vp4y1Y7ac的视频属性抓取结束
# 开始BV号为1pf4y1B7sN视频属性的抓取
# BV号为1pf4y1B7sN的视频属性抓取结束
# 开始BV号为1WV411y73t视频属性的抓取
# BV号为1WV411y73t的视频属性抓取结束
# 开始BV号为14D4y197PR视频属性的抓取
# BV号为14D4y197PR的视频属性抓取结束
# 开始BV号为1Gt4y1i7XX视频属性的抓取
# BV号为1Gt4y1i7XX的视频属性抓取结束
# 开始BV号为1yi4y1E7cU视频属性的抓取
# BV号为1yi4y1E7cU的视频属性抓取结束
# 开始BV号为1P54y1279P视频属性的抓取
# BV号为1P54y1279P的视频属性抓取结束
# 开始BV号为1TT4y1w7L9视频属性的抓取
# BV号为1TT4y1w7L9的视频属性抓取结束
# 开始BV号为1K5411L7q3视频属性的抓取
# BV号为1K5411L7q3的视频属性抓取结束
# 开始BV号为1Ty4y1C7to视频属性的抓取
# BV号为1Ty4y1C7to的视频属性抓取结束
# 开始BV号为1Zf4y1q7Zj视频属性的抓取
# BV号为1Zf4y1q7Zj的视频属性抓取结束
# 开始BV号为1py4y1C7Bj视频属性的抓取
# BV号为1py4y1C7Bj的视频属性抓取结束
# 开始BV号为1QA41177Qx视频属性的抓取
# BV号为1QA41177Qx的视频属性抓取结束
# 开始BV号为1m5411j7oz视频属性的抓取
# BV号为1m5411j7oz的视频属性抓取结束
# 开始BV号为1Ua411w7rr视频属性的抓取
# BV号为1Ua411w7rr的视频属性抓取结束
# 开始BV号为1ja4y1L7uc视频属性的抓取
# BV号为1ja4y1L7uc的视频属性抓取结束
# 开始BV号为1Hr4y1w7NY视频属性的抓取
# BV号为1Hr4y1w7NY的视频属性抓取结束
# 开始BV号为1Fa411P7zh视频属性的抓取
# BV号为1Fa411P7zh的视频属性抓取结束
# 开始BV号为1na411A7VT视频属性的抓取
# BV号为1na411A7VT的视频属性抓取结束
# 开始BV号为1WZ4y157g6视频属性的抓取
# BV号为1WZ4y157g6的视频属性抓取结束
# 开始BV号为1ma411A7hE视频属性的抓取
# BV号为1ma411A7hE的视频属性抓取结束
# 开始BV号为1oK411A7ju视频属性的抓取
# BV号为1oK411A7ju的视频属性抓取结束
# 开始BV号为1Yk4y1C7Gg视频属性的抓取
# BV号为1Yk4y1C7Gg的视频属性抓取结束
# 开始BV号为1by4y1B7Sv视频属性的抓取
# BV号为1by4y1B7Sv的视频属性抓取结束
# 开始BV号为1Vy4y1r78q视频属性的抓取
# BV号为1Vy4y1r78q的视频属性抓取结束
# 开始BV号为1tK411A7N2视频属性的抓取
# BV号为1tK411A7N2的视频属性抓取结束
# 开始BV号为13a4y1s7ib视频属性的抓取
# BV号为13a4y1s7ib的视频属性抓取结束
# 开始BV号为1w541177sM视频属性的抓取
# BV号为1w541177sM的视频属性抓取结束
# 开始BV号为1RD4y1R7PS视频属性的抓取
# BV号为1RD4y1R7PS的视频属性抓取结束
# 开始BV号为16p4y1a7Se视频属性的抓取
# BV号为16p4y1a7Se的视频属性抓取结束
# 开始BV号为17z4y1o71Q视频属性的抓取
# BV号为17z4y1o71Q的视频属性抓取结束
# 开始BV号为1iV41127tx视频属性的抓取
# BV号为1iV41127tx的视频属性抓取结束
# 开始BV号为1j54y1r7Et视频属性的抓取
# BV号为1j54y1r7Et的视频属性抓取结束
# 开始BV号为1ea4y1L7MW视频属性的抓取
# BV号为1ea4y1L7MW的视频属性抓取结束
# 开始BV号为1VA411E71y视频属性的抓取
# BV号为1VA411E71y的视频属性抓取结束
# 开始BV号为11y4y1r7SA视频属性的抓取
# BV号为11y4y1r7SA的视频属性抓取结束
# 开始BV号为1d5411j74W视频属性的抓取
# BV号为1d5411j74W的视频属性抓取结束
# 开始BV号为11y4y1r7jD视频属性的抓取
# BV号为11y4y1r7jD的视频属性抓取结束
# 开始BV号为1W54y1C7bQ视频属性的抓取
# BV号为1W54y1C7bQ的视频属性抓取结束
# 开始BV号为1UV41117sH视频属性的抓取
# BV号为1UV41117sH的视频属性抓取结束
# 开始BV号为1p54y117aF视频属性的抓取
# BV号为1p54y117aF的视频属性抓取结束
# 开始BV号为1H54y1R731视频属性的抓取
# BV号为1H54y1R731的视频属性抓取结束
# 开始BV号为1ZK4y187pV视频属性的抓取
# BV号为1ZK4y187pV的视频属性抓取结束
# 开始BV号为1Ja4y1L7BN视频属性的抓取
# BV号为1Ja4y1L7BN的视频属性抓取结束
# 开始BV号为1f541157JY视频属性的抓取
# BV号为1f541157JY的视频属性抓取结束
# 开始BV号为1w54y127os视频属性的抓取
# BV号为1w54y127os的视频属性抓取结束
# 开始BV号为1sT4y1w7xF视频属性的抓取
# BV号为1sT4y1w7xF的视频属性抓取结束
# 开始BV号为1wK4y1h7DL视频属性的抓取
# BV号为1wK4y1h7DL的视频属性抓取结束
# 开始BV号为1WK4y1E72H视频属性的抓取
# BV号为1WK4y1E72H的视频属性抓取结束
# 开始BV号为13i4y1L7fq视频属性的抓取
# BV号为13i4y1L7fq的视频属性抓取结束
# 开始BV号为1sA411E77Q视频属性的抓取
# BV号为1sA411E77Q的视频属性抓取结束
# 开始BV号为1G54y1k7mP视频属性的抓取
# BV号为1G54y1k7mP的视频属性抓取结束
# 开始BV号为19z4y1d7Ng视频属性的抓取
# BV号为19z4y1d7Ng的视频属性抓取结束
# 开始BV号为1fp4y1r7hX视频属性的抓取
# BV号为1fp4y1r7hX的视频属性抓取结束
# 开始BV号为14p4y1k7om视频属性的抓取
# BV号为14p4y1k7om的视频属性抓取结束
# 开始BV号为1ap4y1k7am视频属性的抓取
# BV号为1ap4y1k7am的视频属性抓取结束
# 开始BV号为1dr4y1c7Sn视频属性的抓取
# BV号为1dr4y1c7Sn的视频属性抓取结束
# 开始BV号为1hp4y1Y7J9视频属性的抓取
# BV号为1hp4y1Y7J9的视频属性抓取结束
# 开始BV号为1k54y1R71C视频属性的抓取
# BV号为1k54y1R71C的视频属性抓取结束
# 开始BV号为1mi4y1j746视频属性的抓取
# BV号为1mi4y1j746的视频属性抓取结束
# 开始BV号为1u541177Ai视频属性的抓取
# BV号为1u541177Ai的视频属性抓取结束
# 开始BV号为1JT4y1F7tu视频属性的抓取
# BV号为1JT4y1F7tu的视频属性抓取结束
# 开始BV号为1Y5411L7X2视频属性的抓取
# BV号为1Y5411L7X2的视频属性抓取结束
# 开始BV号为1fp4y1r7dm视频属性的抓取
# BV号为1fp4y1r7dm的视频属性抓取结束
# 开始BV号为1si4y177gL视频属性的抓取
# BV号为1si4y177gL的视频属性抓取结束
# 开始BV号为1eK411G74A视频属性的抓取
# BV号为1eK411G74A的视频属性抓取结束
# 开始BV号为12Z4y15734视频属性的抓取
# BV号为12Z4y15734的视频属性抓取结束
# 开始BV号为13Z4y1V7kj视频属性的抓取
# BV号为13Z4y1V7kj的视频属性抓取结束
# 开始BV号为1wr4y1w7ZF视频属性的抓取
# BV号为1wr4y1w7ZF的视频属性抓取结束
# 开始BV号为1ZA411L7N9视频属性的抓取
# BV号为1ZA411L7N9的视频属性抓取结束
# 开始BV号为1Ea4y1L7i6视频属性的抓取
# BV号为1Ea4y1L7i6的视频属性抓取结束
# 开始BV号为1vA41177e6视频属性的抓取
# BV号为1vA41177e6的视频属性抓取结束
# 开始BV号为1Z5411j7aw视频属性的抓取
# BV号为1Z5411j7aw的视频属性抓取结束
# 2020-12-19 00:17:15.514743

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-30-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
driver.execute_script('window.scrollTo(0, 700)')

# %%
channel_meishi_jilu.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月    97   97    97   97   97   97   97   97    97      97   97    97   97
# 1月     96   96    96   96   96   96   96   96    96      96   96    96   96
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月     98   98    98   98   98   98   98   98    98      98   98    98   98
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月   97   97   97   97   97   97    97
# 1月    96   96   96   96   96   96    96
# 2月   100  100  100  100  100  100   100
# 3月    99   99   99   99   99   99    99
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月    98   98   98   98   98   98    98
# 7月   100  100  100  100  100  100   100
# 8月   100  100  100  100  100  100   100
# 9月   100  100  100  100  100  100   100

# %%
channel_meishi_jilu.to_json('channel_meishi_jilu.json')

# %%
pd.set_option('display.max_rows', None)

# %%
channel_youxi_danji[channel_youxi_danji['时间']=='4月']
# Out:
#             时间            作者名  作者类型      粉丝数   投稿数  \
# 1h54y1d7Qq  4月            鹤吱菌  个人认证   191.3万    81
# 1L64y1M7Dp  4月            老番茄  个人认证  1360.1万   348
# 18K41157Tu  4月            老番茄  个人认证  1360.1万   348
# 1PT4y1G7ME  4月            老番茄  个人认证  1360.1万   348
# 1S54y197uX  4月           徐大虾咯  个人认证   570.1万   224
# 1ti4y1t7YM  4月            老番茄  个人认证  1360.1万   348
# 1Ai4y1b7ET  4月            敖厂长  个人认证   735.1万   348
# 1Up4y1C7PB  4月        丢鹏D1uuu     无     8.4万    20
# 1wi4y187bu  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 13t4y1U7kQ  4月           徐大虾咯  个人认证   570.1万   224
# 1fe411x7FA  4月         芦苇草的梦想  个人认证    29.3万   726
# 1LA411b7Dt  4月      LexBurner  个人认证   929.6万   383
# 1Ji4y1t7T9  4月            沧桑丸  个人认证    86.6万    57
# 1Lz411z72u  4月           徐大虾咯  个人认证   570.1万   224
# 13T4y1G7WT  4月          逗比的雀巢  个人认证   242.3万    82
# 1T54y197DH  4月           徐大虾咯  个人认证   570.1万   224
# 1Va4y147fH  4月            鹤吱菌  个人认证   191.3万    81
# 1tt4y127yy  4月           小潮院长  个人认证   481.6万   266
# 16T4y1g7RY  4月         吉儿一范伦婷  个人认证    67.6万    79
# 1754y197Da  4月            敖厂长  个人认证   735.1万   348
# 1hK41157M3  4月           花少北丶  个人认证   491.9万   173
# 1Rk4y197kw  4月       3DM游戏网官方  机构认证    13.5万  2822
# 1ST4y1G7E1  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1H54y1d76B  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1Sz411B7P4  4月          游汐_YX  个人认证    12.9万    98
# 1CT4y1g7Ya  4月    育碧中国Ubisoft  机构认证    64.5万  1211
# 12T4y1G7AZ  4月          与山0v0  个人认证   208.5万   557
# 1iJ411L7n2  【小莉帮忙】太恶心了！网上看直播买的烤鹌鹑，吃的时候竟然还...  美食  美食记录  普通视频  ...
# 197411i7dk               [徐大sao早期作品]人人鱼钓龙虾失败  美食  美食记录  普通视频  ...
# 1MJ411J7qB                   每 日 一 遍，防 止 饥 饿  美食  美食记录  普通视频  ...
# 1m7411s73N                           过 气 网 红  美食  美食记录  普通视频  ...
# ...                                      ...  ..   ...   ...  ...
# 1bg4y1B7zs                          全网成本最大雪糕  美食  美食记录  普通视频  ...
# 15Q4y1P7YN                    用蟋蟀做的拉面，大家敢吃吗？  美食  美食记录  活动作品  ...
# 1xC4y1H72h             【鬼灭之刃】帝骑哥变成无惨晒太阳做起了咖喱  美食  美食记录  普通视频  ...
# 1vQ4y1N71K                          这次真的是狗肉了  美食  美食记录  普通视频  ...
# 1AZ4y1W7iZ                      这些奇怪的酒，你敢喝吗？  美食  美食记录  普通视频  ...
#
#                                                            标签   视频长度     播放量  \
# 1vJ411j79g                             [美食, 美食, 美食记录, 套餐, 快手]  00:55  110.0万
# 1iJ411L7n2                    [美食, 美食, 美食记录, 烤鹌鹑, 网上购买, 小莉帮忙]  02:30   70.3万
# 197411i7dk        [美食, 美食, 美食记录, 日常, 生活, 美食圈, 人人鱼, 龙虾, 徐大sao]  05:31   63.4万
# 1MJ411J7qB  [李圣经, 南柱赫, 韩剧, 鬼畜调教, 鬼畜, 美食, 搞笑, 美食, 美食记录, 恶搞,...  02:40   36.8万
# 1m7411s73N            [美食, 搞笑, 美食, 美食记录, 自制, 料理, 网红, 撒盐, 撒盐哥]  00:20   29.5万
# ...                                                       ...    ...     ...
# 1bg4y1B7zs                        [美食, 美食, 美食记录, 甜品, 雪糕, 雪茸堂]  00:55   13.0万
# 15Q4y1P7YN    [黑暗料理, 日本, 美食, 美食, 美食记录, 地道美食大赏, 虫酒, 吃虫子, 蟋蟀拉面]  00:56   10.3万
# 1xC4y1H72h  [鬼灭之刃, 假面骑士, 特摄, 美食, 搞笑, 美食, 美食记录, 料理, 帝骑哥, 鬼舞...  04:41    5.7万
# 1vQ4y1N71K                             [美食, 美食, 美食记录, 狗肉, 越南]  08:19    5.6万
# 1AZ4y1W7iZ        [美食, 美食, 美食记录, 红酒, 故事, 葡萄酒, 奇怪, 蛇酒, 洋酒, 李格]  07:09    4.9万
#
#              点赞数  投币数   收藏数   转发数   评论数   弹幕数 有无分集
# 1vJ411j79g  5546  131  1425  4619  1528  2214    否
# 1iJ411L7n2  1.0万  221   886  1406  1214   856    否
# 197411i7dk  1.2万  493  1673  3813   559  4737    否
# 1MJ411J7qB  1.3万  750  5046  1297   173   335    否
# 1m7411s73N  5028   31   165    14   244    42    否
# ...          ...  ...   ...   ...   ...   ...  ...
# 1bg4y1B7zs   995   12   108   101   196    59    否
# 15Q4y1P7YN  7547  374   335    41   270   131    否
# 1xC4y1H72h   951   58   349   592   158   141    否
# 1vQ4y1N71K   900  245    79    50  1212   302    否
# 1AZ4y1W7iZ  2823  561   258    74   227   257    否
#
# [409 rows x 21 columns]
