# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_meishi_tianyuan=pd.DataFrame(columns=columns)
channel_meishi_tianyuan
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[18]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '美食'

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[18]/div/a/span').click()  #选择频道

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[5]/a').click()  #选择子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[5]/a').text
sub_channel
# Out:
# '田园美食'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(1,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_meishi_tianyuan.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-17 21:54:46.369842
# <ipython-input-10-51b76c08566c>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-10-51b76c08566c>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-10-51b76c08566c>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1cJ411E7Bd视频属性的抓取
# BV号为1cJ411E7Bd的视频属性抓取结束
# <ipython-input-10-51b76c08566c>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1TJ411p7JC视频属性的抓取
# BV号为1TJ411p7JC的视频属性抓取结束
# 开始BV号为1GJ411G7Ld视频属性的抓取
# BV号为1GJ411G7Ld的视频属性抓取结束
# 开始BV号为1VJ411b7RK视频属性的抓取
# BV号为1VJ411b7RK的视频属性抓取结束
# 开始BV号为19J411E7fJ视频属性的抓取
# BV号为19J411E7fJ的视频属性抓取结束
# 开始BV号为1AJ41157vL视频属性的抓取
# BV号为1AJ41157vL的视频属性抓取结束
# 开始BV号为1W7411i7NM视频属性的抓取
# BV号为1W7411i7NM的视频属性抓取结束
# 开始BV号为1YJ411E75n视频属性的抓取
# BV号为1YJ411E75n的视频属性抓取结束
# 开始BV号为1aJ411J7gK视频属性的抓取
# BV号为1aJ411J7gK的视频属性抓取结束
# 开始BV号为1bJ411V7qz视频属性的抓取
# BV号为1bJ411V7qz的视频属性抓取结束
# 开始BV号为1i7411r7hW视频属性的抓取
# BV号为1i7411r7hW的视频属性抓取结束
# 开始BV号为1d741167fL视频属性的抓取
# BV号为1d741167fL的视频属性抓取结束
# 开始BV号为1wJ411j74o视频属性的抓取
# BV号为1wJ411j74o的视频属性抓取结束
# 开始BV号为1RJ411L7qq视频属性的抓取
# BV号为1RJ411L7qq的视频属性抓取结束
# 开始BV号为14J41187dW视频属性的抓取
# BV号为14J41187dW的视频属性抓取结束
# 开始BV号为1GJ411G77W视频属性的抓取
# BV号为1GJ411G77W的视频属性抓取结束
# 开始BV号为1bJ411G7Rx视频属性的抓取
# BV号为1bJ411G7Rx的视频属性抓取结束
# 开始BV号为1R7411z7x7视频属性的抓取
# BV号为1R7411z7x7的视频属性抓取结束
# 开始BV号为1hJ411E7hX视频属性的抓取
# BV号为1hJ411E7hX的视频属性抓取结束
# 开始BV号为1u7411v7Wj视频属性的抓取
# 开始BV号为1u7411v7Wj视频属性的抓取
# 开始BV号为1u7411v7Wj视频属性的抓取
# BV号为1u7411v7Wj的视频属性抓取结束
# 开始BV号为1kJ411J7Bq视频属性的抓取
# BV号为1kJ411J7Bq的视频属性抓取结束
# 开始BV号为1YJ411b7s3视频属性的抓取
# BV号为1YJ411b7s3的视频属性抓取结束
# 开始BV号为1LJ411E7MZ视频属性的抓取
# BV号为1LJ411E7MZ的视频属性抓取结束
# 开始BV号为1f7411r7px视频属性的抓取
# BV号为1f7411r7px的视频属性抓取结束
# 开始BV号为1tJ41187pf视频属性的抓取
# BV号为1tJ41187pf的视频属性抓取结束
# 开始BV号为1NJ411j7Ag视频属性的抓取
# BV号为1NJ411j7Ag的视频属性抓取结束
# 开始BV号为1z7411a7Le视频属性的抓取
# BV号为1z7411a7Le的视频属性抓取结束
# 开始BV号为1KJ411J711视频属性的抓取
# BV号为1KJ411J711的视频属性抓取结束
# 开始BV号为1LJ41157mY视频属性的抓取
# BV号为1LJ41157mY的视频属性抓取结束
# 开始BV号为1sJ411j7o3视频属性的抓取
# BV号为1sJ411j7o3的视频属性抓取结束
# 开始BV号为1x7411q7Hz视频属性的抓取
# BV号为1x7411q7Hz的视频属性抓取结束
# 开始BV号为1KJ411V7EM视频属性的抓取
# BV号为1KJ411V7EM的视频属性抓取结束
# 开始BV号为1H7411e79X视频属性的抓取
# BV号为1H7411e79X的视频属性抓取结束
# 开始BV号为1r7411i7wR视频属性的抓取
# BV号为1r7411i7wR的视频属性抓取结束
# 开始BV号为1B7411r7km视频属性的抓取
# BV号为1B7411r7km的视频属性抓取结束
# 开始BV号为19J411G7kY视频属性的抓取
# BV号为19J411G7kY的视频属性抓取结束
# 开始BV号为1G741167sp视频属性的抓取
# BV号为1G741167sp的视频属性抓取结束
# 开始BV号为1r7411e71V视频属性的抓取
# BV号为1r7411e71V的视频属性抓取结束
# 开始BV号为1cJ411H7Yt视频属性的抓取
# BV号为1cJ411H7Yt的视频属性抓取结束
# 开始BV号为1YJ411E7e1视频属性的抓取
# BV号为1YJ411E7e1的视频属性抓取结束
# 开始BV号为1uJ411n7di视频属性的抓取
# BV号为1uJ411n7di的视频属性抓取结束
# 开始BV号为1UJ411J7pW视频属性的抓取
# BV号为1UJ411J7pW的视频属性抓取结束
# 开始BV号为1u7411v7Hg视频属性的抓取
# BV号为1u7411v7Hg的视频属性抓取结束
# 开始BV号为1VJ411G7j9视频属性的抓取
# BV号为1VJ411G7j9的视频属性抓取结束
# 开始BV号为1bJ411h7zL视频属性的抓取
# BV号为1bJ411h7zL的视频属性抓取结束
# 开始BV号为1S7411v763视频属性的抓取
# BV号为1S7411v763的视频属性抓取结束
# 开始BV号为19J411j7rZ视频属性的抓取
# BV号为19J411j7rZ的视频属性抓取结束
# 开始BV号为1s7411e7Z3视频属性的抓取
# BV号为1s7411e7Z3的视频属性抓取结束
# 开始BV号为1c741167yu视频属性的抓取
# BV号为1c741167yu的视频属性抓取结束
# 开始BV号为1MJ411H7DM视频属性的抓取
# BV号为1MJ411H7DM的视频属性抓取结束
# 开始BV号为1rJ411J7ig视频属性的抓取
# BV号为1rJ411J7ig的视频属性抓取结束
# 开始BV号为1UJ411n7jb视频属性的抓取
# BV号为1UJ411n7jb的视频属性抓取结束
# 开始BV号为1YJ41177rN视频属性的抓取
# BV号为1YJ41177rN的视频属性抓取结束
# 开始BV号为1tJ411H7vL视频属性的抓取
# BV号为1tJ411H7vL的视频属性抓取结束
# 开始BV号为1ZJ41157dF视频属性的抓取
# BV号为1ZJ41157dF的视频属性抓取结束
# 开始BV号为1HJ41177H7视频属性的抓取
# BV号为1HJ41177H7的视频属性抓取结束
# 开始BV号为1LJ411G7cR视频属性的抓取
# BV号为1LJ411G7cR的视频属性抓取结束
# 开始BV号为1X7411v71s视频属性的抓取
# BV号为1X7411v71s的视频属性抓取结束
# 开始BV号为18J411p7Pt视频属性的抓取
# BV号为18J411p7Pt的视频属性抓取结束
# 开始BV号为1dJ411G71k视频属性的抓取
# BV号为1dJ411G71k的视频属性抓取结束
# 开始BV号为1V7411i77V视频属性的抓取
# BV号为1V7411i77V的视频属性抓取结束
# 开始BV号为1n7411z785视频属性的抓取
# BV号为1n7411z785的视频属性抓取结束
# 开始BV号为1E7411q7La视频属性的抓取
# BV号为1E7411q7La的视频属性抓取结束
# 开始BV号为19J411G7RC视频属性的抓取
# BV号为19J411G7RC的视频属性抓取结束
# 开始BV号为1X7411v7cG视频属性的抓取
# BV号为1X7411v7cG的视频属性抓取结束
# 开始BV号为1sJ411G7sJ视频属性的抓取
# BV号为1sJ411G7sJ的视频属性抓取结束
# 开始BV号为1Q7411k7Fw视频属性的抓取
# BV号为1Q7411k7Fw的视频属性抓取结束
# 开始BV号为15J411p7kz视频属性的抓取
# BV号为15J411p7kz的视频属性抓取结束
# 开始BV号为1aJ411V7Qs视频属性的抓取
# BV号为1aJ411V7Qs的视频属性抓取结束
# 开始BV号为1aJ411H7GB视频属性的抓取
# BV号为1aJ411H7GB的视频属性抓取结束
# 开始BV号为1uJ411E7ou视频属性的抓取
# BV号为1uJ411E7ou的视频属性抓取结束
# 开始BV号为1cJ41157sS视频属性的抓取
# BV号为1cJ41157sS的视频属性抓取结束
# 开始BV号为197411B7Y1视频属性的抓取
# BV号为197411B7Y1的视频属性抓取结束
# 开始BV号为1Y7411i7sG视频属性的抓取
# BV号为1Y7411i7sG的视频属性抓取结束
# 开始BV号为1yJ411571K视频属性的抓取
# BV号为1yJ411571K的视频属性抓取结束
# 开始BV号为1R7411a7Xn视频属性的抓取
# BV号为1R7411a7Xn的视频属性抓取结束
# 开始BV号为1jJ41157bP视频属性的抓取
# BV号为1jJ41157bP的视频属性抓取结束
# 开始BV号为1jJ411b7AE视频属性的抓取
# BV号为1jJ411b7AE的视频属性抓取结束
# 开始BV号为1dJ411b7Sn视频属性的抓取
# BV号为1dJ411b7Sn的视频属性抓取结束
# 开始BV号为1x7411e7qv视频属性的抓取
# BV号为1x7411e7qv的视频属性抓取结束
# 开始BV号为1W7411i7Km视频属性的抓取
# BV号为1W7411i7Km的视频属性抓取结束
# 开始BV号为1fJ411E7vn视频属性的抓取
# BV号为1fJ411E7vn的视频属性抓取结束
# 开始BV号为1b7411e7SU视频属性的抓取
# BV号为1b7411e7SU的视频属性抓取结束
# 开始BV号为1mJ411h7aX视频属性的抓取
# BV号为1mJ411h7aX的视频属性抓取结束
# 开始BV号为1eJ411j7vG视频属性的抓取
# BV号为1eJ411j7vG的视频属性抓取结束
# 开始BV号为1oJ411n77E视频属性的抓取
# BV号为1oJ411n77E的视频属性抓取结束
# 开始BV号为1D7411B78p视频属性的抓取
# BV号为1D7411B78p的视频属性抓取结束
# 开始BV号为1qJ411n7Tp视频属性的抓取
# BV号为1qJ411n7Tp的视频属性抓取结束
# 开始BV号为1yJ411H7zP视频属性的抓取
# BV号为1yJ411H7zP的视频属性抓取结束
# 开始BV号为1t741167AM视频属性的抓取
# BV号为1t741167AM的视频属性抓取结束
# 开始BV号为1dJ41177yy视频属性的抓取
# BV号为1dJ41177yy的视频属性抓取结束
# 开始BV号为1VJ411j7RH视频属性的抓取
# BV号为1VJ411j7RH的视频属性抓取结束
# 开始BV号为17J411L7m8视频属性的抓取
# BV号为17J411L7m8的视频属性抓取结束
# 开始BV号为1NJ411H7ft视频属性的抓取
# BV号为1NJ411H7ft的视频属性抓取结束
# 开始BV号为1GJ411p7f6视频属性的抓取
# BV号为1GJ411p7f6的视频属性抓取结束
# 开始BV号为1XJ4115738视频属性的抓取
# BV号为1XJ4115738的视频属性抓取结束
# 开始BV号为1bJ411L7dB视频属性的抓取
# BV号为1bJ411L7dB的视频属性抓取结束
# 开始BV号为1m741167YK视频属性的抓取
# BV号为1m741167YK的视频属性抓取结束
# 开始BV号为16J411H7TH视频属性的抓取
# BV号为16J411H7TH的视频属性抓取结束
# 开始BV号为15J411G7NR视频属性的抓取
# BV号为15J411G7NR的视频属性抓取结束
# 开始BV号为1o7411w7hk视频属性的抓取
# BV号为1o7411w7hk的视频属性抓取结束
# 开始BV号为1P7411E7wU视频属性的抓取
# BV号为1P7411E7wU的视频属性抓取结束
# 开始BV号为1B7411h7Le视频属性的抓取
# BV号为1B7411h7Le的视频属性抓取结束
# 开始BV号为1U741137xk视频属性的抓取
# BV号为1U741137xk的视频属性抓取结束
# 开始BV号为1R7411P7bd视频属性的抓取
# BV号为1R7411P7bd的视频属性抓取结束
# 开始BV号为1g7411L7sX视频属性的抓取
# BV号为1g7411L7sX的视频属性抓取结束
# 开始BV号为1o7411n7fS视频属性的抓取
# BV号为1o7411n7fS的视频属性抓取结束
# 开始BV号为1D7411H76K视频属性的抓取
# BV号为1D7411H76K的视频属性抓取结束
# 开始BV号为187411w7u2视频属性的抓取
# BV号为187411w7u2的视频属性抓取结束
# 开始BV号为157411u75M视频属性的抓取
# BV号为157411u75M的视频属性抓取结束
# 开始BV号为1N7411u7b4视频属性的抓取
# BV号为1N7411u7b4的视频属性抓取结束
# 开始BV号为1Q7411t74K视频属性的抓取
# BV号为1Q7411t74K的视频属性抓取结束
# 开始BV号为1z7411L7xs视频属性的抓取
# BV号为1z7411L7xs的视频属性抓取结束
# 开始BV号为1J7411h7et视频属性的抓取
# BV号为1J7411h7et的视频属性抓取结束
# 开始BV号为1z741177rA视频属性的抓取
# BV号为1z741177rA的视频属性抓取结束
# 开始BV号为1o7411H74m视频属性的抓取
# BV号为1o7411H74m的视频属性抓取结束
# 开始BV号为117411x7TA视频属性的抓取
# BV号为117411x7TA的视频属性抓取结束
# 开始BV号为1H7411h79C视频属性的抓取
# BV号为1H7411h79C的视频属性抓取结束
# 开始BV号为1T7411w7B5视频属性的抓取
# BV号为1T7411w7B5的视频属性抓取结束
# 开始BV号为1n7411p7Cs视频属性的抓取
# BV号为1n7411p7Cs的视频属性抓取结束
# 开始BV号为1Q7411F7WM视频属性的抓取
# BV号为1Q7411F7WM的视频属性抓取结束
# 开始BV号为1h7411V77P视频属性的抓取
# BV号为1h7411V77P的视频属性抓取结束
# 开始BV号为1L741187wH视频属性的抓取
# BV号为1L741187wH的视频属性抓取结束
# 开始BV号为1n7411w77A视频属性的抓取
# BV号为1n7411w77A的视频属性抓取结束
# 开始BV号为1T741157eo视频属性的抓取
# BV号为1T741157eo的视频属性抓取结束
# 开始BV号为1B7411J7rC视频属性的抓取
# BV号为1B7411J7rC的视频属性抓取结束
# 开始BV号为1Z7411G78F视频属性的抓取
# BV号为1Z7411G78F的视频属性抓取结束
# 开始BV号为1R741187NU视频属性的抓取
# BV号为1R741187NU的视频属性抓取结束
# 开始BV号为1k7411F7nh视频属性的抓取
# BV号为1k7411F7nh的视频属性抓取结束
# 开始BV号为1B741147Xj视频属性的抓取
# BV号为1B741147Xj的视频属性抓取结束
# 开始BV号为1v7411E7bw视频属性的抓取
# BV号为1v7411E7bw的视频属性抓取结束
# 开始BV号为1M741187jK视频属性的抓取
# BV号为1M741187jK的视频属性抓取结束
# 开始BV号为197411376P视频属性的抓取
# BV号为197411376P的视频属性抓取结束
# 开始BV号为1U7411W7w3视频属性的抓取
# BV号为1U7411W7w3的视频属性抓取结束
# 开始BV号为1x7411G7Fb视频属性的抓取
# BV号为1x7411G7Fb的视频属性抓取结束
# 开始BV号为1P7411V7HX视频属性的抓取
# BV号为1P7411V7HX的视频属性抓取结束
# 开始BV号为147411n7AL视频属性的抓取
# BV号为147411n7AL的视频属性抓取结束
# 开始BV号为1H7411t7fb视频属性的抓取
# BV号为1H7411t7fb的视频属性抓取结束
# 开始BV号为1N7411W77B视频属性的抓取
# BV号为1N7411W77B的视频属性抓取结束
# 开始BV号为1L7411V7cJ视频属性的抓取
# BV号为1L7411V7cJ的视频属性抓取结束
# 开始BV号为1j7411W7Ch视频属性的抓取
# BV号为1j7411W7Ch的视频属性抓取结束
# 开始BV号为1B7411W7eu视频属性的抓取
# BV号为1B7411W7eu的视频属性抓取结束
# 开始BV号为16j411f72d视频属性的抓取
# BV号为16j411f72d的视频属性抓取结束
# 开始BV号为1Q7411g7UP视频属性的抓取
# BV号为1Q7411g7UP的视频属性抓取结束
# 开始BV号为1y7411W7AH视频属性的抓取
# BV号为1y7411W7AH的视频属性抓取结束
# 开始BV号为1u7411s7jk视频属性的抓取
# BV号为1u7411s7jk的视频属性抓取结束
# 开始BV号为1i7411W7s3视频属性的抓取
# BV号为1i7411W7s3的视频属性抓取结束
# 开始BV号为147411t7Ex视频属性的抓取
# BV号为147411t7Ex的视频属性抓取结束
# 开始BV号为1w7411t74X视频属性的抓取
# BV号为1w7411t74X的视频属性抓取结束
# 开始BV号为1f7411x7uc视频属性的抓取
# BV号为1f7411x7uc的视频属性抓取结束
# <ipython-input-10-51b76c08566c>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1a7411K7oh视频属性的抓取
# BV号为1a7411K7oh的视频属性抓取结束
# 开始BV号为1R7411M7TG视频属性的抓取
# BV号为1R7411M7TG的视频属性抓取结束
# 开始BV号为1g7411t7tJ视频属性的抓取
# BV号为1g7411t7tJ的视频属性抓取结束
# 开始BV号为1S741177jt视频属性的抓取
# BV号为1S741177jt的视频属性抓取结束
# 开始BV号为1V7411G7h5视频属性的抓取
# BV号为1V7411G7h5的视频属性抓取结束
# 开始BV号为1a7411h7ni视频属性的抓取
# BV号为1a7411h7ni的视频属性抓取结束
# 开始BV号为1J7411H7KF视频属性的抓取
# BV号为1J7411H7KF的视频属性抓取结束
# 开始BV号为1v7411J7e3视频属性的抓取
# BV号为1v7411J7e3的视频属性抓取结束
# 开始BV号为1X741137tf视频属性的抓取
# BV号为1X741137tf的视频属性抓取结束
# 开始BV号为1k741177oq视频属性的抓取
# BV号为1k741177oq的视频属性抓取结束
# 开始BV号为1a7411b7ER视频属性的抓取
# BV号为1a7411b7ER的视频属性抓取结束
# 开始BV号为1c7411p7iT视频属性的抓取
# BV号为1c7411p7iT的视频属性抓取结束
# 开始BV号为1c7411n7NX视频属性的抓取
# BV号为1c7411n7NX的视频属性抓取结束
# 开始BV号为1e7411V7Yj视频属性的抓取
# BV号为1e7411V7Yj的视频属性抓取结束
# 开始BV号为1G7411J7jo视频属性的抓取
# BV号为1G7411J7jo的视频属性抓取结束
# 开始BV号为1w7411A7Hd视频属性的抓取
# BV号为1w7411A7Hd的视频属性抓取结束
# 开始BV号为1u7411J7T7视频属性的抓取
# BV号为1u7411J7T7的视频属性抓取结束
# 开始BV号为1h7411h7yn视频属性的抓取
# BV号为1h7411h7yn的视频属性抓取结束
# 开始BV号为14741177wG视频属性的抓取
# BV号为14741177wG的视频属性抓取结束
# 开始BV号为147411j7e1视频属性的抓取
# BV号为147411j7e1的视频属性抓取结束
# 开始BV号为1Qj411f7B1视频属性的抓取
# BV号为1Qj411f7B1的视频属性抓取结束
# 开始BV号为137411H7qh视频属性的抓取
# BV号为137411H7qh的视频属性抓取结束
# 开始BV号为1a7411J7ry视频属性的抓取
# BV号为1a7411J7ry的视频属性抓取结束
# 开始BV号为1s7411H71r视频属性的抓取
# BV号为1s7411H71r的视频属性抓取结束
# 开始BV号为1Y7411s7uQ视频属性的抓取
# BV号为1Y7411s7uQ的视频属性抓取结束
# 开始BV号为147411t7sN视频属性的抓取
# BV号为147411t7sN的视频属性抓取结束
# 开始BV号为1o741187zx视频属性的抓取
# BV号为1o741187zx的视频属性抓取结束
# 开始BV号为1Y7411s7YW视频属性的抓取
# BV号为1Y7411s7YW的视频属性抓取结束
# 开始BV号为1N7411N74Y视频属性的抓取
# BV号为1N7411N74Y的视频属性抓取结束
# 开始BV号为1f7411p7SQ视频属性的抓取
# BV号为1f7411p7SQ的视频属性抓取结束
# 开始BV号为1T7411u72B视频属性的抓取
# BV号为1T7411u72B的视频属性抓取结束
# 开始BV号为1L7411x7Cn视频属性的抓取
# BV号为1L7411x7Cn的视频属性抓取结束
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# 开始BV号为1T7411u78K视频属性的抓取
# BV号为1T7411u78K的视频属性抓取结束
# 开始BV号为167411V7qh视频属性的抓取
# BV号为167411V7qh的视频属性抓取结束
# 开始BV号为1i741157SU视频属性的抓取
# BV号为1i741157SU的视频属性抓取结束
# 开始BV号为1K741137qi视频属性的抓取
# BV号为1K741137qi的视频属性抓取结束
# 开始BV号为1W7411W7Y9视频属性的抓取
# BV号为1W7411W7Y9的视频属性抓取结束
# 开始BV号为1f7411p7NW视频属性的抓取
# BV号为1f7411p7NW的视频属性抓取结束
# 开始BV号为187411L74M视频属性的抓取
# BV号为187411L74M的视频属性抓取结束
# 开始BV号为1m7411s7RS视频属性的抓取
# BV号为1m7411s7RS的视频属性抓取结束
# 开始BV号为1w741137Yk视频属性的抓取
# BV号为1w741137Yk的视频属性抓取结束
# 开始BV号为1T7411j7Xy视频属性的抓取
# BV号为1T7411j7Xy的视频属性抓取结束
# 开始BV号为1K7411t7cX视频属性的抓取
# BV号为1K7411t7cX的视频属性抓取结束
# 开始BV号为1gE411H7q2视频属性的抓取
# BV号为1gE411H7q2的视频属性抓取结束
# 开始BV号为1Q7411b7cW视频属性的抓取
# BV号为1Q7411b7cW的视频属性抓取结束
# 开始BV号为1x7411b7wY视频属性的抓取
# BV号为1x7411b7wY的视频属性抓取结束
# 开始BV号为1v7411b7zM视频属性的抓取
# BV号为1v7411b7zM的视频属性抓取结束
# 开始BV号为1d741147iK视频属性的抓取
# BV号为1d741147iK的视频属性抓取结束
# 开始BV号为1Q741147vb视频属性的抓取
# BV号为1Q741147vb的视频属性抓取结束
# 开始BV号为1kE411K7V4视频属性的抓取
# BV号为1kE411K7V4的视频属性抓取结束
# 开始BV号为19E411j7Lt视频属性的抓取
# BV号为19E411j7Lt的视频属性抓取结束
# 开始BV号为1NE411N7nQ视频属性的抓取
# BV号为1NE411N7nQ的视频属性抓取结束
# 开始BV号为167411f715视频属性的抓取
# BV号为167411f715的视频属性抓取结束
# 开始BV号为1WE411s7ZQ视频属性的抓取
# BV号为1WE411s7ZQ的视频属性抓取结束
# 开始BV号为1G7411f7Wv视频属性的抓取
# BV号为1G7411f7Wv的视频属性抓取结束
# 开始BV号为1W7411U71B视频属性的抓取
# BV号为1W7411U71B的视频属性抓取结束
# 开始BV号为1FE41147v1视频属性的抓取
# BV号为1FE41147v1的视频属性抓取结束
# 开始BV号为1sE411M7Uo视频属性的抓取
# BV号为1sE411M7Uo的视频属性抓取结束
# 开始BV号为1BC4y147ds视频属性的抓取
# BV号为1BC4y147ds的视频属性抓取结束
# 开始BV号为1rE411j7Xx视频属性的抓取
# BV号为1rE411j7Xx的视频属性抓取结束
# 开始BV号为12E411s7m2视频属性的抓取
# BV号为12E411s7m2的视频属性抓取结束
# 开始BV号为19E411H7X4视频属性的抓取
# BV号为19E411H7X4的视频属性抓取结束
# 开始BV号为1SE411F7KB视频属性的抓取
# BV号为1SE411F7KB的视频属性抓取结束
# 开始BV号为1HE411u7ca视频属性的抓取
# BV号为1HE411u7ca的视频属性抓取结束
# 开始BV号为1b7411d7XR视频属性的抓取
# BV号为1b7411d7XR的视频属性抓取结束
# 开始BV号为1d7411m75p视频属性的抓取
# BV号为1d7411m75p的视频属性抓取结束
# 开始BV号为197411y7VV视频属性的抓取
# BV号为197411y7VV的视频属性抓取结束
# 开始BV号为1XE411P77Z视频属性的抓取
# BV号为1XE411P77Z的视频属性抓取结束
# 开始BV号为16E411W7ge视频属性的抓取
# BV号为16E411W7ge的视频属性抓取结束
# 开始BV号为1PE411W7vw视频属性的抓取
# BV号为1PE411W7vw的视频属性抓取结束
# 开始BV号为1uE411N7VS视频属性的抓取
# BV号为1uE411N7VS的视频属性抓取结束
# 开始BV号为1dE411P7NL视频属性的抓取
# BV号为1dE411P7NL的视频属性抓取结束
# 开始BV号为1d7411f782视频属性的抓取
# BV号为1d7411f782的视频属性抓取结束
# 开始BV号为1k7411R75G视频属性的抓取
# BV号为1k7411R75G的视频属性抓取结束
# 开始BV号为1PE411t7Fw视频属性的抓取
# BV号为1PE411t7Fw的视频属性抓取结束
# 开始BV号为1b7411S7if视频属性的抓取
# BV号为1b7411S7if的视频属性抓取结束
# 开始BV号为1qE411s7e3视频属性的抓取
# BV号为1qE411s7e3的视频属性抓取结束
# 开始BV号为1F54y1d74f视频属性的抓取
# BV号为1F54y1d74f的视频属性抓取结束
# 开始BV号为19E411G7P9视频属性的抓取
# BV号为19E411G7P9的视频属性抓取结束
# 开始BV号为1BE411p7Dh视频属性的抓取
# BV号为1BE411p7Dh的视频属性抓取结束
# 开始BV号为1sE411W7KH视频属性的抓取
# BV号为1sE411W7KH的视频属性抓取结束
# 开始BV号为1rt4y1m793视频属性的抓取
# BV号为1rt4y1m793的视频属性抓取结束
# 开始BV号为12E411H71Y视频属性的抓取
# BV号为12E411H71Y的视频属性抓取结束
# 开始BV号为1H7411m7rZ视频属性的抓取
# BV号为1H7411m7rZ的视频属性抓取结束
# 开始BV号为1GE411P7QX视频属性的抓取
# BV号为1GE411P7QX的视频属性抓取结束
# 开始BV号为1N7411R7Cc视频属性的抓取
# BV号为1N7411R7Cc的视频属性抓取结束
# 开始BV号为167411m7Eb视频属性的抓取
# BV号为167411m7Eb的视频属性抓取结束
# 开始BV号为1b7411y77W视频属性的抓取
# BV号为1b7411y77W的视频属性抓取结束
# 开始BV号为1PE411s7nC视频属性的抓取
# BV号为1PE411s7nC的视频属性抓取结束
# 开始BV号为1cE411J7r6视频属性的抓取
# BV号为1cE411J7r6的视频属性抓取结束
# 开始BV号为1kE41157nm视频属性的抓取
# BV号为1kE41157nm的视频属性抓取结束
# 开始BV号为1qK41177vS视频属性的抓取
# BV号为1qK41177vS的视频属性抓取结束
# 开始BV号为1se411x75t视频属性的抓取
# BV号为1se411x75t的视频属性抓取结束
# 开始BV号为157411f73Q视频属性的抓取
# BV号为157411f73Q的视频属性抓取结束
# 开始BV号为1sE411w7zY视频属性的抓取
# BV号为1sE411w7zY的视频属性抓取结束
# 开始BV号为1VE411W7Gm视频属性的抓取
# BV号为1VE411W7Gm的视频属性抓取结束
# 开始BV号为1yE411u7yc视频属性的抓取
# BV号为1yE411u7yc的视频属性抓取结束
# 开始BV号为17E411F76z视频属性的抓取
# BV号为17E411F76z的视频属性抓取结束
# 开始BV号为1TE411s752视频属性的抓取
# BV号为1TE411s752的视频属性抓取结束
# 开始BV号为1ME411c7wy视频属性的抓取
# BV号为1ME411c7wy的视频属性抓取结束
# 开始BV号为1gA411h7wg视频属性的抓取
# BV号为1gA411h7wg的视频属性抓取结束
# 开始BV号为1v7411C7rn视频属性的抓取
# BV号为1v7411C7rn的视频属性抓取结束
# 开始BV号为1Q7411m7be视频属性的抓取
# BV号为1Q7411m7be的视频属性抓取结束
# 开始BV号为1JZ4y1j7JL视频属性的抓取
# BV号为1JZ4y1j7JL的视频属性抓取结束
# 开始BV号为1d7411m7iP视频属性的抓取
# BV号为1d7411m7iP的视频属性抓取结束
# 开始BV号为1t7411Z79N视频属性的抓取
# BV号为1t7411Z79N的视频属性抓取结束
# 开始BV号为1z7411o7rK视频属性的抓取
# BV号为1z7411o7rK的视频属性抓取结束
# 开始BV号为1fE411M7v6视频属性的抓取
# BV号为1fE411M7v6的视频属性抓取结束
# 开始BV号为1X64y1M7py视频属性的抓取
# BV号为1X64y1M7py的视频属性抓取结束
# 开始BV号为19E411F7C6视频属性的抓取
# BV号为19E411F7C6的视频属性抓取结束
# 开始BV号为137411m7oe视频属性的抓取
# BV号为137411m7oe的视频属性抓取结束
# 开始BV号为147411f7TE视频属性的抓取
# BV号为147411f7TE的视频属性抓取结束
# 开始BV号为1DE4113752视频属性的抓取
# BV号为1DE4113752的视频属性抓取结束
# 开始BV号为1PE411p734视频属性的抓取
# BV号为1PE411p734的视频属性抓取结束
# 开始BV号为157411f7iL视频属性的抓取
# BV号为157411f7iL的视频属性抓取结束
# 开始BV号为1CE411K7Ff视频属性的抓取
# BV号为1CE411K7Ff的视频属性抓取结束
# 开始BV号为1k64y1M7ET视频属性的抓取
# BV号为1k64y1M7ET的视频属性抓取结束
# 开始BV号为1JA411h7ja视频属性的抓取
# BV号为1JA411h7ja的视频属性抓取结束
# 开始BV号为1gE411w742视频属性的抓取
# BV号为1gE411w742的视频属性抓取结束
# 开始BV号为1jE411w7Ga视频属性的抓取
# BV号为1jE411w7Ga的视频属性抓取结束
# 开始BV号为197411m7V2视频属性的抓取
# BV号为197411m7V2的视频属性抓取结束
# 开始BV号为1r5411674V视频属性的抓取
# BV号为1r5411674V的视频属性抓取结束
# 开始BV号为1t741127zo视频属性的抓取
# BV号为1t741127zo的视频属性抓取结束
# 开始BV号为1S741117pG视频属性的抓取
# BV号为1S741117pG的视频属性抓取结束
# 开始BV号为1Z7411D7c9视频属性的抓取
# BV号为1Z7411D7c9的视频属性抓取结束
# 开始BV号为1VE411E7Yz视频属性的抓取
# BV号为1VE411E7Yz的视频属性抓取结束
# 开始BV号为17E411E7vq视频属性的抓取
# BV号为17E411E7vq的视频属性抓取结束
# 开始BV号为1tp411A7KY视频属性的抓取
# BV号为1tp411A7KY的视频属性抓取结束
# 开始BV号为1EE411L7LH视频属性的抓取
# BV号为1EE411L7LH的视频属性抓取结束
# 开始BV号为1ee411x7ho视频属性的抓取
# BV号为1ee411x7ho的视频属性抓取结束
# 开始BV号为1dE411g7Ps视频属性的抓取
# BV号为1dE411g7Ps的视频属性抓取结束
# 开始BV号为1z741127cL视频属性的抓取
# BV号为1z741127cL的视频属性抓取结束
# 开始BV号为1D7411d7Lq视频属性的抓取
# BV号为1D7411d7Lq的视频属性抓取结束
# 开始BV号为1CE41177yU视频属性的抓取
# BV号为1CE41177yU的视频属性抓取结束
# 开始BV号为1S7411C75y视频属性的抓取
# BV号为1S7411C75y的视频属性抓取结束
# 开始BV号为1HE411L7DY视频属性的抓取
# BV号为1HE411L7DY的视频属性抓取结束
# 开始BV号为1nT4y15796视频属性的抓取
# BV号为1nT4y15796的视频属性抓取结束
# 开始BV号为1JE411476G视频属性的抓取
# BV号为1JE411476G的视频属性抓取结束
# 开始BV号为1qp4y1177r视频属性的抓取
# BV号为1qp4y1177r的视频属性抓取结束
# 开始BV号为1ME411F7VB视频属性的抓取
# BV号为1ME411F7VB的视频属性抓取结束
# 开始BV号为1EE411p7xY视频属性的抓取
# BV号为1EE411p7xY的视频属性抓取结束
# 开始BV号为1s7411f7Cr视频属性的抓取
# BV号为1s7411f7Cr的视频属性抓取结束
# 开始BV号为1C7411y7XM视频属性的抓取
# BV号为1C7411y7XM的视频属性抓取结束
# 开始BV号为1PE411E7dU视频属性的抓取
# BV号为1PE411E7dU的视频属性抓取结束
# 开始BV号为1bE411x7Dq视频属性的抓取
# BV号为1bE411x7Dq的视频属性抓取结束
# 开始BV号为1e7411m7S2视频属性的抓取
# BV号为1e7411m7S2的视频属性抓取结束
# 开始BV号为1iE411E7wh视频属性的抓取
# BV号为1iE411E7wh的视频属性抓取结束
# 开始BV号为1DE411L7uQ视频属性的抓取
# BV号为1DE411L7uQ的视频属性抓取结束
# 开始BV号为1fa4y147GF视频属性的抓取
# BV号为1fa4y147GF的视频属性抓取结束
# 开始BV号为1ap4y1C7Sw视频属性的抓取
# BV号为1ap4y1C7Sw的视频属性抓取结束
# 开始BV号为1qC4y1s78v视频属性的抓取
# BV号为1qC4y1s78v的视频属性抓取结束
# 开始BV号为1c54y1d7Tv视频属性的抓取
# BV号为1c54y1d7Tv的视频属性抓取结束
# 开始BV号为1vg4y1z7ZA视频属性的抓取
# BV号为1vg4y1z7ZA的视频属性抓取结束
# 开始BV号为15f4y1m74S视频属性的抓取
# BV号为15f4y1m74S的视频属性抓取结束
# 开始BV号为1n54y1d7rp视频属性的抓取
# BV号为1n54y1d7rp的视频属性抓取结束
# 开始BV号为16z411B7DH视频属性的抓取
# BV号为16z411B7DH的视频属性抓取结束
# 开始BV号为12z411b7Jw视频属性的抓取
# BV号为12z411b7Jw的视频属性抓取结束
# 开始BV号为1HZ4y1x7Jn视频属性的抓取
# BV号为1HZ4y1x7Jn的视频属性抓取结束
# 开始BV号为1y54y1Q7uF视频属性的抓取
# BV号为1y54y1Q7uF的视频属性抓取结束
# 开始BV号为13V411o7QW视频属性的抓取
# BV号为13V411o7QW的视频属性抓取结束
# 开始BV号为1E64y1u7B8视频属性的抓取
# BV号为1E64y1u7B8的视频属性抓取结束
# 开始BV号为1rk4y1R7jM视频属性的抓取
# BV号为1rk4y1R7jM的视频属性抓取结束
# 开始BV号为1eQ4y1M7Gc视频属性的抓取
# BV号为1eQ4y1M7Gc的视频属性抓取结束
# 开始BV号为1qK4y1r7wD视频属性的抓取
# BV号为1qK4y1r7wD的视频属性抓取结束
# 开始BV号为1dk4y197cL视频属性的抓取
# 开始BV号为1dk4y197cL视频属性的抓取
# BV号为1dk4y197cL的视频属性抓取结束
# 开始BV号为1Ec411h7dk视频属性的抓取
# BV号为1Ec411h7dk的视频属性抓取结束
# 开始BV号为1xQ4y1K7cY视频属性的抓取
# BV号为1xQ4y1K7cY的视频属性抓取结束
# 开始BV号为1dC4y1s7Bz视频属性的抓取
# BV号为1dC4y1s7Bz的视频属性抓取结束
# 开始BV号为1Sp4y1X7Xy视频属性的抓取
# BV号为1Sp4y1X7Xy的视频属性抓取结束
# 开始BV号为13Q4y1M7Pb视频属性的抓取
# BV号为13Q4y1M7Pb的视频属性抓取结束
# 开始BV号为1BA41147RQ视频属性的抓取
# BV号为1BA41147RQ的视频属性抓取结束
# 开始BV号为1x64y1T7M9视频属性的抓取
# BV号为1x64y1T7M9的视频属性抓取结束
# 开始BV号为1hc411h766视频属性的抓取
# BV号为1hc411h766的视频属性抓取结束
# 开始BV号为1tC4y1s74p视频属性的抓取
# 开始BV号为1tC4y1s74p视频属性的抓取
# BV号为1tC4y1s74p的视频属性抓取结束
# 开始BV号为1v64y1u7Va视频属性的抓取
# BV号为1v64y1u7Va的视频属性抓取结束
# 开始BV号为1AT4y1G7cH视频属性的抓取
# BV号为1AT4y1G7cH的视频属性抓取结束
# 开始BV号为1Cp4y1X7EU视频属性的抓取
# BV号为1Cp4y1X7EU的视频属性抓取结束
# 开始BV号为1jQ4y1T7EF视频属性的抓取
# BV号为1jQ4y1T7EF的视频属性抓取结束
# 开始BV号为1C5411x76D视频属性的抓取
# BV号为1C5411x76D的视频属性抓取结束
# 开始BV号为15K4y1C7Yc视频属性的抓取
# BV号为15K4y1C7Yc的视频属性抓取结束
# 开始BV号为1Mp4y1y7cQ视频属性的抓取
# BV号为1Mp4y1y7cQ的视频属性抓取结束
# 开始BV号为12g4y187qH视频属性的抓取
# BV号为12g4y187qH的视频属性抓取结束
# 开始BV号为18g4y187Cw视频属性的抓取
# BV号为18g4y187Cw的视频属性抓取结束
# 开始BV号为1az411B79U视频属性的抓取
# BV号为1az411B79U的视频属性抓取结束
# 开始BV号为1q54y1Q7i2视频属性的抓取
# BV号为1q54y1Q7i2的视频属性抓取结束
# 开始BV号为1yK411V7Vf视频属性的抓取
# BV号为1yK411V7Vf的视频属性抓取结束
# 开始BV号为1Sg4y1z7PJ视频属性的抓取
# BV号为1Sg4y1z7PJ的视频属性抓取结束
# 开始BV号为1Dg4y1z78Z视频属性的抓取
# BV号为1Dg4y1z78Z的视频属性抓取结束
# 开始BV号为1864y1u76P视频属性的抓取
# BV号为1864y1u76P的视频属性抓取结束
# 开始BV号为1wp4y1y7AG视频属性的抓取
# BV号为1wp4y1y7AG的视频属性抓取结束
# 开始BV号为1Dg4y1z7YV视频属性的抓取
# BV号为1Dg4y1z7YV的视频属性抓取结束
# 开始BV号为1ha4y1t7YS视频属性的抓取
# BV号为1ha4y1t7YS的视频属性抓取结束
# 开始BV号为1Ht4y1279G视频属性的抓取
# BV号为1Ht4y1279G的视频属性抓取结束
# 开始BV号为1Q5411x7NF视频属性的抓取
# BV号为1Q5411x7NF的视频属性抓取结束
# 开始BV号为1Hg4y1z79i视频属性的抓取
# BV号为1Hg4y1z79i的视频属性抓取结束
# 开始BV号为1jC4y1x71A视频属性的抓取
# BV号为1jC4y1x71A的视频属性抓取结束
# 开始BV号为1wc411h7w8视频属性的抓取
# BV号为1wc411h7w8的视频属性抓取结束
# 开始BV号为1gt4y127jn视频属性的抓取
# BV号为1gt4y127jn的视频属性抓取结束
# 开始BV号为1Ea4y1x7XX视频属性的抓取
# BV号为1Ea4y1x7XX的视频属性抓取结束
# 开始BV号为1At4y1m7iq视频属性的抓取
# BV号为1At4y1m7iq的视频属性抓取结束
# 开始BV号为1p5411t773视频属性的抓取
# BV号为1p5411t773的视频属性抓取结束
# 开始BV号为1NC4y1x75D视频属性的抓取
# BV号为1NC4y1x75D的视频属性抓取结束
# 开始BV号为1Tt4y127Ty视频属性的抓取
# BV号为1Tt4y127Ty的视频属性抓取结束
# 开始BV号为1Hp4y1y7AN视频属性的抓取
# BV号为1Hp4y1y7AN的视频属性抓取结束
# 开始BV号为1ug4y187xp视频属性的抓取
# BV号为1ug4y187xp的视频属性抓取结束
# 开始BV号为1QV411o771视频属性的抓取
# BV号为1QV411o771的视频属性抓取结束
# 开始BV号为1gC4y1W7oy视频属性的抓取
# BV号为1gC4y1W7oy的视频属性抓取结束
# 开始BV号为12f4y1S7F2视频属性的抓取
# BV号为12f4y1S7F2的视频属性抓取结束
# 开始BV号为1Za4y1v7Eb视频属性的抓取
# BV号为1Za4y1v7Eb的视频属性抓取结束
# 开始BV号为1EK4y1k73f视频属性的抓取
# BV号为1EK4y1k73f的视频属性抓取结束
# 开始BV号为1y64y1u7eF视频属性的抓取
# BV号为1y64y1u7eF的视频属性抓取结束
# 开始BV号为14e411s7PZ视频属性的抓取
# BV号为14e411s7PZ的视频属性抓取结束
# 开始BV号为1u64y1M74f视频属性的抓取
# BV号为1u64y1M74f的视频属性抓取结束
# 开始BV号为1RQ4y1K7tN视频属性的抓取
# BV号为1RQ4y1K7tN的视频属性抓取结束
# 开始BV号为1U5411t7oJ视频属性的抓取
# BV号为1U5411t7oJ的视频属性抓取结束
# 开始BV号为1oa4y1v7CS视频属性的抓取
# BV号为1oa4y1v7CS的视频属性抓取结束
# 开始BV号为1qg4y187PM视频属性的抓取
# BV号为1qg4y187PM的视频属性抓取结束
# 开始BV号为16K4y1r7ZE视频属性的抓取
# BV号为16K4y1r7ZE的视频属性抓取结束
# 开始BV号为1qZ4y1W7K4视频属性的抓取
# BV号为1qZ4y1W7K4的视频属性抓取结束
# 开始BV号为1Sp4y1X7GF视频属性的抓取
# BV号为1Sp4y1X7GF的视频属性抓取结束
# 开始BV号为1mk4y1R74n视频属性的抓取
# BV号为1mk4y1R74n的视频属性抓取结束
# 开始BV号为1q64y1T7pA视频属性的抓取
# BV号为1q64y1T7pA的视频属性抓取结束
# 开始BV号为1gK411j7KC视频属性的抓取
# BV号为1gK411j7KC的视频属性抓取结束
# 开始BV号为1D54y1976X视频属性的抓取
# BV号为1D54y1976X的视频属性抓取结束
# 开始BV号为1jt4y1U7MK视频属性的抓取
# BV号为1jt4y1U7MK的视频属性抓取结束
# 开始BV号为1NV411Z731视频属性的抓取
# BV号为1NV411Z731的视频属性抓取结束
# 开始BV号为1Na4y147Av视频属性的抓取
# BV号为1Na4y147Av的视频属性抓取结束
# 开始BV号为1aK4y1b7qL视频属性的抓取
# BV号为1aK4y1b7qL的视频属性抓取结束
# 开始BV号为1QZ4y1W78Z视频属性的抓取
# BV号为1QZ4y1W78Z的视频属性抓取结束
# 开始BV号为1P64y1u7eX视频属性的抓取
# BV号为1P64y1u7eX的视频属性抓取结束
# 开始BV号为18i4y1t7uG视频属性的抓取
# BV号为18i4y1t7uG的视频属性抓取结束
# 开始BV号为1Ct4y127Nc视频属性的抓取
# BV号为1Ct4y127Nc的视频属性抓取结束
# 开始BV号为1zz411B7tP视频属性的抓取
# BV号为1zz411B7tP的视频属性抓取结束
# 开始BV号为12t4y127QP视频属性的抓取
# BV号为12t4y127QP的视频属性抓取结束
# 开始BV号为1cV411Z7HG视频属性的抓取
# BV号为1cV411Z7HG的视频属性抓取结束
# 开始BV号为17A411h7GY视频属性的抓取
# BV号为17A411h7GY的视频属性抓取结束
# 开始BV号为1k54y1Q7V1视频属性的抓取
# BV号为1k54y1Q7V1的视频属性抓取结束
# 开始BV号为1ok4y1r7nd视频属性的抓取
# BV号为1ok4y1r7nd的视频属性抓取结束
# 开始BV号为1at4y127Y6视频属性的抓取
# BV号为1at4y127Y6的视频属性抓取结束
# 开始BV号为1XT4y1G7yN视频属性的抓取
# BV号为1XT4y1G7yN的视频属性抓取结束
# 开始BV号为1Ue411W7jY视频属性的抓取
# BV号为1Ue411W7jY的视频属性抓取结束
# 开始BV号为1qC4y1s74Y视频属性的抓取
# BV号为1qC4y1s74Y的视频属性抓取结束
# 开始BV号为185411x7bL视频属性的抓取
# BV号为185411x7bL的视频属性抓取结束
# 开始BV号为1VQ4y1K7wm视频属性的抓取
# BV号为1VQ4y1K7wm的视频属性抓取结束
# 开始BV号为17K411j7hh视频属性的抓取
# BV号为17K411j7hh的视频属性抓取结束
# 开始BV号为12C4y1s7Hu视频属性的抓取
# BV号为12C4y1s7Hu的视频属性抓取结束
# 开始BV号为1NV411d7Mm视频属性的抓取
# BV号为1NV411d7Mm的视频属性抓取结束
# 开始BV号为1se411x76V视频属性的抓取
# BV号为1se411x76V的视频属性抓取结束
# 开始BV号为1aK41157P6视频属性的抓取
# BV号为1aK41157P6的视频属性抓取结束
# 开始BV号为1K54y1X7tG视频属性的抓取
# BV号为1K54y1X7tG的视频属性抓取结束
# 开始BV号为12Q4y1N7ih视频属性的抓取
# BV号为12Q4y1N7ih的视频属性抓取结束
# 开始BV号为1Ez411q7ue视频属性的抓取
# BV号为1Ez411q7ue的视频属性抓取结束
# 开始BV号为1pe411W7ry视频属性的抓取
# BV号为1pe411W7ry的视频属性抓取结束
# 开始BV号为1ep4y1Q76i视频属性的抓取
# BV号为1ep4y1Q76i的视频属性抓取结束
# 开始BV号为1C54y1X7Hp视频属性的抓取
# BV号为1C54y1X7Hp的视频属性抓取结束
# 开始BV号为1Ja4y1e7sP视频属性的抓取
# BV号为1Ja4y1e7sP的视频属性抓取结束
# 开始BV号为1Vi4y147ka视频属性的抓取
# BV号为1Vi4y147ka的视频属性抓取结束
# 开始BV号为1hz411q7Uz视频属性的抓取
# BV号为1hz411q7Uz的视频属性抓取结束
# 开始BV号为1fK4y1b748视频属性的抓取
# BV号为1fK4y1b748的视频属性抓取结束
# 开始BV号为1YA411q7yo视频属性的抓取
# BV号为1YA411q7yo的视频属性抓取结束
# 开始BV号为1Wa4y147g9视频属性的抓取
# BV号为1Wa4y147g9的视频属性抓取结束
# 开始BV号为1s541147ZY视频属性的抓取
# BV号为1s541147ZY的视频属性抓取结束
# 开始BV号为1Tg4y167Xa视频属性的抓取
# BV号为1Tg4y167Xa的视频属性抓取结束
# 开始BV号为1bQ4y1T7Hs视频属性的抓取
# BV号为1bQ4y1T7Hs的视频属性抓取结束
# 开始BV号为1kZ4y1p7gc视频属性的抓取
# BV号为1kZ4y1p7gc的视频属性抓取结束
# 开始BV号为1gK411W7Cf视频属性的抓取
# BV号为1gK411W7Cf的视频属性抓取结束
# 开始BV号为1yZ4y1s7d6视频属性的抓取
# BV号为1yZ4y1s7d6的视频属性抓取结束
# 开始BV号为1qC4y1p7u1视频属性的抓取
# BV号为1qC4y1p7u1的视频属性抓取结束
# 开始BV号为1Qf4y1m74e视频属性的抓取
# BV号为1Qf4y1m74e的视频属性抓取结束
# 开始BV号为17K411s7Tq视频属性的抓取
# BV号为17K411s7Tq的视频属性抓取结束
# 开始BV号为1Y5411s7is视频属性的抓取
# BV号为1Y5411s7is的视频属性抓取结束
# 开始BV号为1Xt4y127CD视频属性的抓取
# BV号为1Xt4y127CD的视频属性抓取结束
# 开始BV号为1Bi4y147zv视频属性的抓取
# BV号为1Bi4y147zv的视频属性抓取结束
# 开始BV号为1jz411q7Xk视频属性的抓取
# BV号为1jz411q7Xk的视频属性抓取结束
# 开始BV号为1mV411C7BX视频属性的抓取
# BV号为1mV411C7BX的视频属性抓取结束
# 开始BV号为1nk4y167hM视频属性的抓取
# BV号为1nk4y167hM的视频属性抓取结束
# 开始BV号为1wQ4y1K7tD视频属性的抓取
# BV号为1wQ4y1K7tD的视频属性抓取结束
# 开始BV号为1H5411s7qf视频属性的抓取
# BV号为1H5411s7qf的视频属性抓取结束
# 开始BV号为1o5411s71w视频属性的抓取
# BV号为1o5411s71w的视频属性抓取结束
# 开始BV号为1fV411d7TB视频属性的抓取
# BV号为1fV411d7TB的视频属性抓取结束
# 开始BV号为1wK411s7T4视频属性的抓取
# BV号为1wK411s7T4的视频属性抓取结束
# 开始BV号为1dK411W7vM视频属性的抓取
# 开始BV号为1dK411W7vM视频属性的抓取
# BV号为1dK411W7vM的视频属性抓取结束
# 开始BV号为1GZ4y1W7in视频属性的抓取
# BV号为1GZ4y1W7in的视频属性抓取结束
# 开始BV号为1Ki4y1b7Ha视频属性的抓取
# BV号为1Ki4y1b7Ha的视频属性抓取结束
# 开始BV号为19f4y117eq视频属性的抓取
# BV号为19f4y117eq的视频属性抓取结束
# 开始BV号为1dZ4y1p7ib视频属性的抓取
# BV号为1dZ4y1p7ib的视频属性抓取结束
# 开始BV号为1Ce411p7DR视频属性的抓取
# BV号为1Ce411p7DR的视频属性抓取结束
# 开始BV号为1ot4y1278s视频属性的抓取
# BV号为1ot4y1278s的视频属性抓取结束
# 开始BV号为1Zg4y1q7Bp视频属性的抓取
# BV号为1Zg4y1q7Bp的视频属性抓取结束
# 开始BV号为1ia4y1i7nu视频属性的抓取
# BV号为1ia4y1i7nu的视频属性抓取结束
# 开始BV号为17f4y1U721视频属性的抓取
# BV号为17f4y1U721的视频属性抓取结束
# 开始BV号为1aQ4y1A7ej视频属性的抓取
# BV号为1aQ4y1A7ej的视频属性抓取结束
# 开始BV号为1cK4y1t7qd视频属性的抓取
# BV号为1cK4y1t7qd的视频属性抓取结束
# 开始BV号为1xK4y187dc视频属性的抓取
# BV号为1xK4y187dc的视频属性抓取结束
# 开始BV号为1LV411C7pC视频属性的抓取
# BV号为1LV411C7pC的视频属性抓取结束
# 开始BV号为1Cp4y1Q7Bo视频属性的抓取
# BV号为1Cp4y1Q7Bo的视频属性抓取结束
# 开始BV号为1jg4y1B7cF视频属性的抓取
# BV号为1jg4y1B7cF的视频属性抓取结束
# 开始BV号为1xA411q7rn视频属性的抓取
# BV号为1xA411q7rn的视频属性抓取结束
# 开始BV号为1kA411t7Dc视频属性的抓取
# BV号为1kA411t7Dc的视频属性抓取结束
# 开始BV号为1Jk4y167BG视频属性的抓取
# BV号为1Jk4y167BG的视频属性抓取结束
# 开始BV号为11i4y147bs视频属性的抓取
# BV号为11i4y147bs的视频属性抓取结束
# 开始BV号为1Xz4y1X7dr视频属性的抓取
# BV号为1Xz4y1X7dr的视频属性抓取结束
# 开始BV号为1Sg4y1q7Gp视频属性的抓取
# BV号为1Sg4y1q7Gp的视频属性抓取结束
# 开始BV号为1rQ4y1A7Zi视频属性的抓取
# BV号为1rQ4y1A7Zi的视频属性抓取结束
# 开始BV号为1it4y1C7uK视频属性的抓取
# BV号为1it4y1C7uK的视频属性抓取结束
# 开始BV号为1Rg4y1B7Tn视频属性的抓取
# BV号为1Rg4y1B7Tn的视频属性抓取结束
# 开始BV号为1JZ4y1p7TS视频属性的抓取
# BV号为1JZ4y1p7TS的视频属性抓取结束
# 开始BV号为1ik4y1k7gD视频属性的抓取
# BV号为1ik4y1k7gD的视频属性抓取结束
# 开始BV号为1Tf4y127br视频属性的抓取
# BV号为1Tf4y127br的视频属性抓取结束
# 开始BV号为17Z4y1p7gf视频属性的抓取
# BV号为17Z4y1p7gf的视频属性抓取结束
# 开始BV号为1xz4y1d7fK视频属性的抓取
# BV号为1xz4y1d7fK的视频属性抓取结束
# 开始BV号为1NZ4y1W7Kn视频属性的抓取
# BV号为1NZ4y1W7Kn的视频属性抓取结束
# 开始BV号为19k4y167xX视频属性的抓取
# BV号为19k4y167xX的视频属性抓取结束
# 开始BV号为16Q4y1N76Z视频属性的抓取
# BV号为16Q4y1N76Z的视频属性抓取结束
# 开始BV号为1XK411W7YM视频属性的抓取
# BV号为1XK411W7YM的视频属性抓取结束
# 开始BV号为1Qe411p7Jw视频属性的抓取
# BV号为1Qe411p7Jw的视频属性抓取结束
# 开始BV号为1kf4y1m7VD视频属性的抓取
# BV号为1kf4y1m7VD的视频属性抓取结束
# 开始BV号为1ef4y1m73w视频属性的抓取
# BV号为1ef4y1m73w的视频属性抓取结束
# 开始BV号为1c5411x73J视频属性的抓取
# BV号为1c5411x73J的视频属性抓取结束
# 开始BV号为1Ua4y1i7Zw视频属性的抓取
# BV号为1Ua4y1i7Zw的视频属性抓取结束
# 开始BV号为1j54y1D77h视频属性的抓取
# BV号为1j54y1D77h的视频属性抓取结束
# 开始BV号为1Bp4y1Q7mr视频属性的抓取
# BV号为1Bp4y1Q7mr的视频属性抓取结束
# 开始BV号为1JT4y1u7iA视频属性的抓取
# BV号为1JT4y1u7iA的视频属性抓取结束
# 开始BV号为1Ta4y1v7mS视频属性的抓取
# BV号为1Ta4y1v7mS的视频属性抓取结束
# 开始BV号为1f54y1D7B3视频属性的抓取
# BV号为1f54y1D7B3的视频属性抓取结束
# 开始BV号为1XA41147oZ视频属性的抓取
# 开始BV号为1XA41147oZ视频属性的抓取
# BV号为1XA41147oZ的视频属性抓取结束
# 开始BV号为1o5411s74m视频属性的抓取
# BV号为1o5411s74m的视频属性抓取结束
# 开始BV号为1Ak4y1r79T视频属性的抓取
# BV号为1Ak4y1r79T的视频属性抓取结束
# 开始BV号为1Me411W7tj视频属性的抓取
# BV号为1Me411W7tj的视频属性抓取结束
# 开始BV号为11i4y147jo视频属性的抓取
# BV号为11i4y147jo的视频属性抓取结束
# 开始BV号为1cK4y1b791视频属性的抓取
# BV号为1cK4y1b791的视频属性抓取结束
# 开始BV号为1GQ4y1P7au视频属性的抓取
# BV号为1GQ4y1P7au的视频属性抓取结束
# 开始BV号为1pA411q7U6视频属性的抓取
# BV号为1pA411q7U6的视频属性抓取结束
# 开始BV号为1cZ4y1W7bk视频属性的抓取
# BV号为1cZ4y1W7bk的视频属性抓取结束
# 开始BV号为1xe411p7iG视频属性的抓取
# BV号为1xe411p7iG的视频属性抓取结束
# 开始BV号为1oz4y1X7fJ视频属性的抓取
# BV号为1oz4y1X7fJ的视频属性抓取结束
# 开始BV号为1Jg4y167cN视频属性的抓取
# BV号为1Jg4y167cN的视频属性抓取结束
# 开始BV号为1pg4y1B7io视频属性的抓取
# BV号为1pg4y1B7io的视频属性抓取结束
# 开始BV号为1BA411t7sg视频属性的抓取
# BV号为1BA411t7sg的视频属性抓取结束
# 开始BV号为1ea4y1i7uT视频属性的抓取
# BV号为1ea4y1i7uT的视频属性抓取结束
# 开始BV号为1Mk4y167vh视频属性的抓取
# BV号为1Mk4y167vh的视频属性抓取结束
# 开始BV号为1zf4y1m72f视频属性的抓取
# BV号为1zf4y1m72f的视频属性抓取结束
# 开始BV号为1rp4y1Q7L5视频属性的抓取
# BV号为1rp4y1Q7L5的视频属性抓取结束
# 开始BV号为1a54y1D7cj视频属性的抓取
# BV号为1a54y1D7cj的视频属性抓取结束
# 开始BV号为1J54y1D7e2视频属性的抓取
# BV号为1J54y1D7e2的视频属性抓取结束
# 开始BV号为15541147mF视频属性的抓取
# BV号为15541147mF的视频属性抓取结束
# 开始BV号为1G5411s7Qo视频属性的抓取
# BV号为1G5411s7Qo的视频属性抓取结束
# 开始BV号为12C4y1W72C视频属性的抓取
# BV号为12C4y1W72C的视频属性抓取结束
# 开始BV号为1nz411i7dW视频属性的抓取
# BV号为1nz411i7dW的视频属性抓取结束
# 开始BV号为12T4y1E7Hz视频属性的抓取
# BV号为12T4y1E7Hz的视频属性抓取结束
# 开始BV号为1DK4y147Kf视频属性的抓取
# BV号为1DK4y147Kf的视频属性抓取结束
# 开始BV号为1Ca4y1Y7XJ视频属性的抓取
# BV号为1Ca4y1Y7XJ的视频属性抓取结束
# 开始BV号为1kk4y1z7RD视频属性的抓取
# BV号为1kk4y1z7RD的视频属性抓取结束
# 开始BV号为12f4y11721视频属性的抓取
# BV号为12f4y11721的视频属性抓取结束
# 开始BV号为19K411p7A4视频属性的抓取
# BV号为19K411p7A4的视频属性抓取结束
# 开始BV号为1ha4y1v71W视频属性的抓取
# BV号为1ha4y1v71W的视频属性抓取结束
# 开始BV号为1gD4y1Q7pY视频属性的抓取
# BV号为1gD4y1Q7pY的视频属性抓取结束
# 开始BV号为1Hz4y1X7sQ视频属性的抓取
# BV号为1Hz4y1X7sQ的视频属性抓取结束
# 开始BV号为1tK411p7rP视频属性的抓取
# BV号为1tK411p7rP的视频属性抓取结束
# 开始BV号为1Qv411B7fb视频属性的抓取
# BV号为1Qv411B7fb的视频属性抓取结束
# 开始BV号为1Sk4y1z78b视频属性的抓取
# BV号为1Sk4y1z78b的视频属性抓取结束
# 开始BV号为1vf4y1274r视频属性的抓取
# BV号为1vf4y1274r的视频属性抓取结束
# 开始BV号为1vf4y127vr视频属性的抓取
# BV号为1vf4y127vr的视频属性抓取结束
# 开始BV号为1Ma4y1Y7Es视频属性的抓取
# BV号为1Ma4y1Y7Es的视频属性抓取结束
# 开始BV号为1tT4y177Vj视频属性的抓取
# BV号为1tT4y177Vj的视频属性抓取结束
# 开始BV号为1eV411k7uZ视频属性的抓取
# BV号为1eV411k7uZ的视频属性抓取结束
# 开始BV号为1P5411W7rQ视频属性的抓取
# BV号为1P5411W7rQ的视频属性抓取结束
# 开始BV号为1GA411B72a视频属性的抓取
# BV号为1GA411B72a的视频属性抓取结束
# 开始BV号为1MK4y147Fm视频属性的抓取
# BV号为1MK4y147Fm的视频属性抓取结束
# 开始BV号为1Ev411B75M视频属性的抓取
# BV号为1Ev411B75M的视频属性抓取结束
# 开始BV号为1oK4y1t7CT视频属性的抓取
# BV号为1oK4y1t7CT的视频属性抓取结束
# 开始BV号为1154y1B7R4视频属性的抓取
# BV号为1154y1B7R4的视频属性抓取结束
# 开始BV号为1AE411W72h视频属性的抓取
# BV号为1AE411W72h的视频属性抓取结束
# 开始BV号为16K4y1x7Hr视频属性的抓取
# BV号为16K4y1x7Hr的视频属性抓取结束
# 开始BV号为1tg4y1q7tC视频属性的抓取
# BV号为1tg4y1q7tC的视频属性抓取结束
# 开始BV号为1cz4y1R7ED视频属性的抓取
# BV号为1cz4y1R7ED的视频属性抓取结束
# 开始BV号为1UK411p717视频属性的抓取
# BV号为1UK411p717的视频属性抓取结束
# 开始BV号为16z4y197SA视频属性的抓取
# BV号为16z4y197SA的视频属性抓取结束
# 开始BV号为16i4y1x7MH视频属性的抓取
# BV号为16i4y1x7MH的视频属性抓取结束
# 开始BV号为1qT4y1E76k视频属性的抓取
# BV号为1qT4y1E76k的视频属性抓取结束
# 开始BV号为1eA411v7va视频属性的抓取
# BV号为1eA411v7va的视频属性抓取结束
# 开始BV号为18z411e7uw视频属性的抓取
# BV号为18z411e7uw的视频属性抓取结束
# 开始BV号为1EC4y1s7ZE视频属性的抓取
# BV号为1EC4y1s7ZE的视频属性抓取结束
# 开始BV号为1EK411p7XP视频属性的抓取
# BV号为1EK411p7XP的视频属性抓取结束
# 开始BV号为1fz411i7Bf视频属性的抓取
# BV号为1fz411i7Bf的视频属性抓取结束
# 开始BV号为1qg4y1q7HT视频属性的抓取
# BV号为1qg4y1q7HT的视频属性抓取结束
# 开始BV号为1NT4y1J7Dc视频属性的抓取
# BV号为1NT4y1J7Dc的视频属性抓取结束
# 开始BV号为1sz411e7RA视频属性的抓取
# BV号为1sz411e7RA的视频属性抓取结束
# 开始BV号为1sD4y1D7Yw视频属性的抓取
# BV号为1sD4y1D7Yw的视频属性抓取结束
# 开始BV号为1eg4y1q7qP视频属性的抓取
# BV号为1eg4y1q7qP的视频属性抓取结束
# 开始BV号为1a5411Y7e5视频属性的抓取
# BV号为1a5411Y7e5的视频属性抓取结束
# 开始BV号为1gz4y1R7fy视频属性的抓取
# BV号为1gz4y1R7fy的视频属性抓取结束
# 开始BV号为1Qg4y1v7Ld视频属性的抓取
# BV号为1Qg4y1v7Ld的视频属性抓取结束
# 开始BV号为1mA411v7vo视频属性的抓取
# BV号为1mA411v7vo的视频属性抓取结束
# 开始BV号为1bD4y1D7z7视频属性的抓取
# BV号为1bD4y1D7z7的视频属性抓取结束
# 开始BV号为16z4y1X7cR视频属性的抓取
# BV号为16z4y1X7cR的视频属性抓取结束
# 开始BV号为1NK4y147Ba视频属性的抓取
# BV号为1NK4y147Ba的视频属性抓取结束
# 开始BV号为1BK4y147f7视频属性的抓取
# BV号为1BK4y147f7的视频属性抓取结束
# 开始BV号为1TK4y147mP视频属性的抓取
# BV号为1TK4y147mP的视频属性抓取结束
# 开始BV号为12K4y147x3视频属性的抓取
# BV号为12K4y147x3的视频属性抓取结束
# 开始BV号为14t4y1y7xa视频属性的抓取
# BV号为14t4y1y7xa的视频属性抓取结束
# 开始BV号为1Jg4y1q7Hv视频属性的抓取
# BV号为1Jg4y1q7Hv的视频属性抓取结束
# 开始BV号为1yT4y1J7uw视频属性的抓取
# BV号为1yT4y1J7uw的视频属性抓取结束
# 开始BV号为1KV411k7XM视频属性的抓取
# BV号为1KV411k7XM的视频属性抓取结束
# 开始BV号为1st4y197Tp视频属性的抓取
# BV号为1st4y197Tp的视频属性抓取结束
# 开始BV号为1Hp4y1D7G2视频属性的抓取
# BV号为1Hp4y1D7G2的视频属性抓取结束
# 开始BV号为1sK411p7dy视频属性的抓取
# BV号为1sK411p7dy的视频属性抓取结束
# 开始BV号为1254y1B7oq视频属性的抓取
# BV号为1254y1B7oq的视频属性抓取结束
# 开始BV号为1N54y1z7kP视频属性的抓取
# BV号为1N54y1z7kP的视频属性抓取结束
# 开始BV号为1BQ4y1P7jf视频属性的抓取
# BV号为1BQ4y1P7jf的视频属性抓取结束
# 开始BV号为1tt4y1U7CX视频属性的抓取
# BV号为1tt4y1U7CX的视频属性抓取结束
# 开始BV号为1xC4y1a744视频属性的抓取
# BV号为1xC4y1a744的视频属性抓取结束
# 开始BV号为1hE411s76Q视频属性的抓取
# BV号为1hE411s76Q的视频属性抓取结束
# 开始BV号为13f4y1m7zb视频属性的抓取
# BV号为13f4y1m7zb的视频属性抓取结束
# 开始BV号为1jT4y1J7fb视频属性的抓取
# BV号为1jT4y1J7fb的视频属性抓取结束
# 开始BV号为1gt4y197Fi视频属性的抓取
# BV号为1gt4y197Fi的视频属性抓取结束
# 开始BV号为1rK411n782视频属性的抓取
# BV号为1rK411n782的视频属性抓取结束
# 开始BV号为125411p7RB视频属性的抓取
# BV号为125411p7RB的视频属性抓取结束
# 开始BV号为1Vt4y1y7o2视频属性的抓取
# BV号为1Vt4y1y7o2的视频属性抓取结束
# 开始BV号为1qT4y1J7dz视频属性的抓取
# BV号为1qT4y1J7dz的视频属性抓取结束
# 开始BV号为1Mz411z7FW视频属性的抓取
# BV号为1Mz411z7FW的视频属性抓取结束
# 开始BV号为16T4y1J7Vq视频属性的抓取
# BV号为16T4y1J7Vq的视频属性抓取结束
# 开始BV号为19z4y197TP视频属性的抓取
# BV号为19z4y197TP的视频属性抓取结束
# 开始BV号为1ip4y1D7GB视频属性的抓取
# BV号为1ip4y1D7GB的视频属性抓取结束
# 开始BV号为1tg4y1v75b视频属性的抓取
# BV号为1tg4y1v75b的视频属性抓取结束
# 开始BV号为1Cf4y127L9视频属性的抓取
# BV号为1Cf4y127L9的视频属性抓取结束
# 开始BV号为1vz411i7PX视频属性的抓取
# BV号为1vz411i7PX的视频属性抓取结束
# 开始BV号为1vZ4y1W7xN视频属性的抓取
# BV号为1vZ4y1W7xN的视频属性抓取结束
# 开始BV号为1Cp4y1U7kh视频属性的抓取
# BV号为1Cp4y1U7kh的视频属性抓取结束
# 开始BV号为1Dp4y1U7FP视频属性的抓取
# BV号为1Dp4y1U7FP的视频属性抓取结束
# 开始BV号为1Zp4y1D7gV视频属性的抓取
# BV号为1Zp4y1D7gV的视频属性抓取结束
# 开始BV号为1uk4y1z7T7视频属性的抓取
# BV号为1uk4y1z7T7的视频属性抓取结束
# 开始BV号为1cK4y147Du视频属性的抓取
# BV号为1cK4y147Du的视频属性抓取结束
# 开始BV号为1EK4y147MY视频属性的抓取
# BV号为1EK4y147MY的视频属性抓取结束
# 开始BV号为1Pt4y1y7ez视频属性的抓取
# BV号为1Pt4y1y7ez的视频属性抓取结束
# 开始BV号为16C4y1a79j视频属性的抓取
# BV号为16C4y1a79j的视频属性抓取结束
# 开始BV号为17D4y1Q7Mf视频属性的抓取
# BV号为17D4y1Q7Mf的视频属性抓取结束
# 开始BV号为1WE411s7eF视频属性的抓取
# BV号为1WE411s7eF的视频属性抓取结束
# 开始BV号为1L5411W7y7视频属性的抓取
# BV号为1L5411W7y7的视频属性抓取结束
# 开始BV号为11p4y1D7cn视频属性的抓取
# BV号为11p4y1D7cn的视频属性抓取结束
# 开始BV号为1Yg4y1i7r6视频属性的抓取
# BV号为1Yg4y1i7r6的视频属性抓取结束
# 开始BV号为1kQ4y1P7aK视频属性的抓取
# BV号为1kQ4y1P7aK的视频属性抓取结束
# 开始BV号为1qk4y1z7E5视频属性的抓取
# BV号为1qk4y1z7E5的视频属性抓取结束
# 开始BV号为1KK411W7Ct视频属性的抓取
# BV号为1KK411W7Ct的视频属性抓取结束
# 开始BV号为19z4y197T7视频属性的抓取
# BV号为19z4y197T7的视频属性抓取结束
# 开始BV号为125411p7t2视频属性的抓取
# BV号为125411p7t2的视频属性抓取结束
# 开始BV号为1p5411Y7N5视频属性的抓取
# BV号为1p5411Y7N5的视频属性抓取结束
# 开始BV号为1Ti4y1x73z视频属性的抓取
# BV号为1Ti4y1x73z的视频属性抓取结束
# 开始BV号为19k4y127pr视频属性的抓取
# BV号为19k4y127pr的视频属性抓取结束
# 开始BV号为1YD4y1S7vc视频属性的抓取
# BV号为1YD4y1S7vc的视频属性抓取结束
# 开始BV号为1Tv411q7GN视频属性的抓取
# BV号为1Tv411q7GN的视频属性抓取结束
# 开始BV号为1Jg4y1v7go视频属性的抓取
# BV号为1Jg4y1v7go的视频属性抓取结束
# 开始BV号为1mT4y177Kq视频属性的抓取
# BV号为1mT4y177Kq的视频属性抓取结束
# 开始BV号为19V41167Em视频属性的抓取
# BV号为19V41167Em的视频属性抓取结束
# 开始BV号为1v54y1q7CT视频属性的抓取
# BV号为1v54y1q7CT的视频属性抓取结束
# 开始BV号为1uK4y1v7B2视频属性的抓取
# BV号为1uK4y1v7B2的视频属性抓取结束
# 开始BV号为16a4y1h7VD视频属性的抓取
# BV号为16a4y1h7VD的视频属性抓取结束
# 开始BV号为1u54y1q7V8视频属性的抓取
# BV号为1u54y1q7V8的视频属性抓取结束
# 开始BV号为1hz4y1X7i8视频属性的抓取
# BV号为1hz4y1X7i8的视频属性抓取结束
# 开始BV号为1tD4y1U7NA视频属性的抓取
# BV号为1tD4y1U7NA的视频属性抓取结束
# 开始BV号为1ih411o71f视频属性的抓取
# BV号为1ih411o71f的视频属性抓取结束
# 开始BV号为1iZ4y1T7Sr视频属性的抓取
# BV号为1iZ4y1T7Sr的视频属性抓取结束
# 开始BV号为1Nh411Z75R视频属性的抓取
# BV号为1Nh411Z75R的视频属性抓取结束
# 开始BV号为1q5411a7mu视频属性的抓取
# BV号为1q5411a7mu的视频属性抓取结束
# 开始BV号为1Wz411v7s2视频属性的抓取
# BV号为1Wz411v7s2的视频属性抓取结束
# 开始BV号为1w54y1D7rP视频属性的抓取
# BV号为1w54y1D7rP的视频属性抓取结束
# 开始BV号为1Uh411o7AY视频属性的抓取
# BV号为1Uh411o7AY的视频属性抓取结束
# 开始BV号为1kV411B7sT视频属性的抓取
# BV号为1kV411B7sT的视频属性抓取结束
# 开始BV号为1Ni4y1V794视频属性的抓取
# BV号为1Ni4y1V794的视频属性抓取结束
# 开始BV号为1MT4y1E7c4视频属性的抓取
# BV号为1MT4y1E7c4的视频属性抓取结束
# 开始BV号为19C4y187P2视频属性的抓取
# BV号为19C4y187P2的视频属性抓取结束
# 开始BV号为1nD4y1D7q6视频属性的抓取
# BV号为1nD4y1D7q6的视频属性抓取结束
# 开始BV号为1Sk4y1q774视频属性的抓取
# BV号为1Sk4y1q774的视频属性抓取结束
# 开始BV号为1bC4y1h72s视频属性的抓取
# BV号为1bC4y1h72s的视频属性抓取结束
# 开始BV号为1WD4y1U7XE视频属性的抓取
# BV号为1WD4y1U7XE的视频属性抓取结束
# 开始BV号为1iD4y1S7Ga视频属性的抓取
# BV号为1iD4y1S7Ga的视频属性抓取结束
# 开始BV号为1ti4y1V7GD视频属性的抓取
# BV号为1ti4y1V7GD的视频属性抓取结束
# 开始BV号为1Xg4y1v7vJ视频属性的抓取
# BV号为1Xg4y1v7vJ的视频属性抓取结束
# 开始BV号为1yz4y1X7cx视频属性的抓取
# BV号为1yz4y1X7cx的视频属性抓取结束
# 开始BV号为1E54y1S7mo视频属性的抓取
# BV号为1E54y1S7mo的视频属性抓取结束
# 开始BV号为155411a7aA视频属性的抓取
# BV号为155411a7aA的视频属性抓取结束
# 开始BV号为1XK411J7eY视频属性的抓取
# BV号为1XK411J7eY的视频属性抓取结束
# 开始BV号为1vk4y1B7Un视频属性的抓取
# BV号为1vk4y1B7Un的视频属性抓取结束
# 开始BV号为19z4y1Q7fJ视频属性的抓取
# BV号为19z4y1Q7fJ的视频属性抓取结束
# 开始BV号为1zh411o7X3视频属性的抓取
# BV号为1zh411o7X3的视频属性抓取结束
# 开始BV号为1JC4y1b7NP视频属性的抓取
# BV号为1JC4y1b7NP的视频属性抓取结束
# 开始BV号为1DT4y177vv视频属性的抓取
# BV号为1DT4y177vv的视频属性抓取结束
# 开始BV号为1A5411Y7pH视频属性的抓取
# BV号为1A5411Y7pH的视频属性抓取结束
# 开始BV号为1Zp4y1U7sm视频属性的抓取
# BV号为1Zp4y1U7sm的视频属性抓取结束
# 开始BV号为1Y5411Y7u6视频属性的抓取
# BV号为1Y5411Y7u6的视频属性抓取结束
# 开始BV号为1nk4y1m7Zm视频属性的抓取
# BV号为1nk4y1m7Zm的视频属性抓取结束
# 开始BV号为12K4y1s7t2视频属性的抓取
# BV号为12K4y1s7t2的视频属性抓取结束
# 开始BV号为17g4y1i7Hj视频属性的抓取
# BV号为17g4y1i7Hj的视频属性抓取结束
# 开始BV号为1XZ4y1M7Hf视频属性的抓取
# BV号为1XZ4y1M7Hf的视频属性抓取结束
# 开始BV号为1VD4y1D7m4视频属性的抓取
# BV号为1VD4y1D7m4的视频属性抓取结束
# 开始BV号为1TK411J7DD视频属性的抓取
# BV号为1TK411J7DD的视频属性抓取结束
# 开始BV号为1hK411H7q6视频属性的抓取
# BV号为1hK411H7q6的视频属性抓取结束
# 开始BV号为1Ht4y1Q7jK视频属性的抓取
# BV号为1Ht4y1Q7jK的视频属性抓取结束
# 开始BV号为1Bt4y1Q7jV视频属性的抓取
# BV号为1Bt4y1Q7jV的视频属性抓取结束
# 开始BV号为1va4y1a7uF视频属性的抓取
# BV号为1va4y1a7uF的视频属性抓取结束
# 开始BV号为1xC4y1h7So视频属性的抓取
# BV号为1xC4y1h7So的视频属性抓取结束
# 开始BV号为1XA411i7M8视频属性的抓取
# BV号为1XA411i7M8的视频属性抓取结束
# 开始BV号为1d54y1U7uL视频属性的抓取
# BV号为1d54y1U7uL的视频属性抓取结束
# 开始BV号为1s54y1q7z2视频属性的抓取
# BV号为1s54y1q7z2的视频属性抓取结束
# 开始BV号为14t4y1Q7dD视频属性的抓取
# BV号为14t4y1Q7dD的视频属性抓取结束
# 开始BV号为16a4y1h7Pm视频属性的抓取
# BV号为16a4y1h7Pm的视频属性抓取结束
# 开始BV号为1154y1q7gT视频属性的抓取
# BV号为1154y1q7gT的视频属性抓取结束
# 开始BV号为1dT4y177gV视频属性的抓取
# BV号为1dT4y177gV的视频属性抓取结束
# 开始BV号为1554y1D7KT视频属性的抓取
# BV号为1554y1D7KT的视频属性抓取结束
# 开始BV号为1mT4y177HP视频属性的抓取
# BV号为1mT4y177HP的视频属性抓取结束
# 开始BV号为1Z5411Y7Wp视频属性的抓取
# BV号为1Z5411Y7Wp的视频属性抓取结束
# 开始BV号为1ht4y197WH视频属性的抓取
# BV号为1ht4y197WH的视频属性抓取结束
# 开始BV号为1254y1S7zc视频属性的抓取
# BV号为1254y1S7zc的视频属性抓取结束
# 开始BV号为1VC4y1h7jA视频属性的抓取
# BV号为1VC4y1h7jA的视频属性抓取结束
# 开始BV号为1rZ4y1T7Ju视频属性的抓取
# BV号为1rZ4y1T7Ju的视频属性抓取结束
# 开始BV号为1TA411Y7Ew视频属性的抓取
# BV号为1TA411Y7Ew的视频属性抓取结束
# 开始BV号为1Uf4y117SH视频属性的抓取
# BV号为1Uf4y117SH的视频属性抓取结束
# 开始BV号为1SD4y1m7y4视频属性的抓取
# BV号为1SD4y1m7y4的视频属性抓取结束
# 开始BV号为1iV411z7TK视频属性的抓取
# BV号为1iV411z7TK的视频属性抓取结束
# 开始BV号为1LA411e7tv视频属性的抓取
# BV号为1LA411e7tv的视频属性抓取结束
# 开始BV号为18D4y1Q7zk视频属性的抓取
# BV号为18D4y1Q7zk的视频属性抓取结束
# 开始BV号为1Vf4y117ks视频属性的抓取
# BV号为1Vf4y117ks的视频属性抓取结束
# 开始BV号为1uV411r7TS视频属性的抓取
# BV号为1uV411r7TS的视频属性抓取结束
# 开始BV号为1yf4y1X79J视频属性的抓取
# BV号为1yf4y1X79J的视频属性抓取结束
# 开始BV号为12V411B77m视频属性的抓取
# BV号为12V411B77m的视频属性抓取结束
# 开始BV号为1av411q7QN视频属性的抓取
# BV号为1av411q7QN的视频属性抓取结束
# 开始BV号为1DA411e7mP视频属性的抓取
# BV号为1DA411e7mP的视频属性抓取结束
# 开始BV号为115411a7Ez视频属性的抓取
# BV号为115411a7Ez的视频属性抓取结束
# 开始BV号为1rp4y1i71E视频属性的抓取
# BV号为1rp4y1i71E的视频属性抓取结束
# 开始BV号为1cf4y1d79s视频属性的抓取
# BV号为1cf4y1d79s的视频属性抓取结束
# 开始BV号为1yC4y1h73d视频属性的抓取
# BV号为1yC4y1h73d的视频属性抓取结束
# 开始BV号为1Bk4y1B7xh视频属性的抓取
# BV号为1Bk4y1B7xh的视频属性抓取结束
# 开始BV号为1it4y1X7fn视频属性的抓取
# BV号为1it4y1X7fn的视频属性抓取结束
# 开始BV号为1Bz411v7to视频属性的抓取
# BV号为1Bz411v7to的视频属性抓取结束
# 开始BV号为1oa4y1a7w2视频属性的抓取
# BV号为1oa4y1a7w2的视频属性抓取结束
# 开始BV号为1CA411i7tv视频属性的抓取
# BV号为1CA411i7tv的视频属性抓取结束
# 开始BV号为1hk4y1q7dA视频属性的抓取
# BV号为1hk4y1q7dA的视频属性抓取结束
# 开始BV号为1Nh411Z7Es视频属性的抓取
# BV号为1Nh411Z7Es的视频属性抓取结束
# 开始BV号为1ak4y1m7o7视频属性的抓取
# BV号为1ak4y1m7o7的视频属性抓取结束
# 开始BV号为1G5411Y7vr视频属性的抓取
# BV号为1G5411Y7vr的视频属性抓取结束
# 开始BV号为1av411q7gP视频属性的抓取
# BV号为1av411q7gP的视频属性抓取结束
# 开始BV号为14p4y1U7y9视频属性的抓取
# BV号为14p4y1U7y9的视频属性抓取结束
# 开始BV号为1zK411J74L视频属性的抓取
# BV号为1zK411J74L的视频属性抓取结束
# 开始BV号为1EV411r7Qz视频属性的抓取
# BV号为1EV411r7Qz的视频属性抓取结束
# 开始BV号为1LA411Y7Jq视频属性的抓取
# BV号为1LA411Y7Jq的视频属性抓取结束
# 开始BV号为1QK4y1s7iF视频属性的抓取
# BV号为1QK4y1s7iF的视频属性抓取结束
# 开始BV号为1YK411J7kt视频属性的抓取
# BV号为1YK411J7kt的视频属性抓取结束
# 开始BV号为1Xh411o7jU视频属性的抓取
# BV号为1Xh411o7jU的视频属性抓取结束
# 开始BV号为1tA411Y7Ct视频属性的抓取
# BV号为1tA411Y7Ct的视频属性抓取结束
# 开始BV号为1ti4y1M7Ae视频属性的抓取
# BV号为1ti4y1M7Ae的视频属性抓取结束
# 开始BV号为1854y1v75g视频属性的抓取
# BV号为1854y1v75g的视频属性抓取结束
# 开始BV号为1Cf4y197j6视频属性的抓取
# BV号为1Cf4y197j6的视频属性抓取结束
# 开始BV号为1Sk4y1m7it视频属性的抓取
# BV号为1Sk4y1m7it的视频属性抓取结束
# 开始BV号为1C54y1i7V1视频属性的抓取
# BV号为1C54y1i7V1的视频属性抓取结束
# 开始BV号为1FD4y1S7fg视频属性的抓取
# BV号为1FD4y1S7fg的视频属性抓取结束
# 开始BV号为1hD4y1U7hQ视频属性的抓取
# 开始BV号为1hD4y1U7hQ视频属性的抓取
# BV号为1hD4y1U7hQ的视频属性抓取结束
# 开始BV号为1EA411n7oX视频属性的抓取
# BV号为1EA411n7oX的视频属性抓取结束
# 开始BV号为11h411d7aT视频属性的抓取
# BV号为11h411d7aT的视频属性抓取结束
# 开始BV号为19K4y1v7kX视频属性的抓取
# BV号为19K4y1v7kX的视频属性抓取结束
# 开始BV号为1yf4y197yK视频属性的抓取
# BV号为1yf4y197yK的视频属性抓取结束
# 开始BV号为19541187ds视频属性的抓取
# BV号为19541187ds的视频属性抓取结束
# 开始BV号为1Qa4y1E7RX视频属性的抓取
# BV号为1Qa4y1E7RX的视频属性抓取结束
# 开始BV号为1Tk4y1U7aD视频属性的抓取
# BV号为1Tk4y1U7aD的视频属性抓取结束
# 开始BV号为1PA411Y74K视频属性的抓取
# BV号为1PA411Y74K的视频属性抓取结束
# 开始BV号为1QC4y1t72U视频属性的抓取
# BV号为1QC4y1t72U的视频属性抓取结束
# 开始BV号为1254y1v72b视频属性的抓取
# BV号为1254y1v72b的视频属性抓取结束
# 开始BV号为1Qa4y1J7gD视频属性的抓取
# BV号为1Qa4y1J7gD的视频属性抓取结束
# 开始BV号为1eC4y1t73A视频属性的抓取
# BV号为1eC4y1t73A的视频属性抓取结束
# 开始BV号为19t4y1D79S视频属性的抓取
# BV号为19t4y1D79S的视频属性抓取结束
# 开始BV号为1zV411z73u视频属性的抓取
# BV号为1zV411z73u的视频属性抓取结束
# 开始BV号为1ef4y1Q7tc视频属性的抓取
# BV号为1ef4y1Q7tc的视频属性抓取结束
# 开始BV号为1Qk4y117ma视频属性的抓取
# BV号为1Qk4y117ma的视频属性抓取结束
# 开始BV号为1f5411a7rv视频属性的抓取
# BV号为1f5411a7rv的视频属性抓取结束
# 开始BV号为1ht4y1D7Cr视频属性的抓取
# BV号为1ht4y1D7Cr的视频属性抓取结束
# 开始BV号为1Di4y1u73x视频属性的抓取
# BV号为1Di4y1u73x的视频属性抓取结束
# 开始BV号为1tt4y1S7AW视频属性的抓取
# BV号为1tt4y1S7AW的视频属性抓取结束
# 开始BV号为1JA411n7bR视频属性的抓取
# BV号为1JA411n7bR的视频属性抓取结束
# 开始BV号为1of4y1X7Tj视频属性的抓取
# BV号为1of4y1X7Tj的视频属性抓取结束
# 开始BV号为1LZ4y1M7WR视频属性的抓取
# BV号为1LZ4y1M7WR的视频属性抓取结束
# 开始BV号为1XV411z7yi视频属性的抓取
# BV号为1XV411z7yi的视频属性抓取结束
# 开始BV号为1mk4y1271G视频属性的抓取
# BV号为1mk4y1271G的视频属性抓取结束
# 开始BV号为1aV411U76M视频属性的抓取
# BV号为1aV411U76M的视频属性抓取结束
# 开始BV号为1XK4y1v7zu视频属性的抓取
# BV号为1XK4y1v7zu的视频属性抓取结束
# 开始BV号为1mT4y1L7ZL视频属性的抓取
# BV号为1mT4y1L7ZL的视频属性抓取结束
# 开始BV号为1Sh411d7eD视频属性的抓取
# BV号为1Sh411d7eD的视频属性抓取结束
# 开始BV号为1b64y1c7eN视频属性的抓取
# BV号为1b64y1c7eN的视频属性抓取结束
# 开始BV号为15T4y1777N视频属性的抓取
# BV号为15T4y1777N的视频属性抓取结束
# 开始BV号为1UK4y1v7P8视频属性的抓取
# BV号为1UK4y1v7P8的视频属性抓取结束
# 开始BV号为1Up4y1v7Wn视频属性的抓取
# BV号为1Up4y1v7Wn的视频属性抓取结束
# 开始BV号为1WC4y187Q5视频属性的抓取
# BV号为1WC4y187Q5的视频属性抓取结束
# 开始BV号为1kh41197gg视频属性的抓取
# BV号为1kh41197gg的视频属性抓取结束
# 开始BV号为1BT4y157bD视频属性的抓取
# BV号为1BT4y157bD的视频属性抓取结束
# 开始BV号为16h411d7Vh视频属性的抓取
# BV号为16h411d7Vh的视频属性抓取结束
# 开始BV号为1G54y1i7g3视频属性的抓取
# BV号为1G54y1i7g3的视频属性抓取结束
# 开始BV号为1aT4y1w7yD视频属性的抓取
# BV号为1aT4y1w7yD的视频属性抓取结束
# 开始BV号为1nT4y1L7eV视频属性的抓取
# BV号为1nT4y1L7eV的视频属性抓取结束
# 开始BV号为1aC4y1t76Q视频属性的抓取
# BV号为1aC4y1t76Q的视频属性抓取结束
# 开始BV号为11K4y1Y7UA视频属性的抓取
# BV号为11K4y1Y7UA的视频属性抓取结束
# 开始BV号为1xv41117NT视频属性的抓取
# BV号为1xv41117NT的视频属性抓取结束
# 开始BV号为1b54y1e7T1视频属性的抓取
# BV号为1b54y1e7T1的视频属性抓取结束
# 开始BV号为1b54y1i7vB视频属性的抓取
# BV号为1b54y1i7vB的视频属性抓取结束
# 开始BV号为17A411Y7nD视频属性的抓取
# BV号为17A411Y7nD的视频属性抓取结束
# 开始BV号为1ka4y177za视频属性的抓取
# BV号为1ka4y177za的视频属性抓取结束
# 开始BV号为1wv411i7aw视频属性的抓取
# BV号为1wv411i7aw的视频属性抓取结束
# 开始BV号为1Lk4y1y7VC视频属性的抓取
# BV号为1Lk4y1y7VC的视频属性抓取结束
# 开始BV号为19h411d7wu视频属性的抓取
# BV号为19h411d7wu的视频属性抓取结束
# 开始BV号为19T4y157MM视频属性的抓取
# BV号为19T4y157MM的视频属性抓取结束
# 开始BV号为1v54y1e7FT视频属性的抓取
# BV号为1v54y1e7FT的视频属性抓取结束
# 开始BV号为1YV411z7XL视频属性的抓取
# BV号为1YV411z7XL的视频属性抓取结束
# 开始BV号为1754y127oE视频属性的抓取
# BV号为1754y127oE的视频属性抓取结束
# 开始BV号为1FZ4y1T7eV视频属性的抓取
# BV号为1FZ4y1T7eV的视频属性抓取结束
# 开始BV号为1ff4y1X7ci视频属性的抓取
# BV号为1ff4y1X7ci的视频属性抓取结束
# 开始BV号为1rk4y127TL视频属性的抓取
# BV号为1rk4y127TL的视频属性抓取结束
# 开始BV号为1ep4y1v7Z9视频属性的抓取
# BV号为1ep4y1v7Z9的视频属性抓取结束
# 开始BV号为1mK4y1e78f视频属性的抓取
# BV号为1mK4y1e78f的视频属性抓取结束
# 开始BV号为1c54y1U76J视频属性的抓取
# BV号为1c54y1U76J的视频属性抓取结束
# 开始BV号为1g54y1v71g视频属性的抓取
# BV号为1g54y1v71g的视频属性抓取结束
# 开始BV号为12D4y127pc视频属性的抓取
# BV号为12D4y127pc的视频属性抓取结束
# 开始BV号为1CZ4y1M7kz视频属性的抓取
# BV号为1CZ4y1M7kz的视频属性抓取结束
# 开始BV号为1H64y1c7gg视频属性的抓取
# BV号为1H64y1c7gg的视频属性抓取结束
# 开始BV号为1fA411J7uM视频属性的抓取
# BV号为1fA411J7uM的视频属性抓取结束
# 开始BV号为1nk4y1m74Y视频属性的抓取
# BV号为1nk4y1m74Y的视频属性抓取结束
# 开始BV号为1pi4y1g7ez视频属性的抓取
# BV号为1pi4y1g7ez的视频属性抓取结束
# 开始BV号为1Qi4y1g7eX视频属性的抓取
# BV号为1Qi4y1g7eX的视频属性抓取结束
# 开始BV号为1Ua4y1J7mS视频属性的抓取
# BV号为1Ua4y1J7mS的视频属性抓取结束
# 开始BV号为1GK411T7Fo视频属性的抓取
# BV号为1GK411T7Fo的视频属性抓取结束
# 开始BV号为1D54y1e7Xf视频属性的抓取
# BV号为1D54y1e7Xf的视频属性抓取结束
# 开始BV号为1sD4y1U7tM视频属性的抓取
# BV号为1sD4y1U7tM的视频属性抓取结束
# 开始BV号为19A411Y76n视频属性的抓取
# BV号为19A411Y76n的视频属性抓取结束
# 开始BV号为1zK4y1v78Y视频属性的抓取
# 开始BV号为1zK4y1v78Y视频属性的抓取
# BV号为1zK4y1v78Y的视频属性抓取结束
# 开始BV号为1mC4y1t7jd视频属性的抓取
# BV号为1mC4y1t7jd的视频属性抓取结束
# 开始BV号为1Xv411y7cX视频属性的抓取
# BV号为1Xv411y7cX的视频属性抓取结束
# 开始BV号为1uh411Z76v视频属性的抓取
# BV号为1uh411Z76v的视频属性抓取结束
# 开始BV号为1eV411z7T6视频属性的抓取
# BV号为1eV411z7T6的视频属性抓取结束
# 开始BV号为1E5411h7Mp视频属性的抓取
# BV号为1E5411h7Mp的视频属性抓取结束
# 开始BV号为15A411n7PK视频属性的抓取
# BV号为15A411n7PK的视频属性抓取结束
# 开始BV号为1hv411v7bL视频属性的抓取
# BV号为1hv411v7bL的视频属性抓取结束
# 开始BV号为1Qv411y7zV视频属性的抓取
# BV号为1Qv411y7zV的视频属性抓取结束
# 开始BV号为1EZ4y1K75a视频属性的抓取
# BV号为1EZ4y1K75a的视频属性抓取结束
# 开始BV号为1764y1c7Xi视频属性的抓取
# BV号为1764y1c7Xi的视频属性抓取结束
# 开始BV号为1Nh411d7DZ视频属性的抓取
# BV号为1Nh411d7DZ的视频属性抓取结束
# 开始BV号为1bV411U7Rx视频属性的抓取
# BV号为1bV411U7Rx的视频属性抓取结束
# 开始BV号为17Z4y1T7cA视频属性的抓取
# BV号为17Z4y1T7cA的视频属性抓取结束
# 开始BV号为1GT4y1L7bC视频属性的抓取
# BV号为1GT4y1L7bC的视频属性抓取结束
# 开始BV号为13A411n7cu视频属性的抓取
# BV号为13A411n7cu的视频属性抓取结束
# 开始BV号为12V411U7BF视频属性的抓取
# BV号为12V411U7BF的视频属性抓取结束
# 开始BV号为1Kp4y1i78n视频属性的抓取
# BV号为1Kp4y1i78n的视频属性抓取结束
# 开始BV号为18f4y1Q7L4视频属性的抓取
# BV号为18f4y1Q7L4的视频属性抓取结束
# 开始BV号为1aT4y1A7Jn视频属性的抓取
# BV号为1aT4y1A7Jn的视频属性抓取结束
# 开始BV号为1FA411H7gr视频属性的抓取
# BV号为1FA411H7gr的视频属性抓取结束
# 开始BV号为1zZ4y1N76b视频属性的抓取
# BV号为1zZ4y1N76b的视频属性抓取结束
# 开始BV号为1av41117Js视频属性的抓取
# BV号为1av41117Js的视频属性抓取结束
# 开始BV号为1NV411m7FG视频属性的抓取
# BV号为1NV411m7FG的视频属性抓取结束
# 开始BV号为1zK411P7aT视频属性的抓取
# BV号为1zK411P7aT的视频属性抓取结束
# 开始BV号为1Ek4y117PY视频属性的抓取
# BV号为1Ek4y117PY的视频属性抓取结束
# 开始BV号为1pv411y7T4视频属性的抓取
# BV号为1pv411y7T4的视频属性抓取结束
# 开始BV号为18a4y1j72L视频属性的抓取
# BV号为18a4y1j72L的视频属性抓取结束
# 开始BV号为12K411P763视频属性的抓取
# BV号为12K411P763的视频属性抓取结束
# 开始BV号为1Wa4y1E7AB视频属性的抓取
# BV号为1Wa4y1E7AB的视频属性抓取结束
# 开始BV号为1Tk4y117pe视频属性的抓取
# BV号为1Tk4y117pe的视频属性抓取结束
# 开始BV号为1yv41117nU视频属性的抓取
# BV号为1yv41117nU的视频属性抓取结束
# 开始BV号为1U5411b7Qk视频属性的抓取
# BV号为1U5411b7Qk的视频属性抓取结束
# 开始BV号为1MK411K7cc视频属性的抓取
# BV号为1MK411K7cc的视频属性抓取结束
# 开始BV号为1ok4y1k79E视频属性的抓取
# BV号为1ok4y1k79E的视频属性抓取结束
# 开始BV号为1pT4y1A7yR视频属性的抓取
# BV号为1pT4y1A7yR的视频属性抓取结束
# 开始BV号为1n54y1v76e视频属性的抓取
# BV号为1n54y1v76e的视频属性抓取结束
# 开始BV号为19k4y1k7dX视频属性的抓取
# BV号为19k4y1k7dX的视频属性抓取结束
# 开始BV号为1vK4y1a7SK视频属性的抓取
# BV号为1vK4y1a7SK的视频属性抓取结束
# 开始BV号为1Ht4y1q7kH视频属性的抓取
# BV号为1Ht4y1q7kH的视频属性抓取结束
# 开始BV号为14f4y1D79h视频属性的抓取
# BV号为14f4y1D79h的视频属性抓取结束
# 开始BV号为1pK411K7Jj视频属性的抓取
# BV号为1pK411K7Jj的视频属性抓取结束
# 开始BV号为1Gt4y1q7PX视频属性的抓取
# BV号为1Gt4y1q7PX的视频属性抓取结束
# 开始BV号为1VK4y1a7pR视频属性的抓取
# BV号为1VK4y1a7pR的视频属性抓取结束
# 开始BV号为1wv411y7NW视频属性的抓取
# BV号为1wv411y7NW的视频属性抓取结束
# 开始BV号为18K4y1a7sv视频属性的抓取
# BV号为18K4y1a7sv的视频属性抓取结束
# 开始BV号为1hf4y1D7L8视频属性的抓取
# BV号为1hf4y1D7L8的视频属性抓取结束
# 开始BV号为1bD4y1m7Uh视频属性的抓取
# BV号为1bD4y1m7Uh的视频属性抓取结束
# 开始BV号为1XV41117KF视频属性的抓取
# BV号为1XV41117KF的视频属性抓取结束
# 开始BV号为1jV411m7AQ视频属性的抓取
# BV号为1jV411m7AQ的视频属性抓取结束
# 开始BV号为1g54y1m76L视频属性的抓取
# BV号为1g54y1m76L的视频属性抓取结束
# 开始BV号为1Ry4y1y7q2视频属性的抓取
# BV号为1Ry4y1y7q2的视频属性抓取结束
# 开始BV号为1Dp4y1e7Fj视频属性的抓取
# BV号为1Dp4y1e7Fj的视频属性抓取结束
# 开始BV号为1Yz4y1Z71N视频属性的抓取
# BV号为1Yz4y1Z71N的视频属性抓取结束
# 开始BV号为11y4y1C7LP视频属性的抓取
# BV号为11y4y1C7LP的视频属性抓取结束
# 开始BV号为1QD4y1R7sw视频属性的抓取
# BV号为1QD4y1R7sw的视频属性抓取结束
# 开始BV号为1ap4y1e7wA视频属性的抓取
# BV号为1ap4y1e7wA的视频属性抓取结束
# 开始BV号为1wZ4y1N7Mi视频属性的抓取
# BV号为1wZ4y1N7Mi的视频属性抓取结束
# 开始BV号为1aA411J7Tv视频属性的抓取
# BV号为1aA411J7Tv的视频属性抓取结束
# 开始BV号为1vz4y1d7Ng视频属性的抓取
# BV号为1vz4y1d7Ng的视频属性抓取结束
# 开始BV号为1bA411J7SB视频属性的抓取
# BV号为1bA411J7SB的视频属性抓取结束
# 开始BV号为1j54y117Dc视频属性的抓取
# BV号为1j54y117Dc的视频属性抓取结束
# 开始BV号为11K411K7CM视频属性的抓取
# BV号为11K411K7CM的视频属性抓取结束
# 开始BV号为1y54y127wr视频属性的抓取
# BV号为1y54y127wr的视频属性抓取结束
# 开始BV号为1pt4y1v7tm视频属性的抓取
# BV号为1pt4y1v7tm的视频属性抓取结束
# 开始BV号为1Kv411k7vp视频属性的抓取
# BV号为1Kv411k7vp的视频属性抓取结束
# 开始BV号为135411j79Q视频属性的抓取
# BV号为135411j79Q的视频属性抓取结束
# 开始BV号为1Et4y1S7GB视频属性的抓取
# BV号为1Et4y1S7GB的视频属性抓取结束
# 开始BV号为1Vy4y1y7Kx视频属性的抓取
# BV号为1Vy4y1y7Kx的视频属性抓取结束
# 开始BV号为1CV411m71Z视频属性的抓取
# BV号为1CV411m71Z的视频属性抓取结束
# 开始BV号为1ua4y177LF视频属性的抓取
# BV号为1ua4y177LF的视频属性抓取结束
# 开始BV号为1s64y1F7vC视频属性的抓取
# BV号为1s64y1F7vC的视频属性抓取结束
# 开始BV号为1Qk4y1y7eL视频属性的抓取
# BV号为1Qk4y1y7eL的视频属性抓取结束
# 开始BV号为1q5411b7uz视频属性的抓取
# BV号为1q5411b7uz的视频属性抓取结束
# 开始BV号为1x64y1F7bB视频属性的抓取
# BV号为1x64y1F7bB的视频属性抓取结束
# 开始BV号为19z4y1o7dv视频属性的抓取
# BV号为19z4y1o7dv的视频属性抓取结束
# 开始BV号为11y4y1y7NM视频属性的抓取
# BV号为11y4y1y7NM的视频属性抓取结束
# 开始BV号为1b5411j7Ug视频属性的抓取
# BV号为1b5411j7Ug的视频属性抓取结束
# 开始BV号为1c54y1m752视频属性的抓取
# BV号为1c54y1m752的视频属性抓取结束
# 开始BV号为1qz4y1Z7pY视频属性的抓取
# 开始BV号为1qz4y1Z7pY视频属性的抓取
# BV号为1qz4y1Z7pY的视频属性抓取结束
# 开始BV号为1H54y117vw视频属性的抓取
# BV号为1H54y117vw的视频属性抓取结束
# 开始BV号为1zV411m7q7视频属性的抓取
# BV号为1zV411m7q7的视频属性抓取结束
# 开始BV号为1Zp4y1e7aA视频属性的抓取
# BV号为1Zp4y1e7aA的视频属性抓取结束
# 开始BV号为15K4y1Y7XY视频属性的抓取
# BV号为15K4y1Y7XY的视频属性抓取结束
# 开始BV号为1A5411j7JC视频属性的抓取
# BV号为1A5411j7JC的视频属性抓取结束
# 开始BV号为1Dp4y1e7WA视频属性的抓取
# BV号为1Dp4y1e7WA的视频属性抓取结束
# 开始BV号为19f4y1S7fg视频属性的抓取
# BV号为19f4y1S7fg的视频属性抓取结束
# 开始BV号为1oh411975N视频属性的抓取
# BV号为1oh411975N的视频属性抓取结束
# 开始BV号为1KZ4y1K7Za视频属性的抓取
# BV号为1KZ4y1K7Za的视频属性抓取结束
# 开始BV号为1s54y1y7mx视频属性的抓取
# BV号为1s54y1y7mx的视频属性抓取结束
# 开始BV号为1Kt4y1q79U视频属性的抓取
# BV号为1Kt4y1q79U的视频属性抓取结束
# 开始BV号为115411b7ks视频属性的抓取
# BV号为115411b7ks的视频属性抓取结束
# 开始BV号为1tK4y1a7oK视频属性的抓取
# BV号为1tK4y1a7oK的视频属性抓取结束
# 开始BV号为1Z5411L7wU视频属性的抓取
# BV号为1Z5411L7wU的视频属性抓取结束
# 开始BV号为1m54y1272B视频属性的抓取
# BV号为1m54y1272B的视频属性抓取结束
# 开始BV号为1fa4y1j7k2视频属性的抓取
# BV号为1fa4y1j7k2的视频属性抓取结束
# 开始BV号为1HD4y1o7X8视频属性的抓取
# BV号为1HD4y1o7X8的视频属性抓取结束
# 开始BV号为13K411K77h视频属性的抓取
# BV号为13K411K77h的视频属性抓取结束
# 开始BV号为13V411S7Nt视频属性的抓取
# BV号为13V411S7Nt的视频属性抓取结束
# 开始BV号为11A411E71k视频属性的抓取
# BV号为11A411E71k的视频属性抓取结束
# 开始BV号为1XD4y1o7dt视频属性的抓取
# BV号为1XD4y1o7dt的视频属性抓取结束
# 开始BV号为1aK411K73X视频属性的抓取
# BV号为1aK411K73X的视频属性抓取结束
# 开始BV号为1eT4y1A7P3视频属性的抓取
# BV号为1eT4y1A7P3的视频属性抓取结束
# 开始BV号为1bv411C7bq视频属性的抓取
# BV号为1bv411C7bq的视频属性抓取结束
# 开始BV号为1qf4y1Q7aA视频属性的抓取
# BV号为1qf4y1Q7aA的视频属性抓取结束
# 开始BV号为1tA411n7td视频属性的抓取
# BV号为1tA411n7td的视频属性抓取结束
# 开始BV号为1Uz4y1f7y3视频属性的抓取
# BV号为1Uz4y1f7y3的视频属性抓取结束
# 开始BV号为1m5411b7hk视频属性的抓取
# BV号为1m5411b7hk的视频属性抓取结束
# 开始BV号为1hy4y1k7Lv视频属性的抓取
# BV号为1hy4y1k7Lv的视频属性抓取结束
# 开始BV号为1qk4y127JL视频属性的抓取
# BV号为1qk4y127JL的视频属性抓取结束
# 开始BV号为1yK411K7Eo视频属性的抓取
# BV号为1yK411K7Eo的视频属性抓取结束
# 开始BV号为1Zy4y1C78E视频属性的抓取
# BV号为1Zy4y1C78E的视频属性抓取结束
# 开始BV号为1vK411K7LC视频属性的抓取
# BV号为1vK411K7LC的视频属性抓取结束
# 开始BV号为1pp4y1e75z视频属性的抓取
# BV号为1pp4y1e75z的视频属性抓取结束
# 开始BV号为18D4y1o7TG视频属性的抓取
# BV号为18D4y1o7TG的视频属性抓取结束
# 开始BV号为1Pp4y1e7FH视频属性的抓取
# BV号为1Pp4y1e7FH的视频属性抓取结束
# 开始BV号为1wz4y1Z7wt视频属性的抓取
# BV号为1wz4y1Z7wt的视频属性抓取结束
# 开始BV号为17D4y1o7WY视频属性的抓取
# BV号为17D4y1o7WY的视频属性抓取结束
# 开始BV号为1Uv41117rY视频属性的抓取
# BV号为1Uv41117rY的视频属性抓取结束
# 开始BV号为1HT4y1w7HX视频属性的抓取
# BV号为1HT4y1w7HX的视频属性抓取结束
# 开始BV号为1YK4y1778P视频属性的抓取
# BV号为1YK4y1778P的视频属性抓取结束
# 开始BV号为1zp4y1k7p7视频属性的抓取
# BV号为1zp4y1k7p7的视频属性抓取结束
# 开始BV号为1Yy4y1r7RA视频属性的抓取
# BV号为1Yy4y1r7RA的视频属性抓取结束
# 开始BV号为1st4y1i7Yh视频属性的抓取
# BV号为1st4y1i7Yh的视频属性抓取结束
# 开始BV号为1vK411A7p8视频属性的抓取
# BV号为1vK411A7p8的视频属性抓取结束
# 开始BV号为1ft4y1v7b7视频属性的抓取
# BV号为1ft4y1v7b7的视频属性抓取结束
# 开始BV号为1gt4y1e7E7视频属性的抓取
# BV号为1gt4y1e7E7的视频属性抓取结束
# 开始BV号为1AV411278z视频属性的抓取
# BV号为1AV411278z的视频属性抓取结束
# 开始BV号为1k54y1171f视频属性的抓取
# BV号为1k54y1171f的视频属性抓取结束
# 开始BV号为1Ap4y1Y721视频属性的抓取
# BV号为1Ap4y1Y721的视频属性抓取结束
# 开始BV号为1oz4y1d7qQ视频属性的抓取
# BV号为1oz4y1d7qQ的视频属性抓取结束
# 开始BV号为1Ty4y1C7p3视频属性的抓取
# BV号为1Ty4y1C7p3的视频属性抓取结束
# 开始BV号为1p54y1C7nq视频属性的抓取
# BV号为1p54y1C7nq的视频属性抓取结束
# 开始BV号为1t54y117Mn视频属性的抓取
# BV号为1t54y117Mn的视频属性抓取结束
# 开始BV号为1Mf4y1z7sN视频属性的抓取
# BV号为1Mf4y1z7sN的视频属性抓取结束
# 开始BV号为1Ha4y1L7wU视频属性的抓取
# BV号为1Ha4y1L7wU的视频属性抓取结束
# 开始BV号为1TA411E7yz视频属性的抓取
# BV号为1TA411E7yz的视频属性抓取结束
# 开始BV号为1Ey4y1r7on视频属性的抓取
# BV号为1Ey4y1r7on的视频属性抓取结束
# 开始BV号为1ya411A74n视频属性的抓取
# BV号为1ya411A74n的视频属性抓取结束
# 开始BV号为1fZ4y1G7KT视频属性的抓取
# BV号为1fZ4y1G7KT的视频属性抓取结束
# 开始BV号为1Dk4y1C7G6视频属性的抓取
# BV号为1Dk4y1C7G6的视频属性抓取结束
# 开始BV号为1fK4y177HH视频属性的抓取
# BV号为1fK4y177HH的视频属性抓取结束
# 开始BV号为1pp4y1Y74k视频属性的抓取
# BV号为1pp4y1Y74k的视频属性抓取结束
# 开始BV号为1ki4y1j7VT视频属性的抓取
# BV号为1ki4y1j7VT的视频属性抓取结束
# 开始BV号为1rp4y1k7rt视频属性的抓取
# BV号为1rp4y1k7rt的视频属性抓取结束
# 开始BV号为1cz4y1o78K视频属性的抓取
# BV号为1cz4y1o78K的视频属性抓取结束
# 开始BV号为1vV41117WQ视频属性的抓取
# BV号为1vV41117WQ的视频属性抓取结束
# 开始BV号为1Fy4y1r7aG视频属性的抓取
# BV号为1Fy4y1r7aG的视频属性抓取结束
# 开始BV号为18K411A7yQ视频属性的抓取
# BV号为18K411A7yQ的视频属性抓取结束
# 开始BV号为1sy4y1C76E视频属性的抓取
# BV号为1sy4y1C76E的视频属性抓取结束
# 开始BV号为1gT4y1F7Ev视频属性的抓取
# BV号为1gT4y1F7Ev的视频属性抓取结束
# 开始BV号为1Pa4y1s7Ab视频属性的抓取
# BV号为1Pa4y1s7Ab的视频属性抓取结束
# 开始BV号为1R54y167Qb视频属性的抓取
# BV号为1R54y167Qb的视频属性抓取结束
# 开始BV号为1uk4y1C7ws视频属性的抓取
# BV号为1uk4y1C7ws的视频属性抓取结束
# 开始BV号为15t4y1i7Ni视频属性的抓取
# BV号为15t4y1i7Ni的视频属性抓取结束
# 开始BV号为18T4y1F7sF视频属性的抓取
# BV号为18T4y1F7sF的视频属性抓取结束
# 开始BV号为1qV411y7YV视频属性的抓取
# BV号为1qV411y7YV的视频属性抓取结束
# 开始BV号为1Wr4y1w7Dv视频属性的抓取
# BV号为1Wr4y1w7Dv的视频属性抓取结束
# 开始BV号为19f4y1q7Gs视频属性的抓取
# BV号为19f4y1q7Gs的视频属性抓取结束
# 开始BV号为1w54y1C7we视频属性的抓取
# BV号为1w54y1C7we的视频属性抓取结束
# 开始BV号为16i4y1E76g视频属性的抓取
# BV号为16i4y1E76g的视频属性抓取结束
# 开始BV号为1Rt4y1Y76E视频属性的抓取
# BV号为1Rt4y1Y76E的视频属性抓取结束
# 开始BV号为1YD4y1R76Y视频属性的抓取
# BV号为1YD4y1R76Y的视频属性抓取结束
# 开始BV号为1mK4y1f7Fx视频属性的抓取
# BV号为1mK4y1f7Fx的视频属性抓取结束
# 开始BV号为1qy4y1r7px视频属性的抓取
# BV号为1qy4y1r7px的视频属性抓取结束
# 开始BV号为11K4y187vT视频属性的抓取
# BV号为11K4y187vT的视频属性抓取结束
# 开始BV号为1y541157tL视频属性的抓取
# BV号为1y541157tL的视频属性抓取结束
# 开始BV号为1ay4y1r7MM视频属性的抓取
# BV号为1ay4y1r7MM的视频属性抓取结束
# 开始BV号为1V5411776s视频属性的抓取
# BV号为1V5411776s的视频属性抓取结束
# 开始BV号为1KD4y1d7DJ视频属性的抓取
# BV号为1KD4y1d7DJ的视频属性抓取结束
# 开始BV号为15y4y1C7n8视频属性的抓取
# BV号为15y4y1C7n8的视频属性抓取结束
# 开始BV号为1xz4y1o7Su视频属性的抓取
# BV号为1xz4y1o7Su的视频属性抓取结束
# 开始BV号为1Ca411A7FN视频属性的抓取
# BV号为1Ca411A7FN的视频属性抓取结束
# 开始BV号为1NA411E7d9视频属性的抓取
# BV号为1NA411E7d9的视频属性抓取结束
# 开始BV号为1kK4y1h7H5视频属性的抓取
# BV号为1kK4y1h7H5的视频属性抓取结束
# 开始BV号为12K4y177YC视频属性的抓取
# BV号为12K4y177YC的视频属性抓取结束
# 开始BV号为1Hy4y1B7Aq视频属性的抓取
# BV号为1Hy4y1B7Aq的视频属性抓取结束
# 开始BV号为1Na4y1s7LF视频属性的抓取
# BV号为1Na4y1s7LF的视频属性抓取结束
# 开始BV号为19r4y1c77r视频属性的抓取
# BV号为19r4y1c77r的视频属性抓取结束
# 开始BV号为1cr4y1w7Wf视频属性的抓取
# BV号为1cr4y1w7Wf的视频属性抓取结束
# 开始BV号为1dy4y1r7VM视频属性的抓取
# BV号为1dy4y1r7VM的视频属性抓取结束
# 开始BV号为1wv411C7cu视频属性的抓取
# BV号为1wv411C7cu的视频属性抓取结束
# 开始BV号为1TK411A7bc视频属性的抓取
# BV号为1TK411A7bc的视频属性抓取结束
# 开始BV号为1Vz4y1o7Hu视频属性的抓取
# BV号为1Vz4y1o7Hu的视频属性抓取结束
# 开始BV号为1xt4y1i7Uh视频属性的抓取
# BV号为1xt4y1i7Uh的视频属性抓取结束
# 开始BV号为15Z4y157g9视频属性的抓取
# BV号为15Z4y157g9的视频属性抓取结束
# 开始BV号为15i4y1L711视频属性的抓取
# BV号为15i4y1L711的视频属性抓取结束
# 开始BV号为1h54y1R7Ek视频属性的抓取
# BV号为1h54y1R7Ek的视频属性抓取结束
# 开始BV号为1WZ4y1L7H5视频属性的抓取
# BV号为1WZ4y1L7H5的视频属性抓取结束
# 开始BV号为1RA411L7s2视频属性的抓取
# BV号为1RA411L7s2的视频属性抓取结束
# 开始BV号为1wp4y1Y7d6视频属性的抓取
# BV号为1wp4y1Y7d6的视频属性抓取结束
# 开始BV号为1ma411A7SH视频属性的抓取
# BV号为1ma411A7SH的视频属性抓取结束
# 开始BV号为16a4y1L7bD视频属性的抓取
# BV号为16a4y1L7bD的视频属性抓取结束
# 开始BV号为1q541157Gj视频属性的抓取
# BV号为1q541157Gj的视频属性抓取结束
# 开始BV号为11v41167pd视频属性的抓取
# BV号为11v41167pd的视频属性抓取结束
# 开始BV号为1Ct4y1v7sy视频属性的抓取
# BV号为1Ct4y1v7sy的视频属性抓取结束
# 开始BV号为1154y117Kf视频属性的抓取
# BV号为1154y117Kf的视频属性抓取结束
# 开始BV号为1Ki4y177mH视频属性的抓取
# BV号为1Ki4y177mH的视频属性抓取结束
# 开始BV号为1H54y1C7gH视频属性的抓取
# BV号为1H54y1C7gH的视频属性抓取结束
# 开始BV号为1sD4y1d7jW视频属性的抓取
# BV号为1sD4y1d7jW的视频属性抓取结束
# 开始BV号为1FA411j7BR视频属性的抓取
# BV号为1FA411j7BR的视频属性抓取结束
# 开始BV号为1154y1k74P视频属性的抓取
# BV号为1154y1k74P的视频属性抓取结束
# 开始BV号为19K4y1h7GK视频属性的抓取
# BV号为19K4y1h7GK的视频属性抓取结束
# 开始BV号为1Df4y1B7HB视频属性的抓取
# BV号为1Df4y1B7HB的视频属性抓取结束
# 开始BV号为1Tp4y1k7YN视频属性的抓取
# BV号为1Tp4y1k7YN的视频属性抓取结束
# 开始BV号为1V54y1C7it视频属性的抓取
# BV号为1V54y1C7it的视频属性抓取结束
# 开始BV号为1J54y1r7pX视频属性的抓取
# BV号为1J54y1r7pX的视频属性抓取结束
# 开始BV号为1Jp4y1k7n6视频属性的抓取
# BV号为1Jp4y1k7n6的视频属性抓取结束
# 开始BV号为1xT4y1F7GA视频属性的抓取
# BV号为1xT4y1F7GA的视频属性抓取结束
# 开始BV号为14y4y1B7Co视频属性的抓取
# BV号为14y4y1B7Co的视频属性抓取结束
# 开始BV号为1qK4y177iZ视频属性的抓取
# BV号为1qK4y177iZ的视频属性抓取结束
# 开始BV号为1ff4y1B7db视频属性的抓取
# BV号为1ff4y1B7db的视频属性抓取结束
# 开始BV号为1Ek4y1C7oS视频属性的抓取
# BV号为1Ek4y1C7oS的视频属性抓取结束
# 开始BV号为1YK4y177R1视频属性的抓取
# BV号为1YK4y177R1的视频属性抓取结束
# 开始BV号为18f4y1i7Ns视频属性的抓取
# BV号为18f4y1i7Ns的视频属性抓取结束
# 开始BV号为16K4y177BD视频属性的抓取
# BV号为16K4y177BD的视频属性抓取结束
# 开始BV号为1ry4y1r7M2视频属性的抓取
# BV号为1ry4y1r7M2的视频属性抓取结束
# 开始BV号为1rp4y1k7B5视频属性的抓取
# BV号为1rp4y1k7B5的视频属性抓取结束
# 开始BV号为1qa411c7ec视频属性的抓取
# BV号为1qa411c7ec的视频属性抓取结束
# 2020-12-18 10:38:37.354561

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-14-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_meishi_tianyuan.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 3月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月   100  100  100  100  100  100   100
# 1KJ411e7nN                              如何提高审美？审美有无高低？审美是谁建立？  数码  摄影摄像  普通视频
# ...                                                       ...  ..   ...   ...
# 1cr4y1w7ig              困难重重，国家天文签约摄影师遭遇拍摄滑铁卢？！【华为Mate40 Pro】  数码  摄影摄像  活动作品
# 1Y5411L7TW                     富士X-S10相机测试——2020 apsc画幅性价比最强机  数码  摄影摄像  活动作品
# 1c541177hR      索尼（Sony）12-24mm F2.8 GM深度评测，只要买得起，它就是一颗完美的镜头！  数码  摄影摄像  普通视频
# 1DA41177UY                            大疆旗舰稳定器 - DJI RS 2 正式登场  数码  摄影摄像  普通视频
# 1rA411776p                 让我非常失望的佳能M50 Mark II（来自一代老用户的真实心声）  数码  摄影摄像  普通视频
#
#             ...                                                 标签   视频长度  \
# 1gJ411n7hp  ...                         [摄影, 数码, 摄影摄像, 数码, 教程, 器材]  01:44
# 1tJ41187w6  ...  [相机, 数码, 摄影摄像, 数码, 何同学, 啊吗粽, 宝剑嫂, 自媒体, 大祥哥, 体验...  30:03
# 1i7411i7yA  ...        [摄影, 短片, 数码, 摄影摄像, 数码, 创意, YOUTUBE, 镜头, 老蛙]  04:51
# 1gJ411G7Cs  ...           [摄影, 数码, 摄影摄像, 数码, VLOG, 后期, 教程, ps, 器材]  06:01
# 1KJ411e7nN  ...  [校园vlog, 相机, 脱口秀, 摄影, 公开课, vlog, 科普, 数码, 摄影摄像,...  27:08
# ...         ...                                                ...    ...
# 1cr4y1w7ig  ...  [vlog, 数码, 摄影摄像, 数码, 放心购机攻略, 敦煌, 星空, 手机摄影, 华为,...  11:43
# 1Y5411L7TW  ...  [相机, 摄影, 数码, 摄影摄像, 数码, 数码玩家训练营, 拍照, 测评, xs10, ...  10:20
# 1c541177hR  ...  [摄影, 数码, 摄影摄像, 数码, 评测, 超广角大光圈, 摄像, 镜头, 数码评测, 超...  21:23
# 1DA41177UY  ...   [相机, 摄影, 数码, 摄影摄像, 数码, 科技, 测评, 器材, 大疆, DJI, 稳定器]  02:26
# 1rA411776p  ...  [vlog, 数码, 摄影摄像, 数码, 佳能, 测评, 体验, m50 mark ii, ...  06:30
#
#                播放量    点赞数   投币数   收藏数   转发数   评论数   弹幕数 有无分集
# 1gJ411n7hp  222.4万   9.7万  2.0万  1.4万  4980  3182  1571    否
# 1tJ41187w6  134.0万  10.7万  8.4万  5.8万  8907  3935  3.0万    否
# 1i7411i7yA   57.8万   4.4万  1.0万  1.6万  2043   641   983    否
# 1gJ411G7Cs   42.3万   3.3万  3.4万  8.6万  2605  1405   612    否
# 1KJ411e7nN   39.6万   4.8万  5.4万  3.4万  6217  1156  1.0万    否
# ...            ...    ...   ...   ...   ...   ...   ...  ...
# 1cr4y1w7ig    4.3万   3051  1391   692   255   337   349    否
# 1Y5411L7TW    4.3万    773   219   221   111   273   104    否
# 1c541177hR    4.1万   1469   443   297   123   250   561    否
# 1DA41177UY    4.1万   1565   197   334   640   171   110    否
# 1rA411776p    4.1万   1262   267   147   101   385   314    否
#
# [999 rows x 21 columns]
