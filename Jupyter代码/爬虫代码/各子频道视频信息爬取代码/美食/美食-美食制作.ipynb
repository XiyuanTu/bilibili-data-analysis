# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_meishi_zhizuo=pd.DataFrame(columns=columns)
channel_meishi_zhizuo
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[18]/div/a/span').click()  #选择频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[18]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '美食'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[2]/a').click()  #选择子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[2]/a').text
sub_channel
# Out:
# '美食制作'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(1,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_meishi_zhizuo.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-17 21:47:25.011713
# <ipython-input-10-86c6193e44fc>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-10-86c6193e44fc>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-10-86c6193e44fc>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1C7411e7Qa视频属性的抓取
# BV号为1C7411e7Qa的视频属性抓取结束
# <ipython-input-10-86c6193e44fc>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1sJ411H7y7视频属性的抓取
# BV号为1sJ411H7y7的视频属性抓取结束
# 开始BV号为1YJ411V7jd视频属性的抓取
# BV号为1YJ411V7jd的视频属性抓取结束
# 开始BV号为1k7411B7Pn视频属性的抓取
# BV号为1k7411B7Pn的视频属性抓取结束
# 开始BV号为1vJ411p7ZC视频属性的抓取
# BV号为1vJ411p7ZC的视频属性抓取结束
# 开始BV号为12J411H76g视频属性的抓取
# BV号为12J411H76g的视频属性抓取结束
# 开始BV号为1rJ41177t1视频属性的抓取
# BV号为1rJ41177t1的视频属性抓取结束
# 开始BV号为1AJ411E7wx视频属性的抓取
# BV号为1AJ411E7wx的视频属性抓取结束
# 开始BV号为1cJ411E7HT视频属性的抓取
# BV号为1cJ411E7HT的视频属性抓取结束
# 开始BV号为1o7411e7Mb视频属性的抓取
# BV号为1o7411e7Mb的视频属性抓取结束
# 开始BV号为1R7411r7ZP视频属性的抓取
# BV号为1R7411r7ZP的视频属性抓取结束
# 开始BV号为1G7411z7Ss视频属性的抓取
# BV号为1G7411z7Ss的视频属性抓取结束
# 开始BV号为1mJ411j7n1视频属性的抓取
# BV号为1mJ411j7n1的视频属性抓取结束
# 开始BV号为1ZJ411V71L视频属性的抓取
# BV号为1ZJ411V71L的视频属性抓取结束
# 开始BV号为1kJ411j7Zd视频属性的抓取
# BV号为1kJ411j7Zd的视频属性抓取结束
# 开始BV号为1j7411q7rH视频属性的抓取
# BV号为1j7411q7rH的视频属性抓取结束
# 开始BV号为1JJ411j7bf视频属性的抓取
# BV号为1JJ411j7bf的视频属性抓取结束
# 开始BV号为1J7411e7sh视频属性的抓取
# BV号为1J7411e7sh的视频属性抓取结束
# 开始BV号为1gJ41177K9视频属性的抓取
# BV号为1gJ41177K9的视频属性抓取结束
# 开始BV号为1z7411k7FP视频属性的抓取
# BV号为1z7411k7FP的视频属性抓取结束
# 开始BV号为1qJ41177GX视频属性的抓取
# BV号为1qJ41177GX的视频属性抓取结束
# 开始BV号为1dJ411H7EK视频属性的抓取
# BV号为1dJ411H7EK的视频属性抓取结束
# 开始BV号为1kJ41157Gy视频属性的抓取
# BV号为1kJ41157Gy的视频属性抓取结束
# 开始BV号为18J411L7qe视频属性的抓取
# BV号为18J411L7qe的视频属性抓取结束
# 开始BV号为1KJ41177Y3视频属性的抓取
# BV号为1KJ41177Y3的视频属性抓取结束
# 开始BV号为1jJ411574q视频属性的抓取
# BV号为1jJ411574q的视频属性抓取结束
# 开始BV号为1KJ411G7vS视频属性的抓取
# BV号为1KJ411G7vS的视频属性抓取结束
# 开始BV号为1BJ411j7EX视频属性的抓取
# BV号为1BJ411j7EX的视频属性抓取结束
# 开始BV号为1sJ411V7C5视频属性的抓取
# BV号为1sJ411V7C5的视频属性抓取结束
# 开始BV号为18J411H7bv视频属性的抓取
# BV号为18J411H7bv的视频属性抓取结束
# 开始BV号为1CJ411p7Cx视频属性的抓取
# BV号为1CJ411p7Cx的视频属性抓取结束
# 开始BV号为1MJ411L7Ea视频属性的抓取
# BV号为1MJ411L7Ea的视频属性抓取结束
# 开始BV号为167411r7gi视频属性的抓取
# BV号为167411r7gi的视频属性抓取结束
# 开始BV号为1X7411a7EQ视频属性的抓取
# BV号为1X7411a7EQ的视频属性抓取结束
# 开始BV号为1vJ411b7E4视频属性的抓取
# BV号为1vJ411b7E4的视频属性抓取结束
# 开始BV号为1JJ41177uB视频属性的抓取
# BV号为1JJ41177uB的视频属性抓取结束
# 开始BV号为1jJ41177wq视频属性的抓取
# BV号为1jJ41177wq的视频属性抓取结束
# 开始BV号为1UJ411b79Z视频属性的抓取
# BV号为1UJ411b79Z的视频属性抓取结束
# 开始BV号为1mJ411b7PD视频属性的抓取
# BV号为1mJ411b7PD的视频属性抓取结束
# 开始BV号为1r7411v7Dm视频属性的抓取
# BV号为1r7411v7Dm的视频属性抓取结束
# 开始BV号为1bJ411V7zg视频属性的抓取
# BV号为1bJ411V7zg的视频属性抓取结束
# 开始BV号为1hJ411V7yk视频属性的抓取
# BV号为1hJ411V7yk的视频属性抓取结束
# 开始BV号为1s7411e7Cj视频属性的抓取
# BV号为1s7411e7Cj的视频属性抓取结束
# 开始BV号为1vJ411E7ey视频属性的抓取
# BV号为1vJ411E7ey的视频属性抓取结束
# 开始BV号为1tJ41157eN视频属性的抓取
# BV号为1tJ41157eN的视频属性抓取结束
# 开始BV号为1DJ411J7a6视频属性的抓取
# BV号为1DJ411J7a6的视频属性抓取结束
# 开始BV号为1oJ411J7zY视频属性的抓取
# BV号为1oJ411J7zY的视频属性抓取结束
# 开始BV号为1kJ411E7YQ视频属性的抓取
# BV号为1kJ411E7YQ的视频属性抓取结束
# 开始BV号为18J411p7DC视频属性的抓取
# BV号为18J411p7DC的视频属性抓取结束
# 开始BV号为1XJ411G7wS视频属性的抓取
# BV号为1XJ411G7wS的视频属性抓取结束
# 开始BV号为1b741167cA视频属性的抓取
# BV号为1b741167cA的视频属性抓取结束
# 开始BV号为1TJ411n74P视频属性的抓取
# BV号为1TJ411n74P的视频属性抓取结束
# 开始BV号为1rJ411G7xT视频属性的抓取
# BV号为1rJ411G7xT的视频属性抓取结束
# 开始BV号为1zJ411h7Sb视频属性的抓取
# BV号为1zJ411h7Sb的视频属性抓取结束
# 开始BV号为1k7411v7JH视频属性的抓取
# BV号为1k7411v7JH的视频属性抓取结束
# 开始BV号为1G7411q7dz视频属性的抓取
# BV号为1G7411q7dz的视频属性抓取结束
# 开始BV号为1rJ411777r视频属性的抓取
# BV号为1rJ411777r的视频属性抓取结束
# 开始BV号为1DJ411V72d视频属性的抓取
# BV号为1DJ411V72d的视频属性抓取结束
# 开始BV号为1zJ41177YT视频属性的抓取
# BV号为1zJ41177YT的视频属性抓取结束
# 开始BV号为1JJ411L7nL视频属性的抓取
# BV号为1JJ411L7nL的视频属性抓取结束
# 开始BV号为1E741167po视频属性的抓取
# BV号为1E741167po的视频属性抓取结束
# 开始BV号为1WJ411V7hE视频属性的抓取
# BV号为1WJ411V7hE的视频属性抓取结束
# 开始BV号为1i7411e7Bn视频属性的抓取
# BV号为1i7411e7Bn的视频属性抓取结束
# 开始BV号为14J41187Tj视频属性的抓取
# BV号为14J41187Tj的视频属性抓取结束
# 开始BV号为1z7411k7kV视频属性的抓取
# BV号为1z7411k7kV的视频属性抓取结束
# 开始BV号为11J411L7mx视频属性的抓取
# BV号为11J411L7mx的视频属性抓取结束
# 开始BV号为1TJ411p7yG视频属性的抓取
# BV号为1TJ411p7yG的视频属性抓取结束
# 开始BV号为12J41177qA视频属性的抓取
# BV号为12J41177qA的视频属性抓取结束
# 开始BV号为1MJ411E72Y视频属性的抓取
# BV号为1MJ411E72Y的视频属性抓取结束
# 开始BV号为157411z7Ci视频属性的抓取
# BV号为157411z7Ci的视频属性抓取结束
# 开始BV号为13J411G7JZ视频属性的抓取
# BV号为13J411G7JZ的视频属性抓取结束
# 开始BV号为1jJ411j7rZ视频属性的抓取
# BV号为1jJ411j7rZ的视频属性抓取结束
# 开始BV号为1t7411k7t7视频属性的抓取
# BV号为1t7411k7t7的视频属性抓取结束
# 开始BV号为1zJ411E7tP视频属性的抓取
# BV号为1zJ411E7tP的视频属性抓取结束
# 开始BV号为11J411J7X2视频属性的抓取
# BV号为11J411J7X2的视频属性抓取结束
# 开始BV号为1X7411v7Jm视频属性的抓取
# BV号为1X7411v7Jm的视频属性抓取结束
# 开始BV号为15J41157GX视频属性的抓取
# BV号为15J41157GX的视频属性抓取结束
# 开始BV号为147411i797视频属性的抓取
# BV号为147411i797的视频属性抓取结束
# 开始BV号为1uJ411p745视频属性的抓取
# BV号为1uJ411p745的视频属性抓取结束
# 开始BV号为1F7411i7QF视频属性的抓取
# BV号为1F7411i7QF的视频属性抓取结束
# 开始BV号为15J411573A视频属性的抓取
# BV号为15J411573A的视频属性抓取结束
# 开始BV号为167411v732视频属性的抓取
# BV号为167411v732的视频属性抓取结束
# 开始BV号为157411Y72q视频属性的抓取
# BV号为157411Y72q的视频属性抓取结束
# 开始BV号为1vJ411L7na视频属性的抓取
# BV号为1vJ411L7na的视频属性抓取结束
# 开始BV号为1S7411Y7qe视频属性的抓取
# BV号为1S7411Y7qe的视频属性抓取结束
# 开始BV号为1x7411z71e视频属性的抓取
# BV号为1x7411z71e的视频属性抓取结束
# 开始BV号为12J411j7xV视频属性的抓取
# BV号为12J411j7xV的视频属性抓取结束
# 开始BV号为1pJ41157f1视频属性的抓取
# BV号为1pJ41157f1的视频属性抓取结束
# 开始BV号为1fJ411H7Fh视频属性的抓取
# BV号为1fJ411H7Fh的视频属性抓取结束
# 开始BV号为1pJ411n7aL视频属性的抓取
# BV号为1pJ411n7aL的视频属性抓取结束
# 开始BV号为1TJ411n7vm视频属性的抓取
# BV号为1TJ411n7vm的视频属性抓取结束
# 开始BV号为1c7411B7v5视频属性的抓取
# BV号为1c7411B7v5的视频属性抓取结束
# 开始BV号为1MJ411G73U视频属性的抓取
# BV号为1MJ411G73U的视频属性抓取结束
# 开始BV号为1R7411q7zz视频属性的抓取
# BV号为1R7411q7zz的视频属性抓取结束
# 开始BV号为1kJ411V7HS视频属性的抓取
# BV号为1kJ411V7HS的视频属性抓取结束
# 开始BV号为1Q7411a7tD视频属性的抓取
# BV号为1Q7411a7tD的视频属性抓取结束
# 开始BV号为1wJ41157xg视频属性的抓取
# BV号为1wJ41157xg的视频属性抓取结束
# 开始BV号为1nJ411E7YL视频属性的抓取
# BV号为1nJ411E7YL的视频属性抓取结束
# 开始BV号为1eJ411n7td视频属性的抓取
# BV号为1eJ411n7td的视频属性抓取结束
# 开始BV号为1T7411v7V8视频属性的抓取
# BV号为1T7411v7V8的视频属性抓取结束
# 开始BV号为1SE411J7qV视频属性的抓取
# BV号为1SE411J7qV的视频属性抓取结束
# 开始BV号为147411H7VT视频属性的抓取
# BV号为147411H7VT的视频属性抓取结束
# 开始BV号为1G7411g7WC视频属性的抓取
# BV号为1G7411g7WC的视频属性抓取结束
# 开始BV号为1B7411L7LU视频属性的抓取
# BV号为1B7411L7LU的视频属性抓取结束
# 开始BV号为1A7411V7oo视频属性的抓取
# BV号为1A7411V7oo的视频属性抓取结束
# 开始BV号为1F7411a7vS视频属性的抓取
# BV号为1F7411a7vS的视频属性抓取结束
# 开始BV号为1P7411g7Jk视频属性的抓取
# BV号为1P7411g7Jk的视频属性抓取结束
# 开始BV号为1W7411c7hG视频属性的抓取
# BV号为1W7411c7hG的视频属性抓取结束
# 开始BV号为1E7411T7RC视频属性的抓取
# BV号为1E7411T7RC的视频属性抓取结束
# 开始BV号为1K7411g74E视频属性的抓取
# BV号为1K7411g74E的视频属性抓取结束
# 开始BV号为1u7411n7MH视频属性的抓取
# BV号为1u7411n7MH的视频属性抓取结束
# 开始BV号为1p741157a1视频属性的抓取
# BV号为1p741157a1的视频属性抓取结束
# 开始BV号为1A7411b7Cy视频属性的抓取
# BV号为1A7411b7Cy的视频属性抓取结束
# 开始BV号为1b7411n72p视频属性的抓取
# BV号为1b7411n72p的视频属性抓取结束
# 开始BV号为1ij411f7kv视频属性的抓取
# BV号为1ij411f7kv的视频属性抓取结束
# 开始BV号为1x7411G7BB视频属性的抓取
# BV号为1x7411G7BB的视频属性抓取结束
# 开始BV号为197411G7Ky视频属性的抓取
# BV号为197411G7Ky的视频属性抓取结束
# 开始BV号为1v7411s7Yd视频属性的抓取
# BV号为1v7411s7Yd的视频属性抓取结束
# 开始BV号为1cE411H7Ex视频属性的抓取
# BV号为1cE411H7Ex的视频属性抓取结束
# 开始BV号为1s7411x7Lu视频属性的抓取
# BV号为1s7411x7Lu的视频属性抓取结束
# 开始BV号为1A7411u7Ji视频属性的抓取
# BV号为1A7411u7Ji的视频属性抓取结束
# 开始BV号为1Hj411f7Yj视频属性的抓取
# BV号为1Hj411f7Yj的视频属性抓取结束
# 开始BV号为1U7411E7LH视频属性的抓取
# BV号为1U7411E7LH的视频属性抓取结束
# 开始BV号为1N7411H7yC视频属性的抓取
# BV号为1N7411H7yC的视频属性抓取结束
# 开始BV号为1k7411V7Ni视频属性的抓取
# BV号为1k7411V7Ni的视频属性抓取结束
# 开始BV号为1Q741187uv视频属性的抓取
# BV号为1Q741187uv的视频属性抓取结束
# 开始BV号为177411A74B视频属性的抓取
# BV号为177411A74B的视频属性抓取结束
# 开始BV号为1GE411H75J视频属性的抓取
# BV号为1GE411H75J的视频属性抓取结束
# 开始BV号为1p7411H7yV视频属性的抓取
# BV号为1p7411H7yV的视频属性抓取结束
# 开始BV号为1H7411776j视频属性的抓取
# BV号为1H7411776j的视频属性抓取结束
# 开始BV号为1Z7411G7AW视频属性的抓取
# BV号为1Z7411G7AW的视频属性抓取结束
# 开始BV号为1V7411x73o视频属性的抓取
# BV号为1V7411x73o的视频属性抓取结束
# 开始BV号为147411w7Dz视频属性的抓取
# BV号为147411w7Dz的视频属性抓取结束
# 开始BV号为1z7411J7x9视频属性的抓取
# BV号为1z7411J7x9的视频属性抓取结束
# 开始BV号为1d7411L7Jt视频属性的抓取
# BV号为1d7411L7Jt的视频属性抓取结束
# 开始BV号为1j7411h7Mt视频属性的抓取
# BV号为1j7411h7Mt的视频属性抓取结束
# 开始BV号为1W741157D9视频属性的抓取
# BV号为1W741157D9的视频属性抓取结束
# 开始BV号为11j411f7cx视频属性的抓取
# BV号为11j411f7cx的视频属性抓取结束
# 开始BV号为1Y7411377f视频属性的抓取
# BV号为1Y7411377f的视频属性抓取结束
# 开始BV号为1sE411n74q视频属性的抓取
# BV号为1sE411n74q的视频属性抓取结束
# 开始BV号为1X7411x7qx视频属性的抓取
# BV号为1X7411x7qx的视频属性抓取结束
# 开始BV号为1ME411J7RG视频属性的抓取
# BV号为1ME411J7RG的视频属性抓取结束
# 开始BV号为1c7411u7g7视频属性的抓取
# BV号为1c7411u7g7的视频属性抓取结束
# 开始BV号为1r7411j7vi视频属性的抓取
# BV号为1r7411j7vi的视频属性抓取结束
# 开始BV号为1D7411E75Q视频属性的抓取
# BV号为1D7411E75Q的视频属性抓取结束
# 开始BV号为1q7411T7BP视频属性的抓取
# BV号为1q7411T7BP的视频属性抓取结束
# 开始BV号为1E7411w7fX视频属性的抓取
# BV号为1E7411w7fX的视频属性抓取结束
# 开始BV号为1g7411g71q视频属性的抓取
# BV号为1g7411g71q的视频属性抓取结束
# 开始BV号为1j7411j76B视频属性的抓取
# BV号为1j7411j76B的视频属性抓取结束
# 开始BV号为1W7411V7Lr视频属性的抓取
# BV号为1W7411V7Lr的视频属性抓取结束
# 开始BV号为1B7411j7ok视频属性的抓取
# BV号为1B7411j7ok的视频属性抓取结束
# 开始BV号为1z7411p7NT视频属性的抓取
# BV号为1z7411p7NT的视频属性抓取结束
# 开始BV号为1H7411w7BG视频属性的抓取
# BV号为1H7411w7BG的视频属性抓取结束
# 开始BV号为1U7411F7SE视频属性的抓取
# BV号为1U7411F7SE的视频属性抓取结束
# 开始BV号为1Wj411f7AQ视频属性的抓取
# BV号为1Wj411f7AQ的视频属性抓取结束
# 开始BV号为117411478m视频属性的抓取
# BV号为117411478m的视频属性抓取结束
# 开始BV号为1n741137Tb视频属性的抓取
# BV号为1n741137Tb的视频属性抓取结束
# 开始BV号为1i7411G7nb视频属性的抓取
# BV号为1i7411G7nb的视频属性抓取结束
# 开始BV号为1D7411t757视频属性的抓取
# 开始BV号为1D7411t757视频属性的抓取
# BV号为1D7411t757的视频属性抓取结束
# 开始BV号为1Q7411g7gL视频属性的抓取
# BV号为1Q7411g7gL的视频属性抓取结束
# 开始BV号为1a7411A72M视频属性的抓取
# BV号为1a7411A72M的视频属性抓取结束
# 开始BV号为137411W7ex视频属性的抓取
# BV号为137411W7ex的视频属性抓取结束
# 开始BV号为1W7411K7oK视频属性的抓取
# BV号为1W7411K7oK的视频属性抓取结束
# 开始BV号为1F7411G7SS视频属性的抓取
# BV号为1F7411G7SS的视频属性抓取结束
# 开始BV号为16741147ok视频属性的抓取
# BV号为16741147ok的视频属性抓取结束
# 开始BV号为1dj411f7sR视频属性的抓取
# BV号为1dj411f7sR的视频属性抓取结束
# 开始BV号为1o7411A7dV视频属性的抓取
# BV号为1o7411A7dV的视频属性抓取结束
# 开始BV号为1N7411T7Ve视频属性的抓取
# BV号为1N7411T7Ve的视频属性抓取结束
# 开始BV号为1a7411V7nS视频属性的抓取
# BV号为1a7411V7nS的视频属性抓取结束
# 开始BV号为1T7411P7Ms视频属性的抓取
# BV号为1T7411P7Ms的视频属性抓取结束
# 开始BV号为1P7411s7my视频属性的抓取
# BV号为1P7411s7my的视频属性抓取结束
# 开始BV号为1H7411c7Xe视频属性的抓取
# BV号为1H7411c7Xe的视频属性抓取结束
# 开始BV号为1NE411J7i7视频属性的抓取
# BV号为1NE411J7i7的视频属性抓取结束
# 开始BV号为117411h7xf视频属性的抓取
# BV号为117411h7xf的视频属性抓取结束
# 开始BV号为1e741137YZ视频属性的抓取
# BV号为1e741137YZ的视频属性抓取结束
# 开始BV号为1q7411W7K4视频属性的抓取
# BV号为1q7411W7K4的视频属性抓取结束
# 开始BV号为1u7411c7RG视频属性的抓取
# BV号为1u7411c7RG的视频属性抓取结束
# 开始BV号为1K7411F7RD视频属性的抓取
# BV号为1K7411F7RD的视频属性抓取结束
# 开始BV号为167411E7zQ视频属性的抓取
# BV号为167411E7zQ的视频属性抓取结束
# 开始BV号为1c741187M6视频属性的抓取
# BV号为1c741187M6的视频属性抓取结束
# 开始BV号为1k7411w7rb视频属性的抓取
# BV号为1k7411w7rb的视频属性抓取结束
# 开始BV号为157411N7bP视频属性的抓取
# BV号为157411N7bP的视频属性抓取结束
# 开始BV号为1A7411N7TQ视频属性的抓取
# BV号为1A7411N7TQ的视频属性抓取结束
# 开始BV号为1A7411a7cu视频属性的抓取
# BV号为1A7411a7cu的视频属性抓取结束
# 开始BV号为1Vj411f7Df视频属性的抓取
# BV号为1Vj411f7Df的视频属性抓取结束
# 开始BV号为1w7411u7WU视频属性的抓取
# BV号为1w7411u7WU的视频属性抓取结束
# 开始BV号为1C7411b7MR视频属性的抓取
# BV号为1C7411b7MR的视频属性抓取结束
# 开始BV号为1v7411V7fp视频属性的抓取
# BV号为1v7411V7fp的视频属性抓取结束
# 开始BV号为16j411f7VZ视频属性的抓取
# BV号为16j411f7VZ的视频属性抓取结束
# 开始BV号为1f741157KA视频属性的抓取
# BV号为1f741157KA的视频属性抓取结束
# 开始BV号为1T741137iG视频属性的抓取
# BV号为1T741137iG的视频属性抓取结束
# 开始BV号为1V7411E7Jm视频属性的抓取
# BV号为1V7411E7Jm的视频属性抓取结束
# 开始BV号为1g7411P7Qc视频属性的抓取
# BV号为1g7411P7Qc的视频属性抓取结束
# 开始BV号为1r7411J7Yc视频属性的抓取
# BV号为1r7411J7Yc的视频属性抓取结束
# 开始BV号为187411u7GF视频属性的抓取
# BV号为187411u7GF的视频属性抓取结束
# 开始BV号为1m7411V7va视频属性的抓取
# BV号为1m7411V7va的视频属性抓取结束
# 开始BV号为1nj411f7vo视频属性的抓取
# BV号为1nj411f7vo的视频属性抓取结束
# 开始BV号为1F741157iP视频属性的抓取
# BV号为1F741157iP的视频属性抓取结束
# 开始BV号为187411T7AC视频属性的抓取
# BV号为187411T7AC的视频属性抓取结束
# 开始BV号为117411t73c视频属性的抓取
# BV号为117411t73c的视频属性抓取结束
# 开始BV号为13E411p7pu视频属性的抓取
# BV号为13E411p7pu的视频属性抓取结束
# 开始BV号为1eE411P7Xt视频属性的抓取
# BV号为1eE411P7Xt的视频属性抓取结束
# 开始BV号为1rE411A7Gc视频属性的抓取
# BV号为1rE411A7Gc的视频属性抓取结束
# 开始BV号为1ME411W7ry视频属性的抓取
# BV号为1ME411W7ry的视频属性抓取结束
# 开始BV号为1bE411u7VZ视频属性的抓取
# BV号为1bE411u7VZ的视频属性抓取结束
# 开始BV号为1ME411E7rf视频属性的抓取
# BV号为1ME411E7rf的视频属性抓取结束
# 开始BV号为1Bp4y117LU视频属性的抓取
# BV号为1Bp4y117LU的视频属性抓取结束
# 开始BV号为17E411E7sq视频属性的抓取
# BV号为17E411E7sq的视频属性抓取结束
# 开始BV号为1wE411w7AM视频属性的抓取
# BV号为1wE411w7AM的视频属性抓取结束
# 开始BV号为1J7411C7PL视频属性的抓取
# BV号为1J7411C7PL的视频属性抓取结束
# 开始BV号为1G7411f76J视频属性的抓取
# BV号为1G7411f76J的视频属性抓取结束
# 开始BV号为1G7411f7FA视频属性的抓取
# BV号为1G7411f7FA的视频属性抓取结束
# 开始BV号为1vE411A7FE视频属性的抓取
# BV号为1vE411A7FE的视频属性抓取结束
# 开始BV号为1NE41177mj视频属性的抓取
# BV号为1NE41177mj的视频属性抓取结束
# 开始BV号为1ME411A7ig视频属性的抓取
# BV号为1ME411A7ig的视频属性抓取结束
# 开始BV号为1tp411A75F视频属性的抓取
# BV号为1tp411A75F的视频属性抓取结束
# 开始BV号为1iE411u76P视频属性的抓取
# BV号为1iE411u76P的视频属性抓取结束
# 开始BV号为1EE411w75R视频属性的抓取
# BV号为1EE411w75R的视频属性抓取结束
# 开始BV号为1R741197GD视频属性的抓取
# BV号为1R741197GD的视频属性抓取结束
# 开始BV号为127411C7XQ视频属性的抓取
# BV号为127411C7XQ的视频属性抓取结束
# 开始BV号为1gE411G7QG视频属性的抓取
# BV号为1gE411G7QG的视频属性抓取结束
# 开始BV号为14741127P7视频属性的抓取
# BV号为14741127P7的视频属性抓取结束
# 开始BV号为1j7411d7pv视频属性的抓取
# BV号为1j7411d7pv的视频属性抓取结束
# 开始BV号为1e7411S7ps视频属性的抓取
# BV号为1e7411S7ps的视频属性抓取结束
# 开始BV号为167411C7Vf视频属性的抓取
# BV号为167411C7Vf的视频属性抓取结束
# 开始BV号为1EE411s79R视频属性的抓取
# BV号为1EE411s79R的视频属性抓取结束
# 开始BV号为1f7411y782视频属性的抓取
# BV号为1f7411y782的视频属性抓取结束
# 开始BV号为167411y7GZ视频属性的抓取
# BV号为167411y7GZ的视频属性抓取结束
# 开始BV号为1nE411P7ct视频属性的抓取
# BV号为1nE411P7ct的视频属性抓取结束
# 开始BV号为1CE411F7zh视频属性的抓取
# BV号为1CE411F7zh的视频属性抓取结束
# 开始BV号为1W741127Sq视频属性的抓取
# BV号为1W741127Sq的视频属性抓取结束
# 开始BV号为1J741117qH视频属性的抓取
# BV号为1J741117qH的视频属性抓取结束
# 开始BV号为1ZE411x7fG视频属性的抓取
# BV号为1ZE411x7fG的视频属性抓取结束
# 开始BV号为1YE411V7Rw视频属性的抓取
# BV号为1YE411V7Rw的视频属性抓取结束
# 开始BV号为1G7411m7Qn视频属性的抓取
# BV号为1G7411m7Qn的视频属性抓取结束
# 开始BV号为1C541147tf视频属性的抓取
# BV号为1C541147tf的视频属性抓取结束
# 开始BV号为1QE411H7J2视频属性的抓取
# BV号为1QE411H7J2的视频属性抓取结束
# 开始BV号为1A7411Z7ag视频属性的抓取
# BV号为1A7411Z7ag的视频属性抓取结束
# 开始BV号为1e7411m7EP视频属性的抓取
# BV号为1e7411m7EP的视频属性抓取结束
# 开始BV号为1hE411A78A视频属性的抓取
# BV号为1hE411A78A的视频属性抓取结束
# 开始BV号为1yE411A7Mm视频属性的抓取
# BV号为1yE411A7Mm的视频属性抓取结束
# 开始BV号为1vE41157DM视频属性的抓取
# BV号为1vE41157DM的视频属性抓取结束
# 开始BV号为16E41157v6视频属性的抓取
# BV号为16E41157v6的视频属性抓取结束
# 开始BV号为1tc411h7Ah视频属性的抓取
# BV号为1tc411h7Ah的视频属性抓取结束
# 开始BV号为1yE411u7dV视频属性的抓取
# BV号为1yE411u7dV的视频属性抓取结束
# 开始BV号为1wE411W71w视频属性的抓取
# BV号为1wE411W71w的视频属性抓取结束
# 开始BV号为1A7411o7m7视频属性的抓取
# BV号为1A7411o7m7的视频属性抓取结束
# 开始BV号为1Q7411D7eh视频属性的抓取
# BV号为1Q7411D7eh的视频属性抓取结束
# 开始BV号为1Bk4y197Eg视频属性的抓取
# BV号为1Bk4y197Eg的视频属性抓取结束
# 开始BV号为1aC4y147vU视频属性的抓取
# BV号为1aC4y147vU的视频属性抓取结束
# 开始BV号为1SE411P7zt视频属性的抓取
# BV号为1SE411P7zt的视频属性抓取结束
# 开始BV号为12E411j7EY视频属性的抓取
# BV号为12E411j7EY的视频属性抓取结束
# 开始BV号为1b7411d74a视频属性的抓取
# BV号为1b7411d74a的视频属性抓取结束
# 开始BV号为1QE411u7fe视频属性的抓取
# BV号为1QE411u7fe的视频属性抓取结束
# 开始BV号为1B7411y7oi视频属性的抓取
# BV号为1B7411y7oi的视频属性抓取结束
# 开始BV号为1GE411W7Uk视频属性的抓取
# BV号为1GE411W7Uk的视频属性抓取结束
# 开始BV号为1dE411T75t视频属性的抓取
# BV号为1dE411T75t的视频属性抓取结束
# 开始BV号为1h7411S7wH视频属性的抓取
# BV号为1h7411S7wH的视频属性抓取结束
# 开始BV号为1AE411M75S视频属性的抓取
# BV号为1AE411M75S的视频属性抓取结束
# 开始BV号为11E411g7pF视频属性的抓取
# BV号为11E411g7pF的视频属性抓取结束
# 开始BV号为1eE411A7T9视频属性的抓取
# BV号为1eE411A7T9的视频属性抓取结束
# 开始BV号为14E411c7MH视频属性的抓取
# BV号为14E411c7MH的视频属性抓取结束
# 开始BV号为17E41157ub视频属性的抓取
# BV号为17E41157ub的视频属性抓取结束
# 开始BV号为1iK41177wn视频属性的抓取
# BV号为1iK41177wn的视频属性抓取结束
# 开始BV号为187411D73X视频属性的抓取
# BV号为187411D73X的视频属性抓取结束
# 开始BV号为1S541147eV视频属性的抓取
# BV号为1S541147eV的视频属性抓取结束
# 开始BV号为1gE411L76k视频属性的抓取
# BV号为1gE411L76k的视频属性抓取结束
# 开始BV号为1T741117Qi视频属性的抓取
# BV号为1T741117Qi的视频属性抓取结束
# 开始BV号为1W7411D7b6视频属性的抓取
# BV号为1W7411D7b6的视频属性抓取结束
# 开始BV号为15E411x7Ej视频属性的抓取
# BV号为15E411x7Ej的视频属性抓取结束
# 开始BV号为1oE411w7wr视频属性的抓取
# BV号为1oE411w7wr的视频属性抓取结束
# 开始BV号为1FE411F7CE视频属性的抓取
# BV号为1FE411F7CE的视频属性抓取结束
# <ipython-input-10-86c6193e44fc>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1XE411V7xH视频属性的抓取
# BV号为1XE411V7xH的视频属性抓取结束
# 开始BV号为1h7411Z7eM视频属性的抓取
# BV号为1h7411Z7eM的视频属性抓取结束
# 开始BV号为1CE411c7KL视频属性的抓取
# BV号为1CE411c7KL的视频属性抓取结束
# 开始BV号为1RE411p7P2视频属性的抓取
# BV号为1RE411p7P2的视频属性抓取结束
# 开始BV号为1o7411m7AU视频属性的抓取
# BV号为1o7411m7AU的视频属性抓取结束
# 开始BV号为1X7411X71B视频属性的抓取
# BV号为1X7411X71B的视频属性抓取结束
# 开始BV号为11E411H7Bx视频属性的抓取
# BV号为11E411H7Bx的视频属性抓取结束
# 开始BV号为1rE411w75f视频属性的抓取
# 开始BV号为1rE411w75f视频属性的抓取
# BV号为1rE411w75f的视频属性抓取结束
# 开始BV号为1c7411U7ub视频属性的抓取
# BV号为1c7411U7ub的视频属性抓取结束
# 开始BV号为1bz411h7wN视频属性的抓取
# BV号为1bz411h7wN的视频属性抓取结束
# <ipython-input-10-86c6193e44fc>:190: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1LE411T7eK视频属性的抓取
# BV号为1LE411T7eK的视频属性抓取结束
# 开始BV号为177411f7aE视频属性的抓取
# BV号为177411f7aE的视频属性抓取结束
# 开始BV号为1G7411U7sF视频属性的抓取
# BV号为1G7411U7sF的视频属性抓取结束
# 开始BV号为19741197Zx视频属性的抓取
# BV号为19741197Zx的视频属性抓取结束
# 开始BV号为1ZE411G7AK视频属性的抓取
# BV号为1ZE411G7AK的视频属性抓取结束
# 开始BV号为1hz411h7NQ视频属性的抓取
# BV号为1hz411h7NQ的视频属性抓取结束
# 开始BV号为147411d79B视频属性的抓取
# BV号为147411d79B的视频属性抓取结束
# 开始BV号为1dE41137CF视频属性的抓取
# BV号为1dE41137CF的视频属性抓取结束
# 开始BV号为1eE411T7Mb视频属性的抓取
# BV号为1eE411T7Mb的视频属性抓取结束
# 开始BV号为1SE41157tQ视频属性的抓取
# BV号为1SE41157tQ的视频属性抓取结束
# 开始BV号为1mE411p7aQ视频属性的抓取
# BV号为1mE411p7aQ的视频属性抓取结束
# 开始BV号为1eE411j72Y视频属性的抓取
# BV号为1eE411j72Y的视频属性抓取结束
# 开始BV号为1U7411Q7hG视频属性的抓取
# BV号为1U7411Q7hG的视频属性抓取结束
# 开始BV号为1Na4y1t79d视频属性的抓取
# BV号为1Na4y1t79d的视频属性抓取结束
# 开始BV号为1pE411c7PE视频属性的抓取
# BV号为1pE411c7PE的视频属性抓取结束
# 开始BV号为1FE411N7HL视频属性的抓取
# BV号为1FE411N7HL的视频属性抓取结束
# 开始BV号为18z411B7Yc视频属性的抓取
# BV号为18z411B7Yc的视频属性抓取结束
# 开始BV号为1NA41187oc视频属性的抓取
# BV号为1NA41187oc的视频属性抓取结束
# 开始BV号为1Ya4y147T6视频属性的抓取
# BV号为1Ya4y147T6的视频属性抓取结束
# 开始BV号为1mk4y197a9视频属性的抓取
# BV号为1mk4y197a9的视频属性抓取结束
# 开始BV号为1Hk4y1R7id视频属性的抓取
# BV号为1Hk4y1R7id的视频属性抓取结束
# 开始BV号为1cV411d7HJ视频属性的抓取
# BV号为1cV411d7HJ的视频属性抓取结束
# 开始BV号为1S541167iC视频属性的抓取
# BV号为1S541167iC的视频属性抓取结束
# 开始BV号为1b54y1d725视频属性的抓取
# BV号为1b54y1d725的视频属性抓取结束
# 开始BV号为1564y1u77p视频属性的抓取
# BV号为1564y1u77p的视频属性抓取结束
# 开始BV号为1iK4y1r7GL视频属性的抓取
# BV号为1iK4y1r7GL的视频属性抓取结束
# 开始BV号为1SK4y1C7Me视频属性的抓取
# BV号为1SK4y1C7Me的视频属性抓取结束
# 开始BV号为1EV411d7jg视频属性的抓取
# BV号为1EV411d7jg的视频属性抓取结束
# 开始BV号为17p4y117Zx视频属性的抓取
# BV号为17p4y117Zx的视频属性抓取结束
# 开始BV号为1VA411b7TN视频属性的抓取
# BV号为1VA411b7TN的视频属性抓取结束
# 开始BV号为1FK411j72c视频属性的抓取
# BV号为1FK411j72c的视频属性抓取结束
# 开始BV号为1bK4y1b7f8视频属性的抓取
# BV号为1bK4y1b7f8的视频属性抓取结束
# 开始BV号为1ai4y1t7e5视频属性的抓取
# BV号为1ai4y1t7e5的视频属性抓取结束
# 开始BV号为1gQ4y1K7pr视频属性的抓取
# BV号为1gQ4y1K7pr的视频属性抓取结束
# 开始BV号为1A54y197y8视频属性的抓取
# BV号为1A54y197y8的视频属性抓取结束
# 开始BV号为1r54y1Q7DH视频属性的抓取
# BV号为1r54y1Q7DH的视频属性抓取结束
# 开始BV号为1TK4y1k7yZ视频属性的抓取
# BV号为1TK4y1k7yZ的视频属性抓取结束
# 开始BV号为1664y1T777视频属性的抓取
# BV号为1664y1T777的视频属性抓取结束
# 开始BV号为1gA411h7aU视频属性的抓取
# BV号为1gA411h7aU的视频属性抓取结束
# 开始BV号为1oT4y1g7bX视频属性的抓取
# BV号为1oT4y1g7bX的视频属性抓取结束
# 开始BV号为1xK4y1b7Lr视频属性的抓取
# BV号为1xK4y1b7Lr的视频属性抓取结束
# 开始BV号为1Vz41187jd视频属性的抓取
# BV号为1Vz41187jd的视频属性抓取结束
# 开始BV号为1o64y1T7CR视频属性的抓取
# BV号为1o64y1T7CR的视频属性抓取结束
# 开始BV号为13t4y1m747视频属性的抓取
# BV号为13t4y1m747的视频属性抓取结束
# 开始BV号为1oK4y1r7JN视频属性的抓取
# BV号为1oK4y1r7JN的视频属性抓取结束
# 开始BV号为1oZ4y1x7HK视频属性的抓取
# BV号为1oZ4y1x7HK的视频属性抓取结束
# 开始BV号为1Nk4y1k7hY视频属性的抓取
# BV号为1Nk4y1k7hY的视频属性抓取结束
# 开始BV号为1sV411o7c4视频属性的抓取
# BV号为1sV411o7c4的视频属性抓取结束
# 开始BV号为1iK4y1b7Rm视频属性的抓取
# BV号为1iK4y1b7Rm的视频属性抓取结束
# 开始BV号为1154y1Q7e5视频属性的抓取
# BV号为1154y1Q7e5的视频属性抓取结束
# 开始BV号为1xc411h7Ph视频属性的抓取
# BV号为1xc411h7Ph的视频属性抓取结束
# 开始BV号为1DK4y1r7Jp视频属性的抓取
# BV号为1DK4y1r7Jp的视频属性抓取结束
# 开始BV号为1RC4y1s7ci视频属性的抓取
# BV号为1RC4y1s7ci的视频属性抓取结束
# 开始BV号为1pC4y1s7KL视频属性的抓取
# BV号为1pC4y1s7KL的视频属性抓取结束
# 开始BV号为1mt4y127V4视频属性的抓取
# BV号为1mt4y127V4的视频属性抓取结束
# 开始BV号为1SZ4y1W7uU视频属性的抓取
# BV号为1SZ4y1W7uU的视频属性抓取结束
# 开始BV号为1aT4y1g7JX视频属性的抓取
# BV号为1aT4y1g7JX的视频属性抓取结束
# 开始BV号为1FV411Z7Re视频属性的抓取
# BV号为1FV411Z7Re的视频属性抓取结束
# 开始BV号为1Jk4y1R7Ka视频属性的抓取
# BV号为1Jk4y1R7Ka的视频属性抓取结束
# 开始BV号为1Uk4y1d7as视频属性的抓取
# BV号为1Uk4y1d7as的视频属性抓取结束
# 开始BV号为1XC4y1p7Yn视频属性的抓取
# BV号为1XC4y1p7Yn的视频属性抓取结束
# 开始BV号为16K411L7A7视频属性的抓取
# BV号为16K411L7A7的视频属性抓取结束
# 开始BV号为1gt4y1U7oj视频属性的抓取
# BV号为1gt4y1U7oj的视频属性抓取结束
# 开始BV号为1BC4y147xH视频属性的抓取
# BV号为1BC4y147xH的视频属性抓取结束
# 开始BV号为1LQ4y1K7Jd视频属性的抓取
# BV号为1LQ4y1K7Jd的视频属性抓取结束
# 开始BV号为11T4y1g7si视频属性的抓取
# BV号为11T4y1g7si的视频属性抓取结束
# 开始BV号为1Ez411b7Q7视频属性的抓取
# BV号为1Ez411b7Q7的视频属性抓取结束
# 开始BV号为1eC4y147qY视频属性的抓取
# BV号为1eC4y147qY的视频属性抓取结束
# 开始BV号为1zT4y1G7Uu视频属性的抓取
# BV号为1zT4y1G7Uu的视频属性抓取结束
# 开始BV号为1dg4y187Cy视频属性的抓取
# BV号为1dg4y187Cy的视频属性抓取结束
# 开始BV号为1Fe411x7cf视频属性的抓取
# BV号为1Fe411x7cf的视频属性抓取结束
# 开始BV号为1KC4y1x79R视频属性的抓取
# BV号为1KC4y1x79R的视频属性抓取结束
# 开始BV号为16K4y1b72h视频属性的抓取
# BV号为16K4y1b72h的视频属性抓取结束
# 开始BV号为1tf4y1S7bx视频属性的抓取
# BV号为1tf4y1S7bx的视频属性抓取结束
# 开始BV号为16e411x7Rs视频属性的抓取
# BV号为16e411x7Rs的视频属性抓取结束
# 开始BV号为1M5411t7TX视频属性的抓取
# BV号为1M5411t7TX的视频属性抓取结束
# 开始BV号为1pg4y1z7Ti视频属性的抓取
# BV号为1pg4y1z7Ti的视频属性抓取结束
# 开始BV号为1MV411d7km视频属性的抓取
# BV号为1MV411d7km的视频属性抓取结束
# 开始BV号为1uA411b75v视频属性的抓取
# BV号为1uA411b75v的视频属性抓取结束
# 开始BV号为1JK4y1r7Ca视频属性的抓取
# BV号为1JK4y1r7Ca的视频属性抓取结束
# 开始BV号为1uT4y1G72R视频属性的抓取
# BV号为1uT4y1G72R的视频属性抓取结束
# 开始BV号为12V411f7TL视频属性的抓取
# BV号为12V411f7TL的视频属性抓取结束
# 开始BV号为1wp4y1y7gu视频属性的抓取
# BV号为1wp4y1y7gu的视频属性抓取结束
# 开始BV号为1ke411s7hs视频属性的抓取
# BV号为1ke411s7hs的视频属性抓取结束
# 开始BV号为1ma4y1v7xd视频属性的抓取
# BV号为1ma4y1v7xd的视频属性抓取结束
# 开始BV号为1ya4y1t7Wq视频属性的抓取
# BV号为1ya4y1t7Wq的视频属性抓取结束
# 开始BV号为1yt4y1y7e9视频属性的抓取
# BV号为1yt4y1y7e9的视频属性抓取结束
# 开始BV号为1Gf4y1m7fa视频属性的抓取
# BV号为1Gf4y1m7fa的视频属性抓取结束
# 开始BV号为1Wa4y1x7sk视频属性的抓取
# BV号为1Wa4y1x7sk的视频属性抓取结束
# 开始BV号为14a4y1474q视频属性的抓取
# BV号为14a4y1474q的视频属性抓取结束
# 开始BV号为18V411o7Lt视频属性的抓取
# BV号为18V411o7Lt的视频属性抓取结束
# 开始BV号为1NK411L7JB视频属性的抓取
# BV号为1NK411L7JB的视频属性抓取结束
# 开始BV号为1HC4y1s7t9视频属性的抓取
# BV号为1HC4y1s7t9的视频属性抓取结束
# 开始BV号为12c411h77P视频属性的抓取
# BV号为12c411h77P的视频属性抓取结束
# 开始BV号为14Q4y1T7CM视频属性的抓取
# BV号为14Q4y1T7CM的视频属性抓取结束
# 开始BV号为1Cp4y117ep视频属性的抓取
# BV号为1Cp4y117ep的视频属性抓取结束
# 开始BV号为18a4y1t7XS视频属性的抓取
# BV号为18a4y1t7XS的视频属性抓取结束
# 开始BV号为1Ap4y1y7PJ视频属性的抓取
# BV号为1Ap4y1y7PJ的视频属性抓取结束
# 开始BV号为1AK4y1k7LF视频属性的抓取
# BV号为1AK4y1k7LF的视频属性抓取结束
# 开始BV号为19K411V7Xy视频属性的抓取
# BV号为19K411V7Xy的视频属性抓取结束
# 开始BV号为1YC4y1s72q视频属性的抓取
# BV号为1YC4y1s72q的视频属性抓取结束
# 开始BV号为1CA411b7hA视频属性的抓取
# BV号为1CA411b7hA的视频属性抓取结束
# 开始BV号为115411x71X视频属性的抓取
# BV号为115411x71X的视频属性抓取结束
# 开始BV号为1vZ4y1x7s5视频属性的抓取
# BV号为1vZ4y1x7s5的视频属性抓取结束
# 开始BV号为1gA411b7tS视频属性的抓取
# BV号为1gA411b7tS的视频属性抓取结束
# 开始BV号为15a4y1x7WH视频属性的抓取
# BV号为15a4y1x7WH的视频属性抓取结束
# 开始BV号为1Vf4y1m7LF视频属性的抓取
# BV号为1Vf4y1m7LF的视频属性抓取结束
# 开始BV号为1vK4y1b7Zx视频属性的抓取
# BV号为1vK4y1b7Zx的视频属性抓取结束
# 开始BV号为12A41147py视频属性的抓取
# BV号为12A41147py的视频属性抓取结束
# 开始BV号为1LA411h7QK视频属性的抓取
# BV号为1LA411h7QK的视频属性抓取结束
# 开始BV号为1mT4y1g7Mh视频属性的抓取
# BV号为1mT4y1g7Mh的视频属性抓取结束
# 开始BV号为1ET4y1G7kx视频属性的抓取
# BV号为1ET4y1G7kx的视频属性抓取结束
# 开始BV号为1gi4y1t74H视频属性的抓取
# BV号为1gi4y1t74H的视频属性抓取结束
# 开始BV号为16t4y1274F视频属性的抓取
# BV号为16t4y1274F的视频属性抓取结束
# 开始BV号为1Wg4y187Qf视频属性的抓取
# BV号为1Wg4y187Qf的视频属性抓取结束
# 开始BV号为1nC4y147VV视频属性的抓取
# BV号为1nC4y147VV的视频属性抓取结束
# 开始BV号为13k4y1678g视频属性的抓取
# BV号为13k4y1678g的视频属性抓取结束
# 开始BV号为14g4y1i76z视频属性的抓取
# BV号为14g4y1i76z的视频属性抓取结束
# 开始BV号为1zQ4y1N7Bm视频属性的抓取
# BV号为1zQ4y1N7Bm的视频属性抓取结束
# 开始BV号为1Zz411q74M视频属性的抓取
# BV号为1Zz411q74M的视频属性抓取结束
# 开始BV号为1Gk4y1r7bk视频属性的抓取
# BV号为1Gk4y1r7bk的视频属性抓取结束
# 开始BV号为13f4y1U7dw视频属性的抓取
# BV号为13f4y1U7dw的视频属性抓取结束
# 开始BV号为1vA411t7EG视频属性的抓取
# BV号为1vA411t7EG的视频属性抓取结束
# 开始BV号为1fC4y1H7xq视频属性的抓取
# BV号为1fC4y1H7xq的视频属性抓取结束
# 开始BV号为1BA41147KF视频属性的抓取
# BV号为1BA41147KF的视频属性抓取结束
# 开始BV号为1Sa4y1i7wi视频属性的抓取
# BV号为1Sa4y1i7wi的视频属性抓取结束
# 开始BV号为1qf4y1S7mP视频属性的抓取
# BV号为1qf4y1S7mP的视频属性抓取结束
# 开始BV号为1Yk4y1k7kj视频属性的抓取
# BV号为1Yk4y1k7kj的视频属性抓取结束
# 开始BV号为1bT4y1374n视频属性的抓取
# BV号为1bT4y1374n的视频属性抓取结束
# 开始BV号为1yZ4y1p7zK视频属性的抓取
# BV号为1yZ4y1p7zK的视频属性抓取结束
# 开始BV号为1Az4y1974r视频属性的抓取
# BV号为1Az4y1974r的视频属性抓取结束
# 开始BV号为1Fz411B7aB视频属性的抓取
# BV号为1Fz411B7aB的视频属性抓取结束
# 开始BV号为1aA411q7b9视频属性的抓取
# BV号为1aA411q7b9的视频属性抓取结束
# 开始BV号为16Q4y1A72L视频属性的抓取
# BV号为16Q4y1A72L的视频属性抓取结束
# 开始BV号为17e411W7Rp视频属性的抓取
# 开始BV号为17e411W7Rp视频属性的抓取
# BV号为17e411W7Rp的视频属性抓取结束
# 开始BV号为1vC4y1p74B视频属性的抓取
# BV号为1vC4y1p74B的视频属性抓取结束
# 开始BV号为1up4y1X773视频属性的抓取
# BV号为1up4y1X773的视频属性抓取结束
# 开始BV号为1xz4y1d7yr视频属性的抓取
# BV号为1xz4y1d7yr的视频属性抓取结束
# 开始BV号为1hZ4y1s7K1视频属性的抓取
# BV号为1hZ4y1s7K1的视频属性抓取结束
# 开始BV号为1XQ4y1N7da视频属性的抓取
# BV号为1XQ4y1N7da的视频属性抓取结束
# 开始BV号为12f4y1m7eW视频属性的抓取
# BV号为12f4y1m7eW的视频属性抓取结束
# 开始BV号为1fA411i78W视频属性的抓取
# BV号为1fA411i78W的视频属性抓取结束
# 开始BV号为1BQ4y1A7Su视频属性的抓取
# BV号为1BQ4y1A7Su的视频属性抓取结束
# 开始BV号为1Hi4y1s7sK视频属性的抓取
# BV号为1Hi4y1s7sK的视频属性抓取结束
# 开始BV号为1tp4y1X7Gg视频属性的抓取
# BV号为1tp4y1X7Gg的视频属性抓取结束
# 开始BV号为1Uz411v75y视频属性的抓取
# BV号为1Uz411v75y的视频属性抓取结束
# 开始BV号为1Yp4y1Q727视频属性的抓取
# BV号为1Yp4y1Q727的视频属性抓取结束
# 开始BV号为1sQ4y1N7Fp视频属性的抓取
# BV号为1sQ4y1N7Fp的视频属性抓取结束
# 开始BV号为1WZ4y1p7i2视频属性的抓取
# BV号为1WZ4y1p7i2的视频属性抓取结束
# 开始BV号为1xp4y1X7JG视频属性的抓取
# BV号为1xp4y1X7JG的视频属性抓取结束
# 开始BV号为1sz411z7Qb视频属性的抓取
# BV号为1sz411z7Qb的视频属性抓取结束
# 开始BV号为1uA411q7YQ视频属性的抓取
# BV号为1uA411q7YQ的视频属性抓取结束
# 开始BV号为1tC4y1W7gD视频属性的抓取
# BV号为1tC4y1W7gD的视频属性抓取结束
# 开始BV号为1Ci4y1x7mG视频属性的抓取
# BV号为1Ci4y1x7mG的视频属性抓取结束
# 开始BV号为1uz4y1d7CZ视频属性的抓取
# 开始BV号为1uz4y1d7CZ视频属性的抓取
# BV号为1uz4y1d7CZ的视频属性抓取结束
# 开始BV号为1Np4y1X7SQ视频属性的抓取
# BV号为1Np4y1X7SQ的视频属性抓取结束
# 开始BV号为1ya4y1e7d4视频属性的抓取
# BV号为1ya4y1e7d4的视频属性抓取结束
# 开始BV号为1Dt4y1y7FV视频属性的抓取
# BV号为1Dt4y1y7FV的视频属性抓取结束
# 开始BV号为18a4y1e7zx视频属性的抓取
# BV号为18a4y1e7zx的视频属性抓取结束
# 开始BV号为13K411s7k7视频属性的抓取
# BV号为13K411s7k7的视频属性抓取结束
# 开始BV号为1cz4y197D9视频属性的抓取
# BV号为1cz4y197D9的视频属性抓取结束
# 开始BV号为1VZ4y1s7Wf视频属性的抓取
# BV号为1VZ4y1s7Wf的视频属性抓取结束
# 开始BV号为1Xa4y1v7Y9视频属性的抓取
# BV号为1Xa4y1v7Y9的视频属性抓取结束
# 开始BV号为1Pg4y1B7nA视频属性的抓取
# BV号为1Pg4y1B7nA的视频属性抓取结束
# 开始BV号为1EA411t7Bd视频属性的抓取
# BV号为1EA411t7Bd的视频属性抓取结束
# 开始BV号为1rQ4y1A7QQ视频属性的抓取
# BV号为1rQ4y1A7QQ的视频属性抓取结束
# 开始BV号为1ti4y1s74N视频属性的抓取
# BV号为1ti4y1s74N的视频属性抓取结束
# 开始BV号为1up4y1X7h4视频属性的抓取
# BV号为1up4y1X7h4的视频属性抓取结束
# 开始BV号为1Ri4y1472j视频属性的抓取
# BV号为1Ri4y1472j的视频属性抓取结束
# 开始BV号为1FK411L7w4视频属性的抓取
# BV号为1FK411L7w4的视频属性抓取结束
# 开始BV号为1hV411d74Q视频属性的抓取
# BV号为1hV411d74Q的视频属性抓取结束
# 开始BV号为1Hz411q73U视频属性的抓取
# BV号为1Hz411q73U的视频属性抓取结束
# 开始BV号为11C4y1W7NN视频属性的抓取
# BV号为11C4y1W7NN的视频属性抓取结束
# 开始BV号为1wV411C79b视频属性的抓取
# BV号为1wV411C79b的视频属性抓取结束
# 开始BV号为1ei4y147wu视频属性的抓取
# BV号为1ei4y147wu的视频属性抓取结束
# 开始BV号为1TA41187xG视频属性的抓取
# BV号为1TA41187xG的视频属性抓取结束
# 开始BV号为17a4y1e7fS视频属性的抓取
# BV号为17a4y1e7fS的视频属性抓取结束
# 开始BV号为1SQ4y1A7Qp视频属性的抓取
# BV号为1SQ4y1A7Qp的视频属性抓取结束
# 开始BV号为1pe411W7BQ视频属性的抓取
# BV号为1pe411W7BQ的视频属性抓取结束
# 开始BV号为1Kp4y1X74F视频属性的抓取
# BV号为1Kp4y1X74F的视频属性抓取结束
# 开始BV号为1af4y1S7wJ视频属性的抓取
# BV号为1af4y1S7wJ的视频属性抓取结束
# 开始BV号为1vC4y1H7Dc视频属性的抓取
# BV号为1vC4y1H7Dc的视频属性抓取结束
# 开始BV号为1Lz4y1R7UK视频属性的抓取
# BV号为1Lz4y1R7UK的视频属性抓取结束
# 开始BV号为1jK411W723视频属性的抓取
# BV号为1jK411W723的视频属性抓取结束
# 开始BV号为18a4y1e7HD视频属性的抓取
# BV号为18a4y1e7HD的视频属性抓取结束
# 开始BV号为1YK4y1t7k9视频属性的抓取
# BV号为1YK4y1t7k9的视频属性抓取结束
# 开始BV号为1UT4y1u7b3视频属性的抓取
# BV号为1UT4y1u7b3的视频属性抓取结束
# 开始BV号为1rp4y1Q7aQ视频属性的抓取
# BV号为1rp4y1Q7aQ的视频属性抓取结束
# 开始BV号为1SC4y1H7z2视频属性的抓取
# BV号为1SC4y1H7z2的视频属性抓取结束
# 开始BV号为1Ba4y1e7WE视频属性的抓取
# BV号为1Ba4y1e7WE的视频属性抓取结束
# 开始BV号为1f54y1D7gQ视频属性的抓取
# BV号为1f54y1D7gQ的视频属性抓取结束
# 开始BV号为1Kz411i72d视频属性的抓取
# BV号为1Kz411i72d的视频属性抓取结束
# 开始BV号为1WZ4y1s7fV视频属性的抓取
# BV号为1WZ4y1s7fV的视频属性抓取结束
# 开始BV号为1qg4y1B7rS视频属性的抓取
# BV号为1qg4y1B7rS的视频属性抓取结束
# 开始BV号为1ba4y1e7eM视频属性的抓取
# BV号为1ba4y1e7eM的视频属性抓取结束
# 开始BV号为1jV411C7LL视频属性的抓取
# BV号为1jV411C7LL的视频属性抓取结束
# 开始BV号为1AK411s7R1视频属性的抓取
# BV号为1AK411s7R1的视频属性抓取结束
# 开始BV号为195411x7D9视频属性的抓取
# BV号为195411x7D9的视频属性抓取结束
# 开始BV号为1FK4y1b7ez视频属性的抓取
# BV号为1FK4y1b7ez的视频属性抓取结束
# 开始BV号为1HT4y1375Q视频属性的抓取
# BV号为1HT4y1375Q的视频属性抓取结束
# 开始BV号为195411x713视频属性的抓取
# BV号为195411x713的视频属性抓取结束
# 开始BV号为1Lv411z72r视频属性的抓取
# BV号为1Lv411z72r的视频属性抓取结束
# 开始BV号为1AA411t7jr视频属性的抓取
# BV号为1AA411t7jr的视频属性抓取结束
# 开始BV号为1SQ4y1N7qY视频属性的抓取
# BV号为1SQ4y1N7qY的视频属性抓取结束
# 开始BV号为155411x7nK视频属性的抓取
# BV号为155411x7nK的视频属性抓取结束
# 开始BV号为1Vi4y147vn视频属性的抓取
# BV号为1Vi4y147vn的视频属性抓取结束
# 开始BV号为1GK411W7nt视频属性的抓取
# BV号为1GK411W7nt的视频属性抓取结束
# 开始BV号为15t4y117zU视频属性的抓取
# BV号为15t4y117zU的视频属性抓取结束
# 开始BV号为1MA411t7Y3视频属性的抓取
# BV号为1MA411t7Y3的视频属性抓取结束
# 开始BV号为115411s7zo视频属性的抓取
# BV号为115411s7zo的视频属性抓取结束
# 开始BV号为11g4y1q7Gm视频属性的抓取
# BV号为11g4y1q7Gm的视频属性抓取结束
# 开始BV号为115411p7Yi视频属性的抓取
# BV号为115411p7Yi的视频属性抓取结束
# 开始BV号为1sT4y1u7Y6视频属性的抓取
# BV号为1sT4y1u7Y6的视频属性抓取结束
# 开始BV号为1Jz411q7UA视频属性的抓取
# BV号为1Jz411q7UA的视频属性抓取结束
# 开始BV号为13k4y1k7aY视频属性的抓取
# BV号为13k4y1k7aY的视频属性抓取结束
# 开始BV号为1fk4y167oW视频属性的抓取
# 开始BV号为1fk4y167oW视频属性的抓取
# 开始BV号为1fk4y167oW视频属性的抓取
# BV号为1fk4y167oW的视频属性抓取结束
# 开始BV号为1DC4y1a7Gb视频属性的抓取
# BV号为1DC4y1a7Gb的视频属性抓取结束
# 开始BV号为1Jt4y197Ht视频属性的抓取
# BV号为1Jt4y197Ht的视频属性抓取结束
# 开始BV号为1XZ4y1H7Eh视频属性的抓取
# BV号为1XZ4y1H7Eh的视频属性抓取结束
# 开始BV号为1JV411k7rf视频属性的抓取
# BV号为1JV411k7rf的视频属性抓取结束
# 开始BV号为1tZ4y1W7qm视频属性的抓取
# BV号为1tZ4y1W7qm的视频属性抓取结束
# 开始BV号为1Xp4y1D7ay视频属性的抓取
# BV号为1Xp4y1D7ay的视频属性抓取结束
# 开始BV号为1nA411i7iU视频属性的抓取
# BV号为1nA411i7iU的视频属性抓取结束
# 开始BV号为1j54y1Q7Ue视频属性的抓取
# BV号为1j54y1Q7Ue的视频属性抓取结束
# 开始BV号为1mv411z7Rp视频属性的抓取
# BV号为1mv411z7Rp的视频属性抓取结束
# 开始BV号为13i4y1x7Km视频属性的抓取
# BV号为13i4y1x7Km的视频属性抓取结束
# 开始BV号为1Mg4y1v7cc视频属性的抓取
# BV号为1Mg4y1v7cc的视频属性抓取结束
# 开始BV号为18k4y1z7fp视频属性的抓取
# BV号为18k4y1z7fp的视频属性抓取结束
# 开始BV号为13Z4y1H7jY视频属性的抓取
# BV号为13Z4y1H7jY的视频属性抓取结束
# 开始BV号为17a4y1Y744视频属性的抓取
# BV号为17a4y1Y744的视频属性抓取结束
# 开始BV号为12g4y1i7dD视频属性的抓取
# BV号为12g4y1i7dD的视频属性抓取结束
# 开始BV号为1mf4y127Qb视频属性的抓取
# BV号为1mf4y127Qb的视频属性抓取结束
# 开始BV号为1h5411W7US视频属性的抓取
# BV号为1h5411W7US的视频属性抓取结束
# 开始BV号为1FC4y1a7MB视频属性的抓取
# BV号为1FC4y1a7MB的视频属性抓取结束
# 开始BV号为1V5411W7Dm视频属性的抓取
# BV号为1V5411W7Dm的视频属性抓取结束
# 开始BV号为1c5411W7hd视频属性的抓取
# BV号为1c5411W7hd的视频属性抓取结束
# 开始BV号为1FD4y1Q7QL视频属性的抓取
# BV号为1FD4y1Q7QL的视频属性抓取结束
# 开始BV号为1TV411k7B8视频属性的抓取
# BV号为1TV411k7B8的视频属性抓取结束
# 开始BV号为1VT4y1J7Y8视频属性的抓取
# BV号为1VT4y1J7Y8的视频属性抓取结束
# 开始BV号为1cZ4y1p7HG视频属性的抓取
# BV号为1cZ4y1p7HG的视频属性抓取结束
# 开始BV号为1oC4y1a7Lg视频属性的抓取
# BV号为1oC4y1a7Lg的视频属性抓取结束
# 开始BV号为1et4y1y7LJ视频属性的抓取
# BV号为1et4y1y7LJ的视频属性抓取结束
# 开始BV号为1pa4y1Y7uR视频属性的抓取
# BV号为1pa4y1Y7uR的视频属性抓取结束
# 开始BV号为1GK411s7kR视频属性的抓取
# BV号为1GK411s7kR的视频属性抓取结束
# 开始BV号为1t54y1Q7bd视频属性的抓取
# BV号为1t54y1Q7bd的视频属性抓取结束
# 开始BV号为1AK4y147CB视频属性的抓取
# BV号为1AK4y147CB的视频属性抓取结束
# 开始BV号为1jZ4y1H71s视频属性的抓取
# BV号为1jZ4y1H71s的视频属性抓取结束
# 开始BV号为1NC4y1h71R视频属性的抓取
# BV号为1NC4y1h71R的视频属性抓取结束
# 开始BV号为1ig4y1i77z视频属性的抓取
# BV号为1ig4y1i77z的视频属性抓取结束
# 开始BV号为1gK4y1b7Ec视频属性的抓取
# BV号为1gK4y1b7Ec的视频属性抓取结束
# 开始BV号为1wZ4y1p7V9视频属性的抓取
# BV号为1wZ4y1p7V9的视频属性抓取结束
# 开始BV号为1fA411v75W视频属性的抓取
# BV号为1fA411v75W的视频属性抓取结束
# 开始BV号为1qT4y1J7Xg视频属性的抓取
# BV号为1qT4y1J7Xg的视频属性抓取结束
# 开始BV号为1op4y1D7Hm视频属性的抓取
# BV号为1op4y1D7Hm的视频属性抓取结束
# 开始BV号为1sa4y1v7WC视频属性的抓取
# BV号为1sa4y1v7WC的视频属性抓取结束
# 开始BV号为1bQ4y1P7Yx视频属性的抓取
# BV号为1bQ4y1P7Yx的视频属性抓取结束
# 开始BV号为1tg4y1v7K2视频属性的抓取
# BV号为1tg4y1v7K2的视频属性抓取结束
# 开始BV号为1T5411W7oV视频属性的抓取
# BV号为1T5411W7oV的视频属性抓取结束
# 开始BV号为1fi4y1s7nT视频属性的抓取
# BV号为1fi4y1s7nT的视频属性抓取结束
# 开始BV号为1cC4y1Y758视频属性的抓取
# BV号为1cC4y1Y758的视频属性抓取结束
# 开始BV号为155411Y7gU视频属性的抓取
# BV号为155411Y7gU的视频属性抓取结束
# 开始BV号为1D5411W7s1视频属性的抓取
# BV号为1D5411W7s1的视频属性抓取结束
# 开始BV号为1XZ4y1M7yp视频属性的抓取
# BV号为1XZ4y1M7yp的视频属性抓取结束
# 开始BV号为1uT4y1J7gJ视频属性的抓取
# BV号为1uT4y1J7gJ的视频属性抓取结束
# 开始BV号为1Bg4y1v7Ty视频属性的抓取
# BV号为1Bg4y1v7Ty的视频属性抓取结束
# 开始BV号为1Bf4y1y7Rp视频属性的抓取
# BV号为1Bf4y1y7Rp的视频属性抓取结束
# 开始BV号为1rC4y1p7ZL视频属性的抓取
# BV号为1rC4y1p7ZL的视频属性抓取结束
# 开始BV号为1b54y1Q7Sy视频属性的抓取
# BV号为1b54y1Q7Sy的视频属性抓取结束
# 开始BV号为1DK411p7cQ视频属性的抓取
# BV号为1DK411p7cQ的视频属性抓取结束
# 开始BV号为1v54y1B7cA视频属性的抓取
# 开始BV号为1v54y1B7cA视频属性的抓取
# BV号为1v54y1B7cA的视频属性抓取结束
# 开始BV号为1mp4y1D7mK视频属性的抓取
# BV号为1mp4y1D7mK的视频属性抓取结束
# 开始BV号为18z411i76o视频属性的抓取
# BV号为18z411i76o的视频属性抓取结束
# 开始BV号为1up4y1D74L视频属性的抓取
# BV号为1up4y1D74L的视频属性抓取结束
# 开始BV号为11k4y1z7p5视频属性的抓取
# BV号为11k4y1z7p5的视频属性抓取结束
# 开始BV号为1vi4y1x7cG视频属性的抓取
# 开始BV号为1vi4y1x7cG视频属性的抓取
# 开始BV号为1vi4y1x7cG视频属性的抓取
# BV号为1vi4y1x7cG的视频属性抓取结束
# 开始BV号为1FK411H7vv视频属性的抓取
# BV号为1FK411H7vv的视频属性抓取结束
# 开始BV号为1BT4y1J7eS视频属性的抓取
# BV号为1BT4y1J7eS的视频属性抓取结束
# 开始BV号为1jT4y1J7qy视频属性的抓取
# BV号为1jT4y1J7qy的视频属性抓取结束
# 开始BV号为1Ez4y197by视频属性的抓取
# BV号为1Ez4y197by的视频属性抓取结束
# 开始BV号为1Kp4y1D7q1视频属性的抓取
# BV号为1Kp4y1D7q1的视频属性抓取结束
# 开始BV号为1sz4y197kj视频属性的抓取
# BV号为1sz4y197kj的视频属性抓取结束
# 开始BV号为1ZK411H7rW视频属性的抓取
# BV号为1ZK411H7rW的视频属性抓取结束
# 开始BV号为1VZ4y1H75g视频属性的抓取
# BV号为1VZ4y1H75g的视频属性抓取结束
# 开始BV号为1Af4y1m7XB视频属性的抓取
# BV号为1Af4y1m7XB的视频属性抓取结束
# 开始BV号为1fC4y1h7HR视频属性的抓取
# BV号为1fC4y1h7HR的视频属性抓取结束
# 开始BV号为1cK411H7fC视频属性的抓取
# BV号为1cK411H7fC的视频属性抓取结束
# 开始BV号为1rg4y1q7og视频属性的抓取
# BV号为1rg4y1q7og的视频属性抓取结束
# 开始BV号为1Mz4y1X7Rz视频属性的抓取
# BV号为1Mz4y1X7Rz的视频属性抓取结束
# 开始BV号为1Yz4y1Q7g5视频属性的抓取
# BV号为1Yz4y1Q7g5的视频属性抓取结束
# 开始BV号为1LZ4y1H7eX视频属性的抓取
# BV号为1LZ4y1H7eX的视频属性抓取结束
# 开始BV号为13K4y147v6视频属性的抓取
# BV号为13K4y147v6的视频属性抓取结束
# 开始BV号为15t4y197SZ视频属性的抓取
# BV号为15t4y197SZ的视频属性抓取结束
# 开始BV号为1pz4y1X7Tj视频属性的抓取
# BV号为1pz4y1X7Tj的视频属性抓取结束
# 开始BV号为1QA411v71A视频属性的抓取
# BV号为1QA411v71A的视频属性抓取结束
# 开始BV号为1vK4y1x721视频属性的抓取
# 开始BV号为1vK4y1x721视频属性的抓取
# BV号为1vK4y1x721的视频属性抓取结束
# 开始BV号为1FD4y1Q7Nn视频属性的抓取
# BV号为1FD4y1Q7Nn的视频属性抓取结束
# 开始BV号为1Sk4y1q7z9视频属性的抓取
# BV号为1Sk4y1q7z9的视频属性抓取结束
# 开始BV号为1Jv41167r1视频属性的抓取
# BV号为1Jv41167r1的视频属性抓取结束
# 开始BV号为1Kt4y1y7MA视频属性的抓取
# BV号为1Kt4y1y7MA的视频属性抓取结束
# 开始BV号为1wD4y1Q72U视频属性的抓取
# BV号为1wD4y1Q72U的视频属性抓取结束
# 开始BV号为1qC4y1a7Tt视频属性的抓取
# BV号为1qC4y1a7Tt的视频属性抓取结束
# 开始BV号为1uz4y1X7LC视频属性的抓取
# BV号为1uz4y1X7LC的视频属性抓取结束
# 开始BV号为1GK411p7qd视频属性的抓取
# BV号为1GK411p7qd的视频属性抓取结束
# 开始BV号为1Di4y1s7Cq视频属性的抓取
# BV号为1Di4y1s7Cq的视频属性抓取结束
# 开始BV号为1Vz4y1X7rC视频属性的抓取
# BV号为1Vz4y1X7rC的视频属性抓取结束
# 开始BV号为19k4y1z7tU视频属性的抓取
# BV号为19k4y1z7tU的视频属性抓取结束
# 开始BV号为1SK411p7PP视频属性的抓取
# BV号为1SK411p7PP的视频属性抓取结束
# 开始BV号为1Kp4y1Q7nQ视频属性的抓取
# BV号为1Kp4y1Q7nQ的视频属性抓取结束
# 开始BV号为1Yt4y1979G视频属性的抓取
# BV号为1Yt4y1979G的视频属性抓取结束
# 开始BV号为1Xz4y1976B视频属性的抓取
# BV号为1Xz4y1976B的视频属性抓取结束
# 开始BV号为1Dp4y1U7r9视频属性的抓取
# BV号为1Dp4y1U7r9的视频属性抓取结束
# 开始BV号为1J5411W7Cn视频属性的抓取
# BV号为1J5411W7Cn的视频属性抓取结束
# 开始BV号为1At4y197Ec视频属性的抓取
# BV号为1At4y197Ec的视频属性抓取结束
# 开始BV号为1YT4y1J7mW视频属性的抓取
# BV号为1YT4y1J7mW的视频属性抓取结束
# 开始BV号为1iz411i7HA视频属性的抓取
# BV号为1iz411i7HA的视频属性抓取结束
# 开始BV号为1ck4y167VL视频属性的抓取
# BV号为1ck4y167VL的视频属性抓取结束
# 开始BV号为1ya4y1E72V视频属性的抓取
# BV号为1ya4y1E72V的视频属性抓取结束
# 开始BV号为1MT4y1j7Lo视频属性的抓取
# 开始BV号为1MT4y1j7Lo视频属性的抓取
# 开始BV号为1MT4y1j7Lo视频属性的抓取
# BV号为1MT4y1j7Lo的视频属性抓取结束
# 开始BV号为1hT4y1E7qj视频属性的抓取
# BV号为1hT4y1E7qj的视频属性抓取结束
# 开始BV号为1za4y1a7mq视频属性的抓取
# 开始BV号为1za4y1a7mq视频属性的抓取
# BV号为1za4y1a7mq的视频属性抓取结束
# 开始BV号为1KD4y1U7gN视频属性的抓取
# BV号为1KD4y1U7gN的视频属性抓取结束
# 开始BV号为1ii4y137Q6视频属性的抓取
# BV号为1ii4y137Q6的视频属性抓取结束
# 开始BV号为1cA411v7pT视频属性的抓取
# BV号为1cA411v7pT的视频属性抓取结束
# 开始BV号为17i4y1V7Nx视频属性的抓取
# BV号为17i4y1V7Nx的视频属性抓取结束
# 开始BV号为1vh411Z7UY视频属性的抓取
# BV号为1vh411Z7UY的视频属性抓取结束
# 开始BV号为1NZ4y1p77Z视频属性的抓取
# BV号为1NZ4y1p77Z的视频属性抓取结束
# 开始BV号为1XT4y1778W视频属性的抓取
# BV号为1XT4y1778W的视频属性抓取结束
# 开始BV号为1pf4y117BS视频属性的抓取
# BV号为1pf4y117BS的视频属性抓取结束
# 开始BV号为1TT4y1j7mW视频属性的抓取
# BV号为1TT4y1j7mW的视频属性抓取结束
# 开始BV号为1wg4y1i7jn视频属性的抓取
# BV号为1wg4y1i7jn的视频属性抓取结束
# 开始BV号为1Y5411Y7rH视频属性的抓取
# BV号为1Y5411Y7rH的视频属性抓取结束
# 开始BV号为1Xf4y1R7Cn视频属性的抓取
# BV号为1Xf4y1R7Cn的视频属性抓取结束
# 开始BV号为1N54y1q7sA视频属性的抓取
# BV号为1N54y1q7sA的视频属性抓取结束
# 开始BV号为18C4y1b7q3视频属性的抓取
# BV号为18C4y1b7q3的视频属性抓取结束
# 开始BV号为1iZ4y1T7yB视频属性的抓取
# BV号为1iZ4y1T7yB的视频属性抓取结束
# 开始BV号为1ip4y1i7Wp视频属性的抓取
# BV号为1ip4y1i7Wp的视频属性抓取结束
# 开始BV号为1H5411e7vU视频属性的抓取
# BV号为1H5411e7vU的视频属性抓取结束
# 开始BV号为1MZ4y1u7fT视频属性的抓取
# BV号为1MZ4y1u7fT的视频属性抓取结束
# 开始BV号为1CK4y147Tt视频属性的抓取
# BV号为1CK4y147Tt的视频属性抓取结束
# 开始BV号为14V41167xv视频属性的抓取
# BV号为14V41167xv的视频属性抓取结束
# 开始BV号为1Zp4y1i7k8视频属性的抓取
# BV号为1Zp4y1i7k8的视频属性抓取结束
# 开始BV号为1Tz4y1Q7ho视频属性的抓取
# BV号为1Tz4y1Q7ho的视频属性抓取结束
# 开始BV号为1HA411v7iv视频属性的抓取
# BV号为1HA411v7iv的视频属性抓取结束
# 开始BV号为1TT4y1E7Xy视频属性的抓取
# BV号为1TT4y1E7Xy的视频属性抓取结束
# 开始BV号为1454y1S7ig视频属性的抓取
# BV号为1454y1S7ig的视频属性抓取结束
# 开始BV号为1rv411q7La视频属性的抓取
# BV号为1rv411q7La的视频属性抓取结束
# 开始BV号为1GC4y1h76k视频属性的抓取
# BV号为1GC4y1h76k的视频属性抓取结束
# 开始BV号为1BV4116728视频属性的抓取
# BV号为1BV4116728的视频属性抓取结束
# 开始BV号为18z4y1Q73Z视频属性的抓取
# BV号为18z4y1Q73Z的视频属性抓取结束
# 开始BV号为1xk4y1B7Lu视频属性的抓取
# BV号为1xk4y1B7Lu的视频属性抓取结束
# 开始BV号为1rV411B7d1视频属性的抓取
# BV号为1rV411B7d1的视频属性抓取结束
# 开始BV号为1mZ4y1u7y8视频属性的抓取
# BV号为1mZ4y1u7y8的视频属性抓取结束
# 开始BV号为1yz4y1D71x视频属性的抓取
# BV号为1yz4y1D71x的视频属性抓取结束
# 开始BV号为14C4y1h7JK视频属性的抓取
# BV号为14C4y1h7JK的视频属性抓取结束
# 开始BV号为1q54y1q797视频属性的抓取
# BV号为1q54y1q797的视频属性抓取结束
# 开始BV号为1Sk4y1q7YB视频属性的抓取
# BV号为1Sk4y1q7YB的视频属性抓取结束
# 开始BV号为1ST4y177EW视频属性的抓取
# BV号为1ST4y177EW的视频属性抓取结束
# 开始BV号为1UK4y1s7dH视频属性的抓取
# BV号为1UK4y1s7dH的视频属性抓取结束
# 开始BV号为1ha4y1a7C1视频属性的抓取
# BV号为1ha4y1a7C1的视频属性抓取结束
# 开始BV号为1JK4y1x7Mf视频属性的抓取
# BV号为1JK4y1x7Mf的视频属性抓取结束
# 开始BV号为1oV411671s视频属性的抓取
# BV号为1oV411671s的视频属性抓取结束
# 开始BV号为1af4y117oW视频属性的抓取
# BV号为1af4y117oW的视频属性抓取结束
# 开始BV号为1LK411n7d9视频属性的抓取
# BV号为1LK411n7d9的视频属性抓取结束
# 开始BV号为1c54y1z7QG视频属性的抓取
# BV号为1c54y1z7QG的视频属性抓取结束
# 开始BV号为1Qa4y1Y7vF视频属性的抓取
# BV号为1Qa4y1Y7vF的视频属性抓取结束
# 开始BV号为15v411v7wa视频属性的抓取
# BV号为15v411v7wa的视频属性抓取结束
# 开始BV号为1P5411a7ch视频属性的抓取
# BV号为1P5411a7ch的视频属性抓取结束
# 开始BV号为1854y1z7PY视频属性的抓取
# BV号为1854y1z7PY的视频属性抓取结束
# 开始BV号为1LA411Y7Sc视频属性的抓取
# BV号为1LA411Y7Sc的视频属性抓取结束
# 开始BV号为1kp4y1i78G视频属性的抓取
# BV号为1kp4y1i78G的视频属性抓取结束
# 开始BV号为1fA411e77U视频属性的抓取
# BV号为1fA411e77U的视频属性抓取结束
# 开始BV号为1pt4y1D73a视频属性的抓取
# BV号为1pt4y1D73a的视频属性抓取结束
# 开始BV号为1854y1v7BL视频属性的抓取
# BV号为1854y1v7BL的视频属性抓取结束
# 开始BV号为1Mt4y1D7yL视频属性的抓取
# BV号为1Mt4y1D7yL的视频属性抓取结束
# 开始BV号为1kC4y1b7aw视频属性的抓取
# BV号为1kC4y1b7aw的视频属性抓取结束
# 开始BV号为1nD4y1D7U9视频属性的抓取
# BV号为1nD4y1D7U9的视频属性抓取结束
# 开始BV号为1ig4y1v76W视频属性的抓取
# BV号为1ig4y1v76W的视频属性抓取结束
# 开始BV号为14h411o7eZ视频属性的抓取
# BV号为14h411o7eZ的视频属性抓取结束
# 开始BV号为12K411n7fL视频属性的抓取
# BV号为12K411n7fL的视频属性抓取结束
# 开始BV号为1yv411q7ip视频属性的抓取
# BV号为1yv411q7ip的视频属性抓取结束
# 开始BV号为1aA411v7G8视频属性的抓取
# BV号为1aA411v7G8的视频属性抓取结束
# 开始BV号为1ez4y1D74j视频属性的抓取
# BV号为1ez4y1D74j的视频属性抓取结束
# 开始BV号为1gV411r7AC视频属性的抓取
# BV号为1gV411r7AC的视频属性抓取结束
# 开始BV号为1Kv411q7BM视频属性的抓取
# BV号为1Kv411q7BM的视频属性抓取结束
# 开始BV号为1ok4y1q7Dx视频属性的抓取
# BV号为1ok4y1q7Dx的视频属性抓取结束
# 开始BV号为1N5411Y7gb视频属性的抓取
# BV号为1N5411Y7gb的视频属性抓取结束
# 开始BV号为1tg4y1v7ai视频属性的抓取
# BV号为1tg4y1v7ai的视频属性抓取结束
# 开始BV号为1uz4y1X73i视频属性的抓取
# BV号为1uz4y1X73i的视频属性抓取结束
# 开始BV号为1A5411Y74c视频属性的抓取
# BV号为1A5411Y74c的视频属性抓取结束
# 开始BV号为1EC4y1b7ir视频属性的抓取
# BV号为1EC4y1b7ir的视频属性抓取结束
# 开始BV号为12A411e76W视频属性的抓取
# BV号为12A411e76W的视频属性抓取结束
# 开始BV号为1of4y1X7TS视频属性的抓取
# BV号为1of4y1X7TS的视频属性抓取结束
# 开始BV号为1fZ4y1H7Qb视频属性的抓取
# BV号为1fZ4y1H7Qb的视频属性抓取结束
# 开始BV号为16z4y1D7Fu视频属性的抓取
# BV号为16z4y1D7Fu的视频属性抓取结束
# 开始BV号为1xt4y1Q7jL视频属性的抓取
# BV号为1xt4y1Q7jL的视频属性抓取结束
# 开始BV号为1J54y1q7ae视频属性的抓取
# BV号为1J54y1q7ae的视频属性抓取结束
# 开始BV号为1ct4y1X7fQ视频属性的抓取
# BV号为1ct4y1X7fQ的视频属性抓取结束
# 开始BV号为19v411i7fq视频属性的抓取
# BV号为19v411i7fq的视频属性抓取结束
# 开始BV号为1kD4y1S7YP视频属性的抓取
# BV号为1kD4y1S7YP的视频属性抓取结束
# 开始BV号为1A5411e7p9视频属性的抓取
# BV号为1A5411e7p9的视频属性抓取结束
# 开始BV号为1WA411v7SK视频属性的抓取
# BV号为1WA411v7SK的视频属性抓取结束
# 开始BV号为1Ha4y1a7Y5视频属性的抓取
# BV号为1Ha4y1a7Y5的视频属性抓取结束
# 开始BV号为13K4y1x7Ua视频属性的抓取
# BV号为13K4y1x7Ua的视频属性抓取结束
# 开始BV号为1zD4y1S7zU视频属性的抓取
# BV号为1zD4y1S7zU的视频属性抓取结束
# 开始BV号为1UA411i75H视频属性的抓取
# BV号为1UA411i75H的视频属性抓取结束
# 开始BV号为1JK411J7Si视频属性的抓取
# BV号为1JK411J7Si的视频属性抓取结束
# 开始BV号为1KV411r7JB视频属性的抓取
# BV号为1KV411r7JB的视频属性抓取结束
# 开始BV号为1za4y1a7qB视频属性的抓取
# BV号为1za4y1a7qB的视频属性抓取结束
# 开始BV号为1Z5411Y7jn视频属性的抓取
# BV号为1Z5411Y7jn的视频属性抓取结束
# 开始BV号为1XZ4y1u7fn视频属性的抓取
# BV号为1XZ4y1u7fn的视频属性抓取结束
# 开始BV号为1ak4y1B7uU视频属性的抓取
# BV号为1ak4y1B7uU的视频属性抓取结束
# 开始BV号为1kk4y1q7fH视频属性的抓取
# BV号为1kk4y1q7fH的视频属性抓取结束
# 开始BV号为1w54y1z7R9视频属性的抓取
# BV号为1w54y1z7R9的视频属性抓取结束
# 开始BV号为1vK411J7in视频属性的抓取
# BV号为1vK411J7in的视频属性抓取结束
# 开始BV号为1gp4y1q7S2视频属性的抓取
# BV号为1gp4y1q7S2的视频属性抓取结束
# 开始BV号为1zt4y1X719视频属性的抓取
# BV号为1zt4y1X719的视频属性抓取结束
# 开始BV号为1354y1i7bB视频属性的抓取
# BV号为1354y1i7bB的视频属性抓取结束
# 开始BV号为1w64y1F7My视频属性的抓取
# BV号为1w64y1F7My的视频属性抓取结束
# 开始BV号为1Ef4y197aR视频属性的抓取
# BV号为1Ef4y197aR的视频属性抓取结束
# 开始BV号为1Cp4y1v7hT视频属性的抓取
# BV号为1Cp4y1v7hT的视频属性抓取结束
# 开始BV号为1ap4y1v7Xt视频属性的抓取
# BV号为1ap4y1v7Xt的视频属性抓取结束
# 开始BV号为1Gh411R7kW视频属性的抓取
# BV号为1Gh411R7kW的视频属性抓取结束
# 开始BV号为1Rf4y1X7Df视频属性的抓取
# BV号为1Rf4y1X7Df的视频属性抓取结束
# 开始BV号为1Ap4y1v7ek视频属性的抓取
# BV号为1Ap4y1v7ek的视频属性抓取结束
# 开始BV号为1NT4y177TM视频属性的抓取
# BV号为1NT4y177TM的视频属性抓取结束
# 开始BV号为1LD4y1U7v5视频属性的抓取
# BV号为1LD4y1U7v5的视频属性抓取结束
# 开始BV号为15p4y1v7YN视频属性的抓取
# BV号为15p4y1v7YN的视频属性抓取结束
# 开始BV号为1NK411M7pP视频属性的抓取
# BV号为1NK411M7pP的视频属性抓取结束
# 开始BV号为1oA411Y7MT视频属性的抓取
# BV号为1oA411Y7MT的视频属性抓取结束
# 开始BV号为1mv411q7ep视频属性的抓取
# BV号为1mv411q7ep的视频属性抓取结束
# 开始BV号为1FT4y1L7ut视频属性的抓取
# BV号为1FT4y1L7ut的视频属性抓取结束
# 开始BV号为1D541187ea视频属性的抓取
# BV号为1D541187ea的视频属性抓取结束
# 开始BV号为1YD4y1U7YV视频属性的抓取
# BV号为1YD4y1U7YV的视频属性抓取结束
# 开始BV号为1Qv411y7Me视频属性的抓取
# BV号为1Qv411y7Me的视频属性抓取结束
# 开始BV号为17K4y1Y75c视频属性的抓取
# BV号为17K4y1Y75c的视频属性抓取结束
# 开始BV号为1oy4y1C77U视频属性的抓取
# BV号为1oy4y1C77U的视频属性抓取结束
# 开始BV号为1fk4y117Ap视频属性的抓取
# BV号为1fk4y117Ap的视频属性抓取结束
# 开始BV号为11v411q7HJ视频属性的抓取
# BV号为11v411q7HJ的视频属性抓取结束
# 开始BV号为1gp4y1q7dz视频属性的抓取
# BV号为1gp4y1q7dz的视频属性抓取结束
# 开始BV号为1H54y1e7Pv视频属性的抓取
# BV号为1H54y1e7Pv的视频属性抓取结束
# 开始BV号为1f54y1e7uY视频属性的抓取
# BV号为1f54y1e7uY的视频属性抓取结束
# 开始BV号为1Et4y1Q7wY视频属性的抓取
# BV号为1Et4y1Q7wY的视频属性抓取结束
# 开始BV号为13D4y1U75y视频属性的抓取
# BV号为13D4y1U75y的视频属性抓取结束
# 开始BV号为1uf4y197S8视频属性的抓取
# BV号为1uf4y197S8的视频属性抓取结束
# 开始BV号为1kh411d7VX视频属性的抓取
# BV号为1kh411d7VX的视频属性抓取结束
# 开始BV号为11V411U7ND视频属性的抓取
# BV号为11V411U7ND的视频属性抓取结束
# 开始BV号为1jz4y1f7pV视频属性的抓取
# BV号为1jz4y1f7pV的视频属性抓取结束
# 开始BV号为1dD4y1m7Tv视频属性的抓取
# BV号为1dD4y1m7Tv的视频属性抓取结束
# 开始BV号为1s54y1i7wa视频属性的抓取
# BV号为1s54y1i7wa的视频属性抓取结束
# 开始BV号为1iD4y1U76A视频属性的抓取
# BV号为1iD4y1U76A的视频属性抓取结束
# 开始BV号为15i4y1g7zm视频属性的抓取
# BV号为15i4y1g7zm的视频属性抓取结束
# 开始BV号为1Gk4y1y7yW视频属性的抓取
# BV号为1Gk4y1y7yW的视频属性抓取结束
# 开始BV号为12V411z7ip视频属性的抓取
# BV号为12V411z7ip的视频属性抓取结束
# 开始BV号为1TZ4y1M7i9视频属性的抓取
# BV号为1TZ4y1M7i9的视频属性抓取结束
# 开始BV号为1y54y1m7jZ视频属性的抓取
# BV号为1y54y1m7jZ的视频属性抓取结束
# 开始BV号为1KA411e7mi视频属性的抓取
# BV号为1KA411e7mi的视频属性抓取结束
# 开始BV号为1v64y1F7pS视频属性的抓取
# BV号为1v64y1F7pS的视频属性抓取结束
# 开始BV号为1Sf4y1X7Cq视频属性的抓取
# BV号为1Sf4y1X7Cq的视频属性抓取结束
# 开始BV号为1AZ4y1T7zh视频属性的抓取
# BV号为1AZ4y1T7zh的视频属性抓取结束
# 开始BV号为19Z4y1K79e视频属性的抓取
# BV号为19Z4y1K79e的视频属性抓取结束
# 开始BV号为1wp4y1i7Ya视频属性的抓取
# BV号为1wp4y1i7Ya的视频属性抓取结束
# 开始BV号为1LK411K7Co视频属性的抓取
# BV号为1LK411K7Co的视频属性抓取结束
# 开始BV号为1bK4y1e7Wq视频属性的抓取
# BV号为1bK4y1e7Wq的视频属性抓取结束
# 开始BV号为1AK4y1e7br视频属性的抓取
# BV号为1AK4y1e7br的视频属性抓取结束
# 开始BV号为1mh411d7zi视频属性的抓取
# BV号为1mh411d7zi的视频属性抓取结束
# 开始BV号为1zK4y1v7Dd视频属性的抓取
# BV号为1zK4y1v7Dd的视频属性抓取结束
# 开始BV号为1Ck4y1m7nB视频属性的抓取
# BV号为1Ck4y1m7nB的视频属性抓取结束
# 开始BV号为1454y1U7qh视频属性的抓取
# BV号为1454y1U7qh的视频属性抓取结束
# 开始BV号为1fD4y127ef视频属性的抓取
# BV号为1fD4y127ef的视频属性抓取结束
# 开始BV号为1d54y1v7JE视频属性的抓取
# BV号为1d54y1v7JE的视频属性抓取结束
# 开始BV号为1Wz4y1f76N视频属性的抓取
# BV号为1Wz4y1f76N的视频属性抓取结束
# 开始BV号为1Lh411R7DS视频属性的抓取
# BV号为1Lh411R7DS的视频属性抓取结束
# 开始BV号为1K5411b79g视频属性的抓取
# BV号为1K5411b79g的视频属性抓取结束
# 开始BV号为1Rf4y1Q7xd视频属性的抓取
# BV号为1Rf4y1Q7xd的视频属性抓取结束
# 开始BV号为1zk4y127S8视频属性的抓取
# BV号为1zk4y127S8的视频属性抓取结束
# 开始BV号为13h411o7sz视频属性的抓取
# BV号为13h411o7sz的视频属性抓取结束
# 开始BV号为1gh411d7sp视频属性的抓取
# BV号为1gh411d7sp的视频属性抓取结束
# 开始BV号为15a4y1J7fw视频属性的抓取
# BV号为15a4y1J7fw的视频属性抓取结束
# 开始BV号为1uC4y1t7YZ视频属性的抓取
# BV号为1uC4y1t7YZ的视频属性抓取结束
# 开始BV号为1t5411a7YP视频属性的抓取
# BV号为1t5411a7YP的视频属性抓取结束
# 开始BV号为1BT4y1j7Ds视频属性的抓取
# BV号为1BT4y1j7Ds的视频属性抓取结束
# 开始BV号为1Eh411Z7kd视频属性的抓取
# BV号为1Eh411Z7kd的视频属性抓取结束
# 开始BV号为1BV411z7ib视频属性的抓取
# BV号为1BV411z7ib的视频属性抓取结束
# 开始BV号为1JA411n7Be视频属性的抓取
# BV号为1JA411n7Be的视频属性抓取结束
# 开始BV号为1Hp4y1v7if视频属性的抓取
# BV号为1Hp4y1v7if的视频属性抓取结束
# 开始BV号为1UA411J7Na视频属性的抓取
# BV号为1UA411J7Na的视频属性抓取结束
# 开始BV号为1oz4y1f7FX视频属性的抓取
# BV号为1oz4y1f7FX的视频属性抓取结束
# 开始BV号为1tK4y1v7HW视频属性的抓取
# BV号为1tK4y1v7HW的视频属性抓取结束
# 开始BV号为1V5411b7pf视频属性的抓取
# BV号为1V5411b7pf的视频属性抓取结束
# 开始BV号为1uK411M796视频属性的抓取
# BV号为1uK411M796的视频属性抓取结束
# 开始BV号为1nV411S7F5视频属性的抓取
# BV号为1nV411S7F5的视频属性抓取结束
# 开始BV号为1i64y1c73a视频属性的抓取
# BV号为1i64y1c73a的视频属性抓取结束
# 开始BV号为1vh411Z7U3视频属性的抓取
# BV号为1vh411Z7U3的视频属性抓取结束
# 开始BV号为1na4y1E7ns视频属性的抓取
# BV号为1na4y1E7ns的视频属性抓取结束
# 开始BV号为1kK4y1Y7Jz视频属性的抓取
# BV号为1kK4y1Y7Jz的视频属性抓取结束
# 开始BV号为1kD4y127CA视频属性的抓取
# BV号为1kD4y127CA的视频属性抓取结束
# 开始BV号为1Zk4y117Ba视频属性的抓取
# BV号为1Zk4y117Ba的视频属性抓取结束
# 开始BV号为1aK4y1Y78e视频属性的抓取
# BV号为1aK4y1Y78e的视频属性抓取结束
# 开始BV号为1UK4y1v7RB视频属性的抓取
# BV号为1UK4y1v7RB的视频属性抓取结束
# 开始BV号为1MK411T7rH视频属性的抓取
# BV号为1MK411T7rH的视频属性抓取结束
# 开始BV号为12y4y1C7cJ视频属性的抓取
# BV号为12y4y1C7cJ的视频属性抓取结束
# 开始BV号为19h41197QY视频属性的抓取
# BV号为19h41197QY的视频属性抓取结束
# 开始BV号为1Rh4119793视频属性的抓取
# BV号为1Rh4119793的视频属性抓取结束
# 开始BV号为1Yp4y1q7x1视频属性的抓取
# BV号为1Yp4y1q7x1的视频属性抓取结束
# 开始BV号为1Gk4y1y7Qk视频属性的抓取
# BV号为1Gk4y1y7Qk的视频属性抓取结束
# 开始BV号为17C4y1871t视频属性的抓取
# 开始BV号为17C4y1871t视频属性的抓取
# BV号为17C4y1871t的视频属性抓取结束
# 开始BV号为1b541187Sg视频属性的抓取
# BV号为1b541187Sg的视频属性抓取结束
# 开始BV号为1zk4y117Ah视频属性的抓取
# BV号为1zk4y117Ah的视频属性抓取结束
# 开始BV号为1qv411v7cW视频属性的抓取
# BV号为1qv411v7cW的视频属性抓取结束
# 开始BV号为1MK411M7qV视频属性的抓取
# BV号为1MK411M7qV的视频属性抓取结束
# 开始BV号为1op4y1Y75u视频属性的抓取
# BV号为1op4y1Y75u的视频属性抓取结束
# 开始BV号为1P64y1F7CV视频属性的抓取
# BV号为1P64y1F7CV的视频属性抓取结束
# 开始BV号为1M5411b7eT视频属性的抓取
# BV号为1M5411b7eT的视频属性抓取结束
# 开始BV号为1BZ4y1N7MA视频属性的抓取
# BV号为1BZ4y1N7MA的视频属性抓取结束
# 开始BV号为1Ci4y1E7xn视频属性的抓取
# BV号为1Ci4y1E7xn的视频属性抓取结束
# 开始BV号为15T4y1c7Yx视频属性的抓取
# BV号为15T4y1c7Yx的视频属性抓取结束
# 开始BV号为1aD4y1o7jx视频属性的抓取
# BV号为1aD4y1o7jx的视频属性抓取结束
# 开始BV号为1vk4y127ZB视频属性的抓取
# BV号为1vk4y127ZB的视频属性抓取结束
# 开始BV号为1W54y1m7TK视频属性的抓取
# BV号为1W54y1m7TK的视频属性抓取结束
# 开始BV号为1gf4y1D7JX视频属性的抓取
# BV号为1gf4y1D7JX的视频属性抓取结束
# 开始BV号为1tf4y1D75w视频属性的抓取
# BV号为1tf4y1D75w的视频属性抓取结束
# 开始BV号为1a64y1F7Kw视频属性的抓取
# BV号为1a64y1F7Kw的视频属性抓取结束
# 开始BV号为1dK411N7Fu视频属性的抓取
# BV号为1dK411N7Fu的视频属性抓取结束
# 开始BV号为1iD4y1o7Ba视频属性的抓取
# BV号为1iD4y1o7Ba的视频属性抓取结束
# 开始BV号为1di4y1M7fE视频属性的抓取
# BV号为1di4y1M7fE的视频属性抓取结束
# 开始BV号为165411b7ko视频属性的抓取
# BV号为165411b7ko的视频属性抓取结束
# 开始BV号为1ip4y1e7wc视频属性的抓取
# BV号为1ip4y1e7wc的视频属性抓取结束
# 开始BV号为1j64y1F7y7视频属性的抓取
# BV号为1j64y1F7y7的视频属性抓取结束
# 开始BV号为1Bv41117mL视频属性的抓取
# BV号为1Bv41117mL的视频属性抓取结束
# 开始BV号为1Hi4y1u7E8视频属性的抓取
# BV号为1Hi4y1u7E8的视频属性抓取结束
# 开始BV号为1yv41117rG视频属性的抓取
# BV号为1yv41117rG的视频属性抓取结束
# 开始BV号为1BD4y1o7mx视频属性的抓取
# BV号为1BD4y1o7mx的视频属性抓取结束
# 开始BV号为1k5411j78b视频属性的抓取
# BV号为1k5411j78b的视频属性抓取结束
# 开始BV号为1ih411R7Zx视频属性的抓取
# BV号为1ih411R7Zx的视频属性抓取结束
# 开始BV号为1t64y1F7Wk视频属性的抓取
# BV号为1t64y1F7Wk的视频属性抓取结束
# 开始BV号为1Gt4y1q7py视频属性的抓取
# BV号为1Gt4y1q7py的视频属性抓取结束
# 开始BV号为1da4y1j7tG视频属性的抓取
# BV号为1da4y1j7tG的视频属性抓取结束
# 开始BV号为1oi4y1771k视频属性的抓取
# BV号为1oi4y1771k的视频属性抓取结束
# 开始BV号为1Z54y1e7Ls视频属性的抓取
# BV号为1Z54y1e7Ls的视频属性抓取结束
# 开始BV号为1Lp4y1i76r视频属性的抓取
# BV号为1Lp4y1i76r的视频属性抓取结束
# 开始BV号为1hZ4y1N78C视频属性的抓取
# BV号为1hZ4y1N78C的视频属性抓取结束
# 开始BV号为1zV411m7Rf视频属性的抓取
# BV号为1zV411m7Rf的视频属性抓取结束
# 开始BV号为1Dv411y7Q6视频属性的抓取
# BV号为1Dv411y7Q6的视频属性抓取结束
# 开始BV号为1LK411M7NE视频属性的抓取
# BV号为1LK411M7NE的视频属性抓取结束
# 开始BV号为1F64y1F7GR视频属性的抓取
# BV号为1F64y1F7GR的视频属性抓取结束
# 开始BV号为1F54y1m7Gt视频属性的抓取
# BV号为1F54y1m7Gt的视频属性抓取结束
# 开始BV号为1Y54y1m7Jb视频属性的抓取
# BV号为1Y54y1m7Jb的视频属性抓取结束
# 开始BV号为1hz4y1Z7Ym视频属性的抓取
# BV号为1hz4y1Z7Ym的视频属性抓取结束
# 开始BV号为1pi4y1E7vz视频属性的抓取
# BV号为1pi4y1E7vz的视频属性抓取结束
# 开始BV号为1kV41127R2视频属性的抓取
# BV号为1kV41127R2的视频属性抓取结束
# 开始BV号为17Z4y1N7yq视频属性的抓取
# BV号为17Z4y1N7yq的视频属性抓取结束
# 开始BV号为12t4y1i75b视频属性的抓取
# BV号为12t4y1i75b的视频属性抓取结束
# 开始BV号为12v411C7Mf视频属性的抓取
# BV号为12v411C7Mf的视频属性抓取结束
# 开始BV号为1Si4y177SE视频属性的抓取
# BV号为1Si4y177SE的视频属性抓取结束
# 开始BV号为1fC4y1t7n2视频属性的抓取
# BV号为1fC4y1t7n2的视频属性抓取结束
# 开始BV号为1Zk4y1y7zt视频属性的抓取
# BV号为1Zk4y1y7zt的视频属性抓取结束
# 开始BV号为1AC4y1b7vW视频属性的抓取
# BV号为1AC4y1b7vW的视频属性抓取结束
# 开始BV号为1Zf4y1S7EY视频属性的抓取
# BV号为1Zf4y1S7EY的视频属性抓取结束
# 开始BV号为1Ch411R7J7视频属性的抓取
# BV号为1Ch411R7J7的视频属性抓取结束
# 开始BV号为1oA411E7RB视频属性的抓取
# BV号为1oA411E7RB的视频属性抓取结束
# 开始BV号为12t4y1S7Z4视频属性的抓取
# BV号为12t4y1S7Z4的视频属性抓取结束
# 开始BV号为1xz4y1Z7AQ视频属性的抓取
# BV号为1xz4y1Z7AQ的视频属性抓取结束
# 开始BV号为1Dy4y1C7d1视频属性的抓取
# BV号为1Dy4y1C7d1的视频属性抓取结束
# 开始BV号为1Jf4y1X7k9视频属性的抓取
# BV号为1Jf4y1X7k9的视频属性抓取结束
# 开始BV号为1Jh411R75D视频属性的抓取
# BV号为1Jh411R75D的视频属性抓取结束
# 开始BV号为14i4y1M7Qd视频属性的抓取
# BV号为14i4y1M7Qd的视频属性抓取结束
# 开始BV号为1Ah41197tP视频属性的抓取
# BV号为1Ah41197tP的视频属性抓取结束
# 开始BV号为1o54y1y7Ee视频属性的抓取
# BV号为1o54y1y7Ee的视频属性抓取结束
# 开始BV号为1HD4y1o76X视频属性的抓取
# BV号为1HD4y1o76X的视频属性抓取结束
# 开始BV号为1Kf4y1D7aw视频属性的抓取
# BV号为1Kf4y1D7aw的视频属性抓取结束
# 开始BV号为1Sp4y1e74A视频属性的抓取
# BV号为1Sp4y1e74A的视频属性抓取结束
# 开始BV号为1mt4y1i7Zr视频属性的抓取
# BV号为1mt4y1i7Zr的视频属性抓取结束
# 开始BV号为1ay4y1y797视频属性的抓取
# BV号为1ay4y1y797的视频属性抓取结束
# 开始BV号为1Fz4y1Z7Gr视频属性的抓取
# BV号为1Fz4y1Z7Gr的视频属性抓取结束
# 开始BV号为1xA411E77s视频属性的抓取
# BV号为1xA411E77s的视频属性抓取结束
# 开始BV号为1mf4y1Q7p6视频属性的抓取
# BV号为1mf4y1Q7p6的视频属性抓取结束
# 开始BV号为1t64y1F7SG视频属性的抓取
# BV号为1t64y1F7SG的视频属性抓取结束
# 开始BV号为18f4y1X7hA视频属性的抓取
# 开始BV号为18f4y1X7hA视频属性的抓取
# BV号为18f4y1X7hA的视频属性抓取结束
# 开始BV号为135411b7cR视频属性的抓取
# BV号为135411b7cR的视频属性抓取结束
# 开始BV号为1Z54y1y7Ed视频属性的抓取
# BV号为1Z54y1y7Ed的视频属性抓取结束
# 开始BV号为18a4y1j7R3视频属性的抓取
# BV号为18a4y1j7R3的视频属性抓取结束
# 开始BV号为1uD4y1o7BP视频属性的抓取
# BV号为1uD4y1o7BP的视频属性抓取结束
# 开始BV号为1q5411h71J视频属性的抓取
# BV号为1q5411h71J的视频属性抓取结束
# 开始BV号为1Jy4y1y7gM视频属性的抓取
# BV号为1Jy4y1y7gM的视频属性抓取结束
# 开始BV号为1nA411J7jP视频属性的抓取
# BV号为1nA411J7jP的视频属性抓取结束
# 开始BV号为1tt4y1q75z视频属性的抓取
# BV号为1tt4y1q75z的视频属性抓取结束
# 开始BV号为1hA411E7Nn视频属性的抓取
# BV号为1hA411E7Nn的视频属性抓取结束
# 开始BV号为1J54y117zo视频属性的抓取
# BV号为1J54y117zo的视频属性抓取结束
# 开始BV号为1gA411J76Z视频属性的抓取
# BV号为1gA411J76Z的视频属性抓取结束
# 开始BV号为1Rk4y1y7sJ视频属性的抓取
# BV号为1Rk4y1y7sJ的视频属性抓取结束
# 开始BV号为1CV41127e7视频属性的抓取
# BV号为1CV41127e7的视频属性抓取结束
# 开始BV号为1aA411779D视频属性的抓取
# BV号为1aA411779D的视频属性抓取结束
# 开始BV号为13i4y1E71f视频属性的抓取
# BV号为13i4y1E71f的视频属性抓取结束
# 开始BV号为12p4y1a7pr视频属性的抓取
# BV号为12p4y1a7pr的视频属性抓取结束
# 开始BV号为1Ct4y1q7Rs视频属性的抓取
# BV号为1Ct4y1q7Rs的视频属性抓取结束
# 开始BV号为13D4y1o7nc视频属性的抓取
# BV号为13D4y1o7nc的视频属性抓取结束
# 开始BV号为1yy4y1C73E视频属性的抓取
# BV号为1yy4y1C73E的视频属性抓取结束
# 开始BV号为1KZ4y1K7yV视频属性的抓取
# BV号为1KZ4y1K7yV的视频属性抓取结束
# 开始BV号为1pp4y1a7Co视频属性的抓取
# BV号为1pp4y1a7Co的视频属性抓取结束
# 开始BV号为17v411C7zZ视频属性的抓取
# BV号为17v411C7zZ的视频属性抓取结束
# 开始BV号为1Ph411R7cT视频属性的抓取
# BV号为1Ph411R7cT的视频属性抓取结束
# 开始BV号为1UA411E7Dy视频属性的抓取
# BV号为1UA411E7Dy的视频属性抓取结束
# 开始BV号为1Vz4y1Z7wp视频属性的抓取
# BV号为1Vz4y1Z7wp的视频属性抓取结束
# 开始BV号为1zt4y1q7Yj视频属性的抓取
# BV号为1zt4y1q7Yj的视频属性抓取结束
# 开始BV号为1o5411L7HC视频属性的抓取
# BV号为1o5411L7HC的视频属性抓取结束
# 开始BV号为1Pi4y1E74q视频属性的抓取
# BV号为1Pi4y1E74q的视频属性抓取结束
# 开始BV号为1xy4y1y7yu视频属性的抓取
# BV号为1xy4y1y7yu的视频属性抓取结束
# 开始BV号为1MZ4y1T7Q8视频属性的抓取
# BV号为1MZ4y1T7Q8的视频属性抓取结束
# 开始BV号为1sf4y1D7FZ视频属性的抓取
# BV号为1sf4y1D7FZ的视频属性抓取结束
# 开始BV号为1zt4y1S7gb视频属性的抓取
# BV号为1zt4y1S7gb的视频属性抓取结束
# 开始BV号为11y4y1k75g视频属性的抓取
# BV号为11y4y1k75g的视频属性抓取结束
# 开始BV号为1NT4y1F7mj视频属性的抓取
# BV号为1NT4y1F7mj的视频属性抓取结束
# 开始BV号为17v411y7w1视频属性的抓取
# BV号为17v411y7w1的视频属性抓取结束
# 开始BV号为1wK411A7pY视频属性的抓取
# BV号为1wK411A7pY的视频属性抓取结束
# 开始BV号为1G54y1C7Zb视频属性的抓取
# BV号为1G54y1C7Zb的视频属性抓取结束
# 开始BV号为1jA41177t6视频属性的抓取
# BV号为1jA41177t6的视频属性抓取结束
# 开始BV号为1ii4y1E7aH视频属性的抓取
# BV号为1ii4y1E7aH的视频属性抓取结束
# 开始BV号为1ai4y177kE视频属性的抓取
# BV号为1ai4y177kE的视频属性抓取结束
# 开始BV号为1df4y1q7nL视频属性的抓取
# BV号为1df4y1q7nL的视频属性抓取结束
# 开始BV号为17V41127vF视频属性的抓取
# BV号为17V41127vF的视频属性抓取结束
# 开始BV号为15i4y177jn视频属性的抓取
# BV号为15i4y177jn的视频属性抓取结束
# 开始BV号为1Ja4y1L7uZ视频属性的抓取
# BV号为1Ja4y1L7uZ的视频属性抓取结束
# 开始BV号为1fa4y157Du视频属性的抓取
# BV号为1fa4y157Du的视频属性抓取结束
# 开始BV号为1kt4y1v7xD视频属性的抓取
# BV号为1kt4y1v7xD的视频属性抓取结束
# 开始BV号为16p4y1k7yp视频属性的抓取
# BV号为16p4y1k7yp的视频属性抓取结束
# 开始BV号为1Rf4y1D7az视频属性的抓取
# BV号为1Rf4y1D7az的视频属性抓取结束
# 开始BV号为1K54y1r7Xk视频属性的抓取
# 开始BV号为1K54y1r7Xk视频属性的抓取
# BV号为1K54y1r7Xk的视频属性抓取结束
# 开始BV号为1oy4y1r7MR视频属性的抓取
# BV号为1oy4y1r7MR的视频属性抓取结束
# 开始BV号为1tz4y1C77P视频属性的抓取
# BV号为1tz4y1C77P的视频属性抓取结束
# 开始BV号为1ha411A7mK视频属性的抓取
# BV号为1ha411A7mK的视频属性抓取结束
# 开始BV号为1qy4y1C7fS视频属性的抓取
# BV号为1qy4y1C7fS的视频属性抓取结束
# 开始BV号为1vp4y1k7um视频属性的抓取
# BV号为1vp4y1k7um的视频属性抓取结束
# 开始BV号为1gV411y7Bo视频属性的抓取
# BV号为1gV411y7Bo的视频属性抓取结束
# 开始BV号为1My4y187Ak视频属性的抓取
# BV号为1My4y187Ak的视频属性抓取结束
# 开始BV号为1Ey4y1C7ci视频属性的抓取
# BV号为1Ey4y1C7ci的视频属性抓取结束
# 开始BV号为1Py4y1C7QE视频属性的抓取
# BV号为1Py4y1C7QE的视频属性抓取结束
# 开始BV号为1gf4y1q7GS视频属性的抓取
# BV号为1gf4y1q7GS的视频属性抓取结束
# 开始BV号为1P5411L7hY视频属性的抓取
# BV号为1P5411L7hY的视频属性抓取结束
# 开始BV号为1n54y1k7UW视频属性的抓取
# BV号为1n54y1k7UW的视频属性抓取结束
# 开始BV号为1d5411j7HN视频属性的抓取
# BV号为1d5411j7HN的视频属性抓取结束
# 开始BV号为1H54y1R7FV视频属性的抓取
# BV号为1H54y1R7FV的视频属性抓取结束
# 开始BV号为1rt4y1v7ZK视频属性的抓取
# BV号为1rt4y1v7ZK的视频属性抓取结束
# 开始BV号为1mr4y1c7jQ视频属性的抓取
# BV号为1mr4y1c7jQ的视频属性抓取结束
# 开始BV号为17v411y73z视频属性的抓取
# BV号为17v411y73z的视频属性抓取结束
# 开始BV号为1vp4y1k7yh视频属性的抓取
# BV号为1vp4y1k7yh的视频属性抓取结束
# 开始BV号为1Wa411A7oT视频属性的抓取
# BV号为1Wa411A7oT的视频属性抓取结束
# 开始BV号为1k54y1y7Zq视频属性的抓取
# BV号为1k54y1y7Zq的视频属性抓取结束
# 开始BV号为1Th41197U2视频属性的抓取
# BV号为1Th41197U2的视频属性抓取结束
# 开始BV号为1FA411E7YA视频属性的抓取
# BV号为1FA411E7YA的视频属性抓取结束
# 开始BV号为1Ka4y1s7N3视频属性的抓取
# BV号为1Ka4y1s7N3的视频属性抓取结束
# 开始BV号为1SK4y1h7AY视频属性的抓取
# BV号为1SK4y1h7AY的视频属性抓取结束
# 开始BV号为1z54y1R7Ge视频属性的抓取
# BV号为1z54y1R7Ge的视频属性抓取结束
# 开始BV号为1Qt4y1q7v8视频属性的抓取
# BV号为1Qt4y1q7v8的视频属性抓取结束
# 开始BV号为1Li4y177Nq视频属性的抓取
# 开始BV号为1Li4y177Nq视频属性的抓取
# BV号为1Li4y177Nq的视频属性抓取结束
# 开始BV号为1Ra411w7xc视频属性的抓取
# BV号为1Ra411w7xc的视频属性抓取结束
# 开始BV号为1iv41167Hm视频属性的抓取
# BV号为1iv41167Hm的视频属性抓取结束
# 开始BV号为1nZ4y157SD视频属性的抓取
# BV号为1nZ4y157SD的视频属性抓取结束
# 开始BV号为1Pa4y1s7nP视频属性的抓取
# BV号为1Pa4y1s7nP的视频属性抓取结束
# 开始BV号为1Wf4y1B7Um视频属性的抓取
# BV号为1Wf4y1B7Um的视频属性抓取结束
# 开始BV号为1Ry4y1b7DP视频属性的抓取
# BV号为1Ry4y1b7DP的视频属性抓取结束
# 开始BV号为1Ht4y1v7Ed视频属性的抓取
# BV号为1Ht4y1v7Ed的视频属性抓取结束
# 开始BV号为1gD4y197D1视频属性的抓取
# BV号为1gD4y197D1的视频属性抓取结束
# 开始BV号为1FK4y1E7AK视频属性的抓取
# BV号为1FK4y1E7AK的视频属性抓取结束
# 开始BV号为1y54y1R7sn视频属性的抓取
# BV号为1y54y1R7sn的视频属性抓取结束
# 开始BV号为1TZ4y1V7aX视频属性的抓取
# BV号为1TZ4y1V7aX的视频属性抓取结束
# 开始BV号为1yt4y1q78i视频属性的抓取
# BV号为1yt4y1q78i的视频属性抓取结束
# 开始BV号为1if4y1B7r3视频属性的抓取
# BV号为1if4y1B7r3的视频属性抓取结束
# 开始BV号为1BK411N7pA视频属性的抓取
# 开始BV号为1BK411N7pA视频属性的抓取
# BV号为1BK411N7pA的视频属性抓取结束
# 开始BV号为1AA411j7xi视频属性的抓取
# BV号为1AA411j7xi的视频属性抓取结束
# 开始BV号为1Cf4y1i7df视频属性的抓取
# BV号为1Cf4y1i7df的视频属性抓取结束
# 开始BV号为1bi4y1j71E视频属性的抓取
# BV号为1bi4y1j71E的视频属性抓取结束
# 开始BV号为1fi4y1j7ER视频属性的抓取
# BV号为1fi4y1j7ER的视频属性抓取结束
# 开始BV号为1p54y1C7kU视频属性的抓取
# BV号为1p54y1C7kU的视频属性抓取结束
# 开始BV号为15p4y1k7Ca视频属性的抓取
# BV号为15p4y1k7Ca的视频属性抓取结束
# 开始BV号为1Ky4y187cu视频属性的抓取
# BV号为1Ky4y187cu的视频属性抓取结束
# 开始BV号为1DK411G734视频属性的抓取
# BV号为1DK411G734的视频属性抓取结束
# 开始BV号为1Av411C7iG视频属性的抓取
# BV号为1Av411C7iG的视频属性抓取结束
# 开始BV号为1Ma4y1L7Qi视频属性的抓取
# BV号为1Ma4y1L7Qi的视频属性抓取结束
# 开始BV号为15a4y1L7GT视频属性的抓取
# BV号为15a4y1L7GT的视频属性抓取结束
# 开始BV号为1TZ4y1L7iS视频属性的抓取
# 开始BV号为1TZ4y1L7iS视频属性的抓取
# 开始BV号为1TZ4y1L7iS视频属性的抓取
# BV号为1TZ4y1L7iS的视频属性抓取结束
# 开始BV号为1yz4y1o7jT视频属性的抓取
# BV号为1yz4y1o7jT的视频属性抓取结束
# 开始BV号为1ea411A7Hv视频属性的抓取
# BV号为1ea411A7Hv的视频属性抓取结束
# 开始BV号为1sV411y7jJ视频属性的抓取
# BV号为1sV411y7jJ的视频属性抓取结束
# 开始BV号为1Qy4y1B7w9视频属性的抓取
# BV号为1Qy4y1B7w9的视频属性抓取结束
# 开始BV号为1wv411k71w视频属性的抓取
# BV号为1wv411k71w的视频属性抓取结束
# 开始BV号为1cT4y1F7at视频属性的抓取
# BV号为1cT4y1F7at的视频属性抓取结束
# 开始BV号为14D4y1R7cX视频属性的抓取
# BV号为14D4y1R7cX的视频属性抓取结束
# 开始BV号为1fK4y177EG视频属性的抓取
# BV号为1fK4y177EG的视频属性抓取结束
# 开始BV号为1Bp4y1Y7oL视频属性的抓取
# BV号为1Bp4y1Y7oL的视频属性抓取结束
# 开始BV号为1UK4y1f7if视频属性的抓取
# BV号为1UK4y1f7if的视频属性抓取结束
# 开始BV号为19541157B5视频属性的抓取
# BV号为19541157B5的视频属性抓取结束
# 开始BV号为1X541157XW视频属性的抓取
# BV号为1X541157XW的视频属性抓取结束
# 开始BV号为1ef4y1i7Ny视频属性的抓取
# BV号为1ef4y1i7Ny的视频属性抓取结束
# 开始BV号为1rK4y1E7Wf视频属性的抓取
# BV号为1rK4y1E7Wf的视频属性抓取结束
# 开始BV号为1Tf4y1z7P9视频属性的抓取
# BV号为1Tf4y1z7P9的视频属性抓取结束
# 开始BV号为1w5411778z视频属性的抓取
# BV号为1w5411778z的视频属性抓取结束
# 开始BV号为1Ua411A7y8视频属性的抓取
# BV号为1Ua411A7y8的视频属性抓取结束
# 开始BV号为1dK4y187tU视频属性的抓取
# BV号为1dK4y187tU的视频属性抓取结束
# 开始BV号为1VZ4y1L73K视频属性的抓取
# BV号为1VZ4y1L73K的视频属性抓取结束
# 开始BV号为1wV411279z视频属性的抓取
# BV号为1wV411279z的视频属性抓取结束
# 开始BV号为1pr4y1w7aB视频属性的抓取
# 开始BV号为1pr4y1w7aB视频属性的抓取
# 开始BV号为1pr4y1w7aB视频属性的抓取
# 开始BV号为1pr4y1w7aB视频属性的抓取
# BV号为1pr4y1w7aB的视频属性抓取结束
# 开始BV号为1AT4y1w7CW视频属性的抓取
# BV号为1AT4y1w7CW的视频属性抓取结束
# 开始BV号为1of4y1q7xm视频属性的抓取
# BV号为1of4y1q7xm的视频属性抓取结束
# 开始BV号为1Zr4y1c7em视频属性的抓取
# BV号为1Zr4y1c7em的视频属性抓取结束
# 开始BV号为1GK4y1h77x视频属性的抓取
# BV号为1GK4y1h77x的视频属性抓取结束
# 开始BV号为19Z4y157Es视频属性的抓取
# 开始BV号为19Z4y157Es视频属性的抓取
# BV号为19Z4y157Es的视频属性抓取结束
# 开始BV号为1ny4y1r7C3视频属性的抓取
# BV号为1ny4y1r7C3的视频属性抓取结束
# 开始BV号为1iD4y1R7yW视频属性的抓取
# BV号为1iD4y1R7yW的视频属性抓取结束
# 开始BV号为1Tt4y1e7Jv视频属性的抓取
# BV号为1Tt4y1e7Jv的视频属性抓取结束
# 开始BV号为1kV41127H8视频属性的抓取
# BV号为1kV41127H8的视频属性抓取结束
# 2020-12-18 09:17:39.575464

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-14-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_meishi_zhizuo.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月    99   99    99   99   99   99   99   99    99      99   99    99   99
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月     98   98    98   98   98   98   98   98    98      98   98    98   98
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 7月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 8月     98   98    98   98   98   98   98   98    98      98   98    98   98
# 9月     99   99    99   99   99   99   99   99    99      99   99    99   99
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月   99   99   99   99   99   99    99
# 1月   100  100  100  100  100  100   100
# 2月   100  100  100  100  100  100   100
# 3月    98   98   98   98   98   98    98
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月    99   99   99   99   99   99    99
# 7月    99   99   99   99   99   99    99
# 8月    98   98   98   98   98   98    98
# 9月    99   99   99   99   99   99    99

# %%
channel_meishi_zhizuo.to_json('channel_meishi_zhizuo.json')

# %%
pd.set_option('display.max_rows', None)

# %%
channel_youxi_danji[channel_youxi_danji['时间']=='4月']
# Out:
#             时间            作者名  作者类型      粉丝数   投稿数  \
# 1h54y1d7Qq  4月            鹤吱菌  个人认证   191.3万    81
# 1L64y1M7Dp  4月            老番茄  个人认证  1360.1万   348
# 18K41157Tu  4月            老番茄  个人认证  1360.1万   348
# 1PT4y1G7ME  4月            老番茄  个人认证  1360.1万   348
# 1S54y197uX  4月           徐大虾咯  个人认证   570.1万   224
# 1ti4y1t7YM  4月            老番茄  个人认证  1360.1万   348
# 1Ai4y1b7ET  4月            敖厂长  个人认证   735.1万   348
# 1Up4y1C7PB  4月        丢鹏D1uuu     无     8.4万    20
# 1wi4y187bu  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 13t4y1U7kQ  4月           徐大虾咯  个人认证   570.1万   224
# 1fe411x7FA  4月         芦苇草的梦想  个人认证    29.3万   726
# 1LA411b7Dt  4月      LexBurner  个人认证   929.6万   383
# 1Ji4y1t7T9  4月            沧桑丸  个人认证    86.6万    57
# 1Lz411z72u  4月           徐大虾咯  个人认证   570.1万   224
# 13T4y1G7WT  4月          逗比的雀巢  个人认证   242.3万    82
# 1T54y197DH  4月           徐大虾咯  个人认证   570.1万   224
# 1Va4y147fH  4月            鹤吱菌  个人认证   191.3万    81
# 1tt4y127yy  4月           小潮院长  个人认证   481.6万   266
# 16T4y1g7RY  4月         吉儿一范伦婷  个人认证    67.6万    79
# 1754y197Da  4月            敖厂长  个人认证   735.1万   348
# 1hK41157M3  4月           花少北丶  个人认证   491.9万   173
# 1Rk4y197kw  4月       3DM游戏网官方  机构认证    13.5万  2822
# 1ST4y1G7E1  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1H54y1d76B  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1Sz411B7P4  4月          游汐_YX  个人认证    12.9万    98
# 1CT4y1g7Ya  4月    育碧中国Ubisoft  机构认证    64.5万  1211
# 12T4y1G7AZ  4月          与山0v0  个人认证   208.5万   557
# 1b5411x79t  4月        东尼ookii  个人认证   331.7万   166
# 1hA411h7Ky  4月          与山0v0  个人认证   208.5万   557
# 1KJ411e7nN                              如何提高审美？审美有无高低？审美是谁建立？  数码  摄影摄像  普通视频
# ...                                                       ...  ..   ...   ...
# 1cr4y1w7ig              困难重重，国家天文签约摄影师遭遇拍摄滑铁卢？！【华为Mate40 Pro】  数码  摄影摄像  活动作品
# 1Y5411L7TW                     富士X-S10相机测试——2020 apsc画幅性价比最强机  数码  摄影摄像  活动作品
# 1c541177hR      索尼（Sony）12-24mm F2.8 GM深度评测，只要买得起，它就是一颗完美的镜头！  数码  摄影摄像  普通视频
# 1DA41177UY                            大疆旗舰稳定器 - DJI RS 2 正式登场  数码  摄影摄像  普通视频
# 1rA411776p                 让我非常失望的佳能M50 Mark II（来自一代老用户的真实心声）  数码  摄影摄像  普通视频
#
#             ...                                                 标签   视频长度  \
# 1gJ411n7hp  ...                         [摄影, 数码, 摄影摄像, 数码, 教程, 器材]  01:44
# 1tJ41187w6  ...  [相机, 数码, 摄影摄像, 数码, 何同学, 啊吗粽, 宝剑嫂, 自媒体, 大祥哥, 体验...  30:03
# 1i7411i7yA  ...        [摄影, 短片, 数码, 摄影摄像, 数码, 创意, YOUTUBE, 镜头, 老蛙]  04:51
# 1gJ411G7Cs  ...           [摄影, 数码, 摄影摄像, 数码, VLOG, 后期, 教程, ps, 器材]  06:01
# 1KJ411e7nN  ...  [校园vlog, 相机, 脱口秀, 摄影, 公开课, vlog, 科普, 数码, 摄影摄像,...  27:08
# ...         ...                                                ...    ...
# 1cr4y1w7ig  ...  [vlog, 数码, 摄影摄像, 数码, 放心购机攻略, 敦煌, 星空, 手机摄影, 华为,...  11:43
# 1Y5411L7TW  ...  [相机, 摄影, 数码, 摄影摄像, 数码, 数码玩家训练营, 拍照, 测评, xs10, ...  10:20
# 1c541177hR  ...  [摄影, 数码, 摄影摄像, 数码, 评测, 超广角大光圈, 摄像, 镜头, 数码评测, 超...  21:23
# 1DA41177UY  ...   [相机, 摄影, 数码, 摄影摄像, 数码, 科技, 测评, 器材, 大疆, DJI, 稳定器]  02:26
# 1rA411776p  ...  [vlog, 数码, 摄影摄像, 数码, 佳能, 测评, 体验, m50 mark ii, ...  06:30
#
#                播放量    点赞数   投币数   收藏数   转发数   评论数   弹幕数 有无分集
# 1gJ411n7hp  222.4万   9.7万  2.0万  1.4万  4980  3182  1571    否
# 1tJ41187w6  134.0万  10.7万  8.4万  5.8万  8907  3935  3.0万    否
# 1i7411i7yA   57.8万   4.4万  1.0万  1.6万  2043   641   983    否
# 1gJ411G7Cs   42.3万   3.3万  3.4万  8.6万  2605  1405   612    否
# 1KJ411e7nN   39.6万   4.8万  5.4万  3.4万  6217  1156  1.0万    否
# ...            ...    ...   ...   ...   ...   ...   ...  ...
# 1cr4y1w7ig    4.3万   3051  1391   692   255   337   349    否
# 1Y5411L7TW    4.3万    773   219   221   111   273   104    否
# 1c541177hR    4.1万   1469   443   297   123   250   561    否
# 1DA41177UY    4.1万   1565   197   334   640   171   110    否
# 1rA411776p    4.1万   1262   267   147   101   385   314    否
#
# [999 rows x 21 columns]
