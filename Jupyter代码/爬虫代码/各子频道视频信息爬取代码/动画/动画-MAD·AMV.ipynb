# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_donghua_MAD·AMV=pd.DataFrame(columns=columns)
channel_donghua_MAD·AMV
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[1]/div/a/span').click()  #选择“动画”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[1]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '动画'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[2]/a').click()  #选择“MAD·AMV”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[2]/a').text
sub_channel
# Out:
# 'MAD·AMV'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(8,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_donghua_MAD·AMV.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-19 09:37:35.269286
# <ipython-input-31-864a38754432>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-31-864a38754432>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-31-864a38754432>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为11A411Y7sX视频属性的抓取
# BV号为11A411Y7sX的视频属性抓取结束
# <ipython-input-31-864a38754432>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为15h411o7KX视频属性的抓取
# BV号为15h411o7KX的视频属性抓取结束
# 开始BV号为1Va4y1E7MS视频属性的抓取
# BV号为1Va4y1E7MS的视频属性抓取结束
# 开始BV号为1Kp4y1v75k视频属性的抓取
# BV号为1Kp4y1v75k的视频属性抓取结束
# 开始BV号为1LA411n7po视频属性的抓取
# BV号为1LA411n7po的视频属性抓取结束
# 开始BV号为1PA411e75q视频属性的抓取
# BV号为1PA411e75q的视频属性抓取结束
# 开始BV号为1Gt4y1S7Jv视频属性的抓取
# BV号为1Gt4y1S7Jv的视频属性抓取结束
# 开始BV号为1R64y1c787视频属性的抓取
# BV号为1R64y1c787的视频属性抓取结束
# 开始BV号为1wv411i7EH视频属性的抓取
# BV号为1wv411i7EH的视频属性抓取结束
# 开始BV号为1FK411K7Di视频属性的抓取
# BV号为1FK411K7Di的视频属性抓取结束
# 开始BV号为1e54y1i7b3视频属性的抓取
# BV号为1e54y1i7b3的视频属性抓取结束
# 开始BV号为1354y1v7sp视频属性的抓取
# BV号为1354y1v7sp的视频属性抓取结束
# 开始BV号为1Hv411i7xZ视频属性的抓取
# BV号为1Hv411i7xZ的视频属性抓取结束
# 开始BV号为1pi4y1M7if视频属性的抓取
# BV号为1pi4y1M7if的视频属性抓取结束
# 开始BV号为12k4y127GX视频属性的抓取
# BV号为12k4y127GX的视频属性抓取结束
# 开始BV号为1Mt4y1S7qe视频属性的抓取
# BV号为1Mt4y1S7qe的视频属性抓取结束
# 开始BV号为1et4y1D7Cf视频属性的抓取
# BV号为1et4y1D7Cf的视频属性抓取结束
# 开始BV号为1hV411U72A视频属性的抓取
# BV号为1hV411U72A的视频属性抓取结束
# 开始BV号为1b64y1c7oX视频属性的抓取
# BV号为1b64y1c7oX的视频属性抓取结束
# 开始BV号为15f4y197cD视频属性的抓取
# BV号为15f4y197cD的视频属性抓取结束
# 开始BV号为1Qv411y7jk视频属性的抓取
# BV号为1Qv411y7jk的视频属性抓取结束
# 开始BV号为1RK4y1v7Tj视频属性的抓取
# BV号为1RK4y1v7Tj的视频属性抓取结束
# 开始BV号为1vT4y1L7t8视频属性的抓取
# BV号为1vT4y1L7t8的视频属性抓取结束
# 开始BV号为19D4y1U7LT视频属性的抓取
# BV号为19D4y1U7LT的视频属性抓取结束
# 开始BV号为1KK411n7dR视频属性的抓取
# BV号为1KK411n7dR的视频属性抓取结束
# 开始BV号为1XK411T7fE视频属性的抓取
# BV号为1XK411T7fE的视频属性抓取结束
# 开始BV号为1GC4y1t7Eg视频属性的抓取
# BV号为1GC4y1t7Eg的视频属性抓取结束
# 开始BV号为1rA411Y7Dq视频属性的抓取
# BV号为1rA411Y7Dq的视频属性抓取结束
# 开始BV号为1Dh411d7RC视频属性的抓取
# BV号为1Dh411d7RC的视频属性抓取结束
# 开始BV号为15h411o7GJ视频属性的抓取
# BV号为15h411o7GJ的视频属性抓取结束
# 开始BV号为1fC4y147H6视频属性的抓取
# BV号为1fC4y147H6的视频属性抓取结束
# 开始BV号为1FT4y1L77o视频属性的抓取
# 开始BV号为1FT4y1L77o视频属性的抓取
# BV号为1FT4y1L77o的视频属性抓取结束
# 开始BV号为1Vt4y1D7iX视频属性的抓取
# BV号为1Vt4y1D7iX的视频属性抓取结束
# 开始BV号为17K411M7uN视频属性的抓取
# BV号为17K411M7uN的视频属性抓取结束
# 开始BV号为12k4y1m7sr视频属性的抓取
# BV号为12k4y1m7sr的视频属性抓取结束
# 开始BV号为1fk4y117FR视频属性的抓取
# BV号为1fk4y117FR的视频属性抓取结束
# 开始BV号为1ea4y1E7iR视频属性的抓取
# BV号为1ea4y1E7iR的视频属性抓取结束
# 开始BV号为1pK411T7YA视频属性的抓取
# BV号为1pK411T7YA的视频属性抓取结束
# 开始BV号为1tA411Y746视频属性的抓取
# BV号为1tA411Y746的视频属性抓取结束
# 开始BV号为16K411T7Eq视频属性的抓取
# BV号为16K411T7Eq的视频属性抓取结束
# 开始BV号为1Ez4y1Q7sS视频属性的抓取
# BV号为1Ez4y1Q7sS的视频属性抓取结束
# 开始BV号为17z4y1f7ak视频属性的抓取
# BV号为17z4y1f7ak的视频属性抓取结束
# 开始BV号为1Rf4y1Q7kC视频属性的抓取
# BV号为1Rf4y1Q7kC的视频属性抓取结束
# 开始BV号为1Uz4y1f7Dq视频属性的抓取
# BV号为1Uz4y1f7Dq的视频属性抓取结束
# 开始BV号为18k4y117Xx视频属性的抓取
# BV号为18k4y117Xx的视频属性抓取结束
# 开始BV号为1vT4y157ky视频属性的抓取
# BV号为1vT4y157ky的视频属性抓取结束
# 开始BV号为1BT4y157jo视频属性的抓取
# BV号为1BT4y157jo的视频属性抓取结束
# 开始BV号为1Q54y1S7pL视频属性的抓取
# BV号为1Q54y1S7pL的视频属性抓取结束
# 开始BV号为1MZ4y1K7Ef视频属性的抓取
# BV号为1MZ4y1K7Ef的视频属性抓取结束
# 开始BV号为1oa4y1E7Rt视频属性的抓取
# BV号为1oa4y1E7Rt的视频属性抓取结束
# 开始BV号为1ni4y1M7ik视频属性的抓取
# BV号为1ni4y1M7ik的视频属性抓取结束
# 开始BV号为1r54y1e7GN视频属性的抓取
# BV号为1r54y1e7GN的视频属性抓取结束
# 开始BV号为1uK411K73f视频属性的抓取
# BV号为1uK411K73f的视频属性抓取结束
# 开始BV号为1Gh411d7hq视频属性的抓取
# BV号为1Gh411d7hq的视频属性抓取结束
# 开始BV号为1pk4y127yM视频属性的抓取
# BV号为1pk4y127yM的视频属性抓取结束
# 开始BV号为1YV411z7rr视频属性的抓取
# BV号为1YV411z7rr的视频属性抓取结束
# 开始BV号为1n54y1i7Nx视频属性的抓取
# BV号为1n54y1i7Nx的视频属性抓取结束
# 开始BV号为1JK411M7n9视频属性的抓取
# BV号为1JK411M7n9的视频属性抓取结束
# 开始BV号为1AK4y1e7EX视频属性的抓取
# BV号为1AK4y1e7EX的视频属性抓取结束
# 开始BV号为1Pk4y127FM视频属性的抓取
# BV号为1Pk4y127FM的视频属性抓取结束
# 开始BV号为1z64y1c7kA视频属性的抓取
# BV号为1z64y1c7kA的视频属性抓取结束
# 开始BV号为1b54y1i7Th视频属性的抓取
# BV号为1b54y1i7Th的视频属性抓取结束
# 开始BV号为1kh411d7sc视频属性的抓取
# BV号为1kh411d7sc的视频属性抓取结束
# 开始BV号为1JZ4y1K7xK视频属性的抓取
# BV号为1JZ4y1K7xK的视频属性抓取结束
# 开始BV号为17Z4y1K7rP视频属性的抓取
# BV号为17Z4y1K7rP的视频属性抓取结束
# 开始BV号为1J54y127bk视频属性的抓取
# BV号为1J54y127bk的视频属性抓取结束
# 开始BV号为1Jf4y197W5视频属性的抓取
# BV号为1Jf4y197W5的视频属性抓取结束
# 开始BV号为1Q64y1c7WU视频属性的抓取
# BV号为1Q64y1c7WU的视频属性抓取结束
# 开始BV号为1Wf4y1X7q9视频属性的抓取
# BV号为1Wf4y1X7q9的视频属性抓取结束
# 开始BV号为13k4y127c7视频属性的抓取
# BV号为13k4y127c7的视频属性抓取结束
# 开始BV号为1xC4y1t7ZK视频属性的抓取
# BV号为1xC4y1t7ZK的视频属性抓取结束
# 开始BV号为1PT4y1L7ef视频属性的抓取
# BV号为1PT4y1L7ef的视频属性抓取结束
# 开始BV号为1rT4y157Z5视频属性的抓取
# BV号为1rT4y157Z5的视频属性抓取结束
# 开始BV号为1TT4y177Qa视频属性的抓取
# BV号为1TT4y177Qa的视频属性抓取结束
# 开始BV号为1it4y1S7WM视频属性的抓取
# BV号为1it4y1S7WM的视频属性抓取结束
# 开始BV号为19t4y1U7nT视频属性的抓取
# BV号为19t4y1U7nT的视频属性抓取结束
# 开始BV号为1Xh411977x视频属性的抓取
# BV号为1Xh411977x的视频属性抓取结束
# 开始BV号为1EC4y1t7EY视频属性的抓取
# BV号为1EC4y1t7EY的视频属性抓取结束
# 开始BV号为1Kh411R7TZ视频属性的抓取
# BV号为1Kh411R7TZ的视频属性抓取结束
# 开始BV号为1n54y127Nn视频属性的抓取
# BV号为1n54y127Nn的视频属性抓取结束
# 开始BV号为1NV411S7ck视频属性的抓取
# BV号为1NV411S7ck的视频属性抓取结束
# 开始BV号为1PC4y1t7Mf视频属性的抓取
# BV号为1PC4y1t7Mf的视频属性抓取结束
# 开始BV号为1CK4y1Y77Z视频属性的抓取
# BV号为1CK4y1Y77Z的视频属性抓取结束
# 开始BV号为1EA411n73v视频属性的抓取
# BV号为1EA411n73v的视频属性抓取结束
# 开始BV号为1Yv411i77Q视频属性的抓取
# BV号为1Yv411i77Q的视频属性抓取结束
# 开始BV号为1DT4y157gu视频属性的抓取
# BV号为1DT4y157gu的视频属性抓取结束
# 开始BV号为1b54y1e7LA视频属性的抓取
# BV号为1b54y1e7LA的视频属性抓取结束
# 开始BV号为1Cy4y1C7o5视频属性的抓取
# BV号为1Cy4y1C7o5的视频属性抓取结束
# 开始BV号为1mC4y1t7NQ视频属性的抓取
# BV号为1mC4y1t7NQ的视频属性抓取结束
# 开始BV号为1ba4y177kQ视频属性的抓取
# BV号为1ba4y177kQ的视频属性抓取结束
# 开始BV号为1DV41127mG视频属性的抓取
# BV号为1DV41127mG的视频属性抓取结束
# 开始BV号为13V411z7wE视频属性的抓取
# BV号为13V411z7wE的视频属性抓取结束
# 开始BV号为1FV411S7kA视频属性的抓取
# BV号为1FV411S7kA的视频属性抓取结束
# 开始BV号为1Ct4y1U74v视频属性的抓取
# BV号为1Ct4y1U74v的视频属性抓取结束
# 开始BV号为19t4y1U7p8视频属性的抓取
# BV号为19t4y1U7p8的视频属性抓取结束
# 开始BV号为1S54y1S7MR视频属性的抓取
# BV号为1S54y1S7MR的视频属性抓取结束
# 开始BV号为1fK4y1Y7kY视频属性的抓取
# BV号为1fK4y1Y7kY的视频属性抓取结束
# 开始BV号为1fC4y147eo视频属性的抓取
# BV号为1fC4y147eo的视频属性抓取结束
# 开始BV号为1Sv411y77A视频属性的抓取
# BV号为1Sv411y77A的视频属性抓取结束
# 开始BV号为1RD4y127yo视频属性的抓取
# BV号为1RD4y127yo的视频属性抓取结束
# 开始BV号为1TA411J7bg视频属性的抓取
# BV号为1TA411J7bg的视频属性抓取结束
# 开始BV号为1oK411P7JU视频属性的抓取
# BV号为1oK411P7JU的视频属性抓取结束
# 开始BV号为1yp4y1a7VG视频属性的抓取
# BV号为1yp4y1a7VG的视频属性抓取结束
# 开始BV号为1P541187VD视频属性的抓取
# BV号为1P541187VD的视频属性抓取结束
# 开始BV号为12T4y1w7wE视频属性的抓取
# BV号为12T4y1w7wE的视频属性抓取结束
# 开始BV号为1E5411878U视频属性的抓取
# BV号为1E5411878U的视频属性抓取结束
# 开始BV号为1of4y1S7qs视频属性的抓取
# BV号为1of4y1S7qs的视频属性抓取结束
# 开始BV号为1Dv41117tt视频属性的抓取
# BV号为1Dv41117tt的视频属性抓取结束
# 开始BV号为1aK4y1a7oT视频属性的抓取
# BV号为1aK4y1a7oT的视频属性抓取结束
# 开始BV号为1XK4y1a7aV视频属性的抓取
# BV号为1XK4y1a7aV的视频属性抓取结束
# 开始BV号为1fa4y1j7x3视频属性的抓取
# BV号为1fa4y1j7x3的视频属性抓取结束
# 开始BV号为17v4111736视频属性的抓取
# BV号为17v4111736的视频属性抓取结束
# 开始BV号为1QZ4y1K7Nw视频属性的抓取
# BV号为1QZ4y1K7Nw的视频属性抓取结束
# 开始BV号为1mp4y1e72Y视频属性的抓取
# BV号为1mp4y1e72Y的视频属性抓取结束
# 开始BV号为1bD4y1R7rq视频属性的抓取
# BV号为1bD4y1R7rq的视频属性抓取结束
# 开始BV号为1iA411E7gB视频属性的抓取
# BV号为1iA411E7gB的视频属性抓取结束
# 开始BV号为14K4y1e7nq视频属性的抓取
# BV号为14K4y1e7nq的视频属性抓取结束
# 开始BV号为1BK411P756视频属性的抓取
# BV号为1BK411P756的视频属性抓取结束
# 开始BV号为1dT4y1w7aR视频属性的抓取
# BV号为1dT4y1w7aR的视频属性抓取结束
# 开始BV号为18z4y1Z7MU视频属性的抓取
# BV号为18z4y1Z7MU的视频属性抓取结束
# 开始BV号为1c54y1m7mi视频属性的抓取
# BV号为1c54y1m7mi的视频属性抓取结束
# 开始BV号为1eZ4y1N7k7视频属性的抓取
# BV号为1eZ4y1N7k7的视频属性抓取结束
# 开始BV号为1qa4y157d5视频属性的抓取
# 开始BV号为1qa4y157d5视频属性的抓取
# BV号为1qa4y157d5的视频属性抓取结束
# 开始BV号为1rK411K7as视频属性的抓取
# BV号为1rK411K7as的视频属性抓取结束
# 开始BV号为1pK4y1a7Gu视频属性的抓取
# BV号为1pK4y1a7Gu的视频属性抓取结束
# 开始BV号为19h411X7Gb视频属性的抓取
# BV号为19h411X7Gb的视频属性抓取结束
# 开始BV号为12k4y127kp视频属性的抓取
# BV号为12k4y127kp的视频属性抓取结束
# 开始BV号为1Z5411b7Ha视频属性的抓取
# BV号为1Z5411b7Ha的视频属性抓取结束
# 开始BV号为1d5411L7JD视频属性的抓取
# BV号为1d5411L7JD的视频属性抓取结束
# 开始BV号为1wD4y1o7RQ视频属性的抓取
# BV号为1wD4y1o7RQ的视频属性抓取结束
# 开始BV号为1Xa4y157Hb视频属性的抓取
# BV号为1Xa4y157Hb的视频属性抓取结束
# 开始BV号为1dt4y1i76A视频属性的抓取
# BV号为1dt4y1i76A的视频属性抓取结束
# 开始BV号为1Nk4y117af视频属性的抓取
# BV号为1Nk4y117af的视频属性抓取结束
# 开始BV号为1s54y117m2视频属性的抓取
# BV号为1s54y117m2的视频属性抓取结束
# 开始BV号为1i5411h7WV视频属性的抓取
# BV号为1i5411h7WV的视频属性抓取结束
# 开始BV号为1kK411P7Kp视频属性的抓取
# BV号为1kK411P7Kp的视频属性抓取结束
# 开始BV号为18k4y1y72y视频属性的抓取
# BV号为18k4y1y72y的视频属性抓取结束
# 开始BV号为1T54y1y74r视频属性的抓取
# BV号为1T54y1y74r的视频属性抓取结束
# 开始BV号为1Xh41197hA视频属性的抓取
# BV号为1Xh41197hA的视频属性抓取结束
# 开始BV号为1rk4y1y7fe视频属性的抓取
# BV号为1rk4y1y7fe的视频属性抓取结束
# 开始BV号为16A411E7t9视频属性的抓取
# BV号为16A411E7t9的视频属性抓取结束
# 开始BV号为1PA411J7ti视频属性的抓取
# BV号为1PA411J7ti的视频属性抓取结束
# 开始BV号为1vT4y1w7qm视频属性的抓取
# BV号为1vT4y1w7qm的视频属性抓取结束
# 开始BV号为1Dv41117Zr视频属性的抓取
# BV号为1Dv41117Zr的视频属性抓取结束
# 开始BV号为1hD4y1o7eW视频属性的抓取
# BV号为1hD4y1o7eW的视频属性抓取结束
# 开始BV号为1Z5411b7nT视频属性的抓取
# BV号为1Z5411b7nT的视频属性抓取结束
# 开始BV号为1pt4y1q7MA视频属性的抓取
# BV号为1pt4y1q7MA的视频属性抓取结束
# 开始BV号为1R54y1y7Ty视频属性的抓取
# BV号为1R54y1y7Ty的视频属性抓取结束
# 开始BV号为1ta4y1j7aB视频属性的抓取
# 开始BV号为1ta4y1j7aB视频属性的抓取
# BV号为1ta4y1j7aB的视频属性抓取结束
# 开始BV号为1354y1v7Sm视频属性的抓取
# 开始BV号为1354y1v7Sm视频属性的抓取
# BV号为1354y1v7Sm的视频属性抓取结束
# 开始BV号为1Wf4y1D7wb视频属性的抓取
# BV号为1Wf4y1D7wb的视频属性抓取结束
# 开始BV号为11p4y1e7j1视频属性的抓取
# BV号为11p4y1e7j1的视频属性抓取结束
# 开始BV号为1SV41127K6视频属性的抓取
# BV号为1SV41127K6的视频属性抓取结束
# 开始BV号为1fZ4y1P78h视频属性的抓取
# BV号为1fZ4y1P78h的视频属性抓取结束
# 开始BV号为1454y127Kn视频属性的抓取
# BV号为1454y127Kn的视频属性抓取结束
# 开始BV号为1jZ4y1N7YM视频属性的抓取
# BV号为1jZ4y1N7YM的视频属性抓取结束
# 开始BV号为1fz4y1f7eA视频属性的抓取
# BV号为1fz4y1f7eA的视频属性抓取结束
# 开始BV号为1Jv41117Pf视频属性的抓取
# BV号为1Jv41117Pf的视频属性抓取结束
# 开始BV号为1h5411j7MB视频属性的抓取
# 开始BV号为1h5411j7MB视频属性的抓取
# BV号为1h5411j7MB的视频属性抓取结束
# 开始BV号为1Kf4y1Q7AQ视频属性的抓取
# BV号为1Kf4y1Q7AQ的视频属性抓取结束
# 开始BV号为1Uf4y1D79p视频属性的抓取
# BV号为1Uf4y1D79p的视频属性抓取结束
# 开始BV号为1xD4y1m7rM视频属性的抓取
# BV号为1xD4y1m7rM的视频属性抓取结束
# 开始BV号为1bv411C7ta视频属性的抓取
# BV号为1bv411C7ta的视频属性抓取结束
# 开始BV号为1UA411E7hm视频属性的抓取
# BV号为1UA411E7hm的视频属性抓取结束
# 开始BV号为1da4y1L7Ct视频属性的抓取
# BV号为1da4y1L7Ct的视频属性抓取结束
# 开始BV号为1Mk4y1y7Wm视频属性的抓取
# BV号为1Mk4y1y7Wm的视频属性抓取结束
# 开始BV号为1ZT4y1w7Wk视频属性的抓取
# BV号为1ZT4y1w7Wk的视频属性抓取结束
# 开始BV号为1ay4y1y7L2视频属性的抓取
# BV号为1ay4y1y7L2的视频属性抓取结束
# 开始BV号为1ov41117Dh视频属性的抓取
# BV号为1ov41117Dh的视频属性抓取结束
# 开始BV号为1Qy4y1y7zH视频属性的抓取
# BV号为1Qy4y1y7zH的视频属性抓取结束
# 开始BV号为1MK4y1a7ss视频属性的抓取
# BV号为1MK4y1a7ss的视频属性抓取结束
# 开始BV号为1LT4y1A75G视频属性的抓取
# BV号为1LT4y1A75G的视频属性抓取结束
# 开始BV号为1Xy4y1y7QX视频属性的抓取
# BV号为1Xy4y1y7QX的视频属性抓取结束
# 开始BV号为1oz4y1o7FB视频属性的抓取
# BV号为1oz4y1o7FB的视频属性抓取结束
# 开始BV号为1PZ4y1T7HS视频属性的抓取
# BV号为1PZ4y1T7HS的视频属性抓取结束
# 开始BV号为1nV411m7J7视频属性的抓取
# BV号为1nV411m7J7的视频属性抓取结束
# 开始BV号为1SA411E7L1视频属性的抓取
# BV号为1SA411E7L1的视频属性抓取结束
# 开始BV号为1DV41117dn视频属性的抓取
# BV号为1DV41117dn的视频属性抓取结束
# 开始BV号为1Ki4y1u75g视频属性的抓取
# BV号为1Ki4y1u75g的视频属性抓取结束
# 开始BV号为1ta4y1j7ap视频属性的抓取
# BV号为1ta4y1j7ap的视频属性抓取结束
# 开始BV号为1M54y1v7pu视频属性的抓取
# BV号为1M54y1v7pu的视频属性抓取结束
# 开始BV号为1Ep4y1a76H视频属性的抓取
# BV号为1Ep4y1a76H的视频属性抓取结束
# 开始BV号为1yD4y1o7Yq视频属性的抓取
# BV号为1yD4y1o7Yq的视频属性抓取结束
# 开始BV号为1RD4y1d7F4视频属性的抓取
# BV号为1RD4y1d7F4的视频属性抓取结束
# 开始BV号为1nK411K78N视频属性的抓取
# BV号为1nK411K78N的视频属性抓取结束
# 开始BV号为1Zz4y1o7uD视频属性的抓取
# BV号为1Zz4y1o7uD的视频属性抓取结束
# 开始BV号为1KD4y1o7kT视频属性的抓取
# BV号为1KD4y1o7kT的视频属性抓取结束
# 开始BV号为1Yk4y1y7sk视频属性的抓取
# BV号为1Yk4y1y7sk的视频属性抓取结束
# 开始BV号为1wz4y1Z7YV视频属性的抓取
# BV号为1wz4y1Z7YV的视频属性抓取结束
# 开始BV号为1eK4y1a7eW视频属性的抓取
# BV号为1eK4y1a7eW的视频属性抓取结束
# 开始BV号为1Hy4y1y71Z视频属性的抓取
# BV号为1Hy4y1y71Z的视频属性抓取结束
# 开始BV号为1tt4y1q7dW视频属性的抓取
# BV号为1tt4y1q7dW的视频属性抓取结束
# 开始BV号为1tp4y1a7h9视频属性的抓取
# BV号为1tp4y1a7h9的视频属性抓取结束
# 开始BV号为1MZ4y1N7uj视频属性的抓取
# BV号为1MZ4y1N7uj的视频属性抓取结束
# 开始BV号为1Ak4y11784视频属性的抓取
# BV号为1Ak4y11784的视频属性抓取结束
# 开始BV号为1VV411S73r视频属性的抓取
# BV号为1VV411S73r的视频属性抓取结束
# 开始BV号为1DK411K7cc视频属性的抓取
# BV号为1DK411K7cc的视频属性抓取结束
# 开始BV号为1WD4y1m7Py视频属性的抓取
# BV号为1WD4y1m7Py的视频属性抓取结束
# 开始BV号为1o54y1C7UP视频属性的抓取
# BV号为1o54y1C7UP的视频属性抓取结束
# 开始BV号为1gf4y1X7yP视频属性的抓取
# BV号为1gf4y1X7yP的视频属性抓取结束
# 开始BV号为1ky4y1r7Ju视频属性的抓取
# BV号为1ky4y1r7Ju的视频属性抓取结束
# 开始BV号为1Jy4y1r7UL视频属性的抓取
# BV号为1Jy4y1r7UL的视频属性抓取结束
# 开始BV号为1hr4y1w7pt视频属性的抓取
# BV号为1hr4y1w7pt的视频属性抓取结束
# 开始BV号为13A411E7NF视频属性的抓取
# BV号为13A411E7NF的视频属性抓取结束
# 开始BV号为1RV41117ii视频属性的抓取
# BV号为1RV41117ii的视频属性抓取结束
# 开始BV号为17t4y1i75f视频属性的抓取
# BV号为17t4y1i75f的视频属性抓取结束
# 开始BV号为1cD4y1d7Fu视频属性的抓取
# BV号为1cD4y1d7Fu的视频属性抓取结束
# 开始BV号为15D4y197NU视频属性的抓取
# BV号为15D4y197NU的视频属性抓取结束
# 开始BV号为1By4y1r75Z视频属性的抓取
# BV号为1By4y1r75Z的视频属性抓取结束
# 开始BV号为18Z4y1V7ZJ视频属性的抓取
# 开始BV号为18Z4y1V7ZJ视频属性的抓取
# BV号为18Z4y1V7ZJ的视频属性抓取结束
# 开始BV号为1Qp4y1a7VJ视频属性的抓取
# BV号为1Qp4y1a7VJ的视频属性抓取结束
# 开始BV号为1e5411L7e2视频属性的抓取
# BV号为1e5411L7e2的视频属性抓取结束
# 开始BV号为1F54y127Xn视频属性的抓取
# BV号为1F54y127Xn的视频属性抓取结束
# 开始BV号为1Pk4y1y7Pw视频属性的抓取
# BV号为1Pk4y1y7Pw的视频属性抓取结束
# 开始BV号为1cZ4y1L7nm视频属性的抓取
# 开始BV号为1cZ4y1L7nm视频属性的抓取
# BV号为1cZ4y1L7nm的视频属性抓取结束
# 开始BV号为19D4y1979d视频属性的抓取
# BV号为19D4y1979d的视频属性抓取结束
# 开始BV号为17V411y7MB视频属性的抓取
# BV号为17V411y7MB的视频属性抓取结束
# 开始BV号为19f4y1D7UB视频属性的抓取
# BV号为19f4y1D7UB的视频属性抓取结束
# 开始BV号为1FK411A7yf视频属性的抓取
# BV号为1FK411A7yf的视频属性抓取结束
# 开始BV号为1jh41197on视频属性的抓取
# BV号为1jh41197on的视频属性抓取结束
# 开始BV号为1B54y117xN视频属性的抓取
# BV号为1B54y117xN的视频属性抓取结束
# 开始BV号为1s5411j77k视频属性的抓取
# BV号为1s5411j77k的视频属性抓取结束
# 开始BV号为11z4y1Z7GW视频属性的抓取
# BV号为11z4y1Z7GW的视频属性抓取结束
# 开始BV号为18z4y1o7Lx视频属性的抓取
# BV号为18z4y1o7Lx的视频属性抓取结束
# 开始BV号为1wy4y1r7L8视频属性的抓取
# BV号为1wy4y1r7L8的视频属性抓取结束
# 开始BV号为1ii4y1E7uK视频属性的抓取
# BV号为1ii4y1E7uK的视频属性抓取结束
# 开始BV号为15T4y1F7Wo视频属性的抓取
# BV号为15T4y1F7Wo的视频属性抓取结束
# 开始BV号为1Zr4y1c7KR视频属性的抓取
# BV号为1Zr4y1c7KR的视频属性抓取结束
# 开始BV号为1Rt4y1Y7at视频属性的抓取
# BV号为1Rt4y1Y7at的视频属性抓取结束
# 开始BV号为1x54y1R77Z视频属性的抓取
# BV号为1x54y1R77Z的视频属性抓取结束
# 开始BV号为1Kt4y1i7Qw视频属性的抓取
# BV号为1Kt4y1i7Qw的视频属性抓取结束
# 开始BV号为1ti4y1E76R视频属性的抓取
# BV号为1ti4y1E76R的视频属性抓取结束
# 开始BV号为1DK411P7Vs视频属性的抓取
# BV号为1DK411P7Vs的视频属性抓取结束
# 开始BV号为1Vp4y1k73q视频属性的抓取
# BV号为1Vp4y1k73q的视频属性抓取结束
# 开始BV号为1za411A7Wv视频属性的抓取
# BV号为1za411A7Wv的视频属性抓取结束
# 开始BV号为1GV41127H5视频属性的抓取
# BV号为1GV41127H5的视频属性抓取结束
# 开始BV号为1uZ4y1V7iL视频属性的抓取
# BV号为1uZ4y1V7iL的视频属性抓取结束
# 开始BV号为19r4y1c72h视频属性的抓取
# BV号为19r4y1c72h的视频属性抓取结束
# 开始BV号为1or4y1c7v3视频属性的抓取
# BV号为1or4y1c7v3的视频属性抓取结束
# 开始BV号为1uv411r7fT视频属性的抓取
# BV号为1uv411r7fT的视频属性抓取结束
# 开始BV号为1P54y1r7Ed视频属性的抓取
# BV号为1P54y1r7Ed的视频属性抓取结束
# 开始BV号为17f4y1B7sF视频属性的抓取
# BV号为17f4y1B7sF的视频属性抓取结束
# 开始BV号为1U54y117gq视频属性的抓取
# BV号为1U54y117gq的视频属性抓取结束
# 开始BV号为1Kh41197Z8视频属性的抓取
# BV号为1Kh41197Z8的视频属性抓取结束
# 开始BV号为1LD4y197hA视频属性的抓取
# BV号为1LD4y197hA的视频属性抓取结束
# 开始BV号为1iT4y1F7Ay视频属性的抓取
# BV号为1iT4y1F7Ay的视频属性抓取结束
# 开始BV号为1CV41117cs视频属性的抓取
# BV号为1CV41117cs的视频属性抓取结束
# 开始BV号为11K411A7xv视频属性的抓取
# BV号为11K411A7xv的视频属性抓取结束
# 开始BV号为1FK411N7R6视频属性的抓取
# BV号为1FK411N7R6的视频属性抓取结束
# 开始BV号为12541157LD视频属性的抓取
# BV号为12541157LD的视频属性抓取结束
# 开始BV号为1Kt4y1i7KV视频属性的抓取
# BV号为1Kt4y1i7KV的视频属性抓取结束
# 开始BV号为1GV41127Ri视频属性的抓取
# BV号为1GV41127Ri的视频属性抓取结束
# 开始BV号为1ry4y1r7qC视频属性的抓取
# BV号为1ry4y1r7qC的视频属性抓取结束
# 开始BV号为1st4y1i7o9视频属性的抓取
# BV号为1st4y1i7o9的视频属性抓取结束
# 开始BV号为1Ka4y1s7AH视频属性的抓取
# BV号为1Ka4y1s7AH的视频属性抓取结束
# 开始BV号为1W54y1R7jX视频属性的抓取
# BV号为1W54y1R7jX的视频属性抓取结束
# 开始BV号为1y54y1y7Dd视频属性的抓取
# BV号为1y54y1y7Dd的视频属性抓取结束
# 开始BV号为18Z4y1V7Tt视频属性的抓取
# BV号为18Z4y1V7Tt的视频属性抓取结束
# 开始BV号为1SK4y1h7Zk视频属性的抓取
# BV号为1SK4y1h7Zk的视频属性抓取结束
# 开始BV号为1GA411E75r视频属性的抓取
# BV号为1GA411E75r的视频属性抓取结束
# 开始BV号为1Vz4y1f78S视频属性的抓取
# BV号为1Vz4y1f78S的视频属性抓取结束
# 开始BV号为19i4y1E7Lh视频属性的抓取
# BV号为19i4y1E7Lh的视频属性抓取结束
# 开始BV号为1g541177ph视频属性的抓取
# BV号为1g541177ph的视频属性抓取结束
# 开始BV号为1MZ4y1V7sU视频属性的抓取
# BV号为1MZ4y1V7sU的视频属性抓取结束
# 开始BV号为1FZ4y1V7ig视频属性的抓取
# BV号为1FZ4y1V7ig的视频属性抓取结束
# 开始BV号为1uA411j7dp视频属性的抓取
# BV号为1uA411j7dp的视频属性抓取结束
# 开始BV号为1Pp4y1k7k2视频属性的抓取
# BV号为1Pp4y1k7k2的视频属性抓取结束
# 开始BV号为1gr4y1w78B视频属性的抓取
# BV号为1gr4y1w78B的视频属性抓取结束
# 开始BV号为17V41127T5视频属性的抓取
# BV号为17V41127T5的视频属性抓取结束
# 开始BV号为17y4y1z763视频属性的抓取
# BV号为17y4y1z763的视频属性抓取结束
# 开始BV号为1xt4y1v7Ds视频属性的抓取
# BV号为1xt4y1v7Ds的视频属性抓取结束
# 开始BV号为1ki4y1j75A视频属性的抓取
# BV号为1ki4y1j75A的视频属性抓取结束
# 开始BV号为17z4y1o7kV视频属性的抓取
# BV号为17z4y1o7kV的视频属性抓取结束
# 开始BV号为1ck4y1C7EC视频属性的抓取
# BV号为1ck4y1C7EC的视频属性抓取结束
# 开始BV号为1wK411P7FV视频属性的抓取
# BV号为1wK411P7FV的视频属性抓取结束
# 开始BV号为1eV411y7xM视频属性的抓取
# BV号为1eV411y7xM的视频属性抓取结束
# 开始BV号为1fh411X7Qd视频属性的抓取
# BV号为1fh411X7Qd的视频属性抓取结束
# 开始BV号为1Xv411k7t3视频属性的抓取
# BV号为1Xv411k7t3的视频属性抓取结束
# 开始BV号为1J54y1k7Pa视频属性的抓取
# BV号为1J54y1k7Pa的视频属性抓取结束
# 开始BV号为1N54y1r7ad视频属性的抓取
# BV号为1N54y1r7ad的视频属性抓取结束
# 开始BV号为1kp4y1k7UA视频属性的抓取
# BV号为1kp4y1k7UA的视频属性抓取结束
# 开始BV号为1VK4y1h7yM视频属性的抓取
# BV号为1VK4y1h7yM的视频属性抓取结束
# 开始BV号为1ti4y177gG视频属性的抓取
# BV号为1ti4y177gG的视频属性抓取结束
# 开始BV号为145411j7fG视频属性的抓取
# BV号为145411j7fG的视频属性抓取结束
# 开始BV号为1TZ4y1L7kq视频属性的抓取
# BV号为1TZ4y1L7kq的视频属性抓取结束
# 开始BV号为1jD4y1d7ij视频属性的抓取
# BV号为1jD4y1d7ij的视频属性抓取结束
# 开始BV号为1MK4y1h74D视频属性的抓取
# BV号为1MK4y1h74D的视频属性抓取结束
# 开始BV号为1Di4y1E74q视频属性的抓取
# 开始BV号为1Di4y1E74q视频属性的抓取
# BV号为1Di4y1E74q的视频属性抓取结束
# 开始BV号为1Ph41197P7视频属性的抓取
# BV号为1Ph41197P7的视频属性抓取结束
# 开始BV号为1k54y1177q视频属性的抓取
# BV号为1k54y1177q的视频属性抓取结束
# 开始BV号为1Ar4y1w7xk视频属性的抓取
# BV号为1Ar4y1w7xk的视频属性抓取结束
# 开始BV号为1V54y1k7Ac视频属性的抓取
# BV号为1V54y1k7Ac的视频属性抓取结束
# 开始BV号为1Uk4y1C7cH视频属性的抓取
# BV号为1Uk4y1C7cH的视频属性抓取结束
# 开始BV号为16Z4y157VX视频属性的抓取
# BV号为16Z4y157VX的视频属性抓取结束
# 开始BV号为1fV41117NX视频属性的抓取
# BV号为1fV41117NX的视频属性抓取结束
# 开始BV号为1py4y1B7sE视频属性的抓取
# BV号为1py4y1B7sE的视频属性抓取结束
# 开始BV号为1Hi4y177a5视频属性的抓取
# BV号为1Hi4y177a5的视频属性抓取结束
# 开始BV号为1Kf4y1Q7b1视频属性的抓取
# BV号为1Kf4y1Q7b1的视频属性抓取结束
# 开始BV号为1cy4y1k7P7视频属性的抓取
# BV号为1cy4y1k7P7的视频属性抓取结束
# 开始BV号为1it4y1v7rY视频属性的抓取
# 开始BV号为1it4y1v7rY视频属性的抓取
# BV号为1it4y1v7rY的视频属性抓取结束
# 2020-12-19 14:15:04.008662

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-21-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_donghua_MAD·AMV.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月   100  100  100  100  100  100   100
# 2月   100  100  100  100  100  100   100
# 3月    99   99   99   99   99   99    99
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月   100  100  100  100  100  100   100
# 7月    99   99   99   99   99   99    99
# 8月   100  100  100  100  100  100   100
# 9月   100  100  100  100  100  100   100

# %%
channel_donghua_MAD·AMV.to_json('channel_donghua_MAD·AMV.json')
