# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_donghua_teshe=pd.DataFrame(columns=columns)
channel_donghua_teshe
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[1]/div/a/span').click()  #选择“动画”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[1]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '动画'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[6]/a').click()  #选择“特摄”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[6]/a').text
sub_channel
# Out:
# '特摄'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(8,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_donghua_teshe.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-19 09:38:18.711229
# <ipython-input-18-32af033be2a5>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-18-32af033be2a5>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-18-32af033be2a5>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1TX4y1u7dR视频属性的抓取
# BV号为1TX4y1u7dR的视频属性抓取结束
# <ipython-input-18-32af033be2a5>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1iZ4y1g7SB视频属性的抓取
# BV号为1iZ4y1g7SB的视频属性抓取结束
# 开始BV号为19D4y1X77c视频属性的抓取
# BV号为19D4y1X77c的视频属性抓取结束
# 开始BV号为1oz4y1k7v1视频属性的抓取
# BV号为1oz4y1k7v1的视频属性抓取结束
# 开始BV号为1JA41147up视频属性的抓取
# BV号为1JA41147up的视频属性抓取结束
# 开始BV号为1XK41137UJ视频属性的抓取
# BV号为1XK41137UJ的视频属性抓取结束
# 开始BV号为1Tz4y1r7r3视频属性的抓取
# BV号为1Tz4y1r7r3的视频属性抓取结束
# 开始BV号为1Tz4y1C7CT视频属性的抓取
# BV号为1Tz4y1C7CT的视频属性抓取结束
# 开始BV号为1t64y1f74a视频属性的抓取
# 开始BV号为1t64y1f74a视频属性的抓取
# BV号为1t64y1f74a的视频属性抓取结束
# 开始BV号为1UV411h7w2视频属性的抓取
# BV号为1UV411h7w2的视频属性抓取结束
# 开始BV号为1Zi4y1c73m视频属性的抓取
# BV号为1Zi4y1c73m的视频属性抓取结束
# 开始BV号为19z4y1k7Ph视频属性的抓取
# BV号为19z4y1k7Ph的视频属性抓取结束
# 开始BV号为1AX4y1u7QQ视频属性的抓取
# BV号为1AX4y1u7QQ的视频属性抓取结束
# 开始BV号为1jf4y1i7zh视频属性的抓取
# 开始BV号为1jf4y1i7zh视频属性的抓取
# BV号为1jf4y1i7zh的视频属性抓取结束
# 开始BV号为14i4y15736视频属性的抓取
# BV号为14i4y15736的视频属性抓取结束
# 开始BV号为1Uf4y1Y7b7视频属性的抓取
# BV号为1Uf4y1Y7b7的视频属性抓取结束
# 开始BV号为1jr4y1F7S5视频属性的抓取
# BV号为1jr4y1F7S5的视频属性抓取结束
# 开始BV号为1xZ4y1g7h5视频属性的抓取
# BV号为1xZ4y1g7h5的视频属性抓取结束
# 开始BV号为1p64y1f71g视频属性的抓取
# BV号为1p64y1f71g的视频属性抓取结束
# 开始BV号为18a411F7Xk视频属性的抓取
# BV号为18a411F7Xk的视频属性抓取结束
# 开始BV号为1Wk4y1y7mS视频属性的抓取
# BV号为1Wk4y1y7mS的视频属性抓取结束
# 开始BV号为1Nt4y1S7uA视频属性的抓取
# BV号为1Nt4y1S7uA的视频属性抓取结束
# 开始BV号为1Ya4y177Bs视频属性的抓取
# BV号为1Ya4y177Bs的视频属性抓取结束
# 开始BV号为17i4y1M7LX视频属性的抓取
# BV号为17i4y1M7LX的视频属性抓取结束
# 开始BV号为1u64y1c7DU视频属性的抓取
# BV号为1u64y1c7DU的视频属性抓取结束
# 开始BV号为1CT4y1L7yn视频属性的抓取
# BV号为1CT4y1L7yn的视频属性抓取结束
# 开始BV号为1hZ4y1K7mz视频属性的抓取
# BV号为1hZ4y1K7mz的视频属性抓取结束
# 开始BV号为16C4y1t7Cw视频属性的抓取
# BV号为16C4y1t7Cw的视频属性抓取结束
# 开始BV号为1WC4y1t7ds视频属性的抓取
# BV号为1WC4y1t7ds的视频属性抓取结束
# 开始BV号为1Gv411i78C视频属性的抓取
# BV号为1Gv411i78C的视频属性抓取结束
# 开始BV号为1pK411T72f视频属性的抓取
# 开始BV号为1pK411T72f视频属性的抓取
# BV号为1pK411T72f的视频属性抓取结束
# 开始BV号为1dt4y1U7g9视频属性的抓取
# BV号为1dt4y1U7g9的视频属性抓取结束
# 开始BV号为1Ti4y1g7Dq视频属性的抓取
# 开始BV号为1Ti4y1g7Dq视频属性的抓取
# BV号为1Ti4y1g7Dq的视频属性抓取结束
# 开始BV号为1fA411Y7m6视频属性的抓取
# BV号为1fA411Y7m6的视频属性抓取结束
# 开始BV号为1gA411Y7BF视频属性的抓取
# BV号为1gA411Y7BF的视频属性抓取结束
# 开始BV号为17v411i7tx视频属性的抓取
# BV号为17v411i7tx的视频属性抓取结束
# 开始BV号为12A411J7UU视频属性的抓取
# BV号为12A411J7UU的视频属性抓取结束
# 开始BV号为155411b7mM视频属性的抓取
# BV号为155411b7mM的视频属性抓取结束
# 开始BV号为1kf4y197sS视频属性的抓取
# BV号为1kf4y197sS的视频属性抓取结束
# 开始BV号为1QV411z7hT视频属性的抓取
# BV号为1QV411z7hT的视频属性抓取结束
# 开始BV号为1SV411z7Pf视频属性的抓取
# BV号为1SV411z7Pf的视频属性抓取结束
# 开始BV号为1Cf4y197XB视频属性的抓取
# BV号为1Cf4y197XB的视频属性抓取结束
# 开始BV号为1iA411Y735视频属性的抓取
# BV号为1iA411Y735的视频属性抓取结束
# 开始BV号为1w5411Y76x视频属性的抓取
# 开始BV号为1w5411Y76x视频属性的抓取
# BV号为1w5411Y76x的视频属性抓取结束
# 开始BV号为1Fv411i7GV视频属性的抓取
# BV号为1Fv411i7GV的视频属性抓取结束
# 开始BV号为1SZ4y1K7Kn视频属性的抓取
# BV号为1SZ4y1K7Kn的视频属性抓取结束
# 开始BV号为1WZ4y1K7xG视频属性的抓取
# 开始BV号为1WZ4y1K7xG视频属性的抓取
# BV号为1WZ4y1K7xG的视频属性抓取结束
# 开始BV号为14K4y1v7FK视频属性的抓取
# BV号为14K4y1v7FK的视频属性抓取结束
# 开始BV号为1PK4y1v7uA视频属性的抓取
# BV号为1PK4y1v7uA的视频属性抓取结束
# 开始BV号为16p4y1q7iF视频属性的抓取
# BV号为16p4y1q7iF的视频属性抓取结束
# 开始BV号为1CV411U7iz视频属性的抓取
# BV号为1CV411U7iz的视频属性抓取结束
# 开始BV号为11T4y157kJ视频属性的抓取
# BV号为11T4y157kJ的视频属性抓取结束
# 开始BV号为1iC4y1t7NB视频属性的抓取
# BV号为1iC4y1t7NB的视频属性抓取结束
# 开始BV号为1uK411M7Xi视频属性的抓取
# BV号为1uK411M7Xi的视频属性抓取结束
# 开始BV号为11f4y197xk视频属性的抓取
# BV号为11f4y197xk的视频属性抓取结束
# 开始BV号为1YT4y1L7xS视频属性的抓取
# BV号为1YT4y1L7xS的视频属性抓取结束
# 开始BV号为1j54y1U7j3视频属性的抓取
# BV号为1j54y1U7j3的视频属性抓取结束
# 开始BV号为1ha4y1J7NE视频属性的抓取
# BV号为1ha4y1J7NE的视频属性抓取结束
# 开始BV号为1KA411n7hL视频属性的抓取
# BV号为1KA411n7hL的视频属性抓取结束
# 开始BV号为1rk4y1m7hs视频属性的抓取
# BV号为1rk4y1m7hs的视频属性抓取结束
# 开始BV号为1Jv411i7hY视频属性的抓取
# BV号为1Jv411i7hY的视频属性抓取结束
# 开始BV号为1gA411Y7ot视频属性的抓取
# BV号为1gA411Y7ot的视频属性抓取结束
# 开始BV号为1k54y1U7VH视频属性的抓取
# BV号为1k54y1U7VH的视频属性抓取结束
# 开始BV号为1kh41197tu视频属性的抓取
# BV号为1kh41197tu的视频属性抓取结束
# 开始BV号为1264y1c7U1视频属性的抓取
# BV号为1264y1c7U1的视频属性抓取结束
# 开始BV号为1qT4y1w7HT视频属性的抓取
# BV号为1qT4y1w7HT的视频属性抓取结束
# 开始BV号为1RK4y1Y7Hh视频属性的抓取
# BV号为1RK4y1Y7Hh的视频属性抓取结束
# 开始BV号为1sv41117ZS视频属性的抓取
# BV号为1sv41117ZS的视频属性抓取结束
# 开始BV号为1F64y1F7uW视频属性的抓取
# BV号为1F64y1F7uW的视频属性抓取结束
# 开始BV号为1Dz4y1f7EX视频属性的抓取
# BV号为1Dz4y1f7EX的视频属性抓取结束
# 开始BV号为1tD4y127oD视频属性的抓取
# BV号为1tD4y127oD的视频属性抓取结束
# 开始BV号为1Ja4y1E73X视频属性的抓取
# BV号为1Ja4y1E73X的视频属性抓取结束
# 开始BV号为15t4y1Q75Z视频属性的抓取
# BV号为15t4y1Q75Z的视频属性抓取结束
# 开始BV号为1iv411v7kR视频属性的抓取
# BV号为1iv411v7kR的视频属性抓取结束
# 开始BV号为1MD4y1m7Qa视频属性的抓取
# BV号为1MD4y1m7Qa的视频属性抓取结束
# 开始BV号为13K411M7H3视频属性的抓取
# BV号为13K411M7H3的视频属性抓取结束
# 开始BV号为1Hi4y1M7mA视频属性的抓取
# BV号为1Hi4y1M7mA的视频属性抓取结束
# 开始BV号为1Mk4y1y71t视频属性的抓取
# BV号为1Mk4y1y71t的视频属性抓取结束
# 开始BV号为1ei4y1M7XG视频属性的抓取
# BV号为1ei4y1M7XG的视频属性抓取结束
# 开始BV号为1754y1e7oA视频属性的抓取
# BV号为1754y1e7oA的视频属性抓取结束
# 开始BV号为1y54y1m7hC视频属性的抓取
# BV号为1y54y1m7hC的视频属性抓取结束
# 开始BV号为1RZ4y1T7xD视频属性的抓取
# BV号为1RZ4y1T7xD的视频属性抓取结束
# 开始BV号为1sD4y1271H视频属性的抓取
# BV号为1sD4y1271H的视频属性抓取结束
# 开始BV号为1nf4y1Q7b2视频属性的抓取
# BV号为1nf4y1Q7b2的视频属性抓取结束
# 开始BV号为12V411U7r7视频属性的抓取
# BV号为12V411U7r7的视频属性抓取结束
# 开始BV号为1Ef4y1Q7Vw视频属性的抓取
# BV号为1Ef4y1Q7Vw的视频属性抓取结束
# 开始BV号为1qA411n7pM视频属性的抓取
# BV号为1qA411n7pM的视频属性抓取结束
# 开始BV号为1Vh411d7Cm视频属性的抓取
# BV号为1Vh411d7Cm的视频属性抓取结束
# 开始BV号为1ot4y1U7za视频属性的抓取
# BV号为1ot4y1U7za的视频属性抓取结束
# 开始BV号为19v411v7Vs视频属性的抓取
# BV号为19v411v7Vs的视频属性抓取结束
# 开始BV号为11v411q7Ht视频属性的抓取
# BV号为11v411q7Ht的视频属性抓取结束
# 开始BV号为1UD4y1U7VF视频属性的抓取
# BV号为1UD4y1U7VF的视频属性抓取结束
# 开始BV号为16t4y1U71M视频属性的抓取
# BV号为16t4y1U71M的视频属性抓取结束
# 开始BV号为1QK4y1v7PX视频属性的抓取
# BV号为1QK4y1v7PX的视频属性抓取结束
# 开始BV号为1x54y1v7Ax视频属性的抓取
# BV号为1x54y1v7Ax的视频属性抓取结束
# 开始BV号为1cp4y1q7nu视频属性的抓取
# BV号为1cp4y1q7nu的视频属性抓取结束
# 开始BV号为1ht4y1D73C视频属性的抓取
# BV号为1ht4y1D73C的视频属性抓取结束
# 开始BV号为1E5411h7aD视频属性的抓取
# BV号为1E5411h7aD的视频属性抓取结束
# 开始BV号为1vD4y1U7en视频属性的抓取
# BV号为1vD4y1U7en的视频属性抓取结束
# 开始BV号为1Ph411R7QS视频属性的抓取
# BV号为1Ph411R7QS的视频属性抓取结束
# 开始BV号为1z54y127AM视频属性的抓取
# BV号为1z54y127AM的视频属性抓取结束
# 开始BV号为1Df4y1Q7gg视频属性的抓取
# BV号为1Df4y1Q7gg的视频属性抓取结束
# 开始BV号为1RK4y1a7Ln视频属性的抓取
# BV号为1RK4y1a7Ln的视频属性抓取结束
# 开始BV号为1Tp4y1e7DT视频属性的抓取
# BV号为1Tp4y1e7DT的视频属性抓取结束
# 开始BV号为1aA411J77Q视频属性的抓取
# BV号为1aA411J77Q的视频属性抓取结束
# 开始BV号为1Gp4y1e77H视频属性的抓取
# BV号为1Gp4y1e77H的视频属性抓取结束
# 开始BV号为1y54y127rc视频属性的抓取
# BV号为1y54y127rc的视频属性抓取结束
# 开始BV号为1XA411n7F4视频属性的抓取
# BV号为1XA411n7F4的视频属性抓取结束
# 开始BV号为18f4y1D7Me视频属性的抓取
# BV号为18f4y1D7Me的视频属性抓取结束
# 开始BV号为1fz4y1f7aH视频属性的抓取
# BV号为1fz4y1f7aH的视频属性抓取结束
# 开始BV号为1AA411J7RY视频属性的抓取
# BV号为1AA411J7RY的视频属性抓取结束
# 开始BV号为1Mk4y1y7S8视频属性的抓取
# BV号为1Mk4y1y7S8的视频属性抓取结束
# 开始BV号为1nk4y117xc视频属性的抓取
# BV号为1nk4y117xc的视频属性抓取结束
# 开始BV号为12K4y1a72f视频属性的抓取
# BV号为12K4y1a72f的视频属性抓取结束
# 开始BV号为19f4y1Q7pm视频属性的抓取
# BV号为19f4y1Q7pm的视频属性抓取结束
# 开始BV号为1Gi4y1E7B7视频属性的抓取
# BV号为1Gi4y1E7B7的视频属性抓取结束
# 开始BV号为15f4y1X7bh视频属性的抓取
# BV号为15f4y1X7bh的视频属性抓取结束
# 开始BV号为1N64y1F7Hz视频属性的抓取
# BV号为1N64y1F7Hz的视频属性抓取结束
# 开始BV号为1La4y1j7A7视频属性的抓取
# BV号为1La4y1j7A7的视频属性抓取结束
# 开始BV号为19A411E7yG视频属性的抓取
# BV号为19A411E7yG的视频属性抓取结束
# 开始BV号为1ak4y1275A视频属性的抓取
# BV号为1ak4y1275A的视频属性抓取结束
# 开始BV号为17v41117g8视频属性的抓取
# BV号为17v41117g8的视频属性抓取结束
# 开始BV号为1jA411J7hD视频属性的抓取
# BV号为1jA411J7hD的视频属性抓取结束
# 开始BV号为1ta4y1j7by视频属性的抓取
# BV号为1ta4y1j7by的视频属性抓取结束
# 开始BV号为1u541187Pi视频属性的抓取
# 开始BV号为1u541187Pi视频属性的抓取
# BV号为1u541187Pi的视频属性抓取结束
# 开始BV号为1J54y1m7hp视频属性的抓取
# BV号为1J54y1m7hp的视频属性抓取结束
# 开始BV号为11T4y1w73E视频属性的抓取
# BV号为11T4y1w73E的视频属性抓取结束
# 开始BV号为1oK411N7U4视频属性的抓取
# BV号为1oK411N7U4的视频属性抓取结束
# 开始BV号为1f54y127Uo视频属性的抓取
# BV号为1f54y127Uo的视频属性抓取结束
# 开始BV号为1gK4y1Y7Ck视频属性的抓取
# BV号为1gK4y1Y7Ck的视频属性抓取结束
# 开始BV号为1uV411m7Bt视频属性的抓取
# BV号为1uV411m7Bt的视频属性抓取结束
# 开始BV号为1954y1C7Lx视频属性的抓取
# BV号为1954y1C7Lx的视频属性抓取结束
# 开始BV号为1ui4y1u7b9视频属性的抓取
# BV号为1ui4y1u7b9的视频属性抓取结束
# 开始BV号为12T4y1A7bF视频属性的抓取
# BV号为12T4y1A7bF的视频属性抓取结束
# 开始BV号为1V541187So视频属性的抓取
# BV号为1V541187So的视频属性抓取结束
# 开始BV号为1ep4y1a7bp视频属性的抓取
# BV号为1ep4y1a7bp的视频属性抓取结束
# 开始BV号为1Bh411R7bs视频属性的抓取
# BV号为1Bh411R7bs的视频属性抓取结束
# 开始BV号为1654y1y7ik视频属性的抓取
# BV号为1654y1y7ik的视频属性抓取结束
# 开始BV号为1xV411m7eB视频属性的抓取
# BV号为1xV411m7eB的视频属性抓取结束
# 开始BV号为1Mz4y1Z7Bi视频属性的抓取
# BV号为1Mz4y1Z7Bi的视频属性抓取结束
# 开始BV号为1kD4y1R7kY视频属性的抓取
# BV号为1kD4y1R7kY的视频属性抓取结束
# 开始BV号为1WA411J7Ao视频属性的抓取
# BV号为1WA411J7Ao的视频属性抓取结束
# 开始BV号为11h411X7tG视频属性的抓取
# BV号为11h411X7tG的视频属性抓取结束
# 开始BV号为1Yi4y1E7U2视频属性的抓取
# BV号为1Yi4y1E7U2的视频属性抓取结束
# 开始BV号为19t4y1S7Ga视频属性的抓取
# BV号为19t4y1S7Ga的视频属性抓取结束
# 开始BV号为1Qt4y1i7RK视频属性的抓取
# BV号为1Qt4y1i7RK的视频属性抓取结束
# 开始BV号为1Ja4y1E7MP视频属性的抓取
# BV号为1Ja4y1E7MP的视频属性抓取结束
# 开始BV号为1vi4y1M7Z3视频属性的抓取
# BV号为1vi4y1M7Z3的视频属性抓取结束
# 开始BV号为12Z4y1N79s视频属性的抓取
# 开始BV号为12Z4y1N79s视频属性的抓取
# BV号为12Z4y1N79s的视频属性抓取结束
# 开始BV号为1Qp4y1e79M视频属性的抓取
# BV号为1Qp4y1e79M的视频属性抓取结束
# 开始BV号为1P54y1v77J视频属性的抓取
# BV号为1P54y1v77J的视频属性抓取结束
# 开始BV号为1dT4y1w72F视频属性的抓取
# BV号为1dT4y1w72F的视频属性抓取结束
# 开始BV号为15y4y1y7em视频属性的抓取
# BV号为15y4y1y7em的视频属性抓取结束
# 开始BV号为1zK4y1a79b视频属性的抓取
# BV号为1zK4y1a79b的视频属性抓取结束
# 开始BV号为1Hp4y1e7Gu视频属性的抓取
# BV号为1Hp4y1e7Gu的视频属性抓取结束
# 开始BV号为1Jk4y1177Y视频属性的抓取
# BV号为1Jk4y1177Y的视频属性抓取结束
# 开始BV号为11f4y1D7Hw视频属性的抓取
# BV号为11f4y1D7Hw的视频属性抓取结束
# 开始BV号为1Dp4y1Y7sm视频属性的抓取
# BV号为1Dp4y1Y7sm的视频属性抓取结束
# 开始BV号为1Yf4y1D7E4视频属性的抓取
# BV号为1Yf4y1D7E4的视频属性抓取结束
# 开始BV号为1zT4y1L7og视频属性的抓取
# BV号为1zT4y1L7og的视频属性抓取结束
# 开始BV号为1NA411H7yG视频属性的抓取
# BV号为1NA411H7yG的视频属性抓取结束
# 开始BV号为1mp4y1a7V6视频属性的抓取
# BV号为1mp4y1a7V6的视频属性抓取结束
# 开始BV号为1vz4y1d7eq视频属性的抓取
# BV号为1vz4y1d7eq的视频属性抓取结束
# 开始BV号为1Jy4y1k7YN视频属性的抓取
# BV号为1Jy4y1k7YN的视频属性抓取结束
# 开始BV号为1b54y1y7cd视频属性的抓取
# BV号为1b54y1y7cd的视频属性抓取结束
# 开始BV号为1s64y1F7Vk视频属性的抓取
# BV号为1s64y1F7Vk的视频属性抓取结束
# 开始BV号为1K541187FS视频属性的抓取
# BV号为1K541187FS的视频属性抓取结束
# 开始BV号为1Jh411X7F2视频属性的抓取
# BV号为1Jh411X7F2的视频属性抓取结束
# 开始BV号为15k4y117Nm视频属性的抓取
# BV号为15k4y117Nm的视频属性抓取结束
# 开始BV号为1Tk4y117KY视频属性的抓取
# BV号为1Tk4y117KY的视频属性抓取结束
# 开始BV号为1M54y1y7nX视频属性的抓取
# BV号为1M54y1y7nX的视频属性抓取结束
# 开始BV号为1qt4y1i76R视频属性的抓取
# BV号为1qt4y1i76R的视频属性抓取结束
# 开始BV号为1p54y1m7H4视频属性的抓取
# BV号为1p54y1m7H4的视频属性抓取结束
# 开始BV号为1ZZ4y1P7At视频属性的抓取
# BV号为1ZZ4y1P7At的视频属性抓取结束
# 开始BV号为1ek4y1C7FG视频属性的抓取
# BV号为1ek4y1C7FG的视频属性抓取结束
# 开始BV号为1j54y1m7m8视频属性的抓取
# BV号为1j54y1m7m8的视频属性抓取结束
# 开始BV号为12V411m7mH视频属性的抓取
# BV号为12V411m7mH的视频属性抓取结束
# 开始BV号为1JK4y1a7q3视频属性的抓取
# BV号为1JK4y1a7q3的视频属性抓取结束
# 开始BV号为1Sv411C7qf视频属性的抓取
# BV号为1Sv411C7qf的视频属性抓取结束
# 开始BV号为1WD4y1o7sP视频属性的抓取
# BV号为1WD4y1o7sP的视频属性抓取结束
# 开始BV号为1Gk4y1175b视频属性的抓取
# BV号为1Gk4y1175b的视频属性抓取结束
# 开始BV号为1mh411X7WJ视频属性的抓取
# BV号为1mh411X7WJ的视频属性抓取结束
# 开始BV号为1iK411P7c9视频属性的抓取
# BV号为1iK411P7c9的视频属性抓取结束
# 开始BV号为1Zv41117cz视频属性的抓取
# 开始BV号为1Zv41117cz视频属性的抓取
# BV号为1Zv41117cz的视频属性抓取结束
# 开始BV号为13T4y1c7wC视频属性的抓取
# BV号为13T4y1c7wC的视频属性抓取结束
# 开始BV号为17p4y1e7JQ视频属性的抓取
# BV号为17p4y1e7JQ的视频属性抓取结束
# 开始BV号为1ma4y1j7St视频属性的抓取
# BV号为1ma4y1j7St的视频属性抓取结束
# 开始BV号为1kD4y1o7e7视频属性的抓取
# BV号为1kD4y1o7e7的视频属性抓取结束
# 开始BV号为1jZ4y157sp视频属性的抓取
# BV号为1jZ4y157sp的视频属性抓取结束
# 开始BV号为1mD4y1d7RJ视频属性的抓取
# BV号为1mD4y1d7RJ的视频属性抓取结束
# 开始BV号为1kp4y1e7HS视频属性的抓取
# BV号为1kp4y1e7HS的视频属性抓取结束
# 开始BV号为1ZV411U7yq视频属性的抓取
# BV号为1ZV411U7yq的视频属性抓取结束
# 开始BV号为1Bh411R7ST视频属性的抓取
# BV号为1Bh411R7ST的视频属性抓取结束
# 开始BV号为1fi4y177BY视频属性的抓取
# BV号为1fi4y177BY的视频属性抓取结束
# 开始BV号为1d54y1e7yG视频属性的抓取
# BV号为1d54y1e7yG的视频属性抓取结束
# 开始BV号为1JA411n7Zk视频属性的抓取
# BV号为1JA411n7Zk的视频属性抓取结束
# 开始BV号为1P54y1y7tA视频属性的抓取
# BV号为1P54y1y7tA的视频属性抓取结束
# 开始BV号为1XA411E7HD视频属性的抓取
# BV号为1XA411E7HD的视频属性抓取结束
# 开始BV号为1iz4y1Z7tS视频属性的抓取
# BV号为1iz4y1Z7tS的视频属性抓取结束
# 开始BV号为1K54y1m7R4视频属性的抓取
# BV号为1K54y1m7R4的视频属性抓取结束
# 开始BV号为1np4y1k7Vm视频属性的抓取
# BV号为1np4y1k7Vm的视频属性抓取结束
# 开始BV号为1KK4y1h76a视频属性的抓取
# BV号为1KK4y1h76a的视频属性抓取结束
# 开始BV号为14Z4y1L7TJ视频属性的抓取
# BV号为14Z4y1L7TJ的视频属性抓取结束
# 开始BV号为1Zf4y1D7Md视频属性的抓取
# BV号为1Zf4y1D7Md的视频属性抓取结束
# 开始BV号为1ya4y1L7RK视频属性的抓取
# BV号为1ya4y1L7RK的视频属性抓取结束
# 开始BV号为17T4y1w7kj视频属性的抓取
# BV号为17T4y1w7kj的视频属性抓取结束
# 开始BV号为1ft4y1Y7gu视频属性的抓取
# BV号为1ft4y1Y7gu的视频属性抓取结束
# 开始BV号为1pK411N7fp视频属性的抓取
# BV号为1pK411N7fp的视频属性抓取结束
# 开始BV号为1Lk4y1C7xA视频属性的抓取
# BV号为1Lk4y1C7xA的视频属性抓取结束
# 开始BV号为17p4y1Y7DR视频属性的抓取
# BV号为17p4y1Y7DR的视频属性抓取结束
# 开始BV号为1nr4y1w7BP视频属性的抓取
# BV号为1nr4y1w7BP的视频属性抓取结束
# 开始BV号为1Uz4y1d7yB视频属性的抓取
# BV号为1Uz4y1d7yB的视频属性抓取结束
# 开始BV号为1rv41167fa视频属性的抓取
# BV号为1rv41167fa的视频属性抓取结束
# 开始BV号为1Ki4y177Z8视频属性的抓取
# BV号为1Ki4y177Z8的视频属性抓取结束
# 开始BV号为1RV411y7r8视频属性的抓取
# BV号为1RV411y7r8的视频属性抓取结束
# 开始BV号为14K4y1h7yF视频属性的抓取
# BV号为14K4y1h7yF的视频属性抓取结束
# 开始BV号为1g541177Df视频属性的抓取
# 开始BV号为1g541177Df视频属性的抓取
# BV号为1g541177Df的视频属性抓取结束
# 开始BV号为1Cz4y1d7FH视频属性的抓取
# BV号为1Cz4y1d7FH的视频属性抓取结束
# 开始BV号为17k4y1C7b4视频属性的抓取
# BV号为17k4y1C7b4的视频属性抓取结束
# 开始BV号为1Za411A7By视频属性的抓取
# BV号为1Za411A7By的视频属性抓取结束
# 开始BV号为1za4y1s7aZ视频属性的抓取
# BV号为1za4y1s7aZ的视频属性抓取结束
# 开始BV号为1qp4y1Y7dd视频属性的抓取
# BV号为1qp4y1Y7dd的视频属性抓取结束
# 开始BV号为1fa411A7G6视频属性的抓取
# BV号为1fa411A7G6的视频属性抓取结束
# 开始BV号为1v5411j76W视频属性的抓取
# BV号为1v5411j76W的视频属性抓取结束
# 开始BV号为1Gy4y187fG视频属性的抓取
# BV号为1Gy4y187fG的视频属性抓取结束
# 开始BV号为1Ny4y187bG视频属性的抓取
# BV号为1Ny4y187bG的视频属性抓取结束
# 开始BV号为1fz4y1Z7o2视频属性的抓取
# BV号为1fz4y1Z7o2的视频属性抓取结束
# 开始BV号为1Kp4y1k7jY视频属性的抓取
# BV号为1Kp4y1k7jY的视频属性抓取结束
# 开始BV号为1ny4y1r7e3视频属性的抓取
# BV号为1ny4y1r7e3的视频属性抓取结束
# 开始BV号为1yz4y1Z77V视频属性的抓取
# BV号为1yz4y1Z77V的视频属性抓取结束
# 开始BV号为1JD4y1R7Ko视频属性的抓取
# BV号为1JD4y1R7Ko的视频属性抓取结束
# 开始BV号为19K4y1771J视频属性的抓取
# BV号为19K4y1771J的视频属性抓取结束
# 开始BV号为1Ek4y1C7jq视频属性的抓取
# BV号为1Ek4y1C7jq的视频属性抓取结束
# 开始BV号为1hD4y1R7Sw视频属性的抓取
# BV号为1hD4y1R7Sw的视频属性抓取结束
# 开始BV号为1Vf4y1q7zX视频属性的抓取
# BV号为1Vf4y1q7zX的视频属性抓取结束
# 开始BV号为1Jr4y1w7XF视频属性的抓取
# BV号为1Jr4y1w7XF的视频属性抓取结束
# 开始BV号为1Xf4y1B7pK视频属性的抓取
# BV号为1Xf4y1B7pK的视频属性抓取结束
# 开始BV号为1DK4y1f76y视频属性的抓取
# BV号为1DK4y1f76y的视频属性抓取结束
# 开始BV号为1rz4y1d76h视频属性的抓取
# BV号为1rz4y1d76h的视频属性抓取结束
# 开始BV号为1Wa411A7ik视频属性的抓取
# BV号为1Wa411A7ik的视频属性抓取结束
# 开始BV号为1jy4y1r7pH视频属性的抓取
# BV号为1jy4y1r7pH的视频属性抓取结束
# 开始BV号为1z54y1k76w视频属性的抓取
# BV号为1z54y1k76w的视频属性抓取结束
# 开始BV号为1oy4y1k7JL视频属性的抓取
# BV号为1oy4y1k7JL的视频属性抓取结束
# 开始BV号为1mK4y177W9视频属性的抓取
# BV号为1mK4y177W9的视频属性抓取结束
# 开始BV号为1cT4y1w7c1视频属性的抓取
# BV号为1cT4y1w7c1的视频属性抓取结束
# 开始BV号为1Yz4y1C7iT视频属性的抓取
# BV号为1Yz4y1C7iT的视频属性抓取结束
# 开始BV号为1b54y1C7DK视频属性的抓取
# BV号为1b54y1C7DK的视频属性抓取结束
# 开始BV号为1Up4y1a7y1视频属性的抓取
# BV号为1Up4y1a7y1的视频属性抓取结束
# 开始BV号为1yK4y1h7cU视频属性的抓取
# BV号为1yK4y1h7cU的视频属性抓取结束
# 开始BV号为1Ui4y1E7Dv视频属性的抓取
# BV号为1Ui4y1E7Dv的视频属性抓取结束
# 开始BV号为1dA411L7Fa视频属性的抓取
# BV号为1dA411L7Fa的视频属性抓取结束
# 开始BV号为1dT4y1c7aG视频属性的抓取
# BV号为1dT4y1c7aG的视频属性抓取结束
# 开始BV号为1hT4y1F7NV视频属性的抓取
# BV号为1hT4y1F7NV的视频属性抓取结束
# 开始BV号为1Ut4y1e7EV视频属性的抓取
# BV号为1Ut4y1e7EV的视频属性抓取结束
# 开始BV号为17K411A7xi视频属性的抓取
# BV号为17K411A7xi的视频属性抓取结束
# 开始BV号为1fT4y1c7Bo视频属性的抓取
# BV号为1fT4y1c7Bo的视频属性抓取结束
# 开始BV号为15y4y1r7dD视频属性的抓取
# BV号为15y4y1r7dD的视频属性抓取结束
# 开始BV号为1r541157E9视频属性的抓取
# BV号为1r541157E9的视频属性抓取结束
# 开始BV号为11y4y1r7ps视频属性的抓取
# BV号为11y4y1r7ps的视频属性抓取结束
# 开始BV号为1TZ4y1V7sy视频属性的抓取
# BV号为1TZ4y1V7sy的视频属性抓取结束
# 开始BV号为1W54y117VE视频属性的抓取
# BV号为1W54y117VE的视频属性抓取结束
# 开始BV号为1ga411A7vh视频属性的抓取
# BV号为1ga411A7vh的视频属性抓取结束
# 开始BV号为1Zf4y1D7aB视频属性的抓取
# BV号为1Zf4y1D7aB的视频属性抓取结束
# 开始BV号为1Ji4y1E75b视频属性的抓取
# BV号为1Ji4y1E75b的视频属性抓取结束
# 开始BV号为1wp4y1k7aD视频属性的抓取
# BV号为1wp4y1k7aD的视频属性抓取结束
# 开始BV号为1ep4y1Y7f9视频属性的抓取
# BV号为1ep4y1Y7f9的视频属性抓取结束
# 开始BV号为1xa411A7B2视频属性的抓取
# BV号为1xa411A7B2的视频属性抓取结束
# 开始BV号为1da411A7j1视频属性的抓取
# BV号为1da411A7j1的视频属性抓取结束
# 开始BV号为1zv411k7r9视频属性的抓取
# BV号为1zv411k7r9的视频属性抓取结束
# 开始BV号为1sh411976g视频属性的抓取
# BV号为1sh411976g的视频属性抓取结束
# 开始BV号为1J54y1k7g6视频属性的抓取
# BV号为1J54y1k7g6的视频属性抓取结束
# 开始BV号为1hp4y1Y7rG视频属性的抓取
# BV号为1hp4y1Y7rG的视频属性抓取结束
# 开始BV号为1PD4y197zS视频属性的抓取
# BV号为1PD4y197zS的视频属性抓取结束
# 开始BV号为1Up4y1k7So视频属性的抓取
# BV号为1Up4y1k7So的视频属性抓取结束
# 开始BV号为1UK4y177Z5视频属性的抓取
# BV号为1UK4y177Z5的视频属性抓取结束
# 开始BV号为19z4y1Z7as视频属性的抓取
# BV号为19z4y1Z7as的视频属性抓取结束
# 开始BV号为1ki4y1j7zf视频属性的抓取
# BV号为1ki4y1j7zf的视频属性抓取结束
# 开始BV号为1bk4y1C7RG视频属性的抓取
# BV号为1bk4y1C7RG的视频属性抓取结束
# 开始BV号为1D54y117hn视频属性的抓取
# BV号为1D54y117hn的视频属性抓取结束
# 开始BV号为1LA41177Ex视频属性的抓取
# BV号为1LA41177Ex的视频属性抓取结束
# 开始BV号为14i4y177X2视频属性的抓取
# BV号为14i4y177X2的视频属性抓取结束
# 开始BV号为1fk4y1k7kR视频属性的抓取
# BV号为1fk4y1k7kR的视频属性抓取结束
# 开始BV号为1Na411A7mM视频属性的抓取
# BV号为1Na411A7mM的视频属性抓取结束
# 开始BV号为1df4y1q7Tv视频属性的抓取
# BV号为1df4y1q7Tv的视频属性抓取结束
# 开始BV号为1qK4y177CY视频属性的抓取
# BV号为1qK4y177CY的视频属性抓取结束
# 开始BV号为13v411r7ra视频属性的抓取
# BV号为13v411r7ra的视频属性抓取结束
# 开始BV号为1vT4y1F73P视频属性的抓取
# BV号为1vT4y1F73P的视频属性抓取结束
# 开始BV号为1RK4y177nN视频属性的抓取
# BV号为1RK4y177nN的视频属性抓取结束
# 开始BV号为1oK411A7Xo视频属性的抓取
# BV号为1oK411A7Xo的视频属性抓取结束
# 开始BV号为1Pi4y1L7WT视频属性的抓取
# BV号为1Pi4y1L7WT的视频属性抓取结束
# 开始BV号为1iy4y1C7Dr视频属性的抓取
# BV号为1iy4y1C7Dr的视频属性抓取结束
# 开始BV号为1ni4y1E7Df视频属性的抓取
# BV号为1ni4y1E7Df的视频属性抓取结束
# 开始BV号为1Xa411w7oq视频属性的抓取
# BV号为1Xa411w7oq的视频属性抓取结束
# 开始BV号为1R54y1k7cd视频属性的抓取
# BV号为1R54y1k7cd的视频属性抓取结束
# 开始BV号为1KA411E7RY视频属性的抓取
# BV号为1KA411E7RY的视频属性抓取结束
# 开始BV号为1Ff4y1B7oF视频属性的抓取
# BV号为1Ff4y1B7oF的视频属性抓取结束
# 开始BV号为1RD4y1R7qH视频属性的抓取
# BV号为1RD4y1R7qH的视频属性抓取结束
# 开始BV号为19V41117n9视频属性的抓取
# BV号为19V41117n9的视频属性抓取结束
# 开始BV号为1BD4y1d726视频属性的抓取
# BV号为1BD4y1d726的视频属性抓取结束
# 开始BV号为1hv411k7hu视频属性的抓取
# BV号为1hv411k7hu的视频属性抓取结束
# 2020-12-19 14:10:49.495868

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-16-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_donghua_teshe.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月     96   96    96   96   96   96   96   96    96      96   96    96   96
# 8月    106  106   106  106  106  106  106  106   106     106  106   106  106
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月   100  100  100  100  100  100   100
# 2月   100  100  100  100  100  100   100
# 3月   100  100  100  100  100  100   100
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月   100  100  100  100  100  100   100
# 7月    96   96   96   96   96   96    96
# 8月   106  106  106  106  106  106   106
# 9月   100  100  100  100  100  100   100

# %%
channel_donghua_teshe.to_json('channel_donghua_teshe.json')
