# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_donghua_MMD·3D=pd.DataFrame(columns=columns)
channel_donghua_MMD·3D
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[1]/div/a/span').click()  #选择“动画”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[1]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '动画'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[3]/a').click()  #选择“MMD·3D”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[3]/a').text
sub_channel
# Out:
# 'MMD·3D'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(8,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_donghua_MMD·3D.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-19 09:37:47.215269
# <ipython-input-24-764e03b54bf4>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-24-764e03b54bf4>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-24-764e03b54bf4>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1Li4y1g7r2视频属性的抓取
# BV号为1Li4y1g7r2的视频属性抓取结束
# <ipython-input-24-764e03b54bf4>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1QA411Y75C视频属性的抓取
# BV号为1QA411Y75C的视频属性抓取结束
# 开始BV号为1ez4y1f7V7视频属性的抓取
# BV号为1ez4y1f7V7的视频属性抓取结束
# 开始BV号为1V64y1c7xJ视频属性的抓取
# BV号为1V64y1c7xJ的视频属性抓取结束
# 开始BV号为1N5411b7cT视频属性的抓取
# BV号为1N5411b7cT的视频属性抓取结束
# 开始BV号为1cV411m7NG视频属性的抓取
# BV号为1cV411m7NG的视频属性抓取结束
# 开始BV号为1WV411z7ny视频属性的抓取
# BV号为1WV411z7ny的视频属性抓取结束
# 开始BV号为1sk4y127xJ视频属性的抓取
# BV号为1sk4y127xJ的视频属性抓取结束
# 开始BV号为1aZ4y1K76Q视频属性的抓取
# BV号为1aZ4y1K76Q的视频属性抓取结束
# 开始BV号为1bh411d7ND视频属性的抓取
# BV号为1bh411d7ND的视频属性抓取结束
# 开始BV号为15h411o7hD视频属性的抓取
# BV号为15h411o7hD的视频属性抓取结束
# 开始BV号为1DK411T7nP视频属性的抓取
# BV号为1DK411T7nP的视频属性抓取结束
# 开始BV号为1S541187xd视频属性的抓取
# BV号为1S541187xd的视频属性抓取结束
# 开始BV号为1ua4y1E7LQ视频属性的抓取
# BV号为1ua4y1E7LQ的视频属性抓取结束
# 开始BV号为1TZ4y1K7Qi视频属性的抓取
# BV号为1TZ4y1K7Qi的视频属性抓取结束
# 开始BV号为1QA411a7JF视频属性的抓取
# BV号为1QA411a7JF的视频属性抓取结束
# 开始BV号为1if4y197EQ视频属性的抓取
# BV号为1if4y197EQ的视频属性抓取结束
# 开始BV号为1bf4y1Q7XU视频属性的抓取
# BV号为1bf4y1Q7XU的视频属性抓取结束
# 开始BV号为1xt4y1D7Fa视频属性的抓取
# BV号为1xt4y1D7Fa的视频属性抓取结束
# 开始BV号为1bK4y1Y7EJ视频属性的抓取
# BV号为1bK4y1Y7EJ的视频属性抓取结束
# 开始BV号为1jv411i7Wa视频属性的抓取
# BV号为1jv411i7Wa的视频属性抓取结束
# 开始BV号为115411872o视频属性的抓取
# BV号为115411872o的视频属性抓取结束
# 开始BV号为1Ev41117nd视频属性的抓取
# 开始BV号为1Ev41117nd视频属性的抓取
# BV号为1Ev41117nd的视频属性抓取结束
# 开始BV号为1oK411T7VV视频属性的抓取
# BV号为1oK411T7VV的视频属性抓取结束
# 开始BV号为1m54y1i7ti视频属性的抓取
# BV号为1m54y1i7ti的视频属性抓取结束
# 开始BV号为1Rf4y197hE视频属性的抓取
# BV号为1Rf4y197hE的视频属性抓取结束
# 开始BV号为1Nt4y1D7kT视频属性的抓取
# BV号为1Nt4y1D7kT的视频属性抓取结束
# 开始BV号为1a54y1i7S3视频属性的抓取
# BV号为1a54y1i7S3的视频属性抓取结束
# 开始BV号为1m541187MB视频属性的抓取
# BV号为1m541187MB的视频属性抓取结束
# 开始BV号为16K411T7aX视频属性的抓取
# BV号为16K411T7aX的视频属性抓取结束
# 开始BV号为1fC4y147JE视频属性的抓取
# BV号为1fC4y147JE的视频属性抓取结束
# 开始BV号为1RA411a7Xm视频属性的抓取
# BV号为1RA411a7Xm的视频属性抓取结束
# 开始BV号为1Vv411v791视频属性的抓取
# BV号为1Vv411v791的视频属性抓取结束
# 开始BV号为1wh411d7SN视频属性的抓取
# BV号为1wh411d7SN的视频属性抓取结束
# 开始BV号为1Fp4y1v7iz视频属性的抓取
# BV号为1Fp4y1v7iz的视频属性抓取结束
# 开始BV号为1at4y1X7wa视频属性的抓取
# BV号为1at4y1X7wa的视频属性抓取结束
# 开始BV号为1fV411U76d视频属性的抓取
# BV号为1fV411U76d的视频属性抓取结束
# 开始BV号为1XC4y1t7qg视频属性的抓取
# BV号为1XC4y1t7qg的视频属性抓取结束
# 开始BV号为1PT4y1L7RM视频属性的抓取
# BV号为1PT4y1L7RM的视频属性抓取结束
# 开始BV号为1Vt4y1S71B视频属性的抓取
# BV号为1Vt4y1S71B的视频属性抓取结束
# 开始BV号为1ph411d7zh视频属性的抓取
# BV号为1ph411d7zh的视频属性抓取结束
# 开始BV号为11D4y1U7Bm视频属性的抓取
# BV号为11D4y1U7Bm的视频属性抓取结束
# 开始BV号为1Ch411d7J6视频属性的抓取
# BV号为1Ch411d7J6的视频属性抓取结束
# 开始BV号为1PA411Y7M3视频属性的抓取
# BV号为1PA411Y7M3的视频属性抓取结束
# 开始BV号为1Bi4y1u7UA视频属性的抓取
# BV号为1Bi4y1u7UA的视频属性抓取结束
# 开始BV号为1ck4y1U7od视频属性的抓取
# BV号为1ck4y1U7od的视频属性抓取结束
# 开始BV号为1Ak4y127kG视频属性的抓取
# BV号为1Ak4y127kG的视频属性抓取结束
# 开始BV号为1oV411z7oc视频属性的抓取
# BV号为1oV411z7oc的视频属性抓取结束
# 开始BV号为13i4y1G7CV视频属性的抓取
# BV号为13i4y1G7CV的视频属性抓取结束
# 开始BV号为1j5411a7cB视频属性的抓取
# BV号为1j5411a7cB的视频属性抓取结束
# 开始BV号为1Ek4y1m71o视频属性的抓取
# BV号为1Ek4y1m71o的视频属性抓取结束
# 开始BV号为15i4y1G7Nk视频属性的抓取
# BV号为15i4y1G7Nk的视频属性抓取结束
# 开始BV号为1Kk4y1U7Ky视频属性的抓取
# BV号为1Kk4y1U7Ky的视频属性抓取结束
# 开始BV号为1JC4y1t73H视频属性的抓取
# BV号为1JC4y1t73H的视频属性抓取结束
# 开始BV号为11T4y1j7Y6视频属性的抓取
# BV号为11T4y1j7Y6的视频属性抓取结束
# 开始BV号为1SC4y1t7P1视频属性的抓取
# BV号为1SC4y1t7P1的视频属性抓取结束
# 开始BV号为1EC4y187pL视频属性的抓取
# BV号为1EC4y187pL的视频属性抓取结束
# 开始BV号为1JV411U7HF视频属性的抓取
# BV号为1JV411U7HF的视频属性抓取结束
# 开始BV号为1Et4y1Q7qF视频属性的抓取
# BV号为1Et4y1Q7qF的视频属性抓取结束
# 开始BV号为1jz4y1f7No视频属性的抓取
# BV号为1jz4y1f7No的视频属性抓取结束
# 开始BV号为1Ef4y197pH视频属性的抓取
# BV号为1Ef4y197pH的视频属性抓取结束
# 开始BV号为1d541187pd视频属性的抓取
# BV号为1d541187pd的视频属性抓取结束
# 开始BV号为1iv411q7at视频属性的抓取
# BV号为1iv411q7at的视频属性抓取结束
# 开始BV号为1PT4y1L7ER视频属性的抓取
# BV号为1PT4y1L7ER的视频属性抓取结束
# 开始BV号为1jv411v7Ck视频属性的抓取
# BV号为1jv411v7Ck的视频属性抓取结束
# 开始BV号为14p4y1q7WN视频属性的抓取
# BV号为14p4y1q7WN的视频属性抓取结束
# 开始BV号为16i4y1u73V视频属性的抓取
# BV号为16i4y1u73V的视频属性抓取结束
# 开始BV号为1264y1F7s5视频属性的抓取
# BV号为1264y1F7s5的视频属性抓取结束
# 开始BV号为1pk4y1y71X视频属性的抓取
# BV号为1pk4y1y71X的视频属性抓取结束
# 开始BV号为12V411U7xj视频属性的抓取
# BV号为12V411U7xj的视频属性抓取结束
# 开始BV号为1TD4y1m7Rs视频属性的抓取
# BV号为1TD4y1m7Rs的视频属性抓取结束
# 开始BV号为1T54y1i7CA视频属性的抓取
# BV号为1T54y1i7CA的视频属性抓取结束
# 开始BV号为14p4y1v7yf视频属性的抓取
# BV号为14p4y1v7yf的视频属性抓取结束
# 开始BV号为1nh411d76E视频属性的抓取
# BV号为1nh411d76E的视频属性抓取结束
# 开始BV号为1KA411v7XJ视频属性的抓取
# BV号为1KA411v7XJ的视频属性抓取结束
# 开始BV号为1kk4y1m7Np视频属性的抓取
# BV号为1kk4y1m7Np的视频属性抓取结束
# 开始BV号为1v5411a7BB视频属性的抓取
# BV号为1v5411a7BB的视频属性抓取结束
# 开始BV号为1Sy4y1C79u视频属性的抓取
# BV号为1Sy4y1C79u的视频属性抓取结束
# 开始BV号为1r541187VK视频属性的抓取
# BV号为1r541187VK的视频属性抓取结束
# 开始BV号为1XA411n7KQ视频属性的抓取
# BV号为1XA411n7KQ的视频属性抓取结束
# 开始BV号为18V411U7rU视频属性的抓取
# BV号为18V411U7rU的视频属性抓取结束
# 开始BV号为1Qp4y1i7nQ视频属性的抓取
# BV号为1Qp4y1i7nQ的视频属性抓取结束
# 开始BV号为1G54y1U7Km视频属性的抓取
# BV号为1G54y1U7Km的视频属性抓取结束
# 开始BV号为1rv411v7dw视频属性的抓取
# BV号为1rv411v7dw的视频属性抓取结束
# 开始BV号为1Ti4y1g75y视频属性的抓取
# BV号为1Ti4y1g75y的视频属性抓取结束
# 开始BV号为1w54y1D72C视频属性的抓取
# BV号为1w54y1D72C的视频属性抓取结束
# 开始BV号为1cV411S7bD视频属性的抓取
# BV号为1cV411S7bD的视频属性抓取结束
# 开始BV号为1cA411n7U3视频属性的抓取
# BV号为1cA411n7U3的视频属性抓取结束
# 开始BV号为1ST4y1j7VQ视频属性的抓取
# BV号为1ST4y1j7VQ的视频属性抓取结束
# 开始BV号为1u54y1v7bo视频属性的抓取
# BV号为1u54y1v7bo的视频属性抓取结束
# 开始BV号为1d54y1m7Kc视频属性的抓取
# BV号为1d54y1m7Kc的视频属性抓取结束
# 开始BV号为1NC4y1t7fR视频属性的抓取
# BV号为1NC4y1t7fR的视频属性抓取结束
# 开始BV号为1xT4y1j7tG视频属性的抓取
# BV号为1xT4y1j7tG的视频属性抓取结束
# 开始BV号为1DC4y1b7MV视频属性的抓取
# BV号为1DC4y1b7MV的视频属性抓取结束
# 开始BV号为1Dt4y1U7nw视频属性的抓取
# BV号为1Dt4y1U7nw的视频属性抓取结束
# 开始BV号为1hZ4y1K7oL视频属性的抓取
# BV号为1hZ4y1K7oL的视频属性抓取结束
# 开始BV号为1MZ4y1M7bT视频属性的抓取
# BV号为1MZ4y1M7bT的视频属性抓取结束
# 开始BV号为1o541187G8视频属性的抓取
# BV号为1o541187G8的视频属性抓取结束
# 开始BV号为15v411i7tb视频属性的抓取
# BV号为15v411i7tb的视频属性抓取结束
# 开始BV号为1zC4y1t75B视频属性的抓取
# BV号为1zC4y1t75B的视频属性抓取结束
# 开始BV号为15A41177WW视频属性的抓取
# BV号为15A41177WW的视频属性抓取结束
# 开始BV号为1ny4y1y7Ue视频属性的抓取
# BV号为1ny4y1y7Ue的视频属性抓取结束
# 开始BV号为1SV411m7da视频属性的抓取
# BV号为1SV411m7da的视频属性抓取结束
# 开始BV号为1my4y1y7Eh视频属性的抓取
# BV号为1my4y1y7Eh的视频属性抓取结束
# 开始BV号为1oA411E7Sn视频属性的抓取
# BV号为1oA411E7Sn的视频属性抓取结束
# 开始BV号为1K541187s1视频属性的抓取
# BV号为1K541187s1的视频属性抓取结束
# 开始BV号为1NZ4y1K7Mm视频属性的抓取
# BV号为1NZ4y1K7Mm的视频属性抓取结束
# 开始BV号为1ri4y177Yb视频属性的抓取
# BV号为1ri4y177Yb的视频属性抓取结束
# 开始BV号为11a4y1j7wY视频属性的抓取
# BV号为11a4y1j7wY的视频属性抓取结束
# 开始BV号为17A411J7Dd视频属性的抓取
# BV号为17A411J7Dd的视频属性抓取结束
# 开始BV号为14i4y1u7z9视频属性的抓取
# BV号为14i4y1u7z9的视频属性抓取结束
# 开始BV号为1bk4y1y7YN视频属性的抓取
# BV号为1bk4y1y7YN的视频属性抓取结束
# 开始BV号为18v411C7qS视频属性的抓取
# BV号为18v411C7qS的视频属性抓取结束
# 开始BV号为1fi4y177cE视频属性的抓取
# BV号为1fi4y177cE的视频属性抓取结束
# 开始BV号为1Tt4y1q7Tq视频属性的抓取
# BV号为1Tt4y1q7Tq的视频属性抓取结束
# 开始BV号为1GD4y1o7ve视频属性的抓取
# BV号为1GD4y1o7ve的视频属性抓取结束
# 开始BV号为11i4y177bh视频属性的抓取
# BV号为11i4y177bh的视频属性抓取结束
# 开始BV号为1CV411m7qi视频属性的抓取
# BV号为1CV411m7qi的视频属性抓取结束
# 开始BV号为1AK411K7qq视频属性的抓取
# BV号为1AK411K7qq的视频属性抓取结束
# 开始BV号为1GK411K7Hr视频属性的抓取
# BV号为1GK411K7Hr的视频属性抓取结束
# 开始BV号为11Z4y1N7js视频属性的抓取
# BV号为11Z4y1N7js的视频属性抓取结束
# 开始BV号为1kV411m7XV视频属性的抓取
# BV号为1kV411m7XV的视频属性抓取结束
# 开始BV号为1wp4y1e7xZ视频属性的抓取
# BV号为1wp4y1e7xZ的视频属性抓取结束
# 开始BV号为1Lz4y1Z7Ac视频属性的抓取
# BV号为1Lz4y1Z7Ac的视频属性抓取结束
# 开始BV号为1ay4y1y7bA视频属性的抓取
# BV号为1ay4y1y7bA的视频属性抓取结束
# 开始BV号为12p4y1e7bD视频属性的抓取
# BV号为12p4y1e7bD的视频属性抓取结束
# 开始BV号为19t4y1i7Js视频属性的抓取
# BV号为19t4y1i7Js的视频属性抓取结束
# 开始BV号为1w5411j7ek视频属性的抓取
# BV号为1w5411j7ek的视频属性抓取结束
# 开始BV号为17K4y1e7RE视频属性的抓取
# BV号为17K4y1e7RE的视频属性抓取结束
# 开始BV号为19V41127qZ视频属性的抓取
# BV号为19V41127qZ的视频属性抓取结束
# 开始BV号为1Ak4y117HP视频属性的抓取
# BV号为1Ak4y117HP的视频属性抓取结束
# 开始BV号为1ji4y1E7zs视频属性的抓取
# BV号为1ji4y1E7zs的视频属性抓取结束
# 开始BV号为1754y127Gq视频属性的抓取
# BV号为1754y127Gq的视频属性抓取结束
# 开始BV号为1qK4y187ED视频属性的抓取
# BV号为1qK4y187ED的视频属性抓取结束
# 开始BV号为1iK411P7gb视频属性的抓取
# BV号为1iK411P7gb的视频属性抓取结束
# 开始BV号为1bA411J72V视频属性的抓取
# BV号为1bA411J72V的视频属性抓取结束
# 开始BV号为1dz4y1o7Vu视频属性的抓取
# BV号为1dz4y1o7Vu的视频属性抓取结束
# 开始BV号为1Aa4y1j7U4视频属性的抓取
# BV号为1Aa4y1j7U4的视频属性抓取结束
# 开始BV号为1WK411P7tb视频属性的抓取
# BV号为1WK411P7tb的视频属性抓取结束
# 开始BV号为1St4y1S7LJ视频属性的抓取
# BV号为1St4y1S7LJ的视频属性抓取结束
# 开始BV号为1Rf4y1S78i视频属性的抓取
# BV号为1Rf4y1S78i的视频属性抓取结束
# 开始BV号为1ni4y1u76X视频属性的抓取
# BV号为1ni4y1u76X的视频属性抓取结束
# 开始BV号为1wh411R7MA视频属性的抓取
# BV号为1wh411R7MA的视频属性抓取结束
# 开始BV号为18K4y1a7tL视频属性的抓取
# BV号为18K4y1a7tL的视频属性抓取结束
# 开始BV号为1B54y117x4视频属性的抓取
# BV号为1B54y117x4的视频属性抓取结束
# 开始BV号为1yk4y127L4视频属性的抓取
# BV号为1yk4y127L4的视频属性抓取结束
# 开始BV号为1gT4y1c7yT视频属性的抓取
# BV号为1gT4y1c7yT的视频属性抓取结束
# 开始BV号为1tV41117tx视频属性的抓取
# BV号为1tV41117tx的视频属性抓取结束
# 开始BV号为1oK411N7gE视频属性的抓取
# BV号为1oK411N7gE的视频属性抓取结束
# 开始BV号为1fZ4y1P7iD视频属性的抓取
# BV号为1fZ4y1P7iD的视频属性抓取结束
# 开始BV号为1ey4y1k7z5视频属性的抓取
# BV号为1ey4y1k7z5的视频属性抓取结束
# 开始BV号为1yT4y1w7mm视频属性的抓取
# BV号为1yT4y1w7mm的视频属性抓取结束
# 开始BV号为1Kv41117pH视频属性的抓取
# BV号为1Kv41117pH的视频属性抓取结束
# 开始BV号为1wv41117qq视频属性的抓取
# BV号为1wv41117qq的视频属性抓取结束
# 开始BV号为1ia4y1j7vF视频属性的抓取
# BV号为1ia4y1j7vF的视频属性抓取结束
# 开始BV号为1Et4y1q7Dx视频属性的抓取
# BV号为1Et4y1q7Dx的视频属性抓取结束
# 开始BV号为1nK4y1a7aP视频属性的抓取
# BV号为1nK4y1a7aP的视频属性抓取结束
# 开始BV号为1ef4y1X7R6视频属性的抓取
# BV号为1ef4y1X7R6的视频属性抓取结束
# 开始BV号为1J54y1m7QG视频属性的抓取
# BV号为1J54y1m7QG的视频属性抓取结束
# 开始BV号为1ii4y1M79r视频属性的抓取
# BV号为1ii4y1M79r的视频属性抓取结束
# 开始BV号为17y4y1y7eb视频属性的抓取
# BV号为17y4y1y7eb的视频属性抓取结束
# 开始BV号为1Ef4y1D75m视频属性的抓取
# BV号为1Ef4y1D75m的视频属性抓取结束
# 开始BV号为1jZ4y1T75g视频属性的抓取
# BV号为1jZ4y1T75g的视频属性抓取结束
# 开始BV号为145411b7pr视频属性的抓取
# BV号为145411b7pr的视频属性抓取结束
# 开始BV号为1Sk4y1y7iB视频属性的抓取
# BV号为1Sk4y1y7iB的视频属性抓取结束
# 开始BV号为1Yh411X7HE视频属性的抓取
# BV号为1Yh411X7HE的视频属性抓取结束
# 开始BV号为1Q54y1y7r3视频属性的抓取
# BV号为1Q54y1y7r3的视频属性抓取结束
# 开始BV号为1n54y1v7v9视频属性的抓取
# BV号为1n54y1v7v9的视频属性抓取结束
# 开始BV号为1VK4y1a7yW视频属性的抓取
# BV号为1VK4y1a7yW的视频属性抓取结束
# 开始BV号为1dh41197Ky视频属性的抓取
# BV号为1dh41197Ky的视频属性抓取结束
# 开始BV号为1pK411N7gq视频属性的抓取
# BV号为1pK411N7gq的视频属性抓取结束
# 开始BV号为1yK4y1a7CF视频属性的抓取
# BV号为1yK4y1a7CF的视频属性抓取结束
# 开始BV号为1n541187SS视频属性的抓取
# BV号为1n541187SS的视频属性抓取结束
# 开始BV号为14a4y1j7eg视频属性的抓取
# BV号为14a4y1j7eg的视频属性抓取结束
# 开始BV号为1K54y1y7jv视频属性的抓取
# BV号为1K54y1y7jv的视频属性抓取结束
# 开始BV号为1Wp4y1a7op视频属性的抓取
# BV号为1Wp4y1a7op的视频属性抓取结束
# 开始BV号为1th411R7Pd视频属性的抓取
# BV号为1th411R7Pd的视频属性抓取结束
# 开始BV号为1bv411C7M7视频属性的抓取
# BV号为1bv411C7M7的视频属性抓取结束
# 开始BV号为1J54y1v7d1视频属性的抓取
# BV号为1J54y1v7d1的视频属性抓取结束
# 开始BV号为1bK411P73m视频属性的抓取
# BV号为1bK411P73m的视频属性抓取结束
# 开始BV号为1Uv411179F视频属性的抓取
# BV号为1Uv411179F的视频属性抓取结束
# 开始BV号为18K411P7VC视频属性的抓取
# BV号为18K411P7VC的视频属性抓取结束
# 开始BV号为1y54y127b8视频属性的抓取
# BV号为1y54y127b8的视频属性抓取结束
# 开始BV号为1Ef4y1D75A视频属性的抓取
# BV号为1Ef4y1D75A的视频属性抓取结束
# 开始BV号为1wv41117Qb视频属性的抓取
# BV号为1wv41117Qb的视频属性抓取结束
# 开始BV号为1ZZ4y1P7dU视频属性的抓取
# BV号为1ZZ4y1P7dU的视频属性抓取结束
# 开始BV号为1Ri4y1M7SP视频属性的抓取
# BV号为1Ri4y1M7SP的视频属性抓取结束
# 开始BV号为1Hh411R7wV视频属性的抓取
# BV号为1Hh411R7wV的视频属性抓取结束
# 开始BV号为1wp4y1Y7Fg视频属性的抓取
# BV号为1wp4y1Y7Fg的视频属性抓取结束
# 开始BV号为1Bv411C7Ke视频属性的抓取
# BV号为1Bv411C7Ke的视频属性抓取结束
# 开始BV号为18K411K7wP视频属性的抓取
# BV号为18K411K7wP的视频属性抓取结束
# 开始BV号为13p4y1i7WV视频属性的抓取
# BV号为13p4y1i7WV的视频属性抓取结束
# 开始BV号为1Rt4y1S7jL视频属性的抓取
# BV号为1Rt4y1S7jL的视频属性抓取结束
# 开始BV号为1kK411P7b7视频属性的抓取
# BV号为1kK411P7b7的视频属性抓取结束
# 开始BV号为1Yp4y1a7GF视频属性的抓取
# BV号为1Yp4y1a7GF的视频属性抓取结束
# 开始BV号为1rt4y1S7zi视频属性的抓取
# BV号为1rt4y1S7zi的视频属性抓取结束
# 开始BV号为1BK411P7WS视频属性的抓取
# BV号为1BK411P7WS的视频属性抓取结束
# 开始BV号为1LT4y1A7Rh视频属性的抓取
# BV号为1LT4y1A7Rh的视频属性抓取结束
# 开始BV号为1Bk4y1y7Hs视频属性的抓取
# 开始BV号为1Bk4y1y7Hs视频属性的抓取
# BV号为1Bk4y1y7Hs的视频属性抓取结束
# 开始BV号为1Mz4y1Z7WP视频属性的抓取
# BV号为1Mz4y1Z7WP的视频属性抓取结束
# 开始BV号为1bK4y177yD视频属性的抓取
# BV号为1bK4y177yD的视频属性抓取结束
# 开始BV号为1WV411y7F8视频属性的抓取
# BV号为1WV411y7F8的视频属性抓取结束
# 开始BV号为1LZ4y1L7NM视频属性的抓取
# BV号为1LZ4y1L7NM的视频属性抓取结束
# 开始BV号为1az4y1o7KN视频属性的抓取
# BV号为1az4y1o7KN的视频属性抓取结束
# 开始BV号为1ut4y1e7mA视频属性的抓取
# BV号为1ut4y1e7mA的视频属性抓取结束
# 开始BV号为12A41177Nd视频属性的抓取
# BV号为12A41177Nd的视频属性抓取结束
# 开始BV号为1Yi4y1j7UE视频属性的抓取
# BV号为1Yi4y1j7UE的视频属性抓取结束
# 开始BV号为18D4y1R7CV视频属性的抓取
# BV号为18D4y1R7CV的视频属性抓取结束
# 开始BV号为1DK4y1876B视频属性的抓取
# BV号为1DK4y1876B的视频属性抓取结束
# 开始BV号为1ei4y1E73K视频属性的抓取
# BV号为1ei4y1E73K的视频属性抓取结束
# 开始BV号为1nZ4y157Qm视频属性的抓取
# BV号为1nZ4y157Qm的视频属性抓取结束
# 开始BV号为1eK411N7Fz视频属性的抓取
# BV号为1eK411N7Fz的视频属性抓取结束
# 开始BV号为1H54y1C7sG视频属性的抓取
# BV号为1H54y1C7sG的视频属性抓取结束
# 开始BV号为1si4y177pj视频属性的抓取
# BV号为1si4y177pj的视频属性抓取结束
# 开始BV号为1St4y1q7Ya视频属性的抓取
# BV号为1St4y1q7Ya的视频属性抓取结束
# 开始BV号为1qz4y1C7iw视频属性的抓取
# BV号为1qz4y1C7iw的视频属性抓取结束
# 开始BV号为1bK411A7rh视频属性的抓取
# BV号为1bK411A7rh的视频属性抓取结束
# 开始BV号为1cD4y1d7Ar视频属性的抓取
# BV号为1cD4y1d7Ar的视频属性抓取结束
# 开始BV号为1Ma4y1s7eH视频属性的抓取
# BV号为1Ma4y1s7eH的视频属性抓取结束
# 开始BV号为1g54y1C7CW视频属性的抓取
# BV号为1g54y1C7CW的视频属性抓取结束
# 开始BV号为1Q54y1y7V2视频属性的抓取
# BV号为1Q54y1y7V2的视频属性抓取结束
# 开始BV号为1qv411k71A视频属性的抓取
# BV号为1qv411k71A的视频属性抓取结束
# 开始BV号为16D4y1d71K视频属性的抓取
# BV号为16D4y1d71K的视频属性抓取结束
# 开始BV号为1Jf4y1B7pK视频属性的抓取
# BV号为1Jf4y1B7pK的视频属性抓取结束
# 开始BV号为1mK4y17752视频属性的抓取
# BV号为1mK4y17752的视频属性抓取结束
# 开始BV号为18y4y1r75x视频属性的抓取
# BV号为18y4y1r75x的视频属性抓取结束
# 开始BV号为1M5411L7Ek视频属性的抓取
# BV号为1M5411L7Ek的视频属性抓取结束
# 开始BV号为1h54y1C7VS视频属性的抓取
# BV号为1h54y1C7VS的视频属性抓取结束
# 开始BV号为1pZ4y1L7fk视频属性的抓取
# BV号为1pZ4y1L7fk的视频属性抓取结束
# 开始BV号为1GA411E73g视频属性的抓取
# BV号为1GA411E73g的视频属性抓取结束
# 开始BV号为1vD4y1R7Tq视频属性的抓取
# BV号为1vD4y1R7Tq的视频属性抓取结束
# 开始BV号为1Jt4y1v7FM视频属性的抓取
# BV号为1Jt4y1v7FM的视频属性抓取结束
# 开始BV号为11f4y1B7rr视频属性的抓取
# BV号为11f4y1B7rr的视频属性抓取结束
# 开始BV号为1er4y1w7NR视频属性的抓取
# BV号为1er4y1w7NR的视频属性抓取结束
# 开始BV号为1T54y127k7视频属性的抓取
# BV号为1T54y127k7的视频属性抓取结束
# 开始BV号为1Zr4y1c756视频属性的抓取
# BV号为1Zr4y1c756的视频属性抓取结束
# 开始BV号为1Fr4y1w7SK视频属性的抓取
# BV号为1Fr4y1w7SK的视频属性抓取结束
# 开始BV号为12i4y1j7ns视频属性的抓取
# BV号为12i4y1j7ns的视频属性抓取结束
# 开始BV号为1J54y1k74k视频属性的抓取
# BV号为1J54y1k74k的视频属性抓取结束
# 开始BV号为1jf4y1B7ot视频属性的抓取
# BV号为1jf4y1B7ot的视频属性抓取结束
# 开始BV号为1uy4y187Aq视频属性的抓取
# BV号为1uy4y187Aq的视频属性抓取结束
# 开始BV号为1Ua411A7Nb视频属性的抓取
# BV号为1Ua411A7Nb的视频属性抓取结束
# 开始BV号为1Y54y117QB视频属性的抓取
# BV号为1Y54y117QB的视频属性抓取结束
# 开始BV号为1tv411y7Gb视频属性的抓取
# BV号为1tv411y7Gb的视频属性抓取结束
# 开始BV号为15a411A7GA视频属性的抓取
# BV号为15a411A7GA的视频属性抓取结束
# 开始BV号为1KK4y1E7Vr视频属性的抓取
# BV号为1KK4y1E7Vr的视频属性抓取结束
# 开始BV号为1oy4y1r7wg视频属性的抓取
# BV号为1oy4y1r7wg的视频属性抓取结束
# 开始BV号为1pA411E7vA视频属性的抓取
# BV号为1pA411E7vA的视频属性抓取结束
# 开始BV号为1ga4y1L7aq视频属性的抓取
# BV号为1ga4y1L7aq的视频属性抓取结束
# 开始BV号为1oi4y1E7uM视频属性的抓取
# BV号为1oi4y1E7uM的视频属性抓取结束
# 开始BV号为1VT4y1F7Gt视频属性的抓取
# BV号为1VT4y1F7Gt的视频属性抓取结束
# 开始BV号为1bK4y1E7Ar视频属性的抓取
# BV号为1bK4y1E7Ar的视频属性抓取结束
# 开始BV号为1xD4y1d7eY视频属性的抓取
# BV号为1xD4y1d7eY的视频属性抓取结束
# 开始BV号为1dA411L7c3视频属性的抓取
# BV号为1dA411L7c3的视频属性抓取结束
# 开始BV号为1m541157Mb视频属性的抓取
# BV号为1m541157Mb的视频属性抓取结束
# 开始BV号为1Ca4y1s71y视频属性的抓取
# BV号为1Ca4y1s71y的视频属性抓取结束
# 开始BV号为15Z4y1V71v视频属性的抓取
# BV号为15Z4y1V71v的视频属性抓取结束
# 开始BV号为1xt4y1i71x视频属性的抓取
# BV号为1xt4y1i71x的视频属性抓取结束
# 开始BV号为1yv411k7JE视频属性的抓取
# BV号为1yv411k7JE的视频属性抓取结束
# 开始BV号为12v411k7NA视频属性的抓取
# BV号为12v411k7NA的视频属性抓取结束
# 开始BV号为1Di4y1j74v视频属性的抓取
# BV号为1Di4y1j74v的视频属性抓取结束
# 开始BV号为1ty4y1C7Fh视频属性的抓取
# BV号为1ty4y1C7Fh的视频属性抓取结束
# 开始BV号为1op4y1r73u视频属性的抓取
# BV号为1op4y1r73u的视频属性抓取结束
# 开始BV号为1Jp4y1Y7To视频属性的抓取
# BV号为1Jp4y1Y7To的视频属性抓取结束
# 开始BV号为1Cr4y1c7Ph视频属性的抓取
# BV号为1Cr4y1c7Ph的视频属性抓取结束
# 开始BV号为1Wp4y1k73Q视频属性的抓取
# BV号为1Wp4y1k73Q的视频属性抓取结束
# 开始BV号为1jA411E73r视频属性的抓取
# BV号为1jA411E73r的视频属性抓取结束
# 开始BV号为1Xr4y1c7sX视频属性的抓取
# BV号为1Xr4y1c7sX的视频属性抓取结束
# 开始BV号为1ri4y1j7B5视频属性的抓取
# BV号为1ri4y1j7B5的视频属性抓取结束
# 开始BV号为1wT4y1F7RP视频属性的抓取
# BV号为1wT4y1F7RP的视频属性抓取结束
# 开始BV号为1z54y117qS视频属性的抓取
# 开始BV号为1z54y117qS视频属性的抓取
# BV号为1z54y117qS的视频属性抓取结束
# 开始BV号为1854y1R7JT视频属性的抓取
# BV号为1854y1R7JT的视频属性抓取结束
# 开始BV号为15541177Y2视频属性的抓取
# BV号为15541177Y2的视频属性抓取结束
# 开始BV号为11z4y1Z7G1视频属性的抓取
# BV号为11z4y1Z7G1的视频属性抓取结束
# <ipython-input-24-764e03b54bf4>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1uD4y197dP视频属性的抓取
# BV号为1uD4y197dP的视频属性抓取结束
# 开始BV号为1gf4y1B7i8视频属性的抓取
# BV号为1gf4y1B7i8的视频属性抓取结束
# 开始BV号为1TT4y1F77Y视频属性的抓取
# BV号为1TT4y1F77Y的视频属性抓取结束
# 开始BV号为1et4y1q7Tb视频属性的抓取
# BV号为1et4y1q7Tb的视频属性抓取结束
# 开始BV号为1gv411C7W3视频属性的抓取
# BV号为1gv411C7W3的视频属性抓取结束
# 开始BV号为1Hv411k7zD视频属性的抓取
# BV号为1Hv411k7zD的视频属性抓取结束
# 开始BV号为1fA411L7dy视频属性的抓取
# BV号为1fA411L7dy的视频属性抓取结束
# 开始BV号为1Ry4y1r7bS视频属性的抓取
# BV号为1Ry4y1r7bS的视频属性抓取结束
# 开始BV号为1Kh41197oP视频属性的抓取
# BV号为1Kh41197oP的视频属性抓取结束
# 开始BV号为1DA411L7Vt视频属性的抓取
# BV号为1DA411L7Vt的视频属性抓取结束
# 开始BV号为1bK4y1h7Qn视频属性的抓取
# BV号为1bK4y1h7Qn的视频属性抓取结束
# 开始BV号为1pA411E7gm视频属性的抓取
# BV号为1pA411E7gm的视频属性抓取结束
# 开始BV号为1354y1r7Ei视频属性的抓取
# BV号为1354y1r7Ei的视频属性抓取结束
# 开始BV号为1st4y1v7fF视频属性的抓取
# BV号为1st4y1v7fF的视频属性抓取结束
# 开始BV号为1J54y1r7bL视频属性的抓取
# BV号为1J54y1r7bL的视频属性抓取结束
# 开始BV号为1154y1k7cr视频属性的抓取
# BV号为1154y1k7cr的视频属性抓取结束
# 开始BV号为1mK411G7f2视频属性的抓取
# BV号为1mK411G7f2的视频属性抓取结束
# 开始BV号为1XK4y1f71P视频属性的抓取
# BV号为1XK4y1f71P的视频属性抓取结束
# 开始BV号为1qz4y1d7XM视频属性的抓取
# BV号为1qz4y1d7XM的视频属性抓取结束
# 开始BV号为1GA411E7c7视频属性的抓取
# BV号为1GA411E7c7的视频属性抓取结束
# 开始BV号为1gf4y1Q7Sd视频属性的抓取
# BV号为1gf4y1Q7Sd的视频属性抓取结束
# 开始BV号为1q54y1179D视频属性的抓取
# BV号为1q54y1179D的视频属性抓取结束
# 开始BV号为1TD4y1d7HP视频属性的抓取
# BV号为1TD4y1d7HP的视频属性抓取结束
# 开始BV号为1gD4y1d7Sn视频属性的抓取
# BV号为1gD4y1d7Sn的视频属性抓取结束
# 开始BV号为1sa411A7Bk视频属性的抓取
# BV号为1sa411A7Bk的视频属性抓取结束
# 2020-12-19 13:47:18.548563

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-6-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_donghua_MMD·3D.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月    99   99    99   99   99   99   99   99    99      99   99    99   99
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月   99   99   99   99   99   99    99
# 1月   100  100  100  100  100  100   100
# 2月   100  100  100  100  100  100   100
# 3月    99   99   99   99   99   99    99
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月   100  100  100  100  100  100   100
# 7月    99   99   99   99   99   99    99
# 8月   100  100  100  100  100  100   100
# 9月   100  100  100  100  100  100   100

# %%
channel_donghua_MMD·3D.to_json('channel_donghua_MMD·3D.json')
