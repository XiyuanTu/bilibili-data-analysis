# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_donghua_shouban=pd.DataFrame(columns=columns)
channel_donghua_shouban
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[1]/div/a/span').click()  #选择“动画”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[1]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '动画'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[5]/a').click()  #选择“手办·模玩”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[5]/a').text
sub_channel
# Out:
# '手办·模玩'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(8,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_donghua_shouban.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-19 09:38:04.775788
# <ipython-input-18-bde654f398ce>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-18-bde654f398ce>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-18-bde654f398ce>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1NA411Y7CE视频属性的抓取
# BV号为1NA411Y7CE的视频属性抓取结束
# <ipython-input-18-bde654f398ce>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1Xf4y1X7k5视频属性的抓取
# BV号为1Xf4y1X7k5的视频属性抓取结束
# <ipython-input-18-bde654f398ce>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1B54y1e7eV视频属性的抓取
# BV号为1B54y1e7eV的视频属性抓取结束
# 开始BV号为1pK4y1Y7VP视频属性的抓取
# BV号为1pK4y1Y7VP的视频属性抓取结束
# 开始BV号为1e54y1e7LA视频属性的抓取
# BV号为1e54y1e7LA的视频属性抓取结束
# 开始BV号为1hT4y1j7aq视频属性的抓取
# BV号为1hT4y1j7aq的视频属性抓取结束
# 开始BV号为1AK4y1e7um视频属性的抓取
# BV号为1AK4y1e7um的视频属性抓取结束
# 开始BV号为1bv411v7jP视频属性的抓取
# BV号为1bv411v7jP的视频属性抓取结束
# 开始BV号为1h5411879W视频属性的抓取
# BV号为1h5411879W的视频属性抓取结束
# 开始BV号为17A411Y7eY视频属性的抓取
# BV号为17A411Y7eY的视频属性抓取结束
# 开始BV号为1wD4y1m79a视频属性的抓取
# 开始BV号为1wD4y1m79a视频属性的抓取
# BV号为1wD4y1m79a的视频属性抓取结束
# 开始BV号为1QT4y1L7pd视频属性的抓取
# BV号为1QT4y1L7pd的视频属性抓取结束
# 开始BV号为11T4y1w7Cq视频属性的抓取
# BV号为11T4y1w7Cq的视频属性抓取结束
# 开始BV号为1Kp4y1e7eN视频属性的抓取
# BV号为1Kp4y1e7eN的视频属性抓取结束
# 开始BV号为1QA411J7Kq视频属性的抓取
# BV号为1QA411J7Kq的视频属性抓取结束
# 开始BV号为1nf4y1Q7Fn视频属性的抓取
# BV号为1nf4y1Q7Fn的视频属性抓取结束
# 开始BV号为1vD4y127cM视频属性的抓取
# BV号为1vD4y127cM的视频属性抓取结束
# 开始BV号为1ep4y1v7oF视频属性的抓取
# BV号为1ep4y1v7oF的视频属性抓取结束
# 开始BV号为14k4y127ff视频属性的抓取
# BV号为14k4y127ff的视频属性抓取结束
# 开始BV号为1p64y1c7mh视频属性的抓取
# BV号为1p64y1c7mh的视频属性抓取结束
# 开始BV号为1mT4y157U1视频属性的抓取
# BV号为1mT4y157U1的视频属性抓取结束
# 开始BV号为1SA411J7ko视频属性的抓取
# BV号为1SA411J7ko的视频属性抓取结束
# 开始BV号为1wC4y1b7Py视频属性的抓取
# BV号为1wC4y1b7Py的视频属性抓取结束
# 开始BV号为1RC4y147MJ视频属性的抓取
# BV号为1RC4y147MJ的视频属性抓取结束
# 开始BV号为1na4y177s3视频属性的抓取
# 开始BV号为1na4y177s3视频属性的抓取
# BV号为1na4y177s3的视频属性抓取结束
# 开始BV号为1Fh411o7VP视频属性的抓取
# BV号为1Fh411o7VP的视频属性抓取结束
# 开始BV号为1ef4y1Q7dY视频属性的抓取
# BV号为1ef4y1Q7dY的视频属性抓取结束
# 开始BV号为1Fk4y127mx视频属性的抓取
# BV号为1Fk4y127mx的视频属性抓取结束
# 开始BV号为1wZ4y1M7Lv视频属性的抓取
# BV号为1wZ4y1M7Lv的视频属性抓取结束
# 开始BV号为16v411v7nz视频属性的抓取
# 开始BV号为16v411v7nz视频属性的抓取
# BV号为16v411v7nz的视频属性抓取结束
# 开始BV号为1BK4y1v74F视频属性的抓取
# BV号为1BK4y1v74F的视频属性抓取结束
# 开始BV号为1Gk4y127ow视频属性的抓取
# BV号为1Gk4y127ow的视频属性抓取结束
# 开始BV号为1Mh411o7eu视频属性的抓取
# BV号为1Mh411o7eu的视频属性抓取结束
# 开始BV号为14v411v7kB视频属性的抓取
# BV号为14v411v7kB的视频属性抓取结束
# 开始BV号为1Dh411d79U视频属性的抓取
# BV号为1Dh411d79U的视频属性抓取结束
# 开始BV号为1VD4y1m7tP视频属性的抓取
# BV号为1VD4y1m7tP的视频属性抓取结束
# 开始BV号为1yV41127RZ视频属性的抓取
# BV号为1yV41127RZ的视频属性抓取结束
# 开始BV号为1B54y1i7Ac视频属性的抓取
# BV号为1B54y1i7Ac的视频属性抓取结束
# 开始BV号为1V54y1v7s1视频属性的抓取
# BV号为1V54y1v7s1的视频属性抓取结束
# 开始BV号为1354y1U7QC视频属性的抓取
# BV号为1354y1U7QC的视频属性抓取结束
# 开始BV号为1kf4y19739视频属性的抓取
# BV号为1kf4y19739的视频属性抓取结束
# 开始BV号为1G54y1i77M视频属性的抓取
# BV号为1G54y1i77M的视频属性抓取结束
# 开始BV号为1MA411e7CG视频属性的抓取
# BV号为1MA411e7CG的视频属性抓取结束
# 开始BV号为1d64y1F7YV视频属性的抓取
# 开始BV号为1d64y1F7YV视频属性的抓取
# BV号为1d64y1F7YV的视频属性抓取结束
# 开始BV号为11V411z7V1视频属性的抓取
# BV号为11V411z7V1的视频属性抓取结束
# 开始BV号为1h5411a7V6视频属性的抓取
# BV号为1h5411a7V6的视频属性抓取结束
# 开始BV号为1wh411d79C视频属性的抓取
# BV号为1wh411d79C的视频属性抓取结束
# 开始BV号为1FV411S7Dn视频属性的抓取
# BV号为1FV411S7Dn的视频属性抓取结束
# 开始BV号为1Mf4y197nF视频属性的抓取
# BV号为1Mf4y197nF的视频属性抓取结束
# 开始BV号为1EC4y18713视频属性的抓取
# BV号为1EC4y18713的视频属性抓取结束
# 开始BV号为1za4y177E2视频属性的抓取
# BV号为1za4y177E2的视频属性抓取结束
# 开始BV号为1Ti4y1g7g2视频属性的抓取
# BV号为1Ti4y1g7g2的视频属性抓取结束
# 开始BV号为1t64y1c7jR视频属性的抓取
# BV号为1t64y1c7jR的视频属性抓取结束
# 开始BV号为1gK4y1e7x8视频属性的抓取
# BV号为1gK4y1e7x8的视频属性抓取结束
# 开始BV号为1DK4y1v7SK视频属性的抓取
# BV号为1DK4y1v7SK的视频属性抓取结束
# 开始BV号为1v54y1m7hj视频属性的抓取
# BV号为1v54y1m7hj的视频属性抓取结束
# 开始BV号为1VV411S7KC视频属性的抓取
# BV号为1VV411S7KC的视频属性抓取结束
# 开始BV号为1np4y1i7Pf视频属性的抓取
# BV号为1np4y1i7Pf的视频属性抓取结束
# 开始BV号为1ka4y1E75i视频属性的抓取
# BV号为1ka4y1E75i的视频属性抓取结束
# 开始BV号为1xh411d7hf视频属性的抓取
# BV号为1xh411d7hf的视频属性抓取结束
# 开始BV号为1Tt4y1S7ag视频属性的抓取
# BV号为1Tt4y1S7ag的视频属性抓取结束
# 开始BV号为1UD4y1U7qU视频属性的抓取
# BV号为1UD4y1U7qU的视频属性抓取结束
# 开始BV号为1yh41197H7视频属性的抓取
# BV号为1yh41197H7的视频属性抓取结束
# 开始BV号为1X541187oq视频属性的抓取
# BV号为1X541187oq的视频属性抓取结束
# 开始BV号为1qK4y1Y79y视频属性的抓取
# BV号为1qK4y1Y79y的视频属性抓取结束
# 开始BV号为1Da4y177FU视频属性的抓取
# BV号为1Da4y177FU的视频属性抓取结束
# 开始BV号为1ZD4y1U7Ad视频属性的抓取
# BV号为1ZD4y1U7Ad的视频属性抓取结束
# 开始BV号为1jZ4y1M7PX视频属性的抓取
# BV号为1jZ4y1M7PX的视频属性抓取结束
# 开始BV号为1kK4y1Y7EG视频属性的抓取
# BV号为1kK4y1Y7EG的视频属性抓取结束
# 开始BV号为1k54y1i7a4视频属性的抓取
# BV号为1k54y1i7a4的视频属性抓取结束
# 开始BV号为11h411973x视频属性的抓取
# BV号为11h411973x的视频属性抓取结束
# 开始BV号为1oC4y1t7zF视频属性的抓取
# BV号为1oC4y1t7zF的视频属性抓取结束
# 开始BV号为1cC4y1t7vo视频属性的抓取
# 开始BV号为1cC4y1t7vo视频属性的抓取
# BV号为1cC4y1t7vo的视频属性抓取结束
# 开始BV号为1H54y1U7La视频属性的抓取
# 开始BV号为1H54y1U7La视频属性的抓取
# BV号为1H54y1U7La的视频属性抓取结束
# 开始BV号为1xC4y187BU视频属性的抓取
# BV号为1xC4y187BU的视频属性抓取结束
# 开始BV号为1LA411Y7dU视频属性的抓取
# BV号为1LA411Y7dU的视频属性抓取结束
# 开始BV号为1FK4y1e7WD视频属性的抓取
# BV号为1FK4y1e7WD的视频属性抓取结束
# 开始BV号为1YA411Y7xi视频属性的抓取
# BV号为1YA411Y7xi的视频属性抓取结束
# 开始BV号为1Rp4y1Y7Zt视频属性的抓取
# BV号为1Rp4y1Y7Zt的视频属性抓取结束
# 开始BV号为1uh411o7Z8视频属性的抓取
# BV号为1uh411o7Z8的视频属性抓取结束
# 开始BV号为1QD4y1U7ej视频属性的抓取
# BV号为1QD4y1U7ej的视频属性抓取结束
# 开始BV号为1yk4y1m7gr视频属性的抓取
# BV号为1yk4y1m7gr的视频属性抓取结束
# 开始BV号为1Zi4y1M7Rc视频属性的抓取
# BV号为1Zi4y1M7Rc的视频属性抓取结束
# 开始BV号为1Tp4y1q7Wa视频属性的抓取
# BV号为1Tp4y1q7Wa的视频属性抓取结束
# 开始BV号为1V64y1F7Ai视频属性的抓取
# BV号为1V64y1F7Ai的视频属性抓取结束
# 开始BV号为1ra4y177LR视频属性的抓取
# BV号为1ra4y177LR的视频属性抓取结束
# 开始BV号为1HZ4y1T7yb视频属性的抓取
# BV号为1HZ4y1T7yb的视频属性抓取结束
# 开始BV号为1EV411z7cq视频属性的抓取
# BV号为1EV411z7cq的视频属性抓取结束
# 开始BV号为1Mf4y197Ez视频属性的抓取
# BV号为1Mf4y197Ez的视频属性抓取结束
# 开始BV号为1QZ4y1P7R1视频属性的抓取
# BV号为1QZ4y1P7R1的视频属性抓取结束
# 开始BV号为1kV411z7vg视频属性的抓取
# BV号为1kV411z7vg的视频属性抓取结束
# 开始BV号为1FV411S7on视频属性的抓取
# BV号为1FV411S7on的视频属性抓取结束
# 开始BV号为1LZ4y1K782视频属性的抓取
# BV号为1LZ4y1K782的视频属性抓取结束
# 开始BV号为1yT4y1j7kL视频属性的抓取
# BV号为1yT4y1j7kL的视频属性抓取结束
# 开始BV号为1ch411o73m视频属性的抓取
# BV号为1ch411o73m的视频属性抓取结束
# 开始BV号为12T4y157q6视频属性的抓取
# BV号为12T4y157q6的视频属性抓取结束
# 开始BV号为12T4y1L73N视频属性的抓取
# BV号为12T4y1L73N的视频属性抓取结束
# 开始BV号为1SD4y1U7MP视频属性的抓取
# BV号为1SD4y1U7MP的视频属性抓取结束
# 开始BV号为1Et4y1v7pw视频属性的抓取
# BV号为1Et4y1v7pw的视频属性抓取结束
# 开始BV号为11k4y1y7dH视频属性的抓取
# BV号为11k4y1y7dH的视频属性抓取结束
# 开始BV号为1ii4y177ZG视频属性的抓取
# BV号为1ii4y177ZG的视频属性抓取结束
# 开始BV号为1pK411N7TD视频属性的抓取
# BV号为1pK411N7TD的视频属性抓取结束
# 开始BV号为1A541187Uy视频属性的抓取
# BV号为1A541187Uy的视频属性抓取结束
# 开始BV号为12v411C7NN视频属性的抓取
# BV号为12v411C7NN的视频属性抓取结束
# 开始BV号为1fv411C7H4视频属性的抓取
# BV号为1fv411C7H4的视频属性抓取结束
# 开始BV号为1xh411X7QD视频属性的抓取
# BV号为1xh411X7QD的视频属性抓取结束
# 开始BV号为1a54y127hH视频属性的抓取
# BV号为1a54y127hH的视频属性抓取结束
# 开始BV号为1mv411C7vB视频属性的抓取
# BV号为1mv411C7vB的视频属性抓取结束
# 开始BV号为1BV411m7Ls视频属性的抓取
# BV号为1BV411m7Ls的视频属性抓取结束
# 开始BV号为1oA411n7Rs视频属性的抓取
# BV号为1oA411n7Rs的视频属性抓取结束
# 开始BV号为1vp4y1a7BT视频属性的抓取
# BV号为1vp4y1a7BT的视频属性抓取结束
# 开始BV号为1Rk4y1y77g视频属性的抓取
# BV号为1Rk4y1y77g的视频属性抓取结束
# 开始BV号为1Pv41117Df视频属性的抓取
# BV号为1Pv41117Df的视频属性抓取结束
# 开始BV号为1xA411E7j2视频属性的抓取
# BV号为1xA411E7j2的视频属性抓取结束
# 开始BV号为1PV411m7xk视频属性的抓取
# BV号为1PV411m7xk的视频属性抓取结束
# 开始BV号为1zt4y1S7jH视频属性的抓取
# BV号为1zt4y1S7jH的视频属性抓取结束
# 开始BV号为1qv41117uD视频属性的抓取
# BV号为1qv41117uD的视频属性抓取结束
# 开始BV号为1xy4y1y7JF视频属性的抓取
# BV号为1xy4y1y7JF的视频属性抓取结束
# 开始BV号为1MV411m7E3视频属性的抓取
# BV号为1MV411m7E3的视频属性抓取结束
# 开始BV号为1wt4y1q7rq视频属性的抓取
# BV号为1wt4y1q7rq的视频属性抓取结束
# 开始BV号为1af4y1D766视频属性的抓取
# 开始BV号为1af4y1D766视频属性的抓取
# BV号为1af4y1D766的视频属性抓取结束
# 开始BV号为1MV411m7MR视频属性的抓取
# BV号为1MV411m7MR的视频属性抓取结束
# 开始BV号为1p54y1v7go视频属性的抓取
# BV号为1p54y1v7go的视频属性抓取结束
# 开始BV号为1hD4y1m7FQ视频属性的抓取
# BV号为1hD4y1m7FQ的视频属性抓取结束
# 开始BV号为1Ak4y1C78Y视频属性的抓取
# BV号为1Ak4y1C78Y的视频属性抓取结束
# 开始BV号为1Tk4y1y7HE视频属性的抓取
# BV号为1Tk4y1y7HE的视频属性抓取结束
# 开始BV号为1gk4y1y7co视频属性的抓取
# BV号为1gk4y1y7co的视频属性抓取结束
# 开始BV号为1pZ4y1T7Hw视频属性的抓取
# BV号为1pZ4y1T7Hw的视频属性抓取结束
# 开始BV号为1Na4y177cV视频属性的抓取
# BV号为1Na4y177cV的视频属性抓取结束
# 开始BV号为1Tz4y1Z7Vr视频属性的抓取
# BV号为1Tz4y1Z7Vr的视频属性抓取结束
# 开始BV号为1ay4y1k7qo视频属性的抓取
# BV号为1ay4y1k7qo的视频属性抓取结束
# 开始BV号为1kK4y1a7af视频属性的抓取
# BV号为1kK4y1a7af的视频属性抓取结束
# 开始BV号为1WV41117kJ视频属性的抓取
# BV号为1WV41117kJ的视频属性抓取结束
# 开始BV号为1n541187Qr视频属性的抓取
# BV号为1n541187Qr的视频属性抓取结束
# 开始BV号为1Jy4y1k7NA视频属性的抓取
# BV号为1Jy4y1k7NA的视频属性抓取结束
# 开始BV号为1pk4y127up视频属性的抓取
# BV号为1pk4y127up的视频属性抓取结束
# 开始BV号为1XA411n71B视频属性的抓取
# BV号为1XA411n71B的视频属性抓取结束
# 开始BV号为1sK4y1a7sZ视频属性的抓取
# BV号为1sK4y1a7sZ的视频属性抓取结束
# 开始BV号为1VZ4y1N7Cx视频属性的抓取
# BV号为1VZ4y1N7Cx的视频属性抓取结束
# 开始BV号为1N54y117jK视频属性的抓取
# BV号为1N54y117jK的视频属性抓取结束
# 开始BV号为1Mf4y1D7FQ视频属性的抓取
# BV号为1Mf4y1D7FQ的视频属性抓取结束
# 开始BV号为1ff4y1D7iY视频属性的抓取
# BV号为1ff4y1D7iY的视频属性抓取结束
# 开始BV号为1Ak4y1C7Mq视频属性的抓取
# BV号为1Ak4y1C7Mq的视频属性抓取结束
# 开始BV号为1ph411R7hW视频属性的抓取
# BV号为1ph411R7hW的视频属性抓取结束
# 开始BV号为1x64y1F7TZ视频属性的抓取
# BV号为1x64y1F7TZ的视频属性抓取结束
# 开始BV号为1xT4y1c7yy视频属性的抓取
# BV号为1xT4y1c7yy的视频属性抓取结束
# 开始BV号为1b5411b736视频属性的抓取
# BV号为1b5411b736的视频属性抓取结束
# 开始BV号为1uk4y117pM视频属性的抓取
# BV号为1uk4y117pM的视频属性抓取结束
# 开始BV号为1kt4y1i7j6视频属性的抓取
# BV号为1kt4y1i7j6的视频属性抓取结束
# 开始BV号为1hf4y1D749视频属性的抓取
# BV号为1hf4y1D749的视频属性抓取结束
# 开始BV号为1it4y1i7Sh视频属性的抓取
# BV号为1it4y1i7Sh的视频属性抓取结束
# 开始BV号为1pv411C7g8视频属性的抓取
# BV号为1pv411C7g8的视频属性抓取结束
# 开始BV号为1fi4y1M73o视频属性的抓取
# BV号为1fi4y1M73o的视频属性抓取结束
# 开始BV号为1wZ4y1N7HL视频属性的抓取
# BV号为1wZ4y1N7HL的视频属性抓取结束
# 开始BV号为1xT4y1A7qe视频属性的抓取
# BV号为1xT4y1A7qe的视频属性抓取结束
# 开始BV号为1DZ4y1P7E4视频属性的抓取
# BV号为1DZ4y1P7E4的视频属性抓取结束
# 开始BV号为1CK411K7qq视频属性的抓取
# BV号为1CK411K7qq的视频属性抓取结束
# 开始BV号为19A411E7yb视频属性的抓取
# BV号为19A411E7yb的视频属性抓取结束
# 开始BV号为1Ei4y1u7gy视频属性的抓取
# BV号为1Ei4y1u7gy的视频属性抓取结束
# 开始BV号为1Ly4y1y7Z6视频属性的抓取
# BV号为1Ly4y1y7Z6的视频属性抓取结束
# 开始BV号为1RK4y1a7qt视频属性的抓取
# BV号为1RK4y1a7qt的视频属性抓取结束
# 开始BV号为1sf4y1D7Jh视频属性的抓取
# BV号为1sf4y1D7Jh的视频属性抓取结束
# 开始BV号为13t4y1q734视频属性的抓取
# 开始BV号为13t4y1q734视频属性的抓取
# BV号为13t4y1q734的视频属性抓取结束
# 开始BV号为1Yi4y1E7k4视频属性的抓取
# BV号为1Yi4y1E7k4的视频属性抓取结束
# 开始BV号为1NZ4y1K7W7视频属性的抓取
# BV号为1NZ4y1K7W7的视频属性抓取结束
# 开始BV号为1p54y1v7YU视频属性的抓取
# BV号为1p54y1v7YU的视频属性抓取结束
# 开始BV号为13K411K7Zq视频属性的抓取
# BV号为13K411K7Zq的视频属性抓取结束
# 开始BV号为1YA411E7o7视频属性的抓取
# BV号为1YA411E7o7的视频属性抓取结束
# 开始BV号为17t4y1q74w视频属性的抓取
# BV号为17t4y1q74w的视频属性抓取结束
# 开始BV号为19a4y1j76R视频属性的抓取
# BV号为19a4y1j76R的视频属性抓取结束
# 开始BV号为1ca4y1j7zp视频属性的抓取
# BV号为1ca4y1j7zp的视频属性抓取结束
# 开始BV号为1ZV411m7H5视频属性的抓取
# BV号为1ZV411m7H5的视频属性抓取结束
# 开始BV号为1bV411m79w视频属性的抓取
# BV号为1bV411m79w的视频属性抓取结束
# 开始BV号为1VA411J7Ak视频属性的抓取
# BV号为1VA411J7Ak的视频属性抓取结束
# 开始BV号为1Wy4y1k7Ss视频属性的抓取
# BV号为1Wy4y1k7Ss的视频属性抓取结束
# 开始BV号为1sp4y1e7kH视频属性的抓取
# BV号为1sp4y1e7kH的视频属性抓取结束
# 开始BV号为1Fp4y1e7xM视频属性的抓取
# BV号为1Fp4y1e7xM的视频属性抓取结束
# 开始BV号为1az4y1Z7xo视频属性的抓取
# BV号为1az4y1Z7xo的视频属性抓取结束
# 开始BV号为1Xi4y177CS视频属性的抓取
# BV号为1Xi4y177CS的视频属性抓取结束
# 开始BV号为1Sv411C78A视频属性的抓取
# BV号为1Sv411C78A的视频属性抓取结束
# 开始BV号为1y54y1179w视频属性的抓取
# BV号为1y54y1179w的视频属性抓取结束
# 开始BV号为1Zi4y1779G视频属性的抓取
# BV号为1Zi4y1779G的视频属性抓取结束
# 开始BV号为1ii4y1M7P7视频属性的抓取
# BV号为1ii4y1M7P7的视频属性抓取结束
# 开始BV号为1XA411n7U1视频属性的抓取
# BV号为1XA411n7U1的视频属性抓取结束
# 开始BV号为1Ci4y17773视频属性的抓取
# BV号为1Ci4y17773的视频属性抓取结束
# 开始BV号为1wi4y1E7d2视频属性的抓取
# BV号为1wi4y1E7d2的视频属性抓取结束
# 开始BV号为1xp4y1a73B视频属性的抓取
# BV号为1xp4y1a73B的视频属性抓取结束
# 开始BV号为1k54y1y7Ay视频属性的抓取
# BV号为1k54y1y7Ay的视频属性抓取结束
# 开始BV号为1ep4y1e7VS视频属性的抓取
# BV号为1ep4y1e7VS的视频属性抓取结束
# 开始BV号为15A411J7L5视频属性的抓取
# BV号为15A411J7L5的视频属性抓取结束
# 开始BV号为16y4y1y7so视频属性的抓取
# BV号为16y4y1y7so的视频属性抓取结束
# 开始BV号为1Ti4y1u7WJ视频属性的抓取
# BV号为1Ti4y1u7WJ的视频属性抓取结束
# 开始BV号为1mK4y1a72N视频属性的抓取
# BV号为1mK4y1a72N的视频属性抓取结束
# 开始BV号为1Di4y177QD视频属性的抓取
# BV号为1Di4y177QD的视频属性抓取结束
# 开始BV号为1N54y117jX视频属性的抓取
# BV号为1N54y117jX的视频属性抓取结束
# 开始BV号为1Jy4y1y71z视频属性的抓取
# BV号为1Jy4y1y71z的视频属性抓取结束
# 开始BV号为1sk4y1y7kT视频属性的抓取
# BV号为1sk4y1y7kT的视频属性抓取结束
# 开始BV号为1UZ4y1N7GS视频属性的抓取
# BV号为1UZ4y1N7GS的视频属性抓取结束
# 开始BV号为1Py4y187d4视频属性的抓取
# BV号为1Py4y187d4的视频属性抓取结束
# 开始BV号为1EK411A7eB视频属性的抓取
# BV号为1EK411A7eB的视频属性抓取结束
# 开始BV号为1Az4y1o72v视频属性的抓取
# BV号为1Az4y1o72v的视频属性抓取结束
# 开始BV号为1ty4y1B7M3视频属性的抓取
# BV号为1ty4y1B7M3的视频属性抓取结束
# 开始BV号为1Lt4y1v7e1视频属性的抓取
# BV号为1Lt4y1v7e1的视频属性抓取结束
# 开始BV号为15p4y1Y7R3视频属性的抓取
# BV号为15p4y1Y7R3的视频属性抓取结束
# 开始BV号为1qy4y1r7uV视频属性的抓取
# BV号为1qy4y1r7uV的视频属性抓取结束
# 开始BV号为1Z54y117Dv视频属性的抓取
# BV号为1Z54y117Dv的视频属性抓取结束
# 开始BV号为1NV411y7Gy视频属性的抓取
# BV号为1NV411y7Gy的视频属性抓取结束
# 开始BV号为1NT4y1w7sA视频属性的抓取
# BV号为1NT4y1w7sA的视频属性抓取结束
# 开始BV号为1Mp4y1k7dJ视频属性的抓取
# BV号为1Mp4y1k7dJ的视频属性抓取结束
# 开始BV号为1HZ4y157eE视频属性的抓取
# BV号为1HZ4y157eE的视频属性抓取结束
# 开始BV号为13p4y1Y7nx视频属性的抓取
# BV号为13p4y1Y7nx的视频属性抓取结束
# 开始BV号为1nt4y1v75p视频属性的抓取
# BV号为1nt4y1v75p的视频属性抓取结束
# 开始BV号为1jK411N7ty视频属性的抓取
# BV号为1jK411N7ty的视频属性抓取结束
# 开始BV号为1y5411j7v6视频属性的抓取
# BV号为1y5411j7v6的视频属性抓取结束
# 开始BV号为19K4y1h7VM视频属性的抓取
# BV号为19K4y1h7VM的视频属性抓取结束
# 开始BV号为1gD4y197fQ视频属性的抓取
# BV号为1gD4y197fQ的视频属性抓取结束
# 开始BV号为1xz4y1o7Ep视频属性的抓取
# BV号为1xz4y1o7Ep的视频属性抓取结束
# 开始BV号为13k4y1C74T视频属性的抓取
# BV号为13k4y1C74T的视频属性抓取结束
# 开始BV号为1Ey4y1B7Hx视频属性的抓取
# BV号为1Ey4y1B7Hx的视频属性抓取结束
# 开始BV号为1bK411N7R3视频属性的抓取
# BV号为1bK411N7R3的视频属性抓取结束
# 开始BV号为1Y54y1k7MV视频属性的抓取
# BV号为1Y54y1k7MV的视频属性抓取结束
# 开始BV号为1gK4y1h7k8视频属性的抓取
# BV号为1gK4y1h7k8的视频属性抓取结束
# 开始BV号为1tk4y1C7fC视频属性的抓取
# BV号为1tk4y1C7fC的视频属性抓取结束
# 开始BV号为1mz4y1o7cW视频属性的抓取
# BV号为1mz4y1o7cW的视频属性抓取结束
# 开始BV号为1WT4y1w7cT视频属性的抓取
# BV号为1WT4y1w7cT的视频属性抓取结束
# 开始BV号为1HV411y7hF视频属性的抓取
# 开始BV号为1HV411y7hF视频属性的抓取
# BV号为1HV411y7hF的视频属性抓取结束
# 开始BV号为17p4y1Y7Js视频属性的抓取
# BV号为17p4y1Y7Js的视频属性抓取结束
# 开始BV号为16D4y1d75s视频属性的抓取
# BV号为16D4y1d75s的视频属性抓取结束
# 开始BV号为1G54117757视频属性的抓取
# BV号为1G54117757的视频属性抓取结束
# 开始BV号为1k54y1y7Xo视频属性的抓取
# BV号为1k54y1y7Xo的视频属性抓取结束
# 开始BV号为1Ji4y1E7M4视频属性的抓取
# BV号为1Ji4y1E7M4的视频属性抓取结束
# 开始BV号为1of4y1B78k视频属性的抓取
# BV号为1of4y1B78k的视频属性抓取结束
# 开始BV号为1MT4y1F7kS视频属性的抓取
# BV号为1MT4y1F7kS的视频属性抓取结束
# 开始BV号为1yv41167uA视频属性的抓取
# BV号为1yv41167uA的视频属性抓取结束
# 开始BV号为1HZ4y1L7Es视频属性的抓取
# BV号为1HZ4y1L7Es的视频属性抓取结束
# 开始BV号为1WA411E72B视频属性的抓取
# BV号为1WA411E72B的视频属性抓取结束
# 开始BV号为1nZ4y157w9视频属性的抓取
# BV号为1nZ4y157w9的视频属性抓取结束
# 开始BV号为1rD4y1d7gP视频属性的抓取
# BV号为1rD4y1d7gP的视频属性抓取结束
# 开始BV号为1Hp4y1Y7FR视频属性的抓取
# BV号为1Hp4y1Y7FR的视频属性抓取结束
# 开始BV号为1M541177jY视频属性的抓取
# BV号为1M541177jY的视频属性抓取结束
# 开始BV号为1wv411k7Bf视频属性的抓取
# BV号为1wv411k7Bf的视频属性抓取结束
# 开始BV号为1Ha411c7E6视频属性的抓取
# BV号为1Ha411c7E6的视频属性抓取结束
# 开始BV号为1Gf4y1B7MP视频属性的抓取
# BV号为1Gf4y1B7MP的视频属性抓取结束
# 开始BV号为1ma411w7Ve视频属性的抓取
# BV号为1ma411w7Ve的视频属性抓取结束
# 开始BV号为1oa411w7pT视频属性的抓取
# BV号为1oa411w7pT的视频属性抓取结束
# 开始BV号为1Xz4y1Z7JE视频属性的抓取
# BV号为1Xz4y1Z7JE的视频属性抓取结束
# 开始BV号为1hf4y1i7Z2视频属性的抓取
# BV号为1hf4y1i7Z2的视频属性抓取结束
# 开始BV号为1pZ4y157Te视频属性的抓取
# BV号为1pZ4y157Te的视频属性抓取结束
# 开始BV号为1xy4y1r7qm视频属性的抓取
# BV号为1xy4y1r7qm的视频属性抓取结束
# 开始BV号为1CK4y1h79z视频属性的抓取
# BV号为1CK4y1h79z的视频属性抓取结束
# 开始BV号为1HK411N79u视频属性的抓取
# BV号为1HK411N79u的视频属性抓取结束
# 开始BV号为1fh411X7Zy视频属性的抓取
# BV号为1fh411X7Zy的视频属性抓取结束
# 开始BV号为1rV411y7rd视频属性的抓取
# BV号为1rV411y7rd的视频属性抓取结束
# 开始BV号为1T54y1r7Z4视频属性的抓取
# BV号为1T54y1r7Z4的视频属性抓取结束
# 开始BV号为1Mt4y1i78v视频属性的抓取
# BV号为1Mt4y1i78v的视频属性抓取结束
# 开始BV号为1Mk4y1C7Yg视频属性的抓取
# BV号为1Mk4y1C7Yg的视频属性抓取结束
# 开始BV号为1Qf4y1B7xt视频属性的抓取
# BV号为1Qf4y1B7xt的视频属性抓取结束
# 开始BV号为1nV41127f1视频属性的抓取
# BV号为1nV41127f1的视频属性抓取结束
# 开始BV号为1ya411A7hj视频属性的抓取
# BV号为1ya411A7hj的视频属性抓取结束
# 开始BV号为1Er4y1w7H7视频属性的抓取
# BV号为1Er4y1w7H7的视频属性抓取结束
# 开始BV号为1xA41177ta视频属性的抓取
# BV号为1xA41177ta的视频属性抓取结束
# 开始BV号为1MD4y1R7m5视频属性的抓取
# BV号为1MD4y1R7m5的视频属性抓取结束
# 开始BV号为1Qi4y1E7YJ视频属性的抓取
# BV号为1Qi4y1E7YJ的视频属性抓取结束
# 开始BV号为1J5411j7M6视频属性的抓取
# BV号为1J5411j7M6的视频属性抓取结束
# 开始BV号为1DK4y177xq视频属性的抓取
# BV号为1DK4y177xq的视频属性抓取结束
# 开始BV号为17Z4y1V72V视频属性的抓取
# BV号为17Z4y1V72V的视频属性抓取结束
# 开始BV号为1FT4y1F7Lt视频属性的抓取
# BV号为1FT4y1F7Lt的视频属性抓取结束
# 开始BV号为1Lt4y1v7hU视频属性的抓取
# BV号为1Lt4y1v7hU的视频属性抓取结束
# 开始BV号为1kK4y1h7f6视频属性的抓取
# BV号为1kK4y1h7f6的视频属性抓取结束
# 开始BV号为15Z4y1L7HX视频属性的抓取
# BV号为15Z4y1L7HX的视频属性抓取结束
# 开始BV号为1zp4y1k7Bu视频属性的抓取
# BV号为1zp4y1k7Bu的视频属性抓取结束
# 开始BV号为1np4y1k7gG视频属性的抓取
# BV号为1np4y1k7gG的视频属性抓取结束
# 开始BV号为1Ak4y1y7MC视频属性的抓取
# BV号为1Ak4y1y7MC的视频属性抓取结束
# 开始BV号为1g54y1C7ih视频属性的抓取
# BV号为1g54y1C7ih的视频属性抓取结束
# 开始BV号为1Ht4y1i7pG视频属性的抓取
# BV号为1Ht4y1i7pG的视频属性抓取结束
# 开始BV号为1kz4y1d74f视频属性的抓取
# BV号为1kz4y1d74f的视频属性抓取结束
# 开始BV号为14T4y1w7uc视频属性的抓取
# BV号为14T4y1w7uc的视频属性抓取结束
# 开始BV号为1LK411N7Vz视频属性的抓取
# BV号为1LK411N7Vz的视频属性抓取结束
# 开始BV号为1Tv411C7Qb视频属性的抓取
# BV号为1Tv411C7Qb的视频属性抓取结束
# 开始BV号为1WA411E7hb视频属性的抓取
# BV号为1WA411E7hb的视频属性抓取结束
# 开始BV号为1a54y1R7xB视频属性的抓取
# BV号为1a54y1R7xB的视频属性抓取结束
# 开始BV号为1hT4y1c733视频属性的抓取
# BV号为1hT4y1c733的视频属性抓取结束
# 开始BV号为1jy4y1C7g1视频属性的抓取
# BV号为1jy4y1C7g1的视频属性抓取结束
# 开始BV号为1Ct4y1q77u视频属性的抓取
# BV号为1Ct4y1q77u的视频属性抓取结束
# 开始BV号为1Hv411y7Ah视频属性的抓取
# BV号为1Hv411y7Ah的视频属性抓取结束
# 开始BV号为1ei4y1j7cy视频属性的抓取
# BV号为1ei4y1j7cy的视频属性抓取结束
# 开始BV号为1Ka4y177fu视频属性的抓取
# BV号为1Ka4y177fu的视频属性抓取结束
# 开始BV号为1B5411L71A视频属性的抓取
# BV号为1B5411L71A的视频属性抓取结束
# 开始BV号为1jt4y1i7eC视频属性的抓取
# BV号为1jt4y1i7eC的视频属性抓取结束
# 开始BV号为1WD4y1R72Z视频属性的抓取
# BV号为1WD4y1R72Z的视频属性抓取结束
# 开始BV号为1Xa4y157wJ视频属性的抓取
# BV号为1Xa4y157wJ的视频属性抓取结束
# 开始BV号为1Xz4y1Z7rp视频属性的抓取
# BV号为1Xz4y1Z7rp的视频属性抓取结束
# 开始BV号为1DA411L7K2视频属性的抓取
# BV号为1DA411L7K2的视频属性抓取结束
# 开始BV号为1v54y117tS视频属性的抓取
# BV号为1v54y117tS的视频属性抓取结束
# 开始BV号为1454y1C7EV视频属性的抓取
# BV号为1454y1C7EV的视频属性抓取结束
# 开始BV号为1UA41177i4视频属性的抓取
# BV号为1UA41177i4的视频属性抓取结束
# 开始BV号为1VV41127Qg视频属性的抓取
# BV号为1VV41127Qg的视频属性抓取结束
# 开始BV号为1oh411X7tA视频属性的抓取
# BV号为1oh411X7tA的视频属性抓取结束
# 2020-12-19 14:19:35.094933

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-27-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_donghua_shouban.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月     97   97    97   97   97   97   97   97    97      97   97    97   97
# 3月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月     96   96    96   96   96   96   96   96    96      96   96    96   96
# 8月     98   98    98   98   98   98   98   98    98      98   98    98   98
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月   100  100  100  100  100  100   100
# 2月    97   97   97   97   97   97    97
# 3月   100  100  100  100  100  100   100
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月   100  100  100  100  100  100   100
# 7月    96   96   96   96   96   96    96
# 8月    98   98   98   98   98   98    98
# 9月   100  100  100  100  100  100   100

# %%
channel_donghua_shouban.to_json('channel_donghua_shouban.json')
