# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_shenghuo_dongwu=pd.DataFrame(columns=columns)
channel_shenghuo_dongwu
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[9]/div/a/span').click()  #选择“生活”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[9]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '生活'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[4]/a').click()  #选择“动物圈”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[4]/a').text
sub_channel
# Out:
# '动物圈'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(7,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_shenghuo_dongwu.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-22 07:42:52.526366
# <ipython-input-11-4aff96770336>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-11-4aff96770336>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-11-4aff96770336>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1kV41167t6视频属性的抓取
# BV号为1kV41167t6的视频属性抓取结束
# <ipython-input-11-4aff96770336>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为16K411n7gU视频属性的抓取
# BV号为16K411n7gU的视频属性抓取结束
# 开始BV号为1Ga4y1a77U视频属性的抓取
# BV号为1Ga4y1a77U的视频属性抓取结束
# 开始BV号为175411e7Aa视频属性的抓取
# BV号为175411e7Aa的视频属性抓取结束
# 开始BV号为1Pg4y1v7ZT视频属性的抓取
# BV号为1Pg4y1v7ZT的视频属性抓取结束
# 开始BV号为1Ca4y1E7sN视频属性的抓取
# BV号为1Ca4y1E7sN的视频属性抓取结束
# 开始BV号为1ap4y1S7AK视频属性的抓取
# BV号为1ap4y1S7AK的视频属性抓取结束
# 开始BV号为1LK4y1x7rt视频属性的抓取
# BV号为1LK4y1x7rt的视频属性抓取结束
# 开始BV号为1gk4y1B7xw视频属性的抓取
# BV号为1gk4y1B7xw的视频属性抓取结束
# 开始BV号为16a4y1a7Jo视频属性的抓取
# BV号为16a4y1a7Jo的视频属性抓取结束
# 开始BV号为1Ji4y1V7Pb视频属性的抓取
# BV号为1Ji4y1V7Pb的视频属性抓取结束
# 开始BV号为1Ni4y1G7Qu视频属性的抓取
# BV号为1Ni4y1G7Qu的视频属性抓取结束
# 开始BV号为1BZ4y1u78m视频属性的抓取
# BV号为1BZ4y1u78m的视频属性抓取结束
# 开始BV号为1hk4y1B72P视频属性的抓取
# BV号为1hk4y1B72P的视频属性抓取结束
# 开始BV号为1Bz4y1D7Xv视频属性的抓取
# BV号为1Bz4y1D7Xv的视频属性抓取结束
# 开始BV号为13i4y137mk视频属性的抓取
# BV号为13i4y137mk的视频属性抓取结束
# 开始BV号为1tK4y1s7KV视频属性的抓取
# BV号为1tK4y1s7KV的视频属性抓取结束
# 开始BV号为1dV411B7fj视频属性的抓取
# BV号为1dV411B7fj的视频属性抓取结束
# 开始BV号为15V411z78W视频属性的抓取
# BV号为15V411z78W的视频属性抓取结束
# 开始BV号为1fZ4y1u7K9视频属性的抓取
# BV号为1fZ4y1u7K9的视频属性抓取结束
# 开始BV号为17f4y1R7ue视频属性的抓取
# BV号为17f4y1R7ue的视频属性抓取结束
# 开始BV号为1K5411e77k视频属性的抓取
# BV号为1K5411e77k的视频属性抓取结束
# 开始BV号为1yz4y1X7ne视频属性的抓取
# BV号为1yz4y1X7ne的视频属性抓取结束
# 开始BV号为1Ua4y1Y7FG视频属性的抓取
# BV号为1Ua4y1Y7FG的视频属性抓取结束
# 开始BV号为1Fv411q7x7视频属性的抓取
# BV号为1Fv411q7x7的视频属性抓取结束
# 开始BV号为1vz411v7Qx视频属性的抓取
# BV号为1vz411v7Qx的视频属性抓取结束
# 开始BV号为12t4y197ti视频属性的抓取
# BV号为12t4y197ti的视频属性抓取结束
# 开始BV号为1bC4y1h7Vg视频属性的抓取
# BV号为1bC4y1h7Vg的视频属性抓取结束
# 开始BV号为13D4y1S7RA视频属性的抓取
# BV号为13D4y1S7RA的视频属性抓取结束
# 开始BV号为1Wp4y1i73A视频属性的抓取
# BV号为1Wp4y1i73A的视频属性抓取结束
# 开始BV号为1Bz4y1D7Jv视频属性的抓取
# BV号为1Bz4y1D7Jv的视频属性抓取结束
# 开始BV号为1wt4y1D7dY视频属性的抓取
# BV号为1wt4y1D7dY的视频属性抓取结束
# 开始BV号为155411a7s1视频属性的抓取
# BV号为155411a7s1的视频属性抓取结束
# 开始BV号为1Cv411i7Bq视频属性的抓取
# BV号为1Cv411i7Bq的视频属性抓取结束
# 开始BV号为1tz411v74a视频属性的抓取
# BV号为1tz411v74a的视频属性抓取结束
# 开始BV号为1FT4y1E7i5视频属性的抓取
# BV号为1FT4y1E7i5的视频属性抓取结束
# 开始BV号为1VK4y1x7mb视频属性的抓取
# BV号为1VK4y1x7mb的视频属性抓取结束
# 开始BV号为1gT4y1E77h视频属性的抓取
# BV号为1gT4y1E77h的视频属性抓取结束
# 开始BV号为1VT4y1j7Vg视频属性的抓取
# BV号为1VT4y1j7Vg的视频属性抓取结束
# 开始BV号为1ra4y1h7Vz视频属性的抓取
# BV号为1ra4y1h7Vz的视频属性抓取结束
# 开始BV号为1x54y1S7En视频属性的抓取
# BV号为1x54y1S7En的视频属性抓取结束
# 开始BV号为1Fg4y1i7X8视频属性的抓取
# BV号为1Fg4y1i7X8的视频属性抓取结束
# 开始BV号为1ph411o7ib视频属性的抓取
# BV号为1ph411o7ib的视频属性抓取结束
# 开始BV号为1Yv411B7uY视频属性的抓取
# BV号为1Yv411B7uY的视频属性抓取结束
# 开始BV号为1gT4y1j7mq视频属性的抓取
# BV号为1gT4y1j7mq的视频属性抓取结束
# 开始BV号为1uz4y1X74X视频属性的抓取
# BV号为1uz4y1X74X的视频属性抓取结束
# 开始BV号为1Yz4y1X7DR视频属性的抓取
# BV号为1Yz4y1X7DR的视频属性抓取结束
# 开始BV号为1zp4y1i7Aj视频属性的抓取
# BV号为1zp4y1i7Aj的视频属性抓取结束
# 开始BV号为1hA411e7rT视频属性的抓取
# BV号为1hA411e7rT的视频属性抓取结束
# 开始BV号为1dZ4y1H7pu视频属性的抓取
# BV号为1dZ4y1H7pu的视频属性抓取结束
# 开始BV号为1Bh411o71T视频属性的抓取
# BV号为1Bh411o71T的视频属性抓取结束
# 开始BV号为1nK4y1x7t8视频属性的抓取
# BV号为1nK4y1x7t8的视频属性抓取结束
# 开始BV号为1xK411H7iA视频属性的抓取
# BV号为1xK411H7iA的视频属性抓取结束
# 开始BV号为1jf4y1R7by视频属性的抓取
# BV号为1jf4y1R7by的视频属性抓取结束
# 开始BV号为1n54y1S7mq视频属性的抓取
# BV号为1n54y1S7mq的视频属性抓取结束
# 开始BV号为1ot4y1Q7S8视频属性的抓取
# BV号为1ot4y1Q7S8的视频属性抓取结束
# 开始BV号为1vK4y1s7E8视频属性的抓取
# BV号为1vK4y1s7E8的视频属性抓取结束
# 开始BV号为17p4y1q7o8视频属性的抓取
# BV号为17p4y1q7o8的视频属性抓取结束
# 开始BV号为1ok4y127Xi视频属性的抓取
# BV号为1ok4y127Xi的视频属性抓取结束
# 开始BV号为1ti4y1V7hT视频属性的抓取
# BV号为1ti4y1V7hT的视频属性抓取结束
# 开始BV号为1pt4y1Q7U9视频属性的抓取
# BV号为1pt4y1Q7U9的视频属性抓取结束
# 开始BV号为1YZ4y1u7tb视频属性的抓取
# BV号为1YZ4y1u7tb的视频属性抓取结束
# 开始BV号为17i4y137wG视频属性的抓取
# BV号为17i4y137wG的视频属性抓取结束
# 开始BV号为1kK4y1e7J9视频属性的抓取
# BV号为1kK4y1e7J9的视频属性抓取结束
# 开始BV号为1Ff4y1R7Cw视频属性的抓取
# BV号为1Ff4y1R7Cw的视频属性抓取结束
# 开始BV号为1tz4y1D7Gj视频属性的抓取
# BV号为1tz4y1D7Gj的视频属性抓取结束
# 开始BV号为1bC4y187iY视频属性的抓取
# BV号为1bC4y187iY的视频属性抓取结束
# 开始BV号为12K411H7FW视频属性的抓取
# BV号为12K411H7FW的视频属性抓取结束
# 开始BV号为15V411z7QG视频属性的抓取
# BV号为15V411z7QG的视频属性抓取结束
# 开始BV号为1CD4y1S7C5视频属性的抓取
# BV号为1CD4y1S7C5的视频属性抓取结束
# 开始BV号为1Si4y137Jx视频属性的抓取
# BV号为1Si4y137Jx的视频属性抓取结束
# 开始BV号为1mA411e78J视频属性的抓取
# BV号为1mA411e78J的视频属性抓取结束
# 开始BV号为1nv411q7jw视频属性的抓取
# BV号为1nv411q7jw的视频属性抓取结束
# 开始BV号为1ok4y1q7nV视频属性的抓取
# BV号为1ok4y1q7nV的视频属性抓取结束
# 开始BV号为1vt4y1X7dn视频属性的抓取
# BV号为1vt4y1X7dn的视频属性抓取结束
# 开始BV号为1mk4y1q78k视频属性的抓取
# BV号为1mk4y1q78k的视频属性抓取结束
# 开始BV号为15z4y1X7Rg视频属性的抓取
# BV号为15z4y1X7Rg的视频属性抓取结束
# 开始BV号为1ka4y1a7cc视频属性的抓取
# BV号为1ka4y1a7cc的视频属性抓取结束
# 开始BV号为1Ei4y1V7XK视频属性的抓取
# BV号为1Ei4y1V7XK的视频属性抓取结束
# 开始BV号为15A411e7FW视频属性的抓取
# BV号为15A411e7FW的视频属性抓取结束
# 开始BV号为1Tz4y1Q7Q1视频属性的抓取
# BV号为1Tz4y1Q7Q1的视频属性抓取结束
# 开始BV号为16p4y1S7P3视频属性的抓取
# BV号为16p4y1S7P3的视频属性抓取结束
# 开始BV号为1A5411e7M4视频属性的抓取
# BV号为1A5411e7M4的视频属性抓取结束
# 开始BV号为1qf4y1R7Hg视频属性的抓取
# BV号为1qf4y1R7Hg的视频属性抓取结束
# 开始BV号为1TV411r7pK视频属性的抓取
# BV号为1TV411r7pK的视频属性抓取结束
# 开始BV号为1PT4y1j7nH视频属性的抓取
# BV号为1PT4y1j7nH的视频属性抓取结束
# 开始BV号为1yC4y187UJ视频属性的抓取
# BV号为1yC4y187UJ的视频属性抓取结束
# 开始BV号为18p4y1S78e视频属性的抓取
# BV号为18p4y1S78e的视频属性抓取结束
# 开始BV号为1Ui4y1u7ys视频属性的抓取
# BV号为1Ui4y1u7ys的视频属性抓取结束
# 开始BV号为1VK4y1x7BW视频属性的抓取
# BV号为1VK4y1x7BW的视频属性抓取结束
# 开始BV号为1bk4y1B7k8视频属性的抓取
# BV号为1bk4y1B7k8的视频属性抓取结束
# 开始BV号为1nT4y1j7r7视频属性的抓取
# BV号为1nT4y1j7r7的视频属性抓取结束
# 开始BV号为1YD4y1S7ao视频属性的抓取
# BV号为1YD4y1S7ao的视频属性抓取结束
# 开始BV号为1nC4y1h7Fp视频属性的抓取
# BV号为1nC4y1h7Fp的视频属性抓取结束
# 开始BV号为1Rv411i7vv视频属性的抓取
# BV号为1Rv411i7vv的视频属性抓取结束
# 开始BV号为1vT4y1E7mh视频属性的抓取
# BV号为1vT4y1E7mh的视频属性抓取结束
# 开始BV号为1Th411Z7j3视频属性的抓取
# BV号为1Th411Z7j3的视频属性抓取结束
# 开始BV号为12k4y1m7S5视频属性的抓取
# BV号为12k4y1m7S5的视频属性抓取结束
# 开始BV号为1Gi4y1G7cM视频属性的抓取
# BV号为1Gi4y1G7cM的视频属性抓取结束
# 开始BV号为16K4y1e72d视频属性的抓取
# 开始BV号为16K4y1e72d视频属性的抓取
# BV号为16K4y1e72d的视频属性抓取结束
# 开始BV号为1WD4y127jx视频属性的抓取
# BV号为1WD4y127jx的视频属性抓取结束
# 开始BV号为1va4y1J7TL视频属性的抓取
# BV号为1va4y1J7TL的视频属性抓取结束
# 开始BV号为1kk4y117Qf视频属性的抓取
# BV号为1kk4y117Qf的视频属性抓取结束
# 开始BV号为1Ba4y177gs视频属性的抓取
# BV号为1Ba4y177gs的视频属性抓取结束
# 开始BV号为1bh411d7Dk视频属性的抓取
# BV号为1bh411d7Dk的视频属性抓取结束
# 开始BV号为1Q54y1e7Va视频属性的抓取
# BV号为1Q54y1e7Va的视频属性抓取结束
# 开始BV号为1yk4y127pm视频属性的抓取
# BV号为1yk4y127pm的视频属性抓取结束
# 开始BV号为11C4y1b7DV视频属性的抓取
# BV号为11C4y1b7DV的视频属性抓取结束
# 开始BV号为1UT4y157tR视频属性的抓取
# BV号为1UT4y157tR的视频属性抓取结束
# 开始BV号为1bA411n7fo视频属性的抓取
# BV号为1bA411n7fo的视频属性抓取结束
# 开始BV号为1g5411h74q视频属性的抓取
# BV号为1g5411h74q的视频属性抓取结束
# 开始BV号为1sK4y1v7qp视频属性的抓取
# BV号为1sK4y1v7qp的视频属性抓取结束
# 开始BV号为1Ct4y1U7GF视频属性的抓取
# BV号为1Ct4y1U7GF的视频属性抓取结束
# 开始BV号为1jK411T7vU视频属性的抓取
# BV号为1jK411T7vU的视频属性抓取结束
# 开始BV号为1Jp4y1i7uV视频属性的抓取
# BV号为1Jp4y1i7uV的视频属性抓取结束
# 开始BV号为1n5411b7Fm视频属性的抓取
# BV号为1n5411b7Fm的视频属性抓取结束
# 开始BV号为1PK4y1e745视频属性的抓取
# BV号为1PK4y1e745的视频属性抓取结束
# 开始BV号为19i4y1M7Wp视频属性的抓取
# BV号为19i4y1M7Wp的视频属性抓取结束
# 开始BV号为1dA411J7Li视频属性的抓取
# BV号为1dA411J7Li的视频属性抓取结束
# 开始BV号为1vi4y1g7rs视频属性的抓取
# BV号为1vi4y1g7rs的视频属性抓取结束
# 开始BV号为13C4y1t7kP视频属性的抓取
# BV号为13C4y1t7kP的视频属性抓取结束
# 开始BV号为1GT4y1L78m视频属性的抓取
# BV号为1GT4y1L78m的视频属性抓取结束
# 开始BV号为1mD4y1U7Kf视频属性的抓取
# BV号为1mD4y1U7Kf的视频属性抓取结束
# 开始BV号为1xZ4y1M7FR视频属性的抓取
# BV号为1xZ4y1M7FR的视频属性抓取结束
# 开始BV号为1gK411T7Qp视频属性的抓取
# BV号为1gK411T7Qp的视频属性抓取结束
# 开始BV号为1354y1e72g视频属性的抓取
# BV号为1354y1e72g的视频属性抓取结束
# 开始BV号为1EK4y1Y7tk视频属性的抓取
# BV号为1EK4y1Y7tk的视频属性抓取结束
# 开始BV号为1yt4y1U728视频属性的抓取
# BV号为1yt4y1U728的视频属性抓取结束
# 开始BV号为1Hi4y1g7V9视频属性的抓取
# BV号为1Hi4y1g7V9的视频属性抓取结束
# 开始BV号为1Zz4y1f7Vm视频属性的抓取
# BV号为1Zz4y1f7Vm的视频属性抓取结束
# 开始BV号为1QZ4y1T76D视频属性的抓取
# BV号为1QZ4y1T76D的视频属性抓取结束
# 开始BV号为1Mp4y1q7Cs视频属性的抓取
# BV号为1Mp4y1q7Cs的视频属性抓取结束
# 开始BV号为18K4y1Y74Y视频属性的抓取
# BV号为18K4y1Y74Y的视频属性抓取结束
# 开始BV号为1y54y1i7wB视频属性的抓取
# BV号为1y54y1i7wB的视频属性抓取结束
# 开始BV号为1Jp4y1i72Z视频属性的抓取
# BV号为1Jp4y1i72Z的视频属性抓取结束
# 开始BV号为1fT4y1j7Nm视频属性的抓取
# BV号为1fT4y1j7Nm的视频属性抓取结束
# 开始BV号为1zf4y197EJ视频属性的抓取
# BV号为1zf4y197EJ的视频属性抓取结束
# 开始BV号为1ZD4y127uh视频属性的抓取
# BV号为1ZD4y127uh的视频属性抓取结束
# 开始BV号为1Qa4y1E74V视频属性的抓取
# BV号为1Qa4y1E74V的视频属性抓取结束
# 开始BV号为1qZ4y1M711视频属性的抓取
# BV号为1qZ4y1M711的视频属性抓取结束
# 开始BV号为1HA411n74r视频属性的抓取
# BV号为1HA411n74r的视频属性抓取结束
# 开始BV号为1qA411Y73V视频属性的抓取
# BV号为1qA411Y73V的视频属性抓取结束
# 开始BV号为11y4y1C7yR视频属性的抓取
# BV号为11y4y1C7yR的视频属性抓取结束
# 开始BV号为1iC4y1t7sJ视频属性的抓取
# BV号为1iC4y1t7sJ的视频属性抓取结束
# 开始BV号为1Za4y177fH视频属性的抓取
# BV号为1Za4y177fH的视频属性抓取结束
# 开始BV号为1fK4y1e74E视频属性的抓取
# BV号为1fK4y1e74E的视频属性抓取结束
# 开始BV号为1RK411T77A视频属性的抓取
# BV号为1RK411T77A的视频属性抓取结束
# 开始BV号为1Ti4y1g7PR视频属性的抓取
# BV号为1Ti4y1g7PR的视频属性抓取结束
# 开始BV号为1BV411U791视频属性的抓取
# BV号为1BV411U791的视频属性抓取结束
# 开始BV号为1NC4y1t769视频属性的抓取
# BV号为1NC4y1t769的视频属性抓取结束
# 开始BV号为1664y1c7f8视频属性的抓取
# BV号为1664y1c7f8的视频属性抓取结束
# 开始BV号为165411a7M8视频属性的抓取
# BV号为165411a7M8的视频属性抓取结束
# 开始BV号为1dT4y157h5视频属性的抓取
# BV号为1dT4y157h5的视频属性抓取结束
# 开始BV号为1jK4y1e7PJ视频属性的抓取
# BV号为1jK4y1e7PJ的视频属性抓取结束
# 开始BV号为1ah411d7sP视频属性的抓取
# BV号为1ah411d7sP的视频属性抓取结束
# 开始BV号为1aa4y1E7md视频属性的抓取
# BV号为1aa4y1E7md的视频属性抓取结束
# 开始BV号为1k54y1U7gE视频属性的抓取
# BV号为1k54y1U7gE的视频属性抓取结束
# 开始BV号为1hD4y1U7C9视频属性的抓取
# BV号为1hD4y1U7C9的视频属性抓取结束
# 开始BV号为1YA411Y7yu视频属性的抓取
# BV号为1YA411Y7yu的视频属性抓取结束
# 开始BV号为15Z4y1M7gZ视频属性的抓取
# BV号为15Z4y1M7gZ的视频属性抓取结束
# 开始BV号为1wK411M7R2视频属性的抓取
# BV号为1wK411M7R2的视频属性抓取结束
# 开始BV号为1654y1m76Z视频属性的抓取
# BV号为1654y1m76Z的视频属性抓取结束
# 开始BV号为1sa4y177u7视频属性的抓取
# BV号为1sa4y177u7的视频属性抓取结束
# 开始BV号为1ia4y177LP视频属性的抓取
# BV号为1ia4y177LP的视频属性抓取结束
# 开始BV号为16T4y1w7WS视频属性的抓取
# BV号为16T4y1w7WS的视频属性抓取结束
# 开始BV号为16Z4y1K7PM视频属性的抓取
# BV号为16Z4y1K7PM的视频属性抓取结束
# 开始BV号为1UA411Y77r视频属性的抓取
# BV号为1UA411Y77r的视频属性抓取结束
# 开始BV号为1up4y1i7rM视频属性的抓取
# BV号为1up4y1i7rM的视频属性抓取结束
# 开始BV号为1W54y1i7XQ视频属性的抓取
# BV号为1W54y1i7XQ的视频属性抓取结束
# 开始BV号为1LK411K7YU视频属性的抓取
# BV号为1LK411K7YU的视频属性抓取结束
# 开始BV号为1Bv411y7u3视频属性的抓取
# BV号为1Bv411y7u3的视频属性抓取结束
# 开始BV号为1vp4y1v7E1视频属性的抓取
# BV号为1vp4y1v7E1的视频属性抓取结束
# 开始BV号为1U64y1c7yr视频属性的抓取
# BV号为1U64y1c7yr的视频属性抓取结束
# 开始BV号为1W54y1U7s2视频属性的抓取
# BV号为1W54y1U7s2的视频属性抓取结束
# 开始BV号为1X64y1c7bB视频属性的抓取
# BV号为1X64y1c7bB的视频属性抓取结束
# 开始BV号为1LZ4y1T7Te视频属性的抓取
# BV号为1LZ4y1T7Te的视频属性抓取结束
# 开始BV号为1XK411T7Ys视频属性的抓取
# BV号为1XK411T7Ys的视频属性抓取结束
# 开始BV号为1Mv411i7oY视频属性的抓取
# BV号为1Mv411i7oY的视频属性抓取结束
# 开始BV号为1v64y1F7XZ视频属性的抓取
# BV号为1v64y1F7XZ的视频属性抓取结束
# 开始BV号为13i4y1g7A4视频属性的抓取
# BV号为13i4y1g7A4的视频属性抓取结束
# 开始BV号为1oh4119792视频属性的抓取
# BV号为1oh4119792的视频属性抓取结束
# 开始BV号为1oT4y157jT视频属性的抓取
# BV号为1oT4y157jT的视频属性抓取结束
# 开始BV号为1bK4y1v7zv视频属性的抓取
# BV号为1bK4y1v7zv的视频属性抓取结束
# 开始BV号为1Uh411d7UP视频属性的抓取
# BV号为1Uh411d7UP的视频属性抓取结束
# 开始BV号为1RD4y127dt视频属性的抓取
# BV号为1RD4y127dt的视频属性抓取结束
# 开始BV号为1Dk4y1m7hs视频属性的抓取
# BV号为1Dk4y1m7hs的视频属性抓取结束
# 开始BV号为1Vf4y197CX视频属性的抓取
# BV号为1Vf4y197CX的视频属性抓取结束
# 开始BV号为12K4y1Y7zK视频属性的抓取
# BV号为12K4y1Y7zK的视频属性抓取结束
# 开始BV号为1QA411J7Ug视频属性的抓取
# BV号为1QA411J7Ug的视频属性抓取结束
# 开始BV号为1854y1i7KE视频属性的抓取
# BV号为1854y1i7KE的视频属性抓取结束
# 开始BV号为1cV411m7VP视频属性的抓取
# BV号为1cV411m7VP的视频属性抓取结束
# 开始BV号为1zp4y1q7m6视频属性的抓取
# BV号为1zp4y1q7m6的视频属性抓取结束
# 开始BV号为1d64y1F7N9视频属性的抓取
# BV号为1d64y1F7N9的视频属性抓取结束
# 开始BV号为1mT4y1j7fG视频属性的抓取
# BV号为1mT4y1j7fG的视频属性抓取结束
# 开始BV号为1C5411873V视频属性的抓取
# BV号为1C5411873V的视频属性抓取结束
# 开始BV号为1RT4y1j7nn视频属性的抓取
# BV号为1RT4y1j7nn的视频属性抓取结束
# 开始BV号为1Ta4y1J7rn视频属性的抓取
# BV号为1Ta4y1J7rn的视频属性抓取结束
# 开始BV号为1Bv411y7S9视频属性的抓取
# BV号为1Bv411y7S9的视频属性抓取结束
# 开始BV号为1fk4y1m7Aa视频属性的抓取
# BV号为1fk4y1m7Aa的视频属性抓取结束
# 开始BV号为1Mi4y1g7Dz视频属性的抓取
# BV号为1Mi4y1g7Dz的视频属性抓取结束
# 开始BV号为1sa4y1j7jk视频属性的抓取
# BV号为1sa4y1j7jk的视频属性抓取结束
# 开始BV号为1rh411R78c视频属性的抓取
# BV号为1rh411R78c的视频属性抓取结束
# 开始BV号为1mk4y1k7s3视频属性的抓取
# BV号为1mk4y1k7s3的视频属性抓取结束
# 开始BV号为1k54y1C7ng视频属性的抓取
# BV号为1k54y1C7ng的视频属性抓取结束
# 开始BV号为1nD4y1m7vH视频属性的抓取
# BV号为1nD4y1m7vH的视频属性抓取结束
# 开始BV号为1T541187yp视频属性的抓取
# BV号为1T541187yp的视频属性抓取结束
# 开始BV号为11D4y1d7Q5视频属性的抓取
# BV号为11D4y1d7Q5的视频属性抓取结束
# 开始BV号为1ty4y1y7Gj视频属性的抓取
# BV号为1ty4y1y7Gj的视频属性抓取结束
# 开始BV号为1pv411C7iR视频属性的抓取
# BV号为1pv411C7iR的视频属性抓取结束
# 开始BV号为1pK411K7Bv视频属性的抓取
# BV号为1pK411K7Bv的视频属性抓取结束
# 开始BV号为1p54y1m7WG视频属性的抓取
# BV号为1p54y1m7WG的视频属性抓取结束
# 开始BV号为1jV411m7sm视频属性的抓取
# BV号为1jV411m7sm的视频属性抓取结束
# 开始BV号为1M5411b7sp视频属性的抓取
# BV号为1M5411b7sp的视频属性抓取结束
# 开始BV号为1DT4y1w75M视频属性的抓取
# BV号为1DT4y1w75M的视频属性抓取结束
# 开始BV号为1Df4y1D7UX视频属性的抓取
# BV号为1Df4y1D7UX的视频属性抓取结束
# 开始BV号为1FA411J7tE视频属性的抓取
# BV号为1FA411J7tE的视频属性抓取结束
# 开始BV号为1gk4y117tp视频属性的抓取
# BV号为1gk4y117tp的视频属性抓取结束
# 开始BV号为1MK4y1e7jg视频属性的抓取
# BV号为1MK4y1e7jg的视频属性抓取结束
# 开始BV号为1iy4y1y7PK视频属性的抓取
# BV号为1iy4y1y7PK的视频属性抓取结束
# 开始BV号为1a64y1F7a3视频属性的抓取
# BV号为1a64y1F7a3的视频属性抓取结束
# 开始BV号为18D4y1o7UY视频属性的抓取
# BV号为18D4y1o7UY的视频属性抓取结束
# 开始BV号为1Bh411R7JP视频属性的抓取
# BV号为1Bh411R7JP的视频属性抓取结束
# 开始BV号为1va4y1j7SG视频属性的抓取
# BV号为1va4y1j7SG的视频属性抓取结束
# 开始BV号为18t4y1S7w6视频属性的抓取
# BV号为18t4y1S7w6的视频属性抓取结束
# 开始BV号为1np4y1e7na视频属性的抓取
# BV号为1np4y1e7na的视频属性抓取结束
# 开始BV号为1rz4y1Z7jC视频属性的抓取
# BV号为1rz4y1Z7jC的视频属性抓取结束
# 开始BV号为1gv411y7Pb视频属性的抓取
# BV号为1gv411y7Pb的视频属性抓取结束
# 开始BV号为1rA411J7LR视频属性的抓取
# BV号为1rA411J7LR的视频属性抓取结束
# 开始BV号为1Zy4y1k7rx视频属性的抓取
# BV号为1Zy4y1k7rx的视频属性抓取结束
# 开始BV号为1S54y1C7t3视频属性的抓取
# BV号为1S54y1C7t3的视频属性抓取结束
# 开始BV号为1sK4y1a74D视频属性的抓取
# BV号为1sK4y1a74D的视频属性抓取结束
# 开始BV号为1hp4y1e7od视频属性的抓取
# BV号为1hp4y1e7od的视频属性抓取结束
# 开始BV号为1Gz4y1Z7NU视频属性的抓取
# BV号为1Gz4y1Z7NU的视频属性抓取结束
# 开始BV号为1QA411E79c视频属性的抓取
# BV号为1QA411E79c的视频属性抓取结束
# 开始BV号为1CK411K72j视频属性的抓取
# BV号为1CK411K72j的视频属性抓取结束
# 开始BV号为1DC4y1t71r视频属性的抓取
# BV号为1DC4y1t71r的视频属性抓取结束
# 开始BV号为17K4y1a7HA视频属性的抓取
# BV号为17K4y1a7HA的视频属性抓取结束
# 开始BV号为1Cp4y1e72x视频属性的抓取
# BV号为1Cp4y1e72x的视频属性抓取结束
# 开始BV号为1Qa4y1L7QH视频属性的抓取
# BV号为1Qa4y1L7QH的视频属性抓取结束
# 开始BV号为1j54y1m7fJ视频属性的抓取
# BV号为1j54y1m7fJ的视频属性抓取结束
# 开始BV号为1sT4y1A7ha视频属性的抓取
# BV号为1sT4y1A7ha的视频属性抓取结束
# 开始BV号为16Z4y1N7wc视频属性的抓取
# BV号为16Z4y1N7wc的视频属性抓取结束
# 开始BV号为1BT4y1L7qs视频属性的抓取
# 开始BV号为1BT4y1L7qs视频属性的抓取
# BV号为1BT4y1L7qs的视频属性抓取结束
# 开始BV号为1V54y1175k视频属性的抓取
# BV号为1V54y1175k的视频属性抓取结束
# 开始BV号为1RV411272w视频属性的抓取
# BV号为1RV411272w的视频属性抓取结束
# 开始BV号为1ui4y1E7JR视频属性的抓取
# BV号为1ui4y1E7JR的视频属性抓取结束
# 开始BV号为1mZ4y1P7L5视频属性的抓取
# BV号为1mZ4y1P7L5的视频属性抓取结束
# 开始BV号为1Qa4y177xQ视频属性的抓取
# BV号为1Qa4y177xQ的视频属性抓取结束
# 开始BV号为1Lk4y117ya视频属性的抓取
# BV号为1Lk4y117ya的视频属性抓取结束
# 开始BV号为1LK4y1e7zq视频属性的抓取
# BV号为1LK4y1e7zq的视频属性抓取结束
# 开始BV号为1JV411S7j9视频属性的抓取
# BV号为1JV411S7j9的视频属性抓取结束
# 开始BV号为1wy4y1y7Cb视频属性的抓取
# BV号为1wy4y1y7Cb的视频属性抓取结束
# 开始BV号为1e64y1F7v7视频属性的抓取
# BV号为1e64y1F7v7的视频属性抓取结束
# 开始BV号为1py4y1k7J4视频属性的抓取
# BV号为1py4y1k7J4的视频属性抓取结束
# 开始BV号为1JK411K72q视频属性的抓取
# BV号为1JK411K72q的视频属性抓取结束
# 开始BV号为1FZ4y1T7ru视频属性的抓取
# BV号为1FZ4y1T7ru的视频属性抓取结束
# 开始BV号为1mK411K7oY视频属性的抓取
# BV号为1mK411K7oY的视频属性抓取结束
# 开始BV号为1F54y117dQ视频属性的抓取
# BV号为1F54y117dQ的视频属性抓取结束
# 开始BV号为1ip4y1e7tA视频属性的抓取
# BV号为1ip4y1e7tA的视频属性抓取结束
# 开始BV号为11k4y127gR视频属性的抓取
# BV号为11k4y127gR的视频属性抓取结束
# 开始BV号为1Wh411X7ZX视频属性的抓取
# BV号为1Wh411X7ZX的视频属性抓取结束
# 开始BV号为1my4y1k752视频属性的抓取
# BV号为1my4y1k752的视频属性抓取结束
# 开始BV号为1PV411m7HP视频属性的抓取
# BV号为1PV411m7HP的视频属性抓取结束
# 开始BV号为1Hp4y1a7yT视频属性的抓取
# BV号为1Hp4y1a7yT的视频属性抓取结束
# 开始BV号为1zi4y1M7FA视频属性的抓取
# BV号为1zi4y1M7FA的视频属性抓取结束
# 开始BV号为1eK411P7LS视频属性的抓取
# BV号为1eK411P7LS的视频属性抓取结束
# 开始BV号为1m54y1C79J视频属性的抓取
# BV号为1m54y1C79J的视频属性抓取结束
# 开始BV号为1pV41117dk视频属性的抓取
# BV号为1pV41117dk的视频属性抓取结束
# 开始BV号为1ca4y1j7xn视频属性的抓取
# BV号为1ca4y1j7xn的视频属性抓取结束
# 开始BV号为1q5411h7dg视频属性的抓取
# BV号为1q5411h7dg的视频属性抓取结束
# 开始BV号为1rh411X78f视频属性的抓取
# BV号为1rh411X78f的视频属性抓取结束
# 开始BV号为1Ja4y1E7HT视频属性的抓取
# BV号为1Ja4y1E7HT的视频属性抓取结束
# 开始BV号为1MK4y1Y7MF视频属性的抓取
# BV号为1MK4y1Y7MF的视频属性抓取结束
# 开始BV号为1qD4y1o7sr视频属性的抓取
# BV号为1qD4y1o7sr的视频属性抓取结束
# 开始BV号为1Lk4y1y7xw视频属性的抓取
# BV号为1Lk4y1y7xw的视频属性抓取结束
# 开始BV号为1sa4y1j7cp视频属性的抓取
# BV号为1sa4y1j7cp的视频属性抓取结束
# 开始BV号为1sV41117Vv视频属性的抓取
# BV号为1sV41117Vv的视频属性抓取结束
# 开始BV号为12K411P7ow视频属性的抓取
# BV号为12K411P7ow的视频属性抓取结束
# 开始BV号为1fV41127Hb视频属性的抓取
# BV号为1fV41127Hb的视频属性抓取结束
# 开始BV号为1pv41117aF视频属性的抓取
# BV号为1pv41117aF的视频属性抓取结束
# 开始BV号为1ut4y1q7J1视频属性的抓取
# BV号为1ut4y1q7J1的视频属性抓取结束
# 开始BV号为1NV411m73X视频属性的抓取
# BV号为1NV411m73X的视频属性抓取结束
# 开始BV号为1cA411J7cP视频属性的抓取
# BV号为1cA411J7cP的视频属性抓取结束
# 开始BV号为1Af4y1D75T视频属性的抓取
# BV号为1Af4y1D75T的视频属性抓取结束
# 开始BV号为1fy4y1y7PV视频属性的抓取
# BV号为1fy4y1y7PV的视频属性抓取结束
# 开始BV号为1mt4y1q7Tp视频属性的抓取
# BV号为1mt4y1q7Tp的视频属性抓取结束
# 开始BV号为1Zi4y177DQ视频属性的抓取
# BV号为1Zi4y177DQ的视频属性抓取结束
# 开始BV号为1h54y127DD视频属性的抓取
# BV号为1h54y127DD的视频属性抓取结束
# 开始BV号为1sp4y1e78i视频属性的抓取
# BV号为1sp4y1e78i的视频属性抓取结束
# 开始BV号为1Dt4y1S7C3视频属性的抓取
# BV号为1Dt4y1S7C3的视频属性抓取结束
# 开始BV号为1Mz4y1Z7pn视频属性的抓取
# BV号为1Mz4y1Z7pn的视频属性抓取结束
# 开始BV号为1zt4y1i7kd视频属性的抓取
# BV号为1zt4y1i7kd的视频属性抓取结束
# 开始BV号为1t54y1y75m视频属性的抓取
# BV号为1t54y1y75m的视频属性抓取结束
# 开始BV号为1YK411P74A视频属性的抓取
# BV号为1YK411P74A的视频属性抓取结束
# 开始BV号为1eh411R7LA视频属性的抓取
# BV号为1eh411R7LA的视频属性抓取结束
# 开始BV号为1T5411j7FU视频属性的抓取
# BV号为1T5411j7FU的视频属性抓取结束
# 开始BV号为1VK4y1Y751视频属性的抓取
# BV号为1VK4y1Y751的视频属性抓取结束
# 开始BV号为1uk4y117Dy视频属性的抓取
# BV号为1uk4y117Dy的视频属性抓取结束
# 开始BV号为1N54y1y7hB视频属性的抓取
# BV号为1N54y1y7hB的视频属性抓取结束
# 开始BV号为16K411P7SN视频属性的抓取
# BV号为16K411P7SN的视频属性抓取结束
# 开始BV号为16z4y1o7Mr视频属性的抓取
# BV号为16z4y1o7Mr的视频属性抓取结束
# 开始BV号为1L54y1r7Xr视频属性的抓取
# BV号为1L54y1r7Xr的视频属性抓取结束
# 开始BV号为1Vy4y1C7gj视频属性的抓取
# BV号为1Vy4y1C7gj的视频属性抓取结束
# 开始BV号为1NV411y7db视频属性的抓取
# BV号为1NV411y7db的视频属性抓取结束
# 开始BV号为1ha4y1L7k5视频属性的抓取
# BV号为1ha4y1L7k5的视频属性抓取结束
# 开始BV号为1Dt4y1v7YG视频属性的抓取
# BV号为1Dt4y1v7YG的视频属性抓取结束
# 开始BV号为1jD4y1d7Ry视频属性的抓取
# BV号为1jD4y1d7Ry的视频属性抓取结束
# 开始BV号为1rz4y1d7xM视频属性的抓取
# BV号为1rz4y1d7xM的视频属性抓取结束
# 开始BV号为1dA41177wu视频属性的抓取
# BV号为1dA41177wu的视频属性抓取结束
# 开始BV号为1ua4y1L7H8视频属性的抓取
# BV号为1ua4y1L7H8的视频属性抓取结束
# 开始BV号为1e54y1k7Vb视频属性的抓取
# BV号为1e54y1k7Vb的视频属性抓取结束
# 开始BV号为1yf4y1B7NY视频属性的抓取
# BV号为1yf4y1B7NY的视频属性抓取结束
# 开始BV号为1Af4y1z7ek视频属性的抓取
# BV号为1Af4y1z7ek的视频属性抓取结束
# 开始BV号为18t4y1v7NJ视频属性的抓取
# BV号为18t4y1v7NJ的视频属性抓取结束
# 开始BV号为175411L7iw视频属性的抓取
# BV号为175411L7iw的视频属性抓取结束
# 开始BV号为1oV411172m视频属性的抓取
# BV号为1oV411172m的视频属性抓取结束
# 开始BV号为14T4y1w7s7视频属性的抓取
# BV号为14T4y1w7s7的视频属性抓取结束
# 开始BV号为15v411y7HE视频属性的抓取
# BV号为15v411y7HE的视频属性抓取结束
# 开始BV号为15v411y7xm视频属性的抓取
# BV号为15v411y7xm的视频属性抓取结束
# 开始BV号为1MD4y197ii视频属性的抓取
# BV号为1MD4y197ii的视频属性抓取结束
# 开始BV号为1Tf4y1B7og视频属性的抓取
# BV号为1Tf4y1B7og的视频属性抓取结束
# 开始BV号为1Ht4y1v7Ba视频属性的抓取
# BV号为1Ht4y1v7Ba的视频属性抓取结束
# 开始BV号为1hk4y1C7tx视频属性的抓取
# BV号为1hk4y1C7tx的视频属性抓取结束
# 开始BV号为1BK411G7uP视频属性的抓取
# BV号为1BK411G7uP的视频属性抓取结束
# 开始BV号为17V411y774视频属性的抓取
# BV号为17V411y774的视频属性抓取结束
# 开始BV号为1vi4y1E7ka视频属性的抓取
# BV号为1vi4y1E7ka的视频属性抓取结束
# 开始BV号为1HK411A7Ey视频属性的抓取
# BV号为1HK411A7Ey的视频属性抓取结束
# 开始BV号为18i4y1j72g视频属性的抓取
# BV号为18i4y1j72g的视频属性抓取结束
# 开始BV号为18v411y7dk视频属性的抓取
# BV号为18v411y7dk的视频属性抓取结束
# 开始BV号为1by4y1r7aq视频属性的抓取
# BV号为1by4y1r7aq的视频属性抓取结束
# 开始BV号为18t4y1v7E8视频属性的抓取
# BV号为18t4y1v7E8的视频属性抓取结束
# 开始BV号为1ya411A7qt视频属性的抓取
# BV号为1ya411A7qt的视频属性抓取结束
# 开始BV号为1qz4y1d7eA视频属性的抓取
# BV号为1qz4y1d7eA的视频属性抓取结束
# 开始BV号为1Xi4y1j77W视频属性的抓取
# BV号为1Xi4y1j77W的视频属性抓取结束
# 开始BV号为1Ph41197yy视频属性的抓取
# BV号为1Ph41197yy的视频属性抓取结束
# 开始BV号为1xt4y1i7ba视频属性的抓取
# BV号为1xt4y1i7ba的视频属性抓取结束
# 开始BV号为13y4y1r7D2视频属性的抓取
# BV号为13y4y1r7D2的视频属性抓取结束
# 开始BV号为1N54y1r7Yu视频属性的抓取
# BV号为1N54y1r7Yu的视频属性抓取结束
# 开始BV号为1av411k7CG视频属性的抓取
# BV号为1av411k7CG的视频属性抓取结束
# 开始BV号为16v411k7ei视频属性的抓取
# BV号为16v411k7ei的视频属性抓取结束
# 开始BV号为1cZ4y1V78z视频属性的抓取
# BV号为1cZ4y1V78z的视频属性抓取结束
# 开始BV号为16D4y1d7TH视频属性的抓取
# BV号为16D4y1d7TH的视频属性抓取结束
# 开始BV号为1ey4y1r7ZK视频属性的抓取
# BV号为1ey4y1r7ZK的视频属性抓取结束
# 开始BV号为1wz4y1o7j1视频属性的抓取
# BV号为1wz4y1o7j1的视频属性抓取结束
# 开始BV号为13Z4y1V7jX视频属性的抓取
# BV号为13Z4y1V7jX的视频属性抓取结束
# 开始BV号为1Nk4y1C79m视频属性的抓取
# BV号为1Nk4y1C79m的视频属性抓取结束
# 开始BV号为11z4y1d7Uc视频属性的抓取
# BV号为11z4y1d7Uc的视频属性抓取结束
# 开始BV号为1hA4117737视频属性的抓取
# BV号为1hA4117737的视频属性抓取结束
# 开始BV号为1QK4y1878z视频属性的抓取
# BV号为1QK4y1878z的视频属性抓取结束
# 开始BV号为1z541157UC视频属性的抓取
# BV号为1z541157UC的视频属性抓取结束
# 开始BV号为1GD4y1972t视频属性的抓取
# BV号为1GD4y1972t的视频属性抓取结束
# 开始BV号为1gp4y1k7iY视频属性的抓取
# BV号为1gp4y1k7iY的视频属性抓取结束
# 开始BV号为1Qa411w7gN视频属性的抓取
# BV号为1Qa411w7gN的视频属性抓取结束
# 开始BV号为1kt4y1v7H6视频属性的抓取
# BV号为1kt4y1v7H6的视频属性抓取结束
# 开始BV号为1AD4y1d72S视频属性的抓取
# BV号为1AD4y1d72S的视频属性抓取结束
# 开始BV号为1Ak4y1y7Tg视频属性的抓取
# BV号为1Ak4y1y7Tg的视频属性抓取结束
# 开始BV号为1ay4y1B7dN视频属性的抓取
# BV号为1ay4y1B7dN的视频属性抓取结束
# 开始BV号为1Ya4y1L7Nt视频属性的抓取
# BV号为1Ya4y1L7Nt的视频属性抓取结束
# 开始BV号为1sy4y1C7Lp视频属性的抓取
# BV号为1sy4y1C7Lp的视频属性抓取结束
# 开始BV号为1o54y167AL视频属性的抓取
# BV号为1o54y167AL的视频属性抓取结束
# 开始BV号为13T4y1w7FU视频属性的抓取
# BV号为13T4y1w7FU的视频属性抓取结束
# 开始BV号为1o54y1k7YF视频属性的抓取
# BV号为1o54y1k7YF的视频属性抓取结束
# 开始BV号为1B54y1k7SE视频属性的抓取
# BV号为1B54y1k7SE的视频属性抓取结束
# 开始BV号为1RV411y733视频属性的抓取
# BV号为1RV411y733的视频属性抓取结束
# 开始BV号为1Nr4y1w7vi视频属性的抓取
# BV号为1Nr4y1w7vi的视频属性抓取结束
# 开始BV号为1Et4y1i79T视频属性的抓取
# BV号为1Et4y1i79T的视频属性抓取结束
# 开始BV号为1Kf4y1z7W2视频属性的抓取
# BV号为1Kf4y1z7W2的视频属性抓取结束
# 开始BV号为1Vv411C78z视频属性的抓取
# BV号为1Vv411C78z的视频属性抓取结束
# 开始BV号为1VK411A7Sv视频属性的抓取
# BV号为1VK411A7Sv的视频属性抓取结束
# 开始BV号为1av411y736视频属性的抓取
# BV号为1av411y736的视频属性抓取结束
# 开始BV号为1vT4y1F78E视频属性的抓取
# BV号为1vT4y1F78E的视频属性抓取结束
# 开始BV号为1h5411L7Ts视频属性的抓取
# BV号为1h5411L7Ts的视频属性抓取结束
# 开始BV号为1Y5411L7gT视频属性的抓取
# BV号为1Y5411L7gT的视频属性抓取结束
# 开始BV号为1GT4y1F7af视频属性的抓取
# BV号为1GT4y1F7af的视频属性抓取结束
# 开始BV号为1gT4y1F7Zn视频属性的抓取
# BV号为1gT4y1F7Zn的视频属性抓取结束
# 开始BV号为1rA41177RB视频属性的抓取
# BV号为1rA41177RB的视频属性抓取结束
# 开始BV号为1sy4y1r7Pi视频属性的抓取
# BV号为1sy4y1r7Pi的视频属性抓取结束
# 开始BV号为1mV411y7yt视频属性的抓取
# BV号为1mV411y7yt的视频属性抓取结束
# 开始BV号为1cT4y1w7zx视频属性的抓取
# BV号为1cT4y1w7zx的视频属性抓取结束
# 开始BV号为1Xz4y1o7rV视频属性的抓取
# BV号为1Xz4y1o7rV的视频属性抓取结束
# 开始BV号为1X5411575f视频属性的抓取
# BV号为1X5411575f的视频属性抓取结束
# 开始BV号为1g54y1271w视频属性的抓取
# BV号为1g54y1271w的视频属性抓取结束
# 开始BV号为1Pp4y1k7Bm视频属性的抓取
# BV号为1Pp4y1k7Bm的视频属性抓取结束
# 开始BV号为1Vz4y1f7KS视频属性的抓取
# BV号为1Vz4y1f7KS的视频属性抓取结束
# 开始BV号为1eK411N72k视频属性的抓取
# BV号为1eK411N72k的视频属性抓取结束
# 开始BV号为1zz4y1C7op视频属性的抓取
# BV号为1zz4y1C7op的视频属性抓取结束
# 开始BV号为1Vv411k7Ey视频属性的抓取
# BV号为1Vv411k7Ey的视频属性抓取结束
# 开始BV号为1fa4y1W7qf视频属性的抓取
# BV号为1fa4y1W7qf的视频属性抓取结束
# 开始BV号为1zV411y7ip视频属性的抓取
# BV号为1zV411y7ip的视频属性抓取结束
# 开始BV号为1ny4y1C7wj视频属性的抓取
# BV号为1ny4y1C7wj的视频属性抓取结束
# 开始BV号为1bp4y1Y7Ks视频属性的抓取
# BV号为1bp4y1Y7Ks的视频属性抓取结束
# 开始BV号为1ya411w74A视频属性的抓取
# BV号为1ya411w74A的视频属性抓取结束
# 开始BV号为1jv411y75B视频属性的抓取
# BV号为1jv411y75B的视频属性抓取结束
# 开始BV号为1Vz4y1o7Wt视频属性的抓取
# BV号为1Vz4y1o7Wt的视频属性抓取结束
# 开始BV号为1Af4y1B7qj视频属性的抓取
# BV号为1Af4y1B7qj的视频属性抓取结束
# 开始BV号为1wD4y1d76r视频属性的抓取
# BV号为1wD4y1d76r的视频属性抓取结束
# 开始BV号为1Sp4y1r7Zw视频属性的抓取
# BV号为1Sp4y1r7Zw的视频属性抓取结束
# 开始BV号为1ei4y1j7xt视频属性的抓取
# BV号为1ei4y1j7xt的视频属性抓取结束
# 开始BV号为1aK4y1Z7Ms视频属性的抓取
# BV号为1aK4y1Z7Ms的视频属性抓取结束
# 开始BV号为1Mv411C7km视频属性的抓取
# BV号为1Mv411C7km的视频属性抓取结束
# 2020-12-22 12:22:52.930001

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-14-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_shenghuo_dongwu.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 2月     98   98    98   98   98   98   98   98    98      98   98    98   98
# 3月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月    99   99   99   99   99   99    99
# 2月    98   98   98   98   98   98    98
# 3月    99   99   99   99   99   99    99
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月   100  100  100  100  100  100   100
# 7月   100  100  100  100  100  100   100
# 8月   100  100  100  100  100  100   100
# 9月   100  100  100  100  100  100   100

# %%
channel_shenghuo_dongwu.to_json('channel_shenghuo_dongwu.json')
