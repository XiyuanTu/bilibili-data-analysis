# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_shenghuo_qita=pd.DataFrame(columns=columns)
channel_shenghuo_qita
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[9]/div/a/span').click()  #选择“生活”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[9]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '生活'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[9]/a').click()  #选择“其他”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[9]/a').text
sub_channel
# Out:
# '其他'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(7,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_shenghuo_qita.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-22 07:43:21.192272
# <ipython-input-25-93c7b881c8e5>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-25-93c7b881c8e5>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-25-93c7b881c8e5>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1oD4y1S7BT视频属性的抓取
# BV号为1oD4y1S7BT的视频属性抓取结束
# <ipython-input-25-93c7b881c8e5>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1CV411B7wr视频属性的抓取
# BV号为1CV411B7wr的视频属性抓取结束
# 开始BV号为11K411J761视频属性的抓取
# BV号为11K411J761的视频属性抓取结束
# 开始BV号为16k4y1m72w视频属性的抓取
# BV号为16k4y1m72w的视频属性抓取结束
# 开始BV号为1254y1S7KP视频属性的抓取
# BV号为1254y1S7KP的视频属性抓取结束
# 开始BV号为1jT4y177Fo视频属性的抓取
# BV号为1jT4y177Fo的视频属性抓取结束
# 开始BV号为1Ft4y1X7T7视频属性的抓取
# BV号为1Ft4y1X7T7的视频属性抓取结束
# 开始BV号为1qD4y1Q7gq视频属性的抓取
# BV号为1qD4y1Q7gq的视频属性抓取结束
# 开始BV号为1uf4y1d7yx视频属性的抓取
# BV号为1uf4y1d7yx的视频属性抓取结束
# 开始BV号为1ii4y1u7Nm视频属性的抓取
# BV号为1ii4y1u7Nm的视频属性抓取结束
# 开始BV号为1kf4y1R7az视频属性的抓取
# BV号为1kf4y1R7az的视频属性抓取结束
# 开始BV号为1Ck4y1q7W2视频属性的抓取
# BV号为1Ck4y1q7W2的视频属性抓取结束
# 开始BV号为1TA411v7S2视频属性的抓取
# BV号为1TA411v7S2的视频属性抓取结束
# 开始BV号为1e54y1S7Ee视频属性的抓取
# BV号为1e54y1S7Ee的视频属性抓取结束
# 开始BV号为1QV411672E视频属性的抓取
# BV号为1QV411672E的视频属性抓取结束
# 开始BV号为1kZ4y1T7D2视频属性的抓取
# BV号为1kZ4y1T7D2的视频属性抓取结束
# 开始BV号为1F54y1q77R视频属性的抓取
# BV号为1F54y1q77R的视频属性抓取结束
# 开始BV号为1ei4y1G7Ua视频属性的抓取
# BV号为1ei4y1G7Ua的视频属性抓取结束
# 开始BV号为1nz4y1X7Qc视频属性的抓取
# BV号为1nz4y1X7Qc的视频属性抓取结束
# 开始BV号为1hz411v7R7视频属性的抓取
# BV号为1hz411v7R7的视频属性抓取结束
# 开始BV号为1VK4y1x7Ge视频属性的抓取
# BV号为1VK4y1x7Ge的视频属性抓取结束
# 开始BV号为1Uk4y1q7gN视频属性的抓取
# BV号为1Uk4y1q7gN的视频属性抓取结束
# 开始BV号为1nv411q72W视频属性的抓取
# BV号为1nv411q72W的视频属性抓取结束
# 开始BV号为1gK411n7Eg视频属性的抓取
# BV号为1gK411n7Eg的视频属性抓取结束
# 开始BV号为1vZ4y1u7nN视频属性的抓取
# BV号为1vZ4y1u7nN的视频属性抓取结束
# 开始BV号为1CD4y1S7gu视频属性的抓取
# BV号为1CD4y1S7gu的视频属性抓取结束
# 开始BV号为1vf4y1R79Y视频属性的抓取
# BV号为1vf4y1R79Y的视频属性抓取结束
# 开始BV号为1E5411e7Fj视频属性的抓取
# BV号为1E5411e7Fj的视频属性抓取结束
# 开始BV号为1ci4y1G7Cw视频属性的抓取
# BV号为1ci4y1G7Cw的视频属性抓取结束
# 开始BV号为1MD4y1S73U视频属性的抓取
# BV号为1MD4y1S73U的视频属性抓取结束
# 开始BV号为1Qt4y197Xs视频属性的抓取
# BV号为1Qt4y197Xs的视频属性抓取结束
# 开始BV号为1R5411Y7kA视频属性的抓取
# BV号为1R5411Y7kA的视频属性抓取结束
# 开始BV号为1wT4y1j7DJ视频属性的抓取
# BV号为1wT4y1j7DJ的视频属性抓取结束
# 开始BV号为1zh411o7u9视频属性的抓取
# BV号为1zh411o7u9的视频属性抓取结束
# 开始BV号为16T4y1779p视频属性的抓取
# BV号为16T4y1779p的视频属性抓取结束
# 开始BV号为1Wt4y1Q7zd视频属性的抓取
# BV号为1Wt4y1Q7zd的视频属性抓取结束
# 开始BV号为1gD4y1U7r5视频属性的抓取
# BV号为1gD4y1U7r5的视频属性抓取结束
# 开始BV号为1xz4y1D7TP视频属性的抓取
# BV号为1xz4y1D7TP的视频属性抓取结束
# 开始BV号为1XD4y1S7KK视频属性的抓取
# BV号为1XD4y1S7KK的视频属性抓取结束
# 开始BV号为1qK4y1e7Mx视频属性的抓取
# BV号为1qK4y1e7Mx的视频属性抓取结束
# 开始BV号为1ja4y1a7rV视频属性的抓取
# BV号为1ja4y1a7rV的视频属性抓取结束
# 开始BV号为1nT4y1779i视频属性的抓取
# BV号为1nT4y1779i的视频属性抓取结束
# 开始BV号为1tA411e7wr视频属性的抓取
# BV号为1tA411e7wr的视频属性抓取结束
# 开始BV号为1JD4y1S7UG视频属性的抓取
# BV号为1JD4y1S7UG的视频属性抓取结束
# 开始BV号为1Kz411v72U视频属性的抓取
# BV号为1Kz411v72U的视频属性抓取结束
# 开始BV号为1fV41167Fa视频属性的抓取
# BV号为1fV41167Fa的视频属性抓取结束
# 开始BV号为1J54y1q7RQ视频属性的抓取
# BV号为1J54y1q7RQ的视频属性抓取结束
# 开始BV号为1Ut4y197Tn视频属性的抓取
# 开始BV号为1Ut4y197Tn视频属性的抓取
# BV号为1Ut4y197Tn的视频属性抓取结束
# 开始BV号为1Ha4y1a7TB视频属性的抓取
# BV号为1Ha4y1a7TB的视频属性抓取结束
# 开始BV号为1m5411Y7ig视频属性的抓取
# BV号为1m5411Y7ig的视频属性抓取结束
# 开始BV号为1Lz4y1D7ov视频属性的抓取
# BV号为1Lz4y1D7ov的视频属性抓取结束
# 开始BV号为1sa4y1a7iV视频属性的抓取
# BV号为1sa4y1a7iV的视频属性抓取结束
# 开始BV号为1KT4y1E7ux视频属性的抓取
# BV号为1KT4y1E7ux的视频属性抓取结束
# 开始BV号为16V411B7AE视频属性的抓取
# BV号为16V411B7AE的视频属性抓取结束
# 开始BV号为1o54y1v7Ac视频属性的抓取
# BV号为1o54y1v7Ac的视频属性抓取结束
# 开始BV号为1Mi4y137P8视频属性的抓取
# BV号为1Mi4y137P8的视频属性抓取结束
# 开始BV号为1jz4y1D77f视频属性的抓取
# BV号为1jz4y1D77f的视频属性抓取结束
# 开始BV号为1w54y1q7Lk视频属性的抓取
# BV号为1w54y1q7Lk的视频属性抓取结束
# 开始BV号为1tD4y1U7r3视频属性的抓取
# BV号为1tD4y1U7r3的视频属性抓取结束
# 开始BV号为1Lt4y197bf视频属性的抓取
# BV号为1Lt4y197bf的视频属性抓取结束
# 开始BV号为1GT4y1j7ep视频属性的抓取
# BV号为1GT4y1j7ep的视频属性抓取结束
# 开始BV号为19Z4y1u7GC视频属性的抓取
# BV号为19Z4y1u7GC的视频属性抓取结束
# 开始BV号为1Yh411Z7xE视频属性的抓取
# BV号为1Yh411Z7xE的视频属性抓取结束
# 开始BV号为1JV41167fb视频属性的抓取
# BV号为1JV41167fb的视频属性抓取结束
# 开始BV号为1rK4y1e7ta视频属性的抓取
# BV号为1rK4y1e7ta的视频属性抓取结束
# 开始BV号为1vT4y1E7a2视频属性的抓取
# BV号为1vT4y1E7a2的视频属性抓取结束
# 开始BV号为1WZ4y1u7jL视频属性的抓取
# BV号为1WZ4y1u7jL的视频属性抓取结束
# 开始BV号为1ui4y137ov视频属性的抓取
# BV号为1ui4y137ov的视频属性抓取结束
# 开始BV号为1iT4y17759视频属性的抓取
# BV号为1iT4y17759的视频属性抓取结束
# 开始BV号为1wh411Z7vE视频属性的抓取
# BV号为1wh411Z7vE的视频属性抓取结束
# 开始BV号为15f4y117D1视频属性的抓取
# BV号为15f4y117D1的视频属性抓取结束
# 开始BV号为1VT4y1E7fZ视频属性的抓取
# BV号为1VT4y1E7fZ的视频属性抓取结束
# 开始BV号为1MD4y1D7wX视频属性的抓取
# BV号为1MD4y1D7wX的视频属性抓取结束
# 开始BV号为1ZV41167sm视频属性的抓取
# BV号为1ZV41167sm的视频属性抓取结束
# 开始BV号为1tp4y1U7jY视频属性的抓取
# BV号为1tp4y1U7jY的视频属性抓取结束
# 开始BV号为1PT4y1j72p视频属性的抓取
# BV号为1PT4y1j72p的视频属性抓取结束
# 开始BV号为1V54y1z7T9视频属性的抓取
# BV号为1V54y1z7T9的视频属性抓取结束
# 开始BV号为1NZ4y1g7uF视频属性的抓取
# BV号为1NZ4y1g7uF的视频属性抓取结束
# 开始BV号为1jA411Y7A3视频属性的抓取
# BV号为1jA411Y7A3的视频属性抓取结束
# 开始BV号为1Ba4y1h77E视频属性的抓取
# BV号为1Ba4y1h77E的视频属性抓取结束
# 开始BV号为1oK4y1e77S视频属性的抓取
# BV号为1oK4y1e77S的视频属性抓取结束
# 开始BV号为11h411o7d3视频属性的抓取
# BV号为11h411o7d3的视频属性抓取结束
# 开始BV号为1Gi4y1G7Bu视频属性的抓取
# BV号为1Gi4y1G7Bu的视频属性抓取结束
# 开始BV号为125411h7mo视频属性的抓取
# BV号为125411h7mo的视频属性抓取结束
# 开始BV号为1SK4y1s7Y8视频属性的抓取
# BV号为1SK4y1s7Y8的视频属性抓取结束
# 开始BV号为1uV411z7Wv视频属性的抓取
# BV号为1uV411z7Wv的视频属性抓取结束
# 开始BV号为1Dv411i7RA视频属性的抓取
# BV号为1Dv411i7RA的视频属性抓取结束
# 开始BV号为13T4y1j7eP视频属性的抓取
# BV号为13T4y1j7eP的视频属性抓取结束
# 开始BV号为1XC4y187oV视频属性的抓取
# BV号为1XC4y187oV的视频属性抓取结束
# 开始BV号为1ip4y1S7jy视频属性的抓取
# BV号为1ip4y1S7jy的视频属性抓取结束
# 开始BV号为1ik4y1q7bv视频属性的抓取
# BV号为1ik4y1q7bv的视频属性抓取结束
# 开始BV号为1EV411z7Jz视频属性的抓取
# BV号为1EV411z7Jz的视频属性抓取结束
# 开始BV号为1eh411o7nB视频属性的抓取
# BV号为1eh411o7nB的视频属性抓取结束
# 开始BV号为1eC4y187p3视频属性的抓取
# BV号为1eC4y187p3的视频属性抓取结束
# 开始BV号为1ND4y1S7tV视频属性的抓取
# BV号为1ND4y1S7tV的视频属性抓取结束
# 开始BV号为1jh411Z7nM视频属性的抓取
# BV号为1jh411Z7nM的视频属性抓取结束
# 开始BV号为1Yk4y1q7eB视频属性的抓取
# BV号为1Yk4y1q7eB的视频属性抓取结束
# 开始BV号为1i5411a7V8视频属性的抓取
# BV号为1i5411a7V8的视频属性抓取结束
# 开始BV号为1CK411J7Rv视频属性的抓取
# BV号为1CK411J7Rv的视频属性抓取结束
# 开始BV号为18p4y1S7hV视频属性的抓取
# BV号为18p4y1S7hV的视频属性抓取结束
# 开始BV号为1AK4y1e7Mm视频属性的抓取
# BV号为1AK4y1e7Mm的视频属性抓取结束
# 开始BV号为1cv41117SB视频属性的抓取
# BV号为1cv41117SB的视频属性抓取结束
# 开始BV号为1yt4y1D7uC视频属性的抓取
# BV号为1yt4y1D7uC的视频属性抓取结束
# 开始BV号为1yf4y1X7wP视频属性的抓取
# BV号为1yf4y1X7wP的视频属性抓取结束
# 开始BV号为1ta4y177ST视频属性的抓取
# BV号为1ta4y177ST的视频属性抓取结束
# 开始BV号为1XC4y1478L视频属性的抓取
# BV号为1XC4y1478L的视频属性抓取结束
# 开始BV号为1rC4y1b76G视频属性的抓取
# BV号为1rC4y1b76G的视频属性抓取结束
# 开始BV号为14a4y177QZ视频属性的抓取
# BV号为14a4y177QZ的视频属性抓取结束
# 开始BV号为11C4y1b7HF视频属性的抓取
# BV号为11C4y1b7HF的视频属性抓取结束
# 开始BV号为18K411T7Mp视频属性的抓取
# BV号为18K411T7Mp的视频属性抓取结束
# 开始BV号为1Z5411a7FK视频属性的抓取
# BV号为1Z5411a7FK的视频属性抓取结束
# 开始BV号为1j64y1c7KW视频属性的抓取
# BV号为1j64y1c7KW的视频属性抓取结束
# 开始BV号为1bZ4y1K71z视频属性的抓取
# BV号为1bZ4y1K71z的视频属性抓取结束
# 开始BV号为1AC4y1t7cw视频属性的抓取
# BV号为1AC4y1t7cw的视频属性抓取结束
# 开始BV号为1CV411z7qb视频属性的抓取
# BV号为1CV411z7qb的视频属性抓取结束
# 开始BV号为19Z4y1K7xu视频属性的抓取
# BV号为19Z4y1K7xu的视频属性抓取结束
# 开始BV号为1Ji4y1g7pz视频属性的抓取
# BV号为1Ji4y1g7pz的视频属性抓取结束
# 开始BV号为1u54y1i71b视频属性的抓取
# BV号为1u54y1i71b的视频属性抓取结束
# 开始BV号为1Dv411q7gB视频属性的抓取
# BV号为1Dv411q7gB的视频属性抓取结束
# 开始BV号为1h54y1v71i视频属性的抓取
# BV号为1h54y1v71i的视频属性抓取结束
# 开始BV号为1Va4y1E7Hm视频属性的抓取
# BV号为1Va4y1E7Hm的视频属性抓取结束
# 开始BV号为1pi4y1g71o视频属性的抓取
# BV号为1pi4y1g71o的视频属性抓取结束
# 开始BV号为1L64y1c7kY视频属性的抓取
# BV号为1L64y1c7kY的视频属性抓取结束
# 开始BV号为1xf4y197cB视频属性的抓取
# BV号为1xf4y197cB的视频属性抓取结束
# 开始BV号为1Ei4y1M7XV视频属性的抓取
# BV号为1Ei4y1M7XV的视频属性抓取结束
# 开始BV号为1k64y1F7b1视频属性的抓取
# BV号为1k64y1F7b1的视频属性抓取结束
# 开始BV号为1GC4y187C5视频属性的抓取
# BV号为1GC4y187C5的视频属性抓取结束
# 开始BV号为1SV411z7FV视频属性的抓取
# BV号为1SV411z7FV的视频属性抓取结束
# 开始BV号为1ka4y1E77y视频属性的抓取
# BV号为1ka4y1E77y的视频属性抓取结束
# 开始BV号为1fV411z7fD视频属性的抓取
# BV号为1fV411z7fD的视频属性抓取结束
# 开始BV号为1mK4y1e7kY视频属性的抓取
# BV号为1mK4y1e7kY的视频属性抓取结束
# 开始BV号为1tk4y1m7uD视频属性的抓取
# BV号为1tk4y1m7uD的视频属性抓取结束
# 开始BV号为1vC4y1t7BW视频属性的抓取
# BV号为1vC4y1t7BW的视频属性抓取结束
# 开始BV号为1zZ4y1M789视频属性的抓取
# BV号为1zZ4y1M789的视频属性抓取结束
# 开始BV号为1Sa4y177Wh视频属性的抓取
# BV号为1Sa4y177Wh的视频属性抓取结束
# 开始BV号为1554y1v7Ka视频属性的抓取
# BV号为1554y1v7Ka的视频属性抓取结束
# 开始BV号为1G64y1F7aW视频属性的抓取
# BV号为1G64y1F7aW的视频属性抓取结束
# 开始BV号为1mi4y1M7JJ视频属性的抓取
# BV号为1mi4y1M7JJ的视频属性抓取结束
# 开始BV号为1HD4y1U7H9视频属性的抓取
# BV号为1HD4y1U7H9的视频属性抓取结束
# 开始BV号为1pK411n7tr视频属性的抓取
# BV号为1pK411n7tr的视频属性抓取结束
# 开始BV号为1HZ4y1M72v视频属性的抓取
# BV号为1HZ4y1M72v的视频属性抓取结束
# 开始BV号为1JK4y1Y7kX视频属性的抓取
# BV号为1JK4y1Y7kX的视频属性抓取结束
# 开始BV号为1ii4y1g78R视频属性的抓取
# BV号为1ii4y1g78R的视频属性抓取结束
# 开始BV号为1Yv411v7nh视频属性的抓取
# BV号为1Yv411v7nh的视频属性抓取结束
# 开始BV号为1zD4y127PB视频属性的抓取
# BV号为1zD4y127PB的视频属性抓取结束
# 开始BV号为1Fh411d7ev视频属性的抓取
# BV号为1Fh411d7ev的视频属性抓取结束
# 开始BV号为1Y54y1U7k8视频属性的抓取
# BV号为1Y54y1U7k8的视频属性抓取结束
# 开始BV号为12V411275T视频属性的抓取
# BV号为12V411275T的视频属性抓取结束
# 开始BV号为1aT4y1j7Lv视频属性的抓取
# BV号为1aT4y1j7Lv的视频属性抓取结束
# 开始BV号为1J54y1U7YR视频属性的抓取
# BV号为1J54y1U7YR的视频属性抓取结束
# 开始BV号为1DZ4y1T7Ko视频属性的抓取
# BV号为1DZ4y1T7Ko的视频属性抓取结束
# 开始BV号为1rp4y1Y7MR视频属性的抓取
# BV号为1rp4y1Y7MR的视频属性抓取结束
# 开始BV号为1iZ4y1M7Mq视频属性的抓取
# BV号为1iZ4y1M7Mq的视频属性抓取结束
# 开始BV号为1a54y127Hx视频属性的抓取
# BV号为1a54y127Hx的视频属性抓取结束
# 开始BV号为1754y127MS视频属性的抓取
# BV号为1754y127MS的视频属性抓取结束
# 开始BV号为1VV411z7cx视频属性的抓取
# BV号为1VV411z7cx的视频属性抓取结束
# 开始BV号为1uZ4y1K7Mu视频属性的抓取
# BV号为1uZ4y1K7Mu的视频属性抓取结束
# 开始BV号为1sk4y1y7zG视频属性的抓取
# BV号为1sk4y1y7zG的视频属性抓取结束
# 开始BV号为1qv41117Qv视频属性的抓取
# BV号为1qv41117Qv的视频属性抓取结束
# 开始BV号为1Pv411i7j5视频属性的抓取
# BV号为1Pv411i7j5的视频属性抓取结束
# 开始BV号为1Rf4y1X7Pi视频属性的抓取
# BV号为1Rf4y1X7Pi的视频属性抓取结束
# 开始BV号为1Kp4y1v71J视频属性的抓取
# BV号为1Kp4y1v71J的视频属性抓取结束
# 开始BV号为1Af4y197pL视频属性的抓取
# BV号为1Af4y197pL的视频属性抓取结束
# 开始BV号为16K4y1Y741视频属性的抓取
# BV号为16K4y1Y741的视频属性抓取结束
# 开始BV号为1uA411n7Q4视频属性的抓取
# BV号为1uA411n7Q4的视频属性抓取结束
# 开始BV号为1e54y1e7Qy视频属性的抓取
# BV号为1e54y1e7Qy的视频属性抓取结束
# 开始BV号为1vD4y1U7k9视频属性的抓取
# BV号为1vD4y1U7k9的视频属性抓取结束
# 开始BV号为1264y1c7zq视频属性的抓取
# BV号为1264y1c7zq的视频属性抓取结束
# 开始BV号为1XT4y157fH视频属性的抓取
# BV号为1XT4y157fH的视频属性抓取结束
# 开始BV号为1m64y1c7ni视频属性的抓取
# BV号为1m64y1c7ni的视频属性抓取结束
# 开始BV号为1r54y1m7fy视频属性的抓取
# BV号为1r54y1m7fy的视频属性抓取结束
# 开始BV号为1GK411n7ce视频属性的抓取
# BV号为1GK411n7ce的视频属性抓取结束
# 开始BV号为1kt4y1D7ci视频属性的抓取
# BV号为1kt4y1D7ci的视频属性抓取结束
# 开始BV号为1Tt4y1Q7jN视频属性的抓取
# BV号为1Tt4y1Q7jN的视频属性抓取结束
# 开始BV号为1vh411d7Sn视频属性的抓取
# BV号为1vh411d7Sn的视频属性抓取结束
# 开始BV号为1o54y1e765视频属性的抓取
# BV号为1o54y1e765的视频属性抓取结束
# 开始BV号为16k4y117su视频属性的抓取
# BV号为16k4y117su的视频属性抓取结束
# 开始BV号为1NK4y1v7bg视频属性的抓取
# BV号为1NK4y1v7bg的视频属性抓取结束
# 开始BV号为1KV411U7wz视频属性的抓取
# BV号为1KV411U7wz的视频属性抓取结束
# 开始BV号为1WC4y187EA视频属性的抓取
# BV号为1WC4y187EA的视频属性抓取结束
# 开始BV号为1Wz4y1Q7Dz视频属性的抓取
# BV号为1Wz4y1Q7Dz的视频属性抓取结束
# 开始BV号为1ft4y1S7o5视频属性的抓取
# BV号为1ft4y1S7o5的视频属性抓取结束
# 开始BV号为1rD4y127s2视频属性的抓取
# BV号为1rD4y127s2的视频属性抓取结束
# 开始BV号为15K411T7K3视频属性的抓取
# BV号为15K411T7K3的视频属性抓取结束
# 开始BV号为1h541187dv视频属性的抓取
# BV号为1h541187dv的视频属性抓取结束
# 开始BV号为1Bp4y1v7T6视频属性的抓取
# BV号为1Bp4y1v7T6的视频属性抓取结束
# 开始BV号为15f4y197zb视频属性的抓取
# BV号为15f4y197zb的视频属性抓取结束
# 开始BV号为1oZ4y1K7eA视频属性的抓取
# BV号为1oZ4y1K7eA的视频属性抓取结束
# 开始BV号为17i4y1M7rB视频属性的抓取
# BV号为17i4y1M7rB的视频属性抓取结束
# 开始BV号为1T54y1U7E8视频属性的抓取
# BV号为1T54y1U7E8的视频属性抓取结束
# 开始BV号为1Kt4y1D7Vt视频属性的抓取
# BV号为1Kt4y1D7Vt的视频属性抓取结束
# 开始BV号为1Bi4y1g7zp视频属性的抓取
# BV号为1Bi4y1g7zp的视频属性抓取结束
# 开始BV号为16z4y1f7dv视频属性的抓取
# BV号为16z4y1f7dv的视频属性抓取结束
# 开始BV号为1r54y1m7yn视频属性的抓取
# BV号为1r54y1m7yn的视频属性抓取结束
# 开始BV号为1bp4y1q7QT视频属性的抓取
# BV号为1bp4y1q7QT的视频属性抓取结束
# 开始BV号为1ut4y1D7Tz视频属性的抓取
# BV号为1ut4y1D7Tz的视频属性抓取结束
# 开始BV号为1zV411U7mz视频属性的抓取
# BV号为1zV411U7mz的视频属性抓取结束
# 开始BV号为1Qt4y1U7Ev视频属性的抓取
# BV号为1Qt4y1U7Ev的视频属性抓取结束
# 开始BV号为1154y1v7Ji视频属性的抓取
# BV号为1154y1v7Ji的视频属性抓取结束
# 开始BV号为1Qf4y197nn视频属性的抓取
# BV号为1Qf4y197nn的视频属性抓取结束
# 开始BV号为1yt4y1i7wU视频属性的抓取
# BV号为1yt4y1i7wU的视频属性抓取结束
# 开始BV号为12a4y1j7bV视频属性的抓取
# BV号为12a4y1j7bV的视频属性抓取结束
# 开始BV号为1kK4y187mv视频属性的抓取
# BV号为1kK4y187mv的视频属性抓取结束
# 开始BV号为1wA411J7ej视频属性的抓取
# BV号为1wA411J7ej的视频属性抓取结束
# 开始BV号为11V41127zW视频属性的抓取
# BV号为11V41127zW的视频属性抓取结束
# 开始BV号为17k4y1C7zV视频属性的抓取
# BV号为17k4y1C7zV的视频属性抓取结束
# 开始BV号为1ry4y1y7wp视频属性的抓取
# BV号为1ry4y1y7wp的视频属性抓取结束
# 开始BV号为17Z4y1N7Jr视频属性的抓取
# BV号为17Z4y1N7Jr的视频属性抓取结束
# 开始BV号为1Hh411X7YJ视频属性的抓取
# BV号为1Hh411X7YJ的视频属性抓取结束
# 开始BV号为1xA411E7tD视频属性的抓取
# BV号为1xA411E7tD的视频属性抓取结束
# 开始BV号为1Ka4y1j7B7视频属性的抓取
# BV号为1Ka4y1j7B7的视频属性抓取结束
# 开始BV号为1aA411J7gD视频属性的抓取
# BV号为1aA411J7gD的视频属性抓取结束
# 开始BV号为1F5411j7ij视频属性的抓取
# BV号为1F5411j7ij的视频属性抓取结束
# 开始BV号为1Qa4y1L7G4视频属性的抓取
# BV号为1Qa4y1L7G4的视频属性抓取结束
# 开始BV号为1Hi4y1E765视频属性的抓取
# BV号为1Hi4y1E765的视频属性抓取结束
# 开始BV号为1KT4y1A7yG视频属性的抓取
# BV号为1KT4y1A7yG的视频属性抓取结束
# 开始BV号为1oD4y1o7oz视频属性的抓取
# BV号为1oD4y1o7oz的视频属性抓取结束
# 开始BV号为1pK4y1a7BJ视频属性的抓取
# BV号为1pK4y1a7BJ的视频属性抓取结束
# 开始BV号为1yv411C7RP视频属性的抓取
# BV号为1yv411C7RP的视频属性抓取结束
# 开始BV号为1MT4y1c7XZ视频属性的抓取
# BV号为1MT4y1c7XZ的视频属性抓取结束
# 开始BV号为1BD4y1o7et视频属性的抓取
# BV号为1BD4y1o7et的视频属性抓取结束
# 开始BV号为1Zp4y1Y7Vb视频属性的抓取
# BV号为1Zp4y1Y7Vb的视频属性抓取结束
# 开始BV号为1ok4y1y7ts视频属性的抓取
# BV号为1ok4y1y7ts的视频属性抓取结束
# 开始BV号为12f4y1D77p视频属性的抓取
# BV号为12f4y1D77p的视频属性抓取结束
# 开始BV号为1UA411E7Li视频属性的抓取
# BV号为1UA411E7Li的视频属性抓取结束
# 开始BV号为15Z4y1N7yX视频属性的抓取
# BV号为15Z4y1N7yX的视频属性抓取结束
# 开始BV号为1sK411N7Ds视频属性的抓取
# BV号为1sK411N7Ds的视频属性抓取结束
# 开始BV号为1nh411X7yR视频属性的抓取
# BV号为1nh411X7yR的视频属性抓取结束
# 开始BV号为1Zi4y177Z8视频属性的抓取
# BV号为1Zi4y177Z8的视频属性抓取结束
# 开始BV号为1py4y1k7BW视频属性的抓取
# BV号为1py4y1k7BW的视频属性抓取结束
# 开始BV号为1av411C77f视频属性的抓取
# BV号为1av411C77f的视频属性抓取结束
# 开始BV号为19z4y1o7S6视频属性的抓取
# BV号为19z4y1o7S6的视频属性抓取结束
# 开始BV号为1Ma4y177ca视频属性的抓取
# BV号为1Ma4y177ca的视频属性抓取结束
# 开始BV号为17D4y1o7nC视频属性的抓取
# BV号为17D4y1o7nC的视频属性抓取结束
# 开始BV号为13a4y1E7q7视频属性的抓取
# BV号为13a4y1E7q7的视频属性抓取结束
# 开始BV号为19k4y1y7uo视频属性的抓取
# BV号为19k4y1y7uo的视频属性抓取结束
# 开始BV号为1rA411J7Me视频属性的抓取
# BV号为1rA411J7Me的视频属性抓取结束
# 开始BV号为1fZ4y1P71z视频属性的抓取
# BV号为1fZ4y1P71z的视频属性抓取结束
# 开始BV号为1QA411E72D视频属性的抓取
# BV号为1QA411E72D的视频属性抓取结束
# 开始BV号为1PD4y1m77a视频属性的抓取
# BV号为1PD4y1m77a的视频属性抓取结束
# 开始BV号为1EK411N7ic视频属性的抓取
# BV号为1EK411N7ic的视频属性抓取结束
# 开始BV号为1gi4y1u7UX视频属性的抓取
# BV号为1gi4y1u7UX的视频属性抓取结束
# 开始BV号为17A411J7Ft视频属性的抓取
# BV号为17A411J7Ft的视频属性抓取结束
# 开始BV号为1Qy4y1y7uG视频属性的抓取
# BV号为1Qy4y1y7uG的视频属性抓取结束
# 开始BV号为1eD4y1o7bE视频属性的抓取
# BV号为1eD4y1o7bE的视频属性抓取结束
# 开始BV号为1uA41177RR视频属性的抓取
# 开始BV号为1uA41177RR视频属性的抓取
# 开始BV号为1uA41177RR视频属性的抓取
# BV号为1uA41177RR的视频属性抓取结束
# 开始BV号为13541187iU视频属性的抓取
# BV号为13541187iU的视频属性抓取结束
# 开始BV号为1g5411j7MQ视频属性的抓取
# BV号为1g5411j7MQ的视频属性抓取结束
# 开始BV号为1kf4y1D7kb视频属性的抓取
# BV号为1kf4y1D7kb的视频属性抓取结束
# 开始BV号为1B54y127Tx视频属性的抓取
# BV号为1B54y127Tx的视频属性抓取结束
# 开始BV号为15y4y1y75F视频属性的抓取
# BV号为15y4y1y75F的视频属性抓取结束
# 开始BV号为1CA411E7t9视频属性的抓取
# BV号为1CA411E7t9的视频属性抓取结束
# 开始BV号为1WD4y1o7UT视频属性的抓取
# BV号为1WD4y1o7UT的视频属性抓取结束
# 开始BV号为19Z4y1P7k8视频属性的抓取
# BV号为19Z4y1P7k8的视频属性抓取结束
# 开始BV号为1gi4y1E7qK视频属性的抓取
# BV号为1gi4y1E7qK的视频属性抓取结束
# 开始BV号为1zy4y1y72W视频属性的抓取
# BV号为1zy4y1y72W的视频属性抓取结束
# 开始BV号为1UT4y1A7i9视频属性的抓取
# BV号为1UT4y1A7i9的视频属性抓取结束
# 开始BV号为1Yp4y1a7Dd视频属性的抓取
# BV号为1Yp4y1a7Dd的视频属性抓取结束
# 开始BV号为1sV41117KD视频属性的抓取
# BV号为1sV41117KD的视频属性抓取结束
# 开始BV号为1hK4y1e7i4视频属性的抓取
# BV号为1hK4y1e7i4的视频属性抓取结束
# 开始BV号为11V41127zd视频属性的抓取
# BV号为11V41127zd的视频属性抓取结束
# 开始BV号为1Ua4y1j7GF视频属性的抓取
# BV号为1Ua4y1j7GF的视频属性抓取结束
# 开始BV号为11t4y1i7i4视频属性的抓取
# BV号为11t4y1i7i4的视频属性抓取结束
# 开始BV号为1Rh411X7ro视频属性的抓取
# BV号为1Rh411X7ro的视频属性抓取结束
# 开始BV号为1MK4y1Y7Qk视频属性的抓取
# BV号为1MK4y1Y7Qk的视频属性抓取结束
# 开始BV号为11p4y1e7HC视频属性的抓取
# BV号为11p4y1e7HC的视频属性抓取结束
# 开始BV号为1nf4y1D71D视频属性的抓取
# BV号为1nf4y1D71D的视频属性抓取结束
# 开始BV号为1Jh411X739视频属性的抓取
# BV号为1Jh411X739的视频属性抓取结束
# 开始BV号为1zK411N7tf视频属性的抓取
# BV号为1zK411N7tf的视频属性抓取结束
# 开始BV号为1Ci4y1M73U视频属性的抓取
# BV号为1Ci4y1M73U的视频属性抓取结束
# 开始BV号为11y4y1y7L7视频属性的抓取
# BV号为11y4y1y7L7的视频属性抓取结束
# 开始BV号为1Di4y1M76o视频属性的抓取
# BV号为1Di4y1M76o的视频属性抓取结束
# 开始BV号为1Hh411X7V5视频属性的抓取
# BV号为1Hh411X7V5的视频属性抓取结束
# 开始BV号为1Tz4y1Z7tP视频属性的抓取
# BV号为1Tz4y1Z7tP的视频属性抓取结束
# 开始BV号为1AV411U7M1视频属性的抓取
# BV号为1AV411U7M1的视频属性抓取结束
# 开始BV号为1Ni4y1u7zy视频属性的抓取
# BV号为1Ni4y1u7zy的视频属性抓取结束
# 开始BV号为1Xa4y1j7bw视频属性的抓取
# BV号为1Xa4y1j7bw的视频属性抓取结束
# 开始BV号为1n64y1F7iN视频属性的抓取
# BV号为1n64y1F7iN的视频属性抓取结束
# 开始BV号为1ep4y1e7nc视频属性的抓取
# BV号为1ep4y1e7nc的视频属性抓取结束
# 开始BV号为1Sk4y1y76V视频属性的抓取
# BV号为1Sk4y1y76V的视频属性抓取结束
# 开始BV号为1nh411R7Jh视频属性的抓取
# BV号为1nh411R7Jh的视频属性抓取结束
# 开始BV号为14h411X7ap视频属性的抓取
# BV号为14h411X7ap的视频属性抓取结束
# 开始BV号为19f4y1S7Jj视频属性的抓取
# BV号为19f4y1S7Jj的视频属性抓取结束
# 开始BV号为1Up4y1Y7ko视频属性的抓取
# BV号为1Up4y1Y7ko的视频属性抓取结束
# 开始BV号为1154y127WS视频属性的抓取
# BV号为1154y127WS的视频属性抓取结束
# 开始BV号为1Zv41117Bi视频属性的抓取
# BV号为1Zv41117Bi的视频属性抓取结束
# 开始BV号为1kD4y1o7ih视频属性的抓取
# BV号为1kD4y1o7ih的视频属性抓取结束
# 开始BV号为1iK411P7zu视频属性的抓取
# BV号为1iK411P7zu的视频属性抓取结束
# 开始BV号为1yi4y177XN视频属性的抓取
# BV号为1yi4y177XN的视频属性抓取结束
# 开始BV号为1rA411n7jE视频属性的抓取
# BV号为1rA411n7jE的视频属性抓取结束
# 开始BV号为1Jv411C7Aq视频属性的抓取
# BV号为1Jv411C7Aq的视频属性抓取结束
# 开始BV号为1R54y127nu视频属性的抓取
# BV号为1R54y127nu的视频属性抓取结束
# 开始BV号为15A411J7n7视频属性的抓取
# BV号为15A411J7n7的视频属性抓取结束
# 开始BV号为14p4y1Y7Tq视频属性的抓取
# BV号为14p4y1Y7Tq的视频属性抓取结束
# 开始BV号为1qT4y1A74B视频属性的抓取
# BV号为1qT4y1A74B的视频属性抓取结束
# 开始BV号为1V64y1F76R视频属性的抓取
# BV号为1V64y1F76R的视频属性抓取结束
# 开始BV号为1SD4y1o7ME视频属性的抓取
# BV号为1SD4y1o7ME的视频属性抓取结束
# 开始BV号为1e5411b7FN视频属性的抓取
# BV号为1e5411b7FN的视频属性抓取结束
# 开始BV号为1rA411J7TJ视频属性的抓取
# BV号为1rA411J7TJ的视频属性抓取结束
# 开始BV号为1JK411K7We视频属性的抓取
# BV号为1JK411K7We的视频属性抓取结束
# 开始BV号为1o54y1677W视频属性的抓取
# BV号为1o54y1677W的视频属性抓取结束
# 开始BV号为1jt4y1v7ic视频属性的抓取
# BV号为1jt4y1v7ic的视频属性抓取结束
# 开始BV号为1fZ4y157u7视频属性的抓取
# BV号为1fZ4y157u7的视频属性抓取结束
# 开始BV号为1gv411k7An视频属性的抓取
# BV号为1gv411k7An的视频属性抓取结束
# 开始BV号为1Ta4y1L7NF视频属性的抓取
# BV号为1Ta4y1L7NF的视频属性抓取结束
# 开始BV号为1B54y1R7Rb视频属性的抓取
# BV号为1B54y1R7Rb的视频属性抓取结束
# 开始BV号为14f4y1B7Ye视频属性的抓取
# BV号为14f4y1B7Ye的视频属性抓取结束
# 开始BV号为16D4y1R7CT视频属性的抓取
# BV号为16D4y1R7CT的视频属性抓取结束
# 开始BV号为1oy4y1k7e4视频属性的抓取
# BV号为1oy4y1k7e4的视频属性抓取结束
# 开始BV号为1tA41177YC视频属性的抓取
# BV号为1tA41177YC的视频属性抓取结束
# 开始BV号为1Ap4y1k7nD视频属性的抓取
# BV号为1Ap4y1k7nD的视频属性抓取结束
# 开始BV号为1a5411L7BJ视频属性的抓取
# BV号为1a5411L7BJ的视频属性抓取结束
# 开始BV号为1cZ4y1V7oB视频属性的抓取
# BV号为1cZ4y1V7oB的视频属性抓取结束
# 开始BV号为1TA411E7Aq视频属性的抓取
# BV号为1TA411E7Aq的视频属性抓取结束
# 开始BV号为1M541177PV视频属性的抓取
# BV号为1M541177PV的视频属性抓取结束
# 开始BV号为13v411k7Zf视频属性的抓取
# BV号为13v411k7Zf的视频属性抓取结束
# 开始BV号为1jK411N7Fu视频属性的抓取
# BV号为1jK411N7Fu的视频属性抓取结束
# 开始BV号为1mt4y1e77p视频属性的抓取
# BV号为1mt4y1e77p的视频属性抓取结束
# 开始BV号为1KZ4y1L7kr视频属性的抓取
# BV号为1KZ4y1L7kr的视频属性抓取结束
# 开始BV号为14v411k7C5视频属性的抓取
# BV号为14v411k7C5的视频属性抓取结束
# 开始BV号为1Ly4y1r7wr视频属性的抓取
# BV号为1Ly4y1r7wr的视频属性抓取结束
# 开始BV号为12r4y1c7iT视频属性的抓取
# BV号为12r4y1c7iT的视频属性抓取结束
# 开始BV号为1PZ4y1V7dU视频属性的抓取
# BV号为1PZ4y1V7dU的视频属性抓取结束
# 开始BV号为13Z4y1L7H5视频属性的抓取
# BV号为13Z4y1L7H5的视频属性抓取结束
# 开始BV号为1dV411177L视频属性的抓取
# BV号为1dV411177L的视频属性抓取结束
# 开始BV号为1sv411y7i7视频属性的抓取
# BV号为1sv411y7i7的视频属性抓取结束
# 开始BV号为13t4y1e7b5视频属性的抓取
# BV号为13t4y1e7b5的视频属性抓取结束
# 开始BV号为1ra4y1L76J视频属性的抓取
# BV号为1ra4y1L76J的视频属性抓取结束
# 开始BV号为115411j7BZ视频属性的抓取
# BV号为115411j7BZ的视频属性抓取结束
# 开始BV号为1AT4y1w7Gx视频属性的抓取
# BV号为1AT4y1w7Gx的视频属性抓取结束
# 开始BV号为1r54y117Nz视频属性的抓取
# BV号为1r54y117Nz的视频属性抓取结束
# 开始BV号为1o54y1k7Tj视频属性的抓取
# BV号为1o54y1k7Tj的视频属性抓取结束
# 开始BV号为13i4y177Kg视频属性的抓取
# BV号为13i4y177Kg的视频属性抓取结束
# 开始BV号为1WZ4y1L7B5视频属性的抓取
# BV号为1WZ4y1L7B5的视频属性抓取结束
# 开始BV号为1ct4y1e7nT视频属性的抓取
# BV号为1ct4y1e7nT的视频属性抓取结束
# 开始BV号为1BD4y1R7k3视频属性的抓取
# BV号为1BD4y1R7k3的视频属性抓取结束
# 开始BV号为1tZ4y1V7Ap视频属性的抓取
# BV号为1tZ4y1V7Ap的视频属性抓取结束
# 开始BV号为1eV411y76S视频属性的抓取
# BV号为1eV411y76S的视频属性抓取结束
# 开始BV号为1PD4y1d7XQ视频属性的抓取
# BV号为1PD4y1d7XQ的视频属性抓取结束
# 开始BV号为1G54y1r7Ld视频属性的抓取
# BV号为1G54y1r7Ld的视频属性抓取结束
# 开始BV号为1qK4y1h7av视频属性的抓取
# BV号为1qK4y1h7av的视频属性抓取结束
# 开始BV号为1vi4y1j76E视频属性的抓取
# BV号为1vi4y1j76E的视频属性抓取结束
# 开始BV号为1ry4y1k7sC视频属性的抓取
# BV号为1ry4y1k7sC的视频属性抓取结束
# 开始BV号为1GA411j7k8视频属性的抓取
# BV号为1GA411j7k8的视频属性抓取结束
# 开始BV号为1M541177zW视频属性的抓取
# BV号为1M541177zW的视频属性抓取结束
# 开始BV号为1i5411j7uu视频属性的抓取
# BV号为1i5411j7uu的视频属性抓取结束
# 开始BV号为1nK4y1h7jK视频属性的抓取
# BV号为1nK4y1h7jK的视频属性抓取结束
# 开始BV号为1PZ4y1L7Wv视频属性的抓取
# BV号为1PZ4y1L7Wv的视频属性抓取结束
# 开始BV号为1wi4y177A5视频属性的抓取
# BV号为1wi4y177A5的视频属性抓取结束
# 开始BV号为12A41177Uj视频属性的抓取
# BV号为12A41177Uj的视频属性抓取结束
# 开始BV号为1tt4y1v7r7视频属性的抓取
# BV号为1tt4y1v7r7的视频属性抓取结束
# 开始BV号为1XK411P7nu视频属性的抓取
# BV号为1XK411P7nu的视频属性抓取结束
# 开始BV号为1cz4y1f7mR视频属性的抓取
# BV号为1cz4y1f7mR的视频属性抓取结束
# 开始BV号为1wf4y1z7o2视频属性的抓取
# BV号为1wf4y1z7o2的视频属性抓取结束
# 开始BV号为1Tp4y1k7j9视频属性的抓取
# BV号为1Tp4y1k7j9的视频属性抓取结束
# 开始BV号为1UA41177S6视频属性的抓取
# BV号为1UA41177S6的视频属性抓取结束
# 开始BV号为1Vk4y1C7dk视频属性的抓取
# BV号为1Vk4y1C7dk的视频属性抓取结束
# 开始BV号为1Ra4y1W7aw视频属性的抓取
# BV号为1Ra4y1W7aw的视频属性抓取结束
# 开始BV号为1y54y117qj视频属性的抓取
# BV号为1y54y117qj的视频属性抓取结束
# 开始BV号为1CA411j73g视频属性的抓取
# BV号为1CA411j73g的视频属性抓取结束
# 开始BV号为1qy4y1C78Q视频属性的抓取
# BV号为1qy4y1C78Q的视频属性抓取结束
# 开始BV号为1gf4y1Q7Aq视频属性的抓取
# BV号为1gf4y1Q7Aq的视频属性抓取结束
# 开始BV号为1ra411w7rM视频属性的抓取
# BV号为1ra411w7rM的视频属性抓取结束
# 开始BV号为1h5411j7v4视频属性的抓取
# BV号为1h5411j7v4的视频属性抓取结束
# 开始BV号为1oT4y1c7t8视频属性的抓取
# BV号为1oT4y1c7t8的视频属性抓取结束
# 开始BV号为1Gy4y1r7Gu视频属性的抓取
# BV号为1Gy4y1r7Gu的视频属性抓取结束
# 开始BV号为1mp4y1a7SP视频属性的抓取
# BV号为1mp4y1a7SP的视频属性抓取结束
# 开始BV号为1C54y1y7A9视频属性的抓取
# BV号为1C54y1y7A9的视频属性抓取结束
# 开始BV号为13541177Um视频属性的抓取
# BV号为13541177Um的视频属性抓取结束
# 开始BV号为1iz4y1o7DJ视频属性的抓取
# BV号为1iz4y1o7DJ的视频属性抓取结束
# 开始BV号为1Lt4y1i7KP视频属性的抓取
# BV号为1Lt4y1i7KP的视频属性抓取结束
# 开始BV号为1tD4y1d7oC视频属性的抓取
# BV号为1tD4y1d7oC的视频属性抓取结束
# 开始BV号为15T4y1w7PQ视频属性的抓取
# BV号为15T4y1w7PQ的视频属性抓取结束
# 开始BV号为1ta411A7uv视频属性的抓取
# BV号为1ta411A7uv的视频属性抓取结束
# 开始BV号为1tT4y1F757视频属性的抓取
# BV号为1tT4y1F757的视频属性抓取结束
# 开始BV号为1yA411J7Q1视频属性的抓取
# BV号为1yA411J7Q1的视频属性抓取结束
# 开始BV号为1o5411j75N视频属性的抓取
# BV号为1o5411j75N的视频属性抓取结束
# 开始BV号为1654y1k77r视频属性的抓取
# BV号为1654y1k77r的视频属性抓取结束
# 开始BV号为17r4y1w7Ao视频属性的抓取
# BV号为17r4y1w7Ao的视频属性抓取结束
# 开始BV号为1mf4y1B7m5视频属性的抓取
# BV号为1mf4y1B7m5的视频属性抓取结束
# 开始BV号为1bt4y1i7s7视频属性的抓取
# BV号为1bt4y1i7s7的视频属性抓取结束
# 开始BV号为1ra411w7k1视频属性的抓取
# BV号为1ra411w7k1的视频属性抓取结束
# 开始BV号为1SK411P73t视频属性的抓取
# BV号为1SK411P73t的视频属性抓取结束
# 开始BV号为1Wa4y1s7WJ视频属性的抓取
# BV号为1Wa4y1s7WJ的视频属性抓取结束
# 开始BV号为1Pt4y1i7pj视频属性的抓取
# BV号为1Pt4y1i7pj的视频属性抓取结束
# 开始BV号为1154y1y7SN视频属性的抓取
# BV号为1154y1y7SN的视频属性抓取结束
# 开始BV号为1av411k7Qd视频属性的抓取
# BV号为1av411k7Qd的视频属性抓取结束
# 开始BV号为1if4y1B7HR视频属性的抓取
# BV号为1if4y1B7HR的视频属性抓取结束
# 开始BV号为1EV41127Gx视频属性的抓取
# BV号为1EV41127Gx的视频属性抓取结束
# 开始BV号为1c54y1C7Fp视频属性的抓取
# BV号为1c54y1C7Fp的视频属性抓取结束
# 开始BV号为1Py4y187Gv视频属性的抓取
# BV号为1Py4y187Gv的视频属性抓取结束
# 开始BV号为1uv411k73h视频属性的抓取
# BV号为1uv411k73h的视频属性抓取结束
# 开始BV号为1KK411P7SX视频属性的抓取
# BV号为1KK411P7SX的视频属性抓取结束
# 开始BV号为1Rp4y1r7i7视频属性的抓取
# BV号为1Rp4y1r7i7的视频属性抓取结束
# 开始BV号为1Ek4y1C7rA视频属性的抓取
# BV号为1Ek4y1C7rA的视频属性抓取结束
# 开始BV号为1MT4y1F7rQ视频属性的抓取
# BV号为1MT4y1F7rQ的视频属性抓取结束
# 开始BV号为1yK4y1h7E8视频属性的抓取
# BV号为1yK4y1h7E8的视频属性抓取结束
# 开始BV号为1ta4y1L7Uh视频属性的抓取
# BV号为1ta4y1L7Uh的视频属性抓取结束
# 开始BV号为15A411E7dY视频属性的抓取
# BV号为15A411E7dY的视频属性抓取结束
# 开始BV号为18k4y1C719视频属性的抓取
# BV号为18k4y1C719的视频属性抓取结束
# 2020-12-22 12:02:12.386963

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-22-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_shenghuo_qita.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 3月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 4月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月   100  100  100  100  100  100   100
# 2月    99   99   99   99   99   99    99
# 3月   100  100  100  100  100  100   100
# 4月    99   99   99   99   99   99    99
# 5月   100  100  100  100  100  100   100
# 6月   100  100  100  100  100  100   100
# 7月   100  100  100  100  100  100   100
# 8月   100  100  100  100  100  100   100
# 9月   100  100  100  100  100  100   100

# %%
channel_shenghuo_qita.to_json('channel_shenghuo_qita')
