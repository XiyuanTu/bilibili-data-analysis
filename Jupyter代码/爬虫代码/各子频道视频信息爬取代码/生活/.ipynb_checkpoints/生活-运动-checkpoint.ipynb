# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_shenghuo_yundong=pd.DataFrame(columns=columns)
channel_shenghuo_yundong
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[9]/div/a/span').click()  #选择“生活”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[9]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '生活'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[7]/a').click()  #选择“运动”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[7]/a').text
sub_channel
# Out:
# '运动'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(1,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_shenghuo_yundong.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-22 13:17:42.499248
# <ipython-input-9-17590af043e4>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-9-17590af043e4>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-9-17590af043e4>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1HJ411L7DP视频属性的抓取
# BV号为1HJ411L7DP的视频属性抓取结束
# <ipython-input-9-17590af043e4>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1UJ411H7i3视频属性的抓取
# BV号为1UJ411H7i3的视频属性抓取结束
# 开始BV号为1ZJ41157fL视频属性的抓取
# BV号为1ZJ41157fL的视频属性抓取结束
# 开始BV号为1sJ411b777视频属性的抓取
# BV号为1sJ411b777的视频属性抓取结束
# 开始BV号为147411z7Dr视频属性的抓取
# BV号为147411z7Dr的视频属性抓取结束
# 开始BV号为1tJ41157i9视频属性的抓取
# BV号为1tJ41157i9的视频属性抓取结束
# 开始BV号为13J411H7c7视频属性的抓取
# BV号为13J411H7c7的视频属性抓取结束
# 开始BV号为1F7411v7W7视频属性的抓取
# BV号为1F7411v7W7的视频属性抓取结束
# 开始BV号为1jJ411J7pa视频属性的抓取
# BV号为1jJ411J7pa的视频属性抓取结束
# 开始BV号为1bJ411J7mP视频属性的抓取
# BV号为1bJ411J7mP的视频属性抓取结束
# 开始BV号为1DJ411V7hb视频属性的抓取
# BV号为1DJ411V7hb的视频属性抓取结束
# 开始BV号为1LJ411G7Gw视频属性的抓取
# BV号为1LJ411G7Gw的视频属性抓取结束
# 开始BV号为1d741167dQ视频属性的抓取
# BV号为1d741167dQ的视频属性抓取结束
# 开始BV号为1e741167qH视频属性的抓取
# BV号为1e741167qH的视频属性抓取结束
# 开始BV号为1AJ411L7Br视频属性的抓取
# BV号为1AJ411L7Br的视频属性抓取结束
# 开始BV号为1h741167mP视频属性的抓取
# BV号为1h741167mP的视频属性抓取结束
# 开始BV号为1QJ411L7qs视频属性的抓取
# BV号为1QJ411L7qs的视频属性抓取结束
# 开始BV号为1BJ411b7W9视频属性的抓取
# BV号为1BJ411b7W9的视频属性抓取结束
# 开始BV号为1EJ411L7GY视频属性的抓取
# BV号为1EJ411L7GY的视频属性抓取结束
# 开始BV号为1uJ411H7es视频属性的抓取
# BV号为1uJ411H7es的视频属性抓取结束
# 开始BV号为157411Y7jV视频属性的抓取
# BV号为157411Y7jV的视频属性抓取结束
# 开始BV号为167411q7Lp视频属性的抓取
# BV号为167411q7Lp的视频属性抓取结束
# 开始BV号为1RJ41157tN视频属性的抓取
# BV号为1RJ41157tN的视频属性抓取结束
# 开始BV号为1z7411a7h8视频属性的抓取
# BV号为1z7411a7h8的视频属性抓取结束
# 开始BV号为157411z7YP视频属性的抓取
# BV号为157411z7YP的视频属性抓取结束
# 开始BV号为1a741167TE视频属性的抓取
# BV号为1a741167TE的视频属性抓取结束
# 开始BV号为1n741167wb视频属性的抓取
# 开始BV号为1n741167wb视频属性的抓取
# BV号为1n741167wb的视频属性抓取结束
# 开始BV号为1j7411r7yj视频属性的抓取
# BV号为1j7411r7yj的视频属性抓取结束
# 开始BV号为1c7411C7Lq视频属性的抓取
# BV号为1c7411C7Lq的视频属性抓取结束
# 开始BV号为1B7411r7ZD视频属性的抓取
# BV号为1B7411r7ZD的视频属性抓取结束
# 开始BV号为1AJ411E78J视频属性的抓取
# BV号为1AJ411E78J的视频属性抓取结束
# 开始BV号为1h741167So视频属性的抓取
# BV号为1h741167So的视频属性抓取结束
# 开始BV号为1AJ411L7Cn视频属性的抓取
# BV号为1AJ411L7Cn的视频属性抓取结束
# 开始BV号为1r7411673K视频属性的抓取
# BV号为1r7411673K的视频属性抓取结束
# 开始BV号为1VJ41187sk视频属性的抓取
# BV号为1VJ41187sk的视频属性抓取结束
# 开始BV号为1FJ411579w视频属性的抓取
# BV号为1FJ411579w的视频属性抓取结束
# 开始BV号为1JJ41177FJ视频属性的抓取
# BV号为1JJ41177FJ的视频属性抓取结束
# 开始BV号为1o7411z7Dc视频属性的抓取
# BV号为1o7411z7Dc的视频属性抓取结束
# 开始BV号为187411v7d3视频属性的抓取
# BV号为187411v7d3的视频属性抓取结束
# 开始BV号为12J411J72K视频属性的抓取
# BV号为12J411J72K的视频属性抓取结束
# 开始BV号为167411v7e9视频属性的抓取
# 开始BV号为167411v7e9视频属性的抓取
# BV号为167411v7e9的视频属性抓取结束
# 开始BV号为177411q7ct视频属性的抓取
# BV号为177411q7ct的视频属性抓取结束
# 开始BV号为1R7411a7UA视频属性的抓取
# BV号为1R7411a7UA的视频属性抓取结束
# 开始BV号为1Y7411674j视频属性的抓取
# BV号为1Y7411674j的视频属性抓取结束
# 开始BV号为1C7411a7yy视频属性的抓取
# BV号为1C7411a7yy的视频属性抓取结束
# 开始BV号为16J41177Ld视频属性的抓取
# BV号为16J41177Ld的视频属性抓取结束
# 开始BV号为1HJ411H7oa视频属性的抓取
# BV号为1HJ411H7oa的视频属性抓取结束
# 开始BV号为1nJ411L7fU视频属性的抓取
# BV号为1nJ411L7fU的视频属性抓取结束
# 开始BV号为1v741167Wq视频属性的抓取
# BV号为1v741167Wq的视频属性抓取结束
# 开始BV号为1pJ41177Gr视频属性的抓取
# BV号为1pJ41177Gr的视频属性抓取结束
# 开始BV号为1p741167XT视频属性的抓取
# BV号为1p741167XT的视频属性抓取结束
# 开始BV号为1aJ41177Zv视频属性的抓取
# BV号为1aJ41177Zv的视频属性抓取结束
# 开始BV号为1z7411k7ef视频属性的抓取
# BV号为1z7411k7ef的视频属性抓取结束
# 开始BV号为1D7411v7vQ视频属性的抓取
# BV号为1D7411v7vQ的视频属性抓取结束
# 开始BV号为1PJ411n72c视频属性的抓取
# BV号为1PJ411n72c的视频属性抓取结束
# 开始BV号为1J7411k7n1视频属性的抓取
# BV号为1J7411k7n1的视频属性抓取结束
# 开始BV号为1z7411a7UH视频属性的抓取
# BV号为1z7411a7UH的视频属性抓取结束
# 开始BV号为1dJ41177Fk视频属性的抓取
# BV号为1dJ41177Fk的视频属性抓取结束
# 开始BV号为1GJ41177Dp视频属性的抓取
# BV号为1GJ41177Dp的视频属性抓取结束
# 开始BV号为1s7411v7Tf视频属性的抓取
# BV号为1s7411v7Tf的视频属性抓取结束
# 开始BV号为1d7411z7fS视频属性的抓取
# BV号为1d7411z7fS的视频属性抓取结束
# 开始BV号为1j741167sz视频属性的抓取
# BV号为1j741167sz的视频属性抓取结束
# 开始BV号为1UJ41177Vp视频属性的抓取
# BV号为1UJ41177Vp的视频属性抓取结束
# 开始BV号为1jJ411G7fc视频属性的抓取
# BV号为1jJ411G7fc的视频属性抓取结束
# 开始BV号为1mJ411V7Li视频属性的抓取
# BV号为1mJ411V7Li的视频属性抓取结束
# 开始BV号为1dJ41157vo视频属性的抓取
# BV号为1dJ41157vo的视频属性抓取结束
# 开始BV号为1RJ41157Jz视频属性的抓取
# BV号为1RJ41157Jz的视频属性抓取结束
# 开始BV号为1wJ411L7dP视频属性的抓取
# BV号为1wJ411L7dP的视频属性抓取结束
# 开始BV号为12J411p7YG视频属性的抓取
# BV号为12J411p7YG的视频属性抓取结束
# 开始BV号为1nJ411n7Ai视频属性的抓取
# BV号为1nJ411n7Ai的视频属性抓取结束
# 开始BV号为1o741167np视频属性的抓取
# BV号为1o741167np的视频属性抓取结束
# 开始BV号为1f7411a7fz视频属性的抓取
# BV号为1f7411a7fz的视频属性抓取结束
# 开始BV号为1sJ411H7Mn视频属性的抓取
# BV号为1sJ411H7Mn的视频属性抓取结束
# 开始BV号为1RJ411E72j视频属性的抓取
# BV号为1RJ411E72j的视频属性抓取结束
# 开始BV号为1b7411B7rr视频属性的抓取
# BV号为1b7411B7rr的视频属性抓取结束
# 开始BV号为1v741167SA视频属性的抓取
# BV号为1v741167SA的视频属性抓取结束
# 开始BV号为127411k7MW视频属性的抓取
# BV号为127411k7MW的视频属性抓取结束
# 开始BV号为1BJ411V7cr视频属性的抓取
# BV号为1BJ411V7cr的视频属性抓取结束
# 开始BV号为1TJ411L7JP视频属性的抓取
# BV号为1TJ411L7JP的视频属性抓取结束
# 开始BV号为1d7411r7r7视频属性的抓取
# BV号为1d7411r7r7的视频属性抓取结束
# 开始BV号为1mJ411E7tg视频属性的抓取
# BV号为1mJ411E7tg的视频属性抓取结束
# 开始BV号为1jJ411p7py视频属性的抓取
# BV号为1jJ411p7py的视频属性抓取结束
# 开始BV号为1m741167xh视频属性的抓取
# BV号为1m741167xh的视频属性抓取结束
# 开始BV号为1aJ411E7zs视频属性的抓取
# BV号为1aJ411E7zs的视频属性抓取结束
# 开始BV号为1HJ411p7Bp视频属性的抓取
# BV号为1HJ411p7Bp的视频属性抓取结束
# 开始BV号为13J411L7Kg视频属性的抓取
# BV号为13J411L7Kg的视频属性抓取结束
# 开始BV号为1L7411r7Ge视频属性的抓取
# BV号为1L7411r7Ge的视频属性抓取结束
# 开始BV号为1M7411q7uG视频属性的抓取
# BV号为1M7411q7uG的视频属性抓取结束
# 开始BV号为1rJ411b7fj视频属性的抓取
# BV号为1rJ411b7fj的视频属性抓取结束
# 开始BV号为1BJ411G72m视频属性的抓取
# BV号为1BJ411G72m的视频属性抓取结束
# 开始BV号为1C741167YB视频属性的抓取
# BV号为1C741167YB的视频属性抓取结束
# 开始BV号为117411Y747视频属性的抓取
# BV号为117411Y747的视频属性抓取结束
# 开始BV号为1a741167NZ视频属性的抓取
# BV号为1a741167NZ的视频属性抓取结束
# 开始BV号为1y7411q7nx视频属性的抓取
# BV号为1y7411q7nx的视频属性抓取结束
# 开始BV号为1N7411r7Uv视频属性的抓取
# BV号为1N7411r7Uv的视频属性抓取结束
# 开始BV号为1t7411v7Zu视频属性的抓取
# BV号为1t7411v7Zu的视频属性抓取结束
# 开始BV号为1c7411C75F视频属性的抓取
# BV号为1c7411C75F的视频属性抓取结束
# 开始BV号为1KJ411p7pS视频属性的抓取
# BV号为1KJ411p7pS的视频属性抓取结束
# 开始BV号为1P7411C7b2视频属性的抓取
# BV号为1P7411C7b2的视频属性抓取结束
# 开始BV号为1Z7411i7j7视频属性的抓取
# BV号为1Z7411i7j7的视频属性抓取结束
# 开始BV号为137411K7my视频属性的抓取
# BV号为137411K7my的视频属性抓取结束
# 开始BV号为1QE411n7w2视频属性的抓取
# BV号为1QE411n7w2的视频属性抓取结束
# 开始BV号为1a741187P2视频属性的抓取
# BV号为1a741187P2的视频属性抓取结束
# 开始BV号为1i7411K7HT视频属性的抓取
# BV号为1i7411K7HT的视频属性抓取结束
# 开始BV号为177411s7fq视频属性的抓取
# BV号为177411s7fq的视频属性抓取结束
# 开始BV号为1T7411P7G4视频属性的抓取
# BV号为1T7411P7G4的视频属性抓取结束
# 开始BV号为1X7411b7aN视频属性的抓取
# BV号为1X7411b7aN的视频属性抓取结束
# 开始BV号为167411u7ZZ视频属性的抓取
# BV号为167411u7ZZ的视频属性抓取结束
# 开始BV号为1Gj411f7QP视频属性的抓取
# BV号为1Gj411f7QP的视频属性抓取结束
# 开始BV号为1Y7411W7Ky视频属性的抓取
# BV号为1Y7411W7Ky的视频属性抓取结束
# 开始BV号为1J7411h7W9视频属性的抓取
# BV号为1J7411h7W9的视频属性抓取结束
# 开始BV号为1a7411V7Ch视频属性的抓取
# BV号为1a7411V7Ch的视频属性抓取结束
# 开始BV号为1C7411773s视频属性的抓取
# BV号为1C7411773s的视频属性抓取结束
# 开始BV号为1W7411t77i视频属性的抓取
# BV号为1W7411t77i的视频属性抓取结束
# 开始BV号为197411j7DD视频属性的抓取
# BV号为197411j7DD的视频属性抓取结束
# 开始BV号为1S7411t7YA视频属性的抓取
# BV号为1S7411t7YA的视频属性抓取结束
# 开始BV号为1j7411V7e7视频属性的抓取
# BV号为1j7411V7e7的视频属性抓取结束
# 开始BV号为1G741177ne视频属性的抓取
# BV号为1G741177ne的视频属性抓取结束
# 开始BV号为1o7411n7zz视频属性的抓取
# BV号为1o7411n7zz的视频属性抓取结束
# 开始BV号为1j7411V7RP视频属性的抓取
# BV号为1j7411V7RP的视频属性抓取结束
# 开始BV号为1Z7411L7w9视频属性的抓取
# BV号为1Z7411L7w9的视频属性抓取结束
# 开始BV号为197411x7hi视频属性的抓取
# BV号为197411x7hi的视频属性抓取结束
# 开始BV号为1A7411T7Qj视频属性的抓取
# BV号为1A7411T7Qj的视频属性抓取结束
# 开始BV号为1x7411M7CF视频属性的抓取
# BV号为1x7411M7CF的视频属性抓取结束
# 开始BV号为1EE411J7Zj视频属性的抓取
# BV号为1EE411J7Zj的视频属性抓取结束
# 开始BV号为1ij411f7MH视频属性的抓取
# BV号为1ij411f7MH的视频属性抓取结束
# 开始BV号为1P7411u7Tg视频属性的抓取
# BV号为1P7411u7Tg的视频属性抓取结束
# 开始BV号为1pE411J7YG视频属性的抓取
# BV号为1pE411J7YG的视频属性抓取结束
# 开始BV号为1u7411j7CA视频属性的抓取
# BV号为1u7411j7CA的视频属性抓取结束
# 开始BV号为1y7411u7vF视频属性的抓取
# BV号为1y7411u7vF的视频属性抓取结束
# 开始BV号为1e7411H7Vb视频属性的抓取
# BV号为1e7411H7Vb的视频属性抓取结束
# 开始BV号为1X7411b75h视频属性的抓取
# BV号为1X7411b75h的视频属性抓取结束
# 开始BV号为1x7411n7zH视频属性的抓取
# BV号为1x7411n7zH的视频属性抓取结束
# 开始BV号为1M741177gM视频属性的抓取
# BV号为1M741177gM的视频属性抓取结束
# 开始BV号为1Y7411H7Po视频属性的抓取
# BV号为1Y7411H7Po的视频属性抓取结束
# 开始BV号为1E741157cu视频属性的抓取
# BV号为1E741157cu的视频属性抓取结束
# 开始BV号为1sj411f7fr视频属性的抓取
# BV号为1sj411f7fr的视频属性抓取结束
# 开始BV号为1f74118781视频属性的抓取
# BV号为1f74118781的视频属性抓取结束
# 开始BV号为1A741177MN视频属性的抓取
# BV号为1A741177MN的视频属性抓取结束
# 开始BV号为1cE411H7Lc视频属性的抓取
# BV号为1cE411H7Lc的视频属性抓取结束
# 开始BV号为1xE411J7wB视频属性的抓取
# BV号为1xE411J7wB的视频属性抓取结束
# 开始BV号为1N7411p75C视频属性的抓取
# BV号为1N7411p75C的视频属性抓取结束
# 开始BV号为127411L7gX视频属性的抓取
# BV号为127411L7gX的视频属性抓取结束
# 开始BV号为1p7411p7F7视频属性的抓取
# BV号为1p7411p7F7的视频属性抓取结束
# 开始BV号为1WE411H7yT视频属性的抓取
# BV号为1WE411H7yT的视频属性抓取结束
# 开始BV号为1k7411u76x视频属性的抓取
# BV号为1k7411u76x的视频属性抓取结束
# 开始BV号为1R741147Xz视频属性的抓取
# BV号为1R741147Xz的视频属性抓取结束
# 开始BV号为1U7411M7cv视频属性的抓取
# BV号为1U7411M7cv的视频属性抓取结束
# 开始BV号为1J7411H7pR视频属性的抓取
# BV号为1J7411H7pR的视频属性抓取结束
# 开始BV号为167411x7Un视频属性的抓取
# BV号为167411x7Un的视频属性抓取结束
# 开始BV号为1R7411K7SJ视频属性的抓取
# BV号为1R7411K7SJ的视频属性抓取结束
# 开始BV号为1N7411p7mF视频属性的抓取
# BV号为1N7411p7mF的视频属性抓取结束
# 开始BV号为127411H7Kv视频属性的抓取
# BV号为127411H7Kv的视频属性抓取结束
# 开始BV号为1n7411P71p视频属性的抓取
# BV号为1n7411P71p的视频属性抓取结束
# 开始BV号为1Y7411378P视频属性的抓取
# BV号为1Y7411378P的视频属性抓取结束
# 开始BV号为1f7411j7vf视频属性的抓取
# BV号为1f7411j7vf的视频属性抓取结束
# 开始BV号为167411F7wE视频属性的抓取
# BV号为167411F7wE的视频属性抓取结束
# 开始BV号为1Y7411b7kd视频属性的抓取
# BV号为1Y7411b7kd的视频属性抓取结束
# 开始BV号为1p7411x7RP视频属性的抓取
# BV号为1p7411x7RP的视频属性抓取结束
# 开始BV号为1E7411s7TY视频属性的抓取
# BV号为1E7411s7TY的视频属性抓取结束
# 开始BV号为1M7411P7Rv视频属性的抓取
# BV号为1M7411P7Rv的视频属性抓取结束
# 开始BV号为1L7411T7WJ视频属性的抓取
# BV号为1L7411T7WJ的视频属性抓取结束
# 开始BV号为1G7411c7yd视频属性的抓取
# BV号为1G7411c7yd的视频属性抓取结束
# 开始BV号为1D7411K7bk视频属性的抓取
# BV号为1D7411K7bk的视频属性抓取结束
# 开始BV号为1p7411F7Zj视频属性的抓取
# BV号为1p7411F7Zj的视频属性抓取结束
# 开始BV号为1T7411s7L9视频属性的抓取
# BV号为1T7411s7L9的视频属性抓取结束
# 开始BV号为1HE411H7F2视频属性的抓取
# BV号为1HE411H7F2的视频属性抓取结束
# 开始BV号为1G7411V7Xt视频属性的抓取
# BV号为1G7411V7Xt的视频属性抓取结束
# 开始BV号为1j7411F7WM视频属性的抓取
# BV号为1j7411F7WM的视频属性抓取结束
# 开始BV号为15E411H7WE视频属性的抓取
# BV号为15E411H7WE的视频属性抓取结束
# 开始BV号为167411P7ME视频属性的抓取
# BV号为167411P7ME的视频属性抓取结束
# 开始BV号为167411b7AB视频属性的抓取
# BV号为167411b7AB的视频属性抓取结束
# 开始BV号为17E411H7Ha视频属性的抓取
# BV号为17E411H7Ha的视频属性抓取结束
# 开始BV号为1Y7411h74L视频属性的抓取
# BV号为1Y7411h74L的视频属性抓取结束
# 开始BV号为197411T7VU视频属性的抓取
# BV号为197411T7VU的视频属性抓取结束
# 开始BV号为177411E7QY视频属性的抓取
# BV号为177411E7QY的视频属性抓取结束
# 开始BV号为187411b7LU视频属性的抓取
# BV号为187411b7LU的视频属性抓取结束
# 开始BV号为1Y7411G7fZ视频属性的抓取
# BV号为1Y7411G7fZ的视频属性抓取结束
# 开始BV号为1e7411p7tH视频属性的抓取
# BV号为1e7411p7tH的视频属性抓取结束
# 开始BV号为1j7411u7LS视频属性的抓取
# BV号为1j7411u7LS的视频属性抓取结束
# 开始BV号为167411W7pJ视频属性的抓取
# BV号为167411W7pJ的视频属性抓取结束
# 开始BV号为1Y7411H7gB视频属性的抓取
# BV号为1Y7411H7gB的视频属性抓取结束
# 开始BV号为137411N771视频属性的抓取
# BV号为137411N771的视频属性抓取结束
# 开始BV号为1z7411L7Kq视频属性的抓取
# BV号为1z7411L7Kq的视频属性抓取结束
# 开始BV号为1A7411K7ew视频属性的抓取
# BV号为1A7411K7ew的视频属性抓取结束
# 开始BV号为1G7411V7uu视频属性的抓取
# BV号为1G7411V7uu的视频属性抓取结束
# 开始BV号为1a7411b74Z视频属性的抓取
# BV号为1a7411b74Z的视频属性抓取结束
# 开始BV号为1f7411V7jx视频属性的抓取
# BV号为1f7411V7jx的视频属性抓取结束
# 开始BV号为1i7411c7Wi视频属性的抓取
# BV号为1i7411c7Wi的视频属性抓取结束
# 开始BV号为1p7411N7WG视频属性的抓取
# BV号为1p7411N7WG的视频属性抓取结束
# 开始BV号为1r7411h7Cs视频属性的抓取
# BV号为1r7411h7Cs的视频属性抓取结束
# 开始BV号为1h7411p7qL视频属性的抓取
# BV号为1h7411p7qL的视频属性抓取结束
# 开始BV号为1y74117747视频属性的抓取
# BV号为1y74117747的视频属性抓取结束
# 开始BV号为1Z7411g7s3视频属性的抓取
# BV号为1Z7411g7s3的视频属性抓取结束
# 开始BV号为1N741147kJ视频属性的抓取
# BV号为1N741147kJ的视频属性抓取结束
# 开始BV号为1hE411J7ve视频属性的抓取
# BV号为1hE411J7ve的视频属性抓取结束
# 开始BV号为1N7411P7Su视频属性的抓取
# BV号为1N7411P7Su的视频属性抓取结束
# 开始BV号为1j7411t7Xd视频属性的抓取
# BV号为1j7411t7Xd的视频属性抓取结束
# 开始BV号为1v7411V7ka视频属性的抓取
# BV号为1v7411V7ka的视频属性抓取结束
# 开始BV号为1L7411M7Mi视频属性的抓取
# BV号为1L7411M7Mi的视频属性抓取结束
# 开始BV号为1At4y1U7Jc视频属性的抓取
# BV号为1At4y1U7Jc的视频属性抓取结束
# 开始BV号为1PE411j7sY视频属性的抓取
# BV号为1PE411j7sY的视频属性抓取结束
# 开始BV号为1GE411W7Df视频属性的抓取
# BV号为1GE411W7Df的视频属性抓取结束
# 开始BV号为1DE411x7yP视频属性的抓取
# BV号为1DE411x7yP的视频属性抓取结束
# 开始BV号为15E411M7BZ视频属性的抓取
# BV号为15E411M7BZ的视频属性抓取结束
# 开始BV号为1LE411j7Mo视频属性的抓取
# BV号为1LE411j7Mo的视频属性抓取结束
# 开始BV号为1oE411J7PB视频属性的抓取
# BV号为1oE411J7PB的视频属性抓取结束
# 开始BV号为15E411n75E视频属性的抓取
# BV号为15E411n75E的视频属性抓取结束
# 开始BV号为17A411h7qn视频属性的抓取
# BV号为17A411h7qn的视频属性抓取结束
# 开始BV号为1a7411d72H视频属性的抓取
# BV号为1a7411d72H的视频属性抓取结束
# 开始BV号为1qE411476X视频属性的抓取
# BV号为1qE411476X的视频属性抓取结束
# 开始BV号为1e7411y7m2视频属性的抓取
# BV号为1e7411y7m2的视频属性抓取结束
# 开始BV号为1v7411f7h7视频属性的抓取
# BV号为1v7411f7h7的视频属性抓取结束
# 开始BV号为1f541167a9视频属性的抓取
# BV号为1f541167a9的视频属性抓取结束
# 开始BV号为1EE4115741视频属性的抓取
# BV号为1EE4115741的视频属性抓取结束
# 开始BV号为1VE411T7AB视频属性的抓取
# BV号为1VE411T7AB的视频属性抓取结束
# 开始BV号为16E411u7Je视频属性的抓取
# BV号为16E411u7Je的视频属性抓取结束
# 开始BV号为1i7411o72n视频属性的抓取
# BV号为1i7411o72n的视频属性抓取结束
# 开始BV号为19E411K7MA视频属性的抓取
# BV号为19E411K7MA的视频属性抓取结束
# 开始BV号为1pE411g7Md视频属性的抓取
# BV号为1pE411g7Md的视频属性抓取结束
# 开始BV号为1L7411R7J6视频属性的抓取
# BV号为1L7411R7J6的视频属性抓取结束
# 开始BV号为1Wc411h7nr视频属性的抓取
# BV号为1Wc411h7nr的视频属性抓取结束
# 开始BV号为17C4y14735视频属性的抓取
# BV号为17C4y14735的视频属性抓取结束
# 开始BV号为1BE411x7v2视频属性的抓取
# BV号为1BE411x7v2的视频属性抓取结束
# 开始BV号为1TE411T7Fb视频属性的抓取
# BV号为1TE411T7Fb的视频属性抓取结束
# 开始BV号为1BE411M7jR视频属性的抓取
# BV号为1BE411M7jR的视频属性抓取结束
# 开始BV号为11E41147e2视频属性的抓取
# BV号为11E41147e2的视频属性抓取结束
# 开始BV号为1t7411U79g视频属性的抓取
# BV号为1t7411U79g的视频属性抓取结束
# 开始BV号为1gE411g77e视频属性的抓取
# BV号为1gE411g77e的视频属性抓取结束
# 开始BV号为1UE411H7BS视频属性的抓取
# 开始BV号为1UE411H7BS视频属性的抓取
# BV号为1UE411H7BS的视频属性抓取结束
# 开始BV号为1FE411n7tr视频属性的抓取
# BV号为1FE411n7tr的视频属性抓取结束
# 开始BV号为1VK411L7KV视频属性的抓取
# BV号为1VK411L7KV的视频属性抓取结束
# 开始BV号为1gE411V7Vw视频属性的抓取
# BV号为1gE411V7Vw的视频属性抓取结束
# 开始BV号为1iE411c7Ni视频属性的抓取
# BV号为1iE411c7Ni的视频属性抓取结束
# 开始BV号为1ME411V7xG视频属性的抓取
# BV号为1ME411V7xG的视频属性抓取结束
# 开始BV号为1rE411w7xD视频属性的抓取
# BV号为1rE411w7xD的视频属性抓取结束
# 开始BV号为11741127n4视频属性的抓取
# BV号为11741127n4的视频属性抓取结束
# 开始BV号为1tE411A7XG视频属性的抓取
# BV号为1tE411A7XG的视频属性抓取结束
# 开始BV号为1JE41177Xz视频属性的抓取
# BV号为1JE41177Xz的视频属性抓取结束
# 开始BV号为1XE411L7kZ视频属性的抓取
# BV号为1XE411L7kZ的视频属性抓取结束
# 开始BV号为1pE411A7XR视频属性的抓取
# BV号为1pE411A7XR的视频属性抓取结束
# 开始BV号为15E411W7eg视频属性的抓取
# BV号为15E411W7eg的视频属性抓取结束
# 开始BV号为1g741127RF视频属性的抓取
# BV号为1g741127RF的视频属性抓取结束
# 开始BV号为1nE411j7aP视频属性的抓取
# BV号为1nE411j7aP的视频属性抓取结束
# 开始BV号为1kE411T7Zj视频属性的抓取
# BV号为1kE411T7Zj的视频属性抓取结束
# 开始BV号为1ZE411M7r1视频属性的抓取
# BV号为1ZE411M7r1的视频属性抓取结束
# 开始BV号为1QE411x7ZW视频属性的抓取
# BV号为1QE411x7ZW的视频属性抓取结束
# 开始BV号为1EE411A7Te视频属性的抓取
# BV号为1EE411A7Te的视频属性抓取结束
# 开始BV号为1xE411c76Z视频属性的抓取
# BV号为1xE411c76Z的视频属性抓取结束
# 开始BV号为1hE411L7Na视频属性的抓取
# BV号为1hE411L7Na的视频属性抓取结束
# 开始BV号为1UE411773a视频属性的抓取
# BV号为1UE411773a的视频属性抓取结束
# 开始BV号为1tE411P713视频属性的抓取
# BV号为1tE411P713的视频属性抓取结束
# 开始BV号为13E411x7kQ视频属性的抓取
# BV号为13E411x7kQ的视频属性抓取结束
# 开始BV号为1f741197pp视频属性的抓取
# BV号为1f741197pp的视频属性抓取结束
# 开始BV号为1mE41157Cu视频属性的抓取
# BV号为1mE41157Cu的视频属性抓取结束
# 开始BV号为1C741127Kx视频属性的抓取
# BV号为1C741127Kx的视频属性抓取结束
# 开始BV号为1u7411m7LH视频属性的抓取
# BV号为1u7411m7LH的视频属性抓取结束
# 开始BV号为1L7411U7VK视频属性的抓取
# BV号为1L7411U7VK的视频属性抓取结束
# 开始BV号为1XE411H7tY视频属性的抓取
# BV号为1XE411H7tY的视频属性抓取结束
# 开始BV号为1FE411T7TB视频属性的抓取
# BV号为1FE411T7TB的视频属性抓取结束
# 开始BV号为17E411j7b7视频属性的抓取
# BV号为17E411j7b7的视频属性抓取结束
# 开始BV号为1wE41157o7视频属性的抓取
# BV号为1wE41157o7的视频属性抓取结束
# 开始BV号为1QE411x7zg视频属性的抓取
# BV号为1QE411x7zg的视频属性抓取结束
# 开始BV号为1t7411y7sG视频属性的抓取
# BV号为1t7411y7sG的视频属性抓取结束
# 开始BV号为1TE411P7We视频属性的抓取
# BV号为1TE411P7We的视频属性抓取结束
# 开始BV号为1QE411x74P视频属性的抓取
# BV号为1QE411x74P的视频属性抓取结束
# 开始BV号为147411Z7rw视频属性的抓取
# BV号为147411Z7rw的视频属性抓取结束
# 开始BV号为1gE411N7MC视频属性的抓取
# BV号为1gE411N7MC的视频属性抓取结束
# 开始BV号为1GE411g7KP视频属性的抓取
# BV号为1GE411g7KP的视频属性抓取结束
# 开始BV号为1jE411T7Fz视频属性的抓取
# BV号为1jE411T7Fz的视频属性抓取结束
# 开始BV号为1DE411W7qo视频属性的抓取
# BV号为1DE411W7qo的视频属性抓取结束
# 开始BV号为1dt4y1m7W1视频属性的抓取
# BV号为1dt4y1m7W1的视频属性抓取结束
# 开始BV号为1EE411K7f8视频属性的抓取
# BV号为1EE411K7f8的视频属性抓取结束
# 开始BV号为12E411M7Pt视频属性的抓取
# BV号为12E411M7Pt的视频属性抓取结束
# 开始BV号为18741197zc视频属性的抓取
# BV号为18741197zc的视频属性抓取结束
# 开始BV号为1sE411E7xs视频属性的抓取
# BV号为1sE411E7xs的视频属性抓取结束
# 开始BV号为16E411j74R视频属性的抓取
# BV号为16E411j74R的视频属性抓取结束
# 开始BV号为1ht4y1m7yM视频属性的抓取
# BV号为1ht4y1m7yM的视频属性抓取结束
# 开始BV号为18E4117783视频属性的抓取
# BV号为18E4117783的视频属性抓取结束
# 开始BV号为1qE411M7JT视频属性的抓取
# BV号为1qE411M7JT的视频属性抓取结束
# 开始BV号为1jE411L7k3视频属性的抓取
# BV号为1jE411L7k3的视频属性抓取结束
# 开始BV号为1dg4y1b7rg视频属性的抓取
# BV号为1dg4y1b7rg的视频属性抓取结束
# 开始BV号为167411f7fu视频属性的抓取
# BV号为167411f7fu的视频属性抓取结束
# 开始BV号为1AE411N7Vh视频属性的抓取
# BV号为1AE411N7Vh的视频属性抓取结束
# 开始BV号为1c74119722视频属性的抓取
# BV号为1c74119722的视频属性抓取结束
# 开始BV号为177411d728视频属性的抓取
# BV号为177411d728的视频属性抓取结束
# 开始BV号为1NE41157Ct视频属性的抓取
# BV号为1NE41157Ct的视频属性抓取结束
# 开始BV号为1QE411g7Rz视频属性的抓取
# BV号为1QE411g7Rz的视频属性抓取结束
# 开始BV号为1x7411d78r视频属性的抓取
# BV号为1x7411d78r的视频属性抓取结束
# 开始BV号为1SE411L72q视频属性的抓取
# BV号为1SE411L72q的视频属性抓取结束
# 开始BV号为1d7411y7C3视频属性的抓取
# BV号为1d7411y7C3的视频属性抓取结束
# 开始BV号为1DE411H7rp视频属性的抓取
# BV号为1DE411H7rp的视频属性抓取结束
# <ipython-input-9-17590af043e4>:190: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1wE411E7uf视频属性的抓取
# BV号为1wE411E7uf的视频属性抓取结束
# 开始BV号为1Hz411b7EJ视频属性的抓取
# BV号为1Hz411b7EJ的视频属性抓取结束
# 开始BV号为1oE411L7EB视频属性的抓取
# BV号为1oE411L7EB的视频属性抓取结束
# 开始BV号为1t7411m7J1视频属性的抓取
# BV号为1t7411m7J1的视频属性抓取结束
# 开始BV号为1S541147LY视频属性的抓取
# BV号为1S541147LY的视频属性抓取结束
# 开始BV号为1a7411Z7PZ视频属性的抓取
# BV号为1a7411Z7PZ的视频属性抓取结束
# 开始BV号为1NE41157wD视频属性的抓取
# BV号为1NE41157wD的视频属性抓取结束
# 开始BV号为18z411b7rp视频属性的抓取
# BV号为18z411b7rp的视频属性抓取结束
# 开始BV号为12e411x7Yq视频属性的抓取
# BV号为12e411x7Yq的视频属性抓取结束
# 开始BV号为1jt4y1U7yb视频属性的抓取
# BV号为1jt4y1U7yb的视频属性抓取结束
# 开始BV号为1wi4y1b7Em视频属性的抓取
# BV号为1wi4y1b7Em的视频属性抓取结束
# 开始BV号为16C4y1s7G3视频属性的抓取
# BV号为16C4y1s7G3的视频属性抓取结束
# 开始BV号为1ef4y1U7oD视频属性的抓取
# BV号为1ef4y1U7oD的视频属性抓取结束
# 开始BV号为1LZ4y147MF视频属性的抓取
# BV号为1LZ4y147MF的视频属性抓取结束
# 开始BV号为1qZ4y1W732视频属性的抓取
# BV号为1qZ4y1W732的视频属性抓取结束
# 开始BV号为13Q4y1T7CL视频属性的抓取
# BV号为13Q4y1T7CL的视频属性抓取结束
# 开始BV号为1xA411h7Rf视频属性的抓取
# BV号为1xA411h7Rf的视频属性抓取结束
# 开始BV号为13K411j7gk视频属性的抓取
# BV号为13K411j7gk的视频属性抓取结束
# 开始BV号为1Mt4y1m7MD视频属性的抓取
# BV号为1Mt4y1m7MD的视频属性抓取结束
# 开始BV号为1Fe411s7nD视频属性的抓取
# BV号为1Fe411s7nD的视频属性抓取结束
# 开始BV号为1EK4y1b7oX视频属性的抓取
# BV号为1EK4y1b7oX的视频属性抓取结束
# 开始BV号为185411t7Ux视频属性的抓取
# BV号为185411t7Ux的视频属性抓取结束
# 开始BV号为1tk4y1r7Yr视频属性的抓取
# BV号为1tk4y1r7Yr的视频属性抓取结束
# 开始BV号为1Kk4y1R7oo视频属性的抓取
# BV号为1Kk4y1R7oo的视频属性抓取结束
# 开始BV号为1wg4y1678h视频属性的抓取
# BV号为1wg4y1678h的视频属性抓取结束
# 开始BV号为1f54y1973y视频属性的抓取
# BV号为1f54y1973y的视频属性抓取结束
# 开始BV号为1rC4y1s7MU视频属性的抓取
# BV号为1rC4y1s7MU的视频属性抓取结束
# 开始BV号为15f4y1m7KD视频属性的抓取
# BV号为15f4y1m7KD的视频属性抓取结束
# 开始BV号为1T64y1M7ww视频属性的抓取
# BV号为1T64y1M7ww的视频属性抓取结束
# 开始BV号为1gT4y137Yh视频属性的抓取
# BV号为1gT4y137Yh的视频属性抓取结束
# 开始BV号为17t4y1U7fn视频属性的抓取
# BV号为17t4y1U7fn的视频属性抓取结束
# 开始BV号为1Ja4y1479a视频属性的抓取
# BV号为1Ja4y1479a的视频属性抓取结束
# 开始BV号为1n64y1T7LB视频属性的抓取
# BV号为1n64y1T7LB的视频属性抓取结束
# 开始BV号为1tT4y157gm视频属性的抓取
# BV号为1tT4y157gm的视频属性抓取结束
# 开始BV号为1eT4y1G7oj视频属性的抓取
# BV号为1eT4y1G7oj的视频属性抓取结束
# 开始BV号为1ef4y1U7ar视频属性的抓取
# BV号为1ef4y1U7ar的视频属性抓取结束
# 开始BV号为1BV411o7WW视频属性的抓取
# BV号为1BV411o7WW的视频属性抓取结束
# 开始BV号为1cA41187GV视频属性的抓取
# BV号为1cA41187GV的视频属性抓取结束
# 开始BV号为1854y197bG视频属性的抓取
# BV号为1854y197bG的视频属性抓取结束
# 开始BV号为1Jf4y1S7K6视频属性的抓取
# BV号为1Jf4y1S7K6的视频属性抓取结束
# 开始BV号为1TK41157t8视频属性的抓取
# BV号为1TK41157t8的视频属性抓取结束
# 开始BV号为1jK4y1b71i视频属性的抓取
# BV号为1jK4y1b71i的视频属性抓取结束
# 开始BV号为16Z4y1x7rL视频属性的抓取
# BV号为16Z4y1x7rL的视频属性抓取结束
# 开始BV号为14z411B7FU视频属性的抓取
# BV号为14z411B7FU的视频属性抓取结束
# 开始BV号为11Z4y1W7oi视频属性的抓取
# BV号为11Z4y1W7oi的视频属性抓取结束
# 开始BV号为11T4y1G7x5视频属性的抓取
# BV号为11T4y1G7x5的视频属性抓取结束
# 开始BV号为1Xt4y1273c视频属性的抓取
# BV号为1Xt4y1273c的视频属性抓取结束
# 开始BV号为1YK41157d2视频属性的抓取
# BV号为1YK41157d2的视频属性抓取结束
# 开始BV号为1Ap4y1y7fP视频属性的抓取
# BV号为1Ap4y1y7fP的视频属性抓取结束
# 开始BV号为11g4y187HP视频属性的抓取
# BV号为11g4y187HP的视频属性抓取结束
# 开始BV号为1Ti4y1t7yp视频属性的抓取
# BV号为1Ti4y1t7yp的视频属性抓取结束
# 开始BV号为1of4y1U76Z视频属性的抓取
# BV号为1of4y1U76Z的视频属性抓取结束
# 开始BV号为1Tf4y1S7ZM视频属性的抓取
# BV号为1Tf4y1S7ZM的视频属性抓取结束
# 开始BV号为1aK4y1r7pQ视频属性的抓取
# BV号为1aK4y1r7pQ的视频属性抓取结束
# 开始BV号为1ek4y1R7Aj视频属性的抓取
# BV号为1ek4y1R7Aj的视频属性抓取结束
# 开始BV号为1TA411h7dc视频属性的抓取
# BV号为1TA411h7dc的视频属性抓取结束
# 开始BV号为1di4y1t7Yk视频属性的抓取
# BV号为1di4y1t7Yk的视频属性抓取结束
# 开始BV号为1UK411L7Sx视频属性的抓取
# BV号为1UK411L7Sx的视频属性抓取结束
# 开始BV号为1Hi4y1t7Kj视频属性的抓取
# BV号为1Hi4y1t7Kj的视频属性抓取结束
# 开始BV号为1Hp4y1y7Cm视频属性的抓取
# BV号为1Hp4y1y7Cm的视频属性抓取结束
# 开始BV号为1qk4y197Ff视频属性的抓取
# BV号为1qk4y197Ff的视频属性抓取结束
# 开始BV号为1MV411Z7m4视频属性的抓取
# BV号为1MV411Z7m4的视频属性抓取结束
# 开始BV号为1D54y1Q7Hp视频属性的抓取
# BV号为1D54y1Q7Hp的视频属性抓取结束
# 开始BV号为1AV411d7Pw视频属性的抓取
# BV号为1AV411d7Pw的视频属性抓取结束
# 开始BV号为1EV411d7G4视频属性的抓取
# BV号为1EV411d7G4的视频属性抓取结束
# 开始BV号为1EV411d79t视频属性的抓取
# BV号为1EV411d79t的视频属性抓取结束
# 开始BV号为1LK4y1k7Gt视频属性的抓取
# BV号为1LK4y1k7Gt的视频属性抓取结束
# 开始BV号为1ge411s729视频属性的抓取
# BV号为1ge411s729的视频属性抓取结束
# 开始BV号为1oa4y1x7jZ视频属性的抓取
# BV号为1oa4y1x7jZ的视频属性抓取结束
# 开始BV号为1oi4y1b7PW视频属性的抓取
# BV号为1oi4y1b7PW的视频属性抓取结束
# 开始BV号为1ua4y14786视频属性的抓取
# BV号为1ua4y14786的视频属性抓取结束
# 开始BV号为1wZ4y1s7Nn视频属性的抓取
# BV号为1wZ4y1s7Nn的视频属性抓取结束
# 开始BV号为1We411x7v7视频属性的抓取
# BV号为1We411x7v7的视频属性抓取结束
# 开始BV号为1Sk4y1d7qL视频属性的抓取
# BV号为1Sk4y1d7qL的视频属性抓取结束
# 开始BV号为1F64y1u7bS视频属性的抓取
# BV号为1F64y1u7bS的视频属性抓取结束
# 开始BV号为19g4y1z7sz视频属性的抓取
# BV号为19g4y1z7sz的视频属性抓取结束
# 开始BV号为1JK411j73W视频属性的抓取
# BV号为1JK411j73W的视频属性抓取结束
# 开始BV号为1HK4y1b77Q视频属性的抓取
# BV号为1HK4y1b77Q的视频属性抓取结束
# 开始BV号为1Y54y1d7ax视频属性的抓取
# BV号为1Y54y1d7ax的视频属性抓取结束
# 开始BV号为1oz411b7sp视频属性的抓取
# BV号为1oz411b7sp的视频属性抓取结束
# 开始BV号为1tV411f7RE视频属性的抓取
# BV号为1tV411f7RE的视频属性抓取结束
# 开始BV号为1he411s74b视频属性的抓取
# BV号为1he411s74b的视频属性抓取结束
# 开始BV号为1Ne411474G视频属性的抓取
# BV号为1Ne411474G的视频属性抓取结束
# 开始BV号为1xA411b7yZ视频属性的抓取
# BV号为1xA411b7yZ的视频属性抓取结束
# 开始BV号为19K4y1C725视频属性的抓取
# BV号为19K4y1C725的视频属性抓取结束
# 开始BV号为1R5411t7Rs视频属性的抓取
# BV号为1R5411t7Rs的视频属性抓取结束
# 开始BV号为1bt4y127xX视频属性的抓取
# BV号为1bt4y127xX的视频属性抓取结束
# 开始BV号为1DC4y1s7ak视频属性的抓取
# BV号为1DC4y1s7ak的视频属性抓取结束
# 开始BV号为1Ya4y1x7jx视频属性的抓取
# BV号为1Ya4y1x7jx的视频属性抓取结束
# 开始BV号为13z41187fm视频属性的抓取
# BV号为13z41187fm的视频属性抓取结束
# 开始BV号为1AK411j7HQ视频属性的抓取
# BV号为1AK411j7HQ的视频属性抓取结束
# 开始BV号为1QC4y1s7xM视频属性的抓取
# BV号为1QC4y1s7xM的视频属性抓取结束
# 开始BV号为1Ua4y1x7mV视频属性的抓取
# BV号为1Ua4y1x7mV的视频属性抓取结束
# 开始BV号为1Zi4y1b7Sb视频属性的抓取
# BV号为1Zi4y1b7Sb的视频属性抓取结束
# 开始BV号为1RQ4y1P7cT视频属性的抓取
# BV号为1RQ4y1P7cT的视频属性抓取结束
# 开始BV号为15Q4y1T7uV视频属性的抓取
# BV号为15Q4y1T7uV的视频属性抓取结束
# 开始BV号为1ic411h79X视频属性的抓取
# BV号为1ic411h79X的视频属性抓取结束
# 开始BV号为1xf4y1S7kK视频属性的抓取
# BV号为1xf4y1S7kK的视频属性抓取结束
# 开始BV号为1WQ4y1K7UH视频属性的抓取
# BV号为1WQ4y1K7UH的视频属性抓取结束
# 开始BV号为1iA41147Lv视频属性的抓取
# BV号为1iA41147Lv的视频属性抓取结束
# 开始BV号为16z411b7PA视频属性的抓取
# BV号为16z411b7PA的视频属性抓取结束
# 开始BV号为1Ma4y147HV视频属性的抓取
# BV号为1Ma4y147HV的视频属性抓取结束
# 开始BV号为1ZQ4y1P7qL视频属性的抓取
# BV号为1ZQ4y1P7qL的视频属性抓取结束
# 开始BV号为1bk4y1R7YE视频属性的抓取
# BV号为1bk4y1R7YE的视频属性抓取结束
# 开始BV号为1Le411s7kt视频属性的抓取
# BV号为1Le411s7kt的视频属性抓取结束
# 开始BV号为19g4y1z7L7视频属性的抓取
# BV号为19g4y1z7L7的视频属性抓取结束
# 开始BV号为1y64y1T7MG视频属性的抓取
# BV号为1y64y1T7MG的视频属性抓取结束
# 开始BV号为12T4y137qC视频属性的抓取
# BV号为12T4y137qC的视频属性抓取结束
# 开始BV号为1NK411s7UL视频属性的抓取
# BV号为1NK411s7UL的视频属性抓取结束
# 开始BV号为1gZ4y1s7YF视频属性的抓取
# BV号为1gZ4y1s7YF的视频属性抓取结束
# 开始BV号为1cK4y1t7cw视频属性的抓取
# BV号为1cK4y1t7cw的视频属性抓取结束
# 开始BV号为1GK411s7uA视频属性的抓取
# BV号为1GK411s7uA的视频属性抓取结束
# 开始BV号为1ht4y117rX视频属性的抓取
# BV号为1ht4y117rX的视频属性抓取结束
# 开始BV号为1eK4y187GC视频属性的抓取
# BV号为1eK4y187GC的视频属性抓取结束
# 开始BV号为1ge411W74H视频属性的抓取
# BV号为1ge411W74H的视频属性抓取结束
# 开始BV号为11t4y117W9视频属性的抓取
# BV号为11t4y117W9的视频属性抓取结束
# 开始BV号为1qe411W73y视频属性的抓取
# BV号为1qe411W73y的视频属性抓取结束
# 开始BV号为1Na4y1i7B3视频属性的抓取
# BV号为1Na4y1i7B3的视频属性抓取结束
# 开始BV号为1Xa4y1e7xM视频属性的抓取
# BV号为1Xa4y1e7xM的视频属性抓取结束
# 开始BV号为1EK411s7Fr视频属性的抓取
# BV号为1EK411s7Fr的视频属性抓取结束
# 开始BV号为1Hk4y1r7NC视频属性的抓取
# BV号为1Hk4y1r7NC的视频属性抓取结束
# 开始BV号为1yz411v7fT视频属性的抓取
# BV号为1yz411v7fT的视频属性抓取结束
# 开始BV号为1dK4y147VY视频属性的抓取
# BV号为1dK4y147VY的视频属性抓取结束
# 开始BV号为1Uz411v7QT视频属性的抓取
# BV号为1Uz411v7QT的视频属性抓取结束
# 开始BV号为1Zt4y1y7Bj视频属性的抓取
# BV号为1Zt4y1y7Bj的视频属性抓取结束
# 开始BV号为1mQ4y1N7yn视频属性的抓取
# BV号为1mQ4y1N7yn的视频属性抓取结束
# 开始BV号为1y5411p7MD视频属性的抓取
# BV号为1y5411p7MD的视频属性抓取结束
# 开始BV号为1kZ4y1p7ud视频属性的抓取
# BV号为1kZ4y1p7ud的视频属性抓取结束
# 开始BV号为1Wp4y197Gh视频属性的抓取
# BV号为1Wp4y197Gh的视频属性抓取结束
# 开始BV号为1Sk4y1679S视频属性的抓取
# BV号为1Sk4y1679S的视频属性抓取结束
# 开始BV号为1eK4y1t7zi视频属性的抓取
# BV号为1eK4y1t7zi的视频属性抓取结束
# 开始BV号为1s54y1D7vm视频属性的抓取
# BV号为1s54y1D7vm的视频属性抓取结束
# 开始BV号为13f4y127Jd视频属性的抓取
# BV号为13f4y127Jd的视频属性抓取结束
# 开始BV号为1uK411s7kL视频属性的抓取
# BV号为1uK411s7kL的视频属性抓取结束
# 开始BV号为1MA411q7oc视频属性的抓取
# BV号为1MA411q7oc的视频属性抓取结束
# 开始BV号为1T54y1X7Ns视频属性的抓取
# BV号为1T54y1X7Ns的视频属性抓取结束
# 开始BV号为1CK4y1t7Jm视频属性的抓取
# BV号为1CK4y1t7Jm的视频属性抓取结束
# 开始BV号为1ag4y1B7cG视频属性的抓取
# BV号为1ag4y1B7cG的视频属性抓取结束
# 开始BV号为1ff4y117oY视频属性的抓取
# BV号为1ff4y117oY的视频属性抓取结束
# 开始BV号为1Sp4y1Q7WV视频属性的抓取
# BV号为1Sp4y1Q7WV的视频属性抓取结束
# 开始BV号为1ia4y1e7Au视频属性的抓取
# BV号为1ia4y1e7Au的视频属性抓取结束
# 开始BV号为1ET4y137Xd视频属性的抓取
# BV号为1ET4y137Xd的视频属性抓取结束
# 开始BV号为16p4y1Q7zP视频属性的抓取
# BV号为16p4y1Q7zP的视频属性抓取结束
# 开始BV号为1Wp4y1X71s视频属性的抓取
# BV号为1Wp4y1X71s的视频属性抓取结束
# 开始BV号为1XT4y137AN视频属性的抓取
# BV号为1XT4y137AN的视频属性抓取结束
# 开始BV号为1x54y1D7D5视频属性的抓取
# BV号为1x54y1D7D5的视频属性抓取结束
# 开始BV号为14T4y1g78C视频属性的抓取
# BV号为14T4y1g78C的视频属性抓取结束
# 开始BV号为1kg4y1z74k视频属性的抓取
# BV号为1kg4y1z74k的视频属性抓取结束
# 开始BV号为1zz411z7gb视频属性的抓取
# BV号为1zz411z7gb的视频属性抓取结束
# 开始BV号为1kA41147RY视频属性的抓取
# BV号为1kA41147RY的视频属性抓取结束
# 开始BV号为18g4y1B7Ts视频属性的抓取
# BV号为18g4y1B7Ts的视频属性抓取结束
# 开始BV号为17Z4y1s7iG视频属性的抓取
# BV号为17Z4y1s7iG的视频属性抓取结束
# 开始BV号为13k4y1k7xU视频属性的抓取
# BV号为13k4y1k7xU的视频属性抓取结束
# 开始BV号为16z4y1R75u视频属性的抓取
# BV号为16z4y1R75u的视频属性抓取结束
# 开始BV号为1sk4y167R8视频属性的抓取
# BV号为1sk4y167R8的视频属性抓取结束
# 开始BV号为1iK4y1t79v视频属性的抓取
# BV号为1iK4y1t79v的视频属性抓取结束
# 开始BV号为1oz4y1R7ur视频属性的抓取
# BV号为1oz4y1R7ur的视频属性抓取结束
# 开始BV号为1wT4y1g76x视频属性的抓取
# BV号为1wT4y1g76x的视频属性抓取结束
# 开始BV号为1UV411k771视频属性的抓取
# BV号为1UV411k771的视频属性抓取结束
# 开始BV号为13C4y1p7SN视频属性的抓取
# BV号为13C4y1p7SN的视频属性抓取结束
# 开始BV号为1ri4y1x7Jd视频属性的抓取
# BV号为1ri4y1x7Jd的视频属性抓取结束
# 开始BV号为12k4y167iT视频属性的抓取
# BV号为12k4y167iT的视频属性抓取结束
# 开始BV号为1hz411q7h8视频属性的抓取
# BV号为1hz411q7h8的视频属性抓取结束
# 开始BV号为1kC4y1W76Y视频属性的抓取
# BV号为1kC4y1W76Y的视频属性抓取结束
# 开始BV号为1dV411k7Bp视频属性的抓取
# BV号为1dV411k7Bp的视频属性抓取结束
# 开始BV号为1PA411q7w6视频属性的抓取
# BV号为1PA411q7w6的视频属性抓取结束
# 开始BV号为1eV411C7vh视频属性的抓取
# BV号为1eV411C7vh的视频属性抓取结束
# 开始BV号为1xk4y1k7ds视频属性的抓取
# BV号为1xk4y1k7ds的视频属性抓取结束
# 开始BV号为1gt4y117Tz视频属性的抓取
# BV号为1gt4y117Tz的视频属性抓取结束
# 开始BV号为1BQ4y1N7gv视频属性的抓取
# BV号为1BQ4y1N7gv的视频属性抓取结束
# 开始BV号为1hT4y1378x视频属性的抓取
# BV号为1hT4y1378x的视频属性抓取结束
# 开始BV号为1Te411W7LX视频属性的抓取
# BV号为1Te411W7LX的视频属性抓取结束
# 开始BV号为18541147Nt视频属性的抓取
# BV号为18541147Nt的视频属性抓取结束
# 开始BV号为1Tp4y197ob视频属性的抓取
# BV号为1Tp4y197ob的视频属性抓取结束
# 开始BV号为1Wz4y1R78P视频属性的抓取
# BV号为1Wz4y1R78P的视频属性抓取结束
# 开始BV号为1tA411q7AK视频属性的抓取
# BV号为1tA411q7AK的视频属性抓取结束
# 开始BV号为19V411d7re视频属性的抓取
# BV号为19V411d7re的视频属性抓取结束
# 开始BV号为11V411C7Hd视频属性的抓取
# BV号为11V411C7Hd的视频属性抓取结束
# 开始BV号为12p4y197Vg视频属性的抓取
# BV号为12p4y197Vg的视频属性抓取结束
# 开始BV号为1wg4y1z7HP视频属性的抓取
# BV号为1wg4y1z7HP的视频属性抓取结束
# 开始BV号为1di4y1x712视频属性的抓取
# BV号为1di4y1x712的视频属性抓取结束
# 开始BV号为17Z4y1p7nR视频属性的抓取
# BV号为17Z4y1p7nR的视频属性抓取结束
# 开始BV号为1tC4y1W79K视频属性的抓取
# BV号为1tC4y1W79K的视频属性抓取结束
# 开始BV号为15a4y1i7Ew视频属性的抓取
# BV号为15a4y1i7Ew的视频属性抓取结束
# 开始BV号为1iQ4y1N7tb视频属性的抓取
# BV号为1iQ4y1N7tb的视频属性抓取结束
# 开始BV号为11Z4y1s7bG视频属性的抓取
# 开始BV号为11Z4y1s7bG视频属性的抓取
# BV号为11Z4y1s7bG的视频属性抓取结束
# 开始BV号为1554y1Q7aX视频属性的抓取
# BV号为1554y1Q7aX的视频属性抓取结束
# 开始BV号为1gz411q7Uv视频属性的抓取
# BV号为1gz411q7Uv的视频属性抓取结束
# 开始BV号为1xZ4y1p7Uy视频属性的抓取
# BV号为1xZ4y1p7Uy的视频属性抓取结束
# 开始BV号为1nt4y117br视频属性的抓取
# BV号为1nt4y117br的视频属性抓取结束
# 开始BV号为1pg4y1i7Q6视频属性的抓取
# BV号为1pg4y1i7Q6的视频属性抓取结束
# 开始BV号为1Sp4y1Q7ig视频属性的抓取
# BV号为1Sp4y1Q7ig的视频属性抓取结束
# 开始BV号为1vT4y1375s视频属性的抓取
# BV号为1vT4y1375s的视频属性抓取结束
# 开始BV号为11p4y197d3视频属性的抓取
# BV号为11p4y197d3的视频属性抓取结束
# 开始BV号为1ZC4y1W7Cj视频属性的抓取
# BV号为1ZC4y1W7Cj的视频属性抓取结束
# 开始BV号为1sT4y1u7n8视频属性的抓取
# BV号为1sT4y1u7n8的视频属性抓取结束
# 开始BV号为1ca4y1v7cq视频属性的抓取
# BV号为1ca4y1v7cq的视频属性抓取结束
# 开始BV号为1UK41157ue视频属性的抓取
# BV号为1UK41157ue的视频属性抓取结束
# 开始BV号为1q54y1X741视频属性的抓取
# BV号为1q54y1X741的视频属性抓取结束
# 开始BV号为1C5411s74o视频属性的抓取
# BV号为1C5411s74o的视频属性抓取结束
# 开始BV号为1az4y1d7KX视频属性的抓取
# BV号为1az4y1d7KX的视频属性抓取结束
# 开始BV号为1Qi4y1471P视频属性的抓取
# BV号为1Qi4y1471P的视频属性抓取结束
# 开始BV号为1DT4y1u7DF视频属性的抓取
# BV号为1DT4y1u7DF的视频属性抓取结束
# 开始BV号为1WV411C7MV视频属性的抓取
# BV号为1WV411C7MV的视频属性抓取结束
# 开始BV号为1Kf4y1U7zr视频属性的抓取
# BV号为1Kf4y1U7zr的视频属性抓取结束
# 开始BV号为1ef4y1m7F7视频属性的抓取
# BV号为1ef4y1m7F7的视频属性抓取结束
# 开始BV号为1SV411k7NQ视频属性的抓取
# BV号为1SV411k7NQ的视频属性抓取结束
# 开始BV号为19p4y1U76R视频属性的抓取
# BV号为19p4y1U76R的视频属性抓取结束
# 开始BV号为14T4y177L4视频属性的抓取
# BV号为14T4y177L4的视频属性抓取结束
# 开始BV号为1hk4y1z7gj视频属性的抓取
# BV号为1hk4y1z7gj的视频属性抓取结束
# 开始BV号为1Aa4y1e7Zy视频属性的抓取
# BV号为1Aa4y1e7Zy的视频属性抓取结束
# 开始BV号为1wD4y1Q7e9视频属性的抓取
# BV号为1wD4y1Q7e9的视频属性抓取结束
# 开始BV号为1d5411p7wV视频属性的抓取
# BV号为1d5411p7wV的视频属性抓取结束
# <ipython-input-9-17590af043e4>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1Wa4y1Y7t6视频属性的抓取
# BV号为1Wa4y1Y7t6的视频属性抓取结束
# 开始BV号为1MV411k73d视频属性的抓取
# BV号为1MV411k73d的视频属性抓取结束
# 开始BV号为1KV411k7f2视频属性的抓取
# BV号为1KV411k7f2的视频属性抓取结束
# 开始BV号为17a4y1Y7VL视频属性的抓取
# BV号为17a4y1Y7VL的视频属性抓取结束
# 开始BV号为12K4y147Kp视频属性的抓取
# BV号为12K4y147Kp的视频属性抓取结束
# 开始BV号为1VK411p7wd视频属性的抓取
# BV号为1VK411p7wd的视频属性抓取结束
# 开始BV号为1FV411y7aN视频属性的抓取
# BV号为1FV411y7aN的视频属性抓取结束
# 开始BV号为1fi4y1s7c4视频属性的抓取
# BV号为1fi4y1s7c4的视频属性抓取结束
# 开始BV号为1454y1B7CT视频属性的抓取
# BV号为1454y1B7CT的视频属性抓取结束
# 开始BV号为1Ba4y1Y77d视频属性的抓取
# BV号为1Ba4y1Y77d的视频属性抓取结束
# 开始BV号为13a4y1e78c视频属性的抓取
# BV号为13a4y1e78c的视频属性抓取结束
# 开始BV号为1mA411q7eQ视频属性的抓取
# BV号为1mA411q7eQ的视频属性抓取结束
# 开始BV号为19A411q74j视频属性的抓取
# BV号为19A411q74j的视频属性抓取结束
# 开始BV号为1hz4y197vZ视频属性的抓取
# BV号为1hz4y197vZ的视频属性抓取结束
# 开始BV号为1ct4y197SQ视频属性的抓取
# BV号为1ct4y197SQ的视频属性抓取结束
# 开始BV号为1LV411k7WR视频属性的抓取
# BV号为1LV411k7WR的视频属性抓取结束
# 开始BV号为1Xz4y1Q7B3视频属性的抓取
# BV号为1Xz4y1Q7B3的视频属性抓取结束
# 开始BV号为19z411i73S视频属性的抓取
# BV号为19z411i73S的视频属性抓取结束
# 开始BV号为1jK411p7Ee视频属性的抓取
# BV号为1jK411p7Ee的视频属性抓取结束
# 开始BV号为1Ti4y1x7xV视频属性的抓取
# BV号为1Ti4y1x7xV的视频属性抓取结束
# 开始BV号为1vf4y1y7w1视频属性的抓取
# BV号为1vf4y1y7w1的视频属性抓取结束
# 开始BV号为18C4y187YC视频属性的抓取
# BV号为18C4y187YC的视频属性抓取结束
# 开始BV号为1NC4y1a7aD视频属性的抓取
# BV号为1NC4y1a7aD的视频属性抓取结束
# 开始BV号为1WV411r7PL视频属性的抓取
# BV号为1WV411r7PL的视频属性抓取结束
# 开始BV号为16T4y1J73X视频属性的抓取
# BV号为16T4y1J73X的视频属性抓取结束
# 开始BV号为1AK411W7fz视频属性的抓取
# BV号为1AK411W7fz的视频属性抓取结束
# 开始BV号为1iT4y1J7zW视频属性的抓取
# BV号为1iT4y1J7zW的视频属性抓取结束
# 开始BV号为1Ck4y1z78g视频属性的抓取
# BV号为1Ck4y1z78g的视频属性抓取结束
# 开始BV号为1YV411r7k6视频属性的抓取
# BV号为1YV411r7k6的视频属性抓取结束
# 开始BV号为1Wg4y1v7dJ视频属性的抓取
# BV号为1Wg4y1v7dJ的视频属性抓取结束
# 开始BV号为1vz411e7rC视频属性的抓取
# BV号为1vz411e7rC的视频属性抓取结束
# 开始BV号为1UK4y1x74k视频属性的抓取
# BV号为1UK4y1x74k的视频属性抓取结束
# 开始BV号为1FZ4y1H77u视频属性的抓取
# BV号为1FZ4y1H77u的视频属性抓取结束
# 开始BV号为1ri4y1s7DB视频属性的抓取
# BV号为1ri4y1s7DB的视频属性抓取结束
# 开始BV号为1GZ4y1H7uj视频属性的抓取
# BV号为1GZ4y1H7uj的视频属性抓取结束
# 开始BV号为1J5411W7z6视频属性的抓取
# BV号为1J5411W7z6的视频属性抓取结束
# 开始BV号为1kf4y127vy视频属性的抓取
# BV号为1kf4y127vy的视频属性抓取结束
# 开始BV号为1ba4y1v7gj视频属性的抓取
# BV号为1ba4y1v7gj的视频属性抓取结束
# 开始BV号为1Xg4y1i77a视频属性的抓取
# BV号为1Xg4y1i77a的视频属性抓取结束
# 开始BV号为1WK411p7HT视频属性的抓取
# BV号为1WK411p7HT的视频属性抓取结束
# 开始BV号为1of4y127YK视频属性的抓取
# BV号为1of4y127YK的视频属性抓取结束
# 开始BV号为13i4y1x7JC视频属性的抓取
# BV号为13i4y1x7JC的视频属性抓取结束
# 开始BV号为18K4y147ji视频属性的抓取
# BV号为18K4y147ji的视频属性抓取结束
# 开始BV号为11k4y1z7dR视频属性的抓取
# BV号为11k4y1z7dR的视频属性抓取结束
# 开始BV号为1LA411i7Ld视频属性的抓取
# BV号为1LA411i7Ld的视频属性抓取结束
# 开始BV号为13a4y1Y7GH视频属性的抓取
# BV号为13a4y1Y7GH的视频属性抓取结束
# 开始BV号为1ri4y1s7GA视频属性的抓取
# BV号为1ri4y1s7GA的视频属性抓取结束
# 开始BV号为1HC4y1a7ha视频属性的抓取
# BV号为1HC4y1a7ha的视频属性抓取结束
# 开始BV号为1YK411p7vR视频属性的抓取
# BV号为1YK411p7vR的视频属性抓取结束
# 开始BV号为1Na4y1Y7rR视频属性的抓取
# BV号为1Na4y1Y7rR的视频属性抓取结束
# 开始BV号为1JK4y1s7dw视频属性的抓取
# BV号为1JK4y1s7dw的视频属性抓取结束
# 开始BV号为1sC4y1a7wy视频属性的抓取
# BV号为1sC4y1a7wy的视频属性抓取结束
# 开始BV号为19z4y1Q7z6视频属性的抓取
# BV号为19z4y1Q7z6的视频属性抓取结束
# 开始BV号为1jf4y11758视频属性的抓取
# BV号为1jf4y11758的视频属性抓取结束
# 开始BV号为1Zz4y1Q7hp视频属性的抓取
# BV号为1Zz4y1Q7hp的视频属性抓取结束
# 开始BV号为1sK4y147CJ视频属性的抓取
# BV号为1sK4y147CJ的视频属性抓取结束
# 开始BV号为13D4y1Q7ey视频属性的抓取
# BV号为13D4y1Q7ey的视频属性抓取结束
# 开始BV号为1Tg4y1v7ju视频属性的抓取
# BV号为1Tg4y1v7ju的视频属性抓取结束
# 开始BV号为1E54y1Q7rv视频属性的抓取
# BV号为1E54y1Q7rv的视频属性抓取结束
# 开始BV号为1rD4y1D7C3视频属性的抓取
# BV号为1rD4y1D7C3的视频属性抓取结束
# 开始BV号为1g5411Y7zk视频属性的抓取
# BV号为1g5411Y7zk的视频属性抓取结束
# 开始BV号为1wg4y1q7tH视频属性的抓取
# BV号为1wg4y1q7tH的视频属性抓取结束
# 开始BV号为1Af4y1m7xK视频属性的抓取
# BV号为1Af4y1m7xK的视频属性抓取结束
# 开始BV号为1Fp4y1Q7hK视频属性的抓取
# BV号为1Fp4y1Q7hK的视频属性抓取结束
# 开始BV号为1ti4y1G7m1视频属性的抓取
# BV号为1ti4y1G7m1的视频属性抓取结束
# 开始BV号为1Ap4y1D73M视频属性的抓取
# BV号为1Ap4y1D73M的视频属性抓取结束
# 开始BV号为1ht4y197Lv视频属性的抓取
# BV号为1ht4y197Lv的视频属性抓取结束
# 开始BV号为1zg4y1q79o视频属性的抓取
# BV号为1zg4y1q79o的视频属性抓取结束
# 开始BV号为1qD4y1D7vj视频属性的抓取
# BV号为1qD4y1D7vj的视频属性抓取结束
# 开始BV号为1D54y1B7ry视频属性的抓取
# BV号为1D54y1B7ry的视频属性抓取结束
# 开始BV号为1WD4y1Q7FK视频属性的抓取
# BV号为1WD4y1Q7FK的视频属性抓取结束
# 开始BV号为1Gt4y1y7kg视频属性的抓取
# BV号为1Gt4y1y7kg的视频属性抓取结束
# 开始BV号为1Wt4y1y7iA视频属性的抓取
# BV号为1Wt4y1y7iA的视频属性抓取结束
# 开始BV号为1YV411r7vz视频属性的抓取
# BV号为1YV411r7vz的视频属性抓取结束
# 开始BV号为1Ug4y1i7fA视频属性的抓取
# BV号为1Ug4y1i7fA的视频属性抓取结束
# 开始BV号为1dk4y1z7jV视频属性的抓取
# BV号为1dk4y1z7jV的视频属性抓取结束
# 开始BV号为14t4y1y7eW视频属性的抓取
# BV号为14t4y1y7eW的视频属性抓取结束
# 开始BV号为1ZC4y1h7he视频属性的抓取
# BV号为1ZC4y1h7he的视频属性抓取结束
# 开始BV号为1Qf4y1y7DQ视频属性的抓取
# BV号为1Qf4y1y7DQ的视频属性抓取结束
# 开始BV号为1Tp4y1D744视频属性的抓取
# BV号为1Tp4y1D744的视频属性抓取结束
# 开始BV号为1Ht4y1y7BR视频属性的抓取
# BV号为1Ht4y1y7BR的视频属性抓取结束
# 开始BV号为1Wv41167Wq视频属性的抓取
# BV号为1Wv41167Wq的视频属性抓取结束
# 开始BV号为1Yg4y1q7Yv视频属性的抓取
# BV号为1Yg4y1q7Yv的视频属性抓取结束
# 开始BV号为1bi4y1x7cx视频属性的抓取
# BV号为1bi4y1x7cx的视频属性抓取结束
# 开始BV号为1rf4y117SF视频属性的抓取
# BV号为1rf4y117SF的视频属性抓取结束
# 开始BV号为1RZ4y1n7Y4视频属性的抓取
# BV号为1RZ4y1n7Y4的视频属性抓取结束
# 开始BV号为1hp4y1U77Q视频属性的抓取
# BV号为1hp4y1U77Q的视频属性抓取结束
# 开始BV号为1bQ4y1P7XV视频属性的抓取
# BV号为1bQ4y1P7XV的视频属性抓取结束
# 开始BV号为1cD4y1Q7Nq视频属性的抓取
# BV号为1cD4y1Q7Nq的视频属性抓取结束
# 开始BV号为12i4y1s7Na视频属性的抓取
# BV号为12i4y1s7Na的视频属性抓取结束
# 开始BV号为1nK4y147rq视频属性的抓取
# BV号为1nK4y147rq的视频属性抓取结束
# 开始BV号为1Yp4y1U7we视频属性的抓取
# BV号为1Yp4y1U7we的视频属性抓取结束
# 开始BV号为1NK4y147gM视频属性的抓取
# BV号为1NK4y147gM的视频属性抓取结束
# 开始BV号为1zK4y1s7JD视频属性的抓取
# BV号为1zK4y1s7JD的视频属性抓取结束
# 开始BV号为15i4y1377r视频属性的抓取
# BV号为15i4y1377r的视频属性抓取结束
# 开始BV号为1f54y1U7tF视频属性的抓取
# BV号为1f54y1U7tF的视频属性抓取结束
# 开始BV号为1Kv411q7eR视频属性的抓取
# BV号为1Kv411q7eR的视频属性抓取结束
# 开始BV号为1ji4y1V7f4视频属性的抓取
# BV号为1ji4y1V7f4的视频属性抓取结束
# 开始BV号为1zz4y1X7em视频属性的抓取
# BV号为1zz4y1X7em的视频属性抓取结束
# 开始BV号为16p4y1i7fP视频属性的抓取
# BV号为16p4y1i7fP的视频属性抓取结束
# 开始BV号为1U5411h73V视频属性的抓取
# BV号为1U5411h73V的视频属性抓取结束
# 开始BV号为1ni4y137S9视频属性的抓取
# BV号为1ni4y137S9的视频属性抓取结束
# 开始BV号为1C5411Y7rr视频属性的抓取
# BV号为1C5411Y7rr的视频属性抓取结束
# 开始BV号为1hv411q7k2视频属性的抓取
# BV号为1hv411q7k2的视频属性抓取结束
# 开始BV号为1da4y1E79A视频属性的抓取
# BV号为1da4y1E79A的视频属性抓取结束
# 开始BV号为1hp4y1U7Ao视频属性的抓取
# BV号为1hp4y1U7Ao的视频属性抓取结束
# 开始BV号为1Ti4y137ks视频属性的抓取
# BV号为1Ti4y137ks的视频属性抓取结束
# 开始BV号为1gf4y197hS视频属性的抓取
# BV号为1gf4y197hS的视频属性抓取结束
# 开始BV号为1q5411Y7KV视频属性的抓取
# BV号为1q5411Y7KV的视频属性抓取结束
# 开始BV号为1La4y1a7Gk视频属性的抓取
# BV号为1La4y1a7Gk的视频属性抓取结束
# 开始BV号为1zf4y117G8视频属性的抓取
# BV号为1zf4y117G8的视频属性抓取结束
# 开始BV号为1A5411Y7Wv视频属性的抓取
# BV号为1A5411Y7Wv的视频属性抓取结束
# 开始BV号为1Lz411v7Lc视频属性的抓取
# BV号为1Lz411v7Lc的视频属性抓取结束
# 开始BV号为1tK411J76b视频属性的抓取
# BV号为1tK411J76b的视频属性抓取结束
# 开始BV号为1Xf4y1R7iW视频属性的抓取
# BV号为1Xf4y1R7iW的视频属性抓取结束
# 开始BV号为1MC4y187Xr视频属性的抓取
# BV号为1MC4y187Xr的视频属性抓取结束
# 开始BV号为1pK4y1x7oW视频属性的抓取
# BV号为1pK4y1x7oW的视频属性抓取结束
# 开始BV号为1KZ4y1g7dN视频属性的抓取
# BV号为1KZ4y1g7dN的视频属性抓取结束
# 开始BV号为1c5411e7sm视频属性的抓取
# BV号为1c5411e7sm的视频属性抓取结束
# 开始BV号为1qi4y137CG视频属性的抓取
# BV号为1qi4y137CG的视频属性抓取结束
# 开始BV号为1Fi4y1G7eJ视频属性的抓取
# BV号为1Fi4y1G7eJ的视频属性抓取结束
# 开始BV号为1WC4y1b75r视频属性的抓取
# BV号为1WC4y1b75r的视频属性抓取结束
# 开始BV号为1954y1i7fa视频属性的抓取
# BV号为1954y1i7fa的视频属性抓取结束
# 开始BV号为1YC4y1h716视频属性的抓取
# BV号为1YC4y1h716的视频属性抓取结束
# 开始BV号为1dA411a7oE视频属性的抓取
# BV号为1dA411a7oE的视频属性抓取结束
# 开始BV号为1f5411Y7P7视频属性的抓取
# BV号为1f5411Y7P7的视频属性抓取结束
# 开始BV号为1pt4y197f2视频属性的抓取
# BV号为1pt4y197f2的视频属性抓取结束
# 开始BV号为1FT4y1E7u3视频属性的抓取
# BV号为1FT4y1E7u3的视频属性抓取结束
# 开始BV号为12K4y1s7Yi视频属性的抓取
# BV号为12K4y1s7Yi的视频属性抓取结束
# 开始BV号为1pD4y1S776视频属性的抓取
# BV号为1pD4y1S776的视频属性抓取结束
# 开始BV号为1Z54y1U7qs视频属性的抓取
# BV号为1Z54y1U7qs的视频属性抓取结束
# 开始BV号为1Gf4y1R7EZ视频属性的抓取
# BV号为1Gf4y1R7EZ的视频属性抓取结束
# 开始BV号为1yA411i7xP视频属性的抓取
# BV号为1yA411i7xP的视频属性抓取结束
# 开始BV号为1f5411Y7ep视频属性的抓取
# BV号为1f5411Y7ep的视频属性抓取结束
# 开始BV号为18V411z7sP视频属性的抓取
# BV号为18V411z7sP的视频属性抓取结束
# 开始BV号为1cZ4y1u7qc视频属性的抓取
# BV号为1cZ4y1u7qc的视频属性抓取结束
# 开始BV号为1RA411a7Gr视频属性的抓取
# BV号为1RA411a7Gr的视频属性抓取结束
# 开始BV号为1Av411z7cR视频属性的抓取
# BV号为1Av411z7cR的视频属性抓取结束
# 开始BV号为1Df4y117jj视频属性的抓取
# BV号为1Df4y117jj的视频属性抓取结束
# 开始BV号为11a4y1h7gA视频属性的抓取
# BV号为11a4y1h7gA的视频属性抓取结束
# 开始BV号为1CD4y1m7qW视频属性的抓取
# BV号为1CD4y1m7qW的视频属性抓取结束
# 开始BV号为1dD4y1m7jC视频属性的抓取
# BV号为1dD4y1m7jC的视频属性抓取结束
# 开始BV号为1S5411h7Xz视频属性的抓取
# BV号为1S5411h7Xz的视频属性抓取结束
# 开始BV号为1854y1S7qd视频属性的抓取
# BV号为1854y1S7qd的视频属性抓取结束
# 开始BV号为1Xk4y127nU视频属性的抓取
# BV号为1Xk4y127nU的视频属性抓取结束
# 开始BV号为1z64y1F7nf视频属性的抓取
# BV号为1z64y1F7nf的视频属性抓取结束
# 开始BV号为1zC4y1h7sy视频属性的抓取
# BV号为1zC4y1h7sy的视频属性抓取结束
# 开始BV号为1UA411e7vb视频属性的抓取
# BV号为1UA411e7vb的视频属性抓取结束
# 开始BV号为1Up4y1i76x视频属性的抓取
# BV号为1Up4y1i76x的视频属性抓取结束
# 开始BV号为1Ht4y1Q753视频属性的抓取
# BV号为1Ht4y1Q753的视频属性抓取结束
# 开始BV号为1Qa4y1a7TR视频属性的抓取
# BV号为1Qa4y1a7TR的视频属性抓取结束
# 开始BV号为1MK411H7c1视频属性的抓取
# BV号为1MK411H7c1的视频属性抓取结束
# 开始BV号为1zk4y1m7CZ视频属性的抓取
# BV号为1zk4y1m7CZ的视频属性抓取结束
# 开始BV号为1N54y1D74i视频属性的抓取
# BV号为1N54y1D74i的视频属性抓取结束
# 开始BV号为1Rt4y1Q7SW视频属性的抓取
# BV号为1Rt4y1Q7SW的视频属性抓取结束
# 开始BV号为1EZ4y1u7x1视频属性的抓取
# BV号为1EZ4y1u7x1的视频属性抓取结束
# 开始BV号为1mk4y1z7rJ视频属性的抓取
# BV号为1mk4y1z7rJ的视频属性抓取结束
# 开始BV号为1GA411Y7x6视频属性的抓取
# BV号为1GA411Y7x6的视频属性抓取结束
# 开始BV号为1354y1S7Mn视频属性的抓取
# BV号为1354y1S7Mn的视频属性抓取结束
# 开始BV号为1xz4y1Q7Ka视频属性的抓取
# BV号为1xz4y1Q7Ka的视频属性抓取结束
# 开始BV号为1p54y1S7XF视频属性的抓取
# BV号为1p54y1S7XF的视频属性抓取结束
# 开始BV号为15C4y1874y视频属性的抓取
# BV号为15C4y1874y的视频属性抓取结束
# 开始BV号为1Ck4y1m7cu视频属性的抓取
# BV号为1Ck4y1m7cu的视频属性抓取结束
# 开始BV号为13v411q7ND视频属性的抓取
# BV号为13v411q7ND的视频属性抓取结束
# 开始BV号为1QK411J7g5视频属性的抓取
# BV号为1QK411J7g5的视频属性抓取结束
# 开始BV号为1M54y1B72A视频属性的抓取
# 开始BV号为1M54y1B72A视频属性的抓取
# BV号为1M54y1B72A的视频属性抓取结束
# 开始BV号为1eD4y1S7fG视频属性的抓取
# BV号为1eD4y1S7fG的视频属性抓取结束
# 开始BV号为1d54y1S7pq视频属性的抓取
# BV号为1d54y1S7pq的视频属性抓取结束
# 开始BV号为18v411v7a8视频属性的抓取
# BV号为18v411v7a8的视频属性抓取结束
# 开始BV号为1dT4y1776o视频属性的抓取
# BV号为1dT4y1776o的视频属性抓取结束
# 开始BV号为1P5411Y7qh视频属性的抓取
# BV号为1P5411Y7qh的视频属性抓取结束
# 开始BV号为1zD4y1S797视频属性的抓取
# BV号为1zD4y1S797的视频属性抓取结束
# 开始BV号为1g5411e7UL视频属性的抓取
# BV号为1g5411e7UL的视频属性抓取结束
# 开始BV号为1Lg4y1i7Dv视频属性的抓取
# BV号为1Lg4y1i7Dv的视频属性抓取结束
# 开始BV号为1Pt4y1X7wQ视频属性的抓取
# BV号为1Pt4y1X7wQ的视频属性抓取结束
# 开始BV号为1RK411n7NU视频属性的抓取
# BV号为1RK411n7NU的视频属性抓取结束
# 开始BV号为1wf4y1R7iH视频属性的抓取
# BV号为1wf4y1R7iH的视频属性抓取结束
# 开始BV号为1Zk4y1z7c9视频属性的抓取
# BV号为1Zk4y1z7c9的视频属性抓取结束
# 开始BV号为1dk4y1q7Me视频属性的抓取
# BV号为1dk4y1q7Me的视频属性抓取结束
# 开始BV号为1f54y1S7cc视频属性的抓取
# BV号为1f54y1S7cc的视频属性抓取结束
# 开始BV号为16i4y137Rr视频属性的抓取
# BV号为16i4y137Rr的视频属性抓取结束
# 开始BV号为1iZ4y1u7Cx视频属性的抓取
# BV号为1iZ4y1u7Cx的视频属性抓取结束
# 开始BV号为1iK411H7Yw视频属性的抓取
# BV号为1iK411H7Yw的视频属性抓取结束
# 开始BV号为1aC4y187DC视频属性的抓取
# BV号为1aC4y187DC的视频属性抓取结束
# 开始BV号为1gK411H7r1视频属性的抓取
# BV号为1gK411H7r1的视频属性抓取结束
# 开始BV号为1JK411H7QB视频属性的抓取
# BV号为1JK411H7QB的视频属性抓取结束
# 开始BV号为1yf4y117jA视频属性的抓取
# BV号为1yf4y117jA的视频属性抓取结束
# 开始BV号为1V5411e7cZ视频属性的抓取
# BV号为1V5411e7cZ的视频属性抓取结束
# 开始BV号为1up4y1S7ji视频属性的抓取
# BV号为1up4y1S7ji的视频属性抓取结束
# 开始BV号为15T4y1E7D3视频属性的抓取
# BV号为15T4y1E7D3的视频属性抓取结束
# 开始BV号为18i4y1V7gs视频属性的抓取
# BV号为18i4y1V7gs的视频属性抓取结束
# 开始BV号为1QC4y1b74M视频属性的抓取
# BV号为1QC4y1b74M的视频属性抓取结束
# 开始BV号为1wf4y1R7Fu视频属性的抓取
# BV号为1wf4y1R7Fu的视频属性抓取结束
# 开始BV号为1Gf4y1X7x6视频属性的抓取
# BV号为1Gf4y1X7x6的视频属性抓取结束
# 开始BV号为1H64y1c7Rj视频属性的抓取
# BV号为1H64y1c7Rj的视频属性抓取结束
# 开始BV号为1Xf4y1976p视频属性的抓取
# BV号为1Xf4y1976p的视频属性抓取结束
# 开始BV号为1VK411T7e9视频属性的抓取
# BV号为1VK411T7e9的视频属性抓取结束
# 开始BV号为1zC4y1t749视频属性的抓取
# BV号为1zC4y1t749的视频属性抓取结束
# 开始BV号为1Ak4y1274w视频属性的抓取
# BV号为1Ak4y1274w的视频属性抓取结束
# 开始BV号为1ai4y1g7Ae视频属性的抓取
# BV号为1ai4y1g7Ae的视频属性抓取结束
# 开始BV号为1Ut4y1U7sR视频属性的抓取
# BV号为1Ut4y1U7sR的视频属性抓取结束
# 开始BV号为16K4y1Y7ew视频属性的抓取
# BV号为16K4y1Y7ew的视频属性抓取结束
# 开始BV号为12k4y1m7qg视频属性的抓取
# BV号为12k4y1m7qg的视频属性抓取结束
# 开始BV号为1cK4y1v7Aq视频属性的抓取
# BV号为1cK4y1v7Aq的视频属性抓取结束
# 开始BV号为1sZ4y1T7Bz视频属性的抓取
# BV号为1sZ4y1T7Bz的视频属性抓取结束
# 开始BV号为1Lf4y1Q7Qz视频属性的抓取
# BV号为1Lf4y1Q7Qz的视频属性抓取结束
# 开始BV号为1tv411i7hY视频属性的抓取
# BV号为1tv411i7hY的视频属性抓取结束
# 开始BV号为1Ph411o7G6视频属性的抓取
# BV号为1Ph411o7G6的视频属性抓取结束
# 开始BV号为1MV411S7DT视频属性的抓取
# BV号为1MV411S7DT的视频属性抓取结束
# 开始BV号为1Ca4y1E7U1视频属性的抓取
# BV号为1Ca4y1E7U1的视频属性抓取结束
# 开始BV号为1NA411n7r4视频属性的抓取
# BV号为1NA411n7r4的视频属性抓取结束
# 开始BV号为1a541187Eb视频属性的抓取
# BV号为1a541187Eb的视频属性抓取结束
# 开始BV号为1qC4y1t72g视频属性的抓取
# BV号为1qC4y1t72g的视频属性抓取结束
# 开始BV号为1XK411N7A6视频属性的抓取
# BV号为1XK411N7A6的视频属性抓取结束
# 开始BV号为1DK4y1Y7xd视频属性的抓取
# BV号为1DK4y1Y7xd的视频属性抓取结束
# 开始BV号为1tK4y1Y7dK视频属性的抓取
# BV号为1tK4y1Y7dK的视频属性抓取结束
# 开始BV号为1xK4y1v7ta视频属性的抓取
# BV号为1xK4y1v7ta的视频属性抓取结束
# 开始BV号为1hK4y1Y7bY视频属性的抓取
# BV号为1hK4y1Y7bY的视频属性抓取结束
# 开始BV号为1ih41197Ud视频属性的抓取
# BV号为1ih41197Ud的视频属性抓取结束
# 开始BV号为1Gi4y1G7me视频属性的抓取
# BV号为1Gi4y1G7me的视频属性抓取结束
# 开始BV号为1Mp4y1i7Tn视频属性的抓取
# BV号为1Mp4y1i7Tn的视频属性抓取结束
# 开始BV号为1fa4y1773a视频属性的抓取
# BV号为1fa4y1773a的视频属性抓取结束
# 开始BV号为15K411M7z7视频属性的抓取
# BV号为15K411M7z7的视频属性抓取结束
# 开始BV号为1xh411Z78T视频属性的抓取
# BV号为1xh411Z78T的视频属性抓取结束
# 开始BV号为1RD4y127CY视频属性的抓取
# BV号为1RD4y127CY的视频属性抓取结束
# 开始BV号为1Jt4y1S7fv视频属性的抓取
# BV号为1Jt4y1S7fv的视频属性抓取结束
# 开始BV号为19i4y1M7bJ视频属性的抓取
# BV号为19i4y1M7bJ的视频属性抓取结束
# 开始BV号为12A411Y7m2视频属性的抓取
# BV号为12A411Y7m2的视频属性抓取结束
# 开始BV号为1nT4y1L7Ua视频属性的抓取
# BV号为1nT4y1L7Ua的视频属性抓取结束
# 开始BV号为1YA411Y7rP视频属性的抓取
# BV号为1YA411Y7rP的视频属性抓取结束
# 开始BV号为1iT4y1L7wH视频属性的抓取
# BV号为1iT4y1L7wH的视频属性抓取结束
# 开始BV号为1gC4y1t7oX视频属性的抓取
# BV号为1gC4y1t7oX的视频属性抓取结束
# 开始BV号为1zC4y1t7ga视频属性的抓取
# BV号为1zC4y1t7ga的视频属性抓取结束
# 开始BV号为1WK411T71J视频属性的抓取
# BV号为1WK411T71J的视频属性抓取结束
# 开始BV号为1gT4y1L7BW视频属性的抓取
# BV号为1gT4y1L7BW的视频属性抓取结束
# 开始BV号为1M54y1v7Ks视频属性的抓取
# BV号为1M54y1v7Ks的视频属性抓取结束
# 开始BV号为1mt4y1U7dR视频属性的抓取
# BV号为1mt4y1U7dR的视频属性抓取结束
# 开始BV号为1KK411M7SC视频属性的抓取
# BV号为1KK411M7SC的视频属性抓取结束
# 开始BV号为1eA411Y7Fn视频属性的抓取
# BV号为1eA411Y7Fn的视频属性抓取结束
# 开始BV号为1Xp4y1Y7QR视频属性的抓取
# BV号为1Xp4y1Y7QR的视频属性抓取结束
# 开始BV号为1TT4y177K5视频属性的抓取
# BV号为1TT4y177K5的视频属性抓取结束
# 开始BV号为1aa4y177tN视频属性的抓取
# BV号为1aa4y177tN的视频属性抓取结束
# 开始BV号为1eD4y1U7cC视频属性的抓取
# BV号为1eD4y1U7cC的视频属性抓取结束
# 开始BV号为1Pk4y1U7Uy视频属性的抓取
# BV号为1Pk4y1U7Uy的视频属性抓取结束
# 开始BV号为1Ap4y1v7X8视频属性的抓取
# BV号为1Ap4y1v7X8的视频属性抓取结束
# 开始BV号为1jK411M7Cc视频属性的抓取
# BV号为1jK411M7Cc的视频属性抓取结束
# 开始BV号为16K4y1Y7KN视频属性的抓取
# BV号为16K4y1Y7KN的视频属性抓取结束
# 开始BV号为1rp4y1Y7Lr视频属性的抓取
# BV号为1rp4y1Y7Lr的视频属性抓取结束
# 开始BV号为1eh411d7CL视频属性的抓取
# BV号为1eh411d7CL的视频属性抓取结束
# 开始BV号为1ta4y177w5视频属性的抓取
# BV号为1ta4y177w5的视频属性抓取结束
# 开始BV号为1Zk4y1m7Dk视频属性的抓取
# BV号为1Zk4y1m7Dk的视频属性抓取结束
# 开始BV号为1F64y1c7PQ视频属性的抓取
# BV号为1F64y1c7PQ的视频属性抓取结束
# 开始BV号为19T4y1L7WF视频属性的抓取
# BV号为19T4y1L7WF的视频属性抓取结束
# 开始BV号为17v411i76n视频属性的抓取
# BV号为17v411i76n的视频属性抓取结束
# 开始BV号为1dp4y1v7iD视频属性的抓取
# BV号为1dp4y1v7iD的视频属性抓取结束
# 开始BV号为1fh41197Ur视频属性的抓取
# BV号为1fh41197Ur的视频属性抓取结束
# 开始BV号为1Mt4y1S7mR视频属性的抓取
# BV号为1Mt4y1S7mR的视频属性抓取结束
# 开始BV号为1vK411T7Gp视频属性的抓取
# BV号为1vK411T7Gp的视频属性抓取结束
# 开始BV号为1Tt4y1S7ez视频属性的抓取
# BV号为1Tt4y1S7ez的视频属性抓取结束
# 开始BV号为12K4y1e7w8视频属性的抓取
# BV号为12K4y1e7w8的视频属性抓取结束
# 开始BV号为16f4y197Dv视频属性的抓取
# BV号为16f4y197Dv的视频属性抓取结束
# 开始BV号为1Qk4y117Ay视频属性的抓取
# BV号为1Qk4y117Ay的视频属性抓取结束
# 开始BV号为1kk4y1m73Y视频属性的抓取
# BV号为1kk4y1m73Y的视频属性抓取结束
# 开始BV号为1C54y12731视频属性的抓取
# BV号为1C54y12731的视频属性抓取结束
# 开始BV号为1pV411S77w视频属性的抓取
# BV号为1pV411S77w的视频属性抓取结束
# 开始BV号为1c5411h7wz视频属性的抓取
# BV号为1c5411h7wz的视频属性抓取结束
# 开始BV号为1fk4y117NE视频属性的抓取
# BV号为1fk4y117NE的视频属性抓取结束
# 开始BV号为1nT4y1L7Q2视频属性的抓取
# BV号为1nT4y1L7Q2的视频属性抓取结束
# 开始BV号为1Xh411979r视频属性的抓取
# BV号为1Xh411979r的视频属性抓取结束
# 开始BV号为1xT4y1j7me视频属性的抓取
# BV号为1xT4y1j7me的视频属性抓取结束
# 开始BV号为1QA411Y7Gk视频属性的抓取
# BV号为1QA411Y7Gk的视频属性抓取结束
# 开始BV号为1zD4y1U7yT视频属性的抓取
# BV号为1zD4y1U7yT的视频属性抓取结束
# 开始BV号为18h411Z7Tg视频属性的抓取
# BV号为18h411Z7Tg的视频属性抓取结束
# 开始BV号为1yi4y137os视频属性的抓取
# BV号为1yi4y137os的视频属性抓取结束
# 开始BV号为1qT4y1L7nQ视频属性的抓取
# BV号为1qT4y1L7nQ的视频属性抓取结束
# 开始BV号为14541187bd视频属性的抓取
# BV号为14541187bd的视频属性抓取结束
# 开始BV号为1Hh411Z7MC视频属性的抓取
# BV号为1Hh411Z7MC的视频属性抓取结束
# 开始BV号为1Bv411y7iS视频属性的抓取
# BV号为1Bv411y7iS的视频属性抓取结束
# 开始BV号为1rT4y1w7ix视频属性的抓取
# BV号为1rT4y1w7ix的视频属性抓取结束
# 开始BV号为17K4y1Y7FH视频属性的抓取
# BV号为17K4y1Y7FH的视频属性抓取结束
# 开始BV号为1TA411e7Ke视频属性的抓取
# BV号为1TA411e7Ke的视频属性抓取结束
# 开始BV号为1vK4y1e7Wk视频属性的抓取
# BV号为1vK4y1e7Wk的视频属性抓取结束
# 开始BV号为1eV411U7wH视频属性的抓取
# BV号为1eV411U7wH的视频属性抓取结束
# 开始BV号为1zD4y1U7sL视频属性的抓取
# BV号为1zD4y1U7sL的视频属性抓取结束
# 开始BV号为1Kv411i7EX视频属性的抓取
# BV号为1Kv411i7EX的视频属性抓取结束
# 开始BV号为12z4y1f7dH视频属性的抓取
# BV号为12z4y1f7dH的视频属性抓取结束
# 开始BV号为1sp4y1v7Rg视频属性的抓取
# BV号为1sp4y1v7Rg的视频属性抓取结束
# 开始BV号为1L54y1U77H视频属性的抓取
# BV号为1L54y1U77H的视频属性抓取结束
# 开始BV号为1QV411U7Bg视频属性的抓取
# BV号为1QV411U7Bg的视频属性抓取结束
# 开始BV号为1fh41197xp视频属性的抓取
# BV号为1fh41197xp的视频属性抓取结束
# 开始BV号为1Ah411d7sY视频属性的抓取
# BV号为1Ah411d7sY的视频属性抓取结束
# 开始BV号为1NT4y1L7Zi视频属性的抓取
# BV号为1NT4y1L7Zi的视频属性抓取结束
# 开始BV号为1eT4y1574Y视频属性的抓取
# BV号为1eT4y1574Y的视频属性抓取结束
# 开始BV号为1ED4y1m7Bc视频属性的抓取
# BV号为1ED4y1m7Bc的视频属性抓取结束
# 开始BV号为11i4y177mU视频属性的抓取
# BV号为11i4y177mU的视频属性抓取结束
# 开始BV号为1S54y1C7fj视频属性的抓取
# BV号为1S54y1C7fj的视频属性抓取结束
# 开始BV号为1TT4y1A7qJ视频属性的抓取
# BV号为1TT4y1A7qJ的视频属性抓取结束
# 开始BV号为1p54y1y7az视频属性的抓取
# BV号为1p54y1y7az的视频属性抓取结束
# 开始BV号为1qZ4y1N7AY视频属性的抓取
# BV号为1qZ4y1N7AY的视频属性抓取结束
# 开始BV号为1nK4y1e7Zf视频属性的抓取
# BV号为1nK4y1e7Zf的视频属性抓取结束
# 开始BV号为1T54y117qX视频属性的抓取
# BV号为1T54y117qX的视频属性抓取结束
# 开始BV号为1ft4y1S7Ww视频属性的抓取
# BV号为1ft4y1S7Ww的视频属性抓取结束
# 开始BV号为1WT4y1c7uK视频属性的抓取
# BV号为1WT4y1c7uK的视频属性抓取结束
# 开始BV号为1Tz4y1Z7KF视频属性的抓取
# BV号为1Tz4y1Z7KF的视频属性抓取结束
# 开始BV号为1qi4y1M7W5视频属性的抓取
# BV号为1qi4y1M7W5的视频属性抓取结束
# 开始BV号为1Zp4y1e7TK视频属性的抓取
# BV号为1Zp4y1e7TK的视频属性抓取结束
# 开始BV号为1mA411E7PB视频属性的抓取
# BV号为1mA411E7PB的视频属性抓取结束
# 开始BV号为1TK411K7zU视频属性的抓取
# BV号为1TK411K7zU的视频属性抓取结束
# 开始BV号为1KC4y1b7JC视频属性的抓取
# BV号为1KC4y1b7JC的视频属性抓取结束
# 开始BV号为15K4y1Y7th视频属性的抓取
# BV号为15K4y1Y7th的视频属性抓取结束
# 开始BV号为1GV411S76V视频属性的抓取
# BV号为1GV411S76V的视频属性抓取结束
# 开始BV号为1mZ4y1P7cD视频属性的抓取
# BV号为1mZ4y1P7cD的视频属性抓取结束
# 开始BV号为1Hh411R7nz视频属性的抓取
# BV号为1Hh411R7nz的视频属性抓取结束
# 开始BV号为1cy4y1y7fx视频属性的抓取
# BV号为1cy4y1y7fx的视频属性抓取结束
# 开始BV号为1Up4y1e7p1视频属性的抓取
# BV号为1Up4y1e7p1的视频属性抓取结束
# 开始BV号为1st4y1q7JQ视频属性的抓取
# BV号为1st4y1q7JQ的视频属性抓取结束
# 开始BV号为18K4y1e7aQ视频属性的抓取
# BV号为18K4y1e7aQ的视频属性抓取结束
# 开始BV号为1tv41117Yf视频属性的抓取
# BV号为1tv41117Yf的视频属性抓取结束
# 开始BV号为17t4y1S7A9视频属性的抓取
# BV号为17t4y1S7A9的视频属性抓取结束
# 开始BV号为1gZ4y1N7ma视频属性的抓取
# BV号为1gZ4y1N7ma的视频属性抓取结束
# 开始BV号为1Wy4y1y7KC视频属性的抓取
# BV号为1Wy4y1y7KC的视频属性抓取结束
# 开始BV号为1y5411j7r2视频属性的抓取
# BV号为1y5411j7r2的视频属性抓取结束
# 开始BV号为1b64y1F7KR视频属性的抓取
# BV号为1b64y1F7KR的视频属性抓取结束
# 开始BV号为1ft4y1S7xn视频属性的抓取
# BV号为1ft4y1S7xn的视频属性抓取结束
# 开始BV号为1Vk4y117u3视频属性的抓取
# BV号为1Vk4y117u3的视频属性抓取结束
# 开始BV号为1J54y1y7wG视频属性的抓取
# BV号为1J54y1y7wG的视频属性抓取结束
# 开始BV号为1ri4y1M7oW视频属性的抓取
# BV号为1ri4y1M7oW的视频属性抓取结束
# 开始BV号为12D4y1o7wC视频属性的抓取
# BV号为12D4y1o7wC的视频属性抓取结束
# 开始BV号为1ot4y1S7iC视频属性的抓取
# BV号为1ot4y1S7iC的视频属性抓取结束
# 开始BV号为1d54y1C7ui视频属性的抓取
# BV号为1d54y1C7ui的视频属性抓取结束
# 开始BV号为1CA411n7nf视频属性的抓取
# BV号为1CA411n7nf的视频属性抓取结束
# 开始BV号为1W5411j7m4视频属性的抓取
# BV号为1W5411j7m4的视频属性抓取结束
# 开始BV号为1ED4y1o74i视频属性的抓取
# BV号为1ED4y1o74i的视频属性抓取结束
# 开始BV号为1ga4y1j7T8视频属性的抓取
# BV号为1ga4y1j7T8的视频属性抓取结束
# 开始BV号为1ZK4y1h7Nx视频属性的抓取
# BV号为1ZK4y1h7Nx的视频属性抓取结束
# 开始BV号为1XK411K7ET视频属性的抓取
# BV号为1XK411K7ET的视频属性抓取结束
# 开始BV号为1Hy4y1k7YT视频属性的抓取
# BV号为1Hy4y1k7YT的视频属性抓取结束
# 开始BV号为1Wp4y1a7Ep视频属性的抓取
# BV号为1Wp4y1a7Ep的视频属性抓取结束
# 开始BV号为12A411E7sj视频属性的抓取
# BV号为12A411E7sj的视频属性抓取结束
# 开始BV号为1AD4y1Z7H4视频属性的抓取
# BV号为1AD4y1Z7H4的视频属性抓取结束
# 开始BV号为18V411m75y视频属性的抓取
# BV号为18V411m75y的视频属性抓取结束
# 开始BV号为1dy4y1y7kJ视频属性的抓取
# BV号为1dy4y1y7kJ的视频属性抓取结束
# 开始BV号为1o5411b7aT视频属性的抓取
# BV号为1o5411b7aT的视频属性抓取结束
# 开始BV号为1CT4y1L7zo视频属性的抓取
# BV号为1CT4y1L7zo的视频属性抓取结束
# 开始BV号为1p54y1v7Lc视频属性的抓取
# BV号为1p54y1v7Lc的视频属性抓取结束
# 开始BV号为1Ha4y1j73C视频属性的抓取
# BV号为1Ha4y1j73C的视频属性抓取结束
# 开始BV号为1uD4y1o79C视频属性的抓取
# BV号为1uD4y1o79C的视频属性抓取结束
# 开始BV号为1ci4y1E7Kv视频属性的抓取
# BV号为1ci4y1E7Kv的视频属性抓取结束
# 开始BV号为1SV411m7iy视频属性的抓取
# BV号为1SV411m7iy的视频属性抓取结束
# 开始BV号为1mZ4y1P79G视频属性的抓取
# BV号为1mZ4y1P79G的视频属性抓取结束
# 开始BV号为1tV41117Pq视频属性的抓取
# BV号为1tV41117Pq的视频属性抓取结束
# 开始BV号为1KV411m7ok视频属性的抓取
# BV号为1KV411m7ok的视频属性抓取结束
# 开始BV号为16Z4y1N7Ng视频属性的抓取
# BV号为16Z4y1N7Ng的视频属性抓取结束
# 开始BV号为1tv411C75H视频属性的抓取
# BV号为1tv411C75H的视频属性抓取结束
# 开始BV号为14v411C7rb视频属性的抓取
# BV号为14v411C7rb的视频属性抓取结束
# 开始BV号为1UZ4y1P7Dj视频属性的抓取
# BV号为1UZ4y1P7Dj的视频属性抓取结束
# 开始BV号为1VT4y1A7ba视频属性的抓取
# BV号为1VT4y1A7ba的视频属性抓取结束
# 开始BV号为1GK411N7vF视频属性的抓取
# BV号为1GK411N7vF的视频属性抓取结束
# 开始BV号为1xt4y1S72o视频属性的抓取
# BV号为1xt4y1S72o的视频属性抓取结束
# 开始BV号为1GK4y1Y71J视频属性的抓取
# BV号为1GK4y1Y71J的视频属性抓取结束
# 开始BV号为1pi4y1u7ko视频属性的抓取
# BV号为1pi4y1u7ko的视频属性抓取结束
# 开始BV号为1354y117FC视频属性的抓取
# BV号为1354y117FC的视频属性抓取结束
# 开始BV号为1AZ4y1K7Wj视频属性的抓取
# BV号为1AZ4y1K7Wj的视频属性抓取结束
# 开始BV号为1YK411P7SC视频属性的抓取
# 开始BV号为1YK411P7SC视频属性的抓取
# BV号为1YK411P7SC的视频属性抓取结束
# 开始BV号为1Lk4y1C7SS视频属性的抓取
# BV号为1Lk4y1C7SS的视频属性抓取结束
# 开始BV号为12v411C79i视频属性的抓取
# BV号为12v411C79i的视频属性抓取结束
# 开始BV号为1B54y1y7ze视频属性的抓取
# BV号为1B54y1y7ze的视频属性抓取结束
# 开始BV号为1qi4y1M7ru视频属性的抓取
# BV号为1qi4y1M7ru的视频属性抓取结束
# 开始BV号为1vA411E7bm视频属性的抓取
# BV号为1vA411E7bm的视频属性抓取结束
# 开始BV号为1UA411E7Hb视频属性的抓取
# BV号为1UA411E7Hb的视频属性抓取结束
# 开始BV号为1iT4y1A7PG视频属性的抓取
# BV号为1iT4y1A7PG的视频属性抓取结束
# 开始BV号为1oi4y1M7ns视频属性的抓取
# BV号为1oi4y1M7ns的视频属性抓取结束
# 开始BV号为1bf4y1D7Gz视频属性的抓取
# BV号为1bf4y1D7Gz的视频属性抓取结束
# 开始BV号为1v54y1C7td视频属性的抓取
# BV号为1v54y1C7td的视频属性抓取结束
# 开始BV号为1DV41127oC视频属性的抓取
# BV号为1DV41127oC的视频属性抓取结束
# 开始BV号为1Qv411C7Zc视频属性的抓取
# BV号为1Qv411C7Zc的视频属性抓取结束
# 开始BV号为1Si4y1M7kh视频属性的抓取
# BV号为1Si4y1M7kh的视频属性抓取结束
# 开始BV号为1H54y1y722视频属性的抓取
# BV号为1H54y1y722的视频属性抓取结束
# 开始BV号为1nV411m7MR视频属性的抓取
# BV号为1nV411m7MR的视频属性抓取结束
# 开始BV号为11f4y1Q7Ht视频属性的抓取
# BV号为11f4y1Q7Ht的视频属性抓取结束
# 开始BV号为1f5411b7Eh视频属性的抓取
# BV号为1f5411b7Eh的视频属性抓取结束
# 开始BV号为1YD4y1o73Z视频属性的抓取
# BV号为1YD4y1o73Z的视频属性抓取结束
# 开始BV号为15T4y1c7mA视频属性的抓取
# BV号为15T4y1c7mA的视频属性抓取结束
# 开始BV号为1sp4y1a7df视频属性的抓取
# BV号为1sp4y1a7df的视频属性抓取结束
# 开始BV号为1hy4y1k7Nn视频属性的抓取
# BV号为1hy4y1k7Nn的视频属性抓取结束
# 开始BV号为1Fi4y1E7JZ视频属性的抓取
# BV号为1Fi4y1E7JZ的视频属性抓取结束
# 开始BV号为1yf4y1Q7dF视频属性的抓取
# BV号为1yf4y1Q7dF的视频属性抓取结束
# 开始BV号为1AV411m7t5视频属性的抓取
# BV号为1AV411m7t5的视频属性抓取结束
# 开始BV号为1rK411P7QB视频属性的抓取
# BV号为1rK411P7QB的视频属性抓取结束
# 开始BV号为1bz4y1Z79F视频属性的抓取
# BV号为1bz4y1Z79F的视频属性抓取结束
# 开始BV号为1op4y1e7CT视频属性的抓取
# BV号为1op4y1e7CT的视频属性抓取结束
# 开始BV号为1FA411H7ii视频属性的抓取
# BV号为1FA411H7ii的视频属性抓取结束
# 开始BV号为1fk4y1C7Z4视频属性的抓取
# BV号为1fk4y1C7Z4的视频属性抓取结束
# 开始BV号为1Jk4y1C7de视频属性的抓取
# BV号为1Jk4y1C7de的视频属性抓取结束
# 开始BV号为1pp4y1Y7ym视频属性的抓取
# BV号为1pp4y1Y7ym的视频属性抓取结束
# 开始BV号为1ZK4y187ve视频属性的抓取
# BV号为1ZK4y187ve的视频属性抓取结束
# 开始BV号为1bz4y1o7AD视频属性的抓取
# 开始BV号为1bz4y1o7AD视频属性的抓取
# BV号为1bz4y1o7AD的视频属性抓取结束
# 开始BV号为11a4y1L76k视频属性的抓取
# BV号为11a4y1L76k的视频属性抓取结束
# 开始BV号为1KD4y197Lg视频属性的抓取
# BV号为1KD4y197Lg的视频属性抓取结束
# 开始BV号为1np4y1k7e5视频属性的抓取
# BV号为1np4y1k7e5的视频属性抓取结束
# 开始BV号为1SA41177fn视频属性的抓取
# BV号为1SA41177fn的视频属性抓取结束
# 开始BV号为1Zk4y1C7jq视频属性的抓取
# BV号为1Zk4y1C7jq的视频属性抓取结束
# 开始BV号为12a4y1L7SK视频属性的抓取
# BV号为12a4y1L7SK的视频属性抓取结束
# 开始BV号为1Fa4y1L7Nf视频属性的抓取
# BV号为1Fa4y1L7Nf的视频属性抓取结束
# 开始BV号为1ov41167ZH视频属性的抓取
# BV号为1ov41167ZH的视频属性抓取结束
# 开始BV号为1z5411j7Vg视频属性的抓取
# BV号为1z5411j7Vg的视频属性抓取结束
# 开始BV号为1F54y1r7zP视频属性的抓取
# BV号为1F54y1r7zP的视频属性抓取结束
# 开始BV号为11v411k7dq视频属性的抓取
# BV号为11v411k7dq的视频属性抓取结束
# 开始BV号为17i4y1j7TC视频属性的抓取
# BV号为17i4y1j7TC的视频属性抓取结束
# 开始BV号为1Q54y167hY视频属性的抓取
# BV号为1Q54y167hY的视频属性抓取结束
# 开始BV号为1QV411y7sV视频属性的抓取
# BV号为1QV411y7sV的视频属性抓取结束
# 开始BV号为1qi4y1j7qv视频属性的抓取
# BV号为1qi4y1j7qv的视频属性抓取结束
# 开始BV号为1R541157wM视频属性的抓取
# BV号为1R541157wM的视频属性抓取结束
# 开始BV号为1py4y1B7gc视频属性的抓取
# BV号为1py4y1B7gc的视频属性抓取结束
# 开始BV号为1gv411C71z视频属性的抓取
# BV号为1gv411C71z的视频属性抓取结束
# 开始BV号为1ua4y1L731视频属性的抓取
# BV号为1ua4y1L731的视频属性抓取结束
# 开始BV号为1GK411A7gk视频属性的抓取
# BV号为1GK411A7gk的视频属性抓取结束
# 开始BV号为1xT4y1w7TN视频属性的抓取
# BV号为1xT4y1w7TN的视频属性抓取结束
# 开始BV号为1Ra4y157b6视频属性的抓取
# BV号为1Ra4y157b6的视频属性抓取结束
# 开始BV号为1Q54y1k7Fm视频属性的抓取
# BV号为1Q54y1k7Fm的视频属性抓取结束
# 开始BV号为1uy4y1z7dd视频属性的抓取
# BV号为1uy4y1z7dd的视频属性抓取结束
# 开始BV号为1wy4y1877f视频属性的抓取
# BV号为1wy4y1877f的视频属性抓取结束
# 开始BV号为1Xa411w7N3视频属性的抓取
# BV号为1Xa411w7N3的视频属性抓取结束
# 开始BV号为1GA411j7L3视频属性的抓取
# BV号为1GA411j7L3的视频属性抓取结束
# 开始BV号为1jA411j7oK视频属性的抓取
# BV号为1jA411j7oK的视频属性抓取结束
# 开始BV号为1ep4y1Y7oe视频属性的抓取
# BV号为1ep4y1Y7oe的视频属性抓取结束
# 开始BV号为1Pp4y1k7rG视频属性的抓取
# BV号为1Pp4y1k7rG的视频属性抓取结束
# 开始BV号为1nK411A7Z2视频属性的抓取
# BV号为1nK411A7Z2的视频属性抓取结束
# 开始BV号为1ki4y1E7Xm视频属性的抓取
# BV号为1ki4y1E7Xm的视频属性抓取结束
# 开始BV号为1x54y1C7As视频属性的抓取
# BV号为1x54y1C7As的视频属性抓取结束
# 开始BV号为1rv411k7DN视频属性的抓取
# BV号为1rv411k7DN的视频属性抓取结束
# 开始BV号为1E54y1r7Sk视频属性的抓取
# BV号为1E54y1r7Sk的视频属性抓取结束
# 开始BV号为1ut4y1e7qH视频属性的抓取
# BV号为1ut4y1e7qH的视频属性抓取结束
# 开始BV号为1Ca411w7hL视频属性的抓取
# BV号为1Ca411w7hL的视频属性抓取结束
# 开始BV号为1mz4y1Z767视频属性的抓取
# BV号为1mz4y1Z767的视频属性抓取结束
# 开始BV号为1XV41117YQ视频属性的抓取
# BV号为1XV41117YQ的视频属性抓取结束
# 开始BV号为1Ma4y1s7QY视频属性的抓取
# BV号为1Ma4y1s7QY的视频属性抓取结束
# 开始BV号为15V4112783视频属性的抓取
# BV号为15V4112783的视频属性抓取结束
# 开始BV号为1vz4y1d7DB视频属性的抓取
# BV号为1vz4y1d7DB的视频属性抓取结束
# 开始BV号为1mi4y1E7R5视频属性的抓取
# BV号为1mi4y1E7R5的视频属性抓取结束
# 开始BV号为1qf4y1i76Q视频属性的抓取
# BV号为1qf4y1i76Q的视频属性抓取结束
# 开始BV号为1Ji4y177Gc视频属性的抓取
# 开始BV号为1Ji4y177Gc视频属性的抓取
# BV号为1Ji4y177Gc的视频属性抓取结束
# 开始BV号为1ma4y1L7hJ视频属性的抓取
# BV号为1ma4y1L7hJ的视频属性抓取结束
# 开始BV号为1Ha4y1L7iS视频属性的抓取
# BV号为1Ha4y1L7iS的视频属性抓取结束
# 开始BV号为1QZ4y1572t视频属性的抓取
# BV号为1QZ4y1572t的视频属性抓取结束
# 开始BV号为1Ya411A7VL视频属性的抓取
# BV号为1Ya411A7VL的视频属性抓取结束
# 开始BV号为1Da411w71B视频属性的抓取
# BV号为1Da411w71B的视频属性抓取结束
# 开始BV号为1TT4y1F79i视频属性的抓取
# BV号为1TT4y1F79i的视频属性抓取结束
# 开始BV号为14h41197pP视频属性的抓取
# BV号为14h41197pP的视频属性抓取结束
# 开始BV号为15t4y1v7U3视频属性的抓取
# BV号为15t4y1v7U3的视频属性抓取结束
# 开始BV号为1mp4y1a7tZ视频属性的抓取
# BV号为1mp4y1a7tZ的视频属性抓取结束
# 开始BV号为1DV411y7AC视频属性的抓取
# BV号为1DV411y7AC的视频属性抓取结束
# 开始BV号为1fp4y1a7mT视频属性的抓取
# BV号为1fp4y1a7mT的视频属性抓取结束
# 开始BV号为18a4y1L7xT视频属性的抓取
# BV号为18a4y1L7xT的视频属性抓取结束
# 开始BV号为1wi4y177b7视频属性的抓取
# BV号为1wi4y177b7的视频属性抓取结束
# 开始BV号为18y4y1B7tr视频属性的抓取
# BV号为18y4y1B7tr的视频属性抓取结束
# 开始BV号为1wt4y1i7bq视频属性的抓取
# BV号为1wt4y1i7bq的视频属性抓取结束
# 开始BV号为1Kk4y1C7Qw视频属性的抓取
# BV号为1Kk4y1C7Qw的视频属性抓取结束
# 开始BV号为1Ey4y1C7n8视频属性的抓取
# BV号为1Ey4y1C7n8的视频属性抓取结束
# 开始BV号为1Hi4y17726视频属性的抓取
# BV号为1Hi4y17726的视频属性抓取结束
# 开始BV号为1tK411N7wP视频属性的抓取
# BV号为1tK411N7wP的视频属性抓取结束
# 开始BV号为1rk4y1C7Po视频属性的抓取
# BV号为1rk4y1C7Po的视频属性抓取结束
# 开始BV号为1Pt4y1i7s4视频属性的抓取
# BV号为1Pt4y1i7s4的视频属性抓取结束
# 开始BV号为12f4y1B77L视频属性的抓取
# BV号为12f4y1B77L的视频属性抓取结束
# 开始BV号为1Lv411C7LB视频属性的抓取
# BV号为1Lv411C7LB的视频属性抓取结束
# 开始BV号为145411L7KM视频属性的抓取
# BV号为145411L7KM的视频属性抓取结束
# 开始BV号为16K4y1h7o7视频属性的抓取
# BV号为16K4y1h7o7的视频属性抓取结束
# 开始BV号为1AD4y197Qj视频属性的抓取
# BV号为1AD4y197Qj的视频属性抓取结束
# 开始BV号为15p4y1k7UN视频属性的抓取
# BV号为15p4y1k7UN的视频属性抓取结束
# 开始BV号为1p5411L71M视频属性的抓取
# BV号为1p5411L71M的视频属性抓取结束
# 开始BV号为1kT4y1c7N7视频属性的抓取
# BV号为1kT4y1c7N7的视频属性抓取结束
# 开始BV号为1eA41177QK视频属性的抓取
# BV号为1eA41177QK的视频属性抓取结束
# 开始BV号为1My4y187Yg视频属性的抓取
# BV号为1My4y187Yg的视频属性抓取结束
# 开始BV号为16k4y1C773视频属性的抓取
# BV号为16k4y1C773的视频属性抓取结束
# 开始BV号为1XK4y1h7ng视频属性的抓取
# BV号为1XK4y1h7ng的视频属性抓取结束
# 开始BV号为12541157Tf视频属性的抓取
# BV号为12541157Tf的视频属性抓取结束
# 开始BV号为1Ny4y187XT视频属性的抓取
# BV号为1Ny4y187XT的视频属性抓取结束
# 开始BV号为18t4y1e7jq视频属性的抓取
# BV号为18t4y1e7jq的视频属性抓取结束
# 开始BV号为1jt4y1v7Eb视频属性的抓取
# BV号为1jt4y1v7Eb的视频属性抓取结束
# 开始BV号为1wA411j7bN视频属性的抓取
# BV号为1wA411j7bN的视频属性抓取结束
# 开始BV号为1Ay4y1873T视频属性的抓取
# BV号为1Ay4y1873T的视频属性抓取结束
# 开始BV号为1Rp4y1a7m4视频属性的抓取
# BV号为1Rp4y1a7m4的视频属性抓取结束
# 开始BV号为1sT4y1F7Cx视频属性的抓取
# BV号为1sT4y1F7Cx的视频属性抓取结束
# 开始BV号为1Xt4y1Y7q7视频属性的抓取
# BV号为1Xt4y1Y7q7的视频属性抓取结束
# 开始BV号为1ei4y177xX视频属性的抓取
# BV号为1ei4y177xX的视频属性抓取结束
# 开始BV号为1vz4y1C7ry视频属性的抓取
# BV号为1vz4y1C7ry的视频属性抓取结束
# 开始BV号为14y4y1C7e4视频属性的抓取
# BV号为14y4y1C7e4的视频属性抓取结束
# 开始BV号为1Ar4y1w7hX视频属性的抓取
# BV号为1Ar4y1w7hX的视频属性抓取结束
# 开始BV号为1Ha411A7Qx视频属性的抓取
# BV号为1Ha411A7Qx的视频属性抓取结束
# 开始BV号为1DA411L7br视频属性的抓取
# BV号为1DA411L7br的视频属性抓取结束
# 开始BV号为1ip4y1Y7RP视频属性的抓取
# BV号为1ip4y1Y7RP的视频属性抓取结束
# 开始BV号为1tZ4y1L7py视频属性的抓取
# BV号为1tZ4y1L7py的视频属性抓取结束
# 2020-12-23 01:34:37.162694

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-30-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_shenghuo_yundong.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月     99   99    99   99   99   99   99   99    99      99   99    99   99
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月   100  100  100  100  100  100   100
# 2月   100  100  100  100  100  100   100
# 3月    99   99   99   99   99   99    99
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月    99   99   99   99   99   99    99
# 7月   100  100  100  100  100  100   100
# 8月   100  100  100  100  100  100   100
# 9月    99   99   99   99   99   99    99

# %%
channel_shenghuo_yundong.to_json('channel_shenghuo_yundong.json')

# 1kk4y1m73Y   9876   159  2247   576   NaN    84    否
# 1c5411h7wz   7189   697  1859   214   288   297    否
# 1nT4y1L7Q2   1.8万   869  4509   869   NaN   730    否
# 1Qk4y117Ay   3279    33   459    49   NaN    31    否
# 1Xh411979r   2194    61   373    32   NaN    22    否
# 1QA411Y7Gk   2.4万  5039  1030  1047   934   684    否
# 1xT4y1j7me   9939   360   501   316   NaN    49    否
# 18h411Z7Tg   1409    56   261   335   295    56    否
# 1yi4y137os   3222   100   236   329   NaN    44    否
# 1zD4y1U7yT   5537   119   666   445   NaN    48    否
# 1qT4y1L7nQ   1469    25   162    16   NaN    28    否
# 1Bv411y7iS   3.6万  2.6万  1.0万  2632   NaN  2782    否
# 1rT4y1w7ix   2.7万  9900  5324   573   NaN  3113    否
# 1vK4y1e7Wk   1.0万  2460  3142  2407   NaN  1626    否
# 1sp4y1v7Rg   4535    16   280   240   189    51    否
# 12z4y1f7dH   2.7万  1.6万  4315   725   NaN  4118    否
# 1L54y1U77H   3043    64   701   548   NaN    72    否
# 1QV411U7Bg   1.3万  5130  1591   334   NaN   188    否
# 17K4y1Y7FH   2.4万  2197   562   894   NaN  1053    否
# 1TA411e7Ke   2722    33   193   141   NaN    40    否
# 1zD4y1U7sL   1.6万   738   323    91   NaN   127    否
# 1fh41197xp   3674    50   245   222   NaN    85    否
# 1Kv411i7EX   1702    12    81   174   490    55    否
# 1Ah411d7sY   3378    18    95    82   NaN    55    否
# 1eT4y1574Y   1.8万  1833  3382   210   NaN   207    否
# 1NT4y1L7Zi   1.6万  2590  5038   352   NaN   140    否
# 1eV411U7wH   4868    95   424   182   NaN   359    否
# 1qK4y1v7r9   1.6万  7971  4634  1410  1157   982    否

# %%
channel_shenghuo_yundong.to_excel('channel_shenghuo_yundong.xlsx')

# %%
channel_shenghuo_yundong
# Out:
#              时间                 发布日期              作者名  作者类型    粉丝数   投稿数  \
# 1HJ411L7DP   1月  2020-01-05 16:04:18          这个世界太太乱     无   6.2万     5
# 1UJ411H7i3   1月  2020-01-10 22:17:01     我永远喜欢西宫硝子jpg  个人认证  10.7万    88
# 1ZJ41157fL   1月  2020-01-04 23:52:48            我是姜鸽鸽     无   3.7万  1352
# 1sJ411b777   1月  2020-01-01 10:42:52      b站buttercup     无   4093    12
# 147411z7Dr   1月  2020-01-29 13:24:50  Livingwallwalls     无    588    14
# ...         ...                  ...              ...   ...    ...   ...
# 1Ar4y1w7hX  10月  2020-10-26 22:11:25           网红关怀计划     无    614    59
# 1Ha411A7Qx  10月  2020-10-27 16:04:55           超神鲸App     无   1.9万  2815
# 1DA411L7br  10月  2020-10-27 20:00:30            XCin_  个人认证  64.4万   589
# 1ip4y1Y7RP  10月  2020-10-17 23:07:32             三代鹿人  个人认证  75.8万    64
# 1tZ4y1L7py  10月  2020-10-16 07:50:06          NBA心晴混剪     无    143    35
#
#                                          视频名  分区 子分区  视频类型  ...  \
# 1HJ411L7DP  健身房的年轻后生不讲武德偷袭马老师，把马保国老师的眼睛给蹭了一下  生活  运动  普通视频  ...
