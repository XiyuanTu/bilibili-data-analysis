# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_shenghuo_qiche=pd.DataFrame(columns=columns)
channel_shenghuo_qiche
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[9]/div/a/span').click()  #选择“生活”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[9]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '生活'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[8]/a').click()  #选择“汽车”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[8]/a').text
sub_channel
# Out:
# '汽车'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(1,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_shenghuo_qiche.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-22 13:16:46.328685
# <ipython-input-12-141e1356cc2f>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-12-141e1356cc2f>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-12-141e1356cc2f>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1e7411r7hr视频属性的抓取
# BV号为1e7411r7hr的视频属性抓取结束
# <ipython-input-12-141e1356cc2f>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1MJ411j7sC视频属性的抓取
# BV号为1MJ411j7sC的视频属性抓取结束
# 开始BV号为1UJ411p7Hc视频属性的抓取
# BV号为1UJ411p7Hc的视频属性抓取结束
# 开始BV号为1bJ411G7vv视频属性的抓取
# BV号为1bJ411G7vv的视频属性抓取结束
# 开始BV号为12J411V7MF视频属性的抓取
# BV号为12J411V7MF的视频属性抓取结束
# 开始BV号为1mJ41157GN视频属性的抓取
# BV号为1mJ41157GN的视频属性抓取结束
# 开始BV号为1FJ411V7oZ视频属性的抓取
# BV号为1FJ411V7oZ的视频属性抓取结束
# 开始BV号为12J411H7kS视频属性的抓取
# BV号为12J411H7kS的视频属性抓取结束
# 开始BV号为1z7411i7Dj视频属性的抓取
# BV号为1z7411i7Dj的视频属性抓取结束
# 开始BV号为18J411L7Sz视频属性的抓取
# BV号为18J411L7Sz的视频属性抓取结束
# 开始BV号为1U7411s73B视频属性的抓取
# BV号为1U7411s73B的视频属性抓取结束
# 开始BV号为1D7411k725视频属性的抓取
# BV号为1D7411k725的视频属性抓取结束
# 开始BV号为1W7411a7CF视频属性的抓取
# BV号为1W7411a7CF的视频属性抓取结束
# 开始BV号为1SJ411V7vL视频属性的抓取
# BV号为1SJ411V7vL的视频属性抓取结束
# 开始BV号为15J411G7Sz视频属性的抓取
# BV号为15J411G7Sz的视频属性抓取结束
# 开始BV号为1eJ411n73o视频属性的抓取
# BV号为1eJ411n73o的视频属性抓取结束
# 开始BV号为1ZJ411b7si视频属性的抓取
# BV号为1ZJ411b7si的视频属性抓取结束
# 开始BV号为1QJ411V74C视频属性的抓取
# BV号为1QJ411V74C的视频属性抓取结束
# 开始BV号为14J411E7x4视频属性的抓取
# BV号为14J411E7x4的视频属性抓取结束
# 开始BV号为1MJ411H76a视频属性的抓取
# BV号为1MJ411H76a的视频属性抓取结束
# 开始BV号为1SJ411b7qt视频属性的抓取
# BV号为1SJ411b7qt的视频属性抓取结束
# 开始BV号为1Y7411a7mg视频属性的抓取
# BV号为1Y7411a7mg的视频属性抓取结束
# 开始BV号为1q7411q7WN视频属性的抓取
# BV号为1q7411q7WN的视频属性抓取结束
# 开始BV号为1cJ411H7KS视频属性的抓取
# BV号为1cJ411H7KS的视频属性抓取结束
# 开始BV号为17J411L78p视频属性的抓取
# BV号为17J411L78p的视频属性抓取结束
# 开始BV号为1Q7411q73A视频属性的抓取
# BV号为1Q7411q73A的视频属性抓取结束
# 开始BV号为1wJ411H7P4视频属性的抓取
# BV号为1wJ411H7P4的视频属性抓取结束
# 开始BV号为1p7411i7g7视频属性的抓取
# BV号为1p7411i7g7的视频属性抓取结束
# 开始BV号为1nJ41177bc视频属性的抓取
# BV号为1nJ41177bc的视频属性抓取结束
# 开始BV号为1H7411679Q视频属性的抓取
# BV号为1H7411679Q的视频属性抓取结束
# 开始BV号为1XJ411G7tM视频属性的抓取
# BV号为1XJ411G7tM的视频属性抓取结束
# 开始BV号为1iJ41177GB视频属性的抓取
# BV号为1iJ41177GB的视频属性抓取结束
# 开始BV号为1YJ41177oy视频属性的抓取
# BV号为1YJ41177oy的视频属性抓取结束
# 开始BV号为1aJ411H7DY视频属性的抓取
# BV号为1aJ411H7DY的视频属性抓取结束
# 开始BV号为1YJ411b78y视频属性的抓取
# BV号为1YJ411b78y的视频属性抓取结束
# 开始BV号为1xJ411V7XK视频属性的抓取
# BV号为1xJ411V7XK的视频属性抓取结束
# 开始BV号为1x7411r7k6视频属性的抓取
# BV号为1x7411r7k6的视频属性抓取结束
# 开始BV号为1RJ411G7kj视频属性的抓取
# BV号为1RJ411G7kj的视频属性抓取结束
# 开始BV号为1BJ411j786视频属性的抓取
# BV号为1BJ411j786的视频属性抓取结束
# 开始BV号为1uJ411V7Ew视频属性的抓取
# BV号为1uJ411V7Ew的视频属性抓取结束
# 开始BV号为1m7411B7H9视频属性的抓取
# BV号为1m7411B7H9的视频属性抓取结束
# 开始BV号为1MJ41187BN视频属性的抓取
# BV号为1MJ41187BN的视频属性抓取结束
# 开始BV号为1SJ411j7sA视频属性的抓取
# BV号为1SJ411j7sA的视频属性抓取结束
# 开始BV号为1JJ41157FD视频属性的抓取
# BV号为1JJ41157FD的视频属性抓取结束
# 开始BV号为1sJ411E7Ut视频属性的抓取
# BV号为1sJ411E7Ut的视频属性抓取结束
# 开始BV号为1iJ411V7KF视频属性的抓取
# BV号为1iJ411V7KF的视频属性抓取结束
# 开始BV号为1tJ411E7Y8视频属性的抓取
# BV号为1tJ411E7Y8的视频属性抓取结束
# 开始BV号为1YJ411j74z视频属性的抓取
# BV号为1YJ411j74z的视频属性抓取结束
# 开始BV号为1HJ41157Qy视频属性的抓取
# BV号为1HJ41157Qy的视频属性抓取结束
# 开始BV号为1yJ411H77L视频属性的抓取
# BV号为1yJ411H77L的视频属性抓取结束
# 开始BV号为1v7411e7nx视频属性的抓取
# BV号为1v7411e7nx的视频属性抓取结束
# 开始BV号为1z7411k78b视频属性的抓取
# BV号为1z7411k78b的视频属性抓取结束
# 开始BV号为1p7411i7HB视频属性的抓取
# BV号为1p7411i7HB的视频属性抓取结束
# 开始BV号为17J41157qV视频属性的抓取
# BV号为17J41157qV的视频属性抓取结束
# 开始BV号为12J411V74E视频属性的抓取
# BV号为12J411V74E的视频属性抓取结束
# 开始BV号为157411e74B视频属性的抓取
# BV号为157411e74B的视频属性抓取结束
# 开始BV号为1YJ411j7qV视频属性的抓取
# BV号为1YJ411j7qV的视频属性抓取结束
# 开始BV号为11J411H7vv视频属性的抓取
# BV号为11J411H7vv的视频属性抓取结束
# 开始BV号为1QJ411G7ep视频属性的抓取
# BV号为1QJ411G7ep的视频属性抓取结束
# 开始BV号为1d7411i7Hd视频属性的抓取
# BV号为1d7411i7Hd的视频属性抓取结束
# 开始BV号为1B7411e7HN视频属性的抓取
# BV号为1B7411e7HN的视频属性抓取结束
# 开始BV号为1UJ411G7go视频属性的抓取
# BV号为1UJ411G7go的视频属性抓取结束
# 开始BV号为1pJ411L7n8视频属性的抓取
# BV号为1pJ411L7n8的视频属性抓取结束
# 开始BV号为1g7411B7zc视频属性的抓取
# BV号为1g7411B7zc的视频属性抓取结束
# 开始BV号为1z7411e7jp视频属性的抓取
# BV号为1z7411e7jp的视频属性抓取结束
# 开始BV号为1i741167Pf视频属性的抓取
# BV号为1i741167Pf的视频属性抓取结束
# 开始BV号为1C7411v7tC视频属性的抓取
# BV号为1C7411v7tC的视频属性抓取结束
# 开始BV号为127411q72S视频属性的抓取
# BV号为127411q72S的视频属性抓取结束
# 开始BV号为1cJ411n7XG视频属性的抓取
# BV号为1cJ411n7XG的视频属性抓取结束
# 开始BV号为1P7411i7Dr视频属性的抓取
# BV号为1P7411i7Dr的视频属性抓取结束
# 开始BV号为1oJ411J75C视频属性的抓取
# BV号为1oJ411J75C的视频属性抓取结束
# 开始BV号为187411Y7gZ视频属性的抓取
# BV号为187411Y7gZ的视频属性抓取结束
# 开始BV号为17J41157TG视频属性的抓取
# BV号为17J41157TG的视频属性抓取结束
# 开始BV号为1iJ411h7jU视频属性的抓取
# BV号为1iJ411h7jU的视频属性抓取结束
# 开始BV号为1DJ411572S视频属性的抓取
# BV号为1DJ411572S的视频属性抓取结束
# 开始BV号为14J411G7JR视频属性的抓取
# BV号为14J411G7JR的视频属性抓取结束
# 开始BV号为1y7411q7Tj视频属性的抓取
# BV号为1y7411q7Tj的视频属性抓取结束
# 开始BV号为1cJ411578t视频属性的抓取
# BV号为1cJ411578t的视频属性抓取结束
# 开始BV号为1K7411C7nP视频属性的抓取
# BV号为1K7411C7nP的视频属性抓取结束
# 开始BV号为1oJ411n76B视频属性的抓取
# BV号为1oJ411n76B的视频属性抓取结束
# 开始BV号为12J411j7jG视频属性的抓取
# BV号为12J411j7jG的视频属性抓取结束
# 开始BV号为1qJ411H7zi视频属性的抓取
# BV号为1qJ411H7zi的视频属性抓取结束
# 开始BV号为1GJ411G7Vz视频属性的抓取
# BV号为1GJ411G7Vz的视频属性抓取结束
# 开始BV号为1qJ411L7Eg视频属性的抓取
# BV号为1qJ411L7Eg的视频属性抓取结束
# 开始BV号为1x7411Y7js视频属性的抓取
# BV号为1x7411Y7js的视频属性抓取结束
# 开始BV号为1k7411e7v4视频属性的抓取
# BV号为1k7411e7v4的视频属性抓取结束
# 开始BV号为1U7411i7kv视频属性的抓取
# BV号为1U7411i7kv的视频属性抓取结束
# 开始BV号为1gJ411V7Qn视频属性的抓取
# BV号为1gJ411V7Qn的视频属性抓取结束
# 开始BV号为1h7411a7oC视频属性的抓取
# BV号为1h7411a7oC的视频属性抓取结束
# 开始BV号为15J411L7Qz视频属性的抓取
# BV号为15J411L7Qz的视频属性抓取结束
# 开始BV号为1eJ411E7LS视频属性的抓取
# BV号为1eJ411E7LS的视频属性抓取结束
# 开始BV号为1Y7411k7gt视频属性的抓取
# BV号为1Y7411k7gt的视频属性抓取结束
# 开始BV号为1SJ411p7Sx视频属性的抓取
# BV号为1SJ411p7Sx的视频属性抓取结束
# 开始BV号为1s7411e7ek视频属性的抓取
# BV号为1s7411e7ek的视频属性抓取结束
# 开始BV号为1ZJ41157iB视频属性的抓取
# BV号为1ZJ41157iB的视频属性抓取结束
# 开始BV号为1tJ411j7R1视频属性的抓取
# BV号为1tJ411j7R1的视频属性抓取结束
# 开始BV号为1JJ411J7Rm视频属性的抓取
# BV号为1JJ411J7Rm的视频属性抓取结束
# 开始BV号为1H7411i7uD视频属性的抓取
# BV号为1H7411i7uD的视频属性抓取结束
# 开始BV号为1k7411v7gi视频属性的抓取
# BV号为1k7411v7gi的视频属性抓取结束
# 开始BV号为1XJ411G7dX视频属性的抓取
# BV号为1XJ411G7dX的视频属性抓取结束
# 开始BV号为1R7411h7Wi视频属性的抓取
# BV号为1R7411h7Wi的视频属性抓取结束
# 开始BV号为1n7411a7ft视频属性的抓取
# BV号为1n7411a7ft的视频属性抓取结束
# 开始BV号为1W741187k9视频属性的抓取
# BV号为1W741187k9的视频属性抓取结束
# 开始BV号为127411j72U视频属性的抓取
# BV号为127411j72U的视频属性抓取结束
# 开始BV号为1L7411g7ux视频属性的抓取
# BV号为1L7411g7ux的视频属性抓取结束
# 开始BV号为177411t7EL视频属性的抓取
# BV号为177411t7EL的视频属性抓取结束
# 开始BV号为1S7411N7vk视频属性的抓取
# BV号为1S7411N7vk的视频属性抓取结束
# 开始BV号为1L7411w7NK视频属性的抓取
# BV号为1L7411w7NK的视频属性抓取结束
# 开始BV号为1s7411M7G6视频属性的抓取
# BV号为1s7411M7G6的视频属性抓取结束
# 开始BV号为1X7411T7aX视频属性的抓取
# BV号为1X7411T7aX的视频属性抓取结束
# 开始BV号为1f741137bF视频属性的抓取
# BV号为1f741137bF的视频属性抓取结束
# 开始BV号为147411N7xW视频属性的抓取
# BV号为147411N7xW的视频属性抓取结束
# 开始BV号为1w7411N7g8视频属性的抓取
# BV号为1w7411N7g8的视频属性抓取结束
# 开始BV号为1Q7411t7mS视频属性的抓取
# BV号为1Q7411t7mS的视频属性抓取结束
# 开始BV号为1R7411j7me视频属性的抓取
# BV号为1R7411j7me的视频属性抓取结束
# 开始BV号为1A7411g7GF视频属性的抓取
# BV号为1A7411g7GF的视频属性抓取结束
# 开始BV号为1C7411t7qJ视频属性的抓取
# BV号为1C7411t7qJ的视频属性抓取结束
# 开始BV号为1X7411w7Wd视频属性的抓取
# BV号为1X7411w7Wd的视频属性抓取结束
# 开始BV号为1aE411H7z5视频属性的抓取
# BV号为1aE411H7z5的视频属性抓取结束
# 开始BV号为1B7411878r视频属性的抓取
# BV号为1B7411878r的视频属性抓取结束
# 开始BV号为1f7411b7JH视频属性的抓取
# BV号为1f7411b7JH的视频属性抓取结束
# 开始BV号为1t7411u7qg视频属性的抓取
# BV号为1t7411u7qg的视频属性抓取结束
# 开始BV号为1K7411w77R视频属性的抓取
# BV号为1K7411w77R的视频属性抓取结束
# 开始BV号为1P7411t7DM视频属性的抓取
# BV号为1P7411t7DM的视频属性抓取结束
# 开始BV号为167411x7XX视频属性的抓取
# BV号为167411x7XX的视频属性抓取结束
# 开始BV号为157411u7ZK视频属性的抓取
# BV号为157411u7ZK的视频属性抓取结束
# 开始BV号为1t7411G7u6视频属性的抓取
# BV号为1t7411G7u6的视频属性抓取结束
# 开始BV号为1m7411g7ms视频属性的抓取
# BV号为1m7411g7ms的视频属性抓取结束
# 开始BV号为1K7411t7Ue视频属性的抓取
# BV号为1K7411t7Ue的视频属性抓取结束
# 开始BV号为1Z7411u73m视频属性的抓取
# BV号为1Z7411u73m的视频属性抓取结束
# 开始BV号为127411V7Hh视频属性的抓取
# BV号为127411V7Hh的视频属性抓取结束
# 开始BV号为1d7411K7c4视频属性的抓取
# BV号为1d7411K7c4的视频属性抓取结束
# 开始BV号为1J7411F723视频属性的抓取
# BV号为1J7411F723的视频属性抓取结束
# 开始BV号为1z7411W752视频属性的抓取
# BV号为1z7411W752的视频属性抓取结束
# 开始BV号为1c741137qj视频属性的抓取
# BV号为1c741137qj的视频属性抓取结束
# 开始BV号为1j7411H7k4视频属性的抓取
# BV号为1j7411H7k4的视频属性抓取结束
# 开始BV号为1f7411M7bg视频属性的抓取
# BV号为1f7411M7bg的视频属性抓取结束
# 开始BV号为1o7411A7mR视频属性的抓取
# BV号为1o7411A7mR的视频属性抓取结束
# 开始BV号为1pE411H7kh视频属性的抓取
# BV号为1pE411H7kh的视频属性抓取结束
# 开始BV号为187411j7Fm视频属性的抓取
# BV号为187411j7Fm的视频属性抓取结束
# 开始BV号为1T7411W7YU视频属性的抓取
# BV号为1T7411W7YU的视频属性抓取结束
# 开始BV号为1Z7411b7CA视频属性的抓取
# BV号为1Z7411b7CA的视频属性抓取结束
# 开始BV号为1D7411V7Ga视频属性的抓取
# BV号为1D7411V7Ga的视频属性抓取结束
# 开始BV号为177411a7yv视频属性的抓取
# BV号为177411a7yv的视频属性抓取结束
# 开始BV号为1M7411p7Nq视频属性的抓取
# BV号为1M7411p7Nq的视频属性抓取结束
# 开始BV号为1AE411J7ew视频属性的抓取
# BV号为1AE411J7ew的视频属性抓取结束
# 开始BV号为1oE411n7mx视频属性的抓取
# BV号为1oE411n7mx的视频属性抓取结束
# 开始BV号为1e741157bJ视频属性的抓取
# BV号为1e741157bJ的视频属性抓取结束
# 开始BV号为1K7411x7GE视频属性的抓取
# BV号为1K7411x7GE的视频属性抓取结束
# 开始BV号为1J7411x78a视频属性的抓取
# BV号为1J7411x78a的视频属性抓取结束
# 开始BV号为1q7411M7wn视频属性的抓取
# BV号为1q7411M7wn的视频属性抓取结束
# 开始BV号为197411P7P5视频属性的抓取
# BV号为197411P7P5的视频属性抓取结束
# 开始BV号为1N7411n7qY视频属性的抓取
# BV号为1N7411n7qY的视频属性抓取结束
# 开始BV号为1M7411P7C2视频属性的抓取
# BV号为1M7411P7C2的视频属性抓取结束
# 开始BV号为1N7411b78E视频属性的抓取
# BV号为1N7411b78E的视频属性抓取结束
# 开始BV号为1k7411x7Uw视频属性的抓取
# BV号为1k7411x7Uw的视频属性抓取结束
# 开始BV号为1L7411x7Au视频属性的抓取
# BV号为1L7411x7Au的视频属性抓取结束
# 开始BV号为1a7411j7TP视频属性的抓取
# BV号为1a7411j7TP的视频属性抓取结束
# 开始BV号为1A7411M7UW视频属性的抓取
# BV号为1A7411M7UW的视频属性抓取结束
# 开始BV号为1a7411J73F视频属性的抓取
# BV号为1a7411J73F的视频属性抓取结束
# 开始BV号为1N7411W7Cr视频属性的抓取
# BV号为1N7411W7Cr的视频属性抓取结束
# 开始BV号为1LE411H7uD视频属性的抓取
# BV号为1LE411H7uD的视频属性抓取结束
# 开始BV号为117411u72F视频属性的抓取
# BV号为117411u72F的视频属性抓取结束
# 开始BV号为1K7411V7mV视频属性的抓取
# BV号为1K7411V7mV的视频属性抓取结束
# 开始BV号为1yE411n7Q4视频属性的抓取
# BV号为1yE411n7Q4的视频属性抓取结束
# 开始BV号为1n7411378P视频属性的抓取
# BV号为1n7411378P的视频属性抓取结束
# 开始BV号为167411776Y视频属性的抓取
# BV号为167411776Y的视频属性抓取结束
# 开始BV号为1d741177So视频属性的抓取
# BV号为1d741177So的视频属性抓取结束
# 开始BV号为1Z7411g7Qw视频属性的抓取
# BV号为1Z7411g7Qw的视频属性抓取结束
# 开始BV号为1U7411c7Ej视频属性的抓取
# BV号为1U7411c7Ej的视频属性抓取结束
# 开始BV号为1n7411E7xP视频属性的抓取
# BV号为1n7411E7xP的视频属性抓取结束
# 开始BV号为1e741137fu视频属性的抓取
# BV号为1e741137fu的视频属性抓取结束
# 开始BV号为1y7411A7ky视频属性的抓取
# BV号为1y7411A7ky的视频属性抓取结束
# 开始BV号为1d741187Uk视频属性的抓取
# BV号为1d741187Uk的视频属性抓取结束
# 开始BV号为15741137aW视频属性的抓取
# BV号为15741137aW的视频属性抓取结束
# 开始BV号为1f7411s7AD视频属性的抓取
# BV号为1f7411s7AD的视频属性抓取结束
# 开始BV号为197411J7fi视频属性的抓取
# BV号为197411J7fi的视频属性抓取结束
# 开始BV号为1J7411M7zU视频属性的抓取
# BV号为1J7411M7zU的视频属性抓取结束
# 开始BV号为1Z7411L7jQ视频属性的抓取
# BV号为1Z7411L7jQ的视频属性抓取结束
# 开始BV号为1n7411G7x9视频属性的抓取
# BV号为1n7411G7x9的视频属性抓取结束
# 开始BV号为1X7411h7pq视频属性的抓取
# BV号为1X7411h7pq的视频属性抓取结束
# 开始BV号为1N7411N7Vg视频属性的抓取
# BV号为1N7411N7Vg的视频属性抓取结束
# 开始BV号为1r7411L7BL视频属性的抓取
# BV号为1r7411L7BL的视频属性抓取结束
# 开始BV号为1o741147eo视频属性的抓取
# BV号为1o741147eo的视频属性抓取结束
# 开始BV号为1fj411f77F视频属性的抓取
# BV号为1fj411f77F的视频属性抓取结束
# 开始BV号为1E7411P7GA视频属性的抓取
# BV号为1E7411P7GA的视频属性抓取结束
# 开始BV号为1u7411t7RZ视频属性的抓取
# BV号为1u7411t7RZ的视频属性抓取结束
# 开始BV号为1M7411W7nV视频属性的抓取
# BV号为1M7411W7nV的视频属性抓取结束
# 开始BV号为197411b7kN视频属性的抓取
# BV号为197411b7kN的视频属性抓取结束
# 开始BV号为1W7411e7HE视频属性的抓取
# BV号为1W7411e7HE的视频属性抓取结束
# 开始BV号为1n741187T7视频属性的抓取
# BV号为1n741187T7的视频属性抓取结束
# 开始BV号为1V7411u7uT视频属性的抓取
# BV号为1V7411u7uT的视频属性抓取结束
# 开始BV号为1t7411s7WR视频属性的抓取
# BV号为1t7411s7WR的视频属性抓取结束
# 开始BV号为1p7411E75t视频属性的抓取
# BV号为1p7411E75t的视频属性抓取结束
# 开始BV号为1D741147Ry视频属性的抓取
# BV号为1D741147Ry的视频属性抓取结束
# 开始BV号为1a7411w7Gs视频属性的抓取
# BV号为1a7411w7Gs的视频属性抓取结束
# 开始BV号为137411g79b视频属性的抓取
# BV号为137411g79b的视频属性抓取结束
# 开始BV号为1t741177RX视频属性的抓取
# BV号为1t741177RX的视频属性抓取结束
# 开始BV号为157411E7VY视频属性的抓取
# BV号为157411E7VY的视频属性抓取结束
# 开始BV号为1J7411b7T6视频属性的抓取
# BV号为1J7411b7T6的视频属性抓取结束
# 开始BV号为12E411p7gR视频属性的抓取
# BV号为12E411p7gR的视频属性抓取结束
# 开始BV号为157411Q7wE视频属性的抓取
# BV号为157411Q7wE的视频属性抓取结束
# 开始BV号为1bE411s7sp视频属性的抓取
# BV号为1bE411s7sp的视频属性抓取结束
# 开始BV号为1EE411x7cc视频属性的抓取
# BV号为1EE411x7cc的视频属性抓取结束
# 开始BV号为1gE411771T视频属性的抓取
# BV号为1gE411771T的视频属性抓取结束
# 开始BV号为1ai4y1b7oE视频属性的抓取
# BV号为1ai4y1b7oE的视频属性抓取结束
# 开始BV号为14E411s7xx视频属性的抓取
# BV号为14E411s7xx的视频属性抓取结束
# 开始BV号为11E411N7Yu视频属性的抓取
# BV号为11E411N7Yu的视频属性抓取结束
# 开始BV号为1rE411A74B视频属性的抓取
# BV号为1rE411A74B的视频属性抓取结束
# 开始BV号为1yE411p77U视频属性的抓取
# BV号为1yE411p77U的视频属性抓取结束
# 开始BV号为1kE41157MQ视频属性的抓取
# BV号为1kE41157MQ的视频属性抓取结束
# 开始BV号为1MV411f7Kt视频属性的抓取
# BV号为1MV411f7Kt的视频属性抓取结束
# 开始BV号为1A5411r7ps视频属性的抓取
# BV号为1A5411r7ps的视频属性抓取结束
# 开始BV号为1yE411A7Zc视频属性的抓取
# BV号为1yE411A7Zc的视频属性抓取结束
# 开始BV号为1X7411Z7yz视频属性的抓取
# BV号为1X7411Z7yz的视频属性抓取结束
# 开始BV号为1s7411Z7dF视频属性的抓取
# BV号为1s7411Z7dF的视频属性抓取结束
# 开始BV号为14E411K7Bi视频属性的抓取
# BV号为14E411K7Bi的视频属性抓取结束
# 开始BV号为1iE411G71d视频属性的抓取
# BV号为1iE411G71d的视频属性抓取结束
# 开始BV号为1sE411g7pw视频属性的抓取
# BV号为1sE411g7pw的视频属性抓取结束
# 开始BV号为117411o7xM视频属性的抓取
# BV号为117411o7xM的视频属性抓取结束
# 开始BV号为1E741117C9视频属性的抓取
# BV号为1E741117C9的视频属性抓取结束
# 开始BV号为1EE411p77W视频属性的抓取
# BV号为1EE411p77W的视频属性抓取结束
# 开始BV号为1R7411d7Dd视频属性的抓取
# BV号为1R7411d7Dd的视频属性抓取结束
# 开始BV号为15Z4y1j7s8视频属性的抓取
# BV号为15Z4y1j7s8的视频属性抓取结束
# 开始BV号为1cE41157rv视频属性的抓取
# BV号为1cE41157rv的视频属性抓取结束
# 开始BV号为1Rk4y1d7tc视频属性的抓取
# BV号为1Rk4y1d7tc的视频属性抓取结束
# 开始BV号为11E411T7L7视频属性的抓取
# BV号为11E411T7L7的视频属性抓取结束
# 开始BV号为1mE411W7TF视频属性的抓取
# BV号为1mE411W7TF的视频属性抓取结束
# 开始BV号为1UE411K7po视频属性的抓取
# BV号为1UE411K7po的视频属性抓取结束
# 开始BV号为1m7411X7Dy视频属性的抓取
# BV号为1m7411X7Dy的视频属性抓取结束
# 开始BV号为1w7411D7t2视频属性的抓取
# BV号为1w7411D7t2的视频属性抓取结束
# 开始BV号为1F741117kM视频属性的抓取
# BV号为1F741117kM的视频属性抓取结束
# 开始BV号为1nE411A7pk视频属性的抓取
# BV号为1nE411A7pk的视频属性抓取结束
# 开始BV号为1Ha4y1t7eU视频属性的抓取
# BV号为1Ha4y1t7eU的视频属性抓取结束
# 开始BV号为1YZ4y1j77i视频属性的抓取
# BV号为1YZ4y1j77i的视频属性抓取结束
# 开始BV号为1n741117bb视频属性的抓取
# BV号为1n741117bb的视频属性抓取结束
# 开始BV号为1WE41157jH视频属性的抓取
# BV号为1WE41157jH的视频属性抓取结束
# 开始BV号为18E411p7Xw视频属性的抓取
# BV号为18E411p7Xw的视频属性抓取结束
# 开始BV号为1XE411G7aC视频属性的抓取
# BV号为1XE411G7aC的视频属性抓取结束
# 开始BV号为1Gz411b7eG视频属性的抓取
# BV号为1Gz411b7eG的视频属性抓取结束
# 开始BV号为1rE411G7vd视频属性的抓取
# BV号为1rE411G7vd的视频属性抓取结束
# 开始BV号为1nE411n7Jk视频属性的抓取
# BV号为1nE411n7Jk的视频属性抓取结束
# 开始BV号为1GE411N7K9视频属性的抓取
# BV号为1GE411N7K9的视频属性抓取结束
# 开始BV号为1xT4y157Y7视频属性的抓取
# BV号为1xT4y157Y7的视频属性抓取结束
# 开始BV号为1r54y1R7RU视频属性的抓取
# BV号为1r54y1R7RU的视频属性抓取结束
# 开始BV号为1TC4y1s76t视频属性的抓取
# BV号为1TC4y1s76t的视频属性抓取结束
# 开始BV号为1xE41177ff视频属性的抓取
# BV号为1xE41177ff的视频属性抓取结束
# 开始BV号为1mE411s7vW视频属性的抓取
# BV号为1mE411s7vW的视频属性抓取结束
# 开始BV号为1WE411N7ee视频属性的抓取
# BV号为1WE411N7ee的视频属性抓取结束
# 开始BV号为1jE411p7Hi视频属性的抓取
# BV号为1jE411p7Hi的视频属性抓取结束
# 开始BV号为1tE41157SH视频属性的抓取
# BV号为1tE41157SH的视频属性抓取结束
# 开始BV号为16E411G7Jn视频属性的抓取
# BV号为16E411G7Jn的视频属性抓取结束
# 开始BV号为1AE41177F5视频属性的抓取
# BV号为1AE41177F5的视频属性抓取结束
# 开始BV号为1nE411G7so视频属性的抓取
# BV号为1nE411G7so的视频属性抓取结束
# 开始BV号为1rp4y117wD视频属性的抓取
# BV号为1rp4y117wD的视频属性抓取结束
# 开始BV号为1dE411w7ho视频属性的抓取
# BV号为1dE411w7ho的视频属性抓取结束
# 开始BV号为1H7411C7Jy视频属性的抓取
# BV号为1H7411C7Jy的视频属性抓取结束
# 开始BV号为19k4y1d7NR视频属性的抓取
# BV号为19k4y1d7NR的视频属性抓取结束
# 开始BV号为1CE411w7HS视频属性的抓取
# BV号为1CE411w7HS的视频属性抓取结束
# 开始BV号为1QE411P7KE视频属性的抓取
# BV号为1QE411P7KE的视频属性抓取结束
# 开始BV号为1iE411w7ry视频属性的抓取
# BV号为1iE411w7ry的视频属性抓取结束
# 开始BV号为1dE411u75m视频属性的抓取
# BV号为1dE411u75m的视频属性抓取结束
# 开始BV号为1AE411p788视频属性的抓取
# BV号为1AE411p788的视频属性抓取结束
# 开始BV号为1xa4y1t7dP视频属性的抓取
# BV号为1xa4y1t7dP的视频属性抓取结束
# 开始BV号为1UE41157sE视频属性的抓取
# BV号为1UE41157sE的视频属性抓取结束
# 开始BV号为177411d7k5视频属性的抓取
# BV号为177411d7k5的视频属性抓取结束
# 开始BV号为1a7411d7Bd视频属性的抓取
# BV号为1a7411d7Bd的视频属性抓取结束
# <ipython-input-12-141e1356cc2f>:190: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1rE411j7RF视频属性的抓取
# BV号为1rE411j7RF的视频属性抓取结束
# 开始BV号为1EE411c7V5视频属性的抓取
# BV号为1EE411c7V5的视频属性抓取结束
# 开始BV号为1hC4y147iT视频属性的抓取
# BV号为1hC4y147iT的视频属性抓取结束
# 开始BV号为17E411p7Yw视频属性的抓取
# BV号为17E411p7Yw的视频属性抓取结束
# 开始BV号为16E411x7Py视频属性的抓取
# BV号为16E411x7Py的视频属性抓取结束
# 开始BV号为1g741127cS视频属性的抓取
# BV号为1g741127cS的视频属性抓取结束
# 开始BV号为1oE411p7r8视频属性的抓取
# BV号为1oE411p7r8的视频属性抓取结束
# 开始BV号为1gE411K77Y视频属性的抓取
# BV号为1gE411K77Y的视频属性抓取结束
# 开始BV号为1tE411L75o视频属性的抓取
# BV号为1tE411L75o的视频属性抓取结束
# 开始BV号为1YE41147HV视频属性的抓取
# BV号为1YE41147HV的视频属性抓取结束
# 开始BV号为1uA411h7dX视频属性的抓取
# BV号为1uA411h7dX的视频属性抓取结束
# 开始BV号为1AE411x7YV视频属性的抓取
# BV号为1AE411x7YV的视频属性抓取结束
# 开始BV号为1vE411j7Sm视频属性的抓取
# BV号为1vE411j7Sm的视频属性抓取结束
# 开始BV号为16i4y1b73o视频属性的抓取
# BV号为16i4y1b73o的视频属性抓取结束
# 开始BV号为1H7411f7Dr视频属性的抓取
# BV号为1H7411f7Dr的视频属性抓取结束
# 开始BV号为1jE411L7mS视频属性的抓取
# BV号为1jE411L7mS的视频属性抓取结束
# 开始BV号为1EE411c7xV视频属性的抓取
# BV号为1EE411c7xV的视频属性抓取结束
# 开始BV号为1j7411C7jR视频属性的抓取
# BV号为1j7411C7jR的视频属性抓取结束
# 开始BV号为1iE411V7aa视频属性的抓取
# BV号为1iE411V7aa的视频属性抓取结束
# 开始BV号为1fE411j7zh视频属性的抓取
# BV号为1fE411j7zh的视频属性抓取结束
# 开始BV号为14E411u7FL视频属性的抓取
# BV号为14E411u7FL的视频属性抓取结束
# 开始BV号为12E41137nE视频属性的抓取
# BV号为12E41137nE的视频属性抓取结束
# 开始BV号为1iE411P7bh视频属性的抓取
# BV号为1iE411P7bh的视频属性抓取结束
# 开始BV号为1tE41147L5视频属性的抓取
# BV号为1tE41147L5的视频属性抓取结束
# 开始BV号为1X7411m71Z视频属性的抓取
# BV号为1X7411m71Z的视频属性抓取结束
# 开始BV号为1g7411m7D3视频属性的抓取
# BV号为1g7411m7D3的视频属性抓取结束
# 开始BV号为1Ne411x7a9视频属性的抓取
# BV号为1Ne411x7a9的视频属性抓取结束
# 开始BV号为1nE411P76o视频属性的抓取
# BV号为1nE411P76o的视频属性抓取结束
# 开始BV号为1rE411g7rX视频属性的抓取
# BV号为1rE411g7rX的视频属性抓取结束
# 开始BV号为1Kz411b7vS视频属性的抓取
# BV号为1Kz411b7vS的视频属性抓取结束
# 开始BV号为1jE411A7At视频属性的抓取
# BV号为1jE411A7At的视频属性抓取结束
# 开始BV号为1SE411A7WL视频属性的抓取
# BV号为1SE411A7WL的视频属性抓取结束
# 开始BV号为1xA411b7RA视频属性的抓取
# BV号为1xA411b7RA的视频属性抓取结束
# 开始BV号为1h64y1T71i视频属性的抓取
# BV号为1h64y1T71i的视频属性抓取结束
# 开始BV号为1Ha4y1x7d1视频属性的抓取
# BV号为1Ha4y1x7d1的视频属性抓取结束
# 开始BV号为16A41147BY视频属性的抓取
# BV号为16A41147BY的视频属性抓取结束
# 开始BV号为1Qt4y127KL视频属性的抓取
# BV号为1Qt4y127KL的视频属性抓取结束
# 开始BV号为1tA411b743视频属性的抓取
# BV号为1tA411b743的视频属性抓取结束
# 开始BV号为1Kt4y1U72w视频属性的抓取
# BV号为1Kt4y1U72w的视频属性抓取结束
# 开始BV号为1gT4y1V7dr视频属性的抓取
# BV号为1gT4y1V7dr的视频属性抓取结束
# 开始BV号为1df4y1U7mZ视频属性的抓取
# BV号为1df4y1U7mZ的视频属性抓取结束
# 开始BV号为1o5411x7e1视频属性的抓取
# BV号为1o5411x7e1的视频属性抓取结束
# 开始BV号为1x64y1M7Ab视频属性的抓取
# BV号为1x64y1M7Ab的视频属性抓取结束
# 开始BV号为1nK4y1r7TR视频属性的抓取
# BV号为1nK4y1r7TR的视频属性抓取结束
# 开始BV号为1LQ4y1K7XG视频属性的抓取
# BV号为1LQ4y1K7XG的视频属性抓取结束
# 开始BV号为1xT4y157Am视频属性的抓取
# BV号为1xT4y157Am的视频属性抓取结束
# 开始BV号为1kK4y1b7sd视频属性的抓取
# BV号为1kK4y1b7sd的视频属性抓取结束
# 开始BV号为1Gz41187ss视频属性的抓取
# BV号为1Gz41187ss的视频属性抓取结束
# 开始BV号为1oQ4y1P7hy视频属性的抓取
# BV号为1oQ4y1P7hy的视频属性抓取结束
# 开始BV号为1gA411b7sJ视频属性的抓取
# BV号为1gA411b7sJ的视频属性抓取结束
# 开始BV号为1Ez411z7AZ视频属性的抓取
# BV号为1Ez411z7AZ的视频属性抓取结束
# 开始BV号为1xQ4y1T7yu视频属性的抓取
# BV号为1xQ4y1T7yu的视频属性抓取结束
# 开始BV号为1R5411t7YL视频属性的抓取
# BV号为1R5411t7YL的视频属性抓取结束
# 开始BV号为1FT4y1377W视频属性的抓取
# BV号为1FT4y1377W的视频属性抓取结束
# 开始BV号为1fK4y1C7j6视频属性的抓取
# BV号为1fK4y1C7j6的视频属性抓取结束
# 开始BV号为1AK4y1k77a视频属性的抓取
# BV号为1AK4y1k77a的视频属性抓取结束
# 开始BV号为11k4y1d7dN视频属性的抓取
# BV号为11k4y1d7dN的视频属性抓取结束
# 开始BV号为1vp4y1C76s视频属性的抓取
# BV号为1vp4y1C76s的视频属性抓取结束
# 开始BV号为1Xi4y1t7Fk视频属性的抓取
# BV号为1Xi4y1t7Fk的视频属性抓取结束
# 开始BV号为1s64y1T71J视频属性的抓取
# BV号为1s64y1T71J的视频属性抓取结束
# 开始BV号为1nt4y1U7Z4视频属性的抓取
# BV号为1nt4y1U7Z4的视频属性抓取结束
# 开始BV号为1t54y197vR视频属性的抓取
# BV号为1t54y197vR的视频属性抓取结束
# 开始BV号为1Si4y1t71T视频属性的抓取
# BV号为1Si4y1t71T的视频属性抓取结束
# 开始BV号为1DK411V7No视频属性的抓取
# BV号为1DK411V7No的视频属性抓取结束
# 开始BV号为1EK411L7kZ视频属性的抓取
# BV号为1EK411L7kZ的视频属性抓取结束
# 开始BV号为1C64y1u72U视频属性的抓取
# BV号为1C64y1u72U的视频属性抓取结束
# 开始BV号为1GC4y1W7pM视频属性的抓取
# BV号为1GC4y1W7pM的视频属性抓取结束
# 开始BV号为1y54y1971X视频属性的抓取
# BV号为1y54y1971X的视频属性抓取结束
# 开始BV号为1wC4y1x7oV视频属性的抓取
# BV号为1wC4y1x7oV的视频属性抓取结束
# 开始BV号为1uz411b77x视频属性的抓取
# BV号为1uz411b77x的视频属性抓取结束
# 开始BV号为15Q4y1N7wu视频属性的抓取
# BV号为15Q4y1N7wu的视频属性抓取结束
# 开始BV号为1GQ4y1M7Vn视频属性的抓取
# BV号为1GQ4y1M7Vn的视频属性抓取结束
# 开始BV号为1AZ4y1s7xU视频属性的抓取
# BV号为1AZ4y1s7xU的视频属性抓取结束
# 开始BV号为1bK41157Cx视频属性的抓取
# BV号为1bK41157Cx的视频属性抓取结束
# 开始BV号为1xV411o7NU视频属性的抓取
# BV号为1xV411o7NU的视频属性抓取结束
# 开始BV号为19i4y1t7ZN视频属性的抓取
# BV号为19i4y1t7ZN的视频属性抓取结束
# 开始BV号为1jK411L7fi视频属性的抓取
# BV号为1jK411L7fi的视频属性抓取结束
# 开始BV号为1Z64y1u7vw视频属性的抓取
# BV号为1Z64y1u7vw的视频属性抓取结束
# 开始BV号为1WK4y1k7hp视频属性的抓取
# BV号为1WK4y1k7hp的视频属性抓取结束
# 开始BV号为1MQ4y1T7cN视频属性的抓取
# BV号为1MQ4y1T7cN的视频属性抓取结束
# 开始BV号为1Hi4y187RY视频属性的抓取
# BV号为1Hi4y187RY的视频属性抓取结束
# 开始BV号为1DZ4y1j7RX视频属性的抓取
# BV号为1DZ4y1j7RX的视频属性抓取结束
# 开始BV号为1Xc411h7S1视频属性的抓取
# BV号为1Xc411h7S1的视频属性抓取结束
# 开始BV号为1V54y1R7BE视频属性的抓取
# BV号为1V54y1R7BE的视频属性抓取结束
# 开始BV号为12c411h7kB视频属性的抓取
# BV号为12c411h7kB的视频属性抓取结束
# 开始BV号为1HQ4y1T7Bu视频属性的抓取
# BV号为1HQ4y1T7Bu的视频属性抓取结束
# 开始BV号为1Wa4y1x7ds视频属性的抓取
# BV号为1Wa4y1x7ds的视频属性抓取结束
# 开始BV号为1FQ4y1M7QA视频属性的抓取
# BV号为1FQ4y1M7QA的视频属性抓取结束
# 开始BV号为1WK411L7rz视频属性的抓取
# BV号为1WK411L7rz的视频属性抓取结束
# 开始BV号为1r54y1Q7on视频属性的抓取
# BV号为1r54y1Q7on的视频属性抓取结束
# 开始BV号为1TK41157vM视频属性的抓取
# BV号为1TK41157vM的视频属性抓取结束
# 开始BV号为1DK411V7i1视频属性的抓取
# BV号为1DK411V7i1的视频属性抓取结束
# 开始BV号为1he411x7h9视频属性的抓取
# BV号为1he411x7h9的视频属性抓取结束
# 开始BV号为1vK4y1k7Xk视频属性的抓取
# BV号为1vK4y1k7Xk的视频属性抓取结束
# 开始BV号为1DZ4y1j7QK视频属性的抓取
# BV号为1DZ4y1j7QK的视频属性抓取结束
# 开始BV号为1EC4y1s7ez视频属性的抓取
# BV号为1EC4y1s7ez的视频属性抓取结束
# 开始BV号为1ip4y1172E视频属性的抓取
# BV号为1ip4y1172E的视频属性抓取结束
# 开始BV号为1ea4y1x7i2视频属性的抓取
# BV号为1ea4y1x7i2的视频属性抓取结束
# 开始BV号为1i54y1Q7A5视频属性的抓取
# BV号为1i54y1Q7A5的视频属性抓取结束
# 开始BV号为1ti4y187nH视频属性的抓取
# BV号为1ti4y187nH的视频属性抓取结束
# 开始BV号为1u64y1u7SL视频属性的抓取
# BV号为1u64y1u7SL的视频属性抓取结束
# 开始BV号为1Nz411872c视频属性的抓取
# BV号为1Nz411872c的视频属性抓取结束
# 开始BV号为1FQ4y1M7RV视频属性的抓取
# BV号为1FQ4y1M7RV的视频属性抓取结束
# 开始BV号为1iK41177DB视频属性的抓取
# BV号为1iK41177DB的视频属性抓取结束
# 开始BV号为1mk4y197gy视频属性的抓取
# BV号为1mk4y197gy的视频属性抓取结束
# 开始BV号为1cV411Z7ni视频属性的抓取
# BV号为1cV411Z7ni的视频属性抓取结束
# 开始BV号为1Qg4y187j2视频属性的抓取
# BV号为1Qg4y187j2的视频属性抓取结束
# 开始BV号为18e411s7Aj视频属性的抓取
# BV号为18e411s7Aj的视频属性抓取结束
# 开始BV号为1Ua4y1x7r6视频属性的抓取
# BV号为1Ua4y1x7r6的视频属性抓取结束
# 开始BV号为1kp4y1C7Fj视频属性的抓取
# BV号为1kp4y1C7Fj的视频属性抓取结束
# 开始BV号为1Ni4y1878m视频属性的抓取
# BV号为1Ni4y1878m的视频属性抓取结束
# 开始BV号为1Zk4y197Kr视频属性的抓取
# BV号为1Zk4y197Kr的视频属性抓取结束
# 开始BV号为1et4y1273v视频属性的抓取
# BV号为1et4y1273v的视频属性抓取结束
# 开始BV号为14a4y147Sx视频属性的抓取
# BV号为14a4y147Sx的视频属性抓取结束
# 开始BV号为1Mp4y1y76Y视频属性的抓取
# BV号为1Mp4y1y76Y的视频属性抓取结束
# 开始BV号为1ht4y1U7Rq视频属性的抓取
# BV号为1ht4y1U7Rq的视频属性抓取结束
# 开始BV号为16Q4y1K7rn视频属性的抓取
# BV号为16Q4y1K7rn的视频属性抓取结束
# 开始BV号为15K4y1b7Lu视频属性的抓取
# BV号为15K4y1b7Lu的视频属性抓取结束
# 开始BV号为1aK4y1k71J视频属性的抓取
# BV号为1aK4y1k71J的视频属性抓取结束
# 开始BV号为1Z64y1M7cM视频属性的抓取
# BV号为1Z64y1M7cM的视频属性抓取结束
# 开始BV号为17p4y197qw视频属性的抓取
# BV号为17p4y197qw的视频属性抓取结束
# 开始BV号为1Sk4y1R7k7视频属性的抓取
# BV号为1Sk4y1R7k7的视频属性抓取结束
# 开始BV号为1Ri4y1t7ii视频属性的抓取
# BV号为1Ri4y1t7ii的视频属性抓取结束
# 开始BV号为1hA411b7ZB视频属性的抓取
# BV号为1hA411b7ZB的视频属性抓取结束
# 开始BV号为1sQ4y1K79T视频属性的抓取
# BV号为1sQ4y1K79T的视频属性抓取结束
# 开始BV号为1CK411V7EQ视频属性的抓取
# BV号为1CK411V7EQ的视频属性抓取结束
# 开始BV号为1Ji4y1t7hb视频属性的抓取
# BV号为1Ji4y1t7hb的视频属性抓取结束
# 开始BV号为1ci4y1b7oJ视频属性的抓取
# BV号为1ci4y1b7oJ的视频属性抓取结束
# 开始BV号为1ip4y117LY视频属性的抓取
# BV号为1ip4y117LY的视频属性抓取结束
# 开始BV号为15Z4y1j7Rc视频属性的抓取
# BV号为15Z4y1j7Rc的视频属性抓取结束
# 开始BV号为1UZ4y1x7NF视频属性的抓取
# BV号为1UZ4y1x7NF的视频属性抓取结束
# 开始BV号为1yQ4y1M7qt视频属性的抓取
# BV号为1yQ4y1M7qt的视频属性抓取结束
# 开始BV号为1s5411s7Vs视频属性的抓取
# BV号为1s5411s7Vs的视频属性抓取结束
# 开始BV号为15T4y137QS视频属性的抓取
# BV号为15T4y137QS的视频属性抓取结束
# 开始BV号为1si4y1s7Ma视频属性的抓取
# BV号为1si4y1s7Ma的视频属性抓取结束
# 开始BV号为14z4y1976q视频属性的抓取
# BV号为14z4y1976q的视频属性抓取结束
# 开始BV号为1si4y1s7Dm视频属性的抓取
# BV号为1si4y1s7Dm的视频属性抓取结束
# 开始BV号为1XV411d7Xb视频属性的抓取
# BV号为1XV411d7Xb的视频属性抓取结束
# 开始BV号为1PC4y1p7AR视频属性的抓取
# BV号为1PC4y1p7AR的视频属性抓取结束
# 开始BV号为1p54y1D7To视频属性的抓取
# BV号为1p54y1D7To的视频属性抓取结束
# 开始BV号为1ap4y1974B视频属性的抓取
# BV号为1ap4y1974B的视频属性抓取结束
# 开始BV号为1yC4y1H7Ug视频属性的抓取
# BV号为1yC4y1H7Ug的视频属性抓取结束
# 开始BV号为12p4y1Q7fG视频属性的抓取
# BV号为12p4y1Q7fG的视频属性抓取结束
# 开始BV号为1Rp4y1S77m视频属性的抓取
# BV号为1Rp4y1S77m的视频属性抓取结束
# 开始BV号为1UK411W7mN视频属性的抓取
# BV号为1UK411W7mN的视频属性抓取结束
# 开始BV号为1qf4y1m7pQ视频属性的抓取
# BV号为1qf4y1m7pQ的视频属性抓取结束
# 开始BV号为1GQ4y1N7CG视频属性的抓取
# BV号为1GQ4y1N7CG的视频属性抓取结束
# 开始BV号为1PC4y1s7hG视频属性的抓取
# BV号为1PC4y1s7hG的视频属性抓取结束
# 开始BV号为1SZ4y1p771视频属性的抓取
# BV号为1SZ4y1p771的视频属性抓取结束
# 开始BV号为1RK411W71o视频属性的抓取
# BV号为1RK411W71o的视频属性抓取结束
# 开始BV号为1SK4y1b7Lc视频属性的抓取
# BV号为1SK4y1b7Lc的视频属性抓取结束
# 开始BV号为1tK4y187Vf视频属性的抓取
# BV号为1tK4y187Vf的视频属性抓取结束
# 开始BV号为1va4y1e715视频属性的抓取
# BV号为1va4y1e715的视频属性抓取结束
# 开始BV号为1Ra4y1i7kz视频属性的抓取
# BV号为1Ra4y1i7kz的视频属性抓取结束
# 开始BV号为1XT4y1g71Y视频属性的抓取
# BV号为1XT4y1g71Y的视频属性抓取结束
# 开始BV号为1Ne411W7FZ视频属性的抓取
# BV号为1Ne411W7FZ的视频属性抓取结束
# 开始BV号为1Rp4y1S7MP视频属性的抓取
# BV号为1Rp4y1S7MP的视频属性抓取结束
# 开始BV号为1xp4y1Q7Ee视频属性的抓取
# BV号为1xp4y1Q7Ee的视频属性抓取结束
# 开始BV号为1Zz411q7Bk视频属性的抓取
# BV号为1Zz411q7Bk的视频属性抓取结束
# 开始BV号为1mZ4y1s7HF视频属性的抓取
# BV号为1mZ4y1s7HF的视频属性抓取结束
# 开始BV号为1bg4y1B7AR视频属性的抓取
# BV号为1bg4y1B7AR的视频属性抓取结束
# 开始BV号为1di4y147mk视频属性的抓取
# BV号为1di4y147mk的视频属性抓取结束
# 开始BV号为1rz4y1R7ma视频属性的抓取
# BV号为1rz4y1R7ma的视频属性抓取结束
# 开始BV号为11a4y1i7b7视频属性的抓取
# BV号为11a4y1i7b7的视频属性抓取结束
# 开始BV号为19e411p7Lv视频属性的抓取
# BV号为19e411p7Lv的视频属性抓取结束
# 开始BV号为1oC4y1H7yo视频属性的抓取
# BV号为1oC4y1H7yo的视频属性抓取结束
# 开始BV号为1at4y1C762视频属性的抓取
# BV号为1at4y1C762的视频属性抓取结束
# 开始BV号为1t5411s7jN视频属性的抓取
# BV号为1t5411s7jN的视频属性抓取结束
# 开始BV号为1Ef4y1m7ni视频属性的抓取
# BV号为1Ef4y1m7ni的视频属性抓取结束
# 开始BV号为1Qf4y1m73Z视频属性的抓取
# BV号为1Qf4y1m73Z的视频属性抓取结束
# 开始BV号为1tQ4y1A7JS视频属性的抓取
# BV号为1tQ4y1A7JS的视频属性抓取结束
# 开始BV号为1154y1Q78W视频属性的抓取
# BV号为1154y1Q78W的视频属性抓取结束
# 开始BV号为1dt4y1C734视频属性的抓取
# BV号为1dt4y1C734的视频属性抓取结束
# 开始BV号为1uK411s7Cu视频属性的抓取
# BV号为1uK411s7Cu的视频属性抓取结束
# 开始BV号为1sK4y187r5视频属性的抓取
# BV号为1sK4y187r5的视频属性抓取结束
# 开始BV号为1iT4y1u721视频属性的抓取
# BV号为1iT4y1u721的视频属性抓取结束
# 开始BV号为1tC4y1W78b视频属性的抓取
# BV号为1tC4y1W78b的视频属性抓取结束
# 开始BV号为1Rz4y1R7Ep视频属性的抓取
# BV号为1Rz4y1R7Ep的视频属性抓取结束
# 开始BV号为1Wk4y167rW视频属性的抓取
# BV号为1Wk4y167rW的视频属性抓取结束
# 开始BV号为1Et4y117By视频属性的抓取
# BV号为1Et4y117By的视频属性抓取结束
# 开始BV号为1nT4y137LA视频属性的抓取
# BV号为1nT4y137LA的视频属性抓取结束
# 开始BV号为1ti4y147v1视频属性的抓取
# BV号为1ti4y147v1的视频属性抓取结束
# 开始BV号为1dt4y1C7vW视频属性的抓取
# BV号为1dt4y1C7vW的视频属性抓取结束
# 开始BV号为125411p7NH视频属性的抓取
# BV号为125411p7NH的视频属性抓取结束
# 开始BV号为1vQ4y1N76w视频属性的抓取
# BV号为1vQ4y1N76w的视频属性抓取结束
# 开始BV号为1tp4y1Q7xH视频属性的抓取
# BV号为1tp4y1Q7xH的视频属性抓取结束
# 开始BV号为1pt4y117mr视频属性的抓取
# BV号为1pt4y117mr的视频属性抓取结束
# 开始BV号为1nz4y1972V视频属性的抓取
# BV号为1nz4y1972V的视频属性抓取结束
# 开始BV号为1mC4y1W7mb视频属性的抓取
# BV号为1mC4y1W7mb的视频属性抓取结束
# 开始BV号为1VK4y187fR视频属性的抓取
# BV号为1VK4y187fR的视频属性抓取结束
# 开始BV号为1va4y1e7jr视频属性的抓取
# BV号为1va4y1e7jr的视频属性抓取结束
# 开始BV号为1wC4y1s7Pj视频属性的抓取
# BV号为1wC4y1s7Pj的视频属性抓取结束
# 开始BV号为1d5411x7rS视频属性的抓取
# 开始BV号为1d5411x7rS视频属性的抓取
# BV号为1d5411x7rS的视频属性抓取结束
# 开始BV号为12Z4y1s7vR视频属性的抓取
# BV号为12Z4y1s7vR的视频属性抓取结束
# 开始BV号为1CQ4y1A7ig视频属性的抓取
# BV号为1CQ4y1A7ig的视频属性抓取结束
# 开始BV号为18K411W7ZL视频属性的抓取
# BV号为18K411W7ZL的视频属性抓取结束
# 开始BV号为1xp4y1X7Bm视频属性的抓取
# BV号为1xp4y1X7Bm的视频属性抓取结束
# 开始BV号为14a4y1e794视频属性的抓取
# BV号为14a4y1e794的视频属性抓取结束
# 开始BV号为1iZ4y1s7EY视频属性的抓取
# BV号为1iZ4y1s7EY的视频属性抓取结束
# 开始BV号为1iZ4y1s7Zr视频属性的抓取
# BV号为1iZ4y1s7Zr的视频属性抓取结束
# 开始BV号为1kp4y1Q78h视频属性的抓取
# BV号为1kp4y1Q78h的视频属性抓取结束
# 开始BV号为1TK411s765视频属性的抓取
# BV号为1TK411s765的视频属性抓取结束
# 开始BV号为1NK411s7Js视频属性的抓取
# BV号为1NK411s7Js的视频属性抓取结束
# 开始BV号为1sk4y1k7zM视频属性的抓取
# BV号为1sk4y1k7zM的视频属性抓取结束
# 开始BV号为1xk4y1k7qg视频属性的抓取
# BV号为1xk4y1k7qg的视频属性抓取结束
# 开始BV号为14z4y1d74k视频属性的抓取
# BV号为14z4y1d74k的视频属性抓取结束
# 开始BV号为14Q4y1P7fj视频属性的抓取
# BV号为14Q4y1P7fj的视频属性抓取结束
# 开始BV号为1Ae411W7PS视频属性的抓取
# BV号为1Ae411W7PS的视频属性抓取结束
# 开始BV号为1ct4y117EZ视频属性的抓取
# BV号为1ct4y117EZ的视频属性抓取结束
# 开始BV号为1Af4y1U7DN视频属性的抓取
# BV号为1Af4y1U7DN的视频属性抓取结束
# 开始BV号为1DV411d7K6视频属性的抓取
# BV号为1DV411d7K6的视频属性抓取结束
# 开始BV号为1pK4y1873E视频属性的抓取
# BV号为1pK4y1873E的视频属性抓取结束
# 开始BV号为1nz4y197qx视频属性的抓取
# BV号为1nz4y197qx的视频属性抓取结束
# 开始BV号为1qK411W79G视频属性的抓取
# BV号为1qK411W79G的视频属性抓取结束
# 开始BV号为1Ai4y147Zf视频属性的抓取
# BV号为1Ai4y147Zf的视频属性抓取结束
# 开始BV号为1H5411s7ho视频属性的抓取
# BV号为1H5411s7ho的视频属性抓取结束
# 开始BV号为1WV411C7Gi视频属性的抓取
# BV号为1WV411C7Gi的视频属性抓取结束
# 开始BV号为1j54y1D7p6视频属性的抓取
# BV号为1j54y1D7p6的视频属性抓取结束
# 开始BV号为1LA411t7mT视频属性的抓取
# BV号为1LA411t7mT的视频属性抓取结束
# 开始BV号为1Wz411q7ig视频属性的抓取
# BV号为1Wz411q7ig的视频属性抓取结束
# 开始BV号为1hg4y1i7Xz视频属性的抓取
# BV号为1hg4y1i7Xz的视频属性抓取结束
# 开始BV号为1Wi4y1s7q3视频属性的抓取
# BV号为1Wi4y1s7q3的视频属性抓取结束
# 开始BV号为1pf4y127rg视频属性的抓取
# BV号为1pf4y127rg的视频属性抓取结束
# 开始BV号为1PV411C7Pc视频属性的抓取
# BV号为1PV411C7Pc的视频属性抓取结束
# 开始BV号为1GK4y187m5视频属性的抓取
# BV号为1GK4y187m5的视频属性抓取结束
# 开始BV号为15V411C7Hh视频属性的抓取
# BV号为15V411C7Hh的视频属性抓取结束
# 开始BV号为1mZ4y1p75W视频属性的抓取
# BV号为1mZ4y1p75W的视频属性抓取结束
# 开始BV号为1ek4y167k2视频属性的抓取
# BV号为1ek4y167k2的视频属性抓取结束
# 开始BV号为1SK411H7fm视频属性的抓取
# BV号为1SK411H7fm的视频属性抓取结束
# 开始BV号为1pa4y1e7Yq视频属性的抓取
# BV号为1pa4y1e7Yq的视频属性抓取结束
# 开始BV号为1Lz411q7AD视频属性的抓取
# BV号为1Lz411q7AD的视频属性抓取结束
# 开始BV号为1FV411o7hg视频属性的抓取
# BV号为1FV411o7hg的视频属性抓取结束
# 开始BV号为1sZ4y1W7Js视频属性的抓取
# BV号为1sZ4y1W7Js的视频属性抓取结束
# 开始BV号为19K411n741视频属性的抓取
# BV号为19K411n741的视频属性抓取结束
# 开始BV号为16A411i73Z视频属性的抓取
# BV号为16A411i73Z的视频属性抓取结束
# 开始BV号为1GV411k71j视频属性的抓取
# BV号为1GV411k71j的视频属性抓取结束
# 开始BV号为1vz4y197zP视频属性的抓取
# BV号为1vz4y197zP的视频属性抓取结束
# 开始BV号为1bp4y1D71K视频属性的抓取
# BV号为1bp4y1D71K的视频属性抓取结束
# 开始BV号为16f4y127BA视频属性的抓取
# BV号为16f4y127BA的视频属性抓取结束
# 开始BV号为1hV411r7eW视频属性的抓取
# BV号为1hV411r7eW的视频属性抓取结束
# 开始BV号为1ta4y1Y7Zu视频属性的抓取
# BV号为1ta4y1Y7Zu的视频属性抓取结束
# 开始BV号为1L54y1z7ta视频属性的抓取
# BV号为1L54y1z7ta的视频属性抓取结束
# 开始BV号为1nk4y1r7AC视频属性的抓取
# BV号为1nk4y1r7AC的视频属性抓取结束
# 开始BV号为1ZV411r79J视频属性的抓取
# BV号为1ZV411r79J的视频属性抓取结束
# 开始BV号为16f4y117nT视频属性的抓取
# BV号为16f4y117nT的视频属性抓取结束
# 开始BV号为12k4y1B7RB视频属性的抓取
# BV号为12k4y1B7RB的视频属性抓取结束
# 开始BV号为1it4y1y7Jx视频属性的抓取
# BV号为1it4y1y7Jx的视频属性抓取结束
# 开始BV号为1pT4y1J7eM视频属性的抓取
# BV号为1pT4y1J7eM的视频属性抓取结束
# 开始BV号为1AA411B7sJ视频属性的抓取
# BV号为1AA411B7sJ的视频属性抓取结束
# 开始BV号为14D4y1D7cw视频属性的抓取
# BV号为14D4y1D7cw的视频属性抓取结束
# 开始BV号为1W5411Y7G9视频属性的抓取
# BV号为1W5411Y7G9的视频属性抓取结束
# 开始BV号为1YK4y1x7H3视频属性的抓取
# BV号为1YK4y1x7H3的视频属性抓取结束
# 开始BV号为1nz411i7An视频属性的抓取
# BV号为1nz411i7An的视频属性抓取结束
# 开始BV号为12T4y1E7zi视频属性的抓取
# BV号为12T4y1E7zi的视频属性抓取结束
# 开始BV号为1Wv41167Pm视频属性的抓取
# BV号为1Wv41167Pm的视频属性抓取结束
# 开始BV号为1NA411i7qq视频属性的抓取
# BV号为1NA411i7qq的视频属性抓取结束
# 开始BV号为1VK411H7wv视频属性的抓取
# BV号为1VK411H7wv的视频属性抓取结束
# 开始BV号为1S5411p7nt视频属性的抓取
# BV号为1S5411p7nt的视频属性抓取结束
# 开始BV号为1ja4y1Y7wT视频属性的抓取
# BV号为1ja4y1Y7wT的视频属性抓取结束
# 开始BV号为1RZ4y1n74h视频属性的抓取
# BV号为1RZ4y1n74h的视频属性抓取结束
# 开始BV号为1rf4y1172r视频属性的抓取
# BV号为1rf4y1172r的视频属性抓取结束
# 开始BV号为1GK411p7aU视频属性的抓取
# BV号为1GK411p7aU的视频属性抓取结束
# 开始BV号为1vv411B7Sj视频属性的抓取
# BV号为1vv411B7Sj的视频属性抓取结束
# 开始BV号为1Ag4y1q7dY视频属性的抓取
# BV号为1Ag4y1q7dY的视频属性抓取结束
# 开始BV号为19g4y1i77t视频属性的抓取
# BV号为19g4y1i77t的视频属性抓取结束
# 开始BV号为1Va4y1Y7j5视频属性的抓取
# BV号为1Va4y1Y7j5的视频属性抓取结束
# 开始BV号为14t4y197Ww视频属性的抓取
# BV号为14t4y197Ww的视频属性抓取结束
# 开始BV号为1BT4y1J7Xq视频属性的抓取
# BV号为1BT4y1J7Xq的视频属性抓取结束
# 开始BV号为1p54y1Q7iG视频属性的抓取
# BV号为1p54y1Q7iG的视频属性抓取结束
# 开始BV号为1Yt4y1y7qM视频属性的抓取
# BV号为1Yt4y1y7qM的视频属性抓取结束
# 开始BV号为1ma4y1Y7Wf视频属性的抓取
# BV号为1ma4y1Y7Wf的视频属性抓取结束
# 开始BV号为1t5411Y7xc视频属性的抓取
# BV号为1t5411Y7xc的视频属性抓取结束
# 开始BV号为1J54y1Q7A9视频属性的抓取
# BV号为1J54y1Q7A9的视频属性抓取结束
# 开始BV号为1Kv41167bF视频属性的抓取
# BV号为1Kv41167bF的视频属性抓取结束
# 开始BV号为13z4y1X7Rj视频属性的抓取
# BV号为13z4y1X7Rj的视频属性抓取结束
# 开始BV号为1RV411r7ds视频属性的抓取
# BV号为1RV411r7ds的视频属性抓取结束
# 开始BV号为1wC4y1a7J5视频属性的抓取
# BV号为1wC4y1a7J5的视频属性抓取结束
# 开始BV号为1TC4y1a7BB视频属性的抓取
# BV号为1TC4y1a7BB的视频属性抓取结束
# 开始BV号为12V411r7jM视频属性的抓取
# BV号为12V411r7jM的视频属性抓取结束
# 开始BV号为1ck4y1z7JR视频属性的抓取
# BV号为1ck4y1z7JR的视频属性抓取结束
# 开始BV号为1iv411B7DM视频属性的抓取
# BV号为1iv411B7DM的视频属性抓取结束
# 开始BV号为1st4y197hC视频属性的抓取
# BV号为1st4y197hC的视频属性抓取结束
# 开始BV号为1ki4y1G7EQ视频属性的抓取
# BV号为1ki4y1G7EQ的视频属性抓取结束
# 开始BV号为1Uf4y127iP视频属性的抓取
# BV号为1Uf4y127iP的视频属性抓取结束
# 开始BV号为1ef4y117Zi视频属性的抓取
# BV号为1ef4y117Zi的视频属性抓取结束
# 开始BV号为1wz4y1R7Ro视频属性的抓取
# BV号为1wz4y1R7Ro的视频属性抓取结束
# 开始BV号为1nV411r74w视频属性的抓取
# BV号为1nV411r74w的视频属性抓取结束
# 开始BV号为1WK411p7JR视频属性的抓取
# BV号为1WK411p7JR的视频属性抓取结束
# 开始BV号为1G54y1B787视频属性的抓取
# BV号为1G54y1B787的视频属性抓取结束
# 开始BV号为1mp4y1D7si视频属性的抓取
# BV号为1mp4y1D7si的视频属性抓取结束
# 开始BV号为1Fz411i7ve视频属性的抓取
# BV号为1Fz411i7ve的视频属性抓取结束
# 开始BV号为1F5411W7hU视频属性的抓取
# BV号为1F5411W7hU的视频属性抓取结束
# 开始BV号为1Pk4y1z7BC视频属性的抓取
# BV号为1Pk4y1z7BC的视频属性抓取结束
# 开始BV号为1QZ4y1H7Sc视频属性的抓取
# BV号为1QZ4y1H7Sc的视频属性抓取结束
# 开始BV号为1eV411r75a视频属性的抓取
# BV号为1eV411r75a的视频属性抓取结束
# 开始BV号为1TT4y1J7vH视频属性的抓取
# BV号为1TT4y1J7vH的视频属性抓取结束
# 开始BV号为1yC4y187CV视频属性的抓取
# BV号为1yC4y187CV的视频属性抓取结束
# 开始BV号为1p54y1z7Xm视频属性的抓取
# BV号为1p54y1z7Xm的视频属性抓取结束
# 开始BV号为1ut4y1y7sH视频属性的抓取
# BV号为1ut4y1y7sH的视频属性抓取结束
# 开始BV号为1vf4y127Lj视频属性的抓取
# BV号为1vf4y127Lj的视频属性抓取结束
# 开始BV号为1qa4y1Y7oy视频属性的抓取
# BV号为1qa4y1Y7oy的视频属性抓取结束
# 开始BV号为1ff4y127Qp视频属性的抓取
# BV号为1ff4y127Qp的视频属性抓取结束
# 开始BV号为1pi4y1G7Df视频属性的抓取
# BV号为1pi4y1G7Df的视频属性抓取结束
# 开始BV号为1ht4y1y7du视频属性的抓取
# BV号为1ht4y1y7du的视频属性抓取结束
# 开始BV号为1LT4y1J76N视频属性的抓取
# BV号为1LT4y1J76N的视频属性抓取结束
# 开始BV号为1jz411i7Sx视频属性的抓取
# BV号为1jz411i7Sx的视频属性抓取结束
# 开始BV号为1fZ4y1n7E4视频属性的抓取
# BV号为1fZ4y1n7E4的视频属性抓取结束
# 开始BV号为1iD4y1Q7mA视频属性的抓取
# BV号为1iD4y1Q7mA的视频属性抓取结束
# 开始BV号为19a4y1Y77u视频属性的抓取
# BV号为19a4y1Y77u的视频属性抓取结束
# 开始BV号为1S5411W7TT视频属性的抓取
# BV号为1S5411W7TT的视频属性抓取结束
# 开始BV号为1Yg4y1q7HD视频属性的抓取
# BV号为1Yg4y1q7HD的视频属性抓取结束
# 开始BV号为1Uv411B7FC视频属性的抓取
# BV号为1Uv411B7FC的视频属性抓取结束
# 开始BV号为1Wk4y1z7W4视频属性的抓取
# BV号为1Wk4y1z7W4的视频属性抓取结束
# 开始BV号为1v54y1B79V视频属性的抓取
# BV号为1v54y1B79V的视频属性抓取结束
# 开始BV号为1dT4y1E7yA视频属性的抓取
# BV号为1dT4y1E7yA的视频属性抓取结束
# 开始BV号为1FK4y147pt视频属性的抓取
# BV号为1FK4y147pt的视频属性抓取结束
# 开始BV号为1EA411i794视频属性的抓取
# BV号为1EA411i794的视频属性抓取结束
# 开始BV号为1qK4y147xE视频属性的抓取
# BV号为1qK4y147xE的视频属性抓取结束
# 开始BV号为1p54y1z79p视频属性的抓取
# BV号为1p54y1z79p的视频属性抓取结束
# 开始BV号为1mk4y1B77c视频属性的抓取
# BV号为1mk4y1B77c的视频属性抓取结束
# 开始BV号为17Z4y1W7Sc视频属性的抓取
# BV号为17Z4y1W7Sc的视频属性抓取结束
# 开始BV号为12k4y1z7Qp视频属性的抓取
# BV号为12k4y1z7Qp的视频属性抓取结束
# 开始BV号为1yQ4y1P7so视频属性的抓取
# BV号为1yQ4y1P7so的视频属性抓取结束
# 开始BV号为1nT4y1J7nJ视频属性的抓取
# BV号为1nT4y1J7nJ的视频属性抓取结束
# 开始BV号为15K4y1s7zk视频属性的抓取
# BV号为15K4y1s7zk的视频属性抓取结束
# 开始BV号为1W54y1Q7jT视频属性的抓取
# BV号为1W54y1Q7jT的视频属性抓取结束
# 开始BV号为1qA411v7Ax视频属性的抓取
# BV号为1qA411v7Ax的视频属性抓取结束
# 开始BV号为1kf4y117Ff视频属性的抓取
# BV号为1kf4y117Ff的视频属性抓取结束
# 开始BV号为1wz4y1R7cb视频属性的抓取
# BV号为1wz4y1R7cb的视频属性抓取结束
# 开始BV号为1pT4y1J7Nr视频属性的抓取
# BV号为1pT4y1J7Nr的视频属性抓取结束
# 开始BV号为1554y1z7MF视频属性的抓取
# 开始BV号为1554y1z7MF视频属性的抓取
# 开始BV号为1554y1z7MF视频属性的抓取
# BV号为1554y1z7MF的视频属性抓取结束
# 开始BV号为1BK4y147Gi视频属性的抓取
# BV号为1BK4y147Gi的视频属性抓取结束
# 开始BV号为14z4y1D7wP视频属性的抓取
# BV号为14z4y1D7wP的视频属性抓取结束
# 开始BV号为1fa4y1h7xT视频属性的抓取
# BV号为1fa4y1h7xT的视频属性抓取结束
# 开始BV号为1gC4y1b7vr视频属性的抓取
# BV号为1gC4y1b7vr的视频属性抓取结束
# 开始BV号为11D4y1S78c视频属性的抓取
# BV号为11D4y1S78c的视频属性抓取结束
# 开始BV号为1pi4y1V7Tg视频属性的抓取
# BV号为1pi4y1V7Tg的视频属性抓取结束
# 开始BV号为1vC4y1h7Fu视频属性的抓取
# BV号为1vC4y1h7Fu的视频属性抓取结束
# 开始BV号为12K4y147Hc视频属性的抓取
# BV号为12K4y147Hc的视频属性抓取结束
# 开始BV号为1rz4y1X7yF视频属性的抓取
# BV号为1rz4y1X7yF的视频属性抓取结束
# 开始BV号为1Yz4y1D7U1视频属性的抓取
# BV号为1Yz4y1D7U1的视频属性抓取结束
# 开始BV号为1sD4y1S7oW视频属性的抓取
# BV号为1sD4y1S7oW的视频属性抓取结束
# 开始BV号为1UD4y1S7go视频属性的抓取
# BV号为1UD4y1S7go的视频属性抓取结束
# 开始BV号为1hK411H7x3视频属性的抓取
# BV号为1hK411H7x3的视频属性抓取结束
# 开始BV号为1Z5411h7gq视频属性的抓取
# BV号为1Z5411h7gq的视频属性抓取结束
# 开始BV号为1TK411J7us视频属性的抓取
# BV号为1TK411J7us的视频属性抓取结束
# 开始BV号为1s54y1S7BQ视频属性的抓取
# BV号为1s54y1S7BQ的视频属性抓取结束
# 开始BV号为1kD4y1m7CZ视频属性的抓取
# BV号为1kD4y1m7CZ的视频属性抓取结束
# 开始BV号为1Bg4y1v7Ae视频属性的抓取
# BV号为1Bg4y1v7Ae的视频属性抓取结束
# 开始BV号为1ta4y1a7yS视频属性的抓取
# BV号为1ta4y1a7yS的视频属性抓取结束
# 开始BV号为16K411J7xZ视频属性的抓取
# BV号为16K411J7xZ的视频属性抓取结束
# 开始BV号为15K411J7Py视频属性的抓取
# BV号为15K411J7Py的视频属性抓取结束
# 开始BV号为1p5411e7nj视频属性的抓取
# BV号为1p5411e7nj的视频属性抓取结束
# 开始BV号为1A54y1D7EJ视频属性的抓取
# BV号为1A54y1D7EJ的视频属性抓取结束
# 开始BV号为1DZ4y1M7dN视频属性的抓取
# BV号为1DZ4y1M7dN的视频属性抓取结束
# 开始BV号为1c54y1S7Hj视频属性的抓取
# BV号为1c54y1S7Hj的视频属性抓取结束
# 开始BV号为1rK4y1e7c8视频属性的抓取
# BV号为1rK4y1e7c8的视频属性抓取结束
# 开始BV号为1y5411a7fr视频属性的抓取
# BV号为1y5411a7fr的视频属性抓取结束
# 开始BV号为1Fk4y1B75R视频属性的抓取
# BV号为1Fk4y1B75R的视频属性抓取结束
# 开始BV号为13v411z74V视频属性的抓取
# BV号为13v411z74V的视频属性抓取结束
# 开始BV号为1Bt4y1X7Qx视频属性的抓取
# BV号为1Bt4y1X7Qx的视频属性抓取结束
# 开始BV号为12a4y1h7dz视频属性的抓取
# BV号为12a4y1h7dz的视频属性抓取结束
# 开始BV号为1hT4y1j7Xh视频属性的抓取
# BV号为1hT4y1j7Xh的视频属性抓取结束
# 开始BV号为1Ap4y1S7Hh视频属性的抓取
# BV号为1Ap4y1S7Hh的视频属性抓取结束
# 开始BV号为1M54y1i7WA视频属性的抓取
# BV号为1M54y1i7WA的视频属性抓取结束
# 开始BV号为1ch411Z7T8视频属性的抓取
# BV号为1ch411Z7T8的视频属性抓取结束
# 开始BV号为1dv411i7j7视频属性的抓取
# BV号为1dv411i7j7的视频属性抓取结束
# 开始BV号为1pt4y1Q77m视频属性的抓取
# BV号为1pt4y1Q77m的视频属性抓取结束
# 开始BV号为1Q64y1F74q视频属性的抓取
# BV号为1Q64y1F74q的视频属性抓取结束
# 开始BV号为1Lp4y1q7gi视频属性的抓取
# BV号为1Lp4y1q7gi的视频属性抓取结束
# 开始BV号为1Nk4y1B7GX视频属性的抓取
# BV号为1Nk4y1B7GX的视频属性抓取结束
# 开始BV号为1Za4y1h7E6视频属性的抓取
# BV号为1Za4y1h7E6的视频属性抓取结束
# 开始BV号为1oT4y1L7ic视频属性的抓取
# BV号为1oT4y1L7ic的视频属性抓取结束
# 开始BV号为1Ua4y1h7mC视频属性的抓取
# BV号为1Ua4y1h7mC的视频属性抓取结束
# 开始BV号为1AD4y1D7ME视频属性的抓取
# BV号为1AD4y1D7ME的视频属性抓取结束
# 开始BV号为1KT4y1j7ac视频属性的抓取
# BV号为1KT4y1j7ac的视频属性抓取结束
# 开始BV号为1Pf4y1d7Jd视频属性的抓取
# BV号为1Pf4y1d7Jd的视频属性抓取结束
# 开始BV号为1sv411q7Yu视频属性的抓取
# BV号为1sv411q7Yu的视频属性抓取结束
# 开始BV号为1S64y1F7hC视频属性的抓取
# BV号为1S64y1F7hC的视频属性抓取结束
# 开始BV号为1Gk4y1m7Nr视频属性的抓取
# BV号为1Gk4y1m7Nr的视频属性抓取结束
# 开始BV号为17D4y1S7vs视频属性的抓取
# BV号为17D4y1S7vs的视频属性抓取结束
# 开始BV号为13A411v7ZD视频属性的抓取
# BV号为13A411v7ZD的视频属性抓取结束
# 开始BV号为1PK411H7s6视频属性的抓取
# BV号为1PK411H7s6的视频属性抓取结束
# 开始BV号为1Nf4y1R7gY视频属性的抓取
# BV号为1Nf4y1R7gY的视频属性抓取结束
# 开始BV号为1JV41167id视频属性的抓取
# BV号为1JV41167id的视频属性抓取结束
# 开始BV号为1d54y1q72c视频属性的抓取
# BV号为1d54y1q72c的视频属性抓取结束
# 开始BV号为1754y1z7VZ视频属性的抓取
# BV号为1754y1z7VZ的视频属性抓取结束
# 开始BV号为1N54y1S72k视频属性的抓取
# BV号为1N54y1S72k的视频属性抓取结束
# 开始BV号为1GV411r7E8视频属性的抓取
# BV号为1GV411r7E8的视频属性抓取结束
# 开始BV号为1yC4y1b7Mb视频属性的抓取
# BV号为1yC4y1b7Mb的视频属性抓取结束
# 开始BV号为1f54y1U7jn视频属性的抓取
# BV号为1f54y1U7jn的视频属性抓取结束
# 开始BV号为1dZ4y1T7vU视频属性的抓取
# BV号为1dZ4y1T7vU的视频属性抓取结束
# 开始BV号为1MV411z71Q视频属性的抓取
# BV号为1MV411z71Q的视频属性抓取结束
# 开始BV号为1yK411J7k7视频属性的抓取
# BV号为1yK411J7k7的视频属性抓取结束
# 开始BV号为1kD4y1m7Sa视频属性的抓取
# BV号为1kD4y1m7Sa的视频属性抓取结束
# 开始BV号为18h411Z7VQ视频属性的抓取
# BV号为18h411Z7VQ的视频属性抓取结束
# 开始BV号为1iC4y1b71Z视频属性的抓取
# BV号为1iC4y1b71Z的视频属性抓取结束
# 开始BV号为15K4y1v746视频属性的抓取
# BV号为15K4y1v746的视频属性抓取结束
# 开始BV号为1QA411e7Xr视频属性的抓取
# BV号为1QA411e7Xr的视频属性抓取结束
# 开始BV号为1rK4y1e7x3视频属性的抓取
# BV号为1rK4y1e7x3的视频属性抓取结束
# 开始BV号为1UA411e7jP视频属性的抓取
# BV号为1UA411e7jP的视频属性抓取结束
# 开始BV号为1LV41167ix视频属性的抓取
# BV号为1LV41167ix的视频属性抓取结束
# 开始BV号为1jD4y1Q7Zt视频属性的抓取
# BV号为1jD4y1Q7Zt的视频属性抓取结束
# 开始BV号为1y64y1F7wV视频属性的抓取
# BV号为1y64y1F7wV的视频属性抓取结束
# 开始BV号为12f4y1R7Tu视频属性的抓取
# BV号为12f4y1R7Tu的视频属性抓取结束
# 开始BV号为14C4y1h7nV视频属性的抓取
# BV号为14C4y1h7nV的视频属性抓取结束
# 开始BV号为1ET4y1j7Yf视频属性的抓取
# BV号为1ET4y1j7Yf的视频属性抓取结束
# 开始BV号为1vh411o7b2视频属性的抓取
# BV号为1vh411o7b2的视频属性抓取结束
# 开始BV号为16Z4y1u7W8视频属性的抓取
# BV号为16Z4y1u7W8的视频属性抓取结束
# 开始BV号为1wi4y137e4视频属性的抓取
# BV号为1wi4y137e4的视频属性抓取结束
# 开始BV号为1Lp4y1S7ys视频属性的抓取
# BV号为1Lp4y1S7ys的视频属性抓取结束
# 开始BV号为1rA411e73s视频属性的抓取
# BV号为1rA411e73s的视频属性抓取结束
# 开始BV号为1VV411z7Fu视频属性的抓取
# BV号为1VV411z7Fu的视频属性抓取结束
# 开始BV号为1qA411e7nP视频属性的抓取
# BV号为1qA411e7nP的视频属性抓取结束
# 开始BV号为1cv411q71k视频属性的抓取
# BV号为1cv411q71k的视频属性抓取结束
# 开始BV号为17g4y1i7uH视频属性的抓取
# BV号为17g4y1i7uH的视频属性抓取结束
# 开始BV号为1AT4y1j76n视频属性的抓取
# BV号为1AT4y1j76n的视频属性抓取结束
# 开始BV号为1rv411i7Ld视频属性的抓取
# BV号为1rv411i7Ld的视频属性抓取结束
# 开始BV号为1Ei4y137pn视频属性的抓取
# BV号为1Ei4y137pn的视频属性抓取结束
# 开始BV号为1Mf4y1d7tc视频属性的抓取
# BV号为1Mf4y1d7tc的视频属性抓取结束
# 开始BV号为12k4y1q7Df视频属性的抓取
# BV号为12k4y1q7Df的视频属性抓取结束
# 开始BV号为1R54y1i7WD视频属性的抓取
# BV号为1R54y1i7WD的视频属性抓取结束
# 开始BV号为1fA411a7Jf视频属性的抓取
# BV号为1fA411a7Jf的视频属性抓取结束
# 开始BV号为1tD4y1U7wJ视频属性的抓取
# BV号为1tD4y1U7wJ的视频属性抓取结束
# 开始BV号为1SD4y1S79v视频属性的抓取
# BV号为1SD4y1S79v的视频属性抓取结束
# 开始BV号为1QK4y1s7PT视频属性的抓取
# BV号为1QK4y1s7PT的视频属性抓取结束
# 开始BV号为1NV41167FD视频属性的抓取
# BV号为1NV41167FD的视频属性抓取结束
# 开始BV号为1wi4y137zp视频属性的抓取
# BV号为1wi4y137zp的视频属性抓取结束
# 开始BV号为1nk4y1B7fi视频属性的抓取
# BV号为1nk4y1B7fi的视频属性抓取结束
# 开始BV号为1U5411a7v2视频属性的抓取
# BV号为1U5411a7v2的视频属性抓取结束
# 开始BV号为1si4y1V7Co视频属性的抓取
# BV号为1si4y1V7Co的视频属性抓取结束
# 开始BV号为1NV411r7Zu视频属性的抓取
# BV号为1NV411r7Zu的视频属性抓取结束
# 开始BV号为1654y1m75z视频属性的抓取
# BV号为1654y1m75z的视频属性抓取结束
# 开始BV号为1yV41127u8视频属性的抓取
# BV号为1yV41127u8的视频属性抓取结束
# 开始BV号为1mD4y1U7zL视频属性的抓取
# BV号为1mD4y1U7zL的视频属性抓取结束
# 开始BV号为1KC4y187Ux视频属性的抓取
# BV号为1KC4y187Ux的视频属性抓取结束
# 开始BV号为1r54y1U7Jm视频属性的抓取
# BV号为1r54y1U7Jm的视频属性抓取结束
# 开始BV号为1dh411d7eB视频属性的抓取
# BV号为1dh411d7eB的视频属性抓取结束
# 开始BV号为1KK411M74H视频属性的抓取
# BV号为1KK411M74H的视频属性抓取结束
# 开始BV号为1JK4y1Y771视频属性的抓取
# BV号为1JK4y1Y771的视频属性抓取结束
# 开始BV号为1pp4y1v7r5视频属性的抓取
# BV号为1pp4y1v7r5的视频属性抓取结束
# 开始BV号为1bf4y197Ry视频属性的抓取
# BV号为1bf4y197Ry的视频属性抓取结束
# 开始BV号为1ek4y1277P视频属性的抓取
# BV号为1ek4y1277P的视频属性抓取结束
# 开始BV号为1eC4y1t7ik视频属性的抓取
# BV号为1eC4y1t7ik的视频属性抓取结束
# 开始BV号为1Tk4y1U79s视频属性的抓取
# BV号为1Tk4y1U79s的视频属性抓取结束
# 开始BV号为1eT4y1j7w4视频属性的抓取
# BV号为1eT4y1j7w4的视频属性抓取结束
# 开始BV号为1cA411n7fw视频属性的抓取
# BV号为1cA411n7fw的视频属性抓取结束
# 开始BV号为1Bk4y117wT视频属性的抓取
# BV号为1Bk4y117wT的视频属性抓取结束
# 开始BV号为1BT4y157f6视频属性的抓取
# BV号为1BT4y157f6的视频属性抓取结束
# 开始BV号为1654y1m7Sk视频属性的抓取
# BV号为1654y1m7Sk的视频属性抓取结束
# 开始BV号为1XA411Y7kd视频属性的抓取
# BV号为1XA411Y7kd的视频属性抓取结束
# 开始BV号为1FT4y1L7Gx视频属性的抓取
# BV号为1FT4y1L7Gx的视频属性抓取结束
# 开始BV号为1V64y1F7Cn视频属性的抓取
# BV号为1V64y1F7Cn的视频属性抓取结束
# 开始BV号为1M54y1U7QN视频属性的抓取
# BV号为1M54y1U7QN的视频属性抓取结束
# 开始BV号为1d54y1m7Ed视频属性的抓取
# BV号为1d54y1m7Ed的视频属性抓取结束
# 开始BV号为1e5411h7LV视频属性的抓取
# BV号为1e5411h7LV的视频属性抓取结束
# 开始BV号为1Sf4y197hP视频属性的抓取
# BV号为1Sf4y197hP的视频属性抓取结束
# 开始BV号为1P5411h7Hs视频属性的抓取
# BV号为1P5411h7Hs的视频属性抓取结束
# 开始BV号为1G54y1i7pb视频属性的抓取
# BV号为1G54y1i7pb的视频属性抓取结束
# 开始BV号为18k4y1m7pw视频属性的抓取
# BV号为18k4y1m7pw的视频属性抓取结束
# 开始BV号为1vz4y1f7Tf视频属性的抓取
# BV号为1vz4y1f7Tf的视频属性抓取结束
# 开始BV号为1pA411n7yU视频属性的抓取
# BV号为1pA411n7yU的视频属性抓取结束
# 开始BV号为1HC4y187pG视频属性的抓取
# BV号为1HC4y187pG的视频属性抓取结束
# 开始BV号为1zk4y1276j视频属性的抓取
# BV号为1zk4y1276j的视频属性抓取结束
# 开始BV号为1qa4y177NP视频属性的抓取
# BV号为1qa4y177NP的视频属性抓取结束
# 开始BV号为1m64y1c767视频属性的抓取
# BV号为1m64y1c767的视频属性抓取结束
# 开始BV号为18i4y1M7eg视频属性的抓取
# BV号为18i4y1M7eg的视频属性抓取结束
# 开始BV号为1tv411v7A9视频属性的抓取
# BV号为1tv411v7A9的视频属性抓取结束
# 开始BV号为1Vk4y1y7qB视频属性的抓取
# BV号为1Vk4y1y7qB的视频属性抓取结束
# 开始BV号为18f4y197Tn视频属性的抓取
# BV号为18f4y197Tn的视频属性抓取结束
# 开始BV号为1GT4y1L728视频属性的抓取
# BV号为1GT4y1L728的视频属性抓取结束
# 开始BV号为1hD4y1m72y视频属性的抓取
# BV号为1hD4y1m72y的视频属性抓取结束
# 开始BV号为1uZ4y1K7bN视频属性的抓取
# BV号为1uZ4y1K7bN的视频属性抓取结束
# 开始BV号为1M64y1c7uN视频属性的抓取
# BV号为1M64y1c7uN的视频属性抓取结束
# 开始BV号为1mv411v7Cx视频属性的抓取
# BV号为1mv411v7Cx的视频属性抓取结束
# 开始BV号为1xC4y1875Q视频属性的抓取
# BV号为1xC4y1875Q的视频属性抓取结束
# 开始BV号为1qf4y19725视频属性的抓取
# BV号为1qf4y19725的视频属性抓取结束
# 开始BV号为16h411d7R1视频属性的抓取
# BV号为16h411d7R1的视频属性抓取结束
# 开始BV号为1UA411n77q视频属性的抓取
# BV号为1UA411n77q的视频属性抓取结束
# 开始BV号为1Lv411i7qj视频属性的抓取
# BV号为1Lv411i7qj的视频属性抓取结束
# 开始BV号为1c54y1i7ra视频属性的抓取
# BV号为1c54y1i7ra的视频属性抓取结束
# 开始BV号为1XC4y147eX视频属性的抓取
# BV号为1XC4y147eX的视频属性抓取结束
# 开始BV号为1ei4y1M7S8视频属性的抓取
# BV号为1ei4y1M7S8的视频属性抓取结束
# 开始BV号为1ta4y177sP视频属性的抓取
# 开始BV号为1ta4y177sP视频属性的抓取
# BV号为1ta4y177sP的视频属性抓取结束
# 开始BV号为1cp4y1i74o视频属性的抓取
# BV号为1cp4y1i74o的视频属性抓取结束
# 开始BV号为1Ua4y1E79N视频属性的抓取
# BV号为1Ua4y1E79N的视频属性抓取结束
# 开始BV号为1af4y1Q7mD视频属性的抓取
# BV号为1af4y1Q7mD的视频属性抓取结束
# 开始BV号为1UK411J7ks视频属性的抓取
# BV号为1UK411J7ks的视频属性抓取结束
# 开始BV号为1x54y1U7sL视频属性的抓取
# BV号为1x54y1U7sL的视频属性抓取结束
# 开始BV号为1QK411T7cv视频属性的抓取
# BV号为1QK411T7cv的视频属性抓取结束
# 开始BV号为12K4y1v7rH视频属性的抓取
# BV号为12K4y1v7rH的视频属性抓取结束
# 开始BV号为12D4y127by视频属性的抓取
# BV号为12D4y127by的视频属性抓取结束
# 开始BV号为1VT4y177a2视频属性的抓取
# BV号为1VT4y177a2的视频属性抓取结束
# 开始BV号为1Bp4y1q79H视频属性的抓取
# BV号为1Bp4y1q79H的视频属性抓取结束
# 开始BV号为18K4y1Y792视频属性的抓取
# BV号为18K4y1Y792的视频属性抓取结束
# 开始BV号为1Zp4y1v7mz视频属性的抓取
# BV号为1Zp4y1v7mz的视频属性抓取结束
# 开始BV号为1LK411n7UM视频属性的抓取
# BV号为1LK411n7UM的视频属性抓取结束
# 开始BV号为1aT4y1L7cw视频属性的抓取
# BV号为1aT4y1L7cw的视频属性抓取结束
# 开始BV号为1Xt4y1D7vK视频属性的抓取
# BV号为1Xt4y1D7vK的视频属性抓取结束
# 开始BV号为1H64y1c7MS视频属性的抓取
# BV号为1H64y1c7MS的视频属性抓取结束
# 开始BV号为1qz4y1f7Eb视频属性的抓取
# BV号为1qz4y1f7Eb的视频属性抓取结束
# 开始BV号为1xD4y1U7XB视频属性的抓取
# BV号为1xD4y1U7XB的视频属性抓取结束
# 开始BV号为1Rt4y1U7EZ视频属性的抓取
# BV号为1Rt4y1U7EZ的视频属性抓取结束
# 开始BV号为1mt4y1U7gr视频属性的抓取
# BV号为1mt4y1U7gr的视频属性抓取结束
# 开始BV号为1pD4y1U7hc视频属性的抓取
# BV号为1pD4y1U7hc的视频属性抓取结束
# 开始BV号为1bh411d7z5视频属性的抓取
# BV号为1bh411d7z5的视频属性抓取结束
# 开始BV号为1Jp4y1q75Q视频属性的抓取
# BV号为1Jp4y1q75Q的视频属性抓取结束
# 开始BV号为1g54y1D7Yn视频属性的抓取
# BV号为1g54y1D7Yn的视频属性抓取结束
# 开始BV号为1854y1i7SM视频属性的抓取
# BV号为1854y1i7SM的视频属性抓取结束
# 开始BV号为1Gi4y1g7dn视频属性的抓取
# BV号为1Gi4y1g7dn的视频属性抓取结束
# 开始BV号为1Vk4y1y75j视频属性的抓取
# BV号为1Vk4y1y75j的视频属性抓取结束
# 开始BV号为12C4y1t7MA视频属性的抓取
# BV号为12C4y1t7MA的视频属性抓取结束
# 开始BV号为1Zt4y1D7kJ视频属性的抓取
# BV号为1Zt4y1D7kJ的视频属性抓取结束
# 开始BV号为1Dh41197Rw视频属性的抓取
# BV号为1Dh41197Rw的视频属性抓取结束
# 开始BV号为11Z4y1M7iQ视频属性的抓取
# BV号为11Z4y1M7iQ的视频属性抓取结束
# 开始BV号为11k4y127jp视频属性的抓取
# BV号为11k4y127jp的视频属性抓取结束
# 开始BV号为1Si4y1g7JN视频属性的抓取
# BV号为1Si4y1g7JN的视频属性抓取结束
# 开始BV号为1Dp4y1v74F视频属性的抓取
# BV号为1Dp4y1v74F的视频属性抓取结束
# 开始BV号为1r54y127sH视频属性的抓取
# BV号为1r54y127sH的视频属性抓取结束
# 开始BV号为15f4y1d7Rf视频属性的抓取
# BV号为15f4y1d7Rf的视频属性抓取结束
# 开始BV号为1ea4y17799视频属性的抓取
# BV号为1ea4y17799的视频属性抓取结束
# 开始BV号为1La4y177NG视频属性的抓取
# BV号为1La4y177NG的视频属性抓取结束
# 开始BV号为1Hi4y1M7K2视频属性的抓取
# BV号为1Hi4y1M7K2的视频属性抓取结束
# 开始BV号为1zK411N7yd视频属性的抓取
# BV号为1zK411N7yd的视频属性抓取结束
# 开始BV号为1Ai4y1G7U9视频属性的抓取
# BV号为1Ai4y1G7U9的视频属性抓取结束
# 开始BV号为1ya4y1E7C5视频属性的抓取
# BV号为1ya4y1E7C5的视频属性抓取结束
# 开始BV号为1fA411J7Sq视频属性的抓取
# BV号为1fA411J7Sq的视频属性抓取结束
# 开始BV号为1Lz4y1Q7N9视频属性的抓取
# BV号为1Lz4y1Q7N9的视频属性抓取结束
# 开始BV号为1mk4y127p2视频属性的抓取
# BV号为1mk4y127p2的视频属性抓取结束
# 开始BV号为1ik4y117bD视频属性的抓取
# BV号为1ik4y117bD的视频属性抓取结束
# 开始BV号为1e64y1c7hJ视频属性的抓取
# BV号为1e64y1c7hJ的视频属性抓取结束
# 开始BV号为185411h79R视频属性的抓取
# BV号为185411h79R的视频属性抓取结束
# 开始BV号为1ek4y1y7Hj视频属性的抓取
# BV号为1ek4y1y7Hj的视频属性抓取结束
# 开始BV号为1Yh411X7ZE视频属性的抓取
# BV号为1Yh411X7ZE的视频属性抓取结束
# 开始BV号为1Hk4y127ao视频属性的抓取
# BV号为1Hk4y127ao的视频属性抓取结束
# 开始BV号为1M5411j7J3视频属性的抓取
# BV号为1M5411j7J3的视频属性抓取结束
# 开始BV号为1LD4y1o7Mi视频属性的抓取
# BV号为1LD4y1o7Mi的视频属性抓取结束
# 开始BV号为14i4y1E7jD视频属性的抓取
# BV号为14i4y1E7jD的视频属性抓取结束
# 开始BV号为17f4y1D72s视频属性的抓取
# BV号为17f4y1D72s的视频属性抓取结束
# 开始BV号为1X54y117L1视频属性的抓取
# BV号为1X54y117L1的视频属性抓取结束
# 开始BV号为115411b7WK视频属性的抓取
# BV号为115411b7WK的视频属性抓取结束
# 开始BV号为1dh411R7yK视频属性的抓取
# BV号为1dh411R7yK的视频属性抓取结束
# 开始BV号为1SK411N7CV视频属性的抓取
# BV号为1SK411N7CV的视频属性抓取结束
# 开始BV号为1qK411K7ug视频属性的抓取
# BV号为1qK411K7ug的视频属性抓取结束
# 开始BV号为1ZD4y1o7Hx视频属性的抓取
# BV号为1ZD4y1o7Hx的视频属性抓取结束
# 开始BV号为1Xh411R7YR视频属性的抓取
# BV号为1Xh411R7YR的视频属性抓取结束
# 开始BV号为1DT4y1w7EC视频属性的抓取
# BV号为1DT4y1w7EC的视频属性抓取结束
# 开始BV号为1bV411m7qu视频属性的抓取
# BV号为1bV411m7qu的视频属性抓取结束
# 开始BV号为1D54y1y7hs视频属性的抓取
# BV号为1D54y1y7hs的视频属性抓取结束
# 开始BV号为1Q54y1C7re视频属性的抓取
# BV号为1Q54y1C7re的视频属性抓取结束
# 开始BV号为1jK411N7XY视频属性的抓取
# BV号为1jK411N7XY的视频属性抓取结束
# 开始BV号为17h411X7yQ视频属性的抓取
# BV号为17h411X7yQ的视频属性抓取结束
# 开始BV号为1Mf4y1D75f视频属性的抓取
# BV号为1Mf4y1D75f的视频属性抓取结束
# 开始BV号为14K4y1a7H9视频属性的抓取
# BV号为14K4y1a7H9的视频属性抓取结束
# 开始BV号为1jK4y1a7Nt视频属性的抓取
# BV号为1jK4y1a7Nt的视频属性抓取结束
# 开始BV号为1Y54y1m71X视频属性的抓取
# BV号为1Y54y1m71X的视频属性抓取结束
# 开始BV号为1xV41117Bm视频属性的抓取
# BV号为1xV41117Bm的视频属性抓取结束
# 开始BV号为1dy4y1y7Hx视频属性的抓取
# BV号为1dy4y1y7Hx的视频属性抓取结束
# 开始BV号为15Z4y1T7FU视频属性的抓取
# BV号为15Z4y1T7FU的视频属性抓取结束
# 开始BV号为1Sv411C7Tk视频属性的抓取
# BV号为1Sv411C7Tk的视频属性抓取结束
# 开始BV号为1W64y1F7UC视频属性的抓取
# BV号为1W64y1F7UC的视频属性抓取结束
# 开始BV号为1QZ4y1P75E视频属性的抓取
# BV号为1QZ4y1P75E的视频属性抓取结束
# 开始BV号为1Bi4y1773X视频属性的抓取
# BV号为1Bi4y1773X的视频属性抓取结束
# 开始BV号为1dy4y1C7Em视频属性的抓取
# BV号为1dy4y1C7Em的视频属性抓取结束
# 开始BV号为1nD4y1m7qe视频属性的抓取
# BV号为1nD4y1m7qe的视频属性抓取结束
# 开始BV号为14k4y1y7dJ视频属性的抓取
# BV号为14k4y1y7dJ的视频属性抓取结束
# 开始BV号为1Vf4y1D7wp视频属性的抓取
# BV号为1Vf4y1D7wp的视频属性抓取结束
# 开始BV号为1zv411C74p视频属性的抓取
# BV号为1zv411C74p的视频属性抓取结束
# 开始BV号为1Ct4y1i7tU视频属性的抓取
# BV号为1Ct4y1i7tU的视频属性抓取结束
# 开始BV号为1XA411n7XJ视频属性的抓取
# BV号为1XA411n7XJ的视频属性抓取结束
# 开始BV号为1Bi4y1M7Ko视频属性的抓取
# BV号为1Bi4y1M7Ko的视频属性抓取结束
# 开始BV号为1454y1v7iU视频属性的抓取
# BV号为1454y1v7iU的视频属性抓取结束
# 开始BV号为1hk4y127mX视频属性的抓取
# BV号为1hk4y127mX的视频属性抓取结束
# 开始BV号为1sk4y1171B视频属性的抓取
# BV号为1sk4y1171B的视频属性抓取结束
# 开始BV号为1Xa4y157Go视频属性的抓取
# BV号为1Xa4y157Go的视频属性抓取结束
# 开始BV号为13z4y1Z7yt视频属性的抓取
# BV号为13z4y1Z7yt的视频属性抓取结束
# 开始BV号为1G54y1m7dC视频属性的抓取
# BV号为1G54y1m7dC的视频属性抓取结束
# 开始BV号为18t4y1q74D视频属性的抓取
# BV号为18t4y1q74D的视频属性抓取结束
# 开始BV号为1w5411b75x视频属性的抓取
# BV号为1w5411b75x的视频属性抓取结束
# 开始BV号为1tA411776Q视频属性的抓取
# BV号为1tA411776Q的视频属性抓取结束
# 开始BV号为1ht4y1S7oi视频属性的抓取
# BV号为1ht4y1S7oi的视频属性抓取结束
# 开始BV号为1g54y1v7Nm视频属性的抓取
# BV号为1g54y1v7Nm的视频属性抓取结束
# 开始BV号为1TV411S7bx视频属性的抓取
# BV号为1TV411S7bx的视频属性抓取结束
# 开始BV号为1854y1m7Js视频属性的抓取
# BV号为1854y1m7Js的视频属性抓取结束
# 开始BV号为1La4y1j7zX视频属性的抓取
# BV号为1La4y1j7zX的视频属性抓取结束
# 开始BV号为1xa4y1j7nL视频属性的抓取
# BV号为1xa4y1j7nL的视频属性抓取结束
# 开始BV号为1St4y1S7eP视频属性的抓取
# BV号为1St4y1S7eP的视频属性抓取结束
# 开始BV号为1ya4y1j7ZK视频属性的抓取
# BV号为1ya4y1j7ZK的视频属性抓取结束
# 开始BV号为1hk4y127RR视频属性的抓取
# BV号为1hk4y127RR的视频属性抓取结束
# 开始BV号为1qt4y1i7Qe视频属性的抓取
# BV号为1qt4y1i7Qe的视频属性抓取结束
# 开始BV号为1QA411E72G视频属性的抓取
# BV号为1QA411E72G的视频属性抓取结束
# 开始BV号为1xt4y1S7xc视频属性的抓取
# BV号为1xt4y1S7xc的视频属性抓取结束
# 开始BV号为1wk4y1C7qx视频属性的抓取
# BV号为1wk4y1C7qx的视频属性抓取结束
# 开始BV号为12T4y1w7j7视频属性的抓取
# BV号为12T4y1w7j7的视频属性抓取结束
# 开始BV号为1VK4y1a7Vw视频属性的抓取
# BV号为1VK4y1a7Vw的视频属性抓取结束
# 开始BV号为1V54y127vQ视频属性的抓取
# BV号为1V54y127vQ的视频属性抓取结束
# 开始BV号为1iK411P7d1视频属性的抓取
# BV号为1iK411P7d1的视频属性抓取结束
# 开始BV号为1mt4y1S76x视频属性的抓取
# BV号为1mt4y1S76x的视频属性抓取结束
# 开始BV号为1M5411874n视频属性的抓取
# BV号为1M5411874n的视频属性抓取结束
# 开始BV号为1vZ4y157xb视频属性的抓取
# BV号为1vZ4y157xb的视频属性抓取结束
# 开始BV号为1K54y117So视频属性的抓取
# BV号为1K54y117So的视频属性抓取结束
# 开始BV号为1Rf4y1S7Aa视频属性的抓取
# BV号为1Rf4y1S7Aa的视频属性抓取结束
# 开始BV号为1Cz4y1f76X视频属性的抓取
# BV号为1Cz4y1f76X的视频属性抓取结束
# 开始BV号为1Mh41197DE视频属性的抓取
# BV号为1Mh41197DE的视频属性抓取结束
# 开始BV号为1ef4y1D7bN视频属性的抓取
# BV号为1ef4y1D7bN的视频属性抓取结束
# 开始BV号为1Sh411R7Gk视频属性的抓取
# BV号为1Sh411R7Gk的视频属性抓取结束
# 开始BV号为1DZ4y1P7MY视频属性的抓取
# BV号为1DZ4y1P7MY的视频属性抓取结束
# 开始BV号为1dZ4y1N75D视频属性的抓取
# BV号为1dZ4y1N75D的视频属性抓取结束
# 开始BV号为15f4y1D7eE视频属性的抓取
# BV号为15f4y1D7eE的视频属性抓取结束
# 开始BV号为1954y1e7d3视频属性的抓取
# BV号为1954y1e7d3的视频属性抓取结束
# 开始BV号为1YK411K7uo视频属性的抓取
# BV号为1YK411K7uo的视频属性抓取结束
# 开始BV号为1ZZ4y1K7Dc视频属性的抓取
# BV号为1ZZ4y1K7Dc的视频属性抓取结束
# 开始BV号为1oZ4y1P7DQ视频属性的抓取
# BV号为1oZ4y1P7DQ的视频属性抓取结束
# 开始BV号为1oz4y1f7Zi视频属性的抓取
# BV号为1oz4y1f7Zi的视频属性抓取结束
# 开始BV号为1up4y1e7y4视频属性的抓取
# BV号为1up4y1e7y4的视频属性抓取结束
# 开始BV号为1kK4y187jx视频属性的抓取
# BV号为1kK4y187jx的视频属性抓取结束
# 开始BV号为18h411R7MA视频属性的抓取
# BV号为18h411R7MA的视频属性抓取结束
# 开始BV号为1d54y1y7Hz视频属性的抓取
# BV号为1d54y1y7Hz的视频属性抓取结束
# 开始BV号为1t54y1v76V视频属性的抓取
# BV号为1t54y1v76V的视频属性抓取结束
# 开始BV号为1k54y1C7EP视频属性的抓取
# BV号为1k54y1C7EP的视频属性抓取结束
# 开始BV号为13p4y1e7HC视频属性的抓取
# BV号为13p4y1e7HC的视频属性抓取结束
# 开始BV号为1A54y1y77Q视频属性的抓取
# BV号为1A54y1y77Q的视频属性抓取结束
# 开始BV号为1B54y1C7AW视频属性的抓取
# BV号为1B54y1C7AW的视频属性抓取结束
# 开始BV号为1N5411872v视频属性的抓取
# BV号为1N5411872v的视频属性抓取结束
# 开始BV号为1Xk4y1k7Bw视频属性的抓取
# BV号为1Xk4y1k7Bw的视频属性抓取结束
# 开始BV号为1JZ4y1N76g视频属性的抓取
# BV号为1JZ4y1N76g的视频属性抓取结束
# 开始BV号为1Xp4y1Y7mL视频属性的抓取
# BV号为1Xp4y1Y7mL的视频属性抓取结束
# 开始BV号为1tK411P7g4视频属性的抓取
# BV号为1tK411P7g4的视频属性抓取结束
# 开始BV号为1gT4y1c7Qv视频属性的抓取
# BV号为1gT4y1c7Qv的视频属性抓取结束
# 开始BV号为1RA411E73P视频属性的抓取
# BV号为1RA411E73P的视频属性抓取结束
# 开始BV号为1zK4y1a7qh视频属性的抓取
# BV号为1zK4y1a7qh的视频属性抓取结束
# 开始BV号为1VZ4y157Jn视频属性的抓取
# BV号为1VZ4y157Jn的视频属性抓取结束
# 开始BV号为1Qt4y1Y76x视频属性的抓取
# BV号为1Qt4y1Y76x的视频属性抓取结束
# 开始BV号为1Xi4y1j7fM视频属性的抓取
# BV号为1Xi4y1j7fM的视频属性抓取结束
# 开始BV号为1Dt4y1v7Z3视频属性的抓取
# BV号为1Dt4y1v7Z3的视频属性抓取结束
# 开始BV号为1qa4y1L7zE视频属性的抓取
# BV号为1qa4y1L7zE的视频属性抓取结束
# 开始BV号为1VV411y7Yw视频属性的抓取
# BV号为1VV411y7Yw的视频属性抓取结束
# 开始BV号为1HV411y7AM视频属性的抓取
# BV号为1HV411y7AM的视频属性抓取结束
# 开始BV号为1ok4y1k7gQ视频属性的抓取
# BV号为1ok4y1k7gQ的视频属性抓取结束
# 开始BV号为1m541157Cv视频属性的抓取
# BV号为1m541157Cv的视频属性抓取结束
# 开始BV号为1aa4y1L7NC视频属性的抓取
# BV号为1aa4y1L7NC的视频属性抓取结束
# 开始BV号为1L541177t9视频属性的抓取
# BV号为1L541177t9的视频属性抓取结束
# 开始BV号为1tf4y1i7qd视频属性的抓取
# BV号为1tf4y1i7qd的视频属性抓取结束
# 开始BV号为1uT4y1w7cA视频属性的抓取
# BV号为1uT4y1w7cA的视频属性抓取结束
# 开始BV号为1Gr4y1w7WY视频属性的抓取
# BV号为1Gr4y1w7WY的视频属性抓取结束
# 开始BV号为1vy4y1B7Zq视频属性的抓取
# BV号为1vy4y1B7Zq的视频属性抓取结束
# 开始BV号为1gt4y1i7aE视频属性的抓取
# BV号为1gt4y1i7aE的视频属性抓取结束
# 开始BV号为1ty4y1C7Pc视频属性的抓取
# BV号为1ty4y1C7Pc的视频属性抓取结束
# 开始BV号为1Hh41197Uw视频属性的抓取
# BV号为1Hh41197Uw的视频属性抓取结束
# 开始BV号为1zz4y1o7u7视频属性的抓取
# BV号为1zz4y1o7u7的视频属性抓取结束
# 开始BV号为1pp4y1Y7rD视频属性的抓取
# BV号为1pp4y1Y7rD的视频属性抓取结束
# 开始BV号为1Aa411A7xE视频属性的抓取
# BV号为1Aa411A7xE的视频属性抓取结束
# 开始BV号为1gt4y1i7cJ视频属性的抓取
# BV号为1gt4y1i7cJ的视频属性抓取结束
# 开始BV号为1gA411E7iJ视频属性的抓取
# BV号为1gA411E7iJ的视频属性抓取结束
# 开始BV号为1DK411A7KT视频属性的抓取
# BV号为1DK411A7KT的视频属性抓取结束
# 开始BV号为1HA411E7iD视频属性的抓取
# BV号为1HA411E7iD的视频属性抓取结束
# 开始BV号为1tf4y1i7ea视频属性的抓取
# BV号为1tf4y1i7ea的视频属性抓取结束
# 开始BV号为1tK411A7RK视频属性的抓取
# BV号为1tK411A7RK的视频属性抓取结束
# 开始BV号为1F54y1C79V视频属性的抓取
# BV号为1F54y1C79V的视频属性抓取结束
# 开始BV号为1ef4y1B7wD视频属性的抓取
# BV号为1ef4y1B7wD的视频属性抓取结束
# 开始BV号为1h54y1C7g4视频属性的抓取
# BV号为1h54y1C7g4的视频属性抓取结束
# 开始BV号为1ry4y1r7xB视频属性的抓取
# BV号为1ry4y1r7xB的视频属性抓取结束
# 开始BV号为1hK411N7oA视频属性的抓取
# BV号为1hK411N7oA的视频属性抓取结束
# 开始BV号为19t4y1Y72r视频属性的抓取
# BV号为19t4y1Y72r的视频属性抓取结束
# 开始BV号为1BV411y7yx视频属性的抓取
# BV号为1BV411y7yx的视频属性抓取结束
# 开始BV号为1VV41127aj视频属性的抓取
# BV号为1VV41127aj的视频属性抓取结束
# 开始BV号为1X54y117YL视频属性的抓取
# BV号为1X54y117YL的视频属性抓取结束
# 开始BV号为1M5411L7QQ视频属性的抓取
# BV号为1M5411L7QQ的视频属性抓取结束
# 开始BV号为1vi4y1j7Bh视频属性的抓取
# BV号为1vi4y1j7Bh的视频属性抓取结束
# 开始BV号为1Tr4y1w7S7视频属性的抓取
# BV号为1Tr4y1w7S7的视频属性抓取结束
# 开始BV号为1Ma4y1L7fH视频属性的抓取
# BV号为1Ma4y1L7fH的视频属性抓取结束
# 开始BV号为1np4y1Y7XL视频属性的抓取
# BV号为1np4y1Y7XL的视频属性抓取结束
# 开始BV号为1ka4y1L7dA视频属性的抓取
# BV号为1ka4y1L7dA的视频属性抓取结束
# 开始BV号为1Wk4y1C7gw视频属性的抓取
# 开始BV号为1Wk4y1C7gw视频属性的抓取
# 开始BV号为1Wk4y1C7gw视频属性的抓取
# BV号为1Wk4y1C7gw的视频属性抓取结束
# 开始BV号为1cp4y1Y7sp视频属性的抓取
# BV号为1cp4y1Y7sp的视频属性抓取结束
# 开始BV号为1ff4y1B7JD视频属性的抓取
# BV号为1ff4y1B7JD的视频属性抓取结束
# 开始BV号为1da4y1W7HE视频属性的抓取
# BV号为1da4y1W7HE的视频属性抓取结束
# 开始BV号为1GK411A7Pk视频属性的抓取
# BV号为1GK411A7Pk的视频属性抓取结束
# 开始BV号为18K4y1h7nR视频属性的抓取
# BV号为18K4y1h7nR的视频属性抓取结束
# 开始BV号为1p5411L7jW视频属性的抓取
# BV号为1p5411L7jW的视频属性抓取结束
# 开始BV号为1oa411A7cs视频属性的抓取
# BV号为1oa411A7cs的视频属性抓取结束
# 开始BV号为1Vy4y187ap视频属性的抓取
# BV号为1Vy4y187ap的视频属性抓取结束
# 开始BV号为1f54y167rk视频属性的抓取
# BV号为1f54y167rk的视频属性抓取结束
# 开始BV号为1Ti4y177bk视频属性的抓取
# BV号为1Ti4y177bk的视频属性抓取结束
# 开始BV号为1Sv411k7Ay视频属性的抓取
# BV号为1Sv411k7Ay的视频属性抓取结束
# 开始BV号为1Ry4y1r7WE视频属性的抓取
# BV号为1Ry4y1r7WE的视频属性抓取结束
# 开始BV号为1Ak4y1y7Cr视频属性的抓取
# BV号为1Ak4y1y7Cr的视频属性抓取结束
# 开始BV号为1MD4y197pT视频属性的抓取
# BV号为1MD4y197pT的视频属性抓取结束
# 开始BV号为1eV411y7c2视频属性的抓取
# BV号为1eV411y7c2的视频属性抓取结束
# 开始BV号为1y5411579H视频属性的抓取
# BV号为1y5411579H的视频属性抓取结束
# 开始BV号为15Z4y1L7sj视频属性的抓取
# BV号为15Z4y1L7sj的视频属性抓取结束
# 开始BV号为1fa411w7EJ视频属性的抓取
# BV号为1fa411w7EJ的视频属性抓取结束
# 开始BV号为1Qz4y1d7q3视频属性的抓取
# BV号为1Qz4y1d7q3的视频属性抓取结束
# 开始BV号为1Yh41197Nv视频属性的抓取
# BV号为1Yh41197Nv的视频属性抓取结束
# 开始BV号为1oz4y1Z7gX视频属性的抓取
# BV号为1oz4y1Z7gX的视频属性抓取结束
# 开始BV号为1nT4y1w7vp视频属性的抓取
# BV号为1nT4y1w7vp的视频属性抓取结束
# 开始BV号为1W54y1R7W8视频属性的抓取
# BV号为1W54y1R7W8的视频属性抓取结束
# 开始BV号为1KD4y1d7up视频属性的抓取
# BV号为1KD4y1d7up的视频属性抓取结束
# 开始BV号为1br4y1w7Je视频属性的抓取
# BV号为1br4y1w7Je的视频属性抓取结束
# 开始BV号为1tr4y1w7CD视频属性的抓取
# BV号为1tr4y1w7CD的视频属性抓取结束
# 开始BV号为1xZ4y157Mh视频属性的抓取
# BV号为1xZ4y157Mh的视频属性抓取结束
# 开始BV号为1TA41177uT视频属性的抓取
# BV号为1TA41177uT的视频属性抓取结束
# 开始BV号为1hK4y1h7EJ视频属性的抓取
# BV号为1hK4y1h7EJ的视频属性抓取结束
# 开始BV号为1454y1C7i9视频属性的抓取
# BV号为1454y1C7i9的视频属性抓取结束
# 开始BV号为1Jf4y1B7Ta视频属性的抓取
# BV号为1Jf4y1B7Ta的视频属性抓取结束
# 开始BV号为1aT4y1c7oz视频属性的抓取
# BV号为1aT4y1c7oz的视频属性抓取结束
# 开始BV号为1xy4y1B7Dn视频属性的抓取
# BV号为1xy4y1B7Dn的视频属性抓取结束
# 开始BV号为1TD4y197Ky视频属性的抓取
# BV号为1TD4y197Ky的视频属性抓取结束
# 开始BV号为1wV411y7th视频属性的抓取
# BV号为1wV411y7th的视频属性抓取结束
# 开始BV号为18Z4y157Qw视频属性的抓取
# BV号为18Z4y157Qw的视频属性抓取结束
# 开始BV号为1Vy4y1z7rr视频属性的抓取
# BV号为1Vy4y1z7rr的视频属性抓取结束
# 开始BV号为1v5411j7Hs视频属性的抓取
# BV号为1v5411j7Hs的视频属性抓取结束
# 开始BV号为18D4y197oM视频属性的抓取
# BV号为18D4y197oM的视频属性抓取结束
# 开始BV号为1bD4y1d7Jq视频属性的抓取
# BV号为1bD4y1d7Jq的视频属性抓取结束
# 开始BV号为1xD4y197fa视频属性的抓取
# BV号为1xD4y197fa的视频属性抓取结束
# <ipython-input-12-141e1356cc2f>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1F54y1r7qV视频属性的抓取
# BV号为1F54y1r7qV的视频属性抓取结束
# 开始BV号为1yz4y1o7F8视频属性的抓取
# BV号为1yz4y1o7F8的视频属性抓取结束
# 开始BV号为1Yp4y1k7ak视频属性的抓取
# BV号为1Yp4y1k7ak的视频属性抓取结束
# 开始BV号为1Gy4y187aZ视频属性的抓取
# BV号为1Gy4y187aZ的视频属性抓取结束
# 开始BV号为1qp4y1Y7kJ视频属性的抓取
# BV号为1qp4y1Y7kJ的视频属性抓取结束
# 开始BV号为1ST4y1c7ty视频属性的抓取
# BV号为1ST4y1c7ty的视频属性抓取结束
# 开始BV号为1X54y167b8视频属性的抓取
# BV号为1X54y167b8的视频属性抓取结束
# 开始BV号为1Ri4y1j7nL视频属性的抓取
# BV号为1Ri4y1j7nL的视频属性抓取结束
# 开始BV号为1Kv411C7B5视频属性的抓取
# BV号为1Kv411C7B5的视频属性抓取结束
# 开始BV号为1LT4y1w779视频属性的抓取
# BV号为1LT4y1w779的视频属性抓取结束
# 开始BV号为1y54y1R7xc视频属性的抓取
# BV号为1y54y1R7xc的视频属性抓取结束
# 开始BV号为1da411w7dA视频属性的抓取
# BV号为1da411w7dA的视频属性抓取结束
# 开始BV号为15V411y7vW视频属性的抓取
# BV号为15V411y7vW的视频属性抓取结束
# 开始BV号为1Lt4y1i7Sm视频属性的抓取
# BV号为1Lt4y1i7Sm的视频属性抓取结束
# 开始BV号为1QD4y1R7uq视频属性的抓取
# BV号为1QD4y1R7uq的视频属性抓取结束
# 开始BV号为12p4y1r7ap视频属性的抓取
# BV号为12p4y1r7ap的视频属性抓取结束
# 2020-12-23 03:37:20.359893

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-11-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_shenghuo_qiche.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月    99   99    99   99   99   99   99   99    99      99   99    99   99
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月   99   99   99   99   99   99    99
# 1月   100  100  100  100  100  100   100
# 2月   100  100  100  100  100  100   100
# 3月    99   99   99   99   99   99    99
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月   100  100  100  100  100  100   100
# 7月   100  100  100  100  100  100   100
# 8月   100  100  100  100  100  100   100
# 9月   100  100  100  100  100  100   100

# %%
channel_shenghuo_qiche.to_json('channel_shenghuo_qiche.json')
