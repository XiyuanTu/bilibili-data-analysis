# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_shenghuo_huihua=pd.DataFrame(columns=columns)
channel_shenghuo_huihua
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[9]/div/a/span').click()  #选择“生活”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[9]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '生活'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[6]/a').click()  #选择“绘画”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[6]/a').text
sub_channel
# Out:
# '绘画'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(1,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_shenghuo_huihua.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-22 13:18:00.392488
# <ipython-input-10-1102175d102f>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-10-1102175d102f>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-10-1102175d102f>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1eJ411V764视频属性的抓取
# BV号为1eJ411V764的视频属性抓取结束
# <ipython-input-10-1102175d102f>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1d7411q7Eo视频属性的抓取
# BV号为1d7411q7Eo的视频属性抓取结束
# 开始BV号为1n7411q787视频属性的抓取
# BV号为1n7411q787的视频属性抓取结束
# 开始BV号为1n7411Y7P8视频属性的抓取
# BV号为1n7411Y7P8的视频属性抓取结束
# 开始BV号为1Z7411B7du视频属性的抓取
# BV号为1Z7411B7du的视频属性抓取结束
# 开始BV号为1CJ411E7Rc视频属性的抓取
# BV号为1CJ411E7Rc的视频属性抓取结束
# 开始BV号为17J411h7tV视频属性的抓取
# BV号为17J411h7tV的视频属性抓取结束
# 开始BV号为1h7411v76T视频属性的抓取
# BV号为1h7411v76T的视频属性抓取结束
# 开始BV号为1aJ411L7ic视频属性的抓取
# BV号为1aJ411L7ic的视频属性抓取结束
# 开始BV号为1n7411e7W7视频属性的抓取
# BV号为1n7411e7W7的视频属性抓取结束
# 开始BV号为1KJ411n71p视频属性的抓取
# BV号为1KJ411n71p的视频属性抓取结束
# 开始BV号为1E7411k78M视频属性的抓取
# BV号为1E7411k78M的视频属性抓取结束
# 开始BV号为11J411V78T视频属性的抓取
# BV号为11J411V78T的视频属性抓取结束
# 开始BV号为1e7411a71Z视频属性的抓取
# BV号为1e7411a71Z的视频属性抓取结束
# 开始BV号为1E7411v7Yt视频属性的抓取
# BV号为1E7411v7Yt的视频属性抓取结束
# 开始BV号为13J411V7VP视频属性的抓取
# BV号为13J411V7VP的视频属性抓取结束
# 开始BV号为1p741167Ta视频属性的抓取
# BV号为1p741167Ta的视频属性抓取结束
# 开始BV号为1o741167fz视频属性的抓取
# BV号为1o741167fz的视频属性抓取结束
# 开始BV号为1R741167HC视频属性的抓取
# BV号为1R741167HC的视频属性抓取结束
# 开始BV号为1z7411B7Fm视频属性的抓取
# BV号为1z7411B7Fm的视频属性抓取结束
# 开始BV号为18J411n7gh视频属性的抓取
# BV号为18J411n7gh的视频属性抓取结束
# 开始BV号为1aJ411V7mS视频属性的抓取
# BV号为1aJ411V7mS的视频属性抓取结束
# 开始BV号为1NJ41157iG视频属性的抓取
# BV号为1NJ41157iG的视频属性抓取结束
# 开始BV号为1eJ411E7a7视频属性的抓取
# BV号为1eJ411E7a7的视频属性抓取结束
# 开始BV号为1rJ411E7i4视频属性的抓取
# BV号为1rJ411E7i4的视频属性抓取结束
# 开始BV号为147411Y7Lr视频属性的抓取
# BV号为147411Y7Lr的视频属性抓取结束
# 开始BV号为1e7411Y79L视频属性的抓取
# BV号为1e7411Y79L的视频属性抓取结束
# 开始BV号为1K7411C7qc视频属性的抓取
# BV号为1K7411C7qc的视频属性抓取结束
# 开始BV号为1w7411i7M9视频属性的抓取
# BV号为1w7411i7M9的视频属性抓取结束
# 开始BV号为1P7411e7nc视频属性的抓取
# BV号为1P7411e7nc的视频属性抓取结束
# 开始BV号为1TJ411h7jj视频属性的抓取
# BV号为1TJ411h7jj的视频属性抓取结束
# 开始BV号为1b7411k7Ur视频属性的抓取
# BV号为1b7411k7Ur的视频属性抓取结束
# 开始BV号为137411v7mY视频属性的抓取
# BV号为137411v7mY的视频属性抓取结束
# 开始BV号为1k7411i7Mi视频属性的抓取
# BV号为1k7411i7Mi的视频属性抓取结束
# 开始BV号为19J411n7Nf视频属性的抓取
# BV号为19J411n7Nf的视频属性抓取结束
# 开始BV号为1EJ411V7rH视频属性的抓取
# BV号为1EJ411V7rH的视频属性抓取结束
# 开始BV号为1qJ411E7BS视频属性的抓取
# BV号为1qJ411E7BS的视频属性抓取结束
# 开始BV号为1f7411B7SP视频属性的抓取
# BV号为1f7411B7SP的视频属性抓取结束
# 开始BV号为1E7411q7eL视频属性的抓取
# BV号为1E7411q7eL的视频属性抓取结束
# 开始BV号为137411q7bY视频属性的抓取
# BV号为137411q7bY的视频属性抓取结束
# 开始BV号为1EJ411b7AC视频属性的抓取
# BV号为1EJ411b7AC的视频属性抓取结束
# 开始BV号为1QJ411V7nL视频属性的抓取
# BV号为1QJ411V7nL的视频属性抓取结束
# 开始BV号为1pJ411J7jj视频属性的抓取
# BV号为1pJ411J7jj的视频属性抓取结束
# 开始BV号为167411z729视频属性的抓取
# BV号为167411z729的视频属性抓取结束
# 开始BV号为11J411E7VS视频属性的抓取
# BV号为11J411E7VS的视频属性抓取结束
# 开始BV号为197411Y7zN视频属性的抓取
# BV号为197411Y7zN的视频属性抓取结束
# 开始BV号为1f7411z7HR视频属性的抓取
# BV号为1f7411z7HR的视频属性抓取结束
# 开始BV号为1hJ411p74n视频属性的抓取
# BV号为1hJ411p74n的视频属性抓取结束
# 开始BV号为1XJ411n7xc视频属性的抓取
# 开始BV号为1XJ411n7xc视频属性的抓取
# BV号为1XJ411n7xc的视频属性抓取结束
# 开始BV号为13J411G7PZ视频属性的抓取
# BV号为13J411G7PZ的视频属性抓取结束
# 开始BV号为1zJ411E7dN视频属性的抓取
# BV号为1zJ411E7dN的视频属性抓取结束
# 开始BV号为1BJ411H7AF视频属性的抓取
# BV号为1BJ411H7AF的视频属性抓取结束
# 开始BV号为1wJ411n7Yc视频属性的抓取
# BV号为1wJ411n7Yc的视频属性抓取结束
# 开始BV号为1fJ411H7Mh视频属性的抓取
# BV号为1fJ411H7Mh的视频属性抓取结束
# 开始BV号为1MJ41187vh视频属性的抓取
# BV号为1MJ41187vh的视频属性抓取结束
# 开始BV号为1GJ411H7JC视频属性的抓取
# BV号为1GJ411H7JC的视频属性抓取结束
# 开始BV号为1kJ411j7XS视频属性的抓取
# BV号为1kJ411j7XS的视频属性抓取结束
# 开始BV号为1C7411q7sn视频属性的抓取
# BV号为1C7411q7sn的视频属性抓取结束
# 开始BV号为1c7411Y7KL视频属性的抓取
# BV号为1c7411Y7KL的视频属性抓取结束
# 开始BV号为1G7411z7ec视频属性的抓取
# BV号为1G7411z7ec的视频属性抓取结束
# 开始BV号为1hJ411E7cb视频属性的抓取
# BV号为1hJ411E7cb的视频属性抓取结束
# 开始BV号为13J411h7B6视频属性的抓取
# BV号为13J411h7B6的视频属性抓取结束
# 开始BV号为1m7411i7vu视频属性的抓取
# BV号为1m7411i7vu的视频属性抓取结束
# 开始BV号为1MJ411p72E视频属性的抓取
# BV号为1MJ411p72E的视频属性抓取结束
# 开始BV号为1BJ411H7JY视频属性的抓取
# BV号为1BJ411H7JY的视频属性抓取结束
# 开始BV号为1PJ411p7MU视频属性的抓取
# BV号为1PJ411p7MU的视频属性抓取结束
# 开始BV号为1s7411r7zA视频属性的抓取
# BV号为1s7411r7zA的视频属性抓取结束
# 开始BV号为1mJ411L7bU视频属性的抓取
# BV号为1mJ411L7bU的视频属性抓取结束
# 开始BV号为1W7411k7EL视频属性的抓取
# BV号为1W7411k7EL的视频属性抓取结束
# 开始BV号为1B7411e7Pd视频属性的抓取
# BV号为1B7411e7Pd的视频属性抓取结束
# 开始BV号为1D7411k7Ke视频属性的抓取
# BV号为1D7411k7Ke的视频属性抓取结束
# 开始BV号为1o7411Y7bT视频属性的抓取
# BV号为1o7411Y7bT的视频属性抓取结束
# 开始BV号为1UJ411577a视频属性的抓取
# BV号为1UJ411577a的视频属性抓取结束
# 开始BV号为1qJ411j7XH视频属性的抓取
# BV号为1qJ411j7XH的视频属性抓取结束
# 开始BV号为1oJ411H7bi视频属性的抓取
# BV号为1oJ411H7bi的视频属性抓取结束
# 开始BV号为1JJ411L7rq视频属性的抓取
# BV号为1JJ411L7rq的视频属性抓取结束
# 开始BV号为11J411G7yT视频属性的抓取
# BV号为11J411G7yT的视频属性抓取结束
# 开始BV号为197411k7jb视频属性的抓取
# BV号为197411k7jb的视频属性抓取结束
# 开始BV号为1AJ41177Bn视频属性的抓取
# BV号为1AJ41177Bn的视频属性抓取结束
# 开始BV号为1iJ411V7CC视频属性的抓取
# BV号为1iJ411V7CC的视频属性抓取结束
# 开始BV号为1BJ411573v视频属性的抓取
# BV号为1BJ411573v的视频属性抓取结束
# 开始BV号为1aJ411j754视频属性的抓取
# BV号为1aJ411j754的视频属性抓取结束
# 开始BV号为1XJ411G72r视频属性的抓取
# BV号为1XJ411G72r的视频属性抓取结束
# 开始BV号为1hJ411p785视频属性的抓取
# BV号为1hJ411p785的视频属性抓取结束
# 开始BV号为1i7411q7hP视频属性的抓取
# BV号为1i7411q7hP的视频属性抓取结束
# 开始BV号为1w7411k7bm视频属性的抓取
# BV号为1w7411k7bm的视频属性抓取结束
# 开始BV号为1ZJ411b7y8视频属性的抓取
# BV号为1ZJ411b7y8的视频属性抓取结束
# 开始BV号为1S7411v7su视频属性的抓取
# BV号为1S7411v7su的视频属性抓取结束
# 开始BV号为1RJ411V7WR视频属性的抓取
# BV号为1RJ411V7WR的视频属性抓取结束
# 开始BV号为1aJ411G7Lu视频属性的抓取
# BV号为1aJ411G7Lu的视频属性抓取结束
# 开始BV号为1uJ411L7va视频属性的抓取
# BV号为1uJ411L7va的视频属性抓取结束
# 开始BV号为1v7411i7Hh视频属性的抓取
# BV号为1v7411i7Hh的视频属性抓取结束
# 开始BV号为1tJ411V7og视频属性的抓取
# BV号为1tJ411V7og的视频属性抓取结束
# 开始BV号为187411v7Au视频属性的抓取
# BV号为187411v7Au的视频属性抓取结束
# 开始BV号为1aJ411L7cT视频属性的抓取
# BV号为1aJ411L7cT的视频属性抓取结束
# 开始BV号为1cJ411J7BP视频属性的抓取
# BV号为1cJ411J7BP的视频属性抓取结束
# 开始BV号为1f7411q79B视频属性的抓取
# BV号为1f7411q79B的视频属性抓取结束
# 开始BV号为1B741167uN视频属性的抓取
# BV号为1B741167uN的视频属性抓取结束
# 开始BV号为1q7411i7Mw视频属性的抓取
# BV号为1q7411i7Mw的视频属性抓取结束
# 开始BV号为1V741167nY视频属性的抓取
# BV号为1V741167nY的视频属性抓取结束
# 开始BV号为187411W7R4视频属性的抓取
# BV号为187411W7R4的视频属性抓取结束
# 开始BV号为1H7411w7bj视频属性的抓取
# BV号为1H7411w7bj的视频属性抓取结束
# 开始BV号为1bj411f7ge视频属性的抓取
# BV号为1bj411f7ge的视频属性抓取结束
# 开始BV号为1N7411b7dP视频属性的抓取
# BV号为1N7411b7dP的视频属性抓取结束
# 开始BV号为1p741177tq视频属性的抓取
# BV号为1p741177tq的视频属性抓取结束
# 开始BV号为1N7411A7wC视频属性的抓取
# BV号为1N7411A7wC的视频属性抓取结束
# 开始BV号为167411H7nL视频属性的抓取
# BV号为167411H7nL的视频属性抓取结束
# 开始BV号为1K7411A7aM视频属性的抓取
# BV号为1K7411A7aM的视频属性抓取结束
# 开始BV号为117411h7mm视频属性的抓取
# BV号为117411h7mm的视频属性抓取结束
# 开始BV号为1TE411H7AU视频属性的抓取
# BV号为1TE411H7AU的视频属性抓取结束
# 开始BV号为1M741157BX视频属性的抓取
# BV号为1M741157BX的视频属性抓取结束
# 开始BV号为11741187Fo视频属性的抓取
# BV号为11741187Fo的视频属性抓取结束
# 开始BV号为1f741137An视频属性的抓取
# BV号为1f741137An的视频属性抓取结束
# 开始BV号为1b7411W7k7视频属性的抓取
# BV号为1b7411W7k7的视频属性抓取结束
# 开始BV号为1C7411j7aX视频属性的抓取
# BV号为1C7411j7aX的视频属性抓取结束
# 开始BV号为1y741147Kt视频属性的抓取
# BV号为1y741147Kt的视频属性抓取结束
# 开始BV号为1gj411f7Yu视频属性的抓取
# BV号为1gj411f7Yu的视频属性抓取结束
# 开始BV号为1T7411V7SS视频属性的抓取
# BV号为1T7411V7SS的视频属性抓取结束
# 开始BV号为1K7411w7T3视频属性的抓取
# BV号为1K7411w7T3的视频属性抓取结束
# 开始BV号为1i7411J7SP视频属性的抓取
# BV号为1i7411J7SP的视频属性抓取结束
# 开始BV号为1e7411p7Zk视频属性的抓取
# BV号为1e7411p7Zk的视频属性抓取结束
# 开始BV号为1B7411b7e5视频属性的抓取
# BV号为1B7411b7e5的视频属性抓取结束
# 开始BV号为1s7411s7UR视频属性的抓取
# BV号为1s7411s7UR的视频属性抓取结束
# 开始BV号为1g7411E7ig视频属性的抓取
# BV号为1g7411E7ig的视频属性抓取结束
# 开始BV号为1G7411u7Ru视频属性的抓取
# BV号为1G7411u7Ru的视频属性抓取结束
# 开始BV号为1v7411w7tb视频属性的抓取
# BV号为1v7411w7tb的视频属性抓取结束
# 开始BV号为1o74117724视频属性的抓取
# BV号为1o74117724的视频属性抓取结束
# 开始BV号为1F7411u733视频属性的抓取
# BV号为1F7411u733的视频属性抓取结束
# 开始BV号为147411x7GY视频属性的抓取
# BV号为147411x7GY的视频属性抓取结束
# 开始BV号为1L7411V7XF视频属性的抓取
# BV号为1L7411V7XF的视频属性抓取结束
# 开始BV号为1a7411x79V视频属性的抓取
# BV号为1a7411x79V的视频属性抓取结束
# 开始BV号为1LE411H7qU视频属性的抓取
# BV号为1LE411H7qU的视频属性抓取结束
# 开始BV号为1L7411u7Xd视频属性的抓取
# BV号为1L7411u7Xd的视频属性抓取结束
# 开始BV号为1V7411h7XJ视频属性的抓取
# BV号为1V7411h7XJ的视频属性抓取结束
# 开始BV号为1J7411J7Gh视频属性的抓取
# BV号为1J7411J7Gh的视频属性抓取结束
# 开始BV号为1Q7411T7ep视频属性的抓取
# BV号为1Q7411T7ep的视频属性抓取结束
# 开始BV号为15741137Xb视频属性的抓取
# BV号为15741137Xb的视频属性抓取结束
# 开始BV号为1B7411E7F8视频属性的抓取
# BV号为1B7411E7F8的视频属性抓取结束
# 开始BV号为1W7411W7xE视频属性的抓取
# BV号为1W7411W7xE的视频属性抓取结束
# 开始BV号为1q7411b7DQ视频属性的抓取
# BV号为1q7411b7DQ的视频属性抓取结束
# 开始BV号为1g7411u7tX视频属性的抓取
# BV号为1g7411u7tX的视频属性抓取结束
# 开始BV号为1Z7411s7rw视频属性的抓取
# BV号为1Z7411s7rw的视频属性抓取结束
# 开始BV号为1N7411N7n2视频属性的抓取
# BV号为1N7411N7n2的视频属性抓取结束
# 开始BV号为1s7411H7Dz视频属性的抓取
# BV号为1s7411H7Dz的视频属性抓取结束
# 开始BV号为1Z7411P7je视频属性的抓取
# BV号为1Z7411P7je的视频属性抓取结束
# 开始BV号为1q7411j7YA视频属性的抓取
# BV号为1q7411j7YA的视频属性抓取结束
# 开始BV号为1j7411E7GF视频属性的抓取
# BV号为1j7411E7GF的视频属性抓取结束
# 开始BV号为1o7411L7jr视频属性的抓取
# BV号为1o7411L7jr的视频属性抓取结束
# 开始BV号为1c7411G7oW视频属性的抓取
# BV号为1c7411G7oW的视频属性抓取结束
# 开始BV号为1n7411J7Wq视频属性的抓取
# BV号为1n7411J7Wq的视频属性抓取结束
# 开始BV号为1h741177YE视频属性的抓取
# BV号为1h741177YE的视频属性抓取结束
# 开始BV号为1Z7411b77p视频属性的抓取
# BV号为1Z7411b77p的视频属性抓取结束
# 开始BV号为1f741157hp视频属性的抓取
# BV号为1f741157hp的视频属性抓取结束
# 开始BV号为1d7411w7tJ视频属性的抓取
# BV号为1d7411w7tJ的视频属性抓取结束
# 开始BV号为1m7411b7nZ视频属性的抓取
# BV号为1m7411b7nZ的视频属性抓取结束
# 开始BV号为1t7411n7Xd视频属性的抓取
# BV号为1t7411n7Xd的视频属性抓取结束
# 开始BV号为1C741147UX视频属性的抓取
# BV号为1C741147UX的视频属性抓取结束
# 开始BV号为1U7411g7NJ视频属性的抓取
# BV号为1U7411g7NJ的视频属性抓取结束
# 开始BV号为1fE411n73s视频属性的抓取
# BV号为1fE411n73s的视频属性抓取结束
# 开始BV号为1D741137rj视频属性的抓取
# BV号为1D741137rj的视频属性抓取结束
# 开始BV号为1r7411W7Vy视频属性的抓取
# BV号为1r7411W7Vy的视频属性抓取结束
# 开始BV号为1L7411T7ix视频属性的抓取
# BV号为1L7411T7ix的视频属性抓取结束
# 开始BV号为197411g7M8视频属性的抓取
# BV号为197411g7M8的视频属性抓取结束
# 开始BV号为1J7411H7bL视频属性的抓取
# BV号为1J7411H7bL的视频属性抓取结束
# 开始BV号为1k7411G764视频属性的抓取
# BV号为1k7411G764的视频属性抓取结束
# 开始BV号为1n741187QL视频属性的抓取
# BV号为1n741187QL的视频属性抓取结束
# 开始BV号为1s7411u7hS视频属性的抓取
# BV号为1s7411u7hS的视频属性抓取结束
# 开始BV号为1d7411W7ws视频属性的抓取
# BV号为1d7411W7ws的视频属性抓取结束
# 开始BV号为1J7411h7b3视频属性的抓取
# BV号为1J7411h7b3的视频属性抓取结束
# 开始BV号为1m7411w7Ct视频属性的抓取
# BV号为1m7411w7Ct的视频属性抓取结束
# 开始BV号为1JE411H77j视频属性的抓取
# BV号为1JE411H77j的视频属性抓取结束
# 开始BV号为1r7411H7LS视频属性的抓取
# BV号为1r7411H7LS的视频属性抓取结束
# 开始BV号为157411n7Pp视频属性的抓取
# BV号为157411n7Pp的视频属性抓取结束
# 开始BV号为1k741177rC视频属性的抓取
# BV号为1k741177rC的视频属性抓取结束
# 开始BV号为1E7411u79c视频属性的抓取
# BV号为1E7411u79c的视频属性抓取结束
# 开始BV号为1G7411K7nD视频属性的抓取
# BV号为1G7411K7nD的视频属性抓取结束
# 开始BV号为1L7411x7ja视频属性的抓取
# BV号为1L7411x7ja的视频属性抓取结束
# 开始BV号为1e7411E715视频属性的抓取
# BV号为1e7411E715的视频属性抓取结束
# 开始BV号为1HE411J7La视频属性的抓取
# BV号为1HE411J7La的视频属性抓取结束
# 开始BV号为1F7411N73z视频属性的抓取
# BV号为1F7411N73z的视频属性抓取结束
# 开始BV号为1w741137kJ视频属性的抓取
# BV号为1w741137kJ的视频属性抓取结束
# 开始BV号为1a7411j7fe视频属性的抓取
# BV号为1a7411j7fe的视频属性抓取结束
# 开始BV号为1k7411J7Ly视频属性的抓取
# BV号为1k7411J7Ly的视频属性抓取结束
# 开始BV号为1N7411T7bj视频属性的抓取
# BV号为1N7411T7bj的视频属性抓取结束
# 开始BV号为1S7411F7q6视频属性的抓取
# BV号为1S7411F7q6的视频属性抓取结束
# 开始BV号为1r7411s7mQ视频属性的抓取
# BV号为1r7411s7mQ的视频属性抓取结束
# 开始BV号为1BE411J7Uo视频属性的抓取
# BV号为1BE411J7Uo的视频属性抓取结束
# 开始BV号为1H7411x7cA视频属性的抓取
# BV号为1H7411x7cA的视频属性抓取结束
# 开始BV号为187411w7Fu视频属性的抓取
# BV号为187411w7Fu的视频属性抓取结束
# 开始BV号为1Y7411x7Yv视频属性的抓取
# BV号为1Y7411x7Yv的视频属性抓取结束
# 开始BV号为1c7411N76h视频属性的抓取
# BV号为1c7411N76h的视频属性抓取结束
# 开始BV号为1Uj411f7GN视频属性的抓取
# BV号为1Uj411f7GN的视频属性抓取结束
# 开始BV号为1Z7411b7JF视频属性的抓取
# BV号为1Z7411b7JF的视频属性抓取结束
# 开始BV号为1y741187jP视频属性的抓取
# BV号为1y741187jP的视频属性抓取结束
# 开始BV号为1D7411H7ju视频属性的抓取
# BV号为1D7411H7ju的视频属性抓取结束
# 开始BV号为1N7411a7We视频属性的抓取
# BV号为1N7411a7We的视频属性抓取结束
# 开始BV号为1B7411w74F视频属性的抓取
# BV号为1B7411w74F的视频属性抓取结束
# 开始BV号为1V7411p7CD视频属性的抓取
# BV号为1V7411p7CD的视频属性抓取结束
# 开始BV号为197411h7mT视频属性的抓取
# BV号为197411h7mT的视频属性抓取结束
# 开始BV号为1A7411c7KS视频属性的抓取
# BV号为1A7411c7KS的视频属性抓取结束
# 开始BV号为1v7411Z7Li视频属性的抓取
# BV号为1v7411Z7Li的视频属性抓取结束
# 开始BV号为1uE411P7fM视频属性的抓取
# BV号为1uE411P7fM的视频属性抓取结束
# 开始BV号为1AE411j7yS视频属性的抓取
# BV号为1AE411j7yS的视频属性抓取结束
# 开始BV号为1VE411T7nf视频属性的抓取
# BV号为1VE411T7nf的视频属性抓取结束
# 开始BV号为14E41137cZ视频属性的抓取
# BV号为14E41137cZ的视频属性抓取结束
# 开始BV号为1r7411Z7rT视频属性的抓取
# BV号为1r7411Z7rT的视频属性抓取结束
# 开始BV号为1k741127VT视频属性的抓取
# BV号为1k741127VT的视频属性抓取结束
# 开始BV号为1t7411U7D5视频属性的抓取
# BV号为1t7411U7D5的视频属性抓取结束
# 开始BV号为1UE41147fX视频属性的抓取
# BV号为1UE41147fX的视频属性抓取结束
# 开始BV号为15E411A7W6视频属性的抓取
# BV号为15E411A7W6的视频属性抓取结束
# 开始BV号为1SE411j76J视频属性的抓取
# BV号为1SE411j76J的视频属性抓取结束
# 开始BV号为1b741127Ys视频属性的抓取
# BV号为1b741127Ys的视频属性抓取结束
# 开始BV号为1ie411x7dN视频属性的抓取
# BV号为1ie411x7dN的视频属性抓取结束
# 开始BV号为1X7411R7ny视频属性的抓取
# BV号为1X7411R7ny的视频属性抓取结束
# 开始BV号为1fE411N7Lc视频属性的抓取
# BV号为1fE411N7Lc的视频属性抓取结束
# 开始BV号为167411D7fg视频属性的抓取
# BV号为167411D7fg的视频属性抓取结束
# 开始BV号为1uE41147Lb视频属性的抓取
# BV号为1uE41147Lb的视频属性抓取结束
# 开始BV号为1GV411f7Lb视频属性的抓取
# BV号为1GV411f7Lb的视频属性抓取结束
# 开始BV号为1gE41147HV视频属性的抓取
# BV号为1gE41147HV的视频属性抓取结束
# 开始BV号为1rE41157tX视频属性的抓取
# BV号为1rE41157tX的视频属性抓取结束
# 开始BV号为1vE411g7dk视频属性的抓取
# BV号为1vE411g7dk的视频属性抓取结束
# 开始BV号为1t7411y7cd视频属性的抓取
# BV号为1t7411y7cd的视频属性抓取结束
# 开始BV号为1eE411x7is视频属性的抓取
# BV号为1eE411x7is的视频属性抓取结束
# 开始BV号为1kE411x7TG视频属性的抓取
# BV号为1kE411x7TG的视频属性抓取结束
# 开始BV号为1rE411c7AL视频属性的抓取
# BV号为1rE411c7AL的视频属性抓取结束
# 开始BV号为16E411P7FM视频属性的抓取
# BV号为16E411P7FM的视频属性抓取结束
# 开始BV号为1G7411C7Um视频属性的抓取
# BV号为1G7411C7Um的视频属性抓取结束
# 开始BV号为1EE41177Fa视频属性的抓取
# BV号为1EE41177Fa的视频属性抓取结束
# 开始BV号为1yE411T7jU视频属性的抓取
# BV号为1yE411T7jU的视频属性抓取结束
# 开始BV号为1w7411f7He视频属性的抓取
# BV号为1w7411f7He的视频属性抓取结束
# 开始BV号为1XE411u7hP视频属性的抓取
# BV号为1XE411u7hP的视频属性抓取结束
# 开始BV号为1hE411A71r视频属性的抓取
# BV号为1hE411A71r的视频属性抓取结束
# 开始BV号为1RE411s7qu视频属性的抓取
# BV号为1RE411s7qu的视频属性抓取结束
# 开始BV号为1bE411M7E5视频属性的抓取
# BV号为1bE411M7E5的视频属性抓取结束
# 开始BV号为1ME411n7Ju视频属性的抓取
# BV号为1ME411n7Ju的视频属性抓取结束
# 开始BV号为1bE411L7J8视频属性的抓取
# BV号为1bE411L7J8的视频属性抓取结束
# 开始BV号为1eE41147JH视频属性的抓取
# BV号为1eE41147JH的视频属性抓取结束
# 开始BV号为1ve411x7vc视频属性的抓取
# BV号为1ve411x7vc的视频属性抓取结束
# 开始BV号为1yE411V7Y1视频属性的抓取
# BV号为1yE411V7Y1的视频属性抓取结束
# 开始BV号为1EE411c79X视频属性的抓取
# BV号为1EE411c79X的视频属性抓取结束
# 开始BV号为167411Q7Hf视频属性的抓取
# BV号为167411Q7Hf的视频属性抓取结束
# 开始BV号为1BE411N7sG视频属性的抓取
# BV号为1BE411N7sG的视频属性抓取结束
# 开始BV号为1ZE411E7Ve视频属性的抓取
# BV号为1ZE411E7Ve的视频属性抓取结束
# 开始BV号为1cE41147N5视频属性的抓取
# BV号为1cE41147N5的视频属性抓取结束
# 开始BV号为12E41147dv视频属性的抓取
# BV号为12E41147dv的视频属性抓取结束
# 开始BV号为127411o7qX视频属性的抓取
# BV号为127411o7qX的视频属性抓取结束
# 开始BV号为1zE411p7ca视频属性的抓取
# BV号为1zE411p7ca的视频属性抓取结束
# 开始BV号为1q7411m7xL视频属性的抓取
# BV号为1q7411m7xL的视频属性抓取结束
# 开始BV号为1WE411772J视频属性的抓取
# BV号为1WE411772J的视频属性抓取结束
# 开始BV号为1AE411w75R视频属性的抓取
# BV号为1AE411w75R的视频属性抓取结束
# 开始BV号为1cA411h7Dr视频属性的抓取
# BV号为1cA411h7Dr的视频属性抓取结束
# 开始BV号为1S7411o7M8视频属性的抓取
# BV号为1S7411o7M8的视频属性抓取结束
# 开始BV号为11E411w7Tz视频属性的抓取
# BV号为11E411w7Tz的视频属性抓取结束
# 开始BV号为1C7411Z7cb视频属性的抓取
# BV号为1C7411Z7cb的视频属性抓取结束
# 开始BV号为1DE411G7Q6视频属性的抓取
# BV号为1DE411G7Q6的视频属性抓取结束
# 开始BV号为1zE411s7KL视频属性的抓取
# BV号为1zE411s7KL的视频属性抓取结束
# 开始BV号为197411976q视频属性的抓取
# BV号为197411976q的视频属性抓取结束
# 开始BV号为1Y7411d7P3视频属性的抓取
# BV号为1Y7411d7P3的视频属性抓取结束
# 开始BV号为1cE411x7Ay视频属性的抓取
# BV号为1cE411x7Ay的视频属性抓取结束
# 开始BV号为1FE411M7k3视频属性的抓取
# BV号为1FE411M7k3的视频属性抓取结束
# 开始BV号为1vE411M7bk视频属性的抓取
# BV号为1vE411M7bk的视频属性抓取结束
# 开始BV号为1C7411o7dX视频属性的抓取
# BV号为1C7411o7dX的视频属性抓取结束
# 开始BV号为1m741197Qw视频属性的抓取
# BV号为1m741197Qw的视频属性抓取结束
# 开始BV号为1u7411d7cZ视频属性的抓取
# BV号为1u7411d7cZ的视频属性抓取结束
# 开始BV号为19741197tK视频属性的抓取
# BV号为19741197tK的视频属性抓取结束
# 开始BV号为1QE411V7yv视频属性的抓取
# BV号为1QE411V7yv的视频属性抓取结束
# 开始BV号为1R741117hZ视频属性的抓取
# BV号为1R741117hZ的视频属性抓取结束
# 开始BV号为1Ve411x7kU视频属性的抓取
# BV号为1Ve411x7kU的视频属性抓取结束
# 开始BV号为1f741127aC视频属性的抓取
# BV号为1f741127aC的视频属性抓取结束
# 开始BV号为1XE411M7As视频属性的抓取
# BV号为1XE411M7As的视频属性抓取结束
# 开始BV号为1PE411n7qz视频属性的抓取
# BV号为1PE411n7qz的视频属性抓取结束
# 开始BV号为1JE41147zV视频属性的抓取
# BV号为1JE41147zV的视频属性抓取结束
# 开始BV号为1gE41137hV视频属性的抓取
# BV号为1gE41137hV的视频属性抓取结束
# 开始BV号为167411m7Rs视频属性的抓取
# BV号为167411m7Rs的视频属性抓取结束
# 开始BV号为1oE41137De视频属性的抓取
# 开始BV号为1oE41137De视频属性的抓取
# 开始BV号为1oE41137De视频属性的抓取
# 开始BV号为1oE41137De视频属性的抓取
# BV号为1oE41137De的视频属性抓取结束
# 开始BV号为1cE411J74B视频属性的抓取
# BV号为1cE411J74B的视频属性抓取结束
# 开始BV号为1HE411N7zQ视频属性的抓取
# BV号为1HE411N7zQ的视频属性抓取结束
# 开始BV号为1TE41147S6视频属性的抓取
# BV号为1TE41147S6的视频属性抓取结束
# 开始BV号为1PE411w78T视频属性的抓取
# BV号为1PE411w78T的视频属性抓取结束
# 开始BV号为1sE41177sc视频属性的抓取
# BV号为1sE41177sc的视频属性抓取结束
# 开始BV号为1JE41157LM视频属性的抓取
# BV号为1JE41157LM的视频属性抓取结束
# 开始BV号为1FE411K7ir视频属性的抓取
# BV号为1FE411K7ir的视频属性抓取结束
# 开始BV号为1hE41157NA视频属性的抓取
# BV号为1hE41157NA的视频属性抓取结束
# 开始BV号为1G7411y73m视频属性的抓取
# BV号为1G7411y73m的视频属性抓取结束
# 开始BV号为15E411E7RQ视频属性的抓取
# BV号为15E411E7RQ的视频属性抓取结束
# 开始BV号为1oE411G75v视频属性的抓取
# BV号为1oE411G75v的视频属性抓取结束
# 开始BV号为1cE411w7PV视频属性的抓取
# BV号为1cE411w7PV的视频属性抓取结束
# 开始BV号为1tE411x7Jz视频属性的抓取
# BV号为1tE411x7Jz的视频属性抓取结束
# 开始BV号为1GE41147Gi视频属性的抓取
# BV号为1GE41147Gi的视频属性抓取结束
# 开始BV号为16t4y1m7Aj视频属性的抓取
# BV号为16t4y1m7Aj的视频属性抓取结束
# 开始BV号为1RE411F7Lg视频属性的抓取
# BV号为1RE411F7Lg的视频属性抓取结束
# 开始BV号为1q7411y7h5视频属性的抓取
# BV号为1q7411y7h5的视频属性抓取结束
# 开始BV号为16K41177Ug视频属性的抓取
# BV号为16K41177Ug的视频属性抓取结束
# 开始BV号为1H7411R71y视频属性的抓取
# BV号为1H7411R71y的视频属性抓取结束
# 开始BV号为15E411T72E视频属性的抓取
# BV号为15E411T72E的视频属性抓取结束
# 开始BV号为127411R7S2视频属性的抓取
# BV号为127411R7S2的视频属性抓取结束
# 开始BV号为18E411V7iS视频属性的抓取
# BV号为18E411V7iS的视频属性抓取结束
# 开始BV号为1bE411g7eT视频属性的抓取
# BV号为1bE411g7eT的视频属性抓取结束
# 开始BV号为1o7411y7uK视频属性的抓取
# BV号为1o7411y7uK的视频属性抓取结束
# 开始BV号为1BE411V7wH视频属性的抓取
# BV号为1BE411V7wH的视频属性抓取结束
# 开始BV号为1wt4y1279x视频属性的抓取
# BV号为1wt4y1279x的视频属性抓取结束
# 开始BV号为1fe411W7X7视频属性的抓取
# BV号为1fe411W7X7的视频属性抓取结束
# 开始BV号为1vc411h7FL视频属性的抓取
# BV号为1vc411h7FL的视频属性抓取结束
# 开始BV号为1P64y1M7ef视频属性的抓取
# BV号为1P64y1M7ef的视频属性抓取结束
# 开始BV号为1MV411o7ym视频属性的抓取
# BV号为1MV411o7ym的视频属性抓取结束
# 开始BV号为1uZ4y1x7Gj视频属性的抓取
# BV号为1uZ4y1x7Gj的视频属性抓取结束
# 开始BV号为16z411b7ym视频属性的抓取
# BV号为16z411b7ym的视频属性抓取结束
# 开始BV号为18Q4y1M7yj视频属性的抓取
# BV号为18Q4y1M7yj的视频属性抓取结束
# 开始BV号为1D5411t7RE视频属性的抓取
# 开始BV号为1D5411t7RE视频属性的抓取
# BV号为1D5411t7RE的视频属性抓取结束
# 开始BV号为1Bi4y1t7im视频属性的抓取
# BV号为1Bi4y1t7im的视频属性抓取结束
# 开始BV号为1Ki4y1t7HD视频属性的抓取
# BV号为1Ki4y1t7HD的视频属性抓取结束
# 开始BV号为1pe41147WB视频属性的抓取
# BV号为1pe41147WB的视频属性抓取结束
# 开始BV号为1u54y1R78k视频属性的抓取
# BV号为1u54y1R78k的视频属性抓取结束
# 开始BV号为12A41147tY视频属性的抓取
# BV号为12A41147tY的视频属性抓取结束
# 开始BV号为1H54y197aj视频属性的抓取
# BV号为1H54y197aj的视频属性抓取结束
# 开始BV号为1a54y197Bo视频属性的抓取
# BV号为1a54y197Bo的视频属性抓取结束
# 开始BV号为1fi4y1t7Pc视频属性的抓取
# BV号为1fi4y1t7Pc的视频属性抓取结束
# 开始BV号为155411t7Ez视频属性的抓取
# BV号为155411t7Ez的视频属性抓取结束
# 开始BV号为1Jk4y1R7Ga视频属性的抓取
# BV号为1Jk4y1R7Ga的视频属性抓取结束
# 开始BV号为1R54y1Q71t视频属性的抓取
# BV号为1R54y1Q71t的视频属性抓取结束
# 开始BV号为1oC4y1p7pc视频属性的抓取
# BV号为1oC4y1p7pc的视频属性抓取结束
# 开始BV号为1HK4y1C7rh视频属性的抓取
# BV号为1HK4y1C7rh的视频属性抓取结束
# 开始BV号为1ra4y1x7WE视频属性的抓取
# BV号为1ra4y1x7WE的视频属性抓取结束
# 开始BV号为1xZ4y1x7Vg视频属性的抓取
# BV号为1xZ4y1x7Vg的视频属性抓取结束
# 开始BV号为1ck4y1R7qH视频属性的抓取
# BV号为1ck4y1R7qH的视频属性抓取结束
# 开始BV号为1vc411h7vg视频属性的抓取
# BV号为1vc411h7vg的视频属性抓取结束
# 开始BV号为1dt4y127Xf视频属性的抓取
# BV号为1dt4y127Xf的视频属性抓取结束
# 开始BV号为1da4y147bk视频属性的抓取
# BV号为1da4y147bk的视频属性抓取结束
# 开始BV号为1wV411d74r视频属性的抓取
# BV号为1wV411d74r的视频属性抓取结束
# 开始BV号为14f4y1S72S视频属性的抓取
# BV号为14f4y1S72S的视频属性抓取结束
# 开始BV号为1pt4y1U7fj视频属性的抓取
# BV号为1pt4y1U7fj的视频属性抓取结束
# 开始BV号为1mi4y1t73g视频属性的抓取
# BV号为1mi4y1t73g的视频属性抓取结束
# 开始BV号为1LK41157sG视频属性的抓取
# BV号为1LK41157sG的视频属性抓取结束
# 开始BV号为1ba4y147Fh视频属性的抓取
# BV号为1ba4y147Fh的视频属性抓取结束
# 开始BV号为1i64y1u7d4视频属性的抓取
# BV号为1i64y1u7d4的视频属性抓取结束
# 开始BV号为11p4y1X7eR视频属性的抓取
# BV号为11p4y1X7eR的视频属性抓取结束
# 开始BV号为11C4y1p7jK视频属性的抓取
# BV号为11C4y1p7jK的视频属性抓取结束
# 开始BV号为15i4y187Ca视频属性的抓取
# BV号为15i4y187Ca的视频属性抓取结束
# 开始BV号为1i54y1Q7Y6视频属性的抓取
# BV号为1i54y1Q7Y6的视频属性抓取结束
# 开始BV号为1zT4y1G7aL视频属性的抓取
# BV号为1zT4y1G7aL的视频属性抓取结束
# 开始BV号为1zp4y1C7ax视频属性的抓取
# BV号为1zp4y1C7ax的视频属性抓取结束
# 开始BV号为18t4y1U7gV视频属性的抓取
# BV号为18t4y1U7gV的视频属性抓取结束
# 开始BV号为1Yt4y1U7Ds视频属性的抓取
# BV号为1Yt4y1U7Ds的视频属性抓取结束
# 开始BV号为1d54y1973N视频属性的抓取
# BV号为1d54y1973N的视频属性抓取结束
# 开始BV号为15t4y1U7bB视频属性的抓取
# BV号为15t4y1U7bB的视频属性抓取结束
# 开始BV号为1gA41187Ah视频属性的抓取
# BV号为1gA41187Ah的视频属性抓取结束
# 开始BV号为1ok4y1d72q视频属性的抓取
# BV号为1ok4y1d72q的视频属性抓取结束
# 开始BV号为1bt4y1U7C1视频属性的抓取
# BV号为1bt4y1U7C1的视频属性抓取结束
# 开始BV号为17C4y147FL视频属性的抓取
# BV号为17C4y147FL的视频属性抓取结束
# 开始BV号为17g4y1a7aV视频属性的抓取
# BV号为17g4y1a7aV的视频属性抓取结束
# 开始BV号为1HQ4y1K7Jg视频属性的抓取
# BV号为1HQ4y1K7Jg的视频属性抓取结束
# 开始BV号为17t4y1U7yo视频属性的抓取
# BV号为17t4y1U7yo的视频属性抓取结束
# 开始BV号为1RA41187A3视频属性的抓取
# BV号为1RA41187A3的视频属性抓取结束
# 开始BV号为12K4y1r749视频属性的抓取
# BV号为12K4y1r749的视频属性抓取结束
# 开始BV号为1Hp4y1y7so视频属性的抓取
# BV号为1Hp4y1y7so的视频属性抓取结束
# 开始BV号为13t4y1m72E视频属性的抓取
# BV号为13t4y1m72E的视频属性抓取结束
# 开始BV号为1qA411b7B6视频属性的抓取
# BV号为1qA411b7B6的视频属性抓取结束
# 开始BV号为17e411s7Pn视频属性的抓取
# BV号为17e411s7Pn的视频属性抓取结束
# 开始BV号为1MZ4y1x7hG视频属性的抓取
# BV号为1MZ4y1x7hG的视频属性抓取结束
# 开始BV号为1KV411d7Ft视频属性的抓取
# BV号为1KV411d7Ft的视频属性抓取结束
# 开始BV号为1ap4y1X7to视频属性的抓取
# BV号为1ap4y1X7to的视频属性抓取结束
# 开始BV号为1Cz411b7wt视频属性的抓取
# BV号为1Cz411b7wt的视频属性抓取结束
# 开始BV号为19K411L7CA视频属性的抓取
# BV号为19K411L7CA的视频属性抓取结束
# 开始BV号为1Dt4y127n4视频属性的抓取
# BV号为1Dt4y127n4的视频属性抓取结束
# 开始BV号为1TA411877y视频属性的抓取
# BV号为1TA411877y的视频属性抓取结束
# 开始BV号为1ug4y1z7mc视频属性的抓取
# BV号为1ug4y1z7mc的视频属性抓取结束
# 开始BV号为11k4y1d76n视频属性的抓取
# BV号为11k4y1d76n的视频属性抓取结束
# 开始BV号为1qg4y18775视频属性的抓取
# BV号为1qg4y18775的视频属性抓取结束
# 开始BV号为1vi4y1t7sp视频属性的抓取
# BV号为1vi4y1t7sp的视频属性抓取结束
# 开始BV号为1Me41147UF视频属性的抓取
# BV号为1Me41147UF的视频属性抓取结束
# 开始BV号为1b64y1T7ML视频属性的抓取
# BV号为1b64y1T7ML的视频属性抓取结束
# 开始BV号为14V411f7Dd视频属性的抓取
# BV号为14V411f7Dd的视频属性抓取结束
# 开始BV号为1Vk4y1R7eV视频属性的抓取
# BV号为1Vk4y1R7eV的视频属性抓取结束
# 开始BV号为1pQ4y1T7we视频属性的抓取
# BV号为1pQ4y1T7we的视频属性抓取结束
# 开始BV号为1Up4y1C7SF视频属性的抓取
# BV号为1Up4y1C7SF的视频属性抓取结束
# 开始BV号为18K41157sz视频属性的抓取
# BV号为18K41157sz的视频属性抓取结束
# 开始BV号为1CV411o7kf视频属性的抓取
# BV号为1CV411o7kf的视频属性抓取结束
# 开始BV号为1Np4y1y7yV视频属性的抓取
# BV号为1Np4y1y7yV的视频属性抓取结束
# 开始BV号为1dZ4y1W7D6视频属性的抓取
# BV号为1dZ4y1W7D6的视频属性抓取结束
# 开始BV号为1ti4y1t7zn视频属性的抓取
# BV号为1ti4y1t7zn的视频属性抓取结束
# 开始BV号为1Xp4y1X7eP视频属性的抓取
# BV号为1Xp4y1X7eP的视频属性抓取结束
# 开始BV号为1pC4y1s7rM视频属性的抓取
# BV号为1pC4y1s7rM的视频属性抓取结束
# 开始BV号为1BK41157dr视频属性的抓取
# BV号为1BK41157dr的视频属性抓取结束
# 开始BV号为1Mt4y1m7R6视频属性的抓取
# BV号为1Mt4y1m7R6的视频属性抓取结束
# 开始BV号为15z41187ny视频属性的抓取
# BV号为15z41187ny的视频属性抓取结束
# 开始BV号为1qZ4y1j7Jn视频属性的抓取
# BV号为1qZ4y1j7Jn的视频属性抓取结束
# 开始BV号为16T4y1g7pS视频属性的抓取
# BV号为16T4y1g7pS的视频属性抓取结束
# 开始BV号为1r64y1M7Vc视频属性的抓取
# BV号为1r64y1M7Vc的视频属性抓取结束
# 开始BV号为1LZ4y1x7Fp视频属性的抓取
# BV号为1LZ4y1x7Fp的视频属性抓取结束
# 开始BV号为1QV411R7yF视频属性的抓取
# BV号为1QV411R7yF的视频属性抓取结束
# 开始BV号为1Vt4y127Ve视频属性的抓取
# BV号为1Vt4y127Ve的视频属性抓取结束
# 开始BV号为18g4y1z792视频属性的抓取
# BV号为18g4y1z792的视频属性抓取结束
# 开始BV号为1yk4y1d7oN视频属性的抓取
# BV号为1yk4y1d7oN的视频属性抓取结束
# 开始BV号为1Fc411h7gZ视频属性的抓取
# BV号为1Fc411h7gZ的视频属性抓取结束
# 开始BV号为1zV411f7CL视频属性的抓取
# BV号为1zV411f7CL的视频属性抓取结束
# 开始BV号为1Se411x7CR视频属性的抓取
# BV号为1Se411x7CR的视频属性抓取结束
# 开始BV号为1JK411576a视频属性的抓取
# BV号为1JK411576a的视频属性抓取结束
# 开始BV号为12g4y187Fk视频属性的抓取
# BV号为12g4y187Fk的视频属性抓取结束
# 开始BV号为1kV411f7JJ视频属性的抓取
# BV号为1kV411f7JJ的视频属性抓取结束
# 开始BV号为1r64y1T7LT视频属性的抓取
# BV号为1r64y1T7LT的视频属性抓取结束
# 开始BV号为1WC4y1H76v视频属性的抓取
# BV号为1WC4y1H76v的视频属性抓取结束
# 开始BV号为1i541147XD视频属性的抓取
# BV号为1i541147XD的视频属性抓取结束
# 开始BV号为1Qp4y1Q77N视频属性的抓取
# BV号为1Qp4y1Q77N的视频属性抓取结束
# 开始BV号为1J5411s7wV视频属性的抓取
# BV号为1J5411s7wV的视频属性抓取结束
# 开始BV号为1854y1X7VA视频属性的抓取
# BV号为1854y1X7VA的视频属性抓取结束
# 开始BV号为1bp4y1Q7xE视频属性的抓取
# BV号为1bp4y1Q7xE的视频属性抓取结束
# 开始BV号为1Bp4y1Q7br视频属性的抓取
# BV号为1Bp4y1Q7br的视频属性抓取结束
# 开始BV号为1tp4y197Sr视频属性的抓取
# BV号为1tp4y197Sr的视频属性抓取结束
# 开始BV号为1Re411s7RZ视频属性的抓取
# BV号为1Re411s7RZ的视频属性抓取结束
# 开始BV号为1Lp4y1Q7p6视频属性的抓取
# BV号为1Lp4y1Q7p6的视频属性抓取结束
# 开始BV号为1tz4y1R7LK视频属性的抓取
# BV号为1tz4y1R7LK的视频属性抓取结束
# 开始BV号为1zt4y1C7fz视频属性的抓取
# BV号为1zt4y1C7fz的视频属性抓取结束
# 开始BV号为1Tf4y1U7pF视频属性的抓取
# BV号为1Tf4y1U7pF的视频属性抓取结束
# 开始BV号为1vi4y1s72p视频属性的抓取
# BV号为1vi4y1s72p的视频属性抓取结束
# 开始BV号为11k4y1k7vv视频属性的抓取
# BV号为11k4y1k7vv的视频属性抓取结束
# 开始BV号为13V411C73d视频属性的抓取
# BV号为13V411C73d的视频属性抓取结束
# 开始BV号为1qQ4y1N7n3视频属性的抓取
# BV号为1qQ4y1N7n3的视频属性抓取结束
# 开始BV号为1Si4y147Hi视频属性的抓取
# BV号为1Si4y147Hi的视频属性抓取结束
# 开始BV号为1AC4y1p7wW视频属性的抓取
# BV号为1AC4y1p7wW的视频属性抓取结束
# 开始BV号为1B54y1D7Aj视频属性的抓取
# BV号为1B54y1D7Aj的视频属性抓取结束
# 开始BV号为1fC4y1W7Fg视频属性的抓取
# BV号为1fC4y1W7Fg的视频属性抓取结束
# 开始BV号为11t4y1y7LM视频属性的抓取
# BV号为11t4y1y7LM的视频属性抓取结束
# 开始BV号为1ti4y147SY视频属性的抓取
# BV号为1ti4y147SY的视频属性抓取结束
# 开始BV号为1HQ4y1T7NR视频属性的抓取
# BV号为1HQ4y1T7NR的视频属性抓取结束
# 开始BV号为1gt4y117Jj视频属性的抓取
# BV号为1gt4y117Jj的视频属性抓取结束
# 开始BV号为1Qz411v71g视频属性的抓取
# BV号为1Qz411v71g的视频属性抓取结束
# 开始BV号为1nT4y1g7BV视频属性的抓取
# BV号为1nT4y1g7BV的视频属性抓取结束
# 开始BV号为13K4y1t7Vi视频属性的抓取
# BV号为13K4y1t7Vi的视频属性抓取结束
# 开始BV号为1CV411C7wU视频属性的抓取
# BV号为1CV411C7wU的视频属性抓取结束
# 开始BV号为1ai4y1t7LX视频属性的抓取
# BV号为1ai4y1t7LX的视频属性抓取结束
# 开始BV号为1pV411C7e9视频属性的抓取
# BV号为1pV411C7e9的视频属性抓取结束
# 开始BV号为1tT4y1g7yt视频属性的抓取
# BV号为1tT4y1g7yt的视频属性抓取结束
# 开始BV号为1Ya4y1i7qG视频属性的抓取
# BV号为1Ya4y1i7qG的视频属性抓取结束
# 开始BV号为1Ha4y1e7aZ视频属性的抓取
# BV号为1Ha4y1e7aZ的视频属性抓取结束
# 开始BV号为1G5411x7ew视频属性的抓取
# BV号为1G5411x7ew的视频属性抓取结束
# 开始BV号为1qg4y1z7E8视频属性的抓取
# BV号为1qg4y1z7E8的视频属性抓取结束
# 开始BV号为12Q4y1A7Yg视频属性的抓取
# BV号为12Q4y1A7Yg的视频属性抓取结束
# 开始BV号为1NV411o7XY视频属性的抓取
# BV号为1NV411o7XY的视频属性抓取结束
# 开始BV号为1pg4y1B7Mm视频属性的抓取
# BV号为1pg4y1B7Mm的视频属性抓取结束
# 开始BV号为11a4y1e7wA视频属性的抓取
# BV号为11a4y1e7wA的视频属性抓取结束
# 开始BV号为1qt4y1C7jG视频属性的抓取
# BV号为1qt4y1C7jG的视频属性抓取结束
# 开始BV号为1vf4y1S7TE视频属性的抓取
# BV号为1vf4y1S7TE的视频属性抓取结束
# 开始BV号为19p4y1Q7hB视频属性的抓取
# BV号为19p4y1Q7hB的视频属性抓取结束
# 开始BV号为17i4y1b7aF视频属性的抓取
# BV号为17i4y1b7aF的视频属性抓取结束
# 开始BV号为1KK4y187dm视频属性的抓取
# BV号为1KK4y187dm的视频属性抓取结束
# 开始BV号为1Te411W79K视频属性的抓取
# BV号为1Te411W79K的视频属性抓取结束
# 开始BV号为1da4y1i7vP视频属性的抓取
# BV号为1da4y1i7vP的视频属性抓取结束
# 开始BV号为1DC4y1W7Wd视频属性的抓取
# BV号为1DC4y1W7Wd的视频属性抓取结束
# 开始BV号为1XZ4y1s767视频属性的抓取
# BV号为1XZ4y1s767的视频属性抓取结束
# 开始BV号为1NQ4y1K7VB视频属性的抓取
# BV号为1NQ4y1K7VB的视频属性抓取结束
# 开始BV号为1HQ4y1P7G1视频属性的抓取
# BV号为1HQ4y1P7G1的视频属性抓取结束
# 开始BV号为1Ht4y1C7BB视频属性的抓取
# BV号为1Ht4y1C7BB的视频属性抓取结束
# 开始BV号为15z4y197yQ视频属性的抓取
# BV号为15z4y197yQ的视频属性抓取结束
# 开始BV号为1Ut4y1y7oz视频属性的抓取
# BV号为1Ut4y1y7oz的视频属性抓取结束
# 开始BV号为1VT4y1g7b6视频属性的抓取
# BV号为1VT4y1g7b6的视频属性抓取结束
# 开始BV号为1bQ4y1N75U视频属性的抓取
# BV号为1bQ4y1N75U的视频属性抓取结束
# 开始BV号为1VK4y187db视频属性的抓取
# BV号为1VK4y187db的视频属性抓取结束
# 开始BV号为1154y1X7Rh视频属性的抓取
# BV号为1154y1X7Rh的视频属性抓取结束
# 开始BV号为1sg4y1i71C视频属性的抓取
# BV号为1sg4y1i71C的视频属性抓取结束
# 开始BV号为17e411W7K2视频属性的抓取
# BV号为17e411W7K2的视频属性抓取结束
# 开始BV号为1Nz411z7CQ视频属性的抓取
# BV号为1Nz411z7CQ的视频属性抓取结束
# 开始BV号为1np4y1X7uf视频属性的抓取
# BV号为1np4y1X7uf的视频属性抓取结束
# 开始BV号为11A411t7ok视频属性的抓取
# BV号为11A411t7ok的视频属性抓取结束
# 开始BV号为1Nz411i7zD视频属性的抓取
# BV号为1Nz411i7zD的视频属性抓取结束
# 开始BV号为1Ft4y117tm视频属性的抓取
# BV号为1Ft4y117tm的视频属性抓取结束
# 开始BV号为13z4y1973C视频属性的抓取
# BV号为13z4y1973C的视频属性抓取结束
# 开始BV号为1XK411W7c5视频属性的抓取
# BV号为1XK411W7c5的视频属性抓取结束
# 开始BV号为1Pi4y1b73o视频属性的抓取
# BV号为1Pi4y1b73o的视频属性抓取结束
# 开始BV号为12a4y1i7Ja视频属性的抓取
# BV号为12a4y1i7Ja的视频属性抓取结束
# 开始BV号为1oZ4y1p7Km视频属性的抓取
# BV号为1oZ4y1p7Km的视频属性抓取结束
# 开始BV号为1Gp4y197mL视频属性的抓取
# BV号为1Gp4y197mL的视频属性抓取结束
# 开始BV号为19p4y1S7gs视频属性的抓取
# BV号为19p4y1S7gs的视频属性抓取结束
# 开始BV号为1Vt4y117eA视频属性的抓取
# BV号为1Vt4y117eA的视频属性抓取结束
# 开始BV号为1G5411s7Vp视频属性的抓取
# BV号为1G5411s7Vp的视频属性抓取结束
# 开始BV号为1qi4y1475L视频属性的抓取
# BV号为1qi4y1475L的视频属性抓取结束
# 开始BV号为1w54y1Q7PG视频属性的抓取
# BV号为1w54y1Q7PG的视频属性抓取结束
# 开始BV号为1Xi4y147E6视频属性的抓取
# BV号为1Xi4y147E6的视频属性抓取结束
# 开始BV号为1Hz4y197a6视频属性的抓取
# BV号为1Hz4y197a6的视频属性抓取结束
# 开始BV号为14V411d7v3视频属性的抓取
# BV号为14V411d7v3的视频属性抓取结束
# 开始BV号为1ff4y1m7Gt视频属性的抓取
# BV号为1ff4y1m7Gt的视频属性抓取结束
# 开始BV号为1Vz4y1d7DN视频属性的抓取
# BV号为1Vz4y1d7DN的视频属性抓取结束
# 开始BV号为1Fa4y1v7y7视频属性的抓取
# BV号为1Fa4y1v7y7的视频属性抓取结束
# 开始BV号为1dV411d7bz视频属性的抓取
# BV号为1dV411d7bz的视频属性抓取结束
# 开始BV号为1YZ4y1s7ap视频属性的抓取
# BV号为1YZ4y1s7ap的视频属性抓取结束
# 开始BV号为1Jp4y197qi视频属性的抓取
# BV号为1Jp4y197qi的视频属性抓取结束
# 开始BV号为1RA411i77m视频属性的抓取
# BV号为1RA411i77m的视频属性抓取结束
# 开始BV号为17t4y1m7GA视频属性的抓取
# BV号为17t4y1m7GA的视频属性抓取结束
# 开始BV号为1aa4y1i7im视频属性的抓取
# BV号为1aa4y1i7im的视频属性抓取结束
# 开始BV号为1eZ4y1p7ng视频属性的抓取
# BV号为1eZ4y1p7ng的视频属性抓取结束
# 开始BV号为1Ng4y1B7Wv视频属性的抓取
# BV号为1Ng4y1B7Wv的视频属性抓取结束
# 开始BV号为1nk4y1k7B1视频属性的抓取
# BV号为1nk4y1k7B1的视频属性抓取结束
# 开始BV号为1M54y1X7yM视频属性的抓取
# BV号为1M54y1X7yM的视频属性抓取结束
# 开始BV号为1wC4y1s7nH视频属性的抓取
# BV号为1wC4y1s7nH的视频属性抓取结束
# 开始BV号为1gK411W7P5视频属性的抓取
# BV号为1gK411W7P5的视频属性抓取结束
# 开始BV号为1gt4y117jy视频属性的抓取
# BV号为1gt4y117jy的视频属性抓取结束
# 开始BV号为1W54y1X7fj视频属性的抓取
# BV号为1W54y1X7fj的视频属性抓取结束
# 开始BV号为1JT4y137eR视频属性的抓取
# BV号为1JT4y137eR的视频属性抓取结束
# 开始BV号为1LA411q75g视频属性的抓取
# BV号为1LA411q75g的视频属性抓取结束
# 开始BV号为1wz411B7DW视频属性的抓取
# BV号为1wz411B7DW的视频属性抓取结束
# 开始BV号为1mt4y117MY视频属性的抓取
# BV号为1mt4y117MY的视频属性抓取结束
# 开始BV号为1FZ4y1H7gh视频属性的抓取
# BV号为1FZ4y1H7gh的视频属性抓取结束
# 开始BV号为1Vv411B7k4视频属性的抓取
# BV号为1Vv411B7k4的视频属性抓取结束
# 开始BV号为1PZ4y1u7uv视频属性的抓取
# BV号为1PZ4y1u7uv的视频属性抓取结束
# 开始BV号为15K411H7NG视频属性的抓取
# BV号为15K411H7NG的视频属性抓取结束
# 开始BV号为1x54y1Q7GR视频属性的抓取
# BV号为1x54y1Q7GR的视频属性抓取结束
# 开始BV号为13g4y1v7Rx视频属性的抓取
# BV号为13g4y1v7Rx的视频属性抓取结束
# 开始BV号为1Ek4y1z7TL视频属性的抓取
# BV号为1Ek4y1z7TL的视频属性抓取结束
# 开始BV号为1kK4y147Ci视频属性的抓取
# BV号为1kK4y147Ci的视频属性抓取结束
# 开始BV号为1iz411i7yj视频属性的抓取
# BV号为1iz411i7yj的视频属性抓取结束
# 开始BV号为17D4y1Q7Zs视频属性的抓取
# BV号为17D4y1Q7Zs的视频属性抓取结束
# 开始BV号为1wk4y1677V视频属性的抓取
# BV号为1wk4y1677V的视频属性抓取结束
# 开始BV号为12a4y1h78p视频属性的抓取
# BV号为12a4y1h78p的视频属性抓取结束
# 开始BV号为1b54y1Q7Z8视频属性的抓取
# BV号为1b54y1Q7Z8的视频属性抓取结束
# 开始BV号为1wV411k75m视频属性的抓取
# BV号为1wV411k75m的视频属性抓取结束
# 开始BV号为1MK411p7qr视频属性的抓取
# BV号为1MK411p7qr的视频属性抓取结束
# 开始BV号为1uA411i7Zo视频属性的抓取
# BV号为1uA411i7Zo的视频属性抓取结束
# 开始BV号为1LZ4y1H7He视频属性的抓取
# BV号为1LZ4y1H7He的视频属性抓取结束
# 开始BV号为1KK4y147EW视频属性的抓取
# BV号为1KK4y147EW的视频属性抓取结束
# 开始BV号为1BZ4y1H7Uv视频属性的抓取
# BV号为1BZ4y1H7Uv的视频属性抓取结束
# 开始BV号为1Nt4y197wV视频属性的抓取
# BV号为1Nt4y197wV的视频属性抓取结束
# 开始BV号为13A411B78G视频属性的抓取
# BV号为13A411B78G的视频属性抓取结束
# 开始BV号为18z411e7gb视频属性的抓取
# BV号为18z411e7gb的视频属性抓取结束
# 开始BV号为1Xa4y1e7PG视频属性的抓取
# BV号为1Xa4y1e7PG的视频属性抓取结束
# 开始BV号为1Qz4y1Q7Yd视频属性的抓取
# BV号为1Qz4y1Q7Yd的视频属性抓取结束
# 开始BV号为1gp4y1D7Nf视频属性的抓取
# BV号为1gp4y1D7Nf的视频属性抓取结束
# 开始BV号为1Tz411v7Hp视频属性的抓取
# BV号为1Tz411v7Hp的视频属性抓取结束
# 开始BV号为1W54y1Q7iR视频属性的抓取
# BV号为1W54y1Q7iR的视频属性抓取结束
# 开始BV号为1TZ4y1H7UR视频属性的抓取
# BV号为1TZ4y1H7UR的视频属性抓取结束
# 开始BV号为1Lz4y1X7JQ视频属性的抓取
# BV号为1Lz4y1X7JQ的视频属性抓取结束
# 开始BV号为1bv41167wL视频属性的抓取
# BV号为1bv41167wL的视频属性抓取结束
# 开始BV号为19z411i7fd视频属性的抓取
# BV号为19z411i7fd的视频属性抓取结束
# 开始BV号为1PV411k7Xe视频属性的抓取
# BV号为1PV411k7Xe的视频属性抓取结束
# 开始BV号为1v54y1Q76k视频属性的抓取
# BV号为1v54y1Q76k的视频属性抓取结束
# 开始BV号为1qK411n7dJ视频属性的抓取
# BV号为1qK411n7dJ的视频属性抓取结束
# 开始BV号为1fp4y1S7U9视频属性的抓取
# BV号为1fp4y1S7U9的视频属性抓取结束
# 开始BV号为1zK411p72V视频属性的抓取
# BV号为1zK411p72V的视频属性抓取结束
# 开始BV号为1454y1Q7zu视频属性的抓取
# BV号为1454y1Q7zu的视频属性抓取结束
# 开始BV号为1af4y117xq视频属性的抓取
# BV号为1af4y117xq的视频属性抓取结束
# 开始BV号为12z4y197j4视频属性的抓取
# BV号为12z4y197j4的视频属性抓取结束
# 开始BV号为1Ra4y1Y7Tq视频属性的抓取
# BV号为1Ra4y1Y7Tq的视频属性抓取结束
# 开始BV号为1k5411W7Hj视频属性的抓取
# BV号为1k5411W7Hj的视频属性抓取结束
# 开始BV号为1ZA411v7VM视频属性的抓取
# BV号为1ZA411v7VM的视频属性抓取结束
# 开始BV号为1UC4y1a75V视频属性的抓取
# BV号为1UC4y1a75V的视频属性抓取结束
# 开始BV号为1NZ4y1u7Sy视频属性的抓取
# BV号为1NZ4y1u7Sy的视频属性抓取结束
# 开始BV号为1CK411n7RZ视频属性的抓取
# BV号为1CK411n7RZ的视频属性抓取结束
# 开始BV号为165411Y7Hc视频属性的抓取
# BV号为165411Y7Hc的视频属性抓取结束
# 开始BV号为1Jk4y1z7Sx视频属性的抓取
# BV号为1Jk4y1z7Sx的视频属性抓取结束
# 开始BV号为14i4y1G7LF视频属性的抓取
# BV号为14i4y1G7LF的视频属性抓取结束
# 开始BV号为1zT4y1E7WY视频属性的抓取
# BV号为1zT4y1E7WY的视频属性抓取结束
# 开始BV号为1mp4y1S77z视频属性的抓取
# BV号为1mp4y1S77z的视频属性抓取结束
# 开始BV号为1ZK411n7z8视频属性的抓取
# BV号为1ZK411n7z8的视频属性抓取结束
# 开始BV号为1mp4y1S7Ui视频属性的抓取
# BV号为1mp4y1S7Ui的视频属性抓取结束
# 开始BV号为16Q4y1P7Hk视频属性的抓取
# BV号为16Q4y1P7Hk的视频属性抓取结束
# 开始BV号为1B5411p79z视频属性的抓取
# BV号为1B5411p79z的视频属性抓取结束
# 开始BV号为1Kz4y1X7SC视频属性的抓取
# BV号为1Kz4y1X7SC的视频属性抓取结束
# 开始BV号为1Tt4y1y7RX视频属性的抓取
# BV号为1Tt4y1y7RX的视频属性抓取结束
# 开始BV号为1WT4y177rL视频属性的抓取
# BV号为1WT4y177rL的视频属性抓取结束
# 开始BV号为1mT4y1E7X5视频属性的抓取
# BV号为1mT4y1E7X5的视频属性抓取结束
# 开始BV号为1pV411r7sk视频属性的抓取
# BV号为1pV411r7sk的视频属性抓取结束
# 开始BV号为1yk4y1z7ne视频属性的抓取
# BV号为1yk4y1z7ne的视频属性抓取结束
# 开始BV号为1gT4y1J7Ya视频属性的抓取
# BV号为1gT4y1J7Ya的视频属性抓取结束
# 开始BV号为1dv411q7qi视频属性的抓取
# BV号为1dv411q7qi的视频属性抓取结束
# 开始BV号为1s54y1B7Hs视频属性的抓取
# BV号为1s54y1B7Hs的视频属性抓取结束
# 开始BV号为1BT4y1J76z视频属性的抓取
# BV号为1BT4y1J76z的视频属性抓取结束
# 开始BV号为16f4y127qd视频属性的抓取
# BV号为16f4y127qd的视频属性抓取结束
# 开始BV号为1oa4y1a7fm视频属性的抓取
# BV号为1oa4y1a7fm的视频属性抓取结束
# 开始BV号为1gi4y1x7FB视频属性的抓取
# BV号为1gi4y1x7FB的视频属性抓取结束
# 开始BV号为1Av411z7hr视频属性的抓取
# BV号为1Av411z7hr的视频属性抓取结束
# 开始BV号为1r5411W7q2视频属性的抓取
# BV号为1r5411W7q2的视频属性抓取结束
# 开始BV号为1sv411B7xY视频属性的抓取
# BV号为1sv411B7xY的视频属性抓取结束
# 开始BV号为1kz4y1975d视频属性的抓取
# BV号为1kz4y1975d的视频属性抓取结束
# 开始BV号为15i4y1G7QM视频属性的抓取
# BV号为15i4y1G7QM的视频属性抓取结束
# 开始BV号为1bz4y197dD视频属性的抓取
# BV号为1bz4y197dD的视频属性抓取结束
# 开始BV号为1Wg4y1q7Wh视频属性的抓取
# BV号为1Wg4y1q7Wh的视频属性抓取结束
# <ipython-input-10-1102175d102f>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1ht4y1y7Co视频属性的抓取
# BV号为1ht4y1y7Co的视频属性抓取结束
# 开始BV号为1jV411k7f2视频属性的抓取
# BV号为1jV411k7f2的视频属性抓取结束
# 开始BV号为1Uz411e77j视频属性的抓取
# BV号为1Uz411e77j的视频属性抓取结束
# 开始BV号为17v411z7TV视频属性的抓取
# BV号为17v411z7TV的视频属性抓取结束
# 开始BV号为1uK4y147EF视频属性的抓取
# BV号为1uK4y147EF的视频属性抓取结束
# 开始BV号为1MC4y1a7o3视频属性的抓取
# BV号为1MC4y1a7o3的视频属性抓取结束
# 开始BV号为1Vi4y1V7Wt视频属性的抓取
# BV号为1Vi4y1V7Wt的视频属性抓取结束
# 开始BV号为18v411B7JK视频属性的抓取
# BV号为18v411B7JK的视频属性抓取结束
# 开始BV号为1P5411Y7Jn视频属性的抓取
# BV号为1P5411Y7Jn的视频属性抓取结束
# 开始BV号为1EZ4y1H7vy视频属性的抓取
# BV号为1EZ4y1H7vy的视频属性抓取结束
# 开始BV号为1YK4y147mb视频属性的抓取
# BV号为1YK4y147mb的视频属性抓取结束
# 开始BV号为19z4y197vM视频属性的抓取
# BV号为19z4y197vM的视频属性抓取结束
# 开始BV号为13v41167z2视频属性的抓取
# BV号为13v41167z2的视频属性抓取结束
# 开始BV号为1yC4y1a7MK视频属性的抓取
# BV号为1yC4y1a7MK的视频属性抓取结束
# 开始BV号为1rZ4y1H7JS视频属性的抓取
# BV号为1rZ4y1H7JS的视频属性抓取结束
# 开始BV号为1Ek4y1z7Hp视频属性的抓取
# BV号为1Ek4y1z7Hp的视频属性抓取结束
# 开始BV号为12Z4y1H7Kx视频属性的抓取
# BV号为12Z4y1H7Kx的视频属性抓取结束
# 开始BV号为1Xz411i7Ct视频属性的抓取
# BV号为1Xz411i7Ct的视频属性抓取结束
# 开始BV号为1C5411Y7gj视频属性的抓取
# BV号为1C5411Y7gj的视频属性抓取结束
# 开始BV号为15T4y1J7cv视频属性的抓取
# BV号为15T4y1J7cv的视频属性抓取结束
# 开始BV号为1VA411B7Xi视频属性的抓取
# BV号为1VA411B7Xi的视频属性抓取结束
# 开始BV号为17p4y1D7zD视频属性的抓取
# BV号为17p4y1D7zD的视频属性抓取结束
# 开始BV号为1et4y1y7gc视频属性的抓取
# BV号为1et4y1y7gc的视频属性抓取结束
# 开始BV号为1BD4y1D7Z2视频属性的抓取
# BV号为1BD4y1D7Z2的视频属性抓取结束
# 开始BV号为1Mp4y1D7hB视频属性的抓取
# BV号为1Mp4y1D7hB的视频属性抓取结束
# 开始BV号为1sK411H7yi视频属性的抓取
# BV号为1sK411H7yi的视频属性抓取结束
# 开始BV号为1Jp4y1S7V8视频属性的抓取
# BV号为1Jp4y1S7V8的视频属性抓取结束
# 开始BV号为14v411q72H视频属性的抓取
# BV号为14v411q72H的视频属性抓取结束
# 开始BV号为12D4y1m7Zv视频属性的抓取
# BV号为12D4y1m7Zv的视频属性抓取结束
# 开始BV号为1FK411n7YB视频属性的抓取
# BV号为1FK411n7YB的视频属性抓取结束
# 开始BV号为1i5411Y71n视频属性的抓取
# BV号为1i5411Y71n的视频属性抓取结束
# 开始BV号为1ok4y127yF视频属性的抓取
# BV号为1ok4y127yF的视频属性抓取结束
# 开始BV号为1kk4y1m7Kj视频属性的抓取
# BV号为1kk4y1m7Kj的视频属性抓取结束
# 开始BV号为1tC4y1h7F9视频属性的抓取
# BV号为1tC4y1h7F9的视频属性抓取结束
# 开始BV号为1Q54y1q7fp视频属性的抓取
# BV号为1Q54y1q7fp的视频属性抓取结束
# 开始BV号为1cT4y1E7Dc视频属性的抓取
# BV号为1cT4y1E7Dc的视频属性抓取结束
# 开始BV号为16p4y1S7gq视频属性的抓取
# BV号为16p4y1S7gq的视频属性抓取结束
# 开始BV号为1zv411B7zr视频属性的抓取
# BV号为1zv411B7zr的视频属性抓取结束
# 开始BV号为1LC4y1b7k3视频属性的抓取
# BV号为1LC4y1b7k3的视频属性抓取结束
# 开始BV号为1g5411e7EM视频属性的抓取
# BV号为1g5411e7EM的视频属性抓取结束
# 开始BV号为1WT4y1j7en视频属性的抓取
# BV号为1WT4y1j7en的视频属性抓取结束
# 开始BV号为1r54y1S7Z8视频属性的抓取
# BV号为1r54y1S7Z8的视频属性抓取结束
# 开始BV号为1J5411e7ag视频属性的抓取
# BV号为1J5411e7ag的视频属性抓取结束
# 开始BV号为1ez4y1D7hu视频属性的抓取
# BV号为1ez4y1D7hu的视频属性抓取结束
# 开始BV号为1cp4y1S7Lw视频属性的抓取
# BV号为1cp4y1S7Lw的视频属性抓取结束
# 开始BV号为1yK411n7v7视频属性的抓取
# BV号为1yK411n7v7的视频属性抓取结束
# 开始BV号为1j54y1z7KD视频属性的抓取
# BV号为1j54y1z7KD的视频属性抓取结束
# 开始BV号为1f5411Y71t视频属性的抓取
# BV号为1f5411Y71t的视频属性抓取结束
# 开始BV号为1ci4y137Yq视频属性的抓取
# BV号为1ci4y137Yq的视频属性抓取结束
# 开始BV号为1yK4y1e7e2视频属性的抓取
# BV号为1yK4y1e7e2的视频属性抓取结束
# 开始BV号为1EK411H7JR视频属性的抓取
# BV号为1EK411H7JR的视频属性抓取结束
# 开始BV号为1Xh411o7Zj视频属性的抓取
# BV号为1Xh411o7Zj的视频属性抓取结束
# 开始BV号为1VC4y1h7bc视频属性的抓取
# BV号为1VC4y1h7bc的视频属性抓取结束
# 开始BV号为19t4y197Zz视频属性的抓取
# BV号为19t4y197Zz的视频属性抓取结束
# 开始BV号为1Zv411i7pw视频属性的抓取
# BV号为1Zv411i7pw的视频属性抓取结束
# 开始BV号为1154y1q788视频属性的抓取
# BV号为1154y1q788的视频属性抓取结束
# 开始BV号为1xk4y1B7pP视频属性的抓取
# 开始BV号为1xk4y1B7pP视频属性的抓取
# BV号为1xk4y1B7pP的视频属性抓取结束
# 开始BV号为18p4y1q7Kn视频属性的抓取
# BV号为18p4y1q7Kn的视频属性抓取结束
# 开始BV号为1cp4y1S7JT视频属性的抓取
# BV号为1cp4y1S7JT的视频属性抓取结束
# 开始BV号为1T54y1q7C2视频属性的抓取
# BV号为1T54y1q7C2的视频属性抓取结束
# 开始BV号为1Fh411Z7Qc视频属性的抓取
# BV号为1Fh411Z7Qc的视频属性抓取结束
# 开始BV号为1AC4y1Y77p视频属性的抓取
# BV号为1AC4y1Y77p的视频属性抓取结束
# 开始BV号为18K411H7u9视频属性的抓取
# BV号为18K411H7u9的视频属性抓取结束
# 开始BV号为11p4y1S7CR视频属性的抓取
# BV号为11p4y1S7CR的视频属性抓取结束
# 开始BV号为1HA411e7yC视频属性的抓取
# BV号为1HA411e7yC的视频属性抓取结束
# 开始BV号为1Wf4y117g7视频属性的抓取
# BV号为1Wf4y117g7的视频属性抓取结束
# 开始BV号为1Ht4y1Q7zq视频属性的抓取
# BV号为1Ht4y1Q7zq的视频属性抓取结束
# 开始BV号为1Qf4y1R7bC视频属性的抓取
# BV号为1Qf4y1R7bC的视频属性抓取结束
# 开始BV号为1Fa4y1J7ow视频属性的抓取
# BV号为1Fa4y1J7ow的视频属性抓取结束
# 开始BV号为1KK4y1x7Ht视频属性的抓取
# BV号为1KK4y1x7Ht的视频属性抓取结束
# 开始BV号为1p5411a7SY视频属性的抓取
# BV号为1p5411a7SY的视频属性抓取结束
# 开始BV号为1Hz4y1Q7QN视频属性的抓取
# BV号为1Hz4y1Q7QN的视频属性抓取结束
# 开始BV号为1bT4y177jA视频属性的抓取
# BV号为1bT4y177jA的视频属性抓取结束
# 开始BV号为18T4y1E7AV视频属性的抓取
# BV号为18T4y1E7AV的视频属性抓取结束
# 开始BV号为1yV411B7pD视频属性的抓取
# BV号为1yV411B7pD的视频属性抓取结束
# 开始BV号为1Di4y1G7Jv视频属性的抓取
# BV号为1Di4y1G7Jv的视频属性抓取结束
# 开始BV号为1fk4y1q7Qe视频属性的抓取
# BV号为1fk4y1q7Qe的视频属性抓取结束
# 开始BV号为1oK4y1s7E4视频属性的抓取
# BV号为1oK4y1s7E4的视频属性抓取结束
# 开始BV号为16f4y1R7df视频属性的抓取
# BV号为16f4y1R7df的视频属性抓取结束
# 开始BV号为1DZ4y1u7GZ视频属性的抓取
# BV号为1DZ4y1u7GZ的视频属性抓取结束
# 开始BV号为13v411z7Zj视频属性的抓取
# BV号为13v411z7Zj的视频属性抓取结束
# 开始BV号为1pz4y1D7wd视频属性的抓取
# BV号为1pz4y1D7wd的视频属性抓取结束
# 开始BV号为1mT4y1j7Mq视频属性的抓取
# BV号为1mT4y1j7Mq的视频属性抓取结束
# 开始BV号为1Sf4y1R77R视频属性的抓取
# BV号为1Sf4y1R77R的视频属性抓取结束
# 开始BV号为1a54y1q7Z8视频属性的抓取
# BV号为1a54y1q7Z8的视频属性抓取结束
# 开始BV号为1Eg4y1i7m3视频属性的抓取
# BV号为1Eg4y1i7m3的视频属性抓取结束
# 开始BV号为1kK4y1s7nf视频属性的抓取
# BV号为1kK4y1s7nf的视频属性抓取结束
# 开始BV号为1da4y1Y7A7视频属性的抓取
# BV号为1da4y1Y7A7的视频属性抓取结束
# 开始BV号为1MD4y1U7rT视频属性的抓取
# BV号为1MD4y1U7rT的视频属性抓取结束
# 开始BV号为1pp4y1q7ek视频属性的抓取
# BV号为1pp4y1q7ek的视频属性抓取结束
# 开始BV号为1bz4y1D7Hh视频属性的抓取
# BV号为1bz4y1D7Hh的视频属性抓取结束
# 开始BV号为1ha4y1a77R视频属性的抓取
# BV号为1ha4y1a77R的视频属性抓取结束
# 开始BV号为1GK4y1s7ma视频属性的抓取
# BV号为1GK4y1s7ma的视频属性抓取结束
# 开始BV号为1jf4y117PM视频属性的抓取
# BV号为1jf4y117PM的视频属性抓取结束
# 开始BV号为1vz4y1D7AN视频属性的抓取
# BV号为1vz4y1D7AN的视频属性抓取结束
# 开始BV号为1g54y1S7fA视频属性的抓取
# BV号为1g54y1S7fA的视频属性抓取结束
# 开始BV号为1kC4y1h7Zb视频属性的抓取
# BV号为1kC4y1h7Zb的视频属性抓取结束
# 开始BV号为1ah411Z7hH视频属性的抓取
# BV号为1ah411Z7hH的视频属性抓取结束
# 开始BV号为1QK411n7HC视频属性的抓取
# BV号为1QK411n7HC的视频属性抓取结束
# 开始BV号为1Sf4y117N1视频属性的抓取
# BV号为1Sf4y117N1的视频属性抓取结束
# 开始BV号为1uz4y1X7uR视频属性的抓取
# BV号为1uz4y1X7uR的视频属性抓取结束
# 开始BV号为12p4y1i78x视频属性的抓取
# BV号为12p4y1i78x的视频属性抓取结束
# 开始BV号为1W54y1S77x视频属性的抓取
# BV号为1W54y1S77x的视频属性抓取结束
# 开始BV号为1Cv411i7GU视频属性的抓取
# BV号为1Cv411i7GU的视频属性抓取结束
# 开始BV号为1Df4y1R7Vo视频属性的抓取
# BV号为1Df4y1R7Vo的视频属性抓取结束
# 开始BV号为1ei4y137GV视频属性的抓取
# BV号为1ei4y137GV的视频属性抓取结束
# 开始BV号为1Rz4y1D7bZ视频属性的抓取
# BV号为1Rz4y1D7bZ的视频属性抓取结束
# 开始BV号为1xt4y1X7gD视频属性的抓取
# BV号为1xt4y1X7gD的视频属性抓取结束
# 开始BV号为1iK411H7RJ视频属性的抓取
# BV号为1iK411H7RJ的视频属性抓取结束
# 开始BV号为1Ui4y137fS视频属性的抓取
# BV号为1Ui4y137fS的视频属性抓取结束
# 开始BV号为1u5411e73B视频属性的抓取
# BV号为1u5411e73B的视频属性抓取结束
# 开始BV号为15f4y1R7Me视频属性的抓取
# BV号为15f4y1R7Me的视频属性抓取结束
# 开始BV号为1pV41167Co视频属性的抓取
# BV号为1pV41167Co的视频属性抓取结束
# 开始BV号为1Zh411o7vz视频属性的抓取
# BV号为1Zh411o7vz的视频属性抓取结束
# 开始BV号为1b5411a7jW视频属性的抓取
# BV号为1b5411a7jW的视频属性抓取结束
# 开始BV号为1Cp4y1S7KV视频属性的抓取
# BV号为1Cp4y1S7KV的视频属性抓取结束
# 开始BV号为1eK411H7uk视频属性的抓取
# BV号为1eK411H7uk的视频属性抓取结束
# 开始BV号为15z4y1X769视频属性的抓取
# BV号为15z4y1X769的视频属性抓取结束
# 开始BV号为1Pz4y1X7t2视频属性的抓取
# BV号为1Pz4y1X7t2的视频属性抓取结束
# 开始BV号为1Mp4y1q71h视频属性的抓取
# BV号为1Mp4y1q71h的视频属性抓取结束
# 开始BV号为1Li4y137SD视频属性的抓取
# BV号为1Li4y137SD的视频属性抓取结束
# 开始BV号为1ov411B7JC视频属性的抓取
# BV号为1ov411B7JC的视频属性抓取结束
# 开始BV号为1iA411i72S视频属性的抓取
# BV号为1iA411i72S的视频属性抓取结束
# 开始BV号为1pa4y1a7VF视频属性的抓取
# BV号为1pa4y1a7VF的视频属性抓取结束
# 开始BV号为1ZC4y187w4视频属性的抓取
# BV号为1ZC4y187w4的视频属性抓取结束
# 开始BV号为1aa4y177c7视频属性的抓取
# BV号为1aa4y177c7的视频属性抓取结束
# 开始BV号为11Z4y1T72z视频属性的抓取
# BV号为11Z4y1T72z的视频属性抓取结束
# 开始BV号为1Uf4y1Q7Bi视频属性的抓取
# BV号为1Uf4y1Q7Bi的视频属性抓取结束
# 开始BV号为1154y1i7qU视频属性的抓取
# BV号为1154y1i7qU的视频属性抓取结束
# 开始BV号为1B54y1e7CH视频属性的抓取
# BV号为1B54y1e7CH的视频属性抓取结束
# 开始BV号为1XD4y1U75d视频属性的抓取
# BV号为1XD4y1U75d的视频属性抓取结束
# 开始BV号为1CD4y1U77D视频属性的抓取
# BV号为1CD4y1U77D的视频属性抓取结束
# 开始BV号为1m54y1e7UF视频属性的抓取
# BV号为1m54y1e7UF的视频属性抓取结束
# 开始BV号为14p4y1v7ma视频属性的抓取
# BV号为14p4y1v7ma的视频属性抓取结束
# 开始BV号为15K411K72K视频属性的抓取
# BV号为15K411K72K的视频属性抓取结束
# 开始BV号为1v54y1272D视频属性的抓取
# BV号为1v54y1272D的视频属性抓取结束
# 开始BV号为1Ci4y1g7wa视频属性的抓取
# BV号为1Ci4y1g7wa的视频属性抓取结束
# 开始BV号为1y54y1i7UW视频属性的抓取
# BV号为1y54y1i7UW的视频属性抓取结束
# 开始BV号为1G54y1e7is视频属性的抓取
# BV号为1G54y1e7is的视频属性抓取结束
# 开始BV号为1Tf4y197LZ视频属性的抓取
# 开始BV号为1Tf4y197LZ视频属性的抓取
# BV号为1Tf4y197LZ的视频属性抓取结束
# 开始BV号为1XT4y1j7tZ视频属性的抓取
# BV号为1XT4y1j7tZ的视频属性抓取结束
# 开始BV号为12V41127yv视频属性的抓取
# BV号为12V41127yv的视频属性抓取结束
# 开始BV号为145411872Y视频属性的抓取
# BV号为145411872Y的视频属性抓取结束
# 开始BV号为1tK4y1Y7MF视频属性的抓取
# BV号为1tK4y1Y7MF的视频属性抓取结束
# 开始BV号为1pz4y1f7EM视频属性的抓取
# BV号为1pz4y1f7EM的视频属性抓取结束
# 开始BV号为1mZ4y1M7fK视频属性的抓取
# BV号为1mZ4y1M7fK的视频属性抓取结束
# 开始BV号为1Ht4y1S7mm视频属性的抓取
# BV号为1Ht4y1S7mm的视频属性抓取结束
# 开始BV号为17t4y1Q7Pb视频属性的抓取
# BV号为17t4y1Q7Pb的视频属性抓取结束
# 开始BV号为1Ya4y1J7xU视频属性的抓取
# BV号为1Ya4y1J7xU的视频属性抓取结束
# 开始BV号为1JA411Y7XN视频属性的抓取
# BV号为1JA411Y7XN的视频属性抓取结束
# 开始BV号为1Tf4y197cv视频属性的抓取
# BV号为1Tf4y197cv的视频属性抓取结束
# 开始BV号为1yp4y1Y7Zg视频属性的抓取
# BV号为1yp4y1Y7Zg的视频属性抓取结束
# 开始BV号为1Y5411a7Cg视频属性的抓取
# BV号为1Y5411a7Cg的视频属性抓取结束
# 开始BV号为18t4y1D79d视频属性的抓取
# BV号为18t4y1D79d的视频属性抓取结束
# 开始BV号为14a4y177sJ视频属性的抓取
# BV号为14a4y177sJ的视频属性抓取结束
# 开始BV号为17A411Y7XF视频属性的抓取
# BV号为17A411Y7XF的视频属性抓取结束
# 开始BV号为1Pt4y1S7Kt视频属性的抓取
# BV号为1Pt4y1S7Kt的视频属性抓取结束
# 开始BV号为1zk4y127GZ视频属性的抓取
# 开始BV号为1zk4y127GZ视频属性的抓取
# BV号为1zk4y127GZ的视频属性抓取结束
# 开始BV号为1zV411z7PU视频属性的抓取
# BV号为1zV411z7PU的视频属性抓取结束
# 开始BV号为13A411Y7bq视频属性的抓取
# BV号为13A411Y7bq的视频属性抓取结束
# 开始BV号为1RV411U7i2视频属性的抓取
# BV号为1RV411U7i2的视频属性抓取结束
# 开始BV号为1L54y127LU视频属性的抓取
# BV号为1L54y127LU的视频属性抓取结束
# 开始BV号为17C4y1t7Bs视频属性的抓取
# BV号为17C4y1t7Bs的视频属性抓取结束
# 开始BV号为1kv411y7sC视频属性的抓取
# BV号为1kv411y7sC的视频属性抓取结束
# 开始BV号为1E54y127Aa视频属性的抓取
# BV号为1E54y127Aa的视频属性抓取结束
# 开始BV号为15f4y197Dg视频属性的抓取
# BV号为15f4y197Dg的视频属性抓取结束
# 开始BV号为1aV411z7sn视频属性的抓取
# BV号为1aV411z7sn的视频属性抓取结束
# 开始BV号为1wk4y1271o视频属性的抓取
# BV号为1wk4y1271o的视频属性抓取结束
# 开始BV号为1wV411S7rw视频属性的抓取
# BV号为1wV411S7rw的视频属性抓取结束
# 开始BV号为1vv411q7M3视频属性的抓取
# BV号为1vv411q7M3的视频属性抓取结束
# 开始BV号为1RD4y1m71d视频属性的抓取
# BV号为1RD4y1m71d的视频属性抓取结束
# 开始BV号为1VK4y1e73r视频属性的抓取
# BV号为1VK4y1e73r的视频属性抓取结束
# 开始BV号为1uA411n79J视频属性的抓取
# BV号为1uA411n79J的视频属性抓取结束
# 开始BV号为1q54y1e77u视频属性的抓取
# BV号为1q54y1e77u的视频属性抓取结束
# 开始BV号为1J5411h7qq视频属性的抓取
# BV号为1J5411h7qq的视频属性抓取结束
# 开始BV号为185411a7EX视频属性的抓取
# BV号为185411a7EX的视频属性抓取结束
# 开始BV号为1Kt4y1S7nY视频属性的抓取
# BV号为1Kt4y1S7nY的视频属性抓取结束
# 开始BV号为1ra4y1E7m6视频属性的抓取
# BV号为1ra4y1E7m6的视频属性抓取结束
# 开始BV号为1eK4y1e7Sp视频属性的抓取
# BV号为1eK4y1e7Sp的视频属性抓取结束
# 开始BV号为12V41127o7视频属性的抓取
# BV号为12V41127o7的视频属性抓取结束
# 开始BV号为19a4y1775i视频属性的抓取
# BV号为19a4y1775i的视频属性抓取结束
# 开始BV号为1ti4y1g7z2视频属性的抓取
# BV号为1ti4y1g7z2的视频属性抓取结束
# 开始BV号为1554y1D7TA视频属性的抓取
# BV号为1554y1D7TA的视频属性抓取结束
# 开始BV号为1gi4y1g7Xd视频属性的抓取
# BV号为1gi4y1g7Xd的视频属性抓取结束
# 开始BV号为1ii4y1g7G4视频属性的抓取
# BV号为1ii4y1g7G4的视频属性抓取结束
# 开始BV号为1vT4y1L7Sz视频属性的抓取
# BV号为1vT4y1L7Sz的视频属性抓取结束
# 开始BV号为1YZ4y1M7F2视频属性的抓取
# BV号为1YZ4y1M7F2的视频属性抓取结束
# 开始BV号为1q5411h7Hz视频属性的抓取
# BV号为1q5411h7Hz的视频属性抓取结束
# 开始BV号为1NV411S7JR视频属性的抓取
# BV号为1NV411S7JR的视频属性抓取结束
# 开始BV号为1PV411S7xV视频属性的抓取
# BV号为1PV411S7xV的视频属性抓取结束
# 开始BV号为1wp4y1i7YG视频属性的抓取
# BV号为1wp4y1i7YG的视频属性抓取结束
# 开始BV号为1sv411i78Q视频属性的抓取
# BV号为1sv411i78Q的视频属性抓取结束
# 开始BV号为1AK411n7g5视频属性的抓取
# BV号为1AK411n7g5的视频属性抓取结束
# 开始BV号为15t4y1Q7Kh视频属性的抓取
# BV号为15t4y1Q7Kh的视频属性抓取结束
# 开始BV号为1BC4y1b7Gd视频属性的抓取
# BV号为1BC4y1b7Gd的视频属性抓取结束
# 开始BV号为17V411S7Z7视频属性的抓取
# BV号为17V411S7Z7的视频属性抓取结束
# 开始BV号为1s64y1c7Sb视频属性的抓取
# BV号为1s64y1c7Sb的视频属性抓取结束
# 开始BV号为1oT4y1j7fU视频属性的抓取
# BV号为1oT4y1j7fU的视频属性抓取结束
# 开始BV号为1ft4y1U76n视频属性的抓取
# BV号为1ft4y1U76n的视频属性抓取结束
# 开始BV号为1XV411U7Ub视频属性的抓取
# BV号为1XV411U7Ub的视频属性抓取结束
# 开始BV号为1F54y1U7DY视频属性的抓取
# BV号为1F54y1U7DY的视频属性抓取结束
# 开始BV号为1GK411n7xo视频属性的抓取
# BV号为1GK411n7xo的视频属性抓取结束
# 开始BV号为1t54y1e7EJ视频属性的抓取
# BV号为1t54y1e7EJ的视频属性抓取结束
# 开始BV号为1zT4y1L7p6视频属性的抓取
# BV号为1zT4y1L7p6的视频属性抓取结束
# 开始BV号为1dy4y1C79o视频属性的抓取
# BV号为1dy4y1C79o的视频属性抓取结束
# 开始BV号为1BV411z71f视频属性的抓取
# BV号为1BV411z71f的视频属性抓取结束
# 开始BV号为1hv411i7wS视频属性的抓取
# BV号为1hv411i7wS的视频属性抓取结束
# 开始BV号为1Ci4y1u7P1视频属性的抓取
# BV号为1Ci4y1u7P1的视频属性抓取结束
# 开始BV号为1JK4y1Y7Jh视频属性的抓取
# BV号为1JK4y1Y7Jh的视频属性抓取结束
# 开始BV号为1zt4y1U7Ce视频属性的抓取
# BV号为1zt4y1U7Ce的视频属性抓取结束
# 开始BV号为11y4y1C72g视频属性的抓取
# BV号为11y4y1C72g的视频属性抓取结束
# 开始BV号为1BD4y127kR视频属性的抓取
# BV号为1BD4y127kR的视频属性抓取结束
# 开始BV号为1Pi4y1G7KL视频属性的抓取
# BV号为1Pi4y1G7KL的视频属性抓取结束
# 开始BV号为1FA411e7TW视频属性的抓取
# BV号为1FA411e7TW的视频属性抓取结束
# 开始BV号为1164y1F7yh视频属性的抓取
# BV号为1164y1F7yh的视频属性抓取结束
# 开始BV号为13K411n7us视频属性的抓取
# BV号为13K411n7us的视频属性抓取结束
# 开始BV号为1Ea4y177oY视频属性的抓取
# BV号为1Ea4y177oY的视频属性抓取结束
# 开始BV号为1Ni4y1g7wp视频属性的抓取
# BV号为1Ni4y1g7wp的视频属性抓取结束
# 开始BV号为1oA411Y7YT视频属性的抓取
# BV号为1oA411Y7YT的视频属性抓取结束
# 开始BV号为1m5411a77X视频属性的抓取
# BV号为1m5411a77X的视频属性抓取结束
# 开始BV号为1n5411h7pk视频属性的抓取
# BV号为1n5411h7pk的视频属性抓取结束
# 开始BV号为1kT4y157nH视频属性的抓取
# BV号为1kT4y157nH的视频属性抓取结束
# 开始BV号为1Cz4y1f7QK视频属性的抓取
# BV号为1Cz4y1f7QK的视频属性抓取结束
# 开始BV号为1Ei4y1M764视频属性的抓取
# BV号为1Ei4y1M764的视频属性抓取结束
# 开始BV号为1iV411U7VL视频属性的抓取
# BV号为1iV411U7VL的视频属性抓取结束
# 开始BV号为1254y127Ni视频属性的抓取
# BV号为1254y127Ni的视频属性抓取结束
# 开始BV号为1X54y1e7jD视频属性的抓取
# BV号为1X54y1e7jD的视频属性抓取结束
# 开始BV号为1Gk4y117nL视频属性的抓取
# BV号为1Gk4y117nL的视频属性抓取结束
# 开始BV号为1MZ4y1T71c视频属性的抓取
# BV号为1MZ4y1T71c的视频属性抓取结束
# 开始BV号为1mk4y1k76x视频属性的抓取
# BV号为1mk4y1k76x的视频属性抓取结束
# 开始BV号为1W5411b7wa视频属性的抓取
# BV号为1W5411b7wa的视频属性抓取结束
# 开始BV号为17a4y1j7iX视频属性的抓取
# BV号为17a4y1j7iX的视频属性抓取结束
# 开始BV号为155411j71A视频属性的抓取
# BV号为155411j71A的视频属性抓取结束
# 开始BV号为1VT4y1c7UK视频属性的抓取
# BV号为1VT4y1c7UK的视频属性抓取结束
# 开始BV号为1xp4y1a7he视频属性的抓取
# BV号为1xp4y1a7he的视频属性抓取结束
# 开始BV号为1RT4y1w79E视频属性的抓取
# BV号为1RT4y1w79E的视频属性抓取结束
# 开始BV号为1wD4y1o7AV视频属性的抓取
# BV号为1wD4y1o7AV的视频属性抓取结束
# 开始BV号为1Nf4y1D7ut视频属性的抓取
# BV号为1Nf4y1D7ut的视频属性抓取结束
# 开始BV号为1vA411J7xt视频属性的抓取
# BV号为1vA411J7xt的视频属性抓取结束
# 开始BV号为12D4y1o7nF视频属性的抓取
# BV号为12D4y1o7nF的视频属性抓取结束
# 开始BV号为1tk4y1y7ew视频属性的抓取
# BV号为1tk4y1y7ew的视频属性抓取结束
# 开始BV号为1j64y1F7Nk视频属性的抓取
# BV号为1j64y1F7Nk的视频属性抓取结束
# 开始BV号为1Yt4y1q73B视频属性的抓取
# BV号为1Yt4y1q73B的视频属性抓取结束
# 开始BV号为1YT4y1A74y视频属性的抓取
# BV号为1YT4y1A74y的视频属性抓取结束
# 开始BV号为1kt4y1S7AD视频属性的抓取
# BV号为1kt4y1S7AD的视频属性抓取结束
# 开始BV号为1Fz4y1Z7Yc视频属性的抓取
# BV号为1Fz4y1Z7Yc的视频属性抓取结束
# 开始BV号为13K4y1Y7oa视频属性的抓取
# BV号为13K4y1Y7oa的视频属性抓取结束
# 开始BV号为165411b7Tw视频属性的抓取
# BV号为165411b7Tw的视频属性抓取结束
# 开始BV号为1hK411K7QF视频属性的抓取
# BV号为1hK411K7QF的视频属性抓取结束
# 开始BV号为1PD4y1Z7Lw视频属性的抓取
# BV号为1PD4y1Z7Lw的视频属性抓取结束
# 开始BV号为1wk4y117Ri视频属性的抓取
# BV号为1wk4y117Ri的视频属性抓取结束
# 开始BV号为19V411m717视频属性的抓取
# BV号为19V411m717的视频属性抓取结束
# 开始BV号为1cz4y1Z7jH视频属性的抓取
# BV号为1cz4y1Z7jH的视频属性抓取结束
# 开始BV号为17Z4y1N7PJ视频属性的抓取
# BV号为17Z4y1N7PJ的视频属性抓取结束
# 开始BV号为1rA411E7h6视频属性的抓取
# BV号为1rA411E7h6的视频属性抓取结束
# 开始BV号为18t4y1q74p视频属性的抓取
# BV号为18t4y1q74p的视频属性抓取结束
# 开始BV号为1vh411R74P视频属性的抓取
# BV号为1vh411R74P的视频属性抓取结束
# 开始BV号为1Yt4y1S7Sd视频属性的抓取
# BV号为1Yt4y1S7Sd的视频属性抓取结束
# 开始BV号为1ah411X7ga视频属性的抓取
# BV号为1ah411X7ga的视频属性抓取结束
# 开始BV号为15K4y1e7np视频属性的抓取
# BV号为15K4y1e7np的视频属性抓取结束
# 开始BV号为16K4y187Bi视频属性的抓取
# BV号为16K4y187Bi的视频属性抓取结束
# 开始BV号为1S54y1y7Lf视频属性的抓取
# BV号为1S54y1y7Lf的视频属性抓取结束
# 开始BV号为11t4y1i7DU视频属性的抓取
# BV号为11t4y1i7DU的视频属性抓取结束
# 开始BV号为1bi4y1u7pw视频属性的抓取
# BV号为1bi4y1u7pw的视频属性抓取结束
# 开始BV号为1t54y1278N视频属性的抓取
# BV号为1t54y1278N的视频属性抓取结束
# 开始BV号为1hk4y1y7un视频属性的抓取
# BV号为1hk4y1y7un的视频属性抓取结束
# 开始BV号为1ui4y1u7oo视频属性的抓取
# BV号为1ui4y1u7oo的视频属性抓取结束
# 开始BV号为1YZ4y157BA视频属性的抓取
# BV号为1YZ4y157BA的视频属性抓取结束
# 开始BV号为1sa4y1E7vF视频属性的抓取
# BV号为1sa4y1E7vF的视频属性抓取结束
# 开始BV号为1UK411P7tG视频属性的抓取
# BV号为1UK411P7tG的视频属性抓取结束
# 开始BV号为1LD4y1o72m视频属性的抓取
# BV号为1LD4y1o72m的视频属性抓取结束
# 开始BV号为1x54y1m786视频属性的抓取
# BV号为1x54y1m786的视频属性抓取结束
# 开始BV号为1JK4y1e7U8视频属性的抓取
# BV号为1JK4y1e7U8的视频属性抓取结束
# 开始BV号为1o54y1C79e视频属性的抓取
# BV号为1o54y1C79e的视频属性抓取结束
# 开始BV号为1sk4y117oE视频属性的抓取
# BV号为1sk4y117oE的视频属性抓取结束
# 开始BV号为1pK411P7AG视频属性的抓取
# BV号为1pK411P7AG的视频属性抓取结束
# 开始BV号为1EZ4y157gL视频属性的抓取
# BV号为1EZ4y157gL的视频属性抓取结束
# 开始BV号为1rh411R7B7视频属性的抓取
# BV号为1rh411R7B7的视频属性抓取结束
# 开始BV号为1Bi4y177KE视频属性的抓取
# BV号为1Bi4y177KE的视频属性抓取结束
# 开始BV号为1vf4y1Q7fW视频属性的抓取
# BV号为1vf4y1Q7fW的视频属性抓取结束
# 开始BV号为1iA411n7TP视频属性的抓取
# BV号为1iA411n7TP的视频属性抓取结束
# 开始BV号为18i4y1u71i视频属性的抓取
# BV号为18i4y1u71i的视频属性抓取结束
# 开始BV号为1tV41117b2视频属性的抓取
# BV号为1tV41117b2的视频属性抓取结束
# 开始BV号为1sZ4y1N7DW视频属性的抓取
# BV号为1sZ4y1N7DW的视频属性抓取结束
# 开始BV号为19i4y1E7ef视频属性的抓取
# BV号为19i4y1E7ef的视频属性抓取结束
# 开始BV号为1Ui4y1M7VL视频属性的抓取
# BV号为1Ui4y1M7VL的视频属性抓取结束
# 开始BV号为1764y1F7HR视频属性的抓取
# BV号为1764y1F7HR的视频属性抓取结束
# 开始BV号为1ui4y1u7zm视频属性的抓取
# BV号为1ui4y1u7zm的视频属性抓取结束
# 开始BV号为19z4y1Z7tC视频属性的抓取
# BV号为19z4y1Z7tC的视频属性抓取结束
# 开始BV号为1iK411P7di视频属性的抓取
# BV号为1iK411P7di的视频属性抓取结束
# 开始BV号为1A541187A1视频属性的抓取
# BV号为1A541187A1的视频属性抓取结束
# 开始BV号为1ZK411K7Ba视频属性的抓取
# BV号为1ZK411K7Ba的视频属性抓取结束
# 开始BV号为1ZD4y1d75H视频属性的抓取
# BV号为1ZD4y1d75H的视频属性抓取结束
# 开始BV号为1sz4y1Z7vD视频属性的抓取
# BV号为1sz4y1Z7vD的视频属性抓取结束
# 开始BV号为1sZ4y1T7Ki视频属性的抓取
# BV号为1sZ4y1T7Ki的视频属性抓取结束
# 开始BV号为1P54y117C6视频属性的抓取
# BV号为1P54y117C6的视频属性抓取结束
# 开始BV号为1rK4y1a7JB视频属性的抓取
# BV号为1rK4y1a7JB的视频属性抓取结束
# 开始BV号为1zp4y1e7Cn视频属性的抓取
# BV号为1zp4y1e7Cn的视频属性抓取结束
# 开始BV号为19p4y1Y7FK视频属性的抓取
# BV号为19p4y1Y7FK的视频属性抓取结束
# 开始BV号为1q5411b7m2视频属性的抓取
# BV号为1q5411b7m2的视频属性抓取结束
# 开始BV号为1Hk4y117zQ视频属性的抓取
# BV号为1Hk4y117zQ的视频属性抓取结束
# 开始BV号为1aA411J77S视频属性的抓取
# BV号为1aA411J77S的视频属性抓取结束
# 开始BV号为1KA411J7ZG视频属性的抓取
# BV号为1KA411J7ZG的视频属性抓取结束
# 开始BV号为1tp4y1a7cM视频属性的抓取
# BV号为1tp4y1a7cM的视频属性抓取结束
# 开始BV号为1uZ4y1T76V视频属性的抓取
# BV号为1uZ4y1T76V的视频属性抓取结束
# 开始BV号为1YK411P7xd视频属性的抓取
# BV号为1YK411P7xd的视频属性抓取结束
# 开始BV号为15h411R7E7视频属性的抓取
# BV号为15h411R7E7的视频属性抓取结束
# 开始BV号为1aA411E7CM视频属性的抓取
# BV号为1aA411E7CM的视频属性抓取结束
# 开始BV号为1Jy4y1y7zM视频属性的抓取
# BV号为1Jy4y1y7zM的视频属性抓取结束
# 开始BV号为1Mt4y1q7yk视频属性的抓取
# BV号为1Mt4y1q7yk的视频属性抓取结束
# 开始BV号为12k4y127f6视频属性的抓取
# BV号为12k4y127f6的视频属性抓取结束
# 开始BV号为11T4y1A7Dh视频属性的抓取
# BV号为11T4y1A7Dh的视频属性抓取结束
# 开始BV号为1Uh411X7FA视频属性的抓取
# BV号为1Uh411X7FA的视频属性抓取结束
# 开始BV号为1xV411m7UW视频属性的抓取
# BV号为1xV411m7UW的视频属性抓取结束
# 开始BV号为1vv411C7Qu视频属性的抓取
# BV号为1vv411C7Qu的视频属性抓取结束
# 开始BV号为1Jv41117Tp视频属性的抓取
# BV号为1Jv41117Tp的视频属性抓取结束
# 开始BV号为1gT4y1c7mx视频属性的抓取
# BV号为1gT4y1c7mx的视频属性抓取结束
# 开始BV号为1Rt4y1S7yc视频属性的抓取
# BV号为1Rt4y1S7yc的视频属性抓取结束
# 开始BV号为1KK4y1e7X9视频属性的抓取
# BV号为1KK4y1e7X9的视频属性抓取结束
# 开始BV号为1Ek4y117kx视频属性的抓取
# BV号为1Ek4y117kx的视频属性抓取结束
# 开始BV号为1KD4y1o761视频属性的抓取
# BV号为1KD4y1o761的视频属性抓取结束
# 开始BV号为1YA411J7M7视频属性的抓取
# BV号为1YA411J7M7的视频属性抓取结束
# 开始BV号为1At4y1q7Ee视频属性的抓取
# BV号为1At4y1q7Ee的视频属性抓取结束
# 开始BV号为1ep4y1a7Dp视频属性的抓取
# BV号为1ep4y1a7Dp的视频属性抓取结束
# 开始BV号为1Jv411C7e8视频属性的抓取
# BV号为1Jv411C7e8的视频属性抓取结束
# 开始BV号为1py4y1C7XQ视频属性的抓取
# BV号为1py4y1C7XQ的视频属性抓取结束
# 开始BV号为1rt4y1v7WL视频属性的抓取
# BV号为1rt4y1v7WL的视频属性抓取结束
# 开始BV号为19D4y1R7qn视频属性的抓取
# BV号为19D4y1R7qn的视频属性抓取结束
# 开始BV号为1554y1r75W视频属性的抓取
# BV号为1554y1r75W的视频属性抓取结束
# 开始BV号为1Lv411C7LV视频属性的抓取
# BV号为1Lv411C7LV的视频属性抓取结束
# 开始BV号为1gt4y1i7Tx视频属性的抓取
# BV号为1gt4y1i7Tx的视频属性抓取结束
# 开始BV号为1vy4y1B72L视频属性的抓取
# BV号为1vy4y1B72L的视频属性抓取结束
# 开始BV号为1NA4117719视频属性的抓取
# BV号为1NA4117719的视频属性抓取结束
# 开始BV号为1DA41177KK视频属性的抓取
# BV号为1DA41177KK的视频属性抓取结束
# 开始BV号为1MA411E7qf视频属性的抓取
# BV号为1MA411E7qf的视频属性抓取结束
# 开始BV号为1Wp4y1k77z视频属性的抓取
# BV号为1Wp4y1k77z的视频属性抓取结束
# 开始BV号为1Mv411C7pc视频属性的抓取
# BV号为1Mv411C7pc的视频属性抓取结束
# 开始BV号为18f4y1i768视频属性的抓取
# BV号为18f4y1i768的视频属性抓取结束
# 开始BV号为1eD4y1d71G视频属性的抓取
# BV号为1eD4y1d71G的视频属性抓取结束
# 开始BV号为1zV41117sw视频属性的抓取
# BV号为1zV41117sw的视频属性抓取结束
# 开始BV号为1TK411N7Cy视频属性的抓取
# BV号为1TK411N7Cy的视频属性抓取结束
# <ipython-input-10-1102175d102f>:190: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为15a4y1s7zP视频属性的抓取
# BV号为15a4y1s7zP的视频属性抓取结束
# 开始BV号为19K411A7Ep视频属性的抓取
# BV号为19K411A7Ep的视频属性抓取结束
# 开始BV号为1Cp4y1r7Zy视频属性的抓取
# BV号为1Cp4y1r7Zy的视频属性抓取结束
# 开始BV号为1Fp4y1k7Ax视频属性的抓取
# BV号为1Fp4y1k7Ax的视频属性抓取结束
# 开始BV号为1zV411y7EZ视频属性的抓取
# BV号为1zV411y7EZ的视频属性抓取结束
# 开始BV号为1aV41127fJ视频属性的抓取
# BV号为1aV41127fJ的视频属性抓取结束
# 开始BV号为1vK4y1h7Zn视频属性的抓取
# BV号为1vK4y1h7Zn的视频属性抓取结束
# 开始BV号为1Dy4y1k7Ua视频属性的抓取
# BV号为1Dy4y1k7Ua的视频属性抓取结束
# 开始BV号为12z4y1Z7fW视频属性的抓取
# BV号为12z4y1Z7fW的视频属性抓取结束
# 开始BV号为1NT4y1w7ib视频属性的抓取
# BV号为1NT4y1w7ib的视频属性抓取结束
# 开始BV号为1By4y1r7sf视频属性的抓取
# BV号为1By4y1r7sf的视频属性抓取结束
# 开始BV号为1uT4y1F7nx视频属性的抓取
# BV号为1uT4y1F7nx的视频属性抓取结束
# 开始BV号为1Ht4y1i7uY视频属性的抓取
# BV号为1Ht4y1i7uY的视频属性抓取结束
# 开始BV号为1zi4y1j7MR视频属性的抓取
# BV号为1zi4y1j7MR的视频属性抓取结束
# 开始BV号为1jz4y1o7gD视频属性的抓取
# BV号为1jz4y1o7gD的视频属性抓取结束
# 开始BV号为1Hi4y1E77B视频属性的抓取
# BV号为1Hi4y1E77B的视频属性抓取结束
# 开始BV号为1ia4y1L7LC视频属性的抓取
# BV号为1ia4y1L7LC的视频属性抓取结束
# 开始BV号为1Wf4y1B7NC视频属性的抓取
# BV号为1Wf4y1B7NC的视频属性抓取结束
# 开始BV号为1vK411A7ij视频属性的抓取
# BV号为1vK411A7ij的视频属性抓取结束
# 开始BV号为1JT4y1F7Ye视频属性的抓取
# BV号为1JT4y1F7Ye的视频属性抓取结束
# 开始BV号为1P54y1C7AA视频属性的抓取
# BV号为1P54y1C7AA的视频属性抓取结束
# 开始BV号为1ot4y1v71F视频属性的抓取
# BV号为1ot4y1v71F的视频属性抓取结束
# 开始BV号为1uK411N7BH视频属性的抓取
# BV号为1uK411N7BH的视频属性抓取结束
# 开始BV号为18K4y177GV视频属性的抓取
# BV号为18K4y177GV的视频属性抓取结束
# 开始BV号为1K54y1r7HJ视频属性的抓取
# BV号为1K54y1r7HJ的视频属性抓取结束
# 开始BV号为1H5411j72Y视频属性的抓取
# BV号为1H5411j72Y的视频属性抓取结束
# 开始BV号为1U54y1k7Nb视频属性的抓取
# BV号为1U54y1k7Nb的视频属性抓取结束
# 开始BV号为18p4y1k7md视频属性的抓取
# BV号为18p4y1k7md的视频属性抓取结束
# 开始BV号为14T4y1w7HL视频属性的抓取
# BV号为14T4y1w7HL的视频属性抓取结束
# 开始BV号为1pp4y1k7AX视频属性的抓取
# BV号为1pp4y1k7AX的视频属性抓取结束
# 开始BV号为1Jv411k7te视频属性的抓取
# BV号为1Jv411k7te的视频属性抓取结束
# 开始BV号为1H54y1C7Dh视频属性的抓取
# BV号为1H54y1C7Dh的视频属性抓取结束
# 开始BV号为1BV41127sU视频属性的抓取
# BV号为1BV41127sU的视频属性抓取结束
# 开始BV号为1bf4y1B7Do视频属性的抓取
# BV号为1bf4y1B7Do的视频属性抓取结束
# 开始BV号为1RK4y1f7a6视频属性的抓取
# BV号为1RK4y1f7a6的视频属性抓取结束
# 开始BV号为1ck4y1y7Pc视频属性的抓取
# BV号为1ck4y1y7Pc的视频属性抓取结束
# 开始BV号为1LD4y1d7HQ视频属性的抓取
# BV号为1LD4y1d7HQ的视频属性抓取结束
# 开始BV号为1ty4y1C7F1视频属性的抓取
# BV号为1ty4y1C7F1的视频属性抓取结束
# 开始BV号为1fk4y1C7we视频属性的抓取
# BV号为1fk4y1C7we的视频属性抓取结束
# 开始BV号为1Ut4y1q7Cr视频属性的抓取
# BV号为1Ut4y1q7Cr的视频属性抓取结束
# 开始BV号为1Ei4y177si视频属性的抓取
# BV号为1Ei4y177si的视频属性抓取结束
# 开始BV号为14K411N7rg视频属性的抓取
# BV号为14K411N7rg的视频属性抓取结束
# 开始BV号为1Wf4y1B7Ts视频属性的抓取
# BV号为1Wf4y1B7Ts的视频属性抓取结束
# 开始BV号为1DK411P7XH视频属性的抓取
# BV号为1DK411P7XH的视频属性抓取结束
# 开始BV号为17v411k72v视频属性的抓取
# BV号为17v411k72v的视频属性抓取结束
# 开始BV号为1oy4y1k76v视频属性的抓取
# BV号为1oy4y1k76v的视频属性抓取结束
# 开始BV号为19t4y1Y7Lt视频属性的抓取
# BV号为19t4y1Y7Lt的视频属性抓取结束
# 开始BV号为1NK411P7JA视频属性的抓取
# BV号为1NK411P7JA的视频属性抓取结束
# 开始BV号为1Hy4y1r7dK视频属性的抓取
# BV号为1Hy4y1r7dK的视频属性抓取结束
# 开始BV号为1mr4y1c761视频属性的抓取
# BV号为1mr4y1c761的视频属性抓取结束
# 开始BV号为19i4y1j7Ex视频属性的抓取
# BV号为19i4y1j7Ex的视频属性抓取结束
# 开始BV号为1Nf4y1z7GR视频属性的抓取
# BV号为1Nf4y1z7GR的视频属性抓取结束
# 开始BV号为1Zf4y1q78C视频属性的抓取
# BV号为1Zf4y1q78C的视频属性抓取结束
# 开始BV号为19y4y1b7DW视频属性的抓取
# BV号为19y4y1b7DW的视频属性抓取结束
# 开始BV号为1Nk4y1y77r视频属性的抓取
# BV号为1Nk4y1y77r的视频属性抓取结束
# 开始BV号为1WZ4y1L71B视频属性的抓取
# BV号为1WZ4y1L71B的视频属性抓取结束
# 开始BV号为1Bt4y1v74T视频属性的抓取
# BV号为1Bt4y1v74T的视频属性抓取结束
# 开始BV号为1MZ4y1L7E1视频属性的抓取
# BV号为1MZ4y1L7E1的视频属性抓取结束
# 开始BV号为1UV41117vw视频属性的抓取
# BV号为1UV41117vw的视频属性抓取结束
# 开始BV号为1j54y1C7z8视频属性的抓取
# BV号为1j54y1C7z8的视频属性抓取结束
# 开始BV号为16A411J7XG视频属性的抓取
# BV号为16A411J7XG的视频属性抓取结束
# 开始BV号为1Nv411C7zF视频属性的抓取
# BV号为1Nv411C7zF的视频属性抓取结束
# 开始BV号为1dy4y1b7Gk视频属性的抓取
# BV号为1dy4y1b7Gk的视频属性抓取结束
# 开始BV号为1Ta411A7b8视频属性的抓取
# BV号为1Ta411A7b8的视频属性抓取结束
# 开始BV号为1Ct4y1v79Q视频属性的抓取
# BV号为1Ct4y1v79Q的视频属性抓取结束
# 开始BV号为1U5411j7Dg视频属性的抓取
# BV号为1U5411j7Dg的视频属性抓取结束
# 开始BV号为175411L75c视频属性的抓取
# BV号为175411L75c的视频属性抓取结束
# 开始BV号为1454y117Lb视频属性的抓取
# BV号为1454y117Lb的视频属性抓取结束
# 开始BV号为1si4y1j77Y视频属性的抓取
# BV号为1si4y1j77Y的视频属性抓取结束
# 开始BV号为1zz4y1C7Kd视频属性的抓取
# BV号为1zz4y1C7Kd的视频属性抓取结束
# 开始BV号为1tV411y71y视频属性的抓取
# BV号为1tV411y71y的视频属性抓取结束
# 开始BV号为1nT4y1F7MZ视频属性的抓取
# BV号为1nT4y1F7MZ的视频属性抓取结束
# 开始BV号为1k541157Qn视频属性的抓取
# BV号为1k541157Qn的视频属性抓取结束
# 开始BV号为1NK411A7jW视频属性的抓取
# BV号为1NK411A7jW的视频属性抓取结束
# 开始BV号为1Aa4y177ik视频属性的抓取
# BV号为1Aa4y177ik的视频属性抓取结束
# 开始BV号为1qv41167Rp视频属性的抓取
# BV号为1qv41167Rp的视频属性抓取结束
# 开始BV号为1Si4y1j7Sq视频属性的抓取
# BV号为1Si4y1j7Sq的视频属性抓取结束
# 开始BV号为15i4y177cP视频属性的抓取
# BV号为15i4y177cP的视频属性抓取结束
# 开始BV号为1X54y1k79q视频属性的抓取
# BV号为1X54y1k79q的视频属性抓取结束
# 开始BV号为1d54y1k7Tm视频属性的抓取
# BV号为1d54y1k7Tm的视频属性抓取结束
# 开始BV号为1z54y1R7pk视频属性的抓取
# BV号为1z54y1R7pk的视频属性抓取结束
# 开始BV号为1GA411E7qn视频属性的抓取
# BV号为1GA411E7qn的视频属性抓取结束
# 开始BV号为1wV411y7yX视频属性的抓取
# BV号为1wV411y7yX的视频属性抓取结束
# 2020-12-23 03:18:29.488126

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-29-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_shenghuo_huihua.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月    99   99    99   99   99   99   99   99    99      99   99    99   99
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月   99   99   99   99   99   99    99
# 1月   100  100  100  100  100  100   100
# 2月   100  100  100  100  100  100   100
# 3月   100  100  100  100  100  100   100
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月    99   99   99   99   99   99    99
# 7月   100  100  100  100  100  100   100
# 8月   100  100  100  100  100  100   100
# 9月   100  100  100  100  100  100   100

# %%
channel_shenghuo_huihua.to_json('channel_shenghuo_huihua.json')
