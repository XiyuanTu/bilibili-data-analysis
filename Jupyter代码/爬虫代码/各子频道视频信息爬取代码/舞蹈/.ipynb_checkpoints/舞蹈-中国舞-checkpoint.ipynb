# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_wudao_zhongguo=pd.DataFrame(columns=columns)
channel_wudao_zhongguo
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[5]/div/a/span').click()  #选择“舞蹈”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[5]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '舞蹈'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[5]/a').click()  #选择“宅舞”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[5]/a').text
sub_channel
# Out:
# '中国舞'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(2,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_wudao_zhongguo.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-20 22:00:41.049569
# <ipython-input-12-514f5f294573>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-12-514f5f294573>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-12-514f5f294573>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1T741177FS视频属性的抓取
# BV号为1T741177FS的视频属性抓取结束
# <ipython-input-12-514f5f294573>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1Y741157yx视频属性的抓取
# BV号为1Y741157yx的视频属性抓取结束
# 开始BV号为197411p7KE视频属性的抓取
# BV号为197411p7KE的视频属性抓取结束
# 开始BV号为177411E7m4视频属性的抓取
# BV号为177411E7m4的视频属性抓取结束
# 开始BV号为157411H7h5视频属性的抓取
# BV号为157411H7h5的视频属性抓取结束
# 开始BV号为1x7411N7Nk视频属性的抓取
# BV号为1x7411N7Nk的视频属性抓取结束
# 开始BV号为197411c7AT视频属性的抓取
# 开始BV号为197411c7AT视频属性的抓取
# BV号为197411c7AT的视频属性抓取结束
# 开始BV号为1s7411u7zG视频属性的抓取
# BV号为1s7411u7zG的视频属性抓取结束
# 开始BV号为11E411n7Qw视频属性的抓取
# BV号为11E411n7Qw的视频属性抓取结束
# 开始BV号为1j7411x7Z7视频属性的抓取
# BV号为1j7411x7Z7的视频属性抓取结束
# 开始BV号为1F7411w7pK视频属性的抓取
# BV号为1F7411w7pK的视频属性抓取结束
# 开始BV号为1Y74114755视频属性的抓取
# BV号为1Y74114755的视频属性抓取结束
# 开始BV号为1g7411p7gH视频属性的抓取
# BV号为1g7411p7gH的视频属性抓取结束
# 开始BV号为1Z741167BB视频属性的抓取
# BV号为1Z741167BB的视频属性抓取结束
# 开始BV号为1v7411E7yL视频属性的抓取
# BV号为1v7411E7yL的视频属性抓取结束
# 开始BV号为1J7411c7R3视频属性的抓取
# BV号为1J7411c7R3的视频属性抓取结束
# 开始BV号为1M7411V71J视频属性的抓取
# BV号为1M7411V71J的视频属性抓取结束
# 开始BV号为1z7411g7UL视频属性的抓取
# BV号为1z7411g7UL的视频属性抓取结束
# 开始BV号为1C7411p7xz视频属性的抓取
# BV号为1C7411p7xz的视频属性抓取结束
# 开始BV号为1a7411g75R视频属性的抓取
# BV号为1a7411g75R的视频属性抓取结束
# 开始BV号为117411p7ms视频属性的抓取
# BV号为117411p7ms的视频属性抓取结束
# 开始BV号为1L7411W7dr视频属性的抓取
# BV号为1L7411W7dr的视频属性抓取结束
# 开始BV号为1i7411s7rU视频属性的抓取
# BV号为1i7411s7rU的视频属性抓取结束
# 开始BV号为1q7411876n视频属性的抓取
# BV号为1q7411876n的视频属性抓取结束
# 开始BV号为1x7411x7Ni视频属性的抓取
# BV号为1x7411x7Ni的视频属性抓取结束
# 开始BV号为1z7411G75s视频属性的抓取
# BV号为1z7411G75s的视频属性抓取结束
# 开始BV号为1Y7411g7ad视频属性的抓取
# BV号为1Y7411g7ad的视频属性抓取结束
# 开始BV号为1W7411L7ft视频属性的抓取
# BV号为1W7411L7ft的视频属性抓取结束
# 开始BV号为1N741157bg视频属性的抓取
# BV号为1N741157bg的视频属性抓取结束
# 开始BV号为1x7411s7CG视频属性的抓取
# BV号为1x7411s7CG的视频属性抓取结束
# 开始BV号为1N741157a5视频属性的抓取
# BV号为1N741157a5的视频属性抓取结束
# 开始BV号为1ij411f7jk视频属性的抓取
# BV号为1ij411f7jk的视频属性抓取结束
# 开始BV号为1w7411p7H5视频属性的抓取
# BV号为1w7411p7H5的视频属性抓取结束
# 开始BV号为1i741157Am视频属性的抓取
# BV号为1i741157Am的视频属性抓取结束
# 开始BV号为1S7411b7XC视频属性的抓取
# BV号为1S7411b7XC的视频属性抓取结束
# 开始BV号为1o7411b7hC视频属性的抓取
# BV号为1o7411b7hC的视频属性抓取结束
# 开始BV号为127411p7So视频属性的抓取
# BV号为127411p7So的视频属性抓取结束
# 开始BV号为1Q7411g7Ry视频属性的抓取
# BV号为1Q7411g7Ry的视频属性抓取结束
# 开始BV号为127411h7kZ视频属性的抓取
# BV号为127411h7kZ的视频属性抓取结束
# 开始BV号为1f7411s7d4视频属性的抓取
# BV号为1f7411s7d4的视频属性抓取结束
# 开始BV号为1a7411t7Pz视频属性的抓取
# BV号为1a7411t7Pz的视频属性抓取结束
# 开始BV号为1N7411P7Ac视频属性的抓取
# BV号为1N7411P7Ac的视频属性抓取结束
# 开始BV号为167411w7EZ视频属性的抓取
# BV号为167411w7EZ的视频属性抓取结束
# 开始BV号为1x7411c7Nc视频属性的抓取
# BV号为1x7411c7Nc的视频属性抓取结束
# 开始BV号为1V7411J7bX视频属性的抓取
# BV号为1V7411J7bX的视频属性抓取结束
# 开始BV号为1p741157pS视频属性的抓取
# BV号为1p741157pS的视频属性抓取结束
# 开始BV号为1s7411g7VH视频属性的抓取
# BV号为1s7411g7VH的视频属性抓取结束
# 开始BV号为137411P79P视频属性的抓取
# BV号为137411P79P的视频属性抓取结束
# 开始BV号为177411p7qX视频属性的抓取
# BV号为177411p7qX的视频属性抓取结束
# 开始BV号为1A7411n7en视频属性的抓取
# BV号为1A7411n7en的视频属性抓取结束
# 开始BV号为1L7411A7Pp视频属性的抓取
# BV号为1L7411A7Pp的视频属性抓取结束
# 开始BV号为1d7411h7iZ视频属性的抓取
# BV号为1d7411h7iZ的视频属性抓取结束
# 开始BV号为1E7411t7hM视频属性的抓取
# BV号为1E7411t7hM的视频属性抓取结束
# 开始BV号为1R7411F7ny视频属性的抓取
# BV号为1R7411F7ny的视频属性抓取结束
# 开始BV号为1d7411p7XQ视频属性的抓取
# 开始BV号为1d7411p7XQ视频属性的抓取
# BV号为1d7411p7XQ的视频属性抓取结束
# 开始BV号为1g7411P71M视频属性的抓取
# BV号为1g7411P71M的视频属性抓取结束
# 开始BV号为1r7411M7UK视频属性的抓取
# BV号为1r7411M7UK的视频属性抓取结束
# 开始BV号为1H7411V7hQ视频属性的抓取
# BV号为1H7411V7hQ的视频属性抓取结束
# 开始BV号为1a7411b7dG视频属性的抓取
# BV号为1a7411b7dG的视频属性抓取结束
# 开始BV号为1J7411F7kf视频属性的抓取
# BV号为1J7411F7kf的视频属性抓取结束
# 开始BV号为1t7411K7pZ视频属性的抓取
# BV号为1t7411K7pZ的视频属性抓取结束
# 开始BV号为147411c7T4视频属性的抓取
# BV号为147411c7T4的视频属性抓取结束
# 开始BV号为1b7411n7uU视频属性的抓取
# BV号为1b7411n7uU的视频属性抓取结束
# 开始BV号为1Z7411G7ur视频属性的抓取
# BV号为1Z7411G7ur的视频属性抓取结束
# 开始BV号为177411P7BU视频属性的抓取
# BV号为177411P7BU的视频属性抓取结束
# 开始BV号为177411t7AA视频属性的抓取
# BV号为177411t7AA的视频属性抓取结束
# 开始BV号为1y7411j7xe视频属性的抓取
# BV号为1y7411j7xe的视频属性抓取结束
# 开始BV号为1B7411M7vq视频属性的抓取
# BV号为1B7411M7vq的视频属性抓取结束
# 开始BV号为1k7411N7ib视频属性的抓取
# BV号为1k7411N7ib的视频属性抓取结束
# 开始BV号为1o7411p7oj视频属性的抓取
# BV号为1o7411p7oj的视频属性抓取结束
# 开始BV号为1X7411x7hp视频属性的抓取
# BV号为1X7411x7hp的视频属性抓取结束
# 开始BV号为1n741187ej视频属性的抓取
# BV号为1n741187ej的视频属性抓取结束
# 开始BV号为1H7411W7Sf视频属性的抓取
# BV号为1H7411W7Sf的视频属性抓取结束
# 开始BV号为1L7411t7sA视频属性的抓取
# BV号为1L7411t7sA的视频属性抓取结束
# 开始BV号为1S7411z7F5视频属性的抓取
# BV号为1S7411z7F5的视频属性抓取结束
# 开始BV号为187411L7LX视频属性的抓取
# BV号为187411L7LX的视频属性抓取结束
# 开始BV号为1g7411M7gF视频属性的抓取
# BV号为1g7411M7gF的视频属性抓取结束
# <ipython-input-12-514f5f294573>:190: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1W7411H7PH视频属性的抓取
# BV号为1W7411H7PH的视频属性抓取结束
# 开始BV号为1q7411M7CT视频属性的抓取
# BV号为1q7411M7CT的视频属性抓取结束
# 开始BV号为1D7411E7Fz视频属性的抓取
# BV号为1D7411E7Fz的视频属性抓取结束
# 开始BV号为1w7411h7HK视频属性的抓取
# BV号为1w7411h7HK的视频属性抓取结束
# 开始BV号为1c7411j7QR视频属性的抓取
# BV号为1c7411j7QR的视频属性抓取结束
# 开始BV号为18E411H7rw视频属性的抓取
# BV号为18E411H7rw的视频属性抓取结束
# 开始BV号为1w7411H7Vb视频属性的抓取
# BV号为1w7411H7Vb的视频属性抓取结束
# 开始BV号为1M7411K7BZ视频属性的抓取
# BV号为1M7411K7BZ的视频属性抓取结束
# 开始BV号为1p7411L7o8视频属性的抓取
# BV号为1p7411L7o8的视频属性抓取结束
# 开始BV号为1Q7411i7YN视频属性的抓取
# BV号为1Q7411i7YN的视频属性抓取结束
# 开始BV号为1X7411G7TN视频属性的抓取
# BV号为1X7411G7TN的视频属性抓取结束
# 开始BV号为1E741157UN视频属性的抓取
# BV号为1E741157UN的视频属性抓取结束
# 开始BV号为127411F75L视频属性的抓取
# BV号为127411F75L的视频属性抓取结束
# 开始BV号为1u7411T7JJ视频属性的抓取
# BV号为1u7411T7JJ的视频属性抓取结束
# 开始BV号为1Y7411s7Me视频属性的抓取
# BV号为1Y7411s7Me的视频属性抓取结束
# 开始BV号为1S7411J7u6视频属性的抓取
# BV号为1S7411J7u6的视频属性抓取结束
# 开始BV号为1o7411678V视频属性的抓取
# BV号为1o7411678V的视频属性抓取结束
# 开始BV号为1jE411H7hE视频属性的抓取
# BV号为1jE411H7hE的视频属性抓取结束
# 开始BV号为177411T7p1视频属性的抓取
# BV号为177411T7p1的视频属性抓取结束
# 开始BV号为1v7411x7UK视频属性的抓取
# BV号为1v7411x7UK的视频属性抓取结束
# 开始BV号为167411P7C5视频属性的抓取
# BV号为167411P7C5的视频属性抓取结束
# 开始BV号为1ij411f7FA视频属性的抓取
# BV号为1ij411f7FA的视频属性抓取结束
# 开始BV号为1p7411o7Xr视频属性的抓取
# BV号为1p7411o7Xr的视频属性抓取结束
# 开始BV号为1yK41177Kn视频属性的抓取
# BV号为1yK41177Kn的视频属性抓取结束
# 开始BV号为1JE411s7U9视频属性的抓取
# BV号为1JE411s7U9的视频属性抓取结束
# 开始BV号为17E411P7Zd视频属性的抓取
# BV号为17E411P7Zd的视频属性抓取结束
# 开始BV号为12E41147m8视频属性的抓取
# BV号为12E41147m8的视频属性抓取结束
# 开始BV号为1t7411y7bx视频属性的抓取
# BV号为1t7411y7bx的视频属性抓取结束
# 开始BV号为1JE411s71M视频属性的抓取
# BV号为1JE411s71M的视频属性抓取结束
# 开始BV号为1S7411o7hs视频属性的抓取
# BV号为1S7411o7hs的视频属性抓取结束
# 开始BV号为13C4y1s7iZ视频属性的抓取
# BV号为13C4y1s7iZ的视频属性抓取结束
# 开始BV号为1rE411V72o视频属性的抓取
# BV号为1rE411V72o的视频属性抓取结束
# 开始BV号为1kE411W745视频属性的抓取
# BV号为1kE411W745的视频属性抓取结束
# 开始BV号为13E411s7Mu视频属性的抓取
# BV号为13E411s7Mu的视频属性抓取结束
# 开始BV号为1uE411A7Ko视频属性的抓取
# BV号为1uE411A7Ko的视频属性抓取结束
# 开始BV号为1oE411A72N视频属性的抓取
# BV号为1oE411A72N的视频属性抓取结束
# 开始BV号为1FE41147Jx视频属性的抓取
# BV号为1FE41147Jx的视频属性抓取结束
# 开始BV号为1LE411V7xN视频属性的抓取
# BV号为1LE411V7xN的视频属性抓取结束
# 开始BV号为1uE411s7v4视频属性的抓取
# BV号为1uE411s7v4的视频属性抓取结束
# 开始BV号为1uE411w7BJ视频属性的抓取
# 开始BV号为1uE411w7BJ视频属性的抓取
# BV号为1uE411w7BJ的视频属性抓取结束
# 开始BV号为1e741127tZ视频属性的抓取
# BV号为1e741127tZ的视频属性抓取结束
# 开始BV号为1t741117ys视频属性的抓取
# BV号为1t741117ys的视频属性抓取结束
# 开始BV号为1XE41147sv视频属性的抓取
# BV号为1XE41147sv的视频属性抓取结束
# 开始BV号为1TE411P7k4视频属性的抓取
# BV号为1TE411P7k4的视频属性抓取结束
# 开始BV号为1sE411x73A视频属性的抓取
# BV号为1sE411x73A的视频属性抓取结束
# 开始BV号为1ME411E7US视频属性的抓取
# BV号为1ME411E7US的视频属性抓取结束
# 开始BV号为1R741127kP视频属性的抓取
# BV号为1R741127kP的视频属性抓取结束
# 开始BV号为1M7411271S视频属性的抓取
# BV号为1M7411271S的视频属性抓取结束
# 开始BV号为1nE41157Lt视频属性的抓取
# BV号为1nE41157Lt的视频属性抓取结束
# 开始BV号为1j64y1u7YJ视频属性的抓取
# BV号为1j64y1u7YJ的视频属性抓取结束
# 开始BV号为15E411p7pb视频属性的抓取
# BV号为15E411p7pb的视频属性抓取结束
# 开始BV号为1ZE411G7EL视频属性的抓取
# BV号为1ZE411G7EL的视频属性抓取结束
# 开始BV号为1TE411u7Sa视频属性的抓取
# BV号为1TE411u7Sa的视频属性抓取结束
# 开始BV号为18E411s7AR视频属性的抓取
# BV号为18E411s7AR的视频属性抓取结束
# 开始BV号为12E411V71k视频属性的抓取
# BV号为12E411V71k的视频属性抓取结束
# 开始BV号为1X7411978R视频属性的抓取
# BV号为1X7411978R的视频属性抓取结束
# 开始BV号为1QE411j7L5视频属性的抓取
# BV号为1QE411j7L5的视频属性抓取结束
# 开始BV号为1sE411s7px视频属性的抓取
# BV号为1sE411s7px的视频属性抓取结束
# 开始BV号为1YE411g7Fw视频属性的抓取
# BV号为1YE411g7Fw的视频属性抓取结束
# 开始BV号为1pE411x7F5视频属性的抓取
# BV号为1pE411x7F5的视频属性抓取结束
# 开始BV号为1XE41147g8视频属性的抓取
# BV号为1XE41147g8的视频属性抓取结束
# 开始BV号为1DE41157A2视频属性的抓取
# BV号为1DE41157A2的视频属性抓取结束
# 开始BV号为1aE41147wG视频属性的抓取
# BV号为1aE41147wG的视频属性抓取结束
# 开始BV号为1kE411p7Sn视频属性的抓取
# BV号为1kE411p7Sn的视频属性抓取结束
# 开始BV号为1ZE411N7KL视频属性的抓取
# BV号为1ZE411N7KL的视频属性抓取结束
# 开始BV号为1zE411J7kA视频属性的抓取
# BV号为1zE411J7kA的视频属性抓取结束
# 开始BV号为1g54y1d7WQ视频属性的抓取
# BV号为1g54y1d7WQ的视频属性抓取结束
# 开始BV号为1Q7411J7LS视频属性的抓取
# BV号为1Q7411J7LS的视频属性抓取结束
# 开始BV号为1xE411L77N视频属性的抓取
# BV号为1xE411L77N的视频属性抓取结束
# 开始BV号为1nC4y1s7Wg视频属性的抓取
# BV号为1nC4y1s7Wg的视频属性抓取结束
# 开始BV号为1g54y1d78X视频属性的抓取
# BV号为1g54y1d78X的视频属性抓取结束
# 开始BV号为1KE411u7eG视频属性的抓取
# BV号为1KE411u7eG的视频属性抓取结束
# 开始BV号为127411R7EE视频属性的抓取
# BV号为127411R7EE的视频属性抓取结束
# 开始BV号为1gE411L7By视频属性的抓取
# BV号为1gE411L7By的视频属性抓取结束
# 开始BV号为1Q7411Z7rk视频属性的抓取
# BV号为1Q7411Z7rk的视频属性抓取结束
# 开始BV号为1dg4y1b7kX视频属性的抓取
# BV号为1dg4y1b7kX的视频属性抓取结束
# 开始BV号为1WQ4y1M7fJ视频属性的抓取
# BV号为1WQ4y1M7fJ的视频属性抓取结束
# 开始BV号为1GE411c7m7视频属性的抓取
# BV号为1GE411c7m7的视频属性抓取结束
# 开始BV号为1VE411P7rE视频属性的抓取
# BV号为1VE411P7rE的视频属性抓取结束
# 开始BV号为1FE411471C视频属性的抓取
# BV号为1FE411471C的视频属性抓取结束
# 开始BV号为16E411P75R视频属性的抓取
# 开始BV号为16E411P75R视频属性的抓取
# BV号为16E411P75R的视频属性抓取结束
# 开始BV号为1i7411m785视频属性的抓取
# BV号为1i7411m785的视频属性抓取结束
# 开始BV号为1QE411G7de视频属性的抓取
# BV号为1QE411G7de的视频属性抓取结束
# 开始BV号为1VE411G7da视频属性的抓取
# BV号为1VE411G7da的视频属性抓取结束
# 开始BV号为16e411x7cn视频属性的抓取
# BV号为16e411x7cn的视频属性抓取结束
# 开始BV号为1q741117Ud视频属性的抓取
# BV号为1q741117Ud的视频属性抓取结束
# 开始BV号为1FE411w7Kq视频属性的抓取
# BV号为1FE411w7Kq的视频属性抓取结束
# 开始BV号为13741117WT视频属性的抓取
# BV号为13741117WT的视频属性抓取结束
# 开始BV号为17e411x7qK视频属性的抓取
# BV号为17e411x7qK的视频属性抓取结束
# 开始BV号为1JE411A7bN视频属性的抓取
# BV号为1JE411A7bN的视频属性抓取结束
# 开始BV号为1eE411P7KD视频属性的抓取
# BV号为1eE411P7KD的视频属性抓取结束
# 开始BV号为1a7411d7Va视频属性的抓取
# BV号为1a7411d7Va的视频属性抓取结束
# 开始BV号为1hE41137WP视频属性的抓取
# BV号为1hE41137WP的视频属性抓取结束
# 开始BV号为1yE411s7XW视频属性的抓取
# BV号为1yE411s7XW的视频属性抓取结束
# 开始BV号为1Wa4y1t7MX视频属性的抓取
# BV号为1Wa4y1t7MX的视频属性抓取结束
# 开始BV号为1NE411T7vu视频属性的抓取
# BV号为1NE411T7vu的视频属性抓取结束
# 开始BV号为1fE411w7Kd视频属性的抓取
# BV号为1fE411w7Kd的视频属性抓取结束
# 开始BV号为1bp411A7GZ视频属性的抓取
# BV号为1bp411A7GZ的视频属性抓取结束
# 开始BV号为1HE411n7tY视频属性的抓取
# BV号为1HE411n7tY的视频属性抓取结束
# 开始BV号为1TE411N7FG视频属性的抓取
# BV号为1TE411N7FG的视频属性抓取结束
# 开始BV号为1xE4117799视频属性的抓取
# BV号为1xE4117799的视频属性抓取结束
# 开始BV号为1V7411m7SY视频属性的抓取
# BV号为1V7411m7SY的视频属性抓取结束
# 开始BV号为1jE411c7YR视频属性的抓取
# BV号为1jE411c7YR的视频属性抓取结束
# 开始BV号为1tE411j7yZ视频属性的抓取
# BV号为1tE411j7yZ的视频属性抓取结束
# 开始BV号为1WE411T7AR视频属性的抓取
# BV号为1WE411T7AR的视频属性抓取结束
# 开始BV号为1xE411A7eQ视频属性的抓取
# BV号为1xE411A7eQ的视频属性抓取结束
# 开始BV号为1NE411F7Cs视频属性的抓取
# BV号为1NE411F7Cs的视频属性抓取结束
# 开始BV号为1nE411A7Jx视频属性的抓取
# BV号为1nE411A7Jx的视频属性抓取结束
# 开始BV号为1FE411W7Lp视频属性的抓取
# BV号为1FE411W7Lp的视频属性抓取结束
# 开始BV号为127411C74A视频属性的抓取
# BV号为127411C74A的视频属性抓取结束
# 开始BV号为1c7411m7xh视频属性的抓取
# BV号为1c7411m7xh的视频属性抓取结束
# 开始BV号为1qE41177XV视频属性的抓取
# BV号为1qE41177XV的视频属性抓取结束
# 开始BV号为1S7411o7eh视频属性的抓取
# BV号为1S7411o7eh的视频属性抓取结束
# 开始BV号为1HE41157aK视频属性的抓取
# BV号为1HE41157aK的视频属性抓取结束
# 开始BV号为1dE411c71t视频属性的抓取
# BV号为1dE411c71t的视频属性抓取结束
# 开始BV号为1X7411Z7gU视频属性的抓取
# BV号为1X7411Z7gU的视频属性抓取结束
# 开始BV号为1K7411d7Fg视频属性的抓取
# BV号为1K7411d7Fg的视频属性抓取结束
# 开始BV号为1h741117ob视频属性的抓取
# BV号为1h741117ob的视频属性抓取结束
# 开始BV号为1pK411L7Jt视频属性的抓取
# BV号为1pK411L7Jt的视频属性抓取结束
# 开始BV号为1TE411N7JH视频属性的抓取
# BV号为1TE411N7JH的视频属性抓取结束
# 开始BV号为1Z7411f7zQ视频属性的抓取
# BV号为1Z7411f7zQ的视频属性抓取结束
# 开始BV号为1u7411d7d8视频属性的抓取
# BV号为1u7411d7d8的视频属性抓取结束
# 开始BV号为1UK4y1C7jc视频属性的抓取
# BV号为1UK4y1C7jc的视频属性抓取结束
# 开始BV号为1Yg4y187eM视频属性的抓取
# BV号为1Yg4y187eM的视频属性抓取结束
# 开始BV号为1PK411L7EN视频属性的抓取
# BV号为1PK411L7EN的视频属性抓取结束
# 开始BV号为1iC4y147A7视频属性的抓取
# BV号为1iC4y147A7的视频属性抓取结束
# 开始BV号为1mi4y1t7ny视频属性的抓取
# BV号为1mi4y1t7ny的视频属性抓取结束
# 开始BV号为13p4y1C7nz视频属性的抓取
# BV号为13p4y1C7nz的视频属性抓取结束
# 开始BV号为1Xi4y1t7o9视频属性的抓取
# BV号为1Xi4y1t7o9的视频属性抓取结束
# 开始BV号为1Ki4y1b7rZ视频属性的抓取
# BV号为1Ki4y1b7rZ的视频属性抓取结束
# 开始BV号为1Zg4y187tX视频属性的抓取
# BV号为1Zg4y187tX的视频属性抓取结束
# 开始BV号为1o541167Rv视频属性的抓取
# BV号为1o541167Rv的视频属性抓取结束
# 开始BV号为1kV411f7TW视频属性的抓取
# BV号为1kV411f7TW的视频属性抓取结束
# 开始BV号为11Z4y1W7W3视频属性的抓取
# BV号为11Z4y1W7W3的视频属性抓取结束
# 开始BV号为1264y1T7Ja视频属性的抓取
# BV号为1264y1T7Ja的视频属性抓取结束
# 开始BV号为1sT4y1G7tC视频属性的抓取
# BV号为1sT4y1G7tC的视频属性抓取结束
# 开始BV号为1oK4y1C7uC视频属性的抓取
# BV号为1oK4y1C7uC的视频属性抓取结束
# 开始BV号为18c411h7cm视频属性的抓取
# BV号为18c411h7cm的视频属性抓取结束
# 开始BV号为15T4y157W5视频属性的抓取
# 开始BV号为15T4y157W5视频属性的抓取
# BV号为15T4y157W5的视频属性抓取结束
# 开始BV号为19g4y187qY视频属性的抓取
# BV号为19g4y187qY的视频属性抓取结束
# 开始BV号为1oi4y1b7qo视频属性的抓取
# BV号为1oi4y1b7qo的视频属性抓取结束
# 开始BV号为1TV411o7rn视频属性的抓取
# BV号为1TV411o7rn的视频属性抓取结束
# 开始BV号为1DT4y1G7jN视频属性的抓取
# BV号为1DT4y1G7jN的视频属性抓取结束
# 开始BV号为1wz41187vU视频属性的抓取
# BV号为1wz41187vU的视频属性抓取结束
# 开始BV号为125411x763视频属性的抓取
# BV号为125411x763的视频属性抓取结束
# 开始BV号为1rV411f7Zb视频属性的抓取
# 开始BV号为1rV411f7Zb视频属性的抓取
# BV号为1rV411f7Zb的视频属性抓取结束
# 开始BV号为17Q4y1T7yo视频属性的抓取
# BV号为17Q4y1T7yo的视频属性抓取结束
# 开始BV号为1KK411j7uy视频属性的抓取
# BV号为1KK411j7uy的视频属性抓取结束
# 开始BV号为1mg4y1874n视频属性的抓取
# BV号为1mg4y1874n的视频属性抓取结束
# 开始BV号为1Bk4y1978w视频属性的抓取
# BV号为1Bk4y1978w的视频属性抓取结束
# 开始BV号为1Se411s7ZV视频属性的抓取
# BV号为1Se411s7ZV的视频属性抓取结束
# 开始BV号为16K4y1b7Bo视频属性的抓取
# BV号为16K4y1b7Bo的视频属性抓取结束
# 开始BV号为1vK4y1r7kK视频属性的抓取
# BV号为1vK4y1r7kK的视频属性抓取结束
# 开始BV号为12Q4y1M7LD视频属性的抓取
# BV号为12Q4y1M7LD的视频属性抓取结束
# 开始BV号为1ki4y1b7r3视频属性的抓取
# BV号为1ki4y1b7r3的视频属性抓取结束
# 开始BV号为1Nf4y1S7km视频属性的抓取
# BV号为1Nf4y1S7km的视频属性抓取结束
# 开始BV号为1AZ4y147LA视频属性的抓取
# BV号为1AZ4y147LA的视频属性抓取结束
# 开始BV号为1nK4y1k7aw视频属性的抓取
# BV号为1nK4y1k7aw的视频属性抓取结束
# 开始BV号为1Vf4y1S7Kj视频属性的抓取
# BV号为1Vf4y1S7Kj的视频属性抓取结束
# 开始BV号为1WV411f7tH视频属性的抓取
# BV号为1WV411f7tH的视频属性抓取结束
# 开始BV号为1Qk4y1r7hQ视频属性的抓取
# BV号为1Qk4y1r7hQ的视频属性抓取结束
# 开始BV号为1Cf4y1U7st视频属性的抓取
# BV号为1Cf4y1U7st的视频属性抓取结束
# 开始BV号为1tZ4y1x72U视频属性的抓取
# BV号为1tZ4y1x72U的视频属性抓取结束
# 开始BV号为1Bp4y1X7Gz视频属性的抓取
# BV号为1Bp4y1X7Gz的视频属性抓取结束
# 开始BV号为12a4y1t7SW视频属性的抓取
# BV号为12a4y1t7SW的视频属性抓取结束
# 开始BV号为1t64y1u7Pp视频属性的抓取
# BV号为1t64y1u7Pp的视频属性抓取结束
# 开始BV号为1Fz411878W视频属性的抓取
# BV号为1Fz411878W的视频属性抓取结束
# 开始BV号为15A411b761视频属性的抓取
# BV号为15A411b761的视频属性抓取结束
# 开始BV号为1qT4y1g7s9视频属性的抓取
# BV号为1qT4y1g7s9的视频属性抓取结束
# 开始BV号为1Ti4y1t7Mf视频属性的抓取
# BV号为1Ti4y1t7Mf的视频属性抓取结束
# 开始BV号为1X5411t7dt视频属性的抓取
# BV号为1X5411t7dt的视频属性抓取结束
# 开始BV号为1qK411L71t视频属性的抓取
# BV号为1qK411L71t的视频属性抓取结束
# 开始BV号为1z64y1T7Ld视频属性的抓取
# BV号为1z64y1T7Ld的视频属性抓取结束
# 开始BV号为1MQ4y1N7Zr视频属性的抓取
# BV号为1MQ4y1N7Zr的视频属性抓取结束
# 开始BV号为1T54y1d78Y视频属性的抓取
# BV号为1T54y1d78Y的视频属性抓取结束
# 开始BV号为1Ez411z7Nk视频属性的抓取
# BV号为1Ez411z7Nk的视频属性抓取结束
# 开始BV号为18Q4y1K7cm视频属性的抓取
# BV号为18Q4y1K7cm的视频属性抓取结束
# 开始BV号为1m5411t7Gv视频属性的抓取
# BV号为1m5411t7Gv的视频属性抓取结束
# 开始BV号为1St4y1m7qE视频属性的抓取
# BV号为1St4y1m7qE的视频属性抓取结束
# 开始BV号为1VK4y1b72n视频属性的抓取
# BV号为1VK4y1b72n的视频属性抓取结束
# 开始BV号为1fz411b76W视频属性的抓取
# BV号为1fz411b76W的视频属性抓取结束
# 开始BV号为1Q64y1u7UE视频属性的抓取
# BV号为1Q64y1u7UE的视频属性抓取结束
# 开始BV号为1Sp4y1C7ot视频属性的抓取
# BV号为1Sp4y1C7ot的视频属性抓取结束
# 开始BV号为15Z4y1j7WG视频属性的抓取
# BV号为15Z4y1j7WG的视频属性抓取结束
# 开始BV号为1hK4y1k7K5视频属性的抓取
# BV号为1hK4y1k7K5的视频属性抓取结束
# 开始BV号为15K4y1b7PC视频属性的抓取
# BV号为15K4y1b7PC的视频属性抓取结束
# 开始BV号为1gK4y1k797视频属性的抓取
# BV号为1gK4y1k797的视频属性抓取结束
# 开始BV号为1VZ4y147ex视频属性的抓取
# BV号为1VZ4y147ex的视频属性抓取结束
# 开始BV号为1f5411t77m视频属性的抓取
# BV号为1f5411t77m的视频属性抓取结束
# 开始BV号为13T4y137NM视频属性的抓取
# BV号为13T4y137NM的视频属性抓取结束
# 开始BV号为1Rf4y1U7B8视频属性的抓取
# BV号为1Rf4y1U7B8的视频属性抓取结束
# 开始BV号为12T4y1G72y视频属性的抓取
# BV号为12T4y1G72y的视频属性抓取结束
# 开始BV号为1st4y127h2视频属性的抓取
# BV号为1st4y127h2的视频属性抓取结束
# 开始BV号为1354y197NR视频属性的抓取
# BV号为1354y197NR的视频属性抓取结束
# 开始BV号为1nV411o7hB视频属性的抓取
# BV号为1nV411o7hB的视频属性抓取结束
# 开始BV号为1Ai4y1b7ZX视频属性的抓取
# BV号为1Ai4y1b7ZX的视频属性抓取结束
# 开始BV号为1hi4y1b7Rx视频属性的抓取
# BV号为1hi4y1b7Rx的视频属性抓取结束
# 开始BV号为1az411B77L视频属性的抓取
# BV号为1az411B77L的视频属性抓取结束
# 开始BV号为1Rz411b79E视频属性的抓取
# BV号为1Rz411b79E的视频属性抓取结束
# 开始BV号为1cp4y1978h视频属性的抓取
# BV号为1cp4y1978h的视频属性抓取结束
# 开始BV号为1Bk4y1R7FA视频属性的抓取
# BV号为1Bk4y1R7FA的视频属性抓取结束
# 开始BV号为1fV411o7JS视频属性的抓取
# BV号为1fV411o7JS的视频属性抓取结束
# 开始BV号为1HK41157GE视频属性的抓取
# BV号为1HK41157GE的视频属性抓取结束
# 开始BV号为1xk4y1r78M视频属性的抓取
# BV号为1xk4y1r78M的视频属性抓取结束
# 开始BV号为1Pa4y147qQ视频属性的抓取
# BV号为1Pa4y147qQ的视频属性抓取结束
# 开始BV号为1mk4y1r7wS视频属性的抓取
# BV号为1mk4y1r7wS的视频属性抓取结束
# 开始BV号为1EZ4y1x71f视频属性的抓取
# BV号为1EZ4y1x71f的视频属性抓取结束
# 开始BV号为1UQ4y1P7Gg视频属性的抓取
# BV号为1UQ4y1P7Gg的视频属性抓取结束
# 开始BV号为1KZ4y1x7Qf视频属性的抓取
# BV号为1KZ4y1x7Qf的视频属性抓取结束
# 开始BV号为1M541147sZ视频属性的抓取
# BV号为1M541147sZ的视频属性抓取结束
# 开始BV号为1aT4y1G7rB视频属性的抓取
# BV号为1aT4y1G7rB的视频属性抓取结束
# 开始BV号为11C4y1s7VE视频属性的抓取
# BV号为11C4y1s7VE的视频属性抓取结束
# 开始BV号为175411t7ed视频属性的抓取
# BV号为175411t7ed的视频属性抓取结束
# 开始BV号为13p4y1y7s5视频属性的抓取
# BV号为13p4y1y7s5的视频属性抓取结束
# 开始BV号为16g4y1z72B视频属性的抓取
# BV号为16g4y1z72B的视频属性抓取结束
# 开始BV号为13K411j7i1视频属性的抓取
# BV号为13K411j7i1的视频属性抓取结束
# 开始BV号为1dK411V7jY视频属性的抓取
# BV号为1dK411V7jY的视频属性抓取结束
# 开始BV号为18e411x7uj视频属性的抓取
# BV号为18e411x7uj的视频属性抓取结束
# 开始BV号为1zz411B7FA视频属性的抓取
# BV号为1zz411B7FA的视频属性抓取结束
# 开始BV号为1WK4y1r7Ck视频属性的抓取
# BV号为1WK4y1r7Ck的视频属性抓取结束
# 开始BV号为1eK4y1b7Ld视频属性的抓取
# BV号为1eK4y1b7Ld的视频属性抓取结束
# 开始BV号为17V411d7hT视频属性的抓取
# BV号为17V411d7hT的视频属性抓取结束
# 开始BV号为1g5411x7Ep视频属性的抓取
# BV号为1g5411x7Ep的视频属性抓取结束
# 开始BV号为1gz411B7Qm视频属性的抓取
# BV号为1gz411B7Qm的视频属性抓取结束
# 开始BV号为15Z4y1W7Hj视频属性的抓取
# BV号为15Z4y1W7Hj的视频属性抓取结束
# 开始BV号为1oz411q7Uw视频属性的抓取
# BV号为1oz411q7Uw的视频属性抓取结束
# 开始BV号为1wK4y1t72r视频属性的抓取
# BV号为1wK4y1t72r的视频属性抓取结束
# 开始BV号为1uV411C7b9视频属性的抓取
# BV号为1uV411C7b9的视频属性抓取结束
# 开始BV号为11g4y1B7Yu视频属性的抓取
# BV号为11g4y1B7Yu的视频属性抓取结束
# 开始BV号为1Tz411q7iF视频属性的抓取
# BV号为1Tz411q7iF的视频属性抓取结束
# 开始BV号为1fz411q792视频属性的抓取
# BV号为1fz411q792的视频属性抓取结束
# 开始BV号为1Ag4y1B7L1视频属性的抓取
# BV号为1Ag4y1B7L1的视频属性抓取结束
# 开始BV号为1ST4y1u7HP视频属性的抓取
# BV号为1ST4y1u7HP的视频属性抓取结束
# 开始BV号为11g4y1q7fv视频属性的抓取
# BV号为11g4y1q7fv的视频属性抓取结束
# 开始BV号为1HA411t7S6视频属性的抓取
# BV号为1HA411t7S6的视频属性抓取结束
# 开始BV号为1Ff4y127pf视频属性的抓取
# BV号为1Ff4y127pf的视频属性抓取结束
# 开始BV号为1Pz411q78g视频属性的抓取
# BV号为1Pz411q78g的视频属性抓取结束
# 开始BV号为1ot4y1y7zT视频属性的抓取
# BV号为1ot4y1y7zT的视频属性抓取结束
# 开始BV号为1gK4y187sT视频属性的抓取
# BV号为1gK4y187sT的视频属性抓取结束
# 开始BV号为1Kf4y127w8视频属性的抓取
# BV号为1Kf4y127w8的视频属性抓取结束
# 开始BV号为1Xz411q7Sn视频属性的抓取
# BV号为1Xz411q7Sn的视频属性抓取结束
# 开始BV号为1fi4y1x7bm视频属性的抓取
# BV号为1fi4y1x7bm的视频属性抓取结束
# 开始BV号为1RK4y147Dx视频属性的抓取
# BV号为1RK4y147Dx的视频属性抓取结束
# 开始BV号为1yg4y1q7c8视频属性的抓取
# BV号为1yg4y1q7c8的视频属性抓取结束
# 开始BV号为1Rp4y1S72R视频属性的抓取
# BV号为1Rp4y1S72R的视频属性抓取结束
# 开始BV号为1Lk4y1r7Tr视频属性的抓取
# BV号为1Lk4y1r7Tr的视频属性抓取结束
# 开始BV号为1cg4y1673V视频属性的抓取
# BV号为1cg4y1673V的视频属性抓取结束
# 开始BV号为1Vp4y197Kw视频属性的抓取
# BV号为1Vp4y197Kw的视频属性抓取结束
# 开始BV号为14A411q71Y视频属性的抓取
# BV号为14A411q71Y的视频属性抓取结束
# 开始BV号为1dz411q7qF视频属性的抓取
# BV号为1dz411q7qF的视频属性抓取结束
# 开始BV号为17Z4y1s7Dm视频属性的抓取
# BV号为17Z4y1s7Dm的视频属性抓取结束
# 开始BV号为1uZ4y1W761视频属性的抓取
# BV号为1uZ4y1W761的视频属性抓取结束
# 开始BV号为1Mp4y1X7kV视频属性的抓取
# BV号为1Mp4y1X7kV的视频属性抓取结束
# 开始BV号为1Sz4y1R7Fx视频属性的抓取
# BV号为1Sz4y1R7Fx的视频属性抓取结束
# 开始BV号为1xa4y1i7mJ视频属性的抓取
# BV号为1xa4y1i7mJ的视频属性抓取结束
# 开始BV号为1na4y147YR视频属性的抓取
# BV号为1na4y147YR的视频属性抓取结束
# 开始BV号为1qA411q7Us视频属性的抓取
# BV号为1qA411q7Us的视频属性抓取结束
# 开始BV号为1A541147gd视频属性的抓取
# BV号为1A541147gd的视频属性抓取结束
# 开始BV号为1aC4y1H7e2视频属性的抓取
# BV号为1aC4y1H7e2的视频属性抓取结束
# 开始BV号为16C4y1p7sh视频属性的抓取
# BV号为16C4y1p7sh的视频属性抓取结束
# 开始BV号为1yZ4y1s7MU视频属性的抓取
# BV号为1yZ4y1s7MU的视频属性抓取结束
# 开始BV号为1Fk4y1r76n视频属性的抓取
# BV号为1Fk4y1r76n的视频属性抓取结束
# 开始BV号为1xC4y1H7nk视频属性的抓取
# BV号为1xC4y1H7nk的视频属性抓取结束
# 开始BV号为1n54y1D7of视频属性的抓取
# BV号为1n54y1D7of的视频属性抓取结束
# 开始BV号为1fi4y1x7r8视频属性的抓取
# BV号为1fi4y1x7r8的视频属性抓取结束
# 开始BV号为1JZ4y1s78Z视频属性的抓取
# BV号为1JZ4y1s78Z的视频属性抓取结束
# 开始BV号为1p541147S3视频属性的抓取
# BV号为1p541147S3的视频属性抓取结束
# 开始BV号为1DQ4y1N7Y3视频属性的抓取
# BV号为1DQ4y1N7Y3的视频属性抓取结束
# 开始BV号为1nT4y137bC视频属性的抓取
# BV号为1nT4y137bC的视频属性抓取结束
# 开始BV号为1ZK4y1b7Gf视频属性的抓取
# BV号为1ZK4y1b7Gf的视频属性抓取结束
# 开始BV号为1uA411t7jT视频属性的抓取
# BV号为1uA411t7jT的视频属性抓取结束
# 开始BV号为1Ct4y1C7JU视频属性的抓取
# BV号为1Ct4y1C7JU的视频属性抓取结束
# 开始BV号为1qZ4y1p7Uq视频属性的抓取
# BV号为1qZ4y1p7Uq的视频属性抓取结束
# 开始BV号为17t4y1C7Z6视频属性的抓取
# BV号为17t4y1C7Z6的视频属性抓取结束
# 开始BV号为1ng4y1B78j视频属性的抓取
# BV号为1ng4y1B78j的视频属性抓取结束
# 开始BV号为1ta4y1i7BR视频属性的抓取
# BV号为1ta4y1i7BR的视频属性抓取结束
# 开始BV号为1dp4y1Q7fa视频属性的抓取
# BV号为1dp4y1Q7fa的视频属性抓取结束
# 开始BV号为19Q4y1A7UD视频属性的抓取
# BV号为19Q4y1A7UD的视频属性抓取结束
# 开始BV号为1WK411s7CT视频属性的抓取
# BV号为1WK411s7CT的视频属性抓取结束
# 开始BV号为15C4y1p73Q视频属性的抓取
# BV号为15C4y1p73Q的视频属性抓取结束
# 开始BV号为1xK4y1t7ua视频属性的抓取
# BV号为1xK4y1t7ua的视频属性抓取结束
# 开始BV号为17a4y1i7Ji视频属性的抓取
# BV号为17a4y1i7Ji的视频属性抓取结束
# 开始BV号为1Qt4y1C7u3视频属性的抓取
# BV号为1Qt4y1C7u3的视频属性抓取结束
# 开始BV号为1CQ4y1A7M8视频属性的抓取
# BV号为1CQ4y1A7M8的视频属性抓取结束
# 开始BV号为1TC4y1p7ra视频属性的抓取
# BV号为1TC4y1p7ra的视频属性抓取结束
# 开始BV号为1Y541147mp视频属性的抓取
# BV号为1Y541147mp的视频属性抓取结束
# 开始BV号为1gt4y117PP视频属性的抓取
# BV号为1gt4y117PP的视频属性抓取结束
# 开始BV号为1554y1X7JJ视频属性的抓取
# BV号为1554y1X7JJ的视频属性抓取结束
# 开始BV号为1ji4y1b7Y6视频属性的抓取
# BV号为1ji4y1b7Y6的视频属性抓取结束
# 开始BV号为1xa4y1i77A视频属性的抓取
# BV号为1xa4y1i77A的视频属性抓取结束
# 开始BV号为1oi4y147zY视频属性的抓取
# BV号为1oi4y147zY的视频属性抓取结束
# 开始BV号为1L64y1M7vu视频属性的抓取
# BV号为1L64y1M7vu的视频属性抓取结束
# 开始BV号为1mV411d7mF视频属性的抓取
# BV号为1mV411d7mF的视频属性抓取结束
# 开始BV号为1u5411s7zS视频属性的抓取
# BV号为1u5411s7zS的视频属性抓取结束
# 开始BV号为1SQ4y1A7NY视频属性的抓取
# BV号为1SQ4y1A7NY的视频属性抓取结束
# 开始BV号为1cp4y1X7YX视频属性的抓取
# BV号为1cp4y1X7YX的视频属性抓取结束
# 开始BV号为1ct4y117oP视频属性的抓取
# BV号为1ct4y117oP的视频属性抓取结束
# 开始BV号为1Fe411W7gN视频属性的抓取
# BV号为1Fe411W7gN的视频属性抓取结束
# 开始BV号为1zQ4y1A7xF视频属性的抓取
# BV号为1zQ4y1A7xF的视频属性抓取结束
# 开始BV号为1wC4y1s7YE视频属性的抓取
# BV号为1wC4y1s7YE的视频属性抓取结束
# 开始BV号为1VA411t7oZ视频属性的抓取
# BV号为1VA411t7oZ的视频属性抓取结束
# 开始BV号为1L541147A5视频属性的抓取
# BV号为1L541147A5的视频属性抓取结束
# 开始BV号为1Ap4y1X7kD视频属性的抓取
# BV号为1Ap4y1X7kD的视频属性抓取结束
# 开始BV号为1pZ4y1p7sR视频属性的抓取
# BV号为1pZ4y1p7sR的视频属性抓取结束
# 开始BV号为1P5411x7Qc视频属性的抓取
# BV号为1P5411x7Qc的视频属性抓取结束
# 开始BV号为1nv411z7Yq视频属性的抓取
# BV号为1nv411z7Yq的视频属性抓取结束
# 开始BV号为1zv411z7MB视频属性的抓取
# BV号为1zv411z7MB的视频属性抓取结束
# 开始BV号为1it4y1C7GW视频属性的抓取
# BV号为1it4y1C7GW的视频属性抓取结束
# 开始BV号为1JT4y1g7MU视频属性的抓取
# BV号为1JT4y1g7MU的视频属性抓取结束
# 开始BV号为1dK411H7ss视频属性的抓取
# BV号为1dK411H7ss的视频属性抓取结束
# 开始BV号为12g4y1q7tp视频属性的抓取
# BV号为12g4y1q7tp的视频属性抓取结束
# 开始BV号为1jK411s7Sv视频属性的抓取
# BV号为1jK411s7Sv的视频属性抓取结束
# 开始BV号为1Rt4y1y7ZD视频属性的抓取
# BV号为1Rt4y1y7ZD的视频属性抓取结束
# 开始BV号为1xe411p7aY视频属性的抓取
# BV号为1xe411p7aY的视频属性抓取结束
# 开始BV号为1tA411q7ew视频属性的抓取
# BV号为1tA411q7ew的视频属性抓取结束
# 开始BV号为1FK4y187aD视频属性的抓取
# BV号为1FK4y187aD的视频属性抓取结束
# 开始BV号为1Ke411W75Q视频属性的抓取
# BV号为1Ke411W75Q的视频属性抓取结束
# 开始BV号为1rt4y1y7zV视频属性的抓取
# BV号为1rt4y1y7zV的视频属性抓取结束
# 开始BV号为1tK41157VL视频属性的抓取
# BV号为1tK41157VL的视频属性抓取结束
# 开始BV号为1ev411z7Tz视频属性的抓取
# BV号为1ev411z7Tz的视频属性抓取结束
# 开始BV号为14C4y1H7AB视频属性的抓取
# BV号为14C4y1H7AB的视频属性抓取结束
# 开始BV号为13z411B7cq视频属性的抓取
# BV号为13z411B7cq的视频属性抓取结束
# 开始BV号为1UA411q7B4视频属性的抓取
# BV号为1UA411q7B4的视频属性抓取结束
# 开始BV号为1pz4y1X7pC视频属性的抓取
# BV号为1pz4y1X7pC的视频属性抓取结束
# 开始BV号为1Tt4y1975d视频属性的抓取
# BV号为1Tt4y1975d的视频属性抓取结束
# 开始BV号为1n54y1B7iN视频属性的抓取
# BV号为1n54y1B7iN的视频属性抓取结束
# 开始BV号为1qk4y1z7P6视频属性的抓取
# BV号为1qk4y1z7P6的视频属性抓取结束
# 开始BV号为1bg4y1q7WN视频属性的抓取
# BV号为1bg4y1q7WN的视频属性抓取结束
# 开始BV号为1KZ4y1H7nP视频属性的抓取
# BV号为1KZ4y1H7nP的视频属性抓取结束
# 开始BV号为1dT4y1E7te视频属性的抓取
# BV号为1dT4y1E7te的视频属性抓取结束
# 开始BV号为1p5411W7oD视频属性的抓取
# BV号为1p5411W7oD的视频属性抓取结束
# 开始BV号为1La4y1Y7uq视频属性的抓取
# BV号为1La4y1Y7uq的视频属性抓取结束
# 开始BV号为13g4y1q7zR视频属性的抓取
# BV号为13g4y1q7zR的视频属性抓取结束
# 开始BV号为1rt4y197VR视频属性的抓取
# BV号为1rt4y197VR的视频属性抓取结束
# 开始BV号为1C5411W7Az视频属性的抓取
# BV号为1C5411W7Az的视频属性抓取结束
# 开始BV号为1tA411q7iQ视频属性的抓取
# BV号为1tA411q7iQ的视频属性抓取结束
# 开始BV号为1Et4y1y7To视频属性的抓取
# BV号为1Et4y1y7To的视频属性抓取结束
# 开始BV号为1W54y1Q7gq视频属性的抓取
# BV号为1W54y1Q7gq的视频属性抓取结束
# 开始BV号为1x54y1z7a5视频属性的抓取
# BV号为1x54y1z7a5的视频属性抓取结束
# 开始BV号为16i4y1s7qu视频属性的抓取
# BV号为16i4y1s7qu的视频属性抓取结束
# 开始BV号为13g4y1v72o视频属性的抓取
# BV号为13g4y1v72o的视频属性抓取结束
# 开始BV号为12K411p7Fa视频属性的抓取
# BV号为12K411p7Fa的视频属性抓取结束
# 开始BV号为1fi4y1G7oc视频属性的抓取
# BV号为1fi4y1G7oc的视频属性抓取结束
# 开始BV号为1na4y1Y7fb视频属性的抓取
# BV号为1na4y1Y7fb的视频属性抓取结束
# 开始BV号为1tD4y1D7mk视频属性的抓取
# BV号为1tD4y1D7mk的视频属性抓取结束
# 开始BV号为1gK4y1b7ao视频属性的抓取
# BV号为1gK4y1b7ao的视频属性抓取结束
# 开始BV号为1sC4y1a7rB视频属性的抓取
# BV号为1sC4y1a7rB的视频属性抓取结束
# 开始BV号为17i4y1x7UK视频属性的抓取
# BV号为17i4y1x7UK的视频属性抓取结束
# 开始BV号为1ik4y1q7iY视频属性的抓取
# BV号为1ik4y1q7iY的视频属性抓取结束
# 开始BV号为1zk4y1z7w3视频属性的抓取
# BV号为1zk4y1z7w3的视频属性抓取结束
# 开始BV号为17K4y147Vr视频属性的抓取
# BV号为17K4y147Vr的视频属性抓取结束
# 开始BV号为1if4y1y7uu视频属性的抓取
# BV号为1if4y1y7uu的视频属性抓取结束
# 开始BV号为1nC4y1a7V1视频属性的抓取
# BV号为1nC4y1a7V1的视频属性抓取结束
# 开始BV号为15A411i7Xf视频属性的抓取
# BV号为15A411i7Xf的视频属性抓取结束
# 开始BV号为1SA411v7LJ视频属性的抓取
# BV号为1SA411v7LJ的视频属性抓取结束
# 开始BV号为1hC4y187Rm视频属性的抓取
# BV号为1hC4y187Rm的视频属性抓取结束
# 开始BV号为1Lg4y1v7H7视频属性的抓取
# BV号为1Lg4y1v7H7的视频属性抓取结束
# 开始BV号为1BV411k7jp视频属性的抓取
# BV号为1BV411k7jp的视频属性抓取结束
# 开始BV号为1qK4y147zD视频属性的抓取
# BV号为1qK4y147zD的视频属性抓取结束
# 开始BV号为1Az4y1X7fd视频属性的抓取
# BV号为1Az4y1X7fd的视频属性抓取结束
# 开始BV号为1iz411e7og视频属性的抓取
# BV号为1iz411e7og的视频属性抓取结束
# 开始BV号为1Lk4y1z7mz视频属性的抓取
# BV号为1Lk4y1z7mz的视频属性抓取结束
# 开始BV号为14t4y1y7Cy视频属性的抓取
# BV号为14t4y1y7Cy的视频属性抓取结束
# 开始BV号为1yz4y197eK视频属性的抓取
# BV号为1yz4y197eK的视频属性抓取结束
# 开始BV号为1tZ4y1H7A8视频属性的抓取
# BV号为1tZ4y1H7A8的视频属性抓取结束
# 开始BV号为1eQ4y1P7DX视频属性的抓取
# BV号为1eQ4y1P7DX的视频属性抓取结束
# 开始BV号为19Z4y1H7gx视频属性的抓取
# BV号为19Z4y1H7gx的视频属性抓取结束
# 开始BV号为18T4y177RV视频属性的抓取
# BV号为18T4y177RV的视频属性抓取结束
# 开始BV号为18Q4y1P7J3视频属性的抓取
# BV号为18Q4y1P7J3的视频属性抓取结束
# 开始BV号为1wf4y117y8视频属性的抓取
# BV号为1wf4y117y8的视频属性抓取结束
# 开始BV号为1Li4y1G7FQ视频属性的抓取
# BV号为1Li4y1G7FQ的视频属性抓取结束
# 开始BV号为12k4y1z7aE视频属性的抓取
# BV号为12k4y1z7aE的视频属性抓取结束
# 开始BV号为13g4y1q7w5视频属性的抓取
# BV号为13g4y1q7w5的视频属性抓取结束
# 开始BV号为1Fv411B7ss视频属性的抓取
# BV号为1Fv411B7ss的视频属性抓取结束
# 开始BV号为1xg4y1v7jk视频属性的抓取
# BV号为1xg4y1v7jk的视频属性抓取结束
# 开始BV号为1Xp4y1D7Ur视频属性的抓取
# BV号为1Xp4y1D7Ur的视频属性抓取结束
# 开始BV号为1ii4y1x7NW视频属性的抓取
# BV号为1ii4y1x7NW的视频属性抓取结束
# 开始BV号为1yQ4y1P7A4视频属性的抓取
# BV号为1yQ4y1P7A4的视频属性抓取结束
# 开始BV号为1H54y1z7Td视频属性的抓取
# BV号为1H54y1z7Td的视频属性抓取结束
# 开始BV号为16z4y1X71m视频属性的抓取
# BV号为16z4y1X71m的视频属性抓取结束
# 开始BV号为1MA411i7ys视频属性的抓取
# BV号为1MA411i7ys的视频属性抓取结束
# 开始BV号为12v411z7f5视频属性的抓取
# BV号为12v411z7f5的视频属性抓取结束
# 开始BV号为1BC4y187bB视频属性的抓取
# BV号为1BC4y187bB的视频属性抓取结束
# 开始BV号为1pi4y1x7HV视频属性的抓取
# BV号为1pi4y1x7HV的视频属性抓取结束
# 开始BV号为1wA411i7vk视频属性的抓取
# BV号为1wA411i7vk的视频属性抓取结束
# 开始BV号为1az4y1Q7Ag视频属性的抓取
# BV号为1az4y1Q7Ag的视频属性抓取结束
# 开始BV号为1XC4y1a7iq视频属性的抓取
# BV号为1XC4y1a7iq的视频属性抓取结束
# 开始BV号为1GT4y1J7xt视频属性的抓取
# BV号为1GT4y1J7xt的视频属性抓取结束
# 开始BV号为15a4y1Y7wG视频属性的抓取
# BV号为15a4y1Y7wG的视频属性抓取结束
# 开始BV号为1G54y1z78Y视频属性的抓取
# BV号为1G54y1z78Y的视频属性抓取结束
# 开始BV号为1mk4y1B7eT视频属性的抓取
# BV号为1mk4y1B7eT的视频属性抓取结束
# 开始BV号为1tV411k7Bs视频属性的抓取
# BV号为1tV411k7Bs的视频属性抓取结束
# 开始BV号为1vf4y127Yi视频属性的抓取
# BV号为1vf4y127Yi的视频属性抓取结束
# 开始BV号为1eA411i7po视频属性的抓取
# BV号为1eA411i7po的视频属性抓取结束
# 开始BV号为1854y1B7Pv视频属性的抓取
# BV号为1854y1B7Pv的视频属性抓取结束
# 开始BV号为1Xf4y127gy视频属性的抓取
# BV号为1Xf4y127gy的视频属性抓取结束
# 开始BV号为1cz4y1R7n4视频属性的抓取
# BV号为1cz4y1R7n4的视频属性抓取结束
# 开始BV号为1J54y1z7Fk视频属性的抓取
# BV号为1J54y1z7Fk的视频属性抓取结束
# 开始BV号为1bV41167Rw视频属性的抓取
# BV号为1bV41167Rw的视频属性抓取结束
# 开始BV号为12g4y1i7TE视频属性的抓取
# BV号为12g4y1i7TE的视频属性抓取结束
# 开始BV号为1ua4y1Y7jd视频属性的抓取
# BV号为1ua4y1Y7jd的视频属性抓取结束
# 开始BV号为1Ng4y1q7GC视频属性的抓取
# BV号为1Ng4y1q7GC的视频属性抓取结束
# 开始BV号为1aK411n7NR视频属性的抓取
# BV号为1aK411n7NR的视频属性抓取结束
# 开始BV号为1Li4y1x7FV视频属性的抓取
# BV号为1Li4y1x7FV的视频属性抓取结束
# 开始BV号为1iV411r7GX视频属性的抓取
# BV号为1iV411r7GX的视频属性抓取结束
# 开始BV号为1ET4y1J7GB视频属性的抓取
# BV号为1ET4y1J7GB的视频属性抓取结束
# 开始BV号为1Mg4y1v7MN视频属性的抓取
# BV号为1Mg4y1v7MN的视频属性抓取结束
# 开始BV号为13f4y117He视频属性的抓取
# BV号为13f4y117He的视频属性抓取结束
# 开始BV号为17V411k75E视频属性的抓取
# BV号为17V411k75E的视频属性抓取结束
# 开始BV号为1ig4y1v7Xg视频属性的抓取
# BV号为1ig4y1v7Xg的视频属性抓取结束
# 开始BV号为15a4y1e7LM视频属性的抓取
# BV号为15a4y1e7LM的视频属性抓取结束
# 开始BV号为18K411p7pA视频属性的抓取
# BV号为18K411p7pA的视频属性抓取结束
# 开始BV号为1eT4y1J7Jj视频属性的抓取
# BV号为1eT4y1J7Jj的视频属性抓取结束
# 开始BV号为1Fi4y1x7qr视频属性的抓取
# BV号为1Fi4y1x7qr的视频属性抓取结束
# 开始BV号为1kA411i7A2视频属性的抓取
# BV号为1kA411i7A2的视频属性抓取结束
# 开始BV号为1at4y1y7HG视频属性的抓取
# BV号为1at4y1y7HG的视频属性抓取结束
# 开始BV号为1mD4y1D7BB视频属性的抓取
# BV号为1mD4y1D7BB的视频属性抓取结束
# 开始BV号为1gA411B7xq视频属性的抓取
# BV号为1gA411B7xq的视频属性抓取结束
# 开始BV号为1ua4y1v7eg视频属性的抓取
# BV号为1ua4y1v7eg的视频属性抓取结束
# 开始BV号为1qg4y1v7Cy视频属性的抓取
# BV号为1qg4y1v7Cy的视频属性抓取结束
# 开始BV号为1Va4y1Y7F1视频属性的抓取
# BV号为1Va4y1Y7F1的视频属性抓取结束
# 开始BV号为16V411r7pU视频属性的抓取
# BV号为16V411r7pU的视频属性抓取结束
# 开始BV号为11v411q7hj视频属性的抓取
# BV号为11v411q7hj的视频属性抓取结束
# 开始BV号为1554y1S7Bw视频属性的抓取
# 开始BV号为1554y1S7Bw视频属性的抓取
# BV号为1554y1S7Bw的视频属性抓取结束
# 开始BV号为1D54y1v7H6视频属性的抓取
# BV号为1D54y1v7H6的视频属性抓取结束
# 开始BV号为1yV41167fT视频属性的抓取
# BV号为1yV41167fT的视频属性抓取结束
# 开始BV号为11T4y1j7iY视频属性的抓取
# BV号为11T4y1j7iY的视频属性抓取结束
# 开始BV号为1654y1S7Ap视频属性的抓取
# BV号为1654y1S7Ap的视频属性抓取结束
# 开始BV号为1Sf4y1R7Zj视频属性的抓取
# BV号为1Sf4y1R7Zj的视频属性抓取结束
# 开始BV号为1HT4y1E7Ff视频属性的抓取
# BV号为1HT4y1E7Ff的视频属性抓取结束
# 开始BV号为1zz411e7QQ视频属性的抓取
# BV号为1zz411e7QQ的视频属性抓取结束
# 开始BV号为15t4y1D76M视频属性的抓取
# BV号为15t4y1D76M的视频属性抓取结束
# 开始BV号为1aZ4y1T7Lh视频属性的抓取
# BV号为1aZ4y1T7Lh的视频属性抓取结束
# 开始BV号为1s54y1z73f视频属性的抓取
# BV号为1s54y1z73f的视频属性抓取结束
# 开始BV号为195411h7aG视频属性的抓取
# BV号为195411h7aG的视频属性抓取结束
# 开始BV号为1av411q72i视频属性的抓取
# BV号为1av411q72i的视频属性抓取结束
# 开始BV号为1kz4y1D7Sc视频属性的抓取
# BV号为1kz4y1D7Sc的视频属性抓取结束
# 开始BV号为14i4y1V7eK视频属性的抓取
# BV号为14i4y1V7eK的视频属性抓取结束
# 开始BV号为1ra4y1Y7Ya视频属性的抓取
# BV号为1ra4y1Y7Ya的视频属性抓取结束
# 开始BV号为1vT4y1E7c8视频属性的抓取
# BV号为1vT4y1E7c8的视频属性抓取结束
# 开始BV号为1VA411v7Wc视频属性的抓取
# BV号为1VA411v7Wc的视频属性抓取结束
# 开始BV号为1fz4y1D7aj视频属性的抓取
# BV号为1fz4y1D7aj的视频属性抓取结束
# 开始BV号为1c5411a7FT视频属性的抓取
# BV号为1c5411a7FT的视频属性抓取结束
# 开始BV号为16T4y1778c视频属性的抓取
# BV号为16T4y1778c的视频属性抓取结束
# 开始BV号为1yg4y1v7jy视频属性的抓取
# BV号为1yg4y1v7jy的视频属性抓取结束
# 开始BV号为1TT4y1j7se视频属性的抓取
# BV号为1TT4y1j7se的视频属性抓取结束
# 开始BV号为14C4y1h7H6视频属性的抓取
# BV号为14C4y1h7H6的视频属性抓取结束
# 开始BV号为1CV41167mv视频属性的抓取
# BV号为1CV41167mv的视频属性抓取结束
# 开始BV号为1vZ4y1u7ZH视频属性的抓取
# BV号为1vZ4y1u7ZH的视频属性抓取结束
# 开始BV号为1bt4y1X774视频属性的抓取
# BV号为1bt4y1X774的视频属性抓取结束
# 开始BV号为1254y1q7TH视频属性的抓取
# BV号为1254y1q7TH的视频属性抓取结束
# 开始BV号为1PT4y1j75j视频属性的抓取
# BV号为1PT4y1j75j的视频属性抓取结束
# 开始BV号为1hK4y1s73D视频属性的抓取
# BV号为1hK4y1s73D的视频属性抓取结束
# 开始BV号为17A411v7Ez视频属性的抓取
# BV号为17A411v7Ez的视频属性抓取结束
# 开始BV号为14p4y1i7YM视频属性的抓取
# BV号为14p4y1i7YM的视频属性抓取结束
# 开始BV号为1Gg4y1v754视频属性的抓取
# BV号为1Gg4y1v754的视频属性抓取结束
# 开始BV号为1Cz4y1D7PZ视频属性的抓取
# BV号为1Cz4y1D7PZ的视频属性抓取结束
# 开始BV号为1zp4y1i7Tj视频属性的抓取
# BV号为1zp4y1i7Tj的视频属性抓取结束
# 开始BV号为1VZ4y1u7JQ视频属性的抓取
# BV号为1VZ4y1u7JQ的视频属性抓取结束
# 开始BV号为1754y1S7FA视频属性的抓取
# BV号为1754y1S7FA的视频属性抓取结束
# 开始BV号为1HD4y1U72p视频属性的抓取
# BV号为1HD4y1U72p的视频属性抓取结束
# 开始BV号为1AD4y1U7wt视频属性的抓取
# BV号为1AD4y1U7wt的视频属性抓取结束
# 开始BV号为1G5411a7yM视频属性的抓取
# BV号为1G5411a7yM的视频属性抓取结束
# <ipython-input-12-514f5f294573>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1Xz4y1D75z视频属性的抓取
# BV号为1Xz4y1D75z的视频属性抓取结束
# 开始BV号为1ez4y1D72b视频属性的抓取
# BV号为1ez4y1D72b的视频属性抓取结束
# 开始BV号为1Ff4y1d7R4视频属性的抓取
# BV号为1Ff4y1d7R4的视频属性抓取结束
# 开始BV号为1Xz4y1D7Jb视频属性的抓取
# BV号为1Xz4y1D7Jb的视频属性抓取结束
# 开始BV号为1Zh411o7H7视频属性的抓取
# BV号为1Zh411o7H7的视频属性抓取结束
# 开始BV号为1oZ4y1T7y5视频属性的抓取
# BV号为1oZ4y1T7y5的视频属性抓取结束
# 开始BV号为1KT4y1j75u视频属性的抓取
# BV号为1KT4y1j75u的视频属性抓取结束
# 开始BV号为1HT4y177qq视频属性的抓取
# BV号为1HT4y177qq的视频属性抓取结束
# 开始BV号为1Nk4y1m7HX视频属性的抓取
# BV号为1Nk4y1m7HX的视频属性抓取结束
# 开始BV号为1oK4y1s7pa视频属性的抓取
# BV号为1oK4y1s7pa的视频属性抓取结束
# 开始BV号为1na4y1a7hk视频属性的抓取
# BV号为1na4y1a7hk的视频属性抓取结束
# 开始BV号为18A411v7by视频属性的抓取
# BV号为18A411v7by的视频属性抓取结束
# 开始BV号为1Pt4y1D7Pt视频属性的抓取
# BV号为1Pt4y1D7Pt的视频属性抓取结束
# 开始BV号为1ea4y1E7eA视频属性的抓取
# BV号为1ea4y1E7eA的视频属性抓取结束
# 开始BV号为1P54y1S7Rx视频属性的抓取
# BV号为1P54y1S7Rx的视频属性抓取结束
# 开始BV号为1Wz4y1D7CY视频属性的抓取
# BV号为1Wz4y1D7CY的视频属性抓取结束
# 开始BV号为1vK411J7C8视频属性的抓取
# BV号为1vK411J7C8的视频属性抓取结束
# 开始BV号为1rt4y1Q7SD视频属性的抓取
# BV号为1rt4y1Q7SD的视频属性抓取结束
# 开始BV号为14K411J7g4视频属性的抓取
# BV号为14K411J7g4的视频属性抓取结束
# 开始BV号为1iK4y1e7Jr视频属性的抓取
# BV号为1iK4y1e7Jr的视频属性抓取结束
# 开始BV号为14z4y1D74K视频属性的抓取
# BV号为14z4y1D74K的视频属性抓取结束
# 开始BV号为1B54y1v74R视频属性的抓取
# BV号为1B54y1v74R的视频属性抓取结束
# 开始BV号为1954y1q7Ci视频属性的抓取
# BV号为1954y1q7Ci的视频属性抓取结束
# 开始BV号为1JT4y1j7Q8视频属性的抓取
# BV号为1JT4y1j7Q8的视频属性抓取结束
# 开始BV号为1BK411H744视频属性的抓取
# BV号为1BK411H744的视频属性抓取结束
# 开始BV号为1zh411o7sP视频属性的抓取
# BV号为1zh411o7sP的视频属性抓取结束
# 开始BV号为1vz411v7aR视频属性的抓取
# BV号为1vz411v7aR的视频属性抓取结束
# 开始BV号为1ND4y1D72x视频属性的抓取
# BV号为1ND4y1D72x的视频属性抓取结束
# 开始BV号为1wK411n78f视频属性的抓取
# BV号为1wK411n78f的视频属性抓取结束
# 开始BV号为1Mg4y1i7FK视频属性的抓取
# BV号为1Mg4y1i7FK的视频属性抓取结束
# 开始BV号为1Dt4y1Q7JE视频属性的抓取
# BV号为1Dt4y1Q7JE的视频属性抓取结束
# 开始BV号为1XV41167zp视频属性的抓取
# BV号为1XV41167zp的视频属性抓取结束
# 开始BV号为1gz4y1D7YV视频属性的抓取
# BV号为1gz4y1D7YV的视频属性抓取结束
# 开始BV号为1oi4y1g7nc视频属性的抓取
# BV号为1oi4y1g7nc的视频属性抓取结束
# 开始BV号为1dv411i7ab视频属性的抓取
# BV号为1dv411i7ab的视频属性抓取结束
# 开始BV号为11f4y1R72p视频属性的抓取
# BV号为11f4y1R72p的视频属性抓取结束
# 开始BV号为1ZK4y1s7Zr视频属性的抓取
# BV号为1ZK4y1s7Zr的视频属性抓取结束
# 开始BV号为1nv411q7RT视频属性的抓取
# BV号为1nv411q7RT的视频属性抓取结束
# 开始BV号为15p4y1S7Gk视频属性的抓取
# BV号为15p4y1S7Gk的视频属性抓取结束
# 开始BV号为1ni4y1375z视频属性的抓取
# BV号为1ni4y1375z的视频属性抓取结束
# 开始BV号为1eC4y1h7AV视频属性的抓取
# BV号为1eC4y1h7AV的视频属性抓取结束
# 开始BV号为1YA411e7YD视频属性的抓取
# BV号为1YA411e7YD的视频属性抓取结束
# 开始BV号为1R54y1q7Vc视频属性的抓取
# BV号为1R54y1q7Vc的视频属性抓取结束
# 开始BV号为11K4y1e75b视频属性的抓取
# BV号为11K4y1e75b的视频属性抓取结束
# 开始BV号为1wf4y1R7M5视频属性的抓取
# BV号为1wf4y1R7M5的视频属性抓取结束
# 开始BV号为1Da4y1a7bQ视频属性的抓取
# BV号为1Da4y1a7bQ的视频属性抓取结束
# 开始BV号为1XK4y1e7JW视频属性的抓取
# BV号为1XK4y1e7JW的视频属性抓取结束
# 开始BV号为1854y1S7UA视频属性的抓取
# BV号为1854y1S7UA的视频属性抓取结束
# 开始BV号为1Tt4y1D7WG视频属性的抓取
# BV号为1Tt4y1D7WG的视频属性抓取结束
# 开始BV号为1ip4y1i7m4视频属性的抓取
# BV号为1ip4y1i7m4的视频属性抓取结束
# 开始BV号为1QZ4y1u7Zx视频属性的抓取
# BV号为1QZ4y1u7Zx的视频属性抓取结束
# 开始BV号为1kk4y1B7v8视频属性的抓取
# BV号为1kk4y1B7v8的视频属性抓取结束
# 开始BV号为1sz4y1Q7Z5视频属性的抓取
# BV号为1sz4y1Q7Z5的视频属性抓取结束
# 开始BV号为1aC4y1b7ha视频属性的抓取
# BV号为1aC4y1b7ha的视频属性抓取结束
# 开始BV号为1SZ4y1u7GW视频属性的抓取
# BV号为1SZ4y1u7GW的视频属性抓取结束
# 开始BV号为1Dp4y1U7yy视频属性的抓取
# BV号为1Dp4y1U7yy的视频属性抓取结束
# 开始BV号为19h411o74V视频属性的抓取
# BV号为19h411o74V的视频属性抓取结束
# 开始BV号为1mV41167jW视频属性的抓取
# BV号为1mV41167jW的视频属性抓取结束
# 开始BV号为1Si4y1u7vz视频属性的抓取
# BV号为1Si4y1u7vz的视频属性抓取结束
# 开始BV号为1Vk4y127E1视频属性的抓取
# BV号为1Vk4y127E1的视频属性抓取结束
# 开始BV号为1Ek4y127w8视频属性的抓取
# BV号为1Ek4y127w8的视频属性抓取结束
# 开始BV号为1iT4y1576B视频属性的抓取
# BV号为1iT4y1576B的视频属性抓取结束
# 开始BV号为1Kp4y1i7tu视频属性的抓取
# BV号为1Kp4y1i7tu的视频属性抓取结束
# 开始BV号为1nv41117vc视频属性的抓取
# BV号为1nv41117vc的视频属性抓取结束
# 开始BV号为1R64y1F7Qq视频属性的抓取
# BV号为1R64y1F7Qq的视频属性抓取结束
# 开始BV号为1Sh411d7Yx视频属性的抓取
# BV号为1Sh411d7Yx的视频属性抓取结束
# 开始BV号为1cp4y1i7yc视频属性的抓取
# BV号为1cp4y1i7yc的视频属性抓取结束
# 开始BV号为1cf4y1X7DG视频属性的抓取
# BV号为1cf4y1X7DG的视频属性抓取结束
# 开始BV号为1NK411M7sY视频属性的抓取
# BV号为1NK411M7sY的视频属性抓取结束
# 开始BV号为1Qh41197og视频属性的抓取
# BV号为1Qh41197og的视频属性抓取结束
# 开始BV号为1gK411M7ib视频属性的抓取
# BV号为1gK411M7ib的视频属性抓取结束
# 开始BV号为1Sa4y1J7L1视频属性的抓取
# BV号为1Sa4y1J7L1的视频属性抓取结束
# 开始BV号为11a4y177UP视频属性的抓取
# BV号为11a4y177UP的视频属性抓取结束
# 开始BV号为1sV411U7xm视频属性的抓取
# BV号为1sV411U7xm的视频属性抓取结束
# 开始BV号为1q54y1e7sd视频属性的抓取
# BV号为1q54y1e7sd的视频属性抓取结束
# 开始BV号为1rt4y1U7ct视频属性的抓取
# BV号为1rt4y1U7ct的视频属性抓取结束
# 开始BV号为1tk4y1m73i视频属性的抓取
# BV号为1tk4y1m73i的视频属性抓取结束
# 开始BV号为1ja4y1J7Fc视频属性的抓取
# BV号为1ja4y1J7Fc的视频属性抓取结束
# 开始BV号为1x54y1v788视频属性的抓取
# BV号为1x54y1v788的视频属性抓取结束
# 开始BV号为1X5411a7pg视频属性的抓取
# BV号为1X5411a7pg的视频属性抓取结束
# 开始BV号为1Vh411o7bL视频属性的抓取
# BV号为1Vh411o7bL的视频属性抓取结束
# 开始BV号为16K4y1Y777视频属性的抓取
# BV号为16K4y1Y777的视频属性抓取结束
# 开始BV号为1Rf4y197ra视频属性的抓取
# BV号为1Rf4y197ra的视频属性抓取结束
# 开始BV号为19D4y1U7Kj视频属性的抓取
# BV号为19D4y1U7Kj的视频属性抓取结束
# 开始BV号为1pv411i7mn视频属性的抓取
# BV号为1pv411i7mn的视频属性抓取结束
# 开始BV号为13h411o74w视频属性的抓取
# BV号为13h411o74w的视频属性抓取结束
# 开始BV号为1Mk4y1m79K视频属性的抓取
# BV号为1Mk4y1m79K的视频属性抓取结束
# 开始BV号为1rT4y1j7jB视频属性的抓取
# BV号为1rT4y1j7jB的视频属性抓取结束
# 开始BV号为1tC4y1t7X4视频属性的抓取
# BV号为1tC4y1t7X4的视频属性抓取结束
# 开始BV号为1HD4y127dG视频属性的抓取
# BV号为1HD4y127dG的视频属性抓取结束
# 开始BV号为1Tf4y197Gp视频属性的抓取
# BV号为1Tf4y197Gp的视频属性抓取结束
# 开始BV号为1Ch41197BU视频属性的抓取
# BV号为1Ch41197BU的视频属性抓取结束
# 开始BV号为1Lv41117Au视频属性的抓取
# BV号为1Lv41117Au的视频属性抓取结束
# 开始BV号为1iZ4y1K7hU视频属性的抓取
# BV号为1iZ4y1K7hU的视频属性抓取结束
# 开始BV号为1Yk4y117qe视频属性的抓取
# BV号为1Yk4y117qe的视频属性抓取结束
# 开始BV号为14k4y127tU视频属性的抓取
# BV号为14k4y127tU的视频属性抓取结束
# 开始BV号为1tK4y1e7QM视频属性的抓取
# BV号为1tK4y1e7QM的视频属性抓取结束
# 开始BV号为1kv411v7Mx视频属性的抓取
# BV号为1kv411v7Mx的视频属性抓取结束
# 开始BV号为1Jv411i7nv视频属性的抓取
# BV号为1Jv411i7nv的视频属性抓取结束
# 开始BV号为1St4y1D7uV视频属性的抓取
# BV号为1St4y1D7uV的视频属性抓取结束
# 开始BV号为1Li4y1g74S视频属性的抓取
# BV号为1Li4y1g74S的视频属性抓取结束
# 开始BV号为16k4y117HL视频属性的抓取
# BV号为16k4y117HL的视频属性抓取结束
# 开始BV号为1Dh41197Q1视频属性的抓取
# BV号为1Dh41197Q1的视频属性抓取结束
# 开始BV号为1wf4y1X7fh视频属性的抓取
# BV号为1wf4y1X7fh的视频属性抓取结束
# 开始BV号为1n54y127bG视频属性的抓取
# BV号为1n54y127bG的视频属性抓取结束
# 开始BV号为1Jt4y1D77Y视频属性的抓取
# BV号为1Jt4y1D77Y的视频属性抓取结束
# 开始BV号为1Q64y1F7zZ视频属性的抓取
# BV号为1Q64y1F7zZ的视频属性抓取结束
# 开始BV号为18C4y1t7JR视频属性的抓取
# BV号为18C4y1t7JR的视频属性抓取结束
# 开始BV号为1dK411N7zD视频属性的抓取
# BV号为1dK411N7zD的视频属性抓取结束
# 开始BV号为11D4y1U7Yo视频属性的抓取
# BV号为11D4y1U7Yo的视频属性抓取结束
# 开始BV号为1wV411S7ks视频属性的抓取
# BV号为1wV411S7ks的视频属性抓取结束
# 开始BV号为1b541187dC视频属性的抓取
# BV号为1b541187dC的视频属性抓取结束
# 开始BV号为1ja4y1J7Kw视频属性的抓取
# BV号为1ja4y1J7Kw的视频属性抓取结束
# 开始BV号为1QA411J7wp视频属性的抓取
# BV号为1QA411J7wp的视频属性抓取结束
# 开始BV号为12k4y117AE视频属性的抓取
# BV号为12k4y117AE的视频属性抓取结束
# 开始BV号为1Nk4y1275Y视频属性的抓取
# BV号为1Nk4y1275Y的视频属性抓取结束
# 开始BV号为1Uf4y197uW视频属性的抓取
# BV号为1Uf4y197uW的视频属性抓取结束
# 开始BV号为11f4y197xC视频属性的抓取
# BV号为11f4y197xC的视频属性抓取结束
# 开始BV号为1zK4y1v792视频属性的抓取
# BV号为1zK4y1v792的视频属性抓取结束
# 开始BV号为15K411T77u视频属性的抓取
# BV号为15K411T77u的视频属性抓取结束
# 开始BV号为1si4y1g7zx视频属性的抓取
# BV号为1si4y1g7zx的视频属性抓取结束
# 开始BV号为1eT4y1w7fQ视频属性的抓取
# BV号为1eT4y1w7fQ的视频属性抓取结束
# 开始BV号为1FV411S79i视频属性的抓取
# BV号为1FV411S79i的视频属性抓取结束
# 开始BV号为1aZ4y1K7Ao视频属性的抓取
# BV号为1aZ4y1K7Ao的视频属性抓取结束
# 开始BV号为1a54y1e739视频属性的抓取
# BV号为1a54y1e739的视频属性抓取结束
# 开始BV号为1ZV411z7hB视频属性的抓取
# BV号为1ZV411z7hB的视频属性抓取结束
# 开始BV号为18C4y1t7bT视频属性的抓取
# BV号为18C4y1t7bT的视频属性抓取结束
# 开始BV号为1Zh41197H4视频属性的抓取
# BV号为1Zh41197H4的视频属性抓取结束
# 开始BV号为1Cv411v7o1视频属性的抓取
# BV号为1Cv411v7o1的视频属性抓取结束
# 开始BV号为1s541187D8视频属性的抓取
# BV号为1s541187D8的视频属性抓取结束
# 开始BV号为1Wf4y197h6视频属性的抓取
# BV号为1Wf4y197h6的视频属性抓取结束
# 开始BV号为1664y1c7gu视频属性的抓取
# BV号为1664y1c7gu的视频属性抓取结束
# 开始BV号为1nC4y1t7oX视频属性的抓取
# BV号为1nC4y1t7oX的视频属性抓取结束
# 开始BV号为1LC4y1t7fy视频属性的抓取
# BV号为1LC4y1t7fy的视频属性抓取结束
# 开始BV号为1Zk4y1177W视频属性的抓取
# BV号为1Zk4y1177W的视频属性抓取结束
# 开始BV号为1Ut4y1U7Ub视频属性的抓取
# BV号为1Ut4y1U7Ub的视频属性抓取结束
# 开始BV号为1a5411a7Zc视频属性的抓取
# BV号为1a5411a7Zc的视频属性抓取结束
# 开始BV号为1Ev411i79Q视频属性的抓取
# BV号为1Ev411i79Q的视频属性抓取结束
# 开始BV号为1ZK411T7aE视频属性的抓取
# BV号为1ZK411T7aE的视频属性抓取结束
# 开始BV号为1DK411T77E视频属性的抓取
# BV号为1DK411T77E的视频属性抓取结束
# 开始BV号为12p4y1Y7E8视频属性的抓取
# BV号为12p4y1Y7E8的视频属性抓取结束
# 开始BV号为1ZV411z7wm视频属性的抓取
# BV号为1ZV411z7wm的视频属性抓取结束
# 开始BV号为1Gi4y1g7D3视频属性的抓取
# BV号为1Gi4y1g7D3的视频属性抓取结束
# 开始BV号为1E64y1c7St视频属性的抓取
# BV号为1E64y1c7St的视频属性抓取结束
# 开始BV号为17Z4y1K7np视频属性的抓取
# BV号为17Z4y1K7np的视频属性抓取结束
# 开始BV号为13A411e79A视频属性的抓取
# BV号为13A411e79A的视频属性抓取结束
# 开始BV号为1Lz4y1Q7zt视频属性的抓取
# BV号为1Lz4y1Q7zt的视频属性抓取结束
# 开始BV号为1Th411d7za视频属性的抓取
# BV号为1Th411d7za的视频属性抓取结束
# 开始BV号为1uZ4y1T71y视频属性的抓取
# BV号为1uZ4y1T71y的视频属性抓取结束
# 开始BV号为1sA411n7tf视频属性的抓取
# BV号为1sA411n7tf的视频属性抓取结束
# 开始BV号为1JK411T7X5视频属性的抓取
# BV号为1JK411T7X5的视频属性抓取结束
# 开始BV号为1ff4y1X7Ax视频属性的抓取
# BV号为1ff4y1X7Ax的视频属性抓取结束
# 开始BV号为1UD4y127Gk视频属性的抓取
# BV号为1UD4y127Gk的视频属性抓取结束
# 开始BV号为1z54y1v7WP视频属性的抓取
# BV号为1z54y1v7WP的视频属性抓取结束
# 开始BV号为1Ev411i7Bu视频属性的抓取
# BV号为1Ev411i7Bu的视频属性抓取结束
# 开始BV号为15p4y1v7W9视频属性的抓取
# BV号为15p4y1v7W9的视频属性抓取结束
# 开始BV号为1Np4y1i7Su视频属性的抓取
# BV号为1Np4y1i7Su的视频属性抓取结束
# 开始BV号为185411a7BY视频属性的抓取
# BV号为185411a7BY的视频属性抓取结束
# 开始BV号为1AD4y1Z7J3视频属性的抓取
# 开始BV号为1AD4y1Z7J3视频属性的抓取
# BV号为1AD4y1Z7J3的视频属性抓取结束
# 开始BV号为1nz4y1Z74A视频属性的抓取
# BV号为1nz4y1Z74A的视频属性抓取结束
# 开始BV号为1sK4y1e75H视频属性的抓取
# BV号为1sK4y1e75H的视频属性抓取结束
# 开始BV号为1cV411U734视频属性的抓取
# BV号为1cV411U734的视频属性抓取结束
# 开始BV号为1xD4y1o72U视频属性的抓取
# BV号为1xD4y1o72U的视频属性抓取结束
# 开始BV号为12h411X7N6视频属性的抓取
# BV号为12h411X7N6的视频属性抓取结束
# 开始BV号为1fZ4y1N7xC视频属性的抓取
# BV号为1fZ4y1N7xC的视频属性抓取结束
# 开始BV号为1Da4y1L7Mm视频属性的抓取
# BV号为1Da4y1L7Mm的视频属性抓取结束
# 开始BV号为1pK411K7JQ视频属性的抓取
# BV号为1pK411K7JQ的视频属性抓取结束
# 开始BV号为1FK4y1a7CA视频属性的抓取
# BV号为1FK4y1a7CA的视频属性抓取结束
# 开始BV号为1op4y1Y7es视频属性的抓取
# BV号为1op4y1Y7es的视频属性抓取结束
# 开始BV号为1r54y1C7ho视频属性的抓取
# BV号为1r54y1C7ho的视频属性抓取结束
# 开始BV号为1uV411m7T4视频属性的抓取
# BV号为1uV411m7T4的视频属性抓取结束
# 开始BV号为1H54y1m7oV视频属性的抓取
# BV号为1H54y1m7oV的视频属性抓取结束
# 开始BV号为1Ty4y1y77X视频属性的抓取
# BV号为1Ty4y1y77X的视频属性抓取结束
# 开始BV号为1af4y1X7xX视频属性的抓取
# BV号为1af4y1X7xX的视频属性抓取结束
# 开始BV号为1x54y127on视频属性的抓取
# BV号为1x54y127on的视频属性抓取结束
# 开始BV号为1gt4y1q7Sj视频属性的抓取
# BV号为1gt4y1q7Sj的视频属性抓取结束
# 开始BV号为1ny4y1k7LK视频属性的抓取
# BV号为1ny4y1k7LK的视频属性抓取结束
# 开始BV号为17v411C7vx视频属性的抓取
# BV号为17v411C7vx的视频属性抓取结束
# 开始BV号为16v411C7pG视频属性的抓取
# BV号为16v411C7pG的视频属性抓取结束
# 开始BV号为1wf4y1X7ka视频属性的抓取
# BV号为1wf4y1X7ka的视频属性抓取结束
# 开始BV号为1it4y1S7Zf视频属性的抓取
# BV号为1it4y1S7Zf的视频属性抓取结束
# 开始BV号为1fy4y1y7gv视频属性的抓取
# BV号为1fy4y1y7gv的视频属性抓取结束
# 开始BV号为1Qk4y1y77a视频属性的抓取
# BV号为1Qk4y1y77a的视频属性抓取结束
# 开始BV号为1U54y1C7TE视频属性的抓取
# BV号为1U54y1C7TE的视频属性抓取结束
# 开始BV号为17541187NE视频属性的抓取
# BV号为17541187NE的视频属性抓取结束
# 开始BV号为11k4y1y76j视频属性的抓取
# BV号为11k4y1y76j的视频属性抓取结束
# 开始BV号为1H54y1y75J视频属性的抓取
# BV号为1H54y1y75J的视频属性抓取结束
# 开始BV号为1iy4y1y7vc视频属性的抓取
# BV号为1iy4y1y7vc的视频属性抓取结束
# 开始BV号为1Ly4y1C7Eu视频属性的抓取
# BV号为1Ly4y1C7Eu的视频属性抓取结束
# 开始BV号为1Nh411R7Vy视频属性的抓取
# BV号为1Nh411R7Vy的视频属性抓取结束
# 开始BV号为1hK4y1a7kj视频属性的抓取
# BV号为1hK4y1a7kj的视频属性抓取结束
# 开始BV号为1T54y117Pm视频属性的抓取
# BV号为1T54y117Pm的视频属性抓取结束
# 开始BV号为1pk4y117Wj视频属性的抓取
# BV号为1pk4y117Wj的视频属性抓取结束
# 开始BV号为1Sz4y1f7gR视频属性的抓取
# BV号为1Sz4y1f7gR的视频属性抓取结束
# 开始BV号为1Wi4y1u7yy视频属性的抓取
# BV号为1Wi4y1u7yy的视频属性抓取结束
# 开始BV号为1uh411R785视频属性的抓取
# BV号为1uh411R785的视频属性抓取结束
# 开始BV号为1cK4y1Y7BT视频属性的抓取
# BV号为1cK4y1Y7BT的视频属性抓取结束
# 开始BV号为1my4y1y78x视频属性的抓取
# BV号为1my4y1y78x的视频属性抓取结束
# 开始BV号为1Kf4y1Q7oP视频属性的抓取
# BV号为1Kf4y1Q7oP的视频属性抓取结束
# 开始BV号为1pD4y1o7kk视频属性的抓取
# BV号为1pD4y1o7kk的视频属性抓取结束
# 开始BV号为1Wh411X7jG视频属性的抓取
# BV号为1Wh411X7jG的视频属性抓取结束
# 开始BV号为1gv411y79T视频属性的抓取
# BV号为1gv411y79T的视频属性抓取结束
# 开始BV号为1dk4y1y7qP视频属性的抓取
# BV号为1dk4y1y7qP的视频属性抓取结束
# 开始BV号为1ty4y1y7fT视频属性的抓取
# BV号为1ty4y1y7fT的视频属性抓取结束
# 开始BV号为1Ht4y1S7z5视频属性的抓取
# BV号为1Ht4y1S7z5的视频属性抓取结束
# 开始BV号为1t64y1F78V视频属性的抓取
# BV号为1t64y1F78V的视频属性抓取结束
# 开始BV号为1EK411K7Ua视频属性的抓取
# BV号为1EK411K7Ua的视频属性抓取结束
# 开始BV号为1YK411K7cX视频属性的抓取
# BV号为1YK411K7cX的视频属性抓取结束
# 开始BV号为1XK4y187Ts视频属性的抓取
# BV号为1XK4y187Ts的视频属性抓取结束
# 开始BV号为1Ay4y1y7ez视频属性的抓取
# BV号为1Ay4y1y7ez的视频属性抓取结束
# 开始BV号为1dk4y1y7kv视频属性的抓取
# BV号为1dk4y1y7kv的视频属性抓取结束
# 开始BV号为1yK4y1a7u4视频属性的抓取
# BV号为1yK4y1a7u4的视频属性抓取结束
# 开始BV号为17D4y1o7mU视频属性的抓取
# BV号为17D4y1o7mU的视频属性抓取结束
# 开始BV号为1bh411X7oA视频属性的抓取
# BV号为1bh411X7oA的视频属性抓取结束
# 开始BV号为11t4y1i7mc视频属性的抓取
# BV号为11t4y1i7mc的视频属性抓取结束
# 开始BV号为1Ep4y1e7vm视频属性的抓取
# BV号为1Ep4y1e7vm的视频属性抓取结束
# 开始BV号为18k4y1y7G9视频属性的抓取
# BV号为18k4y1y7G9的视频属性抓取结束
# 开始BV号为1mK411P7D7视频属性的抓取
# BV号为1mK411P7D7的视频属性抓取结束
# 开始BV号为1ua4y1j71c视频属性的抓取
# BV号为1ua4y1j71c的视频属性抓取结束
# 开始BV号为1M64y1F7AE视频属性的抓取
# BV号为1M64y1F7AE的视频属性抓取结束
# 开始BV号为1oA411n7jw视频属性的抓取
# BV号为1oA411n7jw的视频属性抓取结束
# 开始BV号为1YD4y1o7t8视频属性的抓取
# BV号为1YD4y1o7t8的视频属性抓取结束
# 开始BV号为1wf4y1Q7p8视频属性的抓取
# BV号为1wf4y1Q7p8的视频属性抓取结束
# 开始BV号为1iK411K7cV视频属性的抓取
# BV号为1iK411K7cV的视频属性抓取结束
# 开始BV号为1q5411b77Y视频属性的抓取
# BV号为1q5411b77Y的视频属性抓取结束
# 开始BV号为1MZ4y1T7Km视频属性的抓取
# BV号为1MZ4y1T7Km的视频属性抓取结束
# 开始BV号为1Q54y1177r视频属性的抓取
# BV号为1Q54y1177r的视频属性抓取结束
# 开始BV号为1GV411m7VB视频属性的抓取
# BV号为1GV411m7VB的视频属性抓取结束
# 开始BV号为1Kf4y1D7j2视频属性的抓取
# 开始BV号为1Kf4y1D7j2视频属性的抓取
# BV号为1Kf4y1D7j2的视频属性抓取结束
# 开始BV号为1zT4y1w77A视频属性的抓取
# BV号为1zT4y1w77A的视频属性抓取结束
# 开始BV号为1fi4y177Ub视频属性的抓取
# BV号为1fi4y177Ub的视频属性抓取结束
# 开始BV号为1sK4y1e7zs视频属性的抓取
# BV号为1sK4y1e7zs的视频属性抓取结束
# 开始BV号为1Qf4y1D7MH视频属性的抓取
# BV号为1Qf4y1D7MH的视频属性抓取结束
# 开始BV号为17h411X7j9视频属性的抓取
# BV号为17h411X7j9的视频属性抓取结束
# 开始BV号为1M541187LG视频属性的抓取
# BV号为1M541187LG的视频属性抓取结束
# 开始BV号为1aT4y1A7c6视频属性的抓取
# BV号为1aT4y1A7c6的视频属性抓取结束
# 开始BV号为1Ay4y1y7z7视频属性的抓取
# BV号为1Ay4y1y7z7的视频属性抓取结束
# 开始BV号为1qa4y1j7fi视频属性的抓取
# BV号为1qa4y1j7fi的视频属性抓取结束
# 开始BV号为1p54y11751视频属性的抓取
# BV号为1p54y11751的视频属性抓取结束
# 开始BV号为1Sf4y1Q7pA视频属性的抓取
# BV号为1Sf4y1Q7pA的视频属性抓取结束
# 开始BV号为1iV411m75b视频属性的抓取
# BV号为1iV411m75b的视频属性抓取结束
# 开始BV号为1M541187Hk视频属性的抓取
# BV号为1M541187Hk的视频属性抓取结束
# 开始BV号为13p4y1i7oq视频属性的抓取
# BV号为13p4y1i7oq的视频属性抓取结束
# 开始BV号为1sa4y1E7YH视频属性的抓取
# BV号为1sa4y1E7YH的视频属性抓取结束
# 开始BV号为1554y117pR视频属性的抓取
# BV号为1554y117pR的视频属性抓取结束
# 开始BV号为1tK411K7Pm视频属性的抓取
# BV号为1tK411K7Pm的视频属性抓取结束
# 开始BV号为14z4y1Z74y视频属性的抓取
# BV号为14z4y1Z74y的视频属性抓取结束
# 开始BV号为1c5411j7dB视频属性的抓取
# BV号为1c5411j7dB的视频属性抓取结束
# 开始BV号为18t4y1q7hu视频属性的抓取
# BV号为18t4y1q7hu的视频属性抓取结束
# 开始BV号为1v54y1C7CS视频属性的抓取
# BV号为1v54y1C7CS的视频属性抓取结束
# 开始BV号为1FD4y1Z7se视频属性的抓取
# BV号为1FD4y1Z7se的视频属性抓取结束
# 开始BV号为16A411E7Z3视频属性的抓取
# BV号为16A411E7Z3的视频属性抓取结束
# 开始BV号为1Ea4y1j72B视频属性的抓取
# BV号为1Ea4y1j72B的视频属性抓取结束
# 开始BV号为1P54y1v7dJ视频属性的抓取
# BV号为1P54y1v7dJ的视频属性抓取结束
# 开始BV号为1Ui4y1M7Hs视频属性的抓取
# BV号为1Ui4y1M7Hs的视频属性抓取结束
# 开始BV号为1654y1y7VU视频属性的抓取
# BV号为1654y1y7VU的视频属性抓取结束
# 开始BV号为1FD4y1Z7z9视频属性的抓取
# BV号为1FD4y1Z7z9的视频属性抓取结束
# 开始BV号为1ga4y1L7mH视频属性的抓取
# BV号为1ga4y1L7mH的视频属性抓取结束
# 开始BV号为1C54y1y7J5视频属性的抓取
# BV号为1C54y1y7J5的视频属性抓取结束
# 开始BV号为1354y1r7Fr视频属性的抓取
# BV号为1354y1r7Fr的视频属性抓取结束
# 开始BV号为16p4y1k78n视频属性的抓取
# BV号为16p4y1k78n的视频属性抓取结束
# 开始BV号为1rz4y1d7w3视频属性的抓取
# BV号为1rz4y1d7w3的视频属性抓取结束
# 开始BV号为1P541177rp视频属性的抓取
# BV号为1P541177rp的视频属性抓取结束
# 开始BV号为1BK4y1h7VE视频属性的抓取
# BV号为1BK4y1h7VE的视频属性抓取结束
# 开始BV号为1M54y1r78h视频属性的抓取
# BV号为1M54y1r78h的视频属性抓取结束
# 开始BV号为11z4y1d7gW视频属性的抓取
# BV号为11z4y1d7gW的视频属性抓取结束
# 开始BV号为15V411y7cX视频属性的抓取
# BV号为15V411y7cX的视频属性抓取结束
# 开始BV号为1tK411A7ro视频属性的抓取
# BV号为1tK411A7ro的视频属性抓取结束
# 开始BV号为1Va4y1L7uE视频属性的抓取
# BV号为1Va4y1L7uE的视频属性抓取结束
# 开始BV号为1Pa411A7ju视频属性的抓取
# BV号为1Pa411A7ju的视频属性抓取结束
# 开始BV号为1454y117pM视频属性的抓取
# BV号为1454y117pM的视频属性抓取结束
# 开始BV号为1354y127a9视频属性的抓取
# BV号为1354y127a9的视频属性抓取结束
# 开始BV号为1254y1y7A2视频属性的抓取
# BV号为1254y1y7A2的视频属性抓取结束
# 开始BV号为1EK411N798视频属性的抓取
# BV号为1EK411N798的视频属性抓取结束
# 开始BV号为12i4y1j7Ft视频属性的抓取
# BV号为12i4y1j7Ft的视频属性抓取结束
# 开始BV号为1Ar4y1w7Gz视频属性的抓取
# BV号为1Ar4y1w7Gz的视频属性抓取结束
# 开始BV号为1k5411j7Qu视频属性的抓取
# BV号为1k5411j7Qu的视频属性抓取结束
# 开始BV号为1Xp4y1a799视频属性的抓取
# BV号为1Xp4y1a799的视频属性抓取结束
# 开始BV号为1Mp4y1Y7iK视频属性的抓取
# BV号为1Mp4y1Y7iK的视频属性抓取结束
# 开始BV号为1V54y1C7bA视频属性的抓取
# BV号为1V54y1C7bA的视频属性抓取结束
# 开始BV号为1xp4y1Y7mE视频属性的抓取
# BV号为1xp4y1Y7mE的视频属性抓取结束
# 开始BV号为1P5411L7yK视频属性的抓取
# BV号为1P5411L7yK的视频属性抓取结束
# 开始BV号为1RK411A7hj视频属性的抓取
# BV号为1RK411A7hj的视频属性抓取结束
# 开始BV号为1T5411L7hC视频属性的抓取
# BV号为1T5411L7hC的视频属性抓取结束
# 开始BV号为1hT4y1F7KA视频属性的抓取
# BV号为1hT4y1F7KA的视频属性抓取结束
# 开始BV号为1tz4y1C7vG视频属性的抓取
# BV号为1tz4y1C7vG的视频属性抓取结束
# 开始BV号为1Kr4y1w7nS视频属性的抓取
# BV号为1Kr4y1w7nS的视频属性抓取结束
# 开始BV号为1ba411A7iN视频属性的抓取
# BV号为1ba411A7iN的视频属性抓取结束
# 开始BV号为14V41127Gp视频属性的抓取
# BV号为14V41127Gp的视频属性抓取结束
# 开始BV号为1JD4y1975o视频属性的抓取
# BV号为1JD4y1975o的视频属性抓取结束
# 开始BV号为1RK4y187Vd视频属性的抓取
# BV号为1RK4y187Vd的视频属性抓取结束
# 开始BV号为1Ba411A7bP视频属性的抓取
# BV号为1Ba411A7bP的视频属性抓取结束
# 开始BV号为1uD4y1R7LX视频属性的抓取
# BV号为1uD4y1R7LX的视频属性抓取结束
# 开始BV号为1yz4y1Z7C9视频属性的抓取
# BV号为1yz4y1Z7C9的视频属性抓取结束
# 开始BV号为1n5411L77z视频属性的抓取
# BV号为1n5411L77z的视频属性抓取结束
# 开始BV号为1Rf4y1B7Gq视频属性的抓取
# BV号为1Rf4y1B7Gq的视频属性抓取结束
# 开始BV号为12y4y1z7Um视频属性的抓取
# BV号为12y4y1z7Um的视频属性抓取结束
# 开始BV号为18p4y1Y7L9视频属性的抓取
# BV号为18p4y1Y7L9的视频属性抓取结束
# 开始BV号为1Mf4y1B78G视频属性的抓取
# BV号为1Mf4y1B78G的视频属性抓取结束
# 开始BV号为1d5411j7ST视频属性的抓取
# BV号为1d5411j7ST的视频属性抓取结束
# 开始BV号为1V54y1k7tW视频属性的抓取
# BV号为1V54y1k7tW的视频属性抓取结束
# 开始BV号为1UK4y1874s视频属性的抓取
# BV号为1UK4y1874s的视频属性抓取结束
# 开始BV号为1TT4y1F7uG视频属性的抓取
# BV号为1TT4y1F7uG的视频属性抓取结束
# 开始BV号为1VA411E7C2视频属性的抓取
# BV号为1VA411E7C2的视频属性抓取结束
# 开始BV号为1b54y1k7ci视频属性的抓取
# BV号为1b54y1k7ci的视频属性抓取结束
# 开始BV号为1g541177UU视频属性的抓取
# BV号为1g541177UU的视频属性抓取结束
# 开始BV号为1HV411y7Gb视频属性的抓取
# BV号为1HV411y7Gb的视频属性抓取结束
# 开始BV号为1gD4y197d5视频属性的抓取
# BV号为1gD4y197d5的视频属性抓取结束
# 开始BV号为1ty4y1C7gW视频属性的抓取
# BV号为1ty4y1C7gW的视频属性抓取结束
# 开始BV号为1ar4y1w7Lm视频属性的抓取
# BV号为1ar4y1w7Lm的视频属性抓取结束
# 开始BV号为1Da4y1579r视频属性的抓取
# BV号为1Da4y1579r的视频属性抓取结束
# 开始BV号为1da411A7yV视频属性的抓取
# BV号为1da411A7yV的视频属性抓取结束
# 开始BV号为1C54y1k7xC视频属性的抓取
# BV号为1C54y1k7xC的视频属性抓取结束
# 开始BV号为13Z4y1V7Gw视频属性的抓取
# BV号为13Z4y1V7Gw的视频属性抓取结束
# 开始BV号为1sf4y1q7aX视频属性的抓取
# BV号为1sf4y1q7aX的视频属性抓取结束
# 开始BV号为1fZ4y157GD视频属性的抓取
# BV号为1fZ4y157GD的视频属性抓取结束
# 开始BV号为1WD4y1d7h5视频属性的抓取
# BV号为1WD4y1d7h5的视频属性抓取结束
# 开始BV号为1zp4y1a7zf视频属性的抓取
# BV号为1zp4y1a7zf的视频属性抓取结束
# 开始BV号为1qD4y1d7Pz视频属性的抓取
# BV号为1qD4y1d7Pz的视频属性抓取结束
# 开始BV号为12t4y1q7J2视频属性的抓取
# BV号为12t4y1q7J2的视频属性抓取结束
# 开始BV号为1ry4y1r7Po视频属性的抓取
# BV号为1ry4y1r7Po的视频属性抓取结束
# 开始BV号为1PA411j7De视频属性的抓取
# BV号为1PA411j7De的视频属性抓取结束
# 开始BV号为1Vt4y1i7kZ视频属性的抓取
# BV号为1Vt4y1i7kZ的视频属性抓取结束
# 开始BV号为1vz4y1d7xj视频属性的抓取
# BV号为1vz4y1d7xj的视频属性抓取结束
# 开始BV号为1hp4y167i2视频属性的抓取
# BV号为1hp4y167i2的视频属性抓取结束
# 开始BV号为1Vi4y177Uw视频属性的抓取
# BV号为1Vi4y177Uw的视频属性抓取结束
# 开始BV号为1wa411A7sV视频属性的抓取
# BV号为1wa411A7sV的视频属性抓取结束
# 开始BV号为1cr4y1w7bR视频属性的抓取
# BV号为1cr4y1w7bR的视频属性抓取结束
# 开始BV号为1G54y127zV视频属性的抓取
# BV号为1G54y127zV的视频属性抓取结束
# 开始BV号为11Z4y157e5视频属性的抓取
# BV号为11Z4y157e5的视频属性抓取结束
# 开始BV号为1Fa411A7z5视频属性的抓取
# BV号为1Fa411A7z5的视频属性抓取结束
# 开始BV号为1pr4y1w7t2视频属性的抓取
# BV号为1pr4y1w7t2的视频属性抓取结束
# 开始BV号为1oA41177YL视频属性的抓取
# BV号为1oA41177YL的视频属性抓取结束
# 开始BV号为1et4y1v7qA视频属性的抓取
# BV号为1et4y1v7qA的视频属性抓取结束
# 开始BV号为1aK411A7KH视频属性的抓取
# BV号为1aK411A7KH的视频属性抓取结束
# 开始BV号为1Ky4y1r78k视频属性的抓取
# BV号为1Ky4y1r78k的视频属性抓取结束
# 开始BV号为1ta4y1L7a8视频属性的抓取
# BV号为1ta4y1L7a8的视频属性抓取结束
# 开始BV号为1uV41127Gc视频属性的抓取
# BV号为1uV41127Gc的视频属性抓取结束
# 开始BV号为1wA411j7i5视频属性的抓取
# BV号为1wA411j7i5的视频属性抓取结束
# 开始BV号为1oK411A79T视频属性的抓取
# BV号为1oK411A79T的视频属性抓取结束
# 开始BV号为1BA411J7Ca视频属性的抓取
# BV号为1BA411J7Ca的视频属性抓取结束
# 开始BV号为1fK4y1f7ot视频属性的抓取
# BV号为1fK4y1f7ot的视频属性抓取结束
# 开始BV号为1ci4y177Ky视频属性的抓取
# BV号为1ci4y177Ky的视频属性抓取结束
# 开始BV号为13h41197zn视频属性的抓取
# BV号为13h41197zn的视频属性抓取结束
# 开始BV号为1BK411A7jm视频属性的抓取
# BV号为1BK411A7jm的视频属性抓取结束
# 开始BV号为1cA411E7HV视频属性的抓取
# BV号为1cA411E7HV的视频属性抓取结束
# 开始BV号为1Bi4y1E7yr视频属性的抓取
# BV号为1Bi4y1E7yr的视频属性抓取结束
# 开始BV号为1EK411N7nh视频属性的抓取
# BV号为1EK411N7nh的视频属性抓取结束
# 开始BV号为18y4y1C7YP视频属性的抓取
# BV号为18y4y1C7YP的视频属性抓取结束
# 开始BV号为1Wi4y1j7Eo视频属性的抓取
# BV号为1Wi4y1j7Eo的视频属性抓取结束
# 开始BV号为1Mp4y1k7te视频属性的抓取
# BV号为1Mp4y1k7te的视频属性抓取结束
# 开始BV号为1qy4y1C7T9视频属性的抓取
# BV号为1qy4y1C7T9的视频属性抓取结束
# 开始BV号为13a4y1L7Yw视频属性的抓取
# BV号为13a4y1L7Yw的视频属性抓取结束
# 开始BV号为1Jt4y1i7xj视频属性的抓取
# BV号为1Jt4y1i7xj的视频属性抓取结束
# 开始BV号为1Mz4y1o7Hk视频属性的抓取
# BV号为1Mz4y1o7Hk的视频属性抓取结束
# 开始BV号为1y54y1k7Ba视频属性的抓取
# BV号为1y54y1k7Ba的视频属性抓取结束
# 开始BV号为1nT4y1c7f2视频属性的抓取
# BV号为1nT4y1c7f2的视频属性抓取结束
# 2020-12-21 07:37:26.119176

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-11-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_wudao_zhongguo.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 3月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月     99   99    99   99   99   99   99   99    99      99   99    99   99
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月   100  100  100  100  100  100   100
# 2月    99   99   99   99   99   99    99
# 3月   100  100  100  100  100  100   100
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月   100  100  100  100  100  100   100
# 7月    99   99   99   99   99   99    99
# 8月   100  100  100  100  100  100   100
# 9月    99   99   99   99   99   99    99

# %%
channel_wudao_zhongguo.to_json('channel_wudao_zhongguo.json')
