# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_wudao_mingxing=pd.DataFrame(columns=columns)
channel_wudao_mingxing
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[5]/div/a/span').click()  #选择“舞蹈”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[5]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '舞蹈'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[4]/a').click()  #选择“宅舞”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[4]/a').text
sub_channel
# Out:
# '明星舞蹈'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(1,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_wudao_mingxing.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-20 19:34:16.978016
# <ipython-input-9-1cc189b78ccd>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-9-1cc189b78ccd>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-9-1cc189b78ccd>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1nJ411V7hp视频属性的抓取
# BV号为1nJ411V7hp的视频属性抓取结束
# <ipython-input-9-1cc189b78ccd>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1g7411r7ha视频属性的抓取
# BV号为1g7411r7ha的视频属性抓取结束
# 开始BV号为1UJ411h7D5视频属性的抓取
# BV号为1UJ411h7D5的视频属性抓取结束
# 开始BV号为1DJ4117782视频属性的抓取
# BV号为1DJ4117782的视频属性抓取结束
# 开始BV号为13J411H7WG视频属性的抓取
# BV号为13J411H7WG的视频属性抓取结束
# 开始BV号为1aJ41187DQ视频属性的抓取
# BV号为1aJ41187DQ的视频属性抓取结束
# 开始BV号为1XJ411J7V8视频属性的抓取
# BV号为1XJ411J7V8的视频属性抓取结束
# 开始BV号为1yJ411j7fT视频属性的抓取
# BV号为1yJ411j7fT的视频属性抓取结束
# 开始BV号为1R741167r8视频属性的抓取
# BV号为1R741167r8的视频属性抓取结束
# 开始BV号为1gJ411G7at视频属性的抓取
# BV号为1gJ411G7at的视频属性抓取结束
# 开始BV号为1dJ411V7y1视频属性的抓取
# BV号为1dJ411V7y1的视频属性抓取结束
# 开始BV号为1HJ411p75e视频属性的抓取
# BV号为1HJ411p75e的视频属性抓取结束
# 开始BV号为1JJ411n7or视频属性的抓取
# BV号为1JJ411n7or的视频属性抓取结束
# 开始BV号为1D7411v7nq视频属性的抓取
# BV号为1D7411v7nq的视频属性抓取结束
# 开始BV号为1eJ411j7Rb视频属性的抓取
# BV号为1eJ411j7Rb的视频属性抓取结束
# 开始BV号为1rJ411j7YS视频属性的抓取
# BV号为1rJ411j7YS的视频属性抓取结束
# 开始BV号为1w7411B7nP视频属性的抓取
# BV号为1w7411B7nP的视频属性抓取结束
# 开始BV号为1B7411v7Yn视频属性的抓取
# BV号为1B7411v7Yn的视频属性抓取结束
# 开始BV号为1eJ41157qr视频属性的抓取
# BV号为1eJ41157qr的视频属性抓取结束
# 开始BV号为1B7411r7PZ视频属性的抓取
# BV号为1B7411r7PZ的视频属性抓取结束
# 开始BV号为1qJ411G7N2视频属性的抓取
# BV号为1qJ411G7N2的视频属性抓取结束
# 开始BV号为1J7411e7vG视频属性的抓取
# BV号为1J7411e7vG的视频属性抓取结束
# 开始BV号为127411q7t2视频属性的抓取
# BV号为127411q7t2的视频属性抓取结束
# 开始BV号为1ZJ411E7dX视频属性的抓取
# BV号为1ZJ411E7dX的视频属性抓取结束
# 开始BV号为1UJ411p7pD视频属性的抓取
# BV号为1UJ411p7pD的视频属性抓取结束
# 开始BV号为17J411J7R7视频属性的抓取
# BV号为17J411J7R7的视频属性抓取结束
# 开始BV号为1Z7411i7ds视频属性的抓取
# BV号为1Z7411i7ds的视频属性抓取结束
# 开始BV号为1HJ411L739视频属性的抓取
# BV号为1HJ411L739的视频属性抓取结束
# 开始BV号为15J411L7fn视频属性的抓取
# BV号为15J411L7fn的视频属性抓取结束
# 开始BV号为16J411J7i8视频属性的抓取
# BV号为16J411J7i8的视频属性抓取结束
# 开始BV号为1Y7411i7Me视频属性的抓取
# BV号为1Y7411i7Me的视频属性抓取结束
# 开始BV号为1EJ411h7e2视频属性的抓取
# BV号为1EJ411h7e2的视频属性抓取结束
# 开始BV号为15J411H7Ut视频属性的抓取
# BV号为15J411H7Ut的视频属性抓取结束
# 开始BV号为117411z793视频属性的抓取
# BV号为117411z793的视频属性抓取结束
# 开始BV号为1J7411i7hN视频属性的抓取
# 开始BV号为1J7411i7hN视频属性的抓取
# BV号为1J7411i7hN的视频属性抓取结束
# 开始BV号为127411e7wD视频属性的抓取
# BV号为127411e7wD的视频属性抓取结束
# 开始BV号为1DJ411b7gm视频属性的抓取
# BV号为1DJ411b7gm的视频属性抓取结束
# 开始BV号为12J411p7TD视频属性的抓取
# BV号为12J411p7TD的视频属性抓取结束
# 开始BV号为1xJ411n7me视频属性的抓取
# BV号为1xJ411n7me的视频属性抓取结束
# 开始BV号为1kJ411b74o视频属性的抓取
# BV号为1kJ411b74o的视频属性抓取结束
# 开始BV号为14J411n7mQ视频属性的抓取
# BV号为14J411n7mQ的视频属性抓取结束
# 开始BV号为1XJ41177Jg视频属性的抓取
# BV号为1XJ41177Jg的视频属性抓取结束
# 开始BV号为1Y7411k7xE视频属性的抓取
# BV号为1Y7411k7xE的视频属性抓取结束
# 开始BV号为1cJ411H7vB视频属性的抓取
# BV号为1cJ411H7vB的视频属性抓取结束
# 开始BV号为12741167TF视频属性的抓取
# BV号为12741167TF的视频属性抓取结束
# 开始BV号为1FJ411j77L视频属性的抓取
# BV号为1FJ411j77L的视频属性抓取结束
# 开始BV号为1N741167t8视频属性的抓取
# BV号为1N741167t8的视频属性抓取结束
# 开始BV号为1wJ411n7Vu视频属性的抓取
# BV号为1wJ411n7Vu的视频属性抓取结束
# 开始BV号为13J41157yb视频属性的抓取
# BV号为13J41157yb的视频属性抓取结束
# 开始BV号为1mJ411j7tG视频属性的抓取
# BV号为1mJ411j7tG的视频属性抓取结束
# 开始BV号为13J411J7Vd视频属性的抓取
# BV号为13J411J7Vd的视频属性抓取结束
# 开始BV号为1v7411a73K视频属性的抓取
# BV号为1v7411a73K的视频属性抓取结束
# 开始BV号为1cJ411j7Sx视频属性的抓取
# BV号为1cJ411j7Sx的视频属性抓取结束
# 开始BV号为1BJ411n7cT视频属性的抓取
# BV号为1BJ411n7cT的视频属性抓取结束
# 开始BV号为1S7411i7F1视频属性的抓取
# BV号为1S7411i7F1的视频属性抓取结束
# 开始BV号为1n7411Y71S视频属性的抓取
# BV号为1n7411Y71S的视频属性抓取结束
# 开始BV号为1k741167GB视频属性的抓取
# BV号为1k741167GB的视频属性抓取结束
# 开始BV号为1y7411i7xy视频属性的抓取
# BV号为1y7411i7xy的视频属性抓取结束
# 开始BV号为1vJ411p7no视频属性的抓取
# BV号为1vJ411p7no的视频属性抓取结束
# 开始BV号为14J411J7o9视频属性的抓取
# BV号为14J411J7o9的视频属性抓取结束
# 开始BV号为117411v7dZ视频属性的抓取
# BV号为117411v7dZ的视频属性抓取结束
# 开始BV号为1GJ411L7v4视频属性的抓取
# BV号为1GJ411L7v4的视频属性抓取结束
# 开始BV号为1PJ411J7Bq视频属性的抓取
# BV号为1PJ411J7Bq的视频属性抓取结束
# 开始BV号为1V7411k79f视频属性的抓取
# BV号为1V7411k79f的视频属性抓取结束
# 开始BV号为1F7411i7FJ视频属性的抓取
# BV号为1F7411i7FJ的视频属性抓取结束
# 开始BV号为1n7411i7S3视频属性的抓取
# BV号为1n7411i7S3的视频属性抓取结束
# 开始BV号为1n7411k77j视频属性的抓取
# BV号为1n7411k77j的视频属性抓取结束
# 开始BV号为1C7411z7fL视频属性的抓取
# BV号为1C7411z7fL的视频属性抓取结束
# 开始BV号为1a7411q77m视频属性的抓取
# 开始BV号为1a7411q77m视频属性的抓取
# BV号为1a7411q77m的视频属性抓取结束
# 开始BV号为1yJ41177di视频属性的抓取
# BV号为1yJ41177di的视频属性抓取结束
# 开始BV号为1gJ411V7Gn视频属性的抓取
# BV号为1gJ411V7Gn的视频属性抓取结束
# 开始BV号为1eJ411H7ha视频属性的抓取
# BV号为1eJ411H7ha的视频属性抓取结束
# 开始BV号为1QJ411L77y视频属性的抓取
# BV号为1QJ411L77y的视频属性抓取结束
# 开始BV号为1BJ411p7ii视频属性的抓取
# BV号为1BJ411p7ii的视频属性抓取结束
# 开始BV号为1C7411z7JJ视频属性的抓取
# BV号为1C7411z7JJ的视频属性抓取结束
# 开始BV号为14J411V7yj视频属性的抓取
# BV号为14J411V7yj的视频属性抓取结束
# 开始BV号为1M7411q7u2视频属性的抓取
# BV号为1M7411q7u2的视频属性抓取结束
# 开始BV号为1PJ411p7cA视频属性的抓取
# BV号为1PJ411p7cA的视频属性抓取结束
# 开始BV号为127411Y7Th视频属性的抓取
# BV号为127411Y7Th的视频属性抓取结束
# 开始BV号为1Q7411v7Pz视频属性的抓取
# BV号为1Q7411v7Pz的视频属性抓取结束
# 开始BV号为1GJ41157G6视频属性的抓取
# BV号为1GJ41157G6的视频属性抓取结束
# 开始BV号为1WJ411j7ss视频属性的抓取
# BV号为1WJ411j7ss的视频属性抓取结束
# 开始BV号为19J411n7gp视频属性的抓取
# 开始BV号为19J411n7gp视频属性的抓取
# BV号为19J411n7gp的视频属性抓取结束
# 开始BV号为1U741167HZ视频属性的抓取
# BV号为1U741167HZ的视频属性抓取结束
# 开始BV号为1SJ411b7QW视频属性的抓取
# BV号为1SJ411b7QW的视频属性抓取结束
# 开始BV号为1z7411i7nJ视频属性的抓取
# BV号为1z7411i7nJ的视频属性抓取结束
# 开始BV号为1T7411k7CH视频属性的抓取
# BV号为1T7411k7CH的视频属性抓取结束
# 开始BV号为1P7411v7Y8视频属性的抓取
# BV号为1P7411v7Y8的视频属性抓取结束
# 开始BV号为147411q7LH视频属性的抓取
# BV号为147411q7LH的视频属性抓取结束
# 开始BV号为1F741167pY视频属性的抓取
# BV号为1F741167pY的视频属性抓取结束
# 开始BV号为11J411V7Yi视频属性的抓取
# BV号为11J411V7Yi的视频属性抓取结束
# 开始BV号为1dJ411n7S3视频属性的抓取
# BV号为1dJ411n7S3的视频属性抓取结束
# 开始BV号为18J411b7gs视频属性的抓取
# BV号为18J411b7gs的视频属性抓取结束
# 开始BV号为1Q7411e74B视频属性的抓取
# BV号为1Q7411e74B的视频属性抓取结束
# 开始BV号为1NJ411J7Yd视频属性的抓取
# BV号为1NJ411J7Yd的视频属性抓取结束
# 开始BV号为1UJ411H7j4视频属性的抓取
# BV号为1UJ411H7j4的视频属性抓取结束
# 开始BV号为1R7411v796视频属性的抓取
# BV号为1R7411v796的视频属性抓取结束
# 开始BV号为1SJ411n7EG视频属性的抓取
# BV号为1SJ411n7EG的视频属性抓取结束
# 开始BV号为1XJ411E7m8视频属性的抓取
# BV号为1XJ411E7m8的视频属性抓取结束
# 开始BV号为1NJ411E7sR视频属性的抓取
# BV号为1NJ411E7sR的视频属性抓取结束
# 开始BV号为1y7411J7bx视频属性的抓取
# BV号为1y7411J7bx的视频属性抓取结束
# 开始BV号为187411H72t视频属性的抓取
# BV号为187411H72t的视频属性抓取结束
# 开始BV号为1G7411c7cH视频属性的抓取
# BV号为1G7411c7cH的视频属性抓取结束
# 开始BV号为1k7411G7fn视频属性的抓取
# BV号为1k7411G7fn的视频属性抓取结束
# 开始BV号为157411w7Ao视频属性的抓取
# BV号为157411w7Ao的视频属性抓取结束
# 开始BV号为1n7411a7wA视频属性的抓取
# BV号为1n7411a7wA的视频属性抓取结束
# 开始BV号为1s7411W7hr视频属性的抓取
# BV号为1s7411W7hr的视频属性抓取结束
# 开始BV号为1h741177RX视频属性的抓取
# BV号为1h741177RX的视频属性抓取结束
# 开始BV号为1e7411K7yG视频属性的抓取
# BV号为1e7411K7yG的视频属性抓取结束
# 开始BV号为1v741147uU视频属性的抓取
# BV号为1v741147uU的视频属性抓取结束
# 开始BV号为1PE411H7hC视频属性的抓取
# BV号为1PE411H7hC的视频属性抓取结束
# 开始BV号为137411c7ZQ视频属性的抓取
# BV号为137411c7ZQ的视频属性抓取结束
# 开始BV号为1p7411T7Ft视频属性的抓取
# BV号为1p7411T7Ft的视频属性抓取结束
# 开始BV号为1z7411K7rx视频属性的抓取
# BV号为1z7411K7rx的视频属性抓取结束
# 开始BV号为1e7411T7tu视频属性的抓取
# BV号为1e7411T7tu的视频属性抓取结束
# 开始BV号为1g7411E7iH视频属性的抓取
# BV号为1g7411E7iH的视频属性抓取结束
# 开始BV号为11741137FY视频属性的抓取
# BV号为11741137FY的视频属性抓取结束
# 开始BV号为1g7411j7yo视频属性的抓取
# BV号为1g7411j7yo的视频属性抓取结束
# 开始BV号为1g7411c74K视频属性的抓取
# BV号为1g7411c74K的视频属性抓取结束
# 开始BV号为1n741157zJ视频属性的抓取
# BV号为1n741157zJ的视频属性抓取结束
# 开始BV号为1d7411K7dK视频属性的抓取
# BV号为1d7411K7dK的视频属性抓取结束
# 开始BV号为1H7411s7vf视频属性的抓取
# BV号为1H7411s7vf的视频属性抓取结束
# 开始BV号为187411M7Zy视频属性的抓取
# BV号为187411M7Zy的视频属性抓取结束
# 开始BV号为1p7411u7PL视频属性的抓取
# BV号为1p7411u7PL的视频属性抓取结束
# 开始BV号为1Q741137LS视频属性的抓取
# BV号为1Q741137LS的视频属性抓取结束
# 开始BV号为1R7411q7LU视频属性的抓取
# BV号为1R7411q7LU的视频属性抓取结束
# 开始BV号为1y741177Lk视频属性的抓取
# BV号为1y741177Lk的视频属性抓取结束
# 开始BV号为1Q7411p73c视频属性的抓取
# BV号为1Q7411p73c的视频属性抓取结束
# 开始BV号为1gE411H7PC视频属性的抓取
# 开始BV号为1gE411H7PC视频属性的抓取
# BV号为1gE411H7PC的视频属性抓取结束
# 开始BV号为1z7411E7S2视频属性的抓取
# BV号为1z7411E7S2的视频属性抓取结束
# 开始BV号为1tj411f7Vc视频属性的抓取
# BV号为1tj411f7Vc的视频属性抓取结束
# 开始BV号为197411s7fm视频属性的抓取
# BV号为197411s7fm的视频属性抓取结束
# 开始BV号为1T741177oe视频属性的抓取
# BV号为1T741177oe的视频属性抓取结束
# 开始BV号为1D7411K7KJ视频属性的抓取
# BV号为1D7411K7KJ的视频属性抓取结束
# 开始BV号为147411w7n7视频属性的抓取
# BV号为147411w7n7的视频属性抓取结束
# 开始BV号为1V7411w7et视频属性的抓取
# BV号为1V7411w7et的视频属性抓取结束
# 开始BV号为1G7411N7aU视频属性的抓取
# BV号为1G7411N7aU的视频属性抓取结束
# 开始BV号为1S741137Lx视频属性的抓取
# BV号为1S741137Lx的视频属性抓取结束
# 开始BV号为1Z7411H7BZ视频属性的抓取
# BV号为1Z7411H7BZ的视频属性抓取结束
# 开始BV号为1h7411p7Hd视频属性的抓取
# 开始BV号为1h7411p7Hd视频属性的抓取
# 开始BV号为1h7411p7Hd视频属性的抓取
# BV号为1h7411p7Hd的视频属性抓取结束
# 开始BV号为1gE411H7Hm视频属性的抓取
# BV号为1gE411H7Hm的视频属性抓取结束
# 开始BV号为1x7411t7km视频属性的抓取
# BV号为1x7411t7km的视频属性抓取结束
# 开始BV号为1Y7411T7Kw视频属性的抓取
# BV号为1Y7411T7Kw的视频属性抓取结束
# <ipython-input-9-1cc189b78ccd>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1C7411M7Y9视频属性的抓取
# BV号为1C7411M7Y9的视频属性抓取结束
# 开始BV号为1R7411x71n视频属性的抓取
# BV号为1R7411x71n的视频属性抓取结束
# 开始BV号为1J741187ah视频属性的抓取
# BV号为1J741187ah的视频属性抓取结束
# 开始BV号为1F7411h76x视频属性的抓取
# BV号为1F7411h76x的视频属性抓取结束
# 开始BV号为1S741157a4视频属性的抓取
# BV号为1S741157a4的视频属性抓取结束
# 开始BV号为117411F7db视频属性的抓取
# BV号为117411F7db的视频属性抓取结束
# 开始BV号为1E7411T7cx视频属性的抓取
# BV号为1E7411T7cx的视频属性抓取结束
# 开始BV号为1k7411M7sv视频属性的抓取
# BV号为1k7411M7sv的视频属性抓取结束
# 开始BV号为1Q7411V7yN视频属性的抓取
# BV号为1Q7411V7yN的视频属性抓取结束
# 开始BV号为1R7411M7Dd视频属性的抓取
# 开始BV号为1R7411M7Dd视频属性的抓取
# BV号为1R7411M7Dd的视频属性抓取结束
# 开始BV号为1c7411W7nM视频属性的抓取
# BV号为1c7411W7nM的视频属性抓取结束
# 开始BV号为1e741157bZ视频属性的抓取
# BV号为1e741157bZ的视频属性抓取结束
# 开始BV号为1K7411W7iG视频属性的抓取
# BV号为1K7411W7iG的视频属性抓取结束
# 开始BV号为1H7411E7eM视频属性的抓取
# BV号为1H7411E7eM的视频属性抓取结束
# 开始BV号为1W7411p7Ri视频属性的抓取
# BV号为1W7411p7Ri的视频属性抓取结束
# 开始BV号为1t741147Re视频属性的抓取
# BV号为1t741147Re的视频属性抓取结束
# 开始BV号为1Y7411P7kB视频属性的抓取
# BV号为1Y7411P7kB的视频属性抓取结束
# 开始BV号为1L7411N7A9视频属性的抓取
# BV号为1L7411N7A9的视频属性抓取结束
# 开始BV号为1q7411T773视频属性的抓取
# BV号为1q7411T773的视频属性抓取结束
# 开始BV号为1C741137N1视频属性的抓取
# BV号为1C741137N1的视频属性抓取结束
# 开始BV号为1s7411H7cv视频属性的抓取
# BV号为1s7411H7cv的视频属性抓取结束
# 开始BV号为1V7411E7xP视频属性的抓取
# BV号为1V7411E7xP的视频属性抓取结束
# 开始BV号为1C7411c7Co视频属性的抓取
# BV号为1C7411c7Co的视频属性抓取结束
# 开始BV号为1R7411H7xe视频属性的抓取
# BV号为1R7411H7xe的视频属性抓取结束
# 开始BV号为1G7411h7TK视频属性的抓取
# BV号为1G7411h7TK的视频属性抓取结束
# 开始BV号为18741177N3视频属性的抓取
# BV号为18741177N3的视频属性抓取结束
# 开始BV号为1uE411J7tR视频属性的抓取
# BV号为1uE411J7tR的视频属性抓取结束
# 开始BV号为1v7411K7Ka视频属性的抓取
# BV号为1v7411K7Ka的视频属性抓取结束
# 开始BV号为1V7411x71Y视频属性的抓取
# BV号为1V7411x71Y的视频属性抓取结束
# 开始BV号为1n7411F7t6视频属性的抓取
# BV号为1n7411F7t6的视频属性抓取结束
# 开始BV号为1H741137m4视频属性的抓取
# BV号为1H741137m4的视频属性抓取结束
# 开始BV号为1M7411x7m4视频属性的抓取
# BV号为1M7411x7m4的视频属性抓取结束
# 开始BV号为1uE411J7xS视频属性的抓取
# BV号为1uE411J7xS的视频属性抓取结束
# 开始BV号为187411h7qE视频属性的抓取
# BV号为187411h7qE的视频属性抓取结束
# 开始BV号为1C7411p7Fc视频属性的抓取
# BV号为1C7411p7Fc的视频属性抓取结束
# 开始BV号为1f7411W7L9视频属性的抓取
# BV号为1f7411W7L9的视频属性抓取结束
# 开始BV号为1s7411u7pk视频属性的抓取
# BV号为1s7411u7pk的视频属性抓取结束
# 开始BV号为1k7411E7jn视频属性的抓取
# BV号为1k7411E7jn的视频属性抓取结束
# 开始BV号为1x7411g77o视频属性的抓取
# BV号为1x7411g77o的视频属性抓取结束
# 开始BV号为1D7411L7VM视频属性的抓取
# BV号为1D7411L7VM的视频属性抓取结束
# 开始BV号为1J7411g73b视频属性的抓取
# BV号为1J7411g73b的视频属性抓取结束
# 开始BV号为1s7411K7tF视频属性的抓取
# BV号为1s7411K7tF的视频属性抓取结束
# 开始BV号为1Z7411V7zk视频属性的抓取
# BV号为1Z7411V7zk的视频属性抓取结束
# 开始BV号为1f741177H9视频属性的抓取
# BV号为1f741177H9的视频属性抓取结束
# 开始BV号为1f7411u7mN视频属性的抓取
# BV号为1f7411u7mN的视频属性抓取结束
# 开始BV号为187411M7Kp视频属性的抓取
# BV号为187411M7Kp的视频属性抓取结束
# 开始BV号为1X7411t7JX视频属性的抓取
# BV号为1X7411t7JX的视频属性抓取结束
# 开始BV号为157411g7iw视频属性的抓取
# BV号为157411g7iw的视频属性抓取结束
# 开始BV号为1p7411g7Hi视频属性的抓取
# BV号为1p7411g7Hi的视频属性抓取结束
# 开始BV号为1r741187Cq视频属性的抓取
# BV号为1r741187Cq的视频属性抓取结束
# 开始BV号为1j7411P7Po视频属性的抓取
# BV号为1j7411P7Po的视频属性抓取结束
# 开始BV号为1J741177K4视频属性的抓取
# BV号为1J741177K4的视频属性抓取结束
# 开始BV号为1yj411f7xs视频属性的抓取
# BV号为1yj411f7xs的视频属性抓取结束
# 开始BV号为1p7411h7Br视频属性的抓取
# BV号为1p7411h7Br的视频属性抓取结束
# 开始BV号为1F7411p73n视频属性的抓取
# BV号为1F7411p73n的视频属性抓取结束
# 开始BV号为1R7411K7Jk视频属性的抓取
# BV号为1R7411K7Jk的视频属性抓取结束
# 开始BV号为1DE411u7xJ视频属性的抓取
# BV号为1DE411u7xJ的视频属性抓取结束
# 开始BV号为1zE411j7kj视频属性的抓取
# BV号为1zE411j7kj的视频属性抓取结束
# 开始BV号为1o7411y73g视频属性的抓取
# BV号为1o7411y73g的视频属性抓取结束
# 开始BV号为1fE411g7P6视频属性的抓取
# BV号为1fE411g7P6的视频属性抓取结束
# 开始BV号为1oE411w7ni视频属性的抓取
# BV号为1oE411w7ni的视频属性抓取结束
# 开始BV号为1AE411u7WR视频属性的抓取
# BV号为1AE411u7WR的视频属性抓取结束
# 开始BV号为12E411L7Yr视频属性的抓取
# BV号为12E411L7Yr的视频属性抓取结束
# 开始BV号为18E41137ZS视频属性的抓取
# BV号为18E41137ZS的视频属性抓取结束
# 开始BV号为1eE411M7tU视频属性的抓取
# BV号为1eE411M7tU的视频属性抓取结束
# 开始BV号为1gE411u7jY视频属性的抓取
# BV号为1gE411u7jY的视频属性抓取结束
# 开始BV号为1YE411u7iw视频属性的抓取
# BV号为1YE411u7iw的视频属性抓取结束
# 开始BV号为157411S7TG视频属性的抓取
# BV号为157411S7TG的视频属性抓取结束
# 开始BV号为11741117Fk视频属性的抓取
# BV号为11741117Fk的视频属性抓取结束
# 开始BV号为1M7411m77X视频属性的抓取
# BV号为1M7411m77X的视频属性抓取结束
# 开始BV号为13E411P7Km视频属性的抓取
# BV号为13E411P7Km的视频属性抓取结束
# 开始BV号为18E411M7Zh视频属性的抓取
# BV号为18E411M7Zh的视频属性抓取结束
# 开始BV号为1DE411P7tS视频属性的抓取
# BV号为1DE411P7tS的视频属性抓取结束
# 开始BV号为1Y7411D7rZ视频属性的抓取
# BV号为1Y7411D7rZ的视频属性抓取结束
# 开始BV号为1a7411f7qM视频属性的抓取
# BV号为1a7411f7qM的视频属性抓取结束
# 开始BV号为1oE41137CD视频属性的抓取
# BV号为1oE41137CD的视频属性抓取结束
# 开始BV号为1DE411u7EW视频属性的抓取
# BV号为1DE411u7EW的视频属性抓取结束
# 开始BV号为1eE411j7Vn视频属性的抓取
# BV号为1eE411j7Vn的视频属性抓取结束
# 开始BV号为1Zg4y1b7mh视频属性的抓取
# BV号为1Zg4y1b7mh的视频属性抓取结束
# 开始BV号为1cE411J7f1视频属性的抓取
# BV号为1cE411J7f1的视频属性抓取结束
# 开始BV号为1wE411p7jp视频属性的抓取
# BV号为1wE411p7jp的视频属性抓取结束
# 开始BV号为1x7411C7PH视频属性的抓取
# BV号为1x7411C7PH的视频属性抓取结束
# 开始BV号为1iE41157jj视频属性的抓取
# BV号为1iE41157jj的视频属性抓取结束
# 开始BV号为1GE41157f8视频属性的抓取
# 开始BV号为1GE41157f8视频属性的抓取
# 开始BV号为1GE41157f8视频属性的抓取
# BV号为1GE41157f8的视频属性抓取结束
# 开始BV号为1RE411s7hw视频属性的抓取
# BV号为1RE411s7hw的视频属性抓取结束
# 开始BV号为1A7411y7AP视频属性的抓取
# BV号为1A7411y7AP的视频属性抓取结束
# 开始BV号为1RE411H7Jn视频属性的抓取
# BV号为1RE411H7Jn的视频属性抓取结束
# 开始BV号为1h7411S79t视频属性的抓取
# BV号为1h7411S79t的视频属性抓取结束
# 开始BV号为1v741127rh视频属性的抓取
# 开始BV号为1v741127rh视频属性的抓取
# BV号为1v741127rh的视频属性抓取结束
# 开始BV号为1AE411E7k9视频属性的抓取
# 开始BV号为1AE411E7k9视频属性的抓取
# BV号为1AE411E7k9的视频属性抓取结束
# 开始BV号为17E411V7HC视频属性的抓取
# BV号为17E411V7HC的视频属性抓取结束
# 开始BV号为1tK411772o视频属性的抓取
# 开始BV号为1tK411772o视频属性的抓取
# BV号为1tK411772o的视频属性抓取结束
# 开始BV号为1oE411T7ps视频属性的抓取
# BV号为1oE411T7ps的视频属性抓取结束
# 开始BV号为1R7411R7bi视频属性的抓取
# BV号为1R7411R7bi的视频属性抓取结束
# 开始BV号为1P7411U7NQ视频属性的抓取
# BV号为1P7411U7NQ的视频属性抓取结束
# 开始BV号为1GE411A73M视频属性的抓取
# BV号为1GE411A73M的视频属性抓取结束
# 开始BV号为1qE411P7fV视频属性的抓取
# BV号为1qE411P7fV的视频属性抓取结束
# 开始BV号为1X7411o7tw视频属性的抓取
# BV号为1X7411o7tw的视频属性抓取结束
# 开始BV号为1yE411j7sM视频属性的抓取
# BV号为1yE411j7sM的视频属性抓取结束
# 开始BV号为1m7411Z7P7视频属性的抓取
# BV号为1m7411Z7P7的视频属性抓取结束
# 开始BV号为1M7411Z747视频属性的抓取
# BV号为1M7411Z747的视频属性抓取结束
# 开始BV号为1yC4y147NW视频属性的抓取
# BV号为1yC4y147NW的视频属性抓取结束
# 开始BV号为1nE411A7ys视频属性的抓取
# BV号为1nE411A7ys的视频属性抓取结束
# 开始BV号为1YE411F7ch视频属性的抓取
# BV号为1YE411F7ch的视频属性抓取结束
# 开始BV号为1U7411f7fn视频属性的抓取
# BV号为1U7411f7fn的视频属性抓取结束
# 开始BV号为1XE411j78P视频属性的抓取
# BV号为1XE411j78P的视频属性抓取结束
# 开始BV号为1yE411F7Jr视频属性的抓取
# BV号为1yE411F7Jr的视频属性抓取结束
# 开始BV号为17E411K7TC视频属性的抓取
# BV号为17E411K7TC的视频属性抓取结束
# 开始BV号为1PE411E7n3视频属性的抓取
# BV号为1PE411E7n3的视频属性抓取结束
# 开始BV号为11E411P7zr视频属性的抓取
# BV号为11E411P7zr的视频属性抓取结束
# 开始BV号为1aE411u7j6视频属性的抓取
# BV号为1aE411u7j6的视频属性抓取结束
# 开始BV号为1G7411R7px视频属性的抓取
# BV号为1G7411R7px的视频属性抓取结束
# 开始BV号为1JE411x7yd视频属性的抓取
# BV号为1JE411x7yd的视频属性抓取结束
# 开始BV号为1YE41137cg视频属性的抓取
# BV号为1YE41137cg的视频属性抓取结束
# 开始BV号为1JE411E7LJ视频属性的抓取
# BV号为1JE411E7LJ的视频属性抓取结束
# 开始BV号为1S7411d7nJ视频属性的抓取
# BV号为1S7411d7nJ的视频属性抓取结束
# 开始BV号为1TE411p7xA视频属性的抓取
# BV号为1TE411p7xA的视频属性抓取结束
# 开始BV号为1gE411j7eG视频属性的抓取
# BV号为1gE411j7eG的视频属性抓取结束
# 开始BV号为19E411M7Ti视频属性的抓取
# BV号为19E411M7Ti的视频属性抓取结束
# 开始BV号为1p7411y7Zv视频属性的抓取
# BV号为1p7411y7Zv的视频属性抓取结束
# 开始BV号为1mE411j7cc视频属性的抓取
# BV号为1mE411j7cc的视频属性抓取结束
# 开始BV号为1nE411V7TY视频属性的抓取
# BV号为1nE411V7TY的视频属性抓取结束
# 开始BV号为1GQ4y1M7ox视频属性的抓取
# BV号为1GQ4y1M7ox的视频属性抓取结束
# 开始BV号为1LE411j7EQ视频属性的抓取
# BV号为1LE411j7EQ的视频属性抓取结束
# 开始BV号为1qE411p7aj视频属性的抓取
# BV号为1qE411p7aj的视频属性抓取结束
# 开始BV号为1o7411o7Tb视频属性的抓取
# BV号为1o7411o7Tb的视频属性抓取结束
# 开始BV号为18E411g7g9视频属性的抓取
# BV号为18E411g7g9的视频属性抓取结束
# 开始BV号为1DE41137HT视频属性的抓取
# BV号为1DE41137HT的视频属性抓取结束
# 开始BV号为1GE41177QN视频属性的抓取
# BV号为1GE41177QN的视频属性抓取结束
# 开始BV号为1zE41157fe视频属性的抓取
# BV号为1zE41157fe的视频属性抓取结束
# 开始BV号为1qE411p74u视频属性的抓取
# BV号为1qE411p74u的视频属性抓取结束
# 开始BV号为1wE411u7xV视频属性的抓取
# BV号为1wE411u7xV的视频属性抓取结束
# 开始BV号为1iE411E7KK视频属性的抓取
# BV号为1iE411E7KK的视频属性抓取结束
# 开始BV号为1HE411g7Nd视频属性的抓取
# BV号为1HE411g7Nd的视频属性抓取结束
# 开始BV号为1fE411V7kW视频属性的抓取
# BV号为1fE411V7kW的视频属性抓取结束
# 开始BV号为1h7411C7bo视频属性的抓取
# BV号为1h7411C7bo的视频属性抓取结束
# 开始BV号为1k7411y7q9视频属性的抓取
# BV号为1k7411y7q9的视频属性抓取结束
# 开始BV号为1Bp4y117WV视频属性的抓取
# BV号为1Bp4y117WV的视频属性抓取结束
# 开始BV号为1LE411p7mQ视频属性的抓取
# BV号为1LE411p7mQ的视频属性抓取结束
# 开始BV号为1GE411p72z视频属性的抓取
# BV号为1GE411p72z的视频属性抓取结束
# 开始BV号为18E411N7iz视频属性的抓取
# BV号为18E411N7iz的视频属性抓取结束
# 开始BV号为1SE411A7xw视频属性的抓取
# BV号为1SE411A7xw的视频属性抓取结束
# 开始BV号为14E411W75e视频属性的抓取
# BV号为14E411W75e的视频属性抓取结束
# 开始BV号为1aE411g7g5视频属性的抓取
# BV号为1aE411g7g5的视频属性抓取结束
# 开始BV号为1sE411F757视频属性的抓取
# BV号为1sE411F757的视频属性抓取结束
# 开始BV号为1UE411W7W7视频属性的抓取
# BV号为1UE411W7W7的视频属性抓取结束
# 开始BV号为1pE411N7Cp视频属性的抓取
# BV号为1pE411N7Cp的视频属性抓取结束
# 开始BV号为1LE411u7t5视频属性的抓取
# BV号为1LE411u7t5的视频属性抓取结束
# 开始BV号为1bC4y147Vq视频属性的抓取
# BV号为1bC4y147Vq的视频属性抓取结束
# 开始BV号为1fE411L7ra视频属性的抓取
# BV号为1fE411L7ra的视频属性抓取结束
# 开始BV号为15E411w7UD视频属性的抓取
# BV号为15E411w7UD的视频属性抓取结束
# 开始BV号为1g7411U7Jo视频属性的抓取
# BV号为1g7411U7Jo的视频属性抓取结束
# 开始BV号为1xe411x74q视频属性的抓取
# BV号为1xe411x74q的视频属性抓取结束
# 开始BV号为1H7411Q7qf视频属性的抓取
# BV号为1H7411Q7qf的视频属性抓取结束
# 开始BV号为1sE411N7eh视频属性的抓取
# BV号为1sE411N7eh的视频属性抓取结束
# 开始BV号为1tE41147Wg视频属性的抓取
# BV号为1tE41147Wg的视频属性抓取结束
# 开始BV号为1oV411o7w7视频属性的抓取
# BV号为1oV411o7w7的视频属性抓取结束
# 开始BV号为1ni4y1t7M7视频属性的抓取
# BV号为1ni4y1t7M7的视频属性抓取结束
# 开始BV号为1me411W7J5视频属性的抓取
# BV号为1me411W7J5的视频属性抓取结束
# 开始BV号为1Qa4y1x7Da视频属性的抓取
# BV号为1Qa4y1x7Da的视频属性抓取结束
# 开始BV号为1ZK4y1r7ya视频属性的抓取
# BV号为1ZK4y1r7ya的视频属性抓取结束
# 开始BV号为1oQ4y1K7Fj视频属性的抓取
# BV号为1oQ4y1K7Fj的视频属性抓取结束
# 开始BV号为1di4y1b7sj视频属性的抓取
# BV号为1di4y1b7sj的视频属性抓取结束
# 开始BV号为1iC4y1s7Ly视频属性的抓取
# BV号为1iC4y1s7Ly的视频属性抓取结束
# 开始BV号为1rZ4y1x7BX视频属性的抓取
# BV号为1rZ4y1x7BX的视频属性抓取结束
# 开始BV号为1Uf4y1U7q7视频属性的抓取
# BV号为1Uf4y1U7q7的视频属性抓取结束
# 开始BV号为1F541147GK视频属性的抓取
# BV号为1F541147GK的视频属性抓取结束
# 开始BV号为1nV411o7dr视频属性的抓取
# BV号为1nV411o7dr的视频属性抓取结束
# 开始BV号为1Vp4y1C7d2视频属性的抓取
# 开始BV号为1Vp4y1C7d2视频属性的抓取
# BV号为1Vp4y1C7d2的视频属性抓取结束
# 开始BV号为13g4y1z7hN视频属性的抓取
# BV号为13g4y1z7hN的视频属性抓取结束
# 开始BV号为1s54y1978X视频属性的抓取
# BV号为1s54y1978X的视频属性抓取结束
# 开始BV号为1kg4y1z7ED视频属性的抓取
# BV号为1kg4y1z7ED的视频属性抓取结束
# 开始BV号为1RA411t7ho视频属性的抓取
# 开始BV号为1RA411t7ho视频属性的抓取
# BV号为1RA411t7ho的视频属性抓取结束
# 开始BV号为1Af4y1S7vF视频属性的抓取
# BV号为1Af4y1S7vF的视频属性抓取结束
# 开始BV号为1hK41157pz视频属性的抓取
# BV号为1hK41157pz的视频属性抓取结束
# 开始BV号为1nQ4y1K7th视频属性的抓取
# BV号为1nQ4y1K7th的视频属性抓取结束
# 开始BV号为1Qk4y1d7NY视频属性的抓取
# BV号为1Qk4y1d7NY的视频属性抓取结束
# 开始BV号为1BQ4y1M7ut视频属性的抓取
# BV号为1BQ4y1M7ut的视频属性抓取结束
# 开始BV号为1rz411B732视频属性的抓取
# BV号为1rz411B732的视频属性抓取结束
# 开始BV号为1ok4y197wj视频属性的抓取
# BV号为1ok4y197wj的视频属性抓取结束
# 开始BV号为1wV411Z7Sa视频属性的抓取
# BV号为1wV411Z7Sa的视频属性抓取结束
# 开始BV号为1tV411o7Kr视频属性的抓取
# BV号为1tV411o7Kr的视频属性抓取结束
# 开始BV号为1At4y1U7WP视频属性的抓取
# BV号为1At4y1U7WP的视频属性抓取结束
# 开始BV号为1Gg4y1a7Q3视频属性的抓取
# BV号为1Gg4y1a7Q3的视频属性抓取结束
# 开始BV号为1oA411t757视频属性的抓取
# BV号为1oA411t757的视频属性抓取结束
# 开始BV号为1sV411f7S5视频属性的抓取
# BV号为1sV411f7S5的视频属性抓取结束
# 开始BV号为1X54y1Q73T视频属性的抓取
# BV号为1X54y1Q73T的视频属性抓取结束
# 开始BV号为1Sp4y1C7jF视频属性的抓取
# BV号为1Sp4y1C7jF的视频属性抓取结束
# 开始BV号为1Ck4y1R7Ra视频属性的抓取
# BV号为1Ck4y1R7Ra的视频属性抓取结束
# 开始BV号为1zi4y1t7ze视频属性的抓取
# BV号为1zi4y1t7ze的视频属性抓取结束
# 开始BV号为1w541147Dv视频属性的抓取
# BV号为1w541147Dv的视频属性抓取结束
# 开始BV号为1xa4y1t7wh视频属性的抓取
# BV号为1xa4y1t7wh的视频属性抓取结束
# 开始BV号为1Ai4y1t77q视频属性的抓取
# BV号为1Ai4y1t77q的视频属性抓取结束
# 开始BV号为16K4y1r7xt视频属性的抓取
# BV号为16K4y1r7xt的视频属性抓取结束
# 开始BV号为1GV411Z7br视频属性的抓取
# BV号为1GV411Z7br的视频属性抓取结束
# 开始BV号为1u64y1u7iW视频属性的抓取
# BV号为1u64y1u7iW的视频属性抓取结束
# 开始BV号为1G5411t7Rb视频属性的抓取
# BV号为1G5411t7Rb的视频属性抓取结束
# 开始BV号为1Vf4y1m7Qo视频属性的抓取
# BV号为1Vf4y1m7Qo的视频属性抓取结束
# 开始BV号为1hi4y1t7Na视频属性的抓取
# BV号为1hi4y1t7Na的视频属性抓取结束
# 开始BV号为1h54y197BW视频属性的抓取
# BV号为1h54y197BW的视频属性抓取结束
# 开始BV号为1eQ4y1K7QZ视频属性的抓取
# BV号为1eQ4y1K7QZ的视频属性抓取结束
# 开始BV号为1Ha4y1t7Ht视频属性的抓取
# BV号为1Ha4y1t7Ht的视频属性抓取结束
# 开始BV号为1TC4y1W7bs视频属性的抓取
# BV号为1TC4y1W7bs的视频属性抓取结束
# 开始BV号为1sg4y187it视频属性的抓取
# BV号为1sg4y187it的视频属性抓取结束
# 开始BV号为19K411V7SE视频属性的抓取
# BV号为19K411V7SE的视频属性抓取结束
# 开始BV号为1uQ4y1K7t5视频属性的抓取
# BV号为1uQ4y1K7t5的视频属性抓取结束
# 开始BV号为1tK411L7zB视频属性的抓取
# BV号为1tK411L7zB的视频属性抓取结束
# 开始BV号为1Ki4y1875X视频属性的抓取
# BV号为1Ki4y1875X的视频属性抓取结束
# 开始BV号为1354y197My视频属性的抓取
# BV号为1354y197My的视频属性抓取结束
# 开始BV号为1KC4y1x7QL视频属性的抓取
# BV号为1KC4y1x7QL的视频属性抓取结束
# 开始BV号为1S5411478X视频属性的抓取
# BV号为1S5411478X的视频属性抓取结束
# 开始BV号为1YK41157vp视频属性的抓取
# BV号为1YK41157vp的视频属性抓取结束
# 开始BV号为1gQ4y1M7Af视频属性的抓取
# BV号为1gQ4y1M7Af的视频属性抓取结束
# 开始BV号为1iT4y1g7z9视频属性的抓取
# BV号为1iT4y1g7z9的视频属性抓取结束
# 开始BV号为1vV411o7HT视频属性的抓取
# BV号为1vV411o7HT的视频属性抓取结束
# 开始BV号为1fT4y1G7Yr视频属性的抓取
# BV号为1fT4y1G7Yr的视频属性抓取结束
# 开始BV号为1Yg4y1z7kU视频属性的抓取
# BV号为1Yg4y1z7kU的视频属性抓取结束
# 开始BV号为1JA411h7xo视频属性的抓取
# BV号为1JA411h7xo的视频属性抓取结束
# 开始BV号为1ba4y1x75T视频属性的抓取
# BV号为1ba4y1x75T的视频属性抓取结束
# 开始BV号为1xV411o79k视频属性的抓取
# BV号为1xV411o79k的视频属性抓取结束
# 开始BV号为1LT4y1G7St视频属性的抓取
# BV号为1LT4y1G7St的视频属性抓取结束
# 开始BV号为1d5411t7bS视频属性的抓取
# BV号为1d5411t7bS的视频属性抓取结束
# 开始BV号为1at4y1m7AX视频属性的抓取
# BV号为1at4y1m7AX的视频属性抓取结束
# 开始BV号为1Ap4y197Mg视频属性的抓取
# BV号为1Ap4y197Mg的视频属性抓取结束
# 开始BV号为1mK411L7hu视频属性的抓取
# BV号为1mK411L7hu的视频属性抓取结束
# 开始BV号为1rk4y1R7ee视频属性的抓取
# BV号为1rk4y1R7ee的视频属性抓取结束
# 开始BV号为1jt4y127zy视频属性的抓取
# BV号为1jt4y127zy的视频属性抓取结束
# 开始BV号为1xz411B7rh视频属性的抓取
# BV号为1xz411B7rh的视频属性抓取结束
# 开始BV号为1JK41157c2视频属性的抓取
# BV号为1JK41157c2的视频属性抓取结束
# 开始BV号为1zQ4y1K73H视频属性的抓取
# BV号为1zQ4y1K73H的视频属性抓取结束
# 开始BV号为1nC4y1W7yF视频属性的抓取
# BV号为1nC4y1W7yF的视频属性抓取结束
# 开始BV号为14A411h7DU视频属性的抓取
# BV号为14A411h7DU的视频属性抓取结束
# 开始BV号为1zZ4y1W7Di视频属性的抓取
# BV号为1zZ4y1W7Di的视频属性抓取结束
# 开始BV号为1Yk4y1r7jM视频属性的抓取
# BV号为1Yk4y1r7jM的视频属性抓取结束
# 开始BV号为1bT4y157Qy视频属性的抓取
# BV号为1bT4y157Qy的视频属性抓取结束
# 开始BV号为1Xk4y1r7fp视频属性的抓取
# BV号为1Xk4y1r7fp的视频属性抓取结束
# 开始BV号为1R5411t7VF视频属性的抓取
# BV号为1R5411t7VF的视频属性抓取结束
# 开始BV号为1dT4y1g7C6视频属性的抓取
# BV号为1dT4y1g7C6的视频属性抓取结束
# 开始BV号为1mC4y1p7QT视频属性的抓取
# BV号为1mC4y1p7QT的视频属性抓取结束
# 开始BV号为1n5411t73c视频属性的抓取
# BV号为1n5411t73c的视频属性抓取结束
# 开始BV号为1uk4y1R7u9视频属性的抓取
# BV号为1uk4y1R7u9的视频属性抓取结束
# 开始BV号为1XZ4y1x7Ej视频属性的抓取
# BV号为1XZ4y1x7Ej的视频属性抓取结束
# 开始BV号为1ok4y197oy视频属性的抓取
# BV号为1ok4y197oy的视频属性抓取结束
# 开始BV号为1Ne411x7Fr视频属性的抓取
# BV号为1Ne411x7Fr的视频属性抓取结束
# 开始BV号为1fK411V73u视频属性的抓取
# BV号为1fK411V73u的视频属性抓取结束
# 开始BV号为1dZ4y1s7dA视频属性的抓取
# BV号为1dZ4y1s7dA的视频属性抓取结束
# 开始BV号为1vC4y147a6视频属性的抓取
# BV号为1vC4y147a6的视频属性抓取结束
# 开始BV号为1UQ4y1K7z9视频属性的抓取
# BV号为1UQ4y1K7z9的视频属性抓取结束
# 开始BV号为1Ak4y1k72g视频属性的抓取
# BV号为1Ak4y1k72g的视频属性抓取结束
# 开始BV号为1a54y197Xx视频属性的抓取
# BV号为1a54y197Xx的视频属性抓取结束
# 开始BV号为1jK411j7Ms视频属性的抓取
# BV号为1jK411j7Ms的视频属性抓取结束
# 开始BV号为1pe411479L视频属性的抓取
# BV号为1pe411479L的视频属性抓取结束
# 开始BV号为1XT4y1372g视频属性的抓取
# BV号为1XT4y1372g的视频属性抓取结束
# 开始BV号为1Ka4y147RF视频属性的抓取
# BV号为1Ka4y147RF的视频属性抓取结束
# 开始BV号为1Ki4y187bx视频属性的抓取
# BV号为1Ki4y187bx的视频属性抓取结束
# 开始BV号为1Ae41147NZ视频属性的抓取
# BV号为1Ae41147NZ的视频属性抓取结束
# 开始BV号为16a4y1e7r8视频属性的抓取
# BV号为16a4y1e7r8的视频属性抓取结束
# 开始BV号为1WK41157S6视频属性的抓取
# BV号为1WK41157S6的视频属性抓取结束
# 开始BV号为1iC4y1H7Us视频属性的抓取
# BV号为1iC4y1H7Us的视频属性抓取结束
# 开始BV号为1XA411b741视频属性的抓取
# BV号为1XA411b741的视频属性抓取结束
# 开始BV号为1ni4y1b7Dh视频属性的抓取
# BV号为1ni4y1b7Dh的视频属性抓取结束
# 开始BV号为1q54y1X7vV视频属性的抓取
# BV号为1q54y1X7vV的视频属性抓取结束
# 开始BV号为1654y1Q7Lq视频属性的抓取
# BV号为1654y1Q7Lq的视频属性抓取结束
# 开始BV号为13T4y1u7YX视频属性的抓取
# BV号为13T4y1u7YX的视频属性抓取结束
# 开始BV号为1Fi4y1477V视频属性的抓取
# BV号为1Fi4y1477V的视频属性抓取结束
# 开始BV号为1dt4y1y7ti视频属性的抓取
# BV号为1dt4y1y7ti的视频属性抓取结束
# 开始BV号为1pf4y127Sv视频属性的抓取
# BV号为1pf4y127Sv的视频属性抓取结束
# 开始BV号为1af4y1m7d8视频属性的抓取
# BV号为1af4y1m7d8的视频属性抓取结束
# 开始BV号为1eg4y1B7m6视频属性的抓取
# BV号为1eg4y1B7m6的视频属性抓取结束
# 开始BV号为13a4y1i7f4视频属性的抓取
# BV号为13a4y1i7f4的视频属性抓取结束
# 开始BV号为1zz411z7qE视频属性的抓取
# BV号为1zz411z7qE的视频属性抓取结束
# 开始BV号为1wf4y1U7dL视频属性的抓取
# BV号为1wf4y1U7dL的视频属性抓取结束
# 开始BV号为1Kz4y1d7JR视频属性的抓取
# BV号为1Kz4y1d7JR的视频属性抓取结束
# 开始BV号为1Mk4y1r7VC视频属性的抓取
# BV号为1Mk4y1r7VC的视频属性抓取结束
# 开始BV号为11K41157pt视频属性的抓取
# 开始BV号为11K41157pt视频属性的抓取
# BV号为11K41157pt的视频属性抓取结束
# 开始BV号为16Z4y1p7v3视频属性的抓取
# BV号为16Z4y1p7v3的视频属性抓取结束
# 开始BV号为1jV411C76A视频属性的抓取
# BV号为1jV411C76A的视频属性抓取结束
# 开始BV号为1P541147SP视频属性的抓取
# BV号为1P541147SP的视频属性抓取结束
# 开始BV号为1x54y1D7iX视频属性的抓取
# BV号为1x54y1D7iX的视频属性抓取结束
# 开始BV号为1Ze411p7VA视频属性的抓取
# BV号为1Ze411p7VA的视频属性抓取结束
# 开始BV号为1Xf4y1m791视频属性的抓取
# BV号为1Xf4y1m791的视频属性抓取结束
# 开始BV号为1E5411x7Jf视频属性的抓取
# BV号为1E5411x7Jf的视频属性抓取结束
# 开始BV号为1bg4y1B7eh视频属性的抓取
# BV号为1bg4y1B7eh的视频属性抓取结束
# 开始BV号为15Z4y1s7R2视频属性的抓取
# BV号为15Z4y1s7R2的视频属性抓取结束
# 开始BV号为1XC4y1h7RV视频属性的抓取
# BV号为1XC4y1h7RV的视频属性抓取结束
# 开始BV号为1aT4y1u7xr视频属性的抓取
# BV号为1aT4y1u7xr的视频属性抓取结束
# 开始BV号为1F5411s7Qh视频属性的抓取
# BV号为1F5411s7Qh的视频属性抓取结束
# 开始BV号为1Jz411B7JL视频属性的抓取
# BV号为1Jz411B7JL的视频属性抓取结束
# 开始BV号为1JQ4y1N7Qx视频属性的抓取
# BV号为1JQ4y1N7Qx的视频属性抓取结束
# 开始BV号为1PC4y1p79V视频属性的抓取
# BV号为1PC4y1p79V的视频属性抓取结束
# 开始BV号为17A411t7Yj视频属性的抓取
# BV号为17A411t7Yj的视频属性抓取结束
# 开始BV号为1Xf4y1m7we视频属性的抓取
# BV号为1Xf4y1m7we的视频属性抓取结束
# 开始BV号为1iZ4y1p7Q7视频属性的抓取
# BV号为1iZ4y1p7Q7的视频属性抓取结束
# 开始BV号为12V411k7z7视频属性的抓取
# BV号为12V411k7z7的视频属性抓取结束
# 开始BV号为1sp4y1X7w6视频属性的抓取
# BV号为1sp4y1X7w6的视频属性抓取结束
# 开始BV号为1sZ4y1p7oT视频属性的抓取
# BV号为1sZ4y1p7oT的视频属性抓取结束
# 开始BV号为1UK4y1b7tw视频属性的抓取
# BV号为1UK4y1b7tw的视频属性抓取结束
# 开始BV号为14Z4y1p7Ay视频属性的抓取
# 开始BV号为14Z4y1p7Ay视频属性的抓取
# BV号为14Z4y1p7Ay的视频属性抓取结束
# 开始BV号为1Ct4y1C75t视频属性的抓取
# BV号为1Ct4y1C75t的视频属性抓取结束
# 开始BV号为1Lk4y1r7en视频属性的抓取
# BV号为1Lk4y1r7en的视频属性抓取结束
# 开始BV号为1xt4y117Mi视频属性的抓取
# BV号为1xt4y117Mi的视频属性抓取结束
# 开始BV号为1cg4y1B7fq视频属性的抓取
# BV号为1cg4y1B7fq的视频属性抓取结束
# 开始BV号为1hZ4y1p7de视频属性的抓取
# BV号为1hZ4y1p7de的视频属性抓取结束
# 开始BV号为1Zg4y1B77M视频属性的抓取
# BV号为1Zg4y1B77M的视频属性抓取结束
# 开始BV号为1oz411q7z6视频属性的抓取
# BV号为1oz411q7z6的视频属性抓取结束
# 开始BV号为1ZK4y1b7Lv视频属性的抓取
# BV号为1ZK4y1b7Lv的视频属性抓取结束
# 开始BV号为1Di4y1x7yK视频属性的抓取
# BV号为1Di4y1x7yK的视频属性抓取结束
# 开始BV号为1pg4y1B7HD视频属性的抓取
# BV号为1pg4y1B7HD的视频属性抓取结束
# 开始BV号为1Gt4y1m7vi视频属性的抓取
# BV号为1Gt4y1m7vi的视频属性抓取结束
# 开始BV号为1tp4y1Q7zw视频属性的抓取
# BV号为1tp4y1Q7zw的视频属性抓取结束
# 开始BV号为1pT4y1u7MD视频属性的抓取
# BV号为1pT4y1u7MD的视频属性抓取结束
# 开始BV号为1jV411C7iL视频属性的抓取
# BV号为1jV411C7iL的视频属性抓取结束
# 开始BV号为1Qf4y117he视频属性的抓取
# BV号为1Qf4y117he的视频属性抓取结束
# 开始BV号为1AV411o71F视频属性的抓取
# BV号为1AV411o71F的视频属性抓取结束
# 开始BV号为1QK4y1t7ax视频属性的抓取
# BV号为1QK4y1t7ax的视频属性抓取结束
# 开始BV号为1Uf4y1m7Tb视频属性的抓取
# BV号为1Uf4y1m7Tb的视频属性抓取结束
# 开始BV号为1pt4y117XG视频属性的抓取
# BV号为1pt4y117XG的视频属性抓取结束
# 开始BV号为1AT4y1g7XQ视频属性的抓取
# BV号为1AT4y1g7XQ的视频属性抓取结束
# 开始BV号为1rT4y1u7mC视频属性的抓取
# BV号为1rT4y1u7mC的视频属性抓取结束
# 开始BV号为1jz411q7p2视频属性的抓取
# 开始BV号为1jz411q7p2视频属性的抓取
# BV号为1jz411q7p2的视频属性抓取结束
# 开始BV号为1fK4y1t7Js视频属性的抓取
# BV号为1fK4y1t7Js的视频属性抓取结束
# 开始BV号为1oA411i7vH视频属性的抓取
# BV号为1oA411i7vH的视频属性抓取结束
# 开始BV号为1sk4y1674t视频属性的抓取
# BV号为1sk4y1674t的视频属性抓取结束
# 开始BV号为1Ek4y1k7LY视频属性的抓取
# BV号为1Ek4y1k7LY的视频属性抓取结束
# 开始BV号为1Y5411s7Pa视频属性的抓取
# BV号为1Y5411s7Pa的视频属性抓取结束
# 开始BV号为1Xz411v7UC视频属性的抓取
# BV号为1Xz411v7UC的视频属性抓取结束
# 开始BV号为15a4y1v7Me视频属性的抓取
# BV号为15a4y1v7Me的视频属性抓取结束
# 开始BV号为1jT4y1g7vi视频属性的抓取
# BV号为1jT4y1g7vi的视频属性抓取结束
# 开始BV号为1G54y1Q7Ma视频属性的抓取
# BV号为1G54y1Q7Ma的视频属性抓取结束
# 开始BV号为1LC4y1p7dM视频属性的抓取
# BV号为1LC4y1p7dM的视频属性抓取结束
# 开始BV号为1qi4y147q6视频属性的抓取
# BV号为1qi4y147q6的视频属性抓取结束
# 开始BV号为1yK4y1b7Gq视频属性的抓取
# BV号为1yK4y1b7Gq的视频属性抓取结束
# 开始BV号为1Tk4y1672y视频属性的抓取
# BV号为1Tk4y1672y的视频属性抓取结束
# 开始BV号为1Ez4y197kB视频属性的抓取
# BV号为1Ez4y197kB的视频属性抓取结束
# 开始BV号为12Z4y1p7gS视频属性的抓取
# BV号为12Z4y1p7gS的视频属性抓取结束
# 开始BV号为1rK411W7AJ视频属性的抓取
# BV号为1rK411W7AJ的视频属性抓取结束
# 开始BV号为1sz4y1R7mX视频属性的抓取
# BV号为1sz4y1R7mX的视频属性抓取结束
# 开始BV号为1kt4y117LE视频属性的抓取
# BV号为1kt4y117LE的视频属性抓取结束
# 开始BV号为1UC4y1H7MD视频属性的抓取
# BV号为1UC4y1H7MD的视频属性抓取结束
# 开始BV号为1yk4y167tE视频属性的抓取
# BV号为1yk4y167tE的视频属性抓取结束
# 开始BV号为1jt4y117Nb视频属性的抓取
# BV号为1jt4y117Nb的视频属性抓取结束
# 开始BV号为11Z4y1s7xK视频属性的抓取
# BV号为11Z4y1s7xK的视频属性抓取结束
# 开始BV号为1Vi4y1b7qu视频属性的抓取
# BV号为1Vi4y1b7qu的视频属性抓取结束
# 开始BV号为1jz411q7XF视频属性的抓取
# BV号为1jz411q7XF的视频属性抓取结束
# 开始BV号为1cV411o7t9视频属性的抓取
# BV号为1cV411o7t9的视频属性抓取结束
# 开始BV号为1Lz411B7Sc视频属性的抓取
# BV号为1Lz411B7Sc的视频属性抓取结束
# 开始BV号为1Si4y1x7am视频属性的抓取
# BV号为1Si4y1x7am的视频属性抓取结束
# 开始BV号为1ag4y1B7VJ视频属性的抓取
# BV号为1ag4y1B7VJ的视频属性抓取结束
# 开始BV号为11t4y117JZ视频属性的抓取
# BV号为11t4y117JZ的视频属性抓取结束
# 开始BV号为1SA411t7xy视频属性的抓取
# BV号为1SA411t7xy的视频属性抓取结束
# 开始BV号为1jz4y197zM视频属性的抓取
# BV号为1jz4y197zM的视频属性抓取结束
# 开始BV号为1Rz411v7SL视频属性的抓取
# BV号为1Rz411v7SL的视频属性抓取结束
# 开始BV号为1Xf4y1m7Ht视频属性的抓取
# BV号为1Xf4y1m7Ht的视频属性抓取结束
# 开始BV号为18z4y1d7JU视频属性的抓取
# BV号为18z4y1d7JU的视频属性抓取结束
# 开始BV号为1XV411R7f1视频属性的抓取
# BV号为1XV411R7f1的视频属性抓取结束
# 开始BV号为1GK411s7kL视频属性的抓取
# BV号为1GK411s7kL的视频属性抓取结束
# 开始BV号为1VD4y1S7ho视频属性的抓取
# BV号为1VD4y1S7ho的视频属性抓取结束
# 开始BV号为1Xf4y127Ya视频属性的抓取
# BV号为1Xf4y127Ya的视频属性抓取结束
# 开始BV号为1kt4y1X7ta视频属性的抓取
# BV号为1kt4y1X7ta的视频属性抓取结束
# 开始BV号为1UZ4y1H7cu视频属性的抓取
# BV号为1UZ4y1H7cu的视频属性抓取结束
# 开始BV号为1qK411p7hW视频属性的抓取
# BV号为1qK411p7hW的视频属性抓取结束
# 开始BV号为1Wv411B7Eh视频属性的抓取
# BV号为1Wv411B7Eh的视频属性抓取结束
# 开始BV号为1hg4y1q7w4视频属性的抓取
# BV号为1hg4y1q7w4的视频属性抓取结束
# 开始BV号为1754y1Q7Pf视频属性的抓取
# BV号为1754y1Q7Pf的视频属性抓取结束
# 开始BV号为1H5411W7mQ视频属性的抓取
# BV号为1H5411W7mQ的视频属性抓取结束
# 开始BV号为1Mt4y1y7Xi视频属性的抓取
# BV号为1Mt4y1y7Xi的视频属性抓取结束
# 开始BV号为1Ut4y1X7vY视频属性的抓取
# BV号为1Ut4y1X7vY的视频属性抓取结束
# 开始BV号为1rv411B7j1视频属性的抓取
# BV号为1rv411B7j1的视频属性抓取结束
# 开始BV号为1Q54y1i7hq视频属性的抓取
# BV号为1Q54y1i7hq的视频属性抓取结束
# 开始BV号为1dK4y1x7Dv视频属性的抓取
# BV号为1dK4y1x7Dv的视频属性抓取结束
# 开始BV号为1n54y1z7Zz视频属性的抓取
# BV号为1n54y1z7Zz的视频属性抓取结束
# 开始BV号为1Ba4y1Y7nQ视频属性的抓取
# BV号为1Ba4y1Y7nQ的视频属性抓取结束
# 开始BV号为1DC4y187Lk视频属性的抓取
# BV号为1DC4y187Lk的视频属性抓取结束
# 开始BV号为1PK411H7gP视频属性的抓取
# BV号为1PK411H7gP的视频属性抓取结束
# 开始BV号为1af4y117Rj视频属性的抓取
# BV号为1af4y117Rj的视频属性抓取结束
# 开始BV号为1Ep4y1D7h4视频属性的抓取
# BV号为1Ep4y1D7h4的视频属性抓取结束
# 开始BV号为1nZ4y1H7g3视频属性的抓取
# BV号为1nZ4y1H7g3的视频属性抓取结束
# 开始BV号为1MZ4y1p7Er视频属性的抓取
# BV号为1MZ4y1p7Er的视频属性抓取结束
# 开始BV号为1U5411W7LN视频属性的抓取
# BV号为1U5411W7LN的视频属性抓取结束
# 开始BV号为1YK4y147kR视频属性的抓取
# BV号为1YK4y147kR的视频属性抓取结束
# 开始BV号为1GZ4y1H7Q1视频属性的抓取
# BV号为1GZ4y1H7Q1的视频属性抓取结束
# 开始BV号为1pv41167Km视频属性的抓取
# BV号为1pv41167Km的视频属性抓取结束
# 开始BV号为1yC4y1a7yn视频属性的抓取
# BV号为1yC4y1a7yn的视频属性抓取结束
# 开始BV号为1oz411i7R4视频属性的抓取
# BV号为1oz411i7R4的视频属性抓取结束
# 开始BV号为1PA411i7qn视频属性的抓取
# BV号为1PA411i7qn的视频属性抓取结束
# 开始BV号为1fK411p7Wi视频属性的抓取
# BV号为1fK411p7Wi的视频属性抓取结束
# 开始BV号为1bQ4y1P7Y9视频属性的抓取
# BV号为1bQ4y1P7Y9的视频属性抓取结束
# 开始BV号为1B5411W7f7视频属性的抓取
# BV号为1B5411W7f7的视频属性抓取结束
# 开始BV号为1jV411k77L视频属性的抓取
# BV号为1jV411k77L的视频属性抓取结束
# 开始BV号为18k4y1z74d视频属性的抓取
# BV号为18k4y1z74d的视频属性抓取结束
# 开始BV号为1kQ4y1P7CX视频属性的抓取
# BV号为1kQ4y1P7CX的视频属性抓取结束
# 开始BV号为1Sk4y1B7P3视频属性的抓取
# BV号为1Sk4y1B7P3的视频属性抓取结束
# 开始BV号为1hD4y1D7pC视频属性的抓取
# BV号为1hD4y1D7pC的视频属性抓取结束
# 开始BV号为1ki4y1s77K视频属性的抓取
# BV号为1ki4y1s77K的视频属性抓取结束
# 开始BV号为1eT4y177rC视频属性的抓取
# BV号为1eT4y177rC的视频属性抓取结束
# 开始BV号为1La4y1v7Ao视频属性的抓取
# BV号为1La4y1v7Ao的视频属性抓取结束
# 开始BV号为17i4y1G7aw视频属性的抓取
# BV号为17i4y1G7aw的视频属性抓取结束
# 开始BV号为1Rt4y1X7Ei视频属性的抓取
# BV号为1Rt4y1X7Ei的视频属性抓取结束
# 开始BV号为1hQ4y1P7Dg视频属性的抓取
# BV号为1hQ4y1P7Dg的视频属性抓取结束
# 开始BV号为1p5411W7LE视频属性的抓取
# BV号为1p5411W7LE的视频属性抓取结束
# 开始BV号为1bf4y117kM视频属性的抓取
# BV号为1bf4y117kM的视频属性抓取结束
# 开始BV号为19p4y1U7wt视频属性的抓取
# BV号为19p4y1U7wt的视频属性抓取结束
# 开始BV号为1Np4y1Q7VQ视频属性的抓取
# BV号为1Np4y1Q7VQ的视频属性抓取结束
# 开始BV号为1Tk4y1z7bn视频属性的抓取
# BV号为1Tk4y1z7bn的视频属性抓取结束
# 开始BV号为1fA411v7jF视频属性的抓取
# BV号为1fA411v7jF的视频属性抓取结束
# 开始BV号为1XC4y1h74X视频属性的抓取
# BV号为1XC4y1h74X的视频属性抓取结束
# 开始BV号为15Z4y1H7EE视频属性的抓取
# BV号为15Z4y1H7EE的视频属性抓取结束
# 开始BV号为1QC4y1a7tr视频属性的抓取
# BV号为1QC4y1a7tr的视频属性抓取结束
# 开始BV号为1Pz4y1R7SC视频属性的抓取
# BV号为1Pz4y1R7SC的视频属性抓取结束
# 开始BV号为19Z4y1H7V1视频属性的抓取
# BV号为19Z4y1H7V1的视频属性抓取结束
# 开始BV号为1yk4y1q7Eb视频属性的抓取
# BV号为1yk4y1q7Eb的视频属性抓取结束
# 开始BV号为1pT4y1J7Wb视频属性的抓取
# BV号为1pT4y1J7Wb的视频属性抓取结束
# 开始BV号为1ai4y1x7wa视频属性的抓取
# BV号为1ai4y1x7wa的视频属性抓取结束
# 开始BV号为1kK4y1x7N1视频属性的抓取
# BV号为1kK4y1x7N1的视频属性抓取结束
# 开始BV号为1QK411p7gB视频属性的抓取
# BV号为1QK411p7gB的视频属性抓取结束
# 开始BV号为1pg4y1q7LA视频属性的抓取
# BV号为1pg4y1q7LA的视频属性抓取结束
# 开始BV号为17T4y177hs视频属性的抓取
# BV号为17T4y177hs的视频属性抓取结束
# 开始BV号为1XA411v76e视频属性的抓取
# BV号为1XA411v76e的视频属性抓取结束
# 开始BV号为1rA411i7jK视频属性的抓取
# BV号为1rA411i7jK的视频属性抓取结束
# 开始BV号为1Mf4y1m7C8视频属性的抓取
# BV号为1Mf4y1m7C8的视频属性抓取结束
# 开始BV号为1GT4y1J7Ny视频属性的抓取
# BV号为1GT4y1J7Ny的视频属性抓取结束
# 开始BV号为1c54y1z7Ni视频属性的抓取
# BV号为1c54y1z7Ni的视频属性抓取结束
# 开始BV号为1PZ4y1H7bV视频属性的抓取
# BV号为1PZ4y1H7bV的视频属性抓取结束
# 开始BV号为1gz4y1R7ZM视频属性的抓取
# BV号为1gz4y1R7ZM的视频属性抓取结束
# 开始BV号为1PT4y1J7Lr视频属性的抓取
# BV号为1PT4y1J7Lr的视频属性抓取结束
# 开始BV号为1Q54y1B7De视频属性的抓取
# BV号为1Q54y1B7De的视频属性抓取结束
# 开始BV号为1AA411B7eY视频属性的抓取
# BV号为1AA411B7eY的视频属性抓取结束
# 开始BV号为1Vv41167Kx视频属性的抓取
# BV号为1Vv41167Kx的视频属性抓取结束
# 开始BV号为1vK411n7Rv视频属性的抓取
# BV号为1vK411n7Rv的视频属性抓取结束
# 开始BV号为1HZ4y1H7Rq视频属性的抓取
# BV号为1HZ4y1H7Rq的视频属性抓取结束
# 开始BV号为19V411r7VG视频属性的抓取
# BV号为19V411r7VG的视频属性抓取结束
# 开始BV号为19V411r7Wn视频属性的抓取
# BV号为19V411r7Wn的视频属性抓取结束
# 开始BV号为15t4y197Zj视频属性的抓取
# BV号为15t4y197Zj的视频属性抓取结束
# 开始BV号为17K4y147LN视频属性的抓取
# BV号为17K4y147LN的视频属性抓取结束
# 开始BV号为15z411v7fJ视频属性的抓取
# BV号为15z411v7fJ的视频属性抓取结束
# 开始BV号为1tV411r7C1视频属性的抓取
# BV号为1tV411r7C1的视频属性抓取结束
# 开始BV号为11z411e79L视频属性的抓取
# BV号为11z411e79L的视频属性抓取结束
# 开始BV号为1uv411B7CA视频属性的抓取
# BV号为1uv411B7CA的视频属性抓取结束
# 开始BV号为1Ci4y1G7Dz视频属性的抓取
# BV号为1Ci4y1G7Dz的视频属性抓取结束
# 开始BV号为1Cz4y197at视频属性的抓取
# BV号为1Cz4y197at的视频属性抓取结束
# 开始BV号为1ZT4y1E71G视频属性的抓取
# BV号为1ZT4y1E71G的视频属性抓取结束
# 开始BV号为15k4y1z7Jp视频属性的抓取
# BV号为15k4y1z7Jp的视频属性抓取结束
# 开始BV号为1Kz411i74C视频属性的抓取
# BV号为1Kz411i74C的视频属性抓取结束
# 开始BV号为1ug4y1v7aX视频属性的抓取
# BV号为1ug4y1v7aX的视频属性抓取结束
# 开始BV号为15C4y1a7UR视频属性的抓取
# BV号为15C4y1a7UR的视频属性抓取结束
# 开始BV号为1SC4y1h7mQ视频属性的抓取
# BV号为1SC4y1h7mQ的视频属性抓取结束
# 开始BV号为1kZ4y1H7hy视频属性的抓取
# BV号为1kZ4y1H7hy的视频属性抓取结束
# 开始BV号为1eT4y1J7vh视频属性的抓取
# BV号为1eT4y1J7vh的视频属性抓取结束
# 开始BV号为19z411i7Qv视频属性的抓取
# BV号为19z411i7Qv的视频属性抓取结束
# 开始BV号为1NT4y1J7iU视频属性的抓取
# BV号为1NT4y1J7iU的视频属性抓取结束
# 开始BV号为1fZ4y1H7eD视频属性的抓取
# BV号为1fZ4y1H7eD的视频属性抓取结束
# 开始BV号为1kQ4y1P796视频属性的抓取
# BV号为1kQ4y1P796的视频属性抓取结束
# 开始BV号为1Ak4y16744视频属性的抓取
# BV号为1Ak4y16744的视频属性抓取结束
# 开始BV号为1Rz411i71N视频属性的抓取
# BV号为1Rz411i71N的视频属性抓取结束
# 开始BV号为1KK411H7JJ视频属性的抓取
# BV号为1KK411H7JJ的视频属性抓取结束
# 开始BV号为19k4y1z73M视频属性的抓取
# BV号为19k4y1z73M的视频属性抓取结束
# 开始BV号为1ua4y1a7BK视频属性的抓取
# BV号为1ua4y1a7BK的视频属性抓取结束
# 开始BV号为1ep4y1S76z视频属性的抓取
# BV号为1ep4y1S76z的视频属性抓取结束
# 开始BV号为1LA411e7HN视频属性的抓取
# BV号为1LA411e7HN的视频属性抓取结束
# 开始BV号为1rt4y197uU视频属性的抓取
# BV号为1rt4y197uU的视频属性抓取结束
# 开始BV号为1m54y1q79G视频属性的抓取
# BV号为1m54y1q79G的视频属性抓取结束
# 开始BV号为1Qp4y1U7bm视频属性的抓取
# BV号为1Qp4y1U7bm的视频属性抓取结束
# 开始BV号为1oD4y1m7na视频属性的抓取
# BV号为1oD4y1m7na的视频属性抓取结束
# 开始BV号为1BV41167qR视频属性的抓取
# BV号为1BV41167qR的视频属性抓取结束
# 开始BV号为1J5411Y72Q视频属性的抓取
# BV号为1J5411Y72Q的视频属性抓取结束
# 开始BV号为1H54y1q71V视频属性的抓取
# BV号为1H54y1q71V的视频属性抓取结束
# 开始BV号为1Fk4y1B7zY视频属性的抓取
# BV号为1Fk4y1B7zY的视频属性抓取结束
# 开始BV号为17i4y137CQ视频属性的抓取
# BV号为17i4y137CQ的视频属性抓取结束
# 开始BV号为1qK4y1e7F6视频属性的抓取
# BV号为1qK4y1e7F6的视频属性抓取结束
# 开始BV号为11f4y1R7pr视频属性的抓取
# BV号为11f4y1R7pr的视频属性抓取结束
# 开始BV号为13T4y1j77w视频属性的抓取
# BV号为13T4y1j77w的视频属性抓取结束
# 开始BV号为1Qv411i7YH视频属性的抓取
# BV号为1Qv411i7YH的视频属性抓取结束
# 开始BV号为1K5411e7Ff视频属性的抓取
# BV号为1K5411e7Ff的视频属性抓取结束
# 开始BV号为1ek4y1q7ec视频属性的抓取
# BV号为1ek4y1q7ec的视频属性抓取结束
# 开始BV号为1hf4y1R7ke视频属性的抓取
# BV号为1hf4y1R7ke的视频属性抓取结束
# 开始BV号为1MT4y1E7qr视频属性的抓取
# BV号为1MT4y1E7qr的视频属性抓取结束
# 开始BV号为1cD4y1D7Be视频属性的抓取
# BV号为1cD4y1D7Be的视频属性抓取结束
# 开始BV号为1gT4y1E7XB视频属性的抓取
# BV号为1gT4y1E7XB的视频属性抓取结束
# 开始BV号为1BC4y187Xf视频属性的抓取
# BV号为1BC4y187Xf的视频属性抓取结束
# 开始BV号为1gV41167sH视频属性的抓取
# BV号为1gV41167sH的视频属性抓取结束
# 开始BV号为1Lk4y1m7E9视频属性的抓取
# BV号为1Lk4y1m7E9的视频属性抓取结束
# 开始BV号为1Jt4y1D7vM视频属性的抓取
# BV号为1Jt4y1D7vM的视频属性抓取结束
# 开始BV号为195411Y7gc视频属性的抓取
# BV号为195411Y7gc的视频属性抓取结束
# 开始BV号为18K411H77x视频属性的抓取
# BV号为18K411H77x的视频属性抓取结束
# 开始BV号为1cZ4y1g7uA视频属性的抓取
# BV号为1cZ4y1g7uA的视频属性抓取结束
# 开始BV号为1oK4y1s7xv视频属性的抓取
# BV号为1oK4y1s7xv的视频属性抓取结束
# 开始BV号为1ez411e7jV视频属性的抓取
# BV号为1ez411e7jV的视频属性抓取结束
# 开始BV号为1jv411q7yM视频属性的抓取
# BV号为1jv411q7yM的视频属性抓取结束
# 开始BV号为1Ua4y1a7Na视频属性的抓取
# BV号为1Ua4y1a7Na的视频属性抓取结束
# 开始BV号为11V411B7jT视频属性的抓取
# BV号为11V411B7jT的视频属性抓取结束
# 开始BV号为1GA411Y717视频属性的抓取
# BV号为1GA411Y717的视频属性抓取结束
# 开始BV号为1eK411J7aA视频属性的抓取
# BV号为1eK411J7aA的视频属性抓取结束
# 开始BV号为1t54y1z7hA视频属性的抓取
# BV号为1t54y1z7hA的视频属性抓取结束
# 开始BV号为12Z4y1T74u视频属性的抓取
# BV号为12Z4y1T74u的视频属性抓取结束
# 开始BV号为1si4y137C6视频属性的抓取
# BV号为1si4y137C6的视频属性抓取结束
# 开始BV号为11g4y1v78P视频属性的抓取
# BV号为11g4y1v78P的视频属性抓取结束
# 开始BV号为1EK4y1s7YL视频属性的抓取
# BV号为1EK4y1s7YL的视频属性抓取结束
# 开始BV号为1xZ4y1u7hS视频属性的抓取
# BV号为1xZ4y1u7hS的视频属性抓取结束
# 开始BV号为1np4y1q7CJ视频属性的抓取
# BV号为1np4y1q7CJ的视频属性抓取结束
# 开始BV号为1P5411Y78m视频属性的抓取
# BV号为1P5411Y78m的视频属性抓取结束
# 开始BV号为1yK4y1e7Bk视频属性的抓取
# BV号为1yK4y1e7Bk的视频属性抓取结束
# 开始BV号为1u54y1D7Ut视频属性的抓取
# BV号为1u54y1D7Ut的视频属性抓取结束
# 开始BV号为1x54y1q7PC视频属性的抓取
# BV号为1x54y1q7PC的视频属性抓取结束
# 开始BV号为1kt4y1Q7Ah视频属性的抓取
# BV号为1kt4y1Q7Ah的视频属性抓取结束
# 开始BV号为1SC4y1878w视频属性的抓取
# BV号为1SC4y1878w的视频属性抓取结束
# 开始BV号为1PT4y1j7S8视频属性的抓取
# BV号为1PT4y1j7S8的视频属性抓取结束
# 开始BV号为1nA411e7de视频属性的抓取
# BV号为1nA411e7de的视频属性抓取结束
# 开始BV号为11A411e7RE视频属性的抓取
# BV号为11A411e7RE的视频属性抓取结束
# 开始BV号为1xp4y1S74Z视频属性的抓取
# BV号为1xp4y1S74Z的视频属性抓取结束
# 开始BV号为1AK4y1v7VA视频属性的抓取
# BV号为1AK4y1v7VA的视频属性抓取结束
# 开始BV号为1eK4y147hb视频属性的抓取
# BV号为1eK4y147hb的视频属性抓取结束
# 开始BV号为1rK411H7eC视频属性的抓取
# BV号为1rK411H7eC的视频属性抓取结束
# 开始BV号为1Hp4y1q7NM视频属性的抓取
# BV号为1Hp4y1q7NM的视频属性抓取结束
# 开始BV号为17a4y1a7tv视频属性的抓取
# BV号为17a4y1a7tv的视频属性抓取结束
# 开始BV号为1Bz4y1D7Km视频属性的抓取
# BV号为1Bz4y1D7Km的视频属性抓取结束
# 开始BV号为1WC4y1b7JK视频属性的抓取
# BV号为1WC4y1b7JK的视频属性抓取结束
# 开始BV号为1Vp4y1S74Q视频属性的抓取
# BV号为1Vp4y1S74Q的视频属性抓取结束
# 开始BV号为1i5411a7tf视频属性的抓取
# BV号为1i5411a7tf的视频属性抓取结束
# 开始BV号为1Hh411o7xu视频属性的抓取
# BV号为1Hh411o7xu的视频属性抓取结束
# 开始BV号为1V5411a7rx视频属性的抓取
# BV号为1V5411a7rx的视频属性抓取结束
# 开始BV号为1JD4y1D7MM视频属性的抓取
# BV号为1JD4y1D7MM的视频属性抓取结束
# 开始BV号为1Hp4y1q7y2视频属性的抓取
# BV号为1Hp4y1q7y2的视频属性抓取结束
# 开始BV号为1JZ4y1u71y视频属性的抓取
# BV号为1JZ4y1u71y的视频属性抓取结束
# 开始BV号为1aa4y1E7po视频属性的抓取
# BV号为1aa4y1E7po的视频属性抓取结束
# 开始BV号为1ui4y1V73a视频属性的抓取
# BV号为1ui4y1V73a的视频属性抓取结束
# 开始BV号为1cC4y1h7YQ视频属性的抓取
# BV号为1cC4y1h7YQ的视频属性抓取结束
# 开始BV号为1HC4y1b7r5视频属性的抓取
# BV号为1HC4y1b7r5的视频属性抓取结束
# 开始BV号为12f4y1X7jo视频属性的抓取
# BV号为12f4y1X7jo的视频属性抓取结束
# 开始BV号为1Xt4y1973N视频属性的抓取
# BV号为1Xt4y1973N的视频属性抓取结束
# 开始BV号为1EK4y1x7pw视频属性的抓取
# BV号为1EK4y1x7pw的视频属性抓取结束
# 开始BV号为1RT4y1L7PA视频属性的抓取
# BV号为1RT4y1L7PA的视频属性抓取结束
# 开始BV号为1fa4y1h7jY视频属性的抓取
# BV号为1fa4y1h7jY的视频属性抓取结束
# 开始BV号为1Nk4y1674A视频属性的抓取
# BV号为1Nk4y1674A的视频属性抓取结束
# 开始BV号为19z4y1D7CS视频属性的抓取
# BV号为19z4y1D7CS的视频属性抓取结束
# 开始BV号为1Bf4y1X7nk视频属性的抓取
# BV号为1Bf4y1X7nk的视频属性抓取结束
# 开始BV号为1gf4y1R7j1视频属性的抓取
# BV号为1gf4y1R7j1的视频属性抓取结束
# 开始BV号为1TK411J7sm视频属性的抓取
# BV号为1TK411J7sm的视频属性抓取结束
# 开始BV号为1Cf4y117F1视频属性的抓取
# BV号为1Cf4y117F1的视频属性抓取结束
# 开始BV号为1sC4y1h7RT视频属性的抓取
# BV号为1sC4y1h7RT的视频属性抓取结束
# 开始BV号为1Ti4y137Kj视频属性的抓取
# BV号为1Ti4y137Kj的视频属性抓取结束
# 开始BV号为1NZ4y1u75i视频属性的抓取
# BV号为1NZ4y1u75i的视频属性抓取结束
# 开始BV号为19g4y1v7Xa视频属性的抓取
# BV号为19g4y1v7Xa的视频属性抓取结束
# 开始BV号为1F54y1B7d3视频属性的抓取
# BV号为1F54y1B7d3的视频属性抓取结束
# 开始BV号为1GV411r7S4视频属性的抓取
# BV号为1GV411r7S4的视频属性抓取结束
# 开始BV号为1uK411H7nB视频属性的抓取
# BV号为1uK411H7nB的视频属性抓取结束
# 开始BV号为11C4y1h7qJ视频属性的抓取
# BV号为11C4y1h7qJ的视频属性抓取结束
# 开始BV号为1Zh411o7ej视频属性的抓取
# BV号为1Zh411o7ej的视频属性抓取结束
# 开始BV号为1c5411e75u视频属性的抓取
# BV号为1c5411e75u的视频属性抓取结束
# 开始BV号为1vp4y1S7y6视频属性的抓取
# BV号为1vp4y1S7y6的视频属性抓取结束
# 开始BV号为1it4y1Q7uJ视频属性的抓取
# BV号为1it4y1Q7uJ的视频属性抓取结束
# 开始BV号为1rA411i7Mc视频属性的抓取
# BV号为1rA411i7Mc的视频属性抓取结束
# 开始BV号为1XC4y1b7HA视频属性的抓取
# BV号为1XC4y1b7HA的视频属性抓取结束
# 开始BV号为1DV411679V视频属性的抓取
# BV号为1DV411679V的视频属性抓取结束
# 开始BV号为1mh411o7Nv视频属性的抓取
# BV号为1mh411o7Nv的视频属性抓取结束
# 开始BV号为1dD4y1m7nQ视频属性的抓取
# BV号为1dD4y1m7nQ的视频属性抓取结束
# 开始BV号为1yC4y1h7GJ视频属性的抓取
# BV号为1yC4y1h7GJ的视频属性抓取结束
# 开始BV号为1xC4y1t7k4视频属性的抓取
# BV号为1xC4y1t7k4的视频属性抓取结束
# 开始BV号为1Li4y1g78f视频属性的抓取
# BV号为1Li4y1g78f的视频属性抓取结束
# 开始BV号为1ZA411Y7nt视频属性的抓取
# BV号为1ZA411Y7nt的视频属性抓取结束
# 开始BV号为1xC4y1t7jD视频属性的抓取
# BV号为1xC4y1t7jD的视频属性抓取结束
# 开始BV号为1Th411o7Ty视频属性的抓取
# BV号为1Th411o7Ty的视频属性抓取结束
# 开始BV号为1eK4y1Y7cw视频属性的抓取
# BV号为1eK4y1Y7cw的视频属性抓取结束
# 开始BV号为1k5411h7KX视频属性的抓取
# BV号为1k5411h7KX的视频属性抓取结束
# 开始BV号为14k4y127t5视频属性的抓取
# BV号为14k4y127t5的视频属性抓取结束
# 开始BV号为1cK411M79X视频属性的抓取
# BV号为1cK411M79X的视频属性抓取结束
# 开始BV号为1PK411T7FL视频属性的抓取
# BV号为1PK411T7FL的视频属性抓取结束
# 开始BV号为1UV411U7ZV视频属性的抓取
# BV号为1UV411U7ZV的视频属性抓取结束
# 开始BV号为1SD4y1U7x4视频属性的抓取
# 开始BV号为1SD4y1U7x4视频属性的抓取
# BV号为1SD4y1U7x4的视频属性抓取结束
# 开始BV号为1Qp4y1Y7iB视频属性的抓取
# BV号为1Qp4y1Y7iB的视频属性抓取结束
# 开始BV号为1tD4y1U7Rh视频属性的抓取
# BV号为1tD4y1U7Rh的视频属性抓取结束
# 开始BV号为1jT4y1L7f7视频属性的抓取
# BV号为1jT4y1L7f7的视频属性抓取结束
# 开始BV号为1mv411y7NT视频属性的抓取
# BV号为1mv411y7NT的视频属性抓取结束
# 开始BV号为1gK411T74Q视频属性的抓取
# BV号为1gK411T74Q的视频属性抓取结束
# 开始BV号为1o54118753视频属性的抓取
# BV号为1o54118753的视频属性抓取结束
# 开始BV号为1DD4y1U7dj视频属性的抓取
# BV号为1DD4y1U7dj的视频属性抓取结束
# 开始BV号为13Z4y1K71N视频属性的抓取
# BV号为13Z4y1K71N的视频属性抓取结束
# 开始BV号为17D4y1m74Q视频属性的抓取
# BV号为17D4y1m74Q的视频属性抓取结束
# 开始BV号为1rk4y127A9视频属性的抓取
# BV号为1rk4y127A9的视频属性抓取结束
# 开始BV号为1MK411n7Ty视频属性的抓取
# BV号为1MK411n7Ty的视频属性抓取结束
# 开始BV号为15T4y1L7s9视频属性的抓取
# BV号为15T4y1L7s9的视频属性抓取结束
# 开始BV号为14a4y1E7VH视频属性的抓取
# BV号为14a4y1E7VH的视频属性抓取结束
# 开始BV号为1JD4y127UK视频属性的抓取
# BV号为1JD4y127UK的视频属性抓取结束
# 开始BV号为1sa4y177dq视频属性的抓取
# BV号为1sa4y177dq的视频属性抓取结束
# 开始BV号为1Bi4y1M73p视频属性的抓取
# BV号为1Bi4y1M73p的视频属性抓取结束
# 开始BV号为1Vv411v71h视频属性的抓取
# BV号为1Vv411v71h的视频属性抓取结束
# 开始BV号为1f541187kX视频属性的抓取
# BV号为1f541187kX的视频属性抓取结束
# 开始BV号为1mK411T7Fq视频属性的抓取
# BV号为1mK411T7Fq的视频属性抓取结束
# 开始BV号为1zp4y1q7R2视频属性的抓取
# BV号为1zp4y1q7R2的视频属性抓取结束
# 开始BV号为1vD4y127xn视频属性的抓取
# BV号为1vD4y127xn的视频属性抓取结束
# 开始BV号为1EA411n7u3视频属性的抓取
# BV号为1EA411n7u3的视频属性抓取结束
# 开始BV号为1mv411y7DE视频属性的抓取
# BV号为1mv411y7DE的视频属性抓取结束
# 开始BV号为1ZZ4y1K7LN视频属性的抓取
# BV号为1ZZ4y1K7LN的视频属性抓取结束
# 开始BV号为18a4y1J7iL视频属性的抓取
# BV号为18a4y1J7iL的视频属性抓取结束
# 开始BV号为1sv411i77z视频属性的抓取
# BV号为1sv411i77z的视频属性抓取结束
# 开始BV号为1Kh411o7Vv视频属性的抓取
# BV号为1Kh411o7Vv的视频属性抓取结束
# 开始BV号为1FD4y1S7BU视频属性的抓取
# BV号为1FD4y1S7BU的视频属性抓取结束
# 开始BV号为1hz4y1f7uM视频属性的抓取
# BV号为1hz4y1f7uM的视频属性抓取结束
# 开始BV号为1GZ4y1M7En视频属性的抓取
# BV号为1GZ4y1M7En的视频属性抓取结束
# 开始BV号为1yK411T7Mt视频属性的抓取
# BV号为1yK411T7Mt的视频属性抓取结束
# 开始BV号为1FC4y1t7Cr视频属性的抓取
# BV号为1FC4y1t7Cr的视频属性抓取结束
# 开始BV号为1kV411U75g视频属性的抓取
# BV号为1kV411U75g的视频属性抓取结束
# 开始BV号为17h411Z7aF视频属性的抓取
# BV号为17h411Z7aF的视频属性抓取结束
# 开始BV号为15a4y177td视频属性的抓取
# BV号为15a4y177td的视频属性抓取结束
# 开始BV号为13h411o7iK视频属性的抓取
# BV号为13h411o7iK的视频属性抓取结束
# 开始BV号为14K4y1v7dK视频属性的抓取
# BV号为14K4y1v7dK的视频属性抓取结束
# 开始BV号为1n54y1e7xj视频属性的抓取
# BV号为1n54y1e7xj的视频属性抓取结束
# 开始BV号为1Lt4y1Q7dk视频属性的抓取
# 开始BV号为1Lt4y1Q7dk视频属性的抓取
# BV号为1Lt4y1Q7dk的视频属性抓取结束
# 开始BV号为16v411v7md视频属性的抓取
# BV号为16v411v7md的视频属性抓取结束
# 开始BV号为1N54y1D7vM视频属性的抓取
# 开始BV号为1N54y1D7vM视频属性的抓取
# BV号为1N54y1D7vM的视频属性抓取结束
# 开始BV号为1x54y1e7Hu视频属性的抓取
# BV号为1x54y1e7Hu的视频属性抓取结束
# 开始BV号为1zt4y1X7px视频属性的抓取
# BV号为1zt4y1X7px的视频属性抓取结束
# 开始BV号为1zZ4y1M7Dr视频属性的抓取
# BV号为1zZ4y1M7Dr的视频属性抓取结束
# 开始BV号为1ok4y1m764视频属性的抓取
# BV号为1ok4y1m764的视频属性抓取结束
# 开始BV号为1wi4y1u7uU视频属性的抓取
# BV号为1wi4y1u7uU的视频属性抓取结束
# 开始BV号为1ja4y1J76f视频属性的抓取
# BV号为1ja4y1J76f的视频属性抓取结束
# 开始BV号为1aZ4y1K7iJ视频属性的抓取
# BV号为1aZ4y1K7iJ的视频属性抓取结束
# 开始BV号为14T4y1L72U视频属性的抓取
# BV号为14T4y1L72U的视频属性抓取结束
# 开始BV号为1Zv411y71X视频属性的抓取
# BV号为1Zv411y71X的视频属性抓取结束
# 开始BV号为1n5411h7GL视频属性的抓取
# BV号为1n5411h7GL的视频属性抓取结束
# 开始BV号为1qa4y1J7xh视频属性的抓取
# BV号为1qa4y1J7xh的视频属性抓取结束
# 开始BV号为13T4y177ju视频属性的抓取
# BV号为13T4y177ju的视频属性抓取结束
# 开始BV号为1Gk4y127Rb视频属性的抓取
# BV号为1Gk4y127Rb的视频属性抓取结束
# 开始BV号为1Pv411i73y视频属性的抓取
# BV号为1Pv411i73y的视频属性抓取结束
# 开始BV号为1Vh411o7yF视频属性的抓取
# BV号为1Vh411o7yF的视频属性抓取结束
# 开始BV号为1rf4y1Q7k8视频属性的抓取
# BV号为1rf4y1Q7k8的视频属性抓取结束
# 开始BV号为1xT4y1L7ok视频属性的抓取
# BV号为1xT4y1L7ok的视频属性抓取结束
# 开始BV号为18A411Y7hE视频属性的抓取
# BV号为18A411Y7hE的视频属性抓取结束
# 开始BV号为1cK4y1e74u视频属性的抓取
# BV号为1cK4y1e74u的视频属性抓取结束
# 开始BV号为12k4y127n8视频属性的抓取
# BV号为12k4y127n8的视频属性抓取结束
# 开始BV号为19i4y137oE视频属性的抓取
# BV号为19i4y137oE的视频属性抓取结束
# 开始BV号为1GZ4y1K75e视频属性的抓取
# BV号为1GZ4y1K75e的视频属性抓取结束
# 开始BV号为1P64y1c756视频属性的抓取
# BV号为1P64y1c756的视频属性抓取结束
# 开始BV号为1E54y1v7xi视频属性的抓取
# BV号为1E54y1v7xi的视频属性抓取结束
# 开始BV号为14K411T7oe视频属性的抓取
# BV号为14K411T7oe的视频属性抓取结束
# 开始BV号为1ap4y1q79E视频属性的抓取
# BV号为1ap4y1q79E的视频属性抓取结束
# 开始BV号为1Xt4y1D7DS视频属性的抓取
# BV号为1Xt4y1D7DS的视频属性抓取结束
# 开始BV号为1xT4y1L7WJ视频属性的抓取
# BV号为1xT4y1L7WJ的视频属性抓取结束
# 开始BV号为1zC4y1t7tX视频属性的抓取
# BV号为1zC4y1t7tX的视频属性抓取结束
# 开始BV号为18k4y127du视频属性的抓取
# BV号为18k4y127du的视频属性抓取结束
# 开始BV号为11p4y1Y7FT视频属性的抓取
# BV号为11p4y1Y7FT的视频属性抓取结束
# 开始BV号为1TA411n7Tv视频属性的抓取
# BV号为1TA411n7Tv的视频属性抓取结束
# 开始BV号为15Z4y1K7DD视频属性的抓取
# BV号为15Z4y1K7DD的视频属性抓取结束
# 开始BV号为1BD4y1U7z7视频属性的抓取
# BV号为1BD4y1U7z7的视频属性抓取结束
# 开始BV号为1u64y1c7EC视频属性的抓取
# BV号为1u64y1c7EC的视频属性抓取结束
# 开始BV号为15z4y1Q7oB视频属性的抓取
# BV号为15z4y1Q7oB的视频属性抓取结束
# 开始BV号为19T4y1L7ZY视频属性的抓取
# BV号为19T4y1L7ZY的视频属性抓取结束
# 开始BV号为1TV411U71D视频属性的抓取
# BV号为1TV411U71D的视频属性抓取结束
# 开始BV号为1C5411a7nt视频属性的抓取
# BV号为1C5411a7nt的视频属性抓取结束
# 开始BV号为1W54y1i7ai视频属性的抓取
# BV号为1W54y1i7ai的视频属性抓取结束
# 开始BV号为19f4y1X7vh视频属性的抓取
# BV号为19f4y1X7vh的视频属性抓取结束
# 开始BV号为1xC4y1t7po视频属性的抓取
# BV号为1xC4y1t7po的视频属性抓取结束
# 开始BV号为16V411U7P6视频属性的抓取
# BV号为16V411U7P6的视频属性抓取结束
# 开始BV号为1zV411U7iM视频属性的抓取
# BV号为1zV411U7iM的视频属性抓取结束
# 开始BV号为1Xa4y1E7rG视频属性的抓取
# BV号为1Xa4y1E7rG的视频属性抓取结束
# 开始BV号为1NZ4y1T7X1视频属性的抓取
# BV号为1NZ4y1T7X1的视频属性抓取结束
# 开始BV号为1RD4y1U7Pf视频属性的抓取
# BV号为1RD4y1U7Pf的视频属性抓取结束
# 开始BV号为1Pv41117St视频属性的抓取
# BV号为1Pv41117St的视频属性抓取结束
# 开始BV号为17541187eW视频属性的抓取
# BV号为17541187eW的视频属性抓取结束
# 开始BV号为1by4y1k7vX视频属性的抓取
# BV号为1by4y1k7vX的视频属性抓取结束
# 开始BV号为1nk4y1y7Bf视频属性的抓取
# BV号为1nk4y1y7Bf的视频属性抓取结束
# 开始BV号为1bA411E7ZC视频属性的抓取
# BV号为1bA411E7ZC的视频属性抓取结束
# 开始BV号为1Bi4y177m7视频属性的抓取
# BV号为1Bi4y177m7的视频属性抓取结束
# 开始BV号为1By4y1k7PL视频属性的抓取
# BV号为1By4y1k7PL的视频属性抓取结束
# 开始BV号为1PK4y1Y7x6视频属性的抓取
# BV号为1PK4y1Y7x6的视频属性抓取结束
# 开始BV号为17a4y1E7As视频属性的抓取
# BV号为17a4y1E7As的视频属性抓取结束
# 开始BV号为1nT4y1A7bw视频属性的抓取
# BV号为1nT4y1A7bw的视频属性抓取结束
# 开始BV号为1oD4y1o7jm视频属性的抓取
# BV号为1oD4y1o7jm的视频属性抓取结束
# 开始BV号为1mZ4y1N7UT视频属性的抓取
# BV号为1mZ4y1N7UT的视频属性抓取结束
# 开始BV号为19Z4y1P782视频属性的抓取
# BV号为19Z4y1P782的视频属性抓取结束
# 开始BV号为1Rv4111797视频属性的抓取
# BV号为1Rv4111797的视频属性抓取结束
# 开始BV号为1qy4y1k77K视频属性的抓取
# BV号为1qy4y1k77K的视频属性抓取结束
# 开始BV号为1TK4y1Y7sD视频属性的抓取
# BV号为1TK4y1Y7sD的视频属性抓取结束
# 开始BV号为1Ai4y1E7u9视频属性的抓取
# BV号为1Ai4y1E7u9的视频属性抓取结束
# 开始BV号为15t4y1S7j6视频属性的抓取
# BV号为15t4y1S7j6的视频属性抓取结束
# 开始BV号为1PD4y1Z7Cq视频属性的抓取
# BV号为1PD4y1Z7Cq的视频属性抓取结束
# 开始BV号为1ND4y1m7sd视频属性的抓取
# BV号为1ND4y1m7sd的视频属性抓取结束
# 开始BV号为15f4y1X7xh视频属性的抓取
# BV号为15f4y1X7xh的视频属性抓取结束
# 开始BV号为1Xf4y1Q7i5视频属性的抓取
# BV号为1Xf4y1Q7i5的视频属性抓取结束
# 开始BV号为1Qz4y1f7SU视频属性的抓取
# BV号为1Qz4y1f7SU的视频属性抓取结束
# 开始BV号为1o54y1e7LH视频属性的抓取
# BV号为1o54y1e7LH的视频属性抓取结束
# 开始BV号为1CZ4y1N7JT视频属性的抓取
# BV号为1CZ4y1N7JT的视频属性抓取结束
# 开始BV号为11T4y1A7Qb视频属性的抓取
# BV号为11T4y1A7Qb的视频属性抓取结束
# 开始BV号为1jk4y117MJ视频属性的抓取
# BV号为1jk4y117MJ的视频属性抓取结束
# 开始BV号为1uT4y1A7Zk视频属性的抓取
# BV号为1uT4y1A7Zk的视频属性抓取结束
# 开始BV号为1kT4y1w7jx视频属性的抓取
# BV号为1kT4y1w7jx的视频属性抓取结束
# 开始BV号为1aA411n7Gu视频属性的抓取
# BV号为1aA411n7Gu的视频属性抓取结束
# 开始BV号为1wp4y1e7pA视频属性的抓取
# BV号为1wp4y1e7pA的视频属性抓取结束
# 开始BV号为1S54y1y7jN视频属性的抓取
# BV号为1S54y1y7jN的视频属性抓取结束
# 开始BV号为1a54y1C7id视频属性的抓取
# BV号为1a54y1C7id的视频属性抓取结束
# 开始BV号为1mK411K7vg视频属性的抓取
# BV号为1mK411K7vg的视频属性抓取结束
# 开始BV号为1mk4y1y7pG视频属性的抓取
# BV号为1mk4y1y7pG的视频属性抓取结束
# 开始BV号为1ny4y1y7gt视频属性的抓取
# BV号为1ny4y1y7gt的视频属性抓取结束
# 开始BV号为1bV411m7P9视频属性的抓取
# BV号为1bV411m7P9的视频属性抓取结束
# 开始BV号为12a4y157SK视频属性的抓取
# BV号为12a4y157SK的视频属性抓取结束
# 开始BV号为1G5411b7So视频属性的抓取
# BV号为1G5411b7So的视频属性抓取结束
# 开始BV号为1et4y1S7Ds视频属性的抓取
# BV号为1et4y1S7Ds的视频属性抓取结束
# 开始BV号为1HD4y1m7Cm视频属性的抓取
# BV号为1HD4y1m7Cm的视频属性抓取结束
# 开始BV号为11y4y1k7RH视频属性的抓取
# BV号为11y4y1k7RH的视频属性抓取结束
# 开始BV号为1by4y1y7Vd视频属性的抓取
# BV号为1by4y1y7Vd的视频属性抓取结束
# 开始BV号为1654y1C74D视频属性的抓取
# BV号为1654y1C74D的视频属性抓取结束
# 开始BV号为12D4y1o76Z视频属性的抓取
# BV号为12D4y1o76Z的视频属性抓取结束
# 开始BV号为1sV411m7SU视频属性的抓取
# BV号为1sV411m7SU的视频属性抓取结束
# 开始BV号为1T54y11743视频属性的抓取
# BV号为1T54y11743的视频属性抓取结束
# 开始BV号为1mD4y1d7EZ视频属性的抓取
# BV号为1mD4y1d7EZ的视频属性抓取结束
# 开始BV号为1GA411J7e1视频属性的抓取
# BV号为1GA411J7e1的视频属性抓取结束
# 开始BV号为1iZ4y1N7Be视频属性的抓取
# BV号为1iZ4y1N7Be的视频属性抓取结束
# 开始BV号为1ek4y127kn视频属性的抓取
# BV号为1ek4y127kn的视频属性抓取结束
# 开始BV号为18i4y1u7w3视频属性的抓取
# BV号为18i4y1u7w3的视频属性抓取结束
# 开始BV号为1DT4y1w7zd视频属性的抓取
# BV号为1DT4y1w7zd的视频属性抓取结束
# 开始BV号为14t4y1S7b3视频属性的抓取
# BV号为14t4y1S7b3的视频属性抓取结束
# 开始BV号为16D4y1o75g视频属性的抓取
# BV号为16D4y1o75g的视频属性抓取结束
# 开始BV号为1uK4y1Y76n视频属性的抓取
# BV号为1uK4y1Y76n的视频属性抓取结束
# 开始BV号为1Va4y1j7v6视频属性的抓取
# BV号为1Va4y1j7v6的视频属性抓取结束
# 开始BV号为1XK411K7yW视频属性的抓取
# BV号为1XK411K7yW的视频属性抓取结束
# 开始BV号为1b54y1y7bC视频属性的抓取
# BV号为1b54y1y7bC的视频属性抓取结束
# 开始BV号为1hA411E7EN视频属性的抓取
# BV号为1hA411E7EN的视频属性抓取结束
# 开始BV号为1jz4y1Z7MY视频属性的抓取
# BV号为1jz4y1Z7MY的视频属性抓取结束
# 开始BV号为1ti4y1u7wR视频属性的抓取
# BV号为1ti4y1u7wR的视频属性抓取结束
# 开始BV号为1vp4y1a7SU视频属性的抓取
# BV号为1vp4y1a7SU的视频属性抓取结束
# 开始BV号为1YA411E7ug视频属性的抓取
# BV号为1YA411E7ug的视频属性抓取结束
# 开始BV号为15f4y1X7qh视频属性的抓取
# BV号为15f4y1X7qh的视频属性抓取结束
# 开始BV号为1HD4y1o7wk视频属性的抓取
# BV号为1HD4y1o7wk的视频属性抓取结束
# 开始BV号为1Zz4y1o78p视频属性的抓取
# BV号为1Zz4y1o78p的视频属性抓取结束
# 开始BV号为1vt4y1S7iK视频属性的抓取
# BV号为1vt4y1S7iK的视频属性抓取结束
# 开始BV号为1kK411P76B视频属性的抓取
# BV号为1kK411P76B的视频属性抓取结束
# 开始BV号为14h411X7an视频属性的抓取
# BV号为14h411X7an的视频属性抓取结束
# 开始BV号为1gK411K7JZ视频属性的抓取
# BV号为1gK411K7JZ的视频属性抓取结束
# 开始BV号为1WK4y1a7rM视频属性的抓取
# BV号为1WK4y1a7rM的视频属性抓取结束
# 开始BV号为1Mi4y1u7s4视频属性的抓取
# BV号为1Mi4y1u7s4的视频属性抓取结束
# 开始BV号为17T4y1A7Uw视频属性的抓取
# BV号为17T4y1A7Uw的视频属性抓取结束
# 开始BV号为1Nf4y1X7Y3视频属性的抓取
# BV号为1Nf4y1X7Y3的视频属性抓取结束
# 开始BV号为1QD4y1d7vz视频属性的抓取
# BV号为1QD4y1d7vz的视频属性抓取结束
# 开始BV号为1UV41127Ye视频属性的抓取
# BV号为1UV41127Ye的视频属性抓取结束
# 开始BV号为1TK4y1e77y视频属性的抓取
# BV号为1TK4y1e77y的视频属性抓取结束
# 开始BV号为1ca4y1j74H视频属性的抓取
# BV号为1ca4y1j74H的视频属性抓取结束
# 开始BV号为1fA411E7Pn视频属性的抓取
# BV号为1fA411E7Pn的视频属性抓取结束
# 开始BV号为1vA41177Fe视频属性的抓取
# BV号为1vA41177Fe的视频属性抓取结束
# 开始BV号为1Wy4y1y7M1视频属性的抓取
# BV号为1Wy4y1y7M1的视频属性抓取结束
# 开始BV号为1Fz4y1f7Vt视频属性的抓取
# BV号为1Fz4y1f7Vt的视频属性抓取结束
# 开始BV号为13K4y1a7HX视频属性的抓取
# BV号为13K4y1a7HX的视频属性抓取结束
# 开始BV号为18f4y1X77Z视频属性的抓取
# BV号为18f4y1X77Z的视频属性抓取结束
# 开始BV号为1YA411n7wN视频属性的抓取
# BV号为1YA411n7wN的视频属性抓取结束
# 开始BV号为1YT4y1A7zp视频属性的抓取
# 开始BV号为1YT4y1A7zp视频属性的抓取
# BV号为1YT4y1A7zp的视频属性抓取结束
# 开始BV号为1ua4y1j7ZM视频属性的抓取
# BV号为1ua4y1j7ZM的视频属性抓取结束
# 开始BV号为1P5411j7DQ视频属性的抓取
# BV号为1P5411j7DQ的视频属性抓取结束
# 开始BV号为1Hk4y1y7Xd视频属性的抓取
# BV号为1Hk4y1y7Xd的视频属性抓取结束
# 开始BV号为1bt4y1v7qH视频属性的抓取
# BV号为1bt4y1v7qH的视频属性抓取结束
# 开始BV号为17k4y117vj视频属性的抓取
# BV号为17k4y117vj的视频属性抓取结束
# 开始BV号为1ut4y1S7gQ视频属性的抓取
# BV号为1ut4y1S7gQ的视频属性抓取结束
# 开始BV号为1Xi4y1E7c4视频属性的抓取
# BV号为1Xi4y1E7c4的视频属性抓取结束
# 开始BV号为1XZ4y1N7fT视频属性的抓取
# BV号为1XZ4y1N7fT的视频属性抓取结束
# 开始BV号为1Qk4y1k7Re视频属性的抓取
# BV号为1Qk4y1k7Re的视频属性抓取结束
# 开始BV号为1VT4y1A7VV视频属性的抓取
# BV号为1VT4y1A7VV的视频属性抓取结束
# 开始BV号为1V5411j7rJ视频属性的抓取
# BV号为1V5411j7rJ的视频属性抓取结束
# 开始BV号为1Qa4y1L7FV视频属性的抓取
# BV号为1Qa4y1L7FV的视频属性抓取结束
# 开始BV号为1aK411P7Li视频属性的抓取
# BV号为1aK411P7Li的视频属性抓取结束
# 开始BV号为18a4y1L79m视频属性的抓取
# BV号为18a4y1L79m的视频属性抓取结束
# 开始BV号为1h54y1C7F5视频属性的抓取
# BV号为1h54y1C7F5的视频属性抓取结束
# 开始BV号为14f4y1B72G视频属性的抓取
# BV号为14f4y1B72G的视频属性抓取结束
# 开始BV号为1CK4y1h72E视频属性的抓取
# BV号为1CK4y1h72E的视频属性抓取结束
# 开始BV号为1Ta4y1s7YX视频属性的抓取
# BV号为1Ta4y1s7YX的视频属性抓取结束
# 开始BV号为15D4y197zX视频属性的抓取
# BV号为15D4y197zX的视频属性抓取结束
# 开始BV号为1Hy4y1B7Zy视频属性的抓取
# BV号为1Hy4y1B7Zy的视频属性抓取结束
# 开始BV号为1nt4y1i7xh视频属性的抓取
# BV号为1nt4y1i7xh的视频属性抓取结束
# 开始BV号为1Xi4y1j7gx视频属性的抓取
# BV号为1Xi4y1j7gx的视频属性抓取结束
# 开始BV号为1b54y1C7Jf视频属性的抓取
# BV号为1b54y1C7Jf的视频属性抓取结束
# 开始BV号为1c54y1C7fR视频属性的抓取
# BV号为1c54y1C7fR的视频属性抓取结束
# 开始BV号为1uV41117c9视频属性的抓取
# BV号为1uV41117c9的视频属性抓取结束
# 开始BV号为1v5411L75E视频属性的抓取
# BV号为1v5411L75E的视频属性抓取结束
# 开始BV号为1Fa4y1s7vn视频属性的抓取
# BV号为1Fa4y1s7vn的视频属性抓取结束
# 开始BV号为1wp4y1k77v视频属性的抓取
# BV号为1wp4y1k77v的视频属性抓取结束
# 开始BV号为1UV411y7t4视频属性的抓取
# BV号为1UV411y7t4的视频属性抓取结束
# 开始BV号为1fp4y1r737视频属性的抓取
# BV号为1fp4y1r737的视频属性抓取结束
# 开始BV号为1X54y167te视频属性的抓取
# BV号为1X54y167te的视频属性抓取结束
# 开始BV号为1yr4y1c7hy视频属性的抓取
# BV号为1yr4y1c7hy的视频属性抓取结束
# 开始BV号为1eh41197q2视频属性的抓取
# BV号为1eh41197q2的视频属性抓取结束
# 开始BV号为1Py4y1r7Xe视频属性的抓取
# BV号为1Py4y1r7Xe的视频属性抓取结束
# 开始BV号为1Xz4y1d7gZ视频属性的抓取
# BV号为1Xz4y1d7gZ的视频属性抓取结束
# 开始BV号为1tV411y7TA视频属性的抓取
# BV号为1tV411y7TA的视频属性抓取结束
# 开始BV号为1cr4y1w74P视频属性的抓取
# BV号为1cr4y1w74P的视频属性抓取结束
# 开始BV号为1pp4y1k7tc视频属性的抓取
# BV号为1pp4y1k7tc的视频属性抓取结束
# 开始BV号为17Z4y1V7He视频属性的抓取
# BV号为17Z4y1V7He的视频属性抓取结束
# 开始BV号为1hf4y1i7m2视频属性的抓取
# BV号为1hf4y1i7m2的视频属性抓取结束
# 开始BV号为1Ea4y1s7Ce视频属性的抓取
# BV号为1Ea4y1s7Ce的视频属性抓取结束
# 开始BV号为18p4y1k7dG视频属性的抓取
# BV号为18p4y1k7dG的视频属性抓取结束
# 开始BV号为1zT4y1c7m3视频属性的抓取
# BV号为1zT4y1c7m3的视频属性抓取结束
# 开始BV号为1TV41127E6视频属性的抓取
# BV号为1TV41127E6的视频属性抓取结束
# 开始BV号为1Nk4y1y724视频属性的抓取
# BV号为1Nk4y1y724的视频属性抓取结束
# 开始BV号为1wt4y1e72e视频属性的抓取
# BV号为1wt4y1e72e的视频属性抓取结束
# 开始BV号为1eh41197KS视频属性的抓取
# BV号为1eh41197KS的视频属性抓取结束
# 开始BV号为1iA411J75d视频属性的抓取
# BV号为1iA411J75d的视频属性抓取结束
# 开始BV号为1uy4y187Mu视频属性的抓取
# BV号为1uy4y187Mu的视频属性抓取结束
# 开始BV号为1iK411A73z视频属性的抓取
# BV号为1iK411A73z的视频属性抓取结束
# 开始BV号为1Aa4y1s7q9视频属性的抓取
# BV号为1Aa4y1s7q9的视频属性抓取结束
# 开始BV号为1QK4y177as视频属性的抓取
# BV号为1QK4y177as的视频属性抓取结束
# 开始BV号为1HK4y1h77i视频属性的抓取
# BV号为1HK4y1h77i的视频属性抓取结束
# 开始BV号为15t4y1i7kR视频属性的抓取
# BV号为15t4y1i7kR的视频属性抓取结束
# 开始BV号为1Jy4y1r77L视频属性的抓取
# BV号为1Jy4y1r77L的视频属性抓取结束
# 开始BV号为1Nt4y1i7ZU视频属性的抓取
# BV号为1Nt4y1i7ZU的视频属性抓取结束
# 开始BV号为1Ff4y1B7M1视频属性的抓取
# BV号为1Ff4y1B7M1的视频属性抓取结束
# 开始BV号为1cK4y1h7gE视频属性的抓取
# BV号为1cK4y1h7gE的视频属性抓取结束
# 开始BV号为1Lr4y1w7zr视频属性的抓取
# BV号为1Lr4y1w7zr的视频属性抓取结束
# 开始BV号为1AV411y74T视频属性的抓取
# BV号为1AV411y74T的视频属性抓取结束
# 开始BV号为1854y1R7Zp视频属性的抓取
# BV号为1854y1R7Zp的视频属性抓取结束
# 开始BV号为1Zt4y1Y7FM视频属性的抓取
# BV号为1Zt4y1Y7FM的视频属性抓取结束
# 开始BV号为19f4y1q7sG视频属性的抓取
# BV号为19f4y1q7sG的视频属性抓取结束
# 开始BV号为1Zy4y1r7f6视频属性的抓取
# BV号为1Zy4y1r7f6的视频属性抓取结束
# 开始BV号为1QK411P7Gh视频属性的抓取
# BV号为1QK411P7Gh的视频属性抓取结束
# 开始BV号为1z54y1R7MU视频属性的抓取
# BV号为1z54y1R7MU的视频属性抓取结束
# 开始BV号为11Z4y1575u视频属性的抓取
# BV号为11Z4y1575u的视频属性抓取结束
# 开始BV号为18D4y1974b视频属性的抓取
# BV号为18D4y1974b的视频属性抓取结束
# 开始BV号为1qV411y7Vz视频属性的抓取
# BV号为1qV411y7Vz的视频属性抓取结束
# 开始BV号为1uv411C7oL视频属性的抓取
# BV号为1uv411C7oL的视频属性抓取结束
# 开始BV号为1RD4y1R722视频属性的抓取
# BV号为1RD4y1R722的视频属性抓取结束
# 开始BV号为1Ma4y1s719视频属性的抓取
# BV号为1Ma4y1s719的视频属性抓取结束
# 开始BV号为1Kf4y1B7zc视频属性的抓取
# BV号为1Kf4y1B7zc的视频属性抓取结束
# 开始BV号为1Ja411A7AC视频属性的抓取
# BV号为1Ja411A7AC的视频属性抓取结束
# 开始BV号为18K4y177cz视频属性的抓取
# BV号为18K4y177cz的视频属性抓取结束
# 开始BV号为1KD4y1d7BQ视频属性的抓取
# BV号为1KD4y1d7BQ的视频属性抓取结束
# 开始BV号为1Kv411C7cL视频属性的抓取
# BV号为1Kv411C7cL的视频属性抓取结束
# 开始BV号为13r4y1w7MM视频属性的抓取
# BV号为13r4y1w7MM的视频属性抓取结束
# 开始BV号为1xt4y1i7rP视频属性的抓取
# BV号为1xt4y1i7rP的视频属性抓取结束
# 开始BV号为1s5411L78G视频属性的抓取
# BV号为1s5411L78G的视频属性抓取结束
# 开始BV号为1Jp4y1Y7tH视频属性的抓取
# BV号为1Jp4y1Y7tH的视频属性抓取结束
# 开始BV号为1et4y1v71v视频属性的抓取
# BV号为1et4y1v71v的视频属性抓取结束
# 开始BV号为1iK4y187rd视频属性的抓取
# BV号为1iK4y187rd的视频属性抓取结束
# 开始BV号为1py4y1B7RB视频属性的抓取
# BV号为1py4y1B7RB的视频属性抓取结束
# 开始BV号为1Hy4y1r7Ls视频属性的抓取
# BV号为1Hy4y1r7Ls的视频属性抓取结束
# 开始BV号为1mV411y78s视频属性的抓取
# BV号为1mV411y78s的视频属性抓取结束
# 开始BV号为1TZ4y1V7Se视频属性的抓取
# BV号为1TZ4y1V7Se的视频属性抓取结束
# 开始BV号为1Vr4y1w7Dc视频属性的抓取
# BV号为1Vr4y1w7Dc的视频属性抓取结束
# 开始BV号为1qK411N7q3视频属性的抓取
# BV号为1qK411N7q3的视频属性抓取结束
# 开始BV号为1Jt4y1i7rE视频属性的抓取
# BV号为1Jt4y1i7rE的视频属性抓取结束
# 开始BV号为1K5411771J视频属性的抓取
# BV号为1K5411771J的视频属性抓取结束
# 开始BV号为1gp4y1k7PF视频属性的抓取
# BV号为1gp4y1k7PF的视频属性抓取结束
# 开始BV号为1UK4y1f7p3视频属性的抓取
# BV号为1UK4y1f7p3的视频属性抓取结束
# 开始BV号为1v54y1R7bN视频属性的抓取
# BV号为1v54y1R7bN的视频属性抓取结束
# 开始BV号为1AK411P7zC视频属性的抓取
# BV号为1AK411P7zC的视频属性抓取结束
# 开始BV号为1ut4y1i7bs视频属性的抓取
# BV号为1ut4y1i7bs的视频属性抓取结束
# 开始BV号为1Vt4y1v7fR视频属性的抓取
# BV号为1Vt4y1v7fR的视频属性抓取结束
# 开始BV号为1qZ4y157cq视频属性的抓取
# BV号为1qZ4y157cq的视频属性抓取结束
# 开始BV号为1Z54y1176p视频属性的抓取
# BV号为1Z54y1176p的视频属性抓取结束
# 开始BV号为1mT4y1c7xi视频属性的抓取
# BV号为1mT4y1c7xi的视频属性抓取结束
# 开始BV号为1br4y1F7W4视频属性的抓取
# BV号为1br4y1F7W4的视频属性抓取结束
# 开始BV号为1EK411N7PK视频属性的抓取
# BV号为1EK411N7PK的视频属性抓取结束
# 开始BV号为1kK4y1h754视频属性的抓取
# BV号为1kK4y1h754的视频属性抓取结束
# 开始BV号为1At4y1i7Xb视频属性的抓取
# BV号为1At4y1i7Xb的视频属性抓取结束
# 开始BV号为1Kk4y1y7cQ视频属性的抓取
# BV号为1Kk4y1y7cQ的视频属性抓取结束
# 开始BV号为1HT4y1w7m9视频属性的抓取
# BV号为1HT4y1w7m9的视频属性抓取结束
# 开始BV号为1Xp4y1r7yL视频属性的抓取
# BV号为1Xp4y1r7yL的视频属性抓取结束
# 开始BV号为1SV411y7vs视频属性的抓取
# BV号为1SV411y7vs的视频属性抓取结束
# 开始BV号为1K54y1r73A视频属性的抓取
# BV号为1K54y1r73A的视频属性抓取结束
# 开始BV号为1BK411N7RS视频属性的抓取
# BV号为1BK411N7RS的视频属性抓取结束
# 开始BV号为1Tz4y1y7u5视频属性的抓取
# BV号为1Tz4y1y7u5的视频属性抓取结束
# 开始BV号为1Rk4y1C7zP视频属性的抓取
# BV号为1Rk4y1C7zP的视频属性抓取结束
# 开始BV号为1ni4y1j7fi视频属性的抓取
# BV号为1ni4y1j7fi的视频属性抓取结束
# 2020-12-21 07:13:07.096390

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-27-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_wudao_mingxing.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 3月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月   100  100  100  100  100  100   100
# 2月    99   99   99   99   99   99    99
# 3月   100  100  100  100  100  100   100
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月   100  100  100  100  100  100   100
# 7月   100  100  100  100  100  100   100
# 8月   100  100  100  100  100  100   100
# 9月   100  100  100  100  100  100   100

# %%
channel_wudao_mingxing.to_json('channel_wudao_mingxing.json')
