# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_wudao_jiaocheng=pd.DataFrame(columns=columns)
channel_wudao_jiaocheng
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[5]/div/a/span').click()  #选择“舞蹈”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[5]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '舞蹈'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[7]/a').click()  #选择“宅舞”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[7]/a').text
sub_channel
# Out:
# '舞蹈教程'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(1,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_wudao_jiaocheng.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-21 07:49:12.133045
# <ipython-input-9-57d06d5ff608>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-9-57d06d5ff608>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-9-57d06d5ff608>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1P7411B7Aj视频属性的抓取
# BV号为1P7411B7Aj的视频属性抓取结束
# <ipython-input-9-57d06d5ff608>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1u7411i7iy视频属性的抓取
# BV号为1u7411i7iy的视频属性抓取结束
# 开始BV号为1JJ411V7am视频属性的抓取
# BV号为1JJ411V7am的视频属性抓取结束
# 开始BV号为1SJ411G7vu视频属性的抓取
# BV号为1SJ411G7vu的视频属性抓取结束
# 开始BV号为1BJ411G7b9视频属性的抓取
# BV号为1BJ411G7b9的视频属性抓取结束
# 开始BV号为1k7411z7Lb视频属性的抓取
# BV号为1k7411z7Lb的视频属性抓取结束
# 开始BV号为1UJ411V7P9视频属性的抓取
# BV号为1UJ411V7P9的视频属性抓取结束
# 开始BV号为1sJ411G7Ud视频属性的抓取
# BV号为1sJ411G7Ud的视频属性抓取结束
# 开始BV号为1SJ411J7sw视频属性的抓取
# 开始BV号为1SJ411J7sw视频属性的抓取
# BV号为1SJ411J7sw的视频属性抓取结束
# 开始BV号为1b7411r77Z视频属性的抓取
# BV号为1b7411r77Z的视频属性抓取结束
# 开始BV号为18J411G74B视频属性的抓取
# BV号为18J411G74B的视频属性抓取结束
# 开始BV号为1iJ411H7Jh视频属性的抓取
# BV号为1iJ411H7Jh的视频属性抓取结束
# 开始BV号为1D7411Y7S4视频属性的抓取
# BV号为1D7411Y7S4的视频属性抓取结束
# 开始BV号为1b7411z7of视频属性的抓取
# BV号为1b7411z7of的视频属性抓取结束
# 开始BV号为1u741167qS视频属性的抓取
# BV号为1u741167qS的视频属性抓取结束
# 开始BV号为1zJ411j7iH视频属性的抓取
# BV号为1zJ411j7iH的视频属性抓取结束
# 开始BV号为1xJ411j79H视频属性的抓取
# BV号为1xJ411j79H的视频属性抓取结束
# 开始BV号为1CJ411p7Tx视频属性的抓取
# BV号为1CJ411p7Tx的视频属性抓取结束
# 开始BV号为1SJ411J7uo视频属性的抓取
# BV号为1SJ411J7uo的视频属性抓取结束
# 开始BV号为1vJ411E7ns视频属性的抓取
# BV号为1vJ411E7ns的视频属性抓取结束
# 开始BV号为1Q7411Y7AB视频属性的抓取
# BV号为1Q7411Y7AB的视频属性抓取结束
# 开始BV号为1sJ411874o视频属性的抓取
# BV号为1sJ411874o的视频属性抓取结束
# 开始BV号为1KJ41187XV视频属性的抓取
# BV号为1KJ41187XV的视频属性抓取结束
# 开始BV号为1D7411v7DG视频属性的抓取
# 开始BV号为1D7411v7DG视频属性的抓取
# BV号为1D7411v7DG的视频属性抓取结束
# 开始BV号为1E7411z7HV视频属性的抓取
# BV号为1E7411z7HV的视频属性抓取结束
# 开始BV号为1u7411r7w1视频属性的抓取
# BV号为1u7411r7w1的视频属性抓取结束
# 开始BV号为1kJ411p7ia视频属性的抓取
# BV号为1kJ411p7ia的视频属性抓取结束
# 开始BV号为1v7411k7ia视频属性的抓取
# BV号为1v7411k7ia的视频属性抓取结束
# 开始BV号为12J41157hM视频属性的抓取
# BV号为12J41157hM的视频属性抓取结束
# 开始BV号为1E7411z7JQ视频属性的抓取
# BV号为1E7411z7JQ的视频属性抓取结束
# 开始BV号为1rJ41157EP视频属性的抓取
# BV号为1rJ41157EP的视频属性抓取结束
# 开始BV号为1c7411z7Wp视频属性的抓取
# BV号为1c7411z7Wp的视频属性抓取结束
# 开始BV号为1tJ41187Lj视频属性的抓取
# BV号为1tJ41187Lj的视频属性抓取结束
# 开始BV号为1gJ41157t6视频属性的抓取
# BV号为1gJ41157t6的视频属性抓取结束
# 开始BV号为1A7411B7kK视频属性的抓取
# BV号为1A7411B7kK的视频属性抓取结束
# 开始BV号为1k7411B7x4视频属性的抓取
# BV号为1k7411B7x4的视频属性抓取结束
# 开始BV号为1hJ411p7gq视频属性的抓取
# BV号为1hJ411p7gq的视频属性抓取结束
# 开始BV号为1tJ41177P4视频属性的抓取
# BV号为1tJ41177P4的视频属性抓取结束
# 开始BV号为197411i7hn视频属性的抓取
# BV号为197411i7hn的视频属性抓取结束
# 开始BV号为1RJ411V7mC视频属性的抓取
# BV号为1RJ411V7mC的视频属性抓取结束
# 开始BV号为1bJ411J7Zn视频属性的抓取
# BV号为1bJ411J7Zn的视频属性抓取结束
# 开始BV号为1FJ411J7hY视频属性的抓取
# BV号为1FJ411J7hY的视频属性抓取结束
# 开始BV号为1gJ411V7Np视频属性的抓取
# BV号为1gJ411V7Np的视频属性抓取结束
# 开始BV号为1Y7411a7XD视频属性的抓取
# BV号为1Y7411a7XD的视频属性抓取结束
# 开始BV号为1X7411Y7hZ视频属性的抓取
# BV号为1X7411Y7hZ的视频属性抓取结束
# 开始BV号为1r7411Y7ak视频属性的抓取
# BV号为1r7411Y7ak的视频属性抓取结束
# 开始BV号为18J411n7eY视频属性的抓取
# BV号为18J411n7eY的视频属性抓取结束
# 开始BV号为1J7411r7C2视频属性的抓取
# BV号为1J7411r7C2的视频属性抓取结束
# 开始BV号为17J411V7KK视频属性的抓取
# BV号为17J411V7KK的视频属性抓取结束
# 开始BV号为1zJ411H7UB视频属性的抓取
# BV号为1zJ411H7UB的视频属性抓取结束
# 开始BV号为19J411H7aj视频属性的抓取
# BV号为19J411H7aj的视频属性抓取结束
# 开始BV号为1FJ411p7Sk视频属性的抓取
# BV号为1FJ411p7Sk的视频属性抓取结束
# 开始BV号为157411i7xE视频属性的抓取
# BV号为157411i7xE的视频属性抓取结束
# 开始BV号为1NJ411p7wo视频属性的抓取
# BV号为1NJ411p7wo的视频属性抓取结束
# 开始BV号为1UJ411J7WN视频属性的抓取
# BV号为1UJ411J7WN的视频属性抓取结束
# 开始BV号为1wJ411776v视频属性的抓取
# BV号为1wJ411776v的视频属性抓取结束
# 开始BV号为1T7411e7uo视频属性的抓取
# BV号为1T7411e7uo的视频属性抓取结束
# 开始BV号为1G7411B77D视频属性的抓取
# BV号为1G7411B77D的视频属性抓取结束
# 开始BV号为1YJ411E7MY视频属性的抓取
# BV号为1YJ411E7MY的视频属性抓取结束
# 开始BV号为1v7411i7wa视频属性的抓取
# BV号为1v7411i7wa的视频属性抓取结束
# 开始BV号为1vJ411H7Sm视频属性的抓取
# BV号为1vJ411H7Sm的视频属性抓取结束
# 开始BV号为1HJ411n7td视频属性的抓取
# BV号为1HJ411n7td的视频属性抓取结束
# 开始BV号为1d7411i7uK视频属性的抓取
# BV号为1d7411i7uK的视频属性抓取结束
# 开始BV号为1GJ41187d9视频属性的抓取
# BV号为1GJ41187d9的视频属性抓取结束
# 开始BV号为14J411H7yg视频属性的抓取
# BV号为14J411H7yg的视频属性抓取结束
# 开始BV号为1r7411i7pV视频属性的抓取
# BV号为1r7411i7pV的视频属性抓取结束
# 开始BV号为1r741167tt视频属性的抓取
# BV号为1r741167tt的视频属性抓取结束
# 开始BV号为1T7411q7zr视频属性的抓取
# BV号为1T7411q7zr的视频属性抓取结束
# 开始BV号为1VJ411n7CK视频属性的抓取
# BV号为1VJ411n7CK的视频属性抓取结束
# 开始BV号为1u7411z71d视频属性的抓取
# BV号为1u7411z71d的视频属性抓取结束
# 开始BV号为1WJ411E7jV视频属性的抓取
# BV号为1WJ411E7jV的视频属性抓取结束
# 开始BV号为1k7411q7dn视频属性的抓取
# BV号为1k7411q7dn的视频属性抓取结束
# 开始BV号为1AJ411J7ht视频属性的抓取
# BV号为1AJ411J7ht的视频属性抓取结束
# 开始BV号为1x7411i7V1视频属性的抓取
# BV号为1x7411i7V1的视频属性抓取结束
# 开始BV号为1KJ411J7yV视频属性的抓取
# BV号为1KJ411J7yV的视频属性抓取结束
# 开始BV号为1jJ411G7cg视频属性的抓取
# BV号为1jJ411G7cg的视频属性抓取结束
# 开始BV号为1nJ41177mc视频属性的抓取
# BV号为1nJ41177mc的视频属性抓取结束
# 开始BV号为1v7411q7Qe视频属性的抓取
# BV号为1v7411q7Qe的视频属性抓取结束
# 开始BV号为1Z7411a79u视频属性的抓取
# BV号为1Z7411a79u的视频属性抓取结束
# 开始BV号为1k7411k7xK视频属性的抓取
# BV号为1k7411k7xK的视频属性抓取结束
# 开始BV号为1LJ411G7pm视频属性的抓取
# BV号为1LJ411G7pm的视频属性抓取结束
# 开始BV号为1sJ411n7Td视频属性的抓取
# BV号为1sJ411n7Td的视频属性抓取结束
# 开始BV号为1W7411q7Xc视频属性的抓取
# BV号为1W7411q7Xc的视频属性抓取结束
# 开始BV号为1A7411r75q视频属性的抓取
# BV号为1A7411r75q的视频属性抓取结束
# 开始BV号为1kJ411G7Fi视频属性的抓取
# BV号为1kJ411G7Fi的视频属性抓取结束
# 开始BV号为1TJ411V7tr视频属性的抓取
# BV号为1TJ411V7tr的视频属性抓取结束
# 开始BV号为16J411E7zJ视频属性的抓取
# BV号为16J411E7zJ的视频属性抓取结束
# 开始BV号为1MJ41187fo视频属性的抓取
# BV号为1MJ41187fo的视频属性抓取结束
# 开始BV号为1TJ411G7bB视频属性的抓取
# BV号为1TJ411G7bB的视频属性抓取结束
# 开始BV号为1r7411a7YP视频属性的抓取
# BV号为1r7411a7YP的视频属性抓取结束
# 开始BV号为13741167ap视频属性的抓取
# BV号为13741167ap的视频属性抓取结束
# 开始BV号为1fJ411n7Xg视频属性的抓取
# BV号为1fJ411n7Xg的视频属性抓取结束
# 开始BV号为1aJ411G71P视频属性的抓取
# BV号为1aJ411G71P的视频属性抓取结束
# 开始BV号为1T7411v7ET视频属性的抓取
# BV号为1T7411v7ET的视频属性抓取结束
# 开始BV号为1zJ41177vr视频属性的抓取
# BV号为1zJ41177vr的视频属性抓取结束
# 开始BV号为1HJ411E7pH视频属性的抓取
# BV号为1HJ411E7pH的视频属性抓取结束
# 开始BV号为1z7411r7UA视频属性的抓取
# BV号为1z7411r7UA的视频属性抓取结束
# 开始BV号为14J41187EY视频属性的抓取
# BV号为14J41187EY的视频属性抓取结束
# 开始BV号为1B7411i7DW视频属性的抓取
# BV号为1B7411i7DW的视频属性抓取结束
# 开始BV号为1q7411i78o视频属性的抓取
# BV号为1q7411i78o的视频属性抓取结束
# 开始BV号为1Z7411w7yq视频属性的抓取
# BV号为1Z7411w7yq的视频属性抓取结束
# 开始BV号为1J7411b7kR视频属性的抓取
# BV号为1J7411b7kR的视频属性抓取结束
# 开始BV号为117411L7LB视频属性的抓取
# BV号为117411L7LB的视频属性抓取结束
# 开始BV号为1v7411M76w视频属性的抓取
# BV号为1v7411M76w的视频属性抓取结束
# 开始BV号为1a7411F7Hk视频属性的抓取
# BV号为1a7411F7Hk的视频属性抓取结束
# 开始BV号为1W7411376w视频属性的抓取
# BV号为1W7411376w的视频属性抓取结束
# 开始BV号为1Gj411f7Ug视频属性的抓取
# BV号为1Gj411f7Ug的视频属性抓取结束
# 开始BV号为1a7411H7BA视频属性的抓取
# BV号为1a7411H7BA的视频属性抓取结束
# 开始BV号为1NE411H7r2视频属性的抓取
# BV号为1NE411H7r2的视频属性抓取结束
# 开始BV号为1c7411P7BH视频属性的抓取
# BV号为1c7411P7BH的视频属性抓取结束
# 开始BV号为1m7411K7Ji视频属性的抓取
# BV号为1m7411K7Ji的视频属性抓取结束
# 开始BV号为1e7411T7oC视频属性的抓取
# BV号为1e7411T7oC的视频属性抓取结束
# 开始BV号为1o7411b7Du视频属性的抓取
# BV号为1o7411b7Du的视频属性抓取结束
# 开始BV号为197411V7x4视频属性的抓取
# BV号为197411V7x4的视频属性抓取结束
# 开始BV号为197411M77p视频属性的抓取
# BV号为197411M77p的视频属性抓取结束
# 开始BV号为1r7411u78k视频属性的抓取
# BV号为1r7411u78k的视频属性抓取结束
# 开始BV号为1d741147pF视频属性的抓取
# BV号为1d741147pF的视频属性抓取结束
# 开始BV号为1g7411M7a6视频属性的抓取
# BV号为1g7411M7a6的视频属性抓取结束
# 开始BV号为1T7411V77A视频属性的抓取
# BV号为1T7411V77A的视频属性抓取结束
# 开始BV号为1PE411J7Fc视频属性的抓取
# BV号为1PE411J7Fc的视频属性抓取结束
# 开始BV号为197411n7U8视频属性的抓取
# BV号为197411n7U8的视频属性抓取结束
# 开始BV号为1k7411c7Su视频属性的抓取
# BV号为1k7411c7Su的视频属性抓取结束
# 开始BV号为197411L7YN视频属性的抓取
# BV号为197411L7YN的视频属性抓取结束
# 开始BV号为1C7411K7uW视频属性的抓取
# BV号为1C7411K7uW的视频属性抓取结束
# 开始BV号为1S7411G72q视频属性的抓取
# BV号为1S7411G72q的视频属性抓取结束
# 开始BV号为1D7411p7SR视频属性的抓取
# BV号为1D7411p7SR的视频属性抓取结束
# 开始BV号为167411E7T7视频属性的抓取
# BV号为167411E7T7的视频属性抓取结束
# 开始BV号为1r741177Hp视频属性的抓取
# BV号为1r741177Hp的视频属性抓取结束
# 开始BV号为1H7411F7Nx视频属性的抓取
# BV号为1H7411F7Nx的视频属性抓取结束
# 开始BV号为1q7411n7fc视频属性的抓取
# BV号为1q7411n7fc的视频属性抓取结束
# 开始BV号为1o7411877U视频属性的抓取
# BV号为1o7411877U的视频属性抓取结束
# 开始BV号为1q7411P7Q2视频属性的抓取
# BV号为1q7411P7Q2的视频属性抓取结束
# 开始BV号为1u7411x74t视频属性的抓取
# BV号为1u7411x74t的视频属性抓取结束
# 开始BV号为1h7411j76J视频属性的抓取
# BV号为1h7411j76J的视频属性抓取结束
# 开始BV号为1q741147AL视频属性的抓取
# BV号为1q741147AL的视频属性抓取结束
# 开始BV号为1f7411s78d视频属性的抓取
# BV号为1f7411s78d的视频属性抓取结束
# 开始BV号为16j411f7eP视频属性的抓取
# BV号为16j411f7eP的视频属性抓取结束
# 开始BV号为1J7411P7xV视频属性的抓取
# BV号为1J7411P7xV的视频属性抓取结束
# 开始BV号为1X7411x7GD视频属性的抓取
# BV号为1X7411x7GD的视频属性抓取结束
# 开始BV号为1d7411n7rh视频属性的抓取
# BV号为1d7411n7rh的视频属性抓取结束
# 开始BV号为157411h7bM视频属性的抓取
# BV号为157411h7bM的视频属性抓取结束
# 开始BV号为1Q7411N7Er视频属性的抓取
# BV号为1Q7411N7Er的视频属性抓取结束
# 开始BV号为1C7411W7gK视频属性的抓取
# BV号为1C7411W7gK的视频属性抓取结束
# 开始BV号为177411A7Fe视频属性的抓取
# BV号为177411A7Fe的视频属性抓取结束
# 开始BV号为1f7411F7we视频属性的抓取
# BV号为1f7411F7we的视频属性抓取结束
# 开始BV号为1g7411L7YY视频属性的抓取
# BV号为1g7411L7YY的视频属性抓取结束
# 开始BV号为1M7411W7uh视频属性的抓取
# BV号为1M7411W7uh的视频属性抓取结束
# 开始BV号为1x7411G7Q1视频属性的抓取
# BV号为1x7411G7Q1的视频属性抓取结束
# 开始BV号为137411J7zd视频属性的抓取
# BV号为137411J7zd的视频属性抓取结束
# 开始BV号为1g7411a7gc视频属性的抓取
# BV号为1g7411a7gc的视频属性抓取结束
# 开始BV号为1N741157QJ视频属性的抓取
# BV号为1N741157QJ的视频属性抓取结束
# 开始BV号为13E411H7m9视频属性的抓取
# BV号为13E411H7m9的视频属性抓取结束
# 开始BV号为1Y7411w7YD视频属性的抓取
# BV号为1Y7411w7YD的视频属性抓取结束
# 开始BV号为1C7411H7RH视频属性的抓取
# BV号为1C7411H7RH的视频属性抓取结束
# 开始BV号为1q7411x75B视频属性的抓取
# BV号为1q7411x75B的视频属性抓取结束
# 开始BV号为1q7411G7ca视频属性的抓取
# BV号为1q7411G7ca的视频属性抓取结束
# 开始BV号为1J7411J7rS视频属性的抓取
# BV号为1J7411J7rS的视频属性抓取结束
# 开始BV号为1A7411W7TW视频属性的抓取
# BV号为1A7411W7TW的视频属性抓取结束
# 开始BV号为1Q7411A7SR视频属性的抓取
# BV号为1Q7411A7SR的视频属性抓取结束
# 开始BV号为1b7411J78T视频属性的抓取
# BV号为1b7411J78T的视频属性抓取结束
# 开始BV号为1E741147ff视频属性的抓取
# BV号为1E741147ff的视频属性抓取结束
# 开始BV号为1Gj411f72Y视频属性的抓取
# BV号为1Gj411f72Y的视频属性抓取结束
# 开始BV号为1X7411W7KH视频属性的抓取
# BV号为1X7411W7KH的视频属性抓取结束
# 开始BV号为1c741157kj视频属性的抓取
# BV号为1c741157kj的视频属性抓取结束
# 开始BV号为1g7411a79H视频属性的抓取
# BV号为1g7411a79H的视频属性抓取结束
# 开始BV号为1q7411K7pQ视频属性的抓取
# BV号为1q7411K7pQ的视频属性抓取结束
# 开始BV号为12j411f7Xd视频属性的抓取
# BV号为12j411f7Xd的视频属性抓取结束
# 开始BV号为167411w7jS视频属性的抓取
# BV号为167411w7jS的视频属性抓取结束
# 开始BV号为11j411f7en视频属性的抓取
# BV号为11j411f7en的视频属性抓取结束
# 开始BV号为1k7411w7Vt视频属性的抓取
# BV号为1k7411w7Vt的视频属性抓取结束
# 开始BV号为1F7411L7ey视频属性的抓取
# BV号为1F7411L7ey的视频属性抓取结束
# 开始BV号为1Z7411A7w3视频属性的抓取
# BV号为1Z7411A7w3的视频属性抓取结束
# 开始BV号为1B741187RT视频属性的抓取
# BV号为1B741187RT的视频属性抓取结束
# 开始BV号为1U7411778R视频属性的抓取
# BV号为1U7411778R的视频属性抓取结束
# 开始BV号为1Z7411t7fw视频属性的抓取
# BV号为1Z7411t7fw的视频属性抓取结束
# 开始BV号为1e7411G78f视频属性的抓取
# BV号为1e7411G78f的视频属性抓取结束
# 开始BV号为117411A7Lp视频属性的抓取
# BV号为117411A7Lp的视频属性抓取结束
# 开始BV号为1y7411x7Rr视频属性的抓取
# BV号为1y7411x7Rr的视频属性抓取结束
# 开始BV号为1F7411L7Dn视频属性的抓取
# BV号为1F7411L7Dn的视频属性抓取结束
# 开始BV号为1G7411a7x8视频属性的抓取
# BV号为1G7411a7x8的视频属性抓取结束
# 开始BV号为1L7411J7GL视频属性的抓取
# BV号为1L7411J7GL的视频属性抓取结束
# 开始BV号为1F7411H7ib视频属性的抓取
# BV号为1F7411H7ib的视频属性抓取结束
# 开始BV号为1h7411472W视频属性的抓取
# BV号为1h7411472W的视频属性抓取结束
# 开始BV号为137411P7Lc视频属性的抓取
# BV号为137411P7Lc的视频属性抓取结束
# 开始BV号为1y741177FY视频属性的抓取
# BV号为1y741177FY的视频属性抓取结束
# 开始BV号为1F7411h7w1视频属性的抓取
# BV号为1F7411h7w1的视频属性抓取结束
# 开始BV号为1x741147Yd视频属性的抓取
# BV号为1x741147Yd的视频属性抓取结束
# <ipython-input-9-57d06d5ff608>:190: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1d7411L7Ba视频属性的抓取
# BV号为1d7411L7Ba的视频属性抓取结束
# 开始BV号为1k7411w7r5视频属性的抓取
# BV号为1k7411w7r5的视频属性抓取结束
# 开始BV号为1hj411f7cq视频属性的抓取
# BV号为1hj411f7cq的视频属性抓取结束
# 开始BV号为197411H7Rc视频属性的抓取
# BV号为197411H7Rc的视频属性抓取结束
# 开始BV号为1B7411c7js视频属性的抓取
# BV号为1B7411c7js的视频属性抓取结束
# 开始BV号为1u7411M7Ea视频属性的抓取
# BV号为1u7411M7Ea的视频属性抓取结束
# 开始BV号为1w7411E7xK视频属性的抓取
# BV号为1w7411E7xK的视频属性抓取结束
# 开始BV号为1u7411A7CH视频属性的抓取
# BV号为1u7411A7CH的视频属性抓取结束
# 开始BV号为16741157HK视频属性的抓取
# BV号为16741157HK的视频属性抓取结束
# 开始BV号为1oj411f7kv视频属性的抓取
# BV号为1oj411f7kv的视频属性抓取结束
# 开始BV号为1q7411J7KW视频属性的抓取
# BV号为1q7411J7KW的视频属性抓取结束
# 开始BV号为187411h7ty视频属性的抓取
# BV号为187411h7ty的视频属性抓取结束
# 开始BV号为18741117Nv视频属性的抓取
# BV号为18741117Nv的视频属性抓取结束
# 开始BV号为1GV411o7eu视频属性的抓取
# BV号为1GV411o7eu的视频属性抓取结束
# 开始BV号为1yA411877H视频属性的抓取
# BV号为1yA411877H的视频属性抓取结束
# 开始BV号为1pE411T7Tn视频属性的抓取
# BV号为1pE411T7Tn的视频属性抓取结束
# 开始BV号为1Bp4y117ws视频属性的抓取
# BV号为1Bp4y117ws的视频属性抓取结束
# 开始BV号为1W7411276d视频属性的抓取
# BV号为1W7411276d的视频属性抓取结束
# 开始BV号为1zE411N7pB视频属性的抓取
# BV号为1zE411N7pB的视频属性抓取结束
# 开始BV号为1y7411Z76p视频属性的抓取
# BV号为1y7411Z76p的视频属性抓取结束
# 开始BV号为1s7411o7fQ视频属性的抓取
# BV号为1s7411o7fQ的视频属性抓取结束
# 开始BV号为1EE411w7Ut视频属性的抓取
# BV号为1EE411w7Ut的视频属性抓取结束
# 开始BV号为1vK4y1C7oX视频属性的抓取
# BV号为1vK4y1C7oX的视频属性抓取结束
# 开始BV号为19541167Jx视频属性的抓取
# BV号为19541167Jx的视频属性抓取结束
# 开始BV号为1hE411P7Mq视频属性的抓取
# BV号为1hE411P7Mq的视频属性抓取结束
# 开始BV号为1zE411T75b视频属性的抓取
# BV号为1zE411T75b的视频属性抓取结束
# 开始BV号为1kE411G76J视频属性的抓取
# BV号为1kE411G76J的视频属性抓取结束
# 开始BV号为187411y7gU视频属性的抓取
# BV号为187411y7gU的视频属性抓取结束
# 开始BV号为1vE411L7xf视频属性的抓取
# BV号为1vE411L7xf的视频属性抓取结束
# 开始BV号为1hK4y1C7iE视频属性的抓取
# BV号为1hK4y1C7iE的视频属性抓取结束
# 开始BV号为14E411M7LS视频属性的抓取
# BV号为14E411M7LS的视频属性抓取结束
# 开始BV号为1dE411M7rx视频属性的抓取
# BV号为1dE411M7rx的视频属性抓取结束
# 开始BV号为1tE411E7fq视频属性的抓取
# BV号为1tE411E7fq的视频属性抓取结束
# 开始BV号为1s7411m74X视频属性的抓取
# BV号为1s7411m74X的视频属性抓取结束
# 开始BV号为1Gg4y1a7LU视频属性的抓取
# BV号为1Gg4y1a7LU的视频属性抓取结束
# 开始BV号为1eE411j72H视频属性的抓取
# BV号为1eE411j72H的视频属性抓取结束
# 开始BV号为1Np4y1C7Ps视频属性的抓取
# BV号为1Np4y1C7Ps的视频属性抓取结束
# 开始BV号为13E411x7mS视频属性的抓取
# BV号为13E411x7mS的视频属性抓取结束
# 开始BV号为1BE411E7Sx视频属性的抓取
# BV号为1BE411E7Sx的视频属性抓取结束
# 开始BV号为1BC4y147HQ视频属性的抓取
# BV号为1BC4y147HQ的视频属性抓取结束
# 开始BV号为1y7411m7gS视频属性的抓取
# BV号为1y7411m7gS的视频属性抓取结束
# 开始BV号为1B7411y75h视频属性的抓取
# BV号为1B7411y75h的视频属性抓取结束
# 开始BV号为1XE411G7zk视频属性的抓取
# BV号为1XE411G7zk的视频属性抓取结束
# 开始BV号为1tE41137En视频属性的抓取
# BV号为1tE41137En的视频属性抓取结束
# 开始BV号为1j7411C7Pr视频属性的抓取
# BV号为1j7411C7Pr的视频属性抓取结束
# 开始BV号为1c7411d7Hf视频属性的抓取
# BV号为1c7411d7Hf的视频属性抓取结束
# 开始BV号为1yE411M75B视频属性的抓取
# BV号为1yE411M75B的视频属性抓取结束
# 开始BV号为17E411s7CG视频属性的抓取
# BV号为17E411s7CG的视频属性抓取结束
# 开始BV号为1pE411u7eU视频属性的抓取
# BV号为1pE411u7eU的视频属性抓取结束
# 开始BV号为1qE411g7yS视频属性的抓取
# BV号为1qE411g7yS的视频属性抓取结束
# 开始BV号为1sE411w7Ce视频属性的抓取
# BV号为1sE411w7Ce的视频属性抓取结束
# 开始BV号为1x7411U7SS视频属性的抓取
# BV号为1x7411U7SS的视频属性抓取结束
# 开始BV号为1D7411Z741视频属性的抓取
# BV号为1D7411Z741的视频属性抓取结束
# 开始BV号为1CE411s7kw视频属性的抓取
# BV号为1CE411s7kw的视频属性抓取结束
# 开始BV号为1zE411u7PZ视频属性的抓取
# BV号为1zE411u7PZ的视频属性抓取结束
# 开始BV号为1H7411Z7xd视频属性的抓取
# BV号为1H7411Z7xd的视频属性抓取结束
# 开始BV号为1FE411c7tb视频属性的抓取
# BV号为1FE411c7tb的视频属性抓取结束
# 开始BV号为1KE411w7Fv视频属性的抓取
# BV号为1KE411w7Fv的视频属性抓取结束
# 开始BV号为16741127KX视频属性的抓取
# BV号为16741127KX的视频属性抓取结束
# 开始BV号为18E411L77U视频属性的抓取
# BV号为18E411L77U的视频属性抓取结束
# 开始BV号为1vE411W72s视频属性的抓取
# BV号为1vE411W72s的视频属性抓取结束
# 开始BV号为1j7411f7PZ视频属性的抓取
# BV号为1j7411f7PZ的视频属性抓取结束
# 开始BV号为1x7411m7Dv视频属性的抓取
# BV号为1x7411m7Dv的视频属性抓取结束
# 开始BV号为1jE411L76R视频属性的抓取
# BV号为1jE411L76R的视频属性抓取结束
# 开始BV号为1JE411w77s视频属性的抓取
# BV号为1JE411w77s的视频属性抓取结束
# 开始BV号为12E411V7WJ视频属性的抓取
# BV号为12E411V7WJ的视频属性抓取结束
# 开始BV号为1BE411T7mG视频属性的抓取
# BV号为1BE411T7mG的视频属性抓取结束
# 开始BV号为1B7411R7NF视频属性的抓取
# BV号为1B7411R7NF的视频属性抓取结束
# 开始BV号为1ZE411p7qo视频属性的抓取
# BV号为1ZE411p7qo的视频属性抓取结束
# 开始BV号为1bE411V7sp视频属性的抓取
# BV号为1bE411V7sp的视频属性抓取结束
# 开始BV号为1LE411M7zG视频属性的抓取
# BV号为1LE411M7zG的视频属性抓取结束
# 开始BV号为14E411K7ye视频属性的抓取
# BV号为14E411K7ye的视频属性抓取结束
# 开始BV号为1jE411L79x视频属性的抓取
# BV号为1jE411L79x的视频属性抓取结束
# 开始BV号为1c7411Z74t视频属性的抓取
# BV号为1c7411Z74t的视频属性抓取结束
# 开始BV号为1nZ4y1j7Hv视频属性的抓取
# BV号为1nZ4y1j7Hv的视频属性抓取结束
# 开始BV号为1JE41137iM视频属性的抓取
# BV号为1JE41137iM的视频属性抓取结束
# 开始BV号为1sK411772r视频属性的抓取
# BV号为1sK411772r的视频属性抓取结束
# 开始BV号为1LE411P7ZM视频属性的抓取
# BV号为1LE411P7ZM的视频属性抓取结束
# 开始BV号为14p4y117Sw视频属性的抓取
# BV号为14p4y117Sw的视频属性抓取结束
# 开始BV号为1zE411u7sv视频属性的抓取
# BV号为1zE411u7sv的视频属性抓取结束
# 开始BV号为1N7411o79a视频属性的抓取
# BV号为1N7411o79a的视频属性抓取结束
# 开始BV号为1QE411H76t视频属性的抓取
# BV号为1QE411H76t的视频属性抓取结束
# 开始BV号为1cE411W7uo视频属性的抓取
# BV号为1cE411W7uo的视频属性抓取结束
# 开始BV号为1nC4y147Mg视频属性的抓取
# BV号为1nC4y147Mg的视频属性抓取结束
# 开始BV号为1K7411d7kr视频属性的抓取
# BV号为1K7411d7kr的视频属性抓取结束
# 开始BV号为1F7411m7vz视频属性的抓取
# BV号为1F7411m7vz的视频属性抓取结束
# 开始BV号为1P5411r7rw视频属性的抓取
# BV号为1P5411r7rw的视频属性抓取结束
# 开始BV号为197411d7th视频属性的抓取
# BV号为197411d7th的视频属性抓取结束
# 开始BV号为1564y1u7pa视频属性的抓取
# BV号为1564y1u7pa的视频属性抓取结束
# 开始BV号为1G7411o7Jx视频属性的抓取
# BV号为1G7411o7Jx的视频属性抓取结束
# 开始BV号为1rE411u7ay视频属性的抓取
# BV号为1rE411u7ay的视频属性抓取结束
# 开始BV号为1rK4y1C7Xb视频属性的抓取
# BV号为1rK4y1C7Xb的视频属性抓取结束
# 开始BV号为1g7411R75j视频属性的抓取
# BV号为1g7411R75j的视频属性抓取结束
# 开始BV号为1XA41187Ke视频属性的抓取
# BV号为1XA41187Ke的视频属性抓取结束
# 开始BV号为1YE41137XT视频属性的抓取
# BV号为1YE41137XT的视频属性抓取结束
# 开始BV号为1sp4y117ab视频属性的抓取
# BV号为1sp4y117ab的视频属性抓取结束
# 开始BV号为12K4y1C7eW视频属性的抓取
# BV号为12K4y1C7eW的视频属性抓取结束
# 开始BV号为1oi4y1b7SC视频属性的抓取
# BV号为1oi4y1b7SC的视频属性抓取结束
# 开始BV号为1tK41177mL视频属性的抓取
# BV号为1tK41177mL的视频属性抓取结束
# 开始BV号为147411D7iY视频属性的抓取
# BV号为147411D7iY的视频属性抓取结束
# 开始BV号为1jE411K7En视频属性的抓取
# BV号为1jE411K7En的视频属性抓取结束
# 开始BV号为1p7411f7CW视频属性的抓取
# BV号为1p7411f7CW的视频属性抓取结束
# 开始BV号为1V7411U7Nj视频属性的抓取
# BV号为1V7411U7Nj的视频属性抓取结束
# 开始BV号为1QA41187M9视频属性的抓取
# BV号为1QA41187M9的视频属性抓取结束
# 开始BV号为157411R7UY视频属性的抓取
# BV号为157411R7UY的视频属性抓取结束
# 开始BV号为1xE411c7dM视频属性的抓取
# BV号为1xE411c7dM的视频属性抓取结束
# 开始BV号为1zE411V7hs视频属性的抓取
# BV号为1zE411V7hs的视频属性抓取结束
# 开始BV号为137411Z7jd视频属性的抓取
# BV号为137411Z7jd的视频属性抓取结束
# 开始BV号为1ME41177AZ视频属性的抓取
# BV号为1ME41177AZ的视频属性抓取结束
# 开始BV号为1p7411C7ji视频属性的抓取
# BV号为1p7411C7ji的视频属性抓取结束
# 开始BV号为1cE411V7Pk视频属性的抓取
# BV号为1cE411V7Pk的视频属性抓取结束
# 开始BV号为187411y7v1视频属性的抓取
# BV号为187411y7v1的视频属性抓取结束
# 开始BV号为1RZ4y1x7Dj视频属性的抓取
# BV号为1RZ4y1x7Dj的视频属性抓取结束
# 开始BV号为1UK411V7C9视频属性的抓取
# BV号为1UK411V7C9的视频属性抓取结束
# 开始BV号为1KK41157PZ视频属性的抓取
# BV号为1KK41157PZ的视频属性抓取结束
# 开始BV号为1ni4y187oy视频属性的抓取
# BV号为1ni4y187oy的视频属性抓取结束
# 开始BV号为1SK4y1C7Fc视频属性的抓取
# BV号为1SK4y1C7Fc的视频属性抓取结束
# 开始BV号为1YV411o7Ve视频属性的抓取
# BV号为1YV411o7Ve的视频属性抓取结束
# 开始BV号为1q5411x7y1视频属性的抓取
# BV号为1q5411x7y1的视频属性抓取结束
# 开始BV号为1zK41177bs视频属性的抓取
# BV号为1zK41177bs的视频属性抓取结束
# 开始BV号为1rK41177Vn视频属性的抓取
# BV号为1rK41177Vn的视频属性抓取结束
# 开始BV号为1EC4y1x7b4视频属性的抓取
# BV号为1EC4y1x7b4的视频属性抓取结束
# 开始BV号为1b54y1d7A5视频属性的抓取
# BV号为1b54y1d7A5的视频属性抓取结束
# 开始BV号为1jV411d7Rg视频属性的抓取
# BV号为1jV411d7Rg的视频属性抓取结束
# 开始BV号为1Jg4y1z74Z视频属性的抓取
# BV号为1Jg4y1z74Z的视频属性抓取结束
# 开始BV号为1VA411h7bz视频属性的抓取
# BV号为1VA411h7bz的视频属性抓取结束
# 开始BV号为1xK4y1b7xM视频属性的抓取
# BV号为1xK4y1b7xM的视频属性抓取结束
# 开始BV号为1zk4y197Kn视频属性的抓取
# BV号为1zk4y197Kn的视频属性抓取结束
# 开始BV号为1Eg4y187eH视频属性的抓取
# BV号为1Eg4y187eH的视频属性抓取结束
# 开始BV号为1Mi4y1t7C1视频属性的抓取
# BV号为1Mi4y1t7C1的视频属性抓取结束
# 开始BV号为1R54y1Q7mL视频属性的抓取
# BV号为1R54y1Q7mL的视频属性抓取结束
# 开始BV号为1GA411b7P2视频属性的抓取
# BV号为1GA411b7P2的视频属性抓取结束
# 开始BV号为1t5411x7fj视频属性的抓取
# BV号为1t5411x7fj的视频属性抓取结束
# 开始BV号为1Dg4y1z7bD视频属性的抓取
# BV号为1Dg4y1z7bD的视频属性抓取结束
# 开始BV号为1KK4y1k7R5视频属性的抓取
# BV号为1KK4y1k7R5的视频属性抓取结束
# 开始BV号为1kf4y1S7Vf视频属性的抓取
# BV号为1kf4y1S7Vf的视频属性抓取结束
# 开始BV号为1954y197eY视频属性的抓取
# BV号为1954y197eY的视频属性抓取结束
# 开始BV号为1Vt4y1U7Mp视频属性的抓取
# BV号为1Vt4y1U7Mp的视频属性抓取结束
# 开始BV号为1Sp4y1X744视频属性的抓取
# BV号为1Sp4y1X744的视频属性抓取结束
# 开始BV号为1qf4y1S7n9视频属性的抓取
# BV号为1qf4y1S7n9的视频属性抓取结束
# 开始BV号为1st4y127sE视频属性的抓取
# BV号为1st4y127sE的视频属性抓取结束
# 开始BV号为1RZ4y1W7UB视频属性的抓取
# BV号为1RZ4y1W7UB的视频属性抓取结束
# 开始BV号为1rg4y1b7rM视频属性的抓取
# BV号为1rg4y1b7rM的视频属性抓取结束
# 开始BV号为1wC4y1W7dW视频属性的抓取
# BV号为1wC4y1W7dW的视频属性抓取结束
# 开始BV号为1yC4y1s7dx视频属性的抓取
# BV号为1yC4y1s7dx的视频属性抓取结束
# 开始BV号为1YT4y1G7Yg视频属性的抓取
# BV号为1YT4y1G7Yg的视频属性抓取结束
# 开始BV号为1UK411L7ew视频属性的抓取
# BV号为1UK411L7ew的视频属性抓取结束
# 开始BV号为1ap4y1C75i视频属性的抓取
# BV号为1ap4y1C75i的视频属性抓取结束
# 开始BV号为1wZ4y147AK视频属性的抓取
# BV号为1wZ4y147AK的视频属性抓取结束
# 开始BV号为18k4y1r7iS视频属性的抓取
# BV号为18k4y1r7iS的视频属性抓取结束
# 开始BV号为1BK4y1r7tr视频属性的抓取
# BV号为1BK4y1r7tr的视频属性抓取结束
# 开始BV号为1gi4y1t7Hb视频属性的抓取
# BV号为1gi4y1t7Hb的视频属性抓取结束
# 开始BV号为1vC4y1s7a5视频属性的抓取
# BV号为1vC4y1s7a5的视频属性抓取结束
# 开始BV号为1Ua4y1v7p4视频属性的抓取
# BV号为1Ua4y1v7p4的视频属性抓取结束
# 开始BV号为1Kt4y1m77d视频属性的抓取
# BV号为1Kt4y1m77d的视频属性抓取结束
# 开始BV号为11A41147vt视频属性的抓取
# BV号为11A41147vt的视频属性抓取结束
# 开始BV号为1Yg4y1z7A9视频属性的抓取
# BV号为1Yg4y1z7A9的视频属性抓取结束
# 开始BV号为1kV411o7zb视频属性的抓取
# BV号为1kV411o7zb的视频属性抓取结束
# 开始BV号为1fZ4y1s7vY视频属性的抓取
# BV号为1fZ4y1s7vY的视频属性抓取结束
# 开始BV号为14Q4y1T7Fs视频属性的抓取
# BV号为14Q4y1T7Fs的视频属性抓取结束
# 开始BV号为1UZ4y1W748视频属性的抓取
# BV号为1UZ4y1W748的视频属性抓取结束
# 开始BV号为1w54y197rN视频属性的抓取
# BV号为1w54y197rN的视频属性抓取结束
# 开始BV号为1ht4y127dF视频属性的抓取
# BV号为1ht4y127dF的视频属性抓取结束
# 开始BV号为1EK411j7Qw视频属性的抓取
# BV号为1EK411j7Qw的视频属性抓取结束
# 开始BV号为1ZZ4y1W7Vr视频属性的抓取
# BV号为1ZZ4y1W7Vr的视频属性抓取结束
# 开始BV号为1SK4y1C7Ud视频属性的抓取
# BV号为1SK4y1C7Ud的视频属性抓取结束
# 开始BV号为1DZ4y1x7Vf视频属性的抓取
# BV号为1DZ4y1x7Vf的视频属性抓取结束
# 开始BV号为1Rg4y1z7Uk视频属性的抓取
# BV号为1Rg4y1z7Uk的视频属性抓取结束
# 开始BV号为1Xa4y1t7PA视频属性的抓取
# BV号为1Xa4y1t7PA的视频属性抓取结束
# 开始BV号为1gA411b7Lq视频属性的抓取
# BV号为1gA411b7Lq的视频属性抓取结束
# 开始BV号为1Jz411b7DK视频属性的抓取
# BV号为1Jz411b7DK的视频属性抓取结束
# 开始BV号为1LV411Z79E视频属性的抓取
# BV号为1LV411Z79E的视频属性抓取结束
# 开始BV号为1iT4y1g7Mw视频属性的抓取
# BV号为1iT4y1g7Mw的视频属性抓取结束
# 开始BV号为1ZQ4y1P7rS视频属性的抓取
# BV号为1ZQ4y1P7rS的视频属性抓取结束
# 开始BV号为16K4y1r7kM视频属性的抓取
# BV号为16K4y1r7kM的视频属性抓取结束
# 开始BV号为1Ea4y1x7V5视频属性的抓取
# BV号为1Ea4y1x7V5的视频属性抓取结束
# 开始BV号为1uZ4y1x7ck视频属性的抓取
# BV号为1uZ4y1x7ck的视频属性抓取结束
# 开始BV号为1UQ4y1P7mY视频属性的抓取
# BV号为1UQ4y1P7mY的视频属性抓取结束
# 开始BV号为1g541147TG视频属性的抓取
# BV号为1g541147TG的视频属性抓取结束
# 开始BV号为12K411V74p视频属性的抓取
# BV号为12K411V74p的视频属性抓取结束
# 开始BV号为1zA41147v7视频属性的抓取
# BV号为1zA41147v7的视频属性抓取结束
# 开始BV号为115411x7VH视频属性的抓取
# BV号为115411x7VH的视频属性抓取结束
# 开始BV号为1SV411o7oT视频属性的抓取
# BV号为1SV411o7oT的视频属性抓取结束
# 开始BV号为15a4y1t7bz视频属性的抓取
# BV号为15a4y1t7bz的视频属性抓取结束
# 开始BV号为1NT4y1579t视频属性的抓取
# BV号为1NT4y1579t的视频属性抓取结束
# 开始BV号为1RK411L7Y2视频属性的抓取
# BV号为1RK411L7Y2的视频属性抓取结束
# 开始BV号为1h64y1u7fd视频属性的抓取
# BV号为1h64y1u7fd的视频属性抓取结束
# 开始BV号为1s64y1M7h5视频属性的抓取
# BV号为1s64y1M7h5的视频属性抓取结束
# 开始BV号为1C5411t7T8视频属性的抓取
# BV号为1C5411t7T8的视频属性抓取结束
# 开始BV号为15C4y1s7LP视频属性的抓取
# BV号为15C4y1s7LP的视频属性抓取结束
# 开始BV号为1Mg4y1z7fi视频属性的抓取
# BV号为1Mg4y1z7fi的视频属性抓取结束
# 开始BV号为1rp4y117jg视频属性的抓取
# BV号为1rp4y117jg的视频属性抓取结束
# 开始BV号为1qt4y1y7nJ视频属性的抓取
# BV号为1qt4y1y7nJ的视频属性抓取结束
# 开始BV号为1Yk4y1d7tW视频属性的抓取
# BV号为1Yk4y1d7tW的视频属性抓取结束
# 开始BV号为1Xf4y1S7Fy视频属性的抓取
# BV号为1Xf4y1S7Fy的视频属性抓取结束
# 开始BV号为1154y1Q7nR视频属性的抓取
# BV号为1154y1Q7nR的视频属性抓取结束
# 开始BV号为1eK4y1k7ed视频属性的抓取
# BV号为1eK4y1k7ed的视频属性抓取结束
# 开始BV号为1gV411o7XU视频属性的抓取
# BV号为1gV411o7XU的视频属性抓取结束
# 开始BV号为18a4y147Yy视频属性的抓取
# BV号为18a4y147Yy的视频属性抓取结束
# 开始BV号为1Ki4y187JS视频属性的抓取
# BV号为1Ki4y187JS的视频属性抓取结束
# 开始BV号为1At4y1m7id视频属性的抓取
# BV号为1At4y1m7id的视频属性抓取结束
# 开始BV号为1QV411R7Te视频属性的抓取
# BV号为1QV411R7Te的视频属性抓取结束
# 开始BV号为16p4y1C7kZ视频属性的抓取
# BV号为16p4y1C7kZ的视频属性抓取结束
# 开始BV号为1mz411B71N视频属性的抓取
# BV号为1mz411B71N的视频属性抓取结束
# 开始BV号为1BK41177Sh视频属性的抓取
# BV号为1BK41177Sh的视频属性抓取结束
# 开始BV号为1ce411473N视频属性的抓取
# BV号为1ce411473N的视频属性抓取结束
# 开始BV号为1Ug4y1z7N1视频属性的抓取
# BV号为1Ug4y1z7N1的视频属性抓取结束
# 开始BV号为1La4y1478g视频属性的抓取
# BV号为1La4y1478g的视频属性抓取结束
# 开始BV号为1RZ4y1x7K2视频属性的抓取
# BV号为1RZ4y1x7K2的视频属性抓取结束
# 开始BV号为1Qf4y1m7h5视频属性的抓取
# BV号为1Qf4y1m7h5的视频属性抓取结束
# 开始BV号为1ai4y147tX视频属性的抓取
# BV号为1ai4y147tX的视频属性抓取结束
# 开始BV号为1754y1D7Fw视频属性的抓取
# BV号为1754y1D7Fw的视频属性抓取结束
# 开始BV号为1vp4y197mT视频属性的抓取
# BV号为1vp4y197mT的视频属性抓取结束
# 开始BV号为1yk4y1k7Au视频属性的抓取
# BV号为1yk4y1k7Au的视频属性抓取结束
# 开始BV号为17i4y1b721视频属性的抓取
# BV号为17i4y1b721的视频属性抓取结束
# 开始BV号为1j54y1X7rZ视频属性的抓取
# BV号为1j54y1X7rZ的视频属性抓取结束
# 开始BV号为1fZ4y1p7qZ视频属性的抓取
# BV号为1fZ4y1p7qZ的视频属性抓取结束
# 开始BV号为1XK4y1b7iC视频属性的抓取
# BV号为1XK4y1b7iC的视频属性抓取结束
# 开始BV号为1YC4y1W7EC视频属性的抓取
# BV号为1YC4y1W7EC的视频属性抓取结束
# 开始BV号为1Bp4y1Q7YZ视频属性的抓取
# BV号为1Bp4y1Q7YZ的视频属性抓取结束
# 开始BV号为14v411z7Bx视频属性的抓取
# BV号为14v411z7Bx的视频属性抓取结束
# 开始BV号为1re411W7bq视频属性的抓取
# BV号为1re411W7bq的视频属性抓取结束
# 开始BV号为15K4y1871S视频属性的抓取
# BV号为15K4y1871S的视频属性抓取结束
# 开始BV号为1ma4y1i7au视频属性的抓取
# BV号为1ma4y1i7au的视频属性抓取结束
# 开始BV号为1Tz411q7KR视频属性的抓取
# BV号为1Tz411q7KR的视频属性抓取结束
# 开始BV号为16T4y137CD视频属性的抓取
# BV号为16T4y137CD的视频属性抓取结束
# 开始BV号为1kK4y1t7kG视频属性的抓取
# BV号为1kK4y1t7kG的视频属性抓取结束
# 开始BV号为1Et4y1C7ny视频属性的抓取
# BV号为1Et4y1C7ny的视频属性抓取结束
# 开始BV号为1UK4y1b7pc视频属性的抓取
# BV号为1UK4y1b7pc的视频属性抓取结束
# 开始BV号为1dz4y1R73K视频属性的抓取
# BV号为1dz4y1R73K的视频属性抓取结束
# 开始BV号为1JQ4y1P7XH视频属性的抓取
# BV号为1JQ4y1P7XH的视频属性抓取结束
# 开始BV号为11T4y1u7kN视频属性的抓取
# BV号为11T4y1u7kN的视频属性抓取结束
# 开始BV号为1mt4y1C7AD视频属性的抓取
# BV号为1mt4y1C7AD的视频属性抓取结束
# 开始BV号为1Bv411z7zf视频属性的抓取
# BV号为1Bv411z7zf的视频属性抓取结束
# 开始BV号为1rA411t7vu视频属性的抓取
# BV号为1rA411t7vu的视频属性抓取结束
# 开始BV号为1Dz4y1R7Ld视频属性的抓取
# BV号为1Dz4y1R7Ld的视频属性抓取结束
# 开始BV号为16A411t7YY视频属性的抓取
# BV号为16A411t7YY的视频属性抓取结束
# 开始BV号为16e411W7Hu视频属性的抓取
# BV号为16e411W7Hu的视频属性抓取结束
# 开始BV号为1Bz411q79x视频属性的抓取
# BV号为1Bz411q79x的视频属性抓取结束
# 开始BV号为1wK411p75L视频属性的抓取
# BV号为1wK411p75L的视频属性抓取结束
# 开始BV号为12a4y1e7Kf视频属性的抓取
# BV号为12a4y1e7Kf的视频属性抓取结束
# 开始BV号为1Wz4y1d7gz视频属性的抓取
# BV号为1Wz4y1d7gz的视频属性抓取结束
# 开始BV号为19Q4y1A7Df视频属性的抓取
# BV号为19Q4y1A7Df的视频属性抓取结束
# 开始BV号为1Lp4y1Q7fm视频属性的抓取
# BV号为1Lp4y1Q7fm的视频属性抓取结束
# 开始BV号为17f4y1U7PF视频属性的抓取
# BV号为17f4y1U7PF的视频属性抓取结束
# 开始BV号为1FA411q7G3视频属性的抓取
# BV号为1FA411q7G3的视频属性抓取结束
# 开始BV号为19e411p7Wh视频属性的抓取
# BV号为19e411p7Wh的视频属性抓取结束
# 开始BV号为1wf4y127db视频属性的抓取
# BV号为1wf4y127db的视频属性抓取结束
# 开始BV号为1Fz411B7Ca视频属性的抓取
# BV号为1Fz411B7Ca的视频属性抓取结束
# 开始BV号为1KZ4y1s7ZV视频属性的抓取
# BV号为1KZ4y1s7ZV的视频属性抓取结束
# 开始BV号为1Ba4y1i7or视频属性的抓取
# BV号为1Ba4y1i7or的视频属性抓取结束
# 开始BV号为1oK4y147jH视频属性的抓取
# BV号为1oK4y147jH的视频属性抓取结束
# 开始BV号为1Wz4y1d7T5视频属性的抓取
# BV号为1Wz4y1d7T5的视频属性抓取结束
# 开始BV号为1xp4y1Q7LC视频属性的抓取
# BV号为1xp4y1Q7LC的视频属性抓取结束
# 开始BV号为1K5411x7Dq视频属性的抓取
# BV号为1K5411x7Dq的视频属性抓取结束
# 开始BV号为12g4y1B7vo视频属性的抓取
# BV号为12g4y1B7vo的视频属性抓取结束
# 开始BV号为1Kp4y197Kd视频属性的抓取
# BV号为1Kp4y197Kd的视频属性抓取结束
# 开始BV号为1wg4y1B7L1视频属性的抓取
# BV号为1wg4y1B7L1的视频属性抓取结束
# 开始BV号为1AQ4y1P72S视频属性的抓取
# BV号为1AQ4y1P72S的视频属性抓取结束
# 开始BV号为1ei4y1s79p视频属性的抓取
# BV号为1ei4y1s79p的视频属性抓取结束
# 开始BV号为11V411d7ej视频属性的抓取
# BV号为11V411d7ej的视频属性抓取结束
# 开始BV号为16C4y1W7bZ视频属性的抓取
# BV号为16C4y1W7bZ的视频属性抓取结束
# 开始BV号为1Qa4y1i7wg视频属性的抓取
# BV号为1Qa4y1i7wg的视频属性抓取结束
# 开始BV号为1Bp4y1Q7qu视频属性的抓取
# BV号为1Bp4y1Q7qu的视频属性抓取结束
# 开始BV号为1mK4y1b75X视频属性的抓取
# BV号为1mK4y1b75X的视频属性抓取结束
# 开始BV号为1KQ4y1K7Rj视频属性的抓取
# BV号为1KQ4y1K7Rj的视频属性抓取结束
# 开始BV号为1jk4y1k7GT视频属性的抓取
# BV号为1jk4y1k7GT的视频属性抓取结束
# 开始BV号为17Z4y1p7JX视频属性的抓取
# BV号为17Z4y1p7JX的视频属性抓取结束
# 开始BV号为1DK4y1t7o6视频属性的抓取
# BV号为1DK4y1t7o6的视频属性抓取结束
# 开始BV号为19i4y1x79z视频属性的抓取
# BV号为19i4y1x79z的视频属性抓取结束
# 开始BV号为1NA411q77H视频属性的抓取
# BV号为1NA411q77H的视频属性抓取结束
# 开始BV号为1ZA411i7ro视频属性的抓取
# BV号为1ZA411i7ro的视频属性抓取结束
# 开始BV号为1eC4y1W7e9视频属性的抓取
# BV号为1eC4y1W7e9的视频属性抓取结束
# 开始BV号为1gk4y1r7ts视频属性的抓取
# BV号为1gk4y1r7ts的视频属性抓取结束
# 开始BV号为1nK411W7Fr视频属性的抓取
# BV号为1nK411W7Fr的视频属性抓取结束
# 开始BV号为1oa4y1e7PY视频属性的抓取
# BV号为1oa4y1e7PY的视频属性抓取结束
# 开始BV号为1Qt4y1C76z视频属性的抓取
# BV号为1Qt4y1C76z的视频属性抓取结束
# 开始BV号为1xp4y1Q77t视频属性的抓取
# BV号为1xp4y1Q77t的视频属性抓取结束
# 开始BV号为1Wv411z7N5视频属性的抓取
# BV号为1Wv411z7N5的视频属性抓取结束
# 开始BV号为1Tz411B7p6视频属性的抓取
# BV号为1Tz411B7p6的视频属性抓取结束
# 开始BV号为1Ea4y1i7mf视频属性的抓取
# BV号为1Ea4y1i7mf的视频属性抓取结束
# 开始BV号为18K4y1b7M5视频属性的抓取
# BV号为18K4y1b7M5的视频属性抓取结束
# 开始BV号为13V411C7QX视频属性的抓取
# BV号为13V411C7QX的视频属性抓取结束
# 开始BV号为1Kk4y1r7Tv视频属性的抓取
# BV号为1Kk4y1r7Tv的视频属性抓取结束
# 开始BV号为1VT4y1g7Ua视频属性的抓取
# BV号为1VT4y1g7Ua的视频属性抓取结束
# 开始BV号为1kK411W7rd视频属性的抓取
# BV号为1kK411W7rd的视频属性抓取结束
# 开始BV号为1We411p7NY视频属性的抓取
# BV号为1We411p7NY的视频属性抓取结束
# 开始BV号为1oi4y1x7mj视频属性的抓取
# BV号为1oi4y1x7mj的视频属性抓取结束
# 开始BV号为1bQ4y1A7tG视频属性的抓取
# BV号为1bQ4y1A7tG的视频属性抓取结束
# 开始BV号为1Hk4y1r7Lr视频属性的抓取
# BV号为1Hk4y1r7Lr的视频属性抓取结束
# 开始BV号为1bT4y1u7nC视频属性的抓取
# BV号为1bT4y1u7nC的视频属性抓取结束
# 开始BV号为1LA411q7Kf视频属性的抓取
# BV号为1LA411q7Kf的视频属性抓取结束
# 开始BV号为1kT4y1u7am视频属性的抓取
# BV号为1kT4y1u7am的视频属性抓取结束
# 开始BV号为1YV411C7zh视频属性的抓取
# BV号为1YV411C7zh的视频属性抓取结束
# 开始BV号为165411s7hQ视频属性的抓取
# BV号为165411s7hQ的视频属性抓取结束
# 开始BV号为1pA411q7Bh视频属性的抓取
# BV号为1pA411q7Bh的视频属性抓取结束
# 开始BV号为1RA411i7Ci视频属性的抓取
# BV号为1RA411i7Ci的视频属性抓取结束
# 开始BV号为1oT4y1g7rx视频属性的抓取
# BV号为1oT4y1g7rx的视频属性抓取结束
# 开始BV号为1uA411t7Zg视频属性的抓取
# BV号为1uA411t7Zg的视频属性抓取结束
# 开始BV号为1At4y1m7nm视频属性的抓取
# BV号为1At4y1m7nm的视频属性抓取结束
# 开始BV号为1p5411s7zh视频属性的抓取
# BV号为1p5411s7zh的视频属性抓取结束
# 开始BV号为1CK411W78N视频属性的抓取
# BV号为1CK411W78N的视频属性抓取结束
# 开始BV号为1AT4y1g7e2视频属性的抓取
# BV号为1AT4y1g7e2的视频属性抓取结束
# 开始BV号为1AQ4y1P7a1视频属性的抓取
# BV号为1AQ4y1P7a1的视频属性抓取结束
# 开始BV号为1kZ4y1p7xA视频属性的抓取
# BV号为1kZ4y1p7xA的视频属性抓取结束
# 开始BV号为1XZ4y1p749视频属性的抓取
# BV号为1XZ4y1p749的视频属性抓取结束
# 开始BV号为1iK4y1t726视频属性的抓取
# BV号为1iK4y1t726的视频属性抓取结束
# 开始BV号为1Df4y1S78e视频属性的抓取
# BV号为1Df4y1S78e的视频属性抓取结束
# 开始BV号为1Xf4y1y7Bz视频属性的抓取
# BV号为1Xf4y1y7Bz的视频属性抓取结束
# 开始BV号为1P54y1z7sj视频属性的抓取
# BV号为1P54y1z7sj的视频属性抓取结束
# 开始BV号为1Ez411v7KR视频属性的抓取
# BV号为1Ez411v7KR的视频属性抓取结束
# 开始BV号为1Qi4y1G7ao视频属性的抓取
# BV号为1Qi4y1G7ao的视频属性抓取结束
# 开始BV号为11f4y1y7Ry视频属性的抓取
# BV号为11f4y1y7Ry的视频属性抓取结束
# 开始BV号为1Ep4y1D7Eq视频属性的抓取
# BV号为1Ep4y1D7Eq的视频属性抓取结束
# 开始BV号为19z4y1Q7HW视频属性的抓取
# BV号为19z4y1Q7HW的视频属性抓取结束
# 开始BV号为1Ct4y1975Y视频属性的抓取
# BV号为1Ct4y1975Y的视频属性抓取结束
# 开始BV号为1NV41167gz视频属性的抓取
# BV号为1NV41167gz的视频属性抓取结束
# 开始BV号为1Et4y1y7GV视频属性的抓取
# BV号为1Et4y1y7GV的视频属性抓取结束
# 开始BV号为1Rg4y1i7eX视频属性的抓取
# BV号为1Rg4y1i7eX的视频属性抓取结束
# 开始BV号为14k4y1q7nY视频属性的抓取
# BV号为14k4y1q7nY的视频属性抓取结束
# 开始BV号为19z411e7k1视频属性的抓取
# BV号为19z411e7k1的视频属性抓取结束
# 开始BV号为16T4y1E7s2视频属性的抓取
# BV号为16T4y1E7s2的视频属性抓取结束
# 开始BV号为1Az411i7Ny视频属性的抓取
# BV号为1Az411i7Ny的视频属性抓取结束
# 开始BV号为1Wk4y1z7sT视频属性的抓取
# BV号为1Wk4y1z7sT的视频属性抓取结束
# 开始BV号为1fZ4y1n7ks视频属性的抓取
# BV号为1fZ4y1n7ks的视频属性抓取结束
# 开始BV号为1nt4y197gg视频属性的抓取
# BV号为1nt4y197gg的视频属性抓取结束
# 开始BV号为1ki4y1G7FH视频属性的抓取
# BV号为1ki4y1G7FH的视频属性抓取结束
# 开始BV号为1Uz4y197LT视频属性的抓取
# BV号为1Uz4y197LT的视频属性抓取结束
# 开始BV号为1oz4y197cu视频属性的抓取
# BV号为1oz4y197cu的视频属性抓取结束
# 开始BV号为1jt4y197PN视频属性的抓取
# BV号为1jt4y197PN的视频属性抓取结束
# 开始BV号为1Pf4y117mr视频属性的抓取
# BV号为1Pf4y117mr的视频属性抓取结束
# 开始BV号为1av411B75N视频属性的抓取
# BV号为1av411B75N的视频属性抓取结束
# 开始BV号为1tv411675J视频属性的抓取
# BV号为1tv411675J的视频属性抓取结束
# 开始BV号为1Sv411B7Kh视频属性的抓取
# BV号为1Sv411B7Kh的视频属性抓取结束
# 开始BV号为1TZ4y1H7Bh视频属性的抓取
# BV号为1TZ4y1H7Bh的视频属性抓取结束
# 开始BV号为1NV411k784视频属性的抓取
# BV号为1NV411k784的视频属性抓取结束
# 开始BV号为1Fz411q7tm视频属性的抓取
# BV号为1Fz411q7tm的视频属性抓取结束
# 开始BV号为1KK411H7M2视频属性的抓取
# BV号为1KK411H7M2的视频属性抓取结束
# 开始BV号为1Bz411e7BF视频属性的抓取
# BV号为1Bz411e7BF的视频属性抓取结束
# 开始BV号为1sT4y177Up视频属性的抓取
# BV号为1sT4y177Up的视频属性抓取结束
# 开始BV号为1Z5411p7oz视频属性的抓取
# BV号为1Z5411p7oz的视频属性抓取结束
# 开始BV号为1qz4y1978R视频属性的抓取
# BV号为1qz4y1978R的视频属性抓取结束
# 开始BV号为1TK4y1b7DR视频属性的抓取
# BV号为1TK4y1b7DR的视频属性抓取结束
# 开始BV号为1Rz4y1Q7W6视频属性的抓取
# BV号为1Rz4y1Q7W6的视频属性抓取结束
# 开始BV号为1fZ4y1H7dT视频属性的抓取
# BV号为1fZ4y1H7dT的视频属性抓取结束
# 开始BV号为1fz4y1976A视频属性的抓取
# BV号为1fz4y1976A的视频属性抓取结束
# 开始BV号为1Tz411i7iP视频属性的抓取
# BV号为1Tz411i7iP的视频属性抓取结束
# 开始BV号为1Up4y1D7Ms视频属性的抓取
# BV号为1Up4y1D7Ms的视频属性抓取结束
# 开始BV号为1KA411i7rC视频属性的抓取
# BV号为1KA411i7rC的视频属性抓取结束
# 开始BV号为1qz4y1Q73G视频属性的抓取
# BV号为1qz4y1Q73G的视频属性抓取结束
# 开始BV号为1NZ4y1H73N视频属性的抓取
# BV号为1NZ4y1H73N的视频属性抓取结束
# 开始BV号为1UZ4y1H7s9视频属性的抓取
# BV号为1UZ4y1H7s9的视频属性抓取结束
# 开始BV号为12a4y1Y72u视频属性的抓取
# BV号为12a4y1Y72u的视频属性抓取结束
# 开始BV号为1EK4y1s77N视频属性的抓取
# BV号为1EK4y1s77N的视频属性抓取结束
# 开始BV号为1KZ4y1H7ys视频属性的抓取
# BV号为1KZ4y1H7ys的视频属性抓取结束
# 开始BV号为1m5411W7CD视频属性的抓取
# BV号为1m5411W7CD的视频属性抓取结束
# 开始BV号为1ZC4y1a74w视频属性的抓取
# BV号为1ZC4y1a74w的视频属性抓取结束
# 开始BV号为1uf4y117eA视频属性的抓取
# BV号为1uf4y117eA的视频属性抓取结束
# 开始BV号为1LT4y177zF视频属性的抓取
# BV号为1LT4y177zF的视频属性抓取结束
# 开始BV号为16t4y197i1视频属性的抓取
# BV号为16t4y197i1的视频属性抓取结束
# 开始BV号为1pz411i7ea视频属性的抓取
# BV号为1pz411i7ea的视频属性抓取结束
# 开始BV号为1Mz4y1R7om视频属性的抓取
# BV号为1Mz4y1R7om的视频属性抓取结束
# 开始BV号为1oK4y1t71f视频属性的抓取
# BV号为1oK4y1t71f的视频属性抓取结束
# 开始BV号为1pV411k7GX视频属性的抓取
# BV号为1pV411k7GX的视频属性抓取结束
# 开始BV号为1xz4y1X76Q视频属性的抓取
# BV号为1xz4y1X76Q的视频属性抓取结束
# 开始BV号为11k4y1q7wp视频属性的抓取
# BV号为11k4y1q7wp的视频属性抓取结束
# 开始BV号为1uz411i75V视频属性的抓取
# BV号为1uz411i75V的视频属性抓取结束
# 开始BV号为1eT4y177oo视频属性的抓取
# BV号为1eT4y177oo的视频属性抓取结束
# 开始BV号为1TD4y1Q7Dw视频属性的抓取
# BV号为1TD4y1Q7Dw的视频属性抓取结束
# 开始BV号为1GT4y1J7E4视频属性的抓取
# BV号为1GT4y1J7E4的视频属性抓取结束
# 开始BV号为1ZA411v7Ct视频属性的抓取
# BV号为1ZA411v7Ct的视频属性抓取结束
# 开始BV号为1tK4y147o3视频属性的抓取
# BV号为1tK4y147o3的视频属性抓取结束
# 开始BV号为1KV411k7yZ视频属性的抓取
# BV号为1KV411k7yZ的视频属性抓取结束
# 开始BV号为1AK411H7bm视频属性的抓取
# BV号为1AK411H7bm的视频属性抓取结束
# 开始BV号为15f4y117Ej视频属性的抓取
# BV号为15f4y117Ej的视频属性抓取结束
# 开始BV号为17v41167nA视频属性的抓取
# BV号为17v41167nA的视频属性抓取结束
# 开始BV号为1yp4y1U7bo视频属性的抓取
# BV号为1yp4y1U7bo的视频属性抓取结束
# 开始BV号为1ek4y1q7UK视频属性的抓取
# BV号为1ek4y1q7UK的视频属性抓取结束
# 开始BV号为1dg4y1i7Re视频属性的抓取
# BV号为1dg4y1i7Re的视频属性抓取结束
# 开始BV号为1Zp4y1D7XW视频属性的抓取
# BV号为1Zp4y1D7XW的视频属性抓取结束
# 开始BV号为1Rg4y1i7Rd视频属性的抓取
# BV号为1Rg4y1i7Rd的视频属性抓取结束
# 开始BV号为1oK411p71w视频属性的抓取
# BV号为1oK411p71w的视频属性抓取结束
# 开始BV号为13z4y1X7ip视频属性的抓取
# BV号为13z4y1X7ip的视频属性抓取结束
# 开始BV号为16z4y197bM视频属性的抓取
# BV号为16z4y197bM的视频属性抓取结束
# 开始BV号为1nC4y1a7gL视频属性的抓取
# BV号为1nC4y1a7gL的视频属性抓取结束
# 开始BV号为1MK411p7d8视频属性的抓取
# BV号为1MK411p7d8的视频属性抓取结束
# 开始BV号为1Fz411i7hW视频属性的抓取
# BV号为1Fz411i7hW的视频属性抓取结束
# 开始BV号为1qK4y1x7Wq视频属性的抓取
# BV号为1qK4y1x7Wq的视频属性抓取结束
# 开始BV号为1S5411p75y视频属性的抓取
# BV号为1S5411p75y的视频属性抓取结束
# 开始BV号为1Ki4y1x75j视频属性的抓取
# BV号为1Ki4y1x75j的视频属性抓取结束
# 开始BV号为1ei4y1x7ix视频属性的抓取
# BV号为1ei4y1x7ix的视频属性抓取结束
# 开始BV号为1mv411z7pi视频属性的抓取
# BV号为1mv411z7pi的视频属性抓取结束
# 开始BV号为1Yv41167Fx视频属性的抓取
# BV号为1Yv41167Fx的视频属性抓取结束
# 开始BV号为1hK411p7vX视频属性的抓取
# BV号为1hK411p7vX的视频属性抓取结束
# 开始BV号为1Pk4y1z7Ar视频属性的抓取
# BV号为1Pk4y1z7Ar的视频属性抓取结束
# 开始BV号为1fC4y1h7We视频属性的抓取
# BV号为1fC4y1h7We的视频属性抓取结束
# 开始BV号为13D4y1Q75b视频属性的抓取
# BV号为13D4y1Q75b的视频属性抓取结束
# 开始BV号为1Kv411B7tj视频属性的抓取
# BV号为1Kv411B7tj的视频属性抓取结束
# 开始BV号为1n5411W7A7视频属性的抓取
# BV号为1n5411W7A7的视频属性抓取结束
# 开始BV号为1hz4y197vF视频属性的抓取
# BV号为1hz4y197vF的视频属性抓取结束
# 开始BV号为1Fv411z7S4视频属性的抓取
# BV号为1Fv411z7S4的视频属性抓取结束
# 开始BV号为1cC4y1a7XY视频属性的抓取
# 开始BV号为1cC4y1a7XY视频属性的抓取
# BV号为1cC4y1a7XY的视频属性抓取结束
# 开始BV号为1Vp4y1D7vc视频属性的抓取
# BV号为1Vp4y1D7vc的视频属性抓取结束
# 开始BV号为1aZ4y1W7jY视频属性的抓取
# BV号为1aZ4y1W7jY的视频属性抓取结束
# 开始BV号为11t4y1X7gh视频属性的抓取
# BV号为11t4y1X7gh的视频属性抓取结束
# 开始BV号为1bZ4y1W7Df视频属性的抓取
# BV号为1bZ4y1W7Df的视频属性抓取结束
# 开始BV号为1ni4y1G7ub视频属性的抓取
# BV号为1ni4y1G7ub的视频属性抓取结束
# 开始BV号为1ok4y1z7B2视频属性的抓取
# BV号为1ok4y1z7B2的视频属性抓取结束
# 开始BV号为1GA411e7UM视频属性的抓取
# BV号为1GA411e7UM的视频属性抓取结束
# 开始BV号为1n5411Y7E9视频属性的抓取
# BV号为1n5411Y7E9的视频属性抓取结束
# 开始BV号为17A411i7fw视频属性的抓取
# BV号为17A411i7fw的视频属性抓取结束
# 开始BV号为1fC4y187GE视频属性的抓取
# BV号为1fC4y187GE的视频属性抓取结束
# 开始BV号为1w54y1S7Df视频属性的抓取
# BV号为1w54y1S7Df的视频属性抓取结束
# 开始BV号为1Ct4y1Q7s4视频属性的抓取
# BV号为1Ct4y1Q7s4的视频属性抓取结束
# 开始BV号为1vk4y1q7d3视频属性的抓取
# BV号为1vk4y1q7d3的视频属性抓取结束
# 开始BV号为15h411Z7PP视频属性的抓取
# BV号为15h411Z7PP的视频属性抓取结束
# 开始BV号为1Yz4y1X7k4视频属性的抓取
# BV号为1Yz4y1X7k4的视频属性抓取结束
# 开始BV号为1tC4y1h72D视频属性的抓取
# BV号为1tC4y1h72D的视频属性抓取结束
# 开始BV号为15D4y1S7fB视频属性的抓取
# BV号为15D4y1S7fB的视频属性抓取结束
# 开始BV号为1yt4y197Qn视频属性的抓取
# BV号为1yt4y197Qn的视频属性抓取结束
# 开始BV号为1BV41167Sm视频属性的抓取
# BV号为1BV41167Sm的视频属性抓取结束
# 开始BV号为1554y1S7kU视频属性的抓取
# BV号为1554y1S7kU的视频属性抓取结束
# 开始BV号为1T5411a7Wv视频属性的抓取
# BV号为1T5411a7Wv的视频属性抓取结束
# 开始BV号为1YC4y187z7视频属性的抓取
# BV号为1YC4y187z7的视频属性抓取结束
# 开始BV号为1FD4y1D7Mp视频属性的抓取
# BV号为1FD4y1D7Mp的视频属性抓取结束
# 开始BV号为1sD4y1Q7b4视频属性的抓取
# BV号为1sD4y1Q7b4的视频属性抓取结束
# 开始BV号为1Nf4y117tS视频属性的抓取
# BV号为1Nf4y117tS的视频属性抓取结束
# 开始BV号为1qf4y1X7NG视频属性的抓取
# BV号为1qf4y1X7NG的视频属性抓取结束
# 开始BV号为1A54y1i7F9视频属性的抓取
# BV号为1A54y1i7F9的视频属性抓取结束
# 开始BV号为13p4y1S7mZ视频属性的抓取
# BV号为13p4y1S7mZ的视频属性抓取结束
# 开始BV号为1E5411e777视频属性的抓取
# BV号为1E5411e777的视频属性抓取结束
# 开始BV号为1j5411a7rV视频属性的抓取
# BV号为1j5411a7rV的视频属性抓取结束
# 开始BV号为1ep4y1U76A视频属性的抓取
# BV号为1ep4y1U76A的视频属性抓取结束
# 开始BV号为1Kg4y1v7Bo视频属性的抓取
# BV号为1Kg4y1v7Bo的视频属性抓取结束
# 开始BV号为1cA411v7Ew视频属性的抓取
# BV号为1cA411v7Ew的视频属性抓取结束
# 开始BV号为1xf4y1R7VR视频属性的抓取
# BV号为1xf4y1R7VR的视频属性抓取结束
# 开始BV号为1AT4y1E7dP视频属性的抓取
# BV号为1AT4y1E7dP的视频属性抓取结束
# 开始BV号为1ra4y1a7a6视频属性的抓取
# BV号为1ra4y1a7a6的视频属性抓取结束
# 开始BV号为1P54y1B7Li视频属性的抓取
# BV号为1P54y1B7Li的视频属性抓取结束
# 开始BV号为1M5411Y77Z视频属性的抓取
# BV号为1M5411Y77Z的视频属性抓取结束
# 开始BV号为1Ez4y1D7N9视频属性的抓取
# BV号为1Ez4y1D7N9的视频属性抓取结束
# 开始BV号为1EK411n7if视频属性的抓取
# BV号为1EK411n7if的视频属性抓取结束
# 开始BV号为1SZ4y1M751视频属性的抓取
# BV号为1SZ4y1M751的视频属性抓取结束
# 开始BV号为1hK4y1x7jY视频属性的抓取
# BV号为1hK4y1x7jY的视频属性抓取结束
# 开始BV号为1Li4y1V7H5视频属性的抓取
# BV号为1Li4y1V7H5的视频属性抓取结束
# 开始BV号为17A411v7nu视频属性的抓取
# BV号为17A411v7nu的视频属性抓取结束
# 开始BV号为1XK4y1s7EV视频属性的抓取
# BV号为1XK4y1s7EV的视频属性抓取结束
# 开始BV号为1VA411v7Rk视频属性的抓取
# BV号为1VA411v7Rk的视频属性抓取结束
# 开始BV号为1xA411e7dG视频属性的抓取
# BV号为1xA411e7dG的视频属性抓取结束
# 开始BV号为1Yh411o7ym视频属性的抓取
# BV号为1Yh411o7ym的视频属性抓取结束
# 开始BV号为1Da4y1a7Xo视频属性的抓取
# BV号为1Da4y1a7Xo的视频属性抓取结束
# 开始BV号为1Xv411i78K视频属性的抓取
# BV号为1Xv411i78K的视频属性抓取结束
# 开始BV号为1354y1z7mL视频属性的抓取
# BV号为1354y1z7mL的视频属性抓取结束
# 开始BV号为1TD4y1S7Zc视频属性的抓取
# BV号为1TD4y1S7Zc的视频属性抓取结束
# 开始BV号为13D4y1S7Tz视频属性的抓取
# BV号为13D4y1S7Tz的视频属性抓取结束
# 开始BV号为1qk4y1m7WF视频属性的抓取
# BV号为1qk4y1m7WF的视频属性抓取结束
# 开始BV号为1ph411o7dN视频属性的抓取
# BV号为1ph411o7dN的视频属性抓取结束
# 开始BV号为1tk4y1B7Bq视频属性的抓取
# BV号为1tk4y1B7Bq的视频属性抓取结束
# 开始BV号为1RD4y1S7Si视频属性的抓取
# BV号为1RD4y1S7Si的视频属性抓取结束
# 开始BV号为1jf4y1R7UK视频属性的抓取
# BV号为1jf4y1R7UK的视频属性抓取结束
# 开始BV号为1f54y1v7vU视频属性的抓取
# BV号为1f54y1v7vU的视频属性抓取结束
# 开始BV号为14p4y1q7Sh视频属性的抓取
# BV号为14p4y1q7Sh的视频属性抓取结束
# 开始BV号为1bZ4y1u76K视频属性的抓取
# BV号为1bZ4y1u76K的视频属性抓取结束
# 开始BV号为1eZ4y1u7L4视频属性的抓取
# BV号为1eZ4y1u7L4的视频属性抓取结束
# 开始BV号为1mz411e7P4视频属性的抓取
# BV号为1mz411e7P4的视频属性抓取结束
# 开始BV号为1xv411q7CS视频属性的抓取
# BV号为1xv411q7CS的视频属性抓取结束
# 开始BV号为1w5411e7NA视频属性的抓取
# BV号为1w5411e7NA的视频属性抓取结束
# 开始BV号为1ev411B7dn视频属性的抓取
# BV号为1ev411B7dn的视频属性抓取结束
# 开始BV号为1Ph411Z7f2视频属性的抓取
# BV号为1Ph411Z7f2的视频属性抓取结束
# 开始BV号为1Qp4y1i74K视频属性的抓取
# BV号为1Qp4y1i74K的视频属性抓取结束
# 开始BV号为1Vv411q7uX视频属性的抓取
# BV号为1Vv411q7uX的视频属性抓取结束
# 开始BV号为1qp4y1S7Ww视频属性的抓取
# BV号为1qp4y1S7Ww的视频属性抓取结束
# 开始BV号为1RT4y1j7H8视频属性的抓取
# BV号为1RT4y1j7H8的视频属性抓取结束
# 开始BV号为1Dz411e7Wo视频属性的抓取
# BV号为1Dz411e7Wo的视频属性抓取结束
# 开始BV号为1ya4y1a7K8视频属性的抓取
# BV号为1ya4y1a7K8的视频属性抓取结束
# 开始BV号为1ph411o76Y视频属性的抓取
# BV号为1ph411o76Y的视频属性抓取结束
# 开始BV号为1Ci4y137x3视频属性的抓取
# BV号为1Ci4y137x3的视频属性抓取结束
# 开始BV号为1vk4y1B7f3视频属性的抓取
# BV号为1vk4y1B7f3的视频属性抓取结束
# 开始BV号为1nT4y1777G视频属性的抓取
# BV号为1nT4y1777G的视频属性抓取结束
# 开始BV号为1mK4y1s7qi视频属性的抓取
# BV号为1mK4y1s7qi的视频属性抓取结束
# 开始BV号为1W54y1q7oG视频属性的抓取
# BV号为1W54y1q7oG的视频属性抓取结束
# 开始BV号为1sV411k7XF视频属性的抓取
# BV号为1sV411k7XF的视频属性抓取结束
# 开始BV号为1ot4y1Q7sF视频属性的抓取
# BV号为1ot4y1Q7sF的视频属性抓取结束
# 开始BV号为1rp4y1i75R视频属性的抓取
# BV号为1rp4y1i75R的视频属性抓取结束
# 开始BV号为115411Y7cN视频属性的抓取
# BV号为115411Y7cN的视频属性抓取结束
# 开始BV号为1Gi4y1V739视频属性的抓取
# BV号为1Gi4y1V739的视频属性抓取结束
# 开始BV号为1Lv411z7PW视频属性的抓取
# BV号为1Lv411z7PW的视频属性抓取结束
# 开始BV号为1tA411i76b视频属性的抓取
# BV号为1tA411i76b的视频属性抓取结束
# 开始BV号为16K411H7Tq视频属性的抓取
# BV号为16K411H7Tq的视频属性抓取结束
# 开始BV号为1YT4y1E7mN视频属性的抓取
# BV号为1YT4y1E7mN的视频属性抓取结束
# 开始BV号为1ED4y1S7DA视频属性的抓取
# BV号为1ED4y1S7DA的视频属性抓取结束
# 开始BV号为11D4y1S7GF视频属性的抓取
# BV号为11D4y1S7GF的视频属性抓取结束
# 开始BV号为1WK4y1s7Rj视频属性的抓取
# BV号为1WK4y1s7Rj的视频属性抓取结束
# 开始BV号为19g4y1v7qr视频属性的抓取
# BV号为19g4y1v7qr的视频属性抓取结束
# 开始BV号为1Ev411B7hV视频属性的抓取
# BV号为1Ev411B7hV的视频属性抓取结束
# 开始BV号为1mp4y1i7Lu视频属性的抓取
# BV号为1mp4y1i7Lu的视频属性抓取结束
# 开始BV号为1ia4y1a7x4视频属性的抓取
# BV号为1ia4y1a7x4的视频属性抓取结束
# 开始BV号为1TK4y1x7y2视频属性的抓取
# BV号为1TK4y1x7y2的视频属性抓取结束
# 开始BV号为1fh411R79j视频属性的抓取
# BV号为1fh411R79j的视频属性抓取结束
# 开始BV号为1cp4y1S79A视频属性的抓取
# BV号为1cp4y1S79A的视频属性抓取结束
# 开始BV号为1rg4y1v78h视频属性的抓取
# BV号为1rg4y1v78h的视频属性抓取结束
# 开始BV号为1eC4y1h7Ln视频属性的抓取
# BV号为1eC4y1h7Ln的视频属性抓取结束
# 开始BV号为1AZ4y1p7Hx视频属性的抓取
# BV号为1AZ4y1p7Hx的视频属性抓取结束
# 开始BV号为1QK4y147Ff视频属性的抓取
# BV号为1QK4y147Ff的视频属性抓取结束
# 开始BV号为1TT4y1E7ct视频属性的抓取
# BV号为1TT4y1E7ct的视频属性抓取结束
# 开始BV号为17g4y1v74R视频属性的抓取
# BV号为17g4y1v74R的视频属性抓取结束
# 开始BV号为1d54y1v7cq视频属性的抓取
# BV号为1d54y1v7cq的视频属性抓取结束
# 开始BV号为15t4y1D7ZJ视频属性的抓取
# BV号为15t4y1D7ZJ的视频属性抓取结束
# 开始BV号为13k4y127C4视频属性的抓取
# BV号为13k4y127C4的视频属性抓取结束
# 开始BV号为1dK411N7iL视频属性的抓取
# BV号为1dK411N7iL的视频属性抓取结束
# 开始BV号为1Vf4y1X7XF视频属性的抓取
# BV号为1Vf4y1X7XF的视频属性抓取结束
# 开始BV号为1iA411Y7Ka视频属性的抓取
# BV号为1iA411Y7Ka的视频属性抓取结束
# 开始BV号为1Ct4y1U7FT视频属性的抓取
# BV号为1Ct4y1U7FT的视频属性抓取结束
# 开始BV号为1xD4y127kj视频属性的抓取
# BV号为1xD4y127kj的视频属性抓取结束
# 开始BV号为1Dt4y1U7Yv视频属性的抓取
# BV号为1Dt4y1U7Yv的视频属性抓取结束
# 开始BV号为1Qt4y1D7EL视频属性的抓取
# BV号为1Qt4y1D7EL的视频属性抓取结束
# 开始BV号为14t4y1D7b8视频属性的抓取
# BV号为14t4y1D7b8的视频属性抓取结束
# 开始BV号为1CV411U7LD视频属性的抓取
# BV号为1CV411U7LD的视频属性抓取结束
# 开始BV号为1Pp4y1i7A6视频属性的抓取
# BV号为1Pp4y1i7A6的视频属性抓取结束
# 开始BV号为1C54y1U76V视频属性的抓取
# BV号为1C54y1U76V的视频属性抓取结束
# 开始BV号为1DD4y1d7LJ视频属性的抓取
# BV号为1DD4y1d7LJ的视频属性抓取结束
# 开始BV号为1fK411N7Jh视频属性的抓取
# BV号为1fK411N7Jh的视频属性抓取结束
# 开始BV号为1bK411T79E视频属性的抓取
# BV号为1bK411T79E的视频属性抓取结束
# 开始BV号为1nk4y1m7i6视频属性的抓取
# BV号为1nk4y1m7i6的视频属性抓取结束
# 开始BV号为1up4y1i7tW视频属性的抓取
# BV号为1up4y1i7tW的视频属性抓取结束
# 开始BV号为15A411n7WV视频属性的抓取
# BV号为15A411n7WV的视频属性抓取结束
# 开始BV号为17K4y1v7J3视频属性的抓取
# BV号为17K4y1v7J3的视频属性抓取结束
# 开始BV号为13C4y1t7zn视频属性的抓取
# BV号为13C4y1t7zn的视频属性抓取结束
# 开始BV号为1s54y1e7sN视频属性的抓取
# BV号为1s54y1e7sN的视频属性抓取结束
# 开始BV号为1SA411Y7Aq视频属性的抓取
# BV号为1SA411Y7Aq的视频属性抓取结束
# 开始BV号为1oK411J74W视频属性的抓取
# BV号为1oK411J74W的视频属性抓取结束
# 开始BV号为1mA411Y7hJ视频属性的抓取
# BV号为1mA411Y7hJ的视频属性抓取结束
# 开始BV号为1pa4y1J7rb视频属性的抓取
# BV号为1pa4y1J7rb的视频属性抓取结束
# 开始BV号为1kK411T7Qp视频属性的抓取
# BV号为1kK411T7Qp的视频属性抓取结束
# 开始BV号为1TC4y1877L视频属性的抓取
# BV号为1TC4y1877L的视频属性抓取结束
# 开始BV号为1nC4y1t7dd视频属性的抓取
# BV号为1nC4y1t7dd的视频属性抓取结束
# 开始BV号为1vA411Y7tc视频属性的抓取
# BV号为1vA411Y7tc的视频属性抓取结束
# 开始BV号为1Mv411i71A视频属性的抓取
# BV号为1Mv411i71A的视频属性抓取结束
# 开始BV号为1HK4y1e78f视频属性的抓取
# BV号为1HK4y1e78f的视频属性抓取结束
# 开始BV号为1vA411Y7ru视频属性的抓取
# BV号为1vA411Y7ru的视频属性抓取结束
# 开始BV号为1Uv411q72v视频属性的抓取
# BV号为1Uv411q72v的视频属性抓取结束
# 开始BV号为14k4y127aa视频属性的抓取
# BV号为14k4y127aa的视频属性抓取结束
# 开始BV号为1LK4y1v7bT视频属性的抓取
# BV号为1LK4y1v7bT的视频属性抓取结束
# 开始BV号为13k4y1y7iZ视频属性的抓取
# BV号为13k4y1y7iZ的视频属性抓取结束
# 开始BV号为1bp4y1v7hs视频属性的抓取
# BV号为1bp4y1v7hs的视频属性抓取结束
# 开始BV号为1q54y1i72D视频属性的抓取
# BV号为1q54y1i72D的视频属性抓取结束
# 开始BV号为1BT4y1L7rd视频属性的抓取
# BV号为1BT4y1L7rd的视频属性抓取结束
# 开始BV号为1cK411M7m4视频属性的抓取
# BV号为1cK411M7m4的视频属性抓取结束
# 开始BV号为1ra4y1J7YC视频属性的抓取
# BV号为1ra4y1J7YC的视频属性抓取结束
# 开始BV号为1ZK411T7JQ视频属性的抓取
# BV号为1ZK411T7JQ的视频属性抓取结束
# 开始BV号为1Yh411d7bD视频属性的抓取
# BV号为1Yh411d7bD的视频属性抓取结束
# 开始BV号为1ky4y1C78D视频属性的抓取
# BV号为1ky4y1C78D的视频属性抓取结束
# 开始BV号为1Vt4y1D7LZ视频属性的抓取
# BV号为1Vt4y1D7LZ的视频属性抓取结束
# 开始BV号为1XZ4y1K7Nr视频属性的抓取
# BV号为1XZ4y1K7Nr的视频属性抓取结束
# 开始BV号为1LK411K7JZ视频属性的抓取
# BV号为1LK411K7JZ的视频属性抓取结束
# 开始BV号为1Lh411o7SD视频属性的抓取
# BV号为1Lh411o7SD的视频属性抓取结束
# 开始BV号为1u64y1c7VG视频属性的抓取
# BV号为1u64y1c7VG的视频属性抓取结束
# 开始BV号为1mC4y147b5视频属性的抓取
# BV号为1mC4y147b5的视频属性抓取结束
# 开始BV号为1V54y1i7Gn视频属性的抓取
# BV号为1V54y1i7Gn的视频属性抓取结束
# 开始BV号为1tv41117LB视频属性的抓取
# BV号为1tv41117LB的视频属性抓取结束
# 开始BV号为1EZ4y1M7zk视频属性的抓取
# BV号为1EZ4y1M7zk的视频属性抓取结束
# 开始BV号为12y4y1C7hT视频属性的抓取
# BV号为12y4y1C7hT的视频属性抓取结束
# 开始BV号为1Lp4y1i7bU视频属性的抓取
# BV号为1Lp4y1i7bU的视频属性抓取结束
# 开始BV号为1CV411U7AT视频属性的抓取
# BV号为1CV411U7AT的视频属性抓取结束
# 开始BV号为1mi4y1g7DU视频属性的抓取
# BV号为1mi4y1g7DU的视频属性抓取结束
# 开始BV号为1v64y1c79G视频属性的抓取
# BV号为1v64y1c79G的视频属性抓取结束
# 开始BV号为12t4y1D7Ap视频属性的抓取
# BV号为12t4y1D7Ap的视频属性抓取结束
# 开始BV号为1Ha4y1J7wp视频属性的抓取
# BV号为1Ha4y1J7wp的视频属性抓取结束
# 开始BV号为1aT4y1w7NY视频属性的抓取
# BV号为1aT4y1w7NY的视频属性抓取结束
# 开始BV号为1X54y1m7hJ视频属性的抓取
# BV号为1X54y1m7hJ的视频属性抓取结束
# 开始BV号为1FK411M7cg视频属性的抓取
# BV号为1FK411M7cg的视频属性抓取结束
# 开始BV号为1Zi4y1M7pF视频属性的抓取
# BV号为1Zi4y1M7pF的视频属性抓取结束
# 开始BV号为1dk4y117za视频属性的抓取
# BV号为1dk4y117za的视频属性抓取结束
# 开始BV号为19k4y1m7ww视频属性的抓取
# BV号为19k4y1m7ww的视频属性抓取结束
# 开始BV号为1kK411N7ev视频属性的抓取
# BV号为1kK411N7ev的视频属性抓取结束
# 开始BV号为1wZ4y1T72H视频属性的抓取
# BV号为1wZ4y1T72H的视频属性抓取结束
# 开始BV号为1ZC4y147Kq视频属性的抓取
# BV号为1ZC4y147Kq的视频属性抓取结束
# 开始BV号为1yz4y1f7vt视频属性的抓取
# BV号为1yz4y1f7vt的视频属性抓取结束
# 开始BV号为1cp4y1e7H1视频属性的抓取
# BV号为1cp4y1e7H1的视频属性抓取结束
# 开始BV号为1Yp4y1q78N视频属性的抓取
# BV号为1Yp4y1q78N的视频属性抓取结束
# 开始BV号为1gk4y127xC视频属性的抓取
# BV号为1gk4y127xC的视频属性抓取结束
# 开始BV号为1fa4y177u4视频属性的抓取
# BV号为1fa4y177u4的视频属性抓取结束
# 开始BV号为1jt4y1Q7vR视频属性的抓取
# BV号为1jt4y1Q7vR的视频属性抓取结束
# 开始BV号为1QZ4y1K7kA视频属性的抓取
# BV号为1QZ4y1K7kA的视频属性抓取结束
# 开始BV号为1E5411b74i视频属性的抓取
# BV号为1E5411b74i的视频属性抓取结束
# 开始BV号为1UC4y1b7Ni视频属性的抓取
# BV号为1UC4y1b7Ni的视频属性抓取结束
# 开始BV号为1uf4y197nW视频属性的抓取
# BV号为1uf4y197nW的视频属性抓取结束
# 开始BV号为19V411U723视频属性的抓取
# BV号为19V411U723的视频属性抓取结束
# 开始BV号为19V411z7zE视频属性的抓取
# BV号为19V411z7zE的视频属性抓取结束
# 开始BV号为16A411Y78s视频属性的抓取
# BV号为16A411Y78s的视频属性抓取结束
# 开始BV号为1PA411e76d视频属性的抓取
# BV号为1PA411e76d的视频属性抓取结束
# 开始BV号为1wt4y1S7Th视频属性的抓取
# BV号为1wt4y1S7Th的视频属性抓取结束
# 开始BV号为1B54y1v7qG视频属性的抓取
# BV号为1B54y1v7qG的视频属性抓取结束
# 开始BV号为1af4y1Q7mz视频属性的抓取
# BV号为1af4y1Q7mz的视频属性抓取结束
# 开始BV号为1cZ4y1M7JC视频属性的抓取
# BV号为1cZ4y1M7JC的视频属性抓取结束
# 开始BV号为1qi4y1u7SX视频属性的抓取
# BV号为1qi4y1u7SX的视频属性抓取结束
# 开始BV号为1wC4y1b7FT视频属性的抓取
# BV号为1wC4y1b7FT的视频属性抓取结束
# 开始BV号为1fv411v7n7视频属性的抓取
# BV号为1fv411v7n7的视频属性抓取结束
# 开始BV号为13p4y1q768视频属性的抓取
# BV号为13p4y1q768的视频属性抓取结束
# 开始BV号为16Z4y1K7Xz视频属性的抓取
# BV号为16Z4y1K7Xz的视频属性抓取结束
# 开始BV号为1xk4y127hR视频属性的抓取
# BV号为1xk4y127hR的视频属性抓取结束
# 开始BV号为13t4y1Q7sW视频属性的抓取
# BV号为13t4y1Q7sW的视频属性抓取结束
# 开始BV号为1pi4y1M7Df视频属性的抓取
# BV号为1pi4y1M7Df的视频属性抓取结束
# 开始BV号为1uV411U7y1视频属性的抓取
# BV号为1uV411U7y1的视频属性抓取结束
# 开始BV号为1ZV411z7kJ视频属性的抓取
# BV号为1ZV411z7kJ的视频属性抓取结束
# 开始BV号为1D54y1e7jv视频属性的抓取
# BV号为1D54y1e7jv的视频属性抓取结束
# 开始BV号为1NT4y1A7Dj视频属性的抓取
# BV号为1NT4y1A7Dj的视频属性抓取结束
# 开始BV号为1t54y1v7Lo视频属性的抓取
# BV号为1t54y1v7Lo的视频属性抓取结束
# 开始BV号为1cz4y1Z7FF视频属性的抓取
# BV号为1cz4y1Z7FF的视频属性抓取结束
# 开始BV号为1Ji4y1u7Pn视频属性的抓取
# BV号为1Ji4y1u7Pn的视频属性抓取结束
# 开始BV号为1rA411J7Xs视频属性的抓取
# BV号为1rA411J7Xs的视频属性抓取结束
# 开始BV号为12f4y1Q7T4视频属性的抓取
# BV号为12f4y1Q7T4的视频属性抓取结束
# 开始BV号为1qz4y1Z7TW视频属性的抓取
# BV号为1qz4y1Z7TW的视频属性抓取结束
# 开始BV号为1f5411b7FL视频属性的抓取
# BV号为1f5411b7FL的视频属性抓取结束
# 开始BV号为1m5411b7b7视频属性的抓取
# BV号为1m5411b7b7的视频属性抓取结束
# 开始BV号为1E5411b7mE视频属性的抓取
# BV号为1E5411b7mE的视频属性抓取结束
# 开始BV号为1CK411K7WH视频属性的抓取
# BV号为1CK411K7WH的视频属性抓取结束
# 开始BV号为1sa4y1E7Sa视频属性的抓取
# BV号为1sa4y1E7Sa的视频属性抓取结束
# 开始BV号为1if4y1D7ZD视频属性的抓取
# BV号为1if4y1D7ZD的视频属性抓取结束
# 开始BV号为1YV411m7kD视频属性的抓取
# BV号为1YV411m7kD的视频属性抓取结束
# 开始BV号为1BA411n7yz视频属性的抓取
# BV号为1BA411n7yz的视频属性抓取结束
# 开始BV号为13A411J78s视频属性的抓取
# BV号为13A411J78s的视频属性抓取结束
# 开始BV号为1FZ4y1N7m8视频属性的抓取
# BV号为1FZ4y1N7m8的视频属性抓取结束
# 开始BV号为1kV411m7kF视频属性的抓取
# BV号为1kV411m7kF的视频属性抓取结束
# 开始BV号为1Sf4y1Q7WL视频属性的抓取
# BV号为1Sf4y1Q7WL的视频属性抓取结束
# 开始BV号为1HA411J7ZU视频属性的抓取
# BV号为1HA411J7ZU的视频属性抓取结束
# 开始BV号为1Ek4y117yW视频属性的抓取
# BV号为1Ek4y117yW的视频属性抓取结束
# 开始BV号为1TZ4y1N7gM视频属性的抓取
# BV号为1TZ4y1N7gM的视频属性抓取结束
# 开始BV号为1kK4y1a7fF视频属性的抓取
# BV号为1kK4y1a7fF的视频属性抓取结束
# 开始BV号为1iv411C7oC视频属性的抓取
# BV号为1iv411C7oC的视频属性抓取结束
# 开始BV号为1hv411C78b视频属性的抓取
# BV号为1hv411C78b的视频属性抓取结束
# 开始BV号为17K4y1a7K3视频属性的抓取
# BV号为17K4y1a7K3的视频属性抓取结束
# 开始BV号为1LA411J7di视频属性的抓取
# BV号为1LA411J7di的视频属性抓取结束
# 开始BV号为1nK411K7nn视频属性的抓取
# BV号为1nK411K7nn的视频属性抓取结束
# 开始BV号为1bf4y1X7YP视频属性的抓取
# BV号为1bf4y1X7YP的视频属性抓取结束
# 开始BV号为1TV411S7v8视频属性的抓取
# BV号为1TV411S7v8的视频属性抓取结束
# 开始BV号为1d54y127hM视频属性的抓取
# BV号为1d54y127hM的视频属性抓取结束
# 开始BV号为1WV41117Bt视频属性的抓取
# BV号为1WV41117Bt的视频属性抓取结束
# 开始BV号为1QA411E7r6视频属性的抓取
# BV号为1QA411E7r6的视频属性抓取结束
# 开始BV号为18A411J75d视频属性的抓取
# BV号为18A411J75d的视频属性抓取结束
# 开始BV号为1df4y1Q7Kr视频属性的抓取
# BV号为1df4y1Q7Kr的视频属性抓取结束
# 开始BV号为1Uk4y1k79k视频属性的抓取
# BV号为1Uk4y1k79k的视频属性抓取结束
# 开始BV号为125411b7Bp视频属性的抓取
# BV号为125411b7Bp的视频属性抓取结束
# 开始BV号为1da4y1j71S视频属性的抓取
# BV号为1da4y1j71S的视频属性抓取结束
# 开始BV号为1oa4y1j7Fo视频属性的抓取
# BV号为1oa4y1j7Fo的视频属性抓取结束
# 开始BV号为1ka4y177EC视频属性的抓取
# BV号为1ka4y177EC的视频属性抓取结束
# 开始BV号为1Uh411R7Nb视频属性的抓取
# BV号为1Uh411R7Nb的视频属性抓取结束
# 开始BV号为1xy4y1y7yR视频属性的抓取
# BV号为1xy4y1y7yR的视频属性抓取结束
# 开始BV号为1yi4y177Sq视频属性的抓取
# BV号为1yi4y177Sq的视频属性抓取结束
# 开始BV号为1mK411N71S视频属性的抓取
# BV号为1mK411N71S的视频属性抓取结束
# 开始BV号为1Lt4y1q7UU视频属性的抓取
# BV号为1Lt4y1q7UU的视频属性抓取结束
# 开始BV号为1Qi4y1E7pA视频属性的抓取
# BV号为1Qi4y1E7pA的视频属性抓取结束
# 开始BV号为1RT4y1w7vH视频属性的抓取
# BV号为1RT4y1w7vH的视频属性抓取结束
# 开始BV号为1Ht4y1S7uD视频属性的抓取
# BV号为1Ht4y1S7uD的视频属性抓取结束
# 开始BV号为1DV411m7bN视频属性的抓取
# BV号为1DV411m7bN的视频属性抓取结束
# 开始BV号为1Vz4y1Z754视频属性的抓取
# BV号为1Vz4y1Z754的视频属性抓取结束
# 开始BV号为1654y1y7Mp视频属性的抓取
# BV号为1654y1y7Mp的视频属性抓取结束
# 开始BV号为1FA411J7HB视频属性的抓取
# BV号为1FA411J7HB的视频属性抓取结束
# 开始BV号为1aV41117Ed视频属性的抓取
# BV号为1aV41117Ed的视频属性抓取结束
# 开始BV号为18K4y1e7rJ视频属性的抓取
# BV号为18K4y1e7rJ的视频属性抓取结束
# 开始BV号为1yh411X7wP视频属性的抓取
# BV号为1yh411X7wP的视频属性抓取结束
# 开始BV号为1DT4y1w77r视频属性的抓取
# BV号为1DT4y1w77r的视频属性抓取结束
# 开始BV号为1Za4y1j7V7视频属性的抓取
# BV号为1Za4y1j7V7的视频属性抓取结束
# 开始BV号为1Rv41117Qn视频属性的抓取
# BV号为1Rv41117Qn的视频属性抓取结束
# 开始BV号为1ff4y1Q74N视频属性的抓取
# BV号为1ff4y1Q74N的视频属性抓取结束
# 开始BV号为1VV411m7d5视频属性的抓取
# BV号为1VV411m7d5的视频属性抓取结束
# 开始BV号为1q5411h7V8视频属性的抓取
# BV号为1q5411h7V8的视频属性抓取结束
# 开始BV号为1bp4y1a7Z8视频属性的抓取
# BV号为1bp4y1a7Z8的视频属性抓取结束
# 开始BV号为1hi4y1M7dq视频属性的抓取
# BV号为1hi4y1M7dq的视频属性抓取结束
# 开始BV号为1H541187Ld视频属性的抓取
# BV号为1H541187Ld的视频属性抓取结束
# 开始BV号为1ma4y1j7wH视频属性的抓取
# BV号为1ma4y1j7wH的视频属性抓取结束
# 开始BV号为1y54y127tQ视频属性的抓取
# BV号为1y54y127tQ的视频属性抓取结束
# 开始BV号为1ih411R7ze视频属性的抓取
# BV号为1ih411R7ze的视频属性抓取结束
# 开始BV号为1nh411976k视频属性的抓取
# BV号为1nh411976k的视频属性抓取结束
# 开始BV号为1Yi4y1E7Cf视频属性的抓取
# BV号为1Yi4y1E7Cf的视频属性抓取结束
# 开始BV号为1654y1C7ii视频属性的抓取
# BV号为1654y1C7ii的视频属性抓取结束
# 开始BV号为1Sf4y1q772视频属性的抓取
# BV号为1Sf4y1q772的视频属性抓取结束
# 开始BV号为1Hy4y1k7Cg视频属性的抓取
# BV号为1Hy4y1k7Cg的视频属性抓取结束
# 开始BV号为16K411K7Mw视频属性的抓取
# BV号为16K411K7Mw的视频属性抓取结束
# 开始BV号为1x54y1m7H1视频属性的抓取
# BV号为1x54y1m7H1的视频属性抓取结束
# 开始BV号为1ND4y1o7d2视频属性的抓取
# BV号为1ND4y1o7d2的视频属性抓取结束
# 开始BV号为1Hk4y117np视频属性的抓取
# BV号为1Hk4y117np的视频属性抓取结束
# 开始BV号为1Hy4y1y74e视频属性的抓取
# BV号为1Hy4y1y74e的视频属性抓取结束
# 开始BV号为1pi4y1u7a8视频属性的抓取
# BV号为1pi4y1u7a8的视频属性抓取结束
# 开始BV号为12h411X7EV视频属性的抓取
# BV号为12h411X7EV的视频属性抓取结束
# 开始BV号为1AD4y1o73x视频属性的抓取
# BV号为1AD4y1o73x的视频属性抓取结束
# 开始BV号为1Vh411R7pz视频属性的抓取
# BV号为1Vh411R7pz的视频属性抓取结束
# 开始BV号为1MT4y1c7jN视频属性的抓取
# BV号为1MT4y1c7jN的视频属性抓取结束
# 开始BV号为18f4y1D7WH视频属性的抓取
# BV号为18f4y1D7WH的视频属性抓取结束
# 开始BV号为1GK4y1e7JT视频属性的抓取
# BV号为1GK4y1e7JT的视频属性抓取结束
# 开始BV号为13i4y1E71S视频属性的抓取
# BV号为13i4y1E71S的视频属性抓取结束
# 开始BV号为1iz4y1f7qg视频属性的抓取
# BV号为1iz4y1f7qg的视频属性抓取结束
# 开始BV号为1HK4y1h7aM视频属性的抓取
# BV号为1HK4y1h7aM的视频属性抓取结束
# 开始BV号为1bi4y1u7o6视频属性的抓取
# BV号为1bi4y1u7o6的视频属性抓取结束
# 开始BV号为1hT4y1A7PD视频属性的抓取
# BV号为1hT4y1A7PD的视频属性抓取结束
# 开始BV号为1154y1C7QV视频属性的抓取
# BV号为1154y1C7QV的视频属性抓取结束
# 开始BV号为1gi4y1E77j视频属性的抓取
# BV号为1gi4y1E77j的视频属性抓取结束
# 开始BV号为1t54y117Wf视频属性的抓取
# BV号为1t54y117Wf的视频属性抓取结束
# 开始BV号为1yV411m7RL视频属性的抓取
# BV号为1yV411m7RL的视频属性抓取结束
# 开始BV号为1p54y1m75z视频属性的抓取
# BV号为1p54y1m75z的视频属性抓取结束
# 开始BV号为1tp4y1e75K视频属性的抓取
# BV号为1tp4y1e75K的视频属性抓取结束
# 开始BV号为1tz4y1Z7N2视频属性的抓取
# BV号为1tz4y1Z7N2的视频属性抓取结束
# 开始BV号为1eh411X7GA视频属性的抓取
# BV号为1eh411X7GA的视频属性抓取结束
# 开始BV号为1Yy4y1y7Pu视频属性的抓取
# BV号为1Yy4y1y7Pu的视频属性抓取结束
# 开始BV号为1UZ4y1N7CQ视频属性的抓取
# BV号为1UZ4y1N7CQ的视频属性抓取结束
# 开始BV号为1gk4y117gx视频属性的抓取
# BV号为1gk4y117gx的视频属性抓取结束
# 开始BV号为1zk4y1C7Zz视频属性的抓取
# BV号为1zk4y1C7Zz的视频属性抓取结束
# 开始BV号为1rV411y7GY视频属性的抓取
# BV号为1rV411y7GY的视频属性抓取结束
# 开始BV号为18Z4y157Ja视频属性的抓取
# BV号为18Z4y157Ja的视频属性抓取结束
# 开始BV号为1rZ4y157TP视频属性的抓取
# BV号为1rZ4y157TP的视频属性抓取结束
# 开始BV号为15D4y1d7sG视频属性的抓取
# BV号为15D4y1d7sG的视频属性抓取结束
# 开始BV号为1WA411E7xt视频属性的抓取
# BV号为1WA411E7xt的视频属性抓取结束
# 开始BV号为1R541157ta视频属性的抓取
# BV号为1R541157ta的视频属性抓取结束
# 开始BV号为13f4y1Q7Ks视频属性的抓取
# BV号为13f4y1Q7Ks的视频属性抓取结束
# 开始BV号为1T54y1C7CD视频属性的抓取
# BV号为1T54y1C7CD的视频属性抓取结束
# 开始BV号为1Xy4y1k7Zm视频属性的抓取
# BV号为1Xy4y1k7Zm的视频属性抓取结束
# 开始BV号为12v411k7WG视频属性的抓取
# BV号为12v411k7WG的视频属性抓取结束
# 开始BV号为15K4y1h7Cs视频属性的抓取
# BV号为15K4y1h7Cs的视频属性抓取结束
# 开始BV号为1Na4y1s7dM视频属性的抓取
# BV号为1Na4y1s7dM的视频属性抓取结束
# 开始BV号为1454y1R7JJ视频属性的抓取
# BV号为1454y1R7JJ的视频属性抓取结束
# 开始BV号为1py4y1B7mQ视频属性的抓取
# BV号为1py4y1B7mQ的视频属性抓取结束
# 开始BV号为1Vp4y1Y7ri视频属性的抓取
# BV号为1Vp4y1Y7ri的视频属性抓取结束
# 开始BV号为1Xz4y1Z7gw视频属性的抓取
# BV号为1Xz4y1Z7gw的视频属性抓取结束
# 开始BV号为1Dr4y1c76w视频属性的抓取
# BV号为1Dr4y1c76w的视频属性抓取结束
# 开始BV号为1ca4y1s7nN视频属性的抓取
# BV号为1ca4y1s7nN的视频属性抓取结束
# 开始BV号为1Uz4y1o7Hq视频属性的抓取
# BV号为1Uz4y1o7Hq的视频属性抓取结束
# 开始BV号为1fz4y1d7uF视频属性的抓取
# BV号为1fz4y1d7uF的视频属性抓取结束
# 开始BV号为1YT4y1F7EN视频属性的抓取
# BV号为1YT4y1F7EN的视频属性抓取结束
# 开始BV号为1UK4y1f7bD视频属性的抓取
# BV号为1UK4y1f7bD的视频属性抓取结束
# 开始BV号为1g54y1r7bE视频属性的抓取
# BV号为1g54y1r7bE的视频属性抓取结束
# 开始BV号为1yv41167pB视频属性的抓取
# BV号为1yv41167pB的视频属性抓取结束
# 开始BV号为1ar4y1w7x5视频属性的抓取
# BV号为1ar4y1w7x5的视频属性抓取结束
# 开始BV号为1if4y1B7TU视频属性的抓取
# BV号为1if4y1B7TU的视频属性抓取结束
# 开始BV号为1ji4y1j7aM视频属性的抓取
# BV号为1ji4y1j7aM的视频属性抓取结束
# 开始BV号为1a54y1R7JE视频属性的抓取
# BV号为1a54y1R7JE的视频属性抓取结束
# 开始BV号为1Vf4y1Q7ha视频属性的抓取
# BV号为1Vf4y1Q7ha的视频属性抓取结束
# 开始BV号为1Yf4y1B7YX视频属性的抓取
# BV号为1Yf4y1B7YX的视频属性抓取结束
# 开始BV号为1hK4y1778d视频属性的抓取
# BV号为1hK4y1778d的视频属性抓取结束
# 开始BV号为1wa4y1L7MT视频属性的抓取
# BV号为1wa4y1L7MT的视频属性抓取结束
# 开始BV号为1JA41177da视频属性的抓取
# BV号为1JA41177da的视频属性抓取结束
# 开始BV号为1fa411A7NT视频属性的抓取
# BV号为1fa411A7NT的视频属性抓取结束
# 开始BV号为1ck4y1y7FV视频属性的抓取
# BV号为1ck4y1y7FV的视频属性抓取结束
# 开始BV号为1HZ4y1L7t4视频属性的抓取
# BV号为1HZ4y1L7t4的视频属性抓取结束
# 开始BV号为1fK411w74a视频属性的抓取
# BV号为1fK411w74a的视频属性抓取结束
# 开始BV号为13z4y1o7FX视频属性的抓取
# BV号为13z4y1o7FX的视频属性抓取结束
# 开始BV号为1Rv411k7Kk视频属性的抓取
# BV号为1Rv411k7Kk的视频属性抓取结束
# 开始BV号为16p4y1k7YS视频属性的抓取
# BV号为16p4y1k7YS的视频属性抓取结束
# 开始BV号为1My4y1C7p5视频属性的抓取
# BV号为1My4y1C7p5的视频属性抓取结束
# 开始BV号为1Xi4y1j76o视频属性的抓取
# BV号为1Xi4y1j76o的视频属性抓取结束
# 开始BV号为1ur4y1w7qL视频属性的抓取
# BV号为1ur4y1w7qL的视频属性抓取结束
# 开始BV号为1Kv411C7ga视频属性的抓取
# BV号为1Kv411C7ga的视频属性抓取结束
# 开始BV号为1y54y117Ev视频属性的抓取
# BV号为1y54y117Ev的视频属性抓取结束
# 开始BV号为1ya411A7VN视频属性的抓取
# BV号为1ya411A7VN的视频属性抓取结束
# 开始BV号为1MK411P7hT视频属性的抓取
# BV号为1MK411P7hT的视频属性抓取结束
# 开始BV号为1hV41127WX视频属性的抓取
# BV号为1hV41127WX的视频属性抓取结束
# 开始BV号为1ZT4y1c7JL视频属性的抓取
# BV号为1ZT4y1c7JL的视频属性抓取结束
# 开始BV号为14t4y1i7Pf视频属性的抓取
# BV号为14t4y1i7Pf的视频属性抓取结束
# 开始BV号为1Kz4y1o7GD视频属性的抓取
# BV号为1Kz4y1o7GD的视频属性抓取结束
# 开始BV号为1eh41197u9视频属性的抓取
# BV号为1eh41197u9的视频属性抓取结束
# 开始BV号为1PK4y1E74J视频属性的抓取
# BV号为1PK4y1E74J的视频属性抓取结束
# 开始BV号为1SK4y177sq视频属性的抓取
# BV号为1SK4y177sq的视频属性抓取结束
# 开始BV号为1Jp4y1k7hL视频属性的抓取
# BV号为1Jp4y1k7hL的视频属性抓取结束
# 开始BV号为1y54y1k7Hu视频属性的抓取
# BV号为1y54y1k7Hu的视频属性抓取结束
# 开始BV号为1cT4y1w76M视频属性的抓取
# BV号为1cT4y1w76M的视频属性抓取结束
# 开始BV号为1Ky4y1r7dF视频属性的抓取
# BV号为1Ky4y1r7dF的视频属性抓取结束
# 开始BV号为1Xa4y157Qs视频属性的抓取
# BV号为1Xa4y157Qs的视频属性抓取结束
# 开始BV号为1rV41117M5视频属性的抓取
# BV号为1rV41117M5的视频属性抓取结束
# 开始BV号为1Za411w7vi视频属性的抓取
# BV号为1Za411w7vi的视频属性抓取结束
# 开始BV号为1HZ4y1L7tX视频属性的抓取
# BV号为1HZ4y1L7tX的视频属性抓取结束
# 开始BV号为1ra411w72f视频属性的抓取
# BV号为1ra411w72f的视频属性抓取结束
# 开始BV号为1u54y127Xo视频属性的抓取
# BV号为1u54y127Xo的视频属性抓取结束
# 开始BV号为19z4y1Z7HK视频属性的抓取
# BV号为19z4y1Z7HK的视频属性抓取结束
# 开始BV号为1qD4y1R7Vg视频属性的抓取
# BV号为1qD4y1R7Vg的视频属性抓取结束
# 开始BV号为1aa4y1L78z视频属性的抓取
# BV号为1aa4y1L78z的视频属性抓取结束
# 开始BV号为13T4y1w7aA视频属性的抓取
# BV号为13T4y1w7aA的视频属性抓取结束
# 开始BV号为1s54y1C7R5视频属性的抓取
# BV号为1s54y1C7R5的视频属性抓取结束
# 开始BV号为1Ra4y1W7cs视频属性的抓取
# BV号为1Ra4y1W7cs的视频属性抓取结束
# 开始BV号为1D54y117zP视频属性的抓取
# BV号为1D54y117zP的视频属性抓取结束
# 开始BV号为1zK411A7dt视频属性的抓取
# BV号为1zK411A7dt的视频属性抓取结束
# 开始BV号为18f4y1i7wU视频属性的抓取
# BV号为18f4y1i7wU的视频属性抓取结束
# 开始BV号为1vT4y1c7G6视频属性的抓取
# BV号为1vT4y1c7G6的视频属性抓取结束
# 开始BV号为1vp4y1k7AW视频属性的抓取
# BV号为1vp4y1k7AW的视频属性抓取结束
# 开始BV号为15a4y1s7Tb视频属性的抓取
# BV号为15a4y1s7Tb的视频属性抓取结束
# 开始BV号为1QV411y7bS视频属性的抓取
# BV号为1QV411y7bS的视频属性抓取结束
# 开始BV号为1tT4y1F7gP视频属性的抓取
# BV号为1tT4y1F7gP的视频属性抓取结束
# 开始BV号为1si4y1j74G视频属性的抓取
# BV号为1si4y1j74G的视频属性抓取结束
# 开始BV号为16D4y1R79N视频属性的抓取
# BV号为16D4y1R79N的视频属性抓取结束
# 开始BV号为1Gt4y1i79y视频属性的抓取
# BV号为1Gt4y1i79y的视频属性抓取结束
# 开始BV号为1oy4y1b7Xx视频属性的抓取
# BV号为1oy4y1b7Xx的视频属性抓取结束
# 开始BV号为1Lh41197ms视频属性的抓取
# BV号为1Lh41197ms的视频属性抓取结束
# 开始BV号为14z4y1o7bS视频属性的抓取
# BV号为14z4y1o7bS的视频属性抓取结束
# 开始BV号为1a54y1R7EQ视频属性的抓取
# BV号为1a54y1R7EQ的视频属性抓取结束
# 开始BV号为1bv411k763视频属性的抓取
# BV号为1bv411k763的视频属性抓取结束
# 开始BV号为1FA411j7Gv视频属性的抓取
# BV号为1FA411j7Gv的视频属性抓取结束
# 开始BV号为1AZ4y1L7UY视频属性的抓取
# BV号为1AZ4y1L7UY的视频属性抓取结束
# 开始BV号为1hy4y1r7oY视频属性的抓取
# BV号为1hy4y1r7oY的视频属性抓取结束
# 开始BV号为1gt4y1e7Hk视频属性的抓取
# BV号为1gt4y1e7Hk的视频属性抓取结束
# 开始BV号为1T54y127S4视频属性的抓取
# BV号为1T54y127S4的视频属性抓取结束
# 开始BV号为1jA41177dC视频属性的抓取
# BV号为1jA41177dC的视频属性抓取结束
# 开始BV号为1KD4y1d7A9视频属性的抓取
# BV号为1KD4y1d7A9的视频属性抓取结束
# 开始BV号为1tr4y1w716视频属性的抓取
# BV号为1tr4y1w716的视频属性抓取结束
# 开始BV号为17Z4y1V7LT视频属性的抓取
# BV号为17Z4y1V7LT的视频属性抓取结束
# 开始BV号为1Fa4y1x7TB视频属性的抓取
# BV号为1Fa4y1x7TB的视频属性抓取结束
# 开始BV号为1EZ4y1V7a2视频属性的抓取
# BV号为1EZ4y1V7a2的视频属性抓取结束
# 开始BV号为1Ea411A7fw视频属性的抓取
# BV号为1Ea411A7fw的视频属性抓取结束
# 开始BV号为1Ca411A7c7视频属性的抓取
# BV号为1Ca411A7c7的视频属性抓取结束
# 2020-12-21 20:42:56.372928

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-27-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_wudao_jiaocheng.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 3月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 4月     97   97    97   97   97   97   97   97    97      97   97    97   97
# 5月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 6月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 7月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月   100  100  100  100  100  100   100
# 2月    99   99   99   99   99   99    99
# 3月   100  100  100  100  100  100   100
# 4月    97   97   97   97   97   97    97
# 5月    99   99   99   99   99   99    99
# 6月    99   99   99   99   99   99    99
# 7月    99   99   99   99   99   99    99
# 8月   100  100  100  100  100  100   100
# 9月   100  100  100  100  100  100   100

# %%
channel_wudao_jiaocheng.to_json('channel_wudao_jiaocheng.json')
