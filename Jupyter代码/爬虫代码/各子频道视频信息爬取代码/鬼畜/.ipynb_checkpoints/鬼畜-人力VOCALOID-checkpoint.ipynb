# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_guichu_renli=pd.DataFrame(columns=columns)
channel_guichu_renli
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[10]/div/a/span').click()  #选择频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[10]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '鬼畜'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[4]/a').click()  #选择子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[4]/a').text
sub_channel
# Out:
# '人力VOCALOID'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(4,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_guichu_renli.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-25 19:27:11.279394
# <ipython-input-10-3d45a82901b9>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-10-3d45a82901b9>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-10-3d45a82901b9>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1Ck4y197i1视频属性的抓取
# BV号为1Ck4y197i1的视频属性抓取结束
# <ipython-input-10-3d45a82901b9>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1Wi4y1b77G视频属性的抓取
# BV号为1Wi4y1b77G的视频属性抓取结束
# 开始BV号为1jC4y147rv视频属性的抓取
# BV号为1jC4y147rv的视频属性抓取结束
# 开始BV号为1yA411b7vt视频属性的抓取
# BV号为1yA411b7vt的视频属性抓取结束
# 开始BV号为1Rg4y187Fh视频属性的抓取
# BV号为1Rg4y187Fh的视频属性抓取结束
# 开始BV号为1Ua4y1v7up视频属性的抓取
# BV号为1Ua4y1v7up的视频属性抓取结束
# 开始BV号为1W64y1M7GH视频属性的抓取
# BV号为1W64y1M7GH的视频属性抓取结束
# 开始BV号为1ba4y147aB视频属性的抓取
# BV号为1ba4y147aB的视频属性抓取结束
# 开始BV号为1nC4y1x7Je视频属性的抓取
# BV号为1nC4y1x7Je的视频属性抓取结束
# 开始BV号为1KQ4y1N7JT视频属性的抓取
# BV号为1KQ4y1N7JT的视频属性抓取结束
# 开始BV号为1yk4y1R7KR视频属性的抓取
# BV号为1yk4y1R7KR的视频属性抓取结束
# 开始BV号为1wk4y1R78B视频属性的抓取
# BV号为1wk4y1R78B的视频属性抓取结束
# 开始BV号为1pa4y1t7Ly视频属性的抓取
# BV号为1pa4y1t7Ly的视频属性抓取结束
# 开始BV号为1NC4y1s7p2视频属性的抓取
# BV号为1NC4y1s7p2的视频属性抓取结束
# 开始BV号为1qQ4y1K7Gs视频属性的抓取
# BV号为1qQ4y1K7Gs的视频属性抓取结束
# 开始BV号为1X64y1T7wP视频属性的抓取
# BV号为1X64y1T7wP的视频属性抓取结束
# 开始BV号为1CQ4y1K7tY视频属性的抓取
# BV号为1CQ4y1K7tY的视频属性抓取结束
# 开始BV号为1Qg4y1z7uc视频属性的抓取
# BV号为1Qg4y1z7uc的视频属性抓取结束
# 开始BV号为1cK4y1k7Vj视频属性的抓取
# BV号为1cK4y1k7Vj的视频属性抓取结束
# 开始BV号为1UK4y1r7ky视频属性的抓取
# BV号为1UK4y1r7ky的视频属性抓取结束
# 开始BV号为1wK411j7dH视频属性的抓取
# BV号为1wK411j7dH的视频属性抓取结束
# 开始BV号为1Ng4y1a7SU视频属性的抓取
# BV号为1Ng4y1a7SU的视频属性抓取结束
# 开始BV号为1YT4y1G7G9视频属性的抓取
# BV号为1YT4y1G7G9的视频属性抓取结束
# 开始BV号为1sQ4y1K7QP视频属性的抓取
# BV号为1sQ4y1K7QP的视频属性抓取结束
# 开始BV号为1R541147mr视频属性的抓取
# BV号为1R541147mr的视频属性抓取结束
# 开始BV号为1ze411x7ks视频属性的抓取
# BV号为1ze411x7ks的视频属性抓取结束
# 开始BV号为1XA411b7VP视频属性的抓取
# BV号为1XA411b7VP的视频属性抓取结束
# 开始BV号为1RK4y1r773视频属性的抓取
# BV号为1RK4y1r773的视频属性抓取结束
# 开始BV号为1LV411Z7xG视频属性的抓取
# BV号为1LV411Z7xG的视频属性抓取结束
# 开始BV号为1NV411d7QX视频属性的抓取
# BV号为1NV411d7QX的视频属性抓取结束
# 开始BV号为1Hi4y187rp视频属性的抓取
# BV号为1Hi4y187rp的视频属性抓取结束
# 开始BV号为1mK4y1C7da视频属性的抓取
# BV号为1mK4y1C7da的视频属性抓取结束
# 开始BV号为1jC4y1s7tx视频属性的抓取
# BV号为1jC4y1s7tx的视频属性抓取结束
# 开始BV号为1Zi4y1b7ar视频属性的抓取
# BV号为1Zi4y1b7ar的视频属性抓取结束
# 开始BV号为1EC4y1W7gu视频属性的抓取
# BV号为1EC4y1W7gu的视频属性抓取结束
# 开始BV号为1Di4y1t7MB视频属性的抓取
# BV号为1Di4y1t7MB的视频属性抓取结束
# 开始BV号为17g4y1a7MF视频属性的抓取
# BV号为17g4y1a7MF的视频属性抓取结束
# 开始BV号为1xV411o7h9视频属性的抓取
# BV号为1xV411o7h9的视频属性抓取结束
# 开始BV号为11e411s7rk视频属性的抓取
# BV号为11e411s7rk的视频属性抓取结束
# 开始BV号为1TK4y1k72m视频属性的抓取
# BV号为1TK4y1k72m的视频属性抓取结束
# 开始BV号为1rK41157rj视频属性的抓取
# BV号为1rK41157rj的视频属性抓取结束
# 开始BV号为1VT4y15749视频属性的抓取
# BV号为1VT4y15749的视频属性抓取结束
# 开始BV号为1Cp4y1X7d2视频属性的抓取
# BV号为1Cp4y1X7d2的视频属性抓取结束
# 开始BV号为1LK41157xB视频属性的抓取
# BV号为1LK41157xB的视频属性抓取结束
# 开始BV号为1nA411h7Xi视频属性的抓取
# BV号为1nA411h7Xi的视频属性抓取结束
# 开始BV号为1zQ4y1K7aS视频属性的抓取
# BV号为1zQ4y1K7aS的视频属性抓取结束
# 开始BV号为15g4y1z7Pg视频属性的抓取
# BV号为15g4y1z7Pg的视频属性抓取结束
# 开始BV号为1Jp4y1y72p视频属性的抓取
# BV号为1Jp4y1y72p的视频属性抓取结束
# 开始BV号为13A411b75A视频属性的抓取
# BV号为13A411b75A的视频属性抓取结束
# 开始BV号为1LQ4y1M7LP视频属性的抓取
# BV号为1LQ4y1M7LP的视频属性抓取结束
# 开始BV号为1ma4y1v7br视频属性的抓取
# BV号为1ma4y1v7br的视频属性抓取结束
# 开始BV号为1yp4y1X7iZ视频属性的抓取
# BV号为1yp4y1X7iZ的视频属性抓取结束
# 开始BV号为16Z4y1j74d视频属性的抓取
# BV号为16Z4y1j74d的视频属性抓取结束
# 开始BV号为1bf4y1S7rW视频属性的抓取
# BV号为1bf4y1S7rW的视频属性抓取结束
# 开始BV号为1mV411f7kH视频属性的抓取
# BV号为1mV411f7kH的视频属性抓取结束
# 开始BV号为13T4y137SE视频属性的抓取
# BV号为13T4y137SE的视频属性抓取结束
# 开始BV号为1JC4y1x7vu视频属性的抓取
# BV号为1JC4y1x7vu的视频属性抓取结束
# 开始BV号为1He411x7WP视频属性的抓取
# BV号为1He411x7WP的视频属性抓取结束
# 开始BV号为1Qk4y1r7pA视频属性的抓取
# BV号为1Qk4y1r7pA的视频属性抓取结束
# 开始BV号为1hK4y1b7HD视频属性的抓取
# BV号为1hK4y1b7HD的视频属性抓取结束
# 开始BV号为1Za4y147xQ视频属性的抓取
# BV号为1Za4y147xQ的视频属性抓取结束
# 开始BV号为1ii4y1b7fD视频属性的抓取
# BV号为1ii4y1b7fD的视频属性抓取结束
# 开始BV号为1kK411L7df视频属性的抓取
# BV号为1kK411L7df的视频属性抓取结束
# 开始BV号为1m64y1T7Ko视频属性的抓取
# BV号为1m64y1T7Ko的视频属性抓取结束
# 开始BV号为1pK4y1b7cm视频属性的抓取
# BV号为1pK4y1b7cm的视频属性抓取结束
# 开始BV号为1pf4y1S7G2视频属性的抓取
# BV号为1pf4y1S7G2的视频属性抓取结束
# 开始BV号为1Ht4y1U77f视频属性的抓取
# BV号为1Ht4y1U77f的视频属性抓取结束
# 开始BV号为1Ra4y1v7FN视频属性的抓取
# BV号为1Ra4y1v7FN的视频属性抓取结束
# 开始BV号为1pV411Z7vz视频属性的抓取
# BV号为1pV411Z7vz的视频属性抓取结束
# 开始BV号为1vg4y1z7CE视频属性的抓取
# BV号为1vg4y1z7CE的视频属性抓取结束
# 开始BV号为18g4y1z7v7视频属性的抓取
# BV号为18g4y1z7v7的视频属性抓取结束
# 开始BV号为1554y197SE视频属性的抓取
# BV号为1554y197SE的视频属性抓取结束
# 开始BV号为11C4y1s71u视频属性的抓取
# BV号为11C4y1s71u的视频属性抓取结束
# 开始BV号为1za4y1v7em视频属性的抓取
# BV号为1za4y1v7em的视频属性抓取结束
# 开始BV号为19a4y1t7xh视频属性的抓取
# BV号为19a4y1t7xh的视频属性抓取结束
# 开始BV号为1dA411b7a2视频属性的抓取
# BV号为1dA411b7a2的视频属性抓取结束
# 开始BV号为1bC4y147w1视频属性的抓取
# BV号为1bC4y147w1的视频属性抓取结束
# 开始BV号为1PT4y1575V视频属性的抓取
# BV号为1PT4y1575V的视频属性抓取结束
# 开始BV号为1Nz411z74n视频属性的抓取
# BV号为1Nz411z74n的视频属性抓取结束
# 开始BV号为1mT4y1g7pY视频属性的抓取
# BV号为1mT4y1g7pY的视频属性抓取结束
# 开始BV号为1kf4y1U7En视频属性的抓取
# BV号为1kf4y1U7En的视频属性抓取结束
# 开始BV号为1He41147Tw视频属性的抓取
# BV号为1He41147Tw的视频属性抓取结束
# 开始BV号为1zK41157WC视频属性的抓取
# BV号为1zK41157WC的视频属性抓取结束
# 开始BV号为1Dt4y127p4视频属性的抓取
# BV号为1Dt4y127p4的视频属性抓取结束
# 开始BV号为1Ki4y18728视频属性的抓取
# BV号为1Ki4y18728的视频属性抓取结束
# 开始BV号为1L64y1M7zP视频属性的抓取
# BV号为1L64y1M7zP的视频属性抓取结束
# 开始BV号为1iz411B7hS视频属性的抓取
# BV号为1iz411B7hS的视频属性抓取结束
# 开始BV号为1Gc411h7t7视频属性的抓取
# BV号为1Gc411h7t7的视频属性抓取结束
# 开始BV号为1Mk4y1R7SD视频属性的抓取
# BV号为1Mk4y1R7SD的视频属性抓取结束
# 开始BV号为1YQ4y1M7SJ视频属性的抓取
# BV号为1YQ4y1M7SJ的视频属性抓取结束
# 开始BV号为1vk4y1r7VZ视频属性的抓取
# BV号为1vk4y1r7VZ的视频属性抓取结束
# 开始BV号为1Bi4y1b7wL视频属性的抓取
# BV号为1Bi4y1b7wL的视频属性抓取结束
# 开始BV号为16p4y1X7Z8视频属性的抓取
# BV号为16p4y1X7Z8的视频属性抓取结束
# 开始BV号为19Q4y1P7NZ视频属性的抓取
# BV号为19Q4y1P7NZ的视频属性抓取结束
# 开始BV号为1EK41157bJ视频属性的抓取
# BV号为1EK41157bJ的视频属性抓取结束
# 开始BV号为1jc411h7xc视频属性的抓取
# BV号为1jc411h7xc的视频属性抓取结束
# 开始BV号为1FC4y1W7Bq视频属性的抓取
# BV号为1FC4y1W7Bq的视频属性抓取结束
# 开始BV号为1ya4y1v7QR视频属性的抓取
# BV号为1ya4y1v7QR的视频属性抓取结束
# 开始BV号为1eg4y187yi视频属性的抓取
# BV号为1eg4y187yi的视频属性抓取结束
# 开始BV号为1Dg4y1z7ky视频属性的抓取
# BV号为1Dg4y1z7ky的视频属性抓取结束
# 开始BV号为1PC4y1p7wH视频属性的抓取
# BV号为1PC4y1p7wH的视频属性抓取结束
# 开始BV号为1gk4y1r7sR视频属性的抓取
# BV号为1gk4y1r7sR的视频属性抓取结束
# 开始BV号为14g4y1B7zk视频属性的抓取
# BV号为14g4y1B7zk的视频属性抓取结束
# 开始BV号为1aZ4y1p7Rz视频属性的抓取
# BV号为1aZ4y1p7Rz的视频属性抓取结束
# 开始BV号为12a4y1e7Aa视频属性的抓取
# BV号为12a4y1e7Aa的视频属性抓取结束
# 开始BV号为1Xg4y1q78q视频属性的抓取
# BV号为1Xg4y1q78q的视频属性抓取结束
# 开始BV号为1Lz4y197pZ视频属性的抓取
# BV号为1Lz4y197pZ的视频属性抓取结束
# 开始BV号为1Lk4y1k7FN视频属性的抓取
# BV号为1Lk4y1k7FN的视频属性抓取结束
# 开始BV号为1Up4y1Q7zL视频属性的抓取
# BV号为1Up4y1Q7zL的视频属性抓取结束
# 开始BV号为1EA411t7JK视频属性的抓取
# BV号为1EA411t7JK的视频属性抓取结束
# 开始BV号为1Zk4y167P2视频属性的抓取
# BV号为1Zk4y167P2的视频属性抓取结束
# 开始BV号为1jz4y1d7EY视频属性的抓取
# BV号为1jz4y1d7EY的视频属性抓取结束
# 开始BV号为1bK4y1871h视频属性的抓取
# BV号为1bK4y1871h的视频属性抓取结束
# 开始BV号为11K411W7mk视频属性的抓取
# BV号为11K411W7mk的视频属性抓取结束
# 开始BV号为1BQ4y1N7Po视频属性的抓取
# BV号为1BQ4y1N7Po的视频属性抓取结束
# 开始BV号为1g54y1X7Bt视频属性的抓取
# BV号为1g54y1X7Bt的视频属性抓取结束
# 开始BV号为1R54y1D7sb视频属性的抓取
# BV号为1R54y1D7sb的视频属性抓取结束
# 开始BV号为1SK41157ve视频属性的抓取
# BV号为1SK41157ve的视频属性抓取结束
# 开始BV号为1zA411q7Fi视频属性的抓取
# BV号为1zA411q7Fi的视频属性抓取结束
# 开始BV号为1dt4y1y7rB视频属性的抓取
# BV号为1dt4y1y7rB的视频属性抓取结束
# 开始BV号为11Q4y1N7hW视频属性的抓取
# BV号为11Q4y1N7hW的视频属性抓取结束
# 开始BV号为1ee411W77N视频属性的抓取
# BV号为1ee411W77N的视频属性抓取结束
# 开始BV号为1ug4y167jv视频属性的抓取
# BV号为1ug4y167jv的视频属性抓取结束
# 开始BV号为1Lt4y117PY视频属性的抓取
# BV号为1Lt4y117PY的视频属性抓取结束
# 开始BV号为1nT4y1u7Uq视频属性的抓取
# BV号为1nT4y1u7Uq的视频属性抓取结束
# 开始BV号为1Xf4y1m7dy视频属性的抓取
# BV号为1Xf4y1m7dy的视频属性抓取结束
# 开始BV号为1G5411s7iu视频属性的抓取
# BV号为1G5411s7iu的视频属性抓取结束
# 开始BV号为1sQ4y1P7f7视频属性的抓取
# BV号为1sQ4y1P7f7的视频属性抓取结束
# 开始BV号为1fC4y1p7Wx视频属性的抓取
# BV号为1fC4y1p7Wx的视频属性抓取结束
# 开始BV号为1Hz411q7kB视频属性的抓取
# BV号为1Hz411q7kB的视频属性抓取结束
# 开始BV号为1Vz411B7Xa视频属性的抓取
# BV号为1Vz411B7Xa的视频属性抓取结束
# 开始BV号为1mi4y1t7J3视频属性的抓取
# BV号为1mi4y1t7J3的视频属性抓取结束
# 开始BV号为12p4y197vQ视频属性的抓取
# BV号为12p4y197vQ的视频属性抓取结束
# 开始BV号为1Zz4y1R7Mb视频属性的抓取
# BV号为1Zz4y1R7Mb的视频属性抓取结束
# 开始BV号为1SQ4y1A7Jj视频属性的抓取
# BV号为1SQ4y1A7Jj的视频属性抓取结束
# 开始BV号为1Y64y1M7ET视频属性的抓取
# BV号为1Y64y1M7ET的视频属性抓取结束
# 开始BV号为1ba4y1e7xn视频属性的抓取
# BV号为1ba4y1e7xn的视频属性抓取结束
# 开始BV号为1ie411p7Yq视频属性的抓取
# BV号为1ie411p7Yq的视频属性抓取结束
# 开始BV号为1pK4y18789视频属性的抓取
# BV号为1pK4y18789的视频属性抓取结束
# 开始BV号为1JK4y1b7Ap视频属性的抓取
# BV号为1JK4y1b7Ap的视频属性抓取结束
# 开始BV号为1Zg4y1B7Fr视频属性的抓取
# BV号为1Zg4y1B7Fr的视频属性抓取结束
# 开始BV号为1iT4y1u7i5视频属性的抓取
# BV号为1iT4y1u7i5的视频属性抓取结束
# 开始BV号为1kC4y1H7wB视频属性的抓取
# BV号为1kC4y1H7wB的视频属性抓取结束
# 开始BV号为1bi4y1s7Dh视频属性的抓取
# BV号为1bi4y1s7Dh的视频属性抓取结束
# 开始BV号为1D54y1X7pC视频属性的抓取
# BV号为1D54y1X7pC的视频属性抓取结束
# 开始BV号为1KQ4y1K7Ad视频属性的抓取
# BV号为1KQ4y1K7Ad的视频属性抓取结束
# 开始BV号为1va4y1i7Rr视频属性的抓取
# BV号为1va4y1i7Rr的视频属性抓取结束
# 开始BV号为1YV411C7rt视频属性的抓取
# BV号为1YV411C7rt的视频属性抓取结束
# 开始BV号为19p4y1Q7sU视频属性的抓取
# BV号为19p4y1Q7sU的视频属性抓取结束
# 开始BV号为1hK411W7iC视频属性的抓取
# BV号为1hK411W7iC的视频属性抓取结束
# 开始BV号为16K411W7NT视频属性的抓取
# BV号为16K411W7NT的视频属性抓取结束
# 开始BV号为19K4y1t7we视频属性的抓取
# BV号为19K4y1t7we的视频属性抓取结束
# 开始BV号为1mK411W7c7视频属性的抓取
# BV号为1mK411W7c7的视频属性抓取结束
# 开始BV号为1PV411C7Me视频属性的抓取
# BV号为1PV411C7Me的视频属性抓取结束
# 开始BV号为1HK4y187R6视频属性的抓取
# BV号为1HK4y187R6的视频属性抓取结束
# 开始BV号为1pT4y137zx视频属性的抓取
# BV号为1pT4y137zx的视频属性抓取结束
# 开始BV号为1aK4y1t7wH视频属性的抓取
# BV号为1aK4y1t7wH的视频属性抓取结束
# 开始BV号为1nk4y1k7x5视频属性的抓取
# BV号为1nk4y1k7x5的视频属性抓取结束
# 开始BV号为1BV411C7hz视频属性的抓取
# BV号为1BV411C7hz的视频属性抓取结束
# 开始BV号为17A411t7E1视频属性的抓取
# BV号为17A411t7E1的视频属性抓取结束
# 开始BV号为1Dp4y1Q7f1视频属性的抓取
# BV号为1Dp4y1Q7f1的视频属性抓取结束
# 开始BV号为1Ht4y117sw视频属性的抓取
# BV号为1Ht4y117sw的视频属性抓取结束
# 开始BV号为1WQ4y1T7fy视频属性的抓取
# BV号为1WQ4y1T7fy的视频属性抓取结束
# 开始BV号为17V411C7NW视频属性的抓取
# BV号为17V411C7NW的视频属性抓取结束
# 开始BV号为1eA411t7qd视频属性的抓取
# BV号为1eA411t7qd的视频属性抓取结束
# 开始BV号为1tt4y117VF视频属性的抓取
# BV号为1tt4y117VF的视频属性抓取结束
# 开始BV号为1gp4y1Q76y视频属性的抓取
# BV号为1gp4y1Q76y的视频属性抓取结束
# 开始BV号为14T4y1u7Ku视频属性的抓取
# BV号为14T4y1u7Ku的视频属性抓取结束
# 开始BV号为1Rz4y1X79B视频属性的抓取
# BV号为1Rz4y1X79B的视频属性抓取结束
# 开始BV号为1Uf4y1S7Sn视频属性的抓取
# BV号为1Uf4y1S7Sn的视频属性抓取结束
# 开始BV号为1fQ4y1N7pP视频属性的抓取
# BV号为1fQ4y1N7pP的视频属性抓取结束
# 开始BV号为1gg4y1B7yT视频属性的抓取
# BV号为1gg4y1B7yT的视频属性抓取结束
# 开始BV号为1Vk4y1k76o视频属性的抓取
# BV号为1Vk4y1k76o的视频属性抓取结束
# 开始BV号为1va4y1e7i1视频属性的抓取
# BV号为1va4y1e7i1的视频属性抓取结束
# 开始BV号为1tC4y1p7cW视频属性的抓取
# BV号为1tC4y1p7cW的视频属性抓取结束
# 开始BV号为1XT4y1u7Pt视频属性的抓取
# BV号为1XT4y1u7Pt的视频属性抓取结束
# 开始BV号为16v411z7n2视频属性的抓取
# BV号为16v411z7n2的视频属性抓取结束
# 开始BV号为1ai4y1s74G视频属性的抓取
# BV号为1ai4y1s74G的视频属性抓取结束
# 开始BV号为1ai4y147eY视频属性的抓取
# BV号为1ai4y147eY的视频属性抓取结束
# 开始BV号为1tf4y1U7zM视频属性的抓取
# BV号为1tf4y1U7zM的视频属性抓取结束
# 开始BV号为17a4y1i7bw视频属性的抓取
# BV号为17a4y1i7bw的视频属性抓取结束
# 开始BV号为1cZ4y1W79b视频属性的抓取
# BV号为1cZ4y1W79b的视频属性抓取结束
# 开始BV号为1HZ4y1s7qF视频属性的抓取
# BV号为1HZ4y1s7qF的视频属性抓取结束
# 开始BV号为1dz4y1R7u4视频属性的抓取
# BV号为1dz4y1R7u4的视频属性抓取结束
# 开始BV号为1Az4y197rN视频属性的抓取
# BV号为1Az4y197rN的视频属性抓取结束
# 开始BV号为1Gk4y1r7JW视频属性的抓取
# BV号为1Gk4y1r7JW的视频属性抓取结束
# 开始BV号为1PK4y187JJ视频属性的抓取
# BV号为1PK4y187JJ的视频属性抓取结束
# 开始BV号为11a4y1e77m视频属性的抓取
# BV号为11a4y1e77m的视频属性抓取结束
# 开始BV号为11a4y1e7Zp视频属性的抓取
# BV号为11a4y1e7Zp的视频属性抓取结束
# 开始BV号为1Wg4y1i7R2视频属性的抓取
# BV号为1Wg4y1i7R2的视频属性抓取结束
# 开始BV号为1tf4y127Eo视频属性的抓取
# BV号为1tf4y127Eo的视频属性抓取结束
# 开始BV号为1Gk4y1k77Z视频属性的抓取
# BV号为1Gk4y1k77Z的视频属性抓取结束
# 开始BV号为1RK411H7wk视频属性的抓取
# BV号为1RK411H7wk的视频属性抓取结束
# 开始BV号为16Q4y1A7sg视频属性的抓取
# BV号为16Q4y1A7sg的视频属性抓取结束
# 开始BV号为1fg4y1z7p8视频属性的抓取
# BV号为1fg4y1z7p8的视频属性抓取结束
# 开始BV号为1dK411W78Y视频属性的抓取
# BV号为1dK411W78Y的视频属性抓取结束
# 开始BV号为1a54y1D7Bc视频属性的抓取
# BV号为1a54y1D7Bc的视频属性抓取结束
# 开始BV号为13a4y1i7Fc视频属性的抓取
# BV号为13a4y1i7Fc的视频属性抓取结束
# 开始BV号为12T4y1u7R7视频属性的抓取
# BV号为12T4y1u7R7的视频属性抓取结束
# 开始BV号为1tp4y197Ra视频属性的抓取
# BV号为1tp4y197Ra的视频属性抓取结束
# 开始BV号为1Mk4y1z7ey视频属性的抓取
# BV号为1Mk4y1z7ey的视频属性抓取结束
# 开始BV号为1Ff4y1178U视频属性的抓取
# BV号为1Ff4y1178U的视频属性抓取结束
# 开始BV号为1Vz411i7Bb视频属性的抓取
# BV号为1Vz411i7Bb的视频属性抓取结束
# 开始BV号为1zz411i7TW视频属性的抓取
# BV号为1zz411i7TW的视频属性抓取结束
# 开始BV号为1Nv411671u视频属性的抓取
# BV号为1Nv411671u的视频属性抓取结束
# 开始BV号为1hV411r7TA视频属性的抓取
# BV号为1hV411r7TA的视频属性抓取结束
# 开始BV号为1Mt4y197EA视频属性的抓取
# BV号为1Mt4y197EA的视频属性抓取结束
# 开始BV号为1dK4y1t7jf视频属性的抓取
# BV号为1dK4y1t7jf的视频属性抓取结束
# 开始BV号为1ui4y1x78t视频属性的抓取
# BV号为1ui4y1x78t的视频属性抓取结束
# 开始BV号为1RZ4y1n7Pk视频属性的抓取
# BV号为1RZ4y1n7Pk的视频属性抓取结束
# 开始BV号为1PZ4y1p7sQ视频属性的抓取
# BV号为1PZ4y1p7sQ的视频属性抓取结束
# 开始BV号为1Jg4y1q7YY视频属性的抓取
# BV号为1Jg4y1q7YY的视频属性抓取结束
# 开始BV号为1Av411B7C7视频属性的抓取
# BV号为1Av411B7C7的视频属性抓取结束
# 开始BV号为1PA411B7hp视频属性的抓取
# BV号为1PA411B7hp的视频属性抓取结束
# 开始BV号为11K411n7Mh视频属性的抓取
# BV号为11K411n7Mh的视频属性抓取结束
# 开始BV号为1ez411e7Ny视频属性的抓取
# BV号为1ez411e7Ny的视频属性抓取结束
# 开始BV号为1pK4y1s7UZ视频属性的抓取
# BV号为1pK4y1s7UZ的视频属性抓取结束
# 开始BV号为1jg4y1q7uF视频属性的抓取
# BV号为1jg4y1q7uF的视频属性抓取结束
# 开始BV号为1Nk4y1z7Qx视频属性的抓取
# BV号为1Nk4y1z7Qx的视频属性抓取结束
# 开始BV号为1HA411i7H2视频属性的抓取
# BV号为1HA411i7H2的视频属性抓取结束
# 开始BV号为1zC4y1a7Xf视频属性的抓取
# BV号为1zC4y1a7Xf的视频属性抓取结束
# 开始BV号为1p54y1B77a视频属性的抓取
# BV号为1p54y1B77a的视频属性抓取结束
# 开始BV号为1NK4y147QW视频属性的抓取
# BV号为1NK4y147QW的视频属性抓取结束
# 开始BV号为1Cf4y127iq视频属性的抓取
# BV号为1Cf4y127iq的视频属性抓取结束
# 开始BV号为1Sk4y1q7Eo视频属性的抓取
# BV号为1Sk4y1q7Eo的视频属性抓取结束
# 开始BV号为1LV41167zb视频属性的抓取
# BV号为1LV41167zb的视频属性抓取结束
# 开始BV号为1dC4y1a77u视频属性的抓取
# BV号为1dC4y1a77u的视频属性抓取结束
# 开始BV号为1Mt4y197N4视频属性的抓取
# BV号为1Mt4y197N4的视频属性抓取结束
# 开始BV号为1hz4y1Q7dY视频属性的抓取
# BV号为1hz4y1Q7dY的视频属性抓取结束
# 开始BV号为1Zz4y1Q7jY视频属性的抓取
# BV号为1Zz4y1Q7jY的视频属性抓取结束
# 开始BV号为1NC4y1Y7an视频属性的抓取
# BV号为1NC4y1Y7an的视频属性抓取结束
# 开始BV号为1Wg4y1q7o3视频属性的抓取
# BV号为1Wg4y1q7o3的视频属性抓取结束
# 开始BV号为1Xz411i7Ww视频属性的抓取
# BV号为1Xz411i7Ww的视频属性抓取结束
# 开始BV号为1aD4y1D7BD视频属性的抓取
# BV号为1aD4y1D7BD的视频属性抓取结束
# 开始BV号为1df4y127x5视频属性的抓取
# BV号为1df4y127x5的视频属性抓取结束
# 开始BV号为1jt4y1y7Uz视频属性的抓取
# BV号为1jt4y1y7Uz的视频属性抓取结束
# 开始BV号为1Ea4y1Y7uL视频属性的抓取
# BV号为1Ea4y1Y7uL的视频属性抓取结束
# 开始BV号为1Ei4y1G7fA视频属性的抓取
# BV号为1Ei4y1G7fA的视频属性抓取结束
# 开始BV号为1iz4y197iV视频属性的抓取
# BV号为1iz4y197iV的视频属性抓取结束
# 开始BV号为1nD4y1Q7B6视频属性的抓取
# BV号为1nD4y1Q7B6的视频属性抓取结束
# 开始BV号为1cA411B7qA视频属性的抓取
# BV号为1cA411B7qA的视频属性抓取结束
# 开始BV号为1xK411p7Dt视频属性的抓取
# BV号为1xK411p7Dt的视频属性抓取结束
# 开始BV号为1ZA411q7Cy视频属性的抓取
# BV号为1ZA411q7Cy的视频属性抓取结束
# 开始BV号为17t4y197Kn视频属性的抓取
# BV号为17t4y197Kn的视频属性抓取结束
# 开始BV号为1t54y1Q7Ag视频属性的抓取
# BV号为1t54y1Q7Ag的视频属性抓取结束
# 开始BV号为1K54y1z7gD视频属性的抓取
# BV号为1K54y1z7gD的视频属性抓取结束
# 开始BV号为1nf4y117Jn视频属性的抓取
# BV号为1nf4y117Jn的视频属性抓取结束
# 开始BV号为16i4y1G7V7视频属性的抓取
# BV号为16i4y1G7V7的视频属性抓取结束
# 开始BV号为1oD4y1D7L6视频属性的抓取
# BV号为1oD4y1D7L6的视频属性抓取结束
# 开始BV号为1xv411B7mE视频属性的抓取
# BV号为1xv411B7mE的视频属性抓取结束
# 开始BV号为13D4y1Q75Z视频属性的抓取
# BV号为13D4y1Q75Z的视频属性抓取结束
# 开始BV号为1NT4y1J7X1视频属性的抓取
# BV号为1NT4y1J7X1的视频属性抓取结束
# 开始BV号为1jT4y1J7Kk视频属性的抓取
# BV号为1jT4y1J7Kk的视频属性抓取结束
# 开始BV号为1gf4y1m7Q6视频属性的抓取
# BV号为1gf4y1m7Q6的视频属性抓取结束
# 开始BV号为1EK411p7Wy视频属性的抓取
# BV号为1EK411p7Wy的视频属性抓取结束
# 开始BV号为1pp4y1D74d视频属性的抓取
# BV号为1pp4y1D74d的视频属性抓取结束
# 开始BV号为1Az4y1X76Q视频属性的抓取
# BV号为1Az4y1X76Q的视频属性抓取结束
# 开始BV号为17g4y1v7no视频属性的抓取
# BV号为17g4y1v7no的视频属性抓取结束
# 开始BV号为1vT4y1J7hm视频属性的抓取
# BV号为1vT4y1J7hm的视频属性抓取结束
# 开始BV号为1Kp4y1D7XV视频属性的抓取
# BV号为1Kp4y1D7XV的视频属性抓取结束
# 开始BV号为18k4y1q7o7视频属性的抓取
# BV号为18k4y1q7o7的视频属性抓取结束
# 开始BV号为1vK4y14781视频属性的抓取
# BV号为1vK4y14781的视频属性抓取结束
# 开始BV号为1xK4y147gK视频属性的抓取
# BV号为1xK4y147gK的视频属性抓取结束
# 开始BV号为1BA411i7b2视频属性的抓取
# BV号为1BA411i7b2的视频属性抓取结束
# 开始BV号为1CT4y1779Y视频属性的抓取
# BV号为1CT4y1779Y的视频属性抓取结束
# 开始BV号为1cz4y1R7x1视频属性的抓取
# BV号为1cz4y1R7x1的视频属性抓取结束
# 开始BV号为1FK411W78t视频属性的抓取
# BV号为1FK411W78t的视频属性抓取结束
# 开始BV号为1bQ4y1P7j4视频属性的抓取
# BV号为1bQ4y1P7j4的视频属性抓取结束
# 开始BV号为1dA411q7Rw视频属性的抓取
# BV号为1dA411q7Rw的视频属性抓取结束
# 开始BV号为1rD4y1Q7x2视频属性的抓取
# BV号为1rD4y1Q7x2的视频属性抓取结束
# 开始BV号为17v41167UH视频属性的抓取
# BV号为17v41167UH的视频属性抓取结束
# 开始BV号为1yA411v7Sg视频属性的抓取
# BV号为1yA411v7Sg的视频属性抓取结束
# 开始BV号为1VK4y1b78Z视频属性的抓取
# BV号为1VK4y1b78Z的视频属性抓取结束
# 开始BV号为1YK411p77X视频属性的抓取
# BV号为1YK411p77X的视频属性抓取结束
# 开始BV号为1Q54y1i7Lr视频属性的抓取
# BV号为1Q54y1i7Lr的视频属性抓取结束
# 开始BV号为1gA411i7Dk视频属性的抓取
# BV号为1gA411i7Dk的视频属性抓取结束
# 开始BV号为1MK4y1474g视频属性的抓取
# BV号为1MK4y1474g的视频属性抓取结束
# 开始BV号为1oV411r72H视频属性的抓取
# BV号为1oV411r72H的视频属性抓取结束
# 开始BV号为1Y54y1B7Br视频属性的抓取
# BV号为1Y54y1B7Br的视频属性抓取结束
# 开始BV号为12T4y1E7Zs视频属性的抓取
# BV号为12T4y1E7Zs的视频属性抓取结束
# 开始BV号为1Az411i7Er视频属性的抓取
# BV号为1Az411i7Er的视频属性抓取结束
# 开始BV号为14V411k7FH视频属性的抓取
# BV号为14V411k7FH的视频属性抓取结束
# 开始BV号为1zZ4y1H7dY视频属性的抓取
# BV号为1zZ4y1H7dY的视频属性抓取结束
# 开始BV号为1354y1z7f8视频属性的抓取
# BV号为1354y1z7f8的视频属性抓取结束
# 开始BV号为1154y1B7fH视频属性的抓取
# BV号为1154y1B7fH的视频属性抓取结束
# 开始BV号为1dK4y1t7sE视频属性的抓取
# BV号为1dK4y1t7sE的视频属性抓取结束
# 开始BV号为1np4y1D7eP视频属性的抓取
# BV号为1np4y1D7eP的视频属性抓取结束
# 开始BV号为1CC4y1a7hg视频属性的抓取
# BV号为1CC4y1a7hg的视频属性抓取结束
# 开始BV号为1RZ4y1H76b视频属性的抓取
# BV号为1RZ4y1H76b的视频属性抓取结束
# 开始BV号为1WT4y1J7i2视频属性的抓取
# BV号为1WT4y1J7i2的视频属性抓取结束
# 开始BV号为1WD4y1D7oJ视频属性的抓取
# BV号为1WD4y1D7oJ的视频属性抓取结束
# 开始BV号为1kA411i7Eb视频属性的抓取
# BV号为1kA411i7Eb的视频属性抓取结束
# 开始BV号为1rT4y1E7wD视频属性的抓取
# BV号为1rT4y1E7wD的视频属性抓取结束
# 开始BV号为1yZ4y1H7zL视频属性的抓取
# BV号为1yZ4y1H7zL的视频属性抓取结束
# 开始BV号为1V5411W7N8视频属性的抓取
# BV号为1V5411W7N8的视频属性抓取结束
# 开始BV号为1DC4y1a7Ld视频属性的抓取
# BV号为1DC4y1a7Ld的视频属性抓取结束
# 开始BV号为1ot4y1X7AP视频属性的抓取
# BV号为1ot4y1X7AP的视频属性抓取结束
# 开始BV号为1mt4y1X7TJ视频属性的抓取
# BV号为1mt4y1X7TJ的视频属性抓取结束
# 开始BV号为1zQ4y1P7pi视频属性的抓取
# BV号为1zQ4y1P7pi的视频属性抓取结束
# 开始BV号为1dz4y197Vt视频属性的抓取
# BV号为1dz4y197Vt的视频属性抓取结束
# 开始BV号为1Ua4y1E7kf视频属性的抓取
# BV号为1Ua4y1E7kf的视频属性抓取结束
# 开始BV号为1JD4y1U72G视频属性的抓取
# BV号为1JD4y1U72G的视频属性抓取结束
# 开始BV号为1rh411o7Pz视频属性的抓取
# BV号为1rh411o7Pz的视频属性抓取结束
# 开始BV号为1hK4y1x7Jg视频属性的抓取
# BV号为1hK4y1x7Jg的视频属性抓取结束
# 开始BV号为1ki4y1u7TR视频属性的抓取
# BV号为1ki4y1u7TR的视频属性抓取结束
# 开始BV号为1DC4y1b7GP视频属性的抓取
# BV号为1DC4y1b7GP的视频属性抓取结束
# 开始BV号为1fV411B74C视频属性的抓取
# BV号为1fV411B74C的视频属性抓取结束
# 开始BV号为1df4y1973d视频属性的抓取
# BV号为1df4y1973d的视频属性抓取结束
# <ipython-input-10-3d45a82901b9>:190: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为13p4y1S7RN视频属性的抓取
# BV号为13p4y1S7RN的视频属性抓取结束
# 开始BV号为11p4y1U7ZW视频属性的抓取
# BV号为11p4y1U7ZW的视频属性抓取结束
# 开始BV号为13f4y1R7Nj视频属性的抓取
# BV号为13f4y1R7Nj的视频属性抓取结束
# 开始BV号为12A411e7wr视频属性的抓取
# BV号为12A411e7wr的视频属性抓取结束
# 开始BV号为1pp4y1q79g视频属性的抓取
# BV号为1pp4y1q79g的视频属性抓取结束
# 开始BV号为1kz4y1D73W视频属性的抓取
# BV号为1kz4y1D73W的视频属性抓取结束
# 开始BV号为1zT4y1j7BV视频属性的抓取
# BV号为1zT4y1j7BV的视频属性抓取结束
# 开始BV号为1qi4y1G7hN视频属性的抓取
# BV号为1qi4y1G7hN的视频属性抓取结束
# 开始BV号为19g4y1v7R4视频属性的抓取
# BV号为19g4y1v7R4的视频属性抓取结束
# 开始BV号为1Ga4y1a731视频属性的抓取
# BV号为1Ga4y1a731的视频属性抓取结束
# 开始BV号为1Ff4y1R76M视频属性的抓取
# BV号为1Ff4y1R76M的视频属性抓取结束
# 开始BV号为1EV411r7bJ视频属性的抓取
# BV号为1EV411r7bJ的视频属性抓取结束
# 开始BV号为1Gz4y1Q7dA视频属性的抓取
# BV号为1Gz4y1Q7dA的视频属性抓取结束
# 开始BV号为17z4y1Q7jC视频属性的抓取
# BV号为17z4y1Q7jC的视频属性抓取结束
# 开始BV号为1HV411z7nc视频属性的抓取
# BV号为1HV411z7nc的视频属性抓取结束
# 开始BV号为1aC4y187oz视频属性的抓取
# BV号为1aC4y187oz的视频属性抓取结束
# 开始BV号为17T4y1E7Pv视频属性的抓取
# BV号为17T4y1E7Pv的视频属性抓取结束
# 开始BV号为11v411q74a视频属性的抓取
# BV号为11v411q74a的视频属性抓取结束
# 开始BV号为1ff4y197wM视频属性的抓取
# BV号为1ff4y197wM的视频属性抓取结束
# 开始BV号为1sf4y1R7QY视频属性的抓取
# BV号为1sf4y1R7QY的视频属性抓取结束
# 开始BV号为19a4y1Y7qc视频属性的抓取
# BV号为19a4y1Y7qc的视频属性抓取结束
# 开始BV号为1u54y1S7YH视频属性的抓取
# BV号为1u54y1S7YH的视频属性抓取结束
# 开始BV号为1nh411o7oD视频属性的抓取
# BV号为1nh411o7oD的视频属性抓取结束
# 开始BV号为1kA411i7Jy视频属性的抓取
# BV号为1kA411i7Jy的视频属性抓取结束
# 开始BV号为1Ka4y1e7jG视频属性的抓取
# BV号为1Ka4y1e7jG的视频属性抓取结束
# 开始BV号为1bZ4y1u7z5视频属性的抓取
# BV号为1bZ4y1u7z5的视频属性抓取结束
# 开始BV号为1Ti4y1G7L5视频属性的抓取
# BV号为1Ti4y1G7L5的视频属性抓取结束
# 开始BV号为1Y54y1S7sg视频属性的抓取
# BV号为1Y54y1S7sg的视频属性抓取结束
# 开始BV号为1K5411e7Vf视频属性的抓取
# BV号为1K5411e7Vf的视频属性抓取结束
# 开始BV号为1Ut4y1Q7Tz视频属性的抓取
# BV号为1Ut4y1Q7Tz的视频属性抓取结束
# 开始BV号为1G5411e7k1视频属性的抓取
# BV号为1G5411e7k1的视频属性抓取结束
# 开始BV号为1RT4y177GP视频属性的抓取
# BV号为1RT4y177GP的视频属性抓取结束
# 开始BV号为1Hf4y1R7Nx视频属性的抓取
# BV号为1Hf4y1R7Nx的视频属性抓取结束
# 开始BV号为1u54y1q7sR视频属性的抓取
# BV号为1u54y1q7sR的视频属性抓取结束
# 开始BV号为1fg4y1v72o视频属性的抓取
# BV号为1fg4y1v72o的视频属性抓取结束
# 开始BV号为1Ag4y1i71w视频属性的抓取
# BV号为1Ag4y1i71w的视频属性抓取结束
# 开始BV号为1ui4y1V7uu视频属性的抓取
# BV号为1ui4y1V7uu的视频属性抓取结束
# 开始BV号为1kD4y1m7fZ视频属性的抓取
# BV号为1kD4y1m7fZ的视频属性抓取结束
# 开始BV号为1BK411H7zt视频属性的抓取
# BV号为1BK411H7zt的视频属性抓取结束
# 开始BV号为1qp4y1i7Nw视频属性的抓取
# BV号为1qp4y1i7Nw的视频属性抓取结束
# 开始BV号为18T4y1E7DG视频属性的抓取
# BV号为18T4y1E7DG的视频属性抓取结束
# 开始BV号为1kz4y1X7kn视频属性的抓取
# BV号为1kz4y1X7kn的视频属性抓取结束
# 开始BV号为1rD4y1m72E视频属性的抓取
# BV号为1rD4y1m72E的视频属性抓取结束
# 开始BV号为1V5411e7Hv视频属性的抓取
# BV号为1V5411e7Hv的视频属性抓取结束
# 开始BV号为1Sa4y1a7S5视频属性的抓取
# BV号为1Sa4y1a7S5的视频属性抓取结束
# 开始BV号为1Kg4y1i779视频属性的抓取
# BV号为1Kg4y1i779的视频属性抓取结束
# 开始BV号为11K411H7kZ视频属性的抓取
# BV号为11K411H7kZ的视频属性抓取结束
# 开始BV号为1b54y1q7Rn视频属性的抓取
# BV号为1b54y1q7Rn的视频属性抓取结束
# 开始BV号为1kz4y1X7Qk视频属性的抓取
# BV号为1kz4y1X7Qk的视频属性抓取结束
# 开始BV号为1hK4y1x7R9视频属性的抓取
# BV号为1hK4y1x7R9的视频属性抓取结束
# 开始BV号为1cz4y1Q7pz视频属性的抓取
# BV号为1cz4y1Q7pz的视频属性抓取结束
# 开始BV号为1tp4y1U7Vy视频属性的抓取
# BV号为1tp4y1U7Vy的视频属性抓取结束
# 开始BV号为1tz4y1Q7Yx视频属性的抓取
# BV号为1tz4y1Q7Yx的视频属性抓取结束
# 开始BV号为1Ni4y1G74D视频属性的抓取
# BV号为1Ni4y1G74D的视频属性抓取结束
# 开始BV号为1nT4y1j7W8视频属性的抓取
# BV号为1nT4y1j7W8的视频属性抓取结束
# 开始BV号为1hV411z7vv视频属性的抓取
# BV号为1hV411z7vv的视频属性抓取结束
# 开始BV号为1EV411z7vB视频属性的抓取
# BV号为1EV411z7vB的视频属性抓取结束
# 开始BV号为1Zf4y197By视频属性的抓取
# BV号为1Zf4y197By的视频属性抓取结束
# 开始BV号为1qi4y137E5视频属性的抓取
# BV号为1qi4y137E5的视频属性抓取结束
# 开始BV号为1Uh411o7Tw视频属性的抓取
# BV号为1Uh411o7Tw的视频属性抓取结束
# 开始BV号为1Ni4y1V7bB视频属性的抓取
# BV号为1Ni4y1V7bB的视频属性抓取结束
# 开始BV号为1ai4y1V7JR视频属性的抓取
# BV号为1ai4y1V7JR的视频属性抓取结束
# 开始BV号为1T54y1i7fj视频属性的抓取
# BV号为1T54y1i7fj的视频属性抓取结束
# 开始BV号为1bh411o7Cb视频属性的抓取
# BV号为1bh411o7Cb的视频属性抓取结束
# 开始BV号为1uK411H75a视频属性的抓取
# BV号为1uK411H75a的视频属性抓取结束
# 开始BV号为1Wi4y1V7Yd视频属性的抓取
# BV号为1Wi4y1V7Yd的视频属性抓取结束
# 开始BV号为1cC4y187WS视频属性的抓取
# BV号为1cC4y187WS的视频属性抓取结束
# 开始BV号为1rk4y1q7eh视频属性的抓取
# BV号为1rk4y1q7eh的视频属性抓取结束
# 开始BV号为1Xz4y1D7fT视频属性的抓取
# BV号为1Xz4y1D7fT的视频属性抓取结束
# 开始BV号为1KT4y1j7AE视频属性的抓取
# BV号为1KT4y1j7AE的视频属性抓取结束
# 开始BV号为1cK4y1v7QZ视频属性的抓取
# BV号为1cK4y1v7QZ的视频属性抓取结束
# 开始BV号为1vv411B7Yp视频属性的抓取
# BV号为1vv411B7Yp的视频属性抓取结束
# 开始BV号为1ii4y1G7LY视频属性的抓取
# BV号为1ii4y1G7LY的视频属性抓取结束
# 开始BV号为1g54y1q7Wg视频属性的抓取
# BV号为1g54y1q7Wg的视频属性抓取结束
# 开始BV号为1wt4y1D7Sz视频属性的抓取
# BV号为1wt4y1D7Sz的视频属性抓取结束
# 开始BV号为1ui4y1V7HQ视频属性的抓取
# BV号为1ui4y1V7HQ的视频属性抓取结束
# 开始BV号为14T4y1E7Kq视频属性的抓取
# BV号为14T4y1E7Kq的视频属性抓取结束
# 开始BV号为18A411v7UU视频属性的抓取
# BV号为18A411v7UU的视频属性抓取结束
# 开始BV号为1bv411v77Z视频属性的抓取
# BV号为1bv411v77Z的视频属性抓取结束
# 开始BV号为1Kh411d73U视频属性的抓取
# BV号为1Kh411d73U的视频属性抓取结束
# 开始BV号为1Vz411v7C1视频属性的抓取
# BV号为1Vz411v7C1的视频属性抓取结束
# 开始BV号为1da4y1a7o2视频属性的抓取
# BV号为1da4y1a7o2的视频属性抓取结束
# 开始BV号为1dZ4y1H79Y视频属性的抓取
# BV号为1dZ4y1H79Y的视频属性抓取结束
# 开始BV号为14i4y137fg视频属性的抓取
# BV号为14i4y137fg的视频属性抓取结束
# 开始BV号为1UK4y1s7J3视频属性的抓取
# BV号为1UK4y1s7J3的视频属性抓取结束
# 开始BV号为1wA411v71R视频属性的抓取
# BV号为1wA411v71R的视频属性抓取结束
# 开始BV号为1Pk4y1m7Tb视频属性的抓取
# BV号为1Pk4y1m7Tb的视频属性抓取结束
# 开始BV号为1Gv411q7j6视频属性的抓取
# BV号为1Gv411q7j6的视频属性抓取结束
# 开始BV号为15g4y1i7Yh视频属性的抓取
# BV号为15g4y1i7Yh的视频属性抓取结束
# 开始BV号为1ei4y1V7Tk视频属性的抓取
# BV号为1ei4y1V7Tk的视频属性抓取结束
# 开始BV号为1VA411v7xd视频属性的抓取
# BV号为1VA411v7xd的视频属性抓取结束
# 开始BV号为1QC4y1t7tw视频属性的抓取
# BV号为1QC4y1t7tw的视频属性抓取结束
# 开始BV号为1pz4y1Q7p2视频属性的抓取
# BV号为1pz4y1Q7p2的视频属性抓取结束
# 开始BV号为1AV411S7yc视频属性的抓取
# BV号为1AV411S7yc的视频属性抓取结束
# 开始BV号为1iT4y1j7fW视频属性的抓取
# BV号为1iT4y1j7fW的视频属性抓取结束
# 开始BV号为11Z4y1K7t6视频属性的抓取
# BV号为11Z4y1K7t6的视频属性抓取结束
# 开始BV号为1F64y1c7zN视频属性的抓取
# BV号为1F64y1c7zN的视频属性抓取结束
# 开始BV号为1rh411d75j视频属性的抓取
# BV号为1rh411d75j的视频属性抓取结束
# 开始BV号为1zT4y157pZ视频属性的抓取
# BV号为1zT4y157pZ的视频属性抓取结束
# 开始BV号为1C5411a7Mm视频属性的抓取
# BV号为1C5411a7Mm的视频属性抓取结束
# 开始BV号为1DK4y1Y78E视频属性的抓取
# BV号为1DK4y1Y78E的视频属性抓取结束
# 开始BV号为13D4y1m7Mn视频属性的抓取
# BV号为13D4y1m7Mn的视频属性抓取结束
# 开始BV号为1Vv411i7jr视频属性的抓取
# BV号为1Vv411i7jr的视频属性抓取结束
# 开始BV号为1Ep4y1v7to视频属性的抓取
# BV号为1Ep4y1v7to的视频属性抓取结束
# 开始BV号为1VV411S7zC视频属性的抓取
# BV号为1VV411S7zC的视频属性抓取结束
# 开始BV号为1AK4y1e7JD视频属性的抓取
# BV号为1AK4y1e7JD的视频属性抓取结束
# 开始BV号为1Uk4y1176B视频属性的抓取
# BV号为1Uk4y1176B的视频属性抓取结束
# 开始BV号为1op4y1v79h视频属性的抓取
# BV号为1op4y1v79h的视频属性抓取结束
# 开始BV号为17t4y1Q78m视频属性的抓取
# BV号为17t4y1Q78m的视频属性抓取结束
# 开始BV号为1m54y1i7c4视频属性的抓取
# BV号为1m54y1i7c4的视频属性抓取结束
# 开始BV号为1GC4y187vP视频属性的抓取
# BV号为1GC4y187vP的视频属性抓取结束
# 开始BV号为1Ct4y1U7GS视频属性的抓取
# BV号为1Ct4y1U7GS的视频属性抓取结束
# 开始BV号为1Ea4y1E7pP视频属性的抓取
# BV号为1Ea4y1E7pP的视频属性抓取结束
# 开始BV号为1754y1e79y视频属性的抓取
# BV号为1754y1e79y的视频属性抓取结束
# 开始BV号为1Nv411i7sv视频属性的抓取
# BV号为1Nv411i7sv的视频属性抓取结束
# 开始BV号为1tD4y127E8视频属性的抓取
# BV号为1tD4y127E8的视频属性抓取结束
# 开始BV号为18v411i7QV视频属性的抓取
# BV号为18v411i7QV的视频属性抓取结束
# 开始BV号为1F54y1v7q8视频属性的抓取
# BV号为1F54y1v7q8的视频属性抓取结束
# 开始BV号为11V411z7yw视频属性的抓取
# BV号为11V411z7yw的视频属性抓取结束
# 开始BV号为1X54y1e7dn视频属性的抓取
# BV号为1X54y1e7dn的视频属性抓取结束
# 开始BV号为1HV411z7f7视频属性的抓取
# BV号为1HV411z7f7的视频属性抓取结束
# 开始BV号为15K411T7CD视频属性的抓取
# BV号为15K411T7CD的视频属性抓取结束
# 开始BV号为1554y1v79q视频属性的抓取
# BV号为1554y1v79q的视频属性抓取结束
# 开始BV号为1KT4y177NW视频属性的抓取
# BV号为1KT4y177NW的视频属性抓取结束
# 开始BV号为1JC4y187vf视频属性的抓取
# BV号为1JC4y187vf的视频属性抓取结束
# 开始BV号为11V411U7Q2视频属性的抓取
# BV号为11V411U7Q2的视频属性抓取结束
# 开始BV号为1Nt4y1Q7vU视频属性的抓取
# BV号为1Nt4y1Q7vU的视频属性抓取结束
# 开始BV号为1DZ4y1T7va视频属性的抓取
# BV号为1DZ4y1T7va的视频属性抓取结束
# 开始BV号为1jT4y1L7wy视频属性的抓取
# BV号为1jT4y1L7wy的视频属性抓取结束
# 开始BV号为1jh411o7vn视频属性的抓取
# BV号为1jh411o7vn的视频属性抓取结束
# 开始BV号为11i4y1M751视频属性的抓取
# BV号为11i4y1M751的视频属性抓取结束
# 开始BV号为18K4y1Y7mw视频属性的抓取
# BV号为18K4y1Y7mw的视频属性抓取结束
# 开始BV号为16V411U7tP视频属性的抓取
# BV号为16V411U7tP的视频属性抓取结束
# 开始BV号为1ph411R7fD视频属性的抓取
# BV号为1ph411R7fD的视频属性抓取结束
# 开始BV号为1Ez4y1f7LK视频属性的抓取
# BV号为1Ez4y1f7LK的视频属性抓取结束
# 开始BV号为1RA411Y7F6视频属性的抓取
# BV号为1RA411Y7F6的视频属性抓取结束
# 开始BV号为1gh411Z7a1视频属性的抓取
# BV号为1gh411Z7a1的视频属性抓取结束
# 开始BV号为1UV411z78C视频属性的抓取
# BV号为1UV411z78C的视频属性抓取结束
# 开始BV号为1bh411d7eJ视频属性的抓取
# BV号为1bh411d7eJ的视频属性抓取结束
# 开始BV号为1nK4y1v7BR视频属性的抓取
# BV号为1nK4y1v7BR的视频属性抓取结束
# 开始BV号为1St4y1U72u视频属性的抓取
# BV号为1St4y1U72u的视频属性抓取结束
# 开始BV号为1TV411z7Jj视频属性的抓取
# BV号为1TV411z7Jj的视频属性抓取结束
# 开始BV号为1454y127R4视频属性的抓取
# BV号为1454y127R4的视频属性抓取结束
# 开始BV号为1kV411U7T9视频属性的抓取
# BV号为1kV411U7T9的视频属性抓取结束
# 开始BV号为1Sp4y1Y7G2视频属性的抓取
# BV号为1Sp4y1Y7G2的视频属性抓取结束
# 开始BV号为1Kk4y1U7mt视频属性的抓取
# BV号为1Kk4y1U7mt的视频属性抓取结束
# 开始BV号为1f54y1v793视频属性的抓取
# BV号为1f54y1v793的视频属性抓取结束
# 开始BV号为1fi4y1374k视频属性的抓取
# BV号为1fi4y1374k的视频属性抓取结束
# 开始BV号为1EK4y1e7Vb视频属性的抓取
# BV号为1EK4y1e7Vb的视频属性抓取结束
# 开始BV号为15h411d74z视频属性的抓取
# BV号为15h411d74z的视频属性抓取结束
# 开始BV号为1qa4y1J7Z4视频属性的抓取
# BV号为1qa4y1J7Z4的视频属性抓取结束
# 开始BV号为1vD4y127kD视频属性的抓取
# BV号为1vD4y127kD的视频属性抓取结束
# 开始BV号为1zZ4y1M7Si视频属性的抓取
# BV号为1zZ4y1M7Si的视频属性抓取结束
# 开始BV号为12a4y1J7wQ视频属性的抓取
# BV号为12a4y1J7wQ的视频属性抓取结束
# 开始BV号为1cT4y1L72K视频属性的抓取
# BV号为1cT4y1L72K的视频属性抓取结束
# 开始BV号为1ia4y177p7视频属性的抓取
# BV号为1ia4y177p7的视频属性抓取结束
# 开始BV号为1Hf4y197DU视频属性的抓取
# BV号为1Hf4y197DU的视频属性抓取结束
# 开始BV号为1AD4y1m7qE视频属性的抓取
# BV号为1AD4y1m7qE的视频属性抓取结束
# 开始BV号为1jK4y1v7D1视频属性的抓取
# BV号为1jK4y1v7D1的视频属性抓取结束
# 开始BV号为1CD4y1U7Nx视频属性的抓取
# BV号为1CD4y1U7Nx的视频属性抓取结束
# 开始BV号为1JT4y1L7y1视频属性的抓取
# BV号为1JT4y1L7y1的视频属性抓取结束
# 开始BV号为18i4y1M7fE视频属性的抓取
# BV号为18i4y1M7fE的视频属性抓取结束
# 开始BV号为1Xk4y1m7Zn视频属性的抓取
# BV号为1Xk4y1m7Zn的视频属性抓取结束
# 开始BV号为1Mp4y1i7P8视频属性的抓取
# BV号为1Mp4y1i7P8的视频属性抓取结束
# 开始BV号为1BK4y1v7pJ视频属性的抓取
# BV号为1BK4y1v7pJ的视频属性抓取结束
# 开始BV号为1bD4y1m7tL视频属性的抓取
# BV号为1bD4y1m7tL的视频属性抓取结束
# 开始BV号为1E54y12764视频属性的抓取
# BV号为1E54y12764的视频属性抓取结束
# 开始BV号为15p4y1v7UD视频属性的抓取
# BV号为15p4y1v7UD的视频属性抓取结束
# 开始BV号为1PV411S7ht视频属性的抓取
# BV号为1PV411S7ht的视频属性抓取结束
# 开始BV号为16K4y1v7cP视频属性的抓取
# BV号为16K4y1v7cP的视频属性抓取结束
# 开始BV号为1B5411h7um视频属性的抓取
# BV号为1B5411h7um的视频属性抓取结束
# 开始BV号为1bv411v7N9视频属性的抓取
# BV号为1bv411v7N9的视频属性抓取结束
# 开始BV号为18C4y1t7Pq视频属性的抓取
# BV号为18C4y1t7Pq的视频属性抓取结束
# 开始BV号为1V5411b7Uv视频属性的抓取
# BV号为1V5411b7Uv的视频属性抓取结束
# 开始BV号为1oi4y1u7Bf视频属性的抓取
# BV号为1oi4y1u7Bf的视频属性抓取结束
# 开始BV号为1rf4y1Q73o视频属性的抓取
# BV号为1rf4y1Q73o的视频属性抓取结束
# 开始BV号为1Fv41117nR视频属性的抓取
# BV号为1Fv41117nR的视频属性抓取结束
# 开始BV号为1B54y1m748视频属性的抓取
# BV号为1B54y1m748的视频属性抓取结束
# 开始BV号为1Qf4y197Va视频属性的抓取
# BV号为1Qf4y197Va的视频属性抓取结束
# 开始BV号为1Xh411d7bv视频属性的抓取
# BV号为1Xh411d7bv的视频属性抓取结束
# 开始BV号为1ra4y1E7ga视频属性的抓取
# BV号为1ra4y1E7ga的视频属性抓取结束
# 开始BV号为1mv411q7Vt视频属性的抓取
# BV号为1mv411q7Vt的视频属性抓取结束
# 开始BV号为1LK411T7kv视频属性的抓取
# BV号为1LK411T7kv的视频属性抓取结束
# 开始BV号为14A411Y7pX视频属性的抓取
# BV号为14A411Y7pX的视频属性抓取结束
# 开始BV号为1jZ4y1T7Zi视频属性的抓取
# BV号为1jZ4y1T7Zi的视频属性抓取结束
# 开始BV号为1ma4y177ck视频属性的抓取
# BV号为1ma4y177ck的视频属性抓取结束
# 开始BV号为1PC4y1t7R5视频属性的抓取
# BV号为1PC4y1t7R5的视频属性抓取结束
# 开始BV号为1Jf4y197NH视频属性的抓取
# BV号为1Jf4y197NH的视频属性抓取结束
# 开始BV号为1up4y1v7ua视频属性的抓取
# BV号为1up4y1v7ua的视频属性抓取结束
# 开始BV号为19Z4y1P7ZU视频属性的抓取
# BV号为19Z4y1P7ZU的视频属性抓取结束
# 开始BV号为1164y1c72v视频属性的抓取
# BV号为1164y1c72v的视频属性抓取结束
# 开始BV号为19K4y1a7Xa视频属性的抓取
# BV号为19K4y1a7Xa的视频属性抓取结束
# 开始BV号为1yK411N7ES视频属性的抓取
# BV号为1yK411N7ES的视频属性抓取结束
# 开始BV号为1VT4y1c7PA视频属性的抓取
# BV号为1VT4y1c7PA的视频属性抓取结束
# 开始BV号为14h411X7PD视频属性的抓取
# BV号为14h411X7PD的视频属性抓取结束
# 开始BV号为1Hi4y1u7ts视频属性的抓取
# BV号为1Hi4y1u7ts的视频属性抓取结束
# 开始BV号为1bp4y1e75t视频属性的抓取
# BV号为1bp4y1e75t的视频属性抓取结束
# 开始BV号为1vi4y1M72p视频属性的抓取
# BV号为1vi4y1M72p的视频属性抓取结束
# 开始BV号为1Gz4y1f7nx视频属性的抓取
# BV号为1Gz4y1f7nx的视频属性抓取结束
# 开始BV号为13h41197aH视频属性的抓取
# BV号为13h41197aH的视频属性抓取结束
# 开始BV号为1dK4y1h7GE视频属性的抓取
# BV号为1dK4y1h7GE的视频属性抓取结束
# 开始BV号为1uA411J7LQ视频属性的抓取
# BV号为1uA411J7LQ的视频属性抓取结束
# 开始BV号为1qf4y1D7gk视频属性的抓取
# BV号为1qf4y1D7gk的视频属性抓取结束
# 开始BV号为12D4y1d7Fv视频属性的抓取
# BV号为12D4y1d7Fv的视频属性抓取结束
# 开始BV号为1BT4y1L7kZ视频属性的抓取
# BV号为1BT4y1L7kZ的视频属性抓取结束
# 开始BV号为1qt4y1i7uB视频属性的抓取
# BV号为1qt4y1i7uB的视频属性抓取结束
# 开始BV号为1gK4y1Y7vf视频属性的抓取
# BV号为1gK4y1Y7vf的视频属性抓取结束
# 开始BV号为1gf4y1D7rp视频属性的抓取
# BV号为1gf4y1D7rp的视频属性抓取结束
# 开始BV号为1X5411b7Ho视频属性的抓取
# BV号为1X5411b7Ho的视频属性抓取结束
# 开始BV号为1754y12711视频属性的抓取
# BV号为1754y12711的视频属性抓取结束
# 开始BV号为1rv411C7i6视频属性的抓取
# BV号为1rv411C7i6的视频属性抓取结束
# 开始BV号为1mA411E7Ar视频属性的抓取
# BV号为1mA411E7Ar的视频属性抓取结束
# 开始BV号为1GT4y1c7xV视频属性的抓取
# BV号为1GT4y1c7xV的视频属性抓取结束
# 开始BV号为16h411R7TG视频属性的抓取
# BV号为16h411R7TG的视频属性抓取结束
# 开始BV号为1c54y1m7ze视频属性的抓取
# BV号为1c54y1m7ze的视频属性抓取结束
# 开始BV号为1T541187Mn视频属性的抓取
# BV号为1T541187Mn的视频属性抓取结束
# 开始BV号为1HK4y1e7rE视频属性的抓取
# BV号为1HK4y1e7rE的视频属性抓取结束
# 开始BV号为1yZ4y1N7DN视频属性的抓取
# BV号为1yZ4y1N7DN的视频属性抓取结束
# 开始BV号为1Dh411X7hE视频属性的抓取
# BV号为1Dh411X7hE的视频属性抓取结束
# 开始BV号为1fv411y7D4视频属性的抓取
# BV号为1fv411y7D4的视频属性抓取结束
# 开始BV号为1Na4y1j7if视频属性的抓取
# BV号为1Na4y1j7if的视频属性抓取结束
# 开始BV号为1ry4y1y7uw视频属性的抓取
# BV号为1ry4y1y7uw的视频属性抓取结束
# 开始BV号为1kT4y1A7Ps视频属性的抓取
# BV号为1kT4y1A7Ps的视频属性抓取结束
# 开始BV号为1P54y1y7zd视频属性的抓取
# BV号为1P54y1y7zd的视频属性抓取结束
# 开始BV号为1Pp4y1e779视频属性的抓取
# BV号为1Pp4y1e779的视频属性抓取结束
# 开始BV号为1ja4y1j7Jn视频属性的抓取
# BV号为1ja4y1j7Jn的视频属性抓取结束
# 开始BV号为1yh411X7cJ视频属性的抓取
# BV号为1yh411X7cJ的视频属性抓取结束
# 开始BV号为1Ga4y1E7a3视频属性的抓取
# BV号为1Ga4y1E7a3的视频属性抓取结束
# 开始BV号为1Tp4y1e7i8视频属性的抓取
# BV号为1Tp4y1e7i8的视频属性抓取结束
# 开始BV号为1yp4y1e78d视频属性的抓取
# BV号为1yp4y1e78d的视频属性抓取结束
# 开始BV号为1kz4y1Z7UJ视频属性的抓取
# BV号为1kz4y1Z7UJ的视频属性抓取结束
# 开始BV号为1Sh411R7s1视频属性的抓取
# BV号为1Sh411R7s1的视频属性抓取结束
# 开始BV号为1RV411m7cM视频属性的抓取
# BV号为1RV411m7cM的视频属性抓取结束
# 开始BV号为1d54y1y7wp视频属性的抓取
# BV号为1d54y1y7wp的视频属性抓取结束
# 开始BV号为1bh411R7xs视频属性的抓取
# BV号为1bh411R7xs的视频属性抓取结束
# 开始BV号为1T54y1m7DM视频属性的抓取
# BV号为1T54y1m7DM的视频属性抓取结束
# 开始BV号为1xK411K7sF视频属性的抓取
# BV号为1xK411K7sF的视频属性抓取结束
# 开始BV号为1Lz4y1Z7A5视频属性的抓取
# BV号为1Lz4y1Z7A5的视频属性抓取结束
# 开始BV号为1Sh411R7iB视频属性的抓取
# BV号为1Sh411R7iB的视频属性抓取结束
# 开始BV号为1Gi4y1E7Ff视频属性的抓取
# BV号为1Gi4y1E7Ff的视频属性抓取结束
# 开始BV号为1Wp4y1a7Dg视频属性的抓取
# BV号为1Wp4y1a7Dg的视频属性抓取结束
# 开始BV号为1jv411y7Ca视频属性的抓取
# BV号为1jv411y7Ca的视频属性抓取结束
# 开始BV号为1AV411m7i4视频属性的抓取
# BV号为1AV411m7i4的视频属性抓取结束
# 开始BV号为1rz4y1Z7wf视频属性的抓取
# BV号为1rz4y1Z7wf的视频属性抓取结束
# 开始BV号为1ck4y117ys视频属性的抓取
# BV号为1ck4y117ys的视频属性抓取结束
# 开始BV号为1564y1F7fu视频属性的抓取
# BV号为1564y1F7fu的视频属性抓取结束
# 开始BV号为13K411K7fq视频属性的抓取
# BV号为13K411K7fq的视频属性抓取结束
# 开始BV号为12a4y157nD视频属性的抓取
# BV号为12a4y157nD的视频属性抓取结束
# 开始BV号为1dh411R7Kg视频属性的抓取
# BV号为1dh411R7Kg的视频属性抓取结束
# 开始BV号为1cD4y1o7Fb视频属性的抓取
# BV号为1cD4y1o7Fb的视频属性抓取结束
# 开始BV号为18K4y1e7Ek视频属性的抓取
# BV号为18K4y1e7Ek的视频属性抓取结束
# 开始BV号为11v411C7iF视频属性的抓取
# BV号为11v411C7iF的视频属性抓取结束
# 开始BV号为1x54y1y78p视频属性的抓取
# BV号为1x54y1y78p的视频属性抓取结束
# 开始BV号为1rT4y1w7ti视频属性的抓取
# BV号为1rT4y1w7ti的视频属性抓取结束
# 开始BV号为1F64y1F7bc视频属性的抓取
# BV号为1F64y1F7bc的视频属性抓取结束
# 开始BV号为14i4y1E7Km视频属性的抓取
# BV号为14i4y1E7Km的视频属性抓取结束
# 开始BV号为1QV41127oJ视频属性的抓取
# BV号为1QV41127oJ的视频属性抓取结束
# 开始BV号为1BZ4y1N7aM视频属性的抓取
# BV号为1BZ4y1N7aM的视频属性抓取结束
# 开始BV号为1qz4y1d7DD视频属性的抓取
# BV号为1qz4y1d7DD的视频属性抓取结束
# 开始BV号为1jT4y1A7o9视频属性的抓取
# BV号为1jT4y1A7o9的视频属性抓取结束
# 开始BV号为1v5411h7z7视频属性的抓取
# BV号为1v5411h7z7的视频属性抓取结束
# 开始BV号为15541187bG视频属性的抓取
# BV号为15541187bG的视频属性抓取结束
# 开始BV号为1zt4y1S7dj视频属性的抓取
# BV号为1zt4y1S7dj的视频属性抓取结束
# 开始BV号为14h411R7V7视频属性的抓取
# BV号为14h411R7V7的视频属性抓取结束
# 开始BV号为1Fz4y1Z78Y视频属性的抓取
# BV号为1Fz4y1Z78Y的视频属性抓取结束
# 开始BV号为14f4y1X73Z视频属性的抓取
# BV号为14f4y1X73Z的视频属性抓取结束
# 开始BV号为1PA411J7cn视频属性的抓取
# BV号为1PA411J7cn的视频属性抓取结束
# 开始BV号为1Lp4y1e72y视频属性的抓取
# BV号为1Lp4y1e72y的视频属性抓取结束
# 开始BV号为1YA411E7bp视频属性的抓取
# BV号为1YA411E7bp的视频属性抓取结束
# 开始BV号为1nK411K7sz视频属性的抓取
# BV号为1nK411K7sz的视频属性抓取结束
# 开始BV号为17t4y1q7oV视频属性的抓取
# BV号为17t4y1q7oV的视频属性抓取结束
# 开始BV号为1YK4y1a7Hy视频属性的抓取
# BV号为1YK4y1a7Hy的视频属性抓取结束
# 开始BV号为1Dv41117QP视频属性的抓取
# BV号为1Dv41117QP的视频属性抓取结束
# 开始BV号为1Xv411C7Ge视频属性的抓取
# BV号为1Xv411C7Ge的视频属性抓取结束
# 开始BV号为1qk4y1y7ZA视频属性的抓取
# BV号为1qk4y1y7ZA的视频属性抓取结束
# 开始BV号为1T54y1m7vb视频属性的抓取
# BV号为1T54y1m7vb的视频属性抓取结束
# 开始BV号为1X5411b7VP视频属性的抓取
# BV号为1X5411b7VP的视频属性抓取结束
# 开始BV号为1NA41177Yv视频属性的抓取
# BV号为1NA41177Yv的视频属性抓取结束
# 开始BV号为12y4y1y7Sd视频属性的抓取
# BV号为12y4y1y7Sd的视频属性抓取结束
# 开始BV号为1na4y1E779视频属性的抓取
# BV号为1na4y1E779的视频属性抓取结束
# 开始BV号为1rv41117Pt视频属性的抓取
# BV号为1rv41117Pt的视频属性抓取结束
# 开始BV号为1qA411n75p视频属性的抓取
# BV号为1qA411n75p的视频属性抓取结束
# 开始BV号为1Et4y1S7qN视频属性的抓取
# BV号为1Et4y1S7qN的视频属性抓取结束
# 开始BV号为1Gi4y1u7Hq视频属性的抓取
# BV号为1Gi4y1u7Hq的视频属性抓取结束
# 开始BV号为1Ya4y1j7Vt视频属性的抓取
# BV号为1Ya4y1j7Vt的视频属性抓取结束
# 开始BV号为1LK411K7YR视频属性的抓取
# BV号为1LK411K7YR的视频属性抓取结束
# 开始BV号为1AT4y1A7EG视频属性的抓取
# BV号为1AT4y1A7EG的视频属性抓取结束
# 开始BV号为1Y5411h7ZQ视频属性的抓取
# BV号为1Y5411h7ZQ的视频属性抓取结束
# 开始BV号为1MA411J7QT视频属性的抓取
# BV号为1MA411J7QT的视频属性抓取结束
# 开始BV号为1NZ4y1N72q视频属性的抓取
# BV号为1NZ4y1N72q的视频属性抓取结束
# 开始BV号为1gt4y1i7V9视频属性的抓取
# BV号为1gt4y1i7V9的视频属性抓取结束
# 开始BV号为1DZ4y1G7ji视频属性的抓取
# BV号为1DZ4y1G7ji的视频属性抓取结束
# 开始BV号为1EK411A7Dp视频属性的抓取
# BV号为1EK411A7Dp的视频属性抓取结束
# 开始BV号为1oa4y1W7XE视频属性的抓取
# BV号为1oa4y1W7XE的视频属性抓取结束
# 开始BV号为1Fk4y1y7mn视频属性的抓取
# BV号为1Fk4y1y7mn的视频属性抓取结束
# 开始BV号为1sZ4y157q8视频属性的抓取
# BV号为1sZ4y157q8的视频属性抓取结束
# 开始BV号为1Cp4y1k7FL视频属性的抓取
# BV号为1Cp4y1k7FL的视频属性抓取结束
# 开始BV号为15D4y197m2视频属性的抓取
# BV号为15D4y197m2的视频属性抓取结束
# 开始BV号为1TV411y7L3视频属性的抓取
# BV号为1TV411y7L3的视频属性抓取结束
# 开始BV号为1VZ4y157rP视频属性的抓取
# BV号为1VZ4y157rP的视频属性抓取结束
# 开始BV号为1zA411J7tt视频属性的抓取
# BV号为1zA411J7tt的视频属性抓取结束
# 开始BV号为1HD4y1d7zU视频属性的抓取
# BV号为1HD4y1d7zU的视频属性抓取结束
# 开始BV号为1c541177vu视频属性的抓取
# BV号为1c541177vu的视频属性抓取结束
# 开始BV号为1Z54y167aU视频属性的抓取
# BV号为1Z54y167aU的视频属性抓取结束
# 开始BV号为15v411k71E视频属性的抓取
# BV号为15v411k71E的视频属性抓取结束
# 开始BV号为17V411y75i视频属性的抓取
# BV号为17V411y75i的视频属性抓取结束
# 开始BV号为1Hz4y1o7Am视频属性的抓取
# BV号为1Hz4y1o7Am的视频属性抓取结束
# 开始BV号为1ov411r792视频属性的抓取
# BV号为1ov411r792的视频属性抓取结束
# 开始BV号为1wa411A76u视频属性的抓取
# BV号为1wa411A76u的视频属性抓取结束
# 开始BV号为1WK411N78A视频属性的抓取
# BV号为1WK411N78A的视频属性抓取结束
# 开始BV号为1ot4y1Y7ME视频属性的抓取
# BV号为1ot4y1Y7ME的视频属性抓取结束
# 开始BV号为1di4y1E74B视频属性的抓取
# BV号为1di4y1E74B的视频属性抓取结束
# 开始BV号为1D54y1k7k8视频属性的抓取
# BV号为1D54y1k7k8的视频属性抓取结束
# 开始BV号为1Yf4y1i7uz视频属性的抓取
# BV号为1Yf4y1i7uz的视频属性抓取结束
# 开始BV号为1BA41177u7视频属性的抓取
# BV号为1BA41177u7的视频属性抓取结束
# 开始BV号为1oa4y1W762视频属性的抓取
# BV号为1oa4y1W762的视频属性抓取结束
# 开始BV号为1QK4y1h7WD视频属性的抓取
# BV号为1QK4y1h7WD的视频属性抓取结束
# 开始BV号为1ip4y1Y7KE视频属性的抓取
# BV号为1ip4y1Y7KE的视频属性抓取结束
# 开始BV号为1FK4y1E7aM视频属性的抓取
# BV号为1FK4y1E7aM的视频属性抓取结束
# 开始BV号为1Gp4y1k71P视频属性的抓取
# BV号为1Gp4y1k71P的视频属性抓取结束
# 开始BV号为1jA41177UK视频属性的抓取
# BV号为1jA41177UK的视频属性抓取结束
# 开始BV号为16K4y17797视频属性的抓取
# BV号为16K4y17797的视频属性抓取结束
# 开始BV号为175411L7Hi视频属性的抓取
# BV号为175411L7Hi的视频属性抓取结束
# 开始BV号为1J54y1C7EF视频属性的抓取
# BV号为1J54y1C7EF的视频属性抓取结束
# 开始BV号为12f4y1i7Ye视频属性的抓取
# BV号为12f4y1i7Ye的视频属性抓取结束
# 开始BV号为1qT4y1c7gw视频属性的抓取
# BV号为1qT4y1c7gw的视频属性抓取结束
# 开始BV号为16a4y1L7j4视频属性的抓取
# BV号为16a4y1L7j4的视频属性抓取结束
# 开始BV号为1Ta4y1L76Q视频属性的抓取
# BV号为1Ta4y1L76Q的视频属性抓取结束
# 开始BV号为1Gi4y177vS视频属性的抓取
# BV号为1Gi4y177vS的视频属性抓取结束
# 开始BV号为1m54y1k7fF视频属性的抓取
# BV号为1m54y1k7fF的视频属性抓取结束
# 开始BV号为1654y1k72Z视频属性的抓取
# BV号为1654y1k72Z的视频属性抓取结束
# 开始BV号为1EK411A7Ui视频属性的抓取
# BV号为1EK411A7Ui的视频属性抓取结束
# 开始BV号为1dy4y1b74S视频属性的抓取
# BV号为1dy4y1b74S的视频属性抓取结束
# 开始BV号为1Xz4y1d72i视频属性的抓取
# BV号为1Xz4y1d72i的视频属性抓取结束
# 开始BV号为1GA411j76e视频属性的抓取
# BV号为1GA411j76e的视频属性抓取结束
# 开始BV号为1KD4y1d75E视频属性的抓取
# BV号为1KD4y1d75E的视频属性抓取结束
# 开始BV号为1by4y1C74W视频属性的抓取
# BV号为1by4y1C74W的视频属性抓取结束
# 开始BV号为1uy4y1C76V视频属性的抓取
# BV号为1uy4y1C76V的视频属性抓取结束
# 开始BV号为1tv411y7vy视频属性的抓取
# BV号为1tv411y7vy的视频属性抓取结束
# 开始BV号为1Gz4y1f78X视频属性的抓取
# BV号为1Gz4y1f78X的视频属性抓取结束
# 开始BV号为1vK4y177mv视频属性的抓取
# BV号为1vK4y177mv的视频属性抓取结束
# 开始BV号为1ev411y72L视频属性的抓取
# BV号为1ev411y72L的视频属性抓取结束
# 开始BV号为1Np4y1Y7AF视频属性的抓取
# BV号为1Np4y1Y7AF的视频属性抓取结束
# 开始BV号为1gi4y177wU视频属性的抓取
# BV号为1gi4y177wU的视频属性抓取结束
# 开始BV号为1Ky4y1r7ru视频属性的抓取
# BV号为1Ky4y1r7ru的视频属性抓取结束
# 开始BV号为1ay4y1r7cx视频属性的抓取
# BV号为1ay4y1r7cx的视频属性抓取结束
# 开始BV号为16f4y1B7Lw视频属性的抓取
# BV号为16f4y1B7Lw的视频属性抓取结束
# 开始BV号为1gv411C7mN视频属性的抓取
# BV号为1gv411C7mN的视频属性抓取结束
# 开始BV号为1Vv411k72i视频属性的抓取
# BV号为1Vv411k72i的视频属性抓取结束
# 开始BV号为1h5411j7UU视频属性的抓取
# BV号为1h5411j7UU的视频属性抓取结束
# 开始BV号为1st4y1i7Mx视频属性的抓取
# BV号为1st4y1i7Mx的视频属性抓取结束
# 开始BV号为1df4y1B7Lu视频属性的抓取
# BV号为1df4y1B7Lu的视频属性抓取结束
# 开始BV号为1sy4y1B7tx视频属性的抓取
# BV号为1sy4y1B7tx的视频属性抓取结束
# 开始BV号为1w5411L7aR视频属性的抓取
# BV号为1w5411L7aR的视频属性抓取结束
# 开始BV号为1j54y1k7ZN视频属性的抓取
# BV号为1j54y1k7ZN的视频属性抓取结束
# 开始BV号为1KK411A7WW视频属性的抓取
# BV号为1KK411A7WW的视频属性抓取结束
# 开始BV号为1uZ4y1L7g6视频属性的抓取
# BV号为1uZ4y1L7g6的视频属性抓取结束
# 开始BV号为1uh411978u视频属性的抓取
# BV号为1uh411978u的视频属性抓取结束
# 开始BV号为1Ft4y1e7Gm视频属性的抓取
# BV号为1Ft4y1e7Gm的视频属性抓取结束
# 开始BV号为1Rk4y1C7J5视频属性的抓取
# BV号为1Rk4y1C7J5的视频属性抓取结束
# 开始BV号为16V41117yp视频属性的抓取
# BV号为16V41117yp的视频属性抓取结束
# 开始BV号为1ya4y1s7Ff视频属性的抓取
# BV号为1ya4y1s7Ff的视频属性抓取结束
# 开始BV号为1fK4y1f7TH视频属性的抓取
# BV号为1fK4y1f7TH的视频属性抓取结束
# 开始BV号为1Za411A7c4视频属性的抓取
# BV号为1Za411A7c4的视频属性抓取结束
# 开始BV号为1WT4y1w7er视频属性的抓取
# BV号为1WT4y1w7er的视频属性抓取结束
# 开始BV号为1zy4y1B7ky视频属性的抓取
# BV号为1zy4y1B7ky的视频属性抓取结束
# 开始BV号为11i4y1E7p3视频属性的抓取
# BV号为11i4y1E7p3的视频属性抓取结束
# 开始BV号为1By4y1C7Kg视频属性的抓取
# BV号为1By4y1C7Kg的视频属性抓取结束
# 开始BV号为1ZK411A7zd视频属性的抓取
# BV号为1ZK411A7zd的视频属性抓取结束
# 开始BV号为13A411E7Hn视频属性的抓取
# BV号为13A411E7Hn的视频属性抓取结束
# 开始BV号为1xy4y1C7Mi视频属性的抓取
# BV号为1xy4y1C7Mi的视频属性抓取结束
# 开始BV号为1jV41127id视频属性的抓取
# BV号为1jV41127id的视频属性抓取结束
# 开始BV号为1Pv411C7dm视频属性的抓取
# BV号为1Pv411C7dm的视频属性抓取结束
# 开始BV号为13p4y1k7nB视频属性的抓取
# BV号为13p4y1k7nB的视频属性抓取结束
# 开始BV号为1YT4y1c7xs视频属性的抓取
# BV号为1YT4y1c7xs的视频属性抓取结束
# 开始BV号为1Gp4y1k7vs视频属性的抓取
# BV号为1Gp4y1k7vs的视频属性抓取结束
# 开始BV号为1Yi4y1j76K视频属性的抓取
# BV号为1Yi4y1j76K的视频属性抓取结束
# 开始BV号为1RA41177rB视频属性的抓取
# BV号为1RA41177rB的视频属性抓取结束
# 开始BV号为1my4y1k7xX视频属性的抓取
# BV号为1my4y1k7xX的视频属性抓取结束
# 开始BV号为1ep4y1k7sV视频属性的抓取
# BV号为1ep4y1k7sV的视频属性抓取结束
# 开始BV号为1tK4y1h7Sp视频属性的抓取
# BV号为1tK4y1h7Sp的视频属性抓取结束
# 开始BV号为1Np4y1Y7vz视频属性的抓取
# BV号为1Np4y1Y7vz的视频属性抓取结束
# 开始BV号为1yt4y1v7Vr视频属性的抓取
# BV号为1yt4y1v7Vr的视频属性抓取结束
# 开始BV号为1xA411E7cQ视频属性的抓取
# BV号为1xA411E7cQ的视频属性抓取结束
# 开始BV号为1Za411A7Tu视频属性的抓取
# BV号为1Za411A7Tu的视频属性抓取结束
# 开始BV号为17V41127Ci视频属性的抓取
# BV号为17V41127Ci的视频属性抓取结束
# 开始BV号为1x5411j7ZR视频属性的抓取
# BV号为1x5411j7ZR的视频属性抓取结束
# 开始BV号为1J54y1r7rU视频属性的抓取
# BV号为1J54y1r7rU的视频属性抓取结束
# 开始BV号为1uv411C75d视频属性的抓取
# BV号为1uv411C75d的视频属性抓取结束
# 2020-12-25 23:28:25.518646

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-14-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_guichu_renli.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月    99   99    99   99   99   99   99   99    99      99   99    99   99
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月     99   99    99   99   99   99   99   99    99      99   99    99   99
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月   99   99   99   99   99   99    99
# 1月   100  100  100  100  100  100   100
# 2月   100  100  100  100  100  100   100
# 3月   100  100  100  100  100  100   100
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月   100  100  100  100  100  100   100
# 7月    99   99   99   99   99   99    99
# 8月   100  100  100  100  100  100   100
# 9月    99   99   99   99   99   99    99

# %%
channel_guichu_renli.to_json('channel_guichu_renli.json')
