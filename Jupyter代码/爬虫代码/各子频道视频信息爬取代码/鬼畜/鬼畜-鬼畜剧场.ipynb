# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_guichu_jvchang=pd.DataFrame(columns=columns)
channel_guichu_jvchang
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[10]/div/a/span').click()  #选择频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[10]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '鬼畜'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[5]/a').click()  #选择子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[5]/a').text
sub_channel
# Out:
# '鬼畜剧场'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(1,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_guichu_jvchang.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-16 23:40:45.986342
# <ipython-input-9-3c763d3225d6>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-9-3c763d3225d6>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-9-3c763d3225d6>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1TJ411L7B8视频属性的抓取
# BV号为1TJ411L7B8的视频属性抓取结束
# <ipython-input-9-3c763d3225d6>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1gJ41157qx视频属性的抓取
# BV号为1gJ41157qx的视频属性抓取结束
# 开始BV号为1U7411r7LL视频属性的抓取
# BV号为1U7411r7LL的视频属性抓取结束
# 开始BV号为1BJ411b7nB视频属性的抓取
# BV号为1BJ411b7nB的视频属性抓取结束
# 开始BV号为147411r7tR视频属性的抓取
# BV号为147411r7tR的视频属性抓取结束
# 开始BV号为1d7411r7Bs视频属性的抓取
# BV号为1d7411r7Bs的视频属性抓取结束
# 开始BV号为1S7411q7eH视频属性的抓取
# BV号为1S7411q7eH的视频属性抓取结束
# 开始BV号为157411q7rR视频属性的抓取
# BV号为157411q7rR的视频属性抓取结束
# 开始BV号为16J411J7cn视频属性的抓取
# BV号为16J411J7cn的视频属性抓取结束
# 开始BV号为1a7411e7tt视频属性的抓取
# BV号为1a7411e7tt的视频属性抓取结束
# 开始BV号为1aJ411V7Fe视频属性的抓取
# BV号为1aJ411V7Fe的视频属性抓取结束
# 开始BV号为1d7411q7pc视频属性的抓取
# BV号为1d7411q7pc的视频属性抓取结束
# 开始BV号为1vJ411p7b7视频属性的抓取
# BV号为1vJ411p7b7的视频属性抓取结束
# 开始BV号为1u7411Y7ak视频属性的抓取
# BV号为1u7411Y7ak的视频属性抓取结束
# 开始BV号为1WJ411V7Ey视频属性的抓取
# BV号为1WJ411V7Ey的视频属性抓取结束
# 开始BV号为1qJ411E7At视频属性的抓取
# BV号为1qJ411E7At的视频属性抓取结束
# 开始BV号为1K7411e7id视频属性的抓取
# BV号为1K7411e7id的视频属性抓取结束
# 开始BV号为1UJ411H7oq视频属性的抓取
# BV号为1UJ411H7oq的视频属性抓取结束
# 开始BV号为1YJ411p7Do视频属性的抓取
# BV号为1YJ411p7Do的视频属性抓取结束
# 开始BV号为1U7411B7B8视频属性的抓取
# BV号为1U7411B7B8的视频属性抓取结束
# 开始BV号为1z7411z7cR视频属性的抓取
# BV号为1z7411z7cR的视频属性抓取结束
# 开始BV号为1AJ411n7Fd视频属性的抓取
# BV号为1AJ411n7Fd的视频属性抓取结束
# 开始BV号为19J411b7hf视频属性的抓取
# BV号为19J411b7hf的视频属性抓取结束
# 开始BV号为1t7411k7hH视频属性的抓取
# BV号为1t7411k7hH的视频属性抓取结束
# 开始BV号为1H7411r7Up视频属性的抓取
# BV号为1H7411r7Up的视频属性抓取结束
# 开始BV号为1v7411a7cZ视频属性的抓取
# BV号为1v7411a7cZ的视频属性抓取结束
# 开始BV号为15J411p7wy视频属性的抓取
# BV号为15J411p7wy的视频属性抓取结束
# 开始BV号为1GJ411L7j4视频属性的抓取
# BV号为1GJ411L7j4的视频属性抓取结束
# 开始BV号为1mJ41157Sx视频属性的抓取
# BV号为1mJ41157Sx的视频属性抓取结束
# 开始BV号为17J411n7ye视频属性的抓取
# BV号为17J411n7ye的视频属性抓取结束
# 开始BV号为1bJ411H7f5视频属性的抓取
# BV号为1bJ411H7f5的视频属性抓取结束
# 开始BV号为127411k7H2视频属性的抓取
# BV号为127411k7H2的视频属性抓取结束
# 开始BV号为1m7411Y7s5视频属性的抓取
# BV号为1m7411Y7s5的视频属性抓取结束
# 开始BV号为1qJ411j7YD视频属性的抓取
# BV号为1qJ411j7YD的视频属性抓取结束
# 开始BV号为1fJ411V7Gt视频属性的抓取
# BV号为1fJ411V7Gt的视频属性抓取结束
# 开始BV号为1U7411i7nG视频属性的抓取
# 开始BV号为1U7411i7nG视频属性的抓取
# BV号为1U7411i7nG的视频属性抓取结束
# 开始BV号为1pJ411j72b视频属性的抓取
# BV号为1pJ411j72b的视频属性抓取结束
# 开始BV号为1Z7411k7aD视频属性的抓取
# BV号为1Z7411k7aD的视频属性抓取结束
# 开始BV号为1s7411a7y1视频属性的抓取
# BV号为1s7411a7y1的视频属性抓取结束
# 开始BV号为1WJ411J7Q2视频属性的抓取
# BV号为1WJ411J7Q2的视频属性抓取结束
# <ipython-input-9-3c763d3225d6>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1G7411r7Po视频属性的抓取
# BV号为1G7411r7Po的视频属性抓取结束
# 开始BV号为137411Y77p视频属性的抓取
# BV号为137411Y77p的视频属性抓取结束
# 开始BV号为1m7411z7qw视频属性的抓取
# BV号为1m7411z7qw的视频属性抓取结束
# 开始BV号为1FJ411n7Dw视频属性的抓取
# BV号为1FJ411n7Dw的视频属性抓取结束
# 开始BV号为1a7411B7as视频属性的抓取
# BV号为1a7411B7as的视频属性抓取结束
# 开始BV号为1Z7411a78B视频属性的抓取
# BV号为1Z7411a78B的视频属性抓取结束
# 开始BV号为1M7411z7F6视频属性的抓取
# BV号为1M7411z7F6的视频属性抓取结束
# 开始BV号为1TJ411H7AT视频属性的抓取
# BV号为1TJ411H7AT的视频属性抓取结束
# 开始BV号为1h7411r7TH视频属性的抓取
# BV号为1h7411r7TH的视频属性抓取结束
# 开始BV号为1x7411r7b6视频属性的抓取
# BV号为1x7411r7b6的视频属性抓取结束
# 开始BV号为1sJ411j7oS视频属性的抓取
# BV号为1sJ411j7oS的视频属性抓取结束
# 开始BV号为1A7411B7yE视频属性的抓取
# BV号为1A7411B7yE的视频属性抓取结束
# 开始BV号为1MJ411p7Yy视频属性的抓取
# BV号为1MJ411p7Yy的视频属性抓取结束
# 开始BV号为1yJ411J7rZ视频属性的抓取
# BV号为1yJ411J7rZ的视频属性抓取结束
# 开始BV号为1oJ411V7Py视频属性的抓取
# BV号为1oJ411V7Py的视频属性抓取结束
# 开始BV号为1e7411r79T视频属性的抓取
# BV号为1e7411r79T的视频属性抓取结束
# 开始BV号为1t7411a7Zy视频属性的抓取
# BV号为1t7411a7Zy的视频属性抓取结束
# 开始BV号为11J411G7u3视频属性的抓取
# BV号为11J411G7u3的视频属性抓取结束
# 开始BV号为127411B7kn视频属性的抓取
# BV号为127411B7kn的视频属性抓取结束
# 开始BV号为117411B74p视频属性的抓取
# BV号为117411B74p的视频属性抓取结束
# 开始BV号为1N7411k7uN视频属性的抓取
# BV号为1N7411k7uN的视频属性抓取结束
# 开始BV号为1m7411i7NY视频属性的抓取
# BV号为1m7411i7NY的视频属性抓取结束
# 开始BV号为1DJ411G7i7视频属性的抓取
# BV号为1DJ411G7i7的视频属性抓取结束
# 开始BV号为1e7411B71e视频属性的抓取
# BV号为1e7411B71e的视频属性抓取结束
# 开始BV号为1c7411q7bL视频属性的抓取
# BV号为1c7411q7bL的视频属性抓取结束
# 开始BV号为197411z79r视频属性的抓取
# BV号为197411z79r的视频属性抓取结束
# 开始BV号为1z7411k7Ei视频属性的抓取
# BV号为1z7411k7Ei的视频属性抓取结束
# 开始BV号为1U7411v72T视频属性的抓取
# BV号为1U7411v72T的视频属性抓取结束
# 开始BV号为1TJ41157Nd视频属性的抓取
# BV号为1TJ41157Nd的视频属性抓取结束
# 开始BV号为1TJ411J767视频属性的抓取
# BV号为1TJ411J767的视频属性抓取结束
# 开始BV号为1S7411r7SW视频属性的抓取
# BV号为1S7411r7SW的视频属性抓取结束
# 开始BV号为1GJ411n7Mi视频属性的抓取
# BV号为1GJ411n7Mi的视频属性抓取结束
# 开始BV号为1hJ411E75V视频属性的抓取
# BV号为1hJ411E75V的视频属性抓取结束
# 开始BV号为1t7411q7sK视频属性的抓取
# BV号为1t7411q7sK的视频属性抓取结束
# 开始BV号为1eJ411p7RL视频属性的抓取
# BV号为1eJ411p7RL的视频属性抓取结束
# 开始BV号为1e7411e7oo视频属性的抓取
# BV号为1e7411e7oo的视频属性抓取结束
# 开始BV号为1R741167Ve视频属性的抓取
# BV号为1R741167Ve的视频属性抓取结束
# 开始BV号为177411k7NE视频属性的抓取
# BV号为177411k7NE的视频属性抓取结束
# 开始BV号为1Z7411q7UR视频属性的抓取
# BV号为1Z7411q7UR的视频属性抓取结束
# 开始BV号为14J41177pa视频属性的抓取
# BV号为14J41177pa的视频属性抓取结束
# 开始BV号为1D7411z73x视频属性的抓取
# BV号为1D7411z73x的视频属性抓取结束
# 开始BV号为137411q7ce视频属性的抓取
# BV号为137411q7ce的视频属性抓取结束
# 开始BV号为1aJ411H78e视频属性的抓取
# BV号为1aJ411H78e的视频属性抓取结束
# 开始BV号为1UJ411577H视频属性的抓取
# BV号为1UJ411577H的视频属性抓取结束
# 开始BV号为1nJ411V7rf视频属性的抓取
# BV号为1nJ411V7rf的视频属性抓取结束
# 开始BV号为1g7411q7Py视频属性的抓取
# BV号为1g7411q7Py的视频属性抓取结束
# 开始BV号为1aJ411H774视频属性的抓取
# BV号为1aJ411H774的视频属性抓取结束
# 开始BV号为1W7411e7AM视频属性的抓取
# BV号为1W7411e7AM的视频属性抓取结束
# 开始BV号为1EJ411p7Rm视频属性的抓取
# BV号为1EJ411p7Rm的视频属性抓取结束
# 开始BV号为1mJ41177jd视频属性的抓取
# BV号为1mJ41177jd的视频属性抓取结束
# 开始BV号为1H7411B78s视频属性的抓取
# BV号为1H7411B78s的视频属性抓取结束
# 开始BV号为1K7411v7p5视频属性的抓取
# BV号为1K7411v7p5的视频属性抓取结束
# 开始BV号为1w7411q7jB视频属性的抓取
# BV号为1w7411q7jB的视频属性抓取结束
# 开始BV号为187411a7kE视频属性的抓取
# BV号为187411a7kE的视频属性抓取结束
# 开始BV号为1tJ411V7cs视频属性的抓取
# BV号为1tJ411V7cs的视频属性抓取结束
# 开始BV号为1U7411e7Bv视频属性的抓取
# BV号为1U7411e7Bv的视频属性抓取结束
# 开始BV号为1FJ411J7oE视频属性的抓取
# BV号为1FJ411J7oE的视频属性抓取结束
# 开始BV号为1J7411e7jW视频属性的抓取
# BV号为1J7411e7jW的视频属性抓取结束
# 开始BV号为1q7411x7H6视频属性的抓取
# BV号为1q7411x7H6的视频属性抓取结束
# 开始BV号为1k7411W7Cr视频属性的抓取
# BV号为1k7411W7Cr的视频属性抓取结束
# 开始BV号为167411L7xv视频属性的抓取
# BV号为167411L7xv的视频属性抓取结束
# 开始BV号为1W7411c7MQ视频属性的抓取
# BV号为1W7411c7MQ的视频属性抓取结束
# 开始BV号为1x7411p7kR视频属性的抓取
# BV号为1x7411p7kR的视频属性抓取结束
# 开始BV号为1Q7411u7fE视频属性的抓取
# BV号为1Q7411u7fE的视频属性抓取结束
# 开始BV号为1p7411K7bP视频属性的抓取
# BV号为1p7411K7bP的视频属性抓取结束
# 开始BV号为1p7411x76F视频属性的抓取
# BV号为1p7411x76F的视频属性抓取结束
# 开始BV号为1C7411s7xB视频属性的抓取
# BV号为1C7411s7xB的视频属性抓取结束
# 开始BV号为1Y7411G7gB视频属性的抓取
# BV号为1Y7411G7gB的视频属性抓取结束
# 开始BV号为1e7411K7kj视频属性的抓取
# BV号为1e7411K7kj的视频属性抓取结束
# 开始BV号为1W7411P7uu视频属性的抓取
# BV号为1W7411P7uu的视频属性抓取结束
# 开始BV号为1E7411W7SA视频属性的抓取
# BV号为1E7411W7SA的视频属性抓取结束
# 开始BV号为1T7411s7NB视频属性的抓取
# BV号为1T7411s7NB的视频属性抓取结束
# 开始BV号为147411N7PP视频属性的抓取
# BV号为147411N7PP的视频属性抓取结束
# 开始BV号为1b7411G7BL视频属性的抓取
# BV号为1b7411G7BL的视频属性抓取结束
# 开始BV号为1G7411s75M视频属性的抓取
# BV号为1G7411s75M的视频属性抓取结束
# 开始BV号为147411t7Ek视频属性的抓取
# BV号为147411t7Ek的视频属性抓取结束
# 开始BV号为1V7411F73W视频属性的抓取
# BV号为1V7411F73W的视频属性抓取结束
# 开始BV号为1M741187FV视频属性的抓取
# BV号为1M741187FV的视频属性抓取结束
# 开始BV号为1b7411t7Vx视频属性的抓取
# BV号为1b7411t7Vx的视频属性抓取结束
# 开始BV号为1u7411n7yo视频属性的抓取
# BV号为1u7411n7yo的视频属性抓取结束
# 开始BV号为197411W7oR视频属性的抓取
# BV号为197411W7oR的视频属性抓取结束
# 开始BV号为1zj411f7PC视频属性的抓取
# BV号为1zj411f7PC的视频属性抓取结束
# 开始BV号为1w741137ek视频属性的抓取
# BV号为1w741137ek的视频属性抓取结束
# 开始BV号为1D7411P7QV视频属性的抓取
# BV号为1D7411P7QV的视频属性抓取结束
# 开始BV号为1x7411M77V视频属性的抓取
# BV号为1x7411M77V的视频属性抓取结束
# 开始BV号为1A7411p7AQ视频属性的抓取
# BV号为1A7411p7AQ的视频属性抓取结束
# 开始BV号为137411n7gi视频属性的抓取
# BV号为137411n7gi的视频属性抓取结束
# 开始BV号为1Gj411f7rk视频属性的抓取
# BV号为1Gj411f7rk的视频属性抓取结束
# 开始BV号为1E7411577P视频属性的抓取
# BV号为1E7411577P的视频属性抓取结束
# 开始BV号为1s7411g784视频属性的抓取
# BV号为1s7411g784的视频属性抓取结束
# 开始BV号为1k7411b7t5视频属性的抓取
# BV号为1k7411b7t5的视频属性抓取结束
# 开始BV号为1p7411w7C2视频属性的抓取
# BV号为1p7411w7C2的视频属性抓取结束
# 开始BV号为1Y7411c7Hz视频属性的抓取
# BV号为1Y7411c7Hz的视频属性抓取结束
# 开始BV号为1X7411h7fr视频属性的抓取
# BV号为1X7411h7fr的视频属性抓取结束
# 开始BV号为1S7411p7kn视频属性的抓取
# BV号为1S7411p7kn的视频属性抓取结束
# 开始BV号为1e7411M7ne视频属性的抓取
# BV号为1e7411M7ne的视频属性抓取结束
# 开始BV号为1P7411j7b1视频属性的抓取
# BV号为1P7411j7b1的视频属性抓取结束
# 开始BV号为1h741147PX视频属性的抓取
# BV号为1h741147PX的视频属性抓取结束
# 开始BV号为1J7411H7dr视频属性的抓取
# BV号为1J7411H7dr的视频属性抓取结束
# 开始BV号为137411G7JJ视频属性的抓取
# BV号为137411G7JJ的视频属性抓取结束
# 开始BV号为1D7411p71f视频属性的抓取
# BV号为1D7411p71f的视频属性抓取结束
# 开始BV号为1g7411t78n视频属性的抓取
# BV号为1g7411t78n的视频属性抓取结束
# 开始BV号为1S7411H7PD视频属性的抓取
# BV号为1S7411H7PD的视频属性抓取结束
# 开始BV号为1P7411p779视频属性的抓取
# BV号为1P7411p779的视频属性抓取结束
# 开始BV号为1nE411H7GH视频属性的抓取
# BV号为1nE411H7GH的视频属性抓取结束
# 开始BV号为1L7411G7xP视频属性的抓取
# BV号为1L7411G7xP的视频属性抓取结束
# 开始BV号为1f7411F7XA视频属性的抓取
# BV号为1f7411F7XA的视频属性抓取结束
# 开始BV号为147411u7ip视频属性的抓取
# BV号为147411u7ip的视频属性抓取结束
# 开始BV号为1b7411H7Nm视频属性的抓取
# BV号为1b7411H7Nm的视频属性抓取结束
# 开始BV号为1z7411M7Kt视频属性的抓取
# BV号为1z7411M7Kt的视频属性抓取结束
# 开始BV号为1e7411J7b1视频属性的抓取
# BV号为1e7411J7b1的视频属性抓取结束
# 开始BV号为1r7411N7ni视频属性的抓取
# BV号为1r7411N7ni的视频属性抓取结束
# 开始BV号为1E7411a7Gx视频属性的抓取
# BV号为1E7411a7Gx的视频属性抓取结束
# 开始BV号为1H741137B4视频属性的抓取
# BV号为1H741137B4的视频属性抓取结束
# 开始BV号为1c741137md视频属性的抓取
# BV号为1c741137md的视频属性抓取结束
# 开始BV号为1Z7411P798视频属性的抓取
# BV号为1Z7411P798的视频属性抓取结束
# 开始BV号为1V741177qx视频属性的抓取
# BV号为1V741177qx的视频属性抓取结束
# 开始BV号为1f7411w7WZ视频属性的抓取
# BV号为1f7411w7WZ的视频属性抓取结束
# 开始BV号为1e7411c7Lz视频属性的抓取
# BV号为1e7411c7Lz的视频属性抓取结束
# 开始BV号为1g7411E7DC视频属性的抓取
# BV号为1g7411E7DC的视频属性抓取结束
# 开始BV号为1F7411F771视频属性的抓取
# BV号为1F7411F771的视频属性抓取结束
# 开始BV号为1c7411F78G视频属性的抓取
# BV号为1c7411F78G的视频属性抓取结束
# 开始BV号为1n741137p6视频属性的抓取
# BV号为1n741137p6的视频属性抓取结束
# 开始BV号为1p7411G7vE视频属性的抓取
# BV号为1p7411G7vE的视频属性抓取结束
# 开始BV号为1H7411p7zi视频属性的抓取
# BV号为1H7411p7zi的视频属性抓取结束
# 开始BV号为117411b7fG视频属性的抓取
# BV号为117411b7fG的视频属性抓取结束
# 开始BV号为1F741177iK视频属性的抓取
# BV号为1F741177iK的视频属性抓取结束
# 开始BV号为1x7411K7Uy视频属性的抓取
# BV号为1x7411K7Uy的视频属性抓取结束
# 开始BV号为1c7411x7C3视频属性的抓取
# BV号为1c7411x7C3的视频属性抓取结束
# 开始BV号为1R7411F7zB视频属性的抓取
# BV号为1R7411F7zB的视频属性抓取结束
# 开始BV号为1B7411P7dE视频属性的抓取
# BV号为1B7411P7dE的视频属性抓取结束
# 开始BV号为1BE411J7Dv视频属性的抓取
# BV号为1BE411J7Dv的视频属性抓取结束
# 开始BV号为1w7411g7PB视频属性的抓取
# BV号为1w7411g7PB的视频属性抓取结束
# 开始BV号为147411c7eZ视频属性的抓取
# BV号为147411c7eZ的视频属性抓取结束
# 开始BV号为1j7411a7HY视频属性的抓取
# BV号为1j7411a7HY的视频属性抓取结束
# 开始BV号为1tE411n7wK视频属性的抓取
# BV号为1tE411n7wK的视频属性抓取结束
# 开始BV号为1Q7411E7gW视频属性的抓取
# BV号为1Q7411E7gW的视频属性抓取结束
# 开始BV号为1C7411t7rd视频属性的抓取
# BV号为1C7411t7rd的视频属性抓取结束
# 开始BV号为1K7411L794视频属性的抓取
# BV号为1K7411L794的视频属性抓取结束
# 开始BV号为1H7411c7K2视频属性的抓取
# BV号为1H7411c7K2的视频属性抓取结束
# 开始BV号为1u7411V7GT视频属性的抓取
# BV号为1u7411V7GT的视频属性抓取结束
# 开始BV号为1Y7411H7XW视频属性的抓取
# BV号为1Y7411H7XW的视频属性抓取结束
# 开始BV号为1A7411x7ae视频属性的抓取
# BV号为1A7411x7ae的视频属性抓取结束
# 开始BV号为1yj411f79C视频属性的抓取
# BV号为1yj411f79C的视频属性抓取结束
# 开始BV号为1C741147Lu视频属性的抓取
# BV号为1C741147Lu的视频属性抓取结束
# 开始BV号为1D7411P7po视频属性的抓取
# BV号为1D7411P7po的视频属性抓取结束
# 开始BV号为1R7411E7pp视频属性的抓取
# BV号为1R7411E7pp的视频属性抓取结束
# 开始BV号为1M7411V7Hw视频属性的抓取
# BV号为1M7411V7Hw的视频属性抓取结束
# 开始BV号为1P7411u7gs视频属性的抓取
# BV号为1P7411u7gs的视频属性抓取结束
# 开始BV号为147411E7cK视频属性的抓取
# BV号为147411E7cK的视频属性抓取结束
# 开始BV号为1x7411A7tN视频属性的抓取
# BV号为1x7411A7tN的视频属性抓取结束
# 开始BV号为1S7411s7jP视频属性的抓取
# BV号为1S7411s7jP的视频属性抓取结束
# 开始BV号为1A7411t7xu视频属性的抓取
# BV号为1A7411t7xu的视频属性抓取结束
# 开始BV号为1N7411t7NJ视频属性的抓取
# BV号为1N7411t7NJ的视频属性抓取结束
# 开始BV号为1i7411W7VH视频属性的抓取
# BV号为1i7411W7VH的视频属性抓取结束
# 开始BV号为1K7411c7B7视频属性的抓取
# BV号为1K7411c7B7的视频属性抓取结束
# 开始BV号为187411N734视频属性的抓取
# BV号为187411N734的视频属性抓取结束
# 开始BV号为1L741137R5视频属性的抓取
# BV号为1L741137R5的视频属性抓取结束
# 开始BV号为167411C7yL视频属性的抓取
# BV号为167411C7yL的视频属性抓取结束
# 开始BV号为1E7411f7WH视频属性的抓取
# 开始BV号为1E7411f7WH视频属性的抓取
# BV号为1E7411f7WH的视频属性抓取结束
# 开始BV号为1BK4y1C7Bh视频属性的抓取
# BV号为1BK4y1C7Bh的视频属性抓取结束
# 开始BV号为1oE411M74u视频属性的抓取
# BV号为1oE411M74u的视频属性抓取结束
# 开始BV号为1KE411F7Re视频属性的抓取
# BV号为1KE411F7Re的视频属性抓取结束
# 开始BV号为1LE41157Tn视频属性的抓取
# BV号为1LE41157Tn的视频属性抓取结束
# 开始BV号为1Ez411b7gy视频属性的抓取
# BV号为1Ez411b7gy的视频属性抓取结束
# 开始BV号为1bE411T7sC视频属性的抓取
# BV号为1bE411T7sC的视频属性抓取结束
# 开始BV号为1tE411x7Es视频属性的抓取
# BV号为1tE411x7Es的视频属性抓取结束
# 开始BV号为1S7411d78M视频属性的抓取
# BV号为1S7411d78M的视频属性抓取结束
# 开始BV号为1P5411r7if视频属性的抓取
# BV号为1P5411r7if的视频属性抓取结束
# 开始BV号为1sE411W7PH视频属性的抓取
# BV号为1sE411W7PH的视频属性抓取结束
# 开始BV号为1HE411x74A视频属性的抓取
# BV号为1HE411x74A的视频属性抓取结束
# 开始BV号为1zE41157gS视频属性的抓取
# BV号为1zE41157gS的视频属性抓取结束
# 开始BV号为1BE411H7vX视频属性的抓取
# BV号为1BE411H7vX的视频属性抓取结束
# 开始BV号为17E41147RK视频属性的抓取
# BV号为17E41147RK的视频属性抓取结束
# 开始BV号为1aE411W7Yc视频属性的抓取
# BV号为1aE411W7Yc的视频属性抓取结束
# 开始BV号为157411o7bW视频属性的抓取
# BV号为157411o7bW的视频属性抓取结束
# 开始BV号为1xE411s714视频属性的抓取
# BV号为1xE411s714的视频属性抓取结束
# 开始BV号为1JE411E7SW视频属性的抓取
# BV号为1JE411E7SW的视频属性抓取结束
# 开始BV号为1CC4y147cG视频属性的抓取
# BV号为1CC4y147cG的视频属性抓取结束
# 开始BV号为1z7411d7oj视频属性的抓取
# BV号为1z7411d7oj的视频属性抓取结束
# 开始BV号为1UE411L7XR视频属性的抓取
# BV号为1UE411L7XR的视频属性抓取结束
# 开始BV号为1pc411h71n视频属性的抓取
# BV号为1pc411h71n的视频属性抓取结束
# 开始BV号为12E411u78N视频属性的抓取
# BV号为12E411u78N的视频属性抓取结束
# 开始BV号为1kE411G7wC视频属性的抓取
# BV号为1kE411G7wC的视频属性抓取结束
# 开始BV号为1E7411C7xH视频属性的抓取
# BV号为1E7411C7xH的视频属性抓取结束
# 开始BV号为1b741127sP视频属性的抓取
# BV号为1b741127sP的视频属性抓取结束
# 开始BV号为1W7411X7vN视频属性的抓取
# BV号为1W7411X7vN的视频属性抓取结束
# 开始BV号为1zE411j7zK视频属性的抓取
# BV号为1zE411j7zK的视频属性抓取结束
# 开始BV号为1eE411N77W视频属性的抓取
# BV号为1eE411N77W的视频属性抓取结束
# 开始BV号为1oE411H7FB视频属性的抓取
# BV号为1oE411H7FB的视频属性抓取结束
# 开始BV号为1ME411P75A视频属性的抓取
# BV号为1ME411P75A的视频属性抓取结束
# 开始BV号为1VE411574m视频属性的抓取
# BV号为1VE411574m的视频属性抓取结束
# 开始BV号为1BE411A71J视频属性的抓取
# BV号为1BE411A71J的视频属性抓取结束
# 开始BV号为1gp4y1C7ZZ视频属性的抓取
# BV号为1gp4y1C7ZZ的视频属性抓取结束
# 开始BV号为1dE411M7yc视频属性的抓取
# BV号为1dE411M7yc的视频属性抓取结束
# 开始BV号为1G7411Q7ya视频属性的抓取
# BV号为1G7411Q7ya的视频属性抓取结束
# 开始BV号为1LE411V7ca视频属性的抓取
# 开始BV号为1LE411V7ca视频属性的抓取
# 开始BV号为1LE411V7ca视频属性的抓取
# 开始BV号为1LE411V7ca视频属性的抓取
# BV号为1LE411V7ca的视频属性抓取结束
# 开始BV号为1YE411x7HE视频属性的抓取
# BV号为1YE411x7HE的视频属性抓取结束
# 开始BV号为11E411L7bt视频属性的抓取
# BV号为11E411L7bt的视频属性抓取结束
# 开始BV号为1fE41177AL视频属性的抓取
# 开始BV号为1fE41177AL视频属性的抓取
# BV号为1fE41177AL的视频属性抓取结束
# 开始BV号为1XE411K7yf视频属性的抓取
# BV号为1XE411K7yf的视频属性抓取结束
# 开始BV号为1J7411o7Nv视频属性的抓取
# BV号为1J7411o7Nv的视频属性抓取结束
# 开始BV号为1GE41157HD视频属性的抓取
# BV号为1GE41157HD的视频属性抓取结束
# 开始BV号为1pE411j75x视频属性的抓取
# BV号为1pE411j75x的视频属性抓取结束
# 开始BV号为1fz411t7bT视频属性的抓取
# BV号为1fz411t7bT的视频属性抓取结束
# 开始BV号为1nE411g7EZ视频属性的抓取
# BV号为1nE411g7EZ的视频属性抓取结束
# 开始BV号为1qE411N7pJ视频属性的抓取
# BV号为1qE411N7pJ的视频属性抓取结束
# 开始BV号为1fE411G7iu视频属性的抓取
# BV号为1fE411G7iu的视频属性抓取结束
# 开始BV号为1oE41177qr视频属性的抓取
# BV号为1oE41177qr的视频属性抓取结束
# 开始BV号为1y7411C73p视频属性的抓取
# BV号为1y7411C73p的视频属性抓取结束
# 开始BV号为1t7411f79F视频属性的抓取
# BV号为1t7411f79F的视频属性抓取结束
# 开始BV号为1zE411u74u视频属性的抓取
# BV号为1zE411u74u的视频属性抓取结束
# 开始BV号为12E411j7wF视频属性的抓取
# BV号为12E411j7wF的视频属性抓取结束
# 开始BV号为1fE41137By视频属性的抓取
# BV号为1fE41137By的视频属性抓取结束
# 开始BV号为11E411J7Tn视频属性的抓取
# BV号为11E411J7Tn的视频属性抓取结束
# 开始BV号为11E411P7H4视频属性的抓取
# BV号为11E411P7H4的视频属性抓取结束
# 开始BV号为1oE411T7YC视频属性的抓取
# BV号为1oE411T7YC的视频属性抓取结束
# 开始BV号为1zE411j7f8视频属性的抓取
# BV号为1zE411j7f8的视频属性抓取结束
# 开始BV号为1s7411f7GZ视频属性的抓取
# BV号为1s7411f7GZ的视频属性抓取结束
# 开始BV号为1t7411S75K视频属性的抓取
# BV号为1t7411S75K的视频属性抓取结束
# 开始BV号为15E411G7Cw视频属性的抓取
# BV号为15E411G7Cw的视频属性抓取结束
# 开始BV号为1NK411L7uR视频属性的抓取
# BV号为1NK411L7uR的视频属性抓取结束
# 开始BV号为1p54y1d7r4视频属性的抓取
# BV号为1p54y1d7r4的视频属性抓取结束
# 开始BV号为1X7411y7CD视频属性的抓取
# BV号为1X7411y7CD的视频属性抓取结束
# 开始BV号为1eE411M7Dz视频属性的抓取
# BV号为1eE411M7Dz的视频属性抓取结束
# 开始BV号为1UE41177sC视频属性的抓取
# BV号为1UE41177sC的视频属性抓取结束
# 开始BV号为1rE411G76c视频属性的抓取
# BV号为1rE411G76c的视频属性抓取结束
# 开始BV号为1dk4y1d7ud视频属性的抓取
# BV号为1dk4y1d7ud的视频属性抓取结束
# 开始BV号为1y7411y7xT视频属性的抓取
# BV号为1y7411y7xT的视频属性抓取结束
# 开始BV号为1YE411F7ZE视频属性的抓取
# BV号为1YE411F7ZE的视频属性抓取结束
# 开始BV号为18E411V7pK视频属性的抓取
# BV号为18E411V7pK的视频属性抓取结束
# 开始BV号为1fE411s7gH视频属性的抓取
# BV号为1fE411s7gH的视频属性抓取结束
# 开始BV号为1A7411U7NW视频属性的抓取
# 开始BV号为1A7411U7NW视频属性的抓取
# BV号为1A7411U7NW的视频属性抓取结束
# 开始BV号为1FE411J7LW视频属性的抓取
# BV号为1FE411J7LW的视频属性抓取结束
# 开始BV号为1b7411U7nH视频属性的抓取
# BV号为1b7411U7nH的视频属性抓取结束
# 开始BV号为1rE41137f2视频属性的抓取
# BV号为1rE41137f2的视频属性抓取结束
# 开始BV号为14E411s7GA视频属性的抓取
# BV号为14E411s7GA的视频属性抓取结束
# 开始BV号为177411m7bn视频属性的抓取
# BV号为177411m7bn的视频属性抓取结束
# 开始BV号为1w5411r784视频属性的抓取
# BV号为1w5411r784的视频属性抓取结束
# 开始BV号为1tE411j7o3视频属性的抓取
# BV号为1tE411j7o3的视频属性抓取结束
# 开始BV号为1XE411H7cL视频属性的抓取
# BV号为1XE411H7cL的视频属性抓取结束
# 开始BV号为1SE411g7vs视频属性的抓取
# BV号为1SE411g7vs的视频属性抓取结束
# 开始BV号为1HE411V7gn视频属性的抓取
# BV号为1HE411V7gn的视频属性抓取结束
# 开始BV号为1JE411F7fc视频属性的抓取
# BV号为1JE411F7fc的视频属性抓取结束
# 开始BV号为117411Z7bW视频属性的抓取
# BV号为117411Z7bW的视频属性抓取结束
# 开始BV号为16E411A7Qm视频属性的抓取
# BV号为16E411A7Qm的视频属性抓取结束
# 开始BV号为1EE411A72N视频属性的抓取
# BV号为1EE411A72N的视频属性抓取结束
# 开始BV号为1gE411374n视频属性的抓取
# BV号为1gE411374n的视频属性抓取结束
# 开始BV号为1t7411X78q视频属性的抓取
# BV号为1t7411X78q的视频属性抓取结束
# 开始BV号为1VE411W78G视频属性的抓取
# BV号为1VE411W78G的视频属性抓取结束
# 开始BV号为1eE411g7Z4视频属性的抓取
# BV号为1eE411g7Z4的视频属性抓取结束
# 开始BV号为1JE411T7Kp视频属性的抓取
# BV号为1JE411T7Kp的视频属性抓取结束
# 开始BV号为1Z7411C7gg视频属性的抓取
# BV号为1Z7411C7gg的视频属性抓取结束
# 开始BV号为1SE411j7PR视频属性的抓取
# BV号为1SE411j7PR的视频属性抓取结束
# 开始BV号为127411d7VR视频属性的抓取
# BV号为127411d7VR的视频属性抓取结束
# 开始BV号为1A7411U7TU视频属性的抓取
# BV号为1A7411U7TU的视频属性抓取结束
# 开始BV号为15E411G7zc视频属性的抓取
# BV号为15E411G7zc的视频属性抓取结束
# 开始BV号为16E411p7SY视频属性的抓取
# BV号为16E411p7SY的视频属性抓取结束
# 开始BV号为1xQ4y1T7Xd视频属性的抓取
# BV号为1xQ4y1T7Xd的视频属性抓取结束
# 开始BV号为1Ai4y1875b视频属性的抓取
# BV号为1Ai4y1875b的视频属性抓取结束
# 开始BV号为1Yi4y1b753视频属性的抓取
# BV号为1Yi4y1b753的视频属性抓取结束
# 开始BV号为1Ra4y1t7KP视频属性的抓取
# BV号为1Ra4y1t7KP的视频属性抓取结束
# 开始BV号为1X54y1Q7tw视频属性的抓取
# BV号为1X54y1Q7tw的视频属性抓取结束
# 开始BV号为1Je411s7uG视频属性的抓取
# BV号为1Je411s7uG的视频属性抓取结束
# 开始BV号为1qp4y1C7tH视频属性的抓取
# BV号为1qp4y1C7tH的视频属性抓取结束
# 开始BV号为1jT4y1G7Ce视频属性的抓取
# BV号为1jT4y1G7Ce的视频属性抓取结束
# 开始BV号为1yf4y1S7pk视频属性的抓取
# BV号为1yf4y1S7pk的视频属性抓取结束
# 开始BV号为19e411s7qV视频属性的抓取
# BV号为19e411s7qV的视频属性抓取结束
# 开始BV号为1Yt4y1m7cw视频属性的抓取
# BV号为1Yt4y1m7cw的视频属性抓取结束
# 开始BV号为17c411h7TR视频属性的抓取
# BV号为17c411h7TR的视频属性抓取结束
# 开始BV号为1ea4y1471V视频属性的抓取
# BV号为1ea4y1471V的视频属性抓取结束
# 开始BV号为1fi4y1b7wx视频属性的抓取
# BV号为1fi4y1b7wx的视频属性抓取结束
# 开始BV号为1VT4y157Qc视频属性的抓取
# BV号为1VT4y157Qc的视频属性抓取结束
# 开始BV号为1kK4y1r7ig视频属性的抓取
# BV号为1kK4y1r7ig的视频属性抓取结束
# 开始BV号为11c411h7jx视频属性的抓取
# BV号为11c411h7jx的视频属性抓取结束
# 开始BV号为1g64y1M77B视频属性的抓取
# BV号为1g64y1M77B的视频属性抓取结束
# 开始BV号为1fQ4y1K7GS视频属性的抓取
# BV号为1fQ4y1K7GS的视频属性抓取结束
# 开始BV号为1xp4y1C7Hi视频属性的抓取
# BV号为1xp4y1C7Hi的视频属性抓取结束
# 开始BV号为14Q4y1K73m视频属性的抓取
# BV号为14Q4y1K73m的视频属性抓取结束
# 开始BV号为1Si4y1b73v视频属性的抓取
# BV号为1Si4y1b73v的视频属性抓取结束
# 开始BV号为1sT4y1G7CR视频属性的抓取
# BV号为1sT4y1G7CR的视频属性抓取结束
# 开始BV号为1rV411o7c8视频属性的抓取
# BV号为1rV411o7c8的视频属性抓取结束
# 开始BV号为1W64y1u7AF视频属性的抓取
# BV号为1W64y1u7AF的视频属性抓取结束
# 开始BV号为1mk4y1R7gn视频属性的抓取
# BV号为1mk4y1R7gn的视频属性抓取结束
# 开始BV号为1jK4y1b7Fy视频属性的抓取
# BV号为1jK4y1b7Fy的视频属性抓取结束
# 开始BV号为1754y197va视频属性的抓取
# BV号为1754y197va的视频属性抓取结束
# 开始BV号为1ZZ4y1s7rx视频属性的抓取
# BV号为1ZZ4y1s7rx的视频属性抓取结束
# 开始BV号为1NA411b79b视频属性的抓取
# BV号为1NA411b79b的视频属性抓取结束
# 开始BV号为1U54y1976w视频属性的抓取
# BV号为1U54y1976w的视频属性抓取结束
# 开始BV号为15Q4y1M7Y9视频属性的抓取
# BV号为15Q4y1M7Y9的视频属性抓取结束
# 开始BV号为1oA411876f视频属性的抓取
# BV号为1oA411876f的视频属性抓取结束
# 开始BV号为16e411s7QL视频属性的抓取
# BV号为16e411s7QL的视频属性抓取结束
# 开始BV号为1tA411b724视频属性的抓取
# BV号为1tA411b724的视频属性抓取结束
# 开始BV号为1eK4y1C7ja视频属性的抓取
# BV号为1eK4y1C7ja的视频属性抓取结束
# 开始BV号为1w64y1u7pw视频属性的抓取
# BV号为1w64y1u7pw的视频属性抓取结束
# 开始BV号为1yQ4y1K7S6视频属性的抓取
# BV号为1yQ4y1K7S6的视频属性抓取结束
# 开始BV号为14g4y187rS视频属性的抓取
# BV号为14g4y187rS的视频属性抓取结束
# 开始BV号为1n7411S7hC视频属性的抓取
# BV号为1n7411S7hC的视频属性抓取结束
# 开始BV号为1sZ4y1j7c1视频属性的抓取
# BV号为1sZ4y1j7c1的视频属性抓取结束
# 开始BV号为1Kz411b7Et视频属性的抓取
# BV号为1Kz411b7Et的视频属性抓取结束
# 开始BV号为1mk4y1d7WY视频属性的抓取
# BV号为1mk4y1d7WY的视频属性抓取结束
# 开始BV号为1k5411x77u视频属性的抓取
# BV号为1k5411x77u的视频属性抓取结束
# 开始BV号为19K4y1r7ci视频属性的抓取
# BV号为19K4y1r7ci的视频属性抓取结束
# 开始BV号为1C64y1T72X视频属性的抓取
# BV号为1C64y1T72X的视频属性抓取结束
# 开始BV号为1PA411b7aE视频属性的抓取
# BV号为1PA411b7aE的视频属性抓取结束
# 开始BV号为1xA411b7Xi视频属性的抓取
# BV号为1xA411b7Xi的视频属性抓取结束
# 开始BV号为1dT4y1V7DP视频属性的抓取
# BV号为1dT4y1V7DP的视频属性抓取结束
# 开始BV号为1iz411b7XU视频属性的抓取
# BV号为1iz411b7XU的视频属性抓取结束
# 开始BV号为1K64y1u7n1视频属性的抓取
# BV号为1K64y1u7n1的视频属性抓取结束
# 开始BV号为1kg4y1b7TH视频属性的抓取
# BV号为1kg4y1b7TH的视频属性抓取结束
# 开始BV号为1Fg4y187XL视频属性的抓取
# BV号为1Fg4y187XL的视频属性抓取结束
# 开始BV号为1AQ4y1N7Uu视频属性的抓取
# BV号为1AQ4y1N7Uu的视频属性抓取结束
# 开始BV号为1hA41147BC视频属性的抓取
# BV号为1hA41147BC的视频属性抓取结束
# 开始BV号为1tt4y127hM视频属性的抓取
# BV号为1tt4y127hM的视频属性抓取结束
# 开始BV号为1Ep4y1C7XP视频属性的抓取
# BV号为1Ep4y1C7XP的视频属性抓取结束
# 开始BV号为1sg4y1z7mk视频属性的抓取
# BV号为1sg4y1z7mk的视频属性抓取结束
# 开始BV号为1tK4y1C7MT视频属性的抓取
# BV号为1tK4y1C7MT的视频属性抓取结束
# 开始BV号为1De411W7oJ视频属性的抓取
# BV号为1De411W7oJ的视频属性抓取结束
# 开始BV号为1gK411j74p视频属性的抓取
# BV号为1gK411j74p的视频属性抓取结束
# 开始BV号为1rf4y1U7qv视频属性的抓取
# BV号为1rf4y1U7qv的视频属性抓取结束
# 开始BV号为1SZ4y1W7fN视频属性的抓取
# BV号为1SZ4y1W7fN的视频属性抓取结束
# 开始BV号为1Jp4y1C7KV视频属性的抓取
# BV号为1Jp4y1C7KV的视频属性抓取结束
# 开始BV号为1qp4y1X7Cy视频属性的抓取
# BV号为1qp4y1X7Cy的视频属性抓取结束
# 开始BV号为1JC4y1W7R4视频属性的抓取
# BV号为1JC4y1W7R4的视频属性抓取结束
# 开始BV号为1LC4y1s7jV视频属性的抓取
# BV号为1LC4y1s7jV的视频属性抓取结束
# 开始BV号为14Z4y1x7EZ视频属性的抓取
# BV号为14Z4y1x7EZ的视频属性抓取结束
# 开始BV号为14i4y1t7ME视频属性的抓取
# BV号为14i4y1t7ME的视频属性抓取结束
# 开始BV号为17V411f7fF视频属性的抓取
# BV号为17V411f7fF的视频属性抓取结束
# 开始BV号为14p4y1C7Yx视频属性的抓取
# BV号为14p4y1C7Yx的视频属性抓取结束
# 开始BV号为18p4y1X7aV视频属性的抓取
# BV号为18p4y1X7aV的视频属性抓取结束
# 开始BV号为1WA411h7aA视频属性的抓取
# BV号为1WA411h7aA的视频属性抓取结束
# 开始BV号为1DK411V7cB视频属性的抓取
# BV号为1DK411V7cB的视频属性抓取结束
# 开始BV号为1Sz411b7BH视频属性的抓取
# BV号为1Sz411b7BH的视频属性抓取结束
# 开始BV号为1vp4y1X7NA视频属性的抓取
# BV号为1vp4y1X7NA的视频属性抓取结束
# 开始BV号为1CQ4y1M7RL视频属性的抓取
# BV号为1CQ4y1M7RL的视频属性抓取结束
# 开始BV号为1wZ4y1j7Yd视频属性的抓取
# BV号为1wZ4y1j7Yd的视频属性抓取结束
# 开始BV号为1XA41187ag视频属性的抓取
# BV号为1XA41187ag的视频属性抓取结束
# 开始BV号为1me411s7vN视频属性的抓取
# BV号为1me411s7vN的视频属性抓取结束
# 开始BV号为1kZ4y1j7sk视频属性的抓取
# BV号为1kZ4y1j7sk的视频属性抓取结束
# 开始BV号为1dt4y1m7bn视频属性的抓取
# BV号为1dt4y1m7bn的视频属性抓取结束
# 开始BV号为1KT4y1G73W视频属性的抓取
# BV号为1KT4y1G73W的视频属性抓取结束
# 开始BV号为1Ua4y1x7sh视频属性的抓取
# BV号为1Ua4y1x7sh的视频属性抓取结束
# 开始BV号为1Lc411h7xN视频属性的抓取
# BV号为1Lc411h7xN的视频属性抓取结束
# 开始BV号为1JA411h7jM视频属性的抓取
# BV号为1JA411h7jM的视频属性抓取结束
# 开始BV号为1CV411o7vV视频属性的抓取
# BV号为1CV411o7vV的视频属性抓取结束
# 开始BV号为14K4y1b7j8视频属性的抓取
# BV号为14K4y1b7j8的视频属性抓取结束
# 开始BV号为1r64y1M75q视频属性的抓取
# BV号为1r64y1M75q的视频属性抓取结束
# 开始BV号为1dC4y1s7J6视频属性的抓取
# BV号为1dC4y1s7J6的视频属性抓取结束
# 开始BV号为13T4y137zF视频属性的抓取
# BV号为13T4y137zF的视频属性抓取结束
# 开始BV号为1Wa4y1x7c2视频属性的抓取
# BV号为1Wa4y1x7c2的视频属性抓取结束
# 开始BV号为1he411s7yT视频属性的抓取
# BV号为1he411s7yT的视频属性抓取结束
# 开始BV号为1ek4y197o4视频属性的抓取
# BV号为1ek4y197o4的视频属性抓取结束
# 开始BV号为17p4y1171Q视频属性的抓取
# BV号为17p4y1171Q的视频属性抓取结束
# 开始BV号为1aK411L7oK视频属性的抓取
# BV号为1aK411L7oK的视频属性抓取结束
# 开始BV号为1hK4y1r78D视频属性的抓取
# BV号为1hK4y1r78D的视频属性抓取结束
# 开始BV号为1gC4y1W76E视频属性的抓取
# BV号为1gC4y1W76E的视频属性抓取结束
# 开始BV号为1kK411L7AH视频属性的抓取
# BV号为1kK411L7AH的视频属性抓取结束
# 开始BV号为1ii4y1b7xn视频属性的抓取
# BV号为1ii4y1b7xn的视频属性抓取结束
# 开始BV号为1Dg4y1q7yu视频属性的抓取
# BV号为1Dg4y1q7yu的视频属性抓取结束
# 开始BV号为1Qi4y1x7Je视频属性的抓取
# BV号为1Qi4y1x7Je的视频属性抓取结束
# 开始BV号为1yz4y1R7Gt视频属性的抓取
# BV号为1yz4y1R7Gt的视频属性抓取结束
# 开始BV号为1ht4y1176K视频属性的抓取
# BV号为1ht4y1176K的视频属性抓取结束
# 开始BV号为1bf4y1S7tT视频属性的抓取
# BV号为1bf4y1S7tT的视频属性抓取结束
# 开始BV号为1e54y1D7et视频属性的抓取
# BV号为1e54y1D7et的视频属性抓取结束
# 开始BV号为1tg4y1i79v视频属性的抓取
# BV号为1tg4y1i79v的视频属性抓取结束
# 开始BV号为1hT4y1u7WA视频属性的抓取
# BV号为1hT4y1u7WA的视频属性抓取结束
# 开始BV号为1Xa4y1v7dr视频属性的抓取
# BV号为1Xa4y1v7dr的视频属性抓取结束
# 开始BV号为1SV411C7J2视频属性的抓取
# BV号为1SV411C7J2的视频属性抓取结束
# 开始BV号为1fK411W7FM视频属性的抓取
# BV号为1fK411W7FM的视频属性抓取结束
# 开始BV号为1YV411C7Yq视频属性的抓取
# BV号为1YV411C7Yq的视频属性抓取结束
# 开始BV号为15k4y1r7yZ视频属性的抓取
# BV号为15k4y1r7yZ的视频属性抓取结束
# 开始BV号为1tT4y1g7Dd视频属性的抓取
# BV号为1tT4y1g7Dd的视频属性抓取结束
# 开始BV号为1Pz411q7yF视频属性的抓取
# BV号为1Pz411q7yF的视频属性抓取结束
# 开始BV号为1wz411B7Xp视频属性的抓取
# BV号为1wz411B7Xp的视频属性抓取结束
# 开始BV号为1sC4y1H7V5视频属性的抓取
# BV号为1sC4y1H7V5的视频属性抓取结束
# 开始BV号为19z4y1R7uq视频属性的抓取
# BV号为19z4y1R7uq的视频属性抓取结束
# 开始BV号为1ZC4y1W7Kb视频属性的抓取
# BV号为1ZC4y1W7Kb的视频属性抓取结束
# 开始BV号为1QT4y137dL视频属性的抓取
# BV号为1QT4y137dL的视频属性抓取结束
# 开始BV号为1HQ4y1N7hA视频属性的抓取
# BV号为1HQ4y1N7hA的视频属性抓取结束
# 开始BV号为1aA411q7pd视频属性的抓取
# BV号为1aA411q7pd的视频属性抓取结束
# 开始BV号为1pv411z7xL视频属性的抓取
# BV号为1pv411z7xL的视频属性抓取结束
# 开始BV号为1ht4y1C7Kg视频属性的抓取
# BV号为1ht4y1C7Kg的视频属性抓取结束
# 开始BV号为1UC4y1W7aw视频属性的抓取
# BV号为1UC4y1W7aw的视频属性抓取结束
# 开始BV号为17z4y1979Q视频属性的抓取
# BV号为17z4y1979Q的视频属性抓取结束
# 开始BV号为1LK411W7or视频属性的抓取
# BV号为1LK411W7or的视频属性抓取结束
# 开始BV号为1FK4y1b7T4视频属性的抓取
# BV号为1FK4y1b7T4的视频属性抓取结束
# 开始BV号为1YA41147BU视频属性的抓取
# BV号为1YA41147BU的视频属性抓取结束
# 开始BV号为1hV411d7Xb视频属性的抓取
# BV号为1hV411d7Xb的视频属性抓取结束
# 开始BV号为1Gk4y167R5视频属性的抓取
# BV号为1Gk4y167R5的视频属性抓取结束
# 开始BV号为13k4y1r7kW视频属性的抓取
# BV号为13k4y1r7kW的视频属性抓取结束
# 开始BV号为1PA411q7y2视频属性的抓取
# BV号为1PA411q7y2的视频属性抓取结束
# 开始BV号为13A411q7Rp视频属性的抓取
# BV号为13A411q7Rp的视频属性抓取结束
# 开始BV号为1zf4y127A7视频属性的抓取
# BV号为1zf4y127A7的视频属性抓取结束
# 开始BV号为1gp4y1X7oH视频属性的抓取
# BV号为1gp4y1X7oH的视频属性抓取结束
# 开始BV号为1NV411o7EE视频属性的抓取
# BV号为1NV411o7EE的视频属性抓取结束
# 开始BV号为1df4y117iG视频属性的抓取
# BV号为1df4y117iG的视频属性抓取结束
# 开始BV号为14k4y167c2视频属性的抓取
# BV号为14k4y167c2的视频属性抓取结束
# 开始BV号为14f4y1m7zb视频属性的抓取
# BV号为14f4y1m7zb的视频属性抓取结束
# 开始BV号为175411x736视频属性的抓取
# 开始BV号为175411x736视频属性的抓取
# BV号为175411x736的视频属性抓取结束
# 开始BV号为1j54y1X7k7视频属性的抓取
# BV号为1j54y1X7k7的视频属性抓取结束
# 开始BV号为1Qt4y127Sx视频属性的抓取
# BV号为1Qt4y127Sx的视频属性抓取结束
# 开始BV号为1Te411W7cb视频属性的抓取
# BV号为1Te411W7cb的视频属性抓取结束
# 开始BV号为1Y54y1X7rc视频属性的抓取
# BV号为1Y54y1X7rc的视频属性抓取结束
# 开始BV号为1zz411q7rg视频属性的抓取
# BV号为1zz411q7rg的视频属性抓取结束
# 开始BV号为1bt4y1C73Y视频属性的抓取
# BV号为1bt4y1C73Y的视频属性抓取结束
# 开始BV号为14i4y147GX视频属性的抓取
# BV号为14i4y147GX的视频属性抓取结束
# 开始BV号为1F5411s7Gn视频属性的抓取
# BV号为1F5411s7Gn的视频属性抓取结束
# 开始BV号为1sk4y167rZ视频属性的抓取
# BV号为1sk4y167rZ的视频属性抓取结束
# 开始BV号为1Vp4y1X73d视频属性的抓取
# BV号为1Vp4y1X73d的视频属性抓取结束
# 开始BV号为1dK411H78Y视频属性的抓取
# BV号为1dK411H78Y的视频属性抓取结束
# 开始BV号为13A411t7MF视频属性的抓取
# BV号为13A411t7MF的视频属性抓取结束
# 开始BV号为1xt4y1C71H视频属性的抓取
# BV号为1xt4y1C71H的视频属性抓取结束
# 开始BV号为1rt4y1C7VL视频属性的抓取
# BV号为1rt4y1C7VL的视频属性抓取结束
# 开始BV号为1Zf4y1m7Pe视频属性的抓取
# BV号为1Zf4y1m7Pe的视频属性抓取结束
# 开始BV号为1de411p7MS视频属性的抓取
# BV号为1de411p7MS的视频属性抓取结束
# 开始BV号为15V411C71a视频属性的抓取
# BV号为15V411C71a的视频属性抓取结束
# 开始BV号为1VV411d7pA视频属性的抓取
# BV号为1VV411d7pA的视频属性抓取结束
# 开始BV号为1mK41157v8视频属性的抓取
# BV号为1mK41157v8的视频属性抓取结束
# 开始BV号为14T4y1g72E视频属性的抓取
# BV号为14T4y1g72E的视频属性抓取结束
# 开始BV号为1hA411q7vm视频属性的抓取
# BV号为1hA411q7vm的视频属性抓取结束
# 开始BV号为1Tt4y117SA视频属性的抓取
# BV号为1Tt4y117SA的视频属性抓取结束
# 开始BV号为1pT4y1u7Eu视频属性的抓取
# BV号为1pT4y1u7Eu的视频属性抓取结束
# 开始BV号为1DZ4y1p745视频属性的抓取
# BV号为1DZ4y1p745的视频属性抓取结束
# 开始BV号为17k4y1k7FT视频属性的抓取
# BV号为17k4y1k7FT的视频属性抓取结束
# 开始BV号为1tp4y1X7E5视频属性的抓取
# BV号为1tp4y1X7E5的视频属性抓取结束
# 开始BV号为1fa4y1v7gj视频属性的抓取
# BV号为1fa4y1v7gj的视频属性抓取结束
# 开始BV号为1H54y1D78a视频属性的抓取
# BV号为1H54y1D78a的视频属性抓取结束
# 开始BV号为1Qp4y1S7Cz视频属性的抓取
# BV号为1Qp4y1S7Cz的视频属性抓取结束
# 开始BV号为15i4y147sU视频属性的抓取
# BV号为15i4y147sU的视频属性抓取结束
# 开始BV号为1EK411W78V视频属性的抓取
# BV号为1EK411W78V的视频属性抓取结束
# 开始BV号为1mT4y137oT视频属性的抓取
# BV号为1mT4y137oT的视频属性抓取结束
# 开始BV号为1mA411t77W视频属性的抓取
# BV号为1mA411t77W的视频属性抓取结束
# 开始BV号为1Hi4y1s7xJ视频属性的抓取
# BV号为1Hi4y1s7xJ的视频属性抓取结束
# 开始BV号为1kQ4y1A7FR视频属性的抓取
# BV号为1kQ4y1A7FR的视频属性抓取结束
# 开始BV号为1wC4y1W7FE视频属性的抓取
# BV号为1wC4y1W7FE的视频属性抓取结束
# 开始BV号为1QZ4y1s7Ys视频属性的抓取
# BV号为1QZ4y1s7Ys的视频属性抓取结束
# 开始BV号为1dV411d737视频属性的抓取
# BV号为1dV411d737的视频属性抓取结束
# 开始BV号为1U5411s7HE视频属性的抓取
# BV号为1U5411s7HE的视频属性抓取结束
# 开始BV号为1sg4y1i7EC视频属性的抓取
# BV号为1sg4y1i7EC的视频属性抓取结束
# 开始BV号为1xz411q77N视频属性的抓取
# BV号为1xz411q77N的视频属性抓取结束
# 开始BV号为1Pf4y127Xu视频属性的抓取
# BV号为1Pf4y127Xu的视频属性抓取结束
# 开始BV号为1DV411d7sC视频属性的抓取
# BV号为1DV411d7sC的视频属性抓取结束
# 开始BV号为1m54y1D7L4视频属性的抓取
# BV号为1m54y1D7L4的视频属性抓取结束
# 开始BV号为1xf4y1m77q视频属性的抓取
# BV号为1xf4y1m77q的视频属性抓取结束
# 开始BV号为1UT4y1u7vq视频属性的抓取
# BV号为1UT4y1u7vq的视频属性抓取结束
# 开始BV号为1NT4y1g7yt视频属性的抓取
# BV号为1NT4y1g7yt的视频属性抓取结束
# 开始BV号为1454y1X73n视频属性的抓取
# BV号为1454y1X73n的视频属性抓取结束
# 开始BV号为1pK411s7UA视频属性的抓取
# BV号为1pK411s7UA的视频属性抓取结束
# 开始BV号为1vp4y1Q75E视频属性的抓取
# BV号为1vp4y1Q75E的视频属性抓取结束
# 开始BV号为12z411q7mV视频属性的抓取
# BV号为12z411q7mV的视频属性抓取结束
# 开始BV号为1MQ4y1P7vo视频属性的抓取
# BV号为1MQ4y1P7vo的视频属性抓取结束
# 开始BV号为12V411k7vc视频属性的抓取
# BV号为12V411k7vc的视频属性抓取结束
# 开始BV号为1pK4y187j4视频属性的抓取
# BV号为1pK4y187j4的视频属性抓取结束
# 开始BV号为1FQ4y1K7nd视频属性的抓取
# BV号为1FQ4y1K7nd的视频属性抓取结束
# 开始BV号为1h64y1M7Ei视频属性的抓取
# BV号为1h64y1M7Ei的视频属性抓取结束
# 开始BV号为1cA411t7XE视频属性的抓取
# BV号为1cA411t7XE的视频属性抓取结束
# 开始BV号为1Ki4y147hH视频属性的抓取
# BV号为1Ki4y147hH的视频属性抓取结束
# 开始BV号为1nf4y1U7Pu视频属性的抓取
# BV号为1nf4y1U7Pu的视频属性抓取结束
# 开始BV号为1zK4y1x7Zv视频属性的抓取
# BV号为1zK4y1x7Zv的视频属性抓取结束
# 开始BV号为1Ji4y1G7TV视频属性的抓取
# BV号为1Ji4y1G7TV的视频属性抓取结束
# 开始BV号为1hK411p7v8视频属性的抓取
# BV号为1hK411p7v8的视频属性抓取结束
# 开始BV号为17Z4y1H7NK视频属性的抓取
# BV号为17Z4y1H7NK的视频属性抓取结束
# 开始BV号为16z411e7F4视频属性的抓取
# BV号为16z411e7F4的视频属性抓取结束
# 开始BV号为1S54y1B7r6视频属性的抓取
# BV号为1S54y1B7r6的视频属性抓取结束
# 开始BV号为1VV41167Vc视频属性的抓取
# BV号为1VV41167Vc的视频属性抓取结束
# 开始BV号为1eZ4y1H7U5视频属性的抓取
# BV号为1eZ4y1H7U5的视频属性抓取结束
# 开始BV号为1iZ4y1H7M9视频属性的抓取
# BV号为1iZ4y1H7M9的视频属性抓取结束
# 开始BV号为15i4y1x7NS视频属性的抓取
# BV号为15i4y1x7NS的视频属性抓取结束
# 开始BV号为12C4y187L2视频属性的抓取
# BV号为12C4y187L2的视频属性抓取结束
# 开始BV号为19V411r7Je视频属性的抓取
# BV号为19V411r7Je的视频属性抓取结束
# 开始BV号为1iz4y1Q7vZ视频属性的抓取
# BV号为1iz4y1Q7vZ的视频属性抓取结束
# 开始BV号为1z5411p78K视频属性的抓取
# BV号为1z5411p78K的视频属性抓取结束
# 开始BV号为1Kz4y1R76F视频属性的抓取
# BV号为1Kz4y1R76F的视频属性抓取结束
# 开始BV号为19V411r7Fx视频属性的抓取
# BV号为19V411r7Fx的视频属性抓取结束
# 开始BV号为1eA411q7MW视频属性的抓取
# BV号为1eA411q7MW的视频属性抓取结束
# 开始BV号为18a4y1Y7YG视频属性的抓取
# BV号为18a4y1Y7YG的视频属性抓取结束
# 开始BV号为1qV411r7PR视频属性的抓取
# BV号为1qV411r7PR的视频属性抓取结束
# 开始BV号为1YK411p7co视频属性的抓取
# BV号为1YK411p7co的视频属性抓取结束
# 开始BV号为17k4y1r7JY视频属性的抓取
# BV号为17k4y1r7JY的视频属性抓取结束
# 开始BV号为1ED4y1Q7XD视频属性的抓取
# BV号为1ED4y1Q7XD的视频属性抓取结束
# 开始BV号为1mt4y197gZ视频属性的抓取
# BV号为1mt4y197gZ的视频属性抓取结束
# 开始BV号为1SZ4y1M7Xa视频属性的抓取
# BV号为1SZ4y1M7Xa的视频属性抓取结束
# 开始BV号为1rT4y177H7视频属性的抓取
# BV号为1rT4y177H7的视频属性抓取结束
# 开始BV号为1cK411H7Xv视频属性的抓取
# BV号为1cK411H7Xv的视频属性抓取结束
# 开始BV号为1eK411n7rh视频属性的抓取
# BV号为1eK411n7rh的视频属性抓取结束
# 开始BV号为1Qf4y127xe视频属性的抓取
# BV号为1Qf4y127xe的视频属性抓取结束
# 开始BV号为1LA411i75K视频属性的抓取
# BV号为1LA411i75K的视频属性抓取结束
# 开始BV号为1Ji4y1G7k5视频属性的抓取
# BV号为1Ji4y1G7k5的视频属性抓取结束
# 开始BV号为12C4y1a7Xg视频属性的抓取
# BV号为12C4y1a7Xg的视频属性抓取结束
# 开始BV号为1aK4y147Wv视频属性的抓取
# BV号为1aK4y147Wv的视频属性抓取结束
# 开始BV号为14i4y1x7g7视频属性的抓取
# BV号为14i4y1x7g7的视频属性抓取结束
# 开始BV号为1Cg4y1v7qw视频属性的抓取
# BV号为1Cg4y1v7qw的视频属性抓取结束
# 开始BV号为1Qi4y1G7qM视频属性的抓取
# BV号为1Qi4y1G7qM的视频属性抓取结束
# 开始BV号为1ua4y1e7uT视频属性的抓取
# BV号为1ua4y1e7uT的视频属性抓取结束
# 开始BV号为1r5411p7DT视频属性的抓取
# BV号为1r5411p7DT的视频属性抓取结束
# 开始BV号为1gK4y147AB视频属性的抓取
# BV号为1gK4y147AB的视频属性抓取结束
# 开始BV号为1Kf4y1178G视频属性的抓取
# BV号为1Kf4y1178G的视频属性抓取结束
# 开始BV号为11k4y1z7b7视频属性的抓取
# BV号为11k4y1z7b7的视频属性抓取结束
# 开始BV号为1Yi4y1x7oP视频属性的抓取
# BV号为1Yi4y1x7oP的视频属性抓取结束
# 开始BV号为1Lz411i7jz视频属性的抓取
# BV号为1Lz411i7jz的视频属性抓取结束
# 开始BV号为18i4y1x7RV视频属性的抓取
# BV号为18i4y1x7RV的视频属性抓取结束
# 开始BV号为1ef4y127vv视频属性的抓取
# BV号为1ef4y127vv的视频属性抓取结束
# 开始BV号为1NV41167g8视频属性的抓取
# BV号为1NV41167g8的视频属性抓取结束
# 开始BV号为1Sv411B7Lj视频属性的抓取
# BV号为1Sv411B7Lj的视频属性抓取结束
# 开始BV号为1mK4y14765视频属性的抓取
# BV号为1mK4y14765的视频属性抓取结束
# 开始BV号为1fz411e7TP视频属性的抓取
# BV号为1fz411e7TP的视频属性抓取结束
# 开始BV号为1GA411B7pn视频属性的抓取
# BV号为1GA411B7pn的视频属性抓取结束
# 开始BV号为1JD4y1S7Ff视频属性的抓取
# BV号为1JD4y1S7Ff的视频属性抓取结束
# 开始BV号为1iV411r73L视频属性的抓取
# BV号为1iV411r73L的视频属性抓取结束
# 开始BV号为1V54y1z7qC视频属性的抓取
# BV号为1V54y1z7qC的视频属性抓取结束
# 开始BV号为1d54y1i7BS视频属性的抓取
# BV号为1d54y1i7BS的视频属性抓取结束
# 开始BV号为1yA411q7Cq视频属性的抓取
# BV号为1yA411q7Cq的视频属性抓取结束
# 开始BV号为1Gt4y1975f视频属性的抓取
# BV号为1Gt4y1975f的视频属性抓取结束
# 开始BV号为1rk4y1q74p视频属性的抓取
# BV号为1rk4y1q74p的视频属性抓取结束
# 开始BV号为1UT4y1E7P7视频属性的抓取
# BV号为1UT4y1E7P7的视频属性抓取结束
# 开始BV号为1ya4y1h7AC视频属性的抓取
# BV号为1ya4y1h7AC的视频属性抓取结束
# 开始BV号为1yD4y1D7Az视频属性的抓取
# BV号为1yD4y1D7Az的视频属性抓取结束
# 开始BV号为1CQ4y1P7jB视频属性的抓取
# BV号为1CQ4y1P7jB的视频属性抓取结束
# 开始BV号为1yk4y1674p视频属性的抓取
# BV号为1yk4y1674p的视频属性抓取结束
# 开始BV号为14T4y1g7wK视频属性的抓取
# BV号为14T4y1g7wK的视频属性抓取结束
# 开始BV号为1yt4y197Tw视频属性的抓取
# BV号为1yt4y197Tw的视频属性抓取结束
# 开始BV号为1754y1Q79H视频属性的抓取
# BV号为1754y1Q79H的视频属性抓取结束
# 开始BV号为1Tz4y1R7i8视频属性的抓取
# BV号为1Tz4y1R7i8的视频属性抓取结束
# 开始BV号为1ek4y1z76t视频属性的抓取
# BV号为1ek4y1z76t的视频属性抓取结束
# 开始BV号为1RK4y1x7qi视频属性的抓取
# BV号为1RK4y1x7qi的视频属性抓取结束
# 开始BV号为1VK4y1s7Dx视频属性的抓取
# BV号为1VK4y1s7Dx的视频属性抓取结束
# 开始BV号为14Q4y1P79v视频属性的抓取
# BV号为14Q4y1P79v的视频属性抓取结束
# 开始BV号为13K411H7kf视频属性的抓取
# BV号为13K411H7kf的视频属性抓取结束
# 开始BV号为1Yf4y1y7fi视频属性的抓取
# BV号为1Yf4y1y7fi的视频属性抓取结束
# 开始BV号为1jK411p78Z视频属性的抓取
# BV号为1jK411p78Z的视频属性抓取结束
# 开始BV号为1Ez411i7ut视频属性的抓取
# BV号为1Ez411i7ut的视频属性抓取结束
# 开始BV号为1v54y1B7Yi视频属性的抓取
# BV号为1v54y1B7Yi的视频属性抓取结束
# 开始BV号为1rQ4y1P7YX视频属性的抓取
# 开始BV号为1rQ4y1P7YX视频属性的抓取
# 开始BV号为1rQ4y1P7YX视频属性的抓取
# BV号为1rQ4y1P7YX的视频属性抓取结束
# 开始BV号为1WT4y177RY视频属性的抓取
# BV号为1WT4y177RY的视频属性抓取结束
# 开始BV号为1eK411n7Ck视频属性的抓取
# BV号为1eK411n7Ck的视频属性抓取结束
# 开始BV号为1fZ4y1n7EG视频属性的抓取
# BV号为1fZ4y1n7EG的视频属性抓取结束
# 开始BV号为1FC4y1a7Fc视频属性的抓取
# BV号为1FC4y1a7Fc的视频属性抓取结束
# 开始BV号为15t4y1y7xw视频属性的抓取
# BV号为15t4y1y7xw的视频属性抓取结束
# 开始BV号为1K5411W7hL视频属性的抓取
# BV号为1K5411W7hL的视频属性抓取结束
# 开始BV号为1Vg4y1v76z视频属性的抓取
# BV号为1Vg4y1v76z的视频属性抓取结束
# 开始BV号为1Fz411i7bS视频属性的抓取
# BV号为1Fz411i7bS的视频属性抓取结束
# 开始BV号为1BC4y187CS视频属性的抓取
# BV号为1BC4y187CS的视频属性抓取结束
# 开始BV号为1tZ4y1H7rf视频属性的抓取
# BV号为1tZ4y1H7rf的视频属性抓取结束
# 开始BV号为1ai4y1G7yZ视频属性的抓取
# BV号为1ai4y1G7yZ的视频属性抓取结束
# 开始BV号为1dp4y1S7rT视频属性的抓取
# BV号为1dp4y1S7rT的视频属性抓取结束
# 开始BV号为1pV411r7J6视频属性的抓取
# BV号为1pV411r7J6的视频属性抓取结束
# 开始BV号为11g4y1i7iA视频属性的抓取
# BV号为11g4y1i7iA的视频属性抓取结束
# 开始BV号为11V411r7XL视频属性的抓取
# BV号为11V411r7XL的视频属性抓取结束
# 开始BV号为1Z54y1B7SD视频属性的抓取
# BV号为1Z54y1B7SD的视频属性抓取结束
# 开始BV号为1gi4y1x7Pu视频属性的抓取
# BV号为1gi4y1x7Pu的视频属性抓取结束
# 开始BV号为1Lg4y1q7nq视频属性的抓取
# BV号为1Lg4y1q7nq的视频属性抓取结束
# 开始BV号为16V411r7Dd视频属性的抓取
# BV号为16V411r7Dd的视频属性抓取结束
# 开始BV号为15C4y1a7w1视频属性的抓取
# BV号为15C4y1a7w1的视频属性抓取结束
# 开始BV号为1rK4y1x7Mo视频属性的抓取
# BV号为1rK4y1x7Mo的视频属性抓取结束
# 开始BV号为1jz411v7sx视频属性的抓取
# BV号为1jz411v7sx的视频属性抓取结束
# 开始BV号为1bz411e7PP视频属性的抓取
# BV号为1bz411e7PP的视频属性抓取结束
# 开始BV号为1vV411r7Lv视频属性的抓取
# BV号为1vV411r7Lv的视频属性抓取结束
# 开始BV号为1AK411p7V3视频属性的抓取
# BV号为1AK411p7V3的视频属性抓取结束
# 开始BV号为1pV411z7sV视频属性的抓取
# BV号为1pV411z7sV的视频属性抓取结束
# 开始BV号为1yV41167b4视频属性的抓取
# BV号为1yV41167b4的视频属性抓取结束
# 开始BV号为1hh411Z7DJ视频属性的抓取
# BV号为1hh411Z7DJ的视频属性抓取结束
# 开始BV号为1Vi4y137hG视频属性的抓取
# BV号为1Vi4y137hG的视频属性抓取结束
# 开始BV号为1y5411a75h视频属性的抓取
# BV号为1y5411a75h的视频属性抓取结束
# 开始BV号为1KK411J71c视频属性的抓取
# BV号为1KK411J71c的视频属性抓取结束
# 开始BV号为1AK4y1x7Gm视频属性的抓取
# BV号为1AK4y1x7Gm的视频属性抓取结束
# 开始BV号为1ei4y1V7jS视频属性的抓取
# BV号为1ei4y1V7jS的视频属性抓取结束
# 开始BV号为1Ri4y137pd视频属性的抓取
# BV号为1Ri4y137pd的视频属性抓取结束
# 开始BV号为18K4y1x7Fw视频属性的抓取
# BV号为18K4y1x7Fw的视频属性抓取结束
# 开始BV号为1pA411v7FV视频属性的抓取
# BV号为1pA411v7FV的视频属性抓取结束
# 开始BV号为1dk4y127k1视频属性的抓取
# BV号为1dk4y127k1的视频属性抓取结束
# 开始BV号为1qK4y1s7CE视频属性的抓取
# BV号为1qK4y1s7CE的视频属性抓取结束
# 开始BV号为1uv411q7Q7视频属性的抓取
# BV号为1uv411q7Q7的视频属性抓取结束
# 开始BV号为13A411v7Fi视频属性的抓取
# BV号为13A411v7Fi的视频属性抓取结束
# 开始BV号为15a4y1a7Db视频属性的抓取
# BV号为15a4y1a7Db的视频属性抓取结束
# 开始BV号为16V411B75J视频属性的抓取
# BV号为16V411B75J的视频属性抓取结束
# 开始BV号为1LC4y1b796视频属性的抓取
# BV号为1LC4y1b796的视频属性抓取结束
# 开始BV号为1yK411J7ih视频属性的抓取
# BV号为1yK411J7ih的视频属性抓取结束
# 开始BV号为1xA411v74W视频属性的抓取
# BV号为1xA411v74W的视频属性抓取结束
# 开始BV号为1vT4y1j7FE视频属性的抓取
# BV号为1vT4y1j7FE的视频属性抓取结束
# 开始BV号为1GZ4y1u7RK视频属性的抓取
# BV号为1GZ4y1u7RK的视频属性抓取结束
# 开始BV号为1HC4y1h7Vw视频属性的抓取
# BV号为1HC4y1h7Vw的视频属性抓取结束
# 开始BV号为1Sg4y1v7ZP视频属性的抓取
# BV号为1Sg4y1v7ZP的视频属性抓取结束
# 开始BV号为1nv411q7r2视频属性的抓取
# BV号为1nv411q7r2的视频属性抓取结束
# 开始BV号为16v411B74F视频属性的抓取
# BV号为16v411B74F的视频属性抓取结束
# 开始BV号为1hK411J724视频属性的抓取
# BV号为1hK411J724的视频属性抓取结束
# 开始BV号为1b5411Y7Tc视频属性的抓取
# BV号为1b5411Y7Tc的视频属性抓取结束
# 开始BV号为18k4y1q7tY视频属性的抓取
# BV号为18k4y1q7tY的视频属性抓取结束
# 开始BV号为1Sv411i7tB视频属性的抓取
# BV号为1Sv411i7tB的视频属性抓取结束
# 开始BV号为1fz4y1D77y视频属性的抓取
# BV号为1fz4y1D77y的视频属性抓取结束
# 开始BV号为1Jz4y1Q7KG视频属性的抓取
# BV号为1Jz4y1Q7KG的视频属性抓取结束
# 开始BV号为13K411n7LL视频属性的抓取
# BV号为13K411n7LL的视频属性抓取结束
# 开始BV号为1W54y1q782视频属性的抓取
# BV号为1W54y1q782的视频属性抓取结束
# 开始BV号为1Jp4y1q7ci视频属性的抓取
# BV号为1Jp4y1q7ci的视频属性抓取结束
# 开始BV号为1cp4y1S7hQ视频属性的抓取
# 开始BV号为1cp4y1S7hQ视频属性的抓取
# BV号为1cp4y1S7hQ的视频属性抓取结束
# 开始BV号为1eZ4y1T7Jv视频属性的抓取
# BV号为1eZ4y1T7Jv的视频属性抓取结束
# 开始BV号为1Zp4y1U7er视频属性的抓取
# BV号为1Zp4y1U7er的视频属性抓取结束
# 开始BV号为1G54y1D7NS视频属性的抓取
# BV号为1G54y1D7NS的视频属性抓取结束
# 开始BV号为1cK411n7nL视频属性的抓取
# BV号为1cK411n7nL的视频属性抓取结束
# 开始BV号为1yK4y1e7tu视频属性的抓取
# BV号为1yK4y1e7tu的视频属性抓取结束
# 开始BV号为1F54y1B7dB视频属性的抓取
# BV号为1F54y1B7dB的视频属性抓取结束
# 开始BV号为1fv411B7us视频属性的抓取
# BV号为1fv411B7us的视频属性抓取结束
# 开始BV号为1Vg4y1i7rw视频属性的抓取
# BV号为1Vg4y1i7rw的视频属性抓取结束
# 开始BV号为1LV411r7qG视频属性的抓取
# BV号为1LV411r7qG的视频属性抓取结束
# 开始BV号为1Af4y197QN视频属性的抓取
# 开始BV号为1Af4y197QN视频属性的抓取
# 开始BV号为1Af4y197QN视频属性的抓取
# BV号为1Af4y197QN的视频属性抓取结束
# 开始BV号为1aV411z7iM视频属性的抓取
# BV号为1aV411z7iM的视频属性抓取结束
# 开始BV号为1Yk4y1B7JG视频属性的抓取
# BV号为1Yk4y1B7JG的视频属性抓取结束
# 开始BV号为1Uv411B7Pm视频属性的抓取
# BV号为1Uv411B7Pm的视频属性抓取结束
# 开始BV号为1S64y1F7qC视频属性的抓取
# BV号为1S64y1F7qC的视频属性抓取结束
# 开始BV号为1Za4y1E7qM视频属性的抓取
# BV号为1Za4y1E7qM的视频属性抓取结束
# 开始BV号为1vC4y187QN视频属性的抓取
# BV号为1vC4y187QN的视频属性抓取结束
# 开始BV号为1YC4y1b7ff视频属性的抓取
# BV号为1YC4y1b7ff的视频属性抓取结束
# 开始BV号为1yT4y177aM视频属性的抓取
# BV号为1yT4y177aM的视频属性抓取结束
# 开始BV号为1QD4y1S7st视频属性的抓取
# BV号为1QD4y1S7st的视频属性抓取结束
# 开始BV号为14g4y1v7XG视频属性的抓取
# BV号为14g4y1v7XG的视频属性抓取结束
# 开始BV号为1jA411v77V视频属性的抓取
# BV号为1jA411v77V的视频属性抓取结束
# 开始BV号为1Av411q7eH视频属性的抓取
# BV号为1Av411q7eH的视频属性抓取结束
# 开始BV号为1rC4y18781视频属性的抓取
# BV号为1rC4y18781的视频属性抓取结束
# 开始BV号为1B54y1S7hs视频属性的抓取
# BV号为1B54y1S7hs的视频属性抓取结束
# 开始BV号为1xT4y1E7FF视频属性的抓取
# BV号为1xT4y1E7FF的视频属性抓取结束
# 开始BV号为1HC4y1h7NY视频属性的抓取
# BV号为1HC4y1h7NY的视频属性抓取结束
# 开始BV号为1KD4y1S7ei视频属性的抓取
# BV号为1KD4y1S7ei的视频属性抓取结束
# 开始BV号为13K4y1s7m8视频属性的抓取
# BV号为13K4y1s7m8的视频属性抓取结束
# 开始BV号为12K411J7ay视频属性的抓取
# BV号为12K411J7ay的视频属性抓取结束
# 开始BV号为1Wp4y1q7N3视频属性的抓取
# BV号为1Wp4y1q7N3的视频属性抓取结束
# 开始BV号为1bt4y1976M视频属性的抓取
# BV号为1bt4y1976M的视频属性抓取结束
# 开始BV号为1Z54y1S7b8视频属性的抓取
# BV号为1Z54y1S7b8的视频属性抓取结束
# 开始BV号为1pD4y1U7vS视频属性的抓取
# BV号为1pD4y1U7vS的视频属性抓取结束
# 开始BV号为1Pz4y1Q7jY视频属性的抓取
# BV号为1Pz4y1Q7jY的视频属性抓取结束
# 开始BV号为1SK4y1s7S5视频属性的抓取
# BV号为1SK4y1s7S5的视频属性抓取结束
# 开始BV号为1tt4y1Q7xU视频属性的抓取
# BV号为1tt4y1Q7xU的视频属性抓取结束
# 开始BV号为1d54y1q76p视频属性的抓取
# BV号为1d54y1q76p的视频属性抓取结束
# 开始BV号为1jD4y1D74X视频属性的抓取
# BV号为1jD4y1D74X的视频属性抓取结束
# 开始BV号为1Ba4y1E7Cb视频属性的抓取
# BV号为1Ba4y1E7Cb的视频属性抓取结束
# 开始BV号为1aV411k75N视频属性的抓取
# BV号为1aV411k75N的视频属性抓取结束
# 开始BV号为1KZ4y1M7CP视频属性的抓取
# BV号为1KZ4y1M7CP的视频属性抓取结束
# 开始BV号为1aC4y1h7q4视频属性的抓取
# BV号为1aC4y1h7q4的视频属性抓取结束
# 开始BV号为1Tv411z78K视频属性的抓取
# BV号为1Tv411z78K的视频属性抓取结束
# 开始BV号为1PT4y1E7cd视频属性的抓取
# BV号为1PT4y1E7cd的视频属性抓取结束
# 开始BV号为1Pz4y1X7H3视频属性的抓取
# BV号为1Pz4y1X7H3的视频属性抓取结束
# 开始BV号为1p5411Y7D4视频属性的抓取
# BV号为1p5411Y7D4的视频属性抓取结束
# 开始BV号为1UT4y1j7Zi视频属性的抓取
# BV号为1UT4y1j7Zi的视频属性抓取结束
# 开始BV号为1yp4y1U7TT视频属性的抓取
# BV号为1yp4y1U7TT的视频属性抓取结束
# 开始BV号为1zz411v7sE视频属性的抓取
# BV号为1zz411v7sE的视频属性抓取结束
# 开始BV号为1yC4y187Kv视频属性的抓取
# BV号为1yC4y187Kv的视频属性抓取结束
# 开始BV号为1if4y1X774视频属性的抓取
# BV号为1if4y1X774的视频属性抓取结束
# 开始BV号为1154y1q7FU视频属性的抓取
# BV号为1154y1q7FU的视频属性抓取结束
# 开始BV号为17t4y1D7Ma视频属性的抓取
# BV号为17t4y1D7Ma的视频属性抓取结束
# 开始BV号为1Vf4y1R7HD视频属性的抓取
# BV号为1Vf4y1R7HD的视频属性抓取结束
# 开始BV号为1yh411o7K2视频属性的抓取
# BV号为1yh411o7K2的视频属性抓取结束
# 开始BV号为1hV411z7qR视频属性的抓取
# BV号为1hV411z7qR的视频属性抓取结束
# 开始BV号为1b54y1v7xi视频属性的抓取
# BV号为1b54y1v7xi的视频属性抓取结束
# 开始BV号为1Xp4y1U7sd视频属性的抓取
# BV号为1Xp4y1U7sd的视频属性抓取结束
# 开始BV号为1hT4y1E7Y3视频属性的抓取
# BV号为1hT4y1E7Y3的视频属性抓取结束
# 开始BV号为15p4y1S7KZ视频属性的抓取
# BV号为15p4y1S7KZ的视频属性抓取结束
# 开始BV号为1Ez4y1Q7XE视频属性的抓取
# BV号为1Ez4y1Q7XE的视频属性抓取结束
# 开始BV号为1xk4y1m7VY视频属性的抓取
# BV号为1xk4y1m7VY的视频属性抓取结束
# 开始BV号为1AD4y1S74F视频属性的抓取
# BV号为1AD4y1S74F的视频属性抓取结束
# 开始BV号为1Q5411h7vU视频属性的抓取
# BV号为1Q5411h7vU的视频属性抓取结束
# 开始BV号为1T5411h7dA视频属性的抓取
# BV号为1T5411h7dA的视频属性抓取结束
# 开始BV号为1zf4y1Q7yM视频属性的抓取
# BV号为1zf4y1Q7yM的视频属性抓取结束
# 开始BV号为1G54y1D766视频属性的抓取
# BV号为1G54y1D766的视频属性抓取结束
# 开始BV号为1Yh411d7o1视频属性的抓取
# BV号为1Yh411d7o1的视频属性抓取结束
# 开始BV号为1Nf4y197eA视频属性的抓取
# BV号为1Nf4y197eA的视频属性抓取结束
# 开始BV号为1C54y1U7qL视频属性的抓取
# BV号为1C54y1U7qL的视频属性抓取结束
# 开始BV号为19f4y197m4视频属性的抓取
# BV号为19f4y197m4的视频属性抓取结束
# 开始BV号为1Tp4y1v7dW视频属性的抓取
# BV号为1Tp4y1v7dW的视频属性抓取结束
# 开始BV号为11V411z7uk视频属性的抓取
# BV号为11V411z7uk的视频属性抓取结束
# 开始BV号为1hp4y1v7aR视频属性的抓取
# BV号为1hp4y1v7aR的视频属性抓取结束
# 开始BV号为1Nf4y1972p视频属性的抓取
# BV号为1Nf4y1972p的视频属性抓取结束
# 开始BV号为1if4y197W1视频属性的抓取
# BV号为1if4y197W1的视频属性抓取结束
# 开始BV号为1Pi4y1g76w视频属性的抓取
# BV号为1Pi4y1g76w的视频属性抓取结束
# 开始BV号为1Yp4y1q7Ax视频属性的抓取
# BV号为1Yp4y1q7Ax的视频属性抓取结束
# 开始BV号为1XD4y1U7oH视频属性的抓取
# BV号为1XD4y1U7oH的视频属性抓取结束
# 开始BV号为1rp4y1v7ue视频属性的抓取
# BV号为1rp4y1v7ue的视频属性抓取结束
# 开始BV号为11f4y197As视频属性的抓取
# BV号为11f4y197As的视频属性抓取结束
# 开始BV号为19K4y1v7Kv视频属性的抓取
# BV号为19K4y1v7Kv的视频属性抓取结束
# 开始BV号为1Mh411o7Vz视频属性的抓取
# BV号为1Mh411o7Vz的视频属性抓取结束
# 开始BV号为1YD4y127WV视频属性的抓取
# BV号为1YD4y127WV的视频属性抓取结束
# 开始BV号为1mT4y157tv视频属性的抓取
# BV号为1mT4y157tv的视频属性抓取结束
# 开始BV号为1wA411e76B视频属性的抓取
# BV号为1wA411e76B的视频属性抓取结束
# 开始BV号为1Jf4y1976f视频属性的抓取
# BV号为1Jf4y1976f的视频属性抓取结束
# 开始BV号为16541187te视频属性的抓取
# BV号为16541187te的视频属性抓取结束
# 开始BV号为1sK4y1e7ns视频属性的抓取
# BV号为1sK4y1e7ns的视频属性抓取结束
# 开始BV号为1yD4y127yr视频属性的抓取
# BV号为1yD4y127yr的视频属性抓取结束
# 开始BV号为18V411z7eE视频属性的抓取
# BV号为18V411z7eE的视频属性抓取结束
# 开始BV号为1tV411U78M视频属性的抓取
# BV号为1tV411U78M的视频属性抓取结束
# 开始BV号为18541187N3视频属性的抓取
# BV号为18541187N3的视频属性抓取结束
# 开始BV号为1sz4y1Q7y2视频属性的抓取
# BV号为1sz4y1Q7y2的视频属性抓取结束
# 开始BV号为17z4y1f7g6视频属性的抓取
# BV号为17z4y1f7g6的视频属性抓取结束
# 开始BV号为1aZ4y1K7v6视频属性的抓取
# BV号为1aZ4y1K7v6的视频属性抓取结束
# 开始BV号为16K4y1Y7bF视频属性的抓取
# BV号为16K4y1Y7bF的视频属性抓取结束
# 开始BV号为1bK4y1v7bF视频属性的抓取
# BV号为1bK4y1v7bF的视频属性抓取结束
# 开始BV号为1Si4y1g7L6视频属性的抓取
# BV号为1Si4y1g7L6的视频属性抓取结束
# 开始BV号为1Ri4y1u7yC视频属性的抓取
# BV号为1Ri4y1u7yC的视频属性抓取结束
# 开始BV号为1iA411Y7on视频属性的抓取
# BV号为1iA411Y7on的视频属性抓取结束
# 开始BV号为13A411e7uf视频属性的抓取
# BV号为13A411e7uf的视频属性抓取结束
# 开始BV号为18K4y1e7qD视频属性的抓取
# BV号为18K4y1e7qD的视频属性抓取结束
# 开始BV号为1gC4y1t7N2视频属性的抓取
# BV号为1gC4y1t7N2的视频属性抓取结束
# 开始BV号为1m54y1v7Ao视频属性的抓取
# BV号为1m54y1v7Ao的视频属性抓取结束
# 开始BV号为1fz4y1f7rD视频属性的抓取
# BV号为1fz4y1f7rD的视频属性抓取结束
# 开始BV号为1Qz4y1f7uP视频属性的抓取
# BV号为1Qz4y1f7uP的视频属性抓取结束
# 开始BV号为12C4y147xw视频属性的抓取
# BV号为12C4y147xw的视频属性抓取结束
# 开始BV号为1Nf4y19715视频属性的抓取
# BV号为1Nf4y19715的视频属性抓取结束
# 开始BV号为1z64y1F7bn视频属性的抓取
# BV号为1z64y1F7bn的视频属性抓取结束
# 开始BV号为1G54y1e779视频属性的抓取
# BV号为1G54y1e779的视频属性抓取结束
# 开始BV号为1Ft4y1S77v视频属性的抓取
# BV号为1Ft4y1S77v的视频属性抓取结束
# 开始BV号为14C4y1t7WU视频属性的抓取
# BV号为14C4y1t7WU的视频属性抓取结束
# 开始BV号为1L54y1e7ar视频属性的抓取
# BV号为1L54y1e7ar的视频属性抓取结束
# 开始BV号为1CK4y1Y7TB视频属性的抓取
# BV号为1CK4y1Y7TB的视频属性抓取结束
# 开始BV号为14a4y1E7wV视频属性的抓取
# BV号为14a4y1E7wV的视频属性抓取结束
# 开始BV号为1TZ4y1M7MY视频属性的抓取
# BV号为1TZ4y1M7MY的视频属性抓取结束
# 开始BV号为11D4y1U7fg视频属性的抓取
# BV号为11D4y1U7fg的视频属性抓取结束
# 开始BV号为16V411z7Ye视频属性的抓取
# BV号为16V411z7Ye的视频属性抓取结束
# 开始BV号为1QT4y157zM视频属性的抓取
# BV号为1QT4y157zM的视频属性抓取结束
# 开始BV号为1y54y1S7fu视频属性的抓取
# BV号为1y54y1S7fu的视频属性抓取结束
# 开始BV号为1EK4y1e72u视频属性的抓取
# BV号为1EK4y1e72u的视频属性抓取结束
# 开始BV号为1wA411n7Ts视频属性的抓取
# BV号为1wA411n7Ts的视频属性抓取结束
# 开始BV号为1Gk4y127zj视频属性的抓取
# BV号为1Gk4y127zj的视频属性抓取结束
# 开始BV号为1pp4y1v7Vf视频属性的抓取
# BV号为1pp4y1v7Vf的视频属性抓取结束
# 开始BV号为145411a74G视频属性的抓取
# BV号为145411a74G的视频属性抓取结束
# 开始BV号为16C4y1b7VP视频属性的抓取
# BV号为16C4y1b7VP的视频属性抓取结束
# 开始BV号为1WC4y187HH视频属性的抓取
# BV号为1WC4y187HH的视频属性抓取结束
# 开始BV号为15K411n7EV视频属性的抓取
# BV号为15K411n7EV的视频属性抓取结束
# 开始BV号为13k4y1m7eh视频属性的抓取
# BV号为13k4y1m7eh的视频属性抓取结束
# 开始BV号为1za4y1J7PR视频属性的抓取
# BV号为1za4y1J7PR的视频属性抓取结束
# 开始BV号为1dV411U7kM视频属性的抓取
# BV号为1dV411U7kM的视频属性抓取结束
# 开始BV号为17Z4y1M7y2视频属性的抓取
# BV号为17Z4y1M7y2的视频属性抓取结束
# 开始BV号为1KA411n7rR视频属性的抓取
# BV号为1KA411n7rR的视频属性抓取结束
# 开始BV号为1i54y1U77n视频属性的抓取
# BV号为1i54y1U77n的视频属性抓取结束
# 开始BV号为18a4y1J7ur视频属性的抓取
# BV号为18a4y1J7ur的视频属性抓取结束
# 开始BV号为1364y1c7Am视频属性的抓取
# BV号为1364y1c7Am的视频属性抓取结束
# 开始BV号为1sD4y127Re视频属性的抓取
# BV号为1sD4y127Re的视频属性抓取结束
# 开始BV号为14K411T7h6视频属性的抓取
# BV号为14K411T7h6的视频属性抓取结束
# 开始BV号为1FD4y1m7o5视频属性的抓取
# BV号为1FD4y1m7o5的视频属性抓取结束
# 开始BV号为1uZ4y1T7zo视频属性的抓取
# BV号为1uZ4y1T7zo的视频属性抓取结束
# 开始BV号为1ti4y1M76j视频属性的抓取
# BV号为1ti4y1M76j的视频属性抓取结束
# 开始BV号为1Ut4y1U7Vm视频属性的抓取
# BV号为1Ut4y1U7Vm的视频属性抓取结束
# 开始BV号为11V411z7A2视频属性的抓取
# BV号为11V411z7A2的视频属性抓取结束
# 开始BV号为1Hk4y1m76z视频属性的抓取
# BV号为1Hk4y1m76z的视频属性抓取结束
# 开始BV号为1Pf4y197VE视频属性的抓取
# BV号为1Pf4y197VE的视频属性抓取结束
# 开始BV号为1VD4y1U7sp视频属性的抓取
# BV号为1VD4y1U7sp的视频属性抓取结束
# 开始BV号为1Q54y1m7gn视频属性的抓取
# BV号为1Q54y1m7gn的视频属性抓取结束
# 开始BV号为16Z4y1T7L1视频属性的抓取
# BV号为16Z4y1T7L1的视频属性抓取结束
# 开始BV号为1qV411U7Jv视频属性的抓取
# BV号为1qV411U7Jv的视频属性抓取结束
# 开始BV号为1va4y17767视频属性的抓取
# BV号为1va4y17767的视频属性抓取结束
# 开始BV号为1i541187JV视频属性的抓取
# BV号为1i541187JV的视频属性抓取结束
# 开始BV号为1fZ4y1K7Et视频属性的抓取
# BV号为1fZ4y1K7Et的视频属性抓取结束
# 开始BV号为1ya4y1J7yk视频属性的抓取
# BV号为1ya4y1J7yk的视频属性抓取结束
# 开始BV号为1454y1e73T视频属性的抓取
# BV号为1454y1e73T的视频属性抓取结束
# 开始BV号为1PC4y1b7q5视频属性的抓取
# BV号为1PC4y1b7q5的视频属性抓取结束
# 开始BV号为1AV411z7oJ视频属性的抓取
# BV号为1AV411z7oJ的视频属性抓取结束
# 开始BV号为1pa4y177Dr视频属性的抓取
# BV号为1pa4y177Dr的视频属性抓取结束
# 开始BV号为1Wa4y1J7Zz视频属性的抓取
# BV号为1Wa4y1J7Zz的视频属性抓取结束
# 开始BV号为1Nh411o7at视频属性的抓取
# BV号为1Nh411o7at的视频属性抓取结束
# 开始BV号为1Np4y1v7EY视频属性的抓取
# BV号为1Np4y1v7EY的视频属性抓取结束
# 开始BV号为16k4y127M8视频属性的抓取
# BV号为16k4y127M8的视频属性抓取结束
# 开始BV号为1RD4y1m7pZ视频属性的抓取
# BV号为1RD4y1m7pZ的视频属性抓取结束
# 开始BV号为1HZ4y1K78f视频属性的抓取
# BV号为1HZ4y1K78f的视频属性抓取结束
# 开始BV号为1gz4y1Z7Nz视频属性的抓取
# BV号为1gz4y1Z7Nz的视频属性抓取结束
# 开始BV号为1cC4y1b7zS视频属性的抓取
# BV号为1cC4y1b7zS的视频属性抓取结束
# 开始BV号为1Xa4y1L7FA视频属性的抓取
# BV号为1Xa4y1L7FA的视频属性抓取结束
# 开始BV号为1wa4y1775i视频属性的抓取
# BV号为1wa4y1775i的视频属性抓取结束
# 开始BV号为1vD4y1o7RT视频属性的抓取
# BV号为1vD4y1o7RT的视频属性抓取结束
# 开始BV号为15D4y1o7wK视频属性的抓取
# BV号为15D4y1o7wK的视频属性抓取结束
# 开始BV号为1gp4y1e7WS视频属性的抓取
# BV号为1gp4y1e7WS的视频属性抓取结束
# 开始BV号为1Z54y1C7xe视频属性的抓取
# BV号为1Z54y1C7xe的视频属性抓取结束
# 开始BV号为1Jv411C7fx视频属性的抓取
# BV号为1Jv411C7fx的视频属性抓取结束
# 开始BV号为125411b7Yu视频属性的抓取
# BV号为125411b7Yu的视频属性抓取结束
# 开始BV号为1AZ4y1N7t9视频属性的抓取
# BV号为1AZ4y1N7t9的视频属性抓取结束
# 开始BV号为1Ra4y177qi视频属性的抓取
# BV号为1Ra4y177qi的视频属性抓取结束
# 开始BV号为1764y1F7QZ视频属性的抓取
# BV号为1764y1F7QZ的视频属性抓取结束
# 开始BV号为1zK411K7WK视频属性的抓取
# BV号为1zK411K7WK的视频属性抓取结束
# 开始BV号为1mk4y1y7zM视频属性的抓取
# BV号为1mk4y1y7zM的视频属性抓取结束
# 开始BV号为1Yk4y1C79i视频属性的抓取
# BV号为1Yk4y1C79i的视频属性抓取结束
# 开始BV号为1KD4y1o7XC视频属性的抓取
# BV号为1KD4y1o7XC的视频属性抓取结束
# 开始BV号为1ty4y1y7b1视频属性的抓取
# BV号为1ty4y1y7b1的视频属性抓取结束
# 开始BV号为1Rf4y1Q7vd视频属性的抓取
# BV号为1Rf4y1Q7vd的视频属性抓取结束
# 开始BV号为17t4y1q7DA视频属性的抓取
# BV号为17t4y1q7DA的视频属性抓取结束
# 开始BV号为1cD4y1Z7JV视频属性的抓取
# BV号为1cD4y1Z7JV的视频属性抓取结束
# 开始BV号为1Pf4y1Q7cG视频属性的抓取
# BV号为1Pf4y1Q7cG的视频属性抓取结束
# 开始BV号为15K411K7Ka视频属性的抓取
# BV号为15K411K7Ka的视频属性抓取结束
# 开始BV号为1AZ4y1N7fg视频属性的抓取
# BV号为1AZ4y1N7fg的视频属性抓取结束
# 开始BV号为14p4y1a7j3视频属性的抓取
# BV号为14p4y1a7j3的视频属性抓取结束
# 开始BV号为1Q54y1C7Tm视频属性的抓取
# BV号为1Q54y1C7Tm的视频属性抓取结束
# 开始BV号为1Qf4y1D7Dw视频属性的抓取
# BV号为1Qf4y1D7Dw的视频属性抓取结束
# 开始BV号为1Wk4y1y7WH视频属性的抓取
# BV号为1Wk4y1y7WH的视频属性抓取结束
# 开始BV号为1tK4y1a79j视频属性的抓取
# BV号为1tK4y1a79j的视频属性抓取结束
# 开始BV号为1fi4y1M7sR视频属性的抓取
# BV号为1fi4y1M7sR的视频属性抓取结束
# 开始BV号为1ra4y1j7r5视频属性的抓取
# BV号为1ra4y1j7r5的视频属性抓取结束
# 开始BV号为1hz4y1Z7SN视频属性的抓取
# BV号为1hz4y1Z7SN的视频属性抓取结束
# 开始BV号为1Ya4y1j7RE视频属性的抓取
# BV号为1Ya4y1j7RE的视频属性抓取结束
# 开始BV号为1Tf4y1X7b8视频属性的抓取
# BV号为1Tf4y1X7b8的视频属性抓取结束
# 开始BV号为1wT4y1A7H3视频属性的抓取
# BV号为1wT4y1A7H3的视频属性抓取结束
# 开始BV号为1yV41117dL视频属性的抓取
# BV号为1yV41117dL的视频属性抓取结束
# 开始BV号为1LZ4y1T7YD视频属性的抓取
# BV号为1LZ4y1T7YD的视频属性抓取结束
# 开始BV号为1pp4y1a7JB视频属性的抓取
# BV号为1pp4y1a7JB的视频属性抓取结束
# 开始BV号为1Z5411L7W4视频属性的抓取
# BV号为1Z5411L7W4的视频属性抓取结束
# 开始BV号为1Hy4y1y7nb视频属性的抓取
# BV号为1Hy4y1y7nb的视频属性抓取结束
# 开始BV号为1754y1m7B5视频属性的抓取
# BV号为1754y1m7B5的视频属性抓取结束
# 开始BV号为1ep4y1a72R视频属性的抓取
# BV号为1ep4y1a72R的视频属性抓取结束
# 开始BV号为1QK411K7Fm视频属性的抓取
# BV号为1QK411K7Fm的视频属性抓取结束
# 开始BV号为1mK411N7ba视频属性的抓取
# BV号为1mK411N7ba的视频属性抓取结束
# 开始BV号为1py4y1k77x视频属性的抓取
# BV号为1py4y1k77x的视频属性抓取结束
# 开始BV号为1s54y1m7QJ视频属性的抓取
# BV号为1s54y1m7QJ的视频属性抓取结束
# 开始BV号为1cT4y1A7HP视频属性的抓取
# BV号为1cT4y1A7HP的视频属性抓取结束
# 开始BV号为14A411E7LJ视频属性的抓取
# BV号为14A411E7LJ的视频属性抓取结束
# 开始BV号为1jV411m7m5视频属性的抓取
# BV号为1jV411m7m5的视频属性抓取结束
# 开始BV号为19h411R73T视频属性的抓取
# BV号为19h411R73T的视频属性抓取结束
# 开始BV号为1wK411N7ub视频属性的抓取
# BV号为1wK411N7ub的视频属性抓取结束
# 开始BV号为1KV411S7N5视频属性的抓取
# BV号为1KV411S7N5的视频属性抓取结束
# 开始BV号为1YT4y1w78x视频属性的抓取
# BV号为1YT4y1w78x的视频属性抓取结束
# 开始BV号为1Pt4y1S7Wb视频属性的抓取
# BV号为1Pt4y1S7Wb的视频属性抓取结束
# 开始BV号为1Av411y7Y8视频属性的抓取
# BV号为1Av411y7Y8的视频属性抓取结束
# 开始BV号为1it4y1i7ME视频属性的抓取
# BV号为1it4y1i7ME的视频属性抓取结束
# 开始BV号为1mZ4y1N7wz视频属性的抓取
# BV号为1mZ4y1N7wz的视频属性抓取结束
# 开始BV号为1wK4y1h7ev视频属性的抓取
# BV号为1wK4y1h7ev的视频属性抓取结束
# 开始BV号为18D4y1o7cc视频属性的抓取
# BV号为18D4y1o7cc的视频属性抓取结束
# 开始BV号为1ZA411E7Dy视频属性的抓取
# BV号为1ZA411E7Dy的视频属性抓取结束
# 开始BV号为1Uk4y127K2视频属性的抓取
# BV号为1Uk4y127K2的视频属性抓取结束
# 开始BV号为1rT4y1w7FP视频属性的抓取
# BV号为1rT4y1w7FP的视频属性抓取结束
# 开始BV号为1Sp4y1e78Q视频属性的抓取
# BV号为1Sp4y1e78Q的视频属性抓取结束
# 开始BV号为1vA411n7yg视频属性的抓取
# BV号为1vA411n7yg的视频属性抓取结束
# 开始BV号为1Ci4y1M77j视频属性的抓取
# BV号为1Ci4y1M77j的视频属性抓取结束
# 开始BV号为1bK411K7Nt视频属性的抓取
# BV号为1bK411K7Nt的视频属性抓取结束
# 开始BV号为1vk4y1y7vD视频属性的抓取
# BV号为1vk4y1y7vD的视频属性抓取结束
# 开始BV号为1iK4y1a7YG视频属性的抓取
# BV号为1iK4y1a7YG的视频属性抓取结束
# 开始BV号为1cz4y1Z7Pa视频属性的抓取
# BV号为1cz4y1Z7Pa的视频属性抓取结束
# 开始BV号为1if4y1D74H视频属性的抓取
# BV号为1if4y1D74H的视频属性抓取结束
# 开始BV号为1Wf4y1D7pQ视频属性的抓取
# BV号为1Wf4y1D7pQ的视频属性抓取结束
# 开始BV号为1q54y1C7mN视频属性的抓取
# BV号为1q54y1C7mN的视频属性抓取结束
# 开始BV号为1qD4y1m7BJ视频属性的抓取
# BV号为1qD4y1m7BJ的视频属性抓取结束
# 开始BV号为1Ff4y1Q7sD视频属性的抓取
# BV号为1Ff4y1Q7sD的视频属性抓取结束
# 开始BV号为1754y1y7Ma视频属性的抓取
# BV号为1754y1y7Ma的视频属性抓取结束
# 开始BV号为1Bh411R7An视频属性的抓取
# BV号为1Bh411R7An的视频属性抓取结束
# 开始BV号为1Pa4y1E7CU视频属性的抓取
# BV号为1Pa4y1E7CU的视频属性抓取结束
# 开始BV号为1p5411b7Hc视频属性的抓取
# BV号为1p5411b7Hc的视频属性抓取结束
# 开始BV号为1Ht4y1q7Q5视频属性的抓取
# BV号为1Ht4y1q7Q5的视频属性抓取结束
# 开始BV号为1i54y1y73H视频属性的抓取
# BV号为1i54y1y73H的视频属性抓取结束
# 开始BV号为1HZ4y1N7MF视频属性的抓取
# BV号为1HZ4y1N7MF的视频属性抓取结束
# 开始BV号为1rp4y1e7DY视频属性的抓取
# BV号为1rp4y1e7DY的视频属性抓取结束
# 开始BV号为1nK411K7rX视频属性的抓取
# BV号为1nK411K7rX的视频属性抓取结束
# 开始BV号为1LV411m7CM视频属性的抓取
# BV号为1LV411m7CM的视频属性抓取结束
# 开始BV号为18V411m7Fs视频属性的抓取
# BV号为18V411m7Fs的视频属性抓取结束
# 开始BV号为1JA411n7dY视频属性的抓取
# BV号为1JA411n7dY的视频属性抓取结束
# 开始BV号为1254y1k7dj视频属性的抓取
# BV号为1254y1k7dj的视频属性抓取结束
# 开始BV号为1ay4y1k7sD视频属性的抓取
# BV号为1ay4y1k7sD的视频属性抓取结束
# 开始BV号为1zi4y177gb视频属性的抓取
# BV号为1zi4y177gb的视频属性抓取结束
# 开始BV号为1oz4y1f7it视频属性的抓取
# BV号为1oz4y1f7it的视频属性抓取结束
# 开始BV号为1rK4y187DV视频属性的抓取
# BV号为1rK4y187DV的视频属性抓取结束
# 开始BV号为1py4y1y7LV视频属性的抓取
# BV号为1py4y1y7LV的视频属性抓取结束
# 开始BV号为1na4y1j7qY视频属性的抓取
# BV号为1na4y1j7qY的视频属性抓取结束
# 开始BV号为1rV411m7uc视频属性的抓取
# BV号为1rV411m7uc的视频属性抓取结束
# 开始BV号为1yK4y1a7K2视频属性的抓取
# BV号为1yK4y1a7K2的视频属性抓取结束
# 开始BV号为1RA411n7Dr视频属性的抓取
# BV号为1RA411n7Dr的视频属性抓取结束
# 开始BV号为1Rt4y1i7DD视频属性的抓取
# BV号为1Rt4y1i7DD的视频属性抓取结束
# 开始BV号为18V411m7Xu视频属性的抓取
# BV号为18V411m7Xu的视频属性抓取结束
# 开始BV号为1KK4y1Y738视频属性的抓取
# BV号为1KK4y1Y738的视频属性抓取结束
# 开始BV号为1uK411K76y视频属性的抓取
# BV号为1uK411K76y的视频属性抓取结束
# 开始BV号为1JZ4y157R1视频属性的抓取
# BV号为1JZ4y157R1的视频属性抓取结束
# 开始BV号为1Ay4y187tP视频属性的抓取
# BV号为1Ay4y187tP的视频属性抓取结束
# 开始BV号为1NA411j7Mq视频属性的抓取
# BV号为1NA411j7Mq的视频属性抓取结束
# 开始BV号为1Tr4y1w7m9视频属性的抓取
# BV号为1Tr4y1w7m9的视频属性抓取结束
# 开始BV号为13r4y1w7Lm视频属性的抓取
# BV号为13r4y1w7Lm的视频属性抓取结束
# 开始BV号为1Ua4y1L7Hh视频属性的抓取
# BV号为1Ua4y1L7Hh的视频属性抓取结束
# 开始BV号为1tZ4y1L7SK视频属性的抓取
# BV号为1tZ4y1L7SK的视频属性抓取结束
# 开始BV号为1rv411k7jm视频属性的抓取
# BV号为1rv411k7jm的视频属性抓取结束
# 开始BV号为1NT4y1w776视频属性的抓取
# BV号为1NT4y1w776的视频属性抓取结束
# 开始BV号为1AZ4y1L72q视频属性的抓取
# BV号为1AZ4y1L72q的视频属性抓取结束
# 开始BV号为1or4y1c7oH视频属性的抓取
# BV号为1or4y1c7oH的视频属性抓取结束
# 开始BV号为1oA411L7Cj视频属性的抓取
# BV号为1oA411L7Cj的视频属性抓取结束
# 开始BV号为1qk4y1C72n视频属性的抓取
# BV号为1qk4y1C72n的视频属性抓取结束
# 开始BV号为1kv41167DM视频属性的抓取
# BV号为1kv41167DM的视频属性抓取结束
# 开始BV号为1rT4y1c7Aj视频属性的抓取
# BV号为1rT4y1c7Aj的视频属性抓取结束
# 开始BV号为1n5411L78L视频属性的抓取
# BV号为1n5411L78L的视频属性抓取结束
# 开始BV号为1yK4y1h7XH视频属性的抓取
# BV号为1yK4y1h7XH的视频属性抓取结束
# 开始BV号为1Vy4y1r7Na视频属性的抓取
# BV号为1Vy4y1r7Na的视频属性抓取结束
# 开始BV号为1Bf4y1i7Mt视频属性的抓取
# BV号为1Bf4y1i7Mt的视频属性抓取结束
# 开始BV号为1h54y1R7kr视频属性的抓取
# BV号为1h54y1R7kr的视频属性抓取结束
# 开始BV号为1az4y1o7s7视频属性的抓取
# BV号为1az4y1o7s7的视频属性抓取结束
# 开始BV号为1MD4y1d7TH视频属性的抓取
# BV号为1MD4y1d7TH的视频属性抓取结束
# 开始BV号为1Zf4y1B7a4视频属性的抓取
# BV号为1Zf4y1B7a4的视频属性抓取结束
# 开始BV号为1kv41167ZU视频属性的抓取
# BV号为1kv41167ZU的视频属性抓取结束
# 开始BV号为1Er4y1w7bh视频属性的抓取
# BV号为1Er4y1w7bh的视频属性抓取结束
# 开始BV号为1ap4y1k7gA视频属性的抓取
# 开始BV号为1ap4y1k7gA视频属性的抓取
# BV号为1ap4y1k7gA的视频属性抓取结束
# 开始BV号为1jr4y1w7EW视频属性的抓取
# BV号为1jr4y1w7EW的视频属性抓取结束
# 开始BV号为1V54y1r7ov视频属性的抓取
# BV号为1V54y1r7ov的视频属性抓取结束
# 开始BV号为1954y167gB视频属性的抓取
# BV号为1954y167gB的视频属性抓取结束
# 开始BV号为1nr4y1w7ks视频属性的抓取
# BV号为1nr4y1w7ks的视频属性抓取结束
# 开始BV号为1Wy4y1r775视频属性的抓取
# BV号为1Wy4y1r775的视频属性抓取结束
# 开始BV号为1MK411P7PJ视频属性的抓取
# BV号为1MK411P7PJ的视频属性抓取结束
# 开始BV号为1wr4y1A77c视频属性的抓取
# BV号为1wr4y1A77c的视频属性抓取结束
# 开始BV号为1LT4y1w73v视频属性的抓取
# BV号为1LT4y1w73v的视频属性抓取结束
# 开始BV号为1FK4y1E7ef视频属性的抓取
# BV号为1FK4y1E7ef的视频属性抓取结束
# 开始BV号为1vp4y1Y72d视频属性的抓取
# BV号为1vp4y1Y72d的视频属性抓取结束
# 开始BV号为11t4y1v7y7视频属性的抓取
# BV号为11t4y1v7y7的视频属性抓取结束
# 开始BV号为1hy4y1r72J视频属性的抓取
# BV号为1hy4y1r72J的视频属性抓取结束
# 开始BV号为15v411C7Pw视频属性的抓取
# BV号为15v411C7Pw的视频属性抓取结束
# 开始BV号为1Uy4y1k7sg视频属性的抓取
# BV号为1Uy4y1k7sg的视频属性抓取结束
# 开始BV号为1z541157uh视频属性的抓取
# BV号为1z541157uh的视频属性抓取结束
# 开始BV号为1Nv411C7fm视频属性的抓取
# BV号为1Nv411C7fm的视频属性抓取结束
# 开始BV号为1Ya4y1L7tS视频属性的抓取
# BV号为1Ya4y1L7tS的视频属性抓取结束
# 开始BV号为1Dz4y1o7BL视频属性的抓取
# BV号为1Dz4y1o7BL的视频属性抓取结束
# 开始BV号为1sa411A7CY视频属性的抓取
# 开始BV号为1sa411A7CY视频属性的抓取
# BV号为1sa411A7CY的视频属性抓取结束
# 开始BV号为1hr4y1w7nv视频属性的抓取
# BV号为1hr4y1w7nv的视频属性抓取结束
# 开始BV号为1sK411N7rU视频属性的抓取
# BV号为1sK411N7rU的视频属性抓取结束
# 开始BV号为1Ca411A7YS视频属性的抓取
# BV号为1Ca411A7YS的视频属性抓取结束
# 开始BV号为1Qy4y1k71E视频属性的抓取
# BV号为1Qy4y1k71E的视频属性抓取结束
# 开始BV号为1W5411L7wo视频属性的抓取
# BV号为1W5411L7wo的视频属性抓取结束
# 开始BV号为1Sf4y1B77B视频属性的抓取
# BV号为1Sf4y1B77B的视频属性抓取结束
# 开始BV号为17t4y1i76N视频属性的抓取
# BV号为17t4y1i76N的视频属性抓取结束
# 开始BV号为1UK4y1h7ng视频属性的抓取
# BV号为1UK4y1h7ng的视频属性抓取结束
# 开始BV号为1p54y1C7kg视频属性的抓取
# BV号为1p54y1C7kg的视频属性抓取结束
# 开始BV号为19v411C7yo视频属性的抓取
# BV号为19v411C7yo的视频属性抓取结束
# 开始BV号为1ET4y1w7tS视频属性的抓取
# BV号为1ET4y1w7tS的视频属性抓取结束
# 开始BV号为1RZ4y1G7d6视频属性的抓取
# 开始BV号为1RZ4y1G7d6视频属性的抓取
# BV号为1RZ4y1G7d6的视频属性抓取结束
# 开始BV号为1Wy4y1r7nD视频属性的抓取
# BV号为1Wy4y1r7nD的视频属性抓取结束
# 开始BV号为1sV411y74g视频属性的抓取
# BV号为1sV411y74g的视频属性抓取结束
# 开始BV号为1yy4y1r7SK视频属性的抓取
# BV号为1yy4y1r7SK的视频属性抓取结束
# 开始BV号为1hV411y71A视频属性的抓取
# BV号为1hV411y71A的视频属性抓取结束
# 开始BV号为1jr4y1w7tt视频属性的抓取
# BV号为1jr4y1w7tt的视频属性抓取结束
# 开始BV号为1Gp4y1k7dv视频属性的抓取
# BV号为1Gp4y1k7dv的视频属性抓取结束
# 开始BV号为1fK411w7F7视频属性的抓取
# BV号为1fK411w7F7的视频属性抓取结束
# 开始BV号为1Af4y1Q7it视频属性的抓取
# BV号为1Af4y1Q7it的视频属性抓取结束
# 开始BV号为1or4y1c72M视频属性的抓取
# BV号为1or4y1c72M的视频属性抓取结束
# 开始BV号为1UK4y1f7in视频属性的抓取
# BV号为1UK4y1f7in的视频属性抓取结束
# 开始BV号为1py4y1B7fk视频属性的抓取
# BV号为1py4y1B7fk的视频属性抓取结束
# 开始BV号为16D4y1d7WB视频属性的抓取
# BV号为16D4y1d7WB的视频属性抓取结束
# 开始BV号为19y4y1k7BX视频属性的抓取
# BV号为19y4y1k7BX的视频属性抓取结束
# 开始BV号为1dt4y1Y7a8视频属性的抓取
# BV号为1dt4y1Y7a8的视频属性抓取结束
# 开始BV号为1Ar4y1w7BZ视频属性的抓取
# BV号为1Ar4y1w7BZ的视频属性抓取结束
# 开始BV号为1JZ4y1V7Pn视频属性的抓取
# BV号为1JZ4y1V7Pn的视频属性抓取结束
# 开始BV号为1MT4y1w7eE视频属性的抓取
# BV号为1MT4y1w7eE的视频属性抓取结束
# 开始BV号为1Sy4y1r73z视频属性的抓取
# BV号为1Sy4y1r73z的视频属性抓取结束
# 开始BV号为1E54y1C72P视频属性的抓取
# BV号为1E54y1C72P的视频属性抓取结束
# 开始BV号为16y4y1r75E视频属性的抓取
# BV号为16y4y1r75E的视频属性抓取结束
# 开始BV号为1ua4y1s7qD视频属性的抓取
# BV号为1ua4y1s7qD的视频属性抓取结束
# 开始BV号为1wK411N7ro视频属性的抓取
# BV号为1wK411N7ro的视频属性抓取结束
# 开始BV号为1cV41127wX视频属性的抓取
# BV号为1cV41127wX的视频属性抓取结束
# 开始BV号为1Ey4y1B7xc视频属性的抓取
# BV号为1Ey4y1B7xc的视频属性抓取结束
# 开始BV号为15D4y197Pi视频属性的抓取
# BV号为15D4y197Pi的视频属性抓取结束
# 开始BV号为1Sf4y1B7vR视频属性的抓取
# BV号为1Sf4y1B7vR的视频属性抓取结束
# 开始BV号为1ty4y1B734视频属性的抓取
# BV号为1ty4y1B734的视频属性抓取结束
# 开始BV号为1G54y1r7JS视频属性的抓取
# BV号为1G54y1r7JS的视频属性抓取结束
# 开始BV号为1Ba411A7Mc视频属性的抓取
# BV号为1Ba411A7Mc的视频属性抓取结束
# 开始BV号为1Qa411w77u视频属性的抓取
# BV号为1Qa411w77u的视频属性抓取结束
# 开始BV号为1nr4y1w7pL视频属性的抓取
# BV号为1nr4y1w7pL的视频属性抓取结束
# 开始BV号为1ka4y1L7mL视频属性的抓取
# BV号为1ka4y1L7mL的视频属性抓取结束
# 开始BV号为125411j7S7视频属性的抓取
# BV号为125411j7S7的视频属性抓取结束
# 开始BV号为1Ea4y1L7pu视频属性的抓取
# BV号为1Ea4y1L7pu的视频属性抓取结束
# 开始BV号为1ck4y1C7ax视频属性的抓取
# BV号为1ck4y1C7ax的视频属性抓取结束
# 开始BV号为1Z541157J8视频属性的抓取
# BV号为1Z541157J8的视频属性抓取结束
# 开始BV号为1JD4y1R7L3视频属性的抓取
# BV号为1JD4y1R7L3的视频属性抓取结束
# 开始BV号为1kp4y1k7YR视频属性的抓取
# BV号为1kp4y1k7YR的视频属性抓取结束
# 开始BV号为1SK411A7DS视频属性的抓取
# BV号为1SK411A7DS的视频属性抓取结束
# 开始BV号为16y4y1r7an视频属性的抓取
# BV号为16y4y1r7an的视频属性抓取结束
# 开始BV号为1CK411A7nD视频属性的抓取
# BV号为1CK411A7nD的视频属性抓取结束
# 开始BV号为1CV411y7LE视频属性的抓取
# BV号为1CV411y7LE的视频属性抓取结束
# 开始BV号为19i4y1E7tR视频属性的抓取
# BV号为19i4y1E7tR的视频属性抓取结束
# 2020-12-17 10:26:06.930574

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-14-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_guichu_jvchang.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月     98   98    98   98   98   98   98   98    98      98   98    98   98
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月    98   98   98   98   98   98    98
# 2月   100  100  100  100  100  100   100
# 3月   100  100  100  100  100  100   100
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月   100  100  100  100  100  100   100
# 7月   100  100  100  100  100  100   100
# 8月   100  100  100  100  100  100   100
# 9月   100  100  100  100  100  100   100

# %%
channel_guichu_jvchang.to_json('channel_guichu_jvchang.json')

# %%
pd.set_option('display.max_rows', None)

# %%
channel_youxi_danji[channel_youxi_danji['时间']=='4月']
# Out:
#             时间            作者名  作者类型      粉丝数   投稿数  \
# 1h54y1d7Qq  4月            鹤吱菌  个人认证   191.3万    81
# 1L64y1M7Dp  4月            老番茄  个人认证  1360.1万   348
# 18K41157Tu  4月            老番茄  个人认证  1360.1万   348
# 1PT4y1G7ME  4月            老番茄  个人认证  1360.1万   348
# 1S54y197uX  4月           徐大虾咯  个人认证   570.1万   224
# 1ti4y1t7YM  4月            老番茄  个人认证  1360.1万   348
# 1Ai4y1b7ET  4月            敖厂长  个人认证   735.1万   348
# 1Up4y1C7PB  4月        丢鹏D1uuu     无     8.4万    20
# 1wi4y187bu  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 13t4y1U7kQ  4月           徐大虾咯  个人认证   570.1万   224
# 1fe411x7FA  4月         芦苇草的梦想  个人认证    29.3万   726
# 1LA411b7Dt  4月      LexBurner  个人认证   929.6万   383
# 1Ji4y1t7T9  4月            沧桑丸  个人认证    86.6万    57
# 1Lz411z72u  4月           徐大虾咯  个人认证   570.1万   224
# 13T4y1G7WT  4月          逗比的雀巢  个人认证   242.3万    82
# 1T54y197DH  4月           徐大虾咯  个人认证   570.1万   224
# 1Va4y147fH  4月            鹤吱菌  个人认证   191.3万    81
# 1tt4y127yy  4月           小潮院长  个人认证   481.6万   266
# 16T4y1g7RY  4月         吉儿一范伦婷  个人认证    67.6万    79
# 1754y197Da  4月            敖厂长  个人认证   735.1万   348
# 1hK41157M3  4月           花少北丶  个人认证   491.9万   173
# 1Rk4y197kw  4月       3DM游戏网官方  机构认证    13.5万  2822
# 1ST4y1G7E1  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1H54y1d76B  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1Sz411B7P4  4月          游汐_YX  个人认证    12.9万    98
# 1CT4y1g7Ya  4月    育碧中国Ubisoft  机构认证    64.5万  1211
# 12T4y1G7AZ  4月          与山0v0  个人认证   208.5万   557
# 1b5411x79t  4月        东尼ookii  个人认证   331.7万   166
# 1hA411h7Ky  4月          与山0v0  个人认证   208.5万   557
# 1Gt4y127AJ  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 1KJ411e7nN                              如何提高审美？审美有无高低？审美是谁建立？  数码  摄影摄像  普通视频
# ...                                                       ...  ..   ...   ...
# 1cr4y1w7ig              困难重重，国家天文签约摄影师遭遇拍摄滑铁卢？！【华为Mate40 Pro】  数码  摄影摄像  活动作品
# 1Y5411L7TW                     富士X-S10相机测试——2020 apsc画幅性价比最强机  数码  摄影摄像  活动作品
# 1c541177hR      索尼（Sony）12-24mm F2.8 GM深度评测，只要买得起，它就是一颗完美的镜头！  数码  摄影摄像  普通视频
# 1DA41177UY                            大疆旗舰稳定器 - DJI RS 2 正式登场  数码  摄影摄像  普通视频
# 1rA411776p                 让我非常失望的佳能M50 Mark II（来自一代老用户的真实心声）  数码  摄影摄像  普通视频
#
#             ...                                                 标签   视频长度  \
# 1gJ411n7hp  ...                         [摄影, 数码, 摄影摄像, 数码, 教程, 器材]  01:44
# 1tJ41187w6  ...  [相机, 数码, 摄影摄像, 数码, 何同学, 啊吗粽, 宝剑嫂, 自媒体, 大祥哥, 体验...  30:03
# 1i7411i7yA  ...        [摄影, 短片, 数码, 摄影摄像, 数码, 创意, YOUTUBE, 镜头, 老蛙]  04:51
# 1gJ411G7Cs  ...           [摄影, 数码, 摄影摄像, 数码, VLOG, 后期, 教程, ps, 器材]  06:01
# 1KJ411e7nN  ...  [校园vlog, 相机, 脱口秀, 摄影, 公开课, vlog, 科普, 数码, 摄影摄像,...  27:08
# ...         ...                                                ...    ...
# 1cr4y1w7ig  ...  [vlog, 数码, 摄影摄像, 数码, 放心购机攻略, 敦煌, 星空, 手机摄影, 华为,...  11:43
# 1Y5411L7TW  ...  [相机, 摄影, 数码, 摄影摄像, 数码, 数码玩家训练营, 拍照, 测评, xs10, ...  10:20
# 1c541177hR  ...  [摄影, 数码, 摄影摄像, 数码, 评测, 超广角大光圈, 摄像, 镜头, 数码评测, 超...  21:23
# 1DA41177UY  ...   [相机, 摄影, 数码, 摄影摄像, 数码, 科技, 测评, 器材, 大疆, DJI, 稳定器]  02:26
# 1rA411776p  ...  [vlog, 数码, 摄影摄像, 数码, 佳能, 测评, 体验, m50 mark ii, ...  06:30
#
#                播放量    点赞数   投币数   收藏数   转发数   评论数   弹幕数 有无分集
# 1gJ411n7hp  222.4万   9.7万  2.0万  1.4万  4980  3182  1571    否
# 1tJ41187w6  134.0万  10.7万  8.4万  5.8万  8907  3935  3.0万    否
# 1i7411i7yA   57.8万   4.4万  1.0万  1.6万  2043   641   983    否
# 1gJ411G7Cs   42.3万   3.3万  3.4万  8.6万  2605  1405   612    否
# 1KJ411e7nN   39.6万   4.8万  5.4万  3.4万  6217  1156  1.0万    否
# ...            ...    ...   ...   ...   ...   ...   ...  ...
# 1cr4y1w7ig    4.3万   3051  1391   692   255   337   349    否
# 1Y5411L7TW    4.3万    773   219   221   111   273   104    否
# 1c541177hR    4.1万   1469   443   297   123   250   561    否
# 1DA41177UY    4.1万   1565   197   334   640   171   110    否
# 1rA411776p    4.1万   1262   267   147   101   385   314    否
#
# [999 rows x 21 columns]
