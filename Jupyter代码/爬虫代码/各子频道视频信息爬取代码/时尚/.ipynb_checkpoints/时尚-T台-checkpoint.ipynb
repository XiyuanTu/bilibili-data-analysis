# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_shishang_ttai=pd.DataFrame(columns=columns)
channel_shishang_ttai
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[11]/div/a/span').click()  #选择“时尚”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[11]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '时尚'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[5]/a').click()  #选择“T台”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[5]/a').text
sub_channel
# Out:
# 'T台'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(10,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_shishang_ttai.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-23 09:38:21.629448
# <ipython-input-26-e04754d5de8a>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-26-e04754d5de8a>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-26-e04754d5de8a>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1g54y1C7rD视频属性的抓取
# E:\anaconda\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# BV号为1g54y1C7rD的视频属性抓取结束
# <ipython-input-26-e04754d5de8a>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1Sp4y1r7YH视频属性的抓取
# BV号为1Sp4y1r7YH的视频属性抓取结束
# 开始BV号为1mi4y1j7W9视频属性的抓取
# BV号为1mi4y1j7W9的视频属性抓取结束
# 开始BV号为1pV41127wk视频属性的抓取
# BV号为1pV41127wk的视频属性抓取结束
# 开始BV号为1cy4y1r7e3视频属性的抓取
# BV号为1cy4y1r7e3的视频属性抓取结束
# 开始BV号为1Sr4y1c7ss视频属性的抓取
# BV号为1Sr4y1c7ss的视频属性抓取结束
# 开始BV号为1eK411A79Q视频属性的抓取
# BV号为1eK411A79Q的视频属性抓取结束
# 开始BV号为1ET4y1w7xa视频属性的抓取
# BV号为1ET4y1w7xa的视频属性抓取结束
# 开始BV号为1nt4y1v7Qk视频属性的抓取
# BV号为1nt4y1v7Qk的视频属性抓取结束
# 开始BV号为1BK411A7L4视频属性的抓取
# BV号为1BK411A7L4的视频属性抓取结束
# 开始BV号为1Zz4y1Z7sh视频属性的抓取
# BV号为1Zz4y1Z7sh的视频属性抓取结束
# 开始BV号为1na411A7c2视频属性的抓取
# BV号为1na411A7c2的视频属性抓取结束
# 开始BV号为1zp4y1Y7Fi视频属性的抓取
# BV号为1zp4y1Y7Fi的视频属性抓取结束
# 开始BV号为1xT4y1F7rP视频属性的抓取
# BV号为1xT4y1F7rP的视频属性抓取结束
# 开始BV号为16V411y7tD视频属性的抓取
# BV号为16V411y7tD的视频属性抓取结束
# 开始BV号为1LD4y1d7qj视频属性的抓取
# BV号为1LD4y1d7qj的视频属性抓取结束
# 开始BV号为1WZ4y157pp视频属性的抓取
# BV号为1WZ4y157pp的视频属性抓取结束
# 开始BV号为1br4y1w7HK视频属性的抓取
# BV号为1br4y1w7HK的视频属性抓取结束
# 开始BV号为1Fp4y1Y7fJ视频属性的抓取
# BV号为1Fp4y1Y7fJ的视频属性抓取结束
# 开始BV号为1hz4y1o7dm视频属性的抓取
# BV号为1hz4y1o7dm的视频属性抓取结束
# 开始BV号为1iT4y1F7B1视频属性的抓取
# BV号为1iT4y1F7B1的视频属性抓取结束
# 开始BV号为1hr4y1w7Yn视频属性的抓取
# BV号为1hr4y1w7Yn的视频属性抓取结束
# 开始BV号为1vD4y1d79W视频属性的抓取
# BV号为1vD4y1d79W的视频属性抓取结束
# 开始BV号为1rT4y1c7ZN视频属性的抓取
# BV号为1rT4y1c7ZN的视频属性抓取结束
# 开始BV号为13V41127uA视频属性的抓取
# BV号为13V41127uA的视频属性抓取结束
# 开始BV号为12y4y1k7pU视频属性的抓取
# BV号为12y4y1k7pU的视频属性抓取结束
# 开始BV号为1ki4y1E7a7视频属性的抓取
# BV号为1ki4y1E7a7的视频属性抓取结束
# 开始BV号为1BD4y1d7FD视频属性的抓取
# BV号为1BD4y1d7FD的视频属性抓取结束
# 开始BV号为1xf4y1B72q视频属性的抓取
# BV号为1xf4y1B72q的视频属性抓取结束
# 开始BV号为19D4y1R7zu视频属性的抓取
# BV号为19D4y1R7zu的视频属性抓取结束
# 开始BV号为1ra411w7Cm视频属性的抓取
# BV号为1ra411w7Cm的视频属性抓取结束
# 开始BV号为1b54y1R7tY视频属性的抓取
# BV号为1b54y1R7tY的视频属性抓取结束
# 开始BV号为1qz4y1d71g视频属性的抓取
# BV号为1qz4y1d71g的视频属性抓取结束
# 开始BV号为1cV411y7dy视频属性的抓取
# BV号为1cV411y7dy的视频属性抓取结束
# 开始BV号为1oi4y1E7s1视频属性的抓取
# BV号为1oi4y1E7s1的视频属性抓取结束
# 开始BV号为1Kz4y1o7AD视频属性的抓取
# BV号为1Kz4y1o7AD的视频属性抓取结束
# 开始BV号为1F54y1C7BF视频属性的抓取
# BV号为1F54y1C7BF的视频属性抓取结束
# 开始BV号为1PZ4y1L7JM视频属性的抓取
# BV号为1PZ4y1L7JM的视频属性抓取结束
# 开始BV号为1XD4y1978w视频属性的抓取
# BV号为1XD4y1978w的视频属性抓取结束
# 开始BV号为1iT4y1F75v视频属性的抓取
# BV号为1iT4y1F75v的视频属性抓取结束
# 开始BV号为1gT4y1w7jf视频属性的抓取
# BV号为1gT4y1w7jf的视频属性抓取结束
# 开始BV号为1D54y1k7CK视频属性的抓取
# BV号为1D54y1k7CK的视频属性抓取结束
# 开始BV号为1AA411j7Mz视频属性的抓取
# BV号为1AA411j7Mz的视频属性抓取结束
# 开始BV号为1sV411y7mZ视频属性的抓取
# BV号为1sV411y7mZ的视频属性抓取结束
# 开始BV号为14r4y1w7Bh视频属性的抓取
# BV号为14r4y1w7Bh的视频属性抓取结束
# 开始BV号为1Sv411k7Lv视频属性的抓取
# BV号为1Sv411k7Lv的视频属性抓取结束
# 开始BV号为1ny4y1r7Ge视频属性的抓取
# BV号为1ny4y1r7Ge的视频属性抓取结束
# 开始BV号为1qa4y1L7FJ视频属性的抓取
# BV号为1qa4y1L7FJ的视频属性抓取结束
# 开始BV号为1Yz4y1o7Te视频属性的抓取
# BV号为1Yz4y1o7Te的视频属性抓取结束
# 开始BV号为1wi4y177WF视频属性的抓取
# BV号为1wi4y177WF的视频属性抓取结束
# 开始BV号为1uA411E7qD视频属性的抓取
# BV号为1uA411E7qD的视频属性抓取结束
# 开始BV号为1sD4y1R7ot视频属性的抓取
# BV号为1sD4y1R7ot的视频属性抓取结束
# 开始BV号为1KD4y197KJ视频属性的抓取
# BV号为1KD4y197KJ的视频属性抓取结束
# 开始BV号为1y54y1y7XA视频属性的抓取
# BV号为1y54y1y7XA的视频属性抓取结束
# 开始BV号为1sV41127rE视频属性的抓取
# BV号为1sV41127rE的视频属性抓取结束
# 开始BV号为1tK411N7ki视频属性的抓取
# BV号为1tK411N7ki的视频属性抓取结束
# 开始BV号为1jA411E76t视频属性的抓取
# BV号为1jA411E76t的视频属性抓取结束
# 开始BV号为1sV41127Xj视频属性的抓取
# BV号为1sV41127Xj的视频属性抓取结束
# 开始BV号为1nt4y1v71P视频属性的抓取
# BV号为1nt4y1v71P的视频属性抓取结束
# 开始BV号为1Na4y1L753视频属性的抓取
# BV号为1Na4y1L753的视频属性抓取结束
# 开始BV号为1df4y1q7KA视频属性的抓取
# BV号为1df4y1q7KA的视频属性抓取结束
# 开始BV号为1Yp4y1k7oZ视频属性的抓取
# BV号为1Yp4y1k7oZ的视频属性抓取结束
# 开始BV号为1iv411y7hP视频属性的抓取
# BV号为1iv411y7hP的视频属性抓取结束
# 开始BV号为1Fi4y177ie视频属性的抓取
# BV号为1Fi4y177ie的视频属性抓取结束
# 开始BV号为1dh411X7RG视频属性的抓取
# BV号为1dh411X7RG的视频属性抓取结束
# 开始BV号为16T4y1c72J视频属性的抓取
# BV号为16T4y1c72J的视频属性抓取结束
# 开始BV号为1Ct4y1q7fB视频属性的抓取
# BV号为1Ct4y1q7fB的视频属性抓取结束
# 开始BV号为1C54y117Mq视频属性的抓取
# BV号为1C54y117Mq的视频属性抓取结束
# 开始BV号为1aK411A7n4视频属性的抓取
# BV号为1aK411A7n4的视频属性抓取结束
# 开始BV号为1By4y1r7Zr视频属性的抓取
# BV号为1By4y1r7Zr的视频属性抓取结束
# 开始BV号为16t4y1v75o视频属性的抓取
# BV号为16t4y1v75o的视频属性抓取结束
# 开始BV号为1wK411N7ZF视频属性的抓取
# BV号为1wK411N7ZF的视频属性抓取结束
# 开始BV号为1gZ4y1L7h4视频属性的抓取
# BV号为1gZ4y1L7h4的视频属性抓取结束
# 开始BV号为1A54y127Uz视频属性的抓取
# BV号为1A54y127Uz的视频属性抓取结束
# 开始BV号为1Ra411A7oc视频属性的抓取
# BV号为1Ra411A7oc的视频属性抓取结束
# 开始BV号为1HT4y1w7wZ视频属性的抓取
# BV号为1HT4y1w7wZ的视频属性抓取结束
# 开始BV号为1Nk4y1y7kS视频属性的抓取
# BV号为1Nk4y1y7kS的视频属性抓取结束
# 开始BV号为15Z4y1V776视频属性的抓取
# BV号为15Z4y1V776的视频属性抓取结束
# 开始BV号为1Fz4y1f75o视频属性的抓取
# BV号为1Fz4y1f75o的视频属性抓取结束
# 开始BV号为1Z54y117sH视频属性的抓取
# BV号为1Z54y117sH的视频属性抓取结束
# 开始BV号为1Qp4y1r7LY视频属性的抓取
# BV号为1Qp4y1r7LY的视频属性抓取结束
# 开始BV号为1Hp4y1Y7rW视频属性的抓取
# BV号为1Hp4y1Y7rW的视频属性抓取结束
# 开始BV号为1Kf4y1Q7vq视频属性的抓取
# BV号为1Kf4y1Q7vq的视频属性抓取结束
# 开始BV号为1Gf4y1B72E视频属性的抓取
# BV号为1Gf4y1B72E的视频属性抓取结束
# 开始BV号为1T54y1r7Zg视频属性的抓取
# BV号为1T54y1r7Zg的视频属性抓取结束
# 开始BV号为1ET4y1F76X视频属性的抓取
# BV号为1ET4y1F76X的视频属性抓取结束
# 开始BV号为1ea4y1L7zu视频属性的抓取
# BV号为1ea4y1L7zu的视频属性抓取结束
# 开始BV号为1dz4y1Z7Go视频属性的抓取
# BV号为1dz4y1Z7Go的视频属性抓取结束
# 开始BV号为1My4y187PS视频属性的抓取
# BV号为1My4y187PS的视频属性抓取结束
# 开始BV号为1xf4y1D7er视频属性的抓取
# BV号为1xf4y1D7er的视频属性抓取结束
# 开始BV号为1dK411P7DN视频属性的抓取
# BV号为1dK411P7DN的视频属性抓取结束
# 开始BV号为1bK411A7Hc视频属性的抓取
# BV号为1bK411A7Hc的视频属性抓取结束
# 开始BV号为1AA411E7bh视频属性的抓取
# BV号为1AA411E7bh的视频属性抓取结束
# 开始BV号为1654y1r7aj视频属性的抓取
# BV号为1654y1r7aj的视频属性抓取结束
# 开始BV号为1uk4y1C7Kh视频属性的抓取
# BV号为1uk4y1C7Kh的视频属性抓取结束
# 开始BV号为1nK411N7AF视频属性的抓取
# BV号为1nK411N7AF的视频属性抓取结束
# 开始BV号为18p4y1k7oS视频属性的抓取
# BV号为18p4y1k7oS的视频属性抓取结束
# 开始BV号为1Yz4y1o71C视频属性的抓取
# BV号为1Yz4y1o71C的视频属性抓取结束
# 开始BV号为1fA411L7rZ视频属性的抓取
# BV号为1fA411L7rZ的视频属性抓取结束
# 开始BV号为1xy4y1C7oZ视频属性的抓取
# BV号为1xy4y1C7oZ的视频属性抓取结束
# 2020-12-23 11:00:16.000170

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-19-dd0a1399d54d> in <module>
# ----> 1 driver.switch_to_window(driver.window_handles[-1])
#
# E:\anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in window_handles(self)
#     722         """
#     723         if self.w3c:
# --> 724             return self.execute(Command.W3C_GET_WINDOW_HANDLES)['value']
#     725         else:
#     726             return self.execute(Command.GET_WINDOW_HANDLES)['value']
#
# E:\anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# E:\anaconda\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=86.0.4240.75)

# %%
channel_shishang_ttai.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月     96   96    96   96   96   96   96   96    96      96   96    96   96
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月   100  100  100  100  100  100   100
# 2月   100  100  100  100  100  100   100
# 3月    99   99   99   99   99   99    99
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月   100  100  100  100  100  100   100
# 7月   100  100  100  100  100  100   100
# 8月   100  100  100  100  100  100   100
# 9月    96   96   96   96   96   96    96

# %%
channel_shishang_ttai.to_json('channel_shishang_ttai.json')

# %%
pd.set_option('display.max_rows', None)

# %%
channel_shishang_ttai=pd.read_json('channel_shishang_ttai.json')

# %%
channel_shishang_ttai
# Out:
#              时间                 发布日期               作者名  作者类型    粉丝数   投稿数  \
# 1tJ41187Rr   1月  2020-01-02 19:20:47           阿菠萝的菠萝壳  个人认证  13.3万    82
# 1MJ411J7mS   1月  2020-01-14 19:29:27         Only探索发现号     无   2.9万    71
# 16J41177CB   1月  2020-01-16 17:24:39           阿菠萝的菠萝壳  个人认证  13.3万    82
# 127411i7Ph   1月  2020-01-18 17:11:52           阿菠萝的菠萝壳  个人认证  13.3万    82
# 1E7411r7EE   1月  2020-01-28 18:30:16             少冰七分甜     无   6446    12
# ...         ...                  ...               ...   ...    ...   ...
# 1nK411N7AF  10月  2020-10-08 13:16:46          娜塔莉韦斯特林酱     无   4474    75
# 18p4y1k7oS  10月  2020-10-27 00:31:23          Meng-Mao  个人认证  62.3万   165
# 1Yz4y1o71C  10月  2020-10-28 21:38:37            戳戳的王子_     无   7559    56
# 1fA411L7rZ  10月  2020-10-26 12:51:03          四只牛魔王的小弟     无    154  1375
# 1xy4y1C7oZ  10月  2020-10-15 17:04:41  user_78618949481     无   1637  2985
#
#                                                           视频名  分区 子分区  视频类型  \
# 1tJ41187Rr  要什么楚楚可怜样，就是爱你的强势高级又漂亮！Gucci（Frida Giannini时期）秀场混剪  时尚  T台  普通视频
# 1MJ411J7mS                       【日本女优T台秀】【视觉盛宴，不要眨眼】这才是“处处吻”  时尚  T台  普通视频
# 16J41177CB     【衣架子成精】原来这副神仙身材的主人是她！白俄罗斯模特Darya Kostenich走秀混剪  时尚  T台  普通视频
# 127411i7Ph       什么才是丧心病狂的精致：郭培 Guo Pei 高级定制秀场欣赏（2016 — 2019）  时尚  T台  普通视频
# 1E7411r7EE          【大摆裙】旧贵族时代的挽歌-超大摆公主裙合集 feat. Lana Del Rey  时尚  T台  普通视频
# ...                                                       ...  ..  ..   ...
# 1nK411N7AF                【美呆】1950年代的Dior放到现在依旧能打，复古优雅，经典永不过时  时尚  T台  普通视频
# 18p4y1k7oS                    和我一起看秀｜小时候印象里的Etam不一样啦｜Meng-Mao  时尚  T台  普通视频
# 1Yz4y1o71C    【欧美男模】Finnlay x Leondame两大攻神！比比谁更攻！哈哈哈俩男模我又可以了！  时尚  T台  普通视频
# 1fA411L7rZ                                    #盖娅传说#今日份少主酷帅出街  时尚  T台  普通视频
# 1xy4y1C7oZ                                饱含泪水 吉赛尔·邦辰 最后一场T台秀  时尚  T台  普通视频
#
#             ...                                                 标签   视频长度  \
# 1tJ41187Rr  ...  [秀场, 时尚, T台, 模特, Mariacarla Boscono, 女神, 时尚, 古...  03:18
# 1MJ411J7mS  ...  [桥本环奈, 斋藤飞鸟, 秀场, 日本, 时尚, T台, 新木优子, 时尚, 桐谷美玲, 走...  02:45
# 16J41177CB  ...          [秀场, 时尚, T台, Darya Kostenich, 模特, 资讯, 女神]  03:42
# 127411i7Ph  ...        [秀场, 时尚, T台, 郭培, 混剪, 时尚, 模特, Haute Couture]  03:58
# 1E7411r7EE  ...  [秀场, 服饰, 时尚, T台, 高级定制, 公主裙, 模特, T台, 晚礼服, 女装, 时...  03:58
# ...         ...                                                ...    ...
# 1nK411N7AF  ...               [秀场, 服饰, 时尚, T台, 迪奥, 复古, DIOR, dior]  04:22
# 18p4y1k7oS  ...                            [时装周, 秀场, 时尚, T台, VLOG]  10:17
# 1Yz4y1o71C  ...        [时尚, T台, 欧美, 帅哥, 欧美男模, 高颜值, leondame, 颜值爆表]  01:38
# 1fA411L7rZ  ...  [中国风, 汉服, 服饰, 时尚, T台, 中国华服日, 时尚, 服装搭配, FASHION...  00:24
# 1xy4y1C7oZ  ...                       [秀场, 时尚, T台, 时尚, 走秀, 模特, T台]  02:01
#
#                播放量   点赞数   投币数   收藏数   转发数   评论数   弹幕数 有无分集
# 1tJ41187Rr  247.0万  5.3万  6271  4.8万  1878   365  1000    否
# 1MJ411J7mS  244.2万  4.5万  1.5万  4.5万  1.2万  1148  3013    否
# 16J41177CB  196.9万  7.5万  1.5万  6.5万  7327  1137  2438    否
# 127411i7Ph  124.0万  5.3万  5808  3.6万  2649   878  4036    否
# 1E7411r7EE  113.3万  7.5万  1.4万  8.1万  5948   925  5473    否
# ...            ...   ...   ...   ...   ...   ...   ...  ...
# 1nK411N7AF    3.8万  1860   152  2114    64    40    50    否
# 18p4y1k7oS    3.8万  1524   335   252    35    71   129    否
# 1Yz4y1o71C    3.7万  1887   276  1775   111    46    25    否
# 1fA411L7rZ    3.7万   979     5   205    28    34     6    否
# 1xy4y1C7oZ    3.7万   287     2    83     1     9     4    否
#
# [995 rows x 21 columns]
