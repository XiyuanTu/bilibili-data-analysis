# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_youxi_shouji=pd.DataFrame(columns=columns)
channel_youxi_shouji
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[6]/div/a/span').click()  #选择“游戏”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[6]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '游戏'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[4]/a').click()  #选择“手机游戏”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[4]/a').text
sub_channel
# Out:
# '手机游戏'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(6,7): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_youxi_shouji.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-24 08:10:20.502581
# <ipython-input-11-32077ab1d37d>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-11-32077ab1d37d>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-11-32077ab1d37d>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为16f4y1y7sr视频属性的抓取
# BV号为16f4y1y7sr的视频属性抓取结束
# <ipython-input-11-32077ab1d37d>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1JT4y1J7wC视频属性的抓取
# BV号为1JT4y1J7wC的视频属性抓取结束
# 开始BV号为1ga4y1e7fJ视频属性的抓取
# BV号为1ga4y1e7fJ的视频属性抓取结束
# 开始BV号为1ip4y1D7KL视频属性的抓取
# BV号为1ip4y1D7KL的视频属性抓取结束
# 开始BV号为1WK4y147Ck视频属性的抓取
# BV号为1WK4y147Ck的视频属性抓取结束
# 开始BV号为1dT4y1J7EW视频属性的抓取
# BV号为1dT4y1J7EW的视频属性抓取结束
# 开始BV号为1Mv411B75R视频属性的抓取
# BV号为1Mv411B75R的视频属性抓取结束
# 开始BV号为1Hg4y1q7Ww视频属性的抓取
# BV号为1Hg4y1q7Ww的视频属性抓取结束
# 开始BV号为1Ng4y1v7Fy视频属性的抓取
# BV号为1Ng4y1v7Fy的视频属性抓取结束
# 开始BV号为1vA411i7rd视频属性的抓取
# BV号为1vA411i7rd的视频属性抓取结束
# 开始BV号为1ZV411r7Gs视频属性的抓取
# BV号为1ZV411r7Gs的视频属性抓取结束
# 开始BV号为1aK411n7MV视频属性的抓取
# BV号为1aK411n7MV的视频属性抓取结束
# 开始BV号为1TA411B7t2视频属性的抓取
# BV号为1TA411B7t2的视频属性抓取结束
# 开始BV号为1Ya4y1Y7YQ视频属性的抓取
# BV号为1Ya4y1Y7YQ的视频属性抓取结束
# 开始BV号为1eZ4y1H7L4视频属性的抓取
# BV号为1eZ4y1H7L4的视频属性抓取结束
# 开始BV号为1zi4y1x7M8视频属性的抓取
# BV号为1zi4y1x7M8的视频属性抓取结束
# 开始BV号为18C4y1a7kj视频属性的抓取
# BV号为18C4y1a7kj的视频属性抓取结束
# 开始BV号为1af4y1y7tn视频属性的抓取
# BV号为1af4y1y7tn的视频属性抓取结束
# 开始BV号为1YT4y177b4视频属性的抓取
# BV号为1YT4y177b4的视频属性抓取结束
# 开始BV号为1bC4y187BC视频属性的抓取
# BV号为1bC4y187BC的视频属性抓取结束
# 开始BV号为1bQ4y1P7Zy视频属性的抓取
# BV号为1bQ4y1P7Zy的视频属性抓取结束
# 开始BV号为19z411i7bH视频属性的抓取
# BV号为19z411i7bH的视频属性抓取结束
# 开始BV号为1sT4y1J7EA视频属性的抓取
# BV号为1sT4y1J7EA的视频属性抓取结束
# 开始BV号为1Bz4y1Q7ht视频属性的抓取
# BV号为1Bz4y1Q7ht的视频属性抓取结束
# 开始BV号为1uk4y1z7c2视频属性的抓取
# BV号为1uk4y1z7c2的视频属性抓取结束
# 开始BV号为1Kp4y1D7cp视频属性的抓取
# BV号为1Kp4y1D7cp的视频属性抓取结束
# 开始BV号为1CA411v7eW视频属性的抓取
# BV号为1CA411v7eW的视频属性抓取结束
# 开始BV号为1mz411e7kx视频属性的抓取
# BV号为1mz411e7kx的视频属性抓取结束
# 开始BV号为1Nv411B7HV视频属性的抓取
# BV号为1Nv411B7HV的视频属性抓取结束
# 开始BV号为1KK4y1b7rz视频属性的抓取
# BV号为1KK4y1b7rz的视频属性抓取结束
# 开始BV号为1QZ4y1H7t3视频属性的抓取
# BV号为1QZ4y1H7t3的视频属性抓取结束
# 开始BV号为1x54y1z7fv视频属性的抓取
# BV号为1x54y1z7fv的视频属性抓取结束
# 开始BV号为1hi4y1x7rk视频属性的抓取
# BV号为1hi4y1x7rk的视频属性抓取结束
# 开始BV号为1NK4y147Ep视频属性的抓取
# BV号为1NK4y147Ep的视频属性抓取结束
# 开始BV号为1Cp4y1D7Rq视频属性的抓取
# BV号为1Cp4y1D7Rq的视频属性抓取结束
# 开始BV号为19K411p7Us视频属性的抓取
# BV号为19K411p7Us的视频属性抓取结束
# 开始BV号为1xz411i7D7视频属性的抓取
# BV号为1xz411i7D7的视频属性抓取结束
# 开始BV号为15i4y1G7pU视频属性的抓取
# BV号为15i4y1G7pU的视频属性抓取结束
# 开始BV号为1fC4y1a73U视频属性的抓取
# BV号为1fC4y1a73U的视频属性抓取结束
# 开始BV号为1qi4y1G7K7视频属性的抓取
# BV号为1qi4y1G7K7的视频属性抓取结束
# 开始BV号为1Cp4y1D7Rq视频属性的抓取
# BV号为1Cp4y1D7Rq的视频属性抓取结束
# 开始BV号为19K411p7Us视频属性的抓取
# BV号为19K411p7Us的视频属性抓取结束
# 开始BV号为1dV411C7p2视频属性的抓取
# BV号为1dV411C7p2的视频属性抓取结束
# 开始BV号为1xz411i7D7视频属性的抓取
# BV号为1xz411i7D7的视频属性抓取结束
# 开始BV号为15i4y1G7pU视频属性的抓取
# BV号为15i4y1G7pU的视频属性抓取结束
# 开始BV号为1fC4y1a73U视频属性的抓取
# BV号为1fC4y1a73U的视频属性抓取结束
# 开始BV号为1qi4y1G7K7视频属性的抓取
# BV号为1qi4y1G7K7的视频属性抓取结束
# 开始BV号为17Z4y1H7UN视频属性的抓取
# BV号为17Z4y1H7UN的视频属性抓取结束
# 开始BV号为1dp4y1D7nG视频属性的抓取
# BV号为1dp4y1D7nG的视频属性抓取结束
# 开始BV号为1ez4y197p6视频属性的抓取
# BV号为1ez4y197p6的视频属性抓取结束
# 开始BV号为1MV4116765视频属性的抓取
# BV号为1MV4116765的视频属性抓取结束
# 开始BV号为1pK4y147C9视频属性的抓取
# BV号为1pK4y147C9的视频属性抓取结束
# 开始BV号为17i4y1G7gy视频属性的抓取
# BV号为17i4y1G7gy的视频属性抓取结束
# 开始BV号为1Uz4y1Q7M5视频属性的抓取
# BV号为1Uz4y1Q7M5的视频属性抓取结束
# 开始BV号为1HK4y1476L视频属性的抓取
# BV号为1HK4y1476L的视频属性抓取结束
# 开始BV号为1xV411k7ee视频属性的抓取
# BV号为1xV411k7ee的视频属性抓取结束
# 开始BV号为18V411k7GF视频属性的抓取
# BV号为18V411k7GF的视频属性抓取结束
# 开始BV号为1ZZ4y1n7hv视频属性的抓取
# BV号为1ZZ4y1n7hv的视频属性抓取结束
# 开始BV号为1Xi4y1G7LT视频属性的抓取
# BV号为1Xi4y1G7LT的视频属性抓取结束
# 开始BV号为1wa4y1e7Ky视频属性的抓取
# BV号为1wa4y1e7Ky的视频属性抓取结束
# 开始BV号为1xz4y1X7Bm视频属性的抓取
# BV号为1xz4y1X7Bm的视频属性抓取结束
# 开始BV号为1Zv411q7jz视频属性的抓取
# BV号为1Zv411q7jz的视频属性抓取结束
# 开始BV号为1QC4y1a7jk视频属性的抓取
# BV号为1QC4y1a7jk的视频属性抓取结束
# 开始BV号为185411Y7ru视频属性的抓取
# BV号为185411Y7ru的视频属性抓取结束
# 开始BV号为16D4y1Q7qx视频属性的抓取
# BV号为16D4y1Q7qx的视频属性抓取结束
# 开始BV号为1uV41167Gi视频属性的抓取
# BV号为1uV41167Gi的视频属性抓取结束
# 开始BV号为1Xk4y1q7LN视频属性的抓取
# BV号为1Xk4y1q7LN的视频属性抓取结束
# 开始BV号为19z411i7Xv视频属性的抓取
# BV号为19z411i7Xv的视频属性抓取结束
# 开始BV号为1KK411W7f5视频属性的抓取
# BV号为1KK411W7f5的视频属性抓取结束
# 开始BV号为1hT4y1J7vy视频属性的抓取
# BV号为1hT4y1J7vy的视频属性抓取结束
# 开始BV号为1JA411e7r7视频属性的抓取
# BV号为1JA411e7r7的视频属性抓取结束
# 开始BV号为1gt4y197tm视频属性的抓取
# BV号为1gt4y197tm的视频属性抓取结束
# 开始BV号为1pK4y147m3视频属性的抓取
# BV号为1pK4y147m3的视频属性抓取结束
# 开始BV号为19z411e76a视频属性的抓取
# BV号为19z411e76a的视频属性抓取结束
# 开始BV号为1Ai4y1V7Dq视频属性的抓取
# BV号为1Ai4y1V7Dq的视频属性抓取结束
# 开始BV号为1Dz411e7cs视频属性的抓取
# BV号为1Dz411e7cs的视频属性抓取结束
# 开始BV号为1DV411r7z6视频属性的抓取
# BV号为1DV411r7z6的视频属性抓取结束
# 开始BV号为13A411i7EV视频属性的抓取
# BV号为13A411i7EV的视频属性抓取结束
# 开始BV号为1Hi4y1G7Q8视频属性的抓取
# BV号为1Hi4y1G7Q8的视频属性抓取结束
# 开始BV号为1cV41167Cw视频属性的抓取
# BV号为1cV41167Cw的视频属性抓取结束
# 开始BV号为1tK411p7ag视频属性的抓取
# BV号为1tK411p7ag的视频属性抓取结束
# 开始BV号为1Av411B7FB视频属性的抓取
# BV号为1Av411B7FB的视频属性抓取结束
# 开始BV号为1454y1B7gr视频属性的抓取
# BV号为1454y1B7gr的视频属性抓取结束
# 开始BV号为1BK4y1x7GG视频属性的抓取
# BV号为1BK4y1x7GG的视频属性抓取结束
# 开始BV号为1Sg4y1i7me视频属性的抓取
# BV号为1Sg4y1i7me的视频属性抓取结束
# 开始BV号为16A411i7Wv视频属性的抓取
# BV号为16A411i7Wv的视频属性抓取结束
# 开始BV号为1p54y1B7ku视频属性的抓取
# BV号为1p54y1B7ku的视频属性抓取结束
# 开始BV号为1eg4y1v75M视频属性的抓取
# BV号为1eg4y1v75M的视频属性抓取结束
# 开始BV号为1ND4y1Q7FR视频属性的抓取
# BV号为1ND4y1Q7FR的视频属性抓取结束
# 开始BV号为1Qf4y1y7WA视频属性的抓取
# BV号为1Qf4y1y7WA的视频属性抓取结束
# 开始BV号为1op4y1D7qW视频属性的抓取
# BV号为1op4y1D7qW的视频属性抓取结束
# 开始BV号为18g4y1q7To视频属性的抓取
# BV号为18g4y1q7To的视频属性抓取结束
# 开始BV号为1j5411Y7bC视频属性的抓取
# BV号为1j5411Y7bC的视频属性抓取结束
# 开始BV号为1Uf4y1y7TS视频属性的抓取
# BV号为1Uf4y1y7TS的视频属性抓取结束
# 开始BV号为1zg4y1v7Qy视频属性的抓取
# BV号为1zg4y1v7Qy的视频属性抓取结束
# 开始BV号为16f4y1y7Qm视频属性的抓取
# BV号为16f4y1y7Qm的视频属性抓取结束
# 开始BV号为19p4y1D7Pf视频属性的抓取
# BV号为19p4y1D7Pf的视频属性抓取结束
# 开始BV号为1cf4y117EY视频属性的抓取
# BV号为1cf4y117EY的视频属性抓取结束
# 开始BV号为1vZ4y1H7Cn视频属性的抓取
# BV号为1vZ4y1H7Cn的视频属性抓取结束
# 开始BV号为1wz4y1R7kT视频属性的抓取
# BV号为1wz4y1R7kT的视频属性抓取结束
# 2020-12-24 08:39:07.917106

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-56-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_youxi_shouji.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月     97   97    97   97   97   97   97   97    97      97   97    97   97
# 3月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 4月     96   96    96   96   96   96   96   96    96      96   96    96   96
# 5月     98   98    98   98   98   98   98   98    98      98   98    98   98
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月     93   93    93   93   93   93   93   93    93      93   93    93   93
# 8月     93   93    93   93   93   93   93   93    93      93   93    93   93
# 9月     99   99    99   99   99   99   99   99    99      99   99    99   99
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月   100  100  100  100  100  100   100
# 2月    97   97   97   97   97   97    97
# 3月    99   99   99   99   99   99    99
# 4月    96   96   96   96   96   96    96
# 5月    98   98   98   98   98   98    98
# 6月   100  100  100  100  100  100   100
# 7月    93   93   93   93   93   93    93
# 8月    93   93   93   93   93   93    93
# 9月    99   99   99   99   99   99    99

# %%
channel_youxi_shouji.to_json('channel_youxi_shouji.json')

# %%
pd.set_option('display.max_rows', None)

# %%
channel_youxi_shouji[channel_youxi_shouji['时间']=='6月']=channel_youxi_shouji[channel_youxi_shouji['时间']=='6月'][:100]
