# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_youxi_dianzi=pd.DataFrame(columns=columns)
channel_youxi_dianzi
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[6]/div/a/span').click()  #选择“游戏”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[6]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '游戏'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[3]/a').click()  #选择“电子竞技”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[3]/a').text
sub_channel
# Out:
# '电子竞技'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(1,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_youxi_dianzi.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-23 19:38:47.529669
# <ipython-input-8-c955be8a6d1f>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-8-c955be8a6d1f>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-8-c955be8a6d1f>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1mJ411G7ue视频属性的抓取
# BV号为1mJ411G7ue的视频属性抓取结束
# <ipython-input-8-c955be8a6d1f>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1eJ411V7r3视频属性的抓取
# BV号为1eJ411V7r3的视频属性抓取结束
# 开始BV号为1T7411v7xL视频属性的抓取
# BV号为1T7411v7xL的视频属性抓取结束
# 开始BV号为1TJ411H7Hb视频属性的抓取
# BV号为1TJ411H7Hb的视频属性抓取结束
# 开始BV号为1D7411a7TE视频属性的抓取
# BV号为1D7411a7TE的视频属性抓取结束
# 开始BV号为1W7411a7QB视频属性的抓取
# BV号为1W7411a7QB的视频属性抓取结束
# 开始BV号为1LJ411L7Tj视频属性的抓取
# BV号为1LJ411L7Tj的视频属性抓取结束
# 开始BV号为1S7411B76x视频属性的抓取
# BV号为1S7411B76x的视频属性抓取结束
# 开始BV号为1m7411678Q视频属性的抓取
# BV号为1m7411678Q的视频属性抓取结束
# 开始BV号为1H7411e7rf视频属性的抓取
# BV号为1H7411e7rf的视频属性抓取结束
# 开始BV号为15J411E71m视频属性的抓取
# BV号为15J411E71m的视频属性抓取结束
# 开始BV号为15J411E76S视频属性的抓取
# BV号为15J411E76S的视频属性抓取结束
# 开始BV号为1Z7411v7Fy视频属性的抓取
# BV号为1Z7411v7Fy的视频属性抓取结束
# 开始BV号为1C7411r7si视频属性的抓取
# BV号为1C7411r7si的视频属性抓取结束
# 开始BV号为1L7411v7wx视频属性的抓取
# BV号为1L7411v7wx的视频属性抓取结束
# 开始BV号为1cJ411j7Cj视频属性的抓取
# BV号为1cJ411j7Cj的视频属性抓取结束
# 开始BV号为1D7411a7wN视频属性的抓取
# BV号为1D7411a7wN的视频属性抓取结束
# 开始BV号为1n7411r7sb视频属性的抓取
# BV号为1n7411r7sb的视频属性抓取结束
# 开始BV号为1y7411i7cd视频属性的抓取
# BV号为1y7411i7cd的视频属性抓取结束
# 开始BV号为117411Y7fJ视频属性的抓取
# BV号为117411Y7fJ的视频属性抓取结束
# 开始BV号为1c7411z78C视频属性的抓取
# BV号为1c7411z78C的视频属性抓取结束
# 开始BV号为1vJ411G7iL视频属性的抓取
# BV号为1vJ411G7iL的视频属性抓取结束
# 开始BV号为16J411G7tu视频属性的抓取
# BV号为16J411G7tu的视频属性抓取结束
# 开始BV号为1hJ4117723视频属性的抓取
# BV号为1hJ4117723的视频属性抓取结束
# 开始BV号为15741167gV视频属性的抓取
# BV号为15741167gV的视频属性抓取结束
# 开始BV号为1R7411e7Sw视频属性的抓取
# BV号为1R7411e7Sw的视频属性抓取结束
# 开始BV号为1NJ411J7xM视频属性的抓取
# BV号为1NJ411J7xM的视频属性抓取结束
# 开始BV号为12J411H71m视频属性的抓取
# BV号为12J411H71m的视频属性抓取结束
# 开始BV号为1iJ41157GU视频属性的抓取
# BV号为1iJ41157GU的视频属性抓取结束
# 开始BV号为14J41187MB视频属性的抓取
# BV号为14J41187MB的视频属性抓取结束
# 开始BV号为1a7411q7LR视频属性的抓取
# BV号为1a7411q7LR的视频属性抓取结束
# 开始BV号为1i7411r7wg视频属性的抓取
# BV号为1i7411r7wg的视频属性抓取结束
# 开始BV号为1P7411e7Ss视频属性的抓取
# BV号为1P7411e7Ss的视频属性抓取结束
# 开始BV号为117411k7ZC视频属性的抓取
# BV号为117411k7ZC的视频属性抓取结束
# 开始BV号为1x7411q7Vd视频属性的抓取
# BV号为1x7411q7Vd的视频属性抓取结束
# 开始BV号为1p7411k798视频属性的抓取
# BV号为1p7411k798的视频属性抓取结束
# 开始BV号为1E7411q7ob视频属性的抓取
# BV号为1E7411q7ob的视频属性抓取结束
# 开始BV号为1HJ411V7oo视频属性的抓取
# BV号为1HJ411V7oo的视频属性抓取结束
# 开始BV号为1a7411r74T视频属性的抓取
# BV号为1a7411r74T的视频属性抓取结束
# 开始BV号为1EJ411n7UE视频属性的抓取
# BV号为1EJ411n7UE的视频属性抓取结束
# 开始BV号为1HJ41177Em视频属性的抓取
# BV号为1HJ41177Em的视频属性抓取结束
# 开始BV号为1ZJ411J7KA视频属性的抓取
# BV号为1ZJ411J7KA的视频属性抓取结束
# 开始BV号为1ZJ411L7W2视频属性的抓取
# BV号为1ZJ411L7W2的视频属性抓取结束
# 开始BV号为1j7411r7n7视频属性的抓取
# BV号为1j7411r7n7的视频属性抓取结束
# 开始BV号为1VJ411j7t9视频属性的抓取
# BV号为1VJ411j7t9的视频属性抓取结束
# 开始BV号为1eJ411j7xi视频属性的抓取
# BV号为1eJ411j7xi的视频属性抓取结束
# 开始BV号为187411B7Zq视频属性的抓取
# BV号为187411B7Zq的视频属性抓取结束
# 开始BV号为177411v71c视频属性的抓取
# BV号为177411v71c的视频属性抓取结束
# 开始BV号为1CJ411776i视频属性的抓取
# BV号为1CJ411776i的视频属性抓取结束
# 开始BV号为1h7411a7eM视频属性的抓取
# BV号为1h7411a7eM的视频属性抓取结束
# 开始BV号为1aJ411H7hg视频属性的抓取
# BV号为1aJ411H7hg的视频属性抓取结束
# 开始BV号为19J411j7zC视频属性的抓取
# BV号为19J411j7zC的视频属性抓取结束
# 开始BV号为157411i7Cu视频属性的抓取
# BV号为157411i7Cu的视频属性抓取结束
# 开始BV号为1AJ411572K视频属性的抓取
# BV号为1AJ411572K的视频属性抓取结束
# 开始BV号为1W7411a7m5视频属性的抓取
# BV号为1W7411a7m5的视频属性抓取结束
# 开始BV号为1d7411B7rC视频属性的抓取
# BV号为1d7411B7rC的视频属性抓取结束
# 开始BV号为1P741167gX视频属性的抓取
# BV号为1P741167gX的视频属性抓取结束
# 开始BV号为1G7411i77k视频属性的抓取
# BV号为1G7411i77k的视频属性抓取结束
# 开始BV号为1n7411k7k2视频属性的抓取
# BV号为1n7411k7k2的视频属性抓取结束
# 开始BV号为1r7411z742视频属性的抓取
# BV号为1r7411z742的视频属性抓取结束
# 开始BV号为1F7411C711视频属性的抓取
# BV号为1F7411C711的视频属性抓取结束
# 开始BV号为1hJ411E7iE视频属性的抓取
# BV号为1hJ411E7iE的视频属性抓取结束
# 开始BV号为157411Y73G视频属性的抓取
# BV号为157411Y73G的视频属性抓取结束
# 开始BV号为1V7411Y7Tx视频属性的抓取
# BV号为1V7411Y7Tx的视频属性抓取结束
# 开始BV号为1xJ411872F视频属性的抓取
# BV号为1xJ411872F的视频属性抓取结束
# 开始BV号为1TJ411L7Bd视频属性的抓取
# BV号为1TJ411L7Bd的视频属性抓取结束
# 开始BV号为1MJ41157XS视频属性的抓取
# BV号为1MJ41157XS的视频属性抓取结束
# 开始BV号为1e7411q73k视频属性的抓取
# BV号为1e7411q73k的视频属性抓取结束
# 开始BV号为1cJ411p7zw视频属性的抓取
# BV号为1cJ411p7zw的视频属性抓取结束
# 开始BV号为1c7411i7n2视频属性的抓取
# BV号为1c7411i7n2的视频属性抓取结束
# 开始BV号为1NJ411p7Dz视频属性的抓取
# BV号为1NJ411p7Dz的视频属性抓取结束
# 开始BV号为1hJ411E7F9视频属性的抓取
# BV号为1hJ411E7F9的视频属性抓取结束
# 开始BV号为1QJ411G7Za视频属性的抓取
# BV号为1QJ411G7Za的视频属性抓取结束
# 开始BV号为13741167mt视频属性的抓取
# BV号为13741167mt的视频属性抓取结束
# 开始BV号为1C7411r7P5视频属性的抓取
# BV号为1C7411r7P5的视频属性抓取结束
# 开始BV号为12J411h7UY视频属性的抓取
# BV号为12J411h7UY的视频属性抓取结束
# 开始BV号为1RJ411L7K8视频属性的抓取
# BV号为1RJ411L7K8的视频属性抓取结束
# 开始BV号为1B7411i7yC视频属性的抓取
# BV号为1B7411i7yC的视频属性抓取结束
# 开始BV号为157411k7w3视频属性的抓取
# BV号为157411k7w3的视频属性抓取结束
# 开始BV号为1GJ411J74K视频属性的抓取
# BV号为1GJ411J74K的视频属性抓取结束
# 开始BV号为1N7411e7Lk视频属性的抓取
# BV号为1N7411e7Lk的视频属性抓取结束
# 开始BV号为1hJ411G7AV视频属性的抓取
# BV号为1hJ411G7AV的视频属性抓取结束
# 开始BV号为1jJ411E7mh视频属性的抓取
# BV号为1jJ411E7mh的视频属性抓取结束
# 开始BV号为1yJ411V7nc视频属性的抓取
# BV号为1yJ411V7nc的视频属性抓取结束
# 开始BV号为1dJ411J7W2视频属性的抓取
# BV号为1dJ411J7W2的视频属性抓取结束
# 开始BV号为1Z7411Y7wq视频属性的抓取
# BV号为1Z7411Y7wq的视频属性抓取结束
# 开始BV号为1DJ411G7kh视频属性的抓取
# BV号为1DJ411G7kh的视频属性抓取结束
# 开始BV号为1E7411v7Wg视频属性的抓取
# BV号为1E7411v7Wg的视频属性抓取结束
# 开始BV号为1S7411v72c视频属性的抓取
# BV号为1S7411v72c的视频属性抓取结束
# 开始BV号为1LJ411V7H3视频属性的抓取
# BV号为1LJ411V7H3的视频属性抓取结束
# 开始BV号为1bJ411E7wz视频属性的抓取
# BV号为1bJ411E7wz的视频属性抓取结束
# 开始BV号为1CJ411n7Vk视频属性的抓取
# BV号为1CJ411n7Vk的视频属性抓取结束
# 开始BV号为1eJ411E7ND视频属性的抓取
# BV号为1eJ411E7ND的视频属性抓取结束
# 开始BV号为1tJ41187Nt视频属性的抓取
# BV号为1tJ41187Nt的视频属性抓取结束
# 开始BV号为1L7411i7MN视频属性的抓取
# BV号为1L7411i7MN的视频属性抓取结束
# 开始BV号为1JJ411E7Re视频属性的抓取
# BV号为1JJ411E7Re的视频属性抓取结束
# 开始BV号为1P7411q7jN视频属性的抓取
# BV号为1P7411q7jN的视频属性抓取结束
# 开始BV号为197411i7Je视频属性的抓取
# BV号为197411i7Je的视频属性抓取结束
# 开始BV号为1LJ411j7wj视频属性的抓取
# BV号为1LJ411j7wj的视频属性抓取结束
# 开始BV号为1wJ411J7Ax视频属性的抓取
# BV号为1wJ411J7Ax的视频属性抓取结束
# 开始BV号为1R74113737视频属性的抓取
# BV号为1R74113737的视频属性抓取结束
# 开始BV号为1g741157YU视频属性的抓取
# BV号为1g741157YU的视频属性抓取结束
# 开始BV号为1qE411J7Vm视频属性的抓取
# BV号为1qE411J7Vm的视频属性抓取结束
# 开始BV号为1M7411x7Sp视频属性的抓取
# BV号为1M7411x7Sp的视频属性抓取结束
# 开始BV号为157411G7CH视频属性的抓取
# BV号为157411G7CH的视频属性抓取结束
# 开始BV号为1Zj411f793视频属性的抓取
# BV号为1Zj411f793的视频属性抓取结束
# 开始BV号为1K7411b7dJ视频属性的抓取
# BV号为1K7411b7dJ的视频属性抓取结束
# 开始BV号为1t7411F7ZN视频属性的抓取
# BV号为1t7411F7ZN的视频属性抓取结束
# 开始BV号为1J741157v4视频属性的抓取
# BV号为1J741157v4的视频属性抓取结束
# 开始BV号为1N7411p7Cy视频属性的抓取
# BV号为1N7411p7Cy的视频属性抓取结束
# 开始BV号为1Y741177SW视频属性的抓取
# BV号为1Y741177SW的视频属性抓取结束
# 开始BV号为177411T7J6视频属性的抓取
# BV号为177411T7J6的视频属性抓取结束
# 开始BV号为1y7411T7dj视频属性的抓取
# BV号为1y7411T7dj的视频属性抓取结束
# 开始BV号为1m7411A7ea视频属性的抓取
# BV号为1m7411A7ea的视频属性抓取结束
# 开始BV号为1q7411V77D视频属性的抓取
# BV号为1q7411V77D的视频属性抓取结束
# 开始BV号为1w741137EN视频属性的抓取
# BV号为1w741137EN的视频属性抓取结束
# 开始BV号为137411G72e视频属性的抓取
# BV号为137411G72e的视频属性抓取结束
# 开始BV号为1u7411u7Se视频属性的抓取
# BV号为1u7411u7Se的视频属性抓取结束
# 开始BV号为1u7411G7Ws视频属性的抓取
# BV号为1u7411G7Ws的视频属性抓取结束
# 开始BV号为1z7411p7Ju视频属性的抓取
# BV号为1z7411p7Ju的视频属性抓取结束
# 开始BV号为1kj411f75q视频属性的抓取
# BV号为1kj411f75q的视频属性抓取结束
# 开始BV号为137411G7dL视频属性的抓取
# BV号为137411G7dL的视频属性抓取结束
# 开始BV号为1BE411n7NF视频属性的抓取
# BV号为1BE411n7NF的视频属性抓取结束
# 开始BV号为18E411n7Na视频属性的抓取
# BV号为18E411n7Na的视频属性抓取结束
# 开始BV号为117411M77k视频属性的抓取
# BV号为117411M77k的视频属性抓取结束
# 开始BV号为1o7411L7fk视频属性的抓取
# BV号为1o7411L7fk的视频属性抓取结束
# 开始BV号为1F7411H77X视频属性的抓取
# BV号为1F7411H77X的视频属性抓取结束
# 开始BV号为1N7411a75s视频属性的抓取
# BV号为1N7411a75s的视频属性抓取结束
# 开始BV号为1o7411K7xd视频属性的抓取
# BV号为1o7411K7xd的视频属性抓取结束
# 开始BV号为1T741147km视频属性的抓取
# BV号为1T741147km的视频属性抓取结束
# 开始BV号为1b7411A7Np视频属性的抓取
# BV号为1b7411A7Np的视频属性抓取结束
# 开始BV号为157411u7VV视频属性的抓取
# BV号为157411u7VV的视频属性抓取结束
# 开始BV号为187411g7Ln视频属性的抓取
# BV号为187411g7Ln的视频属性抓取结束
# 开始BV号为1PE411H7ZY视频属性的抓取
# BV号为1PE411H7ZY的视频属性抓取结束
# 开始BV号为137411w7TX视频属性的抓取
# BV号为137411w7TX的视频属性抓取结束
# 开始BV号为1L7411s7pt视频属性的抓取
# BV号为1L7411s7pt的视频属性抓取结束
# 开始BV号为127411A7zS视频属性的抓取
# BV号为127411A7zS的视频属性抓取结束
# 开始BV号为1y7411j7ao视频属性的抓取
# BV号为1y7411j7ao的视频属性抓取结束
# 开始BV号为16741137ik视频属性的抓取
# BV号为16741137ik的视频属性抓取结束
# 开始BV号为1nj411f7BZ视频属性的抓取
# BV号为1nj411f7BZ的视频属性抓取结束
# 开始BV号为1R7411w7F3视频属性的抓取
# BV号为1R7411w7F3的视频属性抓取结束
# 开始BV号为1J7411T7Ab视频属性的抓取
# BV号为1J7411T7Ab的视频属性抓取结束
# 开始BV号为1h7411A7RD视频属性的抓取
# BV号为1h7411A7RD的视频属性抓取结束
# 开始BV号为1y7411c7eM视频属性的抓取
# BV号为1y7411c7eM的视频属性抓取结束
# 开始BV号为13741137BE视频属性的抓取
# BV号为13741137BE的视频属性抓取结束
# 开始BV号为1p741177NG视频属性的抓取
# BV号为1p741177NG的视频属性抓取结束
# 开始BV号为1c7411P7pX视频属性的抓取
# BV号为1c7411P7pX的视频属性抓取结束
# 开始BV号为1f7411G7pi视频属性的抓取
# BV号为1f7411G7pi的视频属性抓取结束
# 开始BV号为1v741157e9视频属性的抓取
# BV号为1v741157e9的视频属性抓取结束
# 开始BV号为1v741177jz视频属性的抓取
# BV号为1v741177jz的视频属性抓取结束
# 开始BV号为1j7411x7E1视频属性的抓取
# BV号为1j7411x7E1的视频属性抓取结束
# 开始BV号为1s7411V7dL视频属性的抓取
# BV号为1s7411V7dL的视频属性抓取结束
# 开始BV号为1s7411h7G9视频属性的抓取
# BV号为1s7411h7G9的视频属性抓取结束
# 开始BV号为1y7411c7He视频属性的抓取
# BV号为1y7411c7He的视频属性抓取结束
# 开始BV号为1A7411h7kd视频属性的抓取
# BV号为1A7411h7kd的视频属性抓取结束
# 开始BV号为177411N7hC视频属性的抓取
# BV号为177411N7hC的视频属性抓取结束
# 开始BV号为1A7411c7ah视频属性的抓取
# BV号为1A7411c7ah的视频属性抓取结束
# 开始BV号为1X7411A7jK视频属性的抓取
# BV号为1X7411A7jK的视频属性抓取结束
# 开始BV号为1s7411H71T视频属性的抓取
# BV号为1s7411H71T的视频属性抓取结束
# 开始BV号为1k7411G7LX视频属性的抓取
# BV号为1k7411G7LX的视频属性抓取结束
# 开始BV号为1J7411W7Pq视频属性的抓取
# BV号为1J7411W7Pq的视频属性抓取结束
# 开始BV号为1F741187QJ视频属性的抓取
# BV号为1F741187QJ的视频属性抓取结束
# 开始BV号为1K7411F74i视频属性的抓取
# BV号为1K7411F74i的视频属性抓取结束
# 开始BV号为1Z7411h7Xd视频属性的抓取
# BV号为1Z7411h7Xd的视频属性抓取结束
# 开始BV号为167411L7U4视频属性的抓取
# BV号为167411L7U4的视频属性抓取结束
# 开始BV号为1u7411s7mp视频属性的抓取
# BV号为1u7411s7mp的视频属性抓取结束
# 开始BV号为1oE411n7rr视频属性的抓取
# BV号为1oE411n7rr的视频属性抓取结束
# 开始BV号为1D7411t7VT视频属性的抓取
# BV号为1D7411t7VT的视频属性抓取结束
# 开始BV号为1y7411H7eX视频属性的抓取
# BV号为1y7411H7eX的视频属性抓取结束
# 开始BV号为1T7411M7eQ视频属性的抓取
# BV号为1T7411M7eQ的视频属性抓取结束
# 开始BV号为1n7411P7Mr视频属性的抓取
# BV号为1n7411P7Mr的视频属性抓取结束
# 开始BV号为1xE411H7Td视频属性的抓取
# BV号为1xE411H7Td的视频属性抓取结束
# 开始BV号为1e741137Hh视频属性的抓取
# BV号为1e741137Hh的视频属性抓取结束
# 开始BV号为1Z741177VY视频属性的抓取
# BV号为1Z741177VY的视频属性抓取结束
# 开始BV号为1F7411b7zX视频属性的抓取
# BV号为1F7411b7zX的视频属性抓取结束
# 开始BV号为1p7411h7Qo视频属性的抓取
# BV号为1p7411h7Qo的视频属性抓取结束
# 开始BV号为14E411J7st视频属性的抓取
# BV号为14E411J7st的视频属性抓取结束
# 开始BV号为1t741137Yn视频属性的抓取
# BV号为1t741137Yn的视频属性抓取结束
# 开始BV号为12741177Lo视频属性的抓取
# BV号为12741177Lo的视频属性抓取结束
# 开始BV号为1uE411H7Ny视频属性的抓取
# BV号为1uE411H7Ny的视频属性抓取结束
# 开始BV号为127411A7NY视频属性的抓取
# BV号为127411A7NY的视频属性抓取结束
# 开始BV号为177411a7Ma视频属性的抓取
# BV号为177411a7Ma的视频属性抓取结束
# 开始BV号为1w7411a7Ps视频属性的抓取
# BV号为1w7411a7Ps的视频属性抓取结束
# 开始BV号为1w7411t7gK视频属性的抓取
# BV号为1w7411t7gK的视频属性抓取结束
# 开始BV号为1e7411J7mZ视频属性的抓取
# BV号为1e7411J7mZ的视频属性抓取结束
# 开始BV号为187411W7Sk视频属性的抓取
# BV号为187411W7Sk的视频属性抓取结束
# 开始BV号为1E7411j7bg视频属性的抓取
# BV号为1E7411j7bg的视频属性抓取结束
# 开始BV号为1A7411F7ZH视频属性的抓取
# BV号为1A7411F7ZH的视频属性抓取结束
# 开始BV号为1R7411x7JH视频属性的抓取
# BV号为1R7411x7JH的视频属性抓取结束
# 开始BV号为1LE411H79s视频属性的抓取
# BV号为1LE411H79s的视频属性抓取结束
# 开始BV号为1G7411s7M1视频属性的抓取
# BV号为1G7411s7M1的视频属性抓取结束
# 开始BV号为1g7411n7eN视频属性的抓取
# BV号为1g7411n7eN的视频属性抓取结束
# 开始BV号为1j7411u7nv视频属性的抓取
# BV号为1j7411u7nv的视频属性抓取结束
# 开始BV号为1H741177K9视频属性的抓取
# BV号为1H741177K9的视频属性抓取结束
# 开始BV号为1G7411s7se视频属性的抓取
# BV号为1G7411s7se的视频属性抓取结束
# 开始BV号为1o7411L72n视频属性的抓取
# BV号为1o7411L72n的视频属性抓取结束
# 开始BV号为1k7411M7Nc视频属性的抓取
# BV号为1k7411M7Nc的视频属性抓取结束
# 开始BV号为1s7411x7ao视频属性的抓取
# BV号为1s7411x7ao的视频属性抓取结束
# 开始BV号为1H7411a7Gn视频属性的抓取
# BV号为1H7411a7Gn的视频属性抓取结束
# 开始BV号为197411n7Jf视频属性的抓取
# BV号为197411n7Jf的视频属性抓取结束
# 开始BV号为1AE411w7jQ视频属性的抓取
# BV号为1AE411w7jQ的视频属性抓取结束
# 开始BV号为1LE411G755视频属性的抓取
# BV号为1LE411G755的视频属性抓取结束
# 开始BV号为1BE411T7VV视频属性的抓取
# BV号为1BE411T7VV的视频属性抓取结束
# 开始BV号为1ME411g78C视频属性的抓取
# BV号为1ME411g78C的视频属性抓取结束
# 开始BV号为1GE411V7cs视频属性的抓取
# BV号为1GE411V7cs的视频属性抓取结束
# <ipython-input-8-c955be8a6d1f>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1uK411L7hz视频属性的抓取
# BV号为1uK411L7hz的视频属性抓取结束
# 开始BV号为1NE411u7Zu视频属性的抓取
# BV号为1NE411u7Zu的视频属性抓取结束
# 开始BV号为1mE411A7Ud视频属性的抓取
# BV号为1mE411A7Ud的视频属性抓取结束
# 开始BV号为1Pe411x72t视频属性的抓取
# BV号为1Pe411x72t的视频属性抓取结束
# 开始BV号为1Bk4y197xt视频属性的抓取
# BV号为1Bk4y197xt的视频属性抓取结束
# 开始BV号为19E411W7yU视频属性的抓取
# BV号为19E411W7yU的视频属性抓取结束
# 开始BV号为1EE41177Eh视频属性的抓取
# BV号为1EE41177Eh的视频属性抓取结束
# 开始BV号为1At4y1U7ef视频属性的抓取
# BV号为1At4y1U7ef的视频属性抓取结束
# 开始BV号为1BK4y1C76C视频属性的抓取
# BV号为1BK4y1C76C的视频属性抓取结束
# 开始BV号为1gE411P7GF视频属性的抓取
# BV号为1gE411P7GF的视频属性抓取结束
# 开始BV号为1iE411T7Tg视频属性的抓取
# BV号为1iE411T7Tg的视频属性抓取结束
# 开始BV号为1UE411K7vR视频属性的抓取
# BV号为1UE411K7vR的视频属性抓取结束
# 开始BV号为1eA41187qK视频属性的抓取
# BV号为1eA41187qK的视频属性抓取结束
# 开始BV号为1gC4y1s7oY视频属性的抓取
# BV号为1gC4y1s7oY的视频属性抓取结束
# 开始BV号为157411f7aC视频属性的抓取
# BV号为157411f7aC的视频属性抓取结束
# 开始BV号为1HE411L7RP视频属性的抓取
# BV号为1HE411L7RP的视频属性抓取结束
# 开始BV号为18p411A75r视频属性的抓取
# BV号为18p411A75r的视频属性抓取结束
# 开始BV号为1G64y1u7tf视频属性的抓取
# BV号为1G64y1u7tf的视频属性抓取结束
# 开始BV号为1p7411272e视频属性的抓取
# BV号为1p7411272e的视频属性抓取结束
# 开始BV号为1j7411d74C视频属性的抓取
# BV号为1j7411d74C的视频属性抓取结束
# 开始BV号为1ME411x7BX视频属性的抓取
# BV号为1ME411x7BX的视频属性抓取结束
# 开始BV号为1AE411E7Qa视频属性的抓取
# BV号为1AE411E7Qa的视频属性抓取结束
# 开始BV号为1sE411c7tU视频属性的抓取
# BV号为1sE411c7tU的视频属性抓取结束
# 开始BV号为1YE41137Wr视频属性的抓取
# BV号为1YE41137Wr的视频属性抓取结束
# 开始BV号为1JE411w7Mj视频属性的抓取
# BV号为1JE411w7Mj的视频属性抓取结束
# 开始BV号为1uE411572d视频属性的抓取
# BV号为1uE411572d的视频属性抓取结束
# 开始BV号为14c411h7ds视频属性的抓取
# BV号为14c411h7ds的视频属性抓取结束
# 开始BV号为1qE411j7Be视频属性的抓取
# BV号为1qE411j7Be的视频属性抓取结束
# 开始BV号为1qE41157aS视频属性的抓取
# BV号为1qE41157aS的视频属性抓取结束
# 开始BV号为1i7411y7gZ视频属性的抓取
# BV号为1i7411y7gZ的视频属性抓取结束
# 开始BV号为1pE41147Yw视频属性的抓取
# BV号为1pE41147Yw的视频属性抓取结束
# 开始BV号为1M7411f7xZ视频属性的抓取
# BV号为1M7411f7xZ的视频属性抓取结束
# 开始BV号为1TE411W7Y5视频属性的抓取
# BV号为1TE411W7Y5的视频属性抓取结束
# 开始BV号为13E41147xJ视频属性的抓取
# BV号为13E41147xJ的视频属性抓取结束
# 开始BV号为1BE411A7xt视频属性的抓取
# BV号为1BE411A7xt的视频属性抓取结束
# 开始BV号为1f7411m7dw视频属性的抓取
# BV号为1f7411m7dw的视频属性抓取结束
# 开始BV号为1554y1d7f4视频属性的抓取
# BV号为1554y1d7f4的视频属性抓取结束
# 开始BV号为1WE411E7mQ视频属性的抓取
# BV号为1WE411E7mQ的视频属性抓取结束
# 开始BV号为1F7411f7qe视频属性的抓取
# BV号为1F7411f7qe的视频属性抓取结束
# 开始BV号为1BE41157Rj视频属性的抓取
# BV号为1BE41157Rj的视频属性抓取结束
# 开始BV号为1Ue411x7VS视频属性的抓取
# BV号为1Ue411x7VS的视频属性抓取结束
# 开始BV号为1Ez411b7nh视频属性的抓取
# BV号为1Ez411b7nh的视频属性抓取结束
# 开始BV号为1KE411p7Er视频属性的抓取
# BV号为1KE411p7Er的视频属性抓取结束
# 开始BV号为1J7411R7ZR视频属性的抓取
# BV号为1J7411R7ZR的视频属性抓取结束
# 开始BV号为1JE411378r视频属性的抓取
# BV号为1JE411378r的视频属性抓取结束
# 开始BV号为1kE411771F视频属性的抓取
# BV号为1kE411771F的视频属性抓取结束
# 开始BV号为1b7411Z7TZ视频属性的抓取
# BV号为1b7411Z7TZ的视频属性抓取结束
# 开始BV号为1rE411V7iH视频属性的抓取
# BV号为1rE411V7iH的视频属性抓取结束
# 开始BV号为1dE41137mS视频属性的抓取
# BV号为1dE41137mS的视频属性抓取结束
# 开始BV号为1Z7411C7FG视频属性的抓取
# BV号为1Z7411C7FG的视频属性抓取结束
# 开始BV号为1mE411P7am视频属性的抓取
# BV号为1mE411P7am的视频属性抓取结束
# 开始BV号为1nE411F7ni视频属性的抓取
# BV号为1nE411F7ni的视频属性抓取结束
# 开始BV号为1CE411J7us视频属性的抓取
# BV号为1CE411J7us的视频属性抓取结束
# 开始BV号为1dE411E7af视频属性的抓取
# BV号为1dE411E7af的视频属性抓取结束
# 开始BV号为1pE411F7Km视频属性的抓取
# BV号为1pE411F7Km的视频属性抓取结束
# 开始BV号为12E411G7YT视频属性的抓取
# BV号为12E411G7YT的视频属性抓取结束
# 开始BV号为1nE411L7BG视频属性的抓取
# BV号为1nE411L7BG的视频属性抓取结束
# 开始BV号为1h7411Z7gB视频属性的抓取
# BV号为1h7411Z7gB的视频属性抓取结束
# 开始BV号为1R7411o7VU视频属性的抓取
# BV号为1R7411o7VU的视频属性抓取结束
# 开始BV号为1DZ4y1j7pK视频属性的抓取
# BV号为1DZ4y1j7pK的视频属性抓取结束
# 开始BV号为1zE411P7Zk视频属性的抓取
# BV号为1zE411P7Zk的视频属性抓取结束
# 开始BV号为1CE411L783视频属性的抓取
# BV号为1CE411L783的视频属性抓取结束
# 开始BV号为12E411G7Yz视频属性的抓取
# BV号为12E411G7Yz的视频属性抓取结束
# 开始BV号为1AE411x7jj视频属性的抓取
# BV号为1AE411x7jj的视频属性抓取结束
# 开始BV号为12E411M7sr视频属性的抓取
# BV号为12E411M7sr的视频属性抓取结束
# 开始BV号为1K7411f7mJ视频属性的抓取
# BV号为1K7411f7mJ的视频属性抓取结束
# 开始BV号为1T7411o731视频属性的抓取
# BV号为1T7411o731的视频属性抓取结束
# 开始BV号为1BE411L7wt视频属性的抓取
# BV号为1BE411L7wt的视频属性抓取结束
# 开始BV号为1nE411p7Kv视频属性的抓取
# BV号为1nE411p7Kv的视频属性抓取结束
# 开始BV号为1qE411776P视频属性的抓取
# BV号为1qE411776P的视频属性抓取结束
# 开始BV号为1sE411T7Vs视频属性的抓取
# BV号为1sE411T7Vs的视频属性抓取结束
# 开始BV号为1UE411G7Zj视频属性的抓取
# BV号为1UE411G7Zj的视频属性抓取结束
# 开始BV号为1NE41157ue视频属性的抓取
# BV号为1NE41157ue的视频属性抓取结束
# 开始BV号为1mE41147Wb视频属性的抓取
# BV号为1mE41147Wb的视频属性抓取结束
# 开始BV号为1gE411c7Mq视频属性的抓取
# 开始BV号为1gE411c7Mq视频属性的抓取
# BV号为1gE411c7Mq的视频属性抓取结束
# 开始BV号为1EE411P7oc视频属性的抓取
# BV号为1EE411P7oc的视频属性抓取结束
# 开始BV号为1Q741127cD视频属性的抓取
# BV号为1Q741127cD的视频属性抓取结束
# 开始BV号为1ze411x7N9视频属性的抓取
# BV号为1ze411x7N9的视频属性抓取结束
# 开始BV号为1K64y1u7gx视频属性的抓取
# BV号为1K64y1u7gx的视频属性抓取结束
# 开始BV号为1nK411L7eu视频属性的抓取
# BV号为1nK411L7eu的视频属性抓取结束
# 开始BV号为1pE41147rz视频属性的抓取
# BV号为1pE41147rz的视频属性抓取结束
# 开始BV号为1dE411F7Kv视频属性的抓取
# BV号为1dE411F7Kv的视频属性抓取结束
# 开始BV号为17c411h7aq视频属性的抓取
# BV号为17c411h7aq的视频属性抓取结束
# 开始BV号为1WE41157Na视频属性的抓取
# BV号为1WE41157Na的视频属性抓取结束
# 开始BV号为1YE411T7qf视频属性的抓取
# BV号为1YE411T7qf的视频属性抓取结束
# 开始BV号为137411o7dJ视频属性的抓取
# BV号为137411o7dJ的视频属性抓取结束
# 开始BV号为1Tp4y1C7Pp视频属性的抓取
# BV号为1Tp4y1C7Pp的视频属性抓取结束
# 开始BV号为17E411x7WP视频属性的抓取
# BV号为17E411x7WP的视频属性抓取结束
# 开始BV号为1W7411U7HY视频属性的抓取
# BV号为1W7411U7HY的视频属性抓取结束
# 开始BV号为197411R7Xm视频属性的抓取
# BV号为197411R7Xm的视频属性抓取结束
# 开始BV号为1q7411Z7iS视频属性的抓取
# BV号为1q7411Z7iS的视频属性抓取结束
# 开始BV号为1eE411T7So视频属性的抓取
# BV号为1eE411T7So的视频属性抓取结束
# 开始BV号为15z411b7Cy视频属性的抓取
# BV号为15z411b7Cy的视频属性抓取结束
# 开始BV号为1ht4y1m7t4视频属性的抓取
# BV号为1ht4y1m7t4的视频属性抓取结束
# 开始BV号为1kA41147yD视频属性的抓取
# BV号为1kA41147yD的视频属性抓取结束
# 开始BV号为1Qa4y1t7sY视频属性的抓取
# BV号为1Qa4y1t7sY的视频属性抓取结束
# 开始BV号为1GZ4y1x7Yy视频属性的抓取
# BV号为1GZ4y1x7Yy的视频属性抓取结束
# 开始BV号为1Nk4y1k746视频属性的抓取
# BV号为1Nk4y1k746的视频属性抓取结束
# 开始BV号为1z5411t7LH视频属性的抓取
# BV号为1z5411t7LH的视频属性抓取结束
# 开始BV号为1fe411W72e视频属性的抓取
# BV号为1fe411W72e的视频属性抓取结束
# 开始BV号为1ik4y197h3视频属性的抓取
# BV号为1ik4y197h3的视频属性抓取结束
# 开始BV号为1tz411B75G视频属性的抓取
# BV号为1tz411B75G的视频属性抓取结束
# 开始BV号为1ng4y1878s视频属性的抓取
# BV号为1ng4y1878s的视频属性抓取结束
# 开始BV号为1Wi4y1t7Gr视频属性的抓取
# BV号为1Wi4y1t7Gr的视频属性抓取结束
# 开始BV号为1xA411h75L视频属性的抓取
# BV号为1xA411h75L的视频属性抓取结束
# 开始BV号为1NA411875u视频属性的抓取
# BV号为1NA411875u的视频属性抓取结束
# 开始BV号为1EA411b7EN视频属性的抓取
# BV号为1EA411b7EN的视频属性抓取结束
# 开始BV号为1ek4y1d7SN视频属性的抓取
# BV号为1ek4y1d7SN的视频属性抓取结束
# 开始BV号为1Yk4y1r7fF视频属性的抓取
# BV号为1Yk4y1r7fF的视频属性抓取结束
# 开始BV号为1pz411b7xj视频属性的抓取
# BV号为1pz411b7xj的视频属性抓取结束
# 开始BV号为1Y54y197xQ视频属性的抓取
# BV号为1Y54y197xQ的视频属性抓取结束
# 开始BV号为11k4y1r7ty视频属性的抓取
# BV号为11k4y1r7ty的视频属性抓取结束
# 开始BV号为1U5411t7T4视频属性的抓取
# BV号为1U5411t7T4的视频属性抓取结束
# 开始BV号为1da4y147Nb视频属性的抓取
# BV号为1da4y147Nb的视频属性抓取结束
# 开始BV号为12T4y1G7Sw视频属性的抓取
# BV号为12T4y1G7Sw的视频属性抓取结束
# 开始BV号为15f4y1S7nu视频属性的抓取
# BV号为15f4y1S7nu的视频属性抓取结束
# 开始BV号为11e411x7PL视频属性的抓取
# BV号为11e411x7PL的视频属性抓取结束
# 开始BV号为1HK41157Ra视频属性的抓取
# BV号为1HK41157Ra的视频属性抓取结束
# 开始BV号为1eK411L7x1视频属性的抓取
# BV号为1eK411L7x1的视频属性抓取结束
# 开始BV号为13e41147SD视频属性的抓取
# BV号为13e41147SD的视频属性抓取结束
# 开始BV号为1NA411b7zY视频属性的抓取
# BV号为1NA411b7zY的视频属性抓取结束
# 开始BV号为1uA41187Ws视频属性的抓取
# BV号为1uA41187Ws的视频属性抓取结束
# 开始BV号为17p4y1C72u视频属性的抓取
# BV号为17p4y1C72u的视频属性抓取结束
# 开始BV号为1ZQ4y1K7SY视频属性的抓取
# BV号为1ZQ4y1K7SY的视频属性抓取结束
# 开始BV号为1x5411t7DT视频属性的抓取
# BV号为1x5411t7DT的视频属性抓取结束
# 开始BV号为1ZT4y1g7kq视频属性的抓取
# BV号为1ZT4y1g7kq的视频属性抓取结束
# 开始BV号为17V411Z7AE视频属性的抓取
# BV号为17V411Z7AE的视频属性抓取结束
# 开始BV号为1xV411Z7Vx视频属性的抓取
# BV号为1xV411Z7Vx的视频属性抓取结束
# 开始BV号为1Gz41187i2视频属性的抓取
# BV号为1Gz41187i2的视频属性抓取结束
# 开始BV号为1BV411o7LQ视频属性的抓取
# BV号为1BV411o7LQ的视频属性抓取结束
# 开始BV号为1KT4y157RZ视频属性的抓取
# BV号为1KT4y157RZ的视频属性抓取结束
# 开始BV号为1h5411t7Ec视频属性的抓取
# BV号为1h5411t7Ec的视频属性抓取结束
# 开始BV号为1ET4y137uX视频属性的抓取
# BV号为1ET4y137uX的视频属性抓取结束
# 开始BV号为1kQ4y1K7kU视频属性的抓取
# BV号为1kQ4y1K7kU的视频属性抓取结束
# 开始BV号为1Kt4y127eY视频属性的抓取
# BV号为1Kt4y127eY的视频属性抓取结束
# 开始BV号为1Ge411s7vc视频属性的抓取
# BV号为1Ge411s7vc的视频属性抓取结束
# 开始BV号为1Bk4y1R7ca视频属性的抓取
# BV号为1Bk4y1R7ca的视频属性抓取结束
# 开始BV号为1of4y1U7k4视频属性的抓取
# BV号为1of4y1U7k4的视频属性抓取结束
# 开始BV号为1wi4y1b7QB视频属性的抓取
# BV号为1wi4y1b7QB的视频属性抓取结束
# 开始BV号为1xA411b7Kp视频属性的抓取
# BV号为1xA411b7Kp的视频属性抓取结束
# 开始BV号为1yz411b7nY视频属性的抓取
# BV号为1yz411b7nY的视频属性抓取结束
# 开始BV号为1qV411f7PE视频属性的抓取
# BV号为1qV411f7PE的视频属性抓取结束
# 开始BV号为1ti4y187e8视频属性的抓取
# BV号为1ti4y187e8的视频属性抓取结束
# 开始BV号为1RV411R7Rj视频属性的抓取
# BV号为1RV411R7Rj的视频属性抓取结束
# 开始BV号为1CZ4y1x7BC视频属性的抓取
# BV号为1CZ4y1x7BC的视频属性抓取结束
# 开始BV号为1fV411o7rn视频属性的抓取
# BV号为1fV411o7rn的视频属性抓取结束
# 开始BV号为18a4y147AN视频属性的抓取
# BV号为18a4y147AN的视频属性抓取结束
# 开始BV号为1k54y1Q7ik视频属性的抓取
# BV号为1k54y1Q7ik的视频属性抓取结束
# 开始BV号为1bA411h7Kp视频属性的抓取
# BV号为1bA411h7Kp的视频属性抓取结束
# 开始BV号为1A64y1M7Ab视频属性的抓取
# BV号为1A64y1M7Ab的视频属性抓取结束
# 开始BV号为1nf4y1S7aT视频属性的抓取
# BV号为1nf4y1S7aT的视频属性抓取结束
# 开始BV号为1G5411t7Q4视频属性的抓取
# BV号为1G5411t7Q4的视频属性抓取结束
# 开始BV号为1eA411473b视频属性的抓取
# BV号为1eA411473b的视频属性抓取结束
# 开始BV号为1di4y1b7Zv视频属性的抓取
# BV号为1di4y1b7Zv的视频属性抓取结束
# 开始BV号为125411x7BV视频属性的抓取
# BV号为125411x7BV的视频属性抓取结束
# 开始BV号为1k64y1T7ff视频属性的抓取
# BV号为1k64y1T7ff的视频属性抓取结束
# 开始BV号为1Z541167DX视频属性的抓取
# BV号为1Z541167DX的视频属性抓取结束
# 开始BV号为1fV411o7uR视频属性的抓取
# BV号为1fV411o7uR的视频属性抓取结束
# 开始BV号为18p4y1X7t1视频属性的抓取
# BV号为18p4y1X7t1的视频属性抓取结束
# 开始BV号为1g5411t79L视频属性的抓取
# BV号为1g5411t79L的视频属性抓取结束
# 开始BV号为14g4y1z7hs视频属性的抓取
# BV号为14g4y1z7hs的视频属性抓取结束
# 开始BV号为1ha4y147XE视频属性的抓取
# BV号为1ha4y147XE的视频属性抓取结束
# 开始BV号为11a4y1x7fq视频属性的抓取
# BV号为11a4y1x7fq的视频属性抓取结束
# 开始BV号为1kZ4y1x7rt视频属性的抓取
# BV号为1kZ4y1x7rt的视频属性抓取结束
# 开始BV号为1J64y1u7Jo视频属性的抓取
# BV号为1J64y1u7Jo的视频属性抓取结束
# 开始BV号为1F5411t71j视频属性的抓取
# BV号为1F5411t71j的视频属性抓取结束
# 开始BV号为1c54y1d7c5视频属性的抓取
# BV号为1c54y1d7c5的视频属性抓取结束
# 开始BV号为1je41147op视频属性的抓取
# BV号为1je41147op的视频属性抓取结束
# 开始BV号为1Dt4y127BJ视频属性的抓取
# BV号为1Dt4y127BJ的视频属性抓取结束
# 开始BV号为16e411x7Ek视频属性的抓取
# BV号为16e411x7Ek的视频属性抓取结束
# 开始BV号为18z411b7b7视频属性的抓取
# BV号为18z411b7b7的视频属性抓取结束
# 开始BV号为1RT4y1G7Ep视频属性的抓取
# BV号为1RT4y1G7Ep的视频属性抓取结束
# 开始BV号为1RQ4y1P7y5视频属性的抓取
# BV号为1RQ4y1P7y5的视频属性抓取结束
# 开始BV号为1UA411b7Tg视频属性的抓取
# BV号为1UA411b7Tg的视频属性抓取结束
# 开始BV号为1Zk4y197JL视频属性的抓取
# BV号为1Zk4y197JL的视频属性抓取结束
# 开始BV号为1af4y1S7Rv视频属性的抓取
# BV号为1af4y1S7Rv的视频属性抓取结束
# 开始BV号为1DZ4y1W7Es视频属性的抓取
# BV号为1DZ4y1W7Es的视频属性抓取结束
# 开始BV号为1NZ4y1s72G视频属性的抓取
# BV号为1NZ4y1s72G的视频属性抓取结束
# 开始BV号为1BV411f7FS视频属性的抓取
# BV号为1BV411f7FS的视频属性抓取结束
# 开始BV号为1sQ4y1T79i视频属性的抓取
# BV号为1sQ4y1T79i的视频属性抓取结束
# 开始BV号为1Ha4y1t7i4视频属性的抓取
# BV号为1Ha4y1t7i4的视频属性抓取结束
# 开始BV号为1Ce411x7pu视频属性的抓取
# BV号为1Ce411x7pu的视频属性抓取结束
# 开始BV号为1Cf4y1U7DT视频属性的抓取
# BV号为1Cf4y1U7DT的视频属性抓取结束
# 开始BV号为1Tp4y197YB视频属性的抓取
# BV号为1Tp4y197YB的视频属性抓取结束
# 开始BV号为1Z54y1X7x4视频属性的抓取
# BV号为1Z54y1X7x4的视频属性抓取结束
# 开始BV号为1GC4y1x7Di视频属性的抓取
# BV号为1GC4y1x7Di的视频属性抓取结束
# 开始BV号为1C64y1u7tt视频属性的抓取
# BV号为1C64y1u7tt的视频属性抓取结束
# 开始BV号为1yC4y1s7a6视频属性的抓取
# BV号为1yC4y1s7a6的视频属性抓取结束
# 开始BV号为1dV411R7XU视频属性的抓取
# BV号为1dV411R7XU的视频属性抓取结束
# 开始BV号为1Ca4y1x7X5视频属性的抓取
# BV号为1Ca4y1x7X5的视频属性抓取结束
# 开始BV号为1fz411b76p视频属性的抓取
# BV号为1fz411b76p的视频属性抓取结束
# 开始BV号为1Lp4y1C76r视频属性的抓取
# BV号为1Lp4y1C76r的视频属性抓取结束
# 开始BV号为1kK41157Es视频属性的抓取
# BV号为1kK41157Es的视频属性抓取结束
# 开始BV号为1ma4y1x7SA视频属性的抓取
# BV号为1ma4y1x7SA的视频属性抓取结束
# 开始BV号为1JT4y1u7MS视频属性的抓取
# BV号为1JT4y1u7MS的视频属性抓取结束
# 开始BV号为1bf4y12727视频属性的抓取
# BV号为1bf4y12727的视频属性抓取结束
# 开始BV号为1zi4y1t7gW视频属性的抓取
# BV号为1zi4y1t7gW的视频属性抓取结束
# 开始BV号为1T54y1X7eH视频属性的抓取
# BV号为1T54y1X7eH的视频属性抓取结束
# 开始BV号为1BK411W77D视频属性的抓取
# BV号为1BK411W77D的视频属性抓取结束
# 开始BV号为1xg4y1i7XG视频属性的抓取
# BV号为1xg4y1i7XG的视频属性抓取结束
# 开始BV号为1ut4y117KU视频属性的抓取
# BV号为1ut4y117KU的视频属性抓取结束
# 开始BV号为1fg4y1B7Pi视频属性的抓取
# BV号为1fg4y1B7Pi的视频属性抓取结束
# 开始BV号为1NA411t7Rv视频属性的抓取
# BV号为1NA411t7Rv的视频属性抓取结束
# 开始BV号为1xk4y1k7bV视频属性的抓取
# BV号为1xk4y1k7bV的视频属性抓取结束
# 开始BV号为1SK411W7nW视频属性的抓取
# BV号为1SK411W7nW的视频属性抓取结束
# 开始BV号为1j54y1D7X6视频属性的抓取
# BV号为1j54y1D7X6的视频属性抓取结束
# 开始BV号为1vQ4y1N7Zr视频属性的抓取
# BV号为1vQ4y1N7Zr的视频属性抓取结束
# 开始BV号为1mQ4y1N7p7视频属性的抓取
# BV号为1mQ4y1N7p7的视频属性抓取结束
# 开始BV号为1qe411W7uL视频属性的抓取
# BV号为1qe411W7uL的视频属性抓取结束
# 开始BV号为1za4y1i7Qp视频属性的抓取
# BV号为1za4y1i7Qp的视频属性抓取结束
# 开始BV号为1xv411z7Se视频属性的抓取
# BV号为1xv411z7Se的视频属性抓取结束
# 开始BV号为1af4y1U7Vf视频属性的抓取
# BV号为1af4y1U7Vf的视频属性抓取结束
# 开始BV号为1FK411s7mx视频属性的抓取
# BV号为1FK411s7mx的视频属性抓取结束
# 开始BV号为1zZ4y1s7Ba视频属性的抓取
# BV号为1zZ4y1s7Ba的视频属性抓取结束
# 开始BV号为1ik4y167vJ视频属性的抓取
# BV号为1ik4y167vJ的视频属性抓取结束
# 开始BV号为1iV411C7ST视频属性的抓取
# BV号为1iV411C7ST的视频属性抓取结束
# 开始BV号为1Fi4y147Ub视频属性的抓取
# BV号为1Fi4y147Ub的视频属性抓取结束
# 开始BV号为1oi4y1x7Tw视频属性的抓取
# BV号为1oi4y1x7Tw的视频属性抓取结束
# 开始BV号为1uK411s74T视频属性的抓取
# BV号为1uK411s74T的视频属性抓取结束
# 开始BV号为1Pk4y1r7Mi视频属性的抓取
# BV号为1Pk4y1r7Mi的视频属性抓取结束
# 开始BV号为18A411q7bz视频属性的抓取
# BV号为18A411q7bz的视频属性抓取结束
# 开始BV号为1X5411s7tn视频属性的抓取
# BV号为1X5411s7tn的视频属性抓取结束
# 开始BV号为1P54y1Q7UG视频属性的抓取
# BV号为1P54y1Q7UG的视频属性抓取结束
# 开始BV号为1dT4y1u781视频属性的抓取
# BV号为1dT4y1u781的视频属性抓取结束
# 开始BV号为17A411t7px视频属性的抓取
# BV号为17A411t7px的视频属性抓取结束
# 开始BV号为15z4y1R7Fp视频属性的抓取
# BV号为15z4y1R7Fp的视频属性抓取结束
# 开始BV号为1Bz411q7g3视频属性的抓取
# BV号为1Bz411q7g3的视频属性抓取结束
# 开始BV号为1t5411s7pk视频属性的抓取
# BV号为1t5411s7pk的视频属性抓取结束
# 开始BV号为1Jv411z7JD视频属性的抓取
# BV号为1Jv411z7JD的视频属性抓取结束
# 开始BV号为1Bg4y1B79W视频属性的抓取
# BV号为1Bg4y1B79W的视频属性抓取结束
# 开始BV号为16K4y1t7p2视频属性的抓取
# BV号为16K4y1t7p2的视频属性抓取结束
# 开始BV号为1nK4y187BM视频属性的抓取
# BV号为1nK4y187BM的视频属性抓取结束
# 开始BV号为1YV411d7kJ视频属性的抓取
# BV号为1YV411d7kJ的视频属性抓取结束
# 开始BV号为1YC4y1p7zk视频属性的抓取
# BV号为1YC4y1p7zk的视频属性抓取结束
# 开始BV号为1wg4y1z711视频属性的抓取
# BV号为1wg4y1z711的视频属性抓取结束
# 开始BV号为1ve411p7FZ视频属性的抓取
# BV号为1ve411p7FZ的视频属性抓取结束
# 开始BV号为1dg4y1B7dd视频属性的抓取
# BV号为1dg4y1B7dd的视频属性抓取结束
# 开始BV号为18V411C7Dm视频属性的抓取
# BV号为18V411C7Dm的视频属性抓取结束
# 开始BV号为1jQ4y1P7Ac视频属性的抓取
# BV号为1jQ4y1P7Ac的视频属性抓取结束
# 开始BV号为1cQ4y1P75T视频属性的抓取
# BV号为1cQ4y1P75T的视频属性抓取结束
# 开始BV号为1oi4y1t7QZ视频属性的抓取
# BV号为1oi4y1t7QZ的视频属性抓取结束
# 开始BV号为1LA411q7DR视频属性的抓取
# BV号为1LA411q7DR的视频属性抓取结束
# 开始BV号为1pi4y147gG视频属性的抓取
# BV号为1pi4y147gG的视频属性抓取结束
# 开始BV号为1P54y1X73Q视频属性的抓取
# BV号为1P54y1X73Q的视频属性抓取结束
# 开始BV号为1Bi4y1s7oa视频属性的抓取
# BV号为1Bi4y1s7oa的视频属性抓取结束
# 开始BV号为1WC4y1p7X7视频属性的抓取
# BV号为1WC4y1p7X7的视频属性抓取结束
# 开始BV号为11p4y1972b视频属性的抓取
# BV号为11p4y1972b的视频属性抓取结束
# 开始BV号为1Za4y1i7WF视频属性的抓取
# BV号为1Za4y1i7WF的视频属性抓取结束
# 开始BV号为1Wp4y1Q7Su视频属性的抓取
# BV号为1Wp4y1Q7Su的视频属性抓取结束
# 开始BV号为1t54y1D7Px视频属性的抓取
# BV号为1t54y1D7Px的视频属性抓取结束
# 开始BV号为1sQ4y1P7p8视频属性的抓取
# BV号为1sQ4y1P7p8的视频属性抓取结束
# 开始BV号为1jK411s7xD视频属性的抓取
# BV号为1jK411s7xD的视频属性抓取结束
# 开始BV号为1h54y1X7L7视频属性的抓取
# BV号为1h54y1X7L7的视频属性抓取结束
# 开始BV号为1Ct4y1y7XX视频属性的抓取
# BV号为1Ct4y1y7XX的视频属性抓取结束
# 开始BV号为1LK4y1t7gP视频属性的抓取
# BV号为1LK4y1t7gP的视频属性抓取结束
# 开始BV号为1Bv411z7B4视频属性的抓取
# BV号为1Bv411z7B4的视频属性抓取结束
# 开始BV号为1Fi4y1t7Gh视频属性的抓取
# BV号为1Fi4y1t7Gh的视频属性抓取结束
# 开始BV号为1Gk4y167gb视频属性的抓取
# BV号为1Gk4y167gb的视频属性抓取结束
# 开始BV号为1Mp4y1X7RE视频属性的抓取
# BV号为1Mp4y1X7RE的视频属性抓取结束
# 开始BV号为1Yp4y1Q7Fp视频属性的抓取
# BV号为1Yp4y1Q7Fp的视频属性抓取结束
# 开始BV号为1iT4y13716视频属性的抓取
# BV号为1iT4y13716的视频属性抓取结束
# 开始BV号为19i4y1x7Ju视频属性的抓取
# BV号为19i4y1x7Ju的视频属性抓取结束
# 开始BV号为1JV411d7jG视频属性的抓取
# BV号为1JV411d7jG的视频属性抓取结束
# 开始BV号为1Yi4y1s7Rh视频属性的抓取
# BV号为1Yi4y1s7Rh的视频属性抓取结束
# 开始BV号为1u5411s7ax视频属性的抓取
# BV号为1u5411s7ax的视频属性抓取结束
# 开始BV号为1Pk4y1r7eD视频属性的抓取
# BV号为1Pk4y1r7eD的视频属性抓取结束
# 开始BV号为1AQ4y1P7Xx视频属性的抓取
# BV号为1AQ4y1P7Xx的视频属性抓取结束
# 开始BV号为1Yz4y1R7Ny视频属性的抓取
# BV号为1Yz4y1R7Ny的视频属性抓取结束
# 开始BV号为1TK4y187nW视频属性的抓取
# BV号为1TK4y187nW的视频属性抓取结束
# 开始BV号为16T4y137tp视频属性的抓取
# BV号为16T4y137tp的视频属性抓取结束
# 开始BV号为1RQ4y1A7S5视频属性的抓取
# BV号为1RQ4y1A7S5的视频属性抓取结束
# 开始BV号为12T4y1u7rz视频属性的抓取
# BV号为12T4y1u7rz的视频属性抓取结束
# 开始BV号为17z411q7h7视频属性的抓取
# BV号为17z411q7h7的视频属性抓取结束
# 开始BV号为1wa4y1i7GK视频属性的抓取
# BV号为1wa4y1i7GK的视频属性抓取结束
# 开始BV号为1f54y1D7LM视频属性的抓取
# BV号为1f54y1D7LM的视频属性抓取结束
# 开始BV号为1Ca4y1e7Zd视频属性的抓取
# BV号为1Ca4y1e7Zd的视频属性抓取结束
# 开始BV号为1PV411o7iG视频属性的抓取
# BV号为1PV411o7iG的视频属性抓取结束
# 开始BV号为1Tp4y1X7ge视频属性的抓取
# BV号为1Tp4y1X7ge的视频属性抓取结束
# 开始BV号为1sZ4y1s7Ym视频属性的抓取
# BV号为1sZ4y1s7Ym的视频属性抓取结束
# 开始BV号为16f4y1m7uP视频属性的抓取
# BV号为16f4y1m7uP的视频属性抓取结束
# 开始BV号为1A5411473W视频属性的抓取
# BV号为1A5411473W的视频属性抓取结束
# 开始BV号为1Ti4y1b7Kq视频属性的抓取
# BV号为1Ti4y1b7Kq的视频属性抓取结束
# 开始BV号为1hp4y197i3视频属性的抓取
# BV号为1hp4y197i3的视频属性抓取结束
# 开始BV号为1WC4y1p7we视频属性的抓取
# BV号为1WC4y1p7we的视频属性抓取结束
# 开始BV号为1ap4y1Q7CU视频属性的抓取
# BV号为1ap4y1Q7CU的视频属性抓取结束
# 开始BV号为1pa4y1e7EX视频属性的抓取
# BV号为1pa4y1e7EX的视频属性抓取结束
# 开始BV号为1c54y1Q7RC视频属性的抓取
# BV号为1c54y1Q7RC的视频属性抓取结束
# 开始BV号为1bT4y1u7bN视频属性的抓取
# BV号为1bT4y1u7bN的视频属性抓取结束
# 开始BV号为1kf4y1m7rW视频属性的抓取
# BV号为1kf4y1m7rW的视频属性抓取结束
# 开始BV号为17V411C7qu视频属性的抓取
# BV号为17V411C7qu的视频属性抓取结束
# 开始BV号为15i4y1b7zP视频属性的抓取
# BV号为15i4y1b7zP的视频属性抓取结束
# 开始BV号为1xk4y1679a视频属性的抓取
# BV号为1xk4y1679a的视频属性抓取结束
# 开始BV号为1CV411C7z7视频属性的抓取
# BV号为1CV411C7z7的视频属性抓取结束
# 开始BV号为1jK411W7LQ视频属性的抓取
# BV号为1jK411W7LQ的视频属性抓取结束
# 开始BV号为1KD4y1S7hk视频属性的抓取
# BV号为1KD4y1S7hk的视频属性抓取结束
# 开始BV号为15Z4y1H7jh视频属性的抓取
# BV号为15Z4y1H7jh的视频属性抓取结束
# 开始BV号为1mf4y1y76g视频属性的抓取
# BV号为1mf4y1y76g的视频属性抓取结束
# 开始BV号为1HT4y1J7N2视频属性的抓取
# BV号为1HT4y1J7N2的视频属性抓取结束
# 开始BV号为1qz411i7V8视频属性的抓取
# BV号为1qz411i7V8的视频属性抓取结束
# 开始BV号为1c5411W7hW视频属性的抓取
# BV号为1c5411W7hW的视频属性抓取结束
# 开始BV号为1Tf4y117Go视频属性的抓取
# BV号为1Tf4y117Go的视频属性抓取结束
# 开始BV号为1QA411q7iP视频属性的抓取
# BV号为1QA411q7iP的视频属性抓取结束
# 开始BV号为1Ta4y1e7ie视频属性的抓取
# BV号为1Ta4y1e7ie的视频属性抓取结束
# 开始BV号为1dC4y1h7at视频属性的抓取
# BV号为1dC4y1h7at的视频属性抓取结束
# 开始BV号为1XT4y1E7XP视频属性的抓取
# BV号为1XT4y1E7XP的视频属性抓取结束
# 开始BV号为11D4y1D7EB视频属性的抓取
# BV号为11D4y1D7EB的视频属性抓取结束
# 开始BV号为1wf4y117KQ视频属性的抓取
# BV号为1wf4y117KQ的视频属性抓取结束
# 开始BV号为1sg4y1v7Jg视频属性的抓取
# BV号为1sg4y1v7Jg的视频属性抓取结束
# 开始BV号为1VC4y1a7hm视频属性的抓取
# BV号为1VC4y1a7hm的视频属性抓取结束
# 开始BV号为1XC4y1a79V视频属性的抓取
# BV号为1XC4y1a79V的视频属性抓取结束
# 开始BV号为1nV411k7u3视频属性的抓取
# BV号为1nV411k7u3的视频属性抓取结束
# 开始BV号为1rK4y1x7pM视频属性的抓取
# BV号为1rK4y1x7pM的视频属性抓取结束
# 开始BV号为1W5411W7Gy视频属性的抓取
# BV号为1W5411W7Gy的视频属性抓取结束
# 开始BV号为1H54y1B7RG视频属性的抓取
# BV号为1H54y1B7RG的视频属性抓取结束
# 开始BV号为1Sg4y1i78B视频属性的抓取
# BV号为1Sg4y1i78B的视频属性抓取结束
# 开始BV号为13D4y1Q7uN视频属性的抓取
# BV号为13D4y1Q7uN的视频属性抓取结束
# 开始BV号为1Ep4y1D7Dz视频属性的抓取
# BV号为1Ep4y1D7Dz的视频属性抓取结束
# 开始BV号为18t4y1y73R视频属性的抓取
# BV号为18t4y1y73R的视频属性抓取结束
# 开始BV号为1ff4y1y7R8视频属性的抓取
# BV号为1ff4y1y7R8的视频属性抓取结束
# 开始BV号为1iK4y1x7T3视频属性的抓取
# BV号为1iK4y1x7T3的视频属性抓取结束
# 开始BV号为18K4y147mT视频属性的抓取
# BV号为18K4y147mT的视频属性抓取结束
# 开始BV号为1DK411p7rT视频属性的抓取
# BV号为1DK411p7rT的视频属性抓取结束
# 开始BV号为1eV411r7WZ视频属性的抓取
# BV号为1eV411r7WZ的视频属性抓取结束
# 开始BV号为1if4y1176d视频属性的抓取
# BV号为1if4y1176d的视频属性抓取结束
# 开始BV号为18p4y1U7rq视频属性的抓取
# BV号为18p4y1U7rq的视频属性抓取结束
# 开始BV号为1vK4y147H1视频属性的抓取
# BV号为1vK4y147H1的视频属性抓取结束
# 开始BV号为1Wa4y1Y7rG视频属性的抓取
# BV号为1Wa4y1Y7rG的视频属性抓取结束
# 开始BV号为1J5411W7Rt视频属性的抓取
# BV号为1J5411W7Rt的视频属性抓取结束
# 开始BV号为1mg4y1v7mN视频属性的抓取
# BV号为1mg4y1v7mN的视频属性抓取结束
# 开始BV号为1bK411p7CH视频属性的抓取
# BV号为1bK411p7CH的视频属性抓取结束
# 开始BV号为1Ma4y1e7Jo视频属性的抓取
# BV号为1Ma4y1e7Jo的视频属性抓取结束
# 开始BV号为1JD4y1Q7x9视频属性的抓取
# BV号为1JD4y1Q7x9的视频属性抓取结束
# 开始BV号为14z4y19733视频属性的抓取
# BV号为14z4y19733的视频属性抓取结束
# 开始BV号为1Ca4y1h7PT视频属性的抓取
# BV号为1Ca4y1h7PT的视频属性抓取结束
# 开始BV号为1Gi4y1x7rb视频属性的抓取
# BV号为1Gi4y1x7rb的视频属性抓取结束
# 开始BV号为1YT4y1J7uY视频属性的抓取
# BV号为1YT4y1J7uY的视频属性抓取结束
# 开始BV号为1154y1B7f1视频属性的抓取
# BV号为1154y1B7f1的视频属性抓取结束
# 开始BV号为1Mf4y1m7eC视频属性的抓取
# BV号为1Mf4y1m7eC的视频属性抓取结束
# 开始BV号为1nz4y1X7WX视频属性的抓取
# BV号为1nz4y1X7WX的视频属性抓取结束
# 开始BV号为1Li4y1G7DY视频属性的抓取
# BV号为1Li4y1G7DY的视频属性抓取结束
# 开始BV号为1XZ4y1H754视频属性的抓取
# BV号为1XZ4y1H754的视频属性抓取结束
# 开始BV号为19K411p7Cm视频属性的抓取
# BV号为19K411p7Cm的视频属性抓取结束
# 开始BV号为13a4y1Y72G视频属性的抓取
# BV号为13a4y1Y72G的视频属性抓取结束
# 开始BV号为1tv41167kh视频属性的抓取
# BV号为1tv41167kh的视频属性抓取结束
# 开始BV号为1Az4y1R7W6视频属性的抓取
# BV号为1Az4y1R7W6的视频属性抓取结束
# 开始BV号为1ef4y127qJ视频属性的抓取
# BV号为1ef4y127qJ的视频属性抓取结束
# 开始BV号为1GZ4y1H7hB视频属性的抓取
# BV号为1GZ4y1H7hB的视频属性抓取结束
# 开始BV号为1tC4y1a7sA视频属性的抓取
# BV号为1tC4y1a7sA的视频属性抓取结束
# 开始BV号为14k4y1q7bt视频属性的抓取
# BV号为14k4y1q7bt的视频属性抓取结束
# 开始BV号为1Kp4y1Q792视频属性的抓取
# BV号为1Kp4y1Q792的视频属性抓取结束
# 开始BV号为1vk4y1z7Wz视频属性的抓取
# BV号为1vk4y1z7Wz的视频属性抓取结束
# 开始BV号为1gT4y1J7jp视频属性的抓取
# BV号为1gT4y1J7jp的视频属性抓取结束
# 开始BV号为1yV411r7Py视频属性的抓取
# BV号为1yV411r7Py的视频属性抓取结束
# 开始BV号为1z54y1B7TS视频属性的抓取
# BV号为1z54y1B7TS的视频属性抓取结束
# 开始BV号为1JZ4y1W7tt视频属性的抓取
# BV号为1JZ4y1W7tt的视频属性抓取结束
# 开始BV号为13T4y1J7Ls视频属性的抓取
# BV号为13T4y1J7Ls的视频属性抓取结束
# 开始BV号为1E54y1z7Xd视频属性的抓取
# BV号为1E54y1z7Xd的视频属性抓取结束
# 开始BV号为1tv411B7bt视频属性的抓取
# BV号为1tv411B7bt的视频属性抓取结束
# 开始BV号为1ot4y197Mx视频属性的抓取
# BV号为1ot4y197Mx的视频属性抓取结束
# 开始BV号为1mt4y1X7mx视频属性的抓取
# BV号为1mt4y1X7mx的视频属性抓取结束
# 开始BV号为1kz4y197Ug视频属性的抓取
# BV号为1kz4y197Ug的视频属性抓取结束
# 开始BV号为1KC4y1h7zt视频属性的抓取
# BV号为1KC4y1h7zt的视频属性抓取结束
# 开始BV号为1Ek4y1z7pw视频属性的抓取
# BV号为1Ek4y1z7pw的视频属性抓取结束
# 开始BV号为1gt4y197WN视频属性的抓取
# BV号为1gt4y197WN的视频属性抓取结束
# 开始BV号为1Hi4y1G7Kq视频属性的抓取
# BV号为1Hi4y1G7Kq的视频属性抓取结束
# 开始BV号为1nK411p7GB视频属性的抓取
# BV号为1nK411p7GB的视频属性抓取结束
# 开始BV号为12Q4y1P7oa视频属性的抓取
# BV号为12Q4y1P7oa的视频属性抓取结束
# 开始BV号为1fz4y1Q7K6视频属性的抓取
# BV号为1fz4y1Q7K6的视频属性抓取结束
# 开始BV号为1MC4y1a7z2视频属性的抓取
# BV号为1MC4y1a7z2的视频属性抓取结束
# 开始BV号为1aT4y177Ma视频属性的抓取
# BV号为1aT4y177Ma的视频属性抓取结束
# 开始BV号为1Ek4y1r74x视频属性的抓取
# BV号为1Ek4y1r74x的视频属性抓取结束
# 开始BV号为1DC4y1h7DM视频属性的抓取
# BV号为1DC4y1h7DM的视频属性抓取结束
# 开始BV号为1sC4y1a7aQ视频属性的抓取
# BV号为1sC4y1a7aQ的视频属性抓取结束
# 开始BV号为1gz411i7mS视频属性的抓取
# BV号为1gz411i7mS的视频属性抓取结束
# 开始BV号为1KT4y1J7Bc视频属性的抓取
# BV号为1KT4y1J7Bc的视频属性抓取结束
# 开始BV号为1fC4y1h75S视频属性的抓取
# BV号为1fC4y1h75S的视频属性抓取结束
# 开始BV号为1Ci4y1s7Cq视频属性的抓取
# BV号为1Ci4y1s7Cq的视频属性抓取结束
# 开始BV号为1o54y1B7aH视频属性的抓取
# BV号为1o54y1B7aH的视频属性抓取结束
# 开始BV号为1Vk4y1z7zQ视频属性的抓取
# BV号为1Vk4y1z7zQ的视频属性抓取结束
# 开始BV号为1x5411W791视频属性的抓取
# BV号为1x5411W791的视频属性抓取结束
# 开始BV号为1Si4y1s7uV视频属性的抓取
# BV号为1Si4y1s7uV的视频属性抓取结束
# 开始BV号为1UC4y1h7Vr视频属性的抓取
# BV号为1UC4y1h7Vr的视频属性抓取结束
# 开始BV号为1GZ4y1H7eQ视频属性的抓取
# BV号为1GZ4y1H7eQ的视频属性抓取结束
# 开始BV号为1ei4y1G7vF视频属性的抓取
# BV号为1ei4y1G7vF的视频属性抓取结束
# 开始BV号为1KD4y1Q74F视频属性的抓取
# BV号为1KD4y1Q74F的视频属性抓取结束
# 开始BV号为1sa4y1Y7fR视频属性的抓取
# BV号为1sa4y1Y7fR的视频属性抓取结束
# 开始BV号为12Q4y1P7rb视频属性的抓取
# BV号为12Q4y1P7rb的视频属性抓取结束
# 开始BV号为16A411i7if视频属性的抓取
# BV号为16A411i7if的视频属性抓取结束
# 开始BV号为1H54y1Q73u视频属性的抓取
# BV号为1H54y1Q73u的视频属性抓取结束
# 开始BV号为19D4y1D7s8视频属性的抓取
# BV号为19D4y1D7s8的视频属性抓取结束
# 开始BV号为1Yt4y1y76C视频属性的抓取
# BV号为1Yt4y1y76C的视频属性抓取结束
# 开始BV号为1ZV411C76c视频属性的抓取
# BV号为1ZV411C76c的视频属性抓取结束
# 开始BV号为1vZ4y1H7L4视频属性的抓取
# BV号为1vZ4y1H7L4的视频属性抓取结束
# 开始BV号为1Bz411i78v视频属性的抓取
# BV号为1Bz411i78v的视频属性抓取结束
# 开始BV号为1JT4y1E7mE视频属性的抓取
# BV号为1JT4y1E7mE的视频属性抓取结束
# 开始BV号为1Xt4y197yg视频属性的抓取
# BV号为1Xt4y197yg的视频属性抓取结束
# 开始BV号为16C4y1h7Rc视频属性的抓取
# BV号为16C4y1h7Rc的视频属性抓取结束
# 开始BV号为1p5411e7F6视频属性的抓取
# BV号为1p5411e7F6的视频属性抓取结束
# 开始BV号为1Jg4y1i7eP视频属性的抓取
# BV号为1Jg4y1i7eP的视频属性抓取结束
# 开始BV号为1Uk4y127VH视频属性的抓取
# BV号为1Uk4y127VH的视频属性抓取结束
# 开始BV号为15g4y1i7mq视频属性的抓取
# BV号为15g4y1i7mq的视频属性抓取结束
# 开始BV号为1Ra4y1E7GR视频属性的抓取
# BV号为1Ra4y1E7GR的视频属性抓取结束
# 开始BV号为1qa4y1a7eo视频属性的抓取
# BV号为1qa4y1a7eo的视频属性抓取结束
# 开始BV号为1Cz4y1D7Cf视频属性的抓取
# BV号为1Cz4y1D7Cf的视频属性抓取结束
# 开始BV号为1tp4y1i7zf视频属性的抓取
# BV号为1tp4y1i7zf的视频属性抓取结束
# 开始BV号为1jf4y117mN视频属性的抓取
# BV号为1jf4y117mN的视频属性抓取结束
# 开始BV号为1xC4y1b7qW视频属性的抓取
# BV号为1xC4y1b7qW的视频属性抓取结束
# 开始BV号为1Bt4y1Q76H视频属性的抓取
# BV号为1Bt4y1Q76H的视频属性抓取结束
# 开始BV号为1m54y1v7ZB视频属性的抓取
# BV号为1m54y1v7ZB的视频属性抓取结束
# 开始BV号为1Nf4y1d72j视频属性的抓取
# BV号为1Nf4y1d72j的视频属性抓取结束
# 开始BV号为1SZ4y1u74X视频属性的抓取
# BV号为1SZ4y1u74X的视频属性抓取结束
# 开始BV号为1DT4y1771p视频属性的抓取
# BV号为1DT4y1771p的视频属性抓取结束
# 开始BV号为1fZ4y1H7rg视频属性的抓取
# BV号为1fZ4y1H7rg的视频属性抓取结束
# 开始BV号为1HA411v7Ui视频属性的抓取
# BV号为1HA411v7Ui的视频属性抓取结束
# 开始BV号为1Pv411q7LW视频属性的抓取
# BV号为1Pv411q7LW的视频属性抓取结束
# 开始BV号为1r54y1S7mT视频属性的抓取
# BV号为1r54y1S7mT的视频属性抓取结束
# 开始BV号为1MC4y1b7yt视频属性的抓取
# BV号为1MC4y1b7yt的视频属性抓取结束
# 开始BV号为16D4y1S7pe视频属性的抓取
# BV号为16D4y1S7pe的视频属性抓取结束
# 开始BV号为1XT4y177H3视频属性的抓取
# BV号为1XT4y177H3的视频属性抓取结束
# 开始BV号为1Hf4y1R7Z6视频属性的抓取
# BV号为1Hf4y1R7Z6的视频属性抓取结束
# 开始BV号为1gC4y1b7ta视频属性的抓取
# BV号为1gC4y1b7ta的视频属性抓取结束
# 开始BV号为18A411v7rk视频属性的抓取
# BV号为18A411v7rk的视频属性抓取结束
# 开始BV号为1dg4y1v74o视频属性的抓取
# BV号为1dg4y1v74o的视频属性抓取结束
# 开始BV号为1KZ4y1g75L视频属性的抓取
# BV号为1KZ4y1g75L的视频属性抓取结束
# 开始BV号为1V5411a7xv视频属性的抓取
# BV号为1V5411a7xv的视频属性抓取结束
# 开始BV号为1Zt4y1Q7Qt视频属性的抓取
# BV号为1Zt4y1Q7Qt的视频属性抓取结束
# 开始BV号为1Na4y1e7na视频属性的抓取
# BV号为1Na4y1e7na的视频属性抓取结束
# 开始BV号为1pi4y1V7cp视频属性的抓取
# BV号为1pi4y1V7cp的视频属性抓取结束
# 开始BV号为1y54y1q7vn视频属性的抓取
# BV号为1y54y1q7vn的视频属性抓取结束
# 开始BV号为15T4y1E769视频属性的抓取
# BV号为15T4y1E769的视频属性抓取结束
# 开始BV号为1rK4y1s7yX视频属性的抓取
# BV号为1rK4y1s7yX的视频属性抓取结束
# 开始BV号为1hA411e7Rt视频属性的抓取
# BV号为1hA411e7Rt的视频属性抓取结束
# 开始BV号为1fK411n75Z视频属性的抓取
# BV号为1fK411n75Z的视频属性抓取结束
# 开始BV号为14i4y1G7YE视频属性的抓取
# BV号为14i4y1G7YE的视频属性抓取结束
# 开始BV号为12z4y1X7B2视频属性的抓取
# BV号为12z4y1X7B2的视频属性抓取结束
# 开始BV号为1tk4y1B7jU视频属性的抓取
# BV号为1tk4y1B7jU的视频属性抓取结束
# 开始BV号为1Ct4y197q9视频属性的抓取
# BV号为1Ct4y197q9的视频属性抓取结束
# 开始BV号为1ak4y1m7E5视频属性的抓取
# BV号为1ak4y1m7E5的视频属性抓取结束
# 开始BV号为1mk4y1q7gy视频属性的抓取
# BV号为1mk4y1q7gy的视频属性抓取结束
# 开始BV号为1TK4y1x78F视频属性的抓取
# BV号为1TK4y1x78F的视频属性抓取结束
# 开始BV号为1oA411a7oS视频属性的抓取
# BV号为1oA411a7oS的视频属性抓取结束
# 开始BV号为1Ki4y137hL视频属性的抓取
# BV号为1Ki4y137hL的视频属性抓取结束
# 开始BV号为1dK4y1s7Gf视频属性的抓取
# BV号为1dK4y1s7Gf的视频属性抓取结束
# 开始BV号为1ez4y1X7hR视频属性的抓取
# BV号为1ez4y1X7hR的视频属性抓取结束
# 开始BV号为1CK4y1s7hQ视频属性的抓取
# BV号为1CK4y1s7hQ的视频属性抓取结束
# 开始BV号为1eK411H7Hq视频属性的抓取
# BV号为1eK411H7Hq的视频属性抓取结束
# 开始BV号为1ri4y137LE视频属性的抓取
# BV号为1ri4y137LE的视频属性抓取结束
# 开始BV号为1yA411e7yu视频属性的抓取
# BV号为1yA411e7yu的视频属性抓取结束
# 开始BV号为14f4y1R7CQ视频属性的抓取
# BV号为14f4y1R7CQ的视频属性抓取结束
# 开始BV号为1qk4y1m7eh视频属性的抓取
# BV号为1qk4y1m7eh的视频属性抓取结束
# 开始BV号为1wT4y1E7CP视频属性的抓取
# BV号为1wT4y1E7CP的视频属性抓取结束
# 开始BV号为1gZ4y1u7Yw视频属性的抓取
# BV号为1gZ4y1u7Yw的视频属性抓取结束
# 开始BV号为1mK4y1s7JA视频属性的抓取
# BV号为1mK4y1s7JA的视频属性抓取结束
# 开始BV号为1Sv411i7Tv视频属性的抓取
# BV号为1Sv411i7Tv的视频属性抓取结束
# 开始BV号为1c54y1S7xt视频属性的抓取
# BV号为1c54y1S7xt的视频属性抓取结束
# 开始BV号为1uZ4y1g7EW视频属性的抓取
# BV号为1uZ4y1g7EW的视频属性抓取结束
# 开始BV号为17v411B7Wy视频属性的抓取
# BV号为17v411B7Wy的视频属性抓取结束
# 开始BV号为1Pk4y1m7Pe视频属性的抓取
# BV号为1Pk4y1m7Pe的视频属性抓取结束
# 开始BV号为1mp4y1i7zc视频属性的抓取
# BV号为1mp4y1i7zc的视频属性抓取结束
# 开始BV号为1gC4y1h7A3视频属性的抓取
# BV号为1gC4y1h7A3的视频属性抓取结束
# 开始BV号为1VC4y1b7b2视频属性的抓取
# BV号为1VC4y1b7b2的视频属性抓取结束
# 开始BV号为1WK411H78i视频属性的抓取
# BV号为1WK411H78i的视频属性抓取结束
# 开始BV号为1Kt4y1X7RN视频属性的抓取
# BV号为1Kt4y1X7RN的视频属性抓取结束
# 开始BV号为18f4y1R7EQ视频属性的抓取
# BV号为18f4y1R7EQ的视频属性抓取结束
# 开始BV号为1qT4y1j78E视频属性的抓取
# BV号为1qT4y1j78E的视频属性抓取结束
# 开始BV号为1e54y1q7Zj视频属性的抓取
# BV号为1e54y1q7Zj的视频属性抓取结束
# 开始BV号为1Lv411q7yf视频属性的抓取
# BV号为1Lv411q7yf的视频属性抓取结束
# 开始BV号为1u5411e7kw视频属性的抓取
# BV号为1u5411e7kw的视频属性抓取结束
# 开始BV号为1eK411J7ZL视频属性的抓取
# BV号为1eK411J7ZL的视频属性抓取结束
# 开始BV号为1ji4y1V7pQ视频属性的抓取
# BV号为1ji4y1V7pQ的视频属性抓取结束
# 开始BV号为1jT4y177Tm视频属性的抓取
# BV号为1jT4y177Tm的视频属性抓取结束
# 开始BV号为1J5411e79k视频属性的抓取
# BV号为1J5411e79k的视频属性抓取结束
# 开始BV号为1P5411e7mE视频属性的抓取
# BV号为1P5411e7mE的视频属性抓取结束
# 开始BV号为1Y5411Y7D9视频属性的抓取
# BV号为1Y5411Y7D9的视频属性抓取结束
# 开始BV号为1Gz4y1D7k1视频属性的抓取
# BV号为1Gz4y1D7k1的视频属性抓取结束
# 开始BV号为1bK4y1x71x视频属性的抓取
# BV号为1bK4y1x71x的视频属性抓取结束
# 开始BV号为1sT4y1j7C1视频属性的抓取
# BV号为1sT4y1j7C1的视频属性抓取结束
# 开始BV号为1Pk4y1B76o视频属性的抓取
# BV号为1Pk4y1B76o的视频属性抓取结束
# 开始BV号为1df4y197dS视频属性的抓取
# BV号为1df4y197dS的视频属性抓取结束
# 开始BV号为1pi4y1V7Rq视频属性的抓取
# BV号为1pi4y1V7Rq的视频属性抓取结束
# 开始BV号为1hD4y1U77j视频属性的抓取
# BV号为1hD4y1U77j的视频属性抓取结束
# 开始BV号为13K4y1v7y1视频属性的抓取
# BV号为13K4y1v7y1的视频属性抓取结束
# 开始BV号为1FZ4y1u76V视频属性的抓取
# BV号为1FZ4y1u76V的视频属性抓取结束
# 开始BV号为1ha4y1a71W视频属性的抓取
# BV号为1ha4y1a71W的视频属性抓取结束
# 开始BV号为1Nf4y1R7Xe视频属性的抓取
# BV号为1Nf4y1R7Xe的视频属性抓取结束
# 开始BV号为1e54y1S74D视频属性的抓取
# BV号为1e54y1S74D的视频属性抓取结束
# 开始BV号为1nK411J7rj视频属性的抓取
# BV号为1nK411J7rj的视频属性抓取结束
# 开始BV号为1Mh411Z7VE视频属性的抓取
# BV号为1Mh411Z7VE的视频属性抓取结束
# 开始BV号为1jT4y1E7Fe视频属性的抓取
# BV号为1jT4y1E7Fe的视频属性抓取结束
# 开始BV号为1UA411e7Tw视频属性的抓取
# BV号为1UA411e7Tw的视频属性抓取结束
# 开始BV号为1zp4y1S7vr视频属性的抓取
# BV号为1zp4y1S7vr的视频属性抓取结束
# 开始BV号为1qi4y137Se视频属性的抓取
# BV号为1qi4y137Se的视频属性抓取结束
# 开始BV号为1o5411h7ju视频属性的抓取
# BV号为1o5411h7ju的视频属性抓取结束
# 开始BV号为18Z4y1u763视频属性的抓取
# BV号为18Z4y1u763的视频属性抓取结束
# 开始BV号为1ZZ4y1K7C2视频属性的抓取
# BV号为1ZZ4y1K7C2的视频属性抓取结束
# 开始BV号为1WC4y1t7B3视频属性的抓取
# BV号为1WC4y1t7B3的视频属性抓取结束
# 开始BV号为1hh411Z77H视频属性的抓取
# BV号为1hh411Z77H的视频属性抓取结束
# 开始BV号为1Vp4y1i7ig视频属性的抓取
# BV号为1Vp4y1i7ig的视频属性抓取结束
# 开始BV号为1654y1e74H视频属性的抓取
# BV号为1654y1e74H的视频属性抓取结束
# 开始BV号为17D4y1m76i视频属性的抓取
# BV号为17D4y1m76i的视频属性抓取结束
# 开始BV号为1WV411S7Aj视频属性的抓取
# BV号为1WV411S7Aj的视频属性抓取结束
# 开始BV号为1Z541187SD视频属性的抓取
# BV号为1Z541187SD的视频属性抓取结束
# 开始BV号为1P5411h7bK视频属性的抓取
# BV号为1P5411h7bK的视频属性抓取结束
# 开始BV号为1gT4y177L6视频属性的抓取
# BV号为1gT4y177L6的视频属性抓取结束
# 开始BV号为1C54y1i78s视频属性的抓取
# BV号为1C54y1i78s的视频属性抓取结束
# 开始BV号为1Ap4y1v7wF视频属性的抓取
# BV号为1Ap4y1v7wF的视频属性抓取结束
# 开始BV号为1eA411Y7aa视频属性的抓取
# BV号为1eA411Y7aa的视频属性抓取结束
# 开始BV号为1GT4y177HW视频属性的抓取
# BV号为1GT4y177HW的视频属性抓取结束
# 开始BV号为1mK411T7Nf视频属性的抓取
# BV号为1mK411T7Nf的视频属性抓取结束
# 开始BV号为1tv41117Bk视频属性的抓取
# BV号为1tv41117Bk的视频属性抓取结束
# 开始BV号为1xK4y1Y7yw视频属性的抓取
# BV号为1xK4y1Y7yw的视频属性抓取结束
# 开始BV号为1ZK4y1Y7XX视频属性的抓取
# BV号为1ZK4y1Y7XX的视频属性抓取结束
# 开始BV号为1w64y1F79x视频属性的抓取
# BV号为1w64y1F79x的视频属性抓取结束
# 开始BV号为1p5411h7Zc视频属性的抓取
# BV号为1p5411h7Zc的视频属性抓取结束
# 开始BV号为1zC4y1t77J视频属性的抓取
# BV号为1zC4y1t77J的视频属性抓取结束
# 开始BV号为19K4y1Y7UU视频属性的抓取
# BV号为19K4y1Y7UU的视频属性抓取结束
# 开始BV号为1eA411Y7QW视频属性的抓取
# BV号为1eA411Y7QW的视频属性抓取结束
# 开始BV号为1Bp4y1q7Mx视频属性的抓取
# BV号为1Bp4y1q7Mx的视频属性抓取结束
# 开始BV号为1AA411e7LB视频属性的抓取
# BV号为1AA411e7LB的视频属性抓取结束
# 开始BV号为19v411v78C视频属性的抓取
# BV号为19v411v78C的视频属性抓取结束
# 开始BV号为18f4y19764视频属性的抓取
# BV号为18f4y19764的视频属性抓取结束
# 开始BV号为1yv411q7SD视频属性的抓取
# BV号为1yv411q7SD的视频属性抓取结束
# 开始BV号为1Mp4y1i79F视频属性的抓取
# BV号为1Mp4y1i79F的视频属性抓取结束
# 开始BV号为1SK4y1v7jV视频属性的抓取
# BV号为1SK4y1v7jV的视频属性抓取结束
# 开始BV号为1Tv41117M4视频属性的抓取
# BV号为1Tv41117M4的视频属性抓取结束
# 开始BV号为1vk4y1m78Y视频属性的抓取
# BV号为1vk4y1m78Y的视频属性抓取结束
# 开始BV号为1AC4y1t7Ka视频属性的抓取
# BV号为1AC4y1t7Ka的视频属性抓取结束
# 开始BV号为1uZ4y1K74X视频属性的抓取
# BV号为1uZ4y1K74X的视频属性抓取结束
# 开始BV号为1Uk4y1m7s4视频属性的抓取
# BV号为1Uk4y1m7s4的视频属性抓取结束
# 开始BV号为1DA411n7aU视频属性的抓取
# BV号为1DA411n7aU的视频属性抓取结束
# 开始BV号为1qi4y1g7eb视频属性的抓取
# BV号为1qi4y1g7eb的视频属性抓取结束
# 开始BV号为1cD4y1S75a视频属性的抓取
# BV号为1cD4y1S75a的视频属性抓取结束
# 开始BV号为1s54y127gY视频属性的抓取
# BV号为1s54y127gY的视频属性抓取结束
# 开始BV号为1Ga4y1E7WD视频属性的抓取
# BV号为1Ga4y1E7WD的视频属性抓取结束
# 开始BV号为1oZ4y1K7aS视频属性的抓取
# BV号为1oZ4y1K7aS的视频属性抓取结束
# 开始BV号为1P54y1i7nn视频属性的抓取
# BV号为1P54y1i7nn的视频属性抓取结束
# 开始BV号为1g54y1U7yF视频属性的抓取
# BV号为1g54y1U7yF的视频属性抓取结束
# 开始BV号为1gp4y1v7a8视频属性的抓取
# BV号为1gp4y1v7a8的视频属性抓取结束
# 开始BV号为1bk4y127Ku视频属性的抓取
# BV号为1bk4y127Ku的视频属性抓取结束
# 开始BV号为1wi4y1g7tv视频属性的抓取
# BV号为1wi4y1g7tv的视频属性抓取结束
# 开始BV号为1H54y1v74b视频属性的抓取
# BV号为1H54y1v74b的视频属性抓取结束
# 开始BV号为1Sv411y7Gy视频属性的抓取
# BV号为1Sv411y7Gy的视频属性抓取结束
# 开始BV号为1Bv411y76Y视频属性的抓取
# BV号为1Bv411y76Y的视频属性抓取结束
# 开始BV号为1sa4y177zp视频属性的抓取
# BV号为1sa4y177zp的视频属性抓取结束
# 开始BV号为11Z4y1M7Cu视频属性的抓取
# BV号为11Z4y1M7Cu的视频属性抓取结束
# 开始BV号为1754y127L9视频属性的抓取
# BV号为1754y127L9的视频属性抓取结束
# 开始BV号为1Jv411i7xU视频属性的抓取
# BV号为1Jv411i7xU的视频属性抓取结束
# 开始BV号为1xh411d7fP视频属性的抓取
# BV号为1xh411d7fP的视频属性抓取结束
# 开始BV号为1kK411T7Xy视频属性的抓取
# BV号为1kK411T7Xy的视频属性抓取结束
# 开始BV号为1hv411v7PK视频属性的抓取
# BV号为1hv411v7PK的视频属性抓取结束
# 开始BV号为1W64y1c7KD视频属性的抓取
# BV号为1W64y1c7KD的视频属性抓取结束
# 开始BV号为1rv411y7sh视频属性的抓取
# BV号为1rv411y7sh的视频属性抓取结束
# 开始BV号为1bD4y1m7c3视频属性的抓取
# BV号为1bD4y1m7c3的视频属性抓取结束
# 开始BV号为1VV411U7dA视频属性的抓取
# BV号为1VV411U7dA的视频属性抓取结束
# 开始BV号为1zz4y1f77p视频属性的抓取
# BV号为1zz4y1f77p的视频属性抓取结束
# 开始BV号为12D4y1U7mf视频属性的抓取
# BV号为12D4y1U7mf的视频属性抓取结束
# 开始BV号为1o54y1e7Yr视频属性的抓取
# BV号为1o54y1e7Yr的视频属性抓取结束
# 开始BV号为1nf4y197LT视频属性的抓取
# BV号为1nf4y197LT的视频属性抓取结束
# 开始BV号为1Dh411d7g8视频属性的抓取
# BV号为1Dh411d7g8的视频属性抓取结束
# 开始BV号为1Vp4y1q7Lv视频属性的抓取
# BV号为1Vp4y1q7Lv的视频属性抓取结束
# 开始BV号为1Hp4y1v7op视频属性的抓取
# BV号为1Hp4y1v7op的视频属性抓取结束
# 开始BV号为1RZ4y1K75G视频属性的抓取
# BV号为1RZ4y1K75G的视频属性抓取结束
# 开始BV号为1Rp4y1Y7gB视频属性的抓取
# BV号为1Rp4y1Y7gB的视频属性抓取结束
# 开始BV号为1up4y1v7cx视频属性的抓取
# BV号为1up4y1v7cx的视频属性抓取结束
# 开始BV号为1JA411Y7tS视频属性的抓取
# BV号为1JA411Y7tS的视频属性抓取结束
# 开始BV号为1GV411S7br视频属性的抓取
# BV号为1GV411S7br的视频属性抓取结束
# 开始BV号为1B54y1U7ze视频属性的抓取
# BV号为1B54y1U7ze的视频属性抓取结束
# 开始BV号为1nZ4y1M7Xv视频属性的抓取
# BV号为1nZ4y1M7Xv的视频属性抓取结束
# 开始BV号为1KC4y187y5视频属性的抓取
# BV号为1KC4y187y5的视频属性抓取结束
# 开始BV号为1Kp4y1v7PC视频属性的抓取
# BV号为1Kp4y1v7PC的视频属性抓取结束
# 开始BV号为1mz4y1f7DF视频属性的抓取
# BV号为1mz4y1f7DF的视频属性抓取结束
# 开始BV号为18v411v7S1视频属性的抓取
# BV号为18v411v7S1的视频属性抓取结束
# 开始BV号为1xT4y1j7zG视频属性的抓取
# BV号为1xT4y1j7zG的视频属性抓取结束
# 开始BV号为1Lz4y1Q7PE视频属性的抓取
# BV号为1Lz4y1Q7PE的视频属性抓取结束
# 开始BV号为1nt4y1S7U5视频属性的抓取
# BV号为1nt4y1S7U5的视频属性抓取结束
# 开始BV号为16t4y1U7bx视频属性的抓取
# BV号为16t4y1U7bx的视频属性抓取结束
# 开始BV号为1yT4y1j7g8视频属性的抓取
# BV号为1yT4y1j7g8的视频属性抓取结束
# 开始BV号为1cv411i7Jc视频属性的抓取
# BV号为1cv411i7Jc的视频属性抓取结束
# 开始BV号为1y54y1e79v视频属性的抓取
# BV号为1y54y1e79v的视频属性抓取结束
# 开始BV号为1PC4y1t7r8视频属性的抓取
# BV号为1PC4y1t7r8的视频属性抓取结束
# 开始BV号为12T4y1w7oi视频属性的抓取
# BV号为12T4y1w7oi的视频属性抓取结束
# 开始BV号为1qf4y197km视频属性的抓取
# BV号为1qf4y197km的视频属性抓取结束
# 开始BV号为1iD4y127jd视频属性的抓取
# BV号为1iD4y127jd的视频属性抓取结束
# 开始BV号为1gk4y127fD视频属性的抓取
# BV号为1gk4y127fD的视频属性抓取结束
# 开始BV号为1KK411n7tj视频属性的抓取
# BV号为1KK411n7tj的视频属性抓取结束
# 开始BV号为1M54y1i7Qk视频属性的抓取
# BV号为1M54y1i7Qk的视频属性抓取结束
# 开始BV号为13h411d7hF视频属性的抓取
# BV号为13h411d7hF的视频属性抓取结束
# 开始BV号为19D4y1U7wD视频属性的抓取
# BV号为19D4y1U7wD的视频属性抓取结束
# 开始BV号为15t4y1Q76R视频属性的抓取
# BV号为15t4y1Q76R的视频属性抓取结束
# 开始BV号为1RA411J7cK视频属性的抓取
# BV号为1RA411J7cK的视频属性抓取结束
# 开始BV号为1A64y1c7qv视频属性的抓取
# BV号为1A64y1c7qv的视频属性抓取结束
# 开始BV号为1zt4y1U7Qf视频属性的抓取
# BV号为1zt4y1U7Qf的视频属性抓取结束
# 开始BV号为1FZ4y1M7Ni视频属性的抓取
# BV号为1FZ4y1M7Ni的视频属性抓取结束
# 开始BV号为15K411K7Cm视频属性的抓取
# BV号为15K411K7Cm的视频属性抓取结束
# 开始BV号为1qh411R7Fu视频属性的抓取
# BV号为1qh411R7Fu的视频属性抓取结束
# 开始BV号为1xh411X7mZ视频属性的抓取
# BV号为1xh411X7mZ的视频属性抓取结束
# 开始BV号为1fK4y1a7Hs视频属性的抓取
# BV号为1fK4y1a7Hs的视频属性抓取结束
# 开始BV号为1464y1F7pZ视频属性的抓取
# BV号为1464y1F7pZ的视频属性抓取结束
# 开始BV号为1tt4y1q7Jb视频属性的抓取
# BV号为1tt4y1q7Jb的视频属性抓取结束
# 开始BV号为1R5411b79P视频属性的抓取
# BV号为1R5411b79P的视频属性抓取结束
# 开始BV号为18K411P7R1视频属性的抓取
# BV号为18K411P7R1的视频属性抓取结束
# 开始BV号为1Ty4y1y7V3视频属性的抓取
# BV号为1Ty4y1y7V3的视频属性抓取结束
# 开始BV号为1454y1k7ED视频属性的抓取
# BV号为1454y1k7ED的视频属性抓取结束
# 开始BV号为1P54y117oS视频属性的抓取
# BV号为1P54y117oS的视频属性抓取结束
# 开始BV号为1UV41127Pc视频属性的抓取
# BV号为1UV41127Pc的视频属性抓取结束
# 开始BV号为1uv411y7N5视频属性的抓取
# BV号为1uv411y7N5的视频属性抓取结束
# 开始BV号为1Zp4y1Y7nx视频属性的抓取
# BV号为1Zp4y1Y7nx的视频属性抓取结束
# 开始BV号为1QD4y1o7uA视频属性的抓取
# BV号为1QD4y1o7uA的视频属性抓取结束
# 开始BV号为1d54y1y7KV视频属性的抓取
# BV号为1d54y1y7KV的视频属性抓取结束
# 开始BV号为1KZ4y1N7sv视频属性的抓取
# BV号为1KZ4y1N7sv的视频属性抓取结束
# 开始BV号为17A411J7bd视频属性的抓取
# BV号为17A411J7bd的视频属性抓取结束
# 开始BV号为1M541187Ju视频属性的抓取
# BV号为1M541187Ju的视频属性抓取结束
# 开始BV号为1154y117q1视频属性的抓取
# BV号为1154y117q1的视频属性抓取结束
# 开始BV号为1gT4y1A7rV视频属性的抓取
# BV号为1gT4y1A7rV的视频属性抓取结束
# 开始BV号为1yK4y1a7qq视频属性的抓取
# BV号为1yK4y1a7qq的视频属性抓取结束
# 开始BV号为1d5411b7fS视频属性的抓取
# BV号为1d5411b7fS的视频属性抓取结束
# 开始BV号为1Dz4y1f7am视频属性的抓取
# BV号为1Dz4y1f7am的视频属性抓取结束
# 开始BV号为1A54y1y7sZ视频属性的抓取
# BV号为1A54y1y7sZ的视频属性抓取结束
# 开始BV号为1VZ4y1N7Pi视频属性的抓取
# BV号为1VZ4y1N7Pi的视频属性抓取结束
# 开始BV号为1dV41127VM视频属性的抓取
# BV号为1dV41127VM的视频属性抓取结束
# 开始BV号为1et4y1i7nn视频属性的抓取
# BV号为1et4y1i7nn的视频属性抓取结束
# 开始BV号为1ky4y1C7Nt视频属性的抓取
# BV号为1ky4y1C7Nt的视频属性抓取结束
# 开始BV号为1PA411J7mT视频属性的抓取
# BV号为1PA411J7mT的视频属性抓取结束
# 开始BV号为1mt4y1i7Jp视频属性的抓取
# BV号为1mt4y1i7Jp的视频属性抓取结束
# 开始BV号为16K4y187Tr视频属性的抓取
# BV号为16K4y187Tr的视频属性抓取结束
# 开始BV号为16p4y1e7gi视频属性的抓取
# BV号为16p4y1e7gi的视频属性抓取结束
# 开始BV号为1rv411C7Tk视频属性的抓取
# BV号为1rv411C7Tk的视频属性抓取结束
# 开始BV号为1F54y1y75a视频属性的抓取
# BV号为1F54y1y75a的视频属性抓取结束
# 开始BV号为1hV41117mp视频属性的抓取
# BV号为1hV41117mp的视频属性抓取结束
# 开始BV号为1Xk4y1k7Zs视频属性的抓取
# BV号为1Xk4y1k7Zs的视频属性抓取结束
# 开始BV号为1Ai4y1E7YK视频属性的抓取
# BV号为1Ai4y1E7YK的视频属性抓取结束
# 开始BV号为1F54y1v7cH视频属性的抓取
# BV号为1F54y1v7cH的视频属性抓取结束
# 开始BV号为1Qk4y1y7GS视频属性的抓取
# BV号为1Qk4y1y7GS的视频属性抓取结束
# 开始BV号为1tD4y1o7tK视频属性的抓取
# BV号为1tD4y1o7tK的视频属性抓取结束
# 开始BV号为1DZ4y1K7PP视频属性的抓取
# BV号为1DZ4y1K7PP的视频属性抓取结束
# 开始BV号为1JA411J7bw视频属性的抓取
# BV号为1JA411J7bw的视频属性抓取结束
# 开始BV号为19h411R77T视频属性的抓取
# BV号为19h411R77T的视频属性抓取结束
# 开始BV号为1UK411N7Z2视频属性的抓取
# BV号为1UK411N7Z2的视频属性抓取结束
# 开始BV号为1jh411X7np视频属性的抓取
# BV号为1jh411X7np的视频属性抓取结束
# 开始BV号为1hD4y1m7iM视频属性的抓取
# BV号为1hD4y1m7iM的视频属性抓取结束
# 开始BV号为1it4y1i77s视频属性的抓取
# BV号为1it4y1i77s的视频属性抓取结束
# 开始BV号为1gi4y1E7Mu视频属性的抓取
# BV号为1gi4y1E7Mu的视频属性抓取结束
# 开始BV号为1NA411H7FW视频属性的抓取
# BV号为1NA411H7FW的视频属性抓取结束
# 开始BV号为1fp4y1e7aZ视频属性的抓取
# BV号为1fp4y1e7aZ的视频属性抓取结束
# 开始BV号为1gK4y1a7bm视频属性的抓取
# BV号为1gK4y1a7bm的视频属性抓取结束
# 开始BV号为1Xf4y1Q7Aj视频属性的抓取
# BV号为1Xf4y1Q7Aj的视频属性抓取结束
# 开始BV号为1354y1y7q3视频属性的抓取
# BV号为1354y1y7q3的视频属性抓取结束
# 开始BV号为1Rt4y1i7ow视频属性的抓取
# BV号为1Rt4y1i7ow的视频属性抓取结束
# 开始BV号为1Ra4y1L72t视频属性的抓取
# BV号为1Ra4y1L72t的视频属性抓取结束
# 开始BV号为1TK4y1Y7nw视频属性的抓取
# BV号为1TK4y1Y7nw的视频属性抓取结束
# 开始BV号为1ui4y1u7Wy视频属性的抓取
# BV号为1ui4y1u7Wy的视频属性抓取结束
# 开始BV号为1ZV411m7iN视频属性的抓取
# BV号为1ZV411m7iN的视频属性抓取结束
# 开始BV号为1pK411K74p视频属性的抓取
# BV号为1pK411K74p的视频属性抓取结束
# 开始BV号为1Yp4y1a7XZ视频属性的抓取
# BV号为1Yp4y1a7XZ的视频属性抓取结束
# 开始BV号为1y5411b7zT视频属性的抓取
# BV号为1y5411b7zT的视频属性抓取结束
# 开始BV号为16a4y1j71V视频属性的抓取
# BV号为16a4y1j71V的视频属性抓取结束
# 开始BV号为1Bz4y1Z7XX视频属性的抓取
# BV号为1Bz4y1Z7XX的视频属性抓取结束
# 开始BV号为1QT4y1L7yH视频属性的抓取
# BV号为1QT4y1L7yH的视频属性抓取结束
# 开始BV号为1nA411J7zc视频属性的抓取
# BV号为1nA411J7zc的视频属性抓取结束
# 开始BV号为12p4y1Y7hd视频属性的抓取
# BV号为12p4y1Y7hd的视频属性抓取结束
# 开始BV号为1Av411y7dk视频属性的抓取
# BV号为1Av411y7dk的视频属性抓取结束
# 开始BV号为16K4y18754视频属性的抓取
# BV号为16K4y18754的视频属性抓取结束
# 开始BV号为18y4y1k7AT视频属性的抓取
# BV号为18y4y1k7AT的视频属性抓取结束
# 开始BV号为1oA411n7Gr视频属性的抓取
# BV号为1oA411n7Gr的视频属性抓取结束
# 开始BV号为1AC4y1b7cJ视频属性的抓取
# BV号为1AC4y1b7cJ的视频属性抓取结束
# 开始BV号为1GK411K7aY视频属性的抓取
# BV号为1GK411K7aY的视频属性抓取结束
# 开始BV号为1H54y127zP视频属性的抓取
# BV号为1H54y127zP的视频属性抓取结束
# 开始BV号为1Yf4y1D7M2视频属性的抓取
# BV号为1Yf4y1D7M2的视频属性抓取结束
# 开始BV号为14y4y1k7wv视频属性的抓取
# BV号为14y4y1k7wv的视频属性抓取结束
# 开始BV号为1iK411P7YG视频属性的抓取
# BV号为1iK411P7YG的视频属性抓取结束
# 开始BV号为1ZZ4y1N7ek视频属性的抓取
# BV号为1ZZ4y1N7ek的视频属性抓取结束
# 开始BV号为1hy4y1y7Fq视频属性的抓取
# BV号为1hy4y1y7Fq的视频属性抓取结束
# 开始BV号为1Cy4y1k78W视频属性的抓取
# BV号为1Cy4y1k78W的视频属性抓取结束
# 开始BV号为1sD4y1o7UT视频属性的抓取
# BV号为1sD4y1o7UT的视频属性抓取结束
# 开始BV号为1gi4y1E7eY视频属性的抓取
# BV号为1gi4y1E7eY的视频属性抓取结束
# 开始BV号为1vA411J7EC视频属性的抓取
# BV号为1vA411J7EC的视频属性抓取结束
# 开始BV号为1Bk4y127vX视频属性的抓取
# BV号为1Bk4y127vX的视频属性抓取结束
# 开始BV号为1C54y127rJ视频属性的抓取
# BV号为1C54y127rJ的视频属性抓取结束
# 开始BV号为1954y1y7mX视频属性的抓取
# BV号为1954y1y7mX的视频属性抓取结束
# 开始BV号为1rA411J7U7视频属性的抓取
# BV号为1rA411J7U7的视频属性抓取结束
# 开始BV号为1fz4y1Z7mN视频属性的抓取
# BV号为1fz4y1Z7mN的视频属性抓取结束
# 开始BV号为1C54y127C1视频属性的抓取
# BV号为1C54y127C1的视频属性抓取结束
# 开始BV号为1Ta4y1E7sY视频属性的抓取
# BV号为1Ta4y1E7sY的视频属性抓取结束
# 开始BV号为1154y1y7iv视频属性的抓取
# BV号为1154y1y7iv的视频属性抓取结束
# 开始BV号为1zi4y1E7rZ视频属性的抓取
# BV号为1zi4y1E7rZ的视频属性抓取结束
# 开始BV号为1DK411K7TU视频属性的抓取
# BV号为1DK411K7TU的视频属性抓取结束
# 开始BV号为17p4y1e7ZC视频属性的抓取
# BV号为17p4y1e7ZC的视频属性抓取结束
# 开始BV号为16K411K7T7视频属性的抓取
# BV号为16K411K7T7的视频属性抓取结束
# 开始BV号为1oh41197QH视频属性的抓取
# BV号为1oh41197QH的视频属性抓取结束
# 开始BV号为1Ba4y157o1视频属性的抓取
# BV号为1Ba4y157o1的视频属性抓取结束
# 开始BV号为1DZ4y1P7y7视频属性的抓取
# BV号为1DZ4y1P7y7的视频属性抓取结束
# 开始BV号为1wZ4y1N7qT视频属性的抓取
# BV号为1wZ4y1N7qT的视频属性抓取结束
# 开始BV号为1Sv41117gU视频属性的抓取
# BV号为1Sv41117gU的视频属性抓取结束
# 开始BV号为1ff4y1D71b视频属性的抓取
# BV号为1ff4y1D71b的视频属性抓取结束
# 开始BV号为1EZ4y1V7ne视频属性的抓取
# BV号为1EZ4y1V7ne的视频属性抓取结束
# 开始BV号为1zA41177FQ视频属性的抓取
# BV号为1zA41177FQ的视频属性抓取结束
# 开始BV号为1ya411A7Jx视频属性的抓取
# BV号为1ya411A7Jx的视频属性抓取结束
# 开始BV号为1KK4y1E7jN视频属性的抓取
# BV号为1KK4y1E7jN的视频属性抓取结束
# 开始BV号为1PV41127KD视频属性的抓取
# BV号为1PV41127KD的视频属性抓取结束
# 开始BV号为1TZ4y1L7bp视频属性的抓取
# BV号为1TZ4y1L7bp的视频属性抓取结束
# 开始BV号为1ut4y1i7aH视频属性的抓取
# BV号为1ut4y1i7aH的视频属性抓取结束
# 开始BV号为1LV411y7BF视频属性的抓取
# BV号为1LV411y7BF的视频属性抓取结束
# 开始BV号为1Y54y1R7x3视频属性的抓取
# BV号为1Y54y1R7x3的视频属性抓取结束
# 开始BV号为1D5411j7Jg视频属性的抓取
# BV号为1D5411j7Jg的视频属性抓取结束
# 开始BV号为1N541177DW视频属性的抓取
# BV号为1N541177DW的视频属性抓取结束
# 开始BV号为1XA411L7Wm视频属性的抓取
# BV号为1XA411L7Wm的视频属性抓取结束
# 开始BV号为1Y54y1r7ux视频属性的抓取
# BV号为1Y54y1r7ux的视频属性抓取结束
# 开始BV号为1QK4y177yX视频属性的抓取
# BV号为1QK4y177yX的视频属性抓取结束
# 开始BV号为1MK411A7g3视频属性的抓取
# BV号为1MK411A7g3的视频属性抓取结束
# 开始BV号为17K4y1h7Li视频属性的抓取
# BV号为17K4y1h7Li的视频属性抓取结束
# 开始BV号为1zV411y7Pw视频属性的抓取
# BV号为1zV411y7Pw的视频属性抓取结束
# 开始BV号为1Lt4y1i7wW视频属性的抓取
# BV号为1Lt4y1i7wW的视频属性抓取结束
# 开始BV号为1B54y1k7SB视频属性的抓取
# BV号为1B54y1k7SB的视频属性抓取结束
# 开始BV号为1pi4y1j7z3视频属性的抓取
# BV号为1pi4y1j7z3的视频属性抓取结束
# 开始BV号为1VA41177qg视频属性的抓取
# BV号为1VA41177qg的视频属性抓取结束
# 开始BV号为1Qr4y1c7RR视频属性的抓取
# BV号为1Qr4y1c7RR的视频属性抓取结束
# 开始BV号为1sD4y197Hf视频属性的抓取
# BV号为1sD4y197Hf的视频属性抓取结束
# 开始BV号为1qA411J7ya视频属性的抓取
# BV号为1qA411J7ya的视频属性抓取结束
# 开始BV号为1bf4y1i75Y视频属性的抓取
# BV号为1bf4y1i75Y的视频属性抓取结束
# 开始BV号为1R541157gG视频属性的抓取
# BV号为1R541157gG的视频属性抓取结束
# 开始BV号为15k4y1C7dF视频属性的抓取
# BV号为15k4y1C7dF的视频属性抓取结束
# 开始BV号为1hK4y1h7if视频属性的抓取
# BV号为1hK4y1h7if的视频属性抓取结束
# 开始BV号为1Ei4y1j7LF视频属性的抓取
# BV号为1Ei4y1j7LF的视频属性抓取结束
# 开始BV号为1S541157Ak视频属性的抓取
# BV号为1S541157Ak的视频属性抓取结束
# 开始BV号为1Ci4y1E7XU视频属性的抓取
# BV号为1Ci4y1E7XU的视频属性抓取结束
# 开始BV号为1cA411j7bV视频属性的抓取
# BV号为1cA411j7bV的视频属性抓取结束
# 开始BV号为1GK411N7y1视频属性的抓取
# BV号为1GK411N7y1的视频属性抓取结束
# 开始BV号为1AT4y1w7wZ视频属性的抓取
# BV号为1AT4y1w7wZ的视频属性抓取结束
# 开始BV号为1DK4y1f7YU视频属性的抓取
# BV号为1DK4y1f7YU的视频属性抓取结束
# 开始BV号为1qz4y1d7n8视频属性的抓取
# BV号为1qz4y1d7n8的视频属性抓取结束
# 开始BV号为1ay4y1r7Qy视频属性的抓取
# BV号为1ay4y1r7Qy的视频属性抓取结束
# 开始BV号为1Cp4y1r7Wb视频属性的抓取
# BV号为1Cp4y1r7Wb的视频属性抓取结束
# 开始BV号为1vK411N7eg视频属性的抓取
# BV号为1vK411N7eg的视频属性抓取结束
# 开始BV号为1HZ4y157oZ视频属性的抓取
# BV号为1HZ4y157oZ的视频属性抓取结束
# 开始BV号为1gv411C7qW视频属性的抓取
# BV号为1gv411C7qW的视频属性抓取结束
# 开始BV号为1AZ4y1L7hX视频属性的抓取
# BV号为1AZ4y1L7hX的视频属性抓取结束
# 开始BV号为1mz4y1d7wK视频属性的抓取
# BV号为1mz4y1d7wK的视频属性抓取结束
# 开始BV号为1y54y1R7Ae视频属性的抓取
# BV号为1y54y1R7Ae的视频属性抓取结束
# 开始BV号为1MD4y1d7Gr视频属性的抓取
# BV号为1MD4y1d7Gr的视频属性抓取结束
# 开始BV号为1n54y1r7Qk视频属性的抓取
# BV号为1n54y1r7Qk的视频属性抓取结束
# 开始BV号为1bD4y1d7Bj视频属性的抓取
# BV号为1bD4y1d7Bj的视频属性抓取结束
# 开始BV号为1Ji4y1E7Ln视频属性的抓取
# BV号为1Ji4y1E7Ln的视频属性抓取结束
# 开始BV号为11p4y1r7mx视频属性的抓取
# BV号为11p4y1r7mx的视频属性抓取结束
# 开始BV号为1fK411w798视频属性的抓取
# BV号为1fK411w798的视频属性抓取结束
# 开始BV号为1k54y1y7vg视频属性的抓取
# BV号为1k54y1y7vg的视频属性抓取结束
# 开始BV号为14K411N7vg视频属性的抓取
# BV号为14K411N7vg的视频属性抓取结束
# 开始BV号为1Ea411A7fu视频属性的抓取
# BV号为1Ea411A7fu的视频属性抓取结束
# 开始BV号为1yi4y1E7v4视频属性的抓取
# BV号为1yi4y1E7v4的视频属性抓取结束
# 开始BV号为1x54y1k7vy视频属性的抓取
# BV号为1x54y1k7vy的视频属性抓取结束
# 开始BV号为1Qz4y1Z7EY视频属性的抓取
# BV号为1Qz4y1Z7EY的视频属性抓取结束
# 开始BV号为1B54y1k7CL视频属性的抓取
# BV号为1B54y1k7CL的视频属性抓取结束
# 开始BV号为1xZ4y1L7zM视频属性的抓取
# BV号为1xZ4y1L7zM的视频属性抓取结束
# 开始BV号为15v411y77M视频属性的抓取
# BV号为15v411y77M的视频属性抓取结束
# 开始BV号为1Rz4y1d78j视频属性的抓取
# BV号为1Rz4y1d78j的视频属性抓取结束
# 开始BV号为1xD4y1R72E视频属性的抓取
# BV号为1xD4y1R72E的视频属性抓取结束
# 开始BV号为11z4y1d7gE视频属性的抓取
# BV号为11z4y1d7gE的视频属性抓取结束
# 开始BV号为1rV41127J8视频属性的抓取
# BV号为1rV41127J8的视频属性抓取结束
# 开始BV号为1zA41177eW视频属性的抓取
# BV号为1zA41177eW的视频属性抓取结束
# 开始BV号为1WD4y1d75m视频属性的抓取
# BV号为1WD4y1d75m的视频属性抓取结束
# 开始BV号为1154y1k7p9视频属性的抓取
# BV号为1154y1k7p9的视频属性抓取结束
# 开始BV号为1g54y1C7xc视频属性的抓取
# BV号为1g54y1C7xc的视频属性抓取结束
# 开始BV号为1cz4y1o7qq视频属性的抓取
# BV号为1cz4y1o7qq的视频属性抓取结束
# 开始BV号为1sD4y197ft视频属性的抓取
# BV号为1sD4y197ft的视频属性抓取结束
# 开始BV号为1va4y15729视频属性的抓取
# 开始BV号为1va4y15729视频属性的抓取
# 开始BV号为1va4y15729视频属性的抓取
# 开始BV号为1va4y15729视频属性的抓取
# BV号为1va4y15729的视频属性抓取结束
# 开始BV号为1354y127Xu视频属性的抓取
# BV号为1354y127Xu的视频属性抓取结束
# 开始BV号为1Mz4y1f71Z视频属性的抓取
# BV号为1Mz4y1f71Z的视频属性抓取结束
# 开始BV号为13i4y177HS视频属性的抓取
# BV号为13i4y177HS的视频属性抓取结束
# 开始BV号为1j54y1k7we视频属性的抓取
# BV号为1j54y1k7we的视频属性抓取结束
# 开始BV号为1Mf4y1z7eK视频属性的抓取
# BV号为1Mf4y1z7eK的视频属性抓取结束
# 开始BV号为1MT4y1F7Tw视频属性的抓取
# BV号为1MT4y1F7Tw的视频属性抓取结束
# 开始BV号为1ZZ4y1G7eM视频属性的抓取
# BV号为1ZZ4y1G7eM的视频属性抓取结束
# 开始BV号为1GZ4y1V7er视频属性的抓取
# BV号为1GZ4y1V7er的视频属性抓取结束
# 开始BV号为1RZ4y157Tt视频属性的抓取
# BV号为1RZ4y157Tt的视频属性抓取结束
# 开始BV号为1P54y1C73Z视频属性的抓取
# BV号为1P54y1C73Z的视频属性抓取结束
# 开始BV号为1jz4y1o7Wp视频属性的抓取
# BV号为1jz4y1o7Wp的视频属性抓取结束
# 开始BV号为1gV411y7G6视频属性的抓取
# BV号为1gV411y7G6的视频属性抓取结束
# 开始BV号为1fh411X7jZ视频属性的抓取
# BV号为1fh411X7jZ的视频属性抓取结束
# 开始BV号为1xV41127wd视频属性的抓取
# BV号为1xV41127wd的视频属性抓取结束
# 开始BV号为1J54y1C7Ch视频属性的抓取
# BV号为1J54y1C7Ch的视频属性抓取结束
# 开始BV号为12a411w7SM视频属性的抓取
# BV号为12a411w7SM的视频属性抓取结束
# 开始BV号为1nK411A7Bn视频属性的抓取
# BV号为1nK411A7Bn的视频属性抓取结束
# 开始BV号为1z5411574Y视频属性的抓取
# BV号为1z5411574Y的视频属性抓取结束
# 开始BV号为1M54y127zU视频属性的抓取
# BV号为1M54y127zU的视频属性抓取结束
# 开始BV号为17i4y177LE视频属性的抓取
# BV号为17i4y177LE的视频属性抓取结束
# 开始BV号为1ny4y1C7qK视频属性的抓取
# BV号为1ny4y1C7qK的视频属性抓取结束
# 开始BV号为1s54y1k7Kc视频属性的抓取
# BV号为1s54y1k7Kc的视频属性抓取结束
# 开始BV号为1SA411L7vU视频属性的抓取
# BV号为1SA411L7vU的视频属性抓取结束
# 开始BV号为1q54y1R7wP视频属性的抓取
# BV号为1q54y1R7wP的视频属性抓取结束
# 开始BV号为1da4y1W7JM视频属性的抓取
# BV号为1da4y1W7JM的视频属性抓取结束
# 开始BV号为1Mp4y1Y7g3视频属性的抓取
# BV号为1Mp4y1Y7g3的视频属性抓取结束
# 开始BV号为1aV41127Ay视频属性的抓取
# BV号为1aV41127Ay的视频属性抓取结束
# 开始BV号为1jK411A7ZW视频属性的抓取
# BV号为1jK411A7ZW的视频属性抓取结束
# 开始BV号为1qK4y1h7F5视频属性的抓取
# BV号为1qK4y1h7F5的视频属性抓取结束
# 开始BV号为1Zp4y1r794视频属性的抓取
# BV号为1Zp4y1r794的视频属性抓取结束
# 2020-12-24 03:42:09.515503

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-15-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_youxi_dianzi.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 4月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月   100  100  100  100  100  100   100
# 2月   100  100  100  100  100  100   100
# 3月    99   99   99   99   99   99    99
# 4月   100  100  100  100  100  100   100
# 5月   100  100  100  100  100  100   100
# 6月   100  100  100  100  100  100   100
# 7月   100  100  100  100  100  100   100
# 8月   100  100  100  100  100  100   100
# 9月   100  100  100  100  100  100   100

# %%
channel_youxi_dianzi.to_json('channel_youxi_dianzi.json')

# %%
pd.set_option('display.max_rows', None)

# %%
channel_youxi_dianzi
# Out:
#             时间           作者名  作者类型     粉丝数   投稿数  \
# 1mJ411G7ue  1月          英雄联盟  机构认证  226.3万  2657
# 1eJ411V7r3  1月       酥酥的十年铁粉     无    4.4万   149
# 1T7411v7xL  1月      活在梦里的苍凌灏     无    6301    62
# 1TJ411H7Hb  1月    哔哩哔哩英雄联盟赛事  机构认证  690.2万  2601
# 1D7411a7TE  1月  整活专家---mata川     无    1458     4
# 1W7411a7QB  1月          罗汉解说  个人认证  261.6万    65
# 1LJ411L7Tj  1月        上网为了喷人     无     449     3
# 1S7411B76x  1月          罗汉解说  个人认证  261.6万    65
# 1m7411678Q  1月           捉长歌     无    5600    18
# 1H7411e7rf  1月      神奇的老皮VFX  个人认证  214.9万   107
# 15J411E71m  1月     想做唱见区的北韬韬  个人认证   12.5万   256
# 15J411E76S  1月         我是TOO  个人认证   47.5万   143
# 1Z7411v7Fy  1月          靠谱电竞  个人认证  216.6万   268
# 1C7411r7si  1月         无敌皮皮鸟  个人认证   99.7万   477
# 1L7411v7wx  1月         香菇滑鸡_  个人认证     33万   219
# 1cJ411j7Cj  1月         司马大食堂  个人认证   18.3万   646
# 1n7411r7sb  1月      歌者文明-二向箔  个人认证   10.1万   160
#
#                                               视频名  分区   子分区  视频类型 自制or转载  \
# 1mJ411G7ue                  【英雄联盟】战士 – 2020赛季CG动画  游戏  电子竞技  普通视频     自制
# 1eJ411V7r3                                 你 再 骂？  游戏  电子竞技  普通视频     自制
# 1T7411v7xL                      这就是**舔狗吗？真是有够搞笑的。  游戏  电子竞技  普通视频     转载
# 1TJ411H7Hb                【LPL春季赛】1月13日 IG vs FPX  游戏  电子竞技  普通视频     自制
# 1D7411a7TE                       ** 人 现 实 中 的 样 子  游戏  电子竞技  普通视频     转载
# 1W7411a7QB              【罗汉鬼套路】拯救ADC最骚套路 把LOL玩成CF  游戏  电子竞技  普通视频     自制
# 1LJ411L7Tj                              不可以哦 不可以哦  游戏  电子竞技  普通视频     转载
# 1S7411B76x               【罗汉鬼套路】大虫子最脏套路 miamiamia  游戏  电子竞技  普通视频     自制
# 1m7411678Q           讨厌大司马的人，这个视频打破你们对大司马实力的全部误解！  游戏  电子竞技  活动作品     自制
# 1H7411e7rf                         史上最沙雕【真人CS:GO】  游戏  电子竞技  普通视频     自制
# 15J411E71m                     无加成usp单刷巨人城.......  游戏  电子竞技  活动作品     自制
# 15J411E76S                拳头我来了，发了这个，会被英雄联盟全球通缉吗？  游戏  电子竞技  普通视频     自制
# 1Z7411v7Fy  靠谱盘点71：郎才女貌？澡子哥直播公开撮合周淑怡和猫皇，我同意了，你们呢？  游戏  电子竞技  普通视频     自制
# 1C7411r7si          王者皮一下：2019年度篇，那些让人笑到窒息的经典名场面！  游戏  电子竞技  活动作品     自制
# 1L7411v7wx            云顶之弈圆梦： 三星 拉克丝 ，我终于完成了你们的梦想  游戏  电子竞技  活动作品     自制
# 1cJ411j7Cj                  大司马真的菜吗？这个视频足以让你颠覆认知！  游戏  电子竞技  活动作品     自制
# 1n7411r7sb      【快乐白给30】茄子直播把儿子吓哭了！小茄子：你个闸总，吓死我了！  游戏  电子竞技  活动作品     自制
#
#                                                            标签   视频长度     播放量  \
# 1mJ411G7ue     [英雄联盟, 游戏, 电子竞技, 电子竞技, LOL, 英雄联盟LOL, CG动画, CG]  03:21  991.0万
# 1eJ411V7r3              [英雄联盟, 游戏, 电子竞技, 电子竞技, 酥酥, LOL, 直播录像]  01:51  727.9万
# 1T7411v7xL              [英雄联盟, 搞笑, 游戏, 电子竞技, 电子竞技, LOL, 搞笑视频]  01:36  559.8万
# 1TJ411H7Hb                  [LPL, 英雄联盟, 游戏, 电子竞技, 游戏赛事, 电子竞技]  07:19  511.2万
# 1D7411a7TE               [英雄联盟, 搞笑, 游戏, 电子竞技, 电子竞技, 娱乐, 查看图片]  00:35  460.9万
# 1W7411a7QB     [英雄联盟, 游戏, 电子竞技, 电子竞技, 罗汉鬼套路, 罗汉解说, LOL, 虚空之女]  08:13  456.1万
# 1LJ411L7Tj                    [英雄联盟, 游戏, 电子竞技, 电子竞技, 小米粥, 黄色]  00:09  412.9万
# 1S7411B76x      [英雄联盟, 游戏, 电子竞技, 电子竞技, LOL, 罗汉鬼套路, 罗汉解说, 大虫子]  07:11  405.0万
# 1m7411678Q  [芜湖大司马, 英雄联盟, 游戏, 电子竞技, 电子竞技, 大司马, LOL, 全能打卡挑战...  04:54  386.9万
# 1H7411e7rf   [反恐精英, CS:GO, 搞笑, 游戏, 电子竞技, 电子竞技, csgo, 特效, FPS]  03:53  366.3万
# 15J411E71m  [穿越火线, 游戏, 电子竞技, 电子竞技, bilibili新星计划, CF, 挑战, usp]  08:14  354.0万
# 15J411E76S  [云顶之弈, 英雄联盟, 搞笑, 游戏, 电子竞技, 电子竞技, LOL, 解说, 原创, ...  05:53  326.7万
# 1Z7411v7Fy  [FPX, LPL, 英雄联盟, 搞笑, 游戏, 电子竞技, 游戏赛事, 电子竞技, Uzi...  11:41  294.8万
# 1C7411r7si  [游戏集锦, 王者荣耀, 搞笑, 游戏, 电子竞技, 电子竞技, 手机游戏, 有团就有聚，过...  39:31  273.4万
# 1L7411v7wx    [游戏, 电子竞技, 电子竞技, 三星光辉, 香菇滑鸡, 云顶之奕, 全能打卡挑战, 拉克丝]  07:14  262.3万
# 1cJ411j7Cj  [芜湖大司马, 英雄联盟, 游戏, 电子竞技, 电子竞技, 马老师, 2019新人嘉年华, ...  05:07  256.8万
# 1n7411r7sb  [茄子, CS:GO, 搞笑, 游戏, 电子竞技, 电子竞技, CSGO, 游戏视频, 网络...  04:09  250.8万
#
#               点赞数    投币数    收藏数    转发数    评论数   弹幕数 有无分集
# 1mJ411G7ue  47.0万  51.1万  30.6万  19.9万  23869  3.2万    否
# 1eJ411V7r3  12.8万   3.1万   5.6万   2.1万   5350  1.8万    否
# 1T7411v7xL  11.8万   1.4万   4.9万   6.3万   9006  8369    否
# 1TJ411H7Hb   5.8万   2.6万   1.8万   9945  11408  8.4万    是
# 1D7411a7TE   8.0万   2428   1.7万   8776   2986  1257    否
# 1W7411a7QB  43.1万  38.1万   9.6万   1.7万   6824  3.1万    否
# 1LJ411L7Tj   3.5万   2781   2.1万   7520    925   769    否
# 1S7411B76x  22.2万  12.8万   4.0万   2.3万   6448  1.4万    否
# 1m7411678Q  33.6万   8.0万   4.8万   2.2万  11417  1.6万    否
# 1H7411e7rf  32.0万  23.8万   9.4万   4.4万   2516  5693    否
# 15J411E71m  50.9万  56.5万   9.7万   8039   6466  2.8万    否
# 15J411E76S  39.2万  34.8万  10.8万   3.7万   5217  8377    否
# 1Z7411v7Fy  32.0万  39.7万   9.0万   7410   3449  1.3万    否
# 1C7411r7si  16.5万   8.4万   8.2万   5.7万   1643  4.8万    否
# 1L7411v7wx  27.2万  31.2万   6.3万   3.0万   3023  1.2万    否
# 1cJ411j7Cj   7.8万   2.4万   2.6万   1.9万   6471  8209    否
# 1n7411r7sb  12.3万   1.3万   1.6万   3785    681  1.0万    否
