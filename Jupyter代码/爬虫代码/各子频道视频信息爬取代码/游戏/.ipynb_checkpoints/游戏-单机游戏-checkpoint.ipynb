# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_youxi_danji=pd.DataFrame(columns=columns)
channel_youxi_danji
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[6]/div/a/span').click()  #选择“游戏”频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[6]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '游戏'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[2]/a').click()  #选择“单机游戏”子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[2]/a').text
sub_channel
# Out:
# '单机游戏'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(4,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, 700)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_youxi_danji.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,100).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-23 09:40:19.520201
# <ipython-input-15-b70ffab2a594>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-15-b70ffab2a594>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-15-b70ffab2a594>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1L64y1M7Dp视频属性的抓取
# BV号为1L64y1M7Dp的视频属性抓取结束
# <ipython-input-15-b70ffab2a594>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为18K41157Tu视频属性的抓取
# BV号为18K41157Tu的视频属性抓取结束
# 开始BV号为1PT4y1G7ME视频属性的抓取
# BV号为1PT4y1G7ME的视频属性抓取结束
# 开始BV号为1S54y197uX视频属性的抓取
# BV号为1S54y197uX的视频属性抓取结束
# 开始BV号为1ti4y1t7YM视频属性的抓取
# BV号为1ti4y1t7YM的视频属性抓取结束
# 开始BV号为1Ai4y1b7ET视频属性的抓取
# BV号为1Ai4y1b7ET的视频属性抓取结束
# 开始BV号为1fe411x7FA视频属性的抓取
# BV号为1fe411x7FA的视频属性抓取结束
# 开始BV号为1LA411b7Dt视频属性的抓取
# BV号为1LA411b7Dt的视频属性抓取结束
# 开始BV号为1Lz411z72u视频属性的抓取
# BV号为1Lz411z72u的视频属性抓取结束
# 开始BV号为1Ji4y1t7T9视频属性的抓取
# BV号为1Ji4y1t7T9的视频属性抓取结束
# 开始BV号为13T4y1G7WT视频属性的抓取
# BV号为13T4y1G7WT的视频属性抓取结束
# 开始BV号为1T54y197DH视频属性的抓取
# BV号为1T54y197DH的视频属性抓取结束
# 开始BV号为1Va4y147fH视频属性的抓取
# BV号为1Va4y147fH的视频属性抓取结束
# 开始BV号为1tt4y127yy视频属性的抓取
# BV号为1tt4y127yy的视频属性抓取结束
# 开始BV号为16T4y1g7RY视频属性的抓取
# BV号为16T4y1g7RY的视频属性抓取结束
# 开始BV号为1754y197Da视频属性的抓取
# BV号为1754y197Da的视频属性抓取结束
# 开始BV号为1P54y197Ru视频属性的抓取
# BV号为1P54y197Ru的视频属性抓取结束
# 开始BV号为1eK411L7Qb视频属性的抓取
# BV号为1eK411L7Qb的视频属性抓取结束
# 开始BV号为1Ap4y197G8视频属性的抓取
# BV号为1Ap4y197G8的视频属性抓取结束
# 开始BV号为1hK41157M3视频属性的抓取
# BV号为1hK41157M3的视频属性抓取结束
# 开始BV号为1Np4y197vB视频属性的抓取
# BV号为1Np4y197vB的视频属性抓取结束
# 开始BV号为1Rk4y197kw视频属性的抓取
# BV号为1Rk4y197kw的视频属性抓取结束
# 开始BV号为1ST4y1G7E1视频属性的抓取
# BV号为1ST4y1G7E1的视频属性抓取结束
# 开始BV号为1H54y1d76B视频属性的抓取
# BV号为1H54y1d76B的视频属性抓取结束
# 开始BV号为1Sz411B7P4视频属性的抓取
# BV号为1Sz411B7P4的视频属性抓取结束
# 开始BV号为1CT4y1g7Ya视频属性的抓取
# BV号为1CT4y1g7Ya的视频属性抓取结束
# 开始BV号为12T4y1G7AZ视频属性的抓取
# BV号为12T4y1G7AZ的视频属性抓取结束
# 开始BV号为1b5411x79t视频属性的抓取
# BV号为1b5411x79t的视频属性抓取结束
# 开始BV号为1hA411h7Ky视频属性的抓取
# BV号为1hA411h7Ky的视频属性抓取结束
# 开始BV号为1Fz41187eM视频属性的抓取
# BV号为1Fz41187eM的视频属性抓取结束
# 开始BV号为13f4y1S7sa视频属性的抓取
# BV号为13f4y1S7sa的视频属性抓取结束
# 开始BV号为1Gt4y127AJ视频属性的抓取
# BV号为1Gt4y127AJ的视频属性抓取结束
# 开始BV号为1Jg4y1z7RH视频属性的抓取
# BV号为1Jg4y1z7RH的视频属性抓取结束
# 开始BV号为1Qk4y197ft视频属性的抓取
# BV号为1Qk4y197ft的视频属性抓取结束
# 开始BV号为1zp4y1C7N1视频属性的抓取
# BV号为1zp4y1C7N1的视频属性抓取结束
# 开始BV号为1iK411L7G5视频属性的抓取
# BV号为1iK411L7G5的视频属性抓取结束
# 开始BV号为1D5411x74c视频属性的抓取
# BV号为1D5411x74c的视频属性抓取结束
# 开始BV号为1Dk4y197gX视频属性的抓取
# BV号为1Dk4y197gX的视频属性抓取结束
# 开始BV号为1ak4y197sR视频属性的抓取
# BV号为1ak4y197sR的视频属性抓取结束
# 开始BV号为1Lz411z77G视频属性的抓取
# BV号为1Lz411z77G的视频属性抓取结束
# 开始BV号为1UQ4y1K7rL视频属性的抓取
# BV号为1UQ4y1K7rL的视频属性抓取结束
# 开始BV号为1AT4y137qe视频属性的抓取
# BV号为1AT4y137qe的视频属性抓取结束
# 开始BV号为1J64y1u7Ua视频属性的抓取
# BV号为1J64y1u7Ua的视频属性抓取结束
# 开始BV号为1cf4y1S7GJ视频属性的抓取
# BV号为1cf4y1S7GJ的视频属性抓取结束
# 开始BV号为1zp4y1X741视频属性的抓取
# BV号为1zp4y1X741的视频属性抓取结束
# 开始BV号为1f54y1974w视频属性的抓取
# BV号为1f54y1974w的视频属性抓取结束
# 开始BV号为1XC4y1p79x视频属性的抓取
# BV号为1XC4y1p79x的视频属性抓取结束
# 开始BV号为16z411B7AS视频属性的抓取
# BV号为16z411B7AS的视频属性抓取结束
# 开始BV号为1yg4y187yh视频属性的抓取
# BV号为1yg4y187yh的视频属性抓取结束
# 开始BV号为1kk4y1r77Y视频属性的抓取
# BV号为1kk4y1r77Y的视频属性抓取结束
# 开始BV号为1tp4y1C7ZD视频属性的抓取
# BV号为1tp4y1C7ZD的视频属性抓取结束
# 开始BV号为1vf4y1S7nN视频属性的抓取
# BV号为1vf4y1S7nN的视频属性抓取结束
# 开始BV号为1r5411t7vN视频属性的抓取
# BV号为1r5411t7vN的视频属性抓取结束
# 开始BV号为1EC4y1W7Jn视频属性的抓取
# BV号为1EC4y1W7Jn的视频属性抓取结束
# 开始BV号为15z411z7F1视频属性的抓取
# BV号为15z411z7F1的视频属性抓取结束
# 开始BV号为1mk4y1R7PP视频属性的抓取
# BV号为1mk4y1R7PP的视频属性抓取结束
# 开始BV号为1oQ4y1K7PC视频属性的抓取
# BV号为1oQ4y1K7PC的视频属性抓取结束
# 开始BV号为1ep4y1C7Av视频属性的抓取
# BV号为1ep4y1C7Av的视频属性抓取结束
# 开始BV号为1eQ4y1K7yU视频属性的抓取
# BV号为1eQ4y1K7yU的视频属性抓取结束
# 开始BV号为16K411L7jb视频属性的抓取
# BV号为16K411L7jb的视频属性抓取结束
# 开始BV号为1mk4y1R7PP视频属性的抓取
# BV号为1mk4y1R7PP的视频属性抓取结束
# 开始BV号为1oQ4y1K7PC视频属性的抓取
# BV号为1oQ4y1K7PC的视频属性抓取结束
# 开始BV号为1ep4y1C7Av视频属性的抓取
# BV号为1ep4y1C7Av的视频属性抓取结束
# 开始BV号为1eQ4y1K7yU视频属性的抓取
# BV号为1eQ4y1K7yU的视频属性抓取结束
# 开始BV号为16K411L7jb视频属性的抓取
# BV号为16K411L7jb的视频属性抓取结束
# 开始BV号为18t4y1U77w视频属性的抓取
# BV号为18t4y1U77w的视频属性抓取结束
# 开始BV号为1ez411b7S9视频属性的抓取
# BV号为1ez411b7S9的视频属性抓取结束
# 开始BV号为1jQ4y1K7EE视频属性的抓取
# BV号为1jQ4y1K7EE的视频属性抓取结束
# 开始BV号为1x5411t7tY视频属性的抓取
# BV号为1x5411t7tY的视频属性抓取结束
# 开始BV号为1z64y1u7RC视频属性的抓取
# BV号为1z64y1u7RC的视频属性抓取结束
# 开始BV号为1TV411d7rx视频属性的抓取
# BV号为1TV411d7rx的视频属性抓取结束
# 开始BV号为1X64y1u7Ld视频属性的抓取
# BV号为1X64y1u7Ld的视频属性抓取结束
# 开始BV号为1yQ4y1M78s视频属性的抓取
# BV号为1yQ4y1M78s的视频属性抓取结束
# 开始BV号为1ek4y1973d视频属性的抓取
# BV号为1ek4y1973d的视频属性抓取结束
# 开始BV号为1nK4y1r74f视频属性的抓取
# BV号为1nK4y1r74f的视频属性抓取结束
# 开始BV号为1fQ4y1K71u视频属性的抓取
# BV号为1fQ4y1K71u的视频属性抓取结束
# 开始BV号为17z411z7cj视频属性的抓取
# BV号为17z411z7cj的视频属性抓取结束
# 开始BV号为1qg4y1z7mb视频属性的抓取
# BV号为1qg4y1z7mb的视频属性抓取结束
# 开始BV号为1x64y1M7Tp视频属性的抓取
# BV号为1x64y1M7Tp的视频属性抓取结束
# 开始BV号为1Mg4y1z75V视频属性的抓取
# BV号为1Mg4y1z75V的视频属性抓取结束
# 开始BV号为18g4y1z7Xd视频属性的抓取
# BV号为18g4y1z7Xd的视频属性抓取结束
# 开始BV号为13i4y1t7KE视频属性的抓取
# BV号为13i4y1t7KE的视频属性抓取结束
# 开始BV号为13e411s7Fv视频属性的抓取
# 开始BV号为13e411s7Fv视频属性的抓取
# BV号为13e411s7Fv的视频属性抓取结束
# 开始BV号为1jt4y1m7ws视频属性的抓取
# BV号为1jt4y1m7ws的视频属性抓取结束
# 开始BV号为19C4y1s7fu视频属性的抓取
# BV号为19C4y1s7fu的视频属性抓取结束
# 开始BV号为1mk4y1r7cP视频属性的抓取
# BV号为1mk4y1r7cP的视频属性抓取结束
# 开始BV号为1Li4y1t7Rg视频属性的抓取
# BV号为1Li4y1t7Rg的视频属性抓取结束
# 开始BV号为11k4y1R7Vf视频属性的抓取
# BV号为11k4y1R7Vf的视频属性抓取结束
# 开始BV号为1hi4y1t71u视频属性的抓取
# BV号为1hi4y1t71u的视频属性抓取结束
# 开始BV号为1Ai4y187gP视频属性的抓取
# BV号为1Ai4y187gP的视频属性抓取结束
# 开始BV号为1Tp4y197nk视频属性的抓取
# BV号为1Tp4y197nk的视频属性抓取结束
# 开始BV号为1QK411L71a视频属性的抓取
# BV号为1QK411L71a的视频属性抓取结束
# 开始BV号为1854y1d7XX视频属性的抓取
# BV号为1854y1d7XX的视频属性抓取结束
# 开始BV号为1pe411s7Nu视频属性的抓取
# BV号为1pe411s7Nu的视频属性抓取结束
# 开始BV号为1y5411x7Kz视频属性的抓取
# BV号为1y5411x7Kz的视频属性抓取结束
# 开始BV号为1X541147uz视频属性的抓取
# BV号为1X541147uz的视频属性抓取结束
# 开始BV号为1zf4y1U7jQ视频属性的抓取
# BV号为1zf4y1U7jQ的视频属性抓取结束
# 开始BV号为1X5411t7WE视频属性的抓取
# BV号为1X5411t7WE的视频属性抓取结束
# 开始BV号为1Jf4y1m7W7视频属性的抓取
# BV号为1Jf4y1m7W7的视频属性抓取结束
# 开始BV号为1na4y1x72n视频属性的抓取
# BV号为1na4y1x72n的视频属性抓取结束
# 开始BV号为1eT4y137cc视频属性的抓取
# BV号为1eT4y137cc的视频属性抓取结束
# 开始BV号为1Vk4y1r7qs视频属性的抓取
# BV号为1Vk4y1r7qs的视频属性抓取结束
# 开始BV号为1qf4y127JS视频属性的抓取
# BV号为1qf4y127JS的视频属性抓取结束
# 开始BV号为1EK411W72w视频属性的抓取
# BV号为1EK411W72w的视频属性抓取结束
# 开始BV号为1WZ4y1p7qd视频属性的抓取
# BV号为1WZ4y1p7qd的视频属性抓取结束
# 开始BV号为1Be411p7EN视频属性的抓取
# BV号为1Be411p7EN的视频属性抓取结束
# 开始BV号为1yi4y1x7dn视频属性的抓取
# BV号为1yi4y1x7dn的视频属性抓取结束
# 开始BV号为1hT4y1g7mY视频属性的抓取
# BV号为1hT4y1g7mY的视频属性抓取结束
# 开始BV号为1MV411C7a7视频属性的抓取
# BV号为1MV411C7a7的视频属性抓取结束
# 开始BV号为1tT4y1u7MB视频属性的抓取
# BV号为1tT4y1u7MB的视频属性抓取结束
# 开始BV号为12K4y1b7ho视频属性的抓取
# BV号为12K4y1b7ho的视频属性抓取结束
# 开始BV号为1i5411s75K视频属性的抓取
# BV号为1i5411s75K的视频属性抓取结束
# 开始BV号为1aK411W7KG视频属性的抓取
# BV号为1aK411W7KG的视频属性抓取结束
# 开始BV号为1i5411s7yt视频属性的抓取
# BV号为1i5411s7yt的视频属性抓取结束
# 开始BV号为1Gz4y1d7yd视频属性的抓取
# BV号为1Gz4y1d7yd的视频属性抓取结束
# 开始BV号为1Je411W7Ub视频属性的抓取
# BV号为1Je411W7Ub的视频属性抓取结束
# 开始BV号为1TA411q7xj视频属性的抓取
# BV号为1TA411q7xj的视频属性抓取结束
# 开始BV号为13Q4y1N7RF视频属性的抓取
# BV号为13Q4y1N7RF的视频属性抓取结束
# 开始BV号为1wK411L7MQ视频属性的抓取
# 开始BV号为1wK411L7MQ视频属性的抓取
# BV号为1wK411L7MQ的视频属性抓取结束
# 开始BV号为1Ut4y1C7DM视频属性的抓取
# BV号为1Ut4y1C7DM的视频属性抓取结束
# 开始BV号为1Fi4y1t7cj视频属性的抓取
# BV号为1Fi4y1t7cj的视频属性抓取结束
# 开始BV号为1Qi4y147jo视频属性的抓取
# BV号为1Qi4y147jo的视频属性抓取结束
# 开始BV号为1Kf4y127od视频属性的抓取
# BV号为1Kf4y127od的视频属性抓取结束
# 开始BV号为1jK4y1871U视频属性的抓取
# BV号为1jK4y1871U的视频属性抓取结束
# 开始BV号为1m5411s7Q9视频属性的抓取
# BV号为1m5411s7Q9的视频属性抓取结束
# 开始BV号为1Gz411B77a视频属性的抓取
# BV号为1Gz411B77a的视频属性抓取结束
# 开始BV号为1oi4y1x7e7视频属性的抓取
# BV号为1oi4y1x7e7的视频属性抓取结束
# 开始BV号为1da4y1e79e视频属性的抓取
# BV号为1da4y1e79e的视频属性抓取结束
# 开始BV号为1SK411H7xF视频属性的抓取
# BV号为1SK411H7xF的视频属性抓取结束
# 开始BV号为1Ua4y1e7pa视频属性的抓取
# BV号为1Ua4y1e7pa的视频属性抓取结束
# 开始BV号为1Rz411v7cF视频属性的抓取
# BV号为1Rz411v7cF的视频属性抓取结束
# 开始BV号为1ge411W7qv视频属性的抓取
# BV号为1ge411W7qv的视频属性抓取结束
# 开始BV号为1Zz4y1X7Yj视频属性的抓取
# BV号为1Zz4y1X7Yj的视频属性抓取结束
# 开始BV号为1QK41157Hb视频属性的抓取
# BV号为1QK41157Hb的视频属性抓取结束
# 开始BV号为1Z54y1D7Z4视频属性的抓取
# BV号为1Z54y1D7Z4的视频属性抓取结束
# 开始BV号为1bp4y1Q7t9视频属性的抓取
# BV号为1bp4y1Q7t9的视频属性抓取结束
# 开始BV号为1Wz411q7F7视频属性的抓取
# BV号为1Wz411q7F7的视频属性抓取结束
# 开始BV号为1Mt4y117ow视频属性的抓取
# BV号为1Mt4y117ow的视频属性抓取结束
# 开始BV号为1PQ4y1P7h4视频属性的抓取
# BV号为1PQ4y1P7h4的视频属性抓取结束
# 开始BV号为1tQ4y1N7hY视频属性的抓取
# BV号为1tQ4y1N7hY的视频属性抓取结束
# 开始BV号为18C4y1W7cz视频属性的抓取
# BV号为18C4y1W7cz的视频属性抓取结束
# 开始BV号为1qa4y1e7jX视频属性的抓取
# BV号为1qa4y1e7jX的视频属性抓取结束
# 开始BV号为1MK411s7rq视频属性的抓取
# BV号为1MK411s7rq的视频属性抓取结束
# 开始BV号为1UT4y1u7Uv视频属性的抓取
# BV号为1UT4y1u7Uv的视频属性抓取结束
# 开始BV号为19C4y1h7aU视频属性的抓取
# BV号为19C4y1h7aU的视频属性抓取结束
# 开始BV号为12A411t7cM视频属性的抓取
# BV号为12A411t7cM的视频属性抓取结束
# 开始BV号为1qk4y167w9视频属性的抓取
# BV号为1qk4y167w9的视频属性抓取结束
# 开始BV号为1wQ4y1K7ta视频属性的抓取
# BV号为1wQ4y1K7ta的视频属性抓取结束
# 开始BV号为1154y1X7TT视频属性的抓取
# BV号为1154y1X7TT的视频属性抓取结束
# 开始BV号为1w5411x7Xo视频属性的抓取
# BV号为1w5411x7Xo的视频属性抓取结束
# 开始BV号为1ni4y1s7bs视频属性的抓取
# BV号为1ni4y1s7bs的视频属性抓取结束
# 开始BV号为1e5411s7t9视频属性的抓取
# BV号为1e5411s7t9的视频属性抓取结束
# 开始BV号为17C4y1p7ib视频属性的抓取
# BV号为17C4y1p7ib的视频属性抓取结束
# 开始BV号为1aK4y187Ja视频属性的抓取
# BV号为1aK4y187Ja的视频属性抓取结束
# 开始BV号为1GT4y1u78g视频属性的抓取
# BV号为1GT4y1u78g的视频属性抓取结束
# 开始BV号为1hC4y1p7Pk视频属性的抓取
# BV号为1hC4y1p7Pk的视频属性抓取结束
# 开始BV号为1fk4y1r7oV视频属性的抓取
# BV号为1fk4y1r7oV的视频属性抓取结束
# 开始BV号为1dp4y1S7q6视频属性的抓取
# BV号为1dp4y1S7q6的视频属性抓取结束
# 开始BV号为1Ua4y1e7px视频属性的抓取
# BV号为1Ua4y1e7px的视频属性抓取结束
# 开始BV号为1Si4y1474J视频属性的抓取
# BV号为1Si4y1474J的视频属性抓取结束
# 开始BV号为1Qt4y1C7K9视频属性的抓取
# BV号为1Qt4y1C7K9的视频属性抓取结束
# 开始BV号为1ne411W75N视频属性的抓取
# BV号为1ne411W75N的视频属性抓取结束
# 开始BV号为19K411W7Sv视频属性的抓取
# BV号为19K411W7Sv的视频属性抓取结束
# 开始BV号为1pt4y1C7Cg视频属性的抓取
# BV号为1pt4y1C7Cg的视频属性抓取结束
# 开始BV号为1pi4y147K8视频属性的抓取
# BV号为1pi4y147K8的视频属性抓取结束
# 开始BV号为1Ce411p7MF视频属性的抓取
# BV号为1Ce411p7MF的视频属性抓取结束
# 开始BV号为19t4y1C7Mf视频属性的抓取
# BV号为19t4y1C7Mf的视频属性抓取结束
# 开始BV号为1b5411475c视频属性的抓取
# BV号为1b5411475c的视频属性抓取结束
# 开始BV号为1Qg4y1B7pn视频属性的抓取
# BV号为1Qg4y1B7pn的视频属性抓取结束
# 开始BV号为1ik4y167Z3视频属性的抓取
# BV号为1ik4y167Z3的视频属性抓取结束
# 开始BV号为1Ag4y1B7bk视频属性的抓取
# BV号为1Ag4y1B7bk的视频属性抓取结束
# 开始BV号为1tT4y1u7Wa视频属性的抓取
# BV号为1tT4y1u7Wa的视频属性抓取结束
# 开始BV号为1Lz4y197uX视频属性的抓取
# BV号为1Lz4y197uX的视频属性抓取结束
# 开始BV号为1y54y1D7ha视频属性的抓取
# BV号为1y54y1D7ha的视频属性抓取结束
# 开始BV号为1GK411s7hr视频属性的抓取
# BV号为1GK411s7hr的视频属性抓取结束
# 开始BV号为14g4y1B74y视频属性的抓取
# BV号为14g4y1B74y的视频属性抓取结束
# 开始BV号为1eT4y1376A视频属性的抓取
# BV号为1eT4y1376A的视频属性抓取结束
# 开始BV号为1zC4y1p7Ch视频属性的抓取
# BV号为1zC4y1p7Ch的视频属性抓取结束
# 开始BV号为16A411q7xL视频属性的抓取
# BV号为16A411q7xL的视频属性抓取结束
# 开始BV号为17t4y1C7c4视频属性的抓取
# BV号为17t4y1C7c4的视频属性抓取结束
# 开始BV号为14k4y1k7G3视频属性的抓取
# BV号为14k4y1k7G3的视频属性抓取结束
# 开始BV号为1gK411W7Si视频属性的抓取
# BV号为1gK411W7Si的视频属性抓取结束
# 开始BV号为1bk4y1k7yF视频属性的抓取
# BV号为1bk4y1k7yF的视频属性抓取结束
# 开始BV号为1Pf4y127L8视频属性的抓取
# BV号为1Pf4y127L8的视频属性抓取结束
# 开始BV号为1Tz411i75g视频属性的抓取
# BV号为1Tz411i75g的视频属性抓取结束
# 开始BV号为12V411d71J视频属性的抓取
# BV号为12V411d71J的视频属性抓取结束
# 开始BV号为1Xz411v7mD视频属性的抓取
# BV号为1Xz411v7mD的视频属性抓取结束
# 开始BV号为1Lk4y1k7dJ视频属性的抓取
# BV号为1Lk4y1k7dJ的视频属性抓取结束
# 开始BV号为1PA411t7Yn视频属性的抓取
# BV号为1PA411t7Yn的视频属性抓取结束
# 开始BV号为1tQ4y1A7jN视频属性的抓取
# BV号为1tQ4y1A7jN的视频属性抓取结束
# 开始BV号为18A411t7e3视频属性的抓取
# BV号为18A411t7e3的视频属性抓取结束
# 开始BV号为17T4y137th视频属性的抓取
# BV号为17T4y137th的视频属性抓取结束
# 开始BV号为1rz411z7V6视频属性的抓取
# BV号为1rz411z7V6的视频属性抓取结束
# 开始BV号为1op4y1Q7Hf视频属性的抓取
# BV号为1op4y1Q7Hf的视频属性抓取结束
# 开始BV号为1Cz4y1R7gM视频属性的抓取
# BV号为1Cz4y1R7gM的视频属性抓取结束
# 开始BV号为1N5411x7Cu视频属性的抓取
# BV号为1N5411x7Cu的视频属性抓取结束
# 开始BV号为1rC4y1H7NE视频属性的抓取
# BV号为1rC4y1H7NE的视频属性抓取结束
# 开始BV号为1Yg4y1B7X5视频属性的抓取
# BV号为1Yg4y1B7X5的视频属性抓取结束
# 开始BV号为1eC4y1p7Ee视频属性的抓取
# BV号为1eC4y1p7Ee的视频属性抓取结束
# 开始BV号为1Az4y1976b视频属性的抓取
# BV号为1Az4y1976b的视频属性抓取结束
# 开始BV号为1XC4y1h78J视频属性的抓取
# BV号为1XC4y1h78J的视频属性抓取结束
# 开始BV号为1Tg4y1q7iK视频属性的抓取
# BV号为1Tg4y1q7iK的视频属性抓取结束
# 开始BV号为1jK4y1s7t1视频属性的抓取
# BV号为1jK4y1s7t1的视频属性抓取结束
# 开始BV号为12f4y1272j视频属性的抓取
# BV号为12f4y1272j的视频属性抓取结束
# 开始BV号为1sz411e78d视频属性的抓取
# BV号为1sz411e78d的视频属性抓取结束
# 开始BV号为1bD4y1Q7LF视频属性的抓取
# BV号为1bD4y1Q7LF的视频属性抓取结束
# 开始BV号为1cz4y1X7TT视频属性的抓取
# BV号为1cz4y1X7TT的视频属性抓取结束
# 开始BV号为1St4y1X7A5视频属性的抓取
# BV号为1St4y1X7A5的视频属性抓取结束
# 开始BV号为1wi4y1V73P视频属性的抓取
# BV号为1wi4y1V73P的视频属性抓取结束
# 开始BV号为15C4y1a7fp视频属性的抓取
# BV号为15C4y1a7fp的视频属性抓取结束
# 开始BV号为1UK4y1x7tC视频属性的抓取
# BV号为1UK4y1x7tC的视频属性抓取结束
# 开始BV号为1MD4y1Q7yU视频属性的抓取
# BV号为1MD4y1Q7yU的视频属性抓取结束
# 开始BV号为145411W71i视频属性的抓取
# BV号为145411W71i的视频属性抓取结束
# 开始BV号为1zQ4y1P7N7视频属性的抓取
# BV号为1zQ4y1P7N7的视频属性抓取结束
# 开始BV号为165411W7gC视频属性的抓取
# BV号为165411W7gC的视频属性抓取结束
# 开始BV号为14Z4y1H7Q8视频属性的抓取
# BV号为14Z4y1H7Q8的视频属性抓取结束
# 开始BV号为1nv411B7B6视频属性的抓取
# BV号为1nv411B7B6的视频属性抓取结束
# 开始BV号为1wv41167VN视频属性的抓取
# BV号为1wv41167VN的视频属性抓取结束
# 开始BV号为1ak4y1z766视频属性的抓取
# BV号为1ak4y1z766的视频属性抓取结束
# 开始BV号为1tZ4y1H7zR视频属性的抓取
# BV号为1tZ4y1H7zR的视频属性抓取结束
# 开始BV号为1554y1B7F7视频属性的抓取
# BV号为1554y1B7F7的视频属性抓取结束
# 开始BV号为1NV41167nt视频属性的抓取
# BV号为1NV41167nt的视频属性抓取结束
# 开始BV号为1rg4y1i7MB视频属性的抓取
# BV号为1rg4y1i7MB的视频属性抓取结束
# 开始BV号为1mp4y1D7Qt视频属性的抓取
# BV号为1mp4y1D7Qt的视频属性抓取结束
# 开始BV号为1FK411p7Da视频属性的抓取
# BV号为1FK411p7Da的视频属性抓取结束
# 开始BV号为14V411C7pU视频属性的抓取
# BV号为14V411C7pU的视频属性抓取结束
# 开始BV号为12Z4y1H7ir视频属性的抓取
# BV号为12Z4y1H7ir的视频属性抓取结束
# 开始BV号为12V411r7yJ视频属性的抓取
# BV号为12V411r7yJ的视频属性抓取结束
# 开始BV号为1PK4y1475S视频属性的抓取
# BV号为1PK4y1475S的视频属性抓取结束
# 开始BV号为1JT4y177YA视频属性的抓取
# BV号为1JT4y177YA的视频属性抓取结束
# 开始BV号为14K411n7RF视频属性的抓取
# BV号为14K411n7RF的视频属性抓取结束
# 开始BV号为16A411v7A3视频属性的抓取
# BV号为16A411v7A3的视频属性抓取结束
# 开始BV号为1zf4y1y7aZ视频属性的抓取
# BV号为1zf4y1y7aZ的视频属性抓取结束
# 开始BV号为1nz411i76N视频属性的抓取
# BV号为1nz411i76N的视频属性抓取结束
# 开始BV号为1hz411i71G视频属性的抓取
# BV号为1hz411i71G的视频属性抓取结束
# 开始BV号为1vf4y1y73W视频属性的抓取
# BV号为1vf4y1y73W的视频属性抓取结束
# 开始BV号为1JZ4y1H7u5视频属性的抓取
# BV号为1JZ4y1H7u5的视频属性抓取结束
# 开始BV号为1Fv41167wq视频属性的抓取
# BV号为1Fv41167wq的视频属性抓取结束
# 开始BV号为18D4y1D7Rm视频属性的抓取
# BV号为18D4y1D7Rm的视频属性抓取结束
# 开始BV号为16z4y197rF视频属性的抓取
# BV号为16z4y197rF的视频属性抓取结束
# 开始BV号为1g54y1z7qs视频属性的抓取
# BV号为1g54y1z7qs的视频属性抓取结束
# 开始BV号为1ez4y1Q7zF视频属性的抓取
# BV号为1ez4y1Q7zF的视频属性抓取结束
# 开始BV号为1Vz411i73R视频属性的抓取
# BV号为1Vz411i73R的视频属性抓取结束
# 开始BV号为1CT4y1E7Bt视频属性的抓取
# BV号为1CT4y1E7Bt的视频属性抓取结束
# 开始BV号为1vV411k7jz视频属性的抓取
# BV号为1vV411k7jz的视频属性抓取结束
# 开始BV号为1Ni4y1V7C3视频属性的抓取
# BV号为1Ni4y1V7C3的视频属性抓取结束
# 开始BV号为13p4y1D7xC视频属性的抓取
# BV号为13p4y1D7xC的视频属性抓取结束
# 开始BV号为1oV411r7tH视频属性的抓取
# BV号为1oV411r7tH的视频属性抓取结束
# 开始BV号为1ND4y1Q7ZC视频属性的抓取
# BV号为1ND4y1Q7ZC的视频属性抓取结束
# 开始BV号为11z4y197Q2视频属性的抓取
# BV号为11z4y197Q2的视频属性抓取结束
# 开始BV号为1kp4y1D7xj视频属性的抓取
# BV号为1kp4y1D7xj的视频属性抓取结束
# 开始BV号为1qf4y117v6视频属性的抓取
# BV号为1qf4y117v6的视频属性抓取结束
# 开始BV号为17T4y1J7n3视频属性的抓取
# 开始BV号为17T4y1J7n3视频属性的抓取
# BV号为17T4y1J7n3的视频属性抓取结束
# 开始BV号为15z411i7G3视频属性的抓取
# BV号为15z411i7G3的视频属性抓取结束
# 开始BV号为1vz411e7UR视频属性的抓取
# BV号为1vz411e7UR的视频属性抓取结束
# 开始BV号为1ck4y167DP视频属性的抓取
# BV号为1ck4y167DP的视频属性抓取结束
# 开始BV号为1zz411e7ar视频属性的抓取
# BV号为1zz411e7ar的视频属性抓取结束
# 开始BV号为1CT4y1E7aZ视频属性的抓取
# BV号为1CT4y1E7aZ的视频属性抓取结束
# 开始BV号为1vK411p7Pd视频属性的抓取
# BV号为1vK411p7Pd的视频属性抓取结束
# 开始BV号为1Pg4y1v7We视频属性的抓取
# BV号为1Pg4y1v7We的视频属性抓取结束
# 开始BV号为1vK411p7Pd视频属性的抓取
# BV号为1vK411p7Pd的视频属性抓取结束
# 开始BV号为1Pg4y1v7We视频属性的抓取
# BV号为1Pg4y1v7We的视频属性抓取结束
# 开始BV号为1cZ4y1H77b视频属性的抓取
# BV号为1cZ4y1H77b的视频属性抓取结束
# 开始BV号为1WV411r7wX视频属性的抓取
# BV号为1WV411r7wX的视频属性抓取结束
# 开始BV号为1Eg4y1q7pu视频属性的抓取
# BV号为1Eg4y1q7pu的视频属性抓取结束
# 开始BV号为1dV411r78v视频属性的抓取
# BV号为1dV411r78v的视频属性抓取结束
# 开始BV号为1FV411y7a5视频属性的抓取
# BV号为1FV411y7a5的视频属性抓取结束
# 开始BV号为1T54y1Q7f8视频属性的抓取
# BV号为1T54y1Q7f8的视频属性抓取结束
# 开始BV号为1E54y1B74z视频属性的抓取
# BV号为1E54y1B74z的视频属性抓取结束
# 开始BV号为1Mk4y1z7s1视频属性的抓取
# BV号为1Mk4y1z7s1的视频属性抓取结束
# 开始BV号为1bT4y177v4视频属性的抓取
# BV号为1bT4y177v4的视频属性抓取结束
# 开始BV号为1hV411r7k2视频属性的抓取
# BV号为1hV411r7k2的视频属性抓取结束
# 开始BV号为1qC4y1a7sK视频属性的抓取
# BV号为1qC4y1a7sK的视频属性抓取结束
# 开始BV号为1Ei4y1x7Vm视频属性的抓取
# BV号为1Ei4y1x7Vm的视频属性抓取结束
# 开始BV号为15p4y1D7X9视频属性的抓取
# BV号为15p4y1D7X9的视频属性抓取结束
# 开始BV号为1DT4y1E73v视频属性的抓取
# BV号为1DT4y1E73v的视频属性抓取结束
# 开始BV号为1B54y1B7B5视频属性的抓取
# BV号为1B54y1B7B5的视频属性抓取结束
# 开始BV号为1kz4y1Q7dw视频属性的抓取
# BV号为1kz4y1Q7dw的视频属性抓取结束
# 开始BV号为1qK4y1x7Ty视频属性的抓取
# BV号为1qK4y1x7Ty的视频属性抓取结束
# 开始BV号为1z5411W7rj视频属性的抓取
# BV号为1z5411W7rj的视频属性抓取结束
# 开始BV号为1ap4y1D7EQ视频属性的抓取
# BV号为1ap4y1D7EQ的视频属性抓取结束
# 开始BV号为1ak4y1z7sf视频属性的抓取
# BV号为1ak4y1z7sf的视频属性抓取结束
# 开始BV号为1HD4y1S7AY视频属性的抓取
# BV号为1HD4y1S7AY的视频属性抓取结束
# 开始BV号为1xD4y1D7oq视频属性的抓取
# 开始BV号为1xD4y1D7oq视频属性的抓取
# BV号为1xD4y1D7oq的视频属性抓取结束
# 开始BV号为1LV41167K8视频属性的抓取
# BV号为1LV41167K8的视频属性抓取结束
# 开始BV号为1G5411Y7VX视频属性的抓取
# BV号为1G5411Y7VX的视频属性抓取结束
# 开始BV号为1e5411W7eh视频属性的抓取
# BV号为1e5411W7eh的视频属性抓取结束
# 开始BV号为1sV411r7vr视频属性的抓取
# BV号为1sV411r7vr的视频属性抓取结束
# 开始BV号为11K4y1x7Ky视频属性的抓取
# BV号为11K4y1x7Ky的视频属性抓取结束
# 开始BV号为1e54y1B7dG视频属性的抓取
# BV号为1e54y1B7dG的视频属性抓取结束
# 开始BV号为1yz4y197rG视频属性的抓取
# BV号为1yz4y197rG的视频属性抓取结束
# 开始BV号为1u5411W7GP视频属性的抓取
# BV号为1u5411W7GP的视频属性抓取结束
# 开始BV号为1ZZ4y1n7JS视频属性的抓取
# BV号为1ZZ4y1n7JS的视频属性抓取结束
# 开始BV号为1Gf4y117uF视频属性的抓取
# BV号为1Gf4y117uF的视频属性抓取结束
# 开始BV号为1ut4y1y78v视频属性的抓取
# BV号为1ut4y1y78v的视频属性抓取结束
# 开始BV号为1wA411i7A1视频属性的抓取
# BV号为1wA411i7A1的视频属性抓取结束
# 开始BV号为1kT4y177Wh视频属性的抓取
# BV号为1kT4y177Wh的视频属性抓取结束
# 开始BV号为1o5411W7qk视频属性的抓取
# BV号为1o5411W7qk的视频属性抓取结束
# 开始BV号为1CQ4y1P77j视频属性的抓取
# BV号为1CQ4y1P77j的视频属性抓取结束
# 开始BV号为1Z5411W7y5视频属性的抓取
# BV号为1Z5411W7y5的视频属性抓取结束
# 开始BV号为1YK4y1s7UA视频属性的抓取
# BV号为1YK4y1s7UA的视频属性抓取结束
# 开始BV号为1K54y1B7Dc视频属性的抓取
# BV号为1K54y1B7Dc的视频属性抓取结束
# 开始BV号为1DC4y1b7UA视频属性的抓取
# BV号为1DC4y1b7UA的视频属性抓取结束
# 开始BV号为1Cp4y1S7HG视频属性的抓取
# BV号为1Cp4y1S7HG的视频属性抓取结束
# 开始BV号为1eh411o7Ze视频属性的抓取
# BV号为1eh411o7Ze的视频属性抓取结束
# 开始BV号为16v411i7JD视频属性的抓取
# BV号为16v411i7JD的视频属性抓取结束
# 开始BV号为1754y1q7qF视频属性的抓取
# BV号为1754y1q7qF的视频属性抓取结束
# 开始BV号为1Wt4y1Q7Z9视频属性的抓取
# BV号为1Wt4y1Q7Z9的视频属性抓取结束
# 开始BV号为1xK4y1x73g视频属性的抓取
# BV号为1xK4y1x73g的视频属性抓取结束
# 开始BV号为1JC4y1h7Cd视频属性的抓取
# 开始BV号为1JC4y1h7Cd视频属性的抓取
# BV号为1JC4y1h7Cd的视频属性抓取结束
# 开始BV号为1Pf4y197zH视频属性的抓取
# BV号为1Pf4y197zH的视频属性抓取结束
# 开始BV号为1vv411q7yw视频属性的抓取
# BV号为1vv411q7yw的视频属性抓取结束
# 开始BV号为1SZ4y1u7aD视频属性的抓取
# BV号为1SZ4y1u7aD的视频属性抓取结束
# 开始BV号为1P54y1S7TB视频属性的抓取
# BV号为1P54y1S7TB的视频属性抓取结束
# 开始BV号为1bk4y1B7Sg视频属性的抓取
# BV号为1bk4y1B7Sg的视频属性抓取结束
# 开始BV号为1st4y1X7DP视频属性的抓取
# BV号为1st4y1X7DP的视频属性抓取结束
# 开始BV号为1x54y1S7gD视频属性的抓取
# BV号为1x54y1S7gD的视频属性抓取结束
# 开始BV号为1EK4y1x7yy视频属性的抓取
# BV号为1EK4y1x7yy的视频属性抓取结束
# 开始BV号为1cV411r79L视频属性的抓取
# BV号为1cV411r79L的视频属性抓取结束
# 开始BV号为11T4y177hb视频属性的抓取
# BV号为11T4y177hb的视频属性抓取结束
# 开始BV号为1nZ4y1u7Hm视频属性的抓取
# BV号为1nZ4y1u7Hm的视频属性抓取结束
# 开始BV号为13C4y1b7n7视频属性的抓取
# BV号为13C4y1b7n7的视频属性抓取结束
# 开始BV号为18C4y1b747视频属性的抓取
# BV号为18C4y1b747的视频属性抓取结束
# 开始BV号为16i4y1u7in视频属性的抓取
# BV号为16i4y1u7in的视频属性抓取结束
# 开始BV号为1xz411v73X视频属性的抓取
# BV号为1xz411v73X的视频属性抓取结束
# 开始BV号为1rK4y1s7M8视频属性的抓取
# BV号为1rK4y1s7M8的视频属性抓取结束
# 开始BV号为1jK4y1x7jK视频属性的抓取
# BV号为1jK4y1x7jK的视频属性抓取结束
# 开始BV号为1Wa4y1a7da视频属性的抓取
# BV号为1Wa4y1a7da的视频属性抓取结束
# 开始BV号为1RT4y1j7Ed视频属性的抓取
# BV号为1RT4y1j7Ed的视频属性抓取结束
# 开始BV号为11T4y177Z6视频属性的抓取
# BV号为11T4y177Z6的视频属性抓取结束
# 开始BV号为1mA411e7hZ视频属性的抓取
# BV号为1mA411e7hZ的视频属性抓取结束
# 开始BV号为1Rz4y1D7Qz视频属性的抓取
# BV号为1Rz4y1D7Qz的视频属性抓取结束
# 开始BV号为1cC4y1h7zv视频属性的抓取
# BV号为1cC4y1h7zv的视频属性抓取结束
# 开始BV号为1Lv411q7nT视频属性的抓取
# BV号为1Lv411q7nT的视频属性抓取结束
# 开始BV号为1Yi4y1V7xB视频属性的抓取
# BV号为1Yi4y1V7xB的视频属性抓取结束
# 开始BV号为1iZ4y1u7fd视频属性的抓取
# BV号为1iZ4y1u7fd的视频属性抓取结束
# 开始BV号为1aD4y1S7wv视频属性的抓取
# BV号为1aD4y1S7wv的视频属性抓取结束
# 开始BV号为1Vz4y1D79R视频属性的抓取
# BV号为1Vz4y1D79R的视频属性抓取结束
# 开始BV号为1Fk4y1B7aX视频属性的抓取
# BV号为1Fk4y1B7aX的视频属性抓取结束
# 开始BV号为13K411J7FX视频属性的抓取
# BV号为13K411J7FX的视频属性抓取结束
# 开始BV号为13K411J7FX视频属性的抓取
# BV号为13K411J7FX的视频属性抓取结束
# 开始BV号为1k5411h7Xg视频属性的抓取
# BV号为1k5411h7Xg的视频属性抓取结束
# 开始BV号为1d54y1S7TV视频属性的抓取
# BV号为1d54y1S7TV的视频属性抓取结束
# 开始BV号为1Mf4y1R7A7视频属性的抓取
# BV号为1Mf4y1R7A7的视频属性抓取结束
# 开始BV号为1554y1q7zA视频属性的抓取
# BV号为1554y1q7zA的视频属性抓取结束
# 开始BV号为1ED4y1D7wN视频属性的抓取
# BV号为1ED4y1D7wN的视频属性抓取结束
# 开始BV号为1mT4y177Yx视频属性的抓取
# BV号为1mT4y177Yx的视频属性抓取结束
# 开始BV号为1Qz4y1D7wp视频属性的抓取
# BV号为1Qz4y1D7wp的视频属性抓取结束
# 开始BV号为1Yp4y1S7um视频属性的抓取
# BV号为1Yp4y1S7um的视频属性抓取结束
# 开始BV号为1ff4y1971p视频属性的抓取
# BV号为1ff4y1971p的视频属性抓取结束
# 开始BV号为1CZ4y1T7gC视频属性的抓取
# BV号为1CZ4y1T7gC的视频属性抓取结束
# 开始BV号为18D4y1U7hK视频属性的抓取
# BV号为18D4y1U7hK的视频属性抓取结束
# 开始BV号为1pv411v7Ee视频属性的抓取
# BV号为1pv411v7Ee的视频属性抓取结束
# 开始BV号为1Q54y1v7c3视频属性的抓取
# BV号为1Q54y1v7c3的视频属性抓取结束
# 开始BV号为1rK411J7XE视频属性的抓取
# BV号为1rK411J7XE的视频属性抓取结束
# 开始BV号为1vT4y1E779视频属性的抓取
# BV号为1vT4y1E779的视频属性抓取结束
# 开始BV号为1164y1F7mp视频属性的抓取
# BV号为1164y1F7mp的视频属性抓取结束
# 开始BV号为1oi4y137sw视频属性的抓取
# BV号为1oi4y137sw的视频属性抓取结束
# 开始BV号为1Ft4y1D774视频属性的抓取
# BV号为1Ft4y1D774的视频属性抓取结束
# 开始BV号为12f4y1R7t6视频属性的抓取
# BV号为12f4y1R7t6的视频属性抓取结束
# 开始BV号为1ki4y1G7Ub视频属性的抓取
# BV号为1ki4y1G7Ub的视频属性抓取结束
# 开始BV号为1vT4y1E779视频属性的抓取
# BV号为1vT4y1E779的视频属性抓取结束
# 开始BV号为1164y1F7mp视频属性的抓取
# BV号为1164y1F7mp的视频属性抓取结束
# 开始BV号为1oi4y137sw视频属性的抓取
# BV号为1oi4y137sw的视频属性抓取结束
# 开始BV号为1WK4y1s78v视频属性的抓取
# BV号为1WK4y1s78v的视频属性抓取结束
# 开始BV号为1Ft4y1D774视频属性的抓取
# BV号为1Ft4y1D774的视频属性抓取结束
# 开始BV号为19i4y1G7fR视频属性的抓取
# BV号为19i4y1G7fR的视频属性抓取结束
# 开始BV号为12f4y1R7t6视频属性的抓取
# BV号为12f4y1R7t6的视频属性抓取结束
# 开始BV号为1uf4y1d7Ho视频属性的抓取
# BV号为1uf4y1d7Ho的视频属性抓取结束
# 开始BV号为1fK4y1e7Yj视频属性的抓取
# BV号为1fK4y1e7Yj的视频属性抓取结束
# 开始BV号为1r54y1q7jM视频属性的抓取
# BV号为1r54y1q7jM的视频属性抓取结束
# 开始BV号为1P54y1D79g视频属性的抓取
# BV号为1P54y1D79g的视频属性抓取结束
# 开始BV号为1ra4y1h77c视频属性的抓取
# BV号为1ra4y1h77c的视频属性抓取结束
# 开始BV号为16A411e7DX视频属性的抓取
# BV号为16A411e7DX的视频属性抓取结束
# 开始BV号为1oA411a72k视频属性的抓取
# BV号为1oA411a72k的视频属性抓取结束
# 开始BV号为1Ya4y1E7Y6视频属性的抓取
# BV号为1Ya4y1E7Y6的视频属性抓取结束
# 开始BV号为1xA411Y7vK视频属性的抓取
# BV号为1xA411Y7vK的视频属性抓取结束
# 开始BV号为1JK411H7eD视频属性的抓取
# BV号为1JK411H7eD的视频属性抓取结束
# 开始BV号为1qf4y1X7Rr视频属性的抓取
# BV号为1qf4y1X7Rr的视频属性抓取结束
# 开始BV号为1sV41167Ai视频属性的抓取
# BV号为1sV41167Ai的视频属性抓取结束
# 开始BV号为1ft4y1S723视频属性的抓取
# BV号为1ft4y1S723的视频属性抓取结束
# 开始BV号为11t4y1Q7iw视频属性的抓取
# BV号为11t4y1Q7iw的视频属性抓取结束
# 开始BV号为1Wi4y1V79D视频属性的抓取
# BV号为1Wi4y1V79D的视频属性抓取结束
# 开始BV号为1i5411Y7Ri视频属性的抓取
# BV号为1i5411Y7Ri的视频属性抓取结束
# 开始BV号为17g4y1i79k视频属性的抓取
# BV号为17g4y1i79k的视频属性抓取结束
# 开始BV号为1Jg4y1i7rp视频属性的抓取
# BV号为1Jg4y1i7rp的视频属性抓取结束
# 开始BV号为18K411H7dm视频属性的抓取
# BV号为18K411H7dm的视频属性抓取结束
# 开始BV号为1TV411r7vC视频属性的抓取
# BV号为1TV411r7vC的视频属性抓取结束
# 开始BV号为1Ff4y1R7wj视频属性的抓取
# BV号为1Ff4y1R7wj的视频属性抓取结束
# 开始BV号为1QZ4y1T7qF视频属性的抓取
# BV号为1QZ4y1T7qF的视频属性抓取结束
# 开始BV号为1NT4y1E7bE视频属性的抓取
# BV号为1NT4y1E7bE的视频属性抓取结束
# 开始BV号为1Yh411o748视频属性的抓取
# BV号为1Yh411o748的视频属性抓取结束
# 开始BV号为1JK411H7mp视频属性的抓取
# BV号为1JK411H7mp的视频属性抓取结束
# 开始BV号为15A411e7Gs视频属性的抓取
# BV号为15A411e7Gs的视频属性抓取结束
# 开始BV号为1t54y1S7gm视频属性的抓取
# BV号为1t54y1S7gm的视频属性抓取结束
# 开始BV号为1KV411r7yB视频属性的抓取
# BV号为1KV411r7yB的视频属性抓取结束
# 开始BV号为1t54y1q7CX视频属性的抓取
# BV号为1t54y1q7CX的视频属性抓取结束
# 开始BV号为19a4y1a7Yg视频属性的抓取
# BV号为19a4y1a7Yg的视频属性抓取结束
# 开始BV号为1Lz4y1D7Vb视频属性的抓取
# BV号为1Lz4y1D7Vb的视频属性抓取结束
# 开始BV号为1ph411o7zk视频属性的抓取
# BV号为1ph411o7zk的视频属性抓取结束
# 开始BV号为1x54y1e7zf视频属性的抓取
# BV号为1x54y1e7zf的视频属性抓取结束
# 开始BV号为11D4y127JX视频属性的抓取
# BV号为11D4y127JX的视频属性抓取结束
# 开始BV号为15a4y1J7Lr视频属性的抓取
# BV号为15a4y1J7Lr的视频属性抓取结束
# 开始BV号为1R54y1e7Bm视频属性的抓取
# BV号为1R54y1e7Bm的视频属性抓取结束
# 开始BV号为1C54y1e7sD视频属性的抓取
# BV号为1C54y1e7sD的视频属性抓取结束
# 开始BV号为1Lf4y197gM视频属性的抓取
# BV号为1Lf4y197gM的视频属性抓取结束
# 开始BV号为1qD4y1m7wR视频属性的抓取
# BV号为1qD4y1m7wR的视频属性抓取结束
# 开始BV号为1854y1e777视频属性的抓取
# BV号为1854y1e777的视频属性抓取结束
# 开始BV号为1uZ4y1K7dP视频属性的抓取
# BV号为1uZ4y1K7dP的视频属性抓取结束
# 开始BV号为1sD4y127PC视频属性的抓取
# BV号为1sD4y127PC的视频属性抓取结束
# 开始BV号为16f4y197qE视频属性的抓取
# BV号为16f4y197qE的视频属性抓取结束
# 开始BV号为1pt4y1S7gR视频属性的抓取
# BV号为1pt4y1S7gR的视频属性抓取结束
# 开始BV号为1DK4y1Y7J9视频属性的抓取
# BV号为1DK4y1Y7J9的视频属性抓取结束
# 开始BV号为1z64y1c7ne视频属性的抓取
# BV号为1z64y1c7ne的视频属性抓取结束
# 开始BV号为11D4y127tj视频属性的抓取
# BV号为11D4y127tj的视频属性抓取结束
# 开始BV号为1vi4y1g7zV视频属性的抓取
# BV号为1vi4y1g7zV的视频属性抓取结束
# 开始BV号为1g64y1F78A视频属性的抓取
# BV号为1g64y1F78A的视频属性抓取结束
# 开始BV号为1df4y1Q7y2视频属性的抓取
# BV号为1df4y1Q7y2的视频属性抓取结束
# 开始BV号为19A411n7JY视频属性的抓取
# BV号为19A411n7JY的视频属性抓取结束
# 开始BV号为1ik4y117r7视频属性的抓取
# BV号为1ik4y117r7的视频属性抓取结束
# 开始BV号为1Ti4y1g7W7视频属性的抓取
# BV号为1Ti4y1g7W7的视频属性抓取结束
# 开始BV号为16C4y1t77N视频属性的抓取
# BV号为16C4y1t77N的视频属性抓取结束
# 开始BV号为1a541187tw视频属性的抓取
# BV号为1a541187tw的视频属性抓取结束
# 开始BV号为1it4y1S7mi视频属性的抓取
# BV号为1it4y1S7mi的视频属性抓取结束
# 开始BV号为14p4y1v7zp视频属性的抓取
# BV号为14p4y1v7zp的视频属性抓取结束
# 开始BV号为17Z4y1K78z视频属性的抓取
# BV号为17Z4y1K78z的视频属性抓取结束
# 开始BV号为1a541187Br视频属性的抓取
# BV号为1a541187Br的视频属性抓取结束
# 开始BV号为1t54y127WA视频属性的抓取
# BV号为1t54y127WA的视频属性抓取结束
# 开始BV号为1jz4y1f79u视频属性的抓取
# BV号为1jz4y1f79u的视频属性抓取结束
# 开始BV号为1da4y177jZ视频属性的抓取
# BV号为1da4y177jZ的视频属性抓取结束
# 开始BV号为16541187S4视频属性的抓取
# BV号为16541187S4的视频属性抓取结束
# 开始BV号为1ch411o7ER视频属性的抓取
# BV号为1ch411o7ER的视频属性抓取结束
# 开始BV号为1a5411h7La视频属性的抓取
# BV号为1a5411h7La的视频属性抓取结束
# 开始BV号为1mT4y1w75X视频属性的抓取
# BV号为1mT4y1w75X的视频属性抓取结束
# 开始BV号为1y64y1c7pb视频属性的抓取
# BV号为1y64y1c7pb的视频属性抓取结束
# 开始BV号为1u54y1U7Ef视频属性的抓取
# BV号为1u54y1U7Ef的视频属性抓取结束
# 开始BV号为1p54y1U7FD视频属性的抓取
# BV号为1p54y1U7FD的视频属性抓取结束
# 开始BV号为1SZ4y1K7vc视频属性的抓取
# BV号为1SZ4y1K7vc的视频属性抓取结束
# 开始BV号为17Z4y1K7in视频属性的抓取
# BV号为17Z4y1K7in的视频属性抓取结束
# 开始BV号为1uK411K7Md视频属性的抓取
# BV号为1uK411K7Md的视频属性抓取结束
# 开始BV号为1y64y1c7pb视频属性的抓取
# BV号为1y64y1c7pb的视频属性抓取结束
# 开始BV号为1u54y1U7Ef视频属性的抓取
# BV号为1u54y1U7Ef的视频属性抓取结束
# 开始BV号为1p54y1U7FD视频属性的抓取
# BV号为1p54y1U7FD的视频属性抓取结束
# 开始BV号为1SZ4y1K7vc视频属性的抓取
# BV号为1SZ4y1K7vc的视频属性抓取结束
# 开始BV号为17Z4y1K7in视频属性的抓取
# BV号为17Z4y1K7in的视频属性抓取结束
# 开始BV号为1uK411K7Md视频属性的抓取
# BV号为1uK411K7Md的视频属性抓取结束
# 开始BV号为1KV411S7xN视频属性的抓取
# BV号为1KV411S7xN的视频属性抓取结束
# 开始BV号为1RD4y127ba视频属性的抓取
# BV号为1RD4y127ba的视频属性抓取结束
# 开始BV号为1Ea4y177D1视频属性的抓取
# BV号为1Ea4y177D1的视频属性抓取结束
# 开始BV号为1RT4y157or视频属性的抓取
# BV号为1RT4y157or的视频属性抓取结束
# 开始BV号为1rh411975M视频属性的抓取
# BV号为1rh411975M的视频属性抓取结束
# 开始BV号为1tD4y127bz视频属性的抓取
# BV号为1tD4y127bz的视频属性抓取结束
# 开始BV号为1J5411h71v视频属性的抓取
# BV号为1J5411h71v的视频属性抓取结束
# 开始BV号为17h411d7Km视频属性的抓取
# BV号为17h411d7Km的视频属性抓取结束
# 开始BV号为1Sp4y1Y7ik视频属性的抓取
# BV号为1Sp4y1Y7ik的视频属性抓取结束
# 开始BV号为1S64y1c7dD视频属性的抓取
# BV号为1S64y1c7dD的视频属性抓取结束
# 开始BV号为1vZ4y1K769视频属性的抓取
# BV号为1vZ4y1K769的视频属性抓取结束
# 开始BV号为1zz4y1f7u8视频属性的抓取
# BV号为1zz4y1f7u8的视频属性抓取结束
# 开始BV号为1xA411n7ro视频属性的抓取
# BV号为1xA411n7ro的视频属性抓取结束
# 开始BV号为1Y54y1e7fx视频属性的抓取
# BV号为1Y54y1e7fx的视频属性抓取结束
# 开始BV号为1P64y1F75k视频属性的抓取
# BV号为1P64y1F75k的视频属性抓取结束
# 开始BV号为1J54y127eh视频属性的抓取
# BV号为1J54y127eh的视频属性抓取结束
# 开始BV号为1f5411a7mu视频属性的抓取
# BV号为1f5411a7mu的视频属性抓取结束
# 开始BV号为1Sp4y1v7Kz视频属性的抓取
# BV号为1Sp4y1v7Kz的视频属性抓取结束
# 开始BV号为1RK411T7Kq视频属性的抓取
# BV号为1RK411T7Kq的视频属性抓取结束
# 开始BV号为1af4y1Q7tV视频属性的抓取
# BV号为1af4y1Q7tV的视频属性抓取结束
# 开始BV号为1ia4y177ns视频属性的抓取
# BV号为1ia4y177ns的视频属性抓取结束
# 开始BV号为1z64y1c7VH视频属性的抓取
# BV号为1z64y1c7VH的视频属性抓取结束
# 开始BV号为11a4y177NS视频属性的抓取
# BV号为11a4y177NS的视频属性抓取结束
# 开始BV号为1dV411z7mi视频属性的抓取
# BV号为1dV411z7mi的视频属性抓取结束
# 开始BV号为1wK411K7Z7视频属性的抓取
# BV号为1wK411K7Z7的视频属性抓取结束
# 开始BV号为1WC4y187bH视频属性的抓取
# BV号为1WC4y187bH的视频属性抓取结束
# 开始BV号为1Yk4y127YR视频属性的抓取
# BV号为1Yk4y127YR的视频属性抓取结束
# 开始BV号为1CD4y1271G视频属性的抓取
# BV号为1CD4y1271G的视频属性抓取结束
# 开始BV号为1nD4y127ZX视频属性的抓取
# BV号为1nD4y127ZX的视频属性抓取结束
# 开始BV号为1UK4y1Y7pu视频属性的抓取
# BV号为1UK4y1Y7pu的视频属性抓取结束
# 开始BV号为1SZ4y1K7Dt视频属性的抓取
# BV号为1SZ4y1K7Dt的视频属性抓取结束
# 开始BV号为1Qk4y117Q7视频属性的抓取
# BV号为1Qk4y117Q7的视频属性抓取结束
# 开始BV号为1jv41117Z4视频属性的抓取
# BV号为1jv41117Z4的视频属性抓取结束
# 开始BV号为1854y1U7LT视频属性的抓取
# BV号为1854y1U7LT的视频属性抓取结束
# 开始BV号为1SZ4y1K7Dt视频属性的抓取
# BV号为1SZ4y1K7Dt的视频属性抓取结束
# 开始BV号为1Qk4y117Q7视频属性的抓取
# BV号为1Qk4y117Q7的视频属性抓取结束
# 开始BV号为1jv41117Z4视频属性的抓取
# BV号为1jv41117Z4的视频属性抓取结束
# 开始BV号为1854y1U7LT视频属性的抓取
# BV号为1854y1U7LT的视频属性抓取结束
# 开始BV号为1cV411S7Ss视频属性的抓取
# BV号为1cV411S7Ss的视频属性抓取结束
# 开始BV号为1K54y1U77v视频属性的抓取
# BV号为1K54y1U77v的视频属性抓取结束
# 开始BV号为1QD4y1U74j视频属性的抓取
# BV号为1QD4y1U74j的视频属性抓取结束
# 开始BV号为1KA411e76v视频属性的抓取
# BV号为1KA411e76v的视频属性抓取结束
# 开始BV号为15a4y1J7TK视频属性的抓取
# BV号为15a4y1J7TK的视频属性抓取结束
# 开始BV号为14a4y1J7hA视频属性的抓取
# BV号为14a4y1J7hA的视频属性抓取结束
# 开始BV号为1mh411d7Wb视频属性的抓取
# BV号为1mh411d7Wb的视频属性抓取结束
# 开始BV号为1fV411z7tF视频属性的抓取
# BV号为1fV411z7tF的视频属性抓取结束
# 开始BV号为1a54y1i7cC视频属性的抓取
# BV号为1a54y1i7cC的视频属性抓取结束
# 开始BV号为1s54y1i7Cu视频属性的抓取
# BV号为1s54y1i7Cu的视频属性抓取结束
# 开始BV号为1yC4y1t7Gb视频属性的抓取
# BV号为1yC4y1t7Gb的视频属性抓取结束
# 开始BV号为1CD4y1276x视频属性的抓取
# BV号为1CD4y1276x的视频属性抓取结束
# 开始BV号为12T4y157BK视频属性的抓取
# BV号为12T4y157BK的视频属性抓取结束
# 开始BV号为14h411d7CB视频属性的抓取
# BV号为14h411d7CB的视频属性抓取结束
# 开始BV号为1Ci4y1M7cP视频属性的抓取
# BV号为1Ci4y1M7cP的视频属性抓取结束
# 开始BV号为1Ef4y1Q7zJ视频属性的抓取
# BV号为1Ef4y1Q7zJ的视频属性抓取结束
# 开始BV号为1zh41197BA视频属性的抓取
# BV号为1zh41197BA的视频属性抓取结束
# 开始BV号为1xD4y1m72R视频属性的抓取
# BV号为1xD4y1m72R的视频属性抓取结束
# 开始BV号为1i5411b7XF视频属性的抓取
# BV号为1i5411b7XF的视频属性抓取结束
# 开始BV号为12t4y1i7jw视频属性的抓取
# BV号为12t4y1i7jw的视频属性抓取结束
# 开始BV号为1z5411b7x1视频属性的抓取
# BV号为1z5411b7x1的视频属性抓取结束
# 开始BV号为1d54y127Qc视频属性的抓取
# BV号为1d54y127Qc的视频属性抓取结束
# 开始BV号为1jz4y1Z7XD视频属性的抓取
# BV号为1jz4y1Z7XD的视频属性抓取结束
# 开始BV号为1nA411J7Xj视频属性的抓取
# BV号为1nA411J7Xj的视频属性抓取结束
# 开始BV号为1zh411R7ac视频属性的抓取
# BV号为1zh411R7ac的视频属性抓取结束
# 开始BV号为1RV41127fq视频属性的抓取
# BV号为1RV41127fq的视频属性抓取结束
# 开始BV号为1sZ4y157Z6视频属性的抓取
# BV号为1sZ4y157Z6的视频属性抓取结束
# 开始BV号为1cv411y7JY视频属性的抓取
# BV号为1cv411y7JY的视频属性抓取结束
# 开始BV号为1jT4y1A7NP视频属性的抓取
# BV号为1jT4y1A7NP的视频属性抓取结束
# 开始BV号为1U54y127cV视频属性的抓取
# BV号为1U54y127cV的视频属性抓取结束
# 开始BV号为1fa4y1j7mu视频属性的抓取
# BV号为1fa4y1j7mu的视频属性抓取结束
# 开始BV号为1iz4y1f7CX视频属性的抓取
# BV号为1iz4y1f7CX的视频属性抓取结束
# 开始BV号为1V5411j7hG视频属性的抓取
# BV号为1V5411j7hG的视频属性抓取结束
# 开始BV号为13V411m77A视频属性的抓取
# BV号为13V411m77A的视频属性抓取结束
# 开始BV号为1qz4y1d7aE视频属性的抓取
# BV号为1qz4y1d7aE的视频属性抓取结束
# 开始BV号为17h411X7HQ视频属性的抓取
# BV号为17h411X7HQ的视频属性抓取结束
# 开始BV号为1jy4y1y7oz视频属性的抓取
# BV号为1jy4y1y7oz的视频属性抓取结束
# 开始BV号为12h411R7q6视频属性的抓取
# BV号为12h411R7q6的视频属性抓取结束
# 开始BV号为1Sy4y1y7NM视频属性的抓取
# BV号为1Sy4y1y7NM的视频属性抓取结束
# 开始BV号为1T5411j7Lo视频属性的抓取
# BV号为1T5411j7Lo的视频属性抓取结束
# 开始BV号为1QZ4y1P78c视频属性的抓取
# BV号为1QZ4y1P78c的视频属性抓取结束
# 开始BV号为1n541187L1视频属性的抓取
# BV号为1n541187L1的视频属性抓取结束
# 开始BV号为1Bi4y1M74b视频属性的抓取
# BV号为1Bi4y1M74b的视频属性抓取结束
# 开始BV号为1Uy4y1y7Vw视频属性的抓取
# BV号为1Uy4y1y7Vw的视频属性抓取结束
# 开始BV号为1gz4y1f7tk视频属性的抓取
# BV号为1gz4y1f7tk的视频属性抓取结束
# 开始BV号为1dh411R7eG视频属性的抓取
# BV号为1dh411R7eG的视频属性抓取结束
# 开始BV号为1sD4y1m7Mo视频属性的抓取
# BV号为1sD4y1m7Mo的视频属性抓取结束
# 开始BV号为1ri4y1M7D3视频属性的抓取
# BV号为1ri4y1M7D3的视频属性抓取结束
# 开始BV号为1b54y1m72X视频属性的抓取
# BV号为1b54y1m72X的视频属性抓取结束
# 开始BV号为1fv411y7vi视频属性的抓取
# BV号为1fv411y7vi的视频属性抓取结束
# 开始BV号为1aA411E7dE视频属性的抓取
# BV号为1aA411E7dE的视频属性抓取结束
# 开始BV号为1ey4y1k7F9视频属性的抓取
# BV号为1ey4y1k7F9的视频属性抓取结束
# 开始BV号为1Gp4y1e7VW视频属性的抓取
# BV号为1Gp4y1e7VW的视频属性抓取结束
# 开始BV号为13A411J7iN视频属性的抓取
# BV号为13A411J7iN的视频属性抓取结束
# 开始BV号为1hA411J7PS视频属性的抓取
# BV号为1hA411J7PS的视频属性抓取结束
# 开始BV号为1Ei4y1u7bL视频属性的抓取
# BV号为1Ei4y1u7bL的视频属性抓取结束
# 开始BV号为1UK411P7mz视频属性的抓取
# BV号为1UK411P7mz的视频属性抓取结束
# 开始BV号为1aT4y1w7jS视频属性的抓取
# BV号为1aT4y1w7jS的视频属性抓取结束
# 开始BV号为12T4y1A7rd视频属性的抓取
# BV号为12T4y1A7rd的视频属性抓取结束
# 开始BV号为1WK4y1a7Y4视频属性的抓取
# BV号为1WK4y1a7Y4的视频属性抓取结束
# 开始BV号为1Cp4y1Y7CJ视频属性的抓取
# BV号为1Cp4y1Y7CJ的视频属性抓取结束
# 开始BV号为1oV411U7o2视频属性的抓取
# BV号为1oV411U7o2的视频属性抓取结束
# 开始BV号为1rD4y1o78L视频属性的抓取
# BV号为1rD4y1o78L的视频属性抓取结束
# 开始BV号为1jv41117q5视频属性的抓取
# BV号为1jv41117q5的视频属性抓取结束
# 开始BV号为1Jy4y1y7xB视频属性的抓取
# BV号为1Jy4y1y7xB的视频属性抓取结束
# 开始BV号为1Gp4y1i72K视频属性的抓取
# BV号为1Gp4y1i72K的视频属性抓取结束
# 开始BV号为1uz4y1Z78s视频属性的抓取
# BV号为1uz4y1Z78s的视频属性抓取结束
# 开始BV号为18D4y1m7KC视频属性的抓取
# BV号为18D4y1m7KC的视频属性抓取结束
# 开始BV号为1rK411K7zi视频属性的抓取
# BV号为1rK411K7zi的视频属性抓取结束
# 开始BV号为145411h7BV视频属性的抓取
# BV号为145411h7BV的视频属性抓取结束
# 开始BV号为1LT4y1A728视频属性的抓取
# BV号为1LT4y1A728的视频属性抓取结束
# 开始BV号为1h64y1F7gH视频属性的抓取
# BV号为1h64y1F7gH的视频属性抓取结束
# 开始BV号为1oK4y1a7tu视频属性的抓取
# BV号为1oK4y1a7tu的视频属性抓取结束
# 开始BV号为1h54y127fh视频属性的抓取
# BV号为1h54y127fh的视频属性抓取结束
# 开始BV号为1ra4y157Ff视频属性的抓取
# BV号为1ra4y157Ff的视频属性抓取结束
# 开始BV号为1yt4y1i7u8视频属性的抓取
# BV号为1yt4y1i7u8的视频属性抓取结束
# 开始BV号为1M54y117iM视频属性的抓取
# BV号为1M54y117iM的视频属性抓取结束
# 开始BV号为1U5411b7Gx视频属性的抓取
# BV号为1U5411b7Gx的视频属性抓取结束
# 开始BV号为1mh41197UG视频属性的抓取
# BV号为1mh41197UG的视频属性抓取结束
# 开始BV号为1ZV411m7Wi视频属性的抓取
# BV号为1ZV411m7Wi的视频属性抓取结束
# 开始BV号为1RT4y1w7Hu视频属性的抓取
# BV号为1RT4y1w7Hu的视频属性抓取结束
# 开始BV号为1gp4y1e7Zi视频属性的抓取
# BV号为1gp4y1e7Zi的视频属性抓取结束
# 开始BV号为1up4y1Y7PC视频属性的抓取
# BV号为1up4y1Y7PC的视频属性抓取结束
# 开始BV号为1QA411E7e5视频属性的抓取
# BV号为1QA411E7e5的视频属性抓取结束
# 开始BV号为1Jt4y1q7Gs视频属性的抓取
# BV号为1Jt4y1q7Gs的视频属性抓取结束
# 开始BV号为1iT4y1A7i5视频属性的抓取
# BV号为1iT4y1A7i5的视频属性抓取结束
# 开始BV号为15K4y1e7U6视频属性的抓取
# BV号为15K4y1e7U6的视频属性抓取结束
# 开始BV号为1hA411J72h视频属性的抓取
# BV号为1hA411J72h的视频属性抓取结束
# 开始BV号为1bV411m7xF视频属性的抓取
# BV号为1bV411m7xF的视频属性抓取结束
# 开始BV号为1Uh411X77f视频属性的抓取
# BV号为1Uh411X77f的视频属性抓取结束
# 开始BV号为1454y127xU视频属性的抓取
# BV号为1454y127xU的视频属性抓取结束
# 开始BV号为12k4y1y7wP视频属性的抓取
# BV号为12k4y1y7wP的视频属性抓取结束
# 开始BV号为1bA411E7sj视频属性的抓取
# BV号为1bA411E7sj的视频属性抓取结束
# 开始BV号为1N54y117cs视频属性的抓取
# BV号为1N54y117cs的视频属性抓取结束
# 开始BV号为1yK411K78j视频属性的抓取
# BV号为1yK411K78j的视频属性抓取结束
# 开始BV号为1ci4y1E7m1视频属性的抓取
# BV号为1ci4y1E7m1的视频属性抓取结束
# 开始BV号为1364y1F7Mr视频属性的抓取
# BV号为1364y1F7Mr的视频属性抓取结束
# 开始BV号为1Dh411X7Jh视频属性的抓取
# BV号为1Dh411X7Jh的视频属性抓取结束
# 开始BV号为1Lk4y1y7o5视频属性的抓取
# BV号为1Lk4y1y7o5的视频属性抓取结束
# 开始BV号为1Xa4y1j7Xe视频属性的抓取
# BV号为1Xa4y1j7Xe的视频属性抓取结束
# 开始BV号为1Kf4y1D7J3视频属性的抓取
# BV号为1Kf4y1D7J3的视频属性抓取结束
# 开始BV号为1n64y1F7mv视频属性的抓取
# BV号为1n64y1F7mv的视频属性抓取结束
# 开始BV号为1Sp4y1Y78w视频属性的抓取
# BV号为1Sp4y1Y78w的视频属性抓取结束
# 开始BV号为1Bh411X7r7视频属性的抓取
# BV号为1Bh411X7r7的视频属性抓取结束
# 开始BV号为1NV411m7TE视频属性的抓取
# BV号为1NV411m7TE的视频属性抓取结束
# 开始BV号为1Uv41117tu视频属性的抓取
# BV号为1Uv41117tu的视频属性抓取结束
# 开始BV号为1Dt4y1i74K视频属性的抓取
# BV号为1Dt4y1i74K的视频属性抓取结束
# 开始BV号为1JK411N79T视频属性的抓取
# BV号为1JK411N79T的视频属性抓取结束
# 开始BV号为1kA411n7vV视频属性的抓取
# BV号为1kA411n7vV的视频属性抓取结束
# 开始BV号为1EZ4y1T7Ri视频属性的抓取
# BV号为1EZ4y1T7Ri的视频属性抓取结束
# 开始BV号为11h411X7h2视频属性的抓取
# BV号为11h411X7h2的视频属性抓取结束
# 开始BV号为1yk4y1274D视频属性的抓取
# BV号为1yk4y1274D的视频属性抓取结束
# 开始BV号为1MD4y1o73x视频属性的抓取
# BV号为1MD4y1o73x的视频属性抓取结束
# 开始BV号为1t64y1F7m5视频属性的抓取
# BV号为1t64y1F7m5的视频属性抓取结束
# 开始BV号为1Jv411C7An视频属性的抓取
# BV号为1Jv411C7An的视频属性抓取结束
# 开始BV号为1Fi4y1E7Hv视频属性的抓取
# BV号为1Fi4y1E7Hv的视频属性抓取结束
# 开始BV号为1554y1k7m5视频属性的抓取
# BV号为1554y1k7m5的视频属性抓取结束
# 开始BV号为19K4y177SG视频属性的抓取
# BV号为19K4y177SG的视频属性抓取结束
# 开始BV号为1hr4y1w7sU视频属性的抓取
# BV号为1hr4y1w7sU的视频属性抓取结束
# 开始BV号为1Z5411j7e7视频属性的抓取
# BV号为1Z5411j7e7的视频属性抓取结束
# 开始BV号为11K4y187rT视频属性的抓取
# BV号为11K4y187rT的视频属性抓取结束
# 开始BV号为1mz4y1Z7gX视频属性的抓取
# BV号为1mz4y1Z7gX的视频属性抓取结束
# 开始BV号为1Mt4y1e7Uh视频属性的抓取
# BV号为1Mt4y1e7Uh的视频属性抓取结束
# 开始BV号为1Ka4y1L7sf视频属性的抓取
# BV号为1Ka4y1L7sf的视频属性抓取结束
# 开始BV号为1cT4y1F7Kv视频属性的抓取
# BV号为1cT4y1F7Kv的视频属性抓取结束
# 开始BV号为1zp4y1k7hk视频属性的抓取
# BV号为1zp4y1k7hk的视频属性抓取结束
# 开始BV号为1gA411E7p3视频属性的抓取
# BV号为1gA411E7p3的视频属性抓取结束
# 开始BV号为1s54y117AE视频属性的抓取
# BV号为1s54y117AE的视频属性抓取结束
# 开始BV号为1c54y1r765视频属性的抓取
# BV号为1c54y1r765的视频属性抓取结束
# 开始BV号为1Gt4y1i7NE视频属性的抓取
# BV号为1Gt4y1i7NE的视频属性抓取结束
# 开始BV号为18p4y1k7GR视频属性的抓取
# BV号为18p4y1k7GR的视频属性抓取结束
# 开始BV号为19y4y1k75o视频属性的抓取
# BV号为19y4y1k75o的视频属性抓取结束
# 开始BV号为1HD4y1d7UK视频属性的抓取
# BV号为1HD4y1d7UK的视频属性抓取结束
# 开始BV号为17A41177U5视频属性的抓取
# BV号为17A41177U5的视频属性抓取结束
# 开始BV号为1Ua4y157sw视频属性的抓取
# BV号为1Ua4y157sw的视频属性抓取结束
# 开始BV号为1Ta411A7bM视频属性的抓取
# BV号为1Ta411A7bM的视频属性抓取结束
# 开始BV号为1EA411E7Pv视频属性的抓取
# BV号为1EA411E7Pv的视频属性抓取结束
# 开始BV号为1di4y1E7h4视频属性的抓取
# BV号为1di4y1E7h4的视频属性抓取结束
# 开始BV号为1Cv41167b6视频属性的抓取
# BV号为1Cv41167b6的视频属性抓取结束
# 开始BV号为1Pz4y1f7Hb视频属性的抓取
# BV号为1Pz4y1f7Hb的视频属性抓取结束
# 开始BV号为1pT4y1w7v2视频属性的抓取
# BV号为1pT4y1w7v2的视频属性抓取结束
# 开始BV号为1154y1y736视频属性的抓取
# BV号为1154y1y736的视频属性抓取结束
# 开始BV号为1qV41117M2视频属性的抓取
# BV号为1qV41117M2的视频属性抓取结束
# 开始BV号为12i4y1j7YX视频属性的抓取
# BV号为12i4y1j7YX的视频属性抓取结束
# 开始BV号为1Sv411k7kf视频属性的抓取
# BV号为1Sv411k7kf的视频属性抓取结束
# 开始BV号为1dA411L7g3视频属性的抓取
# BV号为1dA411L7g3的视频属性抓取结束
# 开始BV号为1XK411A7cg视频属性的抓取
# BV号为1XK411A7cg的视频属性抓取结束
# 开始BV号为1h54y1k7sM视频属性的抓取
# BV号为1h54y1k7sM的视频属性抓取结束
# 开始BV号为1Ca4y1L7Do视频属性的抓取
# BV号为1Ca4y1L7Do的视频属性抓取结束
# 开始BV号为1Q54y167gJ视频属性的抓取
# BV号为1Q54y167gJ的视频属性抓取结束
# 开始BV号为1TA411J7CK视频属性的抓取
# BV号为1TA411J7CK的视频属性抓取结束
# 开始BV号为1rD4y1R7H7视频属性的抓取
# BV号为1rD4y1R7H7的视频属性抓取结束
# 开始BV号为1a54y1r7i1视频属性的抓取
# BV号为1a54y1r7i1的视频属性抓取结束
# 开始BV号为1Jr4y1w7RZ视频属性的抓取
# BV号为1Jr4y1w7RZ的视频属性抓取结束
# 开始BV号为1p5411L7Tz视频属性的抓取
# BV号为1p5411L7Tz的视频属性抓取结束
# 开始BV号为1h54y117Ng视频属性的抓取
# BV号为1h54y117Ng的视频属性抓取结束
# 开始BV号为1j54y1k7AE视频属性的抓取
# BV号为1j54y1k7AE的视频属性抓取结束
# 开始BV号为1ay4y1r7q5视频属性的抓取
# BV号为1ay4y1r7q5的视频属性抓取结束
# 开始BV号为18Z4y157Pe视频属性的抓取
# BV号为18Z4y157Pe的视频属性抓取结束
# 开始BV号为1ca4y1L7uX视频属性的抓取
# BV号为1ca4y1L7uX的视频属性抓取结束
# 开始BV号为1sz4y1o7ib视频属性的抓取
# BV号为1sz4y1o7ib的视频属性抓取结束
# 开始BV号为1TD4y1d7EF视频属性的抓取
# BV号为1TD4y1d7EF的视频属性抓取结束
# 开始BV号为1xf4y1B7zD视频属性的抓取
# BV号为1xf4y1B7zD的视频属性抓取结束
# 开始BV号为1yz4y1Z7em视频属性的抓取
# BV号为1yz4y1Z7em的视频属性抓取结束
# 开始BV号为1fz4y1d7cy视频属性的抓取
# BV号为1fz4y1d7cy的视频属性抓取结束
# 开始BV号为1RK4y187mL视频属性的抓取
# BV号为1RK4y187mL的视频属性抓取结束
# 开始BV号为1iZ4y157E4视频属性的抓取
# BV号为1iZ4y157E4的视频属性抓取结束
# 开始BV号为1ET4y1w7DT视频属性的抓取
# BV号为1ET4y1w7DT的视频属性抓取结束
# 开始BV号为1754y1C7FT视频属性的抓取
# BV号为1754y1C7FT的视频属性抓取结束
# 开始BV号为1GV411y7Ro视频属性的抓取
# BV号为1GV411y7Ro的视频属性抓取结束
# 开始BV号为1X54y117CG视频属性的抓取
# BV号为1X54y117CG的视频属性抓取结束
# 开始BV号为1XK4y17716视频属性的抓取
# BV号为1XK4y17716的视频属性抓取结束
# 开始BV号为19v411k7Wt视频属性的抓取
# BV号为19v411k7Wt的视频属性抓取结束
# 开始BV号为1Lh41197Zn视频属性的抓取
# BV号为1Lh41197Zn的视频属性抓取结束
# 开始BV号为1Ka411A76X视频属性的抓取
# BV号为1Ka411A76X的视频属性抓取结束
# 开始BV号为1Zf4y1D7fm视频属性的抓取
# BV号为1Zf4y1D7fm的视频属性抓取结束
# 开始BV号为1Fv411k7Zg视频属性的抓取
# BV号为1Fv411k7Zg的视频属性抓取结束
# 开始BV号为1uy4y1r7Yp视频属性的抓取
# BV号为1uy4y1r7Yp的视频属性抓取结束
# 开始BV号为1Dt4y1v7E5视频属性的抓取
# BV号为1Dt4y1v7E5的视频属性抓取结束
# 开始BV号为1DK411P7Yr视频属性的抓取
# BV号为1DK411P7Yr的视频属性抓取结束
# 开始BV号为1aA41177a3视频属性的抓取
# BV号为1aA41177a3的视频属性抓取结束
# 开始BV号为16v411k7S7视频属性的抓取
# BV号为16v411k7S7的视频属性抓取结束
# 开始BV号为1xt4y1i7oe视频属性的抓取
# BV号为1xt4y1i7oe的视频属性抓取结束
# 开始BV号为1Kz4y1f76K视频属性的抓取
# BV号为1Kz4y1f76K的视频属性抓取结束
# 开始BV号为1qy4y1r7Rf视频属性的抓取
# BV号为1qy4y1r7Rf的视频属性抓取结束
# 开始BV号为1dp4y1a7WB视频属性的抓取
# BV号为1dp4y1a7WB的视频属性抓取结束
# 开始BV号为1cv411k7fP视频属性的抓取
# BV号为1cv411k7fP的视频属性抓取结束
# 开始BV号为1pD4y197aD视频属性的抓取
# BV号为1pD4y197aD的视频属性抓取结束
# 开始BV号为1Kz4y1o7fD视频属性的抓取
# BV号为1Kz4y1o7fD的视频属性抓取结束
# 开始BV号为1wy4y1C7wC视频属性的抓取
# BV号为1wy4y1C7wC的视频属性抓取结束
# 开始BV号为17V41127Gv视频属性的抓取
# BV号为17V41127Gv的视频属性抓取结束
# 开始BV号为1Ey4y1C7ib视频属性的抓取
# BV号为1Ey4y1C7ib的视频属性抓取结束
# 开始BV号为1e5411j7uE视频属性的抓取
# BV号为1e5411j7uE的视频属性抓取结束
# 开始BV号为1f541157H9视频属性的抓取
# BV号为1f541157H9的视频属性抓取结束
# 开始BV号为1yz4y1d76g视频属性的抓取
# BV号为1yz4y1d76g的视频属性抓取结束
# 开始BV号为1Cy4y1z7fv视频属性的抓取
# BV号为1Cy4y1z7fv的视频属性抓取结束
# 开始BV号为13p4y1k7JY视频属性的抓取
# BV号为13p4y1k7JY的视频属性抓取结束
# 开始BV号为1ny4y1B7JN视频属性的抓取
# BV号为1ny4y1B7JN的视频属性抓取结束
# 开始BV号为1JD4y197iX视频属性的抓取
# BV号为1JD4y197iX的视频属性抓取结束
# 开始BV号为1Ey4y1B7na视频属性的抓取
# BV号为1Ey4y1B7na的视频属性抓取结束
# 开始BV号为1ez4y1C7MU视频属性的抓取
# BV号为1ez4y1C7MU的视频属性抓取结束
# 开始BV号为1iV411y7hq视频属性的抓取
# BV号为1iV411y7hq的视频属性抓取结束
# 开始BV号为1Xr4y1c7xz视频属性的抓取
# BV号为1Xr4y1c7xz的视频属性抓取结束
# 开始BV号为1QK4y187zW视频属性的抓取
# BV号为1QK4y187zW的视频属性抓取结束
# 开始BV号为1vK411G7gZ视频属性的抓取
# BV号为1vK411G7gZ的视频属性抓取结束
# 开始BV号为1D5411j7qP视频属性的抓取
# BV号为1D5411j7qP的视频属性抓取结束
# 开始BV号为1bT4y1F78W视频属性的抓取
# BV号为1bT4y1F78W的视频属性抓取结束
# 开始BV号为1Na411A7Ep视频属性的抓取
# BV号为1Na411A7Ep的视频属性抓取结束
# 开始BV号为1kA411J7n4视频属性的抓取
# BV号为1kA411J7n4的视频属性抓取结束
# 开始BV号为1pD4y1d78C视频属性的抓取
# BV号为1pD4y1d78C的视频属性抓取结束
# 开始BV号为1HK411A7ka视频属性的抓取
# BV号为1HK411A7ka的视频属性抓取结束
# 开始BV号为1j54y1k7HL视频属性的抓取
# BV号为1j54y1k7HL的视频属性抓取结束
# 开始BV号为18Z4y1V7Ck视频属性的抓取
# BV号为18Z4y1V7Ck的视频属性抓取结束
# 开始BV号为1VV411y7cL视频属性的抓取
# BV号为1VV411y7cL的视频属性抓取结束
# 开始BV号为1R54y117GW视频属性的抓取
# BV号为1R54y117GW的视频属性抓取结束
# 开始BV号为1cz4y1o7YV视频属性的抓取
# BV号为1cz4y1o7YV的视频属性抓取结束
# 2020-12-23 18:32:15.709655

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-14-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_youxi_danji.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月     97   97    97   97   97   97   97   97    97      97   97    97   97
# 4月     95   95    95   95   95   95   95   95    95      95   95    95   95
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月     98   98    98   98   98   98   98   98    98      98   98    98   98
# 7月     94   94    94   94   94   94   94   94    94      94   94    94   94
# 8月     90   90    90   90   90   90   90   90    90      90   90    90   90
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月    99   99   99   99   99   99    99
# 2月   100  100  100  100  100  100   100
# 3月    97   97   97   97   97   97    97
# 4月    95   95   95   95   95   95    95
# 5月   100  100  100  100  100  100   100
# 6月    98   98   98   98   98   98    98
# 7月    94   94   94   94   94   94    94
# 8月    90   90   90   90   90   90    90
# 9月   100  100  100  100  100  100   100

# %%
channel_youxi_danji.to_json('channel_youxi_danji.json')

# %%
pd.set_option('display.max_rows', None)

# %%
channel_youxi_danji[channel_youxi_danji['时间']=='4月']
# Out:
#             时间            作者名  作者类型      粉丝数   投稿数  \
# 1h54y1d7Qq  4月            鹤吱菌  个人认证   191.3万    81
# 1L64y1M7Dp  4月            老番茄  个人认证  1360.1万   348
# 18K41157Tu  4月            老番茄  个人认证  1360.1万   348
# 1PT4y1G7ME  4月            老番茄  个人认证  1360.1万   348
# 1S54y197uX  4月           徐大虾咯  个人认证   570.1万   224
# 1ti4y1t7YM  4月            老番茄  个人认证  1360.1万   348
# 1Ai4y1b7ET  4月            敖厂长  个人认证   735.1万   348
# 1Up4y1C7PB  4月        丢鹏D1uuu     无     8.4万    20
# 1wi4y187bu  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 13t4y1U7kQ  4月           徐大虾咯  个人认证   570.1万   224
# 1fe411x7FA  4月         芦苇草的梦想  个人认证    29.3万   726
