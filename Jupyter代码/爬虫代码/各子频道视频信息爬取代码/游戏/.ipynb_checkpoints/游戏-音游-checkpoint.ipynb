# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_youxi_yinyou=pd.DataFrame(columns=columns)
channel_youxi_yinyou
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[6]/div/a/span').click()  #选择频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[6]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '游戏'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[8]/a').click()  #选择子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[8]/a').text
sub_channel
# Out:
# '音游'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(1,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            ### 获取发布日期 ###
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_youxi_yinyou.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-16 00:16:14.499789
# <ipython-input-11-031d135edb76>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-11-031d135edb76>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-11-031d135edb76>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1dJ411n7JG视频属性的抓取
# BV号为1dJ411n7JG的视频属性抓取结束
# <ipython-input-11-031d135edb76>:181: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1ZJ411G7PJ视频属性的抓取
# BV号为1ZJ411G7PJ的视频属性抓取结束
# 开始BV号为1t7411Y7a5视频属性的抓取
# BV号为1t7411Y7a5的视频属性抓取结束
# 开始BV号为1DJ411G7Cq视频属性的抓取
# BV号为1DJ411G7Cq的视频属性抓取结束
# 开始BV号为1m7411e72Q视频属性的抓取
# BV号为1m7411e72Q的视频属性抓取结束
# 开始BV号为167411q7FJ视频属性的抓取
# BV号为167411q7FJ的视频属性抓取结束
# 开始BV号为15J411J7FH视频属性的抓取
# BV号为15J411J7FH的视频属性抓取结束
# 开始BV号为1r741167vG视频属性的抓取
# BV号为1r741167vG的视频属性抓取结束
# 开始BV号为1D7411B7Mn视频属性的抓取
# 开始BV号为1D7411B7Mn视频属性的抓取
# BV号为1D7411B7Mn的视频属性抓取结束
# 开始BV号为1RJ411J7pZ视频属性的抓取
# BV号为1RJ411J7pZ的视频属性抓取结束
# 开始BV号为1MJ411n7k1视频属性的抓取
# BV号为1MJ411n7k1的视频属性抓取结束
# 开始BV号为1gJ411j7C6视频属性的抓取
# 开始BV号为1gJ411j7C6视频属性的抓取
# BV号为1gJ411j7C6的视频属性抓取结束
# 开始BV号为1RJ41157Vo视频属性的抓取
# BV号为1RJ41157Vo的视频属性抓取结束
# 开始BV号为1dJ411G7a6视频属性的抓取
# BV号为1dJ411G7a6的视频属性抓取结束
# 开始BV号为1MJ411n74K视频属性的抓取
# BV号为1MJ411n74K的视频属性抓取结束
# 开始BV号为157411i7uN视频属性的抓取
# BV号为157411i7uN的视频属性抓取结束
# 开始BV号为1m741167Dg视频属性的抓取
# BV号为1m741167Dg的视频属性抓取结束
# 开始BV号为1nJ41157Dc视频属性的抓取
# BV号为1nJ41157Dc的视频属性抓取结束
# 开始BV号为11741167YG视频属性的抓取
# BV号为11741167YG的视频属性抓取结束
# 开始BV号为1cJ411L7nF视频属性的抓取
# BV号为1cJ411L7nF的视频属性抓取结束
# 开始BV号为16J411j7v6视频属性的抓取
# BV号为16J411j7v6的视频属性抓取结束
# 开始BV号为19J411L7ht视频属性的抓取
# BV号为19J411L7ht的视频属性抓取结束
# 开始BV号为1eJ411E7aw视频属性的抓取
# BV号为1eJ411E7aw的视频属性抓取结束
# 开始BV号为1T7411Y7jZ视频属性的抓取
# BV号为1T7411Y7jZ的视频属性抓取结束
# 开始BV号为1gJ411J7Fm视频属性的抓取
# BV号为1gJ411J7Fm的视频属性抓取结束
# 开始BV号为1uJ411n7T8视频属性的抓取
# BV号为1uJ411n7T8的视频属性抓取结束
# 开始BV号为1f7411Y7XT视频属性的抓取
# BV号为1f7411Y7XT的视频属性抓取结束
# 开始BV号为117411v7Gm视频属性的抓取
# BV号为117411v7Gm的视频属性抓取结束
# 开始BV号为18J411J7GS视频属性的抓取
# BV号为18J411J7GS的视频属性抓取结束
# 开始BV号为11J411j7qF视频属性的抓取
# BV号为11J411j7qF的视频属性抓取结束
# 开始BV号为1U7411r7Er视频属性的抓取
# BV号为1U7411r7Er的视频属性抓取结束
# 开始BV号为1U7411q7Xf视频属性的抓取
# BV号为1U7411q7Xf的视频属性抓取结束
# 开始BV号为11J411a7oP视频属性的抓取
# BV号为11J411a7oP的视频属性抓取结束
# 开始BV号为1tJ411H7KV视频属性的抓取
# BV号为1tJ411H7KV的视频属性抓取结束
# 开始BV号为1k7411q7LW视频属性的抓取
# BV号为1k7411q7LW的视频属性抓取结束
# 开始BV号为137411z7NQ视频属性的抓取
# BV号为137411z7NQ的视频属性抓取结束
# 开始BV号为11J411p7EK视频属性的抓取
# BV号为11J411p7EK的视频属性抓取结束
# 开始BV号为1ZJ411E7iD视频属性的抓取
# BV号为1ZJ411E7iD的视频属性抓取结束
# 开始BV号为1r7411k7fR视频属性的抓取
# BV号为1r7411k7fR的视频属性抓取结束
# 开始BV号为1tJ411J71m视频属性的抓取
# BV号为1tJ411J71m的视频属性抓取结束
# 开始BV号为1b7411e7cV视频属性的抓取
# BV号为1b7411e7cV的视频属性抓取结束
# 开始BV号为1jJ411n7Vw视频属性的抓取
# BV号为1jJ411n7Vw的视频属性抓取结束
# 开始BV号为167411s7Px视频属性的抓取
# BV号为167411s7Px的视频属性抓取结束
# 开始BV号为1pJ411h7ja视频属性的抓取
# BV号为1pJ411h7ja的视频属性抓取结束
# 开始BV号为1C7411Y7jr视频属性的抓取
# BV号为1C7411Y7jr的视频属性抓取结束
# 开始BV号为1y7411e7FH视频属性的抓取
# BV号为1y7411e7FH的视频属性抓取结束
# 开始BV号为14J411L7vj视频属性的抓取
# BV号为14J411L7vj的视频属性抓取结束
# 开始BV号为13J411E7HH视频属性的抓取
# BV号为13J411E7HH的视频属性抓取结束
# 开始BV号为1gJ411p7ZH视频属性的抓取
# BV号为1gJ411p7ZH的视频属性抓取结束
# 开始BV号为1RJ411J75X视频属性的抓取
# BV号为1RJ411J75X的视频属性抓取结束
# 开始BV号为1sJ41177T1视频属性的抓取
# BV号为1sJ41177T1的视频属性抓取结束
# 开始BV号为1m7411a7KN视频属性的抓取
# BV号为1m7411a7KN的视频属性抓取结束
# 开始BV号为1Y7411k7eU视频属性的抓取
# BV号为1Y7411k7eU的视频属性抓取结束
# 开始BV号为1m7411i7kH视频属性的抓取
# 开始BV号为1m7411i7kH视频属性的抓取
# BV号为1m7411i7kH的视频属性抓取结束
# 开始BV号为1Q7411q7e8视频属性的抓取
# BV号为1Q7411q7e8的视频属性抓取结束
# 开始BV号为1JJ41177ys视频属性的抓取
# BV号为1JJ41177ys的视频属性抓取结束
# 开始BV号为1xJ411p7xS视频属性的抓取
# BV号为1xJ411p7xS的视频属性抓取结束
# 开始BV号为1hJ411n7Ab视频属性的抓取
# BV号为1hJ411n7Ab的视频属性抓取结束
# 开始BV号为1K7411r7Mk视频属性的抓取
# BV号为1K7411r7Mk的视频属性抓取结束
# 开始BV号为1p7411Y7ST视频属性的抓取
# BV号为1p7411Y7ST的视频属性抓取结束
# 开始BV号为1VJ411H7d2视频属性的抓取
# BV号为1VJ411H7d2的视频属性抓取结束
# 开始BV号为1CJ411j7JG视频属性的抓取
# BV号为1CJ411j7JG的视频属性抓取结束
# 开始BV号为1n7411B7gj视频属性的抓取
# BV号为1n7411B7gj的视频属性抓取结束
# 开始BV号为1H7411a79C视频属性的抓取
# BV号为1H7411a79C的视频属性抓取结束
# 开始BV号为1tJ411V7rR视频属性的抓取
# BV号为1tJ411V7rR的视频属性抓取结束
# 开始BV号为1z741167ax视频属性的抓取
# BV号为1z741167ax的视频属性抓取结束
# 开始BV号为1CJ411E7rT视频属性的抓取
# BV号为1CJ411E7rT的视频属性抓取结束
# 开始BV号为1y7411B7tp视频属性的抓取
# BV号为1y7411B7tp的视频属性抓取结束
# 开始BV号为1aJ411H7YK视频属性的抓取
# BV号为1aJ411H7YK的视频属性抓取结束
# 开始BV号为1GJ411E7uF视频属性的抓取
# BV号为1GJ411E7uF的视频属性抓取结束
# 开始BV号为157411v7wH视频属性的抓取
# BV号为157411v7wH的视频属性抓取结束
# 开始BV号为1u7411q7LM视频属性的抓取
# BV号为1u7411q7LM的视频属性抓取结束
# 开始BV号为1g7411Y73v视频属性的抓取
# BV号为1g7411Y73v的视频属性抓取结束
# 开始BV号为167411v7tV视频属性的抓取
# BV号为167411v7tV的视频属性抓取结束
# 开始BV号为1z7411z729视频属性的抓取
# BV号为1z7411z729的视频属性抓取结束
# 开始BV号为1p7411v7Nr视频属性的抓取
# BV号为1p7411v7Nr的视频属性抓取结束
# 开始BV号为17J41187cd视频属性的抓取
# BV号为17J41187cd的视频属性抓取结束
# 开始BV号为1rJ411b7hB视频属性的抓取
# BV号为1rJ411b7hB的视频属性抓取结束
# 开始BV号为1M7411z7rr视频属性的抓取
# BV号为1M7411z7rr的视频属性抓取结束
# 开始BV号为17J411b7Ut视频属性的抓取
# BV号为17J411b7Ut的视频属性抓取结束
# 开始BV号为1u7411k7ou视频属性的抓取
# BV号为1u7411k7ou的视频属性抓取结束
# 开始BV号为1oJ411b7sv视频属性的抓取
# BV号为1oJ411b7sv的视频属性抓取结束
# 开始BV号为1i7411a7FU视频属性的抓取
# BV号为1i7411a7FU的视频属性抓取结束
# 开始BV号为1v7411B7bT视频属性的抓取
# BV号为1v7411B7bT的视频属性抓取结束
# 开始BV号为1q7411r7Wh视频属性的抓取
# BV号为1q7411r7Wh的视频属性抓取结束
# 开始BV号为147411i7Cc视频属性的抓取
# BV号为147411i7Cc的视频属性抓取结束
# 开始BV号为1V741167j2视频属性的抓取
# BV号为1V741167j2的视频属性抓取结束
# 开始BV号为1VJ4118796视频属性的抓取
# BV号为1VJ4118796的视频属性抓取结束
# 开始BV号为1H7411k7mb视频属性的抓取
# BV号为1H7411k7mb的视频属性抓取结束
# 开始BV号为1f7411v7Lo视频属性的抓取
# BV号为1f7411v7Lo的视频属性抓取结束
# 开始BV号为1r7411e7zc视频属性的抓取
# BV号为1r7411e7zc的视频属性抓取结束
# 开始BV号为1G7411B79g视频属性的抓取
# BV号为1G7411B79g的视频属性抓取结束
# 开始BV号为1s7411r7Z7视频属性的抓取
# BV号为1s7411r7Z7的视频属性抓取结束
# 开始BV号为1sJ411L7n9视频属性的抓取
# BV号为1sJ411L7n9的视频属性抓取结束
# 开始BV号为1S7411Y7uj视频属性的抓取
# BV号为1S7411Y7uj的视频属性抓取结束
# 开始BV号为127411k75h视频属性的抓取
# BV号为127411k75h的视频属性抓取结束
# 开始BV号为1tJ411V71Y视频属性的抓取
# BV号为1tJ411V71Y的视频属性抓取结束
# 开始BV号为1yJ411p768视频属性的抓取
# BV号为1yJ411p768的视频属性抓取结束
# 开始BV号为1q7411r76h视频属性的抓取
# BV号为1q7411r76h的视频属性抓取结束
# 开始BV号为1N7411e7JH视频属性的抓取
# BV号为1N7411e7JH的视频属性抓取结束
# 开始BV号为1p741157Fs视频属性的抓取
# BV号为1p741157Fs的视频属性抓取结束
# 开始BV号为1U7411j7FJ视频属性的抓取
# BV号为1U7411j7FJ的视频属性抓取结束
# 开始BV号为1t741147Xg视频属性的抓取
# BV号为1t741147Xg的视频属性抓取结束
# 开始BV号为1B7411h74N视频属性的抓取
# BV号为1B7411h74N的视频属性抓取结束
# 开始BV号为1pj411f7o9视频属性的抓取
# BV号为1pj411f7o9的视频属性抓取结束
# 开始BV号为1P7411W7cq视频属性的抓取
# BV号为1P7411W7cq的视频属性抓取结束
# 开始BV号为12j411f7eS视频属性的抓取
# 开始BV号为12j411f7eS视频属性的抓取
# BV号为12j411f7eS的视频属性抓取结束
# 开始BV号为1M7411p7YS视频属性的抓取
# BV号为1M7411p7YS的视频属性抓取结束
# 开始BV号为1S7411875d视频属性的抓取
# BV号为1S7411875d的视频属性抓取结束
# 开始BV号为157411s7L8视频属性的抓取
# BV号为157411s7L8的视频属性抓取结束
# 开始BV号为1Y7411x7ZQ视频属性的抓取
# BV号为1Y7411x7ZQ的视频属性抓取结束
# 开始BV号为1S741157we视频属性的抓取
# BV号为1S741157we的视频属性抓取结束
# 开始BV号为1X741157k6视频属性的抓取
# 开始BV号为1X741157k6视频属性的抓取
# BV号为1X741157k6的视频属性抓取结束
# 开始BV号为117411N7X1视频属性的抓取
# BV号为117411N7X1的视频属性抓取结束
# 开始BV号为1g7411A7dC视频属性的抓取
# BV号为1g7411A7dC的视频属性抓取结束
# 开始BV号为177411E7V6视频属性的抓取
# BV号为177411E7V6的视频属性抓取结束
# 开始BV号为1x7411w7Lz视频属性的抓取
# BV号为1x7411w7Lz的视频属性抓取结束
# 开始BV号为1p7411u7Nm视频属性的抓取
# BV号为1p7411u7Nm的视频属性抓取结束
# 开始BV号为1G7411E7em视频属性的抓取
# BV号为1G7411E7em的视频属性抓取结束
# 开始BV号为1L7411p7Qv视频属性的抓取
# BV号为1L7411p7Qv的视频属性抓取结束
# 开始BV号为1T741187ZL视频属性的抓取
# BV号为1T741187ZL的视频属性抓取结束
# 开始BV号为1P741157kT视频属性的抓取
# BV号为1P741157kT的视频属性抓取结束
# 开始BV号为1w7411s7ch视频属性的抓取
# BV号为1w7411s7ch的视频属性抓取结束
# 开始BV号为1Q7411u7hV视频属性的抓取
# BV号为1Q7411u7hV的视频属性抓取结束
# 开始BV号为1Z7411s7gW视频属性的抓取
# BV号为1Z7411s7gW的视频属性抓取结束
# 开始BV号为1w7411p7PG视频属性的抓取
# BV号为1w7411p7PG的视频属性抓取结束
# 开始BV号为187411H7kC视频属性的抓取
# BV号为187411H7kC的视频属性抓取结束
# 开始BV号为1f7411t7ax视频属性的抓取
# BV号为1f7411t7ax的视频属性抓取结束
# 开始BV号为1cE411H7tr视频属性的抓取
# BV号为1cE411H7tr的视频属性抓取结束
# 开始BV号为1V7411b7wV视频属性的抓取
# BV号为1V7411b7wV的视频属性抓取结束
# 开始BV号为1S7411h75T视频属性的抓取
# BV号为1S7411h75T的视频属性抓取结束
# 开始BV号为1D7411471g视频属性的抓取
# BV号为1D7411471g的视频属性抓取结束
# 开始BV号为1E7411j7Yf视频属性的抓取
# BV号为1E7411j7Yf的视频属性抓取结束
# 开始BV号为1N7411p7VE视频属性的抓取
# BV号为1N7411p7VE的视频属性抓取结束
# 开始BV号为1u7411H7AU视频属性的抓取
# BV号为1u7411H7AU的视频属性抓取结束
# 开始BV号为1T7411A7rG视频属性的抓取
# BV号为1T7411A7rG的视频属性抓取结束
# 开始BV号为15741187YZ视频属性的抓取
# BV号为15741187YZ的视频属性抓取结束
# 开始BV号为167411u7bb视频属性的抓取
# BV号为167411u7bb的视频属性抓取结束
# 开始BV号为1h741187CS视频属性的抓取
# BV号为1h741187CS的视频属性抓取结束
# 开始BV号为117411u7Do视频属性的抓取
# BV号为117411u7Do的视频属性抓取结束
# 开始BV号为1C741137dA视频属性的抓取
# BV号为1C741137dA的视频属性抓取结束
# 开始BV号为1i7411374h视频属性的抓取
# BV号为1i7411374h的视频属性抓取结束
# 开始BV号为1z741177z9视频属性的抓取
# BV号为1z741177z9的视频属性抓取结束
# 开始BV号为1j7411b7Y4视频属性的抓取
# BV号为1j7411b7Y4的视频属性抓取结束
# 开始BV号为1f741137Vx视频属性的抓取
# BV号为1f741137Vx的视频属性抓取结束
# 开始BV号为1r7411W7cs视频属性的抓取
# BV号为1r7411W7cs的视频属性抓取结束
# 开始BV号为1Q741147aw视频属性的抓取
# BV号为1Q741147aw的视频属性抓取结束
# 开始BV号为1S7411s73w视频属性的抓取
# BV号为1S7411s73w的视频属性抓取结束
# 开始BV号为1ej411f7fZ视频属性的抓取
# BV号为1ej411f7fZ的视频属性抓取结束
# 开始BV号为1P7411P7B2视频属性的抓取
# BV号为1P7411P7B2的视频属性抓取结束
# 开始BV号为1g7411n7E9视频属性的抓取
# BV号为1g7411n7E9的视频属性抓取结束
# 开始BV号为1b741157TE视频属性的抓取
# BV号为1b741157TE的视频属性抓取结束
# 开始BV号为1p7411776z视频属性的抓取
# BV号为1p7411776z的视频属性抓取结束
# 开始BV号为1w7411E7wu视频属性的抓取
# BV号为1w7411E7wu的视频属性抓取结束
# 开始BV号为1o7411P7US视频属性的抓取
# BV号为1o7411P7US的视频属性抓取结束
# 开始BV号为1m7411F7NM视频属性的抓取
# BV号为1m7411F7NM的视频属性抓取结束
# 开始BV号为1gE411H7ta视频属性的抓取
# BV号为1gE411H7ta的视频属性抓取结束
# 开始BV号为1i7411P746视频属性的抓取
# BV号为1i7411P746的视频属性抓取结束
# 开始BV号为1u741157XW视频属性的抓取
# BV号为1u741157XW的视频属性抓取结束
# 开始BV号为117411E7uf视频属性的抓取
# BV号为117411E7uf的视频属性抓取结束
# 开始BV号为1K7411H7CU视频属性的抓取
# BV号为1K7411H7CU的视频属性抓取结束
# 开始BV号为12741147mh视频属性的抓取
# BV号为12741147mh的视频属性抓取结束
# 开始BV号为1Z7411W7eo视频属性的抓取
# BV号为1Z7411W7eo的视频属性抓取结束
# 开始BV号为1N7411P7gY视频属性的抓取
# BV号为1N7411P7gY的视频属性抓取结束
# 开始BV号为1d741137T9视频属性的抓取
# BV号为1d741137T9的视频属性抓取结束
# 开始BV号为167411n7E5视频属性的抓取
# BV号为167411n7E5的视频属性抓取结束
# 开始BV号为1E7411E7Rg视频属性的抓取
# BV号为1E7411E7Rg的视频属性抓取结束
# 开始BV号为1j7411x7uu视频属性的抓取
# BV号为1j7411x7uu的视频属性抓取结束
# 开始BV号为1v7411t7AU视频属性的抓取
# BV号为1v7411t7AU的视频属性抓取结束
# 开始BV号为1F7411L7oM视频属性的抓取
# BV号为1F7411L7oM的视频属性抓取结束
# 开始BV号为1KE411J7Fs视频属性的抓取
# BV号为1KE411J7Fs的视频属性抓取结束
# 开始BV号为1D741177tM视频属性的抓取
# BV号为1D741177tM的视频属性抓取结束
# 开始BV号为1RE411n7WS视频属性的抓取
# BV号为1RE411n7WS的视频属性抓取结束
# 开始BV号为1b7411t7ax视频属性的抓取
# BV号为1b7411t7ax的视频属性抓取结束
# 开始BV号为1F7411N7Mc视频属性的抓取
# BV号为1F7411N7Mc的视频属性抓取结束
# 开始BV号为1z7411x7TF视频属性的抓取
# BV号为1z7411x7TF的视频属性抓取结束
# 开始BV号为1r7411F7jp视频属性的抓取
# BV号为1r7411F7jp的视频属性抓取结束
# 开始BV号为1g7411a7Km视频属性的抓取
# BV号为1g7411a7Km的视频属性抓取结束
# 开始BV号为1g7411x7RN视频属性的抓取
# BV号为1g7411x7RN的视频属性抓取结束
# 开始BV号为1v7411W7Va视频属性的抓取
# BV号为1v7411W7Va的视频属性抓取结束
# 开始BV号为1Q7411P7v2视频属性的抓取
# BV号为1Q7411P7v2的视频属性抓取结束
# 开始BV号为1h7411s7rS视频属性的抓取
# BV号为1h7411s7rS的视频属性抓取结束
# 开始BV号为1F7411K7tE视频属性的抓取
# BV号为1F7411K7tE的视频属性抓取结束
# 开始BV号为1d7411H7Rb视频属性的抓取
# BV号为1d7411H7Rb的视频属性抓取结束
# 开始BV号为1K7411s7k2视频属性的抓取
# BV号为1K7411s7k2的视频属性抓取结束
# 开始BV号为1p7411772M视频属性的抓取
# BV号为1p7411772M的视频属性抓取结束
# 开始BV号为1A7411x7wj视频属性的抓取
# BV号为1A7411x7wj的视频属性抓取结束
# 开始BV号为1u7411g7bt视频属性的抓取
# BV号为1u7411g7bt的视频属性抓取结束
# 开始BV号为1H7411K7km视频属性的抓取
# BV号为1H7411K7km的视频属性抓取结束
# 开始BV号为1E7411c7nt视频属性的抓取
# BV号为1E7411c7nt的视频属性抓取结束
# 开始BV号为1A7411w7Lx视频属性的抓取
# BV号为1A7411w7Lx的视频属性抓取结束
# 开始BV号为1F7411p7QL视频属性的抓取
# BV号为1F7411p7QL的视频属性抓取结束
# 开始BV号为197411g7LV视频属性的抓取
# BV号为197411g7LV的视频属性抓取结束
# 开始BV号为1o7411t7r1视频属性的抓取
# BV号为1o7411t7r1的视频属性抓取结束
# 开始BV号为1h7411c7GE视频属性的抓取
# BV号为1h7411c7GE的视频属性抓取结束
# 开始BV号为1q7411g73e视频属性的抓取
# BV号为1q7411g73e的视频属性抓取结束
# 开始BV号为1L741157R3视频属性的抓取
# BV号为1L741157R3的视频属性抓取结束
# 开始BV号为16E411J723视频属性的抓取
# 开始BV号为16E411J723视频属性的抓取
# BV号为16E411J723的视频属性抓取结束
# 开始BV号为1v7411A7vY视频属性的抓取
# BV号为1v7411A7vY的视频属性抓取结束
# 开始BV号为1P7411V7Be视频属性的抓取
# BV号为1P7411V7Be的视频属性抓取结束
# 开始BV号为1XE411N7o6视频属性的抓取
# BV号为1XE411N7o6的视频属性抓取结束
# 开始BV号为1i7411y7yv视频属性的抓取
# BV号为1i7411y7yv的视频属性抓取结束
# 开始BV号为1EE411E7Lz视频属性的抓取
# BV号为1EE411E7Lz的视频属性抓取结束
# 开始BV号为1pE411K7VM视频属性的抓取
# 开始BV号为1pE411K7VM视频属性的抓取
# BV号为1pE411K7VM的视频属性抓取结束
# 开始BV号为1zE411P7Up视频属性的抓取
# BV号为1zE411P7Up的视频属性抓取结束
# 开始BV号为1ep4y117ZN视频属性的抓取
# BV号为1ep4y117ZN的视频属性抓取结束
# 开始BV号为1zE411P7wm视频属性的抓取
# BV号为1zE411P7wm的视频属性抓取结束
# 开始BV号为1WE411N73Q视频属性的抓取
# BV号为1WE411N73Q的视频属性抓取结束
# 开始BV号为1nE411W7aM视频属性的抓取
# BV号为1nE411W7aM的视频属性抓取结束
# 开始BV号为1bE411c7gm视频属性的抓取
# BV号为1bE411c7gm的视频属性抓取结束
# 开始BV号为1Qt4y1m79u视频属性的抓取
# BV号为1Qt4y1m79u的视频属性抓取结束
# 开始BV号为17E411W71a视频属性的抓取
# BV号为17E411W71a的视频属性抓取结束
# 开始BV号为1TE411L7YZ视频属性的抓取
# BV号为1TE411L7YZ的视频属性抓取结束
# 开始BV号为1NK411L7r3视频属性的抓取
# 开始BV号为1NK411L7r3视频属性的抓取
# BV号为1NK411L7r3的视频属性抓取结束
# 开始BV号为1HE411j7YZ视频属性的抓取
# BV号为1HE411j7YZ的视频属性抓取结束
# 开始BV号为1YE411V73D视频属性的抓取
# BV号为1YE411V73D的视频属性抓取结束
# 开始BV号为1B741127eQ视频属性的抓取
# BV号为1B741127eQ的视频属性抓取结束
# 开始BV号为1JE411n7xw视频属性的抓取
# BV号为1JE411n7xw的视频属性抓取结束
# 开始BV号为1RE411s7my视频属性的抓取
# BV号为1RE411s7my的视频属性抓取结束
# 开始BV号为1SE411W7BC视频属性的抓取
# BV号为1SE411W7BC的视频属性抓取结束
# 开始BV号为1qE411T7eh视频属性的抓取
# BV号为1qE411T7eh的视频属性抓取结束
# 开始BV号为1ZE411M7uF视频属性的抓取
# BV号为1ZE411M7uF的视频属性抓取结束
# 开始BV号为1h7411f7cQ视频属性的抓取
# BV号为1h7411f7cQ的视频属性抓取结束
# 开始BV号为1ZE411G7pA视频属性的抓取
# BV号为1ZE411G7pA的视频属性抓取结束
# 开始BV号为1SE41147Qv视频属性的抓取
# 开始BV号为1SE41147Qv视频属性的抓取
# 开始BV号为1SE41147Qv视频属性的抓取
# 开始BV号为1SE41147Qv视频属性的抓取
# 开始BV号为1SE41147Qv视频属性的抓取
# 开始BV号为1SE41147Qv视频属性的抓取
# 开始BV号为1SE41147Qv视频属性的抓取
# BV号为1SE41147Qv的视频属性抓取结束
# 开始BV号为1oE411x7Rq视频属性的抓取
# BV号为1oE411x7Rq的视频属性抓取结束
# 开始BV号为1U741117Y1视频属性的抓取
# BV号为1U741117Y1的视频属性抓取结束
# 开始BV号为1qZ4y1j7UQ视频属性的抓取
# BV号为1qZ4y1j7UQ的视频属性抓取结束
# 开始BV号为1LE411j7uo视频属性的抓取
# BV号为1LE411j7uo的视频属性抓取结束
# 开始BV号为1EE411V7Wr视频属性的抓取
# BV号为1EE411V7Wr的视频属性抓取结束
# 开始BV号为1J741127EJ视频属性的抓取
# BV号为1J741127EJ的视频属性抓取结束
# 开始BV号为1hE411s7MU视频属性的抓取
# BV号为1hE411s7MU的视频属性抓取结束
# 开始BV号为19E411u7v3视频属性的抓取
# BV号为19E411u7v3的视频属性抓取结束
# 开始BV号为17E411V7vf视频属性的抓取
# BV号为17E411V7vf的视频属性抓取结束
# 开始BV号为1j7411C7Dx视频属性的抓取
# BV号为1j7411C7Dx的视频属性抓取结束
# 开始BV号为1X7411C7uT视频属性的抓取
# BV号为1X7411C7uT的视频属性抓取结束
# 开始BV号为1pK411L7ex视频属性的抓取
# BV号为1pK411L7ex的视频属性抓取结束
# 开始BV号为1QE411A7p8视频属性的抓取
# BV号为1QE411A7p8的视频属性抓取结束
# 开始BV号为11E411j7ea视频属性的抓取
# BV号为11E411j7ea的视频属性抓取结束
# 开始BV号为1DE411P7Mm视频属性的抓取
# BV号为1DE411P7Mm的视频属性抓取结束
# 开始BV号为1hT4y1573d视频属性的抓取
# BV号为1hT4y1573d的视频属性抓取结束
# 开始BV号为1k7411C7mx视频属性的抓取
# BV号为1k7411C7mx的视频属性抓取结束
# 开始BV号为1D7411R75L视频属性的抓取
# BV号为1D7411R75L的视频属性抓取结束
# 开始BV号为157411d7be视频属性的抓取
# BV号为157411d7be的视频属性抓取结束
# 开始BV号为1sE411T7je视频属性的抓取
# BV号为1sE411T7je的视频属性抓取结束
# 开始BV号为1C7411R7UG视频属性的抓取
# BV号为1C7411R7UG的视频属性抓取结束
# 开始BV号为1ZE411N7Cm视频属性的抓取
# BV号为1ZE411N7Cm的视频属性抓取结束
# 开始BV号为1P7411f74d视频属性的抓取
# BV号为1P7411f74d的视频属性抓取结束
# 开始BV号为1H7411U7Vw视频属性的抓取
# BV号为1H7411U7Vw的视频属性抓取结束
# 开始BV号为1fE411u75q视频属性的抓取
# BV号为1fE411u75q的视频属性抓取结束
# 开始BV号为1XE41137vn视频属性的抓取
# BV号为1XE41137vn的视频属性抓取结束
# 开始BV号为1FE411c7ME视频属性的抓取
# BV号为1FE411c7ME的视频属性抓取结束
# 开始BV号为1L54y1d7i3视频属性的抓取
# BV号为1L54y1d7i3的视频属性抓取结束
# 开始BV号为1oE41177hX视频属性的抓取
# BV号为1oE41177hX的视频属性抓取结束
# 开始BV号为1jE411n7fK视频属性的抓取
# BV号为1jE411n7fK的视频属性抓取结束
# 开始BV号为1zE411E7Ad视频属性的抓取
# BV号为1zE411E7Ad的视频属性抓取结束
# 开始BV号为1sE411N7nC视频属性的抓取
# BV号为1sE411N7nC的视频属性抓取结束
# 开始BV号为13E411p7cH视频属性的抓取
# BV号为13E411p7cH的视频属性抓取结束
# 开始BV号为1ZE411W7rF视频属性的抓取
# BV号为1ZE411W7rF的视频属性抓取结束
# 开始BV号为1RE41137Tc视频属性的抓取
# BV号为1RE41137Tc的视频属性抓取结束
# 开始BV号为1Ck4y1d7U8视频属性的抓取
# BV号为1Ck4y1d7U8的视频属性抓取结束
# 开始BV号为17T4y157SZ视频属性的抓取
# BV号为17T4y157SZ的视频属性抓取结束
# 开始BV号为127411y7cJ视频属性的抓取
# BV号为127411y7cJ的视频属性抓取结束
# 开始BV号为1W7411o7gc视频属性的抓取
# BV号为1W7411o7gc的视频属性抓取结束
# 开始BV号为1VT4y157pZ视频属性的抓取
# BV号为1VT4y157pZ的视频属性抓取结束
# 开始BV号为1nE411M7EB视频属性的抓取
# BV号为1nE411M7EB的视频属性抓取结束
# 开始BV号为1cE411F79M视频属性的抓取
# BV号为1cE411F79M的视频属性抓取结束
# 开始BV号为1k7411Z7mm视频属性的抓取
# BV号为1k7411Z7mm的视频属性抓取结束
# 开始BV号为1D7411f7dn视频属性的抓取
# BV号为1D7411f7dn的视频属性抓取结束
# 开始BV号为1YE411F7Wq视频属性的抓取
# BV号为1YE411F7Wq的视频属性抓取结束
# 开始BV号为11E411A743视频属性的抓取
# BV号为11E411A743的视频属性抓取结束
# 开始BV号为1EZ4y1j7bw视频属性的抓取
# BV号为1EZ4y1j7bw的视频属性抓取结束
# 开始BV号为1TE41177kV视频属性的抓取
# BV号为1TE41177kV的视频属性抓取结束
# 开始BV号为18E411s7aX视频属性的抓取
# BV号为18E411s7aX的视频属性抓取结束
# 开始BV号为1rZ4y1j7MD视频属性的抓取
# BV号为1rZ4y1j7MD的视频属性抓取结束
# 开始BV号为157411d7oz视频属性的抓取
# BV号为157411d7oz的视频属性抓取结束
# 开始BV号为14E411W7vs视频属性的抓取
# BV号为14E411W7vs的视频属性抓取结束
# 开始BV号为15E411p7As视频属性的抓取
# BV号为15E411p7As的视频属性抓取结束
# 开始BV号为1mE411F7HF视频属性的抓取
# BV号为1mE411F7HF的视频属性抓取结束
# 开始BV号为1CE41137rD视频属性的抓取
# BV号为1CE41137rD的视频属性抓取结束
# 开始BV号为18E411P7iN视频属性的抓取
# BV号为18E411P7iN的视频属性抓取结束
# 开始BV号为1Ec411h78N视频属性的抓取
# BV号为1Ec411h78N的视频属性抓取结束
# 开始BV号为1Y7411m7wb视频属性的抓取
# BV号为1Y7411m7wb的视频属性抓取结束
# 开始BV号为1HE411p7Dc视频属性的抓取
# BV号为1HE411p7Dc的视频属性抓取结束
# 开始BV号为1zK41177PT视频属性的抓取
# BV号为1zK41177PT的视频属性抓取结束
# 开始BV号为1M7411Z7zw视频属性的抓取
# BV号为1M7411Z7zw的视频属性抓取结束
# 开始BV号为1mE41147kv视频属性的抓取
# BV号为1mE41147kv的视频属性抓取结束
# 开始BV号为1ZE411L7Ez视频属性的抓取
# BV号为1ZE411L7Ez的视频属性抓取结束
# 开始BV号为1d741117Uz视频属性的抓取
# BV号为1d741117Uz的视频属性抓取结束
# 开始BV号为1AE411g7xi视频属性的抓取
# BV号为1AE411g7xi的视频属性抓取结束
# 开始BV号为13p4y1C7Qv视频属性的抓取
# BV号为13p4y1C7Qv的视频属性抓取结束
# 开始BV号为18E411j7oM视频属性的抓取
# BV号为18E411j7oM的视频属性抓取结束
# 开始BV号为1xE41177S6视频属性的抓取
# BV号为1xE41177S6的视频属性抓取结束
# 开始BV号为1s7411d7qY视频属性的抓取
# BV号为1s7411d7qY的视频属性抓取结束
# 开始BV号为1MV411f7TA视频属性的抓取
# BV号为1MV411f7TA的视频属性抓取结束
# 开始BV号为1KE411E7Xv视频属性的抓取
# BV号为1KE411E7Xv的视频属性抓取结束
# 开始BV号为1pZ4y1j72R视频属性的抓取
# BV号为1pZ4y1j72R的视频属性抓取结束
# 开始BV号为1PE411w7i2视频属性的抓取
# BV号为1PE411w7i2的视频属性抓取结束
# 开始BV号为1r741127Vi视频属性的抓取
# BV号为1r741127Vi的视频属性抓取结束
# 开始BV号为1mA41187TP视频属性的抓取
# BV号为1mA41187TP的视频属性抓取结束
# 开始BV号为1RA411t7U5视频属性的抓取
# BV号为1RA411t7U5的视频属性抓取结束
# 开始BV号为1oT4y137rn视频属性的抓取
# BV号为1oT4y137rn的视频属性抓取结束
# 开始BV号为1Kp4y1C79n视频属性的抓取
# BV号为1Kp4y1C79n的视频属性抓取结束
# 开始BV号为1MT4y1V7He视频属性的抓取
# BV号为1MT4y1V7He的视频属性抓取结束
# 开始BV号为15g4y187ue视频属性的抓取
# BV号为15g4y187ue的视频属性抓取结束
# 开始BV号为18g4y1z7nZ视频属性的抓取
# BV号为18g4y1z7nZ的视频属性抓取结束
# 开始BV号为1L64y1M7sy视频属性的抓取
# BV号为1L64y1M7sy的视频属性抓取结束
# 开始BV号为1BZ4y1j7fy视频属性的抓取
# BV号为1BZ4y1j7fy的视频属性抓取结束
# 开始BV号为1LK411L7m7视频属性的抓取
# BV号为1LK411L7m7的视频属性抓取结束
# 开始BV号为1mQ4y1K7Zy视频属性的抓取
# BV号为1mQ4y1K7Zy的视频属性抓取结束
# 开始BV号为1ag4y187uR视频属性的抓取
# BV号为1ag4y187uR的视频属性抓取结束
# 开始BV号为1XK4y1r7Lv视频属性的抓取
# BV号为1XK4y1r7Lv的视频属性抓取结束
# 开始BV号为1Q64y1M7uC视频属性的抓取
# BV号为1Q64y1M7uC的视频属性抓取结束
# 开始BV号为1Cg4y187Xs视频属性的抓取
# BV号为1Cg4y187Xs的视频属性抓取结束
# 开始BV号为1e54y1973Q视频属性的抓取
# BV号为1e54y1973Q的视频属性抓取结束
# 开始BV号为1ic411h7Sv视频属性的抓取
# BV号为1ic411h7Sv的视频属性抓取结束
# 开始BV号为1UC4y1p7K1视频属性的抓取
# BV号为1UC4y1p7K1的视频属性抓取结束
# 开始BV号为1ZK4y1C74S视频属性的抓取
# BV号为1ZK4y1C74S的视频属性抓取结束
# 开始BV号为1ug4y187EX视频属性的抓取
# BV号为1ug4y187EX的视频属性抓取结束
# 开始BV号为1Jp4y1y78r视频属性的抓取
# BV号为1Jp4y1y78r的视频属性抓取结束
# 开始BV号为1EA411b79H视频属性的抓取
# BV号为1EA411b79H的视频属性抓取结束
# 开始BV号为1LC4y1W7FV视频属性的抓取
# BV号为1LC4y1W7FV的视频属性抓取结束
# 开始BV号为1654y197eq视频属性的抓取
# BV号为1654y197eq的视频属性抓取结束
# 开始BV号为1bz411b7i4视频属性的抓取
# BV号为1bz411b7i4的视频属性抓取结束
# 开始BV号为1jK41157ke视频属性的抓取
# BV号为1jK41157ke的视频属性抓取结束
# 开始BV号为1ZQ4y1K7qa视频属性的抓取
# BV号为1ZQ4y1K7qa的视频属性抓取结束
# 开始BV号为1RK411L7cH视频属性的抓取
# BV号为1RK411L7cH的视频属性抓取结束
# 开始BV号为1Jc411h7oC视频属性的抓取
# BV号为1Jc411h7oC的视频属性抓取结束
# 开始BV号为1sV411Z7Wv视频属性的抓取
# BV号为1sV411Z7Wv的视频属性抓取结束
# 开始BV号为1mQ4y1K7aN视频属性的抓取
# BV号为1mQ4y1K7aN的视频属性抓取结束
# 开始BV号为1fQ4y1K7MW视频属性的抓取
# BV号为1fQ4y1K7MW的视频属性抓取结束
# 开始BV号为14t4y1U7No视频属性的抓取
# BV号为14t4y1U7No的视频属性抓取结束
# 开始BV号为1qK411L7B2视频属性的抓取
# BV号为1qK411L7B2的视频属性抓取结束
# 开始BV号为1ZC4y1p7e3视频属性的抓取
# BV号为1ZC4y1p7e3的视频属性抓取结束
# 开始BV号为1EC4y1s7fM视频属性的抓取
# BV号为1EC4y1s7fM的视频属性抓取结束
# 开始BV号为1iQ4y1M7C9视频属性的抓取
# BV号为1iQ4y1M7C9的视频属性抓取结束
# 开始BV号为1Jg4y187Hc视频属性的抓取
# BV号为1Jg4y187Hc的视频属性抓取结束
# 开始BV号为1fe411x7jW视频属性的抓取
# BV号为1fe411x7jW的视频属性抓取结束
# 开始BV号为1wT4y1G7sx视频属性的抓取
# BV号为1wT4y1G7sx的视频属性抓取结束
# 开始BV号为1He41147yW视频属性的抓取
# BV号为1He41147yW的视频属性抓取结束
# 开始BV号为1L54y1R7Te视频属性的抓取
# BV号为1L54y1R7Te的视频属性抓取结束
# 开始BV号为1vt4y127Jv视频属性的抓取
# BV号为1vt4y127Jv的视频属性抓取结束
# 开始BV号为1Yt4y1U7g8视频属性的抓取
# BV号为1Yt4y1U7g8的视频属性抓取结束
# 开始BV号为1rV411o7zs视频属性的抓取
# BV号为1rV411o7zs的视频属性抓取结束
# 开始BV号为1tg4y1z7VU视频属性的抓取
# BV号为1tg4y1z7VU的视频属性抓取结束
# 开始BV号为1yK41177WR视频属性的抓取
# BV号为1yK41177WR的视频属性抓取结束
# 开始BV号为1454y197Yu视频属性的抓取
# BV号为1454y197Yu的视频属性抓取结束
# 开始BV号为16K4y1r77c视频属性的抓取
# BV号为16K4y1r77c的视频属性抓取结束
# 开始BV号为1u64y1M7b1视频属性的抓取
# BV号为1u64y1M7b1的视频属性抓取结束
# 开始BV号为1e5411x7pS视频属性的抓取
# BV号为1e5411x7pS的视频属性抓取结束
# 开始BV号为16V411f73Q视频属性的抓取
# BV号为16V411f73Q的视频属性抓取结束
# 开始BV号为1Z54y197RU视频属性的抓取
# BV号为1Z54y197RU的视频属性抓取结束
# 开始BV号为1cC4y1x7WB视频属性的抓取
# BV号为1cC4y1x7WB的视频属性抓取结束
# 开始BV号为19Z4y1W7Gb视频属性的抓取
# BV号为19Z4y1W7Gb的视频属性抓取结束
# 开始BV号为1CQ4y1K7G5视频属性的抓取
# BV号为1CQ4y1K7G5的视频属性抓取结束
# 开始BV号为1Rt4y1m7py视频属性的抓取
# BV号为1Rt4y1m7py的视频属性抓取结束
# 开始BV号为1oK411V7s9视频属性的抓取
# BV号为1oK411V7s9的视频属性抓取结束
# 开始BV号为1mi4y1b7LP视频属性的抓取
# BV号为1mi4y1b7LP的视频属性抓取结束
# 开始BV号为1ta4y1x7Mx视频属性的抓取
# BV号为1ta4y1x7Mx的视频属性抓取结束
# 开始BV号为1Wg4y1z7Fs视频属性的抓取
# BV号为1Wg4y1z7Fs的视频属性抓取结束
# 开始BV号为1fK4y1r7iy视频属性的抓取
# BV号为1fK4y1r7iy的视频属性抓取结束
# 开始BV号为1kT4y1G7bi视频属性的抓取
# BV号为1kT4y1G7bi的视频属性抓取结束
# 开始BV号为1gp4y1C7L6视频属性的抓取
# BV号为1gp4y1C7L6的视频属性抓取结束
# 开始BV号为1pT4y157NN视频属性的抓取
# BV号为1pT4y157NN的视频属性抓取结束
# 开始BV号为15A411b7FC视频属性的抓取
# BV号为15A411b7FC的视频属性抓取结束
# 开始BV号为1Q541147gv视频属性的抓取
# BV号为1Q541147gv的视频属性抓取结束
# 开始BV号为1dC4y1s7ks视频属性的抓取
# BV号为1dC4y1s7ks的视频属性抓取结束
# 开始BV号为1ZA411t7En视频属性的抓取
# BV号为1ZA411t7En的视频属性抓取结束
# 开始BV号为1464y1T7Di视频属性的抓取
# BV号为1464y1T7Di的视频属性抓取结束
# 开始BV号为1hV411o7aD视频属性的抓取
# BV号为1hV411o7aD的视频属性抓取结束
# 开始BV号为1hK411L7YQ视频属性的抓取
# BV号为1hK411L7YQ的视频属性抓取结束
# 开始BV号为1sK411772x视频属性的抓取
# BV号为1sK411772x的视频属性抓取结束
# 开始BV号为1Za4y1v7Nm视频属性的抓取
# BV号为1Za4y1v7Nm的视频属性抓取结束
# 开始BV号为1JT4y1G7Pz视频属性的抓取
# BV号为1JT4y1G7Pz的视频属性抓取结束
# 开始BV号为1Hz411z7Ju视频属性的抓取
# BV号为1Hz411z7Ju的视频属性抓取结束
# 开始BV号为1ZQ4y1P78a视频属性的抓取
# 开始BV号为1ZQ4y1P78a视频属性的抓取
# BV号为1ZQ4y1P78a的视频属性抓取结束
# 开始BV号为1u54y197p4视频属性的抓取
# BV号为1u54y197p4的视频属性抓取结束
# 开始BV号为1YV411f7DJ视频属性的抓取
# BV号为1YV411f7DJ的视频属性抓取结束
# 开始BV号为1fT4y1G7Hb视频属性的抓取
# BV号为1fT4y1G7Hb的视频属性抓取结束
# 开始BV号为1B64y1u7FR视频属性的抓取
# BV号为1B64y1u7FR的视频属性抓取结束
# 开始BV号为1re411x7ec视频属性的抓取
# BV号为1re411x7ec的视频属性抓取结束
# 开始BV号为1VK4y1k7Uh视频属性的抓取
# BV号为1VK4y1k7Uh的视频属性抓取结束
# 开始BV号为1V54y197L6视频属性的抓取
# BV号为1V54y197L6的视频属性抓取结束
# 开始BV号为1ie411x7Ke视频属性的抓取
# BV号为1ie411x7Ke的视频属性抓取结束
# 开始BV号为1Xt4y1m7ZE视频属性的抓取
# BV号为1Xt4y1m7ZE的视频属性抓取结束
# 开始BV号为1TA411h7Fk视频属性的抓取
# BV号为1TA411h7Fk的视频属性抓取结束
# 开始BV号为1Jg4y1a7Ed视频属性的抓取
# BV号为1Jg4y1a7Ed的视频属性抓取结束
# 开始BV号为1JK411j7dM视频属性的抓取
# BV号为1JK411j7dM的视频属性抓取结束
# 开始BV号为1q541167U6视频属性的抓取
# BV号为1q541167U6的视频属性抓取结束
# 开始BV号为1654y1Q7MZ视频属性的抓取
# BV号为1654y1Q7MZ的视频属性抓取结束
# 开始BV号为1GQ4y1M71b视频属性的抓取
# BV号为1GQ4y1M71b的视频属性抓取结束
# 开始BV号为1qC4y1s7fE视频属性的抓取
# BV号为1qC4y1s7fE的视频属性抓取结束
# 开始BV号为1La4y1x7zn视频属性的抓取
# BV号为1La4y1x7zn的视频属性抓取结束
# 开始BV号为17t4y1U7e9视频属性的抓取
# BV号为17t4y1U7e9的视频属性抓取结束
# 开始BV号为1m64y1u7Am视频属性的抓取
# BV号为1m64y1u7Am的视频属性抓取结束
# 开始BV号为1ae411s75g视频属性的抓取
# BV号为1ae411s75g的视频属性抓取结束
# 开始BV号为1ut4y1U7dz视频属性的抓取
# BV号为1ut4y1U7dz的视频属性抓取结束
# 开始BV号为1Xt4y127xV视频属性的抓取
# BV号为1Xt4y127xV的视频属性抓取结束
# 开始BV号为1yC4y147x1视频属性的抓取
# BV号为1yC4y147x1的视频属性抓取结束
# <ipython-input-11-031d135edb76>:187: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1rt4y127vS视频属性的抓取
# BV号为1rt4y127vS的视频属性抓取结束
# 开始BV号为1dV411d7oU视频属性的抓取
# BV号为1dV411d7oU的视频属性抓取结束
# 开始BV号为1Wf4y1U7ms视频属性的抓取
# BV号为1Wf4y1U7ms的视频属性抓取结束
# 开始BV号为17C4y1W7EP视频属性的抓取
# BV号为17C4y1W7EP的视频属性抓取结束
# 开始BV号为1854y1D78D视频属性的抓取
# BV号为1854y1D78D的视频属性抓取结束
# 开始BV号为1RV411d7sG视频属性的抓取
# BV号为1RV411d7sG的视频属性抓取结束
# 开始BV号为1xt4y117qL视频属性的抓取
# BV号为1xt4y117qL的视频属性抓取结束
# 开始BV号为12z411v7nR视频属性的抓取
# BV号为12z411v7nR的视频属性抓取结束
# 开始BV号为1Bp4y1Q7Xt视频属性的抓取
# BV号为1Bp4y1Q7Xt的视频属性抓取结束
# 开始BV号为1it4y117fL视频属性的抓取
# BV号为1it4y117fL的视频属性抓取结束
# 开始BV号为1qZ4y1s7AC视频属性的抓取
# BV号为1qZ4y1s7AC的视频属性抓取结束
# 开始BV号为17K4y1t7Es视频属性的抓取
# BV号为17K4y1t7Es的视频属性抓取结束
# 开始BV号为18V411C74G视频属性的抓取
# BV号为18V411C74G的视频属性抓取结束
# 开始BV号为19V411d7YD视频属性的抓取
# BV号为19V411d7YD的视频属性抓取结束
# 开始BV号为13V411C77q视频属性的抓取
# BV号为13V411C77q的视频属性抓取结束
# 开始BV号为1h54y1D7nN视频属性的抓取
# BV号为1h54y1D7nN的视频属性抓取结束
# 开始BV号为1YA41147D5视频属性的抓取
# BV号为1YA41147D5的视频属性抓取结束
# 开始BV号为1F5411s774视频属性的抓取
# BV号为1F5411s774的视频属性抓取结束
# 开始BV号为1mT4y1u75p视频属性的抓取
# BV号为1mT4y1u75p的视频属性抓取结束
# 开始BV号为1Vk4y1r79p视频属性的抓取
# BV号为1Vk4y1r79p的视频属性抓取结束
# 开始BV号为1gk4y1r7jk视频属性的抓取
# BV号为1gk4y1r7jk的视频属性抓取结束
# 开始BV号为1PA411t7WJ视频属性的抓取
# BV号为1PA411t7WJ的视频属性抓取结束
# 开始BV号为1j5411476E视频属性的抓取
# BV号为1j5411476E的视频属性抓取结束
# 开始BV号为1xA411q7h3视频属性的抓取
# BV号为1xA411q7h3的视频属性抓取结束
# 开始BV号为1Yt4y1C7P1视频属性的抓取
# BV号为1Yt4y1C7P1的视频属性抓取结束
# 开始BV号为17f4y1m7B5视频属性的抓取
# BV号为17f4y1m7B5的视频属性抓取结束
# 开始BV号为1rC4y1W7ud视频属性的抓取
# BV号为1rC4y1W7ud的视频属性抓取结束
# 开始BV号为15A411q75R视频属性的抓取
# BV号为15A411q75R的视频属性抓取结束
# 开始BV号为1554y1Q7kY视频属性的抓取
# 开始BV号为1554y1Q7kY视频属性的抓取
# BV号为1554y1Q7kY的视频属性抓取结束
# 开始BV号为1if4y1m7xH视频属性的抓取
# BV号为1if4y1m7xH的视频属性抓取结束
# 开始BV号为1uk4y1k7iN视频属性的抓取
# BV号为1uk4y1k7iN的视频属性抓取结束
# 开始BV号为1wK411L7tD视频属性的抓取
# BV号为1wK411L7tD的视频属性抓取结束
# 开始BV号为1ZV411d7vu视频属性的抓取
# BV号为1ZV411d7vu的视频属性抓取结束
# 开始BV号为1yp4y1Q7bH视频属性的抓取
# BV号为1yp4y1Q7bH的视频属性抓取结束
# 开始BV号为1Hp4y1X7AM视频属性的抓取
# BV号为1Hp4y1X7AM的视频属性抓取结束
# 开始BV号为1DV411d74L视频属性的抓取
# BV号为1DV411d74L的视频属性抓取结束
# 开始BV号为1GA411t7g9视频属性的抓取
# BV号为1GA411t7g9的视频属性抓取结束
# 开始BV号为1Wg4y1B72B视频属性的抓取
# BV号为1Wg4y1B72B的视频属性抓取结束
# 开始BV号为1Wf4y1m7Zh视频属性的抓取
# BV号为1Wf4y1m7Zh的视频属性抓取结束
# 开始BV号为1at4y1C7Ay视频属性的抓取
# BV号为1at4y1C7Ay的视频属性抓取结束
# 开始BV号为1vk4y1672k视频属性的抓取
# BV号为1vk4y1672k的视频属性抓取结束
# 开始BV号为1aa4y1e7A4视频属性的抓取
# BV号为1aa4y1e7A4的视频属性抓取结束
# 开始BV号为1AK411p7dX视频属性的抓取
# BV号为1AK411p7dX的视频属性抓取结束
# 开始BV号为1et4y1C7rJ视频属性的抓取
# BV号为1et4y1C7rJ的视频属性抓取结束
# 开始BV号为1XT4y1u7wr视频属性的抓取
# BV号为1XT4y1u7wr的视频属性抓取结束
# 开始BV号为1o54y197i8视频属性的抓取
# BV号为1o54y197i8的视频属性抓取结束
# 开始BV号为1Rf4y117uu视频属性的抓取
# 开始BV号为1Rf4y117uu视频属性的抓取
# BV号为1Rf4y117uu的视频属性抓取结束
# 开始BV号为1ge411W7zW视频属性的抓取
# BV号为1ge411W7zW的视频属性抓取结束
# 开始BV号为16p4y1Q7N8视频属性的抓取
# BV号为16p4y1Q7N8的视频属性抓取结束
# 开始BV号为1ta4y1i7xQ视频属性的抓取
# BV号为1ta4y1i7xQ的视频属性抓取结束
# 开始BV号为11p4y1X7BK视频属性的抓取
# BV号为11p4y1X7BK的视频属性抓取结束
# 开始BV号为1Ev411z7Kk视频属性的抓取
# BV号为1Ev411z7Kk的视频属性抓取结束
# 开始BV号为1Ka4y1i7qc视频属性的抓取
# BV号为1Ka4y1i7qc的视频属性抓取结束
# 开始BV号为1ip4y197Ev视频属性的抓取
# BV号为1ip4y197Ev的视频属性抓取结束
# 开始BV号为1554y1X7qp视频属性的抓取
# BV号为1554y1X7qp的视频属性抓取结束
# 开始BV号为1rV411C7yi视频属性的抓取
# BV号为1rV411C7yi的视频属性抓取结束
# 开始BV号为18A411t7RD视频属性的抓取
# BV号为18A411t7RD的视频属性抓取结束
# 开始BV号为1Lp4y1Q7cw视频属性的抓取
# BV号为1Lp4y1Q7cw的视频属性抓取结束
# 开始BV号为1bz4y1d7gb视频属性的抓取
# BV号为1bz4y1d7gb的视频属性抓取结束
# 开始BV号为1bK4y1t7kq视频属性的抓取
# BV号为1bK4y1t7kq的视频属性抓取结束
# 开始BV号为1VK411W7h8视频属性的抓取
# BV号为1VK411W7h8的视频属性抓取结束
# 开始BV号为1PK4y187Pf视频属性的抓取
# BV号为1PK4y187Pf的视频属性抓取结束
# 开始BV号为1Pg4y1z7wp视频属性的抓取
# BV号为1Pg4y1z7wp的视频属性抓取结束
# 开始BV号为18C4y1H796视频属性的抓取
# BV号为18C4y1H796的视频属性抓取结束
# 开始BV号为1Lg4y1671F视频属性的抓取
# 开始BV号为1Lg4y1671F视频属性的抓取
# BV号为1Lg4y1671F的视频属性抓取结束
# 开始BV号为1rZ4y1s7Zq视频属性的抓取
# BV号为1rZ4y1s7Zq的视频属性抓取结束
# 开始BV号为1qf4y1m7oW视频属性的抓取
# BV号为1qf4y1m7oW的视频属性抓取结束
# 开始BV号为1gK411s7AH视频属性的抓取
# BV号为1gK411s7AH的视频属性抓取结束
# 开始BV号为1eQ4y1N7nV视频属性的抓取
# BV号为1eQ4y1N7nV的视频属性抓取结束
# 开始BV号为1fV411k7cm视频属性的抓取
# BV号为1fV411k7cm的视频属性抓取结束
# 开始BV号为1va4y1i7W4视频属性的抓取
# BV号为1va4y1i7W4的视频属性抓取结束
# 开始BV号为1JZ4y1s7mY视频属性的抓取
# BV号为1JZ4y1s7mY的视频属性抓取结束
# 开始BV号为1E5411x7kf视频属性的抓取
# BV号为1E5411x7kf的视频属性抓取结束
# 开始BV号为1AQ4y1K7J8视频属性的抓取
# BV号为1AQ4y1K7J8的视频属性抓取结束
# 开始BV号为1sC4y1H7x1视频属性的抓取
# BV号为1sC4y1H7x1的视频属性抓取结束
# 开始BV号为16T4y137VH视频属性的抓取
# BV号为16T4y137VH的视频属性抓取结束
# 开始BV号为1Xe411p7xQ视频属性的抓取
# BV号为1Xe411p7xQ的视频属性抓取结束
# 开始BV号为1Rf4y1m7qU视频属性的抓取
# BV号为1Rf4y1m7qU的视频属性抓取结束
# 开始BV号为1V54y1Q7CL视频属性的抓取
# BV号为1V54y1Q7CL的视频属性抓取结束
# 开始BV号为1V54y1Q7go视频属性的抓取
# BV号为1V54y1Q7go的视频属性抓取结束
# 开始BV号为1nf4y1U7DL视频属性的抓取
# BV号为1nf4y1U7DL的视频属性抓取结束
# 开始BV号为1jK411s7yy视频属性的抓取
# BV号为1jK411s7yy的视频属性抓取结束
# 开始BV号为14f4y1S7Gs视频属性的抓取
# BV号为14f4y1S7Gs的视频属性抓取结束
# 开始BV号为1qa4y1e7pu视频属性的抓取
# BV号为1qa4y1e7pu的视频属性抓取结束
# 开始BV号为1HA411t7wN视频属性的抓取
# BV号为1HA411t7wN的视频属性抓取结束
# 开始BV号为1VQ4y1P76q视频属性的抓取
# BV号为1VQ4y1P76q的视频属性抓取结束
# 开始BV号为1HZ4y1s7mT视频属性的抓取
# BV号为1HZ4y1s7mT的视频属性抓取结束
# 开始BV号为1zz411q7pE视频属性的抓取
# BV号为1zz411q7pE的视频属性抓取结束
# 开始BV号为1y54y1D7QB视频属性的抓取
# BV号为1y54y1D7QB的视频属性抓取结束
# 开始BV号为1154y1X7a8视频属性的抓取
# BV号为1154y1X7a8的视频属性抓取结束
# 开始BV号为1Kz411z78o视频属性的抓取
# BV号为1Kz411z78o的视频属性抓取结束
# 开始BV号为1vV411C7Qh视频属性的抓取
# BV号为1vV411C7Qh的视频属性抓取结束
# 开始BV号为1qt4y1C7eP视频属性的抓取
# BV号为1qt4y1C7eP的视频属性抓取结束
# 开始BV号为1YZ4y1p7b8视频属性的抓取
# BV号为1YZ4y1p7b8的视频属性抓取结束
# 开始BV号为1ht4y1C7gV视频属性的抓取
# BV号为1ht4y1C7gV的视频属性抓取结束
# 开始BV号为1AT4y1g7Qb视频属性的抓取
# BV号为1AT4y1g7Qb的视频属性抓取结束
# 开始BV号为1Mz411q7k3视频属性的抓取
# BV号为1Mz411q7k3的视频属性抓取结束
# 开始BV号为1Fz4y197h8视频属性的抓取
# BV号为1Fz4y197h8的视频属性抓取结束
# 开始BV号为1nC4y1p7Px视频属性的抓取
# BV号为1nC4y1p7Px的视频属性抓取结束
# 开始BV号为1bT4y1g7tD视频属性的抓取
# BV号为1bT4y1g7tD的视频属性抓取结束
# 开始BV号为1Pi4y1x7Pr视频属性的抓取
# BV号为1Pi4y1x7Pr的视频属性抓取结束
# 开始BV号为1UK4y1x7QQ视频属性的抓取
# BV号为1UK4y1x7QQ的视频属性抓取结束
# 开始BV号为1dZ4y1M78P视频属性的抓取
# BV号为1dZ4y1M78P的视频属性抓取结束
# 开始BV号为1R5411p75p视频属性的抓取
# BV号为1R5411p75p的视频属性抓取结束
# 开始BV号为1ut4y197tr视频属性的抓取
# BV号为1ut4y197tr的视频属性抓取结束
# 开始BV号为1ot4y1C71B视频属性的抓取
# BV号为1ot4y1C71B的视频属性抓取结束
# 开始BV号为1ag4y1q7wQ视频属性的抓取
# BV号为1ag4y1q7wQ的视频属性抓取结束
# 开始BV号为1dT4y1E7S6视频属性的抓取
# BV号为1dT4y1E7S6的视频属性抓取结束
# 开始BV号为1EZ4y1H7gj视频属性的抓取
# BV号为1EZ4y1H7gj的视频属性抓取结束
# 开始BV号为13z4y1R7nM视频属性的抓取
# BV号为13z4y1R7nM的视频属性抓取结束
# 开始BV号为1aK4y1474U视频属性的抓取
# 开始BV号为1aK4y1474U视频属性的抓取
# BV号为1aK4y1474U的视频属性抓取结束
# 开始BV号为1xp4y1U7RJ视频属性的抓取
# BV号为1xp4y1U7RJ的视频属性抓取结束
# 开始BV号为1kt4y1X7MB视频属性的抓取
# BV号为1kt4y1X7MB的视频属性抓取结束
# 开始BV号为1Av411z7DR视频属性的抓取
# BV号为1Av411z7DR的视频属性抓取结束
# 开始BV号为15V411k7iM视频属性的抓取
# BV号为15V411k7iM的视频属性抓取结束
# 开始BV号为1xz411i7SP视频属性的抓取
# BV号为1xz411i7SP的视频属性抓取结束
# 开始BV号为125411p7pm视频属性的抓取
# BV号为125411p7pm的视频属性抓取结束
# 开始BV号为1L54y1B7Ri视频属性的抓取
# BV号为1L54y1B7Ri的视频属性抓取结束
# 开始BV号为1ZC4y1a7wJ视频属性的抓取
# BV号为1ZC4y1a7wJ的视频属性抓取结束
# 开始BV号为1Hi4y1x7MJ视频属性的抓取
# BV号为1Hi4y1x7MJ的视频属性抓取结束
# 开始BV号为1GA411i7kG视频属性的抓取
# BV号为1GA411i7kG的视频属性抓取结束
# 开始BV号为1iT4y1E7UM视频属性的抓取
# BV号为1iT4y1E7UM的视频属性抓取结束
# 开始BV号为1ja4y1e7b4视频属性的抓取
# BV号为1ja4y1e7b4的视频属性抓取结束
# 开始BV号为1Pk4y1z7zR视频属性的抓取
# BV号为1Pk4y1z7zR的视频属性抓取结束
# 开始BV号为1kA411v7qq视频属性的抓取
# BV号为1kA411v7qq的视频属性抓取结束
# 开始BV号为1xD4y1Q77R视频属性的抓取
# BV号为1xD4y1Q77R的视频属性抓取结束
# 开始BV号为1Gz4y1R7Tc视频属性的抓取
# BV号为1Gz4y1R7Tc的视频属性抓取结束
# 开始BV号为1UT4y1E73Z视频属性的抓取
# BV号为1UT4y1E73Z的视频属性抓取结束
# 开始BV号为1Gz4y1X7Wt视频属性的抓取
# BV号为1Gz4y1X7Wt的视频属性抓取结束
# 开始BV号为1pv411B7s6视频属性的抓取
# BV号为1pv411B7s6的视频属性抓取结束
# 开始BV号为1xt4y1976m视频属性的抓取
# BV号为1xt4y1976m的视频属性抓取结束
# 开始BV号为1KK411W777视频属性的抓取
# BV号为1KK411W777的视频属性抓取结束
# 开始BV号为17p4y1D7VB视频属性的抓取
# BV号为17p4y1D7VB的视频属性抓取结束
# 开始BV号为12C4y1a7df视频属性的抓取
# BV号为12C4y1a7df的视频属性抓取结束
# 开始BV号为1VA411e7Wv视频属性的抓取
# BV号为1VA411e7Wv的视频属性抓取结束
# 开始BV号为1ba4y1Y7uk视频属性的抓取
# BV号为1ba4y1Y7uk的视频属性抓取结束
# 开始BV号为1az4y197V6视频属性的抓取
# BV号为1az4y197V6的视频属性抓取结束
# 开始BV号为1sk4y1r77i视频属性的抓取
# BV号为1sk4y1r77i的视频属性抓取结束
# 开始BV号为1a54y1Q7ps视频属性的抓取
# BV号为1a54y1Q7ps的视频属性抓取结束
# 开始BV号为1zK411n7sJ视频属性的抓取
# BV号为1zK411n7sJ的视频属性抓取结束
# 开始BV号为1Vt4y1y7oJ视频属性的抓取
# BV号为1Vt4y1y7oJ的视频属性抓取结束
# 开始BV号为1jz411i7YK视频属性的抓取
# BV号为1jz411i7YK的视频属性抓取结束
# 开始BV号为1YZ4y1W7bo视频属性的抓取
# BV号为1YZ4y1W7bo的视频属性抓取结束
# 开始BV号为1Lg4y1q7bm视频属性的抓取
# 开始BV号为1Lg4y1q7bm视频属性的抓取
# BV号为1Lg4y1q7bm的视频属性抓取结束
# 开始BV号为1ga4y1Y7Aa视频属性的抓取
# BV号为1ga4y1Y7Aa的视频属性抓取结束
# 开始BV号为1hv41167Qt视频属性的抓取
# BV号为1hv41167Qt的视频属性抓取结束
# 开始BV号为1vK411p76a视频属性的抓取
# BV号为1vK411p76a的视频属性抓取结束
# 开始BV号为1Ci4y1G7dc视频属性的抓取
# BV号为1Ci4y1G7dc的视频属性抓取结束
# 开始BV号为12p4y1D7wv视频属性的抓取
# BV号为12p4y1D7wv的视频属性抓取结束
# 开始BV号为1YA411v7sC视频属性的抓取
# BV号为1YA411v7sC的视频属性抓取结束
# 开始BV号为1aA411i7AF视频属性的抓取
# BV号为1aA411i7AF的视频属性抓取结束
# 开始BV号为1Tt4y1971q视频属性的抓取
# BV号为1Tt4y1971q的视频属性抓取结束
# 开始BV号为1uf4y117c6视频属性的抓取
# BV号为1uf4y117c6的视频属性抓取结束
# 开始BV号为1Jg4y1q7nJ视频属性的抓取
# BV号为1Jg4y1q7nJ的视频属性抓取结束
# 开始BV号为1jk4y1z7um视频属性的抓取
# BV号为1jk4y1z7um的视频属性抓取结束
# 开始BV号为16g4y1q7Gz视频属性的抓取
# BV号为16g4y1q7Gz的视频属性抓取结束
# 开始BV号为1ci4y1x7uv视频属性的抓取
# BV号为1ci4y1x7uv的视频属性抓取结束
# 开始BV号为1nv41167CM视频属性的抓取
# BV号为1nv41167CM的视频属性抓取结束
# 开始BV号为1DC4y1h7fr视频属性的抓取
# BV号为1DC4y1h7fr的视频属性抓取结束
# 开始BV号为1yD4y1D7BD视频属性的抓取
# BV号为1yD4y1D7BD的视频属性抓取结束
# 开始BV号为1az4y197Lb视频属性的抓取
# BV号为1az4y197Lb的视频属性抓取结束
# 开始BV号为1Tz4y1R7a2视频属性的抓取
# BV号为1Tz4y1R7a2的视频属性抓取结束
# 开始BV号为1AA411B7mj视频属性的抓取
# BV号为1AA411B7mj的视频属性抓取结束
# 开始BV号为1nA411e7jq视频属性的抓取
# BV号为1nA411e7jq的视频属性抓取结束
# 开始BV号为1Xk4y1B7yN视频属性的抓取
# BV号为1Xk4y1B7yN的视频属性抓取结束
# 开始BV号为1hK4y147GJ视频属性的抓取
# BV号为1hK4y147GJ的视频属性抓取结束
# 开始BV号为1rz411i71b视频属性的抓取
# BV号为1rz411i71b的视频属性抓取结束
# 开始BV号为1Gv411B7WJ视频属性的抓取
# BV号为1Gv411B7WJ的视频属性抓取结束
# 开始BV号为1KK4y1b7bu视频属性的抓取
# BV号为1KK4y1b7bu的视频属性抓取结束
# 开始BV号为1dC4y1h7kG视频属性的抓取
# BV号为1dC4y1h7kG的视频属性抓取结束
# 开始BV号为1Jk4y1z7HF视频属性的抓取
# BV号为1Jk4y1z7HF的视频属性抓取结束
# 开始BV号为1iK4y1x7HR视频属性的抓取
# BV号为1iK4y1x7HR的视频属性抓取结束
# 开始BV号为1DK411n7bD视频属性的抓取
# BV号为1DK411n7bD的视频属性抓取结束
# 开始BV号为1pa4y1Y7vM视频属性的抓取
# BV号为1pa4y1Y7vM的视频属性抓取结束
# 开始BV号为16a4y1Y7su视频属性的抓取
# BV号为16a4y1Y7su的视频属性抓取结束
# 开始BV号为13i4y1x7r6视频属性的抓取
# BV号为13i4y1x7r6的视频属性抓取结束
# 开始BV号为1pz4y197zD视频属性的抓取
# BV号为1pz4y197zD的视频属性抓取结束
# 开始BV号为1Dt4y1X7MH视频属性的抓取
# BV号为1Dt4y1X7MH的视频属性抓取结束
# 开始BV号为1Pz411i71n视频属性的抓取
# BV号为1Pz411i71n的视频属性抓取结束
# 开始BV号为1Hi4y1x7Tw视频属性的抓取
# BV号为1Hi4y1x7Tw的视频属性抓取结束
# 开始BV号为16A411i7at视频属性的抓取
# BV号为16A411i7at的视频属性抓取结束
# 开始BV号为1554y1B79b视频属性的抓取
# BV号为1554y1B79b的视频属性抓取结束
# 开始BV号为1kT4y1E7pV视频属性的抓取
# BV号为1kT4y1E7pV的视频属性抓取结束
# 开始BV号为1oK4y1t7px视频属性的抓取
# BV号为1oK4y1t7px的视频属性抓取结束
# 开始BV号为1bz4y1X7yB视频属性的抓取
# BV号为1bz4y1X7yB的视频属性抓取结束
# 开始BV号为1Zt4y1X7XL视频属性的抓取
# BV号为1Zt4y1X7XL的视频属性抓取结束
# 开始BV号为1di4y1s7uP视频属性的抓取
# BV号为1di4y1s7uP的视频属性抓取结束
# 开始BV号为11a4y1h7gy视频属性的抓取
# BV号为11a4y1h7gy的视频属性抓取结束
# 开始BV号为1Yg4y1v7mB视频属性的抓取
# BV号为1Yg4y1v7mB的视频属性抓取结束
# 开始BV号为1jK4y1s71T视频属性的抓取
# BV号为1jK4y1s71T的视频属性抓取结束
# 开始BV号为11f4y127hj视频属性的抓取
# BV号为11f4y127hj的视频属性抓取结束
# 开始BV号为18T4y1771q视频属性的抓取
# BV号为18T4y1771q的视频属性抓取结束
# 开始BV号为1oz4y1Q7No视频属性的抓取
# BV号为1oz4y1Q7No的视频属性抓取结束
# 开始BV号为1Yk4y1z7Wa视频属性的抓取
# BV号为1Yk4y1z7Wa的视频属性抓取结束
# 开始BV号为1r5411Y7Qq视频属性的抓取
# BV号为1r5411Y7Qq的视频属性抓取结束
# 开始BV号为1K5411Y7Tz视频属性的抓取
# BV号为1K5411Y7Tz的视频属性抓取结束
# 开始BV号为1C5411W7Xb视频属性的抓取
# BV号为1C5411W7Xb的视频属性抓取结束
# 开始BV号为1dA411q7wT视频属性的抓取
# BV号为1dA411q7wT的视频属性抓取结束
# 开始BV号为1Eg4y1q77C视频属性的抓取
# BV号为1Eg4y1q77C的视频属性抓取结束
# 开始BV号为1ni4y1G721视频属性的抓取
# BV号为1ni4y1G721的视频属性抓取结束
# 开始BV号为1kz4y1D7MP视频属性的抓取
# BV号为1kz4y1D7MP的视频属性抓取结束
# 开始BV号为1vp4y1i79V视频属性的抓取
# BV号为1vp4y1i79V的视频属性抓取结束
# 开始BV号为13v411z7s8视频属性的抓取
# BV号为13v411z7s8的视频属性抓取结束
# 开始BV号为1fa4y1h73M视频属性的抓取
# BV号为1fa4y1h73M的视频属性抓取结束
# 开始BV号为1Zp4y1U73e视频属性的抓取
# BV号为1Zp4y1U73e的视频属性抓取结束
# 开始BV号为1BK411H7JS视频属性的抓取
# BV号为1BK411H7JS的视频属性抓取结束
# 开始BV号为1qf4y1R7po视频属性的抓取
# BV号为1qf4y1R7po的视频属性抓取结束
# 开始BV号为1nD4y1S7Us视频属性的抓取
# BV号为1nD4y1S7Us的视频属性抓取结束
# 开始BV号为15a4y1e7jE视频属性的抓取
# BV号为15a4y1e7jE的视频属性抓取结束
# 开始BV号为1Hv411q7Le视频属性的抓取
# BV号为1Hv411q7Le的视频属性抓取结束
# 开始BV号为1YT4y1E7vz视频属性的抓取
# BV号为1YT4y1E7vz的视频属性抓取结束
# 开始BV号为1ET4y1j7ty视频属性的抓取
# BV号为1ET4y1j7ty的视频属性抓取结束
# 开始BV号为1Jv411B7ek视频属性的抓取
# 开始BV号为1Jv411B7ek视频属性的抓取
# BV号为1Jv411B7ek的视频属性抓取结束
# 开始BV号为1Qt4y1Q7zG视频属性的抓取
# BV号为1Qt4y1Q7zG的视频属性抓取结束
# 开始BV号为1GA411e751视频属性的抓取
# BV号为1GA411e751的视频属性抓取结束
# 开始BV号为1oT4y1L7A7视频属性的抓取
# BV号为1oT4y1L7A7的视频属性抓取结束
# 开始BV号为1Rf4y1X7C7视频属性的抓取
# BV号为1Rf4y1X7C7的视频属性抓取结束
# 开始BV号为1Wv411q7gx视频属性的抓取
# BV号为1Wv411q7gx的视频属性抓取结束
# 开始BV号为1w5411a7Qt视频属性的抓取
# BV号为1w5411a7Qt的视频属性抓取结束
# 开始BV号为1a54y1q7cY视频属性的抓取
# BV号为1a54y1q7cY的视频属性抓取结束
# 开始BV号为1Lk4y1m7DA视频属性的抓取
# BV号为1Lk4y1m7DA的视频属性抓取结束
# 开始BV号为1cZ4y1u7e9视频属性的抓取
# BV号为1cZ4y1u7e9的视频属性抓取结束
# 开始BV号为1BK411n7wm视频属性的抓取
# BV号为1BK411n7wm的视频属性抓取结束
# 开始BV号为1e54y1S7PS视频属性的抓取
# BV号为1e54y1S7PS的视频属性抓取结束
# 开始BV号为1LA411e7HS视频属性的抓取
# BV号为1LA411e7HS的视频属性抓取结束
# 开始BV号为1RD4y1S7JD视频属性的抓取
# BV号为1RD4y1S7JD的视频属性抓取结束
# 开始BV号为1bK4y1x7kv视频属性的抓取
# BV号为1bK4y1x7kv的视频属性抓取结束
# 开始BV号为1cK4y1x7Nb视频属性的抓取
# 开始BV号为1cK4y1x7Nb视频属性的抓取
# BV号为1cK4y1x7Nb的视频属性抓取结束
# 开始BV号为1eD4y1S7zf视频属性的抓取
# BV号为1eD4y1S7zf的视频属性抓取结束
# 开始BV号为1CT4y177uv视频属性的抓取
# BV号为1CT4y177uv的视频属性抓取结束
# 开始BV号为15t4y1X7Sb视频属性的抓取
# BV号为15t4y1X7Sb的视频属性抓取结束
# 开始BV号为1oz4y1D7dH视频属性的抓取
# BV号为1oz4y1D7dH的视频属性抓取结束
# 开始BV号为1fD4y1S7wQ视频属性的抓取
# BV号为1fD4y1S7wQ的视频属性抓取结束
# 开始BV号为16p4y1i7KA视频属性的抓取
# 开始BV号为16p4y1i7KA视频属性的抓取
# BV号为16p4y1i7KA的视频属性抓取结束
# 开始BV号为1HT4y1j7ee视频属性的抓取
# BV号为1HT4y1j7ee的视频属性抓取结束
# 开始BV号为1cV411r7iK视频属性的抓取
# BV号为1cV411r7iK的视频属性抓取结束
# 开始BV号为1ai4y137vR视频属性的抓取
# BV号为1ai4y137vR的视频属性抓取结束
# 开始BV号为1Yk4y1m7qL视频属性的抓取
# BV号为1Yk4y1m7qL的视频属性抓取结束
# 开始BV号为1qV411z76j视频属性的抓取
# BV号为1qV411z76j的视频属性抓取结束
# 开始BV号为1n54y1S7Kt视频属性的抓取
# BV号为1n54y1S7Kt的视频属性抓取结束
# 开始BV号为135411e7yX视频属性的抓取
# BV号为135411e7yX的视频属性抓取结束
# 开始BV号为11f4y117Y6视频属性的抓取
# BV号为11f4y117Y6的视频属性抓取结束
# 开始BV号为1Hp4y1i71B视频属性的抓取
# 开始BV号为1Hp4y1i71B视频属性的抓取
# 开始BV号为1Hp4y1i71B视频属性的抓取
# BV号为1Hp4y1i71B的视频属性抓取结束
# 开始BV号为1wA411Y7vW视频属性的抓取
# BV号为1wA411Y7vW的视频属性抓取结束
# 开始BV号为1jg4y1i76j视频属性的抓取
# BV号为1jg4y1i76j的视频属性抓取结束
# 开始BV号为16h411o7cw视频属性的抓取
# BV号为16h411o7cw的视频属性抓取结束
# 开始BV号为1Rt4y197tf视频属性的抓取
# BV号为1Rt4y197tf的视频属性抓取结束
# 开始BV号为1EC4y1b7sQ视频属性的抓取
# BV号为1EC4y1b7sQ的视频属性抓取结束
# 开始BV号为1F54y1S7BX视频属性的抓取
# BV号为1F54y1S7BX的视频属性抓取结束
# 开始BV号为1FK4y1x7Uq视频属性的抓取
# BV号为1FK4y1x7Uq的视频属性抓取结束
# 开始BV号为1nt4y1Q7Mu视频属性的抓取
# BV号为1nt4y1Q7Mu的视频属性抓取结束
# 开始BV号为1tC4y1h7ZY视频属性的抓取
# BV号为1tC4y1h7ZY的视频属性抓取结束
# 开始BV号为1qp4y1S7kk视频属性的抓取
# BV号为1qp4y1S7kk的视频属性抓取结束
# 开始BV号为1XK4y1s76X视频属性的抓取
# BV号为1XK4y1s76X的视频属性抓取结束
# 开始BV号为1gz4y1X7vz视频属性的抓取
# BV号为1gz4y1X7vz的视频属性抓取结束
# 开始BV号为1mT4y1J7G1视频属性的抓取
# BV号为1mT4y1J7G1的视频属性抓取结束
# 开始BV号为1vC4y1b7Sw视频属性的抓取
# BV号为1vC4y1b7Sw的视频属性抓取结束
# 开始BV号为1sK4y1s7d1视频属性的抓取
# BV号为1sK4y1s7d1的视频属性抓取结束
# 开始BV号为1xp4y1q7ny视频属性的抓取
# BV号为1xp4y1q7ny的视频属性抓取结束
# 开始BV号为1nT4y1E7bv视频属性的抓取
# BV号为1nT4y1E7bv的视频属性抓取结束
# 开始BV号为1sA411v7xP视频属性的抓取
# BV号为1sA411v7xP的视频属性抓取结束
# 开始BV号为1WT4y1j7HE视频属性的抓取
# BV号为1WT4y1j7HE的视频属性抓取结束
# 开始BV号为1Jv411v7df视频属性的抓取
# BV号为1Jv411v7df的视频属性抓取结束
# 开始BV号为1Kk4y1B74B视频属性的抓取
# BV号为1Kk4y1B74B的视频属性抓取结束
# 开始BV号为1B54y1q7cW视频属性的抓取
# BV号为1B54y1q7cW的视频属性抓取结束
# 开始BV号为1iC4y1h7fE视频属性的抓取
# BV号为1iC4y1h7fE的视频属性抓取结束
# 开始BV号为1uk4y1m7k6视频属性的抓取
# BV号为1uk4y1m7k6的视频属性抓取结束
# 开始BV号为1tK411H7jZ视频属性的抓取
# BV号为1tK411H7jZ的视频属性抓取结束
# 开始BV号为1jt4y1X7a9视频属性的抓取
# BV号为1jt4y1X7a9的视频属性抓取结束
# 开始BV号为1v54y1v7fu视频属性的抓取
# BV号为1v54y1v7fu的视频属性抓取结束
# 开始BV号为1YV41167q5视频属性的抓取
# BV号为1YV41167q5的视频属性抓取结束
# 开始BV号为1j54y1z7Md视频属性的抓取
# BV号为1j54y1z7Md的视频属性抓取结束
# 开始BV号为1yZ4y1u7Gx视频属性的抓取
# BV号为1yZ4y1u7Gx的视频属性抓取结束
# 开始BV号为1Bt4y197TP视频属性的抓取
# BV号为1Bt4y197TP的视频属性抓取结束
# 开始BV号为1Vz4y1X775视频属性的抓取
# BV号为1Vz4y1X775的视频属性抓取结束
# 开始BV号为1zi4y137XL视频属性的抓取
# BV号为1zi4y137XL的视频属性抓取结束
# 开始BV号为1xk4y1q7S9视频属性的抓取
# BV号为1xk4y1q7S9的视频属性抓取结束
# 开始BV号为1G5411e74U视频属性的抓取
# BV号为1G5411e74U的视频属性抓取结束
# 开始BV号为1pt4y1Q7Qg视频属性的抓取
# BV号为1pt4y1Q7Qg的视频属性抓取结束
# 开始BV号为1jK4y1s74X视频属性的抓取
# BV号为1jK4y1s74X的视频属性抓取结束
# 开始BV号为1nv411v777视频属性的抓取
# BV号为1nv411v777的视频属性抓取结束
# 开始BV号为18v411q7ag视频属性的抓取
# BV号为18v411q7ag的视频属性抓取结束
# 开始BV号为16K411J7uC视频属性的抓取
# BV号为16K411J7uC的视频属性抓取结束
# 开始BV号为1ba4y1a7mg视频属性的抓取
# BV号为1ba4y1a7mg的视频属性抓取结束
# 开始BV号为1wZ4y1g7kE视频属性的抓取
# BV号为1wZ4y1g7kE的视频属性抓取结束
# 开始BV号为1xz4y1D7Yx视频属性的抓取
# BV号为1xz4y1D7Yx的视频属性抓取结束
# 开始BV号为17i4y1V7xd视频属性的抓取
# BV号为17i4y1V7xd的视频属性抓取结束
# 开始BV号为1sA411i7Bk视频属性的抓取
# BV号为1sA411i7Bk的视频属性抓取结束
# 开始BV号为1bK4y1x7qC视频属性的抓取
# BV号为1bK4y1x7qC的视频属性抓取结束
# 开始BV号为1rK4y1s7Z3视频属性的抓取
# BV号为1rK4y1s7Z3的视频属性抓取结束
# 开始BV号为1ZD4y1S7VD视频属性的抓取
# BV号为1ZD4y1S7VD的视频属性抓取结束
# 开始BV号为1bA411e7As视频属性的抓取
# BV号为1bA411e7As的视频属性抓取结束
# 开始BV号为1ET4y1j75k视频属性的抓取
# BV号为1ET4y1j75k的视频属性抓取结束
# 开始BV号为1X54y1i7i6视频属性的抓取
# BV号为1X54y1i7i6的视频属性抓取结束
# 开始BV号为1HZ4y1u7qo视频属性的抓取
# BV号为1HZ4y1u7qo的视频属性抓取结束
# 开始BV号为1qD4y1Q74y视频属性的抓取
# BV号为1qD4y1Q74y的视频属性抓取结束
# 开始BV号为1Nf4y1d7Xd视频属性的抓取
# BV号为1Nf4y1d7Xd的视频属性抓取结束
# 开始BV号为1zi4y137qa视频属性的抓取
# BV号为1zi4y137qa的视频属性抓取结束
# 开始BV号为18f4y1R7AG视频属性的抓取
# BV号为18f4y1R7AG的视频属性抓取结束
# 开始BV号为1Sk4y1z7B9视频属性的抓取
# BV号为1Sk4y1z7B9的视频属性抓取结束
# 开始BV号为1UZ4y1K7jd视频属性的抓取
# BV号为1UZ4y1K7jd的视频属性抓取结束
# 开始BV号为1z54y127td视频属性的抓取
# BV号为1z54y127td的视频属性抓取结束
# 开始BV号为1qh411Z7V4视频属性的抓取
# BV号为1qh411Z7V4的视频属性抓取结束
# 开始BV号为1mt4y1D7rg视频属性的抓取
# BV号为1mt4y1D7rg的视频属性抓取结束
# 开始BV号为1pD4y127RU视频属性的抓取
# BV号为1pD4y127RU的视频属性抓取结束
# 开始BV号为1QD4y1272K视频属性的抓取
# BV号为1QD4y1272K的视频属性抓取结束
# 开始BV号为15k4y1y77D视频属性的抓取
# BV号为15k4y1y77D的视频属性抓取结束
# 开始BV号为1Gf4y1X7y3视频属性的抓取
# BV号为1Gf4y1X7y3的视频属性抓取结束
# 开始BV号为1LK411n7Dn视频属性的抓取
# BV号为1LK411n7Dn的视频属性抓取结束
# 开始BV号为1Dh41197eL视频属性的抓取
# BV号为1Dh41197eL的视频属性抓取结束
# 开始BV号为1H54y1U7JB视频属性的抓取
# BV号为1H54y1U7JB的视频属性抓取结束
# 开始BV号为1Wa4y1J7HD视频属性的抓取
# BV号为1Wa4y1J7HD的视频属性抓取结束
# 开始BV号为1LK411T7mN视频属性的抓取
# BV号为1LK411T7mN的视频属性抓取结束
# 开始BV号为1Q64y1F7Bh视频属性的抓取
# BV号为1Q64y1F7Bh的视频属性抓取结束
# 开始BV号为1tK4y1v7U3视频属性的抓取
# BV号为1tK4y1v7U3的视频属性抓取结束
# 开始BV号为1z54y1m7Eg视频属性的抓取
# BV号为1z54y1m7Eg的视频属性抓取结束
# 开始BV号为1z54y1i7Ru视频属性的抓取
# BV号为1z54y1i7Ru的视频属性抓取结束
# 开始BV号为11z4y1f7Gg视频属性的抓取
# BV号为11z4y1f7Gg的视频属性抓取结束
# 开始BV号为1FK411T7yX视频属性的抓取
# BV号为1FK411T7yX的视频属性抓取结束
# 开始BV号为1pp4y1v7St视频属性的抓取
# BV号为1pp4y1v7St的视频属性抓取结束
# 开始BV号为1Ea4y1J7MS视频属性的抓取
# BV号为1Ea4y1J7MS的视频属性抓取结束
# 开始BV号为1fD4y1U78q视频属性的抓取
# BV号为1fD4y1U78q的视频属性抓取结束
# 开始BV号为1o54y1S7eP视频属性的抓取
# BV号为1o54y1S7eP的视频属性抓取结束
# 开始BV号为1Xh41197g4视频属性的抓取
# BV号为1Xh41197g4的视频属性抓取结束
# 开始BV号为17K4y1Y7hL视频属性的抓取
# BV号为17K4y1Y7hL的视频属性抓取结束
# 开始BV号为1qa4y177t5视频属性的抓取
# BV号为1qa4y177t5的视频属性抓取结束
# 开始BV号为1Lv411v79J视频属性的抓取
# BV号为1Lv411v79J的视频属性抓取结束
# 开始BV号为1Xv411y7Vn视频属性的抓取
# BV号为1Xv411y7Vn的视频属性抓取结束
# 开始BV号为1M54y1U7dP视频属性的抓取
# BV号为1M54y1U7dP的视频属性抓取结束
# 开始BV号为1vA411Y7P8视频属性的抓取
# BV号为1vA411Y7P8的视频属性抓取结束
# 开始BV号为14A411Y7gn视频属性的抓取
# BV号为14A411Y7gn的视频属性抓取结束
# 开始BV号为1Dk4y1m7bk视频属性的抓取
# BV号为1Dk4y1m7bk的视频属性抓取结束
# 开始BV号为1Gi4y1M7YY视频属性的抓取
# BV号为1Gi4y1M7YY的视频属性抓取结束
# 开始BV号为1pV411S7WK视频属性的抓取
# BV号为1pV411S7WK的视频属性抓取结束
# 开始BV号为1Wf4y197w7视频属性的抓取
# BV号为1Wf4y197w7的视频属性抓取结束
# 开始BV号为1BT4y1j7M5视频属性的抓取
# BV号为1BT4y1j7M5的视频属性抓取结束
# 开始BV号为1kh411d7mn视频属性的抓取
# BV号为1kh411d7mn的视频属性抓取结束
# 开始BV号为18V411U7yf视频属性的抓取
# BV号为18V411U7yf的视频属性抓取结束
# 开始BV号为11C4y1b7wZ视频属性的抓取
# BV号为11C4y1b7wZ的视频属性抓取结束
# 开始BV号为1qf4y197JY视频属性的抓取
# BV号为1qf4y197JY的视频属性抓取结束
# 开始BV号为1Yv411v7T9视频属性的抓取
# BV号为1Yv411v7T9的视频属性抓取结束
# 开始BV号为1Ai4y1g7cS视频属性的抓取
# BV号为1Ai4y1g7cS的视频属性抓取结束
# 开始BV号为1eA411Y76E视频属性的抓取
# 开始BV号为1eA411Y76E视频属性的抓取
# 开始BV号为1eA411Y76E视频属性的抓取
# BV号为1eA411Y76E的视频属性抓取结束
# 开始BV号为19v411q7tV视频属性的抓取
# BV号为19v411q7tV的视频属性抓取结束
# 开始BV号为1j54y12735视频属性的抓取
# BV号为1j54y12735的视频属性抓取结束
# 开始BV号为1kp4y1v71V视频属性的抓取
# BV号为1kp4y1v71V的视频属性抓取结束
# 开始BV号为1wa4y1E765视频属性的抓取
# BV号为1wa4y1E765的视频属性抓取结束
# 开始BV号为1zt4y1D7ao视频属性的抓取
# BV号为1zt4y1D7ao的视频属性抓取结束
# 开始BV号为1m54y1i78i视频属性的抓取
# BV号为1m54y1i78i的视频属性抓取结束
# 开始BV号为1Rz4y1f7tW视频属性的抓取
# BV号为1Rz4y1f7tW的视频属性抓取结束
# 开始BV号为1u54y1v7vz视频属性的抓取
# BV号为1u54y1v7vz的视频属性抓取结束
# 开始BV号为1UC4y147L2视频属性的抓取
# BV号为1UC4y147L2的视频属性抓取结束
# 开始BV号为14Z4y1T71d视频属性的抓取
# BV号为14Z4y1T71d的视频属性抓取结束
# 开始BV号为1Lz4y1f7DJ视频属性的抓取
# BV号为1Lz4y1f7DJ的视频属性抓取结束
# 开始BV号为1464y1c7qE视频属性的抓取
# BV号为1464y1c7qE的视频属性抓取结束
# 开始BV号为1nK4y1v77A视频属性的抓取
# BV号为1nK4y1v77A的视频属性抓取结束
# 开始BV号为1Hi4y1g7xe视频属性的抓取
# BV号为1Hi4y1g7xe的视频属性抓取结束
# 开始BV号为1Kv411i74R视频属性的抓取
# BV号为1Kv411i74R的视频属性抓取结束
# 开始BV号为1964y1F731视频属性的抓取
# BV号为1964y1F731的视频属性抓取结束
# 开始BV号为1ah411d7Qd视频属性的抓取
# BV号为1ah411d7Qd的视频属性抓取结束
# 开始BV号为1w54y1U74T视频属性的抓取
# BV号为1w54y1U74T的视频属性抓取结束
# 开始BV号为1B5411h78z视频属性的抓取
# BV号为1B5411h78z的视频属性抓取结束
# 开始BV号为1hD4y1m7xU视频属性的抓取
# BV号为1hD4y1m7xU的视频属性抓取结束
# 开始BV号为12C4y1b7fi视频属性的抓取
# BV号为12C4y1b7fi的视频属性抓取结束
# 开始BV号为1rf4y197F6视频属性的抓取
# BV号为1rf4y197F6的视频属性抓取结束
# 开始BV号为1sf4y1972w视频属性的抓取
# BV号为1sf4y1972w的视频属性抓取结束
# 开始BV号为1Lv41117qN视频属性的抓取
# BV号为1Lv41117qN的视频属性抓取结束
# 开始BV号为1NK411T79J视频属性的抓取
# BV号为1NK411T79J的视频属性抓取结束
# 开始BV号为1nZ4y1M7EB视频属性的抓取
# BV号为1nZ4y1M7EB的视频属性抓取结束
# 开始BV号为1gV411U7R5视频属性的抓取
# BV号为1gV411U7R5的视频属性抓取结束
# 开始BV号为1Th411R71S视频属性的抓取
# BV号为1Th411R71S的视频属性抓取结束
# 开始BV号为1ff4y1X7T5视频属性的抓取
# BV号为1ff4y1X7T5的视频属性抓取结束
# 开始BV号为1J5411h7m3视频属性的抓取
# BV号为1J5411h7m3的视频属性抓取结束
# 开始BV号为1Zy4y1C7U6视频属性的抓取
# 开始BV号为1Zy4y1C7U6视频属性的抓取
# BV号为1Zy4y1C7U6的视频属性抓取结束
# 开始BV号为1Mk4y1U7yH视频属性的抓取
# BV号为1Mk4y1U7yH的视频属性抓取结束
# 开始BV号为1bh411d7uf视频属性的抓取
# BV号为1bh411d7uf的视频属性抓取结束
# 开始BV号为1yp4y1v7hw视频属性的抓取
# BV号为1yp4y1v7hw的视频属性抓取结束
# 开始BV号为1UD4y127tV视频属性的抓取
# BV号为1UD4y127tV的视频属性抓取结束
# 开始BV号为1Wh411d7Gv视频属性的抓取
# BV号为1Wh411d7Gv的视频属性抓取结束
# 开始BV号为1ik4y1m71D视频属性的抓取
# BV号为1ik4y1m71D的视频属性抓取结束
# 开始BV号为1pA411n7cL视频属性的抓取
# BV号为1pA411n7cL的视频属性抓取结束
# 开始BV号为1KD4y1m7we视频属性的抓取
# BV号为1KD4y1m7we的视频属性抓取结束
# 开始BV号为1nD4y1m73d视频属性的抓取
# BV号为1nD4y1m73d的视频属性抓取结束
# 开始BV号为1ki4y1M7rF视频属性的抓取
# BV号为1ki4y1M7rF的视频属性抓取结束
# 开始BV号为1E5411h7ie视频属性的抓取
# BV号为1E5411h7ie的视频属性抓取结束
# 开始BV号为16i4y1g7Rk视频属性的抓取
# BV号为16i4y1g7Rk的视频属性抓取结束
# 开始BV号为1U64y1c7im视频属性的抓取
# BV号为1U64y1c7im的视频属性抓取结束
# 开始BV号为1ht4y1X7d7视频属性的抓取
# BV号为1ht4y1X7d7的视频属性抓取结束
# 开始BV号为1yZ4y1K7Kh视频属性的抓取
# BV号为1yZ4y1K7Kh的视频属性抓取结束
# 开始BV号为1yT4y157oY视频属性的抓取
# BV号为1yT4y157oY的视频属性抓取结束
# 开始BV号为1gf4y197om视频属性的抓取
# BV号为1gf4y197om的视频属性抓取结束
# 开始BV号为1fp4y1Y7vu视频属性的抓取
# BV号为1fp4y1Y7vu的视频属性抓取结束
# 开始BV号为1Qh41197Bb视频属性的抓取
# BV号为1Qh41197Bb的视频属性抓取结束
# 开始BV号为1eK4y1Y7Ty视频属性的抓取
# BV号为1eK4y1Y7Ty的视频属性抓取结束
# 开始BV号为1X64y1c7Gk视频属性的抓取
# BV号为1X64y1c7Gk的视频属性抓取结束
# 开始BV号为13h411d7Gg视频属性的抓取
# BV号为13h411d7Gg的视频属性抓取结束
# 开始BV号为1G54y1e7M5视频属性的抓取
# BV号为1G54y1e7M5的视频属性抓取结束
# 开始BV号为1bZ4y1K7jn视频属性的抓取
# BV号为1bZ4y1K7jn的视频属性抓取结束
# 开始BV号为1L54y1e7Lx视频属性的抓取
# BV号为1L54y1e7Lx的视频属性抓取结束
# 开始BV号为1zz4y1f7SZ视频属性的抓取
# BV号为1zz4y1f7SZ的视频属性抓取结束
# 开始BV号为1WA411J7xv视频属性的抓取
# BV号为1WA411J7xv的视频属性抓取结束
# 开始BV号为1Sh411X7J4视频属性的抓取
# BV号为1Sh411X7J4的视频属性抓取结束
# 开始BV号为1AA411H76R视频属性的抓取
# BV号为1AA411H76R的视频属性抓取结束
# 开始BV号为1SK411K7i6视频属性的抓取
# BV号为1SK411K7i6的视频属性抓取结束
# 开始BV号为1Z5411b7AQ视频属性的抓取
# BV号为1Z5411b7AQ的视频属性抓取结束
# 开始BV号为1CA411n7rp视频属性的抓取
# BV号为1CA411n7rp的视频属性抓取结束
# 开始BV号为1Ma4y1j7cC视频属性的抓取
# BV号为1Ma4y1j7cC的视频属性抓取结束
# 开始BV号为1pv411171u视频属性的抓取
# BV号为1pv411171u的视频属性抓取结束
# 开始BV号为11h411R7aC视频属性的抓取
# BV号为11h411R7aC的视频属性抓取结束
# 开始BV号为16a4y15766视频属性的抓取
# BV号为16a4y15766的视频属性抓取结束
# 开始BV号为1yt4y1i7Xr视频属性的抓取
# BV号为1yt4y1i7Xr的视频属性抓取结束
# 开始BV号为1qA411E75j视频属性的抓取
# BV号为1qA411E75j的视频属性抓取结束
# 开始BV号为1ZZ4y1K712视频属性的抓取
# BV号为1ZZ4y1K712的视频属性抓取结束
# 开始BV号为1ik4y1y7RF视频属性的抓取
# BV号为1ik4y1y7RF的视频属性抓取结束
# 开始BV号为1Vk4y1y7DJ视频属性的抓取
# BV号为1Vk4y1y7DJ的视频属性抓取结束
# 开始BV号为1s54y117PK视频属性的抓取
# BV号为1s54y117PK的视频属性抓取结束
# 开始BV号为1jf4y1D7W7视频属性的抓取
# BV号为1jf4y1D7W7的视频属性抓取结束
# 开始BV号为1hk4y1y7HA视频属性的抓取
# BV号为1hk4y1y7HA的视频属性抓取结束
# 开始BV号为1ep4y1e7TG视频属性的抓取
# BV号为1ep4y1e7TG的视频属性抓取结束
# 开始BV号为1uV41127Qs视频属性的抓取
# BV号为1uV41127Qs的视频属性抓取结束
# 开始BV号为1da4y1L7DQ视频属性的抓取
# BV号为1da4y1L7DQ的视频属性抓取结束
# 开始BV号为1mk4y1y7Ao视频属性的抓取
# BV号为1mk4y1y7Ao的视频属性抓取结束
# 开始BV号为1HK411N742视频属性的抓取
# BV号为1HK411N742的视频属性抓取结束
# 开始BV号为1GV411m7aQ视频属性的抓取
# BV号为1GV411m7aQ的视频属性抓取结束
# 开始BV号为1pV411S7dH视频属性的抓取
# BV号为1pV411S7dH的视频属性抓取结束
# 开始BV号为1254y127Rp视频属性的抓取
# BV号为1254y127Rp的视频属性抓取结束
# 开始BV号为1Uy4y1y7oM视频属性的抓取
# BV号为1Uy4y1y7oM的视频属性抓取结束
# 开始BV号为1Gz4y1Z7pP视频属性的抓取
# BV号为1Gz4y1Z7pP的视频属性抓取结束
# 开始BV号为1MZ4y1T7Du视频属性的抓取
# BV号为1MZ4y1T7Du的视频属性抓取结束
# 开始BV号为1Qv411C7P4视频属性的抓取
# BV号为1Qv411C7P4的视频属性抓取结束
# 开始BV号为1Xy4y1C7vK视频属性的抓取
# BV号为1Xy4y1C7vK的视频属性抓取结束
# 开始BV号为1gT4y1A7iP视频属性的抓取
# BV号为1gT4y1A7iP的视频属性抓取结束
# 开始BV号为1ba4y1j7fz视频属性的抓取
# BV号为1ba4y1j7fz的视频属性抓取结束
# 开始BV号为1Zt4y1i7Rk视频属性的抓取
# BV号为1Zt4y1i7Rk的视频属性抓取结束
# 开始BV号为1Fk4y1C7uo视频属性的抓取
# BV号为1Fk4y1C7uo的视频属性抓取结束
# 开始BV号为19K4y1a7gb视频属性的抓取
# BV号为19K4y1a7gb的视频属性抓取结束
# 开始BV号为1D5411b7K8视频属性的抓取
# BV号为1D5411b7K8的视频属性抓取结束
# 开始BV号为1Uk4y127gc视频属性的抓取
# BV号为1Uk4y127gc的视频属性抓取结束
# 开始BV号为1Yt4y1S7Ms视频属性的抓取
# BV号为1Yt4y1S7Ms的视频属性抓取结束
# 开始BV号为1Rp4y1e7Me视频属性的抓取
# BV号为1Rp4y1e7Me的视频属性抓取结束
# 开始BV号为1Ci4y1M74c视频属性的抓取
# BV号为1Ci4y1M74c的视频属性抓取结束
# 开始BV号为1LA411J7k7视频属性的抓取
# BV号为1LA411J7k7的视频属性抓取结束
# 开始BV号为1r54y1C71G视频属性的抓取
# BV号为1r54y1C71G的视频属性抓取结束
# 开始BV号为1a54y1y7yu视频属性的抓取
# BV号为1a54y1y7yu的视频属性抓取结束
# 开始BV号为1nk4y117fQ视频属性的抓取
# BV号为1nk4y117fQ的视频属性抓取结束
# 开始BV号为1oD4y1o7V9视频属性的抓取
# BV号为1oD4y1o7V9的视频属性抓取结束
# 开始BV号为1wT4y1A7SJ视频属性的抓取
# BV号为1wT4y1A7SJ的视频属性抓取结束
# 开始BV号为18K411K7d2视频属性的抓取
# BV号为18K411K7d2的视频属性抓取结束
# 开始BV号为1c54y117Wf视频属性的抓取
# BV号为1c54y117Wf的视频属性抓取结束
# 开始BV号为1LT4y1c7eY视频属性的抓取
# BV号为1LT4y1c7eY的视频属性抓取结束
# 开始BV号为1Gp4y1e77D视频属性的抓取
# 开始BV号为1Gp4y1e77D视频属性的抓取
# BV号为1Gp4y1e77D的视频属性抓取结束
# 开始BV号为1yy4y1C7VF视频属性的抓取
# BV号为1yy4y1C7VF的视频属性抓取结束
# 开始BV号为12K411K7vX视频属性的抓取
# BV号为12K411K7vX的视频属性抓取结束
# 开始BV号为1hf4y1D7gr视频属性的抓取
# BV号为1hf4y1D7gr的视频属性抓取结束
# 开始BV号为1M5411j77s视频属性的抓取
# BV号为1M5411j77s的视频属性抓取结束
# 开始BV号为1F5411j7ff视频属性的抓取
# BV号为1F5411j7ff的视频属性抓取结束
# 开始BV号为1Xt4y1S7K3视频属性的抓取
# BV号为1Xt4y1S7K3的视频属性抓取结束
# 开始BV号为1754y1279W视频属性的抓取
# 开始BV号为1754y1279W视频属性的抓取
# BV号为1754y1279W的视频属性抓取结束
# 开始BV号为1V5411b7Zq视频属性的抓取
# BV号为1V5411b7Zq的视频属性抓取结束
# 开始BV号为1KZ4y1N7yV视频属性的抓取
# BV号为1KZ4y1N7yV的视频属性抓取结束
# 开始BV号为1ji4y1u7dQ视频属性的抓取
# BV号为1ji4y1u7dQ的视频属性抓取结束
# 开始BV号为1Sz4y1Z7KF视频属性的抓取
# BV号为1Sz4y1Z7KF的视频属性抓取结束
# 开始BV号为1uv41117ms视频属性的抓取
# BV号为1uv41117ms的视频属性抓取结束
# 开始BV号为1WD4y1o7uP视频属性的抓取
# BV号为1WD4y1o7uP的视频属性抓取结束
# 开始BV号为14K411P77G视频属性的抓取
# BV号为14K411P77G的视频属性抓取结束
# 开始BV号为1KZ4y1T7t6视频属性的抓取
# BV号为1KZ4y1T7t6的视频属性抓取结束
# 开始BV号为1HK411K7Pq视频属性的抓取
# BV号为1HK411K7Pq的视频属性抓取结束
# 开始BV号为1mV411m7Xn视频属性的抓取
# BV号为1mV411m7Xn的视频属性抓取结束
# 开始BV号为18t4y1v7xU视频属性的抓取
# BV号为18t4y1v7xU的视频属性抓取结束
# 开始BV号为18v411C7wT视频属性的抓取
# BV号为18v411C7wT的视频属性抓取结束
# 开始BV号为12K4y1a7Xe视频属性的抓取
# BV号为12K4y1a7Xe的视频属性抓取结束
# 开始BV号为1sh411R7AF视频属性的抓取
# BV号为1sh411R7AF的视频属性抓取结束
# 开始BV号为1wa4y1E7Q8视频属性的抓取
# BV号为1wa4y1E7Q8的视频属性抓取结束
# 开始BV号为1Di4y1E7JY视频属性的抓取
# BV号为1Di4y1E7JY的视频属性抓取结束
# 开始BV号为1nv41117Zv视频属性的抓取
# BV号为1nv41117Zv的视频属性抓取结束
# 开始BV号为1bv411C7SY视频属性的抓取
# BV号为1bv411C7SY的视频属性抓取结束
# 开始BV号为1Wp4y1a7MK视频属性的抓取
# BV号为1Wp4y1a7MK的视频属性抓取结束
# 开始BV号为1Fp4y1e7qk视频属性的抓取
# BV号为1Fp4y1e7qk的视频属性抓取结束
# 开始BV号为1Ai4y1u7Ds视频属性的抓取
# BV号为1Ai4y1u7Ds的视频属性抓取结束
# 开始BV号为1uK4y1a7Yv视频属性的抓取
# BV号为1uK4y1a7Yv的视频属性抓取结束
# 开始BV号为1F54y1y7Rh视频属性的抓取
# BV号为1F54y1y7Rh的视频属性抓取结束
# 开始BV号为1uZ4y1N7Zh视频属性的抓取
# BV号为1uZ4y1N7Zh的视频属性抓取结束
# 开始BV号为15k4y1y7U3视频属性的抓取
# BV号为15k4y1y7U3的视频属性抓取结束
# 开始BV号为1v54y1y7Bf视频属性的抓取
# BV号为1v54y1y7Bf的视频属性抓取结束
# 开始BV号为1ta4y1E7pq视频属性的抓取
# BV号为1ta4y1E7pq的视频属性抓取结束
# 开始BV号为1az4y1Z7TH视频属性的抓取
# BV号为1az4y1Z7TH的视频属性抓取结束
# 开始BV号为1fp4y1Y7rS视频属性的抓取
# BV号为1fp4y1Y7rS的视频属性抓取结束
# 开始BV号为1qA411n7XY视频属性的抓取
# BV号为1qA411n7XY的视频属性抓取结束
# 开始BV号为1HK4y1a75X视频属性的抓取
# BV号为1HK4y1a75X的视频属性抓取结束
# 开始BV号为1Gz4y1Z7Uy视频属性的抓取
# BV号为1Gz4y1Z7Uy的视频属性抓取结束
# 开始BV号为1PZ4y1N71P视频属性的抓取
# BV号为1PZ4y1N71P的视频属性抓取结束
# 开始BV号为1DK4y1a77W视频属性的抓取
# BV号为1DK4y1a77W的视频属性抓取结束
# 开始BV号为1w54y117Nf视频属性的抓取
# BV号为1w54y117Nf的视频属性抓取结束
# 开始BV号为1CZ4y1N77j视频属性的抓取
# BV号为1CZ4y1N77j的视频属性抓取结束
# 开始BV号为1jf4y1D7uM视频属性的抓取
# BV号为1jf4y1D7uM的视频属性抓取结束
# 开始BV号为1rD4y1o7ex视频属性的抓取
# 开始BV号为1rD4y1o7ex视频属性的抓取
# BV号为1rD4y1o7ex的视频属性抓取结束
# 开始BV号为1t54y1y7xr视频属性的抓取
# BV号为1t54y1y7xr的视频属性抓取结束
# 开始BV号为1ey4y1y7Ab视频属性的抓取
# BV号为1ey4y1y7Ab的视频属性抓取结束
# 开始BV号为1tt4y1S7Zg视频属性的抓取
# BV号为1tt4y1S7Zg的视频属性抓取结束
# 开始BV号为1XV41117Rq视频属性的抓取
# BV号为1XV41117Rq的视频属性抓取结束
# 开始BV号为12v411k73n视频属性的抓取
# BV号为12v411k73n的视频属性抓取结束
# 开始BV号为1PT4y1F7KG视频属性的抓取
# BV号为1PT4y1F7KG的视频属性抓取结束
# 开始BV号为1hK411A7y8视频属性的抓取
# BV号为1hK411A7y8的视频属性抓取结束
# 开始BV号为1ct4y1i7kF视频属性的抓取
# BV号为1ct4y1i7kF的视频属性抓取结束
# 开始BV号为1Gy4y1C7Kf视频属性的抓取
# BV号为1Gy4y1C7Kf的视频属性抓取结束
# 开始BV号为1Wy4y1r73w视频属性的抓取
# BV号为1Wy4y1r73w的视频属性抓取结束
# 开始BV号为1GK4y1h7ew视频属性的抓取
# BV号为1GK4y1h7ew的视频属性抓取结束
# 开始BV号为1zV41127tH视频属性的抓取
# BV号为1zV41127tH的视频属性抓取结束
# 开始BV号为12A411L7hS视频属性的抓取
# BV号为12A411L7hS的视频属性抓取结束
# 开始BV号为1Ry4y1r7sy视频属性的抓取
# BV号为1Ry4y1r7sy的视频属性抓取结束
# 开始BV号为16541157jd视频属性的抓取
# BV号为16541157jd的视频属性抓取结束
# 开始BV号为1U54y1171s视频属性的抓取
# BV号为1U54y1171s的视频属性抓取结束
# 开始BV号为1754y1k7S1视频属性的抓取
# BV号为1754y1k7S1的视频属性抓取结束
# 开始BV号为1k54y1k7cY视频属性的抓取
# BV号为1k54y1k7cY的视频属性抓取结束
# 开始BV号为1Kk4y1y7sB视频属性的抓取
# BV号为1Kk4y1y7sB的视频属性抓取结束
# 开始BV号为1Q5411j7mm视频属性的抓取
# BV号为1Q5411j7mm的视频属性抓取结束
# 开始BV号为1i541157rv视频属性的抓取
# BV号为1i541157rv的视频属性抓取结束
# 开始BV号为1BK411N7a3视频属性的抓取
# BV号为1BK411N7a3的视频属性抓取结束
# 开始BV号为1Nz4y1o7eN视频属性的抓取
# BV号为1Nz4y1o7eN的视频属性抓取结束
# 开始BV号为1Uy4y1k7wD视频属性的抓取
# BV号为1Uy4y1k7wD的视频属性抓取结束
# 开始BV号为1Bk4y1C7Qq视频属性的抓取
# BV号为1Bk4y1C7Qq的视频属性抓取结束
# 开始BV号为165411j7AX视频属性的抓取
# BV号为165411j7AX的视频属性抓取结束
# 开始BV号为15i4y177r4视频属性的抓取
# BV号为15i4y177r4的视频属性抓取结束
# 开始BV号为1Wp4y1Y7fs视频属性的抓取
# BV号为1Wp4y1Y7fs的视频属性抓取结束
# 开始BV号为1zA411773e视频属性的抓取
# BV号为1zA411773e的视频属性抓取结束
# 开始BV号为1jK411N77H视频属性的抓取
# BV号为1jK411N77H的视频属性抓取结束
# 开始BV号为16p4y1a7GW视频属性的抓取
# BV号为16p4y1a7GW的视频属性抓取结束
# 开始BV号为1dD4y1R7Kr视频属性的抓取
# BV号为1dD4y1R7Kr的视频属性抓取结束
# 开始BV号为1BK411N7yM视频属性的抓取
# BV号为1BK411N7yM的视频属性抓取结束
# 开始BV号为13y4y1C7W7视频属性的抓取
# BV号为13y4y1C7W7的视频属性抓取结束
# 开始BV号为1ea4y1L7ak视频属性的抓取
# BV号为1ea4y1L7ak的视频属性抓取结束
# 开始BV号为1wy4y1C78N视频属性的抓取
# BV号为1wy4y1C78N的视频属性抓取结束
# 开始BV号为17a4y1L78y视频属性的抓取
# BV号为17a4y1L78y的视频属性抓取结束
# 开始BV号为1EZ4y157fF视频属性的抓取
# BV号为1EZ4y157fF的视频属性抓取结束
# 开始BV号为18A41177CJ视频属性的抓取
# BV号为18A41177CJ的视频属性抓取结束
# 开始BV号为1hZ4y157Cm视频属性的抓取
# BV号为1hZ4y157Cm的视频属性抓取结束
# 开始BV号为1wT4y1F7PZ视频属性的抓取
# BV号为1wT4y1F7PZ的视频属性抓取结束
# 开始BV号为1Zy4y1k7Wi视频属性的抓取
# BV号为1Zy4y1k7Wi的视频属性抓取结束
# 开始BV号为1654y117Ue视频属性的抓取
# BV号为1654y117Ue的视频属性抓取结束
# 开始BV号为1vv411y7rV视频属性的抓取
# BV号为1vv411y7rV的视频属性抓取结束
# 开始BV号为1vT4y1c7Y7视频属性的抓取
# BV号为1vT4y1c7Y7的视频属性抓取结束
# 开始BV号为1F54y1r7Qy视频属性的抓取
# BV号为1F54y1r7Qy的视频属性抓取结束
# 开始BV号为1vi4y1E7qN视频属性的抓取
# BV号为1vi4y1E7qN的视频属性抓取结束
# 开始BV号为1j54y1r7vS视频属性的抓取
# BV号为1j54y1r7vS的视频属性抓取结束
# 开始BV号为15t4y1v7EB视频属性的抓取
# BV号为15t4y1v7EB的视频属性抓取结束
# 开始BV号为1654y1R7Yq视频属性的抓取
# BV号为1654y1R7Yq的视频属性抓取结束
# 开始BV号为11K411A7uz视频属性的抓取
# BV号为11K411A7uz的视频属性抓取结束
# 开始BV号为1va411A7JL视频属性的抓取
# BV号为1va411A7JL的视频属性抓取结束
# 开始BV号为1Ma411A774视频属性的抓取
# BV号为1Ma411A774的视频属性抓取结束
# 开始BV号为1az4y1o7Lw视频属性的抓取
# BV号为1az4y1o7Lw的视频属性抓取结束
# 开始BV号为1va4y1578Q视频属性的抓取
# BV号为1va4y1578Q的视频属性抓取结束
# 开始BV号为13T4y1F7Ze视频属性的抓取
# BV号为13T4y1F7Ze的视频属性抓取结束
# 开始BV号为1Pa411A7TT视频属性的抓取
# 开始BV号为1Pa411A7TT视频属性的抓取
# 开始BV号为1Pa411A7TT视频属性的抓取
# 开始BV号为1Pa411A7TT视频属性的抓取
# 开始BV号为1Pa411A7TT视频属性的抓取
# BV号为1Pa411A7TT的视频属性抓取结束
# 开始BV号为1Vt4y1v7NP视频属性的抓取
# BV号为1Vt4y1v7NP的视频属性抓取结束
# 开始BV号为1VT4y1F7pV视频属性的抓取
# BV号为1VT4y1F7pV的视频属性抓取结束
# 开始BV号为1dK411P7pJ视频属性的抓取
# BV号为1dK411P7pJ的视频属性抓取结束
# 开始BV号为1PT4y1w74j视频属性的抓取
# BV号为1PT4y1w74j的视频属性抓取结束
# 开始BV号为1ai4y1L73C视频属性的抓取
# BV号为1ai4y1L73C的视频属性抓取结束
# 开始BV号为1k54y1y7Ui视频属性的抓取
# BV号为1k54y1y7Ui的视频属性抓取结束
# 开始BV号为1pZ4y1L72y视频属性的抓取
# BV号为1pZ4y1L72y的视频属性抓取结束
# 开始BV号为1Lp4y1k7xm视频属性的抓取
# BV号为1Lp4y1k7xm的视频属性抓取结束
# 开始BV号为1dp4y1e7gU视频属性的抓取
# BV号为1dp4y1e7gU的视频属性抓取结束
# 开始BV号为16t4y1v7Ys视频属性的抓取
# BV号为16t4y1v7Ys的视频属性抓取结束
# 开始BV号为1yZ4y157io视频属性的抓取
# BV号为1yZ4y157io的视频属性抓取结束
# 开始BV号为1T54y1C7JA视频属性的抓取
# BV号为1T54y1C7JA的视频属性抓取结束
# 开始BV号为1A54y127mn视频属性的抓取
# BV号为1A54y127mn的视频属性抓取结束
# 开始BV号为18t4y1v7of视频属性的抓取
# BV号为18t4y1v7of的视频属性抓取结束
# 开始BV号为17A41177uB视频属性的抓取
# BV号为17A41177uB的视频属性抓取结束
# 开始BV号为1Gv411k7HV视频属性的抓取
# BV号为1Gv411k7HV的视频属性抓取结束
# 开始BV号为19y4y1z7Yr视频属性的抓取
# BV号为19y4y1z7Yr的视频属性抓取结束
# 开始BV号为1HK411N7zq视频属性的抓取
# BV号为1HK411N7zq的视频属性抓取结束
# 开始BV号为1Pv411k7Ym视频属性的抓取
# BV号为1Pv411k7Ym的视频属性抓取结束
# 开始BV号为1Ut4y1q7KD视频属性的抓取
# BV号为1Ut4y1q7KD的视频属性抓取结束
# 开始BV号为1oA411L7JL视频属性的抓取
# BV号为1oA411L7JL的视频属性抓取结束
# 开始BV号为1WA411E7wh视频属性的抓取
# BV号为1WA411E7wh的视频属性抓取结束
# 开始BV号为1754y1k7rv视频属性的抓取
# BV号为1754y1k7rv的视频属性抓取结束
# 开始BV号为1Pp4y1k7BS视频属性的抓取
# BV号为1Pp4y1k7BS的视频属性抓取结束
# 开始BV号为1Vz4y1o7ck视频属性的抓取
# BV号为1Vz4y1o7ck的视频属性抓取结束
# 开始BV号为1BD4y1R7Va视频属性的抓取
# BV号为1BD4y1R7Va的视频属性抓取结束
# 开始BV号为1eV41127nM视频属性的抓取
# BV号为1eV41127nM的视频属性抓取结束
# 开始BV号为1by4y1B747视频属性的抓取
# 开始BV号为1by4y1B747视频属性的抓取
# BV号为1by4y1B747的视频属性抓取结束
# 开始BV号为1hT4y1c7TE视频属性的抓取
# BV号为1hT4y1c7TE的视频属性抓取结束
# 开始BV号为1t54y117A4视频属性的抓取
# BV号为1t54y117A4的视频属性抓取结束
# 开始BV号为1JV411y7YB视频属性的抓取
# BV号为1JV411y7YB的视频属性抓取结束
# 开始BV号为1sT4y1F78y视频属性的抓取
# BV号为1sT4y1F78y的视频属性抓取结束
# 开始BV号为1JK4y1h7Jx视频属性的抓取
# BV号为1JK4y1h7Jx的视频属性抓取结束
# 开始BV号为1cz4y1f7a6视频属性的抓取
# BV号为1cz4y1f7a6的视频属性抓取结束
# 开始BV号为13D4y1977z视频属性的抓取
# BV号为13D4y1977z的视频属性抓取结束
# 开始BV号为1e54y1k7NE视频属性的抓取
# BV号为1e54y1k7NE的视频属性抓取结束
# 开始BV号为1da4y1W73h视频属性的抓取
# BV号为1da4y1W73h的视频属性抓取结束
# 开始BV号为1pZ4y1L7px视频属性的抓取
# BV号为1pZ4y1L7px的视频属性抓取结束
# 开始BV号为1qD4y1d7AA视频属性的抓取
# BV号为1qD4y1d7AA的视频属性抓取结束
# 开始BV号为1Lh41197F4视频属性的抓取
# BV号为1Lh41197F4的视频属性抓取结束
# 开始BV号为11T4y1c7Qx视频属性的抓取
# BV号为11T4y1c7Qx的视频属性抓取结束
# 开始BV号为15T4y1w7yo视频属性的抓取
# BV号为15T4y1w7yo的视频属性抓取结束
# 开始BV号为1hr4y1w7AW视频属性的抓取
# BV号为1hr4y1w7AW的视频属性抓取结束
# 开始BV号为1k54y11793视频属性的抓取
# BV号为1k54y11793的视频属性抓取结束
# 开始BV号为1sK411N7cp视频属性的抓取
# BV号为1sK411N7cp的视频属性抓取结束
# 开始BV号为1F54y127GJ视频属性的抓取
# BV号为1F54y127GJ的视频属性抓取结束
# 2020-12-16 08:44:18.177674

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-10-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_youxi_yinyou.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 4月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月   100  100  100  100  100  100   100
# 2月   100  100  100  100  100  100   100
# 3月   100  100  100  100  100  100   100
# 4月    99   99   99   99   99   99    99
# 5月   100  100  100  100  100  100   100
# 6月   100  100  100  100  100  100   100
# 7月   100  100  100  100  100  100   100
# 8月    99   99   99   99   99   99    99
# 9月   100  100  100  100  100  100   100

# %%
channel_youxi_yinyou.to_json('channel_youxi_yinyou.json')

# %%
pd.set_option('display.max_rows', None)

# %%
channel_youxi_yinyou
# Out:
#              时间                 发布日期        作者名 作者类型   粉丝数  投稿数  \
# 1dJ411n7JG   1月  2020-01-13 14:02:22  莉姊姊要抱抱QAQ    无  5788  359
# 1ZJ411G7PJ   1月  2020-01-10 17:01:45        苦力炸    无  4.4万  102
# 1t7411Y7a5   1月  2020-01-24 20:43:39     凉冬酱OVO    无  1110   16
# 1DJ411G7Cq   1月  2020-01-09 21:34:22   Deplibin    无  6506    4
# 1m7411e72Q   1月  2020-01-23 02:26:09   真的没必要取昵称    无  5919  166
# ...         ...                  ...        ...  ...   ...  ...
# 15T4y1w7yo  10月  2020-10-18 16:58:39  DJSHANG-尚    无  2700   30
# 1hr4y1w7AW  10月  2020-10-24 19:38:46       -清泉-    无  1207   36
# 1k54y11793  10月  2020-10-05 07:58:05   reimi_03    无   114   19
# 1sK411N7cp  10月  2020-10-01 02:55:52       高远合欢    无   188    6
# 1F54y127GJ  10月  2020-10-02 13:35:31      小小吱吱鼠    无  1155   40
#
#                                                           视频名  分区 子分区  视频类型  \
# 1dJ411n7JG                    【节奏大师】拇指科幻片！可以把手指打成死结的一首《左手指月》！  游戏  音游  活动作品
# 1ZJ411G7PJ                             超热血的《鬼灭之刃》OP《红莲华》燃爆全场！  游戏  音游  活动作品
# 1t7411Y7a5                   【Muse Dash】国产小yellow歌（懂得都懂），挺好听的  游戏  音游  活动作品
# 1DJ411G7Cq  [1080P] Just Dance《舞力全开》历代精选（含2020），HIIT 减肥歌单 ...  游戏  音游  普通视频
# 1m7411e72Q                                       建议改为:抽 风 的 线  游戏  音游  普通视频
# ...                                                       ...  ..  ..   ...
# 15T4y1w7yo                     虚拟音游项目《RE:SHIRLEY》概念宣传视频 VOL.1  游戏  音游  普通视频
# 1hr4y1w7AW                   自 作 自 受 ！暴走P挑战初音未来的消失【世界计划 多彩舞台】  游戏  音游  普通视频
# 1k54y11793                      【Project SEKAI】那些跑错sekai的团队们(  游戏  音游  普通视频
# 1sK411N7cp                                         手上的邦邦突然不香了  游戏  音游  普通视频
# 1F54y127GJ                                      【phigros】用光打光  游戏  音游  普通视频
#
#             ...                                                 标签   视频长度  \
# 1dJ411n7JG  ...  [音游, 游戏, 音游, 音乐游戏, 高能, 节奏大师自制谱, 换手, 左手指月, 全能打卡挑战]  02:23
# 1ZJ411G7PJ  ...  [节奏大师, 鬼灭之刃, 搞笑, 单机游戏, 游戏, 音游, 音乐游戏, 2019新人嘉年华...  04:00
# 1t7411Y7a5  ...  [MUSEDASH, 单机游戏, 游戏, 音游, 音乐游戏, 手机游戏, bilibili新...  02:36
# 1DJ411G7Cq  ...        [舞力全开, 蹦迪, 减肥, 音游, 游戏, 音游, 音乐游戏, JUSTDANCE]  03:44
# 1m7411e72Q  ...                         [跳舞的线, 游戏, 音游, 音乐游戏, 手机游戏]  00:47
# ...         ...                                                ...    ...
# 15T4y1w7yo  ...               [音游, 游戏, 音游, 音乐游戏, 平面设计, MG动画, 海报设计]  00:17
# 1hr4y1w7AW  ...  [音游, 游戏, 音游, 音乐游戏, 中文字幕, 初音ミクの消失, 初音未来的消失, 暴走P...  01:27
# 1k54y11793  ...  [初音未来, VOCALOID, 游戏, 音游, 音乐游戏, SEGA, 3DMV, Pro...  01:35
# 1sK411N7cp  ...                  [音游, 游戏, 音游, 音乐游戏, project sekai]  14:43
# 1F54y127GJ  ...                    [Phigros, 音游, 搞笑, 游戏, 音游, 音乐游戏]  02:33
#
#               播放量   点赞数   投币数   收藏数   转发数   评论数   弹幕数 有无分集
# 1dJ411n7JG  70.9万  6.6万  3.6万  1.1万  1.1万  1964  7711    否
# 1ZJ411G7PJ  69.5万  5.4万  2.9万  1.2万  6032  1059  6832    否
# 1t7411Y7a5  62.3万  2.5万   864  7306   212   623   345    否
# 1DJ411G7Cq  57.0万  4712  1912  3.2万  6066   415   735    是
# 1m7411e72Q  53.9万  3.9万   822  4966   982   794   783    否
# ...           ...   ...   ...   ...   ...   ...   ...  ...
# 15T4y1w7yo   3.7万  2479   359   881    66   171    27    否
# 1hr4y1w7AW   3.6万  1367    64   686   601   128    88    否
# 1k54y11793   3.6万  1160   403  1341   372   127   440    是
# 1sK411N7cp   3.5万   847    33   183    49   300    20    是
# 1F54y127GJ   3.5万  1765    27   350   124   150    82    否
#
# [998 rows x 21 columns]
