# %%
from selenium import webdriver
from selenium.webdriver.common.keys import  Keys 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import  By 
from selenium.webdriver.support import  expected_conditions as EC 

import pandas as pd
import numpy as np
import time
import datetime

# %%
#建立数据库
columns=['时间','发布日期','作者名','作者类型','粉丝数','投稿数','视频名','分区','子分区','视频类型','自制or转载','标签','视频长度','播放量','点赞数','投币数','收藏数','转发数','评论数','弹幕数','有无分集']
channel_youxi_zhuoyou=pd.DataFrame(columns=columns)
channel_youxi_zhuoyou
# Out:
# Empty DataFrame
# Columns: [时间, 发布日期, 作者名, 作者类型, 粉丝数, 投稿数, 视频名, 分区, 子分区, 视频类型, 自制or转载, 标签, 视频长度, 播放量, 点赞数, 投币数, 收藏数, 转发数, 评论数, 弹幕数, 有无分集]
# Index: []
#
# [0 rows x 21 columns]

# %%
driver=webdriver.Chrome()
driver.get('https://passport.bilibili.com/login')

# %%
#登录
driver.find_element_by_xpath('//*[@id="login-username"]').send_keys('15717506191')
driver.find_element_by_xpath('//*[@id="login-passwd"]').send_keys('xy000000')
driver.find_element_by_xpath('//*[@id="geetest-wrap"]/div/div[5]/a[1]').click()
#需要手动过验证码

# %%
driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[6]/div/a/span').click()  #选择频道

# %%
#获得分区名
channel=driver.find_element_by_xpath('//*[@id="primaryChannelMenu"]/span[6]/div/a/span').text
channel=channel.strip('0123456789+')
channel
# Out:
# '游戏'

# %%
driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[6]/a').click()  #选择子频道
sub_channel=driver.find_element_by_xpath('//*[@id="subnav"]/ul/li[6]/a').text
sub_channel
# Out:
# '桌游棋牌'

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[1]/ul/a[2]/li').click() #让视频按热度排序

# %%
print(datetime.datetime.now())

for month in range(1,11): 
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div/span').click()
    period=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).text
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[1]/div[3]/div[2]/div[2]/div[2]/div/div[2]/a[%d]'%month).click()
    WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]/div/div[2]/div[3]/a'))) 
    for page in range(5):    #爬取每个频道1月到10月每个月播放量前100的视频

        video_loc=1
        while video_loc<21:

            ### 判断作者类型###
            
            
            driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).click()
            driver.switch_to_window(driver.window_handles[-1])
            
            
            author_web_show='No'
            try:
                i=0
                while author_web_show=='No':
                    driver.refresh()
                    i+=1
                    try:
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="n-fs"]')))  #看作者名是否出现
                        WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="navigator"]/div/div[1]/div[1]/a[3]/span[3]')))  #看投稿数是否出现
                        author_web_show='Yes'
                    except:
                        author_web_show='No' 
                        if i>3:  
                            raise Exception  #刷新几次后仍爬不了说明用户已注销

                try:
                    driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m organization-auth"]')
                    author_type='机构认证'

                except:
                    try:
                        driver.find_element_by_xpath('//*[@class="user-auth-subscript avatar-m personal-auth"]')
                        author_type='个人认证'
                    except:
                        author_type='无'

                fans_num=driver.find_element_by_xpath('//*[@id="n-fs"]').text  #获取作者粉丝数

                ### 获取作者投稿数 ###
                driver.find_element_by_xpath('//*[@class="n-num"]').click()
                WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span')))  
                video_num=driver.find_element_by_xpath('//*[@id="page-video"]/div/div[1]/div/div/ul/li[1]/span').text

                driver.close()
                driver.switch_to_window(driver.window_handles[-1])


                view_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[1]/span'%video_loc).text #获取播放量
                real_dan_mu_num=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[2]/span[2]/span'%video_loc).text #获取弹幕数
                author=driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/div[3]/a'%video_loc).text #获取作者名
                driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/ul/li[%d]/div/div[2]/a'%video_loc).click() #进入视频界面  
                driver.switch_to_window(driver.window_handles[-1]) 

                try:
                    WebDriverWait(driver,5).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))  #若出现视频被删除的情况则退出

                    video_web_show='No'
                    while video_web_show=='No':
                        driver.refresh()

                        try:
                            WebDriverWait(driver,60).until(EC.presence_of_element_located((By.XPATH,'//*[@class="bilibili-player-video-time-total"]'))) #以视频长度出现时间判定网页是否加载完
                            video_web_show='Yes'

                            try:      
                                driver.find_element_by_xpath('//*[@id="multi_page"]')   #测试是否有分集视频
                                multi='是'

                            except:
                                multi='否'

                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            driver.execute_script('window.scrollTo(document.body.scrollHeight,0)') #再调回最上面是因为，视频长度的元素必须在屏幕内才可以被提取，否则为空

                            bv=driver.current_url[33:44] # 获取BV号（BV号在网址中）
                            print('开始BV号为%s视频属性的抓取'%bv)
                            video_name=driver.find_element_by_xpath('//*[@id="viewbox_report"]/h1/span').text #获取视频名
                            
                            release_date=driver.find_element_by_xpath('//*[@id="viewbox_report"]/div/span[3]').text
                            
                            ### 获取视频类型 ###
                            try:
                                video_type=driver.find_element_by_xpath('//*[@class="activity"]').text
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type=video_type+'和合作视频'
                                except:
                                    pass
                            except:
                                try:
                                    driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[2]/div[1]/div[1]/span[1]')
                                    video_type='合作视频'
                                except:
                                    video_type='普通视频'


                            ### 获取点赞数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text=='点赞':
                                like_num=0
                            else:
                                like_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[1]').text 

                            ### 获取投币数 ###
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text=='投币':
                                coin_num=0
                            else:
                                coin_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').text

                            ### 获取收藏数 ###             
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text=='收藏':
                                collect_num=0
                            else:
                                collect_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[3]').text

                            ### 获取转发数 ###       
                            if driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text=='分享':
                                forward_num=0
                            else:
                                forward_num=driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[4]').text

                            ### 获取视频长度 ###

                            video_length=driver.find_element_by_xpath('//*[@class="bilibili-player-video-time-total"]').text  

                            ### 判断自制还是转载 ###
                            driver.find_element_by_xpath('//*[@id="arc_toolbar_report"]/div[1]/span[2]').click()
                            try:
                                driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/div[2]/div[2]').text
                                self_made='自制'
                            except:
                                self_made='转载'
                            driver.find_element_by_xpath('//*[@id="app"]/div[2]/div[3]/div/div/i').click()

                            ### 获取标签 ###
                            k=1
                            labels=np.array
                            while True:
                                try:
                                    labels=np.append(labels,driver.find_element_by_xpath('//*[@id="v_tag"]/ul/li[%d]'%k).text)
                                    k+=1
                                except: 
                                    break
                            labels=labels[1:]

                            ### 获取评论数 ###
                            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')        
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[2]'))) #保证"评论"二字能加载出来                                                   
                            WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div')))
                            if driver.find_element_by_xpath('//*[@id="comment"]/div/div[2]/div/div[4]/div').text=='没有更多信息':    #应对评论区被关闭的情况
                                comment_num='NaN'
                            else:
                                while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                    try:
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[2]/div/div[4]/div[1]')))
                                        while driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text=='':
                                            time.sleep(0.1) #很奇怪，评论数可以定位的一瞬间并不能爬取，会返回空
                                        comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text     
                                    except:
                                        driver.refresh()    #有的时候“评论”二字出现，评论数不出现，页面好像卡住了
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="viewbox_report"]/h1/span')))
                                        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
                                        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="comment"]/div/div[1]/span[1]')))

                                comment_num=driver.find_element_by_xpath('//*[@id="comment"]/div/div[1]/span[1]').text

                            channel_youxi_zhuoyou.loc[bv]=[period,release_date,author,author_type,fans_num,video_num,video_name,channel,sub_channel,video_type,self_made,labels,video_length,view_num,like_num,coin_num,collect_num,forward_num,comment_num,real_dan_mu_num,multi]

                            print('BV号为%s的视频属性抓取结束'%bv)

                            driver.close()
                            driver.switch_to_window(driver.window_handles[-1])

                        except:
                            video_web_show='No' 
                except:
                    driver.close()
                    driver.switch_to_window(driver.window_handles[-1])
            except:
                driver.close()
                driver.switch_to_window(driver.window_handles[-1])
            
            video_loc+=1


        driver.find_element_by_xpath('//*[@class="nav-btn iconfont icon-arrowdown3"]').click() #点击下一页
        WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/ul/li[1]')))  #点击下一页后等页面刷新
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[2]').click()  #回到第1页
    WebDriverWait(driver,10).until(EC.presence_of_element_located((By.XPATH,'//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]')))
    driver.find_element_by_xpath('//*[@id="videolist_box"]/div[2]/div[2]/ul/li[1]').click()  #发现很多月份漏爬了约20个，而且恰好是第一页，所以再点一次第一页
        
        
print(datetime.datetime.now())
# Out:
# 2020-12-16 00:09:52.445593
# <ipython-input-15-27a9ccaa6317>:17: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-15-27a9ccaa6317>:54: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# <ipython-input-15-27a9ccaa6317>:61: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1y7411z71s视频属性的抓取
# BV号为1y7411z71s的视频属性抓取结束
# <ipython-input-15-27a9ccaa6317>:180: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1D7411z7hJ视频属性的抓取
# BV号为1D7411z7hJ的视频属性抓取结束
# 开始BV号为1HJ41157vR视频属性的抓取
# BV号为1HJ41157vR的视频属性抓取结束
# 开始BV号为15J411n7rp视频属性的抓取
# BV号为15J411n7rp的视频属性抓取结束
# 开始BV号为1i7411v7XT视频属性的抓取
# BV号为1i7411v7XT的视频属性抓取结束
# 开始BV号为177411Y7d3视频属性的抓取
# BV号为177411Y7d3的视频属性抓取结束
# 开始BV号为1o7411B79g视频属性的抓取
# BV号为1o7411B79g的视频属性抓取结束
# 开始BV号为1K7411Y7xC视频属性的抓取
# BV号为1K7411Y7xC的视频属性抓取结束
# 开始BV号为1Y7411B71a视频属性的抓取
# BV号为1Y7411B71a的视频属性抓取结束
# 开始BV号为1s7411e7mj视频属性的抓取
# BV号为1s7411e7mj的视频属性抓取结束
# 开始BV号为1X741167ue视频属性的抓取
# BV号为1X741167ue的视频属性抓取结束
# 开始BV号为1i7411r77j视频属性的抓取
# BV号为1i7411r77j的视频属性抓取结束
# 开始BV号为1A7411z7u3视频属性的抓取
# BV号为1A7411z7u3的视频属性抓取结束
# 开始BV号为1w7411B7U2视频属性的抓取
# BV号为1w7411B7U2的视频属性抓取结束
# 开始BV号为1dJ411j7R7视频属性的抓取
# BV号为1dJ411j7R7的视频属性抓取结束
# 开始BV号为1T7411z7RF视频属性的抓取
# BV号为1T7411z7RF的视频属性抓取结束
# 开始BV号为1C7411B7Hr视频属性的抓取
# BV号为1C7411B7Hr的视频属性抓取结束
# 开始BV号为1aJ41157fs视频属性的抓取
# BV号为1aJ41157fs的视频属性抓取结束
# 开始BV号为1iJ411H72J视频属性的抓取
# BV号为1iJ411H72J的视频属性抓取结束
# 开始BV号为1zJ411j7yH视频属性的抓取
# BV号为1zJ411j7yH的视频属性抓取结束
# 开始BV号为127411e788视频属性的抓取
# BV号为127411e788的视频属性抓取结束
# 开始BV号为1aJ411p74q视频属性的抓取
# BV号为1aJ411p74q的视频属性抓取结束
# 开始BV号为1GJ41187ij视频属性的抓取
# BV号为1GJ41187ij的视频属性抓取结束
# 开始BV号为1tJ411p7AJ视频属性的抓取
# BV号为1tJ411p7AJ的视频属性抓取结束
# 开始BV号为1aJ411b7Co视频属性的抓取
# BV号为1aJ411b7Co的视频属性抓取结束
# 开始BV号为1KJ41177gn视频属性的抓取
# BV号为1KJ41177gn的视频属性抓取结束
# 开始BV号为1J7411k7wx视频属性的抓取
# BV号为1J7411k7wx的视频属性抓取结束
# 开始BV号为1x7411B7gU视频属性的抓取
# BV号为1x7411B7gU的视频属性抓取结束
# 开始BV号为137411Y75u视频属性的抓取
# BV号为137411Y75u的视频属性抓取结束
# 开始BV号为1s7411a7C2视频属性的抓取
# BV号为1s7411a7C2的视频属性抓取结束
# 开始BV号为1r7411s7Aj视频属性的抓取
# BV号为1r7411s7Aj的视频属性抓取结束
# 开始BV号为1dJ41157mB视频属性的抓取
# 开始BV号为1dJ41157mB视频属性的抓取
# BV号为1dJ41157mB的视频属性抓取结束
# 开始BV号为1R7411679w视频属性的抓取
# BV号为1R7411679w的视频属性抓取结束
# 开始BV号为19J41157JT视频属性的抓取
# BV号为19J41157JT的视频属性抓取结束
# 开始BV号为1i7411z7Sz视频属性的抓取
# BV号为1i7411z7Sz的视频属性抓取结束
# 开始BV号为147411a7B4视频属性的抓取
# BV号为147411a7B4的视频属性抓取结束
# 开始BV号为1ZJ411j7Rm视频属性的抓取
# BV号为1ZJ411j7Rm的视频属性抓取结束
# 开始BV号为1bJ411V7ep视频属性的抓取
# BV号为1bJ411V7ep的视频属性抓取结束
# 开始BV号为1hJ411E7xq视频属性的抓取
# BV号为1hJ411E7xq的视频属性抓取结束
# 开始BV号为1q7411v79X视频属性的抓取
# BV号为1q7411v79X的视频属性抓取结束
# 开始BV号为11J411G7wu视频属性的抓取
# BV号为11J411G7wu的视频属性抓取结束
# 开始BV号为1F7411B71m视频属性的抓取
# BV号为1F7411B71m的视频属性抓取结束
# 开始BV号为1e7411z7mh视频属性的抓取
# BV号为1e7411z7mh的视频属性抓取结束
# 开始BV号为187411Y7S6视频属性的抓取
# BV号为187411Y7S6的视频属性抓取结束
# 开始BV号为1e7411k7NT视频属性的抓取
# BV号为1e7411k7NT的视频属性抓取结束
# 开始BV号为1CJ411573i视频属性的抓取
# BV号为1CJ411573i的视频属性抓取结束
# 开始BV号为1q741167GV视频属性的抓取
# BV号为1q741167GV的视频属性抓取结束
# 开始BV号为1s7411i7tV视频属性的抓取
# BV号为1s7411i7tV的视频属性抓取结束
# 开始BV号为1E7411i7he视频属性的抓取
# BV号为1E7411i7he的视频属性抓取结束
# 开始BV号为1s7411e7Ex视频属性的抓取
# BV号为1s7411e7Ex的视频属性抓取结束
# 开始BV号为1J7411q72t视频属性的抓取
# BV号为1J7411q72t的视频属性抓取结束
# 开始BV号为1UJ411J7he视频属性的抓取
# BV号为1UJ411J7he的视频属性抓取结束
# 开始BV号为1o7411z7oT视频属性的抓取
# BV号为1o7411z7oT的视频属性抓取结束
# 开始BV号为1LJ411G71k视频属性的抓取
# BV号为1LJ411G71k的视频属性抓取结束
# 开始BV号为1UJ411H7iD视频属性的抓取
# BV号为1UJ411H7iD的视频属性抓取结束
# 开始BV号为1Q7411B7Lo视频属性的抓取
# BV号为1Q7411B7Lo的视频属性抓取结束
# 开始BV号为1Y741167Xw视频属性的抓取
# BV号为1Y741167Xw的视频属性抓取结束
# 开始BV号为1q7411B7hB视频属性的抓取
# BV号为1q7411B7hB的视频属性抓取结束
# 开始BV号为1z741167zA视频属性的抓取
# BV号为1z741167zA的视频属性抓取结束
# 开始BV号为1a7411e7jU视频属性的抓取
# BV号为1a7411e7jU的视频属性抓取结束
# 开始BV号为1wJ411p7J6视频属性的抓取
# BV号为1wJ411p7J6的视频属性抓取结束
# 开始BV号为157411k7CW视频属性的抓取
# BV号为157411k7CW的视频属性抓取结束
# 开始BV号为1JJ411p7dM视频属性的抓取
# BV号为1JJ411p7dM的视频属性抓取结束
# 开始BV号为1U741167oV视频属性的抓取
# BV号为1U741167oV的视频属性抓取结束
# 开始BV号为1JJ41187VF视频属性的抓取
# BV号为1JJ41187VF的视频属性抓取结束
# 开始BV号为1WJ411J7Gt视频属性的抓取
# BV号为1WJ411J7Gt的视频属性抓取结束
# 开始BV号为13J4117783视频属性的抓取
# BV号为13J4117783的视频属性抓取结束
# 开始BV号为1fJ411b7QU视频属性的抓取
# BV号为1fJ411b7QU的视频属性抓取结束
# 开始BV号为1q7411k7xz视频属性的抓取
# BV号为1q7411k7xz的视频属性抓取结束
# 开始BV号为1E7411q7ao视频属性的抓取
# BV号为1E7411q7ao的视频属性抓取结束
# 开始BV号为1DJ411E7pS视频属性的抓取
# BV号为1DJ411E7pS的视频属性抓取结束
# 开始BV号为1g7411q7bH视频属性的抓取
# BV号为1g7411q7bH的视频属性抓取结束
# 开始BV号为1r7411r7i3视频属性的抓取
# BV号为1r7411r7i3的视频属性抓取结束
# 开始BV号为1zJ411j793视频属性的抓取
# BV号为1zJ411j793的视频属性抓取结束
# 开始BV号为1aJ411L7rZ视频属性的抓取
# BV号为1aJ411L7rZ的视频属性抓取结束
# 开始BV号为14J41157GM视频属性的抓取
# BV号为14J41157GM的视频属性抓取结束
# 开始BV号为1C7411v7H6视频属性的抓取
# BV号为1C7411v7H6的视频属性抓取结束
# 开始BV号为1T7411v7tz视频属性的抓取
# BV号为1T7411v7tz的视频属性抓取结束
# 开始BV号为13J411n7RL视频属性的抓取
# BV号为13J411n7RL的视频属性抓取结束
# 开始BV号为117411k7eS视频属性的抓取
# BV号为117411k7eS的视频属性抓取结束
# 开始BV号为1uJ411G7Ng视频属性的抓取
# BV号为1uJ411G7Ng的视频属性抓取结束
# 开始BV号为117411i7rG视频属性的抓取
# BV号为117411i7rG的视频属性抓取结束
# 开始BV号为1kJ411V7yP视频属性的抓取
# 开始BV号为1kJ411V7yP视频属性的抓取
# BV号为1kJ411V7yP的视频属性抓取结束
# 开始BV号为1xJ411H7tb视频属性的抓取
# 开始BV号为1xJ411H7tb视频属性的抓取
# BV号为1xJ411H7tb的视频属性抓取结束
# 开始BV号为197411B78g视频属性的抓取
# BV号为197411B78g的视频属性抓取结束
# 开始BV号为1DJ411p7Ey视频属性的抓取
# BV号为1DJ411p7Ey的视频属性抓取结束
# 开始BV号为1X7411i7Pc视频属性的抓取
# BV号为1X7411i7Pc的视频属性抓取结束
# 开始BV号为1E741167nB视频属性的抓取
# BV号为1E741167nB的视频属性抓取结束
# 开始BV号为1k7411i7T9视频属性的抓取
# BV号为1k7411i7T9的视频属性抓取结束
# 开始BV号为1VJ411578H视频属性的抓取
# BV号为1VJ411578H的视频属性抓取结束
# 开始BV号为1VJ411E7Dp视频属性的抓取
# BV号为1VJ411E7Dp的视频属性抓取结束
# 开始BV号为1L7411z7sP视频属性的抓取
# BV号为1L7411z7sP的视频属性抓取结束
# 开始BV号为1g741167iw视频属性的抓取
# BV号为1g741167iw的视频属性抓取结束
# 开始BV号为1o7411q7Qb视频属性的抓取
# BV号为1o7411q7Qb的视频属性抓取结束
# 开始BV号为1U7411s77U视频属性的抓取
# BV号为1U7411s77U的视频属性抓取结束
# 开始BV号为1C7411B7RY视频属性的抓取
# BV号为1C7411B7RY的视频属性抓取结束
# 开始BV号为1VJ41177rK视频属性的抓取
# BV号为1VJ41177rK的视频属性抓取结束
# 开始BV号为1B7411q76D视频属性的抓取
# BV号为1B7411q76D的视频属性抓取结束
# 开始BV号为1K7411672t视频属性的抓取
# BV号为1K7411672t的视频属性抓取结束
# 开始BV号为1bJ411575k视频属性的抓取
# BV号为1bJ411575k的视频属性抓取结束
# 开始BV号为177411J7j9视频属性的抓取
# BV号为177411J7j9的视频属性抓取结束
# 开始BV号为1J7411c7Ad视频属性的抓取
# BV号为1J7411c7Ad的视频属性抓取结束
# 开始BV号为1q7411h7kC视频属性的抓取
# BV号为1q7411h7kC的视频属性抓取结束
# 开始BV号为11741187AR视频属性的抓取
# BV号为11741187AR的视频属性抓取结束
# 开始BV号为1a7411W7Ng视频属性的抓取
# BV号为1a7411W7Ng的视频属性抓取结束
# 开始BV号为157411W7nx视频属性的抓取
# BV号为157411W7nx的视频属性抓取结束
# 开始BV号为127411N7ns视频属性的抓取
# BV号为127411N7ns的视频属性抓取结束
# 开始BV号为1q741177DQ视频属性的抓取
# BV号为1q741177DQ的视频属性抓取结束
# 开始BV号为1z7411s7iG视频属性的抓取
# BV号为1z7411s7iG的视频属性抓取结束
# 开始BV号为117411A7Hm视频属性的抓取
# BV号为117411A7Hm的视频属性抓取结束
# 开始BV号为137411P7Jc视频属性的抓取
# BV号为137411P7Jc的视频属性抓取结束
# 开始BV号为1u741137sX视频属性的抓取
# BV号为1u741137sX的视频属性抓取结束
# 开始BV号为1C7411c72f视频属性的抓取
# BV号为1C7411c72f的视频属性抓取结束
# 开始BV号为1Y7411s7ss视频属性的抓取
# BV号为1Y7411s7ss的视频属性抓取结束
# 开始BV号为1K7411s7yb视频属性的抓取
# BV号为1K7411s7yb的视频属性抓取结束
# 开始BV号为1A7411w7qW视频属性的抓取
# BV号为1A7411w7qW的视频属性抓取结束
# 开始BV号为157411b7Jr视频属性的抓取
# 开始BV号为157411b7Jr视频属性的抓取
# BV号为157411b7Jr的视频属性抓取结束
# 开始BV号为1N7411a7hC视频属性的抓取
# BV号为1N7411a7hC的视频属性抓取结束
# 开始BV号为1X7411g7fr视频属性的抓取
# BV号为1X7411g7fr的视频属性抓取结束
# 开始BV号为1L7411j7Md视频属性的抓取
# BV号为1L7411j7Md的视频属性抓取结束
# 开始BV号为1G7411b7rX视频属性的抓取
# BV号为1G7411b7rX的视频属性抓取结束
# 开始BV号为1G7411P7Zf视频属性的抓取
# BV号为1G7411P7Zf的视频属性抓取结束
# 开始BV号为1j7411874m视频属性的抓取
# BV号为1j7411874m的视频属性抓取结束
# 开始BV号为1Q7411h7mr视频属性的抓取
# BV号为1Q7411h7mr的视频属性抓取结束
# 开始BV号为1D7411872J视频属性的抓取
# BV号为1D7411872J的视频属性抓取结束
# 开始BV号为1J7411s7Qz视频属性的抓取
# BV号为1J7411s7Qz的视频属性抓取结束
# 开始BV号为1u7411H77u视频属性的抓取
# BV号为1u7411H77u的视频属性抓取结束
# 开始BV号为117411h71j视频属性的抓取
# BV号为117411h71j的视频属性抓取结束
# 开始BV号为14j411f73p视频属性的抓取
# BV号为14j411f73p的视频属性抓取结束
# 开始BV号为12E411n7tj视频属性的抓取
# BV号为12E411n7tj的视频属性抓取结束
# 开始BV号为197411P7dw视频属性的抓取
# BV号为197411P7dw的视频属性抓取结束
# 开始BV号为1y7411j7g6视频属性的抓取
# BV号为1y7411j7g6的视频属性抓取结束
# 开始BV号为13E411H7t9视频属性的抓取
# BV号为13E411H7t9的视频属性抓取结束
# 开始BV号为167411L79q视频属性的抓取
# BV号为167411L79q的视频属性抓取结束
# 开始BV号为1J7411b7sR视频属性的抓取
# BV号为1J7411b7sR的视频属性抓取结束
# 开始BV号为1V7411T7Z7视频属性的抓取
# BV号为1V7411T7Z7的视频属性抓取结束
# 开始BV号为1Y7411F78i视频属性的抓取
# BV号为1Y7411F78i的视频属性抓取结束
# 开始BV号为1k7411F7LF视频属性的抓取
# BV号为1k7411F7LF的视频属性抓取结束
# 开始BV号为1m741137dG视频属性的抓取
# 开始BV号为1m741137dG视频属性的抓取
# BV号为1m741137dG的视频属性抓取结束
# 开始BV号为12j411f73b视频属性的抓取
# BV号为12j411f73b的视频属性抓取结束
# 开始BV号为1BE411n7NQ视频属性的抓取
# BV号为1BE411n7NQ的视频属性抓取结束
# 开始BV号为1M7411A7qg视频属性的抓取
# BV号为1M7411A7qg的视频属性抓取结束
# 开始BV号为1R7411N7MJ视频属性的抓取
# BV号为1R7411N7MJ的视频属性抓取结束
# 开始BV号为16E411H7XE视频属性的抓取
# BV号为16E411H7XE的视频属性抓取结束
# 开始BV号为1J7411a7wU视频属性的抓取
# BV号为1J7411a7wU的视频属性抓取结束
# 开始BV号为1P741147GM视频属性的抓取
# BV号为1P741147GM的视频属性抓取结束
# 开始BV号为1C7411s7Vg视频属性的抓取
# BV号为1C7411s7Vg的视频属性抓取结束
# 开始BV号为1o7411M7iJ视频属性的抓取
# BV号为1o7411M7iJ的视频属性抓取结束
# 开始BV号为1k7411G7UF视频属性的抓取
# BV号为1k7411G7UF的视频属性抓取结束
# 开始BV号为1TE411H7Ve视频属性的抓取
# BV号为1TE411H7Ve的视频属性抓取结束
# 开始BV号为1C7411W7jC视频属性的抓取
# BV号为1C7411W7jC的视频属性抓取结束
# 开始BV号为1Z7411p7C4视频属性的抓取
# BV号为1Z7411p7C4的视频属性抓取结束
# 开始BV号为1t7411K7n6视频属性的抓取
# BV号为1t7411K7n6的视频属性抓取结束
# 开始BV号为1j7411H7c6视频属性的抓取
# BV号为1j7411H7c6的视频属性抓取结束
# 开始BV号为1r7411W7KX视频属性的抓取
# BV号为1r7411W7KX的视频属性抓取结束
# 开始BV号为1c7411j7AC视频属性的抓取
# BV号为1c7411j7AC的视频属性抓取结束
# 开始BV号为1F7411W7X5视频属性的抓取
# BV号为1F7411W7X5的视频属性抓取结束
# 开始BV号为1o7411t7k9视频属性的抓取
# BV号为1o7411t7k9的视频属性抓取结束
# 开始BV号为1j7411j7nw视频属性的抓取
# BV号为1j7411j7nw的视频属性抓取结束
# 开始BV号为1E7411879t视频属性的抓取
# BV号为1E7411879t的视频属性抓取结束
# 开始BV号为1C741177N9视频属性的抓取
# BV号为1C741177N9的视频属性抓取结束
# 开始BV号为1y7411E7MD视频属性的抓取
# BV号为1y7411E7MD的视频属性抓取结束
# 开始BV号为1W7411N7Cw视频属性的抓取
# BV号为1W7411N7Cw的视频属性抓取结束
# 开始BV号为1r7411p71L视频属性的抓取
# BV号为1r7411p71L的视频属性抓取结束
# 开始BV号为1V7411H7UX视频属性的抓取
# BV号为1V7411H7UX的视频属性抓取结束
# 开始BV号为1d7411G7dy视频属性的抓取
# BV号为1d7411G7dy的视频属性抓取结束
# 开始BV号为12741147xc视频属性的抓取
# BV号为12741147xc的视频属性抓取结束
# 开始BV号为1e7411E7A3视频属性的抓取
# BV号为1e7411E7A3的视频属性抓取结束
# 开始BV号为137411L7w8视频属性的抓取
# BV号为137411L7w8的视频属性抓取结束
# 开始BV号为1f7411F7e4视频属性的抓取
# BV号为1f7411F7e4的视频属性抓取结束
# 开始BV号为1b7411J7Wu视频属性的抓取
# BV号为1b7411J7Wu的视频属性抓取结束
# 开始BV号为1u7411t72Q视频属性的抓取
# 开始BV号为1u7411t72Q视频属性的抓取
# 开始BV号为1u7411t72Q视频属性的抓取
# BV号为1u7411t72Q的视频属性抓取结束
# 开始BV号为1Y741187h8视频属性的抓取
# BV号为1Y741187h8的视频属性抓取结束
# 开始BV号为1B7411P7DP视频属性的抓取
# BV号为1B7411P7DP的视频属性抓取结束
# 开始BV号为1S7411T7XU视频属性的抓取
# BV号为1S7411T7XU的视频属性抓取结束
# 开始BV号为1R7411V7UH视频属性的抓取
# BV号为1R7411V7UH的视频属性抓取结束
# 开始BV号为1V7411c7w3视频属性的抓取
# BV号为1V7411c7w3的视频属性抓取结束
# 开始BV号为1B7411b7Qi视频属性的抓取
# BV号为1B7411b7Qi的视频属性抓取结束
# 开始BV号为1S741187os视频属性的抓取
# BV号为1S741187os的视频属性抓取结束
# 开始BV号为1QE411J7R4视频属性的抓取
# BV号为1QE411J7R4的视频属性抓取结束
# 开始BV号为1i7411J7Xj视频属性的抓取
# BV号为1i7411J7Xj的视频属性抓取结束
# 开始BV号为1e741177od视频属性的抓取
# BV号为1e741177od的视频属性抓取结束
# 开始BV号为1c7411V7bv视频属性的抓取
# BV号为1c7411V7bv的视频属性抓取结束
# 开始BV号为1z7411G7Wb视频属性的抓取
# BV号为1z7411G7Wb的视频属性抓取结束
# 开始BV号为1G7411J7yC视频属性的抓取
# BV号为1G7411J7yC的视频属性抓取结束
# 开始BV号为1B7411q74u视频属性的抓取
# BV号为1B7411q74u的视频属性抓取结束
# 开始BV号为1A7411s7nd视频属性的抓取
# BV号为1A7411s7nd的视频属性抓取结束
# 开始BV号为1g7411b76L视频属性的抓取
# BV号为1g7411b76L的视频属性抓取结束
# 开始BV号为1P7411T71Q视频属性的抓取
# BV号为1P7411T71Q的视频属性抓取结束
# 开始BV号为1X7411x7No视频属性的抓取
# BV号为1X7411x7No的视频属性抓取结束
# 开始BV号为1k7411A7hV视频属性的抓取
# BV号为1k7411A7hV的视频属性抓取结束
# 开始BV号为1A741187Hz视频属性的抓取
# BV号为1A741187Hz的视频属性抓取结束
# 开始BV号为1e7411j7Ar视频属性的抓取
# BV号为1e7411j7Ar的视频属性抓取结束
# 开始BV号为1d7411h71P视频属性的抓取
# BV号为1d7411h71P的视频属性抓取结束
# 开始BV号为1c7411W7Pe视频属性的抓取
# BV号为1c7411W7Pe的视频属性抓取结束
# 开始BV号为1Q7411A7kv视频属性的抓取
# BV号为1Q7411A7kv的视频属性抓取结束
# 开始BV号为1q741137Aa视频属性的抓取
# BV号为1q741137Aa的视频属性抓取结束
# 开始BV号为1V741177qC视频属性的抓取
# BV号为1V741177qC的视频属性抓取结束
# 开始BV号为1E741187kh视频属性的抓取
# BV号为1E741187kh的视频属性抓取结束
# 开始BV号为1E7411V7rh视频属性的抓取
# BV号为1E7411V7rh的视频属性抓取结束
# 开始BV号为1pE411M7tR视频属性的抓取
# BV号为1pE411M7tR的视频属性抓取结束
# 开始BV号为1X7411R7EE视频属性的抓取
# BV号为1X7411R7EE的视频属性抓取结束
# 开始BV号为1RK4y1C7f2视频属性的抓取
# BV号为1RK4y1C7f2的视频属性抓取结束
# 开始BV号为1uE411P7RU视频属性的抓取
# BV号为1uE411P7RU的视频属性抓取结束
# 开始BV号为14E411G7Zk视频属性的抓取
# BV号为14E411G7Zk的视频属性抓取结束
# 开始BV号为1DE411w7a4视频属性的抓取
# BV号为1DE411w7a4的视频属性抓取结束
# 开始BV号为1E7411o7P1视频属性的抓取
# BV号为1E7411o7P1的视频属性抓取结束
# 开始BV号为17E411J7CC视频属性的抓取
# BV号为17E411J7CC的视频属性抓取结束
# 开始BV号为1XE41177aF视频属性的抓取
# BV号为1XE41177aF的视频属性抓取结束
# 开始BV号为1j741127cr视频属性的抓取
# BV号为1j741127cr的视频属性抓取结束
# 开始BV号为1Ve411x71b视频属性的抓取
# BV号为1Ve411x71b的视频属性抓取结束
# 开始BV号为1YE411x7KY视频属性的抓取
# BV号为1YE411x7KY的视频属性抓取结束
# 开始BV号为1dE411H7fz视频属性的抓取
# BV号为1dE411H7fz的视频属性抓取结束
# 开始BV号为1w54y1d7V3视频属性的抓取
# BV号为1w54y1d7V3的视频属性抓取结束
# 开始BV号为1eE411p7S6视频属性的抓取
# BV号为1eE411p7S6的视频属性抓取结束
# 开始BV号为1fE41147ZR视频属性的抓取
# BV号为1fE41147ZR的视频属性抓取结束
# 开始BV号为1Z741197fg视频属性的抓取
# BV号为1Z741197fg的视频属性抓取结束
# 开始BV号为1SE41137m6视频属性的抓取
# BV号为1SE41137m6的视频属性抓取结束
# 开始BV号为1wQ4y1M79V视频属性的抓取
# BV号为1wQ4y1M79V的视频属性抓取结束
# 开始BV号为1LE411N7mW视频属性的抓取
# BV号为1LE411N7mW的视频属性抓取结束
# 开始BV号为1JE411G71J视频属性的抓取
# BV号为1JE411G71J的视频属性抓取结束
# 开始BV号为1nE411M7L2视频属性的抓取
# BV号为1nE411M7L2的视频属性抓取结束
# 开始BV号为1NE411N7o3视频属性的抓取
# BV号为1NE411N7o3的视频属性抓取结束
# 开始BV号为1CE411J7QD视频属性的抓取
# BV号为1CE411J7QD的视频属性抓取结束
# 开始BV号为1R7411y7Tb视频属性的抓取
# BV号为1R7411y7Tb的视频属性抓取结束
# 开始BV号为1t7411R7mS视频属性的抓取
# BV号为1t7411R7mS的视频属性抓取结束
# 开始BV号为1FE411K7N4视频属性的抓取
# BV号为1FE411K7N4的视频属性抓取结束
# 开始BV号为14E411V7QM视频属性的抓取
# BV号为14E411V7QM的视频属性抓取结束
# 开始BV号为1kE411K75T视频属性的抓取
# BV号为1kE411K75T的视频属性抓取结束
# 开始BV号为1VE411F7Aq视频属性的抓取
# BV号为1VE411F7Aq的视频属性抓取结束
# 开始BV号为1TE411F7FV视频属性的抓取
# BV号为1TE411F7FV的视频属性抓取结束
# 开始BV号为1mE41177V2视频属性的抓取
# BV号为1mE41177V2的视频属性抓取结束
# 开始BV号为1CV411f78R视频属性的抓取
# BV号为1CV411f78R的视频属性抓取结束
# 开始BV号为1z7411U7fy视频属性的抓取
# BV号为1z7411U7fy的视频属性抓取结束
# 开始BV号为1t7411U7TH视频属性的抓取
# BV号为1t7411U7TH的视频属性抓取结束
# 开始BV号为18E411g7Dm视频属性的抓取
# BV号为18E411g7Dm的视频属性抓取结束
# 开始BV号为16E41177ed视频属性的抓取
# BV号为16E41177ed的视频属性抓取结束
# 开始BV号为1u741127Ha视频属性的抓取
# BV号为1u741127Ha的视频属性抓取结束
# 开始BV号为1PE411G77M视频属性的抓取
# BV号为1PE411G77M的视频属性抓取结束
# 开始BV号为1cE411t7Gh视频属性的抓取
# BV号为1cE411t7Gh的视频属性抓取结束
# 开始BV号为1zE411w7YR视频属性的抓取
# BV号为1zE411w7YR的视频属性抓取结束
# 开始BV号为1AE411L7Xx视频属性的抓取
# BV号为1AE411L7Xx的视频属性抓取结束
# 开始BV号为1Ae411x7D9视频属性的抓取
# BV号为1Ae411x7D9的视频属性抓取结束
# 开始BV号为1DZ4y1j7jm视频属性的抓取
# BV号为1DZ4y1j7jm的视频属性抓取结束
# 开始BV号为127411R7ih视频属性的抓取
# BV号为127411R7ih的视频属性抓取结束
# 开始BV号为1AE411P7hh视频属性的抓取
# BV号为1AE411P7hh的视频属性抓取结束
# 开始BV号为1uE411p7mS视频属性的抓取
# BV号为1uE411p7mS的视频属性抓取结束
# 开始BV号为1eE411j723视频属性的抓取
# BV号为1eE411j723的视频属性抓取结束
# 开始BV号为18E411P7TY视频属性的抓取
# BV号为18E411P7TY的视频属性抓取结束
# 开始BV号为1kE411s7Kp视频属性的抓取
# BV号为1kE411s7Kp的视频属性抓取结束
# 开始BV号为1XE411N7sz视频属性的抓取
# BV号为1XE411N7sz的视频属性抓取结束
# 开始BV号为1HE411V7hw视频属性的抓取
# BV号为1HE411V7hw的视频属性抓取结束
# 开始BV号为1ep4y117kj视频属性的抓取
# BV号为1ep4y117kj的视频属性抓取结束
# 开始BV号为1B7411m7fN视频属性的抓取
# BV号为1B7411m7fN的视频属性抓取结束
# 开始BV号为1VE411g7ag视频属性的抓取
# BV号为1VE411g7ag的视频属性抓取结束
# 开始BV号为1M7411m7bp视频属性的抓取
# BV号为1M7411m7bp的视频属性抓取结束
# 开始BV号为1vE411w713视频属性的抓取
# BV号为1vE411w713的视频属性抓取结束
# 开始BV号为1n7411o7AP视频属性的抓取
# BV号为1n7411o7AP的视频属性抓取结束
# 开始BV号为1VE411M7C6视频属性的抓取
# BV号为1VE411M7C6的视频属性抓取结束
# 开始BV号为1q541167vg视频属性的抓取
# BV号为1q541167vg的视频属性抓取结束
# 开始BV号为19E411E7YT视频属性的抓取
# BV号为19E411E7YT的视频属性抓取结束
# 开始BV号为1ZE411F7Jr视频属性的抓取
# BV号为1ZE411F7Jr的视频属性抓取结束
# 开始BV号为127411X7Y9视频属性的抓取
# BV号为127411X7Y9的视频属性抓取结束
# 开始BV号为1JE411K7eQ视频属性的抓取
# BV号为1JE411K7eQ的视频属性抓取结束
# 开始BV号为1oE411L739视频属性的抓取
# BV号为1oE411L739的视频属性抓取结束
# 开始BV号为1iE411x7Nj视频属性的抓取
# BV号为1iE411x7Nj的视频属性抓取结束
# 开始BV号为15E411E7gM视频属性的抓取
# BV号为15E411E7gM的视频属性抓取结束
# 开始BV号为1FE411p76a视频属性的抓取
# BV号为1FE411p76a的视频属性抓取结束
# 开始BV号为17E411u7Hh视频属性的抓取
# BV号为17E411u7Hh的视频属性抓取结束
# 开始BV号为1t7411y738视频属性的抓取
# BV号为1t7411y738的视频属性抓取结束
# 开始BV号为1kE411P76g视频属性的抓取
# BV号为1kE411P76g的视频属性抓取结束
# 开始BV号为1dE41157Q7视频属性的抓取
# BV号为1dE41157Q7的视频属性抓取结束
# 开始BV号为1jE411n7dt视频属性的抓取
# BV号为1jE411n7dt的视频属性抓取结束
# 开始BV号为1w741127z2视频属性的抓取
# BV号为1w741127z2的视频属性抓取结束
# 开始BV号为1r7411o7iP视频属性的抓取
# BV号为1r7411o7iP的视频属性抓取结束
# 开始BV号为177411972W视频属性的抓取
# BV号为177411972W的视频属性抓取结束
# 开始BV号为1WE411K7nS视频属性的抓取
# BV号为1WE411K7nS的视频属性抓取结束
# 开始BV号为1PZ4y1j7rk视频属性的抓取
# BV号为1PZ4y1j7rk的视频属性抓取结束
# 开始BV号为167411R7Hz视频属性的抓取
# BV号为167411R7Hz的视频属性抓取结束
# 开始BV号为1HE411u7ge视频属性的抓取
# BV号为1HE411u7ge的视频属性抓取结束
# 开始BV号为1yE411p7FE视频属性的抓取
# BV号为1yE411p7FE的视频属性抓取结束
# 开始BV号为1tE411A7mF视频属性的抓取
# BV号为1tE411A7mF的视频属性抓取结束
# 开始BV号为1zE411x74p视频属性的抓取
# BV号为1zE411x74p的视频属性抓取结束
# 开始BV号为1iE411g7Af视频属性的抓取
# BV号为1iE411g7Af的视频属性抓取结束
# 开始BV号为1d7411X7PZ视频属性的抓取
# BV号为1d7411X7PZ的视频属性抓取结束
# 开始BV号为1Rk4y1d7qE视频属性的抓取
# BV号为1Rk4y1d7qE的视频属性抓取结束
# 开始BV号为1xE411T7m9视频属性的抓取
# BV号为1xE411T7m9的视频属性抓取结束
# 开始BV号为1jE41137ub视频属性的抓取
# BV号为1jE41137ub的视频属性抓取结束
# 开始BV号为1TE411F7rr视频属性的抓取
# BV号为1TE411F7rr的视频属性抓取结束
# 开始BV号为1RE411K7yu视频属性的抓取
# BV号为1RE411K7yu的视频属性抓取结束
# 开始BV号为157411d7z1视频属性的抓取
# BV号为157411d7z1的视频属性抓取结束
# 开始BV号为1X7411C71j视频属性的抓取
# BV号为1X7411C71j的视频属性抓取结束
# 开始BV号为11E411H79u视频属性的抓取
# BV号为11E411H79u的视频属性抓取结束
# 开始BV号为1iZ4y1j71v视频属性的抓取
# BV号为1iZ4y1j71v的视频属性抓取结束
# 开始BV号为1jE41137ZB视频属性的抓取
# BV号为1jE41137ZB的视频属性抓取结束
# 开始BV号为1TE411A73X视频属性的抓取
# BV号为1TE411A73X的视频属性抓取结束
# 开始BV号为1kE411T7DR视频属性的抓取
# BV号为1kE411T7DR的视频属性抓取结束
# 开始BV号为1e7411m7EF视频属性的抓取
# BV号为1e7411m7EF的视频属性抓取结束
# 开始BV号为1La4y1t7gh视频属性的抓取
# BV号为1La4y1t7gh的视频属性抓取结束
# 开始BV号为1KE411g7ZP视频属性的抓取
# BV号为1KE411g7ZP的视频属性抓取结束
# 开始BV号为1st4y1U7MQ视频属性的抓取
# BV号为1st4y1U7MQ的视频属性抓取结束
# 开始BV号为1X64y1T7aA视频属性的抓取
# BV号为1X64y1T7aA的视频属性抓取结束
# 开始BV号为1hk4y1r7EF视频属性的抓取
# BV号为1hk4y1r7EF的视频属性抓取结束
# 开始BV号为1ig4y1z7wj视频属性的抓取
# BV号为1ig4y1z7wj的视频属性抓取结束
# 开始BV号为1bp4y1X7MV视频属性的抓取
# BV号为1bp4y1X7MV的视频属性抓取结束
# 开始BV号为1DT4y1G7uJ视频属性的抓取
# BV号为1DT4y1G7uJ的视频属性抓取结束
# 开始BV号为1hC4y1476V视频属性的抓取
# BV号为1hC4y1476V的视频属性抓取结束
# 开始BV号为1HQ4y1K7kL视频属性的抓取
# 开始BV号为1HQ4y1K7kL视频属性的抓取
# BV号为1HQ4y1K7kL的视频属性抓取结束
# 开始BV号为19a4y1t7zz视频属性的抓取
# BV号为19a4y1t7zz的视频属性抓取结束
# 开始BV号为1rg4y1b7R2视频属性的抓取
# BV号为1rg4y1b7R2的视频属性抓取结束
# 开始BV号为1854y1d7Qc视频属性的抓取
# BV号为1854y1d7Qc的视频属性抓取结束
# 开始BV号为1ZC4y1s79u视频属性的抓取
# BV号为1ZC4y1s79u的视频属性抓取结束
# 开始BV号为1if4y1U7ve视频属性的抓取
# BV号为1if4y1U7ve的视频属性抓取结束
# 开始BV号为1Lf4y1S7oM视频属性的抓取
# BV号为1Lf4y1S7oM的视频属性抓取结束
# 开始BV号为1Ti4y187FV视频属性的抓取
# BV号为1Ti4y187FV的视频属性抓取结束
# 开始BV号为175411t7W1视频属性的抓取
# BV号为175411t7W1的视频属性抓取结束
# 开始BV号为1Jg4y1a7CS视频属性的抓取
# BV号为1Jg4y1a7CS的视频属性抓取结束
# 开始BV号为1pe411x7x5视频属性的抓取
# BV号为1pe411x7x5的视频属性抓取结束
# 开始BV号为1u54y1R7oM视频属性的抓取
# BV号为1u54y1R7oM的视频属性抓取结束
# 开始BV号为1bf4y1S72T视频属性的抓取
# BV号为1bf4y1S72T的视频属性抓取结束
# 开始BV号为1PQ4y1T7hy视频属性的抓取
# BV号为1PQ4y1T7hy的视频属性抓取结束
# 开始BV号为1Nk4y1R7eP视频属性的抓取
# BV号为1Nk4y1R7eP的视频属性抓取结束
# 开始BV号为1UZ4y1x7b1视频属性的抓取
# BV号为1UZ4y1x7b1的视频属性抓取结束
# 开始BV号为1Nk4y1k7ds视频属性的抓取
# BV号为1Nk4y1k7ds的视频属性抓取结束
# 开始BV号为1eK4y1r79i视频属性的抓取
# BV号为1eK4y1r79i的视频属性抓取结束
# 开始BV号为1tK41157S2视频属性的抓取
# BV号为1tK41157S2的视频属性抓取结束
# 开始BV号为1gz411b7kR视频属性的抓取
# BV号为1gz411b7kR的视频属性抓取结束
# <ipython-input-15-27a9ccaa6317>:186: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])
# 开始BV号为1VK41157YN视频属性的抓取
# BV号为1VK41157YN的视频属性抓取结束
# 开始BV号为1ot4y127P4视频属性的抓取
# BV号为1ot4y127P4的视频属性抓取结束
# 开始BV号为1r64y1T7KC视频属性的抓取
# BV号为1r64y1T7KC的视频属性抓取结束
# 开始BV号为1Vz411879A视频属性的抓取
# BV号为1Vz411879A的视频属性抓取结束
# 开始BV号为1Bz411B7uV视频属性的抓取
# BV号为1Bz411B7uV的视频属性抓取结束
# 开始BV号为1DK4y1C7Me视频属性的抓取
# BV号为1DK4y1C7Me的视频属性抓取结束
# 开始BV号为11Z4y1x76v视频属性的抓取
# BV号为11Z4y1x76v的视频属性抓取结束
# 开始BV号为1xK4y1r7DN视频属性的抓取
# BV号为1xK4y1r7DN的视频属性抓取结束
# 开始BV号为1bp4y1X7k5视频属性的抓取
# BV号为1bp4y1X7k5的视频属性抓取结束
# 开始BV号为1FC4y1W7hK视频属性的抓取
# BV号为1FC4y1W7hK的视频属性抓取结束
# 开始BV号为1ik4y197VN视频属性的抓取
# BV号为1ik4y197VN的视频属性抓取结束
# 开始BV号为1UK4y1C7nA视频属性的抓取
# BV号为1UK4y1C7nA的视频属性抓取结束
# 开始BV号为1p54y1d7xV视频属性的抓取
# BV号为1p54y1d7xV的视频属性抓取结束
# 开始BV号为1BV411o7EK视频属性的抓取
# BV号为1BV411o7EK的视频属性抓取结束
# 开始BV号为1Hk4y1R7sd视频属性的抓取
# BV号为1Hk4y1R7sd的视频属性抓取结束
# 开始BV号为1pC4y1W73P视频属性的抓取
# BV号为1pC4y1W73P的视频属性抓取结束
# 开始BV号为11z411b7zM视频属性的抓取
# BV号为11z411b7zM的视频属性抓取结束
# 开始BV号为1Rg4y1z72c视频属性的抓取
# BV号为1Rg4y1z72c的视频属性抓取结束
# 开始BV号为1J5411t73p视频属性的抓取
# BV号为1J5411t73p的视频属性抓取结束
# 开始BV号为15a4y1t7b9视频属性的抓取
# BV号为15a4y1t7b9的视频属性抓取结束
# 开始BV号为1sC4y1s7eF视频属性的抓取
# BV号为1sC4y1s7eF的视频属性抓取结束
# 开始BV号为1Z64y1M7TR视频属性的抓取
# BV号为1Z64y1M7TR的视频属性抓取结束
# 开始BV号为1Nf4y1S7Q8视频属性的抓取
# BV号为1Nf4y1S7Q8的视频属性抓取结束
# 开始BV号为1gz41187XC视频属性的抓取
# BV号为1gz41187XC的视频属性抓取结束
# 开始BV号为1b5411t7WC视频属性的抓取
# BV号为1b5411t7WC的视频属性抓取结束
# 开始BV号为1Me411s7Fs视频属性的抓取
# BV号为1Me411s7Fs的视频属性抓取结束
# 开始BV号为1hT4y157uB视频属性的抓取
# BV号为1hT4y157uB的视频属性抓取结束
# 开始BV号为1sK4y1k762视频属性的抓取
# BV号为1sK4y1k762的视频属性抓取结束
# 开始BV号为1fV411o791视频属性的抓取
# BV号为1fV411o791的视频属性抓取结束
# 开始BV号为1gp4y1y7ya视频属性的抓取
# BV号为1gp4y1y7ya的视频属性抓取结束
# 开始BV号为1HA411b7Ec视频属性的抓取
# BV号为1HA411b7Ec的视频属性抓取结束
# 开始BV号为1Ef4y1m7ph视频属性的抓取
# BV号为1Ef4y1m7ph的视频属性抓取结束
# 开始BV号为1r5411t7XL视频属性的抓取
# BV号为1r5411t7XL的视频属性抓取结束
# 开始BV号为1Uz411b7wf视频属性的抓取
# BV号为1Uz411b7wf的视频属性抓取结束
# 开始BV号为18C4y1W7ZC视频属性的抓取
# BV号为18C4y1W7ZC的视频属性抓取结束
# 开始BV号为1CK411V71D视频属性的抓取
# BV号为1CK411V71D的视频属性抓取结束
# 开始BV号为1Bt4y127uY视频属性的抓取
# BV号为1Bt4y127uY的视频属性抓取结束
# 开始BV号为15t4y1m7Kv视频属性的抓取
# BV号为15t4y1m7Kv的视频属性抓取结束
# 开始BV号为1Bk4y1r7Pb视频属性的抓取
# BV号为1Bk4y1r7Pb的视频属性抓取结束
# 开始BV号为1yk4y197cK视频属性的抓取
# BV号为1yk4y197cK的视频属性抓取结束
# 开始BV号为1tk4y1R785视频属性的抓取
# BV号为1tk4y1R785的视频属性抓取结束
# 开始BV号为1mV411o7CK视频属性的抓取
# BV号为1mV411o7CK的视频属性抓取结束
# 开始BV号为1DK411L7E7视频属性的抓取
# BV号为1DK411L7E7的视频属性抓取结束
# 开始BV号为1JK411j7t1视频属性的抓取
# BV号为1JK411j7t1的视频属性抓取结束
# 开始BV号为1iQ4y1K7dd视频属性的抓取
# BV号为1iQ4y1K7dd的视频属性抓取结束
# 开始BV号为1mg4y1z7X4视频属性的抓取
# BV号为1mg4y1z7X4的视频属性抓取结束
# 开始BV号为1Ai4y187dL视频属性的抓取
# BV号为1Ai4y187dL的视频属性抓取结束
# 开始BV号为11Q4y1K7cv视频属性的抓取
# BV号为11Q4y1K7cv的视频属性抓取结束
# 开始BV号为11z411b79r视频属性的抓取
# BV号为11z411b79r的视频属性抓取结束
# 开始BV号为1LK4y1k7zb视频属性的抓取
# BV号为1LK4y1k7zb的视频属性抓取结束
# 开始BV号为1hC4y1W7NL视频属性的抓取
# BV号为1hC4y1W7NL的视频属性抓取结束
# 开始BV号为1Sk4y1R7Lj视频属性的抓取
# BV号为1Sk4y1R7Lj的视频属性抓取结束
# 开始BV号为1s64y1M7tM视频属性的抓取
# BV号为1s64y1M7tM的视频属性抓取结束
# 开始BV号为1Uk4y1r7Vi视频属性的抓取
# BV号为1Uk4y1r7Vi的视频属性抓取结束
# 开始BV号为1JK4y1k7dG视频属性的抓取
# BV号为1JK4y1k7dG的视频属性抓取结束
# 开始BV号为14k4y1R7fx视频属性的抓取
# BV号为14k4y1R7fx的视频属性抓取结束
# 开始BV号为1zg4y187mu视频属性的抓取
# BV号为1zg4y187mu的视频属性抓取结束
# 开始BV号为16Q4y1K7CH视频属性的抓取
# BV号为16Q4y1K7CH的视频属性抓取结束
# 开始BV号为115411t7aN视频属性的抓取
# BV号为115411t7aN的视频属性抓取结束
# 开始BV号为1uQ4y1N7en视频属性的抓取
# BV号为1uQ4y1N7en的视频属性抓取结束
# 开始BV号为1C5411t7XK视频属性的抓取
# BV号为1C5411t7XK的视频属性抓取结束
# 开始BV号为1XA411b7ZF视频属性的抓取
# BV号为1XA411b7ZF的视频属性抓取结束
# 开始BV号为1sk4y1R74R视频属性的抓取
# BV号为1sk4y1R74R的视频属性抓取结束
# 开始BV号为1sk4y1R7Bd视频属性的抓取
# BV号为1sk4y1R7Bd的视频属性抓取结束
# 开始BV号为1Pk4y1k7yE视频属性的抓取
# BV号为1Pk4y1k7yE的视频属性抓取结束
# 开始BV号为1bK411L7We视频属性的抓取
# BV号为1bK411L7We的视频属性抓取结束
# 开始BV号为1Yk4y197LP视频属性的抓取
# BV号为1Yk4y197LP的视频属性抓取结束
# 开始BV号为1Bg4y187Yi视频属性的抓取
# BV号为1Bg4y187Yi的视频属性抓取结束
# 开始BV号为1Dp4y1X7rF视频属性的抓取
# BV号为1Dp4y1X7rF的视频属性抓取结束
# 开始BV号为1Gz411b7E6视频属性的抓取
# BV号为1Gz411b7E6的视频属性抓取结束
# 开始BV号为1Eg4y1874b视频属性的抓取
# BV号为1Eg4y1874b的视频属性抓取结束
# 开始BV号为1A5411t7mq视频属性的抓取
# BV号为1A5411t7mq的视频属性抓取结束
# 开始BV号为1DK411H7Cm视频属性的抓取
# BV号为1DK411H7Cm的视频属性抓取结束
# 开始BV号为1hA411t7NR视频属性的抓取
# BV号为1hA411t7NR的视频属性抓取结束
# 开始BV号为1Rp4y1S7Bj视频属性的抓取
# BV号为1Rp4y1S7Bj的视频属性抓取结束
# 开始BV号为1me411p7tb视频属性的抓取
# BV号为1me411p7tb的视频属性抓取结束
# 开始BV号为1qi4y1s7pz视频属性的抓取
# BV号为1qi4y1s7pz的视频属性抓取结束
# 开始BV号为11Z4y1p7CD视频属性的抓取
# BV号为11Z4y1p7CD的视频属性抓取结束
# 开始BV号为1ya4y1e7yq视频属性的抓取
# BV号为1ya4y1e7yq的视频属性抓取结束
# 开始BV号为1et4y11775视频属性的抓取
# BV号为1et4y11775的视频属性抓取结束
# 开始BV号为1mZ4y1s7kn视频属性的抓取
# BV号为1mZ4y1s7kn的视频属性抓取结束
# 开始BV号为1vA411q7A5视频属性的抓取
# BV号为1vA411q7A5的视频属性抓取结束
# 开始BV号为1Ef4y1274B视频属性的抓取
# BV号为1Ef4y1274B的视频属性抓取结束
# 开始BV号为1Be411W7ea视频属性的抓取
# BV号为1Be411W7ea的视频属性抓取结束
# 开始BV号为19z4y1X7LR视频属性的抓取
# BV号为19z4y1X7LR的视频属性抓取结束
# 开始BV号为1ik4y167qt视频属性的抓取
# BV号为1ik4y167qt的视频属性抓取结束
# 开始BV号为1Hp4y1Q7mF视频属性的抓取
# BV号为1Hp4y1Q7mF的视频属性抓取结束
# 开始BV号为13Q4y1N7Ep视频属性的抓取
# BV号为13Q4y1N7Ep的视频属性抓取结束
# 开始BV号为1wt4y117TD视频属性的抓取
# BV号为1wt4y117TD的视频属性抓取结束
# 开始BV号为1df4y1172L视频属性的抓取
# BV号为1df4y1172L的视频属性抓取结束
# 开始BV号为17z411B7v2视频属性的抓取
# BV号为17z411B7v2的视频属性抓取结束
# 开始BV号为1Tz411B716视频属性的抓取
# BV号为1Tz411B716的视频属性抓取结束
# 开始BV号为1Yp4y1Q7Ym视频属性的抓取
# BV号为1Yp4y1Q7Ym的视频属性抓取结束
# 开始BV号为1bT4y137Kj视频属性的抓取
# BV号为1bT4y137Kj的视频属性抓取结束
# 开始BV号为1ZK4y147Ly视频属性的抓取
# 开始BV号为1ZK4y147Ly视频属性的抓取
# BV号为1ZK4y147Ly的视频属性抓取结束
# 开始BV号为1bf4y1m7Ja视频属性的抓取
# BV号为1bf4y1m7Ja的视频属性抓取结束
# 开始BV号为1Y54y1D7wf视频属性的抓取
# BV号为1Y54y1D7wf的视频属性抓取结束
# 开始BV号为1zz411z7D7视频属性的抓取
# BV号为1zz411z7D7的视频属性抓取结束
# 开始BV号为1Hf4y1U7hs视频属性的抓取
# BV号为1Hf4y1U7hs的视频属性抓取结束
# 开始BV号为1bZ4y1s7jD视频属性的抓取
# BV号为1bZ4y1s7jD的视频属性抓取结束
# 开始BV号为1VQ4y1P7zM视频属性的抓取
# BV号为1VQ4y1P7zM的视频属性抓取结束
# 开始BV号为1V541147sx视频属性的抓取
# BV号为1V541147sx的视频属性抓取结束
# 开始BV号为11V411d7fQ视频属性的抓取
# BV号为11V411d7fQ的视频属性抓取结束
# 开始BV号为1og4y1B7jn视频属性的抓取
# BV号为1og4y1B7jn的视频属性抓取结束
# 开始BV号为1d5411s76B视频属性的抓取
# BV号为1d5411s76B的视频属性抓取结束
# 开始BV号为1pC4y1p7cm视频属性的抓取
# BV号为1pC4y1p7cm的视频属性抓取结束
# 开始BV号为19C4y1H7jr视频属性的抓取
# BV号为19C4y1H7jr的视频属性抓取结束
# 开始BV号为1kQ4y1A7sp视频属性的抓取
# BV号为1kQ4y1A7sp的视频属性抓取结束
# 开始BV号为1sz411z7Pu视频属性的抓取
# BV号为1sz411z7Pu的视频属性抓取结束
# 开始BV号为1ui4y1475T视频属性的抓取
# BV号为1ui4y1475T的视频属性抓取结束
# 开始BV号为1Tp4y1X7x4视频属性的抓取
# BV号为1Tp4y1X7x4的视频属性抓取结束
# 开始BV号为1Pf4y1U72X视频属性的抓取
# BV号为1Pf4y1U72X的视频属性抓取结束
# 开始BV号为1nA411t7R8视频属性的抓取
# BV号为1nA411t7R8的视频属性抓取结束
# 开始BV号为1J54y1D7yZ视频属性的抓取
# BV号为1J54y1D7yZ的视频属性抓取结束
# 开始BV号为1UT4y1u72w视频属性的抓取
# BV号为1UT4y1u72w的视频属性抓取结束
# 开始BV号为1Cg4y1q746视频属性的抓取
# BV号为1Cg4y1q746的视频属性抓取结束
# 开始BV号为1vV411d7FN视频属性的抓取
# BV号为1vV411d7FN的视频属性抓取结束
# 开始BV号为1bT4y137BK视频属性的抓取
# BV号为1bT4y137BK的视频属性抓取结束
# 开始BV号为1yf4y1m7TG视频属性的抓取
# BV号为1yf4y1m7TG的视频属性抓取结束
# 开始BV号为1qT4y137Km视频属性的抓取
# BV号为1qT4y137Km的视频属性抓取结束
# 开始BV号为1oV411C7T2视频属性的抓取
# BV号为1oV411C7T2的视频属性抓取结束
# 开始BV号为1Mg4y1B7pA视频属性的抓取
# BV号为1Mg4y1B7pA的视频属性抓取结束
# 开始BV号为1NA411t7T3视频属性的抓取
# BV号为1NA411t7T3的视频属性抓取结束
# 开始BV号为18e411p7k4视频属性的抓取
# BV号为18e411p7k4的视频属性抓取结束
# 开始BV号为1gK4y187j9视频属性的抓取
# BV号为1gK4y187j9的视频属性抓取结束
# 开始BV号为1hk4y1k7o4视频属性的抓取
# BV号为1hk4y1k7o4的视频属性抓取结束
# 开始BV号为1hK4y1k7TT视频属性的抓取
# BV号为1hK4y1k7TT的视频属性抓取结束
# 开始BV号为1jz411q7qz视频属性的抓取
# BV号为1jz411q7qz的视频属性抓取结束
# 开始BV号为1ga4y1i7r4视频属性的抓取
# BV号为1ga4y1i7r4的视频属性抓取结束
# 开始BV号为1454y1D7JZ视频属性的抓取
# BV号为1454y1D7JZ的视频属性抓取结束
# 开始BV号为1mi4y147Fh视频属性的抓取
# BV号为1mi4y147Fh的视频属性抓取结束
# 开始BV号为1Lk4y167JX视频属性的抓取
# BV号为1Lk4y167JX的视频属性抓取结束
# 开始BV号为1uA411q7vE视频属性的抓取
# BV号为1uA411q7vE的视频属性抓取结束
# 开始BV号为1st4y117xK视频属性的抓取
# BV号为1st4y117xK的视频属性抓取结束
# 开始BV号为1iz411q7ph视频属性的抓取
# BV号为1iz411q7ph的视频属性抓取结束
# 开始BV号为11C4y1W7VD视频属性的抓取
# BV号为11C4y1W7VD的视频属性抓取结束
# 开始BV号为1JT4y1g7Jb视频属性的抓取
# BV号为1JT4y1g7Jb的视频属性抓取结束
# 开始BV号为15i4y1479D视频属性的抓取
# BV号为15i4y1479D的视频属性抓取结束
# 开始BV号为1zT4y137pB视频属性的抓取
# BV号为1zT4y137pB的视频属性抓取结束
# 开始BV号为1JZ4y1s7Tt视频属性的抓取
# BV号为1JZ4y1s7Tt的视频属性抓取结束
# 开始BV号为1DC4y1H7E2视频属性的抓取
# BV号为1DC4y1H7E2的视频属性抓取结束
# 开始BV号为1Ma4y147Co视频属性的抓取
# BV号为1Ma4y147Co的视频属性抓取结束
# 开始BV号为1mQ4y1A7YF视频属性的抓取
# BV号为1mQ4y1A7YF的视频属性抓取结束
# 开始BV号为12K4y1t7Gz视频属性的抓取
# BV号为12K4y1t7Gz的视频属性抓取结束
# 开始BV号为1UC4y1W7oH视频属性的抓取
# BV号为1UC4y1W7oH的视频属性抓取结束
# 开始BV号为11g4y1q742视频属性的抓取
# BV号为11g4y1q742的视频属性抓取结束
# 开始BV号为1d54y1D71k视频属性的抓取
# BV号为1d54y1D71k的视频属性抓取结束
# 开始BV号为1Bp4y1Q7xA视频属性的抓取
# BV号为1Bp4y1Q7xA的视频属性抓取结束
# 开始BV号为15t4y117jf视频属性的抓取
# BV号为15t4y117jf的视频属性抓取结束
# 开始BV号为1oV411d7NA视频属性的抓取
# BV号为1oV411d7NA的视频属性抓取结束
# 开始BV号为1Yt4y117L9视频属性的抓取
# BV号为1Yt4y117L9的视频属性抓取结束
# 开始BV号为1Gg4y1B74X视频属性的抓取
# BV号为1Gg4y1B74X的视频属性抓取结束
# 开始BV号为1Vf4y127dA视频属性的抓取
# BV号为1Vf4y127dA的视频属性抓取结束
# 开始BV号为1je411W7bn视频属性的抓取
# BV号为1je411W7bn的视频属性抓取结束
# 开始BV号为1zf4y1m74C视频属性的抓取
# BV号为1zf4y1m74C的视频属性抓取结束
# 开始BV号为1ET4y1u7fe视频属性的抓取
# BV号为1ET4y1u7fe的视频属性抓取结束
# 开始BV号为1eK4y187wf视频属性的抓取
# BV号为1eK4y187wf的视频属性抓取结束
# 开始BV号为1yQ4y1N7ZA视频属性的抓取
# BV号为1yQ4y1N7ZA的视频属性抓取结束
# 开始BV号为12i4y1x7dX视频属性的抓取
# BV号为12i4y1x7dX的视频属性抓取结束
# 开始BV号为1ff4y117ED视频属性的抓取
# BV号为1ff4y117ED的视频属性抓取结束
# 开始BV号为1Af4y127Ua视频属性的抓取
# BV号为1Af4y127Ua的视频属性抓取结束
# 开始BV号为1Cz411v72v视频属性的抓取
# BV号为1Cz411v72v的视频属性抓取结束
# 开始BV号为1Wg4y1i74F视频属性的抓取
# BV号为1Wg4y1i74F的视频属性抓取结束
# 开始BV号为1JK411W71u视频属性的抓取
# BV号为1JK411W71u的视频属性抓取结束
# 开始BV号为16K4y1t7eJ视频属性的抓取
# BV号为16K4y1t7eJ的视频属性抓取结束
# 开始BV号为1St4y117Tk视频属性的抓取
# BV号为1St4y117Tk的视频属性抓取结束
# 开始BV号为1xk4y1k7sQ视频属性的抓取
# BV号为1xk4y1k7sQ的视频属性抓取结束
# 开始BV号为1vp4y1Q7Xk视频属性的抓取
# BV号为1vp4y1Q7Xk的视频属性抓取结束
# 开始BV号为1XQ4y1A7Ns视频属性的抓取
# BV号为1XQ4y1A7Ns的视频属性抓取结束
# 开始BV号为16A411q7UA视频属性的抓取
# BV号为16A411q7UA的视频属性抓取结束
# 开始BV号为1Tz411q71n视频属性的抓取
# BV号为1Tz411q71n的视频属性抓取结束
# 开始BV号为16z411v7Hk视频属性的抓取
# BV号为16z411v7Hk的视频属性抓取结束
# 开始BV号为1bK411p7QE视频属性的抓取
# BV号为1bK411p7QE的视频属性抓取结束
# 开始BV号为11f4y1y7Lv视频属性的抓取
# BV号为11f4y1y7Lv的视频属性抓取结束
# 开始BV号为1cT4y1J7kD视频属性的抓取
# BV号为1cT4y1J7kD的视频属性抓取结束
# 开始BV号为1Fv411B7Ld视频属性的抓取
# BV号为1Fv411B7Ld的视频属性抓取结束
# 开始BV号为1Uk4y1B7uT视频属性的抓取
# BV号为1Uk4y1B7uT的视频属性抓取结束
# 开始BV号为1uf4y117WK视频属性的抓取
# BV号为1uf4y117WK的视频属性抓取结束
# 开始BV号为1XC4y1a7NW视频属性的抓取
# BV号为1XC4y1a7NW的视频属性抓取结束
# 开始BV号为1k5411p74g视频属性的抓取
# BV号为1k5411p74g的视频属性抓取结束
# 开始BV号为1Pa4y1e766视频属性的抓取
# BV号为1Pa4y1e766的视频属性抓取结束
# 开始BV号为13a4y1v7Fp视频属性的抓取
# BV号为13a4y1v7Fp的视频属性抓取结束
# 开始BV号为1rf4y1y7Uj视频属性的抓取
# BV号为1rf4y1y7Uj的视频属性抓取结束
# 开始BV号为1u54y1z7cu视频属性的抓取
# BV号为1u54y1z7cu的视频属性抓取结束
# 开始BV号为1Ag4y1q7M4视频属性的抓取
# BV号为1Ag4y1q7M4的视频属性抓取结束
# 开始BV号为1GK411p7Fc视频属性的抓取
# BV号为1GK411p7Fc的视频属性抓取结束
# 开始BV号为1Dz4y197wf视频属性的抓取
# BV号为1Dz4y197wf的视频属性抓取结束
# 开始BV号为1mt4y1X7ZW视频属性的抓取
# BV号为1mt4y1X7ZW的视频属性抓取结束
# 开始BV号为1KK411W7bX视频属性的抓取
# BV号为1KK411W7bX的视频属性抓取结束
# 开始BV号为1nk4y1r77w视频属性的抓取
# BV号为1nk4y1r77w的视频属性抓取结束
# 开始BV号为1s5411Y7QD视频属性的抓取
# BV号为1s5411Y7QD的视频属性抓取结束
# 开始BV号为1Rv411B7Tr视频属性的抓取
# BV号为1Rv411B7Tr的视频属性抓取结束
# 开始BV号为1DK4y1x7em视频属性的抓取
# BV号为1DK4y1x7em的视频属性抓取结束
# 开始BV号为1up4y1D7Hb视频属性的抓取
# BV号为1up4y1D7Hb的视频属性抓取结束
# 开始BV号为11g4y1i7Zx视频属性的抓取
# BV号为11g4y1i7Zx的视频属性抓取结束
# 开始BV号为1iV411r7iD视频属性的抓取
# BV号为1iV411r7iD的视频属性抓取结束
# 开始BV号为1mz411i7RV视频属性的抓取
# BV号为1mz411i7RV的视频属性抓取结束
# 开始BV号为12K4y1x7qh视频属性的抓取
# 开始BV号为12K4y1x7qh视频属性的抓取
# 开始BV号为12K4y1x7qh视频属性的抓取
# BV号为12K4y1x7qh的视频属性抓取结束
# 开始BV号为1Uf4y127WM视频属性的抓取
# BV号为1Uf4y127WM的视频属性抓取结束
# 开始BV号为13D4y1Q7Kz视频属性的抓取
# BV号为13D4y1Q7Kz的视频属性抓取结束
# 开始BV号为14p4y1D7mC视频属性的抓取
# BV号为14p4y1D7mC的视频属性抓取结束
# 开始BV号为19T4y1J7xS视频属性的抓取
# BV号为19T4y1J7xS的视频属性抓取结束
# 开始BV号为1Qf4y1y7x5视频属性的抓取
# BV号为1Qf4y1y7x5的视频属性抓取结束
# 开始BV号为1p54y1B7mx视频属性的抓取
# BV号为1p54y1B7mx的视频属性抓取结束
# 开始BV号为1Z5411W7pF视频属性的抓取
# BV号为1Z5411W7pF的视频属性抓取结束
# 开始BV号为13p4y1D7j8视频属性的抓取
# BV号为13p4y1D7j8的视频属性抓取结束
# 开始BV号为1Uf4y117TJ视频属性的抓取
# BV号为1Uf4y117TJ的视频属性抓取结束
# 开始BV号为1BD4y1D7XC视频属性的抓取
# BV号为1BD4y1D7XC的视频属性抓取结束
# 开始BV号为16A411i7xr视频属性的抓取
# BV号为16A411i7xr的视频属性抓取结束
# 开始BV号为1s5411W75Z视频属性的抓取
# BV号为1s5411W75Z的视频属性抓取结束
# 开始BV号为1o54y1i7e4视频属性的抓取
# BV号为1o54y1i7e4的视频属性抓取结束
# 开始BV号为1RV411C7hh视频属性的抓取
# BV号为1RV411C7hh的视频属性抓取结束
# 开始BV号为1Sg4y1i74S视频属性的抓取
# BV号为1Sg4y1i74S的视频属性抓取结束
# 开始BV号为1p5411W7TM视频属性的抓取
# BV号为1p5411W7TM的视频属性抓取结束
# 开始BV号为1dD4y1D78a视频属性的抓取
# BV号为1dD4y1D78a的视频属性抓取结束
# 开始BV号为1mC4y1a7ip视频属性的抓取
# BV号为1mC4y1a7ip的视频属性抓取结束
# 开始BV号为1CK4y1x7Gy视频属性的抓取
# BV号为1CK4y1x7Gy的视频属性抓取结束
# 开始BV号为1gZ4y1p7te视频属性的抓取
# BV号为1gZ4y1p7te的视频属性抓取结束
# 开始BV号为1tZ4y1W7WH视频属性的抓取
# BV号为1tZ4y1W7WH的视频属性抓取结束
# 开始BV号为1ga4y1e7ad视频属性的抓取
# BV号为1ga4y1e7ad的视频属性抓取结束
# 开始BV号为18v411B78M视频属性的抓取
# BV号为18v411B78M的视频属性抓取结束
# 开始BV号为1ug4y1q77q视频属性的抓取
# BV号为1ug4y1q77q的视频属性抓取结束
# 开始BV号为1xV411k77n视频属性的抓取
# BV号为1xV411k77n的视频属性抓取结束
# 开始BV号为1Mv411B7pJ视频属性的抓取
# BV号为1Mv411B7pJ的视频属性抓取结束
# 开始BV号为1GZ4y1H7iW视频属性的抓取
# BV号为1GZ4y1H7iW的视频属性抓取结束
# 开始BV号为1JD4y1S7WM视频属性的抓取
# BV号为1JD4y1S7WM的视频属性抓取结束
# 开始BV号为1RV411r7Jz视频属性的抓取
# BV号为1RV411r7Jz的视频属性抓取结束
# 开始BV号为1d54y1B7jH视频属性的抓取
# BV号为1d54y1B7jH的视频属性抓取结束
# 开始BV号为19K411p7Nf视频属性的抓取
# BV号为19K411p7Nf的视频属性抓取结束
# 开始BV号为1fz411v7ND视频属性的抓取
# BV号为1fz411v7ND的视频属性抓取结束
# 开始BV号为1nk4y1r7eE视频属性的抓取
# BV号为1nk4y1r7eE的视频属性抓取结束
# 开始BV号为1WC4y1a71p视频属性的抓取
# BV号为1WC4y1a71p的视频属性抓取结束
# 开始BV号为1QC4y187Ho视频属性的抓取
# BV号为1QC4y187Ho的视频属性抓取结束
# 开始BV号为1j5411Y7KY视频属性的抓取
# BV号为1j5411Y7KY的视频属性抓取结束
# 开始BV号为1oC4y1a7x4视频属性的抓取
# BV号为1oC4y1a7x4的视频属性抓取结束
# 开始BV号为15z411v7rW视频属性的抓取
# BV号为15z411v7rW的视频属性抓取结束
# 开始BV号为12K411n724视频属性的抓取
# BV号为12K411n724的视频属性抓取结束
# 开始BV号为1Yk4y1z79z视频属性的抓取
# BV号为1Yk4y1z79z的视频属性抓取结束
# 开始BV号为1Ri4y1G73a视频属性的抓取
# BV号为1Ri4y1G73a的视频属性抓取结束
# 开始BV号为1YA411i7qp视频属性的抓取
# BV号为1YA411i7qp的视频属性抓取结束
# 开始BV号为1mZ4y1H7fz视频属性的抓取
# BV号为1mZ4y1H7fz的视频属性抓取结束
# 开始BV号为1bZ4y1H7UV视频属性的抓取
# BV号为1bZ4y1H7UV的视频属性抓取结束
# 开始BV号为1tz411i7NG视频属性的抓取
# BV号为1tz411i7NG的视频属性抓取结束
# 开始BV号为1rA411v7VE视频属性的抓取
# BV号为1rA411v7VE的视频属性抓取结束
# 开始BV号为1BK4y1x7AM视频属性的抓取
# BV号为1BK4y1x7AM的视频属性抓取结束
# 开始BV号为1qz4y1Q7Kz视频属性的抓取
# BV号为1qz4y1Q7Kz的视频属性抓取结束
# 开始BV号为1NK4y147Bi视频属性的抓取
# BV号为1NK4y147Bi的视频属性抓取结束
# 开始BV号为1UA411q7Gs视频属性的抓取
# BV号为1UA411q7Gs的视频属性抓取结束
# 开始BV号为1U54y1B7xa视频属性的抓取
# BV号为1U54y1B7xa的视频属性抓取结束
# 开始BV号为1ct4y1y7kS视频属性的抓取
# BV号为1ct4y1y7kS的视频属性抓取结束
# 开始BV号为1Ma4y1Y7xu视频属性的抓取
# BV号为1Ma4y1Y7xu的视频属性抓取结束
# 开始BV号为14Z4y1H7Tz视频属性的抓取
# BV号为14Z4y1H7Tz的视频属性抓取结束
# 开始BV号为1uf4y1m7oc视频属性的抓取
# BV号为1uf4y1m7oc的视频属性抓取结束
# 开始BV号为1gt4y197y1视频属性的抓取
# BV号为1gt4y197y1的视频属性抓取结束
# 开始BV号为1EA411i7qA视频属性的抓取
# BV号为1EA411i7qA的视频属性抓取结束
# 开始BV号为1sk4y1r7sF视频属性的抓取
# BV号为1sk4y1r7sF的视频属性抓取结束
# 开始BV号为1KK4y1b7C7视频属性的抓取
# BV号为1KK4y1b7C7的视频属性抓取结束
# 开始BV号为1fv411z7wK视频属性的抓取
# BV号为1fv411z7wK的视频属性抓取结束
# 开始BV号为1ff4y12755视频属性的抓取
# BV号为1ff4y12755的视频属性抓取结束
# 开始BV号为1kK4y147mL视频属性的抓取
# BV号为1kK4y147mL的视频属性抓取结束
# 开始BV号为1r5411p7dm视频属性的抓取
# BV号为1r5411p7dm的视频属性抓取结束
# 开始BV号为1ZZ4y1M7jL视频属性的抓取
# BV号为1ZZ4y1M7jL的视频属性抓取结束
# 开始BV号为1AK411p7rD视频属性的抓取
# 开始BV号为1AK411p7rD视频属性的抓取
# BV号为1AK411p7rD的视频属性抓取结束
# 开始BV号为1jt4y197T8视频属性的抓取
# BV号为1jt4y197T8的视频属性抓取结束
# 开始BV号为1CA411i7Xv视频属性的抓取
# BV号为1CA411i7Xv的视频属性抓取结束
# 开始BV号为13f4y1m7gX视频属性的抓取
# BV号为13f4y1m7gX的视频属性抓取结束
# 开始BV号为1X5411p7hV视频属性的抓取
# BV号为1X5411p7hV的视频属性抓取结束
# 开始BV号为1wA411i7Pt视频属性的抓取
# BV号为1wA411i7Pt的视频属性抓取结束
# 开始BV号为13i4y1x7Hy视频属性的抓取
# BV号为13i4y1x7Hy的视频属性抓取结束
# 开始BV号为1E5411Y7hA视频属性的抓取
# BV号为1E5411Y7hA的视频属性抓取结束
# 开始BV号为1NK411W7pJ视频属性的抓取
# BV号为1NK411W7pJ的视频属性抓取结束
# 开始BV号为1L54y1S7sP视频属性的抓取
# BV号为1L54y1S7sP的视频属性抓取结束
# 开始BV号为1nZ4y1u7tP视频属性的抓取
# BV号为1nZ4y1u7tP的视频属性抓取结束
# 开始BV号为1yD4y1m7pe视频属性的抓取
# BV号为1yD4y1m7pe的视频属性抓取结束
# 开始BV号为1pz411v7AA视频属性的抓取
# BV号为1pz411v7AA的视频属性抓取结束
# 开始BV号为1ok4y1q7pp视频属性的抓取
# BV号为1ok4y1q7pp的视频属性抓取结束
# 开始BV号为1kz4y1D7cT视频属性的抓取
# BV号为1kz4y1D7cT的视频属性抓取结束
# 开始BV号为19a4y1Y7ca视频属性的抓取
# BV号为19a4y1Y7ca的视频属性抓取结束
# 开始BV号为1B5411Y7Z2视频属性的抓取
# BV号为1B5411Y7Z2的视频属性抓取结束
# 开始BV号为1VK4y1s7J6视频属性的抓取
# BV号为1VK4y1s7J6的视频属性抓取结束
# 开始BV号为1KC4y18719视频属性的抓取
# BV号为1KC4y18719的视频属性抓取结束
# 开始BV号为1Tk4y1B7V1视频属性的抓取
# BV号为1Tk4y1B7V1的视频属性抓取结束
# 开始BV号为17i4y137My视频属性的抓取
# BV号为17i4y137My的视频属性抓取结束
# 开始BV号为1eZ4y1u7se视频属性的抓取
# BV号为1eZ4y1u7se的视频属性抓取结束
# 开始BV号为1LC4y1b7Rr视频属性的抓取
# BV号为1LC4y1b7Rr的视频属性抓取结束
# 开始BV号为1ZA411a75j视频属性的抓取
# BV号为1ZA411a75j的视频属性抓取结束
# 开始BV号为18D4y1S73j视频属性的抓取
# BV号为18D4y1S73j的视频属性抓取结束
# 开始BV号为1sk4y1B7F5视频属性的抓取
# BV号为1sk4y1B7F5的视频属性抓取结束
# 开始BV号为1pK411H7qH视频属性的抓取
# BV号为1pK411H7qH的视频属性抓取结束
# 开始BV号为1b5411Y76r视频属性的抓取
# BV号为1b5411Y76r的视频属性抓取结束
# 开始BV号为1th411o7Yg视频属性的抓取
# BV号为1th411o7Yg的视频属性抓取结束
# 开始BV号为1Za4y1Y76j视频属性的抓取
# BV号为1Za4y1Y76j的视频属性抓取结束
# 开始BV号为1Lp4y1S7mG视频属性的抓取
# BV号为1Lp4y1S7mG的视频属性抓取结束
# 开始BV号为1G54y1S7n5视频属性的抓取
# BV号为1G54y1S7n5的视频属性抓取结束
# 开始BV号为1M54y1B7MK视频属性的抓取
# BV号为1M54y1B7MK的视频属性抓取结束
# 开始BV号为1QK411J7Po视频属性的抓取
# BV号为1QK411J7Po的视频属性抓取结束
# 开始BV号为1WK4y1x7Dn视频属性的抓取
# BV号为1WK4y1x7Dn的视频属性抓取结束
# 开始BV号为1Ma4y1a7FX视频属性的抓取
# BV号为1Ma4y1a7FX的视频属性抓取结束
# 开始BV号为15C4y1h7BJ视频属性的抓取
# BV号为15C4y1h7BJ的视频属性抓取结束
# 开始BV号为15f4y1d7Z9视频属性的抓取
# BV号为15f4y1d7Z9的视频属性抓取结束
# 开始BV号为1fk4y1z7bA视频属性的抓取
# BV号为1fk4y1z7bA的视频属性抓取结束
# 开始BV号为1kC4y1h73K视频属性的抓取
# BV号为1kC4y1h73K的视频属性抓取结束
# 开始BV号为13D4y1D7sT视频属性的抓取
# BV号为13D4y1D7sT的视频属性抓取结束
# 开始BV号为13T4y1j7yv视频属性的抓取
# BV号为13T4y1j7yv的视频属性抓取结束
# 开始BV号为1oZ4y1u7Cf视频属性的抓取
# BV号为1oZ4y1u7Cf的视频属性抓取结束
# 开始BV号为1rz4y1X75K视频属性的抓取
# 开始BV号为1rz4y1X75K视频属性的抓取
# BV号为1rz4y1X75K的视频属性抓取结束
# 开始BV号为1d54y1U7JZ视频属性的抓取
# BV号为1d54y1U7JZ的视频属性抓取结束
# 开始BV号为1gA411v7wu视频属性的抓取
# BV号为1gA411v7wu的视频属性抓取结束
# 开始BV号为1c5411a7Uw视频属性的抓取
# BV号为1c5411a7Uw的视频属性抓取结束
# 开始BV号为12V411B7oF视频属性的抓取
# BV号为12V411B7oF的视频属性抓取结束
# 开始BV号为1dD4y1S7bN视频属性的抓取
# BV号为1dD4y1S7bN的视频属性抓取结束
# 开始BV号为1Nk4y1m7Nb视频属性的抓取
# BV号为1Nk4y1m7Nb的视频属性抓取结束
# 开始BV号为16K411n7NB视频属性的抓取
# BV号为16K411n7NB的视频属性抓取结束
# 开始BV号为1RV411B7be视频属性的抓取
# BV号为1RV411B7be的视频属性抓取结束
# 开始BV号为1Za4y1h7gS视频属性的抓取
# BV号为1Za4y1h7gS的视频属性抓取结束
# 开始BV号为1Nz4y1X7oP视频属性的抓取
# BV号为1Nz4y1X7oP的视频属性抓取结束
# 开始BV号为1QT4y177dz视频属性的抓取
# BV号为1QT4y177dz的视频属性抓取结束
# 开始BV号为1na4y1a7za视频属性的抓取
# BV号为1na4y1a7za的视频属性抓取结束
# 开始BV号为1ip4y1U75X视频属性的抓取
# BV号为1ip4y1U75X的视频属性抓取结束
# 开始BV号为1DK4y1e77M视频属性的抓取
# BV号为1DK4y1e77M的视频属性抓取结束
# 开始BV号为17C4y1b7uS视频属性的抓取
# BV号为17C4y1b7uS的视频属性抓取结束
# 开始BV号为1Ja4y1a7En视频属性的抓取
# BV号为1Ja4y1a7En的视频属性抓取结束
# 开始BV号为13K4y1x7ev视频属性的抓取
# BV号为13K4y1x7ev的视频属性抓取结束
# 开始BV号为1xt4y1D7fG视频属性的抓取
# BV号为1xt4y1D7fG的视频属性抓取结束
# 开始BV号为1Kf4y1R7qm视频属性的抓取
# BV号为1Kf4y1R7qm的视频属性抓取结束
# 开始BV号为15h411Z7ks视频属性的抓取
# 开始BV号为15h411Z7ks视频属性的抓取
# BV号为15h411Z7ks的视频属性抓取结束
# 开始BV号为1sf4y1R7e4视频属性的抓取
# BV号为1sf4y1R7e4的视频属性抓取结束
# 开始BV号为1gA411v7Z2视频属性的抓取
# BV号为1gA411v7Z2的视频属性抓取结束
# 开始BV号为1ha4y1a7t6视频属性的抓取
# BV号为1ha4y1a7t6的视频属性抓取结束
# 开始BV号为1Fz4y1Q7qz视频属性的抓取
# BV号为1Fz4y1Q7qz的视频属性抓取结束
# 开始BV号为15f4y1d7ar视频属性的抓取
# BV号为15f4y1d7ar的视频属性抓取结束
# 开始BV号为1qh411Z7Eo视频属性的抓取
# BV号为1qh411Z7Eo的视频属性抓取结束
# 开始BV号为1DT4y177wa视频属性的抓取
# BV号为1DT4y177wa的视频属性抓取结束
# 开始BV号为1nf4y1R7jY视频属性的抓取
# BV号为1nf4y1R7jY的视频属性抓取结束
# 开始BV号为1dD4y1m7HS视频属性的抓取
# BV号为1dD4y1m7HS的视频属性抓取结束
# 开始BV号为1nK411n7xG视频属性的抓取
# BV号为1nK411n7xG的视频属性抓取结束
# 开始BV号为1Hf4y1R7CT视频属性的抓取
# 开始BV号为1Hf4y1R7CT视频属性的抓取
# BV号为1Hf4y1R7CT的视频属性抓取结束
# 开始BV号为1gK411H7qW视频属性的抓取
# BV号为1gK411H7qW的视频属性抓取结束
# 开始BV号为1gD4y1U7Mk视频属性的抓取
# BV号为1gD4y1U7Mk的视频属性抓取结束
# 开始BV号为15k4y1B7fT视频属性的抓取
# BV号为15k4y1B7fT的视频属性抓取结束
# 开始BV号为1bv411B7NA视频属性的抓取
# BV号为1bv411B7NA的视频属性抓取结束
# 开始BV号为1zT4y1j716视频属性的抓取
# BV号为1zT4y1j716的视频属性抓取结束
# 开始BV号为1JC4y1h75H视频属性的抓取
# BV号为1JC4y1h75H的视频属性抓取结束
# 开始BV号为1NK4y1x7pQ视频属性的抓取
# BV号为1NK4y1x7pQ的视频属性抓取结束
# 开始BV号为1CK4y147PV视频属性的抓取
# BV号为1CK4y147PV的视频属性抓取结束
# 开始BV号为1Rp4y1i79w视频属性的抓取
# BV号为1Rp4y1i79w的视频属性抓取结束
# 开始BV号为1V5411Y7ge视频属性的抓取
# BV号为1V5411Y7ge的视频属性抓取结束
# 开始BV号为1X54y1i78P视频属性的抓取
# BV号为1X54y1i78P的视频属性抓取结束
# 开始BV号为1Ct4y1Q7vv视频属性的抓取
# BV号为1Ct4y1Q7vv的视频属性抓取结束
# 开始BV号为1Yv411B7sT视频属性的抓取
# BV号为1Yv411B7sT的视频属性抓取结束
# 开始BV号为16Z4y1u76F视频属性的抓取
# BV号为16Z4y1u76F的视频属性抓取结束
# 开始BV号为1xT4y1E7qT视频属性的抓取
# BV号为1xT4y1E7qT的视频属性抓取结束
# 开始BV号为18z411v79J视频属性的抓取
# BV号为18z411v79J的视频属性抓取结束
# 开始BV号为1CC4y1b7fo视频属性的抓取
# BV号为1CC4y1b7fo的视频属性抓取结束
# 开始BV号为16k4y1q7nT视频属性的抓取
# BV号为16k4y1q7nT的视频属性抓取结束
# 开始BV号为1MK4y1x71J视频属性的抓取
# BV号为1MK4y1x71J的视频属性抓取结束
# 开始BV号为1uD4y1D7g6视频属性的抓取
# BV号为1uD4y1D7g6的视频属性抓取结束
# 开始BV号为1Mh411Z7Q6视频属性的抓取
# BV号为1Mh411Z7Q6的视频属性抓取结束
# 开始BV号为1Yh411Z7eu视频属性的抓取
# BV号为1Yh411Z7eu的视频属性抓取结束
# 开始BV号为1jg4y1v73J视频属性的抓取
# BV号为1jg4y1v73J的视频属性抓取结束
# 开始BV号为1r54y1S7Kf视频属性的抓取
# BV号为1r54y1S7Kf的视频属性抓取结束
# 开始BV号为17k4y1B7or视频属性的抓取
# BV号为17k4y1B7or的视频属性抓取结束
# 开始BV号为1554y1z718视频属性的抓取
# BV号为1554y1z718的视频属性抓取结束
# 开始BV号为1vV411k71r视频属性的抓取
# BV号为1vV411k71r的视频属性抓取结束
# 开始BV号为12t4y1Q7tM视频属性的抓取
# BV号为12t4y1Q7tM的视频属性抓取结束
# 开始BV号为19T4y1J7sG视频属性的抓取
# BV号为19T4y1J7sG的视频属性抓取结束
# 开始BV号为1e54y1q7cE视频属性的抓取
# BV号为1e54y1q7cE的视频属性抓取结束
# 开始BV号为1ef4y1R7Pw视频属性的抓取
# BV号为1ef4y1R7Pw的视频属性抓取结束
# 开始BV号为1SV411B7VQ视频属性的抓取
# BV号为1SV411B7VQ的视频属性抓取结束
# 开始BV号为1vC4y1b725视频属性的抓取
# BV号为1vC4y1b725的视频属性抓取结束
# 开始BV号为1KZ4y1p7qM视频属性的抓取
# BV号为1KZ4y1p7qM的视频属性抓取结束
# 开始BV号为12t4y1D79N视频属性的抓取
# BV号为12t4y1D79N的视频属性抓取结束
# 开始BV号为12k4y1m7Fo视频属性的抓取
# BV号为12k4y1m7Fo的视频属性抓取结束
# 开始BV号为1r54y127U1视频属性的抓取
# BV号为1r54y127U1的视频属性抓取结束
# 开始BV号为1964y1c7xy视频属性的抓取
# BV号为1964y1c7xy的视频属性抓取结束
# 开始BV号为1g64y1c7mf视频属性的抓取
# BV号为1g64y1c7mf的视频属性抓取结束
# 开始BV号为1QD4y1U7Lx视频属性的抓取
# BV号为1QD4y1U7Lx的视频属性抓取结束
# 开始BV号为13Z4y1M7zn视频属性的抓取
# BV号为13Z4y1M7zn的视频属性抓取结束
# 开始BV号为1kh411d7ai视频属性的抓取
# BV号为1kh411d7ai的视频属性抓取结束
# 开始BV号为1hi4y1g7Tr视频属性的抓取
# BV号为1hi4y1g7Tr的视频属性抓取结束
# 开始BV号为1sz4y1f7nn视频属性的抓取
# BV号为1sz4y1f7nn的视频属性抓取结束
# 开始BV号为1TT4y177K3视频属性的抓取
# BV号为1TT4y177K3的视频属性抓取结束
# 开始BV号为1fV411B7ku视频属性的抓取
# BV号为1fV411B7ku的视频属性抓取结束
# 开始BV号为1Ca4y1E7RM视频属性的抓取
# BV号为1Ca4y1E7RM的视频属性抓取结束
# 开始BV号为1dV411U72Q视频属性的抓取
# BV号为1dV411U72Q的视频属性抓取结束
# 开始BV号为1pZ4y1M7JS视频属性的抓取
# BV号为1pZ4y1M7JS的视频属性抓取结束
# 开始BV号为1n54y1U7S1视频属性的抓取
# BV号为1n54y1U7S1的视频属性抓取结束
# 开始BV号为1oC4y1b7WX视频属性的抓取
# BV号为1oC4y1b7WX的视频属性抓取结束
# 开始BV号为13K4y1e7sN视频属性的抓取
# BV号为13K4y1e7sN的视频属性抓取结束
# 开始BV号为1RK4y1Y7wn视频属性的抓取
# BV号为1RK4y1Y7wn的视频属性抓取结束
# 开始BV号为1Pf4y197Zf视频属性的抓取
# BV号为1Pf4y197Zf的视频属性抓取结束
# 开始BV号为1QD4y1d7sh视频属性的抓取
# BV号为1QD4y1d7sh的视频属性抓取结束
# 开始BV号为1i54y1i7fQ视频属性的抓取
# BV号为1i54y1i7fQ的视频属性抓取结束
# 开始BV号为1Mp4y1i7sm视频属性的抓取
# BV号为1Mp4y1i7sm的视频属性抓取结束
# 开始BV号为1Ca4y1J7yy视频属性的抓取
# BV号为1Ca4y1J7yy的视频属性抓取结束
# 开始BV号为1Tk4y1y7b8视频属性的抓取
# BV号为1Tk4y1y7b8的视频属性抓取结束
# 开始BV号为1CT4y1j7j8视频属性的抓取
# BV号为1CT4y1j7j8的视频属性抓取结束
# 开始BV号为19y4y1C7be视频属性的抓取
# BV号为19y4y1C7be的视频属性抓取结束
# 开始BV号为1P54y1D7Qn视频属性的抓取
# BV号为1P54y1D7Qn的视频属性抓取结束
# 开始BV号为1xh411Z7z6视频属性的抓取
# BV号为1xh411Z7z6的视频属性抓取结束
# 开始BV号为13i4y1g7DC视频属性的抓取
# BV号为13i4y1g7DC的视频属性抓取结束
# 开始BV号为17Z4y1K7Ep视频属性的抓取
# BV号为17Z4y1K7Ep的视频属性抓取结束
# 开始BV号为1z54y1v7ay视频属性的抓取
# BV号为1z54y1v7ay的视频属性抓取结束
# 开始BV号为1K64y1c7mk视频属性的抓取
# BV号为1K64y1c7mk的视频属性抓取结束
# 开始BV号为1Ci4y1u7Le视频属性的抓取
# BV号为1Ci4y1u7Le的视频属性抓取结束
# 开始BV号为1wp4y1i7Qr视频属性的抓取
# BV号为1wp4y1i7Qr的视频属性抓取结束
# 开始BV号为1964y1c73X视频属性的抓取
# BV号为1964y1c73X的视频属性抓取结束
# 开始BV号为1zf4y1X7K9视频属性的抓取
# BV号为1zf4y1X7K9的视频属性抓取结束
# 开始BV号为1np4y1v7bs视频属性的抓取
# BV号为1np4y1v7bs的视频属性抓取结束
# 开始BV号为1Ut4y1D7NX视频属性的抓取
# BV号为1Ut4y1D7NX的视频属性抓取结束
# 开始BV号为1d64y1F7ae视频属性的抓取
# BV号为1d64y1F7ae的视频属性抓取结束
# 开始BV号为14a4y1J778视频属性的抓取
# BV号为14a4y1J778的视频属性抓取结束
# 开始BV号为1xp4y1v7E6视频属性的抓取
# BV号为1xp4y1v7E6的视频属性抓取结束
# 开始BV号为1dC4y1t7Au视频属性的抓取
# BV号为1dC4y1t7Au的视频属性抓取结束
# 开始BV号为14a4y1J7Dv视频属性的抓取
# BV号为14a4y1J7Dv的视频属性抓取结束
# 开始BV号为17D4y1m77g视频属性的抓取
# BV号为17D4y1m77g的视频属性抓取结束
# 开始BV号为1Fi4y1G7dh视频属性的抓取
# BV号为1Fi4y1G7dh的视频属性抓取结束
# 开始BV号为1j54y1U7GP视频属性的抓取
# BV号为1j54y1U7GP的视频属性抓取结束
# 开始BV号为1mA411J7j2视频属性的抓取
# BV号为1mA411J7j2的视频属性抓取结束
# 开始BV号为1ak4y127NZ视频属性的抓取
# BV号为1ak4y127NZ的视频属性抓取结束
# 开始BV号为15h411d7fq视频属性的抓取
# BV号为15h411d7fq的视频属性抓取结束
# 开始BV号为1ba4y1E7X9视频属性的抓取
# BV号为1ba4y1E7X9的视频属性抓取结束
# 开始BV号为1u54y1e7Q1视频属性的抓取
# BV号为1u54y1e7Q1的视频属性抓取结束
# 开始BV号为1DV411z7df视频属性的抓取
# BV号为1DV411z7df的视频属性抓取结束
# 开始BV号为1w5411b7nQ视频属性的抓取
# BV号为1w5411b7nQ的视频属性抓取结束
# 开始BV号为1L54y1v7FX视频属性的抓取
# BV号为1L54y1v7FX的视频属性抓取结束
# 开始BV号为1kV411z7gS视频属性的抓取
# BV号为1kV411z7gS的视频属性抓取结束
# 开始BV号为1j54y1U7hc视频属性的抓取
# BV号为1j54y1U7hc的视频属性抓取结束
# 开始BV号为1z64y1c7FF视频属性的抓取
# BV号为1z64y1c7FF的视频属性抓取结束
# 开始BV号为1AT4y177gv视频属性的抓取
# BV号为1AT4y177gv的视频属性抓取结束
# 开始BV号为1AD4y1U7LJ视频属性的抓取
# BV号为1AD4y1U7LJ的视频属性抓取结束
# 开始BV号为1Hv41117hd视频属性的抓取
# BV号为1Hv41117hd的视频属性抓取结束
# 开始BV号为1Q64y1c7kJ视频属性的抓取
# BV号为1Q64y1c7kJ的视频属性抓取结束
# 开始BV号为1xZ4y1T7ap视频属性的抓取
# BV号为1xZ4y1T7ap的视频属性抓取结束
# 开始BV号为16p4y1q7ng视频属性的抓取
# BV号为16p4y1q7ng的视频属性抓取结束
# 开始BV号为1ZT4y1j7Mw视频属性的抓取
# BV号为1ZT4y1j7Mw的视频属性抓取结束
# 开始BV号为1rv411v7Jw视频属性的抓取
# BV号为1rv411v7Jw的视频属性抓取结束
# 开始BV号为1t54y1v7ea视频属性的抓取
# BV号为1t54y1v7ea的视频属性抓取结束
# 开始BV号为1vk4y117xd视频属性的抓取
# BV号为1vk4y117xd的视频属性抓取结束
# 开始BV号为1Eh411d79v视频属性的抓取
# BV号为1Eh411d79v的视频属性抓取结束
# 开始BV号为1854y1v7Ag视频属性的抓取
# BV号为1854y1v7Ag的视频属性抓取结束
# 开始BV号为1fC4y147Qw视频属性的抓取
# BV号为1fC4y147Qw的视频属性抓取结束
# 开始BV号为1mV411z7Sf视频属性的抓取
# BV号为1mV411z7Sf的视频属性抓取结束
# 开始BV号为1Af4y1X7ST视频属性的抓取
# BV号为1Af4y1X7ST的视频属性抓取结束
# 开始BV号为17i4y1g7T7视频属性的抓取
# BV号为17i4y1g7T7的视频属性抓取结束
# 开始BV号为1ba4y1774A视频属性的抓取
# BV号为1ba4y1774A的视频属性抓取结束
# 开始BV号为1mv411q71B视频属性的抓取
# BV号为1mv411q71B的视频属性抓取结束
# 开始BV号为12y4y1C7xX视频属性的抓取
# BV号为12y4y1C7xX的视频属性抓取结束
# 开始BV号为11t4y1U7zo视频属性的抓取
# BV号为11t4y1U7zo的视频属性抓取结束
# 开始BV号为1bp4y1v7NY视频属性的抓取
# BV号为1bp4y1v7NY的视频属性抓取结束
# 开始BV号为1HK4y1v7U1视频属性的抓取
# BV号为1HK4y1v7U1的视频属性抓取结束
# 开始BV号为1fa4y177oe视频属性的抓取
# BV号为1fa4y177oe的视频属性抓取结束
# 开始BV号为1ya4y1E7XN视频属性的抓取
# BV号为1ya4y1E7XN的视频属性抓取结束
# 开始BV号为1hk4y1m7kq视频属性的抓取
# BV号为1hk4y1m7kq的视频属性抓取结束
# 开始BV号为1Wi4y1g7Ri视频属性的抓取
# BV号为1Wi4y1g7Ri的视频属性抓取结束
# 开始BV号为1Dh411d7E8视频属性的抓取
# BV号为1Dh411d7E8的视频属性抓取结束
# 开始BV号为1ap4y1v78D视频属性的抓取
# BV号为1ap4y1v78D的视频属性抓取结束
# 开始BV号为1e54y1e7oL视频属性的抓取
# BV号为1e54y1e7oL的视频属性抓取结束
# 开始BV号为1eT4y1j71z视频属性的抓取
# BV号为1eT4y1j71z的视频属性抓取结束
# 开始BV号为1Bf4y197GZ视频属性的抓取
# BV号为1Bf4y197GZ的视频属性抓取结束
# 开始BV号为1K54y1U7cB视频属性的抓取
# BV号为1K54y1U7cB的视频属性抓取结束
# 开始BV号为12T4y157JT视频属性的抓取
# BV号为12T4y157JT的视频属性抓取结束
# 开始BV号为1Ph411d7h5视频属性的抓取
# BV号为1Ph411d7h5的视频属性抓取结束
# 开始BV号为1Wh411d7oM视频属性的抓取
# BV号为1Wh411d7oM的视频属性抓取结束
# 开始BV号为1754y1U7CF视频属性的抓取
# BV号为1754y1U7CF的视频属性抓取结束
# 开始BV号为1HT4y1L7qR视频属性的抓取
# BV号为1HT4y1L7qR的视频属性抓取结束
# 开始BV号为1Nv41117iU视频属性的抓取
# BV号为1Nv41117iU的视频属性抓取结束
# 开始BV号为1jf4y197wU视频属性的抓取
# BV号为1jf4y197wU的视频属性抓取结束
# 开始BV号为1hA411n7QN视频属性的抓取
# BV号为1hA411n7QN的视频属性抓取结束
# 开始BV号为15a4y177q5视频属性的抓取
# BV号为15a4y177q5的视频属性抓取结束
# 开始BV号为1at4y1S7xY视频属性的抓取
# BV号为1at4y1S7xY的视频属性抓取结束
# 开始BV号为1wD4y1Z7pL视频属性的抓取
# BV号为1wD4y1Z7pL的视频属性抓取结束
# 开始BV号为1m54y1y7Qs视频属性的抓取
# BV号为1m54y1y7Qs的视频属性抓取结束
# 开始BV号为1AA411J7SK视频属性的抓取
# BV号为1AA411J7SK的视频属性抓取结束
# 开始BV号为1rK4y1a7YL视频属性的抓取
# BV号为1rK4y1a7YL的视频属性抓取结束
# 开始BV号为1LT4y1A7ia视频属性的抓取
# BV号为1LT4y1A7ia的视频属性抓取结束
# 开始BV号为1ZA411E7Qm视频属性的抓取
# BV号为1ZA411E7Qm的视频属性抓取结束
# 开始BV号为1u541187KA视频属性的抓取
# BV号为1u541187KA的视频属性抓取结束
# 开始BV号为1Yh411R7PT视频属性的抓取
# BV号为1Yh411R7PT的视频属性抓取结束
# 开始BV号为1Li4y1u7Ky视频属性的抓取
# BV号为1Li4y1u7Ky的视频属性抓取结束
# 开始BV号为18V41117Y7视频属性的抓取
# BV号为18V41117Y7的视频属性抓取结束
# 开始BV号为1X54y1e7qy视频属性的抓取
# BV号为1X54y1e7qy的视频属性抓取结束
# 开始BV号为1Ya4y1j7h6视频属性的抓取
# BV号为1Ya4y1j7h6的视频属性抓取结束
# 开始BV号为1Bi4y1M7Gn视频属性的抓取
# BV号为1Bi4y1M7Gn的视频属性抓取结束
# 开始BV号为19a4y1L7p4视频属性的抓取
# BV号为19a4y1L7p4的视频属性抓取结束
# 开始BV号为1yT4y1w7PB视频属性的抓取
# BV号为1yT4y1w7PB的视频属性抓取结束
# 开始BV号为1iT4y1L7nR视频属性的抓取
# BV号为1iT4y1L7nR的视频属性抓取结束
# 开始BV号为1Ht4y1q7A8视频属性的抓取
# BV号为1Ht4y1q7A8的视频属性抓取结束
# 开始BV号为1ri4y1M7zK视频属性的抓取
# BV号为1ri4y1M7zK的视频属性抓取结束
# 开始BV号为1jh411X71L视频属性的抓取
# BV号为1jh411X71L的视频属性抓取结束
# 开始BV号为17h411R7V4视频属性的抓取
# BV号为17h411R7V4的视频属性抓取结束
# 开始BV号为13T4y1A7of视频属性的抓取
# BV号为13T4y1A7of的视频属性抓取结束
# 开始BV号为1sZ4y1T76F视频属性的抓取
# BV号为1sZ4y1T76F的视频属性抓取结束
# 开始BV号为1ET4y1c7Ew视频属性的抓取
# BV号为1ET4y1c7Ew的视频属性抓取结束
# 开始BV号为1x54y117nj视频属性的抓取
# BV号为1x54y117nj的视频属性抓取结束
# 开始BV号为13y4y1C7Yy视频属性的抓取
# BV号为13y4y1C7Yy的视频属性抓取结束
# 开始BV号为1Xh411R73c视频属性的抓取
# BV号为1Xh411R73c的视频属性抓取结束
# 开始BV号为1HV411m7Lh视频属性的抓取
# BV号为1HV411m7Lh的视频属性抓取结束
# 开始BV号为1uK4y1Y7hy视频属性的抓取
# BV号为1uK4y1Y7hy的视频属性抓取结束
# 开始BV号为1J54y1y7sV视频属性的抓取
# BV号为1J54y1y7sV的视频属性抓取结束
# 开始BV号为1wt4y1q76A视频属性的抓取
# BV号为1wt4y1q76A的视频属性抓取结束
# 开始BV号为1754y127TU视频属性的抓取
# BV号为1754y127TU的视频属性抓取结束
# 开始BV号为1TK4y1Y7dr视频属性的抓取
# BV号为1TK4y1Y7dr的视频属性抓取结束
# 开始BV号为1vv411C7TL视频属性的抓取
# BV号为1vv411C7TL的视频属性抓取结束
# 开始BV号为1uT4y1A7FF视频属性的抓取
# BV号为1uT4y1A7FF的视频属性抓取结束
# 开始BV号为1T54y1m78J视频属性的抓取
# BV号为1T54y1m78J的视频属性抓取结束
# 开始BV号为1gz4y1Z74F视频属性的抓取
# BV号为1gz4y1Z74F的视频属性抓取结束
# 开始BV号为1fp4y1e7Ua视频属性的抓取
# BV号为1fp4y1e7Ua的视频属性抓取结束
# 开始BV号为1D5411j7uE视频属性的抓取
# BV号为1D5411j7uE的视频属性抓取结束
# 开始BV号为1By4y1y7Xf视频属性的抓取
# BV号为1By4y1y7Xf的视频属性抓取结束
# 开始BV号为18y4y1y7Zs视频属性的抓取
# BV号为18y4y1y7Zs的视频属性抓取结束
# 开始BV号为1954y1C76N视频属性的抓取
# BV号为1954y1C76N的视频属性抓取结束
# 开始BV号为1oa4y177qJ视频属性的抓取
# BV号为1oa4y177qJ的视频属性抓取结束
# 开始BV号为1ap4y1a7iG视频属性的抓取
# BV号为1ap4y1a7iG的视频属性抓取结束
# 开始BV号为1KA411H7Xu视频属性的抓取
# BV号为1KA411H7Xu的视频属性抓取结束
# 开始BV号为1Wa4y1E7Tf视频属性的抓取
# BV号为1Wa4y1E7Tf的视频属性抓取结束
# 开始BV号为1KA411J7ix视频属性的抓取
# BV号为1KA411J7ix的视频属性抓取结束
# 开始BV号为1Ca4y157wp视频属性的抓取
# BV号为1Ca4y157wp的视频属性抓取结束
# 开始BV号为1454y1v7sQ视频属性的抓取
# BV号为1454y1v7sQ的视频属性抓取结束
# 开始BV号为1dv411C7Pi视频属性的抓取
# BV号为1dv411C7Pi的视频属性抓取结束
# 开始BV号为1bk4y1y7eZ视频属性的抓取
# BV号为1bk4y1y7eZ的视频属性抓取结束
# 开始BV号为1654y1C7ko视频属性的抓取
# BV号为1654y1C7ko的视频属性抓取结束
# 开始BV号为1kK411K7NP视频属性的抓取
# BV号为1kK411K7NP的视频属性抓取结束
# 开始BV号为1Nk4y1175J视频属性的抓取
# BV号为1Nk4y1175J的视频属性抓取结束
# 开始BV号为1xf4y1X71U视频属性的抓取
# BV号为1xf4y1X71U的视频属性抓取结束
# 开始BV号为1g5411j79Z视频属性的抓取
# BV号为1g5411j79Z的视频属性抓取结束
# 开始BV号为1fp4y1Y7SP视频属性的抓取
# BV号为1fp4y1Y7SP的视频属性抓取结束
# 开始BV号为1nZ4y1T7oJ视频属性的抓取
# BV号为1nZ4y1T7oJ的视频属性抓取结束
# 开始BV号为1Tp4y1e7mm视频属性的抓取
# BV号为1Tp4y1e7mm的视频属性抓取结束
# 开始BV号为1864y1F7Wd视频属性的抓取
# BV号为1864y1F7Wd的视频属性抓取结束
# 开始BV号为1Gt4y1q7Tj视频属性的抓取
# BV号为1Gt4y1q7Tj的视频属性抓取结束
# 开始BV号为1CA411n7pq视频属性的抓取
# BV号为1CA411n7pq的视频属性抓取结束
# 开始BV号为1Qi4y1E7CA视频属性的抓取
# BV号为1Qi4y1E7CA的视频属性抓取结束
# 开始BV号为1UD4y1o7Gu视频属性的抓取
# BV号为1UD4y1o7Gu的视频属性抓取结束
# 开始BV号为1St4y1S7Sb视频属性的抓取
# BV号为1St4y1S7Sb的视频属性抓取结束
# 开始BV号为1Up4y1e7AK视频属性的抓取
# BV号为1Up4y1e7AK的视频属性抓取结束
# 开始BV号为11p4y1a7ZF视频属性的抓取
# BV号为11p4y1a7ZF的视频属性抓取结束
# 开始BV号为17D4y1o7Rh视频属性的抓取
# BV号为17D4y1o7Rh的视频属性抓取结束
# 开始BV号为1mp4y1e7cm视频属性的抓取
# BV号为1mp4y1e7cm的视频属性抓取结束
# 开始BV号为1Zk4y1y7Rq视频属性的抓取
# BV号为1Zk4y1y7Rq的视频属性抓取结束
# 开始BV号为1Jh411971L视频属性的抓取
# BV号为1Jh411971L的视频属性抓取结束
# 开始BV号为1Vt4y1q76j视频属性的抓取
# BV号为1Vt4y1q76j的视频属性抓取结束
# 开始BV号为1k5411b73t视频属性的抓取
# BV号为1k5411b73t的视频属性抓取结束
# 开始BV号为1tv411C7Hc视频属性的抓取
# BV号为1tv411C7Hc的视频属性抓取结束
# 开始BV号为1bf4y1X73p视频属性的抓取
# BV号为1bf4y1X73p的视频属性抓取结束
# 开始BV号为1Bv411C7oz视频属性的抓取
# BV号为1Bv411C7oz的视频属性抓取结束
# 开始BV号为1sy4y1y7Kz视频属性的抓取
# BV号为1sy4y1y7Kz的视频属性抓取结束
# 开始BV号为1tz4y1Z7KN视频属性的抓取
# BV号为1tz4y1Z7KN的视频属性抓取结束
# 开始BV号为1Ha4y1E7JE视频属性的抓取
# BV号为1Ha4y1E7JE的视频属性抓取结束
# 开始BV号为1oi4y1M7a4视频属性的抓取
# BV号为1oi4y1M7a4的视频属性抓取结束
# 开始BV号为1XK411K7Du视频属性的抓取
# BV号为1XK411K7Du的视频属性抓取结束
# 开始BV号为1Bv41117at视频属性的抓取
# BV号为1Bv41117at的视频属性抓取结束
# 开始BV号为1wA411J7hn视频属性的抓取
# BV号为1wA411J7hn的视频属性抓取结束
# 开始BV号为1254y127NU视频属性的抓取
# BV号为1254y127NU的视频属性抓取结束
# 开始BV号为1fy4y1y7MK视频属性的抓取
# BV号为1fy4y1y7MK的视频属性抓取结束
# 开始BV号为1Zy4y1C7xm视频属性的抓取
# BV号为1Zy4y1C7xm的视频属性抓取结束
# 开始BV号为1954y12714视频属性的抓取
# BV号为1954y12714的视频属性抓取结束
# 开始BV号为17a4y1j7Wq视频属性的抓取
# BV号为17a4y1j7Wq的视频属性抓取结束
# 开始BV号为19V41127EU视频属性的抓取
# BV号为19V41127EU的视频属性抓取结束
# 开始BV号为1Ti4y1E7R1视频属性的抓取
# BV号为1Ti4y1E7R1的视频属性抓取结束
# 开始BV号为1bp4y1e7BF视频属性的抓取
# BV号为1bp4y1e7BF的视频属性抓取结束
# 开始BV号为1EZ4y157eH视频属性的抓取
# BV号为1EZ4y157eH的视频属性抓取结束
# 开始BV号为1Ni4y1u7Gr视频属性的抓取
# BV号为1Ni4y1u7Gr的视频属性抓取结束
# 开始BV号为1Pa4y1E729视频属性的抓取
# BV号为1Pa4y1E729的视频属性抓取结束
# 开始BV号为1ep4y1a7Yp视频属性的抓取
# BV号为1ep4y1a7Yp的视频属性抓取结束
# 开始BV号为1JV411S7oj视频属性的抓取
# BV号为1JV411S7oj的视频属性抓取结束
# 开始BV号为1ph411X7b2视频属性的抓取
# BV号为1ph411X7b2的视频属性抓取结束
# 开始BV号为11D4y1d7xD视频属性的抓取
# BV号为11D4y1d7xD的视频属性抓取结束
# 开始BV号为1aZ4y1N7ji视频属性的抓取
# BV号为1aZ4y1N7ji的视频属性抓取结束
# 开始BV号为1TK4y1a7CH视频属性的抓取
# BV号为1TK4y1a7CH的视频属性抓取结束
# 开始BV号为1z54y1k7Ad视频属性的抓取
# BV号为1z54y1k7Ad的视频属性抓取结束
# 开始BV号为1AZ4y1L7fi视频属性的抓取
# BV号为1AZ4y1L7fi的视频属性抓取结束
# 开始BV号为12r4y1c7S1视频属性的抓取
# BV号为12r4y1c7S1的视频属性抓取结束
# 开始BV号为1Dz4y1Z732视频属性的抓取
# BV号为1Dz4y1Z732的视频属性抓取结束
# 开始BV号为1aT4y1F7S6视频属性的抓取
# BV号为1aT4y1F7S6的视频属性抓取结束
# 开始BV号为1454y117ma视频属性的抓取
# BV号为1454y117ma的视频属性抓取结束
# 开始BV号为1Pp4y1k7KC视频属性的抓取
# BV号为1Pp4y1k7KC的视频属性抓取结束
# 开始BV号为1LA411E7u7视频属性的抓取
# BV号为1LA411E7u7的视频属性抓取结束
# 开始BV号为1zK4y1h7gk视频属性的抓取
# BV号为1zK4y1h7gk的视频属性抓取结束
# 开始BV号为155411L7DC视频属性的抓取
# BV号为155411L7DC的视频属性抓取结束
# 开始BV号为1oa411A7yS视频属性的抓取
# BV号为1oa411A7yS的视频属性抓取结束
# 开始BV号为1Ry4y1k7pc视频属性的抓取
# BV号为1Ry4y1k7pc的视频属性抓取结束
# 开始BV号为1Sa411w7ea视频属性的抓取
# BV号为1Sa411w7ea的视频属性抓取结束
# 开始BV号为1Bt4y1v7kv视频属性的抓取
# BV号为1Bt4y1v7kv的视频属性抓取结束
# 开始BV号为1Kf4y1B7mt视频属性的抓取
# BV号为1Kf4y1B7mt的视频属性抓取结束
# 开始BV号为16p4y1a7zP视频属性的抓取
# BV号为16p4y1a7zP的视频属性抓取结束
# 开始BV号为16p4y1k72s视频属性的抓取
# BV号为16p4y1k72s的视频属性抓取结束
# 开始BV号为1V5411L7fs视频属性的抓取
# BV号为1V5411L7fs的视频属性抓取结束
# 开始BV号为1BD4y1d7gH视频属性的抓取
# BV号为1BD4y1d7gH的视频属性抓取结束
# 开始BV号为1Hy4y1C7bh视频属性的抓取
# BV号为1Hy4y1C7bh的视频属性抓取结束
# 开始BV号为1Hy4y1B7xh视频属性的抓取
# BV号为1Hy4y1B7xh的视频属性抓取结束
# 开始BV号为1Pk4y1C7Wd视频属性的抓取
# BV号为1Pk4y1C7Wd的视频属性抓取结束
# 开始BV号为1PZ4y1L7KU视频属性的抓取
# BV号为1PZ4y1L7KU的视频属性抓取结束
# 开始BV号为18T4y1c7Dx视频属性的抓取
# BV号为18T4y1c7Dx的视频属性抓取结束
# 开始BV号为1kk4y1C7Sb视频属性的抓取
# BV号为1kk4y1C7Sb的视频属性抓取结束
# 开始BV号为1Ny4y1r7B6视频属性的抓取
# BV号为1Ny4y1r7B6的视频属性抓取结束
# 开始BV号为17a411A7D5视频属性的抓取
# BV号为17a411A7D5的视频属性抓取结束
# 开始BV号为1E54y1k7pN视频属性的抓取
# BV号为1E54y1k7pN的视频属性抓取结束
# 开始BV号为1Mz4y1f7Z7视频属性的抓取
# BV号为1Mz4y1f7Z7的视频属性抓取结束
# 开始BV号为1ph41197CP视频属性的抓取
# BV号为1ph41197CP的视频属性抓取结束
# 开始BV号为1c54y1C7YZ视频属性的抓取
# BV号为1c54y1C7YZ的视频属性抓取结束
# 开始BV号为1SA41177jm视频属性的抓取
# BV号为1SA41177jm的视频属性抓取结束
# 开始BV号为1et4y1q7nD视频属性的抓取
# BV号为1et4y1q7nD的视频属性抓取结束
# 开始BV号为1vh411X7eQ视频属性的抓取
# BV号为1vh411X7eQ的视频属性抓取结束
# 开始BV号为1NK4y1E7Q9视频属性的抓取
# BV号为1NK4y1E7Q9的视频属性抓取结束
# 开始BV号为18T4y1F7dE视频属性的抓取
# BV号为18T4y1F7dE的视频属性抓取结束
# 开始BV号为1PD4y1977Y视频属性的抓取
# BV号为1PD4y1977Y的视频属性抓取结束
# 开始BV号为1Mp4y1k7QD视频属性的抓取
# BV号为1Mp4y1k7QD的视频属性抓取结束
# 开始BV号为12f4y1B7BG视频属性的抓取
# BV号为12f4y1B7BG的视频属性抓取结束
# 开始BV号为1ua4y1s7b2视频属性的抓取
# BV号为1ua4y1s7b2的视频属性抓取结束
# 开始BV号为1Jy4y1r7df视频属性的抓取
# BV号为1Jy4y1r7df的视频属性抓取结束
# 开始BV号为11z4y1d7XL视频属性的抓取
# BV号为11z4y1d7XL的视频属性抓取结束
# 开始BV号为1pK4y1h7CK视频属性的抓取
# BV号为1pK4y1h7CK的视频属性抓取结束
# 开始BV号为1Vp4y1k7j5视频属性的抓取
# BV号为1Vp4y1k7j5的视频属性抓取结束
# 开始BV号为1r541157pK视频属性的抓取
# BV号为1r541157pK的视频属性抓取结束
# 开始BV号为1Nv411r7Ta视频属性的抓取
# BV号为1Nv411r7Ta的视频属性抓取结束
# 开始BV号为1Z54y1k7aB视频属性的抓取
# BV号为1Z54y1k7aB的视频属性抓取结束
# 开始BV号为14t4y1i7tv视频属性的抓取
# BV号为14t4y1i7tv的视频属性抓取结束
# 开始BV号为11541157bR视频属性的抓取
# BV号为11541157bR的视频属性抓取结束
# 开始BV号为16Z4y157j7视频属性的抓取
# BV号为16Z4y157j7的视频属性抓取结束
# 开始BV号为1BV411y7N9视频属性的抓取
# BV号为1BV411y7N9的视频属性抓取结束
# 开始BV号为1zA41177TV视频属性的抓取
# BV号为1zA41177TV的视频属性抓取结束
# 开始BV号为1wa4y1s7bU视频属性的抓取
# BV号为1wa4y1s7bU的视频属性抓取结束
# 开始BV号为1c54y1C7Vi视频属性的抓取
# BV号为1c54y1C7Vi的视频属性抓取结束
# 开始BV号为1mA411L7Hi视频属性的抓取
# BV号为1mA411L7Hi的视频属性抓取结束
# 开始BV号为1h5411j7bZ视频属性的抓取
# BV号为1h5411j7bZ的视频属性抓取结束
# 开始BV号为1B54y1R7qf视频属性的抓取
# BV号为1B54y1R7qf的视频属性抓取结束
# 开始BV号为1hK4y1h7pt视频属性的抓取
# BV号为1hK4y1h7pt的视频属性抓取结束
# 开始BV号为1Bz4y1o7A4视频属性的抓取
# BV号为1Bz4y1o7A4的视频属性抓取结束
# 开始BV号为1ty4y1C7h6视频属性的抓取
# 开始BV号为1ty4y1C7h6视频属性的抓取
# BV号为1ty4y1C7h6的视频属性抓取结束
# 开始BV号为1bT4y1c7Ci视频属性的抓取
# BV号为1bT4y1c7Ci的视频属性抓取结束
# 开始BV号为1154y117mb视频属性的抓取
# BV号为1154y117mb的视频属性抓取结束
# 开始BV号为16541157FS视频属性的抓取
# BV号为16541157FS的视频属性抓取结束
# 开始BV号为1Ct4y1v71p视频属性的抓取
# BV号为1Ct4y1v71p的视频属性抓取结束
# 开始BV号为1Lp4y1Y7Up视频属性的抓取
# BV号为1Lp4y1Y7Up的视频属性抓取结束
# 开始BV号为15a4y1L7UX视频属性的抓取
# BV号为15a4y1L7UX的视频属性抓取结束
# 开始BV号为1hv411k7eg视频属性的抓取
# BV号为1hv411k7eg的视频属性抓取结束
# 开始BV号为1ta4y1L7WL视频属性的抓取
# BV号为1ta4y1L7WL的视频属性抓取结束
# 开始BV号为1op4y1a7Kw视频属性的抓取
# BV号为1op4y1a7Kw的视频属性抓取结束
# 开始BV号为16K4y1778e视频属性的抓取
# BV号为16K4y1778e的视频属性抓取结束
# 开始BV号为1f54y167bW视频属性的抓取
# BV号为1f54y167bW的视频属性抓取结束
# 开始BV号为1Wi4y177ec视频属性的抓取
# BV号为1Wi4y177ec的视频属性抓取结束
# 开始BV号为1LT4y1F7nA视频属性的抓取
# BV号为1LT4y1F7nA的视频属性抓取结束
# 开始BV号为1Qa4y157J7视频属性的抓取
# BV号为1Qa4y157J7的视频属性抓取结束
# 开始BV号为1st4y1i7B9视频属性的抓取
# BV号为1st4y1i7B9的视频属性抓取结束
# 开始BV号为1mz4y1Z71h视频属性的抓取
# BV号为1mz4y1Z71h的视频属性抓取结束
# 开始BV号为1ua4y1s7nG视频属性的抓取
# BV号为1ua4y1s7nG的视频属性抓取结束
# 开始BV号为1nV411y7gx视频属性的抓取
# BV号为1nV411y7gx的视频属性抓取结束
# 开始BV号为1wy4y1C7xZ视频属性的抓取
# BV号为1wy4y1C7xZ的视频属性抓取结束
# 开始BV号为1jA411E7ox视频属性的抓取
# BV号为1jA411E7ox的视频属性抓取结束
# 开始BV号为1Wa411A7zz视频属性的抓取
# BV号为1Wa411A7zz的视频属性抓取结束
# 开始BV号为1Kk4y1y7mK视频属性的抓取
# BV号为1Kk4y1y7mK的视频属性抓取结束
# 开始BV号为1kz4y1d7Vr视频属性的抓取
# BV号为1kz4y1d7Vr的视频属性抓取结束
# 开始BV号为14t4y1i73R视频属性的抓取
# BV号为14t4y1i73R的视频属性抓取结束
# 开始BV号为1LT4y1F7fY视频属性的抓取
# BV号为1LT4y1F7fY的视频属性抓取结束
# 开始BV号为1wz4y1f74e视频属性的抓取
# BV号为1wz4y1f74e的视频属性抓取结束
# 开始BV号为1Vv411k7h2视频属性的抓取
# BV号为1Vv411k7h2的视频属性抓取结束
# 开始BV号为1zK4y177RT视频属性的抓取
# BV号为1zK4y177RT的视频属性抓取结束
# 开始BV号为1Ak4y1C7Z1视频属性的抓取
# BV号为1Ak4y1C7Z1的视频属性抓取结束
# 开始BV号为1S5411j7on视频属性的抓取
# BV号为1S5411j7on的视频属性抓取结束
# 开始BV号为19v411k7BB视频属性的抓取
# BV号为19v411k7BB的视频属性抓取结束
# 开始BV号为1wD4y1d78J视频属性的抓取
# BV号为1wD4y1d78J的视频属性抓取结束
# 开始BV号为1VV41127GQ视频属性的抓取
# BV号为1VV41127GQ的视频属性抓取结束
# 开始BV号为1fD4y1R7cx视频属性的抓取
# BV号为1fD4y1R7cx的视频属性抓取结束
# 开始BV号为1op4y1a7Bj视频属性的抓取
# BV号为1op4y1a7Bj的视频属性抓取结束
# 开始BV号为1Zf4y1D7qG视频属性的抓取
# BV号为1Zf4y1D7qG的视频属性抓取结束
# 开始BV号为1YV411175y视频属性的抓取
# BV号为1YV411175y的视频属性抓取结束
# 开始BV号为1gr4y1w7HC视频属性的抓取
# BV号为1gr4y1w7HC的视频属性抓取结束
# 开始BV号为1da4y1W7z4视频属性的抓取
# BV号为1da4y1W7z4的视频属性抓取结束
# 开始BV号为1Aa4y1L79v视频属性的抓取
# BV号为1Aa4y1L79v的视频属性抓取结束
# 开始BV号为1RV411173A视频属性的抓取
# BV号为1RV411173A的视频属性抓取结束
# 2020-12-16 08:41:55.005216

# %%
driver.switch_to_window(driver.window_handles[-1])
# Out:
# <ipython-input-14-dd0a1399d54d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[-1])

# %%
channel_youxi_zhuoyou.groupby('时间').agg('count')
# Out:
#      发布日期  作者名  作者类型  粉丝数  投稿数  视频名   分区  子分区  视频类型  自制or转载   标签  视频长度  播放量  \
# 时间
# 10月   100  100   100  100  100  100  100  100   100     100  100   100  100
# 1月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 2月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 3月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 4月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 5月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 6月     99   99    99   99   99   99   99   99    99      99   99    99   99
# 7月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 8月    100  100   100  100  100  100  100  100   100     100  100   100  100
# 9月    100  100   100  100  100  100  100  100   100     100  100   100  100
#
#      点赞数  投币数  收藏数  转发数  评论数  弹幕数  有无分集
# 时间
# 10月  100  100  100  100  100  100   100
# 1月   100  100  100  100  100  100   100
# 2月   100  100  100  100  100  100   100
# 3月   100  100  100  100  100  100   100
# 4月    99   99   99   99   99   99    99
# 5月   100  100  100  100  100  100   100
# 6月    99   99   99   99   99   99    99
# 7月   100  100  100  100  100  100   100
# 8月   100  100  100  100  100  100   100
# 9月   100  100  100  100  100  100   100

# %%
channel_youxi_zhuoyou.to_json('channel_youxi_zhuoyou.json')

# %%
pd.set_option('display.max_rows', None)

# %%
channel_youxi_danji[channel_youxi_danji['时间']=='4月']
# Out:
#             时间            作者名  作者类型      粉丝数   投稿数  \
# 1h54y1d7Qq  4月            鹤吱菌  个人认证   191.3万    81
# 1L64y1M7Dp  4月            老番茄  个人认证  1360.1万   348
# 18K41157Tu  4月            老番茄  个人认证  1360.1万   348
# 1PT4y1G7ME  4月            老番茄  个人认证  1360.1万   348
# 1S54y197uX  4月           徐大虾咯  个人认证   570.1万   224
# 1ti4y1t7YM  4月            老番茄  个人认证  1360.1万   348
# 1Ai4y1b7ET  4月            敖厂长  个人认证   735.1万   348
# 1Up4y1C7PB  4月        丢鹏D1uuu     无     8.4万    20
# 1wi4y187bu  4月     中国BOY超级大猩猩  个人认证   663.5万  1380
# 13t4y1U7kQ  4月           徐大虾咯  个人认证   570.1万   224
# 1fe411x7FA  4月         芦苇草的梦想  个人认证    29.3万   726
# 1LA411b7Dt  4月      LexBurner  个人认证   929.6万   383
# 1Ji4y1t7T9  4月            沧桑丸  个人认证    86.6万    57
